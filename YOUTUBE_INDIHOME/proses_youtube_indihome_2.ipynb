# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                             Indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    Saya tinggal di kabupaten Nabire Papua  dan me...
# 3    Ya allah kapan wifi indihome harga super murah...
# 4    Hah? Jaringan tanpa gangguan? Yakinn? Kalo lu ...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "Mak aku masuk yt makk wuu..."
# 175                                        Halo sayang
# 176                                            ribeeet
#
# [177 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 33

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                             Indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    Saya tinggal di kabupaten Nabire Papua  dan me...
# 3    Ya allah kapan wifi indihome harga super murah...
# 34   Channel di usee tv kurang lengkap...gk ada mnc...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "Mak aku masuk yt makk wuu..."
# 175                                        Halo sayang
# 176                                            ribeeet
#
# [114 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                             indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    saya tinggal di kabupaten nabire papua  dan me...
# 3    ya allah kapan wifi indihome harga super murah...
# 34   channel di usee tv kurang lengkap...gk ada mnc...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "mak aku masuk yt makk wuu..."
# 175                                        halo sayang
# 176                                            ribeeet
#
# [114 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                             indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    saya tinggal di kabupaten nabire papua  dan me...
# 3    ya allah kapan wifi indihome harga super murah...
# 34   channel di usee tv kurang lengkap...gk ada mnc...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "mak aku masuk yt makk wuu..."
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                         cleaning_tweet
# 0                               indihome   mbps mantap
# 1    koneksi sering putus berjam jam lemot pedot pe...
# 2    saya tinggal kabupaten nabire papua dan memang...
# 3     allah kapan wifi indihome harga super murah m...
# 34   channel usee kurang lengkap ada mnc media nya ...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru masang baru dua...
# 173                                       cantik mbak
# 174               bocah  bilek mak aku masuk makk wuu
# 175                                        halo sayang
# 176                                            ribeeet
#
# [114 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                             indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    saya tinggal di kabupaten nabire papua  dan me...
# 3    ya allah kapan wifi indihome harga super murah...
# 34   channel di usee tv kurang lengkap...gk ada mnc...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "mak aku masuk yt makk wuu..."
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                         cleaning_tweet  \
# 0                               indihome   mbps mantap
# 1    koneksi sering putus berjam jam lemot pedot pe...
# 2    saya tinggal kabupaten nabire papua dan memang...
# 3     allah kapan wifi indihome harga super murah m...
# 34   channel usee kurang lengkap ada mnc media nya ...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru masang baru dua...
# 173                                       cantik mbak
# 174               bocah  bilek mak aku masuk makk wuu
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                             tokenisasi
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, sering, putus, berjam, jam, lemot, p...
# 2    [saya, tinggal, kabupaten, nabire, papua, dan,...
# 3    [, allah, kapan, wifi, indihome, harga, super,...
# 34   [channel, usee, kurang, lengkap, ada, mnc, med...
# ..                                                 ...
# 172  [aku, baru, ajh, masang, idhme, baru, masang, ...
# 173                                   [cantik, mbak, ]
# 174       [bocah, bilek, mak, aku, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
# [114 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                             indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    saya tinggal di kabupaten nabire papua  dan me...
# 3    ya allah kapan wifi indihome harga super murah...
# 34   channel di usee tv kurang lengkap...gk ada mnc...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "mak aku masuk yt makk wuu..."
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                         cleaning_tweet  \
# 0                               indihome   mbps mantap
# 1    koneksi sering putus berjam jam lemot pedot pe...
# 2    saya tinggal kabupaten nabire papua dan memang...
# 3     allah kapan wifi indihome harga super murah m...
# 34   channel usee kurang lengkap ada mnc media nya ...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru masang baru dua...
# 173                                       cantik mbak
# 174               bocah  bilek mak aku masuk makk wuu
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                             tokenisasi  \
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, sering, putus, berjam, jam, lemot, p...
# 2    [saya, tinggal, kabupaten, nabire, papua, dan,...
# 3    [, allah, kapan, wifi, indihome, harga, super,...
# 34   [channel, usee, kurang, lengkap, ada, mnc, med...
# ..                                                 ...
# 172  [aku, baru, ajh, masang, idhme, baru, masang, ...
# 173                                   [cantik, mbak, ]
# 174       [bocah, bilek, mak, aku, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
#                                               stopword
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, putus, berjam, jam, lemot, pedot, pe...
# 2    [tinggal, kabupaten, nabire, papua, jaringan, ...
# 3    [, allah, wifi, indihome, harga, super, murah,...
# 34   [channel, usee, lengkap, mnc, media, susah, an...
# ..                                                 ...
# 172  [ajh, masang, idhme, masang, mingu, suruh, set...
# 173                                   [cantik, mbak, ]
# 174            [bocah, bilek, mak, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
# [114 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 330
# ------------------------
# indihome : indihome
# mbps : mbps
# mantap : mantap
# koneksi : koneksi
# putus : putus
# berjam : jam
# jam : jam
# lemot : lot
# pedot : pedot
# andalkan : andal
#  :
# tinggal : tinggal
# kabupaten : kabupaten
# nabire : nabire
# papua : papua
# jaringan : jaring
# diawal : awal
# pasang : pasang
# seharga : harga
# allah : allah
# wifi : wifi
# harga : harga
# super : super
# murah : murah
# meriah : riah
# iconnet : iconnet
# channel : channel
# usee : usee
# lengkap : lengkap
# mnc : mnc
# media : media
# susah : susah
# antena : antena
# bye : bye
# indihomo : indihomo
# move : move
# play : play
# nonton : nonton
# tugas : tugas
# video : video
# kasih : kasih
# lag : lag
# ngerjain : ngerjain
# malam : malam
# bet : bet
# make : make
# lelet : lelet
# bener : bener
# doang : doang
# bagus : bagus
# ngapain : ngapain
# report : report
# akun : akun
# gua : gua
# doa : doa
# cepet : cepet
# bangkrut : bangkrut
# kecepatannya : cepat
# udah : udah
# mahal : mahal
# mengecewakan : kecewa
# sumpah : sumpah
# ngajak : ngajak
# berantam : rantam
# mulu : mulu
# burik : burik
# jelek : jelek
# slow : slow
# internet : internet
# nonaktifkan : nonaktif
# komentar : komentar
# takut : takut
# maki : maki
# gara : gara
# lambat : lambat
# bayar : bayar
# puas : puas
# pelanggan : langgan
# taek : taek
# wes : wes
# mbayar : mbayar
# lemottt : lemottt
# mending : mending
# main : main
# roblox : roblox
# ping : ping
# sampe : sampe
# cpt : cpt
# nyesel : nyesel
# cok : cok
# biznet : biznet
# kecepatan : cepat
# gangguan : ganggu
# useetv : useetv
# dih : dih
# woi : woi
# gimana : gimana
# ngelag : ngelag
# download : download
# perdetik : detik
# push : push
# rank : rank
# kesal : kesal
# knpa : knpa
# sinyal : sinyal
# kali : kali
# masang : masang
# kena : kena
# marah : marah
# karna : karna
# telat : telat
# ngumpul : ngumpul
# ngeleggggg : ngeleggggg
# oyy : oyy
# lihat : lihat
# register : register
# aying : aying
# mobile : mobile
# buruk : buruk
# benci : benci
# sampah : sampah
# urusin : urusin
# yaa : yaa
# losestreak : losestreak
# pantek : pantek
# indigo : indigo
# pindah : pindah
# first : first
# lol : lol
# kek : kek
# ajg : ajg
# game : game
# keganggu : ganggu
# ama : ama
# kerja : kerja
# inditod : inditod
# ng : ng
# baiki : baik
# dlu : dlu
# jarinan : jarinan
# promosi : promosi
# nge : nge
# cuman : cuman
# rekomendasikan : rekomendasi
# mata : mata
# duitan : duit
# dengarkan : dengar
# customer : customer
# respon : respon
# giliran : gilir
# duit : duit
# maju : maju
# buriq : buriq
# ogah : ogah
# maen : maen
# iklan : iklan
# bisanya : bisa
# kualitas : kualitas
# kya : kya
# shit : shit
# terusssss : terusssss
# komen : komen
# nonaktif : nonaktif
# dibully : dibully
# maled : maled
# bermodal : modal
# noooobbbb : noooobbbb
# matamu : mata
# goyang : goyang
# ubur : ubur
# tettototetetete : tettototetetete
# bagoes : bagoes
# stres : stres
# ahahahah : ahahahah
# situ : situ
# ngelawak : ngelawak
# bngst : bngst
# leg : leg
# mlu : mlu
# batalin : batalin
# puasa : puasa
# gblk : gblk
# gaplok : gaplok
# bossnya : bossnya
# indogoblok : indogoblok
# valo : valo
# xie : xie
# lite : lite
# dongo : dongo
# yng : yng
# cpet : cpet
# jncvk : jncvk
# sinya : sinya
# bab : bab
# kon : kon
# turun : turun
# terbaik : baik
# penipu : tipu
# kak : kak
# rumah : rumah
# dipasang : pasang
# tiang : tiang
# nunggu : nunggu
# aktif : aktif
# prosesnya : proses
# emang : emang
# bun : bun
# paketnya : paket
# ppn : ppn
# biaya : biaya
# bulanannya : bulan
# mengikuti : ikut
# terbaru : baru
# fup : fup
# banget : banget
# jaringannya : jaring
# ambil : ambil
# paket : paket
# promo : promo
# ribu : ribu
# blacklist : blacklist
# pengaruh : pengaruh
# checking : checking
# bantu : bantu
# gan : gan
# mba : mba
# pembayaran : bayar
# tagihan : tagih
# mbak : mbak
# klu : klu
# diakhir : akhir
# bln : bln
# bearti : bearti
# pemasangan : pasang
# mohon : mohon
# dijwb : dijwb
# trm : trm
# ksih : ksih
# pke : pke
# sebulan : bulan
# rebu : rebu
# tgl : tgl
# pengajuan : aju
# terpasang : pasang
# unlimited : unlimited
# sebulannya : bulan
# berubah : ubah
# pemakaiannya : pakai
# tlp : tlp
# ttangga : ttangga
# kenceng : kenceng
# youtuban : youtuban
# tolong : tolong
# pencerahannya : cerah
# mantaaap : mantaaap
# menit : menit
# lucu : lucu
# hahaha : hahaha
# paketan : paket
# kabel : kabel
# kah : kah
# agustus : agustus
# kemarin : kemarin
# rbu : rbu
# ehh : ehh
# depannya : depan
# tagihanya : tagihanya
# dejelasin : dejelasin
# beneran : beneran
# pingin : pingin
# acc : acc
# suami : suami
# uplod : uplod
# ngak : ngak
# browsing : browsing
# males : males
# pakek : pakek
# saha : saha
# skrg : skrg
# nyaman : nyaman
# dipake : dipake
# ngegame : ngegame
# gue : gue
# cabang : cabang
# melibatkan : libat
# telkom : telkom
# teman : teman
# dicabangkan : cabang
# batasi : batas
# alat : alat
# iuran : iur
# password : password
# diganti : ganti
# menjelang : jelang
# pemakaian : pakai
# melebihi : lebih
# nggak : nggak
# dibayar : bayar
# hemat : hemat
# dedeknya : dedek
# ngilang : ngilang
# november : november
# berlangganan : langgan
# cabut : cabut
# denda : denda
# jt : jt
# peraturan : atur
# barunya : baru
# tyas : tyas
# cantik : cantik
# asli : asli
# jujur : jujur
# mbaknya : mbak
# guyz : guyz
# ajh : ajh
# idhme : idhme
# mingu : mingu
# suruh : suruh
# setor : setor
# coba : coba
# inpormasinyh : inpormasinyh
# bocah : bocah
# bilek : bilek
# mak : mak
# masuk : masuk
# makk : makk
# wuu : wuu
# halo : halo
# sayang : sayang
# ribeeet : ribeeet
# {'indihome': 'indihome', 'mbps': 'mbps', 'mantap': 'mantap', 'koneksi': 'koneksi', 'putus': 'putus', 'berjam': 'jam', 'jam': 'jam', 'lemot': 'lot', 'pedot': 'pedot', 'andalkan': 'andal', '': '', 'tinggal': 'tinggal', 'kabupaten': 'kabupaten', 'nabire': 'nabire', 'papua': 'papua', 'jaringan': 'jaring', 'diawal': 'awal', 'pasang': 'pasang', 'seharga': 'harga', 'allah': 'allah', 'wifi': 'wifi', 'harga': 'harga', 'super': 'super', 'murah': 'murah', 'meriah': 'riah', 'iconnet': 'iconnet', 'channel': 'channel', 'usee': 'usee', 'lengkap': 'lengkap', 'mnc': 'mnc', 'media': 'media', 'susah': 'susah', 'antena': 'antena', 'bye': 'bye', 'indihomo': 'indihomo', 'move': 'move', 'play': 'play', 'nonton': 'nonton', 'tugas': 'tugas', 'video': 'video', 'kasih': 'kasih', 'lag': 'lag', 'ngerjain': 'ngerjain', 'malam': 'malam', 'bet': 'bet', 'make': 'make', 'lelet': 'lelet', 'bener': 'bener', 'doang': 'doang', 'bagus': 'bagus', 'ngapain': 'ngapain', 'report': 'report', 'akun': 'akun', 'gua': 'gua', 'doa': 'doa', 'cepet': 'cepet', 'bangkrut': 'bangkrut', 'kecepatannya': 'cepat', 'udah': 'udah', 'mahal': 'mahal', 'mengecewakan': 'kecewa', 'sumpah': 'sumpah', 'ngajak': 'ngajak', 'berantam': 'rantam', 'mulu': 'mulu', 'burik': 'burik', 'jelek': 'jelek', 'slow': 'slow', 'internet': 'internet', 'nonaktifkan': 'nonaktif', 'komentar': 'komentar', 'takut': 'takut', 'maki': 'maki', 'gara': 'gara', 'lambat': 'lambat', 'bayar': 'bayar', 'puas': 'puas', 'pelanggan': 'langgan', 'taek': 'taek', 'wes': 'wes', 'mbayar': 'mbayar', 'lemottt': 'lemottt', 'mending': 'mending', 'main': 'main', 'roblox': 'roblox', 'ping': 'ping', 'sampe': 'sampe', 'cpt': 'cpt', 'nyesel': 'nyesel', 'cok': 'cok', 'biznet': 'biznet', 'kecepatan': 'cepat', 'gangguan': 'ganggu', 'useetv': 'useetv', 'dih': 'dih', 'woi': 'woi', 'gimana': 'gimana', 'ngelag': 'ngelag', 'download': 'download', 'perdetik': 'detik', 'push': 'push', 'rank': 'rank', 'kesal': 'kesal', 'knpa': 'knpa', 'sinyal': 'sinyal', 'kali': 'kali', 'masang': 'masang', 'kena': 'kena', 'marah': 'marah', 'karna': 'karna', 'telat': 'telat', 'ngumpul': 'ngumpul', 'ngeleggggg': 'ngeleggggg', 'oyy': 'oyy', 'lihat': 'lihat', 'register': 'register', 'aying': 'aying', 'mobile': 'mobile', 'buruk': 'buruk', 'benci': 'benci', 'sampah': 'sampah', 'urusin': 'urusin', 'yaa': 'yaa', 'losestreak': 'losestreak', 'pantek': 'pantek', 'indigo': 'indigo', 'pindah': 'pindah', 'first': 'first', 'lol': 'lol', 'kek': 'kek', 'ajg': 'ajg', 'game': 'game', 'keganggu': 'ganggu', 'ama': 'ama', 'kerja': 'kerja', 'inditod': 'inditod', 'ng': 'ng', 'baiki': 'baik', 'dlu': 'dlu', 'jarinan': 'jarinan', 'promosi': 'promosi', 'nge': 'nge', 'cuman': 'cuman', 'rekomendasikan': 'rekomendasi', 'mata': 'mata', 'duitan': 'duit', 'dengarkan': 'dengar', 'customer': 'customer', 'respon': 'respon', 'giliran': 'gilir', 'duit': 'duit', 'maju': 'maju', 'buriq': 'buriq', 'ogah': 'ogah', 'maen': 'maen', 'iklan': 'iklan', 'bisanya': 'bisa', 'kualitas': 'kualitas', 'kya': 'kya', 'shit': 'shit', 'terusssss': 'terusssss', 'komen': 'komen', 'nonaktif': 'nonaktif', 'dibully': 'dibully', 'maled': 'maled', 'bermodal': 'modal', 'noooobbbb': 'noooobbbb', 'matamu': 'mata', 'goyang': 'goyang', 'ubur': 'ubur', 'tettototetetete': 'tettototetetete', 'bagoes': 'bagoes', 'stres': 'stres', 'ahahahah': 'ahahahah', 'situ': 'situ', 'ngelawak': 'ngelawak', 'bngst': 'bngst', 'leg': 'leg', 'mlu': 'mlu', 'batalin': 'batalin', 'puasa': 'puasa', 'gblk': 'gblk', 'gaplok': 'gaplok', 'bossnya': 'bossnya', 'indogoblok': 'indogoblok', 'valo': 'valo', 'xie': 'xie', 'lite': 'lite', 'dongo': 'dongo', 'yng': 'yng', 'cpet': 'cpet', 'jncvk': 'jncvk', 'sinya': 'sinya', 'bab': 'bab', 'kon': 'kon', 'turun': 'turun', 'terbaik': 'baik', 'penipu': 'tipu', 'kak': 'kak', 'rumah': 'rumah', 'dipasang': 'pasang', 'tiang': 'tiang', 'nunggu': 'nunggu', 'aktif': 'aktif', 'prosesnya': 'proses', 'emang': 'emang', 'bun': 'bun', 'paketnya': 'paket', 'ppn': 'ppn', 'biaya': 'biaya', 'bulanannya': 'bulan', 'mengikuti': 'ikut', 'terbaru': 'baru ...
# ------------------------
# Pandas Apply:   0%|          | 0/114 [00:00<?, ?it/s]
#                                                comment  \
# 0                             indihome 300 mbps mantap
# 1    koneksi sering putus berjam-jam lemot pedot-pe...
# 2    saya tinggal di kabupaten nabire papua  dan me...
# 3    ya allah kapan wifi indihome harga super murah...
# 34   channel di usee tv kurang lengkap...gk ada mnc...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru  masang baru du...
# 173                                     cantik mbak ny
# 174       bocah2 bilek: "mak aku masuk yt makk wuu..."
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                         cleaning_tweet  \
# 0                               indihome   mbps mantap
# 1    koneksi sering putus berjam jam lemot pedot pe...
# 2    saya tinggal kabupaten nabire papua dan memang...
# 3     allah kapan wifi indihome harga super murah m...
# 34   channel usee kurang lengkap ada mnc media nya ...
# ..                                                 ...
# 172  aku baru ajh masang idhme baru masang baru dua...
# 173                                       cantik mbak
# 174               bocah  bilek mak aku masuk makk wuu
# 175                                        halo sayang
# 176                                            ribeeet
#
#                                             tokenisasi  \
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, sering, putus, berjam, jam, lemot, p...
# 2    [saya, tinggal, kabupaten, nabire, papua, dan,...
# 3    [, allah, kapan, wifi, indihome, harga, super,...
# 34   [channel, usee, kurang, lengkap, ada, mnc, med...
# ..                                                 ...
# 172  [aku, baru, ajh, masang, idhme, baru, masang, ...
# 173                                   [cantik, mbak, ]
# 174       [bocah, bilek, mak, aku, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
#                                               stopword  \
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, putus, berjam, jam, lemot, pedot, pe...
# 2    [tinggal, kabupaten, nabire, papua, jaringan, ...
# 3    [, allah, wifi, indihome, harga, super, murah,...
# 34   [channel, usee, lengkap, mnc, media, susah, an...
# ..                                                 ...
# 172  [ajh, masang, idhme, masang, mingu, suruh, set...
# 173                                   [cantik, mbak, ]
# 174            [bocah, bilek, mak, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
#                                               stemming
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, putus, jam, jam, lot, pedot, pedot, ...
# 2    [tinggal, kabupaten, nabire, papua, jaring, in...
# 3    [, allah, wifi, indihome, harga, super, murah,...
# 34   [channel, usee, lengkap, mnc, media, susah, an...
# ..                                                 ...
# 172  [ajh, masang, idhme, masang, mingu, suruh, set...
# 173                                   [cantik, mbak, ]
# 174            [bocah, bilek, mak, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
# [114 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0                             [indihome, mbps, mantap]
# 1    [koneksi, putus, jam, jam, lot, pedot, pedot, ...
# 2    [tinggal, kabupaten, nabire, papua, jaring, in...
# 3    [, allah, wifi, indihome, harga, super, murah,...
# 34   [channel, usee, lengkap, mnc, media, susah, an...
# ..                                                 ...
# 172  [ajh, masang, idhme, masang, mingu, suruh, set...
# 173                                   [cantik, mbak, ]
# 174            [bocah, bilek, mak, masuk, makk, wuu, ]
# 175                                     [halo, sayang]
# 176                                          [ribeeet]
#
# [114 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_2.xlsx')
