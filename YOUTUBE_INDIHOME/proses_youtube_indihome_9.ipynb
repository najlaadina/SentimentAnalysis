# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Alhamdulillah Surabaya udh gak gangguan,walaup...
# 1    PALEMBANG ILANG TIMBUL,,, YA SEMOGA CEPAT SELE...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    Saya sebagai karyawan yang sedang melakukan wo...
# 4    Di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              Gw mau ganti kartu aj
# 483                    Sat mo login epep malah gk bisa
# 484                                Lah Telkomsel anjgg
# 485                Masih gak bisa konek FB dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
# [487 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 114

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Alhamdulillah Surabaya udh gak gangguan,walaup...
# 1    PALEMBANG ILANG TIMBUL,,, YA SEMOGA CEPAT SELE...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    Saya sebagai karyawan yang sedang melakukan wo...
# 4    Di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              Gw mau ganti kartu aj
# 483                    Sat mo login epep malah gk bisa
# 484                                Lah Telkomsel anjgg
# 485                Masih gak bisa konek FB dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
# [264 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    alhamdulillah surabaya udh gak gangguan,walaup...
# 1    palembang ilang timbul,,, ya semoga cepat sele...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4    di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              gw mau ganti kartu aj
# 483                    sat mo login epep malah gk bisa
# 484                                lah telkomsel anjgg
# 485                masih gak bisa konek fb dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
# [264 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah surabaya udh gak gangguan,walaup...
# 1    palembang ilang timbul,,, ya semoga cepat sele...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4    di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              gw mau ganti kartu aj
# 483                    sat mo login epep malah gk bisa
# 484                                lah telkomsel anjgg
# 485                masih gak bisa konek fb dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
#                                       cleaning_comment
# 0    alhamdulillah surabaya udh gak gangguan walaup...
# 1    palembang ilang timbul semoga cepat selesai ur...
# 2    harusnya pelanggan mendapatkan kompensasi piha...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4     era masa kini langganan internet mending jang...
# ..                                                 ...
# 482                                   mau ganti kartu
# 483                          sat login epep malah bisa
# 484                                lah telkomsel anjgg
# 485                     masih gak bisa konek dan game
# 486   skolah gua kya apa bisa buka gogle lgi jonton...
#
# [264 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah surabaya udh gak gangguan,walaup...
# 1    palembang ilang timbul,,, ya semoga cepat sele...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4    di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              gw mau ganti kartu aj
# 483                    sat mo login epep malah gk bisa
# 484                                lah telkomsel anjgg
# 485                masih gak bisa konek fb dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
#                                       cleaning_comment  \
# 0    alhamdulillah surabaya udh gak gangguan walaup...
# 1    palembang ilang timbul semoga cepat selesai ur...
# 2    harusnya pelanggan mendapatkan kompensasi piha...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4     era masa kini langganan internet mending jang...
# ..                                                 ...
# 482                                   mau ganti kartu
# 483                          sat login epep malah bisa
# 484                                lah telkomsel anjgg
# 485                     masih gak bisa konek dan game
# 486   skolah gua kya apa bisa buka gogle lgi jonton...
#
#                                             tokenisasi
# 0    [alhamdulillah, surabaya, udh, gak, gangguan, ...
# 1    [palembang, ilang, timbul, semoga, cepat, sele...
# 2    [harusnya, pelanggan, mendapatkan, kompensasi,...
# 3    [saya, sebagai, karyawan, yang, sedang, melaku...
# 4    [, era, masa, kini, langganan, internet, mendi...
# ..                                                 ...
# 482                            [, mau, ganti, kartu, ]
# 483                    [sat, login, epep, malah, bisa]
# 484                            [lah, telkomsel, anjgg]
# 485             [masih, gak, bisa, konek, dan, game, ]
# 486  [, skolah, gua, kya, apa, bisa, buka, gogle, l...
#
# [264 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah surabaya udh gak gangguan,walaup...
# 1    palembang ilang timbul,,, ya semoga cepat sele...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4    di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              gw mau ganti kartu aj
# 483                    sat mo login epep malah gk bisa
# 484                                lah telkomsel anjgg
# 485                masih gak bisa konek fb dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
#                                       cleaning_comment  \
# 0    alhamdulillah surabaya udh gak gangguan walaup...
# 1    palembang ilang timbul semoga cepat selesai ur...
# 2    harusnya pelanggan mendapatkan kompensasi piha...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4     era masa kini langganan internet mending jang...
# ..                                                 ...
# 482                                   mau ganti kartu
# 483                          sat login epep malah bisa
# 484                                lah telkomsel anjgg
# 485                     masih gak bisa konek dan game
# 486   skolah gua kya apa bisa buka gogle lgi jonton...
#
#                                             tokenisasi  \
# 0    [alhamdulillah, surabaya, udh, gak, gangguan, ...
# 1    [palembang, ilang, timbul, semoga, cepat, sele...
# 2    [harusnya, pelanggan, mendapatkan, kompensasi,...
# 3    [saya, sebagai, karyawan, yang, sedang, melaku...
# 4    [, era, masa, kini, langganan, internet, mendi...
# ..                                                 ...
# 482                            [, mau, ganti, kartu, ]
# 483                    [sat, login, epep, malah, bisa]
# 484                            [lah, telkomsel, anjgg]
# 485             [masih, gak, bisa, konek, dan, game, ]
# 486  [, skolah, gua, kya, apa, bisa, buka, gogle, l...
#
#                                               stopword
# 0    [alhamdulillah, surabaya, udh, gangguan, nge, ...
# 1    [palembang, ilang, timbul, semoga, cepat, sele...
# 2                    [pelanggan, kompensasi, indihome]
# 3    [karyawan, work, from, home, merugikan, jaring...
# 4    [, era, langganan, internet, mending, ngasih, ...
# ..                                                 ...
# 482                                 [, ganti, kartu, ]
# 483                                 [sat, login, epep]
# 484                                 [telkomsel, anjgg]
# 485                                    [konek, game, ]
# 486  [, skolah, gua, kya, buka, gogle, lgi, jonton,...
#
# [264 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 845
# ------------------------
# alhamdulillah : alhamdulillah
# surabaya : surabaya
# udh : udh
# gangguan : ganggu
# nge : nge
# game : game
# ngelag : ngelag
# detik : detik
# gpp : gpp
# dll : dll
# lancar : lancar
# jaya : jaya
# palembang : palembang
# ilang : ilang
# timbul : timbul
# semoga : moga
# cepat : cepat
# selesai : selesai
# urusannya : urus
# kelancaran : lancar
# memperbaikinya : baik
# pelanggan : langgan
# kompensasi : kompensasi
# indihome : indihome
# karyawan : karyawan
# work : work
# from : from
# home : home
# merugikan : rugi
# jaringan : jaring
# internet : internet
#  :
# era : era
# langganan : langgan
# mending : mending
# ngasih : ngasih
# denda : denda
# berhenti : henti
# luwes : luwes
# ragukan : ragu
# layanannya : layan
# gampang : gampang
# pindah : pindah
# provider : provider
# buka : buka
# steam : steam
# gabisa : gabisa
# valorant : valorant
# benernya : benernya
# parah : parah
# kompensasinya : kompensasi
# tolonglah : tolong
# tanyain : tanyain
# banyumas : banyumas
# lemot : lot
# pol : pol
# alesan : alesan
# pembenahan : benah
# anakku : anak
# daftar : daftar
# online : online
# baya : baya
# dipasang : pasang
# lbh : lbh
# blm : blm
# telkomsel : telkomsel
# tanggal : tanggal
# tutup : tutup
# indonesia : indonesia
# paket : paket
# usaha : usaha
# hitungan : hitung
# jam : jam
# berahir : berahir
# bli : bli
# samasekali : samasekali
# hasil : hasil
# rugi : rugi
# gimana : gimana
# untung : untung
# solo : solo
# nie : nie
# cafe : cafe
# lum : lum
# pendapatan : dapat
# sewa : sewa
# manusia : manusia
# laut : laut
# aquaman : aquaman
# putus : putus
# wwkwkwk : wwkwkwk
# purwokerto : purwokerto
# lag : lag
# wifinya : wifinya
# pasang : pasang
# wifi : wifi
# tolong : tolong
# ngomong : ngomong
# sinyal : sinyal
# rusak : rusak
# pakek : pakek
# data : data
# pokoknya : pokok
# gat : gat
# aceh : aceh
# maaih : maaih
# matot : matot
# mati : mati
# total : total
# area : area
# waru : waru
# brp : brp
# ganti : ganti
# perdana : perdana
# gangguanya : gangguanya
# indihomenya : indihomenya
# banget : banget
# ihhhh : ihhhh
# ksian : ksi
# warga : warga
# sampe : sampe
# buffer : buffer
# mulu : mulu
# ngeleg : ngeleg
# cug : cug
# parahhh : parahhh
# minggu : minggu
# owh : owh
# whhhh : whhhh
# blok : blok
# jmn : jmn
# dlu : dlu
# simple : simple
# endpoint : endpoint
# href : href
# tribunnews : tribunnews
# salut : salut
# telkom : telkom
# pelayanan : layan
# memuakkan : muak
# indohome : indohome
# dirumah : rumah
# prestasi : prestasi
# dipertahankan : tahan
# perkembangan : kembang
# tol : tol
# darat : darat
# berjalan : jalan
# udara : udara
# kiblatnya : kiblat
# kayak : kayak
# gini : gin
# pertahankan : tahan
# bayar : bayar
# mahal : mahal
# coneksi : coneksi
# lemotnya : lot
# luarbiasa : luarbiasa
# maaf : maaf
# kalimantan : kalimantan
# utara : utara
# aduhaiii : aduhaiii
# lambat : lambat
# kena : kena
# sungguh : sungguh
# mengecewakan : kecewa
# daerah : daerah
# jember : jember
# jawa : jawa
# timur : timur
# secepatnya : cepat
# normalkan : normal
# salah : salah
# ndak : ndak
# bayarnya : bayar
# full : full
# kerjaan : kerja
# terganggu : ganggu
# down : down
# discount : discount
# tanggung : tanggung
# pintar : pintar
# teknologi : teknologi
# menagih : tagih
# bayaran : bayar
# mengkompensasi : kompensasi
# kerugian : rugi
# trenggalek : trenggalek
# ajur : ajur
# koneksi : koneksi
# kerahkan : kerah
# sdm : sdm
# budget : budget
# perush : perush
# membereskan : beres
# sekelas : kelas
# isa : isa
# lucu : lucu
# kasi : kasi
# gara : gara
# gue : gue
# puluhan : puluh
# juta : juta
# allah : allah
# dpt : dpt
# murahan : murah
# konsumen : konsumen
# balikpapan : balikpapan
# tgl : tgl
# tagihan : tagih
# akses : akses
# malam : malam
# ajah : ajah
# telat : telat
# berharii : hari
# kopensasinya : kopensasinya
# efek : efek
# biznet : biznet
# spanduk : spanduk
# promosi : promosi
# giliran : gilir
# lemoot : lemoot
# sedunia : dunia
# otak : otak
# fikir : fikir
# mlhn : mlhn
# bbrp : bbrp
# buln : buln
# dlm : dlm
# rumh : rumh
# memakai : pakai
# pdhl : pdhl
# meter : meter
# anehnya : aneh
# numpang : numpang
# normal : normal
# tetangga : tetangga
# potongan : potong
# pembayaran : bayar
# doang : doang
# hri : hri
# doank : doank
# makan : makan
# gaji : gaji
# buta : buta
# sayang : sayang
# kota : kota
# ane : ane
# perbaikan : baik
# dilayanannya : layan
# udah : udah
# lelet : lelet
# dasar : dasar
# mutu : mutu
# emang : emang
# harapkan : harap
# btw : btw
# pengalaman : alam
# gua : gua
# tetaplah : tetap
# kadang : kadang
# suka : suka
# kesel : kesel
# signal : signal
# ditempat : tempat
# pas : pas
# beli : beli
# ahsudahlah : ahsudahlah
# komen : komen
# dengarkan : dengar
# merubah : rubah
# kaga : kaga
# dibayar : bayar
# costumer : costumer
# bagus : bagus
# ancur : ancur
# yasallam : yasallam
# rumah : rumah
# alami : alami
# tangsel : tangsel
# perusak : usak
# pencari : cari
# cuan : cuan
# konter : konter
# tiadakan : tiada
# indhihome : indhihome
# enakan : enak
# byk : byk
# swasta : swasta
# kecang : cang
# jaringanya : jaringanya
# murah : murah
# byr : byr
# bln : bln
# trus : trus
# pemaksinya : maksi
# krg : krg
# thn : thn
# finalti : finalti
# menurun : turun
# terlimot : terlimot
# asean : asean
# indonrsia : indonrsia
# sumber : sumber
# nikel : nikel
# tembaga : tembaga
# terbesar : besar
# kalah : kalah
# singapura : singapura
# thailand : thailand
# malaysia : malaysia
# vietnam : vietnam
# filipina : filipina
# smua : smua
# serba : serba
# tertinggal : tinggal
# jelek : jelek
# kya : kya
# kbelnya : kbelnya
# smrawut : smrawut
# pinggir : pinggir
# jalan : jalan
# listrik : listrik
# kelupaan : lupa
# neh : neh
# muter : muter
# aneh : aneh
# nggak : nggak
# konspensasi : konspensasi
# dahlah : dah
# fix : fix
# layanan : layan
# sebelah : belah
# maksimal : maksimal
# keknya : kek
# proveder : proveder
# maintence : maintence
# pengecekan : kece
# kabel : kabel
# air : air
# nyaritau : nyaritau
# masalhnya : masalhnya
# penjahat : jahat
# kuota : kuota
# tukang : tukang
# maling : maling
# hukum : hukum
# ringan : ringan
# cuk : cuk
# sekarat : sekarat
# mbps : mbps
# pamake : pamake
# orang : orang
# kbps : kbps
# percept : percept
# permulihan : permulihan
# daring : daring
# kmaren : kmaren
# kasih : kasih
# proyek : proyek
# tri : tri
# stabil : stabil
# apabisa : apabisa
# maafkan : maaf
# iya : iya
# kacau : kacau
# kacauu : kacauu
# kecewaa : kecewaa
# ditambah : tambah
# gratis : gratis
# indihomeee : indihomeee
# mata : mata
# uang : uang
# terlmbt : terlmbt
# pelayan : layan
# buruk : buruk
# ayo : ayo
# rame : rame
# pindh : pindh
# dri : dri
# bgus : bgus
# kesini : kesini
# berkualitas : kualitas
# msh : msh
# dipake : dipake
# tinggal : tinggal
# beres : beres
# menghujat : hujat
# trs : trs
# maafin : maafin
# internetnya : internetnya
# kendalanya : kendala
# doain : doain
# moga : moga
# buatan : buat
# pln : pln
# resmikan : resmi
# kesitu : kesitu
# memalukan : malu
# cabut : cabut
# nagih : nagih
# penanganan : tangan
# bet : bet
# jringn : jringn
# dhlah : dhlah
# gnti : gnti
# kosan : kosan
# pulkam : pulkam
# lantaran : lantar
# kuliah : kuliah
# modem : modem
# ont : ont
# matiin : matiin
# notifikasi : notifikasi
# pemakaian : pakai
# melebihi : lebih
# fup : fup
# suruh : suruh
# upgrade : upgrade
# laporan : lapor
# bogor : bogor
# selatan : selatan
# gang : gang
# guan : guan
# main : main
# mantab : mantab
# bun : bun
# eropa : eropa
# triliunan : triliun
# cape : cape
# ngadepinnya : ngadepinnya
# dijepang : dijepang
# cerita : cerita
# harga : harga
# kaget : kaget
# liat : liat
# berita : berita
# kolo : kolo
# kualitas : kualitas
# videonya : video
# itupun : itu
# sangkut : sangkut
# dengar : dengar
# kiamat : kiamat
# hoax : hoax
# engga : engga
# penyebabnya : sebab
# mksud : mksud
# ribu : ribu
# kirain : kirain
# ngeluh : ngeluh
# eror : eror
# kek : kek
# gitu : gitu
# indihom : indihom
# yap : yap
# skrang : skrang
# pool : pool
# anjj : anjj
# guaa : guaa
# kenak : nak
# santet : santet
# wkwkwk : wkwkwk
# bismillah : bismillah
# nyata : nyata
# perbaiki : baik
# bandung : bandung
# loading : loading
# teruss : teruss
# pdhlkan : pdhlkan
# lohh : lohh
# mengontol : kontol
# maen : maen
# afk : afk
# mengoleskan : oles
# krim : krim
# anti : anti
# jt : jt
# org : org
# kali : kali
# ratusan : ratus
# kemarin : kemarin
# kab : kab
# bekasi : bekas
# indigo : indigo
# alfamart : alfamart
# takutnya : takut
# trouble : trouble
# tgal : tgal
# sistem : sistem
# beroperasi : operasi
# perbaikannya : baik
# sehari : hari
# pengennya : ken
# daya : daya
# jayapura : jayapura
# diperbaiki : baik
# tikus : tikus
# berbohong : bohong
# gulung : gulung
# tikar : tikar
# gmanaa : gmanaa
# nii : nii
# renew : renew
# eee : eee
# sia : sia
# dapet : dapet
# diskon : diskon
# wilayah : wilayah
# bantul : bantul
# yogyakarta : yogyakarta
# pagi : pagi
# ehhh : ehhh
# siang : siang
# lgi : lgi
# pencet : pencet
# terdampak : dampak
# massal : massal
# hadehhhh : hadehhhh
# mendingan : mending
# indomie : indomie
# mudah : mudah
# dapt : dapt
# gratisan : gratis
# iyah : iyah
# asikk : asikk
# turun : turun
# saham : saham
# myrepublik : myrepublik
# tertawa : tertawa
# indikator : indikator
# pon : pon
# indomaret : indomaret
# karna : karna
# tmksh : tmksh
# amburadul : amburadul
# teross : teross
# mmk : mmk
# exel : exel
# you : you
# tube : tube
# cast : cast
# kpn : kpn
# indie : indie
# woy : woy
# besok : besok
# paketan : paket
# pkek : pkek
# tetep : tetep
# kontollll : kontollll
# nyejek : nyejek
# dendanya : denda
# kapok : kapok
# bumn : bumn
# gtu : gtu
# mengambil : ambil
# alih : alih
# indosat : indosat
# apan : apan
# sans : sans
# pemakai : pakai
# ttanga : ttanga
# sperti : sperti
# kaarmaa : kaarmaa
# berlaku : laku
# upload : upload
# file : file
# serasa : serasa
# njer : njer
# its : its
# maybe : maybe
# cina : cina
# doing : doing
# ahli : ahli
# yaaa : yaaa
# oke : oke
# didenda : denda
# kebanyakan : banyak
# diutak : diutak
# atik : atik
# maklum : maklum
# namanya : nama
# kalanya : kala
# smoga : smoga
# sij : sij
# hilang : hilang
# ahhhhh : ahhhhh
# ampas : ampas
# tergantung : gantung
# butuh : butuh
# terimakasih : terimakasih
# pushrank : pushrank
# bentar : bentar
# season : season
# nomor : nomor
# kayaknya : kayak
# dicoba : coba
# keuangan : uang
# sulit : sulit
# apresiasi : apresiasi
# jng : jng
# arogan : arogan
# karn : karn
# bos : bos
# klw : klw
# terim : rim
# gila : gila
# nunggu : nunggu
# stabill : stabill
# sakit : sakit
# perut : perut
# wujud : wujud
# permintaan : minta
# rekomendasi : rekomendasi
# rhoma : rhoma
# terima : terima
# komisaris : komisaris
# benerinny : benerinny
# pke : pke
# axis : axis
# mohon : mohon
# free : free
# sebulan : bulan
# ajh : ajh
# make : make
# teljomsel : teljomsel
# kah : kah
# pekan : pekan
# kebakaran : bakar
# utuh : utuh
# semogha : semogha
# bangkrut : bangkrut
# buahahaha : buahahaha
# profesional : profesional
# smpai : smpai
# tolonglh : tolonglh
# cpt : cpt
# habis : habis
# jamin : jamin
# hati : hati
# krjaan : krjaan
# berantakan : beranta
# selamat : selamat
# kampung : kampung
# gorowong : gorowong
# desa : desa
# maroko : maroko
# kecamatan : camat
# cibalong : cibalong
# kabupaten : kabupaten
# garut : garut
# provinsi : provinsi
# jawabarat : jawabarat
# peluang : peluang
# kemampuan : mampu
# produk : produk
# mumpung : mumpung
# plat : plat
# merah : merah
# bermasalah : masalah
# kecepatan : cepat
# gpph : gpph
# memperbaiki : baik
# apanya : apa
# skrng : skrng
# masi : mas
# sinyalnya : sinyal
# apaligi : apaligi
# geme : geme
# mumer : mumer
# buang : buang
# kartu : kartu
# telkntl : telkntl
# adakah : ada
# gaada : gaada
# pindal : pindal
# seblah : seblah
# dehh : dehh
# bye : bye
# gan : gan
# nanya : nanya
# yha : yha
# klau : klau
# gni : gni
# bener : bener
# sabar : sabar
# yekan : yekan
# kouta : kouta
# super : super
# jengkel : jengkel
# selasa : selasa
# sidoarjo : sidoarjo
# trobel : trobel
# mah : mah
# kagak : kagak
# bergantung : gantung
# bersaing : saing
# indikasi : indikasi
# monopoli : monopoli
# dagang : dagang
# kebutuhan : butuh
# pokok : pokok
# pulsa : pulsa
# benerin : benerin
# ginian : ginian
# bermimpi : mimpi
# ngalahin : ngalahin
# amerika : amerika
# israel : israel
# wkwkwkwk : wkwkwkwk
# maluku : malu
# dwonload : dwonload
# pantesan : pantesan
# donk : donk
# krja : krja
# kocar : kocar
# kacir : kacir
# tmbah : tmbah
# menumpuk : tumpuk
# pakai : pakai
# orbit : orbit
# jumping : jumping
# doan : doan
# konfensasi : konfensasi
# kecutt : kecutt
# posisi : posisi
# nyet : nyet
# sempet : sempet
# time : time
# dirut : dirut
# tes : tes
# cpns : cpns
# jatwal : jatwal
# antigen : antigen
# penundaan : tunda
# ds : ds
# cepetan : cepetan
# yak : yak
# mang : mang
# perbaikinnya : perbaikinnya
# banner : banner
# margareth : margareth
# ampe : ampe
# kamis : kamis
# nyampe : nyampe
# pity : pity
# hah : hah
# dirugikan : rugi
# cok : cok
# nelpon : nelpon
# ultra : ultra
# hadeeeuuuhh : hadeeeuuuhh
# mbah : mbah
# warkop : warkop
# jdi : jdi
# sepi : sepi
# lol : lol
# rugilah : rugi
# stidaknya : stidaknya
# gmn : gmn
# tiada : tiada
# bagimu : bagi
# terkecuali : kecuali
# kemaren : kemaren
# partyan : partyan
# temen : temen
# disconecting : disconecting
# njirr : njirr
# kasik : kasik
# biaya : biaya
# slma : slma
# login : login
# basssiiii : basssiiii
# naah : naah
# pda : pda
# wfh : wfh
# tugas : tugas
# sekolah : sekolah
# sampek : sampek
# banting : banting
# setabil : setabil
# dinamakan : nama
# badai : badai
# matahari : matahari
# website : website
# dimana : mana
# pengen : ken
# keluarin : keluarin
# unek : unek
# maafmu : maaf
# kompensasimu : kompensasi
# satelitenya : satelitenya
# qlo : qlo
# kmren : kmren
# nusa : nusa
# tenggara : tenggara
# bngt : bngt
# smpe : smpe
# skrg : skrg
# lach : lach
# bukak : bukak
# youtube : youtube
# pulihnya : pulih
# lose : lose
# streak : streak
# nonton : nonton
# thok : thok
# akehhh : akehhh
# tunggale : tunggale
# wahhh : wahhh
# istrht : istrht
# matamu : mata
# aaa : aaa
# asuu : asuu
# indihomee : indihomee
# tuku : tuku
# gigi : gigi
# kau : kau
# hitam : hitam
# trial : trial
# channel : channel
# pcku : pcku
# one : one
# piece : piece
# bounty : bounty
# rush : rush
# sultan : sultan
# kecewa : kecewa
# ping : ping
# kuning : kuning
# ijo : ijo
# setuju : tuju
# jempolnya : jempol
# kredit : kredit
# skor : skor
# gwa : gwa
# ngmgg : ngmgg
# sat : sat
# epep : epep
# anjgg : anjgg
# konek : konek
# skolah : skolah
# gogle : gogle
# jonton : jonton
# video : video
# {'alhamdulillah': 'alhamdulillah', 'surabaya': 'surabaya', 'udh': 'udh', 'gangguan': 'ganggu', 'nge': 'nge', 'game': 'game', 'ngelag': 'ngelag', 'detik': 'detik', 'gpp': 'gpp', 'dll': 'dll', 'lancar': 'lancar', 'jaya': 'jaya', 'palembang': 'palembang', 'ilang': 'ilang', 'timbul': 'timbul', 'semoga': 'moga', 'cepat': 'cepat', 'selesai': 'selesai', 'urusannya': 'urus', 'kelancaran': 'lancar', 'memperbaikinya': 'baik', 'pelanggan': 'langgan', 'kompensasi': 'kompensasi', 'indihome': 'indihome', 'karyawan': 'karyawan', 'work': 'work', 'from': 'from', 'home': 'home', 'merugikan': 'rugi', 'jaringan': 'jaring', 'internet': 'internet', '': '', 'era': 'era', 'langganan': 'langgan', 'mending': 'mending', 'ngasih': 'ngasih', 'denda': 'denda', 'berhenti': 'henti', 'luwes': 'luwes', 'ragukan': 'ragu', 'layanannya': 'layan', 'gampang': 'gampang', 'pindah': 'pindah', 'provider': 'provider', 'buka': 'buka', 'steam': 'steam', 'gabisa': 'gabisa', 'valorant': 'valorant', 'benernya': 'benernya', 'parah': 'parah', 'kompensasinya': 'kompensasi', 'tolonglah': 'tolong', 'tanyain': 'tanyain', 'banyumas': 'banyumas', 'lemot': 'lot', 'pol': 'pol', 'alesan': 'alesan', 'pembenahan': 'benah', 'anakku': 'anak', 'daftar': 'daftar', 'online': 'online', 'baya': 'baya', 'dipasang': 'pasang', 'lbh': 'lbh', 'blm': 'blm', 'telkomsel': 'telkomsel', 'tanggal': 'tanggal', 'tutup': 'tutup', 'indonesia': 'indonesia', 'paket': 'paket', 'usaha': 'usaha', 'hitungan': 'hitung', 'jam': 'jam', 'berahir': 'berahir', 'bli': 'bli', 'samasekali': 'samasekali', 'hasil': 'hasil', 'rugi': 'rugi', 'gimana': 'gimana', 'untung': 'untung', 'solo': 'solo', 'nie': 'nie', 'cafe': 'cafe', 'lum': 'lum', 'pendapatan': 'dapat', 'sewa': 'sewa', 'manusia': 'manusia', 'laut': 'laut', 'aquaman': 'aquaman', 'putus': 'putus', 'wwkwkwk': 'wwkwkwk', 'purwokerto': 'purwokerto', 'lag': 'lag', 'wifinya': 'wifinya', 'pasang': 'pasang', 'wifi': 'wifi', 'tolong': 'tolong', 'ngomong': 'ngomong', 'sinyal': 'sinyal', 'rusak': 'rusak', 'pakek': 'pakek', 'data': 'data', 'pokoknya': 'pokok', 'gat': 'gat', 'aceh': 'aceh', 'maaih': 'maaih', 'matot': 'matot', 'mati': 'mati', 'total': 'total', 'area': 'area', 'waru': 'waru', 'brp': 'brp', 'ganti': 'ganti', 'perdana': 'perdana', 'gangguanya': 'gangguanya', 'indihomenya': 'indihomenya', 'banget': 'banget', 'ihhhh': 'ihhhh', 'ksian': 'ksi', 'warga': 'warga', 'sampe': 'sampe', 'buffer': 'buffer', 'mulu': 'mulu', 'ngeleg': 'ngeleg', 'cug': 'cug', 'parahhh': 'parahhh', 'minggu': 'minggu', 'owh': 'owh', 'whhhh': 'whhhh', 'blok': 'blok', 'jmn': 'jmn', 'dlu': 'dlu', 'simple': 'simple', 'endpoint': 'endpoint', 'href': 'href', 'tribunnews': 'tribunnews', 'salut': 'salut', 'telkom': 'telkom', 'pelayanan': 'layan', 'memuakkan': 'muak', 'indohome': 'indohome', 'dirumah': 'rumah', 'prestasi': 'prestasi', 'dipertahankan': 'tahan', 'perkembangan': 'kembang', 'tol': 'tol', 'darat': 'darat', 'berjalan': 'jalan', 'udara': 'udara', 'kiblatnya': 'kiblat', 'kayak': 'kayak', 'gini': 'gin', 'pertahankan': 'tahan', 'bayar': 'bayar', 'mahal': 'mahal', 'coneksi': 'coneksi', 'lemotnya': 'lot', 'luarbiasa': 'luarbiasa', 'maaf': 'maaf', 'kalimantan': 'kalimantan', 'utara': 'utara', 'aduhaiii': 'aduhaiii', 'lambat': 'lambat', 'kena': 'kena', 'sungguh': 'sungguh', 'mengecewakan': 'kecewa', 'daerah': 'daerah', 'jember': 'jember', 'jawa': 'jawa', 'timur': 'timur', 'secepatnya': 'cepat', 'normalkan': 'normal', 'salah': 'salah', 'ndak': 'ndak', 'bayarnya': 'bayar', 'full': 'full', 'kerjaan': 'kerja', 'terganggu': 'ganggu', 'down': 'down', 'discount': 'discount', 'tanggung': 'tanggung', 'pintar': 'pintar', 'teknologi': 'teknologi', 'menagih': 'tagih', 'bayaran': 'bayar', 'mengkompensasi': 'kompensasi', 'kerugian': 'rugi', 'trenggalek': 'trenggalek', 'ajur': 'ajur', 'koneksi': 'koneksi', 'kerahkan': 'kerah', 'sdm': 'sdm', 'budget': 'budget', 'perush': 'perush', 'membereskan': 'beres', 'sekelas': 'kelas', 'isa': 'isa', 'lucu': 'lucu', 'kasi': 'kasi', 'gara': 'gara', 'gue': 'gue', 'puluhan': 'puluh', 'juta' ...
# ------------------------
# Pandas Apply:   0%|          | 0/264 [00:00<?, ?it/s]
#                                                comment  \
# 0    alhamdulillah surabaya udh gak gangguan,walaup...
# 1    palembang ilang timbul,,, ya semoga cepat sele...
# 2    harusnya pelanggan mendapatkan kompensasi dr p...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4    di era masa kini langganan internet mending ja...
# ..                                                 ...
# 482                              gw mau ganti kartu aj
# 483                    sat mo login epep malah gk bisa
# 484                                lah telkomsel anjgg
# 485                masih gak bisa konek fb dan game ml
# 486  pr skolah gua kya apa,..gk bisa buka gogle lgi...
#
#                                       cleaning_comment  \
# 0    alhamdulillah surabaya udh gak gangguan walaup...
# 1    palembang ilang timbul semoga cepat selesai ur...
# 2    harusnya pelanggan mendapatkan kompensasi piha...
# 3    saya sebagai karyawan yang sedang melakukan wo...
# 4     era masa kini langganan internet mending jang...
# ..                                                 ...
# 482                                   mau ganti kartu
# 483                          sat login epep malah bisa
# 484                                lah telkomsel anjgg
# 485                     masih gak bisa konek dan game
# 486   skolah gua kya apa bisa buka gogle lgi jonton...
#
#                                             tokenisasi  \
# 0    [alhamdulillah, surabaya, udh, gak, gangguan, ...
# 1    [palembang, ilang, timbul, semoga, cepat, sele...
# 2    [harusnya, pelanggan, mendapatkan, kompensasi,...
# 3    [saya, sebagai, karyawan, yang, sedang, melaku...
# 4    [, era, masa, kini, langganan, internet, mendi...
# ..                                                 ...
# 482                            [, mau, ganti, kartu, ]
# 483                    [sat, login, epep, malah, bisa]
# 484                            [lah, telkomsel, anjgg]
# 485             [masih, gak, bisa, konek, dan, game, ]
# 486  [, skolah, gua, kya, apa, bisa, buka, gogle, l...
#
#                                               stopword  \
# 0    [alhamdulillah, surabaya, udh, gangguan, nge, ...
# 1    [palembang, ilang, timbul, semoga, cepat, sele...
# 2                    [pelanggan, kompensasi, indihome]
# 3    [karyawan, work, from, home, merugikan, jaring...
# 4    [, era, langganan, internet, mending, ngasih, ...
# ..                                                 ...
# 482                                 [, ganti, kartu, ]
# 483                                 [sat, login, epep]
# 484                                 [telkomsel, anjgg]
# 485                                    [konek, game, ]
# 486  [, skolah, gua, kya, buka, gogle, lgi, jonton,...
#
#                                               stemming
# 0    [alhamdulillah, surabaya, udh, ganggu, nge, ga...
# 1    [palembang, ilang, timbul, moga, cepat, selesa...
# 2                      [langgan, kompensasi, indihome]
# 3    [karyawan, work, from, home, rugi, jaring, int...
# 4    [, era, langgan, internet, mending, ngasih, de...
# ..                                                 ...
# 482                                 [, ganti, kartu, ]
# 483                                 [sat, login, epep]
# 484                                 [telkomsel, anjgg]
# 485                                    [konek, game, ]
# 486  [, skolah, gua, kya, buka, gogle, lgi, jonton,...
#
# [264 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [alhamdulillah, surabaya, udh, ganggu, nge, ga...
# 1    [palembang, ilang, timbul, moga, cepat, selesa...
# 2                      [langgan, kompensasi, indihome]
# 3    [karyawan, work, from, home, rugi, jaring, int...
# 4    [, era, langgan, internet, mending, ngasih, de...
# ..                                                 ...
# 482                                 [, ganti, kartu, ]
# 483                                 [sat, login, epep]
# 484                                 [telkomsel, anjgg]
# 485                                    [konek, game, ]
# 486  [, skolah, gua, kya, buka, gogle, lgi, jonton,...
#
# [264 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_9.xlsx')
