# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                      sukses trs pak hendra suryana
# 9                             sehat selalu pak hendra
# 10          sukses buat pak hendra dan witel selatan
# 11                              jaya terus pak hendra
# 12                good lucky bang hendra mpok aisyah
# 13

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                               comment  \
# 0   maasyaallah... sukses buat program barunya.. s...
# 1                                        mantulll 👌👌👌
# 2                       suksess trus pak hendraaa.. 😍
# 3   sukses untuk channel nya pak, semoga telkom le...
# 4   keren duet mas bro hendra & aisyah....sukses t...
# 5                                  bravo selatalks...
# 6   wowww mantappp kali...warbiasahhh selatalks......
# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                     sukses trs pak hendra suryana..
# 9                             sehat selalu pak hendra
# 10      sukses buat pak hendra. dan witel selatan...👍
# 11                              jaya terus pak hendra
# 12            good lucky bang hendra n mpok aisyah👍👍👍
# 13                                                  👍
#
#                                      cleaning_comment  \
# 0   maasyaallah sukses buat program barunya selata...
# 1                                           mantulll
# 2                          suksess trus pak hendraaa
# 3   sukses untuk channel nya pak semoga telkom leb...
# 4      keren duet mas bro hendra aisyah sukses terus
# 5                                    bravo selatalks
# 6   wowww mantappp kali warbiasahhh selatalks good...
# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                      sukses trs pak hendra suryana
# 9                             sehat selalu pak hendra
# 10          sukses buat pak hendra dan witel selatan
# 11                              jaya terus pak hendra
# 12                good lucky bang hendra mpok aisyah
# 13
#
#                                            tokenisasi
# 0   [maasyaallah, sukses, buat, program, barunya, ...
# 1                                        [mantulll, ]
# 2                    [suksess, trus, pak, hendraaa, ]
# 3   [sukses, untuk, channel, nya, pak, semoga, tel...
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses...
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7   [semangat, teruuuus, semoga, telkom, selalu, b...
# 8               [sukses, trs, pak, hendra, suryana, ]
# 9                        [sehat, selalu, pak, hendra]
# 10  [sukses, buat, pak, hendra, dan, witel, selata...
# 11                         [jaya, terus, pak, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                               comment  \
# 0   maasyaallah... sukses buat program barunya.. s...
# 1                                        mantulll 👌👌👌
# 2                       suksess trus pak hendraaa.. 😍
# 3   sukses untuk channel nya pak, semoga telkom le...
# 4   keren duet mas bro hendra & aisyah....sukses t...
# 5                                  bravo selatalks...
# 6   wowww mantappp kali...warbiasahhh selatalks......
# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                     sukses trs pak hendra suryana..
# 9                             sehat selalu pak hendra
# 10      sukses buat pak hendra. dan witel selatan...👍
# 11                              jaya terus pak hendra
# 12            good lucky bang hendra n mpok aisyah👍👍👍
# 13                                                  👍
#
#                                      cleaning_comment  \
# 0   maasyaallah sukses buat program barunya selata...
# 1                                           mantulll
# 2                          suksess trus pak hendraaa
# 3   sukses untuk channel nya pak semoga telkom leb...
# 4      keren duet mas bro hendra aisyah sukses terus
# 5                                    bravo selatalks
# 6   wowww mantappp kali warbiasahhh selatalks good...
# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                      sukses trs pak hendra suryana
# 9                             sehat selalu pak hendra
# 10          sukses buat pak hendra dan witel selatan
# 11                              jaya terus pak hendra
# 12                good lucky bang hendra mpok aisyah
# 13
#
#                                            tokenisasi  \
# 0   [maasyaallah, sukses, buat, program, barunya, ...
# 1                                        [mantulll, ]
# 2                    [suksess, trus, pak, hendraaa, ]
# 3   [sukses, untuk, channel, nya, pak, semoga, tel...
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses...
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7   [semangat, teruuuus, semoga, telkom, selalu, b...
# 8               [sukses, trs, pak, hendra, suryana, ]
# 9                        [sehat, selalu, pak, hendra]
# 10  [sukses, buat, pak, hendra, dan, witel, selata...
# 11                         [jaya, terus, pak, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]
#
#                                              stopword
# 0   [maasyaallah, sukses, program, barunya, selata...
# 1                                        [mantulll, ]
# 2                         [suksess, trus, hendraaa, ]
# 3          [sukses, channel, semoga, telkom, berjaya]
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses, ]
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7       [semangat, teruuuus, semoga, telkom, berjaya]
# 8                    [sukses, trs, hendra, suryana, ]
# 9                                     [sehat, hendra]
# 10                 [sukses, hendra, witel, selatan, ]
# 11                                     [jaya, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 42
# ------------------------
# maasyaallah : maasyaallah
# sukses : sukses
# program : program
# barunya : baru
# selatakls : selatakls
# semoga : moga
# byk : byk
# suka : suka
# sehat : sehat
# hendra : hendra
#  :
# mantulll : mantulll
# suksess : suksess
# trus : trus
# hendraaa : hendraaa
# channel : channel
# telkom : telkom
# berjaya : jaya
# keren : keren
# duet : duet
# mas : mas
# bro : bro
# aisyah : aisyah
# bravo : bravo
# selatalks : selatalks
# wowww : wowww
# mantappp : mantappp
# kali : kali
# warbiasahhh : warbiasahhh
# goodbener : goodbener
# dahhh : dahhh
# semangat : semangat
# teruuuus : teruuuus
# trs : trs
# suryana : suryana
# witel : witel
# selatan : selatan
# jaya : jaya
# good : good
# lucky : lucky
# bang : bang
# mpok : mpok
# {'maasyaallah': 'maasyaallah', 'sukses': 'sukses', 'program': 'program', 'barunya': 'baru', 'selatakls': 'selatakls', 'semoga': 'moga', 'byk': 'byk', 'suka': 'suka', 'sehat': 'sehat', 'hendra': 'hendra', '': '', 'mantulll': 'mantulll', 'suksess': 'suksess', 'trus': 'trus', 'hendraaa': 'hendraaa', 'channel': 'channel', 'telkom': 'telkom', 'berjaya': 'jaya', 'keren': 'keren', 'duet': 'duet', 'mas': 'mas', 'bro': 'bro', 'aisyah': 'aisyah', 'bravo': 'bravo', 'selatalks': 'selatalks', 'wowww': 'wowww', 'mantappp': 'mantappp', 'kali': 'kali', 'warbiasahhh': 'warbiasahhh', 'goodbener': 'goodbener', 'dahhh': 'dahhh', 'semangat': 'semangat', 'teruuuus': 'teruuuus', 'trs': 'trs', 'suryana': 'suryana', 'witel': 'witel', 'selatan': 'selatan', 'jaya': 'jaya', 'good': 'good', 'lucky': 'lucky', 'bang': 'bang', 'mpok': 'mpok'}
# ------------------------
# Pandas Apply:   0%|          | 0/14 [00:00<?, ?it/s]
#                                               comment  \
# 0   maasyaallah... sukses buat program barunya.. s...
# 1                                        mantulll 👌👌👌
# 2                       suksess trus pak hendraaa.. 😍
# 3   sukses untuk channel nya pak, semoga telkom le...
# 4   keren duet mas bro hendra & aisyah....sukses t...
# 5                                  bravo selatalks...
# 6   wowww mantappp kali...warbiasahhh selatalks......
# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                     sukses trs pak hendra suryana..
# 9                             sehat selalu pak hendra
# 10      sukses buat pak hendra. dan witel selatan...👍
# 11                              jaya terus pak hendra
# 12            good lucky bang hendra n mpok aisyah👍👍👍
# 13                                                  👍
#
#                                      cleaning_comment  \
# 0   maasyaallah sukses buat program barunya selata...
# 1                                           mantulll
# 2                          suksess trus pak hendraaa
# 3   sukses untuk channel nya pak semoga telkom leb...
# 4      keren duet mas bro hendra aisyah sukses terus
# 5                                    bravo selatalks
# 6   wowww mantappp kali warbiasahhh selatalks good...
# 7      semangat teruuuus semoga telkom selalu berjaya
# 8                      sukses trs pak hendra suryana
# 9                             sehat selalu pak hendra
# 10          sukses buat pak hendra dan witel selatan
# 11                              jaya terus pak hendra
# 12                good lucky bang hendra mpok aisyah
# 13
#
#                                            tokenisasi  \
# 0   [maasyaallah, sukses, buat, program, barunya, ...
# 1                                        [mantulll, ]
# 2                    [suksess, trus, pak, hendraaa, ]
# 3   [sukses, untuk, channel, nya, pak, semoga, tel...
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses...
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7   [semangat, teruuuus, semoga, telkom, selalu, b...
# 8               [sukses, trs, pak, hendra, suryana, ]
# 9                        [sehat, selalu, pak, hendra]
# 10  [sukses, buat, pak, hendra, dan, witel, selata...
# 11                         [jaya, terus, pak, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]
#
#                                              stopword  \
# 0   [maasyaallah, sukses, program, barunya, selata...
# 1                                        [mantulll, ]
# 2                         [suksess, trus, hendraaa, ]
# 3          [sukses, channel, semoga, telkom, berjaya]
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses, ]
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7       [semangat, teruuuus, semoga, telkom, berjaya]
# 8                    [sukses, trs, hendra, suryana, ]
# 9                                     [sehat, hendra]
# 10                 [sukses, hendra, witel, selatan, ]
# 11                                     [jaya, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]
#
#                                              stemming
# 0   [maasyaallah, sukses, program, baru, selatakls...
# 1                                        [mantulll, ]
# 2                         [suksess, trus, hendraaa, ]
# 3               [sukses, channel, moga, telkom, jaya]
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses, ]
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7            [semangat, teruuuus, moga, telkom, jaya]
# 8                    [sukses, trs, hendra, suryana, ]
# 9                                     [sehat, hendra]
# 10                 [sukses, hendra, witel, selatan, ]
# 11                                     [jaya, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                              Comments
# 0   [maasyaallah, sukses, program, baru, selatakls...
# 1                                        [mantulll, ]
# 2                         [suksess, trus, hendraaa, ]
# 3               [sukses, channel, moga, telkom, jaya]
# 4   [keren, duet, mas, bro, hendra, aisyah, sukses, ]
# 5                                [bravo, selatalks, ]
# 6   [wowww, mantappp, kali, warbiasahhh, selatalks...
# 7            [semangat, teruuuus, moga, telkom, jaya]
# 8                    [sukses, trs, hendra, suryana, ]
# 9                                     [sehat, hendra]
# 10                 [sukses, hendra, witel, selatan, ]
# 11                                     [jaya, hendra]
# 12        [good, lucky, bang, hendra, mpok, aisyah, ]
# 13                                               [, ]

# %%
Final.to_excel('databersih_youtube_indihome_6.xlsx')
