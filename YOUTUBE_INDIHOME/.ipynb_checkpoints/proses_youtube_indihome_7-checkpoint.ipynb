# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Mudah-mudahan pihak dari provider internet sel...
# 1    Semangat teknisi indihome. Moga cepat stabil l...
# 2    Semoga cepat selesai benerin jaringan nya,soal...
# 3    Untuk pihak telkomsel, belum semua daerah di p...
# 4    Udah mahal gangguan mulu lagi... Emang the bes...
# ..                                                 ...
# 154  Sekarang paket 2p (internet+UseeTV) pake stb, ...
# 155  Bang apa bener minimal berlangganan indihome1t...
# 156  Misal bulan ini kita paket internet bulan depa...
# 157                             Tempat gw 300rb 65mbps
# 158               anjir gw 20mbps fup di 350 apa apaan
#
# [159 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 26

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Mudah-mudahan pihak dari provider internet sel...
# 1    Semangat teknisi indihome. Moga cepat stabil l...
# 2    Semoga cepat selesai benerin jaringan nya,soal...
# 3    Untuk pihak telkomsel, belum semua daerah di p...
# 4    Udah mahal gangguan mulu lagi... Emang the bes...
# ..                                                 ...
# 134  Saya dr thn 2018 pertama kali pasang yg 10mbps...
# 139  yang  menunggu ISP lain masuk daerah2 terpenci...
# 140  Saya barusan upgrade dari 10mbps ke 20mbps, ( ...
# 141  Kalo penggunaannya 160GB itu berapa dibayarnya...
# 142  Klo FUP nya pengen tetap atau tidak terpakai b...
#
# [107 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    mudah-mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome. moga cepat stabil l...
# 2    semoga cepat selesai benerin jaringan nya,soal...
# 3    untuk pihak telkomsel, belum semua daerah di p...
# 4    udah mahal gangguan mulu lagi... emang the bes...
# ..                                                 ...
# 134  saya dr thn 2018 pertama kali pasang yg 10mbps...
# 139  yang  menunggu isp lain masuk daerah2 terpenci...
# 140  saya barusan upgrade dari 10mbps ke 20mbps, ( ...
# 141  kalo penggunaannya 160gb itu berapa dibayarnya...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
# [107 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    mudah-mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome. moga cepat stabil l...
# 2    semoga cepat selesai benerin jaringan nya,soal...
# 3    untuk pihak telkomsel, belum semua daerah di p...
# 4    udah mahal gangguan mulu lagi... emang the bes...
# ..                                                 ...
# 134  saya dr thn 2018 pertama kali pasang yg 10mbps...
# 139  yang  menunggu isp lain masuk daerah2 terpenci...
# 140  saya barusan upgrade dari 10mbps ke 20mbps, ( ...
# 141  kalo penggunaannya 160gb itu berapa dibayarnya...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                       cleaning_comment
# 0    mudah mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome moga cepat stabil lagi
# 2    semoga cepat selesai benerin jaringan nya soal...
# 3    untuk pihak telkomsel belum semua daerah profi...
# 4    udah mahal gangguan mulu lagi emang the best p...
# ..                                                 ...
# 134  saya thn   pertama kali pasang  mbps  rb blm p...
# 139  yang menunggu isp lain masuk daerah  terpencil...
# 140  saya barusan upgrade dari  mbps  mbps biasa ta...
# 141  kalo penggunaannya  gb itu berapa dibayarnya n...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
# [107 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    mudah-mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome. moga cepat stabil l...
# 2    semoga cepat selesai benerin jaringan nya,soal...
# 3    untuk pihak telkomsel, belum semua daerah di p...
# 4    udah mahal gangguan mulu lagi... emang the bes...
# ..                                                 ...
# 134  saya dr thn 2018 pertama kali pasang yg 10mbps...
# 139  yang  menunggu isp lain masuk daerah2 terpenci...
# 140  saya barusan upgrade dari 10mbps ke 20mbps, ( ...
# 141  kalo penggunaannya 160gb itu berapa dibayarnya...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                       cleaning_comment  \
# 0    mudah mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome moga cepat stabil lagi
# 2    semoga cepat selesai benerin jaringan nya soal...
# 3    untuk pihak telkomsel belum semua daerah profi...
# 4    udah mahal gangguan mulu lagi emang the best p...
# ..                                                 ...
# 134  saya thn   pertama kali pasang  mbps  rb blm p...
# 139  yang menunggu isp lain masuk daerah  terpencil...
# 140  saya barusan upgrade dari  mbps  mbps biasa ta...
# 141  kalo penggunaannya  gb itu berapa dibayarnya n...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                             tokenisasi
# 0    [mudah, mudahan, pihak, dari, provider, intern...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [semoga, cepat, selesai, benerin, jaringan, ny...
# 3    [untuk, pihak, telkomsel, belum, semua, daerah...
# 4    [udah, mahal, gangguan, mulu, lagi, emang, the...
# ..                                                 ...
# 134  [saya, thn, pertama, kali, pasang, mbps, rb, b...
# 139  [yang, menunggu, isp, lain, masuk, daerah, ter...
# 140  [saya, barusan, upgrade, dari, mbps, mbps, bia...
# 141  [kalo, penggunaannya, gb, itu, berapa, dibayar...
# 142  [klo, fup, nya, pengen, tetap, atau, tidak, te...
#
# [107 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    mudah-mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome. moga cepat stabil l...
# 2    semoga cepat selesai benerin jaringan nya,soal...
# 3    untuk pihak telkomsel, belum semua daerah di p...
# 4    udah mahal gangguan mulu lagi... emang the bes...
# ..                                                 ...
# 134  saya dr thn 2018 pertama kali pasang yg 10mbps...
# 139  yang  menunggu isp lain masuk daerah2 terpenci...
# 140  saya barusan upgrade dari 10mbps ke 20mbps, ( ...
# 141  kalo penggunaannya 160gb itu berapa dibayarnya...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                       cleaning_comment  \
# 0    mudah mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome moga cepat stabil lagi
# 2    semoga cepat selesai benerin jaringan nya soal...
# 3    untuk pihak telkomsel belum semua daerah profi...
# 4    udah mahal gangguan mulu lagi emang the best p...
# ..                                                 ...
# 134  saya thn   pertama kali pasang  mbps  rb blm p...
# 139  yang menunggu isp lain masuk daerah  terpencil...
# 140  saya barusan upgrade dari  mbps  mbps biasa ta...
# 141  kalo penggunaannya  gb itu berapa dibayarnya n...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                             tokenisasi  \
# 0    [mudah, mudahan, pihak, dari, provider, intern...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [semoga, cepat, selesai, benerin, jaringan, ny...
# 3    [untuk, pihak, telkomsel, belum, semua, daerah...
# 4    [udah, mahal, gangguan, mulu, lagi, emang, the...
# ..                                                 ...
# 134  [saya, thn, pertama, kali, pasang, mbps, rb, b...
# 139  [yang, menunggu, isp, lain, masuk, daerah, ter...
# 140  [saya, barusan, upgrade, dari, mbps, mbps, bia...
# 141  [kalo, penggunaannya, gb, itu, berapa, dibayar...
# 142  [klo, fup, nya, pengen, tetap, atau, tidak, te...
#
#                                               stopword
# 0    [mudah, mudahan, provider, internet, telkomsel...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [semoga, cepat, selesai, benerin, jaringan, go...
# 3    [telkomsel, daerah, profinsi, internetnya, udh...
# 4    [udah, mahal, gangguan, mulu, emang, the, best...
# ..                                                 ...
# 134  [thn, kali, pasang, mbps, rb, blm, ppn, bln, u...
# 139  [menunggu, isp, masuk, daerah, terpencil, tangan]
# 140  [barusan, upgrade, mbps, mbps, tagihannya, wkt...
# 141                  [penggunaannya, gb, dibayarnya, ]
# 142  [fup, pengen, terpakai, beli, router, sambungi...
#
# [107 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 446
# ------------------------
# mudah : mudah
# mudahan : mudah
# provider : provider
# internet : internet
# telkomsel : telkomsel
# menyediakan : sedia
# kendari : kendari
# seandainya : anda
# indihome : indihome
# pindah : pindah
#  :
# semangat : semangat
# teknisi : teknisi
# moga : moga
# cepat : cepat
# stabil : stabil
# semoga : moga
# selesai : selesai
# benerin : benerin
# jaringan : jaring
# google : google
# classroom : classroom
# jadwal : jadwal
# minggu : minggu
# ngerjain : ngerjain
# tugas : tugas
# daerah : daerah
# profinsi : profinsi
# internetnya : internetnya
# udh : udh
# masi : mas
# kab : kab
# down : down
# toli : tol
# udah : udah
# mahal : mahal
# gangguan : ganggu
# mulu : mulu
# emang : emang
# the : the
# best : best
# pelanggannya : langgan
# istiqomah : istiqomah
# stay : stay
# telkom : telkom
# terpaksa : paksa
# pagi : pagi
# wifi : wifi
# mbps : mbps
# rumah : rumah
# lelet : lelet
# sampe : sampe
# reset : reset
# berkali : kali
# skrng : skrng
# lancar : lancar
# jaya : jaya
# maklum : maklum
# produk : produk
# negri : negri
# bgini : bgini
# jdi : jdi
# bntu : bntu
# doa : doa
# cpat : cpat
# kelar : kelar
# maslahnya : maslahnya
# dicaci : caci
# maki : maki
# mreka : mreka
# berupaya : upaya
# didlam : didlam
# laut : laut
# perbaikinya : baik
# salam : salam
# nusantara : nusantara
# cemungut : cemungut
# memperbaiki : baik
# layanan : layan
# berusaha : usaha
# terbaik : baik
# secepatnya : cepat
# teratasi : atas
# tagihan : tagih
# ditarik : tarik
# hancur : hancur
# karuan : karuan
# pertanggungjawabannya : pertanggungjawabannya
# pelanggan : langgan
# gimana : gimana
# zoom : zoom
# meet : meet
# and : and
# lost : lost
# connectionnya : connectionnya
# kaya : kaya
# jaman : jaman
# nokia : nokia
# telpon : telpon
# smsan : smsan
# gua : gua
# komplain : komplain
# yak : yak
# customernya : customernya
# terserah : serah
# sampean : sampean
# disuruh : suruh
# berhenti : henti
# langganan : langgan
# wkwkwk : wkwkwk
# lucu : lucu
# bener : bener
# banget : banget
# bayar : bayar
# kalsu : kalsu
# pemasukan : pasu
# ajukan : aju
# alamat : alamat
# menunggu : tunggu
# tetep : tetep
# layanannya : layan
# ampas : ampas
# njing : njing
# berharap : harap
# republic : republic
# menjangkau : jangkau
# indonesia : indonesia
# drpd : drpd
# pakai : pakai
# lemot : lot
# bermasalah : masalah
# ganti : ganti
# diwajibkan : wajib
# dipasang : pasang
# kemarin : kemarin
# malam : malam
# skrg : skrg
# ehhh : ehhh
# smartfren : smartfren
# nular : nular
# kosong : kosong
# alhamdulillah : alhamdulillah
# wes : wes
# online : online
# komputer : komputer
# lambat : lambat
# bruh : bruh
# status : status
# like : like
# kerja : kerja
# gara : gara
# sinyal : sinyal
# semalam : malam
# hufffttt : hufffttt
# lombok : lombok
# ntb : ntb
# msih : msih
# pliss : pliss
# normalin : normalin
# komplin : komplin
# kemaren : kemaren
# warnet : warnet
# trus : trus
# telkompay : telkompay
# daun : daun
# streaming : streaming
# video : video
# cmn : cmn
# maav : maav
# nagih : nagih
# penanganan : tangan
# bet : bet
# jringn : jringn
# dhlah : dhlah
# gnti : gnti
# tolong : tolong
# donk : donk
# perbaiki : baik
# krja : krja
# msh : msh
# bnyak : bnyak
# smua : smua
# tergntung : tergntung
# wiffi : wiffi
# semara : semara
# jawa : jawa
# cem : cem
# babi : babi
# signalnya : signalnya
# beli : beli
# paket : paket
# halmahera : halmahera
# utara : utara
# temukan : temu
# kebiasaan : biasa
# september : september
# adik : adik
# gue : gue
# kuliah : kuliah
# susah : susah
# sekeluarga : keluarga
# butuh : butuh
# koneksi : koneksi
# three : three
# yaa : yaa
# nusa : nusa
# tenggara : tenggara
# lag : lag
# parah : parah
# inipun : ini
# jelek : jelek
# tmpt : tmpt
# akses : akses
# taii : taii
# sampek : sampek
# banting : banting
# muter : muter
# teryata : teryata
# meresahkan : resah
# ganguan : ganguan
# turun : turun
# speed : speed
# kpn : kpn
# normal : normal
# kakak : kakak
# off : off
# data : data
# tmpat : tmpat
# buanget : buanget
# yng : yng
# president : president
# titan : titan
# telkomtod : telkomtod
# penyelesaiannya : selesai
# proses : proses
# kartu : kartu
# belinya : beli
# jaringannya : jaring
# gini : gin
# harga : harga
# sesuai : sesuai
# kualitas : kualitas
# dpt : dpt
# kirain : kirain
# mifi : mifi
# rusak : rusak
# kesel : kesel
# bat : bat
# pas : pas
# maen : maen
# stres : stres
# doank : doank
# anjerrr : anjerrr
# kaltim : kaltim
# bojonegoro : bojonegoro
# timur : timur
# kena : kena
# dampaknya : dampak
# error : error
# ngapa : ngapa
# ngapain : ngapain
# sedia : sedia
# boss : boss
# download : download
# super : super
# nonton : nonton
# youtube : youtube
# buffering : buffering
# berjam : jam
# jam : jam
# erooor : erooor
# nampak : nampak
# belom : bom
# perkembangan : kembang
# siang : siang
# pengen : ken
# nggak : nggak
# betulin : betulin
# bagus : bagus
# ksih : ksih
# kompensasi : kompensasi
# dikit : dikit
# dirugikan : rugi
# byar : byar
# jatuh : jatuh
# tempo : tempo
# denda : denda
# tuntasin : tuntasin
# dlu : dlu
# ngoain : ngoain
# cuk : cuk
# nyusahin : nyusahin
# pubg : pubg
# memuat : muat
# btw : btw
# buka : buka
# pkai : pkai
# lngsung : lngsung
# macet : macet
# satelit : satelit
# kabel : kabel
# ngaruhnya : ngaruhnya
# comment : comment
# menngunakan : menngunakan
# tetangga : tetangga
# berbeda : beda
# gni : gni
# memding : memding
# maluku : malu
# gamer : gamer
# kecewa : kecewa
# warkop : warkop
# sepi : sepi
# cukk : cukk
# pecah : pecah
# kyak : kyak
# entok : entok
# bujang : bujang
# ngasi : ngasi
# ranting : ranting
# situs : situs
# web : web
# resmi : resmi
# gmna : gmna
# kasi : kasi
# bintang : bintang
# keleletan : lelet
# karyawan : karyawan
# membetulkan : betul
# sinyak : sinyak
# halamahera : halamahera
# sdah : sdah
# ayo : ayo
# biznet : biznet
# unjuk : unjuk
# gigi : gigi
# ajee : ajee
# yee : yee
# kiraen : kiraen
# jual : jual
# cina : cina
# tangerang : tangerang
# restart : restart
# pantes : pantes
# doeng : doeng
# celek : celek
# doang : doang
# suruh : suruh
# konsumen : konsumen
# anjlokk : anjlokk
# huhhh : huhhh
# payah : payah
# ogah : ogah
# main : main
# game : game
# help : help
# tkp : tkp
# semarang : semarang
# jateng : jateng
# sulawesi : sulawesi
# jember : jember
# jatim : jatim
# upload : upload
# vidio : vidio
# anjg : anjg
# scrim : scrim
# ikutan : ikut
# koment : koment
# letoy : letoy
# nich : nich
# signal : signal
# paan : paan
# sma : sma
# mending : mending
# rebahan : rebah
# yutub : yutub
# first : first
# dapet : dapet
# serentak : serentak
# woi : woi
# wifinya : wifinya
# capek : capek
# siput : siput
# tah : tah
# absen : absen
# kelas : kelas
# ino : ino
# badan : badan
# yputube : yputube
# mutar : mutar
# telat : telat
# classmate : classmate
# coxxxx : coxxxx
# alpa : alpa
# vpn : vpn
# cepet : cepet
# kon : kon
# bye : bye
# welcome : welcome
# myrepublic : myrepublic
# pasang : pasang
# hehehe : hehehe
# upto : upto
# rb : rb
# bln : bln
# bersyukur : syukur
# cover : cover
# bang : bang
# batas : batas
# fup : fup
# brapa : brapa
# sodara : sodara
# gatau : gatau
# skarang : skarang
# batasnya : batas
# thn : thn
# kali : kali
# blm : blm
# ppn : ppn
# upgrade : upgrade
# total : total
# byr : byr
# perbulannya : bulan
# cuman : cuman
# gb : gb
# isp : isp
# masuk : masuk
# terpencil : pencil
# tangan : tangan
# barusan : barusan
# tagihannya : tagih
# wktu : wktu
# klu : klu
# brp : brp
# mas : mas
# liat : liat
# aplikasi : aplikasi
# kenaikan : naik
# tuk : tuk
# penambahan : tambah
# sgtu : sgtu
# penggunaannya : guna
# dibayarnya : bayar
# terpakai : pakai
# router : router
# sambungin : sambungin
# {'mudah': 'mudah', 'mudahan': 'mudah', 'provider': 'provider', 'internet': 'internet', 'telkomsel': 'telkomsel', 'menyediakan': 'sedia', 'kendari': 'kendari', 'seandainya': 'anda', 'indihome': 'indihome', 'pindah': 'pindah', '': '', 'semangat': 'semangat', 'teknisi': 'teknisi', 'moga': 'moga', 'cepat': 'cepat', 'stabil': 'stabil', 'semoga': 'moga', 'selesai': 'selesai', 'benerin': 'benerin', 'jaringan': 'jaring', 'google': 'google', 'classroom': 'classroom', 'jadwal': 'jadwal', 'minggu': 'minggu', 'ngerjain': 'ngerjain', 'tugas': 'tugas', 'daerah': 'daerah', 'profinsi': 'profinsi', 'internetnya': 'internetnya', 'udh': 'udh', 'masi': 'mas', 'kab': 'kab', 'down': 'down', 'toli': 'tol', 'udah': 'udah', 'mahal': 'mahal', 'gangguan': 'ganggu', 'mulu': 'mulu', 'emang': 'emang', 'the': 'the', 'best': 'best', 'pelanggannya': 'langgan', 'istiqomah': 'istiqomah', 'stay': 'stay', 'telkom': 'telkom', 'terpaksa': 'paksa', 'pagi': 'pagi', 'wifi': 'wifi', 'mbps': 'mbps', 'rumah': 'rumah', 'lelet': 'lelet', 'sampe': 'sampe', 'reset': 'reset', 'berkali': 'kali', 'skrng': 'skrng', 'lancar': 'lancar', 'jaya': 'jaya', 'maklum': 'maklum', 'produk': 'produk', 'negri': 'negri', 'bgini': 'bgini', 'jdi': 'jdi', 'bntu': 'bntu', 'doa': 'doa', 'cpat': 'cpat', 'kelar': 'kelar', 'maslahnya': 'maslahnya', 'dicaci': 'caci', 'maki': 'maki', 'mreka': 'mreka', 'berupaya': 'upaya', 'didlam': 'didlam', 'laut': 'laut', 'perbaikinya': 'baik', 'salam': 'salam', 'nusantara': 'nusantara', 'cemungut': 'cemungut', 'memperbaiki': 'baik', 'layanan': 'layan', 'berusaha': 'usaha', 'terbaik': 'baik', 'secepatnya': 'cepat', 'teratasi': 'atas', 'tagihan': 'tagih', 'ditarik': 'tarik', 'hancur': 'hancur', 'karuan': 'karuan', 'pertanggungjawabannya': 'pertanggungjawabannya', 'pelanggan': 'langgan', 'gimana': 'gimana', 'zoom': 'zoom', 'meet': 'meet', 'and': 'and', 'lost': 'lost', 'connectionnya': 'connectionnya', 'kaya': 'kaya', 'jaman': 'jaman', 'nokia': 'nokia', 'telpon': 'telpon', 'smsan': 'smsan', 'gua': 'gua', 'komplain': 'komplain', 'yak': 'yak', 'customernya': 'customernya', 'terserah': 'serah', 'sampean': 'sampean', 'disuruh': 'suruh', 'berhenti': 'henti', 'langganan': 'langgan', 'wkwkwk': 'wkwkwk', 'lucu': 'lucu', 'bener': 'bener', 'banget': 'banget', 'bayar': 'bayar', 'kalsu': 'kalsu', 'pemasukan': 'pasu', 'ajukan': 'aju', 'alamat': 'alamat', 'menunggu': 'tunggu', 'tetep': 'tetep', 'layanannya': 'layan', 'ampas': 'ampas', 'njing': 'njing', 'berharap': 'harap', 'republic': 'republic', 'menjangkau': 'jangkau', 'indonesia': 'indonesia', 'drpd': 'drpd', 'pakai': 'pakai', 'lemot': 'lot', 'bermasalah': 'masalah', 'ganti': 'ganti', 'diwajibkan': 'wajib', 'dipasang': 'pasang', 'kemarin': 'kemarin', 'malam': 'malam', 'skrg': 'skrg', 'ehhh': 'ehhh', 'smartfren': 'smartfren', 'nular': 'nular', 'kosong': 'kosong', 'alhamdulillah': 'alhamdulillah', 'wes': 'wes', 'online': 'online', 'komputer': 'komputer', 'lambat': 'lambat', 'bruh': 'bruh', 'status': 'status', 'like': 'like', 'kerja': 'kerja', 'gara': 'gara', 'sinyal': 'sinyal', 'semalam': 'malam', 'hufffttt': 'hufffttt', 'lombok': 'lombok', 'ntb': 'ntb', 'msih': 'msih', 'pliss': 'pliss', 'normalin': 'normalin', 'komplin': 'komplin', 'kemaren': 'kemaren', 'warnet': 'warnet', 'trus': 'trus', 'telkompay': 'telkompay', 'daun': 'daun', 'streaming': 'streaming', 'video': 'video', 'cmn': 'cmn', 'maav': 'maav', 'nagih': 'nagih', 'penanganan': 'tangan', 'bet': 'bet', 'jringn': 'jringn', 'dhlah': 'dhlah', 'gnti': 'gnti', 'tolong': 'tolong', 'donk': 'donk', 'perbaiki': 'baik', 'krja': 'krja', 'msh': 'msh', 'bnyak': 'bnyak', 'smua': 'smua', 'tergntung': 'tergntung', 'wiffi': 'wiffi', 'semara': 'semara', 'jawa': 'jawa', 'cem': 'cem', 'babi': 'babi', 'signalnya': 'signalnya', 'beli': 'beli', 'paket': 'paket', 'halmahera': 'halmahera', 'utara': 'utara', 'temukan': 'temu', 'kebiasaan': 'biasa', 'september': 'september', 'adik': 'adik', 'gue': 'gue', 'kuliah': 'kuliah', 'susah': 'susah', 'sekeluarga': 'keluarga', 'butuh': 'butuh', 'koneksi': 'koneks ...
# ------------------------
# Pandas Apply:   0%|          | 0/107 [00:00<?, ?it/s]
#                                                comment  \
# 0    mudah-mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome. moga cepat stabil l...
# 2    semoga cepat selesai benerin jaringan nya,soal...
# 3    untuk pihak telkomsel, belum semua daerah di p...
# 4    udah mahal gangguan mulu lagi... emang the bes...
# ..                                                 ...
# 134  saya dr thn 2018 pertama kali pasang yg 10mbps...
# 139  yang  menunggu isp lain masuk daerah2 terpenci...
# 140  saya barusan upgrade dari 10mbps ke 20mbps, ( ...
# 141  kalo penggunaannya 160gb itu berapa dibayarnya...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                       cleaning_comment  \
# 0    mudah mudahan pihak dari provider internet sel...
# 1    semangat teknisi indihome moga cepat stabil lagi
# 2    semoga cepat selesai benerin jaringan nya soal...
# 3    untuk pihak telkomsel belum semua daerah profi...
# 4    udah mahal gangguan mulu lagi emang the best p...
# ..                                                 ...
# 134  saya thn   pertama kali pasang  mbps  rb blm p...
# 139  yang menunggu isp lain masuk daerah  terpencil...
# 140  saya barusan upgrade dari  mbps  mbps biasa ta...
# 141  kalo penggunaannya  gb itu berapa dibayarnya n...
# 142  klo fup nya pengen tetap atau tidak terpakai b...
#
#                                             tokenisasi  \
# 0    [mudah, mudahan, pihak, dari, provider, intern...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [semoga, cepat, selesai, benerin, jaringan, ny...
# 3    [untuk, pihak, telkomsel, belum, semua, daerah...
# 4    [udah, mahal, gangguan, mulu, lagi, emang, the...
# ..                                                 ...
# 134  [saya, thn, pertama, kali, pasang, mbps, rb, b...
# 139  [yang, menunggu, isp, lain, masuk, daerah, ter...
# 140  [saya, barusan, upgrade, dari, mbps, mbps, bia...
# 141  [kalo, penggunaannya, gb, itu, berapa, dibayar...
# 142  [klo, fup, nya, pengen, tetap, atau, tidak, te...
#
#                                               stopword  \
# 0    [mudah, mudahan, provider, internet, telkomsel...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [semoga, cepat, selesai, benerin, jaringan, go...
# 3    [telkomsel, daerah, profinsi, internetnya, udh...
# 4    [udah, mahal, gangguan, mulu, emang, the, best...
# ..                                                 ...
# 134  [thn, kali, pasang, mbps, rb, blm, ppn, bln, u...
# 139  [menunggu, isp, masuk, daerah, terpencil, tangan]
# 140  [barusan, upgrade, mbps, mbps, tagihannya, wkt...
# 141                  [penggunaannya, gb, dibayarnya, ]
# 142  [fup, pengen, terpakai, beli, router, sambungi...
#
#                                               stemming
# 0    [mudah, mudah, provider, internet, telkomsel, ...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [moga, cepat, selesai, benerin, jaring, google...
# 3    [telkomsel, daerah, profinsi, internetnya, udh...
# 4    [udah, mahal, ganggu, mulu, emang, the, best, ...
# ..                                                 ...
# 134  [thn, kali, pasang, mbps, rb, blm, ppn, bln, u...
# 139       [tunggu, isp, masuk, daerah, pencil, tangan]
# 140  [barusan, upgrade, mbps, mbps, tagih, wktu, ms...
# 141                                [guna, gb, bayar, ]
# 142       [fup, ken, pakai, beli, router, sambungin, ]
#
# [107 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [mudah, mudah, provider, internet, telkomsel, ...
# 1    [semangat, teknisi, indihome, moga, cepat, sta...
# 2    [moga, cepat, selesai, benerin, jaring, google...
# 3    [telkomsel, daerah, profinsi, internetnya, udh...
# 4    [udah, mahal, ganggu, mulu, emang, the, best, ...
# ..                                                 ...
# 134  [thn, kali, pasang, mbps, rb, blm, ppn, bln, u...
# 139       [tunggu, isp, masuk, daerah, pencil, tangan]
# 140  [barusan, upgrade, mbps, mbps, tagih, wktu, ms...
# 141                                [guna, gb, bayar, ]
# 142       [fup, ken, pakai, beli, router, sambungin, ]
#
# [107 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_7.xlsx')
