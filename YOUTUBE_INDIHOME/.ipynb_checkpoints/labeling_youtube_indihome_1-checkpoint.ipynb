# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["comment_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\databersih_english_youtube_indihome\databersih_english_youtube_indihome_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                       comment_english
# 0   ['bang', 'list', 'tingal', 'waiting', 'telepho...
# 1   ['Region', 'Different', 'Different', 'Price', '']
# 2                     ['Nyimak', 'friend', 'Success']
# 3                                     ['village', '']
# 4     ['bang', 'waiting', 'verification', 'call', '']
# 5               ['difficult', 'lgsg', 'go', 'office']
# 6   ['Tide', 'pole', 'home', 'pole', 'sebergah', '...
# 7                                        ['', 'Dunk']
# 8   ['bang', 'btw', 'ask', 'install', 'indohome', ...
# 9   ['Bang', 'ask', 'pairs',' Pay ',' Pertima ',' ...
# 10                 ['Package', 'business', 'Net', '']
# 11                                          Of course
# 12                                 ['Lemes', 'Voice']
# 13  ['', 'apk', 'myindihome', 'rb', 'original', 'n...
# 14  ['ask', 'home', 'msh', 'tube', 'no', 'flat', '...
# 15                  ['useetv', 'sucked', 'quota', '']
# 16  ['Klo', 'Install', 'Indihome', 'Get', 'STB', '...
# 17                      ['Kah', 'Region', 'Surabaya']
# 18                                    ['', 'present']
# 19    ['Kereeen', 'Greetings', 'know', 'Success', '']
# 20                          ['Bacot', 'obviously', "]
# 21  ['Sis',' Package ',' Internet ',' Kyk ',' Sist...
# 22  ['bang', 'upgrade', 'via', 'application', 'FUP...
# 23                                            ['Kga']
# 24                    ['Please', 'whispered', 'bang']
# 25  ['', 'Ampe', 'Call', 'Ampe', 'Skrg', 'Change',...
# 26                             ['Namba', 'yak', 'rb']
# 27  ['gantipaket', 'search', 'cheap', 'bang', 'ind...
# 28               ['limit', 'FUP', 'Mbps', 'bang', '']
# 29   ['failed', 'number', 'service', 'kompotibel', "]
# 30                 ['Mas', 'Speed', 'Dimaind', 'SOD']
# 31   ['UPGarad', 'Speed', 'Mbps', 'Rebu', 'Uuyy', '']
# 32  ['Subscribe', 'Package', 'Internet', 'MB', 'Te...
# 33  ['bang', 'upgrade', 'Mbps', 'tags', 'front', '...
# 34  ['Upgrade', 'Mbps', 'Mbs', 'Benner', 'Nambah',...
# 35  ['Upgrade', 'Speed', 'Mbps', 'Mbps', 'Mucul', ...
# 36              ['Mbps', 'HRS', 'Plaza', 'Telkom', "]
# 37  ['Bang', 'subscribe', 'Package', 'Phoenix', 'M...
# 38  ['bang', 'speed', 'uba', 'setela', 'pay', 'atw...
# 39         ['Bang', 'ADD', 'Movin', 'Free', 'Pay', "]
# 40  ['Bang', 'Upgrade', 'Speed', 'Pay', 'Moon', 'D...
# 41                          ['Thanks', 'gan', 'help']
# 42                                 ['Buy', 'balance']

# %%
df['comment_english'] = df['comment_english'].str.lower()
df.head(2000)
# Out:
#                                       comment_english
# 0   ['bang', 'list', 'tingal', 'waiting', 'telepho...
# 1   ['region', 'different', 'different', 'price', '']
# 2                     ['nyimak', 'friend', 'success']
# 3                                     ['village', '']
# 4     ['bang', 'waiting', 'verification', 'call', '']
# 5               ['difficult', 'lgsg', 'go', 'office']
# 6   ['tide', 'pole', 'home', 'pole', 'sebergah', '...
# 7                                        ['', 'dunk']
# 8   ['bang', 'btw', 'ask', 'install', 'indohome', ...
# 9   ['bang', 'ask', 'pairs',' pay ',' pertima ',' ...
# 10                 ['package', 'business', 'net', '']
# 11                                          of course
# 12                                 ['lemes', 'voice']
# 13  ['', 'apk', 'myindihome', 'rb', 'original', 'n...
# 14  ['ask', 'home', 'msh', 'tube', 'no', 'flat', '...
# 15                  ['useetv', 'sucked', 'quota', '']
# 16  ['klo', 'install', 'indihome', 'get', 'stb', '...
# 17                      ['kah', 'region', 'surabaya']
# 18                                    ['', 'present']
# 19    ['kereeen', 'greetings', 'know', 'success', '']
# 20                          ['bacot', 'obviously', "]
# 21  ['sis',' package ',' internet ',' kyk ',' sist...
# 22  ['bang', 'upgrade', 'via', 'application', 'fup...
# 23                                            ['kga']
# 24                    ['please', 'whispered', 'bang']
# 25  ['', 'ampe', 'call', 'ampe', 'skrg', 'change',...
# 26                             ['namba', 'yak', 'rb']
# 27  ['gantipaket', 'search', 'cheap', 'bang', 'ind...
# 28               ['limit', 'fup', 'mbps', 'bang', '']
# 29   ['failed', 'number', 'service', 'kompotibel', "]
# 30                 ['mas', 'speed', 'dimaind', 'sod']
# 31   ['upgarad', 'speed', 'mbps', 'rebu', 'uuyy', '']
# 32  ['subscribe', 'package', 'internet', 'mb', 'te...
# 33  ['bang', 'upgrade', 'mbps', 'tags', 'front', '...
# 34  ['upgrade', 'mbps', 'mbs', 'benner', 'nambah',...
# 35  ['upgrade', 'speed', 'mbps', 'mbps', 'mucul', ...
# 36              ['mbps', 'hrs', 'plaza', 'telkom', "]
# 37  ['bang', 'subscribe', 'package', 'phoenix', 'm...
# 38  ['bang', 'speed', 'uba', 'setela', 'pay', 'atw...
# 39         ['bang', 'add', 'movin', 'free', 'pay', "]
# 40  ['bang', 'upgrade', 'speed', 'pay', 'moon', 'd...
# 41                          ['thanks', 'gan', 'help']
# 42                                 ['buy', 'balance']

# %%
df['label_awal'] = ''
for i,x in df.comment_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.0
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.3
# Index:  3 label_awal 0.0
# Index:  4 label_awal 0.0
# Index:  5 label_awal -0.5
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.0
# Index:  8 label_awal 0.0
# Index:  9 label_awal 0.15
# Index:  10 label_awal 0.0
# Index:  11 label_awal 0.0
# Index:  12 label_awal 0.0
# Index:  13 label_awal 0.375
# Index:  14 label_awal 0.07443181818181818
# Index:  15 label_awal 0.0
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.3
# Index:  20 label_awal 0.0
# Index:  21 label_awal 0.5
# Index:  22 label_awal 0.0
# Index:  23 label_awal 0.0
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.0
# Index:  26 label_awal 0.0
# Index:  27 label_awal 0.4
# Index:  28 label_awal 0.0
# Index:  29 label_awal -0.5
# Index:  30 label_awal 0.0
# Index:  31 label_awal 0.0
# Index:  32 label_awal 0.25
# Index:  33 label_awal 0.0
# Index:  34 label_awal 0.0
# Index:  35 label_awal 0.0
# Index:  36 label_awal 0.0
# Index:  37 label_awal 0.0
# Index:  38 label_awal 0.0
# Index:  39 label_awal 0.4
# Index:  40 label_awal 0.1
# Index:  41 label_awal 0.2
# Index:  42 label_awal 0.0

# %%
df.head()
# Out:
#                                      comment_english label_awal
# 0  ['bang', 'list', 'tingal', 'waiting', 'telepho...        0.0
# 1  ['region', 'different', 'different', 'price', '']        0.0
# 2                    ['nyimak', 'friend', 'success']        0.3
# 3                                    ['village', '']        0.0
# 4    ['bang', 'waiting', 'verification', 'call', '']        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    30
#  0.300000     2
# -0.500000     2
#  0.400000     2
#  0.150000     1
#  0.375000     1
#  0.074432     1
#  0.500000     1
#  0.250000     1
#  0.100000     1
#  0.200000     1
# Name: label_awal, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] > 0.0:
        label.append("negative")
    else:
        label.append("positive")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                       comment_english     label
# 0   ['bang', 'list', 'tingal', 'waiting', 'telepho...  positive
# 1   ['region', 'different', 'different', 'price', '']  positive
# 2                     ['nyimak', 'friend', 'success']  negative
# 3                                     ['village', '']  positive
# 4     ['bang', 'waiting', 'verification', 'call', '']  positive
# 5               ['difficult', 'lgsg', 'go', 'office']  positive
# 6   ['tide', 'pole', 'home', 'pole', 'sebergah', '...  positive
# 7                                        ['', 'dunk']  positive
# 8   ['bang', 'btw', 'ask', 'install', 'indohome', ...  positive
# 9   ['bang', 'ask', 'pairs',' pay ',' pertima ',' ...  negative
# 10                 ['package', 'business', 'net', '']  positive
# 11                                          of course  positive
# 12                                 ['lemes', 'voice']  positive
# 13  ['', 'apk', 'myindihome', 'rb', 'original', 'n...  negative
# 14  ['ask', 'home', 'msh', 'tube', 'no', 'flat', '...  negative
# 15                  ['useetv', 'sucked', 'quota', '']  positive
# 16  ['klo', 'install', 'indihome', 'get', 'stb', '...  positive
# 17                      ['kah', 'region', 'surabaya']  positive
# 18                                    ['', 'present']  positive
# 19    ['kereeen', 'greetings', 'know', 'success', '']  negative
# 20                          ['bacot', 'obviously', "]  positive
# 21  ['sis',' package ',' internet ',' kyk ',' sist...  negative
# 22  ['bang', 'upgrade', 'via', 'application', 'fup...  positive
# 23                                            ['kga']  positive
# 24                    ['please', 'whispered', 'bang']  positive
# 25  ['', 'ampe', 'call', 'ampe', 'skrg', 'change',...  positive
# 26                             ['namba', 'yak', 'rb']  positive
# 27  ['gantipaket', 'search', 'cheap', 'bang', 'ind...  negative
# 28               ['limit', 'fup', 'mbps', 'bang', '']  positive
# 29   ['failed', 'number', 'service', 'kompotibel', "]  positive
# 30                 ['mas', 'speed', 'dimaind', 'sod']  positive
# 31   ['upgarad', 'speed', 'mbps', 'rebu', 'uuyy', '']  positive
# 32  ['subscribe', 'package', 'internet', 'mb', 'te...  negative
# 33  ['bang', 'upgrade', 'mbps', 'tags', 'front', '...  positive
# 34  ['upgrade', 'mbps', 'mbs', 'benner', 'nambah',...  positive
# 35  ['upgrade', 'speed', 'mbps', 'mbps', 'mucul', ...  positive
# 36              ['mbps', 'hrs', 'plaza', 'telkom', "]  positive
# 37  ['bang', 'subscribe', 'package', 'phoenix', 'm...  positive
# 38  ['bang', 'speed', 'uba', 'setela', 'pay', 'atw...  positive
# 39         ['bang', 'add', 'movin', 'free', 'pay', "]  negative
# 40  ['bang', 'upgrade', 'speed', 'pay', 'moon', 'd...  negative
# 41                          ['thanks', 'gan', 'help']  negative
# 42                                 ['buy', 'balance']  positive

# %%
df['label'].value_counts()
# Out:
# positive    32
# negative    11
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_youtube_indihome_1.xlsx')
