# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       Udh bayar ga boleh telat tiba"
# 3    Jangan sering" mengeluh boy, hadapi, rasakan, ...
# 4                             INDIHOME EMANG TERRRLALU
# ..                                                 ...
# 308  Mungkin sudah dikuasai oleh Sybil atau Ultron ...
# 309               Untung udah ganti biznet. Huakakakak
# 310                         Smartfren kok gak kena ya?
# 311                      Di rumah gw kok aman² aja yah
# 312                          Mana ada udah membaik..??
#
# [313 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 53

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       Udh bayar ga boleh telat tiba"
# 3    Jangan sering" mengeluh boy, hadapi, rasakan, ...
# 36                     Stroomnet juara user experience
# ..                                                 ...
# 308  Mungkin sudah dikuasai oleh Sybil atau Ultron ...
# 309               Untung udah ganti biznet. Huakakakak
# 310                         Smartfren kok gak kena ya?
# 311                      Di rumah gw kok aman² aja yah
# 312                          Mana ada udah membaik..??
#
# [207 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       udh bayar ga boleh telat tiba"
# 3    jangan sering" mengeluh boy, hadapi, rasakan, ...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309               untung udah ganti biznet. huakakakak
# 310                         smartfren kok gak kena ya?
# 311                      di rumah gw kok aman² aja yah
# 312                          mana ada udah membaik..??
#
# [207 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       udh bayar ga boleh telat tiba"
# 3    jangan sering" mengeluh boy, hadapi, rasakan, ...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309               untung udah ganti biznet. huakakakak
# 310                         smartfren kok gak kena ya?
# 311                      di rumah gw kok aman² aja yah
# 312                          mana ada udah membaik..??
#
#                                       cleaning_comment
# 0    seharusnya pemerintah membuat platform untuk b...
# 1    semoga internet bisa cepat dan lemot terus tel...
# 2                          udh bayar boleh telat tiba
# 3    jangan sering mengeluh boy hadapi rasakan kepe...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309                untung udah ganti biznet huakakakak
# 310                            smartfren kok gak kena
# 311                             rumah kok aman aja yah
# 312                             mana ada udah membaik
#
# [207 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       udh bayar ga boleh telat tiba"
# 3    jangan sering" mengeluh boy, hadapi, rasakan, ...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309               untung udah ganti biznet. huakakakak
# 310                         smartfren kok gak kena ya?
# 311                      di rumah gw kok aman² aja yah
# 312                          mana ada udah membaik..??
#
#                                       cleaning_comment  \
# 0    seharusnya pemerintah membuat platform untuk b...
# 1    semoga internet bisa cepat dan lemot terus tel...
# 2                          udh bayar boleh telat tiba
# 3    jangan sering mengeluh boy hadapi rasakan kepe...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309                untung udah ganti biznet huakakakak
# 310                            smartfren kok gak kena
# 311                             rumah kok aman aja yah
# 312                             mana ada udah membaik
#
#                                             tokenisasi
# 0    [seharusnya, pemerintah, membuat, platform, un...
# 1    [semoga, internet, bisa, cepat, dan, lemot, te...
# 2                   [udh, bayar, boleh, telat, tiba, ]
# 3    [jangan, sering, mengeluh, boy, hadapi, rasaka...
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308  [mungkin, sudah, dikuasai, oleh, sybil, atau, ...
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                      [smartfren, kok, gak, kena, ]
# 311                     [, rumah, kok, aman, aja, yah]
# 312                       [mana, ada, udah, membaik, ]
#
# [207 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       udh bayar ga boleh telat tiba"
# 3    jangan sering" mengeluh boy, hadapi, rasakan, ...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309               untung udah ganti biznet. huakakakak
# 310                         smartfren kok gak kena ya?
# 311                      di rumah gw kok aman² aja yah
# 312                          mana ada udah membaik..??
#
#                                       cleaning_comment  \
# 0    seharusnya pemerintah membuat platform untuk b...
# 1    semoga internet bisa cepat dan lemot terus tel...
# 2                          udh bayar boleh telat tiba
# 3    jangan sering mengeluh boy hadapi rasakan kepe...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309                untung udah ganti biznet huakakakak
# 310                            smartfren kok gak kena
# 311                             rumah kok aman aja yah
# 312                             mana ada udah membaik
#
#                                             tokenisasi  \
# 0    [seharusnya, pemerintah, membuat, platform, un...
# 1    [semoga, internet, bisa, cepat, dan, lemot, te...
# 2                   [udh, bayar, boleh, telat, tiba, ]
# 3    [jangan, sering, mengeluh, boy, hadapi, rasaka...
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308  [mungkin, sudah, dikuasai, oleh, sybil, atau, ...
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                      [smartfren, kok, gak, kena, ]
# 311                     [, rumah, kok, aman, aja, yah]
# 312                       [mana, ada, udah, membaik, ]
#
#                                               stopword
# 0    [pemerintah, platform, belajar, digratiskan, p...
# 1    [semoga, internet, cepat, lemot, telkomsel, pa...
# 2                                [udh, bayar, telat, ]
# 3    [mengeluh, boy, hadapi, rasakan, kepedihanmu, ...
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308             [dikuasai, sybil, ultron, telkomnya, ]
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                                [smartfren, kena, ]
# 311                                    [, rumah, aman]
# 312                                  [udah, membaik, ]
#
# [207 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 704
# ------------------------
# pemerintah : perintah
# platform : platform
# belajar : ajar
# digratiskan : gratis
# provider : provider
# indonesia : indonesia
# ketimbang : ketimbang
# paket : paket
# internet : internet
# mahal : mahal
# disalahgunakan : disalahgunakan
# semoga : moga
# cepat : cepat
# lemot : lot
# telkomsel : telkomsel
# paketnya : paket
# murahin : murahin
# kemahalan : mahal
# coy : coy
#  :
# udh : udh
# bayar : bayar
# telat : telat
# mengeluh : keluh
# boy : boy
# hadapi : hadap
# rasakan : rasa
# kepedihanmu : pedih
# kehidupan : hidup
# stroomnet : stroomnet
# juara : juara
# user : user
# experience : experience
# alhamdulillah : alhamdulillah
# first : first
# media : media
# mbps : mbps
# lag : lag
# parah : parah
# indihome : indihome
# kualitas : kualitas
# bner : bner
# buruk : buruk
# stb : stb
# tvnya : tvnya
# ditambah : tambah
# teknisinya : teknisi
# ogah : ogah
# ogahan : ogah
# bnerinnya : bnerinnya
# tpi : tpi
# giliran : gilir
# bayaran : bayar
# buru : buru
# pulsa : pulsa
# mending : mending
# modem : modem
# net : net
# kelola : kelola
# desa : desa
# make : make
# customer : customer
# suffer : suffer
# profider : profider
# handalkan : handalkan
# telkom : telkom
# pantesan : pantesan
# gada : gada
# koneksi : koneksi
# teknisi : teknisi
# gatau : gatau
# kepaksa : paksa
# nerima : nerima
# layanan : layan
# gaji : gaji
# the : the
# host : host
# cute : cute
# love : love
# indonesian : indonesian
# news : news
# from : from
# seoul : seoul
# korsel : korsel
# pakai : pakai
# axis : axis
# smartfren : smartfren
# im : im
# server : server
# pekanbaru : pekanbaru
# pulih : pulih
# masuk : masuk
# error : error
# kesel : kesel
# sampe : sampe
# kasian : kasi
# service : service
# korban : korban
# komplain : komplain
# mulu : mulu
# tsel : tsel
# kecepatan : cepat
# unduh : unduh
# kbps : kbps
# unggahnya : unggah
# pdhal : pdhal
# wifi : wifi
# dirmh : dirmh
# moblie : moblie
# mengacau : acau
# kegiatan : giat
# guru : guru
# dosen : dosen
# kgk : kgk
# ngajar : ngajar
# serasa : serasa
# damai : damai
# gitu : gitu
# jaringan : jaring
# kayak : kayak
# sampah : sampah
# akses : akses
# emang : emang
# dimainkan : main
# dapet : dapet
# untung : untung
# denda : denda
# down : down
# kompensasi : kompensasi
# konsumennya : konsumen
# cable : cable
# kadang : kadang
# melambat : lambat
# tersendat : sendat
# very : very
# slow : slow
# response : response
# bagus : bagus
# mengaku : aku
# satelit : satelit
# ambil : ambil
# singapura : singapura
# milik : milik
# maju : maju
# sumpah : sumpah
# deh : deh
# yaaaaa : yaaaaa
# gegara : gegara
# kemaren : kemaren
# karna : karna
# alhasil : alhasil
# nyusul : nyusul
# nilai : nilai
# dipotong : potong
# gurunya : guru
# internetnya : internetnya
# matikan : mati
# seharian : hari
# penuh : penuh
# normal : normal
# engga : engga
# pelanggan : langgan
# mikir : mikir
# koruptor : koruptor
# bawahan : bawah
# atasan : atas
# indiehome : indiehome
# suruh : suruh
# siswa : siswa
# daring : daring
# gpp : gpp
# dikasih : kasih
# sosialis : sosialis
# kapitalis : kapitalis
# bumn : bumn
# republic : republic
# cbn : cbn
# dimana : mana
# murah : murah
# kagak : kagak
# penyebab : sebab
# lemotnya : lot
# krna : krna
# upgrade : upgrade
# cobalah : coba
# masi : mas
# lelet : lelet
# unjuk : unjuk
# mengganggu : ganggu
# kenyamanan : nyaman
# konsumen : konsumen
# selamat : selamat
# tinggal : tinggal
# lgi : lgi
# bulanannya : bulan
# ttapi : ttapi
# koneksinya : koneksi
# sgt : sgt
# smakin : smakin
# unlimited : unlimited
# mmake : mmake
# kartu : kartu
# ccok : ccok
# tolong : tolong
# kedepany : kedepany
# gangguan : ganggu
# minggu : minggu
# sidang : sidang
# online : online
# kominfo : kominfo
# cepet : cepet
# bulanan : bulan
# emosi : emosi
# setia : setia
# ngebacotin : ngebacotin
# aseliiii : aseliiii
# pjj : pjj
# flores : flores
# susah : susah
# diperbaiki : baik
# semsetinya : semsetinya
# contoh : contoh
# perusahaan : usaha
# mentang : mentang
# penguasa : kuasa
# pasar : pasar
# terimakasih : terimakasih
# test : test
# mandarin : mandarin
# zoom : zoom
# tunda : tunda
# berwujud : wujud
# berbentuk : bentuk
# kyak : kyak
# nyetak : nyetak
# duit : duit
# pakek : pakek
# angin : angin
# bener : bener
# banget : banget
# hilang : hilang
# butuh : butuh
# butuhnya : butuh
# ujian : uji
# sambungannya : sambung
# terputus : putus
# doang : doang
# sebulan : bulan
# bnget : bnget
# jengkel : jengkel
# kakak : kakak
# universitas : universitas
# sinyal : sinyal
# aduh : aduh
# sekolah : sekolah
# indi : indi
# home : home
# mohon : mohon
# ter : ter
# ulang : ulang
# indihomo : indihomo
# tiada : tiada
# terpaksa : paksa
# bizznet : bizznet
# najis : najis
# gratis : gratis
# alamat : alamat
# adem : adem
# ayem : ayem
# prnh : prnh
# knp : knp
# udah : udah
# pindah : pindah
# asing : asing
# heran : heran
# negara : negara
# salah : salah
# memakai : pakai
# ribu : ribu
# speed : speed
# speedtest : speedtest
# via : via
# komputer : komputer
# upload : upload
# download : download
# keong : keong
# harga : harga
# konsisten : konsisten
# menerapkan : terap
# tlkm : tlkm
# forever : forever
# allah : allah
# dijatiasih : dijatiasih
# bekasi : bekas
# muncul : muncul
# perbulan : bulan
# quota : quota
# menit : menit
# itupun : itu
# seminggu : minggu
# kali : kali
# semarang : semarang
# off : off
# jam : jam
# pliss : pliss
# satusatu : satusatu
# minus : minus
# cuman : cuman
# subsidi : subsidi
# gratiskan : gratis
# sajaaaaa : sajaaaaa
# konslet : konslet
# indihomenya : indihomenya
# jajaran : jajar
# direktur : direktur
# staff : staff
# ganti : ganti
# slah : slah
# profesional : profesional
# becus : becus
# kemarin : kemarin
# bangga : bangga
# gara : gara
# bales : bales
# ngelag : ngelag
# ilang : ilang
# malas : malas
# ngakak : ngakak
# dengar : dengar
# wkwkwkwk : wkwkwkwk
# pokok : pokok
# uang : uang
# pensiun : pensiun
# tunjangan : tunjang
# membutuhkan : butuh
# maaf : maaf
# mas : mas
# kebakar : bakar
# habis : habis
# data : data
# denny : denny
# caknan : caknan
# beliin : beliin
# putus : putus
# skrg : skrg
# bermslah : bermslah
# konpensiasi : konpensiasi
# laporan : lapor
# ujung : ujung
# ujungnya : ujung
# restart : restart
# modemnya : modem
# santuy : santuy
# hahaha : hahaha
# potongan : potong
# akobat : akobat
# sembako : sembako
# pulsaaaaaaaaaaaaaa : pulsaaaaaaaaaaaaaa
# tweet : tweet
# menkominfo : menkominfo
# jaman : jaman
# sby : sby
# dipakai : pakai
# lumayan : lumayan
# stabil : stabil
# laptop : laptop
# nyambung : nyambung
# konek : konek
# ekspektasi : ekspektasi
# pengen : ken
# kantor : kantor
# nasa : nasa
# memiliki : milik
# gb : gb
# smoga : smoga
# korona : korona
# ilangabis : ilangabis
# gedung : gedung
# demo : demo
# internetan : internetan
# masang : masang
# blm : blm
# dipasang : pasang
# repund : repund
# ign : ign
# pengembalian : kembali
# lbh : lbh
# kembalikan : kembali
# perasaan : asa
# kerasa : rasa
# gede : gede
# biaya : biaya
# servisnya : servis
# buka : buka
# video : video
# muter : muter
# produk : produk
# suka : suka
# pembelian : beli
# berhenti : henti
# langganan : langgan
# terussss : terussss
# menyebalkan : sebal
# isp : isp
# vangsat : vangsat
# tmpt : tmpt
# pasang : pasang
# myrepublic : myrepublic
# biznet : biznet
# citranet : citranet
# telp : telp
# cma : cma
# nembuss : nembuss
# kotaa : kotaa
# sajah : sajah
# heleeeh : heleeeh
# disubsidi : subsidi
# adek : adek
# gue : gue
# gua : gua
# mati : mati
# tagihan : tagih
# rb : rb
# kouta : kouta
# main : main
# bosannnn : bosannnn
# lapor : lapor
# bettt : bettt
# ampas : ampas
# wkwkwk : wkwkwk
# doank : doank
# tahunya : tahu
# skala : skala
# nasional : nasional
# tanda : tanda
# silahkan : silah
# kak : kak
# emangnya : emang
# bakrie : bakrie
# group : group
# bergantung : gantung
# repot : repot
# penerbangan : terbang
# lion : lion
# air : air
# dunia : dunia
# kitapunya : kitapunya
# fup : fup
# ngehe : ngehe
# tri : tri
# full : full
# menyelesaikan : selesai
# komplenan : komplenan
# balikin : balikin
# pemsangan : pemsangan
# cuekin : cuekin
# komplainan : komplain
# gaguna : gaguna
# google : google
# mett : mett
# separuh : paruh
# muka : muka
# keliatan : liat
# nonton : nonton
# lancar : lancar
# bayangin : bayangin
# sendnya : sendnya
# recieve : recieve
# bayangkan : bayang
# pdhl : pdhl
# kompetitornya : kompetitor
# perbaiki : baik
# terusss : terusss
# indigo : indigo
# gjls : gjls
# sumatra : sumatra
# pisah : pisah
# wassalam : wassalam
# pembelajaran : ajar
# mintanya : minta
# digital : digital
# jaringanya : jaringanya
# sehat : sehat
# amzink : amzink
# bali : bal
# fiber : fiber
# jaya : jaya
# kendala : kendala
# leletnya : lelet
# ketulungan : ketulungan
# pembenahan : benah
# sma : sma
# kacau : kacau
# lagnya : lagnya
# super : super
# hadehhhhhhh : hadehhhhhhh
# hate : hate
# merestart : merestart
# telkomnya : telkomnya
# tower : tower
# btsnya : btsnya
# imternet : imternet
# gabutan : gabutan
# diem : diem
# jalan : jalan
# hahahahahaha : hahahahahaha
# rusak : rusak
# bbrp : bbrp
# signalnya : signalnya
# ramai : ramai
# swasta : swasta
# aman : aman
# paketku : paket
# udahlah : udahlah
# lockdown : lockdown
# staffnya : staffnya
# buta : buta
# nyaa : nyaa
# aing : aing
# lagging : lagging
# tanggal : tanggal
# telfon : telfon
# riau : riau
# bngat : bngat
# hri : hri
# maintenance : maintenance
# percaya : percaya
# heboh : heboh
# apapun : apa
# menang : menang
# terkenal : kenal
# binatang : binatang
# kukang : kukang
# makannya : makan
# manjat : manjat
# pohon : pohon
# berjam : jam
# nungguin : nungguin
# mah : mah
# pemasukan : pasu
# kbalik : kbalik
# wekekekkeek : wekekekkeek
# eror : eror
# like : like
# bro : bro
# makenya : makenya
# berita : berita
# kabel : kabel
# jual : jual
# bangkrut : bangkrut
# nol : nol
# cacatnya : cacat
# jepang : jepang
# direkturnya : direktur
# langsung : langsung
# mengundurkan : undur
# single : single
# draft : draft
# beres : beres
# rmh : rmh
# mngkn : mngkn
# tergantung : gantung
# wilayah : wilayah
# orang : orang
# sebagus : bagus
# sejelek : jelek
# puas : puas
# alasan : alas
# woi : woi
# daerah : daerah
# cover : cover
# repvublict : repvublict
# kasi : kasi
# diadain : diadain
# ditempat : tempat
# paiton : paiton
# bosen : bosen
# ama : ama
# rajin : rajin
# males : males
# banten : banten
# jaringannya : jaring
# restard : restard
# routernya : routernya
# btw : btw
# anchor : anchor
# ketawa : ketawa
# bocor : bocor
# mic : mic
# nggak : nggak
# mulus : mulus
# realibilitas : realibilitas
# coi : coi
# agus : agus
# tanggu : tanggu
# dlm : dlm
# bnyk : bnyk
# tikus : tikus
# modal : modal
# hasil : hasil
# seadanya : ada
# mhl : mhl
# duh : duh
# tarif : tarif
# beliau : beliau
# tugas : tugas
# kerjain : kerjain
# kaget : kaget
# sandang : sandang
# pangan : pangan
# papan : papan
# ngontrak : ngontrak
# wakakakakka : wakakakakka
# prasaan : prasaan
# tuuh : tuuh
# iya : iya
# wifinya : wifinya
# kuota : kuota
# msh : msh
# ngeleg : ngeleg
# akibat : akibat
# emg : emg
# uda : uda
# cacat : cacat
# untungnya : untung
# skg : skg
# detik : detik
# menulis : tulis
# komentar : komentar
# ampun : ampun
# komen : komen
# penyiar : siar
# baju : baju
# daleman : dalem
# kuning : kuning
# napsuin : napsuin
# pingin : pingin
# jijik : jijik
# tutup : tutup
# kemana : mana
# harganya : harga
# jambret : jambret
# lokasi : lokasi
# direstart : direstart
# kwkwkw : kwkwkw
# kejadian : jadi
# yaa : yaa
# mundur : mundur
# hayooo : hayooo
# coba : coba
# gini : gin
# amad : amad
# yak : yak
# nyumpahin : nyumpahin
# dll : dll
# menjatuhkan : jatuh
# dukung : dukung
# donk : donk
# kasih : kasih
# saran : saran
# berkembang : kembang
# mental : mental
# goblok : goblok
# pikir : pikir
# loe : loe
# sumpahin : sumpahin
# macem : macem
# gmna : gmna
# pembunuhan : bunuh
# karakter : karakter
# hina : hina
# fakta : fakta
# merugikan : rugi
# elu : elu
# keluhan : keluh
# indomie : indomie
# bagikan : bagi
# sekolahan : sekolah
# setuju : tuju
# pengganti : ganti
# gan : gan
# enak : enak
# pas : pas
# dibutuhkan : butuh
# avatar : avatar
# cuyyy : cuyyy
# wifiku : wifiku
# titip : titip
# indihom : indihom
# resmi : resmi
# balek : balek
# bocil : bocil
# tetangga : tetangga
# hack : hack
# marahin : marahin
# njink : njink
# buabi : buabi
# dikuasai : asai
# sybil : sybil
# ultron : ultron
# huakakakak : huakakakak
# kena : kena
# rumah : rumah
# membaik : baik
# {'pemerintah': 'perintah', 'platform': 'platform', 'belajar': 'ajar', 'digratiskan': 'gratis', 'provider': 'provider', 'indonesia': 'indonesia', 'ketimbang': 'ketimbang', 'paket': 'paket', 'internet': 'internet', 'mahal': 'mahal', 'disalahgunakan': 'disalahgunakan', 'semoga': 'moga', 'cepat': 'cepat', 'lemot': 'lot', 'telkomsel': 'telkomsel', 'paketnya': 'paket', 'murahin': 'murahin', 'kemahalan': 'mahal', 'coy': 'coy', '': '', 'udh': 'udh', 'bayar': 'bayar', 'telat': 'telat', 'mengeluh': 'keluh', 'boy': 'boy', 'hadapi': 'hadap', 'rasakan': 'rasa', 'kepedihanmu': 'pedih', 'kehidupan': 'hidup', 'stroomnet': 'stroomnet', 'juara': 'juara', 'user': 'user', 'experience': 'experience', 'alhamdulillah': 'alhamdulillah', 'first': 'first', 'media': 'media', 'mbps': 'mbps', 'lag': 'lag', 'parah': 'parah', 'indihome': 'indihome', 'kualitas': 'kualitas', 'bner': 'bner', 'buruk': 'buruk', 'stb': 'stb', 'tvnya': 'tvnya', 'ditambah': 'tambah', 'teknisinya': 'teknisi', 'ogah': 'ogah', 'ogahan': 'ogah', 'bnerinnya': 'bnerinnya', 'tpi': 'tpi', 'giliran': 'gilir', 'bayaran': 'bayar', 'buru': 'buru', 'pulsa': 'pulsa', 'mending': 'mending', 'modem': 'modem', 'net': 'net', 'kelola': 'kelola', 'desa': 'desa', 'make': 'make', 'customer': 'customer', 'suffer': 'suffer', 'profider': 'profider', 'handalkan': 'handalkan', 'telkom': 'telkom', 'pantesan': 'pantesan', 'gada': 'gada', 'koneksi': 'koneksi', 'teknisi': 'teknisi', 'gatau': 'gatau', 'kepaksa': 'paksa', 'nerima': 'nerima', 'layanan': 'layan', 'gaji': 'gaji', 'the': 'the', 'host': 'host', 'cute': 'cute', 'love': 'love', 'indonesian': 'indonesian', 'news': 'news', 'from': 'from', 'seoul': 'seoul', 'korsel': 'korsel', 'pakai': 'pakai', 'axis': 'axis', 'smartfren': 'smartfren', 'im': 'im', 'server': 'server', 'pekanbaru': 'pekanbaru', 'pulih': 'pulih', 'masuk': 'masuk', 'error': 'error', 'kesel': 'kesel', 'sampe': 'sampe', 'kasian': 'kasi', 'service': 'service', 'korban': 'korban', 'komplain': 'komplain', 'mulu': 'mulu', 'tsel': 'tsel', 'kecepatan': 'cepat', 'unduh': 'unduh', 'kbps': 'kbps', 'unggahnya': 'unggah', 'pdhal': 'pdhal', 'wifi': 'wifi', 'dirmh': 'dirmh', 'moblie': 'moblie', 'mengacau': 'acau', 'kegiatan': 'giat', 'guru': 'guru', 'dosen': 'dosen', 'kgk': 'kgk', 'ngajar': 'ngajar', 'serasa': 'serasa', 'damai': 'damai', 'gitu': 'gitu', 'jaringan': 'jaring', 'kayak': 'kayak', 'sampah': 'sampah', 'akses': 'akses', 'emang': 'emang', 'dimainkan': 'main', 'dapet': 'dapet', 'untung': 'untung', 'denda': 'denda', 'down': 'down', 'kompensasi': 'kompensasi', 'konsumennya': 'konsumen', 'cable': 'cable', 'kadang': 'kadang', 'melambat': 'lambat', 'tersendat': 'sendat', 'very': 'very', 'slow': 'slow', 'response': 'response', 'bagus': 'bagus', 'mengaku': 'aku', 'satelit': 'satelit', 'ambil': 'ambil', 'singapura': 'singapura', 'milik': 'milik', 'maju': 'maju', 'sumpah': 'sumpah', 'deh': 'deh', 'yaaaaa': 'yaaaaa', 'gegara': 'gegara', 'kemaren': 'kemaren', 'karna': 'karna', 'alhasil': 'alhasil', 'nyusul': 'nyusul', 'nilai': 'nilai', 'dipotong': 'potong', 'gurunya': 'guru', 'internetnya': 'internetnya', 'matikan': 'mati', 'seharian': 'hari', 'penuh': 'penuh', 'normal': 'normal', 'engga': 'engga', 'pelanggan': 'langgan', 'mikir': 'mikir', 'koruptor': 'koruptor', 'bawahan': 'bawah', 'atasan': 'atas', 'indiehome': 'indiehome', 'suruh': 'suruh', 'siswa': 'siswa', 'daring': 'daring', 'gpp': 'gpp', 'dikasih': 'kasih', 'sosialis': 'sosialis', 'kapitalis': 'kapitalis', 'bumn': 'bumn', 'republic': 'republic', 'cbn': 'cbn', 'dimana': 'mana', 'murah': 'murah', 'kagak': 'kagak', 'penyebab': 'sebab', 'lemotnya': 'lot', 'krna': 'krna', 'upgrade': 'upgrade', 'cobalah': 'coba', 'masi': 'mas', 'lelet': 'lelet', 'unjuk': 'unjuk', 'mengganggu': 'ganggu', 'kenyamanan': 'nyaman', 'konsumen': 'konsumen', 'selamat': 'selamat', 'tinggal': 'tinggal', 'lgi': 'lgi', 'bulanannya': 'bulan', 'ttapi': 'ttapi', 'koneksinya': 'koneksi', 'sgt': 'sgt', 'smakin': 'smakin', 'unlimited': 'unlimited', 'mmake': 'mmake', 'kartu': 'kartu', 'ccok': 'cco ...
# ------------------------
# Pandas Apply:   0%|          | 0/207 [00:00<?, ?it/s]
#                                                comment  \
# 0    seharusnya pemerintah membuat 1 platform untuk...
# 1    semoga internet bisa cepat dan ga lemot terus ...
# 2                       udh bayar ga boleh telat tiba"
# 3    jangan sering" mengeluh boy, hadapi, rasakan, ...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309               untung udah ganti biznet. huakakakak
# 310                         smartfren kok gak kena ya?
# 311                      di rumah gw kok aman² aja yah
# 312                          mana ada udah membaik..??
#
#                                       cleaning_comment  \
# 0    seharusnya pemerintah membuat platform untuk b...
# 1    semoga internet bisa cepat dan lemot terus tel...
# 2                          udh bayar boleh telat tiba
# 3    jangan sering mengeluh boy hadapi rasakan kepe...
# 36                     stroomnet juara user experience
# ..                                                 ...
# 308  mungkin sudah dikuasai oleh sybil atau ultron ...
# 309                untung udah ganti biznet huakakakak
# 310                            smartfren kok gak kena
# 311                             rumah kok aman aja yah
# 312                             mana ada udah membaik
#
#                                             tokenisasi  \
# 0    [seharusnya, pemerintah, membuat, platform, un...
# 1    [semoga, internet, bisa, cepat, dan, lemot, te...
# 2                   [udh, bayar, boleh, telat, tiba, ]
# 3    [jangan, sering, mengeluh, boy, hadapi, rasaka...
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308  [mungkin, sudah, dikuasai, oleh, sybil, atau, ...
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                      [smartfren, kok, gak, kena, ]
# 311                     [, rumah, kok, aman, aja, yah]
# 312                       [mana, ada, udah, membaik, ]
#
#                                               stopword  \
# 0    [pemerintah, platform, belajar, digratiskan, p...
# 1    [semoga, internet, cepat, lemot, telkomsel, pa...
# 2                                [udh, bayar, telat, ]
# 3    [mengeluh, boy, hadapi, rasakan, kepedihanmu, ...
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308             [dikuasai, sybil, ultron, telkomnya, ]
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                                [smartfren, kena, ]
# 311                                    [, rumah, aman]
# 312                                  [udah, membaik, ]
#
#                                               stemming
# 0    [perintah, platform, ajar, gratis, provider, i...
# 1    [moga, internet, cepat, lot, telkomsel, paket,...
# 2                                [udh, bayar, telat, ]
# 3       [keluh, boy, hadap, rasa, pedih, hidup, boy, ]
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308                 [asai, sybil, ultron, telkomnya, ]
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                                [smartfren, kena, ]
# 311                                    [, rumah, aman]
# 312                                     [udah, baik, ]
#
# [207 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [perintah, platform, ajar, gratis, provider, i...
# 1    [moga, internet, cepat, lot, telkomsel, paket,...
# 2                                [udh, bayar, telat, ]
# 3       [keluh, boy, hadap, rasa, pedih, hidup, boy, ]
# 36                [stroomnet, juara, user, experience]
# ..                                                 ...
# 308                 [asai, sybil, ultron, telkomnya, ]
# 309          [untung, udah, ganti, biznet, huakakakak]
# 310                                [smartfren, kena, ]
# 311                                    [, rumah, aman]
# 312                                     [udah, baik, ]
#
# [207 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_8.xlsx')
