# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Review Nya Bagus , Jelas , Dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    Keren bang, sangat membantu buat para paketer ...
# 3    Itu bayar kedepannya 240rb flat sebelum PPN te...
# 4    THANKS BANG Karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  Aduh saya udah trlanjur pilih paket, bisa pind...
# 278  Punya saya yang 310,pemasangan lupa taunnya tp...
# 279  Bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  Bang saya pake indihome 20mbps sama telepon ba...
#
# [282 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 55

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Review Nya Bagus , Jelas , Dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    Keren bang, sangat membantu buat para paketer ...
# 3    Itu bayar kedepannya 240rb flat sebelum PPN te...
# 4    THANKS BANG Karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  Aduh saya udah trlanjur pilih paket, bisa pind...
# 278  Punya saya yang 310,pemasangan lupa taunnya tp...
# 279  Bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  Bang saya pake indihome 20mbps sama telepon ba...
#
# [173 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    review nya bagus , jelas , dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    keren bang, sangat membantu buat para paketer ...
# 3    itu bayar kedepannya 240rb flat sebelum ppn te...
# 4    thanks bang karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket, bisa pind...
# 278  punya saya yang 310,pemasangan lupa taunnya tp...
# 279  bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  bang saya pake indihome 20mbps sama telepon ba...
#
# [173 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    review nya bagus , jelas , dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    keren bang, sangat membantu buat para paketer ...
# 3    itu bayar kedepannya 240rb flat sebelum ppn te...
# 4    thanks bang karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket, bisa pind...
# 278  punya saya yang 310,pemasangan lupa taunnya tp...
# 279  bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  bang saya pake indihome 20mbps sama telepon ba...
#
#                                       cleaning_comment
# 0    review nya bagus jelas dan detail banget aku s...
# 1    bang mau tanya kalo buat ingame ping yang lebi...
# 2    keren bang sangat membantu buat para paketer y...
# 3    itu bayar kedepannya  rb flat sebelum ppn tent...
# 4    thanks bang karena vidio gua pasang paket indi...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket bisa pinda...
# 278  punya saya yang   pemasangan lupa taunnya kyak...
# 279  bang kalo kita pilih paket internet telpon kal...
# 280  min kalo paket internet bisa diganti paket int...
# 281  bang saya pake indihome  mbps sama telepon bay...
#
# [173 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    review nya bagus , jelas , dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    keren bang, sangat membantu buat para paketer ...
# 3    itu bayar kedepannya 240rb flat sebelum ppn te...
# 4    thanks bang karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket, bisa pind...
# 278  punya saya yang 310,pemasangan lupa taunnya tp...
# 279  bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  bang saya pake indihome 20mbps sama telepon ba...
#
#                                       cleaning_comment  \
# 0    review nya bagus jelas dan detail banget aku s...
# 1    bang mau tanya kalo buat ingame ping yang lebi...
# 2    keren bang sangat membantu buat para paketer y...
# 3    itu bayar kedepannya  rb flat sebelum ppn tent...
# 4    thanks bang karena vidio gua pasang paket indi...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket bisa pinda...
# 278  punya saya yang   pemasangan lupa taunnya kyak...
# 279  bang kalo kita pilih paket internet telpon kal...
# 280  min kalo paket internet bisa diganti paket int...
# 281  bang saya pake indihome  mbps sama telepon bay...
#
#                                             tokenisasi
# 0    [review, nya, bagus, jelas, dan, detail, bange...
# 1    [bang, mau, tanya, kalo, buat, ingame, ping, y...
# 2    [keren, bang, sangat, membantu, buat, para, pa...
# 3    [itu, bayar, kedepannya, rb, flat, sebelum, pp...
# 4    [thanks, bang, karena, vidio, gua, pasang, pak...
# ..                                                 ...
# 277  [aduh, saya, udah, trlanjur, pilih, paket, bis...
# 278  [punya, saya, yang, pemasangan, lupa, taunnya,...
# 279  [bang, kalo, kita, pilih, paket, internet, tel...
# 280  [min, kalo, paket, internet, bisa, diganti, pa...
# 281  [bang, saya, pake, indihome, mbps, sama, telep...
#
# [173 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    review nya bagus , jelas , dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    keren bang, sangat membantu buat para paketer ...
# 3    itu bayar kedepannya 240rb flat sebelum ppn te...
# 4    thanks bang karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket, bisa pind...
# 278  punya saya yang 310,pemasangan lupa taunnya tp...
# 279  bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  bang saya pake indihome 20mbps sama telepon ba...
#
#                                       cleaning_comment  \
# 0    review nya bagus jelas dan detail banget aku s...
# 1    bang mau tanya kalo buat ingame ping yang lebi...
# 2    keren bang sangat membantu buat para paketer y...
# 3    itu bayar kedepannya  rb flat sebelum ppn tent...
# 4    thanks bang karena vidio gua pasang paket indi...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket bisa pinda...
# 278  punya saya yang   pemasangan lupa taunnya kyak...
# 279  bang kalo kita pilih paket internet telpon kal...
# 280  min kalo paket internet bisa diganti paket int...
# 281  bang saya pake indihome  mbps sama telepon bay...
#
#                                             tokenisasi  \
# 0    [review, nya, bagus, jelas, dan, detail, bange...
# 1    [bang, mau, tanya, kalo, buat, ingame, ping, y...
# 2    [keren, bang, sangat, membantu, buat, para, pa...
# 3    [itu, bayar, kedepannya, rb, flat, sebelum, pp...
# 4    [thanks, bang, karena, vidio, gua, pasang, pak...
# ..                                                 ...
# 277  [aduh, saya, udah, trlanjur, pilih, paket, bis...
# 278  [punya, saya, yang, pemasangan, lupa, taunnya,...
# 279  [bang, kalo, kita, pilih, paket, internet, tel...
# 280  [min, kalo, paket, internet, bisa, diganti, pa...
# 281  [bang, saya, pake, indihome, mbps, sama, telep...
#
#                                               stopword
# 0    [review, bagus, detail, banget, suka, kak, sei...
# 1    [bang, ingame, ping, bagusan, pakai, mbps, mbp...
# 2    [keren, bang, membantu, paketer, gabung, wifie...
# 3    [bayar, kedepannya, rb, flat, ppn, habis, prom...
# 4    [thanks, bang, vidio, gua, pasang, paket, indi...
# ..                                                 ...
# 277  [aduh, udah, trlanjur, pilih, paket, pindah, p...
# 278  [pemasangan, lupa, taunnya, kyaknya, dapet, tsun]
# 279  [bang, pilih, paket, internet, telpon, dirumah...
# 280  [min, paket, internet, diganti, paket, interne...
# 281  [bang, indihome, mbps, telepon, bayar, bulanan...
#
# [173 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 570
# ------------------------
# review : review
# bagus : bagus
# detail : detail
# banget : banget
# suka : suka
# kak : kak
# seiring : iring
# konten : konten
# bangg : bangg
#  :
# bang : bang
# ingame : ingame
# ping : ping
# bagusan : bagus
# pakai : pakai
# mbps : mbps
# perbedaan : beda
# dimana : mana
# main : main
# game : game
# keren : keren
# membantu : bantu
# paketer : paketer
# gabung : gabung
# wifier : wifier
# bayar : bayar
# kedepannya : depan
# rb : rb
# flat : flat
# ppn : ppn
# habis : habis
# promo : promo
# tagihannya : tagih
# iya : iya
# sistem : sistem
# kontrak : kontrak
# minimal : minimal
# thanks : thanks
# vidio : vidio
# gua : gua
# pasang : pasang
# paket : paket
# indihome : indihome
# terimaksih : terimaksih
# reviewnya : reviewnya
# mohon : mohon
# info : info
# livestreaming : livestreaming
# fanspage : fanspage
# masang : masang
# tanggal : tanggal
# september : september
# harga : harga
# pas : pas
# udah : udah
# terpasang : pasang
# dikasih : kasih
# nomor : nomor
# dibayarkan : bayar
# bayarnya : bayar
# teknisi : teknisi
# kyak : kyak
# tagihan : tagih
# tokopedia : tokopedia
# indomaret : indomaret
# alfamart : alfamart
# dll : dll
# pulang : pulang
# teknisinya : teknisi
# emang : emang
# gitu : gitu
# fup : fup
# fupnya : fupnya
# bermanfaat : manfaat
# makasih : makasih
# abis : abis
# verifikasi : verifikasi
# selesai : selesai
# pemasangan : pasang
# upgrade : upgrade
# speed : speed
# diproses : proses
# gan : gan
# beda : beda
# lokasi : lokasi
# kecepatan : cepat
# aing : aing
# dipedalaman : dalam
# brp : brp
# pubg : pubg
# orang : orang
# yutuban : yutuban
# ama : ama
# download : download
# gimana : gimana
# trus : trus
# kah : kah
# normal : normal
# daerah : daerah
# ane : ane
# deket : deket
# tower : tower
# telkom : telkom
# kecepetan : kecepetan
# ngaruh : ngaruh
# cepet : cepet
# rencana : rencana
# cek : cek
# karna : karna
# niat : niat
# internet : internet
# only : only
# hrg : hrg
# blm : blm
# spek : spek
# laptop : laptop
# abang : abang
# registrasi : registrasi
# online : online
# tgl : tgl
# dtg : dtg
# rumah : rumah
# secepat : cepat
# hubungi : hubung
# smpe : smpe
# skrng : skrng
# gaada : gaada
# kabar : kabar
# gmna : gmna
# progres : progres
# selanjutny : selanjutny
# gtu : gtu
# udh : udh
# kesel : kesel
# sya : sya
# nungguin : nungguin
# pdahal : pdahal
# butuh : butuh
# kerja : kerja
# kelemahan : lemah
# gue : gue
# kena : kena
# klw : klw
# bulanannya : bulan
# migrasi : migrasi
# nanya : nanya
# liat : liat
# mpbs : mpbs
# perangkat : perangkat
# pakainya : pakai
# koreksi : koreksi
# phone : phone
# dipake : dipake
# ngga : ngga
# aslii : asli
# puasa : puasa
# bangett : bangett
# cobaa : cobaa
# pakety : pakety
# inii : ini
# tpi : tpi
# dispedtes : dispedtes
# mempengaruhi : pengaruh
# tetep : tetep
# sesuai : sesuai
# daftar : daftar
# dpt : dpt
# akses : akses
# kabel : kabel
# lan : lan
# coba : coba
# lihat : lihat
# settingan : settingan
# wifi : wifi
# next : next
# pengen : ken
# harganya : harga
# pembayaran : bayar
# tolong : tolong
# reply : reply
# mas : mas
# ketiga : tiga
# perbulan : bulan
# ttp : ttp
# berubah : ubah
# siapin : siapin
# telpon : telpon
# rumahnya : rumah
# sinyal : sinyal
# denger : denger
# keluhan : keluh
# dri : dri
# org : org
# temen : temen
# indihomo : indihomo
# jancok : jancok
# sinyale : sinyale
# inet : inet
# tlp : tlp
# kcepatan : kcepatan
# donloud : donloud
# aploud : aploud
# unlimited : unlimited
# bulannya : bulan
# yaa : yaa
# ketipu : tipu
# salesnya : salesnya
# uang : uang
# tertera : tera
# paketnya : paket
# kadang : kadang
# keatas : atas
# buka : buka
# yutup : yutup
# user : user
# total : total
# duit : duit
# nambah : nambah
# bener : bener
# mksdny : mksdny
# telepon : telepon
# menit : menit
# pls : pls
# aman : aman
# jaringan : jaring
# livestream : livestream
# youtube : youtube
# ngangkat : ngangkat
# mang : mang
# balas : balas
# desa : desa
# jaringannya : jaring
# bedanya : beda
# kota : kota
# telkomsel : telkomsel
# axis : axis
# merah : merah
# beralih : alih
# terima : terima
# kasih : kasih
# subscribe : subscribe
# bro : bro
# plasa : plasa
# pemakaian : pakai
# bulanan : bulan
# skrg : skrg
# indihomenya : indihomenya
# instalasi : instalasi
# jga : jga
# banh : banh
# point : point
# blank : blank
# kenak : nak
# nunggu : nunggu
# esokan : esok
# harinya : hari
# cepat : cepat
# pajak : pajak
# gimne : gimne
# perbulannya : bulan
# yangg : yangg
# ribu : ribu
# aplikasi : aplikasi
# bagii : bagi
# ceritanya : cerita
# dongg : dongg
# lancar : lancar
# streaming : streaming
# berlangganan : langgan
# langsung : langsung
# dapet : dapet
# brapa : brapa
# kuat : kuat
# modem : modem
# gratis : gratis
# modemnya : modem
# ghz : ghz
# brow : brow
# kalok : kalok
# pakek : pakek
# jaringanya : jaringanya
# fake : fake
# bruh : bruh
# installed : installed
# and : and
# the : the
# faster : faster
# than : than
# still : still
# getting : getting
# robed : robed
# rp : rp
# monthly : monthly
# for : for
# bln : bln
# wort : wort
# hp : hp
# keperluan : perlu
# sekolah : sekolah
# salah : salah
# fokus : fokus
# iklan : iklan
# sebelah : belah
# kiri : kiri
# aktif : aktif
# jam : jam
# gede : gede
# stabil : stabil
# auto : auto
# lag : lag
# bantu : bantu
# jwb : jwb
# krna : krna
# tercover : tercover
# cuman : cuman
# doang : doang
# konfirmasi : konfirmasi
# gb : gb
# blnnya : blnnya
# mencapai : capai
# mati : mati
# tarif : tarif
# nyala : nyala
# diturunin : diturunin
# kecepatannya : cepat
# nonton : nonton
# video : video
# kualitas : kualitas
# detik : detik
# buffering : buffering
# loncat : loncat
# salfok : salfok
# speedtest : speedtest
# okla : okla
# ngomong : ngomong
# jowo : jowo
# wae : wae
# biaaya : biaaya
# jakarta : jakarta
# timur : timur
# gme : gme
# turun : turun
# pingny : pingny
# pling : pling
# njr : njr
# disebelah : belah
# jualan : jual
# kolor : kolor
# maen : maen
# moba : moba
# maennya : maennya
# nob : nob
# wms : wms
# bkn : bkn
# mending : mending
# biznet : biznet
# zalora : zalora
# wuuuhhhh : wuuuhhhh
# bur : bur
# ubur : ubur
# ting : ting
# palet : palet
# telp : telp
# brosur : brosur
# biaya : biaya
# abonemen : abonemen
# tambahan : tambah
# reguler : reguler
# maaf : maaf
# wilayah : wilayah
# madura : madura
# berlanganan : berlanganan
# pilih : pilih
# ganti : ganti
# kemahalan : mahal
# dicabut : cabut
# pencerahannya : cerah
# diakses : akses
# bersamaan : sama
# brosurnya : brosur
# web : web
# diakalin : diakalin
# dikit : dikit
# nelponnya : nelponnya
# operator : operator
# pelanggan : langgan
# pindah : pindah
# thks : thks
# berlangganannya : langgan
# sampe : sampe
# denda : denda
# pusat : pusat
# mantap : mantap
# pencerahanya : pencerahanya
# infonya : info
# smart : smart
# konek : konek
# bisnis : bisnis
# vocer : vocer
# enakan : enak
# sebulan : bulan
# seterus : terus
# saratnya : sarat
# pusing : pusing
# dipindahkan : pindah
# biayanya : biaya
# brpa : brpa
# rekomended : rekomended
# live : live
# gaming : gaming
# cocok : cocok
# enak : enak
# lfh : lfh
# update : update
# kepikiran : pikir
# nyari : nyari
# bonus : bonus
# terbatas : batas
# saran : saran
# ambil : ambil
# dilepas : lepas
# berkurang : kurang
# perbln : perbln
# diganti : ganti
# android : android
# box : box
# routernya : routernya
# maksimal : maksimal
# pemakaiannya : pakai
# kalu : kalu
# knp : knp
# ferforma : ferforma
# jelek : jelek
# contoh : contoh
# pass : pass
# ms : ms
# rame : rame
# narik : narik
# tetangga : tetangga
# murah : murah
# mksdnya : mksdnya
# chanel : chanel
# ilang : ilang
# kuota : kuota
# terlanjur : lanjur
# milih : milih
# ubah : ubah
# kurangin : rangin
# transisinya : transisi
# jujur : jujur
# rban : rban
# lemot : lot
# beli : beli
# telat : telat
# blokir : blokir
# mis : mis
# oxygen : oxygen
# plus : plus
# flet : flet
# kencang : kencang
# smpai : smpai
# minggu : minggu
# berbeda : beda
# pkt : pkt
# pengaruh : pengaruh
# internetnya : internetnya
# dateng : dateng
# plaza : plaza
# layanan : layan
# terpakai : pakai
# mengurangi : kurang
# kuotanya : kuota
# batasanya : batasanya
# kmrn : kmrn
# mbp : mbp
# prnh : prnh
# memuaskan : muas
# rcti : rcti
# mnc : mnc
# gtv : gtv
# sctv : sctv
# bola : bola
# didaerah : daerah
# telphone : telphone
# membayar : bayar
# putuskan : putus
# diindihome : diindihome
# router : router
# sewa : sewa
# hilang : hilang
# signalnya : signalnya
# pokoknya : pokok
# provider : provider
# indohome : indohome
# mahal : mahal
# meyesalllllll : meyesalllllll
# penah : penah
# cabut : cabut
# gara : gara
# asalnya : asal
# tawarin : tawarin
# masuk : masuk
# akal : akal
# batalin : batalin
# langganan : langgan
# segitu : segitu
# promonya : promonya
# deposit : deposit
# dikembalikan : kembali
# kdepannya : kdepannya
# bgm : bgm
# takut : takut
# terkecoh : kecoh
# mksh : mksh
# butuhkan : butuh
# ato : ato
# tablet : tablet
# petugasnya : tugas
# selebaran : selebaran
# nnya : nnya
# email : email
# ktax : ktax
# hrs : hrs
# minipack : minipack
# preuseeincbsh : preuseeincbsh
# shrga : shrga
# pdhal : pdhal
# bli : bli
# apapn : apapn
# atw : atw
# penambahan : tambah
# fix : fix
# telpone : telpone
# lelet : lelet
# disuruh : suruh
# naikin : naikin
# nolak : nolak
# sampek : sampek
# maret : maret
# nggak : nggak
# penjelasannyaa : penjelasannyaa
# alat : alat
# sndiri : sndiri
# ntah : ntah
# dicek : cek
# aslinya : asli
# nelfon : nelfon
# juni : juni
# wajar : wajar
# byarbulan : byarbulan
# film : film
# netflix : netflix
# cocoknya : cocok
# bayaran : bayar
# kdang : kdang
# tembus : tembus
# enaknya : enak
# dirumah : rumah
# tersambung : sambung
# aduh : aduh
# trlanjur : trlanjur
# lupa : lupa
# taunnya : taun
# kyaknya : kyaknya
# tsun : tsun
# telponya : telponya
# min : min
# mhon : mhon
# via : via
# oktober : oktober
# {'review': 'review', 'bagus': 'bagus', 'detail': 'detail', 'banget': 'banget', 'suka': 'suka', 'kak': 'kak', 'seiring': 'iring', 'konten': 'konten', 'bangg': 'bangg', '': '', 'bang': 'bang', 'ingame': 'ingame', 'ping': 'ping', 'bagusan': 'bagus', 'pakai': 'pakai', 'mbps': 'mbps', 'perbedaan': 'beda', 'dimana': 'mana', 'main': 'main', 'game': 'game', 'keren': 'keren', 'membantu': 'bantu', 'paketer': 'paketer', 'gabung': 'gabung', 'wifier': 'wifier', 'bayar': 'bayar', 'kedepannya': 'depan', 'rb': 'rb', 'flat': 'flat', 'ppn': 'ppn', 'habis': 'habis', 'promo': 'promo', 'tagihannya': 'tagih', 'iya': 'iya', 'sistem': 'sistem', 'kontrak': 'kontrak', 'minimal': 'minimal', 'thanks': 'thanks', 'vidio': 'vidio', 'gua': 'gua', 'pasang': 'pasang', 'paket': 'paket', 'indihome': 'indihome', 'terimaksih': 'terimaksih', 'reviewnya': 'reviewnya', 'mohon': 'mohon', 'info': 'info', 'livestreaming': 'livestreaming', 'fanspage': 'fanspage', 'masang': 'masang', 'tanggal': 'tanggal', 'september': 'september', 'harga': 'harga', 'pas': 'pas', 'udah': 'udah', 'terpasang': 'pasang', 'dikasih': 'kasih', 'nomor': 'nomor', 'dibayarkan': 'bayar', 'bayarnya': 'bayar', 'teknisi': 'teknisi', 'kyak': 'kyak', 'tagihan': 'tagih', 'tokopedia': 'tokopedia', 'indomaret': 'indomaret', 'alfamart': 'alfamart', 'dll': 'dll', 'pulang': 'pulang', 'teknisinya': 'teknisi', 'emang': 'emang', 'gitu': 'gitu', 'fup': 'fup', 'fupnya': 'fupnya', 'bermanfaat': 'manfaat', 'makasih': 'makasih', 'abis': 'abis', 'verifikasi': 'verifikasi', 'selesai': 'selesai', 'pemasangan': 'pasang', 'upgrade': 'upgrade', 'speed': 'speed', 'diproses': 'proses', 'gan': 'gan', 'beda': 'beda', 'lokasi': 'lokasi', 'kecepatan': 'cepat', 'aing': 'aing', 'dipedalaman': 'dalam', 'brp': 'brp', 'pubg': 'pubg', 'orang': 'orang', 'yutuban': 'yutuban', 'ama': 'ama', 'download': 'download', 'gimana': 'gimana', 'trus': 'trus', 'kah': 'kah', 'normal': 'normal', 'daerah': 'daerah', 'ane': 'ane', 'deket': 'deket', 'tower': 'tower', 'telkom': 'telkom', 'kecepetan': 'kecepetan', 'ngaruh': 'ngaruh', 'cepet': 'cepet', 'rencana': 'rencana', 'cek': 'cek', 'karna': 'karna', 'niat': 'niat', 'internet': 'internet', 'only': 'only', 'hrg': 'hrg', 'blm': 'blm', 'spek': 'spek', 'laptop': 'laptop', 'abang': 'abang', 'registrasi': 'registrasi', 'online': 'online', 'tgl': 'tgl', 'dtg': 'dtg', 'rumah': 'rumah', 'secepat': 'cepat', 'hubungi': 'hubung', 'smpe': 'smpe', 'skrng': 'skrng', 'gaada': 'gaada', 'kabar': 'kabar', 'gmna': 'gmna', 'progres': 'progres', 'selanjutny': 'selanjutny', 'gtu': 'gtu', 'udh': 'udh', 'kesel': 'kesel', 'sya': 'sya', 'nungguin': 'nungguin', 'pdahal': 'pdahal', 'butuh': 'butuh', 'kerja': 'kerja', 'kelemahan': 'lemah', 'gue': 'gue', 'kena': 'kena', 'klw': 'klw', 'bulanannya': 'bulan', 'migrasi': 'migrasi', 'nanya': 'nanya', 'liat': 'liat', 'mpbs': 'mpbs', 'perangkat': 'perangkat', 'pakainya': 'pakai', 'koreksi': 'koreksi', 'phone': 'phone', 'dipake': 'dipake', 'ngga': 'ngga', 'aslii': 'asli', 'puasa': 'puasa', 'bangett': 'bangett', 'cobaa': 'cobaa', 'pakety': 'pakety', 'inii': 'ini', 'tpi': 'tpi', 'dispedtes': 'dispedtes', 'mempengaruhi': 'pengaruh', 'tetep': 'tetep', 'sesuai': 'sesuai', 'daftar': 'daftar', 'dpt': 'dpt', 'akses': 'akses', 'kabel': 'kabel', 'lan': 'lan', 'coba': 'coba', 'lihat': 'lihat', 'settingan': 'settingan', 'wifi': 'wifi', 'next': 'next', 'pengen': 'ken', 'harganya': 'harga', 'pembayaran': 'bayar', 'tolong': 'tolong', 'reply': 'reply', 'mas': 'mas', 'ketiga': 'tiga', 'perbulan': 'bulan', 'ttp': 'ttp', 'berubah': 'ubah', 'siapin': 'siapin', 'telpon': 'telpon', 'rumahnya': 'rumah', 'sinyal': 'sinyal', 'denger': 'denger', 'keluhan': 'keluh', 'dri': 'dri', 'org': 'org', 'temen': 'temen', 'indihomo': 'indihomo', 'jancok': 'jancok', 'sinyale': 'sinyale', 'inet': 'inet', 'tlp': 'tlp', 'kcepatan': 'kcepatan', 'donloud': 'donloud', 'aploud': 'aploud', 'unlimited': 'unlimited', 'bulannya': 'bulan', 'yaa': 'yaa', 'ketipu': 'tipu', 'salesnya': 'salesnya', 'uang': 'uang', 'tertera': 'tera', 'paketnya': ...
# ------------------------
# Pandas Apply:   0%|          | 0/173 [00:00<?, ?it/s]
#                                                comment  \
# 0    review nya bagus , jelas , dan detail banget a...
# 1    bang mau tanya, kalo buat ingame ping yang leb...
# 2    keren bang, sangat membantu buat para paketer ...
# 3    itu bayar kedepannya 240rb flat sebelum ppn te...
# 4    thanks bang karena vidio lu gua pasang paket i...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket, bisa pind...
# 278  punya saya yang 310,pemasangan lupa taunnya tp...
# 279  bang kalo kita pilih paket internet+telpon kal...
# 280  min kalo paket (internet+tv) bisa diganti ke p...
# 281  bang saya pake indihome 20mbps sama telepon ba...
#
#                                       cleaning_comment  \
# 0    review nya bagus jelas dan detail banget aku s...
# 1    bang mau tanya kalo buat ingame ping yang lebi...
# 2    keren bang sangat membantu buat para paketer y...
# 3    itu bayar kedepannya  rb flat sebelum ppn tent...
# 4    thanks bang karena vidio gua pasang paket indi...
# ..                                                 ...
# 277  aduh saya udah trlanjur pilih paket bisa pinda...
# 278  punya saya yang   pemasangan lupa taunnya kyak...
# 279  bang kalo kita pilih paket internet telpon kal...
# 280  min kalo paket internet bisa diganti paket int...
# 281  bang saya pake indihome  mbps sama telepon bay...
#
#                                             tokenisasi  \
# 0    [review, nya, bagus, jelas, dan, detail, bange...
# 1    [bang, mau, tanya, kalo, buat, ingame, ping, y...
# 2    [keren, bang, sangat, membantu, buat, para, pa...
# 3    [itu, bayar, kedepannya, rb, flat, sebelum, pp...
# 4    [thanks, bang, karena, vidio, gua, pasang, pak...
# ..                                                 ...
# 277  [aduh, saya, udah, trlanjur, pilih, paket, bis...
# 278  [punya, saya, yang, pemasangan, lupa, taunnya,...
# 279  [bang, kalo, kita, pilih, paket, internet, tel...
# 280  [min, kalo, paket, internet, bisa, diganti, pa...
# 281  [bang, saya, pake, indihome, mbps, sama, telep...
#
#                                               stopword  \
# 0    [review, bagus, detail, banget, suka, kak, sei...
# 1    [bang, ingame, ping, bagusan, pakai, mbps, mbp...
# 2    [keren, bang, membantu, paketer, gabung, wifie...
# 3    [bayar, kedepannya, rb, flat, ppn, habis, prom...
# 4    [thanks, bang, vidio, gua, pasang, paket, indi...
# ..                                                 ...
# 277  [aduh, udah, trlanjur, pilih, paket, pindah, p...
# 278  [pemasangan, lupa, taunnya, kyaknya, dapet, tsun]
# 279  [bang, pilih, paket, internet, telpon, dirumah...
# 280  [min, paket, internet, diganti, paket, interne...
# 281  [bang, indihome, mbps, telepon, bayar, bulanan...
#
#                                               stemming
# 0    [review, bagus, detail, banget, suka, kak, iri...
# 1    [bang, ingame, ping, bagus, pakai, mbps, mbps,...
# 2      [keren, bang, bantu, paketer, gabung, wifier, ]
# 3    [bayar, depan, rb, flat, ppn, habis, promo, ta...
# 4    [thanks, bang, vidio, gua, pasang, paket, indi...
# ..                                                 ...
# 277  [aduh, udah, trlanjur, pilih, paket, pindah, p...
# 278         [pasang, lupa, taun, kyaknya, dapet, tsun]
# 279  [bang, pilih, paket, internet, telpon, rumah, ...
# 280  [min, paket, internet, ganti, paket, internet,...
# 281  [bang, indihome, mbps, telepon, bayar, bulan, ...
#
# [173 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [review, bagus, detail, banget, suka, kak, iri...
# 1    [bang, ingame, ping, bagus, pakai, mbps, mbps,...
# 2      [keren, bang, bantu, paketer, gabung, wifier, ]
# 3    [bayar, depan, rb, flat, ppn, habis, promo, ta...
# 4    [thanks, bang, vidio, gua, pasang, paket, indi...
# ..                                                 ...
# 277  [aduh, udah, trlanjur, pilih, paket, pindah, p...
# 278         [pasang, lupa, taun, kyaknya, dapet, tsun]
# 279  [bang, pilih, paket, internet, telpon, rumah, ...
# 280  [min, paket, internet, ganti, paket, internet,...
# 281  [bang, indihome, mbps, telepon, bayar, bulan, ...
#
# [173 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_3.xlsx')
