# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Auto subscribe bang, terjawab sudah pertanyaan...
# 1    Bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    Thanks bro gw sampe bolak balik ke ATM sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    Aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 307                                     Lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     Indihome gak guna mending mola
# 310  Bro jangan mau daftar, gw daftar yg 20 Mbps le...
# 311  Bang kalau sudah tinggal pemasangan terus pas ...
#
# [312 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 75

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Auto subscribe bang, terjawab sudah pertanyaan...
# 1    Bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    Thanks bro gw sampe bolak balik ke ATM sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    Aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 306  Bang saya udah daftar online sudah d telpon ta...
# 307                                     Lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     Indihome gak guna mending mola
# 310  Bro jangan mau daftar, gw daftar yg 20 Mbps le...
#
# [162 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    auto subscribe bang, terjawab sudah pertanyaan...
# 1    bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    thanks bro gw sampe bolak balik ke atm sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 306  bang saya udah daftar online sudah d telpon ta...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar, gw daftar yg 20 mbps le...
#
# [162 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    auto subscribe bang, terjawab sudah pertanyaan...
# 1    bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    thanks bro gw sampe bolak balik ke atm sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 306  bang saya udah daftar online sudah d telpon ta...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar, gw daftar yg 20 mbps le...
#
#                                       cleaning_comment
# 0    auto subscribe bang terjawab sudah pertanyaan ...
# 1    bayar  rban itu cuma buat bulan aja selanjut n...
# 2    thanks bro sampe bolak balik atm sama mini mar...
# 3    bulan ini gue mengalami hal yang sama kaget aw...
# 4    aku juga kaget bang bulan ini cuman  ribu aja ...
# ..                                                 ...
# 306  bang saya udah daftar online sudah telpon tapi...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome jaringan nya nge l...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar daftar mbps lemot minta ...
#
# [162 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    auto subscribe bang, terjawab sudah pertanyaan...
# 1    bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    thanks bro gw sampe bolak balik ke atm sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 306  bang saya udah daftar online sudah d telpon ta...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar, gw daftar yg 20 mbps le...
#
#                                       cleaning_comment  \
# 0    auto subscribe bang terjawab sudah pertanyaan ...
# 1    bayar  rban itu cuma buat bulan aja selanjut n...
# 2    thanks bro sampe bolak balik atm sama mini mar...
# 3    bulan ini gue mengalami hal yang sama kaget aw...
# 4    aku juga kaget bang bulan ini cuman  ribu aja ...
# ..                                                 ...
# 306  bang saya udah daftar online sudah telpon tapi...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome jaringan nya nge l...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar daftar mbps lemot minta ...
#
#                                             tokenisasi
# 0    [auto, subscribe, bang, terjawab, sudah, perta...
# 1    [bayar, rban, itu, cuma, buat, bulan, aja, sel...
# 2    [thanks, bro, sampe, bolak, balik, atm, sama, ...
# 3    [bulan, ini, gue, mengalami, hal, yang, sama, ...
# 4    [aku, juga, kaget, bang, bulan, ini, cuman, ri...
# ..                                                 ...
# 306  [bang, saya, udah, daftar, online, sudah, telp...
# 307                                 [lag, bangat, asu]
# 308  [jangan, pernah, pake, indihome, jaringan, nya...
# 309               [indihome, gak, guna, mending, mola]
# 310  [bro, jangan, mau, daftar, daftar, mbps, lemot...
#
# [162 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    auto subscribe bang, terjawab sudah pertanyaan...
# 1    bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    thanks bro gw sampe bolak balik ke atm sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 306  bang saya udah daftar online sudah d telpon ta...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar, gw daftar yg 20 mbps le...
#
#                                       cleaning_comment  \
# 0    auto subscribe bang terjawab sudah pertanyaan ...
# 1    bayar  rban itu cuma buat bulan aja selanjut n...
# 2    thanks bro sampe bolak balik atm sama mini mar...
# 3    bulan ini gue mengalami hal yang sama kaget aw...
# 4    aku juga kaget bang bulan ini cuman  ribu aja ...
# ..                                                 ...
# 306  bang saya udah daftar online sudah telpon tapi...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome jaringan nya nge l...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar daftar mbps lemot minta ...
#
#                                             tokenisasi  \
# 0    [auto, subscribe, bang, terjawab, sudah, perta...
# 1    [bayar, rban, itu, cuma, buat, bulan, aja, sel...
# 2    [thanks, bro, sampe, bolak, balik, atm, sama, ...
# 3    [bulan, ini, gue, mengalami, hal, yang, sama, ...
# 4    [aku, juga, kaget, bang, bulan, ini, cuman, ri...
# ..                                                 ...
# 306  [bang, saya, udah, daftar, online, sudah, telp...
# 307                                 [lag, bangat, asu]
# 308  [jangan, pernah, pake, indihome, jaringan, nya...
# 309               [indihome, gak, guna, mending, mola]
# 310  [bro, jangan, mau, daftar, daftar, mbps, lemot...
#
#                                               stopword
# 0              [auto, subscribe, bang, terjawab, hati]
# 1                    [bayar, rban, selanjut, normal, ]
# 2    [thanks, bro, sampe, bolak, atm, mini, market,...
# 3    [gue, mengalami, kaget, pas, dengerin, konten,...
# 4    [kaget, bang, cuman, ribu, bayar, perbulannya,...
# ..                                                 ...
# 306  [bang, udah, daftar, online, telpon, pas, angk...
# 307                                      [lag, bangat]
# 308                     [indihome, jaringan, nge, lag]
# 309                          [indihome, mending, mola]
# 310  [bro, daftar, daftar, mbps, lemot, ampun, jari...
#
# [162 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 567
# ------------------------
# auto : auto
# subscribe : subscribe
# bang : bang
# terjawab : jawab
# hati : hati
# bayar : bayar
# rban : rban
# selanjut : lanjut
# normal : normal
#  :
# thanks : thanks
# bro : bro
# sampe : sampe
# bolak : bolak
# atm : atm
# mini : mini
# market : market
# tagihan : tagih
# tetep : tetep
# ribuan : ribu
# gue : gue
# mengalami : alami
# kaget : kaget
# pas : pas
# dengerin : dengerin
# konten : konten
# makasih : makasih
# udah : udah
# kasih : kasih
# pencerahan : cerah
# bener : bener
# defosit : defosit
# cuman : cuman
# ribu : ribu
# perbulannya : bulan
# kaya : kaya
# percaya : percaya
# sma : sma
# mbak : mbak
# kasirnya : kasir
# hehehe : hehehe
# kirain : kirain
# infonya : info
# kakak : kakak
# kasir : kasir
# serius : serius
# mas : mas
# gabohong : gabohong
# masnya : mas
# nota : nota
# ntar : ntar
# sumpah : sumpah
# banget : banget
# okey : okey
# mksh : mksh
# informasinya : informasi
# membantu : bantu
# pdhl : pdhl
# tolong : tolong
# pasang : pasang
# berhenti : henti
# berlangganan : langgan
# indihome : indihome
# denda : denda
# juta : juta
# gimana : gimana
# terimakasih : terimakasih
# info : info
# sngat : sngat
# pantes : pantes
# paket : paket
# mbps : mbps
# skrng : skrng
# rb : rb
# udh : udh
# september : september
# ceria : ceria
# shopee : shopee
# dana : dana
# beda : beda
# terisolir : isolir
# rajin : rajin
# tgl : tgl
# barusan : barusan
# trnyata : trnyata
# ahahaha : ahahaha
# alhamdulillah : alhamdulillah
# nonton : nonton
# panik : panik
# belom : bom
# masuk : masuk
# kak : kak
# doble : doble
# transfer : transfer
# gara : gara
# sinyal : sinyal
# wifii : wifii
# jelek : jelek
# gb : gb
# pakai : pakai
# org : org
# nyesek : nyesek
# nunggu : nunggu
# setahun : tahun
# putus : putus
# kontrak : kontrak
# kena : kena
# sya : sya
# pertma : pertma
# msang : msang
# bln : bln
# mohon : mohon
# beneran : beneran
# byar : byar
# wifi : wifi
# gua : gua
# tagihanya : tagihanya
# keteranganya : keteranganya
# bulananya : bulananya
# koneksinya : koneksi
# lancar : lancar
# pencerahanya : pencerahanya
# punyaku : punya
# takut : takut
# dobel : dobel
# dibulan : bulan
# kukira : kira
# habis : habis
# sannya : sannya
# disuruh : suruh
# rbu : rbu
# penjelasannya : jelas
# salah : salah
# san : san
# nice : nice
# doang : doang
# ngalamin : ngalamin
# ngasih : ngasih
# untung : untung
# bareng : bareng
# ama : ama
# istri : istri
# ingetin : ingetin
# kebanyakan : banyak
# wkwkwk : wkwkwk
# iya : iya
# kejadiannya : jadi
# mantaap : mantaap
# langsung : langsung
# shock : shock
# nuhun : nuhun
# tenang : tenang
# hahaha : hahaha
# mantap : mantap
# boasa : boasa
# tkt : tkt
# dbayar : dbayar
# sekrg : sekrg
# kjwab : kjwab
# lgsng : lgsng
# like : like
# genap : genap
# potongan : potong
# jarak : jarak
# brpa : brpa
# chat : chat
# blom : blom
# dpt : dpt
# yaampun : yaampun
# kegelisahanku : gelisah
# alfamart : alfamart
# juni : juni
# terima : terima
# penjelasan : jelas
# was : was
# tuk : tuk
# pembayaran : bayar
# tagian : tagian
# maap : maap
# paham : paham
# download : download
# aplikasinya : aplikasi
# pencerahannya : cerah
# suskareb : suskareb
# youtubya : youtubya
# penasaran : penasaran
# lihat : lihat
# perbulan : bulan
# kesalahan : salah
# semoga : moga
# aman : aman
# hadiah : hadiah
# ultah : ultah
# tahunya : tahu
# duit : duit
# flat : flat
# tdnya : tdnya
# tabungan : tabung
# kemaren : kemaren
# pembayarn : pembayarn
# trs : trs
# bingung : bingung
# setaun : taun
# indihimoenya : indihimoenya
# oalah : oalah
# gitu : gitu
# berlaku : laku
# kali : kali
# waw : waw
# mah : mah
# gabakal : gabakal
# lipat : lipat
# sihh : sihh
# rebu : rebu
# merosot : merosot
# syok : syok
# cma : cma
# pintr : pintr
# blm : blm
# staun : staun
# akn : akn
# blik : blik
# deposit : deposit
# angus : angus
# gessss : gessss
# lahh : lahh
# murah : murah
# bet : bet
# relevan : relevan
# content : content
# trims : trims
# nyabut : nyabut
# modem : modem
# video : video
# yaa : yaa
# telat : telat
# januari : januari
# gabisa : gabisa
# karna : karna
# tanggal : tanggal
# segitu : segitu
# melongok : longok
# emang : emang
# njr : njr
# stelah : stelah
# liat : liat
# vid : vid
# abng : abng
# lega : lega
# wkwkkw : wkwkkw
# trima : trima
# ksh : ksh
# byr : byr
# oktober : oktober
# buka : buka
# youtube : youtube
# deh : deh
# kepikiran : pikir
# cmn : cmn
# tdi : tdi
# siang : siang
# brusan : brusan
# dek : dek
# takutnx : takutnx
# membengkak : bengkak
# kah : kah
# berubah : ubah
# pdhal : pdhal
# pasangnya : pasang
# cari : cari
# knp : knp
# uang : uang
# nemu : nemu
# vidio : vidio
# depositku : deposit
# thn : thn
# lbh : lbh
# dikembalikan : kembali
# masihhh : masihhh
# nyantolllll : nyantolllll
# nunggak : nunggak
# thanx : thanx
# indiehome : indiehome
# asli : asli
# plus : plus
# seneng : neng
# bayr : bayr
# shoppe : shoppe
# tagihannya : tagih
# doonggggg : doonggggg
# campur : campur
# aduk : aduk
# yahhh : yahhh
# nihh : nihh
# dab : dab
# lngsng : lngsng
# vlog : vlog
# ohhh : ohhh
# gini : gin
# mudhan : mudhan
# gada : gada
# double : double
# thx : thx
# pembayara : pembayara
# heran : heran
# manfaat : manfaat
# bnr : bnr
# bahas : bahas
# bayarnya : bayar
# dapet : dapet
# konfirmasi : konfirmasi
# guys : guys
# dendanya : denda
# ane : ane
# promo : promo
# pandemi : pandemi
# terkejut : kejut
# main : main
# hasil : hasil
# live : live
# streaming : streaming
# upload : upload
# indihoy : indihoy
# nnya : nnya
# pemasangan : pasang
# hangus : hangus
# jwab : jwab
# kesini : kesini
# turun : turun
# tratis : tratis
# server : server
# cek : cek
# kagett : kagett
# suruh : suruh
# gila : gila
# korupsi : korupsi
# nyokap : nyokap
# wkwwkkw : wkwwkkw
# desember : desember
# ketipu : tipu
# informasi : informasi
# gmna : gmna
# kepotong : potong
# hrganya : hrganya
# mantaaaaap : mantaaaaap
# bbang : bbang
# tulisannya : tulis
# restusi : restusi
# diskon : diskon
# rzki : rzki
# terduga : duga
# lho : lho
# lapor : lapor
# depannya : depan
# biarin : biarin
# capek : capek
# ngantri : ngantri
# berjam : jam
# jam : jam
# nanya : nanya
# meter : meter
# kabel : kabel
# lan : lan
# fiber : fiber
# optic : optic
# perbedaan : beda
# internet : internet
# phone : phone
# digital : digital
# channel : channel
# ganti : ganti
# terlanjur : lanjur
# pilih : pilih
# kusor : kusor
# posisi : posisi
# dipasang : pasang
# teknisi : teknisi
# paralel : paralel
# rumah : rumah
# biaya : biaya
# tambahan : tambah
# ppn : ppn
# masang : masang
# harga : harga
# jaminan : jamin
# verivikasi : verivikasi
# telpon : telpon
# daftar : daftar
# kog : kog
# indihom : indihom
# daftarx : daftarx
# orang : orang
# bkn : bkn
# online : online
# katax : katax
# acc : acc
# gmn : gmn
# solusix : solusix
# bru : bru
# daerah : daerah
# rajapolah : rajapolah
# susah : susah
# aktif : aktif
# alasan : alas
# jaringanpenuh : jaringanpenuh
# bantu : bantu
# perantau : rantau
# alamat : alamat
# kost : kost
# ktp : ktp
# ngisi : ngisi
# data : data
# personalnya : personal
# bantuannya : bantu
# lwt : lwt
# aplikasi : aplikasi
# disurat : surat
# kotanya : kota
# berbeda : beda
# kota : kota
# masukan : masuk
# pengisian : isi
# maksudnya : maksud
# deposito : deposito
# masuknya : masuk
# misao : misao
# ditambah : tambah
# assalamualaikum : assalamualaikum
# lokasi : lokasi
# jaringan : jaring
# tercover : tercover
# solusinya : solusi
# terinstall : terinstall
# ngevote : ngevote
# nggak : nggak
# ter : ter
# install : install
# izin : izin
# abang : abang
# telephone : telephone
# mentok : mentok
# brp : brp
# mksudny : mksudny
# gimna : gimna
# rinci : rinci
# trus : trus
# tinggal : tinggal
# langganan : langgan
# udahan : udahan
# perangkat : perangkat
# router : router
# jdi : jdi
# milik : milik
# kek : kek
# stabil : stabil
# tunggu : tunggu
# nambah : nambah
# lumayan : lumayan
# cancel : cancel
# terimaksih : terimaksih
# mimggu : mimggu
# teknisinya : teknisi
# dtg : dtg
# skrg : skrg
# terbatas : batas
# dibayar : bayar
# sehabis : habis
# registrasi : registrasi
# login : login
# lokal : lokal
# indonesia : indonesia
# siaran : siar
# tayang : tayang
# liga : liga
# diindosiar : diindosiar
# paketnya : paket
# halah : halah
# hoak : hoak
# giliran : gilir
# jaringn : jaringn
# full : full
# bermeter : meter
# jatuhnya : jatuh
# mahal : mahal
# ketentuan : tentu
# mtr : mtr
# akal : akal
# digaji : gaji
# melulu : melulu
# infrastruktur : infrastruktur
# didirikan : diri
# wilayah : wilayah
# merata : rata
# kecamatan : camat
# pengen : ken
# google : google
# maps : maps
# nomor : nomor
# brapa : brapa
# dll : dll
# bersih : bersih
# barang : barang
# tersedia : sedia
# gaada : gaada
# yng : yng
# deket : deket
# pesennya : sen
# krna : krna
# slah : slah
# identitas : identitas
# pesen : sen
# ketersediaan : sedia
# layanan : layan
# kawan : kawan
# kedatangannya : datang
# rumahku : rumah
# jakarta : jakarta
# kode : kode
# otp : otp
# cabut : cabut
# gmedia : gmedia
# sales : sales
# buar : buar
# telfon : telfon
# telefon : telefon
# lupa : lupa
# angkat : angkat
# pesan : pesan
# apk : apk
# ragu : ragu
# aga : aga
# jalan : jalan
# raya : raya
# dftar : dftar
# hindihome : hindihome
# saran : saran
# ngegame : ngegame
# emosi : emosi
# sebulan : bulan
# mutus : mutus
# deda : deda
# jta : jta
# kemahaln : kemahaln
# menyesal : sesal
# mengecewakan : kecewa
# kedepan : depan
# bayaran : bayar
# taik : taik
# tertipu : tipu
# mending : mending
# belih : belih
# dimna : dimna
# prosea : prosea
# hukum : hukum
# cctv : cctv
# tetangga : tetangga
# halaman : halaman
# ruma : ruma
# ngeleg : ngeleg
# dimatiin : dimatiin
# lag : lag
# bangat : bangat
# nge : nge
# mola : mola
# lemot : lot
# ampun : ampun
# indigob : indigob
# {'auto': 'auto', 'subscribe': 'subscribe', 'bang': 'bang', 'terjawab': 'jawab', 'hati': 'hati', 'bayar': 'bayar', 'rban': 'rban', 'selanjut': 'lanjut', 'normal': 'normal', '': '', 'thanks': 'thanks', 'bro': 'bro', 'sampe': 'sampe', 'bolak': 'bolak', 'atm': 'atm', 'mini': 'mini', 'market': 'market', 'tagihan': 'tagih', 'tetep': 'tetep', 'ribuan': 'ribu', 'gue': 'gue', 'mengalami': 'alami', 'kaget': 'kaget', 'pas': 'pas', 'dengerin': 'dengerin', 'konten': 'konten', 'makasih': 'makasih', 'udah': 'udah', 'kasih': 'kasih', 'pencerahan': 'cerah', 'bener': 'bener', 'defosit': 'defosit', 'cuman': 'cuman', 'ribu': 'ribu', 'perbulannya': 'bulan', 'kaya': 'kaya', 'percaya': 'percaya', 'sma': 'sma', 'mbak': 'mbak', 'kasirnya': 'kasir', 'hehehe': 'hehehe', 'kirain': 'kirain', 'infonya': 'info', 'kakak': 'kakak', 'kasir': 'kasir', 'serius': 'serius', 'mas': 'mas', 'gabohong': 'gabohong', 'masnya': 'mas', 'nota': 'nota', 'ntar': 'ntar', 'sumpah': 'sumpah', 'banget': 'banget', 'okey': 'okey', 'mksh': 'mksh', 'informasinya': 'informasi', 'membantu': 'bantu', 'pdhl': 'pdhl', 'tolong': 'tolong', 'pasang': 'pasang', 'berhenti': 'henti', 'berlangganan': 'langgan', 'indihome': 'indihome', 'denda': 'denda', 'juta': 'juta', 'gimana': 'gimana', 'terimakasih': 'terimakasih', 'info': 'info', 'sngat': 'sngat', 'pantes': 'pantes', 'paket': 'paket', 'mbps': 'mbps', 'skrng': 'skrng', 'rb': 'rb', 'udh': 'udh', 'september': 'september', 'ceria': 'ceria', 'shopee': 'shopee', 'dana': 'dana', 'beda': 'beda', 'terisolir': 'isolir', 'rajin': 'rajin', 'tgl': 'tgl', 'barusan': 'barusan', 'trnyata': 'trnyata', 'ahahaha': 'ahahaha', 'alhamdulillah': 'alhamdulillah', 'nonton': 'nonton', 'panik': 'panik', 'belom': 'bom', 'masuk': 'masuk', 'kak': 'kak', 'doble': 'doble', 'transfer': 'transfer', 'gara': 'gara', 'sinyal': 'sinyal', 'wifii': 'wifii', 'jelek': 'jelek', 'gb': 'gb', 'pakai': 'pakai', 'org': 'org', 'nyesek': 'nyesek', 'nunggu': 'nunggu', 'setahun': 'tahun', 'putus': 'putus', 'kontrak': 'kontrak', 'kena': 'kena', 'sya': 'sya', 'pertma': 'pertma', 'msang': 'msang', 'bln': 'bln', 'mohon': 'mohon', 'beneran': 'beneran', 'byar': 'byar', 'wifi': 'wifi', 'gua': 'gua', 'tagihanya': 'tagihanya', 'keteranganya': 'keteranganya', 'bulananya': 'bulananya', 'koneksinya': 'koneksi', 'lancar': 'lancar', 'pencerahanya': 'pencerahanya', 'punyaku': 'punya', 'takut': 'takut', 'dobel': 'dobel', 'dibulan': 'bulan', 'kukira': 'kira', 'habis': 'habis', 'sannya': 'sannya', 'disuruh': 'suruh', 'rbu': 'rbu', 'penjelasannya': 'jelas', 'salah': 'salah', 'san': 'san', 'nice': 'nice', 'doang': 'doang', 'ngalamin': 'ngalamin', 'ngasih': 'ngasih', 'untung': 'untung', 'bareng': 'bareng', 'ama': 'ama', 'istri': 'istri', 'ingetin': 'ingetin', 'kebanyakan': 'banyak', 'wkwkwk': 'wkwkwk', 'iya': 'iya', 'kejadiannya': 'jadi', 'mantaap': 'mantaap', 'langsung': 'langsung', 'shock': 'shock', 'nuhun': 'nuhun', 'tenang': 'tenang', 'hahaha': 'hahaha', 'mantap': 'mantap', 'boasa': 'boasa', 'tkt': 'tkt', 'dbayar': 'dbayar', 'sekrg': 'sekrg', 'kjwab': 'kjwab', 'lgsng': 'lgsng', 'like': 'like', 'genap': 'genap', 'potongan': 'potong', 'jarak': 'jarak', 'brpa': 'brpa', 'chat': 'chat', 'blom': 'blom', 'dpt': 'dpt', 'yaampun': 'yaampun', 'kegelisahanku': 'gelisah', 'alfamart': 'alfamart', 'juni': 'juni', 'terima': 'terima', 'penjelasan': 'jelas', 'was': 'was', 'tuk': 'tuk', 'pembayaran': 'bayar', 'tagian': 'tagian', 'maap': 'maap', 'paham': 'paham', 'download': 'download', 'aplikasinya': 'aplikasi', 'pencerahannya': 'cerah', 'suskareb': 'suskareb', 'youtubya': 'youtubya', 'penasaran': 'penasaran', 'lihat': 'lihat', 'perbulan': 'bulan', 'kesalahan': 'salah', 'semoga': 'moga', 'aman': 'aman', 'hadiah': 'hadiah', 'ultah': 'ultah', 'tahunya': 'tahu', 'duit': 'duit', 'flat': 'flat', 'tdnya': 'tdnya', 'tabungan': 'tabung', 'kemaren': 'kemaren', 'pembayarn': 'pembayarn', 'trs': 'trs', 'bingung': 'bingung', 'setaun': 'taun', 'indihimoenya': 'indihimoenya', 'oalah': 'oalah', 'gitu': 'gitu', 'berlaku': 'laku', 'kali': 'kali ...
# ------------------------
# Pandas Apply:   0%|          | 0/162 [00:00<?, ?it/s]
#                                                comment  \
# 0    auto subscribe bang, terjawab sudah pertanyaan...
# 1    bayar 30-44rban itu cuma buat bulan ke 13 aja,...
# 2    thanks bro gw sampe bolak balik ke atm sama mi...
# 3    bulan ini gue mengalami hal yang sama, kaget a...
# 4    aku juga kaget bang bulan ini  cuman 38ribu aj...
# ..                                                 ...
# 306  bang saya udah daftar online sudah d telpon ta...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome, jaringan nya nge ...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar, gw daftar yg 20 mbps le...
#
#                                       cleaning_comment  \
# 0    auto subscribe bang terjawab sudah pertanyaan ...
# 1    bayar  rban itu cuma buat bulan aja selanjut n...
# 2    thanks bro sampe bolak balik atm sama mini mar...
# 3    bulan ini gue mengalami hal yang sama kaget aw...
# 4    aku juga kaget bang bulan ini cuman  ribu aja ...
# ..                                                 ...
# 306  bang saya udah daftar online sudah telpon tapi...
# 307                                     lag bangat asu
# 308  jangan pernah pake indihome jaringan nya nge l...
# 309                     indihome gak guna mending mola
# 310  bro jangan mau daftar daftar mbps lemot minta ...
#
#                                             tokenisasi  \
# 0    [auto, subscribe, bang, terjawab, sudah, perta...
# 1    [bayar, rban, itu, cuma, buat, bulan, aja, sel...
# 2    [thanks, bro, sampe, bolak, balik, atm, sama, ...
# 3    [bulan, ini, gue, mengalami, hal, yang, sama, ...
# 4    [aku, juga, kaget, bang, bulan, ini, cuman, ri...
# ..                                                 ...
# 306  [bang, saya, udah, daftar, online, sudah, telp...
# 307                                 [lag, bangat, asu]
# 308  [jangan, pernah, pake, indihome, jaringan, nya...
# 309               [indihome, gak, guna, mending, mola]
# 310  [bro, jangan, mau, daftar, daftar, mbps, lemot...
#
#                                               stopword  \
# 0              [auto, subscribe, bang, terjawab, hati]
# 1                    [bayar, rban, selanjut, normal, ]
# 2    [thanks, bro, sampe, bolak, atm, mini, market,...
# 3    [gue, mengalami, kaget, pas, dengerin, konten,...
# 4    [kaget, bang, cuman, ribu, bayar, perbulannya,...
# ..                                                 ...
# 306  [bang, udah, daftar, online, telpon, pas, angk...
# 307                                      [lag, bangat]
# 308                     [indihome, jaringan, nge, lag]
# 309                          [indihome, mending, mola]
# 310  [bro, daftar, daftar, mbps, lemot, ampun, jari...
#
#                                               stemming
# 0                 [auto, subscribe, bang, jawab, hati]
# 1                      [bayar, rban, lanjut, normal, ]
# 2    [thanks, bro, sampe, bolak, atm, mini, market,...
# 3    [gue, alami, kaget, pas, dengerin, konten, mak...
# 4    [kaget, bang, cuman, ribu, bayar, bulan, ribu,...
# ..                                                 ...
# 306  [bang, udah, daftar, online, telpon, pas, angk...
# 307                                      [lag, bangat]
# 308                       [indihome, jaring, nge, lag]
# 309                          [indihome, mending, mola]
# 310  [bro, daftar, daftar, mbps, lot, ampun, jaring...
#
# [162 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0                 [auto, subscribe, bang, jawab, hati]
# 1                      [bayar, rban, lanjut, normal, ]
# 2    [thanks, bro, sampe, bolak, atm, mini, market,...
# 3    [gue, alami, kaget, pas, dengerin, konten, mak...
# 4    [kaget, bang, cuman, ribu, bayar, bulan, ribu,...
# ..                                                 ...
# 306  [bang, udah, daftar, online, telpon, pas, angk...
# 307                                      [lag, bangat]
# 308                       [indihome, jaring, nge, lag]
# 309                          [indihome, mending, mola]
# 310  [bro, daftar, daftar, mbps, lot, ampun, jaring...
#
# [162 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_5.xlsx')
