# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                                            Kocak 🤣🤣🤣
# 1    Alur ceritanya terkadang persis seperti apa yg...
# 2         Turah : bapak bapak rusia yang suka komplain
# 3    Jadi inget dulu kerja di indihome, punya pelan...
# 4    Please IndiHome series nya lanjutin terus yaa🤣...
# ..                                                 ...
# 365  Fight fire with fire.. nyindir balik netizen +...
# 366  Fight fire with fire.. nyindir balik netizen +...
# 367  Terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  Diam ditinggal Coki, bergerak menjadi teknisi....
# 369  Lord Dustin Kocak Parah hahahahah sumpah ini b...
#
# [370 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 92

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 1    Alur ceritanya terkadang persis seperti apa yg...
# 2         Turah : bapak bapak rusia yang suka komplain
# 3    Jadi inget dulu kerja di indihome, punya pelan...
# 4    Please IndiHome series nya lanjutin terus yaa🤣...
# 5                                               Mantap
# ..                                                 ...
# 363  Sumpah bikin ketawa mulu, ditunggu posting epi...
# 364  Indihome mengambil keputusan yg baik dgn beker...
# 367  Terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  Diam ditinggal Coki, bergerak menjadi teknisi....
# 369  Lord Dustin Kocak Parah hahahahah sumpah ini b...
#
# [187 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 1    alur ceritanya terkadang persis seperti apa yg...
# 2         turah : bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja di indihome, punya pelan...
# 4    please indihome series nya lanjutin terus yaa🤣...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu, ditunggu posting epi...
# 364  indihome mengambil keputusan yg baik dgn beker...
# 367  terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  diam ditinggal coki, bergerak menjadi teknisi....
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
# [187 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 1    alur ceritanya terkadang persis seperti apa yg...
# 2         turah : bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja di indihome, punya pelan...
# 4    please indihome series nya lanjutin terus yaa🤣...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu, ditunggu posting epi...
# 364  indihome mengambil keputusan yg baik dgn beker...
# 367  terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  diam ditinggal coki, bergerak menjadi teknisi....
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                       cleaning_comment
# 1    alur ceritanya terkadang persis seperti apa sa...
# 2           turah bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja indihome punya pelanggan...
# 4    please indihome series nya lanjutin terus yaa ...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu ditunggu posting epis...
# 364  indihome mengambil keputusan baik dgn bekerja ...
# 367  terus bikin konten seperti ini lucu wkwk nonto...
# 368  diam ditinggal coki bergerak menjadi teknisi wkwk
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
# [187 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 1    alur ceritanya terkadang persis seperti apa yg...
# 2         turah : bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja di indihome, punya pelan...
# 4    please indihome series nya lanjutin terus yaa🤣...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu, ditunggu posting epi...
# 364  indihome mengambil keputusan yg baik dgn beker...
# 367  terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  diam ditinggal coki, bergerak menjadi teknisi....
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                       cleaning_comment  \
# 1    alur ceritanya terkadang persis seperti apa sa...
# 2           turah bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja indihome punya pelanggan...
# 4    please indihome series nya lanjutin terus yaa ...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu ditunggu posting epis...
# 364  indihome mengambil keputusan baik dgn bekerja ...
# 367  terus bikin konten seperti ini lucu wkwk nonto...
# 368  diam ditinggal coki bergerak menjadi teknisi wkwk
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                             tokenisasi
# 1    [alur, ceritanya, terkadang, persis, seperti, ...
# 2    [turah, bapak, bapak, rusia, yang, suka, kompl...
# 3    [jadi, inget, dulu, kerja, indihome, punya, pe...
# 4    [please, indihome, series, nya, lanjutin, teru...
# 5                                             [mantap]
# ..                                                 ...
# 363  [sumpah, bikin, ketawa, mulu, ditunggu, postin...
# 364  [indihome, mengambil, keputusan, baik, dgn, be...
# 367  [terus, bikin, konten, seperti, ini, lucu, wkw...
# 368  [diam, ditinggal, coki, bergerak, menjadi, tek...
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
# [187 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 1    alur ceritanya terkadang persis seperti apa yg...
# 2         turah : bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja di indihome, punya pelan...
# 4    please indihome series nya lanjutin terus yaa🤣...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu, ditunggu posting epi...
# 364  indihome mengambil keputusan yg baik dgn beker...
# 367  terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  diam ditinggal coki, bergerak menjadi teknisi....
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                       cleaning_comment  \
# 1    alur ceritanya terkadang persis seperti apa sa...
# 2           turah bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja indihome punya pelanggan...
# 4    please indihome series nya lanjutin terus yaa ...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu ditunggu posting epis...
# 364  indihome mengambil keputusan baik dgn bekerja ...
# 367  terus bikin konten seperti ini lucu wkwk nonto...
# 368  diam ditinggal coki bergerak menjadi teknisi wkwk
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                             tokenisasi  \
# 1    [alur, ceritanya, terkadang, persis, seperti, ...
# 2    [turah, bapak, bapak, rusia, yang, suka, kompl...
# 3    [jadi, inget, dulu, kerja, indihome, punya, pe...
# 4    [please, indihome, series, nya, lanjutin, teru...
# 5                                             [mantap]
# ..                                                 ...
# 363  [sumpah, bikin, ketawa, mulu, ditunggu, postin...
# 364  [indihome, mengambil, keputusan, baik, dgn, be...
# 367  [terus, bikin, konten, seperti, ini, lucu, wkw...
# 368  [diam, ditinggal, coki, bergerak, menjadi, tek...
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
#                                               stopword
# 1    [alur, ceritanya, terkadang, persis, rasakan, ...
# 2                       [turah, rusia, suka, komplain]
# 3    [inget, kerja, indihome, pelanggan, bawel, ora...
# 4    [please, indihome, series, lanjutin, yaa, bene...
# 5                                             [mantap]
# ..                                                 ...
# 363  [sumpah, ketawa, mulu, ditunggu, posting, epis...
# 364  [indihome, mengambil, keputusan, orang, gajela...
# 367                 [konten, lucu, nonton, indihome, ]
# 368         [diam, ditinggal, coki, bergerak, teknisi]
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
# [187 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 647
# ------------------------
# alur : alur
# ceritanya : cerita
# terkadang : terkadang
# persis : persis
# rasakan : rasa
# lapangan : lapang
# teknisi : teknisi
#  :
# turah : turah
# rusia : rusia
# suka : suka
# komplain : komplain
# inget : inget
# kerja : kerja
# indihome : indihome
# pelanggan : langgan
# bawel : bawel
# orangnya : orang
# bae : bae
# ngasih : ngasih
# uang : uang
# tip : tip
# makan : makan
# rokoknya : rokok
# please : please
# series : series
# lanjutin : lanjutin
# yaa : yaa
# bener : bener
# hiburan : hibur
# malem : malem
# senin : senin
# mantap : mantap
# gara : gara
# happy : happy
# thank : thank
# mli : mli
# deket : deket
# rumah : rumah
# benerin : benerin
# kabel : kabel
# disuruh : suruh
# nebang : nebang
# pohon : pohon
# nenek : nenek
# cerita : cerita
# sederhana : sederhana
# penuh : penuh
# lawak : lawak
# banjarnegara : banjarnegara
# menyapa : sapa
# nyangka : nyangka
# ber : ber
# udah : udah
# tretan : tretan
# muslim : muslim
# sma : sma
# dustin : dustin
# asik : asik
# tunggu : tunggu
# cocok : cocok
# banget : banget
# kayaknya : kayak
# pas : pas
# puasa : puasa
# uyy : uyy
# nyandu : nyandu
# nontonnya : nontonnya
# berkualitas : kualitas
# brasa : brasa
# keemasan : emas
# net : net
# tolong : tolong
# sertakan : serta
# mas : mas
# agus : agus
# viral : viral
# kalah : kalah
# game : game
# melulu : melulu
# coba : coba
# pakai : pakai
# baju : baju
# capital : capital
# sport : sport
# menang : menang
# ajak : ajak
# rigen : rigen
# customer : customer
# marah : marah
# kek : kek
# seru : seru
# semoga : moga
# pokemon : pokemon
# diikutkan : ikut
# asekkk : asekkk
# menunjukan : tunjuk
# kreatifitas : kreatifitas
# internet : internet
# terbaik : baik
# episode : episode
# signal : signal
# wifi : wifi
# tetangga : tetangga
# lemah : lemah
# dirumah : rumah
# tinggal : tinggal
# pasang : pasang
# extender : extender
# sabii : sabi
# kali : kali
# apresiasi : apresiasi
# tim : tim
# keren : keren
# menunggu : tunggu
# konten : konten
# magang : magang
# oke : oke
# giliran : gilir
# zero : zero
# logic : logic
# ngomong : ngomong
# ambyar : ambyar
# ngeliat : ngeliat
# ngakak : ngakak
# bagus : bagus
# kocag : kocag
# kejadian : jadi
# diundang : undang
# kerumah : rumah
# hadirin : hadirin
# pesta : pesta
# nikahan : nikah
# anaknya : anak
# karna : karna
# gangguan : ganggu
# nunggu : nunggu
# tema : tema
# jaringan : jaring
# hujan : hujan
# keinget : keinget
# film : film
# sketsa : sketsa
# ojan : ojan
# komedi : komedi
# informasi : informasi
# cameo : cameo
# coki : cok
# pardede : pardede
# keluh : keluh
# kesahnya : kesah
# klw : klw
# psb : psb
# dapet : dapet
# order : order
# zonk : zonk
# odp : odp
# wahh : wahh
# pokoke : pokoke
# puyeng : puyeng
# langsung : langsung
# keselek : keselek
# adegan : adegan
# terakhirnya : akhir
# nyariin : nyariin
# minum : minum
# rispo : rispo
# tayang : tayang
# daftar : daftar
# call : call
# centre : centre
# pusat : pusat
# spot : spot
# available : available
# gasabar : gasabar
# formasi : formasi
# lengkap : lengkap
# pemuda : pemuda
# tersesat : sesat
# abang : abang
# jaktim : jaktim
# cakep : cakep
# sumpah : sumpah
# tanggapan : tanggap
# olya : olya
# yulya : yulya
# lihat : lihat
# salalu : salalu
# nonton : nonton
# sebel : sebel
# minggu : minggu
# nungguin : nungguin
# mantaaap : mantaaap
# gajelas : gajelas
# denger : denger
# ngmg : ngmg
# monangis : monangis
# permanenkan : permanen
# terima : terima
# kasih : kasih
# telkom : telkom
# menonton : tonton
# nyari : nyari
# ilmu : ilmu
# bentar : bentar
# tkj : tkj
# hadapin : hadapin
# costomer : costomer
# absurd : absurd
# plot : plot
# mudah : mudah
# tebak : tebak
# teasernya : teasernya
# relate : relate
# pekerjaan : kerja
# tekhnisi : tekhnisi
# habib : habib
# jafar : jafar
# min : min
# pelajaran : ajar
# positif : positif
# paksa : paksa
# suruh : suruh
# pempek : pempek
# plnggan : plnggan
# ikan : ikan
# terpaksa : paksa
# liat : liat
# plngnnya : plngnnya
# tua : tua
# cobain : cobain
# kuat : kuat
# muntahin : muntahin
# pengalaman : alam
# smpe : smpe
# skrng : skrng
# sukaaa : sukaaa
# iniii : iniii
# lucu : lucu
# parah : parah
# wkwkw : wkwkw
# ikutin : ikutin
# trus : trus
# achievement : achievement
# rto : rto
# ending : ending
# membagongkan : bagong
# tawa : tawa
# suwiwiwi : suwiwiwi
# solusi : solusi
# gamers : gamers
# kadang : kadang
# pingnya : pingnya
# merah : merah
# alias : alias
# jump : jump
# ping : ping
# ganggu : ganggu
# pdhl : pdhl
# sinyal : sinyal
# full : full
# tambahin : tambahin
# sales : sales
# kesah : kesah
# bertemu : temu
# scane : scane
# cuan : cuan
# masukkan : masuk
# lanjutkan : lanjut
# sampe : sampe
# eps : eps
# ngga : ngga
# bismillah : bismillah
# far : far
# menangis : menang
# butuh : butuh
# dark : dark
# jok : jok
# sajikan : saji
# dani : dan
# aditya : aditya
# mutan : mutan
# mutannya : mutan
# joke : joke
# dimuncul : muncul
# auto : auto
# subscribe : subscribe
# anak : anak
# beda : beda
# alam : alam
# chaaaaakkkkksssss : chaaaaakkkkksssss
# beli : beli
# extendernya : extendernya
# gimana : gimana
# endingnya : endingnya
# nadanya : nada
# sang : sang
# mendiang : mendiang
# costumer : costumer
# silahkan : silah
# restar : restar
# modem : modem
# kolom : kolom
# komentar : komentar
# ngadu : ngadu
# nasib : nasib
# sabar : sabar
# berjasa : jasa
# lgsg : lgsg
# nie : nie
# jadii : jadi
# punyaa : punyaa
# bangett : bangett
# hahaha : hahaha
# ayo : ayo
# perpanjang : panjang
# tukang : tukang
# bubur : bubur
# haji : haji
# ditunggu : tunggu
# rajin : rajin
# upload : upload
# nge : nge
# apply : apply
# panggilan : panggil
# indi : indi
# home : home
# hidup : hidup
# bahagia : bahagia
# tamat : tamat
# menit : menit
# funny : funny
# moment : moment
# tifunny : tifunny
# diperpanjang : panjang
# ektingnya : ektingnya
# bang : bang
# ajakin : ajakin
# dimana : mana
# gitu : gitu
# salah : salah
# masukin : masukin
# ubur : ubur
# lucunya : lucu
# khas : khas
# abissss : abissss
# untung : untung
# msh : msh
# cinta : cinta
# marketing : marketing
# harga : harga
# ciee : ciee
# aowkwowko : aowkwowko
# jaman : jaman
# jdi : jdi
# disuguhin : disuguhin
# air : air
# botol : botol
# vodka : vodka
# gelasnya : gelas
# sloki : sloki
# astagfirullah : astagfirullah
# putih : putih
# make : make
# makasih : makasih
# kak : kak
# musmlim : musmlim
# chuaks : chuaks
# standar : standar
# sepi : sepi
# parallel : parallel
# wuahahahaha : wuahahahaha
# pararel : pararel
# next : next
# ketemu : ketemu
# gampang : gampang
# olahraga : olahraga
# via : via
# sosmed : sosmed
# mantul : mantul
# idenya : ide
# gilak : gilak
# brp : brp
# lngsung : lngsung
# rame : rame
# deadwood : deadwood
# jujur : jujur
# rada : rada
# komedinya : komedi
# gerr : gerr
# jokes : jokes
# ikutan : ikut
# indihomeee : indihomeee
# jam : jam
# durasinya : durasi
# ngomng : ngomng
# mukak : mukak
# ketawa : ketawa
# gua : gua
# njir : njir
# pengen : ken
# sedih : sedih
# perbaikan : baik
# bayarannya : bayar
# emng : emng
# durasi : durasi
# flm : flm
# dikit : dikit
# subs : subs
# ama : ama
# gausah : gausah
# scrip : scrip
# miliar : miliar
# leluhur : leluhur
# jirr : jirr
# alat : alat
# espender : espender
# gratis : gratis
# kah : kah
# dmn : dmn
# klimaksnya : klimaks
# enak : enak
# seris : seris
# cuk : cuk
# wkwkwkwkwkw : wkwkwkwkwkw
# see : see
# klik : klik
# pizza : pizza
# kuning : kuning
# dikasih : kasih
# selai : selai
# nanas : nanas
# strateginya : strategi
# mantullll : mantullll
# nama : nama
# pertaruhkan : taruh
# video : video
# orang : orang
# kocak : kocak
# wkwkwkwkwk : wkwkwkwkwk
# ratusan : ratus
# fitri : fitri
# menggambarkan : gambar
# tarif : tarif
# serius : serius
# comedy : comedy
# pintar : pintar
# memilih : pilih
# pemeran : per
# pengumpul : kumpul
# mutant : mutant
# the : the
# king : king
# bahan : bahan
# sarkas : sarkas
# roasting : roasting
# chaakksss : chaakksss
# character : character
# unlock : unlock
# gpp : gpp
# deh : deh
# gue : gue
# lemot : lot
# banyakin : banyakin
# ngerasain : ngerasain
# kelemotan : lot
# susah : susah
# bareng : bareng
# solasi : solasi
# keresahan : resah
# kegelisahan : gelisah
# dijadikan : jadi
# kereen : kereen
# kocaak : kocaak
# mantep : mantep
# menggaet : gaet
# skaligus : skaligus
# mengedukasi : edukasi
# sperti : sperti
# lanjutkeunn : lanjutkeunn
# terimakasih : terimakasih
# editor : editor
# menaruh : taruh
# laughtrack : laughtrack
# sfx : sfx
# serial : serial
# kesimpulan : simpul
# dapatkan : dapat
# pecah : pecah
# emang : emang
# wkwkkw : wkwkkw
# gini : gin
# pembawaannya : bawa
# madura : madura
# pkoknya : pkoknya
# cerdas : cerdas
# nggak : nggak
# wkwkwk : wkwkwk
# gokil : gokil
# setuju : tuju
# keluhan : keluh
# pengguna : guna
# gasih : gasih
# wkw : wkw
# naaaaaahhh : naaaaaahhh
# keunggulan : unggul
# pelayanan : layan
# nomor : nomor
# buanget : buanget
# mengadu : adu
# ditanggapi : tanggap
# kilat : kilat
# ramah : ramah
# lancar : lancar
# senang : senang
# bangga : bangga
# mitra : mitra
# wajah : wajah
# pertelivisian : pertelivisian
# youtube : youtube
# indonesia : indonesia
# kantor : kantor
# penyebar : sebar
# hoax : hoax
# search : search
# merekomendasikan : rekomendasi
# menghibur : hibur
# siiiih : siiiih
# ep : ep
# muda : muda
# membanggakan : bangga
# bangsa : bangsa
# puas : puas
# mudahan : mudah
# legendaris : legendaris
# pras : pras
# cukk : cukk
# mantapppp : mantapppp
# seri : seri
# favorit : favorit
# berlangganan : langgan
# instalasi : instalasi
# indhome : indhome
# ruang : ruang
# rehab : rehab
# uncle : uncle
# dastin : dastin
# kombinasi : kombinasi
# komika : komika
# terbaek : terbaek
# ditambah : tambah
# paman : paman
# beuhhhhh : beuhhhhh
# obat : obat
# deby : deby
# ceper : ceper
# hhahah : hhahah
# ngumpulin : ngumpulin
# jadiin : jadiin
# ganti : ganti
# season : season
# contoh : contoh
# code : code
# conduct : conduct
# ditingkatin : ditingkatin
# humoritas : humoritas
# skripnya : skrip
# natural : natural
# acting : acting
# ayah : ayah
# tanggungjawab : tanggungjawab
# ketagihan : tagih
# awas : awas
# partnya : partnya
# putus : putus
# luu : luu
# kos : kos
# kosan : kosan
# mantappp : mantappp
# milih : milih
# talent : talent
# kemaren : kemaren
# epep : epep
# srkarang : srkarang
# hmmm : hmmm
# multi : multi
# talenta : talenta
# gila : gila
# actingnya : actingnya
# euy : euy
# edukasi : edukasi
# dibalut : balut
# goks : goks
# siluman : siluman
# kacang : kacang
# ijo : ijo
# bapack : bapack
# kencanggg : kencanggg
# sistem : sistem
# pascabayar : pascabayar
# abodemen : abodemen
# digeruduk : digeruduk
# ormas : ormas
# nerawang : nerawang
# jin : jin
# lord : lord
# simpulkan : simpul
# cepat : cepat
# mengunggah : unggah
# twitter : twitter
# ditangani : tangan
# jaya : jaya
# salam : salam
# kalbar : kalbar
# jiwa : jiwa
# kenyataan : nyata
# anjirlah : anjir
# cikuakzzssss : cikuakzzssss
# nyaa : nyaa
# ggwp : ggwp
# wkwkwkw : wkwkwkw
# related : related
# mewakili : wakil
# solusinya : solusi
# panas : panas
# kepanasan : panas
# kehujanan : hujan
# idi : idi
# tercinta : cinta
# part : part
# hahah : hahah
# sihh : sihh
# dead : dead
# wood : wood
# umat : umat
# pendengar : dengar
# musuh : musuh
# masyarakat : masyarakat
# ngekek : ngekek
# mulu : mulu
# posting : posting
# mengambil : ambil
# keputusan : putus
# diam : diam
# ditinggal : tinggal
# bergerak : gerak
# hahahahah : hahahahah
# {'alur': 'alur', 'ceritanya': 'cerita', 'terkadang': 'terkadang', 'persis': 'persis', 'rasakan': 'rasa', 'lapangan': 'lapang', 'teknisi': 'teknisi', '': '', 'turah': 'turah', 'rusia': 'rusia', 'suka': 'suka', 'komplain': 'komplain', 'inget': 'inget', 'kerja': 'kerja', 'indihome': 'indihome', 'pelanggan': 'langgan', 'bawel': 'bawel', 'orangnya': 'orang', 'bae': 'bae', 'ngasih': 'ngasih', 'uang': 'uang', 'tip': 'tip', 'makan': 'makan', 'rokoknya': 'rokok', 'please': 'please', 'series': 'series', 'lanjutin': 'lanjutin', 'yaa': 'yaa', 'bener': 'bener', 'hiburan': 'hibur', 'malem': 'malem', 'senin': 'senin', 'mantap': 'mantap', 'gara': 'gara', 'happy': 'happy', 'thank': 'thank', 'mli': 'mli', 'deket': 'deket', 'rumah': 'rumah', 'benerin': 'benerin', 'kabel': 'kabel', 'disuruh': 'suruh', 'nebang': 'nebang', 'pohon': 'pohon', 'nenek': 'nenek', 'cerita': 'cerita', 'sederhana': 'sederhana', 'penuh': 'penuh', 'lawak': 'lawak', 'banjarnegara': 'banjarnegara', 'menyapa': 'sapa', 'nyangka': 'nyangka', 'ber': 'ber', 'udah': 'udah', 'tretan': 'tretan', 'muslim': 'muslim', 'sma': 'sma', 'dustin': 'dustin', 'asik': 'asik', 'tunggu': 'tunggu', 'cocok': 'cocok', 'banget': 'banget', 'kayaknya': 'kayak', 'pas': 'pas', 'puasa': 'puasa', 'uyy': 'uyy', 'nyandu': 'nyandu', 'nontonnya': 'nontonnya', 'berkualitas': 'kualitas', 'brasa': 'brasa', 'keemasan': 'emas', 'net': 'net', 'tolong': 'tolong', 'sertakan': 'serta', 'mas': 'mas', 'agus': 'agus', 'viral': 'viral', 'kalah': 'kalah', 'game': 'game', 'melulu': 'melulu', 'coba': 'coba', 'pakai': 'pakai', 'baju': 'baju', 'capital': 'capital', 'sport': 'sport', 'menang': 'menang', 'ajak': 'ajak', 'rigen': 'rigen', 'customer': 'customer', 'marah': 'marah', 'kek': 'kek', 'seru': 'seru', 'semoga': 'moga', 'pokemon': 'pokemon', 'diikutkan': 'ikut', 'asekkk': 'asekkk', 'menunjukan': 'tunjuk', 'kreatifitas': 'kreatifitas', 'internet': 'internet', 'terbaik': 'baik', 'episode': 'episode', 'signal': 'signal', 'wifi': 'wifi', 'tetangga': 'tetangga', 'lemah': 'lemah', 'dirumah': 'rumah', 'tinggal': 'tinggal', 'pasang': 'pasang', 'extender': 'extender', 'sabii': 'sabi', 'kali': 'kali', 'apresiasi': 'apresiasi', 'tim': 'tim', 'keren': 'keren', 'menunggu': 'tunggu', 'konten': 'konten', 'magang': 'magang', 'oke': 'oke', 'giliran': 'gilir', 'zero': 'zero', 'logic': 'logic', 'ngomong': 'ngomong', 'ambyar': 'ambyar', 'ngeliat': 'ngeliat', 'ngakak': 'ngakak', 'bagus': 'bagus', 'kocag': 'kocag', 'kejadian': 'jadi', 'diundang': 'undang', 'kerumah': 'rumah', 'hadirin': 'hadirin', 'pesta': 'pesta', 'nikahan': 'nikah', 'anaknya': 'anak', 'karna': 'karna', 'gangguan': 'ganggu', 'nunggu': 'nunggu', 'tema': 'tema', 'jaringan': 'jaring', 'hujan': 'hujan', 'keinget': 'keinget', 'film': 'film', 'sketsa': 'sketsa', 'ojan': 'ojan', 'komedi': 'komedi', 'informasi': 'informasi', 'cameo': 'cameo', 'coki': 'cok', 'pardede': 'pardede', 'keluh': 'keluh', 'kesahnya': 'kesah', 'klw': 'klw', 'psb': 'psb', 'dapet': 'dapet', 'order': 'order', 'zonk': 'zonk', 'odp': 'odp', 'wahh': 'wahh', 'pokoke': 'pokoke', 'puyeng': 'puyeng', 'langsung': 'langsung', 'keselek': 'keselek', 'adegan': 'adegan', 'terakhirnya': 'akhir', 'nyariin': 'nyariin', 'minum': 'minum', 'rispo': 'rispo', 'tayang': 'tayang', 'daftar': 'daftar', 'call': 'call', 'centre': 'centre', 'pusat': 'pusat', 'spot': 'spot', 'available': 'available', 'gasabar': 'gasabar', 'formasi': 'formasi', 'lengkap': 'lengkap', 'pemuda': 'pemuda', 'tersesat': 'sesat', 'abang': 'abang', 'jaktim': 'jaktim', 'cakep': 'cakep', 'sumpah': 'sumpah', 'tanggapan': 'tanggap', 'olya': 'olya', 'yulya': 'yulya', 'lihat': 'lihat', 'salalu': 'salalu', 'nonton': 'nonton', 'sebel': 'sebel', 'minggu': 'minggu', 'nungguin': 'nungguin', 'mantaaap': 'mantaaap', 'gajelas': 'gajelas', 'denger': 'denger', 'ngmg': 'ngmg', 'monangis': 'monangis', 'permanenkan': 'permanen', 'terima': 'terima', 'kasih': 'kasih', 'telkom': 'telkom', 'menonton': 'tonton', 'nyari': 'nyari', 'ilmu': 'ilmu', 'bentar': 'bentar', 'tkj': 'tkj', 'hadapin': 'had ...
# ------------------------
# Pandas Apply:   0%|          | 0/187 [00:00<?, ?it/s]
#                                                comment  \
# 1    alur ceritanya terkadang persis seperti apa yg...
# 2         turah : bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja di indihome, punya pelan...
# 4    please indihome series nya lanjutin terus yaa🤣...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu, ditunggu posting epi...
# 364  indihome mengambil keputusan yg baik dgn beker...
# 367  terus bikin konten seperti ini lucu wkwk ☕ non...
# 368  diam ditinggal coki, bergerak menjadi teknisi....
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                       cleaning_comment  \
# 1    alur ceritanya terkadang persis seperti apa sa...
# 2           turah bapak bapak rusia yang suka komplain
# 3    jadi inget dulu kerja indihome punya pelanggan...
# 4    please indihome series nya lanjutin terus yaa ...
# 5                                               mantap
# ..                                                 ...
# 363  sumpah bikin ketawa mulu ditunggu posting epis...
# 364  indihome mengambil keputusan baik dgn bekerja ...
# 367  terus bikin konten seperti ini lucu wkwk nonto...
# 368  diam ditinggal coki bergerak menjadi teknisi wkwk
# 369  lord dustin kocak parah hahahahah sumpah ini b...
#
#                                             tokenisasi  \
# 1    [alur, ceritanya, terkadang, persis, seperti, ...
# 2    [turah, bapak, bapak, rusia, yang, suka, kompl...
# 3    [jadi, inget, dulu, kerja, indihome, punya, pe...
# 4    [please, indihome, series, nya, lanjutin, teru...
# 5                                             [mantap]
# ..                                                 ...
# 363  [sumpah, bikin, ketawa, mulu, ditunggu, postin...
# 364  [indihome, mengambil, keputusan, baik, dgn, be...
# 367  [terus, bikin, konten, seperti, ini, lucu, wkw...
# 368  [diam, ditinggal, coki, bergerak, menjadi, tek...
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
#                                               stopword  \
# 1    [alur, ceritanya, terkadang, persis, rasakan, ...
# 2                       [turah, rusia, suka, komplain]
# 3    [inget, kerja, indihome, pelanggan, bawel, ora...
# 4    [please, indihome, series, lanjutin, yaa, bene...
# 5                                             [mantap]
# ..                                                 ...
# 363  [sumpah, ketawa, mulu, ditunggu, posting, epis...
# 364  [indihome, mengambil, keputusan, orang, gajela...
# 367                 [konten, lucu, nonton, indihome, ]
# 368         [diam, ditinggal, coki, bergerak, teknisi]
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
#                                               stemming
# 1    [alur, cerita, terkadang, persis, rasa, lapang...
# 2                       [turah, rusia, suka, komplain]
# 3    [inget, kerja, indihome, langgan, bawel, orang...
# 4    [please, indihome, series, lanjutin, yaa, bene...
# 5                                             [mantap]
# ..                                                 ...
# 363   [sumpah, ketawa, mulu, tunggu, posting, episode]
# 364         [indihome, ambil, putus, orang, gajelas, ]
# 367                 [konten, lucu, nonton, indihome, ]
# 368               [diam, tinggal, cok, gerak, teknisi]
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
# [187 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 1    [alur, cerita, terkadang, persis, rasa, lapang...
# 2                       [turah, rusia, suka, komplain]
# 3    [inget, kerja, indihome, langgan, bawel, orang...
# 4    [please, indihome, series, lanjutin, yaa, bene...
# 5                                             [mantap]
# ..                                                 ...
# 363   [sumpah, ketawa, mulu, tunggu, posting, episode]
# 364         [indihome, ambil, putus, orang, gajelas, ]
# 367                 [konten, lucu, nonton, indihome, ]
# 368               [diam, tinggal, cok, gerak, teknisi]
# 369  [lord, dustin, kocak, parah, hahahahah, sumpah...
#
# [187 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_11.xlsx')
