# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["comment_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\databersih_english_youtube_indihome\databersih_english_youtube_indihome_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                        comment_english
# 0    ['easy', 'easy', 'series', 'competitiveness', ...
# 1                                ['Turah', 'Turah', "]
# 2    ['Come on', 'Indihome', 'effort', 'can', 'pict...
# 3                                         ['know', '']
# 4        ['Cool', 'three', 'mas', 'mas', 'madura', '']
# ..                                                 ...
# 291  ['Minutes', 'Subtitles', 'Write', 'Butterfly',...
# 292  ['Forgot', 'Subscribe', 'Support', 'Respect', ...
# 293                                ['Dustin', 'Ohang']
# 294  ['money', 'production', 'mending', 'stabilin',...
# 295             ['Series', 'Internet', 'home', 'fast']
#
# [296 rows x 1 columns]

# %%
df['comment_english'] = df['comment_english'].str.lower()
df.head(2000)
# Out:
#                                        comment_english
# 0    ['easy', 'easy', 'series', 'competitiveness', ...
# 1                                ['turah', 'turah', "]
# 2    ['come on', 'indihome', 'effort', 'can', 'pict...
# 3                                         ['know', '']
# 4        ['cool', 'three', 'mas', 'mas', 'madura', '']
# ..                                                 ...
# 291  ['minutes', 'subtitles', 'write', 'butterfly',...
# 292  ['forgot', 'subscribe', 'support', 'respect', ...
# 293                                ['dustin', 'ohang']
# 294  ['money', 'production', 'mending', 'stabilin',...
# 295             ['series', 'internet', 'home', 'fast']
#
# [296 rows x 1 columns]

# %%
df['label_awal'] = ''
for i,x in df.comment_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.43333333333333335
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.0
# Index:  3 label_awal 0.0
# Index:  4 label_awal 0.35
# Index:  5 label_awal 0.4666666666666667
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.0
# Index:  8 label_awal 0.16666666666666666
# Index:  9 label_awal 0.0
# Index:  10 label_awal 0.5
# Index:  11 label_awal -0.4
# Index:  12 label_awal 0.0
# Index:  13 label_awal 0.0
# Index:  14 label_awal 0.0
# Index:  15 label_awal 0.0
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.0
# Index:  20 label_awal 0.0
# Index:  21 label_awal -0.4
# Index:  22 label_awal 0.7
# Index:  23 label_awal 0.0
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.375
# Index:  26 label_awal 0.0
# Index:  27 label_awal 0.0
# Index:  28 label_awal 0.35
# Index:  29 label_awal 0.0
# Index:  30 label_awal 0.0
# Index:  31 label_awal 0.0
# Index:  32 label_awal 0.0
# Index:  33 label_awal 0.0
# ...

# %%
df.head()
# Out:
#                                      comment_english label_awal
# 0  ['easy', 'easy', 'series', 'competitiveness', ...   0.433333
# 1                              ['turah', 'turah', "]        0.0
# 2  ['come on', 'indihome', 'effort', 'can', 'pict...        0.0
# 3                                       ['know', '']        0.0
# 4      ['cool', 'three', 'mas', 'mas', 'madura', '']       0.35

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    194
# -0.500000     16
#  0.350000      9
#  0.375000      7
#  0.700000      6
#  0.200000      5
#  0.500000      4
#  0.166667      3
#  0.250000      3
#  0.083333      2
# -0.300000      2
#  0.100000      2
#  1.000000      2
# -0.400000      2
#  0.325000      1
# -0.350000      1
# -0.151852      1
# -0.250000      1
#  0.248148      1
#  0.800000      1
#  0.433333      1
#  0.175000      1
#  0.066667      1
# -0.150000      1
# -0.016667      1
# -0.700000      1
#  0.337500      1
#  0.233333      1
#  0.233333      1
# -0.102778      1
#  0.600000      1
# -0.050000      1
# -0.166667      1
#  0.483333      1
# -0.650000      1
#  0.466667      1
#  0.156250      1
# -0.085000      1
# -0.150000      1
# -0.178571      1
#  0.400000      1
#  0.150000      1
#  0.050000      1
#  0.300000      1
# -0.275000      1
#  0.157823      1
# -0.100000      1
#  0.275000      1
#  0.383333      1
#  0.455000      1
#  0.550000      1
# -0.800000      1
# ...

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] < 0.0:
        label.append("negative")
    else:
        label.append("positive")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                        comment_english     label
# 0    ['easy', 'easy', 'series', 'competitiveness', ...  positive
# 1                                ['turah', 'turah', "]  positive
# 2    ['come on', 'indihome', 'effort', 'can', 'pict...  positive
# 3                                         ['know', '']  positive
# 4        ['cool', 'three', 'mas', 'mas', 'madura', '']  positive
# ..                                                 ...       ...
# 291  ['minutes', 'subtitles', 'write', 'butterfly',...  positive
# 292  ['forgot', 'subscribe', 'support', 'respect', ...  positive
# 293                                ['dustin', 'ohang']  positive
# 294  ['money', 'production', 'mending', 'stabilin',...  positive
# 295             ['series', 'internet', 'home', 'fast']  positive
#
# [296 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# positive    259
# negative     37
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_youtube_indihome_12.xlsx')
