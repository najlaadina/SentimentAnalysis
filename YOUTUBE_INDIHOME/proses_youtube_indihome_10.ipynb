# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                                      Warsyi Nahwanda
# 1    Review kayak waktu 20Mbps dong bang... sambil ...
# 2    Thankyou bang reviewnya... fix upgrade, baru t...
# 3     Alhamdulillah 30Mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  Sama bang Sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           Saruddu? Saya orang sini
# 112           Indihome anj pantes tadi siang kok lemot
# 113                                  Main emel lag anj
#
# [114 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                                      Warsyi Nahwanda
# 1    Review kayak waktu 20Mbps dong bang... sambil ...
# 2    Thankyou bang reviewnya... fix upgrade, baru t...
# 3     Alhamdulillah 30Mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  Sama bang Sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           Saruddu? Saya orang sini
# 112           Indihome anj pantes tadi siang kok lemot
# 113                                  Main emel lag anj
#
# [89 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                                      warsyi nahwanda
# 1    review kayak waktu 20mbps dong bang... sambil ...
# 2    thankyou bang reviewnya... fix upgrade, baru t...
# 3     alhamdulillah 30mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           saruddu? saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
# [89 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu 20mbps dong bang... sambil ...
# 2    thankyou bang reviewnya... fix upgrade, baru t...
# 3     alhamdulillah 30mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           saruddu? saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                       cleaning_comment
# 0                                      warsyi nahwanda
# 1    review kayak waktu  mbps dong bang sambil main...
# 2    thankyou bang reviewnya fix upgrade baru tau  ...
# 3      alhamdulillah  mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                            saruddu saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
# [89 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu 20mbps dong bang... sambil ...
# 2    thankyou bang reviewnya... fix upgrade, baru t...
# 3     alhamdulillah 30mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           saruddu? saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                       cleaning_comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu  mbps dong bang sambil main...
# 2    thankyou bang reviewnya fix upgrade baru tau  ...
# 3      alhamdulillah  mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                            saruddu saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                             tokenisasi
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, waktu, mbps, dong, bang, sambi...
# 2    [thankyou, bang, reviewnya, fix, upgrade, baru...
# 3    [alhamdulillah, mbps, digunakan, sekeluarga, m...
# 4    [ukuran, buat, home, user, sudah, sangat, sang...
# ..                                                 ...
# 109  [sama, bang, sulsel, juga, tapi, buka, tiktok,...
# 110                                [jatim, juga, bang]
# 111                       [saruddu, saya, orang, sini]
# 112   [indihome, anj, pantes, tadi, siang, kok, lemot]
# 113                             [main, emel, lag, anj]
#
# [89 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu 20mbps dong bang... sambil ...
# 2    thankyou bang reviewnya... fix upgrade, baru t...
# 3     alhamdulillah 30mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           saruddu? saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                       cleaning_comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu  mbps dong bang sambil main...
# 2    thankyou bang reviewnya fix upgrade baru tau  ...
# 3      alhamdulillah  mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                            saruddu saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                             tokenisasi  \
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, waktu, mbps, dong, bang, sambi...
# 2    [thankyou, bang, reviewnya, fix, upgrade, baru...
# 3    [alhamdulillah, mbps, digunakan, sekeluarga, m...
# 4    [ukuran, buat, home, user, sudah, sangat, sang...
# ..                                                 ...
# 109  [sama, bang, sulsel, juga, tapi, buka, tiktok,...
# 110                                [jatim, juga, bang]
# 111                       [saruddu, saya, orang, sini]
# 112   [indihome, anj, pantes, tadi, siang, kok, lemot]
# 113                             [main, emel, lag, anj]
#
#                                               stopword
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, mbps, bang, main, game, nonton...
# 2    [thankyou, bang, reviewnya, fix, upgrade, mbps...
# 3            [alhamdulillah, mbps, sekeluarga, mantap]
# 4    [ukuran, home, user, worth, main, game, downlo...
# ..                                                 ...
# 109  [bang, sulsel, buka, tiktok, lancar, apk, lag,...
# 110                                      [jatim, bang]
# 111                                   [saruddu, orang]
# 112                   [indihome, pantes, siang, lemot]
# 113                                  [main, emel, lag]
#
# [89 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 285
# ------------------------
# warsyi : warsyi
# nahwanda : nahwanda
# review : review
# kayak : kayak
# mbps : mbps
# bang : bang
# main : main
# game : game
# nonton : nonton
# device : device
# please : please
# upgrade : upgrade
# ragu : ragu
# thankyou : thankyou
# reviewnya : reviewnya
# fix : fix
# dihapus : hapus
# rendah : rendah
# wajar : wajar
# speed : speed
#  :
# alhamdulillah : alhamdulillah
# sekeluarga : keluarga
# mantap : mantap
# ukuran : ukur
# home : home
# user : user
# worth : worth
# download : download
# upload : upload
# stabil : stabil
# recomended : recomended
# indihome : indihome
# pelanggan : langgan
# lancar : lancar
# jaya : jaya
# tahunan : tahun
# sukses : sukses
# bro : bro
# uploadnya : uploadnya
# segitu : segitu
# live : live
# streaming : streaming
# channel : channel
# dirumah : rumah
# smart : smart
# pilih : pilih
# paket : paket
# internet : internet
# apaka : apaka
# harga : harga
# stb : stb
# routet : routet
# dsb : dsb
# pasang : pasang
# pas : pas
# tes : tes
# aplikasi : aplikasi
# cuman : cuman
# gimna : gimna
# maksimal : maksimal
# kak : kak
# pakai : pakai
# kuliah : kuliah
# online : online
# via : via
# zoom : zoom
# googlemeet : googlemeet
# taun : taun
# berlanggann : berlanggann
# biyaya : biyaya
# pulau : pulau
# jawa : jawa
# kota : kota
# phone : phone
# pergantian : ganti
# bulanannya : bulan
# berkurang : kurang
# sayang : sayang
# telfonnya : telfonnya
# butuhnya : butuh
# halo : halo
# pkt : pkt
# play : play
# harganya : harga
# blm : blm
# ppn : ppn
# perbulannya : bulan
# bayar : bayar
# totalnya : total
# biaya : biaya
# konsisten : konsisten
# turun : turun
# maximal : maximal
# terdmbung : terdmbung
# mas : mas
# thanks : thanks
# abang : abang
# gimana : gimana
# fupnya : fupnya
# max : max
# brp : brp
# daftar : daftar
# web : web
# aman : aman
# bagus : bagus
# after : after
# sales : sales
# ping : ping
# knp : knp
# faktor : faktor
# lokasi : lokasi
# gmna : gmna
# pelit : pelit
# gila : gila
# wkwkwk : wkwkwk
# provider : provider
# nspeed : nspeed
# twtangga : twtangga
# kecepatan : cepat
# mentok : mentok
# kah : kah
# gua : gua
# apk : apk
# omlet : omlet
# arcade : arcade
# ngga : ngga
# only : only
# didaerah : daerah
# mahal : mahal
# telepon : telepon
# pemasangan : pasang
# doang : doang
# kaga : kaga
# kayanya : kaya
# bet : bet
# rb : rb
# serius : serius
# aktualnya : aktual
# dibawah : bawah
# nge : nge
# lag : lag
# kek : kek
# emot : emot
# gini : gin
# bola : bola
# knapa : knapa
# website : website
# fup : fup
# liat : liat
# komen : komen
# kena : kena
# udh : udh
# udah : udah
# keluarga : keluarga
# aktifitas : aktifitas
# emang : emang
# pasangnya : pasang
# pawonkuy : pawonkuy
# indigo : indigo
# telat : telat
# dikenakan : kena
# denda : denda
# jaringannya : jaring
# konsumennya : konsumen
# dirugikan : rugi
# nggak : nggak
# kompensasinya : kompensasi
# timur : timur
# trobel : trobel
# blitar : blitar
# metro : metro
# ngereang : ngereang
# patah : patah
# salah : salah
# ter : ter
# men : men
# diamon : diamon
# potongan : potong
# pembayaran : bayar
# jngn : jngn
# ambil : ambil
# untung : untung
# seneng : neng
# telkomsel : telkomsel
# loss : loss
# atao : atao
# hack : hack
# salam : salam
# pemuda : pemuda
# transaksi : transaksi
# gagal : gagal
# saldo : saldo
# makassar : makassar
# lemot : lot
# jga : jga
# wifinya : wifinya
# wifi : wifi
# tetangga : tetangga
# kaltim : kaltim
# samarinda : samarinda
# kalimantan : kalimantan
# selatan : selatan
# jogja : jogja
# iyo : iyo
# mass : mass
# kabeh : kabeh
# wess : wess
# angel : angel
# malang : malang
# trobell : trobell
# terkena : kena
# dampak : dampak
# tetep : tetep
# bermasalah : masalah
# daerah : daerah
# timurr : timurr
# normal : normal
# barat : barat
# matikan : mati
# lelet : lelet
# tetring : tetring
# penjualan : jual
# hancur : hancur
# pasuruan : pasuruan
# banget : banget
# trouble : trouble
# bandung : bandung
# cirebon : cirebon
# jombang : jombang
# loby : loby
# epep : epep
# bgs : bgs
# dlm : dlm
# kya : kya
# hmm : hmm
# jaringan : jaring
# ama : ama
# bangle : bangle
# jatim : jatim
# kiamat : kiamat
# down : down
# pantesan : pantesan
# pink : pink
# merah : merah
# tros : tros
# bekasi : bekas
# ngelag : ngelag
# cug : cug
# kemarennnn : kemarennnn
# was : was
# scaredd : scaredd
# smh : smh
# the : the
# worst : worst
# feeling : feeling
# ever : ever
# ngl : ngl
# malem : malem
# tagihan : tagih
# bukalapak : bukalapak
# manapun : mana
# atasi : atas
# vpn : vpn
# min : min
# kpn : kpn
# pulih : pulih
# depok : depok
# bali : bal
# gabisa : gabisa
# ngapa : ngapa
# yeuh : yeuh
# ngerjain : ngerjain
# tugas : tugas
# sulsel : sulsel
# buka : buka
# tiktok : tiktok
# parah : parah
# kyk : kyk
# gitu : gitu
# saruddu : saruddu
# orang : orang
# pantes : pantes
# siang : siang
# emel : emel
# {'warsyi': 'warsyi', 'nahwanda': 'nahwanda', 'review': 'review', 'kayak': 'kayak', 'mbps': 'mbps', 'bang': 'bang', 'main': 'main', 'game': 'game', 'nonton': 'nonton', 'device': 'device', 'please': 'please', 'upgrade': 'upgrade', 'ragu': 'ragu', 'thankyou': 'thankyou', 'reviewnya': 'reviewnya', 'fix': 'fix', 'dihapus': 'hapus', 'rendah': 'rendah', 'wajar': 'wajar', 'speed': 'speed', '': '', 'alhamdulillah': 'alhamdulillah', 'sekeluarga': 'keluarga', 'mantap': 'mantap', 'ukuran': 'ukur', 'home': 'home', 'user': 'user', 'worth': 'worth', 'download': 'download', 'upload': 'upload', 'stabil': 'stabil', 'recomended': 'recomended', 'indihome': 'indihome', 'pelanggan': 'langgan', 'lancar': 'lancar', 'jaya': 'jaya', 'tahunan': 'tahun', 'sukses': 'sukses', 'bro': 'bro', 'uploadnya': 'uploadnya', 'segitu': 'segitu', 'live': 'live', 'streaming': 'streaming', 'channel': 'channel', 'dirumah': 'rumah', 'smart': 'smart', 'pilih': 'pilih', 'paket': 'paket', 'internet': 'internet', 'apaka': 'apaka', 'harga': 'harga', 'stb': 'stb', 'routet': 'routet', 'dsb': 'dsb', 'pasang': 'pasang', 'pas': 'pas', 'tes': 'tes', 'aplikasi': 'aplikasi', 'cuman': 'cuman', 'gimna': 'gimna', 'maksimal': 'maksimal', 'kak': 'kak', 'pakai': 'pakai', 'kuliah': 'kuliah', 'online': 'online', 'via': 'via', 'zoom': 'zoom', 'googlemeet': 'googlemeet', 'taun': 'taun', 'berlanggann': 'berlanggann', 'biyaya': 'biyaya', 'pulau': 'pulau', 'jawa': 'jawa', 'kota': 'kota', 'phone': 'phone', 'pergantian': 'ganti', 'bulanannya': 'bulan', 'berkurang': 'kurang', 'sayang': 'sayang', 'telfonnya': 'telfonnya', 'butuhnya': 'butuh', 'halo': 'halo', 'pkt': 'pkt', 'play': 'play', 'harganya': 'harga', 'blm': 'blm', 'ppn': 'ppn', 'perbulannya': 'bulan', 'bayar': 'bayar', 'totalnya': 'total', 'biaya': 'biaya', 'konsisten': 'konsisten', 'turun': 'turun', 'maximal': 'maximal', 'terdmbung': 'terdmbung', 'mas': 'mas', 'thanks': 'thanks', 'abang': 'abang', 'gimana': 'gimana', 'fupnya': 'fupnya', 'max': 'max', 'brp': 'brp', 'daftar': 'daftar', 'web': 'web', 'aman': 'aman', 'bagus': 'bagus', 'after': 'after', 'sales': 'sales', 'ping': 'ping', 'knp': 'knp', 'faktor': 'faktor', 'lokasi': 'lokasi', 'gmna': 'gmna', 'pelit': 'pelit', 'gila': 'gila', 'wkwkwk': 'wkwkwk', 'provider': 'provider', 'nspeed': 'nspeed', 'twtangga': 'twtangga', 'kecepatan': 'cepat', 'mentok': 'mentok', 'kah': 'kah', 'gua': 'gua', 'apk': 'apk', 'omlet': 'omlet', 'arcade': 'arcade', 'ngga': 'ngga', 'only': 'only', 'didaerah': 'daerah', 'mahal': 'mahal', 'telepon': 'telepon', 'pemasangan': 'pasang', 'doang': 'doang', 'kaga': 'kaga', 'kayanya': 'kaya', 'bet': 'bet', 'rb': 'rb', 'serius': 'serius', 'aktualnya': 'aktual', 'dibawah': 'bawah', 'nge': 'nge', 'lag': 'lag', 'kek': 'kek', 'emot': 'emot', 'gini': 'gin', 'bola': 'bola', 'knapa': 'knapa', 'website': 'website', 'fup': 'fup', 'liat': 'liat', 'komen': 'komen', 'kena': 'kena', 'udh': 'udh', 'udah': 'udah', 'keluarga': 'keluarga', 'aktifitas': 'aktifitas', 'emang': 'emang', 'pasangnya': 'pasang', 'pawonkuy': 'pawonkuy', 'indigo': 'indigo', 'telat': 'telat', 'dikenakan': 'kena', 'denda': 'denda', 'jaringannya': 'jaring', 'konsumennya': 'konsumen', 'dirugikan': 'rugi', 'nggak': 'nggak', 'kompensasinya': 'kompensasi', 'timur': 'timur', 'trobel': 'trobel', 'blitar': 'blitar', 'metro': 'metro', 'ngereang': 'ngereang', 'patah': 'patah', 'salah': 'salah', 'ter': 'ter', 'men': 'men', 'diamon': 'diamon', 'potongan': 'potong', 'pembayaran': 'bayar', 'jngn': 'jngn', 'ambil': 'ambil', 'untung': 'untung', 'seneng': 'neng', 'telkomsel': 'telkomsel', 'loss': 'loss', 'atao': 'atao', 'hack': 'hack', 'salam': 'salam', 'pemuda': 'pemuda', 'transaksi': 'transaksi', 'gagal': 'gagal', 'saldo': 'saldo', 'makassar': 'makassar', 'lemot': 'lot', 'jga': 'jga', 'wifinya': 'wifinya', 'wifi': 'wifi', 'tetangga': 'tetangga', 'kaltim': 'kaltim', 'samarinda': 'samarinda', 'kalimantan': 'kalimantan', 'selatan': 'selatan', 'jogja': 'jogja', 'iyo': 'iyo', 'mass': 'mass', 'kabeh': 'kabeh', 'wess': 'wess', 'angel': 'angel', ...
# ------------------------
# Pandas Apply:   0%|          | 0/89 [00:00<?, ?it/s]
#                                                comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu 20mbps dong bang... sambil ...
# 2    thankyou bang reviewnya... fix upgrade, baru t...
# 3     alhamdulillah 30mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                           saruddu? saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                       cleaning_comment  \
# 0                                      warsyi nahwanda
# 1    review kayak waktu  mbps dong bang sambil main...
# 2    thankyou bang reviewnya fix upgrade baru tau  ...
# 3      alhamdulillah  mbps digunakan sekeluarga mantap
# 4    ukuran buat home user sudah sangat sangat wort...
# ..                                                 ...
# 109  sama bang sulsel juga tapi buka tiktok lancar ...
# 110                                    jatim juga bang
# 111                            saruddu saya orang sini
# 112           indihome anj pantes tadi siang kok lemot
# 113                                  main emel lag anj
#
#                                             tokenisasi  \
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, waktu, mbps, dong, bang, sambi...
# 2    [thankyou, bang, reviewnya, fix, upgrade, baru...
# 3    [alhamdulillah, mbps, digunakan, sekeluarga, m...
# 4    [ukuran, buat, home, user, sudah, sangat, sang...
# ..                                                 ...
# 109  [sama, bang, sulsel, juga, tapi, buka, tiktok,...
# 110                                [jatim, juga, bang]
# 111                       [saruddu, saya, orang, sini]
# 112   [indihome, anj, pantes, tadi, siang, kok, lemot]
# 113                             [main, emel, lag, anj]
#
#                                               stopword  \
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, mbps, bang, main, game, nonton...
# 2    [thankyou, bang, reviewnya, fix, upgrade, mbps...
# 3            [alhamdulillah, mbps, sekeluarga, mantap]
# 4    [ukuran, home, user, worth, main, game, downlo...
# ..                                                 ...
# 109  [bang, sulsel, buka, tiktok, lancar, apk, lag,...
# 110                                      [jatim, bang]
# 111                                   [saruddu, orang]
# 112                   [indihome, pantes, siang, lemot]
# 113                                  [main, emel, lag]
#
#                                               stemming
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, mbps, bang, main, game, nonton...
# 2    [thankyou, bang, reviewnya, fix, upgrade, mbps...
# 3              [alhamdulillah, mbps, keluarga, mantap]
# 4    [ukur, home, user, worth, main, game, download...
# ..                                                 ...
# 109  [bang, sulsel, buka, tiktok, lancar, apk, lag,...
# 110                                      [jatim, bang]
# 111                                   [saruddu, orang]
# 112                     [indihome, pantes, siang, lot]
# 113                                  [main, emel, lag]
#
# [89 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0                                   [warsyi, nahwanda]
# 1    [review, kayak, mbps, bang, main, game, nonton...
# 2    [thankyou, bang, reviewnya, fix, upgrade, mbps...
# 3              [alhamdulillah, mbps, keluarga, mantap]
# 4    [ukur, home, user, worth, main, game, download...
# ..                                                 ...
# 109  [bang, sulsel, buka, tiktok, lancar, apk, lag,...
# 110                                      [jatim, bang]
# 111                                   [saruddu, orang]
# 112                     [indihome, pantes, siang, lot]
# 113                                  [main, emel, lag]
#
# [89 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_10.xlsx')
