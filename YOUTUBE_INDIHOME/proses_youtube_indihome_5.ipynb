# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    INDIHOME STANDART RENDAH SEKARANG! BANYAK LEMO...
# 1                             Real life beda dgn iklan
# 2                                        Pas main MLBB
# 3                                      Mantap indihome
# 4                         Mana mas Agus dan mas Prass😂
# ..                                                 ...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        Gw kaga bayar udah 750 ribu
# 143            Gu kena 1 jta anj nunggak 2 bulan doang
# 144  SMA kaya sy mas nya ,,trus gy mnh kalo yang gk...
#
# [145 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 28

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    INDIHOME STANDART RENDAH SEKARANG! BANYAK LEMO...
# 1                             Real life beda dgn iklan
# 2                                        Pas main MLBB
# 3                                      Mantap indihome
# 4                         Mana mas Agus dan mas Prass😂
# ..                                                 ...
# 139  Emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        Gw kaga bayar udah 750 ribu
# 143            Gu kena 1 jta anj nunggak 2 bulan doang
#
# [89 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    indihome standart rendah sekarang! banyak lemo...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass😂
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        gw kaga bayar udah 750 ribu
# 143            gu kena 1 jta anj nunggak 2 bulan doang
#
# [89 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    indihome standart rendah sekarang! banyak lemo...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass😂
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        gw kaga bayar udah 750 ribu
# 143            gu kena 1 jta anj nunggak 2 bulan doang
#
#                                       cleaning_comment
# 0    indihome standart rendah sekarang banyak lemot...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo bayar tagihan denda ada orang keja...
# 141                                   asli kacau kacau
# 142                             kaga bayar udah   ribu
# 143                   kena jta anj nunggak bulan doang
#
# [89 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    indihome standart rendah sekarang! banyak lemo...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass😂
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        gw kaga bayar udah 750 ribu
# 143            gu kena 1 jta anj nunggak 2 bulan doang
#
#                                       cleaning_comment  \
# 0    indihome standart rendah sekarang banyak lemot...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo bayar tagihan denda ada orang keja...
# 141                                   asli kacau kacau
# 142                             kaga bayar udah   ribu
# 143                   kena jta anj nunggak bulan doang
#
#                                             tokenisasi
# 0    [indihome, standart, rendah, sekarang, banyak,...
# 1                       [real, life, beda, dgn, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                 [mana, mas, agus, dan, mas, prass, ]
# ..                                                 ...
# 139  [emang, gak, jelas, telkom, saya, sudah, berhe...
# 140  [katanya, klo, bayar, tagihan, denda, ada, ora...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143          [, kena, jta, anj, nunggak, bulan, doang]
#
# [89 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    indihome standart rendah sekarang! banyak lemo...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass😂
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        gw kaga bayar udah 750 ribu
# 143            gu kena 1 jta anj nunggak 2 bulan doang
#
#                                       cleaning_comment  \
# 0    indihome standart rendah sekarang banyak lemot...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo bayar tagihan denda ada orang keja...
# 141                                   asli kacau kacau
# 142                             kaga bayar udah   ribu
# 143                   kena jta anj nunggak bulan doang
#
#                                             tokenisasi  \
# 0    [indihome, standart, rendah, sekarang, banyak,...
# 1                       [real, life, beda, dgn, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                 [mana, mas, agus, dan, mas, prass, ]
# ..                                                 ...
# 139  [emang, gak, jelas, telkom, saya, sudah, berhe...
# 140  [katanya, klo, bayar, tagihan, denda, ada, ora...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143          [, kena, jta, anj, nunggak, bulan, doang]
#
#                                               stopword
# 0             [indihome, standart, rendah, lemotnya, ]
# 1                            [real, life, beda, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                            [mas, agus, mas, prass, ]
# ..                                                 ...
# 139  [emang, telkom, berhenti, berlangganan, udah, ...
# 140  [bayar, tagihan, denda, orang, kejaksaan, keru...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143                      [, kena, jta, nunggak, doang]
#
# [89 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 498
# ------------------------
# indihome : indihome
# standart : standart
# rendah : rendah
# lemotnya : lot
#  :
# real : real
# life : life
# beda : beda
# iklan : iklan
# pas : pas
# main : main
# mlbb : mlbb
# mantap : mantap
# mas : mas
# agus : agus
# prass : prass
# game : game
# sekelas : kelas
# ping : ping
# merah : merah
# pagi : pagi
# videonya : video
# andalkan : andal
# buang : buang
# uang : uang
# doang : doang
# ngaca : ngaca
# woy : woy
# rendahan : rendah
# gua : gua
# abang : abang
# abangku : abang
# dimarahi : marah
# mak : mak
# belajar : ajar
# biznet : biznet
# sabi : sabi
# jedag : jedag
# jedug : jedug
# wifi : wifi
# sampah : sampah
# sinyal : sinyal
# burik : burik
# tari : tari
# ubur : ubur
# bur : bur
# kosong : kosong
# delapan : delapan
# sembilan : sembilan
# kali : kali
# zzzzzz : zzzzzz
# ganguan : ganguan
# taiiiiii : taiiiiii
# keren : keren
# bang : bang
# penjelasanya : jasa
# berlangganan : langgan
# rampung : rampung
# isolir : isolir
# biaya : biaya
# bulanan : bulan
# ppn : ppn
# pembayaran : bayar
# telat : telat
# gimana : gimana
# cerita : cerita
# pengalaman : alam
# posisi : posisi
# pemakaian : pakai
# emang : emang
# sayaa : sayaa
# berlangganankan : berlangganankan
# problem : problem
# pemindahan : pindah
# alamat : alamat
# dendanya : denda
# lumayan : lumayan
# jt : jt
# kga : kga
# bayar : bayar
# ampe : ampe
# skrng : skrng
# nunggak : nunggak
# plasa : plasa
# prosedur : prosedur
# shock : shock
# salahkan : salah
# selesnya : les
# kasih : kasih
# denda : denda
# cuman : cuman
# putus : putus
# berpelangganan : langgan
# situ : situ
# orang : orang
# plasanya : plasanya
# jalan : jalan
# keluarnya : keluar
# enak : enak
# ngapain : ngapain
# makasih : makasih
# memakai : pakai
# internet : internet
# dipaksa : paksa
# setahun : tahun
# jaringan : jaring
# jelek : jelek
# pindah : pindah
# rumah : rumah
# dll : dll
# haknya : hak
# dendain : dendain
# ambil : ambil
# balim : balim
# barang : barang
# menjamin : jamin
# syarat : syarat
# berkurang : kurang
# setitik : titik
# july : july
# pemasangan : pasang
# idihome : idihome
# copot : copot
# mahal : mahal
# masuk : masuk
# checking : checking
# solusinya : solusi
# gan : gan
# th : th
# tplinknya : tplinknya
# pakai : pakai
# trus : trus
# langganan : langgan
# saye : saye
# gthu : gthu
# kayak : kayak
# abg : abg
# berlaku : laku
# bro : bro
# gitu : gitu
# make : make
# bayarnya : bayar
# indhihome : indhihome
# mati : mati
# hebat : hebat
# penipuan : tipu
# terang : terang
# naudzubilah : naudzubilah
# mindzalik : mindzalik
# korupsi : korupsi
# musim : musim
# pandemi : pandemi
# kesel : kesel
# nor : nor
# bantunya : bantu
# tnggal : tnggal
# brapa : brapa
# indihomnya : indihomnya
# kaloq : kaloq
# pemakianya : pemakianya
# truss : truss
# trimaksih : trimaksih
# barusan : barusan
# alami : alami
# nama : nama
# pawan : pawan
# fiber : fiber
# tifu : tifu
# beli : beli
# paket : paket
# harga : harga
# tentukan : tentu
# kejadian : jadi
# plg : plg
# lbran : lbran
# isi : isi
# pemotongan : potong
# dtangi : dtangi
# aturan : atur
# berati : berat
# karna : karna
# sistim : sistim
# senasib : nasib
# dasar : dasar
# logika : logika
# pascabayar : pascabayar
# dapet : dapet
# solusi : solusi
# gmna : gmna
# udah : udah
# diputus : putus
# ditagih : tagih
# kampret : kampret
# semoga : moga
# bangkrut : bangkrut
# direksinya : direksi
# diazab : azab
# allah : allah
# bgtt : bgtt
# niih : niih
# jelasin : jelasin
# kesitu : kesitu
# aneh : aneh
# pengen : ken
# asliiii : asliiii
# januari : januari
# aktifkan : aktif
# juli : juli
# kontrakan : kontra
# menggantikan : ganti
# ngak : ngak
# dihubungi : hubung
# biarkan : biar
# nomer : nomer
# whats : whats
# suruh : suruh
# skrg : skrg
# tagihannya : tagih
# gmn : gmn
# tolong : tolong
# astagfirullah : astagfirullah
# dibayar : bayar
# thnk : thnk
# infonya : info
# thn : thn
# terahir : terahir
# tgl : tgl
# tagihan : tagih
# kaget : kaget
# bln : bln
# gue : gue
# stop : stop
# ganti : ganti
# resmi : resmi
# balikin : balikin
# modem : modem
# surat : surat
# somasi : somasi
# untung : untung
# dokumen : dokumen
# bukti : bukti
# simpen : simpen
# bajingan : bajing
# andai : andai
# ngerasa : ngerasa
# clear : clear
# kemarin : kemarin
# server : server
# telkom : telkom
# data : data
# dianggap : anggap
# ngutang : ngutang
# nanya : nanya
# sbnrnya : sbnrnya
# sya : sya
# byar : byar
# mgkn : mgkn
# kna : kna
# tipu : tipu
# sales : sales
# kayanya : kaya
# pdhl : pdhl
# ttngga : ttngga
# ato : ato
# oon : oon
# udh : udh
# mbps : mbps
# krna : krna
# promo : promo
# slahnya : slah
# dteng : dteng
# plaza : plaza
# mlah : mlah
# lwat : lwat
# ngmong : ngmong
# kdu : kdu
# dlu : dlu
# sisitimnya : sisitimnya
# deposit : deposit
# pasang : pasang
# nnti : nnti
# nagih : nagih
# tlp : tlp
# ktanya : ktanya
# alloh : alloh
# mnggu : mnggu
# tnggung : tnggung
# jwb : jwb
# biarin : biarin
# bkln : bkln
# singkatnya : singkat
# kmrn : kmrn
# puasa : puasa
# dpt : dpt
# pengadilan : adil
# gara : gara
# mkin : mkin
# sbel : sbel
# tlponin : tlponin
# nma : nma
# qta : qta
# brangkali : brangkali
# lucu : lucu
# kena : kena
# logikanya : logika
# persis : persis
# listrik : listrik
# token : token
# diisi : isi
# gelap : gelap
# gelapan : gelap
# pln : pln
# memberlakukan : laku
# sistem : sistem
# gpp : gpp
# juni : juni
# mei : mei
# app : app
# ribu : ribu
# speed : speed
# bayaran : bayar
# pulang : pulang
# kampung : kampung
# medan : medan
# ratus : ratus
# plis : plis
# rbu : rbu
# blan : blan
# kenaikan : naik
# pikir : pikir
# sengaja : sengaja
# cinta : cinta
# kmren : kmren
# mesti : mesti
# pdhal : pdhal
# november : november
# ink : ink
# full : full
# total : total
# bener : bener
# tunggakan : tunggak
# sampek : sampek
# tahunan : tahun
# hasilnya : hasil
# kagak : kagak
# berani : berani
# hadepin : hadepin
# intinya : inti
# akal : akal
# engga : engga
# wifinya : wifinya
# ttp : ttp
# sisitim : sisitim
# njir : njir
# mohon : mohon
# indohome : indohome
# februari : februari
# dikarenkan : dikarenkan
# kuat : kuat
# soale : soale
# istri : istri
# melahirkan : lahir
# scr : scr
# otomatis : otomatis
# cma : cma
# mencabut : cabut
# kabelnya : kabel
# mberesin : mberesin
# modemnya : modem
# waduhhh : waduhhh
# dituntut : tuntut
# ternyta : ternyta
# prank : prank
# lemot : lot
# banget : banget
# putuskan : putus
# email : email
# kirain : kirain
# kelar : kelar
# kejaksaan : jaksa
# ditempuh : tempuh
# jalur : jalur
# hukum : hukum
# bgitu : bgitu
# kondisi : kondisi
# tempati : tempat
# kondisinya : kondisi
# sdng : sdng
# jaga : jaga
# tua : tua
# sakit : sakit
# smpe : smpe
# orng : orng
# meninggal : tinggal
# berlanjut : lanjut
# ngurus : ngurus
# pemakaman : makam
# tempatin : tempatin
# berniat : niat
# nerusin : nerusin
# indihom : indihom
# tagihanya : tagihanya
# hrs : hrs
# bayarkan : bayar
# lanjutkan : lanjut
# pemutusan : putus
# pemakean : pemakean
# brarti : brarti
# dalem : dalem
# berhenti : henti
# papa : papa
# jatuhnya : jatuh
# kaya : kaya
# jebakan : jebak
# temen : temen
# masukan : masuk
# st : st
# media : media
# dibantu : bantu
# pegawai : pegawai
# tenang : tenang
# terima : terima
# beres : beres
# byr : byr
# tegur : tegur
# diurus : urus
# pemutihan : mutih
# dtg : dtg
# serang : serang
# penalti : penalti
# juta : juta
# blm : blm
# sthn : sthn
# pemerasan : peras
# selajutnya : selajutnya
# cabut : cabut
# alatnya : alat
# mengatasnamakan : mengatasnamakan
# pengacara : acara
# menuntut : tuntut
# membayar : bayar
# nasib : nasib
# ditlpn : ditlpn
# matiin : matiin
# ngalamin : ngalamin
# marah : marah
# tetep : tetep
# ngalah : ngalah
# alhasil : alhasil
# lakuin : lakuin
# handle : handle
# ngringangin : ngringangin
# pencerahan : cerah
# salesnya : salesnya
# sumpah : sumpah
# ragu : ragu
# gini : gin
# tanda : tanda
# tangan : tangan
# kontrak : kontrak
# berhak : hak
# nuntut : nuntut
# bisaan : bisa
# ane : ane
# sehari : hari
# rb : rb
# kelupaan : lupa
# lol : lol
# nasibnya : nasib
# pny : pny
# masi : mas
# namanya : nama
# kenak : nak
# macem : macem
# hutang : hutang
# kejar : kejar
# mulu : mulu
# bumn : bumn
# kek : kek
# rentenir : rentenir
# anjr : anjr
# sebulan : bulan
# ajg : ajg
# setres : tres
# acc : acc
# router : router
# skrang : skrang
# kamprettttttt : kamprettttttt
# nyesel : nyesel
# daftar : daftar
# pelangan : pelang
# kerumah : rumah
# iya : iya
# kah : kah
# asli : asli
# kacau : kacau
# kaga : kaga
# jta : jta
# {'indihome': 'indihome', 'standart': 'standart', 'rendah': 'rendah', 'lemotnya': 'lot', '': '', 'real': 'real', 'life': 'life', 'beda': 'beda', 'iklan': 'iklan', 'pas': 'pas', 'main': 'main', 'mlbb': 'mlbb', 'mantap': 'mantap', 'mas': 'mas', 'agus': 'agus', 'prass': 'prass', 'game': 'game', 'sekelas': 'kelas', 'ping': 'ping', 'merah': 'merah', 'pagi': 'pagi', 'videonya': 'video', 'andalkan': 'andal', 'buang': 'buang', 'uang': 'uang', 'doang': 'doang', 'ngaca': 'ngaca', 'woy': 'woy', 'rendahan': 'rendah', 'gua': 'gua', 'abang': 'abang', 'abangku': 'abang', 'dimarahi': 'marah', 'mak': 'mak', 'belajar': 'ajar', 'biznet': 'biznet', 'sabi': 'sabi', 'jedag': 'jedag', 'jedug': 'jedug', 'wifi': 'wifi', 'sampah': 'sampah', 'sinyal': 'sinyal', 'burik': 'burik', 'tari': 'tari', 'ubur': 'ubur', 'bur': 'bur', 'kosong': 'kosong', 'delapan': 'delapan', 'sembilan': 'sembilan', 'kali': 'kali', 'zzzzzz': 'zzzzzz', 'ganguan': 'ganguan', 'taiiiiii': 'taiiiiii', 'keren': 'keren', 'bang': 'bang', 'penjelasanya': 'jasa', 'berlangganan': 'langgan', 'rampung': 'rampung', 'isolir': 'isolir', 'biaya': 'biaya', 'bulanan': 'bulan', 'ppn': 'ppn', 'pembayaran': 'bayar', 'telat': 'telat', 'gimana': 'gimana', 'cerita': 'cerita', 'pengalaman': 'alam', 'posisi': 'posisi', 'pemakaian': 'pakai', 'emang': 'emang', 'sayaa': 'sayaa', 'berlangganankan': 'berlangganankan', 'problem': 'problem', 'pemindahan': 'pindah', 'alamat': 'alamat', 'dendanya': 'denda', 'lumayan': 'lumayan', 'jt': 'jt', 'kga': 'kga', 'bayar': 'bayar', 'ampe': 'ampe', 'skrng': 'skrng', 'nunggak': 'nunggak', 'plasa': 'plasa', 'prosedur': 'prosedur', 'shock': 'shock', 'salahkan': 'salah', 'selesnya': 'les', 'kasih': 'kasih', 'denda': 'denda', 'cuman': 'cuman', 'putus': 'putus', 'berpelangganan': 'langgan', 'situ': 'situ', 'orang': 'orang', 'plasanya': 'plasanya', 'jalan': 'jalan', 'keluarnya': 'keluar', 'enak': 'enak', 'ngapain': 'ngapain', 'makasih': 'makasih', 'memakai': 'pakai', 'internet': 'internet', 'dipaksa': 'paksa', 'setahun': 'tahun', 'jaringan': 'jaring', 'jelek': 'jelek', 'pindah': 'pindah', 'rumah': 'rumah', 'dll': 'dll', 'haknya': 'hak', 'dendain': 'dendain', 'ambil': 'ambil', 'balim': 'balim', 'barang': 'barang', 'menjamin': 'jamin', 'syarat': 'syarat', 'berkurang': 'kurang', 'setitik': 'titik', 'july': 'july', 'pemasangan': 'pasang', 'idihome': 'idihome', 'copot': 'copot', 'mahal': 'mahal', 'masuk': 'masuk', 'checking': 'checking', 'solusinya': 'solusi', 'gan': 'gan', 'th': 'th', 'tplinknya': 'tplinknya', 'pakai': 'pakai', 'trus': 'trus', 'langganan': 'langgan', 'saye': 'saye', 'gthu': 'gthu', 'kayak': 'kayak', 'abg': 'abg', 'berlaku': 'laku', 'bro': 'bro', 'gitu': 'gitu', 'make': 'make', 'bayarnya': 'bayar', 'indhihome': 'indhihome', 'mati': 'mati', 'hebat': 'hebat', 'penipuan': 'tipu', 'terang': 'terang', 'naudzubilah': 'naudzubilah', 'mindzalik': 'mindzalik', 'korupsi': 'korupsi', 'musim': 'musim', 'pandemi': 'pandemi', 'kesel': 'kesel', 'nor': 'nor', 'bantunya': 'bantu', 'tnggal': 'tnggal', 'brapa': 'brapa', 'indihomnya': 'indihomnya', 'kaloq': 'kaloq', 'pemakianya': 'pemakianya', 'truss': 'truss', 'trimaksih': 'trimaksih', 'barusan': 'barusan', 'alami': 'alami', 'nama': 'nama', 'pawan': 'pawan', 'fiber': 'fiber', 'tifu': 'tifu', 'beli': 'beli', 'paket': 'paket', 'harga': 'harga', 'tentukan': 'tentu', 'kejadian': 'jadi', 'plg': 'plg', 'lbran': 'lbran', 'isi': 'isi', 'pemotongan': 'potong', 'dtangi': 'dtangi', 'aturan': 'atur', 'berati': 'berat', 'karna': 'karna', 'sistim': 'sistim', 'senasib': 'nasib', 'dasar': 'dasar', 'logika': 'logika', 'pascabayar': 'pascabayar', 'dapet': 'dapet', 'solusi': 'solusi', 'gmna': 'gmna', 'udah': 'udah', 'diputus': 'putus', 'ditagih': 'tagih', 'kampret': 'kampret', 'semoga': 'moga', 'bangkrut': 'bangkrut', 'direksinya': 'direksi', 'diazab': 'azab', 'allah': 'allah', 'bgtt': 'bgtt', 'niih': 'niih', 'jelasin': 'jelasin', 'kesitu': 'kesitu', 'aneh': 'aneh', 'pengen': 'ken', 'asliiii': 'asliiii', 'januari': 'januari', 'aktifkan': 'aktif', 'juli': 'juli ...
# ------------------------
# Pandas Apply:   0%|          | 0/89 [00:00<?, ?it/s]
#                                                comment  \
# 0    indihome standart rendah sekarang! banyak lemo...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass😂
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo ga bayar tagihan sm denda ada oran...
# 141                                   asli kacau kacau
# 142                        gw kaga bayar udah 750 ribu
# 143            gu kena 1 jta anj nunggak 2 bulan doang
#
#                                       cleaning_comment  \
# 0    indihome standart rendah sekarang banyak lemot...
# 1                             real life beda dgn iklan
# 2                                        pas main mlbb
# 3                                      mantap indihome
# 4                         mana mas agus dan mas prass
# ..                                                 ...
# 139  emang gak jelas telkom saya sudah berhenti ber...
# 140  katanya klo bayar tagihan denda ada orang keja...
# 141                                   asli kacau kacau
# 142                             kaga bayar udah   ribu
# 143                   kena jta anj nunggak bulan doang
#
#                                             tokenisasi  \
# 0    [indihome, standart, rendah, sekarang, banyak,...
# 1                       [real, life, beda, dgn, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                 [mana, mas, agus, dan, mas, prass, ]
# ..                                                 ...
# 139  [emang, gak, jelas, telkom, saya, sudah, berhe...
# 140  [katanya, klo, bayar, tagihan, denda, ada, ora...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143          [, kena, jta, anj, nunggak, bulan, doang]
#
#                                               stopword  \
# 0             [indihome, standart, rendah, lemotnya, ]
# 1                            [real, life, beda, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                            [mas, agus, mas, prass, ]
# ..                                                 ...
# 139  [emang, telkom, berhenti, berlangganan, udah, ...
# 140  [bayar, tagihan, denda, orang, kejaksaan, keru...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143                      [, kena, jta, nunggak, doang]
#
#                                               stemming
# 0                  [indihome, standart, rendah, lot, ]
# 1                            [real, life, beda, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                            [mas, agus, mas, prass, ]
# ..                                                 ...
# 139  [emang, telkom, henti, langgan, udah, telkom, ...
# 140  [bayar, tagih, denda, orang, jaksa, rumah, iya...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143                      [, kena, jta, nunggak, doang]
#
# [89 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0                  [indihome, standart, rendah, lot, ]
# 1                            [real, life, beda, iklan]
# 2                                    [pas, main, mlbb]
# 3                                   [mantap, indihome]
# 4                            [mas, agus, mas, prass, ]
# ..                                                 ...
# 139  [emang, telkom, henti, langgan, udah, telkom, ...
# 140  [bayar, tagih, denda, orang, jaksa, rumah, iya...
# 141                               [asli, kacau, kacau]
# 142                        [, kaga, bayar, udah, ribu]
# 143                      [, kena, jta, nunggak, doang]
#
# [89 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_5.xlsx')
