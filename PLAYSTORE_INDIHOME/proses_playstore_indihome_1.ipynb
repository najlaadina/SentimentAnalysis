# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                content  score
# 0                          Hanya bisa berkata leg uhhh      1
# 1                       Internetnya benerin dulu.. thx      2
# 2                           Fiber optik SR mudah putus      4
# 3    Gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    Saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                Wou      5
# 974                  Kenapa skrg LOS nya sering merah?      1
# 975                                              Bagus      5
# 976                                               Good      5
#
# [977 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 65

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                content  score
# 0                          Hanya bisa berkata leg uhhh      1
# 1                       Internetnya benerin dulu.. thx      2
# 2                           Fiber optik SR mudah putus      4
# 3    Gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    Saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 970                                Susah upgrade speed      3
# 971                                       Sangat bagus      5
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                Wou      5
# 974                  Kenapa skrg LOS nya sering merah?      1
#
# [896 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                content  score
# 0                          hanya bisa berkata leg uhhh      1
# 1                       internetnya benerin dulu.. thx      2
# 2                           fiber optik sr mudah putus      4
# 3    gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 970                                susah upgrade speed      3
# 971                                       sangat bagus      5
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                wou      5
# 974                  kenapa skrg los nya sering merah?      1
#
# [896 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                content  score  \
# 0                          hanya bisa berkata leg uhhh      1
# 1                       internetnya benerin dulu.. thx      2
# 2                           fiber optik sr mudah putus      4
# 3    gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 970                                susah upgrade speed      3
# 971                                       sangat bagus      5
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                wou      5
# 974                  kenapa skrg los nya sering merah?      1
#
#                                       cleaning_content
# 0                          hanya bisa berkata leg uhhh
# 1                         internetnya benerin dulu thx
# 2                              fiber optik mudah putus
# 3    gak tau lagi sama indihome koneksi nya jelek b...
# 4    saya pasang kecepatan  mbps knp skrg jadi kura...
# ..                                                 ...
# 970                                susah upgrade speed
# 971                                       sangat bagus
# 972   bisa redeem point sudah lapor malah suruh bol...
# 973                                                wou
# 974                  kenapa skrg los nya sering merah
#
# [896 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                content  score  \
# 0                          hanya bisa berkata leg uhhh      1
# 1                       internetnya benerin dulu.. thx      2
# 2                           fiber optik sr mudah putus      4
# 3    gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 970                                susah upgrade speed      3
# 971                                       sangat bagus      5
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                wou      5
# 974                  kenapa skrg los nya sering merah?      1
#
#                                       cleaning_content  \
# 0                          hanya bisa berkata leg uhhh
# 1                         internetnya benerin dulu thx
# 2                              fiber optik mudah putus
# 3    gak tau lagi sama indihome koneksi nya jelek b...
# 4    saya pasang kecepatan  mbps knp skrg jadi kura...
# ..                                                 ...
# 970                                susah upgrade speed
# 971                                       sangat bagus
# 972   bisa redeem point sudah lapor malah suruh bol...
# 973                                                wou
# 974                  kenapa skrg los nya sering merah
#
#                                             tokenisasi
# 0                    [hanya, bisa, berkata, leg, uhhh]
# 1                    [internetnya, benerin, dulu, thx]
# 2                         [fiber, optik, mudah, putus]
# 3    [gak, tau, lagi, sama, indihome, koneksi, nya,...
# 4    [saya, pasang, kecepatan, mbps, knp, skrg, jad...
# ..                                                 ...
# 970                            [susah, upgrade, speed]
# 971                                    [sangat, bagus]
# 972  [, bisa, redeem, point, sudah, lapor, malah, s...
# 973                                              [wou]
# 974          [kenapa, skrg, los, nya, sering, merah, ]
#
# [896 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                content  score  \
# 0                          hanya bisa berkata leg uhhh      1
# 1                       internetnya benerin dulu.. thx      2
# 2                           fiber optik sr mudah putus      4
# 3    gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 970                                susah upgrade speed      3
# 971                                       sangat bagus      5
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                wou      5
# 974                  kenapa skrg los nya sering merah?      1
#
#                                       cleaning_content  \
# 0                          hanya bisa berkata leg uhhh
# 1                         internetnya benerin dulu thx
# 2                              fiber optik mudah putus
# 3    gak tau lagi sama indihome koneksi nya jelek b...
# 4    saya pasang kecepatan  mbps knp skrg jadi kura...
# ..                                                 ...
# 970                                susah upgrade speed
# 971                                       sangat bagus
# 972   bisa redeem point sudah lapor malah suruh bol...
# 973                                                wou
# 974                  kenapa skrg los nya sering merah
#
#                                             tokenisasi  \
# 0                    [hanya, bisa, berkata, leg, uhhh]
# 1                    [internetnya, benerin, dulu, thx]
# 2                         [fiber, optik, mudah, putus]
# 3    [gak, tau, lagi, sama, indihome, koneksi, nya,...
# 4    [saya, pasang, kecepatan, mbps, knp, skrg, jad...
# ..                                                 ...
# 970                            [susah, upgrade, speed]
# 971                                    [sangat, bagus]
# 972  [, bisa, redeem, point, sudah, lapor, malah, s...
# 973                                              [wou]
# 974          [kenapa, skrg, los, nya, sering, merah, ]
#
#                                               stopword
# 0                                          [leg, uhhh]
# 1                          [internetnya, benerin, thx]
# 2                         [fiber, optik, mudah, putus]
# 3    [indihome, koneksi, jelek, banget, udah, kayak...
# 4           [pasang, kecepatan, mbps, knp, skrg, mbps]
# ..                                                 ...
# 970                            [susah, upgrade, speed]
# 971                                            [bagus]
# 972  [, redeem, point, lapor, suruh, bolak, relogin...
# 973                                              [wou]
# 974                               [skrg, los, merah, ]
#
# [896 rows x 5 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 2439
# ------------------------
# leg : leg
# uhhh : uhhh
# internetnya : internetnya
# benerin : benerin
# thx : thx
# fiber : fiber
# optik : optik
# mudah : mudah
# putus : putus
# indihome : indihome
# koneksi : koneksi
# jelek : jelek
# banget : banget
# udah : udah
# kayak : kayak
# numpang : numpang
# wifi : wifi
# tetangga : tetangga
# speed : speed
# lancar : lancar
# lokasi : lokasi
# pamekasan : pamekasan
# madura : madura
#  :
# pasang : pasang
# kecepatan : cepat
# mbps : mbps
# knp : knp
# skrg : skrg
# provider : provider
# jaringan : jaring
# lelet : lelet
# dibayar : bayar
# kek : kek
# ganti : ganti
# mahal : mahal
# jingan : jingan
# solo : solo
# lagnya : lagnya
# main : main
# cokkk : cokkk
# one : one
# jancokk : jancokk
# nggk : nggk
# ngotak : ngotak
# coba : coba
# bagusin : bagusin
# pelayanannya : layan
# iya : iya
# los : los
# mulu : mulu
# lapor : lapor
# berkali : kali
# kali : kali
# teknisi : teknisi
# dateng : dateng
# internet : internet
# doang : doang
# harganya : harga
# harga : harga
# paket : paket
# serba : serba
# gabisa : gabisa
# register : register
# login : login
# the : the
# best : best
# sinyal : sinyal
# bagus : bagus
# kadang : kadang
# kendala : kendala
# wajar : wajar
# namanya : nama
# kenap : kenap
# upgrade : upgrade
# perincian : perinci
# biayanya : biaya
# totalnya : total
# lihat : lihat
# pemakaian : pakai
# terpakai : pakai
# lemot : lot
# mbak : mbak
# mas : mas
# admin : admin
# pas : pas
# download : download
# kb : kb
# detik : detik
# mb : mb
# buka : buka
# youtube : youtube
# mohon : mohon
# bantuannya : bantu
# laporan : lapor
# komplain : komplain
# gangguan : ganggu
# kemarin : kemarin
# via : via
# apk : apk
# myindihome : myindihome
# tindak : tindak
# perhatiannya : perhati
# woy : woy
# goblog : goblog
# ccd : ccd
# berasa : asa
# merah : merah
# gitu : gitu
# mending : mending
# bizznet : bizznet
# verifikasi : verifikasi
# sms : sms
# gmn : gmn
# aplikasi : aplikasi
# payah : payah
# aplikasinya : aplikasi
# luamaaaaa : luamaaaaa
# loadingnya : loadingnya
# gadget : gadget
# email : email
# trs : trs
# dapet : dapet
# parah : parah
# bener : bener
# kecewa : kecewa
# registrasi : registrasi
# pendaftaran : daftar
# jumat : jumat
# tgl : tgl
# dijanjiin : dijanjiin
# dipasang : pasang
# sampe : sampe
# teknisinya : teknisi
# jga : jga
# kerumah : rumah
# salesnya : salesnya
# bilangnya : bilang
# libur : libur
# emng : emng
# dihari : hari
# yaa : yaa
# janjiin : janjiin
# kaya : kaya
# gini : gin
# ngecewain : ngecewain
# customer : customer
# keren : keren
# pelayanan : layan
# ditingkatkan : tingkat
# kurangi : kurang
# bulannya : bulan
# yth : yth
# karyawan : karyawan
# indi : indi
# pleaseeeeeeeee : pleaseeeeeeeee
# napa : napa
# pubg : pubg
# ngak : ngak
# matcmaking : matcmaking
# sumpah : sumpah
# mintak : mintak
# tolong : tolong
# ama : ama
# ngurus : ngurus
# tolongggg : tolongggg
# hutan : hutan
# pedalaman : dalam
# sinyalnya : sinyal
# anjg : anjg
# bayar : bayar
# perbaiki : baik
# jaringanya : jaringanya
# bayarnya : bayar
# udh : udh
# massi : massi
# ngeleg : ngeleg
# siip : siip
# telkomsel : telkomsel
# sedunia : dunia
# kuota : kuota
# indonesia : indonesia
# raya : raya
# ngapain : ngapain
# perluasan : luas
# cukz : cukz
# hoax : hoax
# komplex : komplex
# dtk : dtk
# acara : acara
# tipu : tipu
# andalin : andalin
# emosi : emosi
# trading : trading
# auto : auto
# bangkrut : bangkrut
# payaaaaaah : payaaaaaah
# mutu : mutu
# burukkkkkkk : burukkkkkkk
# penanganan : tangan
# lamaaa : lamaaa
# kota : kota
# tarakan : tara
# bikinin : bikinin
# minjem : minjem
# sebelah : belah
# oke : oke
# memuaskan : muas
# respon : respon
# cepat : cepat
# ditanggap : tanggap
# langsung : langsung
# diperogres : diperogres
# terima : terima
# kasihhh : kasihhh
# layanannya : layan
# akun : akun
# log : log
# out : out
# gbisa : gbisa
# masuk : masuk
# nomor : nomor
# sesuai : sesuai
# jaringannya : jaring
# jualitasnya : jualitasnya
# buruk : buruk
# lemotnya : lot
# ampun : ampun
# pikir : pikir
# ampas : ampas
# otaknya : otak
# im : im
# memuas : muas
# min : min
# memperbaiki : baik
# ganguan : ganguan
# sosmed : sosmed
# mobile : mobile
# legends : legends
# lag : lag
# masyaallah : masyaallah
# turet : turet
# orang : orang
# marah : marah
# baguss : baguss
# ribuan : ribu
# gua : gua
# diperbaiki : baik
# eneg : eneg
# pakai : pakai
# mendownload : mendownload
# melaporkan : lapor
# pengguna : guna
# nyaman : nyaman
# mengunakannya : mengunakannya
# error : error
# sungguh : sungguh
# versi : versi
# web : web
# mendingan : mending
# bumn : bumn
# sekelas : kelas
# telkom : telkom
# kalah : kalah
# dev : dev
# amatiran : amatir
# ramah : ramah
# mntap : mntap
# puas : puas
# mengecewakan : kecewa
# tembaga : tembaga
# ciber : ciber
# cari : cari
# kelompok : kelompok
# nambah : nambah
# susahnya : susah
# taguhan : taguhan
# jaringanmu : jaring
# benakno : benakno
# bos : bos
# pemasangan : pasang
# daftar : daftar
# love : love
# much : much
# fast : fast
# melapor : lapor
# menumpuk : tumpuk
# smpe : smpe
# kasih : kasih
# bintang : bintang
# ajaa : ajaa
# kedokan : dok
# bunder : bunder
# kabupaten : kabupaten
# indramayu : indramayu
# blum : blum
# terkana : kana
# fup : fup
# jujur : jujur
# layanan : layan
# dulunya : dulunya
# speedy : speedy
# nggak : nggak
# bedanya : beda
# mengeluhkan : keluh
# menyesuaikan : sesuai
# paketnya : paket
# kestabilan : stabil
# perubahan : ubah
# koneksinya : koneksi
# terputus : putus
# rumah : rumah
# device : device
# kantornya : kantor
# disuruh : suruh
# teross : teross
# mantap : mantap
# semangat : semangat
# kerja : kerja
# lapangan : lapang
# nyesal : nyesal
# dihati : hati
# keluhan : keluh
# sergap : sergap
# mantappppppppp : mantappppppppp
# lapet : lapet
# tukang : tukang
# servis : servis
# dibilang : bilang
# besoknya : besok
# wifinya : wifinya
# sakit : sakit
# hancurkan : hancur
# suka : suka
# iklan : iklan
# sepupu : sepupu
# jalankan : jalan
# skripsi : skripsi
# kasihan : kasihan
# wahhh : wahhh
# pelaporan : lapor
# good : good
# job : job
# terimakasih : terimakasih
# nge : nge
# game : game
# keknya : kek
# awokawok : awokawok
# wkwkwkkwkkk : wkwkwkkwkkk
# konyol : konyol
# otp : otp
# salah : salah
# nomer : nomer
# telepon : telepon
# langganan : langgan
# databasenya : databasenya
# sinkron : sinkron
# trus : trus
# musti : musti
# gimana : gimana
# eror : eror
# ngegem : ngegem
# ngelag : ngelag
# busuk : busuk
# lambat : lambat
# streaming : streaming
# online : online
# ping : ping
# sehari : hari
# pengaduan : adu
# paraaaah : paraaaah
# indihomenya : indihomenya
# gps : gps
# isi : isi
# data : data
# lengkap : lengkap
# ktp : ktp
# pop : pop
# maaf : maaf
# donk : donk
# info : info
# maksimal : maksimal
# perbulannya : bulan
# tanganin : tanganin
# kendalanya : kendala
# trimakasih : trimakasih
# applikasinya : applikasinya
# berat : berat
# tlg : tlg
# berguna : guna
# masak : masak
# cek : cek
# saingan : saing
# banwitch : banwitch
# kenceng : kenceng
# troble : troble
# kacau : kacau
# musim : musim
# hujan : hujan
# jaribgan : jaribgan
# fix : fix
# fepan : fepan
# biznet : biznet
# cuk : cuk
# udahlah : udahlah
# cape : cape
# fupnya : fupnya
# cuman : cuman
# website : website
# nunggunya : nunggunya
# ampe : ampe
# berjam : jam
# jam : jam
# kapok : kapok
# berlangganan : langgan
# lemottttt : lemottttt
# sekaliii : sekaliii
# tksi : tksi
# inovasi : inovasi
# montoon : montoon
# anying : anying
# reset : reset
# ato : ato
# kereset : kereset
# renew : renew
# tiket : tiket
# ane : ane
# konfirmasi : konfirmasi
# petugasnya : tugas
# chat : chat
# nunggu : nunggu
# make : make
# kagak : kagak
# niat : niat
# miyindihom : miyindihom
# cpet : cpet
# kerusakan : rusa
# tlp : tlp
# lanjuti : lanjut
# hri : hri
# tech : tech
# nisi : nisi
# cekatan : cekat
# trmpil : trmpil
# perusahaan : usaha
# uang : uang
# refund : refund
# blm : blm
# dikembalikan : kembali
# janji : janji
# bln : bln
# lbh : lbh
# duit : duit
# pelanggan : langgan
# telat : telat
# byr : byr
# didenda : denda
# balikin : balikin
# ayo : ayo
# tingkatin : tingkatin
# kualitasnya : kualitas
# bantu : bantu
# pelayan : layan
# ditindak : tindak
# total : total
# kash : kash
# perbulan : bulan
# detail : detail
# blank : blank
# wow : wow
# maximal : maximal
# membantu : bantu
# trouble : trouble
# tinggal : tinggal
# klik : klik
# dlm : dlm
# wktu : wktu
# maintenance : maintenance
# matap : matap
# ajh : ajh
# kesalahan : salah
# nyesel : nyesel
# indigogo : indigogo
# ulang : ulang
# masukin : masukin
# password : password
# dianggap : anggap
# pilih : pilih
# lupa : lupa
# muncul : muncul
# hang : hang
# menu : menu
# pembuatan : buat
# permudah : mudah
# ribet : ribet
# akses : akses
# suruh : suruh
# hapus : hapus
# dri : dri
# playstore : playstore
# profider : profider
# tower : tower
# restart : restart
# modemnya : modem
# stabil : stabil
# hilang : hilang
# mendadak : dadak
# sarankan : saran
# malem : malem
# gajelas : gajelas
# providernya : providernya
# pin : pin
# saldo : saldo
# ngebug : ngebug
# masal : masal
# seminggu : minggu
# tagihan : tagih
# tanggapi : tanggap
# peningkatan : tingkat
# penggunanya : guna
# astagaa : astagaa
# kondisi : kondisi
# mobalagend : mobalagend
# sebulan : bulan
# males : males
# aneh : aneh
# lalot : lalot
# hem : hem
# sll : sll
# memiliki : milik
# klau : klau
# telfon : telfon
# cmn : cmn
# menyuruh : suruh
# reload : reload
# restar : restar
# kmi : kmi
# gratisan : gratis
# blng : blng
# bkn : bkn
# kah : kah
# adminx : adminx
# dmn : dmn
# dst : dst
# periksa : periksa
# pelangggan : pelangggan
# lari : lari
# diakses : akses
# lalod : lalod
# sja : sja
# laju : laju
# buln : buln
# kmrin : kmrin
# ribu : ribu
# gblk : gblk
# facebook : facebook
# twiter : twiter
# isolir : isolir
# minggu : minggu
# giliran : gilir
# penangannya : nang
# didatangin : didatangin
# kantor : kantor
# tida : tida
# full : full
# tpi : tpi
# update : update
# relogin : relogin
# membayar : bayar
# pemberitahuan : pemberitahuan
# melewati : lewat
# perbaikannya : baik
# gaada : gaada
# kena : kena
# lgsg : lgsg
# diputus : putus
# saluran : salur
# penanganannya : tangan
# super : super
# profesionalnya : profesional
# didunia : dunia
# tagihannya : tagih
# aplikasinyaa : aplikasinyaa
# tertulisnya : tulis
# fitur : fitur
# pln : pln
# bet : bet
# msh : msh
# box : box
# penuh : penuh
# paksakan : paksa
# permintaan : minta
# tambahin : tambahin
# fasilitasnya : fasilitas
# problem : problem
# merugikan : rugi
# konsumen : konsumen
# komunikatif : komunikatif
# sisa : sisa
# perbaikan : baik
# tingkatkan : tingkat
# nama : nama
# bangsa : bangsa
# negara : negara
# dipertaruhkan : taruh
# rekrutmen : rekrutmen
# sdm : sdm
# amburadul : amburadul
# panggil : panggil
# bolak : bolak
# buang : buang
# ndak : ndak
# bentar : bentar
# solusi : solusi
# pembayaran : bayar
# kualitas : kualitas
# jaga : jaga
# kabur : kabur
# frist : frist
# media : media
# pleas : pleas
# secepatnya : cepat
# teman : teman
# memakai : pakai
# merasakan : rasa
# sya : sya
# abal : abal
# canda : canda
# nobbbb : nobbbb
# nobbbbbb : nobbbbbb
# becusss : becusss
# prh : prh
# memamg : memamg
# sod : sod
# brheti : brheti
# brlangganan : brlangganan
# addon : addon
# sulit : sulit
# cob : cob
# mudh : mudh
# dgunakan : dgunakan
# terbaca : baca
# bintag : bintag
# digubris : gubris
# tersuspende : tersuspende
# jatuh : jatuh
# tempo : tempo
# menghubungi : hubung
# call : call
# center : center
# kirim : kirim
# kerjaan : kerja
# terbengkalai : bengkalai
# ngejelasin : ngejelasin
# burukny : burukny
# massal : massal
# condet : condet
# jakarta : jakarta
# timur : timur
# klw : klw
# kasian : kasi
# dikerjain : dikerjain
# titik : titik
# lokasinya : lokasi
# jangkauan : jangkau
# paksain : paksain
# jatohnya : jatohnya
# ngerugiin : ngerugiin
# ful : ful
# asli : asli
# recomended : recomended
# taik : taik
# cuih : cuih
# siang : siang
# indibox : indibox
# intalasi : intalasi
# kog : kog
# kabel : kabel
# lan : lan
# intalasai : intalasai
# bodoh : bodoh
# infihome : infihome
# republik : republik
# first : first
# terlambat : lambat
# buoan : buoan
# cabut : cabut
# saranin : saranin
# indihom : indihom
# ditambah : tambah
# kompensasi : kompensasi
# januari : januari
# perkuat : kuat
# sampah : sampah
# org : org
# ngemis : ngemis
# performa : performa
# menurun : turun
# realita : realita
# optimalkan : optimal
# proses : proses
# gagal : gagal
# bused : bused
# wkwkw : wkwkw
# kocak : kocak
# melebihi : lebih
# batas : batas
# astaghfirullah : astaghfirullah
# dipake : dipake
# gb : gb
# habis : habis
# jangka : jangka
# masok : masok
# kenal : kenal
# sistem : sistem
# thun : thun
# langanan : langanan
# wifie : wifie
# jooos : jooos
# butuh : butuh
# rusak : rusak
# coi : coi
# cepattttt : cepattttt
# trima : trima
# beragam : agam
# chanel : chanel
# ngalah : ngalah
# in : in
# leasing : leasing
# kendaraan : kendara
# denda : denda
# barang : barang
# diblokir : blokir
# dipakai : pakai
# berjalan : jalan
# plus : plus
# mantab : mantab
# loading : loading
# dikasih : kasih
# telpon : telpon
# susah : susah
# informasi : informasi
# sangan : sangan
# dipahami : paham
# promo : promo
# tersedia : sedia
# semoga : moga
# bertambah : tambah
# inovatif : inovatif
# bermanfaat : manfaat
# gakan : gakan
# kepake : kepake
# harapan : harap
# kesel : kesel
# berulang : ulang
# conter : conter
# komplen : komplen
# tindakan : tindak
# pindah : pindah
# browsing : browsing
# lumayan : lumayan
# bermain : main
# report : report
# mesin : mesin
# itupun : itu
# tunggu : tunggu
# daring : daring
# anak : anak
# skolah : skolah
# terpaksa : paksa
# bli : bli
# gomeet : gomeet
# tutor : tutor
# mapel : mapel
# yutup : yutup
# transtv : transtv
# trans : trans
# penggunaan : guna
# nyendat : nyendat
# ngk : ngk
# alasan : alas
# petugas : tugas
# penambahan : tambah
# tiang : tiang
# dowlod : dowlod
# jdi : jdi
# ksi : ksi
# daerah : daerah
# gampang : gampang
# ditangani : tangan
# saldonya : saldo
# dimasukin : dimasukin
# melulu : melulu
# aduan : adu
# miggu : miggu
# belom : bom
# istimewa : istimewa
# sekai : seka
# ulasan : ulas
# menilainya : nila
# belajar : ajar
# ppj : ppj
# aman : aman
# hiburan : hibur
# you : you
# tube : tube
# jalan : jalan
# louding : louding
# nti : nti
# selesai : selesai
# bikinapps : bikinapps
# ringan : ringan
# nyusahin : nyusahin
# kalomo : kalomo
# ngaduh : ngaduh
# jqman : jqman
# beres : beres
# bonus : bonus
# gratis : gratis
# biaya : biaya
# nanya : nanya
# dirumah : rumah
# sekalinya : sekali
# kadaluarsa : kadaluarsa
# skrng : skrng
# kejelasan : jelas
# gunain : gunain
# huuhh : huuhh
# seandainya : anda
# mpe : mpe
# deposit : deposit
# kunjung : kunjung
# amanah : amanah
# diturunin : diturunin
# pdhl : pdhl
# bru : bru
# hr : hr
# tanggepannya : tanggepannya
# gtu : gtu
# gausah : gausah
# hahanjing : hahanjing
# multifungsi : multifungsi
# signal : signal
# down : down
# sebangai : bangai
# penyedia : sedia
# kuat : kuat
# pemakaiyan : pemakaiyan
# rumahan : rumah
# bangett : bangett
# sumpahh : sumpahh
# kbs : kbs
# toling : toling
# stabilan : stabil
# hubungan : hubung
# team : team
# robot : robot
# ditanggapi : tanggap
# jan : jan
# fungsi : fungsi
# tes : tes
# gilaaaaaaa : gilaaaaaaa
# rutin : rutin
# barter : barter
# daun : daun
# buffering : buffering
# ber : ber
# makan : makan
# orng : orng
# boss : boss
# situ : situ
# bobrok : bobrok
# sebobrok : bobrok
# pengurusan : urus
# bualan : bual
# apes : apes
# niehhhh : niehhhh
# ngelek : ngelek
# sma : sma
# kmren : kmren
# menawarkan : tawar
# cepet : cepet
# mlah : mlah
# mlu : mlu
# seh : seh
# neh : neh
# tanggal : tanggal
# add : add
# disney : disney
# hotstar : hotstar
# dipotong : potong
# normal : normal
# indikon : indikon
# mental : mental
# gegara : gegara
# emg : emg
# dipakein : dipakein
# nyentuh : nyentuh
# blom : blom
# cabang : cabang
# lambatt : lambatt
# diputuskan : putus
# mengeluh : keluh
# estimasi : estimasi
# repair : repair
# ter : ter
# frezee : frezee
# uqng : uqng
# jaminan : jamin
# pasau : pasau
# blan : blan
# dlu : dlu
# rb : rb
# tunggakan : tunggak
# cman : cman
# biat : biat
# tetep : tetep
# diganti : ganti
# seluler : seluler
# menjamin : jamin
# mengakses : akses
# kemudahan : mudah
# idiot : idiot
# verification : verification
# siii : siii
# rekomendasikan : rekomendasi
# bangga : bangga
# ajak : ajak
# loginya : log
# dibuka : buka
# tercatat : catat
# terdaftar : daftar
# bersinar : sinar
# tanggap : tanggap
# bertemu : temu
# tele : tele
# tambh : tambh
# kesana : kesana
# jaringanny : jaringanny
# ngegame : ngegame
# lola : lola
# ubah : ubah
# bnyak : bnyak
# mengecek : ecek
# pokonya : poko
# bingung : bingung
# mendeskripsikan : deskripsi
# mah : mah
# konek : konek
# terkonek : terkonek
# parahh : parahh
# gerak : gerak
# mengatasinya : atas
# ditelpon : telpon
# santai : santai
# gue : gue
# masang : masang
# maenin : maenin
# nyalahin : nyalahin
# matiin : matiin
# bosen : bosen
# status : status
# murah : murah
# lohh : lohh
# lucu : lucu
# berattt : berattt
# lemootttt : lemootttt
# ehh : ehh
# terisolir : isolir
# seyelah : seyelah
# buffer : buffer
# mnding : mnding
# mohob : mohob
# kepuasan : puas
# sesua : sua
# dngan : dngan
# labil : labil
# mencari : cari
# dapatx : dapatx
# dilaporkan : lapor
# berselang : selang
# hadeeeh : hadeeeh
# seharian : hari
# kukasih : kasih
# app : app
# payahnya : payah
# pelayananya : pelayananya
# tolonglaaah : tolonglaaah
# normalin : normalin
# doong : doong
# sepid : sepid
# jawabannya : jawab
# aktif : aktif
# bufering : bufering
# dunia : dunia
# nyata : nyata
# slow : slow
# blg : blg
# terussssss : terussssss
# sgt : sgt
# recommended : recommended
# menang : menang
# gara : gara
# jing : jing
# dsini : dsini
# timika : timika
# tegang : tegang
# dear : dear
# memasang : pasang
# kelanjutannya : lanjut
# yes : yes
# mawon : mawon
# pesen : sen
# kabar : kabar
# hubungi : hubung
# tanggung : tanggung
# mati : mati
# pemerasan : peras
# haduhh : haduhh
# indihomo : indihomo
# terburuk : buruk
# menyesal : sesal
# terwakilkan : wakil
# rate : rate
# tlfn : tlfn
# merespon : merespon
# ttg : ttg
# tanggapan : tanggap
# infokan : info
# krg : krg
# sepuluh : puluh
# tehnisinya : tehnisinya
# sdg : sdg
# pengerjaan : kerja
# sales : sales
# menempati : tempat
# lgi : lgi
# rekomendasikn : rekomendasikn
# mantaf : mantaf
# peaaaaa : peaaaaa
# seamless : seamless
# karna : karna
# pelayann : pelayann
# bugfix : bugfix
# diaplikasi : aplikasi
# logout : logout
# piye : piye
# developernya : developer
# tanks : tanks
# gaje : gaje
# lol : lol
# berlanggnan : berlanggnan
# odp : odp
# otak : otak
# atik : atik
# kasi : kasi
# terusan : terus
# smpah : smpah
# laen : laen
# router : router
# remote : remote
# terbilang : bilang
# konsisten : konsisten
# sukses : sukses
# indyhome : indyhome
# cerita : cerita
# november : november
# sblm : sblm
# canter : canter
# desember : desember
# ngajuin : ngajuin
# perpindahan : pindah
# grtis : grtis
# smnggu : smnggu
# diemin : diemin
# akhr : akhr
# bsa : bsa
# ydh : ydh
# diem : diem
# gila : gila
# stiap : stiap
# bagt : bagt
# kecewakan : kecewa
# brapa : brapa
# setahun : tahun
# tel : tel
# castamer : castamer
# enggk : enggk
# mita : mita
# yng : yng
# hubung : hubung
# susaaaahhhhhhhhhh : susaaaahhhhhhhhhh
# kode : kode
# terkirim : kirim
# anehhhhhhhhh : anehhhhhhhhh
# ngadu : ngadu
# yaelahh : yaelahh
# gan : gan
# nmor : nmor
# sudh : sudh
# sibuk : sibuk
# prioritaskan : prioritas
# renewspeed : renewspeed
# naungan : naung
# turunkan : turun
# dibenahi : benah
# tanggungan : tanggung
# responnya : responnya
# follow : follow
# twitter : twitter
# messenger : messenger
# kelanjutan : lanjut
# pegawai : pegawai
# lepas : lepas
# dimainin : dimainin
# kerjakan : kerja
# malu : malu
# kinerja : kerja
# profesional : profesional
# zaman : zaman
# teknis : teknis
# moga : moga
# amin : amin
# penangan : nang
# gimna : gimna
# berhenti : henti
# losestreak : losestreak
# maen : maen
# rank : rank
# terbaik : baik
# diperbaharui : baharu
# gilaaaaa : gilaaaaa
# lemotnyaaa : lemotnyaaa
# ampuuunnn : ampuuunnn
# buangeett : buangeett
# istana : istana
# kepresidenan : presiden
# appnya : appnya
# menarik : tarik
# kelewatan : lewat
# sumpaah : sumpaah
# burik : burik
# pke : pke
# takut : takut
# masuknya : masuk
# aktifin : aktifin
# android : android
# nelfon : nelfon
# krna : krna
# bayat : bayat
# arahan : arah
# bantuan : bantu
# sempurna : sempurna
# sbagian : sbagian
# kbaca : kbaca
# kluar : kluar
# sndiri : sndiri
# lgsung : lgsung
# dtonton : dtonton
# skarang : skarang
# jua : jua
# akunnya : akun
# mlh : mlh
# patah : patah
# sihh : sihh
# berlanggan : langgan
# perangkat : perangkat
# bekas : bekas
# bulukan : bulu
# antena : antena
# alhasil : alhasil
# menunggu : tunggu
# ssid : ssid
# hidup : hidup
# sambut : sambut
# mesra : mesra
# sekian : sekian
# untuuuk : untuuuk
# kedatangan : datang
# dataaaanglaaahh : dataaaanglaaahh
# kuu : kuu
# mengaaniiisss : mengaaniiisss
# membayangkan : bayang
# betapa : betapa
# ngerti : ngerti
# donlow : donlow
# pengen : ken
# lht : lht
# nonton : nonton
# lwt : lwt
# batalin : batalin
# regestrasinya : regestrasinya
# sla : sla
# dehh : dehh
# ngga : ngga
# kesini : kesini
# kelantai : lantai
# terkoneksi : koneksi
# dibawah : bawah
# dilantai : lantai
# lantai : lantai
# mantep : mantep
# pagi : pagi
# sore : sore
# merahnya : merah
# memadai : pada
# king : king
# home : home
# solved : solved
# adeh : adeh
# bekasi : bekas
# turun : turun
# diperhatikan : perhati
# workspace : workspace
# dikosan : dikosan
# diperlambat : lambat
# alasannya : alas
# aktivasi : aktivasi
# oknum : oknum
# tunai : tunai
# dilapang : lapang
# bad : bad
# attitude : attitude
# and : and
# sop : sop
# sangatt : sangatt
# bugs : bugs
# knnntl : knnntl
# loging : loging
# abad : abad
# loding : loding
# muluu : muluu
# mantappppppooooolllll : mantappppppooooolllll
# after : after
# service : service
# mnt : mnt
# dtg : dtg
# hrg : hrg
# deh : deh
# dimengerti : erti
# ngeluh : ngeluh
# zhonk : zhonk
# tutup : tutup
# kalok : kalok
# provaider : provaider
# kak : kak
# foto : foto
# identitas : identitas
# mencoba : coba
# dibantu : bantu
# contoh : contoh
# sayang : sayang
# instalasi : instalasi
# diluar : luar
# putuuuss : putuuuss
# ditempat : tempat
# koment : koment
# keluhannya : keluh
# bagusss : bagusss
# cuekin : cuekin
# inter : inter
# massa : massa
# pertanggung : tanggung
# kentot : kentot
# babi : babi
# nurunin : nurunin
# daya : daya
# neraka : neraka
# aminn : aminn
# abis : abis
# dompet : dompet
# dipilih : pilih
# link : link
# bank : bank
# level : level
# penurun : turun
# mmr : mmr
# taaiiik : taaiiik
# urusan : urus
# satupun : satu
# ketemu : ketemu
# menolak : tolak
# menangani : tangan
# sehat : sehat
# telponnya : telpon
# macet : macet
# pengaduannya : adu
# kmna : kmna
# berkala : kala
# kosumen : kosumen
# skali : skali
# halo : halo
# sengaja : sengaja
# ketutup : tutup
# dikata : kata
# nomornya : nomor
# diverifikasi : verifikasi
# struk : struk
# haloooo : haloooo
# lho : lho
# mabok : mabok
# balasan : balas
# dihubungi : hubung
# ngasi : ngasi
# mengirim : kirim
# berisi : isi
# dihilangkan : hilang
# waras : waras
# developer : developer
# diksih : diksih
# sbntar : sbntar
# angka : angka
# penjelasan : jelas
# useetv : useetv
# indhome : indhome
# channel : channel
# tampil : tampil
# connect : connect
# lapornya : lapor
# koneknya : koneknya
# operatornya : operator
# terprogram : program
# posisi : posisi
# hbngi : hbngi
# selesnya : les
# netizen : netizen
# smart : smart
# mengalami : alami
# penyesalan : sesal
# pencabutan : cabut
# skdar : skdar
# masukan : masuk
# alias : alias
# kontrkan : kontrkan
# gamer : gamer
# kemaren : kemaren
# selamat : selamat
# menikmati : nikmat
# kesal : kesal
# perjanjian : janji
# melonjak : lonjak
# heran : heran
# kenak : nak
# logika : logika
# dikit : dikit
# knapa : knapa
# mesti : mesti
# kenakan : kena
# akal : akal
# kyk : kyk
# pertimbangkan : timbang
# kekurangannya : kurang
# loss : loss
# cocok : cocok
# diinstal : diinstal
# ujung : ujung
# nlpn : nlpn
# ush : ush
# fungsinya : fungsi
# menghabiskan : habis
# slot : slot
# memori : memori
# canggih : canggih
# starup : starup
# swasta : swasta
# kerjanya : kerja
# minim : minim
# manfaat : manfaat
# apps : apps
# pembayarannya : bayar
# kuno : kuno
# mbanking : mbanking
# liat : liat
# rincian : rincian
# diklik : klik
# isinya : isi
# bego : bego
# perkembangan : kembang
# goreng : goreng
# patut : patut
# urg : urg
# rek : rek
# sapoe : sapoe
# cenah : cenah
# wawadukan : wawadukan
# skg : skg
# munculin : munculin
# byk : byk
# doubel : doubel
# sptny : sptny
# designer : designer
# inspiratif : inspiratif
# design : design
# smp : smp
# notifikasi : notifikasi
# untung : untung
# responsive : responsive
# lakukan : laku
# bnyk : bnyk
# pembenahan : benah
# terpasang : pasang
# pandemi : pandemi
# dijadikan : jadi
# panduan : pandu
# ngirimin : ngirimin
# hade : hade
# lier : lier
# sia : sia
# dll : dll
# wifix : wifix
# kepercayaan : percaya
# alhamdulillah : alhamdulillah
# teratasi : atas
# sambungan : sambung
# valid : valid
# trhubung : trhubung
# pengecekan : kece
# hai : hai
# indiehome : indiehome
# indira : indira
# gambar : gambar
# screenshoot : screenshoot
# dminta : dminta
# mgirimkan : mgirimkan
# pdahal : pdahal
# nominal : nominal
# stelah : stelah
# konfirm : konfirm
# mmerlukan : mmerlukan
# mguras : mguras
# menguras : uras
# esmosi : esmosi
# progres : progres
# keuntungan : untung
# dibutuhkan : butuh
# pembelajaran : ajar
# ksih : ksih
# riwayat : riwayat
# detailnya : detail
# sewa : sewa
# modem : modem
# ppn : ppn
# kenaikan : naik
# dipersulit : sulit
# antrinya : antri
# direspon : direspon
# mentang : mentang
# dibenerin : dibenerin
# tips : tips
# menjengkelkan : jengkel
# ngurusin : ngurusin
# ginian : ginian
# ilang : ilang
# lemotlah : lot
# woi : woi
# kemana : mana
# poin : poin
# nol : nol
# pertamanya : pertama
# xxx : xxx
# ngumpulin : ngumpulin
# mbaknya : mbak
# jaya : jaya
# saran : saran
# mengajukan : aju
# progress : progress
# plaza : plaza
# pokoknya : pokok
# boong : boong
# palpalepalpale : palpalepalpale
# pale : pale
# pal : pal
# paleeeeepapibo : paleeeeepapibo
# pipabo : pipabo
# oooooooooooo : oooooooooooo
# eeeeee : eeeeee
# papibo : papibo
# suddah : suddah
# telfo : telfo
# ddisuruh : ddisuruh
# kartu : kartu
# akui : aku
# ketidaknyamanannya : ketidaknyamanannya
# meengatasi : meengatasi
# pergeeerakan : pergeeerakan
# telefon : telefon
# ibuku : ibu
# daringku : daringku
# berantakan : beranta
# telp : telp
# kebanyakan : banyak
# ngomongnya : ngomongnya
# penjawab : jawab
# pulsa : pulsa
# mubazir : mubazir
# woeyy : woeyy
# uda : uda
# lemotnyaa : lemotnyaa
# duh : duh
# sekolah : sekolah
# kerjaa : kerjaa
# sbelumnya : sbelumnya
# jelasin : jelasin
# prnah : prnah
# lwat : lwat
# imel : imel
# rp : rp
# teliti : teliti
# kepuasannya : puas
# ayolah : ayo
# dikontrol : kontrol
# takutnya : takut
# gatau : gatau
# limitnya : limit
# please : please
# dota : dota
# hadehh : hadehh
# promosi : promosi
# jor : jor
# joran : joran
# disaat : saat
# bermasalah : masalah
# kejadian : jadi
# repot : repot
# enak : enak
# amplikasi : amplikasi
# tahuan : tahu
# pwmbayaran : pwmbayaran
# mutasi : mutasi
# lucunya : lucu
# duluan : duluan
# diaktifkan : aktif
# ketakutan : takut
# bertahun : tahun
# haribyang : haribyang
# penbahan : penbahan
# amininuntuk : amininuntuk
# menanmbah : menanmbah
# sorry : sorry
# say : say
# opsi : opsi
# credit : credit
# card : card
# banking : banking
# packet : packet
# losss : losss
# client : client
# buuug : buuug
# teroooos : teroooos
# lemooot : lemooot
# terooooooosss : terooooooosss
# lost : lost
# teroooooooos : teroooooooos
# bug : bug
# point : point
# kaka : kaka
# kirimkan : kirim
# dilampirkan : lampir
# bukti : bukti
# lunas : lunas
# format : format
# layaknya : layak
# emang : emang
# bngt : bngt
# pasrah : pasrah
# dahlah : dah
# capek : capek
# wib : wib
# bae : bae
# sinyla : sinyla
# gem : gem
# mobail : mobail
# legen : legen
# setabil : setabil
# pemasanganya : pemasanganya
# kalu : kalu
# mines : mes
# dimana : mana
# beli : beli
# maksimalkan : maksimal
# taiik : taiik
# snyaall : snyaall
# sangattttttttt : sangattttttttt
# tidaaaaaaakk : tidaaaaaaakk
# puaaaaaaasdssssssssss : puaaaaaaasdssssssssss
# mahall : mahall
# sinyaall : sinyaall
# bosooookkk : bosooookkk
# unggah : unggah
# vidio : vidio
# pemelirahaan : pemelirahaan
# apapun : apa
# terkait : kait
# menyempurnskan : menyempurnskan
# ahir : ahir
# onn : onn
# kenyamanan : nyaman
# berilah : ilah
# mksh : mksh
# ngen : ngen
# bulanan : bulan
# berubah : ubah
# meresahkan : resah
# inihome : inihome
# hangus : hangus
# mlulu : mlulu
# memperpanjang : panjang
# indohome : indohome
# mantol : mantol
# mudahan : mudah
# responsif : responsif
# sebatas : batas
# lemottt : lemottt
# ujan : ujan
# waifi : waifi
# baiki : baik
# wakilkan : wakil
# temen : temen
# rating : rating
# terkadang : terkadang
# anggota : anggota
# keluarga : keluarga
# terimksh : terimksh
# alhamdullillah : alhamdullillah
# iyan : iyan
# sayansydah : sayansydah
# amil : amil
# bit : bit
# penangannan : penangannan
# ngentod : ngentod
# luntur : luntur
# melayani : layan
# terbaiknya : baik
# nambahin : nambahin
# plasa : plasa
# bisnis : bisnis
# perusahaannya : usaha
# komen : komen
# bertobatlah : tobat
# serasa : serasa
# prosesnya : proses
# dipusatnya : pusat
# jalur : jalur
# nyambung : nyambung
# bbrp : bbrp
# kerasa : rasa
# mahalnya : mahal
# area : area
# pasarkemis : pasarkemis
# tangerang : tangerang
# angkasa : angkasa
# pasangan : pasang
# berbohong : bohong
# marketing : marketing
# kabelnya : kabel
# kuranglah : kurang
# siapkan : siap
# material : material
# detect : detect
# susahnua : susahnua
# bal : bal
# keterangan : terang
# naikin : naikin
# recomend : recomend
# paswat : paswat
# gaji : gaji
# buta : buta
# indihomeku : indihomeku
# tanda : tanda
# kecover : kecover
# dikos : dikos
# kuliah : kuliah
# bali : bal
# gilaaaaaaaaaaa : gilaaaaaaaaaaa
# jarang : jarang
# suu : suu
# isp : isp
# laennya : laennya
# sabtu : sabtu
# topik : topik
# dipesan : pes
# hallo : hallo
# prosedur : prosedur
# membutuhkan : butuh
# tangani : tangan
# semaksimal : maksimal
# engga : engga
# mahalin : mahalin
# bagusan : bagus
# use : use
# parahnya : parah
# mps : mps
# parahhh : parahhh
# telegram : telegram
# batesin : batesin
# binggung : binggung
# percumah : percumah
# makasih : makasih
# clear : clear
# stable : stable
# public : public
# releease : releease
# pemerintah : perintah
# kekurangan : kurang
# programmer : programmer
# prihatin : prihatin
# papua : papua
# harap : harap
# antusias : antusias
# memperluas : luas
# radius : radius
# perhatikan : perhati
# kelayakan : layak
# peminat : minat
# yogya : yogya
# ajg : ajg
# bdo : bdo
# dijanjikan : janji
# downgrade : downgrade
# play : play
# only : only
# jringnnya : jringnnya
# dahla : dahla
# bangkek : bangkek
# ampir : ampir
# install : install
# mayan : mayan
# gambarnya : gambar
# tulisan : tulis
# klu : klu
# mubasir : mubasir
# user : user
# gmana : gmana
# pingnya : pingnya
# very : very
# nice : nice
# woyyy : woyyy
# napaaaaa : napaaaaa
# gapernah : gapernah
# ngerasa : ngerasa
# trussss : trussss
# bgsd : bgsd
# sllu : sllu
# dtng : dtng
# penagihan : tagih
# hrs : hrs
# tnggu : tnggu
# astaga : astaga
# pelayannya : layan
# operator : operator
# laporkan : lapor
# kecamatan : camat
# dilayani : layan
# selayaknya : layak
# tolak : tolak
# keperluan : perlu
# pambayaran : pambayaran
# kumplit : kumplit
# apn : apn
# sljj : sljj
# perlihatkan : lihat
# dipakek : dipakek
# keringanan : ringan
# bayarannya : bayar
# pakek : pakek
# ketulungan : ketulungan
# rajin : rajin
# pkek : pkek
# nilai : nilai
# membuang : buang
# pengalaman : alam
# slalu : slalu
# ahh : ahh
# sabodo : sabodo
# teuing : teuing
# malas : malas
# perkara : perkara
# wilayah : wilayah
# aekali : aekali
# saking : saking
# leletnyaaaaaa : leletnyaaaaaa
# not : not
# ngelah : ngelah
# tua : tua
# beliin : beliin
# trobel : trobel
# laporannya : lapor
# beralasan : alas
# dibilangnya : bilang
# penuhi : penuh
# kewajiban : wajib
# berhak : hak
# menuntut : tuntut
# hak : hak
# apknya : apknya
# dikirain : dikirain
# taunya : tau
# costumer : costumer
# pelengkap : lengkap
# komunikasi : komunikasi
# maju : maju
# kecepatanny : kecepatanny
# mlbb : mlbb
# tekadang : tekadang
# delay : delay
# lancarnya : lancar
# malam : malam
# menit : menit
# paginya : pagi
# lapangannya : lapang
# pemasangannya : pasang
# produknya : produk
# paham : paham
# bahasa : bahasa
# remot : remot
# huruf : huruf
# ditombol : tombol
# baterai : baterai
# bodohnya : bodoh
# diatas : atas
# ms : ms
# lemotttt : lemotttt
# boskuhh : boskuhh
# ulimited : ulimited
# masi : mas
# quotanya : quotanya
# iki : iki
# unlimited : unlimited
# beneran : beneran
# crash : crash
# pelangan : pelang
# nilainya : nilai
# ngantri : ngantri
# indita : indita
# kau : kau
# mengatasi : atas
# kesulitan : sulit
# pertahankan : tahan
# harinya : hari
# terhubung : hubung
# keinternet : keinternet
# siangnya : siang
# gunanya : guna
# keong : keong
# nyala : nyala
# errornya : errornya
# asw : asw
# cok : cok
# ajah : ajah
# menanggapi : tanggap
# menindaklanjuti : menindaklanjuti
# kecuali : kecuali
# pemberhentian : henti
# rahasia : rahasia
# dicoba : coba
# bosan : bosan
# menerima : terima
# verifikasinya : verifikasi
# disambungkan : sambung
# datanya : data
# berbeda : beda
# verfikasi : verfikasi
# dikirimkan : kirim
# inbox : inbox
# menggunkan : gun
# tros : tros
# otpnya : otpnya
# ngirim : ngirim
# awalpun : awal
# verif : verif
# dikirim : kirim
# bosss : bosss
# lahh : lahh
# fixinggggggg : fixinggggggg
# tooson : tooson
# tosooon : tosooon
# alat : alat
# alamat : alamat
# setia : setia
# berkualitas : kualitas
# kedepannya : depan
# menambah : tambah
# penguat : kuat
# matuuul : matuuul
# sumpeh : sumpeh
# lampu : lampu
# indikator : indikator
# mohoh : mohoh
# maki : maki
# ntr : ntr
# pasal : pasal
# penghinaan : hina
# dech : dech
# dilunasin : dilunasin
# laggggg : laggggg
# inet : inet
# njelimet : njelimet
# lemottttttt : lemottttttt
# mgkn : mgkn
# topang : topang
# beda : beda
# benahi : benah
# hmm : hmm
# timbul : timbul
# biarpun : biarpun
# solusinya : solusi
# hjelas : hjelas
# cupu : cupu
# tdak : tdak
# timbal : timbal
# baliknya : balik
# seimbang : imbang
# responds : responds
# people : people
# division : division
# change : change
# star : star
# thanks : thanks
# frely : frely
# instaler : instaler
# sorong : sorong
# have : have
# great : great
# day : day
# god : god
# bless : bless
# regard : regard
# stv : stv
# ali : ali
# berbulan : bulan
# layani : layan
# ngecek : ngecek
# praktis : praktis
# redeem : redeem
# merchantnya : merchantnya
# dahh : dahh
# kuingin : ingin
# bgini : bgini
# rugii : rugi
# security : security
# haraga : haraga
# wuissss : wuissss
# klomang : klomang
# narik : narik
# grobak : grobak
# sebanding : banding
# lmao : lmao
# mantaab : mantaab
# apgrade : apgrade
# dijaringan : jaring
# tsb : tsb
# ttp : ttp
# memanjakan : manja
# mimpi : mimpi
# belaka : belaka
# semenjak : semenjak
# speednya : speednya
# whatsapp : whatsapp
# yutub : yutub
# bufer : bufer
# prnh : prnh
# kawat : kawat
# penyangganya : sangga
# optiknya : optik
# tumpuan : tumpu
# disambung : sambung
# fibernya : fiber
# kermh : kermh
# tnp : tnp
# menahan : tahan
# beban : beban
# upload : upload
# wfh : wfh
# tersendat : sendat
# sebnarnya : sebnarnya
# mempercepat : cepat
# ngasih : ngasih
# membatu : batu
# bar : bar
# desa : desa
# ditukar : tukar
# coneck : coneck
# speaker : speaker
# drop : drop
# doank : doank
# tolonglah : tolong
# telekomunikasi : telekomunikasi
# pantau : pantau
# intetnetnya : intetnetnya
# tacmbah : tacmbah
# molatv : molatv
# hasilnya : hasil
# gembel : gembel
# layananya : layananya
# aktifitas : aktifitas
# layar : layar
# putih : putih
# far : far
# telkomnya : telkomnya
# tmpt : tmpt
# pengurus : urus
# pemberian : beri
# arahannya : arah
# pergantian : ganti
# terdekat : dekat
# sekarangpun : sekarang
# becus : becus
# diurusnya : urus
# balas : balas
# pengeluaran : keluar
# slj : slj
# iuran : iur
# penasaran : penasaran
# ktnya : ktnya
# dikenal : kenal
# system : system
# edan : edan
# milik : milik
# time : time
# kesiniin : kesiniin
# hancur : hancur
# pemain : main
# lebur : lebur
# dijam : jam
# gabaik : gabaik
# pelayananmu : layan
# menyetujui : tuju
# tlpon : tlpon
# tambahan : tambah
# butu : butu
# ngomong : ngomong
# cuy : cuy
# terbaru : baru
# minipack : minipack
# pemindahan : pindah
# bangunan : bangun
# meter : meter
# dimintakan : minta
# kepetugasnya : tugas
# free : free
# prosesnyaa : prosesnyaa
# mendaftar : daftar
# keburu : keburu
# ngeblank : ngeblank
# benerinya : benerinya
# lamaa : lamaa
# memudahkan : mudah
# billing : billing
# lonjakan : lonjak
# pilihan : pilih
# wallpaper : wallpaper
# dapatnya : dapat
# ngantuk : ngantuk
# pengajuan : aju
# pda : pda
# kebagian : bagi
# pusat : pusat
# pkerjaan : pkerjaan
# terpending : pending
# fixing : fixing
# penggunaannya : guna
# indihone : indihone
# anjimmmmmm : anjimmmmmm
# ngilang : ngilang
# aing : aing
# turnamen : turnamen
# anjim : anjim
# asuuuue : asuuuue
# agus : agus
# ktanya : ktanya
# maksudnya : maksud
# bgmn : bgmn
# komplainan : komplain
# kebuka : buka
# lamaaaaaaaaaaa : lamaaaaaaaaaaa
# bgd : bgd
# berhasil : hasil
# nob : nob
# serius : serius
# valorant : valorant
# katain : katain
# noob : noob
# dilalukan : lalu
# gedeg : gedeg
# indihomne : indihomne
# estimasinya : estimasi
# mundur : mundur
# diusahakan : usaha
# block : block
# kompain : kompain
# sayajuga : sayajuga
# complain : complain
# ngelawak : ngelawak
# depkolektor : depkolektor
# quota : quota
# berfungsi : fungsi
# tersambung : sambung
# pegawainya : pegawai
# penggan : penggan
# zzzzzzz : zzzzzzz
# mempersulit : sulit
# kerjaannya : kerja
# menagih : tagih
# kontak : kontak
# menggantung : gantung
# skrang : skrang
# nghbngi : nghbngi
# kblkang : kblkang
# skrranf : skrranf
# duhh : duhh
# perampokan : ampo
# kebijakan : bijak
# menipu : tipu
# tolol : tolol
# gadapet : gadapet
# mantapp : mantapp
# senenh : senenh
# manteb : manteb
# nik : nik
# fiturnya : fiturnya
# gunainnya : gunainnya
# menyebalkan : sebal
# datangnya : datang
# nominalnya : nominal
# rekom : rekom
# andalkan : andal
# akurat : akurat
# blenk : blenk
# dancokk : dancokk
# taekkk : taekkk
# gamau : gamau
# taekk : taekk
# bayr : bayr
# servise : servise
# parahhhhhh : parahhhhhh
# nyari : nyari
# manis : manis
# mulut : mulut
# smua : smua
# gmna : gmna
# pdhal : pdhal
# ready : ready
# dpn : dpn
# komplek : komplek
# mobil : mobil
# pakainya : pakai
# harian : hari
# ceritanya : cerita
# istirahat : istirahat
# diwarkop : diwarkop
# warkop : warkop
# mhn : mhn
# tampilan : tampil
# perbai : perbai
# bugnya : bugnya
# kebaca : baca
# daftarkan : daftar
# disinkronkan : sinkron
# ternya : ter
# kotak : kotak
# hitamnya : hitam
# kayaknya : kayak
# bengkulu : bengkulu
# kalaubada : kalaubada
# pemberitahuaanya : pemberitahuaanya
# sipppp : sipppp
# terusss : terusss
# gngguan : gngguan
# berbelit : belit
# mutiaranya : mutiara
# okkk : okkk
# deposito : deposito
# cair : cair
# ngapa : ngapa
# gercep : gercep
# berharap : harap
# aje : aje
# bahagia : bahagia
# slotnya : slotnya
# yaudah : yaudah
# cancel : cancel
# duitnya : duit
# kaga : kaga
# bujug : bujug
# ngelucu : ngelucu
# wkwkland : wkwkland
# berhari : hari
# sangaat : sangaat
# mantaaap : mantaaap
# tlf : tlf
# pelunasan : lunas
# selesaikan : selesai
# kembalikan : kembali
# krja : krja
# transfer : transfer
# brp : brp
# limit : limit
# paras : paras
# wetan : wetan
# utara : utara
# tegal : tegal
# siwalan : siwalan
# bangun : bangun
# soalx : soalx
# diselesaikan : selesai
# berak : berak
# gilirahan : gilirahan
# melempem : melempem
# ambil : ambil
# beritahukan : beritahukan
# pemakayan : pemakayan
# stb : stb
# zte : zte
# utama : utama
# menonton : tonton
# demand : demand
# direstart : direstart
# refresh : refresh
# hubungin : hubungin
# cache : cache
# uninstal : uninstal
# stupid : stupid
# nmr : nmr
# minn : minn
# disediakan : sedia
# tivi : tivi
# ntah : ntah
# naiknya : naik
# perkabelan : kabel
# pertahanin : pertahanin
# uangnya : uang
# guys : guys
# kerena : rena
# sinya : sinya
# ngab : ngab
# jelak : jelak
# kenpa : kenpa
# punxa : punxa
# nyampe : nyampe
# diupdate : diupdate
# size : size
# spek : spek
# rendah : rendah
# ram : ram
# membuka : buka
# ckp : ckp
# datng : datng
# hub : hub
# irmel : irmel
# smkn : smkn
# mantul : mantul
# kecepatannya : cepat
# siput : siput
# perbaikannn : perbaikannn
# belakanga : belakanga
# username : username
# pasword : pasword
# digunain : digunain
# heh : heh
# bijak : bijak
# menerus : terus
# angkat : angkat
# rugi : rugi
# edit : edit
# plg : plg
# tag : tag
# xxxxxxxxxx : xxxxxxxxxx
# seb : seb
# kredit : kredit
# tks : tks
# lelah : lelah
# bambang : bambang
# terkendala : kendala
# dimna : dimna
# kontrak : kontrak
# antrian : antri
# mampus : mampus
# janjian : janji
# sempet : sempet
# ditinggal : tinggal
# tidur : tidur
# teras : teras
# gada : gada
# training : training
# benerlah : benerlah
# karyawannya : karyawannya
# mesan : mesan
# maret : maret
# redaman : redam
# surat : surat
# september : september
# akali : akal
# denga : denga
# rokok : rokok
# toleransi : toleransi
# pekerja : kerja
# memilik : milik
# profesionalitas : profesionalitas
# bagua : bagua
# dual : dual
# tripple : tripple
# off : off
# mdh : mdh
# menyaingi : saing
# pelanggannya : langgan
# ajalah : aja
# its : its
# senin : senin
# ngambil : ngambil
# anjer : anjer
# seenak : enak
# melambat : lambat
# sangaaatt : sangaaatt
# membantuuu : membantuuu
# munculkan : muncul
# google : google
# prime : prime
# amazon : amazon
# codm : codm
# imbas : imbas
# seneng : neng
# tingkat : tingkat
# nye : nye
# mentok : mentok
# udeh : udeh
# gede : gede
# debat : debat
# beta : beta
# betenya : betenya
# keduhung : keduhung
# ribetnya : ribetnya
# lengket : lengket
# bergerak : gerak
# tarik : tarik
# open : open
# engineer : engineer
# dipermainin : dipermainin
# nembak : nembak
# gooood : gooood
# beranda : beranda
# uninstall : uninstall
# berlaku : laku
# myindihom : myindihom
# linkaja : linkaja
# berkurang : kurang
# kalinya : kali
# lantas : lantas
# hilangnya : hilang
# payaaah : payaaah
# ads : ads
# tertulis : tulis
# memsang : memsang
# pemasang : pasang
# pindahin : pindahin
# mengejar : kejar
# better : better
# pertamakali : pertamakali
# dijalankan : jalan
# freezing : freezing
# heng : heng
# terbuka : buka
# peraturannya : atur
# bgtu : bgtu
# pinalti : pinalti
# juta : juta
# minimal : minimal
# prima : prima
# benci : benci
# sepadan : padan
# ahirnya : ahirnya
# bengkak : bengkak
# items : items
# for : for
# peoples : peoples
# rupiah : rupiah
# gratisssss : gratisssss
# pungli : pungli
# sony : sony
# xz : xz
# ngeblang : ngeblang
# kupon : kupon
# undian : undi
# kepentingan : penting
# bnget : bnget
# materai : materai
# disembunyikan : sembunyi
# naek : naek
# bukanya : buka
# lagy : lagy
# lembaga : lembaga
# perlukan : perlu
# pendidik : didik
# memperlancar : lancar
# sintem : sintem
# didik : didik
# covid : covid
# protes : protes
# gda : gda
# terhapus : hapus
# berjuta : juta
# memasukan : pasu
# bacot : bacot
# amburadulll : amburadulll
# pesan : pesan
# giga : giga
# tukar : tukar
# tangung : tangung
# selular : selular
# komplit : komplit
# risih : risih
# wajib : wajib
# hmmmmmmm : hmmmmmmm
# psswd : psswd
# pwd : pwd
# barunya : baru
# ntuk : ntuk
# bangat : bangat
# ddirrumah : ddirrumah
# jumping : jumping
# ketengan : keteng
# hilangin : hilangin
# tekhnisi : tekhnisi
# sayangnya : sayang
# konsistensi : konsistensi
# customers : customers
# beralih : alih
# secepat : cepat
# sumatera : sumatera
# barat : barat
# bgus : bgus
# knpa : knpa
# pket : pket
# close : close
# kontrol : kontrol
# mempermudah : mudah
# pengecek : ecek
# pointnya : point
# redem : redem
# wou : wou
# {'leg': 'leg', 'uhhh': 'uhhh', 'internetnya': 'internetnya', 'benerin': 'benerin', 'thx': 'thx', 'fiber': 'fiber', 'optik': 'optik', 'mudah': 'mudah', 'putus': 'putus', 'indihome': 'indihome', 'koneksi': 'koneksi', 'jelek': 'jelek', 'banget': 'banget', 'udah': 'udah', 'kayak': 'kayak', 'numpang': 'numpang', 'wifi': 'wifi', 'tetangga': 'tetangga', 'speed': 'speed', 'lancar': 'lancar', 'lokasi': 'lokasi', 'pamekasan': 'pamekasan', 'madura': 'madura', '': '', 'pasang': 'pasang', 'kecepatan': 'cepat', 'mbps': 'mbps', 'knp': 'knp', 'skrg': 'skrg', 'provider': 'provider', 'jaringan': 'jaring', 'lelet': 'lelet', 'dibayar': 'bayar', 'kek': 'kek', 'ganti': 'ganti', 'mahal': 'mahal', 'jingan': 'jingan', 'solo': 'solo', 'lagnya': 'lagnya', 'main': 'main', 'cokkk': 'cokkk', 'one': 'one', 'jancokk': 'jancokk', 'nggk': 'nggk', 'ngotak': 'ngotak', 'coba': 'coba', 'bagusin': 'bagusin', 'pelayanannya': 'layan', 'iya': 'iya', 'los': 'los', 'mulu': 'mulu', 'lapor': 'lapor', 'berkali': 'kali', 'kali': 'kali', 'teknisi': 'teknisi', 'dateng': 'dateng', 'internet': 'internet', 'doang': 'doang', 'harganya': 'harga', 'harga': 'harga', 'paket': 'paket', 'serba': 'serba', 'gabisa': 'gabisa', 'register': 'register', 'login': 'login', 'the': 'the', 'best': 'best', 'sinyal': 'sinyal', 'bagus': 'bagus', 'kadang': 'kadang', 'kendala': 'kendala', 'wajar': 'wajar', 'namanya': 'nama', 'kenap': 'kenap', 'upgrade': 'upgrade', 'perincian': 'perinci', 'biayanya': 'biaya', 'totalnya': 'total', 'lihat': 'lihat', 'pemakaian': 'pakai', 'terpakai': 'pakai', 'lemot': 'lot', 'mbak': 'mbak', 'mas': 'mas', 'admin': 'admin', 'pas': 'pas', 'download': 'download', 'kb': 'kb', 'detik': 'detik', 'mb': 'mb', 'buka': 'buka', 'youtube': 'youtube', 'mohon': 'mohon', 'bantuannya': 'bantu', 'laporan': 'lapor', 'komplain': 'komplain', 'gangguan': 'ganggu', 'kemarin': 'kemarin', 'via': 'via', 'apk': 'apk', 'myindihome': 'myindihome', 'tindak': 'tindak', 'perhatiannya': 'perhati', 'woy': 'woy', 'goblog': 'goblog', 'ccd': 'ccd', 'berasa': 'asa', 'merah': 'merah', 'gitu': 'gitu', 'mending': 'mending', 'bizznet': 'bizznet', 'verifikasi': 'verifikasi', 'sms': 'sms', 'gmn': 'gmn', 'aplikasi': 'aplikasi', 'payah': 'payah', 'aplikasinya': 'aplikasi', 'luamaaaaa': 'luamaaaaa', 'loadingnya': 'loadingnya', 'gadget': 'gadget', 'email': 'email', 'trs': 'trs', 'dapet': 'dapet', 'parah': 'parah', 'bener': 'bener', 'kecewa': 'kecewa', 'registrasi': 'registrasi', 'pendaftaran': 'daftar', 'jumat': 'jumat', 'tgl': 'tgl', 'dijanjiin': 'dijanjiin', 'dipasang': 'pasang', 'sampe': 'sampe', 'teknisinya': 'teknisi', 'jga': 'jga', 'kerumah': 'rumah', 'salesnya': 'salesnya', 'bilangnya': 'bilang', 'libur': 'libur', 'emng': 'emng', 'dihari': 'hari', 'yaa': 'yaa', 'janjiin': 'janjiin', 'kaya': 'kaya', 'gini': 'gin', 'ngecewain': 'ngecewain', 'customer': 'customer', 'keren': 'keren', 'pelayanan': 'layan', 'ditingkatkan': 'tingkat', 'kurangi': 'kurang', 'bulannya': 'bulan', 'yth': 'yth', 'karyawan': 'karyawan', 'indi': 'indi', 'pleaseeeeeeeee': 'pleaseeeeeeeee', 'napa': 'napa', 'pubg': 'pubg', 'ngak': 'ngak', 'matcmaking': 'matcmaking', 'sumpah': 'sumpah', 'mintak': 'mintak', 'tolong': 'tolong', 'ama': 'ama', 'ngurus': 'ngurus', 'tolongggg': 'tolongggg', 'hutan': 'hutan', 'pedalaman': 'dalam', 'sinyalnya': 'sinyal', 'anjg': 'anjg', 'bayar': 'bayar', 'perbaiki': 'baik', 'jaringanya': 'jaringanya', 'bayarnya': 'bayar', 'udh': 'udh', 'massi': 'massi', 'ngeleg': 'ngeleg', 'siip': 'siip', 'telkomsel': 'telkomsel', 'sedunia': 'dunia', 'kuota': 'kuota', 'indonesia': 'indonesia', 'raya': 'raya', 'ngapain': 'ngapain', 'perluasan': 'luas', 'cukz': 'cukz', 'hoax': 'hoax', 'komplex': 'komplex', 'dtk': 'dtk', 'acara': 'acara', 'tipu': 'tipu', 'andalin': 'andalin', 'emosi': 'emosi', 'trading': 'trading', 'auto': 'auto', 'bangkrut': 'bangkrut', 'payaaaaaah': 'payaaaaaah', 'mutu': 'mutu', 'burukkkkkkk': 'burukkkkkkk', 'penanganan': 'tangan', 'lamaaa': 'lamaaa', 'kota': 'kota', 'tarakan': 'tara', 'bikinin': 'bikinin', 'minjem': 'minj ...
# ------------------------
# Pandas Apply:   0%|          | 0/896 [00:02<?, ?it/s]
#                                                content  score  \
# 0                          hanya bisa berkata leg uhhh      1
# 1                       internetnya benerin dulu.. thx      2
# 2                           fiber optik sr mudah putus      4
# 3    gak tau lagi sama indihome, koneksi nya jelek ...      1
# 4    saya pasang kecepatan 10mbps,knp skrg jadi kur...      1
# ..                                                 ...    ...
# 970                                susah upgrade speed      3
# 971                                       sangat bagus      5
# 972  ga bisa redeem point, sudah lapor malah suruh ...      1
# 973                                                wou      5
# 974                  kenapa skrg los nya sering merah?      1
#
#                                       cleaning_content  \
# 0                          hanya bisa berkata leg uhhh
# 1                         internetnya benerin dulu thx
# 2                              fiber optik mudah putus
# 3    gak tau lagi sama indihome koneksi nya jelek b...
# 4    saya pasang kecepatan  mbps knp skrg jadi kura...
# ..                                                 ...
# 970                                susah upgrade speed
# 971                                       sangat bagus
# 972   bisa redeem point sudah lapor malah suruh bol...
# 973                                                wou
# 974                  kenapa skrg los nya sering merah
#
#                                             tokenisasi  \
# 0                    [hanya, bisa, berkata, leg, uhhh]
# 1                    [internetnya, benerin, dulu, thx]
# 2                         [fiber, optik, mudah, putus]
# 3    [gak, tau, lagi, sama, indihome, koneksi, nya,...
# 4    [saya, pasang, kecepatan, mbps, knp, skrg, jad...
# ..                                                 ...
# 970                            [susah, upgrade, speed]
# 971                                    [sangat, bagus]
# 972  [, bisa, redeem, point, sudah, lapor, malah, s...
# 973                                              [wou]
# 974          [kenapa, skrg, los, nya, sering, merah, ]
#
#                                               stopword  \
# 0                                          [leg, uhhh]
# 1                          [internetnya, benerin, thx]
# 2                         [fiber, optik, mudah, putus]
# 3    [indihome, koneksi, jelek, banget, udah, kayak...
# 4           [pasang, kecepatan, mbps, knp, skrg, mbps]
# ..                                                 ...
# 970                            [susah, upgrade, speed]
# 971                                            [bagus]
# 972  [, redeem, point, lapor, suruh, bolak, relogin...
# 973                                              [wou]
# 974                               [skrg, los, merah, ]
#
#                                               stemming
# 0                                          [leg, uhhh]
# 1                          [internetnya, benerin, thx]
# 2                         [fiber, optik, mudah, putus]
# 3    [indihome, koneksi, jelek, banget, udah, kayak...
# 4               [pasang, cepat, mbps, knp, skrg, mbps]
# ..                                                 ...
# 970                            [susah, upgrade, speed]
# 971                                            [bagus]
# 972  [, redeem, point, lapor, suruh, bolak, relogin...
# 973                                              [wou]
# 974                               [skrg, los, merah, ]
#
# [896 rows x 6 columns]

# %%
Final = df[['stemming','score']]
Final = Final.rename(columns={'stemming':'text_review'})

# %%
Final
# Out:
#                                            text_review  score
# 0                                          [leg, uhhh]      1
# 1                          [internetnya, benerin, thx]      2
# 2                         [fiber, optik, mudah, putus]      4
# 3    [indihome, koneksi, jelek, banget, udah, kayak...      1
# 4               [pasang, cepat, mbps, knp, skrg, mbps]      1
# ..                                                 ...    ...
# 970                            [susah, upgrade, speed]      3
# 971                                            [bagus]      5
# 972  [, redeem, point, lapor, suruh, bolak, relogin...      1
# 973                                              [wou]      5
# 974                               [skrg, los, merah, ]      1
#
# [896 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_1.xlsx')
