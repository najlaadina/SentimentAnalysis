# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     Untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     Jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     Makin lama makin lenot boss, youtube paling ti...      1
# 4     Gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1921  Sinyal selalu putus, lemot. Pokoknya nyesal de...      1
# 1922                                              Bagus      4
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            Aplikasi nya error mulu      1
# 1925                                               Baik      5
#
# [1926 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 127

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     Untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     Jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     Makin lama makin lenot boss, youtube paling ti...      1
# 4     Gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1919  Cemen, gangguan terus. Mending cari provider l...      1
# 1920  Indihome gak gercep. Masa lapor pagi tgl 1 feb...      1
# 1921  Sinyal selalu putus, lemot. Pokoknya nyesal de...      1
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            Aplikasi nya error mulu      1
#
# [1769 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     makin lama makin lenot boss, youtube paling ti...      1
# 4     gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1919  cemen, gangguan terus. mending cari provider l...      1
# 1920  indihome gak gercep. masa lapor pagi tgl 1 feb...      1
# 1921  sinyal selalu putus, lemot. pokoknya nyesal de...      1
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            aplikasi nya error mulu      1
#
# [1769 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     makin lama makin lenot boss, youtube paling ti...      1
# 4     gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1919  cemen, gangguan terus. mending cari provider l...      1
# 1920  indihome gak gercep. masa lapor pagi tgl 1 feb...      1
# 1921  sinyal selalu putus, lemot. pokoknya nyesal de...      1
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            aplikasi nya error mulu      1
#
#                                        cleaning_content
# 0     tolong saya saya udh bayar indihomenya tapi se...
# 1     untuk renew fuf apakah hanya tertentu saya sud...
# 2     jaringan terlemot nomor dunia mbps itu saya ra...
# 3     makin lama makin lenot boss youtube paling tin...
# 4     gila sih lambat banget wifinya  mbps aja seras...
# ...                                                 ...
# 1919  cemen gangguan terus mending cari provider lai...
# 1920  indihome gak gercep masa lapor pagi tgl feb te...
# 1921  sinyal selalu putus lemot pokoknya nyesal deh ...
# 1923                           knpa cek kuota pemakaian
# 1924                            aplikasi nya error mulu
#
# [1769 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     makin lama makin lenot boss, youtube paling ti...      1
# 4     gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1919  cemen, gangguan terus. mending cari provider l...      1
# 1920  indihome gak gercep. masa lapor pagi tgl 1 feb...      1
# 1921  sinyal selalu putus, lemot. pokoknya nyesal de...      1
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            aplikasi nya error mulu      1
#
#                                        cleaning_content  \
# 0     tolong saya saya udh bayar indihomenya tapi se...
# 1     untuk renew fuf apakah hanya tertentu saya sud...
# 2     jaringan terlemot nomor dunia mbps itu saya ra...
# 3     makin lama makin lenot boss youtube paling tin...
# 4     gila sih lambat banget wifinya  mbps aja seras...
# ...                                                 ...
# 1919  cemen gangguan terus mending cari provider lai...
# 1920  indihome gak gercep masa lapor pagi tgl feb te...
# 1921  sinyal selalu putus lemot pokoknya nyesal deh ...
# 1923                           knpa cek kuota pemakaian
# 1924                            aplikasi nya error mulu
#
#                                              tokenisasi
# 0     [tolong, saya, saya, udh, bayar, indihomenya, ...
# 1     [untuk, renew, fuf, apakah, hanya, tertentu, s...
# 2     [jaringan, terlemot, nomor, dunia, mbps, itu, ...
# 3     [makin, lama, makin, lenot, boss, youtube, pal...
# 4     [gila, sih, lambat, banget, wifinya, mbps, aja...
# ...                                                 ...
# 1919  [cemen, gangguan, terus, mending, cari, provid...
# 1920  [indihome, gak, gercep, masa, lapor, pagi, tgl...
# 1921  [sinyal, selalu, putus, lemot, pokoknya, nyesa...
# 1923                      [knpa, cek, kuota, pemakaian]
# 1924                       [aplikasi, nya, error, mulu]
#
# [1769 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     makin lama makin lenot boss, youtube paling ti...      1
# 4     gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1919  cemen, gangguan terus. mending cari provider l...      1
# 1920  indihome gak gercep. masa lapor pagi tgl 1 feb...      1
# 1921  sinyal selalu putus, lemot. pokoknya nyesal de...      1
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            aplikasi nya error mulu      1
#
#                                        cleaning_content  \
# 0     tolong saya saya udh bayar indihomenya tapi se...
# 1     untuk renew fuf apakah hanya tertentu saya sud...
# 2     jaringan terlemot nomor dunia mbps itu saya ra...
# 3     makin lama makin lenot boss youtube paling tin...
# 4     gila sih lambat banget wifinya  mbps aja seras...
# ...                                                 ...
# 1919  cemen gangguan terus mending cari provider lai...
# 1920  indihome gak gercep masa lapor pagi tgl feb te...
# 1921  sinyal selalu putus lemot pokoknya nyesal deh ...
# 1923                           knpa cek kuota pemakaian
# 1924                            aplikasi nya error mulu
#
#                                              tokenisasi  \
# 0     [tolong, saya, saya, udh, bayar, indihomenya, ...
# 1     [untuk, renew, fuf, apakah, hanya, tertentu, s...
# 2     [jaringan, terlemot, nomor, dunia, mbps, itu, ...
# 3     [makin, lama, makin, lenot, boss, youtube, pal...
# 4     [gila, sih, lambat, banget, wifinya, mbps, aja...
# ...                                                 ...
# 1919  [cemen, gangguan, terus, mending, cari, provid...
# 1920  [indihome, gak, gercep, masa, lapor, pagi, tgl...
# 1921  [sinyal, selalu, putus, lemot, pokoknya, nyesa...
# 1923                      [knpa, cek, kuota, pemakaian]
# 1924                       [aplikasi, nya, error, mulu]
#
#                                                stopword
# 0     [tolong, udh, bayar, indihomenya, lost, jaring...
# 1                          [renew, fuf, clear, chahe, ]
# 2     [jaringan, terlemot, nomor, dunia, mbps, keboh...
# 3                 [lenot, boss, youtube, resolusinya, ]
# 4     [gila, lambat, banget, wifinya, mbps, serasa, ...
# ...                                                 ...
# 1919  [cemen, gangguan, mending, cari, provider, deh...
# 1920  [indihome, gercep, lapor, pagi, tgl, feb, tekn...
# 1921  [sinyal, putus, lemot, pokoknya, nyesal, deh, ...
# 1923                      [knpa, cek, kuota, pemakaian]
# 1924                            [aplikasi, error, mulu]
#
# [1769 rows x 5 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3414
# ------------------------
# tolong : tolong
# udh : udh
# bayar : bayar
# indihomenya : indihomenya
# lost : lost
# jaringannya : jaring
# haduh : haduh
# berhenti : henti
# deh : deh
# langganan : langgan
# indihome : indihome
# renew : renew
# fuf : fuf
# clear : clear
# chahe : chahe
#  :
# jaringan : jaring
# terlemot : lot
# nomor : nomor
# dunia : dunia
# mbps : mbps
# kebohongan : bohong
# mencapai : capai
# batas : batas
# lag : lag
# parah : parah
# game : game
# youtube : youtube
# muak : muak
# lenot : lenot
# boss : boss
# resolusinya : resolusi
# gila : gila
# lambat : lambat
# banget : banget
# wifinya : wifinya
# serasa : serasa
# kb : kb
# wifi : wifi
# terbaik : baik
# untung : untung
# pindah : pindah
# biznet : biznet
# kapok : kapok
# gapake : gapake
# pagi : pagi
# lumayan : lumayan
# tagihan : tagih
# cepat : cepat
# ketahui : tahu
# suka : suka
# background : background
# ganti : ganti
# sesuai : sesuai
# keinganan : keinganan
# bermanfaat : manfaat
# lapor : lapor
# gangguan : ganggu
# diam : diam
# terdeteksi : deteksi
# nunggu : nunggu
# pengaduan : adu
# telat : telat
# gegeri : geger
# diblokir : blokir
# permudah : mudah
# topup : topup
# dompet : dompet
# myindihome : myindihome
# mantappp : mantappp
# tyempat : tyempat
# lemot : lot
# sinnyal : sinnyal
# main : main
# mobile : mobile
# lagend : lagend
# sod : sod
# gaada : gaada
# nambah : nambah
# speed : speed
# mantap : mantap
# rto : rto
# responnya : responnya
# giliran : gilir
# sehari : hari
# uang : uang
# gaji : gaji
# blm : blm
# teror : teror
# telpon : telpon
# isolir : isolir
# update : update
# log : log
# out : out
# mati : mati
# kasih : kasih
# opsi : opsi
# otp : otp
# hangus : hangus
# layanan : layan
# simple : simple
# makasih : makasih
# membantu : bantu
# aplikasi : aplikasi
# tingkatkan : tingkat
# kualitas : kualitas
# berkualitas : kualitas
# ngikut : ngikut
# jelek : jelek
# hadeh : hadeh
# respon : respon
# selesaikan : selesai
# tksh : tksh
# aplikasinya : aplikasi
# memudahkan : mudah
# pelanggan : langgan
# thanks : thanks
# mudah : mudah
# bagus : bagus
# gampang : gampang
# mapping : mapping
# sukses : sukses
# bosque : bosque
# ditingkatkan : tingkat
# mantaps : mantaps
# kaliiii : kaliiii
# sumpah : sumpah
# ngelag : ngelag
# gajelas : gajelas
# mahal : mahal
# iya : iya
# ewh : ewh
# udah : udah
# tetep : tetep
# sinyal : sinyal
# pemakian : maki
# laptop : laptop
# download : download
# ampun : ampun
# saran : saran
# kuliatas : kuliatas
# inet : inet
# perbaiki : baik
# daerah : daerah
# padalarang : padalarang
# bandung : bandung
# barat : barat
# jawa : jawa
# membayar : bayar
# mending : mending
# provider : provider
# bye : bye
# pemasangan : pasang
# cek : cek
# promo : promo
# good : good
# job : job
# telkom : telkom
# bangkrut : bangkrut
# pelayanannya : layan
# memuaskan : muas
# patut : patut
# dicoba : coba
# pasang : pasang
# karna : karna
# terpaksa : paksa
# kecewa : kecewa
# besoknya : besok
# router : router
# zte : zte
# error : error
# lampu : lampu
# power : power
# los : los
# hidup : hidup
# internet : internet
# wajar : wajar
# instalasi : instalasi
# minggu : minggu
# live : live
# isutt : isutt
# deposit : deposit
# cepet : cepet
# notifnya : notifnya
# pelayanan : layan
# payah : payah
# tlp : tlp
# suruh : suruh
# tunggu : tunggu
# teknisi : teknisi
# gileeeeee : gileeeeee
# benerrrrr : benerrrrr
# maaf : maaf
# cabut : cabut
# karana : karana
# dipakek : dipakek
# semenjak : semenjak
# dipasang : pasang
# dipake : dipake
# upgrade : upgrade
# bukanya : buka
# lelet : lelet
# mantab : mantab
# skrng : skrng
# info : info
# pemakaian : pakai
# limit : limit
# dihilangkan : hilang
# versi : versi
# pemakain : pemakain
# ping : ping
# turun : turun
# stabil : stabil
# akibatnya : akibat
# bermain : main
# geme : geme
# dijalan : jalan
# lancar : lancar
# hubungi : hubung
# dikembangkan : kembang
# makan : makan
# hati : hati
# berlangganan : langgan
# kelewatan : lewat
# beda : beda
# pakai : pakai
# data : data
# normal : normal
# cacat : cacat
# seeeeeekaaaaaaaliiiiiiiiiii : seeeeeekaaaaaaaliiiiiiiiiii
# telemarketingnya : telemarketingnya
# pinter : pinter
# ngibul : ngibul
# telp : telp
# rubah : rubah
# kunjung : kunjung
# brubah : brubah
# dpt : dpt
# plnggan : plnggan
# seemless : seemless
# cma : cma
# nmbah : nmbah
# rb : rb
# aktif : aktif
# trkhir : trkhir
# dtlp : dtlp
# survey : survey
# dksi : dksi
# pulsa : pulsa
# masuk : masuk
# plsa : plsa
# jualan : jual
# nipu : nipu
# kedok : kedok
# bumn : bumn
# the : the
# mand : mand
# tersedia : sedia
# jaya : jaya
# histori : histori
# pembayaran : bayar
# top : top
# quota : quota
# batasan : batas
# berubah : ubah
# kehabisan : habis
# koq : koq
# poin : poin
# hilang : hilang
# bintang : bintang
# please : please
# app : app
# buka : buka
# muter : muter
# teruss : teruss
# dll : dll
# upgred : upgred
# sampahhhhh : sampahhhhh
# sampaj : sampaj
# melewati : lewat
# indhome : indhome
# hiliiih : hiliiih
# mulu : mulu
# hub : hub
# susah : susah
# bener : bener
# kaya : kaya
# artis : artis
# perbaikilah : baik
# pengen : ken
# gini : gin
# pdhal : pdhal
# konek : konek
# podol : podol
# tpi : tpi
# tgl : tgl
# tanggap : tanggap
# eksekusi : eksekusi
# menunggu : tunggu
# tiket : tiket
# laporan : lapor
# follow : follow
# koneksi : koneksi
# putus : putus
# jam : jam
# siang : siang
# perbaikan : baik
# selesai : selesai
# kerjakan : kerja
# nongol : nongol
# terputus : putus
# kerjain : kerjain
# jadwalin : jadwalin
# teknisinya : teknisi
# rumah : rumah
# hapus : hapus
# bijak : bijak
# siipp : siipp
# pengecekan : kece
# kuota : kuota
# fup : fup
# cuman : cuman
# menu : menu
# terlampau : lampau
# via : via
# link : link
# kecepatan : cepat
# kena : kena
# gmn : gmn
# dibayar : bayar
# layanannya : layan
# gal : gal
# dihapus : hapus
# terima : terima
# gaje : gaje
# klu : klu
# tutup : tutup
# disuruh : suruh
# bln : bln
# kemarin : kemarin
# kepakai : pakai
# lemoottt : lemoottt
# ngeyoutube : ngeyoutube
# codm : codm
# uploud : uploud
# pedahal : pedahal
# video : video
# puaas : puaas
# jambi : jambi
# tmpt : tmpt
# tinggal : tinggal
# conect : conect
# jalan : jalan
# alias : alias
# kali : kali
# melapor : lapor
# sampe : sampe
# janji : janji
# tlfn : tlfn
# pelayaaanan : pelayaaanan
# profesional : profesional
# membeeikan : membeeikan
# solusi : solusi
# trhadap : trhadap
# lalod : lalod
# ambil : ambil
# make : make
# org : org
# dirumah : rumah
# bufering : bufering
# operasi : operasi
# dateng : dateng
# check : check
# tegangan : tegang
# down : down
# and : and
# streamingan : streamingan
# tersambung : sambung
# buruk : buruk
# terdouble : terdouble
# aduan : adu
# ditanggapi : tanggap
# status : status
# diisolir : isolir
# complaint : complaint
# jawabannya : jawab
# diajukan : aju
# progress : progress
# langsung : langsung
# denda : denda
# call : call
# menit : menit
# dengerin : dengerin
# mesin : mesin
# penjawab : jawab
# musik : musik
# semoga : moga
# penanganannya : tangan
# nggak : nggak
# bayaran : bayar
# peringati : ingat
# kyk : kyk
# gua : gua
# habis : habis
# kau : kau
# pakek : pakek
# smpd : smpd
# verifikasi : verifikasi
# gagal : gagal
# rincian : rincian
# kualitasnya : kualitas
# perbaikannya : baik
# kecepatannya : cepat
# spt : spt
# alhadulillah : alhadulillah
# bgs : bgs
# pisan : pis
# kwalitas : kwalitas
# tingkatnya : tingkat
# cacaaaaaaaaaaaaaad : cacaaaaaaaaaaaaaad
# kesel : kesel
# indigo : indigo
# plis : plis
# membaik : baik
# lihat : lihat
# konsumen : konsumen
# berbintang : bintang
# kepikiran : pikir
# mikir : mikir
# kedepan : depan
# merusak : rusak
# citra : citra
# sekedar : dar
# harga : harga
# standar : standar
# informasinya : informasi
# lengkap : lengkap
# melayani : layan
# serba : serba
# komplen : komplen
# add : add
# byk : byk
# bet : bet
# berguna : guna
# dev : dev
# udu : udu
# sore : sore
# kak : kak
# petugas : tugas
# dipakai : pakai
# berjam : jam
# diperbaiki : baik
# lemotnya : lot
# ngotak : ngotak
# may : may
# indihom : indihom
# benerin : benerin
# orang : orang
# kenal : kenal
# kaga : kaga
# tanggung : tanggung
# ngecopot : ngecopot
# jalur : jalur
# koneksinya : koneksi
# pliss : pliss
# jabut : jabut
# kasian : kasi
# pemilik : milik
# bolak : bolak
# dlu : dlu
# ngacabut : ngacabut
# pesaing : saing
# stb : stb
# email : email
# adik : adik
# sekolah : sekolah
# online : online
# sklian : sklian
# menyusahkan : susah
# menyelesaikan : selesai
# kendala : kendala
# skrg : skrg
# becus : becus
# masi : mas
# lemut : lut
# yok : yok
# beralih : alih
# ribet : ribet
# proses : proses
# diproses : proses
# resposif : resposif
# disinformasi : disinformasi
# intenetnya : intenetnya
# sambung : sambung
# terserang : serang
# epidemi : epidemi
# corona : corona
# ajj : ajj
# ditlponin : ditlponin
# nagih : nagih
# bapuk : bapuk
# nonton : nonton
# ngclose : ngclose
# demand : demand
# identitas : identitas
# berulang : ulang
# membuka : buka
# detail : detail
# slalu : slalu
# apkikasi : apkikasi
# siip : siip
# nyesel : nyesel
# bualalan : bualalan
# gada : gada
# smaa : smaa
# kantor : kantor
# gunsar : gunsar
# kota : kota
# priok : priok
# sial : sial
# mempermudah : mudah
# mempersulit : sulit
# wakil : wakil
# rakyat : rakyat
# indikasi : indikasi
# jual : jual
# banwith : banwith
# lola : lola
# gapernah : gapernah
# mohon : mohon
# serius : serius
# tanggapin : tanggapin
# keluh : keluh
# kesah : kesah
# yaaa : yaaa
# user : user
# device : device
# massal : massal
# tanoa : tanoa
# pemberitahuan : pemberitahuan
# terlebuh : lebuh
# repot : repot
# ngandalin : ngandalin
# diandelin : diandelin
# kcepatan : kcepatan
# kadang : kadang
# nyambung : nyambung
# rugi : rugi
# woii : woii
# perbaikin : perbaikin
# asw : asw
# gue : gue
# ksh : ksh
# rating : rating
# mngkn : mngkn
# ksini : ksini
# ancur : ancur
# harganya : harga
# naek : naek
# dibikin : bikin
# pokobya : pokobya
# direkomen : direkomen
# msh : msh
# msk : msk
# intinya : inti
# merekomendasikan : rekomendasi
# kencang : kencang
# puas : puas
# terimakasih : terimakasih
# asli : asli
# seminggu : minggu
# sebulanan : bulan
# januari : januari
# mengajukan : aju
# skrang : skrang
# progres : progres
# meter : meter
# box : box
# fiber : fiber
# cable : cable
# mesti : mesti
# gimana : gimana
# desa : desa
# limbung : limbung
# kabupaten : kabupaten
# kubu : kubu
# raya : raya
# hujan : hujan
# ilang : ilang
# malem : malem
# unlimited : unlimited
# berat : berat
# internetnya : internetnya
# lemooooot : lemooooot
# idah : idah
# bayarnya : bayar
# potongan : potong
# niih : niih
# nanya : nanya
# ngeleg : ngeleg
# alesannya : alesannya
# gamas : gamas
# oke : oke
# menurun : turun
# sue : sue
# penggunaan : guna
# yak : yak
# web : web
# tindakin : tindakin
# mslh : mslh
# complain : complain
# praktis : praktis
# ngecek : ngecek
# bulanan : bulan
# prosesnya : proses
# terbaru : baru
# informatif : informatif
# promonya : promonya
# diperbanyak : banyak
# yaa : yaa
# kesal : kesal
# pas : pas
# perta : perta
# aman : aman
# hade : hade
# setia : setia
# lumayaan : lumayaan
# anak : anak
# sweet : sweet
# home : home
# penanganan : tangan
# lamban : lamban
# menang : menang
# cover : cover
# area : area
# coba : coba
# dibaca : baca
# admin : admin
# penawaran : tawar
# paket : paket
# marketing : marketing
# stlh : stlh
# setuju : tuju
# mandapat : mandapat
# kontrak : kontrak
# tindak : tindak
# wkt : wkt
# ditentukan : tentu
# satupun : satu
# kerumah : rumah
# perangkat : perangkat
# lbh : lbh
# tiang : tiang
# deteksinya : deteksi
# difollow : difollow
# sampahh : sampahh
# merah : merah
# memperbaiki : baik
# hasil : hasil
# nihil : nihil
# kedip : kedip
# keluhan : keluh
# musti : musti
# ceritakan : cerita
# kurangi : kurang
# tuban : tuban
# paketan : paket
# sayangkan : sayang
# didaerah : daerah
# timur : timur
# registrasi : registrasi
# ditolak : tolak
# melebihi : lebih
# estimasi : estimasi
# kerja : kerja
# dikomplain : komplain
# trouble : trouble
# dikembalikan : kembali
# doang : doang
# loading : loading
# maksud : maksud
# indiehome : indiehome
# kakak : kakak
# telekomunikasiindonesia : telekomunikasiindonesia
# ulasan : ulas
# butuh : butuh
# telekomunikasindonesia : telekomunikasindonesia
# sekelas : kelas
# abal : abal
# login : login
# sulit : sulit
# gara : gara
# terhalang : halang
# konyol : konyol
# akun : akun
# sungguh : sungguh
# mental : mental
# korup : korup
# pengeluhan : keluh
# tanggapi : tanggap
# maju : maju
# menjaga : jaga
# masukan : masuk
# bossku : bossku
# kode : kode
# gabisa : gabisa
# pengajuan : aju
# trus : trus
# routernya : routernya
# diambil : ambil
# kejelasan : jelas
# konfirmasi : konfirmasi
# mntapppp : mntapppp
# maen : maen
# ngelek : ngelek
# ajg : ajg
# rusak : rusak
# bgtu : bgtu
# diturutin : diturutin
# bsa : bsa
# masukin : masukin
# nmr : nmr
# sms : sms
# dikirim : kirim
# berkali : kali
# nyoba : nyoba
# dibenahi : benah
# diperbaruin : diperbaruin
# perincian : perinci
# pembayarannya : bayar
# speednya : speednya
# bermasalah : masalah
# end : end
# menjelang : jelang
# malam : malam
# lambatnya : lambat
# bbrp : bbrp
# itupun : itu
# genap : genap
# sebulan : bulan
# loss : loss
# mantul : mantul
# masyarakat : masyarakat
# biji : biji
# mata : mata
# dasar : dasar
# plat : plat
# sampah : sampah
# mantull : mantull
# sngat : sngat
# menyesal : sesal
# daftar : daftar
# diverifikasi : verifikasi
# dihubungi : hubung
# customer : customer
# tehnisinya : tehnisinya
# disetujui : tuju
# instal : instal
# pemasangannya : pasang
# tehnisi : tehnisi
# dilokasi : lokasi
# alasan : alas
# hasilnya : hasil
# penuh : penuh
# pendaftaran : daftar
# cancel : cancel
# buang : buang
# ngurusin : ngurusin
# alhamdullillah : alhamdullillah
# liat : liat
# rantingnya : ranting
# ngelus : ngelus
# pelanggannya : langgan
# gausah : gausah
# kayak : kayak
# kebanyakan : banyak
# eror : eror
# swasta : swasta
# pindahin : pindahin
# alamat : alamat
# tlpn : tlpn
# center : center
# sdg : sdg
# mnc : mnc
# vision : vision
# cpt : cpt
# responya : responya
# wakili : wakil
# ngeluh : ngeluh
# awass : awass
# masang : masang
# ntrr : ntrr
# best : best
# quality : quality
# niiiii : niiiii
# abis : abis
# andalkan : andal
# gie : gie
# tertarik : tarik
# siih : siih
# kelama : lama
# sakit : sakit
# lem : lem
# ottt : ottt
# kosong : kosong
# thn : thn
# besok : besok
# ikuti : ikut
# google : google
# work : work
# kasi : kasi
# beli : beli
# nyari : nyari
# nemu : nemu
# nama : nama
# angka : angka
# penipuan : tipu
# pemaksaan : paksa
# pemerasan : peras
# diresolir : diresolir
# full : full
# matikan : mati
# muncul : muncul
# mlhn : mlhn
# namanya : nama
# memaksa : paksa
# memeras : peras
# paksa : paksa
# adil : adil
# mah : mah
# senang : senang
# stop : stop
# kouta : kouta
# tolkon : tolkon
# request : request
# balasannya : balas
# diinput : diinput
# uda : uda
# maksimal : maksimal
# nyesal : nyesal
# telepon : telepon
# komplain : komplain
# perubahan : ubah
# hay : hay
# register : register
# alat : alat
# terpasang : pasang
# low : low
# perusahaan : usaha
# meningkatkan : tingkat
# terganggu : ganggu
# min : min
# keren : keren
# berpikir : pikir
# stremer : stremer
# terkena : kena
# pelayan : layan
# loe : loe
# komplin : komplin
# udahlah : udahlah
# skali : skali
# trhubung : trhubung
# terulang : ulang
# smooa : smooa
# direspon : direspon
# telkon : telkon
# kembalikan : kembali
# melaporkan : lapor
# sia : sia
# dapet : dapet
# doank : doank
# pelaksanaan : laksana
# offline : offline
# ditambah : tambah
# memikirkan : pikir
# konpensasi : konpensasi
# ketidaknyamanan : ketidaknyamanan
# donasi : donasi
# urusan : urus
# komonikasi : komonikasi
# pekerjaan : kerja
# tuntas : tuntas
# rezeki : rezeki
# bertambah : tambah
# hadeuh : hadeuh
# ngelagg : ngelagg
# rugiii : rugiii
# ush : ush
# ngerasain : ngerasain
# blgnya : blgnya
# maks : maks
# pengembalian : kembali
# balikin : balikin
# giliram : giliram
# kenain : kenain
# bunga : bunga
# beritahu : beritahu
# apps : apps
# pass : pass
# tampilan : tampil
# walpaper : walpaper
# tuker : tuker
# tambahin : tambahin
# merchantnya : merchantnya
# unsubcribe : unsubcribe
# channel : channel
# tambhn : tambhn
# nggk : nggk
# berhasil : hasil
# bantuan : bantu
# salah : salah
# ket : ket
# smakin : smakin
# tagihannya : tagih
# pelaporan : lapor
# keluhannya : keluh
# permudahkan : mudah
# note : note
# alhamdulillah : alhamdulillah
# refund : refund
# sedih : sedih
# sundala : sundala
# comeback : comeback
# suwun : suwun
# notif : notif
# modem : modem
# beemanfaat : beemanfaat
# kebanyak : banyak
# syarat : syarat
# tlng : tlng
# jln : jln
# hasanuddin : hasanuddin
# arenalama : arenalama
# timika : timika
# papua : papua
# tetangga : tetangga
# berbulan : bulan
# malas : malas
# copot : copot
# melulu : melulu
# klw : klw
# kunjungin : kunjungin
# mereja : reja
# angkat : angkat
# klau : klau
# tlpon : tlpon
# kesini : kesini
# merugikan : rugi
# ampas : ampas
# nyee : nyee
# indihomo : indihomo
# lahh : lahh
# sebelah : belah
# sinyalnya : sinyal
# legend : legend
# gppa : gppa
# ampasssssssss : ampasssssssss
# jaringanya : jaringanya
# mnta : mnta
# kenaikan : naik
# push : push
# gencar : gencar
# ama : ama
# tololnya : tolol
# aduannya : adu
# bagimana : bagimana
# bataskan : batas
# restart : restart
# sandinya : sandi
# ajaaa : ajaaa
# percayalah : percaya
# bang : bang
# berusaha : usaha
# ngerating : ngerating
# kek : kek
# ganguan : ganguan
# solusinya : solusi
# kompensasi : kompensasi
# wlan : wlan
# tidaj : tidaj
# ular : ular
# kepanasan : panas
# kirain : kirain
# rendah : rendah
# siput : siput
# menjelekkan : jelek
# buatan : buat
# pemerintah : perintah
# sistem : sistem
# gemes : gemes
# ujung : ujung
# alesan : alesan
# human : human
# najis : najis
# bobrok : bobrok
# jump : jump
# ms : ms
# nyaman : nyaman
# recommend : recommend
# produk : produk
# febuari : febuari
# ningkatan : ningkatan
# suda : suda
# naikin : naikin
# kalu : kalu
# ngini : ngini
# nga : nga
# perna : perna
# petujiknya : petujiknya
# indihomnya : indihomnya
# thx : thx
# markotop : markotop
# disaat : saat
# pandemi : pandemi
# menambah : tambah
# plasa : plasa
# terdekat : dekat
# cust : cust
# awam : awam
# menggunakannya : guna
# indohome : indohome
# keesokan : esok
# harinya : hari
# kedepannya : depan
# feedback : feedback
# customernya : customernya
# nice : nice
# helpfull : helpfull
# hadehh : hadehh
# bnget : bnget
# dibaguskan : bagus
# cakep : cakep
# tambahkan : tambah
# fitur : fitur
# block : block
# penggagu : gagu
# numpang : numpang
# izin : izin
# penggunaannya : guna
# mantao : mantao
# kerjaannya : kerja
# jembut : jembut
# dssr : dssr
# dipesen : sen
# feb : feb
# erornya : eror
# huhfttt : huhfttt
# kece : kece
# memonitor : monitor
# gokil : gokil
# apss : apss
# atasinya : atas
# ndak : ndak
# terbuka : buka
# berkat : berkat
# mantapppp : mantapppp
# pusat : pusat
# memperpanjang : panjang
# tanggapan : tanggap
# mke : mke
# masyaallah : masyaallah
# vpn : vpn
# mempan : mempan
# gmna : gmna
# something : something
# teman : teman
# lol : lol
# labil : labil
# anehnya : aneh
# sibuk : sibuk
# menawarkan : tawar
# handpone : handpone
# knpa : knpa
# kuat : kuat
# mlm : mlm
# keatas : atas
# smpe : smpe
# super : super
# banjarmasin : banjarmasin
# mewakili : wakil
# temen : temen
# nge : nge
# patah : patah
# kemajuan : maju
# bnyak : bnyak
# kah : kah
# kirim : kirim
# bukti : bukti
# foto : foto
# sayang : sayang
# capek : capek
# batasi : batas
# pemakai : pakai
# menerus : terus
# buffring : buffring
# kedepanya : depa
# sdah : sdah
# bnyk : bnyk
# tertera : tera
# susahnya : susah
# mentah : mentah
# pengalaman : alam
# mengecewakan : kecewa
# wilayah : wilayah
# provinsi : provinsi
# sarolangun : sarolangun
# harap : harap
# akses : akses
# paketnya : paket
# kecepatnya : cepat
# wajarnya : wajar
# kartu : kartu
# ps : ps
# baca : baca
# indo : indo
# bingung : bingung
# kesiapa : siapa
# most : most
# worst : worst
# recomended : recomended
# pokoknya : pokok
# ngegame : ngegame
# dijamin : jamin
# losestreak : losestreak
# donlod : donlod
# ngasih : ngasih
# woeee : woeee
# jatuh : jatuh
# tempo : tempo
# sblom : sblom
# sudh : sudh
# blom : blom
# bulannya : bulan
# sya : sya
# dri : dri
# total : total
# sbenarnya : sbenarnya
# diupgrade : diupgrade
# mobil : mobil
# legen : legen
# speeed : speeed
# cikupa : cikupa
# tangerang : tangerang
# frismedia : frismedia
# jamkot : jamkot
# berbeda : beda
# mbpsnya : mbpsnya
# rugikan : rugi
# pelayananya : pelayananya
# berbelit : belit
# belit : belit
# kepengurusanya : kepengurusanya
# anna : anna
# says : says
# apk : apk
# membingungkan : bingung
# gb : gb
# dipersulit : sulit
# ngadu : ngadu
# tolonglah : tolong
# trosss : trosss
# grade : grade
# adaa : adaa
# tah : tah
# buli : buli
# assalamualaikum : assalamualaikum
# jaminan : jamin
# beoom : beoom
# berenti : renti
# belom : bom
# kelar : kelar
# donload : donload
# riwayat : riwayat
# tragihan : tragihan
# sisa : sisa
# terkontrol : kontrol
# mengadu : adu
# wkwkwk : wkwkwk
# euy : euy
# ons : ons
# force : force
# close : close
# wifimu : wifimu
# cak : cak
# ketinggalan : tinggal
# scrim : scrim
# tante : tante
# ditampilkan : tampil
# alakadarnya : alakadarnya
# jos : jos
# tukarkan : tukar
# point : point
# terpencil : pencil
# tampahkan : tampah
# penukaran : tukar
# nikmati : nikmat
# nusantara : nusantara
# wajib : wajib
# edukasi : edukasi
# arahkan : arah
# rasakan : rasa
# fungsi : fungsi
# kegunaan : guna
# dimenu : menu
# ngisi : ngisi
# ngisinya : ngisinya
# permintaan : minta
# silahkan : silah
# keterangan : terang
# tarakan : tara
# subuh : subuh
# prnah : prnah
# gimn : gimn
# cari : cari
# saldo : saldo
# wooy : wooy
# receh : receh
# bacoood : bacoood
# dipercepat : cepat
# jangkauan : jangkau
# berjarak : jarak
# servis : servis
# dikasih : kasih
# notifikasi : notifikasi
# enak : enak
# apapun : apa
# nmor : nmor
# chek : chek
# maap : maap
# lapangan : lapang
# mna : mna
# ngga : ngga
# real : real
# time : time
# nanyak : nanyak
# seiring : iring
# banyaknya : banyak
# kapasitasnya : kapasitas
# terbatas : batas
# useless : useless
# jls : jls
# mandiri : mandiri
# virtual : virtual
# accountnya : accountnya
# ulang : ulang
# jiwa : jiwa
# usse : usse
# memilih : pilih
# catchplay : catchplay
# dilama : lama
# akurat : akurat
# mangkin : mangkin
# makai : maka
# laq : laq
# pernh : pernh
# memakai : pakai
# trobel : trobel
# permasalahan : masalah
# mb : mb
# kemana : mana
# seindah : indah
# mahalnya : mahal
# oni : oni
# troubl : troubl
# palsu : palsu
# disurvey : disurvey
# seakan : akan
# diurus : urus
# dipikirin : dipikirin
# backgroundnya : backgroundnya
# billing : billing
# profil : profil
# diupdate : diupdate
# sipppp : sipppp
# demandnya : demandnya
# kebiasaan : biasa
# tanggal : tanggal
# isolasi : isolasi
# system : system
# kerjasama : kerjasama
# bank : bank
# uber : uber
# aktifin : aktifin
# systemnya : systemnya
# channelnya : channelnya
# terkadang : terkadang
# hehee : hehee
# mantepp : mantepp
# indikator : indikator
# menyala : nyala
# klik : klik
# failed : failed
# mentok : mentok
# situ : situ
# tanggapannya : tanggap
# hahahahahah : hahahahahah
# lemoooooooot : lemoooooooot
# sekaliiiiii : sekaliiiiii
# diretas : retas
# anwar : anwar
# suleman : suleman
# diganti : ganti
# tampilannya : tampil
# isi : isi
# mengaktifkan : aktif
# non : non
# aktifkan : aktif
# sediakan : sedia
# apl : apl
# indita : indita
# dimana : mana
# signal : signal
# byr : byr
# blok : blok
# tingkat : tingkat
# dimasukan : masuk
# ngak : ngak
# powerfull : powerfull
# fiturnya : fiturnya
# late : late
# tindaklanjutnya : tindaklanjutnya
# dihari : hari
# libur : libur
# updet : updet
# bantuannya : bantu
# chat : chat
# kebanjiran : banjir
# kantornya : kantor
# gan : gan
# luas : luas
# knp : knp
# terbayarkan : bayar
# diaktifkan : aktif
# apalikasi : apalikasi
# dibuka : buka
# terbesar : besar
# ditinggalkan : tinggal
# rmh : rmh
# mengalami : alami
# kabel : kabel
# gulung : gulung
# secepet : secepet
# abaikan : abai
# taun : taun
# aseli : aseli
# cacad : cacad
# kbps : kbps
# respons : respons
# server : server
# kenceng : kenceng
# bugs : bugs
# fixing : fixing
# ngebug : ngebug
# kenama : nama
# erro : erro
# blokir : blokir
# diakses : akses
# diupdated : diupdated
# woi : woi
# keblokir : blokir
# fiture : fiture
# pilihan : pilih
# pilih : pilih
# costumer : costumer
# service : service
# kompetitor : kompetitor
# applikasi : applikasi
# maintenance : maintenance
# dibanggain : dibanggain
# disuspend : disuspend
# loding : loding
# bot : bot
# penurunan : turun
# ter : ter
# logout : logout
# perusahan : usah
# kembangkan : kembang
# telkomsel : telkomsel
# trs : trs
# otomatis : otomatis
# connect : connect
# konfirmasipun : konfirmasi
# tullisan : tullisan
# tehnologi : tehnologi
# terlambat : lambat
# keterlambatan : lambat
# connecting : connecting
# pelaku : laku
# bisnis : bisnis
# merugi : rugi
# loadingnya : loadingnya
# terisolir : isolir
# telfon : telfon
# tobat : tobat
# wfi : wfi
# servic : servic
# bos : bos
# semalam : malam
# wifie : wifie
# pon : pon
# berkedip : kedip
# tangani : tangan
# beneran : beneran
# tetiba : tetiba
# komfirmasi : komfirmasi
# komen : komen
# ektension : ektension
# birokrasi : birokrasi
# dihub : dihub
# dibacakan : baca
# dicari : cari
# lupa : lupa
# menghubungi : hubung
# tks : tks
# gaguna : gaguna
# jelasjelas : jelasjelas
# indihime : indihime
# bilng : bilng
# terdaftr : terdaftr
# tertulis : tulis
# februari : februari
# sempurnakan : sempurna
# gimna : gimna
# stelah : stelah
# diperbarui : baru
# bis : bis
# rincin : rincin
# msih : msih
# sblumnya : sblumnya
# dimengerti : erti
# bngt : bngt
# pdahal : pdahal
# tlat : tlat
# bru : bru
# lngsung : lngsung
# eeeh : eeeh
# ajh : ajh
# tlong : tlong
# donk : donk
# smuanya : smuanya
# prgi : prgi
# lho : lho
# saingan : saing
# drpd : drpd
# mas : mas
# mantep : mantep
# interaction : interaction
# deducation : deducation
# diatasi : atas
# secepatnya : cepat
# tertunda : tunda
# berhari : hari
# trimaksi : trimaksi
# hrs : hrs
# lsg : lsg
# otomatos : otomatos
# mlh : mlh
# mhn : mhn
# tuk : tuk
# kuliah : kuliah
# daring : daring
# mksh : mksh
# kekurangannya : kurang
# deteksi : deteksi
# pengguna : guna
# aneh : aneh
# errors : errors
# sdm : sdm
# merespon : merespon
# oengguna : oengguna
# ksni : ksni
# laporkan : lapor
# pembiayaannya : biaya
# males : males
# mngkin : mngkin
# dibantu : bantu
# teknis : teknis
# kontak : kontak
# khusus : khusus
# tanggerang : tanggerang
# selatan : selatan
# semena : semena
# goooooddddd : goooooddddd
# kwlitas : kwlitas
# kya : kya
# gaming : gaming
# setahun : tahun
# tmbah : tmbah
# jringan : jringan
# kog : kog
# ngg : ngg
# petunjuk : tunjuk
# menolong : tolong
# kerjanya : kerja
# mengganggu : ganggu
# ngapain : ngapain
# terimakasiii : terimakasiii
# leg : leg
# tolonggggg : tolonggggg
# pakk : pakk
# oky : oky
# nyala : nyala
# hotspot : hotspot
# sebanding : banding
# bangett : bangett
# rumit : rumit
# perbarui : baru
# kerjaan : kerja
# devnya : devnya
# bilangnya : bilang
# upload : upload
# shot : shot
# kalok : kalok
# ngaruh : ngaruh
# nyuruh : nyuruh
# makasa : makasa
# informasi : informasi
# bosok : bosok
# ketimpa : timpa
# pohon : pohon
# tangni : tangni
# melintang : lintang
# membahayakan : bahaya
# petugasya : petugasya
# kopoken : kopoken
# gsm : gsm
# terblokir : blokir
# bermanfat : bermanfat
# seringkali : seringkali
# very : very
# mmudahkan : mmudahkan
# persulit : sulit
# isp : isp
# keluhkan : keluh
# diperbiki : bik
# nyediain : nyediain
# tukar : tukar
# banyakan : banyak
# kebake : kebake
# bandara : bandara
# menerima : terima
# access : access
# lounge : lounge
# sabar : sabar
# berdoa : doa
# laen : laen
# kedop : dop
# dibenerin : dibenerin
# brp : brp
# kerugian : rugi
# keluarga : keluarga
# sabr : sabr
# manis : manis
# diawal : awal
# pahit : pahit
# balok : balok
# tungu : tungu
# resi : resi
# kwitansi : kwitansi
# sistemnya : sistem
# dihapuskan : hapus
# betulin : betulin
# bangus : bangus
# ayah : ayah
# terburuk : buruk
# playananya : playananya
# haduhh : haduhh
# transfer : transfer
# drefund : drefund
# kenyataannya : nyata
# zonk : zonk
# zzzztttt : zzzztttt
# ahhhh : ahhhh
# ikhlaskan : ikhlas
# uangku : uang
# peningkatan : tingkat
# mendidik : didik
# koreksinya : koreksi
# diaplikasi : aplikasi
# saking : saking
# kencangnya : kencang
# rekomendasi : rekomendasi
# terossss : terossss
# dlm : dlm
# jangka : jangka
# infonya : info
# transaksi : transaksi
# brooo : brooo
# hahaaa : hahaaa
# great : great
# merk : merk
# terjawab : jawab
# script : script
# okeeeeeee : okeeeeeee
# mengadukan : adu
# you : you
# tube : tube
# not : not
# recommended : recommended
# woy : woy
# nomer : nomer
# valid : valid
# niat : niat
# penyelesaian : selesai
# hadewww : hadewww
# segitu : segitu
# kemampuan : mampu
# banyar : banyar
# nokia : nokia
# yng : yng
# hank : hank
# lamanyaa : lamanyaa
# kahhh : kahhh
# baiksekali : baiksekali
# ganggu : ganggu
# serng : serng
# okey : okey
# indonesia : indonesia
# mentang : mentang
# dmana : dmana
# seimbang : imbang
# merampok : rampok
# gamers : gamers
# phoenix : phoenix
# tergoda : goda
# blang : blang
# ratting : ratting
# emosi : emosi
# merasakan : rasa
# pengertianya : pengertianya
# ditransfer : transfer
# teranjing : anjing
# akwoakwok : akwoakwok
# otw : otw
# nabung : nabung
# lodingnya : lodingnya
# pasword : pasword
# dsini : dsini
# motor : motor
# dikit : dikit
# getaran : getar
# dtratis : dtratis
# guys : guys
# tolol : tolol
# kepasang : pasang
# terhubung : hubung
# pemutusan : putus
# jadwalkan : jadwal
# ditempat : tempat
# paksakan : paksa
# putih : putih
# minipack : minipack
# kebutuhan : butuh
# mantapp : mantapp
# ngehang : ngehang
# donggg : donggg
# alert : alert
# friendly : friendly
# bates : bates
# nurun : nurun
# perlambatan : lambat
# motif : motif
# kelas : kelas
# nauzubillah : nauzubillah
# lawan : lawan
# kerennn : kerennn
# gerak : gerak
# terhormat : hormat
# lagg : lagg
# upgrede : upgrede
# sepeti : sepet
# seluler : seluler
# kemaren : kemaren
# incredible : incredible
# servicenya : servicenya
# dahh : dahh
# beres : beres
# ohhh : ohhh
# pakenya : pakenya
# ngirim : ngirim
# enaknya : enak
# seneng : neng
# duhhhh : duhhhh
# stabilkan : stabil
# nyaa : nyaa
# terusss : terusss
# ingus : ingus
# diread : diread
# maksimalkan : maksimal
# tur : tur
# ulangan : ulang
# jawabanya : jawabanya
# kekirim : kirim
# lainya : lai
# penilaian : nilai
# segini : gin
# sinyalmu : sinyal
# burik : burik
# hebat : hebat
# dakor : dakor
# musuhin : musuhin
# neraka : neraka
# sekeluarga : keluarga
# stress : stress
# sunguh : sunguh
# hallo : hallo
# busuk : busuk
# adakan : adakan
# kick : kick
# addon : addon
# pack : pack
# neh : neh
# revisi : revisi
# payment : payment
# alfa : alfa
# indomart : indomart
# dimudahkan : mudah
# hotel : hotel
# melati : melati
# tampilkan : tampil
# harsunya : harsunya
# notifikaainya : notifikaainya
# manteb : manteb
# updatenya : updatenya
# knapa : knapa
# handphone : handphone
# operator : operator
# nelpon : nelpon
# ditunggu : tunggu
# pusing : pusing
# bad : bad
# erorr : erorr
# alkhamdulillah : alkhamdulillah
# moga : moga
# enteng : enteng
# ngebukanya : ngebukanya
# aktivasi : aktivasi
# disuruhnya : suruh
# mantabz : mantabz
# mantaplah : mantap
# engga : engga
# alasannya : alas
# odp : odp
# website : website
# teroasang : teroasang
# tegur : tegur
# karyawannya : karyawannya
# emang : emang
# dftr : dftr
# sales : sales
# plz : plz
# slawi : slawi
# ngebantu : ngebantu
# better : better
# rinciannya : rinciannya
# gitu : gitu
# masukannya : masuk
# diterima : terima
# divice : divice
# seamles : seamles
# telcom : telcom
# ekspedisi : ekspedisi
# acc : acc
# mengirimkan : kirim
# pesan : pesan
# bersabar : sabar
# bertanggung : tanggung
# sma : sma
# munculkan : muncul
# minim : minim
# aksesnya : akses
# maanjiw : maanjiw
# tros : tros
# yaudah : yaudah
# jiwaaaaaaaaa : jiwaaaaaaaaa
# indihomeee : indihomeee
# wfh : wfh
# usage : usage
# diaplikasinya : aplikasi
# smua : smua
# include : include
# jarang : jarang
# dipke : dipke
# meledak : ledak
# ckck : ckck
# dimunculin : dimunculin
# temukan : temu
# kendalanya : kendala
# skarang : skarang
# jgaa : jgaa
# masuknya : masuk
# magrib : magrib
# ampe : ampe
# personal : personal
# huruf : huruf
# istimewa : istimewa
# utak : utak
# atik : atik
# hebaaaat : hebaaaat
# sekalii : sekali
# andaaaa : andaaaa
# jellleeeee : jellleeeee
# eeeeeeeeekkkkkkkk : eeeeeeeeekkkkkkkk
# jelekkkkkkkkk : jelekkkkkkkkk
# laggggggggggg : laggggggggggg
# lagggggggg : lagggggggg
# lagggggg : lagggggg
# mantaaappppppp : mantaaappppppp
# anime : anime
# astaga : astaga
# astagfirullah : astagfirullah
# saranin : saranin
# streesss : streesss
# kotor : kotor
# berdosa : dosa
# plss : plss
# laghhhhhhhhhhhhhhhhhhh : laghhhhhhhhhhhhhhhhhhh
# nyaaaaaaaaaa : nyaaaaaaaaaa
# parahhhhhhhhhhhhhhhhhhhhg : parahhhhhhhhhhhhhhhhhhhhg
# astgaaaaaaaaaaaaaaaa : astgaaaaaaaaaaaaaaaa
# anggota : anggota
# cangkem : cangkem
# nawarin : nawarin
# cangkemnya : cangkemnya
# buk : buk
# omongan : omong
# basi : basi
# cuihhhhhhhhhhh : cuihhhhhhhhhhh
# diimbangi : imbang
# kinerja : kerja
# dear : dear
# kalah : kalah
# lagii : lagi
# sesuaikan : sesuai
# andapun : anda
# menaik : naik
# wtf : wtf
# ksih : ksih
# napa : napa
# ulangpun : ulang
# ttp : ttp
# ragu : ragu
# lamaaaaaaa : lamaaaaaaa
# hariii : hariii
# verifikasinya : verifikasi
# lamaaaaaaaaaa : lamaaaaaaaaaa
# nyampe : nyampe
# lamaaaaaaaa : lamaaaaaaaa
# responsif : responsif
# pembatalan : batal
# diperhatikan : perhati
# penghapusan : hapus
# waw : waw
# lakukan : laku
# gercep : gercep
# berjalan : jalan
# kebantu : bantu
# ciamik : ciamik
# laah : laah
# improve : improve
# perbanyak : banyak
# duit : duit
# november : november
# giran : gir
# rumahnya : rumah
# pelosok : pelosok
# berlaku : laku
# dak : dak
# sampek : sampek
# edge : edge
# keburukannya : keburu
# buffering : buffering
# gasesuai : gasesuai
# gamao : gamao
# turunin : turunin
# merek : merek
# pengaruh : pengaruh
# petugasnya : tugas
# hedeh : hedeh
# fasilitas : fasilitas
# murah : murah
# bangt : bangt
# konfirmasinya : konfirmasi
# usetv : usetv
# lemottttttttttttttttttttttttttttttttttttttt : lemottttttttttttttttttttttttttttttttttttttt
# seting : ting
# seeing : seeing
# kencengin : kencengin
# dikasi : kasi
# pencurry : pencurry
# ngerti : ngerti
# gamer : gamer
# kamma : kamma
# indhihome : indhihome
# jariangan : jariangan
# well : well
# apak : apak
# buktikan : bukti
# kredit : kredit
# kagak : kagak
# dikenali : nali
# marketplace : marketplace
# barangkali : barangkali
# cache : cache
# uninstall : uninstall
# install : install
# pengaduhan : aduh
# kerusakan : rusa
# ytb : ytb
# review : review
# kabar : kabar
# sangan : sangan
# baguus : baguus
# hadehhh : hadehhh
# menanggapi : tanggap
# perihal : perihal
# menjuntai : juntai
# aktifitas : aktifitas
# in : in
# tindakan : tindak
# gangguanya : gangguanya
# sukak : sukak
# tambahan : tambah
# kereeen : kereeen
# adain : adain
# overall : overall
# ngeri : ngeri
# skip : skip
# monitor : monitor
# outdor : outdor
# berhamburan : hambur
# terpakai : pakai
# rapikan : rapi
# bongkar : bongkar
# pengcekan : cek
# membatu : batu
# kebanggan : banggan
# pecus : cus
# wifii : wifii
# usaha : usaha
# memasukkan : masuk
# bestttttt : bestttttt
# menelpon : telpon
# buah : buah
# sdang : sdang
# masal : masal
# malakukan : malakukan
# smoga : smoga
# mengirim : kirim
# balasan : balas
# twit : twit
# ttg : ttg
# naikan : naik
# bintangnya : bintang
# freeze : freeze
# bgmn : bgmn
# ngakses : ngakses
# username : username
# pssword : pssword
# seamless : seamless
# kayaknya : kayak
# okeoke : okeoke
# ulah : ulah
# pekerja : kerja
# alasanya : alasanya
# nasionl : nasionl
# lai : lai
# utuh : utuh
# dandan : dandan
# bkin : bkin
# hancur : hancur
# soax : soax
# jumping : jumping
# jiji : jiji
# bett : bett
# off : off
# memuakkan : muak
# pemula : mula
# dicancel : dicancel
# jarak : jarak
# panel : panel
# ranting : ranting
# menghalangi : halang
# melanjutkan : lanjut
# lokasi : lokasi
# haji : haji
# tepu : tepu
# boribellayya : boribellayya
# maros : maros
# sulawesi : sulawesi
# nyalakan : nyala
# akal : akal
# njing : njing
# bug : bug
# merchant : merchant
# menariknya : tarik
# canggih : canggih
# menarik : tarik
# rekomendasikan : rekomendasi
# helpful : helpful
# informative : informative
# atasi : atas
# manage : manage
# gangguannya : ganggu
# yaaaa : yaaaa
# track : track
# mines : mes
# membeli : beli
# dicek : cek
# problem : problem
# alhasil : alhasil
# pikir : pikir
# custemer : custemer
# karyawan : karyawan
# yudas : yudas
# trimakasih : trimakasih
# indehom : indehom
# mengeluh : keluh
# lgi : lgi
# amin : amin
# mengerti : erti
# pakainya : pakai
# amplas : amplas
# penambahan : tambah
# bantu : bantu
# muantull : muantull
# ntabs : ntabs
# terisolasir : terisolasir
# woooiiii : woooiiii
# setingkat : tingkat
# haram : haram
# dab : dab
# rama : rama
# sopan : sopan
# tindas : tindas
# suru : suru
# ditindas : tindas
# pembatasan : batas
# kuotanya : kuota
# merdeka : merdeka
# hai : hai
# biasaya : biasaya
# disembunyiinlah : disembunyiinlah
# ujan : ujan
# keunggulanya : keunggulanya
# jakarta : jakarta
# kpd : kpd
# indi : indi
# berbanding : banding
# terbalik : balik
# rencana : rencana
# andai : andai
# dengarkan : dengar
# dengar : dengar
# bengong : bengong
# ngempanin : ngempanin
# monopoli : monopoli
# tembaga : tembaga
# migrasi : migrasi
# optic : optic
# dibalikin : dibalikin
# lunasin : lunasin
# bawa : bawa
# ont : ont
# plaza : plaza
# anjg : anjg
# pke : pke
# duhh : duhh
# reset : reset
# sedangakan : sedangakan
# republic : republic
# bumdes : bumdes
# pembelian : beli
# pokok : pokok
# bantuanya : bantuanya
# mantuls : mantuls
# adminnya : adminnya
# jaringannyaaa : jaringannyaaa
# sip : sip
# mini : mini
# errornya : errornya
# dikurangin : rangin
# praktiss : praktiss
# interior : interior
# awalan : awal
# konsep : konsep
# tertolong : tolong
# listrik : listrik
# ubah : ubah
# yoza : yoza
# ktp : ktp
# yuza : yuza
# pelanggang : langgang
# lampirkan : lampir
# photo : photo
# ditlp : ditlp
# salahkan : salah
# bkn : bkn
# mbukak : mbukak
# suntik : suntik
# developer : developer
# ijazah : ijazah
# smpai : smpai
# detik : detik
# berasa : asa
# lancarlah : lancar
# kadng : kadng
# kdng : kdng
# sekli : sekli
# macet : macet
# appnya : appnya
# sndri : sndri
# legends : legends
# bgus : bgus
# kepepet : pepet
# krena : krena
# nikmatin : nikmatin
# penilian : penilian
# jlk : jlk
# gakadaperubahancok : gakadaperubahancok
# sippp : sippp
# permisi : permisi
# pandeglang : pandeglang
# meratakan : rata
# tipe : tipe
# benci : benci
# telekomunisasi : telekomunisasi
# ramai : ramai
# kritik : kritik
# berkenan : kenan
# judes : judes
# diulangi : ulang
# cairkan : cair
# pemberhentian : henti
# blitar : blitar
# gerai : gerai
# nyatutup : nyatutup
# trknisinya : trknisinya
# kenapasetiap : kenapasetiap
# sunggu : sunggu
# hang : hang
# ttep : ttep
# hrus : hrus
# jaringn : jaringn
# anjingg : anjingg
# jringn : jringn
# lejen : lejen
# kntl : kntl
# naiki : naik
# smart : smart
# memorynya : memorynya
# menyumbang : sumbang
# hnya : hnya
# sedikitpun : sedikit
# tidk : tidk
# verifkasinya : verifkasinya
# terkirim : kirim
# ingetin : ingetin
# rajin : rajin
# makasi : makas
# kayaa : kayaa
# taaae : taaae
# ilangan : ilangan
# merahh : merahh
# yahh : yahh
# balas : balas
# terlanjur : lanjur
# puekok : puekok
# kenek : kenek
# gawe : gawe
# dilaporin : dilaporin
# sengaja : sengaja
# bisul : bisul
# pafa : pafa
# ataw : ataw
# berlanggangan : langgang
# jemana : jemana
# gelas : gelas
# kompensasinya : kompensasi
# mendingan : mending
# mega : mega
# bearti : bearti
# ngerjain : ngerjain
# tugas : tugas
# lanjuti : lanjut
# tamabah : tamabah
# thinking : thinking
# membanting : banting
# lemotttttt : lemotttttt
# maunya : mau
# kenyamanan : nyaman
# diruma : diruma
# buruan : buru
# thankyou : thankyou
# gerakin : gerakin
# nunngu : nunngu
# berkokok : kokok
# persetujuan : tuju
# pastinya : pasti
# penaikan : naik
# slow : slow
# megajukan : megajukan
# merchand : merchand
# banyakin : banyakin
# apknya : apknya
# membatalkan : batal
# layak : layak
# donwload : donwload
# drastis : drastis
# jaraknya : jarak
# nelp : nelp
# ketersediaan : sedia
# pengakuan : aku
# jargon : jargon
# menjangkau : jangkau
# negeri : negeri
# menggaet : gaet
# brenti : brenti
# inbok : inbok
# sosmed : sosmed
# terealisasi : realisasi
# depositnya : deposit
# kampung : kampung
# kelapa : kelapa
# citayam : citayam
# tiangnya : tiang
# menikmati : nikmat
# ndk : ndk
# tempatku : tempat
# berlanjut : lanjut
# amanah : amanah
# menipu : tipu
# dijanjikan : janji
# keterang : terang
# penjelasan : jelas
# berfungsi : fungsi
# semestinya : mesti
# ribetin : ribetin
# performa : performa
# nol : nol
# batalin : batalin
# simles : simles
# korupsinya : korupsi
# asing : asing
# mengakibatkan : akibat
# terganggunya : ganggu
# krusial : krusial
# strategi : strategi
# malu : malu
# mosok : mosok
# tok : tok
# planggan : planggan
# rank : rank
# war : war
# tenang : tenang
# sehariiiii : sehariiiii
# gebrak : gebrak
# meja : meja
# banting : banting
# bakar : bakar
# gars : gars
# ngeleggggggggggggg : ngeleggggggggggggg
# growtopia : growtopia
# bit : bit
# bisanyaaaa : bisanyaaaa
# ngelaggg : ngelaggg
# trssss : trssss
# apaa : apaa
# pou : pou
# laaa : laaa
# play : play
# store : store
# delay : delay
# mkin : mkin
# jaringnya : jaring
# provaider : provaider
# ajah : ajah
# dng : dng
# skelas : skelas
# sndiri : sndiri
# apalgi : apalgi
# internasional : internasional
# verikasi : verikasi
# ramah : ramah
# dilayani : layan
# tasikmalaya : tasikmalaya
# macetan : macet
# ajaaaaa : ajaaaaa
# lekuar : lekuar
# registerasi : registerasi
# hilangkan : hilang
# turu : turu
# telekomunikasi : telekomunikasi
# android : android
# selagit : selagit
# babi : babi
# ribu : ribu
# bodoh : bodoh
# belajar : ajar
# pokonya : poko
# kacau : kacau
# terurus : urus
# bangke : bangke
# halo : halo
# brand : brand
# niatan : niat
# ayoo : ayoo
# tunjukan : tunjuk
# kelebihanmu : lebih
# mengenakan : kena
# naiknya : naik
# berjalannya : jalan
# gadget : gadget
# ditulis : tulis
# karakter : karakter
# didalam : dalam
# bersenang : senang
# kegagalan : gagal
# sentuh : sentuh
# taunya : tau
# sekalinya : sekali
# pngajuan : pngajuan
# memindahkan : pindah
# intrnet : intrnet
# pmbyaran : pmbyaran
# mubazir : mubazir
# wes : wes
# wae : wae
# naekin : naekin
# darah : darah
# pantes : pantes
# saing : saing
# oxygen : oxygen
# perbaharui : baharu
# playanan : playanan
# lbih : lbih
# january : january
# pindahkan : pindah
# dtang : dtang
# ktanya : ktanya
# hsil : hsil
# thun : thun
# brbagai : brbagai
# ktakan : ktakan
# krna : krna
# lelah : lelah
# pembuatan : buat
# wktu : wktu
# licik : licik
# mintak : mintak
# ngurus : ngurus
# bizznet : bizznet
# hapis : hap
# fupp : fupp
# jadikan : jadi
# dedicated : dedicated
# tulisannya : tulis
# maksudnya : maksud
# tdi : tdi
# discrool : discrool
# taik : taik
# hbs : hbs
# dbuka : dbuka
# bermasalh : bermasalh
# tnp : tnp
# dibagian : bagi
# pucek : pucek
# pubg : pubg
# beban : beban
# tim : tim
# semangat : semangat
# biaya : biaya
# diatas : atas
# dibandingkan : banding
# pdhl : pdhl
# pembodohan : bodoh
# miskin : miskin
# edan : edan
# standard : standard
# komunikasi : komunikasi
# nasional : nasional
# semalem : semalem
# tanda : tanda
# resivernya : resivernya
# digerakkan : gerak
# mba : mba
# mnjadi : mnjadi
# kepuasan : puas
# utamakan : utama
# putusin : putusin
# ngatas : ngatas
# namakan : nama
# warnet : warnet
# keperluar : luar
# pabrik : pabrik
# terdaftar : daftar
# rewards : rewards
# tsb : tsb
# menukar : tukar
# tahunnya : tahun
# diluar : luar
# tombol : tombol
# unduhan : unduh
# thank : thank
# gembellah : gembel
# kucing : kucing
# karung : karung
# ditelkom : ditelkom
# jasa : jasa
# memasang : pasang
# ane : ane
# loginya : log
# ngelink : ngelink
# berlanganan : berlanganan
# pengunaan : pengunaan
# proviser : proviser
# pling : pling
# psang : psang
# laporin : laporin
# ado : ado
# bloc : bloc
# jngan : jngan
# maksa : maksa
# msang : msang
# arisan : arisan
# jangam : jangam
# sehri : sehri
# permenit : menit
# gnguan : gnguan
# silakan : sila
# restar : restar
# ampir : ampir
# msi : msi
# perbaikinya : baik
# galagi : galagi
# jujur : jujur
# kpda : kpda
# kuning : kuning
# aploud : aploud
# tiktok : tiktok
# cmn : cmn
# berlangan : lang
# ber : ber
# database : database
# rapihin : rapihin
# komentar : komentar
# butut : butut
# loginnya : loginnya
# parahnya : parah
# dashboard : dashboard
# lengkapi : lengkap
# profile : profile
# kolom : kolom
# next : next
# stuck : stuck
# disitu : situ
# ternama : nama
# hadir : hadir
# perkembangan : kembang
# bidang : bidang
# kekurangan : kurang
# kelebihan : lebih
# seruluh : seruluh
# kesalahan : salah
# kedepankan : depan
# tracknya : tracknya
# internetan : internetan
# diperoses : diperoses
# ratingnye : ratingnye
# raksasa : raksasa
# puluhan : puluh
# minus : minus
# penangan : nang
# disimak : simak
# ahli : ahli
# dibidangnya : bidang
# ngakalin : ngakalin
# selang : selang
# penutup : tutup
# ditiang : tiang
# kemari : kemari
# air : air
# reapon : reapon
# istirahat : istirahat
# jaga : jaga
# ridho : ridho
# respond : respond
# merespond : merespond
# maklumi : maklum
# penggunanya : guna
# haripun : hari
# diem : diem
# layarnya : layar
# pencet : pencet
# prt : prt
# sysrq : sysrq
# keyboard : keyboard
# halamanya : halamanya
# responding : responding
# reload : reload
# padalah : pada
# jaringanyaa : jaringanyaa
# perbulan : bulan
# mengecek : ecek
# samsung : samsung
# ultra : ultra
# stack : stack
# halaman : halaman
# pengeluaran : keluar
# bner : bner
# tama : tama
# cct : cct
# ngehank : ngehank
# reinstal : reinstal
# ruang : ruang
# penyimpanan : simpan
# makasihhh : makasihhh
# line : line
# optik : optik
# urusannya : urus
# geometri : geometri
# iyain : iyain
# password : password
# mingking : mingking
# like : like
# berlamgganan : berlamgganan
# otensikasi : otensikasi
# historis : historis
# keloloa : keloloa
# heran : heran
# biometrik : biometrik
# hadoohh : hadoohh
# kmrn : kmrn
# blank : blank
# nominal : nominal
# tghn : tghn
# jalannya : jalan
# trims : trims
# ngecrash : ngecrash
# myi : myi
# terbukti : bukti
# bedanya : beda
# menampilkan : tampil
# malahnkabel : malahnkabel
# jumper : jumper
# arah : arah
# disarankan : saran
# lgsng : lgsng
# bersihkan : sih
# ngaco : ngaco
# selengkapnya : lengkap
# ngapa : ngapa
# back : back
# yaaaaah : yaaaaah
# posting : posting
# kritikan : kritik
# tarif : tarif
# bangat : bangat
# terdftar : terdftar
# jdi : jdi
# bgai : bgai
# luncur : luncur
# mewakilkan : wakil
# reinstall : reinstall
# rinci : rinci
# titik : titik
# janjiin : janjiin
# aplicasinya : aplicasinya
# urgadet : urgadet
# tinkatkan : tinkatkan
# lwat : lwat
# berulankali : berulankali
# lebibagus : lebibagus
# bandin : bandin
# indhom : indhom
# kgk : kgk
# ilangin : ilangin
# barang : barang
# nota : nota
# kepenjual : jual
# blg : blg
# penjual : jual
# ribeeet : ribeeet
# ecek : ecek
# refresh : refresh
# ehh : ehh
# hmm : hmm
# slnjutnya : slnjutnya
# absenin : absenin
# errrrrror : errrrrror
# lemah : lemah
# sudak : sudak
# apgred : apgred
# stlah : stlah
# indhihom : indhihom
# menangani : tangan
# biarlah : biar
# tulisan : tulis
# relogin : relogin
# berlengganan : lengganan
# dihaapus : dihaapus
# dusta : dusta
# tqu : tqu
# terjangkau : jangkau
# auto : auto
# uninstal : uninstal
# jengkel : jengkel
# ulangi : ulang
# sebad : bad
# datanya : data
# edar : edar
# muka : muka
# jga : jga
# tsv : tsv
# fak : fak
# fokus : fokus
# urus : urus
# tmbh : tmbh
# lucu : lucu
# gunanya : guna
# ayooo : ayooo
# lemottt : lemottt
# salut : salut
# mutu : mutu
# sulitnya : sulit
# ampuuuunnn : ampuuuunnn
# deeeh : deeeh
# milik : milik
# lemoott : lemoott
# lammmaaaa : lammmaaaa
# seriusan : serius
# nilai : nilai
# dibawah : bawah
# ngecewain : ngecewain
# datengin : datengin
# ngelola : ngelola
# elu : elu
# masak : masak
# otak : otak
# gpp : gpp
# ikhlas : ikhlas
# amburadul : amburadul
# palah : palah
# langkah : langkah
# gmana : gmana
# kelamaaan : kelamaaan
# lsh : lsh
# kren : kren
# sekrang : sekrang
# samasekali : samasekali
# pengembang : kembang
# carik : carik
# alikasi : alikasi
# skng : skng
# bka : bka
# ngadat : ngadat
# gambaran : gambar
# berantakan : beranta
# ceritnya : cit
# kocak : kocak
# memudah : mudah
# diperjelas : jelas
# perluas : luas
# persebaran : sebar
# kucoba : coba
# youtub : youtub
# kalimat : kalimat
# teros : ros
# indhomenya : indhomenya
# siaran : siar
# connection : connection
# pulak : pulak
# alah : alah
# than : than
# before : before
# bentar : bentar
# gosong : gosong
# screen : screen
# selangit : langit
# penyopotan : penyopotan
# nyopot : nyopot
# rame : rame
# bgitu : bgitu
# bagusn : bagusn
# nnton : nnton
# tes : tes
# browsing : browsing
# msuk : msuk
# mutar : mutar
# bhkan : bhkan
# fix : fix
# erorrrrrrrrr : erorrrrrrrrr
# mengakses : akses
# ringan : ringan
# mencoba : coba
# chace : chace
# sambungan : sambung
# facebook : facebook
# desember : desember
# ditelpon : telpon
# plus : plus
# pajak : pajak
# logikanya : logika
# kisaran : kisar
# twitter : twitter
# lwt : lwt
# akn : akn
# dijelek : jelek
# jelekan : jelek
# difungsikan : fungsi
# gin : gin
# kecepat : cepat
# kebuka : buka
# smntra : smntra
# utama : utama
# brlom : brlom
# gbisa : gbisa
# ppn : ppn
# ikr : ikr
# gtu : gtu
# terhapus : hapus
# skg : skg
# niatnya : niat
# fokusin : fokusin
# lemod : lemod
# ganteng : ganteng
# ibuk : ibuk
# cantik : cantik
# nihh : nihh
# truss : truss
# hape : hape
# penjelasannya : jelas
# idihome : idihome
# kepercayaan : percaya
# report : report
# manta : manta
# berkurang : kurang
# enga : enga
# aplikas : aplikas
# leleeeeeeeeeeeeeeeeeeettttttttttttttt : leleeeeeeeeeeeeeeeeeeettttttttttttttt
# bangetttttttttttttt : bangetttttttttttttt
# jeleeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee : jeleeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# bangettttttttttttttttttttttttttttttttttttttttttttttttt : bangettttttttttttttttttttttttttttttttttttttttttttttttt
# aplikasiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii : aplikasiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii
# yaaaaaaa : yaaaaaaa
# aaaaa : aaaaa
# mohonnnnnnnnnnnnnnnnn : mohonnnnnnnnnnnnnnnnn
# arahannnnnnnnnnnnnnnnn : arahannnnnnnnnnnnnnnnn
# yaaaaaaaaaaaaaa : yaaaaaaaaaaaaaa
# engaaaaaaaaaaaaaaaaaaaaaaa : engaaaaaaaaaaaaaaaaaaaaaaa
# bisaaaaaaaaaaaaaaaaaa : bisaaaaaaaaaaaaaaaaaa
# daftararrrrrrrrrrrrrrrrrrrrr : daftararrrrrrrrrrrrrrrrrrrrr
# indihomeeeeeeeeeeeee : indihomeeeeeeeeeeeee
# sayaaaaaaa : sayaaaaaaa
# dibbuka : dibbuka
# terlaksana : laksana
# terussss : terussss
# trmskh : trmskh
# menyulitkan : sulit
# inibapllikasi : inibapllikasi
# kanapa : kanapa
# digunaain : digunaain
# cuk : cuk
# hadeuuhh : hadeuuhh
# dipublish : dipublish
# sempurna : sempurna
# kepuasaan : puasa
# kemrin : kemrin
# bimbingannya : bimbing
# benhenti : benhenti
# kapitalis : kapitalis
# hilangin : hilangin
# perbandingan : banding
# seribu : ribu
# ratusan : ratus
# mao : mao
# dikondisikan : kondisi
# positif : positif
# protokol : protokol
# manajemen : manajemen
# bermutu : mutu
# instagram : instagram
# nda : nda
# pajangan : pajang
# pegawai : pegawai
# ditanyain : ditanyain
# cuekin : cuekin
# apasih : apasih
# alnya : alnya
# jdinya : jdinya
# bli : bli
# penyebabnya : sebab
# dimna : dimna
# pin : pin
# ngk : ngk
# halamannya : halaman
# direfresh : direfresh
# servernya : servernya
# jelasin : jelasin
# kecewe : kecewe
# nmer : nmer
# barusan : barusan
# transakti : transakti
# tampilanya : tampilanya
# lalulintas : lalulintas
# murahan : murah
# perbaikanalah : perbaikanalah
# diabaikan : abai
# hahahahaha : hahahahaha
# devloper : devloper
# pecat : pecat
# luemot : luemot
# hmpir : hmpir
# lma : lma
# bres : bres
# btul : btul
# slah : slah
# stu : stu
# kcptan : kcptan
# lmbat : lmbat
# hampu : hampu
# srta : srta
# mnyesal : mnyesal
# pkai : pkai
# skli : skli
# gnti : gnti
# provder : provder
# manjadi : manjadi
# myindiehome : myindiehome
# hilangi : hilang
# nonaktifkan : nonaktif
# gaq : gaq
# daritadi : daritadi
# diarahkan : arah
# dilempar : lempar
# angin : angin
# fisik : fisik
# ntah : ntah
# kpan : kpan
# cloud : cloud
# load : load
# yutub : yutub
# tidsk : tidsk
# gaes : gaes
# terkait : kait
# ditangani : tangan
# jempol : jempol
# piye : piye
# webnya : webnya
# player : player
# berbaiki : baik
# streaming : streaming
# terbilang : bilang
# dibilang : bilang
# menjengkelkan : jengkel
# didapatkan : dapat
# menanggulangi : tanggulang
# notes : notes
# berantah : antah
# kontraknya : kontrak
# skr : skr
# terbaca : baca
# bangetttt : bangetttt
# temui : temu
# tdurnya : tdurnya
# gegara : gegara
# trun : trun
# pembaruan : baru
# aoleng : aoleng
# dikarna : dikarna
# baiknya : baik
# sprtinya : sprtinya
# beranda : beranda
# kampreereeet : kampreereeet
# gambarnya : gambar
# aplikasih : aplikasih
# lhat : lhat
# byar : byar
# barapa : barapa
# aplikai : aplikai
# minnnnn : minnnnn
# pemindahan : pindah
# diaktivasi : diaktivasi
# cape : cape
# nemuin : nemuin
# orangnya : orang
# nohp : nohp
# pkek : pkek
# ...
# dasae : dasae
# diperbaikin : diperbaikin
# isinya : isi
# tampil : tampil
# stak : stak
# tggu : tggu
# muluuuuu : muluuuuu
# bantam : bantam
# berdua : dua
# settingan : settingan
# max : max
# akalan : akal
# iming : iming
# sprti : sprti
# kurangin : rangin
# ajak : ajak
# hhh : hhh
# fyi : fyi
# jatiwaringin : jatiwaringin
# pondok : pondok
# gede : gede
# bekasi : bekas
# yudi : yudi
# pecah : pecah
# kadaluarsa : kadaluarsa
# penarikan : tari
# asalan : asal
# ditindak : tindak
# lanjutin : lanjutin
# macan : macan
# indihomeku : indihomeku
# tlfon : tlfon
# puts : puts
# kec : kec
# margasari : margasari
# kab : kab
# tegal : tegal
# mlihat : mlihat
# penagihan : tagih
# layar : layar
# prbaruhi : prbaruhi
# tujuan : tuju
# bubarin : bubarin
# poll : poll
# mendekati : dekat
# penyedia : sedia
# reconecting : reconecting
# muternya : muternya
# abad : abad
# regis : regis
# sekaliiiii : sekaliiiii
# semdiri : semdiri
# reguler : reguler
# dripada : dripada
# menguntungkan : untung
# pengembangan : kembang
# kelola : kelola
# memalukan : malu
# phei : phei
# jngn : jngn
# napah : napah
# lalodnya : lalodnya
# eeehhh : eeehhh
# pengennya : ken
# firstmedia : firstmedia
# tersedianya : sedia
# nasib : nasib
# perdetik : detik
# ngelawak : ngelawak
# ponsel : ponsel
# kebaca : baca
# keapknya : keapknya
# kalimantan : kalimantan
# utara : utara
# ibukota : ibukota
# berharap : harap
# sekian : sekian
# pantesan : pantesan
# transparan : transparan
# cap : cap
# takut : takut
# keluarin : keluarin
# banking : banking
# lemooottt : lemooottt
# ekstrim : ekstrim
# detailnya : detail
# sejam : jam
# kontrol : kontrol
# dimohon : mohon
# kerjasamanya : kerjasamanya
# gonta : gonta
# ngejump : ngejump
# unistal : unistal
# bgmna : bgmna
# custumers : custumers
# sni : sni
# bahaya : bahaya
# dampaknya : dampak
# dirut : dirut
# after : after
# salesnya : salesnya
# medan : medan
# nampil : nampil
# diberanda : beranda
# dianggap : anggap
# haduuhhh : haduuhhh
# keseringan : sering
# ngeblank : ngeblank
# terhambat : hambat
# problemnya : problem
# sorry : sorry
# malh : malh
# naudzubillah : naudzubillah
# anjirrr : anjirrr
# lemottttt : lemottttt
# ajukan : aju
# catatan : catat
# lemooot : lemooot
# applikasiny : applikasiny
# gimmick : gimmick
# informasikan : informasi
# paya : paya
# bat : bat
# sring : sring
# apliasinya : apliasinya
# bgn : bgn
# lepas : lepas
# tangan : tangan
# kebijakannya : bijak
# dibetulkan : betul
# aneeeeeh : aneeeeeh
# predikat : predikat
# terancam : ancam
# mundur : mundur
# ajaa : ajaa
# lemoooot : lemoooot
# publik : publik
# apliksi : apliksi
# masukkan : masuk
# salaaaammmmmmmm : salaaaammmmmmmm
# bugnya : bugnya
# ribett : ribett
# sii : sii
# mafia : mafia
# nnya : nnya
# ammpuunnn : ammpuunnn
# kebalik : balik
# sundah : sundah
# iiii : iiii
# balesan : balesan
# bales : bales
# tampa : tampa
# kampretlah : kampret
# loby : loby
# piturnya : piturnya
# lambangnya : lambang
# muat : muat
# percobaan : coba
# dilampirkan : lampir
# kirimkan : kirim
# meningkat : tingkat
# resah : resah
# rugii : rugi
# sedangkn : sedangkn
# powernya : powernya
# bayarr : bayarr
# mauny : mauny
# tapii : tapi
# kapokk : kapokk
# voucher : voucher
# seribuan : ribu
# disneyhostar : disneyhostar
# seru : seru
# kayanya : kaya
# wawancara : wawancara
# inditod : inditod
# ngen : ngen
# negara : negara
# sesampah : sampah
# mencakup : cakup
# dipaksakan : paksa
# keuntungan : untung
# mengabaikan : abai
# disediakan : sedia
# berbicara : bicara
# happy : happy
# dikonfirmasi : konfirmasi
# statement : statement
# lampiran : lampir
# benefit : benefit
# crash : crash
# nob : nob
# panggil : panggil
# mintain : mintain
# roko : roko
# nyerpis : nyerpis
# lemes : lemes
# flow : flow
# disadari : sadar
# difix : difix
# fixed : fixed
# yanh : yanh
# salam : salam
# sebelumnnya : sebelumnnya
# streamer : streamer
# pegawainya : pegawai
# kasihan : kasihan
# tawaran : tawar
# myindi : myindi
# simpati : simpati
# permasalahanya : permasalahanya
# berfaedah : faedah
# stres : stres
# whatsapp : whatsapp
# terosss : terosss
# but : but
# membangongkan : membangongkan
# asinge : asinge
# obat : obat
# ramahnya : ramah
# padal : padal
# dibetulin : dibetulin
# sukabumi : sukabumi
# jampang : jampang
# kulon : kulon
# bagusan : bagus
# performanya : performa
# menunya : menu
# under : under
# construction : construction
# republik : republik
# ngelos : ngelos
# keringanan : ringan
# cewek : cewek
# jutek : jutek
# mantabs : mantabs
# ngelunjak : ngelunjak
# sebel : sebel
# dehh : dehh
# playstore : playstore
# sekaran : sekar
# oktobet : oktobet
# penyambutan : sambut
# didaftarkan : daftar
# root : root
# dualplay : dualplay
# triple : triple
# pay : pay
# dasarnya : dasar
# nambahin : nambahin
# bohongin : bohongin
# jumplah : jumplah
# ngx : ngx
# sehat : sehat
# knpaa : knpaa
# udaa : udaa
# regiater : regiater
# bisaa : bisaa
# kedetek : kedetek
# juta : juta
# untk : untk
# undefined : undefined
# karepmu : karepmu
# opo : opo
# iki : iki
# ojok : ojok
# perjanjian : janji
# flat : flat
# iso : iso
# sak : sak
# setel : setel
# scroll : scroll
# moba : moba
# vendor : vendor
# underrated : underrated
# free : free
# buriq : buriq
# wooiii : wooiii
# medsos : medsos
# bacaan : baca
# wkwkw : wkwkw
# siii : siii
# perfoma : perfoma
# alih : alih
# dipantau : pantau
# cba : cba
# input : input
# dtolak : dtolak
# tedftr : tedftr
# sebagus : bagus
# padahan : padah
# bro : bro
# pendapatan : dapat
# miliar : miliar
# dollar : dollar
# perhatikan : perhati
# karayawan : karayawan
# mitra : mitra
# nakan : nak
# dipecat : pecat
# bangun : bangun
# apanya : apa
# menagih : tagih
# apain : apain
# pusatnya : pusat
# pecuma : cuma
# ambon : ambon
# slot : slot
# cabutan : cabut
# warga : warga
# menyediakan : sedia
# yaelah : yaelah
# pjj : pjj
# lagends : lagends
# inetnya : inetnya
# sebentar : sebentar
# sbntar : sbntar
# csnya : csnya
# selasa : selasa
# confirm : confirm
# relevan : relevan
# jiancok : jiancok
# ngeselin : ngeselin
# bab : bab
# diklik : klik
# central : central
# unit : unit
# rutin : rutin
# aaplikasi : aaplikasi
# kedap : kedap
# diilangin : diilangin
# quick : quick
# padahl : padahl
# makainya : maka
# sos : sos
# dekoder : dekoder
# legands : legands
# special : special
# negri : negri
# sam : sam
# satunya : satu
# nomornya : nomor
# emain : emain
# pening : pening
# kesabaran : sabar
# sangking : sangking
# keselnya : kesel
# babik : babik
# lomba : lomba
# seburik : burik
# burikkkkkkkkkkkk : burikkkkkkkkkkkk
# anjingggggg : anjingggggg
# agus : agus
# gblkkkkkkk : gblkkkkkkk
# covid : covid
# kontrobusi : kontrobusi
# tarifnya : tarif
# bpk : bpk
# penghasilan : hasil
# warung : warung
# sepi : sepi
# toleransi : toleransi
# rincial : rincial
# diserodok : rodok
# dikubur : kubur
# bumi : bumi
# cantumkan : cantum
# kerusaka : kerusaka
# susa : susa
# hahaha : hahaha
# ngaca : ngaca
# slese : slese
# langaung : langaung
# trmksh : trmksh
# setau : tau
# merata : rata
# aduhhhhhhhhhhhhh : aduhhhhhhhhhhhhh
# masangnya : masangnya
# lnjt : lnjt
# dinonaktifkan : nonaktif
# nonaktif : nonaktif
# pki : pki
# anti : anti
# registrasikan : registrasi
# teluk : teluk
# batang : batang
# kayong : kayong
# kalbar : kalbar
# sekaliiii : sekaliiii
# ribetnya : ribetnya
# mpe : mpe
# timeout : timeout
# case : case
# diselesaikan : selesai
# kapasitas : kapasitas
# instan : instan
# mengubah : ubah
# opini : opini
# aduhh : aduhh
# lahhh : lahhh
# punye : punye
# dahhh : dahhh
# balekk : balekk
# kampungjee : kampungjee
# malaisya : malaisya
# membengkak : bengkak
# booooohooong : booooohooong
# kejebak : jebak
# memuasakan : puasa
# ngadunya : ngadunya
# amps : amps
# berisi : isi
# mantau : mantau
# broken : broken
# aga : aga
# laggg : laggg
# benerrrrrrrrr : benerrrrrrrrr
# konrol : konrol
# mood : mood
# trima : trima
# bau : bau
# film : film
# buffer : buffer
# ayo : ayo
# indah : indah
# fast : fast
# tangapan : tangap
# lokasinya : lokasi
# tekhnisi : tekhnisi
# smartphone : smartphone
# redmi : redmi
# vertifikasi : vertifikasi
# harapan : harap
# kon : kon
# rajanya : raja
# miris : miris
# mengembalikan : kembali
# refound : refound
# pelanganya : pelanganya
# langanan : langanan
# disayangkan : sayang
# direfound : direfound
# ntar : ntar
# koh : koh
# lampunya : lampu
# warna : warna
# woiii : woiii
# woiu : woiu
# contohnya : contoh
# selalh : selalh
# ehhhh : ehhhh
# tuber : tuber
# bocil : bocil
# tahap : tahap
# disurvei : survei
# pribadi : pribadi
# php : php
# kepentingan : penting
# uploadnya : uploadnya
# blum : blum
# kepastian : pasti
# telponnya : telpon
# ngaudzubillah : ngaudzubillah
# spv : spv
# verfikasi : verfikasi
# mumpung : mumpung
# berkepanjangan : panjang
# apbila : apbila
# goodjob : goodjob
# bloon : bloon
# samepe : samepe
# terekam : rekam
# history : history
# ngelaggggg : ngelaggggg
# pemeriksaan : periksa
# aduh : aduh
# mantaaaappp : mantaaaappp
# lelethome : lelethome
# langgangan : langgang
# custumer : custumer
# ampuuuuuun : ampuuuuuun
# mengumpat : umpat
# bulanannya : bulan
# daun : daun
# iklan : iklan
# jor : jor
# zero : zero
# wkwkkwkw : wkwkkwkw
# cemen : cemen
# ontime : ontime
# dtg : dtg
# {'tolong': 'tolong', 'udh': 'udh', 'bayar': 'bayar', 'indihomenya': 'indihomenya', 'lost': 'lost', 'jaringannya': 'jaring', 'haduh': 'haduh', 'berhenti': 'henti', 'deh': 'deh', 'langganan': 'langgan', 'indihome': 'indihome', 'renew': 'renew', 'fuf': 'fuf', 'clear': 'clear', 'chahe': 'chahe', '': '', 'jaringan': 'jaring', 'terlemot': 'lot', 'nomor': 'nomor', 'dunia': 'dunia', 'mbps': 'mbps', 'kebohongan': 'bohong', 'mencapai': 'capai', 'batas': 'batas', 'lag': 'lag', 'parah': 'parah', 'game': 'game', 'youtube': 'youtube', 'muak': 'muak', 'lenot': 'lenot', 'boss': 'boss', 'resolusinya': 'resolusi', 'gila': 'gila', 'lambat': 'lambat', 'banget': 'banget', 'wifinya': 'wifinya', 'serasa': 'serasa', 'kb': 'kb', 'wifi': 'wifi', 'terbaik': 'baik', 'untung': 'untung', 'pindah': 'pindah', 'biznet': 'biznet', 'kapok': 'kapok', 'gapake': 'gapake', 'pagi': 'pagi', 'lumayan': 'lumayan', 'tagihan': 'tagih', 'cepat': 'cepat', 'ketahui': 'tahu', 'suka': 'suka', 'background': 'background', 'ganti': 'ganti', 'sesuai': 'sesuai', 'keinganan': 'keinganan', 'bermanfaat': 'manfaat', 'lapor': 'lapor', 'gangguan': 'ganggu', 'diam': 'diam', 'terdeteksi': 'deteksi', 'nunggu': 'nunggu', 'pengaduan': 'adu', 'telat': 'telat', 'gegeri': 'geger', 'diblokir': 'blokir', 'permudah': 'mudah', 'topup': 'topup', 'dompet': 'dompet', 'myindihome': 'myindihome', 'mantappp': 'mantappp', 'tyempat': 'tyempat', 'lemot': 'lot', 'sinnyal': 'sinnyal', 'main': 'main', 'mobile': 'mobile', 'lagend': 'lagend', 'sod': 'sod', 'gaada': 'gaada', 'nambah': 'nambah', 'speed': 'speed', 'mantap': 'mantap', 'rto': 'rto', 'responnya': 'responnya', 'giliran': 'gilir', 'sehari': 'hari', 'uang': 'uang', 'gaji': 'gaji', 'blm': 'blm', 'teror': 'teror', 'telpon': 'telpon', 'isolir': 'isolir', 'update': 'update', 'log': 'log', 'out': 'out', 'mati': 'mati', 'kasih': 'kasih', 'opsi': 'opsi', 'otp': 'otp', 'hangus': 'hangus', 'layanan': 'layan', 'simple': 'simple', 'makasih': 'makasih', 'membantu': 'bantu', 'aplikasi': 'aplikasi', 'tingkatkan': 'tingkat', 'kualitas': 'kualitas', 'berkualitas': 'kualitas', 'ngikut': 'ngikut', 'jelek': 'jelek', 'hadeh': 'hadeh', 'respon': 'respon', 'selesaikan': 'selesai', 'tksh': 'tksh', 'aplikasinya': 'aplikasi', 'memudahkan': 'mudah', 'pelanggan': 'langgan', 'thanks': 'thanks', 'mudah': 'mudah', 'bagus': 'bagus', 'gampang': 'gampang', 'mapping': 'mapping', 'sukses': 'sukses', 'bosque': 'bosque', 'ditingkatkan': 'tingkat', 'mantaps': 'mantaps', 'kaliiii': 'kaliiii', 'sumpah': 'sumpah', 'ngelag': 'ngelag', 'gajelas': 'gajelas', 'mahal': 'mahal', 'iya': 'iya', 'ewh': 'ewh', 'udah': 'udah', 'tetep': 'tetep', 'sinyal': 'sinyal', 'pemakian': 'maki', 'laptop': 'laptop', 'download': 'download', 'ampun': 'ampun', 'saran': 'saran', 'kuliatas': 'kuliatas', 'inet': 'inet', 'perbaiki': 'baik', 'daerah': 'daerah', 'padalarang': 'padalarang', 'bandung': 'bandung', 'barat': 'barat', 'jawa': 'jawa', 'membayar': 'bayar', 'mending': 'mending', 'provider': 'provider', 'bye': 'bye', 'pemasangan': 'pasang', 'cek': 'cek', 'promo': 'promo', 'good': 'good', 'job': 'job', 'telkom': 'telkom', 'bangkrut': 'bangkrut', 'pelayanannya': 'layan', 'memuaskan': 'muas', 'patut': 'patut', 'dicoba': 'coba', 'pasang': 'pasang', 'karna': 'karna', 'terpaksa': 'paksa', 'kecewa': 'kecewa', 'besoknya': 'besok', 'router': 'router', 'zte': 'zte', 'error': 'error', 'lampu': 'lampu', 'power': 'power', 'los': 'los', 'hidup': 'hidup', 'internet': 'internet', 'wajar': 'wajar', 'instalasi': 'instalasi', 'minggu': 'minggu', 'live': 'live', 'isutt': 'isutt', 'deposit': 'deposit', 'cepet': 'cepet', 'notifnya': 'notifnya', 'pelayanan': 'layan', 'payah': 'payah', 'tlp': 'tlp', 'suruh': 'suruh', 'tunggu': 'tunggu', 'teknisi': 'teknisi', 'gileeeeee': 'gileeeeee', 'benerrrrr': 'benerrrrr', 'maaf': 'maaf', 'cabut': 'cabut', 'karana': 'karana', 'dipakek': 'dipakek', 'semenjak': 'semenjak', 'dipasang': 'pasang', 'dipake': 'dipake', 'upgrade': 'upgrade', 'bukanya': 'buka', 'lelet': 'lelet', 'mantab': 'mantab', 'skrng': 'skrng', ...
# ------------------------
# Pandas Apply:   0%|          | 0/1769 [00:00<?, ?it/s]
#                                                 content  score  \
# 0     tolong saya saya udh bayar indihomenya ,tapi s...      1
# 1     untuk renew fuf apakah hanya no tertentu, saya...      1
# 2     jaringan terlemot nomor 1 di dunia 20 mbps itu...      1
# 3     makin lama makin lenot boss, youtube paling ti...      1
# 4     gila sih lambat banget wifinya 20mbps aja sera...      1
# ...                                                 ...    ...
# 1919  cemen, gangguan terus. mending cari provider l...      1
# 1920  indihome gak gercep. masa lapor pagi tgl 1 feb...      1
# 1921  sinyal selalu putus, lemot. pokoknya nyesal de...      1
# 1923                     knpa gk bs cek kuota pemakaian      3
# 1924                            aplikasi nya error mulu      1
#
#                                        cleaning_content  \
# 0     tolong saya saya udh bayar indihomenya tapi se...
# 1     untuk renew fuf apakah hanya tertentu saya sud...
# 2     jaringan terlemot nomor dunia mbps itu saya ra...
# 3     makin lama makin lenot boss youtube paling tin...
# 4     gila sih lambat banget wifinya  mbps aja seras...
# ...                                                 ...
# 1919  cemen gangguan terus mending cari provider lai...
# 1920  indihome gak gercep masa lapor pagi tgl feb te...
# 1921  sinyal selalu putus lemot pokoknya nyesal deh ...
# 1923                           knpa cek kuota pemakaian
# 1924                            aplikasi nya error mulu
#
#                                              tokenisasi  \
# 0     [tolong, saya, saya, udh, bayar, indihomenya, ...
# 1     [untuk, renew, fuf, apakah, hanya, tertentu, s...
# 2     [jaringan, terlemot, nomor, dunia, mbps, itu, ...
# 3     [makin, lama, makin, lenot, boss, youtube, pal...
# 4     [gila, sih, lambat, banget, wifinya, mbps, aja...
# ...                                                 ...
# 1919  [cemen, gangguan, terus, mending, cari, provid...
# 1920  [indihome, gak, gercep, masa, lapor, pagi, tgl...
# 1921  [sinyal, selalu, putus, lemot, pokoknya, nyesa...
# 1923                      [knpa, cek, kuota, pemakaian]
# 1924                       [aplikasi, nya, error, mulu]
#
#                                                stopword  \
# 0     [tolong, udh, bayar, indihomenya, lost, jaring...
# 1                          [renew, fuf, clear, chahe, ]
# 2     [jaringan, terlemot, nomor, dunia, mbps, keboh...
# 3                 [lenot, boss, youtube, resolusinya, ]
# 4     [gila, lambat, banget, wifinya, mbps, serasa, ...
# ...                                                 ...
# 1919  [cemen, gangguan, mending, cari, provider, deh...
# 1920  [indihome, gercep, lapor, pagi, tgl, feb, tekn...
# 1921  [sinyal, putus, lemot, pokoknya, nyesal, deh, ...
# 1923                      [knpa, cek, kuota, pemakaian]
# 1924                            [aplikasi, error, mulu]
#
#                                                stemming
# 0     [tolong, udh, bayar, indihomenya, lost, jaring...
# 1                          [renew, fuf, clear, chahe, ]
# 2     [jaring, lot, nomor, dunia, mbps, bohong, capa...
# 3                    [lenot, boss, youtube, resolusi, ]
# 4     [gila, lambat, banget, wifinya, mbps, serasa, ...
# ...                                                 ...
# 1919  [cemen, ganggu, mending, cari, provider, deh, ...
# 1920  [indihome, gercep, lapor, pagi, tgl, feb, tekn...
# 1921  [sinyal, putus, lot, pokok, nyesal, deh, langg...
# 1923                          [knpa, cek, kuota, pakai]
# 1924                            [aplikasi, error, mulu]
#
# [1769 rows x 6 columns]

# %%
Final = df[['stemming','score']]
Final = Final.rename(columns={'stemming':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [tolong, udh, bayar, indihomenya, lost, jaring...      1
# 1                          [renew, fuf, clear, chahe, ]      1
# 2     [jaring, lot, nomor, dunia, mbps, bohong, capa...      1
# 3                    [lenot, boss, youtube, resolusi, ]      1
# 4     [gila, lambat, banget, wifinya, mbps, serasa, ...      1
# ...                                                 ...    ...
# 1919  [cemen, ganggu, mending, cari, provider, deh, ...      1
# 1920  [indihome, gercep, lapor, pagi, tgl, feb, tekn...      1
# 1921  [sinyal, putus, lot, pokok, nyesal, deh, langg...      1
# 1923                          [knpa, cek, kuota, pakai]      3
# 1924                            [aplikasi, error, mulu]      1
#
# [1769 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_2.xlsx')
