# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                content  score
# 0    Awal pemasangan good kenpa pas mau berhenti be...      1
# 1    Bayar selalu rutin tapi tiap bulannya internet...      1
# 2    Sering putus jaringan nya indihome, masa hampi...      3
# 3                               sangat membantu, good👍      5
# 4                                            Ok banget      5
# ..                                                 ...    ...
# 980  Saya peguna lama saya sangat kecewa sekarang l...      1
# 981  Laporan kendala dari kemaren jam 11 siang samp...      1
# 982                                            Kereeen      5
# 983  Lucu ini aplikasi. Kemarin sebelum verifikasi ...      1
# 984                                             mantap      5
#
# [985 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 41

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                content  score
# 0    Awal pemasangan good kenpa pas mau berhenti be...      1
# 1    Bayar selalu rutin tapi tiap bulannya internet...      1
# 2    Sering putus jaringan nya indihome, masa hampi...      3
# 3                               sangat membantu, good👍      5
# 5    Rencana ingin berlangganan indihome , Liat pen...      1
# ..                                                 ...    ...
# 980  Saya peguna lama saya sangat kecewa sekarang l...      1
# 981  Laporan kendala dari kemaren jam 11 siang samp...      1
# 982                                            Kereeen      5
# 983  Lucu ini aplikasi. Kemarin sebelum verifikasi ...      1
# 984                                             mantap      5
#
# [930 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                content  score
# 0    awal pemasangan good kenpa pas mau berhenti be...      1
# 1    bayar selalu rutin tapi tiap bulannya internet...      1
# 2    sering putus jaringan nya indihome, masa hampi...      3
# 3                               sangat membantu, good👍      5
# 5    rencana ingin berlangganan indihome , liat pen...      1
# ..                                                 ...    ...
# 980  saya peguna lama saya sangat kecewa sekarang l...      1
# 981  laporan kendala dari kemaren jam 11 siang samp...      1
# 982                                            kereeen      5
# 983  lucu ini aplikasi. kemarin sebelum verifikasi ...      1
# 984                                             mantap      5
#
# [930 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                content  score  \
# 0    awal pemasangan good kenpa pas mau berhenti be...      1
# 1    bayar selalu rutin tapi tiap bulannya internet...      1
# 2    sering putus jaringan nya indihome, masa hampi...      3
# 3                               sangat membantu, good👍      5
# 5    rencana ingin berlangganan indihome , liat pen...      1
# ..                                                 ...    ...
# 980  saya peguna lama saya sangat kecewa sekarang l...      1
# 981  laporan kendala dari kemaren jam 11 siang samp...      1
# 982                                            kereeen      5
# 983  lucu ini aplikasi. kemarin sebelum verifikasi ...      1
# 984                                             mantap      5
#
#                                       cleaning_content
# 0    awal pemasangan good kenpa pas mau berhenti be...
# 1    bayar selalu rutin tapi tiap bulannya internet...
# 2    sering putus jaringan nya indihome masa hampir...
# 3                                sangat membantu good
# 5    rencana ingin berlangganan indihome liat penil...
# ..                                                 ...
# 980  saya peguna lama saya sangat kecewa sekarang l...
# 981  laporan kendala dari kemaren jam siang sampai ...
# 982                                            kereeen
# 983  lucu ini aplikasi kemarin sebelum verifikasi d...
# 984                                             mantap
#
# [930 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                content  score  \
# 0    awal pemasangan good kenpa pas mau berhenti be...      1
# 1    bayar selalu rutin tapi tiap bulannya internet...      1
# 2    sering putus jaringan nya indihome, masa hampi...      3
# 3                               sangat membantu, good👍      5
# 5    rencana ingin berlangganan indihome , liat pen...      1
# ..                                                 ...    ...
# 980  saya peguna lama saya sangat kecewa sekarang l...      1
# 981  laporan kendala dari kemaren jam 11 siang samp...      1
# 982                                            kereeen      5
# 983  lucu ini aplikasi. kemarin sebelum verifikasi ...      1
# 984                                             mantap      5
#
#                                       cleaning_content  \
# 0    awal pemasangan good kenpa pas mau berhenti be...
# 1    bayar selalu rutin tapi tiap bulannya internet...
# 2    sering putus jaringan nya indihome masa hampir...
# 3                                sangat membantu good
# 5    rencana ingin berlangganan indihome liat penil...
# ..                                                 ...
# 980  saya peguna lama saya sangat kecewa sekarang l...
# 981  laporan kendala dari kemaren jam siang sampai ...
# 982                                            kereeen
# 983  lucu ini aplikasi kemarin sebelum verifikasi d...
# 984                                             mantap
#
#                                             tokenisasi
# 0    [awal, pemasangan, good, kenpa, pas, mau, berh...
# 1    [bayar, selalu, rutin, tapi, tiap, bulannya, i...
# 2    [sering, putus, jaringan, nya, indihome, masa,...
# 3                           [sangat, membantu, good, ]
# 5    [rencana, ingin, berlangganan, indihome, liat,...
# ..                                                 ...
# 980  [saya, peguna, lama, saya, sangat, kecewa, sek...
# 981  [laporan, kendala, dari, kemaren, jam, siang, ...
# 982                                          [kereeen]
# 983  [lucu, ini, aplikasi, kemarin, sebelum, verifi...
# 984                                           [mantap]
#
# [930 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                content  score  \
# 0    awal pemasangan good kenpa pas mau berhenti be...      1
# 1    bayar selalu rutin tapi tiap bulannya internet...      1
# 2    sering putus jaringan nya indihome, masa hampi...      3
# 3                               sangat membantu, good👍      5
# 5    rencana ingin berlangganan indihome , liat pen...      1
# ..                                                 ...    ...
# 980  saya peguna lama saya sangat kecewa sekarang l...      1
# 981  laporan kendala dari kemaren jam 11 siang samp...      1
# 982                                            kereeen      5
# 983  lucu ini aplikasi. kemarin sebelum verifikasi ...      1
# 984                                             mantap      5
#
#                                       cleaning_content  \
# 0    awal pemasangan good kenpa pas mau berhenti be...
# 1    bayar selalu rutin tapi tiap bulannya internet...
# 2    sering putus jaringan nya indihome masa hampir...
# 3                                sangat membantu good
# 5    rencana ingin berlangganan indihome liat penil...
# ..                                                 ...
# 980  saya peguna lama saya sangat kecewa sekarang l...
# 981  laporan kendala dari kemaren jam siang sampai ...
# 982                                            kereeen
# 983  lucu ini aplikasi kemarin sebelum verifikasi d...
# 984                                             mantap
#
#                                             tokenisasi  \
# 0    [awal, pemasangan, good, kenpa, pas, mau, berh...
# 1    [bayar, selalu, rutin, tapi, tiap, bulannya, i...
# 2    [sering, putus, jaringan, nya, indihome, masa,...
# 3                           [sangat, membantu, good, ]
# 5    [rencana, ingin, berlangganan, indihome, liat,...
# ..                                                 ...
# 980  [saya, peguna, lama, saya, sangat, kecewa, sek...
# 981  [laporan, kendala, dari, kemaren, jam, siang, ...
# 982                                          [kereeen]
# 983  [lucu, ini, aplikasi, kemarin, sebelum, verifi...
# 984                                           [mantap]
#
#                                               stopword
# 0    [pemasangan, good, kenpa, pas, berhenti, berla...
# 1    [bayar, rutin, bulannya, internet, bermasalah,...
# 2    [putus, jaringan, indihome, stabil, tolong, pe...
# 3                                   [membantu, good, ]
# 5    [rencana, berlangganan, indihome, liat, penila...
# ..                                                 ...
# 980  [peguna, kecewa, lelet, mbps, naikkan, mbps, l...
# 981  [laporan, kendala, kemaren, jam, siang, jam, p...
# 982                                          [kereeen]
# 983  [lucu, aplikasi, kemarin, verifikasi, data, bu...
# 984                                           [mantap]
#
# [930 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                            text_review  score
# 0    [pemasangan, good, kenpa, pas, berhenti, berla...      1
# 1    [bayar, rutin, bulannya, internet, bermasalah,...      1
# 2    [putus, jaringan, indihome, stabil, tolong, pe...      3
# 3                                   [membantu, good, ]      5
# 5    [rencana, berlangganan, indihome, liat, penila...      1
# ..                                                 ...    ...
# 980  [peguna, kecewa, lelet, mbps, naikkan, mbps, l...      1
# 981  [laporan, kendala, kemaren, jam, siang, jam, p...      1
# 982                                          [kereeen]      5
# 983  [lucu, aplikasi, kemarin, verifikasi, data, bu...      1
# 984                                           [mantap]      5
#
# [930 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_6.xlsx')
