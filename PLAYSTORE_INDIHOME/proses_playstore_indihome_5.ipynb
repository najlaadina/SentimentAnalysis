# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                content  score
# 0                                    aplikasinya lelet      1
# 1    Buat apa download aplikasi ini??? Dan untuk ap...      1
# 2                                             Membantu      5
# 3    Ada fitur yang tidak jalan, misal tidak bisa u...      3
# 4    Aplikasi nya ribet mau check tagihan indihome ...      1
# ..                                                 ...    ...
# 755  Pelayanan yang sangat-sangat buruk,di telpon s...      1
# 756  Parah sih,indihome blum kembalikan uang jamina...      2
# 757                                                Top      5
# 758  Baru semalem ,sekarang trable lagi,gmm sih ind...      1
# 759                                Koprett pelayanan 0      1
#
# [760 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 34

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                content  score
# 0                                    aplikasinya lelet      1
# 1    Buat apa download aplikasi ini??? Dan untuk ap...      1
# 2                                             Membantu      5
# 3    Ada fitur yang tidak jalan, misal tidak bisa u...      3
# 4    Aplikasi nya ribet mau check tagihan indihome ...      1
# ..                                                 ...    ...
# 754               Jaringan jelek mulu, WIFI Autis gblk      1
# 755  Pelayanan yang sangat-sangat buruk,di telpon s...      1
# 756  Parah sih,indihome blum kembalikan uang jamina...      2
# 758  Baru semalem ,sekarang trable lagi,gmm sih ind...      1
# 759                                Koprett pelayanan 0      1
#
# [716 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                content  score
# 0                                    aplikasinya lelet      1
# 1    buat apa download aplikasi ini??? dan untuk ap...      1
# 2                                             membantu      5
# 3    ada fitur yang tidak jalan, misal tidak bisa u...      3
# 4    aplikasi nya ribet mau check tagihan indihome ...      1
# ..                                                 ...    ...
# 754               jaringan jelek mulu, wifi autis gblk      1
# 755  pelayanan yang sangat-sangat buruk,di telpon s...      1
# 756  parah sih,indihome blum kembalikan uang jamina...      2
# 758  baru semalem ,sekarang trable lagi,gmm sih ind...      1
# 759                                koprett pelayanan 0      1
#
# [716 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                content  score  \
# 0                                    aplikasinya lelet      1
# 1    buat apa download aplikasi ini??? dan untuk ap...      1
# 2                                             membantu      5
# 3    ada fitur yang tidak jalan, misal tidak bisa u...      3
# 4    aplikasi nya ribet mau check tagihan indihome ...      1
# ..                                                 ...    ...
# 754               jaringan jelek mulu, wifi autis gblk      1
# 755  pelayanan yang sangat-sangat buruk,di telpon s...      1
# 756  parah sih,indihome blum kembalikan uang jamina...      2
# 758  baru semalem ,sekarang trable lagi,gmm sih ind...      1
# 759                                koprett pelayanan 0      1
#
#                                       cleaning_content
# 0                                    aplikasinya lelet
# 1    buat apa download aplikasi ini dan untuk apa a...
# 2                                             membantu
# 3    ada fitur yang tidak jalan misal tidak bisa un...
# 4    aplikasi nya ribet mau check tagihan indihome ...
# ..                                                 ...
# 754                jaringan jelek mulu wifi autis gblk
# 755  pelayanan yang sangat sangat buruk telpon sok ...
# 756  parah sih indihome blum kembalikan uang jamina...
# 758  baru semalem sekarang trable lagi gmm sih indi...
# 759                                 koprett pelayanan
#
# [716 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                content  score  \
# 0                                    aplikasinya lelet      1
# 1    buat apa download aplikasi ini??? dan untuk ap...      1
# 2                                             membantu      5
# 3    ada fitur yang tidak jalan, misal tidak bisa u...      3
# 4    aplikasi nya ribet mau check tagihan indihome ...      1
# ..                                                 ...    ...
# 754               jaringan jelek mulu, wifi autis gblk      1
# 755  pelayanan yang sangat-sangat buruk,di telpon s...      1
# 756  parah sih,indihome blum kembalikan uang jamina...      2
# 758  baru semalem ,sekarang trable lagi,gmm sih ind...      1
# 759                                koprett pelayanan 0      1
#
#                                       cleaning_content  \
# 0                                    aplikasinya lelet
# 1    buat apa download aplikasi ini dan untuk apa a...
# 2                                             membantu
# 3    ada fitur yang tidak jalan misal tidak bisa un...
# 4    aplikasi nya ribet mau check tagihan indihome ...
# ..                                                 ...
# 754                jaringan jelek mulu wifi autis gblk
# 755  pelayanan yang sangat sangat buruk telpon sok ...
# 756  parah sih indihome blum kembalikan uang jamina...
# 758  baru semalem sekarang trable lagi gmm sih indi...
# 759                                 koprett pelayanan
#
#                                             tokenisasi
# 0                                 [aplikasinya, lelet]
# 1    [buat, apa, download, aplikasi, ini, dan, untu...
# 2                                           [membantu]
# 3    [ada, fitur, yang, tidak, jalan, misal, tidak,...
# 4    [aplikasi, nya, ribet, mau, check, tagihan, in...
# ..                                                 ...
# 754         [jaringan, jelek, mulu, wifi, autis, gblk]
# 755  [pelayanan, yang, sangat, sangat, buruk, telpo...
# 756  [parah, sih, indihome, blum, kembalikan, uang,...
# 758  [baru, semalem, sekarang, trable, lagi, gmm, s...
# 759                             [koprett, pelayanan, ]
#
# [716 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                content  score  \
# 0                                    aplikasinya lelet      1
# 1    buat apa download aplikasi ini??? dan untuk ap...      1
# 2                                             membantu      5
# 3    ada fitur yang tidak jalan, misal tidak bisa u...      3
# 4    aplikasi nya ribet mau check tagihan indihome ...      1
# ..                                                 ...    ...
# 754               jaringan jelek mulu, wifi autis gblk      1
# 755  pelayanan yang sangat-sangat buruk,di telpon s...      1
# 756  parah sih,indihome blum kembalikan uang jamina...      2
# 758  baru semalem ,sekarang trable lagi,gmm sih ind...      1
# 759                                koprett pelayanan 0      1
#
#                                       cleaning_content  \
# 0                                    aplikasinya lelet
# 1    buat apa download aplikasi ini dan untuk apa a...
# 2                                             membantu
# 3    ada fitur yang tidak jalan misal tidak bisa un...
# 4    aplikasi nya ribet mau check tagihan indihome ...
# ..                                                 ...
# 754                jaringan jelek mulu wifi autis gblk
# 755  pelayanan yang sangat sangat buruk telpon sok ...
# 756  parah sih indihome blum kembalikan uang jamina...
# 758  baru semalem sekarang trable lagi gmm sih indi...
# 759                                 koprett pelayanan
#
#                                             tokenisasi  \
# 0                                 [aplikasinya, lelet]
# 1    [buat, apa, download, aplikasi, ini, dan, untu...
# 2                                           [membantu]
# 3    [ada, fitur, yang, tidak, jalan, misal, tidak,...
# 4    [aplikasi, nya, ribet, mau, check, tagihan, in...
# ..                                                 ...
# 754         [jaringan, jelek, mulu, wifi, autis, gblk]
# 755  [pelayanan, yang, sangat, sangat, buruk, telpo...
# 756  [parah, sih, indihome, blum, kembalikan, uang,...
# 758  [baru, semalem, sekarang, trable, lagi, gmm, s...
# 759                             [koprett, pelayanan, ]
#
#                                               stopword
# 0                                 [aplikasinya, lelet]
# 1    [download, aplikasi, aplikasi, lapor, gangguan...
# 2                                           [membantu]
# 3                    [fitur, jalan, untik, renewspeed]
# 4    [aplikasi, ribet, check, tagihan, indihome, up...
# ..                                                 ...
# 754         [jaringan, jelek, mulu, wifi, autis, gblk]
# 755  [pelayanan, buruk, telpon, sok, ngartis, respo...
# 756  [parah, indihome, blum, kembalikan, uang, jami...
# 758  [semalem, trable, gmm, indihome, udah, bayar, ...
# 759                             [koprett, pelayanan, ]
#
# [716 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                            text_review  score
# 0                                 [aplikasinya, lelet]      1
# 1    [download, aplikasi, aplikasi, lapor, gangguan...      1
# 2                                           [membantu]      5
# 3                    [fitur, jalan, untik, renewspeed]      3
# 4    [aplikasi, ribet, check, tagihan, indihome, up...      1
# ..                                                 ...    ...
# 754         [jaringan, jelek, mulu, wifi, autis, gblk]      1
# 755  [pelayanan, buruk, telpon, sok, ngartis, respo...      1
# 756  [parah, indihome, blum, kembalikan, uang, jami...      2
# 758  [semalem, trable, gmm, indihome, udah, bayar, ...      1
# 759                             [koprett, pelayanan, ]      1
#
# [716 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_5.xlsx')
