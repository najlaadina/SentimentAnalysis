# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Harga tiba2 naik sendiri tanpa pemberitahuan, ...      1
# 1     Tolong di benerin lagi indihome nya knp setiap...      1
# 2     Aplikasi tidak berguna, di update terus tapi k...      1
# 3     Apanya yg di fix coba, aplikasi masih tetep le...      1
# 4     Layanan internet di rumah saya bagus dan lanca...      5
# ...                                                 ...    ...
# 1995  Indihome memang terbaik, jarang ada gangguan, ...      5
# 1996  Saya selalu di permainkan oleh pihak indihome,...      1
# 1997                                             Daftar      3
# 1998                     App nya lemot kayak koneksinya      1
# 1999  mangkin ke sini mangkin gaa jelas, ada saja ma...      1
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 90

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Harga tiba2 naik sendiri tanpa pemberitahuan, ...      1
# 1     Tolong di benerin lagi indihome nya knp setiap...      1
# 2     Aplikasi tidak berguna, di update terus tapi k...      1
# 3     Apanya yg di fix coba, aplikasi masih tetep le...      1
# 4     Layanan internet di rumah saya bagus dan lanca...      5
# ...                                                 ...    ...
# 2044  Saya ada masalah internet saya sdh download my...      3
# 2045  Tambah lama pelayanan tambah menurun, fitur pe...      1
# 2046                     Teknisi lambat sekali datang 😰      1
# 2047  Koneksi Yang Sangat Tidak Bagus, Awal - Awal P...      1
# 2048                Aplikasi ga guna, g bsa log in.....      1
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     harga tiba2 naik sendiri tanpa pemberitahuan, ...      1
# 1     tolong di benerin lagi indihome nya knp setiap...      1
# 2     aplikasi tidak berguna, di update terus tapi k...      1
# 3     apanya yg di fix coba, aplikasi masih tetep le...      1
# 4     layanan internet di rumah saya bagus dan lanca...      5
# ...                                                 ...    ...
# 2044  saya ada masalah internet saya sdh download my...      3
# 2045  tambah lama pelayanan tambah menurun, fitur pe...      1
# 2046                     teknisi lambat sekali datang 😰      1
# 2047  koneksi yang sangat tidak bagus, awal - awal p...      1
# 2048                aplikasi ga guna, g bsa log in.....      1
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     harga tiba2 naik sendiri tanpa pemberitahuan, ...      1
# 1     tolong di benerin lagi indihome nya knp setiap...      1
# 2     aplikasi tidak berguna, di update terus tapi k...      1
# 3     apanya yg di fix coba, aplikasi masih tetep le...      1
# 4     layanan internet di rumah saya bagus dan lanca...      5
# ...                                                 ...    ...
# 2044  saya ada masalah internet saya sdh download my...      3
# 2045  tambah lama pelayanan tambah menurun, fitur pe...      1
# 2046                     teknisi lambat sekali datang 😰      1
# 2047  koneksi yang sangat tidak bagus, awal - awal p...      1
# 2048                aplikasi ga guna, g bsa log in.....      1
#
#                                        cleaning_content
# 0     harga tiba  naik sendiri tanpa pemberitahuan l...
# 1     tolong benerin lagi indihome nya knp setiap ja...
# 2     aplikasi tidak berguna update terus tapi kagak...
# 3     apanya fix coba aplikasi masih tetep lemot sem...
# 4     layanan internet rumah saya bagus dan lancar t...
# ...                                                 ...
# 2044  saya ada masalah internet saya sdh download my...
# 2045  tambah lama pelayanan tambah menurun fitur pen...
# 2046                      teknisi lambat sekali datang
# 2047  koneksi yang sangat tidak bagus awal awal pasa...
# 2048                             aplikasi guna bsa log
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     harga tiba2 naik sendiri tanpa pemberitahuan, ...      1
# 1     tolong di benerin lagi indihome nya knp setiap...      1
# 2     aplikasi tidak berguna, di update terus tapi k...      1
# 3     apanya yg di fix coba, aplikasi masih tetep le...      1
# 4     layanan internet di rumah saya bagus dan lanca...      5
# ...                                                 ...    ...
# 2044  saya ada masalah internet saya sdh download my...      3
# 2045  tambah lama pelayanan tambah menurun, fitur pe...      1
# 2046                     teknisi lambat sekali datang 😰      1
# 2047  koneksi yang sangat tidak bagus, awal - awal p...      1
# 2048                aplikasi ga guna, g bsa log in.....      1
#
#                                        cleaning_content  \
# 0     harga tiba  naik sendiri tanpa pemberitahuan l...
# 1     tolong benerin lagi indihome nya knp setiap ja...
# 2     aplikasi tidak berguna update terus tapi kagak...
# 3     apanya fix coba aplikasi masih tetep lemot sem...
# 4     layanan internet rumah saya bagus dan lancar t...
# ...                                                 ...
# 2044  saya ada masalah internet saya sdh download my...
# 2045  tambah lama pelayanan tambah menurun fitur pen...
# 2046                      teknisi lambat sekali datang
# 2047  koneksi yang sangat tidak bagus awal awal pasa...
# 2048                             aplikasi guna bsa log
#
#                                              tokenisasi
# 0     [harga, tiba, naik, sendiri, tanpa, pemberitah...
# 1     [tolong, benerin, lagi, indihome, nya, knp, se...
# 2     [aplikasi, tidak, berguna, update, terus, tapi...
# 3     [apanya, fix, coba, aplikasi, masih, tetep, le...
# 4     [layanan, internet, rumah, saya, bagus, dan, l...
# ...                                                 ...
# 2044  [saya, ada, masalah, internet, saya, sdh, down...
# 2045  [tambah, lama, pelayanan, tambah, menurun, fit...
# 2046                [teknisi, lambat, sekali, datang, ]
# 2047  [koneksi, yang, sangat, tidak, bagus, awal, aw...
# 2048                       [aplikasi, guna, bsa, log, ]
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["in","pas", "ajg", "bge", "ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     harga tiba2 naik sendiri tanpa pemberitahuan, ...      1
# 1     tolong di benerin lagi indihome nya knp setiap...      1
# 2     aplikasi tidak berguna, di update terus tapi k...      1
# 3     apanya yg di fix coba, aplikasi masih tetep le...      1
# 4     layanan internet di rumah saya bagus dan lanca...      5
# ...                                                 ...    ...
# 2044  saya ada masalah internet saya sdh download my...      3
# 2045  tambah lama pelayanan tambah menurun, fitur pe...      1
# 2046                     teknisi lambat sekali datang 😰      1
# 2047  koneksi yang sangat tidak bagus, awal - awal p...      1
# 2048                aplikasi ga guna, g bsa log in.....      1
#
#                                        cleaning_content  \
# 0     harga tiba  naik sendiri tanpa pemberitahuan l...
# 1     tolong benerin lagi indihome nya knp setiap ja...
# 2     aplikasi tidak berguna update terus tapi kagak...
# 3     apanya fix coba aplikasi masih tetep lemot sem...
# 4     layanan internet rumah saya bagus dan lancar t...
# ...                                                 ...
# 2044  saya ada masalah internet saya sdh download my...
# 2045  tambah lama pelayanan tambah menurun fitur pen...
# 2046                      teknisi lambat sekali datang
# 2047  koneksi yang sangat tidak bagus awal awal pasa...
# 2048                             aplikasi guna bsa log
#
#                                              tokenisasi  \
# 0     [harga, tiba, naik, sendiri, tanpa, pemberitah...
# 1     [tolong, benerin, lagi, indihome, nya, knp, se...
# 2     [aplikasi, tidak, berguna, update, terus, tapi...
# 3     [apanya, fix, coba, aplikasi, masih, tetep, le...
# 4     [layanan, internet, rumah, saya, bagus, dan, l...
# ...                                                 ...
# 2044  [saya, ada, masalah, internet, saya, sdh, down...
# 2045  [tambah, lama, pelayanan, tambah, menurun, fit...
# 2046                [teknisi, lambat, sekali, datang, ]
# 2047  [koneksi, yang, sangat, tidak, bagus, awal, aw...
# 2048                       [aplikasi, guna, bsa, log, ]
#
#                                                stopword
# 0     [harga, pemberitahuan, layanan, komplain, kena...
# 1     [tolong, benerin, indihome, knp, jam, malam, k...
# 2     [aplikasi, berguna, update, kagak, enak, enaknya]
# 3     [apanya, fix, coba, aplikasi, tetep, lemot, se...
# 4     [layanan, internet, rumah, bagus, lancar, teri...
# ...                                                 ...
# 2044  [internet, download, mylndihome, mtk, bantuan,...
# 2045  [pelayanan, menurun, fitur, laporan, dihilangk...
# 2046                                [teknisi, lambat, ]
# 2047  [koneksi, bagus, pasang, bagus, jelek, salut, ...
# 2048                             [aplikasi, bsa, log, ]
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [harga, pemberitahuan, layanan, komplain, kena...      1
# 1     [tolong, benerin, indihome, knp, jam, malam, k...      1
# 2     [aplikasi, berguna, update, kagak, enak, enaknya]      1
# 3     [apanya, fix, coba, aplikasi, tetep, lemot, se...      1
# 4     [layanan, internet, rumah, bagus, lancar, teri...      5
# ...                                                 ...    ...
# 4656                         [cepat, anti, lemot, suka]      5
# 4657                                [lemot, informatif]      1
# 4658  [buruk, aplikasi, indihome, upgrade, speed, sp...      1
# 4659  [aplikasinya, lelet, banget, loading, layanan,...      1
# 4660                    [skip, aplikasi, update, login]      1
#
# [4543 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_12.xlsx')
