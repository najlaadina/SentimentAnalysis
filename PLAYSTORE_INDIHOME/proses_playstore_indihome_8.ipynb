# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Ini Indihome lagi ada masalah apa ya ? Udah 3x...      1
# 1     Baru mau daftar tapi malah "Nomor Telah di Gun...      1
# 2     Aplikasi yang mudah untuk diakses, apalagi jik...      5
# 3     Sangat terbantu dgn adanya aplikasi myIndiHome...      5
# 4                                    Internet lag idiot      1
# ...                                                 ...    ...
# 1007           masuk untuk liat tagihan selalu di tolak      1
# 1008  Memakai layanan pengaduan dari aplikasi ini me...      1
# 1009  Wifi tersambung,tapi no internet?sedangkan kuo...      2
# 1010  Ampun bener nich telkom perusahaan plat merah ...      1
# 1011  Tolong dong jaringan diperbaiki masa 20mbps le...      1
#
# [1012 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 47

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Ini Indihome lagi ada masalah apa ya ? Udah 3x...      1
# 1     Baru mau daftar tapi malah "Nomor Telah di Gun...      1
# 2     Aplikasi yang mudah untuk diakses, apalagi jik...      5
# 3     Sangat terbantu dgn adanya aplikasi myIndiHome...      5
# 4                                    Internet lag idiot      1
# ...                                                 ...    ...
# 1007           masuk untuk liat tagihan selalu di tolak      1
# 1008  Memakai layanan pengaduan dari aplikasi ini me...      1
# 1009  Wifi tersambung,tapi no internet?sedangkan kuo...      2
# 1010  Ampun bener nich telkom perusahaan plat merah ...      1
# 1011  Tolong dong jaringan diperbaiki masa 20mbps le...      1
#
# [951 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     ini indihome lagi ada masalah apa ya ? udah 3x...      1
# 1     baru mau daftar tapi malah "nomor telah di gun...      1
# 2     aplikasi yang mudah untuk diakses, apalagi jik...      5
# 3     sangat terbantu dgn adanya aplikasi myindihome...      5
# 4                                    internet lag idiot      1
# ...                                                 ...    ...
# 1007           masuk untuk liat tagihan selalu di tolak      1
# 1008  memakai layanan pengaduan dari aplikasi ini me...      1
# 1009  wifi tersambung,tapi no internet?sedangkan kuo...      2
# 1010  ampun bener nich telkom perusahaan plat merah ...      1
# 1011  tolong dong jaringan diperbaiki masa 20mbps le...      1
#
# [951 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     ini indihome lagi ada masalah apa ya ? udah 3x...      1
# 1     baru mau daftar tapi malah "nomor telah di gun...      1
# 2     aplikasi yang mudah untuk diakses, apalagi jik...      5
# 3     sangat terbantu dgn adanya aplikasi myindihome...      5
# 4                                    internet lag idiot      1
# ...                                                 ...    ...
# 1007           masuk untuk liat tagihan selalu di tolak      1
# 1008  memakai layanan pengaduan dari aplikasi ini me...      1
# 1009  wifi tersambung,tapi no internet?sedangkan kuo...      2
# 1010  ampun bener nich telkom perusahaan plat merah ...      1
# 1011  tolong dong jaringan diperbaiki masa 20mbps le...      1
#
#                                        cleaning_content
# 0     ini indihome lagi ada masalah apa udah los nya...
# 1     baru mau daftar tapi malah nomor telah gunakan...
# 2     aplikasi yang mudah untuk diakses apalagi jika...
# 3     sangat terbantu dgn adanya aplikasi myindihome...
# 4                                    internet lag idiot
# ...                                                 ...
# 1007              masuk untuk liat tagihan selalu tolak
# 1008  memakai layanan pengaduan dari aplikasi ini me...
# 1009  wifi tersambung tapi internet sedangkan kuota ...
# 1010  ampun bener nich telkom perusahaan plat merah ...
# 1011  tolong dong jaringan diperbaiki masa  mbps lem...
#
# [951 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     ini indihome lagi ada masalah apa ya ? udah 3x...      1
# 1     baru mau daftar tapi malah "nomor telah di gun...      1
# 2     aplikasi yang mudah untuk diakses, apalagi jik...      5
# 3     sangat terbantu dgn adanya aplikasi myindihome...      5
# 4                                    internet lag idiot      1
# ...                                                 ...    ...
# 1007           masuk untuk liat tagihan selalu di tolak      1
# 1008  memakai layanan pengaduan dari aplikasi ini me...      1
# 1009  wifi tersambung,tapi no internet?sedangkan kuo...      2
# 1010  ampun bener nich telkom perusahaan plat merah ...      1
# 1011  tolong dong jaringan diperbaiki masa 20mbps le...      1
#
#                                        cleaning_content  \
# 0     ini indihome lagi ada masalah apa udah los nya...
# 1     baru mau daftar tapi malah nomor telah gunakan...
# 2     aplikasi yang mudah untuk diakses apalagi jika...
# 3     sangat terbantu dgn adanya aplikasi myindihome...
# 4                                    internet lag idiot
# ...                                                 ...
# 1007              masuk untuk liat tagihan selalu tolak
# 1008  memakai layanan pengaduan dari aplikasi ini me...
# 1009  wifi tersambung tapi internet sedangkan kuota ...
# 1010  ampun bener nich telkom perusahaan plat merah ...
# 1011  tolong dong jaringan diperbaiki masa  mbps lem...
#
#                                              tokenisasi
# 0     [ini, indihome, lagi, ada, masalah, apa, udah,...
# 1     [baru, mau, daftar, tapi, malah, nomor, telah,...
# 2     [aplikasi, yang, mudah, untuk, diakses, apalag...
# 3     [sangat, terbantu, dgn, adanya, aplikasi, myin...
# 4                                [internet, lag, idiot]
# ...                                                 ...
# 1007       [masuk, untuk, liat, tagihan, selalu, tolak]
# 1008  [memakai, layanan, pengaduan, dari, aplikasi, ...
# 1009  [wifi, tersambung, tapi, internet, sedangkan, ...
# 1010  [ampun, bener, nich, telkom, perusahaan, plat,...
# 1011  [tolong, dong, jaringan, diperbaiki, masa, mbp...
#
# [951 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     ini indihome lagi ada masalah apa ya ? udah 3x...      1
# 1     baru mau daftar tapi malah "nomor telah di gun...      1
# 2     aplikasi yang mudah untuk diakses, apalagi jik...      5
# 3     sangat terbantu dgn adanya aplikasi myindihome...      5
# 4                                    internet lag idiot      1
# ...                                                 ...    ...
# 1007           masuk untuk liat tagihan selalu di tolak      1
# 1008  memakai layanan pengaduan dari aplikasi ini me...      1
# 1009  wifi tersambung,tapi no internet?sedangkan kuo...      2
# 1010  ampun bener nich telkom perusahaan plat merah ...      1
# 1011  tolong dong jaringan diperbaiki masa 20mbps le...      1
#
#                                        cleaning_content  \
# 0     ini indihome lagi ada masalah apa udah los nya...
# 1     baru mau daftar tapi malah nomor telah gunakan...
# 2     aplikasi yang mudah untuk diakses apalagi jika...
# 3     sangat terbantu dgn adanya aplikasi myindihome...
# 4                                    internet lag idiot
# ...                                                 ...
# 1007              masuk untuk liat tagihan selalu tolak
# 1008  memakai layanan pengaduan dari aplikasi ini me...
# 1009  wifi tersambung tapi internet sedangkan kuota ...
# 1010  ampun bener nich telkom perusahaan plat merah ...
# 1011  tolong dong jaringan diperbaiki masa  mbps lem...
#
#                                              tokenisasi  \
# 0     [ini, indihome, lagi, ada, masalah, apa, udah,...
# 1     [baru, mau, daftar, tapi, malah, nomor, telah,...
# 2     [aplikasi, yang, mudah, untuk, diakses, apalag...
# 3     [sangat, terbantu, dgn, adanya, aplikasi, myin...
# 4                                [internet, lag, idiot]
# ...                                                 ...
# 1007       [masuk, untuk, liat, tagihan, selalu, tolak]
# 1008  [memakai, layanan, pengaduan, dari, aplikasi, ...
# 1009  [wifi, tersambung, tapi, internet, sedangkan, ...
# 1010  [ampun, bener, nich, telkom, perusahaan, plat,...
# 1011  [tolong, dong, jaringan, diperbaiki, masa, mbp...
#
#                                                stopword
# 0     [indihome, udah, los, merah, udah, dibenerin, ...
# 1     [daftar, nomor, pas, login, nomor, terdaftar, ...
# 2     [aplikasi, mudah, diakses, upgrade, speed, ter...
# 3     [terbantu, aplikasi, myindihome, pasang, mudah...
# 4                                [internet, lag, idiot]
# ...                                                 ...
# 1007                      [masuk, liat, tagihan, tolak]
# 1008  [memakai, layanan, pengaduan, aplikasi, mengec...
# 1009        [wifi, tersambung, internet, kuota, wifi, ]
# 1010  [ampun, bener, nich, telkom, perusahaan, plat,...
# 1011  [tolong, jaringan, diperbaiki, mbps, lemot, pe...
#
# [951 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [indihome, udah, los, merah, udah, dibenerin, ...      1
# 1     [daftar, nomor, pas, login, nomor, terdaftar, ...      1
# 2     [aplikasi, mudah, diakses, upgrade, speed, ter...      5
# 3     [terbantu, aplikasi, myindihome, pasang, mudah...      5
# 4                                [internet, lag, idiot]      1
# ...                                                 ...    ...
# 1007                      [masuk, liat, tagihan, tolak]      1
# 1008  [memakai, layanan, pengaduan, aplikasi, mengec...      1
# 1009        [wifi, tersambung, internet, kuota, wifi, ]      2
# 1010  [ampun, bener, nich, telkom, perusahaan, plat,...      1
# 1011  [tolong, jaringan, diperbaiki, mbps, lemot, pe...      1
#
# [951 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_8.xlsx')
