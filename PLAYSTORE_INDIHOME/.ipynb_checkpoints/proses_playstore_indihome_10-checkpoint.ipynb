# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Terdapat bug di bagian kelengkapan profil dan ...      2
# 1                                            no comment      5
# 2                                                    Ik      5
# 3     Bagaimana ini tiba tiba jaringan on offf... ma...      2
# 4                                   Tidak bisa diinstal      2
# ...                                                 ...    ...
# 1117  Jaringan sering Connection out.Ccd saya kasih ...      1
# 1118  Udah 2 tahun berlangganan,memang kdang kala ad...      5
# 1119  Sangat Rekomendasi!!Gak bakal rugi bossku Down...      5
# 1120  Ini kali yang ke2 saya udah ga tahan untuk die...      1
# 1121                           Cuma satu kata "amazing"      5
#
# [1122 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 58

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Terdapat bug di bagian kelengkapan profil dan ...      2
# 1                                            no comment      5
# 2                                                    Ik      5
# 3     Bagaimana ini tiba tiba jaringan on offf... ma...      2
# 4                                   Tidak bisa diinstal      2
# ...                                                 ...    ...
# 1117  Jaringan sering Connection out.Ccd saya kasih ...      1
# 1118  Udah 2 tahun berlangganan,memang kdang kala ad...      5
# 1119  Sangat Rekomendasi!!Gak bakal rugi bossku Down...      5
# 1120  Ini kali yang ke2 saya udah ga tahan untuk die...      1
# 1121                           Cuma satu kata "amazing"      5
#
# [1045 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     terdapat bug di bagian kelengkapan profil dan ...      2
# 1                                            no comment      5
# 2                                                    ik      5
# 3     bagaimana ini tiba tiba jaringan on offf... ma...      2
# 4                                   tidak bisa diinstal      2
# ...                                                 ...    ...
# 1117  jaringan sering connection out.ccd saya kasih ...      1
# 1118  udah 2 tahun berlangganan,memang kdang kala ad...      5
# 1119  sangat rekomendasi!!gak bakal rugi bossku down...      5
# 1120  ini kali yang ke2 saya udah ga tahan untuk die...      1
# 1121                           cuma satu kata "amazing"      5
#
# [1045 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     terdapat bug di bagian kelengkapan profil dan ...      2
# 1                                            no comment      5
# 2                                                    ik      5
# 3     bagaimana ini tiba tiba jaringan on offf... ma...      2
# 4                                   tidak bisa diinstal      2
# ...                                                 ...    ...
# 1117  jaringan sering connection out.ccd saya kasih ...      1
# 1118  udah 2 tahun berlangganan,memang kdang kala ad...      5
# 1119  sangat rekomendasi!!gak bakal rugi bossku down...      5
# 1120  ini kali yang ke2 saya udah ga tahan untuk die...      1
# 1121                           cuma satu kata "amazing"      5
#
#                                        cleaning_content
# 0     terdapat bug bagian kelengkapan profil dan riw...
# 1                                               comment
# 2
# 3     bagaimana ini tiba tiba jaringan offf matiii b...
# 4                                   tidak bisa diinstal
# ...                                                 ...
# 1117  jaringan sering connection out ccd saya kasih ...
# 1118  udah tahun berlangganan memang kdang kala ada ...
# 1119  sangat rekomendasi gak bakal rugi bossku downl...
# 1120  ini kali yang ke  saya udah tahan untuk diem k...
# 1121                            cuma satu kata amazing
#
# [1045 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     terdapat bug di bagian kelengkapan profil dan ...      2
# 1                                            no comment      5
# 2                                                    ik      5
# 3     bagaimana ini tiba tiba jaringan on offf... ma...      2
# 4                                   tidak bisa diinstal      2
# ...                                                 ...    ...
# 1117  jaringan sering connection out.ccd saya kasih ...      1
# 1118  udah 2 tahun berlangganan,memang kdang kala ad...      5
# 1119  sangat rekomendasi!!gak bakal rugi bossku down...      5
# 1120  ini kali yang ke2 saya udah ga tahan untuk die...      1
# 1121                           cuma satu kata "amazing"      5
#
#                                        cleaning_content  \
# 0     terdapat bug bagian kelengkapan profil dan riw...
# 1                                               comment
# 2
# 3     bagaimana ini tiba tiba jaringan offf matiii b...
# 4                                   tidak bisa diinstal
# ...                                                 ...
# 1117  jaringan sering connection out ccd saya kasih ...
# 1118  udah tahun berlangganan memang kdang kala ada ...
# 1119  sangat rekomendasi gak bakal rugi bossku downl...
# 1120  ini kali yang ke  saya udah tahan untuk diem k...
# 1121                            cuma satu kata amazing
#
#                                              tokenisasi
# 0     [terdapat, bug, bagian, kelengkapan, profil, d...
# 1                                           [, comment]
# 2                                                  [, ]
# 3     [bagaimana, ini, tiba, tiba, jaringan, offf, m...
# 4                               [tidak, bisa, diinstal]
# ...                                                 ...
# 1117  [jaringan, sering, connection, out, ccd, saya,...
# 1118  [udah, tahun, berlangganan, memang, kdang, kal...
# 1119  [sangat, rekomendasi, gak, bakal, rugi, bossku...
# 1120  [ini, kali, yang, ke, saya, udah, tahan, untuk...
# 1121                      [cuma, satu, kata, amazing, ]
#
# [1045 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["in","pas", "ajg", "bge", "ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     terdapat bug di bagian kelengkapan profil dan ...      2
# 1                                            no comment      5
# 2                                                    ik      5
# 3     bagaimana ini tiba tiba jaringan on offf... ma...      2
# 4                                   tidak bisa diinstal      2
# ...                                                 ...    ...
# 1117  jaringan sering connection out.ccd saya kasih ...      1
# 1118  udah 2 tahun berlangganan,memang kdang kala ad...      5
# 1119  sangat rekomendasi!!gak bakal rugi bossku down...      5
# 1120  ini kali yang ke2 saya udah ga tahan untuk die...      1
# 1121                           cuma satu kata "amazing"      5
#
#                                        cleaning_content  \
# 0     terdapat bug bagian kelengkapan profil dan riw...
# 1                                               comment
# 2
# 3     bagaimana ini tiba tiba jaringan offf matiii b...
# 4                                   tidak bisa diinstal
# ...                                                 ...
# 1117  jaringan sering connection out ccd saya kasih ...
# 1118  udah tahun berlangganan memang kdang kala ada ...
# 1119  sangat rekomendasi gak bakal rugi bossku downl...
# 1120  ini kali yang ke  saya udah tahan untuk diem k...
# 1121                            cuma satu kata amazing
#
#                                              tokenisasi  \
# 0     [terdapat, bug, bagian, kelengkapan, profil, d...
# 1                                           [, comment]
# 2                                                  [, ]
# 3     [bagaimana, ini, tiba, tiba, jaringan, offf, m...
# 4                               [tidak, bisa, diinstal]
# ...                                                 ...
# 1117  [jaringan, sering, connection, out, ccd, saya,...
# 1118  [udah, tahun, berlangganan, memang, kdang, kal...
# 1119  [sangat, rekomendasi, gak, bakal, rugi, bossku...
# 1120  [ini, kali, yang, ke, saya, udah, tahan, untuk...
# 1121                      [cuma, satu, kata, amazing, ]
#
#                                                stopword
# 0     [bug, kelengkapan, profil, riwayat, pembelian,...
# 1                                           [, comment]
# 2                                                  [, ]
# 3     [jaringan, offf, matiii, bayar, hrs, time, lay...
# 4                                            [diinstal]
# ...                                                 ...
# 1117  [jaringan, connection, out, ccd, kasih, gimana...
# 1118  [udah, berlangganan, kdang, gangguan, wajarlah...
# 1119  [rekomendasi, rugi, bossku, download, app, pak...
# 1120  [kali, udah, tahan, diem, buruk, buka, aplikas...
# 1121                                        [amazing, ]
#
# [1045 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [bug, kelengkapan, profil, riwayat, pembelian,...      2
# 1                                           [, comment]      5
# 2                                                  [, ]      5
# 3     [jaringan, offf, matiii, bayar, hrs, time, lay...      2
# 4                                            [diinstal]      2
# ...                                                 ...    ...
# 1117  [jaringan, connection, out, ccd, kasih, gimana...      1
# 1118  [udah, berlangganan, kdang, gangguan, wajarlah...      5
# 1119  [rekomendasi, rugi, bossku, download, app, pak...      5
# 1120  [kali, udah, tahan, diem, buruk, buka, aplikas...      1
# 1121                                        [amazing, ]      5
#
# [1045 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_10.xlsx')
