# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     aplikasinya lemot, loading nya lama banget pad...      1
# 1     pliss donk kapan bener nya ini APK masa seteng...      1
# 2     Aplikasi yang sangat membantu sekali yang puny...      5
# 3     Makin susah penggunaannya. Lebih baik di downg...      1
# 4                                        Mending biznet      1
# ...                                                 ...    ...
# 1995  Kacau lah. Aplikasi bis diupdate malah gbener....      2
# 1996  pakai aplikasi ini di masa pandemi emang palin...      5
# 1997                  Pembayarannya mudah bisa pakai QR      5
# 1998  Aplikasi ini memudahkan saya untuk mendapatkan...      5
# 1999  Tampilan baru, penanganan juga yang tadinya la...      5
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 155

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     aplikasinya lemot, loading nya lama banget pad...      1
# 1     pliss donk kapan bener nya ini APK masa seteng...      1
# 2     Aplikasi yang sangat membantu sekali yang puny...      5
# 3     Makin susah penggunaannya. Lebih baik di downg...      1
# 4                                        Mending biznet      1
# ...                                                 ...    ...
# 2101  Mohon aplikasi diperbaiki, ga berguna serius d...      1
# 2102  Akun. Saya. G bisa buka di aplikasi ini gimna ...      1
# 2103     Bayar harus lancar,tapi jaringan lemot.kecewa.      1
# 2104                       Update versi makin jelek aja      1
# 2105  Buruk. Saya gagal login. Email pemulihan nggak...      1
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     aplikasinya lemot, loading nya lama banget pad...      1
# 1     pliss donk kapan bener nya ini apk masa seteng...      1
# 2     aplikasi yang sangat membantu sekali yang puny...      5
# 3     makin susah penggunaannya. lebih baik di downg...      1
# 4                                        mending biznet      1
# ...                                                 ...    ...
# 2101  mohon aplikasi diperbaiki, ga berguna serius d...      1
# 2102  akun. saya. g bisa buka di aplikasi ini gimna ...      1
# 2103     bayar harus lancar,tapi jaringan lemot.kecewa.      1
# 2104                       update versi makin jelek aja      1
# 2105  buruk. saya gagal login. email pemulihan nggak...      1
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     aplikasinya lemot, loading nya lama banget pad...      1
# 1     pliss donk kapan bener nya ini apk masa seteng...      1
# 2     aplikasi yang sangat membantu sekali yang puny...      5
# 3     makin susah penggunaannya. lebih baik di downg...      1
# 4                                        mending biznet      1
# ...                                                 ...    ...
# 2101  mohon aplikasi diperbaiki, ga berguna serius d...      1
# 2102  akun. saya. g bisa buka di aplikasi ini gimna ...      1
# 2103     bayar harus lancar,tapi jaringan lemot.kecewa.      1
# 2104                       update versi makin jelek aja      1
# 2105  buruk. saya gagal login. email pemulihan nggak...      1
#
#                                        cleaning_content
# 0     aplikasinya lemot loading nya lama banget pada...
# 1     pliss donk kapan bener nya ini apk masa seteng...
# 2     aplikasi yang sangat membantu sekali yang puny...
# 3     makin susah penggunaannya lebih baik downgrade...
# 4                                        mending biznet
# ...                                                 ...
# 2101  mohon aplikasi diperbaiki berguna serius dah m...
# 2102  akun saya bisa buka aplikasi ini gimna sih mau...
# 2103     bayar harus lancar tapi jaringan lemot kecewa
# 2104                       update versi makin jelek aja
# 2105  buruk saya gagal login email pemulihan nggak b...
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     aplikasinya lemot, loading nya lama banget pad...      1
# 1     pliss donk kapan bener nya ini apk masa seteng...      1
# 2     aplikasi yang sangat membantu sekali yang puny...      5
# 3     makin susah penggunaannya. lebih baik di downg...      1
# 4                                        mending biznet      1
# ...                                                 ...    ...
# 2101  mohon aplikasi diperbaiki, ga berguna serius d...      1
# 2102  akun. saya. g bisa buka di aplikasi ini gimna ...      1
# 2103     bayar harus lancar,tapi jaringan lemot.kecewa.      1
# 2104                       update versi makin jelek aja      1
# 2105  buruk. saya gagal login. email pemulihan nggak...      1
#
#                                        cleaning_content  \
# 0     aplikasinya lemot loading nya lama banget pada...
# 1     pliss donk kapan bener nya ini apk masa seteng...
# 2     aplikasi yang sangat membantu sekali yang puny...
# 3     makin susah penggunaannya lebih baik downgrade...
# 4                                        mending biznet
# ...                                                 ...
# 2101  mohon aplikasi diperbaiki berguna serius dah m...
# 2102  akun saya bisa buka aplikasi ini gimna sih mau...
# 2103     bayar harus lancar tapi jaringan lemot kecewa
# 2104                       update versi makin jelek aja
# 2105  buruk saya gagal login email pemulihan nggak b...
#
#                                              tokenisasi
# 0     [aplikasinya, lemot, loading, nya, lama, bange...
# 1     [pliss, donk, kapan, bener, nya, ini, apk, mas...
# 2     [aplikasi, yang, sangat, membantu, sekali, yan...
# 3     [makin, susah, penggunaannya, lebih, baik, dow...
# 4                                     [mending, biznet]
# ...                                                 ...
# 2101  [mohon, aplikasi, diperbaiki, berguna, serius,...
# 2102  [akun, saya, bisa, buka, aplikasi, ini, gimna,...
# 2103  [bayar, harus, lancar, tapi, jaringan, lemot, ...
# 2104                 [update, versi, makin, jelek, aja]
# 2105  [buruk, saya, gagal, login, email, pemulihan, ...
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["in","pas", "ajg", "bge", "ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     aplikasinya lemot, loading nya lama banget pad...      1
# 1     pliss donk kapan bener nya ini apk masa seteng...      1
# 2     aplikasi yang sangat membantu sekali yang puny...      5
# 3     makin susah penggunaannya. lebih baik di downg...      1
# 4                                        mending biznet      1
# ...                                                 ...    ...
# 2101  mohon aplikasi diperbaiki, ga berguna serius d...      1
# 2102  akun. saya. g bisa buka di aplikasi ini gimna ...      1
# 2103     bayar harus lancar,tapi jaringan lemot.kecewa.      1
# 2104                       update versi makin jelek aja      1
# 2105  buruk. saya gagal login. email pemulihan nggak...      1
#
#                                        cleaning_content  \
# 0     aplikasinya lemot loading nya lama banget pada...
# 1     pliss donk kapan bener nya ini apk masa seteng...
# 2     aplikasi yang sangat membantu sekali yang puny...
# 3     makin susah penggunaannya lebih baik downgrade...
# 4                                        mending biznet
# ...                                                 ...
# 2101  mohon aplikasi diperbaiki berguna serius dah m...
# 2102  akun saya bisa buka aplikasi ini gimna sih mau...
# 2103     bayar harus lancar tapi jaringan lemot kecewa
# 2104                       update versi makin jelek aja
# 2105  buruk saya gagal login email pemulihan nggak b...
#
#                                              tokenisasi  \
# 0     [aplikasinya, lemot, loading, nya, lama, bange...
# 1     [pliss, donk, kapan, bener, nya, ini, apk, mas...
# 2     [aplikasi, yang, sangat, membantu, sekali, yan...
# 3     [makin, susah, penggunaannya, lebih, baik, dow...
# 4                                     [mending, biznet]
# ...                                                 ...
# 2101  [mohon, aplikasi, diperbaiki, berguna, serius,...
# 2102  [akun, saya, bisa, buka, aplikasi, ini, gimna,...
# 2103  [bayar, harus, lancar, tapi, jaringan, lemot, ...
# 2104                 [update, versi, makin, jelek, aja]
# 2105  [buruk, saya, gagal, login, email, pemulihan, ...
#
#                                                stopword
# 0     [aplikasinya, lemot, loading, banget, speed, w...
# 1     [pliss, donk, bener, apk, jam, loading, doang,...
# 2     [aplikasi, membantu, wifi, setabil, pakai, ind...
# 3     [susah, penggunaannya, downgrade, versi, user,...
# 4                                     [mending, biznet]
# ...                                                 ...
# 2101  [mohon, aplikasi, diperbaiki, berguna, serius,...
# 2102  [akun, buka, aplikasi, gimna, byr, klu, aplika...
# 2103         [bayar, lancar, jaringan, lemot, kecewa, ]
# 2104                             [update, versi, jelek]
# 2105  [buruk, gagal, login, email, pemulihan, nggak,...
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [aplikasinya, lemot, loading, banget, speed, w...      1
# 1     [pliss, donk, bener, apk, jam, loading, doang,...      1
# 2     [aplikasi, membantu, wifi, setabil, pakai, ind...      5
# 3     [susah, penggunaannya, downgrade, versi, user,...      1
# 4                                     [mending, biznet]      1
# ...                                                 ...    ...
# 3681                    [bayar, telat, gangguan, keren]      1
# 3682                             [aplikasi, bwt, bgung]      1
# 3683  [update, aplikasi, suka, ngefrezee, buka, apk,...      3
# 3685  [update, login, susah, nomer, sudh, aktif, kir...      4
# 3686  [taik, udh, reset, berkali, kali, tetep, dapet...      1
#
# [3485 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_11.xlsx')
