# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["text_review"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\databersih_english_playstore_indihome\databersih_english_playstore_indihome_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                             text_review
# 0     ['harga', 'pemberitahuan', 'layanan', 'komplai...
# 1     ['tolong', 'benerin', 'indihome', 'knp', 'jam'...
# 2     ['aplikasi', 'berguna', 'update', 'kagak', 'en...
# 3     ['apanya', 'fix', 'coba', 'aplikasi', 'tetep',...
# 4     ['layanan', 'internet', 'rumah', 'bagus', 'lan...
# ...                                                 ...
# 1995  ['internet', 'download', 'mylndihome', 'mtk', ...
# 1996  ['pelayanan', 'menurun', 'fitur', 'laporan', '...
# 1997                          ['teknisi', 'lambat', '']
# 1998  ['koneksi', 'bagus', 'pasang', 'bagus', 'jelek...
# 1999                     ['aplikasi', 'bsa', 'log', '']
#
# [2000 rows x 1 columns]

# %%
df['text_review'] = df['text_review'].str.lower()
df.head(2000)
# Out:
#                                             text_review
# 0     ['harga', 'pemberitahuan', 'layanan', 'komplai...
# 1     ['tolong', 'benerin', 'indihome', 'knp', 'jam'...
# 2     ['aplikasi', 'berguna', 'update', 'kagak', 'en...
# 3     ['apanya', 'fix', 'coba', 'aplikasi', 'tetep',...
# 4     ['layanan', 'internet', 'rumah', 'bagus', 'lan...
# ...                                                 ...
# 1995  ['internet', 'download', 'mylndihome', 'mtk', ...
# 1996  ['pelayanan', 'menurun', 'fitur', 'laporan', '...
# 1997                          ['teknisi', 'lambat', '']
# 1998  ['koneksi', 'bagus', 'pasang', 'bagus', 'jelek...
# 1999                     ['aplikasi', 'bsa', 'log', '']
#
# [2000 rows x 1 columns]

# %%
df['label_awal'] = ''
for i,x in df.text_review.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.0
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.0
# Index:  3 label_awal 0.1
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.0
# Index:  8 label_awal 0.0
# Index:  9 label_awal 0.0
# Index:  10 label_awal 0.0
# Index:  11 label_awal 0.0
# Index:  12 label_awal 0.0
# Index:  13 label_awal 0.0
# Index:  14 label_awal 0.0
# Index:  15 label_awal 0.0
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.5
# Index:  20 label_awal 0.0
# Index:  21 label_awal 0.0
# Index:  22 label_awal 0.0
# Index:  23 label_awal 0.0
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.0
# Index:  26 label_awal 0.0
# Index:  27 label_awal 0.0
# Index:  28 label_awal 0.0
# Index:  29 label_awal -0.2
# Index:  30 label_awal 0.0
# Index:  31 label_awal 0.1
# Index:  32 label_awal 0.0
# Index:  33 label_awal 0.0
# Index:  34 label_awal 0.375
# ...

# %%
df.head()
# Out:
#                                          text_review label_awal
# 0  ['harga', 'pemberitahuan', 'layanan', 'komplai...        0.0
# 1  ['tolong', 'benerin', 'indihome', 'knp', 'jam'...        0.0
# 2  ['aplikasi', 'berguna', 'update', 'kagak', 'en...        0.0
# 3  ['apanya', 'fix', 'coba', 'aplikasi', 'tetep',...        0.1
# 4  ['layanan', 'internet', 'rumah', 'bagus', 'lan...        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    4020
#  0.200000      59
# -0.116667      58
# -0.400000      48
#  0.500000      46
#              ...
#  0.650000       1
#  0.091667       1
# -0.400000       1
#  0.404167       1
#  0.450000       1
# Name: label_awal, Length: 74, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] < 0.0:
        label.append("negative")
    else:
        label.append("positive")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                             text_review     label
# 0     ['harga', 'pemberitahuan', 'layanan', 'komplai...  positive
# 1     ['tolong', 'benerin', 'indihome', 'knp', 'jam'...  positive
# 2     ['aplikasi', 'berguna', 'update', 'kagak', 'en...  positive
# 3     ['apanya', 'fix', 'coba', 'aplikasi', 'tetep',...  positive
# 4     ['layanan', 'internet', 'rumah', 'bagus', 'lan...  positive
# ...                                                 ...       ...
# 1995  ['internet', 'download', 'mylndihome', 'mtk', ...  positive
# 1996  ['pelayanan', 'menurun', 'fitur', 'laporan', '...  positive
# 1997                          ['teknisi', 'lambat', '']  positive
# 1998  ['koneksi', 'bagus', 'pasang', 'bagus', 'jelek...  positive
# 1999                     ['aplikasi', 'bsa', 'log', '']  positive
#
# [2000 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# positive    4370
# negative     173
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_playstore_indihome_12.xlsx')
