# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                content  score
# 0    Gangguan terusssss sedangkan bayar harus tepat...      1
# 1                Jaringan gajelas ping naik turun mulu      1
# 2    Tolong perbaikan sinya nya lh, kecepatan 20 mb...      1
# 3                                           Eror terus      1
# 4    Aplikasinya lemot, apa sinyalnya yg lemot, had...      1
# ..                                                 ...    ...
# 777                                     Gk bisa login.      1
# 778                                      TOP IndiHome!      5
# 779  Sinyalnya terparah setiap akhir bulan mendekat...      1
# 780                                               Suka      5
# 781  Tanpa fikir panjang, langsung cabut routernya,...      1
#
# [782 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 19

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                content  score
# 0    Gangguan terusssss sedangkan bayar harus tepat...      1
# 1                Jaringan gajelas ping naik turun mulu      1
# 2    Tolong perbaikan sinya nya lh, kecepatan 20 mb...      1
# 3                                           Eror terus      1
# 4    Aplikasinya lemot, apa sinyalnya yg lemot, had...      1
# ..                                                 ...    ...
# 777                                     Gk bisa login.      1
# 778                                      TOP IndiHome!      5
# 779  Sinyalnya terparah setiap akhir bulan mendekat...      1
# 780                                               Suka      5
# 781  Tanpa fikir panjang, langsung cabut routernya,...      1
#
# [755 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                content  score
# 0    gangguan terusssss sedangkan bayar harus tepat...      1
# 1                jaringan gajelas ping naik turun mulu      1
# 2    tolong perbaikan sinya nya lh, kecepatan 20 mb...      1
# 3                                           eror terus      1
# 4    aplikasinya lemot, apa sinyalnya yg lemot, had...      1
# ..                                                 ...    ...
# 777                                     gk bisa login.      1
# 778                                      top indihome!      5
# 779  sinyalnya terparah setiap akhir bulan mendekat...      1
# 780                                               suka      5
# 781  tanpa fikir panjang, langsung cabut routernya,...      1
#
# [755 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                content  score  \
# 0    gangguan terusssss sedangkan bayar harus tepat...      1
# 1                jaringan gajelas ping naik turun mulu      1
# 2    tolong perbaikan sinya nya lh, kecepatan 20 mb...      1
# 3                                           eror terus      1
# 4    aplikasinya lemot, apa sinyalnya yg lemot, had...      1
# ..                                                 ...    ...
# 777                                     gk bisa login.      1
# 778                                      top indihome!      5
# 779  sinyalnya terparah setiap akhir bulan mendekat...      1
# 780                                               suka      5
# 781  tanpa fikir panjang, langsung cabut routernya,...      1
#
#                                       cleaning_content
# 0    gangguan terusssss sedangkan bayar harus tepat...
# 1                jaringan gajelas ping naik turun mulu
# 2    tolong perbaikan sinya nya kecepatan mbps make...
# 3                                           eror terus
# 4    aplikasinya lemot apa sinyalnya lemot hadoh lo...
# ..                                                 ...
# 777                                        bisa login
# 778                                      top indihome
# 779  sinyalnya terparah setiap akhir bulan mendekat...
# 780                                               suka
# 781  tanpa fikir panjang langsung cabut routernya l...
#
# [755 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                content  score  \
# 0    gangguan terusssss sedangkan bayar harus tepat...      1
# 1                jaringan gajelas ping naik turun mulu      1
# 2    tolong perbaikan sinya nya lh, kecepatan 20 mb...      1
# 3                                           eror terus      1
# 4    aplikasinya lemot, apa sinyalnya yg lemot, had...      1
# ..                                                 ...    ...
# 777                                     gk bisa login.      1
# 778                                      top indihome!      5
# 779  sinyalnya terparah setiap akhir bulan mendekat...      1
# 780                                               suka      5
# 781  tanpa fikir panjang, langsung cabut routernya,...      1
#
#                                       cleaning_content  \
# 0    gangguan terusssss sedangkan bayar harus tepat...
# 1                jaringan gajelas ping naik turun mulu
# 2    tolong perbaikan sinya nya kecepatan mbps make...
# 3                                           eror terus
# 4    aplikasinya lemot apa sinyalnya lemot hadoh lo...
# ..                                                 ...
# 777                                        bisa login
# 778                                      top indihome
# 779  sinyalnya terparah setiap akhir bulan mendekat...
# 780                                               suka
# 781  tanpa fikir panjang langsung cabut routernya l...
#
#                                             tokenisasi
# 0    [gangguan, terusssss, sedangkan, bayar, harus,...
# 1         [jaringan, gajelas, ping, naik, turun, mulu]
# 2    [tolong, perbaikan, sinya, nya, kecepatan, mbp...
# 3                                        [eror, terus]
# 4    [aplikasinya, lemot, apa, sinyalnya, lemot, ha...
# ..                                                 ...
# 777                                  [, bisa, login, ]
# 778                                  [top, indihome, ]
# 779  [sinyalnya, terparah, setiap, akhir, bulan, me...
# 780                                             [suka]
# 781  [tanpa, fikir, panjang, langsung, cabut, route...
#
# [755 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                content  score  \
# 0    gangguan terusssss sedangkan bayar harus tepat...      1
# 1                jaringan gajelas ping naik turun mulu      1
# 2    tolong perbaikan sinya nya lh, kecepatan 20 mb...      1
# 3                                           eror terus      1
# 4    aplikasinya lemot, apa sinyalnya yg lemot, had...      1
# ..                                                 ...    ...
# 777                                     gk bisa login.      1
# 778                                      top indihome!      5
# 779  sinyalnya terparah setiap akhir bulan mendekat...      1
# 780                                               suka      5
# 781  tanpa fikir panjang, langsung cabut routernya,...      1
#
#                                       cleaning_content  \
# 0    gangguan terusssss sedangkan bayar harus tepat...
# 1                jaringan gajelas ping naik turun mulu
# 2    tolong perbaikan sinya nya kecepatan mbps make...
# 3                                           eror terus
# 4    aplikasinya lemot apa sinyalnya lemot hadoh lo...
# ..                                                 ...
# 777                                        bisa login
# 778                                      top indihome
# 779  sinyalnya terparah setiap akhir bulan mendekat...
# 780                                               suka
# 781  tanpa fikir panjang langsung cabut routernya l...
#
#                                             tokenisasi  \
# 0    [gangguan, terusssss, sedangkan, bayar, harus,...
# 1         [jaringan, gajelas, ping, naik, turun, mulu]
# 2    [tolong, perbaikan, sinya, nya, kecepatan, mbp...
# 3                                        [eror, terus]
# 4    [aplikasinya, lemot, apa, sinyalnya, lemot, ha...
# ..                                                 ...
# 777                                  [, bisa, login, ]
# 778                                  [top, indihome, ]
# 779  [sinyalnya, terparah, setiap, akhir, bulan, me...
# 780                                             [suka]
# 781  [tanpa, fikir, panjang, langsung, cabut, route...
#
#                                               stopword
# 0                         [gangguan, terusssss, bayar]
# 1               [jaringan, gajelas, ping, turun, mulu]
# 2    [tolong, perbaikan, sinya, kecepatan, mbps, ma...
# 3                                               [eror]
# 4    [aplikasinya, lemot, sinyalnya, lemot, hadoh, ...
# ..                                                 ...
# 777                                        [, login, ]
# 778                                  [top, indihome, ]
# 779  [sinyalnya, terparah, mendekati, tgl, eror, ga...
# 780                                             [suka]
# 781  [fikir, langsung, cabut, routernya, langsung, ...
#
# [755 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                            text_review  score
# 0                         [gangguan, terusssss, bayar]      1
# 1               [jaringan, gajelas, ping, turun, mulu]      1
# 2    [tolong, perbaikan, sinya, kecepatan, mbps, ma...      1
# 3                                               [eror]      1
# 4    [aplikasinya, lemot, sinyalnya, lemot, hadoh, ...      1
# ..                                                 ...    ...
# 777                                        [, login, ]      1
# 778                                  [top, indihome, ]      5
# 779  [sinyalnya, terparah, mendekati, tgl, eror, ga...      1
# 780                                             [suka]      5
# 781  [fikir, langsung, cabut, routernya, langsung, ...      1
#
# [755 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_7.xlsx')
