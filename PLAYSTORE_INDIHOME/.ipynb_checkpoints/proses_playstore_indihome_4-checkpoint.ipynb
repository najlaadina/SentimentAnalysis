# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_INDIHOME\data_mentah\playstore_indihome_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                content  score
# 0    Saya sampai menghapus game saya karna sinyal I...      1
# 1    Hi indihome Tolong hapus FUP nya dan kecepatan...      1
# 2    Gara" ada yang servis jaringan. teknisi ngawur...      1
# 3    Saya ingin nya deposi sebagai mana saya ingin ...      5
# 4    Saya tidak bisa login, kode otp yg dikirim ke ...      2
# ..                                                 ...    ...
# 851  Baru sehari pasang eh udah ngalamin kendala in...      1
# 852                                    Sangat nembantu      4
# 853                          Mending Jangan pasang lah      1
# 854  wifi apaan kyk gini 20mbps ngk mempan buat gam...      1
# 855                                      kualitas baik      4
#
# [856 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 54

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                content  score
# 0    Saya sampai menghapus game saya karna sinyal I...      1
# 1    Hi indihome Tolong hapus FUP nya dan kecepatan...      1
# 2    Gara" ada yang servis jaringan. teknisi ngawur...      1
# 3    Saya ingin nya deposi sebagai mana saya ingin ...      5
# 4    Saya tidak bisa login, kode otp yg dikirim ke ...      2
# ..                                                 ...    ...
# 851  Baru sehari pasang eh udah ngalamin kendala in...      1
# 852                                    Sangat nembantu      4
# 853                          Mending Jangan pasang lah      1
# 854  wifi apaan kyk gini 20mbps ngk mempan buat gam...      1
# 855                                      kualitas baik      4
#
# [789 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                content  score
# 0    saya sampai menghapus game saya karna sinyal i...      1
# 1    hi indihome tolong hapus fup nya dan kecepatan...      1
# 2    gara" ada yang servis jaringan. teknisi ngawur...      1
# 3    saya ingin nya deposi sebagai mana saya ingin ...      5
# 4    saya tidak bisa login, kode otp yg dikirim ke ...      2
# ..                                                 ...    ...
# 851  baru sehari pasang eh udah ngalamin kendala in...      1
# 852                                    sangat nembantu      4
# 853                          mending jangan pasang lah      1
# 854  wifi apaan kyk gini 20mbps ngk mempan buat gam...      1
# 855                                      kualitas baik      4
#
# [789 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                content  score  \
# 0    saya sampai menghapus game saya karna sinyal i...      1
# 1    hi indihome tolong hapus fup nya dan kecepatan...      1
# 2    gara" ada yang servis jaringan. teknisi ngawur...      1
# 3    saya ingin nya deposi sebagai mana saya ingin ...      5
# 4    saya tidak bisa login, kode otp yg dikirim ke ...      2
# ..                                                 ...    ...
# 851  baru sehari pasang eh udah ngalamin kendala in...      1
# 852                                    sangat nembantu      4
# 853                          mending jangan pasang lah      1
# 854  wifi apaan kyk gini 20mbps ngk mempan buat gam...      1
# 855                                      kualitas baik      4
#
#                                       cleaning_content
# 0    saya sampai menghapus game saya karna sinyal i...
# 1     indihome tolong hapus fup nya dan kecepatan u...
# 2    gara ada yang servis jaringan teknisi ngawur k...
# 3    saya ingin nya deposi sebagai mana saya ingin ...
# 4    saya tidak bisa login kode otp dikirim nomor s...
# ..                                                 ...
# 851  baru sehari pasang udah ngalamin kendala inter...
# 852                                    sangat nembantu
# 853                          mending jangan pasang lah
# 854  wifi apaan kyk gini  mbps ngk mempan buat game...
# 855                                      kualitas baik
#
# [789 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                content  score  \
# 0    saya sampai menghapus game saya karna sinyal i...      1
# 1    hi indihome tolong hapus fup nya dan kecepatan...      1
# 2    gara" ada yang servis jaringan. teknisi ngawur...      1
# 3    saya ingin nya deposi sebagai mana saya ingin ...      5
# 4    saya tidak bisa login, kode otp yg dikirim ke ...      2
# ..                                                 ...    ...
# 851  baru sehari pasang eh udah ngalamin kendala in...      1
# 852                                    sangat nembantu      4
# 853                          mending jangan pasang lah      1
# 854  wifi apaan kyk gini 20mbps ngk mempan buat gam...      1
# 855                                      kualitas baik      4
#
#                                       cleaning_content  \
# 0    saya sampai menghapus game saya karna sinyal i...
# 1     indihome tolong hapus fup nya dan kecepatan u...
# 2    gara ada yang servis jaringan teknisi ngawur k...
# 3    saya ingin nya deposi sebagai mana saya ingin ...
# 4    saya tidak bisa login kode otp dikirim nomor s...
# ..                                                 ...
# 851  baru sehari pasang udah ngalamin kendala inter...
# 852                                    sangat nembantu
# 853                          mending jangan pasang lah
# 854  wifi apaan kyk gini  mbps ngk mempan buat game...
# 855                                      kualitas baik
#
#                                             tokenisasi
# 0    [saya, sampai, menghapus, game, saya, karna, s...
# 1    [, indihome, tolong, hapus, fup, nya, dan, kec...
# 2    [gara, ada, yang, servis, jaringan, teknisi, n...
# 3    [saya, ingin, nya, deposi, sebagai, mana, saya...
# 4    [saya, tidak, bisa, login, kode, otp, dikirim,...
# ..                                                 ...
# 851  [baru, sehari, pasang, udah, ngalamin, kendala...
# 852                                 [sangat, nembantu]
# 853                     [mending, jangan, pasang, lah]
# 854  [wifi, apaan, kyk, gini, mbps, ngk, mempan, bu...
# 855                                   [kualitas, baik]
#
# [789 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["ke", "meng", "i" ,"me", "an", "di", "ter", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                content  score  \
# 0    saya sampai menghapus game saya karna sinyal i...      1
# 1    hi indihome tolong hapus fup nya dan kecepatan...      1
# 2    gara" ada yang servis jaringan. teknisi ngawur...      1
# 3    saya ingin nya deposi sebagai mana saya ingin ...      5
# 4    saya tidak bisa login, kode otp yg dikirim ke ...      2
# ..                                                 ...    ...
# 851  baru sehari pasang eh udah ngalamin kendala in...      1
# 852                                    sangat nembantu      4
# 853                          mending jangan pasang lah      1
# 854  wifi apaan kyk gini 20mbps ngk mempan buat gam...      1
# 855                                      kualitas baik      4
#
#                                       cleaning_content  \
# 0    saya sampai menghapus game saya karna sinyal i...
# 1     indihome tolong hapus fup nya dan kecepatan u...
# 2    gara ada yang servis jaringan teknisi ngawur k...
# 3    saya ingin nya deposi sebagai mana saya ingin ...
# 4    saya tidak bisa login kode otp dikirim nomor s...
# ..                                                 ...
# 851  baru sehari pasang udah ngalamin kendala inter...
# 852                                    sangat nembantu
# 853                          mending jangan pasang lah
# 854  wifi apaan kyk gini  mbps ngk mempan buat game...
# 855                                      kualitas baik
#
#                                             tokenisasi  \
# 0    [saya, sampai, menghapus, game, saya, karna, s...
# 1    [, indihome, tolong, hapus, fup, nya, dan, kec...
# 2    [gara, ada, yang, servis, jaringan, teknisi, n...
# 3    [saya, ingin, nya, deposi, sebagai, mana, saya...
# 4    [saya, tidak, bisa, login, kode, otp, dikirim,...
# ..                                                 ...
# 851  [baru, sehari, pasang, udah, ngalamin, kendala...
# 852                                 [sangat, nembantu]
# 853                     [mending, jangan, pasang, lah]
# 854  [wifi, apaan, kyk, gini, mbps, ngk, mempan, bu...
# 855                                   [kualitas, baik]
#
#                                               stopword
# 0    [menghapus, game, karna, sinyal, indihome, kua...
# 1    [, indihome, tolong, hapus, fup, kecepatan, up...
# 2    [gara, servis, jaringan, teknisi, ngawur, kone...
# 3                  [deposi, menginkan, kah, tuju, rek]
# 4    [login, kode, otp, dikirim, nomor, sms, salah,...
# ..                                                 ...
# 851  [sehari, pasang, udah, ngalamin, kendala, inte...
# 852                                         [nembantu]
# 853                                  [mending, pasang]
# 854  [wifi, kyk, gini, mbps, ngk, mempan, game, you...
# 855                                         [kualitas]
#
# [789 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                            text_review  score
# 0    [menghapus, game, karna, sinyal, indihome, kua...      1
# 1    [, indihome, tolong, hapus, fup, kecepatan, up...      1
# 2    [gara, servis, jaringan, teknisi, ngawur, kone...      1
# 3                  [deposi, menginkan, kah, tuju, rek]      5
# 4    [login, kode, otp, dikirim, nomor, sms, salah,...      2
# ..                                                 ...    ...
# 851  [sehari, pasang, udah, ngalamin, kendala, inte...      1
# 852                                         [nembantu]      4
# 853                                  [mending, pasang]      1
# 854  [wifi, kyk, gini, mbps, ngk, mempan, game, you...      1
# 855                                         [kualitas]      4
#
# [789 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_indihome_4.xlsx')
