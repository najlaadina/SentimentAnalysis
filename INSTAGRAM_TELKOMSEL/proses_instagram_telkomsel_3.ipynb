# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0    TELKOMSEL KENAPA DOWNLOAD SPEEDNYA CUMAN 3.85m...
# 1                               *500# untuk apa min???
# 2                                           CEK DM min
# 3    Telkomsel Maju Terus, Telkomsel Sinyal No.1❤️❤...
# 4                            Sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  Telkomsel Maju Terus, Telkomsel No.1 ❤️❤️❤️❤️❤...
# 168  Kalau boleh tau selain dari my telkomsel apaka...
# 169           Sinyal min urusin, indihome geh sama bae
# 170                           Jenengmu @adhi._ramadhan
# 171               Sinyal oh sinyal,. Mimin sinyal min
#
# [172 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 31

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0    TELKOMSEL KENAPA DOWNLOAD SPEEDNYA CUMAN 3.85m...
# 1                               *500# untuk apa min???
# 2                                           CEK DM min
# 3    Telkomsel Maju Terus, Telkomsel Sinyal No.1❤️❤...
# 4                            Sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  Telkomsel Maju Terus, Telkomsel No.1 ❤️❤️❤️❤️❤...
# 168  Kalau boleh tau selain dari my telkomsel apaka...
# 169           Sinyal min urusin, indihome geh sama bae
# 170                           Jenengmu @adhi._ramadhan
# 171               Sinyal oh sinyal,. Mimin sinyal min
#
# [134 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0    telkomsel kenapa download speednya cuman 3.85m...
# 1                               *500# untuk apa min???
# 2                                           cek dm min
# 3    telkomsel maju terus, telkomsel sinyal no.1❤️❤...
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  telkomsel maju terus, telkomsel no.1 ❤️❤️❤️❤️❤...
# 168  kalau boleh tau selain dari my telkomsel apaka...
# 169           sinyal min urusin, indihome geh sama bae
# 170                           jenengmu @adhi._ramadhan
# 171               sinyal oh sinyal,. mimin sinyal min
#
# [134 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0    telkomsel kenapa download speednya cuman 3.85m...
# 1                               *500# untuk apa min???
# 2                                           cek dm min
# 3    telkomsel maju terus, telkomsel sinyal no.1❤️❤...
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  telkomsel maju terus, telkomsel no.1 ❤️❤️❤️❤️❤...
# 168  kalau boleh tau selain dari my telkomsel apaka...
# 169           sinyal min urusin, indihome geh sama bae
# 170                           jenengmu @adhi._ramadhan
# 171               sinyal oh sinyal,. mimin sinyal min
#
#                                          cleaning_text
# 0    telkomsel kenapa download speednya cuman  mbps...
# 1                                       untuk apa min
# 2                                              cek min
# 3               telkomsel maju terus telkomsel sinyal
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167                    telkomsel maju terus telkomsel
# 168  kalau boleh tau selain dari telkomsel apakah b...
# 169            sinyal min urusin indihome geh sama bae
# 170                                  jenengmu ramadhan
# 171                     sinyal sinyal mimin sinyal min
#
# [134 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0    telkomsel kenapa download speednya cuman 3.85m...
# 1                               *500# untuk apa min???
# 2                                           cek dm min
# 3    telkomsel maju terus, telkomsel sinyal no.1❤️❤...
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  telkomsel maju terus, telkomsel no.1 ❤️❤️❤️❤️❤...
# 168  kalau boleh tau selain dari my telkomsel apaka...
# 169           sinyal min urusin, indihome geh sama bae
# 170                           jenengmu @adhi._ramadhan
# 171               sinyal oh sinyal,. mimin sinyal min
#
#                                          cleaning_text  \
# 0    telkomsel kenapa download speednya cuman  mbps...
# 1                                       untuk apa min
# 2                                              cek min
# 3               telkomsel maju terus telkomsel sinyal
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167                    telkomsel maju terus telkomsel
# 168  kalau boleh tau selain dari telkomsel apakah b...
# 169            sinyal min urusin indihome geh sama bae
# 170                                  jenengmu ramadhan
# 171                     sinyal sinyal mimin sinyal min
#
#                                             tokenisasi
# 0    [telkomsel, kenapa, download, speednya, cuman,...
# 1                                [, untuk, apa, min, ]
# 2                                           [cek, min]
# 3        [telkomsel, maju, terus, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167              [telkomsel, maju, terus, telkomsel, ]
# 168  [kalau, boleh, tau, selain, dari, telkomsel, a...
# 169    [sinyal, min, urusin, indihome, geh, sama, bae]
# 170                               [jenengmu, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
# [134 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0    telkomsel kenapa download speednya cuman 3.85m...
# 1                               *500# untuk apa min???
# 2                                           cek dm min
# 3    telkomsel maju terus, telkomsel sinyal no.1❤️❤...
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  telkomsel maju terus, telkomsel no.1 ❤️❤️❤️❤️❤...
# 168  kalau boleh tau selain dari my telkomsel apaka...
# 169           sinyal min urusin, indihome geh sama bae
# 170                           jenengmu @adhi._ramadhan
# 171               sinyal oh sinyal,. mimin sinyal min
#
#                                          cleaning_text  \
# 0    telkomsel kenapa download speednya cuman  mbps...
# 1                                       untuk apa min
# 2                                              cek min
# 3               telkomsel maju terus telkomsel sinyal
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167                    telkomsel maju terus telkomsel
# 168  kalau boleh tau selain dari telkomsel apakah b...
# 169            sinyal min urusin indihome geh sama bae
# 170                                  jenengmu ramadhan
# 171                     sinyal sinyal mimin sinyal min
#
#                                             tokenisasi  \
# 0    [telkomsel, kenapa, download, speednya, cuman,...
# 1                                [, untuk, apa, min, ]
# 2                                           [cek, min]
# 3        [telkomsel, maju, terus, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167              [telkomsel, maju, terus, telkomsel, ]
# 168  [kalau, boleh, tau, selain, dari, telkomsel, a...
# 169    [sinyal, min, urusin, indihome, geh, sama, bae]
# 170                               [jenengmu, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
#                                               stopword
# 0    [telkomsel, download, speednya, cuman, mbps, t...
# 1                                            [, min, ]
# 2                                           [cek, min]
# 3               [telkomsel, maju, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167                     [telkomsel, maju, telkomsel, ]
# 168                         [telkomsel, buka, ketik, ]
# 169          [sinyal, min, urusin, indihome, geh, bae]
# 170                               [jenengmu, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
# [134 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 547
# ------------------------
# telkomsel : telkomsel
# download : download
# speednya : speednya
# cuman : cuman
# mbps : mbps
# padal : padal
# sinyal : sinyal
# full : full
# lte : lte
#  :
# min : min
# cek : cek
# maju : maju
# sinyall : sinyall
# nyaaa : nyaaa
# woooeeeyyyy : woooeeeyyyy
# makasih : makasih
# hadiah : hadiah
# saldo : saldo
# gopay : gopay
# terima : terima
# sinyalnya : sinyal
# tolong : tolong
# benerin : benerin
# semoga : moga
# sehat : sehat
# tertimpa : timpa
# musibah : musibah
# iya : iya
# kasih : kasih
# kuota : kuota
# dri : dri
# pemerintah : perintah
# akses : akses
# aplikasi : aplikasi
# terbatas : batas
# sosmed : sosmed
# whatsapp : whatsapp
# youtube : youtube
# gabisa : gabisa
# kendala : kendala
# tanda : tanda
# silang : silang
# gmn : gmn
# ney : ney
# ngos : ngos
# ngosan : ngosan
# bentar : bentar
# ujian : uji
# sekolah : sekolah
# syedih : syedih
# malesin : malesin
# sumpah : sumpah
# jaringannya : jaring
# cakra : cakra
# halah : halah
# kopet : kopet
# perbaiki : baik
# ngegame : ngegame
# mendadak : dadak
# merah : merah
# ping : ping
# mending : mending
# kuning : kuning
# disconnected : disconnected
# pantes : pantes
# gada : gada
# koleb : koleb
# pengaturan : atur
# tampilan : tampil
# mulu : mulu
# gimana : gimana
# fungsi : fungsi
# internet : internet
# kemendikbud : kemendikbud
# dipake : dipake
# zoom : zoom
# gogling : gogling
# ujung : ujung
# make : make
# wife : wife
# bermanfaat : manfaat
# telkom : telkom
# malam : malam
# begadang : begadang
# pas : pas
# pelajar : ajar
# mahasiswa : mahasiswa
# namanya : nama
# ganti : ganti
# kemendibud : kemendibud
# bales : bales
# gue : gue
# barry : barry
# prima : prima
# renaldi : renaldi
# ngga : ngga
# direspon : direspon
# respon : respon
# semalam : malam
# transfer : transfer
# pulsa : pulsa
# sistem : sistem
# sibuk : sibuk
# parah : parah
# kab : kab
# oki : oki
# sumsel : sumsel
# banget : banget
# kualitas : kualitas
# buruk : buruk
# yaa : yaa
# masuk : masuk
# semalem : semalem
# tanggung : tanggung
# gmna : gmna
# dibales : dibales
# please : please
# udh : udh
# hubungi : hubung
# veronika : veronika
# perbaikan : baik
# baca : baca
# sinyak : sinyak
# ilang : ilang
# knp : knp
# woy : woy
# mempersulit : sulit
# hidup : hidup
# beli : beli
# paketin : paketin
# buka : buka
# game : game
# main : main
# mode : mode
# ranked : ranked
# selamat : selamat
# menurunkan : turun
# rank : rank
# terimakasih : terimakasih
# saran : saran
# banyakin : banyakin
# promo : promo
# bagusin : bagusin
# adminnn : adminnn
# terhormaattt : terhormaattt
# sinyaalll : sinyaalll
# nyaa : nyaa
# gimanaaa : gimanaaa
# ngelag : ngelag
# muluuu : muluuu
# media : media
# sosial : sosial
# jugaaa : jugaaa
# ngeleg : ngeleg
# tolongggg : tolongggg
# ngk : ngk
# nyamaan : nyamaan
# trusss : trusss
# lancar : lancar
# mohon : mohon
# tindak : tindak
# lanjutin : lanjutin
# request : request
# tambahin : tambahin
# unlimited : unlimited
# call : call
# duty : duty
# kemanain : kemanain
# kontolll : kontolll
# paket : paket
# mahal : mahal
# beda : beda
# promosi : promosi
# pasca : pasca
# bayar : bayar
# giga : giga
# serius : serius
# maen : maen
# mlbb : mlbb
# turun : turun
# busuk : busuk
# pelayanan : layan
# konsumennya : konsumen
# beriteraksi : beriteraksi
# robot : robot
# keluhan : keluh
# pelanggan : langgan
# semuannya : semu
# abaikan : abai
# solusi : solusi
# nyata : nyata
# disuruh : suruh
# nanya : nanya
# restart : restart
# indihome : indihome
# tower : tower
# pengen : ken
# pasang : pasang
# dirumah : rumah
# towernya : towernya
# bagus : bagus
# pagi : pagi
# sisa : sisa
# gb : gb
# pajangan : pajang
# doang : doang
# manual : manual
# signal : signal
# hai : hai
# capek : capek
# teruuss : teruuss
# diabaikan : abai
# kasi : kasi
# bug : bug
# ketengan : keteng
# bertambah : tambah
# perak : perak
# tuhh : tuhh
# lupain : lupain
# sampe : sampe
# stabil : stabil
# gtu : gtu
# nyesel : nyesel
# gua : gua
# harga : harga
# dinaikin : dinaikin
# utama : utama
# harian : hari
# udah : udah
# kadang : kadang
# mytelkomsel : mytelkomsel
# eror : eror
# melulu : melulu
# ngecek : ngecek
# delay : delay
# heran : heran
# sebulann : sebulann
# btw : btw
# ngehubungi : ngehubungi
# inet : inet
# seriusan : serius
# adain : adain
# surprisedeal : surprisedeal
# belajar : ajar
# rb : rb
# seminggu : minggu
# diperhatikan : perhati
# murah : murah
# diskon : diskon
# pengguna : guna
# kartu : kartu
# dibanding : banding
# pakai : pakai
# bertahun : tahun
# contohnya : contoh
# combo : combo
# sakti : sakti
# betah : betah
# minnnnnnn : minnnnnnn
# dmmmmmmmmmmmmmmmmmmmmmmmm : dmmmmmmmmmmmmmmmmmmmmmmmm
# miinn : miinn
# habis : habis
# lokal : lokal
# bv : bv
# halo : halo
# admin : admin
# cantik : cantik
# ganteng : ganteng
# maaf : maaf
# kak : kak
# kemarin : kemarin
# menang : menang
# tunggu : tunggu
# maks : maks
# pengiriman : kirim
# tpi : tpi
# bulanan : bulan
# konfirmasi : konfirmasi
# emang : emang
# kah : kah
# pengirimannya : kirim
# infonya : info
# nonton : nonton
# via : via
# maxstream : maxstream
# berkurang : kurang
# hujan : hujan
# angin : angin
# lenyap : lenyap
# situ : situ
# sulap : sulap
# th : th
# al : al
# the : the
# real : real
# percaya : percaya
# bangke : bangke
# ngaco : ngaco
# giveaway : giveaway
# blm : blm
# dikirim : kirim
# minggu : minggu
# balas : balas
# adminnya : adminnya
# hidayah : hidayah
# pes : pes
# mobile : mobile
# ngankat : ngankat
# loading : loading
# kyk : kyk
# ceria : ceria
# setia : setia
# ayo : ayo
# borong : borong
# masi : mas
# hape : hape
# januari : januari
# stiap : stiap
# pembelian : beli
# voucher : voucher
# sidang : sidang
# gini : gin
# teruus : teruus
# skrg : skrg
# jepara : jepara
# jawa : jawa
# medsos : medsos
# lancarnya : lancar
# paketan : paket
# potong : potong
# diemin : diemin
# ngelu : ngelu
# jak : jak
# karna : karna
# nominal : nominal
# engga : engga
# sesuai : sesuai
# tinggal : tinggal
# kota : kota
# berasa : asa
# oksibil : oksibil
# papua : papua
# setan : setan
# pretelin : pretelin
# menara : menara
# pemancar : pancar
# isi : isi
# komeeentarnya : komeeentarnya
# dapet : dapet
# bonus : bonus
# daftar : daftar
# pribadi : pribadi
# sedot : sedot
# berlaku : laku
# taruh : taruh
# list : list
# nge : nge
# prank : prank
# orang : orang
# kaya : kaya
# miskin : miskin
# bakso : bakso
# sepuluh : puluh
# bungkus : bungkus
# dihabisin : dihabisin
# sehari : hari
# penindasan : tindas
# rakyat : rakyat
# memakmurkan : makmur
# bantu : bantu
# disaat : saat
# pandemi : pandemi
# musim : musim
# pelik : pelik
# makan : makan
# hak : hak
# hebat : hebat
# siswa : siswa
# terinspirasi : inspirasi
# snmptn : snmptn
# ngambil : ngambil
# jurusan : jurus
# sastra : sastra
# rusia : rusia
# alhamdulillah : alhamdulillah
# lolos : lolos
# umur : umur
# inspirasi : inspirasi
# tetaplah : tetap
# berkembang : kembang
# kemajuan : maju
# penerus : terus
# bangsamu : bangsa
# join : join
# wag : wag
# prakerja : prakerja
# yok : yok
# ndm : ndm
# sinyalmu : sinyal
# kpn : kpn
# bagusnya : bagus
# cok : cok
# kntil : kntil
# mati : mati
# kao : kao
# memek : memek
# muka : muka
# kek : kek
# kntol : kntol
# gitu : gitu
# woi : woi
# jabodetabek : jabodetabek
# wijaya : wijaya
# kusuma : kusuma
# parahhh : parahhh
# rusakkkk : rusakkkk
# telkomonyet : telkomonyet
# kesini : kesini
# hancur : hancur
# tlg : tlg
# simpati : simpati
# hangus : hangus
# sinta : sinta
# gblk : gblk
# jaringanmu : jaring
# bos : bos
# merugikan : rugi
# siyal : siyal
# geleg : geleg
# ngeliat : ngeliat
# drop : drop
# bsa : bsa
# astaga : astaga
# ngedown : ngedown
# bye : bye
# tsel : tsel
# buang : buang
# pindah : pindah
# provider : provider
# guys : guys
# vero : vero
# apalah : apa
# nyaut : nyaut
# becus : becus
# prpfesional : prpfesional
# app : app
# kaga : kaga
# login : login
# something : something
# wrong : wrong
# niat : niat
# gasih : gasih
# unstable : unstable
# connection : connection
# komentar : komentar
# suru : suru
# veronica : veronica
# gabakal : gabakal
# nyambung : nyambung
# contoh : contoh
# adik : adik
# cust : cust
# servicenya : servicenya
# pelayanannya : layan
# ngebuat : ngebuat
# asisten : asisten
# virtual : virtual
# kemajuannya : maju
# ngomong : ngomong
# tembok : tembok
# rugi : rugi
# bandar : bandar
# seriusss : seriusss
# bgsatt : bgsatt
# konfirm : konfirm
# telkomselnya : telkomselnya
# minn : minn
# chat : chat
# responn : responn
# enakan : enak
# anjinggg : anjinggg
# cukii : cuki
# kauu : kauu
# ribu : ribu
# pembayaran : bayar
# sukses : sukses
# kuotanya : kuota
# kembalikan : kembali
# komplain : komplain
# dengerin : dengerin
# lemah : lemah
# sedrop : drop
# penjelasannya : jelas
# subsidi : subsidi
# hj : hj
# kode : kode
# poin : poin
# milik : milik
# pemenang : menang
# periode : periode
# butuh : butuh
# rekomendasi : rekomendasi
# makanan : makan
# gajian : gaji
# pgn : pgn
# enak : enak
# undian : undi
# beruntung : untung
# amin : amin
# kebutuhan : butuh
# pokok : pokok
# pln : pln
# pdam : pdam
# cari : cari
# uang : uang
# syukur : syukur
# bangga : bangga
# gasar : gasar
# geser : geser
# ngebank : ngebank
# iphone : iphone
# desember : desember
# pemenamg : pemenamg
# kuis : kuis
# bergerak : gerak
# penuh : penuh
# didesaku : desa
# timbul : timbul
# tenggelam : tenggelam
# mengganggu : ganggu
# diperbaiki : baik
# mantap : mantap
# pubgm : pubgm
# memuat : muat
# mamuat : mamuat
# njepat : njepat
# huft : huft
# tarot : tarot
# yaelah : yaelah
# ketik : ketik
# urusin : urusin
# geh : geh
# bae : bae
# jenengmu : jeneng
# ramadhan : ramadhan
# mimin : mimin
# {'telkomsel': 'telkomsel', 'download': 'download', 'speednya': 'speednya', 'cuman': 'cuman', 'mbps': 'mbps', 'padal': 'padal', 'sinyal': 'sinyal', 'full': 'full', 'lte': 'lte', '': '', 'min': 'min', 'cek': 'cek', 'maju': 'maju', 'sinyall': 'sinyall', 'nyaaa': 'nyaaa', 'woooeeeyyyy': 'woooeeeyyyy', 'makasih': 'makasih', 'hadiah': 'hadiah', 'saldo': 'saldo', 'gopay': 'gopay', 'terima': 'terima', 'sinyalnya': 'sinyal', 'tolong': 'tolong', 'benerin': 'benerin', 'semoga': 'moga', 'sehat': 'sehat', 'tertimpa': 'timpa', 'musibah': 'musibah', 'iya': 'iya', 'kasih': 'kasih', 'kuota': 'kuota', 'dri': 'dri', 'pemerintah': 'perintah', 'akses': 'akses', 'aplikasi': 'aplikasi', 'terbatas': 'batas', 'sosmed': 'sosmed', 'whatsapp': 'whatsapp', 'youtube': 'youtube', 'gabisa': 'gabisa', 'kendala': 'kendala', 'tanda': 'tanda', 'silang': 'silang', 'gmn': 'gmn', 'ney': 'ney', 'ngos': 'ngos', 'ngosan': 'ngosan', 'bentar': 'bentar', 'ujian': 'uji', 'sekolah': 'sekolah', 'syedih': 'syedih', 'malesin': 'malesin', 'sumpah': 'sumpah', 'jaringannya': 'jaring', 'cakra': 'cakra', 'halah': 'halah', 'kopet': 'kopet', 'perbaiki': 'baik', 'ngegame': 'ngegame', 'mendadak': 'dadak', 'merah': 'merah', 'ping': 'ping', 'mending': 'mending', 'kuning': 'kuning', 'disconnected': 'disconnected', 'pantes': 'pantes', 'gada': 'gada', 'koleb': 'koleb', 'pengaturan': 'atur', 'tampilan': 'tampil', 'mulu': 'mulu', 'gimana': 'gimana', 'fungsi': 'fungsi', 'internet': 'internet', 'kemendikbud': 'kemendikbud', 'dipake': 'dipake', 'zoom': 'zoom', 'gogling': 'gogling', 'ujung': 'ujung', 'make': 'make', 'wife': 'wife', 'bermanfaat': 'manfaat', 'telkom': 'telkom', 'malam': 'malam', 'begadang': 'begadang', 'pas': 'pas', 'pelajar': 'ajar', 'mahasiswa': 'mahasiswa', 'namanya': 'nama', 'ganti': 'ganti', 'kemendibud': 'kemendibud', 'bales': 'bales', 'gue': 'gue', 'barry': 'barry', 'prima': 'prima', 'renaldi': 'renaldi', 'ngga': 'ngga', 'direspon': 'direspon', 'respon': 'respon', 'semalam': 'malam', 'transfer': 'transfer', 'pulsa': 'pulsa', 'sistem': 'sistem', 'sibuk': 'sibuk', 'parah': 'parah', 'kab': 'kab', 'oki': 'oki', 'sumsel': 'sumsel', 'banget': 'banget', 'kualitas': 'kualitas', 'buruk': 'buruk', 'yaa': 'yaa', 'masuk': 'masuk', 'semalem': 'semalem', 'tanggung': 'tanggung', 'gmna': 'gmna', 'dibales': 'dibales', 'please': 'please', 'udh': 'udh', 'hubungi': 'hubung', 'veronika': 'veronika', 'perbaikan': 'baik', 'baca': 'baca', 'sinyak': 'sinyak', 'ilang': 'ilang', 'knp': 'knp', 'woy': 'woy', 'mempersulit': 'sulit', 'hidup': 'hidup', 'beli': 'beli', 'paketin': 'paketin', 'buka': 'buka', 'game': 'game', 'main': 'main', 'mode': 'mode', 'ranked': 'ranked', 'selamat': 'selamat', 'menurunkan': 'turun', 'rank': 'rank', 'terimakasih': 'terimakasih', 'saran': 'saran', 'banyakin': 'banyakin', 'promo': 'promo', 'bagusin': 'bagusin', 'adminnn': 'adminnn', 'terhormaattt': 'terhormaattt', 'sinyaalll': 'sinyaalll', 'nyaa': 'nyaa', 'gimanaaa': 'gimanaaa', 'ngelag': 'ngelag', 'muluuu': 'muluuu', 'media': 'media', 'sosial': 'sosial', 'jugaaa': 'jugaaa', 'ngeleg': 'ngeleg', 'tolongggg': 'tolongggg', 'ngk': 'ngk', 'nyamaan': 'nyamaan', 'trusss': 'trusss', 'lancar': 'lancar', 'mohon': 'mohon', 'tindak': 'tindak', 'lanjutin': 'lanjutin', 'request': 'request', 'tambahin': 'tambahin', 'unlimited': 'unlimited', 'call': 'call', 'duty': 'duty', 'kemanain': 'kemanain', 'kontolll': 'kontolll', 'paket': 'paket', 'mahal': 'mahal', 'beda': 'beda', 'promosi': 'promosi', 'pasca': 'pasca', 'bayar': 'bayar', 'giga': 'giga', 'serius': 'serius', 'maen': 'maen', 'mlbb': 'mlbb', 'turun': 'turun', 'busuk': 'busuk', 'pelayanan': 'layan', 'konsumennya': 'konsumen', 'beriteraksi': 'beriteraksi', 'robot': 'robot', 'keluhan': 'keluh', 'pelanggan': 'langgan', 'semuannya': 'semu', 'abaikan': 'abai', 'solusi': 'solusi', 'nyata': 'nyata', 'disuruh': 'suruh', 'nanya': 'nanya', 'restart': 'restart', 'indihome': 'indihome', 'tower': 'tower', 'pengen': 'ken', 'pasang': 'pasang', 'dirumah': 'rumah', 'towernya': 'towernya', 'bagus': 'bagus' ...
# ------------------------
# Pandas Apply:   0%|          | 0/134 [00:00<?, ?it/s]
#                                                   text  \
# 0    telkomsel kenapa download speednya cuman 3.85m...
# 1                               *500# untuk apa min???
# 2                                           cek dm min
# 3    telkomsel maju terus, telkomsel sinyal no.1❤️❤...
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167  telkomsel maju terus, telkomsel no.1 ❤️❤️❤️❤️❤...
# 168  kalau boleh tau selain dari my telkomsel apaka...
# 169           sinyal min urusin, indihome geh sama bae
# 170                           jenengmu @adhi._ramadhan
# 171               sinyal oh sinyal,. mimin sinyal min
#
#                                          cleaning_text  \
# 0    telkomsel kenapa download speednya cuman  mbps...
# 1                                       untuk apa min
# 2                                              cek min
# 3               telkomsel maju terus telkomsel sinyal
# 4                            sinyall nyaaa woooeeeyyyy
# ..                                                 ...
# 167                    telkomsel maju terus telkomsel
# 168  kalau boleh tau selain dari telkomsel apakah b...
# 169            sinyal min urusin indihome geh sama bae
# 170                                  jenengmu ramadhan
# 171                     sinyal sinyal mimin sinyal min
#
#                                             tokenisasi  \
# 0    [telkomsel, kenapa, download, speednya, cuman,...
# 1                                [, untuk, apa, min, ]
# 2                                           [cek, min]
# 3        [telkomsel, maju, terus, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167              [telkomsel, maju, terus, telkomsel, ]
# 168  [kalau, boleh, tau, selain, dari, telkomsel, a...
# 169    [sinyal, min, urusin, indihome, geh, sama, bae]
# 170                               [jenengmu, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
#                                               stopword  \
# 0    [telkomsel, download, speednya, cuman, mbps, t...
# 1                                            [, min, ]
# 2                                           [cek, min]
# 3               [telkomsel, maju, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167                     [telkomsel, maju, telkomsel, ]
# 168                         [telkomsel, buka, ketik, ]
# 169          [sinyal, min, urusin, indihome, geh, bae]
# 170                               [jenengmu, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
#                                               stemming
# 0    [telkomsel, download, speednya, cuman, mbps, t...
# 1                                            [, min, ]
# 2                                           [cek, min]
# 3               [telkomsel, maju, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167                     [telkomsel, maju, telkomsel, ]
# 168                         [telkomsel, buka, ketik, ]
# 169          [sinyal, min, urusin, indihome, geh, bae]
# 170                                 [jeneng, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
# [134 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [telkomsel, download, speednya, cuman, mbps, t...
# 1                                            [, min, ]
# 2                                           [cek, min]
# 3               [telkomsel, maju, telkomsel, sinyal, ]
# 4                        [sinyall, nyaaa, woooeeeyyyy]
# ..                                                 ...
# 167                     [telkomsel, maju, telkomsel, ]
# 168                         [telkomsel, buka, ketik, ]
# 169          [sinyal, min, urusin, indihome, geh, bae]
# 170                                 [jeneng, ramadhan]
# 171               [sinyal, sinyal, mimin, sinyal, min]
#
# [134 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_3.xlsx')
