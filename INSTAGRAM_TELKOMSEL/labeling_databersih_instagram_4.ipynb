# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["comment_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data bersih_translate instagram telkomsel\databersih_english_instagram_telkomsel_4.xlsx', usecols=columns)
df['label_awal'] = ''
for i,x in df.comment_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.7
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.7
# Index:  3 label_awal 0.7
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.2
# Index:  7 label_awal 0.0
# Index:  8 label_awal 0.0
# Index:  9 label_awal 0.0
# Index:  10 label_awal 1.0
# Index:  11 label_awal -0.4
# Index:  12 label_awal 0.0
# Index:  13 label_awal 0.0
# Index:  14 label_awal 0.0
# Index:  15 label_awal 0.43333333333333335
# Index:  16 label_awal -0.5
# Index:  17 label_awal 0.2
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.5
# Index:  20 label_awal 0.0
# Index:  21 label_awal 0.0
# Index:  22 label_awal 0.0
# Index:  23 label_awal 0.0
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.16666666666666666
# Index:  26 label_awal 0.0
# Index:  27 label_awal 0.5
# Index:  28 label_awal 0.0
# Index:  29 label_awal 0.0
# Index:  30 label_awal 0.1
# Index:  31 label_awal 0.0
# Index:  32 label_awal 0.0
# Index:  33 label_awal 0.057142857142857134
# Index:  34 label_awal 0.0
# Index:  35 label_awal -0.3
# Index:  36 label_awal 0.44999999999999996
# Index:  37 label_awal 0.0
# Index:  38 label_awal -0.13333333333333333
# Index:  39 label_awal 0.0
# Index:  40 label_awal 0.0
# Index:  41 label_awal 0.0
# Index:  42 label_awal 0.0
# Index:  43 label_awal 0.0
# Index:  44 label_awal 0.0
# Index:  45 label_awal 0.0
# Index:  46 label_awal 0.0
# Index:  47 label_awal 0.022222222222222227
# Index:  48 label_awal 0.0
# Index:  49 label_awal 0.0
# Index:  50 label_awal 0.0
# Index:  51 label_awal 0.8
# Index:  52 label_awal 0.0
# Index:  53 label_awal 0.0
# Index:  54 label_awal 0.0
# Index:  55 label_awal 0.0
# Index:  56 label_awal 0.0
# Index:  57 label_awal 0.0
# Index:  58 label_awal 0.0
# Index:  59 label_awal 0.0
# Index:  60 label_awal 0.16666666666666666
# Index:  61 label_awal 0.2
# Index:  62 label_awal 0.0
# Index:  63 label_awal 0.0
# Index:  64 label_awal 0.0
# Index:  65 label_awal 0.0
# Index:  66 label_awal 0.2
# Index:  67 label_awal 0.0
# Index:  68 label_awal 0.0
# Index:  69 label_awal 0.0
# Index:  70 label_awal 0.0
# Index:  71 label_awal 0.4
# Index:  72 label_awal 0.0
# Index:  73 label_awal 0.16666666666666666
# Index:  74 label_awal 0.10952380952380954
# Index:  75 label_awal 0.0
# Index:  76 label_awal 0.225
# Index:  77 label_awal 0.0
# Index:  78 label_awal 0.0
# Index:  79 label_awal 0.0
# Index:  80 label_awal 0.0
# Index:  81 label_awal 0.0
# Index:  82 label_awal 0.0
# Index:  83 label_awal 0.35714285714285715
# Index:  84 label_awal -0.08857142857142858
# Index:  85 label_awal -0.13333333333333333
# Index:  86 label_awal 0.1875
# Index:  87 label_awal 0.5
# Index:  88 label_awal -0.30000000000000004
# Index:  89 label_awal -0.15
# Index:  90 label_awal 0.0
# Index:  91 label_awal 0.0
# Index:  92 label_awal 0.0
# Index:  93 label_awal 0.0
# Index:  94 label_awal -0.30000000000000004
# Index:  95 label_awal -1.0
# Index:  96 label_awal 0.0
# Index:  97 label_awal 0.8
# Index:  98 label_awal 0.0
# Index:  99 label_awal 0.0
# Index:  100 label_awal 0.0
# Index:  101 label_awal 0.0
# Index:  102 label_awal 0.0
# Index:  103 label_awal 0.8
# Index:  104 label_awal 0.0
# Index:  105 label_awal -0.3
# Index:  106 label_awal 0.0
# Index:  107 label_awal 0.0
# Index:  108 label_awal 0.0
# Index:  109 label_awal -0.15
# Index:  110 label_awal 0.1
# Index:  111 label_awal 0.0
# Index:  112 label_awal 0.30000000000000004
# Index:  113 label_awal 0.0
# Index:  114 label_awal 0.0
# Index:  115 label_awal 0.25
# Index:  116 label_awal 0.0
# Index:  117 label_awal 0.0
# Index:  118 label_awal 0.0
# Index:  119 label_awal 0.41666666666666663
# Index:  120 label_awal 0.1
# Index:  121 label_awal 0.4
# Index:  122 label_awal 0.0
# Index:  123 label_awal 0.0
# Index:  124 label_awal 0.0
# Index:  125 label_awal 0.0
# Index:  126 label_awal 0.0
# Index:  127 label_awal 0.2
# Index:  128 label_awal 0.0
# Index:  129 label_awal 0.0
# Index:  130 label_awal 0.0
# Index:  131 label_awal 0.7
# Index:  132 label_awal 0.0
# Index:  133 label_awal 0.7
# Index:  134 label_awal 0.0
# Index:  135 label_awal 0.0
# Index:  136 label_awal 0.8
# Index:  137 label_awal 0.0
# Index:  138 label_awal 0.0
# Index:  139 label_awal 0.0
# Index:  140 label_awal 0.0
# Index:  141 label_awal 0.0
# Index:  142 label_awal -0.15555555555555559
# Index:  143 label_awal 0.0
# Index:  144 label_awal 0.0
# Index:  145 label_awal 0.0
# Index:  146 label_awal 0.0
# Index:  147 label_awal 0.7
# Index:  148 label_awal 0.0
# Index:  149 label_awal -0.1
# Index:  150 label_awal 0.0
# Index:  151 label_awal 0.0
# Index:  152 label_awal 0.0
# Index:  153 label_awal 0.0
# Index:  154 label_awal -0.5
# Index:  155 label_awal 0.0
# Index:  156 label_awal -0.15
# Index:  157 label_awal 0.0
# Index:  158 label_awal 0.4888888888888889
# Index:  159 label_awal 0.0
# Index:  160 label_awal -0.5

# %%
df.head()
# Out:
#                                      comment_english label_awal
# 0                          ['good', 'signal', 'woi']        0.7
# 1                                      ['passiontt']        0.0
# 2  ['signal', 'quota', 'unlimitedmax', 'good', 's...        0.7
# 3        ['signal', 'quota', 'unlimitedmax', 'good']        0.7
# 4  ['signal', 'redik', 'min', 'cellphone', 'janua...        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    105
#  0.700000      6
#  0.200000      5
#  0.800000      4
# -0.500000      3
#  0.500000      3
#  0.166667      3
#  0.100000      3
# -0.150000      3
# -0.300000      2
#  0.400000      2
# -0.300000      2
# -0.133333      2
# -1.000000      1
#  0.300000      1
# -0.400000      1
#  0.250000      1
#  0.416667      1
#  0.187500      1
# -0.100000      1
# -0.155556      1
#  0.109524      1
# -0.088571      1
#  0.357143      1
#  0.225000      1
#  0.433333      1
#  1.000000      1
#  0.022222      1
#  0.450000      1
#  0.057143      1
#  0.488889      1
# Name: label_awal, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] > 0.0:
        label.append("positive")
    else:
        label.append("negative")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                        comment_english     label
# 0                            ['good', 'signal', 'woi']  positive
# 1                                        ['passiontt']  negative
# 2    ['signal', 'quota', 'unlimitedmax', 'good', 's...  positive
# 3          ['signal', 'quota', 'unlimitedmax', 'good']  positive
# 4    ['signal', 'redik', 'min', 'cellphone', 'janua...  negative
# ..                                                 ...       ...
# 156  ['region', 'aceh', 'tamiang', 'sinya', 'play',...  negative
# 157                                   ['check', 'min']  negative
# 158  ['thank', 'love', 'telkomsel', 'good', 'thanks...  positive
# 159  ['sort', 'name', 'device', 'dcdu', 'emub', 'bb...  negative
# 160      ['signal', 'signal', 'difficult', 'times', "]  negative
#
# [161 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# negative    122
# positive     39
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_instagram_indihome_4.xlsx')
