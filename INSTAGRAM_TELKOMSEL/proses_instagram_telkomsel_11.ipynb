# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                               Mantab
# 1    Lancar banget saking lancarnya sampai pengen b...
# 2    Pascabayar kok lebih lemah dari prabayar? Pasc...
# 3    HOAX !!! Kuota reguler abis ,,tetep aja ngelag...
# 4          Malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         DMnya gak pernah di respon
# 104                                Min cek DM nya dong
# 105  Min ini ko paket daruratnya muncul terus ya ? ...
# 106  Keseringan pulsa kepotong teros, padahal paket...
# 107                                 Jessie Frye - High
#
# [108 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 9

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                               Mantab
# 1    Lancar banget saking lancarnya sampai pengen b...
# 2    Pascabayar kok lebih lemah dari prabayar? Pasc...
# 3    HOAX !!! Kuota reguler abis ,,tetep aja ngelag...
# 4          Malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         DMnya gak pernah di respon
# 104                                Min cek DM nya dong
# 105  Min ini ko paket daruratnya muncul terus ya ? ...
# 106  Keseringan pulsa kepotong teros, padahal paket...
# 107                                 Jessie Frye - High
#
# [96 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar? pasc...
# 3    hoax !!! kuota reguler abis ,,tetep aja ngelag...
# 4          malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         dmnya gak pernah di respon
# 104                                min cek dm nya dong
# 105  min ini ko paket daruratnya muncul terus ya ? ...
# 106  keseringan pulsa kepotong teros, padahal paket...
# 107                                 jessie frye - high
#
# [96 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar? pasc...
# 3    hoax !!! kuota reguler abis ,,tetep aja ngelag...
# 4          malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         dmnya gak pernah di respon
# 104                                min cek dm nya dong
# 105  min ini ko paket daruratnya muncul terus ya ? ...
# 106  keseringan pulsa kepotong teros, padahal paket...
# 107                                 jessie frye - high
#
#                                          cleaning_text
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar pasca...
# 3    hoax kuota reguler abis tetep aja ngelag game ...
# 4            malah gak bisa ini signal nya gak muncul
# ..                                                 ...
# 103                            dmnya gak pernah respon
# 104                                   min cek nya dong
# 105  min ini paket daruratnya muncul terus padahal ...
# 106  keseringan pulsa kepotong teros padahal paket ...
# 107                                   jessie frye high
#
# [96 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar? pasc...
# 3    hoax !!! kuota reguler abis ,,tetep aja ngelag...
# 4          malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         dmnya gak pernah di respon
# 104                                min cek dm nya dong
# 105  min ini ko paket daruratnya muncul terus ya ? ...
# 106  keseringan pulsa kepotong teros, padahal paket...
# 107                                 jessie frye - high
#
#                                          cleaning_text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar pasca...
# 3    hoax kuota reguler abis tetep aja ngelag game ...
# 4            malah gak bisa ini signal nya gak muncul
# ..                                                 ...
# 103                            dmnya gak pernah respon
# 104                                   min cek nya dong
# 105  min ini paket daruratnya muncul terus padahal ...
# 106  keseringan pulsa kepotong teros padahal paket ...
# 107                                   jessie frye high
#
#                                             tokenisasi
# 0                                             [mantab]
# 1    [lancar, banget, saking, lancarnya, sampai, pe...
# 2    [pascabayar, kok, lebih, lemah, dari, prabayar...
# 3    [hoax, kuota, reguler, abis, tetep, aja, ngela...
# 4    [malah, gak, bisa, ini, signal, nya, gak, munc...
# ..                                                 ...
# 103                       [dmnya, gak, pernah, respon]
# 104                              [min, cek, nya, dong]
# 105  [min, ini, paket, daruratnya, muncul, terus, p...
# 106  [keseringan, pulsa, kepotong, teros, padahal, ...
# 107                               [jessie, frye, high]
#
# [96 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar? pasc...
# 3    hoax !!! kuota reguler abis ,,tetep aja ngelag...
# 4          malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         dmnya gak pernah di respon
# 104                                min cek dm nya dong
# 105  min ini ko paket daruratnya muncul terus ya ? ...
# 106  keseringan pulsa kepotong teros, padahal paket...
# 107                                 jessie frye - high
#
#                                          cleaning_text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar pasca...
# 3    hoax kuota reguler abis tetep aja ngelag game ...
# 4            malah gak bisa ini signal nya gak muncul
# ..                                                 ...
# 103                            dmnya gak pernah respon
# 104                                   min cek nya dong
# 105  min ini paket daruratnya muncul terus padahal ...
# 106  keseringan pulsa kepotong teros padahal paket ...
# 107                                   jessie frye high
#
#                                             tokenisasi  \
# 0                                             [mantab]
# 1    [lancar, banget, saking, lancarnya, sampai, pe...
# 2    [pascabayar, kok, lebih, lemah, dari, prabayar...
# 3    [hoax, kuota, reguler, abis, tetep, aja, ngela...
# 4    [malah, gak, bisa, ini, signal, nya, gak, munc...
# ..                                                 ...
# 103                       [dmnya, gak, pernah, respon]
# 104                              [min, cek, nya, dong]
# 105  [min, ini, paket, daruratnya, muncul, terus, p...
# 106  [keseringan, pulsa, kepotong, teros, padahal, ...
# 107                               [jessie, frye, high]
#
#                                               stopword
# 0                                             [mantab]
# 1    [lancar, banget, saking, lancarnya, pengen, ba...
# 2    [pascabayar, lemah, prabayar, pascabayar, mbps...
# 3    [hoax, kuota, reguler, abis, tetep, ngelag, ga...
# 4                                   [signal, muncul, ]
# ..                                                 ...
# 103                                    [dmnya, respon]
# 104                                         [min, cek]
# 105  [min, paket, daruratnya, muncul, aktifin, akti...
# 106  [keseringan, pulsa, kepotong, teros, paket, in...
# 107                               [jessie, frye, high]
#
# [96 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 321
# ------------------------
# mantab : mantab
# lancar : lancar
# banget : banget
# saking : saking
# lancarnya : lancar
# pengen : ken
# banting : banting
#  :
# pascabayar : pascabayar
# lemah : lemah
# prabayar : prabayar
# mbps : mbps
# area : area
# device : device
# tolong : tolong
# hoax : hoax
# kuota : kuota
# reguler : reguler
# abis : abis
# tetep : tetep
# ngelag : ngelag
# game : game
# jalan : jalan
# kaya : kaya
# jokowi : jokowi
# tukang : tukang
# ngeprank : ngeprank
# signal : signal
# muncul : muncul
# duluuu : duluuu
# bar : bar
# pernuh : pernuh
# sekaramg : sekaramg
# jual : jual
# swasta : swasta
# beres : beres
# ketawa : ketawa
# takut : takut
# respon : respon
# ngeleg : ngeleg
# ngeghosting : ngeghosting
# kualitas : kualitas
# sinyal : sinyal
# buruk : buruk
# blumdi : blumdi
# coba : coba
# paket : paket
# nihh : nihh
# mudah : mudah
# mudahan : mudah
# bermanfaat : manfaat
# ngecap : ngecap
# ancur : ancur
# bener : bener
# kota : kota
# sukabumi : sukabumi
# sumpah : sumpah
# simpati : simpati
# puluhan : puluh
# taon : taon
# skrng : skrng
# parah : parah
# maen : maen
# pingnya : pingnya
# naek : naek
# turun : turun
# nyaman : nyaman
# cuyy : cuyy
# main : main
# kerumah : rumah
# segimana : segimana
# pantesan : pantesan
# anti : anti
# club : club
# pengguna : guna
# tsel : tsel
# siyaapp : siyaapp
# perbaikin : perbaikin
# dlu : dlu
# yeee : yeee
# dibales : dibales
# update : update
# perjam : jam
# kouta : kouta
# aktif : aktif
# habis : habis
# terpakai : pakai
# bermutu : mutu
# baca : baca
# postingan : postingan
# kasar : kasar
# daya : daya
# jawabannya : jawab
# veronika : veronika
# imba : imba
# min : min
# perbaiki : baik
# sinyalnya : sinyal
# posting : posting
# ijo : ijo
# royo : royo
# lemes : lemes
# kesel : kesel
# sndri : sndri
# jumpingnya : jumpingnya
# stabil : stabil
# solusinya : solusi
# maaf : maaf
# doang : doang
# ping : ping
# merah : merah
# lawak : lawak
# ngesarkas : ngesarkas
# njis : njis
# cape : cape
# komen : komen
# suruh : suruh
# cek : cek
# tindakan : tindak
# gratisan : gratis
# beli : beli
# kartu : kartu
# telkomsel : telkomsel
# counter : counter
# belun : bun
# barusan : barusan
# jakarta : jakarta
# release : release
# cikarang : cikarang
# support : support
# ehehehe : ehehehe
# ndak : ndak
# bagus : bagus
# udah : udah
# alhamdulillah : alhamdulillah
# nyiapin : nyiapin
# provider : provider
# gini : gin
# pulsa : pulsa
# isi : isi
# ngejar : ngejar
# daerah : daerah
# semenjak : semenjak
# jariangan : jariangan
# menyerang : serang
# jarigan : jarigan
# serasa : serasa
# nggk : nggk
# barnya : bar
# benerin : benerin
# sel : sel
# sell : sell
# upgrade : upgrade
# sulit : sulit
# mohon : mohon
# buka : buka
# lowongan : lowong
# kerja : kerja
# bos : bos
# pesan : pesan
# gimana : gimana
# mimin : mimin
# gal : gal
# unlimited : unlimited
# sebulan : bulan
# youtube : youtube
# hotstar : hotstar
# social : social
# media : media
# upload : upload
# content : content
# hemat : hemat
# indihome : indihome
# firstmedia : firstmedia
# biznet : biznet
# myrepublik : myrepublik
# sejenisnya : jenis
# kabel : kabel
# wifi : wifi
# aplikasi : aplikasi
# mytelkomsel : mytelkomsel
# gabisa : gabisa
# gmn : gmn
# gausah : gausah
# kepoin : poin
# org : org
# gajian : gaji
# kelarin : kelarin
# urusan : urus
# ganti : ganti
# tgl : tgl
# nov : nov
# kemaren : kemaren
# balikin : balikin
# ainyal : ainyal
# kepo : kepo
# ama : ama
# mengaktifkan : aktif
# mati : mati
# tipe : tipe
# mengerti : erti
# harga : harga
# awas : awas
# hati : hati
# paketnya : paket
# uda : uda
# bantuannya : bantu
# perumahan : rumah
# griya : griya
# hegar : hegar
# asri : asri
# kab : kab
# bekasi : bekas
# internet : internet
# telp : telp
# kadang : kadang
# putus : putus
# bagusin : bagusin
# jaringannya : jaring
# dirumahku : rumah
# nonton : nonton
# ngelaq : ngelaq
# pulau : pulau
# jawa : jawa
# balas : balas
# chatnya : chatnya
# bot : bot
# jagan : jagan
# truss : truss
# admin : admin
# kayak : kayak
# sumbar : sumbar
# aza : aza
# sekarat : sekarat
# boro : boro
# bermimpilah : mimpi
# bermimpi : mimpi
# pelosok : pelosok
# kabupaten : kabupaten
# kualitasnya : kualitas
# bngt : bngt
# pakai : pakai
# kak : kak
# registrasi : registrasi
# nik : nik
# nomor : nomor
# milik : milik
# bgaimana : bgaimana
# unreg : unreg
# nmornya : nmornya
# dimna : dimna
# data : data
# multimedia : multimedia
# mlm : mlm
# hangus : hangus
# deh : deh
# mlbb : mlbb
# hadehh : hadehh
# tangerang : tangerang
# titiknya : titik
# dpt : dpt
# empot : empot
# empotan : empot
# bogor : bogor
# hadir : hadir
# toraja : toraja
# ratain : ratain
# pinggiran : pinggir
# menerus : terus
# digangguu : digangguu
# sms : sms
# menyuruh : suruh
# aktifkan : aktif
# kerjaan : kerja
# orang : orang
# iseng : iseng
# penipu : tipu
# diganggu : ganggu
# akuuuuu : akuuuuu
# akuuu : akuuu
# absen : absen
# udab : udab
# combo : combo
# sakti : sakti
# trus : trus
# maxstream : maxstream
# disney : disney
# kepotong : potong
# ngehabisin : ngehabisin
# telkom : telkom
# woy : woy
# astaga : astaga
# bales : bales
# jam : jam
# produktif : produktif
# halo : halo
# liat : liat
# kasih : kasih
# solusi : solusi
# lampu : lampu
# hilanggg : hilanggg
# anak : anak
# sekolah : sekolah
# terkendala : kendala
# ujian : uji
# terkuras : kuras
# pdhl : pdhl
# daily : daily
# check : check
# berkurang : kurang
# dmnya : dmnya
# daruratnya : darurat
# aktifin : aktifin
# keseringan : sering
# teros : ros
# penipuan : tipu
# masuk : masuk
# penjelasan : jelas
# jessie : jessie
# frye : frye
# high : high
# {'mantab': 'mantab', 'lancar': 'lancar', 'banget': 'banget', 'saking': 'saking', 'lancarnya': 'lancar', 'pengen': 'ken', 'banting': 'banting', '': '', 'pascabayar': 'pascabayar', 'lemah': 'lemah', 'prabayar': 'prabayar', 'mbps': 'mbps', 'area': 'area', 'device': 'device', 'tolong': 'tolong', 'hoax': 'hoax', 'kuota': 'kuota', 'reguler': 'reguler', 'abis': 'abis', 'tetep': 'tetep', 'ngelag': 'ngelag', 'game': 'game', 'jalan': 'jalan', 'kaya': 'kaya', 'jokowi': 'jokowi', 'tukang': 'tukang', 'ngeprank': 'ngeprank', 'signal': 'signal', 'muncul': 'muncul', 'duluuu': 'duluuu', 'bar': 'bar', 'pernuh': 'pernuh', 'sekaramg': 'sekaramg', 'jual': 'jual', 'swasta': 'swasta', 'beres': 'beres', 'ketawa': 'ketawa', 'takut': 'takut', 'respon': 'respon', 'ngeleg': 'ngeleg', 'ngeghosting': 'ngeghosting', 'kualitas': 'kualitas', 'sinyal': 'sinyal', 'buruk': 'buruk', 'blumdi': 'blumdi', 'coba': 'coba', 'paket': 'paket', 'nihh': 'nihh', 'mudah': 'mudah', 'mudahan': 'mudah', 'bermanfaat': 'manfaat', 'ngecap': 'ngecap', 'ancur': 'ancur', 'bener': 'bener', 'kota': 'kota', 'sukabumi': 'sukabumi', 'sumpah': 'sumpah', 'simpati': 'simpati', 'puluhan': 'puluh', 'taon': 'taon', 'skrng': 'skrng', 'parah': 'parah', 'maen': 'maen', 'pingnya': 'pingnya', 'naek': 'naek', 'turun': 'turun', 'nyaman': 'nyaman', 'cuyy': 'cuyy', 'main': 'main', 'kerumah': 'rumah', 'segimana': 'segimana', 'pantesan': 'pantesan', 'anti': 'anti', 'club': 'club', 'pengguna': 'guna', 'tsel': 'tsel', 'siyaapp': 'siyaapp', 'perbaikin': 'perbaikin', 'dlu': 'dlu', 'yeee': 'yeee', 'dibales': 'dibales', 'update': 'update', 'perjam': 'jam', 'kouta': 'kouta', 'aktif': 'aktif', 'habis': 'habis', 'terpakai': 'pakai', 'bermutu': 'mutu', 'baca': 'baca', 'postingan': 'postingan', 'kasar': 'kasar', 'daya': 'daya', 'jawabannya': 'jawab', 'veronika': 'veronika', 'imba': 'imba', 'min': 'min', 'perbaiki': 'baik', 'sinyalnya': 'sinyal', 'posting': 'posting', 'ijo': 'ijo', 'royo': 'royo', 'lemes': 'lemes', 'kesel': 'kesel', 'sndri': 'sndri', 'jumpingnya': 'jumpingnya', 'stabil': 'stabil', 'solusinya': 'solusi', 'maaf': 'maaf', 'doang': 'doang', 'ping': 'ping', 'merah': 'merah', 'lawak': 'lawak', 'ngesarkas': 'ngesarkas', 'njis': 'njis', 'cape': 'cape', 'komen': 'komen', 'suruh': 'suruh', 'cek': 'cek', 'tindakan': 'tindak', 'gratisan': 'gratis', 'beli': 'beli', 'kartu': 'kartu', 'telkomsel': 'telkomsel', 'counter': 'counter', 'belun': 'bun', 'barusan': 'barusan', 'jakarta': 'jakarta', 'release': 'release', 'cikarang': 'cikarang', 'support': 'support', 'ehehehe': 'ehehehe', 'ndak': 'ndak', 'bagus': 'bagus', 'udah': 'udah', 'alhamdulillah': 'alhamdulillah', 'nyiapin': 'nyiapin', 'provider': 'provider', 'gini': 'gin', 'pulsa': 'pulsa', 'isi': 'isi', 'ngejar': 'ngejar', 'daerah': 'daerah', 'semenjak': 'semenjak', 'jariangan': 'jariangan', 'menyerang': 'serang', 'jarigan': 'jarigan', 'serasa': 'serasa', 'nggk': 'nggk', 'barnya': 'bar', 'benerin': 'benerin', 'sel': 'sel', 'sell': 'sell', 'upgrade': 'upgrade', 'sulit': 'sulit', 'mohon': 'mohon', 'buka': 'buka', 'lowongan': 'lowong', 'kerja': 'kerja', 'bos': 'bos', 'pesan': 'pesan', 'gimana': 'gimana', 'mimin': 'mimin', 'gal': 'gal', 'unlimited': 'unlimited', 'sebulan': 'bulan', 'youtube': 'youtube', 'hotstar': 'hotstar', 'social': 'social', 'media': 'media', 'upload': 'upload', 'content': 'content', 'hemat': 'hemat', 'indihome': 'indihome', 'firstmedia': 'firstmedia', 'biznet': 'biznet', 'myrepublik': 'myrepublik', 'sejenisnya': 'jenis', 'kabel': 'kabel', 'wifi': 'wifi', 'aplikasi': 'aplikasi', 'mytelkomsel': 'mytelkomsel', 'gabisa': 'gabisa', 'gmn': 'gmn', 'gausah': 'gausah', 'kepoin': 'poin', 'org': 'org', 'gajian': 'gaji', 'kelarin': 'kelarin', 'urusan': 'urus', 'ganti': 'ganti', 'tgl': 'tgl', 'nov': 'nov', 'kemaren': 'kemaren', 'balikin': 'balikin', 'ainyal': 'ainyal', 'kepo': 'kepo', 'ama': 'ama', 'mengaktifkan': 'aktif', 'mati': 'mati', 'tipe': 'tipe', 'mengerti': 'erti', 'harga': 'harga', 'awas': 'awas', 'hati': 'hati', 'paketnya': 'paket', 'uda': 'uda', 'ban ...
# ------------------------
# Pandas Apply:   0%|          | 0/96 [00:00<?, ?it/s]
#                                                   text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar? pasc...
# 3    hoax !!! kuota reguler abis ,,tetep aja ngelag...
# 4          malah gak bisa ini..signal nya gak muncul..
# ..                                                 ...
# 103                         dmnya gak pernah di respon
# 104                                min cek dm nya dong
# 105  min ini ko paket daruratnya muncul terus ya ? ...
# 106  keseringan pulsa kepotong teros, padahal paket...
# 107                                 jessie frye - high
#
#                                          cleaning_text  \
# 0                                               mantab
# 1    lancar banget saking lancarnya sampai pengen b...
# 2    pascabayar kok lebih lemah dari prabayar pasca...
# 3    hoax kuota reguler abis tetep aja ngelag game ...
# 4            malah gak bisa ini signal nya gak muncul
# ..                                                 ...
# 103                            dmnya gak pernah respon
# 104                                   min cek nya dong
# 105  min ini paket daruratnya muncul terus padahal ...
# 106  keseringan pulsa kepotong teros padahal paket ...
# 107                                   jessie frye high
#
#                                             tokenisasi  \
# 0                                             [mantab]
# 1    [lancar, banget, saking, lancarnya, sampai, pe...
# 2    [pascabayar, kok, lebih, lemah, dari, prabayar...
# 3    [hoax, kuota, reguler, abis, tetep, aja, ngela...
# 4    [malah, gak, bisa, ini, signal, nya, gak, munc...
# ..                                                 ...
# 103                       [dmnya, gak, pernah, respon]
# 104                              [min, cek, nya, dong]
# 105  [min, ini, paket, daruratnya, muncul, terus, p...
# 106  [keseringan, pulsa, kepotong, teros, padahal, ...
# 107                               [jessie, frye, high]
#
#                                               stopword  \
# 0                                             [mantab]
# 1    [lancar, banget, saking, lancarnya, pengen, ba...
# 2    [pascabayar, lemah, prabayar, pascabayar, mbps...
# 3    [hoax, kuota, reguler, abis, tetep, ngelag, ga...
# 4                                   [signal, muncul, ]
# ..                                                 ...
# 103                                    [dmnya, respon]
# 104                                         [min, cek]
# 105  [min, paket, daruratnya, muncul, aktifin, akti...
# 106  [keseringan, pulsa, kepotong, teros, paket, in...
# 107                               [jessie, frye, high]
#
#                                               stemming
# 0                                             [mantab]
# 1     [lancar, banget, saking, lancar, ken, banting, ]
# 2    [pascabayar, lemah, prabayar, pascabayar, mbps...
# 3    [hoax, kuota, reguler, abis, tetep, ngelag, ga...
# 4                                   [signal, muncul, ]
# ..                                                 ...
# 103                                    [dmnya, respon]
# 104                                         [min, cek]
# 105    [min, paket, darurat, muncul, aktifin, aktif, ]
# 106  [sering, pulsa, potong, ros, paket, internet, ...
# 107                               [jessie, frye, high]
#
# [96 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                             [mantab]
# 1     [lancar, banget, saking, lancar, ken, banting, ]
# 2    [pascabayar, lemah, prabayar, pascabayar, mbps...
# 3    [hoax, kuota, reguler, abis, tetep, ngelag, ga...
# 4                                   [signal, muncul, ]
# ..                                                 ...
# 103                                    [dmnya, respon]
# 104                                         [min, cek]
# 105    [min, paket, darurat, muncul, aktifin, aktif, ]
# 106  [sering, pulsa, potong, ros, paket, internet, ...
# 107                               [jessie, frye, high]
#
# [96 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_11.xlsx')
