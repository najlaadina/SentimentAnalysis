# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                        Yukkk..mari bantu sama2 y..❤️
# 1                        Yukkk..mari bantu sama2 y..❤️
# 2    Awas php telkomsel . Tuker poin telko extra ku...
# 3    Mo nanya apa my telkomsel bermasalah. Tiba² lo...
# 4    HALO SELAMAT MLM ADMIN TELKOMSEL YTH, SAYA SUD...
# ..                                                 ...
# 103  Dunia industri public administration bakal ber...
# 104                          Ayo dong secepatnya ya 5G
# 105                             Mantap banget telkmsel
# 106                                                 ❤️
# 107  Mon maap min, sudah beberapa bulan untuk urusa...
#
# [108 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 2    Awas php telkomsel . Tuker poin telko extra ku...
# 3    Mo nanya apa my telkomsel bermasalah. Tiba² lo...
# 4    HALO SELAMAT MLM ADMIN TELKOMSEL YTH, SAYA SUD...
# 5                                                  NaN
# 6                        Di tempat sya juga jrngnya 4G
# ..                                                 ...
# 103  Dunia industri public administration bakal ber...
# 104                          Ayo dong secepatnya ya 5G
# 105                             Mantap banget telkmsel
# 106                                                 ❤️
# 107  Mon maap min, sudah beberapa bulan untuk urusa...
#
# [92 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 2    awas php telkomsel . tuker poin telko extra ku...
# 3    mo nanya apa my telkomsel bermasalah. tiba² lo...
# 4    halo selamat mlm admin telkomsel yth, saya sud...
# 5                                                  NaN
# 6                        di tempat sya juga jrngnya 4g
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                          ayo dong secepatnya ya 5g
# 105                             mantap banget telkmsel
# 106                                                 ❤️
# 107  mon maap min, sudah beberapa bulan untuk urusa...
#
# [92 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 2    awas php telkomsel . tuker poin telko extra ku...
# 3    mo nanya apa my telkomsel bermasalah. tiba² lo...
# 4    halo selamat mlm admin telkomsel yth, saya sud...
# 5                                                  NaN
# 6                        di tempat sya juga jrngnya 4g
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                          ayo dong secepatnya ya 5g
# 105                             mantap banget telkmsel
# 106                                                 ❤️
# 107  mon maap min, sudah beberapa bulan untuk urusa...
#
#                                          cleaning_text
# 2    awas php telkomsel tuker poin telko extra kuot...
# 3     nanya apa telkomsel bermasalah tiba log out t...
# 4    halo selamat mlm admin telkomsel yth saya suda...
# 5                                                  nan
# 6                             tempat sya juga jrngnya
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                               ayo dong secepatnya
# 105                             mantap banget telkmsel
# 106
# 107  mon maap min sudah beberapa bulan untuk urusan...
#
# [92 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 2    awas php telkomsel . tuker poin telko extra ku...
# 3    mo nanya apa my telkomsel bermasalah. tiba² lo...
# 4    halo selamat mlm admin telkomsel yth, saya sud...
# 5                                                  NaN
# 6                        di tempat sya juga jrngnya 4g
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                          ayo dong secepatnya ya 5g
# 105                             mantap banget telkmsel
# 106                                                 ❤️
# 107  mon maap min, sudah beberapa bulan untuk urusa...
#
#                                          cleaning_text  \
# 2    awas php telkomsel tuker poin telko extra kuot...
# 3     nanya apa telkomsel bermasalah tiba log out t...
# 4    halo selamat mlm admin telkomsel yth saya suda...
# 5                                                  nan
# 6                             tempat sya juga jrngnya
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                               ayo dong secepatnya
# 105                             mantap banget telkmsel
# 106
# 107  mon maap min sudah beberapa bulan untuk urusan...
#
#                                             tokenisasi
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, apa, telkomsel, bermasalah, tiba, lo...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, sa...
# 5                                                [nan]
# 6                     [, tempat, sya, juga, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, baka...
# 104                          [ayo, dong, secepatnya, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, sudah, beberapa, bulan, untuk...
#
# [92 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 2    awas php telkomsel . tuker poin telko extra ku...
# 3    mo nanya apa my telkomsel bermasalah. tiba² lo...
# 4    halo selamat mlm admin telkomsel yth, saya sud...
# 5                                                  NaN
# 6                        di tempat sya juga jrngnya 4g
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                          ayo dong secepatnya ya 5g
# 105                             mantap banget telkmsel
# 106                                                 ❤️
# 107  mon maap min, sudah beberapa bulan untuk urusa...
#
#                                          cleaning_text  \
# 2    awas php telkomsel tuker poin telko extra kuot...
# 3     nanya apa telkomsel bermasalah tiba log out t...
# 4    halo selamat mlm admin telkomsel yth saya suda...
# 5                                                  nan
# 6                             tempat sya juga jrngnya
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                               ayo dong secepatnya
# 105                             mantap banget telkmsel
# 106
# 107  mon maap min sudah beberapa bulan untuk urusan...
#
#                                             tokenisasi  \
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, apa, telkomsel, bermasalah, tiba, lo...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, sa...
# 5                                                [nan]
# 6                     [, tempat, sya, juga, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, baka...
# 104                          [ayo, dong, secepatnya, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, sudah, beberapa, bulan, untuk...
#
#                                               stopword
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, telkomsel, bermasalah, log, out, tru...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, ch...
# 5                                                   []
# 6                                   [, sya, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, berk...
# 104                                [ayo, secepatnya, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, urusan, onlen, habisnya, meng...
#
# [92 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 336
# ------------------------
# awas : awas
# php : php
# telkomsel : telkomsel
# tuker : tuker
# poin : poin
# telko : telko
# extra : extra
# kuota : kuota
# kelar : kelar
# solusinya : solusi
#  :
# nanya : nanya
# bermasalah : masalah
# log : log
# out : out
# trus : trus
# login : login
# halo : halo
# selamat : selamat
# mlm : mlm
# admin : admin
# yth : yth
# chat : chat
# layanan : layan
# langit : langit
# musik : musik
# pengisian : isi
# pulsa : pulsa
# kepotong : potong
# download : download
# apk : apk
# tolong : tolong
# direspon : direspon
# terimakasih : terimakasih
# sya : sya
# jrngnya : jrngnya
# setabil : setabil
# aph : aph
# sinyal : sinyal
# hidup : hidup
# kota : kota
# medukung : medukung
# frekuensi : frekuensi
# engga : engga
# nyesel : nyesel
# pilih : pilih
# ckckck : ckckck
# mantap : mantap
# pokoknya : pokok
# semoga : moga
# kedepannya : depan
# pelayanan : layan
# terbaik : baik
# pengguna : guna
# mkn : mkn
# notif : notif
# upload : upload
# konten : konten
# langsung : langsung
# liat : liat
# yokk : yokk
# buruan : buru
# ratain : ratain
# direktur : direktur
# terhormat : hormat
# bair : bair
# ngerasain : ngerasain
# teknologi : teknologi
# canggih : canggih
# kecepatan : cepat
# sabar : sabar
# make : make
# emang : emang
# deh : deh
# tlkomsl : tlkomsl
# doang : doang
# bgini : bgini
# lanjutkan : lanjut
# min : min
# support : support
# top : top
# duanya : dua
# setia : setia
# perubahan : ubah
# bareng : bareng
# heh : heh
# gile : gile
# mantep : mantep
# penasaran : penasaran
# semangat : semangat
# teruss : teruss
# stabil : stabil
# sok : sok
# soan : soan
# kualitas : kualitas
# benerin : benerin
# gimana : gimana
# aktivasi : aktivasi
# paket : paket
# disney : disney
# eror : eror
# blm : blm
# solusi : solusi
# error : error
# jaringannya : jaring
# gua : gua
# daring : daring
# ngelag : ngelag
# pas : pas
# hujan : hujan
# ama : ama
# mati : mati
# listrik : listrik
# claim : claim
# bonus : bonus
# check : check
# daily : daily
# sampe : sampe
# diproses : proses
# gpp : gpp
# goceng : goceng
# app : app
# hubungi : hubung
# suruh : suruh
# isi : isi
# kuestioner : kuestioner
# kepuasan : puas
# bolak : bolak
# dipakai : pakai
# silahkan : silah
# hapus : hapus
# cust : cust
# suprise : suprise
# deal : deal
# kirimilah : kirim
# penguras : uras
# cepat : cepat
# org : org
# susah : susah
# minnn : minnn
# menang : menang
# dikirim : kirim
# giveawaynya : giveawaynya
# udah : udah
# banget : banget
# thr : thr
# downgrade : downgrade
# kartu : kartu
# gimna : gimna
# akses : akses
# redeem : redeem
# point : point
# aplikasi : aplikasi
# payah : payah
# beli : beli
# mulu : mulu
# ilmu : ilmu
# mencontek : contek
# tingkat : tingkat
# dewa : dewa
# endingnya : endingnya
# bener : bener
# restart : restart
# sma : sma
# mimin : mimin
# cek : cek
# area : area
# donk : donk
# jwb : jwb
# baeee : baeee
# hello : hello
# kuis : kuis
# tanggal : tanggal
# april : april
# blom : blom
# tanda : tanda
# makanisme : makan
# maksimal : maksimal
# kerja : kerja
# knapa : knapa
# dosa : dosa
# nepatin : nepatin
# janji : janji
# woi : woi
# gabisa : gabisa
# diakses : akses
# hidupin : hidupin
# internet : internet
# ngakses : ngakses
# kesedot : sedot
# gitu : gitu
# konsumen : konsumen
# suram : suram
# aplikasinya : aplikasi
# diperbaikilah : baik
# dialihkan : alih
# veronika : veronika
# bot : bot
# dichat : dichat
# ngasih : ngasih
# panas : panas
# brapa : brapa
# tkp : tkp
# list : list
# volte : volte
# tpi : tpi
# velte : velte
# muncul : muncul
# ajah : ajah
# customernya : customernya
# pasca : pasca
# bayar : bayar
# promo : promo
# keren : keren
# gue : gue
# hangus : hangus
# dimana : mana
# paketan : paket
# internetomg : internetomg
# knp : knp
# internetan : internetan
# game : game
# youtube : youtube
# dibelah : belah
# sebulan : bulan
# gmanaaaaa : gmanaaaaa
# tol : tol
# pembelian : beli
# via : via
# gopay : gopay
# berhasil : hasil
# riwayat : riwayat
# pembeliannya : beli
# mytelkomsel : mytelkomsel
# masuk : masuk
# metode : metode
# pembayarannya : bayar
# dana : dana
# please : please
# multimedia : multimedia
# mohon : mohon
# bantuannya : bantu
# ingus : ingus
# naek : naek
# turun : turun
# ikutan : ikut
# gan : gan
# hallo : hallo
# semjak : semjak
# pindah : pindah
# putus : putus
# bales : bales
# bismillah : bismillah
# headshot : headshot
# fd : fd
# data : data
# dapet : dapet
# fdqzs : fdqzs
# laptop : laptop
# emas : emas
# gram : gram
# smartphone : smartphone
# ribuan : ribu
# orang : orang
# pemenang : menang
# kukira : kira
# berkhianat : khianat
# nge : nge
# sms : sms
# temen : temen
# txuh : txuh
# siang : siang
# skarang : skarang
# siiih : siiih
# pemberitahuan : pemberitahuan
# laaaah : laaaah
# woiiiiiii : woiiiiiii
# habis : habis
# memakai : pakai
# instagram : instagram
# pagi : pagi
# maketin : maketin
# utama : utama
# tinggal : tinggal
# iya : iya
# bentaran : bentar
# redi : redi
# berminat : minat
# belajar : ajar
# kekuras : kuras
# aapaan : aapaan
# lemmmoot : lemmmoot
# mintak : mintak
# ampuuun : ampuuun
# memburuk : buruk
# intinya : inti
# indo : indo
# dipake : dipake
# semngat : semngat
# nungguin : nungguin
# mengenal : kenal
# auto : auto
# karna : karna
# menariknya : tarik
# xixix : xixix
# membawa : bawa
# berharap : harap
# meningkat : tingkat
# hadir : hadir
# indonesia : indonesia
# ngeleg : ngeleg
# bermain : main
# lancar : lancar
# gara : gara
# turunin : turunin
# kualitasnya : kualitas
# perbaiki : baik
# juara : juara
# salah : salah
# provider : provider
# dunia : dunia
# industri : industri
# public : public
# administration : administration
# berkembang : kembang
# pesat : pesat
# ayo : ayo
# secepatnya : cepat
# telkmsel : telkmsel
# mon : mon
# maap : maap
# urusan : urus
# onlen : onlen
# habisnya : habis
# mengecewakan : kecewa
# koling : koling
# {'awas': 'awas', 'php': 'php', 'telkomsel': 'telkomsel', 'tuker': 'tuker', 'poin': 'poin', 'telko': 'telko', 'extra': 'extra', 'kuota': 'kuota', 'kelar': 'kelar', 'solusinya': 'solusi', '': '', 'nanya': 'nanya', 'bermasalah': 'masalah', 'log': 'log', 'out': 'out', 'trus': 'trus', 'login': 'login', 'halo': 'halo', 'selamat': 'selamat', 'mlm': 'mlm', 'admin': 'admin', 'yth': 'yth', 'chat': 'chat', 'layanan': 'layan', 'langit': 'langit', 'musik': 'musik', 'pengisian': 'isi', 'pulsa': 'pulsa', 'kepotong': 'potong', 'download': 'download', 'apk': 'apk', 'tolong': 'tolong', 'direspon': 'direspon', 'terimakasih': 'terimakasih', 'sya': 'sya', 'jrngnya': 'jrngnya', 'setabil': 'setabil', 'aph': 'aph', 'sinyal': 'sinyal', 'hidup': 'hidup', 'kota': 'kota', 'medukung': 'medukung', 'frekuensi': 'frekuensi', 'engga': 'engga', 'nyesel': 'nyesel', 'pilih': 'pilih', 'ckckck': 'ckckck', 'mantap': 'mantap', 'pokoknya': 'pokok', 'semoga': 'moga', 'kedepannya': 'depan', 'pelayanan': 'layan', 'terbaik': 'baik', 'pengguna': 'guna', 'mkn': 'mkn', 'notif': 'notif', 'upload': 'upload', 'konten': 'konten', 'langsung': 'langsung', 'liat': 'liat', 'yokk': 'yokk', 'buruan': 'buru', 'ratain': 'ratain', 'direktur': 'direktur', 'terhormat': 'hormat', 'bair': 'bair', 'ngerasain': 'ngerasain', 'teknologi': 'teknologi', 'canggih': 'canggih', 'kecepatan': 'cepat', 'sabar': 'sabar', 'make': 'make', 'emang': 'emang', 'deh': 'deh', 'tlkomsl': 'tlkomsl', 'doang': 'doang', 'bgini': 'bgini', 'lanjutkan': 'lanjut', 'min': 'min', 'support': 'support', 'top': 'top', 'duanya': 'dua', 'setia': 'setia', 'perubahan': 'ubah', 'bareng': 'bareng', 'heh': 'heh', 'gile': 'gile', 'mantep': 'mantep', 'penasaran': 'penasaran', 'semangat': 'semangat', 'teruss': 'teruss', 'stabil': 'stabil', 'sok': 'sok', 'soan': 'soan', 'kualitas': 'kualitas', 'benerin': 'benerin', 'gimana': 'gimana', 'aktivasi': 'aktivasi', 'paket': 'paket', 'disney': 'disney', 'eror': 'eror', 'blm': 'blm', 'solusi': 'solusi', 'error': 'error', 'jaringannya': 'jaring', 'gua': 'gua', 'daring': 'daring', 'ngelag': 'ngelag', 'pas': 'pas', 'hujan': 'hujan', 'ama': 'ama', 'mati': 'mati', 'listrik': 'listrik', 'claim': 'claim', 'bonus': 'bonus', 'check': 'check', 'daily': 'daily', 'sampe': 'sampe', 'diproses': 'proses', 'gpp': 'gpp', 'goceng': 'goceng', 'app': 'app', 'hubungi': 'hubung', 'suruh': 'suruh', 'isi': 'isi', 'kuestioner': 'kuestioner', 'kepuasan': 'puas', 'bolak': 'bolak', 'dipakai': 'pakai', 'silahkan': 'silah', 'hapus': 'hapus', 'cust': 'cust', 'suprise': 'suprise', 'deal': 'deal', 'kirimilah': 'kirim', 'penguras': 'uras', 'cepat': 'cepat', 'org': 'org', 'susah': 'susah', 'minnn': 'minnn', 'menang': 'menang', 'dikirim': 'kirim', 'giveawaynya': 'giveawaynya', 'udah': 'udah', 'banget': 'banget', 'thr': 'thr', 'downgrade': 'downgrade', 'kartu': 'kartu', 'gimna': 'gimna', 'akses': 'akses', 'redeem': 'redeem', 'point': 'point', 'aplikasi': 'aplikasi', 'payah': 'payah', 'beli': 'beli', 'mulu': 'mulu', 'ilmu': 'ilmu', 'mencontek': 'contek', 'tingkat': 'tingkat', 'dewa': 'dewa', 'endingnya': 'endingnya', 'bener': 'bener', 'restart': 'restart', 'sma': 'sma', 'mimin': 'mimin', 'cek': 'cek', 'area': 'area', 'donk': 'donk', 'jwb': 'jwb', 'baeee': 'baeee', 'hello': 'hello', 'kuis': 'kuis', 'tanggal': 'tanggal', 'april': 'april', 'blom': 'blom', 'tanda': 'tanda', 'makanisme': 'makan', 'maksimal': 'maksimal', 'kerja': 'kerja', 'knapa': 'knapa', 'dosa': 'dosa', 'nepatin': 'nepatin', 'janji': 'janji', 'woi': 'woi', 'gabisa': 'gabisa', 'diakses': 'akses', 'hidupin': 'hidupin', 'internet': 'internet', 'ngakses': 'ngakses', 'kesedot': 'sedot', 'gitu': 'gitu', 'konsumen': 'konsumen', 'suram': 'suram', 'aplikasinya': 'aplikasi', 'diperbaikilah': 'baik', 'dialihkan': 'alih', 'veronika': 'veronika', 'bot': 'bot', 'dichat': 'dichat', 'ngasih': 'ngasih', 'panas': 'panas', 'brapa': 'brapa', 'tkp': 'tkp', 'list': 'list', 'volte': 'volte', 'tpi': 'tpi', 'velte': 'velte', 'muncul': 'muncul', 'ajah': 'ajah', 'customernya': 'customernya', 'pa ...
# ------------------------
# Pandas Apply:   0%|          | 0/92 [00:00<?, ?it/s]
#                                                   text  \
# 2    awas php telkomsel . tuker poin telko extra ku...
# 3    mo nanya apa my telkomsel bermasalah. tiba² lo...
# 4    halo selamat mlm admin telkomsel yth, saya sud...
# 5                                                  NaN
# 6                        di tempat sya juga jrngnya 4g
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                          ayo dong secepatnya ya 5g
# 105                             mantap banget telkmsel
# 106                                                 ❤️
# 107  mon maap min, sudah beberapa bulan untuk urusa...
#
#                                          cleaning_text  \
# 2    awas php telkomsel tuker poin telko extra kuot...
# 3     nanya apa telkomsel bermasalah tiba log out t...
# 4    halo selamat mlm admin telkomsel yth saya suda...
# 5                                                  nan
# 6                             tempat sya juga jrngnya
# ..                                                 ...
# 103  dunia industri public administration bakal ber...
# 104                               ayo dong secepatnya
# 105                             mantap banget telkmsel
# 106
# 107  mon maap min sudah beberapa bulan untuk urusan...
#
#                                             tokenisasi  \
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, apa, telkomsel, bermasalah, tiba, lo...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, sa...
# 5                                                [nan]
# 6                     [, tempat, sya, juga, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, baka...
# 104                          [ayo, dong, secepatnya, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, sudah, beberapa, bulan, untuk...
#
#                                               stopword  \
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, telkomsel, bermasalah, log, out, tru...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, ch...
# 5                                                   []
# 6                                   [, sya, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, berk...
# 104                                [ayo, secepatnya, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, urusan, onlen, habisnya, meng...
#
#                                               stemming
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, telkomsel, masalah, log, out, trus, ...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, ch...
# 5                                                   []
# 6                                   [, sya, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, kemb...
# 104                                     [ayo, cepat, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, urus, onlen, habis, kecewa, k...
#
# [92 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 2    [awas, php, telkomsel, tuker, poin, telko, ext...
# 3    [, nanya, telkomsel, masalah, log, out, trus, ...
# 4    [halo, selamat, mlm, admin, telkomsel, yth, ch...
# 5                                                   []
# 6                                   [, sya, jrngnya, ]
# ..                                                 ...
# 103  [dunia, industri, public, administration, kemb...
# 104                                     [ayo, cepat, ]
# 105                         [mantap, banget, telkmsel]
# 106                                               [, ]
# 107  [mon, maap, min, urus, onlen, habis, kecewa, k...
#
# [92 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_7.xlsx')
