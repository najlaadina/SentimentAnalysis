# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                Paket gamesmax..GK bisa di pake haduh
# 1                                                  NaN
# 2                                   MIN CEK DM PLEASE!
# 3    Sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  Min
# ..                                                 ...
# 190  Iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        Rebahaan~~~
# 192                        Hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
# [195 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                Paket gamesmax..GK bisa di pake haduh
# 3    Sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  Min
# 5    Min saya beli paket internet di my telkomsel k...
# 6    Ini gimana sih min,aplikasi my Telkomsel kok g...
# ..                                                 ...
# 190  Iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        Rebahaan~~~
# 192                        Hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
# [172 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                paket gamesmax..gk bisa di pake haduh
# 3    sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  min
# 5    min saya beli paket internet di my telkomsel k...
# 6    ini gimana sih min,aplikasi my telkomsel kok g...
# ..                                                 ...
# 190  iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        rebahaan~~~
# 192                        hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
# [172 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                paket gamesmax..gk bisa di pake haduh
# 3    sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  min
# 5    min saya beli paket internet di my telkomsel k...
# 6    ini gimana sih min,aplikasi my telkomsel kok g...
# ..                                                 ...
# 190  iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        rebahaan~~~
# 192                        hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
#                                          cleaning_text
# 0                       paket gamesmax bisa pake haduh
# 3    sinyalnya payah kayak lagi hutan belantara pad...
# 4                                                  min
# 5    min saya beli paket internet telkomsel kok gak...
# 6    ini gimana sih min aplikasi telkomsel kok gabi...
# ..                                                 ...
# 190  iya min nanem bunga sama melihara cupang wkwkw...
# 191                                          rebahaan
# 192                         hobi baru ngikut give away
# 193
# 194  hobi saya   ini sekarang aktif berolahraga khu...
#
# [172 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                paket gamesmax..gk bisa di pake haduh
# 3    sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  min
# 5    min saya beli paket internet di my telkomsel k...
# 6    ini gimana sih min,aplikasi my telkomsel kok g...
# ..                                                 ...
# 190  iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        rebahaan~~~
# 192                        hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
#                                          cleaning_text  \
# 0                       paket gamesmax bisa pake haduh
# 3    sinyalnya payah kayak lagi hutan belantara pad...
# 4                                                  min
# 5    min saya beli paket internet telkomsel kok gak...
# 6    ini gimana sih min aplikasi telkomsel kok gabi...
# ..                                                 ...
# 190  iya min nanem bunga sama melihara cupang wkwkw...
# 191                                          rebahaan
# 192                         hobi baru ngikut give away
# 193
# 194  hobi saya   ini sekarang aktif berolahraga khu...
#
#                                             tokenisasi
# 0                 [paket, gamesmax, bisa, pake, haduh]
# 3    [sinyalnya, payah, kayak, lagi, hutan, belanta...
# 4                                                [min]
# 5    [min, saya, beli, paket, internet, telkomsel, ...
# 6    [ini, gimana, sih, min, aplikasi, telkomsel, k...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, sama, melihara, cupan...
# 191                                       [rebahaan, ]
# 192                   [hobi, baru, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, saya, ini, sekarang, aktif, berolahraga...
#
# [172 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                paket gamesmax..gk bisa di pake haduh
# 3    sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  min
# 5    min saya beli paket internet di my telkomsel k...
# 6    ini gimana sih min,aplikasi my telkomsel kok g...
# ..                                                 ...
# 190  iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        rebahaan~~~
# 192                        hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
#                                          cleaning_text  \
# 0                       paket gamesmax bisa pake haduh
# 3    sinyalnya payah kayak lagi hutan belantara pad...
# 4                                                  min
# 5    min saya beli paket internet telkomsel kok gak...
# 6    ini gimana sih min aplikasi telkomsel kok gabi...
# ..                                                 ...
# 190  iya min nanem bunga sama melihara cupang wkwkw...
# 191                                          rebahaan
# 192                         hobi baru ngikut give away
# 193
# 194  hobi saya   ini sekarang aktif berolahraga khu...
#
#                                             tokenisasi  \
# 0                 [paket, gamesmax, bisa, pake, haduh]
# 3    [sinyalnya, payah, kayak, lagi, hutan, belanta...
# 4                                                [min]
# 5    [min, saya, beli, paket, internet, telkomsel, ...
# 6    [ini, gimana, sih, min, aplikasi, telkomsel, k...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, sama, melihara, cupan...
# 191                                       [rebahaan, ]
# 192                   [hobi, baru, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, saya, ini, sekarang, aktif, berolahraga...
#
#                                               stopword
# 0                             [paket, gamesmax, haduh]
# 3    [sinyalnya, payah, kayak, hutan, belantara, ko...
# 4                                                [min]
# 5    [min, beli, paket, internet, telkomsel, beli, ...
# 6    [gimana, min, aplikasi, telkomsel, gabisa, dib...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, melihara, cupang, wkw...
# 191                                       [rebahaan, ]
# 192                         [hobi, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, aktif, berolahraga, khusunya, lari, pag...
#
# [172 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 626
# ------------------------
# paket : paket
# gamesmax : gamesmax
# haduh : haduh
# sinyalnya : sinyal
# payah : payah
# kayak : kayak
# hutan : hutan
# belantara : belantara
# kota : kota
#  :
# min : min
# beli : beli
# internet : internet
# telkomsel : telkomsel
# pakai : pakai
# kode : kode
# dial : dial
# masuk : masuk
# gimana : gimana
# aplikasi : aplikasi
# gabisa : gabisa
# dibuka : buka
# gajelas : gajelas
# habis : habis
# update : update
# ancur : ancur
# respon : respon
# tolong : tolong
# cek : cek
# omg : omg
# disney : disney
# pas : pas
# buka : buka
# aplikasinya : aplikasi
# berlangganan : langgan
# gua : gua
# kuota : kuota
# khusus : khusus
# game : game
# dipake : dipake
# iya : iya
# utama : utama
# cel : cel
# kualitas : kualitas
# buruk : buruk
# suruh : suruh
# veronika : veronika
# tpi : tpi
# teljomselnya : teljomselnya
# eror : eror
# kring : kring
# laaa : laaa
# hallo : hallo
# margaretta : margaretta
# tamba : tamba
# salah : salah
# pemenang : menang
# pantun : pantun
# live : live
# chat : chat
# youtube : youtube
# halo : halo
# kak : kak
# dapet : dapet
# ceria : ceria
# dikit : dikit
# grapari : grapari
# ganti : ganti
# kartu : kartu
# rb : rb
# woy : woy
# signal : signal
# brantakan : brantakan
# goblok : goblok
# knp : knp
# apk : apk
# liat : liat
# dilingkungan : lingkung
# radius : radius
# meter : meter
# jangkauan : jangkau
# sinyal : sinyal
# serasa : serasa
# hidup : hidup
# akses : akses
# nelpon : nelpon
# ditempat : tempat
# tingggi : tingggi
# indonesia : indonesia
# raya : raya
# plis : plis
# poin : poin
# baca : baca
# lingkungan : lingkung
# kalangan : kalang
# anak : anak
# remaja : remaja
# sibuk : sibuk
# terimakasih : terimakasih
# combo : combo
# langganan : langgan
# hotstar : hotstar
# tambahan : tambah
# makasih : makasih
# parahhh : parahhh
# rame : rame
# gitu : gitu
# film : film
# nonton : nonton
# bentar : bentar
# udah : udah
# betah : betah
# rhn : rhn
# ntn : ntn
# reguler : reguler
# gmna : gmna
# seru : seru
# kocak : kocak
# diawal : awal
# tunggu : tunggu
# prasetio : prasetio
# suka : suka
# help : help
# nyeleneh : nyeleneh
# azwwwwww : azwwwwww
# pengumuman : umum
# iphone : iphone
# dmn : dmn
# rameee : rameee
# kamar : kamar
# cman : cman
# bar : bar
# simpati : simpati
# pelayanannya : layan
# ngikutin : ngikutin
# episode : episode
# ketiga : tiga
# bayi : bayi
# laki : laki
# kembar : kembar
# wanda : wanda
# vision : vision
# married : married
# really : really
# bro : bro
# njh : njh
# eps : eps
# gregett : gregett
# kemarin : kemarin
# isi : isi
# paketan : paket
# terpotong : potong
# saldo : saldo
# ampe : ampe
# aktifin : aktifin
# ipone : ipone
# gmn : gmn
# ngk : ngk
# bener : bener
# maen : maen
# ngelag : ngelag
# mulu : mulu
# perbaikan : baik
# yak : yak
# mantap : mantap
# stream : stream
# sepuasnya : puas
# mending : mending
# kaga : kaga
# promo : promo
# unlimited : unlimited
# segalaaa : segalaaa
# klw : klw
# niat : niat
# kasih : kasih
# harga : harga
# termurah : murah
# ngadi : ngadi
# woi : woi
# dihp : dihp
# ios : ios
# type : type
# ip : ip
# force : force
# close : close
# kouta : kouta
# kendala : kendala
# bismillah : bismillah
# ngedown : ngedown
# area : area
# duren : duren
# sawit : sawit
# malam : malam
# koneksi : koneksi
# jam : jam
# heloooooo : heloooooo
# tsel : tsel
# rewel : rewel
# gini : gin
# signalnya : signalnya
# problem : problem
# sbnernya : sbnernya
# emosi : emosi
# kadang : kadang
# nggak : nggak
# ngebantu : ngebantu
# alesan : alesan
# lari : lari
# tanggung : tanggung
# stop : stop
# opsi : opsi
# mohon : mohon
# infonya : info
# aktivasi : aktivasi
# telpon : telpon
# loop : loop
# ldr : ldr
# panggilan : panggil
# memiliki : milik
# pulsa : pulsa
# aktif : aktif
# huuftt : huuftt
# nybelin : nybelin
# banget : banget
# abisss : abisss
# kesedot : sedot
# kemana : mana
# kena : kena
# tarif : tarif
# sungguh : sungguh
# butuh : butuh
# murah : murah
# thn : thn
# dpt : dpt
# mencekikkkkkk : mencekikkkkkk
# don : don
# you : you
# feel : feel
# user : user
# complaints : complaints
# selamat : selamat
# pagi : pagi
# izin : izin
# nomor : nomor
# mati : mati
# aktifkan : aktif
# orang : orang
# donk : donk
# php : php
# dibalesnya : dibalesnya
# seklia : seklia
# doank : doank
# parah : parah
# bgtttt : bgtttt
# laporan : lapor
# bjn : bjn
# proses : proses
# hubungi : hubung
# secepatnya : cepat
# melapor : lapor
# januari : januari
# tgl : tgl
# email : email
# tanggal : tanggal
# solusi : solusi
# hai : hai
# tenggang : tenggang
# sebulan : bulan
# hidupin : hidupin
# trim : trim
# gratisin : gratisin
# aktivin : aktivin
# blok : blok
# bayar : bayar
# upgrade : upgrade
# system : system
# sampe : sampe
# segitu : segitu
# sinya : sinya
# jadul : jadul
# donlot : donlot
# hikhikhik : hikhikhik
# pny : pny
# diamon : diamon
# instaloop : instaloop
# sinyale : sinyale
# alot : alot
# kang : kang
# ketengan : keteng
# kemaren : kemaren
# mytelkomsel : mytelkomsel
# via : via
# umb : umb
# notifikasinya : notifikasi
# telat : telat
# sms : sms
# lucky : lucky
# draw : draw
# terblokir : blokir
# nomornya : nomor
# whatsapp : whatsapp
# urus : urus
# seminggu : minggu
# nga : nga
# tanggapannya : tanggap
# carax : carax
# mudah : mudah
# puk : puk
# diarahin : diarahin
# kirim : kirim
# datanya : data
# dianterin : dianterin
# deh : deh
# barunya : baru
# rumah : rumah
# terima : terima
# vero : vero
# permisi : permisi
# memperbarui : baru
# koneksinya : koneksi
# udh : udh
# lemah : lemah
# kebanyakan : banyak
# bagus : bagus
# pindah : pindah
# migrasi : migrasi
# nonaktifkan : nonaktif
# ngga : ngga
# support : support
# esim : esim
# blm : blm
# produk : produk
# keluarin : keluarin
# sya : sya
# karti : karti
# ngak : ngak
# gnti : gnti
# model : model
# krtu : krtu
# nano : nano
# perdana : perdana
# prabayar : prabayar
# pengen : ken
# upgred : upgred
# makinueeedaann : makinueeedaann
# samakan : sama
# ubah : ubah
# rbu : rbu
# gb : gb
# log : log
# maaf : maaf
# kakk : kakk
# daftar : daftar
# bngt : bngt
# facebook : facebook
# top : top
# kpn : kpn
# pngumuman : pngumuman
# point : point
# desember : desember
# ktya : ktya
# suprise : suprise
# best : best
# deal : deal
# surprise : surprise
# instagram : instagram
# admin : admin
# undian : undi
# the : the
# pengumumannya : umum
# kaa : kaa
# tukar : tukar
# taun : taun
# topup : topup
# voucher : voucher
# gamemax : gamemax
# bln : bln
# kmrn : kmrn
# freedom : freedom
# max : max
# media : media
# social : social
# hapus : hapus
# free : free
# mola : mola
# menang : menang
# ntar : ntar
# hub : hub
# siang : siang
# oke : oke
# astagfirullah : astagfirullah
# wow : wow
# matap : matap
# tlpon : tlpon
# cintak : cintak
# center : center
# lost : lost
# kontak : kontak
# ataw : ataw
# matiin : matiin
# aslmualaikum : aslmualaikum
# hadiah : hadiah
# giveaway : giveaway
# yaa : yaa
# minggu : minggu
# diundi : undi
# pengundian : undi
# beneran : beneran
# masak : masak
# ngecek : ngecek
# kupon : kupon
# ditukerin : ditukerin
# mlh : mlh
# penjelasan : jelas
# something : something
# went : went
# wrong : wrong
# klu : klu
# wentvw : wentvw
# diakses : akses
# untung : untung
# benahin : benahin
# kasian : kasi
# temen : temen
# ilang : ilang
# make : make
# kepengen : ken
# mercedes : mercedes
# benz : benz
# nnti : nnti
# dilan : dil
# foreign : foreign
# error : error
# normal : normal
# kendalanya : kendala
# total : total
# telkomselnya : telkomselnya
# urgent : urgent
# hobi : hobi
# jdi : jdi
# trader : trader
# hobiku : hobi
# ikutan : ikut
# heee : heee
# keliling : keliling
# nyarinwifi : nyarinwifi
# gratis : gratis
# daerah : daerah
# ngedrakor : ngedrakor
# ganggu : ganggu
# dapatkan : dapat
# discount : discount
# minimum : minimum
# pembelian : beli
# cuman : cuman
# libur : libur
# order : order
# grabfood : grabfood
# agen : agen
# data : data
# melayani : layan
# pembayaran : bayar
# ppob : ppob
# transfer : transfer
# bank : bank
# bisaa : bisaa
# registrasi : registrasi
# ayo : ayo
# sia : sia
# siakan : sia
# kesempatan : sempat
# download : download
# instal : instal
# payfazz : payfazz
# klik : klik
# tulisan : tulis
# akun : akun
# link : link
# bio : bio
# masukkan : masuk
# dipakai : pakai
# notifikasi : notifikasi
# otp : otp
# sesuai : sesuai
# masuh : masuh
# ketik : ketik
# nama : nama
# lengkap : lengkap
# buatlah : buat
# password : password
# dikombinasikan : kombinasi
# huruf : huruf
# sertakan : serta
# angka : angka
# contoh : contoh
# komisi : komisi
# transaksi : transaksi
# refferal : refferal
# ika : ika
# cue : cue
# wajib : wajib
# diisi : isi
# login : login
# langsung : langsung
# booommmm : booommmm
# bergabung : gabung
# semoga : moga
# sukses : sukses
# bisnis : bisnis
# salam : salam
# catatan : catat
# cashback : cashback
# full : full
# bimbingan : bimbing
# bercocok : cocok
# tanam : tanam
# tanaman : tanam
# hias : hias
# bunga : bunga
# kacau : kacau
# gercep : gercep
# reload : reload
# ampun : ampun
# kuantitas : kuantitas
# lawan : lawan
# terlupakan : lupa
# sedih : sedih
# lampu : lampu
# wonogiri : wonogiri
# tirtomoyo : tirtomoyo
# woyyy : woyyy
# anjay : anjay
# mabar : mabar
# semangattt : semangattt
# biasaaa : biasaaa
# berusaha : usaha
# terbaik : baik
# situasi : situasi
# apapun : apa
# karna : karna
# efek : efek
# riau : riau
# desa : desa
# kulau : kulau
# kecamatan : camat
# tambang : tambang
# perum : perum
# graha : graha
# kualu : alu
# payung : payung
# sekaki : sekak
# internetnya : internetnya
# diskon : diskon
# terdampak : dampak
# bisalah : bisa
# tegal : tegal
# okeh : okeh
# pagerbarang : pagerbarang
# skrng : skrng
# blom : blom
# mengakses : akses
# gprs : gprs
# nomer : nomer
# flash : flash
# ngehabisin : ngehabisin
# pulsaku : pulsa
# sumatra : sumatra
# selatan : selatan
# kususnya : sus
# kayuagung : kayuagung
# kec : kec
# pampangan : pampang
# pulihkan : pulih
# semangat : semangat
# kawan : kawan
# teknisi : teknisi
# dealnya : dealnya
# wowwwww : wowwwww
# unfollow : unfollow
# ngradag : ngradag
# good : good
# bersepeda : sepeda
# mematuhi : patuh
# protokol : protokol
# kesehatan : sehat
# menulis : tulis
# novel : novel
# bgeet : bgeet
# dunia : dunia
# trus : trus
# potret : potret
# keindahan : indah
# alam : alam
# diseluruh : seluruh
# lancar : lancar
# nanem : nanem
# melihara : melihara
# cupang : cupang
# wkwkwkkwk : wkwkwkkwk
# rebahaan : rebahaan
# ngikut : ngikut
# give : give
# away : away
# berolahraga : olahraga
# khusunya : khusunya
# berjemur : jemur
# cuaca : cuaca
# mendukung : dukung
# disaat : saat
# pandemi : pandemi
# corona : corona
# lbh : lbh
# diam : diam
# dirumah : rumah
# rajin : rajin
# imun : imun
# tubuh : tubuh
# sehat : sehat
# beres : beres
# nyapu : nyapu
# ngepel : ngepel
# cuci : cuci
# piring : piring
# mengeluarkan : keluar
# keringat : keringat
# gais : gais
# {'paket': 'paket', 'gamesmax': 'gamesmax', 'haduh': 'haduh', 'sinyalnya': 'sinyal', 'payah': 'payah', 'kayak': 'kayak', 'hutan': 'hutan', 'belantara': 'belantara', 'kota': 'kota', '': '', 'min': 'min', 'beli': 'beli', 'internet': 'internet', 'telkomsel': 'telkomsel', 'pakai': 'pakai', 'kode': 'kode', 'dial': 'dial', 'masuk': 'masuk', 'gimana': 'gimana', 'aplikasi': 'aplikasi', 'gabisa': 'gabisa', 'dibuka': 'buka', 'gajelas': 'gajelas', 'habis': 'habis', 'update': 'update', 'ancur': 'ancur', 'respon': 'respon', 'tolong': 'tolong', 'cek': 'cek', 'omg': 'omg', 'disney': 'disney', 'pas': 'pas', 'buka': 'buka', 'aplikasinya': 'aplikasi', 'berlangganan': 'langgan', 'gua': 'gua', 'kuota': 'kuota', 'khusus': 'khusus', 'game': 'game', 'dipake': 'dipake', 'iya': 'iya', 'utama': 'utama', 'cel': 'cel', 'kualitas': 'kualitas', 'buruk': 'buruk', 'suruh': 'suruh', 'veronika': 'veronika', 'tpi': 'tpi', 'teljomselnya': 'teljomselnya', 'eror': 'eror', 'kring': 'kring', 'laaa': 'laaa', 'hallo': 'hallo', 'margaretta': 'margaretta', 'tamba': 'tamba', 'salah': 'salah', 'pemenang': 'menang', 'pantun': 'pantun', 'live': 'live', 'chat': 'chat', 'youtube': 'youtube', 'halo': 'halo', 'kak': 'kak', 'dapet': 'dapet', 'ceria': 'ceria', 'dikit': 'dikit', 'grapari': 'grapari', 'ganti': 'ganti', 'kartu': 'kartu', 'rb': 'rb', 'woy': 'woy', 'signal': 'signal', 'brantakan': 'brantakan', 'goblok': 'goblok', 'knp': 'knp', 'apk': 'apk', 'liat': 'liat', 'dilingkungan': 'lingkung', 'radius': 'radius', 'meter': 'meter', 'jangkauan': 'jangkau', 'sinyal': 'sinyal', 'serasa': 'serasa', 'hidup': 'hidup', 'akses': 'akses', 'nelpon': 'nelpon', 'ditempat': 'tempat', 'tingggi': 'tingggi', 'indonesia': 'indonesia', 'raya': 'raya', 'plis': 'plis', 'poin': 'poin', 'baca': 'baca', 'lingkungan': 'lingkung', 'kalangan': 'kalang', 'anak': 'anak', 'remaja': 'remaja', 'sibuk': 'sibuk', 'terimakasih': 'terimakasih', 'combo': 'combo', 'langganan': 'langgan', 'hotstar': 'hotstar', 'tambahan': 'tambah', 'makasih': 'makasih', 'parahhh': 'parahhh', 'rame': 'rame', 'gitu': 'gitu', 'film': 'film', 'nonton': 'nonton', 'bentar': 'bentar', 'udah': 'udah', 'betah': 'betah', 'rhn': 'rhn', 'ntn': 'ntn', 'reguler': 'reguler', 'gmna': 'gmna', 'seru': 'seru', 'kocak': 'kocak', 'diawal': 'awal', 'tunggu': 'tunggu', 'prasetio': 'prasetio', 'suka': 'suka', 'help': 'help', 'nyeleneh': 'nyeleneh', 'azwwwwww': 'azwwwwww', 'pengumuman': 'umum', 'iphone': 'iphone', 'dmn': 'dmn', 'rameee': 'rameee', 'kamar': 'kamar', 'cman': 'cman', 'bar': 'bar', 'simpati': 'simpati', 'pelayanannya': 'layan', 'ngikutin': 'ngikutin', 'episode': 'episode', 'ketiga': 'tiga', 'bayi': 'bayi', 'laki': 'laki', 'kembar': 'kembar', 'wanda': 'wanda', 'vision': 'vision', 'married': 'married', 'really': 'really', 'bro': 'bro', 'njh': 'njh', 'eps': 'eps', 'gregett': 'gregett', 'kemarin': 'kemarin', 'isi': 'isi', 'paketan': 'paket', 'terpotong': 'potong', 'saldo': 'saldo', 'ampe': 'ampe', 'aktifin': 'aktifin', 'ipone': 'ipone', 'gmn': 'gmn', 'ngk': 'ngk', 'bener': 'bener', 'maen': 'maen', 'ngelag': 'ngelag', 'mulu': 'mulu', 'perbaikan': 'baik', 'yak': 'yak', 'mantap': 'mantap', 'stream': 'stream', 'sepuasnya': 'puas', 'mending': 'mending', 'kaga': 'kaga', 'promo': 'promo', 'unlimited': 'unlimited', 'segalaaa': 'segalaaa', 'klw': 'klw', 'niat': 'niat', 'kasih': 'kasih', 'harga': 'harga', 'termurah': 'murah', 'ngadi': 'ngadi', 'woi': 'woi', 'dihp': 'dihp', 'ios': 'ios', 'type': 'type', 'ip': 'ip', 'force': 'force', 'close': 'close', 'kouta': 'kouta', 'kendala': 'kendala', 'bismillah': 'bismillah', 'ngedown': 'ngedown', 'area': 'area', 'duren': 'duren', 'sawit': 'sawit', 'malam': 'malam', 'koneksi': 'koneksi', 'jam': 'jam', 'heloooooo': 'heloooooo', 'tsel': 'tsel', 'rewel': 'rewel', 'gini': 'gin', 'signalnya': 'signalnya', 'problem': 'problem', 'sbnernya': 'sbnernya', 'emosi': 'emosi', 'kadang': 'kadang', 'nggak': 'nggak', 'ngebantu': 'ngebantu', 'alesan': 'alesan', 'lari': 'lari', 'tanggung': 'tanggung', 'stop': 'stop', 'opsi': 'opsi', 'mohon ...
# ------------------------
# Pandas Apply:   0%|          | 0/172 [00:00<?, ?it/s]
#                                                   text  \
# 0                paket gamesmax..gk bisa di pake haduh
# 3    sinyalnya payah kayak lagi di hutan belantara ...
# 4                                                  min
# 5    min saya beli paket internet di my telkomsel k...
# 6    ini gimana sih min,aplikasi my telkomsel kok g...
# ..                                                 ...
# 190  iya min, nanem bunga sama melihara cupang wkwk...
# 191                                        rebahaan~~~
# 192                        hobi baru ngikut give away
# 193                                           ❤️❤️❤️❤️
# 194  hobi saya 2021 ini sekarang aktif berolahraga ...
#
#                                          cleaning_text  \
# 0                       paket gamesmax bisa pake haduh
# 3    sinyalnya payah kayak lagi hutan belantara pad...
# 4                                                  min
# 5    min saya beli paket internet telkomsel kok gak...
# 6    ini gimana sih min aplikasi telkomsel kok gabi...
# ..                                                 ...
# 190  iya min nanem bunga sama melihara cupang wkwkw...
# 191                                          rebahaan
# 192                         hobi baru ngikut give away
# 193
# 194  hobi saya   ini sekarang aktif berolahraga khu...
#
#                                             tokenisasi  \
# 0                 [paket, gamesmax, bisa, pake, haduh]
# 3    [sinyalnya, payah, kayak, lagi, hutan, belanta...
# 4                                                [min]
# 5    [min, saya, beli, paket, internet, telkomsel, ...
# 6    [ini, gimana, sih, min, aplikasi, telkomsel, k...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, sama, melihara, cupan...
# 191                                       [rebahaan, ]
# 192                   [hobi, baru, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, saya, ini, sekarang, aktif, berolahraga...
#
#                                               stopword  \
# 0                             [paket, gamesmax, haduh]
# 3    [sinyalnya, payah, kayak, hutan, belantara, ko...
# 4                                                [min]
# 5    [min, beli, paket, internet, telkomsel, beli, ...
# 6    [gimana, min, aplikasi, telkomsel, gabisa, dib...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, melihara, cupang, wkw...
# 191                                       [rebahaan, ]
# 192                         [hobi, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, aktif, berolahraga, khusunya, lari, pag...
#
#                                               stemming
# 0                             [paket, gamesmax, haduh]
# 3     [sinyal, payah, kayak, hutan, belantara, kota, ]
# 4                                                [min]
# 5    [min, beli, paket, internet, telkomsel, beli, ...
# 6    [gimana, min, aplikasi, telkomsel, gabisa, buk...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, melihara, cupang, wkw...
# 191                                       [rebahaan, ]
# 192                         [hobi, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, aktif, olahraga, khusunya, lari, pagi, ...
#
# [172 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                             [paket, gamesmax, haduh]
# 3     [sinyal, payah, kayak, hutan, belantara, kota, ]
# 4                                                [min]
# 5    [min, beli, paket, internet, telkomsel, beli, ...
# 6    [gimana, min, aplikasi, telkomsel, gabisa, buk...
# ..                                                 ...
# 190  [iya, min, nanem, bunga, melihara, cupang, wkw...
# 191                                       [rebahaan, ]
# 192                         [hobi, ngikut, give, away]
# 193                                               [, ]
# 194  [hobi, aktif, olahraga, khusunya, lari, pagi, ...
#
# [172 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_1.xlsx')
