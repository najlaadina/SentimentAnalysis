# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                                Done
# 1                                                Done
# 2                                 Done #serunyasenyawa
# 3                                                 DONE
# 4                                                 Done
# ..                                                 ...
# 155  Pengguna Setia Telkomsel , Memang Paling Kuali...
# 156  Aku pelanggan setia Telkomsel ngak pernah dpt ...
# 157                              Sinyalnya bikin emosi
# 158                    Ga pernah dapet apa2 dari dulu.
# 159  Min DM ku untuk ngeklaim hadiah pulsa kok gak ...
#
# [160 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 15

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 3                                                 DONE
# 4                                                 Done
# 5    sudah, semoga kali ini beruntung Aamiin @telko...
# 6                                 Done #serunyaSenyawa
# 7                                      #SerunyaSenyawa
# ..                                                 ...
# 155  Pengguna Setia Telkomsel , Memang Paling Kuali...
# 156  Aku pelanggan setia Telkomsel ngak pernah dpt ...
# 157                              Sinyalnya bikin emosi
# 158                    Ga pernah dapet apa2 dari dulu.
# 159  Min DM ku untuk ngeklaim hadiah pulsa kok gak ...
#
# [135 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 3                                                 done
# 4                                                 done
# 5    sudah, semoga kali ini beruntung aamiin @telko...
# 6                                 done #serunyasenyawa
# 7                                      #serunyasenyawa
# ..                                                 ...
# 155  pengguna setia telkomsel , memang paling kuali...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                    ga pernah dapet apa2 dari dulu.
# 159  min dm ku untuk ngeklaim hadiah pulsa kok gak ...
#
# [135 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 3                                                 done
# 4                                                 done
# 5    sudah, semoga kali ini beruntung aamiin @telko...
# 6                                 done #serunyasenyawa
# 7                                      #serunyasenyawa
# ..                                                 ...
# 155  pengguna setia telkomsel , memang paling kuali...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                    ga pernah dapet apa2 dari dulu.
# 159  min dm ku untuk ngeklaim hadiah pulsa kok gak ...
#
#                                          cleaning_text
# 3                                                 done
# 4                                                 done
# 5               sudah semoga kali ini beruntung aamiin
# 6                                                 done
# 7
# ..                                                 ...
# 155  pengguna setia telkomsel memang paling kualita...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                       pernah dapet apa  dari dulu
# 159  min untuk ngeklaim hadiah pulsa kok gak diliha...
#
# [135 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 3                                                 done
# 4                                                 done
# 5    sudah, semoga kali ini beruntung aamiin @telko...
# 6                                 done #serunyasenyawa
# 7                                      #serunyasenyawa
# ..                                                 ...
# 155  pengguna setia telkomsel , memang paling kuali...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                    ga pernah dapet apa2 dari dulu.
# 159  min dm ku untuk ngeklaim hadiah pulsa kok gak ...
#
#                                          cleaning_text  \
# 3                                                 done
# 4                                                 done
# 5               sudah semoga kali ini beruntung aamiin
# 6                                                 done
# 7
# ..                                                 ...
# 155  pengguna setia telkomsel memang paling kualita...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                       pernah dapet apa  dari dulu
# 159  min untuk ngeklaim hadiah pulsa kok gak diliha...
#
#                                             tokenisasi
# 3                                               [done]
# 4                                               [done]
# 5        [sudah, semoga, kali, ini, beruntung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155  [pengguna, setia, telkomsel, memang, paling, k...
# 156  [aku, pelanggan, setia, telkomsel, ngak, perna...
# 157                          [sinyalnya, bikin, emosi]
# 158               [, pernah, dapet, apa, dari, dulu, ]
# 159  [min, untuk, ngeklaim, hadiah, pulsa, kok, gak...
#
# [135 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 3                                                 done
# 4                                                 done
# 5    sudah, semoga kali ini beruntung aamiin @telko...
# 6                                 done #serunyasenyawa
# 7                                      #serunyasenyawa
# ..                                                 ...
# 155  pengguna setia telkomsel , memang paling kuali...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                    ga pernah dapet apa2 dari dulu.
# 159  min dm ku untuk ngeklaim hadiah pulsa kok gak ...
#
#                                          cleaning_text  \
# 3                                                 done
# 4                                                 done
# 5               sudah semoga kali ini beruntung aamiin
# 6                                                 done
# 7
# ..                                                 ...
# 155  pengguna setia telkomsel memang paling kualita...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                       pernah dapet apa  dari dulu
# 159  min untuk ngeklaim hadiah pulsa kok gak diliha...
#
#                                             tokenisasi  \
# 3                                               [done]
# 4                                               [done]
# 5        [sudah, semoga, kali, ini, beruntung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155  [pengguna, setia, telkomsel, memang, paling, k...
# 156  [aku, pelanggan, setia, telkomsel, ngak, perna...
# 157                          [sinyalnya, bikin, emosi]
# 158               [, pernah, dapet, apa, dari, dulu, ]
# 159  [min, untuk, ngeklaim, hadiah, pulsa, kok, gak...
#
#                                               stopword
# 3                                               [done]
# 4                                               [done]
# 5                    [semoga, kali, beruntung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155             [pengguna, setia, telkomsel, kualitas]
# 156  [pelanggan, setia, telkomsel, ngak, dpt, hadia...
# 157                                 [sinyalnya, emosi]
# 158                                        [, dapet, ]
# 159                   [min, ngeklaim, hadiah, pulsa, ]
#
# [135 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 463
# ------------------------
# done : done
# semoga : moga
# kali : kali
# beruntung : untung
# aamiin : aamiin
#  :
# minnn : minnn
# wish : wish
# luck : luck
# min : min
# rezekinya : rezeki
# carax : carax
# gmna : gmna
# fdl : fdl
# bakar : bakar
# sosis : sosis
# diatas : atas
# tungku : tungku
# tumpah : tumpah
# taukah : tau
# harapanku : harap
# raih : raih
# hadiah : hadiah
# tdc : tdc
# mwc : mwc
# et : et
# langgeng : langgeng
# pf : pf
# bue : bue
# pfq : pfq
# cv : cv
# hf : hf
# pfuc : pfuc
# pfwjcd : pfwjcd
# hq : hq
# pfp : pfp
# pfm : pfm
# pfde : pfde
# pfnt : pfnt
# bfy : bfy
# pfr : pfr
# lw : lw
# dcv : dcv
# pfj : pfj
# csz : csz
# jq : jq
# pftvl : pftvl
# pfeaxm : pfeaxm
# pftke : pftke
# pftd : pftd
# pflb : pflb
# pfwgj : pfwgj
# pfbcfky : pfbcfky
# ep : ep
# pfg : pfg
# st : st
# rb : rb
# pfh : pfh
# muter : muter
# beli : beli
# bolpoin : bolpoin
# warung : warung
# zubaedah : zubaedah
# lupa : lupa
# membeli : beli
# gelas : gelas
# parsel : parsel
# tuker : tuker
# poin : poin
# berfaedah : faedah
# iphone : iphone
# belas : belas
# telkomsel : telkomsel
# yuk : yuk
# guys : guys
# buruan : buru
# kawan : kawan
# gall : gall
# djawas : djawas
# raffi : raffi
# ardaya : ardaya
# jumat : jumat
# jam : jam
# fjleu : fjleu
# pergi : pergi
# pasar : pasar
# buah : buah
# bahagiain : bahagiain
# ortu : ortu
# bawain : bawain
# berangkat : berangkat
# umroh : umroh
# lsh : lsh
# makan : makan
# mie : mie
# bihun : bihun
# pakai : pakai
# sambal : sambal
# terasi : terasi
# nendang : nendang
# terjungkal : jungkal
# esok : esok
# sukses : sukses
# belajar : ajar
# puisi : puisi
# menang : menang
# lomba : lomba
# nasional : nasional
# pff : pff
# hiburan : hibur
# termanis : man
# kuterima : terima
# disurprise : disurprise
# ultah : ultah
# pulang : pulang
# rumah : rumah
# kantor : kantor
# ac : ac
# selamat : selamat
# jumpa : jumpa
# penuh : penuh
# makna : makna
# semester : semester
# predikat : predikat
# zf : zf
# ulang : ulang
# kue : kue
# bugis : bugis
# terbungkus : bungkus
# daun : daun
# balutan : balut
# kismis : kismis
# berbahasa : bahasa
# inggris : inggris
# kemarin : kemarin
# mudah : mudah
# mudahan : mudah
# amin : amin
# gimana : gimana
# respons : respons
# mozart : mozart
# nokia : nokia
# tune : tune
# tanggapan : tanggap
# nikia : nikia
# ringtone : ringtone
# suara : suara
# mantan : mantan
# tone : tone
# tun : tun
# soni : soni
# eriksen : eriksen
# espionage : espionage
# melegenda : legenda
# terkenang : kenang
# aplikasi : aplikasi
# dibuka : buka
# tiket : tiket
# kuota : kuota
# habis : habis
# lsg : lsg
# bulanan : bulan
# terima : terima
# kasih : kasih
# alm : alm
# ibuku : ibu
# sony : sony
# tambak : tambak
# meduka : meduka
# ayu : ayu
# rungkut : rungkut
# surabaya : surabaya
# sinyal : sinyal
# melulu : melulu
# full : full
# bar : bar
# kartu : kartu
# haloku : halo
# jarang : jarang
# pakek : pakek
# bayar : bayar
# amal : amal
# bumn : bumn
# ericsson : ericsson
# blom : blom
# kak : kak
# link : link
# sms : sms
# buka : buka
# tpi : tpi
# aplikasinya : aplikasi
# mash : mash
# belom : bom
# emg : emg
# beneran : beneran
# dapet : dapet
# cair : cair
# cuman : cuman
# prank : prank
# sampek : sampek
# hadiahnya : hadiah
# alhamdulillah : alhamdulillah
# data : data
# tbl : tbl
# tungguin : tungguin
# banget : banget
# lhohhhh : lhohhhh
# dapetin : dapetin
# pulsa : pulsa
# nyaa : nyaa
# kpnucd : kpnucd
# tag : tag
# karyawannya : karyawannya
# blm : blm
# dpt : dpt
# pan : pan
# makasi : makas
# mimin : mimin
# live : live
# desember : desember
# dikasih : kasih
# disuruh : suruh
# langsung : langsung
# capture : capture
# pengumuman : umum
# pemenang : menang
# klaim : klaim
# respon : respon
# bro : bro
# saputra : saputra
# direspon : direspon
# ato : ato
# tukar : tukar
# points : points
# semangat : semangat
# josss : josss
# bcn : bcn
# make : make
# jaman : jaman
# hadian : hadian
# terimakasih : terimakasih
# pulsanya : pulsa
# garing : garing
# ampunn : ampunn
# dahhh : dahhh
# parah : parah
# krinj : krinj
# benerin : benerin
# gausah : gausah
# ngelawak : ngelawak
# kem : kem
# robot : robot
# hasilnya : hasil
# ancur : ancur
# komplain : komplain
# via : via
# apapaun : apapaun
# perubahan : ubah
# isi : isi
# paketan : paket
# ngga : ngga
# masuk : masuk
# heran : heran
# pas : pas
# malam : malam
# lemah : lemah
# kejar : kejar
# shopee : shopee
# terganggu : ganggu
# lucu : lucu
# mending : mending
# urusin : urusin
# dipake : dipake
# orang : orang
# temannya : teman
# tuyul : tuyul
# mba : mba
# yul : yul
# kentung : kentung
# klu : klu
# signal : signal
# bagus : bagus
# namanya : nama
# ngadat : ngadat
# telkomcil : telkomcil
# sumatera : sumatera
# sltan : sltan
# dri : dri
# hngga : hngga
# skrg : skrg
# main : main
# game : game
# ngelag : ngelag
# pkai : pkai
# telkomsl : telkomsl
# sayah : sayah
# read : read
# kayanya : kaya
# tlong : tlong
# cek : cek
# makasih : makasih
# besok : besok
# natal : natal
# pagi : pagi
# dilancarkan : lancar
# gnya : gnya
# kota : kota
# duri : duri
# riau : riau
# mohon : mohon
# fd : fd
# qb : qb
# dm : dm
# wk : wk
# kenyamanan : nyaman
# nonton : nonton
# mengisi : isi
# baterai : baterai
# cemilan : cemilan
# ricky : ricky
# ikutan : ikut
# kuis : kuis
# silakan : sila
# kakak : kakak
# infokan : info
# kolom : kolom
# komentar : komentar
# postingan : postingan
# feed : feed
# syarat : syarat
# ketentuan : tentu
# info : info
# lengkap : lengkap
# aimee : aimee
# hello : hello
# kode : kode
# unik : unik
# fdg : fdg
# chz : chz
# bismillah : bismillah
# update : update
# gadget : gadget
# gasss : gasss
# ndap : ndap
# fdds : fdds
# giveaway : giveaway
# diterima : terima
# tanggal : tanggal
# eq : eq
# persiapan : siap
# nge : nge
# charge : charge
# sampe : sampe
# aktifkan : aktif
# paket : paket
# internet : internet
# combo : combo
# sakti : sakti
# camilan : camil
# asik : asik
# pfc : pfc
# konser : konser
# donk : donk
# trus : trus
# comment : comment
# terpaksa : paksa
# chat : chat
# admin : admin
# bukakan : buka
# temen : temen
# dulur : dulur
# bareng : bareng
# pool : pool
# party : party
# rame : rame
# asyek : asyek
# kp : kp
# ydal : ydal
# wuhs : wuhs
# vduw : vduw
# ip : ip
# pffrp : pffrp
# app : app
# mytelkomsel : mytelkomsel
# tolong : tolong
# kasi : kasi
# solusinya : solusi
# misro : misro
# ampe : ampe
# blank : blank
# putih : putih
# samsung : samsung
# mahaaaaaaal : mahaaaaaaal
# msh : msh
# layar : layar
# tunggu : tunggu
# perbaikan : baik
# bugnya : bugnya
# membutuhkan : butuh
# jokes : jokes
# bapack : bapack
# wadul : wadul
# minggu : minggu
# telkomsen : telkomsen
# tukang : tukang
# ngeprank : ngeprank
# nggak : nggak
# pusing : pusing
# harga : harga
# daerahku : daerah
# bener : bener
# siang : siang
# btw : btw
# daerah : daerah
# desa : desa
# dolago : dolago
# padang : padang
# kec : kec
# parigi : parigi
# selatan : selatan
# kab : kab
# moutong : moutong
# prop : prop
# sulawesi : sulawesi
# barusan : barusan
# gb : gb
# bututttt : bututttt
# tidakk : tidakk
# unlimited : unlimited
# combro : combro
# dibatesin : dibatesin
# enak : enak
# batas : batas
# rizki : rizki
# aminnn : aminnn
# iya : iya
# gima : gima
# udah : udah
# pengentau : pengentau
# kaga : kaga
# evek : evek
# perna : perna
# bismillahirohmanirohim : bismillahirohmanirohim
# aasshhiiaapppp : aasshhiiaapppp
# ameer : ameer
# undian : undi
# hepi : hepi
# nongol : nongol
# nomer : nomer
# moga : moga
# dapatkan : dapat
# mencuri : curi
# celengan : celengan
# spp : spp
# adik : adik
# pengguna : guna
# setia : setia
# kualitas : kualitas
# pelanggan : langgan
# ngak : ngak
# sinyalnya : sinyal
# emosi : emosi
# ngeklaim : ngeklaim
# {'done': 'done', 'semoga': 'moga', 'kali': 'kali', 'beruntung': 'untung', 'aamiin': 'aamiin', '': '', 'minnn': 'minnn', 'wish': 'wish', 'luck': 'luck', 'min': 'min', 'rezekinya': 'rezeki', 'carax': 'carax', 'gmna': 'gmna', 'fdl': 'fdl', 'bakar': 'bakar', 'sosis': 'sosis', 'diatas': 'atas', 'tungku': 'tungku', 'tumpah': 'tumpah', 'taukah': 'tau', 'harapanku': 'harap', 'raih': 'raih', 'hadiah': 'hadiah', 'tdc': 'tdc', 'mwc': 'mwc', 'et': 'et', 'langgeng': 'langgeng', 'pf': 'pf', 'bue': 'bue', 'pfq': 'pfq', 'cv': 'cv', 'hf': 'hf', 'pfuc': 'pfuc', 'pfwjcd': 'pfwjcd', 'hq': 'hq', 'pfp': 'pfp', 'pfm': 'pfm', 'pfde': 'pfde', 'pfnt': 'pfnt', 'bfy': 'bfy', 'pfr': 'pfr', 'lw': 'lw', 'dcv': 'dcv', 'pfj': 'pfj', 'csz': 'csz', 'jq': 'jq', 'pftvl': 'pftvl', 'pfeaxm': 'pfeaxm', 'pftke': 'pftke', 'pftd': 'pftd', 'pflb': 'pflb', 'pfwgj': 'pfwgj', 'pfbcfky': 'pfbcfky', 'ep': 'ep', 'pfg': 'pfg', 'st': 'st', 'rb': 'rb', 'pfh': 'pfh', 'muter': 'muter', 'beli': 'beli', 'bolpoin': 'bolpoin', 'warung': 'warung', 'zubaedah': 'zubaedah', 'lupa': 'lupa', 'membeli': 'beli', 'gelas': 'gelas', 'parsel': 'parsel', 'tuker': 'tuker', 'poin': 'poin', 'berfaedah': 'faedah', 'iphone': 'iphone', 'belas': 'belas', 'telkomsel': 'telkomsel', 'yuk': 'yuk', 'guys': 'guys', 'buruan': 'buru', 'kawan': 'kawan', 'gall': 'gall', 'djawas': 'djawas', 'raffi': 'raffi', 'ardaya': 'ardaya', 'jumat': 'jumat', 'jam': 'jam', 'fjleu': 'fjleu', 'pergi': 'pergi', 'pasar': 'pasar', 'buah': 'buah', 'bahagiain': 'bahagiain', 'ortu': 'ortu', 'bawain': 'bawain', 'berangkat': 'berangkat', 'umroh': 'umroh', 'lsh': 'lsh', 'makan': 'makan', 'mie': 'mie', 'bihun': 'bihun', 'pakai': 'pakai', 'sambal': 'sambal', 'terasi': 'terasi', 'nendang': 'nendang', 'terjungkal': 'jungkal', 'esok': 'esok', 'sukses': 'sukses', 'belajar': 'ajar', 'puisi': 'puisi', 'menang': 'menang', 'lomba': 'lomba', 'nasional': 'nasional', 'pff': 'pff', 'hiburan': 'hibur', 'termanis': 'man', 'kuterima': 'terima', 'disurprise': 'disurprise', 'ultah': 'ultah', 'pulang': 'pulang', 'rumah': 'rumah', 'kantor': 'kantor', 'ac': 'ac', 'selamat': 'selamat', 'jumpa': 'jumpa', 'penuh': 'penuh', 'makna': 'makna', 'semester': 'semester', 'predikat': 'predikat', 'zf': 'zf', 'ulang': 'ulang', 'kue': 'kue', 'bugis': 'bugis', 'terbungkus': 'bungkus', 'daun': 'daun', 'balutan': 'balut', 'kismis': 'kismis', 'berbahasa': 'bahasa', 'inggris': 'inggris', 'kemarin': 'kemarin', 'mudah': 'mudah', 'mudahan': 'mudah', 'amin': 'amin', 'gimana': 'gimana', 'respons': 'respons', 'mozart': 'mozart', 'nokia': 'nokia', 'tune': 'tune', 'tanggapan': 'tanggap', 'nikia': 'nikia', 'ringtone': 'ringtone', 'suara': 'suara', 'mantan': 'mantan', 'tone': 'tone', 'tun': 'tun', 'soni': 'soni', 'eriksen': 'eriksen', 'espionage': 'espionage', 'melegenda': 'legenda', 'terkenang': 'kenang', 'aplikasi': 'aplikasi', 'dibuka': 'buka', 'tiket': 'tiket', 'kuota': 'kuota', 'habis': 'habis', 'lsg': 'lsg', 'bulanan': 'bulan', 'terima': 'terima', 'kasih': 'kasih', 'alm': 'alm', 'ibuku': 'ibu', 'sony': 'sony', 'tambak': 'tambak', 'meduka': 'meduka', 'ayu': 'ayu', 'rungkut': 'rungkut', 'surabaya': 'surabaya', 'sinyal': 'sinyal', 'melulu': 'melulu', 'full': 'full', 'bar': 'bar', 'kartu': 'kartu', 'haloku': 'halo', 'jarang': 'jarang', 'pakek': 'pakek', 'bayar': 'bayar', 'amal': 'amal', 'bumn': 'bumn', 'ericsson': 'ericsson', 'blom': 'blom', 'kak': 'kak', 'link': 'link', 'sms': 'sms', 'buka': 'buka', 'tpi': 'tpi', 'aplikasinya': 'aplikasi', 'mash': 'mash', 'belom': 'bom', 'emg': 'emg', 'beneran': 'beneran', 'dapet': 'dapet', 'cair': 'cair', 'cuman': 'cuman', 'prank': 'prank', 'sampek': 'sampek', 'hadiahnya': 'hadiah', 'alhamdulillah': 'alhamdulillah', 'data': 'data', 'tbl': 'tbl', 'tungguin': 'tungguin', 'banget': 'banget', 'lhohhhh': 'lhohhhh', 'dapetin': 'dapetin', 'pulsa': 'pulsa', 'nyaa': 'nyaa', 'kpnucd': 'kpnucd', 'tag': 'tag', 'karyawannya': 'karyawannya', 'blm': 'blm', 'dpt': 'dpt', 'pan': 'pan', 'makasi': 'makas', 'mimin': 'mimin', 'live': 'live', 'desember': 'desember', 'dikasi ...
# ------------------------
# Pandas Apply:   0%|          | 0/135 [00:00<?, ?it/s]
#                                                   text  \
# 3                                                 done
# 4                                                 done
# 5    sudah, semoga kali ini beruntung aamiin @telko...
# 6                                 done #serunyasenyawa
# 7                                      #serunyasenyawa
# ..                                                 ...
# 155  pengguna setia telkomsel , memang paling kuali...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                    ga pernah dapet apa2 dari dulu.
# 159  min dm ku untuk ngeklaim hadiah pulsa kok gak ...
#
#                                          cleaning_text  \
# 3                                                 done
# 4                                                 done
# 5               sudah semoga kali ini beruntung aamiin
# 6                                                 done
# 7
# ..                                                 ...
# 155  pengguna setia telkomsel memang paling kualita...
# 156  aku pelanggan setia telkomsel ngak pernah dpt ...
# 157                              sinyalnya bikin emosi
# 158                       pernah dapet apa  dari dulu
# 159  min untuk ngeklaim hadiah pulsa kok gak diliha...
#
#                                             tokenisasi  \
# 3                                               [done]
# 4                                               [done]
# 5        [sudah, semoga, kali, ini, beruntung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155  [pengguna, setia, telkomsel, memang, paling, k...
# 156  [aku, pelanggan, setia, telkomsel, ngak, perna...
# 157                          [sinyalnya, bikin, emosi]
# 158               [, pernah, dapet, apa, dari, dulu, ]
# 159  [min, untuk, ngeklaim, hadiah, pulsa, kok, gak...
#
#                                               stopword  \
# 3                                               [done]
# 4                                               [done]
# 5                    [semoga, kali, beruntung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155             [pengguna, setia, telkomsel, kualitas]
# 156  [pelanggan, setia, telkomsel, ngak, dpt, hadia...
# 157                                 [sinyalnya, emosi]
# 158                                        [, dapet, ]
# 159                   [min, ngeklaim, hadiah, pulsa, ]
#
#                                               stemming
# 3                                               [done]
# 4                                               [done]
# 5                         [moga, kali, untung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155                 [guna, setia, telkomsel, kualitas]
# 156  [langgan, setia, telkomsel, ngak, dpt, hadiah,...
# 157                                    [sinyal, emosi]
# 158                                        [, dapet, ]
# 159                   [min, ngeklaim, hadiah, pulsa, ]
#
# [135 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 3                                               [done]
# 4                                               [done]
# 5                         [moga, kali, untung, aamiin]
# 6                                               [done]
# 7                                                   []
# ..                                                 ...
# 155                 [guna, setia, telkomsel, kualitas]
# 156  [langgan, setia, telkomsel, ngak, dpt, hadiah,...
# 157                                    [sinyal, emosi]
# 158                                        [, dapet, ]
# 159                   [min, ngeklaim, hadiah, pulsa, ]
#
# [135 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_12.xlsx')
