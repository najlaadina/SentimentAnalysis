# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                               PERBAIKI SINYALNYA WOI
# 1                                     Tetap Semangattt
# 2    sinyal kuota unlimitedMAX perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedMAX perbaiki dulu
# 4    Kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  Kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         Cek DM min
# 185  Terima kasih TELKOMSEL memang beberapa hari in...
# 186  Urutan nama perangkat dari bawah: DCDU, EMUB, ...
# 187       Signal oh signal, mengapa kamu sulit kali...
#
# [188 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 18

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                               PERBAIKI SINYALNYA WOI
# 1                                     Tetap Semangattt
# 2    sinyal kuota unlimitedMAX perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedMAX perbaiki dulu
# 4    Kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  Kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         Cek DM min
# 185  Terima kasih TELKOMSEL memang beberapa hari in...
# 186  Urutan nama perangkat dari bawah: DCDU, EMUB, ...
# 187       Signal oh signal, mengapa kamu sulit kali...
#
# [161 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         cek dm min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah: dcdu, emub, ...
# 187       signal oh signal, mengapa kamu sulit kali...
#
# [161 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         cek dm min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah: dcdu, emub, ...
# 187       signal oh signal, mengapa kamu sulit kali...
#
#                                          cleaning_text
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu sinyal...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal kamu redikan min hape saya sudah ...
# ..                                                 ...
# 183  kenapa daerah aceh tamiang sinya pada saat mai...
# 184                                            cek min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah dcdu emub bbu...
# 187             signal signal mengapa kamu sulit kali
#
# [161 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         cek dm min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah: dcdu, emub, ...
# 187       signal oh signal, mengapa kamu sulit kali...
#
#                                          cleaning_text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu sinyal...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal kamu redikan min hape saya sudah ...
# ..                                                 ...
# 183  kenapa daerah aceh tamiang sinya pada saat mai...
# 184                                            cek min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah dcdu emub bbu...
# 187             signal signal mengapa kamu sulit kali
#
#                                             tokenisasi
# 0                           [perbaiki, sinyalnya, woi]
# 1                                  [tetap, semangattt]
# 2    [sinyal, kuota, unlimitedmax, perbaiki, dulu, ...
# 3        [sinyal, kuota, unlimitedmax, perbaiki, dulu]
# 4    [kapan, sinyal, kamu, redikan, min, hape, saya...
# ..                                                 ...
# 183  [kenapa, daerah, aceh, tamiang, sinya, pada, s...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, memang, beberapa, h...
# 186  [urutan, nama, perangkat, dari, bawah, dcdu, e...
# 187     [signal, signal, mengapa, kamu, sulit, kali, ]
#
# [161 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         cek dm min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah: dcdu, emub, ...
# 187       signal oh signal, mengapa kamu sulit kali...
#
#                                          cleaning_text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu sinyal...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal kamu redikan min hape saya sudah ...
# ..                                                 ...
# 183  kenapa daerah aceh tamiang sinya pada saat mai...
# 184                                            cek min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah dcdu emub bbu...
# 187             signal signal mengapa kamu sulit kali
#
#                                             tokenisasi  \
# 0                           [perbaiki, sinyalnya, woi]
# 1                                  [tetap, semangattt]
# 2    [sinyal, kuota, unlimitedmax, perbaiki, dulu, ...
# 3        [sinyal, kuota, unlimitedmax, perbaiki, dulu]
# 4    [kapan, sinyal, kamu, redikan, min, hape, saya...
# ..                                                 ...
# 183  [kenapa, daerah, aceh, tamiang, sinya, pada, s...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, memang, beberapa, h...
# 186  [urutan, nama, perangkat, dari, bawah, dcdu, e...
# 187     [signal, signal, mengapa, kamu, sulit, kali, ]
#
#                                               stopword
# 0                           [perbaiki, sinyalnya, woi]
# 1                                         [semangattt]
# 2    [sinyal, kuota, unlimitedmax, perbaiki, sinyal...
# 3              [sinyal, kuota, unlimitedmax, perbaiki]
# 4    [sinyal, redikan, min, hape, januari, sinyal, ...
# ..                                                 ...
# 183  [daerah, aceh, tamiang, sinya, main, game, dro...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, membaik, terima, ka...
# 186  [urutan, nama, perangkat, dcdu, emub, bbu, dcd...
# 187                    [signal, signal, sulit, kali, ]
#
# [161 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 561
# ------------------------
# perbaiki : baik
# sinyalnya : sinyal
# woi : woi
# semangattt : semangattt
# sinyal : sinyal
# kuota : kuota
# unlimitedmax : unlimitedmax
# parah : parah
# lemotnya : lot
# redikan : redik
# min : min
# hape : hape
# januari : januari
# uda : uda
# uji : uji
# coba : coba
# jakarta : jakarta
#  :
# telkomsel : telkomsel
# maju : maju
# drop : drop
# banget : banget
# oooiii : oooiii
# cek : cek
# percaya : percaya
# best : best
# rusak : rusak
# kmren : kmren
# smw : smw
# sosmed : sosmed
# inbox : inbox
# dibalas : balas
# sinyall : sinyall
# bobrok : bobrok
# kak : kak
# promo : promo
# ngga : ngga
# mudah : mudah
# kedepan : depan
# minggu : minggu
# superdeal : superdeal
# salah : salah
# alesan : alesan
# setia : setia
# provider : provider
# untung : untung
# jumat : jumat
# berkah : berkah
# namanya : nama
# udh : udh
# beli : beli
# paketan : paket
# bener : bener
# dipake : dipake
# disemua : semua
# sepuasnya : puas
# mauuuuuuuuuu : mauuuuuuuuuu
# surprise : surprise
# deal : deal
# emg : emg
# kah : kah
# msh : msh
# bnyk : bnyk
# skrg : skrg
# ribu : ribu
# deh : deh
# gimana : gimana
# paket : paket
# gada : gada
# mantap : mantap
# gua : gua
# sekian : sekian
# surpise : surpise
# liat : liat
# line : line
# official : official
# account : account
# tsel : tsel
# giliran : gilir
# masukan : masuk
# customer : customer
# dikasih : kasih
# pilihan : pilih
# lbh : lbh
# tergantung : gantung
# pemakaian : pakai
# trus : trus
# sesuai : sesuai
# dpt : dpt
# doang : doang
# rb : rb
# siang : siang
# stay : stay
# tune : tune
# batal : batal
# wajar : wajar
# artis : artis
# acara : acara
# hadiah : hadiah
# netflix : netflix
# film : film
# apapaun : apapaun
# saksikan : saksi
# semi : semi
# final : final
# ngilang : ngilang
# nonton : nonton
# diinvite : diinvite
# jwb : jwb
# cerdas : cerdas
# cermatnya : cermat
# jga : jga
# jringan : jringan
# skrng : skrng
# merahmerahan : merahmerahan
# keluhan : keluh
# unlimited : unlimited
# batasi : batas
# butuh : butuh
# ganti : ganti
# kartu : kartu
# bagus : bagus
# rumah : rumah
# lolos : lolos
# spill : spill
# sya : sya
# udah : udah
# seandai : anda
# gb : gb
# hbis : hbis
# seblm : seblm
# aktif : aktif
# internetny : internetny
# jaln : jaln
# sinyalmu : sinyal
# merah : merah
# merona : rona
# ngegame : ngegame
# dealnya : dealnya
# huhu : huhu
# semangat : semangat
# dianggep : dianggep
# suruh : suruh
# respon : respon
# oteweeee : oteweeee
# isi : isi
# ulang : ulang
# pulsa : pulsa
# pliss : pliss
# admin : admin
# syusahhhhh : syusahhhhh
# syekalee : syekalee
# jam : jam
# sampe : sampe
# speednya : speednya
# mbps : mbps
# baca : baca
# sihhhhhh : sihhhhhh
# internet : internet
# whatsapp : whatsapp
# menarik : tarik
# combo : combo
# omg : omg
# seharga : harga
# rp : rp
# ketengan : keteng
# bulanan : bulan
# tiktok : tiktok
# youtube : youtube
# kategori : kategori
# habis : habis
# masuk : masuk
# selamat : selamat
# lokal : lokal
# menit : menit
# sms : sms
# disney : disney
# hotstar : hotstar
# berlaku : laku
# tgl : tgl
# pkl : pkl
# wib : wib
# status : status
# berhenti : henti
# berlangganan : langgan
# apps : apps
# hub : hub
# info : info
# kesel : kesel
# berharap : harap
# dapet : dapet
# dapetnya : dapetnya
# ituuuuuu : ituuuuuu
# rugi : rugi
# guaa : guaa
# jigsaw : jigsaw
# hunger : hunger
# games : games
# stabil : stabil
# berkesan : kesan
# ikutan : ikut
# giveaway : giveaway
# semoga : moga
# menang : menang
# app : app
# mockingjay : mockingjay
# saw : saw
# twilight : twilight
# donk : donk
# the : the
# hidup : hidup
# tolong : tolong
# sakti : sakti
# fup : fup
# bonus : bonus
# motong : motong
# utama : utama
# kacau : kacau
# gabisa : gabisa
# astaga : astaga
# minnn : minnn
# menimbulkan : timbul
# kesan : kesan
# mendalam : dalam
# twihards : twihards
# cinna : cinna
# cressida : cressida
# karakter : karakter
# favoritkooooo : favoritkooooo
# simpati : simpati
# kena : kena
# batas : batas
# hadehhh : hadehhh
# ampasss : ampasss
# gadirespon : gadirespon
# lemottttt : lemottttt
# mobile : mobile
# legend : legend
# adain : adain
# bonusan : bonus
# skin : skin
# free : free
# fire : fire
# pubg : pubg
# muluu : muluu
# pket : pket
# pke : pke
# sekalinya : sekali
# tetep : tetep
# nyedot : nyedot
# utana : utana
# gamemax : gamemax
# sentuh : sentuh
# acan : acan
# update : update
# ttp : ttp
# nyentuh : nyentuh
# unlimitedny : unlimitedny
# dibatasin : dibatasin
# gitu : gitu
# mending : mending
# kuning : kuning
# murah : murah
# iya : iya
# seru : seru
# main : main
# game : game
# pakai : pakai
# doakan : doa
# pemenang : menang
# iphone : iphone
# nungguin : nungguin
# twitter : twitter
# kemarin : kemarin
# dibales : dibales
# infonya : info
# ngab : ngab
# kembalikan : kembali
# pup : pup
# iyn : iyn
# minnnnn : minnnnn
# jangann : jangann
# dibatesinn : dibatesinn
# aplikasinya : aplikasi
# minn : minn
# khususu : khususu
# honkai : honkai
# impact : impact
# psbb : psbb
# diperpanjang : panjang
# senjata : senjata
# kekerasan : keras
# fisik : fisik
# krisis : krisis
# ekonomi : ekonomi
# for : for
# all : all
# people : people
# country : country
# god : god
# save : save
# fourth : fourth
# king : king
# bambang : bambang
# sumarsono : sumarsono
# nilawati : nilawati
# berry : berry
# wilambang : wilambang
# harwika : harwika
# rindayu : rindayu
# resti : resti
# wandari : wandari
# address : address
# bukit : bukit
# cengkeh : cengkeh
# jalan : jalan
# tugu : tugu
# cimanggis : cimanggis
# depok : depok
# indonesia : indonesia
# come : come
# commander : commander
# bin : bin
# tni : tni
# polri : polri
# brimob : brimob
# paspampres : paspampres
# sis : sis
# gchq : gchq
# britisharmy : britisharmy
# fbi : fbi
# cia : cia
# secret : secret
# service : service
# army : army
# multiply : multiply
# money : money
# heritage : heritage
# second : second
# keluarga : keluarga
# raja : raja
# dilindungi : lindung
# ketat : ketat
# dikawal : kawal
# dijaga : jaga
# dipagar : pagar
# hangus : hangus
# aktifkan : aktif
# asli : asli
# ceet : ceet
# bet : bet
# jaringannya : jaring
# officialstore : officialstore
# gini : gin
# sib : sib
# elegan : elegan
# tulisan : tulis
# kek : kek
# eropa : eropa
# ajang : ajang
# cari : cari
# follower : follower
# penanganan : tangan
# lambat : lambat
# pindah : pindah
# bangkek : bangkek
# mohon : mohon
# maaf : maaf
# kasr : kasr
# emng : emng
# kenyataannya : nyata
# geulis : geulis
# kitu : kitu
# teteh : teteh
# yok : yok
# fokus : fokus
# liga : liga
# bobotoh : bobotoh
# mendoakan : doa
# musib : musib
# yahahah : yahahah
# kalah : kalah
# wkwkkw : wkwkkw
# benerin : benerin
# pengaduan : adu
# slow : slow
# jijik : jijik
# knp : knp
# nomor : nomor
# beda : beda
# pdhl : pdhl
# kartunya : kartu
# habi : habi
# lumy : lumy
# doain : doain
# kota : kota
# gue : gue
# juara : juara
# ncang : ncang
# ncing : ncing
# nyak : nyak
# babeh : babeh
# persija : persija
# day : day
# firmansyah : firmansyah
# persib : persib
# biruu : biruu
# jersey : jersey
# give : give
# away : away
# duh : duh
# gestur : gestur
# gerakannya : gera
# pengen : ken
# meluk : luk
# hahhaa : hahhaa
# elu : elu
# gmna : gmna
# msk : msk
# rutin : rutin
# gangguanx : gangguanx
# dibatasi : batas
# sedih : sedih
# telp : telp
# langsung : langsung
# ditawarin : ditawarin
# diubah : ubah
# hallo : hallo
# apik : apik
# tenan : tenan
# lawannn : lawannn
# nget : nget
# tambahan : tambah
# gokil : gokil
# pisan : pis
# euy : euy
# kenceng : kenceng
# asekk : asekk
# harga : harga
# terjangkau : jangkau
# always : always
# noted : noted
# wokwowkwokwow : wokwowkwokwow
# demen : demen
# kasih : kasih
# penawaran : tawar
# super : super
# gas : gas
# gratis : gratis
# mangtap : mangtap
# ngak : ngak
# ilang : ilang
# lgi : lgi
# busuk : busuk
# done : done
# terimakasih : terimakasih
# menyediakan : sedia
# layanan : layan
# memadai : pada
# jasa : jasa
# convert : convert
# withdraw : withdraw
# jual : jual
# saldo : saldo
# paypal : paypal
# terpercaya : percaya
# transfer : transfer
# bank : bank
# wallet : wallet
# dana : dana
# ovo : ovo
# dunia : dunia
# balance : balance
# tersedia : sedia
# dollar : dollar
# pembayaran : bayar
# linkaja : linkaja
# gopay : gopay
# tunggu : tunggu
# chat : chat
# signyalnya : signyalnya
# tolog : tolog
# dikampung : kampung
# bismillah : bismillah
# blm : blm
# data : data
# ios : ios
# robot : robot
# androit : androit
# ngasih : ngasih
# nanya : nanya
# taun : taun
# ijin : ijin
# kritik : kritik
# dlu : dlu
# datanya : data
# kualitas : kualitas
# menurun : turun
# androiders : androiders
# miin : miin
# ngelag : ngelag
# muluuuu : muluuuu
# android : android
# duly : duly
# promonya : promonya
# prank : prank
# biang : biang
# kerok : kerok
# macet : macet
# laku : laku
# jualan : jual
# tems : tems
# pilih : pilih
# daerah : daerah
# banda : banda
# aceh : aceh
# kaga : kaga
# wilayah : wilayah
# selatan : selatan
# ntt : ntt
# kec : kec
# amarasi : amarasi
# kab : kab
# kupang : kupang
# prop : prop
# jrg : jrg
# berfungsi : fungsi
# sulit : sulit
# berkomunikasi : komunikasi
# dkt : dkt
# pemancar : pancar
# perhatian : perhati
# bencana : bencana
# jngnkan : jngnkan
# sumatera : sumatera
# maksimal : maksimal
# bengkulu : bengkulu
# tamiang : tamiang
# sinya : sinya
# penjelasannya : jelas
# terima : terima
# membaik : baik
# ksigapannya : ksigapannya
# grapari : grapari
# sangan : sangan
# berbaik : baik
# hati : hati
# membagi : bagi
# listrik : listrik
# charger : charger
# pemakai : pakai
# setiamu : setia
# urutan : urut
# nama : nama
# perangkat : perangkat
# dcdu : dcdu
# emub : emub
# bbu : bbu
# fan : fan
# signal : signal
# kali : kali
# {'perbaiki': 'baik', 'sinyalnya': 'sinyal', 'woi': 'woi', 'semangattt': 'semangattt', 'sinyal': 'sinyal', 'kuota': 'kuota', 'unlimitedmax': 'unlimitedmax', 'parah': 'parah', 'lemotnya': 'lot', 'redikan': 'redik', 'min': 'min', 'hape': 'hape', 'januari': 'januari', 'uda': 'uda', 'uji': 'uji', 'coba': 'coba', 'jakarta': 'jakarta', '': '', 'telkomsel': 'telkomsel', 'maju': 'maju', 'drop': 'drop', 'banget': 'banget', 'oooiii': 'oooiii', 'cek': 'cek', 'percaya': 'percaya', 'best': 'best', 'rusak': 'rusak', 'kmren': 'kmren', 'smw': 'smw', 'sosmed': 'sosmed', 'inbox': 'inbox', 'dibalas': 'balas', 'sinyall': 'sinyall', 'bobrok': 'bobrok', 'kak': 'kak', 'promo': 'promo', 'ngga': 'ngga', 'mudah': 'mudah', 'kedepan': 'depan', 'minggu': 'minggu', 'superdeal': 'superdeal', 'salah': 'salah', 'alesan': 'alesan', 'setia': 'setia', 'provider': 'provider', 'untung': 'untung', 'jumat': 'jumat', 'berkah': 'berkah', 'namanya': 'nama', 'udh': 'udh', 'beli': 'beli', 'paketan': 'paket', 'bener': 'bener', 'dipake': 'dipake', 'disemua': 'semua', 'sepuasnya': 'puas', 'mauuuuuuuuuu': 'mauuuuuuuuuu', 'surprise': 'surprise', 'deal': 'deal', 'emg': 'emg', 'kah': 'kah', 'msh': 'msh', 'bnyk': 'bnyk', 'skrg': 'skrg', 'ribu': 'ribu', 'deh': 'deh', 'gimana': 'gimana', 'paket': 'paket', 'gada': 'gada', 'mantap': 'mantap', 'gua': 'gua', 'sekian': 'sekian', 'surpise': 'surpise', 'liat': 'liat', 'line': 'line', 'official': 'official', 'account': 'account', 'tsel': 'tsel', 'giliran': 'gilir', 'masukan': 'masuk', 'customer': 'customer', 'dikasih': 'kasih', 'pilihan': 'pilih', 'lbh': 'lbh', 'tergantung': 'gantung', 'pemakaian': 'pakai', 'trus': 'trus', 'sesuai': 'sesuai', 'dpt': 'dpt', 'doang': 'doang', 'rb': 'rb', 'siang': 'siang', 'stay': 'stay', 'tune': 'tune', 'batal': 'batal', 'wajar': 'wajar', 'artis': 'artis', 'acara': 'acara', 'hadiah': 'hadiah', 'netflix': 'netflix', 'film': 'film', 'apapaun': 'apapaun', 'saksikan': 'saksi', 'semi': 'semi', 'final': 'final', 'ngilang': 'ngilang', 'nonton': 'nonton', 'diinvite': 'diinvite', 'jwb': 'jwb', 'cerdas': 'cerdas', 'cermatnya': 'cermat', 'jga': 'jga', 'jringan': 'jringan', 'skrng': 'skrng', 'merahmerahan': 'merahmerahan', 'keluhan': 'keluh', 'unlimited': 'unlimited', 'batasi': 'batas', 'butuh': 'butuh', 'ganti': 'ganti', 'kartu': 'kartu', 'bagus': 'bagus', 'rumah': 'rumah', 'lolos': 'lolos', 'spill': 'spill', 'sya': 'sya', 'udah': 'udah', 'seandai': 'anda', 'gb': 'gb', 'hbis': 'hbis', 'seblm': 'seblm', 'aktif': 'aktif', 'internetny': 'internetny', 'jaln': 'jaln', 'sinyalmu': 'sinyal', 'merah': 'merah', 'merona': 'rona', 'ngegame': 'ngegame', 'dealnya': 'dealnya', 'huhu': 'huhu', 'semangat': 'semangat', 'dianggep': 'dianggep', 'suruh': 'suruh', 'respon': 'respon', 'oteweeee': 'oteweeee', 'isi': 'isi', 'ulang': 'ulang', 'pulsa': 'pulsa', 'pliss': 'pliss', 'admin': 'admin', 'syusahhhhh': 'syusahhhhh', 'syekalee': 'syekalee', 'jam': 'jam', 'sampe': 'sampe', 'speednya': 'speednya', 'mbps': 'mbps', 'baca': 'baca', 'sihhhhhh': 'sihhhhhh', 'internet': 'internet', 'whatsapp': 'whatsapp', 'menarik': 'tarik', 'combo': 'combo', 'omg': 'omg', 'seharga': 'harga', 'rp': 'rp', 'ketengan': 'keteng', 'bulanan': 'bulan', 'tiktok': 'tiktok', 'youtube': 'youtube', 'kategori': 'kategori', 'habis': 'habis', 'masuk': 'masuk', 'selamat': 'selamat', 'lokal': 'lokal', 'menit': 'menit', 'sms': 'sms', 'disney': 'disney', 'hotstar': 'hotstar', 'berlaku': 'laku', 'tgl': 'tgl', 'pkl': 'pkl', 'wib': 'wib', 'status': 'status', 'berhenti': 'henti', 'berlangganan': 'langgan', 'apps': 'apps', 'hub': 'hub', 'info': 'info', 'kesel': 'kesel', 'berharap': 'harap', 'dapet': 'dapet', 'dapetnya': 'dapetnya', 'ituuuuuu': 'ituuuuuu', 'rugi': 'rugi', 'guaa': 'guaa', 'jigsaw': 'jigsaw', 'hunger': 'hunger', 'games': 'games', 'stabil': 'stabil', 'berkesan': 'kesan', 'ikutan': 'ikut', 'giveaway': 'giveaway', 'semoga': 'moga', 'menang': 'menang', 'app': 'app', 'mockingjay': 'mockingjay', 'saw': 'saw', 'twilight': 'twilight', 'donk': 'donk', 'the': 'the', 'hidup': 'hidup ...
# ------------------------
# Pandas Apply:   0%|          | 0/161 [00:00<?, ?it/s]
#                                                   text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu, sinya...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal 5g kamu redikan min...hape saya s...
# ..                                                 ...
# 183  kenapa di daerah aceh tamiang sinya pada saat ...
# 184                                         cek dm min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah: dcdu, emub, ...
# 187       signal oh signal, mengapa kamu sulit kali...
#
#                                          cleaning_text  \
# 0                               perbaiki sinyalnya woi
# 1                                     tetap semangattt
# 2    sinyal kuota unlimitedmax perbaiki dulu sinyal...
# 3              sinyal kuota unlimitedmax perbaiki dulu
# 4    kapan sinyal kamu redikan min hape saya sudah ...
# ..                                                 ...
# 183  kenapa daerah aceh tamiang sinya pada saat mai...
# 184                                            cek min
# 185  terima kasih telkomsel memang beberapa hari in...
# 186  urutan nama perangkat dari bawah dcdu emub bbu...
# 187             signal signal mengapa kamu sulit kali
#
#                                             tokenisasi  \
# 0                           [perbaiki, sinyalnya, woi]
# 1                                  [tetap, semangattt]
# 2    [sinyal, kuota, unlimitedmax, perbaiki, dulu, ...
# 3        [sinyal, kuota, unlimitedmax, perbaiki, dulu]
# 4    [kapan, sinyal, kamu, redikan, min, hape, saya...
# ..                                                 ...
# 183  [kenapa, daerah, aceh, tamiang, sinya, pada, s...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, memang, beberapa, h...
# 186  [urutan, nama, perangkat, dari, bawah, dcdu, e...
# 187     [signal, signal, mengapa, kamu, sulit, kali, ]
#
#                                               stopword  \
# 0                           [perbaiki, sinyalnya, woi]
# 1                                         [semangattt]
# 2    [sinyal, kuota, unlimitedmax, perbaiki, sinyal...
# 3              [sinyal, kuota, unlimitedmax, perbaiki]
# 4    [sinyal, redikan, min, hape, januari, sinyal, ...
# ..                                                 ...
# 183  [daerah, aceh, tamiang, sinya, main, game, dro...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, membaik, terima, ka...
# 186  [urutan, nama, perangkat, dcdu, emub, bbu, dcd...
# 187                    [signal, signal, sulit, kali, ]
#
#                                               stemming
# 0                                  [baik, sinyal, woi]
# 1                                         [semangattt]
# 2    [sinyal, kuota, unlimitedmax, baik, sinyal, pa...
# 3                  [sinyal, kuota, unlimitedmax, baik]
# 4    [sinyal, redik, min, hape, januari, sinyal, re...
# ..                                                 ...
# 183  [daerah, aceh, tamiang, sinya, main, game, dro...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, baik, terima, kasih...
# 186  [urut, nama, perangkat, dcdu, emub, bbu, dcdu,...
# 187                    [signal, signal, sulit, kali, ]
#
# [161 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                  [baik, sinyal, woi]
# 1                                         [semangattt]
# 2    [sinyal, kuota, unlimitedmax, baik, sinyal, pa...
# 3                  [sinyal, kuota, unlimitedmax, baik]
# 4    [sinyal, redik, min, hape, januari, sinyal, re...
# ..                                                 ...
# 183  [daerah, aceh, tamiang, sinya, main, game, dro...
# 184                                         [cek, min]
# 185  [terima, kasih, telkomsel, baik, terima, kasih...
# 186  [urut, nama, perangkat, dcdu, emub, bbu, dcdu,...
# 187                    [signal, signal, sulit, kali, ]
#
# [161 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_4.xlsx')
