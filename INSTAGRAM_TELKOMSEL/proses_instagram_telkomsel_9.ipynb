# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                  Keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     Min, sinyal lagi bermasalah kah?
# 2                                    Info yang menarik
# 3    Mendingan makan tumis kangkung dari pada makan...
# 4    Pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              Min bales DM.. thanks
# 217  Paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  Sinyal lu benerin ANJNGGG jangan lip service m...
#
# [221 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 26

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                  Keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     Min, sinyal lagi bermasalah kah?
# 2                                    Info yang menarik
# 3    Mendingan makan tumis kangkung dari pada makan...
# 4    Pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              Min bales DM.. thanks
# 217  Paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  Sinyal lu benerin ANJNGGG jangan lip service m...
#
# [174 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                  keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     min, sinyal lagi bermasalah kah?
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              min bales dm.. thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  sinyal lu benerin anjnggg jangan lip service m...
#
# [174 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                  keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     min, sinyal lagi bermasalah kah?
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              min bales dm.. thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  sinyal lu benerin anjnggg jangan lip service m...
#
#                                          cleaning_text
# 0                                               keren
# 1                      min sinyal lagi bermasalah kah
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya bisa internetan min masalah jasu...
# ..                                                 ...
# 216                                   min bales thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                             astaga
# 219
# 220  sinyal benerin anjnggg jangan lip service melu...
#
# [174 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                  keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     min, sinyal lagi bermasalah kah?
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              min bales dm.. thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  sinyal lu benerin anjnggg jangan lip service m...
#
#                                          cleaning_text  \
# 0                                               keren
# 1                      min sinyal lagi bermasalah kah
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya bisa internetan min masalah jasu...
# ..                                                 ...
# 216                                   min bales thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                             astaga
# 219
# 220  sinyal benerin anjnggg jangan lip service melu...
#
#                                             tokenisasi
# 0                                            [keren, ]
# 1               [min, sinyal, lagi, bermasalah, kah, ]
# 2                                [info, yang, menarik]
# 3    [mendingan, makan, tumis, kangkung, dari, pada...
# 4    [pantasan, saya, bisa, internetan, min, masala...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217  [paket, unlimited, sosmed, games, kok, gak, bi...
# 218                                           [astaga]
# 219                                               [, ]
# 220  [sinyal, benerin, anjnggg, jangan, lip, servic...
#
# [174 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                  keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     min, sinyal lagi bermasalah kah?
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              min bales dm.. thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  sinyal lu benerin anjnggg jangan lip service m...
#
#                                          cleaning_text  \
# 0                                               keren
# 1                      min sinyal lagi bermasalah kah
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya bisa internetan min masalah jasu...
# ..                                                 ...
# 216                                   min bales thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                             astaga
# 219
# 220  sinyal benerin anjnggg jangan lip service melu...
#
#                                             tokenisasi  \
# 0                                            [keren, ]
# 1               [min, sinyal, lagi, bermasalah, kah, ]
# 2                                [info, yang, menarik]
# 3    [mendingan, makan, tumis, kangkung, dari, pada...
# 4    [pantasan, saya, bisa, internetan, min, masala...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217  [paket, unlimited, sosmed, games, kok, gak, bi...
# 218                                           [astaga]
# 219                                               [, ]
# 220  [sinyal, benerin, anjnggg, jangan, lip, servic...
#
#                                               stopword
# 0                                            [keren, ]
# 1                     [min, sinyal, bermasalah, kah, ]
# 2                                      [info, menarik]
# 3    [mendingan, makan, tumis, kangkung, makan, piz...
# 4    [pantasan, internetan, min, jasuka, kabel, lau...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217    [paket, unlimited, sosmed, games, game, online]
# 218                                           [astaga]
# 219                                               [, ]
# 220   [sinyal, benerin, anjnggg, lip, service, melulu]
#
# [174 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 634
# ------------------------
# keren : keren
#  :
# min : min
# sinyal : sinyal
# bermasalah : masalah
# kah : kah
# info : info
# menarik : tarik
# mendingan : mending
# makan : makan
# tumis : tumis
# kangkung : kangkung
# pizza : pizza
# mimpi : mimpi
# pantasan : pantas
# internetan : internetan
# jasuka : jasuka
# kabel : kabel
# laut : laut
# internet : internet
# udah : udah
# masuk : masuk
# lancarnya : lancar
# mohon : mohon
# ditanggapi : tanggap
# telkomsel : telkomsel
# gabisa : gabisa
# kebuka : buka
# kesalahan : salah
# sistem : sistem
# kak : kak
# tolong : tolong
# cek : cek
# kpm : kpm
# zr : zr
# ditemenin : ditemenin
# nyari : nyari
# eceng : eceng
# gondok : gondok
# penelitian : teliti
# skripsi : skripsi
# rela : rela
# turun : turun
# kolam : kolam
# ngambil : ngambil
# diriku : diri
# mawar : mawar
# tulip : tulip
# jatuhcinta : jatuhcinta
# event : event
# disuruh : suruh
# komen : komen
# btw : btw
# postingan : postingan
# bnyk : bnyk
# koin : koin
# tukar : tukar
# lancar : lancar
# heng : heng
# kebutuhan : butuh
# jualan : jual
# online : online
# mata : mata
# pencarian : cari
# lcd : lcd
# pecah : pecah
# make : make
# halo : halo
# ancur : ancur
# setahun : tahun
# daerah : daerah
# skrg : skrg
# kualitas : kualitas
# bagus : bagus
# komplain : komplain
# nanya : nanya
# nggak : nggak
# stabil : stabil
# ganggu : ganggu
# banget : banget
# pas : pas
# ujian : uji
# selesai : selesai
# ngerjain : ngerjain
# kekoreksi : koreksi
# gara : gara
# sinyalnya : sinyal
# paket : paket
# bundling : bundling
# iphone : iphone
# gmn : gmn
# nyicil : nyicil
# grapari : grapari
# bandung : bandung
# dmn : dmn
# ajbyg : ajbyg
# buka : buka
# aplikasi : aplikasi
# gambarnya : gambar
# kuota : kuota
# deh : deh
# baca : baca
# wkwkwkkw : wkwkwkkw
# aseli : aseli
# tersendat : sendat
# nipu : nipu
# tanggung : tanggung
# boy : boy
# sampe : sampe
# tsel : tsel
# gua : gua
# wkwkwk : wkwkwk
# byu : byu
# iklan : iklan
# penipuan : tipu
# akun : akun
# bales : bales
# cirebon : cirebon
# leg : leg
# signal : signal
# ilang : ilang
# trus : trus
# push : push
# rankk : rankk
# udh : udh
# isi : isi
# mah : mah
# wifi : wifi
# indihomeeeee : indihomeeeee
# ngelag : ngelag
# jugaaaaaaaa : jugaaaaaaaa
# kesel : kesel
# emang : emang
# aktif : aktif
# jual : jual
# gmna : gmna
# bertahun : tahun
# gambar : gambar
# org : org
# ngga : ngga
# dibuka : buka
# aktifin : aktifin
# kartu : kartu
# angus : angus
# karna : karna
# jarang : jarang
# isii : isi
# plsa : plsa
# gue : gue
# error : error
# pagi : pagi
# system : system
# restart : restart
# mohom : mohom
# lgi : lgi
# promonya : promonya
# iya : iya
# temen : temen
# suka : suka
# curhat : curhat
# kadang : kadang
# males : males
# off : off
# mulu : mulu
# ngellag : ngellag
# cok : cok
# infonya : info
# kemarin : kemarin
# tuker : tuker
# poin : poin
# voucer : voucer
# toyota : toyota
# rush : rush
# dpet : dpet
# teman : teman
# workaholic : workaholic
# workholic : workholic
# rebahan : rebah
# kode : kode
# kpd : kpd
# ltv : ltv
# spasi : spasi
# cerita : cerita
# romantis : romantis
# prnh : prnh
# alami : alami
# tag : tag
# entertainment : entertainment
# menangin : menangin
# hadiah : hadiah
# periode : periode
# link : link
# diakses : akses
# hmm : hmm
# nge : nge
# duhh : duhh
# undi : undi
# hepi : hepi
# kapn : kapn
# umumin : umumin
# ndak : ndak
# tengotengok : tengotengok
# tersedia : sedia
# mngkin : mngkin
# kuotanya : kuota
# terbatas : batas
# gtu : gtu
# hapus : hapus
# iklannya : iklan
# maaf : maaf
# ambyar : ambyar
# gini : gin
# paketan : paket
# larangan : larang
# aswww : aswww
# menu : menu
# akses : akses
# silahkan : silah
# pilih : pilih
# parlan : parlan
# semogah : semogah
# sukses : sukses
# ditunggu : tunggu
# september : september
# knp : knp
# dibalas : balas
# kpr : kpr
# efpy : efpy
# fd : fd
# ah : ah
# hai : hai
# ricky : ricky
# the : the
# house : house
# kpz : kpz
# uang : uang
# tambahan : tambah
# sehari : hari
# semoga : moga
# bismillah : bismillah
# menangg : menangg
# lupa : lupa
# point : point
# fde : fde
# ajt : ajt
# tanggal : tanggal
# tua : tua
# penawaran : tawar
# saldo : saldo
# jajan : jajan
# beli : beli
# cilok : cilok
# heheheh : heheheh
# berharap : harap
# perbanyak : banyak
# penukaran : tukar
# nominal : nominal
# rajin : rajin
# edisi : edisi
# app : app
# patia : patia
# harap : harap
# gratisan : gratis
# ekstra : ekstra
# harga : harga
# promo : promo
# perbayak : bayak
# pket : pket
# giveawaya : giveawaya
# fdc : fdc
# eo : eo
# fdqufxl : fdqufxl
# tunggu : tunggu
# menukarkan : tukar
# termurah : murah
# fdvso : fdvso
# yaaa : yaaa
# termurahh : termurahh
# pulsa : pulsa
# potong : potong
# sisa : sisa
# kbnyakan : kbnyakan
# kau : kau
# urus : urus
# curi : curi
# orang : orang
# rusak : rusak
# hancur : hancur
# pindah : pindah
# yok : yok
# provider : provider
# taek : taek
# ribu : ribu
# masak : masak
# muter : muter
# lagu : lagu
# spotify : spotify
# detik : detik
# loading : loading
# patah : patah
# separah : parah
# wooiii : wooiii
# kompensasi : kompensasi
# jaringannya : jaring
# auto : auto
# wow : wow
# mudah : mudah
# han : han
# cepat : cepat
# tabanan : taban
# bali : bal
# langsung : langsung
# modemnya : modem
# butuh : butuh
# bicara : bicara
# veronika : veronika
# merusak : rusak
# hubungan : hubung
# dirubah : rubah
# otak : otak
# berjalan : jalan
# merugikan : rugi
# pribadi : pribadi
# ngomong : ngomong
# sedot : sedot
# ubah : ubah
# hak : hak
# izin : izin
# fdb : fdb
# qrm : qrm
# bkn : bkn
# kenceng : kenceng
# jaringanny : jaringanny
# mlh : mlh
# nyampaikan : nyampaikan
# keluhan : keluh
# jwb : jwb
# jga : jga
# boot : boot
# solusi : solusi
# ganti : ganti
# laen : laen
# reply : reply
# customer : customer
# jawabannya : jawab
# kaya : kaya
# brobot : brobot
# robot : robot
# karyawan : karyawan
# manusianya : manusia
# hati : hati
# smpe : smpe
# skrng : skrng
# streaming : streaming
# film : film
# buffering : buffering
# hadeh : hadeh
# doang : doang
# perpanjang : panjang
# kantor : kantor
# ngelus : ngelus
# dada : dada
# degghh : degghh
# kota : kota
# plis : plis
# telfonan : telfonan
# doi : doi
# menyambungkan : sambung
# atuhlah : atuhlah
# benerin : benerin
# jaringanx : jaringanx
# prabayar : prabayar
# semenjak : semenjak
# sms : sms
# tlp : tlp
# kepake : kepake
# datanya : data
# doangg : doangg
# perbaiki : baik
# data : data
# bisaa : bisaa
# turn : turn
# airplane : airplane
# mode : mode
# seluler : seluler
# apn : apn
# router : router
# gitu : gitu
# ulang : ulang
# smoga : smoga
# telkom : telkom
# memperbaiki : baik
# klw : klw
# nnti : nnti
# sbgai : sbgai
# istighfar : istighfar
# ngg : ngg
# slowmotion : slowmotion
# dibenerin : dibenerin
# please : please
# kasih : kasih
# akibat : akibat
# gangguaj : gangguaj
# telat : telat
# diputus : putus
# denda : denda
# balesin : balesin
# tinggal : tinggal
# template : template
# copy : copy
# paste : paste
# posting : posting
# teroooooos : teroooooos
# pelanggannya : langgan
# whatsapp : whatsapp
# empot : empot
# imagine : imagine
# tagihan : tagih
# dikit : dikit
# gausa : gausa
# ajaa : ajaa
# huhuhu : huhuhu
# ayo : ayo
# bisnet : bisnet
# dijamin : jamin
# kencang : kencang
# survey : survey
# membuktikan : bukti
# zoom : zoom
# pro : pro
# indihome : indihome
# orbit : orbit
# ngapa : ngapa
# dlu : dlu
# darah : darah
# jqngan : jqngan
# zoomnya : zoomnya
# normal : normal
# adain : adain
# kayak : kayak
# tetangga : tetangga
# sebelah : belah
# kirim : kirim
# gatau : gatau
# pengen : ken
# terserah : serah
# ndang : ndang
# file : file
# ringan : ringan
# jalan : jalan
# mintak : mintak
# allah : allah
# lemott : lemott
# telpon : telpon
# nerima : nerima
# main : main
# epep : epep
# mahal : mahal
# kek : kek
# taiii : taiii
# season : season
# woi : woi
# samatelkomsel : samatelkomsel
# murah : murah
# manaaaa : manaaaa
# woiii : woiii
# sinyallll : sinyallll
# kite : kite
# udin : udin
# byr : byr
# mehong : mehong
# capeee : capeee
# dheee : dheee
# vera : vera
# berhadapan : hadap
# menyelamatkan : selamat
# miko : miko
# yuuk : yuuk
# amd : amd
# ramona : ramona
# aprilinawulandr : aprilinawulandr
# srirah : srirah
# sandega : sandega
# dea : dea
# bee : bee
# irr : irr
# bani : bani
# adam : adam
# lathifah : lathifah
# aji : aji
# mukie : mukie
# dev : dev
# adityas : adityas
# khayla : khayla
# yuk : yuk
# ikutan : ikut
# giveaway : giveaway
# brata : brata
# ts : ts
# pengumuman : umum
# oktober : oktober
# nma : nma
# tercantum : cantum
# hadiahnya : hadiah
# anjj : anjj
# nuker : nuker
# mending : mending
# gampang : gampang
# ajj : ajj
# kali : kali
# ama : ama
# kgk : kgk
# kpwph : kpwph
# sejalan : jalan
# pisah : pisah
# terpilih : pilih
# aulia : aulia
# legend : legend
# nukerin : nukerin
# berdonasi : donasi
# menang : menang
# perwakilan : wakil
# indonesia : indonesia
# timur : timur
# wish : wish
# luck : luck
# terimakasih : terimakasih
# bagusin : bagusin
# tanggepi : tanggepi
# mls : mls
# nukar : nukar
# prnah : prnah
# dpat : dpat
# ditukar : tukar
# linkaja : linkaja
# capek : capek
# buang : buang
# salah : salah
# pantang : pantang
# menyerah : serah
# blm : blm
# beruntung : untung
# bsok : bsok
# rejekinya : rejekinya
# usaha : usaha
# rezeki : rezeki
# tertukar : tukar
# semangat : semangat
# poinnya : poin
# tukerin : tukerin
# barang : barang
# seru : seru
# dapet : dapet
# undian : undi
# mantap : mantap
# siip : siip
# jqrngn : jqrngn
# tlkomsel : tlkomsel
# ntr : ntr
# gnti : gnti
# gimana : gimana
# nonton : nonton
# redeem : redeem
# rugi : rugi
# donload : donload
# vidio : vidio
# kuncie : kuncie
# gmana : gmana
# reedem : reedem
# baby : baby
# koneksi : koneksi
# tertera : tera
# syukur : syukur
# dual : dual
# sim : sim
# backup : backup
# radeemnya : radeemnya
# mim : mim
# keong : keong
# lawak : lawak
# hijrah : hijrah
# maksudnya : maksud
# yeayy : yeayy
# cakeep : cakeep
# memuaskan : muas
# ngegame : ngegame
# putus : putus
# makasih : makasih
# ikuti : ikut
# kuis : kuis
# tim : tim
# emoji : emoji
# merapat : rapat
# emot : emot
# donggg : donggg
# hhh : hhh
# bintang : bintang
# berotasi : rotasi
# full : full
# kecuali : kecuali
# pusing : pusing
# koneksinya : koneksi
# lambat : lambat
# bagusnya : bagus
# followers : followers
# like : like
# tembus : tembus
# mimin : mimin
# ditempat : tempat
# berat : berat
# alias : alias
# dlm : dlm
# jam : jam
# triliun : triliun
# juta : juta
# miliar : miliar
# lewati : lewat
# mental : mental
# aman : aman
# klau : klau
# artiny : artiny
# artnya : artnya
# tuju : tuju
# keliling : keliling
# thanks : thanks
# unlimited : unlimited
# sosmed : sosmed
# games : games
# game : game
# astaga : astaga
# anjnggg : anjnggg
# lip : lip
# service : service
# melulu : melulu
# {'keren': 'keren', '': '', 'min': 'min', 'sinyal': 'sinyal', 'bermasalah': 'masalah', 'kah': 'kah', 'info': 'info', 'menarik': 'tarik', 'mendingan': 'mending', 'makan': 'makan', 'tumis': 'tumis', 'kangkung': 'kangkung', 'pizza': 'pizza', 'mimpi': 'mimpi', 'pantasan': 'pantas', 'internetan': 'internetan', 'jasuka': 'jasuka', 'kabel': 'kabel', 'laut': 'laut', 'internet': 'internet', 'udah': 'udah', 'masuk': 'masuk', 'lancarnya': 'lancar', 'mohon': 'mohon', 'ditanggapi': 'tanggap', 'telkomsel': 'telkomsel', 'gabisa': 'gabisa', 'kebuka': 'buka', 'kesalahan': 'salah', 'sistem': 'sistem', 'kak': 'kak', 'tolong': 'tolong', 'cek': 'cek', 'kpm': 'kpm', 'zr': 'zr', 'ditemenin': 'ditemenin', 'nyari': 'nyari', 'eceng': 'eceng', 'gondok': 'gondok', 'penelitian': 'teliti', 'skripsi': 'skripsi', 'rela': 'rela', 'turun': 'turun', 'kolam': 'kolam', 'ngambil': 'ngambil', 'diriku': 'diri', 'mawar': 'mawar', 'tulip': 'tulip', 'jatuhcinta': 'jatuhcinta', 'event': 'event', 'disuruh': 'suruh', 'komen': 'komen', 'btw': 'btw', 'postingan': 'postingan', 'bnyk': 'bnyk', 'koin': 'koin', 'tukar': 'tukar', 'lancar': 'lancar', 'heng': 'heng', 'kebutuhan': 'butuh', 'jualan': 'jual', 'online': 'online', 'mata': 'mata', 'pencarian': 'cari', 'lcd': 'lcd', 'pecah': 'pecah', 'make': 'make', 'halo': 'halo', 'ancur': 'ancur', 'setahun': 'tahun', 'daerah': 'daerah', 'skrg': 'skrg', 'kualitas': 'kualitas', 'bagus': 'bagus', 'komplain': 'komplain', 'nanya': 'nanya', 'nggak': 'nggak', 'stabil': 'stabil', 'ganggu': 'ganggu', 'banget': 'banget', 'pas': 'pas', 'ujian': 'uji', 'selesai': 'selesai', 'ngerjain': 'ngerjain', 'kekoreksi': 'koreksi', 'gara': 'gara', 'sinyalnya': 'sinyal', 'paket': 'paket', 'bundling': 'bundling', 'iphone': 'iphone', 'gmn': 'gmn', 'nyicil': 'nyicil', 'grapari': 'grapari', 'bandung': 'bandung', 'dmn': 'dmn', 'ajbyg': 'ajbyg', 'buka': 'buka', 'aplikasi': 'aplikasi', 'gambarnya': 'gambar', 'kuota': 'kuota', 'deh': 'deh', 'baca': 'baca', 'wkwkwkkw': 'wkwkwkkw', 'aseli': 'aseli', 'tersendat': 'sendat', 'nipu': 'nipu', 'tanggung': 'tanggung', 'boy': 'boy', 'sampe': 'sampe', 'tsel': 'tsel', 'gua': 'gua', 'wkwkwk': 'wkwkwk', 'byu': 'byu', 'iklan': 'iklan', 'penipuan': 'tipu', 'akun': 'akun', 'bales': 'bales', 'cirebon': 'cirebon', 'leg': 'leg', 'signal': 'signal', 'ilang': 'ilang', 'trus': 'trus', 'push': 'push', 'rankk': 'rankk', 'udh': 'udh', 'isi': 'isi', 'mah': 'mah', 'wifi': 'wifi', 'indihomeeeee': 'indihomeeeee', 'ngelag': 'ngelag', 'jugaaaaaaaa': 'jugaaaaaaaa', 'kesel': 'kesel', 'emang': 'emang', 'aktif': 'aktif', 'jual': 'jual', 'gmna': 'gmna', 'bertahun': 'tahun', 'gambar': 'gambar', 'org': 'org', 'ngga': 'ngga', 'dibuka': 'buka', 'aktifin': 'aktifin', 'kartu': 'kartu', 'angus': 'angus', 'karna': 'karna', 'jarang': 'jarang', 'isii': 'isi', 'plsa': 'plsa', 'gue': 'gue', 'error': 'error', 'pagi': 'pagi', 'system': 'system', 'restart': 'restart', 'mohom': 'mohom', 'lgi': 'lgi', 'promonya': 'promonya', 'iya': 'iya', 'temen': 'temen', 'suka': 'suka', 'curhat': 'curhat', 'kadang': 'kadang', 'males': 'males', 'off': 'off', 'mulu': 'mulu', 'ngellag': 'ngellag', 'cok': 'cok', 'infonya': 'info', 'kemarin': 'kemarin', 'tuker': 'tuker', 'poin': 'poin', 'voucer': 'voucer', 'toyota': 'toyota', 'rush': 'rush', 'dpet': 'dpet', 'teman': 'teman', 'workaholic': 'workaholic', 'workholic': 'workholic', 'rebahan': 'rebah', 'kode': 'kode', 'kpd': 'kpd', 'ltv': 'ltv', 'spasi': 'spasi', 'cerita': 'cerita', 'romantis': 'romantis', 'prnh': 'prnh', 'alami': 'alami', 'tag': 'tag', 'entertainment': 'entertainment', 'menangin': 'menangin', 'hadiah': 'hadiah', 'periode': 'periode', 'link': 'link', 'diakses': 'akses', 'hmm': 'hmm', 'nge': 'nge', 'duhh': 'duhh', 'undi': 'undi', 'hepi': 'hepi', 'kapn': 'kapn', 'umumin': 'umumin', 'ndak': 'ndak', 'tengotengok': 'tengotengok', 'tersedia': 'sedia', 'mngkin': 'mngkin', 'kuotanya': 'kuota', 'terbatas': 'batas', 'gtu': 'gtu', 'hapus': 'hapus', 'iklannya': 'iklan', 'maaf': 'maaf', 'ambyar': 'ambyar', 'gini': 'gin', 'paketan': 'paket',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/174 [00:00<?, ?it/s]
#                                                   text  \
# 0                                  keren ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 1                     min, sinyal lagi bermasalah kah?
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya ga bisa internetan min.masalah j...
# ..                                                 ...
# 216                              min bales dm.. thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                            astaga
# 219                                 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 220  sinyal lu benerin anjnggg jangan lip service m...
#
#                                          cleaning_text  \
# 0                                               keren
# 1                      min sinyal lagi bermasalah kah
# 2                                    info yang menarik
# 3    mendingan makan tumis kangkung dari pada makan...
# 4    pantasan saya bisa internetan min masalah jasu...
# ..                                                 ...
# 216                                   min bales thanks
# 217  paket unlimited sosmed games kok gak bisa buat...
# 218                                             astaga
# 219
# 220  sinyal benerin anjnggg jangan lip service melu...
#
#                                             tokenisasi  \
# 0                                            [keren, ]
# 1               [min, sinyal, lagi, bermasalah, kah, ]
# 2                                [info, yang, menarik]
# 3    [mendingan, makan, tumis, kangkung, dari, pada...
# 4    [pantasan, saya, bisa, internetan, min, masala...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217  [paket, unlimited, sosmed, games, kok, gak, bi...
# 218                                           [astaga]
# 219                                               [, ]
# 220  [sinyal, benerin, anjnggg, jangan, lip, servic...
#
#                                               stopword  \
# 0                                            [keren, ]
# 1                     [min, sinyal, bermasalah, kah, ]
# 2                                      [info, menarik]
# 3    [mendingan, makan, tumis, kangkung, makan, piz...
# 4    [pantasan, internetan, min, jasuka, kabel, lau...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217    [paket, unlimited, sosmed, games, game, online]
# 218                                           [astaga]
# 219                                               [, ]
# 220   [sinyal, benerin, anjnggg, lip, service, melulu]
#
#                                               stemming
# 0                                            [keren, ]
# 1                        [min, sinyal, masalah, kah, ]
# 2                                        [info, tarik]
# 3    [mending, makan, tumis, kangkung, makan, pizza...
# 4    [pantas, internetan, min, jasuka, kabel, laut,...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217    [paket, unlimited, sosmed, games, game, online]
# 218                                           [astaga]
# 219                                               [, ]
# 220   [sinyal, benerin, anjnggg, lip, service, melulu]
#
# [174 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                            [keren, ]
# 1                        [min, sinyal, masalah, kah, ]
# 2                                        [info, tarik]
# 3    [mending, makan, tumis, kangkung, makan, pizza...
# 4    [pantas, internetan, min, jasuka, kabel, laut,...
# ..                                                 ...
# 216                               [min, bales, thanks]
# 217    [paket, unlimited, sosmed, games, game, online]
# 218                                           [astaga]
# 219                                               [, ]
# 220   [sinyal, benerin, anjnggg, lip, service, melulu]
#
# [174 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_9.xlsx')
