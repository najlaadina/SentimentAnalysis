# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                           Sinyak Telkomsel sngt jlek
# 1       Selamat Pak , semoga berkah dan amanah ,Aamiin
# 2    Percuma ganti direksi. Keluhan saya aja belum ...
# 3                     Angkat dong saya jadi Komisaris
# 4    Min aku udah kasih no.hp loh yang kemarin di m...
# ..                                                 ...
# 110                             Sukse buat telkomsel❤️
# 111                                         Mantap....
# 112  Saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               Pengiriman hadiah giveaway kapan min
# 114                                                Waw
#
# [115 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 9

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                           Sinyak Telkomsel sngt jlek
# 1       Selamat Pak , semoga berkah dan amanah ,Aamiin
# 2    Percuma ganti direksi. Keluhan saya aja belum ...
# 4    Min aku udah kasih no.hp loh yang kemarin di m...
# 5    Balas dm kak, ditunggu hadiah giveawaynya, uda...
# ..                                                 ...
# 110                             Sukse buat telkomsel❤️
# 111                                         Mantap....
# 112  Saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               Pengiriman hadiah giveaway kapan min
# 114                                                Waw
#
# [97 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                           sinyak telkomsel sngt jlek
# 1       selamat pak , semoga berkah dan amanah ,aamiin
# 2    percuma ganti direksi. keluhan saya aja belum ...
# 4    min aku udah kasih no.hp loh yang kemarin di m...
# 5    balas dm kak, ditunggu hadiah giveawaynya, uda...
# ..                                                 ...
# 110                             sukse buat telkomsel❤️
# 111                                         mantap....
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
# [97 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                           sinyak telkomsel sngt jlek
# 1       selamat pak , semoga berkah dan amanah ,aamiin
# 2    percuma ganti direksi. keluhan saya aja belum ...
# 4    min aku udah kasih no.hp loh yang kemarin di m...
# 5    balas dm kak, ditunggu hadiah giveawaynya, uda...
# ..                                                 ...
# 110                             sukse buat telkomsel❤️
# 111                                         mantap....
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                          cleaning_text
# 0                           sinyak telkomsel sngt jlek
# 1          selamat pak semoga berkah dan amanah aamiin
# 2    percuma ganti direksi keluhan saya aja belum b...
# 4    min aku udah kasih loh yang kemarin minta kok ...
# 5    balas kak ditunggu hadiah giveawaynya udah lum...
# ..                                                 ...
# 110                              sukse buat telkomsel
# 111                                            mantap
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
# [97 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                           sinyak telkomsel sngt jlek
# 1       selamat pak , semoga berkah dan amanah ,aamiin
# 2    percuma ganti direksi. keluhan saya aja belum ...
# 4    min aku udah kasih no.hp loh yang kemarin di m...
# 5    balas dm kak, ditunggu hadiah giveawaynya, uda...
# ..                                                 ...
# 110                             sukse buat telkomsel❤️
# 111                                         mantap....
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                          cleaning_text  \
# 0                           sinyak telkomsel sngt jlek
# 1          selamat pak semoga berkah dan amanah aamiin
# 2    percuma ganti direksi keluhan saya aja belum b...
# 4    min aku udah kasih loh yang kemarin minta kok ...
# 5    balas kak ditunggu hadiah giveawaynya udah lum...
# ..                                                 ...
# 110                              sukse buat telkomsel
# 111                                            mantap
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                             tokenisasi
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1    [selamat, pak, semoga, berkah, dan, amanah, aa...
# 2    [percuma, ganti, direksi, keluhan, saya, aja, ...
# 4    [min, aku, udah, kasih, loh, yang, kemarin, mi...
# 5    [balas, kak, ditunggu, hadiah, giveawaynya, ud...
# ..                                                 ...
# 110                         [sukse, buat, telkomsel, ]
# 111                                         [mantap, ]
# 112  [saya, pengguna, tlkomsel, dan, pake, nomor, i...
# 113         [pengiriman, hadiah, giveaway, kapan, min]
# 114                                              [waw]
#
# [97 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                           sinyak telkomsel sngt jlek
# 1       selamat pak , semoga berkah dan amanah ,aamiin
# 2    percuma ganti direksi. keluhan saya aja belum ...
# 4    min aku udah kasih no.hp loh yang kemarin di m...
# 5    balas dm kak, ditunggu hadiah giveawaynya, uda...
# ..                                                 ...
# 110                             sukse buat telkomsel❤️
# 111                                         mantap....
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                          cleaning_text  \
# 0                           sinyak telkomsel sngt jlek
# 1          selamat pak semoga berkah dan amanah aamiin
# 2    percuma ganti direksi keluhan saya aja belum b...
# 4    min aku udah kasih loh yang kemarin minta kok ...
# 5    balas kak ditunggu hadiah giveawaynya udah lum...
# ..                                                 ...
# 110                              sukse buat telkomsel
# 111                                            mantap
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                             tokenisasi  \
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1    [selamat, pak, semoga, berkah, dan, amanah, aa...
# 2    [percuma, ganti, direksi, keluhan, saya, aja, ...
# 4    [min, aku, udah, kasih, loh, yang, kemarin, mi...
# 5    [balas, kak, ditunggu, hadiah, giveawaynya, ud...
# ..                                                 ...
# 110                         [sukse, buat, telkomsel, ]
# 111                                         [mantap, ]
# 112  [saya, pengguna, tlkomsel, dan, pake, nomor, i...
# 113         [pengiriman, hadiah, giveaway, kapan, min]
# 114                                              [waw]
#
#                                               stopword
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1            [selamat, semoga, berkah, amanah, aamiin]
# 2                   [ganti, direksi, keluhan, beres, ]
# 4                 [min, udah, kasih, kemarin, belom, ]
# 5    [balas, kak, ditunggu, hadiah, giveawaynya, ud...
# ..                                                 ...
# 110                               [sukse, telkomsel, ]
# 111                                         [mantap, ]
# 112  [pengguna, tlkomsel, nomor, udh, hadiah, appun, ]
# 113                [pengiriman, hadiah, giveaway, min]
# 114                                              [waw]
#
# [97 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 390
# ------------------------
# sinyak : sinyak
# telkomsel : telkomsel
# sngt : sngt
# jlek : jlek
# selamat : selamat
# semoga : moga
# berkah : berkah
# amanah : amanah
# aamiin : aamiin
# ganti : ganti
# direksi : direksi
# keluhan : keluh
# beres : beres
#  :
# min : min
# udah : udah
# kasih : kasih
# kemarin : kemarin
# belom : bom
# balas : balas
# kak : kak
# ditunggu : tunggu
# hadiah : hadiah
# giveawaynya : giveawaynya
# lumayan : lumayan
# takutnya : takut
# lupa : lupa
# daftarin : daftarin
# nik : nik
# nomor : nomor
# ketiga : tiga
# pas : pas
# cek : cek
# milik : milik
# bantu : bantu
# menonaktifkan : nonaktif
# takut : takut
# salah : salah
# masukan : masuk
# vocer : vocer
# gimana : gimana
# halah : halah
# kuota : kuota
# free : free
# game : game
# dikasih : kasih
# keluhannya : keluh
# april : april
# penyelesaian : selesai
# hubungi : hubung
# aplikasi : aplikasi
# messenger : messenger
# admin : admin
# nyolot : nyolot
# daerah : daerah
# cikarang : cikarang
# tepatnya : tepat
# pintu : pintu
# masuk : masuk
# kawasan : kawasan
# jababeka : jababeka
# sinyal : sinyal
# stabil : stabil
# sampe : sampe
# pindah : pindah
# tolong : tolong
# diperbaiki : baik
# temen : temen
# sya : sya
# pengguna : guna
# tsel : tsel
# buruk : buruk
# boss : boss
# harga : harga
# paket : paket
# turunin : turunin
# boaa : boaa
# sukses : sukses
# berkarya : karya
# mentang : mentang
# pulsa : pulsa
# paketan : paket
# mahal : mahal
# rban : rban
# undi : undi
# happy : happy
# siih : siih
# tlng : tlng
# ajah : ajah
# konsumen : konsumen
# pemakai : pakai
# unsur : unsur
# penipuan : tipu
# bolt : bolt
# nonton : nonton
# keknya : kek
# menunggu : tunggu
# batas : batas
# menjual : jual
# hangus : hangus
# internet : internet
# blm : blm
# bagus : bagus
# putra : putra
# aqsa : aqsa
# iya : iya
# enak : enak
# suka : suka
# knp : knp
# berubah : ubah
# dikit : dikit
# marketing : marketing
# unlimited : unlimited
# batasan : batas
# combo : combo
# batasin : batasin
# rubah : rubah
# pakai : pakai
# gini : gin
# tpi : tpi
# knpa : knpa
# kesedot : sedot
# komplain : komplain
# nii : nii
# beli : beli
# unlimeted : unlimeted
# dibatasi : batas
# namanya : nama
# dongg : dongg
# rugi : rugi
# gabisa : gabisa
# dipake : dipake
# telkomsell : telkomsell
# diperbaikkii : diperbaikkii
# merugikan : rugi
# berkurang : kurang
# ribulo : ribulo
# sehari : hari
# dicek : cek
# kosong : kosong
# anvugr : anvugr
# produk : produk
# negeri : negeri
# rara : rara
# nusa : nusa
# film : film
# penuh : penuh
# ajaran : ajar
# moral : moral
# pendidikan : didik
# loha : loha
# minn : minn
# fup : fup
# kaya : kaya
# butuh : butuh
# banget : banget
# anv : anv
# rx : rx
# bk : bk
# perbaiki : baik
# kartu : kartu
# jarus : jarus
# grapaari : grapaari
# online : online
# nomorku : nomor
# blokir : blokir
# telkomselslank : telkomselslank
# tmpat : tmpat
# jringannya : jringannya
# beda : beda
# sblah : sblah
# timur : timur
# tower : tower
# lbih : lbih
# dri : dri
# pda : pda
# barat : barat
# cman : cman
# stu : stu
# bda : bda
# gtu : gtu
# kcepatn : kcepatn
# berasa : asa
# kek : kek
# edge : edge
# hancur : hancur
# habis : habis
# boro : boro
# akses : akses
# browsing : browsing
# ngeload : ngeload
# parah : parah
# sinyalnya : sinyal
# note : note
# veronika : veronika
# perbaikan : baik
# penyemarataan : penyemarataan
# internetnya : internetnya
# sebulan : bulan
# kecepatan : cepat
# surabaya : surabaya
# helehhh : helehhh
# terseok : seok
# seok : seok
# wilayah : wilayah
# pinggiran : pinggir
# ibukotaapalagi : ibukotaapalagi
# hujan : hujan
# mati : mati
# lampu : lampu
# masi : mas
# ngandelin : ngandelin
# ups : ups
# tua : tua
# kali : kali
# mimin : mimin
# ngak : ngak
# bundling : bundling
# mimpi : mimpi
# sim : sim
# card : card
# diganti : ganti
# grapari : grapari
# telkimsel : telkimsel
# unruk : unruk
# main : main
# msh : msh
# ngelag : ngelag
# alay : alay
# kedepannya : depan
# telkom : telkom
# sel : sel
# joooiisssssss : joooiisssssss
# bentar : bentar
# hape : hape
# turun : turun
# plat : plat
# merah : merah
# membalikan : balik
# investasi : investasi
# profit : profit
# bumn : bumn
# cianjur : cianjur
# kecamatan : camat
# padasuka : padasuka
# kabupaten : kabupaten
# cibinong : cibinong
# kadang : kadang
# signal : signal
# pulau : pulau
# jawa : jawa
# benerin : benerin
# kepelosok : pelosok
# pelosok : pelosok
# semangat : semangat
# gokil : gokil
# krna : krna
# kenceng : kenceng
# jambi : jambi
# tanjab : tanjab
# sungguh : sungguh
# mencoba : coba
# cepet : cepet
# teknologi : teknologi
# canggih : canggih
# fix : fix
# nnti : nnti
# make : make
# coba : coba
# menarik : tarik
# dicoba : coba
# gang : gang
# infonya : info
# migrasi : migrasi
# hrs : hrs
# mendukung : dukung
# ayo : ayo
# bayangin : bayangin
# ntr : ntr
# dwi : dwi
# kho : kho
# lampung : lampung
# udh : udh
# lom : lom
# maaf : maaf
# dibales : dibales
# diread : diread
# giveaway : giveaway
# diproses : proses
# kepastian : pasti
# ulang : ulang
# berkembang : kembang
# lelt : lelt
# yaaa : yaaa
# forzi : forzi
# loo : loo
# selamaat : selamaat
# jaya : jaya
# berjaya : jaya
# hati : hati
# masyarakat : masyarakat
# terussssss : terussssss
# gratis : gratis
# smoga : smoga
# bnyak : bnyak
# kejutan : kejut
# pke : pke
# bertahun : tahun
# dirgahayu : dirgahayu
# slalu : slalu
# pelayanan : layan
# terbaik : baik
# terimakasih : terimakasih
# melayani : layan
# indonesia : indonesia
# halonya : halo
# downgrade : downgrade
# woy : woy
# mengecewakan : kecewa
# pelanggan : langgan
# setia : setia
# terima : terima
# memenuhi : penuh
# kebutuhan : butuh
# komunikasi : komunikasi
# mendoakan : doa
# terdepan : depan
# met : met
# ultah : ultah
# favorit : favorit
# amin : amin
# internetan : internetan
# kabel : kabel
# optik : optik
# putus : putus
# mei : mei
# khusus : khusus
# jayapura : jayapura
# pengangguran : anggur
# cashback : cashback
# murah : murah
# bangett : bangett
# kennanya : kennanya
# doain : doain
# pilih : pilih
# pemenang : menang
# th : th
# undian : undi
# app : app
# liat : liat
# rajin : rajin
# aktif : aktif
# ahh : ahh
# jaringannya : jaring
# muter : muter
# gara : gara
# muncul : muncul
# pdahal : pdahal
# dlu : dlu
# assalamu : assalamu
# alaikum : alaikum
# please : please
# notif : notif
# terpilih : pilih
# pantengin : pantengin
# live : live
# ditelpon : telpon
# suci : suci
# sehat : sehat
# team : team
# semngat : semngat
# mulu : mulu
# day : day
# menang : menang
# bawa : bawa
# pulang : pulang
# iphone : iphone
# deh : deh
# done : done
# tukar : tukar
# poin : poin
# cv : cv
# anvp : anvp
# hkz : hkz
# sukse : sukse
# mantap : mantap
# tlkomsel : tlkomsel
# appun : appun
# pengiriman : kirim
# waw : waw
# {'sinyak': 'sinyak', 'telkomsel': 'telkomsel', 'sngt': 'sngt', 'jlek': 'jlek', 'selamat': 'selamat', 'semoga': 'moga', 'berkah': 'berkah', 'amanah': 'amanah', 'aamiin': 'aamiin', 'ganti': 'ganti', 'direksi': 'direksi', 'keluhan': 'keluh', 'beres': 'beres', '': '', 'min': 'min', 'udah': 'udah', 'kasih': 'kasih', 'kemarin': 'kemarin', 'belom': 'bom', 'balas': 'balas', 'kak': 'kak', 'ditunggu': 'tunggu', 'hadiah': 'hadiah', 'giveawaynya': 'giveawaynya', 'lumayan': 'lumayan', 'takutnya': 'takut', 'lupa': 'lupa', 'daftarin': 'daftarin', 'nik': 'nik', 'nomor': 'nomor', 'ketiga': 'tiga', 'pas': 'pas', 'cek': 'cek', 'milik': 'milik', 'bantu': 'bantu', 'menonaktifkan': 'nonaktif', 'takut': 'takut', 'salah': 'salah', 'masukan': 'masuk', 'vocer': 'vocer', 'gimana': 'gimana', 'halah': 'halah', 'kuota': 'kuota', 'free': 'free', 'game': 'game', 'dikasih': 'kasih', 'keluhannya': 'keluh', 'april': 'april', 'penyelesaian': 'selesai', 'hubungi': 'hubung', 'aplikasi': 'aplikasi', 'messenger': 'messenger', 'admin': 'admin', 'nyolot': 'nyolot', 'daerah': 'daerah', 'cikarang': 'cikarang', 'tepatnya': 'tepat', 'pintu': 'pintu', 'masuk': 'masuk', 'kawasan': 'kawasan', 'jababeka': 'jababeka', 'sinyal': 'sinyal', 'stabil': 'stabil', 'sampe': 'sampe', 'pindah': 'pindah', 'tolong': 'tolong', 'diperbaiki': 'baik', 'temen': 'temen', 'sya': 'sya', 'pengguna': 'guna', 'tsel': 'tsel', 'buruk': 'buruk', 'boss': 'boss', 'harga': 'harga', 'paket': 'paket', 'turunin': 'turunin', 'boaa': 'boaa', 'sukses': 'sukses', 'berkarya': 'karya', 'mentang': 'mentang', 'pulsa': 'pulsa', 'paketan': 'paket', 'mahal': 'mahal', 'rban': 'rban', 'undi': 'undi', 'happy': 'happy', 'siih': 'siih', 'tlng': 'tlng', 'ajah': 'ajah', 'konsumen': 'konsumen', 'pemakai': 'pakai', 'unsur': 'unsur', 'penipuan': 'tipu', 'bolt': 'bolt', 'nonton': 'nonton', 'keknya': 'kek', 'menunggu': 'tunggu', 'batas': 'batas', 'menjual': 'jual', 'hangus': 'hangus', 'internet': 'internet', 'blm': 'blm', 'bagus': 'bagus', 'putra': 'putra', 'aqsa': 'aqsa', 'iya': 'iya', 'enak': 'enak', 'suka': 'suka', 'knp': 'knp', 'berubah': 'ubah', 'dikit': 'dikit', 'marketing': 'marketing', 'unlimited': 'unlimited', 'batasan': 'batas', 'combo': 'combo', 'batasin': 'batasin', 'rubah': 'rubah', 'pakai': 'pakai', 'gini': 'gin', 'tpi': 'tpi', 'knpa': 'knpa', 'kesedot': 'sedot', 'komplain': 'komplain', 'nii': 'nii', 'beli': 'beli', 'unlimeted': 'unlimeted', 'dibatasi': 'batas', 'namanya': 'nama', 'dongg': 'dongg', 'rugi': 'rugi', 'gabisa': 'gabisa', 'dipake': 'dipake', 'telkomsell': 'telkomsell', 'diperbaikkii': 'diperbaikkii', 'merugikan': 'rugi', 'berkurang': 'kurang', 'ribulo': 'ribulo', 'sehari': 'hari', 'dicek': 'cek', 'kosong': 'kosong', 'anvugr': 'anvugr', 'produk': 'produk', 'negeri': 'negeri', 'rara': 'rara', 'nusa': 'nusa', 'film': 'film', 'penuh': 'penuh', 'ajaran': 'ajar', 'moral': 'moral', 'pendidikan': 'didik', 'loha': 'loha', 'minn': 'minn', 'fup': 'fup', 'kaya': 'kaya', 'butuh': 'butuh', 'banget': 'banget', 'anv': 'anv', 'rx': 'rx', 'bk': 'bk', 'perbaiki': 'baik', 'kartu': 'kartu', 'jarus': 'jarus', 'grapaari': 'grapaari', 'online': 'online', 'nomorku': 'nomor', 'blokir': 'blokir', 'telkomselslank': 'telkomselslank', 'tmpat': 'tmpat', 'jringannya': 'jringannya', 'beda': 'beda', 'sblah': 'sblah', 'timur': 'timur', 'tower': 'tower', 'lbih': 'lbih', 'dri': 'dri', 'pda': 'pda', 'barat': 'barat', 'cman': 'cman', 'stu': 'stu', 'bda': 'bda', 'gtu': 'gtu', 'kcepatn': 'kcepatn', 'berasa': 'asa', 'kek': 'kek', 'edge': 'edge', 'hancur': 'hancur', 'habis': 'habis', 'boro': 'boro', 'akses': 'akses', 'browsing': 'browsing', 'ngeload': 'ngeload', 'parah': 'parah', 'sinyalnya': 'sinyal', 'note': 'note', 'veronika': 'veronika', 'perbaikan': 'baik', 'penyemarataan': 'penyemarataan', 'internetnya': 'internetnya', 'sebulan': 'bulan', 'kecepatan': 'cepat', 'surabaya': 'surabaya', 'helehhh': 'helehhh', 'terseok': 'seok', 'seok': 'seok', 'wilayah': 'wilayah', 'pinggiran': 'pinggir', 'ibukotaapalagi': 'ibukotaapalagi', 'hujan': 'hujan', 'ma ...
# ------------------------
# Pandas Apply:   0%|          | 0/97 [00:00<?, ?it/s]
#                                                   text  \
# 0                           sinyak telkomsel sngt jlek
# 1       selamat pak , semoga berkah dan amanah ,aamiin
# 2    percuma ganti direksi. keluhan saya aja belum ...
# 4    min aku udah kasih no.hp loh yang kemarin di m...
# 5    balas dm kak, ditunggu hadiah giveawaynya, uda...
# ..                                                 ...
# 110                             sukse buat telkomsel❤️
# 111                                         mantap....
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                          cleaning_text  \
# 0                           sinyak telkomsel sngt jlek
# 1          selamat pak semoga berkah dan amanah aamiin
# 2    percuma ganti direksi keluhan saya aja belum b...
# 4    min aku udah kasih loh yang kemarin minta kok ...
# 5    balas kak ditunggu hadiah giveawaynya udah lum...
# ..                                                 ...
# 110                              sukse buat telkomsel
# 111                                            mantap
# 112  saya pengguna tlkomsel dan pake nomor ini udh ...
# 113               pengiriman hadiah giveaway kapan min
# 114                                                waw
#
#                                             tokenisasi  \
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1    [selamat, pak, semoga, berkah, dan, amanah, aa...
# 2    [percuma, ganti, direksi, keluhan, saya, aja, ...
# 4    [min, aku, udah, kasih, loh, yang, kemarin, mi...
# 5    [balas, kak, ditunggu, hadiah, giveawaynya, ud...
# ..                                                 ...
# 110                         [sukse, buat, telkomsel, ]
# 111                                         [mantap, ]
# 112  [saya, pengguna, tlkomsel, dan, pake, nomor, i...
# 113         [pengiriman, hadiah, giveaway, kapan, min]
# 114                                              [waw]
#
#                                               stopword  \
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1            [selamat, semoga, berkah, amanah, aamiin]
# 2                   [ganti, direksi, keluhan, beres, ]
# 4                 [min, udah, kasih, kemarin, belom, ]
# 5    [balas, kak, ditunggu, hadiah, giveawaynya, ud...
# ..                                                 ...
# 110                               [sukse, telkomsel, ]
# 111                                         [mantap, ]
# 112  [pengguna, tlkomsel, nomor, udh, hadiah, appun, ]
# 113                [pengiriman, hadiah, giveaway, min]
# 114                                              [waw]
#
#                                               stemming
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1              [selamat, moga, berkah, amanah, aamiin]
# 2                     [ganti, direksi, keluh, beres, ]
# 4                   [min, udah, kasih, kemarin, bom, ]
# 5    [balas, kak, tunggu, hadiah, giveawaynya, udah...
# ..                                                 ...
# 110                               [sukse, telkomsel, ]
# 111                                         [mantap, ]
# 112      [guna, tlkomsel, nomor, udh, hadiah, appun, ]
# 113                     [kirim, hadiah, giveaway, min]
# 114                                              [waw]
#
# [97 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                      [sinyak, telkomsel, sngt, jlek]
# 1              [selamat, moga, berkah, amanah, aamiin]
# 2                     [ganti, direksi, keluh, beres, ]
# 4                   [min, udah, kasih, kemarin, bom, ]
# 5    [balas, kak, tunggu, hadiah, giveawaynya, udah...
# ..                                                 ...
# 110                               [sukse, telkomsel, ]
# 111                                         [mantap, ]
# 112      [guna, tlkomsel, nomor, udh, hadiah, appun, ]
# 113                     [kirim, hadiah, giveaway, min]
# 114                                              [waw]
#
# [97 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_5.xlsx')
