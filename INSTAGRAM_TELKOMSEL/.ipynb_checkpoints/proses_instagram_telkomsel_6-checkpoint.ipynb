# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0    Jringannya gmn ini.. Knpa smkin lama smkin kac...
# 1    Hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 2    Di Gayo Lues udah beberapa hari sinyal ga bagu...
# 3    Di Gayo Lues udah beberapa hari sinyal ga bagu...
# 4                 Ga bisa beli pket ga ada balesan nyl
# ..                                                 ...
# 102  Admin omg kouta nonton gk bisa di pake kouta i...
# 103                            Harga nya tunjukin dong
# 104  Kuota maxtream skg ga bisa buat akses Netflix ...
# 105                                                NaN
# 106  Min Kuota lokal ga bisa kepake, padahal aku ga...
#
# [107 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0    Jringannya gmn ini.. Knpa smkin lama smkin kac...
# 1    Hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 6                                                 Bagi
# 7           Admin kembalikan paket combo unlimited nya
# 8    Logo doang baru,, internet dah kaya jaman mega...
# ..                                                 ...
# 102  Admin omg kouta nonton gk bisa di pake kouta i...
# 103                            Harga nya tunjukin dong
# 104  Kuota maxtream skg ga bisa buat akses Netflix ...
# 105                                                NaN
# 106  Min Kuota lokal ga bisa kepake, padahal aku ga...
#
# [95 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0    jringannya gmn ini.. knpa smkin lama smkin kac...
# 1    hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru,, internet dah kaya jaman mega...
# ..                                                 ...
# 102  admin omg kouta nonton gk bisa di pake kouta i...
# 103                            harga nya tunjukin dong
# 104  kuota maxtream skg ga bisa buat akses netflix ...
# 105                                                NaN
# 106  min kuota lokal ga bisa kepake, padahal aku ga...
#
# [95 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0    jringannya gmn ini.. knpa smkin lama smkin kac...
# 1    hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru,, internet dah kaya jaman mega...
# ..                                                 ...
# 102  admin omg kouta nonton gk bisa di pake kouta i...
# 103                            harga nya tunjukin dong
# 104  kuota maxtream skg ga bisa buat akses netflix ...
# 105                                                NaN
# 106  min kuota lokal ga bisa kepake, padahal aku ga...
#
#                                          cleaning_text
# 0    jringannya gmn ini knpa smkin lama smkin kacau...
# 1    hadeuhhhhhhhh sinyalmu bikin emosi please siny...
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru internet dah kaya jaman megali...
# ..                                                 ...
# 102  admin omg kouta nonton bisa pake kouta interne...
# 103                            harga nya tunjukin dong
# 104    kuota maxtream skg bisa buat akses netflix gan
# 105                                                nan
# 106  min kuota lokal bisa kepake padahal aku keluar...
#
# [95 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0    jringannya gmn ini.. knpa smkin lama smkin kac...
# 1    hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru,, internet dah kaya jaman mega...
# ..                                                 ...
# 102  admin omg kouta nonton gk bisa di pake kouta i...
# 103                            harga nya tunjukin dong
# 104  kuota maxtream skg ga bisa buat akses netflix ...
# 105                                                NaN
# 106  min kuota lokal ga bisa kepake, padahal aku ga...
#
#                                          cleaning_text  \
# 0    jringannya gmn ini knpa smkin lama smkin kacau...
# 1    hadeuhhhhhhhh sinyalmu bikin emosi please siny...
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru internet dah kaya jaman megali...
# ..                                                 ...
# 102  admin omg kouta nonton bisa pake kouta interne...
# 103                            harga nya tunjukin dong
# 104    kuota maxtream skg bisa buat akses netflix gan
# 105                                                nan
# 106  min kuota lokal bisa kepake padahal aku keluar...
#
#                                             tokenisasi
# 0    [jringannya, gmn, ini, knpa, smkin, lama, smki...
# 1    [hadeuhhhhhhhh, sinyalmu, bikin, emosi, please...
# 6                                               [bagi]
# 7    [admin, kembalikan, paket, combo, unlimited, nya]
# 8    [logo, doang, baru, internet, dah, kaya, jaman...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, bisa, pake, kouta,...
# 103                       [harga, nya, tunjukin, dong]
# 104  [kuota, maxtream, skg, bisa, buat, akses, netf...
# 105                                              [nan]
# 106  [min, kuota, lokal, bisa, kepake, padahal, aku...
#
# [95 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0    jringannya gmn ini.. knpa smkin lama smkin kac...
# 1    hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru,, internet dah kaya jaman mega...
# ..                                                 ...
# 102  admin omg kouta nonton gk bisa di pake kouta i...
# 103                            harga nya tunjukin dong
# 104  kuota maxtream skg ga bisa buat akses netflix ...
# 105                                                NaN
# 106  min kuota lokal ga bisa kepake, padahal aku ga...
#
#                                          cleaning_text  \
# 0    jringannya gmn ini knpa smkin lama smkin kacau...
# 1    hadeuhhhhhhhh sinyalmu bikin emosi please siny...
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru internet dah kaya jaman megali...
# ..                                                 ...
# 102  admin omg kouta nonton bisa pake kouta interne...
# 103                            harga nya tunjukin dong
# 104    kuota maxtream skg bisa buat akses netflix gan
# 105                                                nan
# 106  min kuota lokal bisa kepake padahal aku keluar...
#
#                                             tokenisasi  \
# 0    [jringannya, gmn, ini, knpa, smkin, lama, smki...
# 1    [hadeuhhhhhhhh, sinyalmu, bikin, emosi, please...
# 6                                               [bagi]
# 7    [admin, kembalikan, paket, combo, unlimited, nya]
# 8    [logo, doang, baru, internet, dah, kaya, jaman...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, bisa, pake, kouta,...
# 103                       [harga, nya, tunjukin, dong]
# 104  [kuota, maxtream, skg, bisa, buat, akses, netf...
# 105                                              [nan]
# 106  [min, kuota, lokal, bisa, kepake, padahal, aku...
#
#                                               stopword
# 0    [jringannya, gmn, knpa, smkin, smkin, kacau, j...
# 1    [hadeuhhhhhhhh, sinyalmu, emosi, please, sinya...
# 6                                                   []
# 7         [admin, kembalikan, paket, combo, unlimited]
# 8    [logo, doang, internet, kaya, jaman, megalitik...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, kouta, internet, f...
# 103                                  [harga, tunjukin]
# 104      [kuota, maxtream, skg, akses, netflix, gan, ]
# 105                                                 []
# 106     [min, kuota, lokal, kepake, zona, pendaftaran]
#
# [95 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 453
# ------------------------
# jringannya : jringannya
# gmn : gmn
# knpa : knpa
# smkin : smkin
# kacau : kacau
# jrngan : jrngan
# telkomsel : telkomsel
# refresh : refresh
# msh : msh
# ttp : ttp
#  :
# hadeuhhhhhhhh : hadeuhhhhhhhh
# sinyalmu : sinyal
# emosi : emosi
# please : please
# sinyalnya : sinyal
# benerin : benerin
# admin : admin
# kembalikan : kembali
# paket : paket
# combo : combo
# unlimited : unlimited
# logo : logo
# doang : doang
# internet : internet
# kaya : kaya
# jaman : jaman
# megalitikum : megalitikum
# cek : cek
# udeh : udeh
# sanggup : sanggup
# nanganin : nanganin
# sinyal : sinyal
# ilang : ilang
# mending : mending
# jualan : jual
# deh : deh
# rugi : rugi
# beli : beli
# quota : quota
# ngelaq : ngelaq
# parah : parah
# sumpah : sumpah
# bet : bet
# dahhh : dahhh
# tolong : tolong
# perbaikin : perbaikin
# min : min
# baca : baca
# sikattt : sikattt
# astaga : astaga
# toxic : toxic
# prioritaskan : prioritas
# banget : banget
# euy : euy
# sejarah : sejarah
# indonesia : indonesia
# teknologi : teknologi
# bkalan : bkalan
# mudah : mudah
# canggih : canggih
# asli : asli
# beneran : beneran
# gokil : gokil
# serba : serba
# gampang : gampang
# dlu : dlu
# suka : suka
# adeh : adeh
# iya : iya
# bagus : bagus
# gny : gny
# jagan : jagan
# tinggalin : tinggalin
# pindah : pindah
# gimna : gimna
# komenan : komenan
# kendala : kendala
# paraah : paraah
# kah : kah
# dimana : mana
# signal : signal
# full : full
# trus : trus
# pas : pas
# maen : maen
# game : game
# langsung : langsung
# ping : ping
# merah : merah
# ranked : ranked
# duhh : duhh
# kesel : kesel
# pulsa : pulsa
# gua : gua
# datengg : datengg
# minn : minn
# oalah : oalah
# diaplikasi : aplikasi
# bosan : bosan
# cuman : cuman
# berita : berita
# wujudnya : wujud
# terbatas : batas
# grapari : grapari
# bgm : bgm
# mencoba : coba
# hadeh : hadeh
# udh : udh
# lapor : lapor
# seminggu : minggu
# drop : drop
# browsing : browsing
# aktifin : aktifin
# airplane : airplane
# mode : mode
# normalin : normalin
# maaf : maaf
# penanganan : tangan
# wkwkwk : wkwkwk
# lte : lte
# dibkin : dibkin
# gbps : gbps
# iyah : iyah
# repot : repot
# lounching : lounching
# blm : blm
# utamakan : utama
# kecewaun : kecewaun
# konsumen : konsumen
# ngk : ngk
# jls : jls
# ngarep : ngarep
# kadang : kadang
# miris : miris
# knp : knp
# pemberitahuan : pemberitahuan
# givway : givway
# shoot : shoot
# target : target
# harry : harry
# ken : ken
# kali : kali
# shot : shot
# dewi : dewi
# exotique : exotique
# sok : sok
# fatahillah : fatahillah
# lupa : lupa
# follow : follow
# just : just
# terget : terget
# halo : halo
# sundulan : sundul
# membawa : bawa
# inggris : inggris
# lolos : lolos
# babak : babak
# ayo : ayo
# ikutan : ikut
# guys : guys
# dijamin : jamin
# seru : seru
# arya : arya
# lilis : lil
# enam : enam
# alha : alha
# hadeyyy : hadeyyy
# hay : hay
# jawabannya : jawab
# yuk : yuk
# gaes : gaes
# kuis : kuis
# serunya : seru
# menangkan : menang
# hadiah : hadiah
# menariknya : tarik
# patuhi : patuh
# rulesnya : rulesnya
# jalan : jalan
# pinggir : pinggir
# empang : empang
# nemu : nemu
# katak : katak
# hey : hey
# kawan : kawan
# bimbang : bimbang
# kemari : kemari
# olive : olive
# nazra : nazra
# meriana : meriana
# silva : silva
# gelang : gelang
# rumah : rumah
# lulu : lulu
# karatan : karat
# teman : teman
# galau : galau
# raflipradipta : raflipradipta
# kh : kh
# liaa : liaa
# main : main
# taman : taman
# bareng : bareng
# siti : siti
# sengaja : sengaja
# dijalan : jalan
# ketemu : ketemu
# pitung : pitung
# kak : kak
# hati : hati
# udah : udah
# semoga : moga
# beruntung : untung
# done : done
# like : like
# sosmed : sosmed
# anisa : anisa
# rohmah : rohmah
# share : share
# postingan : postingan
# mention : mention
# disertai : serta
# hastag : hastag
# goal : goal
# kemenangan : menang
# jerman : jerman
# tho : tho
# sukarto : sukarto
# djack : djack
# etriwa : etriwa
# dear : dear
# jawabanyaa : jawabanyaa
# one : one
# hidyt : hidyt
# ha : ha
# egisurya : egisurya
# masak : masak
# ngga : ngga
# dipakek : dipakek
# paketan : paket
# tri : tri
# mohon : mohon
# ketidaknyamanannya : ketidaknyamanannya
# sarankan : saran
# diperiksa : periksa
# miliki : milik
# kejelasannya : jelas
# silakan : sila
# hubungi : hubung
# contact : contact
# center : center
# terima : terima
# kasih : kasih
# bermanfaat : manfaat
# mayoritas : mayoritas
# komplain : komplain
# berkali : kali
# perubahan : ubah
# veronika : veronika
# isi : isi
# form : form
# nama : nama
# alamat : alamat
# dsb : dsb
# gitu : gitu
# smpe : smpe
# skrg : skrg
# perbaikan : baik
# saranin : saranin
# ganti : ganti
# kartu : kartu
# ntar : ntar
# doi : doi
# kehilangan : hilang
# pelanggan : langgan
# kerasa : rasa
# pst : pst
# buru : buru
# layanannya : layan
# ngebantu : ngebantu
# solusi : solusi
# suruh : suruh
# restart : restart
# ulang : ulang
# mulu : mulu
# keluhan : keluh
# arah : arah
# asisten : asisten
# virtual : virtual
# ngapa : ngapa
# provider : provider
# kuota : kuota
# kuotanya : kuota
# aktif : aktif
# daerah : daerah
# kabupaten : kabupaten
# bogor : bogor
# dmn : dmn
# kota : kota
# rusak : rusak
# trims : trims
# sblmnya : sblmnya
# selamat : selamat
# siang : siang
# perihal : perihal
# umkm : umkm
# online : online
# butuh : butuh
# extra : extra
# trimakasih : trimakasih
# assalamualaikum : assalamualaikum
# terkait : kait
# pasca : pasca
# bayar : bayar
# prabayar : prabayar
# anehnya : aneh
# beliau : beliau
# dpt : dpt
# sms : sms
# pembayaran : bayar
# sistemnya : sistem
# pemakaian : pakai
# muncul : muncul
# tagihan : tagih
# salesnya : salesnya
# nawarin : nawarin
# sesuai : sesuai
# pleaseeee : pleaseeee
# nginfoin : nginfoin
# coba : coba
# telp : telp
# call : call
# infonya : info
# ditutup : tutup
# tagihannya : tagih
# orang : orang
# tua : tua
# diwajibkan : wajib
# dtg : dtg
# phone : phone
# bagia : bagia
# nutup : nutup
# dateng : dateng
# sii : sii
# advise : advise
# nalar : nalar
# terooooos : terooooos
# uda : uda
# ciri : ciri
# khas : khas
# napa : napa
# diganti : ganti
# buka : buka
# syaa : syaa
# dri : dri
# pagi : pagi
# jaringannya : jaring
# pke : pke
# smaa : smaa
# ancur : ancur
# mutu : mutu
# bnrn : bnrn
# mempersulit : sulit
# customer : customer
# nntinya : nntinya
# error : error
# kmren : kmren
# youtube : youtube
# dibales : dibales
# data : data
# gimana : gimana
# solusinya : solusi
# habis : habis
# pakai : pakai
# ketenangan : tenang
# sisa : sisa
# kesirup : sirup
# huuuuuu : huuuuuu
# koneksi : koneksi
# stabil : stabil
# mati : mati
# nyala : nyala
# trs : trs
# cape : cape
# veronica : veronica
# tlg : tlg
# donk : donk
# ceritakan : cerita
# pengalaman : alam
# sebulan : bulan
# migrasinya : migrasi
# sihh : sihh
# kog : kog
# ilangan : ilangan
# emg : emg
# kode : kode
# voucher : voucher
# gamesmax : gamesmax
# berlakunya : laku
# emang : emang
# harga : harga
# omg : omg
# naek : naek
# wooyy : wooyy
# meringankan : ringan
# disaat : saat
# kondisi : kondisi
# pandemi : pandemi
# gini : gin
# nyekek : nyekek
# payah : payah
# penghisap : penghisap
# darah : darah
# iflix : iflix
# telkom : telkom
# batas : batas
# multimedia : multimedia
# yutub : yutub
# kaga : kaga
# hallo : hallo
# internetan : internetan
# trimakasi : trimakasi
# setip : setip
# harganya : harga
# males : males
# dibatasin : dibatasin
# respon : respon
# fan : fan
# kerjasama : kerjasama
# netflix : netflix
# aplikasi : aplikasi
# bls : bls
# kondisikan : kondisi
# tas : tas
# terjangkau : jangkau
# lancaran : lancar
# kayak : kayak
# lancar : lancar
# saran : saran
# perbaiki : baik
# kouta : kouta
# nonton : nonton
# jam : jam
# tunjukin : tunjukin
# maxtream : maxtream
# skg : skg
# akses : akses
# gan : gan
# lokal : lokal
# kepake : kepake
# zona : zona
# pendaftaran : daftar
# {'jringannya': 'jringannya', 'gmn': 'gmn', 'knpa': 'knpa', 'smkin': 'smkin', 'kacau': 'kacau', 'jrngan': 'jrngan', 'telkomsel': 'telkomsel', 'refresh': 'refresh', 'msh': 'msh', 'ttp': 'ttp', '': '', 'hadeuhhhhhhhh': 'hadeuhhhhhhhh', 'sinyalmu': 'sinyal', 'emosi': 'emosi', 'please': 'please', 'sinyalnya': 'sinyal', 'benerin': 'benerin', 'admin': 'admin', 'kembalikan': 'kembali', 'paket': 'paket', 'combo': 'combo', 'unlimited': 'unlimited', 'logo': 'logo', 'doang': 'doang', 'internet': 'internet', 'kaya': 'kaya', 'jaman': 'jaman', 'megalitikum': 'megalitikum', 'cek': 'cek', 'udeh': 'udeh', 'sanggup': 'sanggup', 'nanganin': 'nanganin', 'sinyal': 'sinyal', 'ilang': 'ilang', 'mending': 'mending', 'jualan': 'jual', 'deh': 'deh', 'rugi': 'rugi', 'beli': 'beli', 'quota': 'quota', 'ngelaq': 'ngelaq', 'parah': 'parah', 'sumpah': 'sumpah', 'bet': 'bet', 'dahhh': 'dahhh', 'tolong': 'tolong', 'perbaikin': 'perbaikin', 'min': 'min', 'baca': 'baca', 'sikattt': 'sikattt', 'astaga': 'astaga', 'toxic': 'toxic', 'prioritaskan': 'prioritas', 'banget': 'banget', 'euy': 'euy', 'sejarah': 'sejarah', 'indonesia': 'indonesia', 'teknologi': 'teknologi', 'bkalan': 'bkalan', 'mudah': 'mudah', 'canggih': 'canggih', 'asli': 'asli', 'beneran': 'beneran', 'gokil': 'gokil', 'serba': 'serba', 'gampang': 'gampang', 'dlu': 'dlu', 'suka': 'suka', 'adeh': 'adeh', 'iya': 'iya', 'bagus': 'bagus', 'gny': 'gny', 'jagan': 'jagan', 'tinggalin': 'tinggalin', 'pindah': 'pindah', 'gimna': 'gimna', 'komenan': 'komenan', 'kendala': 'kendala', 'paraah': 'paraah', 'kah': 'kah', 'dimana': 'mana', 'signal': 'signal', 'full': 'full', 'trus': 'trus', 'pas': 'pas', 'maen': 'maen', 'game': 'game', 'langsung': 'langsung', 'ping': 'ping', 'merah': 'merah', 'ranked': 'ranked', 'duhh': 'duhh', 'kesel': 'kesel', 'pulsa': 'pulsa', 'gua': 'gua', 'datengg': 'datengg', 'minn': 'minn', 'oalah': 'oalah', 'diaplikasi': 'aplikasi', 'bosan': 'bosan', 'cuman': 'cuman', 'berita': 'berita', 'wujudnya': 'wujud', 'terbatas': 'batas', 'grapari': 'grapari', 'bgm': 'bgm', 'mencoba': 'coba', 'hadeh': 'hadeh', 'udh': 'udh', 'lapor': 'lapor', 'seminggu': 'minggu', 'drop': 'drop', 'browsing': 'browsing', 'aktifin': 'aktifin', 'airplane': 'airplane', 'mode': 'mode', 'normalin': 'normalin', 'maaf': 'maaf', 'penanganan': 'tangan', 'wkwkwk': 'wkwkwk', 'lte': 'lte', 'dibkin': 'dibkin', 'gbps': 'gbps', 'iyah': 'iyah', 'repot': 'repot', 'lounching': 'lounching', 'blm': 'blm', 'utamakan': 'utama', 'kecewaun': 'kecewaun', 'konsumen': 'konsumen', 'ngk': 'ngk', 'jls': 'jls', 'ngarep': 'ngarep', 'kadang': 'kadang', 'miris': 'miris', 'knp': 'knp', 'pemberitahuan': 'pemberitahuan', 'givway': 'givway', 'shoot': 'shoot', 'target': 'target', 'harry': 'harry', 'ken': 'ken', 'kali': 'kali', 'shot': 'shot', 'dewi': 'dewi', 'exotique': 'exotique', 'sok': 'sok', 'fatahillah': 'fatahillah', 'lupa': 'lupa', 'follow': 'follow', 'just': 'just', 'terget': 'terget', 'halo': 'halo', 'sundulan': 'sundul', 'membawa': 'bawa', 'inggris': 'inggris', 'lolos': 'lolos', 'babak': 'babak', 'ayo': 'ayo', 'ikutan': 'ikut', 'guys': 'guys', 'dijamin': 'jamin', 'seru': 'seru', 'arya': 'arya', 'lilis': 'lil', 'enam': 'enam', 'alha': 'alha', 'hadeyyy': 'hadeyyy', 'hay': 'hay', 'jawabannya': 'jawab', 'yuk': 'yuk', 'gaes': 'gaes', 'kuis': 'kuis', 'serunya': 'seru', 'menangkan': 'menang', 'hadiah': 'hadiah', 'menariknya': 'tarik', 'patuhi': 'patuh', 'rulesnya': 'rulesnya', 'jalan': 'jalan', 'pinggir': 'pinggir', 'empang': 'empang', 'nemu': 'nemu', 'katak': 'katak', 'hey': 'hey', 'kawan': 'kawan', 'bimbang': 'bimbang', 'kemari': 'kemari', 'olive': 'olive', 'nazra': 'nazra', 'meriana': 'meriana', 'silva': 'silva', 'gelang': 'gelang', 'rumah': 'rumah', 'lulu': 'lulu', 'karatan': 'karat', 'teman': 'teman', 'galau': 'galau', 'raflipradipta': 'raflipradipta', 'kh': 'kh', 'liaa': 'liaa', 'main': 'main', 'taman': 'taman', 'bareng': 'bareng', 'siti': 'siti', 'sengaja': 'sengaja', 'dijalan': 'jalan', 'ketemu': 'ketemu', 'pitung': 'pitung', 'kak': 'kak', 'hati': 'hat ...
# ------------------------
# Pandas Apply:   0%|          | 0/95 [00:00<?, ?it/s]
#                                                   text  \
# 0    jringannya gmn ini.. knpa smkin lama smkin kac...
# 1    hadeuhhhhhhhh @telkomsel sinyalmu bikin emosi....
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru,, internet dah kaya jaman mega...
# ..                                                 ...
# 102  admin omg kouta nonton gk bisa di pake kouta i...
# 103                            harga nya tunjukin dong
# 104  kuota maxtream skg ga bisa buat akses netflix ...
# 105                                                NaN
# 106  min kuota lokal ga bisa kepake, padahal aku ga...
#
#                                          cleaning_text  \
# 0    jringannya gmn ini knpa smkin lama smkin kacau...
# 1    hadeuhhhhhhhh sinyalmu bikin emosi please siny...
# 6                                                 bagi
# 7           admin kembalikan paket combo unlimited nya
# 8    logo doang baru internet dah kaya jaman megali...
# ..                                                 ...
# 102  admin omg kouta nonton bisa pake kouta interne...
# 103                            harga nya tunjukin dong
# 104    kuota maxtream skg bisa buat akses netflix gan
# 105                                                nan
# 106  min kuota lokal bisa kepake padahal aku keluar...
#
#                                             tokenisasi  \
# 0    [jringannya, gmn, ini, knpa, smkin, lama, smki...
# 1    [hadeuhhhhhhhh, sinyalmu, bikin, emosi, please...
# 6                                               [bagi]
# 7    [admin, kembalikan, paket, combo, unlimited, nya]
# 8    [logo, doang, baru, internet, dah, kaya, jaman...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, bisa, pake, kouta,...
# 103                       [harga, nya, tunjukin, dong]
# 104  [kuota, maxtream, skg, bisa, buat, akses, netf...
# 105                                              [nan]
# 106  [min, kuota, lokal, bisa, kepake, padahal, aku...
#
#                                               stopword  \
# 0    [jringannya, gmn, knpa, smkin, smkin, kacau, j...
# 1    [hadeuhhhhhhhh, sinyalmu, emosi, please, sinya...
# 6                                                   []
# 7         [admin, kembalikan, paket, combo, unlimited]
# 8    [logo, doang, internet, kaya, jaman, megalitik...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, kouta, internet, f...
# 103                                  [harga, tunjukin]
# 104      [kuota, maxtream, skg, akses, netflix, gan, ]
# 105                                                 []
# 106     [min, kuota, lokal, kepake, zona, pendaftaran]
#
#                                               stemming
# 0    [jringannya, gmn, knpa, smkin, smkin, kacau, j...
# 1    [hadeuhhhhhhhh, sinyal, emosi, please, sinyal,...
# 6                                                   []
# 7            [admin, kembali, paket, combo, unlimited]
# 8    [logo, doang, internet, kaya, jaman, megalitik...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, kouta, internet, f...
# 103                                  [harga, tunjukin]
# 104      [kuota, maxtream, skg, akses, netflix, gan, ]
# 105                                                 []
# 106          [min, kuota, lokal, kepake, zona, daftar]
#
# [95 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [jringannya, gmn, knpa, smkin, smkin, kacau, j...
# 1    [hadeuhhhhhhhh, sinyal, emosi, please, sinyal,...
# 6                                                   []
# 7            [admin, kembali, paket, combo, unlimited]
# 8    [logo, doang, internet, kaya, jaman, megalitik...
# ..                                                 ...
# 102  [admin, omg, kouta, nonton, kouta, internet, f...
# 103                                  [harga, tunjukin]
# 104      [kuota, maxtream, skg, akses, netflix, gan, ]
# 105                                                 []
# 106          [min, kuota, lokal, kepake, zona, daftar]
#
# [95 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_6.xlsx')
