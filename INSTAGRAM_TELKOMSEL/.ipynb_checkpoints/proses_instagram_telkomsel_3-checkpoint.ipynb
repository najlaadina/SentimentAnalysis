# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                       Telkomsel No.1
# 1                                               Gabung
# 2    Daftar paket ini, baru sehari pake udah gak bi...
# 3    Min Saya Menang HP Iphone 11 Giveaway Hari Ter...
# 4    Alah setiap ada komplain malah di suruh telpon...
# ..                                                 ...
# 169                                         Cek dm min
# 170                       Ancurrr system sibuk... Zzzz
# 171            Gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 Sinyal mana sinyal
# 173  Kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
# [174 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 1                                               Gabung
# 2    Daftar paket ini, baru sehari pake udah gak bi...
# 3    Min Saya Menang HP Iphone 11 Giveaway Hari Ter...
# 4    Alah setiap ada komplain malah di suruh telpon...
# 5                                         Sinyal busuk
# ..                                                 ...
# 168                                         Sinyal woe
# 170                       Ancurrr system sibuk... Zzzz
# 171            Gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 Sinyal mana sinyal
# 173  Kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
# [137 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 1                                               gabung
# 2    daftar paket ini, baru sehari pake udah gak bi...
# 3    min saya menang hp iphone 11 giveaway hari ter...
# 4    alah setiap ada komplain malah di suruh telpon...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                       ancurrr system sibuk... zzzz
# 171            gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 sinyal mana sinyal
# 173  kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
# [137 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 1                                               gabung
# 2    daftar paket ini, baru sehari pake udah gak bi...
# 3    min saya menang hp iphone 11 giveaway hari ter...
# 4    alah setiap ada komplain malah di suruh telpon...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                       ancurrr system sibuk... zzzz
# 171            gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 sinyal mana sinyal
# 173  kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
#                                          cleaning_text
# 1                                               gabung
# 2    daftar paket ini baru sehari pake udah gak bis...
# 3    min saya menang iphone giveaway hari terakhir ...
# 4    alah setiap ada komplain malah suruh telpon ve...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                          ancurrr system sibuk zzzz
# 171               gilaaa sinya lemott nmpe skrnggg fck
# 172                                 sinyal mana sinyal
# 173   kartu bisa dftrin kuota darurat gmna min solusi
#
# [137 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 1                                               gabung
# 2    daftar paket ini, baru sehari pake udah gak bi...
# 3    min saya menang hp iphone 11 giveaway hari ter...
# 4    alah setiap ada komplain malah di suruh telpon...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                       ancurrr system sibuk... zzzz
# 171            gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 sinyal mana sinyal
# 173  kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
#                                          cleaning_text  \
# 1                                               gabung
# 2    daftar paket ini baru sehari pake udah gak bis...
# 3    min saya menang iphone giveaway hari terakhir ...
# 4    alah setiap ada komplain malah suruh telpon ve...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                          ancurrr system sibuk zzzz
# 171               gilaaa sinya lemott nmpe skrnggg fck
# 172                                 sinyal mana sinyal
# 173   kartu bisa dftrin kuota darurat gmna min solusi
#
#                                             tokenisasi
# 1                                             [gabung]
# 2    [daftar, paket, ini, baru, sehari, pake, udah,...
# 3    [min, saya, menang, iphone, giveaway, hari, te...
# 4    [alah, setiap, ada, komplain, malah, suruh, te...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                             [sinyal, mana, sinyal]
# 173  [kartu, bisa, dftrin, kuota, darurat, gmna, mi...
#
# [137 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 1                                               gabung
# 2    daftar paket ini, baru sehari pake udah gak bi...
# 3    min saya menang hp iphone 11 giveaway hari ter...
# 4    alah setiap ada komplain malah di suruh telpon...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                       ancurrr system sibuk... zzzz
# 171            gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 sinyal mana sinyal
# 173  kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
#                                          cleaning_text  \
# 1                                               gabung
# 2    daftar paket ini baru sehari pake udah gak bis...
# 3    min saya menang iphone giveaway hari terakhir ...
# 4    alah setiap ada komplain malah suruh telpon ve...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                          ancurrr system sibuk zzzz
# 171               gilaaa sinya lemott nmpe skrnggg fck
# 172                                 sinyal mana sinyal
# 173   kartu bisa dftrin kuota darurat gmna min solusi
#
#                                             tokenisasi  \
# 1                                             [gabung]
# 2    [daftar, paket, ini, baru, sehari, pake, udah,...
# 3    [min, saya, menang, iphone, giveaway, hari, te...
# 4    [alah, setiap, ada, komplain, malah, suruh, te...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                             [sinyal, mana, sinyal]
# 173  [kartu, bisa, dftrin, kuota, darurat, gmna, mi...
#
#                                               stopword
# 1                                             [gabung]
# 2    [daftar, paket, sehari, udah, dipake, kuota, n...
# 3    [min, menang, iphone, giveaway, seminggu, penu...
# 4    [alah, komplain, suruh, telpon, veronikaa, woy...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                                   [sinyal, sinyal]
# 173  [kartu, dftrin, kuota, darurat, gmna, min, sol...
#
# [137 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 440
# ------------------------
# gabung : gabung
# daftar : daftar
# paket : paket
# sehari : hari
# udah : udah
# dipake : dipake
# kuota : kuota
# nelfonnya : nelfonnya
# banyakk : banyakk
# min : min
#  :
# menang : menang
# iphone : iphone
# giveaway : giveaway
# seminggu : minggu
# penuh : penuh
# taggal : taggal
# desember : desember
# foto : foto
# ktp : ktp
# data : data
# kirim : kirim
# hadiah : hadiah
# dikirim : kirim
# alah : alah
# komplain : komplain
# suruh : suruh
# telpon : telpon
# veronikaa : veronikaa
# woyy : woyy
# robottt : robottt
# manusia : manusia
# butuh : butuh
# sinyal : sinyal
# stabil : stabil
# nelpon : nelpon
# robot : robot
# macemmm : macemmm
# bangkruttt : bangkruttt
# biarr : biarr
# ain : ain
# skliannn : skliannn
# busuk : busuk
# udh : udh
# bln : bln
# parah : parah
# kaya : kaya
# goa : goa
# gimana : gimana
# kelanjutannya : lanjut
# plis : plis
# kasih : kasih
# promo : promo
# tuker : tuker
# poin : poin
# mytelkomsel : mytelkomsel
# saldo : saldo
# linkaja : linkaja
# kode : kode
# aktifkan : aktif
# gratis : gratis
# bantu : bantu
# follow : follow
# kurakurachannel : kurakurachannel
# terimakasih : terimakasih
# telkomsel : telkomsel
# gajelas : gajelas
# jaringannya : jaring
# rank : rank
# tusun : tusun
# teruss : teruss
# kredit : kredit
# skor : skor
# bais : bais
# guys : guys
# huh : huh
# mohon : mohon
# cek : cek
# cinta : cinta
# orang : orang
# puter : puter
# bsa : bsa
# donlot : donlot
# wlu : wlu
# langganan : langgan
# naksir : naksir
# pulsa : pulsa
# suka : suka
# menarik : tarik
# nomer : nomer
# terblokir : blokir
# donk : donk
# film : film
# india : india
# bedion : bedion
# yaaa : yaaa
# single : single
# happy : happy
# dooonk : dooonk
# males : males
# telkom : telkom
# ngelag : ngelag
# banget : banget
# sip : sip
# memudahkan : mudah
# beli : beli
# lumayan : lumayan
# chat : chat
# kepakai : pakai
# pulsanya : pulsa
# kuaota : kuaota
# chatnya : chatnya
# pakai : pakai
# tolong : tolong
# dirugikan : rugi
# memiliki : milik
# tsel : tsel
# sms : sms
# berlaku : laku
# pkl : pkl
# mnt : mnt
# internet : internet
# info : info
# donlod : donlod
# mb : mb
# bli : bli
# kota : kota
# hadeh : hadeh
# blm : blm
# kau : kau
# ajing : ajing
# rb : rb
# cashback : cashback
# taek : taek
# please : please
# kartu : kartu
# nomornya : nomor
# whatsapp : whatsapp
# pertanyaannya : tanya
# urus : urus
# grapari : grapari
# perbaiki : baik
# protes : protes
# bullshit : bullshit
# membohongi : bohong
# signal : signal
# kmpung : kmpung
# veronika : veronika
# gitu : gitu
# pecat : pecat
# doi : doi
# hidupnya : hidup
# berguna : guna
# kak : kak
# adain : adain
# rakyat : rakyat
# sprtiku : sprtiku
# mulu : mulu
# nambahin : nambahin
# aktif : aktif
# gmna : gmna
# isi : isi
# nambah : nambah
# ngak : ngak
# dapet : dapet
# admin : admin
# bahasa : bahasa
# pusinggggg : pusinggggg
# jawanya : jawanya
# ngapusi : ngapusi
# putang : putang
# ina : ina
# hedehh : hedehh
# skrang : skrang
# kura : kura
# lemotnya : lot
# bnyak : bnyak
# mubazirnya : mubazir
# nggak : nggak
# kepake : kepake
# krna : krna
# capek : capek
# divisi : divisi
# perkontenannya : konten
# mumet : mumet
# mimin : mimin
# teu : teu
# lucu : lucu
# siah : siah
# laina : laina
# benerkeun : benerkeun
# maneh : maneh
# teh : teh
# elah : elah
# ngutip : ngutip
# lord : lord
# youtube : youtube
# kadang : kadang
# muter : muter
# belajar : ajar
# utama : utama
# gopud : gopud
# teroooooss : teroooooss
# syopi : syopi
# terooooooss : terooooooss
# kabar : kabar
# hedeeeh : hedeeeh
# makan : makan
# what : what
# you : you
# want : want
# eat : eat
# terserah : serah
# uwang : uwang
# sayang : sayang
# terbuang : buang
# berteman : teman
# berat : berat
# sebelah : belah
# tekor : tekor
# mencoba : coba
# melucu : lucu
# tpi : tpi
# trnyata : trnyata
# garing : garing
# berapaan : berapa
# sinyalnya : sinyal
# abis : abis
# ngeleg : ngeleg
# ngelegmasa : ngelegmasa
# main : main
# mobile : mobile
# legen : legen
# pas : pas
# ilang : ilang
# gue : gue
# pindah : pindah
# tbk : tbk
# bagus : bagus
# kacau : kacau
# better : better
# pemerataan : perata
# lte : lte
# indonesia : indonesia
# msh : msh
# daerah : daerah
# merasakan : rasa
# alangkah : alangkah
# baiknya : baik
# warga : warga
# belanti : belanti
# siam : siam
# respon : respon
# trima : trima
# diratakan : rata
# bar : bar
# rendah : rendah
# bot : bot
# tolonglah : tolong
# kualitas : kualitas
# gedung : gedung
# pengguna : guna
# provider : provider
# kenceng : kenceng
# doang : doang
# pln : pln
# mati : mati
# daring : daring
# gara : gara
# hallo : hallo
# sinyale : sinyale
# buruk : buruk
# malam : malam
# lambat : lambat
# setuju : tuju
# seneng : neng
# nian : nian
# give : give
# away : away
# suara : suara
# motor : motor
# racing : racing
# sumpah : sumpah
# auto : auto
# nyebutin : nyebutin
# nama : nama
# hewan : hewan
# kebun : kebun
# binatang : binatang
# meeeoong : meeeoong
# maaf : maaf
# habis : habis
# panggilan : panggil
# normal : normal
# kembalinya : kembali
# dibaca : baca
# parabot : parabot
# rumah : rumah
# tangga : tangga
# kesel : kesel
# sampe : sampe
# toanya : toanya
# kekerasan : keras
# baca : baca
# negeri : negeri
# urgent : urgent
# keperluan : perlu
# bni : bni
# anak : anak
# nangis : nang
# bakpauu : bakpauu
# ayam : ayam
# berkokok : kokok
# suaraa : suaraa
# adek : adek
# nyanyi : nyanyi
# ganggu : ganggu
# tukang : tukang
# bakso : bakso
# ting : ting
# peuyeum : peuyeum
# hubungi : hubung
# vero : vero
# nawarin : nawarin
# trus : trus
# ngasih : ngasih
# solusi : solusi
# gambar : gambar
# gambarnya : gambar
# dizoom : dizoom
# kebaca : baca
# jarak : jarak
# bts : bts
# deket : deket
# kilo : kilo
# selamat : selamat
# siang : siang
# bantuan : bantu
# permasalahan : masalah
# masuk : masuk
# aplikasi : aplikasi
# keluhan : keluh
# pelanggan : langgan
# wa : wa
# dst : dst
# dichat : dichat
# jawabannya : jawab
# ndak : ndak
# nyambung : nyambung
# berkelit : kelit
# motonya : moto
# hujan : hujan
# hilaaaaaang : hilaaaaaang
# stabilkan : stabil
# dlu : dlu
# rembang : rembang
# jawa : jawa
# cpet : cpet
# panas : panas
# diperbaikin : diperbaikin
# kembaliin : kembaliin
# kek : kek
# kemana : mana
# lancar : lancar
# internetan : internetan
# jaringanya : jaringanya
# kalah : kalah
# sma : sma
# kelas : kelas
# th : th
# kesini : kesini
# jringanya : jringanya
# bismillah : bismillah
# wifi : wifi
# indihome : indihome
# fiber : fiber
# speed : speed
# mbps : mbps
# telfon : telfon
# skrg : skrg
# langsung : langsung
# pasang : pasang
# veronica : veronica
# benerin : benerin
# hncur : hncur
# push : push
# buriq : buriq
# burik : burik
# beneriiinnnn : beneriiinnnn
# weeiiii : weeiiii
# bagusin : bagusin
# game : game
# sesuka : suka
# bejibun : bejibun
# ngakak : ngakak
# mantap : mantap
# engga : engga
# siaap : siaap
# mkasih : mkasih
# membantu : bantu
# verigikasi : verigikasi
# knp : knp
# gaberubah : gaberubah
# hai : hai
# berbagi : bagi
# hbs : hbs
# ulang : ulang
# pdhl : pdhl
# jug : jug
# ngilang : ngilang
# jarigan : jarigan
# beralih : alih
# omg : omg
# combo : combo
# sakti : sakti
# yaa : yaa
# adil : adil
# gopay : gopay
# tts : tts
# asah : asah
# otak : otak
# pngumuman : pngumuman
# januari : januari
# pemenang : menang
# kecewain : kecewain
# kmi : kmi
# woe : woe
# woy : woy
# ancurrr : ancurrr
# system : system
# sibuk : sibuk
# zzzz : zzzz
# gilaaa : gilaaa
# sinya : sinya
# lemott : lemott
# nmpe : nmpe
# skrnggg : skrnggg
# fck : fck
# dftrin : dftrin
# darurat : darurat
# {'gabung': 'gabung', 'daftar': 'daftar', 'paket': 'paket', 'sehari': 'hari', 'udah': 'udah', 'dipake': 'dipake', 'kuota': 'kuota', 'nelfonnya': 'nelfonnya', 'banyakk': 'banyakk', 'min': 'min', '': '', 'menang': 'menang', 'iphone': 'iphone', 'giveaway': 'giveaway', 'seminggu': 'minggu', 'penuh': 'penuh', 'taggal': 'taggal', 'desember': 'desember', 'foto': 'foto', 'ktp': 'ktp', 'data': 'data', 'kirim': 'kirim', 'hadiah': 'hadiah', 'dikirim': 'kirim', 'alah': 'alah', 'komplain': 'komplain', 'suruh': 'suruh', 'telpon': 'telpon', 'veronikaa': 'veronikaa', 'woyy': 'woyy', 'robottt': 'robottt', 'manusia': 'manusia', 'butuh': 'butuh', 'sinyal': 'sinyal', 'stabil': 'stabil', 'nelpon': 'nelpon', 'robot': 'robot', 'macemmm': 'macemmm', 'bangkruttt': 'bangkruttt', 'biarr': 'biarr', 'ain': 'ain', 'skliannn': 'skliannn', 'busuk': 'busuk', 'udh': 'udh', 'bln': 'bln', 'parah': 'parah', 'kaya': 'kaya', 'goa': 'goa', 'gimana': 'gimana', 'kelanjutannya': 'lanjut', 'plis': 'plis', 'kasih': 'kasih', 'promo': 'promo', 'tuker': 'tuker', 'poin': 'poin', 'mytelkomsel': 'mytelkomsel', 'saldo': 'saldo', 'linkaja': 'linkaja', 'kode': 'kode', 'aktifkan': 'aktif', 'gratis': 'gratis', 'bantu': 'bantu', 'follow': 'follow', 'kurakurachannel': 'kurakurachannel', 'terimakasih': 'terimakasih', 'telkomsel': 'telkomsel', 'gajelas': 'gajelas', 'jaringannya': 'jaring', 'rank': 'rank', 'tusun': 'tusun', 'teruss': 'teruss', 'kredit': 'kredit', 'skor': 'skor', 'bais': 'bais', 'guys': 'guys', 'huh': 'huh', 'mohon': 'mohon', 'cek': 'cek', 'cinta': 'cinta', 'orang': 'orang', 'puter': 'puter', 'bsa': 'bsa', 'donlot': 'donlot', 'wlu': 'wlu', 'langganan': 'langgan', 'naksir': 'naksir', 'pulsa': 'pulsa', 'suka': 'suka', 'menarik': 'tarik', 'nomer': 'nomer', 'terblokir': 'blokir', 'donk': 'donk', 'film': 'film', 'india': 'india', 'bedion': 'bedion', 'yaaa': 'yaaa', 'single': 'single', 'happy': 'happy', 'dooonk': 'dooonk', 'males': 'males', 'telkom': 'telkom', 'ngelag': 'ngelag', 'banget': 'banget', 'sip': 'sip', 'memudahkan': 'mudah', 'beli': 'beli', 'lumayan': 'lumayan', 'chat': 'chat', 'kepakai': 'pakai', 'pulsanya': 'pulsa', 'kuaota': 'kuaota', 'chatnya': 'chatnya', 'pakai': 'pakai', 'tolong': 'tolong', 'dirugikan': 'rugi', 'memiliki': 'milik', 'tsel': 'tsel', 'sms': 'sms', 'berlaku': 'laku', 'pkl': 'pkl', 'mnt': 'mnt', 'internet': 'internet', 'info': 'info', 'donlod': 'donlod', 'mb': 'mb', 'bli': 'bli', 'kota': 'kota', 'hadeh': 'hadeh', 'blm': 'blm', 'kau': 'kau', 'ajing': 'ajing', 'rb': 'rb', 'cashback': 'cashback', 'taek': 'taek', 'please': 'please', 'kartu': 'kartu', 'nomornya': 'nomor', 'whatsapp': 'whatsapp', 'pertanyaannya': 'tanya', 'urus': 'urus', 'grapari': 'grapari', 'perbaiki': 'baik', 'protes': 'protes', 'bullshit': 'bullshit', 'membohongi': 'bohong', 'signal': 'signal', 'kmpung': 'kmpung', 'veronika': 'veronika', 'gitu': 'gitu', 'pecat': 'pecat', 'doi': 'doi', 'hidupnya': 'hidup', 'berguna': 'guna', 'kak': 'kak', 'adain': 'adain', 'rakyat': 'rakyat', 'sprtiku': 'sprtiku', 'mulu': 'mulu', 'nambahin': 'nambahin', 'aktif': 'aktif', 'gmna': 'gmna', 'isi': 'isi', 'nambah': 'nambah', 'ngak': 'ngak', 'dapet': 'dapet', 'admin': 'admin', 'bahasa': 'bahasa', 'pusinggggg': 'pusinggggg', 'jawanya': 'jawanya', 'ngapusi': 'ngapusi', 'putang': 'putang', 'ina': 'ina', 'hedehh': 'hedehh', 'skrang': 'skrang', 'kura': 'kura', 'lemotnya': 'lot', 'bnyak': 'bnyak', 'mubazirnya': 'mubazir', 'nggak': 'nggak', 'kepake': 'kepake', 'krna': 'krna', 'capek': 'capek', 'divisi': 'divisi', 'perkontenannya': 'konten', 'mumet': 'mumet', 'mimin': 'mimin', 'teu': 'teu', 'lucu': 'lucu', 'siah': 'siah', 'laina': 'laina', 'benerkeun': 'benerkeun', 'maneh': 'maneh', 'teh': 'teh', 'elah': 'elah', 'ngutip': 'ngutip', 'lord': 'lord', 'youtube': 'youtube', 'kadang': 'kadang', 'muter': 'muter', 'belajar': 'ajar', 'utama': 'utama', 'gopud': 'gopud', 'teroooooss': 'teroooooss', 'syopi': 'syopi', 'terooooooss': 'terooooooss', 'kabar': 'kabar', 'hedeeeh': 'hedeeeh', 'makan': 'makan', 'what': 'what', 'you': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/137 [00:00<?, ?it/s]
#                                                   text  \
# 1                                               gabung
# 2    daftar paket ini, baru sehari pake udah gak bi...
# 3    min saya menang hp iphone 11 giveaway hari ter...
# 4    alah setiap ada komplain malah di suruh telpon...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                       ancurrr system sibuk... zzzz
# 171            gilaaa sinya lemott nmpe 3g skrnggg fck
# 172                                 sinyal mana sinyal
# 173  kartu ku gk bisa di  dftrin ke  kuota darurat ...
#
#                                          cleaning_text  \
# 1                                               gabung
# 2    daftar paket ini baru sehari pake udah gak bis...
# 3    min saya menang iphone giveaway hari terakhir ...
# 4    alah setiap ada komplain malah suruh telpon ve...
# 5                                         sinyal busuk
# ..                                                 ...
# 168                                         sinyal woe
# 170                          ancurrr system sibuk zzzz
# 171               gilaaa sinya lemott nmpe skrnggg fck
# 172                                 sinyal mana sinyal
# 173   kartu bisa dftrin kuota darurat gmna min solusi
#
#                                             tokenisasi  \
# 1                                             [gabung]
# 2    [daftar, paket, ini, baru, sehari, pake, udah,...
# 3    [min, saya, menang, iphone, giveaway, hari, te...
# 4    [alah, setiap, ada, komplain, malah, suruh, te...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                             [sinyal, mana, sinyal]
# 173  [kartu, bisa, dftrin, kuota, darurat, gmna, mi...
#
#                                               stopword  \
# 1                                             [gabung]
# 2    [daftar, paket, sehari, udah, dipake, kuota, n...
# 3    [min, menang, iphone, giveaway, seminggu, penu...
# 4    [alah, komplain, suruh, telpon, veronikaa, woy...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                                   [sinyal, sinyal]
# 173  [kartu, dftrin, kuota, darurat, gmna, min, sol...
#
#                                               stemming
# 1                                             [gabung]
# 2    [daftar, paket, hari, udah, dipake, kuota, nel...
# 3    [min, menang, iphone, giveaway, minggu, penuh,...
# 4    [alah, komplain, suruh, telpon, veronikaa, woy...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                                   [sinyal, sinyal]
# 173  [kartu, dftrin, kuota, darurat, gmna, min, sol...
#
# [137 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 1                                             [gabung]
# 2    [daftar, paket, hari, udah, dipake, kuota, nel...
# 3    [min, menang, iphone, giveaway, minggu, penuh,...
# 4    [alah, komplain, suruh, telpon, veronikaa, woy...
# 5                                      [sinyal, busuk]
# ..                                                 ...
# 168                                      [sinyal, woe]
# 170                     [ancurrr, system, sibuk, zzzz]
# 171        [gilaaa, sinya, lemott, nmpe, skrnggg, fck]
# 172                                   [sinyal, sinyal]
# 173  [kartu, dftrin, kuota, darurat, gmna, min, sol...
#
# [137 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_3.xlsx')
