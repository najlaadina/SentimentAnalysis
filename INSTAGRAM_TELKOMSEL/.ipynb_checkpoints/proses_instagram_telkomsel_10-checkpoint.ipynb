# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                                  :((
# 1    Min @telkomsel Institut Teknologi Surabaya ata...
# 2                   Ngomong2 gua orang Sumenep nih min
# 3           Saya ingin di desa saya koneksinya kencang
# 4    Sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 123                                     ❤️❤️❤️❤️❤️❤️❤️
# 124  Hidup anda sering sial dan sakit2an? Pasti str...
# 125  Pak Jokowi tolong segera ganti nama Indonesia ...
# 126  Pak Jokowi kalau negara masih mau selamat tolo...
#
# [127 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 11

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                                  :((
# 1    Min @telkomsel Institut Teknologi Surabaya ata...
# 2                   Ngomong2 gua orang Sumenep nih min
# 3           Saya ingin di desa saya koneksinya kencang
# 4    Sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 121  Yth @telkomsel saya mau meminta penjelasan ter...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 124  Hidup anda sering sial dan sakit2an? Pasti str...
# 125  Pak Jokowi tolong segera ganti nama Indonesia ...
# 126  Pak Jokowi kalau negara masih mau selamat tolo...
#
# [109 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                                  :((
# 1    min @telkomsel institut teknologi surabaya ata...
# 2                   ngomong2 gua orang sumenep nih min
# 3           saya ingin di desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 121  yth @telkomsel saya mau meminta penjelasan ter...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 124  hidup anda sering sial dan sakit2an? pasti str...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
# [109 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                                  :((
# 1    min @telkomsel institut teknologi surabaya ata...
# 2                   ngomong2 gua orang sumenep nih min
# 3           saya ingin di desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 121  yth @telkomsel saya mau meminta penjelasan ter...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 124  hidup anda sering sial dan sakit2an? pasti str...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                          cleaning_text
# 0
# 1    min institut teknologi surabaya atau institut ...
# 2                   ngomong  gua orang sumenep nih min
# 3              saya ingin desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk bikinin tower dong ds...
# ..                                                 ...
# 121  yth saya mau meminta penjelasan terkait koneks...
# 122           min buka jgn php dong dari kemarin juga
# 124  hidup anda sering sial dan sakit an pasti stru...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
# [109 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                                  :((
# 1    min @telkomsel institut teknologi surabaya ata...
# 2                   ngomong2 gua orang sumenep nih min
# 3           saya ingin di desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 121  yth @telkomsel saya mau meminta penjelasan ter...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 124  hidup anda sering sial dan sakit2an? pasti str...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                          cleaning_text  \
# 0
# 1    min institut teknologi surabaya atau institut ...
# 2                   ngomong  gua orang sumenep nih min
# 3              saya ingin desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk bikinin tower dong ds...
# ..                                                 ...
# 121  yth saya mau meminta penjelasan terkait koneks...
# 122           min buka jgn php dong dari kemarin juga
# 124  hidup anda sering sial dan sakit an pasti stru...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                             tokenisasi
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, atau, ins...
# 2             [ngomong, gua, orang, sumenep, nih, min]
# 3       [saya, ingin, desa, saya, koneksinya, kencang]
# 4    [sinyalmu, urusin, taeeekkk, bikinin, tower, d...
# ..                                                 ...
# 121  [yth, saya, mau, meminta, penjelasan, terkait,...
# 122  [min, buka, jgn, php, dong, dari, kemarin, jug...
# 124  [hidup, anda, sering, sial, dan, sakit, an, pa...
# 125  [pak, jokowi, tolong, segera, ganti, nama, ind...
# 126  [pak, jokowi, kalau, negara, masih, mau, selam...
#
# [109 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                                  :((
# 1    min @telkomsel institut teknologi surabaya ata...
# 2                   ngomong2 gua orang sumenep nih min
# 3           saya ingin di desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 121  yth @telkomsel saya mau meminta penjelasan ter...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 124  hidup anda sering sial dan sakit2an? pasti str...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                          cleaning_text  \
# 0
# 1    min institut teknologi surabaya atau institut ...
# 2                   ngomong  gua orang sumenep nih min
# 3              saya ingin desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk bikinin tower dong ds...
# ..                                                 ...
# 121  yth saya mau meminta penjelasan terkait koneks...
# 122           min buka jgn php dong dari kemarin juga
# 124  hidup anda sering sial dan sakit an pasti stru...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                             tokenisasi  \
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, atau, ins...
# 2             [ngomong, gua, orang, sumenep, nih, min]
# 3       [saya, ingin, desa, saya, koneksinya, kencang]
# 4    [sinyalmu, urusin, taeeekkk, bikinin, tower, d...
# ..                                                 ...
# 121  [yth, saya, mau, meminta, penjelasan, terkait,...
# 122  [min, buka, jgn, php, dong, dari, kemarin, jug...
# 124  [hidup, anda, sering, sial, dan, sakit, an, pa...
# 125  [pak, jokowi, tolong, segera, ganti, nama, ind...
# 126  [pak, jokowi, kalau, negara, masih, mau, selam...
#
#                                               stopword
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, institut,...
# 2                  [ngomong, gua, orang, sumenep, min]
# 3                          [desa, koneksinya, kencang]
# 4    [sinyalmu, urusin, taeeekkk, bikinin, tower, d...
# ..                                                 ...
# 121  [yth, penjelasan, terkait, koneksi, internet, ...
# 122                        [min, buka, php, kemarin, ]
# 124  [hidup, sial, sakit, struktur, nama, bermasala...
# 125  [jokowi, tolong, ganti, nama, indonesia, nusan...
# 126  [jokowi, negara, selamat, tolong, dpr, menggel...
#
# [109 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 444
# ------------------------
#  :
# min : min
# institut : institut
# teknologi : teknologi
# surabaya : surabaya
# sepuluh : puluh
# nopember : nopember
# campus : campus
# ngomong : ngomong
# gua : gua
# orang : orang
# sumenep : sumenep
# desa : desa
# koneksinya : koneksi
# kencang : kencang
# sinyalmu : sinyal
# urusin : urusin
# taeeekkk : taeeekkk
# bikinin : bikinin
# tower : tower
# dsni : dsni
# njing : njing
# beli : beli
# obat : obat
# terhalang : halang
# jarak : jarak
# met : met
# sore : sore
# saldo : saldo
# gopayku : gopayku
# ribu : ribu
# hadiah : hadiah
# program : program
# live : live
# kuncie : kuncie
# hendy : hendy
# setiono : setiono
# ceo : ceo
# baba : baba
# rafi : rafi
# agustus : agustus
# dikirim : kirim
# kerja : kerja
# bolak : bolak
# respon : respon
# mosok : mosok
# gopay : gopay
# sekelas : kelas
# telkomsel : telkomsel
# ngemplang : ngemplang
# sayang : sayang
# reputasinya : reputasi
# ambyar : ambyar
# lho : lho
# tunggu : tunggu
# typo : typo
# its : its
# anak : anak
# dajjal : dajjal
# cinta : cinta
# beda : beda
# serumah : rumah
# tolong : tolong
# tuhan : tuhan
# engkau : engkau
# paket : paket
# membeli : beli
# jaringanya : jaringanya
# mati : mati
# matian : mati
# fdfjx : fdfjx
# cek : cek
# bales : bales
# trs : trs
# solusi : solusi
# pilihan : pilih
# nutup : nutup
# halo : halo
# udah : udah
# thn : thn
# sisain : sisain
# simpati : simpati
# sinyal : sinyal
# ngdown : ngdown
# nelpon : nelpon
# raib : raib
# tnpa : tnpa
# kabar : kabar
# sinyalnya : sinyal
# baperan : baperan
# geser : geser
# dikit : dikit
# ilang : ilang
# fd : fd
# mudah : mudah
# ajak : ajak
# mabar : mabar
# putus : putus
# main : main
# genshin : genshin
# impact : impact
# ping : ping
# merah : merah
# teross : teross
# woii : woii
# pakai : pakai
# tanyak : tanyak
# registrasi : registrasi
# kartu : kartu
# alasan : alas
# nomor : nomor
# data : data
# baca : baca
# please : please
# mind : mind
# done : done
# sejoli : joli
# bahagia : bahagia
# pernikahannya : nikah
# rezeki : rezeki
# nama : nama
# hidup : hidup
# combo : combo
# sakti : sakti
# kaku : kaku
# coklat : coklat
# beuh : beuh
# dirumah : rumah
# tross : tross
# temenan : temenan
# kuning : kuning
# slalu : slalu
# terbentang : bentang
# biarkan : biar
# kupeluk : peluk
# erat : erat
# bayangmu : bayang
# tuk : tuk
# melepaskan : lepas
# kerinduanku : rindu
# pelanggan : langgan
# setia : setia
# melengkapi : lengkap
# transferin : transferin
# pulsa : pulsa
# intinya : inti
# hati : hati
# jumping : jumping
# temen : temen
# ngga : ngga
# muluk : muluk
# jejaring : jejaring
# medsos : medsos
# blokir : blokir
# untung : untung
# untungan : untung
# sekeluarga : keluarga
# semoga : moga
# tersemogakan : moga
# aamiin : aamiin
# hijau : hijau
# berempat : empat
# multimedia : multimedia
# sosmed : sosmed
# games : games
# fungsi : fungsi
# game : game
# yatim : yatim
# telkontol : telkontol
# free : free
# fire : fire
# mobile : mobile
# legends : legends
# pubd : pubd
# callofduty : callofduty
# clash : clash
# clan : clan
# coc : coc
# admin : admin
# mobilegends : mobilegends
# codm : codm
# terusss : terusss
# minnnn : minnnn
# turnamen : turnamen
# mampir : mampir
# sungguh : sungguh
# disayangkan : sayang
# kuota : kuota
# utam : utam
# hbs : hbs
# trnyt : trnyt
# berguna : guna
# sperti : sperti
# profider : profider
# klow : klow
# beban : beban
# utama : utama
# mai : mai
# bulnn : bulnn
# trnyta : trnyta
# mntok : mntok
# duh : duh
# diperbaiki : baik
# kak : kak
# fdhyv : fdhyv
# perbaikin : perbaikin
# aov : aov
# monetary : monetary
# extra : extra
# tsel : tsel
# kepakai : pakai
# berlaku : laku
# tgl : tgl
# november : november
# paketnya : paket
# ngobrol : ngobrol
# veronica : veronica
# jaka : jaka
# sembung : sembung
# ojek : ojek
# nyambung : nyambung
# jek : jek
# memuaskan : muas
# cape : cape
# punten : punten
# parah : parah
# banget : banget
# maen : maen
# online : online
# lancar : lancar
# malam : malam
# blm : blm
# masuk : masuk
# masi : mas
# perbaikan : baik
# sistem : sistem
# kah : kah
# fdxw : fdxw
# te : te
# the : the
# bets : bets
# pembayaran : bayar
# skrg : skrg
# jelass : jelass
# masak : masak
# uda : uda
# daftar : daftar
# pakek : pakek
# suda : suda
# barhasil : barhasil
# sms : sms
# pulsaku : pulsa
# kepotong : potong
# rb : rb
# anjenkkk : anjenkkk
# menhubungi : menhubungi
# care : care
# responnya : responnya
# terima : terima
# kasih : kasih
# pengguna : guna
# hangus : hangus
# terlambat : lambat
# mengisi : isi
# muncul : muncul
# keterangan : terang
# panggilan : panggil
# darurat : darurat
# mengaktifkan : aktif
# solusinya : solusi
# internet : internet
# linkaja : linkaja
# liat : liat
# bantu : bantu
# check : check
# perihal : perihal
# pemenang : menang
# giveaway : giveaway
# kepana : pana
# kali : kali
# expaire : expaire
# berbeda : beda
# pembelian : beli
# contoh : contoh
# end : end
# date : date
# bearti : bearti
# tks : tks
# permisi : permisi
# disitu : situ
# lokal : lokal
# maksudnya : maksud
# gmna : gmna
# kartunya : kartu
# kota : kota
# pontianak : pontianak
# pergi : pergi
# kabupaten : kabupaten
# bengkayang : bengkayang
# lokalnya : lokal
# daerah : daerah
# tempati : tempat
# menang : menang
# hadiahnya : hadiah
# nyampe : nyampe
# maaf : maaf
# jam : jam
# segini : gin
# kouta : kouta
# unlimited : unlimited
# udh : udh
# bayar : bayar
# via : via
# keptong : keptong
# saldonya : saldo
# gitu : gitu
# duid : duid
# mengecewakan : kecewa
# daftarnya : daftar
# gimana : gimana
# nyaman : nyaman
# stabil : stabil
# coba : coba
# kabarin : kabarin
# gwa : gwa
# makek : makek
# telkom : telkom
# adu : adu
# nasi : nasi
# yuk : yuk
# bro : bro
# gue : gue
# nggak : nggak
# jaringann : jaringann
# leletnya : lelet
# biyuuuoooh : biyuuuoooh
# telkomselllll : telkomselllll
# emosiiiii : emosiiiii
# lemooootttt : lemooootttt
# pollll : pollll
# woi : woi
# butuh : butuh
# murah : murah
# kayak : kayak
# kemaren : kemaren
# keluhan : keluh
# umur : umur
# perbaiki : baik
# pasang : pasang
# postingan : postingan
# mimin : mimin
# veronika : veronika
# sesuai : sesuai
# home : home
# mytelkomsel : mytelkomsel
# mohon : mohon
# bls : bls
# ngedrop : ngedrop
# informasinya : informasi
# akurat : akurat
# informasi : informasi
# aktif : aktif
# keliru : keliru
# aplikasi : aplikasi
# seminggu : minggu
# yth : yth
# penjelasan : jelas
# terkait : kait
# koneksi : koneksi
# pusat : pusat
# palembang : palembang
# jaringannya : jaring
# kuat : kuat
# lambat : lambat
# habis : habis
# sblm : sblm
# menonton : tonton
# youtube : youtube
# buka : buka
# viu : viu
# hambatan : hambat
# sisa : sisa
# sia : sia
# membuka : buka
# maxstrem : maxstrem
# pindah : pindah
# php : php
# kemarin : kemarin
# sial : sial
# sakit : sakit
# struktur : struktur
# bermasalah : masalah
# konsultasikan : konsultasi
# jokowi : jokowi
# ganti : ganti
# indonesia : indonesia
# nusantara : nusantara
# membawa : bawa
# perpecahan : pecah
# ketidakmampuan : ketidakmampuan
# follow : follow
# negara : negara
# selamat : selamat
# dpr : dpr
# menggelar : gelar
# referendum : referendum
# mengubah : ubah
# negaranya : negara
# ideologi : ideologi
# dasar : dasar
# diubah : ubah
# luas : luas
# wilayahnya : wilayah
# murni : murni
# berharani : berharani
# harani : harani
# uni : uni
# soviet : soviet
# terpecah : pecah
# belah : belah
# dengarkan : dengar
# arkand : arkand
# kick : kick
# andy : andy
# stasiun : stasiun
# disearch : disearch
# tanda : tanda
# bangsa : bangsa
# nyata : nyata
# hebat : hebat
# aceh : aceh
# papua : papua
# lepas : lepas
# duluan : duluan
# efek : efek
# domino : domino
# provinsi : provinsi
# budaya : budaya
# akar : akar
# tanggal : tanggal
# berdiri : diri
# pengaruh : pengaruh
# buruk : buruk
# presiden : presiden
# {'': '', 'min': 'min', 'institut': 'institut', 'teknologi': 'teknologi', 'surabaya': 'surabaya', 'sepuluh': 'puluh', 'nopember': 'nopember', 'campus': 'campus', 'ngomong': 'ngomong', 'gua': 'gua', 'orang': 'orang', 'sumenep': 'sumenep', 'desa': 'desa', 'koneksinya': 'koneksi', 'kencang': 'kencang', 'sinyalmu': 'sinyal', 'urusin': 'urusin', 'taeeekkk': 'taeeekkk', 'bikinin': 'bikinin', 'tower': 'tower', 'dsni': 'dsni', 'njing': 'njing', 'beli': 'beli', 'obat': 'obat', 'terhalang': 'halang', 'jarak': 'jarak', 'met': 'met', 'sore': 'sore', 'saldo': 'saldo', 'gopayku': 'gopayku', 'ribu': 'ribu', 'hadiah': 'hadiah', 'program': 'program', 'live': 'live', 'kuncie': 'kuncie', 'hendy': 'hendy', 'setiono': 'setiono', 'ceo': 'ceo', 'baba': 'baba', 'rafi': 'rafi', 'agustus': 'agustus', 'dikirim': 'kirim', 'kerja': 'kerja', 'bolak': 'bolak', 'respon': 'respon', 'mosok': 'mosok', 'gopay': 'gopay', 'sekelas': 'kelas', 'telkomsel': 'telkomsel', 'ngemplang': 'ngemplang', 'sayang': 'sayang', 'reputasinya': 'reputasi', 'ambyar': 'ambyar', 'lho': 'lho', 'tunggu': 'tunggu', 'typo': 'typo', 'its': 'its', 'anak': 'anak', 'dajjal': 'dajjal', 'cinta': 'cinta', 'beda': 'beda', 'serumah': 'rumah', 'tolong': 'tolong', 'tuhan': 'tuhan', 'engkau': 'engkau', 'paket': 'paket', 'membeli': 'beli', 'jaringanya': 'jaringanya', 'mati': 'mati', 'matian': 'mati', 'fdfjx': 'fdfjx', 'cek': 'cek', 'bales': 'bales', 'trs': 'trs', 'solusi': 'solusi', 'pilihan': 'pilih', 'nutup': 'nutup', 'halo': 'halo', 'udah': 'udah', 'thn': 'thn', 'sisain': 'sisain', 'simpati': 'simpati', 'sinyal': 'sinyal', 'ngdown': 'ngdown', 'nelpon': 'nelpon', 'raib': 'raib', 'tnpa': 'tnpa', 'kabar': 'kabar', 'sinyalnya': 'sinyal', 'baperan': 'baperan', 'geser': 'geser', 'dikit': 'dikit', 'ilang': 'ilang', 'fd': 'fd', 'mudah': 'mudah', 'ajak': 'ajak', 'mabar': 'mabar', 'putus': 'putus', 'main': 'main', 'genshin': 'genshin', 'impact': 'impact', 'ping': 'ping', 'merah': 'merah', 'teross': 'teross', 'woii': 'woii', 'pakai': 'pakai', 'tanyak': 'tanyak', 'registrasi': 'registrasi', 'kartu': 'kartu', 'alasan': 'alas', 'nomor': 'nomor', 'data': 'data', 'baca': 'baca', 'please': 'please', 'mind': 'mind', 'done': 'done', 'sejoli': 'joli', 'bahagia': 'bahagia', 'pernikahannya': 'nikah', 'rezeki': 'rezeki', 'nama': 'nama', 'hidup': 'hidup', 'combo': 'combo', 'sakti': 'sakti', 'kaku': 'kaku', 'coklat': 'coklat', 'beuh': 'beuh', 'dirumah': 'rumah', 'tross': 'tross', 'temenan': 'temenan', 'kuning': 'kuning', 'slalu': 'slalu', 'terbentang': 'bentang', 'biarkan': 'biar', 'kupeluk': 'peluk', 'erat': 'erat', 'bayangmu': 'bayang', 'tuk': 'tuk', 'melepaskan': 'lepas', 'kerinduanku': 'rindu', 'pelanggan': 'langgan', 'setia': 'setia', 'melengkapi': 'lengkap', 'transferin': 'transferin', 'pulsa': 'pulsa', 'intinya': 'inti', 'hati': 'hati', 'jumping': 'jumping', 'temen': 'temen', 'ngga': 'ngga', 'muluk': 'muluk', 'jejaring': 'jejaring', 'medsos': 'medsos', 'blokir': 'blokir', 'untung': 'untung', 'untungan': 'untung', 'sekeluarga': 'keluarga', 'semoga': 'moga', 'tersemogakan': 'moga', 'aamiin': 'aamiin', 'hijau': 'hijau', 'berempat': 'empat', 'multimedia': 'multimedia', 'sosmed': 'sosmed', 'games': 'games', 'fungsi': 'fungsi', 'game': 'game', 'yatim': 'yatim', 'telkontol': 'telkontol', 'free': 'free', 'fire': 'fire', 'mobile': 'mobile', 'legends': 'legends', 'pubd': 'pubd', 'callofduty': 'callofduty', 'clash': 'clash', 'clan': 'clan', 'coc': 'coc', 'admin': 'admin', 'mobilegends': 'mobilegends', 'codm': 'codm', 'terusss': 'terusss', 'minnnn': 'minnnn', 'turnamen': 'turnamen', 'mampir': 'mampir', 'sungguh': 'sungguh', 'disayangkan': 'sayang', 'kuota': 'kuota', 'utam': 'utam', 'hbs': 'hbs', 'trnyt': 'trnyt', 'berguna': 'guna', 'sperti': 'sperti', 'profider': 'profider', 'klow': 'klow', 'beban': 'beban', 'utama': 'utama', 'mai': 'mai', 'bulnn': 'bulnn', 'trnyta': 'trnyta', 'mntok': 'mntok', 'duh': 'duh', 'diperbaiki': 'baik', 'kak': 'kak', 'fdhyv': 'fdhyv', 'perbaikin': 'perbaikin', 'aov': 'aov', 'monetary': 'monetary', 'ext ...
# ------------------------
# Pandas Apply:   0%|          | 0/109 [00:00<?, ?it/s]
#                                                   text  \
# 0                                                  :((
# 1    min @telkomsel institut teknologi surabaya ata...
# 2                   ngomong2 gua orang sumenep nih min
# 3           saya ingin di desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk, bikinin tower dong d...
# ..                                                 ...
# 121  yth @telkomsel saya mau meminta penjelasan ter...
# 122  min buka dm...jgn php dong...dari kemarin juga...
# 124  hidup anda sering sial dan sakit2an? pasti str...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                          cleaning_text  \
# 0
# 1    min institut teknologi surabaya atau institut ...
# 2                   ngomong  gua orang sumenep nih min
# 3              saya ingin desa saya koneksinya kencang
# 4    sinyalmu urusin taeeekkk bikinin tower dong ds...
# ..                                                 ...
# 121  yth saya mau meminta penjelasan terkait koneks...
# 122           min buka jgn php dong dari kemarin juga
# 124  hidup anda sering sial dan sakit an pasti stru...
# 125  pak jokowi tolong segera ganti nama indonesia ...
# 126  pak jokowi kalau negara masih mau selamat tolo...
#
#                                             tokenisasi  \
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, atau, ins...
# 2             [ngomong, gua, orang, sumenep, nih, min]
# 3       [saya, ingin, desa, saya, koneksinya, kencang]
# 4    [sinyalmu, urusin, taeeekkk, bikinin, tower, d...
# ..                                                 ...
# 121  [yth, saya, mau, meminta, penjelasan, terkait,...
# 122  [min, buka, jgn, php, dong, dari, kemarin, jug...
# 124  [hidup, anda, sering, sial, dan, sakit, an, pa...
# 125  [pak, jokowi, tolong, segera, ganti, nama, ind...
# 126  [pak, jokowi, kalau, negara, masih, mau, selam...
#
#                                               stopword  \
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, institut,...
# 2                  [ngomong, gua, orang, sumenep, min]
# 3                          [desa, koneksinya, kencang]
# 4    [sinyalmu, urusin, taeeekkk, bikinin, tower, d...
# ..                                                 ...
# 121  [yth, penjelasan, terkait, koneksi, internet, ...
# 122                        [min, buka, php, kemarin, ]
# 124  [hidup, sial, sakit, struktur, nama, bermasala...
# 125  [jokowi, tolong, ganti, nama, indonesia, nusan...
# 126  [jokowi, negara, selamat, tolong, dpr, menggel...
#
#                                               stemming
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, institut,...
# 2                  [ngomong, gua, orang, sumenep, min]
# 3                             [desa, koneksi, kencang]
# 4    [sinyal, urusin, taeeekkk, bikinin, tower, dsn...
# ..                                                 ...
# 121  [yth, jelas, kait, koneksi, internet, pusat, k...
# 122                        [min, buka, php, kemarin, ]
# 124  [hidup, sial, sakit, struktur, nama, masalah, ...
# 125  [jokowi, tolong, ganti, nama, indonesia, nusan...
# 126  [jokowi, negara, selamat, tolong, dpr, gelar, ...
#
# [109 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                                 [, ]
# 1    [min, institut, teknologi, surabaya, institut,...
# 2                  [ngomong, gua, orang, sumenep, min]
# 3                             [desa, koneksi, kencang]
# 4    [sinyal, urusin, taeeekkk, bikinin, tower, dsn...
# ..                                                 ...
# 121  [yth, jelas, kait, koneksi, internet, pusat, k...
# 122                        [min, buka, php, kemarin, ]
# 124  [hidup, sial, sakit, struktur, nama, masalah, ...
# 125  [jokowi, tolong, ganti, nama, indonesia, nusan...
# 126  [jokowi, negara, selamat, tolong, dpr, gelar, ...
#
# [109 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_10.xlsx')
