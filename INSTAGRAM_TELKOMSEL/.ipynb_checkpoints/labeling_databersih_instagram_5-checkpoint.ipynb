# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["comment_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data bersih_translate instagram telkomsel\databersih_english_instagram_telkomsel_5.xlsx', usecols=columns)
df['label_awal'] = ''
for i,x in df.comment_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.35
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.0
# Index:  3 label_awal 0.0
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.2
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.5
# Index:  8 label_awal 0.5
# Index:  9 label_awal -0.025
# Index:  10 label_awal 0.0
# Index:  11 label_awal 0.0
# Index:  12 label_awal 0.13999999999999999
# Index:  13 label_awal 0.0
# Index:  14 label_awal 0.7
# Index:  15 label_awal 0.24642857142857144
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.0
# Index:  20 label_awal 0.1
# Index:  21 label_awal 0.2
# Index:  22 label_awal 0.0
# Index:  23 label_awal -0.6999999999999998
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.7
# Index:  26 label_awal 0.7
# Index:  27 label_awal 0.0
# Index:  28 label_awal 0.0
# Index:  29 label_awal -0.2944444444444444
# Index:  30 label_awal -0.12222222222222223
# Index:  31 label_awal 0.15000000000000002
# Index:  32 label_awal -0.4
# Index:  33 label_awal 0.0
# Index:  34 label_awal -0.25
# Index:  35 label_awal 0.7
# Index:  36 label_awal 0.0
# Index:  37 label_awal -0.24444444444444446
# Index:  38 label_awal -0.04999999999999999
# Index:  39 label_awal 0.0
# Index:  40 label_awal 0.0
# Index:  41 label_awal 0.7
# Index:  42 label_awal 0.0
# Index:  43 label_awal 0.0
# Index:  44 label_awal 0.0
# Index:  45 label_awal 0.0
# Index:  46 label_awal -0.4
# Index:  47 label_awal -0.3
# Index:  48 label_awal 0.0
# Index:  49 label_awal 0.0
# Index:  50 label_awal 0.0
# Index:  51 label_awal 0.7
# Index:  52 label_awal 0.0
# Index:  53 label_awal 0.13333333333333333
# Index:  54 label_awal 0.0
# Index:  55 label_awal 0.18333333333333332
# Index:  56 label_awal 0.0
# Index:  57 label_awal 0.0
# Index:  58 label_awal 0.0
# Index:  59 label_awal 0.4
# Index:  60 label_awal 0.0
# Index:  61 label_awal 0.0
# Index:  62 label_awal -0.26666666666666666
# Index:  63 label_awal 0.0
# Index:  64 label_awal 0.0
# Index:  65 label_awal 0.0
# Index:  66 label_awal 0.41250000000000003
# Index:  67 label_awal 0.0
# Index:  68 label_awal 0.5
# Index:  69 label_awal 0.2
# Index:  70 label_awal 0.0
# Index:  71 label_awal 0.0
# Index:  72 label_awal -0.4
# Index:  73 label_awal 0.43333333333333335
# Index:  74 label_awal 0.0
# Index:  75 label_awal 0.1
# Index:  76 label_awal 0.0
# Index:  77 label_awal 0.26666666666666666
# Index:  78 label_awal 0.0
# Index:  79 label_awal 0.0
# Index:  80 label_awal 0.0
# Index:  81 label_awal 0.0
# Index:  82 label_awal -0.02785714285714287
# Index:  83 label_awal 0.325
# Index:  84 label_awal 0.0
# Index:  85 label_awal 0.14999999999999997
# Index:  86 label_awal -0.2
# Index:  87 label_awal 0.0
# Index:  88 label_awal 0.0
# Index:  89 label_awal 0.0
# Index:  90 label_awal 0.0
# Index:  91 label_awal 0.0
# Index:  92 label_awal 0.14285714285714285
# Index:  93 label_awal 0.0
# Index:  94 label_awal 0.0
# Index:  95 label_awal 0.0
# Index:  96 label_awal 0.0
# Index:  97 label_awal 0.35
# Index:  98 label_awal 0.0
# Index:  99 label_awal 0.0
# Index:  100 label_awal 0.0
# Index:  101 label_awal 0.375
# Index:  102 label_awal 0.0
# Index:  103 label_awal 0.0
# Index:  104 label_awal -0.2
# Index:  105 label_awal -0.5
# Index:  106 label_awal 0.7
# Index:  107 label_awal 0.0
# Index:  108 label_awal -0.4
# Index:  109 label_awal 0.8
# Index:  110 label_awal 0.35
# Index:  111 label_awal 0.0
# Index:  112 label_awal 0.0
# Index:  113 label_awal 0.3
# Index:  114 label_awal 0.0
# Index:  115 label_awal -0.13749999999999998
# Index:  116 label_awal 0.0
# Index:  117 label_awal 0.0
# Index:  118 label_awal 0.8
# Index:  119 label_awal 0.6
# Index:  120 label_awal 0.0
# Index:  121 label_awal 0.0
# Index:  122 label_awal 0.0
# Index:  123 label_awal 0.8
# Index:  124 label_awal 0.0
# Index:  125 label_awal 0.35
# Index:  126 label_awal 0.7
# Index:  127 label_awal 0.16666666666666666
# Index:  128 label_awal 0.0
# Index:  129 label_awal 0.0
# Index:  130 label_awal 0.0
# Index:  131 label_awal 0.0
# Index:  132 label_awal 0.0
# Index:  133 label_awal 0.0

# %%
df.head()
# Out:
#                                      comment_english label_awal
# 0  ['telkomsel', 'download', 'speed', 'just', 'mb...       0.35
# 1                                    ['', 'min', '']        0.0
# 2                                   ['check', 'min']        0.0
# 3  ['telkomsel', 'forward', 'telkomsel', 'signal'...        0.0
# 4                ['sinyall', 'nyaaa', 'woooeeeyyyy']        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    77
#  0.700000     8
#  0.350000     4
# -0.400000     4
#  0.200000     3
#  0.500000     3
#  0.800000     3
#  0.100000     2
# -0.200000     2
#  0.266667     1
# -0.027857     1
#  0.325000     1
#  0.150000     1
# -0.500000     1
#  0.142857     1
#  0.375000     1
#  0.412500     1
#  0.300000     1
# -0.137500     1
#  0.600000     1
#  0.433333     1
#  0.133333     1
# -0.266667     1
#  0.400000     1
#  0.183333     1
# -0.300000     1
# -0.050000     1
# -0.244444     1
# -0.250000     1
#  0.150000     1
# -0.122222     1
# -0.294444     1
# -0.700000     1
#  0.246429     1
#  0.140000     1
# -0.025000     1
#  0.166667     1
# Name: label_awal, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] > 0.0:
        label.append("positive")
    else:
        label.append("negative")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                        comment_english     label
# 0    ['telkomsel', 'download', 'speed', 'just', 'mb...  positive
# 1                                      ['', 'min', '']  negative
# 2                                     ['check', 'min']  negative
# 3    ['telkomsel', 'forward', 'telkomsel', 'signal'...  negative
# 4                  ['sinyall', 'nyaaa', 'woooeeeyyyy']  negative
# ..                                                 ...       ...
# 129          ['telkomsel', 'forward', 'telkomsel', '']  negative
# 130                  ['telkomsel', 'open', 'type', '']  negative
# 131  ['signal', 'min', 'urusin', 'indihome', 'geh',...  negative
# 132                              ['jenen', 'ramadhan']  negative
# 133     ['signal', 'signal', 'mimin', 'signal', 'min']  negative
#
# [134 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# negative    95
# positive    39
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_instagram_indihome_5.xlsx')
