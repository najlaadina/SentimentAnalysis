# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_TELKOMSEL\data mentah\instagram_telkomsel_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game MLBB ?...
# 2    Min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         Pdhl 4G..tp ga ada garis2nya
# 4                               Kenapa sinyal ku ilang
# ..                                                 ...
# 98                                          Cek dm kak
# 99                                   Bales dm dong min
# 100       Sapa tau rejeki  saya alhamdulillah  Aamiin.
# 101                             Cek dm dong ka penting
# 102                             Cek dm dong ka penting
#
# [103 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game MLBB ?...
# 2    Min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         Pdhl 4G..tp ga ada garis2nya
# 4                               Kenapa sinyal ku ilang
# ..                                                 ...
# 96                                      Baca dm ya min
# 97   @telkomsel min saya mau tanya kalo upgrade lin...
# 98                                          Cek dm kak
# 99                                   Bales dm dong min
# 100       Sapa tau rejeki  saya alhamdulillah  Aamiin.
#
# [70 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game mlbb ?...
# 2    min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         pdhl 4g..tp ga ada garis2nya
# 4                               kenapa sinyal ku ilang
# ..                                                 ...
# 96                                      baca dm ya min
# 97   @telkomsel min saya mau tanya kalo upgrade lin...
# 98                                          cek dm kak
# 99                                   bales dm dong min
# 100       sapa tau rejeki  saya alhamdulillah  aamiin.
#
# [70 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game mlbb ?...
# 2    min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         pdhl 4g..tp ga ada garis2nya
# 4                               kenapa sinyal ku ilang
# ..                                                 ...
# 96                                      baca dm ya min
# 97   @telkomsel min saya mau tanya kalo upgrade lin...
# 98                                          cek dm kak
# 99                                   bales dm dong min
# 100       sapa tau rejeki  saya alhamdulillah  aamiin.
#
#                                          cleaning_text
# 0    min mohon cek min mohon sekali min udh hari mi...
# 1    min kenapa telkomsel bisa login game mlbb tapi...
# 2    min saya tiba tiba dapet paket denim maksudnya...
# 3                                   pdhl ada garis nya
# 4                                  kenapa sinyal ilang
# ..                                                 ...
# 96                                            baca min
# 97   min saya mau tanya kalo upgrade linkaja grapar...
# 98                                             cek kak
# 99                                      bales dong min
# 100         sapa tau rejeki saya alhamdulillah aamiin
#
# [70 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game mlbb ?...
# 2    min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         pdhl 4g..tp ga ada garis2nya
# 4                               kenapa sinyal ku ilang
# ..                                                 ...
# 96                                      baca dm ya min
# 97   @telkomsel min saya mau tanya kalo upgrade lin...
# 98                                          cek dm kak
# 99                                   bales dm dong min
# 100       sapa tau rejeki  saya alhamdulillah  aamiin.
#
#                                          cleaning_text  \
# 0    min mohon cek min mohon sekali min udh hari mi...
# 1    min kenapa telkomsel bisa login game mlbb tapi...
# 2    min saya tiba tiba dapet paket denim maksudnya...
# 3                                   pdhl ada garis nya
# 4                                  kenapa sinyal ilang
# ..                                                 ...
# 96                                            baca min
# 97   min saya mau tanya kalo upgrade linkaja grapar...
# 98                                             cek kak
# 99                                      bales dong min
# 100         sapa tau rejeki saya alhamdulillah aamiin
#
#                                             tokenisasi
# 0    [min, mohon, cek, min, mohon, sekali, min, udh...
# 1    [min, kenapa, telkomsel, bisa, login, game, ml...
# 2    [min, saya, tiba, tiba, dapet, paket, denim, m...
# 3                              [pdhl, ada, garis, nya]
# 4                              [kenapa, sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, saya, mau, tanya, kalo, upgrade, linkaja...
# 98                                          [cek, kak]
# 99                                  [bales, dong, min]
# 100  [sapa, tau, rejeki, saya, alhamdulillah, aamii...
#
# [70 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game mlbb ?...
# 2    min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         pdhl 4g..tp ga ada garis2nya
# 4                               kenapa sinyal ku ilang
# ..                                                 ...
# 96                                      baca dm ya min
# 97   @telkomsel min saya mau tanya kalo upgrade lin...
# 98                                          cek dm kak
# 99                                   bales dm dong min
# 100       sapa tau rejeki  saya alhamdulillah  aamiin.
#
#                                          cleaning_text  \
# 0    min mohon cek min mohon sekali min udh hari mi...
# 1    min kenapa telkomsel bisa login game mlbb tapi...
# 2    min saya tiba tiba dapet paket denim maksudnya...
# 3                                   pdhl ada garis nya
# 4                                  kenapa sinyal ilang
# ..                                                 ...
# 96                                            baca min
# 97   min saya mau tanya kalo upgrade linkaja grapar...
# 98                                             cek kak
# 99                                      bales dong min
# 100         sapa tau rejeki saya alhamdulillah aamiin
#
#                                             tokenisasi  \
# 0    [min, mohon, cek, min, mohon, sekali, min, udh...
# 1    [min, kenapa, telkomsel, bisa, login, game, ml...
# 2    [min, saya, tiba, tiba, dapet, paket, denim, m...
# 3                              [pdhl, ada, garis, nya]
# 4                              [kenapa, sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, saya, mau, tanya, kalo, upgrade, linkaja...
# 98                                          [cek, kak]
# 99                                  [bales, dong, min]
# 100  [sapa, tau, rejeki, saya, alhamdulillah, aamii...
#
#                                               stopword
# 0    [min, mohon, cek, min, mohon, min, udh, min, t...
# 1    [min, telkomsel, login, game, mlbb, buka, dll,...
# 2    [min, dapet, paket, denim, maksudnya, kits, ma...
# 3                                        [pdhl, garis]
# 4                                      [sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, upgrade, linkaja, grapari, telkomsel, sy...
# 98                                          [cek, kak]
# 99                                        [bales, min]
# 100            [sapa, rejeki, alhamdulillah, aamiin, ]
#
# [70 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 315
# ------------------------
# min : min
# mohon : mohon
# cek : cek
# udh : udh
# tunggu : tunggu
# telkomsel : telkomsel
# login : login
# game : game
# mlbb : mlbb
# buka : buka
# dll : dll
# lancar : lancar
# jaya : jaya
# malam : malam
#  :
# dapet : dapet
# paket : paket
# denim : denim
# maksudnya : maksud
# kits : kits
# mantis : mantis
# bayar : bayar
# pulsar : pulsar
# pdhl : pdhl
# garis : garis
# sinyal : sinyal
# ilang : ilang
# bales : bales
# dmku : dmku
# secepat : cepat
# dsni : dsni
# bagus : bagus
# paketan : paket
# unlimited : unlimited
# kena : kena
# fup : fup
# kota : kota
# purwokerto : purwokerto
# banyumas : banyumas
# suport : suport
# extra : extra
# unlimeted : unlimeted
# asik : asik
# perbulan : bulan
# kuota : kuota
# murni : murni
# disney : disney
# promo : promo
# app : app
# kode : kode
# dial : dial
# kmrn : kmrn
# gb : gb
# sakti : sakti
# blm : blm
# sempet : sempet
# kebeli : kebel
# pembelian : beli
# mantap : mantap
# the : the
# real : real
# entry : entry
# level : level
# killer : killer
# advan : advan
# pulsa : pulsa
# kah : kah
# murah : murah
# kartu : kartu
# rb : rb
# semoga : moga
# beruntung : untung
# uuh : uuh
# tgl : tgl
# september : september
# pket : pket
# ekstra : ekstra
# ketengan : keteng
# youtube : youtube
# uda : uda
# tolong : tolong
# kali : kali
# tolongbkali : tolongbkali
# combo : combo
# thrifty : thrifty
# tlong : tlong
# diadain : diadain
# data : data
# kyk : kyk
# tetangga : tetangga
# sebelah : belah
# disegala : segala
# medan : medan
# internet : internet
# gratis : gratis
# wifi : wifi
# menghemat : hemat
# tlpn : tlpn
# dear : dear
# admin : admin
# baca : baca
# dung : dung
# trim : trim
# lihat : lihat
# terimakasih : terimakasih
# lokal : lokal
# gabisa : gabisa
# tdi : tdi
# dpt : dpt
# telpon : telpon
# nomor : nomor
# pencerahannya : cerah
# mengaktifkan : aktif
# signal : signal
# buruk : buruk
# provider : provider
# gmna : gmna
# komunikasi : komunikasi
# terkendala : kendala
# tanggal : tanggal
# segini : gin
# beli : beli
# paketnya : paket
# penggemar : gemar
# god : god
# bless : bless
# album : album
# favorit : favorit
# ane : ane
# cermin : cermin
# albumnya : album
# progress : progress
# abisss : abisss
# pertunjukannya : tunjuk
# lupa : lupa
# mainkan : main
# selamat : selamat
# pagi : pagi
# indonesia : indonesia
# lagu : lagu
# kisah : kisah
# nyata : nyata
# mantan : mantan
# pejuang : juang
# perampok : rampok
# permisi : permisi
# izin : izin
# profile : profile
# bahaya : bahaya
# keamanan : aman
# palingan : paling
# diblokir : blokir
# ribetnya : ribetnya
# ampun : ampun
# butuh : butuh
# gimana : gimana
# simswap : simswap
# hardjya : hardjya
# redeem : redeem
# klaim : klaim
# hadiah : hadiah
# program : program
# check : check
# blsannya : blsannya
# maaf : maaf
# ambil : ambil
# coba : coba
# restrat : restrat
# berhasil : hasil
# veronika : veronika
# poin : poin
# mencukupi : cukup
# tukar : tukar
# halo : halo
# udah : udah
# minggu : minggu
# superdeal : superdeal
# bner : bner
# brrti : brrti
# kya : kya
# gtu : gtu
# mudah : mudah
# terhindar : hindar
# dri : dri
# gtuan : gtuan
# aamiin : aamiin
# makasi : makas
# kang : kang
# jawabanny : jawabanny
# cuman : cuman
# nerbitkan : nerbitkan
# org : org
# pemiliki : milik
# aslinya : asli
# bener : bener
# tuhh : tuhh
# knpa : knpa
# sllu : sllu
# sms : sms
# jls : jls
# mengatasnamakan : mengatasnamakan
# pinjol : pinjol
# menuhin : menuhin
# kotak : kotak
# tindak : tindak
# tsel : tsel
# pengguna : guna
# setia : setia
# bertaun : taun
# taun : taun
# mas : mas
# salah : salah
# tokopedia : tokopedia
# kebocoran : bocor
# perusahaan : usaha
# leak : leak
# yaa : yaa
# gitu : gitu
# deh : deh
# gatau : gatau
# dimana : mana
# jamin : jamin
# ngisi : ngisi
# wallet : wallet
# commerce : commerce
# aplikasi : aplikasi
# true : true
# caller : caller
# blok : blok
# knl : knl
# huhuhu : huhuhu
# pilihan : pilih
# kuotanya : kuota
# skrg : skrg
# mahaaallllll : mahaaallllll
# dicek : cek
# wilayah : wilayah
# indragiri : indragiri
# hulu : hulu
# kecamatan : camat
# batang : batang
# cenaku : cena
# putus : putus
# kasihan : kasihan
# siswa : siswa
# belajarnya : ajar
# daring : daring
# dicheck : dicheck
# ngapain : ngapain
# cgalontang : cgalontang
# tasikmalaya : tasikmalaya
# lionsgate : lionsgate
# lengkap : lengkap
# joss : joss
# hbo : hbo
# gua : gua
# tuker : tuker
# downgrade : downgrade
# kick : kick
# sekolah : sekolah
# main : main
# ajh : ajh
# turun : turun
# streaming : streaming
# minb : minb
# tpi : tpi
# prnh : prnh
# disuruh : suruh
# sabar : sabar
# lgi : lgi
# yaak : yaak
# kouta : kouta
# jokowi : jokowi
# ganti : ganti
# nama : nama
# nusantara : nusantara
# membawa : bawa
# perpecahan : pecah
# ketidakmampuan : ketidakmampuan
# zoom : zoom
# gmeet : gmeet
# mintrimakasih : mintrimakasih
# jutan : jutan
# hrga : hrga
# ssuai : ssuai
# heleh : heleh
# apalah : apa
# daya : daya
# bantuanya : bantuanya
# mim : mim
# hasil : hasil
# live : live
# persib : persib
# dihari : hari
# sabtu : sabtu
# latihan : latih
# kabarnya : kabar
# infonya : info
# surih : surih
# akun : akun
# terbantu : bantu
# harga : harga
# ekonomis : ekonomis
# pandemi : pandemi
# terima : terima
# kasih : kasih
# upgrade : upgrade
# linkaja : linkaja
# grapari : grapari
# syarat : syarat
# biaya : biaya
# kak : kak
# sapa : sapa
# rejeki : rejeki
# alhamdulillah : alhamdulillah
# {'min': 'min', 'mohon': 'mohon', 'cek': 'cek', 'udh': 'udh', 'tunggu': 'tunggu', 'telkomsel': 'telkomsel', 'login': 'login', 'game': 'game', 'mlbb': 'mlbb', 'buka': 'buka', 'dll': 'dll', 'lancar': 'lancar', 'jaya': 'jaya', 'malam': 'malam', '': '', 'dapet': 'dapet', 'paket': 'paket', 'denim': 'denim', 'maksudnya': 'maksud', 'kits': 'kits', 'mantis': 'mantis', 'bayar': 'bayar', 'pulsar': 'pulsar', 'pdhl': 'pdhl', 'garis': 'garis', 'sinyal': 'sinyal', 'ilang': 'ilang', 'bales': 'bales', 'dmku': 'dmku', 'secepat': 'cepat', 'dsni': 'dsni', 'bagus': 'bagus', 'paketan': 'paket', 'unlimited': 'unlimited', 'kena': 'kena', 'fup': 'fup', 'kota': 'kota', 'purwokerto': 'purwokerto', 'banyumas': 'banyumas', 'suport': 'suport', 'extra': 'extra', 'unlimeted': 'unlimeted', 'asik': 'asik', 'perbulan': 'bulan', 'kuota': 'kuota', 'murni': 'murni', 'disney': 'disney', 'promo': 'promo', 'app': 'app', 'kode': 'kode', 'dial': 'dial', 'kmrn': 'kmrn', 'gb': 'gb', 'sakti': 'sakti', 'blm': 'blm', 'sempet': 'sempet', 'kebeli': 'kebel', 'pembelian': 'beli', 'mantap': 'mantap', 'the': 'the', 'real': 'real', 'entry': 'entry', 'level': 'level', 'killer': 'killer', 'advan': 'advan', 'pulsa': 'pulsa', 'kah': 'kah', 'murah': 'murah', 'kartu': 'kartu', 'rb': 'rb', 'semoga': 'moga', 'beruntung': 'untung', 'uuh': 'uuh', 'tgl': 'tgl', 'september': 'september', 'pket': 'pket', 'ekstra': 'ekstra', 'ketengan': 'keteng', 'youtube': 'youtube', 'uda': 'uda', 'tolong': 'tolong', 'kali': 'kali', 'tolongbkali': 'tolongbkali', 'combo': 'combo', 'thrifty': 'thrifty', 'tlong': 'tlong', 'diadain': 'diadain', 'data': 'data', 'kyk': 'kyk', 'tetangga': 'tetangga', 'sebelah': 'belah', 'disegala': 'segala', 'medan': 'medan', 'internet': 'internet', 'gratis': 'gratis', 'wifi': 'wifi', 'menghemat': 'hemat', 'tlpn': 'tlpn', 'dear': 'dear', 'admin': 'admin', 'baca': 'baca', 'dung': 'dung', 'trim': 'trim', 'lihat': 'lihat', 'terimakasih': 'terimakasih', 'lokal': 'lokal', 'gabisa': 'gabisa', 'tdi': 'tdi', 'dpt': 'dpt', 'telpon': 'telpon', 'nomor': 'nomor', 'pencerahannya': 'cerah', 'mengaktifkan': 'aktif', 'signal': 'signal', 'buruk': 'buruk', 'provider': 'provider', 'gmna': 'gmna', 'komunikasi': 'komunikasi', 'terkendala': 'kendala', 'tanggal': 'tanggal', 'segini': 'gin', 'beli': 'beli', 'paketnya': 'paket', 'penggemar': 'gemar', 'god': 'god', 'bless': 'bless', 'album': 'album', 'favorit': 'favorit', 'ane': 'ane', 'cermin': 'cermin', 'albumnya': 'album', 'progress': 'progress', 'abisss': 'abisss', 'pertunjukannya': 'tunjuk', 'lupa': 'lupa', 'mainkan': 'main', 'selamat': 'selamat', 'pagi': 'pagi', 'indonesia': 'indonesia', 'lagu': 'lagu', 'kisah': 'kisah', 'nyata': 'nyata', 'mantan': 'mantan', 'pejuang': 'juang', 'perampok': 'rampok', 'permisi': 'permisi', 'izin': 'izin', 'profile': 'profile', 'bahaya': 'bahaya', 'keamanan': 'aman', 'palingan': 'paling', 'diblokir': 'blokir', 'ribetnya': 'ribetnya', 'ampun': 'ampun', 'butuh': 'butuh', 'gimana': 'gimana', 'simswap': 'simswap', 'hardjya': 'hardjya', 'redeem': 'redeem', 'klaim': 'klaim', 'hadiah': 'hadiah', 'program': 'program', 'check': 'check', 'blsannya': 'blsannya', 'maaf': 'maaf', 'ambil': 'ambil', 'coba': 'coba', 'restrat': 'restrat', 'berhasil': 'hasil', 'veronika': 'veronika', 'poin': 'poin', 'mencukupi': 'cukup', 'tukar': 'tukar', 'halo': 'halo', 'udah': 'udah', 'minggu': 'minggu', 'superdeal': 'superdeal', 'bner': 'bner', 'brrti': 'brrti', 'kya': 'kya', 'gtu': 'gtu', 'mudah': 'mudah', 'terhindar': 'hindar', 'dri': 'dri', 'gtuan': 'gtuan', 'aamiin': 'aamiin', 'makasi': 'makas', 'kang': 'kang', 'jawabanny': 'jawabanny', 'cuman': 'cuman', 'nerbitkan': 'nerbitkan', 'org': 'org', 'pemiliki': 'milik', 'aslinya': 'asli', 'bener': 'bener', 'tuhh': 'tuhh', 'knpa': 'knpa', 'sllu': 'sllu', 'sms': 'sms', 'jls': 'jls', 'mengatasnamakan': 'mengatasnamakan', 'pinjol': 'pinjol', 'menuhin': 'menuhin', 'kotak': 'kotak', 'tindak': 'tindak', 'tsel': 'tsel', 'pengguna': 'guna', 'setia': 'setia', 'bertaun': 'taun', 'taun': 'taun', 'mas': 'mas', 'salah': ...
# ------------------------
# Pandas Apply:   0%|          | 0/70 [00:00<?, ?it/s]
#                                                   text  \
# 0    @telkomsel min mohon cek dm min mohon sekali m...
# 1    min kenapa telkomsel ga bisa login game mlbb ?...
# 2    min, saya tiba tiba dapet paket denim 6 gb, it...
# 3                         pdhl 4g..tp ga ada garis2nya
# 4                               kenapa sinyal ku ilang
# ..                                                 ...
# 96                                      baca dm ya min
# 97   @telkomsel min saya mau tanya kalo upgrade lin...
# 98                                          cek dm kak
# 99                                   bales dm dong min
# 100       sapa tau rejeki  saya alhamdulillah  aamiin.
#
#                                          cleaning_text  \
# 0    min mohon cek min mohon sekali min udh hari mi...
# 1    min kenapa telkomsel bisa login game mlbb tapi...
# 2    min saya tiba tiba dapet paket denim maksudnya...
# 3                                   pdhl ada garis nya
# 4                                  kenapa sinyal ilang
# ..                                                 ...
# 96                                            baca min
# 97   min saya mau tanya kalo upgrade linkaja grapar...
# 98                                             cek kak
# 99                                      bales dong min
# 100         sapa tau rejeki saya alhamdulillah aamiin
#
#                                             tokenisasi  \
# 0    [min, mohon, cek, min, mohon, sekali, min, udh...
# 1    [min, kenapa, telkomsel, bisa, login, game, ml...
# 2    [min, saya, tiba, tiba, dapet, paket, denim, m...
# 3                              [pdhl, ada, garis, nya]
# 4                              [kenapa, sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, saya, mau, tanya, kalo, upgrade, linkaja...
# 98                                          [cek, kak]
# 99                                  [bales, dong, min]
# 100  [sapa, tau, rejeki, saya, alhamdulillah, aamii...
#
#                                               stopword  \
# 0    [min, mohon, cek, min, mohon, min, udh, min, t...
# 1    [min, telkomsel, login, game, mlbb, buka, dll,...
# 2    [min, dapet, paket, denim, maksudnya, kits, ma...
# 3                                        [pdhl, garis]
# 4                                      [sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, upgrade, linkaja, grapari, telkomsel, sy...
# 98                                          [cek, kak]
# 99                                        [bales, min]
# 100            [sapa, rejeki, alhamdulillah, aamiin, ]
#
#                                               stemming
# 0    [min, mohon, cek, min, mohon, min, udh, min, t...
# 1    [min, telkomsel, login, game, mlbb, buka, dll,...
# 2    [min, dapet, paket, denim, maksud, kits, manti...
# 3                                        [pdhl, garis]
# 4                                      [sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, upgrade, linkaja, grapari, telkomsel, sy...
# 98                                          [cek, kak]
# 99                                        [bales, min]
# 100            [sapa, rejeki, alhamdulillah, aamiin, ]
#
# [70 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [min, mohon, cek, min, mohon, min, udh, min, t...
# 1    [min, telkomsel, login, game, mlbb, buka, dll,...
# 2    [min, dapet, paket, denim, maksud, kits, manti...
# 3                                        [pdhl, garis]
# 4                                      [sinyal, ilang]
# ..                                                 ...
# 96                                         [baca, min]
# 97   [min, upgrade, linkaja, grapari, telkomsel, sy...
# 98                                          [cek, kak]
# 99                                        [bales, min]
# 100            [sapa, rejeki, alhamdulillah, aamiin, ]
#
# [70 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_telkomsel_8.xlsx')
