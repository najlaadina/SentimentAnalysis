# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Setelah Update kenapa makin jelek ni Aplikasi ...      1
# 1     Sumpah my telkomsel susah dibuka. Alasan ada k...      1
# 2     Kenapa aplikasi my Telkomsel sangat buruk seka...      1
# 3     Kok setelah update malah jadi lama buat login ...      1
# 4     Sudah harga paketan dinaikkan tapi fasilitas m...      1
# ...                                                 ...    ...
# 1995  Di aplikasi ada promo paket combo sakti. ketik...      1
# 1996  Mohon perbaikan sinyal ditiap daerah , sangat ...      2
# 1997  Baru update, buka langsung error.. Diulang uni...      1
# 1998  sedih pakai Telkomsel skrng, waktu pertama kel...      3
# 1999  Woii telkomsel paket internet khusus ojol klw ...      1
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Setelah Update kenapa makin jelek ni Aplikasi ...      1
# 1     Sumpah my telkomsel susah dibuka. Alasan ada k...      1
# 2     Kenapa aplikasi my Telkomsel sangat buruk seka...      1
# 3     Kok setelah update malah jadi lama buat login ...      1
# 4     Sudah harga paketan dinaikkan tapi fasilitas m...      1
# ...                                                 ...    ...
# 1995  Di aplikasi ada promo paket combo sakti. ketik...      1
# 1996  Mohon perbaikan sinyal ditiap daerah , sangat ...      2
# 1997  Baru update, buka langsung error.. Diulang uni...      1
# 1998  sedih pakai Telkomsel skrng, waktu pertama kel...      3
# 1999  Woii telkomsel paket internet khusus ojol klw ...      1
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     setelah update kenapa makin jelek ni aplikasi ...      1
# 1     sumpah my telkomsel susah dibuka. alasan ada k...      1
# 2     kenapa aplikasi my telkomsel sangat buruk seka...      1
# 3     kok setelah update malah jadi lama buat login ...      1
# 4     sudah harga paketan dinaikkan tapi fasilitas m...      1
# ...                                                 ...    ...
# 1995  di aplikasi ada promo paket combo sakti. ketik...      1
# 1996  mohon perbaikan sinyal ditiap daerah , sangat ...      2
# 1997  baru update, buka langsung error.. diulang uni...      1
# 1998  sedih pakai telkomsel skrng, waktu pertama kel...      3
# 1999  woii telkomsel paket internet khusus ojol klw ...      1
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     setelah update kenapa makin jelek ni aplikasi ...      1
# 1     sumpah my telkomsel susah dibuka. alasan ada k...      1
# 2     kenapa aplikasi my telkomsel sangat buruk seka...      1
# 3     kok setelah update malah jadi lama buat login ...      1
# 4     sudah harga paketan dinaikkan tapi fasilitas m...      1
# ...                                                 ...    ...
# 1995  di aplikasi ada promo paket combo sakti. ketik...      1
# 1996  mohon perbaikan sinyal ditiap daerah , sangat ...      2
# 1997  baru update, buka langsung error.. diulang uni...      1
# 1998  sedih pakai telkomsel skrng, waktu pertama kel...      3
# 1999  woii telkomsel paket internet khusus ojol klw ...      1
#
#                                        cleaning_content
# 0     setelah update kenapa makin jelek aplikasi mau...
# 1     sumpah telkomsel susah dibuka alasan ada kesal...
# 2     kenapa aplikasi telkomsel sangat buruk sekaran...
# 3     kok setelah update malah jadi lama buat login ...
# 4     sudah harga paketan dinaikkan tapi fasilitas m...
# ...                                                 ...
# 1995   aplikasi ada promo paket combo sakti ketika s...
# 1996  mohon perbaikan sinyal ditiap daerah sangat di...
# 1997  baru update buka langsung error diulang uninst...
# 1998  sedih pakai telkomsel skrng waktu pertama kelu...
# 1999  woii telkomsel paket internet khusus ojol klw ...
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     setelah update kenapa makin jelek ni aplikasi ...      1
# 1     sumpah my telkomsel susah dibuka. alasan ada k...      1
# 2     kenapa aplikasi my telkomsel sangat buruk seka...      1
# 3     kok setelah update malah jadi lama buat login ...      1
# 4     sudah harga paketan dinaikkan tapi fasilitas m...      1
# ...                                                 ...    ...
# 1995  di aplikasi ada promo paket combo sakti. ketik...      1
# 1996  mohon perbaikan sinyal ditiap daerah , sangat ...      2
# 1997  baru update, buka langsung error.. diulang uni...      1
# 1998  sedih pakai telkomsel skrng, waktu pertama kel...      3
# 1999  woii telkomsel paket internet khusus ojol klw ...      1
#
#                                        cleaning_content  \
# 0     setelah update kenapa makin jelek aplikasi mau...
# 1     sumpah telkomsel susah dibuka alasan ada kesal...
# 2     kenapa aplikasi telkomsel sangat buruk sekaran...
# 3     kok setelah update malah jadi lama buat login ...
# 4     sudah harga paketan dinaikkan tapi fasilitas m...
# ...                                                 ...
# 1995   aplikasi ada promo paket combo sakti ketika s...
# 1996  mohon perbaikan sinyal ditiap daerah sangat di...
# 1997  baru update buka langsung error diulang uninst...
# 1998  sedih pakai telkomsel skrng waktu pertama kelu...
# 1999  woii telkomsel paket internet khusus ojol klw ...
#
#                                              tokenisasi
# 0     [setelah, update, kenapa, makin, jelek, aplika...
# 1     [sumpah, telkomsel, susah, dibuka, alasan, ada...
# 2     [kenapa, aplikasi, telkomsel, sangat, buruk, s...
# 3     [kok, setelah, update, malah, jadi, lama, buat...
# 4     [sudah, harga, paketan, dinaikkan, tapi, fasil...
# ...                                                 ...
# 1995  [, aplikasi, ada, promo, paket, combo, sakti, ...
# 1996  [mohon, perbaikan, sinyal, ditiap, daerah, san...
# 1997  [baru, update, buka, langsung, error, diulang,...
# 1998  [sedih, pakai, telkomsel, skrng, waktu, pertam...
# 1999  [woii, telkomsel, paket, internet, khusus, ojo...
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     setelah update kenapa makin jelek ni aplikasi ...      1
# 1     sumpah my telkomsel susah dibuka. alasan ada k...      1
# 2     kenapa aplikasi my telkomsel sangat buruk seka...      1
# 3     kok setelah update malah jadi lama buat login ...      1
# 4     sudah harga paketan dinaikkan tapi fasilitas m...      1
# ...                                                 ...    ...
# 1995  di aplikasi ada promo paket combo sakti. ketik...      1
# 1996  mohon perbaikan sinyal ditiap daerah , sangat ...      2
# 1997  baru update, buka langsung error.. diulang uni...      1
# 1998  sedih pakai telkomsel skrng, waktu pertama kel...      3
# 1999  woii telkomsel paket internet khusus ojol klw ...      1
#
#                                        cleaning_content  \
# 0     setelah update kenapa makin jelek aplikasi mau...
# 1     sumpah telkomsel susah dibuka alasan ada kesal...
# 2     kenapa aplikasi telkomsel sangat buruk sekaran...
# 3     kok setelah update malah jadi lama buat login ...
# 4     sudah harga paketan dinaikkan tapi fasilitas m...
# ...                                                 ...
# 1995   aplikasi ada promo paket combo sakti ketika s...
# 1996  mohon perbaikan sinyal ditiap daerah sangat di...
# 1997  baru update buka langsung error diulang uninst...
# 1998  sedih pakai telkomsel skrng waktu pertama kelu...
# 1999  woii telkomsel paket internet khusus ojol klw ...
#
#                                              tokenisasi  \
# 0     [setelah, update, kenapa, makin, jelek, aplika...
# 1     [sumpah, telkomsel, susah, dibuka, alasan, ada...
# 2     [kenapa, aplikasi, telkomsel, sangat, buruk, s...
# 3     [kok, setelah, update, malah, jadi, lama, buat...
# 4     [sudah, harga, paketan, dinaikkan, tapi, fasil...
# ...                                                 ...
# 1995  [, aplikasi, ada, promo, paket, combo, sakti, ...
# 1996  [mohon, perbaikan, sinyal, ditiap, daerah, san...
# 1997  [baru, update, buka, langsung, error, diulang,...
# 1998  [sedih, pakai, telkomsel, skrng, waktu, pertam...
# 1999  [woii, telkomsel, paket, internet, khusus, ojo...
#
#                                                stopword
# 0     [update, jelek, aplikasi, login, mencoba, berk...
# 1     [sumpah, telkomsel, susah, dibuka, alasan, kes...
# 2     [aplikasi, telkomsel, buruk, membuka, aplikasi...
# 3     [update, login, gini, dapet, gini, ngasih, pel...
# 4     [harga, paketan, dinaikkan, fasilitas, dikuran...
# ...                                                 ...
# 1995  [, aplikasi, promo, paket, combo, sakti, isi, ...
# 1996  [mohon, perbaikan, sinyal, ditiap, daerah, dis...
# 1997  [update, buka, langsung, error, diulang, unins...
# 1998  [sedih, pakai, telkomsel, skrng, kartu, combos...
# 1999  [woii, telkomsel, paket, internet, khusus, ojo...
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [update, jelek, aplikasi, login, mencoba, berk...      1
# 1     [sumpah, telkomsel, susah, dibuka, alasan, kes...      1
# 2     [aplikasi, telkomsel, buruk, membuka, aplikasi...      1
# 3     [update, login, gini, dapet, gini, ngasih, pel...      1
# 4     [harga, paketan, dinaikkan, fasilitas, dikuran...      1
# ...                                                 ...    ...
# 2636  [jam, paket, kasih, tanggal, doang, kaya, tang...      2
# 2637  [waah, parah, neh, kemaren, bermasalah, aplika...      1
# 2638  [telkomsel, jangkauan, luas, saking, luasnya, ...      5
# 2639  [byk, pengguna, bebenah, parah, sinyal, pulsa,...      1
# 2640  [ngeleg, versi, terbaru, kaya, jaringan, pas, ...      4
#
# [2641 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_7.xlsx')
