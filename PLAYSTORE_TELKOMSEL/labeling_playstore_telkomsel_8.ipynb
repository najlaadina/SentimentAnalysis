# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["text_review_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\databersih_english_playstore_telkomsel\databersih_english_playstore_telkomsel_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                     text_review_english
# 0     ['Telkomsel', 'Maling', 'Credit', 'Kouta', 'GB...
# 1     ['number', 'Different', 'quota', 'price', 'dif...
# 2     ['', 'Region', 'Tanjung', 'Sari', 'Natar', 'La...
# 3     ['', 'Telkomsel', 'update', 'ugly', 'good', 'u...
# 4     ['Application', 'garbage', 'RAM', 'Cave', 'GB'...
# ...                                                 ...
# 1920  ['Mao', 'activation', 'Package', 'Open', 'Appl...
# 1921  ['suprise', 'Deal', 'Unlimited', 'Adin', 'Min'...
# 1922  ['sucked', 'credit', 'data', 'already', 'Matii...
# 1923  ['Hello', 'UDH', 'Open', 'Application', 'Telko...
# 1924  ['Telkomsel', 'yrs',' number ',' bbrp ',' upda...
#
# [1925 rows x 1 columns]

# %%
df['text_review_english'] = df['text_review_english'].str.lower()
df.head(2000)
# Out:
#                                     text_review_english
# 0     ['telkomsel', 'maling', 'credit', 'kouta', 'gb...
# 1     ['number', 'different', 'quota', 'price', 'dif...
# 2     ['', 'region', 'tanjung', 'sari', 'natar', 'la...
# 3     ['', 'telkomsel', 'update', 'ugly', 'good', 'u...
# 4     ['application', 'garbage', 'ram', 'cave', 'gb'...
# ...                                                 ...
# 1920  ['mao', 'activation', 'package', 'open', 'appl...
# 1921  ['suprise', 'deal', 'unlimited', 'adin', 'min'...
# 1922  ['sucked', 'credit', 'data', 'already', 'matii...
# 1923  ['hello', 'udh', 'open', 'application', 'telko...
# 1924  ['telkomsel', 'yrs',' number ',' bbrp ',' upda...
#
# [1925 rows x 1 columns]

# %%
df['label_awal'] = ''
for i,x in df.text_review_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.3333333333333333
# Index:  1 label_awal -0.25
# Index:  2 label_awal -0.30000000000000004
# Index:  3 label_awal -0.175
# Index:  4 label_awal -0.06666666666666667
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.2
# Index:  7 label_awal 0.13636363636363635
# Index:  8 label_awal 0.24000000000000005
# Index:  9 label_awal -0.47500000000000003
# Index:  10 label_awal 0.07999999999999999
# Index:  11 label_awal -0.35
# Index:  12 label_awal -0.2
# Index:  13 label_awal 0.0
# Index:  14 label_awal -0.09285714285714286
# Index:  15 label_awal 0.5
# Index:  16 label_awal 0.35
# Index:  17 label_awal -0.20476190476190473
# Index:  18 label_awal 0.15
# Index:  19 label_awal 0.25
# Index:  20 label_awal -0.26666666666666666
# Index:  21 label_awal 0.0
# Index:  22 label_awal 0.45
# Index:  23 label_awal -0.07500000000000001
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.35555555555555557
# Index:  26 label_awal -0.4
# Index:  27 label_awal 0.5
# ...

# %%
df.head()
# Out:
#                                  text_review_english label_awal
# 0  ['telkomsel', 'maling', 'credit', 'kouta', 'gb...   0.333333
# 1  ['number', 'different', 'quota', 'price', 'dif...      -0.25
# 2  ['', 'region', 'tanjung', 'sari', 'natar', 'la...       -0.3
# 3  ['', 'telkomsel', 'update', 'ugly', 'good', 'u...     -0.175
# 4  ['application', 'garbage', 'ram', 'cave', 'gb'...  -0.066667

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    259
# -0.500000     66
#  0.500000     34
# -0.250000     24
# -0.750000     24
#             ...
# -0.082222      1
#  0.183333      1
#  0.400000      1
#  0.552381      1
#  0.016667      1
# Name: label_awal, Length: 741, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] < 0.0:
        label.append("negative")
    else:
        label.append("positive")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                     text_review_english     label
# 0     ['telkomsel', 'maling', 'credit', 'kouta', 'gb...  positive
# 1     ['number', 'different', 'quota', 'price', 'dif...  negative
# 2     ['', 'region', 'tanjung', 'sari', 'natar', 'la...  negative
# 3     ['', 'telkomsel', 'update', 'ugly', 'good', 'u...  negative
# 4     ['application', 'garbage', 'ram', 'cave', 'gb'...  negative
# ...                                                 ...       ...
# 1920  ['mao', 'activation', 'package', 'open', 'appl...  positive
# 1921  ['suprise', 'deal', 'unlimited', 'adin', 'min'...  positive
# 1922  ['sucked', 'credit', 'data', 'already', 'matii...  positive
# 1923  ['hello', 'udh', 'open', 'application', 'telko...  negative
# 1924  ['telkomsel', 'yrs',' number ',' bbrp ',' upda...  positive
#
# [1925 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# negative    974
# positive    951
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_playstore_telkomsel_8.xlsx')
