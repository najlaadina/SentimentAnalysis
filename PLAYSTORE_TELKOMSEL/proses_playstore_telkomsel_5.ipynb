# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Memudh kan sekali, dalam segal hal untuk ngece...      5
# 1     Okehh sih 5G, saya ucapkan selamat. Device say...      1
# 2     Kok paket data saya gak bisa di pake ya katany...      1
# 3     Please.. di tingkatkan untuk Jaringan internet...      4
# 4     Misi nih kok paketnya naik yah walaupun cuma s...      2
# ...                                                 ...    ...
# 1995  Saya sangat kecewa dengan Telkomsel saat ini k...      1
# 1996  Lebih d tingkatkan kualitas signal nya aja dul...      4
# 1997  Saya mau tanya nih kenapa sekarang telkomsel j...      1
# 1998  Parah saya dari awal pake handphone udh pakai ...      1
# 1999  Saya sdh membeli Kouta ketengan YouTube dan wa...      1
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Memudh kan sekali, dalam segal hal untuk ngece...      5
# 1     Okehh sih 5G, saya ucapkan selamat. Device say...      1
# 2     Kok paket data saya gak bisa di pake ya katany...      1
# 3     Please.. di tingkatkan untuk Jaringan internet...      4
# 4     Misi nih kok paketnya naik yah walaupun cuma s...      2
# ...                                                 ...    ...
# 1995  Saya sangat kecewa dengan Telkomsel saat ini k...      1
# 1996  Lebih d tingkatkan kualitas signal nya aja dul...      4
# 1997  Saya mau tanya nih kenapa sekarang telkomsel j...      1
# 1998  Parah saya dari awal pake handphone udh pakai ...      1
# 1999  Saya sdh membeli Kouta ketengan YouTube dan wa...      1
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     memudh kan sekali, dalam segal hal untuk ngece...      5
# 1     okehh sih 5g, saya ucapkan selamat. device say...      1
# 2     kok paket data saya gak bisa di pake ya katany...      1
# 3     please.. di tingkatkan untuk jaringan internet...      4
# 4     misi nih kok paketnya naik yah walaupun cuma s...      2
# ...                                                 ...    ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...      1
# 1996  lebih d tingkatkan kualitas signal nya aja dul...      4
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...      1
# 1998  parah saya dari awal pake handphone udh pakai ...      1
# 1999  saya sdh membeli kouta ketengan youtube dan wa...      1
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     memudh kan sekali, dalam segal hal untuk ngece...      5
# 1     okehh sih 5g, saya ucapkan selamat. device say...      1
# 2     kok paket data saya gak bisa di pake ya katany...      1
# 3     please.. di tingkatkan untuk jaringan internet...      4
# 4     misi nih kok paketnya naik yah walaupun cuma s...      2
# ...                                                 ...    ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...      1
# 1996  lebih d tingkatkan kualitas signal nya aja dul...      4
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...      1
# 1998  parah saya dari awal pake handphone udh pakai ...      1
# 1999  saya sdh membeli kouta ketengan youtube dan wa...      1
#
#                                        cleaning_content
# 0     memudh kan sekali dalam segal hal untuk ngecek...
# 1     okehh sih saya ucapkan selamat device saya mun...
# 2     kok paket data saya gak bisa pake katanya game...
# 3     please tingkatkan untuk jaringan internet sepu...
# 4     misi nih kok paketnya naik yah walaupun cuma s...
# ...                                                 ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...
# 1996  lebih tingkatkan kualitas signal nya aja dulu ...
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...
# 1998  parah saya dari awal pake handphone udh pakai ...
# 1999  saya sdh membeli kouta ketengan youtube dan wa...
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     memudh kan sekali, dalam segal hal untuk ngece...      5
# 1     okehh sih 5g, saya ucapkan selamat. device say...      1
# 2     kok paket data saya gak bisa di pake ya katany...      1
# 3     please.. di tingkatkan untuk jaringan internet...      4
# 4     misi nih kok paketnya naik yah walaupun cuma s...      2
# ...                                                 ...    ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...      1
# 1996  lebih d tingkatkan kualitas signal nya aja dul...      4
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...      1
# 1998  parah saya dari awal pake handphone udh pakai ...      1
# 1999  saya sdh membeli kouta ketengan youtube dan wa...      1
#
#                                        cleaning_content  \
# 0     memudh kan sekali dalam segal hal untuk ngecek...
# 1     okehh sih saya ucapkan selamat device saya mun...
# 2     kok paket data saya gak bisa pake katanya game...
# 3     please tingkatkan untuk jaringan internet sepu...
# 4     misi nih kok paketnya naik yah walaupun cuma s...
# ...                                                 ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...
# 1996  lebih tingkatkan kualitas signal nya aja dulu ...
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...
# 1998  parah saya dari awal pake handphone udh pakai ...
# 1999  saya sdh membeli kouta ketengan youtube dan wa...
#
#                                              tokenisasi
# 0     [memudh, kan, sekali, dalam, segal, hal, untuk...
# 1     [okehh, sih, saya, ucapkan, selamat, device, s...
# 2     [kok, paket, data, saya, gak, bisa, pake, kata...
# 3     [please, tingkatkan, untuk, jaringan, internet...
# 4     [misi, nih, kok, paketnya, naik, yah, walaupun...
# ...                                                 ...
# 1995  [saya, sangat, kecewa, dengan, telkomsel, saat...
# 1996  [lebih, tingkatkan, kualitas, signal, nya, aja...
# 1997  [saya, mau, tanya, nih, kenapa, sekarang, telk...
# 1998  [parah, saya, dari, awal, pake, handphone, udh...
# 1999  [saya, sdh, membeli, kouta, ketengan, youtube,...
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     memudh kan sekali, dalam segal hal untuk ngece...      5
# 1     okehh sih 5g, saya ucapkan selamat. device say...      1
# 2     kok paket data saya gak bisa di pake ya katany...      1
# 3     please.. di tingkatkan untuk jaringan internet...      4
# 4     misi nih kok paketnya naik yah walaupun cuma s...      2
# ...                                                 ...    ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...      1
# 1996  lebih d tingkatkan kualitas signal nya aja dul...      4
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...      1
# 1998  parah saya dari awal pake handphone udh pakai ...      1
# 1999  saya sdh membeli kouta ketengan youtube dan wa...      1
#
#                                        cleaning_content  \
# 0     memudh kan sekali dalam segal hal untuk ngecek...
# 1     okehh sih saya ucapkan selamat device saya mun...
# 2     kok paket data saya gak bisa pake katanya game...
# 3     please tingkatkan untuk jaringan internet sepu...
# 4     misi nih kok paketnya naik yah walaupun cuma s...
# ...                                                 ...
# 1995  saya sangat kecewa dengan telkomsel saat ini k...
# 1996  lebih tingkatkan kualitas signal nya aja dulu ...
# 1997  saya mau tanya nih kenapa sekarang telkomsel j...
# 1998  parah saya dari awal pake handphone udh pakai ...
# 1999  saya sdh membeli kouta ketengan youtube dan wa...
#
#                                              tokenisasi  \
# 0     [memudh, kan, sekali, dalam, segal, hal, untuk...
# 1     [okehh, sih, saya, ucapkan, selamat, device, s...
# 2     [kok, paket, data, saya, gak, bisa, pake, kata...
# 3     [please, tingkatkan, untuk, jaringan, internet...
# 4     [misi, nih, kok, paketnya, naik, yah, walaupun...
# ...                                                 ...
# 1995  [saya, sangat, kecewa, dengan, telkomsel, saat...
# 1996  [lebih, tingkatkan, kualitas, signal, nya, aja...
# 1997  [saya, mau, tanya, nih, kenapa, sekarang, telk...
# 1998  [parah, saya, dari, awal, pake, handphone, udh...
# 1999  [saya, sdh, membeli, kouta, ketengan, youtube,...
#
#                                                stopword
# 0     [memudh, segal, ngecek, informasi, telkomsel, ...
# 1     [okehh, ucapkan, selamat, device, support, seb...
# 2     [paket, data, games, dll, pas, buka, game, buk...
# 3     [please, tingkatkan, jaringan, internet, seput...
# 4     [misi, paketnya, serebu, tolong, balikin, sere...
# ...                                                 ...
# 1995  [kecewa, telkomsel, paket, unlimited, dibatasi...
# 1996  [tingkatkan, kualitas, signal, telkomsel, memi...
# 1997  [telkomsel, jaringan, lelet, lemot, notif, kon...
# 1998  [parah, handphone, udh, pakai, telkomsel, isi,...
# 1999  [membeli, kouta, ketengan, youtube, nonton, yo...
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [memudh, segal, ngecek, informasi, telkomsel, ...      5
# 1     [okehh, ucapkan, selamat, device, support, seb...      1
# 2     [paket, data, games, dll, pas, buka, game, buk...      1
# 3     [please, tingkatkan, jaringan, internet, seput...      4
# 4     [misi, paketnya, serebu, tolong, balikin, sere...      2
# ...                                                 ...    ...
# 2128  [beli, paket, data, lelet, cok, wifi, mbps, me...      1
# 2129  [sinyal, buruk, jam, malam, sinyal, hilang, hu...      1
# 2130  [kartu, telkomsel, udah, dapet, paket, interne...      1
# 2131  [senang, telkomsel, keuntungan, harga, paket, ...      5
# 2132  [aplikasinya, bagus, dapet, email, komen, perf...      5
#
# [2133 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_5.xlsx')
