# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#       score                                            content
# 0         2  Tolong kepada pihak my Telkomsel kenapa saya t...
# 1         1  Apaan nih telkomsel, susah amat jaringan buat ...
# 2         5  The best lah buat Aplikasi MyTelkomsel, dapat ...
# 3         1  Apa apaan ini nama nya, masa koneksi jaringan ...
# 4         1  Padahal saya gk ada hidupin data,kenapa di bia...
# ...     ...                                                ...
# 1995      4  Kenpa sekarang my telkom susah sekali di buka,...
# 1996      1  Saya menyesal aktif kan paket data simpati,, H...
# 1997      1  Giliran buak appnya lancar banget... Kalo buka...
# 1998      1  Dah mahal, jaringan buriknya minta ampun padah...
# 1999      1  Slmat malam nma saya angga, mohon maaf nih, ke...
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#       score                                            content
# 0         2  Tolong kepada pihak my Telkomsel kenapa saya t...
# 1         1  Apaan nih telkomsel, susah amat jaringan buat ...
# 2         5  The best lah buat Aplikasi MyTelkomsel, dapat ...
# 3         1  Apa apaan ini nama nya, masa koneksi jaringan ...
# 4         1  Padahal saya gk ada hidupin data,kenapa di bia...
# ...     ...                                                ...
# 1995      4  Kenpa sekarang my telkom susah sekali di buka,...
# 1996      1  Saya menyesal aktif kan paket data simpati,, H...
# 1997      1  Giliran buak appnya lancar banget... Kalo buka...
# 1998      1  Dah mahal, jaringan buriknya minta ampun padah...
# 1999      1  Slmat malam nma saya angga, mohon maaf nih, ke...
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#       score                                            content
# 0         2  tolong kepada pihak my telkomsel kenapa saya t...
# 1         1  apaan nih telkomsel, susah amat jaringan buat ...
# 2         5  the best lah buat aplikasi mytelkomsel, dapat ...
# 3         1  apa apaan ini nama nya, masa koneksi jaringan ...
# 4         1  padahal saya gk ada hidupin data,kenapa di bia...
# ...     ...                                                ...
# 1995      4  kenpa sekarang my telkom susah sekali di buka,...
# 1996      1  saya menyesal aktif kan paket data simpati,, h...
# 1997      1  giliran buak appnya lancar banget... kalo buka...
# 1998      1  dah mahal, jaringan buriknya minta ampun padah...
# 1999      1  slmat malam nma saya angga, mohon maaf nih, ke...
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#       score                                            content  \
# 0         2  tolong kepada pihak my telkomsel kenapa saya t...
# 1         1  apaan nih telkomsel, susah amat jaringan buat ...
# 2         5  the best lah buat aplikasi mytelkomsel, dapat ...
# 3         1  apa apaan ini nama nya, masa koneksi jaringan ...
# 4         1  padahal saya gk ada hidupin data,kenapa di bia...
# ...     ...                                                ...
# 1995      4  kenpa sekarang my telkom susah sekali di buka,...
# 1996      1  saya menyesal aktif kan paket data simpati,, h...
# 1997      1  giliran buak appnya lancar banget... kalo buka...
# 1998      1  dah mahal, jaringan buriknya minta ampun padah...
# 1999      1  slmat malam nma saya angga, mohon maaf nih, ke...
#
#                                        cleaning_content
# 0     tolong kepada pihak telkomsel kenapa saya tida...
# 1     apaan nih telkomsel susah amat jaringan buat n...
# 2     the best lah buat aplikasi mytelkomsel dapat m...
# 3     apa apaan ini nama nya masa koneksi jaringan h...
# 4     padahal saya ada hidupin data kenapa biaya tra...
# ...                                                 ...
# 1995  kenpa sekarang telkom susah sekali buka terus ...
# 1996  saya menyesal aktif kan paket data simpati han...
# 1997  giliran buak appnya lancar banget kalo bukan a...
# 1998  dah mahal jaringan buriknya minta ampun padaha...
# 1999  slmat malam nma saya angga mohon maaf nih kenp...
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#       score                                            content  \
# 0         2  tolong kepada pihak my telkomsel kenapa saya t...
# 1         1  apaan nih telkomsel, susah amat jaringan buat ...
# 2         5  the best lah buat aplikasi mytelkomsel, dapat ...
# 3         1  apa apaan ini nama nya, masa koneksi jaringan ...
# 4         1  padahal saya gk ada hidupin data,kenapa di bia...
# ...     ...                                                ...
# 1995      4  kenpa sekarang my telkom susah sekali di buka,...
# 1996      1  saya menyesal aktif kan paket data simpati,, h...
# 1997      1  giliran buak appnya lancar banget... kalo buka...
# 1998      1  dah mahal, jaringan buriknya minta ampun padah...
# 1999      1  slmat malam nma saya angga, mohon maaf nih, ke...
#
#                                        cleaning_content  \
# 0     tolong kepada pihak telkomsel kenapa saya tida...
# 1     apaan nih telkomsel susah amat jaringan buat n...
# 2     the best lah buat aplikasi mytelkomsel dapat m...
# 3     apa apaan ini nama nya masa koneksi jaringan h...
# 4     padahal saya ada hidupin data kenapa biaya tra...
# ...                                                 ...
# 1995  kenpa sekarang telkom susah sekali buka terus ...
# 1996  saya menyesal aktif kan paket data simpati han...
# 1997  giliran buak appnya lancar banget kalo bukan a...
# 1998  dah mahal jaringan buriknya minta ampun padaha...
# 1999  slmat malam nma saya angga mohon maaf nih kenp...
#
#                                              tokenisasi
# 0     [tolong, kepada, pihak, telkomsel, kenapa, say...
# 1     [apaan, nih, telkomsel, susah, amat, jaringan,...
# 2     [the, best, lah, buat, aplikasi, mytelkomsel, ...
# 3     [apa, apaan, ini, nama, nya, masa, koneksi, ja...
# 4     [padahal, saya, ada, hidupin, data, kenapa, bi...
# ...                                                 ...
# 1995  [kenpa, sekarang, telkom, susah, sekali, buka,...
# 1996  [saya, menyesal, aktif, kan, paket, data, simp...
# 1997  [giliran, buak, appnya, lancar, banget, kalo, ...
# 1998  [dah, mahal, jaringan, buriknya, minta, ampun,...
# 1999  [slmat, malam, nma, saya, angga, mohon, maaf, ...
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#       score                                            content  \
# 0         2  tolong kepada pihak my telkomsel kenapa saya t...
# 1         1  apaan nih telkomsel, susah amat jaringan buat ...
# 2         5  the best lah buat aplikasi mytelkomsel, dapat ...
# 3         1  apa apaan ini nama nya, masa koneksi jaringan ...
# 4         1  padahal saya gk ada hidupin data,kenapa di bia...
# ...     ...                                                ...
# 1995      4  kenpa sekarang my telkom susah sekali di buka,...
# 1996      1  saya menyesal aktif kan paket data simpati,, h...
# 1997      1  giliran buak appnya lancar banget... kalo buka...
# 1998      1  dah mahal, jaringan buriknya minta ampun padah...
# 1999      1  slmat malam nma saya angga, mohon maaf nih, ke...
#
#                                        cleaning_content  \
# 0     tolong kepada pihak telkomsel kenapa saya tida...
# 1     apaan nih telkomsel susah amat jaringan buat n...
# 2     the best lah buat aplikasi mytelkomsel dapat m...
# 3     apa apaan ini nama nya masa koneksi jaringan h...
# 4     padahal saya ada hidupin data kenapa biaya tra...
# ...                                                 ...
# 1995  kenpa sekarang telkom susah sekali buka terus ...
# 1996  saya menyesal aktif kan paket data simpati han...
# 1997  giliran buak appnya lancar banget kalo bukan a...
# 1998  dah mahal jaringan buriknya minta ampun padaha...
# 1999  slmat malam nma saya angga mohon maaf nih kenp...
#
#                                              tokenisasi  \
# 0     [tolong, kepada, pihak, telkomsel, kenapa, say...
# 1     [apaan, nih, telkomsel, susah, amat, jaringan,...
# 2     [the, best, lah, buat, aplikasi, mytelkomsel, ...
# 3     [apa, apaan, ini, nama, nya, masa, koneksi, ja...
# 4     [padahal, saya, ada, hidupin, data, kenapa, bi...
# ...                                                 ...
# 1995  [kenpa, sekarang, telkom, susah, sekali, buka,...
# 1996  [saya, menyesal, aktif, kan, paket, data, simp...
# 1997  [giliran, buak, appnya, lancar, banget, kalo, ...
# 1998  [dah, mahal, jaringan, buriknya, minta, ampun,...
# 1999  [slmat, malam, nma, saya, angga, mohon, maaf, ...
#
#                                                stopword
# 0     [tolong, telkomsel, paket, darurat, mohon, tin...
# 1     [telkomsel, susah, jaringan, ngegame, kesel, j...
# 2     [the, best, aplikasi, mytelkomsel, memudahkan,...
# 3     [nama, koneksi, jaringan, hancur, terusan, knp...
# 4     [hidupin, data, biaya, transaksi, pemakaian, d...
# ...                                                 ...
# 1995  [kenpa, telkom, susah, buka, sinyal, suka, hil...
# 1996  [menyesal, aktif, paket, data, simpati, karna,...
# 1997  [giliran, buak, appnya, lancar, banget, app, l...
# 1998  [mahal, jaringan, buriknya, ampun, udah, kota,...
# 1999  [slmat, malam, nma, angga, mohon, maaf, kenpa,...
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [tolong, telkomsel, paket, darurat, mohon, tin...      2
# 1     [telkomsel, susah, jaringan, ngegame, kesel, j...      1
# 2     [the, best, aplikasi, mytelkomsel, memudahkan,...      5
# 3     [nama, koneksi, jaringan, hancur, terusan, knp...      1
# 4     [hidupin, data, biaya, transaksi, pemakaian, d...      1
# ...                                                 ...    ...
# 5236  [paketnya, masuk, akal, mending, hapus, combo,...      1
# 5237                                   [mantap, baca, ]      5
# 5238  [redeem, poin, saldo, link, parah, banget, ema...      1
# 5239  [pelayanan, jam, kaga, bales, sinyal, bagus, b...      1
# 5240  [kualitas, pelayanan, bangus, kualitas, sinyal...      4
#
# [5241 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_9.xlsx')
