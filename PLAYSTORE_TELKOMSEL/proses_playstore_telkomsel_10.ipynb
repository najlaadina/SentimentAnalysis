# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#       score                                            content
# 0         5  bagus sekali saya suka apk ini ###############...
# 1         1  Telkomsel ngebadut mulu suruh DM mulu lu perba...
# 2         1  Aplikasi provider macam apa ini. Buka app kok ...
# 3         1  Klo mati listrik lngsung hilang sinyalnya...ga...
# 4         5  Ok Juga lho apalag yg menu internet sakti..bua...
# ...     ...                                                ...
# 1995      5                         Bagus aplikasinya, mantap.
# 1996      5                               Telkomsel memang no1
# 1997      5                            app ini sangat membantu
# 1998      2                      Semoga sukses untuk Telkomsel
# 1999      1  Aplikasi bagus...cuma syang makin lelet jaring...
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 400

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#       score                                            content
# 0         5  bagus sekali saya suka apk ini ###############...
# 1         1  Telkomsel ngebadut mulu suruh DM mulu lu perba...
# 2         1  Aplikasi provider macam apa ini. Buka app kok ...
# 3         1  Klo mati listrik lngsung hilang sinyalnya...ga...
# 4         5  Ok Juga lho apalag yg menu internet sakti..bua...
# ...     ...                                                ...
# 2131      5                     keren ada belajar English juga
# 2132      1                         Sinyal sangat buruk. Lemot
# 2133      5  suka banget... memudahkan transaksi pembelian ...
# 2134      2  Pemenang undia telokomsel point TIDAK JELAS, s...
# 2135      1                     Sanagat baik kali jaringan nya
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#       score                                            content
# 0         5  bagus sekali saya suka apk ini ###############...
# 1         1  telkomsel ngebadut mulu suruh dm mulu lu perba...
# 2         1  aplikasi provider macam apa ini. buka app kok ...
# 3         1  klo mati listrik lngsung hilang sinyalnya...ga...
# 4         5  ok juga lho apalag yg menu internet sakti..bua...
# ...     ...                                                ...
# 2131      5                     keren ada belajar english juga
# 2132      1                         sinyal sangat buruk. lemot
# 2133      5  suka banget... memudahkan transaksi pembelian ...
# 2134      2  pemenang undia telokomsel point tidak jelas, s...
# 2135      1                     sanagat baik kali jaringan nya
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#       score                                            content  \
# 0         5  bagus sekali saya suka apk ini ###############...
# 1         1  telkomsel ngebadut mulu suruh dm mulu lu perba...
# 2         1  aplikasi provider macam apa ini. buka app kok ...
# 3         1  klo mati listrik lngsung hilang sinyalnya...ga...
# 4         5  ok juga lho apalag yg menu internet sakti..bua...
# ...     ...                                                ...
# 2131      5                     keren ada belajar english juga
# 2132      1                         sinyal sangat buruk. lemot
# 2133      5  suka banget... memudahkan transaksi pembelian ...
# 2134      2  pemenang undia telokomsel point tidak jelas, s...
# 2135      1                     sanagat baik kali jaringan nya
#
#                                        cleaning_content
# 0                       bagus sekali saya suka apk ini
# 1     telkomsel ngebadut mulu suruh mulu perbaiki la...
# 2     aplikasi provider macam apa ini buka app kok l...
# 3     klo mati listrik lngsung hilang sinyalnya gak ...
# 4      juga lho apalag menu internet sakti buat cari...
# ...                                                 ...
# 2131                     keren ada belajar english juga
# 2132                          sinyal sangat buruk lemot
# 2133  suka banget memudahkan transaksi pembelian pul...
# 2134  pemenang undia telokomsel point tidak jelas si...
# 2135                     sanagat baik kali jaringan nya
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#       score                                            content  \
# 0         5  bagus sekali saya suka apk ini ###############...
# 1         1  telkomsel ngebadut mulu suruh dm mulu lu perba...
# 2         1  aplikasi provider macam apa ini. buka app kok ...
# 3         1  klo mati listrik lngsung hilang sinyalnya...ga...
# 4         5  ok juga lho apalag yg menu internet sakti..bua...
# ...     ...                                                ...
# 2131      5                     keren ada belajar english juga
# 2132      1                         sinyal sangat buruk. lemot
# 2133      5  suka banget... memudahkan transaksi pembelian ...
# 2134      2  pemenang undia telokomsel point tidak jelas, s...
# 2135      1                     sanagat baik kali jaringan nya
#
#                                        cleaning_content  \
# 0                       bagus sekali saya suka apk ini
# 1     telkomsel ngebadut mulu suruh mulu perbaiki la...
# 2     aplikasi provider macam apa ini buka app kok l...
# 3     klo mati listrik lngsung hilang sinyalnya gak ...
# 4      juga lho apalag menu internet sakti buat cari...
# ...                                                 ...
# 2131                     keren ada belajar english juga
# 2132                          sinyal sangat buruk lemot
# 2133  suka banget memudahkan transaksi pembelian pul...
# 2134  pemenang undia telokomsel point tidak jelas si...
# 2135                     sanagat baik kali jaringan nya
#
#                                              tokenisasi
# 0               [bagus, sekali, saya, suka, apk, ini, ]
# 1     [telkomsel, ngebadut, mulu, suruh, mulu, perba...
# 2     [aplikasi, provider, macam, apa, ini, buka, ap...
# 3     [klo, mati, listrik, lngsung, hilang, sinyalny...
# 4     [, juga, lho, apalag, menu, internet, sakti, b...
# ...                                                 ...
# 2131               [keren, ada, belajar, english, juga]
# 2132                     [sinyal, sangat, buruk, lemot]
# 2133  [suka, banget, memudahkan, transaksi, pembelia...
# 2134  [pemenang, undia, telokomsel, point, tidak, je...
# 2135               [sanagat, baik, kali, jaringan, nya]
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#       score                                            content  \
# 0         5  bagus sekali saya suka apk ini ###############...
# 1         1  telkomsel ngebadut mulu suruh dm mulu lu perba...
# 2         1  aplikasi provider macam apa ini. buka app kok ...
# 3         1  klo mati listrik lngsung hilang sinyalnya...ga...
# 4         5  ok juga lho apalag yg menu internet sakti..bua...
# ...     ...                                                ...
# 2131      5                     keren ada belajar english juga
# 2132      1                         sinyal sangat buruk. lemot
# 2133      5  suka banget... memudahkan transaksi pembelian ...
# 2134      2  pemenang undia telokomsel point tidak jelas, s...
# 2135      1                     sanagat baik kali jaringan nya
#
#                                        cleaning_content  \
# 0                       bagus sekali saya suka apk ini
# 1     telkomsel ngebadut mulu suruh mulu perbaiki la...
# 2     aplikasi provider macam apa ini buka app kok l...
# 3     klo mati listrik lngsung hilang sinyalnya gak ...
# 4      juga lho apalag menu internet sakti buat cari...
# ...                                                 ...
# 2131                     keren ada belajar english juga
# 2132                          sinyal sangat buruk lemot
# 2133  suka banget memudahkan transaksi pembelian pul...
# 2134  pemenang undia telokomsel point tidak jelas si...
# 2135                     sanagat baik kali jaringan nya
#
#                                              tokenisasi  \
# 0               [bagus, sekali, saya, suka, apk, ini, ]
# 1     [telkomsel, ngebadut, mulu, suruh, mulu, perba...
# 2     [aplikasi, provider, macam, apa, ini, buka, ap...
# 3     [klo, mati, listrik, lngsung, hilang, sinyalny...
# 4     [, juga, lho, apalag, menu, internet, sakti, b...
# ...                                                 ...
# 2131               [keren, ada, belajar, english, juga]
# 2132                     [sinyal, sangat, buruk, lemot]
# 2133  [suka, banget, memudahkan, transaksi, pembelia...
# 2134  [pemenang, undia, telokomsel, point, tidak, je...
# 2135               [sanagat, baik, kali, jaringan, nya]
#
#                                                stopword
# 0                                  [bagus, suka, apk, ]
# 1     [telkomsel, ngebadut, mulu, suruh, mulu, perba...
# 2     [aplikasi, provider, buka, app, load, data, bn...
# 3     [mati, listrik, lngsung, hilang, sinyalnya, bn...
# 4     [, lho, apalag, menu, internet, sakti, cari, o...
# ...                                                 ...
# 2131                          [keren, belajar, english]
# 2132                             [sinyal, buruk, lemot]
# 2133  [suka, banget, memudahkan, transaksi, pembelia...
# 2134  [pemenang, undia, telokomsel, point, pemenangn...
# 2135                          [sanagat, kali, jaringan]
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0                                  [bagus, suka, apk, ]      5
# 1     [telkomsel, ngebadut, mulu, suruh, mulu, perba...      1
# 2     [aplikasi, provider, buka, app, load, data, bn...      1
# 3     [mati, listrik, lngsung, hilang, sinyalnya, bn...      1
# 4     [, lho, apalag, menu, internet, sakti, cari, o...      5
# ...                                                 ...    ...
# 9716  [gimana, beli, paket, internet, pulsa, tpi, pa...      1
# 9717  [sinyalnya, jelek, banget, pas, hujan, kadang,...      5
# 9718  [telkomsel, terdepan, semoga, bermanfaat, bang...      5
# 9719  [habis, update, beli, pulsa, nominal, aplikasi...      1
# 9720  [dibiarin, paketan, jaringan, ilang, error, se...      1
#
# [9237 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_10.xlsx')
