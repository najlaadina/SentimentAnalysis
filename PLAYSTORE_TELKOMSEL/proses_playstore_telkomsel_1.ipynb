# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Tolong simpati sinyal di benerin ya!!! Karena ...      1
# 1     Kepada yth. Telkomsel tlg jaringan di perbaiki...      1
# 2     Aku download aplikasi ini buat beli yang unlim...      1
# 3     Paket yang aku suka di aplikasi MyTelkomsel da...      5
# 4     Duh, bener bener deh. Ini kenapa makin ke sini...      1
# ...                                                 ...    ...
# 1995  Buat Telkomsel, tolong dong kasi tau cara ngun...      4
# 1996  kenapa sekarang aplikasinya lemot, emang ga di...      4
# 1997  Beli paketan g bisa dipakai max lagi 🙈 Beli pa...      1
# 1998  Sangat kecewa, saya beli kuota ketengan YouTub...      1
# 1999  Tolong signal 4G nya diperbaiki,daerah denpasa...      3
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Tolong simpati sinyal di benerin ya!!! Karena ...      1
# 1     Kepada yth. Telkomsel tlg jaringan di perbaiki...      1
# 2     Aku download aplikasi ini buat beli yang unlim...      1
# 3     Paket yang aku suka di aplikasi MyTelkomsel da...      5
# 4     Duh, bener bener deh. Ini kenapa makin ke sini...      1
# ...                                                 ...    ...
# 1995  Buat Telkomsel, tolong dong kasi tau cara ngun...      4
# 1996  kenapa sekarang aplikasinya lemot, emang ga di...      4
# 1997  Beli paketan g bisa dipakai max lagi 🙈 Beli pa...      1
# 1998  Sangat kecewa, saya beli kuota ketengan YouTub...      1
# 1999  Tolong signal 4G nya diperbaiki,daerah denpasa...      3
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     tolong simpati sinyal di benerin ya!!! karena ...      1
# 1     kepada yth. telkomsel tlg jaringan di perbaiki...      1
# 2     aku download aplikasi ini buat beli yang unlim...      1
# 3     paket yang aku suka di aplikasi mytelkomsel da...      5
# 4     duh, bener bener deh. ini kenapa makin ke sini...      1
# ...                                                 ...    ...
# 1995  buat telkomsel, tolong dong kasi tau cara ngun...      4
# 1996  kenapa sekarang aplikasinya lemot, emang ga di...      4
# 1997  beli paketan g bisa dipakai max lagi 🙈 beli pa...      1
# 1998  sangat kecewa, saya beli kuota ketengan youtub...      1
# 1999  tolong signal 4g nya diperbaiki,daerah denpasa...      3
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     tolong simpati sinyal di benerin ya!!! karena ...      1
# 1     kepada yth. telkomsel tlg jaringan di perbaiki...      1
# 2     aku download aplikasi ini buat beli yang unlim...      1
# 3     paket yang aku suka di aplikasi mytelkomsel da...      5
# 4     duh, bener bener deh. ini kenapa makin ke sini...      1
# ...                                                 ...    ...
# 1995  buat telkomsel, tolong dong kasi tau cara ngun...      4
# 1996  kenapa sekarang aplikasinya lemot, emang ga di...      4
# 1997  beli paketan g bisa dipakai max lagi 🙈 beli pa...      1
# 1998  sangat kecewa, saya beli kuota ketengan youtub...      1
# 1999  tolong signal 4g nya diperbaiki,daerah denpasa...      3
#
#                                        cleaning_content
# 0     tolong simpati sinyal benerin karena paketan m...
# 1     kepada yth telkomsel tlg jaringan perbaiki dar...
# 2     aku download aplikasi ini buat beli yang unlim...
# 3     paket yang aku suka aplikasi mytelkomsel dan s...
# 4     duh bener bener deh ini kenapa makin sini maki...
# ...                                                 ...
# 1995  buat telkomsel tolong dong kasi tau cara ngunc...
# 1996  kenapa sekarang aplikasinya lemot emang uji du...
# 1997  beli paketan bisa dipakai max lagi beli paket ...
# 1998  sangat kecewa saya beli kuota ketengan youtube...
# 1999  tolong signal nya diperbaiki daerah denpasar b...
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     tolong simpati sinyal di benerin ya!!! karena ...      1
# 1     kepada yth. telkomsel tlg jaringan di perbaiki...      1
# 2     aku download aplikasi ini buat beli yang unlim...      1
# 3     paket yang aku suka di aplikasi mytelkomsel da...      5
# 4     duh, bener bener deh. ini kenapa makin ke sini...      1
# ...                                                 ...    ...
# 1995  buat telkomsel, tolong dong kasi tau cara ngun...      4
# 1996  kenapa sekarang aplikasinya lemot, emang ga di...      4
# 1997  beli paketan g bisa dipakai max lagi 🙈 beli pa...      1
# 1998  sangat kecewa, saya beli kuota ketengan youtub...      1
# 1999  tolong signal 4g nya diperbaiki,daerah denpasa...      3
#
#                                        cleaning_content  \
# 0     tolong simpati sinyal benerin karena paketan m...
# 1     kepada yth telkomsel tlg jaringan perbaiki dar...
# 2     aku download aplikasi ini buat beli yang unlim...
# 3     paket yang aku suka aplikasi mytelkomsel dan s...
# 4     duh bener bener deh ini kenapa makin sini maki...
# ...                                                 ...
# 1995  buat telkomsel tolong dong kasi tau cara ngunc...
# 1996  kenapa sekarang aplikasinya lemot emang uji du...
# 1997  beli paketan bisa dipakai max lagi beli paket ...
# 1998  sangat kecewa saya beli kuota ketengan youtube...
# 1999  tolong signal nya diperbaiki daerah denpasar b...
#
#                                              tokenisasi
# 0     [tolong, simpati, sinyal, benerin, karena, pak...
# 1     [kepada, yth, telkomsel, tlg, jaringan, perbai...
# 2     [aku, download, aplikasi, ini, buat, beli, yan...
# 3     [paket, yang, aku, suka, aplikasi, mytelkomsel...
# 4     [duh, bener, bener, deh, ini, kenapa, makin, s...
# ...                                                 ...
# 1995  [buat, telkomsel, tolong, dong, kasi, tau, car...
# 1996  [kenapa, sekarang, aplikasinya, lemot, emang, ...
# 1997  [beli, paketan, bisa, dipakai, max, lagi, beli...
# 1998  [sangat, kecewa, saya, beli, kuota, ketengan, ...
# 1999  [tolong, signal, nya, diperbaiki, daerah, denp...
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     tolong simpati sinyal di benerin ya!!! karena ...      1
# 1     kepada yth. telkomsel tlg jaringan di perbaiki...      1
# 2     aku download aplikasi ini buat beli yang unlim...      1
# 3     paket yang aku suka di aplikasi mytelkomsel da...      5
# 4     duh, bener bener deh. ini kenapa makin ke sini...      1
# ...                                                 ...    ...
# 1995  buat telkomsel, tolong dong kasi tau cara ngun...      4
# 1996  kenapa sekarang aplikasinya lemot, emang ga di...      4
# 1997  beli paketan g bisa dipakai max lagi 🙈 beli pa...      1
# 1998  sangat kecewa, saya beli kuota ketengan youtub...      1
# 1999  tolong signal 4g nya diperbaiki,daerah denpasa...      3
#
#                                        cleaning_content  \
# 0     tolong simpati sinyal benerin karena paketan m...
# 1     kepada yth telkomsel tlg jaringan perbaiki dar...
# 2     aku download aplikasi ini buat beli yang unlim...
# 3     paket yang aku suka aplikasi mytelkomsel dan s...
# 4     duh bener bener deh ini kenapa makin sini maki...
# ...                                                 ...
# 1995  buat telkomsel tolong dong kasi tau cara ngunc...
# 1996  kenapa sekarang aplikasinya lemot emang uji du...
# 1997  beli paketan bisa dipakai max lagi beli paket ...
# 1998  sangat kecewa saya beli kuota ketengan youtube...
# 1999  tolong signal nya diperbaiki daerah denpasar b...
#
#                                              tokenisasi  \
# 0     [tolong, simpati, sinyal, benerin, karena, pak...
# 1     [kepada, yth, telkomsel, tlg, jaringan, perbai...
# 2     [aku, download, aplikasi, ini, buat, beli, yan...
# 3     [paket, yang, aku, suka, aplikasi, mytelkomsel...
# 4     [duh, bener, bener, deh, ini, kenapa, makin, s...
# ...                                                 ...
# 1995  [buat, telkomsel, tolong, dong, kasi, tau, car...
# 1996  [kenapa, sekarang, aplikasinya, lemot, emang, ...
# 1997  [beli, paketan, bisa, dipakai, max, lagi, beli...
# 1998  [sangat, kecewa, saya, beli, kuota, ketengan, ...
# 1999  [tolong, signal, nya, diperbaiki, daerah, denp...
#
#                                                stopword
# 0     [tolong, simpati, sinyal, benerin, paketan, ma...
# 1     [yth, telkomsel, tlg, jaringan, perbaiki, apli...
# 2     [download, aplikasi, beli, unlimited, harganya...
# 3     [paket, suka, aplikasi, mytelkomsel, paket, wa...
# 4     [duh, bener, bener, deh, ancur, jaringannya, b...
# ...                                                 ...
# 1995  [telkomsel, tolong, kasi, ngunci, pulsa, kesed...
# 1996  [aplikasinya, lemot, emang, uji, publikasi, em...
# 1997  [beli, paketan, dipakai, max, beli, paket, tel...
# 1998  [kecewa, beli, kuota, ketengan, youtube, telko...
# 1999  [tolong, signal, diperbaiki, daerah, denpasar,...
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [tolong, simpati, sinyal, benerin, paketan, ma...      1
# 1     [yth, telkomsel, tlg, jaringan, perbaiki, apli...      1
# 2     [download, aplikasi, beli, unlimited, harganya...      1
# 3     [paket, suka, aplikasi, mytelkomsel, paket, wa...      5
# 4     [duh, bener, bener, deh, ancur, jaringannya, b...      1
# ...                                                 ...    ...
# 2898  [daily, check, terkunci, udah, max, point, uda...      1
# 2899  [sya, promo, harga, mahal, min, gax, sperti, d...      1
# 2900  [, beli, kuota, unlimited, chat, sosmed, game,...      1
# 2901  [mff, sebelumny, lancang, tinggal, pedesaan, j...      2
# 2902  [kali, nyaranin, customer, pindah, kartu, halo...      1
#
# [2903 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_1.xlsx')
