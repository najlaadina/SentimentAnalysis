# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Saya minta bantuan semoga paket internet super...      5
# 1                                       sangat membantu      3
# 2     Jaringan internet semakin kacau, tolong lah di...      1
# 3     semoga jaringanya di tahun depan tidak lemot l...      3
# 4     1 BINTANG BUAT MY TELKOMSEL,SEBAB SEKARANG INI...      1
# ...                                                 ...    ...
# 1995                             terima kasih Telkomsel      1
# 1996              sekarang makin mahal aja paketannya 😢      2
# 1997  Nunggu paket Sakti murah di tahun 2022. Semoga...      4
# 1998  Kenapa aplikasi my telkolmsel tiap kali saya b...      2
# 1999  Harga paket Makin lama makin mahal aja ,,,mura...      1
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 1120

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Saya minta bantuan semoga paket internet super...      5
# 2     Jaringan internet semakin kacau, tolong lah di...      1
# 3     semoga jaringanya di tahun depan tidak lemot l...      3
# 4     1 BINTANG BUAT MY TELKOMSEL,SEBAB SEKARANG INI...      1
# 5                                 Apknya sangat berguma      4
# ...                                                 ...    ...
# 2127             Sangat sangat puas dengan my telkomsel      5
# 2128                             Bagus kali ni aplikasi      5
# 2131                                      Bagus sekali,      5
# 2132  Applikasi Telkomsel saya ko tidak bisa di buka...      5
# 2133                                        mengejutkan      5
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     saya minta bantuan semoga paket internet super...      5
# 2     jaringan internet semakin kacau, tolong lah di...      1
# 3     semoga jaringanya di tahun depan tidak lemot l...      3
# 4     1 bintang buat my telkomsel,sebab sekarang ini...      1
# 5                                 apknya sangat berguma      4
# ...                                                 ...    ...
# 2127             sangat sangat puas dengan my telkomsel      5
# 2128                             bagus kali ni aplikasi      5
# 2131                                      bagus sekali,      5
# 2132  applikasi telkomsel saya ko tidak bisa di buka...      5
# 2133                                        mengejutkan      5
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     saya minta bantuan semoga paket internet super...      5
# 2     jaringan internet semakin kacau, tolong lah di...      1
# 3     semoga jaringanya di tahun depan tidak lemot l...      3
# 4     1 bintang buat my telkomsel,sebab sekarang ini...      1
# 5                                 apknya sangat berguma      4
# ...                                                 ...    ...
# 2127             sangat sangat puas dengan my telkomsel      5
# 2128                             bagus kali ni aplikasi      5
# 2131                                      bagus sekali,      5
# 2132  applikasi telkomsel saya ko tidak bisa di buka...      5
# 2133                                        mengejutkan      5
#
#                                        cleaning_content
# 0     saya minta bantuan semoga paket internet super...
# 2     jaringan internet semakin kacau tolong lah dip...
# 3       semoga jaringanya tahun depan tidak lemot lagi
# 4      bintang buat telkomsel sebab sekarang ini jar...
# 5                                 apknya sangat berguma
# ...                                                 ...
# 2127                sangat sangat puas dengan telkomsel
# 2128                                bagus kali aplikasi
# 2131                                      bagus sekali
# 2132          applikasi telkomsel saya tidak bisa buka
# 2133                                        mengejutkan
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     saya minta bantuan semoga paket internet super...      5
# 2     jaringan internet semakin kacau, tolong lah di...      1
# 3     semoga jaringanya di tahun depan tidak lemot l...      3
# 4     1 bintang buat my telkomsel,sebab sekarang ini...      1
# 5                                 apknya sangat berguma      4
# ...                                                 ...    ...
# 2127             sangat sangat puas dengan my telkomsel      5
# 2128                             bagus kali ni aplikasi      5
# 2131                                      bagus sekali,      5
# 2132  applikasi telkomsel saya ko tidak bisa di buka...      5
# 2133                                        mengejutkan      5
#
#                                        cleaning_content  \
# 0     saya minta bantuan semoga paket internet super...
# 2     jaringan internet semakin kacau tolong lah dip...
# 3       semoga jaringanya tahun depan tidak lemot lagi
# 4      bintang buat telkomsel sebab sekarang ini jar...
# 5                                 apknya sangat berguma
# ...                                                 ...
# 2127                sangat sangat puas dengan telkomsel
# 2128                                bagus kali aplikasi
# 2131                                      bagus sekali
# 2132          applikasi telkomsel saya tidak bisa buka
# 2133                                        mengejutkan
#
#                                              tokenisasi
# 0     [saya, minta, bantuan, semoga, paket, internet...
# 2     [jaringan, internet, semakin, kacau, tolong, l...
# 3     [semoga, jaringanya, tahun, depan, tidak, lemo...
# 4     [, bintang, buat, telkomsel, sebab, sekarang, ...
# 5                             [apknya, sangat, berguma]
# ...                                                 ...
# 2127          [sangat, sangat, puas, dengan, telkomsel]
# 2128                            [bagus, kali, aplikasi]
# 2131                                  [bagus, sekali, ]
# 2132  [applikasi, telkomsel, saya, tidak, bisa, buka, ]
# 2133                                      [mengejutkan]
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     saya minta bantuan semoga paket internet super...      5
# 2     jaringan internet semakin kacau, tolong lah di...      1
# 3     semoga jaringanya di tahun depan tidak lemot l...      3
# 4     1 bintang buat my telkomsel,sebab sekarang ini...      1
# 5                                 apknya sangat berguma      4
# ...                                                 ...    ...
# 2127             sangat sangat puas dengan my telkomsel      5
# 2128                             bagus kali ni aplikasi      5
# 2131                                      bagus sekali,      5
# 2132  applikasi telkomsel saya ko tidak bisa di buka...      5
# 2133                                        mengejutkan      5
#
#                                        cleaning_content  \
# 0     saya minta bantuan semoga paket internet super...
# 2     jaringan internet semakin kacau tolong lah dip...
# 3       semoga jaringanya tahun depan tidak lemot lagi
# 4      bintang buat telkomsel sebab sekarang ini jar...
# 5                                 apknya sangat berguma
# ...                                                 ...
# 2127                sangat sangat puas dengan telkomsel
# 2128                                bagus kali aplikasi
# 2131                                      bagus sekali
# 2132          applikasi telkomsel saya tidak bisa buka
# 2133                                        mengejutkan
#
#                                              tokenisasi  \
# 0     [saya, minta, bantuan, semoga, paket, internet...
# 2     [jaringan, internet, semakin, kacau, tolong, l...
# 3     [semoga, jaringanya, tahun, depan, tidak, lemo...
# 4     [, bintang, buat, telkomsel, sebab, sekarang, ...
# 5                             [apknya, sangat, berguma]
# ...                                                 ...
# 2127          [sangat, sangat, puas, dengan, telkomsel]
# 2128                            [bagus, kali, aplikasi]
# 2131                                  [bagus, sekali, ]
# 2132  [applikasi, telkomsel, saya, tidak, bisa, buka, ]
# 2133                                      [mengejutkan]
#
#                                                stopword
# 0      [bantuan, semoga, paket, internet, super, murah]
# 2     [jaringan, internet, kacau, tolong, diperbaiki...
# 3                         [semoga, jaringanya, lemot, ]
# 4     [, bintang, telkomsel, jaringan, aceh, kecewa,...
# 5                                     [apknya, berguma]
# ...                                                 ...
# 2127                                  [puas, telkomsel]
# 2128                            [bagus, kali, aplikasi]
# 2131                                          [bagus, ]
# 2132                     [applikasi, telkomsel, buka, ]
# 2133                                      [mengejutkan]
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                              text_review  score
# 0       [bantuan, semoga, paket, internet, super, murah]      5
# 2      [jaringan, internet, kacau, tolong, diperbaiki...      1
# 3                          [semoga, jaringanya, lemot, ]      3
# 4      [, bintang, telkomsel, jaringan, aceh, kecewa,...      1
# 5                                      [apknya, berguma]      4
# ...                                                  ...    ...
# 23509                [, login, kebanyakan, mahal, doang]      1
# 23510  [, bintang, dlu, klu, sinyal, bonus, oke, bru,...      2
# 23511          [semoga, telkomsel, pelayanan, terbaik, ]      5
# 23512  [simpel, mudah, jenis, transaksi, telkomsel, t...      5
# 23513                                  [jaringan, bagus]      1
#
# [22134 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_12.xlsx')
