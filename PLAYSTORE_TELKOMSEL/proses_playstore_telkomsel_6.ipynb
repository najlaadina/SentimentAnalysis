# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content", "score"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\PLAYSTORE_TELKOMSEL\data_mentah\playstore_telkomsel_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content  score
# 0     Sekarang jelek banget,dari app nya buka nya la...      1
# 1     Paket Promo Yang Hanya Bisa di beli Dengan pul...      1
# 2     Harga kuota tambah mahal, tapi masalah jaringa...      1
# 3     Oh udah sinyal jelek,daftar harga paketnya di ...      1
# 4     Halo admin kenapa paket 4g ceria ngak bisa di ...      1
# ...                                                 ...    ...
# 1995  Jaringan tidak baik , tidak pernah stabil tida...      1
# 1996  Kualitas pelayanan jaringan dan semakin buruk ...      2
# 1997  Jaringan internet di tempat saya lemot banget,...      1
# 1998  Assalamualaikum. Kepada pihak telkomsel yg ter...      1
# 1999  Padahal di kota HP gua juga mendukung.. Tapi k...      1
#
# [2000 rows x 2 columns]

# %%
df.content.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content  score
# 0     Sekarang jelek banget,dari app nya buka nya la...      1
# 1     Paket Promo Yang Hanya Bisa di beli Dengan pul...      1
# 2     Harga kuota tambah mahal, tapi masalah jaringa...      1
# 3     Oh udah sinyal jelek,daftar harga paketnya di ...      1
# 4     Halo admin kenapa paket 4g ceria ngak bisa di ...      1
# ...                                                 ...    ...
# 1995  Jaringan tidak baik , tidak pernah stabil tida...      1
# 1996  Kualitas pelayanan jaringan dan semakin buruk ...      2
# 1997  Jaringan internet di tempat saya lemot banget,...      1
# 1998  Assalamualaikum. Kepada pihak telkomsel yg ter...      1
# 1999  Padahal di kota HP gua juga mendukung.. Tapi k...      1
#
# [2000 rows x 2 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content  score
# 0     sekarang jelek banget,dari app nya buka nya la...      1
# 1     paket promo yang hanya bisa di beli dengan pul...      1
# 2     harga kuota tambah mahal, tapi masalah jaringa...      1
# 3     oh udah sinyal jelek,daftar harga paketnya di ...      1
# 4     halo admin kenapa paket 4g ceria ngak bisa di ...      1
# ...                                                 ...    ...
# 1995  jaringan tidak baik , tidak pernah stabil tida...      1
# 1996  kualitas pelayanan jaringan dan semakin buruk ...      2
# 1997  jaringan internet di tempat saya lemot banget,...      1
# 1998  assalamualaikum. kepada pihak telkomsel yg ter...      1
# 1999  padahal di kota hp gua juga mendukung.. tapi k...      1
#
# [2000 rows x 2 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_content'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     sekarang jelek banget,dari app nya buka nya la...      1
# 1     paket promo yang hanya bisa di beli dengan pul...      1
# 2     harga kuota tambah mahal, tapi masalah jaringa...      1
# 3     oh udah sinyal jelek,daftar harga paketnya di ...      1
# 4     halo admin kenapa paket 4g ceria ngak bisa di ...      1
# ...                                                 ...    ...
# 1995  jaringan tidak baik , tidak pernah stabil tida...      1
# 1996  kualitas pelayanan jaringan dan semakin buruk ...      2
# 1997  jaringan internet di tempat saya lemot banget,...      1
# 1998  assalamualaikum. kepada pihak telkomsel yg ter...      1
# 1999  padahal di kota hp gua juga mendukung.. tapi k...      1
#
#                                        cleaning_content
# 0     sekarang jelek banget dari app nya buka nya la...
# 1     paket promo yang hanya bisa beli dengan pulsa ...
# 2     harga kuota tambah mahal tapi masalah jaringan...
# 3      udah sinyal jelek daftar harga paketnya naiki...
# 4     halo admin kenapa paket ceria ngak bisa pakai ...
# ...                                                 ...
# 1995  jaringan tidak baik tidak pernah stabil tidak ...
# 1996  kualitas pelayanan jaringan dan semakin buruk ...
# 1997  jaringan internet tempat saya lemot banget ken...
# 1998  assalamualaikum kepada pihak telkomsel terhorm...
# 1999  padahal kota gua juga mendukung tapi kenapa su...
#
# [2000 rows x 3 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_content'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     sekarang jelek banget,dari app nya buka nya la...      1
# 1     paket promo yang hanya bisa di beli dengan pul...      1
# 2     harga kuota tambah mahal, tapi masalah jaringa...      1
# 3     oh udah sinyal jelek,daftar harga paketnya di ...      1
# 4     halo admin kenapa paket 4g ceria ngak bisa di ...      1
# ...                                                 ...    ...
# 1995  jaringan tidak baik , tidak pernah stabil tida...      1
# 1996  kualitas pelayanan jaringan dan semakin buruk ...      2
# 1997  jaringan internet di tempat saya lemot banget,...      1
# 1998  assalamualaikum. kepada pihak telkomsel yg ter...      1
# 1999  padahal di kota hp gua juga mendukung.. tapi k...      1
#
#                                        cleaning_content  \
# 0     sekarang jelek banget dari app nya buka nya la...
# 1     paket promo yang hanya bisa beli dengan pulsa ...
# 2     harga kuota tambah mahal tapi masalah jaringan...
# 3      udah sinyal jelek daftar harga paketnya naiki...
# 4     halo admin kenapa paket ceria ngak bisa pakai ...
# ...                                                 ...
# 1995  jaringan tidak baik tidak pernah stabil tidak ...
# 1996  kualitas pelayanan jaringan dan semakin buruk ...
# 1997  jaringan internet tempat saya lemot banget ken...
# 1998  assalamualaikum kepada pihak telkomsel terhorm...
# 1999  padahal kota gua juga mendukung tapi kenapa su...
#
#                                              tokenisasi
# 0     [sekarang, jelek, banget, dari, app, nya, buka...
# 1     [paket, promo, yang, hanya, bisa, beli, dengan...
# 2     [harga, kuota, tambah, mahal, tapi, masalah, j...
# 3     [, udah, sinyal, jelek, daftar, harga, paketny...
# 4     [halo, admin, kenapa, paket, ceria, ngak, bisa...
# ...                                                 ...
# 1995  [jaringan, tidak, baik, tidak, pernah, stabil,...
# 1996  [kualitas, pelayanan, jaringan, dan, semakin, ...
# 1997  [jaringan, internet, tempat, saya, lemot, bang...
# 1998  [assalamualaikum, kepada, pihak, telkomsel, te...
# 1999  [padahal, kota, gua, juga, mendukung, tapi, ke...
#
# [2000 rows x 4 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  score  \
# 0     sekarang jelek banget,dari app nya buka nya la...      1
# 1     paket promo yang hanya bisa di beli dengan pul...      1
# 2     harga kuota tambah mahal, tapi masalah jaringa...      1
# 3     oh udah sinyal jelek,daftar harga paketnya di ...      1
# 4     halo admin kenapa paket 4g ceria ngak bisa di ...      1
# ...                                                 ...    ...
# 1995  jaringan tidak baik , tidak pernah stabil tida...      1
# 1996  kualitas pelayanan jaringan dan semakin buruk ...      2
# 1997  jaringan internet di tempat saya lemot banget,...      1
# 1998  assalamualaikum. kepada pihak telkomsel yg ter...      1
# 1999  padahal di kota hp gua juga mendukung.. tapi k...      1
#
#                                        cleaning_content  \
# 0     sekarang jelek banget dari app nya buka nya la...
# 1     paket promo yang hanya bisa beli dengan pulsa ...
# 2     harga kuota tambah mahal tapi masalah jaringan...
# 3      udah sinyal jelek daftar harga paketnya naiki...
# 4     halo admin kenapa paket ceria ngak bisa pakai ...
# ...                                                 ...
# 1995  jaringan tidak baik tidak pernah stabil tidak ...
# 1996  kualitas pelayanan jaringan dan semakin buruk ...
# 1997  jaringan internet tempat saya lemot banget ken...
# 1998  assalamualaikum kepada pihak telkomsel terhorm...
# 1999  padahal kota gua juga mendukung tapi kenapa su...
#
#                                              tokenisasi  \
# 0     [sekarang, jelek, banget, dari, app, nya, buka...
# 1     [paket, promo, yang, hanya, bisa, beli, dengan...
# 2     [harga, kuota, tambah, mahal, tapi, masalah, j...
# 3     [, udah, sinyal, jelek, daftar, harga, paketny...
# 4     [halo, admin, kenapa, paket, ceria, ngak, bisa...
# ...                                                 ...
# 1995  [jaringan, tidak, baik, tidak, pernah, stabil,...
# 1996  [kualitas, pelayanan, jaringan, dan, semakin, ...
# 1997  [jaringan, internet, tempat, saya, lemot, bang...
# 1998  [assalamualaikum, kepada, pihak, telkomsel, te...
# 1999  [padahal, kota, gua, juga, mendukung, tapi, ke...
#
#                                                stopword
# 0     [jelek, banget, app, buka, suka, log, out, bel...
# 1     [paket, promo, beli, pulsa, hati, jebakan, gag...
# 2     [harga, kuota, mahal, jaringan, solusi, parah,...
# 3     [, udah, sinyal, jelek, daftar, harga, paketny...
# 4     [halo, admin, paket, ceria, ngak, pakai, udah,...
# ...                                                 ...
# 1995  [jaringan, stabil, recommend, telkomsel, ngege...
# 1996  [kualitas, pelayanan, jaringan, buruk, masukan...
# 1997  [jaringan, internet, lemot, banget, perbaiki, ...
# 1998  [assalamualaikum, telkomsel, terhormat, pulsa,...
# 1999  [kota, gua, mendukung, suka, ngeleg, perasaan,...
#
# [2000 rows x 5 columns]

# %%
Final = df[['stopword','score']]
Final = Final.rename(columns={'stopword':'text_review'})

# %%
Final
# Out:
#                                             text_review  score
# 0     [jelek, banget, app, buka, suka, log, out, bel...      1
# 1     [paket, promo, beli, pulsa, hati, jebakan, gag...      1
# 2     [harga, kuota, mahal, jaringan, solusi, parah,...      1
# 3     [, udah, sinyal, jelek, daftar, harga, paketny...      1
# 4     [halo, admin, paket, ceria, ngak, pakai, udah,...      1
# ...                                                 ...    ...
# 2256  [paketan, koq, pakai, kemaren, habis, claim, k...      1
# 2257  [harga, paketan, simpati, mahal, sinyal, jelek...      1
# 2258  [telkomsel, mengecewakan, aplikasi, buka, maaf...      1
# 2259  [kecewa, banget, kuota, rb, udah, dapet, unlim...      1
# 2260  [mengeluh, beli, paketan, promo, langsung, mas...      1
#
# [2261 rows x 2 columns]

# %%
Final.to_excel('databersih_playstore_telkomsel_6.xlsx')
