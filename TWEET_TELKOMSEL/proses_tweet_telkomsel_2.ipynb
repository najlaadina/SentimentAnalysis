# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0                 @FFOODFESS promo telkomsel ga sih ini
# 1     @Telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @MethaWidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 4     Open convert pulsa three 3 - Telkomsel tsel - ...
# ...                                                 ...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @Telkomsel Laiki yoraenek balesan
# 1997  Jual pulsa tri, telkomsel, axis, xl, indosat\n...
# 1998  @irwaaaaaaaan @Telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 1109

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0                 @FFOODFESS promo telkomsel ga sih ini
# 1     @Telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @MethaWidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 5     Aku kira bangun pagi buka hp ada yg ngucapin s...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @Telkomsel Laiki yoraenek balesan
# 1998  @irwaaaaaaaan @Telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
# [766 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0                 @ffoodfess promo telkomsel ga sih ini
# 1     @telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @methawidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 5     aku kira bangun pagi buka hp ada yg ngucapin s...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @telkomsel laiki yoraenek balesan
# 1998  @irwaaaaaaaan @telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
# [766 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0                 @ffoodfess promo telkomsel ga sih ini
# 1     @telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @methawidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 5     aku kira bangun pagi buka hp ada yg ngucapin s...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @telkomsel laiki yoraenek balesan
# 1998  @irwaaaaaaaan @telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
#                                          cleaning_tweet
# 0                               promo telkomsel sih ini
# 1      untuk saat ini kamu kupuji karena paling stabil
# 2      ngadu gerai nya aja malah customer servicenya...
# 3      nah ada apa gerangan sering bgt sms spam nih ...
# 5     aku kira bangun pagi buka ada ngucapin selamat...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995                    min sinyalnya kok ilang an sih
# 1996                             laiki yoraenek balesan
# 1998      koyone admin resign kabeh gara  akeh gangguan
# 1999  telkomsel sama indihome bener bener sepaket sk...
#
# [766 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0                 @ffoodfess promo telkomsel ga sih ini
# 1     @telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @methawidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 5     aku kira bangun pagi buka hp ada yg ngucapin s...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @telkomsel laiki yoraenek balesan
# 1998  @irwaaaaaaaan @telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
#                                          cleaning_tweet  \
# 0                               promo telkomsel sih ini
# 1      untuk saat ini kamu kupuji karena paling stabil
# 2      ngadu gerai nya aja malah customer servicenya...
# 3      nah ada apa gerangan sering bgt sms spam nih ...
# 5     aku kira bangun pagi buka ada ngucapin selamat...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995                    min sinyalnya kok ilang an sih
# 1996                             laiki yoraenek balesan
# 1998      koyone admin resign kabeh gara  akeh gangguan
# 1999  telkomsel sama indihome bener bener sepaket sk...
#
#                                              tokenisasi
# 0                          [promo, telkomsel, sih, ini]
# 1     [untuk, saat, ini, kamu, kupuji, karena, palin...
# 2     [, ngadu, gerai, nya, aja, malah, customer, se...
# 3     [, nah, ada, apa, gerangan, sering, bgt, sms, ...
# 5     [aku, kira, bangun, pagi, buka, ada, ngucapin,...
# ...                                                 ...
# 1994  [telkomsel, tuh, emang, lgi, ada, masalah, sam...
# 1995          [, min, sinyalnya, kok, ilang, an, sih, ]
# 1996                         [laiki, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, sama, indihome, bener, bener, sepa...
#
# [766 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0                 @ffoodfess promo telkomsel ga sih ini
# 1     @telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @methawidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 5     aku kira bangun pagi buka hp ada yg ngucapin s...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @telkomsel laiki yoraenek balesan
# 1998  @irwaaaaaaaan @telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
#                                          cleaning_tweet  \
# 0                               promo telkomsel sih ini
# 1      untuk saat ini kamu kupuji karena paling stabil
# 2      ngadu gerai nya aja malah customer servicenya...
# 3      nah ada apa gerangan sering bgt sms spam nih ...
# 5     aku kira bangun pagi buka ada ngucapin selamat...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995                    min sinyalnya kok ilang an sih
# 1996                             laiki yoraenek balesan
# 1998      koyone admin resign kabeh gara  akeh gangguan
# 1999  telkomsel sama indihome bener bener sepaket sk...
#
#                                              tokenisasi  \
# 0                          [promo, telkomsel, sih, ini]
# 1     [untuk, saat, ini, kamu, kupuji, karena, palin...
# 2     [, ngadu, gerai, nya, aja, malah, customer, se...
# 3     [, nah, ada, apa, gerangan, sering, bgt, sms, ...
# 5     [aku, kira, bangun, pagi, buka, ada, ngucapin,...
# ...                                                 ...
# 1994  [telkomsel, tuh, emang, lgi, ada, masalah, sam...
# 1995          [, min, sinyalnya, kok, ilang, an, sih, ]
# 1996                         [laiki, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, sama, indihome, bener, bener, sepa...
#
#                                                stopword
# 0                                    [promo, telkomsel]
# 1                                    [kupuji, stabil, ]
# 2     [, ngadu, gerai, customer, servicenya, curhat,...
# 3     [, gerangan, sms, spam, tolong, kolabs, bersih...
# 5     [bangun, pagi, buka, ngucapin, selamat, pagi, ...
# ...                                                 ...
# 1994  [telkomsel, emang, lgi, jaringan, yaa, sumpah,...
# 1995                        [, min, sinyalnya, ilang, ]
# 1996                         [laiki, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, indihome, bener, bener, sepaket, s...
#
# [766 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 2077
# ------------------------
# promo : promo
# telkomsel : telkomsel
# kupuji : puji
# stabil : stabil
#  :
# ngadu : ngadu
# gerai : gerai
# customer : customer
# servicenya : servicenya
# curhat : curhat
# dikirimin : dikirimin
# sms : sms
# lhaaaa : lhaaaa
# kocak : kocak
# briefnya : briefnya
# gmn : gmn
# deh : deh
# kli : kli
# dpt : dpt
# aduan : adu
# kek : kek
# gini : gin
# wkwkwk : wkwkwk
# gerangan : gerangan
# spam : spam
# tolong : tolong
# kolabs : kolabs
# bersih : bersih
# duuunkssss : duuunkssss
# bangun : bangun
# pagi : pagi
# buka : buka
# ngucapin : ngucapin
# selamat : selamat
# cantiik : cantiik
# pesan : pesan
# manis : manis
# kuota : kuota
# menipis : tip
# ama : ama
# udah : udah
# minggu : minggu
# busuk : busuk
# buffer : buffer
# parah : parah
# banget : banget
# melebihi : lebih
# kartu : kartu
# indosat : indosat
# mybusiness : mybusiness
# sinyal : sinyal
# lelet : lelet
# dana : dana
# shopeepay : shopeepay
# open : open
# convert : convert
# tukar : tukar
# tuker : tuker
# pulsa : pulsa
# axis : axis
# three : three
# tri : tri
# tsel : tsel
# isat : isat
# uang : uang
# atm : atm
# bank : bank
# ewallet : ewallet
# non : non
# premium : premium
# prem : prem
# ovo : ovo
# gopay : gopay
# linkaja : linkaja
# jual : jual
# preset : preset
# lightroom : lightroom
# ios : ios
# andro : andro
# agen : agen
# notif : notif
# wes : wes
# gek : gek
# jongkarke : jongkarke
# wae : wae
# thetheli : thetheli
# mengecek : ecek
# nomor : nomor
# lihat : lihat
# prediski : prediski
# togel : togel
# february : february
# palapatoto : palapatoto
# bandar : bandar
# games : games
# online : online
# new : new
# member : member
# bonus : bonus
# deposit : deposit
# login : login
# site : site
# terima : terima
# info : info
# live : live
# chat : chat
# jam : jam
# beneran : beneran
# rencana : rencana
# iki : iki
# dus : dus
# tenan : tenan
# sinyale : sinyale
# ilang : ilang
# koyo : koyo
# koe : koe
# min : min
# giga : giga
# sisa : sisa
# mb : mb
# sehari : hari
# org : org
# hemat : hemat
# kirain : kirain
# bug : bug
# gataunya : gataunya
# koneksi : koneksi
# bapuk : bapuk
# theteli : theteli
# dol : dol
# kilon : kilon
# kenapaa : kenapaa
# lagiii : lagiii
# admin : admin
# langganan : langgan
# aktfikan : aktfikan
# paket : paket
# internet : internet
# memiliki : milik
# varian : varian
# data : data
# flash : flash
# bulk : bulk
# omg : omg
# combo : combo
# sakti : sakti
# surprise : surprise
# deal : deal
# tiktok : tiktok
# youtube : youtube
# prediksi : prediksi
# pools : pools
# februari : februari
# transfer : transfer
# ready : ready
# smartfren : smartfren
# area : area
# jawa : jawa
# bali : bal
# dorong : dorong
# pengguna : guna
# beralih : alih
# bonekaqq : bonekaqq
# banjir : banjir
# wede : wede
# bebas : bebas
# potongan : potong
# bossku : bossku
# daftar : daftar
# buktikan : bukti
# pemenang : menang
# pkv : pkv
# link : link
# dot : dot
# com : com
# whatsapp : whatsapp
# line : line
# udh : udh
# mati : mati
# lampu : lampu
# jaringannya : jaring
# kuntul : kuntul
# wifi : wifi
# lemot : lot
# listrik : listrik
# malam : malam
# unlimitied : unlimitied
# browsing : browsing
# ruangan : ruang
# darah : darah
# ancur : ancur
# sialan : sial
# hahahahahah : hahahahahah
# ganti : ganti
# sayang : sayang
# nomornya : nomor
# dipake : dipake
# iya : iya
# bar : bar
# penuh : penuh
# loading : loading
# matiin : matiin
# trs : trs
# hidupin : hidupin
# enak : enak
# masang : masang
# app : app
# payment : payment
# via : via
# anjing : anjing
# kadang : kadang
# suka : suka
# tersedia : sedia
# gjls : gjls
# bagus : bagus
# pengalamanku : alam
# normal : normal
# masuk : masuk
# kuatur : atur
# notification : notification
# settings : settings
# emang : emang
# mode : mode
# not : not
# disturb : disturb
# cmiiw : cmiiw
# tlp : tlp
# nder : nder
# nomermu : nomermu
# soale : soale
# dapet : dapet
# solusinya : solusi
# kah : kah
# bang : bang
# ayo : ayo
# beli : beli
# kak : kak
# murah : murah
# gaperlu : gaperlu
# nunggu : nunggu
# fullslot : fullslot
# diproses : proses
# rate : rate
# start : start
# from : from
# bca : bca
# unlimited : unlimited
# support : support
# twiteran : twiteran
# sekalinya : sekali
# telponan : telpon
# sinyalnya : sinyal
# gembel : gembel
# fix : fix
# tower : tower
# sebelah : belah
# rumah : rumah
# pacar : pacar
# mayan : mayan
# jaringan : jaring
# dago : dago
# netflix : netflix
# sebulan : bulan
# voucher : voucher
# mola : mola
# gratis : gratis
# itunes : itunes
# cimb : cimb
# gratisan : gratis
# ngapain : ngapain
# bayar : bayar
# kenyataannyaa : kenyataannyaa
# hadehhh : hadehhh
# gb : gb
# rb : rb
# society : society
# salah : salah
# namanya : nama
# gitu : gitu
# lupa : lupa
# ngutang : ngutang
# gasalah : gasalah
# cek : cek
# error : error
# bener : bener
# perasaan : asa
# panas : panas
# macet : macet
# wall : wall
# climbing : climbing
# merah : merah
# foto : foto
# int : int
# byu : byu
# boongan : boongan
# sebagus : bagus
# boong : boong
# paketan : paket
# separah : parah
# lemotnya : lot
# game : game
# bos : bos
# ngga : ngga
# kasih : kasih
# hamba : hamba
# jelek : jelek
# diperkuat : kuat
# aura : aura
# negatif : negatif
# disekitar : sekitar
# alek : alek
# kaga : kaga
# ngapa : ngapa
# tpi : tpi
# mikir : mikir
# anjer : anjer
# isi : isi
# status : status
# sukses : sukses
# pulsanya : pulsa
# mulu : mulu
# kawit : kawit
# disney : disney
# berlaku : laku
# dund : dund
# dibantu : bantu
# seputar : putar
# produk : produk
# layanan : layan
# silakan : sila
# mention : mention
# jfb : jfb
# peka : peka
# mengurangi : kurang
# kenyamanannya : nyaman
# twitter : twitter
# aduh : aduh
# ubah : ubah
# call : call
# custemer : custemer
# service : service
# mas : mas
# results : results
# tonton : tonton
# videonya : video
# say : say
# hotstar : hotstar
# twitt : twitt
# habis : habis
# nonton : nonton
# kingsman : kingsman
# ngerilah : ngeri
# ngasi : ngasi
# simcard : simcard
# nelpon : nelpon
# hurley : hurley
# great : great
# take : take
# you : you
# out : out
# think : think
# this : this
# big : big
# chills : chills
# texas : texas
# good : good
# shout : shout
# ever : ever
# wanted : wanted
# too : too
# fair : fair
# well : well
# trying : trying
# london : london
# mba : mba
# telpon : telpon
# keep : keep
# away : away
# people : people
# who : who
# try : try
# belittle : belittle
# your : your
# ambitions : ambitions
# small : small
# always : always
# that : that
# but : but
# the : the
# really : really
# make : make
# feel : feel
# can : can
# become : become
# all : all
# things : things
# consider : consider
# end : end
# gua : gua
# kayak : kayak
# bangsat : bangsat
# ngeload : ngeload
# diem : diem
# doang : doang
# every : every
# failure : failure
# brings : brings
# with : with
# seed : seed
# equivalent : equivalent
# success : success
# our : our
# business : business
# life : life
# get : get
# ahead : ahead
# others : others
# ourselves : ourselves
# pindah : pindah
# kaya : kaya
# blm : blm
# full : full
# signalnya : signalnya
# ngilang : ngilang
# cuk : cuk
# bilaaa : bilaaa
# th : th
# prio : prio
# skali : skali
# sis : sis
# sbelum : sbelum
# regular : regular
# merasuki : rasuk
# drama : drama
# babang : babang
# duren : duren
# tamfan : tamfan
# ngelag : ngelag
# refres : refres
# berkali : kali
# sekedar : dar
# share : share
# clear : clear
# hmmmm : hmmmm
# check : check
# meresahkan : resah
# inet : inet
# kalah : kalah
# paketnya : paket
# cloudmax : cloudmax
# pakek : pakek
# temen : temen
# kamar : kamar
# buffering : buffering
# yaaaa : yaaaa
# tembok : tembok
# tebel : tebel
# galau : galau
# ghosting : ghosting
# huhu : huhu
# help : help
# nyoba : nyoba
# langsung : langsung
# isa : isa
# aneh : aneh
# bnget : bnget
# kieee : kieee
# dear : dear
# lapor : lapor
# signal : signal
# menelfon : menelfon
# terputus : putus
# desa : desa
# lenggadai : lenggadai
# hilir : hilir
# kecamatan : camat
# rimba : rimba
# melintang : lintang
# kabupaten : kabupaten
# rokan : rok
# provinsi : provinsi
# riau : riau
# pengusaha : usaha
# sawit : sawit
# terganggu : ganggu
# hati : hati
# gasuka : gasuka
# twt : twt
# yaallah : yaallah
# kuala : kuala
# tungkal : tungkal
# masihhhh : masihhhh
# bae : bae
# kabar : kabar
# spesial : spesial
# mytelkomsel : mytelkomsel
# dptkan : dptkan
# hr : hr
# telp : telp
# klik : klik
# mar : mar
# skb : skb
# kacau : kacau
# knp : knp
# lemoooottt : lemoooottt
# skrg : skrg
# harga : harga
# mahal : mahal
# pelanggan : langgan
# migrasi : migrasi
# usim : usim
# bontang : bontang
# gang : gang
# tos : tos
# senin : senin
# besok : besok
# ujian : uji
# ujiannya : uji
# belajar : ajar
# gabisa : gabisa
# chrome : chrome
# gimana : gimana
# allah : allah
# gadapet : gadapet
# kepotong : potong
# biat : biat
# sekaya : kaya
# plis : plis
# bantu : bantu
# order : order
# video : video
# cewek : cewek
# boker : boker
# silahkan : silah
# ngadat : ngadat
# drakor : drakor
# terjeda : jeda
# balikin : balikin
# pulsaku : pulsa
# kesel : kesel
# anying : anying
# setengahnya : tengah
# bucin : bucin
# giliran : gilir
# sosiolinguistika : sosiolinguistika
# aplikasi : aplikasi
# yaampun : yaampun
# susah : susah
# bsa : bsa
# otomatis : otomatis
# blokir : blokir
# yaa : yaa
# syg : syg
# buy : buy
# bye : bye
# btw : btw
# berjam : jam
# respon : respon
# nyaaa : nyaaa
# maapin : maapin
# gue : gue
# kambing : kambing
# hitam : hitam
# miscall : miscall
# msh : msh
# nyambung : nyambung
# indohome : indohome
# ujan : ujan
# angin : angin
# ndak : ndak
# diklaim : klaim
# knapa : knapa
# sedih : sedih
# mixlr : mixlr
# tuhan : tuhan
# demen : demen
# mending : mending
# aje : aje
# poin : poin
# kali : kali
# abang : abang
# akses : akses
# pls : pls
# skrnh : skrnh
# kopraldeles : kopraldeles
# keluhannya : keluh
# mohon : mohon
# pengen : ken
# hujat : hujat
# istigfar : istigfar
# scam : scam
# crazy : crazy
# how : how
# fake : fake
# accounts : accounts
# marks : marks
# these : these
# days : days
# mcl : mcl
# gegara : gegara
# jebul : jebul
# bermasalah : masalah
# yak : yak
# juk : juk
# terusss : terusss
# piye : piye
# lom : lom
# bales : bales
# nanya : nanya
# donk : donk
# krtu : krtu
# tenggang : tenggang
# tgl : tgl
# skrng : skrng
# aktf : aktf
# sumpah : sumpah
# frustasi : frustasi
# cari : cari
# tingkat : tingkat
# kemenangan : menang
# terbaik : baik
# menyediakan : sedia
# coba : coba
# punyaku : punya
# gamasuk : gamasuk
# teros : ros
# beet : beet
# sukak : sukak
# server : server
# discord : discord
# lemoooot : lemoooot
# sedihnya : sedih
# tinggal : tinggal
# pelosok : pelosok
# update : update
# pemerintah : perintah
# gencar : gencar
# gencarnya : gencar
# sosialisasi : sosialisasi
# daring : daring
# berharap : harap
# pianjingen : pianjingen
# bangke : bangke
# tumben : tumben
# ngaceng : ngaceng
# tim : tim
# profesional : profesional
# menyelesaikan : selesai
# berniat : niat
# menunggu : tunggu
# ditinggal : tinggal
# knpsih : knpsih
# woy : woy
# matek : matek
# hadeh : hadeh
# mnyusahkan : mnyusahkan
# semoga : moga
# refund : refund
# keiisi : keiisi
# liat : liat
# mantep : mantep
# bund : bund
# malem : malem
# safrie : safrie
# notifikasi : notifikasi
# grabbenefit : grabbenefit
# aktivasi : aktivasi
# khusus : khusus
# grab : grab
# merasakan : rasa
# ancurnya : ancurnya
# towernya : towernya
# rubuh : rubuh
# gara : gara
# hujan : hujan
# kemaren : kemaren
# apapun : apa
# hebat : hebat
# lancar : lancar
# aktifkan : aktif
# halo : halo
# syaratnya : syarat
# kenek : kenek
# udan : udan
# nemen : nemen
# anjink : anjink
# asli : asli
# tulisannya : tulis
# kenyataannya : nyata
# limit : limit
# kecepatannya : cepat
# beluuum : beluuum
# hiks : hiks
# lucunya : lucu
# ane : ane
# only : only
# lumayan : lumayan
# kagak : kagak
# cepet : cepet
# sampis : sampis
# serasa : serasa
# gprs : gprs
# niken : niken
# samsung : samsung
# mbak : mbak
# ken : ken
# buktinya : bukti
# provider : provider
# keluarga : keluarga
# perusahaan : usaha
# penanganan : tangan
# leboh : leboh
# dibawahnya : bawah
# solusi : solusi
# trus : trus
# laporan : lapor
# pegimane : pegimane
# tetangga : tetangga
# aryotong : aryotong
# dikunci : kunci
# dihape : dihape
# lamaku : lama
# jaringanlu : jaringanlu
# dibikin : bikin
# nge : nge
# ping : ping
# siang : siang
# menjelang : jelang
# sore : sore
# down : down
# what : what
# point : point
# providing : providing
# conference : conference
# package : package
# useless : useless
# bought : bought
# used : used
# for : for
# google : google
# meet : meet
# didn : didn
# affect : affect
# quota : quota
# disappointment : disappointment
# immeasurable : immeasurable
# and : and
# day : day
# ruined : ruined
# happened : happened
# many : many
# times : times
# mesti : mesti
# sabar : sabar
# ngadapin : ngadapin
# tenang : tenang
# dsini : dsini
# uda : uda
# cerita : cerita
# tulisan : tulis
# sistem : sistem
# sibuk : sibuk
# doyan : doyan
# lag : lag
# pas : pas
# war : war
# mlbb : mlbb
# aov : aov
# bulanan : bulan
# mingguan : minggu
# harian : hari
# itung : itung
# bnr : bnr
# rmh : rmh
# kondisi : kondisi
# stress : stress
# tertawa : tertawa
# apresiasi : apresiasi
# pergantian : ganti
# sim : sim
# tambahan : tambah
# bermasalh : bermasalh
# bet : bet
# subhanallah : subhanallah
# maen : maen
# pabji : pabji
# internetan : internetan
# pindahin : pindahin
# kuotanya : kuota
# karna : karna
# reg : reg
# ktp : ktp
# alasan : alas
# aktif : aktif
# diambil : ambil
# distributor : distributor
# diaktifkan : aktif
# tbk : tbk
# prioritas : prioritas
# saran : saran
# nggak : nggak
# semenyebalkan : sebal
# didownload : didownload
# diplaystore : diplaystore
# aplikasinya : aplikasi
# lte : lte
# umts : umts
# auto : auto
# prl : prl
# ditekan : tekan
# dipilih : pilih
# ngunci : ngunci
# gtu : gtu
# kelemahannya : lemah
# gunain : gunain
# adl : adl
# klw : klw
# dikembalikan : kembali
# eror : eror
# hallo : hallo
# menikmati : nikmat
# daftarnya : daftar
# penawarannya : tawar
# menu : menu
# mendaftarnya : daftar
# papua : papua
# gituu : gituu
# bertahan : tahan
# ldr : ldr
# vcall : vcall
# sampe : sampe
# gangguan : ganggu
# marah : marah
# tunjukan : tunjuk
# pesonamu : pesona
# linknya : linknya
# dikirim : kirim
# kirim : kirim
# ulang : ulang
# numpuk : numpuk
# kadaluwarsa : kadaluwarsa
# nomer : nomer
# akun : akun
# mam : mam
# kerjanya : kerja
# duit : duit
# isinya : isi
# gabs : gabs
# coin : coin
# webtoon : webtoon
# bisnis : bisnis
# dihabisin : dihabisin
# starlink : starlink
# stateless : stateless
# borderless : borderless
# maap : maap
# jbjb : jbjb
# pakai : pakai
# berhasil : hasil
# diriwayat : riwayat
# mytelkom : mytelkom
# shopee : shopee
# telkomselku : telkomselku
# aman : aman
# mei : mei
# mgkin : mgkin
# nabrak : nabrak
# base : base
# musuh : musuh
# direspon : direspon
# ampun : ampun
# membayangkan : bayang
# quad : quad
# sopipay : sopipay
# gamasukk : gamasukk
# dijambi : dijambi
# kota : kota
# orang : orang
# kartunya : kartu
# simpati : simpati
# melayani : layan
# pengaduan : adu
# astaga : astaga
# jhoseok : jhoseok
# jiminie : jiminie
# taehyng : taehyng
# knjoon : knjoon
# kook : kook
# twtjh : twtjh
# bighit : bighit
# jufa : jufa
# merauke : merauke
# kutahu : tahu
# bak : bak
# muevbaga : muevbaga
# toko : toko
# handphone : handphone
# gajelas : gajelas
# plisss : plisss
# disaat : saat
# deras : deras
# internetnya : internetnya
# sat : sat
# set : set
# kluwer : kluwer
# paham : paham
# iyaa : iyaa
# ehh : ehh
# yth : yth
# trx : trx
# tsl : tsl
# nmr : nmr
# tujuan : tuju
# mhn : mhn
# bantuannya : bantu
# guys : guys
# dimana : mana
# stand : stand
# kumpul : kumpul
# kenalan : kenal
# buruk : buruk
# complain : complain
# gada : gada
# maneh : maneh
# fey : fey
# aing : aing
# yeuh : yeuh
# hub : hub
# tlkmsel : tlkmsel
# bukti : bukti
# spay : spay
# beliin : beliin
# saham : saham
# sharing : sharing
# private : private
# ppj : ppj
# bill : bill
# indo : indo
# fresh : fresh
# legal : legal
# garansi : garansi
# uhd : uhd
# qris : qris
# maksud : maksud
# kesedot : sedot
# ginian : ginian
# ngajak : ngajak
# ribut : ribut
# serius : serius
# kotaku : kota
# ajhh : ajhh
# top : top
# kombo : kombo
# pembayaran : bayar
# shoppee : shoppee
# pay : pay
# gagal : gagal
# love : love
# oknum : oknum
# mengaku : aku
# pegawai : pegawai
# penipuan : tipu
# dalih : dalih
# menguras : uras
# investigasi : investigasi
# tsb : tsb
# ditingkatkan : tingkat
# kayaknya : kayak
# mapping : mapping
# showroom : showroom
# lwt : lwt
# taunya : tau
# bkn : bkn
# ppn : ppn
# biaya : biaya
# jasa : jasa
# daily : daily
# wallet : wallet
# bni : bni
# mandiri : mandiri
# jasatukarpulsa : jasatukarpulsa
# yuk : yuk
# mari : mari
# pembelian : beli
# done : done
# lombok : lombok
# mataram : mataram
# strip : strip
# dirumah : rumah
# dok : dok
# ngalamin : ngalamin
# bbgi : bbgi
# slain : slain
# mksh : mksh
# jwb : jwb
# wal : wal
# off : off
# internetnyaa : internetnyaa
# pdhl : pdhl
# semangat : semangat
# terpakai : pakai
# padam : padam
# mohoh : mohoh
# bantuan : bantu
# bgus : bgus
# kelupaan : lupa
# hafal : hafal
# nyontek : nyontek
# gaada : gaada
# menarik : tarik
# ajel : ajel
# gppa : gppa
# sopo : sopo
# seh : seh
# maaf : maaf
# kenala : nala
# porong : porong
# panggilan : panggil
# darurat : darurat
# grapari : grapari
# jabode : jabode
# emg : emg
# kemarin : kemarin
# goblok : goblok
# pricelist : pricelist
# elektrik : elektrik
# menambah : tambah
# maret : maret
# juli : juli
# assalamu : assalamu
# alaikum : alaikum
# bengek : bengek
# ihh : ihh
# nambah : nambah
# rebu : rebu
# ribu : ribu
# seribu : ribu
# geser : geser
# pantat : pantat
# dikit : dikit
# ngawur : ngawur
# rodok : rodok
# bosok : bosok
# kecewa : kecewa
# penyelamat : selamat
# garut : garut
# mah : mah
# dilantai : lantai
# tetep : tetep
# gembor : gembor
# anak : anak
# pershaan : pershaan
# install : install
# appny : appny
# ntar : ntar
# dftar : dftar
# dkirim : dkirim
# kantor : kantor
# ajaaa : ajaaa
# cobaa : cobaa
# hshsh : hshsh
# nurutin : nurutin
# ambis : ambis
# pasang : pasang
# males : males
# nungguin : nungguin
# user : user
# jaemin : jaemin
# pakabar : pakabar
# serebu : rebu
# duh : duh
# gasanggup : gasanggup
# pke : pke
# kyak : kyak
# eek : eek
# gasih : gasih
# feed : feed
# back : back
# ditiktok : ditiktok
# rame : rame
# spoiler : spoiler
# wandavision : wandavision
# untung : untung
# free : free
# driver : driver
# ngacung : ngacung
# utamakan : utama
# membutuhkan : butuh
# pilih : pilih
# nuhun : nuhun
# lemah : lemah
# lunglay : lunglay
# berhari : hari
# bagusnya : bagus
# konci : konci
# keberhasilan : hasil
# pembangun : bangun
# sdm : sdm
# interkoneksi : interkoneksi
# wilayah : wilayah
# wisnutama : wisnutama
# mengembangakan : mengembangakan
# super : super
# bts : bts
# telkom : telkom
# daerah : daerah
# alas : alas
# roban : roban
# berjaya : jaya
# fuel : fuel
# batang : batang
# dunia : dunia
# berputar : putar
# menempati : tempat
# peringkat : peringkat
# pengujiannya : uji
# meliputi : liput
# download : download
# upload : upload
# streaming : streaming
# latensi : latensi
# main : main
# sii : sii
# nvm : nvm
# they : they
# gone : gone
# some : some
# reason : reason
# why : why
# weird : weird
# ass : ass
# comments : comments
# tweet : tweet
# mengecewakan : kecewa
# instagram : instagram
# kzl : kzl
# scammer : scammer
# steal : steal
# bitcoin : bitcoin
# fools : fools
# adminnn : adminnn
# hai : hai
# care : care
# diakses : akses
# email : email
# orbit : orbit
# mengembangkan : kembang
# membuka : buka
# channel : channel
# cetek : cetek
# ketutup : tutup
# mendung : mendung
# basah : basah
# kena : kena
# culun : culun
# ahh : ahh
# kindly : kindly
# pemukiman : mukim
# nyampai : nyampai
# pripun : pripun
# niku : niku
# reseller : reseller
# drop : drop
# ngasih : ngasih
# apanya : apa
# capacity : capacity
# internetku : internetku
# koq : koq
# emng : emng
# dih : dih
# babi : babi
# tolol : tolol
# lemott : lemott
# bunnn : bunnn
# mitratel : mitratel
# rampungkan : rampung
# pengalihan : alih
# kepemilikan : milik
# menara : menara
# telekomunikasi : telekomunikasi
# abisssss : abisssss
# akademi : akademi
# nuclear : nuclear
# facilities : facilities
# are : are
# modern : modern
# steam : steam
# engines : engines
# produces : produces
# glowing : glowing
# green : green
# goo : goo
# someone : someone
# needs : needs
# bury : bury
# years : years
# wanna : wanna
# talk : talk
# about : about
# efficient : efficient
# use : use
# energy : energy
# puoll : puoll
# bisaa : bisaa
# muter : muter
# muluk : muluk
# anggota : anggota
# terdaftar : daftar
# family : family
# daftarkan : daftar
# fitur : fitur
# membantu : bantu
# menemukan : temu
# trims : trims
# ketengan : keteng
# notifnya : notifnya
# kecuali : kecuali
# dream : dream
# fusion : fusion
# because : because
# viable : viable
# option : option
# solve : solve
# crisis : crisis
# right : right
# now : now
# clean : clean
# powerful : powerful
# other : other
# renewables : renewables
# need : need
# utilized : utilized
# massive : massive
# scale : scale
# depend : depend
# natural : natural
# conditions : conditions
# ngetag : ngetag
# event : event
# tyes : tyes
# youth : youth
# entrepreneur : entrepreneur
# squad : squad
# acaranya : acara
# wib : wib
# saksikan : saksi
# maxstream : maxstream
# wow : wow
# farukdemir : farukdemir
# sea : sea
# ocean : ocean
# water : water
# also : also
# aboundant : aboundant
# utilised : utilised
# working : working
# microhydroelectricity : microhydroelectricity
# will : will
# waste : waste
# engine : engine
# has : has
# recycling : recycling
# feature : feature
# litres : litres
# required : required
# once : once
# cars : cars
# domestic : domestic
# generators : generators
# run : run
# continuously : continuously
# kuis : kuis
# facebook : facebook
# menulis : tulis
# fanpage : fanpage
# banar : banar
# buhankam : buhankam
# jua : jua
# paketannya : paket
# infona : infona
# napa : napa
# bgtttt : bgtttt
# gamemax : gamemax
# iso : iso
# digunake : digunake
# mangan : mangan
# kakeane : kakeane
# koneksinya : koneksi
# diperbaiki : baik
# grc : grc
# bojonggede : bojonggede
# bogor : bogor
# barat : barat
# outlet : outlet
# kode : kode
# kilat : kilat
# urgent : urgent
# semexant : semexant
# glenn : glenn
# menieb : menieb
# toniey : toniey
# kendala : kendala
# wtf : wtf
# here : here
# dtac : dtac
# seluler : seluler
# sial : sial
# kemana : mana
# dieum : dieum
# kejelasan : jelas
# jangkan : jangkan
# sosial : sosial
# media : media
# pending : pending
# terlelet : lelet
# abad : abad
# pemenangnya : menang
# cibinong : cibinong
# babak : babak
# playoff : playoff
# zenius : zenius
# ilmupedia : ilmupedia
# berani : berani
# season : season
# inibknp : inibknp
# tagihan : tagih
# gamuncul : gamuncul
# bayarnya : bayar
# offense : offense
# menang : menang
# hadiah : hadiah
# actually : actually
# sucks : sucks
# aselii : aselii
# keseell : keseell
# kelewat : lewat
# jungkook : jungkook
# terooosss : terooosss
# jualan : jual
# ngaktifin : ngaktifin
# roaming : roaming
# brsanq : brsanq
# dipke : dipke
# seinget : seinget
# keterangan : terang
# diset : set
# kpn : kpn
# dipakenya : dipakenya
# blg : blg
# bsk : bsk
# ajg : ajg
# ice : ice
# pizza : pizza
# blank : blank
# spot : spot
# bangettttt : bangettttt
# review : review
# test : test
# speed : speed
# star : star
# kartuhalo : kartuhalo
# telkomhell : telkomhell
# haduuuu : haduuuu
# gasss : gasss
# dicariin : dicariin
# sender : sender
# lola : lola
# bngt : bngt
# pengisian : isi
# nominal : nominal
# pastikan : pasti
# bri : bri
# testi : testi
# tag : tag
# sell : sell
# yoi : yoi
# ogut : ogut
# match : match
# butuh : butuh
# meriah : riah
# ribet : ribet
# berlangganan : langgan
# hate : hate
# resmi : resmi
# milik : milik
# promosinya : promosi
# blablabla : blablabla
# terpotong : potong
# ketidaktahuannya : ketidaktahuannya
# blame : blame
# everything : everything
# first : first
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# malang : malang
# bedmar : bedmar
# one : one
# gets : gets
# chance : chance
# dogs : dogs
# man : man
# best : best
# friend : friend
# cat : cat
# was : was
# setting : setting
# sabotage : sabotage
# theory : theory
# much : much
# concentration : concentration
# real : real
# issue : issue
# imo : imo
# said : said
# www : www
# claimbtc : claimbtc
# pro : pro
# hope : hope
# helps : helps
# cheers : cheers
# hurry : hurry
# terblokir : blokir
# sultan : sultan
# fuck : fuck
# there : there
# shortage : shortage
# remarkable : remarkable
# ideas : ideas
# missing : missing
# execute : execute
# them : them
# ind : ind
# ngemper : ngemper
# diparkiran : parkir
# gambar : gambar
# errr : errr
# dadi : dadi
# dominoqq : dominoqq
# onfire : onfire
# kontakk : kontakk
# awas : awas
# iyah : iyah
# viral : viral
# ring : ring
# tbw : tbw
# vitaalvia : vitaalvia
# nsp : nsp
# buruan : buru
# dapatkan : dapat
# ost : ost
# sinetron : sinetron
# favorit : favorit
# dinyanyikan : nyanyi
# idola : idola
# subscribe : subscribe
# cmp : cmp
# label : label
# sesore : sore
# konfirmasi : konfirmasi
# kaaihan : kaaihan
# nama : nama
# kelakuan : laku
# level : level
# rusak : rusak
# sia : sia
# derita : derita
# tele : tele
# proxy : proxy
# bangett : bangett
# setiamu : setia
# harapan : harap
# warga : warga
# pasir : pasir
# indah : indah
# kunto : kunto
# darussalam : darussalam
# hulu : hulu
# membangun : bangun
# selatan : selatan
# dinyalnya : dinyalnya
# masyaallah : masyaallah
# susahnya : susah
# does : does
# lawas : lawas
# lansung : lansung
# mudah : mudah
# terjangkau : jangkau
# mengatasnamakan : mengatasnamakan
# priode : priode
# thn : thn
# mengirimkan : kirim
# dri : dri
# password : password
# usut : usut
# bahaya : bahaya
# astagaa : astagaa
# sah : sah
# mimin : mimin
# cuti : cuti
# fup : fup
# sing : sing
# eneng : eneng
# centage : centage
# ojok : ojok
# lucu : lucu
# report : report
# yutubnya : yutubnya
# ditonton : tonton
# dislike : dislike
# traffic : traffic
# numpang : numpang
# promosi : promosi
# gan : gan
# topup : topup
# pln : pln
# prabayar : prabayar
# plus : plus
# gadibales : gadibales
# arahin : arahin
# veronika : veronika
# both : both
# kouta : kouta
# abis : abis
# indramayu : indramayu
# semenjak : semenjak
# kuy : kuy
# nikmati : nikmat
# rp : rp
# dapetin : dapetin
# beragam : agam
# portal : portal
# learning : learning
# sekolah : sekolah
# kampus : kampus
# apasih : apasih
# gembira : gembira
# nycta : nycta
# gina : gina
# ajak : ajak
# lunch : lunch
# shopping : shopping
# bareng : bareng
# hubungi : hubung
# markonah : markonah
# hilang : hilang
# padhal : padhal
# langanan : langanan
# lowongan : lowong
# kerja : kerja
# indonesia : indonesia
# dibutuhkan : butuh
# kua : kua
# tan : tan
# pic : pic
# ngeklaim : ngeklaim
# bonusan : bonus
# amit : amit
# yatuhan : yatuhan
# menguji : uji
# kesabaran : sabar
# tethering : tethering
# tlfon : tlfon
# hitungan : hitung
# mnit : mnit
# sll : sll
# putus : putus
# nada : nada
# tutut : tutut
# abs : abs
# pengaturan : atur
# apn : apn
# dll : dll
# caplok : caplok
# bunian : bunian
# kebuka : buka
# reddit : reddit
# website : website
# porn : porn
# incognitio : incognitio
# sekaramg : sekaramg
# mabok : mabok
# yutub : yutub
# adegan : adegan
# sby : sby
# kebayang : bayang
# pinggiran : pinggir
# gresik : gresik
# akh : akh
# wonder : wonder
# maybe : maybe
# secretly : secretly
# picking : picking
# where : where
# nikola : nikola
# tesla : tesla
# left : left
# sure : sure
# internets : internets
# fine : fine
# tapping : tapping
# into : into
# earth : earth
# magnetic : magnetic
# field : field
# baller : baller
# move : move
# lol : lol
# komitmen : komitmen
# tingkatkan : tingkat
# kesetaraan : tara
# pemerataan : perata
# broadband : broadband
# ponsel : ponsel
# ceria : ceria
# mual : mual
# bntr : bntr
# trending : trending
# miiinn : miiinn
# please : please
# thankyou : thankyou
# hijaudaun : hijaudaun
# ketik : ketik
# ktsep : ktsep
# lambat : lambat
# donggg : donggg
# mamah : mamah
# daxx : daxx
# egk : egk
# cok : cok
# berkat : berkat
# nimbun : nimbun
# ratusan : ratus
# bwt : bwt
# jualin : jualin
# kluarga : kluarga
# trutama : trutama
# loyal : loyal
# ahahahahahah : ahahahahahah
# sbg : sbg
# alumni : alumni
# gedung : gedung
# kebakaran : bakar
# excel : excel
# pacaran : pacar
# kualitasnya : kualitas
# seengganya : seengganya
# harganya : harga
# diturunin : diturunin
# kualitas : kualitas
# loadingnya : loadingnya
# double : double
# kill : kill
# myorbit : myorbit
# engga : engga
# ikutan : ikut
# cover : cover
# kreasi : kreasi
# memenangkan : menang
# iphone : iphone
# saldo : saldo
# total : total
# jutaan : juta
# rupiah : rupiah
# ikutannya : ikut
# formal : formal
# education : education
# living : living
# self : self
# fortune : fortune
# urutan : urut
# kasta : kasta
# pemakai : pakai
# perdana : perdana
# youtuber : youtuber
# sugar : sugar
# daddy : daddy
# pns : pns
# mahasiswa : mahasiswa
# tua : tua
# tajir : tajir
# karyawan : karyawan
# swasta : swasta
# kost : kost
# pedagang : dagang
# pelajar : ajar
# penerima : terima
# beras : beras
# raskin : raskin
# socmed : socmed
# nikmatin : nikmatin
# cashback : cashback
# contoh : contoh
# pelayanan : layan
# halmahera : halmahera
# utara : utara
# terlampir : lampir
# pemeriksaan : periksa
# monopoli : monopoli
# maluku : malu
# dipanggil : panggil
# polres : polres
# rasuk : rasuk
# gadateng : gadateng
# bocor : bocor
# ngamuk : ngamuk
# curiga : curiga
# ditutupin : ditutupin
# adminnya : adminnya
# seminggu : minggu
# aktivitas : aktivitas
# twitternya : twitternya
# adsl : adsl
# isdn : isdn
# dibalas : balas
# cuman : cuman
# dudududu : dudududu
# speednya : speednya
# beda : beda
# lancarnya : lancar
# cacing : cacing
# ngakak : ngakak
# heboh : heboh
# heheh : heheh
# hahah : hahah
# ngeluarin : ngeluarin
# gituan : gituan
# jarang : jarang
# lokal : lokal
# weh : weh
# pantesan : pantesan
# culas : culas
# lord : lord
# membangongkan : membangongkan
# sekalii : sekali
# keluhan : keluh
# trimakasii : trimakasii
# alhamdulilla : alhamdulilla
# terimakasih : terimakasih
# mendorong : dorong
# diisi : isi
# keperluan : perlu
# raib : raib
# hei : hei
# makasih : makasih
# bandung : bandung
# heran : heran
# segini : gin
# kelen : kelen
# buriq : buriq
# wooii : wooii
# dikemanain : dikemanain
# hentai : hentai
# gojek : gojek
# diskon : diskon
# pulsatel : pulsatel
# feb : feb
# halooo : halooo
# last : last
# activenya : activenya
# komplain : komplain
# ngebut : ngebut
# halal : halal
# disambat : sambat
# murahan : murah
# merampungkan : rampung
# jakarta : jakarta
# mengumumkan : umum
# finalisasi : final
# dayamitra : dayamitra
# termurah : murah
# realisasi : realisasi
# hallooooo : hallooooo
# tindak : tindak
# bumn : bumn
# punyanya : punya
# btn : btn
# guru : guru
# ade : ade
# stop : stop
# gamesmax : gamesmax
# upgrade : upgrade
# selani : selan
# pubg : pubg
# utntuk : utntuk
# kestabilan : stabil
# max : max
# gunaa : gunaa
# fyi : fyi
# bendungan : bendung
# just : just
# wait : wait
# ads : ads
# after : after
# any : any
# cuaca : cuaca
# cerah : cerah
# hidup : hidup
# sungguh : sungguh
# menfess : menfess
# telegram : telegram
# tergantung : gantung
# providernya : providernya
# indihome : indihome
# downloadnya : downloadnya
# dibatasi : batas
# operator : operator
# scroll : scroll
# kebawah : bawah
# teleponan : telepon
# kring : kring
# weekend : weekend
# telepon : telepon
# menit : menit
# brg : brg
# applikasinya : applikasinya
# kenceng : kenceng
# sumbagteng : sumbagteng
# dimaksimalkan : maksimal
# stock : stock
# rese : rese
# bgttttttttt : bgttttttttt
# content : content
# creator : creator
# rajin : rajin
# posting : posting
# loopers : loopers
# siapin : siapin
# dikasih : kasih
# pliz : pliz
# dicoba : coba
# mincun : mincun
# nomernya : nomernya
# rabu : rabu
# dipakai : pakai
# telfon : telfon
# umsfess : umsfess
# lur : lur
# sadari : sadar
# kehidupan : hidup
# memanfaatkan : manfaat
# teknologi : teknologi
# kecerdasan : cerdas
# buatan : buat
# contohnya : contoh
# asisten : asisten
# virtual : virtual
# asisstent : asisstent
# belanja : belanja
# cepat : cepat
# cuy : cuy
# dsny : dsny
# gimanaa : gimanaa
# mencukupi : cukup
# penjual : jual
# wetv : wetv
# setahun : tahun
# mobile : mobile
# gapake : gapake
# tunggu : tunggu
# agama : agama
# urus : urus
# terdekat : dekat
# yaaa : yaaa
# gestun : gestun
# pencairan : cair
# paylater : paylater
# kredivo : kredivo
# akulaku : akulaku
# traveloka : traveloka
# indodana : indodana
# homecredit : homecredit
# kredit : kredit
# mbcgestunonline : mbcgestunonline
# payah : payah
# grand : grand
# galaxy : galaxy
# bekasi : bekas
# sejelek : jelek
# berbaik : baik
# alhamdulillah : alhamdulillah
# komunikasi : komunikasi
# sabang : sabang
# island : island
# annnaaaa : annnaaaa
# lawak : lawak
# informasi : informasi
# perangkat : perangkat
# iot : iot
# palsu : palsu
# penipu : tipu
# sindikat : sindikat
# polri : polri
# membeli : beli
# lampirkan : lampir
# screenshot : screenshot
# history : history
# jalan : jalan
# jga : jga
# yul : yul
# sinyalmu : sinyal
# kucing : kucing
# geus : geus
# lila : lila
# haluan : haluan
# urang : urang
# euy : euy
# ditindak : tindak
# anyway : anyway
# dititipin : dititipin
# holla : holla
# transaksi : transaksi
# melalu : lalu
# banking : banking
# butuhnya : butuh
# ketuk : ketuk
# kay : kay
# unroll : unroll
# selular : selular
# soon : soon
# kikikikikikik : kikikikikikik
# atuh : atuh
# biasana : biasana
# telkomselkan : telkomselkan
# kodenya : kode
# suee : suee
# ngezoom : ngezoom
# danta : danta
# pisan : pis
# kesatuan : satu
# kompak : kompak
# paketin : paketin
# rbt : rbt
# citraallegro : citraallegro
# kesetiaan : setia
# setia : setia
# read : read
# pliiss : pliiss
# opo : opo
# meneh : teh
# berbagi : bagi
# mengurus : urus
# persyaratannya : syarat
# gausah : gausah
# jleg : jleg
# menjual : jual
# dihutan : hut
# atmm : atmm
# money : money
# dkk : dkk
# upgradenya : upgradenya
# tcash : tcash
# kerjasama : kerjasama
# bensin : bensin
# segel : segel
# ask : ask
# long : long
# number : number
# active : active
# today : today
# hours : hours
# change : change
# ngurus : ngurus
# mbanking : mbanking
# tanggal : tanggal
# nek : nek
# akeh : akeh
# keitung : keitung
# mudorot : mudorot
# sekaliiii : sekaliiii
# bikinnya : bikin
# dips : dips
# tokopedia : tokopedia
# masuknya : masuk
# isiin : isiin
# toped : toped
# takut : takut
# ketahuan : tahu
# xixi : xixi
# mantab : mantab
# mudorote : mudorote
# baek : baek
# kabel : kabel
# rendah : rendah
# terpaksa : paksa
# disanggah : sanggah
# balok : balok
# masyarakat : masyarakat
# masukin : masukin
# card : card
# buang : buang
# baca : baca
# gilaaaaa : gilaaaaa
# darimana : darimana
# ngeribetin : ngeribetin
# barusan : barusan
# kakk : kakk
# simak : simak
# ulasannya : ulas
# lanjutin : lanjutin
# rekomendasiin : rekomendasiin
# worth : worth
# sosmed : sosmed
# kulon : kulon
# boros : boros
# bentar : bentar
# bls : bls
# ndaa : ndaa
# yuhuuu : yuhuuu
# pertandingan : tanding
# olahraga : olahraga
# film : film
# series : series
# seru : seru
# vidio : vidio
# yukk : yukk
# premier : premier
# platinum : platinum
# menemani : tani
# tayangan : tayang
# harinya : hari
# aaaaah : aaaaah
# laah : laah
# ilangan : ilangan
# dibenerin : dibenerin
# hey : hey
# korup : korup
# begimana : begimana
# selesai : selesai
# hay : hay
# ambil : ambil
# patahin : patahin
# sampah : sampah
# yok : yok
# sebarkan : sebar
# ilmu : ilmu
# pedia : dia
# gmeet : gmeet
# askrl : askrl
# iyaaa : iyaaa
# even : even
# nyandet : nyandet
# terdepan : depan
# bbrp : bbrp
# lokasi : lokasi
# rawakalong : rawakalong
# gunung : gunung
# sindur : sindur
# jae : jae
# skt : skt
# south : south
# korea : korea
# dolanan : dolan
# neh : neh
# duku : duku
# surat : surat
# polisi : polisi
# dihubungi : hubung
# testimoni : testimoni
# pkl : pkl
# berhenti : henti
# apps : apps
# bagaiaman : bagaiaman
# pakainya : pakai
# tertulis : tulis
# pang : pang
# jajal : jajal
# neng : neng
# lgi : lgi
# laiki : laik
# yoraenek : yoraenek
# balesan : balesan
# koyone : koyone
# resign : resign
# kabeh : kabeh
# sepaket : paket
# skrgggg : skrgggg
# {'promo': 'promo', 'telkomsel': 'telkomsel', 'kupuji': 'puji', 'stabil': 'stabil', '': '', 'ngadu': 'ngadu', 'gerai': 'gerai', 'customer': 'customer', 'servicenya': 'servicenya', 'curhat': 'curhat', 'dikirimin': 'dikirimin', 'sms': 'sms', 'lhaaaa': 'lhaaaa', 'kocak': 'kocak', 'briefnya': 'briefnya', 'gmn': 'gmn', 'deh': 'deh', 'kli': 'kli', 'dpt': 'dpt', 'aduan': 'adu', 'kek': 'kek', 'gini': 'gin', 'wkwkwk': 'wkwkwk', 'gerangan': 'gerangan', 'spam': 'spam', 'tolong': 'tolong', 'kolabs': 'kolabs', 'bersih': 'bersih', 'duuunkssss': 'duuunkssss', 'bangun': 'bangun', 'pagi': 'pagi', 'buka': 'buka', 'ngucapin': 'ngucapin', 'selamat': 'selamat', 'cantiik': 'cantiik', 'pesan': 'pesan', 'manis': 'manis', 'kuota': 'kuota', 'menipis': 'tip', 'ama': 'ama', 'udah': 'udah', 'minggu': 'minggu', 'busuk': 'busuk', 'buffer': 'buffer', 'parah': 'parah', 'banget': 'banget', 'melebihi': 'lebih', 'kartu': 'kartu', 'indosat': 'indosat', 'mybusiness': 'mybusiness', 'sinyal': 'sinyal', 'lelet': 'lelet', 'dana': 'dana', 'shopeepay': 'shopeepay', 'open': 'open', 'convert': 'convert', 'tukar': 'tukar', 'tuker': 'tuker', 'pulsa': 'pulsa', 'axis': 'axis', 'three': 'three', 'tri': 'tri', 'tsel': 'tsel', 'isat': 'isat', 'uang': 'uang', 'atm': 'atm', 'bank': 'bank', 'ewallet': 'ewallet', 'non': 'non', 'premium': 'premium', 'prem': 'prem', 'ovo': 'ovo', 'gopay': 'gopay', 'linkaja': 'linkaja', 'jual': 'jual', 'preset': 'preset', 'lightroom': 'lightroom', 'ios': 'ios', 'andro': 'andro', 'agen': 'agen', 'notif': 'notif', 'wes': 'wes', 'gek': 'gek', 'jongkarke': 'jongkarke', 'wae': 'wae', 'thetheli': 'thetheli', 'mengecek': 'ecek', 'nomor': 'nomor', 'lihat': 'lihat', 'prediski': 'prediski', 'togel': 'togel', 'february': 'february', 'palapatoto': 'palapatoto', 'bandar': 'bandar', 'games': 'games', 'online': 'online', 'new': 'new', 'member': 'member', 'bonus': 'bonus', 'deposit': 'deposit', 'login': 'login', 'site': 'site', 'terima': 'terima', 'info': 'info', 'live': 'live', 'chat': 'chat', 'jam': 'jam', 'beneran': 'beneran', 'rencana': 'rencana', 'iki': 'iki', 'dus': 'dus', 'tenan': 'tenan', 'sinyale': 'sinyale', 'ilang': 'ilang', 'koyo': 'koyo', 'koe': 'koe', 'min': 'min', 'giga': 'giga', 'sisa': 'sisa', 'mb': 'mb', 'sehari': 'hari', 'org': 'org', 'hemat': 'hemat', 'kirain': 'kirain', 'bug': 'bug', 'gataunya': 'gataunya', 'koneksi': 'koneksi', 'bapuk': 'bapuk', 'theteli': 'theteli', 'dol': 'dol', 'kilon': 'kilon', 'kenapaa': 'kenapaa', 'lagiii': 'lagiii', 'admin': 'admin', 'langganan': 'langgan', 'aktfikan': 'aktfikan', 'paket': 'paket', 'internet': 'internet', 'memiliki': 'milik', 'varian': 'varian', 'data': 'data', 'flash': 'flash', 'bulk': 'bulk', 'omg': 'omg', 'combo': 'combo', 'sakti': 'sakti', 'surprise': 'surprise', 'deal': 'deal', 'tiktok': 'tiktok', 'youtube': 'youtube', 'prediksi': 'prediksi', 'pools': 'pools', 'februari': 'februari', 'transfer': 'transfer', 'ready': 'ready', 'smartfren': 'smartfren', 'area': 'area', 'jawa': 'jawa', 'bali': 'bal', 'dorong': 'dorong', 'pengguna': 'guna', 'beralih': 'alih', 'bonekaqq': 'bonekaqq', 'banjir': 'banjir', 'wede': 'wede', 'bebas': 'bebas', 'potongan': 'potong', 'bossku': 'bossku', 'daftar': 'daftar', 'buktikan': 'bukti', 'pemenang': 'menang', 'pkv': 'pkv', 'link': 'link', 'dot': 'dot', 'com': 'com', 'whatsapp': 'whatsapp', 'line': 'line', 'udh': 'udh', 'mati': 'mati', 'lampu': 'lampu', 'jaringannya': 'jaring', 'kuntul': 'kuntul', 'wifi': 'wifi', 'lemot': 'lot', 'listrik': 'listrik', 'malam': 'malam', 'unlimitied': 'unlimitied', 'browsing': 'browsing', 'ruangan': 'ruang', 'darah': 'darah', 'ancur': 'ancur', 'sialan': 'sial', 'hahahahahah': 'hahahahahah', 'ganti': 'ganti', 'sayang': 'sayang', 'nomornya': 'nomor', 'dipake': 'dipake', 'iya': 'iya', 'bar': 'bar', 'penuh': 'penuh', 'loading': 'loading', 'matiin': 'matiin', 'trs': 'trs', 'hidupin': 'hidupin', 'enak': 'enak', 'masang': 'masang', 'app': 'app', 'payment': 'payment', 'via': 'via', 'anjing': 'anjing', 'kadang': 'kadang', 'suka': 'suka', 'tersedia': 'sedia' ...
# ------------------------
# Pandas Apply:   0%|          | 0/766 [00:00<?, ?it/s]
#                                                 content  \
# 0                 @ffoodfess promo telkomsel ga sih ini
# 1     @telkomsel untuk saat ini kamu kupuji karena p...
# 2     @ibalpradana_ @methawidyana @kemkominfo @aduan...
# 3     @alizawijaya @ibalpradana_ @txtdrpemerintah @k...
# 5     aku kira bangun pagi buka hp ada yg ngucapin s...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995  @byu_id @telkomsel min sinyalnya kok ilang2an ...
# 1996      @kangsetrom @telkomsel laiki yoraenek balesan
# 1998  @irwaaaaaaaan @telkomsel koyone admin e resign...
# 1999  telkomsel sama indihome bener bener sepaket ya...
#
#                                          cleaning_tweet  \
# 0                               promo telkomsel sih ini
# 1      untuk saat ini kamu kupuji karena paling stabil
# 2      ngadu gerai nya aja malah customer servicenya...
# 3      nah ada apa gerangan sering bgt sms spam nih ...
# 5     aku kira bangun pagi buka ada ngucapin selamat...
# ...                                                 ...
# 1994  telkomsel tuh emang lgi ada masalah sama jarin...
# 1995                    min sinyalnya kok ilang an sih
# 1996                             laiki yoraenek balesan
# 1998      koyone admin resign kabeh gara  akeh gangguan
# 1999  telkomsel sama indihome bener bener sepaket sk...
#
#                                              tokenisasi  \
# 0                          [promo, telkomsel, sih, ini]
# 1     [untuk, saat, ini, kamu, kupuji, karena, palin...
# 2     [, ngadu, gerai, nya, aja, malah, customer, se...
# 3     [, nah, ada, apa, gerangan, sering, bgt, sms, ...
# 5     [aku, kira, bangun, pagi, buka, ada, ngucapin,...
# ...                                                 ...
# 1994  [telkomsel, tuh, emang, lgi, ada, masalah, sam...
# 1995          [, min, sinyalnya, kok, ilang, an, sih, ]
# 1996                         [laiki, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, sama, indihome, bener, bener, sepa...
#
#                                                stopword  \
# 0                                    [promo, telkomsel]
# 1                                    [kupuji, stabil, ]
# 2     [, ngadu, gerai, customer, servicenya, curhat,...
# 3     [, gerangan, sms, spam, tolong, kolabs, bersih...
# 5     [bangun, pagi, buka, ngucapin, selamat, pagi, ...
# ...                                                 ...
# 1994  [telkomsel, emang, lgi, jaringan, yaa, sumpah,...
# 1995                        [, min, sinyalnya, ilang, ]
# 1996                         [laiki, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, indihome, bener, bener, sepaket, s...
#
#                                                stemming
# 0                                    [promo, telkomsel]
# 1                                      [puji, stabil, ]
# 2     [, ngadu, gerai, customer, servicenya, curhat,...
# 3     [, gerangan, sms, spam, tolong, kolabs, bersih...
# 5     [bangun, pagi, buka, ngucapin, selamat, pagi, ...
# ...                                                 ...
# 1994  [telkomsel, emang, lgi, jaring, yaa, sumpah, j...
# 1995                           [, min, sinyal, ilang, ]
# 1996                          [laik, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, indihome, bener, bener, paket, skr...
#
# [766 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0                                    [promo, telkomsel]
# 1                                      [puji, stabil, ]
# 2     [, ngadu, gerai, customer, servicenya, curhat,...
# 3     [, gerangan, sms, spam, tolong, kolabs, bersih...
# 5     [bangun, pagi, buka, ngucapin, selamat, pagi, ...
# ...                                                 ...
# 1994  [telkomsel, emang, lgi, jaring, yaa, sumpah, j...
# 1995                           [, min, sinyal, ilang, ]
# 1996                          [laik, yoraenek, balesan]
# 1998  [koyone, admin, resign, kabeh, gara, akeh, gan...
# 1999  [telkomsel, indihome, bener, bener, paket, skr...
#
# [766 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_2.xlsx')
