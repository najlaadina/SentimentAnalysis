# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @_darkestdawn Siap, Kak. Mohon berkenan menung...
# 1     Mau menang sampai puluhan hingga ratusan juga?...
# 2     Mau menang sampai puluhan hingga ratusan juga?...
# 3     Mau menang sampai puluhan hingga ratusan juga?...
# 4     @Telkomsel \n\nNmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  Telkomsel jelek banget astaghfirullah. Minta d...
# 1997  @kesimayo Hai, Kak. Maaf ya. Mengenai kendala ...
# 1998  @Telkomsel Selamat malam, sinyal telkomsel apa...
# 1999  @Telkomsel ini kuota multimedia gimana ya maks...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 27

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @_darkestdawn Siap, Kak. Mohon berkenan menung...
# 1     Mau menang sampai puluhan hingga ratusan juga?...
# 2     Mau menang sampai puluhan hingga ratusan juga?...
# 3     Mau menang sampai puluhan hingga ratusan juga?...
# 4     @Telkomsel \n\nNmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  Telkomsel jelek banget astaghfirullah. Minta d...
# 1997  @kesimayo Hai, Kak. Maaf ya. Mengenai kendala ...
# 1998  @Telkomsel Selamat malam, sinyal telkomsel apa...
# 1999  @Telkomsel ini kuota multimedia gimana ya maks...
#
# [1958 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @_darkestdawn siap, kak. mohon berkenan menung...
# 1     mau menang sampai puluhan hingga ratusan juga?...
# 2     mau menang sampai puluhan hingga ratusan juga?...
# 3     mau menang sampai puluhan hingga ratusan juga?...
# 4     @telkomsel \n\nnmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  telkomsel jelek banget astaghfirullah. minta d...
# 1997  @kesimayo hai, kak. maaf ya. mengenai kendala ...
# 1998  @telkomsel selamat malam, sinyal telkomsel apa...
# 1999  @telkomsel ini kuota multimedia gimana ya maks...
#
# [1958 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @_darkestdawn siap, kak. mohon berkenan menung...
# 1     mau menang sampai puluhan hingga ratusan juga?...
# 2     mau menang sampai puluhan hingga ratusan juga?...
# 3     mau menang sampai puluhan hingga ratusan juga?...
# 4     @telkomsel \n\nnmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  telkomsel jelek banget astaghfirullah. minta d...
# 1997  @kesimayo hai, kak. maaf ya. mengenai kendala ...
# 1998  @telkomsel selamat malam, sinyal telkomsel apa...
# 1999  @telkomsel ini kuota multimedia gimana ya maks...
#
#                                          cleaning_tweet
# 0      darkestdawn siap kak mohon berkenan menunggu ...
# 1     mau menang sampai puluhan hingga ratusan juga ...
# 2     mau menang sampai puluhan hingga ratusan juga ...
# 3     mau menang sampai puluhan hingga ratusan juga ...
# 4     nmr saya tidak bisa telepon dan dihubungi saya...
# ...                                                 ...
# 1995  butuh paket internet plzzz atau telkomsel deh ...
# 1996  telkomsel jelek banget astaghfirullah minta di...
# 1997  hai kak maaf mengenai kendala ketidaksesuaian ...
# 1998  selamat malam sinyal telkomsel apakah lagi gan...
# 1999  ini kuota multimedia gimana maksudnya saya pak...
#
# [1958 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @_darkestdawn siap, kak. mohon berkenan menung...
# 1     mau menang sampai puluhan hingga ratusan juga?...
# 2     mau menang sampai puluhan hingga ratusan juga?...
# 3     mau menang sampai puluhan hingga ratusan juga?...
# 4     @telkomsel \n\nnmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  telkomsel jelek banget astaghfirullah. minta d...
# 1997  @kesimayo hai, kak. maaf ya. mengenai kendala ...
# 1998  @telkomsel selamat malam, sinyal telkomsel apa...
# 1999  @telkomsel ini kuota multimedia gimana ya maks...
#
#                                          cleaning_tweet  \
# 0      darkestdawn siap kak mohon berkenan menunggu ...
# 1     mau menang sampai puluhan hingga ratusan juga ...
# 2     mau menang sampai puluhan hingga ratusan juga ...
# 3     mau menang sampai puluhan hingga ratusan juga ...
# 4     nmr saya tidak bisa telepon dan dihubungi saya...
# ...                                                 ...
# 1995  butuh paket internet plzzz atau telkomsel deh ...
# 1996  telkomsel jelek banget astaghfirullah minta di...
# 1997  hai kak maaf mengenai kendala ketidaksesuaian ...
# 1998  selamat malam sinyal telkomsel apakah lagi gan...
# 1999  ini kuota multimedia gimana maksudnya saya pak...
#
#                                              tokenisasi
# 0     [, darkestdawn, siap, kak, mohon, berkenan, me...
# 1     [mau, menang, sampai, puluhan, hingga, ratusan...
# 2     [mau, menang, sampai, puluhan, hingga, ratusan...
# 3     [mau, menang, sampai, puluhan, hingga, ratusan...
# 4     [nmr, saya, tidak, bisa, telepon, dan, dihubun...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, atau, telkomse...
# 1996  [telkomsel, jelek, banget, astaghfirullah, min...
# 1997  [hai, kak, maaf, mengenai, kendala, ketidakses...
# 1998  [selamat, malam, sinyal, telkomsel, apakah, la...
# 1999  [ini, kuota, multimedia, gimana, maksudnya, sa...
#
# [1958 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @_darkestdawn siap, kak. mohon berkenan menung...
# 1     mau menang sampai puluhan hingga ratusan juga?...
# 2     mau menang sampai puluhan hingga ratusan juga?...
# 3     mau menang sampai puluhan hingga ratusan juga?...
# 4     @telkomsel \n\nnmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  telkomsel jelek banget astaghfirullah. minta d...
# 1997  @kesimayo hai, kak. maaf ya. mengenai kendala ...
# 1998  @telkomsel selamat malam, sinyal telkomsel apa...
# 1999  @telkomsel ini kuota multimedia gimana ya maks...
#
#                                          cleaning_tweet  \
# 0      darkestdawn siap kak mohon berkenan menunggu ...
# 1     mau menang sampai puluhan hingga ratusan juga ...
# 2     mau menang sampai puluhan hingga ratusan juga ...
# 3     mau menang sampai puluhan hingga ratusan juga ...
# 4     nmr saya tidak bisa telepon dan dihubungi saya...
# ...                                                 ...
# 1995  butuh paket internet plzzz atau telkomsel deh ...
# 1996  telkomsel jelek banget astaghfirullah minta di...
# 1997  hai kak maaf mengenai kendala ketidaksesuaian ...
# 1998  selamat malam sinyal telkomsel apakah lagi gan...
# 1999  ini kuota multimedia gimana maksudnya saya pak...
#
#                                              tokenisasi  \
# 0     [, darkestdawn, siap, kak, mohon, berkenan, me...
# 1     [mau, menang, sampai, puluhan, hingga, ratusan...
# 2     [mau, menang, sampai, puluhan, hingga, ratusan...
# 3     [mau, menang, sampai, puluhan, hingga, ratusan...
# 4     [nmr, saya, tidak, bisa, telepon, dan, dihubun...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, atau, telkomse...
# 1996  [telkomsel, jelek, banget, astaghfirullah, min...
# 1997  [hai, kak, maaf, mengenai, kendala, ketidakses...
# 1998  [selamat, malam, sinyal, telkomsel, apakah, la...
# 1999  [ini, kuota, multimedia, gimana, maksudnya, sa...
#
#                                                stopword
# 0     [, darkestdawn, kak, mohon, berkenan, menunggu...
# 1     [menang, puluhan, ratusan, proses, cepat, depo...
# 2     [menang, puluhan, ratusan, proses, cepat, depo...
# 3     [menang, puluhan, ratusan, proses, cepat, depo...
# 4     [nmr, telepon, dihubungi, paket, telpon, combo...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, telkomsel, deh...
# 1996  [telkomsel, jelek, banget, astaghfirullah, dim...
# 1997  [hai, kak, maaf, kendala, ketidaksesuaian, pen...
# 1998  [selamat, malam, sinyal, telkomsel, gangguan, ...
# 1999  [kuota, multimedia, gimana, maksudnya, pakai, ...
#
# [1958 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3598
# ------------------------
#  :
# darkestdawn : darkestdawn
# kak : kak
# mohon : mohon
# berkenan : kenan
# menunggu : tunggu
# interaksi : interaksi
# makasih : makasih
# tere : tere
# menang : menang
# puluhan : puluh
# ratusan : ratus
# proses : proses
# cepat : cepat
# deposit : deposit
# withdraw : withdraw
# pembayaran : bayar
# bank : bank
# pulsa : pulsa
# telkomsel : telkomsel
# online : online
# jam : jam
# live : live
# chat : chat
# bonus : bonus
# referral : referral
# rolingan : rolingan
# menyediakan : sedia
# games : games
# user : user
# yuk : yuk
# main : main
# operaqq : operaqq
# nmr : nmr
# telepon : telepon
# dihubungi : hubung
# paket : paket
# telpon : telpon
# combo : combo
# sakti : sakti
# cek : cek
# kah : kah
# daily : daily
# check : check
# app : app
# thanks : thanks
# hancur : hancur
# pendamping : damping
# pendulang : dulang
# suara : suara
# beda : beda
# komut : komut
# open : open
# convert : convert
# all : all
# rekening : rekening
# ewallet : ewallet
# axis : axis
# isat : isat
# indosat : indosat
# im : im
# tsel : tsel
# simpati : simpati
# tri : tri
# three : three
# premium : premium
# non : non
# shopeepay : shopeepay
# dana : dana
# linkaja : linkaja
# ovo : ovo
# gopay : gopay
# fee : fee
# start : start
# prem : prem
# testi : testi
# udah : udah
# infokan : info
# data : data
# via : via
# dibantu : bantu
# privasi : privasi
# terjaga : jaga
# nomor : nomor
# tanggal : tanggal
# kejadian : jadi
# lokasi : lokasi
# detail : detail
# kecamatan : camat
# kota : kota
# berkendala : kendala
# kanaya : kanaya
# hai : hai
# maaf : maaf
# nyaman : nyaman
# kendala : kendala
# sinyal : sinyal
# menyebabkan : sebab
# akses : akses
# internet : internet
# lambat : lambat
# stabil : stabil
# kakak : kakak
# coba : coba
# refresh : refresh
# jaringan : jaring
# off : off
# service : service
# ready : ready
# reguler : reguler
# nambah : nambah
# aktif : aktif
# smartfren : smartfren
# minat : minat
# langsung : langsung
# bio : bio
# yaa : yaa
# wts : wts
# wtb : wtb
# murah : murah
# provider : provider
# langsug : langsug
# kualitas : kualitas
# knpa : knpa
# emosi : emosi
# buang : buang
# energi : energi
# tolong : tolong
# diperbaiki : baik
# daerah : daerah
# sndiri : sndiri
# tautan : taut
# terimakasih : terimakasih
# poco : poco
# pro : pro
# dukung : dukung
# bona : bona
# penggunaan : guna
# solusi : solusi
# halo : halo
# ditunggu : tunggu
# respon : respon
# rekan : rekan
# mimin : mimin
# noela : noela
# admin : admin
# plis : plis
# betull : betull
# enak : enak
# yves : yves
# infoin : infoin
# tgl : tgl
# tks : tks
# hakim : hakim
# pastikan : pasti
# masuk : masuk
# aplikasi : aplikasi
# disney : disney
# hotstar : hotstar
# gara : gara
# flop : flop
# maketin : maketin
# udh : udh
# free : free
# langganan : langgan
# min : min
# beli : beli
# plus : plus
# login : login
# nonton : nonton
# disuruh : suruh
# berlangganam : berlangganam
# raisa : raisa
# perihal : perihal
# terpotong : potong
# bantu : bantu
# silakan : sila
# iya : iya
# bagus : bagus
# potongan : potong
# harga : harga
# hallo : hallo
# selamat : selamat
# pagi : pagi
# ngisi : ngisi
# saldonya : saldo
# sampe : sampe
# lupa : lupa
# berkurang : kurang
# sebelah : belah
# kemaren : kemaren
# posisi : posisi
# kemarin : kemarin
# sore : sore
# hilang : hilang
# skrg : skrg
# pakai : pakai
# wifi : wifi
# bantuannya : bantu
# dicheck : dicheck
# nomornya : nomor
# nanya : nanya
# doang : doang
# kuota : kuota
# twitter : twitter
# duluan : duluan
# dipake : dipake
# ato : ato
# utama : utama
# kontak : kontak
# enam : enam
# menyelesaikan : selesai
# mundak : mundak
# sewu : sewu
# april : april
# huhu : huhu
# imyourdad : imyourdad
# luke : luke
# nomer : nomer
# telp : telp
# dibebankan : beban
# google : google
# play : play
# music : music
# membatalkan : batal
# apps : apps
# tsb : tsb
# oktober : oktober
# msh : msh
# ditagih : tagih
# hubungi : hubung
# dilempar : lempar
# saran : saran
# bulanan : bulan
# mengapresiasi : apresiasi
# peningkatan : tingkat
# produk : produk
# layanan : layan
# semoga : moga
# harapan : harap
# terealisasikan : realisasi
# sehat : sehat
# ilham : ilham
# dapet : dapet
# salah : salah
# sasaran : sasar
# pelajar : ajar
# membutuhkan : butuh
# ngent : ngent
# jelek : jelek
# partai : partai
# demokrat : demokrat
# soroti : sorot
# peretasan : retas
# akun : akun
# abang : abang
# erick : erick
# thohir : thohir
# wanti : wanti
# bos : bos
# telkom : telkom
# sexi : sexi
# pancing : pancing
# feature : feature
# pengiriman : kirim
# invoice : invoice
# email : email
# terdaftar : daftar
# dihilangkan : hilang
# aktivasi : aktivasi
# update : update
# available : available
# butuh : butuh
# gimana : gimana
# dapetinnya : dapetinnya
# ifb : ifb
# abdullatif : abdullatif
# telegram : telegram
# direspon : direspon
# bangfu : bangfu
# emg : emg
# gangguan : ganggu
# bang : bang
# drtd : drtd
# pantengin : pantengin
# gambar : gambar
# share : share
# brubah : brubah
# bermasalah : masalah
# kali : kali
# babi : babi
# yaelah : yaelah
# merata : rata
# mbahmu : mbah
# perhatin : perhatin
# noh : noh
# pedalaman : dalam
# terpencil : pencil
# sekedar : dar
# sms : sms
# boro : boro
# mahal : mahal
# susah : susah
# orang : orang
# senin : senin
# kamis : kamis
# buruan : buru
# gabung : gabung
# ligapoker : ligapoker
# aman : aman
# ribet : ribet
# suport : suport
# indonesia : indonesia
# kartu : kartu
# gtu : gtu
# unlimited : unlimited
# kyak : kyak
# minimal : minimal
# link : link
# bingung : bingung
# memilih : pilih
# situs : situs
# terbukti : bukti
# keamanan : aman
# kenyamanan : nyaman
# kunjungi : kunjung
# sahabatpoker : sahabatpoker
# jamin : jamin
# menerima : terima
# wallet : wallet
# contact : contact
# livechat : livechat
# indosahabatpk : indosahabatpk
# info : info
# whatsapp : whatsapp
# why : why
# arum : arum
# bersedia : sedia
# melanjutkan : lanjut
# faza : faza
# sai : sai
# gb : gb
# lemottt : lemottt
# pindahkan : pindah
# otomatis : otomatis
# manual : manual
# restart : restart
# mentok : mentok
# kirimnya : kirim
# kemana : mana
# ampe : ampe
# jengkel : jengkel
# isi : isi
# aturannya : atur
# lumayan : lumayan
# abis : abis
# mata : mata
# kaki : kaki
# kepancal : pancal
# gledak : gledak
# fadh : fadh
# bodoamat : bodoamat
# gua : gua
# kesel : kesel
# resmi : resmi
# meluncur : luncur
# menikmati : nikmat
# parah : parah
# banget : banget
# empet : empet
# nyong : nyong
# pacaran : pacar
# yaaa : yaaa
# mingyu : mingyu
# end : end
# enaknya : enak
# dimata : mata
# semenjak : semenjak
# ganti : ganti
# gue : gue
# apl : apl
# sang : sang
# pencipta : cipta
# samakan : sama
# udaaahhh : udaaahhh
# gitu : gitu
# mulu : mulu
# jawabannya : jawab
# keluhan : keluh
# iyya : iyya
# bad : bad
# network : network
# ever : ever
# informasikan : informasi
# maksud : maksud
# mrk : mrk
# bisnis : bisnis
# bayar : bayar
# emang : emang
# hutang : hutang
# bidang : bidang
# komunikasi : komunikasi
# bangun : bangun
# punyamu : punya
# berlangganan : langgan
# logo : logo
# barunya : baru
# kyk : kyk
# logonya : logo
# firemonkeys : firemonkeys
# mutus : mutus
# sambungan : sambung
# kabel : kabel
# malam : malam
# terkait : kait
# ketentuannya : tentu
# habi : habi
# tiyang : tiyang
# pusinggg : pusinggg
# duh : duh
# gini : gin
# weh : weh
# melemot : lot
# maxtream : maxtream
# dioptimalisasi : optimalisasi
# terbesar : besar
# pelanggan : langgan
# juta : juta
# nyuk : nyuk
# sinyalmu : sinyal
# bosokkk : bosokkk
# suog : suog
# sumpah : sumpah
# knp : knp
# jari : jari
# terakhi : akh
# ampas : ampas
# bngt : bngt
# dahhh : dahhh
# rto : rto
# muluuuuu : muluuuuu
# terbaik : baik
# setting : setting
# apn : apn
# tercepat : cepat
# android : android
# neyney : neyney
# heheheee : heheheee
# dicoba : coba
# diisi : isi
# kepotong : potong
# nggak : nggak
# denger : denger
# orng : orng
# cerita : cerita
# adekku : adekku
# nol : nol
# ngerti : ngerti
# bkn : bkn
# memantau : pantau
# inggris : inggris
# jerman : jerman
# streaming : streaming
# kaga : kaga
# ngasih : ngasih
# gratisan : gratis
# bantuanya : bantuanya
# trms : trms
# sistem : sistem
# mytelkomsel : mytelkomsel
# versi : versi
# terbaru : baru
# berkala : kala
# diharapkan : harap
# normal : normal
# secepatnya : cepat
# allah : allah
# setuju : tuju
# indihomo : indihomo
# samaa : samaa
# ngelagg : ngelagg
# anjing : anjing
# wkwkkk : wkwkkk
# motong : motong
# utang : utang
# datanya : data
# make : make
# keselnya : kesel
# unli : unli
# sabar : sabar
# tesla : tesla
# corp : corp
# hehh : hehh
# ngeri : ngeri
# ribu : ribu
# dipaketin : dipaketin
# lenyap : lenyap
# gegara : gegara
# matiin : matiin
# mobile : mobile
# telkomselnya : telkomselnya
# berlaku : laku
# pkl : pkl
# wib : wib
# status : status
# berhenti : henti
# hub : hub
# sosmed : sosmed
# menipu : tipu
# anjg : anjg
# dibatasin : dibatasin
# dikasi : kasi
# batasan : batas
# babiii : babiii
# pusing : pusing
# bgttt : bgttt
# sorry : sorry
# gabisa : gabisa
# balessssss : balessssss
# lemot : lot
# indihome : indihome
# ngerapik : ngerapik
# katany : katany
# lgi : lgi
# urgent : urgent
# elss : elss
# channel : channel
# baba : baba
# buka : buka
# menu : menu
# habis : habis
# download : download
# twitteran : twitteran
# youtube : youtube
# well : well
# dipotong : potong
# ntar : ntar
# pas : pas
# siang : siang
# error : error
# oala : oala
# btw : btw
# pke : pke
# deng : deng
# konfirmasi : konfirmasi
# terbatas : batas
# karakter : karakter
# rain : rain
# paketan : paket
# bosen : bosen
# seneng : neng
# bercanda : canda
# jeanknown : jeanknown
# seluler : seluler
# kendalanya : kendala
# joe : joe
# ketidaksesuaian : ketidaksesuaian
# karna : karna
# buyback : buyback
# the : the
# king : king
# lip : lip
# fdjr : fdjr
# cobaen : cobaen
# vpn : vpn
# wkwkwk : wkwkwk
# instansi : instansi
# reza : reza
# euro : euro
# maxstream : maxstream
# pastiin : pastiin
# jaringannya : jaring
# lokal : lokal
# ayo : ayo
# lanjutin : lanjutin
# terlewat : lewat
# tungguin : tungguin
# boros : boros
# kokoh : kokoh
# halah : halah
# mola : mola
# salaman : salam
# drop : drop
# lho : lho
# wak : wak
# terlambat : lambat
# chatku : chatku
# dibalas : balas
# udahlah : udahlah
# santai : santai
# komplain : komplain
# hasilnya : hasil
# tetep : tetep
# sedih : sedih
# khawatir : khawatir
# kirim : kirim
# dicek : cek
# mati : mati
# hidupkan : hidup
# hape : hape
# bosan : bosan
# perbaikan : baik
# konsumen : konsumen
# dirugikan : rugi
# tunggu : tunggu
# accept : accept
# sombong : sombong
# bestie : bestie
# pengisian : isi
# nominal : nominal
# pembelian : beli
# thx : thx
# rico : rico
# syarat : syarat
# ngurus : ngurus
# sim : sim
# card : card
# capture : capture
# keterangan : terang
# hola : hola
# seputar : putar
# kuy : kuy
# sesuai : sesuai
# gonta : gonta
# ttep : ttep
# selesai : selesai
# dinikmati : nikmat
# bohong : bohong
# lihat : lihat
# bintang : bintang
# ngeliat : ngeliat
# wallpaper : wallpaper
# jahat : jahat
# deh : deh
# ampuun : ampuun
# ampuunn : ampuunn
# dasar : dasar
# living : living
# merugikan : rugi
# awak : awak
# asuu : asuu
# busuk : busuk
# ditangani : tangan
# kerja : kerja
# tidur : tidur
# melulu : melulu
# bego : bego
# untung : untung
# ari : ari
# galon : galon
# yekan : yekan
# ngajak : ngajak
# gelud : gelud
# ehh : ehh
# jdi : jdi
# mencoba : coba
# mode : mode
# kembalikan : kembali
# farhang : farhang
# tarif : tarif
# mengacu : acu
# besaran : besar
# biaya : biaya
# pengeluaran : keluar
# berbeda : beda
# akibat : akibat
# berbedanya : beda
# tingkat : tingkat
# kesulitan : sulit
# komponen : komponen
# dibutuhkan : butuh
# menggelar : gelar
# ping : ping
# gaada : gaada
# leletnya : lelet
# mengambil : ambil
# sikap : sikap
# seruan : seru
# salahkan : salah
# keresahan : resah
# diroasting : diroasting
# segitu : segitu
# begimana : begimana
# daritadi : daritadi
# trs : trs
# gimanaa : gimanaa
# molatv : molatv
# penipu : tipu
# aplikasinya : aplikasi
# lemotnya : lot
# lhoo : lhoo
# myrepublic : myrepublic
# giliran : gilir
# switch : switch
# perumahan : rumah
# tot : tot
# lucu : lucu
# maen : maen
# genshin : genshin
# kedisconnect : kedisconnect
# jahhh : jahhh
# sebutkan : sebut
# persatu : satu
# hati : hati
# dpt : dpt
# membaca : baca
# rakyat : rakyat
# penyedia : sedia
# promo : promo
# diatas : atas
# std : std
# pelayanan : layan
# customer : customer
# belly : belly
# website : website
# myorbit : myorbit
# muter : muter
# memproses : proses
# kelar : kelar
# down : down
# bangett : bangett
# lemah : lemah
# handphone : handphone
# memindahkan : pindah
# janjian : janji
# yak : yak
# njaukkk : njaukkk
# tulung : tulung
# rek : rek
# iki : iki
# aswwwwwwww : aswwwwwwww
# dika : dika
# senang : senang
# membantu : bantu
# sungkan : sungkan
# have : have
# nice : nice
# day : day
# iyo : iyo
# makasi : makas
# jaringnya : jaring
# duda : duda
# berulah : ulah
# avo : avo
# fast : fast
# trusted : trusted
# ijo : ijo
# dongg : dongg
# mari : mari
# hangatkan : hangat
# tubuhnya : tubuh
# score : score
# brp : brp
# infonya : info
# ardo : ardo
# trik : trik
# merusak : rusak
# pln : pln
# penderitaan : derita
# hidup : hidup
# hiburan : hibur
# ikutan : ikut
# kek : kek
# taik : taik
# ngapa : ngapa
# sii : sii
# ngilang : ngilang
# pdahal : pdahal
# rumah : rumah
# plosok : plosok
# matlis : matlis
# ujaann : ujaann
# hasil : hasil
# result : result
# hongkong : hongkong
# shio : shio
# tikus : tikus
# beting : beting
# togel : togel
# perak : perak
# terima : terima
# pendaftaran : daftar
# kktoto : kktoto
# daftar : daftar
# infrastruktur : infrastruktur
# hadeh : hadeh
# icha : icha
# alias : alias
# berpikir : pikir
# spt : spt
# hangus : hangus
# pulsanya : pulsa
# asumsi : asumsi
# uang : uang
# ditukar : tukar
# setara : tara
# nilainya : nilai
# barter : barter
# dibeli : beli
# hak : hak
# milik : milik
# turunkan : turun
# keputusan : putus
# menaikan : naik
# situasi : situasi
# pandemi : pandemi
# memberatkan : berat
# karyawan : karyawan
# bergaji : gaji
# pasan : pas
# lancar : lancar
# cuman : cuman
# gregetan : gregetan
# kirain : kirain
# quota : quota
# krisma : krisma
# kris : kris
# jay : jay
# ikhwan : ikhwan
# pasca : pasca
# menggantikan : ganti
# kartuhalo : kartuhalo
# bara : bara
# laen : laen
# unable : unable
# load : load
# gmana : gmana
# mending : mending
# tan : tan
# tim : tim
# rp : rp
# transfer : transfer
# blm : blm
# kmaren : kmaren
# jakarta : jakarta
# selatan : selatan
# orbit : orbit
# darman : darman
# stuju : stuju
# dyan : dyan
# adit : adit
# maafin : maafin
# cobain : cobain
# pindahin : pindahin
# alamat : alamat
# psssst : psssst
# baguus : baguus
# euy : euy
# tjakeeeep : tjakeeeep
# bismillah : bismillah
# turun : turun
# ape : ape
# dajjal : dajjal
# uda : uda
# princess : princess
# maksudnya : maksud
# include : include
# maxtrem : maxtrem
# milih : milih
# viu : viu
# vision : vision
# prime : prime
# sebulan : bulan
# lelet : lelet
# loading : loading
# gmn : gmn
# ceritanya : cerita
# tnya : tnya
# paska : paska
# prabayar : prabayar
# kebiasaan : biasa
# elahhh : elahhh
# njir : njir
# chika : chika
# dibuka : buka
# caranyaa : caranyaa
# help : help
# menambah : tambah
# anggota : anggota
# keluarga : keluarga
# plissss : plissss
# disearching : disearching
# bangsat : bangsat
# dengernya : dengernya
# kemendikbud : kemendikbud
# mei : mei
# bgmn : bgmn
# mendaftarkannya : daftar
# ceritain : ceritain
# pertanyaannya : tanya
# nge : nge
# pertandingan : tanding
# perempat : empat
# final : final
# jagoan : jago
# reply : reply
# tonton : tonton
# jagoanmu : jago
# berlaga : laga
# merah : merah
# teruss : teruss
# kaya : kaya
# kasih : kasih
# berpartisipasi : partisipasi
# mention : mention
# aris : aris
# didaftarkan : daftar
# umpama : umpama
# org : org
# ditambah : tambah
# kya : kya
# mahalnya : mahal
# doank : doank
# bangke : bangke
# ngelag : ngelag
# tolol : tolol
# julia : julia
# taufik : taufik
# ditrade : ditrade
# tinder : tinder
# monetary : monetary
# dugunakan : dugunakan
# panggilan : panggil
# kekmana : kekmana
# gajelass : gajelass
# perdana : perdana
# loop : loop
# internetnya : internetnya
# jalan : jalan
# spek : spek
# mediatek : mediatek
# promosikan : promosi
# bapuk : bapuk
# oalah : oalah
# apk : apk
# dwld : dwld
# modem : modem
# rumahan : rumah
# googling : googling
# bro : bro
# trus : trus
# mantapp : mantapp
# fah : fah
# rugi : rugi
# max : max
# kolaborasinya : kolaborasi
# punyanya : punya
# need : need
# order : order
# perpanjang : panjang
# trf : trf
# chakrisn : chakrisn
# terkonsumsi : konsumsi
# multimedia : multimedia
# winking : winking
# face : face
# oooo : oooo
# hahahaha : hahahaha
# ngeh : ngeh
# byasalah : byasalah
# germany : germany
# ngga : ngga
# paham : paham
# kemakan : makan
# hmm : hmm
# bales : bales
# ilang : ilang
# pasang : pasang
# rusak : rusak
# sayang : sayang
# dibales : dibales
# nia : nia
# lulu : lulu
# bumn : bumn
# amad : amad
# adela : adela
# dengarnya : dengar
# setia : setia
# trade : trade
# ngalahin : ngalahin
# komisaris : komisaris
# skip : skip
# ciap : ciap
# maacih : maacih
# plat : plat
# rb : rb
# beliin : beliin
# garang : garang
# kecepatan : cepat
# moncer : moncer
# pemancarnya : pancar
# nebeng : nebeng
# dibanding : banding
# suka : suka
# duf : duf
# besok : besok
# ndak : ndak
# absen : absen
# kantor : kantor
# asli : asli
# hah : hah
# gambarnya : gambar
# samsek : samsek
# optimalisasi : optimalisasi
# diupayakan : upaya
# kesetiannya : seti
# jul : jul
# venn : venn
# upgrade : upgrade
# samak : samak
# gas : gas
# isiin : isiin
# raden : raden
# octa : octa
# dibikin : bikin
# mytelkosel : mytelkosel
# clear : clear
# cache : cache
# force : force
# stop : stop
# lengkap : lengkap
# ghia : ghia
# pandawa : pandawa
# benerin : benerin
# mboh : mboh
# maksimalnya : maksimal
# pengirimnya : kirim
# indikasi : indikasi
# penipuan : tipu
# loe : loe
# akunku : akun
# adis : adis
# ifnu : ifnu
# keluhanku : keluh
# mbok : mbok
# ekstra : ekstra
# ngirimin : ngirimin
# gratis : gratis
# ngab : ngab
# betulin : betulin
# sengaja : sengaja
# apgret : apgret
# mai : mai
# setelahnya : telah
# niat : niat
# ngelayanin : ngelayanin
# ditahun : tahun
# inget : inget
# virus : virus
# veronica : veronica
# mengidap : idap
# pengguna : guna
# kehabisan : habis
# vito : vito
# dialami : alami
# optimal : optimal
# cape : cape
# nie : nie
# bisanya : bisa
# rebeca : rebeca
# dibedain : dibedain
# dimahalin : dimahalin
# shopee : shopee
# bener : bener
# mytsel : mytsel
# gbs : gbs
# ardin : ardin
# robby : robby
# seiring : iring
# peluncuran : luncur
# identitas : identitas
# dilebur : lebur
# huhuu : huhuu
# ituu : ituu
# ajaa : ajaa
# maayy : maayy
# inii : ini
# nnaa : nnaa
# belom : bom
# kaget : kaget
# gituu : gituu
# syarif : syarif
# rahandy : rahandy
# napa : napa
# galau : galau
# diaksesnya : akses
# putus : putus
# cinta : cinta
# eror : eror
# kayak : kayak
# cwek : cwek
# hpus : hpus
# iklann : iklann
# lohhhhhh : lohhhhhh
# reddevil : reddevil
# peluang : peluang
# sejarah : sejarah
# contohnya : contoh
# bersejarah : sejarah
# ngelewatin : ngelewatin
# bangunannya : bangun
# muncul : muncul
# kaca : kaca
# mobil : mobil
# naiki : naik
# sbl : sbl
# ngomong : ngomong
# diupdate : diupdate
# dodol : dodol
# subscribe : subscribe
# kesini : kesini
# kontol : kontol
# masak : masak
# kalah : kalah
# simple : simple
# nyesatin : nyesatin
# gampang : gampang
# jalanin : jalanin
# namanya : nama
# hrs : hrs
# blom : blom
# akal : akal
# profesional : profesional
# alus : alus
# keneh : keneh
# esia : esia
# bnerin : bnerin
# dlu : dlu
# mytelkomselnya : mytelkomselnya
# penah : penah
# alhamdulillah : alhamdulillah
# lmyn : lmyn
# drakor : drakor
# hahaha : hahaha
# juara : juara
# buruknya : buruk
# mwreka : mwreka
# mah : mah
# template : template
# pengen : ken
# kasar : kasar
# ane : ane
# perbaiki : baik
# publish : publish
# store : store
# seng : seng
# pakek : pakek
# njaok : njaok
# bukak : bukak
# gopek : gopek
# kaet : kaet
# loadinh : loadinh
# isok : isok
# malem : malem
# sinyalnya : sinyal
# dikit : dikit
# sibap : sibap
# updet : updet
# mao : mao
# nggk : nggk
# sejam : jam
# gagal : gagal
# pulsaa : pulsaa
# pls : pls
# drakoran : drakoran
# brengsek : brengsek
# tag : tag
# abde : abde
# slank : slank
# wisnutama : wisnutama
# bapuukkk : bapuukkk
# bapukkk : bapukkk
# heyyyy : heyyyy
# ndhs : ndhs
# izin : izin
# tampilannya : tampil
# hooh : hooh
# nihh : nihh
# apapun : apa
# gila : gila
# heeeii : heeeii
# malu : malu
# atuh : atuh
# iraha : iraha
# asia : asia
# geus : geus
# target : target
# teh : teh
# luhur : luhur
# servicenya : servicenya
# pindah : pindah
# sisa : sisa
# kebutuhan : butuh
# membeli : beli
# operasikan : operasi
# telfon : telfon
# keganggu : ganggu
# aing : aing
# konter : konter
# tutup : tutup
# segini : gin
# marah : marah
# kacau : kacau
# tololkomsel : tololkomsel
# ona : ona
# sekarat : sekarat
# astagaaa : astagaaa
# punten : punten
# diakses : akses
# woi : woi
# jualan : jual
# tulisannya : tulis
# menampilkan : tampil
# bawang : bawang
# ditumis : tum
# ahhaha : ahhaha
# sihh : sihh
# dom : dom
# solo : solo
# huhue : huhue
# aga : aga
# bye : bye
# gee : gee
# aplikasimu : aplikasi
# cepetan : cepetan
# paimin : paimin
# paketanku : paket
# arep : arep
# entekk : entekk
# applikasi : applikasi
# signal : signal
# reload : reload
# hiks : hiks
# minnn : minnn
# biaa : biaa
# barusan : barusan
# tokopedia : tokopedia
# coverage : coverage
# wanaraja : wanaraja
# garut : garut
# padat : padat
# penduduk : duduk
# hutan : hutan
# pantes : pantes
# demo : demo
# omg : omg
# trnyata : trnyata
# bolak : bolak
# hapeku : hapeku
# nomernya : nomernya
# aneh : aneh
# shoppepay : shoppepay
# woy : woy
# bacot : bacot
# muat : muat
# please : please
# rating : rating
# rese : rese
# menghubungi : hubung
# digital : digital
# merespon : merespon
# pemberitahuan : pemberitahuan
# wuii : wuii
# gapake : gapake
# kesal : kesal
# loding : loding
# kunaon : kunaon
# ieu : ieu
# butut : butut
# kieu : kieu
# telkomslank : telkomslank
# jigana : jigana
# lembur : lembur
# developer : developer
# mangat : mangat
# fine : fine
# dirilis : rilis
# penuh : penuh
# bug : bug
# teroosss : teroosss
# appnya : appnya
# che : che
# hadeuhhh : hadeuhhh
# dahlah : dah
# gaguna : gaguna
# tok : tok
# statusnya : status
# cant : cant
# loaded : loaded
# kynya : kynya
# ngerasaiin : ngerasaiin
# tuuuuuu : tuuuuuu
# kampredddddd : kampredddddd
# kenapeeee : kenapeeee
# sibuk : sibuk
# time : time
# wakru : wakru
# risk : risk
# management : management
# reminder : reminder
# install : install
# minggu : minggu
# jefri : jefri
# kasdarianysah : kasdarianysah
# kebumen : kebumen
# jawa : jawa
# ganguan : ganguan
# kenapaa : kenapaa
# yaampun : yaampun
# gbsa : gbsa
# taunya : tau
# bukann : bukann
# tumben : tumben
# hadeeh : hadeeh
# lambang : lambang
# perusahaan : usaha
# hehehe : hehehe
# troubleshoot : troubleshoot
# software : software
# ngadat : ngadat
# tangerang : tangerang
# lenyappp : lenyappp
# dahh : dahh
# astaghfirullahh : astaghfirullahh
# dri : dri
# ulasan : ulas
# diplay : diplay
# inih : inih
# kuliah : kuliah
# pemerintah : perintah
# kadang : kadang
# serang : serang
# bekasi : bekas
# masi : mas
# kouta : kouta
# idenya : ide
# keliatan : liat
# ngerasa : ngerasa
# hedon : hedon
# bobrok : bobrok
# heran : heran
# banyakmba : banyakmba
# ngalamin : ngalamin
# sulit : sulit
# teros : ros
# permisi : permisi
# apknya : apknya
# jbjb : jbjb
# smpe : smpe
# apus : apus
# dijabanin : dijabanin
# wifinya : wifinya
# mendukung : dukung
# mama : mama
# kinerjanya : kerja
# mantep : mantep
# ehehe : ehehe
# baleg : baleg
# mun : mun
# gulung : gulung
# tikar : tikar
# puguh : puguh
# hanas : hanas
# mahalna : mahalna
# hayoh : hayoh
# isya : isya
# ngapasi : ngapasi
# cacat : cacat
# payah : payah
# diandalkan : andal
# tmbahin : tmbahin
# ccd : ccd
# soak : soak
# perasaan : asa
# yutuban : yutuban
# sopi : sopi
# instagram : instagram
# erfror : erfror
# follow : follow
# maintenance : maintenance
# apalah : apa
# tinggal : tinggal
# siput : siput
# lolaaaa : lolaaaa
# gung : gung
# super : super
# pegimana : pegimana
# memuat : muat
# ulang : ulang
# whats : whats
# wrong : wrong
# bre : bre
# jaleh : jaleh
# mancaliak : mancaliak
# kanai : kana
# bantai : bantai
# ngapain : ngapain
# balabat : balabat
# hiya : hiya
# saba : saba
# sepabanyak : sepabanyak
# lai : lai
# design : design
# putih : putih
# button : button
# retry : retry
# call : call
# center : center
# rupiah : rupiah
# rampok : rampok
# miiiinn : miiiinn
# baa : baa
# bola : bola
# beko : beko
# goh : goh
# sayuik : sayuik
# pandu : pandu
# gabener : gabener
# kenapasih : kenapasih
# berjam : jam
# bsa : bsa
# terkoneksi : koneksi
# ngecek : ngecek
# bat : bat
# kittinggi : kittinggi
# sdg : sdg
# miiinn : miiinn
# laptop : laptop
# berak : berak
# lmao : lmao
# budget : budget
# ngeberantas : ngeberantas
# spam : spam
# tingkatkan : tingkat
# drpd : drpd
# rebranding : rebranding
# pisan : pis
# hallooooo : hallooooo
# oit : oit
# may : may
# dont : dont
# blame : blame
# very : very
# good : good
# enggggg : enggggg
# nganu : nganu
# her : her
# kanca : kanca
# sma : sma
# situ : situ
# tenin : tenin
# suk : suk
# kancani : kancani
# yahh : yahh
# bund : bund
# signalnya : signalnya
# menteri : menteri
# badan : badan
# usaha : usaha
# negara : negara
# mewanti : mewanti
# jajaran : jajar
# direksi : direksi
# sel : sel
# gajadi : gajadi
# neh : neh
# looooo : looooo
# aplikasih : aplikasih
# restar : restar
# ttp : ttp
# kena : kena
# sedot : sedot
# pdhal : pdhal
# ngktifkn : ngktifkn
# internt : internt
# untk : untk
# kdepn : kdepn
# pdhl : pdhl
# kmren : kmren
# msih : msih
# tinggl : tinggl
# kode : kode
# transaksi : transaksi
# trnyta : trnyta
# sumph : sumph
# fikir : fikir
# cus : cus
# nobar : nobar
# teteh : teteh
# jie : jie
# paan : paan
# kang : kang
# prioritas : prioritas
# pesawat : pesawat
# haji : haji
# giga : giga
# allahuakbar : allahuakbar
# kelonnya : kelon
# medsos : medsos
# rekomendasi : rekomendasi
# series : series
# amazone : amazone
# close : close
# androidnya : androidnya
# bun : bun
# kpn : kpn
# malmm : malmm
# portugal : portugal
# lolos : lolos
# tenang : tenang
# nangis : nang
# dear : dear
# trouble : trouble
# delive : delive
# edy : edy
# latest : latest
# version : version
# yutub : yutub
# jaksel : jaksel
# cikoko : cikoko
# skrng : skrng
# fix : fix
# bukanya : buka
# suruh : suruh
# nunggu : nunggu
# kapaaan : kapaaan
# yakk : yakk
# oke : oke
# parahhhh : parahhhh
# ayolah : ayo
# sblm : sblm
# sebenernya : sebenernya
# mosok : mosok
# kelon : kelon
# tetring : tetring
# fess : fess
# diluar : luar
# wifii : wifii
# makasii : makasii
# jangkung : jangkung
# masyaallah : masyaallah
# transport : transport
# puskesmas : puskesmas
# harapannya : harap
# pastinya : pasti
# hambatan : hambat
# england : england
# sweden : sweden
# kondisi : kondisi
# dianjurkan : anjur
# memakai : pakai
# apd : apd
# nongkrong : nongkrong
# gentengnya : genteng
# kainmana : kainmana
# assalamualaikum : assalamualaikum
# geuning : geuning
# wae : wae
# urang : urang
# enggs : enggs
# meuli : meuli
# goreng : goreng
# jelaskeun : jelaskeun
# nyusahin : nyusahin
# idup : idup
# stelah : stelah
# mlh : mlh
# giniii : giniii
# knapa : knapa
# bukaaa : bukaaa
# mpet : mpet
# mpetan : mpetan
# iniiii : iniiii
# iyaaaaa : iyaaaaa
# katanyaaa : katanyaaa
# keren : keren
# yakkk : yakkk
# uhh : uhh
# buset : buset
# minnnn : minnnn
# ninuninuninu : ninuninuninu
# mytselkomsel : mytselkomsel
# nama : nama
# telkontol : telkontol
# eeeh : eeeh
# mytelkom : mytelkom
# silit : silit
# kzl : kzl
# omelin : omelin
# lag : lag
# ngambek : ngambek
# megang : megang
# ukraina : ukraina
# romelu : romelu
# lukaku : luka
# man : man
# match : match
# keknya : kek
# yaallah : yaallah
# hubungannya : hubung
# level : level
# koneksi : koneksi
# infrastrukturnya : infrastruktur
# imbasnya : imbas
# ancur : ancur
# minn : minn
# hae : hae
# larang : larang
# mlayune : mlayune
# pithik : pithik
# dichat : dichat
# emgnya : emgnya
# percaya : percaya
# kualitasnya : kualitas
# menurun : turun
# iyani : iyani
# like : like
# shit : shit
# greget : greget
# blum : blum
# pajak : pajak
# arahkan : arah
# tbk : tbk
# mengusut : usut
# pelaku : laku
# layak : layak
# perlindungan : lindung
# tandatangani : tandatangani
# petisi : petisi
# auk : auk
# donggg : donggg
# minnnnn : minnnnn
# netflix : netflix
# spotify : spotify
# murahan : murah
# firda : firda
# sejaman : jam
# susaah : susaah
# yee : yee
# heii : heii
# petersaysdenim : petersaysdenim
# contorl : contorl
# union : union
# ajaaa : ajaaa
# prosesnya : proses
# jagoin : jagoin
# terpilih : pilih
# jazakallah : jazakallah
# tlp : tlp
# blangsak : blangsak
# pbat : pbat
# hujan : hujan
# deras : deras
# lampu : lampu
# panas : panas
# ngadatan : ngadatan
# yoon : yoon
# pulsaaa : pulsaaa
# keburu : keburu
# liat : liat
# pemeliharaan : pelihara
# diarahkan : arah
# berentiin : berentiin
# hatus : hatus
# aktifin : aktifin
# harian : hari
# full : full
# aww : aww
# harganya : harga
# terjangkau : jangkau
# vocher : vocher
# steam : steam
# mb : mb
# edun : edun
# dibawah : bawah
# jy : jy
# beneran : beneran
# sobat : sobat
# stefanus : stefanus
# aplikas : aplikas
# slowrespon : slowrespon
# banhet : banhet
# kepo : kepo
# bangga : bangga
# menggandeng : gandeng
# partner : partner
# kolaborasi : kolaborasi
# memudahkan : mudah
# mengakses : akses
# welcome : welcome
# era : era
# sob : sob
# ajaloh : ajaloh
# hebat : hebat
# game : game
# job : job
# and : and
# byu : byu
# server : server
# mastiinnya : mastiinnya
# nunggunya : nunggunya
# yaowoh : yaowoh
# german : german
# juaranya : juara
# hbatannya : hbatannya
# cemana : cemana
# intenet : intenet
# telat : telat
# susahnya : susah
# ampun : ampun
# gustopher : gustopher
# skor : skor
# vale : vale
# lamaaaaa : lamaaaaa
# kluwer : kluwer
# aamiin : aamiin
# guys : guys
# rbu : rbu
# saksikan : saksi
# siapin : siapin
# begadang : begadang
# wfh : wfh
# penjelasan : jelas
# nyaa : nyaa
# kepake : kepake
# penjelasannya : jelas
# tebak : tebak
# shot : shot
# komen : komen
# giveaway : giveaway
# fitri : fitri
# loey : loey
# tergantung : gantung
# ade : ade
# paketannya : paket
# nada : nada
# tut : tut
# terpakai : pakai
# nerima : nerima
# hibahan : hibah
# kas : kas
# gengs : gengs
# hpku : hpku
# disusahin : disusahin
# riweh : riweh
# ngerampok : ngerampok
# sari : sari
# ketidaknyamanan : ketidaknyamanan
# jendela : jendela
# itung : itung
# cari : cari
# udara : udara
# segar : segar
# genteng : genteng
# taek : taek
# sangar : sangar
# sing : sing
# ngechat : ngechat
# gur : gur
# operator : operator
# euforia : euforia
# seru : seru
# eksklusif : eksklusif
# bareng : bareng
# widianto : widianto
# total : total
# mekanismenya : mekanisme
# thread : thread
# kosan : kosan
# anget : anget
# angetan : angetan
# doi : doi
# apaansih : apaansih
# lte : lte
# ngak : ngak
# sekolah : sekolah
# cod : cod
# depok : depok
# bentuk : bentuk
# pasukan : pasu
# exo : exo
# paansi : paansi
# nyesel : nyesel
# eur : eur
# kece : kece
# prediksi : prediksi
# kids : kids
# wkwkkw : wkwkkw
# hyunjin : hyunjin
# hyunjindosat : hyunjindosat
# taken : taken
# serius : serius
# based : based
# baca : baca
# usn : usn
# biru : biru
# sigit : sigit
# cem : cem
# ngene : ngene
# toooook : toooook
# luwarangg : luwarangg
# pol : pol
# dayana : dayana
# kayaknya : kayak
# dendam : dendam
# nisa : nisa
# payment : payment
# bakotan : bakotan
# eaaa : eaaa
# angkatan : angkat
# jadoel : jadoel
# menampar : tampar
# eka : eka
# sabrina : sabrina
# melaporkan : lapor
# korban : korban
# tsutejo : tsutejo
# tenz : tenz
# jago : jago
# hei : hei
# belik : belik
# tolonglah : tolong
# kenceng : kenceng
# perbaikin : perbaikin
# warga : warga
# aceh : aceh
# utara : utara
# tuntut : tuntut
# suwe : suwe
# obong : obong
# kui : kui
# grapari : grapari
# baek : baek
# beralih : alih
# bilangnya : bilang
# setahun : tahun
# change : change
# review : review
# disepelekan : sepele
# entar : entar
# entarin : entarin
# permintaan : minta
# baiknya : baik
# semarang : semarang
# ria : ria
# pulau : pulau
# jaya : jaya
# keisi : isi
# telo : telo
# ngesearch : ngesearch
# hhhh : hhhh
# doyle : doyle
# wendi : wendi
# prsdn : prsdn
# dikritik : kritik
# tanggapannya : tanggap
# bar : bar
# bete : bete
# seharian : hari
# engga : engga
# connection : connection
# ngaruh : ngaruh
# sabarin : sabarin
# lur : lur
# pramono : pramono
# yudhi : yudhi
# melapor : lapor
# mengunjungi : unjung
# surat : surat
# rumit : rumit
# diluangkan : luang
# taruhan : taruh
# dosa : dosa
# tar : tar
# repnya : repnya
# janlup : janlup
# hestek : hestek
# nontonnya : nontonnya
# gais : gais
# pilih : pilih
# rampis : rampis
# neng : neng
# mranggen : mranggen
# rung : rung
# ono : ono
# bentar : bentar
# bedanya : beda
# jual : jual
# under : under
# req : req
# qris : qris
# wtt : wtt
# mingguan : minggu
# twt : twt
# gmna : gmna
# sehh : sehh
# pancet : pancet
# diupdateeeeee : diupdateeeeee
# haloooooo : haloooooo
# bisaa : bisaa
# heraaan : heraaan
# rada : rada
# berat : berat
# persiapan : siap
# menentukan : tentu
# prestasi : prestasi
# donk : donk
# nyalain : nyalain
# zsa : zsa
# persis : persis
# bgitu : bgitu
# kejadiannya : jadi
# tower : tower
# geregetan : gereget
# pesen : sen
# pcs : pcs
# dikirim : kirim
# pack : pack
# dibalikin : dibalikin
# penjualnya : jual
# tampilan : tampil
# batu : batu
# support : support
# mengatasnamakan : mengatasnamakan
# terahir : terahir
# centang : centang
# tanggapan : tanggap
# menginformasikan : informasi
# otp : otp
# memblokir : blokir
# lakukan : laku
# menyasar : sasar
# lucky : lucky
# mas : mas
# ayok : ayok
# dmku : dmku
# obat : obat
# pura : pura
# ama : ama
# antrian : antri
# pemakaian : pakai
# sehari : hari
# internetan : internetan
# buffer : buffer
# rianti : rianti
# iqbal : iqbal
# bnyk : bnyk
# dibanggakan : bangga
# sok : sok
# sokan : sok
# fuck : fuck
# you : you
# zaki : zaki
# samaaaaann : samaaaaann
# keju : keju
# sampah : sampah
# web : web
# uaah : uaah
# nihil : nihil
# samsung : samsung
# note : note
# ultra : ultra
# toyota : toyota
# rush : rush
# honda : honda
# jazz : jazz
# adv : adv
# beat : beat
# yamaha : yamaha
# nmax : nmax
# cbr : cbr
# tuker : tuker
# undi : undi
# hepi : hepi
# moci : moci
# wkwkwjw : wkwkwjw
# woh : woh
# top : top
# wish : wish
# can : can
# actually : actually
# bring : bring
# otherwise : otherwise
# with : with
# wira : wira
# ngapaaa : ngapaaa
# topang : topang
# kinerja : kerja
# kuartal : kuartal
# diana : ana
# maunya : mau
# halohhh : halohhh
# faisal : faisal
# bantuin : bantuin
# putra : putra
# reksa : reksa
# muser : muser
# muluk : muluk
# prastyo : prastyo
# kesedot : sedot
# andree : andree
# matur : matur
# suwon : suwon
# jga : jga
# masihbada : masihbada
# qori : qori
# spamnya : spamnya
# ditelpon : telpon
# diangkat : angkat
# get : get
# engkau : engkau
# internetmu : internetmu
# lombok : lombok
# lockdown : lockdown
# nyuruh : nyuruh
# complain : complain
# bernabeu : bernabeu
# kitiran : kitir
# hafidz : hafidz
# menunjukan : tunjuk
# bukti : bukti
# dimiliki : milik
# kerugian : rugi
# materi : materi
# disarankan : saran
# polisi : polisi
# cyber : cyber
# crime : crime
# terdekat : dekat
# ketentuan : tentu
# membawa : bawa
# ktp : ktp
# memiliki : milik
# suket : suket
# dinas : dinas
# kependudukan : duduk
# pencatatan : catat
# sipil : sipil
# wajib : wajib
# melampirkan : lampir
# wakilin : wakilin
# noor : noor
# prihatin : prihatin
# alami : alami
# oknum : oknum
# messenger : messenger
# blokir : blokir
# adem : adem
# balas : balas
# keterlambatan : lambat
# membalas : balas
# logout : logout
# antisipasi : antisipasi
# willy : willy
# loren : loren
# micheil : micheil
# pilihan : pilih
# ikuti : ikut
# panduan : pandu
# menit : menit
# dianggurin : dianggurin
# hey : hey
# yudha : yudha
# jilly : jilly
# mianhe : mianhe
# iuris : iur
# ayu : ayu
# pengecekan : kece
# layanannya : layan
# tselnya : tselnya
# berdoa : doa
# verif : verif
# droop : droop
# gapernah : gapernah
# koutanya : koutanya
# notif : notif
# menyeramkan : seram
# orsil : orsil
# kritis : kritis
# ngefek : ngefek
# geri : geri
# diiih : diiih
# ngecheck : ngecheck
# bgni : bgni
# sya : sya
# layarnya : layar
# sekalinya : sekali
# tulisan : tulis
# diselesaikan : selesai
# kau : kau
# downgrade : downgrade
# cherey : cherey
# waeyo : waeyo
# dama : dama
# ngeload : ngeload
# kebuka : buka
# detailnya : detail
# dhyas : dhyas
# ajggg : ajggg
# pedawat : dawat
# berkali : kali
# whyyyy : whyyyy
# trias : trias
# limit : limit
# lahir : lahir
# yes : yes
# ank : ank
# ngetes : ngetes
# kecepatannya : cepat
# termakasih : termakasih
# silahkan : silah
# matikan : mati
# nyalakan : nyala
# leci : leci
# rate : rate
# turn : turn
# connct : connct
# ngebut : ngebut
# bukit : bukit
# utamanya : utama
# ganggu : ganggu
# aktivitas : aktivitas
# jiwa : jiwa
# kagak : kagak
# nyantol : nyantol
# oreedo : oreedo
# masalhnya : masalhnya
# cokelat : cokelat
# bali : bal
# nglawak : nglawak
# bimo : bimo
# diaktivasi : diaktivasi
# nub : nub
# tenan : tenan
# boys : boys
# adi : adi
# nuker : nuker
# poin : poin
# abs : abs
# told : told
# use : use
# eomma : eomma
# party : party
# stiap : stiap
# qouta : qouta
# irit : irit
# kabhi : kabhi
# khushi : khushi
# kabhie : kabhie
# gham : gham
# waras : waras
# edan : edan
# ian : ian
# ceria : ceria
# diaktifkan : aktif
# penawaran : tawar
# tersedia : sedia
# dial : dial
# munculnya : muncul
# fal : fal
# arif : arif
# kerjanya : kerja
# kehambat : hambat
# pendidikan : didik
# smoga : smoga
# jaringanmu : jaring
# nak : nak
# buta : buta
# logika : logika
# makan : makan
# laper : laper
# laah : laah
# paradisum : paradisum
# random : random
# mbaknya : mbak
# diskon : diskon
# ngirim : ngirim
# file : file
# menggangu : menggangu
# pekerjaan : kerja
# mencapai : capai
# batas : batas
# tambahan : tambah
# saranin : saranin
# done : done
# berjalan : jalan
# cintahh : cintahh
# perbarui : baru
# paketnya : paket
# berdasarkan : dasar
# umur : umur
# sarankan : saran
# tata : tata
# dik : dik
# raline : raline
# alfauzi : alfauzi
# jenis : jenis
# ditanyain : ditanyain
# ath : ath
# saktiku : sakti
# sebulannya : bulan
# halooo : halooo
# flash : flash
# tenggang : tenggang
# diendorse : diendorse
# gratisspun : gratisspun
# rela : rela
# optimalkan : optimal
# berbasis : bas
# cpaas : cpaas
# ngage : ngage
# kepuasan : puas
# meningkat : tingkat
# peka : peka
# tika : tika
# riska : riska
# kedepan : depan
# sukabumi : sukabumi
# ngaku : ngaku
# kreatif : kreatif
# buktiin : buktiin
# tunjukkin : tunjukkin
# jersey : jersey
# competition : competition
# never : never
# too : too
# lavish : lavish
# hadiah : hadiah
# menangin : menangin
# join : join
# juli : juli
# kayanya : kaya
# sampean : sampean
# endorse : endorse
# gbisa : gbisa
# roni : roni
# balesin : balesin
# mba : mba
# olivia : olivia
# maksimal : maksimal
# menutup : tutup
# benny : benny
# sinyalny : sinyalny
# multimedianya : multimedia
# apasi : apas
# ngeproses : ngeproses
# niatnya : niat
# merek : merek
# kecantol : kecantol
# telponnya : telpon
# asik : asik
# dipromoin : dipromoin
# nyampe : nyampe
# zona : zona
# gembel : gembel
# lgsg : lgsg
# bundir : bundir
# diujung : ujung
# gedung : gedung
# ngibarin : ngibarin
# bendera : bendera
# real : real
# question : question
# andik : andik
# deskripsi : deskripsi
# blankspot : blankspot
# cheque : cheque
# gita : gita
# token : token
# deskripsinya : deskripsi
# facebook : facebook
# bandung : bandung
# lowongan : lowong
# csr : csr
# wisma : wisma
# alia : alia
# tasya : tasya
# ulfha : ulfha
# haris : haris
# scroll : scroll
# mengirim : kirim
# pesan : pesan
# hijaudaun : hijaudaun
# sakit : sakit
# rindu : rindu
# ketik : ketik
# strlm : strlm
# kaak : kaak
# kembal : kembal
# fup : fup
# surprise : surprise
# deal : deal
# lapak : lapak
# mempresentasikan : presentasi
# indah : indah
# dll : dll
# gprs : gprs
# klaim : klaim
# voucher : voucher
# telek : telek
# koceng : koceng
# metode : metode
# vouchernya : vouchernya
# tony : tony
# ahli : ahli
# investasi : investasi
# mengembangkan : kembang
# teknologi : teknologi
# grabfood : grabfood
# salin : salin
# silkan : sil
# masukan : masuk
# add : add
# rencananya : rencana
# ilmi : ilmi
# terhubung : hubung
# omonaa : omonaa
# tkud : tkud
# diculik : culik
# tkg : tkg
# rentenir : rentenir
# towernya : towernya
# dimana : mana
# informasi : informasi
# mahfud : mahfud
# berabad : abad
# abad : abad
# sanggup : sanggup
# menstabilkan : stabil
# boy : boy
# list : list
# berakibat : akibat
# kemenag : kemenag
# dmn : dmn
# kuotanya : kuota
# loss : loss
# dol : dol
# berbisnis : bisnis
# branding : branding
# webinar : webinar
# kuncie : kuncie
# anak : anak
# bapaknyatoby : bapaknyatoby
# mantap : mantap
# presiden : presiden
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# malang : malang
# season : season
# toby : toby
# kb : kb
# mleyoy : mleyoy
# for : for
# iphone : iphone
# terduga : duga
# persalinan : salin
# jumping : jumping
# auto : auto
# gataunya : gataunya
# dibutuhin : dibutuhin
# hshhshshs : hshhshshs
# pergi : pergi
# plongsok : plongsok
# plg : plg
# kuat : kuat
# cmn : cmn
# ooredoo : ooredoo
# laut : laut
# mudah : mudah
# zulfia : zulfia
# setop : setop
# ketergantungan : gantung
# iklan : iklan
# global : global
# jokowi : jokowi
# tadex : tadex
# firstmedia : firstmedia
# hadeuh : hadeuh
# okay : okay
# ega : ega
# aizen : aizen
# bintaro : bintaro
# operasional : operasional
# juni : juni
# mall : mall
# xchange : xchange
# cbd : cbd
# sektor : sektor
# vii : vii
# lantai : lantai
# nuswantara : nuswantara
# tessa : tessa
# rai : rai
# ketidaknyamanannya : ketidaknyamanannya
# karina : karina
# padam : padam
# menengah : tengah
# petugas : tugas
# penormalan : normal
# gilang : gilang
# lantas : lantas
# manfaat : manfaat
# pertumbuhan : tumbuh
# industri : industri
# temukan : temu
# otw : otw
# registrasi : registrasi
# jakal : jakal
# ngikutin : ngikutin
# arahannya : arah
# bca : bca
# cepatt : cepatt
# thanksss : thanksss
# migrasi : migrasi
# mukanya : muka
# imut : imut
# kelakuannya : laku
# fadhilah : fadhilah
# fauzan : fauzan
# dilain : lain
# smile : smile
# iron : iron
# nonaktivasi : nonaktivasi
# class : class
# message : message
# lidya : lidya
# nonaktifkan : nonaktif
# responnya : responnya
# ajarin : ajarin
# marlena : marlena
# sumo : sumo
# junii : juni
# rewel : rewel
# terhormat : hormat
# informasinya : informasi
# gksi : gksi
# diterima : terima
# serial : serial
# milan : mil
# saldo : saldo
# nominalnya : nominal
# ditindaklanjutin : ditindaklanjutin
# solusinya : solusi
# wow : wow
# sukses : sukses
# tae : tae
# dafalih : dafalih
# terkutuklah : kutuk
# ikon : ikon
# enhypen : enhypen
# kurome : kurome
# gada : gada
# jing : jing
# pingnya : pingnya
# luas : luas
# anjr : anjr
# ketinggalan : tinggal
# bangtan : bangtan
# kampar : kampar
# suntikan : sunti
# ko : ko
# indri : indri
# diinfoin : diinfoin
# permasalahan : masalah
# bagitu : bagitu
# cepet : cepet
# efra : efra
# sgituan : sgituan
# gasalah : gasalah
# dy : dy
# rivaldy : rivaldy
# instal : instal
# suruhnya : suruh
# karis : karis
# interasinya : interasinya
# statement : statement
# pelayanannya : layan
# dipersulit : sulit
# dipermudah : mudah
# ujian : uji
# pricelist : pricelist
# murce : murce
# sialan : sial
# mieee : mieee
# menunjang : tunjang
# keberlangsungan : langsung
# melayani : layan
# pembagian : bagi
# smartphone : smartphone
# konten : konten
# diberlakukan : laku
# penyesuaian : sesuai
# hpnya : hpnya
# ujan : ujan
# shsxuospqqygzvnzka : shsxuospqqygzvnzka
# bangettt : bangettt
# kyaknya : kyaknya
# speedy : speedy
# ribetnya : ribetnya
# dipecah : pecah
# benefit : benefit
# simpel : simpel
# iswant : iswant
# sally : sally
# sabiq : sabiq
# jiyaa : jiyaa
# permasalahannya : masalah
# reset : reset
# alhasil : alhasil
# sulis : sulis
# jiyad : jiyad
# to : to
# biyel : biyel
# product : product
# semboyan : semboyan
# memotong : potong
# gaje : gaje
# berulang : ulang
# bawi : bawi
# ella : ella
# ramadhan : ramadhan
# tegal : tegal
# jumat : jumat
# sabtu : sabtu
# inbox : inbox
# buatkan : buat
# pelaporan : lapor
# kronologi : kronologi
# risone : risone
# bakul : bakul
# cah : cah
# unlimate : unlimate
# unlimatenya : unlimatenya
# lalot : lalot
# maluu : maluu
# ditelepon : telepon
# kenal : kenal
# manggil : manggil
# rencana : rencana
# ketemu : ketemu
# aamiiin : aamiiin
# boljug : boljug
# shena : shena
# khusus : khusus
# mencukupi : cukup
# nala : nala
# puk : puk
# bersangkutan : sangkut
# maya : maya
# membuka : buka
# video : video
# nyesal : nyesal
# penganan : penganan
# mentang : mentang
# pengirim : kirim
# ilangan : ilangan
# bahas : bahas
# loncat : loncat
# aktifkan : aktif
# konyol : konyol
# veronika : veronika
# line : line
# messanger : messanger
# ketikan : keti
# petunjuknya : tunjuk
# bantuan : bantu
# rachmah : rachmah
# klok : klok
# dilanjut : lanjut
# pikir : pikir
# kerjaan : kerja
# njirrrrt : njirrrrt
# balau : balau
# replies : replies
# palsunya : palsu
# permata : permata
# dme : dme
# gblk : gblk
# dihapus : hapus
# wkwkwkw : wkwkwkw
# masker : masker
# ninjaku : ninjaku
# lindungin : lindungin
# ekspresi : ekspresi
# cengar : cengar
# cengir : cengir
# scrolling : scrolling
# media : media
# sosial : sosial
# favorit : favorit
# ketengan : keteng
# pket : pket
# seminggu : minggu
# perubahan : ubah
# terkirim : kirim
# gajelasss : gajelasss
# dita : dita
# graphari : graphari
# kakakku : kakak
# bawa : bawa
# kesananya : kesana
# raven : raven
# jagajaga : jagajaga
# lindungi : lindung
# serangan : serang
# siber : siber
# incar : incar
# wilayah : wilayah
# medan : medan
# duper : duper
# tercantum : cantum
# akunnya : akun
# denny : denny
# kmrn : kmrn
# diretas : retas
# dpr : dpr
# mingkem : mingkem
# penghina : hina
# berlagak : lagak
# pahlawan : pahlawan
# wuaaaaach : wuaaaaach
# pantesan : pantesan
# hrg : hrg
# melambung : lambung
# subsidi : subsidi
# makam : makam
# telekomunikasi : telekomunikasi
# disalurkan : salur
# bergerak : gerak
# eful : eful
# upaya : upaya
# menjaga : jaga
# regulator : regulator
# peraturan : atur
# menkominfo : menkominfo
# penetapan : tetap
# jasa : jasa
# menilai : nilai
# menghadapi : hadap
# tantangan : tantang
# satunya : satu
# frekuensi : frekuensi
# ketenganmu : keteng
# huh : huh
# mahasidwa : mahasidwa
# uns : uns
# pengkar : pengkar
# magang : magang
# kampis : kamp
# merdeka : merdeka
# cekidot : cekidot
# kuncoro : kuncoro
# kejar : kejar
# trims : trims
# jep : jep
# balesan : balesan
# dmnya : dmnya
# kemudahan : mudah
# petunjuk : tunjuk
# verifikasi : verifikasi
# twitt : twitt
# patahkan : patah
# angkat : angkat
# jalur : jalur
# ikatan : ikat
# perkuliahan : kuliah
# gugur : gugur
# lulus : lulus
# ditempatkan : tempat
# terblokir : blokir
# arya : arya
# disesuaikan : sesuai
# dimasing : dimasing
# gaperlu : gaperlu
# gugatan : gugat
# des : des
# cair : cair
# baz : baz
# bebas : bebas
# teguh : teguh
# outlet : outlet
# puasa : puasa
# lebaran : lebaran
# rilis : rilis
# wudufuk : wudufuk
# tbtb : tbtb
# axisku : axisku
# slama : slama
# diktifkan : diktifkan
# zuhril : zuhril
# claim : claim
# roli : rol
# ngotak : ngotak
# patrol : patrol
# gebril : gebril
# sunghoon : sunghoon
# upload : upload
# fotonya : foto
# tanda : tanda
# silang : silang
# jugaaa : jugaaa
# anakkolong : anakkolong
# berpeci : peci
# teteek : teteek
# amlpop : amlpop
# sogokan : sogo
# bodoh : bodoh
# gembosi : gembos
# koruptor : koruptor
# iam : iam
# saraf : saraf
# gass : gass
# combat : combat
# terealisasi : realisasi
# permanentnya : permanentnya
# dimytelkomsel : dimytelkomsel
# prpanjang : prpanjang
# inovasi : inovasi
# wujud : wujud
# komitmen : komitmen
# memperluas : luas
# portofolio : portofolio
# memperkuat : kuat
# transformasi : transformasi
# segmen : segmen
# korporasi : korporasi
# dtg : dtg
# diganti : ganti
# pemotongan : potong
# pemberitahun : pemberitahun
# spell : spell
# salam : salam
# borosss : borosss
# podo : podo
# suwun : suwun
# oyi : oyi
# prosedur : prosedur
# lanjutan : lanjut
# jalankan : jalan
# pengambilan : ambil
# fisik : fisik
# dibatasi : batas
# payu : payu
# pay : pay
# used : used
# internetmax : internetmax
# konsumsi : konsumsi
# kanna : kanna
# caper : caper
# jebol : jebol
# minus : minus
# nder : nder
# faiq : faiq
# hho : hho
# pahri : pahri
# ciro : ciro
# menyambut : sambut
# yudi : yudi
# adguard : adguard
# format : format
# reg : reg
# spasi : spasi
# nik : nik
# febyriannicola : febyriannicola
# mengakibatkan : akibat
# aktifnya : aktif
# bts : bts
# sehingg : sehingg
# mencari : cari
# diruangan : ruang
# terbuka : buka
# muh : muh
# dns : dns
# over : over
# https : https
# film : film
# nikmati : nikmat
# sepuasnya : puas
# jugaa : jugaa
# kamar : kamar
# hadehhh : hadehhh
# adnan : adnan
# dariku : dari
# keatas : atas
# berhasil : hasil
# new : new
# oil : oil
# beliau : beliau
# kai : kai
# unik : unik
# relate : relate
# marshmellow : marshmellow
# tablet : tablet
# gausah : gausah
# ngadi : ngadi
# tibatiba : tibatiba
# intan : intan
# tangal : tangal
# telkomse : telkomse
# paymentnya : paymentnya
# shopepay : shopepay
# cherry : cherry
# pascabayar : pascabayar
# halounlimited : halounlimited
# aktivasinya : aktivasinya
# abdillah : abdillah
# plumber : plumber
# koneksinya : koneksi
# vidio : vidio
# semusim : musim
# pie : pie
# carane : carane
# lak : lak
# diwakilno : diwakilno
# due : due
# uduk : uduk
# dewe : dewe
# caesarida : caesarida
# guembel : guembel
# kustara : kustara
# fitrah : fitrah
# feedback : feedback
# ilsa : ilsa
# badai : badai
# tornado : tornado
# cerahh : cerahh
# sentosa : sentosa
# hormat : hormat
# mubazir : mubazir
# lagipula : lagipula
# tlpin : tlpin
# jaman : jaman
# trend : trend
# bunus : bunus
# penghargaan : harga
# gtg : gtg
# sumatera : sumatera
# batam : batam
# centre : centre
# kepri : kepri
# terminal : terminal
# soekarno : soekarno
# hatta : hatta
# cengkareng : cengkareng
# pemuda : pemuda
# surabaya : surabaya
# renon : renon
# denpasar : denpasar
# balipapan : balipapan
# pettarani : pettarani
# makassar : makassar
# roris : roris
# meliputi : liput
# alam : alam
# sutera : sutera
# bumi : bumi
# serpong : serpong
# damai : damai
# iii : iii
# pantai : pantai
# kapuk : kapuk
# kelapa : kelapa
# gading : gading
# pondok : pondok
# widya : widya
# candra : candra
# hot : hot
# spot : spot
# keitung : keitung
# tukar : tukar
# smf : smf
# koin : koin
# ngasi : ngasi
# skksksks : skksksks
# waalaikumsalam : waalaikumsalam
# sahabat : sahabat
# syariah : syariah
# menarik : tarik
# lainya : lai
# teke : teke
# saiki : saiki
# kertumu : kertumu
# siji : siji
# len : len
# tercover : tercover
# ulangan : ulang
# belajar : ajar
# keperluan : perlu
# onlinemu : onlinemu
# wkwkwkwk : wkwkwkwk
# raimu : rai
# wan : wan
# jarene : jarene
# iso : iso
# nggo : nggo
# nokk : nokk
# ttl : ttl
# pemblokiran : blokir
# dek : dek
# een : een
# ngegas : ngegas
# nanda : nanda
# gasii : gasii
# jan : jan
# perbulan : bulan
# cocok : cocok
# cadangan : cadang
# rizki : rizki
# mase : mase
# gold : gold
# kancaku : kancaku
# rak : rak
# ana : ana
# bahasa : bahasa
# pais : pais
# ruangan : ruang
# berpindah : pindah
# area : area
# listrik : listrik
# alea : alea
# menara : menara
# pemancar : pancar
# aliran : alir
# memancarkan : pancar
# terganggu : ganggu
# mengalami : alami
# gimaneeeee : gimaneeeee
# siiiii : siiiii
# rana : rana
# kuwe : kuwe
# baroto : baroto
# elia : elia
# band : band
# influncer : influncer
# ambil : ambil
# pianis : pianis
# wisnu : wisnu
# dibongkar : bongkar
# urusan : urus
# perut : perut
# ajg : ajg
# bangkrut : bangkrut
# deddy : deddy
# tanggalwaktu : tanggalwaktu
# terajaga : terajaga
# btul : btul
# skali : skali
# smakin : smakin
# burukkkk : burukkkk
# yeaaayyyyy : yeaaayyyyy
# sadar : sadar
# dimanfaatin : dimanfaatin
# whitelist : whitelist
# winner : winner
# dipenuhi : penuh
# jaringat : jaringat
# tlkm : tlkm
# begok : begok
# set : set
# rheza : rheza
# ndeso : ndeso
# dirasa : rasa
# sbeelumnya : sbeelumnya
# kakk : kakk
# def : def
# rfs : rfs
# sikat : sikat
# kirimin : kirimin
# ginian : ginian
# bertemu : temu
# jodohmu : jodoh
# badoo : badoo
# direct : direct
# memakan : makan
# tweet : tweet
# sempet : sempet
# ahkkkk : ahkkkk
# rinduu : rinduu
# offline : offline
# beginii : begini
# renkun : renkun
# lap : lap
# air : air
# matanya : mata
# eko : eko
# vaksin : vaksin
# chip : chip
# diketawain : diketawain
# menyalurkan : salur
# lasmaria : lasmaria
# virtual : virtual
# account : account
# kementerian : menteri
# informatika : informatika
# kominfo : kominfo
# axiata : axiata
# uji : uji
# laik : laik
# operasi : operasi
# ulo : ulo
# susul : susul
# mendaftarkan : daftar
# corporaite : corporaite
# reaktivasi : reaktivasi
# takut : takut
# tiket : tiket
# fanmeet : fanmeet
# bela : bela
# in : in
# kampung : kampung
# yongie : yongie
# trust : trust
# issue : issue
# jasman : jasman
# desy : desy
# cardnya : cardnya
# membayar : bayar
# tagihan : tagih
# kindly : kindly
# limo : limo
# perusahan : usah
# registrasinya : registrasi
# daftarkan : daftar
# kabur : kabur
# hiksrot : hiksrot
# ino : ino
# queen : queen
# razia : razia
# ppkm : ppkm
# keblokir : blokir
# hello : hello
# kerahasiaan : rahasia
# customernya : customernya
# aduh : aduh
# kailan : kail
# kiki : kiki
# nastiti : nastiti
# wahyudi : wahyudi
# mbak : mbak
# busuknya : busuk
# hanna : hanna
# broadband : broadband
# manapun : mana
# akwk : akwk
# sulawesi : sulawesi
# ...
# foto : foto
# twit : twit
# pop : pop
# promosi : promosi
# jugo : jugo
# sebel : sebel
# sungguh : sungguh
# penyangga : sangga
# connect : connect
# airplane : airplane
# bandwidth : bandwidth
# ariixoxo : ariixoxo
# luang : luang
# menghargai : harga
# ghosting : ghosting
# testing : testing
# derajat : derajat
# nurass : nurass
# galaxy : galaxy
# plan : plan
# favoritmu : favorit
# lionsgate : lionsgate
# ambisi : ambisi
# menghegemoni : hegemoni
# pasar : pasar
# gawai : gawai
# ditulisannya : tulis
# nelfon : nelfon
# nawarin : nawarin
# samsunh : samsunh
# mengaktifkan : aktif
# ori : ori
# berkah : berkah
# dirumah : rumah
# pulang : pulang
# pengalaman : alam
# buruk : buruk
# mereview : mereview
# kebijakan : bijak
# meresahkan : resah
# direject : direject
# maria : maria
# acara : acara
# silaturahmi : silaturahmi
# bpk : bpk
# agus : agus
# komite : komite
# audit : audit
# ngeles : ngeles
# eleanor : eleanor
# lanjutkan : lanjut
# kebangetan : banget
# cerah : cerah
# jadwal : jadwal
# bimbingan : bimbing
# onlen : onlen
# sia : sia
# pioner : pioner
# gajelas : gajelas
# dikiraan : kira
# gaji : gaji
# ucapkan : ucap
# mengirimkan : kirim
# hate : hate
# bsi : bsi
# kenapasi : napas
# bbrp : bbrp
# teregistrasi : registrasi
# donlut : donlut
# cobaa : cobaa
# monmaap : monmaap
# kesekian : sekian
# kalinya : kali
# anjengg : anjengg
# gunawan : gunawan
# keluhannya : keluh
# tangani : tangan
# teratasi : atas
# spektrum : spektrum
# tahap : tahap
# first : first
# med : med
# ghz : ghz
# imas : imas
# pulsanyaa : pulsanyaa
# biby : biby
# berubah : ubah
# ayaayawae : ayaayawae
# cibinong : cibinong
# dipagi : pagi
# semangat : semangat
# browsing : browsing
# menghambur : hambur
# badmood : badmood
# digiinin : digiinin
# moveon : moveon
# mantul : mantul
# jajal : jajal
# berminat : minat
# grup : grup
# banyakk : banyakk
# maataappp : maataappp
# emng : emng
# mint : mint
# refund : refund
# prosuk : prosuk
# nelpon : nelpon
# duit : duit
# ning : ning
# dusun : dusun
# dikulik : lik
# personal : personal
# nuntut : nuntut
# miliar : miliar
# hadir : hadir
# promonya : promonya
# vote : vote
# koq : koq
# setan : setan
# tangsel : tangsel
# mendatfar : mendatfar
# bpjs : bpjs
# penjelasanya : jasa
# arahanya : arahanya
# trusteedd : trusteedd
# dosen : dosen
# congratulation : congratulation
# yuna : yuna
# awas : awas
# ketawa : ketawa
# bayarrrr : bayarrrr
# persiapkan : siap
# dirimu : diri
# adtech : adtech
# martech : martech
# berkembang : kembang
# profitable : profitable
# sustainable : sustainable
# ngl : ngl
# looks : looks
# vagina : vagina
# its : its
# supremacy : supremacy
# hehehehe : hehehehe
# official : official
# pnya : pnya
# buy : buy
# ahh : ahh
# mesti : mesti
# dijelasin : dijelasin
# belm : belm
# spendapat : spendapat
# tejo : tejo
# tpi : tpi
# ndk : ndk
# berusaha : usaha
# tuk : tuk
# goodbye : goodbye
# siii : siii
# log : log
# gamaslaah : gamaslaah
# roy : roy
# rachmanu : rachmanu
# laporan : lapor
# sapa : sapa
# laporannya : lapor
# mafu : mafu
# tersedot : sedot
# diproses : proses
# nitip : nitip
# lite : lite
# dikenakan : kena
# tll : tll
# sipaa : sipaa
# bravas : bravas
# anz : anz
# tertagih : tagih
# walking : walking
# street : street
# kuta : kuta
# kfc : kfc
# starbucks : starbucks
# kopi : kopi
# janji : janji
# labuan : labu
# bajo : bajo
# gokil : gokil
# evita : evita
# pengennya : ken
# plusnya : plus
# nyari : nyari
# diinternet : diinternet
# penjilat : jilat
# ngigau : ngigau
# teraneh : aneh
# nguapainnnn : nguapainnnn
# ngigaunya : ngigaunya
# bni : bni
# fyi : fyi
# dataku : data
# digendam : gendam
# deaktivasi : deaktivasi
# ngurusin : ngurusin
# berkas : berkas
# covid : covid
# pos : pos
# pelabuhan : labuh
# keluarlah : keluar
# raya : raya
# deketnya : deketnya
# ketat : ketat
# dipelabuhan : labuh
# cashback : cashback
# soktau : soktau
# wartawan : wartawan
# kompos : kompos
# mifi : mifi
# tagihannya : tagih
# magfiroh : magfiroh
# dispam : dispam
# judi : judi
# pesugihan : sugih
# halal : halal
# pinjol : pinjol
# undian : undi
# berhadiah : hadiah
# gemin : gin
# koe : koe
# perhatian : perhati
# memanggil : panggil
# kabupaten : kabupaten
# pedesaan : desa
# jelasin : jelasin
# oredo : oredo
# youtuban : youtuban
# sekelas : kelas
# ngerasain : ngerasain
# didapatkan : dapat
# out : out
# uowowo : uowowo
# castol : castol
# spams : spams
# morning : morning
# nonprem : nonprem
# mandiri : mandiri
# oo : oo
# proofs : proofs
# pinned : pinned
# fastresp : fastresp
# disono : sono
# angsuran : angsur
# lunas : lunas
# nongol : nongol
# iin : iin
# quiin : quiin
# tertersedia : sedia
# ceri : ceri
# fachmi : fachmi
# terlkomsel : terlkomsel
# huawei : huawei
# mate : mate
# oppo : oppo
# reno : reno
# cpe : cpe
# vivo : vivo
# find : find
# wadu : wadu
# megavvati : megavvati
# loopkita : loopkita
# telfonan : telfonan
# penggelaran : gelar
# harijanto : harijanto
# nachtt : nachtt
# caca : caca
# gamau : gamau
# urus : urus
# gerai : gerai
# ketersedian : dian
# dapetnya : dapetnya
# gift : gift
# spay : spay
# atm : atm
# preset : preset
# lightroom : lightroom
# cairin : cairin
# paylater : paylater
# beserta : serta
# menyetujui : tuju
# wirabest : wirabest
# dihentikan : henti
# polri : polri
# masuknya : masuk
# yohana : yohana
# kirimkan : kirim
# chatan : chatan
# denganmu : dengan
# diinfokan : info
# charge : charge
# nyedot : nyedot
# paginya : pagi
# putri : putri
# basmah : basmah
# bint : bint
# saud : saud
# bin : bin
# abdulaziz : abdulaziz
# raja : raja
# saudi : saudi
# arabia : arabia
# november : november
# kpop : kpop
# savhiraiysa : savhiraiysa
# micha : micha
# gaa : gaa
# miiin : miiin
# musicmax : musicmax
# legend : legend
# fire : fire
# lapor : lapor
# grahapari : grahapari
# teroris : teroris
# digambarkan : gambar
# from : from
# rizka : rizka
# vinn : vinn
# christine : christine
# mantab : mantab
# pidato : pidato
# bush : bush
# thn : thn
# cuplikan : cuplik
# dlm : dlm
# kelompok : kelompok
# radikal : radikal
# screenshot : screenshot
# yusup : yusup
# mhn : mhn
# produknya : produk
# goblokkkk : goblokkkk
# tangkap : tangkap
# komplotan : komplot
# pencuri : curi
# baterai : baterai
# cdc : cdc
# talaud : talaud
# bajingan : bajing
# lonte : lonte
# idn : idn
# rendezvous : rendezvous
# kemdikbud : kemdikbud
# berkolaborasi : kolaborasi
# mumpung : mumpung
# mengevaluasi : evaluasi
# aspek : aspek
# disetiap : tiap
# kampus : kampus
# universitas : universitas
# tembusan : tembus
# yth : yth
# diaplikasi : aplikasi
# diturunkan : turun
# pemenang : menang
# permainan : main
# dominoqq : dominoqq
# meraih : raih
# kemenangan : menang
# jutaan : juta
# bossku : bossku
# buktikan : bukti
# pkv : pkv
# bonekaqq : bonekaqq
# register : register
# kontakk : kontakk
# wechat : wechat
# melebihi : lebih
# mambuuuu : mambuuuu
# sinyale : sinyale
# mblangsak : mblangsak
# huhhh : huhhh
# sin : sin
# maap : maap
# modal : modal
# nagaqq : nagaqq
# rollingan : rollingan
# referal : referal
# seumur : umur
# alternatif : alternatif
# nagaq : nagaq
# com : com
# noah : noah
# let : let
# inform : inform
# about : about
# questions : questions
# products : products
# services : services
# thank : thank
# lawan : lawan
# rangkum : rangkum
# kalimatnya : kalimat
# said : said
# agil : agil
# harisma : harisma
# kentel : kentel
# pisanlah : pis
# nepi : nepi
# lemotnage : lemotnage
# pengaturan : atur
# gem : gem
# intrnet : intrnet
# barang : barang
# itulo : itulo
# woooe : woooe
# berupaya : upaya
# meningkatkan : tingkat
# yippy : yippy
# murahhh : murahhh
# sksksksk : sksksksk
# jenenge : jenenge
# dirempongin : dirempongin
# tulus : tulus
# mulus : mulus
# alvinandrian : alvinandrian
# bundddd : bundddd
# aje : aje
# erlangga : erlangga
# simcard : simcard
# white : white
# perencanaan : rencana
# pembegembangannya : pembegembangannya
# jancokkkk : jancokkkk
# leleeet : leleeet
# aconk : aconk
# something : something
# ros : ros
# blacpink : blacpink
# gkkkk : gkkkk
# more : more
# information : information
# astagfirulloh : astagfirulloh
# ielham : ielham
# klen : klen
# bagusin : bagusin
# tabagsel : tabagsel
# padang : padang
# lawas : lawas
# th : th
# nek : nek
# sugeh : sugeh
# tuku : tuku
# sak : sak
# towere : towere
# pasangke : pasangke
# ngarep : ngarep
# omahku : omahku
# sisan : sis
# hamdallah : hamdallah
# berlangganannya : langgan
# package : package
# cak : cak
# mul : mul
# maha : maha
# dahsyat : dahsyat
# tahlil : tahlil
# muhammad : muhammad
# redeem : redeem
# code : code
# codenya : codenya
# molanya : mola
# waenahi : waenahi
# sie : sie
# ngeluh : ngeluh
# dis : dis
# dipakai : pakai
# ajalah : aja
# butuhnya : butuh
# ketuk : ketuk
# kay : kay
# dapatkan : dapat
# merubah : rubah
# alokasi : alokasi
# push : push
# rank : rank
# team : team
# bloon : bloon
# naudzubillah : naudzubillah
# kumat : kumat
# dimaki : maki
# maki : maki
# pelanggannya : langgan
# ihhh : ihhh
# olla : olla
# kevin : kevin
# mampir : mampir
# spicybites : spicybites
# ichwan : ichwan
# glitch : glitch
# rebu : rebu
# cuy : cuy
# acak : acak
# kriteria : kriteria
# ditentukan : tentu
# mendapatkannya : dapat
# sweet : sweet
# skema : skema
# penjelasanmu : jelas
# perlakukan : laku
# didit : didit
# plzzz : plzzz
# astaghfirullah : astaghfirullah
# nyambung : nyambung
# musik : musik
# {'': '', 'darkestdawn': 'darkestdawn', 'kak': 'kak', 'mohon': 'mohon', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'interaksi': 'interaksi', 'makasih': 'makasih', 'tere': 'tere', 'menang': 'menang', 'puluhan': 'puluh', 'ratusan': 'ratus', 'proses': 'proses', 'cepat': 'cepat', 'deposit': 'deposit', 'withdraw': 'withdraw', 'pembayaran': 'bayar', 'bank': 'bank', 'pulsa': 'pulsa', 'telkomsel': 'telkomsel', 'online': 'online', 'jam': 'jam', 'live': 'live', 'chat': 'chat', 'bonus': 'bonus', 'referral': 'referral', 'rolingan': 'rolingan', 'menyediakan': 'sedia', 'games': 'games', 'user': 'user', 'yuk': 'yuk', 'main': 'main', 'operaqq': 'operaqq', 'nmr': 'nmr', 'telepon': 'telepon', 'dihubungi': 'hubung', 'paket': 'paket', 'telpon': 'telpon', 'combo': 'combo', 'sakti': 'sakti', 'cek': 'cek', 'kah': 'kah', 'daily': 'daily', 'check': 'check', 'app': 'app', 'thanks': 'thanks', 'hancur': 'hancur', 'pendamping': 'damping', 'pendulang': 'dulang', 'suara': 'suara', 'beda': 'beda', 'komut': 'komut', 'open': 'open', 'convert': 'convert', 'all': 'all', 'rekening': 'rekening', 'ewallet': 'ewallet', 'axis': 'axis', 'isat': 'isat', 'indosat': 'indosat', 'im': 'im', 'tsel': 'tsel', 'simpati': 'simpati', 'tri': 'tri', 'three': 'three', 'premium': 'premium', 'non': 'non', 'shopeepay': 'shopeepay', 'dana': 'dana', 'linkaja': 'linkaja', 'ovo': 'ovo', 'gopay': 'gopay', 'fee': 'fee', 'start': 'start', 'prem': 'prem', 'testi': 'testi', 'udah': 'udah', 'infokan': 'info', 'data': 'data', 'via': 'via', 'dibantu': 'bantu', 'privasi': 'privasi', 'terjaga': 'jaga', 'nomor': 'nomor', 'tanggal': 'tanggal', 'kejadian': 'jadi', 'lokasi': 'lokasi', 'detail': 'detail', 'kecamatan': 'camat', 'kota': 'kota', 'berkendala': 'kendala', 'kanaya': 'kanaya', 'hai': 'hai', 'maaf': 'maaf', 'nyaman': 'nyaman', 'kendala': 'kendala', 'sinyal': 'sinyal', 'menyebabkan': 'sebab', 'akses': 'akses', 'internet': 'internet', 'lambat': 'lambat', 'stabil': 'stabil', 'kakak': 'kakak', 'coba': 'coba', 'refresh': 'refresh', 'jaringan': 'jaring', 'off': 'off', 'service': 'service', 'ready': 'ready', 'reguler': 'reguler', 'nambah': 'nambah', 'aktif': 'aktif', 'smartfren': 'smartfren', 'minat': 'minat', 'langsung': 'langsung', 'bio': 'bio', 'yaa': 'yaa', 'wts': 'wts', 'wtb': 'wtb', 'murah': 'murah', 'provider': 'provider', 'langsug': 'langsug', 'kualitas': 'kualitas', 'knpa': 'knpa', 'emosi': 'emosi', 'buang': 'buang', 'energi': 'energi', 'tolong': 'tolong', 'diperbaiki': 'baik', 'daerah': 'daerah', 'sndiri': 'sndiri', 'tautan': 'taut', 'terimakasih': 'terimakasih', 'poco': 'poco', 'pro': 'pro', 'dukung': 'dukung', 'bona': 'bona', 'penggunaan': 'guna', 'solusi': 'solusi', 'halo': 'halo', 'ditunggu': 'tunggu', 'respon': 'respon', 'rekan': 'rekan', 'mimin': 'mimin', 'noela': 'noela', 'admin': 'admin', 'plis': 'plis', 'betull': 'betull', 'enak': 'enak', 'yves': 'yves', 'infoin': 'infoin', 'tgl': 'tgl', 'tks': 'tks', 'hakim': 'hakim', 'pastikan': 'pasti', 'masuk': 'masuk', 'aplikasi': 'aplikasi', 'disney': 'disney', 'hotstar': 'hotstar', 'gara': 'gara', 'flop': 'flop', 'maketin': 'maketin', 'udh': 'udh', 'free': 'free', 'langganan': 'langgan', 'min': 'min', 'beli': 'beli', 'plus': 'plus', 'login': 'login', 'nonton': 'nonton', 'disuruh': 'suruh', 'berlangganam': 'berlangganam', 'raisa': 'raisa', 'perihal': 'perihal', 'terpotong': 'potong', 'bantu': 'bantu', 'silakan': 'sila', 'iya': 'iya', 'bagus': 'bagus', 'potongan': 'potong', 'harga': 'harga', 'hallo': 'hallo', 'selamat': 'selamat', 'pagi': 'pagi', 'ngisi': 'ngisi', 'saldonya': 'saldo', 'sampe': 'sampe', 'lupa': 'lupa', 'berkurang': 'kurang', 'sebelah': 'belah', 'kemaren': 'kemaren', 'posisi': 'posisi', 'kemarin': 'kemarin', 'sore': 'sore', 'hilang': 'hilang', 'skrg': 'skrg', 'pakai': 'pakai', 'wifi': 'wifi', 'bantuannya': 'bantu', 'dicheck': 'dicheck', 'nomornya': 'nomor', 'nanya': 'nanya', 'doang': 'doang', 'kuota': 'kuota', 'twitter': 'twitter', 'duluan': 'duluan', 'dipake': 'dipake', 'ato': 'ato', 'utama': 'utama', 'kontak': 'kontak', 'enam':  ...
# ------------------------
# Pandas Apply:   0%|          | 0/1958 [00:00<?, ?it/s]
#                                                 content  \
# 0     @_darkestdawn siap, kak. mohon berkenan menung...
# 1     mau menang sampai puluhan hingga ratusan juga?...
# 2     mau menang sampai puluhan hingga ratusan juga?...
# 3     mau menang sampai puluhan hingga ratusan juga?...
# 4     @telkomsel \n\nnmr saya tidak bisa telepon dan...
# ...                                                 ...
# 1995  butuh paket internet xl plzzz atau telkomsel d...
# 1996  telkomsel jelek banget astaghfirullah. minta d...
# 1997  @kesimayo hai, kak. maaf ya. mengenai kendala ...
# 1998  @telkomsel selamat malam, sinyal telkomsel apa...
# 1999  @telkomsel ini kuota multimedia gimana ya maks...
#
#                                          cleaning_tweet  \
# 0      darkestdawn siap kak mohon berkenan menunggu ...
# 1     mau menang sampai puluhan hingga ratusan juga ...
# 2     mau menang sampai puluhan hingga ratusan juga ...
# 3     mau menang sampai puluhan hingga ratusan juga ...
# 4     nmr saya tidak bisa telepon dan dihubungi saya...
# ...                                                 ...
# 1995  butuh paket internet plzzz atau telkomsel deh ...
# 1996  telkomsel jelek banget astaghfirullah minta di...
# 1997  hai kak maaf mengenai kendala ketidaksesuaian ...
# 1998  selamat malam sinyal telkomsel apakah lagi gan...
# 1999  ini kuota multimedia gimana maksudnya saya pak...
#
#                                              tokenisasi  \
# 0     [, darkestdawn, siap, kak, mohon, berkenan, me...
# 1     [mau, menang, sampai, puluhan, hingga, ratusan...
# 2     [mau, menang, sampai, puluhan, hingga, ratusan...
# 3     [mau, menang, sampai, puluhan, hingga, ratusan...
# 4     [nmr, saya, tidak, bisa, telepon, dan, dihubun...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, atau, telkomse...
# 1996  [telkomsel, jelek, banget, astaghfirullah, min...
# 1997  [hai, kak, maaf, mengenai, kendala, ketidakses...
# 1998  [selamat, malam, sinyal, telkomsel, apakah, la...
# 1999  [ini, kuota, multimedia, gimana, maksudnya, sa...
#
#                                                stopword  \
# 0     [, darkestdawn, kak, mohon, berkenan, menunggu...
# 1     [menang, puluhan, ratusan, proses, cepat, depo...
# 2     [menang, puluhan, ratusan, proses, cepat, depo...
# 3     [menang, puluhan, ratusan, proses, cepat, depo...
# 4     [nmr, telepon, dihubungi, paket, telpon, combo...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, telkomsel, deh...
# 1996  [telkomsel, jelek, banget, astaghfirullah, dim...
# 1997  [hai, kak, maaf, kendala, ketidaksesuaian, pen...
# 1998  [selamat, malam, sinyal, telkomsel, gangguan, ...
# 1999  [kuota, multimedia, gimana, maksudnya, pakai, ...
#
#                                                stemming
# 0     [, darkestdawn, kak, mohon, kenan, tunggu, int...
# 1     [menang, puluh, ratus, proses, cepat, deposit,...
# 2     [menang, puluh, ratus, proses, cepat, deposit,...
# 3     [menang, puluh, ratus, proses, cepat, deposit,...
# 4     [nmr, telepon, hubung, paket, telpon, combo, s...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, telkomsel, deh...
# 1996  [telkomsel, jelek, banget, astaghfirullah, mak...
# 1997  [hai, kak, maaf, kendala, ketidaksesuaian, gun...
# 1998  [selamat, malam, sinyal, telkomsel, ganggu, si...
# 1999  [kuota, multimedia, gimana, maksud, pakai, non...
#
# [1958 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [, darkestdawn, kak, mohon, kenan, tunggu, int...
# 1     [menang, puluh, ratus, proses, cepat, deposit,...
# 2     [menang, puluh, ratus, proses, cepat, deposit,...
# 3     [menang, puluh, ratus, proses, cepat, deposit,...
# 4     [nmr, telepon, hubung, paket, telpon, combo, s...
# ...                                                 ...
# 1995  [butuh, paket, internet, plzzz, telkomsel, deh...
# 1996  [telkomsel, jelek, banget, astaghfirullah, mak...
# 1997  [hai, kak, maaf, kendala, ketidaksesuaian, gun...
# 1998  [selamat, malam, sinyal, telkomsel, ganggu, si...
# 1999  [kuota, multimedia, gimana, maksud, pakai, non...
#
# [1958 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_6.xlsx')
