# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @Telkomsel Hallo min, DM dan cuitan saya kenap...
# 1     @NetflixID @TelkomIndonesia @Telkomsel @IndiHo...
# 2     @Telkomsel hallo min, kenapa jaringan aku x te...
# 3     @Telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @Telkomsel  pagi kak, buka dm dong
# 1997  Kalau mau pembatalan paket kartu halo prosedur...
# 1998   Ai telkomsel milu puasa? Laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 52

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @Telkomsel Hallo min, DM dan cuitan saya kenap...
# 1     @NetflixID @TelkomIndonesia @Telkomsel @IndiHo...
# 2     @Telkomsel hallo min, kenapa jaringan aku x te...
# 3     @Telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @Telkomsel  pagi kak, buka dm dong
# 1997  Kalau mau pembatalan paket kartu halo prosedur...
# 1998   Ai telkomsel milu puasa? Laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
# [1916 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @telkomsel hallo min, dm dan cuitan saya kenap...
# 1     @netflixid @telkomindonesia @telkomsel @indiho...
# 2     @telkomsel hallo min, kenapa jaringan aku x te...
# 3     @telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @telkomsel  pagi kak, buka dm dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998   ai telkomsel milu puasa? laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
# [1916 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @telkomsel hallo min, dm dan cuitan saya kenap...
# 1     @netflixid @telkomindonesia @telkomsel @indiho...
# 2     @telkomsel hallo min, kenapa jaringan aku x te...
# 3     @telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @telkomsel  pagi kak, buka dm dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998   ai telkomsel milu puasa? laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
#                                          cleaning_tweet
# 0      hallo min dan cuitan saya kenapa tidak direspon
# 1                                       hmm sudah akur
# 2              hallo min kenapa jaringan aku terus ini
# 3       harga paket nambah mahal jaringan service terus
# 4     masih aja nyedot nyedotin pulsa wahai ngebug k...
# ...                                                 ...
# 1995       telkomsel akhir akhir iki sinyal menggoblok
# 1996                                 pagi kak buka dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998       telkomsel milu puasa laleuleus kie jaringana
# 1999   punya pulsa tri atau telkomsel tapi butuhnya ...
#
# [1916 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @telkomsel hallo min, dm dan cuitan saya kenap...
# 1     @netflixid @telkomindonesia @telkomsel @indiho...
# 2     @telkomsel hallo min, kenapa jaringan aku x te...
# 3     @telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @telkomsel  pagi kak, buka dm dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998   ai telkomsel milu puasa? laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
#                                          cleaning_tweet  \
# 0      hallo min dan cuitan saya kenapa tidak direspon
# 1                                       hmm sudah akur
# 2              hallo min kenapa jaringan aku terus ini
# 3       harga paket nambah mahal jaringan service terus
# 4     masih aja nyedot nyedotin pulsa wahai ngebug k...
# ...                                                 ...
# 1995       telkomsel akhir akhir iki sinyal menggoblok
# 1996                                 pagi kak buka dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998       telkomsel milu puasa laleuleus kie jaringana
# 1999   punya pulsa tri atau telkomsel tapi butuhnya ...
#
#                                              tokenisasi
# 0     [hallo, min, dan, cuitan, saya, kenapa, tidak,...
# 1                                  [hmm, sudah, akur, ]
# 2     [hallo, min, kenapa, jaringan, aku, terus, ini, ]
# 3     [harga, paket, nambah, mahal, jaringan, servic...
# 4     [masih, aja, nyedot, nyedotin, pulsa, wahai, n...
# ...                                                 ...
# 1995  [telkomsel, akhir, akhir, iki, sinyal, menggob...
# 1996                            [pagi, kak, buka, dong]
# 1997  [kalau, mau, pembatalan, paket, kartu, halo, p...
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, punya, pulsa, tri, atau, telkomsel, tapi, b...
#
# [1916 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @telkomsel hallo min, dm dan cuitan saya kenap...
# 1     @netflixid @telkomindonesia @telkomsel @indiho...
# 2     @telkomsel hallo min, kenapa jaringan aku x te...
# 3     @telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @telkomsel  pagi kak, buka dm dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998   ai telkomsel milu puasa? laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
#                                          cleaning_tweet  \
# 0      hallo min dan cuitan saya kenapa tidak direspon
# 1                                       hmm sudah akur
# 2              hallo min kenapa jaringan aku terus ini
# 3       harga paket nambah mahal jaringan service terus
# 4     masih aja nyedot nyedotin pulsa wahai ngebug k...
# ...                                                 ...
# 1995       telkomsel akhir akhir iki sinyal menggoblok
# 1996                                 pagi kak buka dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998       telkomsel milu puasa laleuleus kie jaringana
# 1999   punya pulsa tri atau telkomsel tapi butuhnya ...
#
#                                              tokenisasi  \
# 0     [hallo, min, dan, cuitan, saya, kenapa, tidak,...
# 1                                  [hmm, sudah, akur, ]
# 2     [hallo, min, kenapa, jaringan, aku, terus, ini, ]
# 3     [harga, paket, nambah, mahal, jaringan, servic...
# 4     [masih, aja, nyedot, nyedotin, pulsa, wahai, n...
# ...                                                 ...
# 1995  [telkomsel, akhir, akhir, iki, sinyal, menggob...
# 1996                            [pagi, kak, buka, dong]
# 1997  [kalau, mau, pembatalan, paket, kartu, halo, p...
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, punya, pulsa, tri, atau, telkomsel, tapi, b...
#
#                                                stopword
# 0                      [hallo, min, cuitan, direspon, ]
# 1                                         [hmm, akur, ]
# 2                              [hallo, min, jaringan, ]
# 3      [harga, paket, nambah, mahal, jaringan, service]
# 4     [nyedot, nyedotin, pulsa, ngebug, kali, aplika...
# ...                                                 ...
# 1995             [telkomsel, iki, sinyal, menggoblok, ]
# 1996                                  [pagi, kak, buka]
# 1997  [pembatalan, paket, kartu, halo, prosedurnya, ...
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, pulsa, tri, telkomsel, butuhnya, dana, ketu...
#
# [1916 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3822
# ------------------------
# hallo : hallo
# min : min
# cuitan : cuit
# direspon : direspon
#  :
# hmm : hmm
# akur : akur
# jaringan : jaring
# harga : harga
# paket : paket
# nambah : nambah
# mahal : mahal
# service : service
# nyedot : nyedot
# nyedotin : nyedotin
# pulsa : pulsa
# ngebug : ngebug
# kali : kali
# aplikasi : aplikasi
# telkomsel : telkomsel
# yak : yak
# kejadian : jadi
# buka : buka
# sisa : sisa
# kepotong : potong
# coba : coba
# jelasin : jelasin
# internet : internet
# kb : kb
# ngabisin : ngabisin
# cobanya : coba
# cepetnya : cepetnya
# wechat : wechat
# belom : bom
# scan : scan
# pelangiqq : pelangiqq
# nikmati : nikmat
# hot : hot
# promo : promo
# bonus : bonus
# turnover : turnover
# dibagikan : bagi
# minggu : minggu
# referral : referral
# seumur : umur
# hidup : hidup
# whatssapp : whatssapp
# facebook : facebook
# menerima : terima
# deposit : deposit
# via : via
# iyaa : iyaa
# mesti : mesti
# jam : jam
# keramat : keramat
# tetep : tetep
# beli : beli
# nomer : nomer
# harian : hari
# pagi : pagi
# grapari : grapari
# pahlawan : pahlawan
# revolusi : revolusi
# pondok : pondok
# bambu : bambu
# msh : msh
# ber : ber
# operasional : operasional
# kah : kah
# terdekat : dekat
# jatiwaringin : jatiwaringin
# dimana : mana
# terima : terima
# kasih : kasih
# kemkominfo : kemkominfo
# penghargaan : harga
# rajin : rajin
# hadiah : hadiah
# netflix : netflix
# indosat : indosat
# iflix : iflix
# cek : cek
# tengkiyuu : tengkiyuu
# tim : tim
# flash : flash
# murah : murah
# ehe : ehe
# klu : klu
# iklan : iklan
# opsel : opsel
# sufah : sufah
# lapor : lapor
# dikirim : kirim
# detelah : detelah
# panggilan : panggil
# bgmn : bgmn
# koneksi : koneksi
# subang : subang
# jawa : jawa
# barat : barat
# butut : butut
# disconect : disconect
# parah : parah
# udah : udah
# restart : restart
# mati : mati
# mulu : mulu
# yaman : yaman
# hati : hati
# open : open
# convert : convert
# rate : rate
# smartfren : smartfren
# transfer : transfer
# judi : judi
# penipuan : tipu
# tindakan : tindak
# sejenisnya : jenis
# tukar : tukar
# tsel : tsel
# three : three
# ewallet : ewallet
# isat : isat
# smf : smf
# jago : jago
# knp : knp
# bandung : bandung
# timur : timur
# daerah : daerah
# ujung : ujung
# berung : berung
# arcamanik : arcamanik
# sinyal : sinyal
# telkomselnya : telkomselnya
# jelek : jelek
# engga : engga
# tolong : tolong
# diperbaiki : baik
# menghambat : hambat
# aktivitas : aktivitas
# uzumaki : uzumaki
# nyari : nyari
# referensi : referensi
# nama : nama
# anak : anak
# nnti : nnti
# sengaja : sengaja
# satelit : satelit
# salah : salah
# satunya : satu
# namain : namain
# ayo : ayo
# mendingan : mending
# main : main
# menang : menang
# ngapain : ngapain
# vcs : vcs
# sewa : sewa
# cari : cari
# situs : situs
# online : online
# fair : fair
# bot : bot
# admin : admin
# murni : murni
# player : player
# tersedia : sedia
# whatsapp : whatsapp
# nagaqq : nagaqq
# link : link
# alternatif : alternatif
# tanduknaga : tanduknaga
# com : com
# kagak : kagak
# aktif : aktif
# nyaaaa : nyaaaa
# hueeee : hueeee
# kuota : kuota
# dimanasihh : dimanasihh
# gang : gang
# haaa : haaa
# pny : pny
# debit : debit
# kaa : kaa
# bank : bank
# gtu : gtu
# mksdnyaa : mksdnyaa
# ngeluhnya : ngeluhnya
# bales : bales
# cosplaynya : cosplaynya
# bca : bca
# kaka : kaka
# unlimited : unlimited
# twitter : twitter
# tweet : tweet
# pict : pict
# pictnya : pictnya
# loading : loading
# tgl : tgl
# apr : apr
# top : top
# mandiri : mandiri
# virtual : virtual
# account : account
# ayah : ayah
# status : status
# pembayaran : bayar
# gagal : gagal
# rekening : rekening
# terdebit : debit
# kemana : mana
# uang : uang
# hasut : hasut
# musuhin : musuhin
# xyx : xyx
# dimusuhin : dimusuhin
# gum : gum
# wkwkwk : wkwkwk
# bts : bts
# kalinya : kali
# ngasih : ngasih
# berhenti : henti
# langganan : langgan
# kerja : kerja
# deposito : deposito
# blm : blm
# refund : refund
# terimakasih : terimakasih
# bojongsari : bojongsari
# depok : depok
# semalam : malam
# trus : trus
# banget : banget
# sinyalnya : sinyal
# diganti : ganti
# manual : manual
# otomoatis : otomoatis
# flop : flop
# majalengka : majalengka
# ohh : ohh
# simpati : simpati
# maksud : maksud
# aowkwkwowkwkwk : aowkwkwowkwkwk
# gabisa : gabisa
# donlod : donlod
# playstore : playstore
# sosmed : sosmed
# lancar : lancar
# jaya : jaya
# btw : btw
# gini : gin
# terusss : terusss
# hshshshsh : hshshshsh
# cieee : cieee
# combo : combo
# trmakasih : trmakasih
# indihome : indihome
# dapet : dapet
# uhd : uhd
# hdr : hdr
# bantu : bantu
# laa : laa
# yahh : yahh
# kirain : kirain
# rb : rb
# paketnya : paket
# udh : udh
# yulatama : yulatama
# wkwkw : wkwkw
# bakiak : bakiak
# smp : smp
# skrng : skrng
# keluarga : keluarga
# skrg : skrg
# dihilangkan : hilang
# peberitahuan : peberitahuan
# konsumen : konsumen
# hilang : hilang
# gimana : gimana
# lemot : lot
# hehehe : hehehe
# lola : lola
# yaaa : yaaa
# jaringannya : jaring
# pricelist : pricelist
# verif : verif
# sehat : sehat
# ooo : ooo
# create : create
# akun : akun
# ock : ock
# khusus : khusus
# kartu : kartu
# gmail : gmail
# non : non
# garansi : garansi
# telegram : telegram
# oo : oo
# each : each
# juni : juni
# emang : emang
# habis : habis
# ratus : ratus
# ribu : ribu
# makasih : makasih
# mbak : mbak
# kris : kris
# disana : sana
# aman : aman
# pakai : pakai
# cashback : cashback
# kupon : kupon
# produk : produk
# prabayar : prabayar
# data : data
# axis : axis
# potongan : potong
# respon : respon
# gda : gda
# ngab : ngab
# sultan : sultan
# paketan : paket
# bangsat : bangsat
# daerahku : daerah
# sampe : sampe
# mampetttttt : mampetttttt
# kyk : kyk
# makanan : makan
# berserat : serat
# terpaksa : paksa
# numpang : numpang
# hotspot : hotspot
# tetangga : tetangga
# spy : spy
# ketemu : ketemu
# teman : teman
# ngangenin : ngangenin
# netempe : netempe
# melulu : melulu
# jakarta : jakarta
# purwakarta : purwakarta
# wey : wey
# ajg : ajg
# gajelas : gajelas
# ilang : ilang
# ilangan : ilangan
# teru : teru
# mah : mah
# abis : abis
# pas : pas
# macet : macet
# digali : gali
# diteliti : teliti
# gentho : gentho
# kak : kak
# sel : sel
# wtb : wtb
# jumat : jumat
# bareng : bareng
# jalin : jalin
# silaturahmi : silaturahmi
# medsos : medsos
# streaming : streaming
# film : film
# favorit : favorit
# game : game
# temen : temen
# browsing : browsing
# sepuasnya : puas
# aktifin : aktifin
# mytelkomsel : mytelkomsel
# woi : woi
# tante : tante
# veronica : veronica
# kunaon : kunaon
# atuh : atuh
# selesaikan : selesai
# baikbaik : baikbaik
# donk : donk
# plafon : plafon
# beton : beton
# gedung : gedung
# simpang : simpang
# runtuh : runtuh
# lantai : lantai
# menimpa : timpa
# orang : orang
# salesperson : salesperson
# fleksi : fleksi
# mezanin : mezanin
# duanya : dua
# selamat : selamat
# dirawat : rawat
# was : was
# there : there
# fuck : fuck
# you : you
# error : error
# ngegame : ngegame
# signal : signal
# org : org
# net : net
# info : info
# wifi : wifi
# nyampe : nyampe
# rmh : rmh
# layak : layak
# dipakai : pakai
# kualitas : kualitas
# internetnya : internetnya
# lelet : lelet
# evaluasi : evaluasi
# berkali : kali
# pelanggan : langgan
# mengadukan : adu
# tpi : tpi
# janji : janji
# manis : manis
# mending : mending
# pilih : pilih
# tri : tri
# kasihan : kasihan
# warga : warga
# dibodohi : bodoh
# narasi : narasi
# penuh : penuh
# tipu : tipu
# daya : daya
# allah : allah
# ngeselin : ngeselin
# bangat : bangat
# lelaamuslimin : lelaamuslimin
# mdak : mdak
# malam : malam
# member : member
# bonekaqq : bonekaqq
# meraih : raih
# kemenangan : menang
# beruntun : untun
# permainan : main
# bandar : bandar
# biasayuk : biasayuk
# buruan : buru
# gabung : gabung
# boneka : boneka
# bebas : bebas
# bos : bos
# register : register
# livechat : livechat
# line : line
# asyiik : asyiik
# semoga : moga
# kabar : kabar
# cepat : cepat
# make : make
# bundling : bundling
# disney : disney
# are : are
# okay : okay
# please : please
# kek : kek
# ngomong : ngomong
# bantuannya : bantu
# anjg : anjg
# bet : bet
# gangguan : ganggu
# ramadhan : ramadhan
# rewel : rewel
# aasuuu : aasuuu
# bapuk : bapuk
# gais : gais
# udahan : udahan
# gue : gue
# bakar : bakar
# emg : emg
# tower : tower
# surprise : surprise
# deal : deal
# tanggal : tanggal
# setua : tua
# beda : beda
# harganya : harga
# lipat : lipat
# maki : maki
# luapkan : luap
# buffering : buffering
# sakti : sakti
# youtube : youtube
# kemarin : kemarin
# normal : normal
# perbaiki : baik
# login : login
# force : force
# close : close
# hapus : hapus
# apk : apk
# download : download
# iya : iya
# doang : doang
# kecewa : kecewa
# sumpa : sumpa
# update : update
# perubahan : ubah
# baca : baca
# woy : woy
# katain : katain
# ampun : ampun
# pantesan : pantesan
# dicek : cek
# halo : halo
# bingung : bingung
# deh : deh
# yuk : yuk
# gendeng : gendeng
# sumpah : sumpah
# terbaikk : terbaikk
# ngerush : ngerush
# tro : tro
# anjimm : anjimm
# pubg : pubg
# menit : menit
# bar : bar
# sma : sma
# hebatnya : hebat
# bener : bener
# kapok : kapok
# penunjang : tunjang
# perkuliahan : kuliah
# masi : mas
# support : support
# gmeet : gmeet
# zoom : zoom
# gcr : gcr
# yutub : yutub
# harapan : harap
# itumah : itumah
# cita : cita
# citaku : cita
# tanah : tanah
# disewa : sewa
# off : off
# save : save
# budget : budget
# ngak : ngak
# masuk : masuk
# saldo : saldo
# terpotong : potong
# babi : babi
# gua : gua
# pingnya : pingnya
# jumping : jumping
# ijo : ijo
# merah : merah
# taiiiiii : taiiiiii
# taiiiiiii : taiiiiiii
# uancok : uancok
# telkomsell : telkomsell
# milih : milih
# opsi : opsi
# bsa : bsa
# msuk : msuk
# pembelian : beli
# metode : metode
# cobaa : cobaa
# liat : liat
# tulisannya : tulis
# kaya : kaya
# gitu : gitu
# klik : klik
# tulisan : tulis
# tersedianya : sedia
# naskleng : naskleng
# gopay : gopay
# dibenahi : benah
# nyaman : nyaman
# gb : gb
# perbulan : bulan
# rugi : rugi
# tut : tut
# hahaa : hahaa
# boros : boros
# yaa : yaa
# mba : mba
# pke : pke
# nek : nek
# wes : wes
# tua : tua
# nyambung : nyambung
# umur : umur
# dsini : dsini
# lumayan : lumayan
# cma : cma
# internetny : internetny
# sing : sing
# twt : twt
# rise : rise
# billkin : billkin
# tbk : tbk
# memilih : pilih
# terbukti : bukti
# keamanan : aman
# kenyamanan : nyaman
# kunjungi : kunjung
# sahabatpoker : sahabatpoker
# jamin : jamin
# contact : contact
# indosahabatpk : indosahabatpk
# jaringamu : jaringamu
# stabil : stabil
# mahalnya : mahal
# chat : chat
# mengeluhkan : keluh
# sinyalmu : sinyal
# nonton : nonton
# bola : bola
# dikasih : kasih
# iyaaaa : iyaaaa
# samaa : samaa
# ane : ane
# ehh : ehh
# sekrang : sekrang
# kuat : kuat
# aneee : aneee
# program : program
# google : google
# dihapus : hapus
# dilarang : larang
# negara : negara
# dikeluarkan : keluar
# kota : kota
# ngawi : ngawi
# browser : browser
# dijual : jual
# membantu : bantu
# pki : pki
# merongrong : rongrong
# nkri : nkri
# bull : bull
# paleng : paleng
# paksa : paksa
# semangat : semangat
# hotstar : hotstar
# marvel : marvel
# series : series
# golek : golek
# seng : seng
# ngerespon : ngerespon
# cepet : cepet
# contoh : contoh
# traveloka : traveloka
# ngk : ngk
# moga : moga
# dipake : dipake
# aplikasimu : aplikasi
# angin : angin
# setelh : setelh
# operator : operator
# pegawai : pegawai
# awasin : awasin
# ngadrun : ngadrun
# kibul : kibul
# uda : uda
# baikan : baik
# asik : asik
# dibulan : bulan
# koin : koin
# webtoon : webtoon
# potong : potong
# koinnya : koin
# beneran : beneran
# berhasil : hasil
# tkp : tkp
# pdhal : pdhal
# unlimitedmax : unlimitedmax
# bgtbgtbgt : bgtbgtbgt
# akses : akses
# shopee : shopee
# ping : ping
# byyu : byyu
# diharepin : diharepin
# rizki : rizki
# plisss : plisss
# tidur : tidur
# lupa : lupa
# gnitee : gnitee
# pengisian : isi
# ulang : ulang
# menambah : tambah
# credit : credit
# limit : limit
# ngomongnya : ngomongnya
# ningkatin : ningkatin
# ningkatnya : ningkatnya
# nomor : nomor
# berjalannya : jalan
# isi : isi
# nominal : nominal
# mohon : mohon
# penjelasan : jelas
# detailnya : detail
# trims : trims
# keknya : kek
# huehehehehhe : huehehehehhe
# yokk : yokk
# boyy : boyy
# maap : maap
# yee : yee
# jimin : jimin
# namjoon : namjoon
# makenya : makenya
# buatmu : buat
# nak : nak
# kenceng : kenceng
# dirumah : rumah
# ambyar : ambyar
# internetan : internetan
# fucck : fucck
# menghubungkan : hubung
# settingan : settingan
# rendah : rendah
# eror : eror
# bayar : bayar
# busuk : busuk
# hatii : hati
# nder : nder
# keblokir : blokir
# striming : striming
# butter : butter
# ganti : ganti
# gmn : gmn
# aduh : aduh
# kab : kab
# bogor : bogor
# ditelpon : telpon
# center : center
# jujur : jujur
# mengganggu : ganggu
# smaa : smaa
# miskin : miskin
# dikirimin : dikirimin
# pinjol : pinjol
# emag : emag
# iyaya : iyaya
# bagus : bagus
# maaf : maaf
# gaada : gaada
# temennya : temennya
# best : best
# sksks : sksks
# apasi : apas
# perusahaan : usaha
# assalamualaikum : assalamualaikum
# infonya : info
# pencerahananya : pencerahananya
# stanby : stanby
# kejam : kejam
# mahalan : mahal
# pakenya : pakenya
# desaku : desa
# cumn : cumn
# anjr : anjr
# dlu : dlu
# boy : boy
# gasuka : gasuka
# palagi : palagi
# begituan : begitu
# sorry : sorry
# telponable : telponable
# gapake : gapake
# anakannya : ana
# wkwkk : wkwkk
# lach : lach
# mantap : mantap
# ngandelin : ngandelin
# provider : provider
# pemerintah : perintah
# errornya : errornya
# barengann : barengann
# official : official
# karna : karna
# loop : loop
# kth : kth
# pokokny : pokokny
# and : and
# gegara : gegara
# jadwal : jadwal
# trining : trining
# belajar : ajar
# ogah : ogah
# mikirin : mikirin
# haish : haish
# pasang : pasang
# full : full
# tiang : tiang
# solusi : solusi
# oake : oake
# orbit : orbit
# tergantung : gantung
# guys : guys
# nanya : nanya
# gila : gila
# tinggal : tinggal
# susah : susah
# jungkookie : jungkookie
# sie : sie
# dunia : dunia
# namanya : nama
# usaha : usaha
# keras : keras
# lakuin : lakuin
# ngoceh : ngoceh
# bawa : bawa
# true : true
# mytimeee : mytimeee
# pakainya : pakai
# siang : siang
# truee : truee
# lagipula : lagipula
# kompetisi : kompetisi
# tempatnya : tempat
# vote : vote
# for : for
# the : the
# ngantuk : ngantuk
# msih : msih
# bkin : bkin
# ketawa : ketawa
# duh : duh
# sender : sender
# sales : sales
# jls : jls
# idupny : idupny
# harap : harap
# burik : burik
# streamingnya : streamingnya
# hiksss : hiksss
# hujan : hujan
# besok : besok
# iki : iki
# myrep : myrep
# berasa : asa
# idup : idup
# jaman : jaman
# ice : ice
# age : age
# sodaraan : sodaraan
# akutuh : akutuh
# penasaran : penasaran
# mimin : mimin
# instagram : instagram
# caption : caption
# sll : sll
# membuatku : buat
# tertawa : tertawa
# dikala : kala
# gundah : gundah
# gulana : gulana
# menghadapi : hadap
# beratnya : berat
# jadikan : jadi
# jodohmu : jodoh
# jga : jga
# sempet : sempet
# nge : nge
# lagg : lagg
# pacaran : pacar
# oprator : oprator
# gmnaa : gmnaa
# knpaa : knpaa
# cowok : cowok
# nggak : nggak
# anjirr : anjirr
# aktivasi : aktivasi
# galaxy : galaxy
# plan : plan
# buah : buah
# lobi : lobi
# bupati : bupati
# anambas : anambas
# bangun : bangun
# desa : desa
# teluk : teluk
# sunting : sunting
# ladan : ladan
# kerjasama : kerjasama
# siapkan : siap
# infrastruktur : infrastruktur
# komunikasi : komunikasi
# dukung : dukung
# pon : pon
# papua : papua
# sekencang : kencang
# weh : weh
# jele : jele
# ansgdjfll : ansgdjfll
# tibake : tibake
# hapene : hapene
# sek : sek
# sepi : sepi
# welahh : welahh
# cetek : cetek
# otaknya : otak
# pdahal : pdahal
# islam : islam
# flexible : flexible
# exis : exis
# asia : asia
# mentari : mentari
# bermasalah : masalah
# trs : trs
# coeey : coeey
# hasil : hasil
# result : result
# hongkong : hongkong
# shio : shio
# tikus : tikus
# web : web
# www : www
# kktoto : kktoto
# surf : surf
# minimal : minimal
# beting : beting
# togel : togel
# perak : perak
# pendaftaran : daftar
# dana : dana
# ovo : ovo
# daftar : daftar
# buruk : buruk
# telkom : telkom
# ngebuka : ngebuka
# mas : mas
# sugab : sugab
# serasa : serasa
# monangis : monangis
# terharu : haru
# minnn : minnn
# gampangin : gampangin
# pembayarannya : bayar
# tambahin : tambahin
# jnius : jnius
# ndak : ndak
# ituuu : ituuu
# domino : domino
# langgar : langgar
# aturan : atur
# persaingan : saing
# perpanjang : panjang
# trf : trf
# im : im
# token : token
# pln : pln
# nahkan : nahkan
# kitanya : kita
# kesel : kesel
# perdana : perdana
# pemesanan : mesan
# wassap : wassap
# citayam : citayam
# lampu : lampu
# indikator : indikator
# bagong : bagong
# giga : giga
# multimedia : multimedia
# ngakses : ngakses
# oom : oom
# hey : hey
# down : down
# bangkeeeeeeeee : bangkeeeeeeeee
# area : area
# coverage : coverage
# home : home
# hub : hub
# jarjitot : jarjitot
# stress : stress
# blockir : blockir
# hack : hack
# bedanya : beda
# dipermudah : mudah
# gpp : gpp
# dipepet : pepet
# kasi : kasi
# menghapus : hapus
# nik : nik
# masak : masak
# nyusahin : nyusahin
# kakak : kakak
# melanjutkan : lanjut
# interaksinya : interaksi
# linaldi : linaldi
# hai : hai
# natalia : natalia
# perihal : perihal
# layanan : layan
# fup : fup
# melebihi : lebih
# batas : batas
# direset : direset
# nol : nol
# usage : usage
# dihitung : hitung
# terupdate : terupdate
# labil : labil
# siii : siii
# bbrp : bbrp
# nampol : nampol
# kaga : kaga
# mention : mention
# ikatan : ikat
# damai : damai
# manfaatnya : manfaat
# merasakan : rasa
# kelancaran : lancar
# tuker : tuker
# poin : poin
# gratis : gratis
# hahahah : hahahah
# gokilll : gokilll
# tlg : tlg
# nyaaa : nyaaa
# nitip : nitip
# barangkali : barangkali
# minat : minat
# trusted : trusted
# sedia : sedia
# all : all
# langsung : langsung
# jual : jual
# fliss : fliss
# tauuiu : tauuiu
# nextime : nextime
# lahhh : lahhh
# real : real
# dpt : dpt
# pnya : pnya
# ibuku : ibu
# unli : unli
# sebulan : bulan
# tlkmsl : tlkmsl
# ciee : ciee
# akurrr : akurrr
# segini : gin
# bidadari : bidadari
# next : next
# time : time
# ajakin : ajakin
# kantor : kantor
# doi : doi
# pelatihan : latih
# digitalisasi : digitalisasi
# umkm : umkm
# flobamora : flobamora
# indonesia : indonesia
# kominfo : kominfo
# onboarding : onboarding
# tokopedia : tokopedia
# pijar : pijar
# padi : padi
# ditanggapi : tanggap
# speed : speed
# dipota : dipota
# bermaslaha : bermaslaha
# kppu : kppu
# kartunya : kartu
# manggarai : manggarai
# berkat : berkat
# jajal : jajal
# genre : genre
# animasi : animasi
# dlm : dlm
# sulih : sulih
# suara : suara
# bahasa : bahasa
# kun : kun
# sihh : sihh
# ngerasain : ngerasain
# sinyalnyaa : sinyalnyaa
# plg : plg
# better : better
# dibanding : banding
# ajaaa : ajaaa
# hft : hft
# tambahan : tambah
# modal : modal
# rollingan : rollingan
# senin : senin
# referal : referal
# crownqq : crownqq
# ciyeeee : ciyeeee
# ciyeeeee : ciyeeeee
# garda : garda
# pasangan : pasang
# with : with
# komplen : komplen
# dibales : dibales
# kenapasiii : kenapasiii
# teruus : teruus
# nyoba : nyoba
# gara : gara
# minn : minn
# dmku : dmku
# dibalasss : dibalasss
# dri : dri
# plus : plus
# sabi : sabi
# lemottttt : lemottttt
# muluuuuu : muluuuuu
# kesini : kesini
# ngapa : ngapa
# mobile : mobile
# lejen : lejen
# gatau : gatau
# cerita : cerita
# manjur : manjur
# males : males
# tangani : tangan
# kwkwkwk : kwkwkwk
# salfok : salfok
# makanannya : makan
# bujang : bujang
# lapuk : lapuk
# lte : lte
# hadir : hadir
# kecamatan : camat
# pantan : pantan
# cuaca : cuaca
# berulang : ulang
# ulangg : ulangg
# cuan : cuan
# arek : arek
# uni : uni
# huaaa : huaaa
# kesana : kesana
# dear : dear
# refresh : refresh
# search : search
# membaca : baca
# keluhan : keluh
# stb : stb
# cape : cape
# spill : spill
# dikit : dikit
# serunyaaa : serunyaaa
# nunggu : nunggu
# sabtu : sabtu
# rabu : rabu
# kamis : kamis
# april : april
# sore : sore
# prioritas : prioritas
# ngirim : ngirim
# tugas : tugas
# sekolah : sekolah
# daerahnya : daerah
# kepo : kepo
# ngga : ngga
# ngobrolinnya : ngobrolinnya
# taruhan : taruh
# yuukk : yuukk
# yuuukk : yuuukk
# telepon : telepon
# rumah : rumah
# koyone : koyone
# ket : ket
# taun : taun
# wingi : wing
# iso : iso
# netflixan : netflixan
# nganggo : nganggo
# muu : muu
# pakek : pakek
# smatpren : smatpren
# hmmm : hmmm
# mengaggu : mengaggu
# uts : uts
# bgtdah : bgtdah
# free : free
# aplikasinya : aplikasi
# dayun : dayun
# siak : siak
# sri : sri
# indrapura : indrapura
# timbul : timbul
# sms : sms
# spam : spam
# blokir : blokir
# system : system
# menu : menu
# terkoneksi : koneksi
# segerain : gain
# useetvnya : useetvnya
# app : app
# etjieee : etjieee
# temenan : temenan
# ngobrolin : ngobrolin
# inovasi : inovasi
# tng : tng
# iyaaa : iyaaa
# berkah : berkah
# puasa : puasa
# sekarat : sekarat
# gambar : gambar
# jdinya : jdinya
# digunain : digunain
# kesah : kesah
# tuhan : tuhan
# kebangetan : banget
# upload : upload
# laporan : lapor
# putuskan : putus
# mengakibatkan : akibat
# diblur : diblur
# shopeepay : shopeepay
# linkaja : linkaja
# atm : atm
# testi : testi
# fastresp : fastresp
# tele : tele
# jasa : jasa
# yha : yha
# sebenernya : sebenernya
# nga : nga
# monopoli : monopoli
# ott : ott
# dibikinin : dibikinin
# perkara : perkara
# penelitian : teliti
# inisiatif : inisiatif
# seiring : iring
# temuan : temu
# pemblokiran : blokir
# mengakses : akses
# konten : konten
# mybusiness : mybusiness
# setuju : tuju
# kemaren : kemaren
# diblokir : blokir
# skr : skr
# maunya : mau
# muncul : muncul
# selesai : selesai
# tks : tks
# dikembalikan : kembali
# etikad : etikad
# membalas : balas
# complain : complain
# cie : cie
# gontok : gontok
# gontokan : gontok
# hpku : hpku
# kulon : kulon
# butuh : butuh
# bantuan : bantu
# anjinggggggg : anjinggggggg
# handphone : handphone
# laptop : laptop
# tunggu : tunggu
# enak : enak
# hello : hello
# kesedot : sedot
# pdhl : pdhl
# dimatikan : mati
# least : least
# seru : seru
# dokumenter : dokumenter
# judulnya : judul
# never : never
# stop : stop
# reset : reset
# modem : modem
# dibutuhin : dibutuhin
# sistem : sistem
# gausah : gausah
# tumben : tumben
# premium : premium
# siiih : siiih
# cieeee : cieeee
# trade : trade
# barter : barter
# qris : qris
# ktp : ktp
# prem : prem
# preset : preset
# lightroom : lightroom
# paylater : paylater
# punyaku : punya
# oiii : oiii
# udhh : udhh
# ajaa : ajaa
# tagihan : tagih
# hangus : hangus
# total : total
# awas : awas
# dibomb : dibomb
# sensor : sensor
# bumn : bumn
# spay : spay
# periode : periode
# penawaran : tawar
# makek : makek
# yok : yok
# adminya : adminya
# terawih : terawih
# minnnn : minnnn
# txtfromnetflik : txtfromnetflik
# kendala : kendala
# mencoba : coba
# pindahkan : pindah
# mode : mode
# otomatis : otomatis
# kembalikan : kembali
# mhn : mhn
# dibantu : bantu
# komplek : komplek
# perum : perum
# puri : puri
# surya : surya
# cluster : cluster
# valencia : valencia
# icon : icon
# gedangan : gedang
# sidoarjo : sidoarjo
# thanks : thanks
# yuhuu : yuhuu
# wid : wid
# selengkapnya : lengkap
# agen : agen
# bandarpoker : bandarpoker
# bandarq : bandarq
# terpercaya : percaya
# teraman : ram
# buktikan : bukti
# bergabung : gabung
# ama : ama
# maxstream : maxstream
# kayak : kayak
# sebelah : belah
# asli : asli
# in : in
# kuotaa : kuotaa
# ngisi : ngisi
# ketinggalan : tinggal
# kutbah : kutbah
# berbagi : bagi
# obi : obi
# tenang : tenang
# nungguin : nungguin
# tipsnya : tipsnya
# video : video
# elah : elah
# ban : ban
# direload : direload
# keitung : keitung
# hadeh : hadeh
# sknyalnya : sknyalnya
# alay : alay
# hdhh : hdhh
# princess : princess
# mrah : mrah
# nieee : nieee
# spotify : spotify
# hbo : hbo
# mantep : mantep
# ragu : ragu
# migrasi : migrasi
# kartuhalo : kartuhalo
# sip : sip
# telkosmel : telkosmel
# canda : canda
# mudah : mudah
# donggggggggggt : donggggggggggt
# heh : heh
# sii : sii
# layanannya : layan
# berubah : ubah
# kecepatan : cepat
# lambat : lambat
# perasaan : asa
# berap : rap
# aaaa : aaaa
# aneh : aneh
# majii : majii
# plis : plis
# dirut : dirut
# stafsus : stafsus
# milenial : milenial
# masukin : masukin
# blog : blog
# ruangguru : ruangguru
# xxx : xxx
# anggota : anggota
# kkn : kkn
# tergabut : tergabut
# malu : malu
# taik : taik
# ngadat : ngadat
# lokasi : lokasi
# kec : kec
# gabus : gabus
# grobogan : grobogan
# jateng : jateng
# kesaaal : kesaaal
# reply : reply
# dibalas : balas
# indihom : indihom
# cinta : cinta
# indomeh : indomeh
# sukses : sukses
# anjing : anjing
# membuang : buang
# buang : buang
# mesra : mesra
# ritwit : ritwit
# seribu : ribu
# ntu : ntu
# denda : denda
# rupiah : rupiah
# bikinin : bikinin
# serial : serial
# horror : horror
# tuyul : tuyul
# ngepet : ngepet
# ngelawan : ngelawan
# detektif : detektif
# polisi : polisi
# pilihannya : pilih
# kolaborasi : kolaborasi
# bestie : bestie
# jawabannya : jawab
# lemotnya : lot
# lbh : lbh
# tinggalkan : tinggal
# dirmh : dirmh
# bukber : bukber
# adzan : adzan
# magrib : magrib
# muadzinnya : muadzinnya
# delay : delay
# disuruh : suruh
# awawawaw : awawawaw
# router : router
# bertamunya : tamu
# kompetitor : kompetitor
# wih : wih
# jancok : jancok
# kabeh : kabeh
# diajak : ajak
# kau : kau
# dicampakkan : campak
# hahaha : hahaha
# ngobrolnya : ngobrolnya
# putus : putus
# rilis : rilis
# statistik : statistik
# berdasarkan : dasar
# model : model
# dibawah : bawah
# kabur : kabur
# yes : yes
# setahun : tahun
# terbaiks : terbaiks
# kumat : kumat
# alias : alias
# hemat : hemat
# serba : serba
# digital : digital
# sim : sim
# card : card
# jangkauan : jangkau
# terluas : luas
# wajib : wajib
# tonight : tonight
# show : show
# wib : wib
# sok : sok
# siaaalaaannnn : siaaalaaannnn
# this : this
# why : why
# dont : dont
# use : use
# kids : kids
# suruh : suruh
# larang : larang
# tayangan : tayang
# mei : mei
# solusinya : solusi
# ecieeee : ecieeee
# nice : nice
# semacem : semacem
# menggandeng : gandeng
# platform : platform
# mola : mola
# vidio : vidio
# viu : viu
# lionsgate : lionsgate
# play : play
# dll : dll
# user : user
# advantage : advantage
# apaaaa : apaaaa
# serius : serius
# lhooooo : lhooooo
# include : include
# subscription : subscription
# syopi : syopi
# tokped : tokped
# auto : auto
# debet : debet
# gampang : gampang
# hedon : hedon
# kadang : kadang
# plot : plot
# twist : twist
# ols : ols
# rek : rek
# diluk : luk
# men : men
# cuman : cuman
# kiro : kiro
# sak : sak
# ulan : ulan
# pirang : pirang
# ngunu : ngunu
# ancen : ancen
# lek : lek
# wedi : wedi
# ngomel : ngomel
# soale : soale
# cont : cont
# university : university
# beasiswa : beasiswa
# cetak : cetak
# talenta : talenta
# nasi : nasi
# email : email
# btpncare : btpncare
# berkenan : kenan
# informasi : informasi
# projectan : projectan
# anyar : anyar
# berita : berita
# ampe : ampe
# blur : blur
# tipi : tipi
# xixix : xixix
# ciye : ciye
# ditunggu : tunggu
# collabnya : collabnya
# adain : adain
# asikkkl : asikkkl
# bni : bni
# bilangin : bilangin
# woahh : woahh
# suka : suka
# akurr : akurr
# akurnya : akur
# senang : senang
# yya : yya
# diseluruh : seluruh
# pelosok : pelosok
# hayooo : hayooo
# gan : gan
# bang : bang
# bayarnya : bayar
# dendam : dendam
# nntn : nntn
# ngampus : ngampus
# dada : dada
# loadingnya : loadingnya
# lamaaaa : lamaaaa
# bangetttttt : bangetttttt
# block : block
# makannya : makan
# tumpeng : tumpeng
# mini : mini
# biru : biru
# ato : ato
# kuning : kuning
# pelanggannya : langgan
# kolabsnya : kolabsnya
# nepi : nepi
# ayena : ayena
# keneh : keneh
# mutiara : mutiara
# ngke : ngke
# heula : heula
# teruss : teruss
# tamabahin : tamabahin
# pembayarannyaa : pembayarannyaa
# kredit : kredit
# first : first
# date : date
# mencium : cium
# aroma : aroma
# nihh : nihh
# bangettt : bangettt
# temanku : teman
# beliin : beliin
# berkesinambungan : sambung
# meningkatkan : tingkat
# kapasitas : kapasitas
# mengantisipasi : antisipasi
# kenaikan : naik
# traffic : traffic
# menikmati : nikmat
# berkualitas : kualitas
# samanya : sama
# pengguna : guna
# sengsara : sengsara
# filtering : filtering
# paketannya : paket
# sahabat : sahabat
# karib : karib
# chill : chill
# cell : cell
# amirsyarif : amirsyarif
# temenku : temenku
# bulanannya : bulan
# device : device
# hape : hape
# nebeng : nebeng
# netflixnya : netflixnya
# kalah : kalah
# maksudnya : maksud
# box : box
# install : install
# android : android
# tungguuu : tungguuu
# burem : burem
# kerjaan : kerja
# klien : klien
# kekirim : kirim
# resolusi : resolusi
# homecare : homecare
# arya : arya
# valzz : valzz
# informasikan : informasi
# sesuai : sesuai
# hubungi : hubung
# ngeluh : ngeluh
# wkwkwkwkkkkk : wkwkwkwkkkkk
# ayolah : ayo
# permudah : mudah
# pribadi : pribadi
# jilat : jilat
# ludah : ludah
# even : even
# bisnis : bisnis
# lumrah : lumrah
# ajasi : ajasi
# dulunya : dulunya
# musuhan : musuh
# deketan : deketan
# gemay : gemay
# kenalaan : nala
# baiknya : baik
# menyusul : susul
# sensar : sensar
# terlaluu : terlaluu
# rencana : rencana
# turun : turun
# eciee : eciee
# diajar : ajar
# ajarin : ajarin
# berharap : harap
# diskon : diskon
# pertahun : tahun
# ngayal : ngayal
# gapapa : gapapa
# tersisa : sisa
# uppp : uppp
# komen : komen
# dicekik : cekik
# bandwithnya : bandwithnya
# good : good
# kelen : kelen
# akrab : akrab
# indomaret : indomaret
# patria : patria
# menyediakan : sedia
# broadband : broadband
# interaksi : interaksi
# silakan : sila
# menghubungi : hubung
# resmi : resmi
# zaf : zaf
# terregistrasi : terregistrasi
# ngrasa : ngrasa
# unreg : unreg
# dftar : dftar
# dftr : dftr
# bobotoh : bobotoh
# dukungan : dukung
# menuliskan : tulis
# juta : juta
# pemenang : menang
# mekanismenya : mekanisme
# kedepannya : depan
# love : love
# hate : hate
# relationship : relationship
# ciieee : ciieee
# langgeng : langgeng
# wallet : wallet
# dibaca : baca
# gdrive : gdrive
# mega : mega
# drive : drive
# orderan : order
# proses : proses
# pengerjaan : kerja
# widevine : widevine
# peluang : peluang
# dimaafkan : maaf
# sajaaaa : sajaaaa
# gaet : gaet
# keliatan : liat
# gede : gede
# sung : sung
# jokowi : jokowi
# prabowo : prabowo
# gadibales : gadibales
# tanggepan : tanggepan
# pindah : pindah
# haloooo : haloooo
# jogja : jogja
# trouble : trouble
# when : when
# datamu : data
# diliat : liat
# kmaren : kmaren
# berantem : antem
# bedua : bedua
# dibuka : buka
# blocknya : blocknya
# mahh : mahh
# bangtan : bangtan
# cieeeee : cieeeee
# sohib : sohib
# aje : aje
# digandeng : gandeng
# hih : hih
# dibuang : buang
# sepah : sepah
# dimanis : man
# ayoooooo : ayoooooo
# unlimax : unlimax
# batang : batang
# max : max
# jadian : jadi
# tho : tho
# ngira : ngira
# rusak : rusak
# munculin : munculin
# ditest : ditest
#  : 
# bisain : bisain
# kawan : kawan
# kawannya : kawan
# mbok : mbok
# suadaramu : suadaramu
# tanggap : tanggap
# super : super
# bebasin : bebasin
# asyu : asyu
# kmrn : kmrn
# napa : napa
# kantornya : kantor
# ngobrol : ngobrol
# kemusuhan : musuh
# mendadak : dadak
# nyala : nyala
# boro : boro
# indo : indo
# useless : useless
# but : but
# yeah : yeah
# hahah : hahah
# fix : fix
# bye : bye
# alhirnya : alhirnya
# yaallah : yaallah
# menangis : menang
# lgsg : lgsg
# kkp : kkp
# perkaya : kaya
# edukatif : edukatif
# kelautan : laut
# pendatang : datang
# penantang : tantang
# pasar : pasar
# seluler : seluler
# need : need
# murce : murce
# rush : rush
# berlangganan : langgan
# ngeri : ngeri
# melewati : lewat
# tenggang : tenggang
# voucher : voucher
# makasi : makas
# semogaa : semogaa
# quota : quota
# berguna : guna
# kepake : kepake
# will : will
# spacex : spacex
# released : released
# bored : bored
# gmna : gmna
# cdm : cdm
# ngetag : ngetag
# dibilangin : dibilangin
# mima : mima
# jugak : jugak
# bangg : bangg
# yaampun : yaampun
# bacanya : baca
# sibapak : sibapak
# diwawancara : wawancara
# kelewat : lewat
# memancing : pancing
# emosi : emosi
# pay : pay
# loopers : loopers
# ingetin : ingetin
# keseruan : seru
# undi : undi
# hepi : hepi
# tukerin : tukerin
# keep : keep
# getting : getting
# reconnecting : reconnecting
# during : during
# your : your
# meetings : meetings
# then : then
# that : that
# switch : switch
# ngcom : ngcom
# today : today
# call : call
# get : get
# started : started
# gaenak : gaenak
# customer : customer
# servicenya : servicenya
# dihubungin : dihubungin
# psst : psst
# diamond : diamond
# codashop : codashop
# belanja : belanja
# rp : rp
# kuy : kuy
# sobat : sobat
# seputar : putar
# rekan : rekan
# platinum : platinum
# ngezoom : ngezoom
# syafuani : syafuani
# songong : songong
# kouta : kouta
# ketengan : keteng
# respect : respect
# nyaa : nyaa
# tampil : tampil
# pengalaman : alam
# wktu : wktu
# pal : pal
# gantikan : ganti
# setauku : tau
# jua : jua
# syarar : syarar
# tiket : tiket
# kse : kse
# px : px
# berkurang : kurang
# utama : utama
# nyampein : nyampein
# kmn : kmn
# bkn : bkn
# load : load
# foto : foto
# menangin : menangin
# gfriend : gfriend
# event : event
# asiknya : asiknya
# seminggu : minggu
# mingguan : minggu
# ditambah : tambah
# berlaku : laku
# heran : heran
# sibuk : sibuk
# knpa : knpa
# seh : seh
# poinnya : poin
# qaqa : qaqa
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# malang : malang
# ganguan : ganguan
# pasir : pasir
# putih : putih
# sawangan : sawangan
# nyatakan : nyata
# bersalah : salah
# jancuk : jancuk
# menolong : tolong
# tenggat : tenggat
# mengintai : intai
# mari : mari
# mampir : mampir
# disitus : situs
# ioncasino : ioncasino
# scatter : scatter
# stake : stake
# klaim : klaim
# inget : inget
# ngetweet : ngetweet
# lkomsel : lkomsel
# unblock : unblock
# wkwkwkwwk : wkwkwkwwk
# menikah : meni
# order : order
# konfirmasi : konfirmasi
# tolonglah : tolong
# ngutang : ngutang
# lihat : lihat
# nomornya : nomor
# pemakaian : pakai
# wajar : wajar
# apps : apps
# bayangin : bayangin
# tbtb : tbtb
# selonjoran : selonjor
# teras : teras
# suri : suri
# astaghfirullah : astaghfirullah
# menguji : uji
# kesabaran : sabar
# enzy : enzy
# janjian : janji
# ditinggalin : ditinggalin
# kena : kena
# ghosting : ghosting
# hiks : hiks
# kisah : kisah
# denger : denger
# lindungi : lindung
# dirimu : diri
# proteksi : proteksi
# manfaat : manfaat
# asuransi : asuransi
# aktifkan : aktif
# perlindungan : lindung
# drpd : drpd
# mamas : mamas
# hobi : hobi
# guyon : guyon
# ciyee : ciyee
# naikin : naikin
# niyee : niyee
# aamiinn : aamiinn
# memutuskan : putus
# sanksi : sanksi
# memblokir : blokir
# muak : muak
# gedeg : gedeg
# message : message
# balasan : balas
# here : here
# say : say
# boring : boring
# fire : fire
# kece : kece
# offering : offering
# special : special
# gacha : gacha
# item : item
# skin : skin
# keren : keren
# topup : topup
# diamonds : diamonds
# motong : motong
# reguler : reguler
# hhh : hhh
# membeli : beli
# dibayar : bayar
# kunjung : kunjung
# central : central
# park : park
# mall : mall
# dikost : dikost
# ajak : ajak
# betumbuk : betumbuk
# bukanya : buka
# bentrok : bentrok
# spamming : spamming
# maksa : maksa
# drama : drama
# korea : korea
# dengerin : dengerin
# soundtrack : soundtrack
# musik : musik
# lagu : lagu
# lagunya : lagu
# musicmax : musicmax
# elektrik : elektrik
# kaak : kaak
# kementerian : menteri
# perikanan : ikan
# berkolaborasi : kolaborasi
# menyajikan : saji
# edukasi : edukasi
# bentuk : bentuk
# demand : demand
# terkait : kait
# sektor : sektor
# channel : channel
# neptunetv : neptunetv
# sepakat : sepakat
# dar : dar
# bosok : bosok
# menarik : tarik
# kolaborasinya : kolaborasi
# normatif : normatif
# kayaknya : kayak
# hooq : hooq
# laku : laku
# ditutup : tutup
# nemu : nemu
# pengganti : ganti
# indomy : indomy
# come : come
# our : our
# leader : leader
# using : using
# simcard : simcard
# want : want
# phone : phone
# number : number
# tonton : tonton
# perancang : ancang
# bangunan : bangun
# hompimpa : hompimpa
# animation : animation
# beb : beb
# aamiin : aamiin
# rep : rep
# happy : happy
# menjalankan : jalan
# mampus : mampus
# telp : telp
# isinya : isi
# sampah : sampah
# aing : aing
# acara : acara
# puasamu : puasa
# solaria : solaria
# tukarkan : tukar
# poinmu : poin
# dapatkan : dapat
# senilai : nila
# syarat : syarat
# ketentuan : tentu
# infoin : infoin
# telpon : telpon
# ngajak : ngajak
# gelud : gelud
# yaaaaa : yaaaaa
# gamasuk : gamasuk
# misqin : misqin
# nawarin : nawarin
# minjemin : minjemin
# duit : duit
# gratisan : gratis
# tselnya : tselnya
# ngecek : ngecek
# gaasikk : gaasikk
# wis : wis
# entek : entek
# seko : seko
# kampus : kampus
# durung : durung
# mlebu : mlebu
# ngesakne : ngesakne
# dadi : dadi
# tiri : tiri
# gamer : gamer
# target : target
# eksis : eks
# media : media
# sosial : sosial
# tiktok : tiktok
# thx : thx
# pembodohan : bodoh
# dibeli : beli
# dapetin : dapetin
# samsung : samsung
# ramadan : ramadan
# cum : cum
# tin : tin
# hdh : hdh
# dominoqq : dominoqq
# jutaan : juta
# bossku : bossku
# pkv : pkv
# games : games
# kontakk : kontakk
# worth : worth
# listrik : listrik
# padam : padam
# mempengaruhi : pengaruh
# dikasi : kasi
# yahoo : yahoo
# mail : mail
# apsi : apsi
# bngwt : bngwt
# menemani : tani
# mudik : mudik
# smua : smua
# babii : babi
# kenwpa : kenwpa
# ajgggg : ajgggg
# bertumbuk : tumbuk
# setia : setia
# disedot : sedot
# diapa : apa
# kecuali : kecuali
# kesesot : kesesot
# hmmmmm : hmmmmm
# toko : toko
# bangett : bangett
# lemotnyaaa : lemotnyaaa
# darah : darah
# entertainment : entertainment
# keuntungannya : untung
# mengaktifkan : aktif
# keambil : ambil
# darurat : darurat
# kelewatan : lewat
# ikutan : ikut
# lucky : lucky
# draw : draw
# kemendikbud : kemendikbud
# gadget : gadget
# nikmatin : nikmatin
# huhuuu : huhuuu
# sunoo : sunoo
# eehh : eehh
# kgk : kgk
# apasih : apasih
# dmnya : dmnya
# teh : teh
# sekaliii : sekaliii
# twrjangkau : twrjangkau
# masyarakat : masyarakat
# request : request
# read : read
# leletnya : lelet
# meeting : meeting
# perbaikan : baik
# miminn : miminn
# balas : balas
# sayaa : sayaa
# urgent : urgent
# uee : uee
# sist : sist
# mid : mid
# motor : motor
# honda : honda
# beat : beat
# otr : otr
# menunggu : tunggu
# kontak : kontak
# pengambilan : ambil
# motornya : motor
# menjual : jual
# dealer : dealer
# ente : ente
# cok : cok
# gandeng : gandeng
# hwaa : hwaa
# bgtt : bgtt
# anjcc : anjcc
# package : package
# wtfff : wtfff
# grgr : grgr
# colab : colab
# arghhhhhhh : arghhhhhhh
# klau : klau
# amburadul : amburadul
# tod : tod
# benerin : benerin
# kajoran : kajoran
# kabupaten : kabupaten
# magelang : magelang
# bosen : bosen
# survei : survei
# nggk : nggk
# dama : dama
# oke : oke
# byu : byu
# apn : apn
# nyimak : nyimak
# dunk : dunk
# mengalami : alami
# kesulitan : sulit
# transaksi : transaksi
# ekstra : ekstra
# vaik : vaik
# aaa : aaa
# keterangan : terang
# yeay : yeay
# hbis : hbis
# ingatin : ingatin
# maen : maen
# eee : eee
# bolh : bolh
# yth : yth
# penjelasannya : jelas
# trmksh : trmksh
# bedahan : bedah
# tipe : tipe
# undian : undi
# buru : buru
# asmo : asmo
# klnlagi : klnlagi
# jt : jt
# share : share
# loc : loc
# ditarik : tarik
# sabar : sabar
# merambah : rambah
# dicari : cari
# mytsel : mytsel
# hadirkan : hadir
# dorong : dorong
# terciptanya : cipta
# maxstreambersama : maxstreambersama
# tyker : tyker
# point : point
# cakap : cakap
# kcp : kcp
# sayangnya : sayang
# kondisi : kondisi
# terdesak : desak
# jes : jes
# tertipu : tipu
# ipo : ipo
# indotelko : indotelko
# tergiur : giur
# keuntungan : untung
# wahh : wahh
# korban : korban
# sesuaikan : sesuai
# aceh : aceh
# ketidaknyamanannya : ketidaknyamanannya
# penggunaan : guna
# ruksyaaak : ruksyaaak
# masanya : masa
# takutnya : takut
# toling : toling
# zonk : zonk
# bisi : bis
# biasalah : biasa
# profider : profider
# jumawa : jumawa
# merata : rata
# bjb : bjb
# nelpon : nelpon
# susahnha : susahnha
# check : check
# also : also
# vipul : vipul
# dmn : dmn
# terbaik : baik
# ditempat : tempat
# un : un
# ty : ty
# joo : joo
# pesan : pesan
# private : private
# disebar : sebar
# sanggat : sanggat
# pengen : ken
# marah : marah
# jalan : jalan
# seharian : hari
# appsnya : appsnya
# connect : connect
# sertakan : serta
# sekian : sekian
# terimagaji : terimagaji
# satui : satu
# bumbu : bumbu
# kalimantan : kalimantan
# selagan : lagan
# pemeliharaan : pelihara
# mim : mim
# fasilitas : fasilitas
# daftarin : daftarin
# gasalah : gasalah
# affandi : affandi
# ajah : ajah
# konek : konek
# cocok : cocok
# piro : piro
# nggawe : nggawe
# karyawan : karyawan
# libur : libur
# tanggapan : tanggap
# pket : pket
# gigamax : gigamax
# fit : fit
# fess : fess
# sblmnya : sblmnya
# omg : omg
# gantian : ganti
# duaduanya : duaduanya
# latsar : latsar
# pemadaman : madam
# test : test
# kickboxing : kickboxing
# bollywood : bollywood
# favoritmu : favorit
# premier : premier
# gold : gold
# socmed : socmed
# ngelag : ngelag
# look : look
# its : its
# about : about
# quality : quality
# not : not
# quantity : quantity
# meed : meed
# aint : aint
# worthy : worthy
# like : like
# been : been
# more : more
# than : than
# month : month
# wtf : wtf
# pangkalan : pangkal
# kerinci : kerinci
# pelalawan : pelalawan
# riau : riau
# hancur : hancur
# kacau : kacau
# would : would
# recommend : recommend
# too : too
# anyone : anyone
# frienemy : frienemy
# cause : cause
# expensive : expensive
# hell : hell
# secondly : secondly
# suck : suck
# last : last
# shit : shit
# costumer : costumer
# samaan : sama
# jdoh : jdoh
# jim : jim
# temurun : turun
# pasca : pasca
# gamau : gamau
# terbayar : bayar
# tanggalannya : tanggal
# astaga : astaga
# budug : budug
# payah : payah
# kwkwkwkkwk : kwkwkwkkwk
# log : log
# innya : innya
# siaran : siar
# musti : musti
# belinya : beli
# still : still
# idont : idont
# promotion : promotion
# before : before
# some : some
# stupid : stupid
# een : een
# permahal : mahal
# tampilan : tampil
# macemnya : macemnya
# heyyyy : heyyyy
# andaa : andaa
# kenapasi : napas
# cikarang : cikarang
# kecepatannya : cepat
# jarang : jarang
# cobaan : coba
# dimaki : maki
# ntah : ntah
# berantah : antah
# monetary : monetary
# digabungin : digabungin
# apah : apah
# kasian : kasi
# kebuang : buang
# tekanan : tekan
# membaik : baik
# pekerjanya : kerja
# sombong : sombong
# kejahatan : jahat
# rakyat : rakyat
# waspada : waspada
# ancuur : ancuur
# fyi : fyi
# didaerah : daerah
# banguntapan : banguntapan
# bantul : bantul
# diy : diy
# jun : jun
# erfian : erfian
# help : help
# graphari : graphari
# terbaca : baca
# trnyta : trnyta
# hrs : hrs
# note : note
# tkt : tkt
# krjakan : krjakan
# drumah : drumah
# nmr : nmr
# gakbbisa : gakbbisa
# skali : skali
# mklum : mklum
# kentakng : kentakng
# klw : klw
# kmpung : kmpung
# gonta : gonta
# gnti : gnti
# posisi : posisi
# surabaya : surabaya
# notifikasi : notifikasi
# mitra : mitra
# gojek : gojek
# sedih : sedih
# bun : bun
# naiknya : naik
# ngisinya : ngisinya
# pasan : pas
# teu : teu
# rudet : rudet
# ieu : ieu
# netlix : netlix
# mengumumkan : umum
# kemitraan : mitra
# depannya : depan
# meresahkan : resah
# ancur : ancur
# anehnya : aneh
# kyknya : kyknya
# byk : byk
# lancarnya : lancar
# ngakak : ngakak
# wkwkwkkw : wkwkwkkw
# nanami : nanami
# gapai : gapai
# gaje : gaje
# walapun : walapun
# wlpun : wlpun
# ttp : ttp
# kuotanya : kuota
# egde : egde
# tree : tree
# sejatinya : sejati
# memback : memback
# lemah : lemah
# responsif : responsif
# iklannya : iklan
# wkwkwkkwk : wkwkwkkwk
# mencari : cari
# lokal : lokal
# ngentot : ngentot
# sopipei : sopipei
# fee : fee
# heuu : heuu
# amel : amel
# office : office
# pilihan : pilih
# lifestyle : lifestyle
# diperpanjang : panjang
# tersubscribe : tersubscribe
# kmrin : kmrin
# tanggapi : tanggap
# menawarkan : tawar
# pinjaman : pinjam
# gemuk : gemuk
# gaeesss : gaeesss
# jazakumullah : jazakumullah
# khoir : khoir
# latih : latih
# solo : solo
# keuangan : uang
# nerima : nerima
# berbeda : beda
# niat : niat
# setting : setting
# dilan : dil
# jadul : jadul
# rambut : rambut
# gaya : gaya
# pemerannya : per
# totalitas : totalitas
# lingkungan : lingkung
# kedapetan : kedapetan
# spanduk : spanduk
# mendukung : dukung
# penampilan : tampil
# cast : cast
# angkot : angkot
# betinggan : betinggan
# bayaran : bayar
# ion : ion
# casino : casino
# terjamin : jamin
# sadar : sadar
# paham : paham
# wahaii : wahai
# nyai : nyai
# diam : diam
# kisanak : kisanak
# dicuekin : dicuekin
# isa : isa
# diginiin : diginiin
# angsana : angsana
# kindly : kindly
# membuka : buka
# kesempatan : sempat
# mahasiswa : mahasiswa
# gelar : gelar
# sepunggur : punggur
# kusan : kus
# hilir : hilir
# gangguannya : ganggu
# brengsek : brengsek
# unlimitednya : unlimitednya
# manaaaaaaaaaa : manaaaaaaaaaa
# laahhh : laahhh
# sejuta : juta
# umat : umat
# kehilangan : hilang
# naaah : naaah
# dongg : dongg
# seyenggg : seyenggg
# brharap : brharap
# connection : connection
# sprti : sprti
# selasa : selasa
# ngajar : ngajar
# kelas : kelas
# robot : robot
# suaranya : suara
# andalkan : andal
# rumahan : rumah
# terfollow : terfollow
# society : society
# barengan : bareng
# pektan : pektan
# sndri : sndri
# netplik : netplik
# sepaket : paket
# mendapatkn : mendapatkn
# indih : indih
# me : me
# elek : elek
# saran : saran
# gituu : gituu
# notif : notif
# masukk : masukk
# sayang : sayang
# gopaynya : gopaynya
# pulsanya : pulsa
# huf : huf
# pergi : pergi
# pergilah : pergi
# widii : widi
# hehh : hehh
# signalnya : signalnya
# penuhhh : penuhhh
# jodoh : jodoh
# sebel : sebel
# tingkat : tingkat
# stok : stok
# tanyaaa : tanyaaa
# dikambing : kambing
# hitamkan : hitam
# imessage : imessage
# permasalahan : masalah
# saham : saham
# gim : gim
# wow : wow
# kta : kta
# euy : euy
# ngahambat : ngahambat
# pisan : pis
# pekerja : kerja
# berbasis : bas
# ganggu : ganggu
# work : work
# ngekost : ngekost
# loker : loker
# kost : kost
# bagusan : bagus
# sihhh : sihhh
# bgttttt : bgttttt
# relate : relate
# bole : bole
# trimksh : trimksh
# angkut : angkut
# towerna : towerna
# bal : bal
# tuman : tuman
# nomerku : nomerku
# bberapa : bberapa
# ngilang : ngilang
# cijotang : cijotang
# gamesnya : gamesnya
# legend : legend
# yach : yach
# padang : padang
# pariaman : pariaman
# gasan : gas
# gadapet : gadapet
# joon : joon
# iyaaah : iyaaah
# hahahha : hahahha
# pelayanan : layan
# ambil : ambil
# hikmahnya : hikmah
# pertanyaannya : tanya
# hapal : hapal
# adminnya : adminnya
# nakes : nakes
# gula : gula
# diabet : abet
# sob : sob
# legendary : legendary
# silang : silang
# rutin : rutin
# ngidupin : ngidupin
# termurah : murah
# ooredoo : ooredoo
# stres : stres
# ape : ape
# kebiasaan : biasa
# hedeh : hedeh
# maintennance : maintennance
# untung : untung
# pasword : pasword
# pasaran : pasar
# live : live
# nyesel : nyesel
# alihin : alihin
# askrl : askrl
# sidang : sidang
# skripsi : skripsi
# googlemeet : googlemeet
# prediksi : prediksi
# pools : pools
# stand : stand
# battle : battle
# buset : buset
# wifinya : wifinya
# dahlah : dah
# duet : duet
# mautttt : mautttt
# ampas : ampas
# puwokerto : puwokerto
# ngeganggu : ngeganggu
# mubazir : mubazir
# upgrade : upgrade
# tarif : tarif
# dipaksa : paksa
# mulus : mulus
# scudetto : scudetto
# jalur : jalur
# covid : covid
# indomie : indomie
# pecel : pecel
# lele : lele
# pngn : pngn
# cmn : cmn
# hop : hop
# chatime : chatime
# slalu : slalu
# ribut : ribut
# tmn : tmn
# repotin : repotin
# bisanya : bisa
# indihomo : indihomo
# alig : alig
# ngawur : ngawur
# paman : paman
# makannye : makannye
# beres : beres
# eek : eek
# mvp : mvp
# scudeto : scudeto
# dituker : dituker
# months : months
# ngikutin : ngikutin
# wandavision : wandavision
# grates : grates
# cosplay : cosplay
# jugaa : jugaa
# penjual : jual
# sesat : sesat
# memaksakan : paksa
# kehendak : hendak
# pms : pms
# remot : remot
# masala : masala
# monitoring : monitoring
# pango : pango
# raya : raya
# uleee : uleee
# kareng : kareng
# banda : banda
# hisss : hisss
# mengaum : aum
# lainya : lai
# gaes : gaes
# ntar : ntar
# takut : takut
# ketarik : tarik
# mamaku : mama
# china : china
# blok : blok
# firstmedia : firstmedia
# berenti : renti
# lancaaar : lancaaar
# jayaaa : jayaaa
# apresiasi : apresiasi
# barusan : barusan
# brp : brp
# hbs : hbs
# ceria : ceria
# ram : ram
# rangkul : rangkul
# malem : malem
# terussssss : terussssss
# andelin : andelin
# backup : backup
# connecting : connecting
# menerus : terus
# cennection : cennection
# ceritanya : cerita
# pemberitahuan : pemberitahuan
# eue : eue
# krena : krena
# voc : voc
# mainnya : main
# push : push
# mmr : mmr
# capek : capek
# klen : klen
# nchhcxyhvchhvhhhv : nchhcxyhvchhvhhhv
# donggku : donggku
# berkomitmen : komitmen
# mempercepat : cepat
# transformasi : transformasi
# perseroan : persero
# rasain : rasain
# ayas : ayas
# hokinya : hoki
# direfund : direfund
# gathering : gathering
# diundi : undi
# macbook : macbook
# air : air
# pemenangnya : menang
# helooo : helooo
# jaringanya : jaringanya
# mental : mental
# tkan : tkan
# perbaikannya : baik
# silahkan : silah
# diberikut : ikut
# wijaya : wijaya
# aruki : aruk
# diakses : akses
# penanganan : tangan
# teknisi : teknisi
# meningka : meningka
# muhammad : muhammad
# rudi : rudi
# pembangunan : bangun
# batam : batam
# eehhhh : eehhhh
# trossss : trossss
# mumpuni : mumpuni
# bandingkan : banding
# videonya : video
# tethering : tethering
# hei : hei
# pokonya : poko
# apliaksi : apliaksi
# vocher : vocher
# dcon : dcon
# lazada : lazada
# herman : herman
# manja : manja
# sialan : sial
# balikin : balikin
# bismillah : bismillah
# ready : ready
# seri : seri
# psht : psht
# dipikir : pikir
# borosnya : boros
# masya : masya
# gituan : gituan
# mbanking : mbanking
# asyuuuuu : asyuuuuu
# haduuu : haduuu
# gilak : gilak
# ganes : ganes
# ketularan : tular
# aheng : aheng
# nangor : nangor
# nyasar : nyasar
# pubgm : pubgm
# siput : siput
# santai : santai
# acs : acs
# robi : robi
# mencukupi : cukup
# registrasikan : registrasi
# mengirimkan : kirim
# format : format
# reg : reg
# spasi : spasi
# enjoy : enjoy
# life : life
# wwkkw : wwkkw
# minutes : minutes
# istigfar : istigfar
# bawaannya : bawa
# kekenyangan : kenyang
# sumur : sumur
# batu : batu
# iii : iii
# perumahan : rumah
# griya : griya
# agung : agung
# permai : permai
# jdi : jdi
# ssinyal : ssinyal
# welehhh : welehhh
# karo : karo
# pekok : kok
# jancokkk : jancokkk
# kaco : kaco
# bett : bett
# dehhh : dehhh
# keselll : keselll
# pengecekan : kece
# troy : troy
# page : page
# tengkyu : tengkyu
# grab : grab
# food : food
# hhehe : hhehe
# onlen : onlen
# ditelp : ditelp
# nebak : nebak
# diitung : diitung
# samaaa : samaaa
# dok : dok
# olga : olga
# naek : naek
# rank : rank
# terganggu : ganggu
# asku : asku
# dighosting : dighosting
# hda : hda
# srg : srg
# kamren : kamren
# prnh : prnh
# gbs : gbs
# tlp : tlp
# skli : skli
# menelphon : menelphon
# stlh : stlh
# katay : katay
# buku : buku
# dilirik : lirik
# opo : opo
# dekekne : dekekne
# jendela : jendela
# ben : ben
# sinyale : sinyale
# dat : dat
# hahahaaha : hahahaaha
# lmao : lmao
# dead : dead
# woyyyy : woyyyy
# ujan : ujan
# drop : drop
# esia : esia
# hidayah : hidayah
# blom : blom
# matiin : matiin
# patah : patah
# blackout : blackout
# mnt : mnt
# pkl : pkl
# ajaaaa : ajaaaa
# musolaaa : musolaaa
# melaporkan : lapor
# mencuri : curi
# gaadil : gaadil
# wait : wait
# sir : sir
# anw : anw
# must : must
# medaeng : medaeng
# muter : muter
# aya : aya
# eleuh : eleuh
# ceurik : ceurik
# jemput : jemput
# kosan : kosan
# wae : wae
# kuliahnya : kuliah
# beneer : beneer
# sent : sent
# ikuti : ikut
# univtelkom : univtelkom
# career : career
# coffee : coffee
# kenapaa : kenapaa
# sinting : sinting
# ngotak : ngotak
# santet : santet
# ndah : ndah
# berati : berat
# kesebar : sebar
# nat : nat
# mhl : mhl
# hdeh : hdeh
# merugikan : rugi
# allahuakbar : allahuakbar
# rebo : rebo
# cyiin : cyiin
# udahannya : udahannya
# cepetan : cepetan
# kinerja : kerja
# merealisasikan : realisasi
# terbaru : baru
# menyelenggarakan : selenggara
# unlimitid : unlimitid
# mobitekno : mobitekno
# sinergi : sinergi
# feed : feed
# whichone : whichone
# belongs : belongs
# banjaran : banjaran
# riki : riki
# kea : kea
# olo : olo
# samua : samua
# adaa : adaa
# kawasan : kawasan
# menteng : menteng
# jakpus : jakpus
# monile : monile
# legends : legends
# lag : lag
# ditindaklanjuti : ditindaklanjuti
# kno : kno
# nnton : nnton
# ktnya : ktnya
# care : care
# yuuukkk : yuuukkk
# gorontalo : gorontalo
# balesan : balesan
# template : template
# bel : bel
# krtu : krtu
# bru : bru
# smpt : smpt
# dftrkn : dftrkn
# plsa : plsa
# tlpon : tlpon
# npa : npa
# jrngn : jrngn
# sbuk : sbuk
# mohn : mohn
# bntuan : bntuan
# struggle : struggle
# menggelar : gelar
# meet : meet
# greet : greet
# menghadirkan : hadir
# sosok : sosok
# bintang : bintang
# tamu : tamu
# della : della
# puspita : puspita
# syakir : syakir
# daulay : daulay
# syekh : syekh
# ahmad : ahmad
# jaber : jaber
# ummi : ummi
# pipik : pipik
# pemain : main
# surga : surga
# huhuhu : huhuhu
# dadah : dadah
# wilayah : wilayah
# oun : oun
# ...
# jungkooktsel : jungkooktsel
# jungkook : jungkook
# anggap : anggap
# jungkool : jungkool
# terdaftar : daftar
# uner : uner
# rekomendasi : rekomendasi
# ashh : ashh
# kartumu : kartu
# leweung : leweung
# bicara : bicara
# checkout : checkout
# pencerahan : cerah
# beragam : agam
# kekartu : kartu
# genshin : genshin
# ditolak : tolak
# ngelink : ngelink
# kebanyak : banyak
# dikuasai : asai
# bnyk : bnyk
# hijaudaun : hijaudaun
# sakit : sakit
# rindu : rindu
# ketik : ketik
# strlm : strlm
# membenci : benci
# kemeja : kemeja
# macem : macem
# gapernah : gapernah
# telat : telat
# statusnya : status
# temui : temu
# kick : kick
# langit : langit
# lelett : lelett
# gaib : gaib
# dikampung : kampung
# aktifnya : aktif
# kubutuhannya : butuh
# memuaskan : muas
# kemudahan : mudah
# hollywood : hollywood
# blockbusters : blockbusters
# kepri : kepri
# kerjaaaaaa : kerjaaaaaa
# bufering : bufering
# serang : serang
# banten : banten
# bngt : bngt
# koq : koq
# jelekkkk : jelekkkk
# tips : tips
# kebutuhanmu : butuh
# kosku : kosku
# mbps : mbps
# rbt : rbt
# deasy : deasy
# natalina : natalina
# filaa : filaa
# deasyofficials : deasyofficials
# fhani : fhani
# perhari : hari
# dimanapun : mana
# saudara : saudara
# sampeyan : sampeyan
# ganteng : ganteng
# serem : rem
# diatas : atas
# prov : prov
# looking : looking
# man : man
# mojokerto : mojokerto
# adakan : adakan
# training : training
# improve : improve
# youth : youth
# skill : skill
# jrg : jrg
# selenggarakan : selenggara
# kualitasnya : kualitas
# kepotongvpadahal : kepotongvpadahal
# ternyta : ternyta
# mengaktifinny : mengaktifinny
# mempan : mempan
# terpakai : pakai
# gaboleh : gaboleh
# dibatam : dibatam
# nelp : nelp
# followers : followers
# cobain : cobain
# kebutuhan : butuh
# merdeka : merdeka
# biaya : biaya
# ora : ora
# kui : kui
# mugo : mugo
# neh : neh
# ning : ning
# omah : omah
# jane : jane
# wasyu : wasyu
# nilai : nilai
# hiburan : hibur
# adakah : ada
# muraahhh : muraahhh
# sekenceng : kenceng
# tae : tae
# diprotes : protes
# mulyani : mulyani
# spamnya : spamnya
# dalamnya : dalam
# unlock : unlock
# menkominfo : menkominfo
# smartfen : smartfen
# menangkan : menang
# frekuensi : frekuensi
# tlkm : tlkm
# fren : fren
# berpahala : pahala
# hansyah : hansyah
# bilek : bilek
# seharga : harga
# learning : learning
# remek : rek
# pancen : pancen
# tok : tok
# teknis : teknis
# aktifasi : aktifasi
# daftarkan : daftar
# formulir : formulir
# wfh : wfh
# photo : photo
# sukanya : suka
# petak : petak
# umpet : umpet
# ngukur : ngukur
# hasilnya : hasil
# hahahaha : hahahaha
# blank : blank
# spot : spot
# pelajar : ajar
# dapeti : dapeti
# verifnya : verifnya
# kode : kode
# beberape : beberape
# ektra : ektra
# tertera : tera
# pajak : pajak
# kite : kite
# apply : apply
# nye : nye
# ajaib : ajaib
# mantaapp : mantaapp
# gtw : gtw
# jaemin : jaemin
# endors : endors
# mikir : mikir
# bangsa : bangsa
# ramah : ramah
# beradab : adab
# makinya : maki
# kendalanya : kendala
# sarankan : saran
# melepas : lepas
# pasangkan : pasang
# ayang : ayang
# nyebelin : nyebelin
# rawa : rawa
# bukti : bukti
# dipersulit : sulit
# berbelit : belit
# laksono : laksono
# alah : alah
# bisaa : bisaa
# alfamart : alfamart
# kpop : kpop
# jake : jake
# jodohku : jodoh
# enhypen : enhypen
# claim : claim
# investasi : investasi
# nangis : nang
# wifii : wifii
# sekomplek : sekomplek
# biznet : biznet
# tba : tba
# ngacooo : ngacooo
# wifiinya : wifiinya
# penghuni : huni
# twitnya : twitnya
# lurrr : lurrr
# penggemar : gemar
# rapi : rapi
# bgtttt : bgtttt
# disitu : situ
# salty : salty
# lewatkan : lewat
# kring : kring
# sahur : sahur
# ngabuburit : ngabuburit
# irit : irit
# kulo : kulo
# enggih : enggih
# sami : sami
# ditipu : tipu
# diarahinnya : diarahinnya
# ubah : ubah
# cakep : cakep
# mon : mon
# dibilang : bilang
# modemnya : modem
# fungsi : fungsi
# pokoknya : pokok
# nyiasatin : nyiasatin
# idonesia : idonesia
# gaih : gaih
# veli : veli
# pernahnya : pernah
# diem : diem
# gabut : gabut
# kepikiran : pikir
# manjat : manjat
# gasengaja : gasengaja
# ketutup : tutup
# assalamu : assalamu
# alaikum : alaikum
# unstable : unstable
# laahh : laahh
# pulau : pulau
# nias : nias
# gunungsitoli : gunungsitoli
# puncak : puncak
# rri : rri
# rebu : rebu
# hebat : hebat
# berpuasa : puasa
# ramen : ramen
# lovers : lovers
# dekorasi : dekorasi
# ramenations : ramenations
# palembang : palembang
# veteran : veteran
# seberang : seberang
# soma : soma
# deretan : deret
# sumatera : sumatera
# selatan : selatan
# kepana : pana
# siih : siih
# payment : payment
# progress : progress
# djdk : djdk
# case : case
# terulang : ulang
# tjhge : tjhge
# serpong : serpong
# cristian : cristian
# hooh : hooh
# boonk : boonk
# unsolicited : unsolicited
# ib : ib
# delete : delete
# kelarnya : kelar
# tegaskan : tegas
# hentikan : henti
# memgganggu : memgganggu
# speednya : speednya
# segitu : segitu
# dgr : dgr
# acc : acc
# paje : paje
# insyaallah : insyaallah
# abadi : abadi
# urus : urus
# hii : hii
# can : can
# ngelapak : ngelapak
# wika : wika
# complaint : complaint
# bertambah : tambah
# koneksina : koneksina
# goblog : goblog
# lakah : lakah
# tanggepin : tanggepin
# percaya : percaya
# hmhmhmhmhmhm : hmhmhmhmhmhm
# ngelewatin : ngelewatin
# pastiin : pastiin
# follow : follow
# ketinggaln : ketinggaln
# sesinya : sesi
# keamanannya : aman
# dokumen : dokumen
# ribet : ribet
# ngurusin : ngurusin
# belikan : belikan
# mafia : mafia
# ucapkan : ucap
# bla : bla
# permohonan : mohon
# dipikirkan : pikir
# indahnya : indah
# bercengkrama : bercengkrama
# billing : billing
# cycle : cycle
# penyedia : sedia
# youtuban : youtuban
# lho : lho
# closed : closed
# ceritanyaaa : ceritanyaaa
# digantung : gantung
# lamaaa : lamaaa
# nuhun : nuhun
# progres : progres
# permintaan : minta
# ordernya : order
# ngumpulin : ngumpulin
# cus : cus
# redmiqq : redmiqq
# tercepat : cepat
# mempermudah : mudah
# resiko : resiko
# mgkn : mgkn
# mrk : mrk
# profile : profile
# spt : spt
# rencananya : rencana
# standar : standar
# jelasss : jelasss
# jualan : jual
# finet : finet
# dikirimi : kirim
# instruksi : instruksi
# kelanjutannya : lanjut
# peduli : peduli
# pasien : pasien
# berjalan : jalan
# becus : becus
# jiakjhh : jiakjhh
# meninggalkan : tinggal
# satupun : satu
# liburrr : liburrr
# menempel : tempel
# saputrabayu : saputrabayu
# terkadang : terkadang
# fpt : fpt
# crnya : crnya
# screening : screening
# babiiiiiii : babiiiiiii
# starter : starter
# pack : pack
# sehabis : habis
# bulanan : bulan
# pengaktifan : aktif
# berhentinya : henti
# pembahasan : bahas
# disangkutpautkan : disangkutpautkan
# jurusan : jurus
# pelabuhan : labuh
# damnnn : damnnn
# sick : sick
# people : people
# sex : sex
# puas : puas
# kiboo : kiboo
# mastip : mastip
# take : take
# shope : shope
# gadis : gadis
# pecahkan : pecah
# rekor : rekor
# moba : moba
# roli : rol
# project : project
# jne : jne
# karuan : karuan
# dipedesaan : desa
# sia : sia
# memperbesar : besar
# dpet : dpet
# fine : fine
# diaktifkan : aktif
# tuku : tuku
# nanggung : nanggung
# daniel : daniel
# grafari : grafari
# okelah : oke
# bohong : bohong
# kampung : kampung
# dipkai : dipkai
# heuheu : heuheu
# banking : banking
# wooy : wooy
# jargonmu : jargon
# nusantara : nusantara
# mauk : mauk
# km : km
# sukadiri : sukadiri
# tangerang : tangerang
# konfirmasiinya : konfirmasi
# cantik : cantik
# tritnya : tritnya
# sugan : sugan
# pintar : pintar
# saha : saha
# tar : tar
# disisi : sisi
# ebanking : ebanking
# ooredo : ooredo
# low : low
# broadcast : broadcast
# goib : goib
# heboh : heboh
# serame : serame
# shame : shame
# atitude : atitude
# ngaktifin : ngaktifin
# amblas : amblas
# jelasinnya : jelasinnya
# parahh : parahh
# perbedaan : beda
# jackpot : jackpot
# triple : triple
# sakong : sakong
# berhutang : hutang
# budi : budi
# dinomer : dinomer
# mmg : mmg
# purwadi : purwadi
# sesertakan : serta
# teleponan : telepon
# pencet : pencet
# batal : batal
# kidding : kidding
# mang : mang
# koncoku : konco
# protes : protes
# nang : nang
# admine : admine
# semingguan : minggu
# pancet : pancet
# menunggumu : tunggu
# ngaplod : ngaplod
# rada : rada
# dipelosok : pelosok
# ngamprahhhhh : ngamprahhhhh
# gunung : gunung
# cantikqq : cantikqq
# refferal : refferal
# perpaduan : padu
# bangsyaaaat : bangsyaaaat
# baiklah : baik
# taek : taek
# internetmax : internetmax
# ketiga : tiga
# ojok : ojok
# bee : bee
# tetel : tetel
# marketing : marketing
# timor : timor
# leste : leste
# kang : kang
# heru : heru
# meniti : titi
# karir : karir
# diluar : luar
# kartuas : kartuas
# sdkgkan : sdkgkan
# sbnernya : sbnernya
# sehari : hari
# dijelasin : dijelasin
# tanda : tanda
# gangguang : gangguang
# deui : deui
# sylkstw : sylkstw
# senasib : nasib
# ngalamin : ngalamin
# latest : latest
# includes : includes
# flubot : flubot
# malware : malware
# meets : meets
# phishing : phishing
# lookout : lookout
# partners : partners
# deliver : deliver
# application : application
# security : security
# pascabayar : pascabayar
# berlanjut : lanjut
# persetujuan : tuju
# menggoblok : goblok
# pembatalan : batal
# prosedurnya : prosedur
# milu : milu
# laleuleus : laleuleus
# kie : kie
# jaringana : jaringana
# butuhnya : butuh
# ketuk : ketuk
# kay : kay
# {'hallo': 'hallo', 'min': 'min', 'cuitan': 'cuit', 'direspon': 'direspon', '': '', 'hmm': 'hmm', 'akur': 'akur', 'jaringan': 'jaring', 'harga': 'harga', 'paket': 'paket', 'nambah': 'nambah', 'mahal': 'mahal', 'service': 'service', 'nyedot': 'nyedot', 'nyedotin': 'nyedotin', 'pulsa': 'pulsa', 'ngebug': 'ngebug', 'kali': 'kali', 'aplikasi': 'aplikasi', 'telkomsel': 'telkomsel', 'yak': 'yak', 'kejadian': 'jadi', 'buka': 'buka', 'sisa': 'sisa', 'kepotong': 'potong', 'coba': 'coba', 'jelasin': 'jelasin', 'internet': 'internet', 'kb': 'kb', 'ngabisin': 'ngabisin', 'cobanya': 'coba', 'cepetnya': 'cepetnya', 'wechat': 'wechat', 'belom': 'bom', 'scan': 'scan', 'pelangiqq': 'pelangiqq', 'nikmati': 'nikmat', 'hot': 'hot', 'promo': 'promo', 'bonus': 'bonus', 'turnover': 'turnover', 'dibagikan': 'bagi', 'minggu': 'minggu', 'referral': 'referral', 'seumur': 'umur', 'hidup': 'hidup', 'whatssapp': 'whatssapp', 'facebook': 'facebook', 'menerima': 'terima', 'deposit': 'deposit', 'via': 'via', 'iyaa': 'iyaa', 'mesti': 'mesti', 'jam': 'jam', 'keramat': 'keramat', 'tetep': 'tetep', 'beli': 'beli', 'nomer': 'nomer', 'harian': 'hari', 'pagi': 'pagi', 'grapari': 'grapari', 'pahlawan': 'pahlawan', 'revolusi': 'revolusi', 'pondok': 'pondok', 'bambu': 'bambu', 'msh': 'msh', 'ber': 'ber', 'operasional': 'operasional', 'kah': 'kah', 'terdekat': 'dekat', 'jatiwaringin': 'jatiwaringin', 'dimana': 'mana', 'terima': 'terima', 'kasih': 'kasih', 'kemkominfo': 'kemkominfo', 'penghargaan': 'harga', 'rajin': 'rajin', 'hadiah': 'hadiah', 'netflix': 'netflix', 'indosat': 'indosat', 'iflix': 'iflix', 'cek': 'cek', 'tengkiyuu': 'tengkiyuu', 'tim': 'tim', 'flash': 'flash', 'murah': 'murah', 'ehe': 'ehe', 'klu': 'klu', 'iklan': 'iklan', 'opsel': 'opsel', 'sufah': 'sufah', 'lapor': 'lapor', 'dikirim': 'kirim', 'detelah': 'detelah', 'panggilan': 'panggil', 'bgmn': 'bgmn', 'koneksi': 'koneksi', 'subang': 'subang', 'jawa': 'jawa', 'barat': 'barat', 'butut': 'butut', 'disconect': 'disconect', 'parah': 'parah', 'udah': 'udah', 'restart': 'restart', 'mati': 'mati', 'mulu': 'mulu', 'yaman': 'yaman', 'hati': 'hati', 'open': 'open', 'convert': 'convert', 'rate': 'rate', 'smartfren': 'smartfren', 'transfer': 'transfer', 'judi': 'judi', 'penipuan': 'tipu', 'tindakan': 'tindak', 'sejenisnya': 'jenis', 'tukar': 'tukar', 'tsel': 'tsel', 'three': 'three', 'ewallet': 'ewallet', 'isat': 'isat', 'smf': 'smf', 'jago': 'jago', 'knp': 'knp', 'bandung': 'bandung', 'timur': 'timur', 'daerah': 'daerah', 'ujung': 'ujung', 'berung': 'berung', 'arcamanik': 'arcamanik', 'sinyal': 'sinyal', 'telkomselnya': 'telkomselnya', 'jelek': 'jelek', 'engga': 'engga', 'tolong': 'tolong', 'diperbaiki': 'baik', 'menghambat': 'hambat', 'aktivitas': 'aktivitas', 'uzumaki': 'uzumaki', 'nyari': 'nyari', 'referensi': 'referensi', 'nama': 'nama', 'anak': 'anak', 'nnti': 'nnti', 'sengaja': 'sengaja', 'satelit': 'satelit', 'salah': 'salah', 'satunya': 'satu', 'namain': 'namain', 'ayo': 'ayo', 'mendingan': 'mending', 'main': 'main', 'menang': 'menang', 'ngapain': 'ngapain', 'vcs': 'vcs', 'sewa': 'sewa', 'cari': 'cari', 'situs': 'situs', 'online': 'online', 'fair': 'fair', 'bot': 'bot', 'admin': 'admin', 'murni': 'murni', 'player': 'player', 'tersedia': 'sedia', 'whatsapp': 'whatsapp', 'nagaqq': 'nagaqq', 'link': 'link', 'alternatif': 'alternatif', 'tanduknaga': 'tanduknaga', 'com': 'com', 'kagak': 'kagak', 'aktif': 'aktif', 'nyaaaa': 'nyaaaa', 'hueeee': 'hueeee', 'kuota': 'kuota', 'dimanasihh': 'dimanasihh', 'gang': 'gang', 'haaa': 'haaa', 'pny': 'pny', 'debit': 'debit', 'kaa': 'kaa', 'bank': 'bank', 'gtu': 'gtu', 'mksdnyaa': 'mksdnyaa', 'ngeluhnya': 'ngeluhnya', 'bales': 'bales', 'cosplaynya': 'cosplaynya', 'bca': 'bca', 'kaka': 'kaka', 'unlimited': 'unlimited', 'twitter': 'twitter', 'tweet': 'tweet', 'pict': 'pict', 'pictnya': 'pictnya', 'loading': 'loading', 'tgl': 'tgl', 'apr': 'apr', 'top': 'top', 'mandiri': 'mandiri', 'virtual': 'virtual', 'account': 'account', 'ayah': 'ayah', 'status': 'status', 'pembayaran': 'bay ...
# ------------------------
# Pandas Apply:   0%|          | 0/1916 [00:00<?, ?it/s]
#                                                 content  \
# 0     @telkomsel hallo min, dm dan cuitan saya kenap...
# 1     @netflixid @telkomindonesia @telkomsel @indiho...
# 2     @telkomsel hallo min, kenapa jaringan aku x te...
# 3     @telkomsel harga paket nambah mahal, jaringan ...
# 4     masih aja lu nyedot nyedotin pulsa wahai @telk...
# ...                                                 ...
# 1995     telkomsel akhir-akhir iki sinyal e menggoblok.
# 1996                 @telkomsel  pagi kak, buka dm dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998   ai telkomsel milu puasa? laleuleus kie jaringana
# 1999  ❀ punya pulsa tri atau telkomsel, tapi butuhny...
#
#                                          cleaning_tweet  \
# 0      hallo min dan cuitan saya kenapa tidak direspon
# 1                                       hmm sudah akur
# 2              hallo min kenapa jaringan aku terus ini
# 3       harga paket nambah mahal jaringan service terus
# 4     masih aja nyedot nyedotin pulsa wahai ngebug k...
# ...                                                 ...
# 1995       telkomsel akhir akhir iki sinyal menggoblok
# 1996                                 pagi kak buka dong
# 1997  kalau mau pembatalan paket kartu halo prosedur...
# 1998       telkomsel milu puasa laleuleus kie jaringana
# 1999   punya pulsa tri atau telkomsel tapi butuhnya ...
#
#                                              tokenisasi  \
# 0     [hallo, min, dan, cuitan, saya, kenapa, tidak,...
# 1                                  [hmm, sudah, akur, ]
# 2     [hallo, min, kenapa, jaringan, aku, terus, ini, ]
# 3     [harga, paket, nambah, mahal, jaringan, servic...
# 4     [masih, aja, nyedot, nyedotin, pulsa, wahai, n...
# ...                                                 ...
# 1995  [telkomsel, akhir, akhir, iki, sinyal, menggob...
# 1996                            [pagi, kak, buka, dong]
# 1997  [kalau, mau, pembatalan, paket, kartu, halo, p...
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, punya, pulsa, tri, atau, telkomsel, tapi, b...
#
#                                                stopword  \
# 0                      [hallo, min, cuitan, direspon, ]
# 1                                         [hmm, akur, ]
# 2                              [hallo, min, jaringan, ]
# 3      [harga, paket, nambah, mahal, jaringan, service]
# 4     [nyedot, nyedotin, pulsa, ngebug, kali, aplika...
# ...                                                 ...
# 1995             [telkomsel, iki, sinyal, menggoblok, ]
# 1996                                  [pagi, kak, buka]
# 1997  [pembatalan, paket, kartu, halo, prosedurnya, ...
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, pulsa, tri, telkomsel, butuhnya, dana, ketu...
#
#                                                stemming
# 0                        [hallo, min, cuit, direspon, ]
# 1                                         [hmm, akur, ]
# 2                                [hallo, min, jaring, ]
# 3        [harga, paket, nambah, mahal, jaring, service]
# 4     [nyedot, nyedotin, pulsa, ngebug, kali, aplika...
# ...                                                 ...
# 1995                 [telkomsel, iki, sinyal, goblok, ]
# 1996                                  [pagi, kak, buka]
# 1997    [batal, paket, kartu, halo, prosedur, gimana, ]
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, pulsa, tri, telkomsel, butuh, dana, ketuk, ...
#
# [1916 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0                        [hallo, min, cuit, direspon, ]
# 1                                         [hmm, akur, ]
# 2                                [hallo, min, jaring, ]
# 3        [harga, paket, nambah, mahal, jaring, service]
# 4     [nyedot, nyedotin, pulsa, ngebug, kali, aplika...
# ...                                                 ...
# 1995                 [telkomsel, iki, sinyal, goblok, ]
# 1996                                  [pagi, kak, buka]
# 1997    [batal, paket, kartu, halo, prosedur, gimana, ]
# 1998  [, telkomsel, milu, puasa, laleuleus, kie, jar...
# 1999  [, pulsa, tri, telkomsel, butuh, dana, ketuk, ...
#
# [1916 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_4.xlsx')
