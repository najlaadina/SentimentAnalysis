# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     Aplikasi udah terupdate, udah direstart hape, ...
# 1     Halo @Telkomsel \nSaya cuma ngisi pulsa 100.00...
# 2                             @Telkomsel Grapari tambun
# 3                   @Telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn Hai, Kak Ki. Terkait GraPARI, bisa...
# ...                                                 ...
# 1995  Sementara itu, perusahaan Telkomsel akan difok...
# 1996  @Telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @Telkomsel Bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz Hai, Kak Pais. Maaf ya. Terkait ken...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 37

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     Aplikasi udah terupdate, udah direstart hape, ...
# 1     Halo @Telkomsel \nSaya cuma ngisi pulsa 100.00...
# 2                             @Telkomsel Grapari tambun
# 3                   @Telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn Hai, Kak Ki. Terkait GraPARI, bisa...
# ...                                                 ...
# 1995  Sementara itu, perusahaan Telkomsel akan difok...
# 1996  @Telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @Telkomsel Bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz Hai, Kak Pais. Maaf ya. Terkait ken...
#
# [1933 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     aplikasi udah terupdate, udah direstart hape, ...
# 1     halo @telkomsel \nsaya cuma ngisi pulsa 100.00...
# 2                             @telkomsel grapari tambun
# 3                   @telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn hai, kak ki. terkait grapari, bisa...
# ...                                                 ...
# 1995  sementara itu, perusahaan telkomsel akan difok...
# 1996  @telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @telkomsel bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz hai, kak pais. maaf ya. terkait ken...
#
# [1933 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     aplikasi udah terupdate, udah direstart hape, ...
# 1     halo @telkomsel \nsaya cuma ngisi pulsa 100.00...
# 2                             @telkomsel grapari tambun
# 3                   @telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn hai, kak ki. terkait grapari, bisa...
# ...                                                 ...
# 1995  sementara itu, perusahaan telkomsel akan difok...
# 1996  @telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @telkomsel bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz hai, kak pais. maaf ya. terkait ken...
#
#                                          cleaning_tweet
# 0     aplikasi udah terupdate udah direstart hape ud...
# 1     halo saya cuma ngisi pulsa     lewat banking k...
# 2                                        grapari tambun
# 3                                  lha signalnya tetep
# 4     hai kak terkait grapari bisa diinfokan grapari...
# ...                                                 ...
# 1995  sementara itu perusahaan telkomsel akan difoku...
# 1996  udah harian jaringan jelas main game delay uda...
# 1997                              bonusnya aktif doank
# 1998  babu main genshin pake telkomsel sekarang siny...
# 1999  hai kak pais maaf terkait kendala jaringan int...
#
# [1933 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     aplikasi udah terupdate, udah direstart hape, ...
# 1     halo @telkomsel \nsaya cuma ngisi pulsa 100.00...
# 2                             @telkomsel grapari tambun
# 3                   @telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn hai, kak ki. terkait grapari, bisa...
# ...                                                 ...
# 1995  sementara itu, perusahaan telkomsel akan difok...
# 1996  @telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @telkomsel bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz hai, kak pais. maaf ya. terkait ken...
#
#                                          cleaning_tweet  \
# 0     aplikasi udah terupdate udah direstart hape ud...
# 1     halo saya cuma ngisi pulsa     lewat banking k...
# 2                                        grapari tambun
# 3                                  lha signalnya tetep
# 4     hai kak terkait grapari bisa diinfokan grapari...
# ...                                                 ...
# 1995  sementara itu perusahaan telkomsel akan difoku...
# 1996  udah harian jaringan jelas main game delay uda...
# 1997                              bonusnya aktif doank
# 1998  babu main genshin pake telkomsel sekarang siny...
# 1999  hai kak pais maaf terkait kendala jaringan int...
#
#                                              tokenisasi
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, saya, cuma, ngisi, pulsa, lewat, bankin...
# 2                                     [grapari, tambun]
# 3                             [lha, signalnya, tetep, ]
# 4     [hai, kak, terkait, grapari, bisa, diinfokan, ...
# ...                                                 ...
# 1995  [sementara, itu, perusahaan, telkomsel, akan, ...
# 1996  [udah, harian, jaringan, jelas, main, game, de...
# 1997                         [bonusnya, aktif, doank, ]
# 1998  [babu, main, genshin, pake, telkomsel, sekaran...
# 1999  [hai, kak, pais, maaf, terkait, kendala, jarin...
#
# [1933 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     aplikasi udah terupdate, udah direstart hape, ...
# 1     halo @telkomsel \nsaya cuma ngisi pulsa 100.00...
# 2                             @telkomsel grapari tambun
# 3                   @telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn hai, kak ki. terkait grapari, bisa...
# ...                                                 ...
# 1995  sementara itu, perusahaan telkomsel akan difok...
# 1996  @telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @telkomsel bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz hai, kak pais. maaf ya. terkait ken...
#
#                                          cleaning_tweet  \
# 0     aplikasi udah terupdate udah direstart hape ud...
# 1     halo saya cuma ngisi pulsa     lewat banking k...
# 2                                        grapari tambun
# 3                                  lha signalnya tetep
# 4     hai kak terkait grapari bisa diinfokan grapari...
# ...                                                 ...
# 1995  sementara itu perusahaan telkomsel akan difoku...
# 1996  udah harian jaringan jelas main game delay uda...
# 1997                              bonusnya aktif doank
# 1998  babu main genshin pake telkomsel sekarang siny...
# 1999  hai kak pais maaf terkait kendala jaringan int...
#
#                                              tokenisasi  \
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, saya, cuma, ngisi, pulsa, lewat, bankin...
# 2                                     [grapari, tambun]
# 3                             [lha, signalnya, tetep, ]
# 4     [hai, kak, terkait, grapari, bisa, diinfokan, ...
# ...                                                 ...
# 1995  [sementara, itu, perusahaan, telkomsel, akan, ...
# 1996  [udah, harian, jaringan, jelas, main, game, de...
# 1997                         [bonusnya, aktif, doank, ]
# 1998  [babu, main, genshin, pake, telkomsel, sekaran...
# 1999  [hai, kak, pais, maaf, terkait, kendala, jarin...
#
#                                                stopword
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, ngisi, pulsa, banking, paket, internet,...
# 2                                     [grapari, tambun]
# 3                                  [signalnya, tetep, ]
# 4     [hai, kak, terkait, grapari, diinfokan, grapar...
# ...                                                 ...
# 1995  [perusahaan, telkomsel, difokuskan, layanan, b...
# 1996  [udah, harian, jaringan, main, game, delay, ud...
# 1997                         [bonusnya, aktif, doank, ]
# 1998  [babu, main, genshin, telkomsel, sinyalnya, ng...
# 1999  [hai, kak, pais, maaf, terkait, kendala, jarin...
#
# [1933 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3610
# ------------------------
# aplikasi : aplikasi
# udah : udah
# terupdate : terupdate
# direstart : direstart
# hape : hape
# clear : clear
# cache : cache
# teteeep : teteeep
# blank : blank
# muncul : muncul
# telkomsel : telkomsel
#  :
# halo : halo
# ngisi : ngisi
# pulsa : pulsa
# banking : banking
# paket : paket
# internet : internet
# otomatis : otomatis
# aktif : aktif
# isi : isi
# mengaktifkan : aktif
# engga : engga
# diskon : diskon
# hahaha : hahaha
# grapari : grapari
# tambun : tambun
# signalnya : signalnya
# tetep : tetep
# hai : hai
# kak : kak
# terkait : kait
# diinfokan : info
# kakak : kakak
# kunjungi : kunjung
# mimin : mimin
# bantu : bantu
# cek : cek
# jam : jam
# operasional : operasional
# tsb : tsb
# tks : tks
# risa : risa
# sabtu : sabtu
# buka : buka
# sabar : sabar
# atuh : atuh
# kuota : kuota
# gua : gua
# pinjem : pinjem
# rebu : rebu
# menteri : menteri
# bumn : bumn
# bentuk : bentuk
# telkom : telkom
# perombakan : ombak
# fokus : fokus
# business : business
# infrastruktur : infrastruktur
# data : data
# fiber : fiber
# optic : optic
# center : center
# cloud : cloud
# need : need
# drop : drop
# pricelist : pricelist
# masuk : masuk
# antrian : antri
# rekan : rekan
# meluncur : luncur
# makasih : makasih
# jul : jul
# template : template
# mulu : mulu
# heran : heran
# tunggu : tunggu
# dm : dm
# payah : payah
# maaf : maaf
# akses : akses
# lambat : lambat
# udh : udh
# coba : coba
# refresh : refresh
# jaringan : jaring
# offkan : offkan
# airplane : airplane
# mode : mode
# ttp : ttp
# yuk : yuk
# infokan : info
# kejadian : jadi
# lokasi : lokasi
# detail : detail
# berkendala : kendala
# via : via
# privasi : privasi
# terjaga : jaga
# ijud : ijud
# kendala : kendala
# dpt : dpt
# mytelkomsel : mytelkomsel
# pastikan : pasti
# koneksi : koneksi
# msh : msh
# capture : capture
# gagal : gagal
# dwika : dwika
# this : this
# provider : provider
# are : are
# ruin : ruin
# morning : morning
# ude : ude
# mahal : mahal
# ping : ping
# jumping : jumping
# halah : halah
# logo : logo
# doang : doang
# ganti : ganti
# perbaikan : baik
# sucks : sucks
# min : min
# pro : pro
# kosong : kosong
# ceritain : ceritain
# alami : alami
# cerita : cerita
# plis : plis
# beli : beli
# sekarangg : sekarangg
# linda : linda
# aktivasi : aktivasi
# voucher : voucher
# nomor : nomor
# serial : serial
# selamat : selamat
# pagi : pagi
# mohon : mohon
# bantuannya : bantu
# diisikan : isi
# perintah : perintah
# ketik : ketik
# kode : kode
# wilayah : wilayah
# tertera : tera
# kelas : kelas
# kartu : kartu
# pra : pra
# bayar : bayar
# digunain : digunain
# yaa : yaa
# rekening : rekening
# tabungan : tabung
# deposito : deposito
# rebahan : rebah
# rumah : rumah
# banget : banget
# pembukaan : buka
# rekeningnya : rekening
# redi : redi
# review : review
# lengkap : lengkap
# blogku : blog
# juara : juara
# ngecek : ngecek
# myim : myim
# giliran : gilir
# pakai : pakai
# stabil : stabil
# jaringannya : jaring
# terbaiklah : baik
# bener : bener
# enak : enak
# terkadang : terkadang
# gitu : gitu
# murah : murah
# terima : terima
# kasih : kasih
# indonesia : indonesia
# menunggu : tunggu
# aksi : aksi
# niat : niat
# operator : operator
# seluler : seluler
# diuntungkan : untung
# beraksi : aksi
# dipakai : pakai
# sms : sms
# penipuan : tipu
# kepotong : potong
# gara : gara
# lupa : lupa
# habis : habis
# kepake : kepake
# fitur : fitur
# lock : lock
# kaya : kaya
# punyanya : punya
# axis : axis
# nam : nam
# keluhan : keluh
# terpotong : potong
# infoin : infoin
# tanggal : tanggal
# lin : lin
# nie : nie
# oke : oke
# aplikasinya : aplikasi
# update : update
# interaksinya : interaksi
# dilanjut : lanjut
# solusi : solusi
# kecolongan : colong
# rb : rb
# ketiduran : tidur
# paagii : paagii
# semuaa : semuaa
# cici : cici
# open : open
# verif : verif
# januari : januari
# sehat : sehat
# create : create
# khusus : khusus
# semi : semi
# gmail : gmail
# tele : tele
# netflix : netflix
# whatsapp : whatsapp
# apps : apps
# sii : sii
# gabisa : gabisa
# log : log
# apk : apk
# nyaa : nyaa
# emg : emg
# gangguan : ganggu
# ratih : ratih
# info : info
# berhenti : henti
# langganan : langgan
# uri : uri
# adaaa : adaaa
# combo : combo
# harian : hari
# nonaktifkan : nonaktif
# gimana : gimana
# adi : adi
# app : app
# dibantu : bantu
# aman : aman
# jual : jual
# ngga : ngga
# orbit : orbit
# gb : gb
# wkwkwk : wkwkwk
# abdullah : abdullah
# wahhh : wahhh
# era : era
# jokowi : jokowi
# abdi : abdi
# negara : negara
# sejahtera : sejahtera
# gmana : gmana
# diangkat : angkat
# komisaris : komisaris
# saipul : saipul
# maafin : maafin
# langsung : langsung
# nge : nge
# kim : kim
# mlm : mlm
# nyampe : nyampe
# sampe : sampe
# terimakasih : terimakasih
# ian : ian
# god : god
# you : you
# guys : guys
# doing : doing
# well : well
# and : and
# have : have
# pleasant : pleasant
# day : day
# ahead : ahead
# your : your
# house : house
# just : just
# got : got
# home : home
# from : from
# work : work
# tartali : tartali
# aunya : aunya
# terbaru : baru
# apple : apple
# iphone : iphone
# sebisa : bisa
# allah : allah
# swt : swt
# isabella : isabella
# pertanyaannya : tanya
# dahlah : dah
# males : males
# apaa : apaa
# niiiih : niiiih
# gini : gin
# alamat : alamat
# beresin : resin
# check : check
# ambil : ambil
# bonus : bonus
# dibikin : bikin
# nyaman : nyaman
# restart : restart
# kelurahan : lurah
# kecamatan : camat
# kota : kota
# tgl : tgl
# gatau : gatau
# suka : suka
# lte : lte
# kakanya : kakanya
# sasha : sasha
# gileee : gileee
# dibuka : buka
# putih : putih
# kebiasaan : biasa
# lemot : lot
# kzllll : kzllll
# erick : erick
# thohir : thohir
# bermain : main
# segmen : segmen
# berbeda : beda
# pasar : pasar
# korporasi : korporasi
# consumer : consumer
# konsumen : konsumen
# yan : yan
# login : login
# thanks : thanks
# saran : saran
# harapan : harap
# upayakan : upaya
# kepuasan : puas
# pelanggan : langgan
# prioritas : prioritas
# okay : okay
# considering : considering
# paketnya : paket
# terjangkau : jangkau
# berasa : asa
# overpriced : overpriced
# justmyfrugal : justmyfrugal
# cents : cents
# fenny : fenny
# terblokir : blokir
# iya : iya
# mengalami : alami
# kemarin : kemarin
# kesedot : sedot
# padahl : padahl
# dibayar : bayar
# araya : araya
# penyesuaian : sesuai
# tarif : tarif
# salah : salah
# upaya : upaya
# menjaga : jaga
# kualitas : kualitas
# silakan : sila
# nominal : nominal
# nggak : nggak
# thx : thx
# merata : rata
# keterangan : terang
# dicek : cek
# willy : willy
# yayuk : yayuk
# pilihan : pilih
# pembayaran : bayar
# shopeepay : shopeepay
# berdomisili : domisili
# jabodetabek : jabodetabek
# bandung : bandung
# surabaya : surabaya
# klop : klop
# semoga : moga
# membantu : bantu
# waskito : waskito
# informasikan : informasi
# syarat : syarat
# pengajuan : aju
# pinjaman : pinjam
# berstatus : status
# warga : warga
# wni : wni
# berusia : usia
# prabayar : prabayar
# dynamic : dynamic
# lite : lite
# corporate : corporate
# driver : driver
# ojek : ojek
# online : online
# swadaya : swadaya
# bundlingmax : bundlingmax
# discount : discount
# saldo : saldo
# monetary : monetary
# pembelian : beli
# kecuali : kecuali
# mobile : mobile
# legen : legen
# quota : quota
# multimedia : multimedia
# utama : utama
# leo : leo
# mytelkomselnya : mytelkomselnya
# dicoba : coba
# pergijauh : pergijauh
# radue : radue
# paketan : paket
# ngechat : ngechat
# neng : neng
# hmmm : hmmm
# kau : kau
# berkeringat : keringat
# teriknya : terik
# matahari : matahari
# menyekolahkan : sekolah
# dikeluhkan : keluh
# pengguna : guna
# uninstal : uninstal
# instal : instal
# edy : edy
# produk : produk
# layanan : layan
# haloo : haloo
# membeli : beli
# hiburan : hibur
# fast : fast
# skrang : skrang
# wih : wih
# mntep : mntep
# signal : signal
# menanggapi : tanggap
# tungguin : tungguin
# bingung : bingung
# memilih : pilih
# situs : situs
# terbukti : bukti
# keamanan : aman
# kenyamanan : nyaman
# sahabatpoker : sahabatpoker
# jamin : jamin
# menerima : terima
# deposit : deposit
# contact : contact
# livechat : livechat
# spkmantap : spkmantap
# org : org
# memenuhi : penuh
# persyaratannya : syarat
# pinjam : pinjam
# respon : respon
# make : make
# sim : sim
# logikanya : logika
# main : main
# poker : poker
# dana : dana
# atm : atm
# astonpkv : astonpkv
# bandarpoker : bandarpoker
# terpercaya : percaya
# asia : asia
# melayani : layan
# rate : rate
# bersain : bersain
# proses : proses
# mudah : mudah
# cannedy : cannedy
# admin : admin
# recommends : recommends
# not : not
# post : post
# personal : personal
# mentions : mentions
# order : order
# avoid : avoid
# misuse : misuse
# irresponsible : irresponsible
# people : people
# let : let
# continue : continue
# the : the
# interaction : interaction
# waiting : waiting
# matsila : matsila
# village : village
# vhembe : vhembe
# district : district
# more : more
# top : top
# now : now
# sluggish : sluggish
# connection : connection
# for : for
# gaming : gaming
# damn : damn
# gerai : gerai
# cape : cape
# dinonaktifin : dinonaktifin
# nomer : nomer
# gampang : gampang
# sayang : sayang
# kel : kel
# kec : kec
# nmr : nmr
# ferdy : ferdy
# sinyal : sinyal
# blankspot : blankspot
# pindahkan : pindah
# manual : manual
# emang : emang
# gmna : gmna
# indihome : indihome
# jangn : jangn
# sampah : sampah
# entrance : entrance
# nope : nope
# daerah : daerah
# selatan : selatan
# tepatnya : tepat
# baleendah : baleendah
# arah : arah
# majalaya : majalaya
# sinyalnya : sinyal
# knp : knp
# siii : siii
# mati : mati
# total : total
# convert : convert
# trade : trade
# tukar : tukar
# cairin : cairin
# indosat : indosat
# isat : isat
# tsel : tsel
# wallet : wallet
# linkaja : linkaja
# ovo : ovo
# gopay : gopay
# bri : bri
# bni : bni
# bca : bca
# mandiri : mandiri
# neobank : neobank
# koin : koin
# shopee : shopee
# under : under
# butuh : butuh
# melewati : lewat
# tenggang : tenggang
# ketentuannya : tentu
# berbatas : batas
# karakter : karakter
# sumpah : sumpah
# gedek : gedek
# ngebantu : ngebantu
# itikad : itikad
# ditawarkan : tawar
# ngerugiin : ngerugiin
# kali : kali
# afraid : afraid
# beyond : beyond
# that : that
# fault : fault
# towers : towers
# few : few
# kilometres : kilometres
# away : away
# what : what
# asking : asking
# how : how
# can : can
# radius : radius
# increased : increased
# current : current
# tower : tower
# accommodate : accommodate
# bungeni : bungeni
# one : one
# majosi : majosi
# location : location
# sub : sub
# city : city
# other : other
# number : number
# which : which
# has : has
# same : same
# issue : issue
# ifcurrently : ifcurrently
# locationwhich : locationwhich
# hasthe : hasthe
# problem : problem
# please : please
# send : send
# longlat : longlat
# googlemap : googlemap
# accurate : accurate
# thank : thank
# amo : amo
# keep : keep
# privacy : privacy
# since : since
# when : when
# apologize : apologize
# inconvenience : inconvenience
# regarding : regarding
# unstable : unstable
# try : try
# network : network
# switching : switching
# automatic : automatic
# then : then
# switch : switch
# back : back
# auto : auto
# already : already
# inform : inform
# following : following
# through : through
# pren : pren
# tukuo : tukuo
# oelh : oelh
# disney : disney
# ulan : ulan
# ancur : ancur
# perasaan : asa
# ngeselin : ngeselin
# geh : geh
# kah : kah
# ajg : ajg
# bapuk : bapuk
# informasi : informasi
# reaktivasi : reaktivasi
# prepaid : prepaid
# malam : malam
# ngakak : ngakak
# beneran : beneran
# replied : replied
# dilabrak : labrak
# wkwkwkwk : wkwkwkwk
# hananta : hananta
# ahay : ahay
# litia : litia
# panggilan : panggil
# susahnya : susah
# ampun : ampun
# panamera : panamera
# perihal : perihal
# off : off
# service : service
# aciaa : aciaa
# diterima : terima
# telpon : telpon
# pdhal : pdhal
# jaringanmu : jaring
# bos : bos
# hallo : hallo
# mslh : mslh
# card : card
# tolonglah : tolong
# report : report
# nta : nta
# berhasil : hasil
# status : status
# suruh : suruh
# blm : blm
# iyakan : iya
# kayak : kayak
# sanggup : sanggup
# anak : anak
# kosan : kosan
# uang : uang
# bulanan : bulan
# pas : pas
# eky : eky
# notifikasi : notifikasi
# channel : channel
# chandz : chandz
# abis : abis
# notif : notif
# oaket : oaket
# sukses : sukses
# tidaknya : tidak
# tolong : tolong
# trims : trims
# salahbae : salahbae
# richard : richard
# yuwantoro : yuwantoro
# informasiin : informasiin
# device : device
# support : support
# rian : rian
# abraa : abraa
# bram : bram
# ulang : ulang
# garra : garra
# much : much
# pengen : ken
# tpi : tpi
# duit : duit
# kaga : kaga
# telfon : telfon
# jelasin : jelasin
# kirim : kirim
# kembalikan : kembali
# modem : modem
# kenpa : kenpa
# limpopo : limpopo
# called : called
# collins : collins
# chabane : chabane
# municipality : municipality
# struggling : struggling
# with : with
# years : years
# about : about
# getting : getting
# sorted : sorted
# difb : difb
# base : base
# bekas : bekas
# gogreen : gogreen
# tahan : tahan
# banting : banting
# usn : usn
# mulchar : mulchar
# all : all
# mastip : mastip
# herannn : herannn
# ngikut : ngikut
# sistem : sistem
# byu : byu
# yaudah : yaudah
# ngapa : ngapa
# ngapain : ngapain
# sadar : sadar
# connect : connect
# vincell : vincell
# november : november
# three : three
# smartfren : smartfren
# saleh : saleh
# harga : harga
# series : series
# website : website
# disitu : situ
# infonya : info
# raama : raama
# anwar : anwar
# bosen : bosen
# cok : cok
# seng : seng
# mek : mek
# karo : karo
# promo : promo
# mcd : mcd
# tok : tok
# klu : klu
# hmm : hmm
# firda : firda
# replynya : replynya
# orang : orang
# complain : complain
# nanges : nanges
# jele : jele
# abdul : abdul
# mengikuti : ikut
# program : program
# bundling : bundling
# konfirmasi : konfirmasi
# menyertakan : serta
# terbatas : batas
# berani : berani
# cicilan : cicil
# lunas : lunas
# dibuanglah : buang
# berubah : ubah
# menambah : tambah
# qris : qris
# pemesanan : mesan
# cari : cari
# wtb : wtb
# payment : payment
# lancar : lancar
# jaya : jaya
# hello : hello
# lia : lia
# being : being
# loyal : loyal
# using : using
# products : products
# our : our
# best : best
# satisfy : satisfy
# users : users
# don : don
# forget : forget
# wear : wear
# mask : mask
# outside : outside
# stay : stay
# safe : safe
# healthy : healthy
# billing : billing
# terlunasi : lunas
# berlaku : laku
# terdaftar : daftar
# perbankan : perban
# wajib : wajib
# digit : digit
# keluarga : keluarga
# membawa : bawa
# identitas : identitas
# paspor : paspor
# kta : kta
# sesuai : sesuai
# ktp : ktp
# penerima : terima
# kuasa : kuasa
# tambahan : tambah
# berhalangan : halang
# hadir : hadir
# diwakilkan : wakil
# melampirkan : lampir
# surat : surat
# bermaterai : bermaterai
# pemilik : milik
# asli : asli
# pemberi : beri
# memiliki : milik
# suket : suket
# dinas : dinas
# kependudukan : duduk
# pencatatan : catat
# sipil : sipil
# pemerintah : perintah
# lucas : lucas
# prihatin : prihatin
# hilangnya : hilang
# hilang : hilang
# terdekat : dekat
# ketentuan : tentu
# dimiliki : milik
# welcome : welcome
# like : like
# beserta : serta
# telkomselnya : telkomselnya
# mengklaim : klaim
# seputar : putar
# mantap : mantap
# bima : bima
# install : install
# diinfoin : diinfoin
# undia : undia
# taun : taun
# poin : poin
# maksudnya : maksud
# nyari : nyari
# kdg : kdg
# mesti : mesti
# genteng : genteng
# insyaallah : insyaallah
# difokuskan : fokus
# pik : pik
# dapet : dapet
# telkomsell : telkomsell
# samsung : samsung
# note : note
# ultra : ultra
# android : android
# invalid : invalid
# pemerataan : perata
# pendidikan : didik
# jawa : jawa
# ibukota : ibukota
# gembor : gembor
# adminnya : adminnya
# gercep : gercep
# lakukan : laku
# mei : mei
# bagus : bagus
# tdi : tdi
# karna : karna
# jelek : jelek
# hayang : hayang
# aing : aing
# lmn : lmn
# kitu : kitu
# mah : mah
# wkwkw : wkwkw
# anjing : anjing
# susah : susah
# tiktok : tiktok
# deh : deh
# sbl : sbl
# mencoba : coba
# caca : caca
# simcard : simcard
# favourite : favourite
# jaman : jaman
# adik : adik
# dirumah : rumah
# seka : seka
# syg : syg
# lampu : lampu
# xlku : xlku
# kalah : kalah
# tri : tri
# im : im
# ewallet : ewallet
# prem : prem
# non : non
# bank : bank
# proofs : proofs
# pinned : pinned
# jasa : jasa
# tuker : tuker
# fatya : fatya
# serius : serius
# ngomongin : ngomongin
# kadang : kadang
# sedih : sedih
# indra : indra
# santok : santok
# atika : atika
# jeo : jeo
# chaa : chaa
# marah : marah
# blom : blom
# lihat : lihat
# jenooo : jenooo
# lmfaooooooo : lmfaooooooo
# disuruh : suruh
# dibalas : balas
# toxic : toxic
# yaktul : yaktul
# heeee : heeee
# nek : nek
# wani : wani
# rene : rene
# yamor : yamor
# ipon : ipon
# ditambah : tambah
# inet : inet
# jatuhnya : jatuh
# mahalan : mahal
# ato : ato
# hanset : hanset
# gmn : gmn
# mekanisme : mekanisme
# dks : dks
# jjh : jjh
# tina : tina
# pricey : pricey
# astaghfirullah : astaghfirullah
# teaser : teaser
# jeno : jeno
# chmb : chmb
# join : join
# here : here
# friends : friends
# perbagus : bagus
# kabupaten : kabupaten
# sarolangun : sarolangun
# seno : seno
# penggunaan : guna
# pengembangan : kembang
# woi : woi
# anjig : anjig
# hih : hih
# benerin : benerin
# subsreb : subsreb
# hotstar : hotstar
# hangus : hangus
# astaga : astaga
# ainia : ainia
# forceclosed : forceclosed
# perdana : perdana
# trs : trs
# nomornya : nomor
# rugi : rugi
# staffnya : staffnya
# blg : blg
# ksl : ksl
# waaaah : waaaah
# sungchan : sungchan
# pls : pls
# gue : gue
# gbs : gbs
# liat : liat
# project : project
# hope : hope
# follow : follow
# rofiq : rofiq
# dibenerin : dibenerin
# user : user
# kek : kek
# asyu : asyu
# ngapasi : ngapasi
# emosi : emosi
# jeleekkk : jeleekkk
# poll : poll
# dirmh : dirmh
# gaada : gaada
# akun : akun
# tathering : tathering
# rin : rin
# benerr : benerr
# kartunya : kartu
# sultan : sultan
# aamiin : aamiin
# rezekinya : rezeki
# dipermudah : mudah
# riiizal : riiizal
# bingit : bingit
# rezeki : rezeki
# baca : baca
# ardiansyah : ardiansyah
# ketengan : keteng
# maling : maling
# penipu : tipu
# perubahan : ubah
# survei : survei
# dirikan : diri
# kyk : kyk
# mencret : mencret
# menbumn : menbumn
# beberkan : kan
# menilai : nilai
# industri : industri
# telekomunikasi : telekomunikasi
# telepon : telepon
# menopang : topang
# bisnis : bisnis
# perusahaan : usaha
# terbaik : baik
# desa : desa
# towernya : towernya
# terpakasa : terpakasa
# wiki : wiki
# bacanya : baca
# okee : okee
# blokir : blokir
# sinya : sinya
# lawas : lawas
# imei : imei
# kemenperin : kemenperin
# kena : kena
# say : say
# internetan : internetan
# digimanain : digimanain
# aldo : aldo
# manfaat : manfaat
# teknologi : teknologi
# simak : simak
# obrolan : obrol
# dirjen : dirjen
# sdppi : sdppi
# ismail : ismail
# video : video
# credit : credit
# youtube : youtube
# helmy : helmy
# yahya : yahya
# bicara : bicara
# fuck : fuck
# anjgg : anjgg
# dina : dina
# aduh : aduh
# long : long
# latitude : latitude
# google : google
# maps : maps
# mengecek : ecek
# akurat : akurat
# lemah : lemah
# kun : kun
# wetv : wetv
# premium : premium
# pkee : pkee
# tuhan : tuhan
# halooo : halooo
# izin : izin
# berkeluh : keluh
# kesah : kesah
# gerimis : gerimis
# pay : pay
# berselang : selang
# berjalan : jalan
# kunjung : kunjung
# terdebet : debet
# yaampun : yaampun
# kudunya : kudu
# gegera : gegera
# ilangnya : ilangnya
# hadehh : hadehh
# memperkuat : kuat
# ekosistem : ekosistem
# menjalin : jalin
# kerja : kerja
# tim : tim
# lokal : lokal
# esport : esport
# sulsel : sulsel
# takae : takae
# dance : dance
# nyanyi : nyanyi
# konten : konten
# ikutan : ikut
# berhadiah : hadiah
# puluhan : puluh
# juta : juta
# rupiah : rupiah
# klik : klik
# ikutannya : ikut
# des : des
# nyetel : nyetel
# yusupp : yusupp
# jga : jga
# baperin : baperin
# trus : trus
# baperinn : baperinn
# haaii : haaii
# buy : buy
# wts : wts
# minat : minat
# hnya : hnya
# buset : buset
# doank : doank
# trading : trading
# loss : loss
# jujur : jujur
# gpp : gpp
# nyusahin : nyusahin
# yaallah : yaallah
# chat : chat
# rahmat : rahmat
# eksisting : eksisting
# migrasi : migrasi
# pascabayar : pascabayar
# punten : punten
# internit : internit
# sektor : sektor
# kopo : kopo
# rada : rada
# goyss : goyss
# syafii : syafii
# hemat : hemat
# jt : jt
# menghemat : hemat
# butut : butut
# satunya : satu
# rentan : rentan
# dear : dear
# pesawat : pesawat
# upgrade : upgrade
# ris : ris
# balasan : balas
# kiamat : kiamat
# blangkejeren : blangkejeren
# gayoluwes : gayoluwes
# istighfar : istighfar
# dituker : dituker
# orbitnya : orbit
# trouble : trouble
# teroosssss : teroosssss
# anyinnkk : anyinnkk
# angin : angin
# dikit : dikit
# ilang : ilang
# tae : tae
# ajel : ajel
# ryan : ryan
# list : list
# berkenan : kenan
# pengertiannya : erti
# sahabat : sahabat
# sahabatku : sahabat
# pacarku : pacar
# gratis : gratis
# tira : tira
# ketidaksesuaian : ketidaksesuaian
# maxstream : maxstream
# gala : gala
# barusan : barusan
# regist : regist
# dipake : dipake
# mon : mon
# hei : hei
# daily : daily
# rekomendasi : rekomendasi
# sdgkan : sdgkan
# skrg : skrg
# peraturannya : atur
# ditulis : tulis
# diberitahu : diberitahu
# ksh : ksh
# juai : jua
# transfer : transfer
# simpati : simpati
# call : call
# ajaa : ajaa
# menghilang : hilang
# bertanggung : tanggung
# setia : setia
# burik : burik
# genshin : genshin
# impact : impact
# harganya : harga
# gamenya : gamenya
# menyebabkan : sebab
# kenapaa : kenapaa
# siiihhh : siiihhh
# diinbox : diinbox
# seminggu : minggu
# musim : musim
# hujan : hujan
# greget : greget
# ktl : ktl
# lelet : lelet
# njgg : njgg
# include : include
# hbo : hbo
# ngambil : ngambil
# sia : sia
# sapta : sapta
# zabo : zabo
# rusak : rusak
# ngotaxk : ngotaxk
# langit : langit
# turunkan : turun
# untukku : untuk
# canda : canda
# yahh : yahh
# jrngn : jrngn
# pindah : pindah
# steve : steve
# mas : mas
# wifi : wifi
# mbps : mbps
# lho : lho
# pesan : pesan
# hubungi : hubung
# chatting : chatting
# raih : raih
# dilacak : lacak
# perbesi : besi
# tigabinanga : tigabinanga
# buruk : buruk
# sediakan : sedia
# dongkol : dongkol
# rum : rum
# kartuhalo : kartuhalo
# perpanjang : panjang
# kurio : kurio
# dihp : dihp
# dinomor : nomor
# dipepanjang : panjang
# untung : untung
# ditempat : tempat
# legend : legend
# bbrp : bbrp
# pacarnya : pacar
# jaemin : jaemin
# reply : reply
# komplain : komplain
# berujung : ujung
# mending : mending
# speed : speed
# bye : bye
# autopilot : autopilot
# robot : robot
# veronika : veronika
# membingungkan : bingung
# mimpi : mimpi
# amin : amin
# pegang : pegang
# uta : uta
# nmor : nmor
# fix : fix
# bermasalah : masalah
# area : area
# pia : pia
# darurat : darurat
# uda : uda
# otak : otak
# unlimited : unlimited
# instagram : instagram
# trism : trism
# septa : septa
# priatna : priatna
# nyalain : nyalain
# matiin : matiin
# address : address
# ngelag : ngelag
# game : game
# ms : ms
# nonton : nonton
# viu : viu
# keburu : keburu
# gratisan : gratis
# dri : dri
# dilunasin : dilunasin
# teu : teu
# rumasa : rumasa
# minjem : minjem
# ath : ath
# kumaha : maha
# simon : simon
# stop : stop
# reg : reg
# kebeli : kebel
# anjeng : anjeng
# jugaa : jugaa
# elektronik : elektronik
# yukk : yukk
# aurelia : aurelia
# bolak : bolak
# tagihan : tagih
# livin : livin
# dapatkan : dapat
# bebas : bebas
# aksesnya : akses
# omg : omg
# rp : rp
# raf : raf
# ngaruh : ngaruh
# knapa : knapa
# hadeh : hadeh
# mahmud : mahmud
# minn : minn
# ngajak : ngajak
# berantem : antem
# menghubungi : hubung
# email : email
# imron : imron
# temen : temen
# pke : pke
# jkt : jkt
# kampung : kampung
# ohhh : ohhh
# brebes : brebes
# pasang : pasang
# tb : tb
# dll : dll
# smp : smp
# error : error
# keluhkan : keluh
# kpd : kpd
# pemilihan : pilih
# dinonaktifkan : nonaktif
# mendingan : mending
# lancaran : lancar
# okeh : okeh
# gan : gan
# buffering : buffering
# kecepatan : cepat
# normal : normal
# ola : ola
# cuman : cuman
# asaa : asaa
# aneh : aneh
# nominalnya : nominal
# genapn : genapn
# gaesss : gaesss
# belomm : belomm
# selangkah : selang
# maju : maju
# reviu : reviu
# pengalamanku : alam
# terdeteksi : deteksi
# fee : fee
# sey : sey
# pakkk : pakkk
# menarik : tarik
# mix : mix
# cobain : cobain
# murni : murni
# dalem : dalem
# apain : apain
# nyaut : nyaut
# mobil : mobil
# motor : motor
# gadget : gadget
# trendi : trendi
# undi : undi
# hepi : hepi
# kesempatan : sempat
# menangin : menangin
# honda : honda
# mobilio : mobilio
# adv : adv
# hadiah : hadiah
# ios : ios
# perangkat : perangkat
# tambora : tambora
# ama : ama
# mempengaruhi : pengaruh
# promonya : promonya
# maap : maap
# aduan : adu
# putus : putus
# diladenin : diladenin
# tetaaaap : tetaaaap
# syaratnya : syarat
# kirain : kirain
# datanya : data
# dijual : jual
# bocor : bocor
# apdet : apdet
# makek : makek
# keknya : kek
# sempet : sempet
# kitanya : kita
# kaki : kaki
# tips : tips
# agung : agung
# setujuuuuuuuu : setujuuuuuuuu
# database : database
# tinggal : tinggal
# balikin : balikin
# unit : unit
# blacklist : blacklist
# perhatikan : perhati
# dibawah : bawah
# daud : daud
# nohp : nohp
# pindahin : pindahin
# derry : derry
# versi : versi
# ditunggu : tunggu
# kesetiaannya : setia
# aka : aka
# cocoknya : cocok
# dengerin : dengerin
# playlist : playlist
# galau : galau
# mood : mood
# berantakan : beranta
# jeda : jeda
# iklan : iklan
# aktifin : aktifin
# joox : joox
# vip : vip
# puas : puas
# streaming : streaming
# anti : anti
# aries : aries
# detailnya : detail
# nyebelin : nyebelin
# bangettttttt : bangettttttt
# muak : muak
# dibayarkan : bayar
# kualiatas : kualiatas
# peoduk : peoduk
# bar : bar
# jogja : jogja
# lag : lag
# sedikitpun : sedikit
# beralih : alih
# membuang : buang
# bsa : bsa
# download : download
# arya : arya
# apoi : apo
# saloka : saloka
# kaleng : kaleng
# xixixi : xixixi
# apoooiii : apoooiii
# lebak : lebak
# gede : gede
# pulomerak : pulomerak
# cilegon : cilegon
# telp : telp
# reno : reno
# pakem : pakem
# anggar : anggar
# nama : nama
# ttl : ttl
# didaerah : daerah
# prov : prov
# banten : banten
# dewa : dewa
# paham : paham
# tehnologi : tehnologi
# dipandang : pandang
# sebelah : belah
# mata : mata
# jabingan : jabingan
# gada : gada
# yab : yab
# sisa : sisa
# iqbal : iqbal
# bosokk : bosokk
# wes : wes
# mene : mene
# drakor : drakor
# episode : episode
# sakti : sakti
# dapetin : dapetin
# seharian : hari
# kuat : kuat
# yaqin : yaqin
# jrgn : jrgn
# cba : cba
# seandainya : anda
# telat : telat
# rabbal : rabbal
# alamin : alamin
# oknum : oknum
# modus : modus
# korbannya : korban
# diarahkan : arah
# pin : pin
# rahasia : rahasia
# virtual : virtual
# ress : ress
# minnnn : minnnn
# urgent : urgent
# nihhhh : nihhhh
# listrik : listrik
# babi : babi
# yaaa : yaaa
# kompak : kompak
# luntur : luntur
# air : air
# meriah : riah
# istigfar : istigfar
# subhanallah : subhanallah
# astagfirullah : astagfirullah
# sekrang : sekrang
# ujan : ujan
# otomatisnya : otomatis
# interaksi : interaksi
# waduhh : waduhh
# keseringan : sering
# lost : lost
# bes : bes
# ngajuin : ngajuin
# misscall : misscall
# ayah : ayah
# naha : naha
# pulsaa : pulsaa
# darel : darel
# minimal : minimal
# solusikan : solusi
# jaem : jaem
# dicky : dicky
# mencegah : cegah
# tersedia : sedia
# sarankan : saran
# terkena : kena
# dasar : dasar
# noer : noer
# pny : pny
# pacar : pacar
# nunggu : nunggu
# masalahkan : masalah
# termakan : makan
# tumbenan : tumben
# adaan : ada
# film : film
# favoritmu : favorit
# cashback : cashback
# nobar : nobar
# asisten : asisten
# dibuatkan : buat
# laporan : lapor
# ratusan : ratus
# bohong : bohong
# mbak : mbak
# aaaaa : aaaaa
# pakenya : pakenya
# dipotongnya : potong
# balance : balance
# muraah : muraah
# legal : legal
# aleah : aleah
# ubah : ubah
# testimonial : testimonial
# jadikan : jadi
# koq : koq
# parah : parah
# malem : malem
# rekomendasiin : rekomendasiin
# tangi : tang
# turu : turu
# hpku : hpku
# tuling : tuling
# kiro : kiro
# teko : teko
# awkmu : awkmu
# tibake : tibake
# abiza : abiza
# ahmad : ahmad
# senang : senang
# berinteraksi : interaksi
# customer : customer
# digital : digital
# sungkan : sungkan
# mij : mij
# force : force
# dialami : alami
# disarankan : saran
# antisipasi : antisipasi
# ikuti : ikut
# panduan : pandu
# handphone : handphone
# diperpanjang : panjang
# dilema : dilema
# milih : milih
# pilih : pilih
# tag : tag
# temenmu : temenmu
# ngadepin : ngadepin
# starvision : starvision
# nomo : nomo
# mvp : mvp
# annisa : annisa
# april : april
# vidio : vidio
# gold : gold
# sushiroll : sushiroll
# myplay : myplay
# iflix : iflix
# waduw : waduw
# nyoba : nyoba
# aceh : aceh
# papua : papua
# kenceng : kenceng
# ibusalsa : ibusalsa
# dipisah : pisah
# mksh : mksh
# tawuran : tawur
# kupikir : pikir
# hpnya : hpnya
# cmiiw : cmiiw
# minhyung : minhyung
# membeberkan : beber
# games : games
# alamt : alamt
# dikasih : kasih
# almatnya : almatnya
# diproses : proses
# maen : maen
# ngpush : ngpush
# merah : merah
# spa : spa
# salim : salim
# penawaran : tawar
# yak : yak
# muter : muter
# muluk : muluk
# sunhan : sunhan
# jang : jang
# mantep : mantep
# saktinya : sakti
# ceban : ceban
# ngelek : ngelek
# tengok : tengok
# cita : cita
# citanya : cita
# magang : magang
# jink : jink
# contoh : contoh
# negeri : negeri
# kangguru : kangguru
# udeh : udeh
# faktanya : fakta
# ngeleg : ngeleg
# grmis : grmis
# jaa : jaa
# hrs : hrs
# ful : ful
# menantimu : nanti
# belajar : ajar
# perbesar : besar
# desember : desember
# balapan : balap
# kuotanya : kuota
# trusted : trusted
# murce : murce
# dtf : dtf
# alias : alias
# hiw : hiw
# beda : beda
# disesuaikan : sesuai
# skema : skema
# umur : umur
# kondisi : kondisi
# rviolas : rviolas
# basi : basi
# kekuatan : kuat
# gausah : gausah
# dibatesin : dibatesin
# bodo : bodo
# ngbedain : ngbedain
# wkt : wkt
# siang : siang
# percaya : percaya
# kwkwkwk : kwkwkwk
# pliss : pliss
# gamasuk : gamasuk
# lumayan : lumayan
# duitnya : duit
# kotak : kotak
# res : res
# riki : riki
# rhino : rhino
# tayang : tayang
# rencana : rencana
# animasi : animasi
# ditonton : tonton
# testi : testi
# subtitlenya : subtitlenya
# indosub : indosub
# eng : eng
# providernya : providernya
# maxtream : maxtream
# register : register
# ogah : ogah
# cuapek : cuapek
# etmin : etmin
# slowresp : slowresp
# brasa : brasa
# doi : doi
# makasiiiii : makasiiiii
# cepat : cepat
# imam : imam
# twiter : twiter
# kebanyakan : banyak
# cewek : cewek
# ngumbar : ngumbar
# aurat : aurat
# takut : takut
# sika : sika
# azab : azab
# kubur : kubur
# sehari : hari
# prof : prof
# kuy : kuy
# aldy : aldy
# uti : uti
# dede : dede
# kecdan : kecdan
# cayo : cayo
# curhat : curhat
# berupaya : upaya
# lads : lads
# agunk : agunk
# seizzy : seizzy
# kett : kett
# gajelas : gajelas
# siswanto : siswanto
# diaktifkan : aktif
# ruangan : ruang
# pakainya : pakai
# lanjutin : lanjutin
# ykntktnrsts : ykntktnrsts
# hah : hah
# mention : mention
# toko : toko
# busa : busa
# spam : spam
# mengganggu : ganggu
# korban : korban
# kerugian : rugi
# suhu : suhu
# rekomen : rekomen
# timbang : timbang
# fauzan : fauzan
# digimap : digimap
# erafone : erafone
# ibox : ibox
# hum : hum
# atu : atu
# hidupkankembali : hidupkankembali
# kesel : kesel
# tolonggg : tolonggg
# waah : waah
# tolongggggggggggggggg : tolongggggggggggggggg
# anjirrr : anjirrr
# bersyukur : syukur
# kunci : kunci
# zktiva : zktiva
# ngetwit : ngetwit
# bismillah : bismillah
# bundle : bundle
# hehee : hehee
# semangat : semangat
# rubah : rubah
# pusing : pusing
# adisha : adisha
# dihubungi : hubung
# laporkan : lapor
# format : format
# kejadiannya : jadi
# tindaklanjuti : tindaklanjuti
# silahkan : silah
# maapin : maapin
# linglung : linglung
# asueii : asueii
# informasinya : informasi
# memposting : memposting
# disalahgunakan : disalahgunakan
# dilanjutkan : lanjut
# bersainh : bersainh
# hny : hny
# bidang : bidang
# usaha : usaha
# laen : laen
# bergerak : gerak
# perkebunan : kebun
# ala : ala
# poliback : poliback
# ember : ember
# gori : gori
# pengusaha : usaha
# triluyun : triluyun
# angka : angka
# penghargaan : harga
# warung : warung
# hutang : hutang
# rokok : rokok
# beny : beny
# jember : jember
# soale : soale
# posisi : posisi
# jatim : jatim
# daritadi : daritadi
# kayk : kayk
# pelayanan : layan
# indosar : indosar
# dendam : dendam
# aul : aul
# in : in
# ganggu : ganggu
# dimatiin : dimatiin
# dikatain : dikatain
# kenal : kenal
# tbk : tbk
# usahanya : usaha
# selular : selular
# mengubah : ubah
# model : model
# ayo : ayo
# tebak : tebak
# dirut : dirut
# distrik : distrik
# muara : muara
# tami : tam
# slmat : slmat
# thn : thn
# keluarganya : keluarga
# brp : brp
# menit : menit
# selulernya : seluler
# tnp : tnp
# trputus : trputus
# periode : periode
# nuri : nuri
# lionsgate : lionsgate
# play : play
# segerakan : segera
# nungguin : nungguin
# perhitungan : hitung
# plan : plan
# smartphone : smartphone
# kontrak : kontrak
# aktivasinya : aktivasinya
# cicendo : cicendo
# pamoyanan : pamoyanan
# bandubg : bandubg
# prameswari : prameswari
# hati : hati
# potongan : potong
# ongkos : ongkos
# senilai : nila
# ribu : ribu
# buruan : buru
# incaran : incar
# pengiriman : kirim
# jne : jne
# nikmatin : nikmatin
# kirimnya : kirim
# bro : bro
# idaman : idam
# metode : metode
# kredit : kredit
# ribuan : ribu
# sleepcall : sleepcall
# cuan : cuan
# impian : impi
# akulaku : akulaku
# nikmati : nikmat
# spesial : spesial
# akuday : akuday
# out : out
# pesananmu : pesan
# ponsel : ponsel
# adam : adam
# hasilnya : hasil
# libi : libi
# gaperlu : gaperlu
# khawatir : khawatir
# dial : dial
# konser : konser
# army : army
# fancampun : fancampun
# bet : bet
# hidup : hidup
# bangun : bangun
# sayaaaa : sayaaaa
# willyy : willyy
# ketersediaan : sedia
# prima : prima
# gina : gina
# insfratruktur : insfratruktur
# serat : serat
# optik : optik
# ready : ready
# gift : gift
# mingguan : minggu
# unlimitedmax : unlimitedmax
# strawberry : strawberry
# feedbacknya : feedbacknya
# halim : halim
# arief : arief
# terhormat : hormat
# perbaiki : baik
# terpencil : pencil
# premiere : premiere
# penawarannya : tawar
# dimakan : makan
# apapun : apa
# ega : ega
# feedback : feedback
# jocelyn : jocelyn
# herman : herman
# premier : premier
# yahaha : yahaha
# ary : ary
# ika : ika
# jaga : jaga
# ntar : ntar
# ngadat : ngadat
# dedek : dedek
# kaze : kaze
# eko : eko
# ilham : ilham
# esim : esim
# sigap : sigap
# disconnect : disconnect
# mendungg : mendungg
# cuyyyy : cuyyyy
# busuk : busuk
# iniiii : iniiii
# ngomah : ngomah
# elek : elek
# metu : metu
# ndeso : ndeso
# ngebut : ngebut
# belom : bom
# lemotnya : lot
# ngalahin : ngalahin
# keong : keong
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# malang : malang
# letak : letak
# rumahku : rumah
# disembunyikan : sembunyi
# penasaran : penasaran
# nanya : nanya
# zul : zul
# dandi : dandi
# gangguankah : ganggu
# pleaselah : pleaselah
# down : down
# mentok : mentok
# kb : kb
# sklii : sklii
# pasha : pasha
# gamesmax : gamesmax
# miliki : milik
# uli : uli
# piye : piye
# combosakti : combosakti
# shalawat : shalawat
# wak : wak
# hatinya : hati
# laku : laku
# meniru : tiru
# mempelajari : ajar
# kecerdasan : cerdas
# buatan : buat
# menangkal : tangkal
# sungguh : sungguh
# menjengkelkan : jengkel
# monopoli : monopoli
# penyebabnya : sebab
# kontol : kontol
# heleh : heleh
# geografis : geografis
# disalahin : disalahin
# noooh : noooh
# berhubung : hubung
# menginfoin : menginfoin
# leluasa : leluasa
# haii : hai
# bsd : bsd
# akur : akur
# stok : stok
# central : central
# park : park
# mengunjungi : unjung
# mencari : cari
# kantong : kantong
# daftar : daftar
# trm : trm
# monmaaf : monmaaf
# salfok : salfok
# tulisan : tulis
# only : only
# mind : mind
# bawahnya : bawah
# simulasi : simulasi
# dlu : dlu
# kodong : kodong
# mba : mba
# lgi : lgi
# sbuk : sbuk
# terganggu : ganggu
# preorder : preorder
# dibilangnya : bilang
# barang : barang
# kadarshian : kadarshian
# jong : jong
# misi : misi
# mnt : mnt
# itung : itung
# annya : annya
# sblmnya : sblmnya
# bnyk : bnyk
# hubungin : hubungin
# terjga : terjga
# soree : soree
# tergantung : gantung
# berminat : minat
# bekasi : bekas
# internetnya : internetnya
# dibandingkan : banding
# jayapura : jayapura
# risiko : risiko
# dikotomi : dikotomi
# ooo : ooo
# jualan : jual
# wadduh : wadduh
# digugat : gugat
# trilyun : trilyun
# boomi : boomi
# ngerasa : ngerasa
# wow : wow
# laptopku : laptop
# bsod : bsod
# salahkan : salah
# mengeluh : keluh
# mely : mely
# kesetiaan : setia
# doain : doain
# kedepannya : depan
# musik : musik
# budget : budget
# twitter : twitter
# ariani : ariani
# hobi : hobi
# push : push
# rank : rank
# legends : legends
# bekali : bekal
# seru : seru
# ngaco : ngaco
# panjull : panjull
# gaguna : gaguna
# maunya : mau
# cung : cung
# ngacung : ngacung
# should : should
# resmi : resmi
# tercatat : catat
# bella : bella
# kurleb : kurleb
# aktifkan : aktif
# nextdev : nextdev
# perkuat : kuat
# potensi : potensi
# startup : startup
# irit : irit
# stalinorgel : stalinorgel
# udan : udan
# yodah : yodah
# jokul : jokul
# gelar : gelar
# kegiatan : giat
# sinergi : sinergi
# lbh : lbh
# pndh : pndh
# adus : adus
# disit : sit
# pelat : pelat
# intervensi : intervensi
# meluncurkan : luncur
# fund : fund
# didkg : didkg
# danai : dana
# start : start
# luncurkn : luncurkn
# presiden : presiden
# joko : joko
# widodo : widodo
# pertghn : pertghn
# gilang : gilang
# kacau : kacau
# vikaaa : vikaaa
# tumben : tumben
# daerahnya : daerah
# depok : depok
# lemooottt : lemooottt
# bgtttt : bgtttt
# even : even
# beh : beh
# eeq : eeq
# super : super
# kencangnya : kencang
# gapernah : gapernah
# alief : alief
# permatatel : permatatel
# verifikasi : verifikasi
# terpenuhi : penuh
# rubi : rubi
# ganguan : ganguan
# rela : rela
# krna : krna
# tinggalin : tinggalin
# zahra : zahra
# temukan : temu
# rab : rab
# bln : bln
# geratis : gerat
# mundur : mundur
# lowongan : lowong
# hadirr : hadirr
# trf : trf
# token : token
# pln : pln
# namanya : nama
# haechan : haechan
# opo : opo
# nyat : nyat
# sing : sing
# undlap : undlap
# undlup : undlup
# ramah : ramah
# sop : sop
# jeleeee : jeleeee
# emosii : emosi
# banjarmasinpost : banjarmasinpost
# dijamin : jamin
# ati : ati
# merangkul : rangkul
# nasionalis : nasionalis
# didukung : dukung
# mendanai : dana
# founder : founder
# public : public
# expo : expo
# exhibition : exhibition
# sales : sales
# webinar : webinar
# knpa : knpa
# inii : ini
# batu : batu
# luxe : luxe
# vidcall : vidcall
# testimoni : testimoni
# tweet : tweet
# telegram : telegram
# neo : neo
# sore : sore
# numpang : numpang
# pengaktifan : aktif
# kalu : kalu
# membutuhkan : butuh
# logout : logout
# trimakasih : trimakasih
# pleaseee : pleaseee
# cindy : cindy
# direaktivasi : direaktivasi
# tiada : tiada
# pendapatan : dapat
# jumbo : jumbo
# kuartal : kuartal
# iii : iii
# tembus : tembus
# triliun : triliun
# tulang : tulang
# punggung : punggung
# berasal : asal
# year : year
# yoy : yoy
# max : max
# tinder : tinder
# omah : omah
# angel : angel
# boros : boros
# cen : cen
# waspada : waspada
# setan : setan
# chek : chek
# diian : diian
# unreg : unreg
# rahood : rahood
# gpernah : gpernah
# pulsanya : pulsa
# berkurang : kurang
# sllu : sllu
# pemakaian : pakai
# gimanasikk : gimanasikk
# menfess : menfess
# cholidjaya : cholidjaya
# serinya : seri
# temenku : temenku
# stp : stp
# dipotong : potong
# kbiasaan : kbiasaan
# klau : klau
# nggih : nggih
# berlangganan : langgan
# batas : batas
# ditentukan : tentu
# indirumah : indirumah
# mengeluhkan : keluh
# ditolak : tolak
# mbok : mbok
# bolong : bolong
# heu : heu
# sodaraan : sodaraan
# transformasi : transformasi
# asn : asn
# ganjar : ganjar
# disiapkan : siap
# society : society
# siiiih : siiiih
# anam : anam
# lanjutkan : lanjut
# interkasi : interkasi
# pisahkan : pisah
# akademisi : akademisi
# rumit : rumit
# esta : esta
# itam : itam
# tumijajar : tumijajar
# daya : daya
# asri : asri
# tlg : tlg
# tindak : tindak
# gunain : gunain
# pengecekan : kece
# lena : lena
# dikirimkan : kirim
# lat : lat
# melaporkan : lapor
# pelaporan : lapor
# ditindaklanjuti : ditindaklanjuti
# trianggung : trianggung
# didm : didm
# rizky : rizky
# diperangkat : perangkat
# tawarkan : tawar
# barviq : barviq
# melulu : melulu
# modemnya : modem
# myorbit : myorbit
# official : official
# store : store
# kesini : kesini
# ngajakin : ngajakin
# rusuh : rusuh
# mengkesal : kesal
# kalung : kalung
# kucing : kucing
# rully : rully
# bett : bett
# sandezthira : sandezthira
# fisik : fisik
# full : full
# tselnya : tselnya
# unli : unli
# unlimax : unlimax
# bawang : bawang
# barat : barat
# tubaba : tubaba
# provinsi : provinsi
# lampung : lampung
# yutub : yutub
# ngeclose : ngeclose
# sistemnya : sistem
# bangke : bangke
# rozak : rozak
# sedati : sedat
# sidoarjo : sidoarjo
# timur : timur
# delay : delay
# suara : suara
# meeting : meeting
# new : new
# starter : starter
# pack : pack
# favorit : favorit
# superior : superior
# prosedur : prosedur
# kylie : kylie
# tanda : tanda
# tangan : tangan
# kertas : kertas
# npwp : npwp
# pajak : pajak
# perpajakan : paja
# persyaratan : syarat
# sbb : sbb
# rasain : rasain
# nabung : nabung
# vena : vena
# klaim : klaim
# lnjut : lnjut
# bindonya : bindonya
# diperbaiki : baik
# terklaim : klaim
# giftnya : giftnya
# gbnya : gbnya
# kaak : kaak
# nelpon : nelpon
# ingetin : ingetin
# zoom : zoom
# kuliah : kuliah
# laptop : laptop
# lek : lek
# jare : jare
# arek : arek
# tanggung : tanggung
# lucu : lucu
# capek : capek
# ribet : ribet
# smua : smua
# nyambung : nyambung
# mendaftarkan : daftar
# company : company
# vandesty : vandesty
# mengirim : kirim
# ngene : ngene
# mprop : mprop
# nov : nov
# hbs : hbs
# isya : isya
# wujug : wujug
# trz : trz
# ces : ces
# ngecese : ngecese
# mlaku : mlaku
# njur : njur
# warna : warna
# meh : meh
# dino : dino
# minggu : minggu
# tutup : tutup
# servis : servis
# ditingkatin : ditingkatin
# donk : donk
# spot : spot
# walalupun : walalupun
# jakarta : jakarta
# nelfon : nelfon
# nerima : nerima
# pdhl : pdhl
# dikonter : konter
# mbank : mbank
# beliin : beliin
# lobak : lobak
# penyalahgunaan : penyalahgunaan
# jagajaga : jagajaga
# scanning : scanning
# browsing : browsing
# perlindungan : lindung
# referral : referral
# rollingan : rollingan
# casino : casino
# sbo : sbo
# joker : joker
# dibagikan : bagi
# dimasukkan : masuk
# senin : senin
# kamis : kamis
# onoslot : onoslot
# ahen : ahen
# rbt : rbt
# deasy : deasy
# natalina : natalina
# first : first
# love : love
# filaa : filaa
# deasyofficials : deasyofficials
# cetak : cetak
# seragam : seragam
# kaos : kaos
# packaging : packaging
# promosi : promosi
# vendor : vendor
# merchandise : merchandise
# dian : dian
# bayarnya : bayar
# kia : kia
# beatles : beatles
# get : get
# billy : billy
# preston : preston
# seharga : harga
# byr : byr
# help : help
# adminnnn : adminnnn
# semalem : semalem
# diamonds : diamonds
# free : free
# fire : fire
# ekstra : ekstra
# pstt : pstt
# tercantum : cantum
# aryan : aryan
# recycle : recycle
# registrasi : registrasi
# terhapus : hapus
# tergantikan : ganti
# firza : firza
# ikurniawaaan : ikurniawaaan
# kemaleman : maleman
# ente : ente
# gojek : gojek
# kelogout : kelogout
# tbtb : tbtb
# retailnya : retail
# murahan : murah
# segi : segi
# risman : risman
# maksimal : maksimal
# menghidupkan : hidup
# digunankan : digunankan
# yoongi : yoongi
# kemana : mana
# bukti : bukti
# un : un
# usnya : usnya
# lune : lune
# bagusin : bagusin
# tika : tika
# ponselnya : ponselnya
# plislah : plislah
# verifikasinya : verifikasi
# ditungguin : ditungguin
# kpn : kpn
# disc : disc
# redeem : redeem
# digabung : gabung
# wawa : wawa
# keluhannya : keluh
# yudhi : yudhi
# pelunasan : lunas
# mengabaikannya : abai
# terkendala : kendala
# blh : blh
# kjdn : kjdn
# lunasin : lunasin
# tagih : tagih
# paksa : paksa
# selesai : selesai
# skin : skin
# polosan : polos
# tampil : tampil
# summertime : summertime
# stuff : stuff
# pubgm : pubgm
# bawa : bawa
# pulang : pulang
# itemnya : item
# tahukah : tahu
# jari : jari
# jemari : jemari
# assistant : assistant
# commerce : commerce
# widi : widi
# pemberitahuan : pemberitahuan
# ditagih : tagih
# nipu : nipu
# tolol : tolol
# oki : oki
# khasa : khasa
# nyedot : nyedot
# ngadatnya : ngadatnya
# keuntungan : untung
# beragam : agam
# ketambahan : tambah
# hadehhh : hadehhh
# una : una
# kka : kka
# bui : bui
# kaa : kaa
# makasiii : makasiii
# opa : opa
# cariin : cariin
# intiny : intiny
# berry : berry
# ajalah : aja
# baginda : baginda
# raja : raja
# diubah : ubah
# loop : loop
# uninstall : uninstall
# tingkatkan : tingkat
# umkm : umkm
# tanah : tanah
# merk : merk
# type : type
# cicilia : cicilia
# didapatkan : dapat
# dimatikan : mati
# diisi : isi
# pencurian : curi
# merugikan : rugi
# celular : celular
# kesalahan : salah
# tanggapi : tanggap
# mencantumkan : cantum
# bersinergi : sinergi
# dijadikan : jadi
# parter : parter
# vustomer : vustomer
# keren : keren
# tenang : tenang
# kab : kab
# han : han
# slalu : slalu
# iyaaahh : iyaaahh
# bdr : bdr
# ananda : ananda
# penanganan : tangan
# hadapi : hadap
# mengirimkan : kirim
# direct : direct
# message : message
# melakukannya : laku
# kesediaannya : sedia
# panggil : panggil
# reedem : reedem
# penukaran : tukar
# khusu : khusu
# sri : sri
# wid : wid
# menawarkan : tawar
# kebutuhan : butuh
# haduuh : haduuh
# sosmed : sosmed
# peluang : peluang
# bojong : bojong
# susukan : susu
# duren : duren
# bgs : bgs
# biru : biru
# harap : harap
# jangkauannya : jangkau
# perluas : luas
# paketannya : paket
# segede : gede
# bantuin : bantuin
# bgkkkkkai : bgkkkkkai
# balasannya : balas
# rombak : rombak
# barunya : baru
# badan : badan
# milik : milik
# sun : sun
# mendadak : dadak
# keponakan : keponakan
# didalam : dalam
# kolaborasi : kolaborasi
# sooltan : sooltan
# bermanfaat : manfaat
# penggerak : gerak
# harapannya : harap
# ampe : ampe
# endah : endah
# cocok : cocok
# apasi : apas
# aryadharma : aryadharma
# masukannya : masuk
# berusaha : usaha
# kritik : kritik
# voice : voice
# kemajuan : maju
# zaman : zaman
# perkembangan : kembang
# bertranformasi : bertranformasi
# transaksi : transaksi
# zize : zize
# bisi : bis
# may : may
# ngabisin : ngabisin
# segini : gin
# besok : besok
# loading : loading
# hadirkan : hadir
# catchplay : catchplay
# sebel : sebel
# mysooltan : mysooltan
# survive : survive
# pandemi : pandemi
# kolaborasinya : kolaborasi
# kirimkan : kirim
# inovasi : inovasi
# keluarkan : keluar
# samsek : samsek
# berlakunya : laku
# tokyo : tokyo
# jdi : jdi
# oncam : oncam
# item : item
# kulon : kulon
# hotspot : hotspot
# sulfian : sulfian
# kembangkan : kembang
# pasaran : pasar
# siti : siti
# urus : urus
# gagasan : gagas
# hebat : hebat
# link : link
# bio : bio
# ngurus : ngurus
# dipersulit : sulit
# lapor : lapor
# polisi : polisi
# ketinggalan : tinggal
# bts : bts
# bantuan : bantu
# solusinya : solusi
# otp : otp
# berkali : kali
# smsnya : smsnya
# bergabung : gabung
# member : member
# cug : cug
# pasangan : pasang
# suami : suami
# isteri : isteri
# kekasih : kasih
# ayub : ayub
# pang : pang
# lohhh : lohhh
# halaman : halaman
# ditemukan : temu
# ginana : gana
# kartuku : kartu
# titok : titok
# adl : adl
# dipilih : pilih
# dipasarkan : pasar
# scr : scr
# luas : luas
# brapa : brapa
# amaaat : amaaat
# bedua : bedua
# terobosan : terobos
# nich : nich
# resky : resky
# bangey : bangey
# permasalahan : masalah
# benarbenar : benarbenar
# puspito : puspito
# aris : aris
# eek : eek
# ntn : ntn
# kompertibel : kompertibel
# developer : developer
# tan : tan
# menghindari : hindar
# pribadi : pribadi
# melebihi : lebih
# rek : rek
# halonya : halo
# gandeng : gandeng
# maren : maren
# hadeuh : hadeuh
# robby : robby
# notelkomsel : notelkomsel
# desi : desi
# cus : cus
# berulang : ulang
# record : record
# tlp : tlp
# inbox : inbox
# kecdankota : kecdankota
# bonusan : bonus
# dipaketin : dipaketin
# didapet : didapet
# hudi : hudi
# bertanggungjawab : bertanggungjawab
# kuala : kuala
# tanjung : tanjung
# posting : posting
# tmn : tmn
# matlis : matlis
# kjadian : kjadian
# hijaudaun : hijaudaun
# sakit : sakit
# rindu : rindu
# strlm : strlm
# aje : aje
# trobosan : trobosan
# kemudahan : mudah
# dlm : dlm
# menjalankan : jalan
# emng : emng
# habisnya : habis
# ngeluarin : ngeluarin
# definitely : definitely
# without : without
# lagging : lagging
# kinda : kinda
# lovely : lovely
# visioner : visioner
# nihh : nihh
# metem : metem
# por : por
# dar : dar
# carregador : carregador
# usernya : usernya
# otpnya : otpnya
# modern : modern
# serba : serba
# bernama : nama
# mengembangkan : kembang
# mengatur : atur
# perputaran : putar
# roda : roda
# memperluas : luas
# pemasaran : pasar
# bangga : bangga
# persembahan : sembah
# pelanggam : langgam
# setianya : setia
# mempermudah : mudah
# penggunanya : guna
# berprofesi : profesi
# pedagang : dagang
# trobosam : trobosam
# proud : proud
# mengeluarkan : keluar
# sekeren : keren
# memudahkan : mudah
# mengelola : kelola
# dikeluarkan : keluar
# mewujudkan : wujud
# bangsa : bangsa
# inovasinya : inovasi
# terdepan : depan
# wahh : wahh
# kebingungan : bingung
# repot : repot
# mencatat : catat
# keuangan : uang
# ber : ber
# masyarakat : masyarakat
# berkembang : kembang
# ide : ide
# hadirnya : hadir
# dampak : dampak
# positif : positif
# umb : umb
# sibuk : sibuk
# ari : ari
# pertamina : pertamina
# optimis : optimis
# cabangnya : cabang
# bersaing : saing
# dunia : dunia
# global : global
# curi : curi
# pulsaku : pulsa
# kebanggaan : bangga
# ngiklan : ngiklan
# lestari : lestari
# ag : ag
# ever : ever
# kanan : kanan
# kiri : kiri
# tipikal : tipikal
# tuitmu : tuit
# kebaca : baca
# ngomong : ngomong
# tuiteran : tuiteran
# move : move
# eee : eee
# nyalaaaaa : nyalaaaaa
# wifiiiii : wifiiiii
# linknya : linknya
# aktifasi : aktifasi
# klpap : klpap
# judul : judul
# artist : artist
# raisya : raisya
# ramlah : ram
# senasib : nasib
# indosatnya : indosatnya
# commis : commis
# chara : chara
# mutia : mutia
# diuangkan : uang
# explore : explore
# bersahabat : sahabat
# siaangg : siaangg
# sulit : sulit
# penjelasan : jelas
# lelen : lelen
# sip : sip
# mom : mom
# humam : humam
# dinikmati : nikmat
# tipe : tipe
# usim : usim
# tercakup : cakup
# cakupan : cakup
# sihh : sihh
# slot : slot
# close : close
# tindakan : tindak
# sejenisnya : jenis
# zonauang : zonauang
# teman : teman
# dirasa : rasa
# kntl : kntl
# kayaknya : kayak
# miminnya : miminnya
# miskom : miskom
# diajukan : aju
# bertebaran : tebar
# but : but
# chose : chose
# moment : moment
# bertahan : tahan
# bertahun : tahun
# akutu : akutu
# balas : balas
# menjalani : jalan
# indah : indah
# ravel : ravel
# berhari : hari
# bgttt : bgttt
# yara : yara
# mengatasnamakan : mengatasnamakan
# mengabaikan : abai
# pemblokiran : blokir
# sosial : sosial
# media : media
# cdm : cdm
# byron : byron
# menikmati : nikmat
# aulia : aulia
# terlaksana : laksana
# peningkatan : tingkat
# jatuhe : jatuhe
# woy : woy
# kepler : kepler
# ngirim : ngirim
# bumi : bumi
# dani : dan
# memohon : mohon
# sangta : sangta
# dompet : dompet
# tranfer : tranfer
# nontonnnn : nontonnnn
# konwer : konwer
# mamah : mamah
# stella : stella
# permisi : permisi
# reddit : reddit
# betot : betot
# yee : yee
# bsia : bsia
# himbau : himbau
# membagikan : bagi
# laman : laman
# dhidayat : dhidayat
# yefta : yefta
# daria : daria
# hidayat : hidayat
# kakk : kakk
# brkndlasama : brkndlasama
# sdg : sdg
# mapsmimin : mapsmimin
# mayan : mayan
# simpatiku : simpati
# wpa : wpa
# kelebihan : lebih
# mendapakatkan : mendapakatkan
# sebulan : bulan
# komunitas : komunitas
# dita : dita
# pnjelasannya : pnjelasannya
# sweet : sweet
# permata : permata
# tata : tata
# musti : musti
# kacab : kacab
# nahan : nahan
# ahkirnya : ahkirnya
# kesabaran : sabar
# ampass : ampass
# krisna : krisna
# ibok : ibok
# alek : alek
# ngadi : ngadi
# ayu : ayu
# merubah : rubah
# malu : malu
# ihh : ihh
# teteh : teteh
# wfh : wfh
# produktifff : produktifff
# syamsuri : syamsuri
# arif : arif
# win : win
# lemott : lemott
# bgtt : bgtt
# kouta : kouta
# mini : mini
# midnight : midnight
# flash : flash
# ukm : ukm
# tqpi : tqpi
# ngehabisinnya : ngehabisinnya
# setting : setting
# vidionya : vidionya
# jalringan : jalringan
# perbulan : bulan
# kantor : kantor
# rakyat : rakyat
# eror : eror
# paketin : paketin
# elektrik : elektrik
# termurah : murah
# indotelko : indotelko
# iniko : iniko
# jangkauan : jangkau
# kapasitasnya : kapasitas
# tilep : tilep
# gapapa : gapapa
# helpp : helpp
# jarang : jarang
# iseng : iseng
# hehehe : hehehe
# nita : nita
# giveaway : giveaway
# ifo : ifo
# denganmu : dengan
# semalam : malam
# know : know
# mirdong : mirdong
# begitulaa : begitulaa
# nasib : nasib
# semarang : semarang
# lokalnya : lokal
# payahh : payahh
# ngeluh : ngeluh
# bang : bang
# cel : cel
# qrt : qrt
# tlkm : tlkm
# dikelola : kelola
# mikir : mikir
# dibiarin : dibiarin
# pemegang : pegang
# saham : saham
# ngalami : ngalami
# prnh : prnh
# ngalamin : ngalamin
# ginian : ginian
# benefit : benefit
# bulannya : bulan
# yakale : yakale
# gasi : gas
# bls : bls
# duanya : dua
# miskin : miskin
# gegara : gegara
# rel : rel
# nurcahyo : nurcahyo
# nsp : nsp
# tiket : tiket
# byk : byk
# ngantri : ngantri
# perhatian : perhati
# hancur : hancur
# direfund : direfund
# tanggapan : tanggap
# batam : batam
# tawaran : tawar
# pinjol : pinjol
# sisanya : sisa
# judi : judi
# dauph : dauph
# ne : ne
# telapak : telapak
# ...
# eve : eve
# sara : sara
# protes : protes
# pala : pala
# tanyak : tanyak
# dibagian : bagi
# mananya : mana
# panci : panci
# spaming : spaming
# spt : spt
# hilman : hilman
# yourbae : yourbae
# apn : apn
# gim : gim
# endingnya : endingnya
# outlet : outlet
# intip : intip
# price : price
# adristi : adristi
# ifhul : ifhul
# expired : expired
# gedung : gedung
# senen : senen
# helahhh : helahhh
# kelen : kelen
# dafuq : dafuq
# mendaftar : daftar
# thxs : thxs
# thoma : thoma
# offin : offin
# reconnecting : reconnecting
# dhea : dhea
# points : points
# nonprem : nonprem
# finet : finet
# seatalk : seatalk
# dibio : dibio
# sedia : sedia
# katalog : katalog
# duluan : duluan
# hanie : hanie
# yunus : yunus
# ragu : ragu
# sapa : sapa
# nemuin : nemuin
# akhirnyaaa : akhirnyaaa
# sekian : sekian
# purnama : purnama
# komplit : komplit
# hahahaha : hahahaha
# bun : bun
# gasemua : gasemua
# diperbarui : baru
# mbales : mbales
# pret : pret
# sono : sono
# olive : olive
# hanif : hanif
# channnel : channnel
# ibahrudi : ibahrudi
# bair : bair
# dibls : dibls
# kygni : kygni
# menginfokan : info
# thankyou : thankyou
# foto : foto
# mytsel : mytsel
# nder : nder
# mengaktivasi : mengaktivasi
# utang : utang
# ngutang : ngutang
# uae : uae
# nawidya : nawidya
# ditawarin : ditawarin
# tertutup : tutup
# dimana : mana
# terbuka : buka
# kalangan : kalang
# heykal : heykal
# nantikan : nanti
# terbarunya : baru
# point : point
# nemenin : nemenin
# class : class
# mutualan : mutualan
# followan : followan
# jfb : jfb
# beruang : beruang
# patoyoso : patoyoso
# perpanjangan : panjang
# ketidaknyamanan : ketidaknyamanan
# achmad : achmad
# stlh : stlh
# dpn : dpn
# pengalaman : alam
# maksud : maksud
# memperpanjang : panjang
# tenggan : tenggan
# yoga : yoga
# saking : saking
# kayanya : kaya
# timtim : timtim
# membanjiri : banjir
# dibeli : beli
# labuan : labu
# bajo : bajo
# mandalika : mandalika
# bali : bal
# diinvest : diinvest
# puasss : puasss
# adim : adim
# cool : cool
# ded : ded
# asing : asing
# bisanya : bisa
# pola : pola
# pikir : pikir
# jauuuh : jauuuh
# diatas : atas
# rakyatnya : rakyat
# mengerti : erti
# trobel : trobel
# ditindak : tindak
# lanjuti : lanjut
# ndara : ndara
# apalan : apalan
# pancasila : pancasila
# personalia : personalia
# pimpinan : pimpin
# karyawan : karyawan
# pusat : pusat
# mendem : mendem
# sosjsksjjsjsjs : sosjsksjjsjsjs
# unu : unu
# telkontoooooooool : telkontoooooooool
# prlayanan : prlayanan
# memek : memek
# bayaangin : bayaangin
# ter : ter
# dapetnya : dapetnya
# sambungan : sambung
# kontooool : kontooool
# dont : dont
# speak : speak
# indo : indo
# mygrapari : mygrapari
# situ : situ
# nontonnya : nontonnya
# real : real
# time : time
# tayangnya : tayang
# selasa : selasa
# gedeg : gedeg
# dika : dika
# masker : masker
# tar : tar
# inget : inget
# mendukung : dukung
# prasyarat : prasyarat
# hyper : hyper
# strategi : strategi
# dipersiapkan : siap
# cash : cash
# debit : debit
# jo : jo
# jenis : jenis
# lose : lose
# streak : streak
# bego : bego
# ngatasin : ngatasin
# masal : masal
# dirombak : rombak
# bacot : bacot
# noh : noh
# berkualitas : kualitas
# toff : toff
# stabilnya : stabil
# kerjaan : kerja
# cuaca : cuaca
# cerah : cerah
# selana : lana
# bole : bole
# ketentuans : ketentuans
# haru : haru
# adaa : adaa
# andre : andre
# kegunaannya : guna
# financial : financial
# planning : planning
# kenyamananmu : nyaman
# blu : blu
# phone : phone
# intercarier : intercarier
# flexi : flexi
# snowy : snowy
# tertunda : tunda
# praying : praying
# won : won
# suck : suck
# bad : bad
# slow : slow
# snail : snail
# once : once
# afford : afford
# miss : miss
# megtan : megtan
# tony : tony
# mafa : mafa
# cobak : cobak
# ninggalin : ninggalin
# telkomsat : telkomsat
# tombol : tombol
# repeat : repeat
# jebol : jebol
# reconnect : reconnect
# gunanya : guna
# kebuang : buang
# bundlingnya : bundlingnya
# dialihin : dialihin
# ngasih : ngasih
# rayuan : rayu
# tipuan : tipu
# tommy : tommy
# dikenakan : kena
# ditampilkan : tampil
# mengurangi : kurang
# haishhh : haishhh
# nambahin : nambahin
# beban : beban
# merinbeli : merinbeli
# penggunaa : penggunaa
# exsisting : exsisting
# teh : teh
# ieu : ieu
# existing : existing
# oce : oce
# emergency : emergency
# calls : calls
# miyagi : miyagi
# tenggangnya : tenggang
# hish : hish
# nais : nais
# ingfo : ingfo
# banyaknya : banyak
# iqro : iqro
# pemakaiannya : pakai
# ibanezblack : ibanezblack
# margaretha : margaretha
# triady : triady
# dandy : dandy
# tertarik : tarik
# lk : lk
# karakternya : karakter
# oo : oo
# collect : collect
# btw : btw
# sibukrtga : sibukrtga
# giaa : giaa
# achi : achi
# persis : persis
# gunung : gunung
# kemaren : kemaren
# jenius : jenius
# perumahan : rumah
# kedamaian : damai
# residence : residence
# tanggamus : tanggamus
# penjelasannya : jelas
# edward : edward
# tahap : tahap
# perkembangannya : kembang
# menjual : jual
# vcr : vcr
# memakai : pakai
# arti : arti
# rudi : rudi
# gima : gima
# keaktif : aktif
# gamau : gamau
# dikirim : kirim
# dermen : dermen
# sarah : sarah
# give : give
# sugeng : sugeng
# kei : kei
# larang : larang
# ambyar : ambyar
# cabang : cabang
# mmg : mmg
# lahir : lahir
# teknis : teknis
# sudaba : sudaba
# popup : popup
# bersedia : sedia
# pangrib : pangrib
# membayar : bayar
# feby : feby
# sorong : sorong
# distirk : distirk
# palputih : palputih
# gnya : gnya
# ip : ip
# apanya : apa
# tampilannya : tampil
# anjer : anjer
# intinya : inti
# mgkn : mgkn
# belaian : belai
# menonaktifkan : nonaktif
# layar : layar
# munculnya : muncul
# hapus : hapus
# gittu : gittu
# impianmu : impi
# terkini : kini
# oalah : oalah
# skrng : skrng
# applikasi : applikasi
# ulfi : ulfi
# wihh : wihh
# udahh : udahh
# setaun : taun
# pekan : pekan
# diaktifin : diaktifin
# getcontact : getcontact
# lamaku : lama
# kehapus : hapus
# system : system
# cantik : cantik
# iklannya : iklan
# merapat : rapat
# old : old
# trafford : trafford
# ralf : ralf
# rangnick : rangnick
# julian : juli
# nagelsmann : nagelsmann
# manchester : manchester
# united : united
# berita : berita
# selengkapnya : lengkap
# kemenangan : menang
# bayarkan : bayar
# obsesi : obsesi
# cristiano : cristiano
# ronaldo : ronaldo
# pensiun : pensiun
# trofi : trofi
# ballon : ballon
# lionel : lionel
# messi : messi
# klasemen : klasemen
# skor : skor
# liga : liga
# italia : italia
# juventus : juventus
# inter : inter
# perkasa : perkasa
# www : www
# bolamario : bolamario
# com : com
# ramadani : ramadan
# ngimpi : ngimpi
# character : character
# kabar : kabar
# ditelpon : telpon
# biaya : biaya
# dibales : dibales
# anyar : anyar
# yaaah : yaaah
# yawda : yawda
# biayanya : biaya
# marilaahhh : marilaahhh
# berantas : berantas
# korupsi : korupsi
# bibir : bibir
# senyum : senyum
# pandang : pandang
# buluu : buluu
# bertaruh : taruh
# jiwa : jiwa
# raga : raga
# nahhh : nahhh
# lelaki : lelaki
# kaget : kaget
# mentab : mentab
# rame : rame
# yey : yey
# does : does
# happening : happening
# abiss : abiss
# restock : restock
# belinya : beli
# den : den
# tersisa : sisa
# terpakai : pakai
# wuih : wuih
# bgmn : bgmn
# malaamm : malaamm
# ihwan : ihwan
# penwarannya : penwarannya
# tergiur : giur
# kirimin : kirimin
# marvin : marvin
# parts : parts
# nickname : nickname
# apin : apin
# adek : adek
# sinyalmu : sinyal
# tapiii : tapiii
# bosik : bosik
# bgtbgtbgt : bgtbgtbgt
# perbedaan : beda
# karen : karen
# emma : emma
# jodi : jodi
# kenzo : kenzo
# twt : twt
# privat : privat
# curcol : curcol
# sialan : sial
# skam : skam
# beres : beres
# lola : lola
# abe : abe
# iyaaaa : iyaaaa
# bangett : bangett
# jawabannya : jawab
# huhuuu : huhuuu
# superrr : superrr
# grab : grab
# alfamart : alfamart
# indomart : indomart
# lazada : lazada
# sicepat : sicepat
# edo : edo
# dicuri : curi
# dalamnya : dalam
# disneyhotstar : disneyhotstar
# gantenk : gantenk
# aira : aira
# potong : potong
# mengsedih : mengsedih
# diajak : ajak
# tokrev : tokrev
# ngerasain : ngerasain
# pembayan : pembayan
# kabel : kabel
# kenak : nak
# gigit : gigit
# tikus : tikus
# hehhe : hehhe
# iki : iki
# direspond : direspond
# bobrok : bobrok
# bogor : bogor
# bat : bat
# heraaannn : heraaannn
# erfan : erfan
# bejat : bejat
# memuaskan : muas
# nda : nda
# makasihh : makasihh
# bngt : bngt
# terkendali : kendali
# twitteran : twitteran
# scroll : scroll
# karamoy : karamoy
# puk : puk
# terkunci : kunci
# mobelejen : mobelejen
# publik : publik
# yaallahh : yaallahh
# gae : gae
# bosok : bosok
# pisan : pis
# cuk : cuk
# sinyale : sinyale
# terlock : terlock
# hub : hub
# plot : plot
# twist : twist
# latencynya : latencynya
# xixixix : xixixix
# nat : nat
# abay : abay
# pohoo : pohoo
# gblg : gblg
# ayoooo : ayoooo
# ngingetin : ngingetin
# digembok : gembok
# chacha : chacha
# nyesel : nyesel
# akk : akk
# ujung : ujung
# minskuu : minskuu
# daftarin : daftarin
# sekolah : sekolah
# okta : okta
# iyaa : iyaa
# sngt : sngt
# melecehkan : leceh
# septiawan : septiawan
# koneksinya : koneksi
# menyediakan : sedia
# posisikan : posisi
# agregator : agregator
# kreator : kreator
# fintech : fintech
# healthtech : healthtech
# edutech : edutech
# macem : macem
# bonusnya : bonus
# babu : babu
# char : char
# load : load
# damage : damage
# musuhnya : musuh
# oot : oot
# wahyu : wahyu
# pais : pais
# {'aplikasi': 'aplikasi', 'udah': 'udah', 'terupdate': 'terupdate', 'direstart': 'direstart', 'hape': 'hape', 'clear': 'clear', 'cache': 'cache', 'teteeep': 'teteeep', 'blank': 'blank', 'muncul': 'muncul', 'telkomsel': 'telkomsel', '': '', 'halo': 'halo', 'ngisi': 'ngisi', 'pulsa': 'pulsa', 'banking': 'banking', 'paket': 'paket', 'internet': 'internet', 'otomatis': 'otomatis', 'aktif': 'aktif', 'isi': 'isi', 'mengaktifkan': 'aktif', 'engga': 'engga', 'diskon': 'diskon', 'hahaha': 'hahaha', 'grapari': 'grapari', 'tambun': 'tambun', 'signalnya': 'signalnya', 'tetep': 'tetep', 'hai': 'hai', 'kak': 'kak', 'terkait': 'kait', 'diinfokan': 'info', 'kakak': 'kakak', 'kunjungi': 'kunjung', 'mimin': 'mimin', 'bantu': 'bantu', 'cek': 'cek', 'jam': 'jam', 'operasional': 'operasional', 'tsb': 'tsb', 'tks': 'tks', 'risa': 'risa', 'sabtu': 'sabtu', 'buka': 'buka', 'sabar': 'sabar', 'atuh': 'atuh', 'kuota': 'kuota', 'gua': 'gua', 'pinjem': 'pinjem', 'rebu': 'rebu', 'menteri': 'menteri', 'bumn': 'bumn', 'bentuk': 'bentuk', 'telkom': 'telkom', 'perombakan': 'ombak', 'fokus': 'fokus', 'business': 'business', 'infrastruktur': 'infrastruktur', 'data': 'data', 'fiber': 'fiber', 'optic': 'optic', 'center': 'center', 'cloud': 'cloud', 'need': 'need', 'drop': 'drop', 'pricelist': 'pricelist', 'masuk': 'masuk', 'antrian': 'antri', 'rekan': 'rekan', 'meluncur': 'luncur', 'makasih': 'makasih', 'jul': 'jul', 'template': 'template', 'mulu': 'mulu', 'heran': 'heran', 'tunggu': 'tunggu', 'dm': 'dm', 'payah': 'payah', 'maaf': 'maaf', 'akses': 'akses', 'lambat': 'lambat', 'udh': 'udh', 'coba': 'coba', 'refresh': 'refresh', 'jaringan': 'jaring', 'offkan': 'offkan', 'airplane': 'airplane', 'mode': 'mode', 'ttp': 'ttp', 'yuk': 'yuk', 'infokan': 'info', 'kejadian': 'jadi', 'lokasi': 'lokasi', 'detail': 'detail', 'berkendala': 'kendala', 'via': 'via', 'privasi': 'privasi', 'terjaga': 'jaga', 'ijud': 'ijud', 'kendala': 'kendala', 'dpt': 'dpt', 'mytelkomsel': 'mytelkomsel', 'pastikan': 'pasti', 'koneksi': 'koneksi', 'msh': 'msh', 'capture': 'capture', 'gagal': 'gagal', 'dwika': 'dwika', 'this': 'this', 'provider': 'provider', 'are': 'are', 'ruin': 'ruin', 'morning': 'morning', 'ude': 'ude', 'mahal': 'mahal', 'ping': 'ping', 'jumping': 'jumping', 'halah': 'halah', 'logo': 'logo', 'doang': 'doang', 'ganti': 'ganti', 'perbaikan': 'baik', 'sucks': 'sucks', 'min': 'min', 'pro': 'pro', 'kosong': 'kosong', 'ceritain': 'ceritain', 'alami': 'alami', 'cerita': 'cerita', 'plis': 'plis', 'beli': 'beli', 'sekarangg': 'sekarangg', 'linda': 'linda', 'aktivasi': 'aktivasi', 'voucher': 'voucher', 'nomor': 'nomor', 'serial': 'serial', 'selamat': 'selamat', 'pagi': 'pagi', 'mohon': 'mohon', 'bantuannya': 'bantu', 'diisikan': 'isi', 'perintah': 'perintah', 'ketik': 'ketik', 'kode': 'kode', 'wilayah': 'wilayah', 'tertera': 'tera', 'kelas': 'kelas', 'kartu': 'kartu', 'pra': 'pra', 'bayar': 'bayar', 'digunain': 'digunain', 'yaa': 'yaa', 'rekening': 'rekening', 'tabungan': 'tabung', 'deposito': 'deposito', 'rebahan': 'rebah', 'rumah': 'rumah', 'banget': 'banget', 'pembukaan': 'buka', 'rekeningnya': 'rekening', 'redi': 'redi', 'review': 'review', 'lengkap': 'lengkap', 'blogku': 'blog', 'juara': 'juara', 'ngecek': 'ngecek', 'myim': 'myim', 'giliran': 'gilir', 'pakai': 'pakai', 'stabil': 'stabil', 'jaringannya': 'jaring', 'terbaiklah': 'baik', 'bener': 'bener', 'enak': 'enak', 'terkadang': 'terkadang', 'gitu': 'gitu', 'murah': 'murah', 'terima': 'terima', 'kasih': 'kasih', 'indonesia': 'indonesia', 'menunggu': 'tunggu', 'aksi': 'aksi', 'niat': 'niat', 'operator': 'operator', 'seluler': 'seluler', 'diuntungkan': 'untung', 'beraksi': 'aksi', 'dipakai': 'pakai', 'sms': 'sms', 'penipuan': 'tipu', 'kepotong': 'potong', 'gara': 'gara', 'lupa': 'lupa', 'habis': 'habis', 'kepake': 'kepake', 'fitur': 'fitur', 'lock': 'lock', 'kaya': 'kaya', 'punyanya': 'punya', 'axis': 'axis', 'nam': 'nam', 'keluhan': 'keluh', 'terpotong': 'potong', 'infoin': 'infoin', 'tanggal': 'tanggal', 'lin': 'lin', 'nie': 'nie', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/1933 [00:00<?, ?it/s]
#                                                 content  \
# 0     aplikasi udah terupdate, udah direstart hape, ...
# 1     halo @telkomsel \nsaya cuma ngisi pulsa 100.00...
# 2                             @telkomsel grapari tambun
# 3                   @telkomsel lha tp signalnya tetep ❌
# 4     @kenapabunn hai, kak ki. terkait grapari, bisa...
# ...                                                 ...
# 1995  sementara itu, perusahaan telkomsel akan difok...
# 1996  @telkomsel udah 3 harian jaringan ga jelas, ma...
# 1997  @freddyarjuna @telkomsel bonusnya cm aktif dr ...
# 1998  babu! yg main genshin pake by.u / telkomsel se...
# 1999  @mhmdffaiz hai, kak pais. maaf ya. terkait ken...
#
#                                          cleaning_tweet  \
# 0     aplikasi udah terupdate udah direstart hape ud...
# 1     halo saya cuma ngisi pulsa     lewat banking k...
# 2                                        grapari tambun
# 3                                  lha signalnya tetep
# 4     hai kak terkait grapari bisa diinfokan grapari...
# ...                                                 ...
# 1995  sementara itu perusahaan telkomsel akan difoku...
# 1996  udah harian jaringan jelas main game delay uda...
# 1997                              bonusnya aktif doank
# 1998  babu main genshin pake telkomsel sekarang siny...
# 1999  hai kak pais maaf terkait kendala jaringan int...
#
#                                              tokenisasi  \
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, saya, cuma, ngisi, pulsa, lewat, bankin...
# 2                                     [grapari, tambun]
# 3                             [lha, signalnya, tetep, ]
# 4     [hai, kak, terkait, grapari, bisa, diinfokan, ...
# ...                                                 ...
# 1995  [sementara, itu, perusahaan, telkomsel, akan, ...
# 1996  [udah, harian, jaringan, jelas, main, game, de...
# 1997                         [bonusnya, aktif, doank, ]
# 1998  [babu, main, genshin, pake, telkomsel, sekaran...
# 1999  [hai, kak, pais, maaf, terkait, kendala, jarin...
#
#                                                stopword  \
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, ngisi, pulsa, banking, paket, internet,...
# 2                                     [grapari, tambun]
# 3                                  [signalnya, tetep, ]
# 4     [hai, kak, terkait, grapari, diinfokan, grapar...
# ...                                                 ...
# 1995  [perusahaan, telkomsel, difokuskan, layanan, b...
# 1996  [udah, harian, jaringan, main, game, delay, ud...
# 1997                         [bonusnya, aktif, doank, ]
# 1998  [babu, main, genshin, telkomsel, sinyalnya, ng...
# 1999  [hai, kak, pais, maaf, terkait, kendala, jarin...
#
#                                                stemming
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, ngisi, pulsa, banking, paket, internet,...
# 2                                     [grapari, tambun]
# 3                                  [signalnya, tetep, ]
# 4     [hai, kak, kait, grapari, info, grapari, kakak...
# ...                                                 ...
# 1995  [usaha, telkomsel, fokus, layan, business, con...
# 1996  [udah, hari, jaring, main, game, delay, udah, ...
# 1997                            [bonus, aktif, doank, ]
# 1998  [babu, main, genshin, telkomsel, sinyal, ngala...
# 1999  [hai, kak, pais, maaf, kait, kendala, jaring, ...
#
# [1933 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [aplikasi, udah, terupdate, udah, direstart, h...
# 1     [halo, ngisi, pulsa, banking, paket, internet,...
# 2                                     [grapari, tambun]
# 3                                  [signalnya, tetep, ]
# 4     [hai, kak, kait, grapari, info, grapari, kakak...
# ...                                                 ...
# 1995  [usaha, telkomsel, fokus, layan, business, con...
# 1996  [udah, hari, jaring, main, game, delay, udah, ...
# 1997                            [bonus, aktif, doank, ]
# 1998  [babu, main, genshin, telkomsel, sinyal, ngala...
# 1999  [hai, kak, pais, maaf, kait, kendala, jaring, ...
#
# [1933 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_11.xlsx')
