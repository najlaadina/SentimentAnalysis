# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @fajrisabti Hai Kak Fajri. Makasih ya buat dat...
# 1     @vemipelawi @Dennysiregar7 @PDemokrat @Telkoms...
# 2     @rizkylbs_ Pagi, Kak Rizky. Maaf ya jadi buat ...
# 3     Hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     Min @Telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @Telkomsel Boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  Cari uang tambahan dengan modal 20 ribu..??\nB...
# 1999  @robertp43247255 Hai, Kak Robert. Maaf ya mimi...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 67

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @fajrisabti Hai Kak Fajri. Makasih ya buat dat...
# 1     @vemipelawi @Dennysiregar7 @PDemokrat @Telkoms...
# 2     @rizkylbs_ Pagi, Kak Rizky. Maaf ya jadi buat ...
# 3     Hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     Min @Telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @Telkomsel Boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  Cari uang tambahan dengan modal 20 ribu..??\nB...
# 1999  @robertp43247255 Hai, Kak Robert. Maaf ya mimi...
#
# [1901 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @fajrisabti hai kak fajri. makasih ya buat dat...
# 1     @vemipelawi @dennysiregar7 @pdemokrat @telkoms...
# 2     @rizkylbs_ pagi, kak rizky. maaf ya jadi buat ...
# 3     hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     min @telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @telkomsel boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  cari uang tambahan dengan modal 20 ribu..??\nb...
# 1999  @robertp43247255 hai, kak robert. maaf ya mimi...
#
# [1901 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @fajrisabti hai kak fajri. makasih ya buat dat...
# 1     @vemipelawi @dennysiregar7 @pdemokrat @telkoms...
# 2     @rizkylbs_ pagi, kak rizky. maaf ya jadi buat ...
# 3     hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     min @telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @telkomsel boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  cari uang tambahan dengan modal 20 ribu..??\nb...
# 1999  @robertp43247255 hai, kak robert. maaf ya mimi...
#
#                                          cleaning_tweet
# 0     hai kak fajri makasih buat data datanya namun ...
# 1                             memang bgtu kenyataannya
# 2      pagi kak rizky maaf jadi buat kakak nyaman te...
# 3     hai kak aku jual pulsa tsel telkomsel axis isa...
# 4     min saya kok tidak ada paket giga net saya sud...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  boleh diwakilkan atau harus pemiliknya sendiri...
# 1997       telkomsel tolol amat buat aplikasi jelas anj
# 1998  cari uang tambahan dengan modal ribu bonus rol...
# 1999  hai kak robert maaf mimin infokan terkait kode...
#
# [1901 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @fajrisabti hai kak fajri. makasih ya buat dat...
# 1     @vemipelawi @dennysiregar7 @pdemokrat @telkoms...
# 2     @rizkylbs_ pagi, kak rizky. maaf ya jadi buat ...
# 3     hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     min @telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @telkomsel boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  cari uang tambahan dengan modal 20 ribu..??\nb...
# 1999  @robertp43247255 hai, kak robert. maaf ya mimi...
#
#                                          cleaning_tweet  \
# 0     hai kak fajri makasih buat data datanya namun ...
# 1                             memang bgtu kenyataannya
# 2      pagi kak rizky maaf jadi buat kakak nyaman te...
# 3     hai kak aku jual pulsa tsel telkomsel axis isa...
# 4     min saya kok tidak ada paket giga net saya sud...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  boleh diwakilkan atau harus pemiliknya sendiri...
# 1997       telkomsel tolol amat buat aplikasi jelas anj
# 1998  cari uang tambahan dengan modal ribu bonus rol...
# 1999  hai kak robert maaf mimin infokan terkait kode...
#
#                                              tokenisasi
# 0     [hai, kak, fajri, makasih, buat, data, datanya...
# 1                        [memang, bgtu, kenyataannya, ]
# 2     [, pagi, kak, rizky, maaf, jadi, buat, kakak, ...
# 3     [hai, kak, aku, jual, pulsa, tsel, telkomsel, ...
# 4     [min, saya, kok, tidak, ada, paket, giga, net,...
# ...                                                 ...
# 1995             [yaallah, mau, marah, sama, telkomsel]
# 1996  [boleh, diwakilkan, atau, harus, pemiliknya, s...
# 1997  [telkomsel, tolol, amat, buat, aplikasi, jelas...
# 1998  [cari, uang, tambahan, dengan, modal, ribu, bo...
# 1999  [hai, kak, robert, maaf, mimin, infokan, terka...
#
# [1901 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @fajrisabti hai kak fajri. makasih ya buat dat...
# 1     @vemipelawi @dennysiregar7 @pdemokrat @telkoms...
# 2     @rizkylbs_ pagi, kak rizky. maaf ya jadi buat ...
# 3     hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     min @telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @telkomsel boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  cari uang tambahan dengan modal 20 ribu..??\nb...
# 1999  @robertp43247255 hai, kak robert. maaf ya mimi...
#
#                                          cleaning_tweet  \
# 0     hai kak fajri makasih buat data datanya namun ...
# 1                             memang bgtu kenyataannya
# 2      pagi kak rizky maaf jadi buat kakak nyaman te...
# 3     hai kak aku jual pulsa tsel telkomsel axis isa...
# 4     min saya kok tidak ada paket giga net saya sud...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  boleh diwakilkan atau harus pemiliknya sendiri...
# 1997       telkomsel tolol amat buat aplikasi jelas anj
# 1998  cari uang tambahan dengan modal ribu bonus rol...
# 1999  hai kak robert maaf mimin infokan terkait kode...
#
#                                              tokenisasi  \
# 0     [hai, kak, fajri, makasih, buat, data, datanya...
# 1                        [memang, bgtu, kenyataannya, ]
# 2     [, pagi, kak, rizky, maaf, jadi, buat, kakak, ...
# 3     [hai, kak, aku, jual, pulsa, tsel, telkomsel, ...
# 4     [min, saya, kok, tidak, ada, paket, giga, net,...
# ...                                                 ...
# 1995             [yaallah, mau, marah, sama, telkomsel]
# 1996  [boleh, diwakilkan, atau, harus, pemiliknya, s...
# 1997  [telkomsel, tolol, amat, buat, aplikasi, jelas...
# 1998  [cari, uang, tambahan, dengan, modal, ribu, bo...
# 1999  [hai, kak, robert, maaf, mimin, infokan, terka...
#
#                                                stopword
# 0     [hai, kak, fajri, makasih, data, datanya, mimi...
# 1                                [bgtu, kenyataannya, ]
# 2     [, pagi, kak, rizky, maaf, kakak, nyaman, terk...
# 3     [hai, kak, jual, pulsa, tsel, telkomsel, axis,...
# 4     [min, paket, giga, net, tekan, muncul, paket, ...
# ...                                                 ...
# 1995                        [yaallah, marah, telkomsel]
# 1996   [diwakilkan, pemiliknya, min, dateng, grapari, ]
# 1997                       [telkomsel, tolol, aplikasi]
# 1998  [cari, uang, tambahan, modal, ribu, bonus, rol...
# 1999  [hai, kak, robert, maaf, mimin, infokan, terka...
#
# [1901 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3709
# ------------------------
# hai : hai
# kak : kak
# fajri : fajri
# makasih : makasih
# data : data
# datanya : data
# mimin : mimin
# saranin : saranin
# nggak : nggak
# mencantumkan : cantum
# pribadi : pribadi
# kolom : kolom
# tweet : tweet
# menghindari : hindar
# potensi : potensi
# penyalahgunaan : penyalahgunaan
# bertanggung : tanggung
# yuk : yuk
# sapa : sapa
# tks : tks
# flo : flo
# bgtu : bgtu
# kenyataannya : nyata
#  :
# pagi : pagi
# rizky : rizky
# maaf : maaf
# kakak : kakak
# nyaman : nyaman
# terkait : kait
# paket : paket
# giga : giga
# net : net
# tersedia : sedia
# akses : akses
# interaksinya : interaksi
# via : via
# infokan : info
# bantu : bantu
# cek : cek
# privasi : privasi
# terjaga : jaga
# ditunggu : tunggu
# lena : lena
# jual : jual
# pulsa : pulsa
# tsel : tsel
# telkomsel : telkomsel
# axis : axis
# isat : isat
# indosat : indosat
# harga : harga
# murah : murah
# banget : banget
# transfer : transfer
# menambah : tambah
# aktif : aktif
# elektrik : elektrik
# nambah : nambah
# followan : followan
# mutualan : mutualan
# like : like
# butuh : butuh
# need : need
# cheap : cheap
# min : min
# tekan : tekan
# muncul : muncul
# combo : combo
# extra : extra
# solusi : solusi
# gmana : gmana
# kos : kos
# buk : buk
# ida : ida
# mutiara : mutiara
# kasih : kasih
# ramadhani : ramadhani
# off : off
# hpbsaya : hpbsaya
# pakai : pakai
# nyangkut : nyangkut
# kirim : kirim
# emg : emg
# suka : suka
# pilih : pilih
# ngasi : ngasi
# promo : promo
# emang : emang
# mahal : mahal
# membangsatipun : bangsat
# nomor : nomor
# dapet : dapet
# ayahku : ayah
# hangus : hangus
# reaktivasi : reaktivasi
# syarat : syarat
# tenggang : tenggang
# infoin : infoin
# lokasi : lokasi
# detail : detail
# dibantu : bantu
# uli : uli
# layanannya : layan
# orbit : orbit
# telkom : telkom
# indihome : indihome
# kanibal : kanibal
# halo : halo
# diaktifkan : aktif
# mohon : mohon
# informasinya : informasi
# apapun : apa
# lakukan : laku
# terima : terima
# bener : bener
# emosi : emosi
# yaa : yaa
# guenya : gue
# tinggal : tinggal
# pedalaman : dalam
# pengguna : guna
# sentuh : sentuh
# ronny : ronny
# meluncur : luncur
# berkenan : kenan
# menunggu : tunggu
# interaksi : interaksi
# mimim : mimim
# kuota : kuota
# omg : omg
# nonton : nonton
# gb : gb
# youtube : youtube
# maxstream : maxstream
# facebook : facebook
# instagram : instagram
# whatsapp : whatsapp
# line : line
# games : games
# max : max
# music : music
# tiktok : tiktok
# mola : mola
# viu : viu
# disney : disney
# amazon : amazon
# vidio : vidio
# lionsgate : lionsgate
# tolong : tolong
# sinyal : sinyal
# jalur : jalur
# krl : krl
# rangkas : rangkas
# sampe : sampe
# maja : maja
# dibenerin : dibenerin
# mulu : mulu
# tobelly : tobelly
# sofia : sofia
# kendala : kendala
# aktivasi : aktivasi
# mytelkomsel : mytelkomsel
# udah : udah
# coba : coba
# restart : restart
# nohp : nohp
# kel : kel
# kec : kec
# kota : kota
# infonya : info
# selamat : selamat
# gagal : gagal
# transaksi : transaksi
# app : app
# veronika : veronika
# template : template
# tlp : tlp
# antri : antri
# urgent : urgent
# menjalani : jalan
# indah : indah
# berkendala : kendala
# dikirimkan : kirim
# titik : titik
# koordinat : koordinat
# google : google
# maps : maps
# pengecekan : kece
# akurat : akurat
# marsel : marsel
# tetep : tetep
# tanggal : tanggal
# kejadian : jadi
# minimal : minimal
# informasi : informasi
# kelurahan : lurah
# nama : nama
# jalan : jalan
# keluhan : keluh
# jaringan : jaring
# menyebabkan : sebab
# internet : internet
# lambat : lambat
# mencoba : coba
# refresh : refresh
# service : service
# menjual : jual
# star : star
# seharga : harga
# rp : rp
# dapatkan : dapat
# shopee : shopee
# sakti : sakti
# unlimited : unlimited
# ganggu : ganggu
# holit : holit
# namanya : nama
# open : open
# isi : isi
# ulang : ulang
# gatau : gatau
# lemot : lot
# kek : kek
# jadinyaa : jadinyaa
# signalnya : signalnya
# selin : lin
# kah : kah
# nikmati : nikmat
# potongan : potong
# spesial : spesial
# pilihan : pilih
# kode : kode
# kupon : kupon
# diskontsel : diskontsel
# sob : sob
# buruan : buru
# kuponnya : kupon
# convert : convert
# trade : trade
# tukar : tukar
# cairin : cairin
# saldo : saldo
# wallet : wallet
# linkaja : linkaja
# dana : dana
# ovo : ovo
# gopay : gopay
# shopeepay : shopeepay
# bri : bri
# bni : bni
# bca : bca
# mandiri : mandiri
# koin : koin
# under : under
# yovie : yovie
# rate : rate
# sussh : sussh
# kali : kali
# internetan : internetan
# kadang : kadang
# daerah : daerah
# kecamatan : camat
# ujung : ujung
# batu : batu
# kab : kab
# rokan : rok
# hulu : hulu
# provinsi : provinsi
# riau : riau
# iya : iya
# tunggu : tunggu
# jng : jng
# takutnya : takut
# pindah : pindah
# kelain : lain
# hati : hati
# manggil : manggil
# gue : gue
# apeeeeeh : apeeeeeh
# fastresp : fastresp
# pelit : pelit
# persiapan : siap
# pilpres : pilpres
# selamatkan : selamat
# partai : partai
# demokratnya : demokrat
# kalah : kalah
# demokrat : demokrat
# tandingan : tanding
# hartono : hartono
# list : list
# antrian : antri
# pengertiannya : erti
# iin : iin
# samaaa : samaaa
# gtu : gtu
# guaaa : guaaa
# charce : charce
# gangguan : ganggu
# nga : nga
# willy : willy
# lite : lite
# daily : daily
# check : check
# alam : alam
# aplikasi : aplikasi
# tgl : tgl
# ntar : ntar
# tayang : tayang
# langganan : langgan
# bersyukur : syukur
# dicoba : coba
# clear : clear
# cache : cache
# memiliki : milik
# diaktivasi : diaktivasi
# metode : metode
# sisa : sisa
# ribu : ribu
# sekian : sekian
# beli : beli
# munculnya : muncul
# mencukupi : cukup
# android : android
# ios : ios
# versi : versi
# keatas : atas
# sungkan : sungkan
# menghubungi : hubung
# sehat : sehat
# alfalaki : alfalaki
# farid : farid
# masukannya : masuk
# upayakan : upaya
# kepuasan : puas
# pelanggan : langgan
# prioritas : prioritas
# bonus : bonus
# balikin : balikin
# rb : rb
# donk : donk
# tri : tri
# smf : smf
# anindita : anindita
# senang : senang
# berinteraksi : interaksi
# layanan : layan
# customer : customer
# digital : digital
# prem : prem
# nonprem : nonprem
# all : all
# bank : bank
# indonesia : indonesia
# smartfren : smartfren
# cantik : cantik
# pencairan : cair
# paylater : paylater
# bayar : bayar
# tagihan : tagih
# pembayaran : bayar
# ukt : ukt
# trusted : trusted
# fast : fast
# buluk : buluk
# semalam : malam
# diclear : diclear
# ttp : ttp
# gabisa : gabisa
# nyoba : nyoba
# yiha : yiha
# kudeta : kudeta
# dicek : cek
# indra : indra
# mytelkomselnya : mytelkomselnya
# kmrn : kmrn
# error : error
# kaya : kaya
# gini : gin
# trs : trs
# ngecek : ngecek
# manual : manual
# penjelasannya : jelas
# thanks : thanks
# semalem : semalem
# sandro : sandro
# solid : solid
# cuman : cuman
# buang : buang
# bola : bola
# bentancur : bentancur
# main : main
# bagus : bagus
# rabiot : rabiot
# deposit : deposit
# link : link
# anjing : anjing
# rahmad : rahmad
# keterangan : terang
# numpang : numpang
# urang : urang
# reh : reh
# alasannya : alas
# masi : mas
# gimana : gimana
# lelet : lelet
# twit : twit
# mengalami : alami
# silakan : sila
# tauuuu : tauuuu
# bayu : bayu
# jga : jga
# bat : bat
# najis : najis
# ganendra : ganendra
# maafin : maafin
# ceritain : ceritain
# pertanyaannya : tanya
# langsung : langsung
# nge : nge
# login : login
# smsnya : smsnya
# masuk : masuk
# ali : ali
# djiopata : djiopata
# seputar : putar
# produk : produk
# rekan : rekan
# email : email
# anpras : anpras
# selesai : selesai
# long : long
# lat : lat
# kordinat : kordinat
# jizah : jizah
# koneksi : koneksi
# stabil : stabil
# ibab : ibab
# www : www
# yak : yak
# gua : gua
# tungguin : tungguin
# twd : twd
# doang : doang
# film : film
# box : box
# offices : offices
# marvel : marvel
# penasaran : penasaran
# siang : siang
# pekerjaan : kerja
# online : online
# terganggu : ganggu
# perbaikan : baik
# btw : btw
# gais : gais
# make : make
# nuker : nuker
# poinnya : poin
# premium : premium
# mayan : mayan
# pliss : pliss
# kmu : kmu
# mlm : mlm
# emosie : emosie
# admin : admin
# stress : stress
# disuruh : suruh
# aje : aje
# pelayanan : layan
# buruk : buruk
# tbk : tbk
# buka : buka
# operator : operator
# aman : aman
# set : set
# tim : tim
# gitu : gitu
# akeh : akeh
# mentolo : mentolo
# nang : nang
# galih : galih
# perihal : perihal
# airplane : airplane
# mode : mode
# eko : eko
# jringam : jringam
# tmbah : tmbah
# lag : lag
# stelah : stelah
# sya : sya
# laporkan : lapor
# balesan : balesan
# askrl : askrl
# playstore : playstore
# pulsanya : pulsa
# klian : klian
# qibul : qibul
# diterima : terima
# nominal : nominal
# dibeli : beli
# hallo : hallo
# kakk : kakk
# udh : udh
# isya : isya
# ngisi : ngisi
# situs : situs
# teraman : ram
# terpercaya : percaya
# alternatif : alternatif
# kartu : kartu
# pindahkan : pindah
# otomatis : otomatis
# kembalikan : kembali
# adinda : adinda
# gausah : gausah
# cemas : cemas
# risau : risau
# temen : temen
# okt : okt
# lho : lho
# byu : byu
# dilanjutkan : lanjut
# menyertakan : serta
# menarik : tarik
# dial : dial
# semoga : moga
# fatih : fatih
# ceria : ceria
# penawaran : tawar
# bersifat : sifat
# personal : personal
# mengaktifkan : aktif
# berbatas : batas
# berlaku : laku
# reinstall : reinstall
# capture : capture
# alya : alya
# apps : apps
# ter : ter
# debest : debest
# safari : safari
# kaga : kaga
# kuat : kuat
# jelek : jelek
# ohhh : ohhh
# tohh : tohh
# wkwkw : wkwkw
# sebulan : bulan
# gara : gara
# uda : uda
# gratisan : gratis
# ditabok : tabok
# wkwkwk : wkwkwk
# colek : colek
# paketnya : paket
# download : download
# apk : apk
# andre : andre
# ary : ary
# dhika : dhika
# kenapaaa : kenapaaa
# dibuka : buka
# responnya : responnya
# ampun : ampun
# support : support
# parah : parah
# kualitas : kualitas
# after : after
# sales : sales
# channel : channel
# cmn : cmn
# gimmick : gimmick
# pajangan : pajang
# anak : anak
# perusahaan : usaha
# improvement : improvement
# fair : fair
# adini : adini
# dibales : dibales
# simpati : simpati
# perumahan : rumah
# kacau : kacau
# pesawat : pesawat
# super : super
# perdana : perdana
# tetangga : tetangga
# pelajar : ajar
# gimna : gimna
# blm : blm
# respon : respon
# kehabisan : habis
# muter : muter
# tolonglah : tolong
# kelen : kelen
# muthya : muthya
# oke : oke
# sim : sim
# terbaca : baca
# bbrp : bbrp
# gmn : gmn
# simnya : simnya
# bermasalah : masalah
# speednya : speednya
# kemarin : kemarin
# burik : burik
# dimaki : maki
# maki : maki
# dlu : dlu
# bagusin : bagusin
# hasan : hasan
# orang : orang
# dilanjut : lanjut
# mengirimkan : kirim
# part : part
# diganti : ganti
# penyesuaian : sesuai
# tarif : tarif
# khawatir : khawatir
# membantu : bantu
# asterid : asterid
# membeli : beli
# redeem : redeem
# point : point
# trims : trims
# zabo : zabo
# knp : knp
# bnagt : bnagt
# ngambil : ngambil
# anjink : anjink
# ngajak : ngajak
# gelud : gelud
# hermosa : hermosa
# menanggapi : tanggap
# multimedia : multimedia
# terpotong : potong
# dipaket : paket
# quota : quota
# dalamnya : dalam
# halooo : halooo
# notifnya : notifnya
# tersedot : sedot
# yaaaa : yaaaa
# refarming : refarming
# pita : pita
# frekuensi : frekuensi
# ghz : ghz
# sembilan : sembilan
# area : area
# dilayani : layan
# ngebut : ngebut
# info : info
# sleepcall : sleepcall
# voba : voba
# adminnya : adminnya
# slipkolnya : slipkolnya
# kosong : kosong
# lapan : lap
# ung : ung
# dikasih : kasih
# rudi : rudi
# sudh : sudh
# update : update
# chace : chace
# hapus : hapus
# call : call
# center : center
# aplikasinya : aplikasi
# bego : bego
# jaringannya : jaring
# kumat : kumat
# misuh : misuh
# pas : pas
# diperhatiin : diperhatiin
# matiin : matiin
# sksbksdjskjd : sksbksdjskjd
# netflix : netflix
# hotstar : hotstar
# karna : karna
# ujian : uji
# bangett : bangett
# nero : nero
# aktifasi : aktifasi
# khusus : khusus
# ketik : ketik
# isjak : isjak
# judul : judul
# kau : kau
# artist : artist
# minor : minor
# segmen : segmen
# keluarga : keluarga
# lahir : lahir
# ron : ron
# ganyaman : ganyaman
# kartuhalo : kartuhalo
# pemakaian : pakai
# lengkap : lengkap
# hamzah : hamzah
# exstra : exstra
# informasikan : informasi
# membahayakan : bahaya
# mengikuti : ikut
# hilmy : hilmy
# pengaktifan : aktif
# melewati : lewat
# detailnya : detail
# sinyalnya : sinyal
# lte : lte
# loading : loading
# penyebab : sebab
# raih : raih
# pertumbuhan : tumbuh
# carax : carax
# ngaktifin : ngaktifin
# mati : mati
# putra : putra
# habis : habis
# sedot : sedot
# sarankan : saran
# mengecek : ecek
# silahkan : silah
# mematikan : mati
# seluler : seluler
# bocorre : bocorre
# cepet : cepet
# abis : abis
# sistem : sistem
# sediakan : sedia
# fasilitas : fasilitas
# gerai : gerai
# grapari : grapari
# kabupaten : kabupaten
# landak : landak
# tandatangani : tandatangani
# petisi : petisi
# mitshuya : mitshuya
# darurat : darurat
# booster : booster
# terakumulasi : akumulasi
# internetnya : internetnya
# angkanya : angka
# pdhl : pdhl
# kesini : kesini
# hakimyoy : hakimyoy
# sinya : sinya
# hilang : hilang
# cantumkan : cantum
# mention : mention
# seharian : hari
# diakses : akses
# wanda : wanda
# nmr : nmr
# wtb : wtb
# drop : drop
# plis : plis
# kog : kog
# dpt : dpt
# pesan : pesan
# melunasi : lunas
# hutang : hutang
# ngga : ngga
# kepotong : potong
# bersabar : sabar
# pastiin : pastiin
# gada : gada
# terlewat : lewat
# ditanganinya : tangan
# fasa : fasa
# tenang : tenang
# pindahin : pindahin
# reza : reza
# berbeda : beda
# beda : beda
# disesuaikan : sesuai
# skema : skema
# umur : umur
# penggunaan : guna
# afdal : afdal
# applikasi : applikasi
# failure : failure
# ngaruh : ngaruh
# pusat : pusat
# pengen : ken
# ganti : ganti
# nada : nada
# dering : dering
# with : with
# seoul : seoul
# crystal : crystal
# snow : snow
# life : life
# goes : goes
# setia : setia
# game : game
# silver : silver
# ngisiin : ngisiin
# tpi : tpi
# nerima : nerima
# sms : sms
# miqsyal : miqsyal
# sudaaah : sudaaah
# komplek : komplek
# rumah : rumah
# bantuannya : bantu
# wilayah : wilayah
# desa : desa
# panggoi : panggoi
# muara : muara
# lhokseumawe : lhokseumawe
# aceh : aceh
# wellieu : wellieu
# tumbuh : tumbuh
# inovasi : inovasi
# barunya : baru
# apesi : apes
# aaa : aaa
# prtangung : prtangung
# jwab : jwab
# twtter : twtter
# neh : neh
# bkan : bkan
# sumpah : sumpah
# iye : iye
# ditanyain : ditanyain
# dibalas : balas
# bos : bos
# ilang : ilang
# ngk : ngk
# nanya : nanya
# teman : teman
# terosss : terosss
# nnyain : nnyain
# bls : bls
# goceng : goceng
# normal : normal
# murasimu : muras
# bantuin : bantuin
# initu : initu
# pakenya : pakenya
# gantiin : gantiin
# goblok : goblok
# idiot : idiot
# provider : provider
# autis : autis
# pepek : pepek
# tarik : tarik
# twitter : twitter
# myorbitid : myorbitid
# suport : suport
# jayapura : jayapura
# papua : papua
# hooh : hooh
# proses : proses
# gift : gift
# duit : duit
# bang : bang
# yaaa : yaaa
# untung : untung
# ngezoom : ngezoom
# awas : awas
# eror : eror
# pusing : pusing
# malam : malam
# oiii : oiii
# nak : nak
# waktumu : waktu
# kost : kost
# mending : mending
# tuku : tuku
# sing : sing
# iso : iso
# ngeteng : ngeteng
# koyo : koyo
# opo : opo
# ciya : ciya
# nugasnya : nugasnya
# inget : inget
# indo : indo
# bobrok : bobrok
# ampe : ampe
# trending : trending
# twiter : twiter
# duh : duh
# konek : konek
# zoom : zoom
# ngelag : ngelag
# posisi : posisi
# kaki : kaki
# gunung : gunung
# hahaha : hahaha
# iyaa : iyaa
# gratis : gratis
# salah : salah
# rusli : rusli
# wkwkwkkwkk : wkwkwkkwkk
# desy : desy
# dibanggain : dibanggain
# tasik : tasik
# kabur : kabur
# des : des
# woho : woho
# paketan : paket
# plus : plus
# ribut : ribut
# iyaishh : iyaishh
# gituu : gituu
# ajsgdahaksbsjskbx : ajsgdahaksbsjskbx
# baptis : baptis
# ege : ege
# sinyalmu : sinyal
# sesuai : sesuai
# tingkatkan : tingkat
# quantity : quantity
# bts : bts
# pelosok : pelosok
# gembar : gembar
# gembor : gembor
# iklan : iklan
# dinamakan : nama
# win : win
# the : the
# hearts : hearts
# new : new
# generation : generation
# southeast : southeast
# largest : largest
# decided : decided
# embark : embark
# big : big
# bold : bold
# transformation : transformation
# discover : discover
# how : how
# helped : helped
# opportunity : opportunity
# reinvent : reinvent
# itself : itself
# dual : dual
# hpnya : hpnya
# slow : slow
# wifinya : wifinya
# sarah : sarah
# kemaren : kemaren
# devita : devita
# kerja : kerja
# telat : telat
# cenderung : cenderung
# isolir : isolir
# upgrade : upgrade
# speed : speed
# mbps : mbps
# pertanggungjawabannya : pertanggungjawabannya
# oswella : oswella
# aduhh : aduhh
# ajaa : ajaa
# menerima : terima
# spam : spam
# ttl : ttl
# lagu : lagu
# kento : kento
# sunset : sunset
# sore : sore
# minum : minum
# teh : teh
# nasgitel : nasgitel
# panas : panas
# legi : legi
# kentel : kentel
# daritadi : daritadi
# berhenti : henti
# messages : messages
# kayak : kayak
# isinya : isi
# risih : risih
# sebenernya : sebenernya
# wangja : wangja
# ayo : ayo
# fariz : fariz
# ama : ama
# apaa : apaa
# ricardo : ricardo
# haloo : haloo
# pranata : pranata
# susah : susah
# nurma : nurma
# asli : asli
# usaha : usaha
# keganggu : ganggu
# yuda : yuda
# kyk : kyk
# beraaakk : beraaakk
# hubungin : hubungin
# beginii : begini
# gal : gal
# secepatnyaa : secepatnyaa
# ngeceknya : ngeceknya
# jamur : jamur
# yhaaaaa : yhaaaaa
# yaudadeh : yaudadeh
# minceu : minceu
# baca : baca
# sinyallnya : sinyallnya
# ngapa : ngapa
# ketidaksesuaian : ketidaksesuaian
# pls : pls
# berasa : asa
# mondok : mondok
# dalem : dalem
# goa : goa
# gws : gws
# enak : enak
# dipakai : pakai
# ngapain : ngapain
# viva : viva
# rahasianya : rahasia
# kekeliruan : keliru
# maksud : maksud
# pascabayar : pascabayar
# permintaan : minta
# pemberhentian : henti
# terhenti : henti
# knpa : knpa
# jan : jan
# membosankan : bosan
# berpaling : paling
# woy : woy
# dasar : dasar
# hoax : hoax
# atuhlah : atuhlah
# dijawaaab : dijawaaab
# reply : reply
# melebihi : lebih
# bales : bales
# lanjutkan : lanjut
# pengecekannya : kece
# rose : rose
# blackpink : blackpink
# nomer : nomer
# anjj : anjj
# astagfirullah : astagfirullah
# jam : jam
# kabelnya : kabel
# digigit : gigit
# iwak : iwak
# hiu : hiu
# merapat : rapat
# pembelian : beli
# unlimitedmax : unlimitedmax
# tanyain : tanyain
# jumping : jumping
# kenyataan : nyata
# disemua : semua
# menyediakan : sedia
# busuk : busuk
# alasan : alas
# kabel : kabel
# neraka : neraka
# kebakar : bakar
# laut : laut
# gigit : gigit
# rayap : rayap
# asuu : asuu
# diah : diah
# heripede : heripede
# gaada : gaada
# bisanya : bisa
# ready : ready
# nego : nego
# ngadat : ngadat
# payah : payah
# ahmad : ahmad
# sejarahnya : sejarah
# kader : kader
# mrk : mrk
# korup : korup
# brti : brti
# nyari : nyari
# dwt : dwt
# suruh : suruh
# ngeluarin : ngeluarin
# pantees : pantees
# nicola : nicola
# baskoro : baskoro
# agus : agus
# bell : bell
# pusatnya : pusat
# say : say
# goodbye : goodbye
# drama : drama
# tethering : tethering
# hadir : hadir
# commerce : commerce
# favorit : favorit
# store : store
# lengkapnya : lengkap
# hadiah : hadiah
# diklaim : klaim
# adam : adam
# senggol : senggol
# icha : icha
# bersedia : sedia
# nungguin : nungguin
# lanjutin : lanjutin
# kei : kei
# ghina : ghina
# telepon : telepon
# komitmen : komitmen
# akselerasikan : akselerasi
# adopsi : adopsi
# gaya : gaya
# hidup : hidup
# ngini : ngini
# love : love
# rnck : rnck
# badmood : badmood
# inet : inet
# latency : latency
# nangis : nang
# perfect : perfect
# kerjaan : kerja
# ramdani : ramdani
# rio : rio
# prabayar : prabayar
# gus : gus
# pundung : pundung
# ditungguin : ditungguin
# tergantung : gantung
# cape : cape
# intan : intan
# erys : erys
# ratnadewanti : ratnadewanti
# ratna : ratna
# fahri : fahri
# tengku : tengku
# amod : amod
# otp : otp
# perangkat : perangkat
# sembuhnya : sembuh
# azhari : azhari
# zain : zain
# ngeleg : ngeleg
# anjeerrrrrrr : anjeerrrrrrr
# istighfar : istighfar
# boros : boros
# dipake : dipake
# meet : meet
# lim : lim
# kesedot : sedot
# dibikin : bikin
# tower : tower
# energi : energi
# samsek : samsek
# true : true
# story : story
# tonight : tonight
# was : was
# annoyed : annoyed
# shitty : shitty
# package : package
# ended : ended
# browsing : browsing
# for : for
# similar : similar
# experiences : experiences
# sel : sel
# users : users
# ambon : ambon
# using : using
# different : different
# keywords : keywords
# just : just
# typing : typing
# search : search
# bar : bar
# and : and
# voila : voila
# gilaaa : gilaaa
# kirain : kirain
# jaringanmu : jaring
# boss : boss
# seaakan : seaakan
# perpanjang : panjang
# wkw : wkw
# kaget : kaget
# hape : hape
# masukin : masukin
# jay : jay
# jeje : jeje
# transformed : transformed
# reach : reach
# first : first
# consumers : consumers
# nunggu : nunggu
# brp : brp
# giliran : gilir
# mencekik : cekik
# pandemi : pandemi
# modem : modem
# full : full
# asliii : asliii
# sosro : sosro
# emina : emina
# bngt : bngt
# sponsor : sponsor
# wkwkwkwk : wkwkwkwk
# jugaa : jugaa
# jualin : jualin
# apateh : apateh
# macem : macem
# bentuknya : bentuk
# bulet : bulet
# kangen : kangen
# panitia : panitia
# pensi : pensi
# euy : euy
# terpaksa : paksa
# masang : masang
# miak : miak
# penyelamat : selamat
# kencengan : kenceng
# hadeeeh : hadeeeh
# ngahambat : ngahambat
# pisan : pis
# siii : siii
# allah : allah
# akutu : akutu
# liat : liat
# genshin : genshin
# pingnya : pingnya
# merah : merah
# ms : ms
# reconnecting : reconnecting
# seh : seh
# sengaja : sengaja
# diisiin : diisiin
# prabayarnya : prabayarnya
# gemana : gana
# makai : maka
# utuh : utuh
# utama : utama
# class : class
# message : message
# dirumah : rumah
# when : when
# sabar : sabar
# nikmatin : nikmatin
# nyumpahin : nyumpahin
# miliarder : miliarder
# alias : alias
# terimakasih : terimakasih
# keren : keren
# gegara : gegara
# hebat : hebat
# pertahankan : tahan
# kualitasnya : kualitas
# ping : ping
# mecahin : mecahin
# rekor : rekor
# well : well
# least : least
# ngomong : ngomong
# manusia : manusia
# kepala : kepala
# sakit : sakit
# skrg : skrg
# sempet : sempet
# ngeload : ngeload
# menit : menit
# wow : wow
# nurunin : nurunin
# kesal : kesal
# marahan : marah
# air : air
# pacah : pacah
# padang : padang
# talak : talak
# posting : posting
# pemenang : menang
# undian : undi
# kena : kena
# klu : klu
# mengatifkn : mengatifkn
# krtu : krtu
# trblokir : trblokir
# puk : puk
# dptnx : dptnx
# bgmn : bgmn
# kim : kim
# latitude : latitude
# minie : minie
# rada : rada
# dikeplak : keplak
# astaghfirullah : astaghfirullah
# sholeh : sholeh
# unreg : unreg
# mengirim : kirim
# format : format
# flash : flash
# spasi : spasi
# miliki : milik
# belangganan : banggan
# asiyah : asiyah
# jalu : jalu
# speechless : speechless
# score : score
# minus : minus
# xxx : xxx
# nmor : nmor
# andry : andry
# lemah : lemah
# logo : logo
# seminggu : minggu
# teroos : teroos
# request : request
# mama : mama
# kantor : kantor
# polisi : polisi
# lani : lani
# penanganannya : tangan
# lala : lala
# doain : doain
# kuy : kuy
# klik : klik
# fyi : fyi
# promonya : promonya
# diaktifin : diaktifin
# berdasarkan : dasar
# perbulan : bulan
# kondisi : kondisi
# arfy : arfy
# pmbatasan : pmbatasan
# limit : limit
# hendraz : hendraz
# hendra : hendra
# bilangnya : bilang
# kabar : kabar
# kelanjutannya : lanjut
# pemakaiannya : pakai
# dibatasi : batas
# limitnya : limit
# prata : prata
# aktifkan : aktif
# berkurang : kurang
# solusinya : solusi
# thx : thx
# artian : arti
# kepake : kepake
# nambahnya : nambahnya
# feedback : feedback
# ucapan : ucap
# dedi : dedi
# patah : patah
# semangat : semangat
# sllu : sllu
# positif : positif
# thinking : thinking
# minn : minn
# ibuk : ibuk
# adaa : adaa
# sinyaal : sinyaal
# riyan : riyan
# memposting : memposting
# ngedrop : ngedrop
# wapun : wapun
# kemudahan : mudah
# pln : pln
# mobile : mobile
# petunjuk : tunjuk
# verifikasi : verifikasi
# akun : akun
# mutakin : mutakin
# turun : turun
# cekan : cek
# pengisian : isi
# reguler : reguler
# sukses : sukses
# gbrl : gbrl
# steve : steve
# canva : canva
# meetup : meetup
# gabriel : gabriel
# vaduka : vaduka
# cari : cari
# ayiex : ayiex
# mah : mah
# gasih : gasih
# skor : skor
# reksa : reksa
# terparah : parah
# sii : sii
# help : help
# sisi : sisi
# selengkapnya : lengkap
# dongkrak : dongkrak
# trafik : trafik
# msh : msh
# cica : cica
# dijelasin : dijelasin
# dialami : alami
# hubungi : hubung
# three : three
# tumben : tumben
# pengurusan : urus
# pengembalian : kembali
# berulah : ulah
# heh : heh
# jarang : jarang
# lihat : lihat
# kriteria : kriteria
# terpilihnya : pilih
# padamu : pada
# lopyupullll : lopyupullll
# bella : bella
# elah : elah
# sebel : sebel
# ucok : ucok
# gres : gres
# trus : trus
# klanjutan : klanjutan
# abang : abang
# doi : doi
# bangga : bangga
# telkomselnya : telkomselnya
# dihack : dihack
# membagikan : bagi
# pribai : pribai
# tiada : tiada
# memaki : maki
# kenapaaaa : kenapaaaa
# yatuhan : yatuhan
# hack : hack
# laga : laga
# lanjutan : lanjut
# grup : grup
# liga : liga
# champions : champions
# september : september
# wib : wib
# keseruannya : seru
# bernadus : bernadus
# naha : naha
# wae : wae
# heran : heran
# alami : alami
# chaca : chaca
# andriani : andriani
# andang : andang
# saran : saran
# reyhan : reyhan
# terkonfirmasi : konfirmasi
# lupa : lupa
# masker : masker
# ngak : ngak
# lancar : lancar
# kebun : kebun
# oalah : oalah
# yutube : yutube
# masuknya : masuk
# kesitu : kesitu
# oiya : oiya
# hrs : hrs
# berlangganan : langgan
# fly : fly
# haengbok : haengbok
# gajelas : gajelas
# fak : fak
# dll : dll
# load : load
# fitra : fitra
# dirilis : rilis
# meraup : raup
# sahaja : sahaja
# bills : bills
# myim : myim
# takut : takut
# zonk : zonk
# pergantian : ganti
# terpakai : pakai
# membuka : buka
# server : server
# genshinnya : genshinnya
# down : down
# taopik : taopik
# aiman : aiman
# menghilang : hilang
# jaehyun : jaehyun
# rizz : rizz
# ubah : ubah
# kenape : kenape
# astaga : astaga
# cpek : cpek
# bumn : bumn
# bangsad : bangsad
# bapuk : bapuk
# mokad : mokad
# komisaris : komisaris
# pembuat : buat
# kebijakannya : bijak
# terpendek : pendek
# dikonsumsi : konsumsi
# hujan : hujan
# sinii : sini
# bio : bio
# bak : bak
# emas : emas
# perlakukan : laku
# trav : trav
# gpp : gpp
# comba : comba
# gga : gga
# ngokeyy : ngokeyy
# hadirr : hadirr
# nder : nder
# merin : merin
# aamiin : aamiin
# aamiiin : aamiiin
# dimas : mas
# yra : yra
# diakumulasikan : akumulasi
# marbunz : marbunz
# wkwkwkwkwkwkwkw : wkwkwkwkwkwkwkw
# beres : beres
# brrti : brrti
# mawar : mawar
# nasional : nasional
# lumayan : lumayan
# amour : amour
# tipenya : tipe
# gambar : gambar
# hayo : hayo
# satunya : satu
# ketiga : tiga
# tipe : tipe
# postingan : postingan
# prihatin : prihatin
# anggota : anggota
# podo : podo
# ngamuk : ngamuk
# mensos : mensos
# kasihan : kasihan
# denny : denny
# membandingkan : banding
# menggandeng : gandeng
# pengacara : acara
# otto : otto
# hasibuan : hasibuan
# menggugat : gugat
# pil : pil
# yandi : yandi
# workout : workout
# lowongan : lowong
# lulusan : lulus
# jurusan : jurus
# isme : isme
# gamal : gamal
# rese : rese
# terbaru : baru
# force : force
# stop : stop
# menu : menu
# setting : setting
# handphone : handphone
# log : log
# out : out
# tlg : tlg
# jelasin : jelasin
# pakainya : pakai
# bulanan : bulan
# gaperlu : gaperlu
# jenis : jenis
# wajib : wajib
# yap : yap
# sungjin : sungjin
# restu : restu
# platinum : platinum
# pending : pending
# chanel : chanel
# gasengaja : gasengaja
# kampus : kampus
# thn : thn
# ttg : ttg
# penghuna : penghuna
# replynya : replynya
# salty : salty
# pembelajarannya : ajar
# getting : getting
# tired : tired
# this : this
# ketawa : ketawa
# dehhh : dehhh
# iniiii : iniiii
# sihhh : sihhh
# versus : versus
# mayanlah : mayanlah
# melatih : latih
# kesabaran : sabar
# dibilang : bilang
# payment : payment
# being : being
# processed : processed
# maksimum : maksimum
# berpengaruh : pengaruh
# lupaa : lupaa
# berapaa : berapaa
# dalton : dalton
# manjava : manjava
# peny : peny
# ilmalana : ilmalana
# alan : alan
# mengingatkanku : ingat
# toxic : toxic
# relationship : relationship
# nyata : nyata
# dibanding : banding
# ruangan : ruang
# berpindah : pindah
# listrik : listrik
# padam : padam
# menara : menara
# pemancar : pancar
# membutuhkan : butuh
# aliran : alir
# memancarkan : pancar
# smartphone : smartphone
# mencari : cari
# nomernya : nomernya
# ultah : ultah
# cadangan : cadang
# kenceng : kenceng
# meriah : riah
# bayangkan : bayang
# juarang : juarang
# buanget : buanget
# kebagian : bagi
# ancur : ancur
# ancuran : ancuran
# jnck : jnck
# itungannya : itungannya
# maen : maen
# tweter : tweter
# perilaku : perilaku
# telpon : telpon
# charge : charge
# nelpon : nelpon
# berjam : jam
# kayaknya : kayak
# deh : deh
# perpindahan : pindah
# konfirmasi : konfirmasi
# pemadaman : madam
# rbt : rbt
# permisi : permisi
# resek : resek
# musim : musim
# penghujan : hujan
# sabtu : sabtu
# striming : striming
# huhu : huhu
# oiiii : oiiii
# buffering : buffering
# regular : regular
# ges : ges
# teu : teu
# team : team
# medsa : medsa
# non : non
# bokap : bokap
# mengogrek : mengogrek
# manekin : manekin
# tangan : tangan
# infus : infus
# berujung : ujung
# rusak : rusak
# karma : karma
# marah : marah
# manik : manik
# ihh : ihh
# seriusan : serius
# bamget : bamget
# siiii : siiii
# butuhnya : butuh
# ketuk : ketuk
# kay : kay
# nyedot : nyedot
# deres : deres
# bah : bah
# puluhan : puluh
# detik : detik
# kompensasi : kompensasi
# evan : evan
# pastikan : pasti
# boro : boro
# foya : foya
# anggapmi : anggapmi
# barang : barang
# mewah : mewah
# takada : takada
# disitu : situ
# bgini : bgini
# gmna : gmna
# gacornya : gacornya
# konsisten : konsisten
# profit : profit
# member : member
# sakuku : saku
# daftar : daftar
# gacor : gacor
# parahhh : parahhh
# alfi : alf
# bwf : bwf
# badminton : badminton
# regularnya : regularnya
# ngurangin : ngurangin
# vpn : vpn
# unlimitednya : unlimitednya
# berfungsi : fungsi
# beliau : beliau
# kluarga : kluarga
# sndri : sndri
# bewe : bewe
# deni : den
# asik : asik
# lampu : lampu
# dhyna : dhyna
# hay : hay
# lgi : lgi
# beginimana : beginimana
# dear : dear
# babi : babi
# seakan : akan
# hutan : hutan
# nyala : nyala
# sobat : sobat
# operasional : operasional
# mitra : mitra
# terpilih : pilih
# bauran : baur
# pembiayaan : biaya
# merk : merk
# type : type
# yudistira : yudistira
# alvi : alvi
# rafi : rafi
# bangsat : bangsat
# babu : babu
# secepatnya : cepat
# smartfrn : smartfrn
# palem : palem
# semi : semi
# terputus : putus
# bahaya : bahaya
# almor : almor
# ditindak : tindak
# lanjuti : lanjut
# wanareja : wanareja
# signal : signal
# oklah : oklah
# wifi : wifi
# putus : putus
# ikutan : ikut
# kaa : kaa
# sharing : sharing
# private : private
# soschat : soschat
# acc : acc
# stupid : stupid
# appointed : appointed
# kso : kso
# partners : partners
# manage : manage
# villages : villages
# corner : corner
# minuman : minum
# indomaret : indomaret
# ciri : ciri
# masokis : masokis
# rere : rere
# mencobanya : coba
# bagusnya : bagus
# mendukung : dukung
# join : join
# gaws : gaws
# oranglain : oranglain
# kartunya : kartu
# telponan : telpon
# hayu : hayu
# kenapaa : kenapaa
# san : san
# cuy : cuy
# hospot : hospot
# damara : damara
# mushawwir : mushawwir
# wirsa : wirsa
# yas : yas
# berhasil : hasil
# jaringab : jaringab
# ulin : ulin
# kandangan : kandang
# kalimantan : kalimantan
# selatan : selatan
# mincuuu : mincuuu
# tauuu : tauuu
# perluas : luas
# penjualan : jual
# catat : catat
# signifikan : signifikan
# rhine : rhine
# iyaaa : iyaaa
# les : les
# jdbksbdksbnshs : jdbksbdksbnshs
# budi : budi
# diem : diem
# bae : bae
# pov : pov
# wish : wish
# luck : luck
# portable : portable
# aldi : aldi
# rilis : rilis
# dibanderol : banderol
# ikar : ikar
# mas : mas
# gmne : gmne
# sie : sie
# gwe : gwe
# weeeyyyy : weeeyyyy
# tsb : tsb
# sohib : sohib
# jabodetabek : jabodetabek
# hotspot : hotspot
# plss : plss
# ngabarin : ngabarin
# tua : tua
# ninjamu : ninjamu
# hemat : hemat
# free : free
# aktifin : aktifin
# apple : apple
# dengerin : dengerin
# medsos : medsos
# pengunaan : pengunaan
# mengambil : ambil
# sosmed : sosmed
# jujur : jujur
# kamar : kamar
# ngeblank : ngeblank
# diluar : luar
# emergency : emergency
# calls : calls
# only : only
# dibanjaran : banjar
# hohoho : hohoho
# bantuan : bantu
# ajah : ajah
# lost : lost
# kubunga : bunga
# telkomselku : telkomselku
# yuhuuuuuuu : yuhuuuuuuu
# diperbaiki : baik
# woi : woi
# ayokk : ayokk
# bismillah : bismillah
# aii : aii
# akuu : akuu
# elektronik : elektronik
# yukk : yukk
# order : order
# user : user
# berubah : ubah
# memasuki : pasuk
# aiiii : aiiii
# gelut : gelut
# anjenkkkk : anjenkkkk
# telek : telek
# sbg : sbg
# mifi : mifi
# laptop : laptop
# jos : jos
# anti : anti
# boncos : boncos
# teleponan : telepon
# talkmania : talkmania
# bahas : bahas
# bisnis : bisnis
# tugas : tugas
# kuliah : kuliah
# curhat : curhat
# ngobrol : ngobrol
# sepuasnya : puas
# besaran : besar
# bocoran : bocor
# lolos : lolos
# seleksi : seleksi
# naon : naon
# goblog : goblog
# thrilled : thrilled
# that : that
# vccp : vccp
# singapore : singapore
# our : our
# branding : branding
# design : design
# agency : agency
# have : have
# been : been
# shortlisted : shortlisted
# best : best
# visual : visual
# identity : identity
# from : from
# technology : technology
# media : media
# telecommunications : telecommunications
# sector : sector
# awards : awards
# their : their
# campaign : campaign
# done : done
# good : good
# logonya : logo
# mengakses : akses
# spt : spt
# sebutkan : sebut
# tasikmalaya : tasikmalaya
# sosial : sosial
# terbuka : buka
# wtf : wtf
# whats : whats
# wrong : wrong
# uuuu : uuuu
# dude : dude
# paypal : paypal
# musuhan : musuh
# web : web
# jaya : jaya
# top : top
# piye : piye
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# malang : malang
# jes : jes
# merata : rata
# thank : thank
# you : you
# menghambat : hambat
# makasii : makasii
# nyantol : nyantol
# will : will
# shop : shop
# other : other
# art : art
# intro : intro
# render : render
# random : random
# wallpaper : wallpaper
# nfsw : nfsw
# simple : simple
# rig : rig
# dak : dak
# kejelasan : jelas
# gangguannya : ganggu
# yess : yess
# kesehatan : sehat
# amin : amin
# spay : spay
# im : im
# aank : aank
# hasil : hasil
# evaluasi : evaluasi
# keminfo : keminfo
# berdasar : dasar
# dimiliki : milik
# mempersulit : sulit
# memperhatikan : perhati
# ketersediaan : sedia
# keekonomian : ekonomi
# tidur : tidur
# penipu : tipu
# sok : sok
# nawarin : nawarin
# tuker : tuker
# woii : woii
# gabutuh : gabutuh
# sayang : sayang
# duitnya : duit
# nyapres : nyapres
# ketum : tum
# pemilihan : pilih
# blu : blu
# bakti : bakti
# kominfo : kominfo
# program : program
# penyediaan : sedia
# seksama : seksama
# karakteristik : karakteristik
# menteri : menteri
# komunikasi : komunikasi
# informatika : informatika
# johnny : johnny
# plate : plate
# tindak : tindak
# konektivitas : konektivitas
# blak : blak
# baper : baper
# axiata : axiata
# menggarap : garap
# base : base
# transceiver : transceiver
# station : station
# ketinggalan : tinggal
# berita : berita
# viral : viral
# irit : irit
# dapetin : dapetin
# bebas : bebas
# smsan : smsan
# pemeliharaan : pelihara
# mengalahkan : kalah
# qris : qris
# murce : murce
# wowowowowoowiw : wowowowowoowiw
# indihom : indihom
# pdahal : pdahal
# diupdate : diupdate
# pajagan : pajagan
# gekbrong : gekbrong
# cianjur : cianjur
# jawa : jawa
# barat : barat
# cur : cur
# ooalah : ooalah
# selow : selow
# depok : depok
# dimana : mana
# margocity : margocity
# tutup : tutup
# ketahui : tahu
# tiang : tiang
# dikuasai : asai
# slot : slot
# kebayang : bayang
# kejar : kejar
# deadline : deadline
# monetary : monetary
# notifikasi : notifikasi
# realitanya : realitanya
# keburu : keburu
# aktipnya : aktipnya
# braw : braw
# kasihh : kasihh
# waras : waras
# dikit : dikit
# but : but
# dijamin : jamin
# kabarin : kabarin
# jemput : jemput
# buatmu : buat
# bermasalahnya : masalah
# serumahnya : rumah
# bgus : bgus
# jringan : jringan
# jdi : jdi
# wkwkkw : wkwkkw
# mendingan : mending
# gra : gra
# korpri : korpri
# sukarame : sukarame
# bandar : bandar
# lampung : lampung
# livia : livia
# pulsaku : pulsa
# dibilangnya : bilang
# bioskop : bioskop
# maxtream : maxtream
# hello : hello
# connection : connection
# seemed : seemed
# some : some
# minutes : minutes
# still : still
# unstable : unstable
# now : now
# there : there
# any : any
# problem : problem
# cindy : cindy
# nelfon : nelfon
# ditengah : tengah
# pandemic : pandemic
# samsung : samsung
# flip : flip
# ikuti : ikut
# kompetisinya : kompetisi
# nomorku : nomor
# adikku : adik
# seruan : seru
# atur : atur
# sesukanya : suka
# krna : krna
# pembagian : bagi
# sekelas : kelas
# adib : adib
# dwika : dwika
# advance : advance
# belasan : bas
# taun : taun
# mantap : mantap
# nggk : nggk
# kyak : kyak
# vella : vella
# kia : kia
# berupaya : upaya
# maksimal : maksimal
# memuaskan : muas
# maunya : mau
# nomornya : nomor
# lin : lin
# mencantumkanlong : mencantumkanlong
# minggu : minggu
# plan : plan
# weekend : weekend
# rebahan : rebah
# streaming : streaming
# series : series
# kesukaan : suka
# cakep : cakep
# ngaku : ngaku
# pcrku : pcrku
# pap : pap
# one : one
# onli : onli
# soobin : soobin
# iseng : iseng
# huhuhu : huhuhu
# ngupload : ngupload
# sminggu : sminggu
# jaringn : jaringn
# ngirim : ngirim
# ketulis : ketul
# kekirim : kirim
# diumumin : diumumin
# hiksrot : hiksrot
# rosa : rosa
# seng : seng
# ngene : ngene
# lak : lak
# omah : omah
# berharap : harap
# disc : disc
# tag : tag
# taikk : taikk
# brhenti : brhenti
# danz : danz
# ramdan : ramdan
# beib : beib
# sile : sile
# griya : griya
# bandung : bandung
# asri : asri
# tulip : tulip
# sultan : sultan
# nunik : nunik
# setya : setya
# lelah : lelah
# sakiti : sakit
# emng : emng
# kentang : kentang
# levan : levan
# diisi : isi
# keluargamu : keluarga
# jele : jele
# brou : brou
# ich : ich
# apilikasinya : apilikasinya
# vicon : vicon
# edukasi : edukasi
# kids : kids
# tepatnya : tepat
# hyunjin : hyunjin
# berisi : isi
# kayanya : kaya
# kulitnya : kulit
# bersih : bersih
# aya : aya
# terupdate : terupdate
# terkendala : kendala
# kesel : kesel
# bet : bet
# woe : woe
# sabaran : sabar
# hadeh : hadeh
# uefa : uefa
# league : league
# manchester : manchester
# united : united
# villarreal : villarreal
# kamis : kamis
# terbaik : baik
# kemenangan : menang
# bayarkan : bayar
# mariobola : mariobola
# korporat : korporat
# djarum : djarum
# emtek : emtek
# astra : astra
# incumbents : incumbents
# mendanai : dana
# startup : startup
# sekedar : dar
# gayaan : gaya
# jawabannya : jawab
# manfaat : manfaat
# desamu : desa
# daerahmu : daerah
# sektor : sektor
# meningkatkan : tingkat
# hadirnya : hadir
# follow : follow
# ogah : ogah
# ogahhan : ogahhan
# ikan : ikan
# terowongan : terowongan
# jebol : jebol
# sdmnya : sdmnya
# wulandani : wulandani
# shella : shella
# lorensya : lorensya
# sip : sip
# gabisaaaaaaaaaaaaaaaaaaa : gabisaaaaaaaaaaaaaaaaaaa
# wahyu : wahyu
# penyelesaiannya : selesai
# elu : elu
# dibayar : bayar
# nyet : nyet
# halouo : halouo
# pricelist : pricelist
# killuash : killuash
# nihil : nihil
# killu : killu
# lebihh : lebihh
# kampuaaanggg : kampuaaanggg
# budget : budget
# nokia : nokia
# date : date
# bundlingmax : bundlingmax
# auto : auto
# bintang : bintang
# timbul : timbul
# loop : loop
# pencerahan : cerah
# anisa : anisa
# daringnya : daringnya
# han : han
# ade : ade
# ape : ape
# idupkan : idupkan
# segitu : segitu
# idup : idup
# belom : bom
# daetah : daetah
# sawangan : sawangan
# much : much
# despise : despise
# isp : isp
# got : got
# choice : choice
# arda : arda
# sinyale : sinyale
# medioker : medioker
# disarankan : saran
# antisipasi : antisipasi
# nicko : nicko
# okeh : okeh
# nahan : nahan
# ngeliat : ngeliat
# malem : malem
# berungkali : ungkal
# kapal : kapal
# kereta : kereta
# api : api
# menguras : uras
# oalahh : oalahh
# tita : tita
# dikirim : kirim
# uri : uri
# kalbar : kalbar
# tokped : tokped
# namjoon : namjoon
# sampah : sampah
# smash : smash
# hadianto : hadianto
# tulisannya : tulis
# puas : puas
# terkati : kati
# sin : sin
# boemdy : boemdy
# harap : harap
# terbalas : balas
# dipercaya : percaya
# mengelola : kelola
# daring : daring
# stres : stres
# diapain : diapain
# setuju : tuju
# prestasinya : prestasi
# datar : datar
# jakarta : jakarta
# nangkap : nangkap
# koruptor : koruptor
# omong : omong
# kpk : kpk
# dilemahkan : lemah
# dijakarta : dijakarta
# koruptooooor : koruptooooor
# musicmax : musicmax
# gamesmax : gamesmax
# shodiks : shodiks
# bangun : bangun
# ribuan : ribu
# asuransi : asuransi
# daniel : daniel
# benernya : benernya
# mainstream : mainstream
# barusan : barusan
# maksudnya : maksud
# motong : motong
# gre : gre
# promosi : promosi
# napa : napa
# urus : urus
# costumer : costumer
# ngalamin : ngalamin
# jaringa : jaringa
# jagoanmu : jago
# pertandingan : tanding
# zoomnya : zoomnya
# cdm : cdm
# kimjnie : kimjnie
# mvrah : mvrah
# mvrce : mvrce
# pr : pr
# mo : mo
# cuss : cuss
# lewatkan : lewat
# bergengsi : gengsi
# psis : psis
# semarang : semarang
# madura : madura
# mudah : mudah
# mvvrce : mvvrce
# laaaah : laaaah
# gapapa : gapapa
# tolonglaaaaah : tolonglaaaaah
# pad : pad
# sajak : sajak
# besok : besok
# kedepan : depan
# jasa : jasa
# followers : followers
# views : views
# cepat : cepat
# bersahabat : sahabat
# minat : minat
# yawes : yawes
# tebengan : tebeng
# kayake : kayake
# rumahku : rumah
# doel : doel
# okeyy : okeyy
# ppp : ppp
# hihihi : hihihi
# year : year
# old : old
# telecom : telecom
# incumbent : incumbent
# seized : seized
# attract : attract
# its : its
# next : next
# customers : customers
# kocak : kocak
# ngereplynya : ngereplynya
# wkwkwwk : wkwkwwk
# pvn : pvn
# tvri : tvri
# org : org
# depo : depo
# xpoker : xpoker
# gueeeee : gueeeee
# monmaap : monmaap
# hrsnyaaa : hrsnyaaa
# bangke : bangke
# seru : seru
# dicemilin : dicemilin
# bun : bun
# ekstra : ekstra
# diamond : diamond
# fire : fire
# jajan : jajan
# eryn : eryn
# telkomgroup : telkomgroup
# penuh : penuh
# kementerian : menteri
# arahan : arah
# satunta : satunta
# direktur : direktur
# tuhan : tuhan
# please : please
# dirut : dirut
# dijabat : jabat
# perempuan : perempuan
# fuck : fuck
# dahhhh : dahhhh
# utara : utara
# firstmed : firstmed
# why : why
# fitur : fitur
# logout : logout
# diuntungkan : untung
# pertahanin : pertahanin
# kecepatan : cepat
# performanya : performa
# sifat : sifat
# rakus : rakus
# merek : merek
# membayar : bayar
# pan : pan
# dunia : dunia
# tonton : tonton
# signature : signature
# content : content
# konten : konten
# podcast : podcast
# cheat : cheat
# dawn : dawn
# mia : mia
# deasy : deasy
# natalina : natalina
# filaa : filaa
# deasyofficials : deasyofficials
# buying : buying
# selling : selling
# goods : goods
# services : services
# account : account
# billion : billion
# annually : annually
# forming : forming
# has : has
# emerged : emerged
# major : major
# driver : driver
# local : local
# jobs : jobs
# perubahan : ubah
# penanganan : tangan
# nabil : nabil
# siapkan : siap
# ktp : ktp
# kunjungi : kunjung
# oktober : oktober
# khasa : khasa
# sugi : sugi
# ratih : ratih
# alamat : alamat
# angin : angin
# ujan : ujan
# panik : panik
# syaratnya : syarat
# dibawa : bawa
# mbanking : mbanking
# ros : ros
# febbyardian : febbyardian
# ardian : ardi
# balas : balas
# terdekat : dekat
# batasan : batas
# taqi : taqi
# taqiya : taqiya
# kesempatan : sempat
# hepi : hepi
# cashback : cashback
# poin : poin
# mak : mak
# aulia : aulia
# corporate : corporate
# upload : upload
# naek : naek
# dongg : dongg
# sudirman : sudirman
# cup : cup
# dotcom : dotcom
# kjdn : kjdn
# sam : sam
# cia : cia
# waspada : waspada
# virus : virus
# corona : corona
# hindari : hindar
# yawlah : yawlah
# bsok : bsok
# nagih : nagih
# ribet : ribet
# ditelpon : telpon
# bro : bro
# kawan : kawan
# siput : siput
# permasalahan : masalah
# bermingguminggu : bermingguminggu
# edge : edge
# sik : sik
# ning : ning
# meneh : teh
# hpku : hpku
# baterene : baterene
# dadi : dadi
# awet : awet
# benci : benci
# busukk : busukk
# zalfa : zalfa
# erick : erick
# thohir : thohir
# pimpinan : pimpin
# diambil : ambil
# alih : alih
# angkasa : angkasa
# pura : pura
# rakyat : rakyat
# kimia : kimia
# farma : farma
# persero : persero
# diambilalih : diambilalih
# bundling : bundling
# menguntungkan : untung
# ambil : ambil
# toko : toko
# buset : buset
# dritd : dritd
# fahmi : fahmi
# ragu : ragu
# weh : weh
# hayang : hayang
# sialan : sial
# beneran : beneran
# boong : boong
# valorant : valorant
# dibelikan : beli
# gedung : gedung
# sahid : sahid
# harian : hari
# ayoo : ayoo
# saksikan : saksi
# pertandingannya : tanding
# pasang : pasang
# taruhanmu : taruh
# hitsbola : hitsbola
# mainkan : main
# bermain : main
# april : april
# trias : trias
# singer : singer
# marla : marla
# tambahan : tambah
# perbedaan : beda
# pengaruh : pengaruh
# anjg : anjg
# bunga : bunga
# bauk : bauk
# pin : pin
# selesaiin : selesaiin
# kendalanya : kendala
# memakai : pakai
# permata : permata
# trim : trim
# belajar : ajar
# allhamdulillah : allhamdulillah
# kupake : kupake
# anime : anime
# ambilnya : ambil
# indomart : indomart
# konter : konter
# samping : samping
# akntor : akntor
# beliii : beliii
# bantuinnn : bantuinnn
# kaka : kaka
# tes : tes
# sempetin : sempetin
# bentar : bentar
# fokus : fokus
# aktivitasmu : aktivitas
# chat : chat
# asisten : asisten
# virtual : virtual
# hmssss : hmssss
# baiklah : baik
# kupi : kupi
# kental : kental
# kenal : kenal
# lawan : lawan
# mental : mental
# kelas : kelas
# fenomenal : fenomenal
# markipiut : markipiut
# mari : mari
# srupiuuuut : srupiuuuut
# atensien : atensien
# nyang : nyang
# bloonan : bloonan
# sikat : sikat
# ji : ji
# nk : nk
# dilarank : dilarank
# ngupi : ngupi
# barenk : barenk
# anin : anin
# pantau : pantau
# melisacl : melisacl
# zoelfikar : zoelfikar
# berkala : kala
# den : den
# menang : menang
# bin : bin
# nyonyot : nyonyot
# teknisnya : teknis
# gampang : gampang
# claimnya : claimnya
# penukaran : tukar
# ketentuan : tentu
# subdealer : subdealer
# lebong : lebong
# suprapto : suprapto
# talang : talang
# rimbo : rimbo
# curup : curup
# simpang : simpang
# perumnas : perumnas
# rejang : rejang
# ketapel : ketapel
# bertarung : tarung
# bersenjatakan : senjata
# tank : tank
# nia : nia
# lambatnya : lambat
# website : website
# github : github
# stackoverflow : stackoverflow
# okee : okee
# nyatabya : nyatabya
# telkomnyet : telkomnyet
# daun : daun
# bangkrut : bangkrut
# belanja : belanja
# item : item
# sale : sale
# diamonds : diamonds
# pos : pos
# official : official
# bungkus : bungkus
# tertera : tera
# juli : juli
# jesse : jesse
# pinjam : pinjam
# ngecengin : ngecengin
# madrid : madrid
# tambahin : tambahin
# otrayigus : otrayigus
# coffeecandy : coffeecandy
# chandz : chandz
# gede : gede
# pulang : pulang
# ngadepin : ngadepin
# persidangan : sidang
# bocor : bocor
# sewa : sewa
# kolam : kolam
# diskusi : diskusi
# silaturahmi : silaturahmi
# ceo : ceo
# menyerahkan : serah
# buku : buku
# karya : karya
# pilar : pilar
# pembangunan : bangun
# bangsa : bangsa
# integritas : integritas
# bangsaku : bangsa
# bermanfaat : manfaat
# diberkahi : kah
# screenshot : screenshot
# sblm : sblm
# citranet : citranet
# notif : notif
# ooh : ooh
# dika : dika
# olympic : olympic
# loker : loker
# sma : sma
# smk : smk
# persyaratannya : syarat
# iyoo : iyoo
# ngo : ngo
# menangis : menang
# streamingan : streamingan
# acara : acara
# musik : musik
# favoritmu : favorit
# wfh : wfh
# hambatan : hambat
# terkuat : kuat
# terluas : luas
# senilai : nila
# periode : periode
# sept : sept
# roblox : roblox
# currency : currency
# slmt : slmt
# tselnya : tselnya
# kumpulin : kumpulin
# frustasi : frustasi
# lylia : lylia
# diunduh : unduh
# play : play
# reamur : reamur
# switch : switch
# network : network
# kompatibel : kompatibel
# install : install
# demongkrak : dongkrak
# hambalang : hambalang
# mangkrak : mangkrak
# kurupsi : kurupsi
# ngembat : ngembat
# century : century
# blt : blt
# gila : gila
# waang : waang
# pantek : pantek
# ang : ang
# sekolah : sekolah
# menjaga : jaga
# menginfokan : info
# disalahgunakan : disalahgunakan
# hiks : hiks
# begelud : begelud
# eitia : eitia
# beralih : alih
# daya : daya
# okay : okay
# linta : linta
# push : push
# rank : rank
# bayarnya : bayar
# papatungan : papatungan
# yakk : yakk
# jibal : jibal
# bakoel : bakoel
# direct : direct
# live : live
# terinstall : terinstall
# resmi : resmi
# probono : probono
# nyarinya : nyarinya
# blokir : blokir
# dihubungi : hubung
# penipuan : tipu
# lokasinya : lokasi
# aktifinya : aktif
# lapor : lapor
# diteror : teror
# dikenal : kenal
# kasusmu : kasus
# kelar : kelar
# sombong : sombong
# tob : tob
# deny : deny
# loe : loe
# mikir : mikir
# ketipu : tipu
# famplan : famplan
# inplan : inplan
# biasnya : bias
# hewanya : hewanya
# didalem : dalem
# perpaduan : padu
# menguji : uji
# ide : ide
# kado : kado
# bahagia : bahagia
# kejutan : kejut
# terduga : duga
# kemari : kemari
# rekomen : rekomen
# miskin : miskin
# lawyernya : lawyernya
# mgk : mgk
# lawyer : lawyer
# ngurus : ngurus
# ketengan : keteng
# mabar : mabar
# aov : aov
# konsumen : konsumen
# seimbang : imbang
# nonstopnya : nonstop
# kestabilan : stabil
# pakein : pakein
# secare : secare
# rizki : rizki
# memilih : pilih
# putri : putri
# gading : gading
# cempaka : cempaka
# penurunan : turun
# ratu : ratu
# samban : samban
# bengkulu : bengkulu
# adnan : adnan
# buzzer : buzzer
# ngitung : ngitung
# kasian : kasi
# cahyadi : cahyadi
# put : put
# lilo : lilo
# trilyunan : trilyunan
# prnh : prnh
# guys : guys
# kecepatannya : cepat
# grgr : grgr
# berapaan : berapa
# senin : senin
# player : player
# training : training
# jersey : jersey
# persib : persib
# muk : muk
# jaga : jaga
# prov : prov
# aing : aing
# bingung : bingung
# perdalam : dalam
# ilmu : ilmu
# agama : agama
# kesibukan : sibuk
# bubbly : bubbly
# tausyiah : tausyiah
# ceramah : ceramah
# bawa : bawa
# iphone : iphone
# simcard : simcard
# imei : imei
# kece : kece
# sad : sad
# nyai : nyai
# dingin : dingin
# tibatiba : tibatiba
# atuh : atuh
# penjelasan : jelas
# warning : warning
# dirumaku : dirumaku
# aneh : aneh
# wllwlw : wllwlw
# aida : aida
# joni : joni
# tolongg : tolongg
# yakkk : yakkk
# gabisaa : gabisaa
# dinyalain : dinyalain
# pencet : pencet
# power : power
# button : button
# pke : pke
# murahnya : murah
# bruh : bruh
# what : what
# twitch : twitch
# istg : istg
# muke : muke
# jamban : jamban
# berisik : berisik
# mnt : mnt
# raya : raya
# pontianak : pontianak
# ngabang : ngabang
# serius : serius
# neng : neng
# hawaii : hawaii
# kono : kono
# nggada : nggada
# soale : soale
# mbak : mbak
# tokopedia : tokopedia
# bel : bel
# diskon : diskon
# ngece : ngece
# ngikut : ngikut
# separah : parah
# ngeluh : ngeluh
# ckckck : ckckck
# gez : gez
# gumilar : gumilar
# voucher : voucher
# dijual : jual
# sihh : sihh
# gabti : gabti
# nyusahin : nyusahin
# anaz : anaz
# alhamdulillah : alhamdulillah
# hah : hah
# rudet : rudet
# ajig : ajig
# hygbt : hygbt
# jatuh : jatuh
# cinta : cinta
# heri : heri
# yoga : yoga
# gretonk : gretonk
# yusril : yusril
# megap : megap
# kalino : kalino
# koar : koar
# geblek : geblek
# mulut : mulut
# huhuh : huhuh
# maluu : maluu
# mba : mba
# konternya : konter
# smpe : smpe
# densi : densi
# bodonya : bodonya
# tamat : tamat
# aturan : atur
# hukum : hukum
# kuasa : kuasa
# bacaannya : baca
# bkn : bkn
# advokat : advokat
# ente : ente
# nilai : nilai
# kebenaran : benar
# keadilan : adil
# dikedepankan : depan
# besarnya : besar
# hny : hny
# dlm : dlm
# berbohong : bohong
# bajet : bajet
# otak : otak
# minim : minim
# petinju : tinju
# badan : badan
# jaminan : jamin
# sekil : sekil
# kelincahan : lincah
# tarung : tarung
# byk : byk
# skg : skg
# frinzy : frinzy
# card : card
# ketentuannya : tentu
# responn : responn
# berr : berr
# isa : isa
# dosen : dosen
# bod : bod
# pahamnya : paham
# ngilang : ngilang
# paham : paham
# klaten : klaten
# tulung : tulung
# bertepi : tepi
# dikuliti : kulit
# kuntadi : kuntadi
# pekok : kok
# ngulitin : ngulitin
# handal : handal
# sulit : sulit
# perkuliahan : kuliah
# terhambat : hambat
# saiki : saiki
# tontonanku : tonton
# candaan : canda
# ruang : ruang
# uninstall : uninstall
# contact : contact
# nyimpenin : nyimpenin
# justin : justin
# bieber : bieber
# selena : lena
# gomez : gomez
# miley : miley
# cyrus : cyrus
# simpenin : simpenin
# negeri : negeri
# jir : jir
# cacat : cacat
# anggarannya : anggar
# biayain : biayain
# demo : demo
# bocah : bocah
# pras : pras
# agung : agung
# testi : testi
# dibio : dibio
# testt : testt
# fuckkkk : fuckkkk
# knapa : knapa
# galang : galang
# donasi : donasi
# noona : noona
# tisna : tisna
# receh : receh
# siregar : siregar
# melawan : lawan
# tse : tse
# uang : uang
# sieeeee : sieeeee
# ifan : ifan
# wml : wml
# blbi : blbi
# membela : bela
# kopi : kopi
# sianida : sianida
# kebaca : baca
# gayanya : gaya
# bilanglah : bilang
# pemerintah : perintah
# curang : curang
# jokowilah : jokowilah
# taek : taek
# onlaen : onlaen
# bsa : bsa
# batas : batas
# moga : moga
# aging : aging
# tenggangnya : tenggang
# direaktivasi : direaktivasi
# dewasa : dewasa
# terdaftar : daftar
# perbankan : perban
# digit : digit
# membawa : bawa
# identitas : identitas
# paspor : paspor
# ...
# rutinitas : rutinitas
# ngawor : ngawor
# bokek : bokek
# bedua : bedua
# tobat : tobat
# butuhh : butuhh
# aaaa : aaaa
# kbps : kbps
# mengganggu : ganggu
# iki : iki
# atek : atek
# lapo : lapo
# arep : arep
# isok : isok
# lek : lek
# gawe : gawe
# menonaktifkan : nonaktif
# pop : pop
# btol : btol
# konth : konth
# parhan : parhan
# klaim : klaim
# zalora : zalora
# pembelanjaan : belanja
# testimoni : testimoni
# oxygen : oxygen
# bannernya : bannernya
# dijalan : jalan
# lamalama : lamalama
# taunya : tau
# conversa : conversa
# day : day
# webinar : webinar
# dibahas : bahas
# dharma : dharma
# simorangkir : simorangkir
# svp : svp
# enterprise : enterprise
# ainun : ainun
# najib : najib
# praktisi : praktisi
# ahli : ahli
# sains : sains
# teknologi : teknologi
# ewallet : ewallet
# mini : mini
# mingguan : minggu
# kouta : kouta
# bareng : bareng
# rasain : rasain
# outlet : outlet
# subscriber : subscriber
# device : device
# tablet : tablet
# trouble : trouble
# yosh : yosh
# panggilannya : panggil
# kesalahan : salah
# kiriim : kiriim
# foto : foto
# copy : copy
# invest : invest
# mesin : mesin
# potokopi : potokopi
# lukman : lukman
# sidiq : sidiq
# interaksiselanjutnya : interaksiselanjutnya
# home : home
# marketing : marketing
# samaa : samaa
# payahhh : payahhh
# kasihhh : kasihhh
# afni : afni
# penawaraan : penawaraan
# dihitungnya : hitung
# dminta : dminta
# masukan : masuk
# memasukkan : masuk
# ato : ato
# lemotnya : lot
# tobaaattttt : tobaaattttt
# informasikah : informasi
# mastip : mastip
# migrasi : migrasi
# batalkan : batal
# ngucapin : ngucapin
# depannya : depan
# ilyjake : ilyjake
# nay : nay
# terjangkau : jangkau
# dokter : dokter
# dateng : dateng
# teriakkk : teriakkk
# edwin : edwin
# kombo : kombo
# sulawesi : sulawesi
# maluku : malu
# cable : cable
# system : system
# smpcs : smpcs
# satelit : satelit
# radio : radio
# cyber : cyber
# security : security
# attack : attack
# ddos : ddos
# protection : protection
# ngentot : ngentot
# price : price
# likes : likes
# jaraaaang : jaraaaang
# ris : ris
# wal : wal
# mamaku : mama
# menelpon : telpon
# kada : kada
# okey : okey
# trimakasih : trimakasih
# anis : anis
# udahh : udahh
# nathalie : nathalie
# ketahuan : tahu
# matikan : mati
# olin : olin
# ngerasa : ngerasa
# sch : sch
# trivia : trivia
# khawarizmi : khawarizmi
# muhammad : muhammad
# ibn : ibn
# musa : musa
# khwarizmi : khwarizmi
# dijuluki : juluk
# aljabar : aljabar
# arif : arif
# laporan : lapor
# miin : miin
# himbau : himbau
# menampilkan : tampil
# ponsel : ponsel
# laman : laman
# komentar : komentar
# dwi : dwi
# komplen : komplen
# diwaro : diwaro
# waro : waro
# harif : harif
# diinfokan : info
# article : article
# kblikannya : kblikannya
# prnah : prnah
# bangunnya : bangun
# jadwal : jadwal
# presensi : presensi
# ditiadakan : tiada
# pdhal : pdhal
# ttangga : ttangga
# indiehome : indiehome
# hoki : hoki
# seumur : umur
# yunus : yunus
# coverage : coverage
# surabaya : surabaya
# pemuda : pemuda
# ilangan : ilangan
# gebetan : gebetan
# matkul : matkul
# diulang : ulang
# ngetweet : ngetweet
# ifgd : ifgd
# mtt : mtt
# assalamualaikum : assalamualaikum
# warrahmatullahi : warrahmatullahi
# wabarakatuh : wabarakatuh
# syiarkan : syiar
# majelis : majelis
# taqwa : taqwa
# mengundang : undang
# muslimin : muslimin
# muslimat : muslimat
# rabu : rabu
# panggilan : panggil
# merestart : merestart
# taupik : taupik
# nek : nek
# harapan : harap
# kakkk : kakkk
# gabut : gabut
# sistemnya : sistem
# unfaedah : unfaedah
# nonaktifkan : nonaktif
# marcel : marcel
# hdhcnzjjdjx : hdhcnzjjdjx
# supportnya : supportnya
# loyo : loyo
# internetny : internetny
# tercover : tercover
# andreas : andreas
# menkominfo : menkominfo
# urusin : urusin
# telekomunikasi : telekomunikasi
# mentri : tri
# perhubungan : hubung
# ngasih : ngasih
# nich : nich
# maling : maling
# rampok : rampok
# kagak : kagak
# saudara : saudara
# pstn : pstn
# berkali : kali
# zhe : zhe
# dihapus : hapus
# terhapus : hapus
# direcycle : direcycle
# apanih : apanih
# remuk : remuk
# aga : aga
# bertahun : tahun
# muka : muka
# wkwkwkwkwkw : wkwkwkwkwkw
# smsm : smsm
# wendy : wendy
# luckk : luckk
# giveawayynya : giveawayynya
# yuuukkk : yuuukkk
# etalase : etalase
# tertempel : tempel
# stiker : stiker
# hot : hot
# terstiker : stiker
# salam : salam
# cuan : cuan
# berkualitas : kualitas
# anaknya : anak
# butut : butut
# dahlah : dah
# uti : uti
# balai : balai
# gadang : gadang
# koto : koto
# tangah : tangah
# teratasi : atas
# kl : kl
# ra : ra
# eka : eka
# dom : dom
# wireless : wireless
# males : males
# teknisi : teknisi
# woeeh : woeeh
# semenit : menit
# judi : judi
# dibackground : dibackground
# cuk : cuk
# keknya : kek
# gapake : gapake
# teknis : teknis
# rheeva : rheeva
# dmahalin : dmahalin
# smua : smua
# ayyy : ayyy
# uts : uts
# nihh : nihh
# picknava : picknava
# vidi : vidi
# makasihhh : makasihhh
# romi : romi
# rina : rina
# convo : convo
# telp : telp
# terlamabat : terlamabat
# maitau : maitau
# selingkuh : selingkuh
# tuln : tuln
# bismillahirahmanirahim : bismillahirahmanirahim
# memperkenalkan : kenal
# kuncie : kuncie
# platform : platform
# video : video
# masyarakat : masyarakat
# tertarik : tarik
# jenius : jenius
# tahunan : tahun
# kredit : kredit
# itunes : itunes
# hoiii : hoiii
# benerin : benerin
# rayhan : rayhan
# goodgoodbye : goodgoodbye
# eksis : eks
# gemas : gemas
# tempatku : tempat
# pinjaman : pinjam
# sudi : sudi
# beckham : beckham
# nugraha : nugraha
# brengsek : brengsek
# adminya : adminya
# ngajakin : ngajakin
# dm : dm
# dikata : kata
# kitorang : kitorang
# trauma : trauma
# tajelas : tajelas
# momon : momon
# cloverqq : cloverqq
# winrate : winrate
# bettor : bettor
# juta : juta
# referral : referral
# registrasi : registrasi
# privilege : privilege
# rsud : rsud
# disediakan : sedia
# dirs : dirs
# menonton : tonton
# resolusi : resolusi
# bertugas : tugas
# mentionin : mentionin
# kuotanya : kuota
# jar : jar
# biaya : biaya
# hufffff : hufffff
# abay : abay
# onkan : onkan
# wilda : wilda
# pantes : pantes
# pemenangnya : menang
# ditunjukin : ditunjukin
# xxxx : xxxx
# orangnya : orang
# fotonya : foto
# apadah : apadah
# dih : dih
# anjr : anjr
# gandeng : gandeng
# akakk : akakk
# terlaksana : laksana
# ojo : ojo
# mneh : mneh
# melu : melu
# terang : terang
# benderang : benderang
# lemote : lemote
# kuning : kuning
# mkddr : mkddr
# ijudin : ijudin
# rahmat : rahmat
# farah : farah
# ket : ket
# knoa : knoa
# ckup : ckup
# progress : progress
# msk : msk
# dipekanbaru : dipekanbaru
# pekanbaru : pekanbaru
# xnova : xnova
# rue : rue
# ruruh : ruruh
# beautiful : beautiful
# dayyy : dayyy
# hasilnya : hasil
# memudahkan : mudah
# fendy : fendy
# prepaid : prepaid
# gosah : gosah
# dimari : mari
# selam : selam
# jet : jet
# helikopter : helikopter
# kirimkan : kirim
# membangun : bangun
# mempercepat : cepat
# terealisasinya : real
# diajak : ajak
# smga : smga
# rezeki : rezeki
# huft : huft
# nurul : nurul
# pembuatan : buat
# linebank : linebank
# tercatat : catat
# gabung : gabung
# priaqq : priaqq
# vicky : vicky
# nyri : nyri
# bnyk : bnyk
# nii : nii
# lgsng : lgsng
# bec : bec
# mall : mall
# beralamat : alamat
# electronic : electronic
# centre : centre
# purnawarman : purnawarman
# dago : dago
# juanda : juanda
# gratisnya : gratis
# alfamidi : alfamidi
# dwif : dwif
# didapatkan : dapat
# arumbai : arumba
# terblokir : blokir
# mirna : mirna
# entangkita : entangkita
# nantikan : nanti
# umb : umb
# fanda : fanda
# smpai : smpai
# jakub : jakub
# sayuti : sayuti
# nsp : nsp
# nafi : nafi
# keteledoran : teledor
# kekurang : kurang
# tahuan : tahu
# pengambilan : ambil
# menguasai : kuasa
# hak : hak
# seijin : seijin
# kriminal : kriminal
# pencurian : curi
# memaksa : paksa
# cobalah : coba
# halal : halal
# polri : polri
# sri : sri
# terkena : kena
# akad : akad
# perjanjiannya : janji
# hbo : hbo
# avail : avail
# katalog : katalog
# kaaak : kaaak
# jack : jack
# undi : undi
# testimoninya : testimoninya
# fee : fee
# idn : idn
# moldova : moldova
# fix : fix
# tepakai : tepakai
# hufp : hufp
# smoga : smoga
# pubg : pubg
# ptmdh : ptmdh
# past : past
# medic : medic
# sikit : sikit
# dicover : dicover
# mreka : mreka
# mengkases : mengkases
# regulernya : reguler
# hbs : hbs
# total : total
# legends : legends
# garena : garena
# arena : arena
# valor : valor
# let : let
# get : get
# rich : rich
# shellfire : shellfire
# black : black
# desert : desert
# lifeafter : lifeafter
# rise : rise
# nowlins : nowlins
# war : war
# tutorial : tutorial
# phase : phase
# key : key
# warnain : warnain
# mang : mang
# asuk : asuk
# crownqq : crownqq
# rollingan : rollingan
# refferal : refferal
# betcrownqq : betcrownqq
# lfc : lfc
# halahh : halahh
# fikrii : fikrii
# fikri : fikri
# jauhary : jauhary
# arindra : arindra
# dinty : dinty
# grasia : grasia
# prosesnya : proses
# melek : melek
# vcs : vcs
# nyaingin : nyaingin
# tempo : tempo
# enteng : enteng
# mengacaukan : acau
# disaat : saat
# zezen : zezen
# panduan : pandu
# ghivary : ghivary
# rahasinya : rahasinya
# jak : jak
# trakhir : trakhir
# ngirit : ngirit
# amit : amit
# trf : trf
# woiii : woiii
# cokkkk : cokkkk
# mao : mao
# iat : iat
# yaallah : yaallah
# pemiliknya : milik
# tolol : tolol
# robert : robert
# rahasia : rahasia
# {'hai': 'hai', 'kak': 'kak', 'fajri': 'fajri', 'makasih': 'makasih', 'data': 'data', 'datanya': 'data', 'mimin': 'mimin', 'saranin': 'saranin', 'nggak': 'nggak', 'mencantumkan': 'cantum', 'pribadi': 'pribadi', 'kolom': 'kolom', 'tweet': 'tweet', 'menghindari': 'hindar', 'potensi': 'potensi', 'penyalahgunaan': 'penyalahgunaan', 'bertanggung': 'tanggung', 'yuk': 'yuk', 'sapa': 'sapa', 'tks': 'tks', 'flo': 'flo', 'bgtu': 'bgtu', 'kenyataannya': 'nyata', '': '', 'pagi': 'pagi', 'rizky': 'rizky', 'maaf': 'maaf', 'kakak': 'kakak', 'nyaman': 'nyaman', 'terkait': 'kait', 'paket': 'paket', 'giga': 'giga', 'net': 'net', 'tersedia': 'sedia', 'akses': 'akses', 'interaksinya': 'interaksi', 'via': 'via', 'infokan': 'info', 'bantu': 'bantu', 'cek': 'cek', 'privasi': 'privasi', 'terjaga': 'jaga', 'ditunggu': 'tunggu', 'lena': 'lena', 'jual': 'jual', 'pulsa': 'pulsa', 'tsel': 'tsel', 'telkomsel': 'telkomsel', 'axis': 'axis', 'isat': 'isat', 'indosat': 'indosat', 'harga': 'harga', 'murah': 'murah', 'banget': 'banget', 'transfer': 'transfer', 'menambah': 'tambah', 'aktif': 'aktif', 'elektrik': 'elektrik', 'nambah': 'nambah', 'followan': 'followan', 'mutualan': 'mutualan', 'like': 'like', 'butuh': 'butuh', 'need': 'need', 'cheap': 'cheap', 'min': 'min', 'tekan': 'tekan', 'muncul': 'muncul', 'combo': 'combo', 'extra': 'extra', 'solusi': 'solusi', 'gmana': 'gmana', 'kos': 'kos', 'buk': 'buk', 'ida': 'ida', 'mutiara': 'mutiara', 'kasih': 'kasih', 'ramadhani': 'ramadhani', 'off': 'off', 'hpbsaya': 'hpbsaya', 'pakai': 'pakai', 'nyangkut': 'nyangkut', 'kirim': 'kirim', 'emg': 'emg', 'suka': 'suka', 'pilih': 'pilih', 'ngasi': 'ngasi', 'promo': 'promo', 'emang': 'emang', 'mahal': 'mahal', 'membangsatipun': 'bangsat', 'nomor': 'nomor', 'dapet': 'dapet', 'ayahku': 'ayah', 'hangus': 'hangus', 'reaktivasi': 'reaktivasi', 'syarat': 'syarat', 'tenggang': 'tenggang', 'infoin': 'infoin', 'lokasi': 'lokasi', 'detail': 'detail', 'dibantu': 'bantu', 'uli': 'uli', 'layanannya': 'layan', 'orbit': 'orbit', 'telkom': 'telkom', 'indihome': 'indihome', 'kanibal': 'kanibal', 'halo': 'halo', 'diaktifkan': 'aktif', 'mohon': 'mohon', 'informasinya': 'informasi', 'apapun': 'apa', 'lakukan': 'laku', 'terima': 'terima', 'bener': 'bener', 'emosi': 'emosi', 'yaa': 'yaa', 'guenya': 'gue', 'tinggal': 'tinggal', 'pedalaman': 'dalam', 'pengguna': 'guna', 'sentuh': 'sentuh', 'ronny': 'ronny', 'meluncur': 'luncur', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'interaksi': 'interaksi', 'mimim': 'mimim', 'kuota': 'kuota', 'omg': 'omg', 'nonton': 'nonton', 'gb': 'gb', 'youtube': 'youtube', 'maxstream': 'maxstream', 'facebook': 'facebook', 'instagram': 'instagram', 'whatsapp': 'whatsapp', 'line': 'line', 'games': 'games', 'max': 'max', 'music': 'music', 'tiktok': 'tiktok', 'mola': 'mola', 'viu': 'viu', 'disney': 'disney', 'amazon': 'amazon', 'vidio': 'vidio', 'lionsgate': 'lionsgate', 'tolong': 'tolong', 'sinyal': 'sinyal', 'jalur': 'jalur', 'krl': 'krl', 'rangkas': 'rangkas', 'sampe': 'sampe', 'maja': 'maja', 'dibenerin': 'dibenerin', 'mulu': 'mulu', 'tobelly': 'tobelly', 'sofia': 'sofia', 'kendala': 'kendala', 'aktivasi': 'aktivasi', 'mytelkomsel': 'mytelkomsel', 'udah': 'udah', 'coba': 'coba', 'restart': 'restart', 'nohp': 'nohp', 'kel': 'kel', 'kec': 'kec', 'kota': 'kota', 'infonya': 'info', 'selamat': 'selamat', 'gagal': 'gagal', 'transaksi': 'transaksi', 'app': 'app', 'veronika': 'veronika', 'template': 'template', 'tlp': 'tlp', 'antri': 'antri', 'urgent': 'urgent', 'menjalani': 'jalan', 'indah': 'indah', 'berkendala': 'kendala', 'dikirimkan': 'kirim', 'titik': 'titik', 'koordinat': 'koordinat', 'google': 'google', 'maps': 'maps', 'pengecekan': 'kece', 'akurat': 'akurat', 'marsel': 'marsel', 'tetep': 'tetep', 'tanggal': 'tanggal', 'kejadian': 'jadi', 'minimal': 'minimal', 'informasi': 'informasi', 'kelurahan': 'lurah', 'nama': 'nama', 'jalan': 'jalan', 'keluhan': 'keluh', 'jaringan': 'jaring', 'menyebabkan': 'sebab', 'internet': 'internet', 'lambat': 'lambat', 'mencoba': 'coba', 'refre ...
# ------------------------
# Pandas Apply:   0%|          | 0/1901 [00:00<?, ?it/s]
#                                                 content  \
# 0     @fajrisabti hai kak fajri. makasih ya buat dat...
# 1     @vemipelawi @dennysiregar7 @pdemokrat @telkoms...
# 2     @rizkylbs_ pagi, kak rizky. maaf ya jadi buat ...
# 3     hai kak, aku jual pulsa xl, tsel, telkomsel, a...
# 4     min @telkomsel no saya kok tidak ada paket gig...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  @telkomsel boleh diwakilkan atau harus pemilik...
# 1997    telkomsel tolol amat buat aplikasi ga jelas anj
# 1998  cari uang tambahan dengan modal 20 ribu..??\nb...
# 1999  @robertp43247255 hai, kak robert. maaf ya mimi...
#
#                                          cleaning_tweet  \
# 0     hai kak fajri makasih buat data datanya namun ...
# 1                             memang bgtu kenyataannya
# 2      pagi kak rizky maaf jadi buat kakak nyaman te...
# 3     hai kak aku jual pulsa tsel telkomsel axis isa...
# 4     min saya kok tidak ada paket giga net saya sud...
# ...                                                 ...
# 1995                   yaallah mau marah sama telkomsel
# 1996  boleh diwakilkan atau harus pemiliknya sendiri...
# 1997       telkomsel tolol amat buat aplikasi jelas anj
# 1998  cari uang tambahan dengan modal ribu bonus rol...
# 1999  hai kak robert maaf mimin infokan terkait kode...
#
#                                              tokenisasi  \
# 0     [hai, kak, fajri, makasih, buat, data, datanya...
# 1                        [memang, bgtu, kenyataannya, ]
# 2     [, pagi, kak, rizky, maaf, jadi, buat, kakak, ...
# 3     [hai, kak, aku, jual, pulsa, tsel, telkomsel, ...
# 4     [min, saya, kok, tidak, ada, paket, giga, net,...
# ...                                                 ...
# 1995             [yaallah, mau, marah, sama, telkomsel]
# 1996  [boleh, diwakilkan, atau, harus, pemiliknya, s...
# 1997  [telkomsel, tolol, amat, buat, aplikasi, jelas...
# 1998  [cari, uang, tambahan, dengan, modal, ribu, bo...
# 1999  [hai, kak, robert, maaf, mimin, infokan, terka...
#
#                                                stopword  \
# 0     [hai, kak, fajri, makasih, data, datanya, mimi...
# 1                                [bgtu, kenyataannya, ]
# 2     [, pagi, kak, rizky, maaf, kakak, nyaman, terk...
# 3     [hai, kak, jual, pulsa, tsel, telkomsel, axis,...
# 4     [min, paket, giga, net, tekan, muncul, paket, ...
# ...                                                 ...
# 1995                        [yaallah, marah, telkomsel]
# 1996   [diwakilkan, pemiliknya, min, dateng, grapari, ]
# 1997                       [telkomsel, tolol, aplikasi]
# 1998  [cari, uang, tambahan, modal, ribu, bonus, rol...
# 1999  [hai, kak, robert, maaf, mimin, infokan, terka...
#
#                                                stemming
# 0     [hai, kak, fajri, makasih, data, data, mimin, ...
# 1                                       [bgtu, nyata, ]
# 2     [, pagi, kak, rizky, maaf, kakak, nyaman, kait...
# 3     [hai, kak, jual, pulsa, tsel, telkomsel, axis,...
# 4     [min, paket, giga, net, tekan, muncul, paket, ...
# ...                                                 ...
# 1995                        [yaallah, marah, telkomsel]
# 1996             [wakil, milik, min, dateng, grapari, ]
# 1997                       [telkomsel, tolol, aplikasi]
# 1998  [cari, uang, tambah, modal, ribu, bonus, rolli...
# 1999  [hai, kak, robert, maaf, mimin, info, kait, ko...
#
# [1901 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [hai, kak, fajri, makasih, data, data, mimin, ...
# 1                                       [bgtu, nyata, ]
# 2     [, pagi, kak, rizky, maaf, kakak, nyaman, kait...
# 3     [hai, kak, jual, pulsa, tsel, telkomsel, axis,...
# 4     [min, paket, giga, net, tekan, muncul, paket, ...
# ...                                                 ...
# 1995                        [yaallah, marah, telkomsel]
# 1996             [wakil, milik, min, dateng, grapari, ]
# 1997                       [telkomsel, tolol, aplikasi]
# 1998  [cari, uang, tambah, modal, ribu, bonus, rolli...
# 1999  [hai, kak, robert, maaf, mimin, info, kait, ko...
#
# [1901 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_9.xlsx')
