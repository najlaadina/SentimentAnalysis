# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @quanshika Permisi.. Nitip iklan ya kak🙇‍♀️ Re...
# 1     96. Testi pembelian ; jual pulsa telkomsel mur...
# 2                @Telkomsel @pppunten @Telkomsel cek dm
# 3     @buburayamena Sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1995  @rizqycipta Baik, Kak. Mimin cek DM Kakak suda...
# 1996  Bos jaringan lu tengah malem gg parah sih @Tel...
# 1997  @gaze_valiant Jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant Hai, Kak. Mohon maaf, perihal ke...
# 1999                              @Telkomsel cek dm min
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 25

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @quanshika Permisi.. Nitip iklan ya kak🙇‍♀️ Re...
# 1     96. Testi pembelian ; jual pulsa telkomsel mur...
# 2                @Telkomsel @pppunten @Telkomsel cek dm
# 3     @buburayamena Sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1993  @spicygiggle @GamesMenfess @erlandarln report ...
# 1995  @rizqycipta Baik, Kak. Mimin cek DM Kakak suda...
# 1996  Bos jaringan lu tengah malem gg parah sih @Tel...
# 1997  @gaze_valiant Jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant Hai, Kak. Mohon maaf, perihal ke...
#
# [1953 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @quanshika permisi.. nitip iklan ya kak🙇‍♀️ re...
# 1     96. testi pembelian ; jual pulsa telkomsel mur...
# 2                @telkomsel @pppunten @telkomsel cek dm
# 3     @buburayamena sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1993  @spicygiggle @gamesmenfess @erlandarln report ...
# 1995  @rizqycipta baik, kak. mimin cek dm kakak suda...
# 1996  bos jaringan lu tengah malem gg parah sih @tel...
# 1997  @gaze_valiant jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant hai, kak. mohon maaf, perihal ke...
#
# [1953 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @quanshika permisi.. nitip iklan ya kak🙇‍♀️ re...
# 1     96. testi pembelian ; jual pulsa telkomsel mur...
# 2                @telkomsel @pppunten @telkomsel cek dm
# 3     @buburayamena sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1993  @spicygiggle @gamesmenfess @erlandarln report ...
# 1995  @rizqycipta baik, kak. mimin cek dm kakak suda...
# 1996  bos jaringan lu tengah malem gg parah sih @tel...
# 1997  @gaze_valiant jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant hai, kak. mohon maaf, perihal ke...
#
#                                          cleaning_tweet
# 0     permisi nitip iklan kak readystock nomer canti...
# 1            testi pembelian jual pulsa telkomsel murah
# 2                                                  cek
# 3     sama aku juga dpt ucapan selamat pagi dari ope...
# 4     open convert pulsa tri three axis tsel telkoms...
# ...                                                 ...
# 1993                                   report telkomsel
# 1995  baik kak mimin cek kakak sudah masuk antrian m...
# 1996           bos jaringan tengah malem parah sih cek
# 1997   valiant jika sudah namun tetap sama yuk infok...
# 1998   valiant hai kak mohon maaf perihal kendala si...
#
# [1953 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @quanshika permisi.. nitip iklan ya kak🙇‍♀️ re...
# 1     96. testi pembelian ; jual pulsa telkomsel mur...
# 2                @telkomsel @pppunten @telkomsel cek dm
# 3     @buburayamena sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1993  @spicygiggle @gamesmenfess @erlandarln report ...
# 1995  @rizqycipta baik, kak. mimin cek dm kakak suda...
# 1996  bos jaringan lu tengah malem gg parah sih @tel...
# 1997  @gaze_valiant jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant hai, kak. mohon maaf, perihal ke...
#
#                                          cleaning_tweet  \
# 0     permisi nitip iklan kak readystock nomer canti...
# 1            testi pembelian jual pulsa telkomsel murah
# 2                                                  cek
# 3     sama aku juga dpt ucapan selamat pagi dari ope...
# 4     open convert pulsa tri three axis tsel telkoms...
# ...                                                 ...
# 1993                                   report telkomsel
# 1995  baik kak mimin cek kakak sudah masuk antrian m...
# 1996           bos jaringan tengah malem parah sih cek
# 1997   valiant jika sudah namun tetap sama yuk infok...
# 1998   valiant hai kak mohon maaf perihal kendala si...
#
#                                              tokenisasi
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1     [, testi, pembelian, jual, pulsa, telkomsel, m...
# 2                                               [cek, ]
# 3     [sama, aku, juga, dpt, ucapan, selamat, pagi, ...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [baik, kak, mimin, cek, kakak, sudah, masuk, a...
# 1996  [bos, jaringan, tengah, malem, parah, sih, cek, ]
# 1997  [, valiant, jika, sudah, namun, tetap, sama, y...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
# [1953 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @quanshika permisi.. nitip iklan ya kak🙇‍♀️ re...
# 1     96. testi pembelian ; jual pulsa telkomsel mur...
# 2                @telkomsel @pppunten @telkomsel cek dm
# 3     @buburayamena sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1993  @spicygiggle @gamesmenfess @erlandarln report ...
# 1995  @rizqycipta baik, kak. mimin cek dm kakak suda...
# 1996  bos jaringan lu tengah malem gg parah sih @tel...
# 1997  @gaze_valiant jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant hai, kak. mohon maaf, perihal ke...
#
#                                          cleaning_tweet  \
# 0     permisi nitip iklan kak readystock nomer canti...
# 1            testi pembelian jual pulsa telkomsel murah
# 2                                                  cek
# 3     sama aku juga dpt ucapan selamat pagi dari ope...
# 4     open convert pulsa tri three axis tsel telkoms...
# ...                                                 ...
# 1993                                   report telkomsel
# 1995  baik kak mimin cek kakak sudah masuk antrian m...
# 1996           bos jaringan tengah malem parah sih cek
# 1997   valiant jika sudah namun tetap sama yuk infok...
# 1998   valiant hai kak mohon maaf perihal kendala si...
#
#                                              tokenisasi  \
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1     [, testi, pembelian, jual, pulsa, telkomsel, m...
# 2                                               [cek, ]
# 3     [sama, aku, juga, dpt, ucapan, selamat, pagi, ...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [baik, kak, mimin, cek, kakak, sudah, masuk, a...
# 1996  [bos, jaringan, tengah, malem, parah, sih, cek, ]
# 1997  [, valiant, jika, sudah, namun, tetap, sama, y...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
#                                                stopword
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1     [, testi, pembelian, jual, pulsa, telkomsel, m...
# 2                                               [cek, ]
# 3     [dpt, ucapan, selamat, pagi, operator, telkoms...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [kak, mimin, cek, kakak, masuk, antrian, mohon...
# 1996               [bos, jaringan, malem, parah, cek, ]
# 1997  [, valiant, yuk, infokan, nomor, lokasi, nomor...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
# [1953 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3493
# ------------------------
# permisi : permisi
# nitip : nitip
# iklan : iklan
# kak : kak
# readystock : readystock
# nomer : nomer
# cantik : cantik
# start : start
# harga : harga
# rb : rb
# telkomsel : telkomsel
# indosat : indosat
# smart : smart
# cek : cek
# stock : stock
# lbh : lbh
# sesuai : sesuai
# budget : budget
# fastrespon : fastrespon
# rossvalinshop : rossvalinshop
# loc : loc
# malang : malang
# req : req
# shopee : shopee
#  :
# testi : testi
# pembelian : beli
# jual : jual
# pulsa : pulsa
# murah : murah
# dpt : dpt
# ucapan : ucap
# selamat : selamat
# pagi : pagi
# operator : operator
# bahagianya : bahagia
# anjim : anjim
# banget : banget
# open : open
# convert : convert
# tri : tri
# three : three
# axis : axis
# tsel : tsel
# isat : isat
# im : im
# ewallet : ewallet
# bank : bank
# non : non
# premium : premium
# dana : dana
# ovo : ovo
# gopay : gopay
# shopeepay : shopeepay
# linkaja : linkaja
# preset : preset
# lightroom : lightroom
# agen : agen
# kuota : kuota
# halo : halo
# kecepatan : cepat
# produk : produk
# beda : beda
# kartu : kartu
# mohon : mohon
# penjelasan : jelas
# prem : prem
# ios : ios
# andro : andro
# join : join
# dilikes : dilikes
# member : member
# maaf : maaf
# terkait : kait
# keluhan : keluh
# sinyal : sinyal
# stabil : stabil
# udah : udah
# coba : coba
# refresh : refresh
# jaringan : jaring
# pindahkan : pindah
# otomatis : otomatis
# manual : manual
# yuk : yuk
# infoin : infoin
# nomor : nomor
# lokasi : lokasi
# tanggal : tanggal
# kejadian : jadi
# berkendala : kendala
# tks : tks
# asti : asti
# skrg : skrg
# bayar : bayar
# pay : pay
# bales : bales
# kaya : kaya
# gini : gin
# ngebantu : ngebantu
# solusi : solusi
# ujung : ujung
# ujungnya : ujung
# dibales : dibales
# sebenernya : sebenernya
# adminnya : adminnya
# hidup : hidup
# komputer : komputer
# beli : beli
# ekstra : ekstra
# maek : maek
# haji : haji
# gb : gb
# hijaudaun : hijaudaun
# sakit : sakit
# rindu : rindu
# ketik : ketik
# strlm : strlm
# kirim : kirim
# emg : emg
# mantap : mantap
# wkwkw : wkwkw
# recommend : recommend
# game : game
# online : online
# gausah : gausah
# compare : compare
# ama : ama
# sejaringan : jaring
# pabji : pabji
# ms : ms
# byu : byu
# cocok : cocok
# download : download
# streaming : streaming
# speed : speed
# kirain : kirain
# kya : kya
# gitu : gitu
# bosen : bosen
# komplen : komplen
# pakai : pakai
# bagus : bagus
# rumah : rumah
# provider : provider
# dlu : dlu
# dipinggir : pinggir
# jalan : jalan
# rei : rei
# mimin : mimin
# meluncur : luncur
# berkenan : kenan
# menunggu : tunggu
# makasih : makasih
# fadh : fadh
# internet : internet
# ganggu : ganggu
# bln : bln
# gni : gni
# daily : daily
# update : update
# rate : rate
# terima : terima
# support : support
# bca : bca
# bni : bni
# mandiri : mandiri
# admin : admin
# wallet : wallet
# hoyong : hoyong
# mah : mah
# ganti : ganti
# iyeu : iyeu
# utama : utama
# iya : iya
# bener : bener
# teratasi : atas
# setuju : tuju
# jwbanya : jwbanya
# gtu : gtu
# sampe : sampe
# grapari : grapari
# sigyalnya : sigyalnya
# ilang : ilang
# pdhal : pdhal
# tinggal : tinggal
# kota : kota
# paket : paket
# mahal : mahal
# cepet : cepet
# habis : habis
# sigyal : sigyal
# lemah : lemah
# berfikir : berfikir
# sigyalnta : sigyalnta
# urang : urang
# ayeuna : ayeuna
# tos : tos
# lur : lur
# saipul : saipul
# perihal : perihal
# kendala : kendala
# kakak : kakak
# infokan : info
# via : via
# privasi : privasi
# terjaga : jaga
# bangun : bangun
# tidur : tidur
# solat : solat
# hilang : hilang
# kesini : kesini
# jelek : jelek
# kualitas : kualitas
# jaringannya : jaring
# paketnya : paket
# doang : doang
# pkai : pkai
# mnurutku : mnurutku
# cukupthree : cukupthree
# anti : anti
# lelet : lelet
# lancar : lancar
# jaya : jaya
# unli : unli
# telkom : telkom
# servernya : servernya
# seindonesia : indonesia
# mending : mending
# yaaaaaan : yaaaaaan
# paketan : paket
# bulanan : bulan
# mytelkomsel : mytelkomsel
# niscaya : niscaya
# free : free
# disney : disney
# asli : asli
# ngeselin : ngeselin
# servis : servis
# boros : boros
# batre : batre
# alamat : alamat
# pindah : pindah
# hai : hai
# eka : eka
# terpotong : potong
# silakan : sila
# data : data
# detail : detail
# min : min
# temen : temen
# simpati : simpati
# kemaren : kemaren
# isi : isi
# kepotong : potong
# darurat : darurat
# tolong : tolong
# deposit : deposit
# potongan : potong
# minimal : minimal
# link : link
# gambar : gambar
# siang : siang
# mbps : mbps
# beranjak : anjak
# malam : malam
# whatsapp : whatsapp
# pending : pending
# buka : buka
# youtube : youtube
# maksud : maksud
# berlaku : laku
# jam : jam
# tembus : tembus
# lemot : lot
# ampun : ampun
# kebanyakan : banyak
# penggunaan : guna
# bersamaan : sama
# semoga : moga
# menyikapi : sikap
# bijak : bijak
# gratisan : gratis
# telfon : telfon
# atusan : atus
# menit : menit
# nggo : nggo
# ngopo : ngopo
# myungjoon : myungjoon
# dibantu : bantu
# nama : nama
# lengkap : lengkap
# lahir : lahir
# ari : ari
# kemana : mana
# deh : deh
# nganjuk : nganjuk
# jan : jan
# nyaman : nyaman
# pembayaran : bayar
# chand : chand
# tidor : tidor
# ane : ane
# berkurang : kurang
# mulu : mulu
# capek : capek
# chat : chat
# wifiid : wifiid
# nominal : nominal
# sekian : sekian
# ngendap : ngendap
# kang : kang
# informasikan : informasi
# bantu : bantu
# kalok : kalok
# ngendapnya : ngendapnya
# ardhy : ardhy
# done : done
# akses : akses
# lambat : lambat
# kbps : kbps
# off : off
# service : service
# wey : wey
# anjlok : anjlok
# internetnya : internetnya
# bbrp : bbrp
# abidhas : abidhas
# bisaa : bisaa
# kakk : kakk
# nonton : nonton
# nyaa : nyaa
# hadir : hadir
# akun : akun
# udh : udh
# ready : ready
# dikirim : kirim
# nunggu : nunggu
# langsung : langsung
# dipakai : pakai
# detik : detik
# jugaa : jugaa
# nihh : nihh
# yuhuuu : yuhuuu
# fast : fast
# respoon : respoon
# trusted : trusted
# fresh : fresh
# billing : billing
# parahsi : parahsi
# aing : aing
# tuku : tuku
# ning : ning
# nggonku : nggonku
# audah : audah
# belajar : ajar
# hahahahaha : hahahahaha
# otw : otw
# sak : sak
# taun : taun
# jugaaaa : jugaaaa
# sems : sems
# syamsi : syamsi
# jlek : jlek
# daftarkan : daftar
# ikuti : ikut
# tournament : tournament
# slotgames : slotgames
# spade : spade
# gaming : gaming
# palapatoto : palapatoto
# new : new
# harian : hari
# www : www
# indopalapa : indopalapa
# net : net
# info : info
# live : live
# shelby : shelby
# yallah : yallah
# kenapaa : kenapaa
# siiiiih : siiiiih
# lebib : lebib
# mencoba : coba
# hoki : hoki
# miin : miin
# area : area
# jogja : jogja
# hmmm : hmmm
# daerah : daerah
# rumahku : rumah
# kek : kek
# taik : taik
# masuk : masuk
# antrian : antri
# interaksi : interaksi
# permadi : madi
# aktivis : aktivis
# marah : marah
# in : in
# yaa : yaa
# tgl : tgl
# mode : mode
# woii : woii
# asuuu : asuuu
# bab : bab
# hestek : hestek
# malem : malem
# minggu : minggu
# anya : anya
# gabut : gabut
# kaga : kaga
# tongkrongan : tongkrong
# nongkrong : nongkrong
# emak : emak
# disuruh : suruh
# tejen : tejen
# kasihan : kasihan
# masyarakat : masyarakat
# with : with
# sedap : sedap
# line : line
# laju : laju
# bile : bile
# mati : mati
# lampu : lampu
# sembg : sembg
# duk : duk
# indo : indo
# kerjasama : kerjasama
# anjengg : anjengg
# fokus : fokus
# masukin : masukin
# hape : hape
# bawa : bawa
# dibenerin : dibenerin
# login : login
# logout : logout
# sndiri : sndiri
# alasan : alas
# keamanan : aman
# hedehh : hedehh
# cari : cari
# uang : uang
# tambahan : tambah
# modal : modal
# ribu : ribu
# bonus : bonus
# rollingan : rollingan
# senin : senin
# referal : referal
# seumur : umur
# ayo : ayo
# gabung : gabung
# crownqq : crownqq
# bombardir : bombardir
# sms : sms
# kayak : kayak
# refil : refil
# siklus : siklus
# penagihan : tagih
# mba : mba
# kontrak : kontrak
# ngisi : ngisi
# sopir : sopir
# jt : jt
# norek : norek
# uji : uji
# gamau : gamau
# maksa : maksa
# gofur : gofur
# balas : balas
# jay : jay
# komplain : komplain
# say : say
# teh : teh
# brp : brp
# diisiin : diisiin
# vip : vip
# iflix : iflix
# penasaran : penasaran
# drama : drama
# cina : cina
# taunya : tau
# gabisa : gabisa
# aktif : aktif
# hhh : hhh
# episode : episode
# bajakan : baja
# dimanaa : dimanaa
# guntur : guntur
# tanpanya : tanpa
# serem : rem
# bund : bund
# ngelek : ngelek
# hahahahah : hahahahah
# sff : sff
# imam : imam
# main : main
# knpa : knpa
# rugikan : rugi
# gada : gada
# busuk : busuk
# agil : agil
# christoper : christoper
# intan : intan
# ulang : ulang
# berhasil : hasil
# layanan : layan
# didapatkan : dapat
# dikhawatirkan : khawatir
# gangguan : ganggu
# tumben : tumben
# nayangin : nayangin
# matchnya : matchnya
# pas : pas
# big : big
# match : match
# kaum : kaum
# mola : mola
# terbantu : bantu
# suka : suka
# ngajak : ngajak
# berantem : antem
# saldo : saldo
# bertambah : tambah
# aplikasi : aplikasi
# kali : kali
# lenyap : lenyap
# transaksi : transaksi
# pengunaannya : pengunaannya
# pop : pop
# sistem : sistem
# sibuk : sibuk
# mengisi : isi
# voucer : voucer
# barusan : barusan
# call : call
# tunggu : tunggu
# gila : gila
# pelayanan : layan
# buruk : buruk
# unlimited : unlimited
# rebu : rebu
# acc : acc
# tagihan : tagih
# kartuhalo : kartuhalo
# pascabayar : pascabayar
# telat : telat
# sehari : hari
# batas : batas
# wkwkkwwkwkkwkwkwkwkwk : wkwkkwwkwkkwkwkwkwkwk
# kecamatan : camat
# selvia : selvia
# kembalikan : kembali
# sok : sok
# cobak : cobak
# mbak : mbak
# bangsat : bangsat
# dont : dont
# need : need
# excuse : excuse
# just : just
# fix : fix
# your : your
# connection : connection
# please : please
# gue : gue
# muak : muak
# ishhhh : ishhhh
# sinyalnya : sinyal
# bnerin : bnerin
# gimana : gimana
# daritadi : daritadi
# ping : ping
# merah : merah
# ofa : ofa
# refund : refund
# diakibatkan : akibat
# double : double
# aktivasi : aktivasi
# nazar : nazar
# hapizin : hapizin
# ditunggu : tunggu
# lupa : lupa
# sehat : sehat
# baba : baba
# segi : segi
# kuotanya : kuota
# ditotal : total
# abis : abis
# februari : februari
# kiw : kiw
# dear : dear
# kindly : kindly
# check : check
# thankyou : thankyou
# dial : dial
# diproses : proses
# kelanjutan : lanjut
# sekejap : kejap
# konfirmasi : konfirmasi
# persis : persis
# reckon : reckon
# the : the
# fault : fault
# yours : yours
# kenapasih : kenapasih
# hah : hah
# permintaan : minta
# kode : kode
# puk : puk
# rekan : rekan
# menyesuaikan : sesuai
# miliki : milik
# rhina : rhina
# panggilan : panggil
# dialihkan : alih
# request : request
# telpon : telpon
# dimatikan : mati
# urgent : urgent
# yonisha : yonisha
# seputar : putar
# wifi : wifi
# sangking : sangking
# dipake : dipake
# duh : duh
# emosi : emosi
# knp : knp
# klw : klw
# panggilannya : panggil
# alihkan : alih
# cekkan : cek
# terkejut : kejut
# app : app
# msh : msh
# sisa : sisa
# berkali : kali
# secepet : secepet
# pdhl : pdhl
# usage : usage
# otak : otak
# atik : atik
# gaptek : gaptek
# ketidaksesuaian : ketidaksesuaian
# gilang : gilang
# iyanih : iyanih
# menggangu : menggangu
# aktivitas : aktivitas
# okee : okee
# pengguna : guna
# bulannya : bulan
# hiburan : hibur
# entertainment : entertainment
# maxstream : maxstream
# kepake : kepake
# pertanyaannya : tanya
# nggak : nggak
# aprillia : aprillia
# yaz : yaz
# wtf : wtf
# boss : boss
# jebol : jebol
# kris : kris
# tcdharma : tcdharma
# hassan : hassan
# pmj : pmj
# oppo : oppo
# android : android
# lolipop : lolipop
# instal : instal
# persyaratannya : syarat
# payment : payment
# method : method
# respon : respon
# perubahan : ubah
# feedback : feedback
# harapan : harap
# terealisasikan : realisasi
# setia : setia
# erwin : erwin
# fastresp : fastresp
# nangis : nang
# bombay : bombay
# susah : susah
# signal : signal
# kagak : kagak
# sepadan : padan
# keciwa : keciwa
# peningkatan : tingkat
# selesai : selesai
# barengan : bareng
# corona : corona
# kelar : kelar
# berujung : ujung
# twitter : twitter
# dimasukkan : masuk
# kategori : kategori
# socmed : socmed
# combo : combo
# sakti : sakti
# tuan : tuan
# oke : oke
# hidayatullah : hidayatullah
# interaksinya : interaksi
# zeus : zeus
# almandio : almandio
# eko : eko
# doi : doi
# wew : wew
# sampek : sampek
# tingkat : tingkat
# helo : helo
# hallo : hallo
# cacad : cacad
# bangets : bangets
# mins : mins
# pengen : ken
# rasany : rasany
# berpindah : pindah
# super : super
# beginiin : beginiin
# omg : omg
# untung : untung
# burik : burik
# membaik : baik
# kompalin : kompalin
# pelanggan : langgan
# mengeluh : keluh
# diperbaiki : baik
# yanuar : yanuar
# motto : motto
# indonesia : indonesia
# orang : orang
# mobilitas : mobilitas
# allah : allah
# cape : cape
# sma : sma
# tingkah : tingkah
# dri : dri
# restart : restart
# handphone : handphone
# hizkia : hizkia
# pol : pol
# brok : brok
# spotipay : spotipay
# toktok : toktok
# order : order
# video : video
# cewek : cewek
# boker : boker
# silahkan : silah
# hanif : hanif
# pulsanya : pulsa
# gaenak : gaenak
# ditempletin : ditempletin
# ngaco : ngaco
# dimakan : makan
# templet : templet
# keenan : keenan
# dedi : dedi
# smooa : smooa
# arin : arin
# salah : salah
# mencari : cari
# semudah : mudah
# menjaga : jaga
# perbaiki : baik
# dtk : dtk
# massss : massss
# langganan : langgan
# extend : extend
# koq : koq
# bahas : bahas
# blokir : blokir
# kuatin : kuatin
# capeq : capeq
# ati : ati
# begitulau : begitulau
# kelakuan : laku
# bar : bar
# penuh : penuh
# bngt : bngt
# ngadat : ngadat
# maen : maen
# sasa : sasa
# netflix : netflix
# aplikasinya : aplikasi
# aziz : aziz
# sarankan : saran
# kevin : kevin
# aldo : aldo
# bayanginn : bayanginn
# kartunya : kartu
# harganya : harga
# wajarr : wajarr
# jemina : jemina
# spotify : spotify
# baju : baju
# dramaku : drama
# keknya : kek
# banned : banned
# lho : lho
# angin : angin
# duluan : duluan
# indihkme : indihkme
# ngeluh : ngeluh
# nang : nang
# wkwkwk : wkwkwk
# asap : asap
# koneksi : koneksi
# gua : gua
# gara : gara
# kesel : kesel
# nyalahin : nyalahin
# quota : quota
# lately : lately
# semenjak : semenjak
# hujan : hujan
# parah : parah
# caur : caur
# hann : hann
# sinyalmu : sinyal
# niat : niat
# ngeki : ngeki
# pora : pora
# jane : jane
# lengkapi : lengkap
# gemesin : gemesin
# terkendala : kendala
# januari : januari
# signalnyaa : signalnyaa
# sore : sore
# ajaa : ajaa
# ttp : ttp
# jeleknya : jelek
# selevel : level
# bumn : bumn
# jualan : jual
# survive : survive
# lukman : lukman
# ngambek : ngambek
# perasaan : asa
# ngapa : ngapa
# lte : lte
# smartfren : smartfren
# kayanya : kaya
# exokei : exokei
# kah : kah
# situs : situs
# judi : judi
# fair : fair
# bot : bot
# murni : murni
# player : player
# solusinya : solusi
# hnya : hnya
# tersedia : sedia
# alternatif : alternatif
# jaemin : jaemin
# belom : bom
# beliin : beliin
# butuh : butuh
# dirumah : rumah
# ngrh : ngrh
# ngalem : ngalem
# ngerti : ngerti
# indihome : indihome
# beserta : serta
# antek : antek
# anteknya : antek
# emang : emang
# gembel : gembel
# alief : alief
# entertainmemt : entertainmemt
# gunain : gunain
# nnton : nnton
# bola : bola
# ngelag : ngelag
# mcl : mcl
# ngerank : ngerank
# diko : diko
# rizqi : rizqi
# flop : flop
# berubah : ubah
# search : search
# mengeluhkan : keluh
# tolonglah : tolong
# samuel : samuel
# kasih : kasih
# bantuan : bantu
# infonya : info
# mksh : mksh
# viuers : viuers
# menganalisa : menganalisa
# bareng : bareng
# detective : detective
# conan : conan
# tayangan : tayang
# asia : asia
# promo : promo
# khusus : khusus
# viu : viu
# klik : klik
# berlangganan : langgan
# karir : karir
# gamerku : gamerku
# terhambat : hambat
# irwansyah : irwansyah
# fajar : fajar
# mahmud : mahmud
# turun : turun
# hadueh : hadueh
# njiiiir : njiiiir
# beut : beut
# browsing : browsing
# logonya : logo
# siput : siput
# balikin : balikin
# hr : hr
# gppaaa : gppaaa
# ngaruh : ngaruh
# rasain : rasain
# sampah : sampah
# unlimitednya : unlimitednya
# instagram : instagram
# tiktok : tiktok
# kangen : kangen
# kegaduhan : gaduh
# jarang : jarang
# sosmed : sosmed
# dikerjain : dikerjain
# alhamdulillaah : alhamdulillaah
# tlphon : tlphon
# untu : untu
# prioritas : prioritas
# lemooot : lemooot
# habisnya : habis
# bertahun : tahun
# kecewa : kecewa
# sihhhhh : sihhhhh
# jijik : jijik
# satya : satya
# hasil : hasil
# kisel : kisel
# mukomuko : mukomuko
# benerin : benerin
# simcard : simcard
# rusak : rusak
# dipaksa : paksa
# hotstar : hotstar
# dilayani : layan
# hebat : hebat
# capture : capture
# keterangan : terang
# gagal : gagal
# restar : restar
# najis : najis
# ujan : ujan
# seharian : hari
# bapuk : bapuk
# bergaransi : garansi
# zonaba : zonaba
# zonabu : zonabu
# zonauang : zonauang
# apple : apple
# music : music
# canva : canva
# vsco : vsco
# kaaa : kaaa
# efek : efek
# mekdi : mekdi
# pke : pke
# napa : napa
# inet : inet
# gbsa : gbsa
# zzzzzzzz : zzzzzzzz
# yaaaa : yaaaa
# huhu : huhu
# lmot : lmot
# lwmot : lwmot
# ueue : ueue
# ngapain : ngapain
# ributkah : ribut
# tingkap : tingkap
# cabin : cabin
# mengadap : adap
# batam : batam
# roaming : roaming
# kapal : kapal
# pusing : pusing
# tukar : tukar
# heading : heading
# singapore : singapore
# pulak : pulak
# kena : kena
# singtel : singtel
# duit : duit
# macamni : macamni
# mat : mat
# hadeh : hadeh
# ribet : ribet
# bandung : bandung
# org : org
# ngomong : ngomong
# cobain : cobain
# apn : apn
# sopan : sopan
# dikasih : kasih
# informasi : informasi
# reiwayat : reiwayat
# sebutkan : sebut
# mencocokan : cocok
# riwayat : riwayat
# ulangnya : ulang
# dibalas : balas
# nur : nur
# malih : malih
# hapuskan : hapus
# membantu : bantu
# membeli : beli
# nol : nol
# jujur : jujur
# kalu : kalu
# face : face
# throwing : throwing
# kissterima : kissterima
# setiamu : setia
# rina : rina
# terua : rua
# brengsek : brengsek
# abisnya : abis
# resti : resti
# kalah : kalah
# sad : sad
# berduka : duka
# ngamuk : ngamuk
# sifatnya : sifat
# nyet : nyet
# india : india
# yaaa : yaaa
# stupid : stupid
# putra : putra
# garut : garut
# napasii : napasii
# heran : heran
# lelah : lelah
# malu : malu
# tah : tah
# berminggu : minggu
# dikomplen : dikomplen
# customer : customer
# nanya : nanya
# woy : woy
# baca : baca
# mention : mention
# bnyak : bnyak
# anteng : anteng
# dikamar : kamar
# teras : teras
# ditengah : tengah
# febiyanti : febiyanti
# ratih : ratih
# bagas : bagas
# lemod : lemod
# hancur : hancur
# sebanding : banding
# berika : berika
# penambahan : tambah
# peluasan : luas
# kerja : kerja
# nuggu : nuggu
# mengikuti : ikut
# zona : zona
# wib : wib
# lag : lag
# wes : wes
# larang : larang
# meneh : teh
# marai : mara
# loss : loss
# streak : streak
# hmmmm : hmmmm
# claim : claim
# gilaaaa : gilaaaa
# parahhhh : parahhhh
# akhlak : akhlak
# nambah : nambah
# mahalnya : mahal
# terjun : terjun
# bebas : bebas
# ihh : ihh
# bang : bang
# tergantung : gantung
# kuat : kuat
# alhi : alhi
# dyan : dyan
# dialami : alami
# hakim : hakim
# menu : menu
# pilih : pilih
# yudha : yudha
# leg : leg
# muter : muter
# akibat : akibat
# jdi : jdi
# ngleg : ngleg
# didaerah : daerah
# kisaran : kisar
# pubg : pubg
# timed : timed
# out : out
# pengecekan : kece
# channel : channel
# dapet : dapet
# ndk : ndk
# omah : omah
# sampean : sampean
# yaopo : yaopo
# bek : bek
# sek : sek
# tetep : tetep
# memng : memng
# pakuy : pakuy
# akiem : akiem
# pengisian : isi
# joshua : joshua
# masyaallah : masyaallah
# bayarnya : bayar
# transfer : transfer
# oulsa : oulsa
# plssss : plssss
# dit : dit
# internetan : internetan
# kenceng : kenceng
# mbanking : mbanking
# gojek : gojek
# dll : dll
# ambil : ambil
# gasalah : gasalah
# freedom : freedom
# lumayan : lumayan
# wasapan : wasapan
# ngadet : ngadet
# cerah : cerah
# ngegame : ngegame
# kmrn : kmrn
# soleh : soleh
# hermanto : hermanto
# keluhannya : keluh
# feqih : feqih
# poin : poin
# tereset : tereset
# desember : desember
# woiiii : woiiii
# reply : reply
# all : all
# bosok : bosok
# dikit : dikit
# ssksksk : ssksksk
# aditya : aditya
# sabar : sabar
# bantuin : bantuin
# beny : beny
# dine : dine
# yugyeom : yugyeom
# terimakasih : terimakasih
# ridwan : ridwan
# ngumpat : ngumpat
# awas : awas
# lhoo : lhoo
# ketutup : tutup
# tembok : tembok
# kayaknya : kayak
# pal : pal
# kacida : kacida
# pisan : pis
# sueq : sueq
# rawuri : rawuri
# neil : neil
# lakukan : laku
# rilis : rilis
# taanpa : taanpa
# fup : fup
# hayo : hayo
# pesaing : saing
# tbk : tbk
# perkara : perkara
# liat : liat
# story : story
# dasar : dasar
# merata : rata
# talkomsel : talkomsel
# tuaaaa : tuaaaa
# purbo : purbo
# bri : bri
# gaada : gaada
# notif : notif
# apapun : apa
# syarat : syarat
# ketentuannya : tentu
# down : down
# prosedur : prosedur
# pengurusan : urus
# sim : sim
# njir : njir
# mane : mane
# ade : ade
# plat : plat
# biru : biru
# same : same
# yak : yak
# wisnu : wisnu
# aneh : aneh
# kesedot : sedot
# cil : cil
# segini : gin
# setan : setan
# wae : wae
# dahlah : dah
# darah : darah
# dosa : dosa
# kebun : kebun
# binatang : binatang
# bye : bye
# robby : robby
# yoongi : yoongi
# neh : neh
# men : men
# sesempak : sempak
# gakuat : gakuat
# naufal : naufal
# diinformasikan : informasi
# kronologis : kronologis
# permasalahannya : masalah
# tindaklanjuti : tindaklanjuti
# berlanjut : lanjut
# donlot : donlot
# dibeli : beli
# relatif : relatif
# melanjutkan : lanjut
# chika : chika
# zakarya : zakarya
# lgi : lgi
# samping : samping
# tokopedia : tokopedia
# lazada : lazada
# diperpanjang : panjang
# periode : periode
# menawarkan : tawar
# benefit : benefit
# terdaftar : daftar
# gamesmax : gamesmax
# musicmax : musicmax
# ruangan : ruang
# skarang : skarang
# okky : okky
# boljug : boljug
# yokdah : yokdah
# gelud : gelud
# pantes : pantes
# ancene : ancene
# telkompret : telkompret
# ngab : ngab
# lingga : lingga
# reinkarnasi : reinkarnasi
# komandan : komandan
# perang : perang
# troya : troya
# nyalinya : nyali
# gaes : gaes
# aliyas : aliyas
# dunia : dunia
# akhirat : akhirat
# nomornya : nomor
# youngkkkkk : youngkkkkk
# pelit : pelit
# tauuuu : tauuuu
# gocap : gocap
# setahun : tahun
# mei : mei
# tenggang : tenggang
# nelpon : nelpon
# spam : spam
# raka : raka
# raihan : raih
# rida : rida
# automatis : automatis
# listrik : listrik
# ditambah : tambah
# macem : macem
# ngilangan : ngilangan
# paketnmahal : paketnmahal
# apasih : apasih
# aik : aik
# nder : nder
# weekend : weekend
# survivors : survivors
# fire : fire
# merapat : rapat
# elite : elite
# pass : pass
# specter : specter
# squad : squad
# ikutan : ikut
# diamonds : diamonds
# bundle : bundle
# gan : gan
# mesti : mesti
# daftar : daftar
# best : best
# dipakein : dipakein
# anonytune : anonytune
# outlet : outlet
# terdekat : dekat
# ewa : ewa
# fara : fara
# hangus : hangus
# melewati : lewat
# aktifkan : aktif
# terhubung : hubung
# komen : komen
# jawabannya : jawab
# bentar : bentar
# nge : nge
# jumping : jumping
# dimana : mana
# laporan : lapor
# rodi : rodi
# teregister : register
# posisi : posisi
# chi : chi
# memindahkan : pindah
# askrl : askrl
# society : society
# berlakunya : laku
# taufik : taufik
# ceria : ceria
# ente : ente
# setelahnya : telah
# kacau : kacau
# karuan : karuan
# basi : basi
# gelut : gelut
# pikir : pikir
# mantan : mantan
# bad : bad
# hii : hii
# samsek : samsek
# kemarin : kemarin
# mpe : mpe
# kmrin : kmrin
# kasin : kasin
# tamat : tamat
# mendingan : mending
# nyala : nyala
# mb : mb
# sesek : sek
# napas : napas
# salman : salman
# thank : thank
# ndak : ndak
# mendadak : dadak
# goblok : goblok
# nilai : nilai
# kepuasan : puas
# petugas : tugas
# gratis : gratis
# gundul : gundul
# duanya : dua
# diizinkan : izin
# sumpah : sumpah
# itupun : itu
# loading : loading
# gimanasih : gimanasih
# trs : trs
# tbtb : tbtb
# reconnecting : reconnecting
# providernya : providernya
# novic : novic
# otp : otp
# ngga : ngga
# seleeai : seleeai
# ngadu : ngadu
# bermasalah : masalah
# adz : adz
# sayang : sayang
# paketzn : paketzn
# hall : hall
# mubazir : mubazir
# maghrib : maghrib
# mengacaukan : acau
# mood : mood
# bau : bau
# signalnya : signalnya
# masi : mas
# gabs : gabs
# masang : masang
# membutuhkan : butuh
# reguler : reguler
# pastikan : pasti
# memiliki : milik
# brandweer : brandweer
# ignas : ignas
# pieter : pieter
# kemendikbudku : kemendikbudku
# clear : clear
# cache : cache
# force : force
# stop : stop
# panduan : pandu
# versi : versi
# terbaru : baru
# fay : fay
# diaktivasi : diaktivasi
# php : php
# utan : utan
# kayu : kayu
# utara : utara
# jakarta : jakarta
# timur : timur
# wonomerto : wonomerto
# usmna : usmna
# pls : pls
# gmn : gmn
# ciseeng : ciseeng
# bogor : bogor
# fl : fl
# konsumen : konsumen
# ngk : ngk
# sebulan : bulan
# yup : yup
# ayu : ayu
# hor : hor
# serious : serious
# ceruk : ceruk
# lampung : lampung
# digi : digi
# duduk : duduk
# tebakang : tebakang
# naseb : naseb
# ley : ley
# scandal : scandal
# terdapatnya : dapat
# penawaran : tawar
# maxtreme : maxtreme
# terbaik : baik
# dang : dang
# tlg : tlg
# difollow : difollow
# hati : hati
# gag : gag
# payahh : payahh
# yora : yora
# berhanti : berhanti
# kunjungi : kunjung
# garpari : garpari
# fisik : fisik
# biaya : biaya
# kalem : kalem
# joe : joe
# berhenti : henti
# unavailable : unavailable
# myapps : myapps
# alami : alami
# ilangan : ilangan
# tida : tida
# terbuang : buang
# sia : sia
# auto : auto
# besok : besok
# viny : viny
# imessage : imessage
# make : make
# niatan : niat
# baikan : baik
# telegram : telegram
# marahan : marah
# anjj : anjj
# dedik : dedik
# pastiin : pastiin
# engga : engga
# apk : apk
# trus : trus
# web : web
# muncul : muncul
# gatau : gatau
# nanyain : nanyain
# aktifin : aktifin
# kontak : kontak
# thanks : thanks
# koneksinya : koneksi
# bela : bela
# airplane : airplane
# betulll : betulll
# mainnya : main
# tenang : tenang
# nikmatin : nikmatin
# registrasi : registrasi
# panjualan : panjualan
# perdana : perdana
# membawa : bawa
# ktp : ktp
# kasi : kasi
# surat : surat
# alhamdulillah : alhamdulillah
# telponnya : telpon
# achmad : achmad
# diaktifin : diaktifin
# yaampun : yaampun
# tek : tek
# subscribe : subscribe
# nyampe : nyampe
# dibuka : buka
# sebelah : belah
# maybe : maybe
# pribadi : pribadi
# plis : plis
# nungguin : nungguin
# kaann : kaann
# kunaon : kunaon
# ampas : ampas
# berulah : ulah
# selepet : lepet
# dianak : anak
# tirikan : tiri
# hadiah : hadiah
# undian : undi
# menang : menang
# bos : bos
# kejambretan : jambret
# kantor : kantor
# gubernur : gubernur
# manokwari : manokwari
# hadiahnya : hadiah
# fitria : fitria
# pha : pha
# sinyalku : sinyal
# satunya : satu
# full : full
# arahan : arah
# suruh : suruh
# istirahat : istirahat
# stalking : stalking
# film : film
# commerce : commerce
# tik : tik
# tok : tok
# awards : awards
# gegara : gegara
# setiawan : setiawan
# priaji : priaji
# immediately : immediately
# replied : replied
# wait : wait
# for : for
# next : next
# interaction : interaction
# read : read
# taek : taek
# kabeh : kabeh
# jancok : jancok
# paketny : paketny
# lis : lis
# form : form
# pendaftaran : daftar
# ditanyain : ditanyain
# knph : knph
# ulimited : ulimited
# maksudnya : maksud
# memakain : memakain
# pemakaian : pakai
# pemakain : pemakain
# perhari : hari
# edge : edge
# lokal : lokal
# yuda : yuda
# malaysia : malaysia
# agung : agung
# kampung : kampung
# gunung : gunung
# laut : laut
# ariyo : ariyo
# klu : klu
# daftarnya : daftar
# ngalangin : ngalangin
# kontol : kontol
# rekomendasi : rekomendasi
# biografi : biografi
# inspiratif : inspiratif
# bidang : bidang
# tambahin : tambahin
# tontonan : tonton
# gala : gala
# rp : rp
# anjing : anjing
# teriak : teriak
# abim : abim
# bolak : bolak
# mendukung : dukung
# yuliani : yuliani
# perpanjang : panjang
# gmna : gmna
# adakah : ada
# hilangan : hilang
# berry : berry
# review : review
# speednya : speednya
# donkkkk : donkkkk
# zama : zama
# lemotnya : lot
# hahaha : hahaha
# musim : musim
# ngandelin : ngandelin
# scoojay : scoojay
# fiersa : fiersa
# switch : switch
# network : network
# beudd : beudd
# mom : mom
# gedor : gedor
# telepon : telepon
# bkin : bkin
# tlpon : tlpon
# kouta : kouta
# ketengan : keteng
# sweetsugardrop : sweetsugardrop
# brapa : brapa
# sis : sis
# jga : jga
# kasir : kasir
# tenyata : tenyata
# persiapan : siap
# menentukan : tentu
# prestasi : prestasi
# tanggapan : tanggap
# mengumumkan : umum
# startup : startup
# berdampak : dampak
# sosial : sosial
# ajang : ajang
# nextdev : nextdev
# talent : talent
# scouting : scouting
# mmek : mmek
# pliss : pliss
# desaku : desa
# peettt : peettt
# bayangin : bayangin
# minn : minn
# desa : desa
# gaess : gaess
# corporate : corporate
# mngkin : mngkin
# kack : kack
# gkgk : gkgk
# yaudah : yaudah
# punyamu : punya
# pajak : pajak
# sah : sah
# soche : soche
# ctk : ctk
# andah : andah
# farhan : farhan
# cairin : cairin
# ubah : ubah
# rekening : rekening
# btn : btn
# jenius : jenius
# syariah : syariah
# iyaa : iyaa
# hiks : hiks
# ribut : ribut
# suee : suee
# bgke : bgke
# samaan : sama
# chaki : chaki
# bnyk : bnyk
# dipencet : pencet
# cepat : cepat
# gtgt : gtgt
# doangg : doangg
# blank : blank
# gtuu : gtuu
# repeated : repeated
# purchase : purchase
# since : since
# august : august
# meqa : meqa
# bernadine : bernadine
# ajege : ajege
# kemendikbud : kemendikbud
# siyaaaap : siyaaaap
# samasamaa : samasamaa
# sinyalny : sinyalny
# ogie : ogie
# uanehh : uanehh
# livvv : livvv
# iki : iki
# menyebar : sebar
# ajee : ajee
# kucobaa : kucobaa
# timaaci : timaaci
# sel : sel
# pendinggggg : pendinggggg
# ices : ices
# sudahh : sudahh
# uda : uda
# matiin : matiin
# nyalain : nyalain
# jugakk : jugakk
# yakk : yakk
# response : response
# nyaaaa : nyaaaa
# renjun : renjun
# aliansi : aliansi
# diisi : isi
# statusnya : status
# ceritain : ceritain
# percakapan : cakap
# klaim : klaim
# sukses : sukses
# hooo : hooo
# oohhh : oohhh
# lawan : lawan
# teflon : teflon
# melayang : layang
# mayanlah : mayanlah
# wandavision : wandavision
# dmnya : dmnya
# sik : sik
# nganggo : nganggo
# ngemis : ngemis
# hora : hora
# ngutang : ngutang
# scroll : scroll
# pencarian : cari
# byk : byk
# potong : potong
# seenak : enak
# jidat : jidat
# abaikan : abai
# pidihil : pidihil
# bon : bon
# ngaret : ngaret
# kamar : kamar
# diluar : luar
# lawak : lawak
# thn : thn
# jebot : jebot
# hapus : hapus
# account : account
# kun : kun
# cimerak : cimerak
# rip : rip
# temennya : temennya
# jojon : jojon
# wkwkwkw : wkwkwkw
# jisung : jisung
# edan : edan
# rezim : rezim
# joko : joko
# bego : bego
# dilaporin : dilaporin
# gajelas : gajelas
# abang : abang
# dipelak : pelak
# malunya : malu
# dobel : dobel
# mff : mff
# yach : yach
# tpi : tpi
# egk : egk
# adha : adha
# jringan : jringan
# smartphone : smartphone
# pembayarannya : bayar
# voucher : voucher
# gratisnya : gratis
# hobi : hobi
# senilai : nila
# google : google
# play : play
# jajan : jajan
# gofood : gofood
# simak : simak
# tweet : tweet
# vpn : vpn
# tag : tag
# oasu : oasu
# bangke : bangke
# bat : bat
# bandarq : bandarq
# terpercaya : percaya
# site : site
# gii : gii
# irfansyah : irfansyah
# tolok : tolok
# faisal : faisal
# elma : elma
# bersahabat : sahabat
# apaa : apaa
# amattt : amattt
# tanggapanya : tanggapanya
# pemblokiran : blokir
# payied : payied
# tips : tips
# surga : surga
# ayah : ayah
# sediain : ain
# anaknya : anak
# theboyz : theboyz
# nyesek : nyesek
# daripda : daripda
# unje : unje
# apdet : apdet
# vlive : vlive
# berbarengan : bareng
# pemenang : menang
# undi : undi
# afi : afi
# thankyouu : thankyouu
# meratapi : ratap
# ketampanan : tampan
# pacar : pacar
# bakar : bakar
# jlas : jlas
# bjink : bjink
# pengalaman : alam
# set : set
# hspa : hspa
# ketimbang : ketimbang
# learning : learning
# kampus : kampus
# sekolah : sekolah
# conference : conference
# mencakup : cakup
# zoom : zoom
# meet : meet
# cisco : cisco
# webex : webex
# umetmee : umetmee
# teams : teams
# micha : micha
# syahrizal : syahrizal
# sweetchat : sweetchat
# quipper : quipper
# cakap : cakap
# bahaso : bahaso
# ayoblajar : ayoblajar
# kippin : kippin
# school : school
# sekolahmu : sekolah
# udemy : udemy
# duolingo : duolingo
# meeting : meeting
# edukasi : edukasi
# birru : birru
# ratusan : ratus
# portal : portal
# pendidikan : didik
# confrence : confrence
# classroom : classroom
# zenius : zenius
# modem : modem
# firmware : firmware
# shop : shop
# hartono : hartono
# mall : mall
# yogyakarta : yogyakarta
# barang : barang
# wajib : wajib
# bindling : bindling
# pesen : sen
# modus : modus
# informasinya : informasi
# rizcasya : rizcasya
# tangal : tangal
# banting : banting
# drive : drive
# buaya : buaya
# upgrade : upgrade
# nano : nano
# andhika : andhika
# datanya : data
# skrng : skrng
# yun : yun
# emng : emng
# shatar : shatar
# mrk : mrk
# powerful : powerful
# agency : agency
# skalanya : skala
# perusahaan : usaha
# spt : spt
# kabar : kabar
# agensi : agens
# nego : nego
# pemotongan : potong
# penjelasannya : jelas
# dinyalain : dinyalain
# nofri : nofri
# pengaduah : pengaduah
# panipuan : panipuan
# nongol : nongol
# motong : motong
# nonaktifinnya : nonaktifinnya
# ajaaa : ajaaa
# elsura : elsura
# pekan : pekan
# arsenal : arsenal
# manchester : manchester
# united : united
# saksikan : saksi
# duel : duel
# sengit : sengit
# rival : rival
# daratan : darat
# britania : britania
# seharga : harga
# tonton : tonton
# laga : laga
# panasnya : panas
# halooooo : halooooo
# konek : konek
# wifian : wifian
# begimane : begimane
# ceritanya : cerita
# tim : tim
# berupaya : upaya
# menyelesaikan : selesai
# proses : proses
# maksimalnya : maksimal
# buanget : buanget
# punyaku : punya
# tapiii : tapiii
# aot : aot
# waswas : waswas
# nontonyaaa : nontonyaaa
# perkembangan : kembang
# sabtu : sabtu
# tmp : tmp
# harinya : hari
# pramudio : pramudio
# event : event
# promosi : promosi
# kondisi : kondisi
# ditawarkan : tawar
# telkomselnya : telkomselnya
# menarik : tarik
# selenjutnya : selenjutnya
# kick : kick
# beruntung : untung
# lapor : lapor
# diaktifkan : aktif
# penawarannya : tawar
# ciee : ciee
# blunder : blunder
# segitu : segitu
# ampe : ampe
# senen : senen
# mingguan : minggu
# ngeri : ngeri
# hmm : hmm
# pakainya : pakai
# bii : bii
# stepnya : step
# diumumin : diumumin
# gampang : gampang
# suer : suer
# koin : koin
# tiketnya : tiket
# debit : debit
# sirait : sirait
# hadeeehh : hadeeehh
# makasihh : makasihh
# sarannya : saran
# angkanya : angka
# stress : stress
# mikirin : mikirin
# jagak : jagak
# peka : peka
# didm : didm
# broo : broo
# uki : uki
# rodif : rodif
# togelnya : togel
# trims : trims
# mimi : mimi
# ngak : ngak
# diajak : ajak
# sekrang : sekrang
# niko : niko
# bersifat : sifat
# berbatas : batas
# jina : jina
# diterima : terima
# rutin : rutin
# aktifasi : aktifasi
# bantuannya : bantu
# blum : blum
# celine : celine
# putry : putry
# vesca : vesca
# blm : blm
# kesalahan : salah
# perampokan : ampo
# namanya : nama
# pingin : pingin
# pesawat : pesawat
# tlp : tlp
# follow : follow
# maksimal : maksimal
# hendrik : hendrik
# keren : keren
# giga : giga
# tagihannya : tagih
# dibayar : bayar
# saiki : saiki
# lemote : lemote
# koyok : koyok
# uridu : uridu
# kebuka : buka
# paka : paka
# firstmedia : firstmedia
# buseett : buseett
# astraa : astraa
# singkat : singkat
# dramaa : dramaa
# mgkin : mgkin
# expect : expect
# disana : sana
# joy : joy
# dekatkan : dekat
# anita : anita
# bakery : bakery
# salary : salary
# anak : anak
# dihubungi : hubung
# not : not
# recomended : recomended
# sorong : sorong
# wika : wika
# beatrice : beatrice
# dicoba : coba
# mobile : mobile
# legend : legend
# berdasarkan : dasar
# kat : kat
# setakat : takat
# slow : slow
# telco : telco
# kadang : kadang
# fake : fake
# hope : hope
# jugak : jugak
# topup : topup
# charge : charge
# tegar : tegar
# beralih : alih
# ulah : ulah
# dianggap : anggap
# hrus : hrus
# brusan : brusan
# aje : aje
# hyung : hyung
# bntu : bntu
# eidaaan : eidaaan
# astuti : astuti
# gaseneng : gaseneng
# mbe : mbe
# awamu : awa
# prabayar : prabayar
# heru : heru
# perbaikan : baik
# nata : nata
# dimas : mas
# bpak : bpak
# inna : inna
# hipo : hipo
# oake : oake
# kahfi : kahfi
# era : era
# sipp : sipp
# miiliki : miiliki
# ziva : ziva
# poker : poker
# resmi : resmi
# evodomino : evodomino
# mudah : mudah
# banjir : banjir
# kemenangan : menang
# jackpot : jackpot
# buruan : buru
# money : money
# promonya : promonya
# know : know
# mengaktifkan : aktif
# hybrid : hybrid
# tarif : tarif
# wilayah : wilayah
# bambang : bambang
# mengirim : kirim
# internasional : internasional
# negara : negara
# spasi : spasi
# stevan : stevan
# ketawa : ketawa
# salam : salam
# dibilang : bilang
# wkwkwkkw : wkwkwkkw
# acak : acak
# biasalah : biasa
# ngasih : ngasih
# laela : laela
# iyess : iyess
# day : day
# left : left
# kosong : kosong
# hemat : hemat
# tsb : tsb
# telp : telp
# merepotkan : repot
# ririz : ririz
# deaktivasi : deaktivasi
# flash : flash
# nonaktif : nonaktif
# maunya : mau
# povider : povider
# efiqa : efiqa
# kren : kren
# setting : setting
# negeri : negeri
# gmana : gmana
# auliani : auliani
# los : los
# unreg : unreg
# manusiawi : manusiawi
# pandemi : pandemi
# berhentikan : henti
# ditangani : tangan
# th : th
# daniel : daniel
# teknis : teknis
# terhormat : hormat
# berusaha : usaha
# menipu : tipu
# penukaran : tukar
# point : point
# reward : reward
# blanja : blanja
# des : des
# seandainya : anda
# tepu : tepu
# brianajie : brianajie
# pengaturan : atur
# kalibanteng : kalibanteng
# penipuan : tipu
# pelaporan : lapor
# mamed : mamed
# blankspot : blankspot
# prihatin : prihatin
# korban : korban
# berhadiah : hadiah
# disarankan : saran
# melaporkan : lapor
# polisi : polisi
# cyber : cyber
# crime : crime
# bukti : bukti
# dimiliki : milik
# kejelasan : jelas
# angkat : angkat
# memotong : potong
# bekasi : bekas
# aktifnya : aktif
# ditgg : ditgg
# ditindak : tindak
# upaya : upaya
# dibacakan : baca
# password : password
# maxtream : maxtream
# store : store
# bangett : bangett
# hariini : hariini
# trouble : trouble
# bekali : bekal
# pasang : pasang
# status : status
# ctofficialstore : ctofficialstore
# spay : spay
# nonya : nonya
# moa : moa
# trendsetter : trendsetter
# together : together
# members : members
# bighit : bighit
# jaringanmu : jaring
# biat : biat
# seneng : neng
# pemain : main
# hukuman : hukum
# tapir : tapir
# semingguan : minggu
# mumpung : mumpung
# diskon : diskon
# monyet : monyet
# semalem : semalem
# jujutsu : jujutsu
# kaisen : kaisen
# anjeng : anjeng
# teguh : teguh
# frida : frida
# sfdn : sfdn
# yayat : yayat
# aman : aman
# btw : btw
# mencentak : mencentak
# dicek : cek
# keperluan : perlu
# dinomor : nomor
# verifikasi : verifikasi
# ketentuan : tentu
# dijaman : jam
# podo : podo
# renek : renek
# mundak : mundak
# terah : terah
# matuk : matuk
# gawe : gawe
# regane : regane
# joh : joh
# tedisan : tedisan
# maxstreamnya : maxstreamnya
# aktip : aktip
# aktipnya : aktipnya
# mantanku : mantan
# gunawan : gunawan
# enakan : enak
# mengandung : kandung
# ady : ady
# wal : wal
# betakun : betakun
# unlimted : unlimted
# mun : mun
# hbs : hbs
# batasan : batas
# smarfren : smarfren
# dibayarkan : bayar
# ter : ter
# block : block
# ala : ala
# kasein : kasein
# mental : mental
# kelvin : kelvin
# yulius : yulius
# yusuf : yusuf
# suami : suami
# mas : mas
# yon : yon
# notifikasi : notifikasi
# dpn : dpn
# mabar : mabar
# gamenya : gamenya
# nub : nub
# woyy : woyy
# febrinaaa : febrinaaa
# sengaja : sengaja
# exis : exis
# trnyata : trnyata
# ckp : ckp
# nana : nana
# imut : imut
# suri : suri
# syamsuri : syamsuri
# shireen : shireen
# putrioct : putrioct
# putri : putri
# nycta : nycta
# gina : gina
# ajak : ajak
# lunch : lunch
# shopping : shopping
# kenal : kenal
# sosok : sosok
# terkenal : kenal
# perannya : peran
# jengkelin : jengkelin
# hubungi : hubung
# tdi : tdi
# error : error
# gpp : gpp
# caroline : caroline
# ktnya : ktnya
# beres : beres
# woi : woi
# loe : loe
# berws : berws
# bengkel : bengkel
# sepeda : sepeda
# profesional : profesional
# format : format
# sbb : sbb
# plsaku : plsaku
# disek : sek
# leng : leng
# foto : foto
# have : have
# nice : nice
# protes : protes
# gubris : gubris
# lanjuti : lanjut
# test : test
# ombak : ombak
# twips : twips
# yoks : yoks
# like : like
# buciner : buciner
# tebak : tebak
# judul : judul
# penyanyi : nyanyi
# lagu : lagu
# dinyanyikan : nyanyi
# yayank : yayank
# emezz : emezz
# rocker : rocker
# junior : junior
# dbawah : dbawah
# gaskeeuun : gaskeeuun
# cuaca : cuaca
# mendung : mendung
# ajau : ajau
# berinteraksi : interaksi
# sungkan : sungkan
# oalah : oalah
# masnya : mas
# first : first
# media : media
# tethering : tethering
# banged : banged
# kelas : kelas
# daring : daring
# dng : dng
# perbulan : bulan
# pasir : pasir
# putih : putih
# mengecewakan : kecewa
# sakia : sakia
# oiya : oiya
# berterima : terima
# kebaca : baca
# karakter : karakter
# helmi : helm
# nis : nis
# seluler : seluler
# mengkaji : kaji
# peraturan : atur
# bersekongkol : sekongkol
# memantau : pantau
# kesetiaan : setia
# migrasi : migrasi
# khawatir : khawatir
# kemudahan : mudah
# kinanthi : kinanthi
# expiry : expiry
# neng : neng
# sinyale : sinyale
# krsan : krsan
# jaringanku : jaring
# terjamin : jamin
# testinya : testinya
# gsm : gsm
# jjur : jjur
# rolly : rolly
# mengakibatkan : akibat
# yeyek : yeyek
# memegang : pegang
# tifatul : tifatul
# krs : krs
# insyaallah : insyaallah
# akunnya : akun
# tanggapin : tanggapin
# memperbaiki : baik
# pulau : pulau
# maluku : malu
# haruku : haru
# kasian : kasi
# mengajar : ajar
# hrs : hrs
# love : love
# naufall : naufall
# gembok : gembok
# hhhhhhhhhhhhh : hhhhhhhhhhhhh
# batuceper : batuceper
# kelurahan : lurah
# poris : poris
# january : january
# buriq : buriq
# okay : okay
# citra : citra
# diah : diah
# erli : erli
# card : card
# terbaca : baca
# nihhhh : nihhhh
# pengumuman : umum
# umumkan : umum
# makan : makan
# dapatkan : dapat
# ruby : ruby
# item : item
# skin : skin
# pilihanmu : pilih
# lek : lek
# ukurane : ukurane
# jareku : jareku
# soale : soale
# ndek : ndek
# monetary : monetary
# sii : sii
# paketannya : paket
# halah : halah
# slash : slash
# mainkan : main
# gitar : gitar
# muh : muh
# elah : elah
# akhri : akhri
# umur : umur
# loop : loop
# gunanya : guna
# bonusan : bonus
# cice : cice
# usia : usia
# last : last
# nie : nie
# waqaf : waqaf
# warga : warga
# yha : yha
# pesan : pesan
# artis : artis
# perhatian : perhati
# hasan : hasan
# tindak : tindak
# iseng : iseng
# tnyt : tnyt
# ngabisin : ngabisin
# bocor : bocor
# alus : alus
# sadar : sadar
# tiang : tiang
# keropos : keropos
# jln : jln
# kalibaru : kalibaru
# kel : kel
# kec : kec
# cilincing : cilincing
# jakut : jakut
# secepanya : secepanya
# membahayakan : bahaya
# ners : ners
# handphonenya : handphonenya
# makasi : makas
# siaangg : siaangg
# diperbaruin : diperbaruin
# titik : titik
# syafiq : syafiq
# kdg : kdg
# jgk : jgk
# caj : caj
# bakat : bakat
# peserta : serta
# giveaway : giveaway
# melok : lok
# mypertamina : mypertamina
# blas : blas
# care : care
# gapake : gapake
# br : br
# miyun : miyun
# senang : senang
# merespon : merespon
# masib : masib
# asmara : asmara
# maudy : maudy
# tuker : tuker
# riana : riana
# gamemax : gamemax
# respons : respons
# aturan : atur
# penjualan : jual
# dibekukan : beku
# spill : spill
# stamps : stamps
# firman : firman
# pemasangan : pasang
# quppa : quppa
# riko : riko
# membayar : bayar
# berjalan : jalan
# suket : suket
# dinas : dinas
# kependudukan : duduk
# pencatatan : catat
# sipil : sipil
# pemerintah : perintah
# melampirkan : lampir
# keluarga : keluarga
# alisa : alisa
# mengunjungi : unjung
# kulakannya : kulak
# unang : unang
# rmadhanta : rmadhanta
# nutup : nutup
# wakaf : wakaf
# internt : internt
# tipu : tipu
# binjai : binjai
# daei : daei
# tawaran : tawar
# pemberitahuan : pemberitahuan
# interner : interner
# pmblian : pmblian
# mili : mil
# lewatkan : lewat
# pertandingan : tanding
# mince : mince
# bls : bls
# sbel : sbel
# badanku : badan
# gemukan : gemuk
# pdahal : pdahal
# otot : otot
# iri : iri
# smnyg : smnyg
# kulitnya : kulit
# cat : cat
# avian : avian
# pesek : pesek
# idung : idung
# tower : tower
# ipk : ipk
# sepi : sepi
# bor : bor
# juara : juara
# wijadnako : wijadnako
# aseng : aseng
# nyedot : nyedot
# anomali : anomali
# membuka : buka
# bandwidth : bandwidth
# laman : laman
# leletnya : lelet
# como : como
# kuy : kuy
# kehabisan : habis
# kwota : kwota
# saliman : salim
# menyebabkan : sebab
# adelia : adelia
# kekuras : kuras
# bles : bles
# purwonegoro : purwonegoro
# selatan : selatan
# kab : kab
# banjarnegara : banjarnegara
# jateng : jateng
# berfungsi : fungsi
# mari : mari
# pelapor : lapor
# abu : abu
# janda : janda
# dilaporkan : lapor
# mencatut : catut
# knpi : knpi
# kyk : kyk
# deny : deny
# zulfikar : zulfikar
# ditgkp : ditgkp
# karyawan : karyawan
# mengatasnamakan : mengatasnamakan
# ditindaklanjuti : ditindaklanjuti
# regular : regular
# kecuali : kecuali
# kgk : kgk
# skg : skg
# kebutuhan : butuh
# cmn : cmn
# survei : survei
# bner : bner
# dibaca : baca
# serius : serius
# kau : kau
# nak : nak
# betapa : betapa
# lajulah : laju
# indoosat : indoosat
# toko : toko
# takde : takde
# pros : pros
# cons : cons
# package : package
# vcc : vcc
# jasa : jasa
# jola : jola
# nawarin : nawarin
# plsa : plsa
# plg : plg
# bundling : bundling
# adrian : adrian
# berbeda : beda
# disesuaikan : sesuai
# skema : skema
# diperhatiin : diperhatiin
# togel : togel
# cctv : cctv
# pinjaman : pinjam
# nguehehehe : nguehehehe
# rentenir : rentenir
# jatuhnya : jatuh
# selisih : selisih
# diganti : ganti
# blockir : blockir
# sos : sos
# setianya : setia
# tega : tega
# platinum : platinum
# gold : gold
# menguntungkan : untung
# gapunya : gapunya
# wipi : wipi
# bersahabatlah : sahabat
# denganku : dengan
# barat : barat
# roxy : roxy
# tarik : tarik
# benangnya : benang
# sebentar : sebentar
# kepcer : kepcer
# telkonsel : telkonsel
# tiada : tiada
# bayu : bayu
# ukuran : ukur
# cross : cross
# selling : selling
# kebijakan : bijak
# andika : andika
# angel : angel
# warrior : warrior
# seru : seru
# games : games
# website : website
# dapetin : dapetin
# kos : kos
# maling : maling
# asca : asca
# fitnah : fitnah
# ketidaknyamanannya : ketidaknyamanannya
# investigasi : investigasi
# diharapkan : harap
# secepatnya : cepat
# ukuranya : ukuranya
# dipotong : potong
# stlh : stlh
# simnya : simnya
# slot : slot
# melanggar : langgar
# adab : adab
# etika : etika
# tuduhan : tuduh
# utamanya : utama
# dio : dio
# memble : memble
# anyinglah : anyinglah
# blok : blok
# yok : yok
# utang : utang
# ngadi : ngadi
# menurutku : turut
# enak : enak
# leluasa : leluasa
# syg : syg
# tuk : tuk
# yutup : yutup
# nyediain : nyediain
# stabilin : stabilin
# sinyall : sinyall
# ngopi : ngopi
# mager : mager
# gerai : gerai
# ekeke : ekeke
# yeye : yeye
# stay : stay
# kut : kut
# mempertahankan : tahan
# kacrut : kacrut
# mehong : mehong
# hyllyh : hyllyh
# kronologi : kronologi
# penipu : tipu
# sianto : sianto
# register : register
# diblokir : blokir
# rekeningnya : rekening
# andre : andre
# guritno : guritno
# memnag : memnag
# qilla : qilla
# malming : malming
# babi : babi
# history : history
# berpuluh : puluh
# puluh : puluh
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# isinya : isi
# cuman : cuman
# menyapa : sapa
# top : top
# amakasih : amakasih
# paham : paham
# kestabilan : stabil
# coc : coc
# momon : momon
# normal : normal
# selasa : selasa
# chek : chek
# kenormalan : normal
# josh : josh
# rafly : rafly
# sekalinya : sekali
# semarang : semarang
# gedung : gedung
# smpe : smpe
# barangkali : barangkali
# mbutuhkan : mbutuhkan
# yesss : yesss
# prasetiyo : prasetiyo
# musik : musik
# acoustic : acoustic
# ramenations : ramenations
# satnight : satnight
# star : star
# close : close
# special : special
# perfomance : perfomance
# thedthreeband : thedthreeband
# sempai : sempai
# terlewatkan : lewat
# palembang : palembang
# veteran : veteran
# seberang : seberang
# soma : soma
# deretan : deret
# sumatera : sumatera
# haloo : haloo
# alatnya : alat
# deskripsi : deskripsi
# wkwkwkwk : wkwkwkwk
# mepet : mepet
# rugi : rugi
# stiker : stiker
# yosep : yosep
# cardku : cardku
# eror : eror
# kredit : kredit
# merelakan : rela
# tehambat : tehambat
# udahan : udahan
# perbandingan : banding
# lost : lost
# rbt : rbt
# citraallegro : citraallegro
# dibebankan : beban
# dipajakin : dipajakin
# dikenakan : kena
# stamp : stamp
# menukarkan : tukar
# yes : yes
# try : try
# jambi : jambi
# hahahha : hahahha
# ciput : ciput
# elok : elok
# sikit : sikit
# haih : haih
# pon : pon
# there : there
# okedeh : okedeh
# sbnrnya : sbnrnya
# asing : asing
# krna : krna
# official : official
# kerajinan : rajin
# kendor : kendor
# agree : agree
# mmg : mmg
# power : power
# being : being
# pain : pain
# pantat : pantat
# ketinggalan : tinggal
# misuh : misuh
# discord : discord
# nyinggung : nyinggung
# overhype : overhype
# kisah : kisah
# hans : hans
# ginting : ginting
# indomie : indomie
# saran : saran
# udeh : udeh
# mcm : mcm
# hahahah : hahahah
# amir : amir
# ahmat : ahmat
# yuli : yuli
# nlp : nlp
# putus : putus
# ucapin : ucapin
# keseruan : seru
# dosenku : dosen
# repot : repot
# gaasik : gaasik
# kumpul : kumpul
# virtual : virtual
# dandan : dandan
# tampil : tampil
# tipsnya : tipsnya
# nagita : nagita
# corner : corner
# fashion : fashion
# stylist : stylist
# artist : artist
# ternama : nama
# dicetup : dicetup
# indra : indra
# bgsdddt : bgsdddt
# cia : cia
# true : true
# pergi : pergi
# tumpak : tumpak
# sewu : sewu
# air : air
# around : around
# kebawah : bawah
# still : still
# which : which
# think : think
# telko : telko
# kalimat : kalimat
# nyebutin : nyebutin
# kodenya : kode
# argh : argh
# gasih : gasih
# samisami : samisami
# genset : genset
# bukit : bukit
# antena : antena
# menaranya : menara
# terbangun : bangun
# ijal : ijal
# apanii : apanii
# fahri : fahri
# kwonie : kwonie
# mendpatkan : mendpatkan
# tertera : tera
# gbytes : gbytes
# innalilahi : innalilahi
# berpulang : pulang
# ditinggalian : ditinggalian
# ketabahan : tabah
# pray : pray
# terkirim : kirim
# notifnya : notifnya
# matikan : mati
# mitra : mitra
# tertulis : tulis
# menghubungi : hubung
# mematikan : mati
# langganannya : langgan
# peduli : peduli
# orangnya : orang
# yaallah : yaallah
# yuta : yuta
# nctzen : nctzen
# berburu : buru
# wallpaper : wallpaper
# eiffel : eiffel
# menara : menara
# tdnya : tdnya
# tkt : tkt
# vina : vina
# seriusan : serius
# twit : twit
# waw : waw
# penyebaran : sebar
# virus : virus
# terhindar : hindar
# rama : rama
# reynita : reynita
# ravi : ravi
# membuatmu : buat
# beristighfar : beristighfar
# wahyu : wahyu
# ryn : ryn
# gimane : gimane
# bacaan : baca
# berkala : kala
# yailah : yailah
# program : program
# memek : memek
# helloooo : helloooo
# yunus : yunus
# ghufron : ghufron
# hub : hub
# dikembalikan : kembali
# enaknya : enak
# alias : alias
# ngentooooooddddd : ngentooooooddddd
# balaaa : balaaa
# settingan : settingan
# belaka : belaka
# pemenangnya : menang
# setinggan : setinggan
# icha : icha
# bec : bec
# electronic : electronic
# centre : centre
# purnawarman : purnawarman
# mvakeee : mvakeee
# luwih : luwih
# difa : difa
# alaidid : alaidid
# polri : polri
# menggugat : gugat
# bro : bro
# gprs : gprs
# diinfokan : info
# jengkel : jengkel
# bingin : bingin
# ngatain : ngatain
# ntar : ntar
# tuntut : tuntut
# mukmin : mukmin
# jela : jela
# padu : padu
# melawat : lawat
# rmh : rmh
# kwn : kwn
# indon : indon
# sial : sial
# template : template
# induknye : induknye
# lk : lk
# siiih : siiih
# ninja : ninja
# pontianak : pontianak
# nek : nek
# berjuang : juang
# ming : ming
# chatan : chatan
# iso : iso
# cuk : cuk
# ngadain : ngadain
# telkomseeel : telkomseeel
# oelh : oelh
# terpaksa : paksa
# dibatalkan : batal
# dicharge : dicharge
# grapatri : grapatri
# nikolas : nikolas
# rizya : rizya
# rhia : rhia
# nda : nda
# die : die
# lajuu : lajuu
# batalkan : batal
# hero : hero
# meta : meta
# legends : legends
# vocer : vocer
# simpang : simpang
# ulim : ulim
# aceh : aceh
# kot : kot
# timetu : timetu
# puas : puas
# kawasan : kawasan
# banda : banda
# tiptop : tiptop
# kenapasi : napas
# benci : benci
# lohiya : lohiya
# setahu : tahu
# distributor : distributor
# pengedar : edar
# pengecer : ecer
# lgs : lgs
# gede : gede
# dikenai : kena
# cilik : cilik
# masakan : masakan
# posting : posting
# screenshot : screenshot
# menangkal : tangkal
# bentuk : bentuk
# terang : terang
# kenyamanan : nyaman
# inbox : inbox
# papa : papa
# hikd : hikd
# buffer : buffer
# deal : deal
# kabupaten : kabupaten
# provinsi : provinsi
# diteror : teror
# dikenal : kenal
# pkaet : pkaet
# rekomended : rekomended
# kate : kate
# ngawi : ngawi
# push : push
# rank : rank
# bully : bully
# team : team
# hmmmmm : hmmmmm
# jatim : jatim
# prank : prank
# cerita : cerita
# musuhan : musuh
# moonton : moonton
# kyknya : kyknya
# pingnya : pingnya
# tulisannya : tulis
# problem : problem
# invalid : invalid
# mmi : mmi
# ningkatin : ningkatin
# hack : hack
# aov : aov
# jsm : jsm
# dapatin : dapatin
# gratisannya : gratis
# paraaahhh : paraaahhh
# gerak : gerak
# alhasil : alhasil
# ditoxicin : ditoxicin
# panen : panen
# cokelat : cokelat
# signalmu : signalmu
# ndet : ndet
# ndetan : ndetan
# mybusiness : mybusiness
# dewo : dewo
# saranin : saranin
# good : good
# lockey : lockey
# fhaa : fhaa
# risss : risss
# udara : udara
# ranii : rani
# nyapa : nyapa
# melemah : lemah
# memposting : memposting
# menghindari : hindar
# penyalahgunaan : penyalahgunaan
# bertanggung : tanggung
# curang : curang
# milih : milih
# lncar : lncar
# xuxi : xuxi
# kimmy : kimmy
# fitur : fitur
# masya : masya
# giliran : gilir
# nanggepin : nanggepin
# gondrongan : gondrong
# couldn : couldn
# send : send
# message : message
# iman : iman
# ces : ces
# reg : reg
# nik : nik
# price : price
# list : list
# sedot : sedot
# sempet : sempet
# perluas : luas
# pasar : pasar
# gandeng : gandeng
# sediakan : sedia
# digital : digital
# arah : arah
# kalimatx : kalimatx
# pln : pln
# susahx : susahx
# rakyat : rakyat
# nii : nii
# besarx : besarx
# beban : beban
# smakin : smakin
# raya : raya
# miskin : miskin
# melarat : melarat
# knapa : knapa
# toraja : toraja
# saluputti : saluputti
# bangt : bangt
# skolah : skolah
# terganggu : ganggu
# andalannye : andalannye
# perubahannya : ubah
# ika : ika
# mar : mar
# bernostalgia : nostalgia
# situ : situ
# perumtel : perumtel
# menyediakan : sedia
# telekomunikasi : telekomunikasi
# kelak : kelak
# melahirkan : lahir
# bicara : bicara
# medio : medio
# fathan : fathan
# nastiti : nastiti
# okey : okey
# widya : widya
# mamang : mamang
# pindahin : pindahin
# mita : mita
# nomerku : nomerku
# ketarik : tarik
# terpecahkan : pecah
# eek : eek
# roberdtian : roberdtian
# harun : harun
# sinyalkuuu : sinyalkuuu
# nanang : nanang
# diangkat : angkat
# temenku : temenku
# kalopun : kalo
# syopi : syopi
# nelfon : nelfon
# vincell : vincell
# tokped : tokped
# sihh : sihh
# jncokk : jncokk
# blyat : blyat
# sumbersalak : sumbersalak
# ledokombo : ledokombo
# jawa : jawa
# ayas : ayas
# ngetweet : ngetweet
# progress : progress
# diruqyah : diruqyah
# awet : awet
# seboros : boros
# nich : nich
# bercecerannya : cecer
# kadrun : kadrun
# mestinya : mesti
# erick : erick
# thohir : thohir
# mengambil : ambil
# publik : publik
# menteri : menteri
# kuasa : kuasa
# membersihkan : bersih
# tanggung : tanggung
# bersihkan : sih
# induknya : induk
# veronika : veronika
# asisten : asisten
# berita : berita
# ginj : ginj
# ujian : uji
# percaya : percaya
# dehh : dehh
# vader : vader
# banu : banu
# dipenjelsan : dipenjelsan
# bein : bein
# instgram : instgram
# rudy : rudy
# heh : heh
# disuru : disuru
# semalam : malam
# lakuin : lakuin
# dicuri : curi
# rizahinterland : rizahinterland
# penyedia : sedia
# smm : smm
# view : view
# instagran : instagran
# ket : ket
# permanen : permanen
# pemesanan : mesan
# komentar : komentar
# random : random
# followers : followers
# permanent : permanent
# fyp : fyp
# share : share
# maisara : maisara
# pegiat : giat
# menyoroti : sorot
# organisasi : organisasi
# kerohanian : rohani
# dikuasai : asai
# kzl : kzl
# bet : bet
# sportivo : sportivo
# nambahin : nambahin
# adm : adm
# sya : sya
# penyesuaian : sesuai
# dikondisikan : kondisi
# disediakan : sedia
# dibandingkan : banding
# merakyat : rakyat
# patut : patut
# diapresiasi : apresiasi
# rizka : rizka
# doyoung : doyoung
# taeyong : taeyong
# lahhhhhhhh : lahhhhhhhh
# mahalllll : mahalllll
# bjbdigi : bjbdigi
# gal : gal
# berlin : lin
# febi : febi
# rian : rian
# okta : okta
# jia : jia
# tizna : tizna
# misbah : misbah
# complain : complain
# noh : noh
# tiati : tiati
# dkk : dkk
# menerima : terima
# twitternya : twitternya
# prime : prime
# doank : doank
# leptop : leptop
# nyoba : nyoba
# ngikutin : ngikutin
# drakor : drakor
# vik : vik
# towernya : towernya
# ajah : ajah
# bpp : bpp
# only : only
# blong : blong
# duta : duta
# bandara : bandara
# permai : permai
# aryadipa : aryadipa
# spesial : spesial
# aslina : aslina
# ciga : ciga
# pelangi : pelangi
# adaa : adaa
# diskonnya : diskon
# baris : baris
# gues : gues
# bagii : bagi
# bisaaa : bisaaa
# misna : misna
# desag : desag
# prialugu : prialugu
# ceheck : ceheck
# neeeng : neeeng
# extra : extra
# dihilanginn : dihilanginn
# dihilangin : dihilangin
# serasa : serasa
# nasabah : nasabah
# jerry : jerry
# menonton : tonton
# high : high
# medium : medium
# low : low
# perangkat : perangkat
# bara : bara
# cuuuk : cuuuk
# monmaap : monmaap
# sultan : sultan
# noted : noted
# lucky : lucky
# draw : draw
# more : more
# ita : ita
# winda : winda
# multimedia : multimedia
# pembohong : bohong
# utuh : utuh
# turunin : turunin
# kosan : kosan
# gas : gas
# numpang : numpang
# divani : divani
# laras : laras
# email : email
# digubris : gubris
# berhari : hari
# kuliah : kuliah
# dina : dina
# suci : suci
# aisha : aisha
# rudi : rudi
# sari : sari
# sent : sent
# cancel : cancel
# mugiwara : mugiwara
# sekar : sekar
# pam : pam
# anah : anah
# wingi : wing
# menghanguskan : hangus
# kene : kene
# dikos : dikos
# gek : gek
# wektuku : wektuku
# akeh : akeh
# entek : entek
# bien : bien
# apik : apik
# from : from
# rani : rani
# mekakses : mekakses
# enggk : enggk
# yosh : yosh
# sidang : sidang
# pinjam : pinjam
# weehii : weehii
# gretong : gretong
# disneyyy : disneyyy
# wts : wts
# under : under
# apps : apps
# ych : ych
# pkek : pkek
# dwi : dwi
# tito : tito
# mencangkup : cangkup
# okeee : okeee
# melakikan : laki
# mainan : main
# brand : brand
# rayan : rayan
# nontin : nontin
# rcti : rcti
# maxmedia : maxmedia
# konfirmasinya : konfirmasi
# mengurusnya : urus
# alpri : alpri
# yag : yag
# aksesnya : akses
# kurangi : kurang
# label : label
# rbu : rbu
# ngelucu : ngelucu
# nyuruh : nyuruh
# layananmu : layan
# ghia : ghia
# kurangin : rangin
# mengganggu : ganggu
# bagusnya : bagus
# dibatasin : dibatasin
# downloadnya : downloadnya
# jdinya : jdinya
# stream : stream
# namamu : nama
# marce : marce
# help : help
# ilhamsah : ilhamsah
# fachul : fachul
# collect : collect
# tersisa : sisa
# tujuan : tuju
# bersedia : sedia
# mengenal : kenal
# permainan : main
# agusdomino : agusdomino
# hukan : hukan
# frendy : frendy
# lucu : lucu
# ngedonlot : ngedonlot
# akunya : aku
# diaa : diaa
# taring : taring
# beneran : beneran
# mastiin : mastiin
# byte : byte
# takut : takut
# nangkep : nangkep
# maksutnya : maksutnya
# cowo : cowo
# menikmati : nikmat
# merlion : merlion
# undiannya : undi
# lihatnya : lihat
# cappuicino : cappuicino
# prediksi : prediksi
# pools : pools
# dmm : dmm
# kakkk : kakkk
# yayas : yayas
# kntol : kntol
# beristirahat : istirahat
# sektor : sektor
# usaha : usaha
# korporasi : korporasi
# kesehatan : sehat
# private : private
# joni : joni
# keliatan : liat
# syipa : syipa
# fajaar : fajaar
# mengganti : ganti
# sedih : sedih
# langit : langit
# center : center
# yaelah : yaelah
# suru : suru
# hehehe : hehehe
# pelayanannya : layan
# wis : wis
# kekno : kekno
# indihom : indihom
# sukhoon : sukhoon
# nad : nad
# angot : angot
# inforjmasikan : inforjmasikan
# banking : banking
# gataunya : gataunya
# warung : warung
# mang : mang
# oyo : oyo
# gdc : gdc
# syalan : syal
# ginian : ginian
# ritual : ritual
# goib : goib
# ckck : ckck
# nsp : nsp
# cita : cita
# citata : citata
# lisa : lisa
# nggada : nggada
# saputri : saputri
# pic : pic
# person : person
# mengelola : kelola
# komunitas : komunitas
# cug : cug
# jago : jago
# nyedotin : nyedotin
# khilap : khilap
# sedetik : detik
# udahhh : udahhh
# ngentoy : ngentoy
# teu : teu
# waro : waro
# jadaah : jadaah
# telkon : telkon
# pengertian : erti
# definisi : definisi
# kepanjangan : panjang
# tetsebut : tetsebut
# pham : pham
# aldilla : aldilla
# isna : isna
# pakaimasker : pakaimasker
# peredaran : edar
# seminggu : minggu
# bersua : sua
# dim : dim
# panduannya : pandu
# kendalanya : kendala
# kirimkan : kirim
# pecin : pecin
# socah : socah
# bangkalan : bangkal
# madura : madura
# merasakan : rasa
# report : report
# valiant : valiant
# {'permisi': 'permisi', 'nitip': 'nitip', 'iklan': 'iklan', 'kak': 'kak', 'readystock': 'readystock', 'nomer': 'nomer', 'cantik': 'cantik', 'start': 'start', 'harga': 'harga', 'rb': 'rb', 'telkomsel': 'telkomsel', 'indosat': 'indosat', 'smart': 'smart', 'cek': 'cek', 'stock': 'stock', 'lbh': 'lbh', 'sesuai': 'sesuai', 'budget': 'budget', 'fastrespon': 'fastrespon', 'rossvalinshop': 'rossvalinshop', 'loc': 'loc', 'malang': 'malang', 'req': 'req', 'shopee': 'shopee', '': '', 'testi': 'testi', 'pembelian': 'beli', 'jual': 'jual', 'pulsa': 'pulsa', 'murah': 'murah', 'dpt': 'dpt', 'ucapan': 'ucap', 'selamat': 'selamat', 'pagi': 'pagi', 'operator': 'operator', 'bahagianya': 'bahagia', 'anjim': 'anjim', 'banget': 'banget', 'open': 'open', 'convert': 'convert', 'tri': 'tri', 'three': 'three', 'axis': 'axis', 'tsel': 'tsel', 'isat': 'isat', 'im': 'im', 'ewallet': 'ewallet', 'bank': 'bank', 'non': 'non', 'premium': 'premium', 'dana': 'dana', 'ovo': 'ovo', 'gopay': 'gopay', 'shopeepay': 'shopeepay', 'linkaja': 'linkaja', 'preset': 'preset', 'lightroom': 'lightroom', 'agen': 'agen', 'kuota': 'kuota', 'halo': 'halo', 'kecepatan': 'cepat', 'produk': 'produk', 'beda': 'beda', 'kartu': 'kartu', 'mohon': 'mohon', 'penjelasan': 'jelas', 'prem': 'prem', 'ios': 'ios', 'andro': 'andro', 'join': 'join', 'dilikes': 'dilikes', 'member': 'member', 'maaf': 'maaf', 'terkait': 'kait', 'keluhan': 'keluh', 'sinyal': 'sinyal', 'stabil': 'stabil', 'udah': 'udah', 'coba': 'coba', 'refresh': 'refresh', 'jaringan': 'jaring', 'pindahkan': 'pindah', 'otomatis': 'otomatis', 'manual': 'manual', 'yuk': 'yuk', 'infoin': 'infoin', 'nomor': 'nomor', 'lokasi': 'lokasi', 'tanggal': 'tanggal', 'kejadian': 'jadi', 'berkendala': 'kendala', 'tks': 'tks', 'asti': 'asti', 'skrg': 'skrg', 'bayar': 'bayar', 'pay': 'pay', 'bales': 'bales', 'kaya': 'kaya', 'gini': 'gin', 'ngebantu': 'ngebantu', 'solusi': 'solusi', 'ujung': 'ujung', 'ujungnya': 'ujung', 'dibales': 'dibales', 'sebenernya': 'sebenernya', 'adminnya': 'adminnya', 'hidup': 'hidup', 'komputer': 'komputer', 'beli': 'beli', 'ekstra': 'ekstra', 'maek': 'maek', 'haji': 'haji', 'gb': 'gb', 'hijaudaun': 'hijaudaun', 'sakit': 'sakit', 'rindu': 'rindu', 'ketik': 'ketik', 'strlm': 'strlm', 'kirim': 'kirim', 'emg': 'emg', 'mantap': 'mantap', 'wkwkw': 'wkwkw', 'recommend': 'recommend', 'game': 'game', 'online': 'online', 'gausah': 'gausah', 'compare': 'compare', 'ama': 'ama', 'sejaringan': 'jaring', 'pabji': 'pabji', 'ms': 'ms', 'byu': 'byu', 'cocok': 'cocok', 'download': 'download', 'streaming': 'streaming', 'speed': 'speed', 'kirain': 'kirain', 'kya': 'kya', 'gitu': 'gitu', 'bosen': 'bosen', 'komplen': 'komplen', 'pakai': 'pakai', 'bagus': 'bagus', 'rumah': 'rumah', 'provider': 'provider', 'dlu': 'dlu', 'dipinggir': 'pinggir', 'jalan': 'jalan', 'rei': 'rei', 'mimin': 'mimin', 'meluncur': 'luncur', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'makasih': 'makasih', 'fadh': 'fadh', 'internet': 'internet', 'ganggu': 'ganggu', 'bln': 'bln', 'gni': 'gni', 'daily': 'daily', 'update': 'update', 'rate': 'rate', 'terima': 'terima', 'support': 'support', 'bca': 'bca', 'bni': 'bni', 'mandiri': 'mandiri', 'admin': 'admin', 'wallet': 'wallet', 'hoyong': 'hoyong', 'mah': 'mah', 'ganti': 'ganti', 'iyeu': 'iyeu', 'utama': 'utama', 'iya': 'iya', 'bener': 'bener', 'teratasi': 'atas', 'setuju': 'tuju', 'jwbanya': 'jwbanya', 'gtu': 'gtu', 'sampe': 'sampe', 'grapari': 'grapari', 'sigyalnya': 'sigyalnya', 'ilang': 'ilang', 'pdhal': 'pdhal', 'tinggal': 'tinggal', 'kota': 'kota', 'paket': 'paket', 'mahal': 'mahal', 'cepet': 'cepet', 'habis': 'habis', 'sigyal': 'sigyal', 'lemah': 'lemah', 'berfikir': 'berfikir', 'sigyalnta': 'sigyalnta', 'urang': 'urang', 'ayeuna': 'ayeuna', 'tos': 'tos', 'lur': 'lur', 'saipul': 'saipul', 'perihal': 'perihal', 'kendala': 'kendala', 'kakak': 'kakak', 'infokan': 'info', 'via': 'via', 'privasi': 'privasi', 'terjaga': 'jaga', 'bangun': 'bangun', 'tidur': 'tidur', 'solat': 'solat', 'hilang': 'hilang', 'kesini': 'kesini', 'jelek': ...
# ------------------------
# Pandas Apply:   0%|          | 0/1953 [00:00<?, ?it/s]
#                                                 content  \
# 0     @quanshika permisi.. nitip iklan ya kak🙇‍♀️ re...
# 1     96. testi pembelian ; jual pulsa telkomsel mur...
# 2                @telkomsel @pppunten @telkomsel cek dm
# 3     @buburayamena sama, aku juga dpt ucapan selama...
# 4     open convert🤑\n✨cv pulsa (tri three, xl axis, ...
# ...                                                 ...
# 1993  @spicygiggle @gamesmenfess @erlandarln report ...
# 1995  @rizqycipta baik, kak. mimin cek dm kakak suda...
# 1996  bos jaringan lu tengah malem gg parah sih @tel...
# 1997  @gaze_valiant jika sudah, namun tetap sama, yu...
# 1998  @gaze_valiant hai, kak. mohon maaf, perihal ke...
#
#                                          cleaning_tweet  \
# 0     permisi nitip iklan kak readystock nomer canti...
# 1            testi pembelian jual pulsa telkomsel murah
# 2                                                  cek
# 3     sama aku juga dpt ucapan selamat pagi dari ope...
# 4     open convert pulsa tri three axis tsel telkoms...
# ...                                                 ...
# 1993                                   report telkomsel
# 1995  baik kak mimin cek kakak sudah masuk antrian m...
# 1996           bos jaringan tengah malem parah sih cek
# 1997   valiant jika sudah namun tetap sama yuk infok...
# 1998   valiant hai kak mohon maaf perihal kendala si...
#
#                                              tokenisasi  \
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1     [, testi, pembelian, jual, pulsa, telkomsel, m...
# 2                                               [cek, ]
# 3     [sama, aku, juga, dpt, ucapan, selamat, pagi, ...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [baik, kak, mimin, cek, kakak, sudah, masuk, a...
# 1996  [bos, jaringan, tengah, malem, parah, sih, cek, ]
# 1997  [, valiant, jika, sudah, namun, tetap, sama, y...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
#                                                stopword  \
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1     [, testi, pembelian, jual, pulsa, telkomsel, m...
# 2                                               [cek, ]
# 3     [dpt, ucapan, selamat, pagi, operator, telkoms...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [kak, mimin, cek, kakak, masuk, antrian, mohon...
# 1996               [bos, jaringan, malem, parah, cek, ]
# 1997  [, valiant, yuk, infokan, nomor, lokasi, nomor...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
#                                                stemming
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1        [, testi, beli, jual, pulsa, telkomsel, murah]
# 2                                               [cek, ]
# 3     [dpt, ucap, selamat, pagi, operator, telkomsel...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [kak, mimin, cek, kakak, masuk, antri, mohon, ...
# 1996                 [bos, jaring, malem, parah, cek, ]
# 1997  [, valiant, yuk, info, nomor, lokasi, nomor, k...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
# [1953 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [permisi, nitip, iklan, kak, readystock, nomer...
# 1        [, testi, beli, jual, pulsa, telkomsel, murah]
# 2                                               [cek, ]
# 3     [dpt, ucap, selamat, pagi, operator, telkomsel...
# 4     [open, convert, pulsa, tri, three, axis, tsel,...
# ...                                                 ...
# 1993                                [report, telkomsel]
# 1995  [kak, mimin, cek, kakak, masuk, antri, mohon, ...
# 1996                 [bos, jaring, malem, parah, cek, ]
# 1997  [, valiant, yuk, info, nomor, lokasi, nomor, k...
# 1998  [, valiant, hai, kak, mohon, maaf, perihal, ke...
#
# [1953 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_1.xlsx')
