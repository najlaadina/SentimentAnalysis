# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @Gadis48060642 2. Facebook Messenger 'Telkomse...
# 1     @Gadis48060642 Baik, Kak Indra. Maaf banget ya...
# 2     @AlprimaJurnas Hai, Kak Alprima. Maaf ya. Meng...
# 3     @Telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @Telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan Hai, Kak Indah. Maaf ya. Mengena...
# 1996         @Telkomsel Ya iya semua kawang nguluh sama
# 1997  @almasyfm @Telkomsel @IndiHome Pagi kak alma, ...
# 1998  @islamianandaku Baik, Kak Islamia. Maaf ya Mim...
# 1999  @max2game 4. Nomor Telkomsel lain yang berkend...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 39

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @Gadis48060642 2. Facebook Messenger 'Telkomse...
# 1     @Gadis48060642 Baik, Kak Indra. Maaf banget ya...
# 2     @AlprimaJurnas Hai, Kak Alprima. Maaf ya. Meng...
# 3     @Telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @Telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan Hai, Kak Indah. Maaf ya. Mengena...
# 1996         @Telkomsel Ya iya semua kawang nguluh sama
# 1997  @almasyfm @Telkomsel @IndiHome Pagi kak alma, ...
# 1998  @islamianandaku Baik, Kak Islamia. Maaf ya Mim...
# 1999  @max2game 4. Nomor Telkomsel lain yang berkend...
#
# [1943 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @gadis48060642 2. facebook messenger 'telkomse...
# 1     @gadis48060642 baik, kak indra. maaf banget ya...
# 2     @alprimajurnas hai, kak alprima. maaf ya. meng...
# 3     @telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan hai, kak indah. maaf ya. mengena...
# 1996         @telkomsel ya iya semua kawang nguluh sama
# 1997  @almasyfm @telkomsel @indihome pagi kak alma, ...
# 1998  @islamianandaku baik, kak islamia. maaf ya mim...
# 1999  @max2game 4. nomor telkomsel lain yang berkend...
#
# [1943 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @gadis48060642 2. facebook messenger 'telkomse...
# 1     @gadis48060642 baik, kak indra. maaf banget ya...
# 2     @alprimajurnas hai, kak alprima. maaf ya. meng...
# 3     @telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan hai, kak indah. maaf ya. mengena...
# 1996         @telkomsel ya iya semua kawang nguluh sama
# 1997  @almasyfm @telkomsel @indihome pagi kak alma, ...
# 1998  @islamianandaku baik, kak islamia. maaf ya mim...
# 1999  @max2game 4. nomor telkomsel lain yang berkend...
#
#                                          cleaning_tweet
# 0      facebook messenger telkomsel telegram officia...
# 1     baik kak indra maaf banget jika kakak berkenda...
# 2     hai kak alprima maaf mengenai keluhan gak bisa...
# 3        kenapa sinyal telkomsel sekarang lemot sekali
# 4     pagi min saya bisa login aplikasi telkomsel ve...
# ...                                                 ...
# 1995  hai kak indah maaf mengenai kendala akses inte...
# 1996                       iya semua kawang nguluh sama
# 1997      pagi kak alma silahkan telkomselnya lewat yaa
# 1998  baik kak islamia maaf mimin sarankan tidak inf...
# 1999   nomor telkomsel lain yang berkendala minimal ...
#
# [1943 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @gadis48060642 2. facebook messenger 'telkomse...
# 1     @gadis48060642 baik, kak indra. maaf banget ya...
# 2     @alprimajurnas hai, kak alprima. maaf ya. meng...
# 3     @telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan hai, kak indah. maaf ya. mengena...
# 1996         @telkomsel ya iya semua kawang nguluh sama
# 1997  @almasyfm @telkomsel @indihome pagi kak alma, ...
# 1998  @islamianandaku baik, kak islamia. maaf ya mim...
# 1999  @max2game 4. nomor telkomsel lain yang berkend...
#
#                                          cleaning_tweet  \
# 0      facebook messenger telkomsel telegram officia...
# 1     baik kak indra maaf banget jika kakak berkenda...
# 2     hai kak alprima maaf mengenai keluhan gak bisa...
# 3        kenapa sinyal telkomsel sekarang lemot sekali
# 4     pagi min saya bisa login aplikasi telkomsel ve...
# ...                                                 ...
# 1995  hai kak indah maaf mengenai kendala akses inte...
# 1996                       iya semua kawang nguluh sama
# 1997      pagi kak alma silahkan telkomselnya lewat yaa
# 1998  baik kak islamia maaf mimin sarankan tidak inf...
# 1999   nomor telkomsel lain yang berkendala minimal ...
#
#                                              tokenisasi
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [baik, kak, indra, maaf, banget, jika, kakak, ...
# 2     [hai, kak, alprima, maaf, mengenai, keluhan, g...
# 3     [kenapa, sinyal, telkomsel, sekarang, lemot, s...
# 4     [pagi, min, saya, bisa, login, aplikasi, telko...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, mengenai, kendala, aks...
# 1996               [, iya, semua, kawang, nguluh, sama]
# 1997  [pagi, kak, alma, silahkan, telkomselnya, lewa...
# 1998  [baik, kak, islamia, maaf, mimin, sarankan, ti...
# 1999  [, nomor, telkomsel, lain, yang, berkendala, m...
#
# [1943 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @gadis48060642 2. facebook messenger 'telkomse...
# 1     @gadis48060642 baik, kak indra. maaf banget ya...
# 2     @alprimajurnas hai, kak alprima. maaf ya. meng...
# 3     @telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan hai, kak indah. maaf ya. mengena...
# 1996         @telkomsel ya iya semua kawang nguluh sama
# 1997  @almasyfm @telkomsel @indihome pagi kak alma, ...
# 1998  @islamianandaku baik, kak islamia. maaf ya mim...
# 1999  @max2game 4. nomor telkomsel lain yang berkend...
#
#                                          cleaning_tweet  \
# 0      facebook messenger telkomsel telegram officia...
# 1     baik kak indra maaf banget jika kakak berkenda...
# 2     hai kak alprima maaf mengenai keluhan gak bisa...
# 3        kenapa sinyal telkomsel sekarang lemot sekali
# 4     pagi min saya bisa login aplikasi telkomsel ve...
# ...                                                 ...
# 1995  hai kak indah maaf mengenai kendala akses inte...
# 1996                       iya semua kawang nguluh sama
# 1997      pagi kak alma silahkan telkomselnya lewat yaa
# 1998  baik kak islamia maaf mimin sarankan tidak inf...
# 1999   nomor telkomsel lain yang berkendala minimal ...
#
#                                              tokenisasi  \
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [baik, kak, indra, maaf, banget, jika, kakak, ...
# 2     [hai, kak, alprima, maaf, mengenai, keluhan, g...
# 3     [kenapa, sinyal, telkomsel, sekarang, lemot, s...
# 4     [pagi, min, saya, bisa, login, aplikasi, telko...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, mengenai, kendala, aks...
# 1996               [, iya, semua, kawang, nguluh, sama]
# 1997  [pagi, kak, alma, silahkan, telkomselnya, lewa...
# 1998  [baik, kak, islamia, maaf, mimin, sarankan, ti...
# 1999  [, nomor, telkomsel, lain, yang, berkendala, m...
#
#                                                stopword
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [kak, indra, maaf, banget, kakak, berkendala, ...
# 2     [hai, kak, alprima, maaf, keluhan, login, apli...
# 3                          [sinyal, telkomsel, lemot, ]
# 4     [pagi, min, login, aplikasi, telkomsel, verifi...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, kendala, akses, intern...
# 1996                            [, iya, kawang, nguluh]
# 1997     [pagi, kak, alma, silahkan, telkomselnya, yaa]
# 1998  [kak, islamia, maaf, mimin, sarankan, infokan,...
# 1999  [, nomor, telkomsel, berkendala, minimal, nomo...
#
# [1943 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3762
# ------------------------
#  :
# facebook : facebook
# messenger : messenger
# telkomsel : telkomsel
# telegram : telegram
# official : official
# bot : bot
# situs : situs
# whatsapp : whatsapp
# virtual : virtual
# asisten : asisten
# aplikasi : aplikasi
# mytelkomsel : mytelkomsel
# makasih : makasih
# micha : micha
# kak : kak
# indra : indra
# maaf : maaf
# banget : banget
# kakak : kakak
# berkendala : kendala
# menghubungi : hubung
# mimin : mimin
# silakan : sila
# instagram : instagram
# email : email
# resmi : resmi
# layanan : layan
# assistant : assistant
# veronika : veronika
# akses : akses
# line : line
# hai : hai
# alprima : alprima
# keluhan : keluh
# login : login
# infokan : info
# nomor : nomor
# via : via
# dibantu : bantu
# cek : cek
# privasi : privasi
# terjaga : jaga
# elma : elma
# sinyal : sinyal
# lemot : lot
# pagi : pagi
# min : min
# verification : verification
# linknya : linknya
# masuk : masuk
# sms : sms
# koneksinya : koneksi
# bingsit : bingsit
# kamboja : kamboja
# bang : bang
# murah : murah
# toel : toel
# langsung : langsung
# gerak : gerak
# cepat : cepat
# pengalaman : alam
# pribadi : pribadi
# komplain : komplain
# gara : gara
# bayar : bayar
# mahal : mahal
# nanya : nanya
# wil : wil
# kalsel : kalsel
# khusus : khusus
# kab : kab
# hst : hst
# hilang : hilang
# mulu : mulu
# tolong : tolong
# perbaiki : baik
# kualitas : kualitas
# ane : ane
# jdi : jdi
# rugi : rugi
# beli : beli
# paket : paket
# pakai : pakai
# kuota : kuota
# restu : restu
# terhubung : hubung
# rekan : rekan
# melanjutkan : lanjut
# interaksi : interaksi
# pricing : pricing
# strategy : strategy
# terbaik : baik
# memenuhi : penuh
# aspek : aspek
# fachmi : fachmi
# zakki : zakki
# hangus : hangus
# data : data
# teregistrasinya : registrasi
# otomatis : otomatis
# terhapus : hapus
# nyaman : nyaman
# jeslyn : jeslyn
# diterima : terima
# berubah : ubah
# sesuai : sesuai
# program : program
# diselenggarakan : selenggara
# berlaku : laku
# penawaran : tawar
# aktivasi : aktivasi
# tersedia : sedia
# dial : dial
# tks : tks
# aloisius : aloisius
# combo : combo
# sakti : sakti
# unlimited : unlimited
# promo : promo
# personal : personal
# skema : skema
# tarif : tarif
# umur : umur
# kartu : kartu
# penggunaan : guna
# kondisi : kondisi
# diregistrasikan : registrasi
# lokasi : lokasi
# detail : detail
# minimal : minimal
# mengandung : kandung
# kecamatan : camat
# kota : kota
# datanya : data
# aman : aman
# kendala : kendala
# udah : udah
# coba : coba
# pilih : pilih
# off : off
# service : service
# infoin : infoin
# uang : uang
# hasil : hasil
# ngebacot : ngebacot
# buzzer : buzzer
# mengeluh : keluh
# emang : emang
# jatah : jatah
# beduai : beduai
# kabupaten : kabupaten
# sanggau : sanggau
# prov : prov
# kalimantan : kalimantan
# barat : barat
# paketan : paket
# internet : internet
# termurah : murah
# malam : malam
# modem : modem
# flash : flash
# lempar : lempar
# kesal : kesal
# iya : iya
# kayak : kayak
# kura : kura
# lemood : lemood
# buang : buang
# sayang : sayang
# puluhan : puluh
# esmosi : esmosi
# provider : provider
# bagus : bagus
# gue : gue
# deh : deh
# mengubungi : ubung
# twitter : twitter
# dias : dias
# mohon : mohon
# berkenan : kenan
# menunggu : tunggu
# agnes : agnes
# ellenwina : ellenwina
# stabil : stabil
# mencoba : coba
# refresh : refresh
# jaringan : jaring
# handphone : handphone
# memindahkan : pindah
# mode : mode
# manual : manual
# pulsa : pulsa
# terlambat : lambat
# peningkatan : tingkat
# sistem : sistem
# mengirim : kirim
# ulang : ulang
# kode : kode
# verifikasi : verifikasi
# indosat : indosat
# pastikan : pasti
# mencukupi : cukup
# trus : trus
# ilang : ilang
# kupang : kupang
# gagal : gagal
# tag : tag
# suwi : suwi
# menerima : terima
# tagihan : tagih
# darurat : darurat
# tanggal : tanggal
# kejadian : jadi
# jelek : jelek
# wajib : wajib
# konsumen : konsumen
# memilih : pilih
# admin : admin
# koreksi : koreksi
# tetiba : tetiba
# permitaan : permitaan
# perihal : perihal
# terpotong : potong
# kemendikbud : kemendikbud
# tgl : tgl
# nominal : nominal
# memalukan : malu
# sekentara : kentara
# harga : harga
# pelangiqq : pelangiqq
# nikmati : nikmat
# hot : hot
# bonus : bonus
# turnover : turnover
# dibagikan : bagi
# minggu : minggu
# referral : referral
# seumur : umur
# hidup : hidup
# whatssapp : whatssapp
# deposit : deposit
# gb : gb
# pas : pas
# nyalain : nyalain
# nyedot : nyedot
# gakepake : gakepake
# kuotanya : kuota
# nia : nia
# bantu : bantu
# karunia : karunia
# terimakasih : terimakasih
# naw : naw
# tunggu : tunggu
# interaksinya : interaksi
# kesini : kesini
# ngerasa : ngerasa
# boros : boros
# simpati : simpati
# simati : simati
# pakainya : pakai
# wilayah : wilayah
# bermasalah : masalah
# knp : knp
# seburuk : buruk
# jarinhan : jarinhan
# indonesia : indonesia
# dibenahi : benah
# rencana : rencana
# persiden : persiden
# memajukan : maju
# tol : tol
# langit : langit
# terpenuhi : penuh
# halo : halo
# seputar : putar
# internetnya : internetnya
# hancurrrr : hancurrrr
# anum : anum
# layanannya : layan
# potong : potong
# cuman : cuman
# kali : kali
# simak : simak
# artikel : artikel
# depo : depo
# wede : wede
# permainan : main
# domino : domino
# bebas : bebas
# potongan : potong
# bos : bos
# register : register
# livechat : livechat
# boneka : boneka
# com : com
# bonekaqq : bonekaqq
# yara : yara
# kayu : kayu
# yak : yak
# far : far
# jaringannya : jaring
# ngegame : ngegame
# manaan : mana
# goblok : goblok
# najis : najis
# butut : butut
# hadirkan : hadir
# proteksi : proteksi
# kemudahan : mudah
# manfaat : manfaat
# produk : produk
# asuransi : asuransi
# allianz : allianz
# segitu : segitu
# dibilang : bilang
# kasihan : kasihan
# ganti : ganti
# benefit : benefit
# prioritas : prioritas
# memantau : pantau
# pemakaian : pakai
# terima : terima
# kasih : kasih
# kesetiaan : setia
# migrasi : migrasi
# kartuhalo : kartuhalo
# prabayar : prabayar
# khawatir : khawatir
# luas : luas
# pelosok : pelosok
# daerah : daerah
# hujan : hujan
# badai : badai
# punyaku : punya
# sinyalnya : sinyal
# ampek : ampek
# muntah : muntah
# bca : bca
# dana : dana
# open : open
# convert : convert
# tukar : tukar
# tuker : tuker
# axis : axis
# three : three
# tri : tri
# tsel : tsel
# isat : isat
# atm : atm
# bank : bank
# ewallet : ewallet
# non : non
# premium : premium
# prem : prem
# shopeepay : shopeepay
# ovo : ovo
# gopay : gopay
# linkaja : linkaja
# jual : jual
# preset : preset
# lightroom : lightroom
# ios : ios
# andro : andro
# agen : agen
# duluan : duluan
# cowok : cowok
# goerge : goerge
# berdampak : dampak
# lambat : lambat
# bni : bni
# selamat : selamat
# memotong : potong
# berbayar : bayar
# terdaftar : daftar
# spay : spay
# pokoknya : pokok
# reguler : reguler
# apapun : apa
# habis : habis
# dipake : dipake
# youtube : youtube
# derry : derry
# kirim : kirim
# follow : follow
# channel : channel
# jaringamu : jaringamu
# hancur : hancur
# paketanmu : paket
# mencekik : cekik
# sesuaikanlah : sesuai
# kek : kek
# anjinggg : anjinggg
# chat : chat
# baca : baca
# sengaja : sengaja
# balas : balas
# melayani : layan
# pelangankah : pelang
# profilnya : profil
# icon : icon
# gimana : gimana
# biarkan : biar
# konfirmasi : konfirmasi
# antrian : antri
# sehat : sehat
# kevin : kevin
# hallo : hallo
# acm : acm
# melebihi : lebih
# batas : batas
# oke : oke
# telpnya : telpnya
# pilihan : pilih
# utama : utama
# berengsek : berengsek
# hape : hape
# eror : eror
# lionsgate : lionsgate
# ramaikan : ramai
# pasar : pasar
# svod : svod
# jalin : jalin
# kemitraan : mitra
# sayaa : sayaa
# ambil : ambil
# utamaa : utamaa
# gigamax : gigamax
# panggilan : panggil
# restart : restart
# pindahkan : pindah
# perbandingan : banding
# januari : januari
# juta : juta
# maret : maret
# maling : maling
# kemana : mana
# patricia : patricia
# ditunggu : tunggu
# senang : senang
# hati : hati
# merespon : merespon
# memanggil : panggil
# peringatan : ingat
# solusi : solusi
# makan : makan
# sampe : sampe
# ready : ready
# puluh : puluh
# pricelist : pricelist
# kekuatan : kuat
# beda : beda
# kesamaannya : sama
# pelanggan : langgan
# dikirimi : kirim
# iklan : iklan
# notif : notif
# aktif : aktif
# cuitan : cuit
# terhenti : henti
# ludes : ludes
# gitu : gitu
# langganan : langgan
# disney : disney
# active : active
# kah : kah
# pdhl : pdhl
# nggak : nggak
# melewati : lewat
# tenggang : tenggang
# isi : isi
# diaktifin : diaktifin
# sarankan : saran
# membeli : beli
# perdana : perdana
# outlet : outlet
# grapari : grapari
# terdekat : dekat
# diaktifkan : aktif
# dkk : dkk
# zonk : zonk
# whatapp : whatapp
# dinomor : nomor
# semoga : moga
# membantu : bantu
# ari : ari
# sebel : sebel
# gabisa : gabisa
# ngedm : ngedm
# kim : kim
# lokal : lokal
# yuk : yuk
# dicek : cek
# rek : rek
# fer : fer
# kirimi : kirim
# msh : msh
# dikasih : kasih
# kerjaan : kerja
# ama : ama
# rezim : rezim
# bandar : bandar
# list : list
# nyaaa : nyaaa
# orbit : orbit
# rb : rb
# nadya : nadya
# kembalikan : kembali
# payah : payah
# gini : gin
# dwi : dwi
# diperpanjang : panjang
# berhenti : henti
# mission : mission
# connect : connect
# the : the
# world : world
# net : net
# diinfokan : info
# nambah : nambah
# billing : billing
# rafindra : rafindra
# bukti : bukti
# tertulis : tulis
# pamungkasnya : pamungkas
# pengen : ken
# pembelaan : bela
# sebrapa : sebrapa
# integritas : integritas
# dipertaruhkan : taruh
# sekian : sekian
# let : let
# see : see
# then : then
# bio : bio
# byu : byu
# lak : lak
# jakarta : jakarta
# flores : flores
# pya : pya
# paketannya : paket
# ampun : ampun
# signalnya : signalnya
# skali : skali
# full : full
# top : top
# link : link
# daftar : daftar
# dot : dot
# trouble : trouble
# terjangkau : jangkau
# terkait : kait
# dibrebes : dibrebes
# ezra : ezra
# wanian : wani
# terdepan : depan
# dikurangin : rangin
# mengeluhkan : keluh
# buruk : buruk
# kalangan : kalang
# kabar : kabar
# harganya : harga
# berulang : ulang
# debora : debora
# tetao : tetao
# mega : mega
# slot : slot
# cashback : cashback
# rollingan : rollingan
# reload : reload
# harian : hari
# new : new
# member : member
# live : live
# casino : casino
# ribu : ribu
# sisa : sisa
# asulah : asu
# org : org
# aelahh : aelahh
# tlg : tlg
# matiin : matiin
# nomernya : nomernya
# andripati : andripati
# menarik : tarik
# tirta : tirta
# bersifat : sifat
# berbatas : batas
# kalah : kalah
# tole : tole
# airplane : airplane
# wkt : wkt
# signal : signal
# buka : buka
# disarankan : saran
# proses : proses
# maksimal : maksimal
# diharapkan : harap
# selesai : selesai
# secepatnya : cepat
# hubungi : hubung
# care : care
# prosesnya : proses
# jam : jam
# agus : agus
# calvin : calvin
# kasian : kasi
# alfamart : alfamart
# bawa : bawa
# fak : fak
# kgk : kgk
# doang : doang
# kondisikan : kondisi
# wfh : wfh
# ganggu : ganggu
# bangsat : bangsat
# bangke : bangke
# lemah : lemah
# kepakai : pakai
# panggil : panggil
# kaka : kaka
# bong : bong
# kepanjangan : panjang
# abang : abang
# kecebong : kecebong
# keluarga : keluarga
# logout : logout
# clear : clear
# cache : cache
# update : update
# versi : versi
# terbaru : baru
# perhitungan : hitung
# fler : fler
# dapet : dapet
# ngomel : ngomel
# orang : orang
# kaya : kaya
# ribuan : ribu
# kayaknya : kayak
# tinggalku : tinggal
# kantor : kantor
# penuh : penuh
# ttp : ttp
# saran : saran
# daerahmu : daerah
# mending : mending
# skip : skip
# loe : loe
# murahan : murah
# kencang : kencang
# bacot : bacot
# gede : gede
# ketengan : keteng
# tha : tha
# malaya : malaya
# arno : arno
# profile : profile
# berdasarkan : dasar
# berlangganan : langgan
# periode : periode
# ditentukan : tentu
# kagak : kagak
# euy : euy
# ngisi : ngisi
# masuj : masuj
# woi : woi
# panik : panik
# hihihi : hihihi
# thanks : thanks
# berat : berat
# cont : cont
# sobat : sobat
# bri : bri
# bpk : bpk
# mendaftarkan : daftar
# ponsel : ponsel
# gsm : gsm
# informasi : informasi
# akun : akun
# sosmed : sosmed
# centang : centang
# birunya : biru
# verified : verified
# arim : arim
# ngira : ngira
# penipuan : tipu
# sign : sign
# beneran : beneran
# feeding : feeding
# into : into
# addiction : addiction
# loop : loop
# aktipkan : aktipkan
# hotstar : hotstar
# bulanan : bulan
# gratis : gratis
# apta : apta
# barusan : barusan
# operator : operator
# alamat : alamat
# dpt : dpt
# jay : jay
# ojo : ojo
# mitra : mitra
# samarinda : samarinda
# raih : raih
# unit : unit
# mobil : mobil
# toyota : toyota
# avanza : avanza
# apresiasi : apresiasi
# tribun : tribun
# kaltim : kaltim
# heloo : heloo
# tumben : tumben
# ajoes : ajoes
# angga : angga
# transfer : transfer
# aktifin : aktifin
# nsp : nsp
# cita : cita
# citata : citata
# call : call
# center : center
# biasnya : bias
# menawarkan : tawar
# folbek : folbek
# respon : respon
# follback : follback
# plis : plis
# saldo : saldo
# jt : jt
# pascabayar : pascabayar
# bertambah : tambah
# sistemnya : sistem
# pls : pls
# retweet : retweet
# tan : tan
# first : first
# media : media
# loading : loading
# kecepatan : cepat
# tetep : tetep
# mah : mah
# kebiasaan : biasa
# kadang : kadang
# nomer : nomer
# males : males
# dialami : alami
# gangguan : ganggu
# karna : karna
# dinikmati : nikmat
# ngak : ngak
# tulang : tulang
# lepas : lepas
# kangen : kangen
# ngobrol : ngobrol
# sahabatku : sahabat
# putus : putus
# muzhir : muzhir
# ahmad : ahmad
# mengirimkan : kirim
# kirimkan : kirim
# beribu : ibu
# tlp : tlp
# tindak : tindak
# pembenahan : benah
# turun : turun
# lapangan : lapang
# ngagame : ngagame
# pengin : pengin
# cabut : cabut
# laina : laina
# korea : korea
# komplit : komplit
# infonya : info
# diunfollow : diunfollow
# gapapa : gapapa
# homecare : homecare
# evi : evi
# syam : syam
# dilokasi : lokasi
# informasikan : informasi
# btw : btw
# salfok : salfok
# koin : koin
# ngebuzzer : ngebuzzer
# blm : blm
# kelas : kelas
# zoom : zoom
# webinar : webinar
# online : online
# lancar : lancar
# hambatan : hambat
# sedikitpun : sedikit
# materi : materi
# kuliah : kuliah
# dosen : dosen
# ikutan : ikut
# rbu : rbu
# centre : centre
# perbaikan : baik
# sales : sales
# abaikan : abai
# bicara : bicara
# manis : manis
# kenyataan : nyata
# pahit : pahit
# here : here
# serius : serius
# transportasi : transportasi
# daratnya : darat
# didesa : desa
# pedalaman : dalam
# susah : susah
# tempatku : tempat
# udh : udh
# trmasuk : trmasuk
# kereta : kereta
# api : api
# disebagian : bagi
# provinsi : provinsi
# tpi : tpi
# koneksi : koneksi
# bayarnya : bayar
# bengkak : bengkak
# sampah : sampah
# pasang : pasang
# wifi : wifi
# kecewa : kecewa
# parah : parah
# telfon : telfon
# mba : mba
# customer : customer
# servicenya : servicenya
# mas : mas
# bagas : bagas
# temen : temen
# tinggal : tinggal
# gunung : gunung
# yaa : yaa
# nongol : nongol
# gerai : gerai
# disuruh : suruh
# ehh : ehh
# ujung : ujung
# pergantian : ganti
# ngirim : ngirim
# pesan : pesan
# ngapa : ngapa
# nyambung : nyambung
# ngapain : ngapain
# play : play
# partners : partners
# with : with
# telco : telco
# for : for
# indonesian : indonesian
# roll : roll
# out : out
# pret : pret
# sangkin : sangkin
# takutnya : takut
# ditelfon : ditelfon
# gadikenal : gadikenal
# sampek : sampek
# tolak : tolak
# unggul : unggul
# providers : providers
# pertanyaannya : tanya
# ping : ping
# penjelasan : jelas
# digital : digital
# sungkan : sungkan
# aktivitas : aktivitas
# dikawasan : kawasan
# pakisaji : pakisaji
# malang : malang
# laut : laut
# nurul : nurul
# berinteraksi : interaksi
# menikmati : nikmat
# ribet : ribet
# indihome : indihome
# josss : josss
# minul : minul
# terputus : putus
# pesawat : pesawat
# memiliki : milik
# ealah : ealah
# anjing : anjing
# tumbenan : tumben
# bae : bae
# lucas : lucas
# laah : laah
# masak : masak
# cbn : cbn
# ndrrreeww : ndrrreeww
# asli : asli
# sateh : sateh
# teu : teu
# naon : naon
# angger : angger
# weh : weh
# untung : untung
# urg : urg
# dipahami : paham
# std : std
# mbps : mbps
# nonton : nonton
# liga : liga
# chanel : chanel
# kebangetan : banget
# banking : banking
# pulsanya : pulsa
# ngga : ngga
# maunya : mau
# teknisi : teknisi
# itupun : itu
# lemotnya : lot
# gratisnya : gratis
# handri : handri
# kombinasi : kombinasi
# laptop : laptop
# macbook : macbook
# berhasil : hasil
# besok : besok
# eform : eform
# disumbit : disumbit
# pajak : pajak
# bangun : bangun
# muter : muter
# paketnya : paket
# republic : republic
# jaman : jaman
# inovet : inovet
# internetan : internetan
# kenceng : kenceng
# kai : kai
# nelpon : nelpon
# maintenance : maintenance
# megenai : megenai
# logou : logou
# pembelian : beli
# bener : bener
# ngemaps : ngemaps
# emosi : emosi
# kaga : kaga
# kemarin : kemarin
# pilihannya : pilih
# ilangan : ilangan
# silang : silang
# khamal : khamal
# hei : hei
# maksudnya : maksud
# perasaan : asa
# desa : desa
# pantura : pantura
# timur : timur
# jateng : jateng
# nembus : nembus
# megap : megap
# spt : spt
# pencet : pencet
# gmn : gmn
# lgsg : lgsg
# menonaktifkannya : nonaktif
# prnh : prnh
# kelanjutannya : lanjut
# penasaran : penasaran
# sochan : sochan
# your : your
# good : good
# but : but
# weak : weak
# dont : dont
# wanna : wanna
# hear : hear
# sorry : sorry
# apologies : apologies
# blablabla : blablabla
# bla : bla
# its : its
# easy : easy
# say : say
# wheres : wheres
# promise : promise
# did : did
# you : you
# really : really
# work : work
# konfirmasinya : konfirmasi
# trims : trims
# farah : farah
# hey : hey
# excuse : excuse
# been : been
# week : week
# since : since
# report : report
# and : and
# yall : yall
# tell : tell
# wait : wait
# hours : hours
# seems : seems
# like : like
# didnt : didnt
# fix : fix
# something : something
# ive : ive
# already : already
# instructions : instructions
# know : know
# change : change
# anything : anything
# still : still
# zalfa : zalfa
# menggunkana : menggunkana
# hahha : hahha
# syaapp : syaapp
# minnn : minnn
# bantuan : bantu
# waktunyaa : waktunyaa
# sukses : sukses
# selalluuu : selalluuu
# pindah : pindah
# server : server
# gamau : gamau
# ngambek : ngambek
# capekk : capekk
# sebagus : bagus
# segini : gin
# gua : gua
# rank : rank
# tembus : tembus
# ms : ms
# memperhitungkan : hitung
# kepuasan : puas
# hak : hak
# uda : uda
# dikirimin : dikirimin
# kakl : kakl
# yorifano : yorifano
# fadh : fadh
# secepatnyqa : secepatnyqa
# kampret : kampret
# berbuat : buat
# wkwkwk : wkwkwk
# matikan : mati
# bro : bro
# sis : sis
# paketin : paketin
# digimanakan : digimanakan
# ngejengkelin : ngejengkelin
# beud : beud
# pengecekan : kece
# lokalnya : lokal
# tidam : tidam
# terpakai : pakai
# putra : putra
# download : download
# holstar : holstar
# menonton : tonton
# film : film
# mengunjungi : unjung
# jogja : jogja
# city : city
# mall : mall
# jcm : jcm
# wib : wib
# rahmat : rahmat
# bakar : bakar
# ngaruh : ngaruh
# balasan : balas
# ajg : ajg
# ambarukmo : ambarukmo
# plaza : plaza
# bodo : bodo
# mlz : mlz
# tower : tower
# diriin : diriin
# skrg : skrg
# jualannya : jual
# kapasitasnya : kapasitas
# pengguna : guna
# perhatikan : perhati
# ditindak : tindak
# lanjuti : lanjut
# rupiah : rupiah
# conference : conference
# penyelamat : selamat
# lupa : lupa
# menerapkan : terap
# protokol : protokol
# kesehatan : sehat
# nanyain : nanyain
# tetek : tetek
# bengek : bengek
# wml : wml
# benda : benda
# tangerang : tangerang
# okee : okee
# baikk : baikk
# minn : minn
# costumer : costumer
# perku : per
# ujan : ujan
# mkin : mkin
# nguji : nguji
# kesabaran : sabar
# enak : enak
# nntn : nntn
# stenap : stenap
# yutub : yutub
# loding : loding
# video : video
# menit : menit
# lodingnya : lodingnya
# nympe : nympe
# ttep : ttep
# allahumma : allahumma
# shoyyiban : shoyyiban
# naafi : naafi
# lag : lag
# browser : browser
# kuat : kuat
# kontol : kontol
# andi : andi
# kerahasiaan : rahasia
# nama : nama
# lengkap : lengkap
# lahir : lahir
# ora : ora
# popo : popo
# nder : nder
# kui : kui
# tandane : tandane
# dee : dee
# seng : seng
# durung : durung
# iso : iso
# move : move
# dek : dek
# koe : koe
# mbien : mbien
# drg : drg
# biso : biso
# mantan : mantan
# mantanku : mantan
# kei : kei
# wirya : wirya
# meluncur : luncur
# ancur : ancur
# menyebalkan : sebal
# tersedot : sedot
# persis : persis
# sebulan : bulan
# bntar : bntar
# cpt : cpt
# prubahannya : prubahannya
# detik : detik
# hartono : hartono
# yogyakarta : yogyakarta
# downkah : downkah
# main : main
# afk : afk
# belangganan : banggan
# iseng : iseng
# nelp : nelp
# ala : ala
# penjahat : jahat
# drakor : drakor
# voice : voice
# changer : changer
# kalik : kalik
# merusak : rusak
# rumah : rumah
# tangga : tangga
# unfaedah : unfaedah
# down : down
# perubahan : ubah
# hitungan : hitung
# batang : batang
# membayar : bayar
# berjalan : jalan
# suka : suka
# gajelas : gajelas
# ngalamin : ngalamin
# manik : manik
# ketentuan : tentu
# membawa : bawa
# sim : sim
# card : card
# ktp : ktp
# dimiliki : milik
# nattahu : nattahu
# lina : lina
# setia : setia
# jaga : jaga
# masker : masker
# anjr : anjr
# budhi : budhi
# sakit : sakit
# bls : bls
# ngaco : ngaco
# sora : sora
# kotau : kotau
# make : make
# abiss : abiss
# siak : siak
# hulu : hulu
# kampar : kampar
# riau : riau
# konten : konten
# gandeng : gandeng
# liat : liat
# info : info
# trs : trs
# muncul : muncul
# klik : klik
# takut : takut
# iyaa : iyaa
# operasinya : operasi
# maacii : maacii
# youbote : youbote
# hbs : hbs
# dicoba : coba
# alias : alias
# nol : nol
# kernel : kernel
# system : system
# sprti : sprti
# apn : apn
# custum : custum
# room : room
# ajj : ajj
# ampai : ampai
# oprek : oprek
# buildprop : buildprop
# tweak : tweak
# noll : noll
# klmpk : klmpk
# haikal : haikal
# hasan : hasan
# kerja : kerja
# sibuk : sibuk
# menghambat : hambat
# hoshi : hoshi
# ooredo : ooredo
# cepet : cepet
# wayahe : wayahe
# mantap : mantap
# sia : sia
# nnton : nnton
# andri : andri
# roy : roy
# sultanahmad : sultanahmad
# mang : mang
# cageur : cageur
# setuju : tuju
# sip : sip
# lemotttttt : lemotttttt
# lae : lae
# speed : speed
# emergency : emergency
# sumber : sumber
# dosa : dosa
# daddy : daddy
# sugar : sugar
# tukang : tukang
# galon : galon
# duit : duit
# arum : arum
# tidur : tidur
# nyenyak : nyenyak
# ngerti : ngerti
# ntah : ntah
# berserta : serta
# perangkatnya : perangkat
# indohome : indohome
# busuk : busuk
# allah : allah
# telpon : telpon
# ditutup : tutup
# hostar : hostar
# rei : rei
# vinka : vinka
# akka : akka
# partiga : partiga
# jago : jago
# bah : bah
# sbg : sbg
# sungguh : sungguh
# yaaaa : yaaaa
# rudet : rudet
# hayoh : hayoh
# ieu : ieu
# heran : heran
# meuli : meuli
# meunang : meunang
# menta : menta
# stop : stop
# distop : stop
# dobel : dobel
# rebu : rebu
# nggakjadi : nggakjadi
# berenti : renti
# smp : smp
# kronologi : kronologi
# dihubungi : hubung
# tim : tim
# teknis : teknis
# blokir : blokir
# pelaporan : lapor
# anicka : anicka
# prihatin : prihatin
# alami : alami
# korban : korban
# berhadiah : hadiah
# melaporkan : lapor
# polisi : polisi
# cyber : cyber
# crime : crime
# morgan : morgan
# dasar : dasar
# silaturahmi : silaturahmi
# pelayanan : layan
# garr : garr
# dilacak : lacak
# ngaku : ngaku
# kenal : kenal
# indikasi : indikasi
# lelet : lelet
# masya : masya
# hoax : hoax
# hadiah : hadiah
# ratusan : ratus
# nonaktifkan : nonaktif
# telepon : telepon
# hitung : hitung
# anjinglah : anjing
# koq : koq
# mati : mati
# pacar : pacar
# aktifkan : aktif
# usa : usa
# stelah : stelah
# mengalami : alami
# super : super
# huft : huft
# jaringanya : jaringanya
# asw : asw
# notifikasi : notifikasi
# smartfren : smartfren
# need : need
# aahhsimpati : aahhsimpati
# product : product
# ambyar : ambyar
# punyamu : punya
# jilatan : jilat
# menjilat : jilat
# jiwa : jiwa
# raga : raga
# hihihiii : hihihiii
# myrepublic : myrepublic
# disalah : salah
# bertanggung : tanggung
# sialakan : sialakan
# spesial : spesial
# dptkan : dptkan
# hr : hr
# telp : telp
# apr : apr
# skb : skb
# twt : twt
# nmr : nmr
# bungkus : bungkus
# nyi : nyi
# madura : madura
# aduuuhhhh : aduuuhhhh
# selisihnya : selisih
# paraahhh : paraahhh
# sabar : sabar
# telkomselku : telkomselku
# kebanjiran : banjir
# spam : spam
# capek : capek
# komplin : komplin
# hhmmm : hhmmm
# angus : angus
# tlng : tlng
# gedeg : gedeg
# sultan : sultan
# lamban : lamban
# dibikin : bikin
# ghia : ghia
# medan : medan
# irwan : irwan
# shien : shien
# disistem : sistem
# pro : pro
# store : store
# commerce : commerce
# rasakan : rasa
# serba : serba
# cihuy : cihuy
# tonight : tonight
# lovers : lovers
# pesen : sen
# from : from
# home : home
# school : school
# belanja : belanja
# game : game
# streaming : streaming
# xiaxia : xiaxia
# makasi : makas
# kirino : kirino
# direstuin : direstuin
# nyerah : nyerah
# mbul : mbul
# produktif : produktif
# efisien : efisien
# atur : atur
# keceoatannya : keceoatannya
# tugas : tugas
# sekolah : sekolah
# haloo : haloo
# wal : wal
# kada : kada
# barabai : barabai
# fanmeet : fanmeet
# dmna : dmna
# gfriend : gfriend
# point : point
# elhasan : elhasan
# zubeer : zubeer
# jing : jing
# steven : steven
# layy : layy
# zahra : zahra
# nini : nini
# satunya : satu
# moodku : moodku
# status : status
# nomornya : nomor
# tiasa : tiasa
# tibra : tibra
# ayeunmh : ayeunmh
# nuhun : nuhun
# persib : persib
# lope : lope
# salawasna : salawasna
# stres : stres
# gubris : gubris
# cari : cari
# pelampiasan : lampias
# melintir : melintir
# ngebut : ngebut
# best : best
# punten : punten
# dipusat : pusat
# realistis : realistis
# bermanfaat : manfaat
# aini : ain
# ketidaksesuaian : ketidaksesuaian
# whiteee : whiteee
# lampu : lampu
# batere : batere
# rectifier : rectifier
# refund : refund
# asalnya : asal
# direfund : direfund
# engga : engga
# hihihih : hihihih
# surat : surat
# profil : profil
# perbulanya : perbulanya
# mbk : mbk
# soetta : soetta
# subscribe : subscribe
# capture : capture
# keterangan : terang
# haean : haean
# toktok : toktok
# wifinya : wifinya
# adek : adek
# ulangan : ulang
# keganggu : ganggu
# kehambat : hambat
# skg : skg
# chip : chip
# mendeteksi : deteksi
# gadget : gadget
# tajir : tajir
# kere : kere
# bernad : bernad
# fery : fery
# tjahjono : tjahjono
# moyoy : moyoy
# kabeh : kabeh
# bobotoh : bobotoh
# peuting : peuting
# ayeuna : ayeuna
# lawan : lawan
# aceh : aceh
# laga : laga
# azmi : azmi
# afif : afif
# ayo : ayo
# wkwkwkw : wkwkwkw
# gdm : gdm
# ketikan : keti
# asudahlah : asudahlah
# shito : shito
# silahkan : silah
# penawarannya : tawar
# dimana : mana
# yth : yth
# guys : guys
# kau : kau
# fitnah : fitnah
# pemakai : pakai
# ewo : ewo
# mmf : mmf
# mamah : mamah
# twttr : twttr
# satelinya : satelinya
# taruh : taruh
# kmr : kmr
# pengecekkan : ecek
# situ : situ
# lapor : lapor
# pulici : pulici
# pembunuhan : bunuh
# telat : telat
# setahun : tahun
# tonton : tonton
# tayangan : tayang
# unduh : unduh
# aplikasinya : aplikasi
# maksud : maksud
# buzzerp : buzzerp
# fakir : fakir
# malu : malu
# in : in
# biasaan : biasa
# cuci : cuci
# tangan : tangan
# disalahin : disalahin
# naiseeee : naiseeee
# bbrp : bbrp
# seceara : seceara
# berkala : kala
# menghindari : hindar
# terkena : kena
# double : double
# charging : charging
# menginfokan : info
# bokek : bokek
# pemasukan : pasu
# disosmed : disosmed
# mutu : mutu
# selemot : lot
# pikiran : pikir
# mengaktifkan : aktif
# pokona : pokona
# mkan : mkan
# ngope : ngope
# menang : menang
# gas : gas
# pooll : pooll
# gebuk : gebuk
# keanya : keanya
# astagaaa : astagaaa
# touch : touch
# goal : goal
# pilihanku : pilih
# jatuh : jatuh
# posisi : posisi
# sumba : sumba
# ntt : ntt
# aktifasi : aktifasi
# jakarya : jakarya
# hasilnya : hasil
# lpg : lpg
# hahahaha : hahahaha
# wess : wess
# sambat : sambat
# tweeter : tweeter
# gayanya : gaya
# kereeeeee : kereeeeee
# kereeee : kereeee
# terkaitkeluhan : terkaitkeluhan
# both : both
# place : place
# that : that
# sucks : sucks
# lumayan : lumayan
# dendanya : denda
# didenda : denda
# dibanding : banding
# firstmedia : firstmedia
# lost : lost
# kepikiran : pikir
# tonny : tonny
# sekelas : kelas
# ferdinand : ferdinand
# masyarakat : masyarakat
# tanggepin : tanggepin
# bkn : bkn
# aasu : aasu
# lahh : lahh
# ketawain : ketawain
# neng : neng
# melacak : lacak
# berduit : duit
# hahaha : hahaha
# template : template
# sib : sib
# ridho : ridho
# fahmi : fahmi
# synk : synk
# megalami : megalami
# peranakan : ana
# yeah : yeah
# sii : sii
# judi : judi
# fair : fair
# murni : murni
# player : player
# solusinya : solusi
# hnya : hnya
# alternatif : alternatif
# menggandeng : gandeng
# platform : platform
# hadir : hadir
# pesaing : saing
# netflix : netflix
# langganannya : langgan
# butuh : butuh
# ruqyah : ruqyah
# pembayaran : bayar
# ceritanya : cerita
# lte : lte
# ciut : ciut
# balesane : balesane
# ming : ming
# kat : kat
# biyen : biyen
# jatingan : jatingan
# useetv : useetv
# error : error
# jawabane : jawabane
# trusndi : trusndi
# hidupkan : hidup
# rfresh : rfresh
# lho : lho
# ngikutin : ngikutin
# delay : delay
# suara : suara
# nicholas : nicholas
# halahhh : halahhh
# kafirrr : kafirrr
# kafir : kafir
# lagu : lagu
# sok : sok
# politikus : politikus
# wahid : wahid
# ngoceh : ngoceh
# tuiter : tuiter
# eceran : ecer
# queen : queen
# yudi : yudi
# tetangga : tetangga
# darah : darah
# rendah : rendah
# direkomendasikan : rekomendasi
# bayangkara : bayangkara
# kec : kec
# ciampea : ciampea
# bogor : bogor
# ermici : ermici
# berkomunikasi : komunikasi
# social : social
# hutan : hutan
# pulau : pulau
# terpencil : pencil
# dirumah : rumah
# nyebelin : nyebelin
# beres : beres
# knpa : knpa
# omg : omg
# pdhal : pdhal
# kya : kya
# yaakk : yaakk
# done : done
# fast : fast
# respond : respond
# yaaa : yaaa
# makasii : makasii
# dsn : dsn
# ngab : ngab
# vpn : vpn
# wijaya : wijaya
# senin : senin
# kebon : kebon
# jeruk : jeruk
# mnt : mnt
# rp : rp
# hub : hub
# gang : gang
# wya : wya
# ndut : ndut
# terkadang : terkadang
# roaming : roaming
# hilih : hilih
# menge : menge
# tweet : tweet
# siska : siska
# butuhkan : butuh
# menguhubungi : menguhubungi
# dear : dear
# diisi : isi
# libur : libur
# wkwkw : wkwkw
# menghubngi : menghubngi
# menungug : menungug
# nelepon : nelepon
# shinee : shinee
# ars : ars
# kangenin : kangenin
# pulang : pulang
# aseliiii : aseliiii
# lambretta : lambretta
# sangaaat : sangaaat
# palagi : palagi
# ampe : ampe
# timbul : timbul
# tenggelam : tenggelam
# acep : acep
# dibalas : balas
# bagusss : bagusss
# papua : papua
# aslina : aslina
# afrian : afrian
# sahabat : sahabat
# van : van
# beek : beek
# whaqia : whaqia
# terkendala : kendala
# callcenter : callcenter
# dungss : dungss
# apdet : apdet
# klasemen : klasemen
# grup : grup
# robot : robot
# ngeluh : ngeluh
# ricky : ricky
# gilang : gilang
# better : better
# life : life
# kelapa : kelapa
# gading : gading
# kualitasnya : kualitas
# kang : kang
# idola : idola
# aing : aing
# hotsatar : hotsatar
# ferdinan : ferdinan
# sinaga : sinaga
# pie : pie
# luncurkan : luncur
# mudahkan : mudah
# elahhh : elahhh
# mamprang : mamprang
# kelupaan : lupa
# hafal : hafal
# bapuk : bapuk
# siaapp : siaapp
# nunggunya : nunggunya
# tah : tah
# kitu : kitu
# mamang : mamang
# wander : wander
# luiz : luiz
# ken : ken
# mimiti : mimiti
# mar : mar
# joe : joe
# feedback : feedback
# kemajuan : maju
# kedepannya : depan
# harapan : harap
# terrealisasi : terrealisasi
# siang : siang
# keterangannya : terang
# tdi : tdi
# sblm : sblm
# mengetikkan : etik
# tlpon : tlpon
# ketik : ketik
# ayah : ayah
# huhu : huhu
# takdir : takdir
# berbeda : beda
# nin : nin
# special : special
# treatment : treatment
# tidakkk : tidakkk
# indo : indo
# kakk : kakk
# bhabinkamtibmas : bhabinkamtibmas
# gedangan : gedang
# bripka : bripka
# rahmidi : rahmidi
# melaksanakan : laksana
# kegiatan : giat
# binluh : binluh
# anggota : anggota
# satpam : satpam
# grogol : grogol
# meningkatkan : tingkat
# kewaspadaan : waspada
# keamanan : aman
# dilanjutkan : lanjut
# olahraga : olahraga
# latihan : latih
# pbb : pbb
# ferdi : ferdi
# bantuannya : bantu
# waahh : waahh
# lebar : lebar
# jelasin : jelasin
# screen : screen
# shoot : shoot
# haqiya : haqiya
# biaya : biaya
# laras : laras
# salam : salam
# usul : usul
# poin : poin
# aneh : aneh
# undian : undi
# cape : cape
# sumbangin : sumbangin
# opsi : opsi
# sumbangan : sumbang
# terserah : serah
# pkl : pkl
# apps : apps
# namanya : nama
# untukmu : untuk
# tselme : tselme
# diandra : diandra
# penjelasannya : jelas
# gusti : gusti
# agung : agung
# nominalnya : nominal
# menangkan : menang
# grandprize : grandprize
# motor : motor
# transaksi : transaksi
# banyaknya : banyak
# zyad : zyad
# yantok : yantok
# registrasi : registrasi
# masrur : masrur
# dibenerin : dibenerin
# semogaa : semogaa
# fusion : fusion
# aldwin : aldwin
# aris : aris
# nda : nda
# fiturnya : fiturnya
# ketidaknyamanan : ketidaknyamanan
# astaghfirullah : astaghfirullah
# katain : katain
# bgtlu : bgtlu
# switch : switch
# hmmm : hmmm
# telfonan : telfonan
# berbusa : busa
# ngeles : ngeles
# terganggu : ganggu
# pop : pop
# siti : siti
# mugen : mugen
# kuenya : kue
# gemoy : gemoy
# berwarna : warna
# bin : bin
# traktir : traktir
# jarang : jarang
# mahfuedz : mahfuedz
# lalukan : lalu
# rongsok : rongsok
# koplok : koplok
# izin : izin
# sosial : sosial
# tercantum : cantum
# google : google
# check : check
# edge : edge
# ketidaknyamanannya : ketidaknyamanannya
# kemenangan : menang
# dipersembahkan : sembah
# gosh : gosh
# current : current
# fave : fave
# seharian : hari
# tulisannya : tulis
# berasa : asa
# netral : netral
# hen : hen
# bayu : bayu
# fikri : fikri
# menjanjikam : menjanjikam
# meni : meni
# kasep : kasep
# menak : menak
# jinggo : jinggo
# thx : thx
# setting : setting
# area : area
# zam : zam
# zum : zum
# wasu : wasu
# diketawain : diketawain
# xixixi : xixixi
# jaringann : jaringann
# kyk : kyk
# saingan : saing
# anisa : anisa
# berbasis : bas
# daring : daring
# conccting : conccting
# yaaaaaa : yaaaaaa
# ay : ay
# yahya : yahya
# faza : faza
# meluncurkan : luncur
# chatbot : chatbot
# tema : tema
# abi : abi
# kabogoh : kabogoh
# saha : saha
# occur : occur
# inform : inform
# cellphone : cellphone
# number : number
# complete : complete
# details : details
# location : location
# time : time
# incident : incident
# other : other
# numbers : numbers
# problems : problems
# keep : keep
# privacy : privacy
# naomi : naomi
# apologize : apologize
# inconvenience : inconvenience
# regarding : regarding
# signals : signals
# have : have
# try : try
# network : network
# automatic : automatic
# again : again
# fisik : fisik
# pemain : main
# tingkat : tingkat
# goodgamesib : goodgamesib
# tingkatkan : tingkat
# kalitengah : kalitengah
# purwanegara : purwanegara
# banjarnegara : banjarnegara
# jawa : jawa
# sng : sng
# keperluan : perlu
# burik : burik
# bat : bat
# hobi : hobi
# mengarungi : arung
# dalamnya : dalam
# samudera : samudera
# eta : eta
# erwin : erwin
# loankeun : loankeun
# bandung : bandung
# yunaitid : yunaitid
# hoream : hoream
# pisan : pis
# tebaik : tebaik
# mesti : mesti
# suruh : suruh
# melarat : melarat
# tunjukin : tunjukin
# omongan : omong
# ngotot : ngotot
# tiket : tiket
# pmlyh : pmlyh
# buruan : buru
# terjangkit : jangkit
# lola : lola
# subang : subang
# spill : spill
# dapetin : dapetin
# kuy : kuy
# kesempatan : sempat
# gampang : gampang
# miskin : miskin
# modar : modar
# bangsad : bangsad
# syahdan : syahdan
# ngeunaheun : ngeunaheun
# alus : alus
# jaba : jaba
# siga : siga
# beckham : beckham
# geus : geus
# mangprang : mangprang
# ngan : ngan
# legeg : legeg
# rada : rada
# tingkatkeun : tingkatkeun
# slow : slow
# mun : mun
# gelut : gelut
# mantuan : mantu
# giliran : gilir
# epul : epul
# sareng : sareng
# jardel : jardel
# show : show
# persiraja : persiraja
# cloudx : cloudx
# dansa : dansa
# host : host
# mengundang : undang
# peserta : serta
# berdansa : dansa
# bareng : bareng
# selengkapnya : lengkap
# cobain : cobain
# box : box
# seru : seru
# bachata : bachata
# tango : tango
# kardio : kardio
# lemak : lemak
# jenuh : jenuh
# tubuh : tubuh
# populer : populer
# pria : pria
# wanita : wanita
# gengs : gengs
# layak : layak
# lanjutkeun : lanjutkeun
# ahh : ahh
# kieu : kieu
# henhen : henhen
# sina : sina
# ball : ball
# boy : boy
# tos : tos
# enakeun : enakeun
# maen : maen
# mengganti : ganti
# pengiriman : kirim
# otp : otp
# ubah : ubah
# database : database
# tersimpan : simpan
# love : love
# rarantayan : rarantayan
# kepuasaan : puasa
# semongko : semongko
# disimpan : simpan
# djp : djp
# ruang : ruang
# penyimpanan : simpan
# taxmin : taxmin
# menyediakan : sedia
# fitur : fitur
# dikirim : kirim
# babak : babak
# duet : duet
# viscara : viscara
# noor : noor
# febri : febri
# kereen : kereen
# ngawalan : ngawalan
# sakiyeu : sakiyeu
# sinyalmu : sinyal
# nohara : nohara
# bngst : bngst
# dragon : dragon
# suplai : suplai
# bola : bola
# naise : naise
# kurangi : kurang
# sangu : sangu
# koneng : koneng
# pra : pra
# musim : musim
# keneh : keneh
# maungggg : maungggg
# janji : janji
# klasemena : klasemena
# baraha : baraha
# keun : keun
# bow : bow
# jng : jng
# hariwang : hariwang
# sugan : sugan
# next : next
# macth : macth
# perusahaan : usaha
# swasta : swasta
# peduli : peduli
# too : too
# semenjak : semenjak
# kampang : kampang
# yey : yey
# merah : merah
# pojok : pojok
# logo : logo
# kaget : kaget
# ambassador : ambassador
# lay : lay
# mantapp : mantapp
# iloveyou : iloveyou
# anjinc : anjinc
# hatur : hatur
# pardi : pardi
# umsfess : umsfess
# ilham : ilham
# was : was
# superb : superb
# muting : muting
# this : this
# conversation : conversation
# aihhhh : aihhhh
# sent : sent
# hera : hera
# donwload : donwload
# android : android
# app : app
# tenaga : tenaga
# citanya : cita
# era : era
# lawak : lawak
# max : max
# mager : mager
# ngechat : ngechat
# kendalanya : kendala
# mudah : mudah
# voucher : voucher
# seharga : harga
# galang : galang
# disesuaikan : sesuai
# igho : igho
# kcepatan : kcepatan
# kbps : kbps
# telkom : telkom
# ram : ram
# kancut : kancut
# dijakarta : dijakarta
# dalem : dalem
# kamar : kamar
# setel : setel
# watch : watch
# gratisan : gratis
# beralih : alih
# dipercaya : percaya
# lambaaaaaat : lambaaaaaat
# mngenai : mngenai
# tuhan : tuhan
# berkali : kali
# merahnya : merah
# gerangan : gerangan
# inetmu : inetmu
# labil : labil
# drtd : drtd
# sore : sore
# pwr : pwr
# suda : suda
# berrti : berrti
# kecematan : cemat
# maksimum : maksimum
# gtu : gtu
# jualan : jual
# upgrade : upgrade
# ikuti : ikut
# petunjuk : tunjuk
# website : website
# amira : amira
# belajar : ajar
# microsoft : microsoft
# teams : teams
# konfirm : konfirm
# nunggu : nunggu
# seminggu : minggu
# woy : woy
# laporan : lapor
# php : php
# menu : menu
# diumpetin : diumpetin
# reza : reza
# fup : fup
# diluar : luar
# unlimitedmax : unlimitedmax
# bosan : bosan
# ajakin : ajakin
# rame : rame
# sabi : sabi
# sob : sob
# leletnya : lelet
# ketulangan : tulang
# bosen : bosen
# nanda : nanda
# carikan : cari
# wassaf : wassaf
# burung : burung
# gembrot : gembrot
# mantau : mantau
# didapatkan : dapat
# plus : plus
# recheck : recheck
# bolak : bolak
# trimz : trimz
# sertakan : serta
# sejam : jam
# inovasi : inovasi
# memperkuat : kuat
# komitmen : komitmen
# komprehensif : komprehensif
# ketenangan : tenang
# panduan : pandu
# perlindungan : lindung
# kecelakaan : celaka
# berkurang : kurang
# koordinasi : koordinasi
# kelengkapan : lengkap
# penipu : tipu
# log : log
# betulin : betulin
# yaak : yaak
# iqbal : iqbal
# pengaduan : adu
# dilaporkan : lapor
# format : format
# keindahan : indah
# alam : alam
# berbagi : bagi
# cerita : cerita
# ngiri : ngiri
# kln : kln
# dejetaitu : dejetaitu
# aignal : aignal
# normal : normal
# kerumah : rumah
# kalan : kalan
# swakarya : swakarya
# puin : puin
# pakaijatingan : pakaijatingan
# menbuka : menbuka
# medsos : medsos
# ajagk : ajagk
# putar : putar
# sett : sett
# sebenernya : sebenernya
# history : history
# notes : notes
# elah : elah
# salah : salah
# vidio : vidio
# bnyk : bnyk
# pemotongan : potong
# terbaca : baca
# weeeyy : weeeyy
# historynya : historynya
# under : under
# maksd : maksd
# bps : bps
# legend : legend
# singapore : singapore
# telkompret : telkompret
# stevan : stevan
# ame : ame
# buktikan : bukti
# giveaway : giveaway
# didepan : depan
# waynez : waynez
# track : track
# complain : complain
# paham : paham
# assistent : assistent
# seeee : seeee
# tkp : tkp
# bojonggede : bojonggede
# jln : jln
# keatas : atas
# maan : maan
# sognal : sognal
# disaatlembali : disaatlembali
# pemancardeketsitu : pemancardeketsitu
# diperbaiki : baik
# plisss : plisss
# donggg : donggg
# nampak : nampak
# kekbali : kekbali
# kembqli : kembqli
# tolongdgn : tolongdgn
# diatasi : atas
# mengganggu : ganggu
# aktifitas : aktifitas
# astaga : astaga
# ngebayangin : ngebayangin
# cuan : cuan
# nyangkut : nyangkut
# adaa : adaa
# kakkk : kakkk
# apple : apple
# music : music
# spotify : spotify
# viu : viu
# canva : canva
# invite : invite
# team : team
# payment : payment
# selly : selly
# yeollaa : yeollaa
# soul : soul
# oks : oks
# bestie : bestie
# apasih : apasih
# menderita : derita
# kualitasnyaaaaa : kualitasnyaaaaa
# scribd : scribd
# iqiyi : iqiyi
# camscanner : camscanner
# vsco : vsco
# wattpad : wattpad
# calm : calm
# wetv : wetv
# iflix : iflix
# mola : mola
# mubi : mubi
# remini : rini
# linktree : linktree
# crunchyroll : crunchyroll
# grammarly : grammarly
# picsart : picsart
# shudder : shudder
# coin : coin
# direspon : direspon
# dikomplain : komplain
# oalah : oalah
# neh : neh
# coverage : coverage
# share : share
# loopers : loopers
# berkesempatan : sempat
# menangin : menangin
# senilai : nila
# detailnya : detail
# loyalitas : loyalitas
# mengapresiasi : apresiasi
# cakep : cakep
# tatkala : tatkala
# bts : bts
# digembok : gembok
# dipalang : palang
# dicuri : curi
# accunya : accunya
# warga : warga
# ormas : ormas
# menuntut : tuntut
# kerahiman : rahim
# santuy : santuy
# bukit : bukit
# kerangka : kerangka
# besinya : besi
# dikilo : kilo
# dimakan : makan
# genderewo : genderewo
# milik : milik
# nga : nga
# debet : debet
# mandiri : mandiri
# misi : misi
# kesayangan : sayang
# kuis : kuis
# tea : tea
# pemenang : menang
# koment : koment
# ngadain : ngadain
# iphone : iphone
# ginian : ginian
# bintang : bintang
# keluhannya : keluh
# kemdikbud : kemdikbud
# frets : frets
# underrated : underrated
# aktifnya : aktif
# solusikan : solusi
# iris : iris
# daerahnya : daerah
# gebyah : gebyah
# uyah : uyah
# dipabrik : pabrik
# ditengah : tengah
# dititik : titik
# bagusan : bagus
# imho : imho
# nur : nur
# waduhhh : waduhhh
# intan : intan
# dikhawatirkan : khawatir
# deni : den
# diupayakan : upaya
# ajaa : ajaa
# nawarin : nawarin
# hoodie : hoodie
# auto : auto
# gmna : gmna
# gprs : gprs
# abis : abis
# penerima : terima
# semangat : semangat
# gol : gol
# loyal : loyal
# gannguan : gannguan
# tanggap : tanggap
# okeyy : okeyy
# doyoung : doyoung
# teh : teh
# meur : meur
# uhuyy : uhuyy
# mantulll : mantulll
# gasskeun : gasskeun
# please : please
# thanx : thanx
# deui : deui
# anjrit : anjrit
# yelli : yelli
# bersedia : sedia
# baduy : baduy
# cuocok : cuocok
# bet : bet
# hiburan : hibur
# teleponan : telepon
# free : free
# ampuun : ampuun
# brp : brp
# lsg : lsg
# jebol : jebol
# drop : drop
# dateng : dateng
# sepuasnya : puas
# direstart : direstart
# istri : istri
# nurunin : nurunin
# raaa : raaa
# balikkk : balikkk
# memuaskan : muas
# dibaca : baca
# terbuka : buka
# komen : komen
# penutupan : tutup
# reply : reply
# kudus : kudus
# pic : pic
# campus : campus
# beny : beny
# babelnya : babelnya
# mao : mao
# disinu : sinu
# ngelag : ngelag
# sisan : sis
# kae : kae
# dijak : dijak
# nek : nek
# wis : wis
# buset : buset
# pim : pim
# keblokir : blokir
# hufftttt : hufftttt
# majelis : majelis
# taqwa : taqwa
# mtt : mtt
# lazismu : lazismu
# membangun : bangun
# sumur : sumur
# bor : bor
# rawan : rawan
# kekeringan : kering
# brama : brama
# diomelin : diomelin
# suami : suami
# bangkek : bangkek
# tlf : tlf
# deuh : deuh
# tanggung : tanggung
# kena : kena
# omel : omel
# komfirmasi : komfirmasi
# devi : devi
# menyenangkan : senang
# telalu : talu
# mengunggu : mengunggu
# pondok : pondok
# indah : indah
# metro : metro
# cipulir : cipulir
# doing : doing
# not : not
# sel : sel
# subscriber : subscriber
# veronica : veronica
# only : only
# nautica : nautica
# shelby : shelby
# owh : owh
# informasinya : informasi
# kirain : kirain
# nada : nada
# tut : tut
# semenit : menit
# ditelpon : telpon
# sekalinya : sekali
# diputus : putus
# wujiaxin : wujiaxin
# theme : theme
# ditempat : tempat
# dipakai : pakai
# lenyap : lenyap
# wino : wino
# myorbit : myorbit
# sasa : sasa
# smsm : smsm
# menghubungkan : hubung
# adik : adik
# makassar : makassar
# bali : bal
# mengerti : erti
# aldy : aldy
# membutuhkan : butuh
# aliran : alir
# listrik : listrik
# memancarkan : pancar
# hadehhhh : hadehhhh
# huffftttt : huffftttt
# strategis : strategis
# kopi : kopi
# kosmetik : kosmetik
# obat : obat
# herbal : herbal
# kasur : kasur
# shop : shop
# dijelajahi : jajah
# arya : arya
# manda : manda
# fara : fara
# imbas : imbas
# boomingnya : boomingnya
# okesip : okesip
# tergiur : giur
# fiktif : fiktif
# pulsapun : pulsa
# yuna : yuna
# antri : antri
# diinfo : info
# didatengin : didatengin
# csnya : csnya
# pecinta : cinta
# serial : serial
# diakses : akses
# maxstream : maxstream
# beeeeee : beeeeee
# ono : ono
# muahal : muahal
# kayanya : kaya
# nerima : nerima
# addie : addie
# penyedia : sedia
# oknum : oknum
# memblokir : blokir
# disuruhnya : suruh
# dibeli : beli
# bisaa : bisaa
# gacukupp : gacukupp
# pulsaku : pulsa
# kemaren : kemaren
# bantuannyaaa : bantuannyaaa
# favoritnya : favorit
# pastiin : pastiin
# meeting : meeting
# jangkauan : jangkau
# modemnya : modem
# kadrun : kadrun
# kominfo : kominfo
# horizzon : horizzon
# dehhh : dehhh
# mayan : mayan
# soyie : soyie
# lamar : lamar
# dealer : dealer
# yamaha : yamaha
# honda : honda
# rekrutmen : rekrutmen
# wajar : wajar
# running : running
# file : file
# logikanya : logika
# mecet : mecet
# bongkar : bongkar
# dilla : dilla
# realy : realy
# mhl : mhl
# alpha : alpha
# rusak : rusak
# langusng : langusng
# exol : exol
# darting : darting
# membanting : banting
# prepare : prepare
# gojekin : gojekin
# jeljar : jeljar
# jalan : jalan
# lurus : lurus
# back : back
# ngedumel : ngedumel
# towernya : towernya
# begindang : begindang
# surabaya : surabaya
# sekitaran : sekitar
# mayjen : mayjen
# soengkono : soengkono
# joss : joss
# ogah : ogah
# ogahan : ogah
# merajai : raja
# penanganan : tangan
# modal : modal
# dikit : dikit
# sksksk : sksksk
# kesel : kesel
# setan : setan
# julian : juli
# tnya : tnya
# tetngga : tetngga
# sya : sya
# kado : kado
# diskon : diskon
# device : device
# plan : plan
# dapatkan : dapat
# bulannya : bulan
# taeyong : taeyong
# pakenya : pakenya
# eeq : eeq
# icey : icey
# zakia : zakia
# berakibat : akibat
# geza : geza
# zenius : zenius
# umumkan : umum
# kompetisi : kompetisi
# ilmupedia : ilmupedia
# berani : berani
# season : season
# hadiahnya : hadiah
# ismi : ismi
# bekasi : bekas
# gedung : gedung
# park : park
# noer : noer
# ali : ali
# selatan : selatan
# operasional : operasional
# wdh : wdh
# pandaan : pandaan
# gaena : gaena
# sending : sending
# text : text
# pending : pending
# huhuhuuu : huhuhuuu
# sopankah : sopan
# bgitu : bgitu
# ehehe : ehehe
# canda : canda
# sopan : sopan
# mengakses : akses
# dibatasi : batas
# dikenakan : kena
# kia : kia
# teman : teman
# nyampe : nyampe
# bundlingnya : bundlingnya
# rbuan : rbuan
# nelfon : nelfon
# kepotong : potong
# tagih : tagih
# terucap : ucap
# nyolott : nyolott
# myads : myads
# bedakan : beda
# keunggulannya : unggul
# kemampuan : mampu
# konsisten : konsisten
# menjaga : jaga
# kestabilan : stabil
# teknisnya : teknis
# standby : standby
# eksternal : eksternal
# masi : mas
# tbtb : tbtb
# kesedot : sedot
# hadeh : hadeh
# wow : wow
# repot : repot
# susahnya : susah
# supervisor : supervisor
# perbedaan : beda
# menyesuaikan : sesuai
# besaran : besar
# penggunan : gun
# hello : hello
# ngecek : ngecek
# trafik : trafik
# statistik : statistik
# terburuk : buruk
# reseller : reseller
# alba : alba
# kanaya : kanaya
# nomortujuan : nomortujuan
# nominaltransfer : nominaltransfer
# mohob : mohob
# thnx : thnx
# kampung : kampung
# adlh : adlh
# blng : blng
# mulutku : mulut
# prasaan : prasaan
# farhan : farhan
# jirrr : jirrr
# sebelomnya : bom
# malem : malem
# sialan : sial
# samsek : samsek
# hmm : hmm
# pesimis : pesimis
# lihat : lihat
# ite : ite
# bersentuhan : sentuh
# kekuasaan : kuasa
# didiemin : didiemin
# nekat : nekat
# serunya : seru
# berinternet : berinternet
# alief : alief
# uncomfortable : uncomfortable
# complaints : complaints
# just : just
# send : send
# following : following
# sahrrul : sahrrul
# jaringanmu : jaring
# using : using
# latest : latest
# version : version
# calv : calv
# yoaiii : yoaiii
# duluu : duluu
# istrinya : istri
# currently : currently
# having : having
# troubles : troubles
# our : our
# unable : unable
# moment : moment
# sure : sure
# one : one
# thank : thank
# senasib : nasib
# apk : apk
# brimo : brimo
# general : general
# how : how
# evan : evan
# padat : padat
# sapa : sapa
# biby : biby
# ybs : ybs
# trsf : trsf
# mbayar : mbayar
# seriiing : seriiing
# kouta : kouta
# noela : noela
# real : real
# manusia : manusia
# piala : piala
# menpora : menpora
# buffering : buffering
# ngasih : ngasih
# berkolaborasi : kolaborasi
# yakali : yakali
# bocor : bocor
# lur : lur
# mutan : mutan
# jenis : jenis
# emg : emg
# identitas : identitas
# erdi : erdi
# bersangkutan : sangkut
# uy : uy
# mendikbud : mendikbud
# boong : boong
# sehari : hari
# epic : epic
# mingguan : minggu
# kehilangan : hilang
# meresahkan : resah
# pencuri : curi
# hpnya : hpnya
# contact : contact
# tsb : tsb
# simpatiku : simpati
# mental : mental
# brimonya : brimonya
# terkahir : terkahir
# artl : artl
# gh : gh
# aul : aul
# pnd : pnd
# nungguin : nungguin
# zona : zona
# merasakan : rasa
# undi : undi
# hepi : hepi
# tukarkan : tukar
# terpilih : pilih
# alprie : alprie
# azi : azi
# alasan : alas
# grace : grace
# mengisi : isi
# dimohon : mohon
# semingguan : minggu
# mantablah : mantablah
# pranowo : pranowo
# kick : kick
# lakukan : laku
# simcard : simcard
# mesin : mesin
# sedia : sedia
# ektp : ektp
# bingund : bingund
# diurus : urus
# dicolek : colek
# diaktivasi : diaktivasi
# telko : telko
# strategi : strategi
# khas : khas
# debut : debut
# ott : ott
# asing : asing
# nice : nice
# cingcong : cingcong
# stlh : stlh
# colek : colek
# keliatan : liat
# panen : panen
# boled : boled
# klaim : klaim
# reedem : reedem
# jasa : jasa
# im : im
# mark : mark
# rekening : rekening
# shopee : shopee
# pay : pay
# james : james
# gasengaja : gasengaja
# support : support
# wallet : wallet
# rate : rate
# tips : tips
# etmin : etmin
# cdm : cdm
# hendra : hendra
# penjual : jual
# guntur : guntur
# result : result
# togel : togel
# sumo : sumo
# jink : jink
# otak : otak
# skrng : skrng
# upayain : upayain
# pengertian : erti
# pela : pela
# upsssh : upsssh
# macem : macem
# gedungnya : gedung
# milea : milea
# innes : innes
# cheryl : cheryl
# kembaliin : kembaliin
# uninstall : uninstall
# berguna : guna
# yahdi : yahdi
# haaii : haaii
# tanggapan : tanggap
# niat : niat
# dpet : dpet
# orng : orng
# nyasar : nyasar
# pagiiiiii : pagiiiiii
# bar : bar
# connection : connection
# siiii : siiii
# dibawah : bawah
# didaftarkan : daftar
# rara : rara
# menyebabkan : sebab
# pengaturan : atur
# aleem : aleem
# diabantu : diabantu
# lunar : lunar
# gada : gada
# pindahin : pindahin
# galih : galih
# tolonglah : tolong
# twtr : twtr
# ato : ato
# daftarkan : daftar
# dikembalikan : kembali
# rizki : rizki
# kambing : kambing
# gabby : gabby
# lanjutin : lanjutin
# karakter : karakter
# tasyarp : tasyarp
# halus : halus
# ter : ter
# ahaha : ahaha
# rugikan : rugi
# ketersedian : dian
# dimigrasi : migrasi
# okey : okey
# manisnya : manis
# jawabannya : jawab
# day : day
# jawabanmu : jawab
# senyum : senyum
# keenan : keenan
# manyue : manyue
# puk : puk
# yosahi : yosahi
# boss : boss
# begeeste : begeeste
# usage : usage
# weverse : weverse
# pendaftaran : daftar
# ngangenin : ngangenin
# syaratnya : syarat
# kahar : kahar
# batam : batam
# sumbar : sumbar
# kepri : kepri
# pembagian : bagi
# konser : konser
# eits : eits
# vibe : vibe
# musicmax : musicmax
# langitmusik : langitmusik
# bisanya : bisa
# test : test
# shireen : shireen
# desta : desta
# ketagihan : tagih
# menjelajahi : jajah
# dunia : dunia
# maya : maya
# jaya : jaya
# selancar : selancar
# pantengin : pantengin
# debat : debat
# bentuk : bentuk
# cacad : cacad
# rbt : rbt
# deasy : deasy
# natalina : natalina
# filaa : filaa
# deasyofficials : deasyofficials
# gibran : gibran
# ditanggapi : tanggap
# menyuruh : suruh
# bedanya : beda
# galakk : galakk
# beb : beb
# himbauan : himbauan
# kepastian : pasti
# berupaya : upaya
# sakia : sakia
# raden : raden
# kring : kring
# mention : mention
# jari : jari
# padamu : pada
# tolol : tolol
# benerin : benerin
# bejejer : bejejer
# arifin : arifin
# puas : puas
# dengerin : dengerin
# musik : musik
# didik : didik
# jairngan : jairngan
# petir : petir
# ngadet : ngadet
# hebring : hebring
# dikala : kala
# booring : booring
# asyik : asyik
# movie : movie
# series : series
# favorit : favorit
# berjejer : jejer
# fungsi : fungsi
# komunikasi : komunikasi
# shiva : shiva
# made : made
# sense : sense
# decision : decision
# major : major
# ...
# tanah : tanah
# goreng : goreng
# jang : jang
# moal : moal
# laluasa : laluasa
# teun : teun
# urang : urang
# sabtu : sabtu
# loba : loba
# jelema : jelema
# ngetawain : ngetawain
# tik : tik
# tod : tod
# kacau : kacau
# iyeu : iyeu
# cianjur : cianjur
# subuh : subuh
# imah : imah
# tewira : tewira
# awe : awe
# njir : njir
# nambahan : nambahan
# didinya : didinya
# hayu : hayu
# cacat : cacat
# ngolo : ngolo
# jadikeun : jadikeun
# ajakan : aja
# lobaan : loba
# siyap : siyap
# hayang : hayang
# model : model
# kumaha : maha
# baleg : baleg
# beuki : beuki
# dieu : dieu
# asa : asa
# singit : singit
# ketiga : tiga
# ngetweet : ngetweet
# astagaa : astagaa
# boro : boro
# stengah : stengah
# munding : munding
# gelo : gelo
# ngadon : ngadon
# dewek : dewek
# biang : biang
# maneh : maneh
# kade : kade
# katularan : katularan
# komo : komo
# leuweung : leuweung
# ulah : ulah
# tatangga : tatangga
# araneheun : araneheun
# naha : naha
# cenah : cenah
# bari : bari
# piraku : piraku
# jeung : jeung
# panto : panto
# kepo : kepo
# ladenan : laden
# oge : oge
# baraleg : baraleg
# wkwkwkwk : wkwkwkwk
# euweuh : euweuh
# beukieun : beukieun
# jieun : jieun
# candil : candil
# nyesa : nyesa
# teuh : teuh
# nyimpang : nyimpang
# nganteurkeun : nganteurkeun
# dewi : dewi
# enya : enya
# jeumpling : jeumpling
# kiyeu : kiyeu
# bud : bud
# perhatian : perhati
# ngasupan : ngasupan
# ngahaseupan : ngahaseupan
# moto : moto
# saparo : saparo
# wadul : wadul
# cik : cik
# poto : poto
# bbrpa : bbrpa
# aplg : aplg
# yaallah : yaallah
# euh : euh
# ngenca : ngenca
# ngolong : ngolong
# puter : puter
# trie : trie
# multimedia : multimedia
# gamemax : gamemax
# boa : boa
# paehan : paehan
# pengumuman : umum
# atawa : atawa
# ngabejaan : ngabejaan
# keur : keur
# gawe : gawe
# nyeupan : nyeupan
# meuren : meuren
# selesainya : selesai
# marwc : marwc
# nana : nana
# legends : legends
# lieur : lieur
# eun : eun
# kmh : kmh
# ngajawab : ngajawab
# ajak : ajak
# ning : ning
# ezi : ezi
# riwayat : riwayat
# kyoongb : kyoongb
# malas : malas
# warung : warung
# randa : randa
# asupan : asupan
# ngasupkeun : ngasupkeun
# manteb : manteb
# saking : saking
# ngebutnya : ngebut
# semesta : semesta
# becandanya : becandanya
# kureng : reng
# custumer : custumer
# penambahan : tambah
# kartunya : kartu
# ngopi : ngopi
# ngajak : ngajak
# limit : limit
# tuju : tuju
# mawa : mawa
# sing : sing
# lembar : lembar
# twit : twit
# bisnis : bisnis
# ihh : ihh
# puguh : puguh
# waranian : waranian
# phone : phone
# ajen : ajen
# oohh : oohh
# njiiir : njiiir
# uyy : uyy
# ngacak : ngacak
# lapak : lapak
# ananda : ananda
# somantri : somantri
# hahaa : hahaa
# toss : toss
# mantul : mantul
# bingung : bingung
# kost : kost
# deya : deya
# reservasi : reservasi
# psb : psb
# respons : respons
# daun : daun
# twitterku : twitterku
# adaaaa : adaaaa
# gangguannya : ganggu
# perna : perna
# target : target
# keteteran : keteter
# astrid : astrid
# mita : mita
# xxx : xxx
# dataseluler : dataseluler
# sampingannya : samping
# pegawai : pegawai
# kontrak : kontrak
# ngadagoan : ngadagoan
# heula : heula
# jcw : jcw
# pengsian : sian
# dwiieng : dwiieng
# dasarnya : dasar
# maulana : maulana
# ervan : ervan
# giga : giga
# tiktok : tiktok
# tarik : tarik
# ngerih : ngerih
# relatif : relatif
# diajar : ajar
# bahasa : bahasa
# sunda : sunda
# citizent : citizent
# mematikan : mati
# force : force
# terkoneksi : koneksi
# dimatikan : mati
# background : background
# hemat : hemat
# saver : saver
# citraallegro : citraallegro
# ceunah : ceunah
# miminnya : miminnya
# dipanjat : panjat
# sengol : sengol
# tegak : tegak
# jol : jol
# nyegag : nyegag
# gelud : gelud
# aries : aries
# promosi : promosi
# mantengin : mantengin
# simpsons : simpsons
# desi : desi
# layo : layo
# close : close
# sebegitunya : begitu
# bayangin : bayangin
# panjat : panjat
# jadiin : jadiin
# arena : arena
# goyang : goyang
# udel : udel
# jamin : jamin
# ngatjenk : ngatjenk
# ips : ips
# tata : tata
# letak : letak
# suagtu : suagtu
# pekerjakan : kerja
# ahli : ahli
# dibidangnya : bidang
# bodoh : bodoh
# shiren : shiren
# mencari : cari
# usaha : usaha
# sampingan : samping
# menghargai : harga
# pelanggannya : langgan
# kmrn : kmrn
# ren : ren
# lapaoran : lapaoran
# tahan : tahan
# jga : jga
# lainnnn : lainnnn
# engke : engke
# ovi : ovi
# kunaon : kunaon
# sasaran : sasar
# cipta : cipta
# tere : tere
# ditwitter : ditwitter
# bufferingnya : bufferingnya
# hap : hap
# alhamdulillah : alhamdulillah
# nyala : nyala
# semalem : semalem
# ledakan : ledak
# kilang : kilang
# pet : pet
# cable : cable
# lonte : lonte
# komplen : komplen
# edi : edi
# dbantu : dbantu
# topan : topan
# all : all
# qris : qris
# digambarin : digambarin
# bangett : bangett
# yukkk : yukkk
# hakpelanggan : hakpelanggan
# sarana : sarana
# munculnya : muncul
# ngomong : ngomong
# ichay : ichay
# diinjak : injak
# haknya : hak
# memeknya : memek
# sayangnya : sayang
# negeri : negeri
# perampok : rampok
# ggak : ggak
# dihujat : hujat
# dhiel : dhiel
# tina : tina
# bayuu : bayuu
# memasukan : pasu
# pin : pin
# ananta : ananta
# pengirim : kirim
# worth : worth
# ajik : ajik
# anan : anan
# pemilik : milik
# pemberi : beri
# kuasa : kuasa
# perbankan : perban
# fintech : fintech
# paspor : paspor
# kta : kta
# ipunk : ipunk
# diwakilkan : wakil
# melampirkan : lampir
# bermaterai : bermaterai
# browsing : browsing
# ceuk : ceuk
# bule : bule
# ngarti : ngarti
# pramudita : pramudita
# haura : haura
# gintung : gintung
# kel : kel
# tanjung : tanjung
# jagakarsa : jagakarsa
# parahhh : parahhh
# hrs : hrs
# bentar : bentar
# isii : isi
# secretonya : secretonya
# hecan : hecan
# gila : gila
# wishnu : wishnu
# komisaris : komisaris
# tokped : tokped
# meeen : meeen
# pikiranku : pikir
# right : right
# use : use
# local : local
# quota : quota
# can : can
# used : used
# activation : activation
# hope : hope
# helps : helps
# testi : testi
# tokopedia : tokopedia
# blibli : blibli
# trusted : trusted
# kenapaaaa : kenapaaaa
# sans : sans
# kocak : kocak
# jirrrr : jirrrr
# dmnya : dmnya
# diulang : ulang
# ngulibek : ngulibek
# puputeran : puputeran
# dipaketin : dipaketin
# nyoba : nyoba
# maketin : maketin
# welkin : welkin
# daftarin : daftarin
# ngertiin : ngertiin
# dkit : dkit
# penguat : kuat
# mini : mini
# musti : musti
# mikir : mikir
# portable : portable
# kabel : kabel
# adaptor : adaptor
# penghantar : hantar
# daya : daya
# balasanya : balasanya
# rejeki : rejeki
# ager : ager
# kabagean : kabagean
# bikeun : bikeun
# sampaiin : sampaiin
# pling : pling
# kekeh : kekeh
# kebijakan : bijak
# melek : melek
# patah : patah
# arang : arang
# anang : anang
# sarua : sarua
# geura : geura
# tulisan : tulis
# what : what
# meaning : meaning
# activate : activate
# package : package
# below : below
# lydia : lydia
# ngilang : ngilang
# maap : maap
# tutupin : tutupin
# soalnyaa : soalnyaa
# tdii : tdii
# santet : santet
# wae : wae
# rayakan : raya
# puncak : puncak
# mobitekno : mobitekno
# inisiatif : inisiatif
# diusung : usung
# ngajuin : ngajuin
# pinjaman : pinjam
# kog : kog
# menguntungkan : untung
# kinerja : kerja
# optimal : optimal
# meletakkan : letak
# router : router
# mebel : mebel
# berukuran : ukur
# dinding : dinding
# tebal : tebal
# dipengaruhi : pengaruh
# penempatan : tempat
# ditempatkan : tempat
# ramah : ramah
# meja : meja
# lemari : lemari
# jendela : jendela
# jahat : jahat
# kpdku : kpdku
# pagj : pagj
# mentah : mentah
# rumit : rumit
# rudi : rudi
# rahw : rahw
# pd : pd
# marah : marah
# iki : iki
# elek : elek
# tenan : tenan
# kenopo : kenopo
# ceritain : ceritain
# curiga : curiga
# ngeri : ngeri
# kenpa : kenpa
# tante : tante
# kakek : kakek
# nenek : nenek
# sekrng : sekrng
# taunya : tau
# kasi : kasi
# refrsh : refrsh
# hening : hening
# ntar : ntar
# ngegantiin : ngegantiin
# walopun : walopun
# mksi : mksi
# nyet : nyet
# diikuti : ikut
# murid : murid
# seleanggarakan : seleanggarakan
# cerdas : cerdas
# cermat : cermat
# bei : bei
# ingetin : ingetin
# tdak : tdak
# panimbang : panimbang
# ndat : ndat
# siqnal : siqnal
# zaman : zaman
# mengharuskan : harus
# pelangganya : pelangganya
# neteng : neteng
# percayaan : percaya
# penomoran : nomor
# dukcapil : dukcapil
# dituker : dituker
# belain : bain
# brngkt : brngkt
# dri : dri
# membawahasil : membawahasil
# nihil : nihil
# dlu : dlu
# pengurusan : urus
# ckup : ckup
# kebijaksanaan : bijaksana
# setianya : setia
# wooyy : wooyy
# gimna : gimna
# lemooot : lemooot
# maintanance : maintanance
# diem : diem
# ciwi : ciwi
# idup : idup
# sumpah : sumpah
# gmeet : gmeet
# maksuddd : maksuddd
# anjjjjj : anjjjjj
# numpuk : numpuk
# gambar : gambar
# kecepatannya : cepat
# cappuccino : cappuccino
# pasca : pasca
# billingnya : billingnya
# deadline : deadline
# oembayaran : oembayaran
# gkc : gkc
# hendrie : hendrie
# solved : solved
# mendampingi : damping
# anak : anak
# gundu : gundu
# omdo : omdo
# sekebon : kebon
# wkkww : wkkww
# rin : rin
# codenya : codenya
# gatau : gatau
# lurah : lurah
# kenapaa : kenapaa
# abu : abu
# donny : donny
# ngancem : ngancem
# berprinsip : prinsip
# hukum : hukum
# ciri : ciri
# negara : negara
# maju : maju
# selalau : lalau
# peralih : alih
# laine : laine
# ngungsi : ngungsi
# jawap : jawap
# kawang : kawang
# nguluh : nguluh
# alma : alma
# telkomselnya : telkomselnya
# {'': '', 'facebook': 'facebook', 'messenger': 'messenger', 'telkomsel': 'telkomsel', 'telegram': 'telegram', 'official': 'official', 'bot': 'bot', 'situs': 'situs', 'whatsapp': 'whatsapp', 'virtual': 'virtual', 'asisten': 'asisten', 'aplikasi': 'aplikasi', 'mytelkomsel': 'mytelkomsel', 'makasih': 'makasih', 'micha': 'micha', 'kak': 'kak', 'indra': 'indra', 'maaf': 'maaf', 'banget': 'banget', 'kakak': 'kakak', 'berkendala': 'kendala', 'menghubungi': 'hubung', 'mimin': 'mimin', 'silakan': 'sila', 'instagram': 'instagram', 'email': 'email', 'resmi': 'resmi', 'layanan': 'layan', 'assistant': 'assistant', 'veronika': 'veronika', 'akses': 'akses', 'line': 'line', 'hai': 'hai', 'alprima': 'alprima', 'keluhan': 'keluh', 'login': 'login', 'infokan': 'info', 'nomor': 'nomor', 'via': 'via', 'dibantu': 'bantu', 'cek': 'cek', 'privasi': 'privasi', 'terjaga': 'jaga', 'elma': 'elma', 'sinyal': 'sinyal', 'lemot': 'lot', 'pagi': 'pagi', 'min': 'min', 'verification': 'verification', 'linknya': 'linknya', 'masuk': 'masuk', 'sms': 'sms', 'koneksinya': 'koneksi', 'bingsit': 'bingsit', 'kamboja': 'kamboja', 'bang': 'bang', 'murah': 'murah', 'toel': 'toel', 'langsung': 'langsung', 'gerak': 'gerak', 'cepat': 'cepat', 'pengalaman': 'alam', 'pribadi': 'pribadi', 'komplain': 'komplain', 'gara': 'gara', 'bayar': 'bayar', 'mahal': 'mahal', 'nanya': 'nanya', 'wil': 'wil', 'kalsel': 'kalsel', 'khusus': 'khusus', 'kab': 'kab', 'hst': 'hst', 'hilang': 'hilang', 'mulu': 'mulu', 'tolong': 'tolong', 'perbaiki': 'baik', 'kualitas': 'kualitas', 'ane': 'ane', 'jdi': 'jdi', 'rugi': 'rugi', 'beli': 'beli', 'paket': 'paket', 'pakai': 'pakai', 'kuota': 'kuota', 'restu': 'restu', 'terhubung': 'hubung', 'rekan': 'rekan', 'melanjutkan': 'lanjut', 'interaksi': 'interaksi', 'pricing': 'pricing', 'strategy': 'strategy', 'terbaik': 'baik', 'memenuhi': 'penuh', 'aspek': 'aspek', 'fachmi': 'fachmi', 'zakki': 'zakki', 'hangus': 'hangus', 'data': 'data', 'teregistrasinya': 'registrasi', 'otomatis': 'otomatis', 'terhapus': 'hapus', 'nyaman': 'nyaman', 'jeslyn': 'jeslyn', 'diterima': 'terima', 'berubah': 'ubah', 'sesuai': 'sesuai', 'program': 'program', 'diselenggarakan': 'selenggara', 'berlaku': 'laku', 'penawaran': 'tawar', 'aktivasi': 'aktivasi', 'tersedia': 'sedia', 'dial': 'dial', 'tks': 'tks', 'aloisius': 'aloisius', 'combo': 'combo', 'sakti': 'sakti', 'unlimited': 'unlimited', 'promo': 'promo', 'personal': 'personal', 'skema': 'skema', 'tarif': 'tarif', 'umur': 'umur', 'kartu': 'kartu', 'penggunaan': 'guna', 'kondisi': 'kondisi', 'diregistrasikan': 'registrasi', 'lokasi': 'lokasi', 'detail': 'detail', 'minimal': 'minimal', 'mengandung': 'kandung', 'kecamatan': 'camat', 'kota': 'kota', 'datanya': 'data', 'aman': 'aman', 'kendala': 'kendala', 'udah': 'udah', 'coba': 'coba', 'pilih': 'pilih', 'off': 'off', 'service': 'service', 'infoin': 'infoin', 'uang': 'uang', 'hasil': 'hasil', 'ngebacot': 'ngebacot', 'buzzer': 'buzzer', 'mengeluh': 'keluh', 'emang': 'emang', 'jatah': 'jatah', 'beduai': 'beduai', 'kabupaten': 'kabupaten', 'sanggau': 'sanggau', 'prov': 'prov', 'kalimantan': 'kalimantan', 'barat': 'barat', 'paketan': 'paket', 'internet': 'internet', 'termurah': 'murah', 'malam': 'malam', 'modem': 'modem', 'flash': 'flash', 'lempar': 'lempar', 'kesal': 'kesal', 'iya': 'iya', 'kayak': 'kayak', 'kura': 'kura', 'lemood': 'lemood', 'buang': 'buang', 'sayang': 'sayang', 'puluhan': 'puluh', 'esmosi': 'esmosi', 'provider': 'provider', 'bagus': 'bagus', 'gue': 'gue', 'deh': 'deh', 'mengubungi': 'ubung', 'twitter': 'twitter', 'dias': 'dias', 'mohon': 'mohon', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'agnes': 'agnes', 'ellenwina': 'ellenwina', 'stabil': 'stabil', 'mencoba': 'coba', 'refresh': 'refresh', 'jaringan': 'jaring', 'handphone': 'handphone', 'memindahkan': 'pindah', 'mode': 'mode', 'manual': 'manual', 'pulsa': 'pulsa', 'terlambat': 'lambat', 'peningkatan': 'tingkat', 'sistem': 'sistem', 'mengirim': 'kirim', 'ulang': 'ulang', 'kode': 'kode', 'verifikasi': 'verifikasi', 'indosat ...
# ------------------------
# Pandas Apply:   0%|          | 0/1943 [00:00<?, ?it/s]
#                                                 content  \
# 0     @gadis48060642 2. facebook messenger 'telkomse...
# 1     @gadis48060642 baik, kak indra. maaf banget ya...
# 2     @alprimajurnas hai, kak alprima. maaf ya. meng...
# 3     @telkomsel kenapa ya sinyal telkomsel sekarang...
# 4     @telkomsel pagi min saya ga bisa login aplikas...
# ...                                                 ...
# 1995  @indahpshasan hai, kak indah. maaf ya. mengena...
# 1996         @telkomsel ya iya semua kawang nguluh sama
# 1997  @almasyfm @telkomsel @indihome pagi kak alma, ...
# 1998  @islamianandaku baik, kak islamia. maaf ya mim...
# 1999  @max2game 4. nomor telkomsel lain yang berkend...
#
#                                          cleaning_tweet  \
# 0      facebook messenger telkomsel telegram officia...
# 1     baik kak indra maaf banget jika kakak berkenda...
# 2     hai kak alprima maaf mengenai keluhan gak bisa...
# 3        kenapa sinyal telkomsel sekarang lemot sekali
# 4     pagi min saya bisa login aplikasi telkomsel ve...
# ...                                                 ...
# 1995  hai kak indah maaf mengenai kendala akses inte...
# 1996                       iya semua kawang nguluh sama
# 1997      pagi kak alma silahkan telkomselnya lewat yaa
# 1998  baik kak islamia maaf mimin sarankan tidak inf...
# 1999   nomor telkomsel lain yang berkendala minimal ...
#
#                                              tokenisasi  \
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [baik, kak, indra, maaf, banget, jika, kakak, ...
# 2     [hai, kak, alprima, maaf, mengenai, keluhan, g...
# 3     [kenapa, sinyal, telkomsel, sekarang, lemot, s...
# 4     [pagi, min, saya, bisa, login, aplikasi, telko...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, mengenai, kendala, aks...
# 1996               [, iya, semua, kawang, nguluh, sama]
# 1997  [pagi, kak, alma, silahkan, telkomselnya, lewa...
# 1998  [baik, kak, islamia, maaf, mimin, sarankan, ti...
# 1999  [, nomor, telkomsel, lain, yang, berkendala, m...
#
#                                                stopword  \
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [kak, indra, maaf, banget, kakak, berkendala, ...
# 2     [hai, kak, alprima, maaf, keluhan, login, apli...
# 3                          [sinyal, telkomsel, lemot, ]
# 4     [pagi, min, login, aplikasi, telkomsel, verifi...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, kendala, akses, intern...
# 1996                            [, iya, kawang, nguluh]
# 1997     [pagi, kak, alma, silahkan, telkomselnya, yaa]
# 1998  [kak, islamia, maaf, mimin, sarankan, infokan,...
# 1999  [, nomor, telkomsel, berkendala, minimal, nomo...
#
#                                                stemming
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [kak, indra, maaf, banget, kakak, kendala, hub...
# 2     [hai, kak, alprima, maaf, keluh, login, aplika...
# 3                            [sinyal, telkomsel, lot, ]
# 4     [pagi, min, login, aplikasi, telkomsel, verifi...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, kendala, akses, intern...
# 1996                            [, iya, kawang, nguluh]
# 1997        [pagi, kak, alma, silah, telkomselnya, yaa]
# 1998  [kak, islamia, maaf, mimin, saran, info, data,...
# 1999  [, nomor, telkomsel, kendala, minimal, nomor, ...
#
# [1943 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [, facebook, messenger, telkomsel, telegram, o...
# 1     [kak, indra, maaf, banget, kakak, kendala, hub...
# 2     [hai, kak, alprima, maaf, keluh, login, aplika...
# 3                            [sinyal, telkomsel, lot, ]
# 4     [pagi, min, login, aplikasi, telkomsel, verifi...
# ...                                                 ...
# 1995  [hai, kak, indah, maaf, kendala, akses, intern...
# 1996                            [, iya, kawang, nguluh]
# 1997        [pagi, kak, alma, silah, telkomselnya, yaa]
# 1998  [kak, islamia, maaf, mimin, saran, info, data,...
# 1999  [, nomor, telkomsel, kendala, minimal, nomor, ...
#
# [1943 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_3.xlsx')
