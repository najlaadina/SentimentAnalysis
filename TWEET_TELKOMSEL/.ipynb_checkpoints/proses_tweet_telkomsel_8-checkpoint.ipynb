# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @RDW12_ Hai Kak. Maaf ya, apakah yang dimaksud...
# 1     @Telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di Hi Mr. Indra. Sorry for the pro...
# 3     ➡️ $ZM Strong Business Metrics 💪🏻\n\n- Cust &g...
# 4     @Telkomsel Iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess Yg Telkomsel kapan min? @SiapUnd...
# 1996  @Noyah77106135 infoin No HP, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @Noyah77106135 Hai, Kak Noyah. Maaf ya. Buat h...
# 1999  Haii, Selamat pagii\nyang need pulsa cepat bis...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 26

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @RDW12_ Hai Kak. Maaf ya, apakah yang dimaksud...
# 1     @Telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di Hi Mr. Indra. Sorry for the pro...
# 3     ➡️ $ZM Strong Business Metrics 💪🏻\n\n- Cust &g...
# 4     @Telkomsel Iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess Yg Telkomsel kapan min? @SiapUnd...
# 1996  @Noyah77106135 infoin No HP, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @Noyah77106135 Hai, Kak Noyah. Maaf ya. Buat h...
# 1999  Haii, Selamat pagii\nyang need pulsa cepat bis...
#
# [1957 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @rdw12_ hai kak. maaf ya, apakah yang dimaksud...
# 1     @telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di hi mr. indra. sorry for the pro...
# 3     ➡️ $zm strong business metrics 💪🏻\n\n- cust &g...
# 4     @telkomsel iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess yg telkomsel kapan min? @siapund...
# 1996  @noyah77106135 infoin no hp, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @noyah77106135 hai, kak noyah. maaf ya. buat h...
# 1999  haii, selamat pagii\nyang need pulsa cepat bis...
#
# [1957 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @rdw12_ hai kak. maaf ya, apakah yang dimaksud...
# 1     @telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di hi mr. indra. sorry for the pro...
# 3     ➡️ $zm strong business metrics 💪🏻\n\n- cust &g...
# 4     @telkomsel iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess yg telkomsel kapan min? @siapund...
# 1996  @noyah77106135 infoin no hp, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @noyah77106135 hai, kak noyah. maaf ya. buat h...
# 1999  haii, selamat pagii\nyang need pulsa cepat bis...
#
#                                          cleaning_tweet
# 0      hai kak maaf apakah yang dimaksud dengan kart...
# 1     min apa bisa pindahin nomor kartu lama kartu b...
# 2      indra sorry for the problem have you tried re...
# 3      strong business metrics cust arr   cust ttm  ...
# 4     iya semakin lama paket ditawarkan semakin maha...
# ...                                                 ...
# 1995                               telkomsel kapan min
# 1996  infoin tgl kejadian lokasi detail dan lain yan...
# 1997  kenapa hadiah daily check telkomsel tidak bisa...
# 1998  hai kak noyah maaf buat harga telkomsel sudah ...
# 1999  haii selamat pagii yang need pulsa cepat bisa ...
#
# [1957 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @rdw12_ hai kak. maaf ya, apakah yang dimaksud...
# 1     @telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di hi mr. indra. sorry for the pro...
# 3     ➡️ $zm strong business metrics 💪🏻\n\n- cust &g...
# 4     @telkomsel iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess yg telkomsel kapan min? @siapund...
# 1996  @noyah77106135 infoin no hp, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @noyah77106135 hai, kak noyah. maaf ya. buat h...
# 1999  haii, selamat pagii\nyang need pulsa cepat bis...
#
#                                          cleaning_tweet  \
# 0      hai kak maaf apakah yang dimaksud dengan kart...
# 1     min apa bisa pindahin nomor kartu lama kartu b...
# 2      indra sorry for the problem have you tried re...
# 3      strong business metrics cust arr   cust ttm  ...
# 4     iya semakin lama paket ditawarkan semakin maha...
# ...                                                 ...
# 1995                               telkomsel kapan min
# 1996  infoin tgl kejadian lokasi detail dan lain yan...
# 1997  kenapa hadiah daily check telkomsel tidak bisa...
# 1998  hai kak noyah maaf buat harga telkomsel sudah ...
# 1999  haii selamat pagii yang need pulsa cepat bisa ...
#
#                                              tokenisasi
# 0     [, hai, kak, maaf, apakah, yang, dimaksud, den...
# 1     [min, apa, bisa, pindahin, nomor, kartu, lama,...
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, semakin, lama, paket, ditawarkan, semaki...
# ...                                                 ...
# 1995                        [, telkomsel, kapan, min, ]
# 1996  [infoin, tgl, kejadian, lokasi, detail, dan, l...
# 1997  [kenapa, hadiah, daily, check, telkomsel, tida...
# 1998  [hai, kak, noyah, maaf, buat, harga, telkomsel...
# 1999  [haii, selamat, pagii, yang, need, pulsa, cepa...
#
# [1957 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @rdw12_ hai kak. maaf ya, apakah yang dimaksud...
# 1     @telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di hi mr. indra. sorry for the pro...
# 3     ➡️ $zm strong business metrics 💪🏻\n\n- cust &g...
# 4     @telkomsel iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess yg telkomsel kapan min? @siapund...
# 1996  @noyah77106135 infoin no hp, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @noyah77106135 hai, kak noyah. maaf ya. buat h...
# 1999  haii, selamat pagii\nyang need pulsa cepat bis...
#
#                                          cleaning_tweet  \
# 0      hai kak maaf apakah yang dimaksud dengan kart...
# 1     min apa bisa pindahin nomor kartu lama kartu b...
# 2      indra sorry for the problem have you tried re...
# 3      strong business metrics cust arr   cust ttm  ...
# 4     iya semakin lama paket ditawarkan semakin maha...
# ...                                                 ...
# 1995                               telkomsel kapan min
# 1996  infoin tgl kejadian lokasi detail dan lain yan...
# 1997  kenapa hadiah daily check telkomsel tidak bisa...
# 1998  hai kak noyah maaf buat harga telkomsel sudah ...
# 1999  haii selamat pagii yang need pulsa cepat bisa ...
#
#                                              tokenisasi  \
# 0     [, hai, kak, maaf, apakah, yang, dimaksud, den...
# 1     [min, apa, bisa, pindahin, nomor, kartu, lama,...
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, semakin, lama, paket, ditawarkan, semaki...
# ...                                                 ...
# 1995                        [, telkomsel, kapan, min, ]
# 1996  [infoin, tgl, kejadian, lokasi, detail, dan, l...
# 1997  [kenapa, hadiah, daily, check, telkomsel, tida...
# 1998  [hai, kak, noyah, maaf, buat, harga, telkomsel...
# 1999  [haii, selamat, pagii, yang, need, pulsa, cepa...
#
#                                                stopword
# 0     [, hai, kak, maaf, kartu, rusak, diganti, iya,...
# 1                [min, pindahin, nomor, kartu, kartu, ]
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, paket, ditawarkan, mahal, promo, kartu, ...
# ...                                                 ...
# 1995                               [, telkomsel, min, ]
# 1996  [infoin, tgl, kejadian, lokasi, detail, terken...
# 1997         [hadiah, daily, check, telkomsel, diklaim]
# 1998  [hai, kak, noyah, maaf, harga, telkomsel, peny...
# 1999  [haii, selamat, pagii, need, pulsa, cepat, bel...
#
# [1957 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3829
# ------------------------
#  :
# hai : hai
# kak : kak
# maaf : maaf
# kartu : kartu
# rusak : rusak
# diganti : ganti
# iya : iya
# yuk : yuk
# infokan : info
# nama : nama
# via : via
# privasi : privasi
# terjaga : jaga
# tks : tks
# uri : uri
# min : min
# pindahin : pindahin
# nomor : nomor
# indra : indra
# sorry : sorry
# for : for
# the : the
# problem : problem
# have : have
# you : you
# tried : tried
# reinstall : reinstall
# still : still
# same : same
# please : please
# inform : inform
# your : your
# number : number
# phone : phone
# date : date
# incident : incident
# detail : detail
# location : location
# that : that
# privacy : privacy
# maintained : maintained
# and : and
# admin : admin
# checks : checks
# further : further
# strong : strong
# business : business
# metrics : metrics
# cust : cust
# arr : arr
# ttm : ttm
# staff : staff
# nder : nder
# th : th
# quarter : quarter
# new : new
# wins : wins
# nec : nec
# seagate : seagate
# exxonmobil : exxonmobil
# telkomsel : telkomsel
# adds : adds
# upsells : upsells
# apac : apac
# zoom : zoom
# rooms : rooms
# paket : paket
# ditawarkan : tawar
# mahal : mahal
# promo : promo
# sakti : sakti
# multimedia : multimedia
# sinyalnya : sinyal
# hilang : hilang
# sebainya : sebai
# ganti : ganti
# profider : profider
# uda : uda
# gaes : gaes
# beli : beli
# tiket : tiket
# godbless : godbless
# antri : antri
# pas : pas
# kali : kali
# pandemi : pandemi
# gini : gin
# online : online
# klik : klik
# nunggu : nunggu
# konser : konser
# kerj : kerj
# kerjaan : kerja
# rmh : rmh
# jgb : jgb
# lupa : lupa
# follow : follow
# com : com
# yes : yes
# like : like
# this : this
# app : app
# doesnt : doesnt
# work : work
# iphone : iphone
# tbk : tbk
# ily : ily
# logo : logo
# widya : widya
# penawaran : tawar
# ditentukan : tentu
# acak : acak
# sistem : sistem
# menyesuaikan : sesuai
# lokasi : lokasi
# skema : skema
# tarif : tarif
# umur : umur
# penggunaan : guna
# kondisi : kondisi
# khusus : khusus
# semoga : moga
# membantu : bantu
# lin : lin
# menyedihkan : sedih
# berlangganan : langgan
# nomer : nomer
# promonya : promonya
# banget : banget
# murah : murah
# haloo : haloo
# selamat : selamat
# pagi : pagi
# butuh : butuh
# pulsa : pulsa
# cepat : cepat
# yaa : yaa
# fastrespon : fastrespon
# need : need
# jual : jual
# axis : axis
# tri : tri
# smatfren : smatfren
# isat : isat
# indosat : indosat
# tsel : tsel
# wts : wts
# wtb : wtb
# price : price
# drop : drop
# mah : mah
# suka : suka
# boy : boy
# alias : alias
# bucin : bucin
# ice : ice
# cappucino : cappucino
# sajah : sajah
# wilujeng : wilujeng
# sarapan : sarap
# gorengan : goreng
# naskun : naskun
# terkait : kait
# kendala : kendala
# sinyal : sinyal
# coba : coba
# pindahkan : pindah
# mode : mode
# jaringan : jaring
# otomatis : otomatis
# manual : manual
# kembalikan : kembali
# tgl : tgl
# kejadian : jadi
# data : data
# rin : rin
# spay : spay
# gopay : gopay
# non : non
# bca : bca
# convert : convert
# trade : trade
# tukar : tukar
# tuker : tuker
# barter : barter
# three : three
# im : im
# uang : uang
# atm : atm
# bank : bank
# saldo : saldo
# ewallet : ewallet
# qris : qris
# premium : premium
# verif : verif
# ktp : ktp
# plus : plus
# prem : prem
# shopeepay : shopeepay
# shopee : shopee
# dana : dana
# ovo : ovo
# linkaja : linkaja
# preset : preset
# lightroom : lightroom
# cairin : cairin
# paylater : paylater
# dear : dear
# mohon : mohon
# informasi : informasi
# signal : signal
# didaerah : daerah
# jakarta : jakarta
# selatan : selatan
# tepatnya : tepat
# jalan : jalan
# duren : duren
# pancoran : pancoran
# adakah : ada
# solusi : solusi
# pengguna : guna
# thanks : thanks
# internet : internet
# kakak : kakak
# maksud : maksud
# tersedia : sedia
# khawatir : khawatir
# menarik : tarik
# mytelkomsel : mytelkomsel
# makasih : makasih
# kendalanya : kendala
# restart : restart
# clear : clear
# cache : cache
# aplikasinya : aplikasi
# hpnya : hpnya
# esha : esha
# ayu : ayu
# infoin : infoin
# keluhan : keluh
# pertanyaannya : tanya
# mimin : mimin
# cuss : cuss
# lahhh : lahhh
# error : error
# melulu : melulu
# kemaren : kemaren
# ngaruh : ngaruh
# booster : booster
# unlimited : unlimited
# gabisa : gabisa
# isi : isi
# pulsaa : pulsaa
# gangguan : ganggu
# tindak : tindak
# sampe : sampe
# berbulan : bulan
# beneran : beneran
# provider : provider
# kalah : kalah
# vidcon : vidcon
# download : download
# dokumen : dokumen
# lampiran : lampir
# musti : musti
# pinjem : pinjem
# tethering : tethering
# orang : orang
# gimana : gimana
# jujur : jujur
# arya : arya
# ayo : ayo
# lanjutin : lanjutin
# interaksi : interaksi
# berkenan : kenan
# menunggu : tunggu
# pastiin : pastiin
# masuk : masuk
# terlewat : lewat
# tungguin : tungguin
# keterlambatan : lambat
# responnya : responnya
# list : list
# antrian : antri
# dibutuhkan : butuh
# penyenang : senang
# dikasih : kasih
# marah : marah
# pelanggan : langgan
# udah : udah
# lari : lari
# duluan : duluan
# meeting : meeting
# teams : teams
# ngadat : ngadat
# lee : lee
# pilihan : pilih
# combo : combo
# silakan : sila
# bantu : bantu
# cek : cek
# tanggal : tanggal
# chika : chika
# ditunggu : tunggu
# angelyca : angelyca
# perihal : perihal
# lambat : lambat
# refresh : refresh
# off : off
# service : service
# berkendala : kendala
# dicek : cek
# kuota : kuota
# under : under
# apk : apk
# gift : gift
# proses : proses
# full : full
# jam : jam
# bonus : bonus
# disney : disney
# hotstar : hotstar
# omg : omg
# harga : harga
# beda : beda
# tergantung : gantung
# tselnya : tselnya
# zulfikar : zulfikar
# stabil : stabil
# nonton : nonton
# god : god
# bless : bless
# langsung : langsung
# nyangka : nyangka
# konsernya : konser
# walupun : walupun
# virtual : virtual
# menginspirasi : inspirasi
# ketinggalan : tinggal
# grup : grup
# legendaris : legendaris
# tiketnya : tiket
# jugaa : jugaa
# link : link
# dapet : dapet
# sma : sma
# isyana : isyana
# obat : obat
# kangen : kangen
# cus : cus
# lahh : lahh
# teh : teh
# wml : wml
# kangeb : kangeb
# gabut : gabut
# offline : offline
# inject : inject
# gb : gb
# keren : keren
# jadwalkan : jadwal
# jingga : jingga
# ulang : ulang
# agustus : agustus
# mantul : mantul
# hajar : hajar
# hahaha : hahaha
# enak : enak
# rebahan : rebah
# hehhe : hehhe
# kemarin : kemarin
# gue : gue
# simple : simple
# tinggal : tinggal
# dpt : dpt
# dech : dech
# ntn : ntn
# nyantai : nyantai
# rumah : rumah
# minum : minum
# coke : coke
# popcorn : popcorn
# cetarrrr : cetarrrr
# ajaa : ajaa
# kann : kann
# airplane : airplane
# kirim : kirim
# aman : aman
# feeding : feeding
# frenzy : frenzy
# njir : njir
# onie : onie
# habis : habis
# qilla : qilla
# ath : ath
# chiken : chiken
# teu : teu
# boyah : boyah
# santi : santi
# balas : balas
# tunggu : tunggu
# iyoot : iyoot
# rant : rant
# bruh : bruh
# terima : terima
# kode : kode
# verifikasi : verifikasi
# gampang : gampang
# skrg : skrg
# maxstream : maxstream
# kepanasan : panas
# legenda : legenda
# kadinya : kadi
# konsep : konsep
# komedina : komedina
# kiduy : kiduy
# agig : agig
# wkwkwk : wkwkwk
# abi : abi
# sabana : sabana
# doakeun : doakeun
# ceo : ceo
# sing : sing
# miskin : miskin
# galandangan : galandangan
# chicken : chicken
# kuningan : kuningan
# ambas : ambas
# harmoni : harmoni
# email : email
# whatsapp : whatsapp
# jarang : jarang
# mending : mending
# nostalgia : nostalgia
# inimah : inimah
# doi : doi
# seneng : neng
# band : band
# favorit : favorit
# aplikasi : aplikasi
# terbaru : baru
# donlot : donlot
# oke : oke
# ngeselin : ngeselin
# emang : emang
# gapapa : gapapa
# sabar : sabar
# aktivasi : aktivasi
# pastikan : pasti
# update : update
# merk : merk
# type : type
# santaikeun : santaikeun
# sia : sia
# in : in
# auto : auto
# karakter : karakter
# papji : papji
# reiiny : reiiny
# reni : reni
# gagal : gagal
# naon : naon
# maot : maot
# kesel : kesel
# atuda : atuda
# resep : resep
# kopi : kopi
# silentmary : silentmary
# gandeng : gandeng
# goblog : goblog
# rudet : rudet
# siamah : siamah
# aing : aing
# keur : keur
# pabji : pabji
# terpotong : potong
# ozul : ozul
# nyaman : nyaman
# seputar : putar
# produk : produk
# layanan : layan
# waaaah : waaaah
# keknya : kek
# mantap : mantap
# niih : niih
# grub : grub
# lokal : lokal
# tampil : tampil
# code : code
# agung : agung
# sarankan : saran
# lite : lite
# pembelian : beli
# mudah : mudah
# gais : gais
# jagonya : jago
# sedot : sedot
# malam : malam
# sisa : sisa
# ribuan : ribu
# ludes : ludes
# membeli : beli
# sekedar : dar
# menelpon : telpon
# untung : untung
# teman : teman
# sekamar : kamar
# modenah : modenah
# review : review
# bagus : bagus
# ngopi : ngopi
# ieu : ieu
# boyan : boyan
# geura : geura
# meh : meh
# cenghar : cenghar
# asikk : asikk
# kuotanya : kuota
# mantep : mantep
# padeh : padeh
# mon : mon
# kuleh : kuleh
# rb : rb
# sebulen : sebulen
# isuk : isuk
# keneh : keneh
# geus : geus
# nekah : nekah
# sebulan : bulan
# ghi : ghi
# install : install
# ary : ary
# marennah : marennah
# ngangguy : ngangguy
# wifi : wifi
# neng : neng
# roma : roma
# elektrik : elektrik
# nambah : nambah
# mastip : mastip
# all : all
# smartfren : smartfren
# murce : murce
# cepet : cepet
# seller : seller
# galak : galak
# wallet : wallet
# uninstall : uninstall
# pindah : pindah
# wiiih : wiiih
# gassin : gassin
# sobat : sobat
# dolan : dolan
# beuuhhh : beuuhhh
# beliin : beliin
# perangkat : perangkat
# jalankan : jalan
# minimal : minimal
# android : android
# ios : ios
# zabo : zabo
# dibeli : beli
# nikmati : nikmat
# virtualnya : virtual
# mantulll : mantulll
# gillaakkkk : gillaakkkk
# pengen : ken
# wadidaaaw : wadidaaaw
# seriusss : seriusss
# knp : knp
# dipake : dipake
# kena : kena
# prank : prank
# haaaaa : haaaaa
# mauu : mauu
# donk : donk
# konsernyaaaa : konsernyaaaa
# bisikiinnn : bisikiinnn
# bang : bang
# leora : leora
# four : four
# twenty : twenty
# ngisi : ngisi
# seriusan : serius
# sobatt : sobatt
# yaaa : yaaa
# skuy : skuy
# dluu : dluu
# uhuy : uhuy
# bahagia : bahagia
# awokawwok : awokawwok
# bener : bener
# spektakuler : spektakuler
# aaaaaaa : aaaaaaa
# order : order
# aon : aon
# unli : unli
# fup : fup
# mb : mb
# ica : ica
# danilla : danilla
# deh : deh
# lagu : lagu
# duuh : duuh
# nggak : nggak
# dlu : dlu
# ngefans : ngefans
# mangggung : mangggung
# lagii : lagi
# asli : asli
# jann : jann
# wow : wow
# ampun : ampun
# lancar : lancar
# beud : beud
# anti : anti
# alhamdulillah : alhamdulillah
# gas : gas
# tapii : tapi
# aslii : asli
# gua : gua
# duh : duh
# eldhiar : eldhiar
# nyesel : nyesel
# modal : modal
# ribu : ribu
# terpenting : penting
# legend : legend
# deket : deket
# mainnya : main
# cusss : cusss
# guys : guys
# ngadain : ngadain
# daniel : daniel
# puk : puk
# kodenya : kode
# menu : menu
# tertera : tera
# pilih : pilih
# lihat : lihat
# ditampilkan : tampil
# penggemar : gemar
# gass : gass
# pagii : pagi
# group : group
# idola : idola
# terlewatkan : lewat
# konservasi : konservasi
# kulihat : lihat
# batinmu : batin
# terbaik : baik
# lho : lho
# pencinta : cinta
# musik : musik
# rock : rock
# seumuran : umur
# reunian : reuni
# bro : bro
# whattt : whattt
# mauuu : mauuu
# bareng : bareng
# come : come
# brodiesd : brodiesd
# gedubrakan : gedubrakan
# lan : lan
# coy : coy
# aktifasi : aktifasi
# ketik : ketik
# mrlbo : mrlbo
# judul : judul
# jomblo : jomblo
# sejati : sejati
# artist : artist
# material : material
# mari : mari
# yaudah : yaudah
# lauma : lauma
# maklum : maklum
# mgkin : mgkin
# dibilangkan : bilang
# satunya : satu
# negeri : negeri
# swasta : swasta
# penghilang : hilang
# kegabutan : kegabutan
# wlw : wlw
# nontom : nontom
# nyediain : nyediain
# fans : fans
# rindu : rindu
# nyanyi : nyanyi
# hallo : hallo
# halo : halo
# prabayar : prabayar
# tontonan : tonton
# wajib : wajib
# penasaran : penasaran
# liat : liat
# dont : dont
# hesitate : hesitate
# nisya : nisya
# trims : trims
# internetnya : internetnya
# lemot : lot
# tolong : tolong
# diperbaiki : baik
# andra : andra
# imessage : imessage
# ditambah : tambah
# bangun : bangun
# tidur : tidur
# buka : buka
# tergoda : goda
# info : info
# semangat : semangat
# tergokil : tergokil
# milenial : milenial
# jagoin : jagoin
# termahal : mahal
# suara : suara
# beratnya : berat
# gasskeun : gasskeun
# bsa : bsa
# ketemuan : ketemu
# aslian : asli
# pokonya : poko
# welkin : welkin
# mahalan : mahal
# kaya : kaya
# salty : salty
# org : org
# ngeluarulin : ngeluarulin
# game : game
# lol : lol
# kayaknya : kayak
# buruan : buru
# dimari : mari
# mimpi : mimpi
# semalem : semalem
# indonesia : indonesia
# berskala : skala
# ramaikan : ramai
# blum : blum
# nitip : nitip
# disatuin : disatuin
# wahhh : wahhh
# papa : papa
# nihhhh : nihhhh
# dahhh : dahhh
# ntar : ntar
# malem : malem
# diganggu : ganggu
# ikutan : ikut
# wasekkkk : wasekkkk
# roll : roll
# gasss : gasss
# pooll : pooll
# hahaaa : hahaaa
# wahhhh : wahhhh
# sealirann : sealirann
# opa : opa
# kalauu : kalauu
# bakallan : bakallan
# nontonn : nontonn
# pastii : pasti
# pengennya : ken
# saraswati : saraswati
# serius : serius
# nihh : nihh
# kekinian : kini
# live : live
# semut : semut
# hitam : hitam
# dibawain : dibawain
# jan : jan
# lohh : lohh
# wihhhh : wihhhh
# kerennnn : kerennnn
# cuii : cuii
# gila : gila
# nostal : nostal
# giaa : giaa
# zamam : zamam
# kakek : kakek
# personil : personil
# ahmad : ahmad
# albar : albar
# sukses : sukses
# selaluuu : selaluuu
# bingung : bingung
# gmn : gmn
# guee : guee
# belumm : belumm
# lahirr : lahirr
# rame : rame
# acara : acara
# gede : gede
# cekidot : cekidot
# wahh : wahh
# beneeann : beneeann
# manggung : manggung
# fix : fix
# lumayan : lumayan
# nana : nana
# large : large
# account : account
# corp : corp
# largest : largest
# subarti : subarti
# achmad : achmad
# sim : sim
# jaringannya : jaring
# udh : udh
# offkan : offkan
# ttp : ttp
# infonya : info
# buatkan : buat
# pelayanan : layan
# pintu : pintu
# lindungi : lindung
# korban : korban
# pembohongan : bohong
# terbesar : besar
# dunia : dunia
# sapa : sapa
# btw : btw
# wihhh : wihhh
# ntnnya : ntnnya
# murmer : murmer
# ngajakin : ngajakin
# twitter : twitter
# eehhh : eehhh
# nech : nech
# ahhh : ahhh
# ngacung : ngacung
# konseran : konser
# bini : bini
# main : main
# poker : poker
# rekening : rekening
# priaqq : priaqq
# bandapoker : bandapoker
# terpercaya : percaya
# asia : asia
# melayani : layan
# deposit : deposit
# rate : rate
# bersain : bersain
# ligacapsa : ligacapsa
# ligapoker : ligapoker
# nixh : nixh
# kasih : kasih
# abis : abis
# bales : bales
# makasii : makasii
# kehabisan : habis
# penyanyi : nyanyi
# top : top
# sms : sms
# bernostalgia : nostalgia
# garcep : garcep
# bocorin : bocorin
# belinya : beli
# stiusan : stiusan
# dimasa : masa
# tlg : tlg
# pokoknya : pokok
# muda : muda
# pengecekan : kece
# aktif : aktif
# memiliki : milik
# hati : hati
# tulus : tulus
# hidup : hidup
# mulus : mulus
# engga : engga
# dirumah : rumah
# solusinya : solusi
# join : join
# apl : apl
# adminnnnn : adminnnnn
# nemenin : nemenin
# kepoin : poin
# gatau : gatau
# caliphate : caliphate
# ijal : ijal
# gamau : gamau
# nsdbe : nsdbe
# mozzarefa : mozzarefa
# salah : salah
# server : server
# adain : adain
# menit : menit
# muncul : muncul
# bentukan : bentuk
# macem : macem
# mas : mas
# interaksinya : interaksi
# grapari : grapari
# video : video
# dibuka : buka
# tnyt : tnyt
# dibilang : bilang
# aneh : aneh
# dst : dst
# yakena : yakena
# farhan : farhan
# mbuapa : mbuapa
# donkk : donkk
# mami : mami
# kenalan : kenal
# neno : neno
# bilangin : bilangin
# sky : sky
# nanda : nanda
# berinteraksi : interaksi
# pengertiannya : erti
# kei : kei
# kesini : kesini
# gara : gara
# temen : temen
# pgn : pgn
# miminnya : miminnya
# nyuruh : nyuruh
# covid : covid
# beres : beres
# tahan : tahan
# kluar : kluar
# ksh : ksh
# bukti : bukti
# foto : foto
# datanya : data
# sekalinya : sekali
# cuy : cuy
# gaskeun : gaskeun
# oey : oey
# dongs : dongs
# danu : danu
# nmr : nmr
# slipkol : slipkol
# pacar : pacar
# gajelas : gajelas
# depo : depo
# free : free
# daftar : daftar
# xpoker : xpoker
# doang : doang
# mulu : mulu
# sore : sore
# lord : lord
# ditteyya : ditteyya
# jarinfan : jarinfan
# november : november
# melepas : lepas
# besok : besok
# alief : alief
# hmm : hmm
# colek : colek
# seru : seru
# meluncur : luncur
# curhat : curhat
# bund : bund
# putri : putri
# detailnya : detail
# anpras : anpras
# masi : mas
# smapai : smapai
# ngga : ngga
# today : today
# news : news
# highlights : highlights
# revolve : revolve
# around : around
# quota : quota
# even : even
# distribution : distribution
# salak : salak
# export : export
# opportunity : opportunity
# cepa : cepa
# implementation : implementation
# indonesian : indonesian
# telecommunication : telecommunication
# would : would
# support : support
# minist : minist
# fess : fess
# lur : lur
# kemdikbud : kemdikbud
# cair : cair
# tho : tho
# aktifnya : aktif
# diakumulasikan : akumulasi
# berbeda : beda
# maafin : maafin
# mengalami : alami
# penyesuaian : sesuai
# upaya : upaya
# menjaga : jaga
# kualitas : kualitas
# prima : prima
# babi : babi
# ngadet : ngadet
# disedot : sedot
# bajingan : bajing
# bru : bru
# pakainya : pakai
# yahhh : yahhh
# harian : hari
# unlimitednya : unlimitednya
# turun : turun
# yahh : yahh
# kaum : kaum
# ketengan : keteng
# terbatasi : batas
# cant : cant
# wait : wait
# aww : aww
# gaa : gaa
# ihhh : ihhh
# gpp : gpp
# mengobati : obat
# bersahabat : sahabat
# bangett : bangett
# tetep : tetep
# maxtream : maxtream
# yachhh : yachhh
# tenyata : tenyata
# ditunda : tunda
# bazinggg : bazinggg
# orgorg : orgorg
# confess : confess
# selancar : selancar
# tonton : tonton
# speed : speed
# dibandingin : dibandingin
# thailand : thailand
# batu : batu
# orangnya : orang
# kayanya : kaya
# cryptonya : cryptonya
# fredi : fredi
# dmnya : dmnya
# thx : thx
# jno : jno
# allah : allah
# kendaraan : kendara
# mingyu : mingyu
# cakep : cakep
# kontol : kontol
# tweet : tweet
# isinya : isi
# kencang : kencang
# mention : mention
# gambar : gambar
# posting : posting
# bawa : bawa
# sakit : sakit
# ihiyyy : ihiyyy
# dihibur : hibur
# infonyaaa : infonyaaa
# halangan : halang
# loo : loo
# best : best
# dehhh : dehhh
# kpan : kpan
# potongan : potong
# mengirimkan : kirim
# permasalahan : masalah
# dibantu : bantu
# terselesaikan : selesai
# pastinya : pasti
# guyss : guyss
# hiburan : hibur
# jahat : jahat
# senengg : senengg
# poll : poll
# gasabar : gasabar
# nntn : nntn
# berulah : ulah
# unstable : unstable
# akses : akses
# kecepatannya : cepat
# dibatasi : batas
# sesuai : sesuai
# batasan : batas
# bertujuan : tuju
# pengalaman : alam
# mengakses : akses
# payu : payu
# pay : pay
# used : used
# ama : ama
# tembok : tembok
# gedung : gedung
# ckck : ckck
# ben : ben
# buruannn : buruannn
# fair : fair
# usage : usage
# policy : policy
# batas : batas
# pemakaian : pakai
# wajar : wajar
# penerapan : terap
# mencegah : cegah
# aktivitas : aktivitas
# penyalahgunaan : penyalahgunaan
# mengerti : erti
# sylva : sylva
# spam : spam
# blokir : blokir
# lengkap : lengkap
# capture : capture
# alam : alam
# akuu : akuu
# meet : meet
# gegara : gegara
# tergiur : giur
# diadakan : ada
# sekala : sekala
# rangka : rangka
# berita : berita
# hwaa : hwaa
# hapus : hapus
# ganggu : ganggu
# manfaatnya : manfaat
# insomnia : insomnia
# nemu : nemu
# kabar : kabar
# ngobatin : ngobatin
# gasih : gasih
# line : line
# pengisi : isi
# sekeren : keren
# pasar : pasar
# goa : goa
# dipasang : pasang
# telkom : telkom
# indihome : indihome
# kabel : kabel
# laut : laut
# penghubung : hubung
# internasional : internasional
# berkembang : kembang
# iri : iri
# fav : fav
# bokap : bokap
# racunin : racunin
# bsok : bsok
# xixi : xixi
# mengadakan : ada
# ditonton : tonton
# nii : nii
# fyi : fyi
# dijamin : jamin
# gassss : gassss
# luorang : luorang
# netijen : netijen
# ngangur : ngangur
# ajakin : ajakin
# rebu : rebu
# gabakal : gabakal
# dsno : dsno
# nnti : nnti
# danila : danila
# fourtwnty : fourtwnty
# dll : dll
# promotor : promotor
# panggung : panggung
# terharu : haru
# sekian : sekian
# kuy : kuy
# kumpul : kumpul
# kacau : kacau
# sihhh : sihhh
# konsepnya : konsep
# kerjasama : kerjasama
# open : open
# boong : boong
# disitu : situ
# guysss : guysss
# aslikk : aslikk
# cpba : cpba
# miskaaah : miskaaah
# nontonnya : nontonnya
# beuhhh : beuhhh
# gpplah : gpplah
# ngobati : ngobati
# finally : finally
# aaa : aaa
# matinya : mati
# lagunya : lagu
# ngerasa : ngerasa
# diuntungkan : untung
# deeh : deeh
# tiker : tiker
# gratis : gratis
# godblees : godblees
# ksl : ksl
# ngode : ngode
# dibeliin : dibeliin
# wey : wey
# labi : lab
# pubg : pubg
# rto : rto
# gaasss : gaasss
# beuuhh : beuuhh
# gabole : gabole
# otw : otw
# oyie : oyie
# transfer : transfer
# seruu : seruu
# bangettt : bangettt
# awww : awww
# guyyss : guyyss
# tiffany : tiffany
# situ : situ
# sonyeoshidae : sonyeoshidae
# young : young
# papah : papah
# lolik : lolik
# nungguin : nungguin
# konfirmasi : konfirmasi
# nanya : nanya
# regis : regis
# crita : crita
# dengerin : dengerin
# yak : yak
# dimana : mana
# menemukan : temu
# untungnya : untung
# tua : tua
# keladi : keladi
# sihh : sihh
# woee : woee
# siii : siii
# woilaaahhh : woilaaahhh
# kebaca : baca
# kaann : kaann
# cantik : cantik
# diapun : dia
# body : body
# asik : asik
# dada : dada
# deg : deg
# mulut : mulut
# lelaki : lelaki
# gadis : gadis
# remaja : remaja
# aaaa : aaaa
# spechlees : spechlees
# semurah : murah
# dapetin : dapetin
# nilai : nilai
# sumpah : sumpah
# terbek : bek
# jaman : jaman
# komen : komen
# ntflx : ntflx
# bayar : bayar
# indo : indo
# langganan : langgan
# bbrp : bbrp
# antrean : antre
# sembako : sembako
# bansos : bansos
# anang : anang
# hangus : hangus
# tenggang : tenggang
# reaktivasi : reaktivasi
# max : max
# terhapus : hapus
# customer : customer
# tipikal : tipikal
# ngebit : ngebit
# gitu : gitu
# flyer : flyer
# excited : excited
# kisanak : kisanak
# hayuk : hayuk
# cari : cari
# streaming : streaming
# sarua : sarua
# jiga : jiga
# ayah : ayah
# hanif : hanif
# kim : kim
# kek : kek
# astaga : astaga
# mati : mati
# aktifkan : aktif
# solanya : solanya
# login : login
# google : google
# password : password
# melek : melek
# ginian : ginian
# operator : operator
# seluler : seluler
# anak : anak
# usaha : usaha
# bumn : bumn
# telekomunikasi : telekomunikasi
# mendukung : dukung
# kementerian : menteri
# pendidikan : didik
# kebudayaan : budaya
# riset : riset
# teknologi : teknologi
# penyaluran : salur
# bantuan : bantu
# pelajar : ajar
# tenaga : tenaga
# pengajar : ajar
# huhuhu : huhuhu
# seminggu : minggu
# project : project
# pop : pop
# ultah : ultah
# ceritain : ceritain
# nge : nge
# gmail : gmail
# revovery : revovery
# recovery : recovery
# malang : malang
# sby : sby
# team : team
# monopoli : monopoli
# boos : boos
# sebgaian : sebgaian
# istilahnya : istilah
# induknya : induk
# satelit : satelit
# utama : utama
# fiber : fiber
# optik : optik
# sewa : sewa
# gokiiil : gokiiil
# mbanking : mbanking
# duluu : duluu
# aduh : aduh
# alyu : alyu
# yaah : yaah
# ngerti : ngerti
# ampe : ampe
# jamin : jamin
# agent : agent
# laah : laah
# murahh : murahh
# kuylah : kuylah
# nich : nich
# noh : noh
# paketnya : paket
# sekelas : kelas
# disinj : disinj
# maeeeen : maeeeen
# gengs : gengs
# keabisan : abis
# ehh : ehh
# saksikan : saksi
# awas : awas
# ultahnya : ultahnya
# daerah : daerah
# rungkut : rungkut
# lor : lor
# surabaya : surabaya
# perasaan : asa
# caur : caur
# kenceng : kenceng
# kgen : kgen
# kesengsem : kesengsem
# milan : mil
# bantuin : bantuin
# belom : bom
# tenang : tenang
# akun : akun
# tulong : tulong
# plis : plis
# wuih : wuih
# lewatkan : lewat
# keseruannya : seru
# serbu : serbu
# asyik : asyik
# mumpung : mumpung
# disni : disni
# pgen : pgen
# aada : aada
# kah : kah
# rere : rere
# widihhhh : widihhhh
# bertajuk : tajuk
# apresiasi : apresiasi
# perjalanan : jalan
# karir : karir
# lgi : lgi
# dsini : dsini
# khoiri : khoiri
# kepotong : potong
# hostar : hostar
# menngunakan : menngunakan
# thks : thks
# unlimitedmax : unlimitedmax
# diilangin : diilangin
# ngitung : ngitung
# nyiapinn : nyiapinn
# gaada : gaada
# bosen : bosen
# hhhhu : hhhhu
# catet : catet
# tanggalnya : tanggal
# gaesss : gaesss
# cocok : cocok
# atur : atur
# hostspot : hostspot
# membalas : balas
# nominal : nominal
# biaya : biaya
# intan : intan
# menerima : terima
# collection : collection
# ditanggung : tanggung
# tujuan : tuju
# alvin : alvin
# lemah : lemah
# bermasalah : masalah
# daeraj : daeraj
# ngadad : ngadad
# call : call
# center : center
# bayu : bayu
# menghubungi : hubung
# rekan : rekan
# facebook : facebook
# koin : koin
# makannyaa : makannyaa
# minat : minat
# manjangin : manjangin
# berlakunya : laku
# giveaway : giveaway
# wish : wish
# luck : luck
# terombang : terombang
# ambing : ambing
# harapan : harap
# perbaikannya : baik
# bandar : bandar
# lampung : lampung
# nonaktifkan : nonaktif
# berkala : kala
# yosenju : yosenju
# suram : suram
# nyalain : nyalain
# hotspot : hotspot
# netflix : netflix
# maju : maju
# kirain : kirain
# kacrut : kacrut
# taunya : tau
# aowkakak : aowkakak
# suruh : suruh
# kecepatan : cepat
# orgil : orgil
# nyedot : nyedot
# ngomong : ngomong
# sedetik : detik
# lgsg : lgsg
# kesedotnya : sedot
# makasi : makas
# oiya : oiya
# lali : lali
# crisgo : crisgo
# elloco : elloco
# trs : trs
# mahyadi : mahyadi
# pangabean : pangabean
# kbar : kbar
# lucky : lucky
# feedback : feedback
# bersifat : sifat
# saranin : saranin
# dial : dial
# ella : ella
# melody : melody
# nabilla : nabilla
# goodbles : goodbles
# marcio : marcio
# sembiring : sembiring
# persisam : persisam
# dmn : dmn
# tag : tag
# noticc : noticc
# jotic : jotic
# nurunin : nurunin
# setia : setia
# kampung : kampung
# beliau : beliau
# smoga : smoga
# membawakan : bawa
# hits : hits
# andalannya : andal
# heavy : heavy
# rotation : rotation
# user : user
# teruntuk : untuk
# pemilik : milik
# perusahaan : usaha
# kampungan : kampung
# desaan : desa
# tingkatkan : tingkat
# sedih : sedih
# hape : hape
# butut : butut
# luplep : luplep
# menangis : menang
# bertegur : tegur
# dikala : kala
# magrib : magrib
# danilo : danilo
# fernando : fernando
# temennya : temennya
# souza : souza
# ronal : ronal
# fagundez : fagundez
# kbarnya : kbarnya
# shat : shat
# mdrid : mdrid
# will : will
# wandys : wandys
# bersedia : sedia
# kusnandhar : kusnandhar
# bwt : bwt
# nyambung : nyambung
# akir : akir
# bln : bln
# tewas : tewas
# paketan : paket
# rp : rp
# dibebankan : beban
# setuju : tuju
# permintaan : minta
# tsb : tsb
# gmau : gmau
# persik : persik
# nton : nton
# blm : blm
# kesampean : sampean
# tbatiba : tbatiba
# dikabarin : dikabarin
# kmu : kmu
# bsk : bsk
# ckup : ckup
# lwt : lwt
# lbih : lbih
# balasan : balas
# terkadang : terkadang
# kecewa : kecewa
# lemotnya : lot
# menjangkau : jangkau
# sanggup : sanggup
# berpaling : paling
# helour : helour
# ghostingin : ghostingin
# ngajak : ngajak
# gelud : gelud
# titipin : titipin
# nggakpapa : nggakpapa
# punyaku : punya
# selesai : selesai
# vote : vote
# proof : proof
# beih : beih
# perhatiin : perhatiin
# jelek : jelek
# bat : bat
# upgrade : upgrade
# speedy : speedy
# koneksinya : koneksi
# aje : aje
# router : router
# reset : reset
# gantinsetingan : gantinsetingan
# koneksi : koneksi
# budi : budi
# eko : eko
# cebong : cebong
# anjing : anjing
# kadrun : kadrun
# sehari : hari
# brp : brp
# siih : siih
# kencing : kencing
# unta : unta
# begonya : bego
# note : note
# keras : keras
# mulia : mulia
# drpd : drpd
# parah : parah
# berulang : ulang
# area : area
# kalteng : kalteng
# ancur : ancur
# telkomnet : telkomnet
# instant : instant
# gadue : gadue
# hubungi : hubung
# apapun : apa
# konsumsi : konsumsi
# goceng : goceng
# kenapasi : napas
# effort : effort
# hasil : hasil
# kerja : kerja
# gapantes : gapantes
# perjuangin : perjuangin
# chill : chill
# trusted : trusted
# bolehh : bolehh
# fast : fast
# respon : respon
# lkomsel : lkomsel
# berkurang : kurang
# registrasi : registrasi
# reg : reg
# spasi : spasi
# nik : nik
# berupaya : upaya
# maksimal : maksimal
# memuaskan : muas
# harapannya : harap
# terealisasikan : realisasi
# sial : sial
# jaringanku : jaring
# rumahku : rumah
# lionsgate : lionsgate
# play : play
# filmnya : film
# berhenti : henti
# oyeeek : oyeeek
# mabok : mabok
# kadang : kadang
# koyo : koyo
# taekkk : taekkk
# sinyale : sinyale
# cuk : cuk
# eror : eror
# maafkan : maaf
# fahmy : fahmy
# harryanto : harryanto
# ceria : ceria
# terpakai : pakai
# reguler : reguler
# diaktifkan : aktif
# simpati : simpati
# tanggapanya : tanggapanya
# kinerja : kerja
# yzz : yzz
# firhan : firhan
# emosi : emosi
# dips : dips
# pesan : pesan
# daftarin : daftarin
# dapodik : dapodik
# gmna : gmna
# thankss : thankss
# feronita : feronita
# feedbacknya : feedbacknya
# nuker : nuker
# testi : testi
# pinned : pinned
# prosesnya : proses
# tele : tele
# gabriel : gabriel
# bentar : bentar
# pakai : pakai
# segini : gin
# lier : lier
# lieeeer : lieeeer
# moving : moving
# keliatan : liat
# profesional : profesional
# sigap : sigap
# pelanggannya : langgan
# pantes : pantes
# unggul : unggul
# penggunanya : guna
# ngisiin : ngisiin
# serumah : rumah
# pdhl : pdhl
# yaampun : yaampun
# nasib : nasib
# gadiisi : gadiisi
# meninggoy : meninggoy
# amazon : amazon
# prime : prime
# sempet : sempet
# setop : setop
# ide : ide
# sektor : sektor
# periklanan : iklan
# digital : digital
# ajang : ajang
# digihackaction : digihackaction
# otp : otp
# repot : repot
# dikit : dikit
# bejo : bejo
# vocer : vocer
# rebutan : rebut
# ditengah : tengah
# eog : eog
# efek : efek
# gratisan : gratis
# baskara : baskara
# tbtb : tbtb
# pnh : pnh
# susah : susah
# verificatiom : verificatiom
# step : step
# because : because
# jimin : jimin
# owe : owe
# want : want
# watch : watch
# but : but
# don : don
# twt : twt
# bighit : bighit
# tpi : tpi
# sie : sie
# sultan : sultan
# awikwok : awikwok
# pemerasan : peras
# kabur : kabur
# arey : arey
# anjirr : anjirr
# ditag : ditag
# desember : desember
# dicancel : dicancel
# diterusin : diterusin
# ambil : ambil
# thank : thank
# dicky : dicky
# orbit : orbit
# restat : restat
# berkali : kali
# langkah : langkah
# fikri : fikri
# putar : putar
# aktifin : aktifin
# minggu : minggu
# kepake : kepake
# dibalas : balas
# antrianya : antrianya
# muluu : muluu
# kirimkan : kirim
# howalah : howalah
# gustiii : gustiii
# pisan : pis
# sambat : sambat
# menungso : menungso
# dudu : dudu
# malaikat : malaikat
# toko : toko
# sebelah : belah
# berhasil : hasil
# juara : juara
# program : program
# senang : senang
# sungkan : sungkan
# sehat : sehat
# jpg : jpg
# keysha : keysha
# hakiki : hakiki
# mia : mia
# uki : uki
# lahir : lahir
# terimakasih : terimakasih
# alamat : alamat
# kecamatan : camat
# kota : kota
# keterangan : terang
# regista : regista
# mengikuti : ikut
# mengaktifkan : aktif
# lahirkan : lahir
# eunhwimnida : eunhwimnida
# sel : sel
# vidio : vidio
# viu : viu
# banyaknya : banyak
# kau : kau
# sakiti : sakit
# arief : arief
# penayangan : tayang
# liga : liga
# italy : italy
# menikmati : nikmat
# tayangan : tayang
# tiktok : tiktok
# genflix : genflix
# hbo : hbo
# iflix : iflix
# rcti : rcti
# sushiroll : sushiroll
# useetv : useetv
# home : home
# peduli : peduli
# care : care
# share : share
# topup : topup
# masukan : masuk
# wlcm : wlcm
# fauzi : fauzi
# telepon : telepon
# bahasa : bahasa
# inggris : inggris
# opsi : opsi
# pemblokiran : blokir
# mila : mila
# eek : eek
# sebel : sebel
# mohond : mohond
# lanjuti : lanjut
# nugas : nugas
# kehalang : halang
# terpilih : pilih
# pascabayar : pascabayar
# ato : ato
# nerima : nerima
# banking : banking
# emng : emng
# gtu : gtu
# bnking : bnking
# ngapa : ngapa
# ming : ming
# met : met
# mumet : mumet
# marakke : marakke
# okay : okay
# selulernya : seluler
# vpn : vpn
# negara : negara
# sadekah : sadekah
# aghi : aghi
# kule : kule
# fakir : fakir
# kaget : kaget
# leletnya : lelet
# putus : putus
# samsek : samsek
# dapetnya : dapetnya
# woyyy : woyyy
# wina : wina
# nayangin : nayangin
# itali : itali
# buset : buset
# wkwkw : wkwkw
# bodo : bodo
# winto : winto
# terhubung : hubung
# lamban : lamban
# alter : alter
# ego : ego
# penanganannya : tangan
# tagihan : tagih
# sunu : sunu
# memposting : memposting
# pribadi : pribadi
# menghindari : hindar
# bertanggung : tanggung
# byu : byu
# blok : blok
# urusan : urus
# kartuhalo : kartuhalo
# statusnya : status
# heh : heh
# karepmu : karepmu
# piye : piye
# ilang : ilang
# kon : kon
# sek : sek
# model : model
# meneh : teh
# nek : nek
# ngeneki : ngeneki
# dihubungi : hubung
# tim : tim
# teknis : teknis
# eka : eka
# popup : popup
# promosi : promosi
# kedepannya : depan
# jaya : jaya
# maksudnya : maksud
# maksimum : maksimum
# prioritas : prioritas
# feliana : feliana
# menanggapi : tanggap
# isiin : isiin
# timbul : timbul
# jodoh : jodoh
# mencoba : coba
# saran : saran
# umumkan : umum
# hadirkan : hadir
# izin : izin
# lapor : lapor
# grand : grand
# cinunuk : cinunuk
# kab : kab
# bandung : bandung
# diperkuat : kuat
# drtd : drtd
# make : make
# noservice : noservice
# smua : smua
# nyoba : nyoba
# heran : heran
# suryaqq : suryaqq
# cashback : cashback
# referral : referral
# rendah : rendah
# tdi : tdi
# bri : bri
# notif : notif
# menerangkan : terang
# nasabah : nasabah
# mengatasinya : atas
# diena : diena
# anin : anin
# surprisedeal : surprisedeal
# periodenya : periode
# nantikan : nanti
# lanjutan : lanjut
# huhu : huhu
# nelfon : nelfon
# nomornya : nomor
# hadeh : hadeh
# riyan : riyan
# berubah : ubah
# menambah : tambah
# pembayaran : bayar
# pemesanan : mesan
# mingguan : minggu
# bulanan : bulan
# diana : ana
# sampah : sampah
# tanggungjawabmu : tanggungjawabmu
# menyebabkan : sebab
# informasinya : informasi
# akurat : akurat
# blom : blom
# pembukaan : buka
# smooa : smooa
# apalah : apa
# mhn : mhn
# belah : belah
# krna : krna
# memerintahkan : perintah
# deaktif : deaktif
# eyyoo : eyyoo
# what : what
# happen : happen
# haiyaa : haiyaa
# erick : erick
# terdaftar : daftar
# asyuuuu : asyuuuu
# payment : payment
# ket : ket
# nurul : nurul
# dicoba : coba
# check : check
# dipakai : pakai
# dijaringan : jaring
# sadry : sadry
# laiya : laiya
# dijawa : dijawa
# berkelok : kelok
# ecek : ecek
# lanjutkan : lanjut
# menyertakan : serta
# temukan : temu
# ohh : ohh
# mbaknya : mbak
# mbak : mbak
# dikonter : konter
# loops : loops
# laket : laket
# heeyy : heeyy
# gada : gada
# feny : feny
# wib : wib
# nawarin : nawarin
# pinjaman : pinjam
# gadai : gadai
# bpkb : bpkb
# ngasih : ngasih
# hadiah : hadiah
# nagih : nagih
# kontrakan : kontra
# pura : pura
# ngeri : ngeri
# potongannya : potong
# ajg : ajg
# altair : altair
# flores : flores
# jawa : jawa
# real : real
# gunain : gunain
# digunain : digunain
# pliss : pliss
# helpp : helpp
# giganya : giganya
# zonk : zonk
# plat : plat
# merah : merah
# bli : bli
# anjinggg : anjinggg
# dzikri : dzikri
# worth : worth
# bedanya : beda
# nazar : nazar
# ketidaksesuaian : ketidaksesuaian
# jenis : jenis
# sindu : sindu
# instagram : instagram
# jatuh : jatuh
# tempo : tempo
# dipaketin : dipaketin
# mbb : mbb
# dibikinin : dibikinin
# nomerku : nomerku
# abror : abror
# ecky : ecky
# awwkwkwk : awwkwkwk
# ngakak : ngakak
# lmao : lmao
# nyadar : nyadar
# haii : hai
# youtube : youtube
# family : family
# plan : plan
# individual : individual
# belajar : ajar
# tugas : tugas
# kelar : kelar
# presentasi : presentasi
# bos : bos
# praktis : praktis
# kebutuhan : butuh
# mindahin : mindahin
# gardu : gardu
# kamar : kamar
# pinggir : pinggir
# lemari : lemari
# gantungan : gantung
# viol : viol
# vio : vio
# capek : capek
# baca : baca
# dmku : dmku
# miiin : miiin
# makasiii : makasiii
# maulana : maulana
# direspon : direspon
# minn : minn
# semangatt : semangatt
# too : too
# zee : zee
# macan : macan
# kos : kos
# emosiii : emosiii
# transaksi : transaksi
# udahan : udahan
# nayaa : nayaa
# kuis : kuis
# menulis : tulis
# wall : wall
# fanpage : fanpage
# namjoon : namjoon
# fiks : fiks
# bay : bay
# aulielv : aulielv
# kumbakarna : kumbakarna
# daisy : daisy
# done : done
# ntang : ntang
# ngelag : ngelag
# gausa : gausa
# dibales : dibales
# tower : tower
# legal : legal
# discount : discount
# loop : loop
# alah : alah
# jorgi : jorgi
# risha : risha
# panggilannya : panggil
# kayak : kayak
# zio : zio
# ara : ara
# sibuk : sibuk
# tutup : tutup
# akunnya : akun
# syfa : syfa
# yusran : yusran
# bahagianya : bahagia
# memakai : pakai
# mencari : cari
# nafkah : nafkah
# tinggalmenunggu : tinggalmenunggu
# harinya : hari
# rezeki : rezeki
# dadakan : dada
# bernilai : nila
# ratusan : ratus
# juta : juta
# rupiah : rupiah
# nikmat : nikmat
# dustai : dusta
# okki : okki
# sayangnya : sayang
# kyk : kyk
# kasta : kasta
# abs : abs
# pesawat : pesawat
# gbsa : gbsa
# out : out
# brilianta : brilianta
# peng : peng
# pitu : pitu
# jane : jane
# pingin : pingin
# sugiih : sugiih
# ora : ora
# sungjin : sungjin
# merugikan : rugi
# gunanya : guna
# penjelasan : jelas
# estimasi : estimasi
# sulaiman : sulaiman
# pangesti : pangesti
# anggit : anggit
# tara : tara
# bete : bete
# ntr : ntr
# peningkatan : tingkat
# biasalah : biasa
# marketing : marketing
# melanjutkan : lanjut
# mengecewakan : kecewa
# koneki : koneki
# paraaaaah : paraaaaah
# shifly : shifly
# adniaz : adniaz
# pendaftaran : daftar
# agen : agen
# kotamu : kota
# aru : aru
# semuaa : semuaa
# malesin : malesin
# dirumahku : rumah
# thnaks : thnaks
# tang : tang
# andik : andik
# muat : muat
# kartunya : kartu
# took : took
# gold : gold
# industry : industry
# transformation : transformation
# category : category
# learn : learn
# made : made
# disruptor : disruptor
# stand : stand
# our : our
# judges : judges
# kasihhh : kasihhh
# berguna : guna
# hujan : hujan
# pakek : pakek
# orangtua : orangtua
# siswa : siswa
# keluhkan : keluh
# kesulitan : sulit
# pelajaran : ajar
# daring : daring
# laman : laman
# riau : riau
# males : males
# gile : gile
# tumben : tumben
# vlive : vlive
# bangga : bangga
# tlkm : tlkm
# rincian : rincian
# subsidi : subsidi
# kemendikbud : kemendikbud
# disalurkan : salur
# september : september
# voucher : voucher
# ghia : ghia
# dunk : dunk
# ikutaaaan : ikutaaaan
# gaezz : gaezz
# abg : abg
# fei : fei
# skrng : skrng
# gakuat : gakuat
# wkwkwkwk : wkwkwkwk
# ngebuang : ngebuang
# okayy : okayy
# mba : mba
# lala : lala
# pencerahannya : cerah
# mahall : mahall
# wasaf : wasaf
# diisi : isi
# ehehehehhehehehe : ehehehehhehehehe
# cuman : cuman
# ngambekan : ngambekan
# ngegame : ngegame
# terhambat : hambat
# nagapain : nagapain
# eyy : eyy
# penerima : terima
# manfaat : manfaat
# terverifikasi : verifikasi
# kouta : kouta
# ketersediaan : sedia
# apps : apps
# ngertiin : ngertiin
# ekstra : ekstra
# ila : ila
# mandiri : mandiri
# loading : loading
# dataku : data
# luas : luas
# bla : bla
# solo : solo
# disuruh : suruh
# laporan : lapor
# hrs : hrs
# dateng : dateng
# kecuali : kecuali
# mobile : mobile
# mayza : mayza
# kenalnya : kenal
# agus : agus
# terkahir : terkahir
# kucing : kucing
# kelakuan : laku
# reuse : reuse
# chat : chat
# gaje : gaje
# cefattt : cefattt
# suamiku : suami
# adminnya : adminnya
# rama : rama
# membanting : banting
# anjrit : anjrit
# ndut : ndut
# bagas : bagas
# syarif : syarif
# sabulen : sabulen
# kadheng : kadheng
# eabhik : eabhik
# peketan : ketan
# bein : bein
# sosmed : sosmed
# peserta : serta
# pemenang : menang
# berinovasi : inovasi
# kemajuan : maju
# adtech : adtech
# martech : martech
# arie : arie
# hot : hot
# rod : rod
# nyampe : nyampe
# printer : printer
# saranghae : saranghae
# park : park
# seonghwa : seonghwa
# brand : brand
# ambassador : ambassador
# tuku : tuku
# kanca : kanca
# tirta : tirta
# ditanyain : ditanyain
# cmn : cmn
# sblm : sblm
# anggaran : anggar
# juarang : juarang
# hancur : hancur
# dompet : dompet
# lowongan : lowong
# kabarin : kabarin
# sepertiga : tiga
# mksh : mksh
# mampuku : mampu
# trus : trus
# cpt : cpt
# sii : sii
# njingg : njingg
# ping : ping
# merahmu : merah
# merugikanku : rugi
# nyalakan : nyala
# nyambungnya : nyambungnya
# tetiba : tetiba
# dikabari : kabar
# inet : inet
# anjirla : anjirla
# diharapkan : harap
# sindir : sindir
# langsuuung : langsuuung
# jebakan : jebak
# betmen : betmen
# hazel : hazel
# randi : randi
# telpon : telpon
# tempt : tempt
# diterima : terima
# semarang : semarang
# kendal : kendal
# apilikasinya : apilikasinya
# cepetan : cepetan
# tether : tether
# indigo : indigo
# plsss : plsss
# pls : pls
# society : society
# siang : siang
# ngalahin : ngalahin
# custumer : custumer
# servicenya : servicenya
# thankyou : thankyou
# bantuanya : bantuanya
# sumpa : sumpa
# yey : yey
# cii : cii
# sialan : sial
# ditny : ditny
# seakan : akan
# memisahkn : memisahkn
# orbitnya : orbit
# csnya : csnya
# gubris : gubris
# brtanya : brtanya
# menkominfo : menkominfo
# busuk : busuk
# ngak : ngak
# rea : rea
# beremma : beremma
# asek : asek
# buru : buru
# dewi : dewi
# sari : sari
# ditipu : tipu
# jahahahaha : jahahahaha
# paham : paham
# yha : yha
# korporat : korporat
# kantor : kantor
# nyepam : nyepam
# debt : debt
# collector : collector
# pinjol : pinjol
# complain : complain
# modem : modem
# harganya : harga
# terjangkau : jangkau
# terpenuhi : penuh
# nguras : nguras
# kantong : kantong
# kaleng : kaleng
# ohiya : ohiya
# pakenya : pakenya
# pke : pke
# tlkmsel : tlkmsel
# yeni : yen
# protes : protes
# akibat : akibat
# lelet : lelet
# mubazir : mubazir
# mestinya : mesti
# diperpanjang : panjang
# kesalahan : salah
# terdepan : depan
# partisipasi : partisipasi
# kemendikbudristek : kemendikbudristek
# nyata : nyata
# perubahan : ubah
# perilaku : perilaku
# masyarakat : masyarakat
# beradaptasi : adaptasi
# kebiasaan : biasa
# memudahkan : mudah
# broadband : broadband
# berteknologi : teknologi
# cakupan : cakup
# merata : rata
# pelosok : pelosok
# kenyamanan : nyaman
# mengajar : ajar
# jarak : jarak
# pemerintah : perintah
# republik : republik
# periode : periode
# caca : caca
# kenny : kenny
# parluasan : parluasan
# kec : kec
# sidikalang : sidikalang
# dairi : dairi
# peristiwa : peristiwa
# ditinjau : tinjau
# veronika : veronika
# curtomer : curtomer
# ngebantuu : ngebantuu
# keburu : keburu
# okkkk : okkkk
# mkasi : mkasi
# digaji : gaji
# mek : mek
# plisss : plisss
# lisa : lisa
# kece : kece
# gajian : gaji
# outfitnya : outfitnya
# games : games
# monstore : monstore
# apparel : apparel
# shirt : shirt
# hoodie : hoodie
# masker : masker
# diskon : diskon
# anjj : anjj
# maen : maen
# didaprt : didaprt
# jdi : jdi
# jatuhnya : jatuh
# ampas : ampas
# lte : lte
# maunya : mau
# semuaaa : semuaaa
# bik : bik
# bim : bim
# ttl : ttl
# lgsng : lgsng
# shope : shope
# later : later
# memblokir : blokir
# nonya : nonya
# mengembalikan : kembali
# pesanan : pesan
# dibatalkan : batal
# kui : kui
# murahmennnn : murahmennnn
# sengkok : sengkok
# pinda : pinda
# ebuh : ebuh
# kle : kle
# rekomendasi : rekomendasi
# kesebar : sebar
# breach : breach
# bisanya : bisa
# dikontak : kontak
# dikenal : kenal
# pasca : pasca
# bintaro : bintaro
# pung : pung
# xchange : xchange
# alhamdulilah : alhamdulilah
# berkah : berkah
# maaciw : maaciw
# huha : huha
# nepatin : nepatin
# janji : janji
# junpii : junpii
# insta : insta
# moots : moots
# only : only
# rules : rules
# end : end
# wita : wita
# wit : wit
# announce : announce
# yosh : yosh
# budiono : budiono
# tote : tote
# darurat : darurat
# giga : giga
# suryandar : suryandar
# bango : bango
# padat : padat
# ketarik : tarik
# berkomitmen : komitmen
# menerapkan : terap
# standar : standar
# operasional : operasional
# penanganan : tangan
# perlindungan : lindung
# kerahasiaan : rahasia
# ragam : ragam
# lambatt : lambatt
# jowo : jowo
# yas : yas
# berstatus : status
# bangkrut : bangkrut
# banting : banting
# gugling : gugling
# atalatalan : atalatalan
# pessenahh : pessenahh
# duhhh : duhhh
# agellek : agellek
# ngkoookkkkk : ngkoookkkkk
# ditransfer : transfer
# ditelfon : ditelfon
# terluvv : terluvv
# setahun : tahun
# diprioritaskan : prioritas
# eksklusif : eksklusif
# tukang : tukang
# tipu : tipu
# penipuan : tipu
# sekelangkong : langkong
# pesse : pesse
# gebey : gebey
# melleh : melleh
# berres : berres
# bhik : bhik
# jukok : jukok
# tempe : tempe
# ttd : ttd
# konsumenmu : konsumen
# ataltalan : ataltalan
# pessenah : pessenah
# sosialisasi : sosialisasi
# mika : mika
# inisialnya : inisial
# dialami : alami
# kejadiannya : jadi
# triadi : triadi
# total : total
# point : point
# ane : ane
# minimarket : minimarket
# claim : claim
# wadidaw : wadidaw
# dikirim : kirim
# permasalahannya : masalah
# tech : tech
# titans : titans
# perkuat : kuat
# kompetensi : kompetensi
# era : era
# bangke : bangke
# tlpn : tlpn
# mengaku : aku
# bilangnya : bilang
# docmart : docmart
# converse : converse
# sweater : sweater
# kitkat : kitkat
# greentea : greentea
# balance : balance
# tongsis : tongsis
# fisheye : fisheye
# latte : latte
# soree : soree
# migrasi : migrasi
# card : card
# ngab : ngab
# tnyain : tnyain
# gaji : gaji
# seseorg : seseorg
# tanyain : tanyain
# duit : duit
# cici : cici
# asub : asub
# kurir : kurir
# sya : sya
# ala : ala
# bacot : bacot
# giliran : gilir
# official : official
# store : store
# tokopedia : tokopedia
# senilai : nila
# favoritmu : favorit
# lupit : lupit
# sandi : sandi
# oknum : oknum
# gabertanggung : gabertanggung
# versi : versi
# playstore : playstore
# reva : reva
# ketagihan : tagih
# life : life
# after : after
# credit : credit
# redeem : redeem
# skill : skill
# dollar : dollar
# panggilan : panggil
# benerin : benerin
# gwe : gwe
# ms : ms
# gunung : gunung
# daftarkan : daftar
# diproses : proses
# selasa : selasa
# kiriman : kirim
# listnya : listnya
# maximalkan : maximalkan
# toling : toling
# ngecek : ngecek
# ngeluh : ngeluh
# komputer : komputer
# tolol : tolol
# apn : apn
# elu : elu
# interkasinya : interkasinya
# christina : christina
# iklan : iklan
# chloe : chloe
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# verivery : verivery
# diblok : blok
# serial : serial
# bebas : bebas
# redhattelco : redhattelco
# webinar : webinar
# answer : answer
# key : key
# questions : questions
# how : how
# operators : operators
# are : are
# building : building
# edge : edge
# much : much
# their : their
# infrastructure : infrastructure
# provided : provided
# sign : sign
# now : now
# potong : potong
# internetan : internetan
# hapene : hapene
# tok : tok
# ijih : ijih
# ono : ono
# mbah : mbah
# jaluk : jaluk
# pulsane : pulsane
# wae : wae
# sistemnya : sistem
# smf : smf
# alfri : alfri
# ahsan : ahsan
# pengirim : kirim
# kelengkapan : lengkap
# icha : icha
# siska : siska
# lakukan : laku
# emg : emg
# gmnsi : gmnsi
# shanum : shanum
# syifauddin : syifauddin
# metode : metode
# shoppe : shoppe
# segeraaa : segeraaa
# dianggurin : dianggurin
# egh : egh
# lbh : lbh
# loe : loe
# retweet : retweet
# susi : sus
# aleah : aleah
# akuin : akuin
# tersebar : sebar
# menurunkan : turun
# mengganggu : ganggu
# penipu : tipu
# nomernya : nomernya
# nggrundel : nggrundel
# perkara : perkara
# ditanggepin : ditanggepin
# dikurangin : rangin
# kagak : kagak
# nie : nie
# sabi : sabi
# manies : manies
# kelko : kelko
# katain : katain
# mulung : mulung
# adek : adek
# tersesat : sesat
# tolonng : tolonng
# yank : yank
# bet : bet
# sebulannya : bulan
# absen : absen
# mark : mark
# maghrib : maghrib
# hahahaa : hahahaa
# becanda : becanda
# appnya : appnya
# kurangin : rangin
# tana : tana
# gws : gws
# bntr : bntr
# loc : loc
# emot : emot
# klinci : klinci
# jian : jian
# woahh : woahh
# demen : demen
# napa : napa
# slow : slow
# teriak : teriak
# diinfo : info
# barusan : barusan
# urgent : urgent
# refund : refund
# terakumulasi : akumulasi
# masuknya : masuk
# jordy : jordy
# persen : persen
# shayaang : shayaang
# perpanjang : panjang
# trf : trf
# token : token
# pln : pln
# adaa : adaa
# sinii : sini
# ketidaknyamanannya : ketidaknyamanannya
# kesediaannya : sedia
# belanja : belanja
# hemat : hemat
# daur : daur
# sulit : sulit
# digit : digit
# terpantau : pantau
# keikut : ikut
# unlimeted : unlimeted
# rizkilucky : rizkilucky
# yudhi : yudhi
# traffic : traffic
# dimaklum : maklum
# didaur : daur
# berasa : asa
# kecewanya : kecewa
# bela : bela
# berlaku : laku
# pkl : pkl
# status : status
# hub : hub
# finnet : finnet
# respons : respons
# ngelama : ngelama
# senin : senin
# askrl : askrl
# karna : karna
# kontak : kontak
# bisnis : bisnis
# myorbit : myorbit
# detik : detik
# secepatnya : cepat
# terhormat : hormat
# pengisian : isi
# kunjung : kunjung
# siapin : siapin
# dukung : dukung
# keperluan : perlu
# wfh : wfh
# kartumu : kartu
# beragam : agam
# pembayran : pembayran
# pulsanya : pulsa
# available : available
# uli : uli
# dhila : dhila
# gapluk : gapluk
# ulfa : ulfa
# sekolah : sekolah
# php : php
# diem : diem
# putriprmta : putriprmta
# raden : raden
# syarat : syarat
# permisi : permisi
# trima : trima
# nayna : nayna
# irt : irt
# bandel : bandel
# kuliah : kuliah
# lulus : lulus
# smp : smp
# british : british
# petroleum : petroleum
# dosen : dosen
# univ : univ
# bdg : bdg
# kelas : kelas
# pns : pns
# bps : bps
# hasilnya : hasil
# mksd : mksd
# dideskripsinya : deskripsi
# atw : atw
# wkwkwkwkw : wkwkwkwkw
# petinggi : petinggi
# jajaran : jajar
# direksi : direksi
# meninggal : tinggal
# riswanda : riswanda
# risa : risa
# dibikin : bikin
# contoh : contoh
# bersamaan : sama
# semalam : malam
# setya : setya
# lena : lena
# wkwkwkkw : wkwkwkkw
# jakpus : jakpus
# tailah : tailah
# opo : opo
# mung : mung
# nggonaku : nggonaku
# seng : seng
# undlap : undlap
# undlup : undlup
# meta : meta
# metu : metu
# jret : jret
# lebi : lebi
# yea : yea
# nmrnya : nmrnya
# lleh : lleh
# mentari : mentari
# panas : panas
# senyumannya : senyum
# indah : indah
# berseri : seri
# memahami : paham
# eaaaa : eaaaa
# berjalan : jalan
# normal : normal
# minimum : minimum
# dibawah : bawah
# diunduh : unduh
# hbs : hbs
# pdhal : pdhal
# punten : punten
# spotify : spotify
# dwika : dwika
# lambatnya : lambat
# honored : honored
# samuel : samuel
# pasaribu : pasaribu
# vice : vice
# president : president
# network : network
# sumatera : sumatera
# next : next
# has : has
# years : years
# professional : professional
# experience : experience
# deploying : deploying
# technology : technology
# transmission : transmission
# equipment : equipment
# currently : currently
# developing : developing
# silahkan : silah
# kia : kia
# memindahkan : pindah
# nuri : nuri
# matikan : mati
# legends : legends
# fire : fire
# maw : maw
# pembagian : bagi
# diisiin : diisiin
# slotnya : slotnya
# penuh : penuh
# urg : urg
# banjar : banjar
# membaik : baik
# niswatun : niswatun
# terkendala : kendala
# khasa : khasa
# mail : mail
# trans : trans
# ribet : ribet
# bayarnya : bayar
# produktivitas : produktivitas
# komitmen : komitmen
# hahhh : hahhh
# kasian : kasi
# jelekk : jelekk
# surat : surat
# suket : suket
# dinas : dinas
# kependudukan : duduk
# pencatatan : catat
# sipil : sipil
# melampirkan : lampir
# keluarga : keluarga
# membayar : bayar
# mengunjungi : unjung
# terdekat : dekat
# ketentuan : tentu
# membawa : bawa
# dimiliki : milik
# njih : njih
# disambi : sambi
# kaleh : kaleh
# dongo : dongo
# novita : novita
# notifikasi : notifikasi
# amr : amr
# achonk : achonk
# berdasarkan : dasar
# pencerahan : cerah
# meriah : riah
# rugi : rugi
# berharap : harap
# sambung : sambung
# fahmi : fahmi
# menyebabkkan : menyebabkkan
# undian : undi
# berhadiah : hadiah
# wil : wil
# udeh : udeh
# ngapain : ngapain
# maenan : maenan
# file : file
# doc : doc
# pdf : pdf
# xls : xls
# dimanasih : dimanasih
# fungsi : fungsi
# kegunaan : guna
# utamanya : utama
# syaratnya : syarat
# spt : spt
# catur : catur
# fauzan : fauzan
# gojek : gojek
# mitra : mitra
# bangkit : bangkit
# hadapi : hadap
# tuba : tuba
# telat : telat
# mengajukan : aju
# anjirrr : anjirrr
# icacat : icacat
# woiii : woiii
# iyah : iyah
# penelitian : teliti
# sendernya : sender
# base : base
# door : door
# prize : prize
# nihhh : nihhh
# medan : medan
# city : city
# hall : hall
# kolaborasi : kolaborasi
# halodoc : halodoc
# sentra : sentra
# vaksinasi : vaksinasi
# chua : chua
# nasional : nasional
# simcard : simcard
# close : close
# kredit : kredit
# mengirim : kirim
# registrasinya : registrasi
# tsm : tsm
# aulia : aulia
# ngabisin : ngabisin
# gasi : gas
# anjr : anjr
# gofood : gofood
# ajahbayar : ajahbayar
# ajah : ajah
# pikir : pikir
# kenyang : kenyang
# hah : hah
# wis : wis
# podo : podo
# suwun : suwun
# tuhkan : tuhkan
# mamah : mamah
# debes : debes
# mengalahkan : kalah
# bukanya : buka
# diamond : diamond
# berbatas : batas
# beraktivitas : aktivitas
# paketmu : paket
# menipis : tip
# tambahan : tambah
# kebutuhanmu : butuh
# balesan : balesan
# makasihhhh : makasihhhh
# okee : okee
# bole : bole
# hijrah : hijrah
# lgg : lgg
# keambil : ambil
# maksuddd : maksuddd
# dichat : dichat
# kaged : kaged
# takut : takut
# get : get
# contact : contact
# yudhaa : yudhaa
# yulian : yulian
# telkomselnya : telkomselnya
# bawaan : bawa
# guru : guru
# gegeh : gegeh
# responenya : responenya
# ubah : ubah
# murahin : murahin
# gito : gito
# ndesoku : ndesoku
# welek : welek
# gems : gems
# prustasi : prustasi
# msh : msh
# donggg : donggg
# telesales : telesales
# nelpon : nelpon
# tujuannya : tuju
# bray : bray
# gapaham : gapaham
# pertelesales : pertelesales
# its : its
# fishy : fishy
# sesering : sering
# gadiangkat : gadiangkat
# sbg : sbg
# pendukung : dukung
# meli : mel
# ...
# kalsel : kalsel
# keringat : keringat
# dalamnya : dalam
# romy : romy
# leo : leo
# kusdi : kusdi
# aditya : aditya
# adel : adel
# jeleeeee : jeleeeee
# lirik : lirik
# xxxribu : xxxribu
# keamanan : aman
# kunci : kunci
# ppp : ppp
# nyari : nyari
# jua : jua
# mincun : mincun
# robot : robot
# perbaikan : baik
# lmyan : lmyan
# payah : payah
# yola : yola
# fira : fira
# mira : mira
# yodalah : yodalah
# direct : direct
# message : message
# prihatin : prihatin
# hilangnya : hilang
# upayakan : upaya
# percepatannya : cepat
# tersolusikan : solusi
# terkhusus : khusus
# lazada : lazada
# blibli : blibli
# perusahaannya : usaha
# maks : maks
# lalita : lalita
# nonprem : nonprem
# testimoni : testimoni
# njirt : njirt
# wetv : wetv
# niihh : niihh
# chellivia : chellivia
# daerahku : daerah
# paginya : pagi
# quick : quick
# dlm : dlm
# menangani : tangan
# sabtu : sabtu
# terblokir : blokir
# tomp : tomp
# tools : tools
# manajemen : manajemen
# proyek : proyek
# berbasis : bas
# hadir : hadir
# merencanakan : rencana
# mengontrol : kontrol
# mengevaluasi : evaluasi
# realtime : realtime
# tipe : tipe
# usim : usim
# tercakup : cakup
# yusuf : yusuf
# kesetiaan : setia
# persyaratan : syarat
# smartphone : smartphone
# korupsi : korupsi
# bandwidth : bandwidth
# ratenya : ratenya
# rebuan : rebu
# rugii : rugi
# mendesak : desak
# asisten : asisten
# nga : nga
# hpku : hpku
# nda : nda
# tembus : tembus
# gamalan : gamal
# pedagang : dagang
# menghitung : hitung
# kemahalan : mahal
# bar : bar
# pelaporan : lapor
# prasaan : prasaan
# secepat : cepat
# bisaa : bisaa
# mama : mama
# panik : panik
# qia : qia
# tlng : tlng
# jatengdiy : jatengdiy
# mjk : mjk
# dongload : dongload
# downlod : downlod
# jatingan : jatingan
# sempak : sempak
# kay : kay
# myorbitid : myorbitid
# padam : padam
# listrik : listrik
# mabar : mabar
# bantuannya : bantu
# gumanti : gumanti
# kesekian : sekian
# lelah : lelah
# dimention : dimention
# perawatan : awat
# ngutang : ngutang
# penyelamat : selamat
# batalinnya : batalinnya
# kebijakannya : bijak
# ditawarin : ditawarin
# kepikiran : pikir
# bertahun : tahun
# sayang : sayang
# dilanjut : lanjut
# diaktivasi : diaktivasi
# apaaaa : apaaaa
# tolonggg : tolonggg
# mang : mang
# bulanannya : bulan
# jga : jga
# telfon : telfon
# batalin : batalin
# jugakan : juga
# denger : denger
# serah : serah
# kbnykn : kbnykn
# drama : drama
# meloverse : meloverse
# gatcha : gatcha
# judi : judi
# ngandelin : ngandelin
# keberuntungan : untung
# dibaca : baca
# boros : boros
# gprn : gprn
# segitu : segitu
# huaaa : huaaa
# gituu : gituu
# gaisss : gaisss
# dani : dan
# deaktivasi : deaktivasi
# siee : siee
# mesti : mesti
# bgtt : bgtt
# parung : parung
# asep : asep
# mengapresiasi : apresiasi
# zilly : zilly
# kebijakan : bijak
# tinjau : tinjau
# mengundang : undang
# suarakan : suara
# aspirasimu : aspirasi
# identitas : identitas
# form : form
# survey : survey
# kumpulan : kumpul
# aspirasi : aspirasi
# dikaitkan : kait
# pleaseee : pleaseee
# puluh : puluh
# kemudahan : mudah
# memantau : pantau
# slamat : slamat
# beserta : serta
# pemulihan : pulih
# donny : donny
# benefit : benefit
# recycle : recycle
# dipindahin : dipindahin
# bahaya : bahaya
# wirawan : wirawan
# wayan : wayan
# mangats : mangats
# laku : laku
# ruangan : ruang
# gnya : gnya
# hananto : hananto
# pengaturan : atur
# device : device
# alma : alma
# margana : margana
# yoowa : yoowa
# fransisca : fransisca
# esther : esther
# penawarannya : tawar
# jlek : jlek
# prepaid : prepaid
# pusat : pusat
# nang : nang
# bayarane : bayarane
# tep : tep
# iki : iki
# koplak : koplak
# membutuhkan : butuh
# kmaren : kmaren
# bryan : bryan
# music : music
# sule : sule
# feat : feat
# runtah : runtah
# channel : channel
# menghilangkan : hilang
# lezhin : lezhin
# diakses : akses
# kakk : kakk
# meleng : meleng
# gtw : gtw
# pokoke : pokoke
# heshhh : heshhh
# jatah : jatah
# why : why
# win : win
# nsp : nsp
# lapo : lapo
# ngene : ngene
# alodokter : alodokter
# kawasan : kawasan
# lop : lop
# segituu : segituu
# uma : uma
# ituu : ituu
# pov : pov
# sinyall : sinyall
# ayolah : ayo
# kaa : kaa
# pket : pket
# tharco : tharco
# pertanyan : pertanyan
# ardi : ardi
# habisnya : habis
# dek : dek
# skrang : skrang
# perdana : perdana
# banjir : banjir
# kenal : kenal
# ana : ana
# iyosih : iyosih
# twit : twit
# bts : bts
# konten : konten
# memilih : pilih
# vision : vision
# pambudi : pambudi
# pemasangan : pasang
# serpong : serpong
# mall : mall
# summarecon : summarecon
# unit : unit
# tangerang : tangerang
# banten : banten
# website : website
# lengkapnya : lengkap
# buruk : buruk
# muu : muu
# tadii : tadi
# delina : dina
# manaa : manaa
# muncull : muncull
# zamil : zamil
# menginfokan : info
# disalahgunakan : disalahgunakan
# yogs : yogs
# vibes : vibes
# tosell : tosell
# kunjungi : kunjung
# didapatkan : dapat
# sumarecon : sumarecon
# resmi : resmi
# tercatat : catat
# trai : tra
# benefitnya : benefitnya
# quipper : quipper
# udemy : udemy
# duolingo : duolingo
# cakap : cakap
# bahaso : bahaso
# cambridge : cambridge
# assessment : assessment
# english : english
# kipin : kipin
# school : school
# pijar : pijar
# ayoblajar : ayoblajar
# edukasi : edukasi
# learning : learning
# kampus : kampus
# seryl : seryl
# cloudx : cloudx
# zenius : zenius
# dendam : dendam
# rustam : rustam
# tokped : tokped
# cih : cih
# knpppp : knpppp
# mundurrrrrr : mundurrrrrr
# arin : arin
# elisa : elisa
# cristian : cristian
# diinfokan : info
# pemberhentian : henti
# kakrtu : kakrtu
# ngezoom : ngezoom
# belajarnya : ajar
# begimane : begimane
# mee : mee
# dunlud : dunlud
# dik : dik
# seribu : ribu
# weh : weh
# hiks : hiks
# halooo : halooo
# bogor : bogor
# sekaliiii : sekaliiii
# aktifitas : aktifitas
# ditangani : tangan
# impoten : impoten
# niiii : niiii
# gathel : gathel
# jancuuuuuooook : jancuuuuuooook
# linknya : linknya
# kepuasan : puas
# malu : malu
# bgttt : bgttt
# iyaa : iyaa
# lampu : lampu
# matiiiiii : matiiiiii
# nominalnya : nominal
# cobaan : coba
# bueneerr : bueneerr
# ngaktifin : ngaktifin
# mlm : mlm
# ginih : ginih
# matahari : matahari
# tersenyum : senyum
# cerah : cerah
# sungguh : sungguh
# rutin : rutin
# inih : inih
# menyebalkan : sebal
# mytelkomselnya : mytelkomselnya
# request : request
# oranglain : oranglain
# desyy : desyy
# dahh : dahh
# nganggo : nganggo
# stgh : stgh
# smpe : smpe
# tetring : tetring
# nembak : nembak
# hoki : hoki
# dru : dru
# berkelas : kelas
# halloo : halloo
# rakyat : rakyat
# muke : muke
# logikanya : logika
# badan : badan
# milik : milik
# menyediakan : sedia
# fasilitas : fasilitas
# tuan : tuan
# takur : takur
# subuh : subuh
# bida : bida
# kulon : kulon
# gerangan : gerangan
# kawan : kawan
# direktur : direktur
# adiwinahyu : adiwinahyu
# basuki : basuki
# sigit : sigit
# dirimu : diri
# berisik : berisik
# peyeek : peyeek
# diambil : ambil
# wafi : wafi
# bantul : bantul
# buluk : buluk
# kindly : kindly
# register : register
# anggi : anggi
# ulangnya : ulang
# nathalie : nathalie
# okey : okey
# piru : piru
# kabupaten : kabupaten
# seram : seram
# visat : visat
# tempatku : tempat
# nyobain : nyobain
# bangt : bangt
# ayoo : ayoo
# pertandingannya : tanding
# pasang : pasang
# taruhanmu : taruh
# hitsbola : hitsbola
# mainkan : main
# bermain : main
# irwan : irwan
# tgal : tgal
# mhon : mhon
# sbelumnya : sbelumnya
# nasir : nasir
# dedi : dedi
# hahahaha : hahahaha
# digelar : gelar
# mobitekno : mobitekno
# memasuki : pasuk
# kuartal : kuartal
# ketiga : tiga
# menghadirkan : hadir
# league : league
# hr : hr
# thrifty : thrifty
# paaagi : paaagi
# fildzah : fildzah
# limbangan : limbang
# garut : garut
# trouble : trouble
# petugas : tugas
# hrus : hrus
# kontrak : kontrak
# sddi : sddi
# rugikan : rugi
# attention : attention
# plz : plz
# mifi : mifi
# kuliahku : kuliah
# yuhu : yuhu
# eheheh : eheheh
# sucks : sucks
# ivan : ivan
# nyala : nyala
# alloo : alloo
# reboot : reboot
# woi : woi
# test : test
# angka : angka
# mbps : mbps
# dabrus : dabrus
# ibukota : ibukota
# tips : tips
# simak : simak
# reason : reason
# hendry : hendry
# wtf : wtf
# dikoordinasikan : koordinasi
# pelayanannya : layan
# pacific : pacific
# power : power
# rachel : rachel
# goh : goh
# forefront : forefront
# pandemic : pandemic
# shone : shone
# light : light
# gaadanpaketan : gaadanpaketan
# siiii : siiii
# samlayka : samlayka
# aji : aji
# tha : tha
# pergantian : ganti
# siapkan : siap
# ponsel : ponsel
# ngomongnya : ngomongnya
# koordinasi : koordinasi
# nihil : nihil
# terang : terang
# betapa : betapa
# diulang : ulang
# komplain : komplain
# komplainan : komplain
# anugrah : anugrah
# kubeli : bel
# pram : pram
# rinciin : rinciin
# prosedur : prosedur
# mini : mini
# sekarat : sekarat
# takutnya : takut
# kedobel : dobel
# kocak : kocak
# hidupmu : hidup
# penipunya : tipu
# ghaib : ghaib
# mengurus : urus
# sarakan : sara
# web : web
# kaga : kaga
# ngurus : ngurus
# ready : ready
# sebarkan : sebar
# followersmu : followersmu
# layak : layak
# warganet : warganet
# dinsey : dinsey
# darah : darah
# nofaf : nofaf
# anggari : anggar
# digubris : gubris
# konsumen : konsumen
# jeblok : jeblok
# telp : telp
# nyri : nyri
# bnyk : bnyk
# amelle : amelle
# read : read
# ituuuu : ituuuu
# daily : daily
# diklaim : klaim
# noyah : noyah
# {'': '', 'hai': 'hai', 'kak': 'kak', 'maaf': 'maaf', 'kartu': 'kartu', 'rusak': 'rusak', 'diganti': 'ganti', 'iya': 'iya', 'yuk': 'yuk', 'infokan': 'info', 'nama': 'nama', 'via': 'via', 'privasi': 'privasi', 'terjaga': 'jaga', 'tks': 'tks', 'uri': 'uri', 'min': 'min', 'pindahin': 'pindahin', 'nomor': 'nomor', 'indra': 'indra', 'sorry': 'sorry', 'for': 'for', 'the': 'the', 'problem': 'problem', 'have': 'have', 'you': 'you', 'tried': 'tried', 'reinstall': 'reinstall', 'still': 'still', 'same': 'same', 'please': 'please', 'inform': 'inform', 'your': 'your', 'number': 'number', 'phone': 'phone', 'date': 'date', 'incident': 'incident', 'detail': 'detail', 'location': 'location', 'that': 'that', 'privacy': 'privacy', 'maintained': 'maintained', 'and': 'and', 'admin': 'admin', 'checks': 'checks', 'further': 'further', 'strong': 'strong', 'business': 'business', 'metrics': 'metrics', 'cust': 'cust', 'arr': 'arr', 'ttm': 'ttm', 'staff': 'staff', 'nder': 'nder', 'th': 'th', 'quarter': 'quarter', 'new': 'new', 'wins': 'wins', 'nec': 'nec', 'seagate': 'seagate', 'exxonmobil': 'exxonmobil', 'telkomsel': 'telkomsel', 'adds': 'adds', 'upsells': 'upsells', 'apac': 'apac', 'zoom': 'zoom', 'rooms': 'rooms', 'paket': 'paket', 'ditawarkan': 'tawar', 'mahal': 'mahal', 'promo': 'promo', 'sakti': 'sakti', 'multimedia': 'multimedia', 'sinyalnya': 'sinyal', 'hilang': 'hilang', 'sebainya': 'sebai', 'ganti': 'ganti', 'profider': 'profider', 'uda': 'uda', 'gaes': 'gaes', 'beli': 'beli', 'tiket': 'tiket', 'godbless': 'godbless', 'antri': 'antri', 'pas': 'pas', 'kali': 'kali', 'pandemi': 'pandemi', 'gini': 'gin', 'online': 'online', 'klik': 'klik', 'nunggu': 'nunggu', 'konser': 'konser', 'kerj': 'kerj', 'kerjaan': 'kerja', 'rmh': 'rmh', 'jgb': 'jgb', 'lupa': 'lupa', 'follow': 'follow', 'com': 'com', 'yes': 'yes', 'like': 'like', 'this': 'this', 'app': 'app', 'doesnt': 'doesnt', 'work': 'work', 'iphone': 'iphone', 'tbk': 'tbk', 'ily': 'ily', 'logo': 'logo', 'widya': 'widya', 'penawaran': 'tawar', 'ditentukan': 'tentu', 'acak': 'acak', 'sistem': 'sistem', 'menyesuaikan': 'sesuai', 'lokasi': 'lokasi', 'skema': 'skema', 'tarif': 'tarif', 'umur': 'umur', 'penggunaan': 'guna', 'kondisi': 'kondisi', 'khusus': 'khusus', 'semoga': 'moga', 'membantu': 'bantu', 'lin': 'lin', 'menyedihkan': 'sedih', 'berlangganan': 'langgan', 'nomer': 'nomer', 'promonya': 'promonya', 'banget': 'banget', 'murah': 'murah', 'haloo': 'haloo', 'selamat': 'selamat', 'pagi': 'pagi', 'butuh': 'butuh', 'pulsa': 'pulsa', 'cepat': 'cepat', 'yaa': 'yaa', 'fastrespon': 'fastrespon', 'need': 'need', 'jual': 'jual', 'axis': 'axis', 'tri': 'tri', 'smatfren': 'smatfren', 'isat': 'isat', 'indosat': 'indosat', 'tsel': 'tsel', 'wts': 'wts', 'wtb': 'wtb', 'price': 'price', 'drop': 'drop', 'mah': 'mah', 'suka': 'suka', 'boy': 'boy', 'alias': 'alias', 'bucin': 'bucin', 'ice': 'ice', 'cappucino': 'cappucino', 'sajah': 'sajah', 'wilujeng': 'wilujeng', 'sarapan': 'sarap', 'gorengan': 'goreng', 'naskun': 'naskun', 'terkait': 'kait', 'kendala': 'kendala', 'sinyal': 'sinyal', 'coba': 'coba', 'pindahkan': 'pindah', 'mode': 'mode', 'jaringan': 'jaring', 'otomatis': 'otomatis', 'manual': 'manual', 'kembalikan': 'kembali', 'tgl': 'tgl', 'kejadian': 'jadi', 'data': 'data', 'rin': 'rin', 'spay': 'spay', 'gopay': 'gopay', 'non': 'non', 'bca': 'bca', 'convert': 'convert', 'trade': 'trade', 'tukar': 'tukar', 'tuker': 'tuker', 'barter': 'barter', 'three': 'three', 'im': 'im', 'uang': 'uang', 'atm': 'atm', 'bank': 'bank', 'saldo': 'saldo', 'ewallet': 'ewallet', 'qris': 'qris', 'premium': 'premium', 'verif': 'verif', 'ktp': 'ktp', 'plus': 'plus', 'prem': 'prem', 'shopeepay': 'shopeepay', 'shopee': 'shopee', 'dana': 'dana', 'ovo': 'ovo', 'linkaja': 'linkaja', 'preset': 'preset', 'lightroom': 'lightroom', 'cairin': 'cairin', 'paylater': 'paylater', 'dear': 'dear', 'mohon': 'mohon', 'informasi': 'informasi', 'signal': 'signal', 'didaerah': 'daerah', 'jakarta': 'jakarta', 'selatan': 'selatan', 'tepatnya': 'tepat', 'jalan': 'jala ...
# ------------------------
# Pandas Apply:   0%|          | 0/1957 [00:03<?, ?it/s]
#                                                 content  \
# 0     @rdw12_ hai kak. maaf ya, apakah yang dimaksud...
# 1     @telkomsel min, apa bisa pindahin nomor kartu ...
# 2     @dollyindra_di hi mr. indra. sorry for the pro...
# 3     ➡️ $zm strong business metrics 💪🏻\n\n- cust &g...
# 4     @telkomsel iya semakin lama paket yg ditawarka...
# ...                                                 ...
# 1995  @undipmenfess yg telkomsel kapan min? @siapund...
# 1996  @noyah77106135 infoin no hp, tgl kejadian, lok...
# 1997  kenapa hadiah daily check in telkomsel tidak b...
# 1998  @noyah77106135 hai, kak noyah. maaf ya. buat h...
# 1999  haii, selamat pagii\nyang need pulsa cepat bis...
#
#                                          cleaning_tweet  \
# 0      hai kak maaf apakah yang dimaksud dengan kart...
# 1     min apa bisa pindahin nomor kartu lama kartu b...
# 2      indra sorry for the problem have you tried re...
# 3      strong business metrics cust arr   cust ttm  ...
# 4     iya semakin lama paket ditawarkan semakin maha...
# ...                                                 ...
# 1995                               telkomsel kapan min
# 1996  infoin tgl kejadian lokasi detail dan lain yan...
# 1997  kenapa hadiah daily check telkomsel tidak bisa...
# 1998  hai kak noyah maaf buat harga telkomsel sudah ...
# 1999  haii selamat pagii yang need pulsa cepat bisa ...
#
#                                              tokenisasi  \
# 0     [, hai, kak, maaf, apakah, yang, dimaksud, den...
# 1     [min, apa, bisa, pindahin, nomor, kartu, lama,...
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, semakin, lama, paket, ditawarkan, semaki...
# ...                                                 ...
# 1995                        [, telkomsel, kapan, min, ]
# 1996  [infoin, tgl, kejadian, lokasi, detail, dan, l...
# 1997  [kenapa, hadiah, daily, check, telkomsel, tida...
# 1998  [hai, kak, noyah, maaf, buat, harga, telkomsel...
# 1999  [haii, selamat, pagii, yang, need, pulsa, cepa...
#
#                                                stopword  \
# 0     [, hai, kak, maaf, kartu, rusak, diganti, iya,...
# 1                [min, pindahin, nomor, kartu, kartu, ]
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, paket, ditawarkan, mahal, promo, kartu, ...
# ...                                                 ...
# 1995                               [, telkomsel, min, ]
# 1996  [infoin, tgl, kejadian, lokasi, detail, terken...
# 1997         [hadiah, daily, check, telkomsel, diklaim]
# 1998  [hai, kak, noyah, maaf, harga, telkomsel, peny...
# 1999  [haii, selamat, pagii, need, pulsa, cepat, bel...
#
#                                                stemming
# 0     [, hai, kak, maaf, kartu, rusak, ganti, iya, y...
# 1                [min, pindahin, nomor, kartu, kartu, ]
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, paket, tawar, mahal, promo, kartu, sakti...
# ...                                                 ...
# 1995                               [, telkomsel, min, ]
# 1996  [infoin, tgl, jadi, lokasi, detail, kendala, v...
# 1997           [hadiah, daily, check, telkomsel, klaim]
# 1998  [hai, kak, noyah, maaf, harga, telkomsel, sesu...
# 1999  [hai, selamat, pagi, need, pulsa, cepat, beli,...
#
# [1957 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [, hai, kak, maaf, kartu, rusak, ganti, iya, y...
# 1                [min, pindahin, nomor, kartu, kartu, ]
# 2     [, indra, sorry, for, the, problem, have, you,...
# 3     [, strong, business, metrics, cust, arr, cust,...
# 4     [iya, paket, tawar, mahal, promo, kartu, sakti...
# ...                                                 ...
# 1995                               [, telkomsel, min, ]
# 1996  [infoin, tgl, jadi, lokasi, detail, kendala, v...
# 1997           [hadiah, daily, check, telkomsel, klaim]
# 1998  [hai, kak, noyah, maaf, harga, telkomsel, sesu...
# 1999  [hai, selamat, pagi, need, pulsa, cepat, beli,...
#
# [1957 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_8.xlsx')
