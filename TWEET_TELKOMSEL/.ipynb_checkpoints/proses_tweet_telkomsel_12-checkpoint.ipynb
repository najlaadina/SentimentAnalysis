# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @Telkomsel @bengbeng_topp Emang dianya aja ka ...
# 1            AKHIR TAHUN SAATNY AKU PAKE POIN TELKOMSEL
# 2     @sunyoursouI Hai, Kak. Apabila  ada pertanyaan...
# 3     @Luthfi_irT Hai, Kak Aldi. Maaf ya perihal kel...
# 4     @convomfs Telkomsel kan, Nonton film/download ...
# ...                                                 ...
# 1995  @Telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa Sama-sama, Kak Zahra. Makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh Pemerin...
# 1998  @bocahngapag Hi, Kak. Maaf ya mengenai Kuota I...
# 1999          @Telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 78

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @Telkomsel @bengbeng_topp Emang dianya aja ka ...
# 1            AKHIR TAHUN SAATNY AKU PAKE POIN TELKOMSEL
# 2     @sunyoursouI Hai, Kak. Apabila  ada pertanyaan...
# 3     @Luthfi_irT Hai, Kak Aldi. Maaf ya perihal kel...
# 4     @convomfs Telkomsel kan, Nonton film/download ...
# ...                                                 ...
# 1995  @Telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa Sama-sama, Kak Zahra. Makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh Pemerin...
# 1998  @bocahngapag Hi, Kak. Maaf ya mengenai Kuota I...
# 1999          @Telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
# [1893 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @telkomsel @bengbeng_topp emang dianya aja ka ...
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     @sunyoursoui hai, kak. apabila  ada pertanyaan...
# 3     @luthfi_irt hai, kak aldi. maaf ya perihal kel...
# 4     @convomfs telkomsel kan, nonton film/download ...
# ...                                                 ...
# 1995  @telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa sama-sama, kak zahra. makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh pemerin...
# 1998  @bocahngapag hi, kak. maaf ya mengenai kuota i...
# 1999          @telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
# [1893 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @telkomsel @bengbeng_topp emang dianya aja ka ...
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     @sunyoursoui hai, kak. apabila  ada pertanyaan...
# 3     @luthfi_irt hai, kak aldi. maaf ya perihal kel...
# 4     @convomfs telkomsel kan, nonton film/download ...
# ...                                                 ...
# 1995  @telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa sama-sama, kak zahra. makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh pemerin...
# 1998  @bocahngapag hi, kak. maaf ya mengenai kuota i...
# 1999          @telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
#                                          cleaning_tweet
# 0                    topp emang dianya aja hutan kwkwkw
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     hai kak apabila ada pertanyaan atau keluhan se...
# 3      irt hai kak aldi maaf perihal keluhan menerim...
# 4     telkomsel kan nonton film download    disney nder
# ...                                                 ...
# 1995  yaaayyy sama  kak untuk mengecek apakah nomor ...
# 1996  sama sama kak zahra makasih udah menghubungi l...
# 1997  yang telah disetujui oleh pemerintah kak info ...
# 1998   kak maaf mengenai kuota internet pemerintah a...
# 1999                       aaak yeyyy trimaaaci miminn
#
# [1893 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @telkomsel @bengbeng_topp emang dianya aja ka ...
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     @sunyoursoui hai, kak. apabila  ada pertanyaan...
# 3     @luthfi_irt hai, kak aldi. maaf ya perihal kel...
# 4     @convomfs telkomsel kan, nonton film/download ...
# ...                                                 ...
# 1995  @telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa sama-sama, kak zahra. makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh pemerin...
# 1998  @bocahngapag hi, kak. maaf ya mengenai kuota i...
# 1999          @telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
#                                          cleaning_tweet  \
# 0                    topp emang dianya aja hutan kwkwkw
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     hai kak apabila ada pertanyaan atau keluhan se...
# 3      irt hai kak aldi maaf perihal keluhan menerim...
# 4     telkomsel kan nonton film download    disney nder
# ...                                                 ...
# 1995  yaaayyy sama  kak untuk mengecek apakah nomor ...
# 1996  sama sama kak zahra makasih udah menghubungi l...
# 1997  yang telah disetujui oleh pemerintah kak info ...
# 1998   kak maaf mengenai kuota internet pemerintah a...
# 1999                       aaak yeyyy trimaaaci miminn
#
#                                              tokenisasi
# 0           [, topp, emang, dianya, aja, hutan, kwkwkw]
# 1     [akhir, tahun, saatny, aku, pake, poin, telkom...
# 2     [hai, kak, apabila, ada, pertanyaan, atau, kel...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluhan...
# 4     [telkomsel, kan, nonton, film, download, disne...
# ...                                                 ...
# 1995  [yaaayyy, sama, kak, untuk, mengecek, apakah, ...
# 1996  [sama, sama, kak, zahra, makasih, udah, menghu...
# 1997  [yang, telah, disetujui, oleh, pemerintah, kak...
# 1998  [, kak, maaf, mengenai, kuota, internet, pemer...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
# [1893 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @telkomsel @bengbeng_topp emang dianya aja ka ...
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     @sunyoursoui hai, kak. apabila  ada pertanyaan...
# 3     @luthfi_irt hai, kak aldi. maaf ya perihal kel...
# 4     @convomfs telkomsel kan, nonton film/download ...
# ...                                                 ...
# 1995  @telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa sama-sama, kak zahra. makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh pemerin...
# 1998  @bocahngapag hi, kak. maaf ya mengenai kuota i...
# 1999          @telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
#                                          cleaning_tweet  \
# 0                    topp emang dianya aja hutan kwkwkw
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     hai kak apabila ada pertanyaan atau keluhan se...
# 3      irt hai kak aldi maaf perihal keluhan menerim...
# 4     telkomsel kan nonton film download    disney nder
# ...                                                 ...
# 1995  yaaayyy sama  kak untuk mengecek apakah nomor ...
# 1996  sama sama kak zahra makasih udah menghubungi l...
# 1997  yang telah disetujui oleh pemerintah kak info ...
# 1998   kak maaf mengenai kuota internet pemerintah a...
# 1999                       aaak yeyyy trimaaaci miminn
#
#                                              tokenisasi  \
# 0           [, topp, emang, dianya, aja, hutan, kwkwkw]
# 1     [akhir, tahun, saatny, aku, pake, poin, telkom...
# 2     [hai, kak, apabila, ada, pertanyaan, atau, kel...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluhan...
# 4     [telkomsel, kan, nonton, film, download, disne...
# ...                                                 ...
# 1995  [yaaayyy, sama, kak, untuk, mengecek, apakah, ...
# 1996  [sama, sama, kak, zahra, makasih, udah, menghu...
# 1997  [yang, telah, disetujui, oleh, pemerintah, kak...
# 1998  [, kak, maaf, mengenai, kuota, internet, pemer...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
#                                                stopword
# 0                        [, topp, emang, dianya, hutan]
# 1                             [saatny, poin, telkomsel]
# 2     [hai, kak, keluhan, seputar, produk, layanan, ...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluhan...
# 4     [telkomsel, nonton, film, download, disney, nder]
# ...                                                 ...
# 1995  [yaaayyy, kak, mengecek, nomor, masi, aktif, k...
# 1996  [kak, zahra, makasih, udah, menghubungi, layan...
# 1997  [disetujui, pemerintah, kak, info, detail, kuo...
# 1998  [, kak, maaf, kuota, internet, pemerintah, lan...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
# [1893 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3465
# ------------------------
#  :
# topp : topp
# emang : emang
# dianya : dia
# hutan : hutan
# saatny : saatny
# poin : poin
# telkomsel : telkomsel
# hai : hai
# kak : kak
# keluhan : keluh
# seputar : putar
# produk : produk
# layanan : layan
# yuk : yuk
# infoin : infoin
# detail : detail
# via : via
# mimin : mimin
# bantu : bantu
# makasih : makasih
# rin : rin
# irt : irt
# aldi : aldi
# maaf : maaf
# perihal : perihal
# menerima : terima
# sms : sms
# nofitikasi : nofitikasi
# berulang : ulang
# nomor : nomor
# kejadian : jadi
# lokasi : lokasi
# kecamatan : camat
# kelurahan : lurah
# kota : kota
# cek : cek
# tindak : tindak
# selamat : selamat
# beraktivitas : aktivitas
# steve : steve
# nonton : nonton
# film : film
# download : download
# disney : disney
# nder : nder
# min : min
# stop : stop
# smsnya : smsnya
# gimana : gimana
# habis : habis
# daftar : daftar
# paket : paket
# mytelkomsel : mytelkomsel
# terusan : terus
# kayak : kayak
# gini : gin
# sampe : sampe
# dial : dial
# info : info
# lengkapnya : lengkap
# semoga : moga
# membantu : bantu
# kia : kia
# letna : letna
# terkait : kait
# kakak : kakak
# tukarkan : tukar
# telepon : telepon
# internet : internet
# digital : digital
# nsp : nsp
# video : video
# games : games
# diskon : diskon
# menarik : tarik
# merchant : merchant
# bekerjasama : bekerjasama
# saldo : saldo
# linkaja : linkaja
# aplikasi : aplikasi
# hallo : hallo
# guys : guys
# tolong : tolong
# habisin : habisin
# sayang : sayang
# banget : banget
# tinggal : tinggal
# sehari : hari
# huhu : huhu
# diperpanjang : panjang
# btw : btw
# error : error
# mulu : mulu
# kah : kah
# program : program
# khusus : khusus
# pelanggan : langgan
# prabayar : prabayar
# komunitas : komunitas
# tertutup : tutup
# dimana : mana
# terbuka : buka
# kalangan : kalang
# hadi : had
# kirim : kirim
# masuk : masuk
# list : list
# antrian : antri
# mohon : mohon
# berkenan : kenan
# menunggu : tunggu
# interaksi : interaksi
# tks : tks
# cris : cris
# keterlambatan : lambat
# balasan : balas
# diterima : terima
# silakan : sila
# konfirmasi : konfirmasi
# lina : lina
# biasce : biasce
# maafin : maafin
# ceritain : ceritain
# pertanyaannya : tanya
# langsung : langsung
# nge : nge
# privasi : privasi
# terjaga : jaga
# dpt : dpt
# dibantu : bantu
# sedih : sedih
# pulang : pulang
# kampung : kampung
# total : total
# ribuan : ribu
# hangus : hangus
# meninggoy : meninggoy
# infokan : info
# monetary : monetary
# telpon : telpon
# voucher : voucher
# berbeda : beda
# zabo : zabo
# kebalikanny : kebalikanny
# dirumah : rumah
# gada : gada
# sinyal : sinyal
# gue : gue
# liat : liat
# apk : apk
# seribu : ribu
# gitu : gitu
# rani : rani
# pengguna : guna
# lupa : lupa
# tukerin : tukerin
# basah : basah
# isi : isi
# pulsa : pulsa
# banking : banking
# jam : jam
# nmr : nmr
# tgl : tgl
# capture : capture
# pembelian : beli
# trims : trims
# pagi : pagi
# mbanking : mbanking
# rekening : rekening
# terdebet : debet
# udh : udh
# ditunggu : tunggu
# ciye : ciye
# kena : kena
# prank : prank
# kenapaaa : kenapaaa
# sabar : sabar
# meluncur : luncur
# yaaa : yaaa
# jul : jul
# semangat : semangat
# arya : arya
# kendala : kendala
# keterangan : terang
# gagal : gagal
# admin : admin
# knp : knp
# yyyy : yyyy
# provider : provider
# lisa : lisa
# blekping : blekping
# ian : ian
# reaktivasi : reaktivasi
# boros : boros
# menfess : menfess
# iya : iya
# kuota : kuota
# dapet : dapet
# gratis : gratis
# langganan : langgan
# sebulan : bulan
# lumayan : lumayan
# agiegi : agiegi
# extra : extra
# aktif : aktif
# pengecekan : kece
# random : random
# jdi : jdi
# udah : udah
# cmn : cmn
# ngulur : ngulur
# cari : cari
# penipuan : tipu
# kaya : kaya
# gtu : gtu
# wkwkw : wkwkw
# nada : nada
# aktifasi : aktifasi
# ketik : ketik
# nslap : nslap
# judul : judul
# hitam : hitam
# putih : putih
# artist : artist
# the : the
# gajah : gajah
# mada : mada
# spam : spam
# chat : chat
# blok : blok
# setau : tau
# bocorin : bocorin
# nomer : nomer
# alhamdulillahnya : alhamdulillah
# rumahku : rumah
# oke : oke
# stabil : stabil
# matlis : matlis
# hujan : hujan
# msh : msh
# lancar : lancar
# beda : beda
# wilayah : wilayah
# kadang : kadang
# ngacak : ngacak
# ehh : ehh
# nyambung : nyambung
# gua : gua
# salah : salah
# yaa : yaa
# digua : gua
# bagus : bagus
# jaringannya : jaring
# aman : aman
# gaada : gaada
# piyayi : piyayi
# matiin : matiin
# pengaturan : atur
# battery : battery
# saving : saving
# mode : mode
# deh : deh
# coba : coba
# ngaruh : ngaruh
# performa : performa
# restart : restart
# situ : situ
# kartu : kartu
# sinyalnya : sinyal
# adek : adek
# giliran : gilir
# lgi : lgi
# berulah : ulah
# main : main
# segini : gin
# ngelag : ngelag
# tuu : tuu
# lope : lope
# lopee : lopee
# jia : jia
# tdur : tdur
# jiaa : jiaa
# lanang : lanang
# dhea : dhea
# maxstream : maxstream
# akun : akun
# viu : viu
# premium : premium
# tanggal : tanggal
# dicek : cek
# data : data
# alam : alam
# thank : thank
# youu : youu
# smga : smga
# nnti : nnti
# pas : pas
# tahuan : tahu
# baruan : baru
# happy : happy
# yeppi : yeppi
# yakk : yakk
# sing : sing
# onok : onok
# tah : tah
# mas : mas
# adminnya : adminnya
# ngetik : ngetik
# cuman : cuman
# fitrah : fitrah
# inbox : inbox
# setan : setan
# suka : suka
# berhenti : henti
# ekstra : ekstra
# kartuhalo : kartuhalo
# nama : nama
# lengkap : lengkap
# lahir : lahir
# nominal : nominal
# tagihan : tagih
# done : done
# wml : wml
# rezeki : rezeki
# ntr : ntr
# mampet : mampet
# insyaallah : insyaallah
# members : members
# lho : lho
# beli : beli
# ramenya : ramenya
# ama : ama
# verif : verif
# code : code
# mls : mls
# berasa : asa
# axis : axis
# bapa : bapa
# merah : merah
# ampun : ampun
# murah : murah
# sygnya : sygnya
# tempatku : tempat
# pergi : pergi
# rumah : rumah
# jelek : jelek
# astaga : astaga
# njirrr : njirrr
# frusciante : frusciante
# darurat : darurat
# memotong : potong
# otomatis : otomatis
# asfsgahajsv : asfsgahajsv
# apapun : apa
# bngtt : bngtt
# bos : bos
# iki : iki
# pie : pie
# ndue : ndue
# utang : utang
# ngisi : ngisi
# kesedot : sedot
# renek : renek
# pulsane : pulsane
# wae : wae
# mbok : mbok
# tagihiii : tagihiii
# apala : apala
# ngulah : ngulah
# jaringan : jaring
# refresh : refresh
# off : off
# service : service
# berkendala : kendala
# halo : halo
# nyaman : nyaman
# akses : akses
# pastiin : pastiin
# hasilnya : hasil
# beny : beny
# ish : ish
# kontol : kontol
# memek : memek
# ngeleg : ngeleg
# ngentod : ngentod
# unlimited : unlimited
# sin : sin
# speed : speed
# sinyale : sinyale
# jancoookk : jancoookk
# pupuk : pupuk
# indonesia : indonesia
# persero : persero
# makmur : makmur
# menjalankan : jalan
# pertanian : tani
# presisi : presisi
# kabupaten : kabupaten
# karawang : karawang
# jawa : jawa
# barat : barat
# proyek : proyek
# telekomunikasi : telekomunikasi
# seluler : seluler
# bergabung : gabung
# tumben : tumben
# ngadat : ngadat
# sesuai : sesuai
# periode : periode
# atur : atur
# ngab : ngab
# yak : yak
# nurunin : nurunin
# hehehe : hehehe
# mengurangi : kurang
# pengeluaran : keluar
# pemasukan : pasu
# berkurang : kurang
# covid : covid
# lihat : lihat
# deal : deal
# orbit : orbit
# fantasix : fantasix
# promo : promo
# aca : aca
# simpati : simpati
# tri : tri
# kangen : kangen
# marah : marah
# ilang : ilang
# twit : twit
# aldo : aldo
# dicoba : coba
# silahkan : silah
# kirimkan : kirim
# anpras : anpras
# pastinya : pasti
# udahlah : udahlah
# semalam : malam
# reset : reset
# perubahan : ubah
# solusinyaaaaa : solusinyaaaaa
# diperbaiki : baik
# secepatnyaaa : secepatnyaaa
# lambat : lambat
# airplane : airplane
# indosat : indosat
# vivi : vivi
# open : open
# kimjw : kimjw
# alda : alda
# ily : ily
# muach : muach
# anehh : anehh
# mbe : mbe
# jeng : jeng
# kuda : kuda
# naha : naha
# bedaaa : bedaaa
# pke : pke
# tsel : tsel
# keluhannya : keluh
# singkat : singkat
# dibantuin : dibantuin
# telkomsek : telkomsek
# ajg : ajg
# keterlambatannya : lambat
# dibales : dibales
# gece : gece
# soup : soup
# erick : erick
# thohir : thohir
# sim : sim
# dikunci : kunci
# maksudnya : maksud
# urgent : urgent
# ariyo : ariyo
# tipu : tipu
# melapor : lapor
# kepolisian : polisi
# memburu : buru
# penipu : tipu
# menipu : tipu
# mengatasnamakan : mengatasnamakan
# urusan : urus
# korban : korban
# tunggu : tunggu
# baca : baca
# arie : arie
# penukaran : tukar
# hotstar : hotstar
# tersedia : sedia
# tenang : tenang
# hadiah : hadiah
# hadiahnya : hadiah
# nggak : nggak
# bangke : bangke
# penukarannya : tukar
# pilih : pilih
# sesuka : suka
# hati : hati
# ketersediaan : sedia
# operator : operator
# ditukarkan : tukar
# pilihannya : pilih
# haloo : haloo
# sule : sule
# waspada : waspada
# waspadalah : waspada
# percaya : percaya
# teruskan : terus
# permintaannya : minta
# meraka : raka
# kasihan : kasihan
# orang : orang
# dishy : dishy
# aktivasi : aktivasi
# dipake : dipake
# limit : limit
# kepake : kepake
# nambah : nambah
# harian : hari
# rb : rb
# ajah : ajah
# susah : susah
# dipaksa : paksa
# mantap : mantap
# malem : malem
# kurasa : rasa
# jaringannyaa : jaringannyaa
# but : but
# bersyukur : syukur
# lancaarr : lancaarr
# bang : bang
# ane : ane
# deres : deres
# bae : bae
# bogor : bogor
# lag : lag
# sebentar : sebentar
# telkomselnya : telkomselnya
# ditta : ditta
# setia : setia
# berupaya : upaya
# maksimal : maksimal
# memuaskan : muas
# pakai : pakai
# masker : masker
# stay : stay
# safe : safe
# and : and
# healthy : healthy
# kim : kim
# cinta : cinta
# kagak : kagak
# dipusat : pusat
# streaming : streaming
# yutub : yutub
# bogornye : bogornye
# mari : mari
# gacor : gacor
# bet : bet
# kehadiran : hadir
# kuncie : kuncie
# fita : fita
# wujud : wujud
# nyata : nyata
# keseriusan : serius
# mengembangkan : kembang
# trifecta : trifecta
# perusahaan : usaha
# ditempatku : tempat
# ono : ono
# jaringane : jaringane
# opo : opo
# soale : soale
# daerahnya : daerah
# mepet : mepet
# belantara : belantara
# ngene : ngene
# review : review
# cakep : cakep
# reviewnya : reviewnya
# tukar : tukar
# illa : illa
# rekan : rekan
# interaksinya : interaksi
# thanks : thanks
# ucup : ucup
# pindahkan : pindah
# manual : manual
# berkali : kali
# app : app
# ignya : ignya
# reinstall : reinstall
# hpku : hpku
# tetep : tetep
# gabisa : gabisa
# gmana : gmana
# bantuannya : bantu
# yulia : yulia
# minn : minn
# nanyaa : nanyaa
# barusan : barusan
# paketan : paket
# combo : combo
# sakti : sakti
# buka : buka
# iyaaa : iyaaa
# anak : anak
# ikutan : ikut
# heyy : heyy
# bocil : bocil
# ikutin : ikutin
# keknya : kek
# dlu : dlu
# jaman : jaman
# nelpon : nelpon
# abis : abis
# paketnya : paket
# doi : doi
# paketannya : paket
# wkwkwke : wkwkwke
# kesini : kesini
# kang : kang
# jualan : jual
# sepatu : sepatu
# aladin : aladin
# riki : riki
# solusi : solusi
# anying : anying
# besok : besok
# ganti : ganti
# asli : asli
# gajelas : gajelas
# pelayanannya : layan
# mahal : mahal
# doang : doang
# lancat : lancat
# beralih : alih
# mencekik : cekik
# anjirrr : anjirrr
# kek : kek
# dikit : dikit
# gils : gils
# ayok : ayok
# wwwww : wwwww
# mitratel : mitratel
# peluang : peluang
# penyewaan : sewa
# menara : menara
# dinand : dinand
# luthfi : luthfi
# egi : egi
# bantuin : bantuin
# ceritakan : cerita
# dialami : alami
# ditangani : tangan
# benci : benci
# bilangnya : bilang
# bales : bales
# diinfokan : info
# esim : esim
# proses : proses
# pengembangan : kembang
# diusahakan : usaha
# secepatnya : cepat
# sehat : sehat
# dita : dita
# don : don
# engga : engga
# trs : trs
# gituu : gituu
# nahhh : nahhh
# support : support
# keren : keren
# emng : emng
# temen : temen
# knapa : knapa
# sore : sore
# trus : trus
# mega : mega
# informasi : informasi
# mati : mati
# listrik : listrik
# tower : tower
# mencari : cari
# bts : bts
# terdekat : dekat
# mempengaruhi : pengaruh
# kekuatan : kuat
# berapaa : berapaa
# yga : yga
# area : area
# bassura : bassura
# city : city
# jakarta : jakarta
# sebenernya : sebenernya
# buruk : buruk
# ntah : ntah
# palagi : palagi
# banding : banding
# sebelah : belah
# kalah : kalah
# ampe : ampe
# tathering : tathering
# ngetuit : ngetuit
# padam : padam
# aseli : aseli
# danta : danta
# koneksinya : koneksi
# hery : hery
# lose : lose
# streak : streak
# hdeeh : hdeeh
# abdul : abdul
# ppp : ppp
# convert : convert
# dana : dana
# drop : drop
# fee : fee
# nikmati : nikmat
# macem : macem
# skrg : skrg
# lemot : lot
# donlot : donlot
# mb : mb
# nunggu : nunggu
# inimah : inimah
# karna : karna
# liburan : libur
# aris : aris
# yalord : yalord
# live : live
# bro : bro
# user : user
# experience : experience
# dibanding : banding
# bapuk : bapuk
# diandalkan : andal
# cepat : cepat
# uhuy : uhuy
# galih : galih
# senang : senang
# berinteraksi : interaksi
# menghubungi : hubung
# customer : customer
# sungkan : sungkan
# you : you
# direct : direct
# message : message
# facebook : facebook
# byu : byu
# terinstall : terinstall
# penanganan : tangan
# resmi : resmi
# channel : channel
# help : help
# center : center
# website : website
# instagram : instagram
# twitter : twitter
# telkomel : telkomel
# amelia : amelia
# sarankan : saran
# share : share
# mention : mention
# menghindari : hindar
# penyalahgunaan : penyalahgunaan
# ngegame : ngegame
# ping : ping
# jump : jump
# perhatiin : perhatiin
# kei : kei
# duh : duh
# pindahin : pindahin
# sue : sue
# manamanamana : manamanamana
# desa : desa
# ranggitgit : ranggitgit
# kec : kec
# parmonangan : parmonangan
# tapanuli : tapanuli
# utara : utara
# sumatera : sumatera
# hilang : hilang
# perbaikin : perbaikin
# penawaran : tawar
# harga : harga
# queen : queen
# pemakaian : pakai
# fine : fine
# ndak : ndak
# nyedot : nyedot
# mksdnya : mksdnya
# fast : fast
# respon : respon
# call : call
# switch : switch
# network : network
# sinyalmu : sinyal
# butut : butut
# sekaliii : sekaliii
# malam : malam
# lelah : lelah
# buffering : buffering
# can : can
# something : something
# taun : taun
# tolkemsol : tolkemsol
# kebelakang : belakang
# parah : parah
# dilarang : larang
# beropini : opini
# hape : hape
# bobby : bobby
# tangerang : tangerang
# unreg : unreg
# kemarin : kemarin
# morak : morak
# marik : marik
# sii : sii
# jujur : jujur
# bot : bot
# capek : capek
# telkom : telkom
# semalaman : malam
# jomblo : jomblo
# maling : maling
# najis : najis
# beneran : beneran
# gegee : gegee
# balas : balas
# sihh : sihh
# nunu : nunu
# pribadi : pribadi
# dilanjut : lanjut
# adminn : adminn
# dmku : dmku
# tidur : tidur
# reboot : reboot
# semacamnya : macam
# bosan : bosan
# asin : asin
# metode : metode
# pembayaran : bayar
# shopeepay : shopeepay
# device : device
# nyempil : nyempil
# makasi : makas
# bray : bray
# thx : thx
# bre : bre
# masukannya : masuk
# terimakasih : terimakasih
# informasinya : informasi
# informasikan : informasi
# memposting : memposting
# publik : publik
# disalahgunakan : disalahgunakan
# oknum : oknum
# bertanggung : tanggung
# dilanjutkan : lanjut
# butong : butong
# menyertakan : serta
# hei : hei
# ilyt : ilyt
# terima : terima
# kasih : kasih
# leo : leo
# telp : telp
# aneh : aneh
# hr : hr
# bebas : bebas
# menit : menit
# goblok : goblok
# kesel : kesel
# tulis : tulis
# daerah : daerah
# merasakan : rasa
# direspon : direspon
# gasih : gasih
# kendalanya : kendala
# datanya : data
# garra : garra
# eeh : eeh
# plsss : plsss
# lelet : lelet
# adelia : adelia
# statusnya : status
# mencoba : coba
# mengganti : ganti
# winoto : winoto
# diinfoin : diinfoin
# serem : rem
# bjing : bjing
# yaudah : yaudah
# pasrah : pasrah
# plat : plat
# lancang : lancang
# terapkan : terap
# robot : robot
# sibuk : sibuk
# mending : mending
# perbaiki : baik
# kontttt : kontttt
# menghambat : hambat
# kerjaan : kerja
# kygssdh : kygssdh
# include : include
# subs : subs
# pesawat : pesawat
# knpa : knpa
# ngefollow : ngefollow
# skskksks : skskksks
# betol : betol
# kmk : kmk
# kembalikan : kembali
# kau : kau
# lae : lae
# menang : menang
# gugatan : gugat
# triliyun : triliyun
# buzzerp : buzzerp
# enaknya : enak
# dituker : dituker
# gan : gan
# sok : sok
# block : block
# jatuh : jatuh
# tempo : tempo
# alias : alias
# bingung : bingung
# radar : radar
# hadirkan : hadir
# natal : natal
# regional : regional
# bener : bener
# jaringannnn : jaringannnn
# sumpahhhh : sumpahhhh
# bogorrrrr : bogorrrrr
# pls : pls
# santet : santet
# jiaaaa : jiaaaa
# notair : notair
# multimedia : multimedia
# whatsapp : whatsapp
# line : line
# musicmax : musicmax
# gamesmax : gamesmax
# tiktok : tiktok
# zoom : zoom
# alfian : alfian
# terpotong : potong
# syahrul : syahrul
# willy : willy
# run : run
# drakor : drakor
# netflix : netflix
# tpi : tpi
# gembokan : gembok
# lari : lari
# cepet : cepet
# pindah : pindah
# deket : deket
# gapapa : gapapa
# gatau : gatau
# males : males
# hangussss : hangussss
# siiiii : siiiii
# gb : gb
# ngakak : ngakak
# puas : puas
# horor : horor
# serial : serial
# seru : seru
# hemat : hemat
# eric : eric
# seharian : hari
# berlaku : laku
# omg : omg
# spesial : spesial
# full : full
# mostly : mostly
# series : series
# judulnya : judul
# aurel : aurel
# dibagi : bagi
# speednya : speednya
# unit : unit
# enjoyers : enjoyers
# mantep : mantep
# putu : putu
# bole : bole
# dibawa : bawa
# namanya : nama
# grapari : grapari
# disana : sana
# dibenerin : dibenerin
# kartunya : kartu
# nomornya : nomor
# clear : clear
# cache : cache
# pastikan : pasti
# aplikasinya : aplikasi
# update : update
# aaaa : aaaa
# ututuu : ututuu
# asw : asw
# notif : notif
# dibuka : buka
# isinya : isi
# teu : teu
# kuat : kuat
# mawa : mawa
# lowongan : lowong
# kerja : kerja
# indihum : indihum
# problematik : problematik
# bgd : bgd
# serasa : serasa
# batang : batang
# mars : mars
# tulloh : tulloh
# beat : beat
# akn : akn
# kouta : kouta
# susanto : susanto
# jee : jee
# hubungi : hubung
# sedekah : sedekah
# percm : percm
# mio : mio
# mobill : mobill
# dkk : dkk
# akhirat : akhirat
# coy : coy
# sma : sma
# kenceng : kenceng
# annisa : annisa
# keliling : keliling
# rutinitas : rutinitas
# mendekati : dekat
# tontonan : tonton
# terfavorit : favorit
# redeem : redeem
# yekan : yekan
# hoki : hoki
# sperti : sperti
# gambir : gambir
# benerin : benerin
# kali : kali
# ckck : ckck
# cocok : cocok
# komunikasi : komunikasi
# keluarga : keluarga
# bisnis : bisnis
# sekolah : sekolah
# kampus : kampus
# hubungan : hubung
# jarak : jarak
# anan : anan
# promosi : promosi
# diiinfokan : diiinfokan
# serius : serius
# ditukerin : ditukerin
# popup : popup
# blokir : blokir
# kedepannya : depan
# bersedia : sedia
# skg : skg
# response : response
# samudra : samudra
# siii : siii
# lohh : lohh
# hzz : hzz
# ookay : ookay
# fren : fren
# refres : refres
# penerbangan : terbang
# spay : spay
# rate : rate
# samaa : samaa
# gangguan : ganggu
# teman : teman
# menghabiskan : habis
# point : point
# januari : januari
# sepi : sepi
# muehehe : muehehe
# aaawe : aaawe
# maaciii : maaciii
# cyn : cyn
# tobat : tobat
# ujan : ujan
# angin : angin
# badai : badai
# mendadak : dadak
# tergantung : gantung
# kebutuhan : butuh
# pakenya : pakenya
# jaya : jaya
# jeleqqq : jeleqqq
# bru : bru
# kereta : kereta
# express : express
# sorry : sorry
# sunghoon : sunghoon
# temennya : temennya
# kyungjun : kyungjun
# gedek : gedek
# anjor : anjor
# anjing : anjing
# wkwkwkwk : wkwkwkwk
# privatter : privatter
# aduh : aduh
# galauin : galauin
# astagfirullah : astagfirullah
# kuyusan : kuyusan
# bayar : bayar
# zaa : zaa
# biasanyaa : biasanyaa
# spamnya : spamnya
# prosesnya : proses
# transfer : transfer
# ready : ready
# smartfren : smartfren
# besti : besti
# alhamdulilah : alhamdulilah
# suda : suda
# operasi : operasi
# erran : erran
# utama : utama
# kecepatan : cepat
# diturunkan : turun
# kbps : kbps
# kecuali : kecuali
# pilihan : pilih
# mengkonsumsi : konsumsi
# batas : batas
# wajar : wajar
# salsa : salsa
# kode : kode
# otp : otp
# solusinya : solusi
# juni : juni
# darah : darah
# boss : boss
# sign : sign
# out : out
# disuruh : suruh
# login : login
# ulang : ulang
# raid : raid
# sumpaah : sumpaah
# kesal : kesal
# gold : gold
# ilanggg : ilanggg
# cape : cape
# komplain : komplain
# alamat : alamat
# hasil : hasil
# nol : nol
# salfok : salfok
# baekhyun : baekhyun
# helmy : helmy
# jarang : jarang
# uda : uda
# hadehhhh : hadehhhh
# pantes : pantes
# kelapangan : lapang
# mobile : mobile
# cobain : cobain
# adi : adi
# tekap : tekap
# polres : polres
# tubaba : tubaba
# pencurian : curi
# pengrusakan : rusa
# lutfia : lutfia
# kaleemm : kaleemm
# elu : elu
# too : too
# lintas : lintas
# ekbis : ekbis
# kerjasama : kerjasama
# bni : bni
# muncul : muncul
# dea : dea
# recycle : recycle
# terhapus : hapus
# urusin : urusin
# siang : siang
# emg : emg
# cpt : cpt
# erorr : erorr
# kaga : kaga
# berati : berat
# maap : maap
# ralat : ralat
# neng : neng
# cerita : cerita
# didengerin : didengerin
# mytelkomselnya : mytelkomselnya
# pket : pket
# sgtu : sgtu
# kese : kese
# emm : emm
# rugi : rugi
# gpp : gpp
# bonusannya : bonus
# koin : koin
# alice : alice
# heee : heee
# mosok : mosok
# mba : mba
# tiwas : tiwas
# ngamuk : ngamuk
# rek : rek
# digagas : gagas
# mamacih : mamacih
# zelf : zelf
# nukerin : nukerin
# pda : pda
# mendingan : mending
# donasi : donasi
# wkwkwkwkwkwk : wkwkwkwkwkwk
# blm : blm
# sembuh : sembuh
# teruss : teruss
# unlimitedmax : unlimitedmax
# apps : apps
# batasan : batas
# fup : fup
# frio : frio
# lite : lite
# web : web
# link : link
# versi : versi
# pemilik : milik
# ktp : ktp
# pemberi : beri
# penerima : terima
# kuasa : kuasa
# imel : imel
# prihatin : prihatin
# hilangnya : hilang
# card : card
# membawa : bawa
# berhalangan : halang
# hadir : hadir
# diwakilkan : wakil
# melampirkan : lampir
# surat : surat
# bermaterai : bermaterai
# protest : protest
# fess : fess
# rungkad : rungkad
# pisan : pis
# pokona : pokona
# mah : mah
# ngajemad : ngajemad
# musingkeun : musingkeun
# dipakai : pakai
# ter : ter
# khawatir : khawatir
# registrasi : registrasi
# febri : febri
# cashback : cashback
# minimal : minimal
# veronika : veronika
# virtual : virtual
# assistant : assistant
# mama : mama
# masi : mas
# bagemana : bagemana
# down : down
# maketin : maketin
# gope : gope
# tanggung : tanggung
# garis : garis
# hotspot : hotspot
# ponakan : ponakan
# ilyyyy : ilyyyy
# untung : untung
# signal : signal
# penjelasannya : jelas
# org : org
# laen : laen
# tsb : tsb
# kaleidoskop : kaleidoskop
# ict : ict
# november : november
# national : national
# day : day
# expo : expo
# dubai : dubai
# inovasi : inovasi
# teknologi : teknologi
# terdepan : depan
# investasi : investasi
# global : global
# yoga : yoga
# melanjutkan : lanjut
# davin : davin
# upgrade : upgrade
# ponsel : ponsel
# plan : plan
# rp : rp
# ribu : ribu
# dapetin : dapetin
# sedari : dar
# kayanya : kaya
# sistemnya : sistem
# bgusin : bgusin
# refund : refund
# lindeuk : lindeuk
# japati : japati
# nuhun : nuhun
# bilangin : bilangin
# mmah : mmah
# laginya : lagi
# haiii : haiii
# jual : jual
# buset : buset
# kemendikbud : kemendikbud
# dikirimin : dikirimin
# dibeli : beli
# wkwkwk : wkwkwk
# diam : diam
# sunset : sunset
# medsos : medsos
# lewatkan : lewat
# keseruan : seru
# man : man
# utd : utd
# burnley : burnley
# tonton : tonton
# mola : mola
# entertainment : entertainment
# hbo : hbo
# tambahan : tambah
# dinoe : dinoe
# yaiyalah : yaiyalah
# desember : desember
# umb : umb
# penuh : penuh
# jalan : jalan
# iko : iko
# smp : smp
# perpanjang : panjang
# terime : rime
# komplen : komplen
# purba : purba
# menyambut : sambut
# lindungan : lindung
# allah : allah
# swt : swt
# prediksi : prediksi
# bola : bola
# onoslot : onoslot
# liga : liga
# inggris : inggris
# manchester : manchester
# united : united
# hdp : hdp
# over : over
# deposit : deposit
# telegram : telegram
# ngapain : ngapain
# berpa : berpa
# sekrng : sekrng
# unlimtd : unlimtd
# jaringanya : jaringanya
# eror : eror
# nyesel : nyesel
# joss : joss
# tuker : tuker
# spt : spt
# inget : inget
# jams : jams
# migrasi : migrasi
# pengaduan : adu
# kemana : mana
# kepotong : potong
# available : available
# memeriksa : periksa
# bye : bye
# smartphone : smartphone
# iphone : iphone
# dapatkan : dapat
# cicilan : cicil
# erafone : erafone
# ibox : ibox
# syarat : syarat
# ketentuan : tentu
# layananan : layananan
# cug : cug
# closed : closed
# group : group
# pekerjaan : kerja
# ochi : ochi
# bersifat : sifat
# berlangganan : langgan
# pascabayar : pascabayar
# im : im
# ngga : ngga
# bosen : bosen
# bangsat : bangsat
# iloyo : iloyo
# lucky : lucky
# ambisi : ambisi
# raja : raja
# mtel : mtel
# pintu : pintu
# benefitnya : benefitnya
# cume : cume
# nanye : nanye
# care : care
# seeh : seeh
# kelamean : kelamean
# taook : taook
# keburu : keburu
# ape : ape
# sengaje : sengaje
# pdhl : pdhl
# caper : caper
# efa : efa
# semenjak : semenjak
# logo : logo
# joki : joki
# izin : izin
# libur : libur
# minggu : minggu
# terpaksa : paksa
# pengertiannya : erti
# early : early
# new : new
# year : year
# sekitaran : sekitar
# ciracas : ciracas
# kacau : kacau
# balau : balau
# panas : panas
# byee : byee
# terserah : serah
# plsa : plsa
# idupin : idupin
# always : always
# bad : bad
# yeee : yeee
# internetnya : internetnya
# kismin : kismin
# huh : huh
# telponan : telpon
# berganti : ganti
# kartumu : kartu
# menikmati : nikmat
# terbaik : baik
# bonus : bonus
# lampu : lampu
# pengen : ken
# kado : kado
# penasaran : penasaran
# kadonya : kado
# kesempatan : sempat
# sani : sani
# lemah : lemah
# fany : fany
# force : force
# set : set
# preferred : preferred
# tujuan : tuju
# berjalan : jalan
# budidaya : budidaya
# padi : padi
# tebu : tebu
# jagung : jagung
# pinkers : pinkers
# nuri : nuri
# namanyaa : namanyaa
# siti : siti
# mabar : mabar
# push : push
# rank : rank
# henpon : henpon
# lucu : lucu
# darimane : darimane
# geser : geser
# kecover : kecover
# relatif : relatif
# uri : uri
# gampang : gampang
# hahaha : hahaha
# dee : dee
# hakim : hakim
# ubah : ubah
# tenggang : tenggang
# akurat : akurat
# nbsp : nbsp
# kuul : kuul
# keilangan : keilangan
# ngapa : ngapa
# sik : sik
# kupandang : pandang
# pandang : pandang
# busuk : busuk
# gamau : gamau
# santai : santai
# ihhh : ihhh
# megang : megang
# kabur : kabur
# xabara : xabara
# baikmu : baik
# gkkk : gkkk
# antriannya : antri
# responnya : responnya
# jes : jes
# antriaan : antriaan
# keperluan : perlu
# sapa : sapa
# hah : hah
# nyebut : nyebut
# nyebutt : nyebutt
# kodomo : kodomo
# umur : umur
# wati : wati
# brp : brp
# hello : hello
# geli : geli
# apanya : apa
# hrs : hrs
# ajgg : ajgg
# kaget : kaget
# syp : syp
# fasilitas : fasilitas
# pembiayaan : biaya
# supply : supply
# chain : chain
# financing : financing
# mitra : mitra
# mbek : mbek
# dipegang : pegang
# bau : bau
# follow : follow
# jobs : jobs
# merinding : merinding
# katsumoto : katsumoto
# rico : rico
# kerayu : rayu
# ungu : ungu
# syok : syok
# kambing : kambing
# membiasakan : biasa
# membuka : buka
# youtube : youtube
# efaaa : efaaa
# allahhhh : allahhhh
# wihhh : wihhh
# memey : memey
# terbaca : baca
# diperangkat : perangkat
# ponselnya : ponselnya
# akwkwk : akwkwk
# rutin : rutin
# check : check
# seruangan : ruang
# papa : papa
# php : php
# aishhhh : aishhhh
# jorokkkkk : jorokkkkk
# indihome : indihome
# gmn : gmn
# ngirim : ngirim
# melulu : melulu
# yud : yud
# teleq : teleq
# bossss : bossss
# nanya : nanya
# kuotanya : kuota
# pau : pau
# terakumulasi : akumulasi
# membeli : beli
# mengikuti : ikut
# ketentuannya : tentu
# belinya : beli
# istilah : istilah
# surya : surya
# marshel : marshel
# kelucuan : lucu
# senyum : senyum
# tertawa : tertawa
# kelucuannya : lucu
# walopun : walopun
# inti : inti
# need : need
# isiin : isiin
# byr : byr
# sisa : sisa
# ditambah : tambah
# koutanya : koutanya
# kenape : kenape
# enak : enak
# kannn : kannn
# reynaldi : reynaldi
# mudah : mudah
# lakukan : laku
# woy : woy
# tuhan : tuhan
# adie : adie
# penggunaan : guna
# multimedianya : multimedia
# terpakai : pakai
# diatas : atas
# selebihnya : lebih
# aksesnya : akses
# ketidaksesuaian : ketidaksesuaian
# memadai : pada
# terganggu : ganggu
# game : game
# online : online
# jurusan : jurus
# bumn : bumn
# tbk : tbk
# melamar : lamar
# signalnya : signalnya
# ganggu : ganggu
# ena : ena
# expired : expired
# item : item
# kesentuh : sentuh
# jajaki : jajak
# sektor : sektor
# kesehatan : sehat
# nonstop : nonstop
# sarah : sarah
# festival : festival
# explore : explore
# rahma : rahma
# loading : loading
# verifikasi : verifikasi
# nomorku : nomor
# segitu : segitu
# mahaaal : mahaaal
# bentuk : bentuk
# uang : uang
# cantik : cantik
# jep : jep
# lang : lang
# siapkan : siap
# diaktifkan : aktif
# wifi : wifi
# anjrit : anjrit
# aing : aing
# miskin : miskin
# gemini : gemini
# dibecandain : dibecandain
# tanduk : tanduk
# kaum : kaum
# jaringanmu : jaring
# beraq : beraq
# cuk : cuk
# samsung : samsung
# galaxy : galaxy
# bundlingmax : bundlingmax
# gadget : gadget
# store : store
# infonya : info
# dimaafin : dimaafin
# sereceh : receh
# diamonds : diamonds
# favorit : favorit
# aktifin : aktifin
# ijo : ijo
# mengaktifkan : aktif
# ngetawain : ngetawain
# jubah : jubah
# pratama : pratama
# diperhatikan : perhati
# dinaikkan : naik
# peningkatan : tingkat
# kualitas : kualitas
# swicth : swicth
# memilih : pilih
# tantyo : tantyo
# tokopedia : tokopedia
# mendapatkannya : dapat
# normal : normal
# kukira : kira
# edwin : edwin
# opsi : opsi
# klik : klik
# nyuruh : nyuruh
# direstart : direstart
# jailbreaknya : jailbreaknya
# fitur : fitur
# saran : saran
# solutif : solutif
# template : template
# rusman : rusman
# berubah : ubah
# disesuaikan : sesuai
# skema : skema
# tarif : tarif
# kondisi : kondisi
# dijelasin : dijelasin
# detailnya : detail
# sertakan : serta
# dayat : dayat
# wey : wey
# baal : baal
# membayar : bayar
# tanggapan : tanggap
# prima : prima
# play : play
# penyesuaian : sesuai
# upaya : upaya
# menjaga : jaga
# abdurrahman : abdurrahman
# amir : amir
# loop : loop
# strange : strange
# gaes : gaes
# lena : lena
# pelanggantelkomsel : pelanggantelkomsel
# nawari : nawari
# anti : anti
# namaku : nama
# canggih : canggih
# menanggapi : tanggap
# tungguin : tungguin
# des : des
# rupiah : rupiah
# gmna : gmna
# mulung : mulung
# plisss : plisss
# muter : muter
# tokped : tokped
# potongan : potong
# digrapari : digrapari
# ambil : ambil
# ibuku : ibu
# android : android
# beliau : beliau
# jadul : jadul
# ckckck : ckckck
# yawes : yawes
# ngalah : ngalah
# telponnya : telpon
# bingit : bingit
# yakali : yakali
# ngabisin : ngabisin
# memiliki : milik
# digit : digit
# aktifkan : aktif
# nomormu : nomor
# maintenance : maintenance
# beres : beres
# commerce : commerce
# shopee : shopee
# dll : dll
# saranin : saranin
# responsif : responsif
# kebiasaan : biasa
# tlpon : tlpon
# kyk : kyk
# albedo : albedo
# bruh : bruh
# transaksi : transaksi
# historynya : historynya
# ato : ato
# maretta : maretta
# billy : billy
# solo : solo
# senin : senin
# jumat : jumat
# sabtu : sabtu
# tutup : tutup
# slamet : slamet
# riyadi : riyadi
# sriwerdari : sriwerdari
# moro : moro
# ning : ning
# jcm : jcm
# ngeselin : ngeselin
# far : far
# good : good
# merchandise : merchandise
# gerai : gerai
# william : william
# tampil : tampil
# anyway : anyway
# elektrik : elektrik
# all : all
# three : three
# isat : isat
# trusted : trusted
# ayaahh : ayaahh
# gembokannn : gembokannn
# hurts : hurts
# love : love
# more : more
# than : than
# just : just
# sampah : sampah
# komisaris : komisaris
# mandiri : mandiri
# sbg : sbg
# rawan : rawan
# telfon : telfon
# billing : billing
# sungguh : sungguh
# menganggu : menganggu
# hubungin : hubungin
# petunjuk : tunjuk
# maks : maks
# kmu : kmu
# register : register
# drtd : drtd
# deni : den
# jaga : jaga
# kerahasiaan : rahasia
# diinformasikan : informasi
# permintaan : minta
# puk : puk
# syifa : syifa
# panggilan : panggil
# pemblokiran : blokir
# perangkat : perangkat
# pelanggannya : langgan
# mantul : mantul
# mpoy : mpoy
# bukti : bukti
# kodenya : kode
# bajingan : bajing
# tolol : tolol
# hebiirote : hebiirote
# weh : weh
# dakjal : dakjal
# teros : ros
# subuh : subuh
# kilas : kilas
# netizen : netizen
# idenya : ide
# unik : unik
# bestie : bestie
# reply : reply
# pendanaan : dana
# pendampingan : damping
# melalu : lalu
# bri : bri
# holding : holding
# ultra : ultra
# mikro : mikro
# pemanfaatan : manfaat
# gedung : gedung
# sarinah : sarinah
# fund : fund
# mendukung : dukung
# konten : konten
# gim : gim
# loka : loka
# pengusaha : usaha
# watsapnya : watsapnya
# emak : emak
# namain : namain
# kontak : kontak
# hpnya : hpnya
# manda : manda
# ngaku : ngaku
# nelfonnya : nelfonnya
# nuker : nuker
# nutup : nutup
# yee : yee
# niat : niat
# nipunya : nipunya
# operasional : operasional
# kronologis : kronologis
# riserais : riserais
# alami : alami
# dikunjungi : kunjung
# memperpanjang : panjang
# cangkang : cangkang
# jir : jir
# gopay : gopay
# butuh : butuh
# kelanjutannya : lanjut
# kalea : kalea
# terbalas : balas
# chan : chan
# tune : tune
# ketinggalan : tinggal
# giveaway : giveaway
# fisik : fisik
# bntar : bntar
# angus : angus
# renaldi : renaldi
# gara : gara
# idup : idup
# hih : hih
# dmnya : dmnya
# flash : flash
# sale : sale
# favoritmu : favorit
# snk : snk
# seprti : seprti
# laki : laki
# disuru : disuru
# atm : atm
# bareng : bareng
# diingetin : diingetin
# gapernah : gapernah
# irsan : irsan
# pengecekannnya : pengecekannnya
# ble : ble
# iyaa : iyaa
# persyaratan : syarat
# handphone : handphone
# email : email
# pembukaan : buka
# sisil : sisil
# fandy : fandy
# hilal : hilal
# kemaren : kemaren
# tbtb : tbtb
# kelogout : kelogout
# kalimantan : kalimantan
# wtb : wtb
# kenapasi : napas
# gratisannya : gratis
# wetv : wetv
# nntn : nntn
# semarang : semarang
# trouble : trouble
# daritadi : daritadi
# ridwan : ridwan
# gakuat : gakuat
# indihomo : indihomo
# khudri : khudri
# lin : lin
# harry : harry
# pasuruan : pasuruan
# kecataman : kecataman
# lekok : lekok
# nikmatin : nikmatin
# momen : momen
# sinergi : sinergi
# negeri : negeri
# hiburan : hibur
# langitmusik : langitmusik
# myorbitid : myorbitid
# wow : wow
# mengalami : alami
# kenaikan : naik
# berdasarkan : dasar
# jenis : jenis
# penjelajah : jelajah
# giliranmu : gilir
# gabung : gabung
# hl : hl
# ut : ut
# dongg : dongg
# mon : mon
# gaktau : gaktau
# ira : ira
# pengumuman : umum
# pemenang : menang
# alfamidi : alfamidi
# terpilih : pilih
# family : family
# midi : midi
# kunjungi : kunjung
# situs : situs
# mknya : mknya
# thread : thread
# dibaca : baca
# temenmu : temenmu
# sanksi : sanksi
# apus : apus
# nzr : nzr
# onya : onya
# dihp : dihp
# ruuud : ruuud
# telpn : telpn
# connecting : connecting
# denpasar : denpasar
# bali : bal
# ruangan : ruang
# problems : problems
# ngasih : ngasih
# mutiara : mutiara
# laporan : lapor
# kartuku : kartu
# menyesuaikan : sesuai
# apaka : apaka
# brtahun : brtahun
# bcnda : bcnda
# kasi : kasi
# pdhal : pdhal
# gtau : gtau
# aktifnya : aktif
# brapa : brapa
# sistem : sistem
# atuh : atuh
# klu : klu
# blom : blom
# enakan : enak
# tselnya : tselnya
# batuan : batu
# cap : cap
# bertahun : tahun
# phone : phone
# kitanya : kita
# pulsanya : pulsa
# adem : adem
# ayem : ayem
# iklan : iklan
# setaun : taun
# pesan : pesan
# kann : kann
# diakses : akses
# fair : fair
# usage : usage
# policy : policy
# ikxxi : ikxxi
# amanda : amanda
# salma : salma
# ajikk : ajikk
# ajik : ajik
# adjie : adjie
# raga : raga
# ewallet : ewallet
# yaap : yaap
# dijamin : jamin
# bangettt : bangettt
# bonua : bonua
# swinata : swinata
# dikirimkan : kirim
# long : long
# lat : lat
# google : google
# maps : maps
# ardhi : ardhi
# ttp : ttp
# acc : acc
# ntar : ntar
# numpang : numpang
# hostpot : hostpot
# pasca : pasca
# lionsgate : lionsgate
# amazone : amazone
# prime : prime
# vidio : vidio
# junay : junay
# giganet : giganet
# terbagi : bagi
# intagram : intagram
# jazz : jazz
# subang : subang
# bdg : bdg
# bekasi : bekas
# jkt : jkt
# depok : depok
# pendapatan : dapat
# kookie : kookie
# najiah : najiah
# teguh : teguh
# prik : prik
# webtoon : webtoon
# dikata : kata
# are : are
# semingguan : minggu
# pinggir : pinggir
# laut : laut
# slow : slow
# gegara : gegara
# jebakan : jebak
# ora : ora
# kantong : kantong
# kering : kering
# linknya : linknya
# raih : raih
# awards : awards
# ragu : ragu
# sukses : sukses
# putri : putri
# petir : petir
# gede : gede
# sempet : sempet
# lost : lost
# cerah : cerah
# kompakan : kompak
# gangguannya : ganggu
# tlp : tlp
# please : please
# internetan : internetan
# settingan : settingan
# yaaampun : yaaampun
# kmrin : kmrin
# kli : kli
# bkn : bkn
# ngakunya : ngakunya
# bsi : bsi
# ngeh : ngeh
# magribnya : magrib
# enterprise : enterprise
# digitalisasi : digitalisasi
# industri : industri
# bergerak : gerak
# bidang : bidang
# manufaktur : manufaktur
# pertambangan : tambang
# perkebunan : kebun
# temukan : temu
# booth : booth
# ribet : ribet
# parsel : parsel
# kirimin : kirimin
# sahabatmu : sahabat
# gift : gift
# tanggepan : tanggepan
# timnas : timnas
# super : super
# siput : siput
# dapin : dapin
# anjritt : anjritt
# jiss : jiss
# hshs : hshs
# have : have
# nice : nice
# kerugian : rugi
# kuliah : kuliah
# kompensasi : kompensasi
# dilampirkan : lampir
# susahkuh : susahkuh
# mengapresiasi : apresiasi
# harapan : harap
# terlaksana : laksana
# dirugikan : rugi
# memangnya : memang
# kesalahan : salah
# diproses : proses
# bank : bank
# negara : negara
# sepakat : sepakat
# kemudahan : mudah
# selular : selular
# memperkuat : kuat
# doni : doni
# menjelang : jelang
# yap : yap
# mlbb : mlbb
# plus : plus
# dapetinnya : dapetinnya
# top : top
# kaka : kaka
# diberhentiin : diberhentiin
# denny : denny
# akumulasi : akumulasi
# penggabungan : gabung
# digunain : digunain
# menyetakan : seta
# kampret : kampret
# ditukar : tukar
# saaad : saaad
# eug : eug
# alur : alur
# dikenal : kenal
# belom : bom
# segedeg : segedeg
# dimention : dimention
# kantor : kantor
# sam : sam
# langkah : langkah
# pelakunya : laku
# ditangkap : tangkap
# sumpah : sumpah
# blas : blas
# mentok : mentok
# spotify : spotify
# tanah : tanah
# abang : abang
# pesen : sen
# grab : grab
# nyaut : nyaut
# edan : edan
# menemui : temu
# himbau : himbau
# putus : putus
# pulkam : pulkam
# rada : rada
# riweuh : riweuh
# praktis : praktis
# harimu : hari
# nay : nay
# jwab : jwab
# dibls : dibls
# modus : modus
# konsumen : konsumen
# ditindaklanjuti : ditindaklanjuti
# ditertibkan : tertib
# berwajib : wajib
# pelaporan : lapor
# prvasi : prvasi
# bocor : bocor
# ditelfon : ditelfon
# agen : agen
# pinjol : pinjol
# marketing : marketing
# kecewa : kecewa
# dear : dear
# sedot : sedot
# kost : kost
# pakek : pakek
# merugikan : rugi
# tim : tim
# duitnya : duit
# barang : barang
# aware : aware
# serunya : seru
# meriah : riah
# setuju : tuju
# mumpung : mumpung
# buruan : buru
# nika : nika
# akhri : akhri
# penyelamatku : selamat
# iqiyi : iqiyi
# perbulannya : bulan
# rebu : rebu
# rufiatid : rufiatid
# mocham : mocham
# tembakau : tembakau
# cacat : cacat
# diurus : urus
# history : history
# yaudahlah : yaudahlah
# gapake : gapake
# hempaskan : hempas
# bnyk : bnyk
# bhayyy : bhayyy
# persis : persis
# ditonton : tonton
# gratisan : gratis
# anggurin : anggurin
# makasii : makasii
# kenapasiiii : kenapasiiii
# masukan : masuk
# mystery : mystery
# shop : shop
# frosty : frosty
# shawty : shawty
# bundle : bundle
# flake : flake
# blake : blake
# free : free
# fire : fire
# event : event
# promonya : promonya
# dapetnya : dapetnya
# burik : burik
# quota : quota
# sal : sal
# berhasil : hasil
# didapatkan : dapat
# tersolusikan : solusi
# dipaketkan : paket
# eeeh : eeeh
# dimakan : makan
# gr : gr
# seh : seh
# neh : neh
# masak : masak
# anjg : anjg
# leg : leg
# aha : aha
# faindriyani : faindriyani
# upayakan : upaya
# dibalas : balas
# membalas : balas
# pancious : pancious
# pancake : pancake
# solaria : solaria
# adil : adil
# myungsool : myungsool
# ayo : ayo
# jura : jura
# buy : buy
# get : get
# legends : legends
# higgs : higgs
# domino : domino
# lipat : lipat
# emas : emas
# memutuskan : putus
# lamban : lamban
# samosir : samosir
# robert : robert
# non : non
# assist : assist
# only : only
# gaaktif : gaaktif
# amblas : amblas
# gemblung : gemblung
# maunya : mau
# pelihara : pelihara
# tuyul : tuyul
# lintah : lintah
# penghisap : penghisap
# keambil : ambil
# paham : paham
# almost : almost
# kdsdr : kdsdr
# dahaga : dahaga
# rindu : rindu
# ijudin : ijudin
# rahmat : rahmat
# penambahan : tambah
# taunya : tau
# pokok : pokok
# poinnya : poin
# lemotnya : lot
# subhanallah : subhanallah
# gumilar : gumilar
# ketengan : keteng
# akumulasikan : akumulasi
# offf : offf
# mgorbanin : mgorbanin
# ngeretry : ngeretry
# task : task
# diruang : ruang
# rapat : rapat
# upload : upload
# foto : foto
# status : status
# hahah : hahah
# iyapp : iyapp
# denik : denik
# terkonsumsi : konsumsi
# lorentz : lorentz
# skrng : skrng
# beyb : beyb
# nerima : nerima
# reguler : reguler
# for : for
# confirming : confirming
# information : information
# currently : currently
# your : your
# already : already
# queue : queue
# wait : wait
# usaha : usaha
# wkkwkwkwk : wkkwkwkwk
# enggaaa : enggaaa
# baguss : baguss
# kencengin : kencengin
# kamar : kamar
# kosnya : kosnya
# depri : depri
# wahajwjwjwjajajwjqh : wahajwjwjwjajajwjqh
# kemplo : kemplo
# ovo : ovo
# pending : pending
# asuuuu : asuuuu
# mastip : mastip
# diisi : isi
# haein : haein
# jisoo : jisoo
# harganya : harga
# okay : okay
# doaku : doa
# nemu : nemu
# jodoh : jodoh
# bucin : bucin
# abdee : abdee
# nun : nun
# deals : deals
# ditawarin : ditawarin
# greget : greget
# kupon : kupon
# undian : undi
# better : better
# yamg : yamg
# max : max
# embel : embel
# munculnya : muncul
# edge : edge
# bisanya : bisa
# laptop : laptop
# iyh : iyh
# ditelpon : telpon
# sales : sales
# suruh : suruh
# suaranya : suara
# lembut : lembut
# karpet : karpet
# masjid : masjid
# planggan : planggan
# nopal : nopal
# perbedaan : beda
# dasar : dasar
# pilihat : pilihat
# limited : limited
# edition : edition
# nyalain : nyalain
# kerugiannya : rugi
# jt : jt
# bbrp : bbrp
# psikologis : psikologis
# spy : spy
# bhw : bhw
# nlp : nlp
# assistance : assistance
# adl : adl
# pliss : pliss
# nipu : nipu
# pusat : pusat
# butter : butter
# kya : kya
# permudah : mudah
# kredit : kredit
# ajing : ajing
# bangcattt : bangcattt
# babi : babi
# aduan : adu
# berharap : harap
# vocer : vocer
# gofud : gofud
# dikibulin : dikibulin
# pinternya : pinternya
# tulisannya : tulis
# remaining : remaining
# dibalikin : dibalikin
# pancen : pancen
# she : she
# late : late
# terkaget : kaget
# terkonfirmasi : konfirmasi
# setaannn : setaannn
# cermati : cermat
# solusikah : solusi
# inet : inet
# problem : problem
# setahun : tahun
# subscription : subscription
# hentikan : henti
# spamming : spamming
# diblok : blok
# telko : telko
# mestinya : mesti
# lbh : lbh
# etika : etika
# bayu : bayu
# seminggu : minggu
# maja : maja
# lebak : lebak
# browsing : browsing
# terkirim : kirim
# connect : connect
# diperiksa : periksa
# buntu : buntu
# citra : citra
# dibikin : bikin
# kick : kick
# hybrid : hybrid
# gambar : gambar
# period : period
# samsyul : samsyul
# feedback : feedback
# kategori : kategori
# piye : piye
# jane : jane
# noviani : noviani
# indri : indri
# syaratnya : syarat
# terdaftar : daftar
# perbankan : perban
# jabar : jabar
# pertelevisian : televisi
# memenuhi : penuh
# siaran : siar
# tunda : tunda
# kegiatan : giat
# meninjau : tinjau
# compact : compact
# infrastruktur : infrastruktur
# pendukung : dukung
# penguatan : kuat
# kesiapan : kesiap
# disiapkan : siap
# sng : sng
# combat : combat
# menghadirkan : hadir
# perhelatan : helat
# internasional : internasional
# dri : dri
# coverage : coverage
# lgsung : lgsung
# agus : agus
# loyality : loyality
# about : about
# social : social
# media : media
# healty : healty
# cust : cust
# anna : anna
# means : means
# thing : thing
# dyas : dyas
# dihubungi : hubung
# salsabila : salsabila
# jihan : jih
# livin : livin
# zona : zona
# selengkapnya : lengkap
# idr : idr
# ngikut : ngikut
# thankyou : thankyou
# inidah : inidah
# dooong : dooong
# plss : plss
# filmnya : film
# plusnya : plus
# desca : desca
# pemotongan : potong
# air : air
# plane : plane
# bentar : bentar
# work : work
# asshiba : asshiba
# shiba : shiba
# andalan : andal
# tiffa : tiffa
# jenengan : jeneng
# kuita : kuita
# jln : jln
# skli : skli
# prvdr : prvdr
# normalinnya : normalinnya
# setingan : ting
# otak : otak
# atik : atik
# balance : balance
# rizqi : rizqi
# claim : claim
# daily : daily
# slandni : slandni
# maksud : maksud
# music : music
# amazon : amazon
# diborong : borong
# kalao : kalao
# hijaudaun : hijaudaun
# ktsep : ktsep
# terkendala : kendala
# arko : arko
# digantikan : ganti
# direaktivasi : direaktivasi
# prepaid : prepaid
# dipertemukan : temu
# dipisahkan : pisah
# keyakinan : yakin
# saksikan : saksi
# perjuangan : juang
# bagas : bagas
# syakir : syakir
# daulay : daulay
# nadhira : nadhira
# icha : icha
# maysha : maysha
# jodohnya : jodoh
# bulanan : bulan
# jago : jago
# dibenahi : benah
# didaur : daur
# diaktifin : diaktifin
# seandainya : anda
# perkuat : kuat
# alm : alm
# dikonter : konter
# save : save
# lgsg : lgsg
# pure : pure
# disegel : segel
# alief : alief
# posting : posting
# nmor : nmor
# nmornya : nmornya
# daur : daur
# byk : byk
# terooooos : terooooos
# rizki : rizki
# tercantum : cantum
# deskripsi : deskripsi
# payah : payah
# brian : brian
# arief : arief
# yuksapa : yuksapa
# berfungsi : fungsi
# sambung : sambung
# wta : wta
# rep : rep
# dibawah : bawah
# thaankss : thaankss
# honda : honda
# mobilio : mobilio
# cbs : cbs
# indomaret : indomaret
# temuin : temuin
# idak : idak
# itukan : itu
# mesti : mesti
# make : make
# fuck : fuck
# eva : eva
# tekomsel : tekomsel
# notifnya : notifnya
# mencukupi : cukup
# welly : welly
# kayaknya : kayak
# takut : takut
# kehilangan : hilang
# ceritanya : cerita
# koneksi : koneksi
# merata : rata
# nurahmad : nurahmad
# titik : titik
# terluas : luas
# pelosok : pelosok
# yes : yes
# local : local
# operators : operators
# years : years
# since : since
# first : first
# that : that
# here : here
# wake : wake
# spg : spg
# maukah : mau
# hidupku : hidup
# desy : desy
# ubinuno : ubinuno
# amin : amin
# doakan : doa
# beruntung : untung
# beragam : agam
# page : page
# banyaknya : banyak
# dimiliki : milik
# yuuuuk : yuuuuk
# tok : tok
# notice : notice
# yusi : yusi
# tmn : tmn
# lanjutin : lanjutin
# toni : ton
# jeong : jeong
# oww : oww
# okeh : okeh
# budug : budug
# inoy : inoy
# isjak : isjak
# minor : minor
# walah : walah
# kyanya : kyanya
# imran : imran
# dipotong : potong
# sisanya : sisa
# dikenakan : kena
# contoh : contoh
# seharga : harga
# tertera : tera
# hmmmmmm : hmmmmmm
# ditampilkan : tampil
# karina : karina
# menyediakan : sedia
# acces : acces
# venue : venue
# base : base
# transceiver : transceiver
# station : station
# sambungan : sambung
# odp : odp
# watasi : watas
# draw : draw
# simak : simak
# gimanaaa : gimanaaa
# tulisan : tulis
# sept : sept
# dpet : dpet
# suryati : suryati
# tari : tari
# makany : makany
# beliin : beliin
# avatarik : avatarik
# bkin : bkin
# sky : sky
# pally : pally
# tekait : tekait
# masuknya : masuk
# lokal : lokal
# otw : otw
# urutan : urut
# prioritas : prioritas
# konsumsi : konsumsi
# pendek : pendek
# mengakses : akses
# stasion : stasion
# hawa : hawa
# riwayat : riwayat
# teakhir : teakhir
# bangun : bangun
# kasep : kasep
# anita : anita
# lebib : lebib
# gapaham : gapaham
# enih : enih
# awet : awet
# pdahal : pdahal
# dritdi : dritdi
# proof : proof
# atambua : atambua
# persiapan : siap
# menentukan : tentu
# prestasi : prestasi
# vcs : vcs
# reall : reall
# basa : basa
# basi : basi
# omdo : omdo
# berbayar : bayar
# koordinat : koordinat
# marsel : marsel
# ahmad : ahmad
# menyebabkan : sebab
# pemasok : pasok
# aryaan : arya
# kuy : kuy
# adam : adam
# ditawarkan : tawar
# dipasarkan : pasar
# luas : luas
# cetak : cetak
# banner : banner
# minnn : minnn
# adhi : adhi
# pantura : pantura
# brow : brow
# gila : gila
# abisnyaaaa : abisnyaaaa
# btn : btn
# elsa : elsa
# unlimitedplay : unlimitedplay
# hae : hae
# garena : garena
# arena : arena
# valor : valor
# shellfire : shellfire
# rise : rise
# nowlin : nowlin
# ragnarok : ragnarok
# next : next
# generation : generation
# nedaz : nedaz
# rahman : rahman
# regitrasi : regitrasi
# siapin : siapin
# ektp : ektp
# melewati : lewat
# disarankan : saran
# perdana : perdana
# telkomcloud : telkomcloud
# nyari : nyari
# iaas : iaas
# pubg : pubg
# regulernya : reguler
# mihiil : mihiil
# van : van
# jelly : jelly
# buatku : buat
# say : say
# fayan : fayan
# mahmud : mahmud
# noprizal : noprizal
# aul : aul
# dirasa : rasa
# hub : hub
# linkajanya : linkajanya
# baper : baper
# bentaran : bentar
# diatur : atur
# offim : offim
# standar : standar
# penggunaaan : penggunaaan
# anjinm : anjinm
# dha : dha
# bonyok : bonyok
# gueee : gueee
# yoon : yoon
# huft : huft
# pacarmu : pacar
# galon : galon
# burhan : burhan
# nasgor : nasgor
# savior : savior
# dino : dino
# biii : biii
# bebe : bebe
# humor : humor
# sebatas : batas
# kebab : kebab
# komandan : komandan
# haiiii : haiiii
# sinyamu : sinyamu
# woi : woi
# emosi : emosi
# dimas : mas
# ngejaga : ngejaga
# hiii : hiii
# hmmm : hmmm
# nggk : nggk
# langganannya : langgan
# master : master
# marahin : marahin
# selangkah : selang
# mythic : mythic
# turun : turun
# tira : tira
# chandz : chandz
# oks : oks
# btul : btul
# adu : adu
# mekanik : mekanik
# betrik : betrik
# jga : jga
# jumping : jumping
# ms : ms
# kack : kack
# kapok : kapok
# etmin : etmin
# pelayanan : layan
# anjirr : anjirr
# mager : mager
# tercatat : catat
# rang : rang
# yakannn : yakannn
# twt : twt
# load : load
# syukur : syukur
# dikasih : kasih
# haii : hai
# dipanggil : panggil
# okei : oke
# let : let
# interact : interact
# moree : moree
# miliki : milik
# mira : mira
# gen : gen
# daerahku : daerah
# bandingkan : banding
# cepetan : cepetan
# dina : dina
# tahap : tahap
# terealisasikan : realisasi
# ndapapa : ndapapa
# socmed : socmed
# fanfict : fanfict
# wehhh : wehhh
# penjelasan : jelas
# roaming : roaming
# tauu : tauu
# dilan : dil
# yhhh : yhhh
# ngurusnya : ngurusnya
# khenzza : khenzza
# fira : fira
# berantakan : beranta
# mengeluhkan : keluh
# extend : extend
# perpanjangan : panjang
# andy : andy
# bert : bert
# biaya : biaya
# kyu : kyu
# hubungannya : hubung
# ngomongin : ngomongin
# kntl : kntl
# ditajimalela : ditajimalela
# kalianda : kalianda
# lampung : lampung
# selatan : selatan
# kontl : kontl
# ell : ell
# salkenn : salkenn
# lets : lets
# maappp : maappp
# ketawa : ketawa
# nontonnya : nontonnya
# walo : walo
# mantengin : mantengin
# uploadnya : uploadnya
# mbps : mbps
# andrew : andrew
# hrp : hrp
# wlaupun : wlaupun
# plijeu : plijeu
# mksh : mksh
# kwn : kwn
# wkwkkw : wkwkkw
# mbak : mbak
# michelle : michelle
# perkenalkan : kenal
# dosky : dosky
# sinaga : sinaga
# centre : centre
# jancok : jancok
# nam : nam
# taufan : taufan
# skayie : skayie
# space : space
# doank : doank
# ditayangin : ditayangin
# seneng : neng
# harfa : harfa
# langgana : langgana
# pengisian : isi
# ardi : ardi
# hadeh : hadeh
# quit : quit
# texting : texting
# allo : allo
# money : money
# bahula : bahula
# biut : biut
# vinto : vinto
# hee : hee
# bgtt : bgtt
# madura : madura
# ngang : ngang
# ngong : ngong
# teriak : teriak
# bermodalkan : modal
# jleg : jleg
# ditambahin : ditambahin
# tntng : tntng
# sodik : sodik
# kelar : kelar
# tanding : tanding
# nglag : nglag
# samsek : samsek
# gakenapa : gakenapa
# modenya : mode
# siee : siee
# lukmantoro : lukmantoro
# arif : arif
# harijanto : harijanto
# syukurnya : syukur
# penolong : tolong
# wfh : wfh
# perbaikan : baik
# indra : indra
# diluar : luar
# jogja : jogja
# diem : diem
# wkt : wkt
# mamaku : mama
# dtgi : dtgi
# bkan : bkan
# maslah : mas
# tlfnin : tlfnin
# orng : orng
# berkat : berkat
# daku : daku
# marathon : marathon
# hawkeye : hawkeye
# reg : reg
# spasi : spasi
# nik : nik
# menu : menu
# ayoooo : ayoooo
# cepattt : cepattt
# rekrut : rekrut
# noona : noona
# memilki : memilki
# mengecek : ecek
# berkala : kala
# muh : muh
# privacy : privacy
# aryanugraha : aryanugraha
# teraktif : aktif
# klikflim : klikflim
# bls : bls
# terkuras : kuras
# kuata : kuata
# automatis : automatis
# teehhh : teehhh
# dira : dira
# dedi : dedi
# aura : aura
# pengecekannya : kece
# josss : josss
# adel : adel
# memakai : pakai
# taeyong : taeyong
# nyisa : nyisa
# coz : coz
# hezky : hezky
# ihh : ihh
# points : points
# fyadaus : fyadaus
# malkasih : malkasih
# pelan : pelan
# menjerit : jerit
# saripati : saripati
# bansos : bansos
# ngilang : ngilang
# fasya : fasya
# terblokir : blokir
# sumber : sumber
# permasalahannya : masalah
# tersedot : sedot
# astaghfirullah : astaghfirullah
# dikorbanin : dikorbanin
# not : not
# seriously : seriously
# dahlah : dah
# keblok : blok
# kubeli : bel
# bangettttt : bangettttt
# ngejelasin : ngejelasin
# dipercaya : percaya
# memancing : pancing
# ngehadapin : ngehadapin
# manusia : manusia
# endah : endah
# may : may
# mara : mara
# sialan : sial
# bgttt : bgttt
# wahyu : wahyu
# tetherin : tetherin
# berak : berak
# kebon : kebon
# bewan : bewan
# everywhere : everywhere
# sekebon : kebon
# kumat : kumat
# heh : heh
# browser : browser
# failed : failed
# paying : paying
# this : this
# kind : kind
# fix : fix
# kramat : kramat
# jati : jati
# lte : lte
# ngerti : ngerti
# tedri : tedri
# pinoh : pinoh
# trnyata : trnyata
# njirr : njirr
# perasaan : asa
# gandeng : gandeng
# padukan : padu
# tibubeneng : tibubeneng
# kuta : kuta
# kab : kab
# badung : badung
# dibongkar : bongkar
# ryan : ryan
# ngbarin : ngbarin
# mingguan : minggu
# gonta : gonta
# mematikan : mati
# kompak : kompak
# anjeng : anjeng
# duanya : dua
# ngantor : ngantor
# sepran : sepran
# sosmed : sosmed
# tiktokan : tiktokan
# wassap : wassap
# ngandelin : ngandelin
# kecepatannya : cepat
# send : send
# kepala : kepala
# reastart : reastart
# jue : jue
# oiyasih : oiyasih
# sono : sono
# manjat : manjat
# rahmad : rahmad
# ngopo : ngopo
# rban : rban
# ita : ita
# saudara : saudara
# ampana : ampana
# sulawesi : sulawesi
# suara : suara
# kasar : kasar
# diandelin : diandelin
# bbni : bbni
# gulirkan : gulir
# februari : februari
# belaku : bela
# wib : wib
# tahunnya : tahun
# fatma : fatma
# dibiarin : dibiarin
# nggo : nggo
# buffer : buffer
# memadukan : madu
# patungan : patungan
# bertiga : tiga
# tertarik : tarik
# zai : zai
# look : look
# karakter : karakter
# elite : elite
# pass : pass
# palace : palace
# poker : poker
# diamond : diamond
# radellia : radellia
# ngubungin : ngubungin
# nga : nga
# pengaruh : pengaruh
# mengerti : erti
# bangsatttttt : bangsatttttt
# euy : euy
# bacot : bacot
# gedein : gedein
# ngomong : ngomong
# asset : asset
# kwalitas : kwalitas
# pesaingnya : saing
# pertamina : pertamina
# bukit : bukit
# asam : asam
# pama : pama
# sejenisnya : jenis
# ren : ren
# disitu : situ
# elkan : elkan
# rubuh : rubuh
# terkena : kena
# bencana : bencana
# kocak : kocak
# dukung : dukung
# gilak : gilak
# mngpa : mngpa
# sngat : sngat
# kabel : kabel
# dicolong : colong
# dualuzi : dualuzi
# mual : mual
# bsk : bsk
# siiiihh : siiiihh
# banke : banke
# kemakan : makan
# alethea : alethea
# ary : ary
# kentut : kentut
# blg : blg
# wahahahahhahahxixixixixixic : wahahahahhahahxixixixixixic
# heyo : heyo
# galau : galau
# mgd : mgd
# meris : meris
# balasannya : balas
# tuliskan : tulis
# setting : setting
# kenyataannya : nyata
# yaallah : yaallah
# farro : farro
# manteb : manteb
# melalukan : lalu
# tertulis : tulis
# menemukan : temu
# disetel : setel
# even : even
# indo : indo
# cuy : cuy
# boring : boring
# kehabisan : habis
# sekalinya : sekali
# belain : bain
# cam : cam
# pulut : pulut
# telkoms : telkoms
# artiny : artiny
# cma : cma
# perbulan : bulan
# sksksksks : sksksksks
# akutuh : akutuh
# pemkot : pemkot
# poll : poll
# gratiss : gratiss
# away : away
# biznet : biznet
# napa : napa
# digabungin : digabungin
# ega : ega
# livan : livan
# maksaih : maksaih
# gws : gws
# pingnya : pingnya
# motong : motong
# sekelurahan : lurah
# cita : cita
# citata : citata
# ditunjukin : ditunjukin
# huum : huum
# pemberian : beri
# model : model
# soyie : soyie
# dika : dika
# acara : acara
# konser : konser
# musik : musik
# pro : pro
# host : host
# undang : undang
# partisipan : partisipan
# hidup : hidup
# dizaman : zaman
# nikola : nikola
# tesla : tesla
# abg : abg
# nggabisa : nggabisa
# nth : nth
# donk : donk
# samanya : sama
# terimakasi : terimakasi
# sihhh : sihhh
# woiiii : woiiii
# ahhh : ahhh
# gawangnya : gawang
# dibawaaah : dibawaaah
# smua : smua
# bangetttt : bangetttt
# sultan : sultan
# shit : shit
# connection : connection
# honestly : honestly
# properly : properly
# watch : watch
# final : final
# maen : maen
# yok : yok
# sich : sich
# beban : beban
# tongkrongan : tongkrong
# goooowww : goooowww
# napasi : napas
# stroberi : stroberi
# mangga : mangga
# nanas : nanas
# digebuk : gebuk
# yatuhan : yatuhan
# amalia : amalia
# dalem : dalem
# jhon : jhon
# ngana : ngana
# nyanda : nyanda
# penandatanganan : penandatanganan
# gaaaa : gaaaa
# fastrespon : fastrespon
# nebeng : nebeng
# sohib : sohib
# ngerasa : ngerasa
# jlk : jlk
# bangt : bangt
# gerimis : gerimis
# dengerin : dengerin
# lagu : lagu
# joox : joox
# vip : vip
# jutaan : juta
# berkualitas : kualitas
# rusak : rusak
# skarang : skarang
# kemusuhan : musuh
# fisini : fisini
# jatingan : jatingan
# ka : ka
# na : na
# pcs : pcs
# heboh : heboh
# menghitung : hitung
# menangkan : menang
# cokk : cokk
# seng : seng
# eska : eska
# terpotongnya : potong
# kringkring : kringkring
# saham : saham
# naek : naek
# mina : mina
# alhamdulillah : alhamdulillah
# alip : alip
# ampas : ampas
# kieu : kieu
# nyimak : nyimak
# choirul : choirul
# faiz : faiz
# woee : woee
# menukarnya : tukar
# topan : topan
# lanjutkan : lanjut
# interkasi : interkasi
# ken : ken
# temenku : temenku
# gramed : gramed
# jeje : jeje
# platinum : platinum
# downgrade : downgrade
# sesering : sering
# bernafas : nafas
# littleluv : littleluv
# auto : auto
# semalem : semalem
# teknis : teknis
# screen : screen
# shay : shay
# grgr : grgr
# uninstall : uninstall
# jung : jung
# fans : fans
# snowdrop : snowdrop
# mengatur : atur
# volte : volte
# terjangkau : jangkau
# rey : rey
# dinikmati : nikmat
# kriteria : kriteria
# terupdate : terupdate
# twnya : twnya
# bneran : bneran
# guck : guck
# sahabatku : sahabat
# laila : laila
# gencarkan : gencar
# transformasi : transformasi
# jfbaa : jfbaa
# oolyne : oolyne
# strip : strip
# ngape : ngape
# indihom : indihom
# kosan : kosan
# maksimum : maksimum
# bapakku : bapak
# stengah : stengah
# daring : daring
# gimna : gimna
# sabo : sabo
# marijoa : marijoa
# layla : layla
# merapat : rapat
# minimum : minimum
# bayarnya : bayar
# cok : cok
# gemes : gemes
# kadek : kadek
# financingrn : financingrn
# mandet : mandet
# oobe : oobe
# emuachchcgchchh : emuachchcgchchh
# dikonsumsi : konsumsi
# gina : gina
# higashi : higashi
# terbaru : baru
# mendownload : mendownload
# apliaksi : apliaksi
# malang : malang
# lawang : lawang
# fredo : fredo
# menteri : menteri
# menyakini : menyakini
# suksesnya : sukses
# penyelenggaraan : selenggara
# substansi : substansi
# berbatas : batas
# movie : movie
# pengin : pengin
# kebanyakan : banyak
# subscribe : subscribe
# netflik : netflik
# sepaket : paket
# bulutangkis : bulutangkis
# fadlan : fadlan
# header : header
# pakaimasker : pakaimasker
# simcard : simcard
# imei : imei
# diganti : ganti
# fredoo : fredoo
# belasan : bas
# melirik : lirik
# redilla : redilla
# before : before
# ngelesnya : ngelesnya
# baiklah : baik
# wkwkwkw : wkwkwkw
# ewink : ewink
# bundling : bundling
# stock : stock
# gakebaca : gakebaca
# kebaca : baca
# berlakunya : laku
# layar : layar
# hayukk : hayukk
# lovers : lovers
# tingkatkan : tingkat
# dinaekin : dinaekin
# sabrina : sabrina
# aned : aned
# tar : tar
# tertunda : tunda
# kenal : kenal
# kolaborasi : kolaborasi
# awalan : awal
# zahra : zahra
# sefruit : sefruit
# fakta : fakta
# rhino : rhino
# karya : karya
# tayang : tayang
# amerika : amerika
# serikat : serikat
# aps : aps
# gaad : gaad
# adirr : adirr
# appnya : appnya
# giman : gim
# really : really
# lol : lol
# keisha : keisha
# goziz : goziz
# hishh : hishh
# mksudnya : mksudnya
# identitas : identitas
# infromasi : infromasi
# diselenggarakan : selenggara
# wiwi : wiwi
# personal : personal
# profile : profile
# ditentukan : tentu
# yaaayyy : yaaayyy
# disetujui : tuju
# pemerintah : perintah
# terverifikasi : verifikasi
# tervalidasi : tervalidasi
# stpjm : stpjm
# pernyataan : nyata
# mutlak : mutlak
# aaak : aaak
# yeyyy : yeyyy
# trimaaaci : trimaaaci
# miminn : miminn
# {'': '', 'topp': 'topp', 'emang': 'emang', 'dianya': 'dia', 'hutan': 'hutan', 'saatny': 'saatny', 'poin': 'poin', 'telkomsel': 'telkomsel', 'hai': 'hai', 'kak': 'kak', 'keluhan': 'keluh', 'seputar': 'putar', 'produk': 'produk', 'layanan': 'layan', 'yuk': 'yuk', 'infoin': 'infoin', 'detail': 'detail', 'via': 'via', 'mimin': 'mimin', 'bantu': 'bantu', 'makasih': 'makasih', 'rin': 'rin', 'irt': 'irt', 'aldi': 'aldi', 'maaf': 'maaf', 'perihal': 'perihal', 'menerima': 'terima', 'sms': 'sms', 'nofitikasi': 'nofitikasi', 'berulang': 'ulang', 'nomor': 'nomor', 'kejadian': 'jadi', 'lokasi': 'lokasi', 'kecamatan': 'camat', 'kelurahan': 'lurah', 'kota': 'kota', 'cek': 'cek', 'tindak': 'tindak', 'selamat': 'selamat', 'beraktivitas': 'aktivitas', 'steve': 'steve', 'nonton': 'nonton', 'film': 'film', 'download': 'download', 'disney': 'disney', 'nder': 'nder', 'min': 'min', 'stop': 'stop', 'smsnya': 'smsnya', 'gimana': 'gimana', 'habis': 'habis', 'daftar': 'daftar', 'paket': 'paket', 'mytelkomsel': 'mytelkomsel', 'terusan': 'terus', 'kayak': 'kayak', 'gini': 'gin', 'sampe': 'sampe', 'dial': 'dial', 'info': 'info', 'lengkapnya': 'lengkap', 'semoga': 'moga', 'membantu': 'bantu', 'kia': 'kia', 'letna': 'letna', 'terkait': 'kait', 'kakak': 'kakak', 'tukarkan': 'tukar', 'telepon': 'telepon', 'internet': 'internet', 'digital': 'digital', 'nsp': 'nsp', 'video': 'video', 'games': 'games', 'diskon': 'diskon', 'menarik': 'tarik', 'merchant': 'merchant', 'bekerjasama': 'bekerjasama', 'saldo': 'saldo', 'linkaja': 'linkaja', 'aplikasi': 'aplikasi', 'hallo': 'hallo', 'guys': 'guys', 'tolong': 'tolong', 'habisin': 'habisin', 'sayang': 'sayang', 'banget': 'banget', 'tinggal': 'tinggal', 'sehari': 'hari', 'huhu': 'huhu', 'diperpanjang': 'panjang', 'btw': 'btw', 'error': 'error', 'mulu': 'mulu', 'kah': 'kah', 'program': 'program', 'khusus': 'khusus', 'pelanggan': 'langgan', 'prabayar': 'prabayar', 'komunitas': 'komunitas', 'tertutup': 'tutup', 'dimana': 'mana', 'terbuka': 'buka', 'kalangan': 'kalang', 'hadi': 'had', 'kirim': 'kirim', 'masuk': 'masuk', 'list': 'list', 'antrian': 'antri', 'mohon': 'mohon', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'interaksi': 'interaksi', 'tks': 'tks', 'cris': 'cris', 'keterlambatan': 'lambat', 'balasan': 'balas', 'diterima': 'terima', 'silakan': 'sila', 'konfirmasi': 'konfirmasi', 'lina': 'lina', 'biasce': 'biasce', 'maafin': 'maafin', 'ceritain': 'ceritain', 'pertanyaannya': 'tanya', 'langsung': 'langsung', 'nge': 'nge', 'privasi': 'privasi', 'terjaga': 'jaga', 'dpt': 'dpt', 'dibantu': 'bantu', 'sedih': 'sedih', 'pulang': 'pulang', 'kampung': 'kampung', 'total': 'total', 'ribuan': 'ribu', 'hangus': 'hangus', 'meninggoy': 'meninggoy', 'infokan': 'info', 'monetary': 'monetary', 'telpon': 'telpon', 'voucher': 'voucher', 'berbeda': 'beda', 'zabo': 'zabo', 'kebalikanny': 'kebalikanny', 'dirumah': 'rumah', 'gada': 'gada', 'sinyal': 'sinyal', 'gue': 'gue', 'liat': 'liat', 'apk': 'apk', 'seribu': 'ribu', 'gitu': 'gitu', 'rani': 'rani', 'pengguna': 'guna', 'lupa': 'lupa', 'tukerin': 'tukerin', 'basah': 'basah', 'isi': 'isi', 'pulsa': 'pulsa', 'banking': 'banking', 'jam': 'jam', 'nmr': 'nmr', 'tgl': 'tgl', 'capture': 'capture', 'pembelian': 'beli', 'trims': 'trims', 'pagi': 'pagi', 'mbanking': 'mbanking', 'rekening': 'rekening', 'terdebet': 'debet', 'udh': 'udh', 'ditunggu': 'tunggu', 'ciye': 'ciye', 'kena': 'kena', 'prank': 'prank', 'kenapaaa': 'kenapaaa', 'sabar': 'sabar', 'meluncur': 'luncur', 'yaaa': 'yaaa', 'jul': 'jul', 'semangat': 'semangat', 'arya': 'arya', 'kendala': 'kendala', 'keterangan': 'terang', 'gagal': 'gagal', 'admin': 'admin', 'knp': 'knp', 'yyyy': 'yyyy', 'provider': 'provider', 'lisa': 'lisa', 'blekping': 'blekping', 'ian': 'ian', 'reaktivasi': 'reaktivasi', 'boros': 'boros', 'menfess': 'menfess', 'iya': 'iya', 'kuota': 'kuota', 'dapet': 'dapet', 'gratis': 'gratis', 'langganan': 'langgan', 'sebulan': 'bulan', 'lumayan': 'lumayan', 'agiegi': 'agiegi', 'extra': 'extra', 'aktif': 'aktif', 'pengecekan': 'kece', 'rand ...
# ------------------------
# Pandas Apply:   0%|          | 0/1893 [00:00<?, ?it/s]
#                                                 content  \
# 0     @telkomsel @bengbeng_topp emang dianya aja ka ...
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     @sunyoursoui hai, kak. apabila  ada pertanyaan...
# 3     @luthfi_irt hai, kak aldi. maaf ya perihal kel...
# 4     @convomfs telkomsel kan, nonton film/download ...
# ...                                                 ...
# 1995  @telkomsel yaaayyy sama2 kak &lt;3 untuk menge...
# 1996  @zahrazaaaa sama-sama, kak zahra. makasih udah...
# 1997  @bocahngapag yang telah disetujui oleh pemerin...
# 1998  @bocahngapag hi, kak. maaf ya mengenai kuota i...
# 1999          @telkomsel aaak yeyyy trimaaaci miminn 💖✨
#
#                                          cleaning_tweet  \
# 0                    topp emang dianya aja hutan kwkwkw
# 1            akhir tahun saatny aku pake poin telkomsel
# 2     hai kak apabila ada pertanyaan atau keluhan se...
# 3      irt hai kak aldi maaf perihal keluhan menerim...
# 4     telkomsel kan nonton film download    disney nder
# ...                                                 ...
# 1995  yaaayyy sama  kak untuk mengecek apakah nomor ...
# 1996  sama sama kak zahra makasih udah menghubungi l...
# 1997  yang telah disetujui oleh pemerintah kak info ...
# 1998   kak maaf mengenai kuota internet pemerintah a...
# 1999                       aaak yeyyy trimaaaci miminn
#
#                                              tokenisasi  \
# 0           [, topp, emang, dianya, aja, hutan, kwkwkw]
# 1     [akhir, tahun, saatny, aku, pake, poin, telkom...
# 2     [hai, kak, apabila, ada, pertanyaan, atau, kel...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluhan...
# 4     [telkomsel, kan, nonton, film, download, disne...
# ...                                                 ...
# 1995  [yaaayyy, sama, kak, untuk, mengecek, apakah, ...
# 1996  [sama, sama, kak, zahra, makasih, udah, menghu...
# 1997  [yang, telah, disetujui, oleh, pemerintah, kak...
# 1998  [, kak, maaf, mengenai, kuota, internet, pemer...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
#                                                stopword  \
# 0                        [, topp, emang, dianya, hutan]
# 1                             [saatny, poin, telkomsel]
# 2     [hai, kak, keluhan, seputar, produk, layanan, ...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluhan...
# 4     [telkomsel, nonton, film, download, disney, nder]
# ...                                                 ...
# 1995  [yaaayyy, kak, mengecek, nomor, masi, aktif, k...
# 1996  [kak, zahra, makasih, udah, menghubungi, layan...
# 1997  [disetujui, pemerintah, kak, info, detail, kuo...
# 1998  [, kak, maaf, kuota, internet, pemerintah, lan...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
#                                                stemming
# 0                           [, topp, emang, dia, hutan]
# 1                             [saatny, poin, telkomsel]
# 2     [hai, kak, keluh, putar, produk, layan, telkom...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluh, ...
# 4     [telkomsel, nonton, film, download, disney, nder]
# ...                                                 ...
# 1995     [yaaayyy, kak, ecek, nomor, mas, aktif, kak, ]
# 1996  [kak, zahra, makasih, udah, hubung, layan, cus...
# 1997  [tuju, perintah, kak, info, detail, kuota, int...
# 1998  [, kak, maaf, kuota, internet, perintah, langs...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
# [1893 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0                           [, topp, emang, dia, hutan]
# 1                             [saatny, poin, telkomsel]
# 2     [hai, kak, keluh, putar, produk, layan, telkom...
# 3     [, irt, hai, kak, aldi, maaf, perihal, keluh, ...
# 4     [telkomsel, nonton, film, download, disney, nder]
# ...                                                 ...
# 1995     [yaaayyy, kak, ecek, nomor, mas, aktif, kak, ]
# 1996  [kak, zahra, makasih, udah, hubung, layan, cus...
# 1997  [tuju, perintah, kak, info, detail, kuota, int...
# 1998  [, kak, maaf, kuota, internet, perintah, langs...
# 1999                 [aaak, yeyyy, trimaaaci, miminn, ]
#
# [1893 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_12.xlsx')
