# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @shoeelltan Maaf ya atas keterlambatan responn...
# 1     @hardee_90 Pagi, Kak Hardi. Mengenai informasi...
# 2     Nonton bajakan sih terserah ente, tapi ampe no...
# 3     #citatones yuk aktifin NSP cita_citata #sakitn...
# 4                 @Telkomsel pagi min boleh info orbit?
# ...                                                 ...
# 1995                                @joocnie @Telkomsel
# 1996  @Telkomsel Dan sampai skrg tidak ada respon sa...
# 1997  @Telkomsel Apakah terus bisa menerima sms dan ...
# 1998  @muktitiar Hai, Kak Tiar. Maaf ya, mengenai ma...
# 1999                          @joocnie brisik Telkomsel
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 28

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @shoeelltan Maaf ya atas keterlambatan responn...
# 1     @hardee_90 Pagi, Kak Hardi. Mengenai informasi...
# 2     Nonton bajakan sih terserah ente, tapi ampe no...
# 4                 @Telkomsel pagi min boleh info orbit?
# 5     @RifkiAljabar Okay, Kak Aljaber. Mimin cek DM ...
# ...                                                 ...
# 1995                                @joocnie @Telkomsel
# 1996  @Telkomsel Dan sampai skrg tidak ada respon sa...
# 1997  @Telkomsel Apakah terus bisa menerima sms dan ...
# 1998  @muktitiar Hai, Kak Tiar. Maaf ya, mengenai ma...
# 1999                          @joocnie brisik Telkomsel
#
# [1951 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @shoeelltan maaf ya atas keterlambatan responn...
# 1     @hardee_90 pagi, kak hardi. mengenai informasi...
# 2     nonton bajakan sih terserah ente, tapi ampe no...
# 4                 @telkomsel pagi min boleh info orbit?
# 5     @rifkialjabar okay, kak aljaber. mimin cek dm ...
# ...                                                 ...
# 1995                                @joocnie @telkomsel
# 1996  @telkomsel dan sampai skrg tidak ada respon sa...
# 1997  @telkomsel apakah terus bisa menerima sms dan ...
# 1998  @muktitiar hai, kak tiar. maaf ya, mengenai ma...
# 1999                          @joocnie brisik telkomsel
#
# [1951 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @shoeelltan maaf ya atas keterlambatan responn...
# 1     @hardee_90 pagi, kak hardi. mengenai informasi...
# 2     nonton bajakan sih terserah ente, tapi ampe no...
# 4                 @telkomsel pagi min boleh info orbit?
# 5     @rifkialjabar okay, kak aljaber. mimin cek dm ...
# ...                                                 ...
# 1995                                @joocnie @telkomsel
# 1996  @telkomsel dan sampai skrg tidak ada respon sa...
# 1997  @telkomsel apakah terus bisa menerima sms dan ...
# 1998  @muktitiar hai, kak tiar. maaf ya, mengenai ma...
# 1999                          @joocnie brisik telkomsel
#
#                                          cleaning_tweet
# 0     maaf atas keterlambatan responnya kak mimin ce...
# 1      pagi kak hardi mengenai informasi seputar pro...
# 2     nonton bajakan sih terserah ente tapi ampe non...
# 4                            pagi min boleh info orbit
# 5     okay kak aljaber mimin cek kakak udah masuk mo...
# ...                                                 ...
# 1995
# 1996  dan sampai skrg tidak ada respon sama sekali h...
# 1997         apakah terus bisa menerima sms dan telpon
# 1998  hai kak tiar maaf mengenai masa tenggang sudah...
# 1999                                   brisik telkomsel
#
# [1951 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @shoeelltan maaf ya atas keterlambatan responn...
# 1     @hardee_90 pagi, kak hardi. mengenai informasi...
# 2     nonton bajakan sih terserah ente, tapi ampe no...
# 4                 @telkomsel pagi min boleh info orbit?
# 5     @rifkialjabar okay, kak aljaber. mimin cek dm ...
# ...                                                 ...
# 1995                                @joocnie @telkomsel
# 1996  @telkomsel dan sampai skrg tidak ada respon sa...
# 1997  @telkomsel apakah terus bisa menerima sms dan ...
# 1998  @muktitiar hai, kak tiar. maaf ya, mengenai ma...
# 1999                          @joocnie brisik telkomsel
#
#                                          cleaning_tweet  \
# 0     maaf atas keterlambatan responnya kak mimin ce...
# 1      pagi kak hardi mengenai informasi seputar pro...
# 2     nonton bajakan sih terserah ente tapi ampe non...
# 4                            pagi min boleh info orbit
# 5     okay kak aljaber mimin cek kakak udah masuk mo...
# ...                                                 ...
# 1995
# 1996  dan sampai skrg tidak ada respon sama sekali h...
# 1997         apakah terus bisa menerima sms dan telpon
# 1998  hai kak tiar maaf mengenai masa tenggang sudah...
# 1999                                   brisik telkomsel
#
#                                              tokenisasi
# 0     [maaf, atas, keterlambatan, responnya, kak, mi...
# 1     [, pagi, kak, hardi, mengenai, informasi, sepu...
# 2     [nonton, bajakan, sih, terserah, ente, tapi, a...
# 4                     [pagi, min, boleh, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [dan, sampai, skrg, tidak, ada, respon, sama, ...
# 1997  [apakah, terus, bisa, menerima, sms, dan, telp...
# 1998  [hai, kak, tiar, maaf, mengenai, masa, tenggan...
# 1999                                [brisik, telkomsel]
#
# [1951 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @shoeelltan maaf ya atas keterlambatan responn...
# 1     @hardee_90 pagi, kak hardi. mengenai informasi...
# 2     nonton bajakan sih terserah ente, tapi ampe no...
# 4                 @telkomsel pagi min boleh info orbit?
# 5     @rifkialjabar okay, kak aljaber. mimin cek dm ...
# ...                                                 ...
# 1995                                @joocnie @telkomsel
# 1996  @telkomsel dan sampai skrg tidak ada respon sa...
# 1997  @telkomsel apakah terus bisa menerima sms dan ...
# 1998  @muktitiar hai, kak tiar. maaf ya, mengenai ma...
# 1999                          @joocnie brisik telkomsel
#
#                                          cleaning_tweet  \
# 0     maaf atas keterlambatan responnya kak mimin ce...
# 1      pagi kak hardi mengenai informasi seputar pro...
# 2     nonton bajakan sih terserah ente tapi ampe non...
# 4                            pagi min boleh info orbit
# 5     okay kak aljaber mimin cek kakak udah masuk mo...
# ...                                                 ...
# 1995
# 1996  dan sampai skrg tidak ada respon sama sekali h...
# 1997         apakah terus bisa menerima sms dan telpon
# 1998  hai kak tiar maaf mengenai masa tenggang sudah...
# 1999                                   brisik telkomsel
#
#                                              tokenisasi  \
# 0     [maaf, atas, keterlambatan, responnya, kak, mi...
# 1     [, pagi, kak, hardi, mengenai, informasi, sepu...
# 2     [nonton, bajakan, sih, terserah, ente, tapi, a...
# 4                     [pagi, min, boleh, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [dan, sampai, skrg, tidak, ada, respon, sama, ...
# 1997  [apakah, terus, bisa, menerima, sms, dan, telp...
# 1998  [hai, kak, tiar, maaf, mengenai, masa, tenggan...
# 1999                                [brisik, telkomsel]
#
#                                                stopword
# 0     [maaf, keterlambatan, responnya, kak, mimin, c...
# 1     [, pagi, kak, hardi, informasi, seputar, produ...
# 2     [nonton, bajakan, terserah, ente, ampe, nonton...
# 4                            [pagi, min, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [skrg, respon, hebat, bener, kerja, provider, ...
# 1997                          [menerima, sms, telpon, ]
# 1998  [hai, kak, tiar, maaf, tenggang, udah, diaktif...
# 1999                                [brisik, telkomsel]
#
# [1951 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3589
# ------------------------
# maaf : maaf
# keterlambatan : lambat
# responnya : responnya
# kak : kak
# mimin : mimin
# cek : cek
# kakak : kakak
# list : list
# antrian : antri
# mohon : mohon
# tunggu : tunggu
# balasan : balas
# makasih : makasih
# ruina : ruina
#  :
# pagi : pagi
# hardi : hardi
# informasi : informasi
# seputar : putar
# produk : produk
# layanan : layan
# orbit : orbit
# mengubungi : ubung
# twitter : twitter
# myorbitid : myorbitid
# email : email
# semoga : moga
# membantu : bantu
# vivi : vivi
# nonton : nonton
# bajakan : baja
# terserah : serah
# ente : ente
# ampe : ampe
# film : film
# disney : disney
# series : series
# kebangetan : banget
# wkwkwk : wkwkwk
# udh : udh
# murah : murah
# modal : modal
# rebu : rebu
# beli : beli
# paket : paket
# telkomsel : telkomsel
# dapet : dapet
# sebulan : bulan
# streaming : streaming
# masi : mas
# ngebajak : ngebajak
# min : min
# info : info
# okay : okay
# aljaber : aljaber
# udah : udah
# masuk : masuk
# mengirim : kirim
# foto : foto
# sidoarjo : sidoarjo
# aneh : aneh
# banget : banget
# update : update
# bagus : bagus
# kualitas : kualitas
# appnya : appnya
# menguji : uji
# kesabaran : sabar
# paketan : paket
# gajadi : gajadi
# gini : gin
# mah : mah
# cels : cels
# ditunggu : tunggu
# interaksi : interaksi
# meluncur : luncur
# gimana : gimana
# kayake : kayake
# murce : murce
# tolong : tolong
# terima : terima
# kasih : kasih
# menunggu : tunggu
# terkait : kait
# berhenti : henti
# berlangganan : langgan
# halo : halo
# silakan : sila
# infoin : infoin
# nomor : nomor
# nama : nama
# lengkap : lengkap
# tgl : tgl
# lahir : lahir
# via : via
# bantu : bantu
# privasi : privasi
# data : data
# terjaga : jaga
# davidzan : davidzan
# nyaman : nyaman
# aplikasi : aplikasi
# mytelkomsel : mytelkomsel
# transaksi : transaksi
# linkaja : linkaja
# shopeepay : shopeepay
# gopay : gopay
# ovo : ovo
# akses : akses
# internet : internet
# lambat : lambat
# coba : coba
# off : off
# airplane : airplane
# mode : mode
# yuk : yuk
# kejadian : jadi
# lokasi : lokasi
# kendala : kendala
# dibantu : bantu
# tks : tks
# nur : nur
# sinyal : sinyal
# lemah : lemah
# stabil : stabil
# mencoba : coba
# refresh : refresh
# jaringan : jaring
# pindahkan : pindah
# otomatis : otomatis
# manual : manual
# kembalikan : kembali
# jam : jam
# operasional : operasional
# senin : senin
# jum : jum
# buka : buka
# sabtu : sabtu
# minggu : minggu
# libur : libur
# nasional : nasional
# tutup : tutup
# rai : rai
# nunggu : nunggu
# pramudi : pramudi
# grapari : grapari
# wilayah : wilayah
# tangerang : tangerang
# selatan : selatan
# beroperasi : operasi
# ppkm : ppkm
# darurat : darurat
# temukan : temu
# ciputat : ciputat
# beralamatkan : alamat
# dewi : dewi
# sartika : sartika
# support : support
# wallet : wallet
# dana : dana
# apk : apk
# mustain : mustain
# maxstream : maxstream
# menonton : tonton
# vidio : vidio
# sesuai : sesuai
# tertera : tera
# byu : byu
# mantep : mantep
# harga : harga
# bonusnya : bonus
# custom : custom
# nomer : nomer
# jugaa : jugaa
# barbar : barbar
# berkendala : kendala
# infokan : info
# capture : capture
# keterangan : terang
# didapatkan : dapat
# natalia : natalia
# keluhan : keluh
# ikuti : ikut
# panduan : pandu
# restart : restart
# handphone : handphone
# pastikan : pasti
# versi : versi
# terbaru : baru
# lakukan : laku
# clear : clear
# cache : cache
# force : force
# stop : stop
# bapuk : bapuk
# woiiii : woiiii
# hayati : hayati
# mbaa : mbaa
# salam : salam
# kenal : kenal
# mengalami : alami
# lapor : lapor
# hasilnya : hasil
# kmrm : kmrm
# dpt : dpt
# sms : sms
# terlogut : terlogut
# datanya : data
# dicoba : coba
# iseng : iseng
# login : login
# keep : keep
# updated : updated
# mba : mba
# yaa : yaa
# thanks : thanks
# pakai : pakai
# kuota : kuota
# ekason : ekason
# tagihan : tagih
# google : google
# play : play
# music : music
# teakhir : teakhir
# rp : rp
# ribu : ribu
# atm : atm
# livin : livin
# mandiri : mandiri
# bonus : bonus
# tambahan : tambah
# sampe : sampe
# kuotanya : kuota
# googlemusic : googlemusic
# apps : apps
# oktober : oktober
# bln : bln
# komplain : komplain
# diselesaikan : selesai
# customer : customer
# ditagih : tagih
# dirugikan : rugi
# saran : saran
# broh : broh
# emridwan : emridwan
# ridwan : ridwan
# now : now
# mahal : mahal
# sinopharm : sinopharm
# vaksin : vaksin
# gotong : gotong
# royong : royong
# perusahaan : usaha
# mendaftarkan : daftar
# karyawannya : karyawannya
# kadin : kadin
# contoh : contoh
# gojek : gojek
# indonesia : indonesia
# dll : dll
# ayo : ayo
# convert : convert
# pulsa : pulsa
# provider : provider
# tri : tri
# tsel : tsel
# open : open
# kesini : kesini
# suhendra : suhendra
# sebentar : sebentar
# pengguna : guna
# gratis : gratis
# promo : promo
# dipakai : pakai
# memenuhi : penuh
# langganan : langgan
# kartu : kartu
# bgmn : bgmn
# bulanan : bulan
# bete : bete
# japan : japan
# poland : poland
# bismillah : bismillah
# wish : wish
# luck : luck
# ree : ree
# telpon : telpon
# pembagian : bagi
# malam : malam
# hai : hai
# kurnia : kurnia
# dibeli : beli
# menerima : terima
# penawaran : tawar
# memiliki : milik
# batas : batas
# pengaktifan : aktif
# berlaku : laku
# kesediaannya : sedia
# padat : padat
# pengertiannya : erti
# emang : emang
# enak : enak
# combo : combo
# sakti : sakti
# unlimited : unlimited
# ngaktifin : ngaktifin
# max : max
# omg : omg
# nyari : nyari
# pas : pas
# ide : ide
# umkm : umkm
# pendanaan : dana
# solusi : solusi
# kreatifmu : kreatif
# digihackaction : digihackaction
# kesempatan : sempat
# lewatkan : lewat
# hadiah : hadiah
# total : total
# senilai : nila
# juta : juta
# daftar : daftar
# hr : hr
# logout : logout
# uninstall : uninstall
# tetep : tetep
# permintaan : minta
# antrean : antre
# cia : cia
# sumpah : sumpah
# bumn : bumn
# mesti : mesti
# link : link
# valid : valid
# detik : detik
# lemot : lot
# gagal : gagal
# log : log
# mulu : mulu
# asli : asli
# tahi : tahi
# ryan : ryan
# aktivasi : aktivasi
# isi : isi
# harian : hari
# kali : kali
# audra : audra
# wendy : wendy
# alami : alami
# konfirmasi : konfirmasi
# dmnya : dmnya
# rumah : rumah
# zakat : zakat
# majelis : majelis
# taqwa : taqwa
# salurkan : salur
# sembako : sembako
# area : area
# malang : malang
# gangguan : ganggu
# daerah : daerah
# sekitaran : sekitar
# bandara : bandara
# soekarno : soekarno
# hatta : hatta
# berkenan : kenan
# need : need
# bayar : bayar
# disekitar : sekitar
# sepatan : sepat
# terdeteksi : deteksi
# service : service
# pdhl : pdhl
# hard : hard
# shine : shine
# status : status
# reaktivasi : reaktivasi
# biantu : biantu
# punyaku : punya
# hangus : hangus
# juni : juni
# diaktifkan : aktif
# kah : kah
# memilih : pilih
# fila : fila
# bola : bola
# alasannya : alas
# jackpot : jackpot
# member : member
# dibayar : bayar
# depo : depo
# main : main
# slot : slot
# game : game
# potongan : potong
# hubungi : hubung
# whatsapp : whatsapp
# nikmati : nikmat
# menarik : tarik
# tersedia : sedia
# filabola : filabola
# deposit : deposit
# pay : pay
# diurus : urus
# bro : bro
# dapatkan : dapat
# gb : gb
# oke : oke
# gile : gile
# jaman : jaman
# orba : orba
# woii : woii
# gek : gek
# kau : kau
# app : app
# pubg : pubg
# kalah : kalah
# peluru : peluru
# iky : iky
# penggunaan : guna
# multimedia : multimedia
# miliki : milik
# lumy : lumy
# butuh : butuh
# scan : scan
# barcode : barcode
# klik : klik
# mulitimedia : mulitimedia
# menghabisakannya : menghabisakannya
# tenggang : tenggang
# mati : mati
# aktifin : aktifin
# sadar : sadar
# tulisannya : tulis
# tiada : tiada
# kirain : kirain
# sebulanan : bulan
# suruh : suruh
# ciaa : ciaa
# senggol : senggol
# cdm : cdm
# fathurrohman : fathurrohman
# khawatir : khawatir
# aktifkan : aktif
# maw : maw
# kek : kek
# ndra : ndra
# dewa : dewa
# the : the
# backbone : backbone
# tower : tower
# eko : eko
# enakan : enak
# im : im
# manteb : manteb
# malem : malem
# jawabannya : jawab
# ngantuk : ngantuk
# alya : alya
# kirim : kirim
# aizen : aizen
# balas : balas
# mahfuedz : mahfuedz
# dibalas : balas
# pdhal : pdhal
# kontak : kontak
# kemari : kemari
# bsk : bsk
# rencana : rencana
# hectic : hectic
# bingung : bingung
# cari : cari
# updatenya : updatenya
# hpnya : hpnya
# normal : normal
# sayangnya : sayang
# seminggu : minggu
# blm : blm
# perubahan : ubah
# smpt : smpt
# dihibur : hibur
# menit : menit
# trs : trs
# gone : gone
# smp : smp
# amit : amit
# jaringannya : jaring
# woy : woy
# siang : siang
# bales : bales
# listya : listya
# aong : aong
# paham : paham
# ong : ong
# sekar : sekar
# kemarin : kemarin
# format : format
# mengisi : isi
# pribadi : pribadi
# bermasalah : masalah
# disuruh : suruh
# berharap : harap
# berangsur : angsur
# sembuh : sembuh
# gua : gua
# maafin : maafin
# berkurang : kurang
# tanggal : tanggal
# raama : raama
# izin : izin
# admin : admin
# sushi : sushi
# zenin : zenin
# terpotong : potong
# abis : abis
# gara : gara
# babi : babi
# ngentot : ngentot
# anjing : anjing
# napa : napa
# indihome : indihome
# lag : lag
# kaya : kaya
# ceria : ceria
# diterima : terima
# channel : channel
# fanuel : fanuel
# mengaktifkan : aktif
# amazon : amazon
# prime : prime
# video : video
# menikmati : nikmat
# roaming : roaming
# western : western
# aktif : aktif
# kena : kena
# charge : charge
# kenapasih : kenapasih
# bangke : bangke
# keperluan : perlu
# ditangani : tangan
# sapa : sapa
# perihal : perihal
# kecamatan : camat
# kota : kota
# baba : baba
# rizki : rizki
# salah : salah
# orang : orang
# anying : anying
# panik : panik
# bujet : bujet
# naek : naek
# boss : boss
# zzz : zzz
# yth : yth
# berantaslah : rantas
# maling : maling
# disaat : saat
# indosat : indosat
# smartfren : smartfren
# sedot : sedot
# matikan : mati
# seluler : seluler
# msh : msh
# bkn : bkn
# kesalahan : salah
# tekhnologi : tekhnologi
# optrnya : optrnya
# mental : mental
# icha : icha
# aahhh : aahhh
# tdi : tdi
# nnton : nnton
# habis : habis
# pket : pket
# internetku : internetku
# gbisa : gbisa
# pke : pke
# kmvrt : kmvrt
# team : team
# cowo : cowo
# jepang : jepang
# ktanya : ktanya
# maen : maen
# hri : hri
# pnsaran : pnsaran
# liat : liat
# fake : fake
# set : set
# mreka : mreka
# viral : viral
# nurul : nurul
# senang : senang
# hati : hati
# merespon : merespon
# senjata : senjata
# pamungkas : pamungkas
# rena : rena
# gue : gue
# lenyap : lenyap
# bener : bener
# emosi : emosi
# saiki : saiki
# wis : wis
# bundle : bundle
# karo : karo
# maestro : maestro
# ozzy : ozzy
# berwenang : wenang
# sediain : ain
# gasemua : gasemua
# suka : suka
# hand : hand
# hape : hape
# tangan : tangan
# pertimbangan : timbang
# terimakasih : terimakasih
# cma : cma
# sampein : sampein
# berulang : ulang
# root : root
# case : case
# selesai : selesai
# abdul : abdul
# rochim : rochim
# fauji : fauji
# jakarta : jakarta
# telepon : telepon
# penyelesaian : selesai
# laporkan : lapor
# tindakan : tindak
# solusinya : solusi
# ditampung : tampung
# lokal : lokal
# dimiliki : milik
# jenis : jenis
# detail : detail
# secepatnya : cepat
# ind : ind
# sat : sat
# emg : emg
# terdaftarnya : daftar
# pertanyaannya : tanya
# kecepatannya : cepat
# seringan : sering
# menyesal : sesal
# pelanggan : langgan
# kerja : kerja
# alhamdulillah : alhamdulillah
# gada : gada
# ketinggalan : tinggal
# cuman : cuman
# live : live
# nyendat : nyendat
# kecuali : kecuali
# taehyung : taehyung
# lancar : lancar
# jaya : jaya
# doang : doang
# lombok : lombok
# sawi : sawi
# costumer : costumer
# care : care
# resminya : resmi
# call : call
# centernya : centernya
# aksi : aksi
# seru : seru
# olimpiade : olimpiade
# besok : besok
# pertandinganya : pertandinganya
# nungguin : nungguin
# pertandingan : tanding
# guys : guys
# laras : laras
# posisinya : posisi
# wifinya : wifinya
# gatau : gatau
# deh : deh
# males : males
# maap : maap
# kecewa : kecewa
# sebenernya : sebenernya
# gapernah : gapernah
# sekecewa : kecewa
# intinya : inti
# ngentod : ngentod
# baca : baca
# berubah : ubah
# voucher : voucher
# setahun : tahun
# inget : inget
# tim : tim
# timor : timor
# perahu : perahu
# gunung : gunung
# perbatasan : batas
# signal : signal
# leste : leste
# nge : nge
# laporan : lapor
# opo : opo
# sek : sek
# nek : nek
# ntar : ntar
# disambungkan : sambung
# mbak : mbak
# veronica : veronica
# brandon : brandon
# dicek : cek
# koneksinya : koneksi
# servicenya : servicenya
# kesel : kesel
# donlot : donlot
# bolak : bolak
# eror : eror
# endingnya : endingnya
# ngulang : ngulang
# sedangkn : sedangkn
# kebuang : buang
# lumayan : lumayan
# hmpir : hmpir
# segigaan : segigaan
# trus : trus
# bae : bae
# bergiga : bergiga
# giga : giga
# yaallah : yaallah
# ngegame : ngegame
# njing : njing
# gaming : gaming
# adi : adi
# jangkrik : jangkrik
# laporannya : lapor
# arahkan : arah
# tbk : tbk
# mengusut : usut
# pelaku : laku
# peretasan : retas
# konsumen : konsumen
# layak : layak
# perlindungan : lindung
# tandatangani : tandatangani
# petisi : petisi
# pindah : pindah
# mentingin : mentingin
# kotak : kotak
# penuh : penuh
# dellan : dellan
# nsp : nsp
# conten : conten
# dibuka : buka
# langsung : langsung
# toriq : toriq
# jumat : jumat
# antre : antre
# menggila : gila
# nelpon : nelpon
# operator : operator
# mbahmu : mbah
# tino : tino
# berinteraksi : interaksi
# menghubungi : hubung
# digital : digital
# sungkan : sungkan
# sehat : sehat
# lupa : lupa
# dibuatkan : buat
# promosi : promosi
# lijen : lijen
# rico : rico
# makasi : makas
# infonya : info
# android : android
# marshmallow : marshmallow
# download : download
# lite : lite
# ringan : ringan
# wkkwkw : wkkwkw
# kartuku : kartu
# haloo : haloo
# dkk : dkk
# kawa : kawa
# premium : premium
# dipindah : pindah
# wifi : wifi
# tepakai : tepakai
# cemtu : cemtu
# mengerti : erti
# tydack : tydack
# willyan : willyan
# ngapain : ngapain
# macet : macet
# model : model
# lihat : lihat
# melaporkan : lapor
# tertanggal : tanggal
# juli : juli
# database : database
# kemaren : kemaren
# menampung : tampung
# custumercare : custumercare
# klw : klw
# berguna : guna
# bubarkan : bubar
# departemen : departemen
# iksan : iksan
# ronald : ronald
# respon : respon
# koneksi : koneksi
# elu : elu
# beres : beres
# ari : ari
# nnonton : nnonton
# tokyo : tokyo
# minimal : minimal
# embuh : embuh
# nggak : nggak
# spesifikasi : spesifikasi
# musti : musti
# spek : spek
# isinya : isi
# pembelian : beli
# quota : quota
# emilia : emilia
# pindahin : pindahin
# turun : turun
# pingnya : pingnya
# seharian : hari
# segini : gin
# superdeal : superdeal
# kecepatan : cepat
# dibatasi : batas
# halooo : halooo
# urgent : urgent
# ngajak : ngajak
# ributttt : ributttt
# ibank : ibank
# sarankan : saran
# follow : follow
# akun : akun
# cooll : cooll
# kenceng : kenceng
# beda : beda
# terindikasi : indikasi
# spam : spam
# blokir : blokir
# pembicaraan : bicara
# lewar : lewar
# pengumuman : umum
# woi : woi
# cepet : cepet
# youtube : youtube
# allah : allah
# swt : swt
# menghilangkan : hilang
# wabah : wabah
# covid : covid
# arin : arin
# vikri : vikri
# informasikan : informasi
# tlpn : tlpn
# cepat : cepat
# kolektip : kolektip
# org : org
# jawannya : jawannya
# terpasang : pasang
# pasang : pasang
# kebutuhan : butuh
# reply : reply
# finally : finally
# smua : smua
# tpi : tpi
# bagas : bagas
# tetangga : tetangga
# ngalamin : ngalamin
# kyk : kyk
# benahin : benahin
# meneror : teror
# jebakan : jebak
# batman : batman
# sengaja : sengaja
# kebuka : buka
# hilang : hilang
# dipiara : piara
# sepele : sepele
# rugi : rugi
# dipke : dipke
# sejam : jam
# tungguin : tungguin
# singkat : singkat
# dipandu : pandu
# terhubung : hubung
# rekan : rekan
# emelia : emelia
# veronika : veronika
# dikembangkan : kembang
# beragam : agam
# butuhin : butuhin
# agent : agent
# gabisa : gabisa
# berhasil : hasil
# paketnya : paket
# kepotong : potong
# dedi : dedi
# membeli : beli
# commerce : commerce
# tokopedia : tokopedia
# kartunya : kartu
# agustus : agustus
# terhitungnya : hitung
# gpp : gpp
# pembngunan : pembngunan
# situ : situ
# sangaaaaaaaaaaaaaaaaaaaaaaat : sangaaaaaaaaaaaaaaaaaaaaaaat
# laaaaaaaaaaaamaaaaaaaa : laaaaaaaaaaaamaaaaaaaa
# thn : thn
# daftr : daftr
# hiyahiyahiyaa : hiyahiyahiyaa
# token : token
# listrik : listrik
# disalahgunakan : disalahgunakan
# betanggung : betanggung
# ghia : ghia
# telolet : telolet
# okeee : okeee
# thankss : thankss
# pengecekan : kece
# menjaga : jaga
# privacy : privacy
# baiknya : baik
# berhubungan : hubung
# identitas : identitas
# publik : publik
# setting : setting
# terganggu : ganggu
# pop : pop
# iklan : iklan
# reboot : reboot
# memanggil : panggil
# planning : planning
# dibenerin : dibenerin
# orbitpun : orbit
# myorbit : myorbit
# faktanya : fakta
# setlh : setlh
# siiiik : siiiik
# regama : regama
# ale : ale
# babik : babik
# bangkrut : bangkrut
# nggk : nggk
# esti : esti
# keburu : keburu
# tidur : tidur
# plislahhhhh : plislahhhhh
# kejadiaan : kejadiaan
# penjelasan : jelas
# brp : brp
# tarif : tarif
# smsbanking : smsbanking
# bri : bri
# thankyou : thankyou
# for : for
# giveaway : giveaway
# cloud : cloud
# drive : drive
# laku : laku
# sandy : sandy
# ngelag : ngelag
# sore : sore
# tersambung : sambung
# panggilan : panggil
# menyebabkan : sebab
# cosplay : cosplay
# kendalanya : kendala
# nangisssss : nangisssss
# hidupin : hidupin
# mobile : mobile
# disedot : sedot
# plisssss : plisssss
# gegara : gegara
# gtw : gtw
# then : then
# ngapa : ngapa
# sekaliiiii : sekaliiiii
# kwan : kwan
# wahyu : wahyu
# odp : odp
# odpnya : odpnya
# logonya : logo
# jelek : jelek
# hatori : hatori
# mari : mari
# bergabung : gabung
# cmn : cmn
# rb : rb
# bangett : bangett
# ikutan : ikut
# berasa : asa
# goa : goa
# waw : waw
# mgedelin : mgedelin
# top : top
# anjg : anjg
# pulsaaaa : pulsaaaa
# abanianajaksbdhsia : abanianajaksbdhsia
# sinyalnya : sinyal
# ampun : ampun
# kb : kb
# lur : lur
# solusine : solusine
# pie : pie
# sng : sng
# dingge : dingge
# ngirim : ngirim
# sertifikat : sertifikat
# onok : onok
# parahh : parahh
# bett : bett
# teruss : teruss
# pengen : ken
# nangis : nang
# dahh : dahh
# kerjasama : kerjasama
# bngt : bngt
# ayoo : ayoo
# melani : melani
# masukan : masuk
# lho : lho
# sangaaaat : sangaaaat
# silahkan : silah
# dtg : dtg
# kesana : kesana
# liht : liht
# jarngan : jarngan
# mslh : mslh
# smpe : smpe
# skrg : skrg
# dialami : alami
# optimal : optimal
# say : say
# nif : nif
# amir : amir
# please : please
# give : give
# more : more
# details : details
# about : about
# issue : issue
# you : you
# experienced : experienced
# waiting : waiting
# kumat : kumat
# aduh : aduh
# proses : proses
# maksimal : maksimal
# berkala : kala
# antisipasi : antisipasi
# double : double
# charging : charging
# hallo : hallo
# metode : metode
# tik : tik
# tok : tok
# banned : banned
# hong : hong
# kong : kong
# can : can
# unless : unless
# changed : changed
# plan : plan
# and : and
# just : just
# realized : realized
# that : that
# without : without
# changing : changing
# but : but
# lost : lost
# receh : receh
# indonesian : indonesian
# toker : toker
# fyp : fyp
# baikin : baikin
# bru : bru
# migrasi : migrasi
# pakt : pakt
# internetnya : internetnya
# jeblok : jeblok
# ujung : ujung
# ngasih : ngasih
# settingan : settingan
# jaringannnya : jaringannnya
# capek : capek
# wanda : wanda
# diajak : ajak
# heran : heran
# mesyaf : mesyaf
# join : join
# jungkook : jungkook
# lelet : lelet
# rupiah : rupiah
# better : better
# ganti : ganti
# hdspa : hdspa
# center : center
# terdekat : dekat
# github : github
# stackoverflow : stackoverflow
# diakses : akses
# tuhkannnnn : tuhkannnnn
# kenapasii : kenapasii
# pppp : pppp
# putri : putri
# pohinn : pohinn
# tika : tika
# huwaa : huwaa
# sekelas : kelas
# gangerti : gangerti
# dasar : dasar
# rumahnya : rumah
# blusukan : blusukan
# keknya : kek
# fix : fix
# lte : lte
# psti : psti
# raa : raa
# olympics : olympics
# tonton : tonton
# ulang : ulang
# balasannya : balas
# teratasi : atas
# lemotttt : lemotttt
# sjb : sjb
# byr : byr
# tmp : tmp
# untungnya : untung
# free : free
# bth : bth
# sbr : sbr
# huhu : huhu
# meysaf : meysaf
# atlet : atlet
# berjuang : juang
# membawa : bawa
# medali : medali
# pulang : pulang
# pertandingannya : tanding
# bias : bias
# jaehyun : jaehyun
# apdet : apdet
# nabung : nabung
# anak : anak
# telkomgroup : telkomgroup
# meraih : raih
# penghargaan : harga
# telkomsat : telkomsat
# yakes : yakes
# telkom : telkom
# infra : infra
# metranet : metranet
# mitratel : mitratel
# telin : tin
# dapen : dapen
# pins : pins
# nnti : nnti
# geprek : geprek
# aldos : aldos
# pohin : pohin
# ristina : ristina
# heh : heh
# knp : knp
# drpd : drpd
# berhari : hari
# sinyallll : sinyallll
# karna : karna
# telfonannnnn : telfonannnnn
# byeeee : byeeee
# direspon : direspon
# dmku : dmku
# dibales : dibales
# plisss : plisss
# sepakbola : sepakbola
# ceweknya : cewek
# manaaaaaaa : manaaaaaaa
# miinnnn : miinnnn
# diisi : isi
# indoin : indoin
# kejdaian : kejdaian
# sosmedjm : sosmedjm
# rebahan : rebah
# sahabat : sahabat
# dapetin : dapetin
# bmw : bmw
# honda : honda
# all : all
# new : new
# beat : beat
# samsung : samsung
# galaxy : galaxy
# gampang : gampang
# banyakin : banyakin
# ussd : ussd
# banking : banking
# phy : phy
# snarf : snarf
# apaansi : apaansi
# knpa : knpa
# merata : rata
# jadwalnya : jadwal
# konsisten : konsisten
# bertambah : tambah
# games : games
# online : online
# susah : susah
# sklu : sklu
# loginnya : loginnya
# ohh : ohh
# iya : iya
# put : put
# hotstar : hotstar
# jadwal : jadwal
# cabang : cabang
# atletik : atletik
# dukung : dukung
# saksikan : saksi
# jua : jua
# tuhan : tuhan
# gila : gila
# parahnya : parah
# jarang : jarang
# dipake : dipake
# utuh : utuh
# expired : expired
# hadeh : hadeh
# zamannya : zaman
# interview : interview
# radio : radio
# bareng : bareng
# penyiar : siar
# pede : pede
# kamera : kamera
# move : move
# abang : abang
# mature : mature
# glad : glad
# see : see
# grow : grow
# broo : broo
# nikah : nikah
# reuni : reuni
# ghis : ghis
# ehh : ehh
# nich : nich
# hendy : hendy
# sla : sla
# solved : solved
# sinyalmu : sinyal
# njancuki : njancuki
# kenopo : kenopo
# cerito : cerito
# jal : jal
# ndalu : ndalu
# berhubung : hubung
# ade : ade
# xixixixi : xixixixi
# coco : coco
# melon : melon
# atuh : atuh
# beneur : beneur
# mangat : mangat
# dge : dge
# wkwkwkw : wkwkwkw
# gunanya : guna
# extra : extra
# trouble : trouble
# seh : seh
# jing : jing
# digit : digit
# jey : jey
# cashback : cashback
# alamat : alamat
# rmh : rmh
# modem : modem
# smpai : smpai
# krg : krg
# trial : trial
# edition : edition
# gemar : gemar
# sepertiku : seperti
# aplikasinya : aplikasi
# axis : axis
# wuih : wuih
# keren : keren
# kompak : kompak
# gmn : gmn
# gitu : gitu
# mabar : mabar
# esan : es
# leg : leg
# musuh : musuh
# didepan : depan
# alo : alo
# sya : sya
# caca : caca
# janjinya : janji
# pepek : pepek
# saaaaaat : saaaaaat
# minn : minn
# hehehehe : hehehehe
# diinfokan : info
# willis : willis
# ttp : ttp
# ping : ping
# merah : merah
# ajg : ajg
# bassura : bassura
# minggi : minggi
# kalemkeun : kalemkeun
# ketik : ketik
# kuduna : kuduna
# maklum : maklum
# three : three
# hasil : hasil
# shopee : shopee
# tanam : tanam
# nyaan : nyaan
# aing : aing
# hayang : hayang
# minecraft : minecraft
# hungkul : hungkul
# euyyyy : euyyyy
# cik : cik
# ieu : ieu
# tehhhhhhh : tehhhhhhh
# yallagh : yallagh
# perbulannnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn : perbulannnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# kecepatanna : kecepatanna
# burukkkkk : burukkkkk
# seburuk : buruk
# na : na
# didm : didm
# bayarnya : bayar
# saldo : saldo
# promonya : promonya
# pegawai : pegawai
# kebanyakan : banyak
# peduli : peduli
# simpati : simpati
# kadang : kadang
# diduga : duga
# bantuan : bantu
# lusa : lusa
# bebas : bebas
# chat : chat
# dibutuhkan : butuh
# ciledug : ciledug
# bgini : bgini
# kosong : kosong
# jual : jual
# transfer : transfer
# nominal : nominal
# kelipatan : kelipat
# under : under
# disc : disc
# sistem : sistem
# tergantung : gantung
# jenius : jenius
# qris : qris
# cok : cok
# abi : abi
# permata : permata
# kartuhalo : kartuhalo
# something : something
# went : went
# wrong : wrong
# wkwkwkkwkw : wkwkwkkwkw
# semangat : semangat
# hotstarnya : hotstarnya
# ngga : ngga
# kmrin : kmrin
# first : first
# media : media
# nayangin : nayangin
# mayan : mayan
# untung : untung
# bnyk : bnyk
# struggle : struggle
# nyalain : nyalain
# plis : plis
# berulaah : berulaah
# harinya : hari
# tinggal : tinggal
# disana : sana
# cobain : cobain
# hadiahnya : hadiah
# biyan : biyan
# zerra : zerra
# teu : teu
# kapake : kapake
# sejen : sejen
# tel : tel
# angger : angger
# cocok : cocok
# uing : uing
# sasa : sasa
# tuker : tuker
# voucer : voucer
# belanja : belanja
# ditanyain : ditanyain
# pilih : pilih
# jt : jt
# iyain : iyain
# dianya : dia
# nuntun : nuntun
# sebutin : sebutin
# kode : kode
# otp : otp
# blg : blg
# yeee : yeee
# didiemin : didiemin
# barusan : barusan
# ditelpon : telpon
# penipu : tipu
# wkakaka : wkakaka
# feeling : feeling
# ngakunya : ngakunya
# nelpom : nelpom
# yaudah : yaudah
# degerin : degerin
# pinter : pinter
# ngomong : ngomong
# pointnya : point
# dituker : dituker
# berkolaborasi : kolaborasi
# meningkatkan : tingkat
# produktivitas : produktivitas
# mitra : mitra
# menghadapi : hadap
# tantangan : tantang
# pandemi : pandemi
# nisa : nisa
# willy : willy
# greget : greget
# persiapan : siap
# doa : doa
# butuhnya : butuh
# ketuk : ketuk
# kay : kay
# rate : rate
# zonaba : zonaba
# zonabu : zonabu
# zonauang : zonauang
# indikasi : indikasi
# upayakan : upaya
# fitur : fitur
# save : save
# cape : cape
# pulsaku : pulsa
# kesedot : sedot
# egank : egank
# event : event
# kondisi : kondisi
# khusus : khusus
# dial : dial
# ditingkatkan : tingkat
# pelayanan : layan
# onlinenya : onlinenya
# urgenitas : urgenitas
# berbeda : beda
# engga : engga
# demita : demita
# telfon : telfon
# pesawat : pesawat
# daud : daud
# kirimkan : kirim
# parah : parah
# ilang : ilang
# hah : hah
# bangettt : bangettt
# sekarat : sekarat
# pemakaian : pakai
# perasaan : asa
# berlokasi : lokasi
# pemuda : pemuda
# timur : timur
# mengunjungi : unjung
# mall : mall
# cijantung : cijantung
# lantai : lantai
# astagfirullah : astagfirullah
# make : make
# fup : fup
# browser : browser
# hello : hello
# input : input
# ttl : ttl
# tetiba : tetiba
# lgs : lgs
# blank : blank
# putih : putih
# responding : responding
# kumaha : maha
# kitu : kitu
# astaga : astaga
# pantes : pantes
# ngerasa : ngerasa
# sepuasnya : puas
# membalas : balas
# daritadi : daritadi
# arief : arief
# facebook : facebook
# messenger : messenger
# virtual : virtual
# asisten : asisten
# juyeon : juyeon
# tukeran : tukeran
# point : point
# penyesuaian : sesuai
# upaya : upaya
# ketersediaan : sedia
# prima : prima
# flash : flash
# harganya : harga
# keluhannya : keluh
# kelanjutannya : lanjut
# elnyno : elnyno
# diproses : proses
# aik : aik
# barang : barang
# grosir : grosir
# bahan : bahan
# baku : baku
# usaha : usaha
# usahaku : usaha
# biaya : biaya
# penjualan : jual
# oiyh : oiyh
# signalnya : signalnya
# rudy : rudy
# bintang : bintang
# kaki : kaki
# milan : mil
# ariyo : ariyo
# cell : cell
# yuu : yuu
# buruk : buruk
# maybe : maybe
# kayak : kayak
# hijaudaun : hijaudaun
# sayang : sayang
# ktsep : ktsep
# paketannya : paket
# useless : useless
# kuning : kuning
# ihsaan : ihsaan
# cuaca : cuaca
# hujan : hujan
# panas : panas
# dingin : dingin
# sedingin : sedingin
# teman : teman
# poin : poin
# sia : sia
# donasikan : donasi
# tabung : tabung
# oksigen : oksigen
# pasien : pasien
# berkali : kali
# memangnya : memang
# jejak : jejak
# digitalnya : digital
# ngak : ngak
# perbaikan : baik
# telp : telp
# bayaram : bayaram
# halmahera : halmahera
# utara : utara
# tobelo : tobelo
# krna : krna
# kepepet : pepet
# dont : dont
# have : have
# money : money
# belinya : beli
# semenit : menit
# takot : takot
# wkwkwkwk : wkwkwkwk
# dinda : dinda
# iyaa : iyaa
# dikasih : kasih
# gtu : gtu
# pemerintah : perintah
# sekolah : sekolah
# asr : asr
# kesulitan : sulit
# registrasi : registrasi
# prabayar : prabayar
# petunjuknya : tunjuk
# zifahh : zifahh
# dibenahi : benah
# disneyplus : disneyplus
# kenapalah : kenapa
# asrama : asrama
# batang : batang
# kuliat : liat
# kekuatan : kuat
# penangkal : tangkal
# ifa : ifa
# oalah : oalah
# pantesan : pantesan
# komputer : komputer
# kmrn : kmrn
# cipa : cipa
# menelpon : telpon
# pelayanannya : layan
# logo : logo
# komisaris : komisaris
# looh : looh
# slowrespon : slowrespon
# ngechat : ngechat
# donk : donk
# alamai : alamai
# damara : damara
# kaa : kaa
# limited : limited
# ready : ready
# stock : stock
# legal : legal
# oo : oo
# sosmed : sosmed
# loop : loop
# premiumin : premiumin
# plissss : plissss
# michaell : michaell
# terputus : putus
# haisshhh : haisshhh
# noob : noob
# rembang : rembang
# ruslami : ruslami
# memperbaiki : baik
# kntl : kntl
# wes : wes
# kenek : kenek
# entek : entek
# sangu : sangu
# sekolahku : sekolah
# gae : gae
# thok : thok
# biyen : biyen
# paksa : paksa
# bayarin : bayarin
# uang : uang
# kantor : kantor
# kagak : kagak
# ancam : ancam
# apus : apus
# legends : legends
# afk : afk
# taek : taek
# sinyale : sinyale
# ful : ful
# kyara : kyara
# khulaeshi : khulaeshi
# arjaz : arjaz
# cus : cus
# order : order
# chill : chill
# spay : spay
# aman : aman
# trusted : trusted
# bolehh : bolehh
# fast : fast
# wajib : wajib
# unreg : unreg
# ahhh : ahhh
# rekomendasikan : rekomendasi
# disitu : situ
# hahaha : hahaha
# alfamart : alfamart
# bodok : bodok
# install : install
# mengeluh : keluh
# diwilayah : wilayah
# luky : luky
# line : line
# musicmax : musicmax
# gamesmax : gamesmax
# tiktok : tiktok
# akurat : akurat
# kei : kei
# caroline : caroline
# dimana : mana
# berbicara : bicara
# nyalahin : nyalahin
# murahh : murahh
# server : server
# maksud : maksud
# miminnya : miminnya
# jasa : jasa
# tukar : tukar
# isat : isat
# bank : bank
# followers : followers
# likes : likes
# instagram : instagram
# bersahabat : sahabat
# minat : minat
# mention : mention
# abby : abby
# duh : duh
# melewati : lewat
# sulit : sulit
# selengkapnya : lengkap
# perbaiki : baik
# bukti : bukti
# trims : trims
# ary : ary
# mas : mas
# namanya : nama
# makan : makan
# netflix : netflix
# yaaaa : yaaaa
# hiks : hiks
# iki : iki
# lapo : lapo
# jeno : jeno
# sorry : sorry
# sistemnya : sistem
# sibuk : sibuk
# shopeepayku : shopeepayku
# galang : galang
# eeq : eeq
# lemoooddddddd : lemoooddddddd
# bonusan : bonus
# adekku : adekku
# terlanjur : lanjur
# thx : thx
# hamzah : hamzah
# berbagi : bagi
# nomortujuan : nomortujuan
# nominaltransfer : nominaltransfer
# konfirmasinya : konfirmasi
# aleah : aleah
# kakk : kakk
# non : non
# canci : canci
# tuhann : tuhann
# sii : sii
# upload : upload
# seabad : abad
# vin : vin
# semingguan : minggu
# ambil : ambil
# duit : duit
# ngebantu : ngebantu
# cinta : cinta
# padamu : pada
# jiakhhhhh : jiakhhhhh
# nyetor : nyetor
# tugas : tugas
# mintol : mintol
# temen : temen
# kumpulin : kumpulin
# ngelek : ngelek
# hanin : hanin
# mengirimkan : kirim
# melo : melo
# bantuannya : bantu
# bergantung : gantung
# penggunaannya : guna
# informasinya : informasi
# pengalaman : alam
# utama : utama
# dibagi : bagi
# why : why
# kemudahan : mudah
# pln : pln
# petunjuk : tunjuk
# verifikasi : verifikasi
# reka : reka
# voltia : voltia
# keluan : keluan
# telkomselnya : telkomselnya
# austin : austin
# ketidaksesuaian : ketidaksesuaian
# lahh : lahh
# nontonnya : nontonnya
# filmnyaa : filmnyaa
# diskon : diskon
# pembayaran : bayar
# bca : bca
# yosh : yosh
# notif : notif
# kepake : kepake
# tanggung : tanggung
# terpakai : pakai
# anjirr : anjirr
# kemusuhan : musuh
# ssi : ssi
# bannernya : bannernya
# saputro : saputro
# bang : bang
# jelasin : jelasin
# ajalah : aja
# fungsinya : fungsi
# knapa : knapa
# vide : vide
# sertifikatnya : sertifikat
# berdua : dua
# tertulis : tulis
# diblokir : blokir
# terlambat : lambat
# terpaksa : paksa
# kampus : kampus
# dinkes : dinkes
# sumut : sumut
# tolonglah : tolong
# satunya : satu
# mencari : cari
# bts : bts
# mempengaruhi : pengaruh
# lampu : lampu
# mind : mind
# rizky : rizky
# pengerjaan : kerja
# hidup : hidup
# prov : prov
# pakek : pakek
# satelit : satelit
# surat : surat
# ffee : ffee
# nhun : nhun
# okehhh : okehhh
# cakep : cakep
# centre : centre
# dikirim : kirim
# pulsanya : pulsa
# john : john
# push : push
# glory : glory
# buangetttt : buangetttt
# yailah : yailah
# mubazir : mubazir
# ketentuan : tentu
# dahlah : dah
# padahl : padahl
# diklik : klik
# magic : magic
# sisa : sisa
# pemotongan : potong
# indos : indos
# rada : rada
# telkoms : telkoms
# ngetweet : ngetweet
# keluh : keluh
# kesah : kesah
# tag : tag
# kae : kae
# udahan : udahan
# aje : aje
# ngelaggg : ngelaggg
# ngelagg : ngelagg
# moba : moba
# lejen : lejen
# lokalisasi : lokalisasi
# terbuang : buang
# termakan : makan
# fuck : fuck
# dear : dear
# situs : situs
# error : error
# buffering : buffering
# hayo : hayo
# viu : viu
# memasarkan : pasar
# produknya : produk
# selamat : selamat
# tercantum : cantum
# payment : payment
# progress : progress
# lwt : lwt
# webnya : webnya
# ktkan : ktkan
# fktanya : fktanya
# ditmpt : ditmpt
# down : down
# wfh : wfh
# full : full
# kenapaa : kenapaa
# lemottt : lemottt
# inii : ini
# astagaaaa : astagaaaa
# ngecek : ngecek
# profilenya : profilenya
# complain : complain
# kualitasnya : kualitas
# instagramnya : instagramnya
# hmmmm : hmmmm
# primitif : primitif
# prioritas : prioritas
# multimedianya : multimedia
# ewallet : ewallet
# uni : uni
# lemoooot : lemoooot
# dongkol : dongkol
# keluarga : keluarga
# nanya : nanya
# kepotongnya : potong
# belajar : ajar
# ilmupedia : ilmupedia
# conference : conference
# zoom : zoom
# baguss : baguss
# giniii : giniii
# dipercepat : cepat
# bgsd : bgsd
# adri : adri
# angga : angga
# perang : perang
# lemotnya : lot
# istighfar : istighfar
# muluuu : muluuu
# astaghfirullooohhhhhh : astaghfirullooohhhhhh
# nyoba : nyoba
# loading : loading
# pencerahan : cerah
# ninii : nini
# ica : ica
# mayang : mayang
# demik : demik
# kuki : kuk
# ran : ran
# nyar : nyar
# bagoes : bagoes
# asw : asw
# weeww : weeww
# sombong : sombong
# kapal : kapal
# tanker : tanker
# pertamina : pertamina
# dijual : jual
# jaminan : jamin
# pengemplang : kemplang
# blbi : blbi
# lords : lords
# betah : betah
# diamonds : diamonds
# codashop : codashop
# boy : boy
# ngk : ngk
# payah : payah
# sie : sie
# template : template
# tempilan : tempilan
# tinggl : tinggl
# ciseeng : ciseeng
# perum : perum
# taman : taman
# ria : ria
# persada : persada
# skolh : skolh
# jrngan : jrngan
# psng : psng
# orbitstar : orbitstar
# ktnya : ktnya
# bukanaku : bukanaku
# hdd : hdd
# dikbud : dikbud
# gandeng : gandeng
# telyu : telyu
# wwan : wwan
# bundling : bundling
# acara : acara
# berkesempatan : sempat
# anggota : anggota
# komunitas : komunitas
# partner : partner
# mengikuti : ikut
# program : program
# diselenggarakan : selenggara
# digiads : digiads
# tinc : tinc
# daftarkan : daftar
# dirimu : diri
# meh : meh
# podo : podo
# efnu : efnu
# rio : rio
# single : single
# fey : fey
# yoga : yoga
# tenang : tenang
# ket : ket
# ismi : ismi
# delayed : delayed
# oya : oya
# istri : istri
# dlm : dlm
# yaaa : yaaa
# contohnya : contoh
# reguler : reguler
# utup : utup
# regulernya : reguler
# vidionya : vidionya
# bal : bal
# auto : auto
# ntah : ntah
# setup : setup
# gwa : gwa
# kaga : kaga
# diizinin : diizinin
# match : match
# busu : busu
# terkendala : kendala
# lenjut : lenjut
# interaksinya : interaksi
# lanjutkan : lanjut
# kacau : kacau
# wdy : wdy
# kosan : kosan
# sedia : sedia
# ganteng : ganteng
# asty : asty
# ketarik : tarik
# seharga : harga
# ngerampok : ngerampok
# suami : suami
# simcard : simcard
# tsb : tsb
# didaftarkan : daftar
# nik : nik
# terdaftar : daftar
# ello : ello
# pan : pan
# last : last
# developer : developer
# innovator : innovator
# potensi : potensi
# seratus : ratus
# dibanding : banding
# padam : padam
# menara : menara
# pemancar : pancar
# membutuhkan : butuh
# aliran : alir
# memancarkan : pancar
# smartphone : smartphone
# thea : thea
# man : man
# internetan : internetan
# kuoga : oga
# upgrade : upgrade
# sim : sim
# ukuran : ukur
# nano : nano
# memegang : pegang
# ktp : ktp
# kebijakannya : bijak
# ditanggapi : tanggap
# tangkap : tangkap
# in : in
# yak : yak
# maksudnya : maksud
# duanya : dua
# gaada : gaada
# sedikitpun : sedikit
# dile : dile
# dilo : dilo
# dipamer : pamer
# pamer : pamer
# nomornya : nomor
# kertas : kertas
# tiang : tiang
# deket : deket
# huuuuf : huuuuf
# jalan : jalan
# dllakukan : dllakukan
# fathin : fathin
# borneo : borneo
# galuh : galuh
# selfi : selfi
# menyelesaikan : selesai
# favorit : favorit
# ian : ian
# emng : emng
# nginep : nginep
# dek : dek
# harap : harap
# gonta : gonta
# masangnya : masangnya
# file : file
# berjam : jam
# will : will
# satria : satria
# lemooott : lemooott
# lamban : lamban
# nyesel : nyesel
# njir : njir
# nget : nget
# plng : plng
# kasian : kasi
# masak : masak
# mentok : mentok
# negaraku : negara
# providerku : providerku
# arwan : arwan
# priska : priska
# nandita : nandita
# vidiocom : vidiocom
# raz : raz
# berjalan : jalan
# seneng : neng
# iri : iri
# mainnya : main
# skill : skill
# rising : rising
# falcon : falcon
# strike : strike
# menimbulkan : timbul
# damage : damage
# penasaran : penasaran
# store : store
# mar : mar
# rina : rina
# cah : cah
# kediri : diri
# final : final
# husni : husni
# lengkapo : lengkapo
# gimanasih : gimanasih
# diva : diva
# diceritakan : cerita
# menyertakan : serta
# buruuuu : buruuuu
# medan : medan
# muuter : muuter
# muterrr : muterrr
# bedanya : beda
# resmi : resmi
# tlg : tlg
# wkwkwkwkwkwk : wkwkwkwkwkwk
# dateng : dateng
# ceng : ceng
# dirga : dirga
# uhuk : uhuk
# negeri : negeri
# jele : jele
# bgtttttttt : bgtttttttt
# lelaaaaahhhhhhh : lelaaaaahhhhhhh
# mengundang : undang
# vertigo : vertigo
# asam : asam
# lambung : lambung
# komentatornya : komentator
# dri : dri
# plnya : plnya
# tersedot : sedot
# gapake : gapake
# maennya : maennya
# owner : owner
# terkonsumsi : konsumsi
# kabar : kabar
# denny : denny
# siregar : siregar
# akbaaar : akbaaar
# oleng : oleng
# bentar : bentar
# prem : prem
# cabur : cabur
# card : card
# reset : reset
# network : network
# yahh : yahh
# help : help
# paipi : paip
# dilanjut : lanjut
# out : out
# uninstal : uninstal
# instal : instal
# meeting : meeting
# terhambat : hambat
# kompensasi : kompensasi
# done : done
# apply : apply
# kredit : kredit
# bni : bni
# device : device
# kegiatan : giat
# kejadiannya : jadi
# waena : waena
# jayapura : jayapura
# sultan : sultan
# mantap : mantap
# gan : gan
# loadingnya : loadingnya
# jogging : jogging
# keliling : keliling
# kampung : kampung
# prestasinya : prestasi
# sel : sel
# akbar : akbar
# menemukan : temu
# jodoh : jodoh
# terbaik : baik
# aka : aka
# minusnya : minus
# egk : egk
# sha : sha
# sabun : sabun
# aktifasi : aktifasi
# jfbaa : jfbaa
# judul : judul
# artist : artist
# oolyne : oolyne
# yukk : yukk
# murahnya : murah
# menambah : tambah
# adaa : adaa
# proteksi : proteksi
# perangkat : perangkat
# bisnis : bisnis
# enterprise : enterprise
# security : security
# tems : tems
# simak : simak
# tips : tips
# serangan : serang
# siber : siber
# mengancam : ancam
# hola : hola
# tvri : tvri
# indosiar : indosiar
# gabisaa : gabisaa
# hrs : hrs
# badminton : badminton
# terhalang : halang
# alvin : alvin
# tehupeiory : tehupeiory
# beraksi : aksi
# lari : lari
# aksinya : aksi
# giovanno : giovanno
# shayy : shayy
# ajakan : aja
# kemanusiaan : manusia
# notifikasi : notifikasi
# achmad : achmad
# doc : doc
# yopy : yopy
# berlanggan : langgan
# pra : pra
# slow : slow
# refund : refund
# kesesama : sama
# rasakan : rasa
# serunya : seru
# berinternet : berinternet
# rif : rif
# spotify : spotify
# diaktivasi : diaktivasi
# napasi : napas
# edge : edge
# vid : vid
# hubungin : hubungin
# terpencil : pencil
# kayaknya : kayak
# ooh : ooh
# atss : atss
# tayang : tayang
# bay : bay
# mehehe : mehehe
# melanjutkan : lanjut
# kolaborasi : kolaborasi
# unggulan : unggul
# dmn : dmn
# tvnya : tvnya
# parabola : parabola
# diacak : acak
# woee : woee
# indo : indo
# hzosmo : hzosmo
# wahahah : wahahah
# faisal : faisal
# website : website
# kayaaa : kayaaa
# gratiiiiis : gratiiiiis
# hadirkan : hadir
# kuliner : kuliner
# gofood : gofood
# sara : sara
# gig : gig
# depp : depp
# donggggg : donggggg
# kuotanyaaaa : kuotanyaaaa
# irsyad : irsyad
# mengacu : acu
# besaran : besar
# pengeluaran : keluar
# akibat : akibat
# berbedanya : beda
# tingkat : tingkat
# komponen : komponen
# menggelar : gelar
# infrastruktur : infrastruktur
# halah : halah
# kabur : kabur
# wts : wts
# nit : nit
# meriah : riah
# murmer : murmer
# wkwkkwkw : wkwkkwkw
# bisi : bis
# kada : kada
# tepake : tepake
# wkwkkwkwkwk : wkwkkwkwkwk
# kukira : kira
# setia : setia
# teryata : teryata
# diam : diam
# ngchat : ngchat
# temanku : teman
# ketengan : keteng
# mb : mb
# days : days
# web : web
# bar : bar
# didaerah : daerah
# terbosoan : terbosoan
# hackathon : hackathon
# adtech : adtech
# martech : martech
# diadakan : ada
# dailysocial : dailysocial
# bertujuan : tuju
# mempermudah : mudah
# mikro : mikro
# menengah : tengah
# yani : yani
# kebayar : bayar
# layanannya : layan
# salahnya : salah
# reload : reload
# dwiraya : dwiraya
# nglag : nglag
# robbi : robbi
# kesal : kesal
# ngadat : ngadat
# teruuuuus : teruuuuus
# mitha : mitha
# brpa : brpa
# shahnaz : shahnaz
# bersifat : sifat
# personal : personal
# memperoleh : oleh
# benefit : benefit
# firman : firman
# bgmna : bgmna
# booster : booster
# pilihan : pilih
# menggunakaan : menggunakaan
# provided : provided
# btw : btw
# nder : nder
# zuu : zuu
# kete : kete
# membayar : bayar
# percaya : percaya
# fak : fak
# pengisian : isi
# melunasi : lunas
# penagihan : tagih
# bona : bona
# mulut : mulut
# memberdayakan : daya
# rebate : rebate
# onoslot : onoslot
# dibagikan : bagi
# dimasukkan : masuk
# dihitung : hitung
# turnover : turnover
# menang : menang
# sbo : sbo
# joker : joker
# kamis : kamis
# belom : bom
# wtb : wtb
# sikay : sikay
# ahmad : ahmad
# melakuka : melakuka
# dproses : dproses
# kuotany : kuotany
# nuker : nuker
# gausah : gausah
# item : item
# qosim : qosim
# ditembak : tembak
# sentul : sentul
# tapii : tapi
# gembok : gembok
# bahar : bahar
# pedalaman : dalam
# dinonaktifkan : nonaktif
# permanen : permanen
# penukaran : tukar
# menukar : tukar
# reward : reward
# poinnya : poin
# ozzie : ozzie
# pelindung : lindung
# pisan : pis
# kudik : dik
# isok : isok
# sertivikat : sertivikat
# apanya : apa
# diaktifin : diaktifin
# manapun : mana
# uda : uda
# ksh : ksh
# orangnya : orang
# sampek : sampek
# udeh : udeh
# paketin : paketin
# faris : faris
# nikmatin : nikmatin
# ratusan : ratus
# ribuan : ribu
# selasa : selasa
# dividio : dividio
# jogja : jogja
# den : den
# kunjungan : kunjung
# pora : pora
# penipuan : tipu
# dot : dot
# com : com
# siaaa : siaaa
# ananda : ananda
# hapus : hapus
# sma : sma
# donggg : donggg
# gaperlu : gaperlu
# greyap : greyap
# court : court
# which : which
# even : even
# peketin : tin
# pertahankan : tahan
# arahan : arah
# darimana : darimana
# switch : switch
# menu : menu
# networks : networks
# tap : tap
# koplain : koplain
# lebar : lebar
# ngambek : ngambek
# dikenakan : kena
# mengakses : akses
# flo : flo
# yaudeh : yaudeh
# bernomor : nomor
# indra : indra
# mia : mia
# meneruskan : terus
# kanaya : kanaya
# chanka : chanka
# vaik : vaik
# kack : kack
# gia : gia
# bertanggung : tanggung
# kedepannya : depan
# posting : posting
# menghindari : hindar
# penyalahgunaan : penyalahgunaan
# mak : mak
# dongggg : dongggg
# plsss : plsss
# bgttt : bgttt
# tweet : tweet
# direply : direply
# plsssssssssssss : plsssssssssssss
# anpras : anpras
# aya : aya
# walopun : walopun
# fir : fir
# shaci : shaci
# sukses : sukses
# tindak : tindak
# pls : pls
# yogi : yogi
# regional : regional
# www : www
# voucherfisik : voucherfisik
# marsel : marsel
# pengaturan : atur
# membatasi : batas
# memblokir : blokir
# laila : laila
# dwika : dwika
# ntn : ntn
# lwat : lwat
# fernando : fernando
# abaikan : abai
# buang : buang
# jaringen : jaringen
# tukang : tukang
# ribet : ribet
# rifda : rifda
# ngeselin : ngeselin
# feedback : feedback
# berupaya : upaya
# memuaskan : muas
# harapannya : harap
# terealisasikan : realisasi
# ditelepon : telepon
# varian : varian
# reyza : reyza
# moots : moots
# user : user
# adakah : ada
# batu : batu
# kurleb : kurleb
# iphank : iphank
# berbayar : bayar
# siarin : siarin
# tayangan : tayang
# greysia : greysia
# polli : polli
# aprilia : aprilia
# rahayu : rahayu
# gilaaaa : gilaaaa
# dieni : dieni
# nata : nata
# mnaa : mnaa
# kepulauan : pulau
# komodo : komodo
# ancorrrr : ancorrrr
# astagaaa : astagaaa
# keluarin : keluarin
# one : one
# phone : phone
# sialnya : sial
# twt : twt
# gtuuu : gtuuu
# kiw : kiw
# jga : jga
# mantau : mantau
# skor : skor
# nuri : nuri
# geovanie : geovanie
# sihhh : sihhh
# diaktifkantks : diaktifkantks
# adminnya : adminnya
# mindahin : mindahin
# siarannya : siar
# denmark : denmark
# ditayangin : ditayangin
# nasionalis : nasionalis
# greysiap : greysiap
# damay : damay
# huang : huang
# telkomnyet : telkomnyet
# hak : hak
# siar : siar
# niat : niat
# mendukung : dukung
# profesional : profesional
# polii : polii
# qtr : qtr
# ditayangkan : tayang
# iklannya : iklan
# pack : pack
# fuad : fuad
# niko : niko
# nyambung : nyambung
# dikembalikan : kembali
# nico : nico
# masker : masker
# diluar : luar
# zaenal : zaenal
# kompensasinya : kompensasi
# sebelah : belah
# lgi : lgi
# sakit : sakit
# ela : ela
# post : post
# ginian : ginian
# mikirin : mikirin
# teriak : teriak
# berobat : obat
# champion : champion
# ch : ch
# bego : bego
# lailatul : lailatul
# lin : lin
# cham : cham
# taiwan : taiwan
# adeeeeeee : adeeeeeee
# brebet : brebet
# punnn : punnn
# yagituuu : yagituuu
# mihil : mihil
# freeee : freeee
# internetaaan : internetaaan
# wkwkwkwkwkkw : wkwkwkwkwkkw
# corel : corel
# sabar : sabar
# brisik : brisik
# buru : buru
# askrl : askrl
# carany : carany
# perolehan : oleh
# china : china
# memimpin : pimpin
# klasemen : klasemen
# posisi : posisi
# cilangkap : cilangkap
# depok : depok
# ofa : ofa
# novita : novita
# hani : hani
# ilangan : ilangan
# munculnya : muncul
# dashboard : dashboard
# segarkan : segar
# ditekan : tekan
# serkan : serkan
# muncul : muncul
# aktifnya : aktif
# melulu : melulu
# ngisi : ngisi
# subscription : subscription
# ulfa : ulfa
# bbrpa : bbrpa
# ratus : ratus
# komplen : komplen
# nembus : nembus
# twit : twit
# buun : buun
# skip : skip
# pasca : pasca
# ngegerus : ngegerus
# dibilang : bilang
# kasar : kasar
# ckckck : ckckck
# disegarkan : segar
# parkk : parkk
# nntnnya : nntnnya
# xpoker : xpoker
# deteur : deteur
# reedem : reedem
# bau : bau
# digratiskan : gratis
# rick : rick
# ricky : ricky
# moon : moon
# beneran : beneran
# disiarin : disiarin
# bbrp : bbrp
# ssah : ssah
# moodnya : moodnya
# candra : candra
# cuk : cuk
# yom : yom
# ren : ren
# enemyx : enemyx
# hemat : hemat
# buruan : buru
# hematnya : hemat
# permintaannya : minta
# yunarti : yunarti
# uba : uba
# bandar : bandar
# togel : togel
# terbesar : besar
# bolabet : bolabet
# judi : judi
# agen : agen
# casino : casino
# terpercaya : percaya
# mengahabiskan : mengahabiskan
# hei : hei
# warnet : warnet
# gimanaaa : gimanaaa
# beebee : beebee
# sari : sari
# alasan : alas
# akal : akal
# yes : yes
# with : with
# brit : brit
# accent : accent
# shareholder : shareholder
# also : also
# invest : invest
# your : your
# starlink : starlink
# partnership : partnership
# would : would
# tremendous : tremendous
# our : our
# country : country
# christ : christ
# rawamangun : rawamangun
# apasi : apas
# alesannya : alesannya
# peningkatan : tingkat
# kategori : kategori
# penerima : terima
# mece : mece
# makassar : makassar
# hsgk : hsgk
# lhoh : lhoh
# kepakai : pakai
# berlakunya : laku
# mbantu : mbantu
# ditempat : tempat
# karina : karina
# ahahahaa : ahahahaa
# grateess : grateess
# terpujilah : puji
# diajakin : diajakin
# kerjaan : kerja
# sinya : sinya
# lno : lno
# helo : helo
# thank : thank
# beralih : alih
# bebayar : bebayar
# keluarnya : keluar
# qpakah : qpakah
# mikael : mikael
# percepatan : cepat
# pengembangan : kembang
# diseluruh : seluruh
# oiya : oiya
# berdasarkan : dasar
# joe : joe
# munajat : munajat
# nabi : nabi
# portal : portal
# learning : learning
# zunan : zunan
# puput : puput
# adoh : adoh
# ngono : ngono
# pinjaman : pinjam
# kreatif : kreatif
# uong : uong
# iku : iku
# putus : putus
# nayaman : nayam
# berdampak : dampak
# berusaha : usaha
# menipu : tipu
# bangeeet : bangeeet
# mending : mending
# bacanya : baca
# nada : nada
# uncle : uncle
# lucifer : lucifer
# dzulumat : dzulumat
# coki : cok
# pardiedie : pardiedie
# dimintain : dimintain
# hanna : hanna
# chakra : chakra
# merk : merk
# type : type
# royal : royal
# gede : gede
# maketin : maketin
# mbps : mbps
# perhatiannya : perhati
# rilis : rilis
# launch : launch
# held : held
# jarkata : jarkata
# together : together
# displayed : displayed
# several : several
# usage : usage
# scenarios : scenarios
# including : including
# robot : robot
# patrol : patrol
# nunggunya : nunggunya
# ajo : ajo
# ndak : ndak
# nyo : nyo
# omong : omong
# indiehome : indiehome
# matot : matot
# skr : skr
# raden : raden
# bilangin : bilangin
# masnya : mas
# dibidang : bidang
# memperluas : luas
# jangkauan : jangkau
# perbaikin : perbaikin
# ngerjain : ngerjain
# revisian : revisi
# mangatus : mangatus
# ewuuu : ewuuu
# semalam : malam
# ratih : ratih
# jlmebret : jlmebret
# mhn : mhn
# belommmmm : belommmmm
# blom : blom
# bls : bls
# grey : grey
# apri : apri
# ginting : ginting
# jojo : jojo
# salahku : salah
# ceritain : ceritain
# selagi : selagi
# platinum : platinum
# cair : cair
# limit : limit
# mencukupi : cukup
# kasablanka : kasablanka
# erlin : erlin
# fitria : fitria
# nuhun : nuhun
# mbah : mbah
# lena : lena
# ngurus : ngurus
# dsb : dsb
# kejawab : jawab
# dithethering : dithethering
# bawa : bawa
# simcardnya : simcardnya
# kuthethering : kuthethering
# tab : tab
# kokas : kokas
# pekanbaru : pekanbaru
# selebew : selebew
# lek : lek
# endorse : endorse
# kowe : kowe
# wkk : wkk
# wahhh : wahhh
# internetanku : internetanku
# doonggg : doonggg
# ngalahin : ngalahin
# lancarnya : lancar
# bansos : bansos
# masyarakat : masyarakat
# chaksz : chaksz
# menghambat : hambat
# rejeki : rejeki
# nss : nss
# ady : ady
# nonaktifin : nonaktifin
# duluan : duluan
# doble : doble
# elektrik : elektrik
# pricelist : pricelist
# menyusul : susul
# ohhh : ohhh
# ujungnya : ujung
# hahahah : hahahah
# banyakan : banyak
# herannya : heran
# kutida : kutida
# nelfonin : nelfonin
# isjak : isjak
# minor : minor
# pingin : pingin
# puluhan : puluh
# aktifkannya : aktif
# matiuh : matiuh
# dibilangnya : bilang
# sllu : sllu
# bet : bet
# siput : siput
# hobi : hobi
# rahmi : rahmi
# kemana : mana
# klien : klien
# nyangkut : nyangkut
# risa : risa
# cazenove : cazenove
# penyesatan : sesat
# pertimbangkan : timbang
# ngilang : ngilang
# balqis : balqis
# airplan : airplan
# turnitin : turnitin
# repository : repository
# wardi : wardi
# giliran : gilir
# tampilan : tampil
# apapun : apa
# dijadikan : jadi
# nganggur : nganggur
# wkwkk : wkwkk
# akiko : akiko
# copet : copet
# macak : macak
# perusahaaan : perusahaaan
# komunikasi : komunikasi
# mengusahakan : usaha
# standar : standar
# tur : tur
# pelit : pelit
# jason : jason
# may : may
# utamanya : utama
# jwab : jwab
# awas : awas
# alfa : alfa
# vika : vika
# bangsat : bangsat
# adahal : adahal
# net : net
# keluargamu : keluarga
# happy : happy
# lakuin : lakuin
# dijamin : jamin
# bahagia : bahagia
# bersedia : sedia
# dihubungi : hubung
# teknis : teknis
# popup : popup
# serba : serba
# simcardmu : simcardmu
# prepaid : prepaid
# click : click
# kelogout : kelogout
# kyak : kyak
# anjun : anjun
# telksomsel : telksomsel
# eksesif : eksesif
# sehari : hari
# muthiah : muthiah
# bertahun : tahun
# tahunya : tahu
# bali : bal
# buks : buks
# buy : buy
# package : package
# gigamax : gigamax
# fit : fit
# flop : flop
# review : review
# playstore : playstore
# rebranding : rebranding
# worst : worst
# edwin : edwin
# kangen : kangen
# ditahan : tahan
# takut : takut
# telponan : telpon
# mytel : mytel
# mbca : mbca
# nambah : nambah
# direfund : direfund
# dananya : dana
# soalnyaa : soalnyaa
# trx : trx
# premiumkan : premium
# apl : apl
# subs : subs
# widy : widy
# include : include
# terimakasi : terimakasi
# respond : respond
# zonk : zonk
# nyedot : nyedot
# brbyr : brbyr
# aslkn : aslkn
# jrngn : jrngn
# bosss : bosss
# internetmu : internetmu
# terhapus : hapus
# pusat : pusat
# pastiin : pastiin
# annisa : annisa
# dimas : mas
# topik : topik
# terkini : kini
# haram : haram
# gretong : gretong
# asnu : asnu
# senior : senior
# serua : rua
# pams : pams
# wew : wew
# berevolusi : evolusi
# losss : losss
# telat : telat
# yayas : yayas
# magang : magang
# merdeka : merdeka
# rin : rin
# sekian : sekian
# kalinya : kali
# nanang : nanang
# fess : fess
# pascabayar : pascabayar
# iswant : iswant
# maximus : maximus
# syarat : syarat
# ketentuannya : tentu
# arra : arra
# vpn : vpn
# jdi : jdi
# umb : umb
# adminnn : adminnn
# wth : wth
# lagu : lagu
# ttg : ttg
# memakai : pakai
# ashhiap : ashhiap
# dzoel : dzoel
# fahmi : fahmi
# tindaklanjuti : tindaklanjuti
# yuuk : yuuk
# sidiq : sidiq
# tekomsel : tekomsel
# ...
# pengirim : kirim
# kelengkapan : lengkap
# base : base
# tlp : tlp
# mjuu : mjuu
# ngagem : ngagem
# provide : provide
# following : following
# number : number
# name : name
# place : place
# date : date
# birth : birth
# current : current
# location : location
# where : where
# technical : technical
# contacted : contacted
# halooooo : halooooo
# akselerasi : akselerasi
# membuka : buka
# tertarik : tarik
# sir : sir
# regarding : regarding
# complaints : complaints
# receiving : receiving
# promotional : promotional
# block : block
# them : them
# future : future
# not : not
# receive : receive
# any : any
# promotions : promotions
# anymore : anymore
# sends : sends
# like : like
# messages : messages
# day : day
# annoying : annoying
# hena : hena
# chace : chace
# ketidak : tidak
# sesuaian : sesuai
# bim : bim
# pare : pare
# dipindahin : dipindahin
# jebret : jebret
# komentator : komentator
# tahan : tahan
# berisiknya : berisik
# gamau : gamau
# memposting : memposting
# dilanjutkan : lanjut
# kaak : kaak
# premiummm : premiummm
# hotsar : hotsar
# sangkin : sangkin
# ngurusnya : ngurusnya
# saay : saay
# gratiss : gratiss
# riko : riko
# nga : nga
# blgnya : blgnya
# terdkt : terdkt
# reaktifasi : reaktifasi
# lewati : lewat
# kabupaten : kabupaten
# diubah : ubah
# bda : bda
# providernya : providernya
# jayaa : jayaa
# mada : mada
# city : city
# alternatif : alternatif
# gtg : gtg
# bsd : bsd
# tania : tania
# spasi : spasi
# tujuan : tuju
# medeline : medeline
# ponsel : ponsel
# laptop : laptop
# roli : rol
# manfaat : manfaat
# tersembunyi : sembunyi
# bermain : main
# tuamu : tua
# dishare : dishare
# terharu : haru
# volley : volley
# ngikutin : ngikutin
# highlight : highlight
# gpapa : gpapa
# teruuusss : teruuusss
# kaum : kaum
# merekomendasikan : rekomendasi
# myprio : myprio
# nilai : nilai
# terendah : rendah
# tertinggi : tinggi
# kekinian : kini
# optimalkan : optimal
# sosial : sosial
# mediamu : media
# permainan : main
# kayane : kayane
# yan : yan
# kgc : kgc
# susi : sus
# emporium : emporium
# pluit : pluit
# raya : raya
# kec : kec
# penjaringan : jaring
# pin : pin
# xixixi : xixixi
# cabor : cabor
# renang : renang
# bima : bima
# kritik : kritik
# sarannya : saran
# kepuasan : puas
# hrus : hrus
# krtu : krtu
# segeraaa : segeraaa
# brandingan : brandingan
# mendpt : mendpt
# sgt : sgt
# graprari : graprari
# santuy : santuy
# pap : pap
# teliti : teliti
# nasib : nasib
# halahhh : halahhh
# bertele : tele
# load : load
# ato : ato
# pemadaman : madam
# gataunya : gataunya
# padamnya : padam
# barengan : bareng
# lanjutin : lanjutin
# fand : fand
# barat : barat
# pesanku : pesan
# mbaput : mbaput
# ambyar : ambyar
# huee : huee
# zabo : zabo
# pacu : pacu
# laju : laju
# aye : aye
# webex : webex
# april : april
# cerita : cerita
# ngabarin : ngabarin
# akumulasi : akumulasi
# kuotanyaa : kuotanyaa
# bio : bio
# hadir : hadir
# pulsaa : pulsaa
# perpanjang : panjang
# trf : trf
# dih : dih
# hahahahha : hahahahha
# tetring : tetring
# asuu : asuu
# agam : agam
# connect : connect
# menyalakan : nyala
# mematikan : mati
# nyalakan : nyala
# haii : hai
# nihh : nihh
# semuaa : semuaa
# yukss : yukss
# estrella : estrella
# panahan : panah
# bulu : bulu
# tangkis : tangkis
# chache : chache
# masuknya : masuk
# channelnya : channelnya
# streamnya : streamnya
# ane : ane
# fidmah : fidmah
# goblok : goblok
# topping : topping
# bismillahirrahmanirrahim : bismillahirrahmanirrahim
# pangdam : pangdam
# ditungguin : ditungguin
# pendidikan : didik
# bosen : bosen
# berfaedah : faedah
# tingkatin : tingkatin
# kemampuan : mampu
# bahasa : bahasa
# asing : asing
# cakap : cakap
# ngeluh : ngeluh
# pnting : pnting
# tersisa : sisa
# ituu : ituu
# puas : puas
# madet : madet
# elektronik : elektronik
# keliatan : liat
# unlimitednya : unlimitednya
# rain : rain
# estetikanya : estetika
# diperbaiki : baik
# haydar : haydar
# ngantri : ngantri
# bun : bun
# tersebar : sebar
# kebijakan : bijak
# mingguan : minggu
# protes : protes
# dilakuin : dilakuin
# macem : macem
# musim : musim
# bagaima : bagaima
# tlfn : tlfn
# penjilat : jilat
# hebat : hebat
# perdana : perdana
# koq : koq
# iphone : iphone
# warna : warna
# kotaknya : kotak
# lapisan : lapis
# plastik : plastik
# melindungi : lindung
# layar : layar
# kupas : kupas
# cantik : cantik
# sudut : sudut
# kanan : kanan
# kataku : kata
# baruku : baru
# terpantau : pantau
# summerspace : summerspace
# enno : enno
# citra : citra
# nanyain : nanyain
# dibahas : bahas
# fisika : fisika
# matematika : matematika
# euy : euy
# teh : teh
# tipi : tipi
# gera : gera
# dotcom : dotcom
# wkwkw : wkwkw
# fdback : fdback
# trlkomsel : trlkomsel
# kunjung : kunjung
# dibaca : baca
# ngeboost : ngeboost
# there : there
# problem : problem
# this : this
# stream : stream
# hey : hey
# bcorporate : bcorporate
# anira : anira
# chandz : chandz
# uri : uri
# emgnya : emgnya
# melimpah : limpah
# gaya : gaya
# rivan : rivan
# isna : isna
# chanel : chanel
# sedih : sedih
# samaaaa : samaaaa
# bgg : bgg
# casenya : casenya
# pokoknya : pokok
# immediately : immediately
# wait : wait
# next : next
# interaction : interaction
# speed : speed
# kelas : kelas
# lola : lola
# kesukitan : kesukitan
# version : version
# try : try
# again : again
# later : later
# ditindaklanjuti : ditindaklanjuti
# rosa : rosa
# drespon : drespon
# kocak : kocak
# serius : serius
# tmpat : tmpat
# ings : ings
# lgsg : lgsg
# dibenarkan : benar
# kindly : kindly
# check : check
# telefon : telefon
# haziera : haziera
# faishol : faishol
# kate : kate
# ituaku : ituaku
# danny : danny
# kompatibel : kompatibel
# saranin : saranin
# looo : looo
# puk : puk
# btpncare : btpncare
# hahahaha : hahahaha
# anjiiirrr : anjiiirrr
# kerasa : rasa
# jahat : jahat
# beud : beud
# lep : lep
# nntonnya : nntonnya
# smart : smart
# hotspot : hotspot
# resolusi : resolusi
# segede : gede
# gaban : gaban
# angka : angka
# dibelakangnya : belakang
# silvy : silvy
# televisi : televisi
# mibox : mibox
# ganggu : ganggu
# klau : klau
# potong : potong
# kmna : kmna
# kios : kios
# rusak : rusak
# perjuangan : juang
# putra : putra
# bangsa : bangsa
# mengharumkan : harum
# metonton : metonton
# tah : tah
# benerin : benerin
# vel : vel
# telkomcel : telkomcel
# canda : canda
# bangsta : bangsta
# redeem : redeem
# mytelkomsat : mytelkomsat
# skg : skg
# anjin : anjin
# dangkalan : dangkal
# olympic : olympic
# beb : beb
# okee : okee
# mendesak : desak
# akhlak : akhlak
# award : award
# congrats : congrats
# kagok : kagok
# smsnya : smsnya
# konter : konter
# pusing : pusing
# kelurahan : lurah
# pasir : pasir
# layung : layung
# jdnya : jdnya
# nggih : nggih
# cang : cang
# jakson : jakson
# cokry : cokry
# diupadate : diupadate
# kinerjanya : kerja
# baby : baby
# tethering : tethering
# penonaktifan : nonaktif
# gprs : gprs
# sabrina : sabrina
# bandung : bandung
# prouk : prouk
# terbatas : batas
# karakter : karakter
# akumulaso : akumulaso
# tuuuh : tuuuh
# festival : festival
# citylink : citylink
# demon : demon
# menonaktifkan : nonaktif
# dukungan : dukung
# apresiasinya : apresiasi
# salut : salut
# sihh : sihh
# apresiasi : apresiasi
# dimatikan : mati
# offkan : offkan
# diawal : awal
# hit : hit
# run : run
# asik : asik
# dikomplain : komplain
# mustika : mustika
# bkkbn : bkkbn
# bekasi : bekas
# tolol : tolol
# san : san
# testi : testi
# pinned : pinned
# dikit : dikit
# lele : lele
# mudah : mudah
# matiin : matiin
# stress : stress
# elia : elia
# sulis : sulis
# suket : suket
# disdukcapil : disdukcapil
# dukungannya : dukung
# jaga : jaga
# kesehatan : sehat
# cesss : cesss
# yeaaay : yeaaay
# yeayyyy : yeayyyy
# okhie : okhie
# sejenisnya : jenis
# menanggapi : tanggap
# nrp : nrp
# euyyy : euyyy
# direinstall : direinstall
# anis : anis
# restar : restar
# jaringang : jaringang
# gilss : gilss
# serem : rem
# nerbener : nerbener
# hooh : hooh
# basket : basket
# argentina : argentina
# kemenangan : menang
# pertamanya : pertama
# awali : awal
# singal : singal
# butut : butut
# tanding : tanding
# aba : aba
# ril : ril
# penanganannya : tangan
# itupun : itu
# kejar : kejar
# dilupain : dilupain
# olla : olla
# padhal : padhal
# atobik : atobik
# alfi : alf
# url : url
# typ : typ
# konsumsi : konsumsi
# pertemuan : temu
# pemakai : pakai
# korban : korban
# nelfon : nelfon
# dikenal : kenal
# mengaku : aku
# imei : imei
# wna : wna
# paspor : paspor
# visa : visa
# turis : turis
# menunjukan : tunjuk
# beserta : serta
# search : search
# situsnya : situs
# gratisnya : gratis
# membership : membership
# bakti : bakti
# desa : desa
# teluk : teluk
# mutiara : mutiara
# sungai : sungai
# laur : laur
# kab : kab
# ketapang : ketapang
# kalbar : kalbar
# mutunya : mutu
# kampret : kampret
# dibawah : bawah
# kominfo : kominfo
# buktikan : bukti
# bla : bla
# berwacana : wacana
# grimonia : grimonia
# stay : stay
# tuned : tuned
# himasayu : himasayu
# menelfon : menelfon
# boros : boros
# seboros : boros
# dunno : dunno
# jobstreet : jobstreet
# linkedin : linkedin
# horoscope : horoscope
# padhl : padhl
# minnnnn : minnnnn
# sholeha : sholeha
# niyyyyy : niyyyyy
# jeti : jet
# baim : baim
# paula : paula
# tiar : tiar
# sementera : tera
# yuhuu : yuhuu
# what : what
# happened : happened
# handling : handling
# juaraaaa : juaraaaa
# disarankan : saran
# {'maaf': 'maaf', 'keterlambatan': 'lambat', 'responnya': 'responnya', 'kak': 'kak', 'mimin': 'mimin', 'cek': 'cek', 'kakak': 'kakak', 'list': 'list', 'antrian': 'antri', 'mohon': 'mohon', 'tunggu': 'tunggu', 'balasan': 'balas', 'makasih': 'makasih', 'ruina': 'ruina', '': '', 'pagi': 'pagi', 'hardi': 'hardi', 'informasi': 'informasi', 'seputar': 'putar', 'produk': 'produk', 'layanan': 'layan', 'orbit': 'orbit', 'mengubungi': 'ubung', 'twitter': 'twitter', 'myorbitid': 'myorbitid', 'email': 'email', 'semoga': 'moga', 'membantu': 'bantu', 'vivi': 'vivi', 'nonton': 'nonton', 'bajakan': 'baja', 'terserah': 'serah', 'ente': 'ente', 'ampe': 'ampe', 'film': 'film', 'disney': 'disney', 'series': 'series', 'kebangetan': 'banget', 'wkwkwk': 'wkwkwk', 'udh': 'udh', 'murah': 'murah', 'modal': 'modal', 'rebu': 'rebu', 'beli': 'beli', 'paket': 'paket', 'telkomsel': 'telkomsel', 'dapet': 'dapet', 'sebulan': 'bulan', 'streaming': 'streaming', 'masi': 'mas', 'ngebajak': 'ngebajak', 'min': 'min', 'info': 'info', 'okay': 'okay', 'aljaber': 'aljaber', 'udah': 'udah', 'masuk': 'masuk', 'mengirim': 'kirim', 'foto': 'foto', 'sidoarjo': 'sidoarjo', 'aneh': 'aneh', 'banget': 'banget', 'update': 'update', 'bagus': 'bagus', 'kualitas': 'kualitas', 'appnya': 'appnya', 'menguji': 'uji', 'kesabaran': 'sabar', 'paketan': 'paket', 'gajadi': 'gajadi', 'gini': 'gin', 'mah': 'mah', 'cels': 'cels', 'ditunggu': 'tunggu', 'interaksi': 'interaksi', 'meluncur': 'luncur', 'gimana': 'gimana', 'kayake': 'kayake', 'murce': 'murce', 'tolong': 'tolong', 'terima': 'terima', 'kasih': 'kasih', 'menunggu': 'tunggu', 'terkait': 'kait', 'berhenti': 'henti', 'berlangganan': 'langgan', 'halo': 'halo', 'silakan': 'sila', 'infoin': 'infoin', 'nomor': 'nomor', 'nama': 'nama', 'lengkap': 'lengkap', 'tgl': 'tgl', 'lahir': 'lahir', 'via': 'via', 'bantu': 'bantu', 'privasi': 'privasi', 'data': 'data', 'terjaga': 'jaga', 'davidzan': 'davidzan', 'nyaman': 'nyaman', 'aplikasi': 'aplikasi', 'mytelkomsel': 'mytelkomsel', 'transaksi': 'transaksi', 'linkaja': 'linkaja', 'shopeepay': 'shopeepay', 'gopay': 'gopay', 'ovo': 'ovo', 'akses': 'akses', 'internet': 'internet', 'lambat': 'lambat', 'coba': 'coba', 'off': 'off', 'airplane': 'airplane', 'mode': 'mode', 'yuk': 'yuk', 'kejadian': 'jadi', 'lokasi': 'lokasi', 'kendala': 'kendala', 'dibantu': 'bantu', 'tks': 'tks', 'nur': 'nur', 'sinyal': 'sinyal', 'lemah': 'lemah', 'stabil': 'stabil', 'mencoba': 'coba', 'refresh': 'refresh', 'jaringan': 'jaring', 'pindahkan': 'pindah', 'otomatis': 'otomatis', 'manual': 'manual', 'kembalikan': 'kembali', 'jam': 'jam', 'operasional': 'operasional', 'senin': 'senin', 'jum': 'jum', 'buka': 'buka', 'sabtu': 'sabtu', 'minggu': 'minggu', 'libur': 'libur', 'nasional': 'nasional', 'tutup': 'tutup', 'rai': 'rai', 'nunggu': 'nunggu', 'pramudi': 'pramudi', 'grapari': 'grapari', 'wilayah': 'wilayah', 'tangerang': 'tangerang', 'selatan': 'selatan', 'beroperasi': 'operasi', 'ppkm': 'ppkm', 'darurat': 'darurat', 'temukan': 'temu', 'ciputat': 'ciputat', 'beralamatkan': 'alamat', 'dewi': 'dewi', 'sartika': 'sartika', 'support': 'support', 'wallet': 'wallet', 'dana': 'dana', 'apk': 'apk', 'mustain': 'mustain', 'maxstream': 'maxstream', 'menonton': 'tonton', 'vidio': 'vidio', 'sesuai': 'sesuai', 'tertera': 'tera', 'byu': 'byu', 'mantep': 'mantep', 'harga': 'harga', 'bonusnya': 'bonus', 'custom': 'custom', 'nomer': 'nomer', 'jugaa': 'jugaa', 'barbar': 'barbar', 'berkendala': 'kendala', 'infokan': 'info', 'capture': 'capture', 'keterangan': 'terang', 'didapatkan': 'dapat', 'natalia': 'natalia', 'keluhan': 'keluh', 'ikuti': 'ikut', 'panduan': 'pandu', 'restart': 'restart', 'handphone': 'handphone', 'pastikan': 'pasti', 'versi': 'versi', 'terbaru': 'baru', 'lakukan': 'laku', 'clear': 'clear', 'cache': 'cache', 'force': 'force', 'stop': 'stop', 'bapuk': 'bapuk', 'woiiii': 'woiiii', 'hayati': 'hayati', 'mbaa': 'mbaa', 'salam': 'salam', 'kenal': 'kenal', 'mengalami': 'alami', 'lapor': 'lapor', 'hasilnya': 'hasil', 'kmrm': 'kmrm', 'dpt':  ...
# ------------------------
# Pandas Apply:   0%|          | 0/1951 [00:01<?, ?it/s]
#                                                 content  \
# 0     @shoeelltan maaf ya atas keterlambatan responn...
# 1     @hardee_90 pagi, kak hardi. mengenai informasi...
# 2     nonton bajakan sih terserah ente, tapi ampe no...
# 4                 @telkomsel pagi min boleh info orbit?
# 5     @rifkialjabar okay, kak aljaber. mimin cek dm ...
# ...                                                 ...
# 1995                                @joocnie @telkomsel
# 1996  @telkomsel dan sampai skrg tidak ada respon sa...
# 1997  @telkomsel apakah terus bisa menerima sms dan ...
# 1998  @muktitiar hai, kak tiar. maaf ya, mengenai ma...
# 1999                          @joocnie brisik telkomsel
#
#                                          cleaning_tweet  \
# 0     maaf atas keterlambatan responnya kak mimin ce...
# 1      pagi kak hardi mengenai informasi seputar pro...
# 2     nonton bajakan sih terserah ente tapi ampe non...
# 4                            pagi min boleh info orbit
# 5     okay kak aljaber mimin cek kakak udah masuk mo...
# ...                                                 ...
# 1995
# 1996  dan sampai skrg tidak ada respon sama sekali h...
# 1997         apakah terus bisa menerima sms dan telpon
# 1998  hai kak tiar maaf mengenai masa tenggang sudah...
# 1999                                   brisik telkomsel
#
#                                              tokenisasi  \
# 0     [maaf, atas, keterlambatan, responnya, kak, mi...
# 1     [, pagi, kak, hardi, mengenai, informasi, sepu...
# 2     [nonton, bajakan, sih, terserah, ente, tapi, a...
# 4                     [pagi, min, boleh, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [dan, sampai, skrg, tidak, ada, respon, sama, ...
# 1997  [apakah, terus, bisa, menerima, sms, dan, telp...
# 1998  [hai, kak, tiar, maaf, mengenai, masa, tenggan...
# 1999                                [brisik, telkomsel]
#
#                                                stopword  \
# 0     [maaf, keterlambatan, responnya, kak, mimin, c...
# 1     [, pagi, kak, hardi, informasi, seputar, produ...
# 2     [nonton, bajakan, terserah, ente, ampe, nonton...
# 4                            [pagi, min, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [skrg, respon, hebat, bener, kerja, provider, ...
# 1997                          [menerima, sms, telpon, ]
# 1998  [hai, kak, tiar, maaf, tenggang, udah, diaktif...
# 1999                                [brisik, telkomsel]
#
#                                                stemming
# 0     [maaf, lambat, responnya, kak, mimin, cek, kak...
# 1     [, pagi, kak, hardi, informasi, putar, produk,...
# 2     [nonton, baja, serah, ente, ampe, nonton, film...
# 4                            [pagi, min, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [skrg, respon, hebat, bener, kerja, provider, ...
# 1997                            [terima, sms, telpon, ]
# 1998  [hai, kak, tiar, maaf, tenggang, udah, aktif, ...
# 1999                                [brisik, telkomsel]
#
# [1951 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [maaf, lambat, responnya, kak, mimin, cek, kak...
# 1     [, pagi, kak, hardi, informasi, putar, produk,...
# 2     [nonton, baja, serah, ente, ampe, nonton, film...
# 4                            [pagi, min, info, orbit, ]
# 5     [okay, kak, aljaber, mimin, cek, kakak, udah, ...
# ...                                                 ...
# 1995                                                 []
# 1996  [skrg, respon, hebat, bener, kerja, provider, ...
# 1997                            [terima, sms, telpon, ]
# 1998  [hai, kak, tiar, maaf, tenggang, udah, aktif, ...
# 1999                                [brisik, telkomsel]
#
# [1951 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_7.xlsx')
