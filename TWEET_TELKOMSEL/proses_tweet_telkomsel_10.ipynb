# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @pinkluvcattt Hai, Kak. MAaf banget ya Kak. Ta...
# 1     @Telkomsel Tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp Hampir tiap hari dapet SMS dari n...
# 3     @Telkomsel Halo, kartu SIM Loop saya tdk bisa ...
# 4     @l_lhoo Baik, Kak. Maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @AndrianNardo Pagi Kak Andrian. Maaf ya terkai...
# 1996  @alnius Hai, Kak Alif. Maaf ya, terkait kendal...
# 1997                              @Telkomsel Oke bentar
# 1998  @alnius @Telkomsel Iya ngeselin banget padahal...
# 1999  @aLKecilSaja Emang d utan duuuul nyari2 kuota ...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 30

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @pinkluvcattt Hai, Kak. MAaf banget ya Kak. Ta...
# 1     @Telkomsel Tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp Hampir tiap hari dapet SMS dari n...
# 3     @Telkomsel Halo, kartu SIM Loop saya tdk bisa ...
# 4     @l_lhoo Baik, Kak. Maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @AndrianNardo Pagi Kak Andrian. Maaf ya terkai...
# 1996  @alnius Hai, Kak Alif. Maaf ya, terkait kendal...
# 1997                              @Telkomsel Oke bentar
# 1998  @alnius @Telkomsel Iya ngeselin banget padahal...
# 1999  @aLKecilSaja Emang d utan duuuul nyari2 kuota ...
#
# [1952 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @pinkluvcattt hai, kak. maaf banget ya kak. ta...
# 1     @telkomsel tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp hampir tiap hari dapet sms dari n...
# 3     @telkomsel halo, kartu sim loop saya tdk bisa ...
# 4     @l_lhoo baik, kak. maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @andriannardo pagi kak andrian. maaf ya terkai...
# 1996  @alnius hai, kak alif. maaf ya, terkait kendal...
# 1997                              @telkomsel oke bentar
# 1998  @alnius @telkomsel iya ngeselin banget padahal...
# 1999  @alkecilsaja emang d utan duuuul nyari2 kuota ...
#
# [1952 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @pinkluvcattt hai, kak. maaf banget ya kak. ta...
# 1     @telkomsel tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp hampir tiap hari dapet sms dari n...
# 3     @telkomsel halo, kartu sim loop saya tdk bisa ...
# 4     @l_lhoo baik, kak. maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @andriannardo pagi kak andrian. maaf ya terkai...
# 1996  @alnius hai, kak alif. maaf ya, terkait kendal...
# 1997                              @telkomsel oke bentar
# 1998  @alnius @telkomsel iya ngeselin banget padahal...
# 1999  @alkecilsaja emang d utan duuuul nyari2 kuota ...
#
#                                          cleaning_tweet
# 0     hai kak maaf banget kak tapi mimin mohon keter...
# 1     tetep bisa kak ada pesan anda tidak bisa membe...
# 2      gsp hampir tiap hari dapet sms dari nawarin h...
# 3     halo kartu sim loop saya tdk bisa menerima sms...
# 4      lhoo baik kak maaf terkait kendala aktivasi k...
# ...                                                 ...
# 1995  pagi kak andrian maaf terkait pembelian berhas...
# 1996  hai kak alif maaf terkait kendala tdk bisa mel...
# 1997                                         oke bentar
# 1998  iya ngeselin banget padahal butuh buat zoom kelas
# 1999  emang utan duuuul nyari  kuota susah pake apli...
#
# [1952 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @pinkluvcattt hai, kak. maaf banget ya kak. ta...
# 1     @telkomsel tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp hampir tiap hari dapet sms dari n...
# 3     @telkomsel halo, kartu sim loop saya tdk bisa ...
# 4     @l_lhoo baik, kak. maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @andriannardo pagi kak andrian. maaf ya terkai...
# 1996  @alnius hai, kak alif. maaf ya, terkait kendal...
# 1997                              @telkomsel oke bentar
# 1998  @alnius @telkomsel iya ngeselin banget padahal...
# 1999  @alkecilsaja emang d utan duuuul nyari2 kuota ...
#
#                                          cleaning_tweet  \
# 0     hai kak maaf banget kak tapi mimin mohon keter...
# 1     tetep bisa kak ada pesan anda tidak bisa membe...
# 2      gsp hampir tiap hari dapet sms dari nawarin h...
# 3     halo kartu sim loop saya tdk bisa menerima sms...
# 4      lhoo baik kak maaf terkait kendala aktivasi k...
# ...                                                 ...
# 1995  pagi kak andrian maaf terkait pembelian berhas...
# 1996  hai kak alif maaf terkait kendala tdk bisa mel...
# 1997                                         oke bentar
# 1998  iya ngeselin banget padahal butuh buat zoom kelas
# 1999  emang utan duuuul nyari  kuota susah pake apli...
#
#                                              tokenisasi
# 0     [hai, kak, maaf, banget, kak, tapi, mimin, moh...
# 1     [tetep, bisa, kak, ada, pesan, anda, tidak, bi...
# 2     [, gsp, hampir, tiap, hari, dapet, sms, dari, ...
# 3     [halo, kartu, sim, loop, saya, tdk, bisa, mene...
# 4     [, lhoo, baik, kak, maaf, terkait, kendala, ak...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, terkait, pembelian,...
# 1996  [hai, kak, alif, maaf, terkait, kendala, tdk, ...
# 1997                                      [oke, bentar]
# 1998  [iya, ngeselin, banget, padahal, butuh, buat, ...
# 1999  [emang, utan, duuuul, nyari, kuota, susah, pak...
#
# [1952 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     @pinkluvcattt hai, kak. maaf banget ya kak. ta...
# 1     @telkomsel tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp hampir tiap hari dapet sms dari n...
# 3     @telkomsel halo, kartu sim loop saya tdk bisa ...
# 4     @l_lhoo baik, kak. maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @andriannardo pagi kak andrian. maaf ya terkai...
# 1996  @alnius hai, kak alif. maaf ya, terkait kendal...
# 1997                              @telkomsel oke bentar
# 1998  @alnius @telkomsel iya ngeselin banget padahal...
# 1999  @alkecilsaja emang d utan duuuul nyari2 kuota ...
#
#                                          cleaning_tweet  \
# 0     hai kak maaf banget kak tapi mimin mohon keter...
# 1     tetep bisa kak ada pesan anda tidak bisa membe...
# 2      gsp hampir tiap hari dapet sms dari nawarin h...
# 3     halo kartu sim loop saya tdk bisa menerima sms...
# 4      lhoo baik kak maaf terkait kendala aktivasi k...
# ...                                                 ...
# 1995  pagi kak andrian maaf terkait pembelian berhas...
# 1996  hai kak alif maaf terkait kendala tdk bisa mel...
# 1997                                         oke bentar
# 1998  iya ngeselin banget padahal butuh buat zoom kelas
# 1999  emang utan duuuul nyari  kuota susah pake apli...
#
#                                              tokenisasi  \
# 0     [hai, kak, maaf, banget, kak, tapi, mimin, moh...
# 1     [tetep, bisa, kak, ada, pesan, anda, tidak, bi...
# 2     [, gsp, hampir, tiap, hari, dapet, sms, dari, ...
# 3     [halo, kartu, sim, loop, saya, tdk, bisa, mene...
# 4     [, lhoo, baik, kak, maaf, terkait, kendala, ak...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, terkait, pembelian,...
# 1996  [hai, kak, alif, maaf, terkait, kendala, tdk, ...
# 1997                                      [oke, bentar]
# 1998  [iya, ngeselin, banget, padahal, butuh, buat, ...
# 1999  [emang, utan, duuuul, nyari, kuota, susah, pak...
#
#                                                stopword
# 0     [hai, kak, maaf, banget, kak, mimin, mohon, ke...
# 1        [tetep, kak, pesan, membeli, produk, gimana, ]
# 2     [, gsp, dapet, sms, nawarin, hadiah, togel, pi...
# 3     [halo, kartu, sim, loop, menerima, sms, kartu,...
# 4     [, lhoo, kak, maaf, terkait, kendala, aktivasi...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, terkait, pembelian,...
# 1996  [hai, kak, alif, maaf, terkait, kendala, pemba...
# 1997                                      [oke, bentar]
# 1998        [iya, ngeselin, banget, butuh, zoom, kelas]
# 1999  [emang, utan, duuuul, nyari, kuota, susah, apl...
#
# [1952 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3291
# ------------------------
# hai : hai
# kak : kak
# maaf : maaf
# banget : banget
# mimin : mimin
# mohon : mohon
# ketersediaan : sedia
# kakak : kakak
# menunggu : tunggu
# balas : balas
# makasih : makasih
# khasa : khasa
# tetep : tetep
# pesan : pesan
# membeli : beli
# produk : produk
# gimana : gimana
#  :
# gsp : gsp
# dapet : dapet
# sms : sms
# nawarin : nawarin
# hadiah : hadiah
# togel : togel
# pinjol : pinjol
# link : link
# halo : halo
# kartu : kartu
# sim : sim
# loop : loop
# menerima : terima
# mati : mati
# tenggang : tenggang
# tolong : tolong
# dicek : cek
# solusinya : solusi
# cek : cek
# lhoo : lhoo
# terkait : kait
# kendala : kendala
# aktivasi : aktivasi
# kuota : kuota
# malam : malam
# udh : udh
# coba : coba
# saran : saran
# berkendala : kendala
# yuk : yuk
# infoin : infoin
# via : via
# bantu : bantu
# privasi : privasi
# terjaga : jaga
# tks : tks
# risa : risa
# dibalas : balas
# terima : terima
# kasih : kasih
# bsa : bsa
# ngentot : ngentot
# dial : dial
# semoga : moga
# membantu : bantu
# dwika : dwika
# convert : convert
# pulsa : pulsa
# indosat : indosat
# isat : isat
# telkomsel : telkomsel
# tsel : tsel
# smartfren : smartfren
# axis : axis
# testi : testi
# whatsapp : whatsapp
# tuker : tuker
# tukar : tukar
# cairin : cairin
# uang : uang
# ewallet : ewallet
# wallet : wallet
# gopay : gopay
# ovo : ovo
# dana : dana
# linkaja : linkaja
# shopeepay : shopeepay
# spay : spay
# bank : bank
# dwii : dwii
# pagi : pagi
# fredi : fredi
# paket : paket
# udah : udah
# ilang : ilang
# min : min
# detail : detail
# alami : alami
# bantuin : bantuin
# selesaiin : selesaiin
# kendalanya : kendala
# langsung : langsung
# keluhan : keluh
# ketidaksesuaian : ketidaksesuaian
# penggunaan : guna
# tgl : tgl
# kejadian : jadi
# jenis : jenis
# harga : harga
# nuri : nuri
# yuli : yuli
# ketersediaannya : sedia
# gangguan : ganggu
# mulu : mulu
# kesel : kesel
# pas : pas
# org : org
# kerja : kerja
# bangsat : bangsat
# ilangin : ilangin
# down : down
# linda : linda
# tagl : tagl
# kemarin : kemarin
# kirim : kirim
# data : data
# dibalasi : balas
# datanya : data
# dmnya : dmnya
# maksdunya : maksdunya
# langganan : langgan
# viu : viu
# belom : bom
# dipake : dipake
# sampe : sampe
# lupa : lupa
# trs : trs
# beli : beli
# internet : internet
# bisanya : bisa
# bima : bima
# sinyal : sinyal
# stabil : stabil
# refresh : refresh
# jaringan : jaring
# pindah : pindah
# otomatis : otomatis
# manual : manual
# lokasi : lokasi
# kelurahan : lurah
# kecamatan : camat
# nomor : nomor
# dicoba : coba
# restart : restart
# kel : kel
# kec : kec
# kota : kota
# dialami : alami
# chanel : chanel
# pembelian : beli
# dibeli : beli
# berasa : asa
# gb : gb
# sisa : sisa
# bar : bar
# dadakan : dada
# diceritain : diceritain
# layanan : layan
# knp : knp
# paketan : paket
# bngt : bngt
# double : double
# telpon : telpon
# batas : batas
# jam : jam
# nonstop : nonstop
# rb : rb
# silahkan : silah
# ikutan : ikut
# komunitas : komunitas
# cug : cug
# woy : woy
# telkom : telkom
# ajg : ajg
# signal : signal
# tbtb : tbtb
# turun : turun
# daerah : daerah
# mataram : mataram
# shidqon : shidqon
# reaktivasi : reaktivasi
# hangus : hangus
# dibantu : bantu
# ketentuan : tentu
# melebihi : lebih
# cepet : cepet
# sinyalnya : sinyal
# kayak : kayak
# sebagus : bagus
# nonton : nonton
# buffering : buffering
# buka : buka
# twitter : twitter
# kadang : kadang
# reload : reload
# memperpanjang : panjang
# aktif : aktif
# bgmana : bgmana
# isi : isi
# bantuanya : bantuanya
# dna : dna
# nama : nama
# diaktifkan : aktif
# laaahhhh : laaahhhh
# melynda : melynda
# seputar : putar
# pertanyaannya : tanya
# solusi : solusi
# sudahan : sudah
# yaa : yaa
# permisi : permisi
# nitip : nitip
# iklan : iklan
# readystock : readystock
# nomer : nomer
# cantik : cantik
# start : start
# smart : smart
# stock : stock
# lbh : lbh
# sesuai : sesuai
# budget : budget
# fastrespon : fastrespon
# rossvalinshop : rossvalinshop
# loc : loc
# malang : malang
# req : req
# shopee : shopee
# agus : agus
# bales : bales
# gelar : gelar
# dunia : dunia
# games : games
# festival : festival
# ajang : ajang
# gaming : gaming
# esports : esports
# virtual : virtual
# terbesar : besar
# indonesia : indonesia
# cerita : cerita
# balesnya : balesnya
# taun : taun
# feedbacknya : feedbacknya
# kwkwkwkkw : kwkwkwkkw
# jengkelll : jengkelll
# isinya : isi
# simpati : simpati
# masuk : masuk
# cepat : cepat
# balasnya : balas
# nangkep : nangkep
# jual : jual
# harian : hari
# bener : bener
# bos : bos
# antrian : antri
# interaksi : interaksi
# direspons : respons
# msh : msh
# blm : blm
# perihal : perihal
# kejelasan : jelas
# rian : rian
# mode : mode
# farengga : farengga
# laporin : laporin
# ngga : ngga
# perubahan : ubah
# rakjat : rakjat
# kek : kek
# hilang : hilang
# maybe : maybe
# something : something
# went : went
# wrong : wrong
# lgi : lgi
# kumpulin : kumpulin
# cuan : cuan
# tnpa : tnpa
# peduli : peduli
# parah : parah
# silakan : sila
# infokan : info
# tanggal : tanggal
# alam : alam
# joseph : joseph
# nyaman : nyaman
# mencoba : coba
# pindahkan : pindah
# kembalikan : kembali
# jaya : jaya
# singgih : singgih
# android : android
# tahap : tahap
# pengembangan : kembang
# info : info
# lengkap : lengkap
# mytelkomsel : mytelkomsel
# klik : klik
# marsel : marsel
# sei : sei
# berulah : ulah
# woke : woke
# the : the
# most : most
# horrible : horrible
# ever : ever
# hey : hey
# please : please
# fix : fix
# your : your
# shit : shit
# install : install
# ngadat : ngadat
# dibuka : buka
# tom : tom
# mentok : mentok
# wilayah : wilayah
# bali : bal
# list : list
# berkenan : kenan
# pengertiannya : erti
# dikirimkan : kirim
# titik : titik
# koordinat : koordinat
# google : google
# maps : maps
# pengecekan : kece
# akurat : akurat
# minimal : minimal
# informasi : informasi
# lemah : lemah
# respon : respon
# dpt : dpt
# berbeda : beda
# dibilang : bilang
# barusan : barusan
# aktifasi : aktifasi
# khusus : khusus
# ketik : ketik
# oapaa : oapaa
# judul : judul
# love : love
# artist : artist
# syahdan : syahdan
# aplikasi : aplikasi
# tiw : tiw
# murah : murah
# asli : asli
# open : open
# close : close
# sore : sore
# tekno : tekno
# situs : situs
# judi : judi
# online : online
# deposit : deposit
# jeno : jeno
# makasi : makas
# spick : spick
# ditunggu : tunggu
# interaksinya : interaksi
# didmkan : didmkan
# pengaktifan : aktif
# melewati : lewat
# detailnya : detail
# hpnya : hpnya
# nmr : nmr
# terblokir : blokir
# hbs : hbs
# diisi : isi
# okt : okt
# duhh : duhh
# bca : bca
# sii : sii
# kasian : kasi
# orang : orang
# sistem : sistem
# eror : eror
# buru : buru
# benrin : benrin
# didiemin : didiemin
# jaringanmu : jaring
# gabisa : gabisa
# provider : provider
# emang : emang
# setan : setan
# kontol : kontol
# kebiasaan : biasa
# banking : banking
# perbaikan : baik
# iyaa : iyaa
# suka : suka
# gtu : gtu
# ngeselin : ngeselin
# dinda : dinda
# warsono : warsono
# pemblokiran : blokir
# kartuhalo : kartuhalo
# lahir : lahir
# nominal : nominal
# tagihan : tagih
# jelek : jelek
# lte : lte
# iniii : iniii
# tower : tower
# syinal : syinal
# susah : susah
# akses : akses
# perbaiki : baik
# rayon : rayon
# belitang : belitang
# bgtu : bgtu
# bnyak : bnyak
# yng : yng
# bermasalah : masalah
# enak : enak
# skrang : skrang
# event : event
# onoslot : onoslot
# oktober : oktober
# pragmatic : pragmatic
# milyar : milyar
# play : play
# poker : poker
# juta : juta
# undi : undi
# tri : tri
# line : line
# wechat : wechat
# telegram : telegram
# instagram : instagram
# gtuu : gtuu
# kebanyakan : banyak
# tambing : tambing
# dingin : dingin
# purba : purba
# menyebabkan : sebab
# lambat : lambat
# off : off
# service : service
# main : main
# bandarq : bandarq
# sahabatpoker : sahabatpoker
# saldo : saldo
# rekening : rekening
# habis : habis
# daftar : daftar
# gabung : gabung
# sekrang : sekrang
# contact : contact
# livechat : livechat
# spkmantap : spkmantap
# bingung : bingung
# memilih : pilih
# terbukti : bukti
# keamanan : aman
# kenyamanan : nyaman
# kunjungi : kunjung
# jamin : jamin
# aman : aman
# busuk : busuk
# yaallah : yaallah
# jodi : jodi
# transfer : transfer
# knapa : knapa
# lemot : lot
# prioritas : prioritas
# lem : lem
# pintar : pintar
# dipasarkan : pasar
# aika : aika
# aifon : aifon
# pengen : ken
# slot : slot
# dsmbet : dsmbet
# fiki : fiki
# hybrid : hybrid
# pengisian : isi
# telepon : telepon
# sungkan : sungkan
# menghubungi : hubung
# sehat : sehat
# yuris : yuris
# aktifnya : aktif
# berlaku : laku
# tersedia : sedia
# download : download
# store : store
# app : app
# penyesuaian : sesuai
# salah : salah
# upaya : upaya
# menjaga : jaga
# kualitas : kualitas
# prima : prima
# pelanggan : langgan
# tenang : tenang
# sense : sense
# wkwkwk : wkwkwk
# yaudahh : yaudahh
# fast : fast
# aya : aya
# cdm : cdm
# siang : siang
# admin : admin
# dibales : dibales
# sukry : sukry
# mahal : mahal
# lelet : lelet
# ampun : ampun
# internetnya : internetnya
# jugaaaa : jugaaaa
# mukhlisin : mukhlisin
# diaktivasi : diaktivasi
# channel : channel
# pembayaran : bayar
# capture : capture
# keterangan : terang
# gagal : gagal
# thanku : thanku
# much : much
# reliable : reliable
# than : than
# any : any
# other : other
# home : home
# muhtar : muhtar
# beserta : serta
# berhasil : hasil
# ganti : ganti
# zepri : zepri
# keterlambatan : lambat
# reguler : reguler
# terpotong : potong
# pemakaian : pakai
# kali : kali
# wak : wak
# tahan : tahan
# claim : claim
# voucer : voucer
# instal : instal
# ulang : ulang
# terulang : ulang
# paketnya : paket
# ngak : ngak
# hehehe : hehehe
# pdhl : pdhl
# urgent : urgent
# adin : adin
# reinstall : reinstall
# diakses : akses
# transaksi : transaksi
# abis : abis
# gamemax : gamemax
# silver : silver
# voucher : voucher
# tulisannya : tulis
# sibuk : sibuk
# ulangi : ulang
# diapakan : apa
# tlg : tlg
# paketin : paketin
# has : has
# been : been
# extremely : extremely
# kind : kind
# got : got
# worries : worries
# arya : arya
# tpi : tpi
# tuaku : tua
# penipuan : tipu
# gitu : gitu
# gws : gws
# cantumkan : cantum
# pribadi : pribadi
# mention : mention
# bella : bella
# clear : clear
# cache : cache
# butuh : butuh
# diperbaiki : baik
# sdg : sdg
# kerjasama : kerjasama
# terimakasih : terimakasih
# sisil : sisil
# tdi : tdi
# sya : sya
# lwat : lwat
# apk : apk
# blum : blum
# idh : idh
# kepotong : potong
# disitu : situ
# pemberitahuan : pemberitahuan
# orbit : orbit
# mantav : mantav
# mdkdw : mdkdw
# dream : dream
# karcis : karcis
# jasa : jasa
# followers : followers
# like : like
# proses : proses
# bersahabat : sahabat
# minat : minat
# rudy : rudy
# paham : paham
# ceritain : ceritain
# malem : malem
# acara : acara
# abal : abal
# yaaah : yaaah
# brp : brp
# auto : auto
# tengkyuuu : tengkyuuu
# kim : kim
# tias : tias
# sabar : sabar
# mbak : mbak
# mari : mari
# bergandengan : gandeng
# mbknya : mbknya
# pengguna : guna
# dlm : dlm
# screenshot : screenshot
# xiaoxi : xiaoxi
# sosmed : sosmed
# kakk : kakk
# pay : pay
# saldonya : saldo
# berkurang : kurang
# pulsanya : pulsa
# nggak : nggak
# notif : notif
# syarif : syarif
# airplane : airplane
# kab : kab
# adam : adam
# ready : ready
# aidin : aidin
# metode : metode
# ttp : ttp
# web : web
# error : error
# gua : gua
# segede : gede
# perusahan : usah
# appnya : appnya
# hadee : hadee
# long : long
# latitude : latitude
# mengecek : ecek
# rio : rio
# money : money
# tidur : tidur
# jeje : jeje
# zico : zico
# feedback : feedback
# berupaya : upaya
# terbaik : baik
# setia : setia
# pakai : pakai
# masker : masker
# diluar : luar
# rumah : rumah
# dear : dear
# keluarin : keluarin
# ketengan : keteng
# unlimited : unlimited
# netflix : netflix
# asap : asap
# pls : pls
# asliii : asliii
# gratisan : gratis
# amazom : amazom
# prime : prime
# goodbye : goodbye
# world : world
# gonna : gonna
# marathon : marathon
# watching : watching
# office : office
# wkwkwkwkkwkwkwkw : wkwkwkwkkwkwkwkw
# fathimah : fathimah
# hahahaha : hahahaha
# baca : baca
# aktifin : aktifin
# btw : btw
# jaringanya : jaringanya
# uda : uda
# telat : telat
# bepatisimpati : bepatisimpati
# kenalan : kenal
# mobile : mobile
# harap : harap
# status : status
# simcard : simcard
# kedetek : kedetek
# handphone : handphone
# kayaknya : kayak
# digunain : digunain
# bad : bad
# gateway : gateway
# first : first
# media : media
# azriel : azriel
# bawa : bawa
# tiang : tiang
# njay : njay
# shib : shib
# masi : mas
# engga : engga
# ony : ony
# heran : heran
# budgetnya : budgetnya
# support : support
# ternyusahin : ternyusahin
# oke : oke
# peningkatan : tingkat
# skrg : skrg
# sedjak : sedjak
# thx : thx
# gigih : gigih
# streaming : streaming
# netlix : netlix
# mola : mola
# nguramg : nguramg
# utama : utama
# bkn : bkn
# maxtream : maxtream
# why : why
# sumpah : sumpah
# gue : gue
# emg : emg
# aduh : aduh
# capee : capee
# ngehapusin : ngehapusin
# model : model
# mulyadi : mulyadi
# rizqi : rizqi
# trims : trims
# zabo : zabo
# woyy : woyy
# anjingg : anjingg
# doang : doang
# bgini : bgini
# gangu : gangu
# nemu : nemu
# harganya : harga
# dibawah : bawah
# disney : disney
# persis : persis
# bebas : bebas
# ginian : ginian
# beh : beh
# jan : jan
# kukirim : kirim
# gada : gada
# apapun : apa
# yaaaaaa : yaaaaaa
# make : make
# regis : regis
# takut : takut
# perluuuu : perluuuu
# ngapain : ngapain
# buruk : buruk
# ribu : ribu
# lancar : lancar
# dih : dih
# aliran : alir
# kolaborasi : kolaborasi
# redi : redi
# blu : blu
# digital : digital
# integrasikan : integrasi
# perbankan : perban
# keuangan : uang
# mudah : mudah
# ferry : ferry
# three : three
# linknya : linknya
# bio : bio
# becanda : becanda
# edge : edge
# jir : jir
# capeklah : capek
# prosedur : prosedur
# berbelit : belit
# bukti : bukti
# nyata : nyata
# akuin : akuin
# iyaaaa : iyaaaa
# indihome : indihome
# wtt : wtt
# dagangan : dagang
# rugi : rugi
# inud : inud
# ahhh : ahhh
# dahhh : dahhh
# kemana : mana
# ternak : ternak
# gmail : gmail
# aaa : aaa
# prepare : prepare
# sma : sma
# zain : zain
# hvc : hvc
# jong : jong
# vikaa : vikaa
# kei : kei
# keburukan : keburu
# pemakai : pakai
# lari : lari
# segini : gin
# diajak : ajak
# kompromi : kompromi
# mursyid : mursyid
# prem : prem
# zoom : zoom
# premium : premium
# clay : clay
# tengkyu : tengkyu
# hafid : hafid
# berinteraksi : interaksi
# rekan : rekan
# makaksih : makaksih
# nich : nich
# dahh : dahh
# darah : darah
# aneh : aneh
# abyknight : abyknight
# aby : aby
# nungguin : nungguin
# konfirmasi : konfirmasi
# mediy : mediy
# wih : wih
# thanks : thanks
# wahyu : wahyu
# gilaaaaaaaaaa : gilaaaaaaaaaa
# bisaaaaaa : bisaaaaaa
# kampret : kampret
# adi : adi
# atasi : atas
# lag : lag
# leg : leg
# boro : boro
# merch : merch
# kpop : kpop
# pkaet : pkaet
# dri : dri
# tahta : tahta
# kaga : kaga
# wizone : wizone
# ivan : ivan
# iya : iya
# gituan : gituan
# andra : andra
# maafin : maafin
# nge : nge
# terhormat : hormat
# dibaca : baca
# pelan : pelan
# jejak : jejak
# pengeluaran : keluar
# cuman : cuman
# dikasih : kasih
# hadeh : hadeh
# pengalaman : alam
# mengherankan : heran
# penjelasannya : jelas
# maraton : maraton
# star : star
# wars : wars
# ampe : ampe
# mumpung : mumpung
# bbrp : bbrp
# deh : deh
# anjer : anjer
# benci : benci
# sklie : sklie
# bayar : bayar
# hdhhhhh : hdhhhhh
# gin : gin
# ncub : ncub
# minyuk : minyuk
# hui : hui
# tingginya : tinggi
# setara : tara
# foto : foto
# bareng : bareng
# males : males
# dibalesnya : dibalesnya
# seabad : abad
# lavi : lavi
# dilanjutkan : lanjut
# menyertakan : serta
# ahsiyap : ahsiyap
# bestie : bestie
# infonya : info
# habisin : habisin
# sayang : sayang
# semalam : malam
# skalian : skalian
# nomornya : nomor
# kaya : kaya
# gini : gin
# tony : tony
# nanya : nanya
# likes : likes
# views : views
# kirain : kirain
# pokoknya : pokok
# kapok : kapok
# nisa : nisa
# penyedia : sedia
# sultan : sultan
# tsebel : tsebel
# puol : puol
# fuck : fuck
# mbca : mbca
# direfund : direfund
# penanganan : tangan
# disuruh : suruh
# help : help
# napa : napa
# depo : depo
# free : free
# bonus : bonus
# tunggu : tunggu
# xpoker : xpoker
# dey : dey
# juventa : juventa
# makasihh : makasihh
# selamat : selamat
# balasan : balas
# nunggu : nunggu
# gila : gila
# riwayat : riwayat
# setress : setress
# pelayanan : layan
# telkomshhhh : telkomshhhh
# ujan : ujan
# gara : gara
# batere : batere
# mandi : mandi
# seminggu : minggu
# kuat : kuat
# kencang : kencang
# roket : roket
# israel : israel
# udahlah : udahlah
# cape : cape
# shil : shil
# sejam : jam
# terluas : luas
# dipinggir : pinggir
# lampu : lampu
# towernya : towernya
# sarankan : saran
# sapa : sapa
# blkgn : blkgn
# game : game
# beuh : beuh
# connection : connection
# unstable : unstable
# diarahin : diarahin
# suruh : suruh
# whitelist : whitelist
# volte : volte
# date : date
# stuck : stuck
# device : device
# cobalah : coba
# perbarui : baru
# whitelistnya : whitelistnya
# alihkan : alih
# miris : miris
# untung : untung
# bekasi : bekas
# kemaren : kemaren
# smh : smh
# ajar : ajar
# ama : ama
# barengan : bareng
# sak : sak
# wifi : wifi
# drtd : drtd
# kompak : kompak
# bapuk : bapuk
# rifqy : rifqy
# unlim : unlim
# jalan : jalan
# nurdin : nurdin
# sampah : sampah
# capek : capek
# komplain : komplain
# sempet : sempet
# mendingan : mending
# pelanggannya : langgan
# lapor : lapor
# tanggapi : tanggap
# serius : serius
# wes : wes
# firstmedia : firstmedia
# ngedown : ngedown
# nak : nak
# omahku : omahku
# nyendat : nyendat
# sinyale : sinyale
# inhale : inhale
# aaaaaaaaaaasssstaghfirullah : aaaaaaaaaaasssstaghfirullah
# exhale : exhale
# mesti : mesti
# terdaftar : daftar
# update : update
# type : type
# merk : merk
# edisi : edisi
# terbaru : baru
# fitur : fitur
# layananan : layananan
# diiklanin : diiklanin
# implementasi : implementasi
# ter : ter
# najis : najis
# amit : amit
# ckck : ckck
# sir : sir
# waiting : waiting
# for : for
# next : next
# interaction : interaction
# heh : heh
# candra : candra
# memposting : memposting
# menghindari : hindar
# penyalahgunaan : penyalahgunaan
# bertanggung : tanggung
# merubah : rubah
# limit : limit
# check : check
# thank : thank
# you : you
# hilih : hilih
# kyknya : kyknya
# ntek : ntek
# ket : ket
# udan : udan
# bledek : bledek
# gemleger : gemleger
# wau : wau
# listrik : listrik
# ringroad : ringroad
# utara : utara
# murup : murup
# bts : bts
# kayake : kayake
# keno : keno
# dadi : dadi
# syg : syg
# bnyk : bnyk
# kepake : kepake
# karna : karna
# drmh : drmh
# mengurangin : mengurangin
# soak : soak
# sial : sial
# putus : putus
# lin : lin
# mengalami : alami
# tarif : tarif
# agenda : agenda
# butut : butut
# elah : elah
# astaga : astaga
# migrasi : migrasi
# pascabayar : pascabayar
# prabayar : prabayar
# mao : mao
# paska : paska
# pra : pra
# gmna : gmna
# blankspot : blankspot
# pindahin : pindahin
# leviosa : leviosa
# meluncur : luncur
# gojek : gojek
# tsb : tsb
# recycle : recycle
# terverifikasi : verifikasi
# sihhhh : sihhhh
# dedis : dedis
# kirimfeedback : kirimfeedback
# ndak : ndak
# tindak : tindak
# move : move
# rora : rora
# responnya : responnya
# mastiin : mastiin
# terlewatkan : lewat
# sintal : sintal
# ancur : ancur
# pinggiran : pinggir
# dom : dom
# haiii : haiii
# profider : profider
# yaah : yaah
# dijamin : jamin
# yellow : yellow
# mini : mini
# trusted : trusted
# order : order
# chat : chat
# email : email
# bilangnya : bilang
# diproses : proses
# fokus : fokus
# platform : platform
# health : health
# tech : tech
# edu : edu
# api : api
# marketplace : marketplace
# berperan : peran
# enabler : enabler
# content : content
# creator : creator
# lokal : lokal
# jancvcok : jancvcok
# jordy : jordy
# annie : annie
# anjirrr : anjirrr
# menyerahkan : serah
# aset : aset
# menara : menara
# telekomunikasi : telekomunikasi
# miliknya : milik
# induk : induk
# usahanya : usaha
# difokuskan : fokus
# company : company
# digico : digico
# tugasnya : tugas
# mengembangkan : kembang
# arie : arie
# bekendala : bekendala
# victor : victor
# indra : indra
# wadidaw : wadidaw
# ios : ios
# sik : sik
# masalhanya : masalhanya
# penghasil : hasil
# freed : freed
# from : from
# build : build
# all : all
# operator : operator
# maunya : mau
# syarat : syarat
# syaratnya : syarat
# akutu : akutu
# mara : mara
# sarannya : saran
# nda : nda
# full : full
# koneksi : koneksi
# ambyar : ambyar
# gmn : gmn
# rto : rto
# selesain : selesain
# huhu : huhu
# rizky : rizky
# kli : kli
# ranni : ranni
# semenjak : semenjak
# uiiiii : uiiiii
# judulnya : judul
# nodap : nodap
# miss : miss
# reggie : reggie
# chodys : chodys
# rupiah : rupiah
# program : program
# papa : papa
# ngisi : ngisi
# bulannya : bulan
# sisanya : sisa
# kedepannya : depan
# dihitung : hitung
# seru : seru
# seruan : seru
# player : player
# dapetin : dapetin
# pengetahuan : tahu
# menarik : tarik
# ekosistem : ekosistem
# explore : explore
# serunya : seru
# dapatkan : dapat
# benefit : benefit
# gratis : gratis
# sehari : hari
# sebulan : bulan
# ngk : ngk
# kah : kah
# enji : enji
# plis : plis
# chi : chi
# promo : promo
# jaringannya : jaring
# bhima : bhima
# curhat : curhat
# pastikan : pasti
# rayhan : rayhan
# pemuda : pemuda
# celeb : celeb
# cam : cam
# updates : updates
# dibalikin : dibalikin
# treatment : treatment
# kekecewaan : kecewa
# yaudahlah : yaudahlah
# pasang : pasang
# njir : njir
# menang : menang
# hate : hate
# ngasih : ngasih
# marah : marah
# gaisss : gaisss
# kuotaa : kuotaa
# murahh : murahh
# hubungi : hubung
# akuu : akuu
# smarrfren : smarrfren
# arnov : arnov
# miskin : miskin
# andreas : andreas
# azh : azh
# pelacakan : lacak
# pemancar : pancar
# cileungsi : cileungsi
# ambruk : ambruk
# jlk : jlk
# muray : muray
# maxstream : maxstream
# melacaknya : lacak
# bing : bing
# oposisi : oposisi
# nanda : nanda
# informasikan : informasi
# durohman : durohman
# itim : itim
# kemakan : makan
# hbo : hbo
# murray : murray
# alfian : alfian
# payah : payah
# hujan : hujan
# gabsa : gabsa
# pemerintah : perintah
# backup : backup
# plan : plan
# misi : misi
# notifikasinya : notifikasi
# inbox : inbox
# shikado : shikado
# iftia : iftia
# unlimitedmax : unlimitedmax
# terakumulasi : akumulasi
# membuka : buka
# spotify : spotify
# musicmax : musicmax
# ank : ank
# anjing : anjing
# dede : dede
# amin : amin
# monica : monica
# memakan : makan
# stream : stream
# dll : dll
# terpakai : pakai
# berasanya : asa
# anjggg : anjggg
# senang : senang
# customer : customer
# pusing : pusing
# kemendikbud : kemendikbud
# socmed : socmed
# keblokir : blokir
# bambang : bambang
# ken : ken
# unlimax : unlimax
# multimedia : multimedia
# jelasin : jelasin
# tiko : tiko
# bangke : bangke
# roni : roni
# wkwkwkwkwwkwkwkwkwkwkwkwwkwkwkwkwkwkww : wkwkwkwkwwkwkwkwkwkwkwkwwkwkwkwkwkwkww
# istighfar : istighfar
# total : total
# sangir : sangir
# kabupaten : kabupaten
# solok : solok
# selatan : selatan
# sumatera : sumatera
# barat : barat
# penyakit : sakit
# kyk : kyk
# imtad : imtad
# bang : bang
# adek : adek
# cardnya : cardnya
# ari : ari
# cacat : cacat
# dibenerin : dibenerin
# kerjaan : kerja
# terkendala : kendala
# upgrade : upgrade
# krna : krna
# kena : kena
# blokir : blokir
# mba : mba
# diupgrade : diupgrade
# pdahal : pdahal
# nii : nii
# minn : minn
# semangat : semangat
# bergerak : gerak
# maju : maju
# lapisan : lapis
# masyarakat : masyarakat
# berpartisipasi : partisipasi
# expo : expo
# dubai : dubai
# mempromosikan : promosi
# potensi : potensi
# bangsa : bangsa
# mata : mata
# selengkapnya : lengkap
# memiliki : milik
# top : top
# diamond : diamond
# fire : fire
# upoint : upoint
# diterima : terima
# pengirim : kirim
# kelengkapan : lengkap
# dihubungi : hubung
# spam : spam
# sebulanan : bulan
# mah : mah
# ngepom : ngepom
# pom : pom
# sahamnya : saham
# tah : tah
# seneng : neng
# bangeett : bangeett
# poin : poin
# hehehehe : hehehehe
# hanzo : hanzo
# alif : alif
# permisiiiiii : permisiiiiii
# lewaaat : lewaaat
# izzan : izzan
# bercanda : canda
# trus : trus
# ayo : ayo
# bls : bls
# cancel : cancel
# tha : tha
# tito : tito
# cari : cari
# cinta : cinta
# seharian : hari
# ngurusin : ngurusin
# kerjakan : kerja
# balesan : balesan
# dialihkannya : alih
# kepemilikan : milik
# mitratel : mitratel
# mengukuhkan : kukuh
# langkah : langkah
# percepatan : cepat
# digitalisasi : digitalisasi
# della : della
# lanjutkan : lanjut
# asem : asem
# selesai : selesai
# nye : nye
# mura : mura
# makassar : makassar
# nmor : nmor
# hidupkannlagu : hidupkannlagu
# jaringanku : jaring
# cakupan : cakup
# mengunjungi : unjung
# profil : profil
# memenuhi : penuh
# prasyarat : prasyarat
# card : card
# usim : usim
# perangkat : perangkat
# cacad : cacad
# kambuhan : kambuh
# sianjing : sianjing
# berhenti : henti
# sweetchat : sweetchat
# nyedot : nyedot
# aauw : aauw
# insya : insya
# allah : allah
# live : live
# diatas : atas
# besok : besok
# cery : cery
# alias : alias
# anying : anying
# videonya : video
# buffer : buffer
# xixi : xixi
# kebocoran : bocor
# diatasi : atas
# kenceng : kenceng
# perketat : ketat
# respown : respown
# menghabiskan : habis
# expired : expired
# berlakunya : laku
# berdasarkan : dasar
# riza : riza
# telkomselnya : telkomselnya
# dania : dania
# jeff : jeff
# dumb : dumb
# jagatreview : jagatreview
# direct : direct
# release : release
# video : video
# trim : trim
# kode : kode
# ramadhand : ramadhand
# rizki : rizki
# unreg : unreg
# mengirim : kirim
# format : format
# flash : flash
# spasi : spasi
# infromasi : infromasi
# waaah : waaah
# gerakannya : gera
# kerjanya : kerja
# pemesanan : mesan
# dianter : anter
# kerumah : rumah
# pemesanannya : mesan
# basa : basa
# basi : basi
# ujung : ujung
# dateng : dateng
# good : good
# job : job
# mletre : mletre
# terpaksa : paksa
# ngeteng : ngeteng
# secepat : cepat
# nie : nie
# anjinc : anjinc
# seluler : seluler
# berlanggan : langgan
# stb : stb
# useetv : useetv
# tama : tama
# risqi : risqi
# anjrott : anjrott
# ceyen : ceyen
# wahh : wahh
# sadar : sadar
# murni : murni
# cukkk : cukkk
# roem : roem
# ilma : ilma
# nder : nder
# aktifkan : aktif
# tok : tok
# mhon : mhon
# plus : plus
# manfaatkan : manfaat
# senggang : senggang
# film : film
# kau : kau
# ngebuat : ngebuat
# ngumpul : ngumpul
# temen : temen
# segitiga : segitiga
# sahabat : sahabat
# naldo : naldo
# anak : anak
# sekolah : sekolah
# ganteng : ganteng
# drama : drama
# putih : putih
# abu : abu
# gapernah : gapernah
# baper : baper
# kinda : kinda
# moncer : moncer
# timbang : timbang
# ruma : ruma
# nggk : nggk
# rate : rate
# testimoni : testimoni
# liat : liat
# tweet : tweet
# pin : pin
# zahra : zahra
# haloo : haloo
# juai : jua
# under : under
# tele : tele
# murce : murce
# diskon : diskon
# bulanan : bulan
# lapisroti : lapisroti
# yak : yak
# doank : doank
# say : say
# tumben : tumben
# mauri : mauri
# diinfokan : info
# screnshoot : screnshoot
# didapatkan : dapat
# weeee : weeee
# jaring : jaring
# berdua : dua
# buset : buset
# klu : klu
# hidung : hidung
# dicolok : colok
# colok : colok
# kyu : kyu
# senengnya : neng
# hallo : hallo
# aera : aera
# kabel : kabel
# ngalahin : ngalahin
# jebotnya : jebotnya
# lampau : lampau
# mantep : mantep
# nugas : nugas
# menikmati : nikmat
# dilayanan : layan
# dasar : dasar
# intuk : intuk
# gamesmax : gamesmax
# dikenakan : kena
# rara : rara
# call : call
# center : center
# twt : twt
# pending : pending
# kirimnya : kirim
# taufik : taufik
# achmad : achmad
# teknisi : teknisi
# sungai : sungai
# binjiai : binjiai
# muara : muara
# bungo : bungo
# bauttnya : bauttnya
# anjrit : anjrit
# set : set
# refund : refund
# shopeepaynya : shopeepaynya
# kelas : kelas
# bae : bae
# serumah : rumah
# frustasi : frustasi
# dibls : dibls
# nia : nia
# zie : zie
# majalaya : majalaya
# bandung : bandung
# mirim : mirim
# anehnya : aneh
# kacau : kacau
# bet : bet
# hida : hida
# alesan : alesan
# benerin : benerin
# ngegame : ngegame
# slow : slow
# tdak : tdak
# furareki : furareki
# fahrun : fahrun
# informasinya : informasi
# tinggal : tinggal
# gamers : gamers
# rasakan : rasa
# keseruan : seru
# lakuin : lakuin
# keseruannya : seru
# tolonglah : tolong
# quest : quest
# genshin : genshin
# pojok : pojok
# kaanan : kaanan
# merah : merah
# pingnya : pingnya
# kagak : kagak
# berkomunikasi : komunikasi
# tehlah : teh
# belik : belik
# pracimantoro : pracimantoro
# wonogiri : wonogiri
# jawa : jawa
# malu : malu
# blok : blok
# okeh : okeh
# lia : lia
# shiap : shiap
# nur : nur
# pvreheroine : pvreheroine
# yaaa : yaaa
# wait : wait
# perbaikin : perbaikin
# udahh : udahh
# kaa : kaa
# ary : ary
# normal : normal
# berkali : kali
# hidup : hidup
# pesawat : pesawat
# hola : hola
# wow : wow
# memperkuat : kuat
# bisnis : bisnis
# meningkatkan : tingkat
# mengalihkan : alih
# lho : lho
# astagfirullah : astagfirullah
# abim : abim
# jauhari : jauhari
# bagus : bagus
# dino : dino
# duh : duh
# promonya : promonya
# yakalik : yakalik
# belilah : bilah
# maghrib : maghrib
# sialan : sial
# cepettt : cepettt
# dukungan : dukung
# atlet : atlet
# bulu : bulu
# tangkis : tangkis
# kebanggaan : bangga
# france : france
# siapkan : siap
# atributmu : atribut
# pekan : pekan
# grapari : grapari
# oks : oks
# pondok : pondok
# indah : indah
# mall : mall
# naikin : naikin
# ekstra : ekstra
# nemenin : nemenin
# wfh : wfh
# class : class
# dedek : dedek
# mutualan : mutualan
# followan : followan
# jfb : jfb
# tapii : tapi
# ketebas : tebas
# semarang : semarang
# depok : depok
# yosh : yosh
# veronika : veronika
# gaada : gaada
# suaranya : suara
# monetary : monetary
# notifikasi : notifikasi
# memakai : pakai
# non : non
# apanya : apa
# riz : riz
# gratissss : gratissss
# diaktifin : diaktifin
# oo : oo
# qris : qris
# jualan : jual
# belii : beli
# need : need
# tiwi : tiwi
# yoga : yoga
# udi : udi
# add : add
# smooa : smooa
# diregistrasikan : registrasi
# kartuas : kartuas
# aktifasinya : aktifasinya
# mifi : mifi
# byu : byu
# paketannya : paket
# unli : unli
# punyanya : punya
# ninja : ninja
# gabrielle : gabrielle
# donk : donk
# bicara : bicara
# merger : merger
# laporan : lapor
# sutet : sutet
# tinggian : tinggi
# kouta : kouta
# uti : uti
# silfi : silfi
# nasib : nasib
# blitar : blitar
# hadehhhhh : hadehhhhh
# jelekkkkkkk : jelekkkkkkk
# tambahan : tambah
# dimana : mana
# wirawan : wirawan
# fatikh : fatikh
# okk : okk
# rama : rama
# teh : teh
# enakn : enakn
# super : super
# perdana : perdana
# spesial : spesial
# rp : rp
# ngerep : ngerep
# bgke : bgke
# sleanjutnya : sleanjutnya
# uri : uri
# hello : hello
# popicecokelat : popicecokelat
# push : push
# rank : rank
# sepuasnya : puas
# hemat : hemat
# jawabannya : jawab
# korupsi : korupsi
# annis : annis
# pilih : pilih
# pintu : pintu
# musik : musik
# geser : geser
# gambar : gambar
# keunggulan : unggul
# reply : reply
# pilihan : pilih
# follow : follow
# spoiler : spoiler
# giovani : giovani
# hahahahahahahaahahahaha : hahahahahahahaahahahaha
# taix : taix
# rin : rin
# wtf : wtf
# dilaporin : dilaporin
# complaint : complaint
# nearly : nearly
# hours : hours
# and : and
# still : still
# hvn : hvn
# worked : worked
# this : this
# out : out
# really : really
# baran : baran
# erik : erik
# rox : rox
# max : max
# khawatir : khawatir
# upayakan : upaya
# kepuasan : puas
# bru : bru
# yunita : yunita
# terbaca : baca
# dialihkan : alih
# meningkatnya : tingkat
# pelosok : pelosok
# posisinya : posisi
# mbanking : mbanking
# pulak : pulak
# blom : blom
# bert : bert
# gaksihh : gaksihh
# nonya : nonya
# angus : angus
# isiin : isiin
# jarang : jarang
# when : when
# narsum : narsum
# tether : tether
# nyampe : nyampe
# menit : menit
# ngedrop : ngedrop
# matiin : matiin
# nyala : nyala
# batt : batt
# saved : saved
# sedekahkan : sedekah
# kaum : kaum
# fakir : fakir
# ato : ato
# negara : negara
# ribet : ribet
# nambah : nambah
# in : in
# rela : rela
# ikhlas : ikhlas
# urus : urus
# liar : liar
# menawari : tawar
# penipu : tipu
# bocor : bocor
# thnk : thnk
# god : god
# bless : bless
# diabntu : diabntu
# terkahir : terkahir
# beda : beda
# terbitlah : terbit
# woiii : woiii
# mas : mas
# keluhannya : keluh
# efek : efek
# pemadaman : madam
# gatau : gatau
# ngapa : ngapa
# internetan : internetan
# balikin : balikin
# hape : hape
# hapenya : hapenya
# lwt : lwt
# deskripsi : deskripsi
# iflix : iflix
# dsb : dsb
# widjaya : widjaya
# ngaco : ngaco
# nyuruh : nyuruh
# nanyain : nanyain
# dhabi : dhabi
# gugling : gugling
# butek : butek
# thxs : thxs
# jayaaa : jayaaa
# cel : cel
# hati : hati
# biaya : biaya
# mendalami : dalam
# ilmu : ilmu
# agama : agama
# bubbly : bubbly
# tausyiah : tausyiah
# konten : konten
# ceramah : ceramah
# kesempatan : sempat
# pulang : pulang
# iphone : iphone
# pungut : pungut
# kere : kere
# kirimkan : kirim
# drop : drop
# price : price
# makasii : makasii
# blokiran : blokir
# lat : lat
# lena : lena
# han : han
# menukar : tukar
# disertai : serta
# panduan : pandu
# klaim : klaim
# akun : akun
# ponsel : ponsel
# ricky : ricky
# aditya : aditya
# tersimpan : simpan
# dilayani : layan
# refres : refres
# banting : banting
# pecah : pecah
# berobat : obat
# dokter : dokter
# spesialis : spesialis
# mencret : mencret
# david : david
# berinternet : berinternet
# bolak : bolak
# reset : reset
# nggonku : nggonku
# dewe : dewe
# opo : opo
# ncen : ncen
# dasare : dasare
# inet : inet
# hashfi : hashfi
# viren : viren
# terhubung : hubung
# melanjutkan : lanjut
# willy : willy
# kenadala : kenadala
# fafifu : fafifu
# ceri : ceri
# lemotmu : lot
# skip : skip
# absen : absen
# mpd : mpd
# gembel : gembel
# koneksinya : koneksi
# skrng : skrng
# hmmmm : hmmmm
# ksi : ksi
# adminnya : adminnya
# cuek : cuek
# blablablaaa : blablablaaa
# dikau : dikau
# leletnya : lelet
# tertandingin : tertandingin
# raventi : raventi
# terbalas : balas
# infoiin : infoiin
# nikmati : nikmat
# cashback : cashback
# maks : maks
# koin : koin
# diweb : diweb
# melayani : layan
# hrs : hrs
# konsisten : konsisten
# atma : atma
# twiter : twiter
# sbntar : sbntar
# luhut : luhut
# puan : puan
# prabowo : prabowo
# ampuunnn : ampuunnn
# puyeng : puyeng
# bergelud : bergelud
# praktisnya : praktis
# mengakses : akses
# dikirim : kirim
# mesin : mesin
# atm : atm
# disetiap : tiap
# outket : outket
# tetus : tetus
# dashbord : dashbord
# muak : muak
# lihatnya : lihat
# kenapaasii : kenapaasii
# ngajak : ngajak
# ribut : ribut
# ajaaa : ajaaa
# jaringannyaaaa : jaringannyaaaa
# jshsskdb : jshsskdb
# acha : acha
# nyasar : nyasar
# kemanaaaaa : kemanaaaaa
# perasaan : asa
# digantungin : digantungin
# namanya : nama
# skali : skali
# mksdku : mksdku
# shanks : shanks
# fia : fia
# tempatku : tempat
# btsnya : btsnya
# fiber : fiber
# optic : optic
# komplen : komplen
# mempengaruhi : pengaruh
# favorit : favorit
# superior : superior
# beralih : alih
# new : new
# starter : starter
# pack : pack
# nrch : nrch
# arif : arif
# sakti : sakti
# youtube : youtube
# kasi : kasi
# rating : rating
# faza : faza
# koo : koo
# anjlok : anjlok
# kpn : kpn
# dadahup : dadahup
# kapuas : kapuas
# kalteng : kalteng
# proyek : proyek
# strategis : strategis
# nasional : nasional
# ojol : ojol
# sukses : sukses
# nggo : nggo
# gps : gps
# mawut : mawut
# keblasuk : keblasuk
# ngeterke : ngeterke
# orderan : order
# nurfitri : nurfitri
# ruangan : ruang
# berpindah : pindah
# area : area
# padam : padam
# vechter : vechter
# pelajar : ajar
# facebook : facebook
# mey : mey
# yug : yug
# terlanjur : lanjur
# asing : asing
# done : done
# tlp : tlp
# mengkonfirmasi : konfirmasi
# pengechekannya : pengechekannya
# berhubung : hubung
# klop : klop
# keterangannya : terang
# terapi : terapi
# kesabaran : sabar
# bs : bs
# omg : omg
# yuotube : yuotube
# fitri : fitri
# mencari : cari
# terdekat : dekat
# lainya : lai
# dilokasi : lokasi
# sekelas : kelas
# appsnya : appsnya
# bedain : bedain
# gbs : gbs
# apps : apps
# bansos : bansos
# berhak : hak
# keluarga : keluarga
# hee : hee
# dikatain : dikatain
# bpk : bpk
# pembuatan : buat
# laporannya : lapor
# komar : komar
# infokin : infokin
# serial : serial
# number : number
# percobaan : coba
# hasbi : hasbi
# ayoo : ayoo
# berlangganan : langgan
# adaa : adaa
# sdgkan : sdgkan
# jancok : jancok
# semalem : semalem
# muncul : muncul
# bandar : bandar
# urusan : urus
# bumn : bumn
# bram : bram
# tertera : tera
# website : website
# desember : desember
# hotstar : hotstar
# dalem : dalem
# gedung : gedung
# beton : beton
# interetnya : interetnya
# aksdkdbsb : aksdkdbsb
# royale : royale
# pass : pass
# month : month
# seharga : harga
# elite : elite
# november : november
# lewatkan : lewat
# ahmad : ahmad
# kayla : kayla
# dimas : mas
# dikit : dikit
# sja : sja
# pribadinya : pribadi
# klonjotan : klonjotan
# nyalahin : nyalahin
# imbas : imbas
# nyinyir : nyinyir
# bernada : nada
# kebencian : benci
# negatif : negatif
# sok : sok
# nyerang : nyerang
# udak : udak
# loe : loe
# cmiiw : cmiiw
# kabuptaen : kabuptaen
# ditindaklanjuti : ditindaklanjuti
# simabua : simabua
# inget : inget
# jaman : jaman
# kemunculannya : muncul
# jt : jt
# dibagu : dibagu
# wajar : wajar
# gaya : gaya
# pcr : pcr
# berkaiyan : berkaiyan
# nyawa : nyawa
# manusia : manusia
# haduuu : haduuu
# les : les
# gabisaa : gabisaa
# nyalain : nyalain
# robby : robby
# respond : respond
# fedalise : fedalise
# lala : lala
# issue : issue
# mood : mood
# belajar : ajar
# berharap : harap
# jawanan : jawanan
# sholat : sholat
# kaichun : kaichun
# pengaruhnya : pengaruh
# mangkanya : mangkanya
# emosi : emosi
# becus : becus
# mmakai : mmakai
# fianisaaaa : fianisaaaa
# yahh : yahh
# yampun : yampun
# ngetik : ngetik
# loading : loading
# lamaa : lamaa
# kalah : kalah
# berjaya : jaya
# ngaruh : ngaruh
# fian : fian
# im : im
# stres : stres
# tergantung : gantung
# boros : boros
# alternative : alternative
# mbps : mbps
# file : file
# gede : gede
# toping : toping
# bundle : bundle
# baris : baris
# ketikung : tikung
# abin : abin
# ketinggalan : tinggal
# penawaran : tawar
# series : series
# bundling : bundling
# dibanting : banting
# imaa : imaa
# ardina : ardina
# diread : diread
# mask : mask
# halooooooo : halooooooo
# gebuk : gebuk
# dilanjut : lanjut
# sunaji : sunaji
# dony : dony
# mia : mia
# tekomsel : tekomsel
# blg : blg
# transksi : transksi
# history : history
# trimakasih : trimakasih
# denganmu : dengan
# aplikasimu : aplikasi
# terbuka : buka
# desa : desa
# ngaringan : ngaringan
# gandusari : gandusari
# timur : timur
# neh : neh
# jessie : jessie
# kia : kia
# angkat : angkat
# pelajaran : ajar
# jefry : jefry
# hasilnya : hasil
# ibrahim : ibrahim
# bgmn : bgmn
# pipit : pipit
# its : its
# over : over
# activated : activated
# package : package
# better : better
# should : should
# consider : consider
# changing : changing
# operators : operators
# colek : colek
# alamat : alamat
# pembayan : pembayan
# tatap : tatap
# muka : muka
# kumpul : kumpul
# portal : portal
# learning : learning
# bulanannya : bulan
# tekan : tekan
# despite : despite
# marketing : marketing
# exposure : exposure
# building : building
# awareness : awareness
# audience : audience
# how : how
# that : that
# weekly : weekly
# mentoring : mentoring
# session : session
# have : have
# terrific : terrific
# rangga : rangga
# gandina : gandina
# solution : solution
# business : business
# partnership : partnership
# hawwa : hawwa
# okay : okay
# yaaaa : yaaaa
# makasiiiiiih : makasiiiiiih
# dibenahi : benah
# mlilir : mlilir
# ponorogo : ponorogo
# loyo : loyo
# panggilan : panggil
# hawwarana : hawwarana
# risau : risau
# alan : alan
# nelpon : nelpon
# jarak : jarak
# lampung : lampung
# jabar : jabar
# aryo : aryo
# popup : popup
# promosi : promosi
# direspon : direspon
# riska : riska
# holaaaaaa : holaaaaaa
# dooongggg : dooongggg
# aing : aing
# artikel : artikel
# kmrn : kmrn
# samanya : sama
# cmn : cmn
# smp : smp
# des : des
# sluttiebby : sluttiebby
# negeri : negeri
# haru : haru
# jiakhhhh : jiakhhhh
# batesi : batesi
# bersedih : sedih
# industri : industri
# yutub : yutub
# tiktok : tiktok
# bisaa : bisaa
# phuq : phuq
# maudy : maudy
# almo : almo
# pembayarannya : bayar
# saldoku : saldo
# spaaaayyy : spaaaayyy
# marazuddin : marazuddin
# hubungin : hubungin
# hasil : hasil
# pertandingan : tanding
# granada : granada
# getafe : getafe
# member : member
# potongan : potong
# mko : mko
# isika : isika
# hiburan : hibur
# berat : berat
# smartphone : smartphone
# mainin : mainin
# ringan : ringan
# kolak : kolak
# pop : pop
# hungry : hungry
# bird : bird
# masslahmya : masslahmya
# rumahb : rumahb
# kaak : kaak
# process : process
# abang : abang
# diratapi : ratap
# karya : karya
# bahagia : bahagia
# margo : margo
# city : city
# annisa : annisa
# mihails : mihails
# firdaus : firdaus
# terussss : terussss
# buzzer : buzzer
# flowerfantasy : flowerfantasy
# hadir : hadir
# mhn : mhn
# upnya : upnya
# wkt : wkt
# kjdn : kjdn
# berbulan : bulan
# diapa : apa
# apain : apain
# andrea : andrea
# nyambung : nyambung
# nihhh : nihhh
# direaktivasi : direaktivasi
# layanannya : layan
# csr : csr
# infomedia : infomedia
# jurusan : jurus
# fresh : fresh
# graduate : graduate
# berpengalaman : alam
# melamar : lamar
# fajriarahmawati : fajriarahmawati
# winner : winner
# takutnya : takut
# tenggangnya : tenggang
# dirumah : rumah
# sinuraya : suraya
# downgrade : downgrade
# adhitanto : adhitanto
# waah : waah
# dendanya : denda
# snk : snk
# monetery : monetery
# urusannya : urus
# ngg : ngg
# berita : berita
# pucung : pucung
# aren : aren
# daritadi : daritadi
# gerai : gerai
# keterbatasan : batas
# fisik : fisik
# kemampuan : mampu
# berjalan : jalan
# kemudahan : mudah
# alternatif : alternatif
# pandu : pandu
# billing : billing
# statement : statement
# resya : resya
# graparinya : graparinya
# lappr : lappr
# isilop : isilop
# yaudah : yaudah
# lebay : lebay
# arahan : arah
# atur : atur
# kebutuhan : butuh
# pikir : pikir
# menunjang : tunjang
# aktivitas : aktivitas
# onlinemu : onlinemu
# eits : eits
# telkomnyet : telkomnyet
# diginiin : diginiin
# ughi : ughi
# memahami : paham
# dipras : dipras
# plsss : plsss
# lemott : lemott
# bangett : bangett
# haduh : haduh
# lakukan : laku
# honestly : honestly
# intern : intern
# paid : paid
# enjoy : enjoy
# pressure : pressure
# kpi : kpi
# layaknya : layak
# time : time
# gathering : gathering
# fee : fee
# kantong : kantong
# kasusnya : kasus
# campuspedia : campuspedia
# kelewatan : lewat
# setting : setting
# mengganggu : ganggu
# payment : payment
# rbt : rbt
# deasy : deasy
# natalina : natalina
# filaa : filaa
# deasyofficials : deasyofficials
# penyetopan : setop
# neca : neca
# dipenuhi : penuh
# ujungnya : ujung
# mufidah : mufidah
# membatalkan : batal
# gtau : gtau
# pke : pke
# aprina : aprina
# pedra : pedra
# mastip : mastip
# elektrik : elektrik
# digangguin : digangguin
# semalaman : malam
# beliin : beliin
# roaming : roaming
# yay : yay
# kemane : kemane
# kgk : kgk
# venti : venti
# hutan : hutan
# kemdikbud : kemdikbud
# ponselnya : ponselnya
# kepemilikannya : milik
# tingkatkan : tingkat
# value : value
# kukuhkan : kukuh
# keren : keren
# php : php
# ngalah : ngalah
# gebetan : gebetan
# lumutan : lumut
# putri : putri
# memotivasi : motivasi
# belajarrr : belajarrr
# skshhshs : skshhshs
# siapp : siapp
# jga : jga
# vin : vin
# oppo : oppo
# wkwkw : wkwkw
# warga : warga
# sampahnya : sampah
# anjay : anjay
# switch : switch
# network : network
# blh : blh
# nyari : nyari
# saller : saller
# wetv : wetv
# oggy : oggy
# sinyalny : sinyalny
# tulisan : tulis
# monetarynya : monetarynya
# screenrecordingnya : screenrecordingnya
# ecommerce : ecommerce
# terkonfirmasi : konfirmasi
# terisi : isi
# alip : alip
# maksimal : maksimal
# sedih : sedih
# ir : ir
# wawan : wawan
# gbdi : gbdi
# gift : gift
# wajib : wajib
# only : only
# tag : tag
# telfon : telfon
# bagas : bagas
# saktinya : sakti
# asep : asep
# kris : kris
# kartunya : kartu
# dibakar : bakar
# vidcall : vidcall
# taik : taik
# cuk : cuk
# cukkkkkk : cukkkkkk
# mending : mending
# dikembalikan : kembali
# bentuk : bentuk
# mmk : mmk
# bangsd : bangsd
# mendapati : dapat
# niat : niat
# jugaa : jugaa
# seinget : seinget
# perbulannya : bulan
# publik : publik
# disalahgunakan : disalahgunakan
# oknum : oknum
# babi : babi
# spek : spek
# goib : goib
# khalid : khalid
# prepaid : prepaid
# sals : sals
# akhmad : akhmad
# mengaktifkan : aktif
# yaap : yaap
# wtp : wtp
# kombinasikan : kombinasi
# samsung : samsung
# favoritmu : favorit
# contoh : contoh
# tujuan : tuju
# xxxxxxx : xxxxxxx
# nazirul : nazirul
# unregistrasi : unregistrasi
# nik : nik
# ikuti : ikut
# petunjuk : tunjuk
# shopepay : shopepay
# sesok : sok
# unregist : unregist
# smratfren : smratfren
# tanyain : tanyain
# salesnya : salesnya
# fatin : fatin
# spams : spams
# myads : myads
# gapopo : gapopo
# gonta : gonta
# cewe : cewe
# cowo : cowo
# telfonan : telfonan
# mbek : mbek
# untunge : untunge
# pacare : pacare
# cemburuan : cemburu
# berjam : jam
# terburuk : buruk
# avri : avri
# wardana : wardana
# frans : frans
# legal : legal
# menambah : tambah
# pinned : pinned
# penasaran : penasaran
# serandom : serandom
# usernya : usernya
# jutaan : juta
# menangkan : menang
# mengajak : ajak
# sekitarmu : sekitar
# asisten : asisten
# buruan : buru
# ambassador : ambassador
# referral : referral
# daftarkan : daftar
# avrie : avrie
# ulul : ulul
# pemotongan : potong
# nice : nice
# day : day
# teman : teman
# duit : duit
# iqyi : iqyi
# kunandar : kunandar
# steppen : steppen
# tersedot : sedot
# tanggapan : tanggap
# adminya : adminya
# andleaving : andleaving
# combo : combo
# telp : telp
# sari : sari
# cpt : cpt
# ditanggulangi : tanggulang
# rugila : rugila
# konsumen : konsumen
# hii : hii
# pulsaa : pulsaa
# mandiri : mandiri
# internetku : internetku
# nulis : nulis
# zidan : zidan
# lionsgate : lionsgate
# amazone : amazone
# vidio : vidio
# fariz : fariz
# himbau : himbau
# membagikan : bagi
# dilaman : dilam
# komentar : komentar
# epa : epa
# mingguan : minggu
# midnight : midnight
# modem : modem
# ttl : ttl
# smf : smf
# lulu : lulu
# penerima : terima
# kuasa : kuasa
# rangkapan : rangkap
# pancoran : pancoran
# milik : milik
# paspor : paspor
# kta : kta
# berhalangan : halang
# diwakilkan : wakil
# melampirkan : lampir
# surat : surat
# bermaterai : bermaterai
# pemilik : milik
# ktp : ktp
# pemberi : beri
# suket : suket
# dinas : dinas
# kependudukan : duduk
# pencatatan : catat
# sipil : sipil
# digit : digit
# membawa : bawa
# identitas : identitas
# leon : leon
# era : era
# noona : noona
# menginfokan : info
# mencantumkan : cantum
# lambatnya : lambat
# dodi : dodi
# reni : reni
# spele : spele
# ginih : ginih
# gaji : gaji
# primitif : primitif
# ngalamin : ngalamin
# menyayat : sayat
# pendukung : dukung
# diandalkan : andal
# myorbit : myorbit
# official : official
# lina : lina
# fey : fey
# eaaa : eaaa
# sewa : sewa
# kantor : kantor
# meeting : meeting
# metro : metro
# tvonenews : tvonenews
# komunikatif : komunikatif
# kecewa : kecewa
# kenapasi : napas
# diamonds : diamonds
# legends : legends
# maya : maya
# terselesaikan : selesai
# sedot : sedot
# indihomo : indihomo
# beneran : beneran
# kuotanya : kuota
# atleast : atleast
# batre : batre
# meninggal : tinggal
# oiya : oiya
# lucu : lucu
# ngikut : ngikut
# relening : relening
# ulangnya : ulang
# orje : orje
# dimaklumi : maklum
# dikenal : kenal
# ngechat : ngechat
# kieu : kieu
# bosok : bosok
# bajingan : bajing
# worst : worst
# mentabku : mentabku
# merasakan : rasa
# desek : desek
# server : server
# tselnya : tselnya
# man : man
# nomernya : nomernya
# pentingg : pentingg
# thankyou : thankyou
# dimiliki : milik
# diregistrasi : registrasi
# dijual : jual
# registrasi : registrasi
# terhapus : hapus
# jzakaria : jzakaria
# pekerjaan : kerja
# hiks : hiks
# aneka : aneka
# tawaran : tawar
# kesepakatan : sepakat
# opsi : opsi
# unsubscribe : unsubscribe
# ieu : ieu
# naon : naon
# setahun : tahun
# satelit : satelit
# dimakan : makan
# buaya : buaya
# aduhhhhh : aduhhhhh
# ajig : ajig
# ges : ges
# senasib : nasib
# tokped : tokped
# komplenannya : komplenannya
# team : team
# mgn : mgn
# pang : pang
# kambing : kambing
# terputus : putus
# menggasing : gasing
# den : den
# jole : jole
# suko : suko
# tips : tips
# simak : simak
# berterima : terima
# konter : konter
# dlu : dlu
# sales : sales
# dikurangi : rang
# user : user
# alur : alur
# self : self
# songong : songong
# dlunya : dlunya
# responsnya : respons
# ydah : ydah
# pita : pita
# ghz : ghz
# dblg : dblg
# sgla : sgla
# mcam : mcam
# pakek : pakek
# sekarangggg : sekarangggg
# pembeliannya : beli
# lgsg : lgsg
# tuggu : tuggu
# kepaksa : paksa
# sale : sale
# terbatas : batas
# kecepatan : cepat
# nos : nos
# diperpanjang : panjang
# pelayanannya : layan
# terganggu : ganggu
# alfadhil : alfadhil
# fajar : fajar
# mariee : mariee
# nihh : nihh
# pict : pict
# pluss : pluss
# cuss : cuss
# sertifikat : sertifikat
# gilang : gilang
# sinii : sini
# tar : tar
# palingan : paling
# ngeganti : ngeganti
# camela : camela
# problem : problem
# read : read
# mariposa : mariposa
# pemudi : pemudi
# utarakan : utara
# janji : janji
# suci : suci
# talkmania : talkmania
# weekend : weekend
# kemusuhan : musuh
# bye : bye
# mencukupi : cukup
# kesedot : sedot
# adriansyah : adriansyah
# yasfini : yasfini
# ramawica : ramawica
# twitternya : twitternya
# join : join
# kehitung : hitung
# thn : thn
# lagii : lagi
# ketiga : tiga
# naufal : naufal
# okeee : okeee
# miminnn : miminnn
# gass : gass
# cekot : cekot
# gaa : gaa
# rizal : rizal
# intp : intp
# aldi : aldi
# urutan : urut
# konsumsi : konsumsi
# luv : luv
# giganet : giganet
# mengirimkan : kirim
# bnget : bnget
# hbis : hbis
# trf : trf
# ketekan : tekan
# trm : trm
# mksh : mksh
# rajin : rajin
# ngirim : ngirim
# broadcast : broadcast
# prasaan : prasaan
# sesering : sering
# aging : aging
# periode : periode
# rinaagsstn : rinaagsstn
# mamah : mamah
# bukopin : bukopin
# weh : weh
# haaa : haaa
# plislah : plislah
# kerjasamanya : kerjasamanya
# suban : suban
# merbau : merbau
# perbatasan : batas
# bdl : bdl
# lamsel : lamsel
# meleyot : leyot
# yutuban : yutuban
# ngetwit : ngetwit
# marahin : marahin
# lauren : lauren
# mega : mega
# berkala : kala
# ikhlasin : ikhlasin
# teratasi : atas
# bokek : bokek
# respect : respect
# homies : homies
# mengerti : erti
# meriahkan : riah
# jurnalis : jurnalis
# kuotaku : kuota
# luthfi : luthfi
# mantaab : mantaab
# diblockir : diblockir
# congrats : congrats
# devina : devina
# use : use
# can : can
# account : account
# pemabayaran : pemabayaran
# omongan : omong
# stroke : stroke
# inggil : inggil
# take : take
# gogreen : gogreen
# mulchar : mulchar
# space : space
# nelponin : nelponin
# giliran : gilir
# diangkat : angkat
# keputus : putus
# deneng : deneng
# njenengan : njenengan
# nek : nek
# pokemon : pokemon
# unite : unite
# nggeranu : nggeranu
# reconnecting : reconnecting
# ora : ora
# mung : mung
# sepisan : pis
# rapat : rapat
# cha : cha
# penyebabnya : sebab
# pengaturan : atur
# sanjaya : sanjaya
# ryanto : ryanto
# cilacap : cilacap
# manteng : manteng
# terooss : terooss
# dewi : dewi
# secepatnya : cepat
# choco : choco
# ndrew : ndrew
# parista : parista
# kejelasannya : jelas
# gera : gera
# uangnya : uang
# dipotong : potong
# hahaha : hahaha
# ngakak : ngakak
# monmaap : monmaap
# ibox : ibox
# keblok : blok
# bnerinnya : bnerinnya
# oggi : oggi
# pantesan : pantesan
# low : low
# kebanyakkan : banyak
# sponsorin : sponsorin
# speedtest : speedtest
# ookla : ookla
# tercepat : cepat
# dipegang : pegang
# fixed : fixed
# broadband : broadband
# biznet : biznet
# unggul : unggul
# kalen : kalen
# terikat : ikat
# ind : ind
# hom : hom
# fup : fup
# reloas : reloas
# gajadi : gajadi
# bigwin : bigwin
# reza : reza
# yoggi : yoggi
# fastresp : fastresp
# woo : woo
# koneksine : koneksine
# koyo : koyo
# koq : koq
# bayarnya : bayar
# penipunya : tipu
# ceritanya : cerita
# wanda : wanda
# ane : ane
# menghilang : hilang
# andri : andri
# terdaftarnya : daftar
# djponline : djponline
# mendukung : dukung
# pengiriman : kirim
# otp : otp
# mhdand : mhdand
# farid : farid
# dian : dian
# membutuhkan : butuh
# shg : shg
# asik : asik
# knpa : knpa
# kartuhallo : kartuhallo
# hrus : hrus
# berpikir : pikir
# pandemik : pandemik
# anggap : anggap
# kweren : kweren
# joe : joe
# taslim : taslim
# naha : naha
# tukarpulsa : tukarpulsa
# convertpulsa : convertpulsa
# pulsacek : pulsacek
# gih : gih
# inyfm : inyfm
# uname : uname
# jaemin : jaemin
# ehh : ehh
# ngaku : ngaku
# daahh : daahh
# reska : reska
# fin : fin
# tim : tim
# teknis : teknis
# amidamaru : amidamaru
# cahyari : cahyari
# duitnya : duit
# doyan : doyan
# ngebagi : ngebagi
# quota : quota
# gece : gece
# vilora : vilora
# paketnmya : paketnmya
# kindly : kindly
# indo : indo
# kplus : kplus
# haram : haram
# kesini : kesini
# astoge : astoge
# pongki : pongki
# maksud : maksud
# terkhusus : khusus
# tksh : tksh
# hosea : hosea
# ngetweet : ngetweet
# hotspot : hotspot
# kang : kang
# jangkung : jangkung
# makannya : makan
# konsep : konsep
# ngerugiin : ngerugiin
# tanggung : tanggung
# barunya : baru
# getcontact : getcontact
# fess : fess
# gajelas : gajelas
# saputra : saputra
# tmn : tmn
# kacaw : kacaw
# tolol : tolol
# siaap : siaap
# mhmdfadhillah : mhmdfadhillah
# hadirkan : hadir
# entertainment : entertainment
# montage : montage
# asty : asty
# verifikasi : verifikasi
# njaman : njaman
# mengumumkan : umum
# ngebut : ngebut
# eyco : eyco
# accept : accept
# demand : demand
# perfect : perfect
# umur : umur
# kondisi : kondisi
# berbatas : batas
# selelet : lelet
# acak : acak
# menyesuaikan : sesuai
# skema : skema
# mon : mon
# muter : muter
# jeli : jeli
# tku : tku
# lang : lang
# berkolaborasi : kolaborasi
# mengintegrasikan : integrasi
# beragam : agam
# verifikasinya : verifikasi
# kutunggu : tunggu
# membuktikan : bukti
# undian : undi
# sekedar : dar
# mitos : mitos
# minggu : minggu
# kegiatan : giat
# biasku : bias
# sepi : sepi
# logo : logo
# heyoo : heyoo
# ajaa : ajaa
# pastinya : pasti
# dibio : dibio
# saranin : saranin
# logout : logout
# melindungi : lindung
# kerahasiaan : rahasia
# otw : otw
# indri : indri
# ririn : ririn
# bertambah : tambah
# balasannya : balas
# stlh : stlh
# maksudnya : maksud
# report : report
# pengecekannya : kece
# magang : magang
# survey : survey
# dijit : dijit
# sawit : sawit
# parlay : parlay
# lose : lose
# dibayar : bayar
# viabank : viabank
# cimb : cimb
# bni : bni
# bri : bri
# login : login
# smsnya : smsnya
# gmana : gmana
# log : log
# hihhahh : hihhahh
# william : william
# jaja : jaja
# oaket : oaket
# matikan : mati
# nyalakan : nyala
# selasa : selasa
# mnt : mnt
# skg : skg
# caroline : caroline
# posisi : posisi
# disarankan : saran
# hindarin : hindarin
# benefitnya : benefitnya
# nyimpen : nyimpen
# satunya : satu
# batang : batang
# pricelist : pricelist
# ridho : ridho
# jie : jie
# pedraventi : pedraventi
# keburu : keburu
# paketanku : paket
# ahahahah : ahahahah
# tabungan : tabung
# now : now
# cont : cont
# villanelle : villanelle
# widget : widget
# care : care
# bagusnya : bagus
# sdngkan : sdngkan
# pusat : pusat
# yud : yud
# raa : raa
# corporate : corporate
# kepikiran : pikir
# babel : babel
# flap : flap
# mengakibatkan : akibat
# ketidaknyamanannya : ketidaknyamanannya
# hadapi : hadap
# message : message
# dimasukin : dimasukin
# saldokuuu : saldokuuu
# send : send
# umb : umb
# permudah : mudah
# resmi : resmi
# terintegrasi : integrasi
# mobitekno : mobitekno
# memanfaatkan : manfaat
# momentum : momentum
# kamis : kamis
# teutama : teutama
# anime : anime
# peparnas : peparnas
# xvi : xvi
# papua : papua
# termurah : murah
# detik : detik
# woylah : woylah
# paketanya : paketanya
# nafas : nafas
# udahan : udahan
# abaikan : abai
# bobrok : bobrok
# jumat : jumat
# guaaa : guaaa
# kejar : kejar
# mimpi : mimpi
# gaisa : gaisa
# hadewh : hadewh
# faiz : faiz
# commerce : commerce
# suryaqq : suryaqq
# rendah : rendah
# tata : tata
# cakra : cakra
# tindakan : tindak
# sejenisnya : jenis
# dimeeting : dimeeting
# dachlach : dachlach
# merusak : rusak
# moodku : moodku
# buruannnn : buruannnn
# hadehhh : hadehhh
# sengamuk : sengamuk
# points : points
# nonprem : nonprem
# finet : finet
# foya : foya
# ngorbanin : ngorbanin
# gajian : gaji
# untungnya : untung
# silang : silang
# pencerahannya : cerah
# obi : obi
# romeldymastio : romeldymastio
# yozie : yozie
# tungguin : tungguin
# sandy : sandy
# yon : yon
# ikhrulm : ikhrulm
# melalukan : lalu
# unlimeted : unlimeted
# ditindak : tindak
# bybyobi : bybyobi
# kyaa : kyaa
# gomawooooo : gomawooooo
# lope : lope
# adora : adora
# terleselaikan : terleselaikan
# doni : doni
# tasya : tasya
# kamila : kamila
# tenggo : tenggo
# wicaksono : wicaksono
# tethering : tethering
# mbah : mbah
# samaa : samaa
# keyy : keyy
# pie : pie
# huhuhu : huhuhu
# bantuannya : bantu
# ttap : ttap
# brsan : brsan
# automated : automated
# response : response
# gunanya : guna
# shopan : shopan
# nihhhh : nihhhh
# asliiiii : asliiiii
# masukkk : masukkk
# emosiii : emosiii
# anisa : anisa
# bersifat : sifat
# personal : personal
# ditentukan : tentu
# smalem : smalem
# rombak : rombak
# smua : smua
# pegawainya : pegawai
# kenapaaa : kenapaaa
# kkumakilla : kkumakilla
# mamo : mamo
# niatnya : niat
# keisi : isi
# nyoba : nyoba
# scam : scam
# lol : lol
# hmmm : hmmm
# pdhal : pdhal
# pkej : pkej
# mlam : mlam
# rest : rest
# piyo : piyo
# dani : dan
# diabaikan : abai
# scammer : scammer
# legitnya : legit
# request : request
# ussd : ussd
# dikhawatirkan : khawatir
# brian : brian
# ryan : ryan
# fungsi : fungsi
# iky : iky
# complain : complain
# piye : piye
# judistia : judistia
# ping : ping
# wulan : wulan
# menanggapi : tanggap
# kacauu : kacauu
# ngeban : ngeban
# crypto : crypto
# wujud : wujud
# siagakan : siaga
# versi : versi
# kesetiaan : setia
# emergency : emergency
# calls : calls
# cekk : cekk
# leleee : leleee
# vani : vani
# sekolahh : sekolahh
# diinstal : diinstal
# offkan : offkan
# krtu : krtu
# mama : mama
# untk : untk
# ppkm : ppkm
# willi : willi
# kerasa : rasa
# lagnya : lagnya
# anna : anna
# dosa : dosa
# berubah : ubah
# andrian : andrian
# bentar : bentar
# utan : utan
# duuuul : duuuul
# atuh : atuh
# {'hai': 'hai', 'kak': 'kak', 'maaf': 'maaf', 'banget': 'banget', 'mimin': 'mimin', 'mohon': 'mohon', 'ketersediaan': 'sedia', 'kakak': 'kakak', 'menunggu': 'tunggu', 'balas': 'balas', 'makasih': 'makasih', 'khasa': 'khasa', 'tetep': 'tetep', 'pesan': 'pesan', 'membeli': 'beli', 'produk': 'produk', 'gimana': 'gimana', '': '', 'gsp': 'gsp', 'dapet': 'dapet', 'sms': 'sms', 'nawarin': 'nawarin', 'hadiah': 'hadiah', 'togel': 'togel', 'pinjol': 'pinjol', 'link': 'link', 'halo': 'halo', 'kartu': 'kartu', 'sim': 'sim', 'loop': 'loop', 'menerima': 'terima', 'mati': 'mati', 'tenggang': 'tenggang', 'tolong': 'tolong', 'dicek': 'cek', 'solusinya': 'solusi', 'cek': 'cek', 'lhoo': 'lhoo', 'terkait': 'kait', 'kendala': 'kendala', 'aktivasi': 'aktivasi', 'kuota': 'kuota', 'malam': 'malam', 'udh': 'udh', 'coba': 'coba', 'saran': 'saran', 'berkendala': 'kendala', 'yuk': 'yuk', 'infoin': 'infoin', 'via': 'via', 'bantu': 'bantu', 'privasi': 'privasi', 'terjaga': 'jaga', 'tks': 'tks', 'risa': 'risa', 'dibalas': 'balas', 'terima': 'terima', 'kasih': 'kasih', 'bsa': 'bsa', 'ngentot': 'ngentot', 'dial': 'dial', 'semoga': 'moga', 'membantu': 'bantu', 'dwika': 'dwika', 'convert': 'convert', 'pulsa': 'pulsa', 'indosat': 'indosat', 'isat': 'isat', 'telkomsel': 'telkomsel', 'tsel': 'tsel', 'smartfren': 'smartfren', 'axis': 'axis', 'testi': 'testi', 'whatsapp': 'whatsapp', 'tuker': 'tuker', 'tukar': 'tukar', 'cairin': 'cairin', 'uang': 'uang', 'ewallet': 'ewallet', 'wallet': 'wallet', 'gopay': 'gopay', 'ovo': 'ovo', 'dana': 'dana', 'linkaja': 'linkaja', 'shopeepay': 'shopeepay', 'spay': 'spay', 'bank': 'bank', 'dwii': 'dwii', 'pagi': 'pagi', 'fredi': 'fredi', 'paket': 'paket', 'udah': 'udah', 'ilang': 'ilang', 'min': 'min', 'detail': 'detail', 'alami': 'alami', 'bantuin': 'bantuin', 'selesaiin': 'selesaiin', 'kendalanya': 'kendala', 'langsung': 'langsung', 'keluhan': 'keluh', 'ketidaksesuaian': 'ketidaksesuaian', 'penggunaan': 'guna', 'tgl': 'tgl', 'kejadian': 'jadi', 'jenis': 'jenis', 'harga': 'harga', 'nuri': 'nuri', 'yuli': 'yuli', 'ketersediaannya': 'sedia', 'gangguan': 'ganggu', 'mulu': 'mulu', 'kesel': 'kesel', 'pas': 'pas', 'org': 'org', 'kerja': 'kerja', 'bangsat': 'bangsat', 'ilangin': 'ilangin', 'down': 'down', 'linda': 'linda', 'tagl': 'tagl', 'kemarin': 'kemarin', 'kirim': 'kirim', 'data': 'data', 'dibalasi': 'balas', 'datanya': 'data', 'dmnya': 'dmnya', 'maksdunya': 'maksdunya', 'langganan': 'langgan', 'viu': 'viu', 'belom': 'bom', 'dipake': 'dipake', 'sampe': 'sampe', 'lupa': 'lupa', 'trs': 'trs', 'beli': 'beli', 'internet': 'internet', 'bisanya': 'bisa', 'bima': 'bima', 'sinyal': 'sinyal', 'stabil': 'stabil', 'refresh': 'refresh', 'jaringan': 'jaring', 'pindah': 'pindah', 'otomatis': 'otomatis', 'manual': 'manual', 'lokasi': 'lokasi', 'kelurahan': 'lurah', 'kecamatan': 'camat', 'nomor': 'nomor', 'dicoba': 'coba', 'restart': 'restart', 'kel': 'kel', 'kec': 'kec', 'kota': 'kota', 'dialami': 'alami', 'chanel': 'chanel', 'pembelian': 'beli', 'dibeli': 'beli', 'berasa': 'asa', 'gb': 'gb', 'sisa': 'sisa', 'bar': 'bar', 'dadakan': 'dada', 'diceritain': 'diceritain', 'layanan': 'layan', 'knp': 'knp', 'paketan': 'paket', 'bngt': 'bngt', 'double': 'double', 'telpon': 'telpon', 'batas': 'batas', 'jam': 'jam', 'nonstop': 'nonstop', 'rb': 'rb', 'silahkan': 'silah', 'ikutan': 'ikut', 'komunitas': 'komunitas', 'cug': 'cug', 'woy': 'woy', 'telkom': 'telkom', 'ajg': 'ajg', 'signal': 'signal', 'tbtb': 'tbtb', 'turun': 'turun', 'daerah': 'daerah', 'mataram': 'mataram', 'shidqon': 'shidqon', 'reaktivasi': 'reaktivasi', 'hangus': 'hangus', 'dibantu': 'bantu', 'ketentuan': 'tentu', 'melebihi': 'lebih', 'cepet': 'cepet', 'sinyalnya': 'sinyal', 'kayak': 'kayak', 'sebagus': 'bagus', 'nonton': 'nonton', 'buffering': 'buffering', 'buka': 'buka', 'twitter': 'twitter', 'kadang': 'kadang', 'reload': 'reload', 'memperpanjang': 'panjang', 'aktif': 'aktif', 'bgmana': 'bgmana', 'isi': 'isi', 'bantuanya': 'bantuanya', 'dna': 'dna', 'nama': 'nama', 'diaktifkan': 'aktif', 'laaa ...
# ------------------------
# Pandas Apply:   0%|          | 0/1952 [00:00<?, ?it/s]
#                                                 content  \
# 0     @pinkluvcattt hai, kak. maaf banget ya kak. ta...
# 1     @telkomsel tetep ga bisa kak, ada pesan anda t...
# 2     @mazzini_gsp hampir tiap hari dapet sms dari n...
# 3     @telkomsel halo, kartu sim loop saya tdk bisa ...
# 4     @l_lhoo baik, kak. maaf ya, terkait kendala ak...
# ...                                                 ...
# 1995  @andriannardo pagi kak andrian. maaf ya terkai...
# 1996  @alnius hai, kak alif. maaf ya, terkait kendal...
# 1997                              @telkomsel oke bentar
# 1998  @alnius @telkomsel iya ngeselin banget padahal...
# 1999  @alkecilsaja emang d utan duuuul nyari2 kuota ...
#
#                                          cleaning_tweet  \
# 0     hai kak maaf banget kak tapi mimin mohon keter...
# 1     tetep bisa kak ada pesan anda tidak bisa membe...
# 2      gsp hampir tiap hari dapet sms dari nawarin h...
# 3     halo kartu sim loop saya tdk bisa menerima sms...
# 4      lhoo baik kak maaf terkait kendala aktivasi k...
# ...                                                 ...
# 1995  pagi kak andrian maaf terkait pembelian berhas...
# 1996  hai kak alif maaf terkait kendala tdk bisa mel...
# 1997                                         oke bentar
# 1998  iya ngeselin banget padahal butuh buat zoom kelas
# 1999  emang utan duuuul nyari  kuota susah pake apli...
#
#                                              tokenisasi  \
# 0     [hai, kak, maaf, banget, kak, tapi, mimin, moh...
# 1     [tetep, bisa, kak, ada, pesan, anda, tidak, bi...
# 2     [, gsp, hampir, tiap, hari, dapet, sms, dari, ...
# 3     [halo, kartu, sim, loop, saya, tdk, bisa, mene...
# 4     [, lhoo, baik, kak, maaf, terkait, kendala, ak...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, terkait, pembelian,...
# 1996  [hai, kak, alif, maaf, terkait, kendala, tdk, ...
# 1997                                      [oke, bentar]
# 1998  [iya, ngeselin, banget, padahal, butuh, buat, ...
# 1999  [emang, utan, duuuul, nyari, kuota, susah, pak...
#
#                                                stopword  \
# 0     [hai, kak, maaf, banget, kak, mimin, mohon, ke...
# 1        [tetep, kak, pesan, membeli, produk, gimana, ]
# 2     [, gsp, dapet, sms, nawarin, hadiah, togel, pi...
# 3     [halo, kartu, sim, loop, menerima, sms, kartu,...
# 4     [, lhoo, kak, maaf, terkait, kendala, aktivasi...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, terkait, pembelian,...
# 1996  [hai, kak, alif, maaf, terkait, kendala, pemba...
# 1997                                      [oke, bentar]
# 1998        [iya, ngeselin, banget, butuh, zoom, kelas]
# 1999  [emang, utan, duuuul, nyari, kuota, susah, apl...
#
#                                                stemming
# 0     [hai, kak, maaf, banget, kak, mimin, mohon, se...
# 1           [tetep, kak, pesan, beli, produk, gimana, ]
# 2     [, gsp, dapet, sms, nawarin, hadiah, togel, pi...
# 3     [halo, kartu, sim, loop, terima, sms, kartu, m...
# 4     [, lhoo, kak, maaf, kait, kendala, aktivasi, k...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, kait, beli, hasil, ...
# 1996  [hai, kak, alif, maaf, kait, kendala, bayar, m...
# 1997                                      [oke, bentar]
# 1998        [iya, ngeselin, banget, butuh, zoom, kelas]
# 1999  [emang, utan, duuuul, nyari, kuota, susah, apl...
#
# [1952 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [hai, kak, maaf, banget, kak, mimin, mohon, se...
# 1           [tetep, kak, pesan, beli, produk, gimana, ]
# 2     [, gsp, dapet, sms, nawarin, hadiah, togel, pi...
# 3     [halo, kartu, sim, loop, terima, sms, kartu, m...
# 4     [, lhoo, kak, maaf, kait, kendala, aktivasi, k...
# ...                                                 ...
# 1995  [pagi, kak, andrian, maaf, kait, beli, hasil, ...
# 1996  [hai, kak, alif, maaf, kait, kendala, bayar, m...
# 1997                                      [oke, bentar]
# 1998        [iya, ngeselin, banget, butuh, zoom, kelas]
# 1999  [emang, utan, duuuul, nyari, kuota, susah, apl...
#
# [1952 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_10.xlsx')
