# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_TELKOMSEL\data mentah\crawlingtweet_telkomsel_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     #BelievedTesti\n\n#BelievedPulsa pulsa transfe...
# 1     @Achmadsatori4 @Dennysiregar7 @Telkomsel Kok s...
# 2     @muelnoona Hai, Kak Aisha. Maaf ya. Mengenai k...
# 3     @HudihartoBandy @msaid_didu Telkomsel itu anak...
# 4     Ane dah lama ga pake Telkomsel dan Telpon Ruma...
# ...                                                 ...
# 1995  @handre_81 @Dennysiregar7 @Telkomsel bang deny...
# 1996  @Telkomsel Jaringan nya ilang-ilangan terus ka...
# 1997  @Untung51440057 @Dennysiregar7 @Telkomsel http...
# 1998  @RieGucciano Nomornya Abdee Negara Pakai Ex-El...
# 1999  @Dennysiregar7 @Telkomsel Alamat saham $TLKM A...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 9

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     #BelievedTesti\n\n#BelievedPulsa pulsa transfe...
# 1     @Achmadsatori4 @Dennysiregar7 @Telkomsel Kok s...
# 2     @muelnoona Hai, Kak Aisha. Maaf ya. Mengenai k...
# 3     @HudihartoBandy @msaid_didu Telkomsel itu anak...
# 4     Ane dah lama ga pake Telkomsel dan Telpon Ruma...
# ...                                                 ...
# 1995  @handre_81 @Dennysiregar7 @Telkomsel bang deny...
# 1996  @Telkomsel Jaringan nya ilang-ilangan terus ka...
# 1997  @Untung51440057 @Dennysiregar7 @Telkomsel http...
# 1998  @RieGucciano Nomornya Abdee Negara Pakai Ex-El...
# 1999  @Dennysiregar7 @Telkomsel Alamat saham $TLKM A...
#
# [1983 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     #believedtesti\n\n#believedpulsa pulsa transfe...
# 1     @achmadsatori4 @dennysiregar7 @telkomsel kok s...
# 2     @muelnoona hai, kak aisha. maaf ya. mengenai k...
# 3     @hudihartobandy @msaid_didu telkomsel itu anak...
# 4     ane dah lama ga pake telkomsel dan telpon ruma...
# ...                                                 ...
# 1995  @handre_81 @dennysiregar7 @telkomsel bang deny...
# 1996  @telkomsel jaringan nya ilang-ilangan terus ka...
# 1997  @untung51440057 @dennysiregar7 @telkomsel http...
# 1998  @riegucciano nomornya abdee negara pakai ex-el...
# 1999  @dennysiregar7 @telkomsel alamat saham $tlkm a...
#
# [1983 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     #believedtesti\n\n#believedpulsa pulsa transfe...
# 1     @achmadsatori4 @dennysiregar7 @telkomsel kok s...
# 2     @muelnoona hai, kak aisha. maaf ya. mengenai k...
# 3     @hudihartobandy @msaid_didu telkomsel itu anak...
# 4     ane dah lama ga pake telkomsel dan telpon ruma...
# ...                                                 ...
# 1995  @handre_81 @dennysiregar7 @telkomsel bang deny...
# 1996  @telkomsel jaringan nya ilang-ilangan terus ka...
# 1997  @untung51440057 @dennysiregar7 @telkomsel http...
# 1998  @riegucciano nomornya abdee negara pakai ex-el...
# 1999  @dennysiregar7 @telkomsel alamat saham $tlkm a...
#
#                                          cleaning_tweet
# 0     pulsa transfer indosat telkomsel smartfren min...
# 1                        kok senang banget bacanya gue
# 2     hai kak aisha maaf mengenai keluhan paket daru...
# 3      didu telkomsel itu anak usaha telkom blok ken...
# 4     ane dah lama pake telkomsel dan telpon rumah p...
# ...                                                 ...
# 1995   bang deny kalau tidak punya kapabilitas bidan...
# 1996  jaringan nya ilang ilangan terus kaya dia aku ...
# 1997                          itu hskim kadrun wekkkkk
# 1998  nomornya abdee negara pakai bukan nomor telkomsel
# 1999  alamat saham tlkm arb hari malam ngungsi dulu ...
#
# [1983 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     #believedtesti\n\n#believedpulsa pulsa transfe...
# 1     @achmadsatori4 @dennysiregar7 @telkomsel kok s...
# 2     @muelnoona hai, kak aisha. maaf ya. mengenai k...
# 3     @hudihartobandy @msaid_didu telkomsel itu anak...
# 4     ane dah lama ga pake telkomsel dan telpon ruma...
# ...                                                 ...
# 1995  @handre_81 @dennysiregar7 @telkomsel bang deny...
# 1996  @telkomsel jaringan nya ilang-ilangan terus ka...
# 1997  @untung51440057 @dennysiregar7 @telkomsel http...
# 1998  @riegucciano nomornya abdee negara pakai ex-el...
# 1999  @dennysiregar7 @telkomsel alamat saham $tlkm a...
#
#                                          cleaning_tweet  \
# 0     pulsa transfer indosat telkomsel smartfren min...
# 1                        kok senang banget bacanya gue
# 2     hai kak aisha maaf mengenai keluhan paket daru...
# 3      didu telkomsel itu anak usaha telkom blok ken...
# 4     ane dah lama pake telkomsel dan telpon rumah p...
# ...                                                 ...
# 1995   bang deny kalau tidak punya kapabilitas bidan...
# 1996  jaringan nya ilang ilangan terus kaya dia aku ...
# 1997                          itu hskim kadrun wekkkkk
# 1998  nomornya abdee negara pakai bukan nomor telkomsel
# 1999  alamat saham tlkm arb hari malam ngungsi dulu ...
#
#                                              tokenisasi
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                 [kok, senang, banget, bacanya, gue, ]
# 2     [hai, kak, aisha, maaf, mengenai, keluhan, pak...
# 3     [, didu, telkomsel, itu, anak, usaha, telkom, ...
# 4     [ane, dah, lama, pake, telkomsel, dan, telpon,...
# ...                                                 ...
# 1995  [, bang, deny, kalau, tidak, punya, kapabilita...
# 1996  [jaringan, nya, ilang, ilangan, terus, kaya, d...
# 1997                    [itu, hskim, kadrun, wekkkkk, ]
# 1998  [nomornya, abdee, negara, pakai, bukan, nomor,...
# 1999  [alamat, saham, tlkm, arb, hari, malam, ngungs...
#
# [1983 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0     #believedtesti\n\n#believedpulsa pulsa transfe...
# 1     @achmadsatori4 @dennysiregar7 @telkomsel kok s...
# 2     @muelnoona hai, kak aisha. maaf ya. mengenai k...
# 3     @hudihartobandy @msaid_didu telkomsel itu anak...
# 4     ane dah lama ga pake telkomsel dan telpon ruma...
# ...                                                 ...
# 1995  @handre_81 @dennysiregar7 @telkomsel bang deny...
# 1996  @telkomsel jaringan nya ilang-ilangan terus ka...
# 1997  @untung51440057 @dennysiregar7 @telkomsel http...
# 1998  @riegucciano nomornya abdee negara pakai ex-el...
# 1999  @dennysiregar7 @telkomsel alamat saham $tlkm a...
#
#                                          cleaning_tweet  \
# 0     pulsa transfer indosat telkomsel smartfren min...
# 1                        kok senang banget bacanya gue
# 2     hai kak aisha maaf mengenai keluhan paket daru...
# 3      didu telkomsel itu anak usaha telkom blok ken...
# 4     ane dah lama pake telkomsel dan telpon rumah p...
# ...                                                 ...
# 1995   bang deny kalau tidak punya kapabilitas bidan...
# 1996  jaringan nya ilang ilangan terus kaya dia aku ...
# 1997                          itu hskim kadrun wekkkkk
# 1998  nomornya abdee negara pakai bukan nomor telkomsel
# 1999  alamat saham tlkm arb hari malam ngungsi dulu ...
#
#                                              tokenisasi  \
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                 [kok, senang, banget, bacanya, gue, ]
# 2     [hai, kak, aisha, maaf, mengenai, keluhan, pak...
# 3     [, didu, telkomsel, itu, anak, usaha, telkom, ...
# 4     [ane, dah, lama, pake, telkomsel, dan, telpon,...
# ...                                                 ...
# 1995  [, bang, deny, kalau, tidak, punya, kapabilita...
# 1996  [jaringan, nya, ilang, ilangan, terus, kaya, d...
# 1997                    [itu, hskim, kadrun, wekkkkk, ]
# 1998  [nomornya, abdee, negara, pakai, bukan, nomor,...
# 1999  [alamat, saham, tlkm, arb, hari, malam, ngungs...
#
#                                                stopword
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                      [senang, banget, bacanya, gue, ]
# 2     [hai, kak, aisha, maaf, keluhan, paket, darura...
# 3     [, didu, telkomsel, anak, usaha, telkom, blok,...
# 4     [ane, telkomsel, telpon, rumah, pulsa, mahal, ...
# ...                                                 ...
# 1995  [, bang, deny, kapabilitas, bidangnya, kadrun,...
# 1996  [jaringan, ilang, ilangan, kaya, twitteran, le...
# 1997                         [hskim, kadrun, wekkkkk, ]
# 1998  [nomornya, abdee, negara, pakai, nomor, telkom...
# 1999  [alamat, saham, tlkm, arb, malam, ngungsi, pin...
#
# [1983 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 4591
# ------------------------
# pulsa : pulsa
# transfer : transfer
# indosat : indosat
# telkomsel : telkomsel
# smartfren : smartfren
# minggu : minggu
# mei : mei
#  :
# senang : senang
# banget : banget
# bacanya : baca
# gue : gue
# hai : hai
# kak : kak
# aisha : aisha
# maaf : maaf
# keluhan : keluh
# paket : paket
# darurat : darurat
# aktif : aktif
# infokan : info
# data : data
# via : via
# dibantu : bantu
# cek : cek
# privasi : privasi
# terjaga : jaga
# nomor : nomor
# lokasi : lokasi
# makasih : makasih
# elma : elma
# didu : didu
# anak : anak
# usaha : usaha
# telkom : telkom
# blok : blok
# komisaris : komisaris
# lini : lini
# bisnis : bisnis
# salah : salah
# satunya : satu
# ane : ane
# telpon : telpon
# rumah : rumah
# mahal : mahal
# kuota : kuota
# boros : boros
# ampun : ampun
# bandyyy : bandyyy
# bandy : bandy
# umur : umur
# brp : brp
# nak : nak
# blm : blm
# eluh : eluh
# maen : maen
# twiter : twiter
# mancing : mancing
# jugak : jugak
# belajar : ajar
# rajin : rajin
# pinter : pinter
# sbg : sbg
# ttg : ttg
# gih : gih
# korupsi : korupsi
# anies : anies
# dipanggil : panggil
# bang : bang
# inggi : inggi
# xixixixi : xixixixi
# kendala : kendala
# top : top
# silakan : sila
# detail : detail
# tanggal : tanggal
# kejadian : jadi
# kakak : kakak
# micha : micha
# pelanggan : langgan
# udah : udah
# anjlok : anjlok
# kisah : kisah
# lawas : lawas
# versi : versi
# kali : kali
# coba : coba
# failed : failed
# gangguan : ganggu
# notifikasinya : notifikasi
# menunggu : tunggu
# proses : proses
# provider : provider
# kartuhalo : kartuhalo
# syamsurizal : syamsurizal
# mimin : mimin
# sarankan : saran
# memposting : memposting
# pribadi : pribadi
# mention : mention
# menghindari : hindar
# penyalahgunaan : penyalahgunaan
# orang : orang
# bertanggung : tanggung
# bantu : bantu
# mohon : mohon
# berkenan : kenan
# cheryl : cheryl
# woi : woi
# cebong : cebong
# kodok : kodok
# dungu : dungu
# beda : beda
# lol : lol
# goblok : goblok
# bentar : bentar
# dapet : dapet
# hadiah : hadiah
# luh : luh
# ra : ra
# betuuuul : betuuuul
# betuuul : betuuul
# bkn : bkn
# aplg : aplg
# pinjol : pinjol
# sll : sll
# masuk : masuk
# smsnya : smsnya
# perdana : perdana
# simcardnya : simcardnya
# telp : telp
# menawarkan : tawar
# terheran : heran
# heran : heran
# dri : dri
# mmg : mmg
# kerjasama : kerjasama
# aktivasi : aktivasi
# paketnya : paket
# yuk : yuk
# infoin : infoin
# nama : nama
# lengkap : lengkap
# lahir : lahir
# syam : syam
# gimana : gimana
# beli : beli
# tambahan : tambah
# kartu : kartu
# hallo : hallo
# barusan : barusan
# lapor : lapor
# call : call
# center : center
# pembatalan : batal
# transaksi : transaksi
# dibatalkan : batal
# ditambah : tambah
# harian : hari
# solusi : solusi
# wajar : wajar
# den : den
# banting : banting
# tulang : tulang
# jiwa : jiwa
# raga : raga
# pertaruhkan : taruh
# dlm : dlm
# hati : hati
# diamput : amput
# iya : iya
# jatah : jatah
# puas : puas
# dpt : dpt
# gaji : gaji
# kau : kau
# hahahaha : hahahaha
# penyembah : sembah
# kuburan : kubur
# tolol : tolol
# pagi : pagi
# seputar : putar
# produk : produk
# layanan : layan
# ngamuk : ngamuk
# singapur : singapur
# gitaris : gitaris
# dijadikan : jadi
# cocok : cocok
# bingit : bingit
# selamat : selamat
# salahnya : salah
# dimana : mana
# terpilih : pilih
# dipertimbangkan : timbang
# kapasitasnya : kapasitas
# dukung : dukung
# donk : donk
# kemajuan : maju
# bangsa : bangsa
# mudah : mudah
# wkwkwkwkwkw : wkwkwkwkwkw
# ngakak : ngakak
# guling : guling
# raganya : raga
# dipertaruhkan : taruh
# dilirik : lirik
# kagak : kagak
# pekok : kok
# cocot : cocot
# belooon : belooon
# akut : akut
# gsp : gsp
# jokowi : jokowi
# mengangkat : angkat
# abdee : abdee
# slank : slank
# sukses : sukses
# bismillah : bismillah
# direktur : direktur
# ptpn : ptpn
# xii : xii
# anggota : anggota
# agoest : agoest
# kakron : kakron
# moharwani : moharwani
# denny : denny
# baca : baca
# abde : abde
# panik : panik
# gua : gua
# dedikasikan : dedikasi
# menyandang : sandang
# alias : alias
# jabatan : jabat
# daya : daya
# indy : indy
# antrian : antri
# interaksi : interaksi
# chika : chika
# daftar : daftar
# ghz : ghz
# fakhri : fakhri
# jogja : jogja
# membawa : bawa
# redmi : redmi
# note : note
# indonesia : indonesia
# pembelian : beli
# gb : gb
# rb : rb
# rupiah : rupiah
# dongok : dongok
# otak : otak
# dodol : dodol
# bambang : bambang
# setia : setia
# berupaya : upaya
# maksimal : maksimal
# memuaskan : muas
# pengguna : guna
# lupa : lupa
# pakai : pakai
# masker : masker
# sehat : sehat
# ditawarin : ditawarin
# org : org
# isi : isi
# otaknya : otak
# sesuai : sesuai
# cuitannya : cuit
# sampah : sampah
# kelasnya : kelas
# laler : laler
# ijo : ijo
# disampahan : sampah
# prestige : prestige
# halo : halo
# dimas : mas
# konfirmasi : konfirmasi
# list : list
# ditunggu : tunggu
# rekan : rekan
# merespon : merespon
# kerja : kerja
# pegawai : pegawai
# belom : bom
# dibales : dibales
# kebanyakan : banyak
# makan : makan
# bipang : bipang
# guuoblooknya : guuoblooknya
# acut : acut
# mati : mati
# deh : deh
# mediana : mediana
# migrasi : migrasi
# jenis : jenis
# pascabayar : pascabayar
# proteksi : proteksi
# ikutan : ikut
# quiz : quiz
# rasi : rasi
# esia : esia
# zen : zen
# berkendala : kendala
# minimal : minimal
# kecamatan : camat
# kota : kota
# nyaman : nyaman
# jaringan : jaring
# mencoba : coba
# refresh : refresh
# pindahkan : pindah
# mode : mode
# otomatis : otomatis
# manual : manual
# kembalikan : kembali
# open : open
# tri : tri
# rate : rate
# convert : convert
# jual : jual
# tsel : tsel
# murah : murah
# zonaba : zonaba
# zonabu : zonabu
# zonauang : zonauang
# ready : ready
# axis : axis
# admin : admin
# kartunya : kartu
# pasca : pasca
# bayar : bayar
# prabayar : prabayar
# kasih : kasih
# rusak : rusak
# bener : bener
# pemakai : pakai
# narkoba : narkoba
# kambuhan : kambuh
# akses : akses
# spotify : spotify
# nunggu : nunggu
# muncul : muncul
# judulnya : judul
# bersih : bersih
# masak : masak
# iyo : iyo
# dikotorin : dikotorin
# atasi : atas
# oknum : oknum
# pencuri : curi
# meresahkan : resah
# fitur : fitur
# mengunjungi : unjung
# mengisi : isi
# form : form
# registrasi : registrasi
# aspirasi : aspirasi
# bahan : bahan
# pertimbangan : timbang
# pengembangan : kembang
# jay : jay
# neh : neh
# yak : yak
# jamila : jamila
# tunggu : tunggu
# arno : arno
# pls : pls
# tks : tks
# info : info
# diem : diem
# ajalah : aja
# ngalamin : ngalamin
# tagihan : tagih
# th : th
# bermasalah : masalah
# desi : desi
# mansek : mansek
# korbannya : korban
# tetangga : tetangga
# raib : raib
# ratusan : ratus
# juta : juta
# lawyer : lawyer
# polisi : polisi
# mending : mending
# mas : mas
# usim : usim
# diaktifkan : aktif
# im : im
# dikerjain : dikerjain
# praktek : praktek
# sinyal : sinyal
# meluas : luas
# nusantara : nusantara
# rezim : rezim
# kacung : kacung
# china : china
# gagal : gagal
# total : total
# ekonomi : ekonomi
# kuasai : kuasa
# aparat : aparat
# tergiur : giur
# fasis : fasis
# injak : injak
# hukum : hukum
# konstitusi : konstitusi
# kejam : kejam
# membunuh : bunuh
# facist : facist
# regime : regime
# facilitates : facilitates
# predatory : predatory
# business : business
# ayo : ayo
# kuis : kuis
# done : done
# follow : follow
# all : all
# sosmed : sosmed
# sumantri : sumantri
# budi : budi
# utomo : utomo
# dipermasalahkan : masalah
# mempermasalhkan : mempermasalhkan
# cape : cape
# berdarah : darah
# darah : darah
# mendukung : dukung
# pangkat : pangkat
# dikasta : kasta
# terendah : rendah
# buzzer : buzzer
# difollow : difollow
# anggotanya : anggota
# swndiri : swndiri
# bersihkan : sih
# pertamina : pertamina
# kadrun : kadrun
# marketing : marketing
# mulu : mulu
# pelayanan : layan
# abaikan : abai
# sapa : sapa
# ayoo : ayoo
# semoga : moga
# perbaiki : baik
# selulernya : seluler
# tebak : tebak
# kue : kue
# kasusnya : kasus
# ama : ama
# unlimited : unlimited
# terupdate : terupdate
# ngefans : ngefans
# chelsea : chelsea
# sampe : sampe
# gelem : gelem
# ganti : ganti
# bocae : bocae
# btw : btw
# titules : titules
# celsi : celsi
# clesii : clesii
# louder : louder
# ketik : ketik
# ato : ato
# autocorrect : autocorrect
# ginian : ginian
# direspon : direspon
# min : min
# fida : fida
# terkait : kait
# tersedia : sedia
# aplikasi : aplikasi
# mytelkomsel : mytelkomsel
# clear : clear
# cache : cache
# rai : rai
# emang : emang
# temen : temen
# gosah : gosah
# ngarep : ngarep
# omongan : omong
# knp : knp
# gabisa : gabisa
# menganggu : menganggu
# kesel : kesel
# ajarin : ajarin
# bodoh : bodoh
# bedain : bedain
# jahat : jahat
# wkwkwk : wkwkwk
# minim : minim
# internet : internet
# miskin : miskin
# dibikin : bikin
# emosi : emosi
# jelek : jelek
# dikhul : dikhul
# sarannya : saran
# tampung : tampung
# diharapkan : harap
# terealisasikan : realisasi
# cinta : cinta
# nkri : nkri
# ngk : ngk
# bedanya : beda
# waras : waras
# gini : gin
# adakan : adakan
# promo : promo
# besaran : besar
# discount : discount
# dadakan : dada
# bro : bro
# dibahas : bahas
# ngomong : ngomong
# mangap : mangap
# berjuang : juang
# deni : den
# digaris : gar
# terdepan : depan
# maki : maki
# tandai : tanda
# residen : residen
# membela : bela
# apapun : apa
# langkah : langkah
# pokoknya : pokok
# dunia : dunia
# kadang : kadang
# adil : adil
# sabarrr : sabarrr
# hary : hary
# bani : bani
# bidang : bidang
# mingkem : mingkem
# pejabat : jabat
# usil : usil
# donasi : donasi
# umat : umat
# denger : denger
# eksekutif : eksekutif
# pim : pim
# klu : klu
# ngantor : ngantor
# make : make
# drug : drug
# spy : spy
# klihatan : klihatan
# gmane : gmane
# mmpus : mmpus
# corong : corong
# boss : boss
# ngedebus : ngedebus
# sampei : sampei
# lepas : lepas
# gigimu : gigi
# membedakan : beda
# becus : becus
# manusia : manusia
# model : model
# kiarain : kiarain
# neng : neng
# nurhanah : nurhanah
# larinya : lari
# situ : situ
# sim : sim
# kirim : kirim
# dody : dody
# perihal : perihal
# seringkali : seringkali
# complain : complain
# nmr : nmr
# terima : terima
# menit : menit
# koneksi : koneksi
# putus : putus
# kayak : kayak
# robot : robot
# standard : standard
# matikan : mati
# hidupkan : hidup
# malas : malas
# lihat : lihat
# indihome : indihome
# full : full
# nikmati : nikmat
# ikhlas : ikhlas
# dipecatkan : pecat
# perbaikan : baik
# pulihnya : pulih
# juni : juni
# kerusakan : rusa
# april : april
# tagihannya : tagih
# card : card
# telepon : telepon
# sms : sms
# erro : erro
# pembayaran : bayar
# jasa : jasa
# dinikmati : nikmat
# keuntungan : untung
# bayaran : bayar
# gigabit : gigabit
# etdah : etdah
# mah : mah
# ngurusin : ngurusin
# telekomunikasi : telekomunikasi
# milik : milik
# negara : negara
# nasib : nasib
# musisi : musisi
# terlambat : lambat
# kena : kena
# pinalty : pinalty
# suspended : suspended
# dibayar : bayar
# masyarakat : masyarakat
# tagihannnya : tagihannnya
# dicap : cap
# dasar : dasar
# taiii : taiii
# berita : berita
# bagus : bagus
# disana : sana
# modem : modem
# kabel : kabel
# berjalan : jalan
# andria : andria
# kakilima : kakilima
# wkwkwkwk : wkwkwkwk
# sempak : sempak
# merah : merah
# pura : pura
# ngaku : ngaku
# kenal : kenal
# wkwkwkwkwk : wkwkwkwkwk
# ijal : ijal
# terpotong : potong
# selasa : selasa
# bus : bus
# baju : baju
# bayarannya : bayar
# bermain : main
# game : game
# slot : slot
# online : online
# menang : menang
# deposit : deposit
# gopay : gopay
# linkaja : linkaja
# ovo : ovo
# dana : dana
# link : link
# daenk : daenk
# wilayah : wilayah
# jayapura : jayapura
# alami : alami
# saranin : saranin
# anshar : anshar
# permasalahan : masalah
# dialami : alami
# meningkatkan : tingkat
# kualitas : kualitas
# kenyamanan : nyaman
# harapan : harap
# pemerataan : perata
# fiber : fiber
# optik : optik
# menyebabkan : sebab
# intern : intern
# agenda : agenda
# rutin : rutin
# balikin : balikin
# tot : tot
# paketan : paket
# tbtb : tbtb
# sedot : sedot
# gaberes : gaberes
# kadrunnya : kadrunnya
# lucu : lucu
# sedih : sedih
# perusahaan : usaha
# ali : ali
# saran : saran
# nyedot : nyedot
# anjing : anjing
# off : off
# restart : restart
# dipake : dipake
# lambat : lambat
# servicenya : servicenya
# tgl : tgl
# internetan : internetan
# loading : loading
# gajalan : gajalan
# informasi : informasi
# kerahasiaan : rahasia
# new : new
# ekstra : ekstra
# berhentinya : henti
# ngga : ngga
# dikasih : kasih
# menampakkan : tampak
# sisi : sisi
# ketidak : tidak
# pintarannya : pintar
# alus : alus
# koment : koment
# ngerujak : ngerujak
# dibawah : bawah
# pohon : pohon
# asem : asem
# kasian : kasi
# nyela : nyela
# dibully : dibully
# potongan : potong
# birgita : birgita
# status : status
# dicek : cek
# jek : jek
# iso : iso
# gae : gae
# san : san
# maafin : maafin
# handphone : handphone
# dicoba : coba
# kuy : kuy
# edi : edi
# panggilan : panggil
# pelaporan : lapor
# bertugas : tugas
# laporan : lapor
# selesai : selesai
# customer : customer
# service : service
# jam : jam
# aktifasi : aktifasi
# ceria : ceria
# kunjung : kunjung
# berhasil : hasil
# yantie : yantie
# menyelengharakan : menyelengharakan
# bayu : bayu
# berencana : rencana
# simpati : simpati
# ragu : ragu
# kecepatan : cepat
# daerah : daerah
# yofi : yofi
# udh : udh
# launching : launching
# kiteeee : kiteeee
# smartphone : smartphone
# sadar : sadar
# chindev : chindev
# pulang : pulang
# kampung : kampung
# pas : pas
# bandung : bandung
# sirap : sirap
# subang : subang
# porto : porto
# tlkm : tlkm
# langsung : langsung
# hahaha : hahaha
# kuat : kuat
# streaming : streaming
# bola : bola
# kacau : kacau
# alun : alun
# kepake : kepake
# wuzz : wuzz
# cepet : cepet
# anehe : anehe
# omah : omah
# gaiso : gaiso
# ono : ono
# ngalami : ngalami
# opo : opo
# grapari : grapari
# suwun : suwun
# rek : rek
# wes : wes
# respon : respon
# cak : cak
# kenopo : kenopo
# lek : lek
# ndek : ndek
# penuh : penuh
# gawe : gawe
# sinyale : sinyale
# batang : batang
# blas : blas
# setting : setting
# podo : podo
# lemot : lot
# cont : cont
# muslim : muslim
# mgkn : mgkn
# maksud : maksud
# mak : mak
# yoen : yoen
# dikorup : korup
# cebi : cebi
# yamin : yamin
# stabil : stabil
# meunjukkan : meunjukkan
# ketololan : tolol
# stengah : stengah
# teruntuk : untuk
# tolong : tolong
# pelihara : pelihara
# pelosok : pelosok
# desa : desa
# bar : bar
# buffering : buffering
# nonton : nonton
# tanjung : tanjung
# siang : siang
# akhmad : akhmad
# dewi : dewi
# alhamdulilah : alhamdulilah
# skrg : skrg
# cuman : cuman
# dicolong : colong
# ceban : ceban
# pemerintah : perintah
# moh : moh
# bansos : bansos
# diembat : embat
# ngelawak : ngelawak
# napa : napa
# doang : doang
# labil : labil
# tod : tod
# dibandingkan : banding
# memalukan : malu
# bedakan : beda
# yoga : yoga
# ngetwit : ngetwit
# buzzerp : buzzerp
# ngapain : ngapain
# bela : bela
# palestina : palestina
# susah : susah
# anybody : anybody
# asing : asing
# nganggur : nganggur
# cuuuuk : cuuuuk
# kebagian : bagi
# nyalak : nyalak
# belajarlah : bajar
# malu : malu
# prioritas : prioritas
# preeeet : preeeet
# kek : kek
# acara : acara
# tipi : tipi
# nopi : nopi
# waspadalah : waspada
# waspadalahh : waspadalahh
# mantan : mantan
# pecandu : candu
# pezina : zina
# ambyar : ambyar
# menarik : tarik
# dial : dial
# irfan : irfan
# bulanan : bulan
# bersifat : sifat
# berbatas : batas
# berlaku : laku
# kalah : kalah
# meningggalkan : meningggalkan
# menghukum : hukum
# politik : politik
# balas : balas
# berkesudahan : sudah
# chris : chris
# prosesnya : proses
# maxstream : maxstream
# liat : liat
# tab : tab
# ridak : ridak
# distatus : status
# mensosialisasikan : sosialisasi
# cannabis : cannabis
# sativa : sativa
# fans : fans
# meroket : roket
# diangkasa : angkasa
# hahahahaaaaaa : hahahahaaaaaa
# terimakasih : terimakasih
# yaa : yaa
# final : final
# city : city
# payah : payah
# pulsanya : pulsa
# diabisin : diabisin
# melon : melon
# apel : apel
# ukuran : ukur
# strategi : strategi
# pengganti : ganti
# itunes : itunes
# oalahh : oalahh
# gituu : gituu
# okay : okay
# makasihhh : makasihhh
# degdegan : degdegan
# gatau : gatau
# bismilah : bismilah
# sia : sia
# siain : siain
# ribu : ribu
# flissshh : flissshh
# bner : bner
# dlu : dlu
# desain : desain
# halaman : halaman
# layar : layar
# komisarisnya : komisaris
# berfoto : foto
# pose : pose
# buka : buka
# bukaan : buka
# tertutup : tutup
# otongnya : otongnya
# hpmu : hpmu
# charge : charge
# sek : sek
# eng : eng
# ngajak : ngajak
# gelud : gelud
# nggak : nggak
# diangkat : angkat
# ngemeng : ngemeng
# tuk : tuk
# alaidid : alaidid
# notifikasi : notifikasi
# maksa : maksa
# bnget : bnget
# asli : asli
# lady : lady
# terhubung : hubung
# melanjutkan : lanjut
# sefaham : sefaham
# bni : bni
# bri : bri
# mandiri : mandiri
# embel : embel
# syariah : syariah
# securitas : securitas
# bumn : bumn
# maklum : maklum
# spt : spt
# bin : bin
# dibicarakan : bicara
# bahas : bahas
# kelautvsaja : kelautvsaja
# keterangan : terang
# omg : omg
# utama : utama
# hooq : hooq
# viu : viu
# iflix : iflix
# klikfilm : klikfilm
# bein : bein
# sports : sports
# nickelodeon : nickelodeon
# play : play
# duh : duh
# begonya : bego
# naturaaall : naturaaall
# cuk : cuk
# fathul : fathul
# ikuti : ikut
# panduan : pandu
# pastikan : pasti
# update : update
# terbaru : baru
# lakukan : laku
# force : force
# stop : stop
# three : three
# isat : isat
# linknya : linknya
# bio : bio
# slankers : slankers
# pdhl : pdhl
# resign : resign
# skalian : skalian
# dijadiin : dijadiin
# lumayan : lumayan
# maksudnya : maksud
# app : app
# login : login
# crash : crash
# parah : parah
# tabungan : tabung
# gaes : gaes
# dapp : dapp
# pancakeswap : pancakeswap
# register : register
# email : email
# verifikasi : verifikasi
# log : log
# profile : profile
# kyc : kyc
# referal : referal
# dpet : dpet
# cair : cair
# dilock : dilock
# pke : pke
# vpn : vpn
# positif : positif
# slakan : slakan
# gass : gass
# wktu : wktu
# busuk : busuk
# shit : shit
# lahh : lahh
# portnoy : portnoy
# alamat : alamat
# hagi : hagi
# hmm : hmm
# meluncurkan : luncur
# dirumahku : rumah
# hilang : hilang
# timbul : timbul
# rumaj : rumaj
# uwais : uwais
# keterlambatan : lambat
# responnya : responnya
# kaldera : kaldera
# padat : padat
# hengkang : hengkang
# lho : lho
# chat : chat
# untung : untung
# buang : buang
# laut : laut
# aje : aje
# kelola : kelola
# keluarga : keluarga
# relawan : rawan
# diperbaiki : baik
# sumpah : sumpah
# phm : phm
# lgi : lgi
# sma : sma
# doangg : doangg
# kosan : kosan
# bogor : bogor
# apasi : apas
# diharepin : diharepin
# septi : septi
# perkara : perkara
# literally : literally
# signal : signal
# bay : bay
# aufar : aufar
# yumiko : yumiko
# sungkan : sungkan
# keluhannya : keluh
# ryu : ryu
# keren : keren
# erik : erik
# tohir : tohir
# dorong : dorong
# kreator : kreator
# lokal : lokal
# maju : maju
# bersaing : saing
# pricelist : pricelist
# okayy : okayy
# direksi : direksi
# ntah : ntah
# buruk : buruk
# kualitasnya : kualitas
# salsa : salsa
# dugaan : duga
# syakh : syakh
# iyah : iyah
# adaan : ada
# jadiiiii : jadiiiii
# juaranya : juara
# nomer : nomer
# ambil : ambil
# akun : akun
# rido : rido
# hasil : hasil
# zeus : zeus
# lelet : lelet
# heddeh : heddeh
# semaktu : semaktu
# stm : stm
# neda : neda
# ketawa : ketawa
# suara : suara
# takut : takut
# anggap : anggap
# gila : gila
# jilatannya : jilat
# arah : arah
# jadikan : jadi
# duta : duta
# voucher : voucher
# asn : asn
# inet : inet
# kesedot : sedot
# veronika : veronika
# bodohnya : bodoh
# ketulungan : ketulungan
# bunuh : bunuh
# buah : buah
# semangka : semangka
# dimasak : masak
# resep : resep
# kasep : kasep
# dalton : dalton
# nomernya : nomernya
# interaksinya : interaksi
# ttp : ttp
# kucoba : coba
# sisasisa : sisasisa
# anlimitit : anlimitit
# keliat : liat
# gambar : gambar
# video : video
# bajingan : bajing
# najwa : najwa
# slo : slo
# beeeeee : beeeeee
# amran : amran
# patty : patty
# malming : malming
# bunda : bunda
# met : met
# mlem : mlem
# rehat : rehat
# mengerti : erti
# diakses : akses
# spam : spam
# bersihin : bersihin
# ginik : ginik
# trus : trus
# bisanya : bisa
# abdi : abdi
# jdi : jdi
# amanah : amanah
# tanam : tanam
# lbh : lbh
# garasi : garasi
# ampe : ampe
# ketutup : tutup
# nanda : nanda
# samaan : sama
# allah : allah
# percumaaaaaa : percumaaaaaa
# kyk : kyk
# dilaporkan : lapor
# operator : operator
# selular : selular
# dsuruh : dsuruh
# repot : repot
# sbnrnya : sbnrnya
# dng : dng
# mengecek : ecek
# tsb : tsb
# menipu : tipu
# seluler : seluler
# azmi : azmi
# mengalami : alami
# menyenangkan : senang
# bales : bales
# minn : minn
# bilsng : bilsng
# lsngsung : lsngsung
# berani : berani
# providernya : providernya
# wkwkwkw : wkwkwkw
# kirain : kirain
# besarnya : besar
# tarif : tarif
# menyesuaikan : sesuai
# biaya : biaya
# pengeluaran : keluar
# berbeda : beda
# perbedaan : beda
# tingkat : tingkat
# kesulitan : sulit
# komponen : komponen
# dibutuhkan : butuh
# menggelar : gelar
# infrastruktur : infrastruktur
# youtube : youtube
# ryan : ryan
# lancar : lancar
# hubungi : hubung
# istirahat : istirahat
# sip : sip
# thx : thx
# gigabytes : gigabytes
# hubungannya : hubung
# beneran : beneran
# nanya : nanya
# redeem : redeem
# poin : poin
# aplikasinya : aplikasi
# silakna : silakna
# kasihan : kasihan
# ngetik : ngetik
# tweet : tweet
# xixixix : xixixix
# hoong : hoong
# gtau : gtau
# bangett : bangett
# ngeliat : ngeliat
# twt : twt
# mikir : mikir
# kyknya : kyknya
# idihome : idihome
# vidhi : vidhi
# dicandain : dicandain
# ntar : ntar
# dibeli : beli
# kemaren : kemaren
# genep : genep
# check : check
# reward : reward
# being : being
# this : this
# protective : protective
# moots : moots
# indo : indo
# indos : indos
# owe : owe
# bangs : bangs
# kaga : kaga
# diajak : ajak
# voting : voting
# hdhdhdh : hdhdhdh
# lup : lup
# lep : lep
# bagusan : bagus
# adeknowe : adeknowe
# sajah : sajah
# standar : standar
# ruangan : ruang
# dll : dll
# komplain : komplain
# kampret : kampret
# prosedur : prosedur
# ngaruh : ngaruh
# kejang : kejang
# elektrik : elektrik
# nambah : nambah
# mastip : mastip
# oke : oke
# cekndm : cekndm
# dilawan : lawan
# ngerasa : ngerasa
# merrka : merrka
# ngelunjak : ngelunjak
# cuekin : cuekin
# pokok : pokok
# masum : masum
# haoys : haoys
# dibaca : baca
# habis : habis
# jengkel : jengkel
# langgannnya : langgannnya
# mba : mba
# anakannya : ana
# keknya : kek
# ttep : ttep
# keitung : keitung
# dibalesin : dibalesin
# ditanggapin : ditanggapin
# lansung : lansung
# hapus : hapus
# juventino : juventino
# terbuktti : terbuktti
# leonardus : leonardus
# sebutkan : sebut
# ngawur : ngawur
# asumsi : asumsi
# ngeyel : ngeyel
# tololmu : tolol
# nampak : nampak
# separuh : paruh
# msh : msh
# ngeyelah : ngeyelah
# kelkelkelkelkel : kelkelkelkelkel
# diumbar : umbar
# malukah : malu
# cucu : cucu
# majukan : maju
# wkwkwwkwk : wkwkwwkwk
# upaya : upaya
# patut : patut
# apresiasi : apresiasi
# erick : erick
# thohir : thohir
# contoh : contoh
# nyata : nyata
# memajukan : maju
# konten : konten
# keras : keras
# dikit : dikit
# nihil : nihil
# alhamdulillah : alhamdulillah
# tinggalkan : tinggal
# non : non
# sayang : sayang
# duit : duit
# ngegaji : ngegaji
# abal : abal
# nge : nge
# bab : bab
# kuatir : kuatir
# kebawa : bawa
# hanyut : hanyut
# buktinya : bukti
# belepotan : belepotan
# ambyaar : ambyaar
# ysf : ysf
# duduk : duduk
# diluar : luar
# mandangin : mandangin
# berkibar : kibar
# seraya : seraya
# menghayalkan : menghayalkan
# indah : indah
# tambahin : tambahin
# woy : woy
# pang : pang
# membantu : bantu
# tawakal : tawakal
# mendorong : dorong
# gojek : gojek
# gambarnya : gambar
# gakeluat : gakeluat
# samsekkk : samsekkk
# silahkan : silah
# layak : layak
# diliat : liat
# pengalaman : alam
# track : track
# recod : recod
# puluh : puluh
# tugase : tugase
# memperjuangkan : juang
# dewan : dewan
# tugasnya : tugas
# mesti : mesti
# yess : yess
# menteri : menteri
# hire : hire
# industri : industri
# kreatif : kreatif
# perfilman : film
# melindungi : lindung
# hak : hak
# penciptanya : cipta
# sok : sok
# tong : tong
# jebot : jebot
# memonopoli : monopoli
# market : market
# ngalahin : ngalahin
# tower : tower
# ente : ente
# pikir : pikir
# rel : rel
# kereta : kereta
# bambaaaaaaaang : bambaaaaaaaang
# adikmu : adik
# fuji : fuji
# official : official
# most : most
# mayoritas : mayoritas
# comment : comment
# dikecewakan : kecewa
# boro : boro
# depo : depo
# akunnya : akun
# lock : lock
# bank : bank
# system : system
# alasan : alas
# sinyalnya : sinyal
# ilang : ilang
# ilangan : ilangan
# bosen : bosen
# kaya : kaya
# gitu : gitu
# lakai : lakai
# mbak : mbak
# anjloknya : anjlok
# mengurangi : kurang
# profit : profit
# perusahan : usah
# vendor : vendor
# rivalnya : rival
# nyewa : nyewa
# bts : bts
# satelit : satelit
# mangab : mangab
# fransisko : fransisko
# direct : direct
# message : message
# twitter : twitter
# permasalaha : permasalaha
# digipos : digipos
# larinye : larinye
# ahh : ahh
# fuck : fuck
# you : you
# mampossss : mampossss
# benahin : benahin
# akar : akar
# iroel : iroel
# berhenti : henti
# berlangganan : langgan
# malam : malam
# sobat : sobat
# ngerasakan : ngerasakan
# ditelpon : telpon
# undian : undi
# berhadiah : hadiah
# tawarkan : tawar
# pinjaman : pinjam
# lunak : lunak
# huh : huh
# program : program
# strategis : strategis
# rekrutan : rekrut
# masuknya : masuk
# badan : badan
# organisasi : organisasi
# level : level
# pantesan : pantesan
# meme : meme
# mangapnye : mangapnye
# jigong : jigong
# asbun : asbun
# jakarta : jakarta
# sembung : sembung
# naek : naek
# ojek : ojek
# nyambung : nyambung
# dosa : dosa
# abi : abi
# kukulutus : kukulutus
# wae : wae
# yoka : yoka
# carekeun : carekeun
# ussd : ussd
# please : please
# reset : reset
# pin : pin
# perkembangan : kembang
# hubungan : hubung
# yakul : yakul
# brian : brian
# mbuh : mbuh
# nek : nek
# densi : densi
# gajinya : gaji
# duitnya : duit
# doi : doi
# masbro : masbro
# konisaris : konisaris
# lingkaran : lingkar
# kekuasaan : kuasa
# permadi : madi
# arya : arya
# eko : eko
# kuntadi : kuntadi
# pemain : main
# cadangan : cadang
# sekedar : dar
# pion : pion
# mari : mari
# tidur : tidur
# besok : besok
# close : close
# komen : komen
# gada : gada
# teman : teman
# sekolam : kolam
# elo : elo
# panggil : panggil
# menteman : tem
# belain : bain
# sipaa : sipaa
# asyuuu : asyuuu
# laa : laa
# komesaris : komesaris
# wkwkwkwwkwkwkwkwk : wkwkwkwwkwkwkwkwk
# guobblokkk : guobblokkk
# nikmatin : nikmatin
# gara : gara
# ngerti : ngerti
# mudahan : mudah
# hudi : hudi
# cepat : cepat
# tua : tua
# konteks : konteks
# bod : bod
# boc : boc
# grgr : grgr
# joenita : joenita
# dora : dora
# didapatkan : dapat
# harga : harga
# terjangkau : jangkau
# kebagean : kebagean
# sblm : sblm
# rejim : rejim
# endgame : endgame
# wktnya : wktnya
# ngebajer : ngebajer
# harap : harap
# sabar : sabar
# bnyk : bnyk
# dirolling : dirolling
# rejeki : rejeki
# hehehe : hehehe
# ilmu : ilmu
# coment : coment
# saham : saham
# moga : moga
# kabar : kabar
# buyback : buyback
# lemah : lemah
# halnya : hal
# huhuhu : huhuhu
# kindly : kindly
# jelak : jelak
# mentang : mentang
# kouta : kouta
# tinggal : tinggal
# pendapatan : dapat
# terbesar : besar
# woiiiiii : woiiiiii
# bertepi : tepi
# utangnya : utang
# ghoib : ghoib
# nanggung : nanggung
# jejak : jejak
# eyangkewu : eyangkewu
# wifi : wifi
# nasibku : nasib
# upfront : upfront
# payment : payment
# sipil : sipil
# wajib : wajib
# melampirkan : lampir
# memiliki : milik
# kredit : kredit
# tervalidasi : tervalidasi
# bersedia : sedia
# membayar : bayar
# terdekat : dekat
# ketentuan : tentu
# ktp : ktp
# dimiliki : milik
# surat : surat
# suket : suket
# dinas : dinas
# kependudukan : duduk
# pencatatan : catat
# prepaid : prepaid
# postpaid : postpaid
# persyaratan : syarat
# berumur : umur
# penawaran : tawar
# khusus : khusus
# dear : dear
# berdomisili : domisili
# jawa : jawa
# era : era
# digital : digital
# merata : rata
# kemana : mana
# sungguh : sungguh
# miris : miris
# haaddoohh : haaddoohh
# lieeuurr : lieeuurr
# jelma : jelma
# teh : teh
# tugas : tugas
# line : line
# berkenda : berkenda
# alif : alif
# nemesis : nemesis
# nadadering : nadadering
# gratis : gratis
# apk : apk
# sebulan : bulan
# asuransi : asuransi
# perlindungan : lindung
# kecelakaan : celaka
# ramadani : ramadan
# berubah : ubah
# telkomslank : telkomslank
# perkenalkan : kenal
# menkeu : menkeu
# tampilan : tampil
# twit : twit
# ditanggepi : ditanggepi
# prmasalahan : prmasalahan
# ckckck : ckckck
# blom : blom
# tanggapannya : tanggap
# fyi : fyi
# mlm : mlm
# pengecekan : kece
# berkala : kala
# pkl : pkl
# wib : wib
# net : net
# notif : notif
# pengaturan : atur
# sprti : sprti
# telegram : telegram
# discord : discord
# syarat : syarat
# modus : modus
# pilih : pilih
# sii : sii
# milih : milih
# nem : nem
# tiktok : tiktok
# kebuka : buka
# stuck : stuck
# iklan : iklan
# send : send
# pacarku : pacar
# namanya : nama
# bln : bln
# jali : jali
# apple : apple
# iphone : iphone
# pemotongan : potong
# sembarangan : sembarang
# jamin : jamin
# mengakses : akses
# payu : payu
# penerapan : terap
# fup : fup
# mencegah : cegah
# aktivitas : aktivitas
# batasan : batas
# bertujuan : tuju
# lololol : lololol
# emg : emg
# abis : abis
# tujuannya : tuju
# ngisi : ngisi
# promonya : promonya
# hans : hans
# cemerlang : cemerlang
# cermin : cermin
# tranparant : tranparant
# meninggalkan : tinggal
# tuku : tuku
# ora : ora
# polri : polri
# kronologi : kronologi
# dihubungi : hubung
# tim : tim
# teknis : teknis
# balikan : balik
# wajarnya : wajar
# enak : enak
# penipuan : tipu
# blokir : blokir
# meisy : meisy
# prihatin : prihatin
# korban : korban
# disarankan : saran
# melaporkan : lapor
# kantor : kantor
# cyber : cyber
# crime : crime
# bukti : bukti
# subsidikan : subsidi
# kian : kian
# terpuruk : puruk
# receh : receh
# dicatat : catat
# pelaku : laku
# memakan : makan
# uang : uang
# keperluan : perlu
# kuliah : kuliah
# ditemukan : temu
# pelakunya : laku
# pengen : ken
# komentar : komentar
# sarkas : sarkas
# menjilat : jilat
# tawarin : tawarin
# arief : arief
# ribut : ribut
# personil : personil
# rbt : rbt
# dipilih : pilih
# lagunya : lagu
# free : free
# saldoo : saldoo
# nct : nct
# mkny : mkny
# makai : maka
# hidayah : hidayah
# gaonok : gaonok
# esim : esim
# bebas : bebas
# speed : speed
# sebagus : bagus
# cakupan : cakup
# lusia : lusia
# suka : suka
# pendukung : dukung
# pengambilan : ambil
# keputusannya : putus
# terkesan : kes
# egois : egois
# memilih : pilih
# disangkakan : sangka
# berkompeten : kompeten
# perubahan : ubah
# giliran : gilir
# band : band
# not : not
# her : her
# purple : purple
# cryingg : cryingg
# why : why
# there : there
# ketua : ketua
# panitia : panitia
# event : event
# music : music
# disinggung : singgung
# mengandalkan : andal
# membesarkan : besar
# solusinya : solusi
# hpnya : hpnya
# terkendala : kendala
# ngeributin : ngeributin
# heuheuehehehehue : heuheuehehehehue
# aletheia : aletheia
# error : error
# disusul : susul
# pergantian : ganti
# jajaran : jajar
# asalkn : asalkn
# kinerja : kerja
# memikirkan : pikir
# mencekik : cekik
# rakyat : rakyat
# sharusnya : sharusnya
# trmsuk : trmsuk
# muhidin : muhidin
# benefit : benefit
# kemudahan : mudah
# memantau : pantau
# pemakaian : pakai
# playlistny : playlistny
# keajaiban : ajaib
# mem : mem
# nyari : nyari
# for : for
# android : android
# and : and
# perombakan : ombak
# seharian : hari
# said : said
# pesiar : pesiar
# bawa : bawa
# spicker : spicker
# koar : koar
# tlnya : tlnya
# mencari : cari
# dukungan : dukung
# bazer : bazer
# smpai : smpai
# seminggu : minggu
# tdr : tdr
# berharap : harap
# gsm : gsm
# kecewa : kecewa
# sales : sales
# nomerku : nomerku
# kah : kah
# dipas : pas
# bego : bego
# paham : paham
# preet : preet
# ujan : ujan
# reda : reda
# dipertanggungjawabkan : dipertanggungjawabkan
# oenunjukannya : oenunjukannya
# opa : opa
# yukk : yukk
# uyyyy : uyyyy
# ayunda : ayunda
# afy : afy
# tut : tut
# ne : ne
# kep : kep
# saan : saan
# sie : sie
# ditanyain : ditanyain
# pmh : pmh
# screenshot : screenshot
# pesanya : pesa
# bib : bib
# mixtape : mixtape
# nab : nab
# sabam : sabam
# support : support
# generasi : generasi
# kaum : kaum
# dibersihin : dibersihin
# nyahok : nyahok
# luuu : luuu
# diganti : ganti
# bos : bos
# menerima : terima
# faham : faham
# apem : apem
# ping : ping
# boong : boong
# beresih : beresih
# cingkrng : cingkrng
# keluarin : keluarin
# case : case
# ipoelz : ipoelz
# doakan : doa
# terealisasi : realisasi
# bagas : bagas
# batin : batin
# mumpung : mumpung
# basi : basi
# lebarannya : lebaran
# amiin : amiin
# ucl : ucl
# sekelas : kelas
# memfilter : filter
# togel : togel
# halal : halal
# dkk : dkk
# itungannya : itungannya
# pahe : pahe
# ganggu : ganggu
# balam : balam
# gituuu : gituuu
# kondisi : kondisi
# incar : incar
# posisi : posisi
# jancok : jancok
# mobile : mobile
# number : number
# the : the
# date : date
# incident : incident
# with : with
# same : same
# problem : problem
# privacy : privacy
# maintained : maintained
# can : can
# helped : helped
# nyampah : nyampah
# tauk : tauk
# marentuha : marentuha
# sorry : sorry
# unstable : unstable
# have : have
# tried : tried
# refreshing : refreshing
# network : network
# before : before
# switching : switching
# from : from
# automatic : automatic
# then : then
# returning : returning
# but : but
# still : still
# ucup : ucup
# komut : komut
# aman : aman
# gregetan : gregetan
# dirugikan : rugi
# penyedia : sedia
# khoemaini : khoemaini
# capture : capture
# upgred : upgred
# krtu : krtu
# bsa : bsa
# antonio : antonio
# hdehhh : hdehhh
# cpekkk : cpekkk
# jae : jae
# nmor : nmor
# masi : mas
# heni : heni
# bonus : bonus
# fix : fix
# your : your
# coverage : coverage
# area : area
# labuhan : labuh
# batu : batu
# selatan : selatan
# north : north
# sumatera : sumatera
# really : really
# suck : suck
# here : here
# diproses : proses
# upgrade : upgrade
# sukmawati : sukmawati
# perangkat : perangkat
# terbatas : batas
# mengembangkan : kembang
# tercakup : cakup
# rifqi : rifqi
# kendalanya : kendala
# yull : yull
# memenuhi : penuh
# nik : nik
# ilham : ilham
# vocer : vocer
# knpa : knpa
# cacat : cacat
# ajg : ajg
# transit : transit
# tpi : tpi
# koutanya : koutanya
# tnggal : tnggal
# sultan : sultan
# vouchernya : vouchernya
# hemat : hemat
# stres : stres
# ngak : ngak
# sebatas : batas
# search : search
# engine : engine
# jan : jan
# ngimpi : ngimpi
# triliun : triliun
# bngt : bngt
# punyaku : punya
# judi : judi
# balok : balok
# fancy : fancy
# datanya : data
# dwirawan : dwirawan
# cobain : cobain
# pindahin : pindahin
# indosatnya : indosatnya
# palinv : palinv
# valerie : valerie
# meluncur : luncur
# baba : baba
# samsung : samsung
# galaxy : galaxy
# nongol : nongol
# oppo : oppo
# pondok : pondok
# pcrn : pcrn
# ajha : ajha
# tamba : tamba
# bapack : bapack
# kuadrat : kuadrat
# males : males
# prnh : prnh
# nian : nian
# ahmad : ahmad
# mengeluarkan : keluar
# ilh : ilh
# betah : betah
# langit : langit
# kpm : kpm
# atma : atma
# nelfon : nelfon
# ditransfer : transfer
# achmad : achmad
# rival : rival
# device : device
# ter : ter
# cover : cover
# sent : sent
# rena : rena
# drive : drive
# foto : foto
# sinb : sinb
# hanief : hanief
# diinfokan : info
# akurat : akurat
# goddamn : goddamn
# fucking : fucking
# first : first
# switch : switch
# jey : jey
# quora : quora
# saiful : saiful
# cims : cims
# puluhan : puluh
# gal : gal
# tanggapan : tanggap
# thn : thn
# ngebacot : ngebacot
# pitnah : pitnah
# ulama : ulama
# syariat : syariat
# islam : islam
# epes : epes
# kate : kate
# sial : sial
# facebook : facebook
# andluna : andluna
# menghubungi : hubung
# pesawat : pesawat
# copot : copot
# happy : happy
# satnight : satnight
# fast : fast
# perpanjang : panjang
# trf : trf
# token : token
# pln : pln
# gausah : gausah
# ngide : ngide
# lag : lag
# tlg : tlg
# thanks : thanks
# multimedia : multimedia
# playstore : playstore
# amadh : amadh
# lanjutin : lanjutin
# cantumin : cantumin
# transaksinya : transaksi
# penggunaan : guna
# terdaftar : daftar
# konsumsi : konsumsi
# independen : independen
# wanda : wanda
# acak : acak
# sistem : sistem
# skema : skema
# investor : investor
# dikenakan : kena
# fee : fee
# buy : buy
# sell : sell
# busettt : busettt
# kbps : kbps
# jalan : jalan
# browsing : browsing
# edaaaannnnnnnn : edaaaannnnnnnn
# mao : mao
# perubahannya : ubah
# bunny : bunny
# members : members
# bighit : bighit
# chan : chan
# vivo : vivo
# dpat : dpat
# local : local
# semenjak : semenjak
# fal : fal
# arif : arif
# feedback : feedback
# mengapresiasikan : apresiasi
# peningkatan : tingkat
# harapannya : harap
# lewatkan : lewat
# uefa : uefa
# champions : champions
# league : league
# saksikan : saksi
# vidio : vidio
# aktifkan : aktif
# seharga : harga
# rp : rp
# membeli : beli
# combo : combo
# sakti : sakti
# saktinya : sakti
# bwlikan : bwlikan
# nasi : nasi
# tetep : tetep
# lapar : lapar
# mie : mie
# instan : instan
# ganjal : ganjal
# perut : perut
# baanget : baanget
# ditawari : tawar
# apalah : apa
# gafaham : gafaham
# keamanan : aman
# agency : agency
# pusing : pusing
# ngelembur : ngelembur
# jingle : jingle
# liriknya : lirik
# nadanya : nada
# tel : tel
# kom : kom
# give : give
# superdeal : superdeal
# enough : enough
# meeee : meeee
# shdksksks : shdksksks
# mall : mall
# warasto : warasto
# simak : simak
# ponsel : ponsel
# spesifikasi : spesifikasi
# harganya : harga
# cool : cool
# bangke : bangke
# astaga : astaga
# beb : beb
# segini : gin
# one : one
# degree : degree
# freeze : freeze
# teaser : teaser
# together : together
# melewati : lewat
# tenggang : tenggang
# diaktifin : diaktifin
# pastinya : pasti
# cakeup : cakeup
# entertaiment : entertaiment
# bersamaan : sama
# netflix : netflix
# manakah : mana
# banyakk : banyakk
# depannya : depan
# dibuka : buka
# firmware : firmware
# mamet : mamet
# mengaktifkan : aktif
# eksisting : eksisting
# spesial : spesial
# dikonsumsi : konsumsi
# pusat : pusat
# kelewat : lewat
# aktifin : aktifin
# nisa : nisa
# menu : menu
# ujung : ujung
# aspal : aspal
# bekasi : bekas
# jaringannya : jaring
# gmeet : gmeet
# zoom : zoom
# kelas : kelas
# seambyar : ambyar
# ambyarnya : ambyar
# didetailkan : detail
# beliin : beliin
# tisu : tisu
# kalii : kali
# iyaaaa : iyaaaa
# berhalangan : halang
# hadir : hadir
# diwakilkan : wakil
# kuasa : kuasa
# bermaterai : bermaterai
# pemilik : milik
# pemberi : beri
# penerima : terima
# kepotong : potong
# anehnya : aneh
# statusnya : status
# menunya : menu
# timpuk : timpuk
# gemana : gana
# hape : hape
# merla : merla
# menunjukan : tunjuk
# kerugian : rugi
# materi : materi
# permintaan : minta
# kode : kode
# dikhawatirkan : khawatir
# penipu : tipu
# messenger : messenger
# situs : situs
# belanja : belanja
# perbankan : perban
# digit : digit
# identitas : identitas
# paspor : paspor
# kta : kta
# hani : hani
# cross : cross
# selling : selling
# tergantung : gantung
# kebijakan : bijak
# penggantian : ganti
# gajelas : gajelas
# seheran : heran
# goto : goto
# frekuensi : frekuensi
# olahan : olah
# hahahahaha : hahahahaha
# pindah : pindah
# cad : cad
# jago : jago
# twitt : twitt
# ekky : ekky
# bkin : bkin
# bdmd : bdmd
# njr : njr
# jualan : jual
# simpcard : simpcard
# bekas : bekas
# aktip : aktip
# dijual : jual
# sasaran : sasar
# teror : teror
# mengalaminya : alam
# ditagih : tagih
# hutang : hutang
# kontak : kontak
# fokus : fokus
# gnya : gnya
# gembar : gembar
# gembor : gembor
# dikitlah : dikit
# bapuk : bapuk
# cacaaaaaaaat : cacaaaaaaaat
# made : made
# rebutan : rebut
# rezeki : rezeki
# knapa : knapa
# doh : doh
# trouble : trouble
# nano : nano
# persyaratannya : syarat
# ajaya : ajaya
# biayanya : biaya
# peting : peting
# diisi : isi
# niat : niat
# kemarin : kemarin
# tergoda : goda
# smartften : smartften
# sinyalanya : sinyalanya
# zonk : zonk
# niatanya : niatanya
# fintech : fintech
# block : block
# kenz : kenz
# menggugah : gugah
# semangat : semangat
# karyawan : karyawan
# lagu : lagu
# khawatir : khawatir
# berkomitmen : komitmen
# menjaga : jaga
# pelanggannya : langgan
# himbau : himbau
# indikasi : indikasi
# penyalah : salah
# guanaan : guanaan
# berkaitan : kait
# password : password
# otp : otp
# qirdun : qirdun
# beraksi : aksi
# berapi : rap
# iri : iri
# dengki : dengki
# protes : protes
# makhluk : makhluk
# hina : hina
# jls : jls
# quotenya : quotenya
# tujuan : tuju
# memperbaiki : baik
# sikon : sikon
# acakadut : acakadut
# iseng : iseng
# chattingan : chattingan
# matlis : matlis
# karna : karna
# budalkan : budalkan
# puri : puri
# mengikuti : ikut
# siti : siti
# diduga : duga
# dipakai : pakai
# pencegahannya : cegah
# dikirim : kirim
# digandakan : ganda
# bergaransi : garansi
# trusted : trusted
# testi : testi
# ewallet : ewallet
# qris : qris
# opah : opah
# manaf : manaf
# hayuuuuk : hayuuuuk
# aah : aah
# hayuu : hayuu
# tfirmansyah : tfirmansyah
# ketentuannya : tentu
# wakil : wakil
# dirut : dirut
# maksutnya : maksutnya
# gmn : gmn
# gedein : gedein
# titid : titid
# aya : aya
# dendam : dendam
# naon : naon
# meniiii : meniiii
# genks : genks
# jengkol : jengkol
# nci : nci
# ara : ara
# premium : premium
# putry : putry
# stream : stream
# kingdom : kingdom
# periode : periode
# ustad : ustad
# koreksi : koreksi
# siapanya : siapa
# preset : preset
# lightroom : lightroom
# ampas : ampas
# beralih : alih
# pilihan : pilih
# rezimm : rezimm
# astaghfirullah : astaghfirullah
# berbulan : bulan
# berkurang : kurang
# moon : moon
# ngechargenya : ngechargenya
# gede : gede
# pemesanan : mesan
# simcard : simcard
# dikirimkan : kirim
# cust : cust
# prov : prov
# riuhkan : riuh
# willy : willy
# alaziz : alaziz
# php : php
# ngadat : ngadat
# uda : uda
# ndak : ndak
# makasi : makas
# response : response
# dicobaaaa : dicobaaaa
# rhendra : rhendra
# doank : doank
# kayanya : kaya
# kasihhh : kasihhh
# gibian : gibian
# inimah : inimah
# oeniouah : oeniouah
# atuh : atuh
# rhendraaaaaa : rhendraaaaaa
# ngerubah : ngerubah
# yulia : yulia
# memindahkan : pindah
# hujan : hujan
# airplane : airplane
# ervi : ervi
# ridha : ridha
# rani : rani
# novian : novian
# mengapresiasi : apresiasi
# terbaik : baik
# kalibrasi : kalibrasi
# ultah : ultah
# bnyak : bnyak
# bdg : bdg
# emng : emng
# cenah : cenah
# bingung : bingung
# wqwq : wqwq
# terkadang : terkadang
# higienis : higienis
# buffer : buffer
# murahan : murah
# wina : wina
# sdg : sdg
# dahh : dahh
# gercep : gercep
# day : day
# bangkrut : bangkrut
# serahkan : serah
# ahlinya : ahli
# tunggulah : tunggu
# kehacurannya : kehacurannya
# member : member
# jkt : jkt
# kelaut : laut
# goa : goa
# siaap : siaap
# ngadi : ngadi
# lari : lari
# musik : musik
# diterima : terima
# pengirim : kirim
# kelengkapan : lengkap
# beritanya : berita
# mdh : mdh
# siregar : siregar
# ketinggian : tinggi
# jabatannya : jabat
# gigi : gigi
# berkomentar : komentar
# pendidikan : didik
# berorganisasi : organ
# kemampuan : mampu
# managerial : managerial
# mumpuni : mumpuni
# mata : mata
# mengakibatkan : akibat
# tukang : tukang
# komplen : komplen
# errrrroorrr : errrrroorrr
# secepatnya : cepat
# hadirkan : hadir
# jawabannya : jawab
# wtf : wtf
# jeez : jeez
# balasannya : balas
# apasih : apasih
# alfa : alfa
# padet : padet
# tungguin : tungguin
# bareng : bareng
# gunain : gunain
# sirgar : sirgar
# tegar : tegar
# tersenyum : senyum
# kecut : kecut
# menangis : menang
# nelangsa : nelangsa
# berucap : ucap
# cdm : cdm
# dibalas : balas
# ktnya : ktnya
# mengecewakan : kecewa
# rencananya : rencana
# ngeluarin : ngeluarin
# kakkk : kakkk
# dataku : data
# recoknya : recok
# syaratnya : syarat
# sapu : sapu
# tebal : tebal
# lidinya : lidi
# lembar : lembar
# bersihnya : bersih
# walo : walo
# sapunya : sapu
# aleah : aleah
# trisha : trisha
# bagastama : bagastama
# byby : byby
# mksud : mksud
# prubahan : prubahan
# comberan : comberan
# jas : jas
# kayaknya : kayak
# kadaluarsa : kadaluarsa
# gaspoll : gaspoll
# kgak : kgak
# ngejar : ngejar
# target : target
# mangan : mangan
# bantuannya : bantu
# fren : fren
# hadirnya : hadir
# menggerakan : gera
# roda : roda
# perekonomian : ekonomi
# nelponin : nelponin
# penipunya : tipu
# ditindaklanjuti : ditindaklanjuti
# diblokir : blokir
# nmrnya : nmrnya
# korea : korea
# muak : muak
# roaming : roaming
# rifay : rifay
# pucek : pucek
# nindyas : nindyas
# yaaa : yaaa
# didengarkan : dengar
# dirombak : rombak
# terdepak : depak
# uname : uname
# ignya : ignya
# pemakaaian : pemakaaian
# diablo : diablo
# woii : woii
# bahar : bahar
# nelpon : nelpon
# jul : jul
# jangkauan : jangkau
# pantai : pantai
# kapuk : kapuk
# nicco : nicco
# hrs : hrs
# rugi : rugi
# cicipi : cicip
# kang : kang
# bakso : bakso
# aktivasinya : aktivasinya
# dmn : dmn
# beragama : agama
# dibeberapa : beberapa
# bangga : bangga
# komirasisnya : komirasisnya
# cepoe : cepoe
# aps : aps
# leng : leng
# cii : cii
# loi : loi
# gerbong : gerbong
# sulit : sulit
# manuvernya : manuver
# profil : profil
# hendri : hendri
# mulya : mulya
# jagoan : jago
# hunter : hunter
# neraka : neraka
# kshan : kshan
# sore : sore
# lagaknya : lagak
# nawarin : nawarin
# bantuan : bantu
# batas : batas
# kecepatannya : cepat
# dibatasi : batas
# lord : lord
# icad : icad
# serem : rem
# njir : njir
# serel : rel
# memimpin : pimpin
# special : special
# berisi : isi
# tertinggi : tinggi
# mbjj : mbjj
# fatmawati : fatmawati
# dinonaktifkan : nonaktif
# halonya : halo
# ekawati : ekawati
# handset : handset
# type : type
# ultra : ultra
# datuak : datuak
# in : in
# promosi : promosi
# ngurangin : ngurangin
# mengganggu : ganggu
# promosinya : promosi
# ngab : ngab
# tukarkan : tukar
# mytekomsel : mytekomsel
# berkesempatan : sempat
# menangin : menangin
# tukarin : tukarin
# keringanan : ringan
# mengurus : urus
# recyle : recyle
# weekend : weekend
# santai : santai
# main : main
# ketinggalan : tinggal
# tren : tren
# dapetin : dapetin
# bug : bug
# tag : tag
# html : html
# kunjungi : kunjung
# keseruan : seru
# sigit : sigit
# temannya : teman
# ghostbuser : ghostbuser
# langganan : langgan
# aksesnya : akses
# komersil : komersil
# diuji : uji
# bertahun : tahun
# perjalanannya : jalan
# permak : permak
# games : games
# beragam : agam
# maksudnye : maksudnye
# karya : karya
# nsp : nsp
# berburuk : buruk
# sangka : sangka
# kelam : kelam
# intelek : intelek
# pengusaha : usaha
# mempertimbangkan : timbang
# pengangkatan : angkat
# duluan : duluan
# vaksin : vaksin
# ampera : ampera
# neneknya : nenek
# jir : jir
# ksl : ksl
# orng : orng
# pintar : pintar
# ahli : ahli
# tenaga : tenaga
# esquestion : esquestion
# melahirkan : lahir
# bibit : bibit
# koruptor : koruptor
# dipertanggung : tanggung
# jawabkannya : jawab
# penunjukannya : tunjuk
# komind : komind
# pecahkan : pecah
# ngelag : ngelag
# bahodopi : bahodopi
# morowali : morowali
# aduh : aduh
# woiii : woiii
# nyebelin : nyebelin
# beserta : serta
# azul : azul
# rian : rian
# mksdnya : mksdnya
# gtu : gtu
# just : just
# actually : actually
# shitty : shitty
# past : past
# hours : hours
# sya : sya
# khairul : khairul
# ketidaksesuaian : ketidaksesuaian
# dwi : dwi
# emangnya : emang
# muda : muda
# pulau : pulau
# inget : inget
# januari : januari
# stavolt : stavolt
# yuu : yuu
# panyabungan : panyabungan
# membalas : balas
# kawan : kawan
# kec : kec
# natal : natal
# mandailing : mandailing
# produknya : produk
# rabu : rabu
# dikantor : kantor
# normal : normal
# wkwkwkkwwkkwwkwkkkkk : wkwkwkkwwkkwwkwkkkkk
# tengang : tengang
# ayolah : ayo
# joni : joni
# kaget : kaget
# presiden : presiden
# kmn : kmn
# mengeluh : keluh
# tips : tips
# resmi : resmi
# sklo : sklo
# kominfo : kominfo
# terjun : terjun
# serbapromosi : serbapromosi
# tepatbgt : tepatbgt
# jujur : jujur
# malingkoruptornya : malingkoruptornya
# ceybong : ceybong
# kpk : kpk
# tegak : tegak
# lurus : lurus
# memegang : pegang
# prinsip : prinsip
# nego : nego
# suap : suap
# penginku : pengin
# mung : mung
# siji : siji
# men : men
# ngawi : ngawi
# ngesot : ngesot
# bsd : bsd
# zaman : zaman
# perhatikan : perhati
# karier : karier
# twitteran : twitteran
# len : len
# calon : calon
# ulang : ulang
# kalender : kalender
# andi : andi
# ketidaknyamanan : ketidaknyamanan
# berasal : asal
# recycle : recycle
# sehubungan : hubung
# diatur : atur
# keputusan : putus
# perhubungan : hubung
# malem : malem
# rifan : rifan
# format : format
# teguh : teguh
# dateng : dateng
# daerahku : daerah
# tukar : tukar
# kinclong : kinclong
# terbenahi : benah
# thankyouuu : thankyouuu
# beliau : beliau
# angkasa : angkasa
# krakatau : krakatau
# steel : steel
# otw : otw
# nuklir : nuklir
# utara : utara
# ngeradain : ngeradain
# risiko : risiko
# resiko : resiko
# mentari : mentari
# jempol : jempol
# daur : daur
# konter : konter
# telfon : telfon
# pertamini : pertamini
# unlock : unlock
# future : future
# vath : vath
# subscribe : subscribe
# bulanannya : bulan
# ded : ded
# diskon : diskon
# bca : bca
# yosh : yosh
# finally : finally
# pay : pay
# vipul : vipul
# spay : spay
# sinyalmu : sinyal
# benerin : benerin
# bangsat : bangsat
# nyuruh : nyuruh
# ngapa : ngapa
# retakkan : retak
# ginjal : ginjal
# membajak : bajak
# bbrp : bbrp
# wag : wag
# publik : publik
# menyambutnya : sambut
# internetnya : internetnya
# perdananya : perdana
# outlet : outlet
# dapatkan : dapat
# temukan : temu
# genre : genre
# favoritmu : favorit
# download : download
# store : store
# google : google
# otg : otg
# ryzen : ryzen
# win : win
# lcd : lcd
# short : short
# vid : vid
# deket : deket
# semarang : semarang
# thai : thai
# stans : stans
# pdahal : pdahal
# perbaikilah : baik
# hoak : hoak
# efek : efek
# porsinya : porsi
# jembotttt : jembotttt
# rame : rame
# kompak : kompak
# ngehe : ngehe
# prof : prof
# tdi : tdi
# isti : isti
# manfaat : manfaat
# kerasa : rasa
# dtg : dtg
# trs : trs
# mesin : mesin
# masukin : masukin
# scan : scan
# finger : finger
# print : print
# beres : beres
# gudjob : gudjob
# use : use
# truecaller : truecaller
# efektif : efektif
# hilda : hilda
# menikmati : nikmat
# nice : nice
# pesan : pesan
# diamond : diamond
# bossku : bossku
# ufhttt : ufhttt
# gaya : gaya
# flexi : flexi
# sempet : sempet
# gpp : gpp
# pasang : pasang
# reza : reza
# skr : skr
# skak : skak
# mat : mat
# ber : ber
# bae : bae
# gelisah : gelisah
# aditya : aditya
# makiy : makiy
# iqbal : iqbal
# luncurkan : luncur
# berganti : ganti
# pengetahuan : tahu
# manajerial : manajerial
# ngeleg : ngeleg
# muter : muter
# mengacu : acu
# definisi : definisi
# kementerian : menteri
# mengakui : aku
# closed : closed
# nerusin : nerusin
# keukeuh : keukeuh
# monggo : monggo
# aduhhh : aduhhh
# bgni : bgni
# wifinya : wifinya
# disney : disney
# canva : canva
# vsco : vsco
# hbo : hbo
# iqiyi : iqiyi
# kece : kece
# legal : legal
# arc : arc
# nggawe : nggawe
# nich : nich
# endah : endah
# unli : unli
# worth : worth
# wisnu : wisnu
# bersi : bersi
# sehari : hari
# moch : moch
# dian : dian
# kuotanya : kuota
# kenceng : kenceng
# push : push
# rank : rank
# cashback : cashback
# masinis : masinis
# yeol : yeol
# wujud : wujud
# transformasi : transformasi
# bei : bei
# komersial : komersial
# mobitekno : mobitekno
# mengusung : usung
# tema : tema
# ditungguuu : ditungguuu
# bet : bet
# listrik : listrik
# edge : edge
# gni : gni
# yakali : yakali
# disuruh : suruh
# terkhusu : terkhusu
# hms : hms
# pimpinan : pimpin
# mentor : mentor
# diperusahaan : usaha
# baarokallahu : baarokallahu
# fiyk : fiyk
# signalnya : signalnya
# penjilat : jilat
# masah : masah
# slenk : slenk
# denn : denn
# nasih : nasih
# air : air
# liur : liur
# kering : kering
# daper : daper
# aer : aer
# ludah : ludah
# bini : bini
# balasan : balas
# hadin : hadin
# debit : debit
# berheti : berheti
# thank : thank
# zenab : zenab
# busukk : busukk
# bgtttt : bgtttt
# leletnya : lelet
# bimo : bimo
# miiinnn : miiinnn
# adindundendon : adindundendon
# bim : bim
# salabim : salabim
# guiss : guiss
# coa : coa
# tolak : tolak
# pdhal : pdhal
# time : time
# dijanjikan : janji
# bonusnya : bonus
# jaya : jaya
# amin : amin
# panipanipan : panipanipan
# seru : seru
# hotstar : hotstar
# plus : plus
# sengaja : sengaja
# raksasa : raksasa
# terimakasiiiihh : terimakasiiiihh
# lampu : lampu
# menghilang : hilang
# naufal : naufal
# nyet : nyet
# hilangkan : hilang
# warga : warga
# expat : expat
# rombongan : rombong
# pecundang : cundang
# pilpres : pilpres
# junjungan : junjung
# klian : klian
# jinak : jinak
# dhe : dhe
# ngurusi : ngurusi
# sing : sing
# signale : signale
# sebwah : sebwah
# jadul : jadul
# atasan : atas
# screening : screening
# pemanfaatan : manfaat
# teknologi : teknologi
# pinjeman : pinjeman
# pembesar : besar
# penis : penis
# adminnya : adminnya
# moonbyul : moonbyul
# menghilangkan : hilang
# dikenal : kenal
# bojo : bojo
# wkwkwkwkw : wkwkwkwkw
# meremehkan : remeh
# mimpin : mimpin
# menemukan : temu
# kecocokan : cocok
# diluncurkan : luncur
# ditingkatkan : tingkat
# speednya : speednya
# lemes : lemes
# ayam : ayam
# sayur : sayur
# gondalgandul : gondalgandul
# oalah : oalah
# pantes : pantes
# affandy : affandy
# musti : musti
# ngirimin : ngirimin
# dgr : dgr
# loe : loe
# esemka : esemka
# taliban : talib
# wkwkw : wkwkw
# kakaknya : kakak
# adiknya : adik
# berjaya : jaya
# keritik : keritik
# susunan : susun
# potensi : potensi
# cari : cari
# selengkapnya : lengkap
# good : good
# news : news
# kebaikan : baik
# trims : trims
# hendra : hendra
# afdahl : afdahl
# apps : apps
# keluarlah : keluar
# ...
# namaku : nama
# windong : windong
# cok : cok
# begituh : begituh
# cpns : cpns
# percayanya : percaya
# putusan : putus
# exp : exp
# manr : manr
# fire : fire
# purchase : purchase
# rilis : rilis
# aldo : aldo
# divisi : divisi
# dilapangan : lapang
# tes : tes
# slma : slma
# sby : sby
# berkuasa : kuasa
# pks : pks
# sendi : sendi
# str : str
# kesatuan : satu
# bawaan : bawa
# nenekluuuuu : nenekluuuuu
# dialog : dialog
# subtansinya : subtansinya
# cimahi : cimahi
# koq : koq
# cuaca : cuaca
# salahin : salahin
# penanganan : tangan
# jalur : jalur
# berintegritas : integritas
# sirik : sirik
# tanda : tanda
# angin : angin
# segar : segar
# ikj : ikj
# seni : seni
# lainya : lai
# rivalitas : rivalitas
# sarjana : sarjana
# ugm : ugm
# siri : siri
# ngeh : ngeh
# plokis : plokis
# induknya : induk
# ooredoo : ooredoo
# trilyun : trilyun
# kompetensinya : kompetensi
# itukan : itu
# menempatkan : tempat
# kinerjanya : kerja
# tampan : tampan
# yandi : yandi
# engga : engga
# royalti : royalti
# itupun : itu
# firm : firm
# rights : rights
# platform : platform
# dsp : dsp
# kaitannya : kait
# membenahi : benah
# dianggap : anggap
# semudah : mudah
# ngangkat : ngangkat
# prematur : prematur
# tabe : tabe
# iyaa : iyaa
# gwnti : gwnti
# raffi : raffi
# garuda : garuda
# mix : mix
# parlay : parlay
# stake : stake
# buruan : buru
# daftarkan : daftar
# disitus : situs
# ioncasino : ioncasino
# dpd : dpd
# dpr : dpr
# konsolidasi : konsolidasi
# gub : gub
# undang : undang
# kepala : kepala
# diundang : undang
# amati : amat
# polling : polling
# dimainkan : main
# didukung : dukung
# partisan : partisan
# bikinin : bikinin
# bugs : bugs
# reply : reply
# ditindak : tindak
# lanjuti : lanjut
# mengaku : aku
# penukaran : tukar
# allianz : allianz
# bersiaplah : siap
# koleksi : koleksi
# tiket : tiket
# konser : konser
# melapor : lapor
# terselip : selip
# binatang : binatang
# ingame : ingame
# lantas : lantas
# pemusik : musik
# duniapun : dunia
# garap : garap
# digitalnya : digital
# serius : serius
# perkuat : kuat
# pemilu : milu
# pegangan : pegang
# awas : awas
# jatuh : jatuh
# matang : matang
# haok : haok
# pencitraan : citra
# jasmev : jasmev
# bara : bara
# mesake : mesake
# keledaipun : keledai
# terperorok : orok
# lubang : lubang
# fekaes : fekaes
# hayo : hayo
# idha : idha
# jatahnya : jatah
# musuh : musuh
# nyo : nyo
# punyo : punyo
# bramn : bramn
# basis : basis
# fanatik : fanatik
# diarahin : diarahin
# boom : boom
# manajer : manajer
# ide : ide
# kring : kring
# telaah : telaah
# dimenangkannya : menang
# amunisi : amunisi
# money : money
# bandar : bandar
# elektoral : elektoral
# treshold : treshold
# direstui : restu
# elite : elite
# komprador : komprador
# pemburu : buru
# rente : rente
# getha : getha
# arep : arep
# dadi : dadi
# ngonoh : ngonoh
# idep : idep
# nang : nang
# nyong : nyong
# arin : arin
# kompeten : kompeten
# sidang : sidang
# ditunda : tunda
# pemberani : berani
# seekor : ekor
# memecah : pecah
# belah : belah
# pemberitaan : berita
# staff : staff
# aamiin : aamiin
# merasakan : rasa
# bato : bato
# optiknya : optik
# iming : iming
# menukarkan : tukar
# sejuta : juta
# alfamart : alfamart
# sebutin : sebutin
# angka : angka
# membaca : baca
# peta : peta
# berhubungan : hubung
# menumpuk : tumpuk
# jili : jil
# bisikan : bisik
# nafsu : nafsu
# udeh : udeh
# catet : catet
# idnya : idnya
# tlol : tlol
# trafo : trafo
# desaku : desa
# meledak : ledak
# ketengan : keteng
# kebutuhan : butuh
# momen : momen
# terlanjur : lanjur
# ngehek : ngehek
# ribuan : ribu
# istri : istri
# nyerpis : nyerpis
# abang : abang
# kewat : kewat
# andyalby : andyalby
# iyalah : iya
# gopoh : gopoh
# hahah : hahah
# puspita : puspita
# mengawasi : awas
# anggaran : anggar
# perwakilan : wakil
# urusin : urusin
# kalen : kalen
# scrol : scrol
# dimensen : sen
# aroel : aroel
# penasaran : penasaran
# linimasaku : linimasaku
# wow : wow
# project : project
# putih : putih
# terluar : luar
# berkeringat : keringat
# kesabaran : sabar
# ketabahan : tabah
# regis : regis
# eehh : eehh
# smsin : smsin
# brengsek : brengsek
# jaga : jaga
# sodara : sodara
# ntu : ntu
# sampean : sampean
# thu : thu
# sponsornya : sponsor
# berfikir : berfikir
# terpilihnya : pilih
# penyegaran : segar
# takbirrr : takbirrr
# pivasi : pivasi
# dahlah : dah
# ava : ava
# indra : indra
# janjian : janji
# about : about
# work : work
# warning : warning
# firewall : firewall
# blocking : blocking
# now : now
# using : using
# laptop : laptop
# working : working
# fine : fine
# also : also
# well : well
# phone : phone
# big : big
# risk : risk
# try : try
# mereplikasi : mereplikasi
# wisnutama : wisnutama
# telco : telco
# wacana : wacana
# entertainment : entertainment
# berkolaburasi : berkolaburasi
# dalamnya : dalam
# rebound : rebound
# industry : industry
# hukummati : hukummati
# terbukti : bukti
# merger : merger
# live : live
# acoustic : acoustic
# ramenations : ramenations
# star : star
# perfomance : perfomance
# sempai : sempai
# terlewatkan : lewat
# palembang : palembang
# veteran : veteran
# seberang : seberang
# soma : soma
# deretan : deret
# sejam : jam
# siklusnya : siklus
# bgtu : bgtu
# rantaupulut : rantaupulut
# seruyan : seruyan
# kab : kab
# kalimantan : kalimantan
# araboi : araboi
# memutus : putus
# ketergantungan : gantung
# ira : ira
# gajelass : gajelass
# grup : grup
# musiknya : musik
# mandek : mandek
# boa : boa
# next : next
# kreativitas : kreativitas
# lirik : lirik
# gitarisnya : gitaris
# mottonya : mottonya
# takud : takud
# nyambong : nyambong
# ketagihan : tagih
# pisan : pis
# woe : woe
# yoi : yoi
# udahan : udahan
# ladenin : ladenin
# untungnya : untung
# biarkan : biar
# hidupin : hidupin
# keluarganya : keluarga
# cao : cao
# bye : bye
# fadhilah : fadhilah
# templatenya : templatenya
# condong : condong
# kanan : kanan
# joehar : joehar
# art : art
# yohanes : yohanes
# nyamber : nyamber
# without : without
# context : context
# sejahtera : sejahtera
# penjelasan : jelas
# nyalahin : nyalahin
# bgttt : bgttt
# kewenangan : wenang
# dapetnya : dapetnya
# starbucks : starbucks
# minum : minum
# kenpa : kenpa
# sayangkan : sayang
# wkwkwkwkwkwkwkwkwkwkwkwkwkwkwk : wkwkwkwkwkwkwkwkwkwkwkwkwkwkwk
# sumanto : sumanto
# penyihir : sihir
# diamonds : diamonds
# nomornya : nomor
# ngespam : ngespam
# pela : pela
# samaa : samaa
# suee : suee
# styp : styp
# raibnya : raib
# dimohon : mohon
# bbm : bbm
# makasii : makasii
# burhan : burhan
# niiih : niiih
# aditia : aditia
# berbahaya : bahaya
# childe : childe
# jesse : jesse
# posisinya : posisi
# digimanakan : digimanakan
# dianterin : dianterin
# uztad : uztad
# adem : adem
# klojotan : klojotan
# menyalahkan : salah
# juna : juna
# peluang : peluang
# anti : anti
# dsana : dsana
# mon : mon
# maap : maap
# dech : dech
# papa : papa
# komisi : komisi
# ontanya : ontanya
# secede : secede
# gicu : gicu
# matanya : mata
# merosot : merosot
# kehidupan : hidup
# mmang : mmang
# berputar : putar
# takdir : takdir
# bgitu : bgitu
# misteri : misteri
# bsok : bsok
# lusa : lusa
# keberuntungan : untung
# akn : akn
# raih : raih
# mahkluk : mahkluk
# pendatang : datang
# pantesannn : pantesannn
# rmh : rmh
# bandara : bandara
# uas : uas
# telat : telat
# sejem : jem
# ngumpulinnya : ngumpulinnya
# tidal : tidal
# kebocoran : bocor
# kelilipan : kelilip
# onta : onta
# nape : nape
# hhaaa : hhaaa
# rambut : rambut
# wajah : wajah
# ditebelin : ditebelin
# juling : juling
# mbah : mbah
# hero : hero
# stik : stik
# analog : analog
# jutaan : juta
# efect : efect
# usia : usia
# kabinet : kabinet
# elektabilitas : elektabilitas
# perayaan : raya
# waisak : waisak
# supp : supp
# terdebest : terdebest
# dipunahkan : punah
# beka : beka
# bahasa : bahasa
# melayu : melayu
# mengkomersialisasikan : komersialisasi
# jenggot : jenggot
# kambing : kambing
# jidath : jidath
# gosong : gosong
# rebranding : rebranding
# elaahhhh : elaahhhh
# serasa : serasa
# nope : nope
# dude : dude
# luamayan : luamayan
# referensi : referensi
# inggris : inggris
# zer : zer
# release : release
# loeee : loeee
# keringet : keringet
# dubur : dubur
# ubah : ubah
# voecher : voecher
# frifikasi : frifikasi
# informasinya : informasi
# acc : acc
# kenyang : kenyang
# aamin : aamin
# peka : peka
# berantem : antem
# setuju : tuju
# bersangkutan : sangkut
# tembak : tembak
# tkp : tkp
# samarinda : samarinda
# misih : misih
# artis : artis
# aneh : aneh
# kamis : kamis
# persaingan : saing
# land : land
# memanas : panas
# lengah : lengah
# tembulu : tembulu
# hahahha : hahahha
# menggelepar : gelepar
# kumpulin : kumpulin
# gamesmax : gamesmax
# ketemu : ketemu
# import : import
# berbincang : bincang
# bincang : bincang
# fasih : fasih
# diragukan : ragu
# pemikirannya : pikir
# akoooohhh : akoooohhh
# loohh : loohh
# tipe : tipe
# lohhh : lohhh
# gan : gan
# beresin : resin
# arahnya : arah
# kesempatan : sempat
# nyalip : nyalip
# tikungan : tikung
# rekening : rekening
# ratisan : ratisan
# nasabahnya : nasabah
# brapa : brapa
# britanya : britanya
# fase : fase
# deny : deny
# kapabilitas : kapabilitas
# bidangnya : bidang
# pantang : pantang
# mundur : mundur
# biarpun : biarpun
# jurang : jurang
# hebohhhhh : hebohhhhh
# hskim : hskim
# wekkkkk : wekkkkk
# arb : arb
# ngungsi : ngungsi
# lapak : lapak
# excl : excl
# {'pulsa': 'pulsa', 'transfer': 'transfer', 'indosat': 'indosat', 'telkomsel': 'telkomsel', 'smartfren': 'smartfren', 'minggu': 'minggu', 'mei': 'mei', '': '', 'senang': 'senang', 'banget': 'banget', 'bacanya': 'baca', 'gue': 'gue', 'hai': 'hai', 'kak': 'kak', 'aisha': 'aisha', 'maaf': 'maaf', 'keluhan': 'keluh', 'paket': 'paket', 'darurat': 'darurat', 'aktif': 'aktif', 'infokan': 'info', 'data': 'data', 'via': 'via', 'dibantu': 'bantu', 'cek': 'cek', 'privasi': 'privasi', 'terjaga': 'jaga', 'nomor': 'nomor', 'lokasi': 'lokasi', 'makasih': 'makasih', 'elma': 'elma', 'didu': 'didu', 'anak': 'anak', 'usaha': 'usaha', 'telkom': 'telkom', 'blok': 'blok', 'komisaris': 'komisaris', 'lini': 'lini', 'bisnis': 'bisnis', 'salah': 'salah', 'satunya': 'satu', 'ane': 'ane', 'telpon': 'telpon', 'rumah': 'rumah', 'mahal': 'mahal', 'kuota': 'kuota', 'boros': 'boros', 'ampun': 'ampun', 'bandyyy': 'bandyyy', 'bandy': 'bandy', 'umur': 'umur', 'brp': 'brp', 'nak': 'nak', 'blm': 'blm', 'eluh': 'eluh', 'maen': 'maen', 'twiter': 'twiter', 'mancing': 'mancing', 'jugak': 'jugak', 'belajar': 'ajar', 'rajin': 'rajin', 'pinter': 'pinter', 'sbg': 'sbg', 'ttg': 'ttg', 'gih': 'gih', 'korupsi': 'korupsi', 'anies': 'anies', 'dipanggil': 'panggil', 'bang': 'bang', 'inggi': 'inggi', 'xixixixi': 'xixixixi', 'kendala': 'kendala', 'top': 'top', 'silakan': 'sila', 'detail': 'detail', 'tanggal': 'tanggal', 'kejadian': 'jadi', 'kakak': 'kakak', 'micha': 'micha', 'pelanggan': 'langgan', 'udah': 'udah', 'anjlok': 'anjlok', 'kisah': 'kisah', 'lawas': 'lawas', 'versi': 'versi', 'kali': 'kali', 'coba': 'coba', 'failed': 'failed', 'gangguan': 'ganggu', 'notifikasinya': 'notifikasi', 'menunggu': 'tunggu', 'proses': 'proses', 'provider': 'provider', 'kartuhalo': 'kartuhalo', 'syamsurizal': 'syamsurizal', 'mimin': 'mimin', 'sarankan': 'saran', 'memposting': 'memposting', 'pribadi': 'pribadi', 'mention': 'mention', 'menghindari': 'hindar', 'penyalahgunaan': 'penyalahgunaan', 'orang': 'orang', 'bertanggung': 'tanggung', 'bantu': 'bantu', 'mohon': 'mohon', 'berkenan': 'kenan', 'cheryl': 'cheryl', 'woi': 'woi', 'cebong': 'cebong', 'kodok': 'kodok', 'dungu': 'dungu', 'beda': 'beda', 'lol': 'lol', 'goblok': 'goblok', 'bentar': 'bentar', 'dapet': 'dapet', 'hadiah': 'hadiah', 'luh': 'luh', 'ra': 'ra', 'betuuuul': 'betuuuul', 'betuuul': 'betuuul', 'bkn': 'bkn', 'aplg': 'aplg', 'pinjol': 'pinjol', 'sll': 'sll', 'masuk': 'masuk', 'smsnya': 'smsnya', 'perdana': 'perdana', 'simcardnya': 'simcardnya', 'telp': 'telp', 'menawarkan': 'tawar', 'terheran': 'heran', 'heran': 'heran', 'dri': 'dri', 'mmg': 'mmg', 'kerjasama': 'kerjasama', 'aktivasi': 'aktivasi', 'paketnya': 'paket', 'yuk': 'yuk', 'infoin': 'infoin', 'nama': 'nama', 'lengkap': 'lengkap', 'lahir': 'lahir', 'syam': 'syam', 'gimana': 'gimana', 'beli': 'beli', 'tambahan': 'tambah', 'kartu': 'kartu', 'hallo': 'hallo', 'barusan': 'barusan', 'lapor': 'lapor', 'call': 'call', 'center': 'center', 'pembatalan': 'batal', 'transaksi': 'transaksi', 'dibatalkan': 'batal', 'ditambah': 'tambah', 'harian': 'hari', 'solusi': 'solusi', 'wajar': 'wajar', 'den': 'den', 'banting': 'banting', 'tulang': 'tulang', 'jiwa': 'jiwa', 'raga': 'raga', 'pertaruhkan': 'taruh', 'dlm': 'dlm', 'hati': 'hati', 'diamput': 'amput', 'iya': 'iya', 'jatah': 'jatah', 'puas': 'puas', 'dpt': 'dpt', 'gaji': 'gaji', 'kau': 'kau', 'hahahaha': 'hahahaha', 'penyembah': 'sembah', 'kuburan': 'kubur', 'tolol': 'tolol', 'pagi': 'pagi', 'seputar': 'putar', 'produk': 'produk', 'layanan': 'layan', 'ngamuk': 'ngamuk', 'singapur': 'singapur', 'gitaris': 'gitaris', 'dijadikan': 'jadi', 'cocok': 'cocok', 'bingit': 'bingit', 'selamat': 'selamat', 'salahnya': 'salah', 'dimana': 'mana', 'terpilih': 'pilih', 'dipertimbangkan': 'timbang', 'kapasitasnya': 'kapasitas', 'dukung': 'dukung', 'donk': 'donk', 'kemajuan': 'maju', 'bangsa': 'bangsa', 'mudah': 'mudah', 'wkwkwkwkwkw': 'wkwkwkwkwkw', 'ngakak': 'ngakak', 'guling': 'guling', 'raganya': 'raga', 'dipertaruhkan': 'taruh', 'dilirik': 'lirik', 'kaga ...
# ------------------------
# Pandas Apply:   0%|          | 0/1983 [00:04<?, ?it/s]
#                                                 content  \
# 0     #believedtesti\n\n#believedpulsa pulsa transfe...
# 1     @achmadsatori4 @dennysiregar7 @telkomsel kok s...
# 2     @muelnoona hai, kak aisha. maaf ya. mengenai k...
# 3     @hudihartobandy @msaid_didu telkomsel itu anak...
# 4     ane dah lama ga pake telkomsel dan telpon ruma...
# ...                                                 ...
# 1995  @handre_81 @dennysiregar7 @telkomsel bang deny...
# 1996  @telkomsel jaringan nya ilang-ilangan terus ka...
# 1997  @untung51440057 @dennysiregar7 @telkomsel http...
# 1998  @riegucciano nomornya abdee negara pakai ex-el...
# 1999  @dennysiregar7 @telkomsel alamat saham $tlkm a...
#
#                                          cleaning_tweet  \
# 0     pulsa transfer indosat telkomsel smartfren min...
# 1                        kok senang banget bacanya gue
# 2     hai kak aisha maaf mengenai keluhan paket daru...
# 3      didu telkomsel itu anak usaha telkom blok ken...
# 4     ane dah lama pake telkomsel dan telpon rumah p...
# ...                                                 ...
# 1995   bang deny kalau tidak punya kapabilitas bidan...
# 1996  jaringan nya ilang ilangan terus kaya dia aku ...
# 1997                          itu hskim kadrun wekkkkk
# 1998  nomornya abdee negara pakai bukan nomor telkomsel
# 1999  alamat saham tlkm arb hari malam ngungsi dulu ...
#
#                                              tokenisasi  \
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                 [kok, senang, banget, bacanya, gue, ]
# 2     [hai, kak, aisha, maaf, mengenai, keluhan, pak...
# 3     [, didu, telkomsel, itu, anak, usaha, telkom, ...
# 4     [ane, dah, lama, pake, telkomsel, dan, telpon,...
# ...                                                 ...
# 1995  [, bang, deny, kalau, tidak, punya, kapabilita...
# 1996  [jaringan, nya, ilang, ilangan, terus, kaya, d...
# 1997                    [itu, hskim, kadrun, wekkkkk, ]
# 1998  [nomornya, abdee, negara, pakai, bukan, nomor,...
# 1999  [alamat, saham, tlkm, arb, hari, malam, ngungs...
#
#                                                stopword  \
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                      [senang, banget, bacanya, gue, ]
# 2     [hai, kak, aisha, maaf, keluhan, paket, darura...
# 3     [, didu, telkomsel, anak, usaha, telkom, blok,...
# 4     [ane, telkomsel, telpon, rumah, pulsa, mahal, ...
# ...                                                 ...
# 1995  [, bang, deny, kapabilitas, bidangnya, kadrun,...
# 1996  [jaringan, ilang, ilangan, kaya, twitteran, le...
# 1997                         [hskim, kadrun, wekkkkk, ]
# 1998  [nomornya, abdee, negara, pakai, nomor, telkom...
# 1999  [alamat, saham, tlkm, arb, malam, ngungsi, pin...
#
#                                                stemming
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                         [senang, banget, baca, gue, ]
# 2     [hai, kak, aisha, maaf, keluh, paket, darurat,...
# 3     [, didu, telkomsel, anak, usaha, telkom, blok,...
# 4     [ane, telkomsel, telpon, rumah, pulsa, mahal, ...
# ...                                                 ...
# 1995  [, bang, deny, kapabilitas, bidang, kadrun, ma...
# 1996   [jaring, ilang, ilangan, kaya, twitteran, lot, ]
# 1997                         [hskim, kadrun, wekkkkk, ]
# 1998    [nomor, abdee, negara, pakai, nomor, telkomsel]
# 1999  [alamat, saham, tlkm, arb, malam, ngungsi, pin...
#
# [1983 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [pulsa, transfer, indosat, telkomsel, smartfre...
# 1                         [senang, banget, baca, gue, ]
# 2     [hai, kak, aisha, maaf, keluh, paket, darurat,...
# 3     [, didu, telkomsel, anak, usaha, telkom, blok,...
# 4     [ane, telkomsel, telpon, rumah, pulsa, mahal, ...
# ...                                                 ...
# 1995  [, bang, deny, kapabilitas, bidang, kadrun, ma...
# 1996   [jaring, ilang, ilangan, kaya, twitteran, lot, ]
# 1997                         [hskim, kadrun, wekkkkk, ]
# 1998    [nomor, abdee, negara, pakai, nomor, telkomsel]
# 1999  [alamat, saham, tlkm, arb, malam, ngungsi, pin...
#
# [1983 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_telkomsel_5.xlsx')
