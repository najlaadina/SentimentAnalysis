# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                           pagi min, mau nanya boleh?
# 1    Makasiya min, udah lancar nih jaringannya :D M...
# 2                       BALAS DM DONG LAGI DARURAT INI
# 3    hayu berangkattttt\n\n#MajuTerusBersamaIndiHom...
# 4                                              Mantull
# ..                                                 ...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           Wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#Internetn...
# 429  memasuki hari ke 3 Nomor Internet : 1211 2223 ...
# 430                             ‼️MIN, CEK DM PLEASE‼️
#
# [431 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 143

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                           pagi min, mau nanya boleh?
# 3    hayu berangkattttt\n\n#MajuTerusBersamaIndiHom...
# 5    Halo..sudah seminggu internet saya gangguan, n...
# 6          bagaimana caranya beralih ke paket promo kk
# 7           Indihome di rumah saya kenapa jadi LOS yaa
# ..                                                 ...
# 425  kebutuhan kita dipenuhi IndiHome\n#Internetnya...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           Wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#Internetn...
# 430                             ‼️MIN, CEK DM PLEASE‼️
#
# [219 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                           pagi min, mau nanya boleh?
# 3    hayu berangkattttt\n\n#majuterusbersamaindihom...
# 5    halo..sudah seminggu internet saya gangguan, n...
# 6          bagaimana caranya beralih ke paket promo kk
# 7           indihome di rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425  kebutuhan kita dipenuhi indihome\n#internetnya...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#internetn...
# 430                             ‼️min, cek dm please‼️
#
# [219 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                           pagi min, mau nanya boleh?
# 3    hayu berangkattttt\n\n#majuterusbersamaindihom...
# 5    halo..sudah seminggu internet saya gangguan, n...
# 6          bagaimana caranya beralih ke paket promo kk
# 7           indihome di rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425  kebutuhan kita dipenuhi indihome\n#internetnya...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#internetn...
# 430                             ‼️min, cek dm please‼️
#
#                                          cleaning_text
# 0                            pagi min mau nanya boleh
# 3                                   hayu berangkattttt
# 5    halo sudah seminggu internet saya gangguan nom...
# 6               bagaimana caranya beralih paket promo
# 7              indihome rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425                   kebutuhan kita dipenuhi indihome
# 426  teknilogi indihome emang mantul makin asik ber...
# 427           wah mantep gede bgt total penyimpanannya
# 428                 penyimpanan yang sangat bermanfaat
# 430                                    min cek please
#
# [219 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                           pagi min, mau nanya boleh?
# 3    hayu berangkattttt\n\n#majuterusbersamaindihom...
# 5    halo..sudah seminggu internet saya gangguan, n...
# 6          bagaimana caranya beralih ke paket promo kk
# 7           indihome di rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425  kebutuhan kita dipenuhi indihome\n#internetnya...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#internetn...
# 430                             ‼️min, cek dm please‼️
#
#                                          cleaning_text  \
# 0                            pagi min mau nanya boleh
# 3                                   hayu berangkattttt
# 5    halo sudah seminggu internet saya gangguan nom...
# 6               bagaimana caranya beralih paket promo
# 7              indihome rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425                   kebutuhan kita dipenuhi indihome
# 426  teknilogi indihome emang mantul makin asik ber...
# 427           wah mantep gede bgt total penyimpanannya
# 428                 penyimpanan yang sangat bermanfaat
# 430                                    min cek please
#
#                                             tokenisasi
# 0                     [pagi, min, mau, nanya, boleh, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, sudah, seminggu, internet, saya, ganggu...
# 6        [bagaimana, caranya, beralih, paket, promo, ]
# 7      [indihome, rumah, saya, kenapa, jadi, los, yaa]
# ..                                                 ...
# 425              [kebutuhan, kita, dipenuhi, indihome]
# 426  [teknilogi, indihome, emang, mantul, makin, as...
# 427    [wah, mantep, gede, bgt, total, penyimpanannya]
# 428            [penyimpanan, yang, sangat, bermanfaat]
# 430                             [, min, cek, please, ]
#
# [219 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                           pagi min, mau nanya boleh?
# 3    hayu berangkattttt\n\n#majuterusbersamaindihom...
# 5    halo..sudah seminggu internet saya gangguan, n...
# 6          bagaimana caranya beralih ke paket promo kk
# 7           indihome di rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425  kebutuhan kita dipenuhi indihome\n#internetnya...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#internetn...
# 430                             ‼️min, cek dm please‼️
#
#                                          cleaning_text  \
# 0                            pagi min mau nanya boleh
# 3                                   hayu berangkattttt
# 5    halo sudah seminggu internet saya gangguan nom...
# 6               bagaimana caranya beralih paket promo
# 7              indihome rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425                   kebutuhan kita dipenuhi indihome
# 426  teknilogi indihome emang mantul makin asik ber...
# 427           wah mantep gede bgt total penyimpanannya
# 428                 penyimpanan yang sangat bermanfaat
# 430                                    min cek please
#
#                                             tokenisasi  \
# 0                     [pagi, min, mau, nanya, boleh, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, sudah, seminggu, internet, saya, ganggu...
# 6        [bagaimana, caranya, beralih, paket, promo, ]
# 7      [indihome, rumah, saya, kenapa, jadi, los, yaa]
# ..                                                 ...
# 425              [kebutuhan, kita, dipenuhi, indihome]
# 426  [teknilogi, indihome, emang, mantul, makin, as...
# 427    [wah, mantep, gede, bgt, total, penyimpanannya]
# 428            [penyimpanan, yang, sangat, bermanfaat]
# 430                             [, min, cek, please, ]
#
#                                               stopword
# 0                                 [pagi, min, nanya, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, seminggu, internet, gangguan, nomor, ti...
# 6                            [beralih, paket, promo, ]
# 7                          [indihome, rumah, los, yaa]
# ..                                                 ...
# 425                    [kebutuhan, dipenuhi, indihome]
# 426  [teknilogi, indihome, emang, mantul, asik, ind...
# 427              [mantep, gede, total, penyimpanannya]
# 428                          [penyimpanan, bermanfaat]
# 430                             [, min, cek, please, ]
#
# [219 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 505
# ------------------------
# pagi : pagi
# min : min
# nanya : nanya
#  :
# hayu : hayu
# berangkattttt : berangkattttt
# halo : halo
# seminggu : minggu
# internet : internet
# gangguan : ganggu
# nomor : nomor
# tiket : tiket
# in : in
# nggak : nggak
# progress : progress
# penanganan : tangan
# bayar : bayar
# mbps : mbps
# dapetnya : dapetnya
# beralih : alih
# paket : paket
# promo : promo
# indihome : indihome
# rumah : rumah
# los : los
# yaa : yaa
# hallo : hallo
# selamat : selamat
# mohon : mohon
# info : info
# memutus : putus
# ganti : ganti
# tagihan : tagih
# tolong : tolong
# perbaikkan : baik
# mengatasi : atas
# layanan : layan
# buka : buka
# baca : baca
# keren : keren
# akun : akun
# barunya : baru
# maksimal : maksimal
# tgl : tgl
# berp : berp
# balas : balas
# fresh : fresh
# muda : muda
# bun : bun
# haloo : haloo
# selesai : selesai
# telp : telp
# kali : kali
# kelar : kelar
# dpt : dpt
# janji : janji
# upaya : upaya
# konfirmasi : konfirmasi
# dijanjikan : janji
# terlewati : lewat
# ditepati : tepat
# bener : bener
# jaga : jaga
# ketat : ketat
# nihh : nihh
# kereeen : kereeen
# nicee : nicee
# nice : nice
# informasi : informasi
# oke : oke
# minn : minn
# coba : coba
# tipss : tipss
# yaaa : yaaa
# makazih : makazih
# tips : tips
# tanggal : tanggal
# segini : gin
# pas : pas
# banget : banget
# mantaps : mantaps
# euy : euy
# cek : cek
# repot : repot
# mah : mah
# sip : sip
# ribet : ribet
# bpk : bpk
# admin : admin
# maret : maret
# aktif : aktif
# simple : simple
# setuju : tuju
# hitam : hitam
# lancar : lancar
# jalan : jalan
# ikutin : ikutin
# thanks : thanks
# tipsnya : tipsnya
# mimin : mimin
# deh : deh
# dapet : dapet
# yeay : yeay
# top : top
# ngehang : ngehang
# browsernya : browser
# lemot : lot
# kaka : kaka
# mantul : mantul
# pokoknyaa : pokoknyaa
# makasih : makasih
# suka : suka
# cookies : cookies
# mantapp : mantapp
# bangett : bangett
# ohh : ohh
# gitu : gitu
# clear : clear
# password : password
# memasuki : pasuk
# wifi : wifi
# trus : trus
# lupa : lupa
# karna : karna
# pencerahan : cerah
# permasalahan : masalah
# udah : udah
# terhubung : hubung
# rubah : rubah
# pasword : pasword
# akses : akses
# browser : browser
# nyolong : nyolong
# kereennn : kereennn
# maaf : maaf
# kak : kak
# phone : phone
# penggunaan : guna
# teleponnya : telepon
# free : free
# brp : brp
# menit : menit
# aplikasi : aplikasi
# telkom : telkom
# provider : provider
# telepon : telepon
# apl : apl
# gimana : gimana
# donk : donk
# udh : udh
# ngk : ngk
# koneksi : koneksi
# sya : sya
# pdhl : pdhl
# bru : bru
# alfamart : alfamart
# byar : byar
# lngsung : lngsung
# ttp : ttp
# sma : sma
# respon : respon
# betah : betah
# terbaikk : terbaikk
# nyaman : nyaman
# jaringannya : jaring
# alhamdulilah : alhamdulilah
# gila : gila
# promonya : promonya
# terhormat : hormat
# lakukan : laku
# perbaikan : baik
# modem : modem
# nunggu : nunggu
# besok : besok
# rabu : rabu
# mulu : mulu
# teknisinya : teknisi
# butuh : butuh
# doang : doang
# lahhh : lahhh
# asli : asli
# aneh : aneh
# koneksinya : koneksi
# ngebut : ngebut
# dirumah : rumah
# internetnya : internetnya
# area : area
# desa : desa
# fatufia : fatufia
# rusun : rusun
# kurisa : risa
# bahodopi : bahodopi
# morowali : morowali
# sulawesi : sulawesi
# indonesia : indonesia
# pasang : pasang
# hati : hati
# mengalami : alami
# tertipu : tipu
# kesel : kesel
# sumpah : sumpah
# ngeleg : ngeleg
# kaga : kaga
# dibales : dibales
# bales : bales
# kek : kek
# eth : eth
# mao : mao
# rb : rb
# niceee : niceee
# nama : nama
# neneng : neneng
# rohamdah : rohamdah
# wawasan : wawas
# baruu : baruu
# infoo : infoo
# indhihome : indhihome
# nonton : nonton
# film : film
# ama : ama
# nge : nge
# game : game
# mati : mati
# ngetik : ngetik
# mib : mib
# berner : berner
# siiiii : siiiii
# bahaya : bahaya
# emang : emang
# vpn : vpn
# terimkasi : terimkasi
# aman : aman
# semuanyaaa : semuanyaaa
# mantap : mantap
# knp : knp
# terimakasih : terimakasih
# membantu : bantu
# adaa : adaa
# alasan : alas
# yaaaaa : yaaaaa
# check : check
# lengkap : lengkap
# pahammm : pahammm
# bingung : bingung
# panduan : pandu
# lengkapnya : lengkap
# stb : stb
# bermanfaat : manfaat
# rasah : rasah
# ngono : ngono
# raimu : rai
# ngentod : ngentod
# ngelag : ngelag
# tros : tros
# nyapo : nyapo
# ratrimo : ratrimo
# dongakne : dongakne
# sesok : sok
# ngko : ngko
# asui : asu
# jancok : jancok
# wei : wei
# bajingan : bajing
# mending : mending
# cok : cok
# kontol : kontol
# tenan : tenan
# jarak : jarak
# sinyal : sinyal
# meter : meter
# wih : wih
# infonya : info
# tembok : tembok
# menyerap : serap
# malam : malam
# pengguna : guna
# mengadukan : adu
# dibawah : bawah
# langganan : langgan
# bulannya : bulan
# januari : januari
# kemarin : kemarin
# naikkan : naik
# jaringan : jaring
# speedtest : speedtest
# dimanjain : dimanjain
# fitur : fitur
# favorit : favorit
# aneee : aneee
# myindihome : myindihome
# download : download
# dimana : mana
# enaknya : enak
# video : video
# demand : demand
# vod : vod
# ush : ush
# kerjamu : kerja
# super : super
# lelet : lelet
# seru : seru
# eang : eang
# iyaa : iyaa
# berfaedah : faedah
# yuk : yuk
# semoga : moga
# rezeky : rezeky
# peluang : peluang
# bareng : bareng
# kereen : kereen
# uhuy : uhuy
# pemasangan : pasang
# downlod : downlod
# mna : mna
# pelanggan : langgan
# siang : siang
# melaporkan : lapor
# feb : feb
# diinformasikan : informasi
# tim : tim
# daerah : daerah
# tinggal : tinggal
# masal : masal
# isu : isu
# diselesaikan : selesai
# diresponse : diresponse
# keluhan : keluh
# resmi : resmi
# solusi : solusi
# bantuan : bantu
# menginformasikan : informasi
# langkah : langkah
# alternatifnya : alternatif
# relai : relai
# emagn : emagn
# say : say
# keluarga : keluarga
# enak : enak
# praktiss : praktiss
# pkoknya : pkoknya
# praktis : praktis
# ngumpul : ngumpul
# tugas : tugas
# bsa : bsa
# tlfon : tlfon
# normal : normal
# bos : bos
# wadidaw : wadidaw
# kerennn : kerennn
# gmna : gmna
# gimnaa : gimnaa
# iya : iya
# reouter : reouter
# panas : panas
# untung : untung
# gampang : gampang
# step : step
# wahhh : wahhh
# berguna : guna
# nuhun : nuhun
# aahh : aahh
# istirahatin : istirahatin
# bentar : bentar
# suhu : suhu
# terjaga : jaga
# terussss : terussss
# cuy : cuy
# pantes : pantes
# donlot : donlot
# praktekin : praktekin
# drumah : drumah
# stabil : stabil
# yuhuuu : yuhuuu
# dapettt : dapettt
# gakan : gakan
# kelewat : lewat
# lagiii : lagiii
# takit : takit
# ketinggalan : tinggal
# ternyataa : ternyataa
# mantep : mantep
# galau : galau
# sayang : sayang
# indihomecare : indihomecare
# balasnya : balas
# payah : payah
# pelayanan : layan
# padalah : pada
# kena : kena
# biaya : biaya
# tambahan : tambah
# tvod : tvod
# track : track
# myir : myir
# terpasang : pasang
# status : status
# aplikasinya : aplikasi
# ngarep : ngarep
# memudahkan : mudah
# ehh : ehh
# nyusahin : nyusahin
# pengen : ken
# cepet : cepet
# kuliah : kuliah
# online : online
# diatasi : atas
# nyaa : nyaa
# lanjutkan : lanjut
# bagus : bagus
# berani : berani
# ukuran : ukur
# hehehe : hehehe
# gagal : gagal
# file : file
# besarnya : besar
# dicoba : coba
# tes : tes
# kerennya : keren
# penggemar : gemar
# uga : uga
# lampunya : lampu
# hidup : hidup
# dibalas : balas
# duh : duh
# komplen : komplen
# sihh : sihh
# ngeganggu : ngeganggu
# daring : daring
# kaya : kaya
# gini : gin
# tbtb : tbtb
# keputus : putus
# yeiyyy : yeiyyy
# khawatir : khawatir
# panduannya : pandu
# kadang : kadang
# error : error
# imunitas : imunitas
# meningkat : tingkat
# kesehatan : sehat
# mensolusikan : solusi
# omong : omong
# kelanjutan : lanjut
# kendala : kendala
# proses : proses
# smpai : smpai
# skrang : skrang
# edukasi : edukasi
# acara : acara
# bola : bola
# dompet : dompet
# hemat : hemat
# jaya : jaya
# anti : anti
# kelewatan : lewat
# mudah : mudah
# cepat : cepat
# secepatnya : cepat
# mandiri : mandiri
# pemakaiannya : pakai
# app : app
# makasiiih : makasiiih
# takut : takut
# putus : putus
# nyambung : nyambung
# kehabisan : habis
# kuota : kuota
# restar : restar
# minnn : minnn
# seamless : seamless
# device : device
# fiturnya : fiturnya
# atasnama : atasnama
# segeraaaaaaaa : segeraaaaaaaa
# wow : wow
# keuntungannya : untung
# jayalah : jaya
# jndihone : jndihone
# asliii : asliii
# maju : maju
# okeee : okeee
# otw : otw
# lokasi : lokasi
# fiber : fiber
# ilmu : ilmu
# komentar : komentar
# dimatikan : mati
# mengecewakan : kecewa
# skrg : skrg
# refund : refund
# uang : uang
# depost : depost
# haduh : haduh
# merugikan : rugi
# customers : customers
# kecewa : kecewa
# kebutuhan : butuh
# dipenuhi : penuh
# teknilogi : teknilogi
# asik : asik
# gede : gede
# total : total
# penyimpanannya : simpan
# penyimpanan : simpan
# please : please
# {'pagi': 'pagi', 'min': 'min', 'nanya': 'nanya', '': '', 'hayu': 'hayu', 'berangkattttt': 'berangkattttt', 'halo': 'halo', 'seminggu': 'minggu', 'internet': 'internet', 'gangguan': 'ganggu', 'nomor': 'nomor', 'tiket': 'tiket', 'in': 'in', 'nggak': 'nggak', 'progress': 'progress', 'penanganan': 'tangan', 'bayar': 'bayar', 'mbps': 'mbps', 'dapetnya': 'dapetnya', 'beralih': 'alih', 'paket': 'paket', 'promo': 'promo', 'indihome': 'indihome', 'rumah': 'rumah', 'los': 'los', 'yaa': 'yaa', 'hallo': 'hallo', 'selamat': 'selamat', 'mohon': 'mohon', 'info': 'info', 'memutus': 'putus', 'ganti': 'ganti', 'tagihan': 'tagih', 'tolong': 'tolong', 'perbaikkan': 'baik', 'mengatasi': 'atas', 'layanan': 'layan', 'buka': 'buka', 'baca': 'baca', 'keren': 'keren', 'akun': 'akun', 'barunya': 'baru', 'maksimal': 'maksimal', 'tgl': 'tgl', 'berp': 'berp', 'balas': 'balas', 'fresh': 'fresh', 'muda': 'muda', 'bun': 'bun', 'haloo': 'haloo', 'selesai': 'selesai', 'telp': 'telp', 'kali': 'kali', 'kelar': 'kelar', 'dpt': 'dpt', 'janji': 'janji', 'upaya': 'upaya', 'konfirmasi': 'konfirmasi', 'dijanjikan': 'janji', 'terlewati': 'lewat', 'ditepati': 'tepat', 'bener': 'bener', 'jaga': 'jaga', 'ketat': 'ketat', 'nihh': 'nihh', 'kereeen': 'kereeen', 'nicee': 'nicee', 'nice': 'nice', 'informasi': 'informasi', 'oke': 'oke', 'minn': 'minn', 'coba': 'coba', 'tipss': 'tipss', 'yaaa': 'yaaa', 'makazih': 'makazih', 'tips': 'tips', 'tanggal': 'tanggal', 'segini': 'gin', 'pas': 'pas', 'banget': 'banget', 'mantaps': 'mantaps', 'euy': 'euy', 'cek': 'cek', 'repot': 'repot', 'mah': 'mah', 'sip': 'sip', 'ribet': 'ribet', 'bpk': 'bpk', 'admin': 'admin', 'maret': 'maret', 'aktif': 'aktif', 'simple': 'simple', 'setuju': 'tuju', 'hitam': 'hitam', 'lancar': 'lancar', 'jalan': 'jalan', 'ikutin': 'ikutin', 'thanks': 'thanks', 'tipsnya': 'tipsnya', 'mimin': 'mimin', 'deh': 'deh', 'dapet': 'dapet', 'yeay': 'yeay', 'top': 'top', 'ngehang': 'ngehang', 'browsernya': 'browser', 'lemot': 'lot', 'kaka': 'kaka', 'mantul': 'mantul', 'pokoknyaa': 'pokoknyaa', 'makasih': 'makasih', 'suka': 'suka', 'cookies': 'cookies', 'mantapp': 'mantapp', 'bangett': 'bangett', 'ohh': 'ohh', 'gitu': 'gitu', 'clear': 'clear', 'password': 'password', 'memasuki': 'pasuk', 'wifi': 'wifi', 'trus': 'trus', 'lupa': 'lupa', 'karna': 'karna', 'pencerahan': 'cerah', 'permasalahan': 'masalah', 'udah': 'udah', 'terhubung': 'hubung', 'rubah': 'rubah', 'pasword': 'pasword', 'akses': 'akses', 'browser': 'browser', 'nyolong': 'nyolong', 'kereennn': 'kereennn', 'maaf': 'maaf', 'kak': 'kak', 'phone': 'phone', 'penggunaan': 'guna', 'teleponnya': 'telepon', 'free': 'free', 'brp': 'brp', 'menit': 'menit', 'aplikasi': 'aplikasi', 'telkom': 'telkom', 'provider': 'provider', 'telepon': 'telepon', 'apl': 'apl', 'gimana': 'gimana', 'donk': 'donk', 'udh': 'udh', 'ngk': 'ngk', 'koneksi': 'koneksi', 'sya': 'sya', 'pdhl': 'pdhl', 'bru': 'bru', 'alfamart': 'alfamart', 'byar': 'byar', 'lngsung': 'lngsung', 'ttp': 'ttp', 'sma': 'sma', 'respon': 'respon', 'betah': 'betah', 'terbaikk': 'terbaikk', 'nyaman': 'nyaman', 'jaringannya': 'jaring', 'alhamdulilah': 'alhamdulilah', 'gila': 'gila', 'promonya': 'promonya', 'terhormat': 'hormat', 'lakukan': 'laku', 'perbaikan': 'baik', 'modem': 'modem', 'nunggu': 'nunggu', 'besok': 'besok', 'rabu': 'rabu', 'mulu': 'mulu', 'teknisinya': 'teknisi', 'butuh': 'butuh', 'doang': 'doang', 'lahhh': 'lahhh', 'asli': 'asli', 'aneh': 'aneh', 'koneksinya': 'koneksi', 'ngebut': 'ngebut', 'dirumah': 'rumah', 'internetnya': 'internetnya', 'area': 'area', 'desa': 'desa', 'fatufia': 'fatufia', 'rusun': 'rusun', 'kurisa': 'risa', 'bahodopi': 'bahodopi', 'morowali': 'morowali', 'sulawesi': 'sulawesi', 'indonesia': 'indonesia', 'pasang': 'pasang', 'hati': 'hati', 'mengalami': 'alami', 'tertipu': 'tipu', 'kesel': 'kesel', 'sumpah': 'sumpah', 'ngeleg': 'ngeleg', 'kaga': 'kaga', 'dibales': 'dibales', 'bales': 'bales', 'kek': 'kek', 'eth': 'eth', 'mao': 'mao', 'rb': 'rb', 'niceee': 'niceee', 'nama': 'nama', 'neneng': 'neneng', 'roh ...
# ------------------------
# Pandas Apply:   0%|          | 0/219 [00:00<?, ?it/s]
#                                                   text  \
# 0                           pagi min, mau nanya boleh?
# 3    hayu berangkattttt\n\n#majuterusbersamaindihom...
# 5    halo..sudah seminggu internet saya gangguan, n...
# 6          bagaimana caranya beralih ke paket promo kk
# 7           indihome di rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425  kebutuhan kita dipenuhi indihome\n#internetnya...
# 426  teknilogi indihome emang mantul\nmakin asik be...
# 427           wah mantep gede bgt total penyimpanannya
# 428  penyimpanan yang sangat bermanfaat\n#internetn...
# 430                             ‼️min, cek dm please‼️
#
#                                          cleaning_text  \
# 0                            pagi min mau nanya boleh
# 3                                   hayu berangkattttt
# 5    halo sudah seminggu internet saya gangguan nom...
# 6               bagaimana caranya beralih paket promo
# 7              indihome rumah saya kenapa jadi los yaa
# ..                                                 ...
# 425                   kebutuhan kita dipenuhi indihome
# 426  teknilogi indihome emang mantul makin asik ber...
# 427           wah mantep gede bgt total penyimpanannya
# 428                 penyimpanan yang sangat bermanfaat
# 430                                    min cek please
#
#                                             tokenisasi  \
# 0                     [pagi, min, mau, nanya, boleh, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, sudah, seminggu, internet, saya, ganggu...
# 6        [bagaimana, caranya, beralih, paket, promo, ]
# 7      [indihome, rumah, saya, kenapa, jadi, los, yaa]
# ..                                                 ...
# 425              [kebutuhan, kita, dipenuhi, indihome]
# 426  [teknilogi, indihome, emang, mantul, makin, as...
# 427    [wah, mantep, gede, bgt, total, penyimpanannya]
# 428            [penyimpanan, yang, sangat, bermanfaat]
# 430                             [, min, cek, please, ]
#
#                                               stopword  \
# 0                                 [pagi, min, nanya, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, seminggu, internet, gangguan, nomor, ti...
# 6                            [beralih, paket, promo, ]
# 7                          [indihome, rumah, los, yaa]
# ..                                                 ...
# 425                    [kebutuhan, dipenuhi, indihome]
# 426  [teknilogi, indihome, emang, mantul, asik, ind...
# 427              [mantep, gede, total, penyimpanannya]
# 428                          [penyimpanan, bermanfaat]
# 430                             [, min, cek, please, ]
#
#                                               stemming
# 0                                 [pagi, min, nanya, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, minggu, internet, ganggu, nomor, tiket,...
# 6                               [alih, paket, promo, ]
# 7                          [indihome, rumah, los, yaa]
# ..                                                 ...
# 425                           [butuh, penuh, indihome]
# 426  [teknilogi, indihome, emang, mantul, asik, ind...
# 427                      [mantep, gede, total, simpan]
# 428                                  [simpan, manfaat]
# 430                             [, min, cek, please, ]
#
# [219 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                 [pagi, min, nanya, ]
# 3                                [hayu, berangkattttt]
# 5    [halo, minggu, internet, ganggu, nomor, tiket,...
# 6                               [alih, paket, promo, ]
# 7                          [indihome, rumah, los, yaa]
# ..                                                 ...
# 425                           [butuh, penuh, indihome]
# 426  [teknilogi, indihome, emang, mantul, asik, ind...
# 427                      [mantep, gede, total, simpan]
# 428                                  [simpan, manfaat]
# 430                             [, min, cek, please, ]
#
# [219 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_2.xlsx')
