# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0    Maaf kak mau tanya...saya kan baru pasang Indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#Ak...
# 2     50Mbps Cuma 1Mbps??? INDIHOME TERLALU BERCANDAAA
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             Halo min
# ..                                                 ...
# 127    Koneksi internet  di rumah sy mati, kenapa ya ?
# 128  Cek dm @indihomecare ,koneksi internet nya gak...
# 129  Mhn bantuannya wifi indihome lelet dan tanda seru
# 130      Mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         Cek dm kak
#
# [132 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0    Maaf kak mau tanya...saya kan baru pasang Indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#Ak...
# 2     50Mbps Cuma 1Mbps??? INDIHOME TERLALU BERCANDAAA
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             Halo min
# ..                                                 ...
# 127    Koneksi internet  di rumah sy mati, kenapa ya ?
# 128  Cek dm @indihomecare ,koneksi internet nya gak...
# 129  Mhn bantuannya wifi indihome lelet dan tanda seru
# 130      Mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         Cek dm kak
#
# [126 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0    maaf kak mau tanya...saya kan baru pasang indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#ak...
# 2     50mbps cuma 1mbps??? indihome terlalu bercandaaa
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             halo min
# ..                                                 ...
# 127    koneksi internet  di rumah sy mati, kenapa ya ?
# 128  cek dm @indihomecare ,koneksi internet nya gak...
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130      mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         cek dm kak
#
# [126 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0    maaf kak mau tanya...saya kan baru pasang indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#ak...
# 2     50mbps cuma 1mbps??? indihome terlalu bercandaaa
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             halo min
# ..                                                 ...
# 127    koneksi internet  di rumah sy mati, kenapa ya ?
# 128  cek dm @indihomecare ,koneksi internet nya gak...
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130      mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         cek dm kak
#
#                                          cleaning_text
# 0    maaf kak mau tanya saya kan baru pasang indiho...
# 1                  bener bgt makin produktif nih rumah
# 2          mbps cuma  mbps indihome terlalu bercandaaa
# 3    lancar apaan bayar tepat waktu tapi tiap masuk...
# 4                                             halo min
# ..                                                 ...
# 127                koneksi internet rumah mati kenapa
# 128    cek koneksi internet nya gak ada nih rumah saya
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130        mhn bantuannya wifinya lelet dan tanda seru
# 131                                            cek kak
#
# [126 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0    maaf kak mau tanya...saya kan baru pasang indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#ak...
# 2     50mbps cuma 1mbps??? indihome terlalu bercandaaa
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             halo min
# ..                                                 ...
# 127    koneksi internet  di rumah sy mati, kenapa ya ?
# 128  cek dm @indihomecare ,koneksi internet nya gak...
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130      mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         cek dm kak
#
#                                          cleaning_text  \
# 0    maaf kak mau tanya saya kan baru pasang indiho...
# 1                  bener bgt makin produktif nih rumah
# 2          mbps cuma  mbps indihome terlalu bercandaaa
# 3    lancar apaan bayar tepat waktu tapi tiap masuk...
# 4                                             halo min
# ..                                                 ...
# 127                koneksi internet rumah mati kenapa
# 128    cek koneksi internet nya gak ada nih rumah saya
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130        mhn bantuannya wifinya lelet dan tanda seru
# 131                                            cek kak
#
#                                             tokenisasi
# 0    [maaf, kak, mau, tanya, saya, kan, baru, pasan...
# 1           [bener, bgt, makin, produktif, nih, rumah]
# 2    [, mbps, cuma, mbps, indihome, terlalu, bercan...
# 3    [lancar, apaan, bayar, tepat, waktu, tapi, tia...
# 4                                          [halo, min]
# ..                                                 ...
# 127         [koneksi, internet, rumah, mati, kenapa, ]
# 128  [cek, koneksi, internet, nya, gak, ada, nih, r...
# 129  [mhn, bantuannya, wifi, indihome, lelet, dan, ...
# 130  [mhn, bantuannya, wifinya, lelet, dan, tanda, ...
# 131                                         [cek, kak]
#
# [126 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0    maaf kak mau tanya...saya kan baru pasang indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#ak...
# 2     50mbps cuma 1mbps??? indihome terlalu bercandaaa
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             halo min
# ..                                                 ...
# 127    koneksi internet  di rumah sy mati, kenapa ya ?
# 128  cek dm @indihomecare ,koneksi internet nya gak...
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130      mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         cek dm kak
#
#                                          cleaning_text  \
# 0    maaf kak mau tanya saya kan baru pasang indiho...
# 1                  bener bgt makin produktif nih rumah
# 2          mbps cuma  mbps indihome terlalu bercandaaa
# 3    lancar apaan bayar tepat waktu tapi tiap masuk...
# 4                                             halo min
# ..                                                 ...
# 127                koneksi internet rumah mati kenapa
# 128    cek koneksi internet nya gak ada nih rumah saya
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130        mhn bantuannya wifinya lelet dan tanda seru
# 131                                            cek kak
#
#                                             tokenisasi  \
# 0    [maaf, kak, mau, tanya, saya, kan, baru, pasan...
# 1           [bener, bgt, makin, produktif, nih, rumah]
# 2    [, mbps, cuma, mbps, indihome, terlalu, bercan...
# 3    [lancar, apaan, bayar, tepat, waktu, tapi, tia...
# 4                                          [halo, min]
# ..                                                 ...
# 127         [koneksi, internet, rumah, mati, kenapa, ]
# 128  [cek, koneksi, internet, nya, gak, ada, nih, r...
# 129  [mhn, bantuannya, wifi, indihome, lelet, dan, ...
# 130  [mhn, bantuannya, wifinya, lelet, dan, tanda, ...
# 131                                         [cek, kak]
#
#                                               stopword
# 0    [maaf, kak, pasang, indihome, paket, digital, ...
# 1                            [bener, produktif, rumah]
# 2                 [, mbps, mbps, indihome, bercandaaa]
# 3    [lancar, bayar, masuk, tanggal, pembayaran, le...
# 4                                          [halo, min]
# ..                                                 ...
# 127                 [koneksi, internet, rumah, mati, ]
# 128                    [cek, koneksi, internet, rumah]
# 129  [mhn, bantuannya, wifi, indihome, lelet, tanda...
# 130     [mhn, bantuannya, wifinya, lelet, tanda, seru]
# 131                                         [cek, kak]
#
# [126 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 401
# ------------------------
# maaf : maaf
# kak : kak
# pasang : pasang
# indihome : indihome
# paket : paket
# digital : digital
# channel : channel
# maksudnya : maksud
# smart : smart
# adik : adik
# kasih : kasih
# alat : alat
# penghubung : hubung
# trima : trima
# sblmnya : sblmnya
# bener : bener
# produktif : produktif
# rumah : rumah
#  :
# mbps : mbps
# bercandaaa : bercandaaa
# lancar : lancar
# bayar : bayar
# masuk : masuk
# tanggal : tanggal
# pembayaran : bayar
# lemot : lot
# laporan : lapor
# aplikasi : aplikasi
# eror : eror
# jaringan : jaring
# internet : internet
# keluhan : keluh
# kemana : mana
# respon : respon
# rugi : rugi
# pakek : pakek
# gini : gin
# halo : halo
# min : min
# tips : tips
# bermutu : mutu
# mudah : mudah
# hali : hal
# login : login
# gmn : gmn
# yuk : yuk
# kuda : kuda
# gangguan : ganggu
# kerja : kerja
# kaga : kaga
# cuman : cuman
# maen : maen
# zuma : zuma
# nice : nice
# info : info
# upgrade : upgrade
# speed : speed
# mimin : mimin
# suka : suka
# panik : panik
# inet : inet
# lambat : lambat
# langsung : langsung
# lapor : lapor
# csnya : csnya
# cpt : cpt
# ditangani : tangan
# modem : modem
# diletakkan : letak
# posisi : posisi
# berjauhan : jauh
# cek : cek
# tolong : tolong
# balas : balas
# buka : buka
# woy : woy
# baca : baca
# bantu : bantu
# sekolahan : sekolah
# pemasangan : pasang
# udh : udh
# kmarin : kmarin
# sya : sya
# tiket : tiket
# in : in
# sampe : sampe
# skrg : skrg
# blm : blm
# tindak : tindak
# segerakan : segera
# please : please
# makasih : makasih
# yaa : yaa
# normal : normal
# mohon : mohon
# bls : bls
# dmku : dmku
# mengatasinya : atas
# lag : lag
# tros : tros
# udah : udah
# dibenerin : dibenerin
# bolak : bolak
# tagihan : tagih
# sesuai : sesuai
# tarif : tarif
# diperjanjikan : janji
# kelebihan : lebih
# complain : complain
# koreksi : koreksi
# jutaan : juta
# pelanggan : langgan
# diperlakukan : laku
# milyar : milyar
# bulannya : bulan
# pendapatan : dapat
# sah : sah
# dikumpulkan : kumpul
# telkom : telkom
# informasinya : informasi
# fungsi : fungsi
# hayu : hayu
# praktis : praktis
# banget : banget
# gampang : gampang
# oke : oke
# mensolusikan : solusi
# gampil : gampil
# langkah : langkah
# jelek : jelek
# koneksinya : koneksi
# recommended : recommended
# menyerah : serah
# ganti : ganti
# murah : murah
# mahal : mahal
# mati : mati
# knp : knp
# telpon : telpon
# dikenakan : kena
# standar : standar
# bakomen : bakomen
# post : post
# komen : komen
# dmnya : dmnya
# cocok : cocok
# nagian : nagian
# inbox : inbox
# lemut : lut
# data : data
# tinggalkan : tinggal
# refresh : refresh
# tunggu : tunggu
# download : download
# myindihome : myindihome
# dimana : mana
# naissssss : naissssss
# inpoh : inpoh
# tipsnya : tipsnya
# ampuhhhh : ampuhhhh
# napa : napa
# main : main
# mobile : mobile
# legend : legend
# gapernah : gapernah
# kereeen : kereeen
# hallo : hallo
# tolongin : tolongin
# wifi : wifi
# bocor : bocor
# curi : curi
# orang : orang
# pelindung : lindung
# blokir : blokir
# perangkat : perangkat
# nyuri : nyuri
# bermanfaat : manfaat
# maksud : maksud
# game : game
# alatnya : alat
# gimana : gimana
# penjelasannya : jelas
# diperjelaa : diperjelaa
# mengganggu : ganggu
# bisnis : bisnis
# bacot : bacot
# nagih : nagih
# jalan : jalan
# iya : iya
# wifinya : wifinya
# sinyal : sinyal
# disalahin : disalahin
# belom : bom
# ngelag : ngelag
# parah : parah
# paralel : paralel
# total : total
# dibagi : bagi
# ngga : ngga
# woi : woi
# taunya : tau
# meet : meet
# kau : kau
# enak : enak
# blh : blh
# cri : cri
# rejeki : rejeki
# tpi : tpi
# jan : jan
# halangi : halang
# bsa : bsa
# masio : masio
# modemku : modem
# podo : podo
# dasar : dasar
# layananmu : layan
# biyen : biyen
# kecewa : kecewa
# pelayanan : layan
# tlp : tlp
# ngangkat : ngangkat
# bertele : tele
# tele : tele
# kedipan : kedip
# merah : merah
# cepet : cepet
# terealisasikan : realisasi
# butuh : butuh
# kelass : kelass
# inii : ini
# tinggal : tinggal
# minggu : minggu
# telat : telat
# nyala : nyala
# resiper : resiper
# laporanya : laporanya
# bangsat : bangsat
# moga : moga
# putus : putus
# lemburan : lembur
# kompensasi : kompensasi
# jelass : jelass
# gratis : gratis
# all : all
# doang : doang
# ambil : ambil
# angin : angin
# kali : kali
# semangat : semangat
# hebat : hebat
# kemarin : kemarin
# sore : sore
# lampu : lampu
# modemnya : modem
# tetangga : tetangga
# kawan : kawan
# maju : maju
# konek : konek
# oppo : oppo
# vivo : vivo
# samsung : samsung
# merk : merk
# nyambung : nyambung
# ngaduin : ngaduin
# terhubung : hubung
# pdhl : pdhl
# nggak : nggak
# solusi : solusi
# yup : yup
# siang : siang
# website : website
# terkena : kena
# positif : positif
# layanan : layan
# telkomsel : telkomsel
# citranet : citranet
# terblokir : blokir
# foto : foto
# twitter : twitter
# link : link
# lockerz : lockerz
# com : com
# penasaran : penasaran
# saran : saran
# terima : terima
# biaya : biaya
# nonton : nonton
# film : film
# iptv : iptv
# alhamdulillah : alhamdulillah
# kmrn : kmrn
# terang : terang
# deh : deh
# kinerja : kerja
# binun : bun
# stlh : stlh
# hujan : hujan
# badai : badai
# september : september
# depok : depok
# kabel : kabel
# telp : telp
# diganti : ganti
# rmh : rmh
# bbrp : bbrp
# stlhnya : stlhnya
# onoff : onoff
# laporkan : lapor
# malam : malam
# kumat : kumat
# bermasalah : masalah
# plissss : plissss
# dirawat : rawat
# bagus : bagus
# awet : awet
# puas : puas
# hnya : hnya
# ngejar : ngejar
# kuantitas : kuantitas
# nyaman : nyaman
# daerah : daerah
# cililin : cililin
# kzll : kzll
# sumpah : sumpah
# mahall : mahall
# mulu : mulu
# terimakasih : terimakasih
# cepat : cepat
# tangap : tangap
# salut : salut
# yessss : yessss
# betah : betah
# hey : hey
# bales : bales
# hbo : hbo
# katasandi : katasandi
# pdhal : pdhal
# paswordnya : paswordnya
# terisolir : isolir
# ngeleg : ngeleg
# bet : bet
# seamless : seamless
# maksimal : maksimal
# device : device
# pembohong : bohong
# janji : janji
# free : free
# channelnya : channelnya
# balasss : balasss
# anying : anying
# plis : plis
# phk : phk
# teros : ros
# jaringannya : jaring
# menggokil : menggokil
# nambah : nambah
# efeknya : efek
# buang : buang
# uang : uang
# helpppl : helpppl
# thx : thx
# banjarmasin : banjarmasin
# stabil : stabil
# blum : blum
# perbaikan : baik
# berkali : kali
# disuruh : suruh
# ngasih : ngasih
# dibales : dibales
# penipu : tipu
# hrg : hrg
# dunk : dunk
# rumaj : rumaj
# kah : kah
# kerenn : kerenn
# petugas : tugas
# datag : datag
# cmaera : cmaera
# selamat : selamat
# perkemarin : kemarin
# copot : copot
# cape : cape
# harganya : harga
# kena : kena
# denda : denda
# problem : problem
# bermasalh : bermasalh
# mengalami : alami
# ganguan : ganguan
# privadi : privadi
# isi : isi
# secepat : cepat
# gue : gue
# tlg : tlg
# koneksi : koneksi
# mhn : mhn
# bantuannya : bantu
# lelet : lelet
# tanda : tanda
# seru : seru
# {'maaf': 'maaf', 'kak': 'kak', 'pasang': 'pasang', 'indihome': 'indihome', 'paket': 'paket', 'digital': 'digital', 'channel': 'channel', 'maksudnya': 'maksud', 'smart': 'smart', 'adik': 'adik', 'kasih': 'kasih', 'alat': 'alat', 'penghubung': 'hubung', 'trima': 'trima', 'sblmnya': 'sblmnya', 'bener': 'bener', 'produktif': 'produktif', 'rumah': 'rumah', '': '', 'mbps': 'mbps', 'bercandaaa': 'bercandaaa', 'lancar': 'lancar', 'bayar': 'bayar', 'masuk': 'masuk', 'tanggal': 'tanggal', 'pembayaran': 'bayar', 'lemot': 'lot', 'laporan': 'lapor', 'aplikasi': 'aplikasi', 'eror': 'eror', 'jaringan': 'jaring', 'internet': 'internet', 'keluhan': 'keluh', 'kemana': 'mana', 'respon': 'respon', 'rugi': 'rugi', 'pakek': 'pakek', 'gini': 'gin', 'halo': 'halo', 'min': 'min', 'tips': 'tips', 'bermutu': 'mutu', 'mudah': 'mudah', 'hali': 'hal', 'login': 'login', 'gmn': 'gmn', 'yuk': 'yuk', 'kuda': 'kuda', 'gangguan': 'ganggu', 'kerja': 'kerja', 'kaga': 'kaga', 'cuman': 'cuman', 'maen': 'maen', 'zuma': 'zuma', 'nice': 'nice', 'info': 'info', 'upgrade': 'upgrade', 'speed': 'speed', 'mimin': 'mimin', 'suka': 'suka', 'panik': 'panik', 'inet': 'inet', 'lambat': 'lambat', 'langsung': 'langsung', 'lapor': 'lapor', 'csnya': 'csnya', 'cpt': 'cpt', 'ditangani': 'tangan', 'modem': 'modem', 'diletakkan': 'letak', 'posisi': 'posisi', 'berjauhan': 'jauh', 'cek': 'cek', 'tolong': 'tolong', 'balas': 'balas', 'buka': 'buka', 'woy': 'woy', 'baca': 'baca', 'bantu': 'bantu', 'sekolahan': 'sekolah', 'pemasangan': 'pasang', 'udh': 'udh', 'kmarin': 'kmarin', 'sya': 'sya', 'tiket': 'tiket', 'in': 'in', 'sampe': 'sampe', 'skrg': 'skrg', 'blm': 'blm', 'tindak': 'tindak', 'segerakan': 'segera', 'please': 'please', 'makasih': 'makasih', 'yaa': 'yaa', 'normal': 'normal', 'mohon': 'mohon', 'bls': 'bls', 'dmku': 'dmku', 'mengatasinya': 'atas', 'lag': 'lag', 'tros': 'tros', 'udah': 'udah', 'dibenerin': 'dibenerin', 'bolak': 'bolak', 'tagihan': 'tagih', 'sesuai': 'sesuai', 'tarif': 'tarif', 'diperjanjikan': 'janji', 'kelebihan': 'lebih', 'complain': 'complain', 'koreksi': 'koreksi', 'jutaan': 'juta', 'pelanggan': 'langgan', 'diperlakukan': 'laku', 'milyar': 'milyar', 'bulannya': 'bulan', 'pendapatan': 'dapat', 'sah': 'sah', 'dikumpulkan': 'kumpul', 'telkom': 'telkom', 'informasinya': 'informasi', 'fungsi': 'fungsi', 'hayu': 'hayu', 'praktis': 'praktis', 'banget': 'banget', 'gampang': 'gampang', 'oke': 'oke', 'mensolusikan': 'solusi', 'gampil': 'gampil', 'langkah': 'langkah', 'jelek': 'jelek', 'koneksinya': 'koneksi', 'recommended': 'recommended', 'menyerah': 'serah', 'ganti': 'ganti', 'murah': 'murah', 'mahal': 'mahal', 'mati': 'mati', 'knp': 'knp', 'telpon': 'telpon', 'dikenakan': 'kena', 'standar': 'standar', 'bakomen': 'bakomen', 'post': 'post', 'komen': 'komen', 'dmnya': 'dmnya', 'cocok': 'cocok', 'nagian': 'nagian', 'inbox': 'inbox', 'lemut': 'lut', 'data': 'data', 'tinggalkan': 'tinggal', 'refresh': 'refresh', 'tunggu': 'tunggu', 'download': 'download', 'myindihome': 'myindihome', 'dimana': 'mana', 'naissssss': 'naissssss', 'inpoh': 'inpoh', 'tipsnya': 'tipsnya', 'ampuhhhh': 'ampuhhhh', 'napa': 'napa', 'main': 'main', 'mobile': 'mobile', 'legend': 'legend', 'gapernah': 'gapernah', 'kereeen': 'kereeen', 'hallo': 'hallo', 'tolongin': 'tolongin', 'wifi': 'wifi', 'bocor': 'bocor', 'curi': 'curi', 'orang': 'orang', 'pelindung': 'lindung', 'blokir': 'blokir', 'perangkat': 'perangkat', 'nyuri': 'nyuri', 'bermanfaat': 'manfaat', 'maksud': 'maksud', 'game': 'game', 'alatnya': 'alat', 'gimana': 'gimana', 'penjelasannya': 'jelas', 'diperjelaa': 'diperjelaa', 'mengganggu': 'ganggu', 'bisnis': 'bisnis', 'bacot': 'bacot', 'nagih': 'nagih', 'jalan': 'jalan', 'iya': 'iya', 'wifinya': 'wifinya', 'sinyal': 'sinyal', 'disalahin': 'disalahin', 'belom': 'bom', 'ngelag': 'ngelag', 'parah': 'parah', 'paralel': 'paralel', 'total': 'total', 'dibagi': 'bagi', 'ngga': 'ngga', 'woi': 'woi', 'taunya': 'tau', 'meet': 'meet', 'kau': 'kau', 'enak': 'enak', 'blh': 'blh', 'cri': 'cri', 'rejeki': 'rejeki', 'tp ...
# ------------------------
# Pandas Apply:   0%|          | 0/126 [00:00<?, ?it/s]
#                                                   text  \
# 0    maaf kak mau tanya...saya kan baru pasang indi...
# 1    bener bgt, makin produktif nih di rumah\n\n#ak...
# 2     50mbps cuma 1mbps??? indihome terlalu bercandaaa
# 3    lancar apaan, bayar tepat waktu tapi tiap masu...
# 4                                             halo min
# ..                                                 ...
# 127    koneksi internet  di rumah sy mati, kenapa ya ?
# 128  cek dm @indihomecare ,koneksi internet nya gak...
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130      mhn bantuannya , wifinya lelet dan tanda seru
# 131                                         cek dm kak
#
#                                          cleaning_text  \
# 0    maaf kak mau tanya saya kan baru pasang indiho...
# 1                  bener bgt makin produktif nih rumah
# 2          mbps cuma  mbps indihome terlalu bercandaaa
# 3    lancar apaan bayar tepat waktu tapi tiap masuk...
# 4                                             halo min
# ..                                                 ...
# 127                koneksi internet rumah mati kenapa
# 128    cek koneksi internet nya gak ada nih rumah saya
# 129  mhn bantuannya wifi indihome lelet dan tanda seru
# 130        mhn bantuannya wifinya lelet dan tanda seru
# 131                                            cek kak
#
#                                             tokenisasi  \
# 0    [maaf, kak, mau, tanya, saya, kan, baru, pasan...
# 1           [bener, bgt, makin, produktif, nih, rumah]
# 2    [, mbps, cuma, mbps, indihome, terlalu, bercan...
# 3    [lancar, apaan, bayar, tepat, waktu, tapi, tia...
# 4                                          [halo, min]
# ..                                                 ...
# 127         [koneksi, internet, rumah, mati, kenapa, ]
# 128  [cek, koneksi, internet, nya, gak, ada, nih, r...
# 129  [mhn, bantuannya, wifi, indihome, lelet, dan, ...
# 130  [mhn, bantuannya, wifinya, lelet, dan, tanda, ...
# 131                                         [cek, kak]
#
#                                               stopword  \
# 0    [maaf, kak, pasang, indihome, paket, digital, ...
# 1                            [bener, produktif, rumah]
# 2                 [, mbps, mbps, indihome, bercandaaa]
# 3    [lancar, bayar, masuk, tanggal, pembayaran, le...
# 4                                          [halo, min]
# ..                                                 ...
# 127                 [koneksi, internet, rumah, mati, ]
# 128                    [cek, koneksi, internet, rumah]
# 129  [mhn, bantuannya, wifi, indihome, lelet, tanda...
# 130     [mhn, bantuannya, wifinya, lelet, tanda, seru]
# 131                                         [cek, kak]
#
#                                               stemming
# 0    [maaf, kak, pasang, indihome, paket, digital, ...
# 1                            [bener, produktif, rumah]
# 2                 [, mbps, mbps, indihome, bercandaaa]
# 3    [lancar, bayar, masuk, tanggal, bayar, lot, la...
# 4                                          [halo, min]
# ..                                                 ...
# 127                 [koneksi, internet, rumah, mati, ]
# 128                    [cek, koneksi, internet, rumah]
# 129   [mhn, bantu, wifi, indihome, lelet, tanda, seru]
# 130          [mhn, bantu, wifinya, lelet, tanda, seru]
# 131                                         [cek, kak]
#
# [126 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [maaf, kak, pasang, indihome, paket, digital, ...
# 1                            [bener, produktif, rumah]
# 2                 [, mbps, mbps, indihome, bercandaaa]
# 3    [lancar, bayar, masuk, tanggal, bayar, lot, la...
# 4                                          [halo, min]
# ..                                                 ...
# 127                 [koneksi, internet, rumah, mati, ]
# 128                    [cek, koneksi, internet, rumah]
# 129   [mhn, bantu, wifi, indihome, lelet, tanda, seru]
# 130          [mhn, bantu, wifinya, lelet, tanda, seru]
# 131                                         [cek, kak]
#
# [126 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_9.xlsx')
