# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0    sering banget bagi-bagi, luar biasaaa\n\n#Akti...
# 1           #aktivitastanpabatas #InternetnyaIndonesia
# 2    Poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    Tolong min cek DM
# ..                                                 ...
# 145  Baik Min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  Wifi dirumah saya kok kedap kedip ya lampu LOS...
# 148          Terimkasih min, konten yg sangat membantu
# 149               Kapan F1 bisa dinikmati di indihome?
#
# [150 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0    sering banget bagi-bagi, luar biasaaa\n\n#Akti...
# 1           #aktivitastanpabatas #InternetnyaIndonesia
# 2    Poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    Tolong min cek DM
# ..                                                 ...
# 145  Baik Min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  Wifi dirumah saya kok kedap kedip ya lampu LOS...
# 148          Terimkasih min, konten yg sangat membantu
# 149               Kapan F1 bisa dinikmati di indihome?
#
# [139 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0    sering banget bagi-bagi, luar biasaaa\n\n#akti...
# 1           #aktivitastanpabatas #internetnyaindonesia
# 2    poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    tolong min cek dm
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  wifi dirumah saya kok kedap kedip ya lampu los...
# 148          terimkasih min, konten yg sangat membantu
# 149               kapan f1 bisa dinikmati di indihome?
#
# [139 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0    sering banget bagi-bagi, luar biasaaa\n\n#akti...
# 1           #aktivitastanpabatas #internetnyaindonesia
# 2    poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    tolong min cek dm
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  wifi dirumah saya kok kedap kedip ya lampu los...
# 148          terimkasih min, konten yg sangat membantu
# 149               kapan f1 bisa dinikmati di indihome?
#
#                                          cleaning_text
# 0                 sering banget bagi bagi luar biasaaa
# 1
# 2    poin saya ada   min bisa tukar plaza mana aja ...
# 3    suka bgt kalo banyak penukaran voucher dari me...
# 4                                      tolong min cek
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146     channel fox sport sudah gak lagi nya indihome
# 147  wifi dirumah saya kok kedap kedip lampu los ny...
# 148              terimkasih min konten sangat membantu
# 149                     kapan bisa dinikmati indihome
#
# [139 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0    sering banget bagi-bagi, luar biasaaa\n\n#akti...
# 1           #aktivitastanpabatas #internetnyaindonesia
# 2    poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    tolong min cek dm
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  wifi dirumah saya kok kedap kedip ya lampu los...
# 148          terimkasih min, konten yg sangat membantu
# 149               kapan f1 bisa dinikmati di indihome?
#
#                                          cleaning_text  \
# 0                 sering banget bagi bagi luar biasaaa
# 1
# 2    poin saya ada   min bisa tukar plaza mana aja ...
# 3    suka bgt kalo banyak penukaran voucher dari me...
# 4                                      tolong min cek
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146     channel fox sport sudah gak lagi nya indihome
# 147  wifi dirumah saya kok kedap kedip lampu los ny...
# 148              terimkasih min konten sangat membantu
# 149                     kapan bisa dinikmati indihome
#
#                                             tokenisasi
# 0          [sering, banget, bagi, bagi, luar, biasaaa]
# 1                                                   []
# 2    [poin, saya, ada, min, bisa, tukar, plaza, man...
# 3    [suka, bgt, kalo, banyak, penukaran, voucher, ...
# 4                                 [tolong, min, cek, ]
# ..                                                 ...
# 145  [baik, min, terima, kasih, banyak, informasiny...
# 146  [channel, fox, sport, sudah, gak, lagi, nya, i...
# 147  [wifi, dirumah, saya, kok, kedap, kedip, lampu...
# 148        [terimkasih, min, konten, sangat, membantu]
# 149               [kapan, bisa, dinikmati, indihome, ]
#
# [139 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0    sering banget bagi-bagi, luar biasaaa\n\n#akti...
# 1           #aktivitastanpabatas #internetnyaindonesia
# 2    poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    tolong min cek dm
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  wifi dirumah saya kok kedap kedip ya lampu los...
# 148          terimkasih min, konten yg sangat membantu
# 149               kapan f1 bisa dinikmati di indihome?
#
#                                          cleaning_text  \
# 0                 sering banget bagi bagi luar biasaaa
# 1
# 2    poin saya ada   min bisa tukar plaza mana aja ...
# 3    suka bgt kalo banyak penukaran voucher dari me...
# 4                                      tolong min cek
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146     channel fox sport sudah gak lagi nya indihome
# 147  wifi dirumah saya kok kedap kedip lampu los ny...
# 148              terimkasih min konten sangat membantu
# 149                     kapan bisa dinikmati indihome
#
#                                             tokenisasi  \
# 0          [sering, banget, bagi, bagi, luar, biasaaa]
# 1                                                   []
# 2    [poin, saya, ada, min, bisa, tukar, plaza, man...
# 3    [suka, bgt, kalo, banyak, penukaran, voucher, ...
# 4                                 [tolong, min, cek, ]
# ..                                                 ...
# 145  [baik, min, terima, kasih, banyak, informasiny...
# 146  [channel, fox, sport, sudah, gak, lagi, nya, i...
# 147  [wifi, dirumah, saya, kok, kedap, kedip, lampu...
# 148        [terimkasih, min, konten, sangat, membantu]
# 149               [kapan, bisa, dinikmati, indihome, ]
#
#                                               stopword
# 0                                    [banget, biasaaa]
# 1                                                   []
# 2                     [poin, min, tukar, plaza, min, ]
# 3                 [suka, penukaran, voucher, merchant]
# 4                                 [tolong, min, cek, ]
# ..                                                 ...
# 145        [min, terima, kasih, informasinya, berguna]
# 146                  [channel, fox, sport, indihome, ]
# 147  [wifi, dirumah, kedap, kedip, lampu, los, kone...
# 148                [terimkasih, min, konten, membantu]
# 149                            [dinikmati, indihome, ]
#
# [139 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 409
# ------------------------
# banget : banget
# biasaaa : biasaaa
#  :
# poin : poin
# min : min
# tukar : tukar
# plaza : plaza
# suka : suka
# penukaran : tukar
# voucher : voucher
# merchant : merchant
# tolong : tolong
# cek : cek
# yukk : yukk
# kumpulin : kumpulin
# wifi : wifi
# connect : connect
# kartini : kartini
# depok : depok
# kmrn : kmrn
# udh : udh
# normal : normal
# skrg : skrg
# gini : gin
# pelayanannya : layan
# buruk : buruk
# ngumpulin : ngumpulin
# point : point
# dapet : dapet
# diskon : diskon
# mah : mah
# indihomo : indihomo
# ajg : ajg
# tlg : tlg
# gantiin : gantiin
# password : password
# nggk : nggk
# ganti : ganti
# dicoba : coba
# baca : baca
# please : please
# yesss : yesss
# mandiri : mandiri
# bisaa : bisaa
# mohon : mohon
# dibantu : bantu
# mengganti : ganti
# donk : donk
# ketik : ketik
# gagal : gagal
# membuka : buka
# alamat : alamat
# website : website
# terhubung : hubung
# makasih : makasih
# tips : tips
# laporan : lapor
# warga : warga
# pemindahan : pindah
# tiang : tiang
# indihome : indihome
# sembrawut : sembrawut
# tangani : tangan
# nancap : nancap
# kak : kak
# mantulbgt : mantulbgt
# tetangga : tetangga
# gmn : gmn
# admin : admin
# nggak : nggak
# ubah : ubah
# gerai : gerai
# telkom : telkom
# stok : stok
# produknya : produk
# patuhi : patuh
# protokol : protokol
# mantappp : mantappp
# jaringan : jaring
# loding : loding
# perpanjang : panjang
# kabel : kabel
# masang : masang
# teknisinya : teknisi
# butuh : butuh
# cepat : cepat
# penuh : penuh
# solusiny : solusiny
# internet : internet
# not : not
# available : available
# simbol : simbol
# wifinya : wifinya
# tanda : tanda
# seru : seru
# panik : panik
# crosscheck : crosscheck
# udah : udah
# bayar : bayar
# tagihan : tagih
# kemarin : kemarin
# kebiasaan : biasa
# komplen : komplen
# gangguan : ganggu
# teknisi : teknisi
# blm : blm
# dateng : dateng
# kerumah : rumah
# tracker : tracker
# system : system
# bilangnya : bilang
# selesai : selesai
# restat : restat
# modem : modem
# tetep : tetep
# aman : aman
# yaa : yaa
# masker : masker
# saudara : saudara
# berhenti : henti
# berlangganan : langgan
# kantor : kantor
# telp : telp
# menagih : tagih
# biaya : biaya
# bulanan : bulan
# kembalikan : kembali
# deposit : deposit
# meleduk : leduk
# pengaduan : adu
# dak : dak
# penanganan : tangan
# koneksi : koneksi
# nyala : nyala
# doang : doang
# tanggal : tanggal
# bales : bales
# tae : tae
# sembarangan : sembarang
# tancap : tancap
# ijin : ijin
# tanah : tanah
# kusus : sus
# untung : untung
# coba : coba
# brifing : brifing
# anak : anak
# buahnya : buah
# oknum : oknum
# uang : uang
# pelanggan : langgan
# jera : jera
# renew : renew
# speed : speed
# diaplikasi : aplikasi
# terbaru : baru
# kelebihan : lebih
# info : info
# nihh : nihh
# lag : lag
# rumah : rumah
# dibangun : bangun
# cuti : cuti
# seamless : seamless
# maksimal : maksimal
# device : device
# mati : mati
# los : los
# merah : merah
# diperbaiki : baik
# thankyou : thankyou
# halo : halo
# permintaan : minta
# upgrade : upgrade
# mini : mini
# package : package
# dpt : dpt
# pemberitahuan : pemberitahuan
# aktif : aktif
# channelx : channelx
# smbil : smbil
# internetx : internetx
# low : low
# useetv : useetv
# sinyal : sinyal
# mulu : mulu
# kemaren : kemaren
# perasaan : asa
# telat : telat
# trus : trus
# lur : lur
# provider : provider
# burik : burik
# kualitas : kualitas
# harga : harga
# mahal : mahal
# kasi : kasi
# bintang : bintang
# bosen : bosen
# komplain : komplain
# hah : hah
# lampu : lampu
# internetnya : internetnya
# giliran : gilir
# cabut : cabut
# extender : extender
# via : via
# email : email
# detik : detik
# masuk : masuk
# rbu : rbu
# sebanding : banding
# turunin : turunin
# gkk : gkk
# sesuai : sesuai
# byr : byr
# gamgguan : gamgguan
# ngga : ngga
# ditanggapin : ditanggapin
# telpon : telpon
# msh : msh
# parah : parah
# indinhome : indinhome
# ilang : ilang
# lemot : lot
# mantep : mantep
# ingetin : ingetin
# nagih : nagih
# inget : inget
# kewjiban : kewjiban
# customer : customer
# error : error
# trs : trs
# pembayaran : bayar
# gimana : gimana
# minn : minn
# terputuss : terputuss
# sampek : sampek
# tanggapan : tanggap
# ksana : ksana
# besok : besok
# mnunggu : mnunggu
# praktis : praktis
# pokoknya : pokok
# aplikasi : aplikasi
# pasang : pasang
# ngk : ngk
# login : login
# bhaimana : bhaimana
# solusinya : solusi
# membantu : bantu
# myindihome : myindihome
# lancar : lancar
# terima : terima
# layanan : layan
# program : program
# persatu : satu
# hilang : hilang
# wihhh : wihhh
# keren : keren
# infonya : info
# nice : nice
# allah : allah
# dibenerin : dibenerin
# lagiiiii : lagiiiii
# maunya : mau
# yaaa : yaaa
# minbedanya : minbedanya
# paket : paket
# gamer : gamer
# reguler : reguler
# minggu : minggu
# respon : respon
# ngelag : ngelag
# keras : keras
# semenjak : semenjak
# pakai : pakai
# bener : bener
# kenceng : kenceng
# jaringannya : jaring
# diselesaikan : selesai
# pack : pack
# sudh : sudh
# kirim : kirim
# code : code
# eror : eror
# tindak : tindak
# lanjuti : lanjut
# ngebut : ngebut
# gakan : gakan
# muter : muter
# muterrr : muterrr
# cekndm : cekndm
# dem : dem
# gimik : gimik
# sok : sok
# sokan : sok
# joke : joke
# inet : inet
# all : all
# lola : lola
# malam : malam
# siang : siang
# lelet : lelet
# macet : macet
# mohonrespon : mohonrespon
# tindakan : tindak
# langsung : langsung
# lokasi : lokasi
# ehe : ehe
# bijimane : bijimane
# byk : byk
# duit : duit
# berkelanjutan : lanjut
# box : box
# netflix : netflix
# pemasangan : pasang
# berpungsi : pungsi
# dalian : dalian
# bayuran : bayur
# jarak : jarak
# memasang : pasang
# titik : titik
# odp : odp
# meter : meter
# tdi : tdi
# tpi : tpi
# balasan : balas
# suruh : suruh
# tunggu : tunggu
# tgl : tgl
# hmpir : hmpir
# brarti : brarti
# lapor : lapor
# mngkin : mngkin
# blum : blum
# tnggal : tnggal
# tempo : tempo
# memperluas : luas
# jangkuan : jangkuan
# jdi : jdi
# manteppp : manteppp
# ampuh : ampuh
# cuy : cuy
# loss : loss
# ribu : ribu
# sebulan : bulan
# indihomecare : indihomecare
# gila : gila
# smp : smp
# total : total
# seminggu : minggu
# enak : enak
# nyuruhnya : nyuruhnya
# daon : daon
# plis : plis
# bantu : bantu
# pliska : pliska
# dibayar : bayar
# diisolir : isolir
# balas : balas
# bbrp : bbrp
# channel : channel
# diatas : atas
# jam : jam
# sore : sore
# tampilan : tampil
# audio : audio
# video : video
# putus : putus
# pagi : pagi
# sampe : sampe
# sblm : sblm
# mulus : mulus
# work : work
# thanks : thanks
# pas : pas
# kendala : kendala
# dialamin : alamin
# thx : thx
# sip : sip
# tipsnya : tipsnya
# bermanfaat : manfaat
# infonyaa : infonyaa
# manjur : manjur
# langkahnyaa : langkahnyaa
# informasinya : informasi
# terimakasih : terimakasih
# berguna : guna
# kasih : kasih
# kerenn : kerenn
# panduannya : pandu
# okeh : okeh
# informasi : informasi
# bagus : bagus
# jaga : jaga
# konten : konten
# ngeliat : ngeliat
# akun : akun
# ngasih : ngasih
# solusi : solusi
# fox : fox
# sport : sport
# dirumah : rumah
# kedap : kedap
# kedip : kedip
# koneksinya : koneksi
# terimkasih : terimkasih
# dinikmati : nikmat
# {'banget': 'banget', 'biasaaa': 'biasaaa', '': '', 'poin': 'poin', 'min': 'min', 'tukar': 'tukar', 'plaza': 'plaza', 'suka': 'suka', 'penukaran': 'tukar', 'voucher': 'voucher', 'merchant': 'merchant', 'tolong': 'tolong', 'cek': 'cek', 'yukk': 'yukk', 'kumpulin': 'kumpulin', 'wifi': 'wifi', 'connect': 'connect', 'kartini': 'kartini', 'depok': 'depok', 'kmrn': 'kmrn', 'udh': 'udh', 'normal': 'normal', 'skrg': 'skrg', 'gini': 'gin', 'pelayanannya': 'layan', 'buruk': 'buruk', 'ngumpulin': 'ngumpulin', 'point': 'point', 'dapet': 'dapet', 'diskon': 'diskon', 'mah': 'mah', 'indihomo': 'indihomo', 'ajg': 'ajg', 'tlg': 'tlg', 'gantiin': 'gantiin', 'password': 'password', 'nggk': 'nggk', 'ganti': 'ganti', 'dicoba': 'coba', 'baca': 'baca', 'please': 'please', 'yesss': 'yesss', 'mandiri': 'mandiri', 'bisaa': 'bisaa', 'mohon': 'mohon', 'dibantu': 'bantu', 'mengganti': 'ganti', 'donk': 'donk', 'ketik': 'ketik', 'gagal': 'gagal', 'membuka': 'buka', 'alamat': 'alamat', 'website': 'website', 'terhubung': 'hubung', 'makasih': 'makasih', 'tips': 'tips', 'laporan': 'lapor', 'warga': 'warga', 'pemindahan': 'pindah', 'tiang': 'tiang', 'indihome': 'indihome', 'sembrawut': 'sembrawut', 'tangani': 'tangan', 'nancap': 'nancap', 'kak': 'kak', 'mantulbgt': 'mantulbgt', 'tetangga': 'tetangga', 'gmn': 'gmn', 'admin': 'admin', 'nggak': 'nggak', 'ubah': 'ubah', 'gerai': 'gerai', 'telkom': 'telkom', 'stok': 'stok', 'produknya': 'produk', 'patuhi': 'patuh', 'protokol': 'protokol', 'mantappp': 'mantappp', 'jaringan': 'jaring', 'loding': 'loding', 'perpanjang': 'panjang', 'kabel': 'kabel', 'masang': 'masang', 'teknisinya': 'teknisi', 'butuh': 'butuh', 'cepat': 'cepat', 'penuh': 'penuh', 'solusiny': 'solusiny', 'internet': 'internet', 'not': 'not', 'available': 'available', 'simbol': 'simbol', 'wifinya': 'wifinya', 'tanda': 'tanda', 'seru': 'seru', 'panik': 'panik', 'crosscheck': 'crosscheck', 'udah': 'udah', 'bayar': 'bayar', 'tagihan': 'tagih', 'kemarin': 'kemarin', 'kebiasaan': 'biasa', 'komplen': 'komplen', 'gangguan': 'ganggu', 'teknisi': 'teknisi', 'blm': 'blm', 'dateng': 'dateng', 'kerumah': 'rumah', 'tracker': 'tracker', 'system': 'system', 'bilangnya': 'bilang', 'selesai': 'selesai', 'restat': 'restat', 'modem': 'modem', 'tetep': 'tetep', 'aman': 'aman', 'yaa': 'yaa', 'masker': 'masker', 'saudara': 'saudara', 'berhenti': 'henti', 'berlangganan': 'langgan', 'kantor': 'kantor', 'telp': 'telp', 'menagih': 'tagih', 'biaya': 'biaya', 'bulanan': 'bulan', 'kembalikan': 'kembali', 'deposit': 'deposit', 'meleduk': 'leduk', 'pengaduan': 'adu', 'dak': 'dak', 'penanganan': 'tangan', 'koneksi': 'koneksi', 'nyala': 'nyala', 'doang': 'doang', 'tanggal': 'tanggal', 'bales': 'bales', 'tae': 'tae', 'sembarangan': 'sembarang', 'tancap': 'tancap', 'ijin': 'ijin', 'tanah': 'tanah', 'kusus': 'sus', 'untung': 'untung', 'coba': 'coba', 'brifing': 'brifing', 'anak': 'anak', 'buahnya': 'buah', 'oknum': 'oknum', 'uang': 'uang', 'pelanggan': 'langgan', 'jera': 'jera', 'renew': 'renew', 'speed': 'speed', 'diaplikasi': 'aplikasi', 'terbaru': 'baru', 'kelebihan': 'lebih', 'info': 'info', 'nihh': 'nihh', 'lag': 'lag', 'rumah': 'rumah', 'dibangun': 'bangun', 'cuti': 'cuti', 'seamless': 'seamless', 'maksimal': 'maksimal', 'device': 'device', 'mati': 'mati', 'los': 'los', 'merah': 'merah', 'diperbaiki': 'baik', 'thankyou': 'thankyou', 'halo': 'halo', 'permintaan': 'minta', 'upgrade': 'upgrade', 'mini': 'mini', 'package': 'package', 'dpt': 'dpt', 'pemberitahuan': 'pemberitahuan', 'aktif': 'aktif', 'channelx': 'channelx', 'smbil': 'smbil', 'internetx': 'internetx', 'low': 'low', 'useetv': 'useetv', 'sinyal': 'sinyal', 'mulu': 'mulu', 'kemaren': 'kemaren', 'perasaan': 'asa', 'telat': 'telat', 'trus': 'trus', 'lur': 'lur', 'provider': 'provider', 'burik': 'burik', 'kualitas': 'kualitas', 'harga': 'harga', 'mahal': 'mahal', 'kasi': 'kasi', 'bintang': 'bintang', 'bosen': 'bosen', 'komplain': 'komplain', 'hah': 'hah', 'lampu': 'lampu', 'internetnya': 'internetnya', 'giliran': 'gilir', 'cabut': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/139 [00:00<?, ?it/s]
#                                                   text  \
# 0    sering banget bagi-bagi, luar biasaaa\n\n#akti...
# 1           #aktivitastanpabatas #internetnyaindonesia
# 2    poin saya ada 5000 min, bisa di tukar di plaza...
# 3    suka bgt kalo lg banyak penukaran voucher dari...
# 4                                    tolong min cek dm
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146  @indihomecare channel tv fox sport sudah gak l...
# 147  wifi dirumah saya kok kedap kedip ya lampu los...
# 148          terimkasih min, konten yg sangat membantu
# 149               kapan f1 bisa dinikmati di indihome?
#
#                                          cleaning_text  \
# 0                 sering banget bagi bagi luar biasaaa
# 1
# 2    poin saya ada   min bisa tukar plaza mana aja ...
# 3    suka bgt kalo banyak penukaran voucher dari me...
# 4                                      tolong min cek
# ..                                                 ...
# 145  baik min terima kasih banyak informasinya sang...
# 146     channel fox sport sudah gak lagi nya indihome
# 147  wifi dirumah saya kok kedap kedip lampu los ny...
# 148              terimkasih min konten sangat membantu
# 149                     kapan bisa dinikmati indihome
#
#                                             tokenisasi  \
# 0          [sering, banget, bagi, bagi, luar, biasaaa]
# 1                                                   []
# 2    [poin, saya, ada, min, bisa, tukar, plaza, man...
# 3    [suka, bgt, kalo, banyak, penukaran, voucher, ...
# 4                                 [tolong, min, cek, ]
# ..                                                 ...
# 145  [baik, min, terima, kasih, banyak, informasiny...
# 146  [channel, fox, sport, sudah, gak, lagi, nya, i...
# 147  [wifi, dirumah, saya, kok, kedap, kedip, lampu...
# 148        [terimkasih, min, konten, sangat, membantu]
# 149               [kapan, bisa, dinikmati, indihome, ]
#
#                                               stopword  \
# 0                                    [banget, biasaaa]
# 1                                                   []
# 2                     [poin, min, tukar, plaza, min, ]
# 3                 [suka, penukaran, voucher, merchant]
# 4                                 [tolong, min, cek, ]
# ..                                                 ...
# 145        [min, terima, kasih, informasinya, berguna]
# 146                  [channel, fox, sport, indihome, ]
# 147  [wifi, dirumah, kedap, kedip, lampu, los, kone...
# 148                [terimkasih, min, konten, membantu]
# 149                            [dinikmati, indihome, ]
#
#                                              stemming
# 0                                   [banget, biasaaa]
# 1                                                  []
# 2                    [poin, min, tukar, plaza, min, ]
# 3                    [suka, tukar, voucher, merchant]
# 4                                [tolong, min, cek, ]
# ..                                                ...
# 145             [min, terima, kasih, informasi, guna]
# 146                 [channel, fox, sport, indihome, ]
# 147  [wifi, rumah, kedap, kedip, lampu, los, koneksi]
# 148                  [terimkasih, min, konten, bantu]
# 149                              [nikmat, indihome, ]
#
# [139 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                               comment
# 0                                   [banget, biasaaa]
# 1                                                  []
# 2                    [poin, min, tukar, plaza, min, ]
# 3                    [suka, tukar, voucher, merchant]
# 4                                [tolong, min, cek, ]
# ..                                                ...
# 145             [min, terima, kasih, informasi, guna]
# 146                 [channel, fox, sport, indihome, ]
# 147  [wifi, rumah, kedap, kedip, lampu, los, koneksi]
# 148                  [terimkasih, min, konten, bantu]
# 149                              [nikmat, indihome, ]
#
# [139 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_10.xlsx')
