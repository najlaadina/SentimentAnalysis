# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["comment_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data bersih_translate instagram indihome\databersih_english_instagram_indihome_2.xlsx', usecols=columns)
df['label_awal'] = ''
for i,x in df.comment_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.0
# Index:  1 label_awal 0.0
# Index:  2 label_awal -0.5
# Index:  3 label_awal 0.0
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.7
# Index:  7 label_awal 0.25
# Index:  8 label_awal 0.0
# Index:  9 label_awal 0.24318181818181817
# Index:  10 label_awal 0.0
# Index:  11 label_awal 0.0
# Index:  12 label_awal 0.3
# Index:  13 label_awal 0.2857142857142857
# Index:  14 label_awal -0.17857142857142858
# Index:  15 label_awal -0.17857142857142858
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.6
# Index:  19 label_awal 0.5
# Index:  20 label_awal 0.24285714285714285
# Index:  21 label_awal 0.0
# Index:  22 label_awal 0.0
# Index:  23 label_awal -0.13333333333333333
# Index:  24 label_awal 0.0
# Index:  25 label_awal 0.18333333333333335
# Index:  26 label_awal 0.022222222222222237
# Index:  27 label_awal 0.0
# Index:  28 label_awal 0.2
# Index:  29 label_awal 0.6
# Index:  30 label_awal 0.0
# Index:  31 label_awal 0.5
# Index:  32 label_awal 0.0
# Index:  33 label_awal 0.6
# Index:  34 label_awal 0.16666666666666666
# Index:  35 label_awal 0.2
# Index:  36 label_awal 0.2
# Index:  37 label_awal 0.0
# Index:  38 label_awal 0.0
# Index:  39 label_awal 0.35
# Index:  40 label_awal 0.10000000000000002
# Index:  41 label_awal 0.7000000000000001
# Index:  42 label_awal 0.0
# Index:  43 label_awal 0.0
# Index:  44 label_awal 0.6
# Index:  45 label_awal 0.0
# Index:  46 label_awal 0.17500000000000002
# Index:  47 label_awal 0.16
# Index:  48 label_awal 0.0
# Index:  49 label_awal 0.3
# Index:  50 label_awal 0.0
# Index:  51 label_awal 0.0
# Index:  52 label_awal 0.0
# Index:  53 label_awal 0.0
# Index:  54 label_awal 0.4
# Index:  55 label_awal 0.0
# Index:  56 label_awal -0.6
# Index:  57 label_awal -0.6
# Index:  58 label_awal 0.14499999999999996
# Index:  59 label_awal 0.0
# Index:  60 label_awal 0.4
# Index:  61 label_awal 0.0
# Index:  62 label_awal 0.1
# Index:  63 label_awal 0.0
# Index:  64 label_awal 0.4
# Index:  65 label_awal 0.0
# Index:  66 label_awal 0.0
# Index:  67 label_awal 0.0
# Index:  68 label_awal 0.0
# Index:  69 label_awal 0.35
# Index:  70 label_awal 0.0
# Index:  71 label_awal 0.6
# Index:  72 label_awal -0.4
# Index:  73 label_awal 0.0
# Index:  74 label_awal 0.0
# Index:  75 label_awal 0.0
# Index:  76 label_awal 0.0
# Index:  77 label_awal 0.5
# Index:  78 label_awal 0.16666666666666666
# Index:  79 label_awal 0.0
# Index:  80 label_awal 0.0
# Index:  81 label_awal 0.0
# Index:  82 label_awal -0.4
# Index:  83 label_awal 0.0
# Index:  84 label_awal 0.0
# Index:  85 label_awal 0.1
# Index:  86 label_awal 0.0
# Index:  87 label_awal -0.4
# Index:  88 label_awal -0.03333333333333335
# Index:  89 label_awal -0.03333333333333335
# Index:  90 label_awal 0.2
# Index:  91 label_awal 0.0
# Index:  92 label_awal 0.0
# Index:  93 label_awal 0.2
# Index:  94 label_awal 0.0
# Index:  95 label_awal 0.0
# Index:  96 label_awal 0.0
# Index:  97 label_awal 0.0
# Index:  98 label_awal 0.0
# Index:  99 label_awal 0.0
# Index:  100 label_awal 0.0
# Index:  101 label_awal 1.0
# Index:  102 label_awal 0.016666666666666635
# Index:  103 label_awal 0.3
# Index:  104 label_awal 0.0
# Index:  105 label_awal 0.0
# Index:  106 label_awal 0.16666666666666666
# Index:  107 label_awal 0.0
# Index:  108 label_awal 0.2
# Index:  109 label_awal 0.0
# Index:  110 label_awal 0.0
# Index:  111 label_awal 0.0
# Index:  112 label_awal 0.0
# Index:  113 label_awal 0.0
# Index:  114 label_awal 0.0
# Index:  115 label_awal 0.0
# Index:  116 label_awal 0.0
# Index:  117 label_awal 0.0
# Index:  118 label_awal -0.04999999999999999
# Index:  119 label_awal 0.0
# Index:  120 label_awal 0.0
# Index:  121 label_awal 0.0
# Index:  122 label_awal 0.0
# Index:  123 label_awal 0.0
# Index:  124 label_awal 0.0
# Index:  125 label_awal 0.0
# Index:  126 label_awal 0.0
# Index:  127 label_awal 0.11666666666666665
# Index:  128 label_awal 0.0
# Index:  129 label_awal 0.0
# Index:  130 label_awal 0.0
# Index:  131 label_awal 0.25
# Index:  132 label_awal 0.43333333333333335
# Index:  133 label_awal 0.2
# Index:  134 label_awal 0.0
# Index:  135 label_awal 0.0
# Index:  136 label_awal 0.6
# Index:  137 label_awal 0.35
# Index:  138 label_awal 0.6
# Index:  139 label_awal 0.225
# Index:  140 label_awal 0.0
# Index:  141 label_awal 0.2
# Index:  142 label_awal 0.2
# Index:  143 label_awal 0.0
# Index:  144 label_awal 0.0
# Index:  145 label_awal 0.0
# Index:  146 label_awal 0.0
# Index:  147 label_awal 0.4
# Index:  148 label_awal 0.0
# Index:  149 label_awal 0.0
# Index:  150 label_awal 0.0
# Index:  151 label_awal 0.4
# Index:  152 label_awal 0.0
# Index:  153 label_awal 0.0
# Index:  154 label_awal 0.27777777777777773
# Index:  155 label_awal 0.0
# Index:  156 label_awal -0.2
# Index:  157 label_awal 0.7
# Index:  158 label_awal 0.0
# Index:  159 label_awal -0.011904761904761911
# Index:  160 label_awal -0.07500000000000001
# Index:  161 label_awal 0.275
# Index:  162 label_awal 0.35
# Index:  163 label_awal 0.425
# Index:  164 label_awal 0.2
# Index:  165 label_awal 0.0
# Index:  166 label_awal 0.0
# Index:  167 label_awal 0.0
# Index:  168 label_awal 0.4
# Index:  169 label_awal 0.2
# Index:  170 label_awal 0.2
# Index:  171 label_awal 0.35
# Index:  172 label_awal 0.425
# Index:  173 label_awal 0.275
# Index:  174 label_awal 0.0
# Index:  175 label_awal 0.0
# Index:  176 label_awal -0.05
# Index:  177 label_awal 0.2
# Index:  178 label_awal 0.0
# Index:  179 label_awal 0.2
# Index:  180 label_awal 0.0
# Index:  181 label_awal 0.0
# Index:  182 label_awal 0.16666666666666666
# Index:  183 label_awal -0.3
# Index:  184 label_awal 0.2875
# Index:  185 label_awal 0.26666666666666666
# Index:  186 label_awal 0.16666666666666666
# Index:  187 label_awal 0.2
# Index:  188 label_awal 0.25999999999999995
# Index:  189 label_awal 0.0
# Index:  190 label_awal 0.45
# Index:  191 label_awal 0.0
# Index:  192 label_awal 0.1
# Index:  193 label_awal 0.2
# Index:  194 label_awal 0.35
# Index:  195 label_awal 0.0
# Index:  196 label_awal 0.15000000000000002
# Index:  197 label_awal 0.2
# Index:  198 label_awal 0.0
# Index:  199 label_awal 0.0
# Index:  200 label_awal 0.0
# Index:  201 label_awal 0.2875
# Index:  202 label_awal 0.0
# Index:  203 label_awal 0.0
# Index:  204 label_awal 0.0
# Index:  205 label_awal 0.0
# Index:  206 label_awal 0.0
# Index:  207 label_awal 0.0
# Index:  208 label_awal 0.0
# Index:  209 label_awal 0.0
# Index:  210 label_awal -0.5666666666666667
# Index:  211 label_awal 0.0
# Index:  212 label_awal 0.16666666666666666
# Index:  213 label_awal 0.0
# Index:  214 label_awal 0.35
# Index:  215 label_awal 0.0
# Index:  216 label_awal 0.0
# Index:  217 label_awal 0.0
# Index:  218 label_awal 0.0

# %%
df.head()
# Out:
#                                      comment_english label_awal
# 0                       ['morning', 'min', 'ask', "]        0.0
# 1                               ['hayu', 'departts']        0.0
# 2  ['hello', 'week', 'internet', 'disturbing', 'n...       -0.5
# 3               ['overcome', 'package', 'promo', '']        0.0
# 4                ['indihome', 'rumah', 'los', 'yaa']        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    119
#  0.200000     17
#  0.600000      7
#  0.350000      7
#  0.400000      6
#  0.166667      6
#  0.300000      3
#  0.500000      3
# -0.400000      3
#  0.100000      3
#  0.425000      2
#  0.700000      2
#  0.287500      2
# -0.033333      2
#  0.250000      2
# -0.178571      2
#  0.275000      2
# -0.600000      2
#  0.277778      1
# -0.200000      1
# -0.011905      1
#  0.450000      1
# -0.075000      1
# -0.050000      1
#  0.433333      1
#  0.150000      1
# -0.300000      1
#  0.266667      1
#  0.260000      1
#  0.225000      1
#  0.145000      1
#  0.116667      1
# -0.050000      1
#  0.016667      1
#  1.000000      1
# -0.500000      1
#  0.160000      1
#  0.175000      1
#  0.700000      1
#  0.100000      1
#  0.022222      1
#  0.183333      1
# -0.133333      1
#  0.242857      1
#  0.285714      1
#  0.243182      1
# -0.566667      1
# Name: label_awal, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] > 0.0:
        label.append("positive")
    else:
        label.append("negative")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                        comment_english     label
# 0                         ['morning', 'min', 'ask', "]  negative
# 1                                 ['hayu', 'departts']  negative
# 2    ['hello', 'week', 'internet', 'disturbing', 'n...  negative
# 3                 ['overcome', 'package', 'promo', '']  negative
# 4                  ['indihome', 'rumah', 'los', 'yaa']  negative
# ..                                                 ...       ...
# 214                       ['need', 'full', 'indihome']  positive
# 215  ['teknilogi', 'indihome', 'emang', 'mantul', '...  negative
# 216                ['mantep', 'gede', 'total', 'save']  negative
# 217                               ['save', 'benefits']  negative
# 218                 ['', 'min', 'check', 'please', '']  negative
#
# [219 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# negative    137
# positive     82
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_instagram_indihome_2.xlsx')
