# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                MIN BALES DM YAWLAAAA
# 1    Min, kalo ingin memperluas jangkuan wifi IndiH...
# 2    Kedai gw gk ada internet ni gmna IndiHome tolo...
# 3    Min, kalo mau menyaksikan Liga Inggris di Indi...
# 4                                           Cek dm min
# ..                                                 ...
# 113      Kak, kalo mau registrasi IndiHome lewat mana?
# 114  SOD itu apa Min? Soalnya ada muncul di aplikas...
# 115                   IndiHome terbaiiik WFH lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            CEK DM DONG ADMIN INDIHOME YG BAIK HATI
#
# [118 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 14

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                MIN BALES DM YAWLAAAA
# 2    Kedai gw gk ada internet ni gmna IndiHome tolo...
# 4                                           Cek dm min
# 5                 Baca baca komen hampir semua komplen
# 6         Min wifi id seamless maksimal berapa device?
# ..                                                 ...
# 111  Min mau tanya, kalo pasang baru IndiHome itu l...
# 112                                        Cek DM min
# 115                   IndiHome terbaiiik WFH lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            CEK DM DONG ADMIN INDIHOME YG BAIK HATI
#
# [93 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                min bales dm yawlaaaa
# 2    kedai gw gk ada internet ni gmna indihome tolo...
# 4                                           cek dm min
# 5                 baca baca komen hampir semua komplen
# 6         min wifi id seamless maksimal berapa device?
# ..                                                 ...
# 111  min mau tanya, kalo pasang baru indihome itu l...
# 112                                        cek dm min
# 115                   indihome terbaiiik wfh lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            cek dm dong admin indihome yg baik hati
#
# [93 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                min bales dm yawlaaaa
# 2    kedai gw gk ada internet ni gmna indihome tolo...
# 4                                           cek dm min
# 5                 baca baca komen hampir semua komplen
# 6         min wifi id seamless maksimal berapa device?
# ..                                                 ...
# 111  min mau tanya, kalo pasang baru indihome itu l...
# 112                                        cek dm min
# 115                   indihome terbaiiik wfh lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            cek dm dong admin indihome yg baik hati
#
#                                          cleaning_text
# 0                                   min bales yawlaaaa
# 2    kedai ada internet gmna indihome tolong donk l...
# 4                                              cek min
# 5                 baca baca komen hampir semua komplen
# 6            min wifi seamless maksimal berapa device
# ..                                                 ...
# 111  min mau tanya kalo pasang baru indihome itu la...
# 112                                            cek min
# 115                    indihome terbaiiik wfh lancaaar
# 116  memang indihome parah request pasang baru tgl ...
# 117                  cek dong admin indihome baik hati
#
# [93 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                min bales dm yawlaaaa
# 2    kedai gw gk ada internet ni gmna indihome tolo...
# 4                                           cek dm min
# 5                 baca baca komen hampir semua komplen
# 6         min wifi id seamless maksimal berapa device?
# ..                                                 ...
# 111  min mau tanya, kalo pasang baru indihome itu l...
# 112                                        cek dm min
# 115                   indihome terbaiiik wfh lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            cek dm dong admin indihome yg baik hati
#
#                                          cleaning_text  \
# 0                                   min bales yawlaaaa
# 2    kedai ada internet gmna indihome tolong donk l...
# 4                                              cek min
# 5                 baca baca komen hampir semua komplen
# 6            min wifi seamless maksimal berapa device
# ..                                                 ...
# 111  min mau tanya kalo pasang baru indihome itu la...
# 112                                            cek min
# 115                    indihome terbaiiik wfh lancaaar
# 116  memang indihome parah request pasang baru tgl ...
# 117                  cek dong admin indihome baik hati
#
#                                             tokenisasi
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, ada, internet, gmna, indihome, tolong,...
# 4                                           [cek, min]
# 5          [baca, baca, komen, hampir, semua, komplen]
# 6    [min, wifi, seamless, maksimal, berapa, device, ]
# ..                                                 ...
# 111  [min, mau, tanya, kalo, pasang, baru, indihome...
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [memang, indihome, parah, request, pasang, bar...
# 117           [cek, dong, admin, indihome, baik, hati]
#
# [93 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                min bales dm yawlaaaa
# 2    kedai gw gk ada internet ni gmna indihome tolo...
# 4                                           cek dm min
# 5                 baca baca komen hampir semua komplen
# 6         min wifi id seamless maksimal berapa device?
# ..                                                 ...
# 111  min mau tanya, kalo pasang baru indihome itu l...
# 112                                        cek dm min
# 115                   indihome terbaiiik wfh lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            cek dm dong admin indihome yg baik hati
#
#                                          cleaning_text  \
# 0                                   min bales yawlaaaa
# 2    kedai ada internet gmna indihome tolong donk l...
# 4                                              cek min
# 5                 baca baca komen hampir semua komplen
# 6            min wifi seamless maksimal berapa device
# ..                                                 ...
# 111  min mau tanya kalo pasang baru indihome itu la...
# 112                                            cek min
# 115                    indihome terbaiiik wfh lancaaar
# 116  memang indihome parah request pasang baru tgl ...
# 117                  cek dong admin indihome baik hati
#
#                                             tokenisasi  \
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, ada, internet, gmna, indihome, tolong,...
# 4                                           [cek, min]
# 5          [baca, baca, komen, hampir, semua, komplen]
# 6    [min, wifi, seamless, maksimal, berapa, device, ]
# ..                                                 ...
# 111  [min, mau, tanya, kalo, pasang, baru, indihome...
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [memang, indihome, parah, request, pasang, bar...
# 117           [cek, dong, admin, indihome, baik, hati]
#
#                                               stopword
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, internet, gmna, indihome, tolong, donk...
# 4                                           [cek, min]
# 5                         [baca, baca, komen, komplen]
# 6            [min, wifi, seamless, maksimal, device, ]
# ..                                                 ...
# 111                          [min, pasang, indihome, ]
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [indihome, parah, request, pasang, tgl, nov, t...
# 117                       [cek, admin, indihome, hati]
#
# [93 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 330
# ------------------------
# min : min
# bales : bales
# yawlaaaa : yawlaaaa
# kedai : kedai
# internet : internet
# gmna : gmna
# indihome : indihome
# tolong : tolong
# donk : donk
# lekas : lekas
# perbaiki : baik
# jaringan : jaring
# nyaman : nyaman
# cek : cek
# baca : baca
# komen : komen
# komplen : komplen
# wifi : wifi
# seamless : seamless
# maksimal : maksimal
# device : device
#  :
# kreatif : kreatif
# dehhh : dehhh
# pokoknyaaa : pokoknyaaa
# nonton : nonton
# mantapppp : mantapppp
# senang : senang
# banget : banget
# pakai : pakai
# mempermudah : mudah
# proses : proses
# kerja : kerja
# rumaah : rumaah
# turun : turun
# trus : trus
# koneksinya : koneksi
# stabil : stabil
# binggow : binggow
# terbaikkk : terbaikkk
# jaringannya : jaring
# kak : kak
# bayar : bayar
# linkaja : linkaja
# knp : knp
# tulisan : tulis
# pas : pas
# diklik : klik
# uda : uda
# ngak : ngak
# fox : fox
# sport : sport
# usee : usee
# salah : salah
# pengguna : guna
# kecewa : kecewa
# woi : woi
# niat : niat
# ngasih : ngasih
# pelayanan : layan
# telpon : telpon
# mati : mati
# udah : udah
# teknisi : teknisi
# dtg : dtg
# tikeeeeeettt : tikeeeeeettt
# mulu : mulu
# kasih : kasih
# alasan : alas
# gangguan : ganggu
# masal : masal
# box : box
# bermasalah : masalah
# kepenuhan : penuh
# ganti : ganti
# woiiii : woiiii
# org : org
# pasang : pasang
# masuk : masuk
# ilegal : ilegal
# mhl : mhl
# customer : customer
# prioritas : prioritas
# tangani : tangan
# max : max
# jam : jam
# dasar : dasar
# tukang : tukang
# bohong : bohong
# tar : tar
# kaya : kaya
# kompensasi : kompensasi
# telat : telat
# semenit : menit
# langsung : langsung
# putus : putus
# segini : gin
# jatuh : jatuh
# tempo : tempo
# pembayaran : bayar
# mundur : mundur
# kuota : kuota
# tanganin : tanganin
# swasta : swasta
# sekolah : sekolah
# pengaduan : adu
# nganisin : nganisin
# pulsa : pulsa
# iya : iya
# maaf : maaf
# lancar : lancar
# teruss : teruss
# versiku : versi
# pahlawan : pahlawan
# ppkm : ppkm
# berjuang : juang
# membenarkan : benar
# kabel : kabel
# kendala : kendala
# menemani : tani
# wfhku : wfhku
# thanks : thanks
# pagi : pagi
# caption : caption
# sobat : sobat
# provider : provider
# thankss : thankss
# infonya : info
# makasih : makasih
# frans : frans
# lemot : lot
# bangett : bangett
# gimana : gimana
# solusinya : solusi
# domisili : domisili
# bandung : bandung
# kaka : kaka
# lampu : lampu
# merahnya : merah
# coba : coba
# copot : copot
# kabelnya : kabel
# merah : merah
# daerah : daerah
# uber : uber
# pdhl : pdhl
# udh : udh
# paket : paket
# mahal : mahal
# wih : wih
# mantap : mantap
# error : error
# lapor : lapor
# mohon : mohon
# akses : akses
# dirumah : rumah
# nama : nama
# berubah : ubah
# password : password
# gmn : gmn
# oke : oke
# sip : sip
# berhasil : hasil
# terima : terima
# iyaa : iyaa
# mantep : mantep
# step : step
# bgtu : bgtu
# kota : kota
# bogor : bogor
# los : los
# help : help
# wilayah : wilayah
# pondok : pondok
# bambu : bambu
# duren : duren
# sawit : sawit
# koneksi : koneksi
# mah : mah
# slalu : slalu
# nga : nga
# bermanfaat : manfaat
# inbok : inbok
# berlangganan : langgan
# only : only
# apk : apk
# menu : menu
# doang : doang
# download : download
# aplikasi : aplikasi
# myindihome : myindihome
# dimana : mana
# beli : beli
# fup : fup
# pup : pup
# dri : dri
# kmrn : kmrn
# bener : bener
# gampang : gampang
# terbaik : baik
# tangal : tangal
# daftar : daftar
# blm : blm
# konek : konek
# tlpn : tlpn
# emang : emang
# memudahkan : mudah
# sukses : sukses
# mudah : mudah
# kualitas : kualitas
# wfh : wfh
# cmn : cmn
# tanggal : tanggal
# asli : asli
# gampangin : gampangin
# tagihan : tagih
# dll : dll
# ngecek : ngecek
# poinx : poinx
# play : play
# store : store
# psword : psword
# ttap : ttap
# tukar : tukar
# poin : poin
# plasa : plasa
# telkom : telkom
# terdekat : dekat
# nunggu : nunggu
# kemaren : kemaren
# tujuannya : tuju
# respon : respon
# karna : karna
# sayang : sayang
# pointnya : point
# kadaluarsa : kadaluarsa
# bgmn : bgmn
# poinnya : poin
# ribet : ribet
# ulang : ulang
# masukin : masukin
# kode : kode
# tetep : tetep
# suruh : suruh
# bbrp : bbrp
# streess : streess
# ngulang : ngulang
# trs : trs
# nukarin : nukarin
# point : point
# deh : deh
# merchant : merchant
# kerjasama : kerjasama
# wadahnya : wadah
# semangat : semangat
# nanya : nanya
# kakak : kakak
# biaya : biaya
# pendaftaran : daftar
# perbupannya : perbupannya
# indonesia : indonesia
# nggak : nggak
# fungsinya : fungsi
# mksh : mksh
# lokasi : lokasi
# lewati : lewat
# tiang : tiang
# odc : odc
# tmpt : tmpt
# vote : vote
# hlo : hlo
# informasinya : informasi
# fungsi : fungsi
# informasi : informasi
# berguna : guna
# nambah : nambah
# pengetahuan : tahu
# bingung : bingung
# matot : matot
# berhari : hari
# diingetin : diingetin
# tanggapan : tanggap
# woey : woey
# menyaksikan : saksi
# liga : liga
# inggris : inggris
# dmana : dmana
# laaaahhh : laaaahhh
# gercep : gercep
# gua : gua
# noh : noh
# alfamart : alfamart
# taunya : tau
# alfa : alfa
# loading : loading
# malam : malam
# terisolir : isolir
# uang : uang
# kembalikan : kembali
# sampe : sampe
# rerisolir : rerisolir
# bantu : bantu
# msh : msh
# internetnya : internetnya
# perampokan : ampo
# ngelag : ngelag
# november : november
# mantaaap : mantaaap
# indihomee : indihomee
# terbaikk : terbaikk
# aktifkan : aktif
# speddy : speddy
# gurung : gurung
# ngene : ngene
# urgent : urgent
# pemasangan : pasang
# yuhuuu : yuhuuu
# terozzz : terozzz
# syarat : syarat
# stb : stb
# terbaiiik : terbaiiik
# lancaaar : lancaaar
# parah : parah
# request : request
# tgl : tgl
# nov : nov
# dec : dec
# terpasang : pasang
# admin : admin
# hati : hati
# {'min': 'min', 'bales': 'bales', 'yawlaaaa': 'yawlaaaa', 'kedai': 'kedai', 'internet': 'internet', 'gmna': 'gmna', 'indihome': 'indihome', 'tolong': 'tolong', 'donk': 'donk', 'lekas': 'lekas', 'perbaiki': 'baik', 'jaringan': 'jaring', 'nyaman': 'nyaman', 'cek': 'cek', 'baca': 'baca', 'komen': 'komen', 'komplen': 'komplen', 'wifi': 'wifi', 'seamless': 'seamless', 'maksimal': 'maksimal', 'device': 'device', '': '', 'kreatif': 'kreatif', 'dehhh': 'dehhh', 'pokoknyaaa': 'pokoknyaaa', 'nonton': 'nonton', 'mantapppp': 'mantapppp', 'senang': 'senang', 'banget': 'banget', 'pakai': 'pakai', 'mempermudah': 'mudah', 'proses': 'proses', 'kerja': 'kerja', 'rumaah': 'rumaah', 'turun': 'turun', 'trus': 'trus', 'koneksinya': 'koneksi', 'stabil': 'stabil', 'binggow': 'binggow', 'terbaikkk': 'terbaikkk', 'jaringannya': 'jaring', 'kak': 'kak', 'bayar': 'bayar', 'linkaja': 'linkaja', 'knp': 'knp', 'tulisan': 'tulis', 'pas': 'pas', 'diklik': 'klik', 'uda': 'uda', 'ngak': 'ngak', 'fox': 'fox', 'sport': 'sport', 'usee': 'usee', 'salah': 'salah', 'pengguna': 'guna', 'kecewa': 'kecewa', 'woi': 'woi', 'niat': 'niat', 'ngasih': 'ngasih', 'pelayanan': 'layan', 'telpon': 'telpon', 'mati': 'mati', 'udah': 'udah', 'teknisi': 'teknisi', 'dtg': 'dtg', 'tikeeeeeettt': 'tikeeeeeettt', 'mulu': 'mulu', 'kasih': 'kasih', 'alasan': 'alas', 'gangguan': 'ganggu', 'masal': 'masal', 'box': 'box', 'bermasalah': 'masalah', 'kepenuhan': 'penuh', 'ganti': 'ganti', 'woiiii': 'woiiii', 'org': 'org', 'pasang': 'pasang', 'masuk': 'masuk', 'ilegal': 'ilegal', 'mhl': 'mhl', 'customer': 'customer', 'prioritas': 'prioritas', 'tangani': 'tangan', 'max': 'max', 'jam': 'jam', 'dasar': 'dasar', 'tukang': 'tukang', 'bohong': 'bohong', 'tar': 'tar', 'kaya': 'kaya', 'kompensasi': 'kompensasi', 'telat': 'telat', 'semenit': 'menit', 'langsung': 'langsung', 'putus': 'putus', 'segini': 'gin', 'jatuh': 'jatuh', 'tempo': 'tempo', 'pembayaran': 'bayar', 'mundur': 'mundur', 'kuota': 'kuota', 'tanganin': 'tanganin', 'swasta': 'swasta', 'sekolah': 'sekolah', 'pengaduan': 'adu', 'nganisin': 'nganisin', 'pulsa': 'pulsa', 'iya': 'iya', 'maaf': 'maaf', 'lancar': 'lancar', 'teruss': 'teruss', 'versiku': 'versi', 'pahlawan': 'pahlawan', 'ppkm': 'ppkm', 'berjuang': 'juang', 'membenarkan': 'benar', 'kabel': 'kabel', 'kendala': 'kendala', 'menemani': 'tani', 'wfhku': 'wfhku', 'thanks': 'thanks', 'pagi': 'pagi', 'caption': 'caption', 'sobat': 'sobat', 'provider': 'provider', 'thankss': 'thankss', 'infonya': 'info', 'makasih': 'makasih', 'frans': 'frans', 'lemot': 'lot', 'bangett': 'bangett', 'gimana': 'gimana', 'solusinya': 'solusi', 'domisili': 'domisili', 'bandung': 'bandung', 'kaka': 'kaka', 'lampu': 'lampu', 'merahnya': 'merah', 'coba': 'coba', 'copot': 'copot', 'kabelnya': 'kabel', 'merah': 'merah', 'daerah': 'daerah', 'uber': 'uber', 'pdhl': 'pdhl', 'udh': 'udh', 'paket': 'paket', 'mahal': 'mahal', 'wih': 'wih', 'mantap': 'mantap', 'error': 'error', 'lapor': 'lapor', 'mohon': 'mohon', 'akses': 'akses', 'dirumah': 'rumah', 'nama': 'nama', 'berubah': 'ubah', 'password': 'password', 'gmn': 'gmn', 'oke': 'oke', 'sip': 'sip', 'berhasil': 'hasil', 'terima': 'terima', 'iyaa': 'iyaa', 'mantep': 'mantep', 'step': 'step', 'bgtu': 'bgtu', 'kota': 'kota', 'bogor': 'bogor', 'los': 'los', 'help': 'help', 'wilayah': 'wilayah', 'pondok': 'pondok', 'bambu': 'bambu', 'duren': 'duren', 'sawit': 'sawit', 'koneksi': 'koneksi', 'mah': 'mah', 'slalu': 'slalu', 'nga': 'nga', 'bermanfaat': 'manfaat', 'inbok': 'inbok', 'berlangganan': 'langgan', 'only': 'only', 'apk': 'apk', 'menu': 'menu', 'doang': 'doang', 'download': 'download', 'aplikasi': 'aplikasi', 'myindihome': 'myindihome', 'dimana': 'mana', 'beli': 'beli', 'fup': 'fup', 'pup': 'pup', 'dri': 'dri', 'kmrn': 'kmrn', 'bener': 'bener', 'gampang': 'gampang', 'terbaik': 'baik', 'tangal': 'tangal', 'daftar': 'daftar', 'blm': 'blm', 'konek': 'konek', 'tlpn': 'tlpn', 'emang': 'emang', 'memudahkan': 'mudah', 'sukses': 'sukses', 'mudah': 'mudah', 'kualitas': 'kualitas', 'wfh': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/93 [00:00<?, ?it/s]
#                                                   text  \
# 0                                min bales dm yawlaaaa
# 2    kedai gw gk ada internet ni gmna indihome tolo...
# 4                                           cek dm min
# 5                 baca baca komen hampir semua komplen
# 6         min wifi id seamless maksimal berapa device?
# ..                                                 ...
# 111  min mau tanya, kalo pasang baru indihome itu l...
# 112                                        cek dm min
# 115                   indihome terbaiiik wfh lancaaar
# 116  memang indihome parah. request pasang baru dr ...
# 117            cek dm dong admin indihome yg baik hati
#
#                                          cleaning_text  \
# 0                                   min bales yawlaaaa
# 2    kedai ada internet gmna indihome tolong donk l...
# 4                                              cek min
# 5                 baca baca komen hampir semua komplen
# 6            min wifi seamless maksimal berapa device
# ..                                                 ...
# 111  min mau tanya kalo pasang baru indihome itu la...
# 112                                            cek min
# 115                    indihome terbaiiik wfh lancaaar
# 116  memang indihome parah request pasang baru tgl ...
# 117                  cek dong admin indihome baik hati
#
#                                             tokenisasi  \
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, ada, internet, gmna, indihome, tolong,...
# 4                                           [cek, min]
# 5          [baca, baca, komen, hampir, semua, komplen]
# 6    [min, wifi, seamless, maksimal, berapa, device, ]
# ..                                                 ...
# 111  [min, mau, tanya, kalo, pasang, baru, indihome...
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [memang, indihome, parah, request, pasang, bar...
# 117           [cek, dong, admin, indihome, baik, hati]
#
#                                               stopword  \
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, internet, gmna, indihome, tolong, donk...
# 4                                           [cek, min]
# 5                         [baca, baca, komen, komplen]
# 6            [min, wifi, seamless, maksimal, device, ]
# ..                                                 ...
# 111                          [min, pasang, indihome, ]
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [indihome, parah, request, pasang, tgl, nov, t...
# 117                       [cek, admin, indihome, hati]
#
#                                               stemming
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, internet, gmna, indihome, tolong, donk...
# 4                                           [cek, min]
# 5                         [baca, baca, komen, komplen]
# 6            [min, wifi, seamless, maksimal, device, ]
# ..                                                 ...
# 111                          [min, pasang, indihome, ]
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [indihome, parah, request, pasang, tgl, nov, t...
# 117                       [cek, admin, indihome, hati]
#
# [93 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                               [min, bales, yawlaaaa]
# 2    [kedai, internet, gmna, indihome, tolong, donk...
# 4                                           [cek, min]
# 5                         [baca, baca, komen, komplen]
# 6            [min, wifi, seamless, maksimal, device, ]
# ..                                                 ...
# 111                          [min, pasang, indihome, ]
# 112                                         [cek, min]
# 115               [indihome, terbaiiik, wfh, lancaaar]
# 116  [indihome, parah, request, pasang, tgl, nov, t...
# 117                       [cek, admin, indihome, hati]
#
# [93 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_11.xlsx')
