# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                stb #KuisIndiHomeCare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  Klu mw pindahin alat wifi n TV di ats gmn, kn ...
# 158                     Biaya pamasangan brapa min????
# 159                            Min mohon bales dm saya
# 160      Saya sudah sampaikan keluhan saya lewat DM..
# 161  Halo min,,,, indihome ku g konek nih dr subuh,...
#
# [162 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                stb #KuisIndiHomeCare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  Klu mw pindahin alat wifi n TV di ats gmn, kn ...
# 158                     Biaya pamasangan brapa min????
# 159                            Min mohon bales dm saya
# 160      Saya sudah sampaikan keluhan saya lewat DM..
# 161  Halo min,,,, indihome ku g konek nih dr subuh,...
#
# [150 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                stb #kuisindihomecare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  klu mw pindahin alat wifi n tv di ats gmn, kn ...
# 158                     biaya pamasangan brapa min????
# 159                            min mohon bales dm saya
# 160      saya sudah sampaikan keluhan saya lewat dm..
# 161  halo min,,,, indihome ku g konek nih dr subuh,...
#
# [150 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                stb #kuisindihomecare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  klu mw pindahin alat wifi n tv di ats gmn, kn ...
# 158                     biaya pamasangan brapa min????
# 159                            min mohon bales dm saya
# 160      saya sudah sampaikan keluhan saya lewat dm..
# 161  halo min,,,, indihome ku g konek nih dr subuh,...
#
#                                          cleaning_text
# 0                                                  stb
# 1                                      sip banget min
# 2                                         selalu hati
# 3                                            the best
# 4                                             terbaik
# ..                                                 ...
# 157  klu pindahin alat wifi ats gmn awl psng wifi bwh
# 158                        biaya pamasangan brapa min
# 159                               min mohon bales saya
# 160           saya sudah sampaikan keluhan saya lewat
# 161  halo min indihome konek nih subuh lampu pon wi...
#
# [150 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                stb #kuisindihomecare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  klu mw pindahin alat wifi n tv di ats gmn, kn ...
# 158                     biaya pamasangan brapa min????
# 159                            min mohon bales dm saya
# 160      saya sudah sampaikan keluhan saya lewat dm..
# 161  halo min,,,, indihome ku g konek nih dr subuh,...
#
#                                          cleaning_text  \
# 0                                                  stb
# 1                                      sip banget min
# 2                                         selalu hati
# 3                                            the best
# 4                                             terbaik
# ..                                                 ...
# 157  klu pindahin alat wifi ats gmn awl psng wifi bwh
# 158                        biaya pamasangan brapa min
# 159                               min mohon bales saya
# 160           saya sudah sampaikan keluhan saya lewat
# 161  halo min indihome konek nih subuh lampu pon wi...
#
#                                             tokenisasi
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                     [selalu, hati, ]
# 3                                        [the, best, ]
# 4                                          [terbaik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                          [min, mohon, bales, saya]
# 160   [saya, sudah, sampaikan, keluhan, saya, lewat, ]
# 161  [halo, min, indihome, konek, nih, subuh, lampu...
#
# [150 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                stb #kuisindihomecare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  klu mw pindahin alat wifi n tv di ats gmn, kn ...
# 158                     biaya pamasangan brapa min????
# 159                            min mohon bales dm saya
# 160      saya sudah sampaikan keluhan saya lewat dm..
# 161  halo min,,,, indihome ku g konek nih dr subuh,...
#
#                                          cleaning_text  \
# 0                                                  stb
# 1                                      sip banget min
# 2                                         selalu hati
# 3                                            the best
# 4                                             terbaik
# ..                                                 ...
# 157  klu pindahin alat wifi ats gmn awl psng wifi bwh
# 158                        biaya pamasangan brapa min
# 159                               min mohon bales saya
# 160           saya sudah sampaikan keluhan saya lewat
# 161  halo min indihome konek nih subuh lampu pon wi...
#
#                                             tokenisasi  \
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                     [selalu, hati, ]
# 3                                        [the, best, ]
# 4                                          [terbaik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                          [min, mohon, bales, saya]
# 160   [saya, sudah, sampaikan, keluhan, saya, lewat, ]
# 161  [halo, min, indihome, konek, nih, subuh, lampu...
#
#                                               stopword
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                             [hati, ]
# 3                                        [the, best, ]
# 4                                          [terbaik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                                [min, mohon, bales]
# 160                                        [keluhan, ]
# 161  [halo, min, indihome, konek, subuh, lampu, pon...
#
# [150 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 367
# ------------------------
# stb : stb
# sip : sip
# banget : banget
# min : min
#  :
# hati : hati
# the : the
# best : best
# terbaik : baik
# mantap : mantap
# keren : keren
# selamat : selamat
# pagi : pagi
# tolong : tolong
# los : los
# diperbaiki : baik
# balas : balas
# petugas : tugas
# tunggu : tunggu
# terimakasih : terimakasih
# indihome : indihome
# eror : eror
# nyala : nyala
# bermanfaat : manfaat
# laporan : lapor
# pelanggan : langgan
# selasa : selasa
# melapor : lapor
# gerai : gerai
# bone : bone
# sulawesi : sulawesi
# selatan : selatan
# info : info
# didatangi : datang
# kamis : kamis
# koq : koq
# aplikasi : aplikasi
# clear : clear
# mohon : mohon
# solusi : solusi
# internet : internet
# adad : adad
# pekanjaringan : pekanjaringan
# drop : drop
# bales : bales
# infonya : info
# terima : terima
# kasih : kasih
# makasih : makasih
# infonyaa : infonyaa
# matii : mati
# total : total
# responnyaaa : responnyaaa
# oke : oke
# membantu : bantu
# berlangganan : langgan
# terlambat : lambat
# bayar : bayar
# dikenakan : kena
# denda : denda
# dendanya : denda
# sod : sod
# yaa : yaa
# wifi : wifi
# seamless : seamless
# maksimal : maksimal
# brp : brp
# device : device
# teknisi : teknisi
# nakal : nakal
# menawarkan : tawar
# harga : harga
# modem : modem
# extender : extender
# rb : rb
# pemerasan : peras
# alami : alami
# rekan : rekan
# surabaya : surabaya
# ganti : ganti
# dikasih : kasih
# password : password
# mengendalikan : kendali
# modemnya : modem
# melanggar : langgar
# hak : hak
# pasang : pasang
# gimana : gimana
# salesnya : salesnya
# kakaa : kakaa
# apasihh : apasihh
# terbaikkkk : terbaikkkk
# indihomee : indihomee
# untung : untung
# dirumah : rumah
# udah : udah
# tercover : tercover
# jaringan : jaring
# enak : enak
# berguna : guna
# biaya : biaya
# pemasangan : pasang
# thxxx : thxxx
# kaak : kaak
# informasinya : informasi
# bgtt : bgtt
# yuhuuu : yuhuuu
# jaringaan : jaringaan
# lancaaar : lancaaar
# nyesel : nyesel
# daah : daah
# makasihh : makasihh
# perbaikan : baik
# cepett : cepett
# tagihan : tagih
# hmmmmm : hmmmmm
# niii : niii
# edan : edan
# uniqqqq : uniqqqq
# kak : kak
# nanya : nanya
# billing : billing
# cek : cek
# paket : paket
# tanggal : tanggal
# mati : mati
# asiaaaap : asiaaaap
# miiin : miiin
# daftar : daftar
# online : online
# konfirmasi : konfirmasi
# percepat : cepat
# pakai : pakai
# lancar : lancar
# jaya : jaya
# aman : aman
# terkendali : kendali
# mudah : mudah
# menjalani : jalan
# aktivitas : aktivitas
# sehari : hari
# terusss : terusss
# semangat : semangat
# wfhhh : wfhhh
# download : download
# gampang : gampang
# cekin : cekin
# ortu : ortu
# halah : halah
# mulu : mulu
# status : status
# pusat : pusat
# coding : coding
# normal : normal
# lapanganya : lapanganya
# ngingetin : ngingetin
# langsung : langsung
# kena : kena
# isolir : isolir
# gratis : gratis
# melayani : layan
# pengajuan : aju
# box : box
# penuh : penuh
# promo : promo
# kah : kah
# payah : payah
# vidio : vidio
# jatuh : jatuh
# tempo : tempo
# pembayaran : bayar
# tangal : tangal
# diproses : proses
# suruh : suruh
# ibuku : ibu
# regisnya : regisnya
# wifinya : wifinya
# tetrus : tetrus
# grartis : grartis
# nice : nice
# registrasinya : registrasi
# diskon : diskon
# thn : thn
# semenjak : semenjak
# langganan : langgan
# wfh : wfh
# nyaman : nyaman
# ditindaklanjuti : ditindaklanjuti
# udh : udh
# sebulan : bulan
# kecewa : kecewa
# kali : kali
# telpon : telpon
# kirim : kirim
# email : email
# customercare : customercare
# rugi : rugi
# mahal : mahal
# pelayanan : layan
# kek : kek
# gini : gin
# jangkauan : jangkau
# sinyal : sinyal
# indihom : indihom
# membengkak : bengkak
# gmn : gmn
# solusinya : solusi
# takutnya : takut
# berbulan : bulan
# gan : gan
# eab : eab
# main : main
# tajem : tajem
# kooo : kooo
# muncul : muncul
# myindihome : myindihome
# stabil : stabil
# luas : luas
# galau : galau
# pengen : ken
# curhat : curhat
# chat : chat
# gmna : gmna
# coba : coba
# kereenn : kereenn
# deh : deh
# dipasang : pasang
# gabisa : gabisa
# kabarin : kabarin
# cancel : cancel
# kya : kya
# apapun : apa
# masangnya : masangnya
# rtp : rtp
# weyyy : weyyy
# kereeen : kereeen
# layanan : layan
# mnarik : mnarik
# menyaksikan : saksi
# liga : liga
# inggris : inggris
# dmana : dmana
# mantullllll : mantullllll
# knapa : knapa
# permintaan : minta
# upgrade : upgrade
# speed : speed
# apk : apk
# blm : blm
# putuhbyang : putuhbyang
# smbung : smbung
# bingung : bingung
# ngehubungin : ngehubungin
# kemna : kemna
# nyambung : nyambung
# terburuk : buruk
# tolol : tolol
# sampah : sampah
# bajingan : bajing
# dihatiiiii : dihatiiiii
# donk : donk
# jaringannya : jaring
# lemot : lot
# lapor : lapor
# respon : respon
# tindak : tindak
# adh : adh
# tiket : tiket
# maaf : maaf
# ketidaknyamanannya : ketidaknyamanannya
# keluhan : keluh
# customer : customer
# care : care
# nomor : nomor
# in : in
# harap : harap
# ditunggu : tunggu
# perbaikannya : baik
# perihal : perihal
# memperluas : luas
# jangkuan : jangkuan
# dibantu : bantu
# gitu : gitu
# hallo : hallo
# april : april
# balasan : balas
# miiiin : miiiin
# hello : hello
# okee : okee
# sorean : sore
# loss : loss
# nett : nett
# hadeuuhhh : hadeuuhhh
# kualitas : kualitas
# rendah : rendah
# perusahaan : usaha
# sialan : sial
# minn : minn
# iya : iya
# nomornya : nomor
# kontrak : kontrak
# pas : pas
# infonyaaa : infonyaaa
# gangguan : ganggu
# update : update
# manfaat : manfaat
# mimin : mimin
# kewrennn : kewrennn
# mimiiiin : mimiiiin
# minnn : minnn
# selaluu : selaluu
# lancaar : lancaar
# pokoknya : pokok
# mksh : mksh
# minnnn : minnnn
# bantu : bantu
# miinnn : miinnn
# halo : halo
# interner : interner
# rumah : rumah
# losnya : los
# merah : merah
# kerja : kerja
# tangani : tangan
# secepatnya : cepat
# trimakasih : trimakasih
# kecepatan : cepat
# abis : abis
# perangkat : perangkat
# erooorrr : erooorrr
# trooss : trooss
# haaaalllaahhhhh : haaaalllaahhhhh
# system : system
# baca : baca
# hadeuhhhh : hadeuhhhh
# pantesan : pantesan
# lambat : lambat
# dikurangin : rangin
# penggunanya : guna
# cepet : cepet
# speednya : speednya
# remote : remote
# rusak : rusak
# terimakasihmin : terimakasihmin
# youtube : youtube
# dibuka : buka
# orderan : order
# gantung : gantung
# kejelasan : jelas
# terhubung : hubung
# kemarin : kemarin
# sore : sore
# perbaiki : baik
# klu : klu
# pindahin : pindahin
# alat : alat
# ats : ats
# awl : awl
# psng : psng
# bwh : bwh
# pamasangan : pamasangan
# brapa : brapa
# konek : konek
# subuh : subuh
# lampu : lampu
# pon : pon
# thanks : thanks
# {'stb': 'stb', 'sip': 'sip', 'banget': 'banget', 'min': 'min', '': '', 'hati': 'hati', 'the': 'the', 'best': 'best', 'terbaik': 'baik', 'mantap': 'mantap', 'keren': 'keren', 'selamat': 'selamat', 'pagi': 'pagi', 'tolong': 'tolong', 'los': 'los', 'diperbaiki': 'baik', 'balas': 'balas', 'petugas': 'tugas', 'tunggu': 'tunggu', 'terimakasih': 'terimakasih', 'indihome': 'indihome', 'eror': 'eror', 'nyala': 'nyala', 'bermanfaat': 'manfaat', 'laporan': 'lapor', 'pelanggan': 'langgan', 'selasa': 'selasa', 'melapor': 'lapor', 'gerai': 'gerai', 'bone': 'bone', 'sulawesi': 'sulawesi', 'selatan': 'selatan', 'info': 'info', 'didatangi': 'datang', 'kamis': 'kamis', 'koq': 'koq', 'aplikasi': 'aplikasi', 'clear': 'clear', 'mohon': 'mohon', 'solusi': 'solusi', 'internet': 'internet', 'adad': 'adad', 'pekanjaringan': 'pekanjaringan', 'drop': 'drop', 'bales': 'bales', 'infonya': 'info', 'terima': 'terima', 'kasih': 'kasih', 'makasih': 'makasih', 'infonyaa': 'infonyaa', 'matii': 'mati', 'total': 'total', 'responnyaaa': 'responnyaaa', 'oke': 'oke', 'membantu': 'bantu', 'berlangganan': 'langgan', 'terlambat': 'lambat', 'bayar': 'bayar', 'dikenakan': 'kena', 'denda': 'denda', 'dendanya': 'denda', 'sod': 'sod', 'yaa': 'yaa', 'wifi': 'wifi', 'seamless': 'seamless', 'maksimal': 'maksimal', 'brp': 'brp', 'device': 'device', 'teknisi': 'teknisi', 'nakal': 'nakal', 'menawarkan': 'tawar', 'harga': 'harga', 'modem': 'modem', 'extender': 'extender', 'rb': 'rb', 'pemerasan': 'peras', 'alami': 'alami', 'rekan': 'rekan', 'surabaya': 'surabaya', 'ganti': 'ganti', 'dikasih': 'kasih', 'password': 'password', 'mengendalikan': 'kendali', 'modemnya': 'modem', 'melanggar': 'langgar', 'hak': 'hak', 'pasang': 'pasang', 'gimana': 'gimana', 'salesnya': 'salesnya', 'kakaa': 'kakaa', 'apasihh': 'apasihh', 'terbaikkkk': 'terbaikkkk', 'indihomee': 'indihomee', 'untung': 'untung', 'dirumah': 'rumah', 'udah': 'udah', 'tercover': 'tercover', 'jaringan': 'jaring', 'enak': 'enak', 'berguna': 'guna', 'biaya': 'biaya', 'pemasangan': 'pasang', 'thxxx': 'thxxx', 'kaak': 'kaak', 'informasinya': 'informasi', 'bgtt': 'bgtt', 'yuhuuu': 'yuhuuu', 'jaringaan': 'jaringaan', 'lancaaar': 'lancaaar', 'nyesel': 'nyesel', 'daah': 'daah', 'makasihh': 'makasihh', 'perbaikan': 'baik', 'cepett': 'cepett', 'tagihan': 'tagih', 'hmmmmm': 'hmmmmm', 'niii': 'niii', 'edan': 'edan', 'uniqqqq': 'uniqqqq', 'kak': 'kak', 'nanya': 'nanya', 'billing': 'billing', 'cek': 'cek', 'paket': 'paket', 'tanggal': 'tanggal', 'mati': 'mati', 'asiaaaap': 'asiaaaap', 'miiin': 'miiin', 'daftar': 'daftar', 'online': 'online', 'konfirmasi': 'konfirmasi', 'percepat': 'cepat', 'pakai': 'pakai', 'lancar': 'lancar', 'jaya': 'jaya', 'aman': 'aman', 'terkendali': 'kendali', 'mudah': 'mudah', 'menjalani': 'jalan', 'aktivitas': 'aktivitas', 'sehari': 'hari', 'terusss': 'terusss', 'semangat': 'semangat', 'wfhhh': 'wfhhh', 'download': 'download', 'gampang': 'gampang', 'cekin': 'cekin', 'ortu': 'ortu', 'halah': 'halah', 'mulu': 'mulu', 'status': 'status', 'pusat': 'pusat', 'coding': 'coding', 'normal': 'normal', 'lapanganya': 'lapanganya', 'ngingetin': 'ngingetin', 'langsung': 'langsung', 'kena': 'kena', 'isolir': 'isolir', 'gratis': 'gratis', 'melayani': 'layan', 'pengajuan': 'aju', 'box': 'box', 'penuh': 'penuh', 'promo': 'promo', 'kah': 'kah', 'payah': 'payah', 'vidio': 'vidio', 'jatuh': 'jatuh', 'tempo': 'tempo', 'pembayaran': 'bayar', 'tangal': 'tangal', 'diproses': 'proses', 'suruh': 'suruh', 'ibuku': 'ibu', 'regisnya': 'regisnya', 'wifinya': 'wifinya', 'tetrus': 'tetrus', 'grartis': 'grartis', 'nice': 'nice', 'registrasinya': 'registrasi', 'diskon': 'diskon', 'thn': 'thn', 'semenjak': 'semenjak', 'langganan': 'langgan', 'wfh': 'wfh', 'nyaman': 'nyaman', 'ditindaklanjuti': 'ditindaklanjuti', 'udh': 'udh', 'sebulan': 'bulan', 'kecewa': 'kecewa', 'kali': 'kali', 'telpon': 'telpon', 'kirim': 'kirim', 'email': 'email', 'customercare': 'customercare', 'rugi': 'rugi', 'mahal': 'mahal', 'pelayanan': 'layan', 'kek': 'kek', 'gini': 'gin', 'j ...
# ------------------------
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]
#                                                   text  \
# 0                                stb #kuisindihomecare
# 1                                      sip banget min.
# 2                                      selalu di hati.
# 3                                            the best.
# 4                                             terbaik.
# ..                                                 ...
# 157  klu mw pindahin alat wifi n tv di ats gmn, kn ...
# 158                     biaya pamasangan brapa min????
# 159                            min mohon bales dm saya
# 160      saya sudah sampaikan keluhan saya lewat dm..
# 161  halo min,,,, indihome ku g konek nih dr subuh,...
#
#                                          cleaning_text  \
# 0                                                  stb
# 1                                      sip banget min
# 2                                         selalu hati
# 3                                            the best
# 4                                             terbaik
# ..                                                 ...
# 157  klu pindahin alat wifi ats gmn awl psng wifi bwh
# 158                        biaya pamasangan brapa min
# 159                               min mohon bales saya
# 160           saya sudah sampaikan keluhan saya lewat
# 161  halo min indihome konek nih subuh lampu pon wi...
#
#                                             tokenisasi  \
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                     [selalu, hati, ]
# 3                                        [the, best, ]
# 4                                          [terbaik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                          [min, mohon, bales, saya]
# 160   [saya, sudah, sampaikan, keluhan, saya, lewat, ]
# 161  [halo, min, indihome, konek, nih, subuh, lampu...
#
#                                               stopword  \
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                             [hati, ]
# 3                                        [the, best, ]
# 4                                          [terbaik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                                [min, mohon, bales]
# 160                                        [keluhan, ]
# 161  [halo, min, indihome, konek, subuh, lampu, pon...
#
#                                               stemming
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                             [hati, ]
# 3                                        [the, best, ]
# 4                                             [baik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                                [min, mohon, bales]
# 160                                          [keluh, ]
# 161  [halo, min, indihome, konek, subuh, lampu, pon...
#
# [150 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                                [stb]
# 1                                 [sip, banget, min, ]
# 2                                             [hati, ]
# 3                                        [the, best, ]
# 4                                             [baik, ]
# ..                                                 ...
# 157  [klu, pindahin, alat, wifi, ats, gmn, awl, psn...
# 158                  [biaya, pamasangan, brapa, min, ]
# 159                                [min, mohon, bales]
# 160                                          [keluh, ]
# 161  [halo, min, indihome, konek, subuh, lampu, pon...
#
# [150 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_12.xlsx')
