# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                             Balas dm
# 1                                           Min cek DM
# 2                            keren mensolusikan banget
# 3                                               Cek DM
# 4    Refund deposit udah hampir sebulan belum dibal...
# ..                                                 ...
# 218                                     Min cek dm yaa
# 219                                          Keren min
# 220                                         Cek DM kak
# 221                                    Min cek dm dong
# 222  Kapan refund deposit saya dikembalikan? Janjin...
#
# [223 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                             Balas dm
# 1                                           Min cek DM
# 2                            keren mensolusikan banget
# 4    Refund deposit udah hampir sebulan belum dibal...
# 5                                        Genjiiii!!!!!
# ..                                                 ...
# 218                                     Min cek dm yaa
# 219                                          Keren min
# 220                                         Cek DM kak
# 221                                    Min cek dm dong
# 222  Kapan refund deposit saya dikembalikan? Janjin...
#
# [183 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                             balas dm
# 1                                           min cek dm
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                        genjiiii!!!!!
# ..                                                 ...
# 218                                     min cek dm yaa
# 219                                          keren min
# 220                                         cek dm kak
# 221                                    min cek dm dong
# 222  kapan refund deposit saya dikembalikan? janjin...
#
# [183 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                             balas dm
# 1                                           min cek dm
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                        genjiiii!!!!!
# ..                                                 ...
# 218                                     min cek dm yaa
# 219                                          keren min
# 220                                         cek dm kak
# 221                                    min cek dm dong
# 222  kapan refund deposit saya dikembalikan? janjin...
#
#                                          cleaning_text
# 0                                               balas
# 1                                             min cek
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                            genjiiii
# ..                                                 ...
# 218                                        min cek yaa
# 219                                          keren min
# 220                                            cek kak
# 221                                       min cek dong
# 222  kapan refund deposit saya dikembalikan janjiny...
#
# [183 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                             balas dm
# 1                                           min cek dm
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                        genjiiii!!!!!
# ..                                                 ...
# 218                                     min cek dm yaa
# 219                                          keren min
# 220                                         cek dm kak
# 221                                    min cek dm dong
# 222  kapan refund deposit saya dikembalikan? janjin...
#
#                                          cleaning_text  \
# 0                                               balas
# 1                                             min cek
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                            genjiiii
# ..                                                 ...
# 218                                        min cek yaa
# 219                                          keren min
# 220                                            cek kak
# 221                                       min cek dong
# 222  kapan refund deposit saya dikembalikan janjiny...
#
#                                             tokenisasi
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                        [keren, mensolusikan, banget]
# 4    [refund, deposit, udah, hampir, sebulan, belum...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                   [min, cek, dong]
# 222  [kapan, refund, deposit, saya, dikembalikan, j...
#
# [183 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                             balas dm
# 1                                           min cek dm
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                        genjiiii!!!!!
# ..                                                 ...
# 218                                     min cek dm yaa
# 219                                          keren min
# 220                                         cek dm kak
# 221                                    min cek dm dong
# 222  kapan refund deposit saya dikembalikan? janjin...
#
#                                          cleaning_text  \
# 0                                               balas
# 1                                             min cek
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                            genjiiii
# ..                                                 ...
# 218                                        min cek yaa
# 219                                          keren min
# 220                                            cek kak
# 221                                       min cek dong
# 222  kapan refund deposit saya dikembalikan janjiny...
#
#                                             tokenisasi  \
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                        [keren, mensolusikan, banget]
# 4    [refund, deposit, udah, hampir, sebulan, belum...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                   [min, cek, dong]
# 222  [kapan, refund, deposit, saya, dikembalikan, j...
#
#                                               stopword
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                        [keren, mensolusikan, banget]
# 4    [refund, deposit, udah, sebulan, dibaliki, pas...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                         [min, cek]
# 222  [refund, deposit, dikembalikan, janjinya, apri...
#
# [183 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 526
# ------------------------
# balas : balas
#  :
# min : min
# cek : cek
# keren : keren
# mensolusikan : solusi
# banget : banget
# refund : refund
# deposit : deposit
# udah : udah
# sebulan : bulan
# dibaliki : balik
# pas : pas
# hubungi : hubung
# estimasinya : estimasi
# manaaa : manaaa
# tiket : tiket
# genjiiii : genjiiii
# login : login
# register : register
# aplikasi : aplikasi
# indihome : indihome
# internet : internet
# terpasang : pasang
# rumah : rumah
# hevy : hevy
# anaknya : anak
# lag : lag
# tolong : tolong
# wifi : wifi
# ngelag : ngelag
# mulu : mulu
# kemarin : kemarin
# ama : ama
# aman : aman
# udh : udh
# melapor : lapor
# via : via
# twitter : twitter
# myindihome : myindihome
# tpi : tpi
# respon : respon
# skali : skali
# dirumah : rumah
# mati : mati
# semingguan : minggu
# nihh : nihh
# los : los
# perbaikan : baik
# kelar : kelar
# suka : suka
# baca : baca
# bermanfaat : manfaat
# puyennggg : puyennggg
# error : error
# woii : woii
# biaya : biaya
# berlangganan : langgan
# mbps : mbps
# tambahan : tambah
# halo : halo
# kaka : kaka
# mantaaappp : mantaaappp
# broken : broken
# teros : ros
# berhenti : henti
# kemana : mana
# koordinasinya : koordinasi
# byar : byar
# tanggal : tanggal
# kena : kena
# denda : denda
# betah : betah
# lewati : lewat
# pamdemi : pamdemi
# membantu : bantu
# app : app
# kode : kode
# otpnya : otpnya
# salah : salah
# trus : trus
# sesuai : sesuai
# sms : sms
# terima : terima
# malam : malam
# njir : njir
# ngelek : ngelek
# butuh : butuh
# kerja : kerja
# pasang : pasang
# gini : gin
# lak : lak
# paketan : paket
# pulsa : pulsa
# pemasangan : pasang
# cepet : cepet
# gitu : gitu
# jaringannya : jaring
# mantep : mantep
# kenceng : kenceng
# heran : heran
# pelanggan : langgan
# marah : marah
# nice : nice
# info : info
# emang : emang
# infonya : info
# mantul : mantul
# minnnnn : minnnnn
# doong : doong
# sangaat : sangaat
# mantap : mantap
# terimakasih : terimakasih
# tips : tips
# kak : kak
# kartun : kartun
# favorit : favorit
# jaringan : jaring
# peppayuan : peppayuan
# pembayaran : bayar
# oakai : oakai
# ambil : ambil
# cabut : cabut
# uang : uang
# jaminan : jamin
# iklas : iklas
# gmail : gmail
# hadeuuuuuh : hadeuuuuuh
# kecewa : kecewa
# adminn : adminn
# plis : plis
# bls : bls
# april : april
# tangal : tangal
# mei : mei
# suruh : suruh
# bayar : bayar
# pagi : pagi
# telpon : telpon
# minggu : minggu
# marna : marna
# kuota : kuota
# manfaat : manfaat
# kontol : kontol
# taiii : taiii
# menginput : menginput
# merekap : rekap
# mengirim : kirim
# absensi : absensi
# asn : asn
# batas : batas
# ditentukan : tentu
# kalinga : kalinga
# kesulitan : sulit
# gara : gara
# ekspetasi : ekspetasi
# nyaman : nyaman
# khawatir : khawatir
# habis : habis
# realita : realita
# erroran : erroran
# krusial : krusial
# beli : beli
# data : data
# terhormat : hormat
# mengharuskan : harus
# membayar : bayar
# sanksi : sanksi
# berlanggan : langgan
# menyelesaikan : selesai
# internetnya : internetnya
# penanganannya : tangan
# buruk : buruk
# pelayanan : layan
# nahan : nahan
# putus : putus
# menahan : tahan
# sehat : sehat
# engga : engga
# mohon : mohon
# thanks : thanks
# inet : inet
# tlp : tlp
# fasilitas : fasilitas
# bebas : bebas
# akses : akses
# useetvgo : useetvgo
# lol : lol
# bacot : bacot
# alasan : alas
# sinyal : sinyal
# gimana : gimana
# giliran : gilir
# langsung : langsung
# berenti : renti
# langanan : langanan
# tagihan : tagih
# bulanan : bulan
# iyah : iyah
# tertagih : tagih
# pemberitahuan : pemberitahuan
# apapun : apa
# gatau : gatau
# bales : bales
# balikin : balikin
# woi : woi
# lampu : lampu
# indikator : indikator
# wlan : wlan
# router : router
# berkedip : kedip
# ping : ping
# game : game
# jumping : jumping
# mengatasiny : mengatasiny
# gmn : gmn
# mengalami : alami
# trouble : trouble
# wib : wib
# layanan : layan
# terhubung : hubung
# coba : coba
# restart : restart
# raya : raya
# idulfitri : idulfitri
# skrg : skrg
# open : open
# channelnya : channelnya
# niat : niat
# subscribe : subscribe
# ribet : ribet
# masi : mas
# max : max
# smp : smp
# uda : uda
# senin : senin
# dmnya : dmnya
# direspon : direspon
# all : all
# chanel : chanel
# jelek : jelek
# nanya : nanya
# ngatain : ngatain
# akun : akun
# tutup : tutup
# komentar : komentar
# terusss : terusss
# stabil : stabil
# sore : sore
# numpang : numpang
# komen : komen
# telkomntt : telkomntt
# non : non
# aktif : aktif
# kolom : kolom
# maaf : maaf
# rekrut : rekrut
# pegawai : pegawai
# teknisi : teknisi
# lihat : lihat
# kemampuan : mampu
# lapangan : lapang
# kah : kah
# jumat : jumat
# dtg : dtg
# modem : modem
# jalan : jalan
# kejelasan : jelas
# kadang : kadang
# nge : nge
# rugi : rugi
# lebaran : lebaran
# ngga : ngga
# yaa : yaa
# sayang : sayang
# yak : yak
# napa : napa
# lemot : lot
# dipake : dipake
# main : main
# kagak : kagak
# jatohnya : jatohnya
# lampunya : lampu
# merah : merah
# dok : dok
# jayapura : jayapura
# gangugan : gangugan
# rb : rb
# perbulan : bulan
# flat : flat
# kenaikan : naik
# paket : paket
# harian : hari
# kecepatan : cepat
# kbps : kbps
# mengecewakan : kecewa
# menjaga : jaga
# kualitas : kualitas
# datanya : data
# dijanjikan : janji
# wifiiiii : wifiiiii
# kek : kek
# gua : gua
# cok : cok
# bangkrut : bangkrut
# looo : looo
# setan : setan
# babi : babi
# turnamen : turnamen
# kalah : kalah
# cokk : cokk
# asuuuuyyyyyyyyyy : asuuuuyyyyyyyyyy
# ngeleg : ngeleg
# edann : edann
# crew : crew
# indihoom : indihoom
# asy : asy
# jancokkkk : jancokkkk
# mahal : mahal
# cekk : cekk
# kunyykkkk : kunyykkkk
# inter : inter
# lancar : lancar
# langganan : langgan
# indhioom : indhioom
# wifinya : wifinya
# siapp : siapp
# berkat : berkat
# hape : hape
# sayaa : sayaa
# bln : bln
# pindah : pindah
# kota : kota
# ketelatan : telat
# tanggl : tanggl
# tnggl : tnggl
# isolir : isolir
# telkom : telkom
# cma : cma
# kepake : kepake
# brp : brp
# hri : hri
# tolerani : toleran
# hrs : hrs
# byr : byr
# woiz : woiz
# read : read
# doang : doang
# lelet : lelet
# ngpain : ngpain
# dibayar : bayar
# ngntod : ngntod
# tgl : tgl
# telat : telat
# mebayar : mebayar
# tangihan : tangihan
# informasinya : informasi
# berguna : guna
# android : android
# merek : merek
# oppo : oppo
# cennect : cennect
# penjelasan : jelas
# aktivasi : aktivasi
# channel : channel
# otomatis : otomatis
# ditutup : tutup
# dikenakan : kena
# kasih : kasih
# jringannya : jringannya
# ngegame : ngegame
# hancur : hancur
# bettttttttttt : bettttttttttt
# uji : uji
# mentall : mentall
# jadinyaaaa : jadinyaaaa
# semangaaaattt : semangaaaattt
# tanggapan : tanggap
# ditanggapi : tanggap
# knp : knp
# halal : halal
# bihalalnya : bihalalnya
# petugas : tugas
# teknisinya : teknisi
# matikan : mati
# cpt : cpt
# ganti : ganti
# ditunggu : tunggu
# balesan : balesan
# penguat : kuat
# signal : signal
# ongkosnya : ongkos
# nama : nama
# friantara : friantara
# ganguan : ganguan
# stb : stb
# gagal : gagal
# alamat : alamat
# bantu : bantu
# mas : mas
# maapin : maapin
# wowww : wowww
# bingung : bingung
# orang : orang
# gada : gada
# make : make
# wey : wey
# seminggu : minggu
# plasa : plasa
# buka : buka
# selamat : selamat
# kabar : kabar
# benerin : benerin
# benerinnya : benerinnya
# menit : menit
# informasi : informasi
# barusan : barusan
# ternyat : ternyat
# kendalanya : kendala
# port : port
# odpnya : odpnya
# dipasang : pasang
# alias : alias
# ketukar : tukar
# apalah : apa
# bahasanya : bahasa
# karna : karna
# dicabut : cabut
# in : in
# tiang : tiang
# diganti : ganti
# ijin : ijin
# lapor : lapor
# sri : sri
# wahyuning : wahyuning
# nyala : nyala
# kedip : kedip
# berkali : kali
# kali : kali
# kabel : kabel
# bantuan : bantu
# buatkan : buat
# aduan : adu
# gangguan : ganggu
# terkoneksi : koneksi
# muncul : muncul
# lakukan : laku
# berbagae : berbagae
# tetep : tetep
# msih : msih
# tlng : tlng
# sya : sya
# slow : slow
# trs : trs
# jdi : jdi
# hrus : hrus
# gmna : gmna
# tolok : tolok
# sinyalnya : sinyal
# tancap : tancap
# bantuannya : bantu
# trims : trims
# mengajukan : aju
# memperoleh : oleh
# pengajuan : aju
# menunggu : tunggu
# dibuatkan : buat
# direstart : direstart
# bagus : bagus
# hai : hai
# tersambung : sambung
# papah : papah
# kakak : kakak
# memakai : pakai
# inidikator : inidikator
# menyala : nyala
# admin : admin
# ikutin : ikutin
# dipostingan : dipostingan
# sandi : sandi
# password : password
# pencerahannya : cerah
# kereeen : kereeen
# bermanfaatt : bermanfaatt
# internetku : internetku
# lambat : lambat
# bermasalah : masalah
# kontennya : konten
# menurunin : menurunin
# rank : rank
# nov : nov
# may : may
# menikmati : nikmat
# useetv : useetv
# buktinya : bukti
# pakai : pakai
# tra : tra
# vision : vision
# jualan : jual
# jujur : jujur
# curang : curang
# merugikan : rugi
# bumn : bumn
# maju : maju
# pelayanannya : layan
# profesional : profesional
# sip : sip
# patut : patut
# dicoba : coba
# lupa : lupa
# menggantinya : ganti
# mimin : mimin
# lahir : lahir
# batin : batin
# indhihome : indhihome
# februari : februari
# daring : daring
# srkolah : srkolah
# pakr : pakr
# dikembalikan : kembali
# janjinya : janji
# contac : contac
# call : call
# center : center
# jawabannya : jawab
# diupayakan : upaya
# {'balas': 'balas', '': '', 'min': 'min', 'cek': 'cek', 'keren': 'keren', 'mensolusikan': 'solusi', 'banget': 'banget', 'refund': 'refund', 'deposit': 'deposit', 'udah': 'udah', 'sebulan': 'bulan', 'dibaliki': 'balik', 'pas': 'pas', 'hubungi': 'hubung', 'estimasinya': 'estimasi', 'manaaa': 'manaaa', 'tiket': 'tiket', 'genjiiii': 'genjiiii', 'login': 'login', 'register': 'register', 'aplikasi': 'aplikasi', 'indihome': 'indihome', 'internet': 'internet', 'terpasang': 'pasang', 'rumah': 'rumah', 'hevy': 'hevy', 'anaknya': 'anak', 'lag': 'lag', 'tolong': 'tolong', 'wifi': 'wifi', 'ngelag': 'ngelag', 'mulu': 'mulu', 'kemarin': 'kemarin', 'ama': 'ama', 'aman': 'aman', 'udh': 'udh', 'melapor': 'lapor', 'via': 'via', 'twitter': 'twitter', 'myindihome': 'myindihome', 'tpi': 'tpi', 'respon': 'respon', 'skali': 'skali', 'dirumah': 'rumah', 'mati': 'mati', 'semingguan': 'minggu', 'nihh': 'nihh', 'los': 'los', 'perbaikan': 'baik', 'kelar': 'kelar', 'suka': 'suka', 'baca': 'baca', 'bermanfaat': 'manfaat', 'puyennggg': 'puyennggg', 'error': 'error', 'woii': 'woii', 'biaya': 'biaya', 'berlangganan': 'langgan', 'mbps': 'mbps', 'tambahan': 'tambah', 'halo': 'halo', 'kaka': 'kaka', 'mantaaappp': 'mantaaappp', 'broken': 'broken', 'teros': 'ros', 'berhenti': 'henti', 'kemana': 'mana', 'koordinasinya': 'koordinasi', 'byar': 'byar', 'tanggal': 'tanggal', 'kena': 'kena', 'denda': 'denda', 'betah': 'betah', 'lewati': 'lewat', 'pamdemi': 'pamdemi', 'membantu': 'bantu', 'app': 'app', 'kode': 'kode', 'otpnya': 'otpnya', 'salah': 'salah', 'trus': 'trus', 'sesuai': 'sesuai', 'sms': 'sms', 'terima': 'terima', 'malam': 'malam', 'njir': 'njir', 'ngelek': 'ngelek', 'butuh': 'butuh', 'kerja': 'kerja', 'pasang': 'pasang', 'gini': 'gin', 'lak': 'lak', 'paketan': 'paket', 'pulsa': 'pulsa', 'pemasangan': 'pasang', 'cepet': 'cepet', 'gitu': 'gitu', 'jaringannya': 'jaring', 'mantep': 'mantep', 'kenceng': 'kenceng', 'heran': 'heran', 'pelanggan': 'langgan', 'marah': 'marah', 'nice': 'nice', 'info': 'info', 'emang': 'emang', 'infonya': 'info', 'mantul': 'mantul', 'minnnnn': 'minnnnn', 'doong': 'doong', 'sangaat': 'sangaat', 'mantap': 'mantap', 'terimakasih': 'terimakasih', 'tips': 'tips', 'kak': 'kak', 'kartun': 'kartun', 'favorit': 'favorit', 'jaringan': 'jaring', 'peppayuan': 'peppayuan', 'pembayaran': 'bayar', 'oakai': 'oakai', 'ambil': 'ambil', 'cabut': 'cabut', 'uang': 'uang', 'jaminan': 'jamin', 'iklas': 'iklas', 'gmail': 'gmail', 'hadeuuuuuh': 'hadeuuuuuh', 'kecewa': 'kecewa', 'adminn': 'adminn', 'plis': 'plis', 'bls': 'bls', 'april': 'april', 'tangal': 'tangal', 'mei': 'mei', 'suruh': 'suruh', 'bayar': 'bayar', 'pagi': 'pagi', 'telpon': 'telpon', 'minggu': 'minggu', 'marna': 'marna', 'kuota': 'kuota', 'manfaat': 'manfaat', 'kontol': 'kontol', 'taiii': 'taiii', 'menginput': 'menginput', 'merekap': 'rekap', 'mengirim': 'kirim', 'absensi': 'absensi', 'asn': 'asn', 'batas': 'batas', 'ditentukan': 'tentu', 'kalinga': 'kalinga', 'kesulitan': 'sulit', 'gara': 'gara', 'ekspetasi': 'ekspetasi', 'nyaman': 'nyaman', 'khawatir': 'khawatir', 'habis': 'habis', 'realita': 'realita', 'erroran': 'erroran', 'krusial': 'krusial', 'beli': 'beli', 'data': 'data', 'terhormat': 'hormat', 'mengharuskan': 'harus', 'membayar': 'bayar', 'sanksi': 'sanksi', 'berlanggan': 'langgan', 'menyelesaikan': 'selesai', 'internetnya': 'internetnya', 'penanganannya': 'tangan', 'buruk': 'buruk', 'pelayanan': 'layan', 'nahan': 'nahan', 'putus': 'putus', 'menahan': 'tahan', 'sehat': 'sehat', 'engga': 'engga', 'mohon': 'mohon', 'thanks': 'thanks', 'inet': 'inet', 'tlp': 'tlp', 'fasilitas': 'fasilitas', 'bebas': 'bebas', 'akses': 'akses', 'useetvgo': 'useetvgo', 'lol': 'lol', 'bacot': 'bacot', 'alasan': 'alas', 'sinyal': 'sinyal', 'gimana': 'gimana', 'giliran': 'gilir', 'langsung': 'langsung', 'berenti': 'renti', 'langanan': 'langanan', 'tagihan': 'tagih', 'bulanan': 'bulan', 'iyah': 'iyah', 'tertagih': 'tagih', 'pemberitahuan': 'pemberitahuan', 'apapun': 'apa', 'gatau': 'gatau', 'bales': 'bales', 'balikin ...
# ------------------------
# Pandas Apply:   0%|          | 0/183 [00:00<?, ?it/s]
#                                                   text  \
# 0                                             balas dm
# 1                                           min cek dm
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                        genjiiii!!!!!
# ..                                                 ...
# 218                                     min cek dm yaa
# 219                                          keren min
# 220                                         cek dm kak
# 221                                    min cek dm dong
# 222  kapan refund deposit saya dikembalikan? janjin...
#
#                                          cleaning_text  \
# 0                                               balas
# 1                                             min cek
# 2                            keren mensolusikan banget
# 4    refund deposit udah hampir sebulan belum dibal...
# 5                                            genjiiii
# ..                                                 ...
# 218                                        min cek yaa
# 219                                          keren min
# 220                                            cek kak
# 221                                       min cek dong
# 222  kapan refund deposit saya dikembalikan janjiny...
#
#                                             tokenisasi  \
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                        [keren, mensolusikan, banget]
# 4    [refund, deposit, udah, hampir, sebulan, belum...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                   [min, cek, dong]
# 222  [kapan, refund, deposit, saya, dikembalikan, j...
#
#                                               stopword  \
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                        [keren, mensolusikan, banget]
# 4    [refund, deposit, udah, sebulan, dibaliki, pas...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                         [min, cek]
# 222  [refund, deposit, dikembalikan, janjinya, apri...
#
#                                               stemming
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                              [keren, solusi, banget]
# 4    [refund, deposit, udah, bulan, balik, pas, hub...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                         [min, cek]
# 222  [refund, deposit, kembali, janji, april, udah,...
#
# [183 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                            [balas, ]
# 1                                         [min, cek, ]
# 2                              [keren, solusi, banget]
# 4    [refund, deposit, udah, bulan, balik, pas, hub...
# 5                                         [genjiiii, ]
# ..                                                 ...
# 218                                    [min, cek, yaa]
# 219                                       [keren, min]
# 220                                         [cek, kak]
# 221                                         [min, cek]
# 222  [refund, deposit, kembali, janji, april, udah,...
#
# [183 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_5.xlsx')
