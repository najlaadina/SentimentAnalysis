# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0                                            Nice info
# 1       Emang paling gampang beli add on di myindihome
# 2    Maaf belum menerima username dan password nya ...
# 3    Gimana ini min saya sudah add on WiFi seamless...
# 4                                   CACAT GA MEMUASKAN
# ..                                                 ...
# 160                         DM saya mohon di bales Min
# 161                                 makasih infonya ya
# 162  Mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      Malas pakai indihome sinyal selalu tdk stabil
#
# [165 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 4

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0                                            Nice info
# 1       Emang paling gampang beli add on di myindihome
# 2    Maaf belum menerima username dan password nya ...
# 3    Gimana ini min saya sudah add on WiFi seamless...
# 4                                   CACAT GA MEMUASKAN
# ..                                                 ...
# 160                         DM saya mohon di bales Min
# 161                                 makasih infonya ya
# 162  Mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      Malas pakai indihome sinyal selalu tdk stabil
#
# [157 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0                                            nice info
# 1       emang paling gampang beli add on di myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add on wifi seamless...
# 4                                   cacat ga memuaskan
# ..                                                 ...
# 160                         dm saya mohon di bales min
# 161                                 makasih infonya ya
# 162  mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      malas pakai indihome sinyal selalu tdk stabil
#
# [157 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0                                            nice info
# 1       emang paling gampang beli add on di myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add on wifi seamless...
# 4                                   cacat ga memuaskan
# ..                                                 ...
# 160                         dm saya mohon di bales min
# 161                                 makasih infonya ya
# 162  mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                          cleaning_text
# 0                                            nice info
# 1             emang paling gampang beli add myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add wifi seamless ga...
# 4                                      cacat memuaskan
# ..                                                 ...
# 160                               saya mohon bales min
# 161                                   makasih infonya
# 162  mau tanya cara merubah nomor terdaftar indihom...
# 163   kali bikin aduan lom ada progres perbaikan ad...
# 164      malas pakai indihome sinyal selalu tdk stabil
#
# [157 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0                                            nice info
# 1       emang paling gampang beli add on di myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add on wifi seamless...
# 4                                   cacat ga memuaskan
# ..                                                 ...
# 160                         dm saya mohon di bales min
# 161                                 makasih infonya ya
# 162  mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                          cleaning_text  \
# 0                                            nice info
# 1             emang paling gampang beli add myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add wifi seamless ga...
# 4                                      cacat memuaskan
# ..                                                 ...
# 160                               saya mohon bales min
# 161                                   makasih infonya
# 162  mau tanya cara merubah nomor terdaftar indihom...
# 163   kali bikin aduan lom ada progres perbaikan ad...
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                             tokenisasi
# 0                                         [nice, info]
# 1      [emang, paling, gampang, beli, add, myindihome]
# 2    [maaf, belum, menerima, username, dan, passwor...
# 3    [gimana, ini, min, saya, sudah, add, wifi, sea...
# 4                                   [cacat, memuaskan]
# ..                                                 ...
# 160                        [, saya, mohon, bales, min]
# 161                               [makasih, infonya, ]
# 162  [mau, tanya, cara, merubah, nomor, terdaftar, ...
# 163  [, kali, bikin, aduan, lom, ada, progres, perb...
# 164  [malas, pakai, indihome, sinyal, selalu, tdk, ...
#
# [157 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0                                            nice info
# 1       emang paling gampang beli add on di myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add on wifi seamless...
# 4                                   cacat ga memuaskan
# ..                                                 ...
# 160                         dm saya mohon di bales min
# 161                                 makasih infonya ya
# 162  mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                          cleaning_text  \
# 0                                            nice info
# 1             emang paling gampang beli add myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add wifi seamless ga...
# 4                                      cacat memuaskan
# ..                                                 ...
# 160                               saya mohon bales min
# 161                                   makasih infonya
# 162  mau tanya cara merubah nomor terdaftar indihom...
# 163   kali bikin aduan lom ada progres perbaikan ad...
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                             tokenisasi  \
# 0                                         [nice, info]
# 1      [emang, paling, gampang, beli, add, myindihome]
# 2    [maaf, belum, menerima, username, dan, passwor...
# 3    [gimana, ini, min, saya, sudah, add, wifi, sea...
# 4                                   [cacat, memuaskan]
# ..                                                 ...
# 160                        [, saya, mohon, bales, min]
# 161                               [makasih, infonya, ]
# 162  [mau, tanya, cara, merubah, nomor, terdaftar, ...
# 163  [, kali, bikin, aduan, lom, ada, progres, perb...
# 164  [malas, pakai, indihome, sinyal, selalu, tdk, ...
#
#                                               stopword
# 0                                         [nice, info]
# 1              [emang, gampang, beli, add, myindihome]
# 2                 [maaf, menerima, username, password]
# 3    [gimana, min, add, wifi, seamless, gagal, mene...
# 4                                   [cacat, memuaskan]
# ..                                                 ...
# 160                              [, mohon, bales, min]
# 161                               [makasih, infonya, ]
# 162  [merubah, nomor, terdaftar, indihome, nomor, a...
# 163  [, kali, aduan, lom, progres, perbaikan, aduan...
# 164           [malas, pakai, indihome, sinyal, stabil]
#
# [157 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 561
# ------------------------
# nice : nice
# info : info
# emang : emang
# gampang : gampang
# beli : beli
# add : add
# myindihome : myindihome
# maaf : maaf
# menerima : terima
# username : username
# password : password
# gimana : gimana
# min : min
# wifi : wifi
# seamless : seamless
# gagal : gagal
# dilancarkan : lancar
# nlp : nlp
# nyambung : nyambung
#  :
# cacat : cacat
# memuaskan : muas
# miskin : miskin
# woi : woi
# anak : anak
# ngelag : ngelag
# trs : trs
# cafat : cafat
# profider : profider
# nambah : nambah
# smooa : smooa
# cek : cek
# berhenti : henti
# langganan : langgan
# tlp : tlp
# gmn : gmn
# halo : halo
# verifikasi : verifikasi
# udah : udah
# telfon : telfon
# duhh : duhh
# tagihan : tagih
# indihome : indihome
# konfirmasi : konfirmasi
# penambahan : tambah
# lakukan : laku
# pulsa : pulsa
# sampe : sampe
# abis : abis
# telpon : telpon
# keluhan : keluh
# terputus : putus
# sblm : sblm
# solusi : solusi
# mengulang : ulang
# penyelesaian : selesai
# berjalan : jalan
# angka : angka
# beda : beda
# daftarkan : daftar
# yey : yey
# berat : berat
# browsernya : browser
# browser : browser
# cepat : cepat
# mantap : mantap
# performa : performa
# keren : keren
# bener : bener
# cpt : cpt
# bagus : bagus
# tipsnya : tipsnya
# lancar : lancar
# jaya : jaya
# yeay : yeay
# mesolusikan : mesolusikan
# yuhuu : yuhuu
# kenceng : kenceng
# inii : ini
# sekolah : sekolah
# banget : banget
# ngebut : ngebut
# internetnya : internetnya
# tetep : tetep
# lemod : lemod
# panggil : panggil
# teknisi : teknisi
# lemot : lot
# suwex : suwex
# bulanan : bulan
# mahal : mahal
# koneksi : koneksi
# down : down
# mingguan : minggu
# progress : progress
# penanganan : tangan
# jam : jam
# gaada : gaada
# kompensasi : kompensasi
# contohnya : contoh
# rumah : rumah
# minggu : minggu
# gangguan : ganggu
# internet : internet
# paket : paket
# sinyalnya : sinyal
# stabil : stabil
# gitu : gitu
# ilangan : ilangan
# lelah : lelah
# sinyal : sinyal
# hilang : hilang
# jaringan : jaring
# lapor : lapor
# sia : sia
# bayar : bayar
# telat : telat
# sehari : hari
# blokir : blokir
# giliran : gilir
# butuh : butuh
# kerja : kerja
# gini : gin
# dikantor : kantor
# tutup : tutup
# chat : chat
# app : app
# proses : proses
# respon : respon
# sibuk : sibuk
# malu : malu
# alamat : alamat
# pindah : pindah
# perum : perum
# permata : permata
# asri : asri
# karang : karang
# anyar : anyar
# lampung : lampung
# selatan : selatan
# labuhan : labuh
# ratu : ratu
# raya : raya
# bandar : bandar
# sesuai : sesuai
# ktp : ktp
# syaratnya : syarat
# terimakasih : terimakasih
# berehenti : berehenti
# berlangganan : langgan
# stop : stop
# layanan : layan
# musti : musti
# upload : upload
# fto : fto
# kemane : kemane
# mhon : mhon
# rmh : rmh
# blg : blg
# lbh : lbh
# meter : meter
# alesannya : alesannya
# fiber : fiber
# tersedia : sedia
# udahan : udahan
# suru : suru
# byr : byr
# denda : denda
# ribet : ribet
# plasa : plasa
# telkomsel : telkomsel
# bsa : bsa
# via : via
# woy : woy
# udh : udh
# ppn : ppn
# gabisa : gabisa
# dipake : dipake
# kaya : kaya
# mai : mai
# tgl : tgl
# mati : mati
# pemeliharaan : pelihara
# blum : blum
# hidup : hidup
# tolong : tolong
# minn : minn
# fast : fast
# respons : respons
# sekalinya : sekali
# ngerespon : ngerespon
# bertele : tele
# tele : tele
# selamat : selamat
# malam : malam
# mlm : mlm
# hai : hai
# rubah : rubah
# trims : trims
# bayaran : bayar
# pling : pling
# buruk : buruk
# dasar : dasar
# telepon : telepon
# mulu : mulu
# cabut : cabut
# blm : blm
# setahun : tahun
# nanggung : nanggung
# dendanya : denda
# sejuta : juta
# cuy : cuy
# tolol : tolol
# batas : batas
# brp : brp
# admin : admin
# smart : smart
# tulisan : tulis
# terbatas : batas
# smartphone : smartphone
# mohon : mohon
# bantuannya : bantu
# langkah : langkah
# diatas : atas
# ngak : ngak
# gambar : gambar
# sayanudah : sayanudah
# lambat : lambat
# bangat : bangat
# live : live
# akses : akses
# notif : notif
# loyalty : loyalty
# menaikan : naik
# kecepatan : cepat
# mbps : mbps
# biaya : biaya
# tambahan : tambah
# thanks : thanks
# seneng : neng
# open : open
# channel : channel
# kemarin : kemarin
# makasih : makasih
# chanel : chanel
# buka : buka
# iya : iya
# aktifin : aktifin
# tpi : tpi
# ditutup : tutup
# habis : habis
# non : non
# aktifkan : aktif
# masuk : masuk
# gratis : gratis
# all : all
# aktif : aktif
# thx : thx
# terbuka : buka
# cchanel : cchanel
# champion : champion
# please : please
# program : program
# diperpanjang : panjang
# juli : juli
# syarat : syarat
# ketentuan : tentu
# auto : auto
# renewal : renewal
# lho : lho
# pasang : pasang
# pelayanan : layan
# kalah : kalah
# menyayangkan : sayang
# uploadnya : uploadnya
# banding : banding
# produk : produk
# competitor : competitor
# harga : harga
# relatif : relatif
# murah : murah
# berharap : harap
# meningkatkan : tingkat
# kwalitas : kwalitas
# bersaing : saing
# competitornya : competitornya
# malem : malem
# langsung : langsung
# ngga : ngga
# petugas : tugas
# ketiang : tiang
# listrik : listrik
# bermasalah : masalah
# instruksikan : instruksi
# dilapangan : lapang
# kabel : kabel
# optik : optik
# ditiang : tiang
# ditindak : tindak
# lanjuti : lanjut
# besok : besok
# ujian : uji
# piano : piano
# online : online
# tolongan : tolong
# diakses : akses
# dirumah : rumah
# kemaren : kemaren
# siang : siang
# masin : masin
# komplen : komplen
# ditanggap : tanggap
# pembayaran : bayar
# mengecewakan : kecewa
# kak : kak
# infonya : info
# trus : trus
# berkedip : kedip
# warna : warna
# merah : merah
# baca : baca
# main : main
# game : game
# knp : knp
# kdg : kdg
# pas : pas
# gerak : gerak
# aman : aman
# pokonya : poko
# bermanfaat : manfaat
# pintar : pintar
# cocok : cocok
# keamanan : aman
# promo : promo
# wilayah : wilayah
# cikupa : cikupa
# cctv : cctv
# deh : deh
# fiturnya : fiturnya
# indiehome : indiehome
# perbulannya : bulan
# lag : lag
# indihime : indihime
# pura : pura
# suruh : suruh
# operator : operator
# mencoba : coba
# dta : dta
# dpt : dpt
# permudah : mudah
# kasih : kasih
# bukti : bukti
# perhatian : perhati
# kmrn : kmrn
# penghentian : henti
# cam : cam
# lokasi : lokasi
# sya : sya
# daftarkannya : daftar
# bantu : bantu
# dtg : dtg
# orang : orang
# kontak : kontak
# pembayarannya : bayar
# tinggal : tinggal
# transfernya : transfer
# dpat : dpat
# serius : serius
# tqq : tqq
# mimin : mimin
# sore : sore
# kerumah : rumah
# ganti : ganti
# ngerasain : ngerasain
# bwt : bwt
# loading : loading
# video : video
# malamm : malamm
# membantu : bantu
# tanggal : tanggal
# skrg : skrg
# telp : telp
# kali : kali
# cust : cust
# gda : gda
# tindakan : tindak
# diksh : diksh
# tiket : tiket
# dateng : dateng
# pemakai : pakai
# rugi : rugi
# dipakai : pakai
# kenyamanan : nyaman
# pengguna : guna
# wilaya : wilaya
# bogor : bogor
# barat : barat
# sindang : sindang
# barang : barang
# terngelag : terngelag
# ajg : ajg
# oke : oke
# muka : muka
# jalan : jalan
# wkwkwk : wkwkwk
# merugikan : rugi
# plis : plis
# benerin : benerin
# download : download
# warzone : warzone
# kbps : kbps
# haloooo : haloooo
# terisolirrr : terisolirrr
# bales : bales
# catchplay : catchplay
# repeat : repeat
# asyik : asyik
# wahh : wahh
# mudah : mudah
# seru : seru
# film : film
# tips : tips
# pemasangan : pasang
# iflix : iflix
# subtitle : subtitle
# terdengar : dengar
# manajemen : manajemen
# deposit : deposit
# dikembalikan : kembali
# dapet : dapet
# terpilih : pilih
# keceptan : keceptan
# tod : tod
# kel : kel
# bugel : bugel
# kec : kec
# karawaci : karawaci
# tangerang : tangerang
# pls : pls
# yth : yth
# ppkm : ppkm
# ilmu : ilmu
# pengetahuan : tahu
# bentuk : bentuk
# kepedulian : peduli
# masyarakat : masyarakat
# pelanggan : langgan
# kemana : mana
# menemani : tani
# isoman : isoman
# pertimbangkan : timbang
# terima : terima
# perbulan : bulan
# klau : klau
# mpps : mpps
# kamis : kamis
# juni : juni
# instalasi : instalasi
# diaktifkan : aktif
# tehnisi : tehnisi
# sistem : sistem
# error : error
# menunggu : tunggu
# lupakan : lupa
# wow : wow
# bergejolak : gejolak
# kena : kena
# cari : cari
# puteran : puter
# alias : alias
# lola : lola
# berujung : ujung
# pakai : pakai
# review : review
# suka : suka
# ngadat : ngadat
# wfh : wfh
# mengcover : mengcover
# area : area
# andaikan : andai
# tlg : tlg
# modem : modem
# lampu : lampu
# los : los
# menyala : nyala
# diperbaiki : baik
# leptop : leptop
# tab : tab
# penangann : penangann
# berkali : kali
# tetang : tetang
# berantakan : beranta
# bln : bln
# penangan : nang
# tugas : tugas
# tolonglah : tolong
# perbaiki : baik
# secepatnya : cepat
# trimah : trimah
# kpn : kpn
# losssss : losssss
# bsk : bsk
# jga : jga
# berabe : berabe
# mna : mna
# daring : daring
# layanannya : layan
# ampuun : ampuun
# alamin : alamin
# pagi : pagi
# smpe : smpe
# restart : restart
# care : care
# follow : follow
# zonk : zonk
# jdi : jdi
# coba : coba
# mengalami : alami
# lihat : lihat
# box : box
# gmna : gmna
# wifinya : wifinya
# lost : lost
# udaha : udaha
# kuliah : kuliah
# repot : repot
# knpa : knpa
# bca : bca
# nelpon : nelpon
# mesin : mesin
# smlm : smlm
# stb : stb
# matikan : mati
# menit : menit
# nyalakan : nyala
# msh : msh
# indikator : indikator
# berwarna : warna
# hijau : hijau
# solusinya : solusi
# dicek : cek
# pencet : pencet
# seting : ting
# muncul : muncul
# aplikasi : aplikasi
# terpasang : pasang
# merubah : rubah
# nomor : nomor
# terdaftar : daftar
# tsb : tsb
# aduan : adu
# lom : lom
# progres : progres
# perbaikan : baik
# ngaco : ngaco
# link : link
# ksh : ksh
# tertulis : tulis
# kenyataannya : nyata
# nol : nol
# malas : malas
# {'nice': 'nice', 'info': 'info', 'emang': 'emang', 'gampang': 'gampang', 'beli': 'beli', 'add': 'add', 'myindihome': 'myindihome', 'maaf': 'maaf', 'menerima': 'terima', 'username': 'username', 'password': 'password', 'gimana': 'gimana', 'min': 'min', 'wifi': 'wifi', 'seamless': 'seamless', 'gagal': 'gagal', 'dilancarkan': 'lancar', 'nlp': 'nlp', 'nyambung': 'nyambung', '': '', 'cacat': 'cacat', 'memuaskan': 'muas', 'miskin': 'miskin', 'woi': 'woi', 'anak': 'anak', 'ngelag': 'ngelag', 'trs': 'trs', 'cafat': 'cafat', 'profider': 'profider', 'nambah': 'nambah', 'smooa': 'smooa', 'cek': 'cek', 'berhenti': 'henti', 'langganan': 'langgan', 'tlp': 'tlp', 'gmn': 'gmn', 'halo': 'halo', 'verifikasi': 'verifikasi', 'udah': 'udah', 'telfon': 'telfon', 'duhh': 'duhh', 'tagihan': 'tagih', 'indihome': 'indihome', 'konfirmasi': 'konfirmasi', 'penambahan': 'tambah', 'lakukan': 'laku', 'pulsa': 'pulsa', 'sampe': 'sampe', 'abis': 'abis', 'telpon': 'telpon', 'keluhan': 'keluh', 'terputus': 'putus', 'sblm': 'sblm', 'solusi': 'solusi', 'mengulang': 'ulang', 'penyelesaian': 'selesai', 'berjalan': 'jalan', 'angka': 'angka', 'beda': 'beda', 'daftarkan': 'daftar', 'yey': 'yey', 'berat': 'berat', 'browsernya': 'browser', 'browser': 'browser', 'cepat': 'cepat', 'mantap': 'mantap', 'performa': 'performa', 'keren': 'keren', 'bener': 'bener', 'cpt': 'cpt', 'bagus': 'bagus', 'tipsnya': 'tipsnya', 'lancar': 'lancar', 'jaya': 'jaya', 'yeay': 'yeay', 'mesolusikan': 'mesolusikan', 'yuhuu': 'yuhuu', 'kenceng': 'kenceng', 'inii': 'ini', 'sekolah': 'sekolah', 'banget': 'banget', 'ngebut': 'ngebut', 'internetnya': 'internetnya', 'tetep': 'tetep', 'lemod': 'lemod', 'panggil': 'panggil', 'teknisi': 'teknisi', 'lemot': 'lot', 'suwex': 'suwex', 'bulanan': 'bulan', 'mahal': 'mahal', 'koneksi': 'koneksi', 'down': 'down', 'mingguan': 'minggu', 'progress': 'progress', 'penanganan': 'tangan', 'jam': 'jam', 'gaada': 'gaada', 'kompensasi': 'kompensasi', 'contohnya': 'contoh', 'rumah': 'rumah', 'minggu': 'minggu', 'gangguan': 'ganggu', 'internet': 'internet', 'paket': 'paket', 'sinyalnya': 'sinyal', 'stabil': 'stabil', 'gitu': 'gitu', 'ilangan': 'ilangan', 'lelah': 'lelah', 'sinyal': 'sinyal', 'hilang': 'hilang', 'jaringan': 'jaring', 'lapor': 'lapor', 'sia': 'sia', 'bayar': 'bayar', 'telat': 'telat', 'sehari': 'hari', 'blokir': 'blokir', 'giliran': 'gilir', 'butuh': 'butuh', 'kerja': 'kerja', 'gini': 'gin', 'dikantor': 'kantor', 'tutup': 'tutup', 'chat': 'chat', 'app': 'app', 'proses': 'proses', 'respon': 'respon', 'sibuk': 'sibuk', 'malu': 'malu', 'alamat': 'alamat', 'pindah': 'pindah', 'perum': 'perum', 'permata': 'permata', 'asri': 'asri', 'karang': 'karang', 'anyar': 'anyar', 'lampung': 'lampung', 'selatan': 'selatan', 'labuhan': 'labuh', 'ratu': 'ratu', 'raya': 'raya', 'bandar': 'bandar', 'sesuai': 'sesuai', 'ktp': 'ktp', 'syaratnya': 'syarat', 'terimakasih': 'terimakasih', 'berehenti': 'berehenti', 'berlangganan': 'langgan', 'stop': 'stop', 'layanan': 'layan', 'musti': 'musti', 'upload': 'upload', 'fto': 'fto', 'kemane': 'kemane', 'mhon': 'mhon', 'rmh': 'rmh', 'blg': 'blg', 'lbh': 'lbh', 'meter': 'meter', 'alesannya': 'alesannya', 'fiber': 'fiber', 'tersedia': 'sedia', 'udahan': 'udahan', 'suru': 'suru', 'byr': 'byr', 'denda': 'denda', 'ribet': 'ribet', 'plasa': 'plasa', 'telkomsel': 'telkomsel', 'bsa': 'bsa', 'via': 'via', 'woy': 'woy', 'udh': 'udh', 'ppn': 'ppn', 'gabisa': 'gabisa', 'dipake': 'dipake', 'kaya': 'kaya', 'mai': 'mai', 'tgl': 'tgl', 'mati': 'mati', 'pemeliharaan': 'pelihara', 'blum': 'blum', 'hidup': 'hidup', 'tolong': 'tolong', 'minn': 'minn', 'fast': 'fast', 'respons': 'respons', 'sekalinya': 'sekali', 'ngerespon': 'ngerespon', 'bertele': 'tele', 'tele': 'tele', 'selamat': 'selamat', 'malam': 'malam', 'mlm': 'mlm', 'hai': 'hai', 'rubah': 'rubah', 'trims': 'trims', 'bayaran': 'bayar', 'pling': 'pling', 'buruk': 'buruk', 'dasar': 'dasar', 'telepon': 'telepon', 'mulu': 'mulu', 'cabut': 'cabut', 'blm': 'blm', 'setahun': 'tahun', 'nanggung': 'nanggung', 'dend ...
# ------------------------
# Pandas Apply:   0%|          | 0/157 [00:00<?, ?it/s]
#                                                   text  \
# 0                                            nice info
# 1       emang paling gampang beli add on di myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add on wifi seamless...
# 4                                   cacat ga memuaskan
# ..                                                 ...
# 160                         dm saya mohon di bales min
# 161                                 makasih infonya ya
# 162  mau tanya, cara merubah nomor hp yg terdaftar ...
# 163  2 kali bikin aduan lom ada progres perbaikan.....
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                          cleaning_text  \
# 0                                            nice info
# 1             emang paling gampang beli add myindihome
# 2    maaf belum menerima username dan password nya ...
# 3    gimana ini min saya sudah add wifi seamless ga...
# 4                                      cacat memuaskan
# ..                                                 ...
# 160                               saya mohon bales min
# 161                                   makasih infonya
# 162  mau tanya cara merubah nomor terdaftar indihom...
# 163   kali bikin aduan lom ada progres perbaikan ad...
# 164      malas pakai indihome sinyal selalu tdk stabil
#
#                                             tokenisasi  \
# 0                                         [nice, info]
# 1      [emang, paling, gampang, beli, add, myindihome]
# 2    [maaf, belum, menerima, username, dan, passwor...
# 3    [gimana, ini, min, saya, sudah, add, wifi, sea...
# 4                                   [cacat, memuaskan]
# ..                                                 ...
# 160                        [, saya, mohon, bales, min]
# 161                               [makasih, infonya, ]
# 162  [mau, tanya, cara, merubah, nomor, terdaftar, ...
# 163  [, kali, bikin, aduan, lom, ada, progres, perb...
# 164  [malas, pakai, indihome, sinyal, selalu, tdk, ...
#
#                                               stopword  \
# 0                                         [nice, info]
# 1              [emang, gampang, beli, add, myindihome]
# 2                 [maaf, menerima, username, password]
# 3    [gimana, min, add, wifi, seamless, gagal, mene...
# 4                                   [cacat, memuaskan]
# ..                                                 ...
# 160                              [, mohon, bales, min]
# 161                               [makasih, infonya, ]
# 162  [merubah, nomor, terdaftar, indihome, nomor, a...
# 163  [, kali, aduan, lom, progres, perbaikan, aduan...
# 164           [malas, pakai, indihome, sinyal, stabil]
#
#                                               stemming
# 0                                         [nice, info]
# 1              [emang, gampang, beli, add, myindihome]
# 2                   [maaf, terima, username, password]
# 3    [gimana, min, add, wifi, seamless, gagal, teri...
# 4                                        [cacat, muas]
# ..                                                 ...
# 160                              [, mohon, bales, min]
# 161                                  [makasih, info, ]
# 162  [rubah, nomor, daftar, indihome, nomor, aktif,...
# 163  [, kali, adu, lom, progres, baik, adu, ngaco, ...
# 164           [malas, pakai, indihome, sinyal, stabil]
#
# [157 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                         [nice, info]
# 1              [emang, gampang, beli, add, myindihome]
# 2                   [maaf, terima, username, password]
# 3    [gimana, min, add, wifi, seamless, gagal, teri...
# 4                                        [cacat, muas]
# ..                                                 ...
# 160                              [, mohon, bales, min]
# 161                                  [makasih, info, ]
# 162  [rubah, nomor, daftar, indihome, nomor, aktif,...
# 163  [, kali, adu, lom, progres, baik, adu, ngaco, ...
# 164           [malas, pakai, indihome, sinyal, stabil]
#
# [157 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_7.xlsx')
