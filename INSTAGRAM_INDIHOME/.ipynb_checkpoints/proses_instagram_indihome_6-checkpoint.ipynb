# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0    mantep di ingetin nih \n\n#AktivitasTanpaBatas...
# 1                                                  Ajg
# 2                                                  Ajg
# 3                        Jaringan kek babi gitu belagu
# 4             Mudahan cepet bangkrut tu perusahan bgst
# ..                                                 ...
# 112                   waw, sekarang udah gk panik lagi
# 113                                             Cek dm
# 114  Min kalo tentang channel tidak bisa akses cth ...
# 115  Sudah di coba spt panduan tetap gak bisa..moho...
# 116                            Kapan di berhentikan kk
#
# [117 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 4

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0    mantep di ingetin nih \n\n#AktivitasTanpaBatas...
# 3                        Jaringan kek babi gitu belagu
# 4             Mudahan cepet bangkrut tu perusahan bgst
# 5                                            Dasar ajg
# 6                  Emang babi, mampus aja lu semua ajg
# ..                                                 ...
# 111               Kak... Internet tiba2 mati kenapa ya
# 112                   waw, sekarang udah gk panik lagi
# 114  Min kalo tentang channel tidak bisa akses cth ...
# 115  Sudah di coba spt panduan tetap gak bisa..moho...
# 116                            Kapan di berhentikan kk
#
# [109 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0    mantep di ingetin nih \n\n#aktivitastanpabatas...
# 3                        jaringan kek babi gitu belagu
# 4             mudahan cepet bangkrut tu perusahan bgst
# 5                                            dasar ajg
# 6                  emang babi, mampus aja lu semua ajg
# ..                                                 ...
# 111               kak... internet tiba2 mati kenapa ya
# 112                   waw, sekarang udah gk panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah di coba spt panduan tetap gak bisa..moho...
# 116                            kapan di berhentikan kk
#
# [109 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0    mantep di ingetin nih \n\n#aktivitastanpabatas...
# 3                        jaringan kek babi gitu belagu
# 4             mudahan cepet bangkrut tu perusahan bgst
# 5                                            dasar ajg
# 6                  emang babi, mampus aja lu semua ajg
# ..                                                 ...
# 111               kak... internet tiba2 mati kenapa ya
# 112                   waw, sekarang udah gk panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah di coba spt panduan tetap gak bisa..moho...
# 116                            kapan di berhentikan kk
#
#                                          cleaning_text
# 0                                   mantep ingetin nih
# 3                        jaringan kek babi gitu belagu
# 4                mudahan cepet bangkrut perusahan bgst
# 5                                            dasar ajg
# 6                      emang babi mampus aja semua ajg
# ..                                                 ...
# 111                    kak internet tiba  mati kenapa
# 112                       waw sekarang udah panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah coba spt panduan tetap gak bisa mohon bantu
# 116                                 kapan berhentikan
#
# [109 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0    mantep di ingetin nih \n\n#aktivitastanpabatas...
# 3                        jaringan kek babi gitu belagu
# 4             mudahan cepet bangkrut tu perusahan bgst
# 5                                            dasar ajg
# 6                  emang babi, mampus aja lu semua ajg
# ..                                                 ...
# 111               kak... internet tiba2 mati kenapa ya
# 112                   waw, sekarang udah gk panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah di coba spt panduan tetap gak bisa..moho...
# 116                            kapan di berhentikan kk
#
#                                          cleaning_text  \
# 0                                   mantep ingetin nih
# 3                        jaringan kek babi gitu belagu
# 4                mudahan cepet bangkrut perusahan bgst
# 5                                            dasar ajg
# 6                      emang babi mampus aja semua ajg
# ..                                                 ...
# 111                    kak internet tiba  mati kenapa
# 112                       waw sekarang udah panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah coba spt panduan tetap gak bisa mohon bantu
# 116                                 kapan berhentikan
#
#                                             tokenisasi
# 0                               [mantep, ingetin, nih]
# 3                  [jaringan, kek, babi, gitu, belagu]
# 4          [mudahan, cepet, bangkrut, perusahan, bgst]
# 5                                         [dasar, ajg]
# 6               [emang, babi, mampus, aja, semua, ajg]
# ..                                                 ...
# 111              [kak, internet, tiba, mati, kenapa, ]
# 112                 [waw, sekarang, udah, panik, lagi]
# 114  [min, kalo, tentang, channel, tidak, bisa, aks...
# 115  [sudah, coba, spt, panduan, tetap, gak, bisa, ...
# 116                             [kapan, berhentikan, ]
#
# [109 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0    mantep di ingetin nih \n\n#aktivitastanpabatas...
# 3                        jaringan kek babi gitu belagu
# 4             mudahan cepet bangkrut tu perusahan bgst
# 5                                            dasar ajg
# 6                  emang babi, mampus aja lu semua ajg
# ..                                                 ...
# 111               kak... internet tiba2 mati kenapa ya
# 112                   waw, sekarang udah gk panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah di coba spt panduan tetap gak bisa..moho...
# 116                            kapan di berhentikan kk
#
#                                          cleaning_text  \
# 0                                   mantep ingetin nih
# 3                        jaringan kek babi gitu belagu
# 4                mudahan cepet bangkrut perusahan bgst
# 5                                            dasar ajg
# 6                      emang babi mampus aja semua ajg
# ..                                                 ...
# 111                    kak internet tiba  mati kenapa
# 112                       waw sekarang udah panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah coba spt panduan tetap gak bisa mohon bantu
# 116                                 kapan berhentikan
#
#                                             tokenisasi  \
# 0                               [mantep, ingetin, nih]
# 3                  [jaringan, kek, babi, gitu, belagu]
# 4          [mudahan, cepet, bangkrut, perusahan, bgst]
# 5                                         [dasar, ajg]
# 6               [emang, babi, mampus, aja, semua, ajg]
# ..                                                 ...
# 111              [kak, internet, tiba, mati, kenapa, ]
# 112                 [waw, sekarang, udah, panik, lagi]
# 114  [min, kalo, tentang, channel, tidak, bisa, aks...
# 115  [sudah, coba, spt, panduan, tetap, gak, bisa, ...
# 116                             [kapan, berhentikan, ]
#
#                                               stopword
# 0                                    [mantep, ingetin]
# 3                  [jaringan, kek, babi, gitu, belagu]
# 4                [mudahan, cepet, bangkrut, perusahan]
# 5                                         [dasar, ajg]
# 6                           [emang, babi, mampus, ajg]
# ..                                                 ...
# 111                            [kak, internet, mati, ]
# 112                                 [waw, udah, panik]
# 114  [min, channel, akses, cth, transtv, indosiar, ...
# 115                 [coba, spt, panduan, mohon, bantu]
# 116                                    [berhentikan, ]
#
# [109 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 319
# ------------------------
# mantep : mantep
# ingetin : ingetin
# jaringan : jaring
# kek : kek
# babi : babi
# gitu : gitu
# belagu : belagu
# mudahan : mudah
# cepet : cepet
# bangkrut : bangkrut
# perusahan : usah
# dasar : dasar
# ajg : ajg
# emang : emang
# mampus : mampus
# indohome : indohome
# lonte : lonte
# bagus : bagus
# gausah : gausah
# sok : sok
# jualan : jual
# setan : setan
# malem : malem
# gangguan : ganggu
#  :
# hallo : hallo
# tindak : tindak
# keluhan : keluh
# bayaran : bayar
# gapernah : gapernah
# telat : telat
# min : min
# yaa : yaa
# mengecewakan : kecewa
# sekaliiii : sekaliiii
# indihome : indihome
# paket : paket
# promo : promo
# trmksh : trmksh
# pasang : pasang
# gimna : gimna
# siapp : siapp
# bayar : bayar
# cek : cek
# fup : fup
# mbps : mbps
# kak : kak
# tuuh : tuuh
# perbaikan : baik
# masal : masal
# singyal : singyal
# mangkin : mangkin
# lelet : lelet
# terimakasih : terimakasih
# infonya : info
# comment : comment
# pemindahan : pindah
# kabel : kabel
# pindh : pindh
# haruskah : harus
# laporan : lapor
# kantor : kantor
# terdekat : dekat
# nice : nice
# mimin : mimin
# pantau : pantau
# pengguna : guna
# aktif : aktif
# udah : udah
# confirm : confirm
# berhenti : henti
# membantu : bantu
# laggggggggggggggggg : laggggggggggggggggg
# woiiiiii : woiiiiii
# lagggggggggggggggg : lagggggggggggggggg
# lagggggggggggggggggggggggggg : lagggggggggggggggggggggggggg
# lagggygyggggg : lagggygyggggg
# mudah : mudah
# modem : modem
# zte : zte
# kolom : kolom
# ssid : ssid
# keterangan : terang
# security : security
# type : type
# wpa : wpa
# password : password
# disamping : samping
# tulisan : tulis
# show : show
# passwordnya : passwordnya
# setel : setel
# ulang : ulang
# informasinya : informasi
# berguna : guna
# banget : banget
# username : username
# lupa : lupa
# mensolusikan : solusi
# solusi : solusi
# bermanfaat : manfaat
# keren : keren
# tips : tips
# ngepush : ngepush
# turun : turun
# baca : baca
# kualitas : kualitas
# jelek : jelek
# pelayanan : layan
# jawabannya : jawab
# yogya : yogya
# selamat : selamat
# siang : siang
# bgm : bgm
# tagihan : tagih
# pelanggan : langgan
# pasca : pasca
# banjir : banjir
# seroja : seroja
# alami : alami
# tetangga : tetangga
# mengalami : alami
# musibah : musibah
# spt : spt
# membayar : bayar
# sdgkan : sdgkan
# msh : msh
# internet : internet
# matinyala : matinyala
# minggu : minggu
# sampe : sampe
# belasan : bas
# teknisi : teknisi
# dateng : dateng
# bergantian : ganti
# gantian : ganti
# error : error
# seminggu : minggu
# pas : pas
# tanggal : tanggal
# sungguh : sungguh
# iklas : iklas
# gwwww : gwwww
# telpon : telpon
# twitter : twitter
# ngarus : ngarus
# maaf : maaf
# template : template
# muluuuuu : muluuuuu
# donlot : donlot
# link : link
# mohon : mohon
# mei : mei
# juni : juni
# akibat : akibat
# terdampak : dampak
# tks : tks
# lemot : lot
# admin : admin
# tolong : tolong
# bales : bales
# sya : sya
# log : log
# out : out
# clear : clear
# cache : cache
# aplikasi : aplikasi
# tetep : tetep
# dibayar : bayar
# dilunasi : lunas
# terima : terima
# kasih : kasih
# beres : beres
# nama : nama
# ari : ari
# wibowo : wibowo
# stb : stb
# gimana : gimana
# woy : woy
# knp : knp
# masuk : masuk
# myindhome : myindhome
# sesuai : sesuai
# verivikasi : verivikasi
# kirim : kirim
# via : via
# sms : sms
# tipsnya : tipsnya
# bingung : bingung
# sip : sip
# mengatasi : atas
# solusinya : solusi
# yeay : yeay
# informasi : informasi
# ribet : ribet
# yes : yes
# kemudahan : mudah
# simple : simple
# edukasi : edukasi
# mantap : mantap
# dapet : dapet
# deh : deh
# dicoba : coba
# mantul : mantul
# menjadikan : jadi
# gampang : gampang
# lapor : lapor
# selasa : selasa
# wib : wib
# down : down
# tersambung : sambung
# jumat : jumat
# jun : jun
# warna : warna
# lampu : lampu
# pojok : pojok
# kiri : kiri
# nyala : nyala
# hijau : hijau
# tri : tri
# wahyuni : wahyuni
# hub : hub
# hii : hii
# sumatera : sumatera
# bengkulu : bengkulu
# pembayaran : bayar
# lancar : lancar
# membeli : beli
# varian : varian
# whatssapp : whatssapp
# susah : susah
# aman : aman
# mengganti : ganti
# passwod : passwod
# gelap : gelap
# gua : gua
# jinggg : jinggg
# inpo : inpo
# ganti : ganti
# pasword : pasword
# wifi : wifi
# memamg : memamg
# permasalahan : masalah
# digigit : gigit
# tikus : tikus
# dilaporkan : lapor
# perbaikilah : baik
# seriua : seriua
# tambal : tambal
# sulam : sulam
# note : note
# dilarang : larang
# gigit : gigit
# details : details
# kemarin : kemarin
# balasan : balas
# gila : gila
# perhatikan : perhati
# berdekatan : dekat
# junlos : junlos
# los : los
# may : may
# eror : eror
# coba : coba
# jalani : jalan
# prosedur : prosedur
# indihomecare : indihomecare
# blum : blum
# gini : gin
# dicek : cek
# jalur : jalur
# pusat : pusat
# diluar : luar
# pagi : pagi
# malam : malam
# internetnya : internetnya
# mati : mati
# pon : pon
# indikatornya : indikator
# merah : merah
# kabelnya : kabel
# dicabut : cabut
# dipasang : pasang
# jam : jam
# akses : akses
# bbrapa : bbrapa
# kali : kali
# direstart : direstart
# ttp : ttp
# gmn : gmn
# solusiny : solusiny
# thx : thx
# slow : slow
# respon : respon
# indihone : indihone
# bilangnya : bilang
# dibenerin : dibenerin
# central : central
# telpin : telpin
# berkali : kali
# alasannya : alas
# ampe : ampe
# capek : capek
# telp : telp
# gabisa : gabisa
# dipake : dipake
# putus : putus
# kena : kena
# full : full
# waw : waw
# panik : panik
# channel : channel
# cth : cth
# transtv : transtv
# indosiar : indosiar
# kendalanya : kendala
# panduan : pandu
# bantu : bantu
# berhentikan : henti
# {'mantep': 'mantep', 'ingetin': 'ingetin', 'jaringan': 'jaring', 'kek': 'kek', 'babi': 'babi', 'gitu': 'gitu', 'belagu': 'belagu', 'mudahan': 'mudah', 'cepet': 'cepet', 'bangkrut': 'bangkrut', 'perusahan': 'usah', 'dasar': 'dasar', 'ajg': 'ajg', 'emang': 'emang', 'mampus': 'mampus', 'indohome': 'indohome', 'lonte': 'lonte', 'bagus': 'bagus', 'gausah': 'gausah', 'sok': 'sok', 'jualan': 'jual', 'setan': 'setan', 'malem': 'malem', 'gangguan': 'ganggu', '': '', 'hallo': 'hallo', 'tindak': 'tindak', 'keluhan': 'keluh', 'bayaran': 'bayar', 'gapernah': 'gapernah', 'telat': 'telat', 'min': 'min', 'yaa': 'yaa', 'mengecewakan': 'kecewa', 'sekaliiii': 'sekaliiii', 'indihome': 'indihome', 'paket': 'paket', 'promo': 'promo', 'trmksh': 'trmksh', 'pasang': 'pasang', 'gimna': 'gimna', 'siapp': 'siapp', 'bayar': 'bayar', 'cek': 'cek', 'fup': 'fup', 'mbps': 'mbps', 'kak': 'kak', 'tuuh': 'tuuh', 'perbaikan': 'baik', 'masal': 'masal', 'singyal': 'singyal', 'mangkin': 'mangkin', 'lelet': 'lelet', 'terimakasih': 'terimakasih', 'infonya': 'info', 'comment': 'comment', 'pemindahan': 'pindah', 'kabel': 'kabel', 'pindh': 'pindh', 'haruskah': 'harus', 'laporan': 'lapor', 'kantor': 'kantor', 'terdekat': 'dekat', 'nice': 'nice', 'mimin': 'mimin', 'pantau': 'pantau', 'pengguna': 'guna', 'aktif': 'aktif', 'udah': 'udah', 'confirm': 'confirm', 'berhenti': 'henti', 'membantu': 'bantu', 'laggggggggggggggggg': 'laggggggggggggggggg', 'woiiiiii': 'woiiiiii', 'lagggggggggggggggg': 'lagggggggggggggggg', 'lagggggggggggggggggggggggggg': 'lagggggggggggggggggggggggggg', 'lagggygyggggg': 'lagggygyggggg', 'mudah': 'mudah', 'modem': 'modem', 'zte': 'zte', 'kolom': 'kolom', 'ssid': 'ssid', 'keterangan': 'terang', 'security': 'security', 'type': 'type', 'wpa': 'wpa', 'password': 'password', 'disamping': 'samping', 'tulisan': 'tulis', 'show': 'show', 'passwordnya': 'passwordnya', 'setel': 'setel', 'ulang': 'ulang', 'informasinya': 'informasi', 'berguna': 'guna', 'banget': 'banget', 'username': 'username', 'lupa': 'lupa', 'mensolusikan': 'solusi', 'solusi': 'solusi', 'bermanfaat': 'manfaat', 'keren': 'keren', 'tips': 'tips', 'ngepush': 'ngepush', 'turun': 'turun', 'baca': 'baca', 'kualitas': 'kualitas', 'jelek': 'jelek', 'pelayanan': 'layan', 'jawabannya': 'jawab', 'yogya': 'yogya', 'selamat': 'selamat', 'siang': 'siang', 'bgm': 'bgm', 'tagihan': 'tagih', 'pelanggan': 'langgan', 'pasca': 'pasca', 'banjir': 'banjir', 'seroja': 'seroja', 'alami': 'alami', 'tetangga': 'tetangga', 'mengalami': 'alami', 'musibah': 'musibah', 'spt': 'spt', 'membayar': 'bayar', 'sdgkan': 'sdgkan', 'msh': 'msh', 'internet': 'internet', 'matinyala': 'matinyala', 'minggu': 'minggu', 'sampe': 'sampe', 'belasan': 'bas', 'teknisi': 'teknisi', 'dateng': 'dateng', 'bergantian': 'ganti', 'gantian': 'ganti', 'error': 'error', 'seminggu': 'minggu', 'pas': 'pas', 'tanggal': 'tanggal', 'sungguh': 'sungguh', 'iklas': 'iklas', 'gwwww': 'gwwww', 'telpon': 'telpon', 'twitter': 'twitter', 'ngarus': 'ngarus', 'maaf': 'maaf', 'template': 'template', 'muluuuuu': 'muluuuuu', 'donlot': 'donlot', 'link': 'link', 'mohon': 'mohon', 'mei': 'mei', 'juni': 'juni', 'akibat': 'akibat', 'terdampak': 'dampak', 'tks': 'tks', 'lemot': 'lot', 'admin': 'admin', 'tolong': 'tolong', 'bales': 'bales', 'sya': 'sya', 'log': 'log', 'out': 'out', 'clear': 'clear', 'cache': 'cache', 'aplikasi': 'aplikasi', 'tetep': 'tetep', 'dibayar': 'bayar', 'dilunasi': 'lunas', 'terima': 'terima', 'kasih': 'kasih', 'beres': 'beres', 'nama': 'nama', 'ari': 'ari', 'wibowo': 'wibowo', 'stb': 'stb', 'gimana': 'gimana', 'woy': 'woy', 'knp': 'knp', 'masuk': 'masuk', 'myindhome': 'myindhome', 'sesuai': 'sesuai', 'verivikasi': 'verivikasi', 'kirim': 'kirim', 'via': 'via', 'sms': 'sms', 'tipsnya': 'tipsnya', 'bingung': 'bingung', 'sip': 'sip', 'mengatasi': 'atas', 'solusinya': 'solusi', 'yeay': 'yeay', 'informasi': 'informasi', 'ribet': 'ribet', 'yes': 'yes', 'kemudahan': 'mudah', 'simple': 'simple', 'edukasi': 'edukasi', 'mantap': 'mantap', 'dapet': 'dapet', 'deh': ...
# ------------------------
# Pandas Apply:   0%|          | 0/109 [00:00<?, ?it/s]
#                                                   text  \
# 0    mantep di ingetin nih \n\n#aktivitastanpabatas...
# 3                        jaringan kek babi gitu belagu
# 4             mudahan cepet bangkrut tu perusahan bgst
# 5                                            dasar ajg
# 6                  emang babi, mampus aja lu semua ajg
# ..                                                 ...
# 111               kak... internet tiba2 mati kenapa ya
# 112                   waw, sekarang udah gk panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah di coba spt panduan tetap gak bisa..moho...
# 116                            kapan di berhentikan kk
#
#                                          cleaning_text  \
# 0                                   mantep ingetin nih
# 3                        jaringan kek babi gitu belagu
# 4                mudahan cepet bangkrut perusahan bgst
# 5                                            dasar ajg
# 6                      emang babi mampus aja semua ajg
# ..                                                 ...
# 111                    kak internet tiba  mati kenapa
# 112                       waw sekarang udah panik lagi
# 114  min kalo tentang channel tidak bisa akses cth ...
# 115  sudah coba spt panduan tetap gak bisa mohon bantu
# 116                                 kapan berhentikan
#
#                                             tokenisasi  \
# 0                               [mantep, ingetin, nih]
# 3                  [jaringan, kek, babi, gitu, belagu]
# 4          [mudahan, cepet, bangkrut, perusahan, bgst]
# 5                                         [dasar, ajg]
# 6               [emang, babi, mampus, aja, semua, ajg]
# ..                                                 ...
# 111              [kak, internet, tiba, mati, kenapa, ]
# 112                 [waw, sekarang, udah, panik, lagi]
# 114  [min, kalo, tentang, channel, tidak, bisa, aks...
# 115  [sudah, coba, spt, panduan, tetap, gak, bisa, ...
# 116                             [kapan, berhentikan, ]
#
#                                               stopword  \
# 0                                    [mantep, ingetin]
# 3                  [jaringan, kek, babi, gitu, belagu]
# 4                [mudahan, cepet, bangkrut, perusahan]
# 5                                         [dasar, ajg]
# 6                           [emang, babi, mampus, ajg]
# ..                                                 ...
# 111                            [kak, internet, mati, ]
# 112                                 [waw, udah, panik]
# 114  [min, channel, akses, cth, transtv, indosiar, ...
# 115                 [coba, spt, panduan, mohon, bantu]
# 116                                    [berhentikan, ]
#
#                                               stemming
# 0                                    [mantep, ingetin]
# 3                    [jaring, kek, babi, gitu, belagu]
# 4                       [mudah, cepet, bangkrut, usah]
# 5                                         [dasar, ajg]
# 6                           [emang, babi, mampus, ajg]
# ..                                                 ...
# 111                            [kak, internet, mati, ]
# 112                                 [waw, udah, panik]
# 114  [min, channel, akses, cth, transtv, indosiar, ...
# 115                   [coba, spt, pandu, mohon, bantu]
# 116                                          [henti, ]
#
# [109 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                    [mantep, ingetin]
# 3                    [jaring, kek, babi, gitu, belagu]
# 4                       [mudah, cepet, bangkrut, usah]
# 5                                         [dasar, ajg]
# 6                           [emang, babi, mampus, ajg]
# ..                                                 ...
# 111                            [kak, internet, mati, ]
# 112                                 [waw, udah, panik]
# 114  [min, channel, akses, cth, transtv, indosiar, ...
# 115                   [coba, spt, pandu, mohon, bantu]
# 116                                          [henti, ]
#
# [109 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_6.xlsx')
