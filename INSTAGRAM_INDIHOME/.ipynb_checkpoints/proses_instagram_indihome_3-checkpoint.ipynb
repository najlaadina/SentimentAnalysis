# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0             Mantap, emang TOP banget deh IndiHome :D
# 1                                    Mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     Indihome terbaik
# 4                     Kereen, nton bioskop bisa di rmh
# ..                                                 ...
# 507  Asik, gak repot lagi deh, akhirnya dapat tips ...
# 508  Wah, jadi makin simple dong. Makasih tipsnya K...
# 509  Wah, jadi makin simple dong. Makasih tipsnya K...
# 510  Asik, gak repot lagi deh, akhirnya dapat tips ...
# 511  yeay, mantap min. makin gampang deh.\n#Interne...
#
# [512 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 186

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 1                                    Mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     Indihome terbaik
# 4                     Kereen, nton bioskop bisa di rmh
# 6                          Boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            Hai min
# 488  ohh gini caranya toh\n\n#AktivitasTanpaBatas\n...
# 489  Bisa dicoba nanti nih\n#MajuTerusBersamaIndiHo...
# 490                                      Cek dm please
# 491         Wahh jadi tahu deh cari ganti password nih
#
# [251 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     indihome terbaik
# 4                     kereen, nton bioskop bisa di rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488  ohh gini caranya toh\n\n#aktivitastanpabatas\n...
# 489  bisa dicoba nanti nih\n#majuterusbersamaindiho...
# 490                                      cek dm please
# 491         wahh jadi tahu deh cari ganti password nih
#
# [251 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     indihome terbaik
# 4                     kereen, nton bioskop bisa di rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488  ohh gini caranya toh\n\n#aktivitastanpabatas\n...
# 489  bisa dicoba nanti nih\n#majuterusbersamaindiho...
# 490                                      cek dm please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                          cleaning_text
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop era pan...
# 3                                     indihome terbaik
# 4                         kereen nton bioskop bisa rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488                               ohh gini caranya toh
# 489                              bisa dicoba nanti nih
# 490                                         cek please
# 491         wahh jadi tahu deh cari ganti password nih
#
# [251 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     indihome terbaik
# 4                     kereen, nton bioskop bisa di rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488  ohh gini caranya toh\n\n#aktivitastanpabatas\n...
# 489  bisa dicoba nanti nih\n#majuterusbersamaindiho...
# 490                                      cek dm please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                          cleaning_text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop era pan...
# 3                                     indihome terbaik
# 4                         kereen nton bioskop bisa rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488                               ohh gini caranya toh
# 489                              bisa dicoba nanti nih
# 490                                         cek please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                             tokenisasi
# 1                                [mantap, banget, ini]
# 2    [mantep, bgt, kalo, rumah, dijadiin, bioskop, ...
# 3                                  [indihome, terbaik]
# 4                   [kereen, nton, bioskop, bisa, rmh]
# 6                    [boleh, dicoba, ini, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                          [ohh, gini, caranya, toh]
# 489                         [bisa, dicoba, nanti, nih]
# 490                                      [cek, please]
# 491  [wahh, jadi, tahu, deh, cari, ganti, password,...
#
# [251 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     indihome terbaik
# 4                     kereen, nton bioskop bisa di rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488  ohh gini caranya toh\n\n#aktivitastanpabatas\n...
# 489  bisa dicoba nanti nih\n#majuterusbersamaindiho...
# 490                                      cek dm please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                          cleaning_text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop era pan...
# 3                                     indihome terbaik
# 4                         kereen nton bioskop bisa rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488                               ohh gini caranya toh
# 489                              bisa dicoba nanti nih
# 490                                         cek please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                             tokenisasi  \
# 1                                [mantap, banget, ini]
# 2    [mantep, bgt, kalo, rumah, dijadiin, bioskop, ...
# 3                                  [indihome, terbaik]
# 4                   [kereen, nton, bioskop, bisa, rmh]
# 6                    [boleh, dicoba, ini, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                          [ohh, gini, caranya, toh]
# 489                         [bisa, dicoba, nanti, nih]
# 490                                      [cek, please]
# 491  [wahh, jadi, tahu, deh, cari, ganti, password,...
#
#                                               stopword
# 1                                     [mantap, banget]
# 2    [mantep, rumah, dijadiin, bioskop, era, pandem...
# 3                                  [indihome, terbaik]
# 4                         [kereen, nton, bioskop, rmh]
# 6                                [dicoba, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                                        [ohh, gini]
# 489                                           [dicoba]
# 490                                      [cek, please]
# 491                 [wahh, deh, cari, ganti, password]
#
# [251 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 587
# ------------------------
# mantap : mantap
# banget : banget
# mantep : mantep
# rumah : rumah
# dijadiin : dijadiin
# bioskop : bioskop
# era : era
# pandemi : pandemi
# gini : gin
# indihome : indihome
# terbaik : baik
# kereen : kereen
# nton : nton
# rmh : rmh
# dicoba : coba
# mah : mah
# hehehe : hehehe
#  :
# min : min
# berlangganan : langgan
# telpon : telpon
# refund : refund
# proses : proses
# udah : udah
# sebulan : bulan
# benefitnya : benefitnya
# lahhhh : lahhhh
# jaringannya : jaring
# bagus : bagus
# push : push
# rank : rank
# rekomendasi : rekomendasi
# paket : paket
# gamming : gamming
# cek : cek
# nyaman : nyaman
# belajar : ajar
# dirumah : rumah
# emang : emang
# menyenangkan : senang
# siapp : siapp
# promo : promo
# aplikasi : aplikasi
# myindihome : myindihome
# download : download
# dimana : mana
# wifi : wifi
# lemot : lot
# keren : keren
# tolong : tolong
# wih : wih
# woy : woy
# payah : payah
# indihomecare : indihomecare
# not : not
# respon : respon
# pagi : pagi
# skrng : skrng
# tanggapi : tanggap
# hallo : hallo
# admin : admin
# jaringan : jaring
# rada : rada
# lag : lag
# yaaaaa : yaaaaa
# mengembalikan : kembali
# tampilan : tampil
# barubagaimana : barubagaimana
# sekrng : sekrng
# rumit : rumit
# harganya : harga
# mahal : mahal
# berbahaya : bahaya
# darurat : darurat
# kerja : kerja
# enak : enak
# corner : corner
# toptop : toptop
# makasih : makasih
# infonya : info
# informasi : informasi
# waspada : waspada
# pengaduan : adu
# follow : follow
# knpa : knpa
# tersambung : sambung
# seamles : seamles
# bayar : bayar
# tagihan : tagih
# gampang : gampang
# simple : simple
# enteng : enteng
# berat : berat
# perangkat : perangkat
# tips : tips
# bergunaa : bergunaa
# ampuh : ampuh
# tipsnya : tipsnya
# nin : nin
# oke : oke
# yaa : yaa
# makaciii : makaciii
# info : info
# bermanfaat : manfaat
# mantul : mantul
# tipsnyaa : tipsnyaa
# internet : internet
# gangguan : ganggu
# perbaiki : baik
# kec : kec
# singgahan : singgah
# kab : kab
# tuban : tuban
# jawa : jawa
# timur : timur
# kemarin : kemarin
# ganti : ganti
# password : password
# bolak : bolak
# coba : coba
# bantu : bantu
# gantikan : ganti
# terimakasih : terimakasih
# namanya : nama
# setuju : tuju
# tujuan : tuju
# positif : positif
# lancar : lancar
# jaya : jaya
# infonyaaaa : infonyaaaa
# aman : aman
# bales : bales
# mohon : mohon
# voute : voute
# rekasi : rekasi
# pemasangan : pasang
# penarikan : tari
# daring : daring
# butuhkan : butuh
# trimakasih : trimakasih
# beli : beli
# dmna : dmna
# kak : kak
# remot : remot
# feebernya : feebernya
# diganti : ganti
# remotnya : remotnya
# tidkaa : tidkaa
# konex : konex
# pantes : pantes
# informasinya : informasi
# panduannya : pandu
# baca : baca
# okeh : okeh
# nice : nice
# work : work
# cobaaa : cobaaa
# terima : terima
# kasih : kasih
# mimin : mimin
# pisan : pis
# solusinya : solusi
# stb : stb
# malem : malem
# memperbaiki : baik
# akun : akun
# karna : karna
# lupa : lupa
# nama : nama
# paswordnya : paswordnya
# teknisi : teknisi
# sabtu : sabtu
# responsif : responsif
# wahh : wahh
# manfaat : manfaat
# edukatif : edukatif
# naissss : naissss
# inpoh : inpoh
# sesuai : sesuai
# kecepatan : cepat
# diakses : akses
# haduh : haduh
# benerin : benerin
# sistem : sistem
# pemakaian : pakai
# dirasakan : rasa
# customer : customer
# rekam : rekam
# aktif : aktif
# selainnya : selain
# error : error
# tagihannya : tagih
# bengkak : bengkak
# duh : duh
# parah : parah
# kesalahan : salah
# internal : internal
# dibebankan : beban
# membantu : bantu
# lambat : lambat
# menangani : tangan
# keluhan : keluh
# deposite : deposite
# balikin : balikin
# mulu : mulu
# janji : janji
# udh : udh
# woyyyy : woyyyy
# trouble : trouble
# skg : skg
# ribet : ribet
# gabakal : gabakal
# berpaling : paling
# deh : deh
# pokoknya : pokok
# love : love
# you : you
# bangga : bangga
# sinyal : sinyal
# lancarrrrr : lancarrrrr
# terusssss : terusssss
# kerennnnnn : kerennnnnn
# mantulllllllll : mantulllllllll
# kereeenn : kereeenn
# pisaaaann : pisaaaann
# panik : panik
# duluan : duluan
# praktissss : praktissss
# seh : seh
# kasusnya : kasus
# pon : pon
# merah : merah
# panggil : panggil
# kumat : kumat
# wifinya : wifinya
# datengnya : datengnya
# haduhh : haduhh
# gimana : gimana
# betah : betah
# internetnya : internetnya
# tipssnya : tipssnya
# berguna : guna
# panduan : pandu
# attasin : attasin
# kendala : kendala
# yutub : yutub
# mudah : mudah
# usse : usse
# store : store
# instal : instal
# yuotube : yuotube
# langganan : langgan
# gmana : gmana
# wow : wow
# luas : luas
# inspirasi : inspirasi
# menariknya : tarik
# terkendali : kendali
# sepraktis : praktis
# cepat : cepat
# caur : caur
# main : main
# game : game
# mabar : mabar
# yuk : yuk
# kontribusi : kontribusi
# pelayanan : layan
# seamless : seamless
# maksimal : maksimal
# device : device
# sip : sip
# tangani : tangan
# thans : thans
# iya : iya
# kadang : kadang
# bingung : bingung
# semenjak : semenjak
# postingan : postingan
# memudahkan : mudah
# kunci : kunci
# balas : balas
# barusan : barusan
# alat : alat
# modemnya : modem
# pindah : pindah
# lelet : lelet
# jaringanya : jaringanya
# jaringanny : jaringanny
# cuman : cuman
# ngontol : ngontol
# dikit : dikit
# ngeleg : ngeleg
# doang : doang
# ajg : ajg
# emg : emg
# parahh : parahh
# maaciw : maaciw
# kerenn : kerenn
# cba : cba
# smpe : smpe
# skrg : skrg
# tanda : tanda
# seru : seru
# trus : trus
# mhon : mhon
# thx : thx
# bantuan : bantu
# buka : buka
# alamatnya : alamat
# tdak : tdak
# sambungan : sambung
# pdahal : pdahal
# terhubung : hubung
# langkah : langkah
# salah : salah
# thanks : thanks
# ngelag : ngelag
# trosssss : trosssss
# anjeng : anjeng
# ms : ms
# asw : asw
# ngotak : ngotak
# plis : plis
# enaknya : enak
# menerusss : menerusss
# bener : bener
# cocok : cocok
# incognito : incognito
# putus : putus
# duit : duit
# deposit : deposit
# baliknya : balik
# berpaa : berpaa
# koneksi : koneksi
# privasi : privasi
# kejaga : jaga
# manteppp : manteppp
# stres : stres
# omg : omg
# mntang : mntang
# didiemin : didiemin
# mlah : mlah
# keenakan : enak
# yukk : yukk
# gasss : gasss
# los : los
# akses : akses
# pasanag : pasanag
# minnn : minnn
# kecewa : kecewa
# perbaikan : baik
# ditunggu : tunggu
# minggu : minggu
# kabar : kabar
# telkomnya : telkomnya
# pangsung : pangsung
# diarahkan : arah
# kesales : kesales
# sales : sales
# responya : responya
# dibales : dibales
# apke : apke
# salesg : salesg
# hub : hub
# daftar : daftar
# gmn : gmn
# telkomjombang : telkomjombang
# pelayananya : pelayananya
# helppppp : helppppp
# lemooottttt : lemooottttt
# kualitas : kualitas
# layanannya : layan
# abal : abal
# mati : mati
# ngadu : ngadu
# via : via
# telkom : telkom
# twitter : twitter
# email : email
# customercare : customercare
# satupun : satu
# ngrespon : ngrespon
# manusianya : manusia
# ato : ato
# layanan : layan
# beuh : beuh
# isi : isi
# gabutuh : gabutuh
# karaoke : karaoke
# woi : woi
# butuh : butuh
# pls : pls
# lahhhhhhhhhhhh : lahhhhhhhhhhhh
# lemotttt : lemotttt
# tolongggg : tolongggg
# tgl : tgl
# maret : maret
# dijanjikan : janji
# tersedia : sedia
# wilayah : wilayah
# tangerang : tangerang
# selatan : selatan
# doank : doank
# periode : periode
# ngasih : ngasih
# kompensasi : kompensasi
# kerugian : rugi
# apapun : apa
# asik : asik
# nyanyi : nyanyi
# keluarga : keluarga
# dmmm : dmmm
# pakai : pakai
# harga : harga
# selangit : langit
# buruk : buruk
# loss : loss
# kayak : kayak
# ultramen : ultramen
# keabisan : abis
# energi : energi
# daya : daya
# april : april
# dibantu : bantu
# progres : progres
# pencabutan : cabut
# kog : kog
# lamas : lamas
# daritadi : daritadi
# jam : jam
# pdhl : pdhl
# operator : operator
# telkomsel : telkomsel
# denger : denger
# grup : grup
# komplek : komplek
# produk : produk
# daerah : daerah
# klapanunggal : klapanunggal
# bogor : bogor
# habis : habis
# tertipu : tipu
# berhenti : henti
# langgana : langgana
# melebihi : lebih
# alasannya : alas
# pelanggan : langgan
# provider : provider
# menikmati : nikmat
# aturan : atur
# bet : bet
# knp : knp
# massal : massal
# keringanan : ringan
# nunggu : nunggu
# suruh : suruh
# tunggu : tunggu
# indibasket : indibasket
# halahtai : halahtai
# repot : repot
# hhhmmm : hhhmmm
# bosen : bosen
# yan : yan
# informatif : informatif
# mengedukasi : edukasi
# wiih : wiih
# mengudakasi : mengudakasi
# dilanjut : lanjut
# teruslah : terus
# jaga : jaga
# pantau : pantau
# terusss : terusss
# hai : hai
# donlot : donlot
# ajh : ajh
# pemutusan : putus
# jebakkan : jebak
# ujung : ujung
# beserta : serta
# biaya : biaya
# tunggakan : tunggak
# tsb : tsb
# sisa : sisa
# bln : bln
# ancaman : ancam
# whatsapp : whatsapp
# kredit : kredit
# macet : macet
# menjamin : jamin
# laporan : lapor
# lbh : lbh
# dijamin : jamin
# memakai : pakai
# berbulan : bulan
# ancam : ancam
# membayar : bayar
# sja : sja
# sya : sya
# tgihan : tgihan
# rb : rb
# makan : makan
# halo : halo
# pasang : pasang
# tahapan : tahap
# lakukan : laku
# waah : waah
# lekang : lekang
# gunainnya : gunainnya
# keamanan : aman
# terjaga : jaga
# was : was
# kuota : kuota
# giga : giga
# ngelaaggg : ngelaaggg
# dtg : dtg
# mbps : mbps
# bayarvlho : bayarvlho
# gratis : gratis
# aduan : adu
# noya : noya
# lenteng : lenteng
# agung : agung
# smart : smart
# fool : fool
# solusi : solusi
# kepastiannya : pasti
# tanggal : tanggal
# nihhh : nihhh
# php : php
# rugi : rugi
# lapor : lapor
# tiket : tiket
# ditepati : tepat
# loat : loat
# situ : situ
# ttp : ttp
# nagih : nagih
# merugikan : rugi
# ambil : ambil
# keutungan : keutungan
# jalan : jalan
# lost : lost
# diperhatikan : perhati
# alasan : alas
# masal : masal
# kelar : kelar
# kelabakan : laba
# cari : cari
# sore : sore
# fokus : fokus
# perbaikin : perbaikin
# ngebuat : ngebuat
# gajelas : gajelas
# gaada : gaada
# kemajuan : maju
# steam : steam
# mengkonfirmasi : konfirmasi
# indonesai : indonesai
# terlemot : lot
# nihh : nihh
# asli : asli
# trik : trik
# ohh : ohh
# nggak : nggak
# nge : nge
# please : please
# help : help
# tinggal : tinggal
# bangett : bangett
# pokonya : poko
# proteksi : proteksi
# digital : digital
# data : data
# internetan : internetan
# mempromosikan : promosi
# terussss : terussss
# ugha : ugha
# masi : mas
# the : the
# best : best
# film : film
# terupdate : terupdate
# diharapkan : harap
# nonton : nonton
# situasi : situasi
# waw : waw
# uang : uang
# {'mantap': 'mantap', 'banget': 'banget', 'mantep': 'mantep', 'rumah': 'rumah', 'dijadiin': 'dijadiin', 'bioskop': 'bioskop', 'era': 'era', 'pandemi': 'pandemi', 'gini': 'gin', 'indihome': 'indihome', 'terbaik': 'baik', 'kereen': 'kereen', 'nton': 'nton', 'rmh': 'rmh', 'dicoba': 'coba', 'mah': 'mah', 'hehehe': 'hehehe', '': '', 'min': 'min', 'berlangganan': 'langgan', 'telpon': 'telpon', 'refund': 'refund', 'proses': 'proses', 'udah': 'udah', 'sebulan': 'bulan', 'benefitnya': 'benefitnya', 'lahhhh': 'lahhhh', 'jaringannya': 'jaring', 'bagus': 'bagus', 'push': 'push', 'rank': 'rank', 'rekomendasi': 'rekomendasi', 'paket': 'paket', 'gamming': 'gamming', 'cek': 'cek', 'nyaman': 'nyaman', 'belajar': 'ajar', 'dirumah': 'rumah', 'emang': 'emang', 'menyenangkan': 'senang', 'siapp': 'siapp', 'promo': 'promo', 'aplikasi': 'aplikasi', 'myindihome': 'myindihome', 'download': 'download', 'dimana': 'mana', 'wifi': 'wifi', 'lemot': 'lot', 'keren': 'keren', 'tolong': 'tolong', 'wih': 'wih', 'woy': 'woy', 'payah': 'payah', 'indihomecare': 'indihomecare', 'not': 'not', 'respon': 'respon', 'pagi': 'pagi', 'skrng': 'skrng', 'tanggapi': 'tanggap', 'hallo': 'hallo', 'admin': 'admin', 'jaringan': 'jaring', 'rada': 'rada', 'lag': 'lag', 'yaaaaa': 'yaaaaa', 'mengembalikan': 'kembali', 'tampilan': 'tampil', 'barubagaimana': 'barubagaimana', 'sekrng': 'sekrng', 'rumit': 'rumit', 'harganya': 'harga', 'mahal': 'mahal', 'berbahaya': 'bahaya', 'darurat': 'darurat', 'kerja': 'kerja', 'enak': 'enak', 'corner': 'corner', 'toptop': 'toptop', 'makasih': 'makasih', 'infonya': 'info', 'informasi': 'informasi', 'waspada': 'waspada', 'pengaduan': 'adu', 'follow': 'follow', 'knpa': 'knpa', 'tersambung': 'sambung', 'seamles': 'seamles', 'bayar': 'bayar', 'tagihan': 'tagih', 'gampang': 'gampang', 'simple': 'simple', 'enteng': 'enteng', 'berat': 'berat', 'perangkat': 'perangkat', 'tips': 'tips', 'bergunaa': 'bergunaa', 'ampuh': 'ampuh', 'tipsnya': 'tipsnya', 'nin': 'nin', 'oke': 'oke', 'yaa': 'yaa', 'makaciii': 'makaciii', 'info': 'info', 'bermanfaat': 'manfaat', 'mantul': 'mantul', 'tipsnyaa': 'tipsnyaa', 'internet': 'internet', 'gangguan': 'ganggu', 'perbaiki': 'baik', 'kec': 'kec', 'singgahan': 'singgah', 'kab': 'kab', 'tuban': 'tuban', 'jawa': 'jawa', 'timur': 'timur', 'kemarin': 'kemarin', 'ganti': 'ganti', 'password': 'password', 'bolak': 'bolak', 'coba': 'coba', 'bantu': 'bantu', 'gantikan': 'ganti', 'terimakasih': 'terimakasih', 'namanya': 'nama', 'setuju': 'tuju', 'tujuan': 'tuju', 'positif': 'positif', 'lancar': 'lancar', 'jaya': 'jaya', 'infonyaaaa': 'infonyaaaa', 'aman': 'aman', 'bales': 'bales', 'mohon': 'mohon', 'voute': 'voute', 'rekasi': 'rekasi', 'pemasangan': 'pasang', 'penarikan': 'tari', 'daring': 'daring', 'butuhkan': 'butuh', 'trimakasih': 'trimakasih', 'beli': 'beli', 'dmna': 'dmna', 'kak': 'kak', 'remot': 'remot', 'feebernya': 'feebernya', 'diganti': 'ganti', 'remotnya': 'remotnya', 'tidkaa': 'tidkaa', 'konex': 'konex', 'pantes': 'pantes', 'informasinya': 'informasi', 'panduannya': 'pandu', 'baca': 'baca', 'okeh': 'okeh', 'nice': 'nice', 'work': 'work', 'cobaaa': 'cobaaa', 'terima': 'terima', 'kasih': 'kasih', 'mimin': 'mimin', 'pisan': 'pis', 'solusinya': 'solusi', 'stb': 'stb', 'malem': 'malem', 'memperbaiki': 'baik', 'akun': 'akun', 'karna': 'karna', 'lupa': 'lupa', 'nama': 'nama', 'paswordnya': 'paswordnya', 'teknisi': 'teknisi', 'sabtu': 'sabtu', 'responsif': 'responsif', 'wahh': 'wahh', 'manfaat': 'manfaat', 'edukatif': 'edukatif', 'naissss': 'naissss', 'inpoh': 'inpoh', 'sesuai': 'sesuai', 'kecepatan': 'cepat', 'diakses': 'akses', 'haduh': 'haduh', 'benerin': 'benerin', 'sistem': 'sistem', 'pemakaian': 'pakai', 'dirasakan': 'rasa', 'customer': 'customer', 'rekam': 'rekam', 'aktif': 'aktif', 'selainnya': 'selain', 'error': 'error', 'tagihannya': 'tagih', 'bengkak': 'bengkak', 'duh': 'duh', 'parah': 'parah', 'kesalahan': 'salah', 'internal': 'internal', 'dibebankan': 'beban', 'membantu': 'bantu', 'lambat': 'lambat', 'menangani': 'tangan', 'k ...
# ------------------------
# Pandas Apply:   0%|          | 0/251 [00:00<?, ?it/s]
#                                                   text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop di era ...
# 3                                     indihome terbaik
# 4                     kereen, nton bioskop bisa di rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488  ohh gini caranya toh\n\n#aktivitastanpabatas\n...
# 489  bisa dicoba nanti nih\n#majuterusbersamaindiho...
# 490                                      cek dm please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                          cleaning_text  \
# 1                                    mantap banget ini
# 2    mantep bgt kalo rumah dijadiin bioskop era pan...
# 3                                     indihome terbaik
# 4                         kereen nton bioskop bisa rmh
# 6                          boleh dicoba ini mah hehehe
# ..                                                 ...
# 487                                            hai min
# 488                               ohh gini caranya toh
# 489                              bisa dicoba nanti nih
# 490                                         cek please
# 491         wahh jadi tahu deh cari ganti password nih
#
#                                             tokenisasi  \
# 1                                [mantap, banget, ini]
# 2    [mantep, bgt, kalo, rumah, dijadiin, bioskop, ...
# 3                                  [indihome, terbaik]
# 4                   [kereen, nton, bioskop, bisa, rmh]
# 6                    [boleh, dicoba, ini, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                          [ohh, gini, caranya, toh]
# 489                         [bisa, dicoba, nanti, nih]
# 490                                      [cek, please]
# 491  [wahh, jadi, tahu, deh, cari, ganti, password,...
#
#                                               stopword  \
# 1                                     [mantap, banget]
# 2    [mantep, rumah, dijadiin, bioskop, era, pandem...
# 3                                  [indihome, terbaik]
# 4                         [kereen, nton, bioskop, rmh]
# 6                                [dicoba, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                                        [ohh, gini]
# 489                                           [dicoba]
# 490                                      [cek, please]
# 491                 [wahh, deh, cari, ganti, password]
#
#                                               stemming
# 1                                     [mantap, banget]
# 2    [mantep, rumah, dijadiin, bioskop, era, pandem...
# 3                                     [indihome, baik]
# 4                         [kereen, nton, bioskop, rmh]
# 6                                  [coba, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                                         [ohh, gin]
# 489                                             [coba]
# 490                                      [cek, please]
# 491                 [wahh, deh, cari, ganti, password]
#
# [251 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 1                                     [mantap, banget]
# 2    [mantep, rumah, dijadiin, bioskop, era, pandem...
# 3                                     [indihome, baik]
# 4                         [kereen, nton, bioskop, rmh]
# 6                                  [coba, mah, hehehe]
# ..                                                 ...
# 487                                         [hai, min]
# 488                                         [ohh, gin]
# 489                                             [coba]
# 490                                      [cek, please]
# 491                 [wahh, deh, cari, ganti, password]
#
# [251 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_3.xlsx')
