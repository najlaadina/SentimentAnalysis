# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                  text
# 0                                              Mantap
# 1   Tapi untuk proses berhenti berlanganan alur ny...
# 2                          Nmr pelanggan 141425108331
# 3   Min kalau mau berhenti berlangganan gimana car...
# 4   Terima kasih IndiHome, internetnya stabil bang...
# 5   Kalau gapake IndiHome gatau deh pake provider ...
# 6   Kalau gapake IndiHome gatau deh pake provider ...
# 7   Kalau gapake IndiHome gatau deh pake provider ...
# 8                                           BALAS DM!
# 9                                              CEK DM
# 10  mantap nih indihome tipsnya\n#InternetnyaIndon...
# 11  mantap nih indihome tipsnya\n#InternetnyaIndon...
# 12  mantap nih indihome tipsnya\n#InternetnyaIndon...
# 13  mantap nih indihome tipsnya\n#InternetnyaIndon...
# 14  mantap nih indihome tipsnya\n#InternetnyaIndon...
# 15  mantap nih indihome tipsnya\n#InternetnyaIndon...
# 16  bagus nih indihome\n#InternetnyaIndonesia\n#Ma...
# 17  bagus nih indihome\n#InternetnyaIndonesia\n#Ma...
# 18  bagus nih indihome\n#InternetnyaIndonesia\n#Ma...
# 19  bagus nih indihome\n#InternetnyaIndonesia\n#Ma...
# 20  bagus nih indihome\n#InternetnyaIndonesia\n#Ma...
# 21  bagus nih indihome\n#InternetnyaIndonesia\n#Ma...
# 22  ini saran yang keren.\n#InternetnyaIndonesia\n...
# 23  ini saran yang keren.\n#InternetnyaIndonesia\n...
# 24  Mau info, infihome di rumah kami eror sudah sa...
# 25                          Lebih dekat ya min hehehe
# 26  Permisi sy mw melaporkan klo indihome di rumah...
# 27  Terima kasih IndiHome, internetnya stabil bang...
# 28               Mantap min, semangat kerjanya min :D
# 29               Mantap min, semangat kerjanya min :D
# 30  Kalau gapake IndiHome gatau deh pake provider ...
# 31                                          BALAS DM!
# 32  Indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             Cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  Tolong kembalikan uang jaminan saya.. yg sudah...
# 36  Halo..sudah seminggu internet saya gangguan, n...
# 37                 Aplikasi my IndiHome download dmn?
# 38  Kak, paket IndiHome tanpa channel TV 10mbps be...
# 39  Kak, paket IndiHome tanpa channel TV skrng ber...

# %%
df.text.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                  text
# 0                                              Mantap
# 1   Tapi untuk proses berhenti berlanganan alur ny...
# 2                          Nmr pelanggan 141425108331
# 3   Min kalau mau berhenti berlangganan gimana car...
# 9                                              CEK DM
# 24  Mau info, infihome di rumah kami eror sudah sa...
# 25                          Lebih dekat ya min hehehe
# 26  Permisi sy mw melaporkan klo indihome di rumah...
# 32  Indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             Cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  Tolong kembalikan uang jaminan saya.. yg sudah...
# 36  Halo..sudah seminggu internet saya gangguan, n...
# 37                 Aplikasi my IndiHome download dmn?
# 38  Kak, paket IndiHome tanpa channel TV 10mbps be...
# 39  Kak, paket IndiHome tanpa channel TV skrng ber...

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                  text
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                          nmr pelanggan 141425108331
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                              cek dm
# 24  mau info, infihome di rumah kami eror sudah sa...
# 25                          lebih dekat ya min hehehe
# 26  permisi sy mw melaporkan klo indihome di rumah...
# 32  indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  tolong kembalikan uang jaminan saya.. yg sudah...
# 36  halo..sudah seminggu internet saya gangguan, n...
# 37                 aplikasi my indihome download dmn?
# 38  kak, paket indihome tanpa channel tv 10mbps be...
# 39  kak, paket indihome tanpa channel tv skrng ber...

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                  text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                          nmr pelanggan 141425108331
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                              cek dm
# 24  mau info, infihome di rumah kami eror sudah sa...
# 25                          lebih dekat ya min hehehe
# 26  permisi sy mw melaporkan klo indihome di rumah...
# 32  indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  tolong kembalikan uang jaminan saya.. yg sudah...
# 36  halo..sudah seminggu internet saya gangguan, n...
# 37                 aplikasi my indihome download dmn?
# 38  kak, paket indihome tanpa channel tv 10mbps be...
# 39  kak, paket indihome tanpa channel tv skrng ber...
#
#                                         cleaning_text
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                                     nmr pelanggan
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                                cek
# 24  mau info infihome rumah kami eror sudah satu m...
# 25                             lebih dekat min hehehe
# 26  permisi melaporkan klo indihome rumah mati kem...
# 32  indihome saya sdh daftar bln nama tamam supri ...
# 33                                               cek
# 34  makasih satu yang disuka dari indihome fast re...
# 35  tolong kembalikan uang jaminan saya sudah tung...
# 36  halo sudah seminggu internet saya gangguan nom...
# 37                    aplikasi indihome download dmn
# 38     kak paket indihome tanpa channel  mbps berapa
# 39  kak paket indihome tanpa channel skrng berapa ...

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                  text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                          nmr pelanggan 141425108331
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                              cek dm
# 24  mau info, infihome di rumah kami eror sudah sa...
# 25                          lebih dekat ya min hehehe
# 26  permisi sy mw melaporkan klo indihome di rumah...
# 32  indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  tolong kembalikan uang jaminan saya.. yg sudah...
# 36  halo..sudah seminggu internet saya gangguan, n...
# 37                 aplikasi my indihome download dmn?
# 38  kak, paket indihome tanpa channel tv 10mbps be...
# 39  kak, paket indihome tanpa channel tv skrng ber...
#
#                                         cleaning_text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                                     nmr pelanggan
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                                cek
# 24  mau info infihome rumah kami eror sudah satu m...
# 25                             lebih dekat min hehehe
# 26  permisi melaporkan klo indihome rumah mati kem...
# 32  indihome saya sdh daftar bln nama tamam supri ...
# 33                                               cek
# 34  makasih satu yang disuka dari indihome fast re...
# 35  tolong kembalikan uang jaminan saya sudah tung...
# 36  halo sudah seminggu internet saya gangguan nom...
# 37                    aplikasi indihome download dmn
# 38     kak paket indihome tanpa channel  mbps berapa
# 39  kak paket indihome tanpa channel skrng berapa ...
#
#                                            tokenisasi
# 0                                            [mantap]
# 1   [tapi, untuk, proses, berhenti, berlanganan, a...
# 2                                  [nmr, pelanggan, ]
# 3   [min, kalau, mau, berhenti, berlangganan, gima...
# 9                                             [cek, ]
# 24  [mau, info, infihome, rumah, kami, eror, sudah...
# 25                        [lebih, dekat, min, hehehe]
# 26  [permisi, melaporkan, klo, indihome, rumah, ma...
# 32  [indihome, saya, sdh, daftar, bln, nama, tamam...
# 33                                            [cek, ]
# 34  [makasih, satu, yang, disuka, dari, indihome, ...
# 35  [tolong, kembalikan, uang, jaminan, saya, suda...
# 36  [halo, sudah, seminggu, internet, saya, ganggu...
# 37              [aplikasi, indihome, download, dmn, ]
# 38  [kak, paket, indihome, tanpa, channel, mbps, b...
# 39  [kak, paket, indihome, tanpa, channel, skrng, ...

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                  text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                          nmr pelanggan 141425108331
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                              cek dm
# 24  mau info, infihome di rumah kami eror sudah sa...
# 25                          lebih dekat ya min hehehe
# 26  permisi sy mw melaporkan klo indihome di rumah...
# 32  indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  tolong kembalikan uang jaminan saya.. yg sudah...
# 36  halo..sudah seminggu internet saya gangguan, n...
# 37                 aplikasi my indihome download dmn?
# 38  kak, paket indihome tanpa channel tv 10mbps be...
# 39  kak, paket indihome tanpa channel tv skrng ber...
#
#                                         cleaning_text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                                     nmr pelanggan
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                                cek
# 24  mau info infihome rumah kami eror sudah satu m...
# 25                             lebih dekat min hehehe
# 26  permisi melaporkan klo indihome rumah mati kem...
# 32  indihome saya sdh daftar bln nama tamam supri ...
# 33                                               cek
# 34  makasih satu yang disuka dari indihome fast re...
# 35  tolong kembalikan uang jaminan saya sudah tung...
# 36  halo sudah seminggu internet saya gangguan nom...
# 37                    aplikasi indihome download dmn
# 38     kak paket indihome tanpa channel  mbps berapa
# 39  kak paket indihome tanpa channel skrng berapa ...
#
#                                            tokenisasi  \
# 0                                            [mantap]
# 1   [tapi, untuk, proses, berhenti, berlanganan, a...
# 2                                  [nmr, pelanggan, ]
# 3   [min, kalau, mau, berhenti, berlangganan, gima...
# 9                                             [cek, ]
# 24  [mau, info, infihome, rumah, kami, eror, sudah...
# 25                        [lebih, dekat, min, hehehe]
# 26  [permisi, melaporkan, klo, indihome, rumah, ma...
# 32  [indihome, saya, sdh, daftar, bln, nama, tamam...
# 33                                            [cek, ]
# 34  [makasih, satu, yang, disuka, dari, indihome, ...
# 35  [tolong, kembalikan, uang, jaminan, saya, suda...
# 36  [halo, sudah, seminggu, internet, saya, ganggu...
# 37              [aplikasi, indihome, download, dmn, ]
# 38  [kak, paket, indihome, tanpa, channel, mbps, b...
# 39  [kak, paket, indihome, tanpa, channel, skrng, ...
#
#                                              stopword
# 0                                            [mantap]
# 1               [proses, berhenti, berlanganan, alur]
# 2                                       [pelanggan, ]
# 3               [min, berhenti, berlangganan, gimana]
# 9                                             [cek, ]
# 24  [info, infihome, rumah, eror, minggu, lapor, t...
# 25                                      [min, hehehe]
# 26  [permisi, melaporkan, indihome, rumah, mati, k...
# 32  [indihome, daftar, bln, nama, tamam, supri, ya...
# 33                                            [cek, ]
# 34  [makasih, disuka, indihome, fast, respon, frie...
# 35      [tolong, kembalikan, uang, jaminan, tunggu, ]
# 36  [halo, seminggu, internet, gangguan, nomor, ti...
# 37              [aplikasi, indihome, download, dmn, ]
# 38            [kak, paket, indihome, channel, mbps, ]
# 39  [kak, paket, indihome, channel, skrng, kecepat...

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 77
# ------------------------
# mantap : mantap
# proses : proses
# berhenti : henti
# berlanganan : berlanganan
# alur : alur
# pelanggan : langgan
#  :
# min : min
# berlangganan : langgan
# gimana : gimana
# cek : cek
# info : info
# infihome : infihome
# rumah : rumah
# eror : eror
# minggu : minggu
# lapor : lapor
# telkom : telkom
# respon : respon
# bayar : bayar
# lunas : lunas
# hehehe : hehehe
# permisi : permisi
# melaporkan : lapor
# indihome : indihome
# mati : mati
# kemarin : kemarin
# bantu : bantu
# daftar : daftar
# bln : bln
# nama : nama
# tamam : tamam
# supri : supri
# yanto : yanto
# maduran : maduran
# lamongan : lamongan
# jatim : jatim
# nmer : nmer
# registrasi : registrasi
# blm : blm
# pasang : pasang
# tolong : tolong
# kasih : kasih
# cepat : cepat
# sbb : sbb
# buka : buka
# warung : warung
# makasih : makasih
# disuka : suka
# fast : fast
# friendly : friendly
# tetaplah : tetap
# terbaik : baik
# kembalikan : kembali
# uang : uang
# jaminan : jamin
# tunggu : tunggu
# halo : halo
# seminggu : minggu
# internet : internet
# gangguan : ganggu
# nomor : nomor
# tiket : tiket
# in : in
# nggak : nggak
# progress : progress
# penanganan : tangan
# mbps : mbps
# dapetnya : dapetnya
# aplikasi : aplikasi
# download : download
# dmn : dmn
# kak : kak
# paket : paket
# channel : channel
# skrng : skrng
# kecepatan : cepat
# {'mantap': 'mantap', 'proses': 'proses', 'berhenti': 'henti', 'berlanganan': 'berlanganan', 'alur': 'alur', 'pelanggan': 'langgan', '': '', 'min': 'min', 'berlangganan': 'langgan', 'gimana': 'gimana', 'cek': 'cek', 'info': 'info', 'infihome': 'infihome', 'rumah': 'rumah', 'eror': 'eror', 'minggu': 'minggu', 'lapor': 'lapor', 'telkom': 'telkom', 'respon': 'respon', 'bayar': 'bayar', 'lunas': 'lunas', 'hehehe': 'hehehe', 'permisi': 'permisi', 'melaporkan': 'lapor', 'indihome': 'indihome', 'mati': 'mati', 'kemarin': 'kemarin', 'bantu': 'bantu', 'daftar': 'daftar', 'bln': 'bln', 'nama': 'nama', 'tamam': 'tamam', 'supri': 'supri', 'yanto': 'yanto', 'maduran': 'maduran', 'lamongan': 'lamongan', 'jatim': 'jatim', 'nmer': 'nmer', 'registrasi': 'registrasi', 'blm': 'blm', 'pasang': 'pasang', 'tolong': 'tolong', 'kasih': 'kasih', 'cepat': 'cepat', 'sbb': 'sbb', 'buka': 'buka', 'warung': 'warung', 'makasih': 'makasih', 'disuka': 'suka', 'fast': 'fast', 'friendly': 'friendly', 'tetaplah': 'tetap', 'terbaik': 'baik', 'kembalikan': 'kembali', 'uang': 'uang', 'jaminan': 'jamin', 'tunggu': 'tunggu', 'halo': 'halo', 'seminggu': 'minggu', 'internet': 'internet', 'gangguan': 'ganggu', 'nomor': 'nomor', 'tiket': 'tiket', 'in': 'in', 'nggak': 'nggak', 'progress': 'progress', 'penanganan': 'tangan', 'mbps': 'mbps', 'dapetnya': 'dapetnya', 'aplikasi': 'aplikasi', 'download': 'download', 'dmn': 'dmn', 'kak': 'kak', 'paket': 'paket', 'channel': 'channel', 'skrng': 'skrng', 'kecepatan': 'cepat'}
# ------------------------
# Pandas Apply:   0%|          | 0/16 [00:00<?, ?it/s]
#                                                  text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                          nmr pelanggan 141425108331
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                              cek dm
# 24  mau info, infihome di rumah kami eror sudah sa...
# 25                          lebih dekat ya min hehehe
# 26  permisi sy mw melaporkan klo indihome di rumah...
# 32  indihome saya sdh daftar 1 bln nama tamam supr...
# 33                                             cek dm
# 34  makasih, satu yang disuka dari indihome fast r...
# 35  tolong kembalikan uang jaminan saya.. yg sudah...
# 36  halo..sudah seminggu internet saya gangguan, n...
# 37                 aplikasi my indihome download dmn?
# 38  kak, paket indihome tanpa channel tv 10mbps be...
# 39  kak, paket indihome tanpa channel tv skrng ber...
#
#                                         cleaning_text  \
# 0                                              mantap
# 1   tapi untuk proses berhenti berlanganan alur ny...
# 2                                     nmr pelanggan
# 3   min kalau mau berhenti berlangganan gimana car...
# 9                                                cek
# 24  mau info infihome rumah kami eror sudah satu m...
# 25                             lebih dekat min hehehe
# 26  permisi melaporkan klo indihome rumah mati kem...
# 32  indihome saya sdh daftar bln nama tamam supri ...
# 33                                               cek
# 34  makasih satu yang disuka dari indihome fast re...
# 35  tolong kembalikan uang jaminan saya sudah tung...
# 36  halo sudah seminggu internet saya gangguan nom...
# 37                    aplikasi indihome download dmn
# 38     kak paket indihome tanpa channel  mbps berapa
# 39  kak paket indihome tanpa channel skrng berapa ...
#
#                                            tokenisasi  \
# 0                                            [mantap]
# 1   [tapi, untuk, proses, berhenti, berlanganan, a...
# 2                                  [nmr, pelanggan, ]
# 3   [min, kalau, mau, berhenti, berlangganan, gima...
# 9                                             [cek, ]
# 24  [mau, info, infihome, rumah, kami, eror, sudah...
# 25                        [lebih, dekat, min, hehehe]
# 26  [permisi, melaporkan, klo, indihome, rumah, ma...
# 32  [indihome, saya, sdh, daftar, bln, nama, tamam...
# 33                                            [cek, ]
# 34  [makasih, satu, yang, disuka, dari, indihome, ...
# 35  [tolong, kembalikan, uang, jaminan, saya, suda...
# 36  [halo, sudah, seminggu, internet, saya, ganggu...
# 37              [aplikasi, indihome, download, dmn, ]
# 38  [kak, paket, indihome, tanpa, channel, mbps, b...
# 39  [kak, paket, indihome, tanpa, channel, skrng, ...
#
#                                              stopword  \
# 0                                            [mantap]
# 1               [proses, berhenti, berlanganan, alur]
# 2                                       [pelanggan, ]
# 3               [min, berhenti, berlangganan, gimana]
# 9                                             [cek, ]
# 24  [info, infihome, rumah, eror, minggu, lapor, t...
# 25                                      [min, hehehe]
# 26  [permisi, melaporkan, indihome, rumah, mati, k...
# 32  [indihome, daftar, bln, nama, tamam, supri, ya...
# 33                                            [cek, ]
# 34  [makasih, disuka, indihome, fast, respon, frie...
# 35      [tolong, kembalikan, uang, jaminan, tunggu, ]
# 36  [halo, seminggu, internet, gangguan, nomor, ti...
# 37              [aplikasi, indihome, download, dmn, ]
# 38            [kak, paket, indihome, channel, mbps, ]
# 39  [kak, paket, indihome, channel, skrng, kecepat...
#
#                                              stemming
# 0                                            [mantap]
# 1                  [proses, henti, berlanganan, alur]
# 2                                         [langgan, ]
# 3                       [min, henti, langgan, gimana]
# 9                                             [cek, ]
# 24  [info, infihome, rumah, eror, minggu, lapor, t...
# 25                                      [min, hehehe]
# 26  [permisi, lapor, indihome, rumah, mati, kemari...
# 32  [indihome, daftar, bln, nama, tamam, supri, ya...
# 33                                            [cek, ]
# 34  [makasih, suka, indihome, fast, respon, friend...
# 35           [tolong, kembali, uang, jamin, tunggu, ]
# 36  [halo, minggu, internet, ganggu, nomor, tiket,...
# 37              [aplikasi, indihome, download, dmn, ]
# 38            [kak, paket, indihome, channel, mbps, ]
# 39  [kak, paket, indihome, channel, skrng, cepat, ...

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                               comment
# 0                                            [mantap]
# 1                  [proses, henti, berlanganan, alur]
# 2                                         [langgan, ]
# 3                       [min, henti, langgan, gimana]
# 9                                             [cek, ]
# 24  [info, infihome, rumah, eror, minggu, lapor, t...
# 25                                      [min, hehehe]
# 26  [permisi, lapor, indihome, rumah, mati, kemari...
# 32  [indihome, daftar, bln, nama, tamam, supri, ya...
# 33                                            [cek, ]
# 34  [makasih, suka, indihome, fast, respon, friend...
# 35           [tolong, kembali, uang, jamin, tunggu, ]
# 36  [halo, minggu, internet, ganggu, nomor, tiket,...
# 37              [aplikasi, indihome, download, dmn, ]
# 38            [kak, paket, indihome, channel, mbps, ]
# 39  [kak, paket, indihome, channel, skrng, cepat, ...

# %%
Final.to_excel('databersih_instagram_indihome_1.xlsx')
