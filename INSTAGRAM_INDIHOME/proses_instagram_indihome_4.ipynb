# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0          Mau pasang tapi bingung mau tanya kemana ya
# 1    Harus disimpe nomornya biar ga lupa\n\n#Intern...
# 2    Harus di save nihh nomornya biar engga lupa\n#...
# 3    Sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     Ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare STABIL?? BUKA WHATSAPP AJA BUFFE...
# 233  Internet saya sering eror hampir tiap hari sam...
# 234  Makin kesini makin perihatin sinyal Indigo. Ka...
# 235  Ni Kanapa Sih Mati Nyala Mati Nyala Tros Jarin...
# 236  Hari ini cakung gangguan lagi...dilaporin di a...
#
# [237 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 19

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0          Mau pasang tapi bingung mau tanya kemana ya
# 1    Harus disimpe nomornya biar ga lupa\n\n#Intern...
# 2    Harus di save nihh nomornya biar engga lupa\n#...
# 3    Sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     Ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare STABIL?? BUKA WHATSAPP AJA BUFFE...
# 233  Internet saya sering eror hampir tiap hari sam...
# 234  Makin kesini makin perihatin sinyal Indigo. Ka...
# 235  Ni Kanapa Sih Mati Nyala Mati Nyala Tros Jarin...
# 236  Hari ini cakung gangguan lagi...dilaporin di a...
#
# [203 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0          mau pasang tapi bingung mau tanya kemana ya
# 1    harus disimpe nomornya biar ga lupa\n\n#intern...
# 2    harus di save nihh nomornya biar engga lupa\n#...
# 3    sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare stabil?? buka whatsapp aja buffe...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo. ka...
# 235  ni kanapa sih mati nyala mati nyala tros jarin...
# 236  hari ini cakung gangguan lagi...dilaporin di a...
#
# [203 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0          mau pasang tapi bingung mau tanya kemana ya
# 1    harus disimpe nomornya biar ga lupa\n\n#intern...
# 2    harus di save nihh nomornya biar engga lupa\n#...
# 3    sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare stabil?? buka whatsapp aja buffe...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo. ka...
# 235  ni kanapa sih mati nyala mati nyala tros jarin...
# 236  hari ini cakung gangguan lagi...dilaporin di a...
#
#                                          cleaning_text
# 0            mau pasang tapi bingung mau tanya kemana
# 1                     harus disimpe nomornya biar lupa
# 2             harus save nihh nomornya biar engga lupa
# 3     sdh ditelpon   dan sdh melengkapi data  koq b...
# 4        ini dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  stabil buka whatsapp aja buffer ini gmna sikkk...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo kal...
# 235   kanapa sih mati nyala mati nyala tros jaringa...
# 236  hari ini cakung gangguan lagi dilaporin aplika...
#
# [203 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0          mau pasang tapi bingung mau tanya kemana ya
# 1    harus disimpe nomornya biar ga lupa\n\n#intern...
# 2    harus di save nihh nomornya biar engga lupa\n#...
# 3    sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare stabil?? buka whatsapp aja buffe...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo. ka...
# 235  ni kanapa sih mati nyala mati nyala tros jarin...
# 236  hari ini cakung gangguan lagi...dilaporin di a...
#
#                                          cleaning_text  \
# 0            mau pasang tapi bingung mau tanya kemana
# 1                     harus disimpe nomornya biar lupa
# 2             harus save nihh nomornya biar engga lupa
# 3     sdh ditelpon   dan sdh melengkapi data  koq b...
# 4        ini dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  stabil buka whatsapp aja buffer ini gmna sikkk...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo kal...
# 235   kanapa sih mati nyala mati nyala tros jaringa...
# 236  hari ini cakung gangguan lagi dilaporin aplika...
#
#                                             tokenisasi
# 0    [mau, pasang, tapi, bingung, mau, tanya, keman...
# 1               [harus, disimpe, nomornya, biar, lupa]
# 2     [harus, save, nihh, nomornya, biar, engga, lupa]
# 3    [, sdh, ditelpon, dan, sdh, melengkapi, data, ...
# 4    [ini, dikira, dari, syp, hehehe, thanks, kak, ...
# ..                                                 ...
# 232  [stabil, buka, whatsapp, aja, buffer, ini, gmn...
# 233  [internet, saya, sering, eror, hampir, tiap, h...
# 234  [makin, kesini, makin, perihatin, sinyal, indi...
# 235  [, kanapa, sih, mati, nyala, mati, nyala, tros...
# 236  [hari, ini, cakung, gangguan, lagi, dilaporin,...
#
# [203 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0          mau pasang tapi bingung mau tanya kemana ya
# 1    harus disimpe nomornya biar ga lupa\n\n#intern...
# 2    harus di save nihh nomornya biar engga lupa\n#...
# 3    sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare stabil?? buka whatsapp aja buffe...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo. ka...
# 235  ni kanapa sih mati nyala mati nyala tros jarin...
# 236  hari ini cakung gangguan lagi...dilaporin di a...
#
#                                          cleaning_text  \
# 0            mau pasang tapi bingung mau tanya kemana
# 1                     harus disimpe nomornya biar lupa
# 2             harus save nihh nomornya biar engga lupa
# 3     sdh ditelpon   dan sdh melengkapi data  koq b...
# 4        ini dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  stabil buka whatsapp aja buffer ini gmna sikkk...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo kal...
# 235   kanapa sih mati nyala mati nyala tros jaringa...
# 236  hari ini cakung gangguan lagi dilaporin aplika...
#
#                                             tokenisasi  \
# 0    [mau, pasang, tapi, bingung, mau, tanya, keman...
# 1               [harus, disimpe, nomornya, biar, lupa]
# 2     [harus, save, nihh, nomornya, biar, engga, lupa]
# 3    [, sdh, ditelpon, dan, sdh, melengkapi, data, ...
# 4    [ini, dikira, dari, syp, hehehe, thanks, kak, ...
# ..                                                 ...
# 232  [stabil, buka, whatsapp, aja, buffer, ini, gmn...
# 233  [internet, saya, sering, eror, hampir, tiap, h...
# 234  [makin, kesini, makin, perihatin, sinyal, indi...
# 235  [, kanapa, sih, mati, nyala, mati, nyala, tros...
# 236  [hari, ini, cakung, gangguan, lagi, dilaporin,...
#
#                                               stopword
# 0                          [pasang, bingung, kemana, ]
# 1                            [disimpe, nomornya, lupa]
# 2                  [save, nihh, nomornya, engga, lupa]
# 3    [, ditelpon, melengkapi, data, koq, blom, terp...
# 4                  [syp, hehehe, thanks, kak, infonya]
# ..                                                 ...
# 232  [stabil, buka, whatsapp, buffer, gmna, sikkk, ...
# 233  [internet, eror, berjam, jam, eror, jam, pagi,...
# 234  [kesini, perihatin, sinyal, indigo, udah, comp...
# 235  [, kanapa, mati, nyala, mati, nyala, tros, jar...
# 236  [cakung, gangguan, dilaporin, aplikasi, bilang...
#
# [203 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 610
# ------------------------
# pasang : pasang
# bingung : bingung
# kemana : mana
#  :
# disimpe : disimpe
# nomornya : nomor
# lupa : lupa
# save : save
# nihh : nihh
# engga : engga
# ditelpon : telpon
# melengkapi : lengkap
# data : data
# koq : koq
# blom : blom
# terpasang : pasang
# jaringannya : jaring
# syp : syp
# hehehe : hehehe
# thanks : thanks
# kak : kak
# infonya : info
# ngeleg : ngeleg
# jaringan : jaring
# terisolir : isolir
# min : min
# cek : cek
# lgi : lgi
# astaga : astaga
# read : read
# doang : doang
# awasi : awas
# seru : seru
# belajar : ajar
# mengedukasi : edukasi
# bener : bener
# edukids : edukids
# wifiny : wifiny
# terputus : putus
# padhl : padhl
# bayran : bayran
# lancar : lancar
# pass : pass
# wifi : wifi
# kegnti : kegnti
# anak : anak
# bocil : bocil
# betah : betah
# hati : hati
# indihome : indihome
# gangguang : gangguang
# pagi : pagi
# tolong : tolong
# bantu : bantu
# follow : follow
# gangguan : ganggu
# terima : terima
# kasih : kasih
# terbaik : baik
# hai : hai
# bro : bro
# fitur : fitur
# seruin : seruin
# dijaman : jam
# banget : banget
# edukasi : edukasi
# gini : gin
# wahh : wahh
# bermanfaat : manfaat
# sesuai : sesuai
# umur : umur
# sore : sore
# langganan : langgan
# inet : inet
# non : non
# aktifkan : aktif
# internet : internet
# skrg : skrg
# trus : trus
# pemasangan : pasang
# keren : keren
# seamless : seamless
# maksimal : maksimal
# gadget : gadget
# mantapp : mantapp
# selalalu : selalalu
# alasan : alas
# klasik : klasik
# traffic : traffic
# rame : rame
# lag : lag
# bodoamat : bodoamat
# server : server
# kgk : kgk
# peduli : peduli
# sampah : sampah
# bet : bet
# swasta : swasta
# bagus : bagus
# dana : dana
# dikorup : korup
# gmn : gmn
# puna : puna
# negara : negara
# main : main
# ngedelay : ngedelay
# maaf : maaf
# udah : udah
# respon : respon
# uang : uang
# bayar : bayar
# sampe : sampe
# abal : abal
# abalnya : abalnya
# transfer : transfer
# uangnya : uang
# masyaallah : masyaallah
# mengecewakan : kecewa
# lapor : lapor
# via : via
# putusin : putusin
# seminggu : minggu
# perbaikan : baik
# coba : coba
# iya : iya
# dispensasi : dispensasi
# pengurangan : kurang
# pembayaran : bayar
# mah : mah
# rusak : rusak
# jwb : jwb
# aplikasinya : aplikasi
# mudah : mudah
# pengecekkannya : ecek
# tonton : tonton
# internetnya : internetnya
# lelet : lelet
# timbul : timbul
# tenggelam : tenggelam
# online : online
# terganggu : ganggu
# wihhh : wihhh
# yaa : yaa
# aplikasi : aplikasi
# myindihome : myindihome
# pengaduan : adu
# dtanggapi : dtanggapi
# bayaran : bayar
# telat : telat
# denda : denda
# parah : parah
# enak : enak
# praktis : praktis
# mantep : mantep
# kembaliin : kembaliin
# deposit : deposit
# woy : woy
# pemakaian : pakai
# terimakasih : terimakasih
# informasinya : informasi
# latency : latency
# drop : drop
# solusi : solusi
# adminnya : adminnya
# berguna : guna
# lohhh : lohhh
# disarankan : saran
# paket : paket
# mahal : mahal
# smart : smart
# sekaleee : sekaleee
# nama : nama
# neneng : neneng
# rohamdah : rohamdah
# waaahh : waaahh
# teerima : teerima
# good : good
# info : info
# makasih : makasih
# kuy : kuy
# ati : ati
# akses : akses
# ilegal : ilegal
# tipssnyaa : tipssnyaa
# dicoba : coba
# aman : aman
# membantu : bantu
# thank : thank
# eror : eror
# diganti : ganti
# berkali : kali
# kali : kali
# komplain : komplain
# dibales : dibales
# mulu : mulu
# knp : knp
# kayaknya : kayak
# tiapa : tiapa
# tulisan : tulis
# pon : pon
# warna : warna
# merah : merah
# setia : setia
# malem : malem
# halo : halo
# admin : admin
# selamat : selamat
# mohon : mohon
# kereeennnnn : kereeennnnn
# ajib : ajib
# layanan : layan
# seamles : seamles
# brpa : brpa
# devic : devic
# nyaman : nyaman
# mampus : mampus
# dihujat : hujat
# kau : kau
# pepek : pepek
# nonton : nonton
# film : film
# indihometv : indihometv
# nntn : nntn
# lemot : lot
# buruk : buruk
# pakai : pakai
# menarik : tarik
# pelanggan : langgan
# puasa : puasa
# open : open
# all : all
# channel : channel
# bad : bad
# buruan : buru
# dman : dman
# gua : gua
# putus : putus
# kerjaan : kerja
# urgent : urgent
# malam : malam
# ohh : ohh
# luasss : luasss
# teguran : tegur
# atasannya : atas
# krna : krna
# menyelesaikan : selesai
# pekerjaannya : kerja
# kemarin : kemarin
# kerja : kerja
# hosport : hosport
# drafter : drafter
# tekla : tekla
# selamet : selamet
# penyebab : sebab
# rumah : rumah
# pdahal : pdahal
# orang : orang
# mengerti : erti
# computer : computer
# blokir : blokir
# ngak : ngak
# dirumah : rumah
# dipakai : pakai
# leptop : leptop
# diluar : luar
# gitu : gitu
# wahhh : wahhh
# jangkauan : jangkau
# berlangganan : langgan
# extender : extender
# dri : dri
# nambah : nambah
# biaya : biaya
# jaraknya : jarak
# kejauhan : jauh
# titik : titik
# ngentod : ngentod
# sinyal : sinyal
# lancarnya : lancar
# pokoknya : pokok
# sinyalnya : sinyal
# perluas : luas
# sepenuhnya : sepenuh
# merata : rata
# merasakan : rasa
# top : top
# maaci : maaci
# yukk : yukk
# cover : cover
# area : area
# first : first
# medianyaa : medianyaa
# harga : harga
# rban : rban
# unlimited : unlimited
# quotas : quotas
# langsung : langsung
# yahh : yahh
# diperbaiki : baik
# secepatnya : cepat
# los : los
# kendala : kendala
# berani : berani
# gimana : gimana
# ngasi : ngasi
# bahaya : bahaya
# emang : emang
# gaboleh : gaboleh
# minn : minn
# guys : guys
# woooiiiii : woooiiiii
# tagihan : tagih
# kuota : kuota
# habis : habis
# eksis : eks
# boros : boros
# media : media
# hub : hub
# menit : menit
# mati : mati
# koneksi : koneksi
# kualitasnya : kualitas
# perbagus : bagus
# loss : loss
# gblok : gblok
# bls : bls
# gabut : gabut
# lintah : lintah
# darat : darat
# april : april
# kabel : kabel
# isolator : isolator
# bln : bln
# maret : maret
# disuruh : suruh
# gilak : gilak
# astagfirullahaladzim : astagfirullahaladzim
# th : th
# seimbang : imbang
# error : error
# nikrablenya : nikrablenya
# mmmh : mmmh
# musibah : musibah
# mengenal : kenal
# beda : beda
# sebelah : belah
# terbuka : buka
# knapa : knapa
# bola : bola
# acak : acak
# blm : blm
# dtg : dtg
# tmp : tmp
# nge : nge
# mensolusikan : solusi
# trik : trik
# skrng : skrng
# chat : chat
# baca : baca
# bantuannya : bantu
# udh : udh
# ngemis : ngemis
# kayak : kayak
# gaada : gaada
# memperjuangkan : juang
# hak : hak
# nomor : nomor
# rekening : rekening
# dikembalikan : kembali
# odp : odp
# full : full
# regis : regis
# line : line
# tinggal : tinggal
# pln : pln
# amazing : amazing
# terobosan : terobos
# dirut : dirut
# stabil : stabil
# semangat : semangat
# wfhnya : wfhnya
# sebulan : bulan
# tindak : tindak
# lanjuti : lanjut
# sistem : sistem
# services : services
# catat : catat
# repot : repot
# keluhannya : keluh
# telfon : telfon
# call : call
# center : center
# tanggapan : tanggap
# bales : bales
# yak : yak
# gercep : gercep
# proses : proses
# pengembalian : kembali
# depositnya : deposit
# tanggung : tanggung
# costumer : costumer
# dilunasin : dilunasin
# perangkat : perangkat
# anterin : anterin
# giliran : gilir
# tanggal : tanggal
# berhenti : henti
# kapok : kapok
# gampang : gampang
# nyala : nyala
# post : post
# mempermudah : mudah
# memperlambat : lambat
# game : game
# ngelagnya : ngelagnya
# turun : turun
# rank : rank
# balas : balas
# kakak : kakak
# add : add
# melon : melon
# silver : silver
# aktivasi : aktivasi
# delete : delete
# kah : kah
# diem : diem
# baee : baee
# program : program
# ikutan : ikut
# berlaku : laku
# membayar : bayar
# mantap : mantap
# berkaitan : kait
# keluhan : keluh
# sblm : sblm
# tgl : tgl
# promo : promo
# chanel : chanel
# dipilih : pilih
# tambahan : tambah
# hilang : hilang
# phpin : phpin
# oke : oke
# indihomecare : indihomecare
# pertimbangan : timbang
# kondisinya : kondisi
# solusinya : solusi
# tipsnya : tipsnya
# apresiasi : apresiasi
# teknisi : teknisi
# ditingkatkan : tingkat
# prioritasin : prioritasin
# dtgin : dtgin
# pengecekan : kece
# klu : klu
# emg : emg
# karna : karna
# pusat : pusat
# gamasalah : gamasalah
# tunggu : tunggu
# menunggu : tunggu
# sia : sia
# lgs : lgs
# teratasi : atas
# maintenance : maintenance
# meter : meter
# bwt : bwt
# loading : loading
# buffer : buffer
# ampun : ampun
# high : high
# user : user
# haduuu : haduuu
# nyampe : nyampe
# ganti : ganti
# provider : provider
# pilihan : pilih
# kereenn : kereenn
# tips : tips
# janji : janji
# jam : jam
# butuh : butuh
# bareng : bareng
# ngabuburit : ngabuburit
# register : register
# pindah : pindah
# alamat : alamat
# teknisinya : teknisi
# restar : restar
# jaringa : jaringa
# diread : diread
# minnn : minnn
# ngapa : ngapa
# bat : bat
# minggu : minggu
# sempet : sempet
# hadeh : hadeh
# european : european
# super : super
# league : league
# disiarin : disiarin
# pelayanan : layan
# duit : duit
# yeeess : yeeess
# dancok : dancok
# cok : cok
# bulannya : bulan
# dikurangin : rangin
# harinya : hari
# kurangin : rangin
# bayarnya : bayar
# mundur : mundur
# kalender : kalender
# puyeng : puyeng
# pala : pala
# brrby : brrby
# hiburan : hibur
# menu : menu
# renew : renew
# speed : speed
# jelek : jelek
# wih : wih
# memudahkan : mudah
# sinyalna : sinyalna
# dicek : cek
# donk : donk
# umtuk : umtuk
# makasi : makas
# susah : susah
# saldo : saldo
# miiinnnn : miiinnnn
# laq : laq
# tambahin : tambahin
# detail : detail
# permintaan : minta
# dapet : dapet
# pinnya : pin
# notif : notif
# kirim : kirim
# email : email
# sms : sms
# tpi : tpi
# masuk : masuk
# pemeliharan : pemeliharan
# cuman : cuman
# semenjak : semenjak
# nga : nga
# dipanggil : panggil
# penanganan : tangan
# sla : sla
# brp : brp
# handle : handle
# kenapaaaa : kenapaaaa
# wifiiii : wifiiii
# internetnyaa : internetnyaa
# gadaaaaaaa : gadaaaaaaa
# bos : bos
# suspend : suspend
# heran : heran
# gue : gue
# progress : progress
# numpuk : numpuk
# gara : gara
# mbps : mbps
# rbu : rbu
# kemaren : kemaren
# telkom : telkom
# syukron : syukron
# pahala : pahala
# sya : sya
# miris : miris
# sudh : sudh
# suruh : suruh
# status : status
# dibantu : bantu
# daerah : daerah
# pluit : pluit
# tlp : tlp
# neh : neh
# sayah : sayah
# kwatir : kwatir
# check : check
# keluh : keluh
# memakai : pakai
# wms : wms
# kereeenn : kereeenn
# ngga : ngga
# mola : mola
# buka : buka
# whatsapp : whatsapp
# gmna : gmna
# sikkk : sikkk
# ngaku : ngaku
# berjam : jam
# bagaimna : bagaimna
# bngung : bngung
# komplen : komplen
# trima : trima
# kesini : kesini
# perihatin : perihatin
# indigo : indigo
# complain : complain
# kanapa : kanapa
# tros : tros
# cakung : cakung
# dilaporin : dilaporin
# bilangnya : bilang
# massal : massal
# iuran : iur
# gratis : gratis
# {'pasang': 'pasang', 'bingung': 'bingung', 'kemana': 'mana', '': '', 'disimpe': 'disimpe', 'nomornya': 'nomor', 'lupa': 'lupa', 'save': 'save', 'nihh': 'nihh', 'engga': 'engga', 'ditelpon': 'telpon', 'melengkapi': 'lengkap', 'data': 'data', 'koq': 'koq', 'blom': 'blom', 'terpasang': 'pasang', 'jaringannya': 'jaring', 'syp': 'syp', 'hehehe': 'hehehe', 'thanks': 'thanks', 'kak': 'kak', 'infonya': 'info', 'ngeleg': 'ngeleg', 'jaringan': 'jaring', 'terisolir': 'isolir', 'min': 'min', 'cek': 'cek', 'lgi': 'lgi', 'astaga': 'astaga', 'read': 'read', 'doang': 'doang', 'awasi': 'awas', 'seru': 'seru', 'belajar': 'ajar', 'mengedukasi': 'edukasi', 'bener': 'bener', 'edukids': 'edukids', 'wifiny': 'wifiny', 'terputus': 'putus', 'padhl': 'padhl', 'bayran': 'bayran', 'lancar': 'lancar', 'pass': 'pass', 'wifi': 'wifi', 'kegnti': 'kegnti', 'anak': 'anak', 'bocil': 'bocil', 'betah': 'betah', 'hati': 'hati', 'indihome': 'indihome', 'gangguang': 'gangguang', 'pagi': 'pagi', 'tolong': 'tolong', 'bantu': 'bantu', 'follow': 'follow', 'gangguan': 'ganggu', 'terima': 'terima', 'kasih': 'kasih', 'terbaik': 'baik', 'hai': 'hai', 'bro': 'bro', 'fitur': 'fitur', 'seruin': 'seruin', 'dijaman': 'jam', 'banget': 'banget', 'edukasi': 'edukasi', 'gini': 'gin', 'wahh': 'wahh', 'bermanfaat': 'manfaat', 'sesuai': 'sesuai', 'umur': 'umur', 'sore': 'sore', 'langganan': 'langgan', 'inet': 'inet', 'non': 'non', 'aktifkan': 'aktif', 'internet': 'internet', 'skrg': 'skrg', 'trus': 'trus', 'pemasangan': 'pasang', 'keren': 'keren', 'seamless': 'seamless', 'maksimal': 'maksimal', 'gadget': 'gadget', 'mantapp': 'mantapp', 'selalalu': 'selalalu', 'alasan': 'alas', 'klasik': 'klasik', 'traffic': 'traffic', 'rame': 'rame', 'lag': 'lag', 'bodoamat': 'bodoamat', 'server': 'server', 'kgk': 'kgk', 'peduli': 'peduli', 'sampah': 'sampah', 'bet': 'bet', 'swasta': 'swasta', 'bagus': 'bagus', 'dana': 'dana', 'dikorup': 'korup', 'gmn': 'gmn', 'puna': 'puna', 'negara': 'negara', 'main': 'main', 'ngedelay': 'ngedelay', 'maaf': 'maaf', 'udah': 'udah', 'respon': 'respon', 'uang': 'uang', 'bayar': 'bayar', 'sampe': 'sampe', 'abal': 'abal', 'abalnya': 'abalnya', 'transfer': 'transfer', 'uangnya': 'uang', 'masyaallah': 'masyaallah', 'mengecewakan': 'kecewa', 'lapor': 'lapor', 'via': 'via', 'putusin': 'putusin', 'seminggu': 'minggu', 'perbaikan': 'baik', 'coba': 'coba', 'iya': 'iya', 'dispensasi': 'dispensasi', 'pengurangan': 'kurang', 'pembayaran': 'bayar', 'mah': 'mah', 'rusak': 'rusak', 'jwb': 'jwb', 'aplikasinya': 'aplikasi', 'mudah': 'mudah', 'pengecekkannya': 'ecek', 'tonton': 'tonton', 'internetnya': 'internetnya', 'lelet': 'lelet', 'timbul': 'timbul', 'tenggelam': 'tenggelam', 'online': 'online', 'terganggu': 'ganggu', 'wihhh': 'wihhh', 'yaa': 'yaa', 'aplikasi': 'aplikasi', 'myindihome': 'myindihome', 'pengaduan': 'adu', 'dtanggapi': 'dtanggapi', 'bayaran': 'bayar', 'telat': 'telat', 'denda': 'denda', 'parah': 'parah', 'enak': 'enak', 'praktis': 'praktis', 'mantep': 'mantep', 'kembaliin': 'kembaliin', 'deposit': 'deposit', 'woy': 'woy', 'pemakaian': 'pakai', 'terimakasih': 'terimakasih', 'informasinya': 'informasi', 'latency': 'latency', 'drop': 'drop', 'solusi': 'solusi', 'adminnya': 'adminnya', 'berguna': 'guna', 'lohhh': 'lohhh', 'disarankan': 'saran', 'paket': 'paket', 'mahal': 'mahal', 'smart': 'smart', 'sekaleee': 'sekaleee', 'nama': 'nama', 'neneng': 'neneng', 'rohamdah': 'rohamdah', 'waaahh': 'waaahh', 'teerima': 'teerima', 'good': 'good', 'info': 'info', 'makasih': 'makasih', 'kuy': 'kuy', 'ati': 'ati', 'akses': 'akses', 'ilegal': 'ilegal', 'tipssnyaa': 'tipssnyaa', 'dicoba': 'coba', 'aman': 'aman', 'membantu': 'bantu', 'thank': 'thank', 'eror': 'eror', 'diganti': 'ganti', 'berkali': 'kali', 'kali': 'kali', 'komplain': 'komplain', 'dibales': 'dibales', 'mulu': 'mulu', 'knp': 'knp', 'kayaknya': 'kayak', 'tiapa': 'tiapa', 'tulisan': 'tulis', 'pon': 'pon', 'warna': 'warna', 'merah': 'merah', 'setia': 'setia', 'malem': 'malem', 'halo': 'halo', 'admin': 'admin', 'selamat': 'selama ...
# ------------------------
# Pandas Apply:   0%|          | 0/203 [00:00<?, ?it/s]
#                                                   text  \
# 0          mau pasang tapi bingung mau tanya kemana ya
# 1    harus disimpe nomornya biar ga lupa\n\n#intern...
# 2    harus di save nihh nomornya biar engga lupa\n#...
# 3    sy sdh ditelpon 1500620 dan sdh melengkapi dat...
# 4     ini ni dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  @indihomecare stabil?? buka whatsapp aja buffe...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo. ka...
# 235  ni kanapa sih mati nyala mati nyala tros jarin...
# 236  hari ini cakung gangguan lagi...dilaporin di a...
#
#                                          cleaning_text  \
# 0            mau pasang tapi bingung mau tanya kemana
# 1                     harus disimpe nomornya biar lupa
# 2             harus save nihh nomornya biar engga lupa
# 3     sdh ditelpon   dan sdh melengkapi data  koq b...
# 4        ini dikira dari syp hehehe thanks kak infonya
# ..                                                 ...
# 232  stabil buka whatsapp aja buffer ini gmna sikkk...
# 233  internet saya sering eror hampir tiap hari sam...
# 234  makin kesini makin perihatin sinyal indigo kal...
# 235   kanapa sih mati nyala mati nyala tros jaringa...
# 236  hari ini cakung gangguan lagi dilaporin aplika...
#
#                                             tokenisasi  \
# 0    [mau, pasang, tapi, bingung, mau, tanya, keman...
# 1               [harus, disimpe, nomornya, biar, lupa]
# 2     [harus, save, nihh, nomornya, biar, engga, lupa]
# 3    [, sdh, ditelpon, dan, sdh, melengkapi, data, ...
# 4    [ini, dikira, dari, syp, hehehe, thanks, kak, ...
# ..                                                 ...
# 232  [stabil, buka, whatsapp, aja, buffer, ini, gmn...
# 233  [internet, saya, sering, eror, hampir, tiap, h...
# 234  [makin, kesini, makin, perihatin, sinyal, indi...
# 235  [, kanapa, sih, mati, nyala, mati, nyala, tros...
# 236  [hari, ini, cakung, gangguan, lagi, dilaporin,...
#
#                                               stopword  \
# 0                          [pasang, bingung, kemana, ]
# 1                            [disimpe, nomornya, lupa]
# 2                  [save, nihh, nomornya, engga, lupa]
# 3    [, ditelpon, melengkapi, data, koq, blom, terp...
# 4                  [syp, hehehe, thanks, kak, infonya]
# ..                                                 ...
# 232  [stabil, buka, whatsapp, buffer, gmna, sikkk, ...
# 233  [internet, eror, berjam, jam, eror, jam, pagi,...
# 234  [kesini, perihatin, sinyal, indigo, udah, comp...
# 235  [, kanapa, mati, nyala, mati, nyala, tros, jar...
# 236  [cakung, gangguan, dilaporin, aplikasi, bilang...
#
#                                               stemming
# 0                            [pasang, bingung, mana, ]
# 1                               [disimpe, nomor, lupa]
# 2                     [save, nihh, nomor, engga, lupa]
# 3    [, telpon, lengkap, data, koq, blom, pasang, j...
# 4                     [syp, hehehe, thanks, kak, info]
# ..                                                 ...
# 232  [stabil, buka, whatsapp, buffer, gmna, sikkk, ...
# 233  [internet, eror, jam, jam, eror, jam, pagi, sa...
# 234  [kesini, perihatin, sinyal, indigo, udah, comp...
# 235  [, kanapa, mati, nyala, mati, nyala, tros, jar...
# 236  [cakung, ganggu, dilaporin, aplikasi, bilang, ...
#
# [203 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                            [pasang, bingung, mana, ]
# 1                               [disimpe, nomor, lupa]
# 2                     [save, nihh, nomor, engga, lupa]
# 3    [, telpon, lengkap, data, koq, blom, pasang, j...
# 4                     [syp, hehehe, thanks, kak, info]
# ..                                                 ...
# 232  [stabil, buka, whatsapp, buffer, gmna, sikkk, ...
# 233  [internet, eror, jam, jam, eror, jam, pagi, sa...
# 234  [kesini, perihatin, sinyal, indigo, udah, comp...
# 235  [, kanapa, mati, nyala, mati, nyala, tros, jar...
# 236  [cakung, ganggu, dilaporin, aplikasi, bilang, ...
#
# [203 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_4.xlsx')
