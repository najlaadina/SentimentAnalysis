# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["text"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\INSTAGRAM_INDIHOME\data mentah\instagram_indihome_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                   text
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek DM
# 2                                               cek dm
# 3                                               cek dm
# 4                                     ko ga bisa bayar
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    Akhir2 ini jaringan suka hilang sendiri..PARAHH
# 146  Info dong yg kota bekasi, pemasangan baru susa...
# 147  Sudah berkali" saya laporan tapi jawabannya se...
# 148  Min, pemasangan baru dirumah saya ko susah ben...
#
# [149 rows x 1 columns]

# %%
df.text.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(subset="text", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                   text
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek DM
# 4                                     ko ga bisa bayar
# 6    takut kalo data ilang tuh, untung Mimin IndiHo...
# 9                                            cek dm lg
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    Akhir2 ini jaringan suka hilang sendiri..PARAHH
# 146  Info dong yg kota bekasi, pemasangan baru susa...
# 147  Sudah berkali" saya laporan tapi jawabannya se...
# 148  Min, pemasangan baru dirumah saya ko susah ben...
#
# [139 rows x 1 columns]

# %%
#case folding
df['text'] = df['text'].str.lower()
df.head(2000)
# Out:
#                                                   text
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek dm
# 4                                     ko ga bisa bayar
# 6    takut kalo data ilang tuh, untung mimin indiho...
# 9                                            cek dm lg
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    akhir2 ini jaringan suka hilang sendiri..parahh
# 146  info dong yg kota bekasi, pemasangan baru susa...
# 147  sudah berkali" saya laporan tapi jawabannya se...
# 148  min, pemasangan baru dirumah saya ko susah ben...
#
# [139 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_text'] = df['text'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                   text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek dm
# 4                                     ko ga bisa bayar
# 6    takut kalo data ilang tuh, untung mimin indiho...
# 9                                            cek dm lg
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    akhir2 ini jaringan suka hilang sendiri..parahh
# 146  info dong yg kota bekasi, pemasangan baru susa...
# 147  sudah berkali" saya laporan tapi jawabannya se...
# 148  min, pemasangan baru dirumah saya ko susah ben...
#
#                                          cleaning_text
# 0              mininya mantep posting bermanfaat terus
# 1                                                 cek
# 4                                           bisa bayar
# 6    takut kalo data ilang tuh untung mimin indihom...
# 9                                                 cek
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan giliran ...
# 145     akhir  ini jaringan suka hilang sendiri parahh
# 146       info dong kota bekasi pemasangan baru susah
# 147  sudah berkali saya laporan tapi jawabannya sel...
# 148  min pemasangan baru dirumah saya susah bener p...
#
# [139 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_text'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                   text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek dm
# 4                                     ko ga bisa bayar
# 6    takut kalo data ilang tuh, untung mimin indiho...
# 9                                            cek dm lg
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    akhir2 ini jaringan suka hilang sendiri..parahh
# 146  info dong yg kota bekasi, pemasangan baru susa...
# 147  sudah berkali" saya laporan tapi jawabannya se...
# 148  min, pemasangan baru dirumah saya ko susah ben...
#
#                                          cleaning_text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                                 cek
# 4                                           bisa bayar
# 6    takut kalo data ilang tuh untung mimin indihom...
# 9                                                 cek
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan giliran ...
# 145     akhir  ini jaringan suka hilang sendiri parahh
# 146       info dong kota bekasi pemasangan baru susah
# 147  sudah berkali saya laporan tapi jawabannya sel...
# 148  min pemasangan baru dirumah saya susah bener p...
#
#                                             tokenisasi
# 0        [mininya, mantep, posting, bermanfaat, terus]
# 1                                              [cek, ]
# 4                                      [, bisa, bayar]
# 6    [takut, kalo, data, ilang, tuh, untung, mimin,...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, sehari, udah, mati, jaringan, g...
# 145  [akhir, ini, jaringan, suka, hilang, sendiri, ...
# 146  [info, dong, kota, bekasi, pemasangan, baru, s...
# 147  [sudah, berkali, saya, laporan, tapi, jawabann...
# 148  [min, pemasangan, baru, dirumah, saya, susah, ...
#
# [139 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                   text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek dm
# 4                                     ko ga bisa bayar
# 6    takut kalo data ilang tuh, untung mimin indiho...
# 9                                            cek dm lg
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    akhir2 ini jaringan suka hilang sendiri..parahh
# 146  info dong yg kota bekasi, pemasangan baru susa...
# 147  sudah berkali" saya laporan tapi jawabannya se...
# 148  min, pemasangan baru dirumah saya ko susah ben...
#
#                                          cleaning_text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                                 cek
# 4                                           bisa bayar
# 6    takut kalo data ilang tuh untung mimin indihom...
# 9                                                 cek
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan giliran ...
# 145     akhir  ini jaringan suka hilang sendiri parahh
# 146       info dong kota bekasi pemasangan baru susah
# 147  sudah berkali saya laporan tapi jawabannya sel...
# 148  min pemasangan baru dirumah saya susah bener p...
#
#                                             tokenisasi  \
# 0        [mininya, mantep, posting, bermanfaat, terus]
# 1                                              [cek, ]
# 4                                      [, bisa, bayar]
# 6    [takut, kalo, data, ilang, tuh, untung, mimin,...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, sehari, udah, mati, jaringan, g...
# 145  [akhir, ini, jaringan, suka, hilang, sendiri, ...
# 146  [info, dong, kota, bekasi, pemasangan, baru, s...
# 147  [sudah, berkali, saya, laporan, tapi, jawabann...
# 148  [min, pemasangan, baru, dirumah, saya, susah, ...
#
#                                               stopword
# 0               [mininya, mantep, posting, bermanfaat]
# 1                                              [cek, ]
# 4                                            [, bayar]
# 6    [takut, data, ilang, untung, mimin, indihome, ...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, sehari, udah, mati, jaringan, g...
# 145                   [jaringan, suka, hilang, parahh]
# 146          [info, kota, bekasi, pemasangan, susah, ]
# 147     [berkali, laporan, jawabannya, nihil, sabar, ]
# 148  [min, pemasangan, dirumah, susah, bener, kota,...
#
# [139 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 445
# ------------------------
# mininya : mini
# mantep : mantep
# posting : posting
# bermanfaat : manfaat
# cek : cek
#  :
# bayar : bayar
# takut : takut
# data : data
# ilang : ilang
# untung : untung
# mimin : mimin
# indihome : indihome
# ngasih : ngasih
# halo : halo
# miiiin : miiiin
# nais : nais
# inpoh : inpoh
# min : min
# tolong : tolong
# modem : modem
# nokia : nokia
# wl : wl
# gmn : gmn
# banget : banget
# pengguna : guna
# kenal : kenal
# semenjak : semenjak
# informasi : informasi
# membantu : bantu
# makasih : makasih
# hide : hide
# ssid : ssid
# nama : nama
# wifinya : wifinya
# cem : cem
# minnnnn : minnnnn
# rumah : rumah
# semarang : semarang
# demak : demak
# boyolali : boyolali
# pakai : pakai
# sinyal : sinyal
# boosokkkkkk : boosokkkkkk
# udh : udh
# kesel : kesel
# komentar : komentar
# buka : buka
# youtube : youtube
# bufering : bufering
# bufrering : bufrering
# video : video
# refresing : refresing
# game : game
# putus : putus
# jaringannya : jaring
# gimana : gimana
# mahal : mahal
# kualitas : kualitas
# busuk : busuk
# mending : mending
# cabut : cabut
# paket : paket
# telkomsel : telkomsel
# coba : coba
# inet : inet
# error : error
# mulu : mulu
# infonya : info
# wifi : wifi
# ttep : ttep
# account : account
# salah : salah
# lupa : lupa
# password : password
# diganti : ganti
# solusinya : solusi
# gmna : gmna
# kak : kak
# kesal : kesal
# eror : eror
# dri : dri
# pagi : pagi
# lampu : lampu
# internetnya : internetnya
# mati : mati
# malam : malam
# tunggu : tunggu
# kunjung : kunjung
# pon : pon
# hidup : hidup
# kabel : kabel
# menunggu : tunggu
# bosss : bosss
# nice : nice
# aman : aman
# kayanya : kaya
# nanya : nanya
# mendaftar : daftar
# website : website
# udah : udah
# ditelpon : telpon
# survey : survey
# tapiini : tapiini
# pelayanan : layan
# sesuai : sesuai
# dilayani : layan
# lam : lam
# fungsinya : fungsi
# buakn : buakn
# mempermudah : mudah
# ganti : ganti
# berkala : kala
# yuk : yuk
# dijebol : jebol
# sharingnya : sharingnya
# siapp : siapp
# terimakasih : terimakasih
# kmren : kmren
# konek : konek
# merah : merah
# terusssss : terusssss
# blm : blm
# brp : brp
# kali : kali
# follow : follow
# till : till
# today : today
# action : action
# pstn : pstn
# nambah : nambah
# menguntungkan : untung
# pasang : pasang
# maksih : maksih
# seamless : seamless
# maksimal : maksimal
# device : device
# pertandingan : tanding
# berkali : kali
# installed : installed
# mola : mola
# tetep : tetep
# trouble : trouble
# gerah : gerah
# parah : parah
# emang : emang
# respon : respon
# minn : minn
# connectin : connectin
# lan : lan
# kumasukkan : masuk
# pelanggan : langgan
# tulisan : tulis
# jaringan : jaring
# tersambung : sambung
# nonton : nonton
# catchplay : catchplay
# iflix : iflix
# sehabis : habis
# akses : akses
# berbayar : bayar
# solusi : solusi
# masuk : masuk
# layanan : layan
# bayarkan : bayar
# teknisi : teknisi
# dibilang : bilang
# kontak : kontak
# pusat : pusat
# kerjasama : kerjasama
# bgelag : bgelag
# butuh : butuh
# kasih : kasih
# perbaikan : baik
# mesti : mesti
# jaga : jaga
# sampe : sampe
# lolos : lolos
# top : top
# cer : cer
# info : info
# bagus : bagus
# mohon : mohon
# telat : telat
# knapa : knapa
# lag : lag
# ora : ora
# entoss : entoss
# jlas : jlas
# internet : internet
# betulkan : betul
# marah : marah
# bermain : main
# ngelag : ngelag
# nampung : nampung
# dosa : dosa
# hallo : hallo
# halooo : halooo
# haloooo : haloooo
# wifinyaaaa : wifinyaaaa
# jelek : jelek
# download : download
# aplikasi : aplikasi
# myindihome : myindihome
# dima : dima
# bgm : bgm
# mengaktifkan : aktif
# terisolir : isolir
# kmrn : kmrn
# byr : byr
# tagihan : tagih
# skrg : skrg
# dibayar : bayar
# bermasalah : masalah
# terlambat : lambat
# indihomenya : indihomenya
# melewati : lewat
# tanggal : tanggal
# ditentukan : tentu
# penjelasannya : jelas
# bermaslah : mas
# penuh : penuh
# connect : connect
# kah : kah
# bayaran : bayar
# lancar : lancar
# jam : jam
# sore : sore
# smpe : smpe
# skr : skr
# indikator : indikator
# nyala : nyala
# trs : trs
# ngadat : ngadat
# kecewa : kecewa
# balas : balas
# router : router
# bertaun : taun
# blum : blum
# uzur : uzur
# rto : rto
# purbalingga : purbalingga
# minmin : minmin
# isolir : isolir
# gangguan : ganggu
# itungannya : itungannya
# bijak : bijak
# penanganan : tangan
# lambat : lambat
# attitide : attitide
# knp : knp
# menetap : tetap
# pembayarannya : bayar
# bertambah : tambah
# pembayaran : bayar
# masang : masang
# susah : susah
# ragu : ragu
# kek : kek
# gini : gin
# websitenya : websitenya
# promo : promo
# marketing : marketing
# mksd : mksd
# marketinga : marketinga
# shopee : shopee
# knpa : knpa
# huft : huft
# manfaatin : manfaatin
# pay : pay
# trus : trus
# dapet : dapet
# diskon : diskon
# berhasil : hasil
# provider : provider
# laporan : lapor
# keluhan : keluh
# progres : progres
# nyata : nyata
# tiket : tiket
# bernasip : bernasip
# seperi : per
# full : full
# lemot : lot
# looooooooodddddiiiiiiing : looooooooodddddiiiiiiing
# terkadang : terkadang
# dipakai : pakai
# tetangga : tetangga
# cilengsi : cilengsi
# belom : bom
# realisasi : realisasi
# orang : orang
# indohome : indohome
# sabar : sabar
# disuruh : suruh
# stb : stb
# los : los
# berwarna : warna
# lapor : lapor
# pengaduan : adu
# petugas : tugas
# pas : pas
# dicoba : coba
# matiin : matiin
# alat : alat
# wlan : wlan
# silahkan : silah
# restart : restart
# kakak : kakak
# menit : menit
# amnesia : amnesia
# mah : mah
# namanya : nama
# yeay : yeay
# cocok : cocok
# telfon : telfon
# lord : lord
# agus : agus
# suka : suka
# delay : delay
# gaada : gaada
# koneksi : koneksi
# beecanda : beecanda
# kau : kau
# bang : bang
# icon : icon
# skrng : skrng
# pindah : pindah
# stabil : stabil
# maju : maju
# jaya : jaya
# telkom : telkom
# indonesia : indonesia
# secure : secure
# waw : waw
# canggih : canggih
# tenang : tenang
# pengamanannya : aman
# akun : akun
# mbps : mbps
# ngtt : ngtt
# aduh : aduh
# indikatornya : indikator
# kerjaan : kerja
# terbengkalai : bengkalai
# berhenti : henti
# berlangganan : langgan
# alamat : alamat
# ditindak : tindak
# lanjuti : lanjut
# mantap : mantap
# postingannya : postingannya
# tiapa : tiapa
# absent : absent
# oke : oke
# tipsnya : tipsnya
# siang : siang
# tlong : tlong
# loading : loading
# drtd : drtd
# lakukan : laku
# langkah : langkah
# diatas : atas
# gabisa : gabisa
# panik : panik
# kerja : kerja
# ngaco : ngaco
# kaga : kaga
# adminya : adminya
# lagggg : lagggg
# parahhhhhhhh : parahhhhhhhh
# maen : maen
# loncat : loncat
# emosi : emosi
# halah : halah
# uda : uda
# tinfak : tinfak
# nunggu : nunggu
# dateng : dateng
# giliran : gilir
# nagih : nagih
# lelet : lelet
# haduhhh : haduhhh
# membayar : bayar
# tgl : tgl
# agustus : agustus
# alfamart : alfamart
# indomaret : indomaret
# takutnya : takut
# nti : nti
# diputus : putus
# klu : klu
# ttp : ttp
# ktnya : ktnya
# rugi : rugi
# kena : kena
# denda : denda
# dibayarkan : bayar
# kamana : kamana
# kantor : kantor
# bantuannya : bantu
# tny : tny
# kirim : kirim
# notif : notif
# stlh : stlh
# customer : customer
# pmbayaran : pmbayaran
# praktis : praktis
# jualan : jual
# add : add
# ribetnya : ribetnya
# ampun : ampun
# muncul : muncul
# kerugian : rugi
# cari : cari
# duitnya : duit
# bener : bener
# terbukti : bukti
# korban : korban
# dirugikan : rugi
# tukat : tukat
# poin : poin
# terimaksih : terimaksih
# cepat : cepat
# tanggap : tanggap
# seru : seru
# pastiberes : pastiberes
# koq : koq
# biaya : biaya
# anjng : anjng
# depositnya : deposit
# rb : rb
# apapun : apa
# sehari : hari
# kendala : kendala
# hilang : hilang
# parahh : parahh
# kota : kota
# bekasi : bekas
# pemasangan : pasang
# jawabannya : jawab
# nihil : nihil
# dirumah : rumah
# alasannya : alas
# tarik : tarik
# {'mininya': 'mini', 'mantep': 'mantep', 'posting': 'posting', 'bermanfaat': 'manfaat', 'cek': 'cek', '': '', 'bayar': 'bayar', 'takut': 'takut', 'data': 'data', 'ilang': 'ilang', 'untung': 'untung', 'mimin': 'mimin', 'indihome': 'indihome', 'ngasih': 'ngasih', 'halo': 'halo', 'miiiin': 'miiiin', 'nais': 'nais', 'inpoh': 'inpoh', 'min': 'min', 'tolong': 'tolong', 'modem': 'modem', 'nokia': 'nokia', 'wl': 'wl', 'gmn': 'gmn', 'banget': 'banget', 'pengguna': 'guna', 'kenal': 'kenal', 'semenjak': 'semenjak', 'informasi': 'informasi', 'membantu': 'bantu', 'makasih': 'makasih', 'hide': 'hide', 'ssid': 'ssid', 'nama': 'nama', 'wifinya': 'wifinya', 'cem': 'cem', 'minnnnn': 'minnnnn', 'rumah': 'rumah', 'semarang': 'semarang', 'demak': 'demak', 'boyolali': 'boyolali', 'pakai': 'pakai', 'sinyal': 'sinyal', 'boosokkkkkk': 'boosokkkkkk', 'udh': 'udh', 'kesel': 'kesel', 'komentar': 'komentar', 'buka': 'buka', 'youtube': 'youtube', 'bufering': 'bufering', 'bufrering': 'bufrering', 'video': 'video', 'refresing': 'refresing', 'game': 'game', 'putus': 'putus', 'jaringannya': 'jaring', 'gimana': 'gimana', 'mahal': 'mahal', 'kualitas': 'kualitas', 'busuk': 'busuk', 'mending': 'mending', 'cabut': 'cabut', 'paket': 'paket', 'telkomsel': 'telkomsel', 'coba': 'coba', 'inet': 'inet', 'error': 'error', 'mulu': 'mulu', 'infonya': 'info', 'wifi': 'wifi', 'ttep': 'ttep', 'account': 'account', 'salah': 'salah', 'lupa': 'lupa', 'password': 'password', 'diganti': 'ganti', 'solusinya': 'solusi', 'gmna': 'gmna', 'kak': 'kak', 'kesal': 'kesal', 'eror': 'eror', 'dri': 'dri', 'pagi': 'pagi', 'lampu': 'lampu', 'internetnya': 'internetnya', 'mati': 'mati', 'malam': 'malam', 'tunggu': 'tunggu', 'kunjung': 'kunjung', 'pon': 'pon', 'hidup': 'hidup', 'kabel': 'kabel', 'menunggu': 'tunggu', 'bosss': 'bosss', 'nice': 'nice', 'aman': 'aman', 'kayanya': 'kaya', 'nanya': 'nanya', 'mendaftar': 'daftar', 'website': 'website', 'udah': 'udah', 'ditelpon': 'telpon', 'survey': 'survey', 'tapiini': 'tapiini', 'pelayanan': 'layan', 'sesuai': 'sesuai', 'dilayani': 'layan', 'lam': 'lam', 'fungsinya': 'fungsi', 'buakn': 'buakn', 'mempermudah': 'mudah', 'ganti': 'ganti', 'berkala': 'kala', 'yuk': 'yuk', 'dijebol': 'jebol', 'sharingnya': 'sharingnya', 'siapp': 'siapp', 'terimakasih': 'terimakasih', 'kmren': 'kmren', 'konek': 'konek', 'merah': 'merah', 'terusssss': 'terusssss', 'blm': 'blm', 'brp': 'brp', 'kali': 'kali', 'follow': 'follow', 'till': 'till', 'today': 'today', 'action': 'action', 'pstn': 'pstn', 'nambah': 'nambah', 'menguntungkan': 'untung', 'pasang': 'pasang', 'maksih': 'maksih', 'seamless': 'seamless', 'maksimal': 'maksimal', 'device': 'device', 'pertandingan': 'tanding', 'berkali': 'kali', 'installed': 'installed', 'mola': 'mola', 'tetep': 'tetep', 'trouble': 'trouble', 'gerah': 'gerah', 'parah': 'parah', 'emang': 'emang', 'respon': 'respon', 'minn': 'minn', 'connectin': 'connectin', 'lan': 'lan', 'kumasukkan': 'masuk', 'pelanggan': 'langgan', 'tulisan': 'tulis', 'jaringan': 'jaring', 'tersambung': 'sambung', 'nonton': 'nonton', 'catchplay': 'catchplay', 'iflix': 'iflix', 'sehabis': 'habis', 'akses': 'akses', 'berbayar': 'bayar', 'solusi': 'solusi', 'masuk': 'masuk', 'layanan': 'layan', 'bayarkan': 'bayar', 'teknisi': 'teknisi', 'dibilang': 'bilang', 'kontak': 'kontak', 'pusat': 'pusat', 'kerjasama': 'kerjasama', 'bgelag': 'bgelag', 'butuh': 'butuh', 'kasih': 'kasih', 'perbaikan': 'baik', 'mesti': 'mesti', 'jaga': 'jaga', 'sampe': 'sampe', 'lolos': 'lolos', 'top': 'top', 'cer': 'cer', 'info': 'info', 'bagus': 'bagus', 'mohon': 'mohon', 'telat': 'telat', 'knapa': 'knapa', 'lag': 'lag', 'ora': 'ora', 'entoss': 'entoss', 'jlas': 'jlas', 'internet': 'internet', 'betulkan': 'betul', 'marah': 'marah', 'bermain': 'main', 'ngelag': 'ngelag', 'nampung': 'nampung', 'dosa': 'dosa', 'hallo': 'hallo', 'halooo': 'halooo', 'haloooo': 'haloooo', 'wifinyaaaa': 'wifinyaaaa', 'jelek': 'jelek', 'download': 'download', 'aplikasi': 'aplikasi', 'myindihome': 'myindihome', 'dima': 'dima', 'bgm': ...
# ------------------------
# Pandas Apply:   0%|          | 0/139 [00:00<?, ?it/s]
#                                                   text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                               cek dm
# 4                                     ko ga bisa bayar
# 6    takut kalo data ilang tuh, untung mimin indiho...
# 9                                            cek dm lg
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan , gilira...
# 145    akhir2 ini jaringan suka hilang sendiri..parahh
# 146  info dong yg kota bekasi, pemasangan baru susa...
# 147  sudah berkali" saya laporan tapi jawabannya se...
# 148  min, pemasangan baru dirumah saya ko susah ben...
#
#                                          cleaning_text  \
# 0              mininya mantep posting bermanfaat terus
# 1                                                 cek
# 4                                           bisa bayar
# 6    takut kalo data ilang tuh untung mimin indihom...
# 9                                                 cek
# ..                                                 ...
# 144  bayar telat sehari udah mati jaringan giliran ...
# 145     akhir  ini jaringan suka hilang sendiri parahh
# 146       info dong kota bekasi pemasangan baru susah
# 147  sudah berkali saya laporan tapi jawabannya sel...
# 148  min pemasangan baru dirumah saya susah bener p...
#
#                                             tokenisasi  \
# 0        [mininya, mantep, posting, bermanfaat, terus]
# 1                                              [cek, ]
# 4                                      [, bisa, bayar]
# 6    [takut, kalo, data, ilang, tuh, untung, mimin,...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, sehari, udah, mati, jaringan, g...
# 145  [akhir, ini, jaringan, suka, hilang, sendiri, ...
# 146  [info, dong, kota, bekasi, pemasangan, baru, s...
# 147  [sudah, berkali, saya, laporan, tapi, jawabann...
# 148  [min, pemasangan, baru, dirumah, saya, susah, ...
#
#                                               stopword  \
# 0               [mininya, mantep, posting, bermanfaat]
# 1                                              [cek, ]
# 4                                            [, bayar]
# 6    [takut, data, ilang, untung, mimin, indihome, ...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, sehari, udah, mati, jaringan, g...
# 145                   [jaringan, suka, hilang, parahh]
# 146          [info, kota, bekasi, pemasangan, susah, ]
# 147     [berkali, laporan, jawabannya, nihil, sabar, ]
# 148  [min, pemasangan, dirumah, susah, bener, kota,...
#
#                                               stemming
# 0                     [mini, mantep, posting, manfaat]
# 1                                              [cek, ]
# 4                                            [, bayar]
# 6    [takut, data, ilang, untung, mimin, indihome, ...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, hari, udah, mati, jaring, gilir...
# 145                     [jaring, suka, hilang, parahh]
# 146               [info, kota, bekas, pasang, susah, ]
# 147               [kali, lapor, jawab, nihil, sabar, ]
# 148  [min, pasang, rumah, susah, bener, kota, bekas...
#
# [139 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                     [mini, mantep, posting, manfaat]
# 1                                              [cek, ]
# 4                                            [, bayar]
# 6    [takut, data, ilang, untung, mimin, indihome, ...
# 9                                              [cek, ]
# ..                                                 ...
# 144  [bayar, telat, hari, udah, mati, jaring, gilir...
# 145                     [jaring, suka, hilang, parahh]
# 146               [info, kota, bekas, pasang, susah, ]
# 147               [kali, lapor, jawab, nihil, sabar, ]
# 148  [min, pasang, rumah, susah, bener, kota, bekas...
#
# [139 rows x 1 columns]

# %%
Final.to_excel('databersih_instagram_indihome_8.xlsx')
