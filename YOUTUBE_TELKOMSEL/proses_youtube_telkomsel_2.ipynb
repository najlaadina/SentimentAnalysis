# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    TERIMAKASIH TELKOMSEL TELAH MEMBUAT SAYA DARAH...
# 1                  WAH SEMENJAK AKU PAKAI TELKOMTOD!!!
# 2    KERENNN..... makin lama makin ancur sinyal tel...
# 3    Kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    Udah siap mati nih telkomsel lagi!! Geram bang...
# ..                                                 ...
# 203                                 Woi perbaikin dong
# 204                                 Woi perbaikin dong
# 205  Telkomsel Kenapa Ga ada Sinyal Emang ada tower...
# 206                                                  .
# 207                                      Asu sinyalnya
#
# [208 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 53

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    TERIMAKASIH TELKOMSEL TELAH MEMBUAT SAYA DARAH...
# 1                  WAH SEMENJAK AKU PAKAI TELKOMTOD!!!
# 2    KERENNN..... makin lama makin ancur sinyal tel...
# 3    Kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    Udah siap mati nih telkomsel lagi!! Geram bang...
# ..                                                 ...
# 176                Buat Emosi Aja Nih Kartu Telkomsel😈
# 178  Telkomsel kenapa kok gak ada sinyal, gangguan ...
# 179  Oi gimana sih anda kenapa sinyal telkomsel sek...
# 206                                                  .
# 207                                      Asu sinyalnya
#
# [111 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                  wah semenjak aku pakai telkomtod!!!
# 2    kerennn..... makin lama makin ancur sinyal tel...
# 3    kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    udah siap mati nih telkomsel lagi!! geram bang...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel😈
# 178  telkomsel kenapa kok gak ada sinyal, gangguan ...
# 179  oi gimana sih anda kenapa sinyal telkomsel sek...
# 206                                                  .
# 207                                      asu sinyalnya
#
# [111 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                  wah semenjak aku pakai telkomtod!!!
# 2    kerennn..... makin lama makin ancur sinyal tel...
# 3    kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    udah siap mati nih telkomsel lagi!! geram bang...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel😈
# 178  telkomsel kenapa kok gak ada sinyal, gangguan ...
# 179  oi gimana sih anda kenapa sinyal telkomsel sek...
# 206                                                  .
# 207                                      asu sinyalnya
#
#                                       cleaning_comment
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                    wah semenjak aku pakai telkomtod
# 2     kerennn makin lama makin ancur sinyal telkomsel
# 3    kecewa bngt wei internet mingguan  gb    ilang...
# 4    udah siap mati nih telkomsel lagi geram banget...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel
# 178  telkomsel kenapa kok gak ada sinyal gangguan a...
# 179   gimana sih anda kenapa sinyal telkomsel sekar...
# 206
# 207                                      asu sinyalnya
#
# [111 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                  wah semenjak aku pakai telkomtod!!!
# 2    kerennn..... makin lama makin ancur sinyal tel...
# 3    kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    udah siap mati nih telkomsel lagi!! geram bang...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel😈
# 178  telkomsel kenapa kok gak ada sinyal, gangguan ...
# 179  oi gimana sih anda kenapa sinyal telkomsel sek...
# 206                                                  .
# 207                                      asu sinyalnya
#
#                                       cleaning_comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                    wah semenjak aku pakai telkomtod
# 2     kerennn makin lama makin ancur sinyal telkomsel
# 3    kecewa bngt wei internet mingguan  gb    ilang...
# 4    udah siap mati nih telkomsel lagi geram banget...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel
# 178  telkomsel kenapa kok gak ada sinyal gangguan a...
# 179   gimana sih anda kenapa sinyal telkomsel sekar...
# 206
# 207                                      asu sinyalnya
#
#                                             tokenisasi
# 0    [terimakasih, telkomsel, telah, membuat, saya,...
# 1             [wah, semenjak, aku, pakai, telkomtod, ]
# 2    [kerennn, makin, lama, makin, ancur, sinyal, t...
# 3    [kecewa, bngt, wei, internet, mingguan, gb, il...
# 4    [udah, siap, mati, nih, telkomsel, lagi, geram...
# ..                                                 ...
# 176        [buat, emosi, aja, nih, kartu, telkomsel, ]
# 178  [telkomsel, kenapa, kok, gak, ada, sinyal, gan...
# 179  [, gimana, sih, anda, kenapa, sinyal, telkomse...
# 206                                               [, ]
# 207                                   [asu, sinyalnya]
#
# [111 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                  wah semenjak aku pakai telkomtod!!!
# 2    kerennn..... makin lama makin ancur sinyal tel...
# 3    kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    udah siap mati nih telkomsel lagi!! geram bang...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel😈
# 178  telkomsel kenapa kok gak ada sinyal, gangguan ...
# 179  oi gimana sih anda kenapa sinyal telkomsel sek...
# 206                                                  .
# 207                                      asu sinyalnya
#
#                                       cleaning_comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                    wah semenjak aku pakai telkomtod
# 2     kerennn makin lama makin ancur sinyal telkomsel
# 3    kecewa bngt wei internet mingguan  gb    ilang...
# 4    udah siap mati nih telkomsel lagi geram banget...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel
# 178  telkomsel kenapa kok gak ada sinyal gangguan a...
# 179   gimana sih anda kenapa sinyal telkomsel sekar...
# 206
# 207                                      asu sinyalnya
#
#                                             tokenisasi  \
# 0    [terimakasih, telkomsel, telah, membuat, saya,...
# 1             [wah, semenjak, aku, pakai, telkomtod, ]
# 2    [kerennn, makin, lama, makin, ancur, sinyal, t...
# 3    [kecewa, bngt, wei, internet, mingguan, gb, il...
# 4    [udah, siap, mati, nih, telkomsel, lagi, geram...
# ..                                                 ...
# 176        [buat, emosi, aja, nih, kartu, telkomsel, ]
# 178  [telkomsel, kenapa, kok, gak, ada, sinyal, gan...
# 179  [, gimana, sih, anda, kenapa, sinyal, telkomse...
# 206                                               [, ]
# 207                                   [asu, sinyalnya]
#
#                                               stopword
# 0    [terimakasih, telkomsel, darah, semoga, cepat,...
# 1                       [semenjak, pakai, telkomtod, ]
# 2                [kerennn, ancur, sinyal, telkomsel, ]
# 3    [kecewa, bngt, wei, internet, mingguan, gb, il...
# 4               [udah, mati, telkomsel, geram, banget]
# ..                                                 ...
# 176                        [emosi, kartu, telkomsel, ]
# 178               [telkomsel, sinyal, gangguan, gmana]
# 179  [, gimana, sinyal, telkomsel, bener, ajh, urus...
# 206                                               [, ]
# 207                                        [sinyalnya]
#
# [111 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 326
# ------------------------
# terimakasih : terimakasih
# telkomsel : telkomsel
# darah : darah
# semoga : moga
# cepat : cepat
# bangkrut : bangkrut
#  :
# semenjak : semenjak
# pakai : pakai
# telkomtod : telkomtod
# kerennn : kerennn
# ancur : ancur
# sinyal : sinyal
# kecewa : kecewa
# bngt : bngt
# wei : wei
# internet : internet
# mingguan : minggu
# gb : gb
# ilangin : ilangin
# pdahal : pdahal
# udh : udh
# nyaman : nyaman
# paketan : paket
# balikin : balikin
# daftar : daftar
# paketnya : paket
# udah : udah
# mati : mati
# geram : geram
# banget : banget
# diupload : diupload
# cinta : cinta
# dimas : mas
# penasaran : penasaran
# lihat : lihat
# anneth : anneth
# merugikan : rugi
# orang : orang
# simak : simak
# nyimak : nyimak
# jaringan : jaring
# dikit : dikit
# ilang : ilang
# digunain : digunain
# keluhan : keluh
# tanggepin : tanggepin
# didiemin : didiemin
# shitttttt : shitttttt
# film : film
# pulang : pulang
# ganteng : ganteng
# lanjutin : lanjutin
# season : season
# oke : oke
# dibilangin : dibilangin
# lelet : lelet
# awas : awas
# tolong : tolong
# bangat : bangat
# ngelex : ngelex
# kayak : kayak
# otak : otak
# banting : banting
# gara : gara
# nyari : nyari
# pekerja : kerja
# bener : bener
# gimana : gimana
# menjijikan : jijik
# perbaiki : baik
# jaringannya : jaring
# promosi : promosi
# lag : lag
# bang : bang
# astaghfirullah : astaghfirullah
# ganti : ganti
# apn : apn
# main : main
# game : game
# solusi : solusi
# gasssss : gasssss
# salam : salam
# sehat : sehat
# sukses : sukses
# unlimited : unlimited
# kuota : kuota
# youtube : youtube
# tpi : tpi
# parah : parah
# check : check
# kali : kali
# iklannya : iklan
# spanduk : spanduk
# dimna : dimna
# kuat : kuat
# bgus : bgus
# dri : dri
# seleksilah : seleksi
# org : org
# staff : staff
# masukkan : masuk
# nth : nth
# lulusan : lulus
# kerja : kerja
# dlm : dlm
# telkomselnya : telkomselnya
# apanya : apa
# bagus : bagus
# bumn : bumn
# pelayanan : layan
# tolol : tolol
# kontent : kontent
# channel : channel
# youtobe : youtobe
# online : online
# bisanya : bisa
# jln : jln
# perdana : perdana
# optik : optik
# ngelaggg : ngelaggg
# wkwkw : wkwkw
# sekrang : sekrang
# ngelag : ngelag
# ayo : ayo
# ramaikan : ramai
# maaf : maaf
# leg : leg
# biasnya : bias
# baca : baca
# hapus : hapus
# malu : malu
# maluin : maluin
# cocok : cocok
# gamer : gamer
# report : report
# ajaaaaa : ajaaaaa
# tanggu : tanggu
# ribu : ribu
# gue : gue
# dapet : dapet
# kau : kau
# konten : konten
# nungguin : nungguin
# dislike : dislike
# benerin : benerin
# bayar : bayar
# pajak : pajak
# noh : noh
# telkomsell : telkomsell
# ngeleg : ngeleg
# mulu : mulu
# setres : tres
# buka : buka
# snack : snack
# vidio : vidio
# woyy : woyy
# the : the
# dog : dog
# astaga : astaga
# coook : coook
# kartu : kartu
# emosi : emosi
# lebay : lebay
# unlimitid : unlimitid
# gitu : gitu
# lemut : lut
# anjengg : anjengg
# beli : beli
# mahal : mahal
# jls : jls
# telkom : telkom
# baikin : baikin
# anjeeeeeeng : anjeeeeeeng
# sultan : sultan
# bos : bos
# woy : woy
# napa : napa
# isi : isi
# ngeod : ngeod
# minimal : minimal
# sampe : sampe
# abis : abis
# lebaran : lebaran
# jalan : jalan
# kaya : kaya
# anjing : anjing
# emg : emg
# eror : eror
# paket : paket
# proses : proses
# bangstt : bangstt
# gme : gme
# persulit : sulit
# kek : kek
# masuk : masuk
# esprot : esprot
# betulin : betulin
# woi : woi
# down : down
# iklan : iklan
# ngentiit : ngentiit
# darurat : darurat
# knp : knp
# cek : cek
# pulsa : pulsa
# diproses : proses
# max : max
# recommect : recommect
# rilis : rilis
# mending : mending
# block : block
# anjingnya : anjing
# min : min
# riau : riau
# ngk : ngk
# haram : haram
# inih : inih
# ajig : ajig
# sono : sono
# tanggung : tanggung
# halo : halo
# super : super
# keturunan : turun
# kafir : kafir
# tross : tross
# telaso : telaso
# nge : nge
# daerah : daerah
# tegal : tegal
# kemaren : kemaren
# malam : malam
# lancar : lancar
# kesini : kesini
# delete : delete
# mimin : mimin
# jan : jan
# pikirin : pikirin
# ato : ato
# kasih : kasih
# server : server
# anjenk : anjenk
# kak : kak
# koneksinya : koneksi
# normal : normal
# geme : geme
# bantuannya : bantu
# oiii : oiii
# wifi : wifi
# ngelek : ngelek
# ngento : ngento
# admin : admin
# buamg : buamg
# duit : duit
# macem : macem
# gini : gin
# beresin : resin
# muluu : muluu
# taii : taii
# slike : slike
# asli : asli
# ganggu : ganggu
# meeting : meeting
# serba : serba
# zoom : zoom
# karir : karir
# auto : auto
# hancur : hancur
# kirain : kirain
# harga : harga
# dimurahin : dimurahin
# harap : harap
# diperhatikan : perhati
# berbalik : balik
# operator : operator
# hay : hay
# buruk : buruk
# hargai : harga
# bertahan : tahan
# bekasi : bekas
# cikarang : cikarang
# ngerasa : ngerasa
# pas : pas
# afk : afk
# trus : trus
# mikir : mikir
# rugi : rugi
# kebanyakan : banyak
# sms : sms
# ngadat : ngadat
# neraka : neraka
# ngebut : ngebut
# ber : ber
# kembang : kembang
# maki : maki
# makh : makh
# gga : gga
# bales : bales
# llu : llu
# komen : komen
# maluiin : maluiin
# siyal : siyal
# tok : tok
# ngawur : ngawur
# pulsaku : pulsa
# hilang : hilang
# data : data
# sisa : sisa
# mb : mb
# simcard : simcard
# buang : buang
# gangguan : ganggu
# gmana : gmana
# ajh : ajh
# urus : urus
# donk : donk
# untungnya : untung
# gila : gila
# stabil : stabil
# kerepotan : kerepot
# klw : klw
# butuh : butuh
# rumah : rumah
# nyesel : nyesel
# krtu : krtu
# sinyalnya : sinyal
# {'terimakasih': 'terimakasih', 'telkomsel': 'telkomsel', 'darah': 'darah', 'semoga': 'moga', 'cepat': 'cepat', 'bangkrut': 'bangkrut', '': '', 'semenjak': 'semenjak', 'pakai': 'pakai', 'telkomtod': 'telkomtod', 'kerennn': 'kerennn', 'ancur': 'ancur', 'sinyal': 'sinyal', 'kecewa': 'kecewa', 'bngt': 'bngt', 'wei': 'wei', 'internet': 'internet', 'mingguan': 'minggu', 'gb': 'gb', 'ilangin': 'ilangin', 'pdahal': 'pdahal', 'udh': 'udh', 'nyaman': 'nyaman', 'paketan': 'paket', 'balikin': 'balikin', 'daftar': 'daftar', 'paketnya': 'paket', 'udah': 'udah', 'mati': 'mati', 'geram': 'geram', 'banget': 'banget', 'diupload': 'diupload', 'cinta': 'cinta', 'dimas': 'mas', 'penasaran': 'penasaran', 'lihat': 'lihat', 'anneth': 'anneth', 'merugikan': 'rugi', 'orang': 'orang', 'simak': 'simak', 'nyimak': 'nyimak', 'jaringan': 'jaring', 'dikit': 'dikit', 'ilang': 'ilang', 'digunain': 'digunain', 'keluhan': 'keluh', 'tanggepin': 'tanggepin', 'didiemin': 'didiemin', 'shitttttt': 'shitttttt', 'film': 'film', 'pulang': 'pulang', 'ganteng': 'ganteng', 'lanjutin': 'lanjutin', 'season': 'season', 'oke': 'oke', 'dibilangin': 'dibilangin', 'lelet': 'lelet', 'awas': 'awas', 'tolong': 'tolong', 'bangat': 'bangat', 'ngelex': 'ngelex', 'kayak': 'kayak', 'otak': 'otak', 'banting': 'banting', 'gara': 'gara', 'nyari': 'nyari', 'pekerja': 'kerja', 'bener': 'bener', 'gimana': 'gimana', 'menjijikan': 'jijik', 'perbaiki': 'baik', 'jaringannya': 'jaring', 'promosi': 'promosi', 'lag': 'lag', 'bang': 'bang', 'astaghfirullah': 'astaghfirullah', 'ganti': 'ganti', 'apn': 'apn', 'main': 'main', 'game': 'game', 'solusi': 'solusi', 'gasssss': 'gasssss', 'salam': 'salam', 'sehat': 'sehat', 'sukses': 'sukses', 'unlimited': 'unlimited', 'kuota': 'kuota', 'youtube': 'youtube', 'tpi': 'tpi', 'parah': 'parah', 'check': 'check', 'kali': 'kali', 'iklannya': 'iklan', 'spanduk': 'spanduk', 'dimna': 'dimna', 'kuat': 'kuat', 'bgus': 'bgus', 'dri': 'dri', 'seleksilah': 'seleksi', 'org': 'org', 'staff': 'staff', 'masukkan': 'masuk', 'nth': 'nth', 'lulusan': 'lulus', 'kerja': 'kerja', 'dlm': 'dlm', 'telkomselnya': 'telkomselnya', 'apanya': 'apa', 'bagus': 'bagus', 'bumn': 'bumn', 'pelayanan': 'layan', 'tolol': 'tolol', 'kontent': 'kontent', 'channel': 'channel', 'youtobe': 'youtobe', 'online': 'online', 'bisanya': 'bisa', 'jln': 'jln', 'perdana': 'perdana', 'optik': 'optik', 'ngelaggg': 'ngelaggg', 'wkwkw': 'wkwkw', 'sekrang': 'sekrang', 'ngelag': 'ngelag', 'ayo': 'ayo', 'ramaikan': 'ramai', 'maaf': 'maaf', 'leg': 'leg', 'biasnya': 'bias', 'baca': 'baca', 'hapus': 'hapus', 'malu': 'malu', 'maluin': 'maluin', 'cocok': 'cocok', 'gamer': 'gamer', 'report': 'report', 'ajaaaaa': 'ajaaaaa', 'tanggu': 'tanggu', 'ribu': 'ribu', 'gue': 'gue', 'dapet': 'dapet', 'kau': 'kau', 'konten': 'konten', 'nungguin': 'nungguin', 'dislike': 'dislike', 'benerin': 'benerin', 'bayar': 'bayar', 'pajak': 'pajak', 'noh': 'noh', 'telkomsell': 'telkomsell', 'ngeleg': 'ngeleg', 'mulu': 'mulu', 'setres': 'tres', 'buka': 'buka', 'snack': 'snack', 'vidio': 'vidio', 'woyy': 'woyy', 'the': 'the', 'dog': 'dog', 'astaga': 'astaga', 'coook': 'coook', 'kartu': 'kartu', 'emosi': 'emosi', 'lebay': 'lebay', 'unlimitid': 'unlimitid', 'gitu': 'gitu', 'lemut': 'lut', 'anjengg': 'anjengg', 'beli': 'beli', 'mahal': 'mahal', 'jls': 'jls', 'telkom': 'telkom', 'baikin': 'baikin', 'anjeeeeeeng': 'anjeeeeeeng', 'sultan': 'sultan', 'bos': 'bos', 'woy': 'woy', 'napa': 'napa', 'isi': 'isi', 'ngeod': 'ngeod', 'minimal': 'minimal', 'sampe': 'sampe', 'abis': 'abis', 'lebaran': 'lebaran', 'jalan': 'jalan', 'kaya': 'kaya', 'anjing': 'anjing', 'emg': 'emg', 'eror': 'eror', 'paket': 'paket', 'proses': 'proses', 'bangstt': 'bangstt', 'gme': 'gme', 'persulit': 'sulit', 'kek': 'kek', 'masuk': 'masuk', 'esprot': 'esprot', 'betulin': 'betulin', 'woi': 'woi', 'down': 'down', 'iklan': 'iklan', 'ngentiit': 'ngentiit', 'darurat': 'darurat', 'knp': 'knp', 'cek': 'cek', 'pulsa': 'pulsa', 'diproses': 'proses', 'max': 'max', 'recommect': 'recommect', 'rilis': 'ril ...
# ------------------------
# Pandas Apply:   0%|          | 0/111 [00:00<?, ?it/s]
#                                                comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                  wah semenjak aku pakai telkomtod!!!
# 2    kerennn..... makin lama makin ancur sinyal tel...
# 3    kecewa bngt wei internet mingguan 15gb 50k di ...
# 4    udah siap mati nih telkomsel lagi!! geram bang...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel😈
# 178  telkomsel kenapa kok gak ada sinyal, gangguan ...
# 179  oi gimana sih anda kenapa sinyal telkomsel sek...
# 206                                                  .
# 207                                      asu sinyalnya
#
#                                       cleaning_comment  \
# 0    terimakasih telkomsel telah membuat saya darah...
# 1                    wah semenjak aku pakai telkomtod
# 2     kerennn makin lama makin ancur sinyal telkomsel
# 3    kecewa bngt wei internet mingguan  gb    ilang...
# 4    udah siap mati nih telkomsel lagi geram banget...
# ..                                                 ...
# 176                buat emosi aja nih kartu telkomsel
# 178  telkomsel kenapa kok gak ada sinyal gangguan a...
# 179   gimana sih anda kenapa sinyal telkomsel sekar...
# 206
# 207                                      asu sinyalnya
#
#                                             tokenisasi  \
# 0    [terimakasih, telkomsel, telah, membuat, saya,...
# 1             [wah, semenjak, aku, pakai, telkomtod, ]
# 2    [kerennn, makin, lama, makin, ancur, sinyal, t...
# 3    [kecewa, bngt, wei, internet, mingguan, gb, il...
# 4    [udah, siap, mati, nih, telkomsel, lagi, geram...
# ..                                                 ...
# 176        [buat, emosi, aja, nih, kartu, telkomsel, ]
# 178  [telkomsel, kenapa, kok, gak, ada, sinyal, gan...
# 179  [, gimana, sih, anda, kenapa, sinyal, telkomse...
# 206                                               [, ]
# 207                                   [asu, sinyalnya]
#
#                                               stopword  \
# 0    [terimakasih, telkomsel, darah, semoga, cepat,...
# 1                       [semenjak, pakai, telkomtod, ]
# 2                [kerennn, ancur, sinyal, telkomsel, ]
# 3    [kecewa, bngt, wei, internet, mingguan, gb, il...
# 4               [udah, mati, telkomsel, geram, banget]
# ..                                                 ...
# 176                        [emosi, kartu, telkomsel, ]
# 178               [telkomsel, sinyal, gangguan, gmana]
# 179  [, gimana, sinyal, telkomsel, bener, ajh, urus...
# 206                                               [, ]
# 207                                        [sinyalnya]
#
#                                               stemming
# 0    [terimakasih, telkomsel, darah, moga, cepat, b...
# 1                       [semenjak, pakai, telkomtod, ]
# 2                [kerennn, ancur, sinyal, telkomsel, ]
# 3    [kecewa, bngt, wei, internet, minggu, gb, ilan...
# 4               [udah, mati, telkomsel, geram, banget]
# ..                                                 ...
# 176                        [emosi, kartu, telkomsel, ]
# 178                 [telkomsel, sinyal, ganggu, gmana]
# 179  [, gimana, sinyal, telkomsel, bener, ajh, urus...
# 206                                               [, ]
# 207                                           [sinyal]
#
# [111 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [terimakasih, telkomsel, darah, moga, cepat, b...
# 1                       [semenjak, pakai, telkomtod, ]
# 2                [kerennn, ancur, sinyal, telkomsel, ]
# 3    [kecewa, bngt, wei, internet, minggu, gb, ilan...
# 4               [udah, mati, telkomsel, geram, banget]
# ..                                                 ...
# 176                        [emosi, kartu, telkomsel, ]
# 178                 [telkomsel, sinyal, ganggu, gmana]
# 179  [, gimana, sinyal, telkomsel, bener, ajh, urus...
# 206                                               [, ]
# 207                                           [sinyal]
#
# [111 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_2.xlsx')
