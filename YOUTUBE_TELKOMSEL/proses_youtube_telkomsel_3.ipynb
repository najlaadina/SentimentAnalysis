# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    Tolong segera di perbaiki, sekarang zaman nya ...
# 3                                Telkomsel is the best
# 4                         Hbd MyTelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         H mulu ajg
# 140  Dah gak ke tolong lagi nih jaringan mending pi...
# 141  Wahai provider,,tolong buat vidio ama thumnail...
# 142       Kita tidak butuh promo kita butuh nya sinyal
# 143                        Ayo kawan dislike Telkomsel
#
# [144 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 34

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    Tolong segera di perbaiki, sekarang zaman nya ...
# 3                                Telkomsel is the best
# 4                         Hbd MyTelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         H mulu ajg
# 140  Dah gak ke tolong lagi nih jaringan mending pi...
# 141  Wahai provider,,tolong buat vidio ama thumnail...
# 142       Kita tidak butuh promo kita butuh nya sinyal
# 143                        Ayo kawan dislike Telkomsel
#
# [76 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    tolong segera di perbaiki, sekarang zaman nya ...
# 3                                telkomsel is the best
# 4                         hbd mytelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         h mulu ajg
# 140  dah gak ke tolong lagi nih jaringan mending pi...
# 141  wahai provider,,tolong buat vidio ama thumnail...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
# [76 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    tolong segera di perbaiki, sekarang zaman nya ...
# 3                                telkomsel is the best
# 4                         hbd mytelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         h mulu ajg
# 140  dah gak ke tolong lagi nih jaringan mending pi...
# 141  wahai provider,,tolong buat vidio ama thumnail...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                       cleaning_comment
# 0    mogah makin maju dan berkembang terus meningka...
# 1
# 2    tolong segera perbaiki sekarang zaman nya zoom...
# 3                                   telkomsel the best
# 4                            hbd mytelkomsel yang  thn
# ..                                                 ...
# 139                                           mulu ajg
# 140  dah gak tolong lagi nih jaringan mending pinda...
# 141  wahai provider tolong buat vidio ama thumnail ...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
# [76 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    tolong segera di perbaiki, sekarang zaman nya ...
# 3                                telkomsel is the best
# 4                         hbd mytelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         h mulu ajg
# 140  dah gak ke tolong lagi nih jaringan mending pi...
# 141  wahai provider,,tolong buat vidio ama thumnail...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                       cleaning_comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1
# 2    tolong segera perbaiki sekarang zaman nya zoom...
# 3                                   telkomsel the best
# 4                            hbd mytelkomsel yang  thn
# ..                                                 ...
# 139                                           mulu ajg
# 140  dah gak tolong lagi nih jaringan mending pinda...
# 141  wahai provider tolong buat vidio ama thumnail ...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                             tokenisasi
# 0    [mogah, makin, maju, dan, berkembang, terus, m...
# 1                                                 [, ]
# 2    [tolong, segera, perbaiki, sekarang, zaman, ny...
# 3                               [telkomsel, the, best]
# 4                        [hbd, mytelkomsel, yang, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [dah, gak, tolong, lagi, nih, jaringan, mendin...
# 141  [wahai, provider, tolong, buat, vidio, ama, th...
# 142  [kita, tidak, butuh, promo, kita, butuh, nya, ...
# 143                   [ayo, kawan, dislike, telkomsel]
#
# [76 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    tolong segera di perbaiki, sekarang zaman nya ...
# 3                                telkomsel is the best
# 4                         hbd mytelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         h mulu ajg
# 140  dah gak ke tolong lagi nih jaringan mending pi...
# 141  wahai provider,,tolong buat vidio ama thumnail...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                       cleaning_comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1
# 2    tolong segera perbaiki sekarang zaman nya zoom...
# 3                                   telkomsel the best
# 4                            hbd mytelkomsel yang  thn
# ..                                                 ...
# 139                                           mulu ajg
# 140  dah gak tolong lagi nih jaringan mending pinda...
# 141  wahai provider tolong buat vidio ama thumnail ...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                             tokenisasi  \
# 0    [mogah, makin, maju, dan, berkembang, terus, m...
# 1                                                 [, ]
# 2    [tolong, segera, perbaiki, sekarang, zaman, ny...
# 3                               [telkomsel, the, best]
# 4                        [hbd, mytelkomsel, yang, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [dah, gak, tolong, lagi, nih, jaringan, mendin...
# 141  [wahai, provider, tolong, buat, vidio, ama, th...
# 142  [kita, tidak, butuh, promo, kita, butuh, nya, ...
# 143                   [ayo, kawan, dislike, telkomsel]
#
#                                               stopword
# 0      [mogah, maju, berkembang, meningkat, telkomsel]
# 1                                                 [, ]
# 2    [tolong, perbaiki, zaman, zoom, terkendala, si...
# 3                               [telkomsel, the, best]
# 4                              [hbd, mytelkomsel, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [tolong, jaringan, mending, pindah, dri, pda, ...
# 141  [provider, tolong, vidio, ama, thumnail, bener...
# 142                      [butuh, promo, butuh, sinyal]
# 143                   [ayo, kawan, dislike, telkomsel]
#
# [76 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 233
# ------------------------
# mogah : mogah
# maju : maju
# berkembang : kembang
# meningkat : tingkat
# telkomsel : telkomsel
#  :
# tolong : tolong
# perbaiki : baik
# zaman : zaman
# zoom : zoom
# terkendala : kendala
# sinyal : sinyal
# buruk : buruk
# the : the
# best : best
# hbd : hbd
# mytelkomsel : mytelkomsel
# thn : thn
# undian : undi
# poin : poin
# beneran : beneran
# mikirin : mikirin
# duit : duit
# sampe : sampe
# kgk : kgk
# benerin : benerin
# cepetan : cepetan
# beli : beli
# paket : paket
# jaringanya : jaringanya
# pengguna : guna
# menderita : derita
# memakai : pakai
# jaringan : jaring
# sperti : sperti
# dlu : dlu
# jaringannya : jaring
# parah : parah
# gue : gue
# sumpahin : sumpahin
# bangkrut : bangkrut
# perusahaan : usaha
# telkomsellll : telkomsellll
# admin : admin
# channel : channel
# liat : liat
# video : video
# dislike : dislike
# wkwkw : wkwkw
# susah : susah
# maaukin : maaukin
# voucher : voucher
# sistem : sistem
# sibuk : sibuk
# mulu : mulu
# kebanyakan : banyak
# promo : promo
# doang : doang
# perhatiin : perhatiin
# telkom : telkom
# bet : bet
# bawa : bawa
# main : main
# game : game
# ngelag : ngelag
# hilang : hilang
# gajelas : gajelas
# jaringn : jaringn
# terparah : parah
# kecewa : kecewa
# please : please
# mohon : mohon
# banget : banget
# perbaikinnnnnn : perbaikinnnnnn
# siwa : siwa
# artis : artis
# mendingan : mending
# duitnya : duit
# perbanyak : banyak
# tawer : tawer
# keniksinya : keniksinya
# lancar : lancar
# castamernya : castamernya
# komplain : komplain
# kartu : kartu
# kerenkah : keren
# namanya : nama
# kesal : kesal
# gua : gua
# ngepush : ngepush
# afk : afk
# gara : gara
# apke : apke
# mengecewakan : kecewa
# ancur : ancur
# mantap : mantap
# parahhh : parahhh
# darah : darah
# kmrn : kmrn
# pesen : sen
# barang : barang
# online : online
# ilang : ilang
# barangnya : barang
# dabel : dabel
# tekor : tekor
# spa : spa
# nanggung : nanggung
# ruginya : rugi
# secepatnya : cepat
# nge : nge
# kaga : kaga
# stabil : stabil
# make : make
# laku : laku
# mampus : mampus
# cok : cok
# ajg : ajg
# selalunya : selalu
# tetep : tetep
# sumpah : sumpah
# min : min
# leg : leg
# dibetulin : dibetulin
# woi : woi
# pas : pas
# kuota : kuota
# kemendikbud : kemendikbud
# masuk : masuk
# seenak : enak
# leletin : leletin
# wifi : wifi
# temen : temen
# mudah : mudah
# mudahan : mudah
# cepat : cepat
# lag : lag
# tanggapi : tanggap
# njing : njing
# diliat : liat
# woy : woy
# sinyalnya : sinyal
# noh : noh
# udah : udah
# kayak : kayak
# lembek : lembek
# nyesel : nyesel
# jancok : jancok
# ber : ber
# jam : jam
# aneh : aneh
# mainin : mainin
# banting : banting
# buka : buka
# mey : mey
# ajh : ajh
# haduh : haduh
# gimana : gimana
# pusiiiiing : pusiiiiing
# woiiii : woiiii
# kurangin : rangin
# harga : harga
# kouta : kouta
# you : you
# tube : tube
# buferrr : buferrr
# norak : norak
# terbangsad : terbangsad
# tukang : tukang
# dislaik : dislaik
# hadir : hadir
# bangsad : bangsad
# kepake : kepake
# knpa : knpa
# nomor : nomor
# layanan : layan
# mati : mati
# kah : kah
# nomer : nomer
# ganguan : ganguan
# eror : eror
# ngeleg : ngeleg
# anjg : anjg
# asuuu : asuuu
# komen : komen
# masukin : masukin
# baguss : baguss
# iklan : iklan
# bagus : bagus
# dibelipaketnya : dibelipaketnya
# filmnya : film
# scaaaaaaaam : scaaaaaaaam
# justice : justice
# league : league
# more : more
# like : like
# paketnya : paket
# cari : cari
# film : film
# ketemu : ketemu
# alias : alias
# ganti : ganti
# moto : moto
# perbaikin : perbaikin
# sedot : sedot
# pulsa : pulsa
# gokil : gokil
# next : next
# ter : ter
# org : org
# stress : stress
# ayo : ayo
# tembuskan : tembus
# diam : diam
# telkomtot : telkomtot
# jelak : jelak
# emosi : emosi
# down : down
# orang : orang
# daun : daun
# mending : mending
# pindah : pindah
# dri : dri
# pda : pda
# ntar : ntar
# provider : provider
# vidio : vidio
# ama : ama
# thumnail : thumnail
# bener : bener
# sesuai : sesuai
# butuh : butuh
# kawan : kawan
# {'mogah': 'mogah', 'maju': 'maju', 'berkembang': 'kembang', 'meningkat': 'tingkat', 'telkomsel': 'telkomsel', '': '', 'tolong': 'tolong', 'perbaiki': 'baik', 'zaman': 'zaman', 'zoom': 'zoom', 'terkendala': 'kendala', 'sinyal': 'sinyal', 'buruk': 'buruk', 'the': 'the', 'best': 'best', 'hbd': 'hbd', 'mytelkomsel': 'mytelkomsel', 'thn': 'thn', 'undian': 'undi', 'poin': 'poin', 'beneran': 'beneran', 'mikirin': 'mikirin', 'duit': 'duit', 'sampe': 'sampe', 'kgk': 'kgk', 'benerin': 'benerin', 'cepetan': 'cepetan', 'beli': 'beli', 'paket': 'paket', 'jaringanya': 'jaringanya', 'pengguna': 'guna', 'menderita': 'derita', 'memakai': 'pakai', 'jaringan': 'jaring', 'sperti': 'sperti', 'dlu': 'dlu', 'jaringannya': 'jaring', 'parah': 'parah', 'gue': 'gue', 'sumpahin': 'sumpahin', 'bangkrut': 'bangkrut', 'perusahaan': 'usaha', 'telkomsellll': 'telkomsellll', 'admin': 'admin', 'channel': 'channel', 'liat': 'liat', 'video': 'video', 'dislike': 'dislike', 'wkwkw': 'wkwkw', 'susah': 'susah', 'maaukin': 'maaukin', 'voucher': 'voucher', 'sistem': 'sistem', 'sibuk': 'sibuk', 'mulu': 'mulu', 'kebanyakan': 'banyak', 'promo': 'promo', 'doang': 'doang', 'perhatiin': 'perhatiin', 'telkom': 'telkom', 'bet': 'bet', 'bawa': 'bawa', 'main': 'main', 'game': 'game', 'ngelag': 'ngelag', 'hilang': 'hilang', 'gajelas': 'gajelas', 'jaringn': 'jaringn', 'terparah': 'parah', 'kecewa': 'kecewa', 'please': 'please', 'mohon': 'mohon', 'banget': 'banget', 'perbaikinnnnnn': 'perbaikinnnnnn', 'siwa': 'siwa', 'artis': 'artis', 'mendingan': 'mending', 'duitnya': 'duit', 'perbanyak': 'banyak', 'tawer': 'tawer', 'keniksinya': 'keniksinya', 'lancar': 'lancar', 'castamernya': 'castamernya', 'komplain': 'komplain', 'kartu': 'kartu', 'kerenkah': 'keren', 'namanya': 'nama', 'kesal': 'kesal', 'gua': 'gua', 'ngepush': 'ngepush', 'afk': 'afk', 'gara': 'gara', 'apke': 'apke', 'mengecewakan': 'kecewa', 'ancur': 'ancur', 'mantap': 'mantap', 'parahhh': 'parahhh', 'darah': 'darah', 'kmrn': 'kmrn', 'pesen': 'sen', 'barang': 'barang', 'online': 'online', 'ilang': 'ilang', 'barangnya': 'barang', 'dabel': 'dabel', 'tekor': 'tekor', 'spa': 'spa', 'nanggung': 'nanggung', 'ruginya': 'rugi', 'secepatnya': 'cepat', 'nge': 'nge', 'kaga': 'kaga', 'stabil': 'stabil', 'make': 'make', 'laku': 'laku', 'mampus': 'mampus', 'cok': 'cok', 'ajg': 'ajg', 'selalunya': 'selalu', 'tetep': 'tetep', 'sumpah': 'sumpah', 'min': 'min', 'leg': 'leg', 'dibetulin': 'dibetulin', 'woi': 'woi', 'pas': 'pas', 'kuota': 'kuota', 'kemendikbud': 'kemendikbud', 'masuk': 'masuk', 'seenak': 'enak', 'leletin': 'leletin', 'wifi': 'wifi', 'temen': 'temen', 'mudah': 'mudah', 'mudahan': 'mudah', 'cepat': 'cepat', 'lag': 'lag', 'tanggapi': 'tanggap', 'njing': 'njing', 'diliat': 'liat', 'woy': 'woy', 'sinyalnya': 'sinyal', 'noh': 'noh', 'udah': 'udah', 'kayak': 'kayak', 'lembek': 'lembek', 'nyesel': 'nyesel', 'jancok': 'jancok', 'ber': 'ber', 'jam': 'jam', 'aneh': 'aneh', 'mainin': 'mainin', 'banting': 'banting', 'buka': 'buka', 'mey': 'mey', 'ajh': 'ajh', 'haduh': 'haduh', 'gimana': 'gimana', 'pusiiiiing': 'pusiiiiing', 'woiiii': 'woiiii', 'kurangin': 'rangin', 'harga': 'harga', 'kouta': 'kouta', 'you': 'you', 'tube': 'tube', 'buferrr': 'buferrr', 'norak': 'norak', 'terbangsad': 'terbangsad', 'tukang': 'tukang', 'dislaik': 'dislaik', 'hadir': 'hadir', 'bangsad': 'bangsad', 'kepake': 'kepake', 'knpa': 'knpa', 'nomor': 'nomor', 'layanan': 'layan', 'mati': 'mati', 'kah': 'kah', 'nomer': 'nomer', 'ganguan': 'ganguan', 'eror': 'eror', 'ngeleg': 'ngeleg', 'anjg': 'anjg', 'asuuu': 'asuuu', 'komen': 'komen', 'masukin': 'masukin', 'baguss': 'baguss', 'iklan': 'iklan', 'bagus': 'bagus', 'dibelipaketnya': 'dibelipaketnya', 'filmnya': 'film', 'scaaaaaaaam': 'scaaaaaaaam', 'justice': 'justice', 'league': 'league', 'more': 'more', 'like': 'like', 'paketnya': 'paket', 'cari': 'cari', 'film': 'film', 'ketemu': 'ketemu', 'alias': 'alias', 'ganti': 'ganti', 'moto': 'moto', 'perbaikin': 'perbaikin', 'sedot': 'sedot', 'pulsa': 'pulsa', 'gokil': 'gokil', 'ne ...
# ------------------------
# Pandas Apply:   0%|          | 0/76 [00:00<?, ?it/s]
#                                                comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1                                                    💚
# 2    tolong segera di perbaiki, sekarang zaman nya ...
# 3                                telkomsel is the best
# 4                         hbd mytelkomsel yang ke-5thn
# ..                                                 ...
# 139                                         h mulu ajg
# 140  dah gak ke tolong lagi nih jaringan mending pi...
# 141  wahai provider,,tolong buat vidio ama thumnail...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                       cleaning_comment  \
# 0    mogah makin maju dan berkembang terus meningka...
# 1
# 2    tolong segera perbaiki sekarang zaman nya zoom...
# 3                                   telkomsel the best
# 4                            hbd mytelkomsel yang  thn
# ..                                                 ...
# 139                                           mulu ajg
# 140  dah gak tolong lagi nih jaringan mending pinda...
# 141  wahai provider tolong buat vidio ama thumnail ...
# 142       kita tidak butuh promo kita butuh nya sinyal
# 143                        ayo kawan dislike telkomsel
#
#                                             tokenisasi  \
# 0    [mogah, makin, maju, dan, berkembang, terus, m...
# 1                                                 [, ]
# 2    [tolong, segera, perbaiki, sekarang, zaman, ny...
# 3                               [telkomsel, the, best]
# 4                        [hbd, mytelkomsel, yang, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [dah, gak, tolong, lagi, nih, jaringan, mendin...
# 141  [wahai, provider, tolong, buat, vidio, ama, th...
# 142  [kita, tidak, butuh, promo, kita, butuh, nya, ...
# 143                   [ayo, kawan, dislike, telkomsel]
#
#                                               stopword  \
# 0      [mogah, maju, berkembang, meningkat, telkomsel]
# 1                                                 [, ]
# 2    [tolong, perbaiki, zaman, zoom, terkendala, si...
# 3                               [telkomsel, the, best]
# 4                              [hbd, mytelkomsel, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [tolong, jaringan, mending, pindah, dri, pda, ...
# 141  [provider, tolong, vidio, ama, thumnail, bener...
# 142                      [butuh, promo, butuh, sinyal]
# 143                   [ayo, kawan, dislike, telkomsel]
#
#                                               stemming
# 0           [mogah, maju, kembang, tingkat, telkomsel]
# 1                                                 [, ]
# 2    [tolong, baik, zaman, zoom, kendala, sinyal, t...
# 3                               [telkomsel, the, best]
# 4                              [hbd, mytelkomsel, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [tolong, jaring, mending, pindah, dri, pda, nt...
# 141  [provider, tolong, vidio, ama, thumnail, bener...
# 142                      [butuh, promo, butuh, sinyal]
# 143                   [ayo, kawan, dislike, telkomsel]
#
# [76 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0           [mogah, maju, kembang, tingkat, telkomsel]
# 1                                                 [, ]
# 2    [tolong, baik, zaman, zoom, kendala, sinyal, t...
# 3                               [telkomsel, the, best]
# 4                              [hbd, mytelkomsel, thn]
# ..                                                 ...
# 139                                      [, mulu, ajg]
# 140  [tolong, jaring, mending, pindah, dri, pda, nt...
# 141  [provider, tolong, vidio, ama, thumnail, bener...
# 142                      [butuh, promo, butuh, sinyal]
# 143                   [ayo, kawan, dislike, telkomsel]
#
# [76 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_3.xlsx')
