# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5G akan menjadi teknologi terakhir ...
# 2    2 manfaat 5G sebagai Game-Changer yang bisa bi...
# 3    1. 5G akan mampu membantu kita menggali potens...
# 4                                         Manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                Pelayanan yang buruk dari telkonsel
# 407    Jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5G nya 4G nya masih meragukan
# 409                     Raah 5G nan. Sinyale ngelek su
#
# [410 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 109

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5G akan menjadi teknologi terakhir ...
# 2    2 manfaat 5G sebagai Game-Changer yang bisa bi...
# 3    1. 5G akan mampu membantu kita menggali potens...
# 4                                         Manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                Pelayanan yang buruk dari telkonsel
# 407    Jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5G nya 4G nya masih meragukan
# 409                     Raah 5G nan. Sinyale ngelek su
#
# [195 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5g akan menjadi teknologi terakhir ...
# 2    2 manfaat 5g sebagai game-changer yang bisa bi...
# 3    1. 5g akan mampu membantu kita menggali potens...
# 4                                         manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5g nya 4g nya masih meragukan
# 409                     raah 5g nan. sinyale ngelek su
#
# [195 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5g akan menjadi teknologi terakhir ...
# 2    2 manfaat 5g sebagai game-changer yang bisa bi...
# 3    1. 5g akan mampu membantu kita menggali potens...
# 4                                         manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5g nya 4g nya masih meragukan
# 409                     raah 5g nan. sinyale ngelek su
#
#                                       cleaning_comment
# 0    alhamdulillah keluarga besar terbantu komunika...
# 1    sepertinya akan menjadi teknologi terakhir san...
# 2     manfaat sebagai game changer yang bisa bikin ...
# 3     akan mampu membantu kita menggali potensi dir...
# 4                                          manfaatnya
# ..                                                 ...
# 405  telkomsel sinyal nya suka naek turun klau pake...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408                 tunda ajah nya nya masih meragukan
# 409                           raah nan sinyale ngelek
#
# [195 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5g akan menjadi teknologi terakhir ...
# 2    2 manfaat 5g sebagai game-changer yang bisa bi...
# 3    1. 5g akan mampu membantu kita menggali potens...
# 4                                         manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5g nya 4g nya masih meragukan
# 409                     raah 5g nan. sinyale ngelek su
#
#                                       cleaning_comment  \
# 0    alhamdulillah keluarga besar terbantu komunika...
# 1    sepertinya akan menjadi teknologi terakhir san...
# 2     manfaat sebagai game changer yang bisa bikin ...
# 3     akan mampu membantu kita menggali potensi dir...
# 4                                          manfaatnya
# ..                                                 ...
# 405  telkomsel sinyal nya suka naek turun klau pake...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408                 tunda ajah nya nya masih meragukan
# 409                           raah nan sinyale ngelek
#
#                                             tokenisasi
# 0    [alhamdulillah, keluarga, besar, terbantu, kom...
# 1    [sepertinya, akan, menjadi, teknologi, terakhi...
# 2    [, manfaat, sebagai, game, changer, yang, bisa...
# 3    [, akan, mampu, membantu, kita, menggali, pote...
# 4                                       [manfaatnya, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, nya, suka, naek, turun, kl...
# 406          [pelayanan, yang, buruk, dari, telkonsel]
# 407  [jaringan, diperbaiki, dulu, baru, buat, inova...
# 408        [, tunda, ajah, nya, nya, masih, meragukan]
# 409                     [raah, nan, sinyale, ngelek, ]
#
# [195 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5g akan menjadi teknologi terakhir ...
# 2    2 manfaat 5g sebagai game-changer yang bisa bi...
# 3    1. 5g akan mampu membantu kita menggali potens...
# 4                                         manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5g nya 4g nya masih meragukan
# 409                     raah 5g nan. sinyale ngelek su
#
#                                       cleaning_comment  \
# 0    alhamdulillah keluarga besar terbantu komunika...
# 1    sepertinya akan menjadi teknologi terakhir san...
# 2     manfaat sebagai game changer yang bisa bikin ...
# 3     akan mampu membantu kita menggali potensi dir...
# 4                                          manfaatnya
# ..                                                 ...
# 405  telkomsel sinyal nya suka naek turun klau pake...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408                 tunda ajah nya nya masih meragukan
# 409                           raah nan sinyale ngelek
#
#                                             tokenisasi  \
# 0    [alhamdulillah, keluarga, besar, terbantu, kom...
# 1    [sepertinya, akan, menjadi, teknologi, terakhi...
# 2    [, manfaat, sebagai, game, changer, yang, bisa...
# 3    [, akan, mampu, membantu, kita, menggali, pote...
# 4                                       [manfaatnya, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, nya, suka, naek, turun, kl...
# 406          [pelayanan, yang, buruk, dari, telkonsel]
# 407  [jaringan, diperbaiki, dulu, baru, buat, inova...
# 408        [, tunda, ajah, nya, nya, masih, meragukan]
# 409                     [raah, nan, sinyale, ngelek, ]
#
#                                               stopword
# 0    [alhamdulillah, keluarga, terbantu, komunikasi...
# 1                    [teknologi, mumpuni, indonesia, ]
# 2    [, manfaat, game, changer, hidup, mudah, produ...
# 3    [, membantu, menggali, potensi, menginspirasi,...
# 4                                       [manfaatnya, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, suka, naek, turun, klau, m...
# 406                      [pelayanan, buruk, telkonsel]
# 407                    [jaringan, diperbaiki, inovasi]
# 408                         [, tunda, ajah, meragukan]
# 409                          [raah, sinyale, ngelek, ]
#
# [195 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 651
# ------------------------
# alhamdulillah : alhamdulillah
# keluarga : keluarga
# terbantu : bantu
# komunikasi : komunikasi
# lancar : lancar
# telkomsel : telkomsel
#  :
# teknologi : teknologi
# mumpuni : mumpuni
# indonesia : indonesia
# manfaat : manfaat
# game : game
# changer : changer
# hidup : hidup
# mudah : mudah
# produktif : produktif
# direktur : direktur
# utama : utama
# setya : setya
# hantoro : hantoro
# video : video
# membantu : bantu
# menggali : gali
# potensi : potensi
# menginspirasi : inspirasi
# masyarakat : masyarakat
# terpikirkan : pikir
# ujungnya : ujung
# kehidupan : hidup
# bahagia : bahagia
# manfaatnya : manfaat
# mantab : mantab
# titik : titik
# orang : orang
# menikmati : nikmat
# harap : harap
# semangat : semangat
# telkom : telkom
# pita : pita
# mencakup : cakup
# udh : udh
# hadir : hadir
# indo : indo
# tekomsel : tekomsel
# dimohon : mohon
# pemerataan : perata
# jaringan : jaring
# internet : internet
# kestabilan : stabil
# ping : ping
# seluler : seluler
# mengalami : alami
# mengganggu : ganggu
# aktivitas : aktivitas
# berselancar : selancar
# optimalkan : optimal
# daerah : daerah
# barat : barat
# timur : timur
# sabar : sabar
# kepingin : kepingin
# ngerasain : ngerasain
# setuju : tuju
# tpi : tpi
# koq : koq
# stabil : stabil
# moga : moga
# lupa : lupa
# jaringa : jaringa
# perbaikin : perbaikin
# terima : terima
# kasih : kasih
# trus : trus
# sempurnakan : sempurna
# mantap : mantap
# sluurr : sluurr
# langsung : langsung
# luncurin : luncurin
# resmikan : resmi
# nyaa : nyaa
# band : band
# frekuensi : frekuensi
# pakai : pakai
# mantep : mantep
# sampe : sampe
# ketinggalan : tinggal
# beli : beli
# support : support
# yuk : yuk
# perbaiki : baik
# signal : signal
# mohon : mohon
# dlu : dlu
# lbih : lbih
# fokuskan : fokus
# nonton : nonton
# youtube : youtube
# melek : melek
# telekomunikasi : telekomunikasi
# digital : digital
# dirut : dirut
# setyanto : setyanto
# sbg : sbg
# mengenali : nali
# ketahui : tahu
# dlm : dlm
# tekhnologi : tekhnologi
# shg : shg
# ayok : ayok
# memajukan : maju
# bangsa : bangsa
# beralih : alih
# guys : guys
# putri : putri
# mevian : mevian
# munkin : munkin
# kuat : kuat
# sinyalnya : sinyal
# semoga : moga
# kenangan : kenang
# rawan : rawan
# hilang : hilang
# rusak : rusak
# galanya : gala
# cloud : cloud
# skip : skip
# berasa : asa
# menghadirkan : hadir
# telkomesel : telkomesel
# far : far
# good : good
# almost : almost
# years : years
# benahi : benah
# sistemnya : sistem
# boss : boss
# membeli : beli
# poco : poco
# pro : pro
# sukses : sukses
# slalu : slalu
# tsel : tsel
# cmn : cmn
# populer : populer
# beredar : edar
# thanks : thanks
# for : for
# sharing : sharing
# kuota : kuota
# unlimited : unlimited
# tekkomsel : tekkomsel
# dibatesin : dibatesin
# nyaman : nyaman
# psti : psti
# pengguna : guna
# xiaomi : xiaomi
# samsung : samsung
# min : min
# saran : saran
# mah : mah
# promosi : promosi
# kayak : kayak
# thailand : thailand
# brand : brand
# ambassadornya : ambassadornya
# lisa : lisa
# blackpink : blackpink
# ambassador : ambassador
# niki : nik
# rich : rich
# brian : brian
# dita : dita
# karang : karang
# tolong : tolong
# paket : paket
# turunkan : turun
# harganya : harga
# tar : tar
# kebocoran : bocor
# data : data
# tingkatkan : tingkat
# keamanan : aman
# datanya : data
# bocorrrrr : bocorrrrr
# gitu : gitu
# smartfren : smartfren
# rumah : rumah
# raya : raya
# narogong : narogong
# cileungsi : cileungsi
# bogor : bogor
# kota : kota
# desa : desa
# pengen : ken
# merasakan : rasa
# urusan : urus
# bercanda : canda
# emng : emng
# plosok : plosok
# beres : beres
# tinggal : tinggal
# tower : tower
# karna : karna
# korupsi : korupsi
# gratisannya : gratis
# dibatasi : batas
# gb : gb
# sampek : sampek
# sebulan : bulan
# nyiapin : nyiapin
# jringan : jringan
# dibeberapa : beberapa
# jatim : jatim
# bosss : bosss
# kacau : kacau
# trial : trial
# mhz : mhz
# nyobain : nyobain
# thx : thx
# infonya : info
# bagus : bagus
# awet : awet
# internetnya : internetnya
# via : via
# wifi : wifi
# ooo : ooo
# susah : susah
# leley : leley
# banten : banten
# fungsi : fungsi
# mempercepat : cepat
# ketikan : keti
# komentar : komentar
# netizen : netizen
# serangan : serang
# mental : mental
# medsos : medsos
# kesalahan : salah
# tindakan : tindak
# bodoh : bodoh
# jadirkan : jadirkan
# sya : sya
# hrap : hrap
# bsa : bsa
# tipe : tipe
# digadang : gadang
# gadang : gadang
# tanggal : tanggal
# dijakarta : dijakarta
# menggelar : gelar
# gimana : gimana
# solusi : solusi
# sinyal : sinyal
# pelosok : pelosok
# pemancar : pancar
# deket : deket
# nambah : nambah
# biyar : biyar
# dapet : dapet
# ayo : ayo
# buruan : buru
# coba : coba
# skrng : skrng
# turun : turun
# udah : udah
# bruh : bruh
# smh : smh
# janji : janji
# kecepatan : cepat
# apk : apk
# dibawah : bawah
# kbps : kbps
# gua : gua
# byu : byu
# noleh : noleh
# bentar : bentar
# habis : habis
# matiin : matiin
# mic : mic
# aduh : aduh
# lelet : lelet
# banget : banget
# ctrt : ctrt
# cerita : cerita
# tawa : tawa
# ruang : ruang
# gaya : gaya
# jakarta : jakarta
# kaya : kaya
# siput : siput
# dibenahi : benah
# budget : budget
# perusahaan : usaha
# dihambur : hambur
# hamburin : hamburin
# advertising : advertising
# layanan : layan
# butut : butut
# setelan : setel
# bajunya : baju
# bill : bill
# gates : gates
# spammer : spammer
# kmi : kmi
# dilindungi : lindung
# maaf : maaf
# ancur : ancur
# maen : maen
# kobisa : kobisa
# mengecewakan : kecewa
# tolonggg : tolonggg
# knp : knp
# pakk : pakk
# sebulann : sebulann
# paaa : paaa
# ngelag : ngelag
# woi : woi
# jaringanya : jaringanya
# patah : patah
# mulu : mulu
# biat : biat
# ngegame : ngegame
# benerin : benerin
# new : new
# update : update
# gerak : gerak
# cepat : cepat
# bangun : bangun
# lag : lag
# kalah : kalah
# operator : operator
# sebelah : belah
# mending : mending
# sok : sok
# asik : asik
# rb : rb
# indosat : indosat
# rebu : rebu
# wkwkwkwkwkwkwk : wkwkwkwkwkwkwk
# gila : gila
# bobrok : bobrok
# lokasi : lokasi
# gue : gue
# lagg : lagg
# parah : parah
# towr : towr
# kantor : kantor
# rog : rog
# phone : phone
# muncul : muncul
# asus : asus
# store : store
# nunggu : nunggu
# make : make
# kecewa : kecewa
# giniii : giniii
# ajh : ajh
# blm : blm
# bener : bener
# tong : tong
# paketan : paket
# pulah : pulah
# pebaiki : baik
# jawa : jawa
# mlh : mlh
# tmbh : tmbh
# lol : lol
# ora : ora
# ngelek : ngelek
# garai : garai
# emosi : emosi
# sumpah : sumpah
# paa : paa
# bneerinnn : bneerinnn
# pakkkkkkkkkkkkkkk : pakkkkkkkkkkkkkkk
# astaga : astaga
# siaap : siaap
# omong : omong
# kosong : kosong
# belepotan : belepotan
# iklan : iklan
# sampah : sampah
# taripnya : taripnya
# ppppffffff : ppppffffff
# gimmick : gimmick
# doang : doang
# snyal : snyal
# dibenahin : dibenahin
# sinyak : sinyak
# botak : botak
# korup : korup
# kah : kah
# heleeh : heleeh
# sepi : sepi
# ngrleg : ngrleg
# innovation : innovation
# bidang : bidang
# digitalisasi : digitalisasi
# mudahan : mudah
# terwujud : wujud
# diindonesia : indonesia
# contohnya : contoh
# membawa : bawa
# terobosan : terobos
# pengalaman : alam
# tanah : tanah
# air : air
# tercinta : cinta
# negara : negara
# mengimplementasikan : implementasi
# terkhusus : khusus
# kepulaan : pula
# luck : luck
# wishnutama : wishnutama
# pelayanan : layan
# terbaik : baik
# jaya : jaya
# aamiin : aamiin
# kereeenn : kereeenn
# tertarik : tarik
# vitual : vitual
# shopping : shopping
# mall : mall
# wkwkwk : wkwkwk
# keadilan : adil
# rakyat : rakyat
# secepatnya : cepat
# dikota : kota
# nias : nias
# selatan : selatan
# sedih : sedih
# mati : mati
# ngelet : ngelet
# job : job
# trader : trader
# terganggu : ganggu
# kondisi : kondisi
# harga : harga
# murah : murah
# ama : ama
# steve : steve
# jobs : jobs
# wisnutama : wisnutama
# terealisasi : realisasi
# pedesaan : desa
# kecanggihan : canggih
# ditunggu : tunggu
# penerapan : terap
# wahh : wahh
# nungguin : nungguin
# gebrakan : gebrak
# mendukung : dukung
# pemerintah : perintah
# terlaksana : laksana
# lanjutkan : lanjut
# setia : setia
# didaerah : daerah
# kudus : kudus
# area : area
# dersalam : dersalam
# bae : bae
# memprihatinkan : prihatin
# koneksinya : koneksi
# istriku : istri
# kartu : kartu
# halo : halo
# marah : marah
# padaku : pada
# galih : galih
# tunggu : tunggu
# provider : provider
# salam : salam
# tangguh : tangguh
# telkomsell : telkomsell
# mksh : mksh
# mas : mas
# tama : tama
# ayolah : ayo
# xcloud : xcloud
# masuk : masuk
# promo : promo
# hehehehe : hehehehe
# sebenere : sebenere
# smartphone : smartphone
# gmn : gmn
# denger : denger
# industri : industri
# berfikiran : berfikiran
# pengganti : ganti
# komen : komen
# paham : paham
# ending : ending
# wkwkw : wkwkw
# pubg : pubg
# perang : perang
# musuh : musuh
# player : player
# luas : luas
# peta : peta
# kali : kali
# ukuran : ukur
# miranmar : miranmar
# rilis : rilis
# loading : loading
# dear : dear
# berangan : berangan
# angan : angan
# ratakan : rata
# wilayah : wilayah
# iphone : iphone
# max : max
# drastis : drastis
# idola : idola
# enak : enak
# dengerin : dengerin
# ampe : ampe
# menitan : menit
# stadion : stadion
# virtual : virtual
# pertandingan : tanding
# bola : bola
# tiket : tiket
# kursi : kursi
# viewnya : viewnya
# sperti : sperti
# kebayang : bayang
# can : can
# inii : ini
# yeay : yeay
# mei : mei
# kirain : kirain
# wisnu : wisnu
# serius : serius
# ngelucu : ngelucu
# full : full
# berbicara : bicara
# firtual : firtual
# berbahaya : bahaya
# wibu : wibu
# hmmmmm : hmmmmm
# logo : logo
# terbaru : baru
# trans : trans
# ready : ready
# use : use
# kampung : kampung
# penikmat : nikmat
# prioritaskn : prioritaskn
# buruk : buruk
# kembang : kembang
# kempis : kempis
# speed : speed
# konsisten : konsisten
# iklanny : iklanny
# bang : bang
# sengaja : sengaja
# aktifin : aktifin
# subtitle : subtitle
# fauzi : fauzi
# lbh : lbh
# fokus : fokus
# singal : singal
# lembah : lembah
# beringin : beringin
# kec : kec
# nanga : nanga
# mahap : mahap
# kab : kab
# sekadau : sekadau
# kalimantan : kalimantan
# dinanti : nanti
# menit : menit
# kb : kb
# omdo : omdo
# pedalaman : dalam
# papua : papua
# sulit : sulit
# buluk : buluk
# ngapain : ngapain
# fup : fup
# ditiadakan : tiada
# mengakses : akses
# apapun : apa
# kau : kau
# pindah : pindah
# axis : axis
# koneksi : koneksi
# pas : pas
# siang : siang
# alamat : alamat
# rawe : rawe
# lingkungan : lingkung
# xii : xii
# kelurahan : lurah
# tangkahan : tangkah
# kecamatan : camat
# medan : medan
# labuhan : labuh
# terimakasih : terimakasih
# aje : aje
# volte : volte
# meanwhile : meanwhile
# sokan : sok
# kentang : kentang
# pikirin : pikirin
# mendingan : mending
# telkomse : telkomse
# esim : esim
# dongggg : dongggg
# kpn : kpn
# kampubg : kampubg
# surya : surya
# marshel : marshel
# kesini : kesini
# omongan : omong
# besok : besok
# belajar : ajar
# daring : daring
# tii : tii
# kopii : kopi
# tiii : tiii
# kopi : kopi
# main : main
# bhatong : bhatong
# city : city
# terangga : angga
# pondok : pondok
# indah : indah
# buriq : buriq
# lanjay : lanjay
# anjay : anjay
# bantuan : bantu
# gamesmax : gamesmax
# akses : akses
# crany : crany
# agr : agr
# ampas : ampas
# hilangkan : hilang
# unli : unli
# suka : suka
# naek : naek
# klau : klau
# ajah : ajah
# gangguan : ganggu
# telkonsel : telkonsel
# diperbaiki : baik
# inovasi : inovasi
# tunda : tunda
# meragukan : ragu
# raah : raah
# sinyale : sinyale
# {'alhamdulillah': 'alhamdulillah', 'keluarga': 'keluarga', 'terbantu': 'bantu', 'komunikasi': 'komunikasi', 'lancar': 'lancar', 'telkomsel': 'telkomsel', '': '', 'teknologi': 'teknologi', 'mumpuni': 'mumpuni', 'indonesia': 'indonesia', 'manfaat': 'manfaat', 'game': 'game', 'changer': 'changer', 'hidup': 'hidup', 'mudah': 'mudah', 'produktif': 'produktif', 'direktur': 'direktur', 'utama': 'utama', 'setya': 'setya', 'hantoro': 'hantoro', 'video': 'video', 'membantu': 'bantu', 'menggali': 'gali', 'potensi': 'potensi', 'menginspirasi': 'inspirasi', 'masyarakat': 'masyarakat', 'terpikirkan': 'pikir', 'ujungnya': 'ujung', 'kehidupan': 'hidup', 'bahagia': 'bahagia', 'manfaatnya': 'manfaat', 'mantab': 'mantab', 'titik': 'titik', 'orang': 'orang', 'menikmati': 'nikmat', 'harap': 'harap', 'semangat': 'semangat', 'telkom': 'telkom', 'pita': 'pita', 'mencakup': 'cakup', 'udh': 'udh', 'hadir': 'hadir', 'indo': 'indo', 'tekomsel': 'tekomsel', 'dimohon': 'mohon', 'pemerataan': 'perata', 'jaringan': 'jaring', 'internet': 'internet', 'kestabilan': 'stabil', 'ping': 'ping', 'seluler': 'seluler', 'mengalami': 'alami', 'mengganggu': 'ganggu', 'aktivitas': 'aktivitas', 'berselancar': 'selancar', 'optimalkan': 'optimal', 'daerah': 'daerah', 'barat': 'barat', 'timur': 'timur', 'sabar': 'sabar', 'kepingin': 'kepingin', 'ngerasain': 'ngerasain', 'setuju': 'tuju', 'tpi': 'tpi', 'koq': 'koq', 'stabil': 'stabil', 'moga': 'moga', 'lupa': 'lupa', 'jaringa': 'jaringa', 'perbaikin': 'perbaikin', 'terima': 'terima', 'kasih': 'kasih', 'trus': 'trus', 'sempurnakan': 'sempurna', 'mantap': 'mantap', 'sluurr': 'sluurr', 'langsung': 'langsung', 'luncurin': 'luncurin', 'resmikan': 'resmi', 'nyaa': 'nyaa', 'band': 'band', 'frekuensi': 'frekuensi', 'pakai': 'pakai', 'mantep': 'mantep', 'sampe': 'sampe', 'ketinggalan': 'tinggal', 'beli': 'beli', 'support': 'support', 'yuk': 'yuk', 'perbaiki': 'baik', 'signal': 'signal', 'mohon': 'mohon', 'dlu': 'dlu', 'lbih': 'lbih', 'fokuskan': 'fokus', 'nonton': 'nonton', 'youtube': 'youtube', 'melek': 'melek', 'telekomunikasi': 'telekomunikasi', 'digital': 'digital', 'dirut': 'dirut', 'setyanto': 'setyanto', 'sbg': 'sbg', 'mengenali': 'nali', 'ketahui': 'tahu', 'dlm': 'dlm', 'tekhnologi': 'tekhnologi', 'shg': 'shg', 'ayok': 'ayok', 'memajukan': 'maju', 'bangsa': 'bangsa', 'beralih': 'alih', 'guys': 'guys', 'putri': 'putri', 'mevian': 'mevian', 'munkin': 'munkin', 'kuat': 'kuat', 'sinyalnya': 'sinyal', 'semoga': 'moga', 'kenangan': 'kenang', 'rawan': 'rawan', 'hilang': 'hilang', 'rusak': 'rusak', 'galanya': 'gala', 'cloud': 'cloud', 'skip': 'skip', 'berasa': 'asa', 'menghadirkan': 'hadir', 'telkomesel': 'telkomesel', 'far': 'far', 'good': 'good', 'almost': 'almost', 'years': 'years', 'benahi': 'benah', 'sistemnya': 'sistem', 'boss': 'boss', 'membeli': 'beli', 'poco': 'poco', 'pro': 'pro', 'sukses': 'sukses', 'slalu': 'slalu', 'tsel': 'tsel', 'cmn': 'cmn', 'populer': 'populer', 'beredar': 'edar', 'thanks': 'thanks', 'for': 'for', 'sharing': 'sharing', 'kuota': 'kuota', 'unlimited': 'unlimited', 'tekkomsel': 'tekkomsel', 'dibatesin': 'dibatesin', 'nyaman': 'nyaman', 'psti': 'psti', 'pengguna': 'guna', 'xiaomi': 'xiaomi', 'samsung': 'samsung', 'min': 'min', 'saran': 'saran', 'mah': 'mah', 'promosi': 'promosi', 'kayak': 'kayak', 'thailand': 'thailand', 'brand': 'brand', 'ambassadornya': 'ambassadornya', 'lisa': 'lisa', 'blackpink': 'blackpink', 'ambassador': 'ambassador', 'niki': 'nik', 'rich': 'rich', 'brian': 'brian', 'dita': 'dita', 'karang': 'karang', 'tolong': 'tolong', 'paket': 'paket', 'turunkan': 'turun', 'harganya': 'harga', 'tar': 'tar', 'kebocoran': 'bocor', 'data': 'data', 'tingkatkan': 'tingkat', 'keamanan': 'aman', 'datanya': 'data', 'bocorrrrr': 'bocorrrrr', 'gitu': 'gitu', 'smartfren': 'smartfren', 'rumah': 'rumah', 'raya': 'raya', 'narogong': 'narogong', 'cileungsi': 'cileungsi', 'bogor': 'bogor', 'kota': 'kota', 'desa': 'desa', 'pengen': 'ken', 'merasakan': 'rasa', 'urusan': 'urus', 'bercanda': 'canda', 'emng': 'emng',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/195 [00:00<?, ?it/s]
#                                                comment  \
# 0    alhamdulillah, sy & keluarga besar terbantu ko...
# 1    sepertinya 5g akan menjadi teknologi terakhir ...
# 2    2 manfaat 5g sebagai game-changer yang bisa bi...
# 3    1. 5g akan mampu membantu kita menggali potens...
# 4                                         manfaatnya :
# ..                                                 ...
# 405  telkomsel ko sinyal nya suka naek turun pa kla...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408     di tunda ajah pa 5g nya 4g nya masih meragukan
# 409                     raah 5g nan. sinyale ngelek su
#
#                                       cleaning_comment  \
# 0    alhamdulillah keluarga besar terbantu komunika...
# 1    sepertinya akan menjadi teknologi terakhir san...
# 2     manfaat sebagai game changer yang bisa bikin ...
# 3     akan mampu membantu kita menggali potensi dir...
# 4                                          manfaatnya
# ..                                                 ...
# 405  telkomsel sinyal nya suka naek turun klau pake...
# 406                pelayanan yang buruk dari telkonsel
# 407    jaringan diperbaiki dulu baru buat inovasi baru
# 408                 tunda ajah nya nya masih meragukan
# 409                           raah nan sinyale ngelek
#
#                                             tokenisasi  \
# 0    [alhamdulillah, keluarga, besar, terbantu, kom...
# 1    [sepertinya, akan, menjadi, teknologi, terakhi...
# 2    [, manfaat, sebagai, game, changer, yang, bisa...
# 3    [, akan, mampu, membantu, kita, menggali, pote...
# 4                                       [manfaatnya, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, nya, suka, naek, turun, kl...
# 406          [pelayanan, yang, buruk, dari, telkonsel]
# 407  [jaringan, diperbaiki, dulu, baru, buat, inova...
# 408        [, tunda, ajah, nya, nya, masih, meragukan]
# 409                     [raah, nan, sinyale, ngelek, ]
#
#                                               stopword  \
# 0    [alhamdulillah, keluarga, terbantu, komunikasi...
# 1                    [teknologi, mumpuni, indonesia, ]
# 2    [, manfaat, game, changer, hidup, mudah, produ...
# 3    [, membantu, menggali, potensi, menginspirasi,...
# 4                                       [manfaatnya, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, suka, naek, turun, klau, m...
# 406                      [pelayanan, buruk, telkonsel]
# 407                    [jaringan, diperbaiki, inovasi]
# 408                         [, tunda, ajah, meragukan]
# 409                          [raah, sinyale, ngelek, ]
#
#                                               stemming
# 0    [alhamdulillah, keluarga, bantu, komunikasi, l...
# 1                    [teknologi, mumpuni, indonesia, ]
# 2    [, manfaat, game, changer, hidup, mudah, produ...
# 3    [, bantu, gali, potensi, inspirasi, masyarakat...
# 4                                          [manfaat, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, suka, naek, turun, klau, m...
# 406                          [layan, buruk, telkonsel]
# 407                            [jaring, baik, inovasi]
# 408                              [, tunda, ajah, ragu]
# 409                          [raah, sinyale, ngelek, ]
#
# [195 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [alhamdulillah, keluarga, bantu, komunikasi, l...
# 1                    [teknologi, mumpuni, indonesia, ]
# 2    [, manfaat, game, changer, hidup, mudah, produ...
# 3    [, bantu, gali, potensi, inspirasi, masyarakat...
# 4                                          [manfaat, ]
# ..                                                 ...
# 405  [telkomsel, sinyal, suka, naek, turun, klau, m...
# 406                          [layan, buruk, telkonsel]
# 407                            [jaring, baik, inovasi]
# 408                              [, tunda, ajah, ragu]
# 409                          [raah, sinyale, ngelek, ]
#
# [195 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_5.xlsx')
