# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["comment_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\databersih_english_youtube_telkomsel\databersih_english_youtube_telkomsel_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                       comment_english
# 0                                  ['press', 'front']
# 1                              ['Press', 'Telkomsel']
# 2                              ['Champion', 'pis', "]
# 3                                          ['steady']
# 4                                ['Compact', 'limit']
# 5                               ['Amin', 'hopefully']
# 6                                       ['Salkomsel']
# 7           ['Greetings', 'know', 'bang', 'wakatobi']
# 8   ['bangle', 'emang', 'telkom', 'play', 'lag', '...
# 9   ['signal', 'Nge', 'lag', 'severe', 'game', 'un...
# 10  ['', 'Telkomsel', 'Telkomsel', 'already', 'com...
# 11  ['', 'good', 'net', 'Riau', 'UDH', 'beil', 'ko...
# 12  ['Benerin', 'net', 'woy', 'already', 'week', '...
# 13  ['Woy', 'nets', 'good', 'area', 'Centraleng', ...
# 14  ['woi', 'area', 'tanggerang', 'net', 'telkomse...
# 15        ['signal', 'whispered', 'cuk', 'dandanano']
# 16                                        ['present']
# 17                               ['Hey', 'Telkomsel']
# 18               ['Telkomsel', 'lag', 'Ogah', 'make']
# 19  ['Pliss', 'Lahhh', 'UDH', 'Download', 'Net', '...
# 20  ['Good', 'sinya', 'Please', 'like', 'disturbing']
# 21                                           ['poko']
# 22                          ['Telkomsel', 'function']
# 23                         ['Stay', 'Make', 'Telkom']
# 24  ['', 'Credit', 'Cut', 'Costs', 'Internet', 'Qu...
# 25                            ['Telkomsel', 'broken']
# 26                         ['Net', 'Benerin', 'Woii']
# 27                            ['Network', 'brokenkk']
# 28                               ['Telkomsel', 'lag']
# 29                          ['Woy', 'nets', 'denget']
# 30  ['Telkomsel', 'City', 'Bogor', 'Land', 'Sareal...
# 31  ['Satisfied', 'subscribe', 'behavior', 'price'...
# 32             ['Fixed', 'road', 'wave', 'stone', '']
# 33  ['Yesterday', 'buy', 'quota', 'Telkomsel', 'fo...
# 34  ['net', 'spacious', 'difficult', 'good', 'tlfo...
# 35                                         ['Janjot']
# 36                                    ['comment', '']
# 37                               ['comment', 'slurr']
# 38                                            ['hih']
# 39  ['thank', 'love', 'Telkomsel', 'thanks', 'mobi...
# 40  ['Subscribe', 'Telkomsel', 'comments',' No ','...
# 41  ['', 'That's', 'ohhhh', 'yes', 'deh', 'please'...
# 42                      ['', 'space', 'guest', 'bar']
# 43                  ['Since', 'Package', 'Unlimited']
# 44          ['Gausah', 'Telkomsel', 'Gajelas', 'net']

# %%
df['comment_english'] = df['comment_english'].str.lower()
df.head(2000)
# Out:
#                                       comment_english
# 0                                  ['press', 'front']
# 1                              ['press', 'telkomsel']
# 2                              ['champion', 'pis', "]
# 3                                          ['steady']
# 4                                ['compact', 'limit']
# 5                               ['amin', 'hopefully']
# 6                                       ['salkomsel']
# 7           ['greetings', 'know', 'bang', 'wakatobi']
# 8   ['bangle', 'emang', 'telkom', 'play', 'lag', '...
# 9   ['signal', 'nge', 'lag', 'severe', 'game', 'un...
# 10  ['', 'telkomsel', 'telkomsel', 'already', 'com...
# 11  ['', 'good', 'net', 'riau', 'udh', 'beil', 'ko...
# 12  ['benerin', 'net', 'woy', 'already', 'week', '...
# 13  ['woy', 'nets', 'good', 'area', 'centraleng', ...
# 14  ['woi', 'area', 'tanggerang', 'net', 'telkomse...
# 15        ['signal', 'whispered', 'cuk', 'dandanano']
# 16                                        ['present']
# 17                               ['hey', 'telkomsel']
# 18               ['telkomsel', 'lag', 'ogah', 'make']
# 19  ['pliss', 'lahhh', 'udh', 'download', 'net', '...
# 20  ['good', 'sinya', 'please', 'like', 'disturbing']
# 21                                           ['poko']
# 22                          ['telkomsel', 'function']
# 23                         ['stay', 'make', 'telkom']
# 24  ['', 'credit', 'cut', 'costs', 'internet', 'qu...
# 25                            ['telkomsel', 'broken']
# 26                         ['net', 'benerin', 'woii']
# 27                            ['network', 'brokenkk']
# 28                               ['telkomsel', 'lag']
# 29                          ['woy', 'nets', 'denget']
# 30  ['telkomsel', 'city', 'bogor', 'land', 'sareal...
# 31  ['satisfied', 'subscribe', 'behavior', 'price'...
# 32             ['fixed', 'road', 'wave', 'stone', '']
# 33  ['yesterday', 'buy', 'quota', 'telkomsel', 'fo...
# 34  ['net', 'spacious', 'difficult', 'good', 'tlfo...
# 35                                         ['janjot']
# 36                                    ['comment', '']
# 37                               ['comment', 'slurr']
# 38                                            ['hih']
# 39  ['thank', 'love', 'telkomsel', 'thanks', 'mobi...
# 40  ['subscribe', 'telkomsel', 'comments',' no ','...
# 41  ['', 'that's', 'ohhhh', 'yes', 'deh', 'please'...
# 42                      ['', 'space', 'guest', 'bar']
# 43                  ['since', 'package', 'unlimited']
# 44          ['gausah', 'telkomsel', 'gajelas', 'net']

# %%
df['label_awal'] = ''
for i,x in df.comment_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.0
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.0
# Index:  3 label_awal 0.16666666666666666
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.0
# Index:  8 label_awal -0.4
# Index:  9 label_awal -0.1
# Index:  10 label_awal 0.375
# Index:  11 label_awal 0.35
# Index:  12 label_awal 0.1
# Index:  13 label_awal 0.7
# Index:  14 label_awal 0.0
# Index:  15 label_awal 0.0
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.0
# Index:  20 label_awal 0.09999999999999998
# Index:  21 label_awal 0.0
# Index:  22 label_awal 0.0
# Index:  23 label_awal 0.0
# Index:  24 label_awal 0.0
# Index:  25 label_awal -0.4
# Index:  26 label_awal 0.0
# Index:  27 label_awal 0.0
# Index:  28 label_awal 0.0
# Index:  29 label_awal 0.0
# Index:  30 label_awal -0.3499999999999999
# Index:  31 label_awal 0.5666666666666668
# Index:  32 label_awal 0.1
# Index:  33 label_awal -0.2
# Index:  34 label_awal 0.06666666666666665
# Index:  35 label_awal 0.0
# Index:  36 label_awal 0.0
# Index:  37 label_awal 0.0
# Index:  38 label_awal 0.0
# Index:  39 label_awal 0.35
# Index:  40 label_awal 0.26666666666666666
# Index:  41 label_awal 0.2
# Index:  42 label_awal 0.0
# Index:  43 label_awal 0.0
# Index:  44 label_awal 0.0

# %%
df.head()
# Out:
#           comment_english label_awal
# 0      ['press', 'front']        0.0
# 1  ['press', 'telkomsel']        0.0
# 2  ['champion', 'pis', "]        0.0
# 3              ['steady']   0.166667
# 4    ['compact', 'limit']        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    28
# -0.400000     2
#  0.350000     2
#  0.100000     2
#  0.166667     1
# -0.100000     1
#  0.375000     1
#  0.700000     1
#  0.100000     1
# -0.350000     1
#  0.566667     1
# -0.200000     1
#  0.066667     1
#  0.266667     1
#  0.200000     1
# Name: label_awal, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] < 0.0:
        label.append("negative")
    else:
        label.append("positive")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                       comment_english     label
# 0                                  ['press', 'front']  positive
# 1                              ['press', 'telkomsel']  positive
# 2                              ['champion', 'pis', "]  positive
# 3                                          ['steady']  positive
# 4                                ['compact', 'limit']  positive
# 5                               ['amin', 'hopefully']  positive
# 6                                       ['salkomsel']  positive
# 7           ['greetings', 'know', 'bang', 'wakatobi']  positive
# 8   ['bangle', 'emang', 'telkom', 'play', 'lag', '...  negative
# 9   ['signal', 'nge', 'lag', 'severe', 'game', 'un...  negative
# 10  ['', 'telkomsel', 'telkomsel', 'already', 'com...  positive
# 11  ['', 'good', 'net', 'riau', 'udh', 'beil', 'ko...  positive
# 12  ['benerin', 'net', 'woy', 'already', 'week', '...  positive
# 13  ['woy', 'nets', 'good', 'area', 'centraleng', ...  positive
# 14  ['woi', 'area', 'tanggerang', 'net', 'telkomse...  positive
# 15        ['signal', 'whispered', 'cuk', 'dandanano']  positive
# 16                                        ['present']  positive
# 17                               ['hey', 'telkomsel']  positive
# 18               ['telkomsel', 'lag', 'ogah', 'make']  positive
# 19  ['pliss', 'lahhh', 'udh', 'download', 'net', '...  positive
# 20  ['good', 'sinya', 'please', 'like', 'disturbing']  positive
# 21                                           ['poko']  positive
# 22                          ['telkomsel', 'function']  positive
# 23                         ['stay', 'make', 'telkom']  positive
# 24  ['', 'credit', 'cut', 'costs', 'internet', 'qu...  positive
# 25                            ['telkomsel', 'broken']  negative
# 26                         ['net', 'benerin', 'woii']  positive
# 27                            ['network', 'brokenkk']  positive
# 28                               ['telkomsel', 'lag']  positive
# 29                          ['woy', 'nets', 'denget']  positive
# 30  ['telkomsel', 'city', 'bogor', 'land', 'sareal...  negative
# 31  ['satisfied', 'subscribe', 'behavior', 'price'...  positive
# 32             ['fixed', 'road', 'wave', 'stone', '']  positive
# 33  ['yesterday', 'buy', 'quota', 'telkomsel', 'fo...  negative
# 34  ['net', 'spacious', 'difficult', 'good', 'tlfo...  positive
# 35                                         ['janjot']  positive
# 36                                    ['comment', '']  positive
# 37                               ['comment', 'slurr']  positive
# 38                                            ['hih']  positive
# 39  ['thank', 'love', 'telkomsel', 'thanks', 'mobi...  positive
# 40  ['subscribe', 'telkomsel', 'comments',' no ','...  positive
# 41  ['', 'that's', 'ohhhh', 'yes', 'deh', 'please'...  positive
# 42                      ['', 'space', 'guest', 'bar']  positive
# 43                  ['since', 'package', 'unlimited']  positive
# 44          ['gausah', 'telkomsel', 'gajelas', 'net']  positive

# %%
df['label'].value_counts()
# Out:
# positive    40
# negative     5
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_youtube_telkomsel_4.xlsx')
