# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                               comment
# 0   Saya kuota beli bukan minta , apa susahnya sih...
# 1   Telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi H+
# 3                                           Telkomsel
# 4   Min kenapa ini dari kemaren jaringan ane gak l...
# ..                                                ...
# 82                          Gk pernah dapet promo huh
# 83                                   Ngelag parah asw
# 84                           Jaringan gua ngelek ajng
# 85                                      Sinyal bujang
# 86                                           PAN  TEK
#
# [87 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 27

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                               comment
# 0   Saya kuota beli bukan minta , apa susahnya sih...
# 1   Telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi H+
# 3                                           Telkomsel
# 4   Min kenapa ini dari kemaren jaringan ane gak l...
# 5   Gimana indonesia gak rawan covid orang"nya aja...
# 6             Telkomsel itu membangkrutkan kamu kecil
# 19  Selamat untuk para pemenang, semoga menjadi mo...
# 20                     Maju Terus Telkomsel Indonesia
# 21                            Maju terus Telkomsel 👍🏿
# 22                    Terima kasih mba' Tia Hutami. 👍
# 23                             Heran sinyal ga stabil
# 24  Tai, kouta malah jaringan kek tai kucing, mend...
# 25                         Harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  Pindah operator aja guys,GAGUNA INI KARTU SEKA...
# 29               pakae telkomsel selalu hilang sinyal
# 30              Jaringan tai . Mahalnya minta ampun .
# 31    Telkomsel ajggg,ngeleg trus kartu ajggg,sparing
# 33                                        Sinyal taik
# 34                                                Leg
# 35  Ok noted, thanks for sharing. Telkomsel yo're ...
# 36  Kartu simpati habis masa aktifnya harus ganti ...
# 37  Bang Kalo Pen Duitku bilang aja , Gpp aku kasi...
# 38  Bukan tambah bagus, semakin hari semakin buruk...
# 39  Ga guna gua main game lag parah memang Telkom ...
# 40                                          First min
# 54  Kita laporkan,dan konten gak ada gunanya, seba...
# 55  Percuma kalo up 5G pertama kalo jaringan 4G aj...
# 56  Assalamualaikum warahmatullahi wabarakatu sala...
# 57  Telkomsel, ByU , PADA KENAPA NIH !? KOMPENSASI...
# 58  Kenapa telkomsel malam lag dan siang lag dan s...
# 59             Indian how to apply Telkomsel sim card
# 60  Hari ini masi sama ga ada kejelasan. Ngelag sa...
# 61                                  beli subs dimana?
# 86                                           PAN  TEK

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                               comment
# 0   saya kuota beli bukan minta , apa susahnya sih...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi h+
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang"nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang, semoga menjadi mo...
# 20                     maju terus telkomsel indonesia
# 21                            maju terus telkomsel 👍🏿
# 22                    terima kasih mba' tia hutami. 👍
# 23                             heran sinyal ga stabil
# 24  tai, kouta malah jaringan kek tai kucing, mend...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys,gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30              jaringan tai . mahalnya minta ampun .
# 31    telkomsel ajggg,ngeleg trus kartu ajggg,sparing
# 33                                        sinyal taik
# 34                                                leg
# 35  ok noted, thanks for sharing. telkomsel yo're ...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja , gpp aku kasi...
# 38  bukan tambah bagus, semakin hari semakin buruk...
# 39  ga guna gua main game lag parah memang telkom ...
# 40                                          first min
# 54  kita laporkan,dan konten gak ada gunanya, seba...
# 55  percuma kalo up 5g pertama kalo jaringan 4g aj...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel, byu , pada kenapa nih !? kompensasi...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59             indian how to apply telkomsel sim card
# 60  hari ini masi sama ga ada kejelasan. ngelag sa...
# 61                                  beli subs dimana?
# 86                                           pan  tek

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                               comment  \
# 0   saya kuota beli bukan minta , apa susahnya sih...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi h+
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang"nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang, semoga menjadi mo...
# 20                     maju terus telkomsel indonesia
# 21                            maju terus telkomsel 👍🏿
# 22                    terima kasih mba' tia hutami. 👍
# 23                             heran sinyal ga stabil
# 24  tai, kouta malah jaringan kek tai kucing, mend...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys,gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30              jaringan tai . mahalnya minta ampun .
# 31    telkomsel ajggg,ngeleg trus kartu ajggg,sparing
# 33                                        sinyal taik
# 34                                                leg
# 35  ok noted, thanks for sharing. telkomsel yo're ...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja , gpp aku kasi...
# 38  bukan tambah bagus, semakin hari semakin buruk...
# 39  ga guna gua main game lag parah memang telkom ...
# 40                                          first min
# 54  kita laporkan,dan konten gak ada gunanya, seba...
# 55  percuma kalo up 5g pertama kalo jaringan 4g aj...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel, byu , pada kenapa nih !? kompensasi...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59             indian how to apply telkomsel sim card
# 60  hari ini masi sama ga ada kejelasan. ngelag sa...
# 61                                  beli subs dimana?
# 86                                           pan  tek
#
#                                      cleaning_comment
# 0   saya kuota beli bukan minta apa susahnya sih m...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2                   sama tiba tiba sinyal rumah jadi
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang semoga menjadi mot...
# 20                     maju terus telkomsel indonesia
# 21                              maju terus telkomsel
# 22                       terima kasih mba tia hutami
# 23                                heran sinyal stabil
# 24  tai kouta malah jaringan kek tai kucing mendin...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30                 jaringan tai mahalnya minta ampun
# 31    telkomsel ajggg ngeleg trus kartu ajggg sparing
# 33                                        sinyal taik
# 34                                                leg
# 35   noted thanks for sharing telkomsel the best f...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja gpp aku kasih ...
# 38  bukan tambah bagus semakin hari semakin buruk ...
# 39   guna gua main game lag parah memang telkom cacat
# 40                                          first min
# 54  kita laporkan dan konten gak ada gunanya sebag...
# 55  percuma kalo pertama kalo jaringan aja kaya si...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel byu pada kenapa nih kompensasi nya m...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59                indian how apply telkomsel sim card
# 60  hari ini masi sama ada kejelasan ngelag saat m...
# 61                                  beli subs dimana
# 86                                            pan tek

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                               comment  \
# 0   saya kuota beli bukan minta , apa susahnya sih...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi h+
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang"nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang, semoga menjadi mo...
# 20                     maju terus telkomsel indonesia
# 21                            maju terus telkomsel 👍🏿
# 22                    terima kasih mba' tia hutami. 👍
# 23                             heran sinyal ga stabil
# 24  tai, kouta malah jaringan kek tai kucing, mend...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys,gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30              jaringan tai . mahalnya minta ampun .
# 31    telkomsel ajggg,ngeleg trus kartu ajggg,sparing
# 33                                        sinyal taik
# 34                                                leg
# 35  ok noted, thanks for sharing. telkomsel yo're ...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja , gpp aku kasi...
# 38  bukan tambah bagus, semakin hari semakin buruk...
# 39  ga guna gua main game lag parah memang telkom ...
# 40                                          first min
# 54  kita laporkan,dan konten gak ada gunanya, seba...
# 55  percuma kalo up 5g pertama kalo jaringan 4g aj...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel, byu , pada kenapa nih !? kompensasi...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59             indian how to apply telkomsel sim card
# 60  hari ini masi sama ga ada kejelasan. ngelag sa...
# 61                                  beli subs dimana?
# 86                                           pan  tek
#
#                                      cleaning_comment  \
# 0   saya kuota beli bukan minta apa susahnya sih m...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2                   sama tiba tiba sinyal rumah jadi
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang semoga menjadi mot...
# 20                     maju terus telkomsel indonesia
# 21                              maju terus telkomsel
# 22                       terima kasih mba tia hutami
# 23                                heran sinyal stabil
# 24  tai kouta malah jaringan kek tai kucing mendin...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30                 jaringan tai mahalnya minta ampun
# 31    telkomsel ajggg ngeleg trus kartu ajggg sparing
# 33                                        sinyal taik
# 34                                                leg
# 35   noted thanks for sharing telkomsel the best f...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja gpp aku kasih ...
# 38  bukan tambah bagus semakin hari semakin buruk ...
# 39   guna gua main game lag parah memang telkom cacat
# 40                                          first min
# 54  kita laporkan dan konten gak ada gunanya sebag...
# 55  percuma kalo pertama kalo jaringan aja kaya si...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel byu pada kenapa nih kompensasi nya m...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59                indian how apply telkomsel sim card
# 60  hari ini masi sama ada kejelasan ngelag saat m...
# 61                                  beli subs dimana
# 86                                            pan tek
#
#                                            tokenisasi
# 0   [saya, kuota, beli, bukan, minta, apa, susahny...
# 1   [telkomsel, makin, sini, makin, parah, aja, ja...
# 2           [sama, tiba, tiba, sinyal, rumah, jadi, ]
# 3                                         [telkomsel]
# 4   [min, kenapa, ini, dari, kemaren, jaringan, an...
# 5   [gimana, indonesia, gak, rawan, covid, orang, ...
# 6       [telkomsel, itu, membangkrutkan, kamu, kecil]
# 19  [selamat, untuk, para, pemenang, semoga, menja...
# 20                [maju, terus, telkomsel, indonesia]
# 21                         [maju, terus, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24  [tai, kouta, malah, jaringan, kek, tai, kucing...
# 25                    [harga, tinggi, sinyal, rendah]
# 27  [mau, tanya, bang, nomer, simpati, saya, sudah...
# 28  [pindah, operator, aja, guys, gaguna, ini, kar...
# 29         [pakae, telkomsel, selalu, hilang, sinyal]
# 30          [jaringan, tai, mahalnya, minta, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, masa, aktifnya, harus,...
# 37  [bang, kalo, pen, duitku, bilang, aja, gpp, ak...
# 38  [bukan, tambah, bagus, semakin, hari, semakin,...
# 39  [, guna, gua, main, game, lag, parah, memang, ...
# 40                                       [first, min]
# 54  [kita, laporkan, dan, konten, gak, ada, gunany...
# 55  [percuma, kalo, pertama, kalo, jaringan, aja, ...
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, pada, kenapa, nih, kompensasi...
# 58  [kenapa, telkomsel, malam, lag, dan, siang, la...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [hari, ini, masi, sama, ada, kejelasan, ngelag...
# 61                             [beli, subs, dimana, ]
# 86                                         [pan, tek]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                               comment  \
# 0   saya kuota beli bukan minta , apa susahnya sih...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi h+
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang"nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang, semoga menjadi mo...
# 20                     maju terus telkomsel indonesia
# 21                            maju terus telkomsel 👍🏿
# 22                    terima kasih mba' tia hutami. 👍
# 23                             heran sinyal ga stabil
# 24  tai, kouta malah jaringan kek tai kucing, mend...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys,gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30              jaringan tai . mahalnya minta ampun .
# 31    telkomsel ajggg,ngeleg trus kartu ajggg,sparing
# 33                                        sinyal taik
# 34                                                leg
# 35  ok noted, thanks for sharing. telkomsel yo're ...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja , gpp aku kasi...
# 38  bukan tambah bagus, semakin hari semakin buruk...
# 39  ga guna gua main game lag parah memang telkom ...
# 40                                          first min
# 54  kita laporkan,dan konten gak ada gunanya, seba...
# 55  percuma kalo up 5g pertama kalo jaringan 4g aj...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel, byu , pada kenapa nih !? kompensasi...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59             indian how to apply telkomsel sim card
# 60  hari ini masi sama ga ada kejelasan. ngelag sa...
# 61                                  beli subs dimana?
# 86                                           pan  tek
#
#                                      cleaning_comment  \
# 0   saya kuota beli bukan minta apa susahnya sih m...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2                   sama tiba tiba sinyal rumah jadi
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang semoga menjadi mot...
# 20                     maju terus telkomsel indonesia
# 21                              maju terus telkomsel
# 22                       terima kasih mba tia hutami
# 23                                heran sinyal stabil
# 24  tai kouta malah jaringan kek tai kucing mendin...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30                 jaringan tai mahalnya minta ampun
# 31    telkomsel ajggg ngeleg trus kartu ajggg sparing
# 33                                        sinyal taik
# 34                                                leg
# 35   noted thanks for sharing telkomsel the best f...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja gpp aku kasih ...
# 38  bukan tambah bagus semakin hari semakin buruk ...
# 39   guna gua main game lag parah memang telkom cacat
# 40                                          first min
# 54  kita laporkan dan konten gak ada gunanya sebag...
# 55  percuma kalo pertama kalo jaringan aja kaya si...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel byu pada kenapa nih kompensasi nya m...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59                indian how apply telkomsel sim card
# 60  hari ini masi sama ada kejelasan ngelag saat m...
# 61                                  beli subs dimana
# 86                                            pan tek
#
#                                            tokenisasi  \
# 0   [saya, kuota, beli, bukan, minta, apa, susahny...
# 1   [telkomsel, makin, sini, makin, parah, aja, ja...
# 2           [sama, tiba, tiba, sinyal, rumah, jadi, ]
# 3                                         [telkomsel]
# 4   [min, kenapa, ini, dari, kemaren, jaringan, an...
# 5   [gimana, indonesia, gak, rawan, covid, orang, ...
# 6       [telkomsel, itu, membangkrutkan, kamu, kecil]
# 19  [selamat, untuk, para, pemenang, semoga, menja...
# 20                [maju, terus, telkomsel, indonesia]
# 21                         [maju, terus, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24  [tai, kouta, malah, jaringan, kek, tai, kucing...
# 25                    [harga, tinggi, sinyal, rendah]
# 27  [mau, tanya, bang, nomer, simpati, saya, sudah...
# 28  [pindah, operator, aja, guys, gaguna, ini, kar...
# 29         [pakae, telkomsel, selalu, hilang, sinyal]
# 30          [jaringan, tai, mahalnya, minta, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, masa, aktifnya, harus,...
# 37  [bang, kalo, pen, duitku, bilang, aja, gpp, ak...
# 38  [bukan, tambah, bagus, semakin, hari, semakin,...
# 39  [, guna, gua, main, game, lag, parah, memang, ...
# 40                                       [first, min]
# 54  [kita, laporkan, dan, konten, gak, ada, gunany...
# 55  [percuma, kalo, pertama, kalo, jaringan, aja, ...
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, pada, kenapa, nih, kompensasi...
# 58  [kenapa, telkomsel, malam, lag, dan, siang, la...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [hari, ini, masi, sama, ada, kejelasan, ngelag...
# 61                             [beli, subs, dimana, ]
# 86                                         [pan, tek]
#
#                                              stopword
# 0   [kuota, beli, susahnya, memperbaiki, koneksi, ...
# 1   [telkomsel, parah, jaringan, kacau, gara, jari...
# 2                                   [sinyal, rumah, ]
# 3                                         [telkomsel]
# 4         [min, kemaren, jaringan, ane, lancar, mulu]
# 5   [gimana, indonesia, rawan, covid, orang, cari,...
# 6                         [telkomsel, membangkrutkan]
# 19  [selamat, pemenang, semoga, motivasi, membangu...
# 20                       [maju, telkomsel, indonesia]
# 21                                [maju, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24          [kouta, jaringan, kek, kucing, mending, ]
# 25                            [harga, sinyal, rendah]
# 27  [bang, nomer, simpati, aktif, bln, aktifkan, m...
# 28  [pindah, operator, guys, gaguna, kartu, sinyal...
# 29                 [pakae, telkomsel, hilang, sinyal]
# 30                      [jaringan, mahalnya, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, aktifnya, ganti, kartu...
# 37  [bang, duitku, gpp, kasih, terima, kasihnya, j...
# 38       [bagus, buruk, bertambah, buruk, jaringan, ]
# 39     [, gua, main, game, lag, parah, telkom, cacat]
# 40                                       [first, min]
# 54  [laporkan, konten, gunanya, konten, menyesatka...
# 55           [jaringan, kaya, siput, ngak, betulin, ]
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, kompensasi, pelanggan, setia,...
# 58  [telkomsel, malam, lag, siang, lag, sore, lag,...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [masi, kejelasan, ngelag, main, game, promosi,...
# 61                             [beli, subs, dimana, ]
# 86                                         [pan, tek]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 141
# ------------------------
# kuota : kuota
# beli : beli
# susahnya : susah
# memperbaiki : baik
# koneksi : koneksi
# internet : internet
# telkomsel : telkomsel
# parah : parah
# jaringan : jaring
# kacau : kacau
# gara : gara
# sinyal : sinyal
# rumah : rumah
#  :
# min : min
# kemaren : kemaren
# ane : ane
# lancar : lancar
# mulu : mulu
# gimana : gimana
# indonesia : indonesia
# rawan : rawan
# covid : covid
# orang : orang
# cari : cari
# membangkrutkan : bangkrut
# selamat : selamat
# pemenang : menang
# semoga : moga
# motivasi : motivasi
# membangun : bangun
# maju : maju
# terima : terima
# kasih : kasih
# mba : mba
# tia : tia
# hutami : hutami
# heran : heran
# stabil : stabil
# kouta : kouta
# kek : kek
# kucing : kucing
# mending : mending
# harga : harga
# rendah : rendah
# bang : bang
# nomer : nomer
# simpati : simpati
# aktif : aktif
# bln : bln
# aktifkan : aktif
# mohon : mohon
# jawabanya : jawabanya
# pindah : pindah
# operator : operator
# guys : guys
# gaguna : gaguna
# kartu : kartu
# ilang : ilang
# pakae : pakae
# hilang : hilang
# mahalnya : mahal
# ampun : ampun
# ajggg : ajggg
# ngeleg : ngeleg
# trus : trus
# sparing : sparing
# taik : taik
# leg : leg
# noted : noted
# thanks : thanks
# for : for
# sharing : sharing
# the : the
# best : best
# customer : customer
# service : service
# signal : signal
# habis : habis
# aktifnya : aktif
# ganti : ganti
# halo : halo
# aneh : aneh
# maksa : maksa
# konsumen : konsumen
# duitku : duit
# gpp : gpp
# kasihnya : kasih
# jan : jan
# lag : lag
# bagus : bagus
# buruk : buruk
# bertambah : tambah
# gua : gua
# main : main
# game : game
# telkom : telkom
# cacat : cacat
# first : first
# laporkan : lapor
# konten : konten
# gunanya : guna
# menyesatkan : sesat
# setuju : tuju
# server : server
# kaya : kaya
# siput : siput
# ngak : ngak
# betulin : betulin
# assalamualaikum : assalamualaikum
# warahmatullahi : warahmatullahi
# wabarakatu : wabarakatu
# salam : salam
# sukses : sukses
# byu : byu
# kompensasi : kompensasi
# pelanggan : langgan
# setia : setia
# mengecewakan : kecewa
# malam : malam
# siang : siang
# sore : sore
# pelit : pelit
# indian : indian
# how : how
# apply : apply
# sim : sim
# card : card
# masi : mas
# kejelasan : jelas
# ngelag : ngelag
# promosi : promosi
# paket : paket
# doang : doang
# coba : coba
# perbaiki : baik
# abal : abal
# subs : subs
# dimana : mana
# pan : pan
# tek : tek
# {'kuota': 'kuota', 'beli': 'beli', 'susahnya': 'susah', 'memperbaiki': 'baik', 'koneksi': 'koneksi', 'internet': 'internet', 'telkomsel': 'telkomsel', 'parah': 'parah', 'jaringan': 'jaring', 'kacau': 'kacau', 'gara': 'gara', 'sinyal': 'sinyal', 'rumah': 'rumah', '': '', 'min': 'min', 'kemaren': 'kemaren', 'ane': 'ane', 'lancar': 'lancar', 'mulu': 'mulu', 'gimana': 'gimana', 'indonesia': 'indonesia', 'rawan': 'rawan', 'covid': 'covid', 'orang': 'orang', 'cari': 'cari', 'membangkrutkan': 'bangkrut', 'selamat': 'selamat', 'pemenang': 'menang', 'semoga': 'moga', 'motivasi': 'motivasi', 'membangun': 'bangun', 'maju': 'maju', 'terima': 'terima', 'kasih': 'kasih', 'mba': 'mba', 'tia': 'tia', 'hutami': 'hutami', 'heran': 'heran', 'stabil': 'stabil', 'kouta': 'kouta', 'kek': 'kek', 'kucing': 'kucing', 'mending': 'mending', 'harga': 'harga', 'rendah': 'rendah', 'bang': 'bang', 'nomer': 'nomer', 'simpati': 'simpati', 'aktif': 'aktif', 'bln': 'bln', 'aktifkan': 'aktif', 'mohon': 'mohon', 'jawabanya': 'jawabanya', 'pindah': 'pindah', 'operator': 'operator', 'guys': 'guys', 'gaguna': 'gaguna', 'kartu': 'kartu', 'ilang': 'ilang', 'pakae': 'pakae', 'hilang': 'hilang', 'mahalnya': 'mahal', 'ampun': 'ampun', 'ajggg': 'ajggg', 'ngeleg': 'ngeleg', 'trus': 'trus', 'sparing': 'sparing', 'taik': 'taik', 'leg': 'leg', 'noted': 'noted', 'thanks': 'thanks', 'for': 'for', 'sharing': 'sharing', 'the': 'the', 'best': 'best', 'customer': 'customer', 'service': 'service', 'signal': 'signal', 'habis': 'habis', 'aktifnya': 'aktif', 'ganti': 'ganti', 'halo': 'halo', 'aneh': 'aneh', 'maksa': 'maksa', 'konsumen': 'konsumen', 'duitku': 'duit', 'gpp': 'gpp', 'kasihnya': 'kasih', 'jan': 'jan', 'lag': 'lag', 'bagus': 'bagus', 'buruk': 'buruk', 'bertambah': 'tambah', 'gua': 'gua', 'main': 'main', 'game': 'game', 'telkom': 'telkom', 'cacat': 'cacat', 'first': 'first', 'laporkan': 'lapor', 'konten': 'konten', 'gunanya': 'guna', 'menyesatkan': 'sesat', 'setuju': 'tuju', 'server': 'server', 'kaya': 'kaya', 'siput': 'siput', 'ngak': 'ngak', 'betulin': 'betulin', 'assalamualaikum': 'assalamualaikum', 'warahmatullahi': 'warahmatullahi', 'wabarakatu': 'wabarakatu', 'salam': 'salam', 'sukses': 'sukses', 'byu': 'byu', 'kompensasi': 'kompensasi', 'pelanggan': 'langgan', 'setia': 'setia', 'mengecewakan': 'kecewa', 'malam': 'malam', 'siang': 'siang', 'sore': 'sore', 'pelit': 'pelit', 'indian': 'indian', 'how': 'how', 'apply': 'apply', 'sim': 'sim', 'card': 'card', 'masi': 'mas', 'kejelasan': 'jelas', 'ngelag': 'ngelag', 'promosi': 'promosi', 'paket': 'paket', 'doang': 'doang', 'coba': 'coba', 'perbaiki': 'baik', 'abal': 'abal', 'subs': 'subs', 'dimana': 'mana', 'pan': 'pan', 'tek': 'tek'}
# ------------------------
# Pandas Apply:   0%|          | 0/36 [00:00<?, ?it/s]
#                                               comment  \
# 0   saya kuota beli bukan minta , apa susahnya sih...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2           sama tiba tiba sinyal di rumah gw jadi h+
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang"nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang, semoga menjadi mo...
# 20                     maju terus telkomsel indonesia
# 21                            maju terus telkomsel 👍🏿
# 22                    terima kasih mba' tia hutami. 👍
# 23                             heran sinyal ga stabil
# 24  tai, kouta malah jaringan kek tai kucing, mend...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys,gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30              jaringan tai . mahalnya minta ampun .
# 31    telkomsel ajggg,ngeleg trus kartu ajggg,sparing
# 33                                        sinyal taik
# 34                                                leg
# 35  ok noted, thanks for sharing. telkomsel yo're ...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja , gpp aku kasi...
# 38  bukan tambah bagus, semakin hari semakin buruk...
# 39  ga guna gua main game lag parah memang telkom ...
# 40                                          first min
# 54  kita laporkan,dan konten gak ada gunanya, seba...
# 55  percuma kalo up 5g pertama kalo jaringan 4g aj...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel, byu , pada kenapa nih !? kompensasi...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59             indian how to apply telkomsel sim card
# 60  hari ini masi sama ga ada kejelasan. ngelag sa...
# 61                                  beli subs dimana?
# 86                                           pan  tek
#
#                                      cleaning_comment  \
# 0   saya kuota beli bukan minta apa susahnya sih m...
# 1   telkomsel makin sini makin parah aja jaringan ...
# 2                   sama tiba tiba sinyal rumah jadi
# 3                                           telkomsel
# 4   min kenapa ini dari kemaren jaringan ane gak l...
# 5   gimana indonesia gak rawan covid orang nya aja...
# 6             telkomsel itu membangkrutkan kamu kecil
# 19  selamat untuk para pemenang semoga menjadi mot...
# 20                     maju terus telkomsel indonesia
# 21                              maju terus telkomsel
# 22                       terima kasih mba tia hutami
# 23                                heran sinyal stabil
# 24  tai kouta malah jaringan kek tai kucing mendin...
# 25                         harga tinggi sinyal rendah
# 27  mau tanya bang nomer simpati saya sudah tidak ...
# 28  pindah operator aja guys gaguna ini kartu seka...
# 29               pakae telkomsel selalu hilang sinyal
# 30                 jaringan tai mahalnya minta ampun
# 31    telkomsel ajggg ngeleg trus kartu ajggg sparing
# 33                                        sinyal taik
# 34                                                leg
# 35   noted thanks for sharing telkomsel the best f...
# 36  kartu simpati habis masa aktifnya harus ganti ...
# 37  bang kalo pen duitku bilang aja gpp aku kasih ...
# 38  bukan tambah bagus semakin hari semakin buruk ...
# 39   guna gua main game lag parah memang telkom cacat
# 40                                          first min
# 54  kita laporkan dan konten gak ada gunanya sebag...
# 55  percuma kalo pertama kalo jaringan aja kaya si...
# 56  assalamualaikum warahmatullahi wabarakatu sala...
# 57  telkomsel byu pada kenapa nih kompensasi nya m...
# 58  kenapa telkomsel malam lag dan siang lag dan s...
# 59                indian how apply telkomsel sim card
# 60  hari ini masi sama ada kejelasan ngelag saat m...
# 61                                  beli subs dimana
# 86                                            pan tek
#
#                                            tokenisasi  \
# 0   [saya, kuota, beli, bukan, minta, apa, susahny...
# 1   [telkomsel, makin, sini, makin, parah, aja, ja...
# 2           [sama, tiba, tiba, sinyal, rumah, jadi, ]
# 3                                         [telkomsel]
# 4   [min, kenapa, ini, dari, kemaren, jaringan, an...
# 5   [gimana, indonesia, gak, rawan, covid, orang, ...
# 6       [telkomsel, itu, membangkrutkan, kamu, kecil]
# 19  [selamat, untuk, para, pemenang, semoga, menja...
# 20                [maju, terus, telkomsel, indonesia]
# 21                         [maju, terus, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24  [tai, kouta, malah, jaringan, kek, tai, kucing...
# 25                    [harga, tinggi, sinyal, rendah]
# 27  [mau, tanya, bang, nomer, simpati, saya, sudah...
# 28  [pindah, operator, aja, guys, gaguna, ini, kar...
# 29         [pakae, telkomsel, selalu, hilang, sinyal]
# 30          [jaringan, tai, mahalnya, minta, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, masa, aktifnya, harus,...
# 37  [bang, kalo, pen, duitku, bilang, aja, gpp, ak...
# 38  [bukan, tambah, bagus, semakin, hari, semakin,...
# 39  [, guna, gua, main, game, lag, parah, memang, ...
# 40                                       [first, min]
# 54  [kita, laporkan, dan, konten, gak, ada, gunany...
# 55  [percuma, kalo, pertama, kalo, jaringan, aja, ...
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, pada, kenapa, nih, kompensasi...
# 58  [kenapa, telkomsel, malam, lag, dan, siang, la...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [hari, ini, masi, sama, ada, kejelasan, ngelag...
# 61                             [beli, subs, dimana, ]
# 86                                         [pan, tek]
#
#                                              stopword  \
# 0   [kuota, beli, susahnya, memperbaiki, koneksi, ...
# 1   [telkomsel, parah, jaringan, kacau, gara, jari...
# 2                                   [sinyal, rumah, ]
# 3                                         [telkomsel]
# 4         [min, kemaren, jaringan, ane, lancar, mulu]
# 5   [gimana, indonesia, rawan, covid, orang, cari,...
# 6                         [telkomsel, membangkrutkan]
# 19  [selamat, pemenang, semoga, motivasi, membangu...
# 20                       [maju, telkomsel, indonesia]
# 21                                [maju, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24          [kouta, jaringan, kek, kucing, mending, ]
# 25                            [harga, sinyal, rendah]
# 27  [bang, nomer, simpati, aktif, bln, aktifkan, m...
# 28  [pindah, operator, guys, gaguna, kartu, sinyal...
# 29                 [pakae, telkomsel, hilang, sinyal]
# 30                      [jaringan, mahalnya, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, aktifnya, ganti, kartu...
# 37  [bang, duitku, gpp, kasih, terima, kasihnya, j...
# 38       [bagus, buruk, bertambah, buruk, jaringan, ]
# 39     [, gua, main, game, lag, parah, telkom, cacat]
# 40                                       [first, min]
# 54  [laporkan, konten, gunanya, konten, menyesatka...
# 55           [jaringan, kaya, siput, ngak, betulin, ]
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, kompensasi, pelanggan, setia,...
# 58  [telkomsel, malam, lag, siang, lag, sore, lag,...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [masi, kejelasan, ngelag, main, game, promosi,...
# 61                             [beli, subs, dimana, ]
# 86                                         [pan, tek]
#
#                                              stemming
# 0       [kuota, beli, susah, baik, koneksi, internet]
# 1     [telkomsel, parah, jaring, kacau, gara, jaring]
# 2                                   [sinyal, rumah, ]
# 3                                         [telkomsel]
# 4           [min, kemaren, jaring, ane, lancar, mulu]
# 5   [gimana, indonesia, rawan, covid, orang, cari,...
# 6                               [telkomsel, bangkrut]
# 19  [selamat, menang, moga, motivasi, bangun, indo...
# 20                       [maju, telkomsel, indonesia]
# 21                                [maju, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24            [kouta, jaring, kek, kucing, mending, ]
# 25                            [harga, sinyal, rendah]
# 27  [bang, nomer, simpati, aktif, bln, aktif, moho...
# 28  [pindah, operator, guys, gaguna, kartu, sinyal...
# 29                 [pakae, telkomsel, hilang, sinyal]
# 30                           [jaring, mahal, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, aktif, ganti, kartu, h...
# 37  [bang, duit, gpp, kasih, terima, kasih, jan, k...
# 38            [bagus, buruk, tambah, buruk, jaring, ]
# 39     [, gua, main, game, lag, parah, telkom, cacat]
# 40                                       [first, min]
# 54  [lapor, konten, guna, konten, sesat, tuju, ser...
# 55             [jaring, kaya, siput, ngak, betulin, ]
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, kompensasi, langgan, setia, k...
# 58  [telkomsel, malam, lag, siang, lag, sore, lag,...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [mas, jelas, ngelag, main, game, promosi, pake...
# 61                               [beli, subs, mana, ]
# 86                                         [pan, tek]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                              Comments
# 0       [kuota, beli, susah, baik, koneksi, internet]
# 1     [telkomsel, parah, jaring, kacau, gara, jaring]
# 2                                   [sinyal, rumah, ]
# 3                                         [telkomsel]
# 4           [min, kemaren, jaring, ane, lancar, mulu]
# 5   [gimana, indonesia, rawan, covid, orang, cari,...
# 6                               [telkomsel, bangkrut]
# 19  [selamat, menang, moga, motivasi, bangun, indo...
# 20                       [maju, telkomsel, indonesia]
# 21                                [maju, telkomsel, ]
# 22                [terima, kasih, mba, tia, hutami, ]
# 23                            [heran, sinyal, stabil]
# 24            [kouta, jaring, kek, kucing, mending, ]
# 25                            [harga, sinyal, rendah]
# 27  [bang, nomer, simpati, aktif, bln, aktif, moho...
# 28  [pindah, operator, guys, gaguna, kartu, sinyal...
# 29                 [pakae, telkomsel, hilang, sinyal]
# 30                           [jaring, mahal, ampun, ]
# 31  [telkomsel, ajggg, ngeleg, trus, kartu, ajggg,...
# 33                                     [sinyal, taik]
# 34                                              [leg]
# 35  [, noted, thanks, for, sharing, telkomsel, the...
# 36  [kartu, simpati, habis, aktif, ganti, kartu, h...
# 37  [bang, duit, gpp, kasih, terima, kasih, jan, k...
# 38            [bagus, buruk, tambah, buruk, jaring, ]
# 39     [, gua, main, game, lag, parah, telkom, cacat]
# 40                                       [first, min]
# 54  [lapor, konten, guna, konten, sesat, tuju, ser...
# 55             [jaring, kaya, siput, ngak, betulin, ]
# 56  [assalamualaikum, warahmatullahi, wabarakatu, ...
# 57  [telkomsel, byu, kompensasi, langgan, setia, k...
# 58  [telkomsel, malam, lag, siang, lag, sore, lag,...
# 59         [indian, how, apply, telkomsel, sim, card]
# 60  [mas, jelas, ngelag, main, game, promosi, pake...
# 61                               [beli, subs, mana, ]
# 86                                         [pan, tek]

# %%
Final.to_excel('databersih_youtube_telkomsel_9.xlsx')
