# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    inyal 5G tapi berasa 2G , sinyal axis xl dan p...
# 1    Mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        Nyimak kk biar ga gagal faham
# 3    Benerin dulu sinyalnya lah, daerah Cengkareng ...
# 4                             Kartu ga jls ko di pake.
# ..                                                 ...
# 225              Asw makn hari makin gk jls sinyal nya
# 226           Promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             BANGKE
# 229  Mantap telkomesel semoga bisa kolaborasi sama ...
#
# [230 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 67

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    inyal 5G tapi berasa 2G , sinyal axis xl dan p...
# 1    Mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        Nyimak kk biar ga gagal faham
# 3    Benerin dulu sinyalnya lah, daerah Cengkareng ...
# 4                             Kartu ga jls ko di pake.
# ..                                                 ...
# 225              Asw makn hari makin gk jls sinyal nya
# 226           Promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             BANGKE
# 229  Mantap telkomesel semoga bisa kolaborasi sama ...
#
# [96 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    inyal 5g tapi berasa 2g , sinyal axis xl dan p...
# 1    mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        nyimak kk biar ga gagal faham
# 3    benerin dulu sinyalnya lah, daerah cengkareng ...
# 4                             kartu ga jls ko di pake.
# ..                                                 ...
# 225              asw makn hari makin gk jls sinyal nya
# 226           promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
# [96 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    inyal 5g tapi berasa 2g , sinyal axis xl dan p...
# 1    mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        nyimak kk biar ga gagal faham
# 3    benerin dulu sinyalnya lah, daerah cengkareng ...
# 4                             kartu ga jls ko di pake.
# ..                                                 ...
# 225              asw makn hari makin gk jls sinyal nya
# 226           promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                       cleaning_comment
# 0    inyal tapi berasa sinyal axis dan provider lai...
# 1    mohon kepada pihak telkomsel ini knp paket gam...
# 2                              nyimak biar gagal faham
# 3    benerin dulu sinyalnya lah daerah cengkareng j...
# 4                                      kartu jls pake
# ..                                                 ...
# 225                 asw makn hari makin jls sinyal nya
# 226                      promos tapi sama tidak bagus
# 227                                      jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
# [96 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    inyal 5g tapi berasa 2g , sinyal axis xl dan p...
# 1    mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        nyimak kk biar ga gagal faham
# 3    benerin dulu sinyalnya lah, daerah cengkareng ...
# 4                             kartu ga jls ko di pake.
# ..                                                 ...
# 225              asw makn hari makin gk jls sinyal nya
# 226           promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                       cleaning_comment  \
# 0    inyal tapi berasa sinyal axis dan provider lai...
# 1    mohon kepada pihak telkomsel ini knp paket gam...
# 2                              nyimak biar gagal faham
# 3    benerin dulu sinyalnya lah daerah cengkareng j...
# 4                                      kartu jls pake
# ..                                                 ...
# 225                 asw makn hari makin jls sinyal nya
# 226                      promos tapi sama tidak bagus
# 227                                      jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                             tokenisasi
# 0    [inyal, tapi, berasa, sinyal, axis, dan, provi...
# 1    [mohon, kepada, pihak, telkomsel, ini, knp, pa...
# 2                         [nyimak, biar, gagal, faham]
# 3    [benerin, dulu, sinyalnya, lah, daerah, cengka...
# 4                                 [kartu, jls, pake, ]
# ..                                                 ...
# 225         [asw, makn, hari, makin, jls, sinyal, nya]
# 226               [promos, tapi, sama, tidak, bagus, ]
# 227                                [, jam, yang, lalu]
# 228                                           [bangke]
# 229  [mantap, telkomesel, semoga, bisa, kolaborasi,...
#
# [96 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    inyal 5g tapi berasa 2g , sinyal axis xl dan p...
# 1    mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        nyimak kk biar ga gagal faham
# 3    benerin dulu sinyalnya lah, daerah cengkareng ...
# 4                             kartu ga jls ko di pake.
# ..                                                 ...
# 225              asw makn hari makin gk jls sinyal nya
# 226           promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                       cleaning_comment  \
# 0    inyal tapi berasa sinyal axis dan provider lai...
# 1    mohon kepada pihak telkomsel ini knp paket gam...
# 2                              nyimak biar gagal faham
# 3    benerin dulu sinyalnya lah daerah cengkareng j...
# 4                                      kartu jls pake
# ..                                                 ...
# 225                 asw makn hari makin jls sinyal nya
# 226                      promos tapi sama tidak bagus
# 227                                      jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                             tokenisasi  \
# 0    [inyal, tapi, berasa, sinyal, axis, dan, provi...
# 1    [mohon, kepada, pihak, telkomsel, ini, knp, pa...
# 2                         [nyimak, biar, gagal, faham]
# 3    [benerin, dulu, sinyalnya, lah, daerah, cengka...
# 4                                 [kartu, jls, pake, ]
# ..                                                 ...
# 225         [asw, makn, hari, makin, jls, sinyal, nya]
# 226               [promos, tapi, sama, tidak, bagus, ]
# 227                                [, jam, yang, lalu]
# 228                                           [bangke]
# 229  [mantap, telkomesel, semoga, bisa, kolaborasi,...
#
#                                               stopword
# 0    [inyal, berasa, sinyal, axis, provider, telkom...
# 1    [mohon, telkomsel, knp, paket, game, nggak, pa...
# 2                               [nyimak, gagal, faham]
# 3    [benerin, sinyalnya, daerah, cengkareng, jakar...
# 4                                       [kartu, jls, ]
# ..                                                 ...
# 225                           [asw, makn, jls, sinyal]
# 226                                  [promos, bagus, ]
# 227                                            [, jam]
# 228                                           [bangke]
# 229  [mantap, telkomesel, semoga, kolaborasi, cloud...
#
# [96 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 331
# ------------------------
# inyal : inyal
# berasa : asa
# sinyal : sinyal
# axis : axis
# provider : provider
# telkomsel : telkomsel
# kualitas : kualitas
# udah : udah
# melapor : lapor
# jaringan : jaring
# gubris : gubris
# kecewa : kecewa
# sekelas : kelas
# bumn : bumn
# kalah : kalah
# swasta : swasta
# mohon : mohon
# knp : knp
# paket : paket
# game : game
# nggak : nggak
# pakai : pakai
# diperbaiki : baik
# nyimak : nyimak
# gagal : gagal
# faham : faham
# benerin : benerin
# sinyalnya : sinyal
# daerah : daerah
# cengkareng : cengkareng
# jakarta : jakarta
# barat : barat
# susah : susah
# parah : parah
# kartu : kartu
# jls : jls
#  :
# heran : heran
# subscribe : subscribe
# chanel : chanel
# bisanya : bisa
# subs : subs
# tolong : tolong
# matikan : mati
# ponsel : ponsel
# lari : lari
# bentar : bentar
# pertahankan : tahan
# edge : edge
# pengguna : guna
# feature : feature
# phone : phone
# perluas : luas
# bagus : bagus
# layanan : layan
# teknologi : teknologi
# indonesia : indonesia
# tower : tower
# box : box
# pasang : pasang
# tiang : tiang
# listrik : listrik
# kabel : kabel
# praktis : praktis
# kecepatan : cepat
# streaming : streaming
# youtube : youtube
# facebook : facebook
# hadir : hadir
# diwilayah : wilayah
# tinggal : tinggal
# hancur : hancur
# kel : kel
# fatukoa : fatukoa
# ntt : ntt
# jaringanya : jaringanya
# kacau : kacau
# buru : buru
# emang : emang
# persaingan : saing
# ancur : ancur
# pelanggan : langgan
# kabur : kabur
# rugi : rugi
# gedeg : gedeg
# ampun : ampun
# napa : napa
# jalan : jalan
# band : band
# doang : doang
# device : device
# ready : ready
# gapunya : gapunya
# mending : mending
# sebelah : belah
# dinikmati : nikmat
# ping : ping
# urusin : urusin
# iya : iya
# sinya : sinya
# setabil : setabil
# ilang : ilang
# nelpon : nelpon
# butuh : butuh
# kuota : kuota
# chat : chat
# unlimited : unlimited
# murah : murah
# titik : titik
# wafi : wafi
# nomor : nomor
# masuk : masuk
# coba : coba
# wilayah : wilayah
# pondok : pondok
# indah : indah
# smart : smart
# office : office
# info : info
# sales : sales
# ush : ush
# kasi : kasi
# stabil : stabil
# main : main
# oiiii : oiiii
# jumping : jumping
# mulu : mulu
# pertamax : pertamax
# beres : beres
# jaringannya : jaring
# msih : msih
# lelet : lelet
# bro : bro
# preetttt : preetttt
# semangat : semangat
# perusahaan : usaha
# bangsa : bangsa
# salam : salam
# purwakarta : purwakarta
# sukses : sukses
# maju : maju
# mantap : mantap
# inovatif : inovatif
# mah : mah
# berharap : harap
# data : data
# membeli : beli
# prabayar : prabayar
# bocor : bocor
# harga : harga
# paketnya : paket
# dikondisikan : kondisi
# ngarep : ngarep
# blokir : blokir
# sms : sms
# penipuan : tipu
# gebyar : gebyar
# duit : duit
# ghoib : ghoib
# dll : dll
# akhlak : akhlak
# suka : suka
# telkom : telkom
# anti : anti
# lag : lag
# ilangin : ilangin
# fup : fup
# balikin : balikin
# sesungguhnya : sungguh
# jungasuuu : jungasuuu
# keren : keren
# diskriminasi : diskriminasi
# gue : gue
# ngelag : ngelag
# underated : underated
# internet : internet
# ngeleg : ngeleg
# ajg : ajg
# speednya : speednya
# menurun : turun
# beli : beli
# plis : plis
# kota : kota
# lirik : lirik
# menunggu : tunggu
# komisaris : komisaris
# abdee : abdee
# signal : signal
# khusus : khusus
# provinsi : provinsi
# jambi : jambi
# macet : macet
# brpa : brpa
# perbaikan : baik
# hadirrrr : hadirrrr
# skrng : skrng
# dibatasi : batas
# unlimitednya : unlimitednya
# ohh : ohh
# nyesel : nyesel
# kek : kek
# emosi : emosi
# prei : prei
# tros : tros
# kon : kon
# ngen : ngen
# ngelek : ngelek
# kayak : kayak
# indihome : indihome
# perbaiki : baik
# tlol : tlol
# gaenak : gaenak
# zona : zona
# isi : isi
# kouta : kouta
# woi : woi
# ccd : ccd
# sorry : sorry
# better : better
# taik : taik
# palabuhan : palabuhan
# ratu : ratu
# sukabumi : sukabumi
# komtol : komtol
# mwemwekkkk : mwemwekkkk
# bukanya : buka
# kucing : kucing
# ngprank : ngprank
# vidio : vidio
# kak : kak
# nonton : nonton
# vidionya : vidionya
# doakan : doa
# rezeky : rezeky
# lancar : lancar
# sehat : sehat
# aamiin : aamiin
# selangit : langit
# asw : asw
# salamualaikm : salamualaikm
# wrwb : wrwb
# kauuu : kauuu
# kambeeeeeeeng : kambeeeeeeeng
# sesuai : sesuai
# gaes : gaes
# setara : tara
# ngrasin : ngrasin
# real : real
# diluar : luar
# terima : terima
# kasih : kasih
# setia : setia
# berterima : terima
# kas : kas
# terdepannya : depan
# tingkatkan : tingkat
# pelayanannya : layan
# kemajuan : maju
# tanah : tanah
# air : air
# jaya : jaya
# ngilang : ngilang
# maximalkan : maximalkan
# ikutan : ikut
# done : done
# politik : politik
# hadehh : hadehh
# cuman : cuman
# gede : gede
# ampas : ampas
# mimpi : mimpi
# negara : negara
# nyedot : nyedot
# pulsa : pulsa
# paksa : paksa
# langganan : langgan
# diary : diary
# rezky : rezky
# aditya : aditya
# potong : potong
# scr : scr
# gua : gua
# sehari : hari
# sisa : sisa
# ngeluarin : ngeluarin
# makek : makek
# sampah : sampah
# gimana : gimana
# rugikan : rugi
# hack : hack
# cepet : cepet
# the : the
# tiana : tiana
# hutami : hutami
# sok : sok
# benrin : benrin
# noh : noh
# dihati : hati
# tri : tri
# hiri : hiri
# combo : combo
# sakti : sakti
# unlimitid : unlimitid
# nge : nge
# gaaaa : gaaaa
# jdi : jdi
# karuan : karuan
# cuy : cuy
# jaringanmu : jaring
# genakno : genakno
# sek : sek
# onok : onok
# udan : udan
# mro : mro
# kryawanmu : kryawanmu
# bosen : bosen
# krjo : krjo
# makn : makn
# promos : promos
# jam : jam
# bangke : bangke
# telkomesel : telkomesel
# semoga : moga
# kolaborasi : kolaborasi
# cloud : cloud
# gaming : gaming
# xbox : xbox
# pass : pass
# google : google
# stadia : stadia
# gforcenow : gforcenow
# {'inyal': 'inyal', 'berasa': 'asa', 'sinyal': 'sinyal', 'axis': 'axis', 'provider': 'provider', 'telkomsel': 'telkomsel', 'kualitas': 'kualitas', 'udah': 'udah', 'melapor': 'lapor', 'jaringan': 'jaring', 'gubris': 'gubris', 'kecewa': 'kecewa', 'sekelas': 'kelas', 'bumn': 'bumn', 'kalah': 'kalah', 'swasta': 'swasta', 'mohon': 'mohon', 'knp': 'knp', 'paket': 'paket', 'game': 'game', 'nggak': 'nggak', 'pakai': 'pakai', 'diperbaiki': 'baik', 'nyimak': 'nyimak', 'gagal': 'gagal', 'faham': 'faham', 'benerin': 'benerin', 'sinyalnya': 'sinyal', 'daerah': 'daerah', 'cengkareng': 'cengkareng', 'jakarta': 'jakarta', 'barat': 'barat', 'susah': 'susah', 'parah': 'parah', 'kartu': 'kartu', 'jls': 'jls', '': '', 'heran': 'heran', 'subscribe': 'subscribe', 'chanel': 'chanel', 'bisanya': 'bisa', 'subs': 'subs', 'tolong': 'tolong', 'matikan': 'mati', 'ponsel': 'ponsel', 'lari': 'lari', 'bentar': 'bentar', 'pertahankan': 'tahan', 'edge': 'edge', 'pengguna': 'guna', 'feature': 'feature', 'phone': 'phone', 'perluas': 'luas', 'bagus': 'bagus', 'layanan': 'layan', 'teknologi': 'teknologi', 'indonesia': 'indonesia', 'tower': 'tower', 'box': 'box', 'pasang': 'pasang', 'tiang': 'tiang', 'listrik': 'listrik', 'kabel': 'kabel', 'praktis': 'praktis', 'kecepatan': 'cepat', 'streaming': 'streaming', 'youtube': 'youtube', 'facebook': 'facebook', 'hadir': 'hadir', 'diwilayah': 'wilayah', 'tinggal': 'tinggal', 'hancur': 'hancur', 'kel': 'kel', 'fatukoa': 'fatukoa', 'ntt': 'ntt', 'jaringanya': 'jaringanya', 'kacau': 'kacau', 'buru': 'buru', 'emang': 'emang', 'persaingan': 'saing', 'ancur': 'ancur', 'pelanggan': 'langgan', 'kabur': 'kabur', 'rugi': 'rugi', 'gedeg': 'gedeg', 'ampun': 'ampun', 'napa': 'napa', 'jalan': 'jalan', 'band': 'band', 'doang': 'doang', 'device': 'device', 'ready': 'ready', 'gapunya': 'gapunya', 'mending': 'mending', 'sebelah': 'belah', 'dinikmati': 'nikmat', 'ping': 'ping', 'urusin': 'urusin', 'iya': 'iya', 'sinya': 'sinya', 'setabil': 'setabil', 'ilang': 'ilang', 'nelpon': 'nelpon', 'butuh': 'butuh', 'kuota': 'kuota', 'chat': 'chat', 'unlimited': 'unlimited', 'murah': 'murah', 'titik': 'titik', 'wafi': 'wafi', 'nomor': 'nomor', 'masuk': 'masuk', 'coba': 'coba', 'wilayah': 'wilayah', 'pondok': 'pondok', 'indah': 'indah', 'smart': 'smart', 'office': 'office', 'info': 'info', 'sales': 'sales', 'ush': 'ush', 'kasi': 'kasi', 'stabil': 'stabil', 'main': 'main', 'oiiii': 'oiiii', 'jumping': 'jumping', 'mulu': 'mulu', 'pertamax': 'pertamax', 'beres': 'beres', 'jaringannya': 'jaring', 'msih': 'msih', 'lelet': 'lelet', 'bro': 'bro', 'preetttt': 'preetttt', 'semangat': 'semangat', 'perusahaan': 'usaha', 'bangsa': 'bangsa', 'salam': 'salam', 'purwakarta': 'purwakarta', 'sukses': 'sukses', 'maju': 'maju', 'mantap': 'mantap', 'inovatif': 'inovatif', 'mah': 'mah', 'berharap': 'harap', 'data': 'data', 'membeli': 'beli', 'prabayar': 'prabayar', 'bocor': 'bocor', 'harga': 'harga', 'paketnya': 'paket', 'dikondisikan': 'kondisi', 'ngarep': 'ngarep', 'blokir': 'blokir', 'sms': 'sms', 'penipuan': 'tipu', 'gebyar': 'gebyar', 'duit': 'duit', 'ghoib': 'ghoib', 'dll': 'dll', 'akhlak': 'akhlak', 'suka': 'suka', 'telkom': 'telkom', 'anti': 'anti', 'lag': 'lag', 'ilangin': 'ilangin', 'fup': 'fup', 'balikin': 'balikin', 'sesungguhnya': 'sungguh', 'jungasuuu': 'jungasuuu', 'keren': 'keren', 'diskriminasi': 'diskriminasi', 'gue': 'gue', 'ngelag': 'ngelag', 'underated': 'underated', 'internet': 'internet', 'ngeleg': 'ngeleg', 'ajg': 'ajg', 'speednya': 'speednya', 'menurun': 'turun', 'beli': 'beli', 'plis': 'plis', 'kota': 'kota', 'lirik': 'lirik', 'menunggu': 'tunggu', 'komisaris': 'komisaris', 'abdee': 'abdee', 'signal': 'signal', 'khusus': 'khusus', 'provinsi': 'provinsi', 'jambi': 'jambi', 'macet': 'macet', 'brpa': 'brpa', 'perbaikan': 'baik', 'hadirrrr': 'hadirrrr', 'skrng': 'skrng', 'dibatasi': 'batas', 'unlimitednya': 'unlimitednya', 'ohh': 'ohh', 'nyesel': 'nyesel', 'kek': 'kek', 'emosi': 'emosi', 'prei': 'prei', 'tros': 'tros', 'kon': 'kon', 'ngen': 'ngen', 'ngel ...
# ------------------------
# Pandas Apply:   0%|          | 0/96 [00:00<?, ?it/s]
#                                                comment  \
# 0    inyal 5g tapi berasa 2g , sinyal axis xl dan p...
# 1    mohon kepada pihak telkomsel, ini knp paket ga...
# 2                        nyimak kk biar ga gagal faham
# 3    benerin dulu sinyalnya lah, daerah cengkareng ...
# 4                             kartu ga jls ko di pake.
# ..                                                 ...
# 225              asw makn hari makin gk jls sinyal nya
# 226           promos ni tapi sama aj tidak bagus 💩💩💩💩💩
# 227                                    1 jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                       cleaning_comment  \
# 0    inyal tapi berasa sinyal axis dan provider lai...
# 1    mohon kepada pihak telkomsel ini knp paket gam...
# 2                              nyimak biar gagal faham
# 3    benerin dulu sinyalnya lah daerah cengkareng j...
# 4                                      kartu jls pake
# ..                                                 ...
# 225                 asw makn hari makin jls sinyal nya
# 226                      promos tapi sama tidak bagus
# 227                                      jam yang lalu
# 228                                             bangke
# 229  mantap telkomesel semoga bisa kolaborasi sama ...
#
#                                             tokenisasi  \
# 0    [inyal, tapi, berasa, sinyal, axis, dan, provi...
# 1    [mohon, kepada, pihak, telkomsel, ini, knp, pa...
# 2                         [nyimak, biar, gagal, faham]
# 3    [benerin, dulu, sinyalnya, lah, daerah, cengka...
# 4                                 [kartu, jls, pake, ]
# ..                                                 ...
# 225         [asw, makn, hari, makin, jls, sinyal, nya]
# 226               [promos, tapi, sama, tidak, bagus, ]
# 227                                [, jam, yang, lalu]
# 228                                           [bangke]
# 229  [mantap, telkomesel, semoga, bisa, kolaborasi,...
#
#                                               stopword  \
# 0    [inyal, berasa, sinyal, axis, provider, telkom...
# 1    [mohon, telkomsel, knp, paket, game, nggak, pa...
# 2                               [nyimak, gagal, faham]
# 3    [benerin, sinyalnya, daerah, cengkareng, jakar...
# 4                                       [kartu, jls, ]
# ..                                                 ...
# 225                           [asw, makn, jls, sinyal]
# 226                                  [promos, bagus, ]
# 227                                            [, jam]
# 228                                           [bangke]
# 229  [mantap, telkomesel, semoga, kolaborasi, cloud...
#
#                                               stemming
# 0    [inyal, asa, sinyal, axis, provider, telkomsel...
# 1    [mohon, telkomsel, knp, paket, game, nggak, pa...
# 2                               [nyimak, gagal, faham]
# 3    [benerin, sinyal, daerah, cengkareng, jakarta,...
# 4                                       [kartu, jls, ]
# ..                                                 ...
# 225                           [asw, makn, jls, sinyal]
# 226                                  [promos, bagus, ]
# 227                                            [, jam]
# 228                                           [bangke]
# 229  [mantap, telkomesel, moga, kolaborasi, cloud, ...
#
# [96 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [inyal, asa, sinyal, axis, provider, telkomsel...
# 1    [mohon, telkomsel, knp, paket, game, nggak, pa...
# 2                               [nyimak, gagal, faham]
# 3    [benerin, sinyal, daerah, cengkareng, jakarta,...
# 4                                       [kartu, jls, ]
# ..                                                 ...
# 225                           [asw, makn, jls, sinyal]
# 226                                  [promos, bagus, ]
# 227                                            [, jam]
# 228                                           [bangke]
# 229  [mantap, telkomesel, moga, kolaborasi, cloud, ...
#
# [96 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_6.xlsx')
