# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Alhamdulillah bisa saling berbagi semangat Tel...
# 1    Tolong kami sangat butuh respon dari pihak tel...
# 2                                      Salam toleransi
# 3    Kenapa Jaringan Internet Telkomsel sangat2 sem...
# 4    Saya menggunakan Telkomsel saya menyesal karna...
# ..                                                 ...
# 200  Hanya beda ruangan beberapa meter aja udah nge...
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   TELKOMSEL NGELAG
# 204  Assalamualaikum saya pengguna telkomsel,knp se...
#
# [205 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 52

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Alhamdulillah bisa saling berbagi semangat Tel...
# 1    Tolong kami sangat butuh respon dari pihak tel...
# 2                                      Salam toleransi
# 3    Kenapa Jaringan Internet Telkomsel sangat2 sem...
# 4    Saya menggunakan Telkomsel saya menyesal karna...
# ..                                                 ...
# 178      4G AJA TEST SPEED CUMA MENTOK 75-100 KB/PS???
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   TELKOMSEL NGELAG
# 204  Assalamualaikum saya pengguna telkomsel,knp se...
#
# [101 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat2 sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178      4g aja test speed cuma mentok 75-100 kb/ps???
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel,knp se...
#
# [101 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat2 sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178      4g aja test speed cuma mentok 75-100 kb/ps???
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel,knp se...
#
#                                       cleaning_comment
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat  sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178                      aja test speed cuma mentok
# 201                    jaringan kab pekalongan hancur
# 202                 parahhhhhhhhhhh banget signal nya
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel knp se...
#
# [101 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat2 sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178      4g aja test speed cuma mentok 75-100 kb/ps???
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel,knp se...
#
#                                       cleaning_comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat  sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178                      aja test speed cuma mentok
# 201                    jaringan kab pekalongan hancur
# 202                 parahhhhhhhhhhh banget signal nya
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel knp se...
#
#                                             tokenisasi
# 0    [alhamdulillah, bisa, saling, berbagi, semanga...
# 1    [tolong, kami, sangat, butuh, respon, dari, pi...
# 2                                   [salam, toleransi]
# 3    [kenapa, jaringan, internet, telkomsel, sangat...
# 4    [saya, menggunakan, telkomsel, saya, menyesal,...
# ..                                                 ...
# 178               [, aja, test, speed, cuma, mentok, ]
# 201              [jaringan, kab, pekalongan, hancur, ]
# 202           [parahhhhhhhhhhh, banget, signal, nya, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, saya, pengguna, telkomsel, k...
#
# [101 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat2 sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178      4g aja test speed cuma mentok 75-100 kb/ps???
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel,knp se...
#
#                                       cleaning_comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat  sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178                      aja test speed cuma mentok
# 201                    jaringan kab pekalongan hancur
# 202                 parahhhhhhhhhhh banget signal nya
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel knp se...
#
#                                             tokenisasi  \
# 0    [alhamdulillah, bisa, saling, berbagi, semanga...
# 1    [tolong, kami, sangat, butuh, respon, dari, pi...
# 2                                   [salam, toleransi]
# 3    [kenapa, jaringan, internet, telkomsel, sangat...
# 4    [saya, menggunakan, telkomsel, saya, menyesal,...
# ..                                                 ...
# 178               [, aja, test, speed, cuma, mentok, ]
# 201              [jaringan, kab, pekalongan, hancur, ]
# 202           [parahhhhhhhhhhh, banget, signal, nya, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, saya, pengguna, telkomsel, k...
#
#                                               stopword
# 0      [alhamdulillah, berbagi, semangat, telkomsel, ]
# 1    [tolong, butuh, respon, telkomsel, trjadi, kal...
# 2                                   [salam, toleransi]
# 3    [jaringan, internet, telkomsel, buruk, wilayah...
# 4    [telkomsel, menyesal, karna, membeli, kouta, t...
# ..                                                 ...
# 178                          [, test, speed, mentok, ]
# 201              [jaringan, kab, pekalongan, hancur, ]
# 202                [parahhhhhhhhhhh, banget, signal, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, pengguna, telkomsel, knp, te...
#
# [101 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 389
# ------------------------
# alhamdulillah : alhamdulillah
# berbagi : bagi
# semangat : semangat
# telkomsel : telkomsel
#  :
# tolong : tolong
# butuh : butuh
# respon : respon
# trjadi : trjadi
# kaltim : kaltim
# kukar : kukar
# kec : kec
# kenohan : kenohan
# kadang : kadang
# nelpon : nelpon
# sms : sms
# lgi : lgi
# internet : internet
# kdang : kdang
# internetnya : internetnya
# bermasalah : masalah
# kasian : kasi
# jual : jual
# online : online
# perbaikkan : baik
# tlong : tlong
# info : info
# kebingungan : bingung
# salam : salam
# toleransi : toleransi
# jaringan : jaring
# buruk : buruk
# wilayah : wilayah
# muara : muara
# enim : enim
# prabumulih : prabumulih
# tepatnya : tepat
# rambang : rambang
# niru : niru
# harga : harga
# paket : paket
# selangit : langit
# kualitas : kualitas
# jaringannya : jaring
# jongkok : jongkok
# perbaiki : baik
# daerah : daerah
# menyesal : sesal
# karna : karna
# membeli : beli
# kouta : kouta
# tpi : tpi
# udh : udh
# habis : habis
# ketahui : tahu
# dipakek : dipakek
# enga : enga
# lelet : lelet
# kaya : kaya
# sea : sea
# food : food
# merry : merry
# christmas : christmas
# best : best
# friend : friend
# provider : provider
# emang : emang
# binatang : binatang
# udah : udah
# macet : macet
# tungguin : tungguin
# blm : blm
# lancar : lancar
# woy : woy
# sesabar : sabar
# sabarnya : sabar
# org : org
# lag : lag
# abs : abs
# kesabarannya : sabar
# ganti : ganti
# kartu : kartu
# beneran : beneran
# operator : operator
# jamin : jamin
# joss : joss
# sinyal : sinyal
# tsel : tsel
# setahun : tahun
# full : full
# hilang : hilang
# ambil : ambil
# keuntungan : untung
# coba : coba
# mutu : mutu
# layanan : layan
# pastikan : pasti
# tehnisi : tehnisi
# berpengalaman : alam
# ahli : ahli
# bidangnya : bidang
# gangguan : ganggu
# musim : musim
# hujan : hujan
# klarifikasi : klarifikasi
# keluhan : keluh
# pelanggan : langgan
# terhormat : hormat
# emosi : emosi
# membara : bara
# wibu : wibu
# berkekuatan : kuat
# power : power
# pakailah : pakai
# telkomlegg : telkomlegg
# main : main
# game : game
# disconnected : disconnected
# nonton : nonton
# film : film
# resolusi : resolusi
# buffering : buffering
# fokus : fokus
# dlu : dlu
# min : min
# stabilkan : stabil
# leletnya : lelet
# tinggal : tinggal
# kota : kota
# medan : medan
# pls : pls
# youtube : youtube
# akun : akun
# bener : bener
# iklan : iklan
# anti : anti
# club : club
# mbps : mbps
# nyampe : nyampe
# kraken : kraken
# cuman : cuman
# gini : gin
# doang : doang
# klw : klw
# trus : trus
# urusin : urusin
# marketing : marketing
# target : target
# bekasi : bekas
# gajelas : gajelas
# pingnya : pingnya
# mulu : mulu
# jualan : jual
# ngambil : ngambil
# duit : duit
# ready : ready
# change : change
# number : number
# phone : phone
# benerin : benerin
# sosmed : sosmed
# ngelag : ngelag
# heh : heh
# off : off
# gue : gue
# ngomong : ngomong
# kasar : kasar
# kek : kek
# kemaren : kemaren
# telkomnyet : telkomnyet
# pulsa : pulsa
# ilang : ilang
# sndri : sndri
# adminya : adminya
# hewan : hewan
# baca : baca
# sampekan : sampek
# kagak : kagak
# daftar : daftar
# woeee : woeee
# smartfren : smartfren
# gitu : gitu
# johhhhh : johhhhh
# woi : woi
# sinyalnya : sinyal
# jlek : jlek
# amy : amy
# maen : maen
# gamee : gamee
# ngelekk : ngelekk
# gakk : gakk
# usahh : usahh
# sokk : sokk
# keress : keress
# rusak : rusak
# hidup : hidup
# era : era
# speed : speed
# gapernah : gapernah
# stabil : stabil
# hadehhh : hadehhh
# telkom : telkom
# tlkom : tlkom
# gblokk : gblokk
# maaf : maaf
# kecewa : kecewa
# raja : raja
# telk : telk
# nt : nt
# lll : lll
# bismillah : bismillah
# moga : moga
# bangkrut : bangkrut
# aminnn : aminnn
# leg : leg
# bat : bat
# taaiii : taaiii
# gara : gara
# gua : gua
# gagal : gagal
# glory : glory
# njir : njir
# love : love
# you : you
# veronika : veronika
# honey : honey
# asik : asik
# banget : banget
# pilihan : pilih
# kuota : kuota
# bundling : bundling
# disney : disney
# hotstar : hotstar
# ditempat : tempat
# bagus : bagus
# tertandingi : tanding
# omg : omg
# exactly : exactly
# what : what
# needed : needed
# mahalin : mahalin
# otomatis : otomatis
# tersedot : sedot
# pakai : pakai
# data : data
# parah : parah
# bangga : bangga
# kau : kau
# kekuatan : kuat
# ngerti : ngerti
# kebutuhan : butuh
# semoga : moga
# sukses : sukses
# amiin : amiin
# help : help
# kesini : kesini
# kepencet : pencet
# bintang : bintang
# iklannya : iklan
# taekkkkkk : taekkkkkk
# bebas : bebas
# galau : galau
# mantap : mantap
# kak : kak
# tae : tae
# burik : burik
# aneh : aneh
# telmi : telmi
# belagu : belagu
# bosku : bos
# tekomsel : tekomsel
# asli : asli
# nyaman : nyaman
# mohon : mohon
# cepat : cepat
# dirugikan : rugi
# berlangganan : langgan
# mash : mash
# bilanglah : bilang
# first : first
# mati : mati
# gmn : gmn
# pol : pol
# push : push
# dikit : dikit
# bkin : bkin
# rugi : rugi
# costumer : costumer
# huuu : huuu
# ampass : ampass
# menginspirasi : inspirasi
# jenny : jenny
# lagu : lagu
# anak : anak
# super : super
# pokoknya : pokok
# pura : pura
# komen : komen
# dpr : dpr
# bagusnya : bagus
# pengumuman : umum
# undi : undi
# pemenang : menang
# langung : langung
# kasi : kasi
# masuk : masuk
# sapaya : sapaya
# liat : liat
# jarang : jarang
# ribu : ribu
# sayang : sayang
# ikutan : ikut
# padam : padam
# listrik : listrik
# kentang : kentang
# ancur : ancur
# buka : buka
# muterrrrr : muterrrrr
# telat : telat
# bayar : bayar
# didenda : denda
# ter : ter
# janringan : janringan
# terlelet : lelet
# see : see
# indonesia : indonesia
# jaing : jaing
# duch : duch
# sya : sya
# combosakti : combosakti
# dialfamart : dialfamart
# mantabs : mantabs
# pelayanan : layan
# dipermudah : mudah
# trima : trima
# kasih : kasih
# terima : terima
# alfamart : alfamart
# sllu : sllu
# berkah : berkah
# wahhh : wahhh
# undang : undang
# canda : canda
# ruang : ruang
# dustin : dustin
# menang : menang
# dear : dear
# candaan : canda
# plieesss : plieesss
# sultan : sultan
# setingan : ting
# lbh : lbh
# bnyk : bnyk
# alias : alias
# timbul : timbul
# campuraduk : campuraduk
# sengaja : sengaja
# setting : setting
# kerusakan : rusa
# knpa : knpa
# skrng : skrng
# perbaikan : baik
# mmg : mmg
# pindah : pindah
# langsung : langsung
# tempatnya : tempat
# tertutup : tutup
# jumping : jumping
# terusss : terusss
# ngen : ngen
# the : the
# mengecewakan : kecewa
# krtu : krtu
# jawara : jawara
# pling : pling
# kuat : kuat
# skarng : skarng
# ngampas : ngampas
# anjing : anjing
# test : test
# mentok : mentok
# kab : kab
# pekalongan : kalong
# hancur : hancur
# parahhhhhhhhhhh : parahhhhhhhhhhh
# signal : signal
# assalamualaikum : assalamualaikum
# pengguna : guna
# knp : knp
# {'alhamdulillah': 'alhamdulillah', 'berbagi': 'bagi', 'semangat': 'semangat', 'telkomsel': 'telkomsel', '': '', 'tolong': 'tolong', 'butuh': 'butuh', 'respon': 'respon', 'trjadi': 'trjadi', 'kaltim': 'kaltim', 'kukar': 'kukar', 'kec': 'kec', 'kenohan': 'kenohan', 'kadang': 'kadang', 'nelpon': 'nelpon', 'sms': 'sms', 'lgi': 'lgi', 'internet': 'internet', 'kdang': 'kdang', 'internetnya': 'internetnya', 'bermasalah': 'masalah', 'kasian': 'kasi', 'jual': 'jual', 'online': 'online', 'perbaikkan': 'baik', 'tlong': 'tlong', 'info': 'info', 'kebingungan': 'bingung', 'salam': 'salam', 'toleransi': 'toleransi', 'jaringan': 'jaring', 'buruk': 'buruk', 'wilayah': 'wilayah', 'muara': 'muara', 'enim': 'enim', 'prabumulih': 'prabumulih', 'tepatnya': 'tepat', 'rambang': 'rambang', 'niru': 'niru', 'harga': 'harga', 'paket': 'paket', 'selangit': 'langit', 'kualitas': 'kualitas', 'jaringannya': 'jaring', 'jongkok': 'jongkok', 'perbaiki': 'baik', 'daerah': 'daerah', 'menyesal': 'sesal', 'karna': 'karna', 'membeli': 'beli', 'kouta': 'kouta', 'tpi': 'tpi', 'udh': 'udh', 'habis': 'habis', 'ketahui': 'tahu', 'dipakek': 'dipakek', 'enga': 'enga', 'lelet': 'lelet', 'kaya': 'kaya', 'sea': 'sea', 'food': 'food', 'merry': 'merry', 'christmas': 'christmas', 'best': 'best', 'friend': 'friend', 'provider': 'provider', 'emang': 'emang', 'binatang': 'binatang', 'udah': 'udah', 'macet': 'macet', 'tungguin': 'tungguin', 'blm': 'blm', 'lancar': 'lancar', 'woy': 'woy', 'sesabar': 'sabar', 'sabarnya': 'sabar', 'org': 'org', 'lag': 'lag', 'abs': 'abs', 'kesabarannya': 'sabar', 'ganti': 'ganti', 'kartu': 'kartu', 'beneran': 'beneran', 'operator': 'operator', 'jamin': 'jamin', 'joss': 'joss', 'sinyal': 'sinyal', 'tsel': 'tsel', 'setahun': 'tahun', 'full': 'full', 'hilang': 'hilang', 'ambil': 'ambil', 'keuntungan': 'untung', 'coba': 'coba', 'mutu': 'mutu', 'layanan': 'layan', 'pastikan': 'pasti', 'tehnisi': 'tehnisi', 'berpengalaman': 'alam', 'ahli': 'ahli', 'bidangnya': 'bidang', 'gangguan': 'ganggu', 'musim': 'musim', 'hujan': 'hujan', 'klarifikasi': 'klarifikasi', 'keluhan': 'keluh', 'pelanggan': 'langgan', 'terhormat': 'hormat', 'emosi': 'emosi', 'membara': 'bara', 'wibu': 'wibu', 'berkekuatan': 'kuat', 'power': 'power', 'pakailah': 'pakai', 'telkomlegg': 'telkomlegg', 'main': 'main', 'game': 'game', 'disconnected': 'disconnected', 'nonton': 'nonton', 'film': 'film', 'resolusi': 'resolusi', 'buffering': 'buffering', 'fokus': 'fokus', 'dlu': 'dlu', 'min': 'min', 'stabilkan': 'stabil', 'leletnya': 'lelet', 'tinggal': 'tinggal', 'kota': 'kota', 'medan': 'medan', 'pls': 'pls', 'youtube': 'youtube', 'akun': 'akun', 'bener': 'bener', 'iklan': 'iklan', 'anti': 'anti', 'club': 'club', 'mbps': 'mbps', 'nyampe': 'nyampe', 'kraken': 'kraken', 'cuman': 'cuman', 'gini': 'gin', 'doang': 'doang', 'klw': 'klw', 'trus': 'trus', 'urusin': 'urusin', 'marketing': 'marketing', 'target': 'target', 'bekasi': 'bekas', 'gajelas': 'gajelas', 'pingnya': 'pingnya', 'mulu': 'mulu', 'jualan': 'jual', 'ngambil': 'ngambil', 'duit': 'duit', 'ready': 'ready', 'change': 'change', 'number': 'number', 'phone': 'phone', 'benerin': 'benerin', 'sosmed': 'sosmed', 'ngelag': 'ngelag', 'heh': 'heh', 'off': 'off', 'gue': 'gue', 'ngomong': 'ngomong', 'kasar': 'kasar', 'kek': 'kek', 'kemaren': 'kemaren', 'telkomnyet': 'telkomnyet', 'pulsa': 'pulsa', 'ilang': 'ilang', 'sndri': 'sndri', 'adminya': 'adminya', 'hewan': 'hewan', 'baca': 'baca', 'sampekan': 'sampek', 'kagak': 'kagak', 'daftar': 'daftar', 'woeee': 'woeee', 'smartfren': 'smartfren', 'gitu': 'gitu', 'johhhhh': 'johhhhh', 'woi': 'woi', 'sinyalnya': 'sinyal', 'jlek': 'jlek', 'amy': 'amy', 'maen': 'maen', 'gamee': 'gamee', 'ngelekk': 'ngelekk', 'gakk': 'gakk', 'usahh': 'usahh', 'sokk': 'sokk', 'keress': 'keress', 'rusak': 'rusak', 'hidup': 'hidup', 'era': 'era', 'speed': 'speed', 'gapernah': 'gapernah', 'stabil': 'stabil', 'hadehhh': 'hadehhh', 'telkom': 'telkom', 'tlkom': 'tlkom', 'gblokk': 'gblokk', 'maaf': 'maaf', 'kecewa': 'kecewa', 'raja': 'raja', 't ...
# ------------------------
# Pandas Apply:   0%|          | 0/101 [00:00<?, ?it/s]
#                                                comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat2 sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178      4g aja test speed cuma mentok 75-100 kb/ps???
# 201                    jaringan kab pekalongan hancur?
# 202               parahhhhhhhhhhh banget signal nya,,,
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel,knp se...
#
#                                       cleaning_comment  \
# 0    alhamdulillah bisa saling berbagi semangat tel...
# 1    tolong kami sangat butuh respon dari pihak tel...
# 2                                      salam toleransi
# 3    kenapa jaringan internet telkomsel sangat  sem...
# 4    saya menggunakan telkomsel saya menyesal karna...
# ..                                                 ...
# 178                      aja test speed cuma mentok
# 201                    jaringan kab pekalongan hancur
# 202                 parahhhhhhhhhhh banget signal nya
# 203                                   telkomsel ngelag
# 204  assalamualaikum saya pengguna telkomsel knp se...
#
#                                             tokenisasi  \
# 0    [alhamdulillah, bisa, saling, berbagi, semanga...
# 1    [tolong, kami, sangat, butuh, respon, dari, pi...
# 2                                   [salam, toleransi]
# 3    [kenapa, jaringan, internet, telkomsel, sangat...
# 4    [saya, menggunakan, telkomsel, saya, menyesal,...
# ..                                                 ...
# 178               [, aja, test, speed, cuma, mentok, ]
# 201              [jaringan, kab, pekalongan, hancur, ]
# 202           [parahhhhhhhhhhh, banget, signal, nya, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, saya, pengguna, telkomsel, k...
#
#                                               stopword  \
# 0      [alhamdulillah, berbagi, semangat, telkomsel, ]
# 1    [tolong, butuh, respon, telkomsel, trjadi, kal...
# 2                                   [salam, toleransi]
# 3    [jaringan, internet, telkomsel, buruk, wilayah...
# 4    [telkomsel, menyesal, karna, membeli, kouta, t...
# ..                                                 ...
# 178                          [, test, speed, mentok, ]
# 201              [jaringan, kab, pekalongan, hancur, ]
# 202                [parahhhhhhhhhhh, banget, signal, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, pengguna, telkomsel, knp, te...
#
#                                               stemming
# 0         [alhamdulillah, bagi, semangat, telkomsel, ]
# 1    [tolong, butuh, respon, telkomsel, trjadi, kal...
# 2                                   [salam, toleransi]
# 3    [jaring, internet, telkomsel, buruk, wilayah, ...
# 4    [telkomsel, sesal, karna, beli, kouta, tpi, ud...
# ..                                                 ...
# 178                          [, test, speed, mentok, ]
# 201                    [jaring, kab, kalong, hancur, ]
# 202                [parahhhhhhhhhhh, banget, signal, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, guna, telkomsel, knp, telkom...
#
# [101 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0         [alhamdulillah, bagi, semangat, telkomsel, ]
# 1    [tolong, butuh, respon, telkomsel, trjadi, kal...
# 2                                   [salam, toleransi]
# 3    [jaring, internet, telkomsel, buruk, wilayah, ...
# 4    [telkomsel, sesal, karna, beli, kouta, tpi, ud...
# ..                                                 ...
# 178                          [, test, speed, mentok, ]
# 201                    [jaring, kab, kalong, hancur, ]
# 202                [parahhhhhhhhhhh, banget, signal, ]
# 203                                [telkomsel, ngelag]
# 204  [assalamualaikum, guna, telkomsel, knp, telkom...
#
# [101 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_12.xlsx')
