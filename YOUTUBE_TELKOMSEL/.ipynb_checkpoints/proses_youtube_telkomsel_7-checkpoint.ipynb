# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Sekarang bingung ngebedain antara penipuan sam...
# 1    Ini namanya Penipuan .. Gambar dan isi video t...
# 2                                          Pengaduan..
# 3    Cuma mau bilang satu hall.. SINYAL TELKOMSEL L...
# 4    Telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 280                                       Gile lu ndro
# 281                                         Ngeleg woy
# 282                        Udh mhl kaya tai sinyal nya
# 283                  Benerin woi sinyal nya ini gimana
# 284                             Sinyal woy udah 2 hari
#
# [285 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 50

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Sekarang bingung ngebedain antara penipuan sam...
# 1    Ini namanya Penipuan .. Gambar dan isi video t...
# 2                                          Pengaduan..
# 3    Cuma mau bilang satu hall.. SINYAL TELKOMSEL L...
# 4    Telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 260  Please benerin sinyal telkomsel di sidoarjo, s...
# 261                  Telkomsel merugikan pelanggan nya
# 262  Ngakak gw anjing dengan jaringan 5G BOROS + LE...
# 263  Benerin sistem nya oi..gua tiap isi ulang data...
# 268      Telkomsel sekarang macam gimna sih lag banget
#
# [185 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan .. gambar dan isi video t...
# 2                                          pengaduan..
# 3    cuma mau bilang satu hall.. sinyal telkomsel l...
# 4    telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 260  please benerin sinyal telkomsel di sidoarjo, s...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak gw anjing dengan jaringan 5g boros + le...
# 263  benerin sistem nya oi..gua tiap isi ulang data...
# 268      telkomsel sekarang macam gimna sih lag banget
#
# [185 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan .. gambar dan isi video t...
# 2                                          pengaduan..
# 3    cuma mau bilang satu hall.. sinyal telkomsel l...
# 4    telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 260  please benerin sinyal telkomsel di sidoarjo, s...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak gw anjing dengan jaringan 5g boros + le...
# 263  benerin sistem nya oi..gua tiap isi ulang data...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                       cleaning_comment
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan gambar dan isi video tida...
# 2                                           pengaduan
# 3    cuma mau bilang satu hall sinyal telkomsel lel...
# 4    telkomsel terbaik bisa kmn sinyalnya luasin aj...
# ..                                                 ...
# 260  please benerin sinyal telkomsel sidoarjo sejak...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak anjing dengan jaringan boros lelet berb...
# 263  benerin sistem nya gua tiap isi ulang data pak...
# 268      telkomsel sekarang macam gimna sih lag banget
#
# [185 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan .. gambar dan isi video t...
# 2                                          pengaduan..
# 3    cuma mau bilang satu hall.. sinyal telkomsel l...
# 4    telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 260  please benerin sinyal telkomsel di sidoarjo, s...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak gw anjing dengan jaringan 5g boros + le...
# 263  benerin sistem nya oi..gua tiap isi ulang data...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                       cleaning_comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan gambar dan isi video tida...
# 2                                           pengaduan
# 3    cuma mau bilang satu hall sinyal telkomsel lel...
# 4    telkomsel terbaik bisa kmn sinyalnya luasin aj...
# ..                                                 ...
# 260  please benerin sinyal telkomsel sidoarjo sejak...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak anjing dengan jaringan boros lelet berb...
# 263  benerin sistem nya gua tiap isi ulang data pak...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                             tokenisasi
# 0    [sekarang, bingung, ngebedain, antara, penipua...
# 1    [ini, namanya, penipuan, gambar, dan, isi, vid...
# 2                                        [pengaduan, ]
# 3    [cuma, mau, bilang, satu, hall, sinyal, telkom...
# 4    [telkomsel, terbaik, bisa, kmn, sinyalnya, lua...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261             [telkomsel, merugikan, pelanggan, nya]
# 262  [ngakak, anjing, dengan, jaringan, boros, lele...
# 263  [benerin, sistem, nya, gua, tiap, isi, ulang, ...
# 268  [telkomsel, sekarang, macam, gimna, sih, lag, ...
#
# [185 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan .. gambar dan isi video t...
# 2                                          pengaduan..
# 3    cuma mau bilang satu hall.. sinyal telkomsel l...
# 4    telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 260  please benerin sinyal telkomsel di sidoarjo, s...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak gw anjing dengan jaringan 5g boros + le...
# 263  benerin sistem nya oi..gua tiap isi ulang data...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                       cleaning_comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan gambar dan isi video tida...
# 2                                           pengaduan
# 3    cuma mau bilang satu hall sinyal telkomsel lel...
# 4    telkomsel terbaik bisa kmn sinyalnya luasin aj...
# ..                                                 ...
# 260  please benerin sinyal telkomsel sidoarjo sejak...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak anjing dengan jaringan boros lelet berb...
# 263  benerin sistem nya gua tiap isi ulang data pak...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                             tokenisasi  \
# 0    [sekarang, bingung, ngebedain, antara, penipua...
# 1    [ini, namanya, penipuan, gambar, dan, isi, vid...
# 2                                        [pengaduan, ]
# 3    [cuma, mau, bilang, satu, hall, sinyal, telkom...
# 4    [telkomsel, terbaik, bisa, kmn, sinyalnya, lua...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261             [telkomsel, merugikan, pelanggan, nya]
# 262  [ngakak, anjing, dengan, jaringan, boros, lele...
# 263  [benerin, sistem, nya, gua, tiap, isi, ulang, ...
# 268  [telkomsel, sekarang, macam, gimna, sih, lag, ...
#
#                                               stopword
# 0    [bingung, ngebedain, penipuan, strategi, marke...
# 1    [namanya, penipuan, gambar, isi, video, sesuai...
# 2                                        [pengaduan, ]
# 3            [hall, sinyal, telkomsel, lelet, parah, ]
# 4    [telkomsel, terbaik, kmn, sinyalnya, luasin, s...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261                  [telkomsel, merugikan, pelanggan]
# 262  [ngakak, anjing, jaringan, boros, lelet, berbe...
# 263  [benerin, sistem, gua, isi, ulang, data, voche...
# 268                    [telkomsel, gimna, lag, banget]
#
# [185 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 466
# ------------------------
# bingung : bingung
# ngebedain : ngebedain
# penipuan : tipu
# strategi : strategi
# marketing : marketing
# emang : emang
#  :
# namanya : nama
# gambar : gambar
# isi : isi
# video : video
# sesuai : sesuai
# ayo : ayo
# tuntut : tuntut
# bareng : bareng
# ite : ite
# pengaduan : adu
# hall : hall
# sinyal : sinyal
# telkomsel : telkomsel
# lelet : lelet
# parah : parah
# terbaik : baik
# kmn : kmn
# sinyalnya : sinyal
# luasin : luasin
# suka : suka
# pegunungan : gunung
# gituh : gituh
# komentar : komentar
# jaringan : jaring
# perbaikilah : baik
# ngk : ngk
# pasang : pasang
# iklan : iklan
# karna : karna
# kek : kek
# sumpah : sumpah
# unlimited : unlimited
# kecepatan : cepat
# batasi : batas
# wkwkw : wkwkw
# kegabutan : kegabutan
# nonton : nonton
# yutub : yutub
# tolong : tolong
# setabil : setabil
# koneksi : koneksi
# ampun : ampun
# full : full
# promosi : promosi
# kenceng : kenceng
# giliran : gilir
# serasa : serasa
# bangkrut : bangkrut
# pelanggan : langgan
# berubah : ubah
# lag : lag
# gangguan : ganggu
# kompensasinya : kompensasi
# paket : paket
# trimakasih : trimakasih
# moga : moga
# tutup : tutup
# kaya : kaya
# terimakasih : terimakasih
# banyakin : banyakin
# promo : promo
# dikorupsi : korupsi
# njing : njing
# gara : gara
# koruptor : koruptor
# ngeleg : ngeleg
# wooyy : wooyy
# balikin : balikin
# tsel : tsel
# duluu : duluu
# report : report
# cok : cok
# website : website
# telkom : telkom
# kabel : kabel
# dicuri : curi
# jdi : jdi
# goblok : goblok
# sinal : sal
# lemah : lemah
# mulu : mulu
# bos : bos
# ama : ama
# harganya : harga
# asw : asw
# pulsa : pulsa
# kesedot : sedot
# internet : internet
# telpon : telpon
# udah : udah
# beli : beli
# mahal : mahal
# sisa : sisa
# embat : embat
# buruk : buruk
# akun : akun
# youtube : youtube
# susah : susah
# jan : jan
# wajar : wajar
# banting : banting
# heck : heck
# murah : murah
# woy : woy
# benerin : benerin
# banget : banget
# coy : coy
# btw : btw
# ganti : ganti
# logo : logo
# aplikasi : aplikasi
# taik : taik
# gua : gua
# sampek : sampek
# kagak : kagak
# instal : instal
# berpuluh : puluh
# puluh : puluh
# pakek : pakek
# kecewain : kecewain
# kampret : kampret
# rasaku : rasa
# didaerah : daerah
# ngelag : ngelag
# upgred : upgred
# kartu : kartu
# simpati : simpati
# ujung : ujung
# besi : besi
# bekas : bekas
# rusak : rusak
# bagus : bagus
# kuat : kuat
# doang : doang
# laen : laen
# mah : mah
# keong : keong
# thumbnail : thumbnail
# click : click
# bait : bait
# error : error
# paketan : paket
# butuhkan : butuh
# provider : provider
# ampas : ampas
# cepat : cepat
# siput : siput
# main : main
# anjing : anjing
# perbaikin : perbaikin
# kalah : kalah
# kencang : kencang
# im : im
# the : the
# best : best
# berlaku : laku
# nyah : nyah
# bener : bener
# signal : signal
# kena : kena
# covid : covid
# smpk : smpk
# separah : parah
# ngelagnya : ngelagnya
# ayok : ayok
# pindah : pindah
# brand : brand
# sebelah : belah
# astaga : astaga
# axis : axis
# rb : rb
# kuota : kuota
# emng : emng
# biadab : biadab
# belajar : ajar
# konsen : konsen
# cocok : cocok
# bnget : bnget
# ganjelan : ganjelan
# pintu : pintu
# kandang : kandang
# ayam : ayam
# njirr : njirr
# nyesel : nyesel
# ketengan : keteng
# liat : liat
# kualitas : kualitas
# loading : loading
# kamana : kamana
# meni : meni
# goreng : goreng
# patut : patut
# pisan : pis
# menit : menit
# udh : udh
# juta : juta
# mudah : mudah
# bangkrutttt : bangkrutttt
# leg : leg
# muluk : muluk
# merugikan : rugi
# konsumen : konsumen
# boss : boss
# data : data
# harga : harga
# selangit : langit
# jaringam : jaringam
# taek : taek
# manding : manding
# merek : merek
# jijik : jijik
# beda : beda
# nikita : nikita
# willy : willy
# clik : clik
# akting : akting
# niki : nik
# prank : prank
# hadeh : hadeh
# butut : butut
# diandelin : diandelin
# isinya : isi
# mahaberantakan : mahaberantakan
# gajelas : gajelas
# knp : knp
# buka : buka
# perbaiki : baik
# tod : tod
# ampasssss : ampasssss
# gini : gin
# gblokkkk : gblokkkk
# ngent : ngent
# ana : ana
# mending : mending
# bagusin : bagusin
# nggak : nggak
# klw : klw
# dukung : dukung
# hubungannya : hubung
# gue : gue
# skali : skali
# sialan : sial
# ngapain : ngapain
# berlangganan : langgan
# murahan : murah
# tembusin : tembusin
# dis : dis
# like : like
# post : post
# foto : foto
# real : real
# moal : moal
# payu : payu
# lamun : lamun
# wae : wae
# mutu : mutu
# bangkeut : bangkeut
# ajah : ajah
# bgsttt : bgsttt
# ajg : ajg
# kasih : kasih
# karoan : karoan
# niat : niat
# jualan : jual
# gimana : gimana
# ngambil : ngambil
# untungan : untung
# game : game
# candaan : canda
# ruang : ruang
# comeback : comeback
# download : download
# sejam : jam
# telkomnyet : telkomnyet
# telkomtol : telkomtol
# cacad : cacad
# senggol : senggol
# clickbait : clickbait
# dislike : dislike
# playstore : playstore
# lihat : lihat
# komenya : komenya
# boongin : boongin
# ganggu : ganggu
# bakr : bakr
# pabrik : pabrik
# tlkom : tlkom
# ngen : ngen
# ngapa : ngapa
# giga : giga
# indonesia : indonesia
# ilang : ilang
# unlimitednya : unlimitednya
# batasan : batas
# hilang : hilang
# pelayanan : layan
# baguss : baguss
# ngelng : ngelng
# rame : rame
# sampah : sampah
# bansos : bansos
# kentit : kentit
# terang : terang
# kon : kon
# kirain : kirain
# ciuman : cium
# ngelek : ngelek
# lemot : lot
# paksain : paksain
# bro : bro
# tinggalin : tinggalin
# ngapaun : ngapaun
# tahanin : tahanin
# ping : ping
# fun : fun
# fact : fact
# thumbnailnya : thumbnailnya
# mamaksa : mamaksa
# boong : boong
# abis : abis
# unlike : unlike
# keyataan : keyataan
# seindah : indah
# hoax : hoax
# gada : gada
# macem : macem
# tollol : tollol
# nglek : nglek
# sampe : sampe
# apus : apus
# tataunya : tataunya
# koontol : koontol
# lahhhh : lahhhh
# begok : begok
# ngab : ngab
# vidio : vidio
# thubnail : thubnail
# pembodohan : bodoh
# denga : denga
# gaya : gaya
# kls : kls
# sesat : sesat
# dunia : dunia
# cuman : cuman
# jim : jim
# ampe : ampe
# ngelk : ngelk
# jarigan : jarigan
# woii : woii
# sinya : sinya
# wkwkwkw : wkwkwkw
# lansung : lansung
# stabil : stabil
# datanya : data
# sengaja : sengaja
# klik : klik
# favorit : favorit
# gmn : gmn
# enk : enk
# way : way
# kanan : kanan
# lampung : lampung
# pakuan : paku
# ratu : ratu
# anjeng : anjeng
# bodohhhhh : bodohhhhh
# jaringannya : jaring
# maen : maen
# drmh : drmh
# kesel : kesel
# asek : asek
# laso : laso
# ampasss : ampasss
# bree : bree
# denganmu : dengan
# mbak : mbak
# membuatku : buat
# memencet : pencet
# gegara : gegara
# putra : putra
# zonk : zonk
# kepencet : pencet
# guys : guys
# anjeeeng : anjeeeng
# kesini : kesini
# kokgakbisanyetel : kokgakbisanyetel
# lagu : lagu
# lawas : lawas
# babye : babye
# kayak : kayak
# anji : anji
# mmmmmk : mmmmmk
# komen : komen
# nikitanya : nikitanya
# mnaa : mnaa
# nyett : nyett
# tamnel : tamnel
# ambigu : ambigu
# admin : admin
# ketipu : tipu
# balekin : balekin
# cnx : cnx
# jmbd : jmbd
# gambarnya : gambar
# ssbu : ssbu
# cungpanglaphai : cungpanglaphai
# cingcangphaici : cingcangphaici
# chung : chung
# hipo : hipo
# penasaran : penasaran
# cewe : cewe
# ayyu : ayyu
# tox : tox
# hhh : hhh
# woyy : woyy
# meresehkan : meresehkan
# skrg : skrg
# sungguh : sungguh
# melelahkan : lelah
# bar : bar
# ato : ato
# klu : klu
# cepet : cepet
# panas : panas
# gitu : gitu
# sehr : sehr
# cas : cas
# tower : tower
# perusahaan : usaha
# korupsi : korupsi
# please : please
# sidoarjo : sidoarjo
# desember : desember
# ngakak : ngakak
# boros : boros
# berbeda : beda
# negara : negara
# maju : maju
# that : that
# funny : funny
# you : you
# realize : realize
# telkontol : telkontol
# been : been
# almost : almost
# decades : decades
# still : still
# same : same
# bullshit : bullshit
# digedein : digedein
# dipanggil : panggil
# sistem : sistem
# ulang : ulang
# vocher : vocher
# sibuk : sibuk
# uang : uang
# habis : habis
# gunain : gunain
# gimna : gimna
# {'bingung': 'bingung', 'ngebedain': 'ngebedain', 'penipuan': 'tipu', 'strategi': 'strategi', 'marketing': 'marketing', 'emang': 'emang', '': '', 'namanya': 'nama', 'gambar': 'gambar', 'isi': 'isi', 'video': 'video', 'sesuai': 'sesuai', 'ayo': 'ayo', 'tuntut': 'tuntut', 'bareng': 'bareng', 'ite': 'ite', 'pengaduan': 'adu', 'hall': 'hall', 'sinyal': 'sinyal', 'telkomsel': 'telkomsel', 'lelet': 'lelet', 'parah': 'parah', 'terbaik': 'baik', 'kmn': 'kmn', 'sinyalnya': 'sinyal', 'luasin': 'luasin', 'suka': 'suka', 'pegunungan': 'gunung', 'gituh': 'gituh', 'komentar': 'komentar', 'jaringan': 'jaring', 'perbaikilah': 'baik', 'ngk': 'ngk', 'pasang': 'pasang', 'iklan': 'iklan', 'karna': 'karna', 'kek': 'kek', 'sumpah': 'sumpah', 'unlimited': 'unlimited', 'kecepatan': 'cepat', 'batasi': 'batas', 'wkwkw': 'wkwkw', 'kegabutan': 'kegabutan', 'nonton': 'nonton', 'yutub': 'yutub', 'tolong': 'tolong', 'setabil': 'setabil', 'koneksi': 'koneksi', 'ampun': 'ampun', 'full': 'full', 'promosi': 'promosi', 'kenceng': 'kenceng', 'giliran': 'gilir', 'serasa': 'serasa', 'bangkrut': 'bangkrut', 'pelanggan': 'langgan', 'berubah': 'ubah', 'lag': 'lag', 'gangguan': 'ganggu', 'kompensasinya': 'kompensasi', 'paket': 'paket', 'trimakasih': 'trimakasih', 'moga': 'moga', 'tutup': 'tutup', 'kaya': 'kaya', 'terimakasih': 'terimakasih', 'banyakin': 'banyakin', 'promo': 'promo', 'dikorupsi': 'korupsi', 'njing': 'njing', 'gara': 'gara', 'koruptor': 'koruptor', 'ngeleg': 'ngeleg', 'wooyy': 'wooyy', 'balikin': 'balikin', 'tsel': 'tsel', 'duluu': 'duluu', 'report': 'report', 'cok': 'cok', 'website': 'website', 'telkom': 'telkom', 'kabel': 'kabel', 'dicuri': 'curi', 'jdi': 'jdi', 'goblok': 'goblok', 'sinal': 'sal', 'lemah': 'lemah', 'mulu': 'mulu', 'bos': 'bos', 'ama': 'ama', 'harganya': 'harga', 'asw': 'asw', 'pulsa': 'pulsa', 'kesedot': 'sedot', 'internet': 'internet', 'telpon': 'telpon', 'udah': 'udah', 'beli': 'beli', 'mahal': 'mahal', 'sisa': 'sisa', 'embat': 'embat', 'buruk': 'buruk', 'akun': 'akun', 'youtube': 'youtube', 'susah': 'susah', 'jan': 'jan', 'wajar': 'wajar', 'banting': 'banting', 'heck': 'heck', 'murah': 'murah', 'woy': 'woy', 'benerin': 'benerin', 'banget': 'banget', 'coy': 'coy', 'btw': 'btw', 'ganti': 'ganti', 'logo': 'logo', 'aplikasi': 'aplikasi', 'taik': 'taik', 'gua': 'gua', 'sampek': 'sampek', 'kagak': 'kagak', 'instal': 'instal', 'berpuluh': 'puluh', 'puluh': 'puluh', 'pakek': 'pakek', 'kecewain': 'kecewain', 'kampret': 'kampret', 'rasaku': 'rasa', 'didaerah': 'daerah', 'ngelag': 'ngelag', 'upgred': 'upgred', 'kartu': 'kartu', 'simpati': 'simpati', 'ujung': 'ujung', 'besi': 'besi', 'bekas': 'bekas', 'rusak': 'rusak', 'bagus': 'bagus', 'kuat': 'kuat', 'doang': 'doang', 'laen': 'laen', 'mah': 'mah', 'keong': 'keong', 'thumbnail': 'thumbnail', 'click': 'click', 'bait': 'bait', 'error': 'error', 'paketan': 'paket', 'butuhkan': 'butuh', 'provider': 'provider', 'ampas': 'ampas', 'cepat': 'cepat', 'siput': 'siput', 'main': 'main', 'anjing': 'anjing', 'perbaikin': 'perbaikin', 'kalah': 'kalah', 'kencang': 'kencang', 'im': 'im', 'the': 'the', 'best': 'best', 'berlaku': 'laku', 'nyah': 'nyah', 'bener': 'bener', 'signal': 'signal', 'kena': 'kena', 'covid': 'covid', 'smpk': 'smpk', 'separah': 'parah', 'ngelagnya': 'ngelagnya', 'ayok': 'ayok', 'pindah': 'pindah', 'brand': 'brand', 'sebelah': 'belah', 'astaga': 'astaga', 'axis': 'axis', 'rb': 'rb', 'kuota': 'kuota', 'emng': 'emng', 'biadab': 'biadab', 'belajar': 'ajar', 'konsen': 'konsen', 'cocok': 'cocok', 'bnget': 'bnget', 'ganjelan': 'ganjelan', 'pintu': 'pintu', 'kandang': 'kandang', 'ayam': 'ayam', 'njirr': 'njirr', 'nyesel': 'nyesel', 'ketengan': 'keteng', 'liat': 'liat', 'kualitas': 'kualitas', 'loading': 'loading', 'kamana': 'kamana', 'meni': 'meni', 'goreng': 'goreng', 'patut': 'patut', 'pisan': 'pis', 'menit': 'menit', 'udh': 'udh', 'juta': 'juta', 'mudah': 'mudah', 'bangkrutttt': 'bangkrutttt', 'leg': 'leg', 'muluk': 'muluk', 'merugikan': 'rugi', 'konsumen': 'konsumen', 'boss': 'boss', 'data': 'd ...
# ------------------------
# Pandas Apply:   0%|          | 0/185 [00:00<?, ?it/s]
#                                                comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan .. gambar dan isi video t...
# 2                                          pengaduan..
# 3    cuma mau bilang satu hall.. sinyal telkomsel l...
# 4    telkomsel yg terbaik bisa d bw kmn mn sinyalny...
# ..                                                 ...
# 260  please benerin sinyal telkomsel di sidoarjo, s...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak gw anjing dengan jaringan 5g boros + le...
# 263  benerin sistem nya oi..gua tiap isi ulang data...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                       cleaning_comment  \
# 0    sekarang bingung ngebedain antara penipuan sam...
# 1    ini namanya penipuan gambar dan isi video tida...
# 2                                           pengaduan
# 3    cuma mau bilang satu hall sinyal telkomsel lel...
# 4    telkomsel terbaik bisa kmn sinyalnya luasin aj...
# ..                                                 ...
# 260  please benerin sinyal telkomsel sidoarjo sejak...
# 261                  telkomsel merugikan pelanggan nya
# 262  ngakak anjing dengan jaringan boros lelet berb...
# 263  benerin sistem nya gua tiap isi ulang data pak...
# 268      telkomsel sekarang macam gimna sih lag banget
#
#                                             tokenisasi  \
# 0    [sekarang, bingung, ngebedain, antara, penipua...
# 1    [ini, namanya, penipuan, gambar, dan, isi, vid...
# 2                                        [pengaduan, ]
# 3    [cuma, mau, bilang, satu, hall, sinyal, telkom...
# 4    [telkomsel, terbaik, bisa, kmn, sinyalnya, lua...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261             [telkomsel, merugikan, pelanggan, nya]
# 262  [ngakak, anjing, dengan, jaringan, boros, lele...
# 263  [benerin, sistem, nya, gua, tiap, isi, ulang, ...
# 268  [telkomsel, sekarang, macam, gimna, sih, lag, ...
#
#                                               stopword  \
# 0    [bingung, ngebedain, penipuan, strategi, marke...
# 1    [namanya, penipuan, gambar, isi, video, sesuai...
# 2                                        [pengaduan, ]
# 3            [hall, sinyal, telkomsel, lelet, parah, ]
# 4    [telkomsel, terbaik, kmn, sinyalnya, luasin, s...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261                  [telkomsel, merugikan, pelanggan]
# 262  [ngakak, anjing, jaringan, boros, lelet, berbe...
# 263  [benerin, sistem, gua, isi, ulang, data, voche...
# 268                    [telkomsel, gimna, lag, banget]
#
#                                               stemming
# 0    [bingung, ngebedain, tipu, strategi, marketing...
# 1    [nama, tipu, gambar, isi, video, sesuai, ayo, ...
# 2                                              [adu, ]
# 3            [hall, sinyal, telkomsel, lelet, parah, ]
# 4    [telkomsel, baik, kmn, sinyal, luasin, suka, g...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261                         [telkomsel, rugi, langgan]
# 262  [ngakak, anjing, jaring, boros, lelet, beda, j...
# 263  [benerin, sistem, gua, isi, ulang, data, voche...
# 268                    [telkomsel, gimna, lag, banget]
#
# [185 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [bingung, ngebedain, tipu, strategi, marketing...
# 1    [nama, tipu, gambar, isi, video, sesuai, ayo, ...
# 2                                              [adu, ]
# 3            [hall, sinyal, telkomsel, lelet, parah, ]
# 4    [telkomsel, baik, kmn, sinyal, luasin, suka, g...
# ..                                                 ...
# 260  [please, benerin, sinyal, telkomsel, sidoarjo,...
# 261                         [telkomsel, rugi, langgan]
# 262  [ngakak, anjing, jaring, boros, lelet, beda, j...
# 263  [benerin, sistem, gua, isi, ulang, data, voche...
# 268                    [telkomsel, gimna, lag, banget]
#
# [185 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_7.xlsx')
