# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["Comments"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\databersih_english_youtube_telkomsel\databersih_english_youtube_telkomsel_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                              Comments
# 0   ['kuota', 'beli', 'susah', 'baik', 'koneksi', ...
# 1   ['telkomsel', 'parah', 'jaring', 'kacau', 'gar...
# 2                             ['sinyal', 'rumah', '']
# 3                                       ['telkomsel']
# 4   ['min', 'kemaren', 'jaring', 'ane', 'lancar', ...
# 5   ['gimana', 'indonesia', 'rawan', 'covid', 'ora...
# 6                           ['telkomsel', 'bangkrut']
# 7   ['selamat', 'menang', 'moga', 'motivasi', 'ban...
# 8                  ['maju', 'telkomsel', 'indonesia']
# 9                           ['maju', 'telkomsel', '']
# 10    ['terima', 'kasih', 'mba', 'tia', 'hutami', '']
# 11                      ['heran', 'sinyal', 'stabil']
# 12  ['kouta', 'jaring', 'kek', 'kucing', 'mending'...
# 13                      ['harga', 'sinyal', 'rendah']
# 14  ['bang', 'nomer', 'simpati', 'aktif', 'bln', '...
# 15  ['pindah', 'operator', 'guys', 'gaguna', 'kart...
# 16         ['pakae', 'telkomsel', 'hilang', 'sinyal']
# 17                   ['jaring', 'mahal', 'ampun', '']
# 18  ['telkomsel', 'ajggg', 'ngeleg', 'trus', 'kart...
# 19                                 ['sinyal', 'taik']
# 20                                            ['leg']
# 21  ['', 'noted', 'thanks', 'for', 'sharing', 'tel...
# 22  ['kartu', 'simpati', 'habis', 'aktif', 'ganti'...
# 23  ['bang', 'duit', 'gpp', 'kasih', 'terima', 'ka...
# 24  ['bagus', 'buruk', 'tambah', 'buruk', 'jaring'...
# 25  ['', 'gua', 'main', 'game', 'lag', 'parah', 't...
# 26                                   ['first', 'min']
# 27  ['lapor', 'konten', 'guna', 'konten', 'sesat',...
# 28  ['jaring', 'kaya', 'siput', 'ngak', 'betulin',...
# 29  ['assalamualaikum', 'warahmatullahi', 'wabarak...
# 30  ['telkomsel', 'byu', 'kompensasi', 'langgan', ...
# 31  ['telkomsel', 'malam', 'lag', 'siang', 'lag', ...
# 32  ['indian', 'how', 'apply', 'telkomsel', 'sim',...
# 33  ['mas', 'jelas', 'ngelag', 'main', 'game', 'pr...
# 34                       ['beli', 'subs', 'mana', '']
# 35                                     ['pan', 'tek']

# %%
df['Comments'] = df['Comments'].str.lower()
df.head(2000)
# Out:
#                                              Comments
# 0   ['kuota', 'beli', 'susah', 'baik', 'koneksi', ...
# 1   ['telkomsel', 'parah', 'jaring', 'kacau', 'gar...
# 2                             ['sinyal', 'rumah', '']
# 3                                       ['telkomsel']
# 4   ['min', 'kemaren', 'jaring', 'ane', 'lancar', ...
# 5   ['gimana', 'indonesia', 'rawan', 'covid', 'ora...
# 6                           ['telkomsel', 'bangkrut']
# 7   ['selamat', 'menang', 'moga', 'motivasi', 'ban...
# 8                  ['maju', 'telkomsel', 'indonesia']
# 9                           ['maju', 'telkomsel', '']
# 10    ['terima', 'kasih', 'mba', 'tia', 'hutami', '']
# 11                      ['heran', 'sinyal', 'stabil']
# 12  ['kouta', 'jaring', 'kek', 'kucing', 'mending'...
# 13                      ['harga', 'sinyal', 'rendah']
# 14  ['bang', 'nomer', 'simpati', 'aktif', 'bln', '...
# 15  ['pindah', 'operator', 'guys', 'gaguna', 'kart...
# 16         ['pakae', 'telkomsel', 'hilang', 'sinyal']
# 17                   ['jaring', 'mahal', 'ampun', '']
# 18  ['telkomsel', 'ajggg', 'ngeleg', 'trus', 'kart...
# 19                                 ['sinyal', 'taik']
# 20                                            ['leg']
# 21  ['', 'noted', 'thanks', 'for', 'sharing', 'tel...
# 22  ['kartu', 'simpati', 'habis', 'aktif', 'ganti'...
# 23  ['bang', 'duit', 'gpp', 'kasih', 'terima', 'ka...
# 24  ['bagus', 'buruk', 'tambah', 'buruk', 'jaring'...
# 25  ['', 'gua', 'main', 'game', 'lag', 'parah', 't...
# 26                                   ['first', 'min']
# 27  ['lapor', 'konten', 'guna', 'konten', 'sesat',...
# 28  ['jaring', 'kaya', 'siput', 'ngak', 'betulin',...
# 29  ['assalamualaikum', 'warahmatullahi', 'wabarak...
# 30  ['telkomsel', 'byu', 'kompensasi', 'langgan', ...
# 31  ['telkomsel', 'malam', 'lag', 'siang', 'lag', ...
# 32  ['indian', 'how', 'apply', 'telkomsel', 'sim',...
# 33  ['mas', 'jelas', 'ngelag', 'main', 'game', 'pr...
# 34                       ['beli', 'subs', 'mana', '']
# 35                                     ['pan', 'tek']

# %%
df['label_awal'] = ''
for i,x in df.Comments.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.0
# Index:  1 label_awal 0.0
# Index:  2 label_awal 0.0
# Index:  3 label_awal 0.0
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.0
# Index:  8 label_awal 0.0
# Index:  9 label_awal 0.0
# Index:  10 label_awal 0.0
# Index:  11 label_awal 0.0
# Index:  12 label_awal 0.0
# Index:  13 label_awal 0.0
# Index:  14 label_awal 0.0
# Index:  15 label_awal 0.0
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.0
# Index:  18 label_awal 0.0
# Index:  19 label_awal 0.0
# Index:  20 label_awal 0.0
# Index:  21 label_awal 0.6
# Index:  22 label_awal 0.0
# Index:  23 label_awal 0.0
# Index:  24 label_awal 0.0
# Index:  25 label_awal -0.11666666666666668
# Index:  26 label_awal 0.25
# Index:  27 label_awal 0.0
# Index:  28 label_awal 0.0
# Index:  29 label_awal 0.0
# Index:  30 label_awal 0.0
# Index:  31 label_awal 0.0
# Index:  32 label_awal 0.0
# Index:  33 label_awal -0.11666666666666668
# Index:  34 label_awal 0.0
# Index:  35 label_awal 0.0

# %%
df.head()
# Out:
#                                             Comments label_awal
# 0  ['kuota', 'beli', 'susah', 'baik', 'koneksi', ...        0.0
# 1  ['telkomsel', 'parah', 'jaring', 'kacau', 'gar...        0.0
# 2                            ['sinyal', 'rumah', '']        0.0
# 3                                      ['telkomsel']        0.0
# 4  ['min', 'kemaren', 'jaring', 'ane', 'lancar', ...        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    32
# -0.116667     2
#  0.600000     1
#  0.250000     1
# Name: label_awal, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] < 0.0:
        label.append("negative")
    else:
        label.append("positive")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                              Comments     label
# 0   ['kuota', 'beli', 'susah', 'baik', 'koneksi', ...  positive
# 1   ['telkomsel', 'parah', 'jaring', 'kacau', 'gar...  positive
# 2                             ['sinyal', 'rumah', '']  positive
# 3                                       ['telkomsel']  positive
# 4   ['min', 'kemaren', 'jaring', 'ane', 'lancar', ...  positive
# 5   ['gimana', 'indonesia', 'rawan', 'covid', 'ora...  positive
# 6                           ['telkomsel', 'bangkrut']  positive
# 7   ['selamat', 'menang', 'moga', 'motivasi', 'ban...  positive
# 8                  ['maju', 'telkomsel', 'indonesia']  positive
# 9                           ['maju', 'telkomsel', '']  positive
# 10    ['terima', 'kasih', 'mba', 'tia', 'hutami', '']  positive
# 11                      ['heran', 'sinyal', 'stabil']  positive
# 12  ['kouta', 'jaring', 'kek', 'kucing', 'mending'...  positive
# 13                      ['harga', 'sinyal', 'rendah']  positive
# 14  ['bang', 'nomer', 'simpati', 'aktif', 'bln', '...  positive
# 15  ['pindah', 'operator', 'guys', 'gaguna', 'kart...  positive
# 16         ['pakae', 'telkomsel', 'hilang', 'sinyal']  positive
# 17                   ['jaring', 'mahal', 'ampun', '']  positive
# 18  ['telkomsel', 'ajggg', 'ngeleg', 'trus', 'kart...  positive
# 19                                 ['sinyal', 'taik']  positive
# 20                                            ['leg']  positive
# 21  ['', 'noted', 'thanks', 'for', 'sharing', 'tel...  positive
# 22  ['kartu', 'simpati', 'habis', 'aktif', 'ganti'...  positive
# 23  ['bang', 'duit', 'gpp', 'kasih', 'terima', 'ka...  positive
# 24  ['bagus', 'buruk', 'tambah', 'buruk', 'jaring'...  positive
# 25  ['', 'gua', 'main', 'game', 'lag', 'parah', 't...  negative
# 26                                   ['first', 'min']  positive
# 27  ['lapor', 'konten', 'guna', 'konten', 'sesat',...  positive
# 28  ['jaring', 'kaya', 'siput', 'ngak', 'betulin',...  positive
# 29  ['assalamualaikum', 'warahmatullahi', 'wabarak...  positive
# 30  ['telkomsel', 'byu', 'kompensasi', 'langgan', ...  positive
# 31  ['telkomsel', 'malam', 'lag', 'siang', 'lag', ...  positive
# 32  ['indian', 'how', 'apply', 'telkomsel', 'sim',...  positive
# 33  ['mas', 'jelas', 'ngelag', 'main', 'game', 'pr...  negative
# 34                       ['beli', 'subs', 'mana', '']  positive
# 35                                     ['pan', 'tek']  positive

# %%
df['label'].value_counts()
# Out:
# positive    34
# negative     2
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_youtube_telkomsel_9.xlsx')
