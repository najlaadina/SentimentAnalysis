# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Keren Kak Putri menginspirasi sekali dan luar ...
# 1                               So inspiring, kereenn👏
# 2    A leader is not a gender, keren Kak Putri, san...
# 3    Semoga banyak perempuan yang terinspirasi kaya...
# 4    Maju terus perempuan Indonesia.., Sehat terus ...
# ..                                                 ...
# 288   Telkomsel jaringan kek tai ilang ilang GK jelass
# 289                   Udah 4G ngeleg ga jelas telkom*l
# 290                                          Pindah XL
# 291                                                  .
# 292                                                  .
#
# [293 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 60

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Keren Kak Putri menginspirasi sekali dan luar ...
# 1                               So inspiring, kereenn👏
# 2    A leader is not a gender, keren Kak Putri, san...
# 3    Semoga banyak perempuan yang terinspirasi kaya...
# 4    Maju terus perempuan Indonesia.., Sehat terus ...
# ..                                                 ...
# 278                    Keren,saya lihat video 45 detik
# 279  Lama2 sinyal telkomsel sangat sangat buruk. Di...
# 280  Memasuki musim hujan jaringan Telkomsel sering...
# 281  dari komentar yang saya baca, semua gk suka de...
# 282             Udah sinyalnya Burik Maling pulsa pula
#
# [178 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                               so inspiring, kereenn👏
# 2    a leader is not a gender, keren kak putri, san...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia.., sehat terus ...
# ..                                                 ...
# 278                    keren,saya lihat video 45 detik
# 279  lama2 sinyal telkomsel sangat sangat buruk. di...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca, semua gk suka de...
# 282             udah sinyalnya burik maling pulsa pula
#
# [178 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                               so inspiring, kereenn👏
# 2    a leader is not a gender, keren kak putri, san...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia.., sehat terus ...
# ..                                                 ...
# 278                    keren,saya lihat video 45 detik
# 279  lama2 sinyal telkomsel sangat sangat buruk. di...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca, semua gk suka de...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                       cleaning_comment
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                                   inspiring kereenn
# 2     leader not gender keren kak putri sangat meng...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia sehat terus pak...
# ..                                                 ...
# 278                       keren saya lihat video detik
# 279  lama  sinyal telkomsel sangat sangat buruk dae...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca semua suka dengan...
# 282             udah sinyalnya burik maling pulsa pula
#
# [178 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                               so inspiring, kereenn👏
# 2    a leader is not a gender, keren kak putri, san...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia.., sehat terus ...
# ..                                                 ...
# 278                    keren,saya lihat video 45 detik
# 279  lama2 sinyal telkomsel sangat sangat buruk. di...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca, semua gk suka de...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                       cleaning_comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                                   inspiring kereenn
# 2     leader not gender keren kak putri sangat meng...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia sehat terus pak...
# ..                                                 ...
# 278                       keren saya lihat video detik
# 279  lama  sinyal telkomsel sangat sangat buruk dae...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca semua suka dengan...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                             tokenisasi
# 0    [keren, kak, putri, menginspirasi, sekali, dan...
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, san...
# 3    [semoga, banyak, perempuan, yang, terinspirasi...
# 4    [maju, terus, perempuan, indonesia, sehat, ter...
# ..                                                 ...
# 278                 [keren, saya, lihat, video, detik]
# 279  [lama, sinyal, telkomsel, sangat, sangat, buru...
# 280  [memasuki, musim, hujan, jaringan, telkomsel, ...
# 281  [dari, komentar, yang, saya, baca, semua, suka...
# 282      [udah, sinyalnya, burik, maling, pulsa, pula]
#
# [178 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                               so inspiring, kereenn👏
# 2    a leader is not a gender, keren kak putri, san...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia.., sehat terus ...
# ..                                                 ...
# 278                    keren,saya lihat video 45 detik
# 279  lama2 sinyal telkomsel sangat sangat buruk. di...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca, semua gk suka de...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                       cleaning_comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                                   inspiring kereenn
# 2     leader not gender keren kak putri sangat meng...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia sehat terus pak...
# ..                                                 ...
# 278                       keren saya lihat video detik
# 279  lama  sinyal telkomsel sangat sangat buruk dae...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca semua suka dengan...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                             tokenisasi  \
# 0    [keren, kak, putri, menginspirasi, sekali, dan...
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, san...
# 3    [semoga, banyak, perempuan, yang, terinspirasi...
# 4    [maju, terus, perempuan, indonesia, sehat, ter...
# ..                                                 ...
# 278                 [keren, saya, lihat, video, detik]
# 279  [lama, sinyal, telkomsel, sangat, sangat, buru...
# 280  [memasuki, musim, hujan, jaringan, telkomsel, ...
# 281  [dari, komentar, yang, saya, baca, semua, suka...
# 282      [udah, sinyalnya, burik, maling, pulsa, pula]
#
#                                               stopword
# 0    [keren, kak, putri, menginspirasi, pengalaman,...
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, men...
# 3    [semoga, perempuan, terinspirasi, kaya, putri,...
# 4    [maju, perempuan, indonesia, sehat, hms, leade...
# ..                                                 ...
# 278                       [keren, lihat, video, detik]
# 279  [sinyal, telkomsel, buruk, daerahku, mohon, pe...
# 280  [memasuki, musim, hujan, jaringan, telkomsel, ...
# 281  [komentar, baca, suka, jaringan, telkomsel, ke...
# 282            [udah, sinyalnya, burik, maling, pulsa]
#
# [178 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 629
# ------------------------
# keren : keren
# kak : kak
# putri : putri
# menginspirasi : inspirasi
# pengalaman : alam
# ceo : ceo
# sehari : hari
#  :
# inspiring : inspiring
# kereenn : kereenn
# leader : leader
# not : not
# gender : gender
# hms : hms
# telkomsel : telkomsel
# semoga : moga
# perempuan : perempuan
# terinspirasi : inspirasi
# kaya : kaya
# perasaannya : asa
# yahhh : yahhh
# aaaa : aaaa
# pengenn : pengenn
# maju : maju
# indonesia : indonesia
# sehat : sehat
# religious : religious
# gils : gils
# tips : tips
# trik : trik
# gimana : gimana
# barakallahu : barakallahu
# fikum : fikum
# girl : girl
# please : please
# berbenah : benah
# tuk : tuk
# jaringan : jaring
# sinyal : sinyal
# minggu : minggu
# habis : habis
# hujan : hujan
# drop : drop
# timbul : timbul
# hilang : hilang
# ngapain : ngapain
# berjam : jam
# jam : jam
# aman : aman
# hujam : hujam
# lebat : lebat
# angin : angin
# petir : petir
# pelanggan : langgan
# kecewa : kecewa
# pindah : pindah
# provider : provider
# trims : trims
# sukses : sukses
# mao : mao
# perbaikan : baik
# signal : signal
# daerah : daerah
# cepet : cepet
# bangt : bangt
# bagus : bagus
# makasih : makasih
# buruan : buru
# teman : teman
# daftar : daftar
# agen : agen
# reseller : reseller
# plis : plis
# benerin : benerin
# pas : pas
# oke : oke
# sinyalnya : sinyal
# nglag : nglag
# kayak : kayak
# tower : tower
# deket : deket
# kl : kl
# banget : banget
# tolong : tolong
# selamat : selamat
# kampung : kampung
# gorowong : gorowong
# desa : desa
# maroko : maroko
# kecamatan : camat
# cibalong : cibalong
# kabupaten : kabupaten
# garut : garut
# provinsi : provinsi
# jawabarat : jawabarat
# awesome : awesome
# asalamu : asalamu
# alaikum : alaikum
# kebada : bada
# tim : tim
# melaporkan : lapor
# udah : udah
# ciangireun : ciangireun
# girijagabaya : girijagabaya
# muncang : muncang
# lebak : lebak
# banten : banten
# mohon : mohon
# perluas : luas
# apk : apk
# kouta : kouta
# ketengan : keteng
# mikir : mikir
# dlu : dlu
# harga : harga
# paket : paket
# selangit : langit
# main : main
# game : game
# merah : merah
# hijau : hijau
# skrng : skrng
# gaya : gaya
# kalah : kalah
# nasip : nasip
# tanda : tanda
# layanan : layan
# lelet : lelet
# mesti : mesti
# kartu : kartu
# paa : paa
# gua : gua
# maen : maen
# lancar : lancar
# donk : donk
# benahi : benah
# mulu : mulu
# perbaiki : baik
# didaerah : daerah
# terpencil : pencil
# diurusin : diurusin
# kota : kota
# doang : doang
# diurus : urus
# termahal : mahal
# terngelag : terngelag
# telkom : telkom
# buruk : buruk
# stabil : stabil
# area : area
# jepara : jepara
# miris : miris
# taikk : taikk
# woii : woii
# klw : klw
# problem : problem
# gamers : gamers
# tersiksa : siksa
# karyu : karyu
# kek : kek
# gini : gin
# sabar : sabar
# sabarin : sabarin
# sampe : sampe
# masi : mas
# orang : orang
# langsung : langsung
# down : down
# ngntl : ngntl
# sesuai : sesuai
# kualitas : kualitas
# plsss : plsss
# customer : customer
# komplain : komplain
# tanggapin : tanggapin
# gmn : gmn
# respon : respon
# pusat : pusat
# pakai : pakai
# youtube : youtube
# lag : lag
# maksudnya : maksud
# halo : halo
# min : min
# mobile : mobile
# legend : legend
# sore : sore
# urusin : urusin
# beli : beli
# kuota : kuota
# cuman : cuman
# ngerti : ngerti
# lgi : lgi
# ama : ama
# ngeleg : ngeleg
# ngejam : ngejam
# gangguan : ganggu
# kah : kah
# ngelag : ngelag
# bangat : bangat
# luu : luu
# mending : mending
# ilangin : ilangin
# kyak : kyak
# snyal : snyal
# ajg : ajg
# woi : woi
# sampah : sampah
# cokkkk : cokkkk
# leg : leg
# heh : heh
# telkomnyet : telkomnyet
# dipelosok : pelosok
# suka : suka
# ilang : ilang
# napa : napa
# meraanti : meraanti
# jaya : jaya
# alh : alh
# bangsat : bangsat
# bat : bat
# buk : buk
# anjj : anjj
# pengen : ken
# bangkrut : bangkrut
# ajal : ajal
# ijo : ijo
# detik : detik
# ganti : ganti
# sedetik : detik
# nge : nge
# coba : coba
# live : live
# steaming : steaming
# nonton : nonton
# karna : karna
# super : super
# cepat : cepat
# ngebut : ngebut
# gila : gila
# korona : korona
# speed : speed
# mbps : mbps
# keong : keong
# kbps : kbps
# nggak : nggak
# labil : labil
# terima : terima
# kasih : kasih
# memakai : pakai
# bermain : main
# kasar : kasar
# axis : axis
# tri : tri
# bar : bar
# paketan : paket
# murah : murah
# rb : rb
# gb : gb
# anti : anti
# lagnya : lagnya
# beban : beban
# sinyalmu : sinyal
# cok : cok
# pejabat : jabat
# merakyat : rakyat
# jaringannya : jaring
# kenceng : kenceng
# online : online
# sosmed : sosmed
# komunikasi : komunikasi
# lancaaaaar : lancaaaaar
# im : im
# ooreeedoo : ooreeedoo
# perusahaan : usaha
# bumn : bumn
# pebih : pebih
# beralih : alih
# pemasukan : pasu
# negara : negara
# swasta : swasta
# operator : operator
# ttep : ttep
# telfin : telfin
# data : data
# dipake : dipake
# pubg : pubg
# berkurang : kurang
# utama : utama
# jmbt : jmbt
# nggk : nggk
# lucu : lucu
# bet : bet
# allah : allah
# kabulkan : kabul
# permintaan : minta
# btw : btw
# crt : crt
# koq : koq
# menurunkan : turun
# rank : rank
# peningkatan : tingkat
# kelurahan : lurah
# tamansari : tamansari
# kec : kec
# bondowoso : bondowoso
# kab : kab
# terimakasih : terimakasih
# minus : minus
# ampas : ampas
# males : males
# wow : wow
# cepattt : cepattt
# nasa : nasa
# sihh : sihh
# lawaann : lawaann
# sangatt : sangatt
# sangaaatt : sangaaatt
# cacaddd : cacaddd
# trimakasih : trimakasih
# matamu : mata
# gda : gda
# org : org
# stres : stres
# ditempat : tempat
# exis : exis
# hati : hati
# silver : silver
# ribu : ribu
# kedok : kedok
# top : top
# diamond : diamond
# bonus : bonus
# nganggur : nganggur
# dahlah : dah
# auto : auto
# niih : niih
# diperbaiki : baik
# sumpah : sumpah
# rekomen : rekomen
# karuan : karuan
# parah : parah
# full : full
# tetep : tetep
# kadang : kadang
# permasalahan : masalah
# jaga : jaga
# kepercayaan : percaya
# seminggu : minggu
# internet : internet
# gara : gara
# daerahku : daerah
# internetan : internetan
# gamemax : gamemax
# masuk : masuk
# ngerank : ngerank
# pndah : pndah
# kampret : kampret
# penipu : tipu
# langganan : langgan
# trs : trs
# berubah : ubah
# sialan : sial
# tempet : tempet
# kos : kos
# pulang : pulang
# kerumah : rumah
# capet : capet
# marah : marah
# bakar : bakar
# sim : sim
# hahaha : hahaha
# gamesmax : gamesmax
# login : login
# masak : masak
# mie : mie
# loby : loby
# kalimantan : kalimantan
# nyesel : nyesel
# turbo : turbo
# yes : yes
# oowhh : oowhh
# pantes : pantes
# wkwkwkkwkwkk : wkwkwkkwkwkk
# iklan : iklan
# nipu : nipu
# darimana : darimana
# games : games
# ampun : ampun
# providers : providers
# ngimpi : ngimpi
# woy : woy
# pikirin : pikirin
# jateng : jateng
# purbalingga : purbalingga
# dosa : dosa
# burik : burik
# supeeeer : supeeeer
# pokoknya : pokok
# legnya : legnya
# obat : obat
# niat : niat
# promo : promo
# dibully : dibully
# muna : muna
# promosi : promosi
# halu : halu
# fakta : fakta
# minum : minum
# penipuan : tipu
# nie : nie
# pergi : pergi
# konter : konter
# halah : halah
# gmax : gmax
# pubgm : pubgm
# dihapus : hapus
# dukungan : dukung
# habisin : habisin
# uang : uang
# ndk : ndk
# membadut : badut
# club : club
# penjabat : jabat
# berani : berani
# beraninya : berani
# pembodohan : bodoh
# ikhlas : ikhlas
# duit : duit
# gamemek : gamemek
# makan : makan
# haram : haram
# penyakit : sakit
# losestreak : losestreak
# halahhhh : halahhhh
# tsel : tsel
# emang : emang
# konsumen : konsumen
# card : card
# laen : laen
# mantaappssss : mantaappssss
# plus : plus
# hihihi : hihihi
# cman : cman
# ngebacod : ngebacod
# warganet : warganet
# mnding : mnding
# klean : klean
# lumayan : lumayan
# dri : dri
# murahan : murah
# rajanya : raja
# udh : udh
# mahal : mahal
# indosat : indosat
# njirr : njirr
# singnyal : singnyal
# jelasin : jelasin
# maaf : maaf
# pulsa : pulsa
# trus : trus
# terpotong : potong
# berkembang : kembang
# pesat : pesat
# max : max
# trikomsel : trikomsel
# accesoris : accesoris
# berkualitas : kualitas
# rumah : rumah
# dasar : dasar
# buka : buka
# yutube : yutube
# susah : susah
# loading : loading
# abis : abis
# emosi : emosi
# kapok : kapok
# makek : makek
# telkomsem : telkomsem
# palsu : palsu
# pket : pket
# bsa : bsa
# epep : epep
# dll : dll
# slot : slot
# doank : doank
# terburuk : buruk
# najis : najis
# untung : untung
# najisss : najisss
# darurat : darurat
# jir : jir
# judul : judul
# nga : nga
# ngelek : ngelek
# salto : salto
# dikali : kali
# laut : laut
# mesisan : mesisan
# pala : pala
# kau : kau
# ping : ping
# jumping : jumping
# gitu : gitu
# buset : buset
# komen : komen
# temen : temen
# kesel : kesel
# beud : beud
# propider : propider
# senasib : nasib
# ngab : ngab
# aplikasi : aplikasi
# server : server
# takut : takut
# kakku : kak
# wkwkwk : wkwkwk
# gabisa : gabisa
# jalan : jalan
# video : video
# terbaru : baru
# candaan : canda
# ruang : ruang
# nyaaaa : nyaaaa
# skrg : skrg
# wkkkkk : wkkkkk
# bkin : bkin
# ngakak : ngakak
# iya : iya
# ngelawak : ngelawak
# deh : deh
# info : info
# telkomsell : telkomsell
# sammpah : sammpah
# sesek : sek
# kekk : kekk
# taeek : taeek
# war : war
# kuning : kuning
# giliran : gilir
# mati : mati
# glory : glory
# lose : lose
# streak : streak
# smpe : smpe
# aso : aso
# bercanda : canda
# abal : abal
# gajelas : gajelas
# lawak : lawak
# gamesnya : gamesnya
# taekk : taekk
# kredit : kredit
# skor : skor
# gue : gue
# tutup : tutup
# kantor : kantor
# balikin : balikin
# rusak : rusak
# isi : isi
# keluhan : keluh
# gokil : gokil
# ulang : ulang
# apalgi : apalgi
# dijam : jam
# istrht : istrht
# krja : krja
# upgred : upgred
# publik : publik
# hadeh : hadeh
# ancur : ancur
# telkosem : telkosem
# trusssss : trusssss
# guys : guys
# mytik : mytik
# turun : turun
# jaringab : jaringab
# nyh : nyh
# upgrade : upgrade
# beda : beda
# sakti : sakti
# hei : hei
# kru : kru
# wsbk : wsbk
# beredar : edar
# antri : antri
# perdana : perdana
# bandara : bandara
# mengeluh : keluh
# jaringanmu : jaring
# pengguna : guna
# keberatan : berat
# mala : mala
# ngalami : ngalami
# error : error
# koala : koala
# nyaman : nyaman
# memiliki : milik
# sedot : sedot
# kepotong : potong
# alasannya : alas
# dimatikan : mati
# konek : konek
# terhutang : hutang
# dipotong : potong
# rakyat : rakyat
# pemaksaan : paksa
# namanya : nama
# rii : rii
# sinyale : sinyale
# bosok : bosok
# jawa : jawa
# troll : troll
# asw : asw
# tot : tot
# kendala : kendala
# kemarin : kemarin
# bulanan : bulan
# sungguh : sungguh
# dimohon : mohon
# jabar : jabar
# tasikmalaya : tasikmalaya
# ngleg : ngleg
# lihat : lihat
# memasuki : pasuk
# musim : musim
# komentar : komentar
# baca : baca
# maling : maling
# {'keren': 'keren', 'kak': 'kak', 'putri': 'putri', 'menginspirasi': 'inspirasi', 'pengalaman': 'alam', 'ceo': 'ceo', 'sehari': 'hari', '': '', 'inspiring': 'inspiring', 'kereenn': 'kereenn', 'leader': 'leader', 'not': 'not', 'gender': 'gender', 'hms': 'hms', 'telkomsel': 'telkomsel', 'semoga': 'moga', 'perempuan': 'perempuan', 'terinspirasi': 'inspirasi', 'kaya': 'kaya', 'perasaannya': 'asa', 'yahhh': 'yahhh', 'aaaa': 'aaaa', 'pengenn': 'pengenn', 'maju': 'maju', 'indonesia': 'indonesia', 'sehat': 'sehat', 'religious': 'religious', 'gils': 'gils', 'tips': 'tips', 'trik': 'trik', 'gimana': 'gimana', 'barakallahu': 'barakallahu', 'fikum': 'fikum', 'girl': 'girl', 'please': 'please', 'berbenah': 'benah', 'tuk': 'tuk', 'jaringan': 'jaring', 'sinyal': 'sinyal', 'minggu': 'minggu', 'habis': 'habis', 'hujan': 'hujan', 'drop': 'drop', 'timbul': 'timbul', 'hilang': 'hilang', 'ngapain': 'ngapain', 'berjam': 'jam', 'jam': 'jam', 'aman': 'aman', 'hujam': 'hujam', 'lebat': 'lebat', 'angin': 'angin', 'petir': 'petir', 'pelanggan': 'langgan', 'kecewa': 'kecewa', 'pindah': 'pindah', 'provider': 'provider', 'trims': 'trims', 'sukses': 'sukses', 'mao': 'mao', 'perbaikan': 'baik', 'signal': 'signal', 'daerah': 'daerah', 'cepet': 'cepet', 'bangt': 'bangt', 'bagus': 'bagus', 'makasih': 'makasih', 'buruan': 'buru', 'teman': 'teman', 'daftar': 'daftar', 'agen': 'agen', 'reseller': 'reseller', 'plis': 'plis', 'benerin': 'benerin', 'pas': 'pas', 'oke': 'oke', 'sinyalnya': 'sinyal', 'nglag': 'nglag', 'kayak': 'kayak', 'tower': 'tower', 'deket': 'deket', 'kl': 'kl', 'banget': 'banget', 'tolong': 'tolong', 'selamat': 'selamat', 'kampung': 'kampung', 'gorowong': 'gorowong', 'desa': 'desa', 'maroko': 'maroko', 'kecamatan': 'camat', 'cibalong': 'cibalong', 'kabupaten': 'kabupaten', 'garut': 'garut', 'provinsi': 'provinsi', 'jawabarat': 'jawabarat', 'awesome': 'awesome', 'asalamu': 'asalamu', 'alaikum': 'alaikum', 'kebada': 'bada', 'tim': 'tim', 'melaporkan': 'lapor', 'udah': 'udah', 'ciangireun': 'ciangireun', 'girijagabaya': 'girijagabaya', 'muncang': 'muncang', 'lebak': 'lebak', 'banten': 'banten', 'mohon': 'mohon', 'perluas': 'luas', 'apk': 'apk', 'kouta': 'kouta', 'ketengan': 'keteng', 'mikir': 'mikir', 'dlu': 'dlu', 'harga': 'harga', 'paket': 'paket', 'selangit': 'langit', 'main': 'main', 'game': 'game', 'merah': 'merah', 'hijau': 'hijau', 'skrng': 'skrng', 'gaya': 'gaya', 'kalah': 'kalah', 'nasip': 'nasip', 'tanda': 'tanda', 'layanan': 'layan', 'lelet': 'lelet', 'mesti': 'mesti', 'kartu': 'kartu', 'paa': 'paa', 'gua': 'gua', 'maen': 'maen', 'lancar': 'lancar', 'donk': 'donk', 'benahi': 'benah', 'mulu': 'mulu', 'perbaiki': 'baik', 'didaerah': 'daerah', 'terpencil': 'pencil', 'diurusin': 'diurusin', 'kota': 'kota', 'doang': 'doang', 'diurus': 'urus', 'termahal': 'mahal', 'terngelag': 'terngelag', 'telkom': 'telkom', 'buruk': 'buruk', 'stabil': 'stabil', 'area': 'area', 'jepara': 'jepara', 'miris': 'miris', 'taikk': 'taikk', 'woii': 'woii', 'klw': 'klw', 'problem': 'problem', 'gamers': 'gamers', 'tersiksa': 'siksa', 'karyu': 'karyu', 'kek': 'kek', 'gini': 'gin', 'sabar': 'sabar', 'sabarin': 'sabarin', 'sampe': 'sampe', 'masi': 'mas', 'orang': 'orang', 'langsung': 'langsung', 'down': 'down', 'ngntl': 'ngntl', 'sesuai': 'sesuai', 'kualitas': 'kualitas', 'plsss': 'plsss', 'customer': 'customer', 'komplain': 'komplain', 'tanggapin': 'tanggapin', 'gmn': 'gmn', 'respon': 'respon', 'pusat': 'pusat', 'pakai': 'pakai', 'youtube': 'youtube', 'lag': 'lag', 'maksudnya': 'maksud', 'halo': 'halo', 'min': 'min', 'mobile': 'mobile', 'legend': 'legend', 'sore': 'sore', 'urusin': 'urusin', 'beli': 'beli', 'kuota': 'kuota', 'cuman': 'cuman', 'ngerti': 'ngerti', 'lgi': 'lgi', 'ama': 'ama', 'ngeleg': 'ngeleg', 'ngejam': 'ngejam', 'gangguan': 'ganggu', 'kah': 'kah', 'ngelag': 'ngelag', 'bangat': 'bangat', 'luu': 'luu', 'mending': 'mending', 'ilangin': 'ilangin', 'kyak': 'kyak', 'snyal': 'snyal', 'ajg': 'ajg', 'woi': 'woi', 'sampah': 'sampah', 'cokkkk': 'cokkkk', 'leg': 'leg', ...
# ------------------------
# Pandas Apply:   0%|          | 0/178 [00:00<?, ?it/s]
#                                                comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                               so inspiring, kereenn👏
# 2    a leader is not a gender, keren kak putri, san...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia.., sehat terus ...
# ..                                                 ...
# 278                    keren,saya lihat video 45 detik
# 279  lama2 sinyal telkomsel sangat sangat buruk. di...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca, semua gk suka de...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                       cleaning_comment  \
# 0    keren kak putri menginspirasi sekali dan luar ...
# 1                                   inspiring kereenn
# 2     leader not gender keren kak putri sangat meng...
# 3    semoga banyak perempuan yang terinspirasi kaya...
# 4    maju terus perempuan indonesia sehat terus pak...
# ..                                                 ...
# 278                       keren saya lihat video detik
# 279  lama  sinyal telkomsel sangat sangat buruk dae...
# 280  memasuki musim hujan jaringan telkomsel sering...
# 281  dari komentar yang saya baca semua suka dengan...
# 282             udah sinyalnya burik maling pulsa pula
#
#                                             tokenisasi  \
# 0    [keren, kak, putri, menginspirasi, sekali, dan...
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, san...
# 3    [semoga, banyak, perempuan, yang, terinspirasi...
# 4    [maju, terus, perempuan, indonesia, sehat, ter...
# ..                                                 ...
# 278                 [keren, saya, lihat, video, detik]
# 279  [lama, sinyal, telkomsel, sangat, sangat, buru...
# 280  [memasuki, musim, hujan, jaringan, telkomsel, ...
# 281  [dari, komentar, yang, saya, baca, semua, suka...
# 282      [udah, sinyalnya, burik, maling, pulsa, pula]
#
#                                               stopword  \
# 0    [keren, kak, putri, menginspirasi, pengalaman,...
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, men...
# 3    [semoga, perempuan, terinspirasi, kaya, putri,...
# 4    [maju, perempuan, indonesia, sehat, hms, leade...
# ..                                                 ...
# 278                       [keren, lihat, video, detik]
# 279  [sinyal, telkomsel, buruk, daerahku, mohon, pe...
# 280  [memasuki, musim, hujan, jaringan, telkomsel, ...
# 281  [komentar, baca, suka, jaringan, telkomsel, ke...
# 282            [udah, sinyalnya, burik, maling, pulsa]
#
#                                               stemming
# 0    [keren, kak, putri, inspirasi, alam, ceo, hari, ]
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, ins...
# 3    [moga, perempuan, inspirasi, kaya, putri, asa,...
# 4    [maju, perempuan, indonesia, sehat, hms, leade...
# ..                                                 ...
# 278                       [keren, lihat, video, detik]
# 279  [sinyal, telkomsel, buruk, daerah, mohon, baik...
# 280  [pasuk, musim, hujan, jaring, telkomsel, bange...
# 281  [komentar, baca, suka, jaring, telkomsel, kek,...
# 282               [udah, sinyal, burik, maling, pulsa]
#
# [178 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [keren, kak, putri, inspirasi, alam, ceo, hari, ]
# 1                             [, inspiring, kereenn, ]
# 2    [, leader, not, gender, keren, kak, putri, ins...
# 3    [moga, perempuan, inspirasi, kaya, putri, asa,...
# 4    [maju, perempuan, indonesia, sehat, hms, leade...
# ..                                                 ...
# 278                       [keren, lihat, video, detik]
# 279  [sinyal, telkomsel, buruk, daerah, mohon, baik...
# 280  [pasuk, musim, hujan, jaring, telkomsel, bange...
# 281  [komentar, baca, suka, jaring, telkomsel, kek,...
# 282               [udah, sinyal, burik, maling, pulsa]
#
# [178 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_10.xlsx')
