# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_INDIHOME\data_mentah\youtube_indihome_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Dengan adanya series ini, saya memantapkan dir...
# 1    Goks abis, btw ini dari sudut pandang aku tete...
# 2    Mudah mudahan series nya bisa menyaingi episod...
# 3                                Pak turah pak turah🤣🤣
# 4    Ayolah Indihome! Perusahaan sebesar ini masa t...
# ..                                                 ...
# 359                                       Dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 361  Kenapa indihome memasukan biaya telpon,padahal...
# 362  Kenapa indihome memasukan biaya telpon,padahal...
# 363  Akhirnya setelah melihat series ini internet d...
#
# [364 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 35

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 2    Mudah mudahan series nya bisa menyaingi episod...
# 3                                Pak turah pak turah🤣🤣
# 4    Ayolah Indihome! Perusahaan sebesar ini masa t...
# 5                                    Ketahuilah bahwa:
# 6    Keren lah mereka bertiga, apalagi Mas mas Madu...
# ..                                                 ...
# 357  Ada yang merasa gak di menit 1.00 dan mengguna...
# 358  Jangan Lupa di Subscribe buat Support Respect ...
# 359                                       Dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  Akhirnya setelah melihat series ini internet d...
#
# [296 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                pak turah pak turah🤣🤣
# 4    ayolah indihome! perusahaan sebesar ini masa t...
# 5                                    ketahuilah bahwa:
# 6    keren lah mereka bertiga, apalagi mas mas madu...
# ..                                                 ...
# 357  ada yang merasa gak di menit 1.00 dan mengguna...
# 358  jangan lupa di subscribe buat support respect ...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
# [296 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                pak turah pak turah🤣🤣
# 4    ayolah indihome! perusahaan sebesar ini masa t...
# 5                                    ketahuilah bahwa:
# 6    keren lah mereka bertiga, apalagi mas mas madu...
# ..                                                 ...
# 357  ada yang merasa gak di menit 1.00 dan mengguna...
# 358  jangan lupa di subscribe buat support respect ...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                       cleaning_comment
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                 pak turah pak turah
# 4    ayolah indihome perusahaan sebesar ini masa ti...
# 5                                    ketahuilah bahwa
# 6    keren lah mereka bertiga apalagi mas mas madur...
# ..                                                 ...
# 357  ada yang merasa gak menit dan menggunakan subt...
# 358  jangan lupa subscribe buat support respect ser...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
# [296 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                pak turah pak turah🤣🤣
# 4    ayolah indihome! perusahaan sebesar ini masa t...
# 5                                    ketahuilah bahwa:
# 6    keren lah mereka bertiga, apalagi mas mas madu...
# ..                                                 ...
# 357  ada yang merasa gak di menit 1.00 dan mengguna...
# 358  jangan lupa di subscribe buat support respect ...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                       cleaning_comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                 pak turah pak turah
# 4    ayolah indihome perusahaan sebesar ini masa ti...
# 5                                    ketahuilah bahwa
# 6    keren lah mereka bertiga apalagi mas mas madur...
# ..                                                 ...
# 357  ada yang merasa gak menit dan menggunakan subt...
# 358  jangan lupa subscribe buat support respect ser...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                             tokenisasi
# 2    [mudah, mudahan, series, nya, bisa, menyaingi,...
# 3                           [pak, turah, pak, turah, ]
# 4    [ayolah, indihome, perusahaan, sebesar, ini, m...
# 5                                [ketahuilah, bahwa, ]
# 6    [keren, lah, mereka, bertiga, apalagi, mas, ma...
# ..                                                 ...
# 357  [ada, yang, merasa, gak, menit, dan, menggunak...
# 358  [jangan, lupa, subscribe, buat, support, respe...
# 359                                    [dustin, ohang]
# 360  [uang, produksinya, mending, buat, stabilin, j...
# 363  [akhirnya, setelah, melihat, series, ini, inte...
#
# [296 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                pak turah pak turah🤣🤣
# 4    ayolah indihome! perusahaan sebesar ini masa t...
# 5                                    ketahuilah bahwa:
# 6    keren lah mereka bertiga, apalagi mas mas madu...
# ..                                                 ...
# 357  ada yang merasa gak di menit 1.00 dan mengguna...
# 358  jangan lupa di subscribe buat support respect ...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                       cleaning_comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                 pak turah pak turah
# 4    ayolah indihome perusahaan sebesar ini masa ti...
# 5                                    ketahuilah bahwa
# 6    keren lah mereka bertiga apalagi mas mas madur...
# ..                                                 ...
# 357  ada yang merasa gak menit dan menggunakan subt...
# 358  jangan lupa subscribe buat support respect ser...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                             tokenisasi  \
# 2    [mudah, mudahan, series, nya, bisa, menyaingi,...
# 3                           [pak, turah, pak, turah, ]
# 4    [ayolah, indihome, perusahaan, sebesar, ini, m...
# 5                                [ketahuilah, bahwa, ]
# 6    [keren, lah, mereka, bertiga, apalagi, mas, ma...
# ..                                                 ...
# 357  [ada, yang, merasa, gak, menit, dan, menggunak...
# 358  [jangan, lupa, subscribe, buat, support, respe...
# 359                                    [dustin, ohang]
# 360  [uang, produksinya, mending, buat, stabilin, j...
# 363  [akhirnya, setelah, melihat, series, ini, inte...
#
#                                               stopword
# 2    [mudah, mudahan, series, menyaingi, episode, s...
# 3                                     [turah, turah, ]
# 4    [ayolah, indihome, perusahaan, sanggup, memiku...
# 5                                       [ketahuilah, ]
# 6                 [keren, bertiga, mas, mas, madura, ]
# ..                                                 ...
# 357  [menit, subtitel, tulisan, kupu, kupu, muhamma...
# 358  [lupa, subscribe, support, respect, series, tt...
# 359                                    [dustin, ohang]
# 360  [uang, produksinya, mending, stabilin, jaringa...
# 363               [series, internet, dirumah, kencang]
#
# [296 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 746
# ------------------------
# mudah : mudah
# mudahan : mudah
# series : series
# menyaingi : saing
# episode : episode
# sinetron : sinetron
# tukang : tukang
# haji : haji
# bubur : bubur
#  :
# turah : turah
# ayolah : ayo
# indihome : indihome
# perusahaan : usaha
# sanggup : sanggup
# memikul : pikul
# jokes : jokes
# tepi : tepi
# jurang : jurang
# ketahuilah : tahu
# keren : keren
# bertiga : tiga
# mas : mas
# madura : madura
# nonton : nonton
# lgsg : lgsg
# nonstop : nonstop
# kualitas : kualitas
# buffer : buffer
# terima : terima
# kasih : kasih
# biznet : biznet
# mempermudah : mudah
# akses : akses
# hiburan : hibur
# eps : eps
# sampe : sampe
# wifi : wifi
# sampah : sampah
# gaggunaaaaaaa : gaggunaaaaaaa
# mantap : mantap
# udh : udh
# pakek : pakek
# wiuuu : wiuuu
# kalahkan : kalah
# tersanjung : sanjung
# cinta : cinta
# fitri : fitri
# tersayang : sayang
# termehek : termehek
# mehek : mehek
# gua : gua
# mail : mail
# game : game
# ngelag : ngelag
# mohon : mohon
# solusinya : solusi
# iya : iya
# wifinya : wifinya
# lemot : lot
# jing : jing
# perbaikin : perbaikin
# jaringan : jaring
# kontolllk : kontolllk
# sinyal : sinyal
# setabil : setabil
# indihomo : indihomo
# ajg : ajg
# kntool : kntool
# kntoll : kntoll
# gws : gws
# sinyalll : sinyalll
# pas : pas
# buka : buka
# web : web
# err : err
# ssl : ssl
# protocol : protocol
# kek : kek
# mobil : mobil
# mogok : mogok
# lag : lag
# lohhh : lohhh
# nihhh : nihhh
# perbaikan : baik
# nyaaa : nyaaa
# atur : atur
# internet : internet
# abisin : abisin
# duit : duit
# taik : taik
# bettttttt : bettttttt
# ajggg : ajggg
# bang : bang
# mulu : mulu
# main : main
# aslinya : asli
# maniac : maniac
# ehh : ehh
# donk : donk
# ngasih : ngasih
# bagus : bagus
# hey : hey
# lanjutan : lanjut
# saaaat : saaaat
# semoga : moga
# bangkrut : bangkrut
# amin : amin
# saben : saben
# dasar : dasar
# indigay : indigay
# nyesel : nyesel
# beli : beli
# mending : mending
# paket : paket
# nge : nge
# admin : admin
# tolong : tolong
# perbaiki : baik
# hujan : hujan
# karna : karna
# rumah : rumah
# kalu : kalu
# bekasi : bekas
# ngeleg : ngeleg
# aplikasi : aplikasi
# youtube : youtube
# ilang : ilang
# knapa : knapa
# min : min
# anak : anak
# benerin : benerin
# jaringannya : jaring
# bener : bener
# dikit : dikit
# udah : udah
# bayar : bayar
# gapernah : gapernah
# dibikin : bikin
# puas : puas
# ama : ama
# koneksinya : koneksi
# woi : woi
# cuman : cuman
# gangguan : ganggu
# alfamart : alfamart
# ovo : ovo
# putusin : putusin
# hadehhh : hadehhh
# leg : leg
# turahhhhhh : turahhhhhh
# knp : knp
# pesen : sen
# mbps : mbps
# dapet : dapet
# penipuann : penipuann
# ketauilah : tau
# pelanggan : langgan
# dateng : dateng
# malam : malam
# teknisi : teknisi
# jam : jam
# lembur : lembur
# dimana : mana
# bangs : bangs
# indickhome : indickhome
# kuulangi : ulang
# bodoh : bodoh
# kali : kali
# mati : mati
# makan : makan
# gaji : gaji
# haram : haram
# asli : asli
# trouble : trouble
# gatau : gatau
# kecepatan : cepat
# unduh : unduh
# mb : mb
# salah : salah
# dosa : dosa
# telat : telat
# njiirrrrrr : njiirrrrrr
# maaf : maaf
# inihome : inihome
# bagusi : bagus
# kesel : kesel
# ping : ping
# indih : indih
# hahahahahahahhaahhahahaha : hahahahahahahhaahhahahaha
# sosok : sosok
# dikehidupan : hidup
# nyata : nyata
# judul : judul
# what : what
# the : the
# fyck : fyck
# haruss : haruss
# gas : gas
# trus : trus
# webtoon : webtoon
# voice : voice
# indonesia : indonesia
# kebanyakan : banyak
# konten : konten
# malem : malem
# ganggu : ganggu
# push : push
# rank : rank
# meme : meme
# beredar : edar
# sosmed : sosmed
# bukak : bukak
# maskernya : masker
# biarpun : biarpun
# ekting : ekting
# sesak : sesak
# mkn : mkn
# maskeran : masker
# logat : logat
# balinya : bal
# gabisa : gabisa
# lepas : lepas
# sumpahhhh : sumpahhhh
# netizen : netizen
# jaman : jaman
# now : now
# langsung : langsung
# posting : posting
# hahaha : hahaha
# bnyk : bnyk
# smkin : smkin
# cringe : cringe
# batang : batang
# najis : najis
# bat : bat
# lelet : lelet
# see : see
# ditempatin : ditempatin
# sejuta : juta
# bjir : bjir
# indohome : indohome
# los : los
# teruskan : terus
# name : name
# tag : tag
# kaga : kaga
# tulisanya : tulisanya
# ish : ish
# vem : vem
# kopegtel : kopegtel
# kayak : kayak
# organik : organik
# seindonesia : indonesia
# astagaaa : astagaaa
# banget : banget
# pensiun : pensiun
# saran : saran
# kostumer : kostumer
# kristen : kristen
# bahas : bahas
# cloudflare : cloudflare
# mngkin : mngkin
# pms : pms
# sensian : sensian
# yeee : yeee
# tangannya : tangan
# costumernya : costumernya
# gonta : gonta
# ganti : ganti
# kak : kak
# klw : klw
# pakturah : pakturah
# bosen : bosen
# adegan : adegan
# dustin : dustin
# manjat : manjat
# menara : menara
# sutet : sutet
# your : your
# father : father
# join : join
# partai : partai
# gimana : gimana
# kabel : kabel
# diluar : luar
# kena : kena
# benang : benang
# layangan : layang
# pakai : pakai
# potongan : potong
# biaya : biaya
# langganan : langgan
# butuh : butuh
# harga : harga
# pejabat : jabat
# merakyat : rakyat
# ikutin : ikutin
# habib : habib
# far : far
# ngapa : ngapa
# dri : dri
# minggu : minggu
# skrng : skrng
# bayaran : bayar
# sue : sue
# nadya : nadya
# bersatu : satu
# awokawokaowk : awokawokaowk
# kuliah : kuliah
# uni : uni
# soviet : soviet
# emang : emang
# berkualitas : kualitas
# seru : seru
# euy : euy
# gemes : gemes
# diam : diam
# dagang : dagang
# sarung : sarung
# perpanjang : panjang
# episodenya : episode
# ngalahin : ngalahin
# customernya : customernya
# tambahin : tambahin
# next : next
# part : part
# edukasi : edukasi
# unspek : unspek
# minn : minn
# beda : beda
# kadang : kadang
# datengin : datengin
# kerumahnya : rumah
# jelasin : jelasin
# paham : paham
# percaya : percaya
# alhamdulillah : alhamdulillah
# cek : cek
# kedalam : dalam
# rumahnyaa : rumahnyaa
# kendalanya : kendala
# lapor : lapor
# selanjutnyaa : selanjutnyaa
# pelangan : pelang
# vidionya : vidionya
# teknisinya : teknisi
# memngerjakan : memngerjakan
# menyelasikan : lasi
# tuntas : tuntas
# berkualitass : berkualitass
# izin : izin
# masukanya : masukanya
# rispo : rispo
# ebel : ebel
# fanspage : fanspage
# facebook : facebook
# komentanya : komentanya
# ditutup : tutup
# masker : masker
# gajelas : gajelas
# ngomong : ngomong
# mencret : mencret
# ngakak : ngakak
# lord : lord
# pngen : pngen
# deh : deh
# masuk : masuk
# sepatu : sepatu
# bersih : bersih
# monoton : monoton
# kirain : kirain
# last : last
# hope : hope
# kitchen : kitchen
# kontennya : konten
# rigen : rigen
# jarinya : jari
# muslim : muslim
# gitu : gitu
# pindah : pindah
# lokasi : lokasi
# pemasangan : pasang
# menemukan : temu
# kejanggalan : janggal
# lakukan : laku
# ciw : ciw
# indie : indie
# home : home
# mli : mli
# asik : asik
# keseringan : sering
# vaksin : vaksin
# tetrp : tetrp
# jaga : jaga
# kesehatan : sehat
# yellow : yellow
# flag : flag
# watching : watching
# you : you
# tretan : tretan
# yeeeaaahhh : yeeeaaahhh
# akhirnyaa : akhirnyaa
# ngga : ngga
# wkwkwkk : wkwkwkk
# konflik : konflik
# servis : servis
# dukun : dukun
# pelakor : pelakor
# orang : orang
# dihadapi : hadap
# tpi : tpi
# chuaaaaakz : chuaaaaakz
# jari : jari
# indihomee : indihomee
# gini : gin
# formola : formola
# khasnya : khas
# wkwkwk : wkwkwk
# program : program
# pengen : ken
# rebus : rebus
# indomie : indomie
# gada : gada
# choki : choki
# gaseru : gaseru
# when : when
# end : end
# and : and
# chuakss : chuakss
# ketar : ketar
# ketir : tir
# mop : mop
# motor : motor
# tulisan : tulis
# warnaa : warnaa
# merah : merah
# petugas : tugas
# mitra : mitra
# pekerja : kerja
# kontrak : kontrak
# menunggu : tunggu
# indiehome : indiehome
# melibatkan : libat
# trio : trio
# perfect : perfect
# protection : protection
# pendeta : pendeta
# yerry : yerry
# suhu : suhu
# zhuang : zhuang
# xiu : xiu
# lanjutkan : lanjut
# heyyy : heyyy
# sattty : sattty
# bapaknya : bapak
# nyalon : nyalon
# dunia : dunia
# bermasalah : masalah
# cepat : cepat
# direspon : direspon
# hrs : hrs
# ditlpn : ditlpn
# berkali : kali
# sekaliny : sekaliny
# respon : respon
# dtngnya : dtngnya
# nunggu : nunggu
# seharian : hari
# diajak : ajak
# masak : masak
# kurma : kurma
# imejin : imejin
# wen : wen
# hom : hom
# yelow : yelow
# fleg : fleg
# yor : yor
# pader : pader
# responya : responya
# cpet : cpet
# wkwkkw : wkwkkw
# pras : pras
# agus : agus
# viral : viral
# dimasukin : dimasukin
# smarfren : smarfren
# andai : andai
# cewenya : cewenya
# arafah : arafah
# gokil : gokil
# ditunggu : tunggu
# tunggu : tunggu
# durasinya : durasi
# menitan : menit
# why : why
# bertujuan : tuju
# sarkasme : sarkasme
# pelanggannya : langgan
# ajar : ajar
# coba : coba
# endorse : endorse
# teh : teh
# pucuk : pucuk
# lanjutt : lanjutt
# menonton : tonton
# berlangganan : langgan
# tertarik : tarik
# provider : provider
# rekrut : rekrut
# muhidin : muhidin
# tokoh : tokoh
# antagonis : antagonis
# kaya : kaya
# ayo : ayo
# ampe : ampe
# one : one
# piece : piece
# clasico : clasico
# channel : channel
# suaranya : suara
# gabung : gabung
# chuakxxzzz : chuakxxzzz
# benci : benci
# seruuu : seruuu
# film : film
# cmn : cmn
# ngeselin : ngeselin
# smpe : smpe
# customer : customer
# kya : kya
# beneran : beneran
# tumben : tumben
# post : post
# credit : credit
# scene : scene
# marah : marah
# kritik : kritik
# pemainnya : main
# plastik : plastik
# kokoh : kokoh
# china : china
# selamat : selamat
# hut : hut
# telkom : telkom
# peranakan : ana
# kangkung : kangkung
# rawa : rawa
# nadia : nadia
# gass : gass
# teruss : teruss
# flags : flags
# absen : absen
# viewers : viewers
# broo : broo
# sebagus : bagus
# apapun : apa
# blacklist : blacklist
# chuaxck : chuaxck
# hhha : hhha
# gara : gara
# mreka : mreka
# mampir : mampir
# waaaaw : waaaaw
# kah : kah
# lupa : lupa
# nyalakan : nyala
# notif : notif
# bantu : bantu
# liga : liga
# mozambik : mozambik
# tehknisi : tehknisi
# bahagia : bahagia
# bulanan : bulan
# sayang : sayang
# dyah : dyah
# nggak : nggak
# companynya : companynya
# macet : macet
# sinyanya : sinyanya
# curi : curi
# kedepannya : depan
# management : management
# system : system
# routernya : routernya
# mikrotik : mikrotik
# adaptable : adaptable
# mbaknya : mbak
# overacting : overacting
# natural : natural
# rafi : rafi
# ahmad : ahmad
# ajik : ajik
# gek : gek
# nana : nana
# bli : bli
# gang : gang
# poppies : poppies
# lane : lane
# arak : arak
# lol : lol
# telek : telek
# infihome : infihome
# cok : cok
# maju : maju
# bgsad : bgsad
# stiap : stiap
# anjink : anjink
# wkwkw : wkwkw
# lucu : lucu
# yaaa : yaaa
# yaaaaah : yaaaaah
# ngerti : ngerti
# seriesnya : seriesnya
# akting : akting
# whyyyyyyy : whyyyyyyy
# ngntd : ngntd
# ngntod : ngntod
# kesini : kesini
# ngehujat : ngehujat
# like : like
# telkomsel : telkomsel
# ampas : ampas
# indi : indi
# kntl : kntl
# upload : upload
# putus : putus
# parah : parah
# turunkan : turun
# mahal : mahal
# cuk : cuk
# indihihome : indihihome
# kmpret : kmpret
# taekk : taekk
# byr : byr
# uganda : uganda
# von : von
# lul : lul
# doang : doang
# fix : fix
# down : down
# secepatnya : cepat
# susah : susah
# ape : ape
# noob : noob
# kagak : kagak
# kirim : kirim
# tugas : tugas
# ngejar : ngejar
# deadline : deadline
# tod : tod
# always : always
# best : best
# wilyah : wilyah
# wefi : wefi
# stabil : stabil
# infonya : info
# roblox : roblox
# direstart : direstart
# modem : modem
# solusi : solusi
# truss : truss
# taek : taek
# kau : kau
# jelek : jelek
# yaa : yaa
# menyadarkan : sadar
# betapa : betapa
# menyebalkannya : sebal
# mbakku : mbak
# twitter : twitter
# eror : eror
# nin : nin
# hahahaha : hahahaha
# marahhh : marahhh
# indigo : indigo
# sadar : sadar
# menyindir : sindir
# kalin : kalin
# suka : suka
# protes : protes
# engga : engga
# komedi : komedi
# gimanah : gimanah
# pengguna : guna
# karya : karya
# semangat : semangat
# zero : zero
# logic : logic
# kayanya : kaya
# cameo : cameo
# karakter : karakter
# legendary : legendary
# kualitasnya : kualitas
# kebalikan : balik
# cuaaakzzz : cuaaakzzz
# terbaik : baik
# senior : senior
# tarik : tarik
# dorong : dorong
# indoapril : indoapril
# asiik : asiik
# pantes : pantes
# ubi : ubi
# cilembu : cilembu
# kocak : kocak
# dicari : cari
# namanya : nama
# fabien : fabien
# mutumbora : mutumbora
# love : love
# limbat : limbat
# disney : disney
# nanya : nanya
# yak : yak
# hancurkan : hancur
# ikatan : ikat
# mantapp : mantapp
# anime : anime
# durasi : durasi
# sebentar : sebentar
# berhenti : henti
# jngan : jngan
# abis : abis
# alami : alami
# ntuk : ntuk
# ingatkan : ingat
# pintu : pintu
# wajib : wajib
# lanjutkann : lanjutkann
# menit : menit
# subtitel : subtitel
# kupu : kupu
# muhammad : muhammad
# saw : saw
# subscribe : subscribe
# support : support
# respect : respect
# ttep : ttep
# berlanjut : lanjut
# ohang : ohang
# uang : uang
# produksinya : produksi
# stabilin : stabilin
# dirumah : rumah
# kencang : kencang
# {'mudah': 'mudah', 'mudahan': 'mudah', 'series': 'series', 'menyaingi': 'saing', 'episode': 'episode', 'sinetron': 'sinetron', 'tukang': 'tukang', 'haji': 'haji', 'bubur': 'bubur', '': '', 'turah': 'turah', 'ayolah': 'ayo', 'indihome': 'indihome', 'perusahaan': 'usaha', 'sanggup': 'sanggup', 'memikul': 'pikul', 'jokes': 'jokes', 'tepi': 'tepi', 'jurang': 'jurang', 'ketahuilah': 'tahu', 'keren': 'keren', 'bertiga': 'tiga', 'mas': 'mas', 'madura': 'madura', 'nonton': 'nonton', 'lgsg': 'lgsg', 'nonstop': 'nonstop', 'kualitas': 'kualitas', 'buffer': 'buffer', 'terima': 'terima', 'kasih': 'kasih', 'biznet': 'biznet', 'mempermudah': 'mudah', 'akses': 'akses', 'hiburan': 'hibur', 'eps': 'eps', 'sampe': 'sampe', 'wifi': 'wifi', 'sampah': 'sampah', 'gaggunaaaaaaa': 'gaggunaaaaaaa', 'mantap': 'mantap', 'udh': 'udh', 'pakek': 'pakek', 'wiuuu': 'wiuuu', 'kalahkan': 'kalah', 'tersanjung': 'sanjung', 'cinta': 'cinta', 'fitri': 'fitri', 'tersayang': 'sayang', 'termehek': 'termehek', 'mehek': 'mehek', 'gua': 'gua', 'mail': 'mail', 'game': 'game', 'ngelag': 'ngelag', 'mohon': 'mohon', 'solusinya': 'solusi', 'iya': 'iya', 'wifinya': 'wifinya', 'lemot': 'lot', 'jing': 'jing', 'perbaikin': 'perbaikin', 'jaringan': 'jaring', 'kontolllk': 'kontolllk', 'sinyal': 'sinyal', 'setabil': 'setabil', 'indihomo': 'indihomo', 'ajg': 'ajg', 'kntool': 'kntool', 'kntoll': 'kntoll', 'gws': 'gws', 'sinyalll': 'sinyalll', 'pas': 'pas', 'buka': 'buka', 'web': 'web', 'err': 'err', 'ssl': 'ssl', 'protocol': 'protocol', 'kek': 'kek', 'mobil': 'mobil', 'mogok': 'mogok', 'lag': 'lag', 'lohhh': 'lohhh', 'nihhh': 'nihhh', 'perbaikan': 'baik', 'nyaaa': 'nyaaa', 'atur': 'atur', 'internet': 'internet', 'abisin': 'abisin', 'duit': 'duit', 'taik': 'taik', 'bettttttt': 'bettttttt', 'ajggg': 'ajggg', 'bang': 'bang', 'mulu': 'mulu', 'main': 'main', 'aslinya': 'asli', 'maniac': 'maniac', 'ehh': 'ehh', 'donk': 'donk', 'ngasih': 'ngasih', 'bagus': 'bagus', 'hey': 'hey', 'lanjutan': 'lanjut', 'saaaat': 'saaaat', 'semoga': 'moga', 'bangkrut': 'bangkrut', 'amin': 'amin', 'saben': 'saben', 'dasar': 'dasar', 'indigay': 'indigay', 'nyesel': 'nyesel', 'beli': 'beli', 'mending': 'mending', 'paket': 'paket', 'nge': 'nge', 'admin': 'admin', 'tolong': 'tolong', 'perbaiki': 'baik', 'hujan': 'hujan', 'karna': 'karna', 'rumah': 'rumah', 'kalu': 'kalu', 'bekasi': 'bekas', 'ngeleg': 'ngeleg', 'aplikasi': 'aplikasi', 'youtube': 'youtube', 'ilang': 'ilang', 'knapa': 'knapa', 'min': 'min', 'anak': 'anak', 'benerin': 'benerin', 'jaringannya': 'jaring', 'bener': 'bener', 'dikit': 'dikit', 'udah': 'udah', 'bayar': 'bayar', 'gapernah': 'gapernah', 'dibikin': 'bikin', 'puas': 'puas', 'ama': 'ama', 'koneksinya': 'koneksi', 'woi': 'woi', 'cuman': 'cuman', 'gangguan': 'ganggu', 'alfamart': 'alfamart', 'ovo': 'ovo', 'putusin': 'putusin', 'hadehhh': 'hadehhh', 'leg': 'leg', 'turahhhhhh': 'turahhhhhh', 'knp': 'knp', 'pesen': 'sen', 'mbps': 'mbps', 'dapet': 'dapet', 'penipuann': 'penipuann', 'ketauilah': 'tau', 'pelanggan': 'langgan', 'dateng': 'dateng', 'malam': 'malam', 'teknisi': 'teknisi', 'jam': 'jam', 'lembur': 'lembur', 'dimana': 'mana', 'bangs': 'bangs', 'indickhome': 'indickhome', 'kuulangi': 'ulang', 'bodoh': 'bodoh', 'kali': 'kali', 'mati': 'mati', 'makan': 'makan', 'gaji': 'gaji', 'haram': 'haram', 'asli': 'asli', 'trouble': 'trouble', 'gatau': 'gatau', 'kecepatan': 'cepat', 'unduh': 'unduh', 'mb': 'mb', 'salah': 'salah', 'dosa': 'dosa', 'telat': 'telat', 'njiirrrrrr': 'njiirrrrrr', 'maaf': 'maaf', 'inihome': 'inihome', 'bagusi': 'bagus', 'kesel': 'kesel', 'ping': 'ping', 'indih': 'indih', 'hahahahahahahhaahhahahaha': 'hahahahahahahhaahhahahaha', 'sosok': 'sosok', 'dikehidupan': 'hidup', 'nyata': 'nyata', 'judul': 'judul', 'what': 'what', 'the': 'the', 'fyck': 'fyck', 'haruss': 'haruss', 'gas': 'gas', 'trus': 'trus', 'webtoon': 'webtoon', 'voice': 'voice', 'indonesia': 'indonesia', 'kebanyakan': 'banyak', 'konten': 'konten', 'malem': 'malem', 'ganggu': 'ganggu', 'push': 'push', 'rank': 'rank', 'meme': ...
# ------------------------
# Pandas Apply:   0%|          | 0/296 [00:01<?, ?it/s]
#                                                comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                pak turah pak turah🤣🤣
# 4    ayolah indihome! perusahaan sebesar ini masa t...
# 5                                    ketahuilah bahwa:
# 6    keren lah mereka bertiga, apalagi mas mas madu...
# ..                                                 ...
# 357  ada yang merasa gak di menit 1.00 dan mengguna...
# 358  jangan lupa di subscribe buat support respect ...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                       cleaning_comment  \
# 2    mudah mudahan series nya bisa menyaingi episod...
# 3                                 pak turah pak turah
# 4    ayolah indihome perusahaan sebesar ini masa ti...
# 5                                    ketahuilah bahwa
# 6    keren lah mereka bertiga apalagi mas mas madur...
# ..                                                 ...
# 357  ada yang merasa gak menit dan menggunakan subt...
# 358  jangan lupa subscribe buat support respect ser...
# 359                                       dustin ohang
# 360  uang produksinya mending buat stabilin jaringa...
# 363  akhirnya setelah melihat series ini internet d...
#
#                                             tokenisasi  \
# 2    [mudah, mudahan, series, nya, bisa, menyaingi,...
# 3                           [pak, turah, pak, turah, ]
# 4    [ayolah, indihome, perusahaan, sebesar, ini, m...
# 5                                [ketahuilah, bahwa, ]
# 6    [keren, lah, mereka, bertiga, apalagi, mas, ma...
# ..                                                 ...
# 357  [ada, yang, merasa, gak, menit, dan, menggunak...
# 358  [jangan, lupa, subscribe, buat, support, respe...
# 359                                    [dustin, ohang]
# 360  [uang, produksinya, mending, buat, stabilin, j...
# 363  [akhirnya, setelah, melihat, series, ini, inte...
#
#                                               stopword  \
# 2    [mudah, mudahan, series, menyaingi, episode, s...
# 3                                     [turah, turah, ]
# 4    [ayolah, indihome, perusahaan, sanggup, memiku...
# 5                                       [ketahuilah, ]
# 6                 [keren, bertiga, mas, mas, madura, ]
# ..                                                 ...
# 357  [menit, subtitel, tulisan, kupu, kupu, muhamma...
# 358  [lupa, subscribe, support, respect, series, tt...
# 359                                    [dustin, ohang]
# 360  [uang, produksinya, mending, stabilin, jaringa...
# 363               [series, internet, dirumah, kencang]
#
#                                               stemming
# 2    [mudah, mudah, series, saing, episode, sinetro...
# 3                                     [turah, turah, ]
# 4    [ayo, indihome, usaha, sanggup, pikul, jokes, ...
# 5                                             [tahu, ]
# 6                    [keren, tiga, mas, mas, madura, ]
# ..                                                 ...
# 357  [menit, subtitel, tulis, kupu, kupu, muhammad,...
# 358  [lupa, subscribe, support, respect, series, tt...
# 359                                    [dustin, ohang]
# 360  [uang, produksi, mending, stabilin, jaring, mi...
# 363                 [series, internet, rumah, kencang]
#
# [296 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 2    [mudah, mudah, series, saing, episode, sinetro...
# 3                                     [turah, turah, ]
# 4    [ayo, indihome, usaha, sanggup, pikul, jokes, ...
# 5                                             [tahu, ]
# 6                    [keren, tiga, mas, mas, madura, ]
# ..                                                 ...
# 357  [menit, subtitel, tulis, kupu, kupu, muhammad,...
# 358  [lupa, subscribe, support, respect, series, tt...
# 359                                    [dustin, ohang]
# 360  [uang, produksi, mending, stabilin, jaring, mi...
# 363                 [series, internet, rumah, kencang]
#
# [296 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_indihome_12.xlsx')
