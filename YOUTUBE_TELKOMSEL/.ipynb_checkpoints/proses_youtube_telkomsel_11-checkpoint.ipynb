# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Jaringan ga pernah bener nih... Cuma mikirin u...
# 1    Semoga yg buat kartu Telkomsel hari hari semak...
# 2    Tolong lah jaringan di perbaiki daerah Kec. Ga...
# 3    Mari bersama sama kita mendoakan agar Telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            Ilang mulu sinyal w cok
# 207                         Sinyal macam ee skrang njs
# 208                              Perbaiki jaringan kau
# 209                                            Woyyyyy
# 210                                  Bangkrut bangkrut
#
# [211 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 51

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Jaringan ga pernah bener nih... Cuma mikirin u...
# 1    Semoga yg buat kartu Telkomsel hari hari semak...
# 2    Tolong lah jaringan di perbaiki daerah Kec. Ga...
# 3    Mari bersama sama kita mendoakan agar Telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            Ilang mulu sinyal w cok
# 207                         Sinyal macam ee skrang njs
# 208                              Perbaiki jaringan kau
# 209                                            Woyyyyy
# 210                                  Bangkrut bangkrut
#
# [112 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    jaringan ga pernah bener nih... cuma mikirin u...
# 1    semoga yg buat kartu telkomsel hari hari semak...
# 2    tolong lah jaringan di perbaiki daerah kec. ga...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            ilang mulu sinyal w cok
# 207                         sinyal macam ee skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
# [112 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    jaringan ga pernah bener nih... cuma mikirin u...
# 1    semoga yg buat kartu telkomsel hari hari semak...
# 2    tolong lah jaringan di perbaiki daerah kec. ga...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            ilang mulu sinyal w cok
# 207                         sinyal macam ee skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                       cleaning_comment
# 0    jaringan pernah bener nih cuma mikirin untung ...
# 1    semoga buat kartu telkomsel hari hari semakin ...
# 2    tolong lah jaringan perbaiki daerah kec gampen...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun gan...
# ..                                                 ...
# 206                              ilang mulu sinyal cok
# 207                            sinyal macam skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
# [112 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    jaringan ga pernah bener nih... cuma mikirin u...
# 1    semoga yg buat kartu telkomsel hari hari semak...
# 2    tolong lah jaringan di perbaiki daerah kec. ga...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            ilang mulu sinyal w cok
# 207                         sinyal macam ee skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                       cleaning_comment  \
# 0    jaringan pernah bener nih cuma mikirin untung ...
# 1    semoga buat kartu telkomsel hari hari semakin ...
# 2    tolong lah jaringan perbaiki daerah kec gampen...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun gan...
# ..                                                 ...
# 206                              ilang mulu sinyal cok
# 207                            sinyal macam skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                             tokenisasi
# 0    [jaringan, pernah, bener, nih, cuma, mikirin, ...
# 1    [semoga, buat, kartu, telkomsel, hari, hari, s...
# 2    [tolong, lah, jaringan, perbaiki, daerah, kec,...
# 3    [mari, bersama, sama, kita, mendoakan, agar, t...
# 4    [nyesel, pake, pascabayar, ribetnya, mintaampu...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                       [sinyal, macam, skrang, njs]
# 208                          [perbaiki, jaringan, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
# [112 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    jaringan ga pernah bener nih... cuma mikirin u...
# 1    semoga yg buat kartu telkomsel hari hari semak...
# 2    tolong lah jaringan di perbaiki daerah kec. ga...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            ilang mulu sinyal w cok
# 207                         sinyal macam ee skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                       cleaning_comment  \
# 0    jaringan pernah bener nih cuma mikirin untung ...
# 1    semoga buat kartu telkomsel hari hari semakin ...
# 2    tolong lah jaringan perbaiki daerah kec gampen...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun gan...
# ..                                                 ...
# 206                              ilang mulu sinyal cok
# 207                            sinyal macam skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                             tokenisasi  \
# 0    [jaringan, pernah, bener, nih, cuma, mikirin, ...
# 1    [semoga, buat, kartu, telkomsel, hari, hari, s...
# 2    [tolong, lah, jaringan, perbaiki, daerah, kec,...
# 3    [mari, bersama, sama, kita, mendoakan, agar, t...
# 4    [nyesel, pake, pascabayar, ribetnya, mintaampu...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                       [sinyal, macam, skrang, njs]
# 208                          [perbaiki, jaringan, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
#                                               stopword
# 0    [jaringan, bener, mikirin, untung, provider, p...
# 1                    [semoga, kartu, telkomsel, suram]
# 2    [tolong, jaringan, perbaiki, daerah, kec, gamp...
# 3               [mari, mendoakan, telkomsel, bangkrut]
# 4    [nyesel, pascabayar, ribetnya, mintaampun, gan...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                              [sinyal, skrang, njs]
# 208                          [perbaiki, jaringan, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
# [112 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 352
# ------------------------
# jaringan : jaring
# bener : bener
# mikirin : mikirin
# untung : untung
# provider : provider
# paket : paket
# murah : murah
# stabil : stabil
#  :
# semoga : moga
# kartu : kartu
# telkomsel : telkomsel
# suram : suram
# tolong : tolong
# perbaiki : baik
# daerah : daerah
# kec : kec
# gampengrejo : gampengrejo
# pindah : pindah
# mulu : mulu
# udah : udah
# minggu : minggu
# kejadian : jadi
# mari : mari
# mendoakan : doa
# bangkrut : bangkrut
# nyesel : nyesel
# pascabayar : pascabayar
# ribetnya : ribetnya
# mintaampun : mintaampun
# ganti : ganti
# beli : beli
# very : very
# bad : bad
# system : system
# pelayanan : layan
# bagus : bagus
# kapok : kapok
# gabisa : gabisa
# prabayar : prabayar
# diperbaiki : baik
# min : min
# orang : orang
# kerja : kerja
# susah : susah
# skrng : skrng
# knpa : knpa
# pmbngunan : pmbngunan
# tower : tower
# tmpat : tmpat
# lanjutkan : lanjut
# nice : nice
# meet : meet
# you : you
# november : november
# cok : cok
# kiqk : kiqk
# indo : indo
# capek : capek
# main : main
# ping : ping
# bang : bang
# ngelag : ngelag
# lag : lag
# teros : ros
# telkom : telkom
# ajg : ajg
# depresi : depresi
# mebuat : mebuat
# happy : happy
# secepatnya : cepat
# jaringannya : jaring
# anjing : anjing
# muncul : muncul
# sengaja : sengaja
# leletkan : lelet
# hijrah : hijrah
# indosat : indosat
# axis : axis
# harga : harga
# internet : internet
# unlimited : unlimited
# kemaren : kemaren
# gua : gua
# harganya : harga
# satuannya : satu
# contoh : contoh
# pas : pas
# mohon : mohon
# sinyal : sinyal
# terkomsel : terkomsel
# dripada : dripada
# penggunanya : guna
# haluan : haluan
# daerahku : daerah
# snyalnya : snyalnya
# meriah : riah
# aman : aman
# kek : kek
# telkomtol : telkomtol
# mitik : mitik
# lejend : lejend
# bangkrutt : bangkrutt
# memiliki : milik
# kerugian : rugi
# besarrrrr : besarrrrr
# selangit : langit
# hilabg : hilabg
# misi : misi
# ngeleg : ngeleg
# setuju : tuju
# luke : luke
# kuota : kuota
# multimedia : multimedia
# ampas : ampas
# banget : banget
# nonton : nonton
# youtube : youtube
# harum : harum
# urus : urus
# signal : signal
# konto : konto
# promosi : promosi
# ngalamin : ngalamin
# ngelek : ngelek
# jijik : jijik
# bet : bet
# najiss : najiss
# ngapain : ngapain
# dibenerin : dibenerin
# dih : dih
# benerin : benerin
# nyaaa : nyaaa
# taaiiii : taaiiii
# dak : dak
# ngapa : ngapa
# ngga : ngga
# buka : buka
# discord : discord
# sultan : sultan
# mlm : mlm
# kak : kak
# respon : respon
# aying : aying
# jan : jan
# tlkom : tlkom
# bubarin : bubarin
# kesel : kesel
# makasih : makasih
# berkat : berkat
# sampe : sampe
# bunuh : bunuh
# gimana : gimana
# install : install
# pubg : pubg
# diulang : ulang
# huuuuuuu : huuuuuuu
# cemen : cemen
# uploud : uploud
# trus : trus
# video : video
# gausah : gausah
# pikirin : pikirin
# timbul : timbul
# tenggelam : tenggelam
# ajalah : aja
# parahhh : parahhh
# woy : woy
# kaga : kaga
# giliran : gilir
# udh : udh
# penawaran : tawar
# rugi : rugi
# ngasih : ngasih
# gausa : gausa
# blok : blok
# mhl : mhl
# jringanya : jringanya
# anjg : anjg
# malam : malam
# bsa : bsa
# stress : stress
# moga : moga
# bangrut : bangrut
# kodok : kodok
# juma : juma
# sok : sok
# burik : burik
# pejabat : jabat
# taik : taik
# doang : doang
# ajir : ajir
# tloll : tloll
# unsubscribe : unsubscribe
# gini : gin
# sucribe : sucribe
# auto : auto
# film : film
# blm : blm
# dilengkapi : lengkap
# subtitle : subtitle
# indonesia : indonesia
# hoiii : hoiii
# jringan : jringan
# terbaik : baik
# nmer : nmer
# kagak : kagak
# parah : parah
# aminnnn : aminnnn
# game : game
# merah : merah
# tiktok : tiktok
# annnjjeeennng : annnjjeeennng
# niat : niat
# ngepush : ngepush
# rank : rank
# anjlok : anjlok
# cacat : cacat
# sinyalnya : sinyal
# jariangan : jariangan
# tanggung : tanggung
# liat : liat
# baca : baca
# woi : woi
# satt : satt
# eror : eror
# kah : kah
# kena : kena
# utama : utama
# babic : babic
# abis : abis
# gb : gb
# ajig : ajig
# jarongan : jarongan
# tei : tei
# dasar : dasar
# aeu : aeu
# pepkkk : pepkkk
# cita : cita
# membakar : bakar
# kantor : kantor
# tercapai : capai
# amin : amin
# geme : geme
# tailk : tailk
# maaf : maaf
# kendala : kendala
# kemarin : kemarin
# hilang : hilang
# bulanan : bulan
# sungguh : sungguh
# dimohon : mohon
# jabar : jabar
# kota : kota
# tasikmalaya : tasikmalaya
# ngleg : ngleg
# cepat : cepat
# keren : keren
# lihat : lihat
# detik : detik
# buruk : buruk
# memasuki : pasuk
# musim : musim
# hujan : hujan
# komentar : komentar
# suka : suka
# coba : coba
# im : im
# lancar : lancar
# maling : maling
# pulsa : pulsa
# ilang : ilang
# jelass : jelass
# assalamualaikum : assalamualaikum
# terhormat : hormat
# memberitahukan : memberitahukan
# perusahaan : usaha
# menghadapi : hadap
# krisis : krisis
# crm : crm
# buang : buang
# berguna : guna
# dihati : hati
# pelangan : pelang
# permasalahan : masalah
# customer : customer
# jagan : jagan
# isu : isu
# mengambil : ambil
# kebijakan : bijak
# hatur : hatur
# nuhun : nuhun
# salam : salam
# tri : tri
# bar : bar
# speed : speed
# kbps : kbps
# paketan : paket
# rb : rb
# menjamin : jamin
# kualitas : kualitas
# permisi : permisi
# komplain : komplain
# gubris : gubris
# bekasi : bekas
# mya : mya
# uplink : uplink
# downlink : downlink
# bp : bp
# salah : salah
# down : down
# aduh : aduh
# keknya : kek
# peduli : peduli
# duit : duit
# ama : ama
# bagusin : bagusin
# naikin : naikin
# jumat : jumat
# candaan : canda
# ruang : ruang
# miskin : miskin
# memalukan : malu
# kaya : kaya
# tay : tay
# kolom : kolom
# komen : komen
# terbaru : baru
# dimatiin : dimatiin
# ngejhum : ngejhum
# poto : poto
# seru : seru
# telkomselnya : telkomselnya
# the : the
# best : best
# login : login
# kirim : kirim
# pengen : ken
# santet : santet
# pelanggan : langgan
# setia : setia
# kekakuan : kaku
# videomu : video
# muter : muter
# layak : layak
# dipakai : pakai
# jawa : jawa
# taek : taek
# skrang : skrang
# njs : njs
# kau : kau
# woyyyyy : woyyyyy
# {'jaringan': 'jaring', 'bener': 'bener', 'mikirin': 'mikirin', 'untung': 'untung', 'provider': 'provider', 'paket': 'paket', 'murah': 'murah', 'stabil': 'stabil', '': '', 'semoga': 'moga', 'kartu': 'kartu', 'telkomsel': 'telkomsel', 'suram': 'suram', 'tolong': 'tolong', 'perbaiki': 'baik', 'daerah': 'daerah', 'kec': 'kec', 'gampengrejo': 'gampengrejo', 'pindah': 'pindah', 'mulu': 'mulu', 'udah': 'udah', 'minggu': 'minggu', 'kejadian': 'jadi', 'mari': 'mari', 'mendoakan': 'doa', 'bangkrut': 'bangkrut', 'nyesel': 'nyesel', 'pascabayar': 'pascabayar', 'ribetnya': 'ribetnya', 'mintaampun': 'mintaampun', 'ganti': 'ganti', 'beli': 'beli', 'very': 'very', 'bad': 'bad', 'system': 'system', 'pelayanan': 'layan', 'bagus': 'bagus', 'kapok': 'kapok', 'gabisa': 'gabisa', 'prabayar': 'prabayar', 'diperbaiki': 'baik', 'min': 'min', 'orang': 'orang', 'kerja': 'kerja', 'susah': 'susah', 'skrng': 'skrng', 'knpa': 'knpa', 'pmbngunan': 'pmbngunan', 'tower': 'tower', 'tmpat': 'tmpat', 'lanjutkan': 'lanjut', 'nice': 'nice', 'meet': 'meet', 'you': 'you', 'november': 'november', 'cok': 'cok', 'kiqk': 'kiqk', 'indo': 'indo', 'capek': 'capek', 'main': 'main', 'ping': 'ping', 'bang': 'bang', 'ngelag': 'ngelag', 'lag': 'lag', 'teros': 'ros', 'telkom': 'telkom', 'ajg': 'ajg', 'depresi': 'depresi', 'mebuat': 'mebuat', 'happy': 'happy', 'secepatnya': 'cepat', 'jaringannya': 'jaring', 'anjing': 'anjing', 'muncul': 'muncul', 'sengaja': 'sengaja', 'leletkan': 'lelet', 'hijrah': 'hijrah', 'indosat': 'indosat', 'axis': 'axis', 'harga': 'harga', 'internet': 'internet', 'unlimited': 'unlimited', 'kemaren': 'kemaren', 'gua': 'gua', 'harganya': 'harga', 'satuannya': 'satu', 'contoh': 'contoh', 'pas': 'pas', 'mohon': 'mohon', 'sinyal': 'sinyal', 'terkomsel': 'terkomsel', 'dripada': 'dripada', 'penggunanya': 'guna', 'haluan': 'haluan', 'daerahku': 'daerah', 'snyalnya': 'snyalnya', 'meriah': 'riah', 'aman': 'aman', 'kek': 'kek', 'telkomtol': 'telkomtol', 'mitik': 'mitik', 'lejend': 'lejend', 'bangkrutt': 'bangkrutt', 'memiliki': 'milik', 'kerugian': 'rugi', 'besarrrrr': 'besarrrrr', 'selangit': 'langit', 'hilabg': 'hilabg', 'misi': 'misi', 'ngeleg': 'ngeleg', 'setuju': 'tuju', 'luke': 'luke', 'kuota': 'kuota', 'multimedia': 'multimedia', 'ampas': 'ampas', 'banget': 'banget', 'nonton': 'nonton', 'youtube': 'youtube', 'harum': 'harum', 'urus': 'urus', 'signal': 'signal', 'konto': 'konto', 'promosi': 'promosi', 'ngalamin': 'ngalamin', 'ngelek': 'ngelek', 'jijik': 'jijik', 'bet': 'bet', 'najiss': 'najiss', 'ngapain': 'ngapain', 'dibenerin': 'dibenerin', 'dih': 'dih', 'benerin': 'benerin', 'nyaaa': 'nyaaa', 'taaiiii': 'taaiiii', 'dak': 'dak', 'ngapa': 'ngapa', 'ngga': 'ngga', 'buka': 'buka', 'discord': 'discord', 'sultan': 'sultan', 'mlm': 'mlm', 'kak': 'kak', 'respon': 'respon', 'aying': 'aying', 'jan': 'jan', 'tlkom': 'tlkom', 'bubarin': 'bubarin', 'kesel': 'kesel', 'makasih': 'makasih', 'berkat': 'berkat', 'sampe': 'sampe', 'bunuh': 'bunuh', 'gimana': 'gimana', 'install': 'install', 'pubg': 'pubg', 'diulang': 'ulang', 'huuuuuuu': 'huuuuuuu', 'cemen': 'cemen', 'uploud': 'uploud', 'trus': 'trus', 'video': 'video', 'gausah': 'gausah', 'pikirin': 'pikirin', 'timbul': 'timbul', 'tenggelam': 'tenggelam', 'ajalah': 'aja', 'parahhh': 'parahhh', 'woy': 'woy', 'kaga': 'kaga', 'giliran': 'gilir', 'udh': 'udh', 'penawaran': 'tawar', 'rugi': 'rugi', 'ngasih': 'ngasih', 'gausa': 'gausa', 'blok': 'blok', 'mhl': 'mhl', 'jringanya': 'jringanya', 'anjg': 'anjg', 'malam': 'malam', 'bsa': 'bsa', 'stress': 'stress', 'moga': 'moga', 'bangrut': 'bangrut', 'kodok': 'kodok', 'juma': 'juma', 'sok': 'sok', 'burik': 'burik', 'pejabat': 'jabat', 'taik': 'taik', 'doang': 'doang', 'ajir': 'ajir', 'tloll': 'tloll', 'unsubscribe': 'unsubscribe', 'gini': 'gin', 'sucribe': 'sucribe', 'auto': 'auto', 'film': 'film', 'blm': 'blm', 'dilengkapi': 'lengkap', 'subtitle': 'subtitle', 'indonesia': 'indonesia', 'hoiii': 'hoiii', 'jringan': 'jringan', 'terbaik': 'baik', 'nmer': 'nmer', 'kagak': 'kagak', 'parah': 'p ...
# ------------------------
# Pandas Apply:   0%|          | 0/112 [00:00<?, ?it/s]
#                                                comment  \
# 0    jaringan ga pernah bener nih... cuma mikirin u...
# 1    semoga yg buat kartu telkomsel hari hari semak...
# 2    tolong lah jaringan di perbaiki daerah kec. ga...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun mo ...
# ..                                                 ...
# 206                            ilang mulu sinyal w cok
# 207                         sinyal macam ee skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                       cleaning_comment  \
# 0    jaringan pernah bener nih cuma mikirin untung ...
# 1    semoga buat kartu telkomsel hari hari semakin ...
# 2    tolong lah jaringan perbaiki daerah kec gampen...
# 3    mari bersama sama kita mendoakan agar telkomse...
# 4    nyesel pake pascabayar ribetnya mintaampun gan...
# ..                                                 ...
# 206                              ilang mulu sinyal cok
# 207                            sinyal macam skrang njs
# 208                              perbaiki jaringan kau
# 209                                            woyyyyy
# 210                                  bangkrut bangkrut
#
#                                             tokenisasi  \
# 0    [jaringan, pernah, bener, nih, cuma, mikirin, ...
# 1    [semoga, buat, kartu, telkomsel, hari, hari, s...
# 2    [tolong, lah, jaringan, perbaiki, daerah, kec,...
# 3    [mari, bersama, sama, kita, mendoakan, agar, t...
# 4    [nyesel, pake, pascabayar, ribetnya, mintaampu...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                       [sinyal, macam, skrang, njs]
# 208                          [perbaiki, jaringan, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
#                                               stopword  \
# 0    [jaringan, bener, mikirin, untung, provider, p...
# 1                    [semoga, kartu, telkomsel, suram]
# 2    [tolong, jaringan, perbaiki, daerah, kec, gamp...
# 3               [mari, mendoakan, telkomsel, bangkrut]
# 4    [nyesel, pascabayar, ribetnya, mintaampun, gan...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                              [sinyal, skrang, njs]
# 208                          [perbaiki, jaringan, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
#                                               stemming
# 0    [jaring, bener, mikirin, untung, provider, pak...
# 1                      [moga, kartu, telkomsel, suram]
# 2    [tolong, jaring, baik, daerah, kec, gampengrej...
# 3                     [mari, doa, telkomsel, bangkrut]
# 4    [nyesel, pascabayar, ribetnya, mintaampun, gan...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                              [sinyal, skrang, njs]
# 208                                [baik, jaring, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
# [112 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [jaring, bener, mikirin, untung, provider, pak...
# 1                      [moga, kartu, telkomsel, suram]
# 2    [tolong, jaring, baik, daerah, kec, gampengrej...
# 3                     [mari, doa, telkomsel, bangkrut]
# 4    [nyesel, pascabayar, ribetnya, mintaampun, gan...
# ..                                                 ...
# 206                         [ilang, mulu, sinyal, cok]
# 207                              [sinyal, skrang, njs]
# 208                                [baik, jaring, kau]
# 209                                          [woyyyyy]
# 210                               [bangkrut, bangkrut]
#
# [112 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_11.xlsx')
