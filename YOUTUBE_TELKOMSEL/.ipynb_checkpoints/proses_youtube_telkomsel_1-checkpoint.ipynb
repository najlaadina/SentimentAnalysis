# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Kalau kalian ngeluh sinyalnya, cobain provider...
# 1    Mohon di segera diperbaiki, JANGAN  abal2, jan...
# 2                 Di akhir lagunya tambahin lirik geh.
# 3    Tolong diperbaikin sinyalnya, didaearh Sulawes...
# 4                           Bangkrut pakai kartu halo,
# ..                                                 ...
# 359                                      Nah gitu dong
# 360  WOI KENAPA JATIM NGELEG SINYAL NYA UDH SEMINGG...
# 361   Min gimana ini, jaringan makin hancur aja :')...
# 362                        Min first komen dapet apa..
# 363                                             Fibber
#
# [364 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 85

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Kalau kalian ngeluh sinyalnya, cobain provider...
# 1    Mohon di segera diperbaiki, JANGAN  abal2, jan...
# 2                 Di akhir lagunya tambahin lirik geh.
# 3    Tolong diperbaikin sinyalnya, didaearh Sulawes...
# 4                           Bangkrut pakai kartu halo,
# ..                                                 ...
# 358                                        Lagg parah,
# 359                                      Nah gitu dong
# 360  WOI KENAPA JATIM NGELEG SINYAL NYA UDH SEMINGG...
# 362                        Min first komen dapet apa..
# 363                                             Fibber
#
# [199 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    kalau kalian ngeluh sinyalnya, cobain provider...
# 1    mohon di segera diperbaiki, jangan  abal2, jan...
# 2                 di akhir lagunya tambahin lirik geh.
# 3    tolong diperbaikin sinyalnya, didaearh sulawes...
# 4                           bangkrut pakai kartu halo,
# ..                                                 ...
# 358                                        lagg parah,
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                        min first komen dapet apa..
# 363                                             fibber
#
# [199 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    kalau kalian ngeluh sinyalnya, cobain provider...
# 1    mohon di segera diperbaiki, jangan  abal2, jan...
# 2                 di akhir lagunya tambahin lirik geh.
# 3    tolong diperbaikin sinyalnya, didaearh sulawes...
# 4                           bangkrut pakai kartu halo,
# ..                                                 ...
# 358                                        lagg parah,
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                        min first komen dapet apa..
# 363                                             fibber
#
#                                       cleaning_comment
# 0    kalau kalian ngeluh sinyalnya cobain provider ...
# 1    mohon segera diperbaiki jangan abal  jangan me...
# 2                    akhir lagunya tambahin lirik geh
# 3    tolong diperbaikin sinyalnya didaearh sulawesi...
# 4                           bangkrut pakai kartu halo
# ..                                                 ...
# 358                                        lagg parah
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                         min first komen dapet apa
# 363                                             fibber
#
# [199 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    kalau kalian ngeluh sinyalnya, cobain provider...
# 1    mohon di segera diperbaiki, jangan  abal2, jan...
# 2                 di akhir lagunya tambahin lirik geh.
# 3    tolong diperbaikin sinyalnya, didaearh sulawes...
# 4                           bangkrut pakai kartu halo,
# ..                                                 ...
# 358                                        lagg parah,
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                        min first komen dapet apa..
# 363                                             fibber
#
#                                       cleaning_comment  \
# 0    kalau kalian ngeluh sinyalnya cobain provider ...
# 1    mohon segera diperbaiki jangan abal  jangan me...
# 2                    akhir lagunya tambahin lirik geh
# 3    tolong diperbaikin sinyalnya didaearh sulawesi...
# 4                           bangkrut pakai kartu halo
# ..                                                 ...
# 358                                        lagg parah
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                         min first komen dapet apa
# 363                                             fibber
#
#                                             tokenisasi
# 0    [kalau, kalian, ngeluh, sinyalnya, cobain, pro...
# 1    [mohon, segera, diperbaiki, jangan, abal, jang...
# 2           [, akhir, lagunya, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyalnya, didaearh, sul...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                  [nah, gitu, dong]
# 360  [woi, kenapa, jatim, ngeleg, sinyal, nya, udh,...
# 362                  [min, first, komen, dapet, apa, ]
# 363                                           [fibber]
#
# [199 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    kalau kalian ngeluh sinyalnya, cobain provider...
# 1    mohon di segera diperbaiki, jangan  abal2, jan...
# 2                 di akhir lagunya tambahin lirik geh.
# 3    tolong diperbaikin sinyalnya, didaearh sulawes...
# 4                           bangkrut pakai kartu halo,
# ..                                                 ...
# 358                                        lagg parah,
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                        min first komen dapet apa..
# 363                                             fibber
#
#                                       cleaning_comment  \
# 0    kalau kalian ngeluh sinyalnya cobain provider ...
# 1    mohon segera diperbaiki jangan abal  jangan me...
# 2                    akhir lagunya tambahin lirik geh
# 3    tolong diperbaikin sinyalnya didaearh sulawesi...
# 4                           bangkrut pakai kartu halo
# ..                                                 ...
# 358                                        lagg parah
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                         min first komen dapet apa
# 363                                             fibber
#
#                                             tokenisasi  \
# 0    [kalau, kalian, ngeluh, sinyalnya, cobain, pro...
# 1    [mohon, segera, diperbaiki, jangan, abal, jang...
# 2           [, akhir, lagunya, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyalnya, didaearh, sul...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                  [nah, gitu, dong]
# 360  [woi, kenapa, jatim, ngeleg, sinyal, nya, udh,...
# 362                  [min, first, komen, dapet, apa, ]
# 363                                           [fibber]
#
#                                               stopword
# 0    [ngeluh, sinyalnya, cobain, provider, biru, ku...
# 1    [mohon, diperbaiki, abal, menang, brand, doang, ]
# 2                  [, lagunya, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyalnya, didaearh, sul...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                             [gitu]
# 360  [woi, jatim, ngeleg, sinyal, udh, seminggu, cu...
# 362                       [min, first, komen, dapet, ]
# 363                                           [fibber]
#
# [199 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 578
# ------------------------
# ngeluh : ngeluh
# sinyalnya : sinyal
# cobain : cobain
# provider : provider
# biru : biru
# kuning : kuning
# coba : coba
# mohon : mohon
# diperbaiki : baik
# abal : abal
# menang : menang
# brand : brand
# doang : doang
#  :
# lagunya : lagu
# tambahin : tambahin
# lirik : lirik
# geh : geh
# tolong : tolong
# diperbaikin : diperbaikin
# didaearh : didaearh
# sulawesi : sulawesi
# hancur : hancur
# banget : banget
# paketannya : paket
# mahalin : mahalin
# bangkrut : bangkrut
# pakai : pakai
# kartu : kartu
# halo : halo
# telkomsel : telkomsel
# sinyal : sinyal
# buruk : buruk
# asli : asli
# parah : parah
# thn : thn
# maret : maret
# jaringan : jaring
# game : game
# suka : suka
# errorrr : errorrr
# nyesel : nyesel
# gua : gua
# susah : susah
# min : min
# deh : deh
# gue : gue
# beli : beli
# unlimited : unlimited
# nonton : nonton
# youtube : youtube
# udah : udah
# kualitas : kualitas
# ngelag : ngelag
# hhhhh : hhhhh
# iya : iya
# perkuat : kuat
# promo : promo
# lagu : lagu
# sesuai : sesuai
# fakta : fakta
# gitu : gitu
# niat : niat
# njirrr : njirrr
# internet : internet
# kek : kek
# anjim : anjim
# jaringannya : jaring
# ngeleg : ngeleg
# gaa : gaa
# sebagus : bagus
# blokir : blokir
# nomor : nomor
# kha : kha
# suruh : suruh
# ujan : ujan
# berasa : asa
# kuota : kuota
# gratis : gratis
# kecewa : kecewa
# manaa : manaa
# pemenangnya : menang
# chat : chat
# twitter : twitter
# kasi : kasi
# event : event
# tukar : tukar
# poin : poin
# jdi : jdi
# uang : uang
# jajan : jajan
# link : link
# jaring : jaring
# paket : paket
# gamemax : gamemax
# dimainin : dimainin
# smartfren : smartfren
# mantul : mantul
# murah : murah
# bakar : bakar
# paketannn : paketannn
# asssuuuuu : asssuuuuu
# gamer : gamer
# pelagan : lagan
# pindah : pindah
# axis : axis
# indosat : indosat
# three : three
# ngapain : ngapain
# megecewakan : megecewakan
# sedunia : dunia
# kayak : kayak
# taek : taek
# pulsa : pulsa
# hilang : hilang
# sistim : sistim
# semoga : moga
# ganti : ganti
# gelek : gelek
# main : main
# over : over
# masak : masak
# gau : gau
# lag : lag
# teruss : teruss
# rank : rank
# turun : turun
# gara : gara
# mulu : mulu
# ajg : ajg
# kon : kon
# telkom : telkom
# rusak : rusak
# saiki : saiki
# kuat : kuat
# cok : cok
# kaya : kaya
# taii : taii
# inter : inter
# paraaahhhh : paraaahhhh
# englek : englek
# keganggu : ganggu
# kebatal : batal
# masuk : masuk
# pas : pas
# turnamen : turnamen
# wifinya : wifinya
# woyyyy : woyyyy
# sampah : sampah
# njir : njir
# balikin : balikin
# skrng : skrng
# nyindir : nyindir
# perdana : perdana
# hujan : hujan
# waaah : waaah
# auto : auto
# sumpah : sumpah
# gausah : gausah
# dibeli : beli
# buang : buang
# duit : duit
# down : down
# ayo : ayo
# nyusahin : nyusahin
# pengguna : guna
# doank : doank
# telsampah : telsampah
# twi : twi
# tempi : tempi
# mantap : mantap
# lemooottttr : lemooottttr
# laku : laku
# gerti : gerti
# hahahaha : hahahaha
# tekom : tekom
# sel : sel
# bar : bar
# penuh : penuh
# kosong : kosong
# sayangkan : sayang
# andalkan : andal
# pol : pol
# peebaiki : peebaiki
# woi : woi
# tekomsel : tekomsel
# nggak : nggak
# nyesal : nyesal
# mke : mke
# telkosel : telkosel
# aset : aset
# peradaban : adab
# modern : modern
# smgoa : smgoa
# beruntung : untung
# hadiah : hadiah
# saldo : saldo
# amiinn : amiinn
# emang : emang
# rejeki : rejeki
# mah : mah
# atur : atur
# real : real
# settingan : settingan
# mbae : mbae
# pandang : pandang
# bulu : bulu
# berharap : harap
# dapet : dapet
# smartphone : smartphone
# mobil : mobil
# motor : motor
# karna : karna
# menunjang : tunjang
# kehidupan : hidup
# komunikasi : komunikasi
# sehari : hari
# thank : thank
# telkomselll : telkomselll
# alhamdulillah : alhamdulillah
# dpt : dpt
# rp : rp
# pemenang : menang
# lbh : lbh
# sukses : sukses
# paketnya : paket
# dibedakan : beda
# loop : loop
# simpati : simpati
# seru : seru
# dipisah : pisah
# segmen : segmen
# harga : harga
# beda : beda
# serius : serius
# nanya : nanya
# beneran : beneran
# setingan : ting
# husus : husus
# keluarga : keluarga
# karyawan : karyawan
# karyawati : karyawati
# telkomnyeeeeeeet : telkomnyeeeeeeet
# mending : mending
# sebelah : belah
# bos : bos
# stabil : stabil
# lemotnya : lot
# leletnya : lelet
# honda : honda
# adv : adv
# periode : periode
# undi : undi
# hepi : hepi
# tpi : tpi
# sayang : sayang
# surat : surat
# nunggu : nunggu
# undian : undi
# dihitung : hitung
# pemotongan : potong
# sistem : sistem
# pelanggan : langgan
# aktifkan : aktif
# diprogram : program
# memotong : potong
# otomatis : otomatis
# misi : misi
# mba : mba
# tlp : tlp
# suru : suru
# isi : isi
# rb : rb
# juta : juta
# kupang : kupang
# ntt : ntt
# th : th
# blm : blm
# hadiahnya : hadiah
# apapun : apa
# program : program
# berhadiah : hadiah
# yonweslah : yonweslah
# beeuntung : beeuntung
# mgkn : mgkn
# sehat : sehat
# dihati : hati
# daftar : daftar
# kah : kah
# gimik : gimik
# ngundi : ngundi
# koplak : koplak
# liat : liat
# nama : nama
# diterima : terima
# kabarnya : kabar
# enak : enak
# geme : geme
# lansung : lansung
# binatang : binatang
# pengundiannya : undi
# berani : berani
# tampilin : tampilin
# wifi : wifi
# indihome : indihome
# rumah : rumah
# ngapa : ngapa
# leg : leg
# oiii : oiii
# bayar : bayar
# perbulanan : bulan
# udh : udh
# lapor : lapor
# pemerintah : perintah
# daerah : daerah
# oprator : oprator
# tanggapi : tanggap
# makan : makan
# gajih : gajih
# buta : buta
# bukanya : buka
# respeck : respeck
# pekerja : kerja
# lapangan : lapang
# teknisi : teknisi
# coeg : coeg
# makek : makek
# telkomnyet : telkomnyet
# asuuu : asuuu
# perbaiki : baik
# bumn : bumn
# merugihkan : merugihkan
# rakyat : rakyat
# bijakan : bijak
# inpokan : inpokan
# kampung : kampung
# ciangireun : ciangireun
# desa : desa
# girijagabaya : girijagabaya
# kecamatan : camat
# muncang : muncang
# kabupaten : kabupaten
# lebak : lebak
# banten : banten
# tida : tida
# membutuhkan : butuh
# kring : kring
# telefon : telefon
# berdering : dering
# nelfon : nelfon
# untung : untung
# dech : dech
# risna : risna
# kagak : kagak
# abisnya : abis
# mangkin : mangkin
# buriq : buriq
# iklan : iklan
# bagus : bagus
# pembohong : bohong
# instagram : instagram
# kak : kak
# pantun : pantun
# sinyalmu : sinyal
# lebur : lebur
# hidup : hidup
# kota : kota
# terpelosok : pelosok
# emng : emng
# keren : keren
# nyimak : nyimak
# gimana : gimana
# nge : nge
# siang : siang
# malem : malem
# bang : bang
# sarbini : sarbini
# hadir : hadir
# nmr : nmr
# telkomtol : telkomtol
# jls : jls
# lucky : lucky
# draw : draw
# yok : yok
# dislike : dislike
# rame : rame
# push : push
# putus : putus
# hadia : hadia
# kalu : kalu
# jaringanya : jaringanya
# burik : burik
# tinggal : tinggal
# njing : njing
# kelebihan : lebih
# mati : mati
# lelet : lelet
# operator : operator
# emosi : emosi
# anjing : anjing
# kelewat : lewat
# batas : batas
# niak : niak
# kerja : kerja
# pecat : pecat
# taiiiii : taiiiii
# hore : hore
# menanggg : menanggg
# perbaikin : perbaikin
# benerin : benerin
# bener : bener
# dengerin : dengerin
# wey : wey
# bobrok : bobrok
# kali : kali
# bangat : bangat
# kuata : kuata
# gede : gede
# luh : luh
# tenang : tenang
# macem : macem
# telkomsell : telkomsell
# gini : gin
# cacat : cacat
# toloollllllllll : toloollllllllll
# kecawa : kecawa
# berpaling : paling
# pegawai : pegawai
# tdr : tdr
# telkomyet : telkomyet
# males : males
# langganan : langgan
# kecepatan : cepat
# mbps : mbps
# kbps : kbps
# trus : trus
# sinergi : sinergi
# anak : anak
# indonesia : indonesia
# kedaulatan : daulat
# infrastruktur : infrastruktur
# digital : digital
# ekonomi : ekonomi
# dunia : dunia
# tarifnya : tarif
# kerinci : kerinci
# terjang : terjang
# pke : pke
# sllu : sllu
# lancar : lancar
# beralih : alih
# segmennya : segmen
# dlu : dlu
# desak : desak
# lampung : lampung
# aplikasi : aplikasi
# baiki : baik
# hspa : hspa
# knp : knp
# pemasukan : pasu
# ngl : ngl
# gaji : gaji
# dilampung : lampung
# tulang : tulang
# bawang : bawang
# dente : dente
# teladas : teladas
# sungai : sungai
# nibung : nibung
# dusun : dusun
# lemah : lemah
# bohong : bohong
# merata : rata
# seindonesia : indonesia
# besok : besok
# umumkan : umum
# pesta : pesta
# menteri : menteri
# error : error
# woy : woy
# bogor : bogor
# bakti : bakti
# hmmmm : hmmmm
# tlng : tlng
# cpt : cpt
# atasi : atas
# surve : surve
# tangerang : tangerang
# selatan : selatan
# aduh : aduh
# jamd : jamd
# lte : lte
# pasang : pasang
# hape : hape
# ngotak : ngotak
# tarif : tarif
# taik : taik
# negara : negara
# menggebu : gebu
# wkwkwkw : wkwkwkw
# balikan : balik
# perangkat : perangkat
# erikson : erikson
# kasian : kasi
# dmna : dmna
# gangguan : ganggu
# max : max
# cba : cba
# kmren : kmren
# msh : msh
# bgus : bgus
# mlh : mlh
# kpung : kpung
# lembursingkur : lembursingkur
# pasilitas : pasilitas
# kesejahteraan : sejahtera
# mantab : mantab
# donk : donk
# kendari : kendari
# area : area
# tenggara : tenggara
# malaysia : malaysia
# baya : baya
# terbabi : babi
# kalimantan : kalimantan
# nyata : nyata
# nyatu : nyatu
# knapa : knapa
# eror : eror
# terimakasih : terimakasih
# pedalaman : dalam
# papua : papua
# wilayah : wilayah
# asiki : asiki
# distrik : distrik
# jair : jair
# boben : boben
# digoel : goel
# propinsi : propinsi
# menikmati : nikmat
# gunung : gunung
# kab : kab
# pali : pali
# woyy : woyy
# pedesaan : desa
# perbaili : perbaili
# jink : jink
# tolng : tolng
# percepat : cepat
# singapura : singapura
# sidah : sidah
# boro : boro
# lol : lol
# kacau : kacau
# jam : jam
# mlm : mlm
# sampe : sampe
# bandwid : bandwid
# ancur : ancur
# nihhh : nihhh
# ahh : ahh
# hoax : hoax
# setiamu : setia
# pliss : pliss
# jawa : jawa
# timur : timur
# mlosok : mlosok
# woiii : woiii
# didaerah : daerah
# babel : babel
# lagg : lagg
# jatim : jatim
# seminggu : minggu
# cuman : cuman
# mlbb : mlbb
# first : first
# komen : komen
# fibber : fibber
# {'ngeluh': 'ngeluh', 'sinyalnya': 'sinyal', 'cobain': 'cobain', 'provider': 'provider', 'biru': 'biru', 'kuning': 'kuning', 'coba': 'coba', 'mohon': 'mohon', 'diperbaiki': 'baik', 'abal': 'abal', 'menang': 'menang', 'brand': 'brand', 'doang': 'doang', '': '', 'lagunya': 'lagu', 'tambahin': 'tambahin', 'lirik': 'lirik', 'geh': 'geh', 'tolong': 'tolong', 'diperbaikin': 'diperbaikin', 'didaearh': 'didaearh', 'sulawesi': 'sulawesi', 'hancur': 'hancur', 'banget': 'banget', 'paketannya': 'paket', 'mahalin': 'mahalin', 'bangkrut': 'bangkrut', 'pakai': 'pakai', 'kartu': 'kartu', 'halo': 'halo', 'telkomsel': 'telkomsel', 'sinyal': 'sinyal', 'buruk': 'buruk', 'asli': 'asli', 'parah': 'parah', 'thn': 'thn', 'maret': 'maret', 'jaringan': 'jaring', 'game': 'game', 'suka': 'suka', 'errorrr': 'errorrr', 'nyesel': 'nyesel', 'gua': 'gua', 'susah': 'susah', 'min': 'min', 'deh': 'deh', 'gue': 'gue', 'beli': 'beli', 'unlimited': 'unlimited', 'nonton': 'nonton', 'youtube': 'youtube', 'udah': 'udah', 'kualitas': 'kualitas', 'ngelag': 'ngelag', 'hhhhh': 'hhhhh', 'iya': 'iya', 'perkuat': 'kuat', 'promo': 'promo', 'lagu': 'lagu', 'sesuai': 'sesuai', 'fakta': 'fakta', 'gitu': 'gitu', 'niat': 'niat', 'njirrr': 'njirrr', 'internet': 'internet', 'kek': 'kek', 'anjim': 'anjim', 'jaringannya': 'jaring', 'ngeleg': 'ngeleg', 'gaa': 'gaa', 'sebagus': 'bagus', 'blokir': 'blokir', 'nomor': 'nomor', 'kha': 'kha', 'suruh': 'suruh', 'ujan': 'ujan', 'berasa': 'asa', 'kuota': 'kuota', 'gratis': 'gratis', 'kecewa': 'kecewa', 'manaa': 'manaa', 'pemenangnya': 'menang', 'chat': 'chat', 'twitter': 'twitter', 'kasi': 'kasi', 'event': 'event', 'tukar': 'tukar', 'poin': 'poin', 'jdi': 'jdi', 'uang': 'uang', 'jajan': 'jajan', 'link': 'link', 'jaring': 'jaring', 'paket': 'paket', 'gamemax': 'gamemax', 'dimainin': 'dimainin', 'smartfren': 'smartfren', 'mantul': 'mantul', 'murah': 'murah', 'bakar': 'bakar', 'paketannn': 'paketannn', 'asssuuuuu': 'asssuuuuu', 'gamer': 'gamer', 'pelagan': 'lagan', 'pindah': 'pindah', 'axis': 'axis', 'indosat': 'indosat', 'three': 'three', 'ngapain': 'ngapain', 'megecewakan': 'megecewakan', 'sedunia': 'dunia', 'kayak': 'kayak', 'taek': 'taek', 'pulsa': 'pulsa', 'hilang': 'hilang', 'sistim': 'sistim', 'semoga': 'moga', 'ganti': 'ganti', 'gelek': 'gelek', 'main': 'main', 'over': 'over', 'masak': 'masak', 'gau': 'gau', 'lag': 'lag', 'teruss': 'teruss', 'rank': 'rank', 'turun': 'turun', 'gara': 'gara', 'mulu': 'mulu', 'ajg': 'ajg', 'kon': 'kon', 'telkom': 'telkom', 'rusak': 'rusak', 'saiki': 'saiki', 'kuat': 'kuat', 'cok': 'cok', 'kaya': 'kaya', 'taii': 'taii', 'inter': 'inter', 'paraaahhhh': 'paraaahhhh', 'englek': 'englek', 'keganggu': 'ganggu', 'kebatal': 'batal', 'masuk': 'masuk', 'pas': 'pas', 'turnamen': 'turnamen', 'wifinya': 'wifinya', 'woyyyy': 'woyyyy', 'sampah': 'sampah', 'njir': 'njir', 'balikin': 'balikin', 'skrng': 'skrng', 'nyindir': 'nyindir', 'perdana': 'perdana', 'hujan': 'hujan', 'waaah': 'waaah', 'auto': 'auto', 'sumpah': 'sumpah', 'gausah': 'gausah', 'dibeli': 'beli', 'buang': 'buang', 'duit': 'duit', 'down': 'down', 'ayo': 'ayo', 'nyusahin': 'nyusahin', 'pengguna': 'guna', 'doank': 'doank', 'telsampah': 'telsampah', 'twi': 'twi', 'tempi': 'tempi', 'mantap': 'mantap', 'lemooottttr': 'lemooottttr', 'laku': 'laku', 'gerti': 'gerti', 'hahahaha': 'hahahaha', 'tekom': 'tekom', 'sel': 'sel', 'bar': 'bar', 'penuh': 'penuh', 'kosong': 'kosong', 'sayangkan': 'sayang', 'andalkan': 'andal', 'pol': 'pol', 'peebaiki': 'peebaiki', 'woi': 'woi', 'tekomsel': 'tekomsel', 'nggak': 'nggak', 'nyesal': 'nyesal', 'mke': 'mke', 'telkosel': 'telkosel', 'aset': 'aset', 'peradaban': 'adab', 'modern': 'modern', 'smgoa': 'smgoa', 'beruntung': 'untung', 'hadiah': 'hadiah', 'saldo': 'saldo', 'amiinn': 'amiinn', 'emang': 'emang', 'rejeki': 'rejeki', 'mah': 'mah', 'atur': 'atur', 'real': 'real', 'settingan': 'settingan', 'mbae': 'mbae', 'pandang': 'pandang', 'bulu': 'bulu', 'berharap': 'harap', 'dapet': 'dapet', 'smartphone': 'smartphone', 'mobil': 'mobil', 'moto ...
# ------------------------
# Pandas Apply:   0%|          | 0/199 [00:00<?, ?it/s]
#                                                comment  \
# 0    kalau kalian ngeluh sinyalnya, cobain provider...
# 1    mohon di segera diperbaiki, jangan  abal2, jan...
# 2                 di akhir lagunya tambahin lirik geh.
# 3    tolong diperbaikin sinyalnya, didaearh sulawes...
# 4                           bangkrut pakai kartu halo,
# ..                                                 ...
# 358                                        lagg parah,
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                        min first komen dapet apa..
# 363                                             fibber
#
#                                       cleaning_comment  \
# 0    kalau kalian ngeluh sinyalnya cobain provider ...
# 1    mohon segera diperbaiki jangan abal  jangan me...
# 2                    akhir lagunya tambahin lirik geh
# 3    tolong diperbaikin sinyalnya didaearh sulawesi...
# 4                           bangkrut pakai kartu halo
# ..                                                 ...
# 358                                        lagg parah
# 359                                      nah gitu dong
# 360  woi kenapa jatim ngeleg sinyal nya udh semingg...
# 362                         min first komen dapet apa
# 363                                             fibber
#
#                                             tokenisasi  \
# 0    [kalau, kalian, ngeluh, sinyalnya, cobain, pro...
# 1    [mohon, segera, diperbaiki, jangan, abal, jang...
# 2           [, akhir, lagunya, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyalnya, didaearh, sul...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                  [nah, gitu, dong]
# 360  [woi, kenapa, jatim, ngeleg, sinyal, nya, udh,...
# 362                  [min, first, komen, dapet, apa, ]
# 363                                           [fibber]
#
#                                               stopword  \
# 0    [ngeluh, sinyalnya, cobain, provider, biru, ku...
# 1    [mohon, diperbaiki, abal, menang, brand, doang, ]
# 2                  [, lagunya, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyalnya, didaearh, sul...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                             [gitu]
# 360  [woi, jatim, ngeleg, sinyal, udh, seminggu, cu...
# 362                       [min, first, komen, dapet, ]
# 363                                           [fibber]
#
#                                               stemming
# 0    [ngeluh, sinyal, cobain, provider, biru, kunin...
# 1          [mohon, baik, abal, menang, brand, doang, ]
# 2                     [, lagu, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyal, didaearh, sulawe...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                             [gitu]
# 360  [woi, jatim, ngeleg, sinyal, udh, minggu, cuma...
# 362                       [min, first, komen, dapet, ]
# 363                                           [fibber]
#
# [199 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [ngeluh, sinyal, cobain, provider, biru, kunin...
# 1          [mohon, baik, abal, menang, brand, doang, ]
# 2                     [, lagu, tambahin, lirik, geh, ]
# 3    [tolong, diperbaikin, sinyal, didaearh, sulawe...
# 4                     [bangkrut, pakai, kartu, halo, ]
# ..                                                 ...
# 358                                    [lagg, parah, ]
# 359                                             [gitu]
# 360  [woi, jatim, ngeleg, sinyal, udh, minggu, cuma...
# 362                       [min, first, komen, dapet, ]
# 363                                           [fibber]
#
# [199 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_1.xlsx')
