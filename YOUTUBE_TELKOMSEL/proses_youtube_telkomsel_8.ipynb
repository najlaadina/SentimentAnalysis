# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\YOUTUBE_TELKOMSEL\data_mentah\youtube_telkomsel_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Smartfren lebih nikmat sodara meskipun di kamp...
# 1    SIAPA YG BERHARAP ADA OPERATOR YG LEBIH BAIK??...
# 2                                Wow Amazing Telkomsel
# 3                             Telkomsel Tetap Di Udara
# 4    Doga rejekiikwn cell lancar dan barokah Amin2y...
# ..                                                 ...
# 392                                           Kesel gw
# 393                                       Tukang korup
# 394                                   Sinyal mcam taik
# 395                                    Chanel gak guna
# 396  Telkomsel akhir² ini butut. Perbaiki dulu jari...
#
# [397 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 72

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Smartfren lebih nikmat sodara meskipun di kamp...
# 1    SIAPA YG BERHARAP ADA OPERATOR YG LEBIH BAIK??...
# 2                                Wow Amazing Telkomsel
# 3                             Telkomsel Tetap Di Udara
# 4    Doga rejekiikwn cell lancar dan barokah Amin2y...
# ..                                                 ...
# 392                                           Kesel gw
# 393                                       Tukang korup
# 394                                   Sinyal mcam taik
# 395                                    Chanel gak guna
# 396  Telkomsel akhir² ini butut. Perbaiki dulu jari...
#
# [255 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    smartfren lebih nikmat sodara meskipun di kamp...
# 1    siapa yg berharap ada operator yg lebih baik??...
# 2                                wow amazing telkomsel
# 3                             telkomsel tetap di udara
# 4    doga rejekiikwn cell lancar dan barokah amin2y...
# ..                                                 ...
# 392                                           kesel gw
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir² ini butut. perbaiki dulu jari...
#
# [255 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    smartfren lebih nikmat sodara meskipun di kamp...
# 1    siapa yg berharap ada operator yg lebih baik??...
# 2                                wow amazing telkomsel
# 3                             telkomsel tetap di udara
# 4    doga rejekiikwn cell lancar dan barokah amin2y...
# ..                                                 ...
# 392                                           kesel gw
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir² ini butut. perbaiki dulu jari...
#
#                                       cleaning_comment
# 0    smartfren lebih nikmat sodara meskipun kampung...
# 1        siapa berharap ada operator lebih baik absen
# 2                                wow amazing telkomsel
# 3                                telkomsel tetap udara
# 4    doga rejekiikwn cell lancar dan barokah amin y...
# ..                                                 ...
# 392                                             kesel
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir ini butut perbaiki dulu jaring...
#
# [255 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    smartfren lebih nikmat sodara meskipun di kamp...
# 1    siapa yg berharap ada operator yg lebih baik??...
# 2                                wow amazing telkomsel
# 3                             telkomsel tetap di udara
# 4    doga rejekiikwn cell lancar dan barokah amin2y...
# ..                                                 ...
# 392                                           kesel gw
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir² ini butut. perbaiki dulu jari...
#
#                                       cleaning_comment  \
# 0    smartfren lebih nikmat sodara meskipun kampung...
# 1        siapa berharap ada operator lebih baik absen
# 2                                wow amazing telkomsel
# 3                                telkomsel tetap udara
# 4    doga rejekiikwn cell lancar dan barokah amin y...
# ..                                                 ...
# 392                                             kesel
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir ini butut perbaiki dulu jaring...
#
#                                             tokenisasi
# 0    [smartfren, lebih, nikmat, sodara, meskipun, k...
# 1    [siapa, berharap, ada, operator, lebih, baik, ...
# 2                            [wow, amazing, telkomsel]
# 3                            [telkomsel, tetap, udara]
# 4    [doga, rejekiikwn, cell, lancar, dan, barokah,...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                [chanel, gak, guna]
# 396  [telkomsel, akhir, ini, butut, perbaiki, dulu,...
#
# [255 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    smartfren lebih nikmat sodara meskipun di kamp...
# 1    siapa yg berharap ada operator yg lebih baik??...
# 2                                wow amazing telkomsel
# 3                             telkomsel tetap di udara
# 4    doga rejekiikwn cell lancar dan barokah amin2y...
# ..                                                 ...
# 392                                           kesel gw
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir² ini butut. perbaiki dulu jari...
#
#                                       cleaning_comment  \
# 0    smartfren lebih nikmat sodara meskipun kampung...
# 1        siapa berharap ada operator lebih baik absen
# 2                                wow amazing telkomsel
# 3                                telkomsel tetap udara
# 4    doga rejekiikwn cell lancar dan barokah amin y...
# ..                                                 ...
# 392                                             kesel
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir ini butut perbaiki dulu jaring...
#
#                                             tokenisasi  \
# 0    [smartfren, lebih, nikmat, sodara, meskipun, k...
# 1    [siapa, berharap, ada, operator, lebih, baik, ...
# 2                            [wow, amazing, telkomsel]
# 3                            [telkomsel, tetap, udara]
# 4    [doga, rejekiikwn, cell, lancar, dan, barokah,...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                [chanel, gak, guna]
# 396  [telkomsel, akhir, ini, butut, perbaiki, dulu,...
#
#                                               stopword
# 0    [smartfren, nikmat, sodara, kampung, manteng, ...
# 1                        [berharap, operator, absen, ]
# 2                            [wow, amazing, telkomsel]
# 3                                   [telkomsel, udara]
# 4    [doga, rejekiikwn, cell, lancar, barokah, amin...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                           [chanel]
# 396      [telkomsel, butut, perbaiki, jaringan, promo]
#
# [255 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 717
# ------------------------
# smartfren : smartfren
# nikmat : nikmat
# sodara : sodara
# kampung : kampung
# manteng : manteng
# lelet : lelet
# kartu : kartu
# telkom : telkom
# smuanya : smuanya
# pindah : pindah
# smartfreen : smartfreen
#  :
# berharap : harap
# operator : operator
# absen : absen
# wow : wow
# amazing : amazing
# telkomsel : telkomsel
# udara : udara
# doga : doga
# rejekiikwn : rejekiikwn
# cell : cell
# lancar : lancar
# barokah : barokah
# amin : amin
# yarobalamin : yarobalamin
# suka : suka
# nge : nge
# lag : lag
# maknya : maknya
# main : main
# game : game
# stress : stress
# giliran : gilir
# belajar : ajar
# daring : daring
# sinyal : sinyal
# udh : udh
# bagus : bagus
# duluan : duluan
# gua : gua
# kelas : kelas
# smk : smk
# suruh : suruh
# isi : isi
# pendataan : data
# kouta : kouta
# gratis : gratis
# kakak : kakak
# kls : kls
# sekolah : sekolah
# promo : promo
# kelain : lain
# hati : hati
# contoh : contoh
# pulsa : pulsa
# ribu : ribu
# trus : trus
# beli : beli
# paket : paket
# internet : internet
# all : all
# net : net
# harga : harga
# sisa : sisa
# udah : udah
# paketan : paket
# dikit : dikit
# tarik : tarik
# kadang : kadang
# pas : pas
# uang : uang
# tinggal : tinggal
# doang : doang
# hmm : hmm
# knapa : knapa
# ngga : ngga
# combo : combo
# sakti : sakti
# min : min
# mohon : mohon
# balasan : balas
# berbenah : benah
# pasrah : pasrah
# milikku : milik
# provider : provider
# pusing : pusing
# kuotanya : kuota
# abis : abis
# thebest : thebest
# zippp : zippp
# muantaappp : muantaappp
# barusan : barusan
# simpati : simpati
# down : down
# kali : kali
# menit : menit
# bgtu : bgtu
# turun : turun
# bar : bar
# huhu : huhu
# sedih : sedih
# guys : guys
# kawasan : kawasan
# jabodetabek : jabodetabek
# iming : iming
# imingnya : imingnya
# mantep : mantep
# tipu : tipu
# menyakitkan : sakit
# kawan : kawan
# terbaik : baik
# kuota : kuota
# utama : utama
# bonus : bonus
# dipake : dipake
# jenjang : jenjang
# terbatas : batas
# kasih : kasih
# mending : mending
# php : php
# sakit : sakit
# daerah : daerah
# cilacap : cilacap
# jawa : jawa
# parah : parah
# brpa : brpa
# hargany : hargany
# wahahahaa : wahahahaa
# tekomsel : tekomsel
# terburuk : buruk
# koneksi : koneksi
# kirim : kirim
# bantuan : bantu
# ngab : ngab
# axis : axis
# jaringan : jaring
# masi : mas
# stabil : stabil
# wilayah : wilayah
# indosat : indosat
# ganti : ganti
# rebahan : rebah
# rumah : rumah
# golongan : golong
# multimedia : multimedia
# makasih : makasih
# please : please
# diperbaiki : baik
# pup : pup
# nggk : nggk
# ditanggal : tanggal
# hidup : hidup
# salam : salam
# kenal : kenal
# tagus : tagus
# melet : melet
# chanel : chanel
# semoga : moga
# sehat : sehat
# pke : pke
# hotpot : hotpot
# temen : temen
# efek : efek
# nganggur : nganggur
# krja : krja
# sepuasnya : puas
# merdeka : merdeka
# saking : saking
# lancarnya : lancar
# pelajaran : ajar
# kedengeran : kedengeran
# nyakitin : nyakitin
# orang : orang
# nyimak : nyimak
# asik : asik
# seru : seru
# ter : ter
# kecewa : kecewa
# berat : berat
# pdhl : pdhl
# kyk : kyk
# skrg : skrg
# angin : angin
# kenceng : kenceng
# internetnya : internetnya
# gb : gb
# rp : rp
# gimana : gimana
# carayah : carayah
# daftar : daftar
# susah : susah
# ijin : ijin
# mendikbud : mendikbud
# aplikasi : aplikasi
# parahmen : parahmen
# mengeluh : keluh
# pemakaian : pakai
# youtube : youtube
# zoom : zoom
# berganti : ganti
# versi : versi
# sampe : sampe
# sebulan : bulan
# nyedot : nyedot
# banget : banget
# sekeluarga : keluarga
# ngeluarin : ngeluarin
# duit : duit
# gan : gan
# bantu : bantu
# signal : signal
# buruk : buruk
# sprti : sprti
# coba : coba
# pengguna : guna
# berlaku : laku
# gaesss : gaesss
# ilangan : ilangan
# judulnya : judul
# nyari : nyari
# untung : untung
# konsumen : konsumen
# waspadai : waspada
# jebakan : jebak
# batman : batman
# jagoan : jago
# tambahan : tambah
# absennya : absen
# gmana : gmana
# depetin : depetin
# hadir : hadir
# menyimak : simak
# bosqiu : bosqiu
# gaguna : gaguna
# ilang : ilang
# byk : byk
# dpt : dpt
# msh : msh
# akhr : akhr
# org : org
# pket : pket
# tanggung : tanggung
# blm : blm
# uda : uda
# hangus : hangus
# brp : brp
# trs : trs
# habis : habis
# aktinya : aktinya
# rugi : rugi
# otak : otak
# hitung : hitung
# menghitung : hitung
# bkn : bkn
# bisnis : bisnis
# muter : muter
# otaknya : otak
# untk : untk
# mulu : mulu
# telkomselku : telkomselku
# update : update
# dipakek : dipakek
# kentang : kentang
# jaringanya : jaringanya
# murah : murah
# tetep : tetep
# byu : byu
# sihh : sihh
# gini : gin
# percaya : percaya
# prmo : prmo
# hahaha : hahaha
# buktinya : bukti
# menipunya : tipu
# mendingan : mending
# paksi : paksi
# aturan : atur
# kek : kek
# kauta : kauta
# binatang : binatang
# leg : leg
# ama : ama
# singal : singal
# dukung : dukung
# andai : andai
# saaya : saaya
# jls : jls
# woody : woody
# menipu : tipu
# gaya : gaya
# download : download
# kompetibel : kompetibel
# dahlah : dah
# males : males
# saaaa : saaaa
# aeeeee : aeeeee
# tilkimsil : tilkimsil
# online : online
# tolong : tolong
# stabilkan : stabil
# unlimited : unlimited
# batas : batas
# knp : knp
# smenjak : smenjak
# lambang : lambang
# lap : lap
# lep : lep
# sperti : sperti
# tahunan : tahun
# seperrti : seperrti
# layanan : layan
# maaf : maaf
# perbaiki : baik
# trm : trm
# ngak : ngak
# sistem : sistem
# kagak : kagak
# kesedot : sedot
# anti : anti
# sedot : sedot
# sedotan : sedot
# akal : akal
# akalan : akal
# korupsi : korupsi
# mah : mah
# emang : emang
# beda : beda
# aplks : aplks
# skarang : skarang
# skb : skb
# dapet : dapet
# gila : gila
# vendor : vendor
# urus : urus
# sesunnguhnya : sesunnguhnya
# maha : maha
# wifi : wifi
# ala : ala
# hoax : hoax
# ponakan : ponakan
# sekolahnya : sekolah
# dibrebes : dibrebes
# kaya : kaya
# siput : siput
# betulkan : betul
# wis : wis
# malas : malas
# mahalnya : mahal
# nyekik : nyekik
# leher : leher
# tutup : tutup
# negara : negara
# cri : cri
# banyaknya : banyak
# asyarakat : asyarakat
# lgi : lgi
# terpuruk : puruk
# bangsa : bangsa
# malh : malh
# ngasih : ngasih
# weh : weh
# berantakan : beranta
# nnton : nnton
# video : video
# plis : plis
# ngelag : ngelag
# saran : saran
# komplen : komplen
# neh : neh
# telkompret : telkompret
# pasukan : pasu
# dislike : dislike
# tambahin : tambahin
# woi : woi
# aanjing : aanjing
# pandemi : pandemi
# gantungin : gantungin
# nyawa : nyawa
# bayar : bayar
# mengerti : erti
# password : password
# kasihan : kasihan
# emak : emak
# tetangga : tetangga
# aman : aman
# the : the
# good : good
# server : server
# terminale : male
# tulisannya : tulis
# sibuk : sibuk
# gitu : gitu
# kmn : kmn
# awas : awas
# menunggu : tunggu
# notif : notif
# dpet : dpet
# telkomser : telkomser
# chenk : chenk
# harian : hari
# dha : dha
# error : error
# stop : stop
# kasar : kasar
# kepadamu : kepada
# samasekali : samasekali
# bergerak : gerak
# kah : kah
# aneh : aneh
# meras : ras
# berubah : ubah
# keong : keong
# nomer : nomer
# mati : mati
# knpa : knpa
# hrs : hrs
# beralih : alih
# halo : halo
# cuk : cuk
# merugikan : rugi
# pan : pan
# tek : tek
# sorry : sorry
# minggir : minggir
# cacat : cacat
# google : google
# telkomnyet : telkomnyet
# dinyatakan : nyata
# iklanmu : iklan
# mbelgedes : mbelgedes
# sesuai : sesuai
# realita : realita
# terlancar : lancar
# taik : taik
# tsel : tsel
# ngilang : ngilang
# gratisan : gratis
# wkwkwk : wkwkwk
# rod : rod
# ujung : ujung
# kampret : kampret
# lihat : lihat
# komen : komen
# kui : kui
# tuli : tuli
# yoooo : yoooo
# palembang : palembang
# betung : betung
# sad : sad
# aowowkekeoekekkeekw : aowowkekeoekekkeekw
# akalin : akalin
# inject : inject
# dll : dll
# ngevokep : ngevokep
# ghikik : ghikik
# anjenkkkk : anjenkkkk
# bosok : bosok
# masuk : masuk
# boong : boong
# hoak : hoak
# yuk : yuk
# haluuan : haluuan
# kepencet : pencet
# sekian : sekian
# hhe : hhe
# asw : asw
# pembohong : bohong
# taeee : taeee
# huh : huh
# wkwkwkwkwwk : wkwkwkwkwwk
# diurus : urus
# hadehh : hadehh
# bayu : bayu
# anjenkkkkkk : anjenkkkkkk
# gimikkkk : gimikkkk
# ngapain : ngapain
# rajin : rajin
# berguna : guna
# ajg : ajg
# iuiuu : iuiuu
# hayo : hayo
# siah : siah
# buly : buly
# lampu : lampu
# pdahal : pdahal
# yt : yt
# buka : buka
# ngeleg : ngeleg
# iya : iya
# emg : emg
# kota : kota
# pedesaan : desa
# kecamatan : camat
# sebelah : belah
# performanya : performa
# kapok : kapok
# enak : enak
# kayak : kayak
# data : data
# ngelek : ngelek
# elek : elek
# mlempem : mlempem
# smkin : smkin
# ksni : ksni
# hbs : hbs
# telkotolodon : telkotolodon
# beranak : anak
# megalodon : megalodon
# tod : tod
# tlng : tlng
# anjg : anjg
# dibenerin : dibenerin
# dimahalin : dimahalin
# gnti : gnti
# leggggggg : leggggggg
# master : master
# legg : legg
# dedikasi : dedikasi
# anejng : anejng
# riau : riau
# bangkinang : bangkinang
# rusak : rusak
# suda : suda
# anjng : anjng
# pko : pko
# jlk : jlk
# bngtt : bngtt
# kcewa : kcewa
# benerin : benerin
# sialan : sial
# kau : kau
# bet : bet
# tunggu : tunggu
# aktifnya : aktif
# tanda : tanda
# alaahh : alaahh
# preettttt : preettttt
# huhhh : huhhh
# nihh : nihh
# jaman : jaman
# nunggu : nunggu
# terealisasi : realisasi
# secepatnyaa : secepatnyaa
# semangat : semangat
# tim : tim
# luas : luas
# indonesia : indonesia
# ekspetasi : ekspetasi
# keren : keren
# euy : euy
# smoga : smoga
# maju : maju
# masyarakat : masyarakat
# nyaman : nyaman
# internetan : internetan
# mendorong : dorong
# kegiatan : giat
# produktif : produktif
# pstinya : pstinya
# peluang : peluang
# sabar : sabar
# streaming : streaming
# bintang : bintang
# setuju : tuju
# direktur : direktur
# marketingnya : marketingnya
# sektor : sektor
# umkm : umkm
# yaa : yaa
# cepet : cepet
# ngerasain : ngerasain
# sel : sel
# bnget : bnget
# nieee : nieee
# cepat : cepat
# terlaksana : laksana
# teknologi : teknologi
# hyper : hyper
# speed : speed
# penasaran : penasaran
# boljug : boljug
# manfaat : manfaat
# pengusaha : usaha
# sngat : sngat
# semenjak : semenjak
# puas : puas
# krna : krna
# jaringannya : jaring
# ditunggu : tunggu
# letak : letak
# geografis : geografis
# mempengaruhi : pengaruh
# pegunungan : gunung
# podo : podo
# wae : wae
# biarpun : biarpun
# keknya : kek
# dikota : kota
# sebenernya : sebenernya
# cpt : cpt
# lipat : lipat
# mantap : mantap
# lacar : lacar
# pekotaan : kota
# perkuat : kuat
# donk : donk
# ujan : ujan
# ampun : ampun
# low : low
# litensy : litensy
# loading : loading
# karna : karna
# ngapa : ngapa
# admin : admin
# sebarkan : sebar
# eropa : eropa
# kesusahan : susah
# bangun : bangun
# tower : tower
# desa : desa
# ibukota : ibukota
# kabupaten : kabupaten
# kotabaru : kotabaru
# saumlaki : saumlaki
# fakfak : fakfak
# agats : agats
# morotai : morotai
# banggai : bangga
# secepatnya : cepat
# hight : hight
# speednya : speednya
# debest : debest
# woow : woow
# kpop : kpop
# pakai : pakai
# indo : indo
# nonton : nonton
# ikutan : ikut
# giveaway : giveaway
# setia : setia
# asiik : asiik
# ahhh : ahhh
# aduh : aduh
# ngk : ngk
# nungguin : nungguin
# deh : deh
# sumpah : sumpah
# kudus : kudus
# nyobain : nyobain
# pubg : pubg
# cepetan : cepetan
# pengen : ken
# dilupakan : lupa
# wuih : wuih
# lancarrr : lancarrr
# rachel : rachel
# aktris : aktris
# michelle : michelle
# yeoh : yeoh
# kak : kak
# pakeeee : pakeeee
# nol : nol
# peller : peller
# bulanan : bulan
# sinyalnya : sinyal
# dihilangkan : hilang
# cek : cek
# gakbisa : gakbisa
# bagusin : bagusin
# kualitas : kualitas
# dlu : dlu
# dasar : dasar
# terburukkkkkk : terburukkkkkk
# miskin : miskin
# giniin : giniin
# ihiiiiy : ihiiiiy
# mangat : mangat
# yok : yok
# dirasain : dirasain
# warga : warga
# ihiyyy : ihiyyy
# donlot : donlot
# darah : darah
# allah : allah
# excited : excited
# gue : gue
# kutunggu : tunggu
# high : high
# can : can
# wait : wait
# kya : kya
# gni : gni
# pelangganmu : langgan
# hilang : hilang
# support : support
# ckck : ckck
# akses : akses
# telpon : telpon
# sarang : sarang
# jngn : jngn
# ahh : ahh
# asuu : asuu
# kirik : kirik
# niat : niat
# kerja : kerja
# pagi : pagi
# trobel : trobel
# sami : sami
# malam : malam
# giveawaynya : giveawaynya
# jan : jan
# kesel : kesel
# tukang : tukang
# korup : korup
# mcam : mcam
# butut : butut
# {'smartfren': 'smartfren', 'nikmat': 'nikmat', 'sodara': 'sodara', 'kampung': 'kampung', 'manteng': 'manteng', 'lelet': 'lelet', 'kartu': 'kartu', 'telkom': 'telkom', 'smuanya': 'smuanya', 'pindah': 'pindah', 'smartfreen': 'smartfreen', '': '', 'berharap': 'harap', 'operator': 'operator', 'absen': 'absen', 'wow': 'wow', 'amazing': 'amazing', 'telkomsel': 'telkomsel', 'udara': 'udara', 'doga': 'doga', 'rejekiikwn': 'rejekiikwn', 'cell': 'cell', 'lancar': 'lancar', 'barokah': 'barokah', 'amin': 'amin', 'yarobalamin': 'yarobalamin', 'suka': 'suka', 'nge': 'nge', 'lag': 'lag', 'maknya': 'maknya', 'main': 'main', 'game': 'game', 'stress': 'stress', 'giliran': 'gilir', 'belajar': 'ajar', 'daring': 'daring', 'sinyal': 'sinyal', 'udh': 'udh', 'bagus': 'bagus', 'duluan': 'duluan', 'gua': 'gua', 'kelas': 'kelas', 'smk': 'smk', 'suruh': 'suruh', 'isi': 'isi', 'pendataan': 'data', 'kouta': 'kouta', 'gratis': 'gratis', 'kakak': 'kakak', 'kls': 'kls', 'sekolah': 'sekolah', 'promo': 'promo', 'kelain': 'lain', 'hati': 'hati', 'contoh': 'contoh', 'pulsa': 'pulsa', 'ribu': 'ribu', 'trus': 'trus', 'beli': 'beli', 'paket': 'paket', 'internet': 'internet', 'all': 'all', 'net': 'net', 'harga': 'harga', 'sisa': 'sisa', 'udah': 'udah', 'paketan': 'paket', 'dikit': 'dikit', 'tarik': 'tarik', 'kadang': 'kadang', 'pas': 'pas', 'uang': 'uang', 'tinggal': 'tinggal', 'doang': 'doang', 'hmm': 'hmm', 'knapa': 'knapa', 'ngga': 'ngga', 'combo': 'combo', 'sakti': 'sakti', 'min': 'min', 'mohon': 'mohon', 'balasan': 'balas', 'berbenah': 'benah', 'pasrah': 'pasrah', 'milikku': 'milik', 'provider': 'provider', 'pusing': 'pusing', 'kuotanya': 'kuota', 'abis': 'abis', 'thebest': 'thebest', 'zippp': 'zippp', 'muantaappp': 'muantaappp', 'barusan': 'barusan', 'simpati': 'simpati', 'down': 'down', 'kali': 'kali', 'menit': 'menit', 'bgtu': 'bgtu', 'turun': 'turun', 'bar': 'bar', 'huhu': 'huhu', 'sedih': 'sedih', 'guys': 'guys', 'kawasan': 'kawasan', 'jabodetabek': 'jabodetabek', 'iming': 'iming', 'imingnya': 'imingnya', 'mantep': 'mantep', 'tipu': 'tipu', 'menyakitkan': 'sakit', 'kawan': 'kawan', 'terbaik': 'baik', 'kuota': 'kuota', 'utama': 'utama', 'bonus': 'bonus', 'dipake': 'dipake', 'jenjang': 'jenjang', 'terbatas': 'batas', 'kasih': 'kasih', 'mending': 'mending', 'php': 'php', 'sakit': 'sakit', 'daerah': 'daerah', 'cilacap': 'cilacap', 'jawa': 'jawa', 'parah': 'parah', 'brpa': 'brpa', 'hargany': 'hargany', 'wahahahaa': 'wahahahaa', 'tekomsel': 'tekomsel', 'terburuk': 'buruk', 'koneksi': 'koneksi', 'kirim': 'kirim', 'bantuan': 'bantu', 'ngab': 'ngab', 'axis': 'axis', 'jaringan': 'jaring', 'masi': 'mas', 'stabil': 'stabil', 'wilayah': 'wilayah', 'indosat': 'indosat', 'ganti': 'ganti', 'rebahan': 'rebah', 'rumah': 'rumah', 'golongan': 'golong', 'multimedia': 'multimedia', 'makasih': 'makasih', 'please': 'please', 'diperbaiki': 'baik', 'pup': 'pup', 'nggk': 'nggk', 'ditanggal': 'tanggal', 'hidup': 'hidup', 'salam': 'salam', 'kenal': 'kenal', 'tagus': 'tagus', 'melet': 'melet', 'chanel': 'chanel', 'semoga': 'moga', 'sehat': 'sehat', 'pke': 'pke', 'hotpot': 'hotpot', 'temen': 'temen', 'efek': 'efek', 'nganggur': 'nganggur', 'krja': 'krja', 'sepuasnya': 'puas', 'merdeka': 'merdeka', 'saking': 'saking', 'lancarnya': 'lancar', 'pelajaran': 'ajar', 'kedengeran': 'kedengeran', 'nyakitin': 'nyakitin', 'orang': 'orang', 'nyimak': 'nyimak', 'asik': 'asik', 'seru': 'seru', 'ter': 'ter', 'kecewa': 'kecewa', 'berat': 'berat', 'pdhl': 'pdhl', 'kyk': 'kyk', 'skrg': 'skrg', 'angin': 'angin', 'kenceng': 'kenceng', 'internetnya': 'internetnya', 'gb': 'gb', 'rp': 'rp', 'gimana': 'gimana', 'carayah': 'carayah', 'daftar': 'daftar', 'susah': 'susah', 'ijin': 'ijin', 'mendikbud': 'mendikbud', 'aplikasi': 'aplikasi', 'parahmen': 'parahmen', 'mengeluh': 'keluh', 'pemakaian': 'pakai', 'youtube': 'youtube', 'zoom': 'zoom', 'berganti': 'ganti', 'versi': 'versi', 'sampe': 'sampe', 'sebulan': 'bulan', 'nyedot': 'nyedot', 'banget': 'banget', 'sekeluarga': 'keluarga', 'ngeluarin': 'ngeluarin', 'duit': ...
# ------------------------
# Pandas Apply:   0%|          | 0/255 [00:00<?, ?it/s]
#                                                comment  \
# 0    smartfren lebih nikmat sodara meskipun di kamp...
# 1    siapa yg berharap ada operator yg lebih baik??...
# 2                                wow amazing telkomsel
# 3                             telkomsel tetap di udara
# 4    doga rejekiikwn cell lancar dan barokah amin2y...
# ..                                                 ...
# 392                                           kesel gw
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir² ini butut. perbaiki dulu jari...
#
#                                       cleaning_comment  \
# 0    smartfren lebih nikmat sodara meskipun kampung...
# 1        siapa berharap ada operator lebih baik absen
# 2                                wow amazing telkomsel
# 3                                telkomsel tetap udara
# 4    doga rejekiikwn cell lancar dan barokah amin y...
# ..                                                 ...
# 392                                             kesel
# 393                                       tukang korup
# 394                                   sinyal mcam taik
# 395                                    chanel gak guna
# 396  telkomsel akhir ini butut perbaiki dulu jaring...
#
#                                             tokenisasi  \
# 0    [smartfren, lebih, nikmat, sodara, meskipun, k...
# 1    [siapa, berharap, ada, operator, lebih, baik, ...
# 2                            [wow, amazing, telkomsel]
# 3                            [telkomsel, tetap, udara]
# 4    [doga, rejekiikwn, cell, lancar, dan, barokah,...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                [chanel, gak, guna]
# 396  [telkomsel, akhir, ini, butut, perbaiki, dulu,...
#
#                                               stopword  \
# 0    [smartfren, nikmat, sodara, kampung, manteng, ...
# 1                        [berharap, operator, absen, ]
# 2                            [wow, amazing, telkomsel]
# 3                                   [telkomsel, udara]
# 4    [doga, rejekiikwn, cell, lancar, barokah, amin...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                           [chanel]
# 396      [telkomsel, butut, perbaiki, jaringan, promo]
#
#                                               stemming
# 0    [smartfren, nikmat, sodara, kampung, manteng, ...
# 1                           [harap, operator, absen, ]
# 2                            [wow, amazing, telkomsel]
# 3                                   [telkomsel, udara]
# 4    [doga, rejekiikwn, cell, lancar, barokah, amin...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                           [chanel]
# 396            [telkomsel, butut, baik, jaring, promo]
#
# [255 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Comments'})

# %%
Final
# Out:
#                                               Comments
# 0    [smartfren, nikmat, sodara, kampung, manteng, ...
# 1                           [harap, operator, absen, ]
# 2                            [wow, amazing, telkomsel]
# 3                                   [telkomsel, udara]
# 4    [doga, rejekiikwn, cell, lancar, barokah, amin...
# ..                                                 ...
# 392                                          [kesel, ]
# 393                                    [tukang, korup]
# 394                               [sinyal, mcam, taik]
# 395                                           [chanel]
# 396            [telkomsel, butut, baik, jaring, promo]
#
# [255 rows x 1 columns]

# %%
Final.to_excel('databersih_youtube_telkomsel_8.xlsx')
