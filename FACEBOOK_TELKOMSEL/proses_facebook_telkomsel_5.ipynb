# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Sinyal hancur lebur. Dari November lapor sampe...
# 1    Min klo ganti kartu telkomsel 3G ke 4G ga haru...
# 2    Jaringan Telkomsel jumping2 terus gk jelas pak...
# 3    Sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           Telkomsel.
# ..                                                 ...
# 441                                   Mana jaringan 5G
# 442                              Kenapa paket boros ya
# 443  Bantuan kuota kemendikbud april 2021 belum cai...
# 444                Min kok aku gak bisa pake kuota itu
# 445                                                NaN
#
# [446 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Sinyal hancur lebur. Dari November lapor sampe...
# 1    Min klo ganti kartu telkomsel 3G ke 4G ga haru...
# 2    Jaringan Telkomsel jumping2 terus gk jelas pak...
# 3    Sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           Telkomsel.
# ..                                                 ...
# 440             Telkomsel kenapa hilang jaringannya oy
# 441                                   Mana jaringan 5G
# 442                              Kenapa paket boros ya
# 443  Bantuan kuota kemendikbud april 2021 belum cai...
# 444                Min kok aku gak bisa pake kuota itu
#
# [444 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    sinyal hancur lebur. dari november lapor sampe...
# 1    min klo ganti kartu telkomsel 3g ke 4g ga haru...
# 2    jaringan telkomsel jumping2 terus gk jelas pak...
# 3    sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           telkomsel.
# ..                                                 ...
# 440             telkomsel kenapa hilang jaringannya oy
# 441                                   mana jaringan 5g
# 442                              kenapa paket boros ya
# 443  bantuan kuota kemendikbud april 2021 belum cai...
# 444                min kok aku gak bisa pake kuota itu
#
# [444 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    sinyal hancur lebur. dari november lapor sampe...
# 1    min klo ganti kartu telkomsel 3g ke 4g ga haru...
# 2    jaringan telkomsel jumping2 terus gk jelas pak...
# 3    sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           telkomsel.
# ..                                                 ...
# 440             telkomsel kenapa hilang jaringannya oy
# 441                                   mana jaringan 5g
# 442                              kenapa paket boros ya
# 443  bantuan kuota kemendikbud april 2021 belum cai...
# 444                min kok aku gak bisa pake kuota itu
#
#                                       cleaning_comment
# 0    sinyal hancur lebur dari november lapor sampe ...
# 1    min klo ganti kartu telkomsel harus grapari bi...
# 2    jaringan telkomsel jumping  terus jelas paket ...
# 3    sinyal bagian kecamatan tuh tolong baguskn lgi...
# 4                                           telkomsel
# ..                                                 ...
# 440               telkomsel kenapa hilang jaringannya
# 441                                     mana jaringan
# 442                                kenapa paket boros
# 443  bantuan kuota kemendikbud april   belum cair p...
# 444                min kok aku gak bisa pake kuota itu
#
# [444 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    sinyal hancur lebur. dari november lapor sampe...
# 1    min klo ganti kartu telkomsel 3g ke 4g ga haru...
# 2    jaringan telkomsel jumping2 terus gk jelas pak...
# 3    sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           telkomsel.
# ..                                                 ...
# 440             telkomsel kenapa hilang jaringannya oy
# 441                                   mana jaringan 5g
# 442                              kenapa paket boros ya
# 443  bantuan kuota kemendikbud april 2021 belum cai...
# 444                min kok aku gak bisa pake kuota itu
#
#                                       cleaning_comment  \
# 0    sinyal hancur lebur dari november lapor sampe ...
# 1    min klo ganti kartu telkomsel harus grapari bi...
# 2    jaringan telkomsel jumping  terus jelas paket ...
# 3    sinyal bagian kecamatan tuh tolong baguskn lgi...
# 4                                           telkomsel
# ..                                                 ...
# 440               telkomsel kenapa hilang jaringannya
# 441                                     mana jaringan
# 442                                kenapa paket boros
# 443  bantuan kuota kemendikbud april   belum cair p...
# 444                min kok aku gak bisa pake kuota itu
#
#                                             tokenisasi
# 0    [sinyal, hancur, lebur, dari, november, lapor,...
# 1    [min, klo, ganti, kartu, telkomsel, harus, gra...
# 2    [jaringan, telkomsel, jumping, terus, jelas, p...
# 3    [sinyal, bagian, kecamatan, tuh, tolong, bagus...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440         [telkomsel, kenapa, hilang, jaringannya, ]
# 441                                 [mana, jaringan, ]
# 442                           [kenapa, paket, boros, ]
# 443  [bantuan, kuota, kemendikbud, april, belum, ca...
# 444       [min, kok, aku, gak, bisa, pake, kuota, itu]
#
# [444 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    sinyal hancur lebur. dari november lapor sampe...
# 1    min klo ganti kartu telkomsel 3g ke 4g ga haru...
# 2    jaringan telkomsel jumping2 terus gk jelas pak...
# 3    sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           telkomsel.
# ..                                                 ...
# 440             telkomsel kenapa hilang jaringannya oy
# 441                                   mana jaringan 5g
# 442                              kenapa paket boros ya
# 443  bantuan kuota kemendikbud april 2021 belum cai...
# 444                min kok aku gak bisa pake kuota itu
#
#                                       cleaning_comment  \
# 0    sinyal hancur lebur dari november lapor sampe ...
# 1    min klo ganti kartu telkomsel harus grapari bi...
# 2    jaringan telkomsel jumping  terus jelas paket ...
# 3    sinyal bagian kecamatan tuh tolong baguskn lgi...
# 4                                           telkomsel
# ..                                                 ...
# 440               telkomsel kenapa hilang jaringannya
# 441                                     mana jaringan
# 442                                kenapa paket boros
# 443  bantuan kuota kemendikbud april   belum cair p...
# 444                min kok aku gak bisa pake kuota itu
#
#                                             tokenisasi  \
# 0    [sinyal, hancur, lebur, dari, november, lapor,...
# 1    [min, klo, ganti, kartu, telkomsel, harus, gra...
# 2    [jaringan, telkomsel, jumping, terus, jelas, p...
# 3    [sinyal, bagian, kecamatan, tuh, tolong, bagus...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440         [telkomsel, kenapa, hilang, jaringannya, ]
# 441                                 [mana, jaringan, ]
# 442                           [kenapa, paket, boros, ]
# 443  [bantuan, kuota, kemendikbud, april, belum, ca...
# 444       [min, kok, aku, gak, bisa, pake, kuota, itu]
#
#                                               stopword
# 0    [sinyal, hancur, lebur, november, lapor, sampe...
# 1    [min, ganti, kartu, telkomsel, grapari, trimak...
# 2    [jaringan, telkomsel, jumping, paket, mahal, m...
# 3    [sinyal, kecamatan, tolong, baguskn, lgi, kya,...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440                 [telkomsel, hilang, jaringannya, ]
# 441                                       [jaringan, ]
# 442                                   [paket, boros, ]
# 443  [bantuan, kuota, kemendikbud, april, cair, kar...
# 444                                       [min, kuota]
#
# [444 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1340
# ------------------------
# sinyal : sinyal
# hancur : hancur
# lebur : lebur
# november : november
# lapor : lapor
# sampe : sampe
# kgk : kgk
# tidurrr : tidurrr
# terosss : terosss
# min : min
# ganti : ganti
# kartu : kartu
# telkomsel : telkomsel
# grapari : grapari
# trimakasih : trimakasih
#  :
# jaringan : jaring
# jumping : jumping
# paket : paket
# mahal : mahal
# mngecewakan : mngecewakan
# kecamatan : camat
# tolong : tolong
# baguskn : baguskn
# lgi : lgi
# kya : kya
# emak : emak
# sok : sok
# sosmed : sosmed
# posting : posting
# mulu : mulu
# realitanya : realitanya
# bulshitt : bulshitt
# fuckkk : fuckkk
# daerah : daerah
# warga : warga
# jelek : jelek
# kuota : kuota
# buka : buka
# susah : susah
# banget : banget
# main : main
# game : game
# diperbaiki : baik
# gnya : gnya
# beres : beres
# wefi : wefi
# lancarr : lancarr
# krtu : krtu
# tman : tman
# tblokir : tblokir
# gimana : gimana
# carax : carax
# ksi : ksi
# bagus : bagus
# kmbali : kmbali
# hallo : hallo
# kasih : kasih
# saran : saran
# emg : emg
# fup : fup
# jam : jam
# gigabites : gigabites
# stuck : stuck
# jatah : jatah
# gb : gb
# gandakan : ganda
# periode : periode
# tunggu : tunggu
# program : program
# kenyataan : nyata
# klau : klau
# parah : parah
# bangat : bangat
# harga : harga
# data : data
# sinyalnya : sinyal
# perbatasan : batas
# aceh : aceh
# tamiang : tamiang
# kelap : kelap
# kelip : kelip
# payah : payah
# gaguna : gaguna
# bner : bner
# membanting : banting
# ngampas : ngampas
# cuk : cuk
# keluarkan : keluar
# leg : leg
# ayo : ayo
# beralih : alih
# anjjj : anjjj
# bpk : bpk
# direktur : direktur
# mohon : mohon
# tancepin : tancepin
# tower : tower
# wilayah : wilayah
# chat : chat
# veronika : veronika
# bosen : bosen
# orang : orang
# jabodetabek : jabodetabek
# tinggal : tinggal
# lemah : lemah
# ngga : ngga
# loading : loading
# hub : hub
# menghentikan : henti
# layanan : layan
# cloudmax : cloudmax
# dialnya : dialnya
# kualitas : kualitas
# knp : knp
# aplikasi : aplikasi
# lite : lite
# ampun : ampun
# benerin : benerin
# dlu : dlu
# knpa : knpa
# udah : udah
# seminggu : minggu
# gua : gua
# bertahan : tahan
# udh : udh
# emosional : emosional
# babii : babi
# jaringannya : jaring
# woy : woy
# pingin : pingin
# mimpi : mimpi
# tidur : tidur
# ngayal : ngayal
# hey : hey
# kah : kah
# sya : sya
# suport : suport
# pasang : pasang
# hadeh : hadeh
# diberesin : resin
# kebanyakn : kebanyakn
# sampah : sampah
# youtube : youtube
# muter : muter
# edgd : edgd
# komplain : komplain
# puluhan : puluh
# kali : kali
# hmpir : hmpir
# lemot : lot
# facebook : facebook
# pln : pln
# mati : mati
# ngomong : ngomong
# doang : doang
# segede : gede
# bakul : bakul
# angka : angka
# lancar : lancar
# jaya : jaya
# murah : murah
# meriah : riah
# telkomnyet : telkomnyet
# jancukk : jancukk
# tutup : tutup
# provider : provider
# burik : burik
# nyet : nyet
# kek : kek
# bangkrut : bangkrut
# ngapa : ngapa
# menunggu : tunggu
# masuk : masuk
# desa : desa
# perbaiki : baik
# wado : wado
# suka : suka
# unilimitet : unilimitet
# nerf : nerf
# pejabat : jabat
# tkp : tkp
# banten : banten
# darurat : darurat
# kayak : kayak
# tertawa : tertawa
# ditertawain : ditertawain
# postingan : postingan
# lucu : lucu
# kocak : kocak
# mumpung : mumpung
# ngakak : ngakak
# gratis : gratis
# blm : blm
# terealisasi : realisasi
# nunggu : nunggu
# thn : thn
# cikal : cikal
# benarin : benarin
# customer : customer
# sebarin : sebarin
# yutube : yutube
# ketengan : keteng
# aktifin : aktifin
# datanya : data
# stabilin : stabilin
# luasin : luasin
# beranjak : anjak
# rugiin : rugiin
# pelanggannya : langgan
# kawan : kawan
# kena : kena
# pembatasan : batas
# kecepatan : cepat
# mending : mending
# pindah : pindah
# operator : operator
# opo : opo
# woi : woi
# kota : kota
# optimalkan : optimal
# tambahan : tambah
# akselerasi : akselerasi
# pemerataan : perata
# akses : akses
# broadband : broadband
# bantu : bantu
# kode : kode
# puk : puk
# nomor : nomor
# sehat : sehat
# keong : keong
# mencret : mencret
# dpt : dpt
# signal : signal
# syukurrrr : syukurrrr
# ntar : ntar
# gila : gila
# bet : bet
# kasi : kasi
# bonus : bonus
# kejutan : kejut
# internet : internet
# semiggu : semiggu
# pelangan : pelang
# setia : setia
# ajiiiiiing : ajiiiiiing
# maaf : maaf
# bukti : bukti
# solusi : solusi
# kau : kau
# tepati : tepat
# telko : telko
# taek : taek
# bawa : bawa
# maksud : maksud
# ngasih : ngasih
# pelayanan : layan
# super : super
# taik : taik
# kecewa : kecewa
# jngan : jngan
# bnyak : bnyak
# modus : modus
# celcomnyet : celcomnyet
# jaringanya : jaringanya
# lol : lol
# hoax : hoax
# woii : woii
# gini : gin
# gunanya : guna
# parungkuda : parungkuda
# sukabumi : sukabumi
# ping : ping
# kadang : kadang
# merah : merah
# hadeuuh : hadeuuh
# berubah : ubah
# ngotak : ngotak
# buruk : buruk
# urusin : urusin
# noh : noh
# hilang : hilang
# halo : halo
# utama : utama
# kebijakan : bijak
# mengecewakan : kecewa
# member : member
# hayyyyuk : hayyyyuk
# beli : beli
# kertu : kertu
# rbu : rbu
# pagi : pagi
# kak : kak
# admin : admin
# malam : malam
# besok : besok
# youtuber : youtuber
# telekomunikasi : telekomunikasi
# penyedia : sedia
# kerjaannya : kerja
# ngeprank : ngeprank
# konsumen : konsumen
# unlimited : unlimited
# fupnya : fupnya
# diperpanjang : panjang
# aktif : aktif
# penggunaan : guna
# pulsa : pulsa
# copas : copas
# email : email
# salah : salah
# kencengin : kencengin
# speed : speed
# giveaway : giveaway
# please : please
# ngelag : ngelag
# trus : trus
# maen : maen
# malu : malu
# party : party
# nanya : nanya
# nipu : nipu
# xixixi : xixixi
# skg : skg
# bayar : bayar
# sesuai : sesuai
# byk : byk
# usaha : usaha
# bisnis : bisnis
# macet : macet
# gara : gara
# spt : spt
# namanya : nama
# palanggan : palanggan
# parahhhh : parahhhh
# goyang : goyang
# shopee : shopee
# koq : koq
# batas : batas
# pemakaian : pakai
# wajar : wajar
# gitu : gitu
# nyerah : nyerah
# deh : deh
# pakai : pakai
# twitter : twitter
# kebuka : buka
# mimin : mimin
# gabisa : gabisa
# gtu : gtu
# paketan : paket
# gegara : gegara
# keluarin : keluarin
# duit : duit
# minggu : minggu
# mengunakan : mengunakan
# begal : begal
# bisalah : bisa
# thr : thr
# combo : combo
# sakti : sakti
# dibatas : batas
# istilah : istilah
# teleponnya : telepon
# kurangin : rangin
# nggk : nggk
# aktifkan : aktif
# memenuhi : penuh
# kriteria : kriteria
# tpi : tpi
# nge : nge
# ampe : ampe
# pending : pending
# nunggui : nunggui
# ceklis : ceklis
# patut : patut
# apresiasi : apresiasi
# sinya : sinya
# kesel : kesel
# kemarin : kemarin
# sinyalnnya : sinyalnnya
# njirrr : njirrr
# apaaan : apaaan
# sesuaikan : sesuai
# turunin : turunin
# harganya : harga
# sulthan : sulthan
# dok : dok
# kenapan : kenap
# panggil : panggil
# jariang : jariang
# sebenernya : sebenernya
# kencang : kencang
# gue : gue
# lumayan : lumayan
# donk : donk
# isi : isi
# langsung : langsung
# hidupin : hidupin
# link : link
# not : not
# found : found
# cari : cari
# video : video
# candaan : canda
# ruang : ruang
# bacott : bacott
# gagal : gagal
# scream : scream
# tekomtollll : tekomtollll
# card : card
# patah : patah
# anehnya : aneh
# lamaan : lama
# dahh : dahh
# kukira : kira
# pas : pas
# habis : habis
# unlimitednya : unlimitednya
# login : login
# undang : undang
# aps : aps
# taunya : tau
# matchmaking : matchmaking
# detik : detik
# terputus : putus
# telpon : telpon
# kirim : kirim
# salam : salam
# coba : coba
# area : area
# semarang : semarang
# cape : cape
# utak : utak
# atik : atik
# lock : lock
# emosi : emosi
# unlimitedmax : unlimitedmax
# nyaman : nyaman
# maxnya : maxnya
# wkwkwk : wkwkwk
# gmna : gmna
# bos : bos
# wkwkwkwk : wkwkwkwk
# kuotanya : kuota
# dinaikin : dinaikin
# halah : halah
# ribet : ribet
# mikir : mikir
# goblk : goblk
# masak : masak
# presentasi : presentasi
# daring : daring
# murahan : murah
# congean : congean
# mentang : mentang
# laku : laku
# jelekin : jelekin
# dasar : dasar
# conge : conge
# muncul : muncul
# tsel : tsel
# aneh : aneh
# setabil : setabil
# bangke : bangke
# haram : haram
# telkampret : telkampret
# setan : setan
# bisq : bisq
# diregis : diregis
# makasih : makasih
# lose : lose
# streaknya : streaknya
# rusak : rusak
# dimusnahkan : musnah
# rb : rb
# langganan : langgan
# ringtone : ringtone
# pencapai : capai
# dear : dear
# kemari : kemari
# segitu : segitu
# promo : promo
# kyak : kyak
# nnti : nnti
# berkurang : kurang
# pelangganmu : langgan
# contoh : contoh
# terbaik : baik
# pelanggan : langgan
# penuh : penuh
# putus : putus
# max : max
# prank : prank
# melulu : melulu
# make : make
# ribu : ribu
# ancur : ancur
# uang : uang
# ampas : ampas
# hadiah : hadiah
# gasah : gasah
# ngebacot : ngebacot
# jual : jual
# ayam : ayam
# geprek : geprek
# report : report
# nmor : nmor
# menelfon : menelfon
# kabur : kabur
# paketnya : paket
# nii : nii
# tolol : tolol
# lemotttt : lemotttt
# cok : cok
# telkom : telkom
# ulimited : ulimited
# dimana : mana
# cooook : cooook
# judul : judul
# anying : anying
# woiii : woiii
# assalamualaikum : assalamualaikum
# voucher : voucher
# cek : cek
# emang : emang
# pliss : pliss
# bili : bili
# membeli : beli
# mencukupi : cukup
# doank : doank
# aslinya : asli
# mah : mah
# ush : ush
# embel : embel
# niatnya : niat
# sekedar : dar
# nama : nama
# arti : arti
# bata : bata
# tolonglah : tolong
# unli : unli
# napa : napa
# abis : abis
# maxgame : maxgame
# puf : puf
# kb : kb
# pemberitahuan : pemberitahuan
# masuknya : masuk
# nomer : nomer
# gnti : gnti
# bro : bro
# selamat : selamat
# kirain : kirain
# skrg : skrg
# gaanggu : gaanggu
# jaminan : jamin
# ngontol : ngontol
# kampung : kampung
# kepuh : kepuh
# sindang : sindang
# heula : heula
# pabuaran : pabuaran
# serang : serang
# ngutang : ngutang
# kesini : kesini
# baguss : baguss
# ancuurr : ancuurr
# sebulan : bulan
# perbaikan : baik
# ngedrop : ngedrop
# mind : mind
# ribuan : ribu
# ngg : ngg
# snape : snape
# lmot : lmot
# luuu : luuu
# iya : iya
# gada : gada
# angin : angin
# hujan : hujan
# ilang : ilang
# produk : produk
# kembaliin : kembaliin
# produknya : produk
# jga : jga
# stabil : stabil
# selesai : selesai
# nonton : nonton
# yutub : yutub
# buffering : buffering
# tidk : tidk
# trsedia : trsedia
# denger : denger
# bocor : bocor
# gmn : gmn
# pengguna : guna
# tasik : tasik
# malaya : malaya
# jawa : jawa
# barat : barat
# kemaren : kemaren
# enak : enak
# bebas : bebas
# mode : mode
# sayang : sayang
# apk : apk
# mytelkomsel : mytelkomsel
# kbps : kbps
# apanya : apa
# mentok : mentok
# bay : bay
# males : males
# deskripsi : deskripsi
# bantuannya : bantu
# weh : weh
# sadar : sadar
# jdi : jdi
# prsaan : prsaan
# msih : msih
# balikin : balikin
# hemat : hemat
# wkwkkw : wkwkkw
# gangguan : ganggu
# sore : sore
# petir : petir
# jakarta : jakarta
# selatan : selatan
# tiktok : tiktok
# tik : tik
# tok : tok
# serius : serius
# kepotong : potong
# terossss : terossss
# event : event
# dibanyakin : dibanyakin
# diurusin : diurusin
# jaringn : jaringn
# info : info
# halmahera : halmahera
# kemajuan : maju
# menurunnya : turun
# listrik : listrik
# padam : padam
# kabel : kabel
# penghubung : hubung
# laut : laut
# blom : blom
# gban : gban
# ngegame : ngegame
# sungguh : sungguh
# menbagongkan : menbagongkan
# mudah : mudah
# nambah : nambah
# disaat : saat
# migrasi : migrasi
# hijau : hijau
# biru : biru
# kuning : kuning
# tetep : tetep
# orangnya : orang
# sabar : sabar
# padah : padah
# subuh : subuh
# lancarnya : lancar
# unreg : unreg
# sim : sim
# kartunya : kartu
# masanya : masa
# nonaktifkan : nonaktif
# kouta : kouta
# gamesmax : gamesmax
# bapuk : bapuk
# bertahun : tahun
# simpati : simpati
# keluhan : keluh
# dibales : dibales
# nyambung : nyambung
# bang : bang
# uda : uda
# lemotnya : lot
# tuntut : tuntut
# siregar : siregar
# kbocoran : kbocoran
# pribadinya : pribadi
# setingkat : tingkat
# cleaning : cleaning
# service : service
# mmbobol : mmbobol
# pribadi : pribadi
# koneksinya : koneksi
# war : war
# anjlok : anjlok
# puas : puas
# bales : bales
# bot : bot
# bukang : bukang
# mmg : mmg
# mcm : mcm
# kntol : kntol
# jringan : jringan
# klian : klian
# plis : plis
# admind : admind
# membaca : baca
# khusus : khusus
# rating : rating
# turun : turun
# kebanyakan : banyak
# saranin : saranin
# ngilangin : ngilangin
# stres : stres
# berbulan : bulan
# penjelasan : jelas
# memuaskan : muas
# disuruh : suruh
# refresh : refresh
# manual : manual
# otomatis : otomatis
# veronica : veronica
# telp : telp
# mengulang : ulang
# kutulis : tulis
# ditambah : tambah
# menikmati : nikmat
# bersyukur : syukur
# bola : bola
# maxstream : maxstream
# konsumsi : konsumsi
# dawn : dawn
# tumbang : tumbang
# miri : miri
# daah : daah
# apapun : apa
# kuncinya : kunci
# lagu : lagu
# ditemukan : temu
# smaa : smaa
# skli : skli
# pdhl : pdhl
# bnyk : bnyk
# jaringanan : jaringanan
# konfirmasi : konfirmasi
# keluh : keluh
# kesah : kesah
# apalgi : apalgi
# pedesaan : desa
# perhari : hari
# kaya : kaya
# dipake : dipake
# apus : apus
# ngisi : ngisi
# dikondisikan : kondisi
# down : down
# kalah : kalah
# ama : ama
# jadiin : jadiin
# kps : kps
# hadehhh : hadehhh
# ngerubah : ngerubah
# mayan : mayan
# jalan : jalan
# hapus : hapus
# interet : interet
# normal : normal
# iseng : iseng
# nyoba : nyoba
# fupan : fupan
# utamanya : utama
# liat : liat
# tri : tri
# njir : njir
# asik : asik
# penyesuaian : sesuai
# karna : karna
# kenceng : kenceng
# fix : fix
# ripuh : ripuh
# sebener : sebener
# namh : namh
# gegentotan : gegentotan
# marahal : marahal
# siti : siti
# checkout : checkout
# error : error
# time : time
# out : out
# sebelah : belah
# terjelek : jelek
# abad : abad
# bntuk : bntuk
# siput : siput
# jalannya : jalan
# miris : miris
# serasa : serasa
# etc : etc
# motong : motong
# quota : quota
# multimedia : multimedia
# ngurusin : ngurusin
# murahin : murahin
# ngelawak : ngelawak
# nantang : nantang
# kerja : kerja
# kelarin : kelarin
# potong : potong
# mikro : mikro
# chipnya : chipnya
# ebuset : ebuset
# belaga : belaga
# paipji : paipji
# ngeluh : ngeluh
# kuantitas : kuantitas
# sebanding : banding
# jaringa : jaringa
# bagusin : bagusin
# tod : tod
# bln : bln
# lambat : lambat
# slsai : slsai
# pengen : ken
# boros : boros
# full : full
# urusan : urus
# kerjaan : kerja
# nggak : nggak
# ajja : ajja
# pengaduan : adu
# kemana : mana
# diganti : ganti
# bener : bener
# kualitasnya : kualitas
# sikuning : sikuning
# bonusnya : bonus
# takut : takut
# pagar : pagar
# alam : alam
# satelit : satelit
# dipakai : pakai
# rame : rame
# telkomtol : telkomtol
# ngelah : ngelah
# kntl : kntl
# jarang : jarang
# dapet : dapet
# kestabilan : stabil
# kongguan : kongguan
# rengginang : rengginang
# permisi : permisi
# tawaran : tawar
# ceria : ceria
# lag : lag
# dugaan : duga
# bingung : bingung
# masi : mas
# dicek : cek
# digunain : digunain
# kagak : kagak
# edge : edge
# paketny : paketny
# telek : telek
# ajj : ajj
# berkembang : kembang
# problem : problem
# pasty : pasty
# banxak : banxak
# nxanjung : nxanjung
# ngntd : ngntd
# vpn : vpn
# sertakan : serta
# kebobrokan : bobrok
# terpaksa : paksa
# hiburan : hibur
# harapan : harap
# buset : buset
# ms : ms
# leb : leb
# jawabannya : jawab
# benahi : benah
# lebaran : lebaran
# akun : akun
# wishnutama : wishnutama
# yuk : yuk
# gaes : gaes
# memiliki : milik
# fair : fair
# usage : usage
# policy : policy
# penerapan : terap
# mencegah : cegah
# aktivitas : aktivitas
# penyalahgunaan : penyalahgunaan
# kuo : kuo
# sumpah : sumpah
# pilih : pilih
# diteman : tem
# unlimax : unlimax
# berlangganan : langgan
# jahatnya : jahat
# robotnya : robot
# kase : kase
# tersedia : sedia
# pilihannya : pilih
# akui : aku
# dicintai : cinta
# cantik : cantik
# haii : hai
# minnn : minnn
# kann : kann
# belinya : beli
# diluar : luar
# disana : sana
# nahh : nahh
# pulang : pulang
# internetnya : internetnya
# taeekk : taeekk
# jengkel : jengkel
# ksni : ksni
# taeek : taeek
# hrg : hrg
# mkin : mkin
# nol : nol
# bilangnya : bilang
# msh : msh
# dibatesi : dibatesi
# taeeeekkkk : taeeeekkkk
# lgsg : lgsg
# applikasi : applikasi
# toko : toko
# jujur : jujur
# band : band
# draja : draja
# unlim : unlim
# with : with
# stlh : stlh
# giganya : giganya
# kcptn : kcptn
# diturunin : diturunin
# giga : giga
# story : story
# mengaktifkan : aktif
# mengeluh : keluh
# tmm : tmm
# ngawur : ngawur
# online : online
# sisa : sisa
# kebayang : bayang
# lagnya : lagnya
# masukin : masukin
# vochernya : vochernya
# tulisannya : tulis
# sibuk : sibuk
# engkau : engkau
# nawarin : nawarin
# ujung : ujung
# batasi : batas
# rill : rill
# pilihan : pilih
# menarik : tarik
# setidak : tidak
# pungging : pungging
# kabupaten : kabupaten
# mojokerto : mojokerto
# timur : timur
# orbit : orbit
# surprice : surprice
# deal : deal
# hai : hai
# diulang : ulang
# reconnect : reconnect
# didaer : didaer
# tembus : tembus
# ngadat : ngadat
# menandakan : tanda
# indoesia : indoesia
# miskin : miskin
# yaaa : yaaa
# sperti : sperti
# tekomsel : tekomsel
# satunya : satu
# yaa : yaa
# elah : elah
# ajah : ajah
# jumat : jumat
# berkah : berkah
# ramdan : ramdan
# madu : madu
# dicampur : campur
# gula : gula
# ditamba : ditamba
# susu : susu
# aduh : aduh
# manisnya : manis
# balby : balby
# yach : yach
# hayo : hayo
# dicomment : dicomment
# pemasukan : pasu
# dengarin : dengarin
# music : music
# trobel : trobel
# teman : teman
# cepat : cepat
# suuu : suuu
# kembalikan : kembali
# gede : gede
# bobrok : bobrok
# dibawah : bawah
# protes : protes
# youtubnya : youtubnya
# didemo : demo
# ratusan : ratus
# pembeli : beli
# jualan : jual
# perdana : perdana
# pkai : pkai
# dibatasi : batas
# bkn : bkn
# klik : klik
# bait : bait
# operatot : operatot
# sistem : sistem
# perdagangan : dagang
# im : im
# takalar : takalar
# sulawesi : sulawesi
# ultah : ultah
# iternet : iternet
# cmn : cmn
# browsing : browsing
# msti : msti
# loding : loding
# jaring : jaring
# jadul : jadul
# gimna : gimna
# sayangnya : sayang
# adaaaaaaaa : adaaaaaaaa
# rek : rek
# endah : endah
# moal : moal
# cnh : cnh
# iye : iye
# bngst : bngst
# rakus : rakus
# serakah : serakah
# kenal : kenal
# kenyang : kenyang
# persis : persis
# sifat : sifat
# kera : kera
# premium : premium
# apps : apps
# konyol : konyol
# mstelkomsel : mstelkomsel
# boss : boss
# buly : buly
# tokemsel : tokemsel
# normalkan : normal
# poin : poin
# tekumpul : tekumpul
# berpuluhan : puluh
# klafikasi : klafikasi
# off : off
# heee : heee
# bandwidth : bandwidth
# upload : upload
# download : download
# rendah : rendah
# cover : cover
# beban : beban
# suprise : suprise
# hara : hara
# pebih : pebih
# dikit : dikit
# kga : kga
# bnr : bnr
# eror : eror
# emng : emng
# faedah : faedah
# cuba : cuba
# gertisin : gertisin
# nikmati : nikmat
# faedahnya : faedah
# kuita : kuita
# bohong : bohong
# belaka : belaka
# kecuali : kecuali
# memanjakan : manja
# percaya : percaya
# iklan : iklan
# realita : realita
# mahalan : mahal
# sia : sia
# lemoot : lemoot
# oppo : oppo
# ruag : ruag
# omdo : omdo
# najis : najis
# korupsi : korupsi
# jembod : jembod
# raimu : rai
# aky : aky
# streak : streak
# asuuu : asuuu
# celeng : celeng
# cuki : cuki
# kpan : kpan
# bla : bla
# klaim : klaim
# merayakan : raya
# unfaedah : unfaedah
# tersedot : sedot
# ngatasinya : ngatasinya
# jan : jan
# terpercaya : percaya
# bagusan : bagus
# wify : wify
# yoi : yoi
# ulang : ulang
# pala : pala
# bejad : bejad
# membagongkan : bagong
# promonya : promonya
# berguna : guna
# dikuasai : asai
# kadal : kadal
# gurun : gurun
# arab : arab
# top : top
# diamond : diamond
# anjay : anjay
# bacot : bacot
# giliran : gilir
# alasannya : alas
# anak : anak
# kemendikbud : kemendikbud
# sumatra : sumatra
# prabumulih : prabumulih
# utara : utara
# belajar : ajar
# sial : sial
# untung : untung
# buntung : buntung
# prov : prov
# kalsel : kalsel
# kbp : kbp
# kec : kec
# kelp : kelp
# terjngkau : terjngkau
# kelncaran : kelncaran
# jringn : jringn
# sprti : sprti
# ksian : ksi
# siruh : siruh
# bljr : bljr
# skolah : skolah
# sdkn : sdkn
# bgi : bgi
# mreka : mreka
# buktinya : bukti
# perkembangan : kembang
# kabar : kabar
# tindakan : tindak
# ngejar : ngejar
# pendapat : dapat
# dri : dri
# ngk : ngk
# belik : belik
# hotspot : hotspot
# wifi : wifi
# diamon : diamon
# free : free
# fire : fire
# daftar : daftar
# kenepa : kenepa
# besuk : besuk
# terakir : terakir
# jelasin : jelasin
# telkomselnya : telkomselnya
# planet : planet
# mars : mars
# menyelesaikan : selesai
# larinya : lari
# inbok : inbok
# robot : robot
# kitanya : kita
# tasikmalaya : tasikmalaya
# sukalaksana : sukalaksana
# bungursari : bungursari
# intrrnetnya : intrrnetnya
# hei : hei
# serba : serba
# digital : digital
# mlah : mlah
# heiii : heiii
# komen : komen
# batalkan : batal
# bandar : bandar
# lampung : lampung
# teluk : teluk
# betung : betung
# ikan : ikan
# kiter : kiter
# pngaturan : pngaturan
# ttp : ttp
# akibat : akibat
# tugas : tugas
# kuliah : kuliah
# tertinggal : tinggal
# nominal : nominal
# dape : dape
# skrng : skrng
# diklaim : klaim
# mas : mas
# waras : waras
# ngobrol : ngobrol
# lokal : lokal
# pungsi : pungsi
# amatir : amatir
# gratisan : gratis
# ngak : ngak
# alasan : alas
# mengisi : isi
# vouher : vouher
# pemberitahuannya : pemberitahuannya
# sekolah : sekolah
# knapa : knapa
# trs : trs
# tdi : tdi
# siang : siang
# gugel : gugel
# and : and
# gim : gim
# bisanya : bisa
# komo : komo
# pelosok : pelosok
# mereun : mereun
# mandirancan : mandirancan
# kuningan : kuningan
# rp : rp
# whatsap : whatsap
# nelpon : nelpon
# berhentikan : henti
# berhenti : henti
# seringkali : seringkali
# jaringanny : jaringanny
# cuman : cuman
# kemdikbud : kemdikbud
# ngasilin : ngasilin
# kyk : kyk
# tahi : tahi
# tny : tny
# brhenti : brhenti
# brlangganan : brlangganan
# pket : pket
# bgmn : bgmn
# cranya : cranya
# hadir : hadir
# maksut : maksut
# sukses : sukses
# smpe : smpe
# josss : josss
# kotos : kotos
# bngt : bngt
# tahap : tahap
# sblumnya : sblumnya
# smua : smua
# skrang : skrang
# sparuh : sparuh
# mausk : mausk
# palembang : palembang
# ngerjain : ngerjain
# jatibarang : jatibarang
# indramayu : indramayu
# bantuan : bantu
# kemendikbudnya : kemendikbudnya
# lengkap : lengkap
# kekurangannya : kurang
# perasnya : peras
# membara : bara
# pemake : pemake
# pemerasan : peras
# ajing : ajing
# lebak : lebak
# banjarsari : banjarsari
# kawasan : kawasan
# garut : garut
# skitar : skitar
# labil : labil
# kpn : kpn
# mengandalkan : andal
# kuat : kuat
# kelancaran : lancar
# enek : enek
# solusinya : solusi
# blokir : blokir
# knph : knph
# semia : semia
# terparah : parah
# beda : beda
# update : update
# gpor : gpor
# glte : glte
# isiin : isiin
# koneksi : koneksi
# semenjak : semenjak
# astaga : astaga
# ampung : ampung
# terbatas : batas
# batasin : batasin
# youtub : youtub
# google : google
# nglag : nglag
# hago : hago
# zoom : zoom
# apasssi : apasssi
# leeemooott : leeemooott
# petanahan : tanah
# kebumen : kebumen
# sedikitpun : sedikit
# rajin : rajin
# didaerah : daerah
# pdahal : pdahal
# cpet : cpet
# paker : paker
# ditagih : tagih
# atuh : atuh
# lwat : lwat
# internt : internt
# pass : pass
# nda : nda
# internetan : internetan
# kesemua : semua
# cba : cba
# sni : sni
# pengisian : isi
# nyesel : nyesel
# april : april
# cair : cair
# {'sinyal': 'sinyal', 'hancur': 'hancur', 'lebur': 'lebur', 'november': 'november', 'lapor': 'lapor', 'sampe': 'sampe', 'kgk': 'kgk', 'tidurrr': 'tidurrr', 'terosss': 'terosss', 'min': 'min', 'ganti': 'ganti', 'kartu': 'kartu', 'telkomsel': 'telkomsel', 'grapari': 'grapari', 'trimakasih': 'trimakasih', '': '', 'jaringan': 'jaring', 'jumping': 'jumping', 'paket': 'paket', 'mahal': 'mahal', 'mngecewakan': 'mngecewakan', 'kecamatan': 'camat', 'tolong': 'tolong', 'baguskn': 'baguskn', 'lgi': 'lgi', 'kya': 'kya', 'emak': 'emak', 'sok': 'sok', 'sosmed': 'sosmed', 'posting': 'posting', 'mulu': 'mulu', 'realitanya': 'realitanya', 'bulshitt': 'bulshitt', 'fuckkk': 'fuckkk', 'daerah': 'daerah', 'warga': 'warga', 'jelek': 'jelek', 'kuota': 'kuota', 'buka': 'buka', 'susah': 'susah', 'banget': 'banget', 'main': 'main', 'game': 'game', 'diperbaiki': 'baik', 'gnya': 'gnya', 'beres': 'beres', 'wefi': 'wefi', 'lancarr': 'lancarr', 'krtu': 'krtu', 'tman': 'tman', 'tblokir': 'tblokir', 'gimana': 'gimana', 'carax': 'carax', 'ksi': 'ksi', 'bagus': 'bagus', 'kmbali': 'kmbali', 'hallo': 'hallo', 'kasih': 'kasih', 'saran': 'saran', 'emg': 'emg', 'fup': 'fup', 'jam': 'jam', 'gigabites': 'gigabites', 'stuck': 'stuck', 'jatah': 'jatah', 'gb': 'gb', 'gandakan': 'ganda', 'periode': 'periode', 'tunggu': 'tunggu', 'program': 'program', 'kenyataan': 'nyata', 'klau': 'klau', 'parah': 'parah', 'bangat': 'bangat', 'harga': 'harga', 'data': 'data', 'sinyalnya': 'sinyal', 'perbatasan': 'batas', 'aceh': 'aceh', 'tamiang': 'tamiang', 'kelap': 'kelap', 'kelip': 'kelip', 'payah': 'payah', 'gaguna': 'gaguna', 'bner': 'bner', 'membanting': 'banting', 'ngampas': 'ngampas', 'cuk': 'cuk', 'keluarkan': 'keluar', 'leg': 'leg', 'ayo': 'ayo', 'beralih': 'alih', 'anjjj': 'anjjj', 'bpk': 'bpk', 'direktur': 'direktur', 'mohon': 'mohon', 'tancepin': 'tancepin', 'tower': 'tower', 'wilayah': 'wilayah', 'chat': 'chat', 'veronika': 'veronika', 'bosen': 'bosen', 'orang': 'orang', 'jabodetabek': 'jabodetabek', 'tinggal': 'tinggal', 'lemah': 'lemah', 'ngga': 'ngga', 'loading': 'loading', 'hub': 'hub', 'menghentikan': 'henti', 'layanan': 'layan', 'cloudmax': 'cloudmax', 'dialnya': 'dialnya', 'kualitas': 'kualitas', 'knp': 'knp', 'aplikasi': 'aplikasi', 'lite': 'lite', 'ampun': 'ampun', 'benerin': 'benerin', 'dlu': 'dlu', 'knpa': 'knpa', 'udah': 'udah', 'seminggu': 'minggu', 'gua': 'gua', 'bertahan': 'tahan', 'udh': 'udh', 'emosional': 'emosional', 'babii': 'babi', 'jaringannya': 'jaring', 'woy': 'woy', 'pingin': 'pingin', 'mimpi': 'mimpi', 'tidur': 'tidur', 'ngayal': 'ngayal', 'hey': 'hey', 'kah': 'kah', 'sya': 'sya', 'suport': 'suport', 'pasang': 'pasang', 'hadeh': 'hadeh', 'diberesin': 'resin', 'kebanyakn': 'kebanyakn', 'sampah': 'sampah', 'youtube': 'youtube', 'muter': 'muter', 'edgd': 'edgd', 'komplain': 'komplain', 'puluhan': 'puluh', 'kali': 'kali', 'hmpir': 'hmpir', 'lemot': 'lot', 'facebook': 'facebook', 'pln': 'pln', 'mati': 'mati', 'ngomong': 'ngomong', 'doang': 'doang', 'segede': 'gede', 'bakul': 'bakul', 'angka': 'angka', 'lancar': 'lancar', 'jaya': 'jaya', 'murah': 'murah', 'meriah': 'riah', 'telkomnyet': 'telkomnyet', 'jancukk': 'jancukk', 'tutup': 'tutup', 'provider': 'provider', 'burik': 'burik', 'nyet': 'nyet', 'kek': 'kek', 'bangkrut': 'bangkrut', 'ngapa': 'ngapa', 'menunggu': 'tunggu', 'masuk': 'masuk', 'desa': 'desa', 'perbaiki': 'baik', 'wado': 'wado', 'suka': 'suka', 'unilimitet': 'unilimitet', 'nerf': 'nerf', 'pejabat': 'jabat', 'tkp': 'tkp', 'banten': 'banten', 'darurat': 'darurat', 'kayak': 'kayak', 'tertawa': 'tertawa', 'ditertawain': 'ditertawain', 'postingan': 'postingan', 'lucu': 'lucu', 'kocak': 'kocak', 'mumpung': 'mumpung', 'ngakak': 'ngakak', 'gratis': 'gratis', 'blm': 'blm', 'terealisasi': 'realisasi', 'nunggu': 'nunggu', 'thn': 'thn', 'cikal': 'cikal', 'benarin': 'benarin', 'customer': 'customer', 'sebarin': 'sebarin', 'yutube': 'yutube', 'ketengan': 'keteng', 'aktifin': 'aktifin', 'datanya': 'data', 'stabilin': 'stabilin', 'luasin': 'luasin', 'beranjak' ...
# ------------------------
# Pandas Apply:   0%|          | 0/444 [00:00<?, ?it/s]
#                                                comment  \
# 0    sinyal hancur lebur. dari november lapor sampe...
# 1    min klo ganti kartu telkomsel 3g ke 4g ga haru...
# 2    jaringan telkomsel jumping2 terus gk jelas pak...
# 3    sinyal kw bagian kecamatan tuh tolong lh di ba...
# 4                                           telkomsel.
# ..                                                 ...
# 440             telkomsel kenapa hilang jaringannya oy
# 441                                   mana jaringan 5g
# 442                              kenapa paket boros ya
# 443  bantuan kuota kemendikbud april 2021 belum cai...
# 444                min kok aku gak bisa pake kuota itu
#
#                                       cleaning_comment  \
# 0    sinyal hancur lebur dari november lapor sampe ...
# 1    min klo ganti kartu telkomsel harus grapari bi...
# 2    jaringan telkomsel jumping  terus jelas paket ...
# 3    sinyal bagian kecamatan tuh tolong baguskn lgi...
# 4                                           telkomsel
# ..                                                 ...
# 440               telkomsel kenapa hilang jaringannya
# 441                                     mana jaringan
# 442                                kenapa paket boros
# 443  bantuan kuota kemendikbud april   belum cair p...
# 444                min kok aku gak bisa pake kuota itu
#
#                                             tokenisasi  \
# 0    [sinyal, hancur, lebur, dari, november, lapor,...
# 1    [min, klo, ganti, kartu, telkomsel, harus, gra...
# 2    [jaringan, telkomsel, jumping, terus, jelas, p...
# 3    [sinyal, bagian, kecamatan, tuh, tolong, bagus...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440         [telkomsel, kenapa, hilang, jaringannya, ]
# 441                                 [mana, jaringan, ]
# 442                           [kenapa, paket, boros, ]
# 443  [bantuan, kuota, kemendikbud, april, belum, ca...
# 444       [min, kok, aku, gak, bisa, pake, kuota, itu]
#
#                                               stopword  \
# 0    [sinyal, hancur, lebur, november, lapor, sampe...
# 1    [min, ganti, kartu, telkomsel, grapari, trimak...
# 2    [jaringan, telkomsel, jumping, paket, mahal, m...
# 3    [sinyal, kecamatan, tolong, baguskn, lgi, kya,...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440                 [telkomsel, hilang, jaringannya, ]
# 441                                       [jaringan, ]
# 442                                   [paket, boros, ]
# 443  [bantuan, kuota, kemendikbud, april, cair, kar...
# 444                                       [min, kuota]
#
#                                               stemming
# 0    [sinyal, hancur, lebur, november, lapor, sampe...
# 1    [min, ganti, kartu, telkomsel, grapari, trimak...
# 2    [jaring, telkomsel, jumping, paket, mahal, mng...
# 3    [sinyal, camat, tolong, baguskn, lgi, kya, ema...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440                      [telkomsel, hilang, jaring, ]
# 441                                         [jaring, ]
# 442                                   [paket, boros, ]
# 443  [bantu, kuota, kemendikbud, april, cair, kartu...
# 444                                       [min, kuota]
#
# [444 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [sinyal, hancur, lebur, november, lapor, sampe...
# 1    [min, ganti, kartu, telkomsel, grapari, trimak...
# 2    [jaring, telkomsel, jumping, paket, mahal, mng...
# 3    [sinyal, camat, tolong, baguskn, lgi, kya, ema...
# 4                                        [telkomsel, ]
# ..                                                 ...
# 440                      [telkomsel, hilang, jaring, ]
# 441                                         [jaring, ]
# 442                                   [paket, boros, ]
# 443  [bantu, kuota, kemendikbud, april, cair, kartu...
# 444                                       [min, kuota]
#
# [444 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_5.xlsx')
