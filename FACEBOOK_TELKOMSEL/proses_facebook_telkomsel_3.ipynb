# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                Hari ini,.. dari tadi pagi sinyal 4g+
# 2    Asisten nya robot di ciptakan buat mengatasi k...
# 3                            Lambat amat Unduhnya Ni-_
# 4    Asalam alaikum. Mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  Lama 3G Update 4G
# 353    Sinyal di Kendal super lemot. Tolong diperbaiki
# 354             Bacot 5g taik benerin dlu tu jaringan!
# 355                         Harus upgrade kartu kah...
# 356                   Sekarang aja 4G+ masih serasa 3G
#
# [357 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 5

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                Hari ini,.. dari tadi pagi sinyal 4g+
# 2    Asisten nya robot di ciptakan buat mengatasi k...
# 3                            Lambat amat Unduhnya Ni-_
# 4    Asalam alaikum. Mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  Lama 3G Update 4G
# 353    Sinyal di Kendal super lemot. Tolong diperbaiki
# 354             Bacot 5g taik benerin dlu tu jaringan!
# 355                         Harus upgrade kartu kah...
# 356                   Sekarang aja 4G+ masih serasa 3G
#
# [350 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                hari ini,.. dari tadi pagi sinyal 4g+
# 2    asisten nya robot di ciptakan buat mengatasi k...
# 3                            lambat amat unduhnya ni-_
# 4    asalam alaikum. mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  lama 3g update 4g
# 353    sinyal di kendal super lemot. tolong diperbaiki
# 354             bacot 5g taik benerin dlu tu jaringan!
# 355                         harus upgrade kartu kah...
# 356                   sekarang aja 4g+ masih serasa 3g
#
# [350 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                hari ini,.. dari tadi pagi sinyal 4g+
# 2    asisten nya robot di ciptakan buat mengatasi k...
# 3                            lambat amat unduhnya ni-_
# 4    asalam alaikum. mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  lama 3g update 4g
# 353    sinyal di kendal super lemot. tolong diperbaiki
# 354             bacot 5g taik benerin dlu tu jaringan!
# 355                         harus upgrade kartu kah...
# 356                   sekarang aja 4g+ masih serasa 3g
#
#                                       cleaning_comment
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                      hari ini dari tadi pagi sinyal
# 2    asisten nya robot ciptakan buat mengatasi kema...
# 3                                lambat amat unduhnya
# 4    asalam alaikum mohon bantuannya pak untuk tida...
# ..                                                 ...
# 352                                       lama update
# 353        sinyal kendal super lemot tolong diperbaiki
# 354                   bacot taik benerin dlu jaringan
# 355                           harus upgrade kartu kah
# 356                         sekarang aja masih serasa
#
# [350 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                hari ini,.. dari tadi pagi sinyal 4g+
# 2    asisten nya robot di ciptakan buat mengatasi k...
# 3                            lambat amat unduhnya ni-_
# 4    asalam alaikum. mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  lama 3g update 4g
# 353    sinyal di kendal super lemot. tolong diperbaiki
# 354             bacot 5g taik benerin dlu tu jaringan!
# 355                         harus upgrade kartu kah...
# 356                   sekarang aja 4g+ masih serasa 3g
#
#                                       cleaning_comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                      hari ini dari tadi pagi sinyal
# 2    asisten nya robot ciptakan buat mengatasi kema...
# 3                                lambat amat unduhnya
# 4    asalam alaikum mohon bantuannya pak untuk tida...
# ..                                                 ...
# 352                                       lama update
# 353        sinyal kendal super lemot tolong diperbaiki
# 354                   bacot taik benerin dlu jaringan
# 355                           harus upgrade kartu kah
# 356                         sekarang aja masih serasa
#
#                                             tokenisasi
# 0    [min, tolong, ditindaklanjuti, ini, akun, udh,...
# 1              [hari, ini, dari, tadi, pagi, sinyal, ]
# 2    [asisten, nya, robot, ciptakan, buat, mengatas...
# 3                           [lambat, amat, unduhnya, ]
# 4    [asalam, alaikum, mohon, bantuannya, pak, untu...
# ..                                                 ...
# 352                                   [lama, update, ]
# 353  [sinyal, kendal, super, lemot, tolong, diperba...
# 354            [bacot, taik, benerin, dlu, jaringan, ]
# 355                     [harus, upgrade, kartu, kah, ]
# 356                   [sekarang, aja, masih, serasa, ]
#
# [350 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                hari ini,.. dari tadi pagi sinyal 4g+
# 2    asisten nya robot di ciptakan buat mengatasi k...
# 3                            lambat amat unduhnya ni-_
# 4    asalam alaikum. mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  lama 3g update 4g
# 353    sinyal di kendal super lemot. tolong diperbaiki
# 354             bacot 5g taik benerin dlu tu jaringan!
# 355                         harus upgrade kartu kah...
# 356                   sekarang aja 4g+ masih serasa 3g
#
#                                       cleaning_comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                      hari ini dari tadi pagi sinyal
# 2    asisten nya robot ciptakan buat mengatasi kema...
# 3                                lambat amat unduhnya
# 4    asalam alaikum mohon bantuannya pak untuk tida...
# ..                                                 ...
# 352                                       lama update
# 353        sinyal kendal super lemot tolong diperbaiki
# 354                   bacot taik benerin dlu jaringan
# 355                           harus upgrade kartu kah
# 356                         sekarang aja masih serasa
#
#                                             tokenisasi  \
# 0    [min, tolong, ditindaklanjuti, ini, akun, udh,...
# 1              [hari, ini, dari, tadi, pagi, sinyal, ]
# 2    [asisten, nya, robot, ciptakan, buat, mengatas...
# 3                           [lambat, amat, unduhnya, ]
# 4    [asalam, alaikum, mohon, bantuannya, pak, untu...
# ..                                                 ...
# 352                                   [lama, update, ]
# 353  [sinyal, kendal, super, lemot, tolong, diperba...
# 354            [bacot, taik, benerin, dlu, jaringan, ]
# 355                     [harus, upgrade, kartu, kah, ]
# 356                   [sekarang, aja, masih, serasa, ]
#
#                                               stopword
# 0    [min, tolong, ditindaklanjuti, akun, udh, mere...
# 1                                     [pagi, sinyal, ]
# 2    [asisten, robot, ciptakan, mengatasi, kemalesa...
# 3                                 [lambat, unduhnya, ]
# 4    [asalam, alaikum, mohon, bantuannya, mengizink...
# ..                                                 ...
# 352                                         [update, ]
# 353  [sinyal, kendal, super, lemot, tolong, diperba...
# 354            [bacot, taik, benerin, dlu, jaringan, ]
# 355                            [upgrade, kartu, kah, ]
# 356                                         [serasa, ]
#
# [350 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1090
# ------------------------
# min : min
# tolong : tolong
# ditindaklanjuti : ditindaklanjuti
# akun : akun
# udh : udh
# meresahkan : resah
#  :
# pagi : pagi
# sinyal : sinyal
# asisten : asisten
# robot : robot
# ciptakan : cipta
# mengatasi : atas
# kemalesan : kemalesan
# melayani : layan
# pelanggan : langgan
# tugas : tugas
# kemajuan : maju
# jdi : jdi
# cpe : cpe
# ngelayani : ngelayani
# tinggal : tinggal
# duduk : duduk
# meja : meja
# pura : pura
# kerja : kerja
# lambat : lambat
# unduhnya : unduh
# asalam : asalam
# alaikum : alaikum
# mohon : mohon
# bantuannya : bantu
# mengizinkan : izin
# postingan : postingan
# berbau : bau
# porno : porno
# bernama : nama
# sariayu : sariayu
# fatimah : fatimah
# bandung : bandung
# tujuannya : tuju
# merusak : rusak
# nama : nama
# permohonan : mohon
# bertugas : tugas
# telko : telko
# kesampingkan : samping
# sinyalnya : sinyal
# ngelag : ngelag
# mulu : mulu
# spam : spam
# sms : sms
# promosi : promosi
# lemot : lot
# jaringannya : jaring
# perbaiki : baik
# login : login
# game : game
# youtube : youtube
# beralih : alih
# kartu : kartu
# ajalah : aja
# gmna : gmna
# mauh : mauh
# beli : beli
# kuota : kuota
# telkomsel : telkomsel
# ngk : ngk
# jualan : jual
# knpa : knpa
# vohcer : vohcer
# nda : nda
# semangat : semangat
# belajar : ajar
# gagal : gagal
# gimana : gimana
# mantap : mantap
# mksihh : mksihh
# promonyaa : promonyaa
# nyuruh : nyuruh
# malam : malam
# niat : niat
# ganguan : ganguan
# menyebalkan : sebal
# wei : wei
# nggak : nggak
# paket : paket
# mengisi : isi
# kak : kak
# kemarin : kemarin
# gangguan : ganggu
# idupin : idupin
# koneksi : koneksi
# internet : internet
# dibali : bal
# kepencet : pencet
# pinjaman : pinjam
# data : data
# batalkan : batal
# tar : tar
# ditagih : tagih
# trus : trus
# salah : salah
# slalu : slalu
# nongol : nongol
# klu : klu
# buka : buka
# pinjam : pinjam
# darirat : darirat
# bejad : bejad
# kek : kek
# isi : isi
# pls : pls
# kaaa : kaaa
# hahahahahahahahahahaha : hahahahahahahahahahaha
# ilang : ilang
# ilangan : ilangan
# selamat : selamat
# keluhan : keluh
# cepatan : cepat
# unlimited : unlimited
# max : max
# ping : ping
# bagus : bagus
# cuman : cuman
# kecepatan : cepat
# event : event
# butuh : butuh
# menit : menit
# masuk : masuk
# ngak : ngak
# berhenti : henti
# berlangganan : langgan
# skema : skema
# tarif : tarif
# regional : regional
# card : card
# pulsa : pulsa
# ambil : ambil
# pke : pke
# halo : halo
# pasca : pasca
# bayar : bayar
# bali : bal
# toret : toret
# ilmu : ilmu
# kedukunan : dukun
# jaringan : jaring
# internetx : internetx
# bgusin : bgusin
# jaringannn : jaringannn
# wifi : wifi
# minggu : minggu
# ulang : ulang
# pergi : pergi
# gereja : gereja
# februari : februari
# mb : mb
# maret : maret
# izin : izin
# terkait : kait
# informasi : informasi
# kepemilikan : milik
# nomor : nomor
# telp : telp
# provider : provider
# konyol : konyol
# udah : udah
# sebulan : bulan
# lag : lag
# parah : parah
# main : main
# parahsih : parahsih
# unlimitedmax : unlimitedmax
# pakek : pakek
# ngapain : ngapain
# kayak : kayak
# nanya : nanya
# didaerah : daerah
# kecamatan : camat
# semaka : maka
# kabupaten : kabupaten
# tanggamus : tanggamus
# provinsi : provinsi
# lampung : lampung
# susah : susah
# penuh : penuh
# akses : akses
# sulit : sulit
# pencerahanny : pencerahanny
# gamesmaxsilver : gamesmaxsilver
# link : link
# voucher : voucher
# diamond : diamond
# habis : habis
# cum : cum
# sosmed : sosmed
# doang : doang
# mahal : mahal
# gini : gin
# jaman : jaman
# gua : gua
# smp : smp
# mutar : mutar
# mitak : mitak
# ampun : ampun
# alah : alah
# mak : mak
# sedih : sedih
# ngisi : ngisi
# pakai : pakai
# ajara : ajara
# hilang : hilang
# telan : telan
# bumi : bumi
# geram : geram
# daftar : daftar
# darurat : darurat
# minimal : minimal
# kali : kali
# prank : prank
# anjer : anjer
# kendala : kendala
# iya : iya
# jelek : jelek
# banget : banget
# speed : speed
# ngeluh : ngeluh
# bbrapa : bbrapa
# coba : coba
# hubungi : hubung
# balas : balas
# bot : bot
# jawabannya : jawab
# produk : produk
# sore : sore
# kena : kena
# tipu : tipu
# layanan : layan
# aplikasi : aplikasi
# alhasil : alhasil
# terima : terima
# kasih : kasih
# telkombel : telkombel
# megecewakan : megecewakan
# woiii : woiii
# ngurusin : ngurusin
# promo : promo
# kau : kau
# kagak : kagak
# ceria : ceria
# percaya : percaya
# gesek : gesek
# kmrin : kmrin
# sibuk : sibuk
# trs : trs
# gmn : gmn
# solusinya : solusi
# ngapa : ngapa
# burik : burik
# aktifin : aktifin
# pemerintah : perintah
# dipake : dipake
# instagram : instagram
# masukkan : masuk
# kode : kode
# vocher : vocher
# tulisan : tulis
# valid : valid
# masukan : masuk
# voucer : voucer
# gimanah : gimanah
# ayolah : ayo
# diperbaiki : baik
# bosok : bosok
# banged : banged
# aaw : aaw
# heran : heran
# malem : malem
# pikir : pikir
# operator : operator
# kesini : kesini
# ancur : ancur
# giliran : gilir
# pesan : pesan
# hallo : hallo
# diperbaikin : diperbaikin
# mlm : mlm
# ampe : ampe
# skrg : skrg
# blm : blm
# muncul : muncul
# mending : mending
# pindah : pindah
# payah : payah
# kayakna : kayakna
# enak : enak
# kasian : kasi
# taunya : tau
# iklas : iklas
# wkwkw : wkwkw
# nice : nice
# gb : gb
# puas : puas
# anjeng : anjeng
# mbps : mbps
# maen : maen
# hutan : hutan
# kelakuan : laku
# mayan : mayan
# lemod : lemod
# asw : asw
# cht : cht
# kuotanya : kuota
# upload : upload
# gede : gede
# balikin : balikin
# transfer : transfer
# mengajukan : aju
# refund : refund
# kunjung : kunjung
# terselesaikan : selesai
# semen : semen
# jak : jak
# pakaki : pakaki
# lancarrr : lancarrr
# ajing : ajing
# harga : harga
# kualitas : kualitas
# abal : abal
# down : down
# kecewa : kecewa
# kenap : kenap
# neraka : neraka
# heyy : heyy
# orang : orang
# menjual : jual
# setara : tara
# heyyy : heyyy
# menutup : tutup
# telinga : telinga
# mengeluarkan : keluar
# solusi : solusi
# hey : hey
# nerakaaa : nerakaaa
# kaya : kaya
# nangis : nang
# sumpah : sumpah
# ngga : ngga
# paham : paham
# lgi : lgi
# scarlet : scarlet
# with : with
# komen : komen
# kmi : kmi
# mode : mode
# gratis : gratis
# profider : profider
# terburuk : buruk
# dunia : dunia
# pukki : pukki
# ayam : ayam
# info : info
# sim : sim
# blokir : blokir
# bangkrut : bangkrut
# bermasalah : masalah
# taik : taik
# babi : babi
# fungsi : fungsi
# poin : poin
# serius : serius
# bos : bos
# infoya : infoya
# barusan : barusan
# ehh : ehh
# menghubungkan : hubung
# cek : cek
# dial : dial
# menukarkan : tukar
# combo : combo
# sakti : sakti
# pemakaian : pakai
# th : th
# dapt : dapt
# woy : woy
# google : google
# doanggh : doanggh
# gimna : gimna
# bener : bener
# gila : gila
# tsel : tsel
# korupsi : korupsi
# gabut : gabut
# bro : bro
# sapa : sapa
# dapet : dapet
# jodoh : jodoh
# mahanya : maha
# telkomnyet : telkomnyet
# sebentar : sebentar
# murahan : murah
# cman : cman
# pantek : pantek
# rb : rb
# edge : edge
# make : make
# telkomsl : telkomsl
# puluhan : puluh
# trsiksa : trsiksa
# im : im
# josss : josss
# unreg : unreg
# bbbbbbbb : bbbbbbbb
# sinyall : sinyall
# dajjjal : dajjjal
# apn : apn
# stabil : stabil
# ganti : ganti
# mingguan : minggu
# disney : disney
# hotstar : hotstar
# tetep : tetep
# tolonglah : tolong
# ngontoi : ngontoi
# jaringannnn : jaringannnn
# boodoo : boodoo
# harian : hari
# jebakan : jebak
# gitu : gitu
# tanggal : tanggal
# jam : jam
# tahunya : tahu
# expired : expired
# tgl : tgl
# berlaku : laku
# donk : donk
# bantu : bantu
# nyaa : nyaa
# woyyyy : woyyyy
# telkom : telkom
# dancok : dancok
# dengar : dengar
# kacau : kacau
# benerin : benerin
# peler : peler
# halah : halah
# bacot : bacot
# ngntt : ngntt
# stay : stay
# kota : kota
# pelosok : pelosok
# desa : desa
# daerah : daerah
# cirebon : cirebon
# kasugengan : kasugengan
# kidul : kidul
# kec : kec
# depok : depok
# perbaikin : perbaikin
# pelayanan : layan
# kursusnya : kursus
# untung : untung
# saingan : saing
# dibandung : bandung
# cimahi : cimahi
# paketnya : paket
# unlimted : unlimted
# telpon : telpon
# ribu : ribu
# alloh : alloh
# abis : abis
# apk : apk
# mytelkomsel : mytelkomsel
# lngsung : lngsung
# gajelas : gajelas
# bnget : bnget
# kosong : kosong
# chat : chat
# veronika : veronika
# responnya : responnya
# pasir : pasir
# kuda : kuda
# cianjur : cianjur
# lalet : lalet
# karna : karna
# rakus : rakus
# ngabil : ngabil
# jok : jok
# gara : gara
# kelanjur : lanjur
# ogah : ogah
# sampah : sampah
# tri : tri
# lancar : lancar
# jaya : jaya
# bego : bego
# entut : entut
# hugan : hugan
# buruk : buruk
# user : user
# setia : setia
# maksnya : maksnya
# mentok : mentok
# latensi : latensi
# nyaman : nyaman
# online : online
# kalah : kalah
# neg : neg
# jga : jga
# tpi : tpi
# lemoott : lemoott
# biyaya : biyaya
# pokok : pokok
# sesuai : sesuai
# nak : nak
# krtu : krtu
# pusinggg : pusinggg
# bngsat : bngsat
# aktifkan : aktif
# bangai : bangai
# dasar : dasar
# anjii : anjii
# punyaku : punya
# turunin : turunin
# kemahalan : mahal
# toxic : toxic
# kesel : kesel
# qouta : qouta
# sodara : sodara
# anjinc : anjinc
# utamakan : utama
# mendengar : dengar
# streaming : streaming
# buffering : buffering
# nipu : nipu
# play : play
# mendadak : dadak
# banyangkan : banyangkan
# dlm : dlm
# sehari : hari
# kehilangan : hilang
# langsung : langsung
# jt : jt
# gdung : gdung
# pencaakarr : pencaakarr
# langit : langit
# kouta : kouta
# kemendikbud : kemendikbud
# gabisa : gabisa
# dipakai : pakai
# memburuk : buruk
# cash : cash
# ngutang : ngutang
# telkomselnya : telkomselnya
# ditempatku : tempat
# provi : provi
# medan : medan
# nyesal : nyesal
# utama : utama
# sda : sda
# video : video
# mggu : mggu
# skarang : skarang
# knp : knp
# bisanya : bisa
# kebiasaan : biasa
# saran : saran
# teman : teman
# ngalahin : ngalahin
# smartfrieds : smartfrieds
# dpt : dpt
# kuliah : kuliah
# cerdas : cerdas
# hancur : hancur
# omg : omg
# konsisten : konsisten
# paketan : paket
# hotstarnya : hotstarnya
# notifnya : notifnya
# cannot : cannot
# accessed : accessed
# nelpon : nelpon
# csnya : csnya
# diproses : proses
# melulu : melulu
# konsumen : konsumen
# aman : aman
# naruh : naruh
# off : off
# dihabisin : dihabisin
# sue : sue
# berasa : asa
# bansos : bansos
# jual : jual
# aset : aset
# asing : asing
# kmajuan : kmajuan
# dikit : dikit
# dri : dri
# nyusahin : nyusahin
# customer : customer
# internetan : internetan
# full : full
# berulang : ulang
# kalih : kalih
# pesawat : pesawat
# restart : restart
# games : games
# penipuan : tipu
# aktif : aktif
# lansung : lansung
# nyedot : nyedot
# kebiasan : bias
# berlakunya : laku
# andai : andai
# org : org
# pegang : pegang
# psti : psti
# lbh : lbh
# krj : krj
# pnting : pnting
# gaji : gaji
# miskin : miskin
# ide : ide
# sifat : sifat
# tamak : tamak
# mntapp : mntapp
# mkin : mkin
# ksini : ksini
# lemodd : lemodd
# pdhal : pdhal
# kb : kb
# aing : aing
# cape : cape
# kritik : kritik
# ngomong : ngomong
# service : service
# besok : besok
# kepotong : potong
# reguler : reguler
# buang : buang
# karto : karto
# tll : tll
# woe : woe
# soppy : soppy
# berhasil : hasil
# pembayaran : bayar
# ajig : ajig
# nomer : nomer
# puk : puk
# adaan : ada
# terkunci : kunci
# membuka : buka
# membantu : bantu
# cok : cok
# cokkkk : cokkkk
# dadaaa : dadaaa
# nekak : nekak
# gulu : gulu
# wonk : wonk
# cilik : cilik
# sbenernya : sbenernya
# mood : mood
# gmana : gmana
# intinya : inti
# alhamdullilah : alhamdullilah
# bagusss : bagusss
# kepake : kepake
# shopepay : shopepay
# dana : dana
# kepotomg : kepotomg
# pemberitahuan : pemberitahuan
# telkomsenya : telkomsenya
# diinbox : diinbox
# respomm : respomm
# byk : byk
# alsan : alsan
# pket : pket
# boborok : boborok
# berngsek : berngsek
# semoga : moga
# hacker : hacker
# mewakili : wakil
# tlh : tlh
# kecewakan : kecewa
# malu : malu
# kwalitas : kwalitas
# tamparan : tampar
# keras : keras
# no : no
# saing : saing
# ungu : ungu
# atta : atta
# in : in
# send : send
# gift : gift
# trouble : trouble
# keong : keong
# nyari : nyari
# perdana : perdana
# simpati : simpati
# dimana : mana
# atasi : atas
# kesedot : sedot
# komendikbud : komendikbud
# sayang : sayang
# rusak : rusak
# emng : emng
# nyesel : nyesel
# skrng : skrng
# padahan : padah
# telkomasu : telkomasu
# siska : siska
# pekanbaru : pekanbaru
# pemadaman : madam
# listrik : listrik
# tindak : tindak
# lanjuti : lanjut
# kuratai : rata
# pabrik : pabrik
# anjayyy : anjayyy
# pilih : pilih
# ingu : ingu
# kuning : kuning
# pas : pas
# kantong : kantong
# neko : neko
# kedepannya : depan
# menonaktifkan : nonaktif
# grapari : grapari
# jarak : jarak
# tinggalnya : tinggal
# mudah : mudah
# pergantian : ganti
# putus : putus
# persiapan : siap
# kemdikbud : kemdikbud
# asik : asik
# uda : uda
# bsa : bsa
# tae : tae
# berguna : guna
# kampungku : kampung
# senin : senin
# bekasi : bekas
# kya : kya
# kon : kon
# hapus : hapus
# ajh : ajh
# mati : mati
# bagusi : bagus
# gaguna : gaguna
# sumpaa : sumpaa
# kulihat : lihat
# bosen : bosen
# ketik : ketik
# ngeleg : ngeleg
# download : download
# ncur : ncur
# panggilan : panggil
# didata : data
# tlp : tlp
# dlu : dlu
# masak : masak
# bar : bar
# seminggu : minggu
# belar : belar
# sebenrnya : sebenrnya
# nga : nga
# kartumahal : kartumahal
# mah : mah
# buruh : buruh
# berkali : kali
# ngabisin : ngabisin
# telkomshit : telkomshit
# juuuv : juuuv
# koneksinya : koneksi
# balikan : balik
# uang : uang
# stuck : stuck
# ms : ms
# tersedot : sedot
# sisa : sisa
# tidur : tidur
# paginya : pagi
# menghubungi : hubung
# kwota : kwota
# kapok : kapok
# kecuali : kecuali
# emang : emang
# senang : senang
# bohongi : bohong
# maaf : maaf
# system : system
# gilak : gilak
# sedot : sedot
# ngerank : ngerank
# melebihi : lebih
# ngeri : ngeri
# terpake : terpake
# matikan : mati
# ajaa : ajaa
# babay : babay
# move : move
# three : three
# plnggan : plnggan
# sma : sma
# skalii : skalii
# sia : sia
# jakatra : jakatra
# gada : gada
# sinyaal : sinyaal
# respon : respon
# ksih : ksih
# gelar : gelar
# rajanya : raja
# raja : raja
# lalod : lalod
# taek : taek
# pejabat : jabat
# bobrok : bobrok
# aktifasi : aktifasi
# mentri : tri
# pendidikian : kian
# ceknya : cek
# stress : stress
# sikampret : sikampret
# mengeluh : keluh
# lari : lari
# esmosi : esmosi
# kenpa : kenpa
# synal : synal
# sya : sya
# semenjak : semenjak
# pedana : dana
# ntah : ntah
# terboxir : terboxir
# aktipkan : aktipkan
# jarang : jarang
# jringannya : jringannya
# selesai : selesai
# nekan : nekan
# gaya : gaya
# kekurangan : kurang
# gausah : gausah
# ngikut : ngikut
# beres : beres
# sampe : sampe
# sistem : sistem
# pengen : ken
# maki : maki
# entar : entar
# dipidana : pidana
# nasibbbb : nasibbbb
# nasibbb : nasibbb
# warga : warga
# merata : rata
# loading : loading
# siput : siput
# kabur : kabur
# hadehh : hadehh
# bkin : bkin
# vertigo : vertigo
# pemenang : menang
# undi : undi
# hepi : hepi
# periode : periode
# perasaan : asa
# ancurnya : ancurnya
# mqlah : mqlah
# iritan : irit
# kmn : kmn
# akal : akal
# ala : ala
# turun : turun
# boro : boro
# ngegas : ngegas
# masi : mas
# bgus : bgus
# indonesia : indonesia
# tutup : tutup
# perusahaan : usaha
# marah : marah
# kalangan : kalang
# pop : pop
# kelas : kelas
# menganggu : menganggu
# dilayar : layar
# wilayah : wilayah
# baguslah : bagus
# setabil : setabil
# speednya : speednya
# beda : beda
# lemotnya : lot
# anehnya : aneh
# siknyal : siknyal
# hri : hri
# pebaiki : baik
# kab : kab
# landak : landak
# kuala : kuala
# behe : behe
# nyayum : nyayum
# kuat : kuat
# pantes : pantes
# jaringanmu : jaring
# jaringanya : jaringanya
# sekaramg : sekaramg
# tlpn : tlpn
# cell : cell
# cepat : cepat
# pakar : pakar
# sok : sok
# vivo : vivo
# ngomongin : ngomongin
# taikomsel : taikomsel
# berangan : berangan
# angan : angan
# sawah : sawah
# tower : tower
# bongkar : bongkar
# disana : sana
# iphone : iphone
# android : android
# serasa : serasa
# nokia : nokia
# senter : senter
# cmn : cmn
# minggat : minggat
# gunung : gunung
# dihuta : dihuta
# meme : meme
# positif : positif
# siknalnya : siknalnya
# ikhlas : ikhlas
# haramkan : haram
# text : text
# ajah : ajah
# rilis : rilis
# demen : demen
# liat : liat
# bully : bully
# wkwkwk : wkwkwk
# komut : komut
# feb : feb
# gersindo : gersindo
# pasaman : pasaman
# barat : barat
# sumbar : sumbar
# dst : dst
# internetnya : internetnya
# mahalllll : mahalllll
# sidamangura : sidamangura
# kusambi : sambi
# muna : muna
# btsnya : btsnya
# sja : sja
# susahnya : susah
# mesti : mesti
# rumah : rumah
# bru : bru
# muluk : muluk
# kembang : kembang
# kempis : kempis
# kualitasnya : kualitas
# super : super
# mendingn : mendingn
# hadeh : hadeh
# kepala : kepala
# otak : otak
# tourney : tourney
# bumn : bumn
# butut : butut
# fps : fps
# apalgi : apalgi
# next : next
# pengalaman : alam
# buanget : buanget
# berbeda : beda
# wee : wee
# conegtion : conegtion
# time : time
# out : out
# memainkan : main
# free : free
# fire : fire
# sebagus : bagus
# minn : minn
# boy : boy
# tageg : tageg
# plok : plok
# paketkn : paketkn
# jaring : jaring
# semoa : moa
# konen : konen
# nyah : nyah
# baca : baca
# signal : signal
# msi : msi
# kaltim : kaltim
# kah : kah
# penyebap : bap
# prnh : prnh
# napa : napa
# loding : loding
# omongin : omongin
# secepatnya : cepat
# perbaikan : baik
# pengguna : guna
# prabayar : prabayar
# ajjh : ajjh
# busukkkk : busukkkk
# jaringamu : jaringamu
# gayaa : gayaa
# telokmsell : telokmsell
# menyepelekan : sepele
# komplain : komplain
# costumer : costumer
# bca : bca
# mbl : mbl
# alasan : alas
# menyuruh : suruh
# pembeli : beli
# tny : tny
# perihal : perihal
# pulsanya : pulsa
# surat : surat
# pernyataan : nyata
# pandemi : pandemi
# trims : trims
# bosku : bos
# banding : banding
# lte : lte
# karana : karana
# volume : volume
# dengernya : dengernya
# tes : tes
# percumah : percumah
# law : law
# lumpuh : lumpuh
# msh : msh
# awokawokawok : awokawokawok
# eleh : eleh
# cacat : cacat
# soan : soan
# siang : siang
# nyampe : nyampe
# kbps : kbps
# hai : hai
# kentut : kentut
# gapapa : gapapa
# keparat : keparat
# nunggu : nunggu
# magiclink : magiclink
# tekirim : tekirim
# kirim : kirim
# sialan : sial
# fokus : fokus
# ngilang : ngilang
# facebook : facebook
# kadang : kadang
# lokasi : lokasi
# banyumas : banyumas
# woyi : woyi
# wajan : wajan
# bts : bts
# areal : areal
# sesak : sesak
# napas : napas
# towermu : towermu
# padat : padat
# mudahan : mudah
# komenan : komenan
# positiv : positiv
# tengok : tengok
# negara : negara
# maju : maju
# koruptor : koruptor
# dihukum : hukum
# wow : wow
# ngirim : ngirim
# gambar : gambar
# tod : tod
# raimu : rai
# garis : garis
# bagusin : bagusin
# update : update
# kendal : kendal
# upgrade : upgrade
# {'min': 'min', 'tolong': 'tolong', 'ditindaklanjuti': 'ditindaklanjuti', 'akun': 'akun', 'udh': 'udh', 'meresahkan': 'resah', '': '', 'pagi': 'pagi', 'sinyal': 'sinyal', 'asisten': 'asisten', 'robot': 'robot', 'ciptakan': 'cipta', 'mengatasi': 'atas', 'kemalesan': 'kemalesan', 'melayani': 'layan', 'pelanggan': 'langgan', 'tugas': 'tugas', 'kemajuan': 'maju', 'jdi': 'jdi', 'cpe': 'cpe', 'ngelayani': 'ngelayani', 'tinggal': 'tinggal', 'duduk': 'duduk', 'meja': 'meja', 'pura': 'pura', 'kerja': 'kerja', 'lambat': 'lambat', 'unduhnya': 'unduh', 'asalam': 'asalam', 'alaikum': 'alaikum', 'mohon': 'mohon', 'bantuannya': 'bantu', 'mengizinkan': 'izin', 'postingan': 'postingan', 'berbau': 'bau', 'porno': 'porno', 'bernama': 'nama', 'sariayu': 'sariayu', 'fatimah': 'fatimah', 'bandung': 'bandung', 'tujuannya': 'tuju', 'merusak': 'rusak', 'nama': 'nama', 'permohonan': 'mohon', 'bertugas': 'tugas', 'telko': 'telko', 'kesampingkan': 'samping', 'sinyalnya': 'sinyal', 'ngelag': 'ngelag', 'mulu': 'mulu', 'spam': 'spam', 'sms': 'sms', 'promosi': 'promosi', 'lemot': 'lot', 'jaringannya': 'jaring', 'perbaiki': 'baik', 'login': 'login', 'game': 'game', 'youtube': 'youtube', 'beralih': 'alih', 'kartu': 'kartu', 'ajalah': 'aja', 'gmna': 'gmna', 'mauh': 'mauh', 'beli': 'beli', 'kuota': 'kuota', 'telkomsel': 'telkomsel', 'ngk': 'ngk', 'jualan': 'jual', 'knpa': 'knpa', 'vohcer': 'vohcer', 'nda': 'nda', 'semangat': 'semangat', 'belajar': 'ajar', 'gagal': 'gagal', 'gimana': 'gimana', 'mantap': 'mantap', 'mksihh': 'mksihh', 'promonyaa': 'promonyaa', 'nyuruh': 'nyuruh', 'malam': 'malam', 'niat': 'niat', 'ganguan': 'ganguan', 'menyebalkan': 'sebal', 'wei': 'wei', 'nggak': 'nggak', 'paket': 'paket', 'mengisi': 'isi', 'kak': 'kak', 'kemarin': 'kemarin', 'gangguan': 'ganggu', 'idupin': 'idupin', 'koneksi': 'koneksi', 'internet': 'internet', 'dibali': 'bal', 'kepencet': 'pencet', 'pinjaman': 'pinjam', 'data': 'data', 'batalkan': 'batal', 'tar': 'tar', 'ditagih': 'tagih', 'trus': 'trus', 'salah': 'salah', 'slalu': 'slalu', 'nongol': 'nongol', 'klu': 'klu', 'buka': 'buka', 'pinjam': 'pinjam', 'darirat': 'darirat', 'bejad': 'bejad', 'kek': 'kek', 'isi': 'isi', 'pls': 'pls', 'kaaa': 'kaaa', 'hahahahahahahahahahaha': 'hahahahahahahahahahaha', 'ilang': 'ilang', 'ilangan': 'ilangan', 'selamat': 'selamat', 'keluhan': 'keluh', 'cepatan': 'cepat', 'unlimited': 'unlimited', 'max': 'max', 'ping': 'ping', 'bagus': 'bagus', 'cuman': 'cuman', 'kecepatan': 'cepat', 'event': 'event', 'butuh': 'butuh', 'menit': 'menit', 'masuk': 'masuk', 'ngak': 'ngak', 'berhenti': 'henti', 'berlangganan': 'langgan', 'skema': 'skema', 'tarif': 'tarif', 'regional': 'regional', 'card': 'card', 'pulsa': 'pulsa', 'ambil': 'ambil', 'pke': 'pke', 'halo': 'halo', 'pasca': 'pasca', 'bayar': 'bayar', 'bali': 'bal', 'toret': 'toret', 'ilmu': 'ilmu', 'kedukunan': 'dukun', 'jaringan': 'jaring', 'internetx': 'internetx', 'bgusin': 'bgusin', 'jaringannn': 'jaringannn', 'wifi': 'wifi', 'minggu': 'minggu', 'ulang': 'ulang', 'pergi': 'pergi', 'gereja': 'gereja', 'februari': 'februari', 'mb': 'mb', 'maret': 'maret', 'izin': 'izin', 'terkait': 'kait', 'informasi': 'informasi', 'kepemilikan': 'milik', 'nomor': 'nomor', 'telp': 'telp', 'provider': 'provider', 'konyol': 'konyol', 'udah': 'udah', 'sebulan': 'bulan', 'lag': 'lag', 'parah': 'parah', 'main': 'main', 'parahsih': 'parahsih', 'unlimitedmax': 'unlimitedmax', 'pakek': 'pakek', 'ngapain': 'ngapain', 'kayak': 'kayak', 'nanya': 'nanya', 'didaerah': 'daerah', 'kecamatan': 'camat', 'semaka': 'maka', 'kabupaten': 'kabupaten', 'tanggamus': 'tanggamus', 'provinsi': 'provinsi', 'lampung': 'lampung', 'susah': 'susah', 'penuh': 'penuh', 'akses': 'akses', 'sulit': 'sulit', 'pencerahanny': 'pencerahanny', 'gamesmaxsilver': 'gamesmaxsilver', 'link': 'link', 'voucher': 'voucher', 'diamond': 'diamond', 'habis': 'habis', 'cum': 'cum', 'sosmed': 'sosmed', 'doang': 'doang', 'mahal': 'mahal', 'gini': 'gin', 'jaman': 'jaman', 'gua': 'gua', 'smp': 'smp', 'mutar': 'mutar', 'mitak': ...
# ------------------------
# Pandas Apply:   0%|          | 0/350 [00:00<?, ?it/s]
#                                                comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                hari ini,.. dari tadi pagi sinyal 4g+
# 2    asisten nya robot di ciptakan buat mengatasi k...
# 3                            lambat amat unduhnya ni-_
# 4    asalam alaikum. mohon bantuannya pak/bu, untuk...
# ..                                                 ...
# 352                                  lama 3g update 4g
# 353    sinyal di kendal super lemot. tolong diperbaiki
# 354             bacot 5g taik benerin dlu tu jaringan!
# 355                         harus upgrade kartu kah...
# 356                   sekarang aja 4g+ masih serasa 3g
#
#                                       cleaning_comment  \
# 0    min tolong ditindaklanjuti ini akun udh meresa...
# 1                      hari ini dari tadi pagi sinyal
# 2    asisten nya robot ciptakan buat mengatasi kema...
# 3                                lambat amat unduhnya
# 4    asalam alaikum mohon bantuannya pak untuk tida...
# ..                                                 ...
# 352                                       lama update
# 353        sinyal kendal super lemot tolong diperbaiki
# 354                   bacot taik benerin dlu jaringan
# 355                           harus upgrade kartu kah
# 356                         sekarang aja masih serasa
#
#                                             tokenisasi  \
# 0    [min, tolong, ditindaklanjuti, ini, akun, udh,...
# 1              [hari, ini, dari, tadi, pagi, sinyal, ]
# 2    [asisten, nya, robot, ciptakan, buat, mengatas...
# 3                           [lambat, amat, unduhnya, ]
# 4    [asalam, alaikum, mohon, bantuannya, pak, untu...
# ..                                                 ...
# 352                                   [lama, update, ]
# 353  [sinyal, kendal, super, lemot, tolong, diperba...
# 354            [bacot, taik, benerin, dlu, jaringan, ]
# 355                     [harus, upgrade, kartu, kah, ]
# 356                   [sekarang, aja, masih, serasa, ]
#
#                                               stopword  \
# 0    [min, tolong, ditindaklanjuti, akun, udh, mere...
# 1                                     [pagi, sinyal, ]
# 2    [asisten, robot, ciptakan, mengatasi, kemalesa...
# 3                                 [lambat, unduhnya, ]
# 4    [asalam, alaikum, mohon, bantuannya, mengizink...
# ..                                                 ...
# 352                                         [update, ]
# 353  [sinyal, kendal, super, lemot, tolong, diperba...
# 354            [bacot, taik, benerin, dlu, jaringan, ]
# 355                            [upgrade, kartu, kah, ]
# 356                                         [serasa, ]
#
#                                               stemming
# 0    [min, tolong, ditindaklanjuti, akun, udh, resa...
# 1                                     [pagi, sinyal, ]
# 2    [asisten, robot, cipta, atas, kemalesan, layan...
# 3                                    [lambat, unduh, ]
# 4    [asalam, alaikum, mohon, bantu, izin, postinga...
# ..                                                 ...
# 352                                         [update, ]
# 353         [sinyal, kendal, super, lot, tolong, baik]
# 354              [bacot, taik, benerin, dlu, jaring, ]
# 355                            [upgrade, kartu, kah, ]
# 356                                         [serasa, ]
#
# [350 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [min, tolong, ditindaklanjuti, akun, udh, resa...
# 1                                     [pagi, sinyal, ]
# 2    [asisten, robot, cipta, atas, kemalesan, layan...
# 3                                    [lambat, unduh, ]
# 4    [asalam, alaikum, mohon, bantu, izin, postinga...
# ..                                                 ...
# 352                                         [update, ]
# 353         [sinyal, kendal, super, lot, tolong, baik]
# 354              [bacot, taik, benerin, dlu, jaring, ]
# 355                            [upgrade, kartu, kah, ]
# 356                                         [serasa, ]
#
# [350 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_3.xlsx')
