# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Sinyalnya semakin kayak taik mulai hari ini sa...
# 1    Ini kenapa my Telkomsel ga bisa di buka woi.. ...
# 2    Baru aja beli kuota tadi malem  gak pernah kes...
# 3    Telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    Paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 205                                                NaN
# 206      Pulsa suka habis sendiri padahal gak di gunai
# 207                      Kapan sinyal 5Gnya masuk nih?
#
# [208 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 14

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Sinyalnya semakin kayak taik mulai hari ini sa...
# 1    Ini kenapa my Telkomsel ga bisa di buka woi.. ...
# 2    Baru aja beli kuota tadi malem  gak pernah kes...
# 3    Telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    Paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 202  Banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 206      Pulsa suka habis sendiri padahal gak di gunai
# 207                      Kapan sinyal 5Gnya masuk nih?
#
# [193 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa my telkomsel ga bisa di buka woi.. ...
# 2    baru aja beli kuota tadi malem  gak pernah kes...
# 3    telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 206      pulsa suka habis sendiri padahal gak di gunai
# 207                      kapan sinyal 5gnya masuk nih?
#
# [193 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa my telkomsel ga bisa di buka woi.. ...
# 2    baru aja beli kuota tadi malem  gak pernah kes...
# 3    telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 206      pulsa suka habis sendiri padahal gak di gunai
# 207                      kapan sinyal 5gnya masuk nih?
#
#                                       cleaning_comment
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa telkomsel bisa buka woi relog terus...
# 2    baru aja beli kuota tadi malem gak pernah kesa...
# 3    telkomsel memeng sudah nggak jelas tiba tiba h...
# 4    paket undlimited untuk semua termasuk game gil...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi keluhan peng...
# 204  saya mau tanya kenapa kota telkomsel mahal tap...
# 206         pulsa suka habis sendiri padahal gak gunai
# 207                      kapan sinyal  gnya masuk nih
#
# [193 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa my telkomsel ga bisa di buka woi.. ...
# 2    baru aja beli kuota tadi malem  gak pernah kes...
# 3    telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 206      pulsa suka habis sendiri padahal gak di gunai
# 207                      kapan sinyal 5gnya masuk nih?
#
#                                       cleaning_comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa telkomsel bisa buka woi relog terus...
# 2    baru aja beli kuota tadi malem gak pernah kesa...
# 3    telkomsel memeng sudah nggak jelas tiba tiba h...
# 4    paket undlimited untuk semua termasuk game gil...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi keluhan peng...
# 204  saya mau tanya kenapa kota telkomsel mahal tap...
# 206         pulsa suka habis sendiri padahal gak gunai
# 207                      kapan sinyal  gnya masuk nih
#
#                                             tokenisasi
# 0    [sinyalnya, semakin, kayak, taik, mulai, hari,...
# 1    [ini, kenapa, telkomsel, bisa, buka, woi, relo...
# 2    [baru, aja, beli, kuota, tadi, malem, gak, per...
# 3    [telkomsel, memeng, sudah, nggak, jelas, tiba,...
# 4    [paket, undlimited, untuk, semua, termasuk, ga...
# ..                                                 ...
# 202  [banyak, mafia, pulsa, didalam, perusahaan, in...
# 203  [jaringan, macam, sampah, aja, promosi, keluha...
# 204  [saya, mau, tanya, kenapa, kota, telkomsel, ma...
# 206  [pulsa, suka, habis, sendiri, padahal, gak, gu...
# 207                [kapan, sinyal, gnya, masuk, nih, ]
#
# [193 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa my telkomsel ga bisa di buka woi.. ...
# 2    baru aja beli kuota tadi malem  gak pernah kes...
# 3    telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 206      pulsa suka habis sendiri padahal gak di gunai
# 207                      kapan sinyal 5gnya masuk nih?
#
#                                       cleaning_comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa telkomsel bisa buka woi relog terus...
# 2    baru aja beli kuota tadi malem gak pernah kesa...
# 3    telkomsel memeng sudah nggak jelas tiba tiba h...
# 4    paket undlimited untuk semua termasuk game gil...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi keluhan peng...
# 204  saya mau tanya kenapa kota telkomsel mahal tap...
# 206         pulsa suka habis sendiri padahal gak gunai
# 207                      kapan sinyal  gnya masuk nih
#
#                                             tokenisasi  \
# 0    [sinyalnya, semakin, kayak, taik, mulai, hari,...
# 1    [ini, kenapa, telkomsel, bisa, buka, woi, relo...
# 2    [baru, aja, beli, kuota, tadi, malem, gak, per...
# 3    [telkomsel, memeng, sudah, nggak, jelas, tiba,...
# 4    [paket, undlimited, untuk, semua, termasuk, ga...
# ..                                                 ...
# 202  [banyak, mafia, pulsa, didalam, perusahaan, in...
# 203  [jaringan, macam, sampah, aja, promosi, keluha...
# 204  [saya, mau, tanya, kenapa, kota, telkomsel, ma...
# 206  [pulsa, suka, habis, sendiri, padahal, gak, gu...
# 207                [kapan, sinyal, gnya, masuk, nih, ]
#
#                                               stopword
# 0    [sinyalnya, kayak, taik, pakai, simpati, pdhal...
# 1               [telkomsel, buka, woi, relog, tulisan]
# 2    [beli, kuota, malem, kesampean, beli, surprise...
# 3    [telkomsel, memeng, nggak, harga, paket, unlim...
# 4      [paket, undlimited, game, giliran, pembohongan]
# ..                                                 ...
# 202  [mafia, pulsa, didalam, perusahaan, hati, sala...
# 203  [jaringan, sampah, promosi, keluhan, pengguna,...
# 204  [kota, telkomsel, mahal, jaringan, taik, sipa,...
# 206                        [pulsa, suka, habis, gunai]
# 207                            [sinyal, gnya, masuk, ]
#
# [193 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 679
# ------------------------
# sinyalnya : sinyal
# kayak : kayak
# taik : taik
# pakai : pakai
# simpati : simpati
# pdhal : pdhal
# dlu : dlu
# nmor : nmor
# kecewa : kecewa
# telkomsel : telkomsel
# buka : buka
# woi : woi
# relog : relog
# tulisan : tulis
# beli : beli
# kuota : kuota
# malem : malem
# kesampean : sampean
# surprisedeal : surprisedeal
# tanggal : tanggal
# memeng : memeng
# nggak : nggak
# harga : harga
# paket : paket
# unlimitedmax : unlimitedmax
# berubah : ubah
# ubah : ubah
# peraturan : atur
# berbeda : beda
# beda : beda
# via : via
# dial : dial
# aplikasi : aplikasi
# mytelkomsel : mytelkomsel
#  :
# undlimited : undlimited
# game : game
# giliran : gilir
# pembohongan : bohong
# woy : woy
# internet : internet
# jalan : jalan
# loading : loading
# melulu : melulu
# pagi : pagi
# sampe : sampe
# skrg : skrg
# sinyal : sinyal
# benerin : benerin
# lahh : lahh
# jelek : jelek
# gimn : gimn
# udah : udah
# komenin : komenin
# orang : orang
# gaberubah : gaberubah
# parah : parah
# telat : telat
# ngumpulin : ngumpulin
# tugas : tugas
# gegara : gegara
# telkom : telkom
# lemot : lot
# bagus : bagus
# daerah : daerah
# provider : provider
# tolong : tolong
# perbaiki : baik
# mahal : mahal
# sebanding : banding
# didapet : didapet
# utamakan : utama
# pelanggan : langgan
# wos : wos
# jaringan : jaring
# desa : desa
# hilang : hilang
# bagay : bagay
# kinerja : kerja
# merugikan : rugi
# rakyat : rakyat
# rencana : rencana
# perbaikan : baik
# surprase : surprase
# deal : deal
# ilang : ilang
# bru : bru
# sempet : sempet
# bli : bli
# sehari : hari
# ngeleg : ngeleg
# pdhl : pdhl
# dkt : dkt
# towernya : towernya
# love : love
# terima : terima
# kasih : kasih
# buruk : buruk
# semoga : moga
# lgi : lgi
# gimana : gimana
# banget : banget
# gue : gue
# coba : coba
# susah : susah
# login : login
# unlimited : unlimited
# fup : fup
# min : min
# andalan : andal
# kualitasnya : kualitas
# karuan : karuan
# tekomsel : tekomsel
# sdekali : sdekali
# pelan : pelan
# ditinggalkan : tinggal
# byk : byk
# end : end
# kartu : kartu
# halo : halo
# oke : oke
# selamat : selamat
# sukses : sukses
# april : april
# koq : koq
# superdeal : superdeal
# ribu : ribu
# isi : isi
# pulsa : pulsa
# mah : mah
# ngga : ngga
# surprise : surprise
# jum : jum
# barokah : barokah
# nyaaa : nyaaa
# ditinggal : tinggal
# jam : jam
# plsa : plsa
# urusin : urusin
# promo : promo
# sinyalnyaa : sinyalnyaa
# doang : doang
# jelekk : jelekk
# bangatt : bangatt
# biarin : biarin
# komen : komen
# sesuai : sesuai
# posting : posting
# cuman : cuman
# segi : segi
# kecepatan : cepat
# mundur : mundur
# bukanya : buka
# maju : maju
# alias : alias
# hancur : hancur
# fungsi : fungsi
# veronika : veronika
# keluhan : keluh
# komentar : komentar
# costumer : costumer
# giring : giring
# disuruh : suruh
# hasilnya : hasil
# zero : zero
# nol : nol
# ujung : ujung
# menawarkan : tawar
# produk : produk
# jualan : jual
# menyelesaikan : selesai
# solusi : solusi
# puasa : puasa
# emosi : emosi
# taiii : taiii
# sepesial : sial
# ramadhan : ramadhan
# kemarin : kemarin
# maksudnya : maksud
# pas : pas
# gunain : gunain
# kesedot : sedot
# flasnya : flasnya
# akses : akses
# spotify : spotify
# hapus : hapus
# sikyal : sikyal
# dri : dri
# bumi : bumi
# lambat : lambat
# gua : gua
# butuh : butuh
# bantuan : bantu
# balasnya : balas
# kode : kode
# federal : federal
# salah : salah
# kali : kali
# bangkrut : bangkrut
# hadiah : hadiah
# tuker : tuker
# point : point
# jaringannya : jaring
# kaga : kaga
# omg : omg
# max : max
# muter : muter
# suruh : suruh
# refresh : refresh
# emang : emang
# sadar : sadar
# perasan : peras
# nipu : nipu
# udh : udh
# taon : taon
# pke : pke
# lumayan : lumayan
# dibali : bal
# kuotanya : kuota
# seimbang : imbang
# jaringanya : jaringanya
# menangbundian : menangbundian
# tukar : tukar
# poin : poin
# ketengan : keteng
# youtube : youtube
# minggu : minggu
# cek : cek
# sisa : sisa
# mohon : mohon
# penjelasannya : jelas
# pelit : pelit
# boro : boro
# lemottttt : lemottttt
# parahhhhhh : parahhhhhh
# gabisa : gabisa
# sms : sms
# penipuan : tipu
# nomernya : nomernya
# atasnama : atasnama
# tmrw : tmrw
# voucher : voucher
# poko : poko
# nyahh : nyahh
# telkomsell : telkomsell
# mantepp : mantepp
# bagusss : bagusss
# murah : murah
# kampung : kampung
# gueee : gueee
# toop : toop
# bangettt : bangettt
# kenalin : kenalin
# sayah : sayah
# peguna : guna
# setiya : setiya
# kek : kek
# keong : keong
# penjual : jual
# dibikin : bikin
# migrain : migrain
# dll : dll
# jdi : jdi
# bnyk : bnyk
# dompleng : dompleng
# penipu : tipu
# telkomtol : telkomtol
# patut : patut
# acungi : acung
# clurit : clurit
# mkin : mkin
# gabiasanya : gabiasanya
# ngisi : ngisi
# joszz : joszz
# meriah : riah
# santuy : santuy
# jarang : jarang
# gratisan : gratis
# user : user
# percaya : percaya
# pengguna : guna
# setia : setia
# random : random
# wkwkkwkwk : wkwkkwkwk
# telepon : telepon
# maksutnya : maksutnya
# untungnya : untung
# dlm : dlm
# bentuk : bentuk
# apapun : apa
# dipake : dipake
# mengubah : ubah
# gangguan : ganggu
# data : data
# kualitas : kualitas
# lahhhh : lahhhh
# gini : gin
# edge : edge
# bgsad : bgsad
# ganti : ganti
# hallo : hallo
# taunya : tau
# allah : allah
# tower : tower
# hancurin : hancurin
# kamen : kamen
# rider : rider
# masker : masker
# gmana : gmana
# kabar : kabar
# lucky : lucky
# draw : draw
# the : the
# dihubungin : dihubungin
# februari : februari
# diambil : ambil
# grapari : grapari
# blum : blum
# konfirmasi : konfirmasi
# pekat : pekat
# multimedia : multimedia
# maaf : maaf
# sekedar : dar
# kemaren : kemaren
# tlp : tlp
# tpi : tpi
# terangkat : angkat
# atw : atw
# giman : gim
# penjelasanya : jasa
# balas : balas
# nyuruh : nyuruh
# chat : chat
# robot : robot
# virtual : virtual
# assistant : assistant
# super : super
# ngakak : ngakak
# manusia : manusia
# buruknya : buruk
# dikontrol : kontrol
# dkit : dkit
# msak : msak
# trus : trus
# diksi : diksi
# bruk : bruk
# mnding : mnding
# dikasi : kasi
# iklan : iklan
# selangit : langit
# donk : donk
# nomer : nomer
# tsl : tsl
# hangus : hangus
# whatshap : whatshap
# barusan : barusan
# restat : restat
# whatsap : whatsap
# pesan : pesan
# verifikasi : verifikasi
# bantuannya : bantu
# kaya : kaya
# bohong : bohong
# surabaya : surabaya
# pelosok : pelosok
# gajelas : gajelas
# lokasi : lokasi
# aktivasi : aktivasi
# lokal : lokal
# gmna : gmna
# boss : boss
# kadang : kadang
# telko : telko
# kagak : kagak
# marah : marah
# kasian : kasi
# liat : liat
# make : make
# wifi : wifi
# disalahin : disalahin
# pembelian : beli
# voucer : voucer
# terpaksa : paksa
# pindah : pindah
# operator : operator
# mending : mending
# im : im
# oredo : oredo
# ribet : ribet
# terimakasih : terimakasih
# uang : uang
# juta : juta
# beneran : beneran
# raya : raya
# generator : generator
# mati : mati
# lampu : lampu
# towerpun : towerpun
# prasaan : prasaan
# like : like
# jt : jt
# skrng : skrng
# trun : trun
# senang : senang
# lihat : lihat
# melebihi : lebih
# bacot : bacot
# server : server
# kau : kau
# njir : njir
# bnget : bnget
# daritadi : daritadi
# maketin : maketin
# mode : mode
# pesawat : pesawat
# rebot : rebot
# tingkatkan : tingkat
# kasihani : kasihan
# mahasiswa : mahasiswa
# tinggal : tinggal
# perkampungan : kampung
# bayar : bayar
# semester : semester
# ngulang : ngulang
# karna : karna
# lucu : lucu
# menggulung : gulung
# tikar : tikar
# enth : enth
# mna : mna
# muncul : muncul
# membutuhkan : butuh
# menghubungi : hubung
# keluarga : keluarga
# sakit : sakit
# gpp : gpp
# anak : anak
# yatim : yatim
# aktif : aktif
# kouta : kouta
# nanya : nanya
# kepake : kepake
# kesedok : dok
# gb : gb
# klu : klu
# utama : utama
# knpa : knpa
# unlimitid : unlimitid
# gamemax : gamemax
# matching : matching
# reconnect : reconnect
# mulu : mulu
# yak : yak
# dikecewakan : kecewa
# bermain : main
# online : online
# bts : bts
# kedepannya : depan
# mengurangi : kurang
# pemakaian : pakai
# ampun : ampun
# niat : niat
# ngeklik : ngeklik
# respon : respon
# berkurang : kurang
# turun : turun
# harganya : harga
# pon : pon
# nganguan : nganguan
# kekmana : kekmana
# combo : combo
# ulimete : ulimete
# seru : seru
# lag : lag
# telkomlag : telkomlag
# perbaikin : perbaikin
# bner : bner
# konter : konter
# suka : suka
# cra : cra
# tker : tker
# hay : hay
# bantu : bantu
# pls : pls
# paketan : paket
# batasan : batas
# kubutuh : butuh
# inih : inih
# ituh : ituh
# ajh : ajh
# membeli : beli
# darurat : darurat
# ampas : ampas
# cuih : cuih
# najis : najis
# nyaman : nyaman
# hai : hai
# kak : kak
# tsel : tsel
# sales : sales
# mksih : mksih
# ayolah : ayo
# indonesia : indonesia
# nyaingi : nyaingi
# negara : negara
# koneksi : koneksi
# internetnya : internetnya
# kenceng : kenceng
# enak : enak
# asem : asem
# perbaikannya : baik
# malu : malu
# main : main
# lancar : lancar
# kena : kena
# apakok : apakok
# paketkomboe : paketkomboe
# sakti : sakti
# ngak : ngak
# gorenggggggggg : gorenggggggggg
# lahhh : lahhh
# woyy : woyy
# admin : admin
# whatsapp : whatsapp
# nama : nama
# blok : blok
# kembalikan : kembali
# combosakti : combosakti
# yes : yes
# didepan : depan
# woii : woii
# tay : tay
# skrang : skrang
# cepat : cepat
# habiss : habiss
# memburuk : buruk
# teruss : teruss
# payah : payah
# sebelah : belah
# rumah : rumah
# neh : neh
# jarinagnnya : jarinagnnya
# bener : bener
# beneri : beneri
# duper : duper
# slowly : slowly
# dibalas : balas
# anjing : anjing
# lawak : lawak
# batasnya : batas
# plis : plis
# dengarkan : dengar
# wtf : wtf
# fvck : fvck
# link : link
# huuuu : huuuu
# vocer : vocer
# gmn : gmn
# rusak : rusak
# pengen : ken
# mkan : mkan
# layanan : layan
# memuaskan : muas
# cabut : cabut
# gnti : gnti
# sma : sma
# ngerasa : ngerasa
# seringkali : seringkali
# nelfon : nelfon
# nyambunginnya : nyambunginnya
# nyambung : nyambung
# tone : tone
# bar : bar
# signal : signal
# guys : guys
# meminjam : pinjam
# sulit : sulit
# sumut : sumut
# padhal : padhal
# pertanyaannya : tanya
# bertahankah : tahan
# angkat : angkat
# kaki : kaki
# sampah : sampah
# ceria : ceria
# ambil : ambil
# sos : sos
# pinjam : pinjam
# kaali : kaali
# haru : haru
# kapuas : kapuas
# hulu : hulu
# kalbar : kalbar
# balikin : balikin
# milih : milih
# buang : buang
# sayang : sayang
# malam : malam
# cok : cok
# nomor : nomor
# masuk : masuk
# registrasi : registrasi
# lenyap : lenyap
# diubah : ubah
# batesin : batesin
# gwa : gwa
# lncar : lncar
# bet : bet
# korona : korona
# upgrade : upgrade
# gagal : gagal
# down : down
# teroooosssss : teroooosssss
# belikan : belikan
# mb : mb
# tmn : tmn
# setabil : setabil
# memperkuat : kuat
# pgi : pgi
# berhasil : hasil
# emg : emg
# crany : crany
# kes : kes
# poto : poto
# tutor : tutor
# dapet : dapet
# gratis : gratis
# minimal : minimal
# bgmn : bgmn
# history : history
# counter : counter
# msa : msa
# kiye : kiye
# bakul : bakul
# ingus : ingus
# diperbaiki : baik
# sungapan : sungapan
# lor : lor
# wahyuharjo : wahyuharjo
# lendah : lendah
# kabupaten : kabupaten
# kulon : kulon
# progo : progo
# istimewa : istimewa
# yogyakarta : yogyakarta
# veronica : veronica
# jawabannya : jawab
# ngawur : ngawur
# maklum : maklum
# sejenis : jenis
# komputer : komputer
# mesin : mesin
# otomatis : otomatis
# push : push
# asik : asik
# ehh : ehh
# ping : ping
# merah : merah
# eror : eror
# mafia : mafia
# didalam : dalam
# perusahaan : usaha
# hati : hati
# melangkah : lang
# sedot : sedot
# habis : habis
# masyarakat : masyarakat
# paham : paham
# sistem : sistem
# mengadu : adu
# dibilang : bilang
# promosi : promosi
# ndak : ndak
# kota : kota
# sipa : sipa
# klaw : klaw
# tlkomsel : tlkomsel
# gunai : guna
# gnya : gnya
# {'sinyalnya': 'sinyal', 'kayak': 'kayak', 'taik': 'taik', 'pakai': 'pakai', 'simpati': 'simpati', 'pdhal': 'pdhal', 'dlu': 'dlu', 'nmor': 'nmor', 'kecewa': 'kecewa', 'telkomsel': 'telkomsel', 'buka': 'buka', 'woi': 'woi', 'relog': 'relog', 'tulisan': 'tulis', 'beli': 'beli', 'kuota': 'kuota', 'malem': 'malem', 'kesampean': 'sampean', 'surprisedeal': 'surprisedeal', 'tanggal': 'tanggal', 'memeng': 'memeng', 'nggak': 'nggak', 'harga': 'harga', 'paket': 'paket', 'unlimitedmax': 'unlimitedmax', 'berubah': 'ubah', 'ubah': 'ubah', 'peraturan': 'atur', 'berbeda': 'beda', 'beda': 'beda', 'via': 'via', 'dial': 'dial', 'aplikasi': 'aplikasi', 'mytelkomsel': 'mytelkomsel', '': '', 'undlimited': 'undlimited', 'game': 'game', 'giliran': 'gilir', 'pembohongan': 'bohong', 'woy': 'woy', 'internet': 'internet', 'jalan': 'jalan', 'loading': 'loading', 'melulu': 'melulu', 'pagi': 'pagi', 'sampe': 'sampe', 'skrg': 'skrg', 'sinyal': 'sinyal', 'benerin': 'benerin', 'lahh': 'lahh', 'jelek': 'jelek', 'gimn': 'gimn', 'udah': 'udah', 'komenin': 'komenin', 'orang': 'orang', 'gaberubah': 'gaberubah', 'parah': 'parah', 'telat': 'telat', 'ngumpulin': 'ngumpulin', 'tugas': 'tugas', 'gegara': 'gegara', 'telkom': 'telkom', 'lemot': 'lot', 'bagus': 'bagus', 'daerah': 'daerah', 'provider': 'provider', 'tolong': 'tolong', 'perbaiki': 'baik', 'mahal': 'mahal', 'sebanding': 'banding', 'didapet': 'didapet', 'utamakan': 'utama', 'pelanggan': 'langgan', 'wos': 'wos', 'jaringan': 'jaring', 'desa': 'desa', 'hilang': 'hilang', 'bagay': 'bagay', 'kinerja': 'kerja', 'merugikan': 'rugi', 'rakyat': 'rakyat', 'rencana': 'rencana', 'perbaikan': 'baik', 'surprase': 'surprase', 'deal': 'deal', 'ilang': 'ilang', 'bru': 'bru', 'sempet': 'sempet', 'bli': 'bli', 'sehari': 'hari', 'ngeleg': 'ngeleg', 'pdhl': 'pdhl', 'dkt': 'dkt', 'towernya': 'towernya', 'love': 'love', 'terima': 'terima', 'kasih': 'kasih', 'buruk': 'buruk', 'semoga': 'moga', 'lgi': 'lgi', 'gimana': 'gimana', 'banget': 'banget', 'gue': 'gue', 'coba': 'coba', 'susah': 'susah', 'login': 'login', 'unlimited': 'unlimited', 'fup': 'fup', 'min': 'min', 'andalan': 'andal', 'kualitasnya': 'kualitas', 'karuan': 'karuan', 'tekomsel': 'tekomsel', 'sdekali': 'sdekali', 'pelan': 'pelan', 'ditinggalkan': 'tinggal', 'byk': 'byk', 'end': 'end', 'kartu': 'kartu', 'halo': 'halo', 'oke': 'oke', 'selamat': 'selamat', 'sukses': 'sukses', 'april': 'april', 'koq': 'koq', 'superdeal': 'superdeal', 'ribu': 'ribu', 'isi': 'isi', 'pulsa': 'pulsa', 'mah': 'mah', 'ngga': 'ngga', 'surprise': 'surprise', 'jum': 'jum', 'barokah': 'barokah', 'nyaaa': 'nyaaa', 'ditinggal': 'tinggal', 'jam': 'jam', 'plsa': 'plsa', 'urusin': 'urusin', 'promo': 'promo', 'sinyalnyaa': 'sinyalnyaa', 'doang': 'doang', 'jelekk': 'jelekk', 'bangatt': 'bangatt', 'biarin': 'biarin', 'komen': 'komen', 'sesuai': 'sesuai', 'posting': 'posting', 'cuman': 'cuman', 'segi': 'segi', 'kecepatan': 'cepat', 'mundur': 'mundur', 'bukanya': 'buka', 'maju': 'maju', 'alias': 'alias', 'hancur': 'hancur', 'fungsi': 'fungsi', 'veronika': 'veronika', 'keluhan': 'keluh', 'komentar': 'komentar', 'costumer': 'costumer', 'giring': 'giring', 'disuruh': 'suruh', 'hasilnya': 'hasil', 'zero': 'zero', 'nol': 'nol', 'ujung': 'ujung', 'menawarkan': 'tawar', 'produk': 'produk', 'jualan': 'jual', 'menyelesaikan': 'selesai', 'solusi': 'solusi', 'puasa': 'puasa', 'emosi': 'emosi', 'taiii': 'taiii', 'sepesial': 'sial', 'ramadhan': 'ramadhan', 'kemarin': 'kemarin', 'maksudnya': 'maksud', 'pas': 'pas', 'gunain': 'gunain', 'kesedot': 'sedot', 'flasnya': 'flasnya', 'akses': 'akses', 'spotify': 'spotify', 'hapus': 'hapus', 'sikyal': 'sikyal', 'dri': 'dri', 'bumi': 'bumi', 'lambat': 'lambat', 'gua': 'gua', 'butuh': 'butuh', 'bantuan': 'bantu', 'balasnya': 'balas', 'kode': 'kode', 'federal': 'federal', 'salah': 'salah', 'kali': 'kali', 'bangkrut': 'bangkrut', 'hadiah': 'hadiah', 'tuker': 'tuker', 'point': 'point', 'jaringannya': 'jaring', 'kaga': 'kaga', 'omg': 'omg', 'max': 'max', 'muter': 'muter', 'suruh': 'suruh', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/193 [00:00<?, ?it/s]
#                                                comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa my telkomsel ga bisa di buka woi.. ...
# 2    baru aja beli kuota tadi malem  gak pernah kes...
# 3    telkomsel memeng sudah nggak jelas tiba-tiba h...
# 4    paket undlimited untuk semua termasuk game..gi...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi, keluhan pen...
# 204  saya mau tanya ,kenapa kota telkomsel mahal,ta...
# 206      pulsa suka habis sendiri padahal gak di gunai
# 207                      kapan sinyal 5gnya masuk nih?
#
#                                       cleaning_comment  \
# 0    sinyalnya semakin kayak taik mulai hari ini sa...
# 1    ini kenapa telkomsel bisa buka woi relog terus...
# 2    baru aja beli kuota tadi malem gak pernah kesa...
# 3    telkomsel memeng sudah nggak jelas tiba tiba h...
# 4    paket undlimited untuk semua termasuk game gil...
# ..                                                 ...
# 202  banyak mafia pulsa didalam perusahaan ini hati...
# 203  jaringan macam sampah aja promosi keluhan peng...
# 204  saya mau tanya kenapa kota telkomsel mahal tap...
# 206         pulsa suka habis sendiri padahal gak gunai
# 207                      kapan sinyal  gnya masuk nih
#
#                                             tokenisasi  \
# 0    [sinyalnya, semakin, kayak, taik, mulai, hari,...
# 1    [ini, kenapa, telkomsel, bisa, buka, woi, relo...
# 2    [baru, aja, beli, kuota, tadi, malem, gak, per...
# 3    [telkomsel, memeng, sudah, nggak, jelas, tiba,...
# 4    [paket, undlimited, untuk, semua, termasuk, ga...
# ..                                                 ...
# 202  [banyak, mafia, pulsa, didalam, perusahaan, in...
# 203  [jaringan, macam, sampah, aja, promosi, keluha...
# 204  [saya, mau, tanya, kenapa, kota, telkomsel, ma...
# 206  [pulsa, suka, habis, sendiri, padahal, gak, gu...
# 207                [kapan, sinyal, gnya, masuk, nih, ]
#
#                                               stopword  \
# 0    [sinyalnya, kayak, taik, pakai, simpati, pdhal...
# 1               [telkomsel, buka, woi, relog, tulisan]
# 2    [beli, kuota, malem, kesampean, beli, surprise...
# 3    [telkomsel, memeng, nggak, harga, paket, unlim...
# 4      [paket, undlimited, game, giliran, pembohongan]
# ..                                                 ...
# 202  [mafia, pulsa, didalam, perusahaan, hati, sala...
# 203  [jaringan, sampah, promosi, keluhan, pengguna,...
# 204  [kota, telkomsel, mahal, jaringan, taik, sipa,...
# 206                        [pulsa, suka, habis, gunai]
# 207                            [sinyal, gnya, masuk, ]
#
#                                               stemming
# 0    [sinyal, kayak, taik, pakai, simpati, pdhal, d...
# 1                 [telkomsel, buka, woi, relog, tulis]
# 2    [beli, kuota, malem, sampean, beli, surprisede...
# 3    [telkomsel, memeng, nggak, harga, paket, unlim...
# 4             [paket, undlimited, game, gilir, bohong]
# ..                                                 ...
# 202  [mafia, pulsa, dalam, usaha, hati, salah, lang...
# 203  [jaring, sampah, promosi, keluh, guna, ndak, b...
# 204  [kota, telkomsel, mahal, jaring, taik, sipa, k...
# 206                         [pulsa, suka, habis, guna]
# 207                            [sinyal, gnya, masuk, ]
#
# [193 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [sinyal, kayak, taik, pakai, simpati, pdhal, d...
# 1                 [telkomsel, buka, woi, relog, tulis]
# 2    [beli, kuota, malem, sampean, beli, surprisede...
# 3    [telkomsel, memeng, nggak, harga, paket, unlim...
# 4             [paket, undlimited, game, gilir, bohong]
# ..                                                 ...
# 202  [mafia, pulsa, dalam, usaha, hati, salah, lang...
# 203  [jaring, sampah, promosi, keluh, guna, ndak, b...
# 204  [kota, telkomsel, mahal, jaring, taik, sipa, k...
# 206                         [pulsa, suka, habis, guna]
# 207                            [sinyal, gnya, masuk, ]
#
# [193 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_4.xlsx')
