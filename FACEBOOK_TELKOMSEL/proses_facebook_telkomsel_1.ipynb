# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Telkomsel sekarang parah banget, udah sebulana...
# 1    Ini Forji bikin jiji, 2021 makin buruk lu jari...
# 2          Semua juga terkena dampak. Signal lemoooott
# 3    Sukabumi kacauu ahh.. Maen game gk stabill .. ...
# 4    Knpa koneksi internet kec, Pelepat ilir kuaman...
# ..                                                 ...
# 452  Min ko kode voucher yang saya beli tidak bisa ...
# 453                               Lu becanda yah tsel?
# 454  Percuma karena harus ada paket utama baru bisa...
# 455  Pengen posting jga min, tapi gmna liat aja sin...
# 456  Min mau tanya.. ini yang unlimited nya bisa bu...
#
# [457 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 55

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Telkomsel sekarang parah banget, udah sebulana...
# 1    Ini Forji bikin jiji, 2021 makin buruk lu jari...
# 2          Semua juga terkena dampak. Signal lemoooott
# 3    Sukabumi kacauu ahh.. Maen game gk stabill .. ...
# 4    Knpa koneksi internet kec, Pelepat ilir kuaman...
# ..                                                 ...
# 452  Min ko kode voucher yang saya beli tidak bisa ...
# 453                               Lu becanda yah tsel?
# 454  Percuma karena harus ada paket utama baru bisa...
# 455  Pengen posting jga min, tapi gmna liat aja sin...
# 456  Min mau tanya.. ini yang unlimited nya bisa bu...
#
# [348 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    telkomsel sekarang parah banget, udah sebulana...
# 1    ini forji bikin jiji, 2021 makin buruk lu jari...
# 2          semua juga terkena dampak. signal lemoooott
# 3    sukabumi kacauu ahh.. maen game gk stabill .. ...
# 4    knpa koneksi internet kec, pelepat ilir kuaman...
# ..                                                 ...
# 452  min ko kode voucher yang saya beli tidak bisa ...
# 453                               lu becanda yah tsel?
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min, tapi gmna liat aja sin...
# 456  min mau tanya.. ini yang unlimited nya bisa bu...
#
# [348 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    telkomsel sekarang parah banget, udah sebulana...
# 1    ini forji bikin jiji, 2021 makin buruk lu jari...
# 2          semua juga terkena dampak. signal lemoooott
# 3    sukabumi kacauu ahh.. maen game gk stabill .. ...
# 4    knpa koneksi internet kec, pelepat ilir kuaman...
# ..                                                 ...
# 452  min ko kode voucher yang saya beli tidak bisa ...
# 453                               lu becanda yah tsel?
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min, tapi gmna liat aja sin...
# 456  min mau tanya.. ini yang unlimited nya bisa bu...
#
#                                       cleaning_comment
# 0    telkomsel sekarang parah banget udah sebulanan...
# 1      ini forji bikin jiji   makin buruk jaringannya
# 2           semua juga terkena dampak signal lemoooott
# 3    sukabumi kacauu ahh maen game stabill mohon pe...
# 4    knpa koneksi internet kec pelepat ilir kuamang...
# ..                                                 ...
# 452   min kode voucher yang saya beli tidak bisa masuk
# 453                                  becanda yah tsel
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min tapi gmna liat aja siny...
# 456  min mau tanya ini yang unlimited nya bisa buat...
#
# [348 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    telkomsel sekarang parah banget, udah sebulana...
# 1    ini forji bikin jiji, 2021 makin buruk lu jari...
# 2          semua juga terkena dampak. signal lemoooott
# 3    sukabumi kacauu ahh.. maen game gk stabill .. ...
# 4    knpa koneksi internet kec, pelepat ilir kuaman...
# ..                                                 ...
# 452  min ko kode voucher yang saya beli tidak bisa ...
# 453                               lu becanda yah tsel?
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min, tapi gmna liat aja sin...
# 456  min mau tanya.. ini yang unlimited nya bisa bu...
#
#                                       cleaning_comment  \
# 0    telkomsel sekarang parah banget udah sebulanan...
# 1      ini forji bikin jiji   makin buruk jaringannya
# 2           semua juga terkena dampak signal lemoooott
# 3    sukabumi kacauu ahh maen game stabill mohon pe...
# 4    knpa koneksi internet kec pelepat ilir kuamang...
# ..                                                 ...
# 452   min kode voucher yang saya beli tidak bisa masuk
# 453                                  becanda yah tsel
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min tapi gmna liat aja siny...
# 456  min mau tanya ini yang unlimited nya bisa buat...
#
#                                             tokenisasi
# 0    [telkomsel, sekarang, parah, banget, udah, seb...
# 1    [ini, forji, bikin, jiji, makin, buruk, jaring...
# 2    [semua, juga, terkena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, pelepat, ilir, ...
# ..                                                 ...
# 452  [min, kode, voucher, yang, saya, beli, tidak, ...
# 453                           [, becanda, yah, tsel, ]
# 454  [percuma, karena, harus, ada, paket, utama, ba...
# 455  [pengen, posting, jga, min, tapi, gmna, liat, ...
# 456  [min, mau, tanya, ini, yang, unlimited, nya, b...
#
# [348 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    telkomsel sekarang parah banget, udah sebulana...
# 1    ini forji bikin jiji, 2021 makin buruk lu jari...
# 2          semua juga terkena dampak. signal lemoooott
# 3    sukabumi kacauu ahh.. maen game gk stabill .. ...
# 4    knpa koneksi internet kec, pelepat ilir kuaman...
# ..                                                 ...
# 452  min ko kode voucher yang saya beli tidak bisa ...
# 453                               lu becanda yah tsel?
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min, tapi gmna liat aja sin...
# 456  min mau tanya.. ini yang unlimited nya bisa bu...
#
#                                       cleaning_comment  \
# 0    telkomsel sekarang parah banget udah sebulanan...
# 1      ini forji bikin jiji   makin buruk jaringannya
# 2           semua juga terkena dampak signal lemoooott
# 3    sukabumi kacauu ahh maen game stabill mohon pe...
# 4    knpa koneksi internet kec pelepat ilir kuamang...
# ..                                                 ...
# 452   min kode voucher yang saya beli tidak bisa masuk
# 453                                  becanda yah tsel
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min tapi gmna liat aja siny...
# 456  min mau tanya ini yang unlimited nya bisa buat...
#
#                                             tokenisasi  \
# 0    [telkomsel, sekarang, parah, banget, udah, seb...
# 1    [ini, forji, bikin, jiji, makin, buruk, jaring...
# 2    [semua, juga, terkena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, pelepat, ilir, ...
# ..                                                 ...
# 452  [min, kode, voucher, yang, saya, beli, tidak, ...
# 453                           [, becanda, yah, tsel, ]
# 454  [percuma, karena, harus, ada, paket, utama, ba...
# 455  [pengen, posting, jga, min, tapi, gmna, liat, ...
# 456  [min, mau, tanya, ini, yang, unlimited, nya, b...
#
#                                               stopword
# 0    [telkomsel, parah, banget, udah, sebulanan, si...
# 1                  [forji, jiji, buruk, jaringannya, ]
# 2                 [terkena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, pelepat, ilir, ...
# ..                                                 ...
# 452                  [min, kode, voucher, beli, masuk]
# 453                                [, becanda, tsel, ]
# 454                   [paket, utama, bisah, beroprasi]
# 455    [pengen, posting, jga, min, gmna, liat, sinyal]
# 456  [min, unlimited, buka, shopee, dahh, kaga, pliss]
#
# [348 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1163
# ------------------------
# telkomsel : telkomsel
# parah : parah
# banget : banget
# udah : udah
# sebulanan : bulan
# sinyal : sinyal
# jelek : jelek
# mending : mending
# pindah : pindah
# provider : provider
#  :
# forji : forji
# jiji : jiji
# buruk : buruk
# jaringannya : jaring
# terkena : kena
# dampak : dampak
# signal : signal
# lemoooott : lemoooott
# sukabumi : sukabumi
# kacauu : kacauu
# ahh : ahh
# maen : maen
# game : game
# stabill : stabill
# mohon : mohon
# perbaikannya : baik
# secepatnya : cepat
# knpa : knpa
# koneksi : koneksi
# internet : internet
# kec : kec
# pelepat : lepat
# ilir : ilir
# kuamang : amang
# kuning : kuning
# kab : kab
# bungo : bungo
# prov : prov
# jambi : jambi
# susah : susah
# akses : akses
# trimakasih : trimakasih
# kabupaten : kabupaten
# bharat : bharat
# kecamatan : camat
# sukramai : sukramai
# tolong : tolong
# perbaiki : baik
# jarinan : jarinan
# telkoselnya : telkoselnya
# ane : ane
# doain : doain
# moga : moga
# kali : kali
# gedung : gedung
# terbakar : bakar
# hancur : hancur
# lebur : lebur
# jaringan : jaring
# bagus : bagus
# weh : weh
# veronika : veronika
# serang : serang
# banten : banten
# signalnya : signalnya
# hilang : hilang
# kuntul : kuntul
# abis : abis
# update : update
# login : login
# terdampak : dampak
# bencanapun : bencana
# beli : beli
# paket : paket
# midnight : midnight
# tpi : tpi
# suruh : suruh
# kode : kode
# verifikasinya : verifikasi
# kirim : kirim
# diperbaiki : baik
# lgi : lgi
# min : min
# sulawesi : sulawesi
# tenggara : tenggara
# berat : berat
# seberat : berat
# kontainer : kontainer
# khusus : khusus
# wilayah : wilayah
# kapontori : kapontori
# perbaikan : baik
# sajen : sajen
# didaerah : daerah
# mlh : mlh
# sinyalnya : sinyal
# seminggu : minggu
# kemaren : kemaren
# full : full
# payah : payah
# lahat : lahat
# sumatera : sumatera
# selatan : selatan
# cek : cek
# lag : lag
# main : main
# ping : ping
# suka : suka
# beda : beda
# kyak : kyak
# dlu : dlu
# paketan : paket
# mahal : mahal
# sesuai : sesuai
# yaaa : yaaa
# terkadang : terkadang
# putus : putus
# nyambung : nyambung
# bgus : bgus
# signalx : signalx
# dperbaiki : dperbaiki
# yaa : yaa
# semalam : malam
# gitu : gitu
# kuota : kuota
# maaf : maaf
# mengganggu : ganggu
# plm : plm
# jarinya : jari
# setabil : setabil
# kondisikan : kondisi
# trimks : trimks
# mbaca : mbaca
# komentar : komentar
# flores : flores
# ntt : ntt
# kecamata : kecamata
# rahong : rahong
# utara : utara
# jaringanya : jaringanya
# dimna : dimna
# bencana : bencana
# dsitu : dsitu
# bacod : bacod
# cari : cari
# muka : muka
# sadar : sadar
# sluruh : sluruh
# indonesia : indonesia
# ngalamin : ngalamin
# khancuran : khancuran
# kak : kak
# bot : bot
# knapa : knapa
# gangguan : ganggu
# masal : masal
# berhari : hari
# tah : tah
# rusaknya : rusak
# sinyl : sinyl
# lola : lola
# mintak : mintak
# ampun : ampun
# kecepatan : cepat
# rendah : rendah
# udh : udh
# thn : thn
# pakai : pakai
# kesini : kesini
# loyoo : loyoo
# masuk : masuk
# apk : apk
# error : error
# gabisa : gabisa
# reinstall : reinstall
# gimana : gimana
# coba : coba
# gua : gua
# melewati : lewat
# lemotnya : lot
# indah : indah
# miip : miip
# idi : idi
# piningkitin : piningkitin
# piliyinin : piliyinin
# jiringin : jiringin
# kelar : kelar
# woi : woi
# feedback : feedback
# trosss : trosss
# dibilang : bilang
# blm : blm
# dananya : dana
# perbaikin : perbaikin
# klau : klau
# ngerii : ngeri
# desa : desa
# sedan : sedan
# rembang : rembang
# jawa : jawa
# telkomselnya : telkomselnya
# respon : respon
# kaltim : kaltim
# jam : jam
# segini : gin
# eror : eror
# aplikasi : aplikasi
# sial : sial
# seandainya : anda
# kotabaru : kotabaru
# enak : enak
# kartu : kartu
# dapet : dapet
# promo : promo
# unlimited : unlimited
# mifi : mifi
# langsung : langsung
# dri : dri
# ngegame : ngegame
# ilang : ilang
# kamar : kamar
# aman : aman
# ksini : ksini
# kosong : kosong
# trus : trus
# bar : bar
# becus : becus
# kerja : kerja
# fix : fix
# palu : palu
# pasca : pasca
# tsel : tsel
# daerah : daerah
# barat : barat
# komentarnya : komentar
# hmpir : hmpir
# smua : smua
# mngatakan : mngatakan
# kurg : kurg
# puas : puas
# pelayanannya : layan
# kpd : kpd
# telkom : telkom
# ditingkatkan : tingkat
# tks : tks
# harga : harga
# tergila : gila
# dunia : dunia
# waras : waras
# diatas : atas
# malem : malem
# kayak : kayak
# habis : habis
# disapu : sapu
# dibuka : buka
# stabil : stabil
# upadte : upadte
# refresh : refresh
# mulu : mulu
# via : via
# terhalang : halang
# mlm : mlm
# paketnya : paket
# aneh : aneh
# pas : pas
# penyebab : sebab
# minn : minn
# toili : toili
# komen : komen
# keluhan : keluh
# prasaan : prasaan
# sya : sya
# lancarr : lancarr
# ladi : ladi
# klw : klw
# pengguna : guna
# niatan : niat
# nurunin : nurunin
# internetnya : internetnya
# kenpa : kenpa
# wooyy : wooyy
# pulih : pulih
# babadan : babad
# lor : lor
# raid : raid
# gila : gila
# hallo : hallo
# admin : admin
# bbrapa : bbrapa
# jaringanmu : jaring
# skuat : skuat
# gundala : gundala
# putra : putra
# petir : petir
# rasakan : rasa
# lemot : lot
# sjaa : sjaa
# trllu : trllu
# sibuk : sibuk
# memperbaiki : baik
# daerh : daerh
# atw : atw
# systemmu : systemmu
# mmg : mmg
# hrs : hrs
# perbaharui : baharu
# knp : knp
# data : data
# mekarmulya : mekarmulya
# cikalongkulon : cikalongkulon
# cianjur : cianjur
# pedalaman : dalam
# bangt : bangt
# ngelag : ngelag
# keburu : keburu
# ampe : ampe
# kesedot : sedot
# pulsa : pulsa
# sialan : sial
# bener : bener
# kaya : kaya
# orang : orang
# bloon : bloon
# hapus : hapus
# download : download
# ulang : ulang
# make : make
# wifi : wifi
# hotspot : hotspot
# mytelkomsel : mytelkomsel
# bla : bla
# blaaa : blaaa
# weyyy : weyyy
# bang : bang
# bengkulu : bengkulu
# rejang : rejang
# lebong : lebong
# kecewa : kecewa
# gini : gin
# kaga : kaga
# tangerang : tangerang
# hadir : hadir
# lapor : lapor
# customer : customer
# service : service
# sok : sok
# keras : keras
# butut : butut
# emosi : emosi
# maketin : maketin
# doang : doang
# ampas : ampas
# buka : buka
# semalem : semalem
# sumedang : sumedang
# jatinunggal : jatinunggal
# kritis : kritis
# sulsel : sulsel
# luwu : luwu
# timur : timur
# sms : sms
# kezel : kezel
# pekalongan : kalong
# tulakan : tula
# pacitan : pacitan
# jawatimur : jawatimur
# skitar : skitar
# bulanan : bulan
# nggak : nggak
# mendukung : dukung
# kususnya : sus
# misi : misi
# izin : izin
# kondisi : kondisi
# tammerodo : tammerodo
# sendana : sendana
# majene : majene
# provinsi : provinsi
# kesulitan : sulit
# men : men
# kalbar : kalbar
# lombok : lombok
# gag : gag
# ganti : ganti
# pdahal : pdahal
# operator : operator
# tlpon : tlpon
# ttp : ttp
# jha : jha
# jaringn : jaringn
# bagkai : bagkai
# tuban : tuban
# ambil : ambil
# ketengan : keteng
# youtube : youtube
# app : app
# log : log
# kah : kah
# terpantau : pantau
# padat : padat
# ramai : ramai
# lacar : lacar
# komplain : komplain
# lihat : lihat
# tanggapan : tanggap
# adminnya : adminnya
# nga : nga
# mainnya : main
# kgak : kgak
# pdhl : pdhl
# bln : bln
# sumatra : sumatra
# signak : signak
# tower : tower
# morowali : morowali
# pajangan : pajang
# aka : aka
# bgusnya : bgusnya
# rubuhin : rubuhin
# jrngan : jrngan
# terlemote : terlemote
# terburuk : buruk
# makan : makan
# uang : uang
# haram : haram
# gaji : gaji
# buta : buta
# karywan : karywan
# pemalas : malas
# dijual : jual
# perusahaan : usaha
# mantul : mantul
# halo : halo
# daftar : daftar
# link : link
# brp : brp
# awas : awas
# kepotong : potong
# saldonyaa : saldonyaa
# duh : duh
# ayo : ayo
# kaa : kaa
# trs : trs
# bandung : bandung
# muncul : muncul
# lancar : lancar
# sampe : sampe
# kpn : kpn
# lagii : lagi
# sii : sii
# inet : inet
# nnti : nnti
# saldo : saldo
# linkaja : linkaja
# nyaa : nyaa
# terima : terima
# kasih : kasih
# donasi : donasi
# masyarakat : masyarakat
# sulbar : sulbar
# semoga : moga
# umur : umur
# sehat : sehat
# gagal : gagal
# ngk : ngk
# penjelasanya : jasa
# sore : sore
# lohh : lohh
# niat : niat
# ngga : ngga
# disana : sana
# seriously : seriously
# kb : kb
# nyimak : nyimak
# mntap : mntap
# wmx : wmx
# perna : perna
# gvsguan : gvsguan
# jabar : jabar
# ibukota : ibukota
# lambat : lambat
# malu : malu
# ama : ama
# berdiri : diri
# dimana : mana
# berdiriin : berdiriin
# pohon : pohon
# kelapa : kelapa
# ketauan : tau
# elpengalihan : elpengalihan
# kritang : kritang
# telkoms : telkoms
# kalimantan : kalimantan
# tingkat : tingkat
# kualitas : kualitas
# thanks : thanks
# ngerasain : ngerasain
# kadang : kadang
# nyala : nyala
# mati : mati
# sebulan : bulan
# normal : normal
# makasih : makasih
# jaya : jaya
# dituban : tuban
# woooyyy : woooyyy
# kang : kang
# kipak : kipak
# ngehe : ngehe
# akhlak : akhlak
# ujan : ujan
# sekrng : sekrng
# salah : salah
# kelebihan : lebih
# sekeliling : keliling
# menara : menara
# terancam : ancam
# nyawanya : nyawa
# genangan : genang
# air : air
# area : area
# perhatikan : perhati
# bayar : bayar
# besok : besok
# tempo : tempo
# bnget : bnget
# gunain : gunain
# giliran : gilir
# menonaktifkan : nonaktif
# kapa : kapa
# produk : produk
# wooiii : wooiii
# bos : bos
# aduh : aduh
# sumpah : sumpah
# aplikasinya : aplikasi
# cepat : cepat
# fastttt : fastttt
# nyedot : nyedot
# pokoknya : pokok
# benerin : benerin
# jancok : jancok
# hasilnya : hasil
# nihil : nihil
# hargaain : hargaain
# usaha : usaha
# psti : psti
# pnya : pnya
# kelemahan : lemah
# insaallah : insaallah
# masalahx : masalahx
# dislesaikan : dislesaikan
# strong : strong
# truss : truss
# murahin : murahin
# sel : sel
# kemarin : kemarin
# laporan : lapor
# hpq : hpq
# terkirim : kirim
# berkurang : kurang
# tujuan : tuju
# gudal : gudal
# sinyale : sinyale
# telek : telek
# malam : malam
# siput : siput
# perbatikan : bati
# alat : alat
# tembah : tembah
# canggih : canggih
# karna : karna
# mayoritas : mayoritas
# jateng : jateng
# kudus : kudus
# menangis : menang
# sihh : sihh
# mencakup : cakup
# kemana : mana
# pelosok : pelosok
# bogor : bogor
# dutdutan : dutdutan
# ngak : ngak
# kenap : kenap
# telkomselku : telkomselku
# ribet : ribet
# lokasi : lokasi
# bgmn : bgmn
# petugas : tugas
# lokasih : lokasih
# bungoro : bungoro
# pangkep : pangkep
# kampung : kampung
# gatta : gatta
# gattareng : gattareng
# taraweang : taraweang
# ingatkan : ingat
# harap : harap
# tangani : tangan
# surabaya : surabaya
# kota : kota
# kediri : diri
# yutube : yutube
# games : games
# otomatis : otomatis
# matikan : mati
# reguler : reguler
# cepet : cepet
# pemberitahuan : pemberitahuan
# trims : trims
# anjaaaay : anjaaaay
# bangeeeet : bangeeeet
# rumah : rumah
# hnya : hnya
# mtr : mtr
# kalah : kalah
# oprator : oprator
# lein : lein
# jaraknya : jarak
# anggap : anggap
# ancur : ancur
# gausah : gausah
# ngurusi : ngurusi
# merata : rata
# baguss : baguss
# gmna : gmna
# mengembalikan : kembali
# alimitit : alimitit
# pelit : pelit
# byk : byk
# php : php
# tim : tim
# nonton : nonton
# acara : acara
# televisi : televisi
# meningkat : tingkat
# iklan : iklan
# nany : nany
# pintasan : pintas
# special : special
# for : for
# you : you
# hilangkan : hilang
# masak : masak
# bosku : bos
# maxstream : maxstream
# netflix : netflix
# ngecek : ngecek
# nomor : nomor
# gimna : gimna
# selamat : selamat
# hidul : hidul
# pandang : pandang
# kitapun : kita
# berkat : berkat
# buang : buang
# anak : anak
# sekolah : sekolah
# kek : kek
# unlimitedmax : unlimitedmax
# gb : gb
# blum : blum
# dpet : dpet
# tgl : tgl
# telkuntul : telkuntul
# kentod : kentod
# balikin : balikin
# kgk : kgk
# yiba : yiba
# gamemax : gamemax
# fear : fear
# nich : nich
# gamesmax : gamesmax
# super : super
# murah : murah
# negri : negri
# tekomsel : tekomsel
# nyaman : nyaman
# makai : maka
# ribu : ribu
# mhal : mhal
# bngt : bngt
# transfer : transfer
# jaringa : jaringa
# hubungi : hubung
# keluarga : keluarga
# sinyallnya : sinyallnya
# kasihan : kasihan
# tinggal : tinggal
# hadeh : hadeh
# terpaksa : paksa
# dpt : dpt
# notif : notif
# combo : combo
# sakti : sakti
# rb : rb
# hujan : hujan
# magrib : magrib
# sampah : sampah
# deket : deket
# bget : bget
# males : males
# deh : deh
# pokonya : poko
# ngecewain : ngecewain
# kuotanya : kuota
# koq : koq
# keceng : keceng
# edge : edge
# rumahku : rumah
# dket : dket
# tlkmsl : tlkmsl
# hadehhh : hadehhh
# sinyalle : sinyalle
# burig : burig
# jaring : jaring
# gampang : gampang
# hadehhhh : hadehhhh
# kewikayah : kewikayah
# utama : utama
# kesodot : kesodot
# pdhal : pdhal
# menonton : tonton
# terpakai : pakai
# duluan : duluan
# next : next
# time : time
# benci : benci
# bet : bet
# keluhkan : keluh
# dmn : dmn
# taun : taun
# ucapkan : ucap
# selhruh : selhruh
# lembaga : lembaga
# pemerintahan : perintah
# kalondama : kalondama
# tercinta : cinta
# dapst : dapst
# adil : adil
# jujur : jujur
# melagani : lagan
# wajib : wajib
# call : call
# centre : centre
# normalin : normalin
# klu : klu
# nelpon : nelpon
# suara : suara
# whatsapp : whatsapp
# dihapus : hapus
# memerlukannya : perlu
# pket : pket
# pda : pda
# surprise : surprise
# deal : deal
# max : max
# jaringgan : jaringgan
# leleet : leleet
# pecuma : cuma
# hai : hai
# bip : bip
# burik : burik
# tlkmtol : tlkmtol
# woy : woy
# setia : setia
# pribadi : pribadi
# anjim : anjim
# minjam : minjam
# blh : blh
# kmaren : kmaren
# pasang : pasang
# registrasi : registrasi
# memiliki : milik
# solusi : solusi
# maki : maki
# pelayanan : layan
# jakarta : jakarta
# kog : kog
# tel : tel
# cel : cel
# nyesel : nyesel
# bli : bli
# salam : salam
# tgh : tgh
# malamnya : malam
# dihilangin : dihilangin
# robotnya : robot
# duit : duit
# lemmot : lemmot
# pakek : pakek
# hp : hp
# promosi : promosi
# endors : endors
# ajukan : aju
# pinjaman : pinjam
# terbukti : bukti
# cair : cair
# setelh : setelh
# krim : krim
# suru : suru
# nunggu : nunggu
# menit : menit
# alhamdulillah : alhamdulillah
# tampa : tampa
# potongan : potong
# minat : minat
# hub : hub
# baang : baang
# krimin : krimin
# gratisannya : gratis
# bnyak : bnyak
# njirt : njirt
# wkwkwk : wkwkwk
# hhhhh : hhhhh
# bnar : bnar
# kmu : kmu
# blilang : blilang
# pemanen : panen
# adakak : adakak
# pilih : pilih
# please : please
# kenceng : kenceng
# btullll : btullll
# mendaftar : daftar
# kouta : kouta
# belajar : ajar
# beruntung : untung
# membantu : bantu
# komunikasi : komunikasi
# terluas : luas
# membawa : bawa
# maju : maju
# jringan : jringan
# benahi : benah
# bismillah : bismillah
# bantuan : bantu
# bantu : bantu
# oke : oke
# gratis : gratis
# donk : donk
# kehabisan : habis
# hei : hei
# lvyuu : lvyuu
# plisss : plisss
# kntlllll : kntlllll
# mimin : mimin
# konsisten : konsisten
# very : very
# ll : ll
# upgreade : upgreade
# ktp : ktp
# surat : surat
# keterangan : terang
# hrd : hrd
# kantor : kantor
# spt : spt
# ttg : ttg
# muter : muter
# skrng : skrng
# menggelegar : gelegar
# tarif : tarif
# jarang : jarang
# pegunungan : gunung
# pancar : pancar
# looh : looh
# emang : emang
# kelen : kelen
# sementang : sementang
# sma : sma
# tny : tny
# uda : uda
# tenggang : tenggang
# hlg : hlg
# msh : msh
# tlg : tlg
# kebijaksanaan : bijaksana
# sengaja : sengaja
# lupa : lupa
# isi : isi
# bnyk : bnyk
# pembohongggg : pembohongggg
# pngumuman : pngumuman
# undian : undi
# lucky : lucky
# poin : poin
# tnggl : tnggl
# adakan : adakan
# program : program
# selesaikn : selesaikn
# pelanggan : langgan
# mainan : main
# taiii : taiii
# disesuaikan : sesuai
# sebelah : belah
# lampu : lampu
# ceritanya : cerita
# terimakasih : terimakasih
# fasilitasi : fasilitas
# terbaikmu : baik
# dlm : dlm
# sikon : sikon
# apapun : apa
# banyakin : banyakin
# ivent : ivent
# gajelas : gajelas
# cape : cape
# komplein : komplein
# pengumuman : umum
# pemenang : menang
# point : point
# sebagus : bagus
# mahalnya : mahal
# jlek : jlek
# mnta : mnta
# proses : proses
# pening : pening
# nda : nda
# siang : siang
# tooook : tooook
# urus : urus
# kualiyas : kualiyas
# yng : yng
# skarang : skarang
# dibeli : beli
# ditaiwan : ditaiwan
# menipu : tipu
# dibalikkin : dibalikkin
# jaik : jaik
# devy : devy
# kartia : kartia
# menyesal : sesal
# rejekimu : rejekimu
# memadai : pada
# jalur : jalur
# pemasangan : pasang
# kontak : kontak
# live : live
# agent : agent
# paketannya : paket
# menunggu : tunggu
# mbahhh : mbahhh
# dipake : dipake
# sosmed : sosmed
# browsing : browsing
# skrang : skrang
# mandet : mandet
# minggu : minggu
# kmrin : kmrin
# jarigan : jarigan
# benua : benua
# lawas : lawas
# tanah : tanah
# laut : laut
# gara : gara
# kena : kena
# perubahan : ubah
# sistem : sistem
# vocher : vocher
# omg : omg
# met : met
# dengerin : dengerin
# konsumen : konsumen
# ngeluh : ngeluh
# dilaksanain : dilaksanain
# kustomer : kustomer
# paham : paham
# tanggal : tanggal
# info : info
# draw : draw
# kabarnya : kabar
# tolonglah : tolong
# online : online
# beres : beres
# apl : apl
# transaksi : transaksi
# hadeehhhhhh : hadeehhhhhh
# pernh : pernh
# layanan : layan
# aktif : aktif
# iya : iya
# video : video
# perduli : duli
# mariya : mariya
# terkait : kait
# mengacu : acu
# besaran : besar
# biaya : biaya
# pengeluran : pengeluran
# berbeda : beda
# akibat : akibat
# berbedanya : beda
# komponen : komponen
# dibutuhkan : butuh
# menggelar : gelar
# infrastruktur : infrastruktur
# maksud : maksud
# mnghina : mnghina
# merendahkan : rendah
# mnyampai : mnyampai
# prnah : prnah
# mnjadi : mnjadi
# kluhan : kluhan
# krna : krna
# berkali : kali
# kli : kli
# prihal : prihal
# mendapatkn : mendapatkn
# memuaskan : muas
# terbantu : bantu
# han : han
# becanda : becanda
# gtw : gtw
# sisa : sisa
# pengen : ken
# nang : nang
# kebumen : kebumen
# mlepek : mlepek
# ora : ora
# mlebu : mlebu
# lik : lik
# arep : arep
# tilik : tilik
# mbok : mbok
# nyong : nyong
# dadi : dadi
# mercy : mercy
# blas : blas
# ket : ket
# biyen : biyen
# sing : sing
# jenenge : jenenge
# melu : melu
# ana : ana
# nyangkut : nyangkut
# stuck : stuck
# only : only
# posingam : posingam
# tanggepin : tanggepin
# telegram : telegram
# topik : topik
# menyuruh : suruh
# meluncur : luncur
# peningkatan : tingkat
# disitu : situ
# sedih : sedih
# dipanggang : panggang
# berlangganan : langgan
# wow : wow
# sungguh : sungguh
# mantablah : mantablah
# jdi : jdi
# kecepatannya : cepat
# sabgat : sabgat
# kencang : kencang
# kya : kya
# gni : gni
# satunya : satu
# gue : gue
# voucher : voucher
# tulisannya : tulis
# belasan : bas
# masukin : masukin
# segi : segi
# bintang : bintang
# kualitasnya : kualitas
# kegiatan : giat
# berbasis : bas
# tertunda : tunda
# menjengkelkan : jengkel
# the : the
# best : best
# pulsaku : pulsa
# terpotong : potong
# simcard : simcard
# taruh : taruh
# sim : sim
# pengaturan : atur
# setting : setting
# non : non
# jawabanmu : jawab
# beratnya : berat
# responnya : responnya
# jawaranya : jawara
# mode : mode
# plz : plz
# ribuan : ribu
# hangus : hangus
# tutorialnya : tutorial
# sobat : sobat
# ponsel : ponsel
# pengeluaran : keluar
# dibatasi : batas
# bangat : bangat
# modol : modol
# something : something
# thing : thing
# keurus : urus
# kopet : kopet
# bisanya : bisa
# nge : nge
# net : net
# jariangan : jariangan
# butuh : butuh
# mnt : mnt
# unlimeted : unlimeted
# stiap : stiap
# darurat : darurat
# cikarang : cikarang
# galau : galau
# brosis : bros
# ternama : nama
# profesional : profesional
# rating : rating
# playstore : playstore
# event : event
# brni : brni
# pgn : pgn
# nyari : nyari
# sgni : sgni
# doank : doank
# push : push
# rank : rank
# ms : ms
# kyk : kyk
# ush : ush
# koment : koment
# robot : robot
# sni : sni
# berentila : berentila
# meli : mel
# mcm : mcm
# taik : taik
# percumah : percumah
# bkn : bkn
# diutan : diutan
# robohkan : roboh
# bae : bae
# paksa : paksa
# saking : saking
# valentino : valentino
# rossi : rossi
# kesalip : salip
# buyy : buyy
# day : day
# situ : situ
# kebeli : kebel
# ketarik : tarik
# kedepan : depan
# kelain : lain
# hati : hati
# kaliii : kaliii
# merugikan : rugi
# mengerorkan : eror
# bisah : bisah
# beroprasi : beroprasi
# posting : posting
# jga : jga
# liat : liat
# shopee : shopee
# dahh : dahh
# pliss : pliss
# {'telkomsel': 'telkomsel', 'parah': 'parah', 'banget': 'banget', 'udah': 'udah', 'sebulanan': 'bulan', 'sinyal': 'sinyal', 'jelek': 'jelek', 'mending': 'mending', 'pindah': 'pindah', 'provider': 'provider', '': '', 'forji': 'forji', 'jiji': 'jiji', 'buruk': 'buruk', 'jaringannya': 'jaring', 'terkena': 'kena', 'dampak': 'dampak', 'signal': 'signal', 'lemoooott': 'lemoooott', 'sukabumi': 'sukabumi', 'kacauu': 'kacauu', 'ahh': 'ahh', 'maen': 'maen', 'game': 'game', 'stabill': 'stabill', 'mohon': 'mohon', 'perbaikannya': 'baik', 'secepatnya': 'cepat', 'knpa': 'knpa', 'koneksi': 'koneksi', 'internet': 'internet', 'kec': 'kec', 'pelepat': 'lepat', 'ilir': 'ilir', 'kuamang': 'amang', 'kuning': 'kuning', 'kab': 'kab', 'bungo': 'bungo', 'prov': 'prov', 'jambi': 'jambi', 'susah': 'susah', 'akses': 'akses', 'trimakasih': 'trimakasih', 'kabupaten': 'kabupaten', 'bharat': 'bharat', 'kecamatan': 'camat', 'sukramai': 'sukramai', 'tolong': 'tolong', 'perbaiki': 'baik', 'jarinan': 'jarinan', 'telkoselnya': 'telkoselnya', 'ane': 'ane', 'doain': 'doain', 'moga': 'moga', 'kali': 'kali', 'gedung': 'gedung', 'terbakar': 'bakar', 'hancur': 'hancur', 'lebur': 'lebur', 'jaringan': 'jaring', 'bagus': 'bagus', 'weh': 'weh', 'veronika': 'veronika', 'serang': 'serang', 'banten': 'banten', 'signalnya': 'signalnya', 'hilang': 'hilang', 'kuntul': 'kuntul', 'abis': 'abis', 'update': 'update', 'login': 'login', 'terdampak': 'dampak', 'bencanapun': 'bencana', 'beli': 'beli', 'paket': 'paket', 'midnight': 'midnight', 'tpi': 'tpi', 'suruh': 'suruh', 'kode': 'kode', 'verifikasinya': 'verifikasi', 'kirim': 'kirim', 'diperbaiki': 'baik', 'lgi': 'lgi', 'min': 'min', 'sulawesi': 'sulawesi', 'tenggara': 'tenggara', 'berat': 'berat', 'seberat': 'berat', 'kontainer': 'kontainer', 'khusus': 'khusus', 'wilayah': 'wilayah', 'kapontori': 'kapontori', 'perbaikan': 'baik', 'sajen': 'sajen', 'didaerah': 'daerah', 'mlh': 'mlh', 'sinyalnya': 'sinyal', 'seminggu': 'minggu', 'kemaren': 'kemaren', 'full': 'full', 'payah': 'payah', 'lahat': 'lahat', 'sumatera': 'sumatera', 'selatan': 'selatan', 'cek': 'cek', 'lag': 'lag', 'main': 'main', 'ping': 'ping', 'suka': 'suka', 'beda': 'beda', 'kyak': 'kyak', 'dlu': 'dlu', 'paketan': 'paket', 'mahal': 'mahal', 'sesuai': 'sesuai', 'yaaa': 'yaaa', 'terkadang': 'terkadang', 'putus': 'putus', 'nyambung': 'nyambung', 'bgus': 'bgus', 'signalx': 'signalx', 'dperbaiki': 'dperbaiki', 'yaa': 'yaa', 'semalam': 'malam', 'gitu': 'gitu', 'kuota': 'kuota', 'maaf': 'maaf', 'mengganggu': 'ganggu', 'plm': 'plm', 'jarinya': 'jari', 'setabil': 'setabil', 'kondisikan': 'kondisi', 'trimks': 'trimks', 'mbaca': 'mbaca', 'komentar': 'komentar', 'flores': 'flores', 'ntt': 'ntt', 'kecamata': 'kecamata', 'rahong': 'rahong', 'utara': 'utara', 'jaringanya': 'jaringanya', 'dimna': 'dimna', 'bencana': 'bencana', 'dsitu': 'dsitu', 'bacod': 'bacod', 'cari': 'cari', 'muka': 'muka', 'sadar': 'sadar', 'sluruh': 'sluruh', 'indonesia': 'indonesia', 'ngalamin': 'ngalamin', 'khancuran': 'khancuran', 'kak': 'kak', 'bot': 'bot', 'knapa': 'knapa', 'gangguan': 'ganggu', 'masal': 'masal', 'berhari': 'hari', 'tah': 'tah', 'rusaknya': 'rusak', 'sinyl': 'sinyl', 'lola': 'lola', 'mintak': 'mintak', 'ampun': 'ampun', 'kecepatan': 'cepat', 'rendah': 'rendah', 'udh': 'udh', 'thn': 'thn', 'pakai': 'pakai', 'kesini': 'kesini', 'loyoo': 'loyoo', 'masuk': 'masuk', 'apk': 'apk', 'error': 'error', 'gabisa': 'gabisa', 'reinstall': 'reinstall', 'gimana': 'gimana', 'coba': 'coba', 'gua': 'gua', 'melewati': 'lewat', 'lemotnya': 'lot', 'indah': 'indah', 'miip': 'miip', 'idi': 'idi', 'piningkitin': 'piningkitin', 'piliyinin': 'piliyinin', 'jiringin': 'jiringin', 'kelar': 'kelar', 'woi': 'woi', 'feedback': 'feedback', 'trosss': 'trosss', 'dibilang': 'bilang', 'blm': 'blm', 'dananya': 'dana', 'perbaikin': 'perbaikin', 'klau': 'klau', 'ngerii': 'ngeri', 'desa': 'desa', 'sedan': 'sedan', 'rembang': 'rembang', 'jawa': 'jawa', 'telkomselnya': 'telkomselnya', 'respon': 'respon', 'kaltim': 'kaltim', 'jam': 'jam',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/348 [00:00<?, ?it/s]
#                                                comment  \
# 0    telkomsel sekarang parah banget, udah sebulana...
# 1    ini forji bikin jiji, 2021 makin buruk lu jari...
# 2          semua juga terkena dampak. signal lemoooott
# 3    sukabumi kacauu ahh.. maen game gk stabill .. ...
# 4    knpa koneksi internet kec, pelepat ilir kuaman...
# ..                                                 ...
# 452  min ko kode voucher yang saya beli tidak bisa ...
# 453                               lu becanda yah tsel?
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min, tapi gmna liat aja sin...
# 456  min mau tanya.. ini yang unlimited nya bisa bu...
#
#                                       cleaning_comment  \
# 0    telkomsel sekarang parah banget udah sebulanan...
# 1      ini forji bikin jiji   makin buruk jaringannya
# 2           semua juga terkena dampak signal lemoooott
# 3    sukabumi kacauu ahh maen game stabill mohon pe...
# 4    knpa koneksi internet kec pelepat ilir kuamang...
# ..                                                 ...
# 452   min kode voucher yang saya beli tidak bisa masuk
# 453                                  becanda yah tsel
# 454  percuma karena harus ada paket utama baru bisa...
# 455  pengen posting jga min tapi gmna liat aja siny...
# 456  min mau tanya ini yang unlimited nya bisa buat...
#
#                                             tokenisasi  \
# 0    [telkomsel, sekarang, parah, banget, udah, seb...
# 1    [ini, forji, bikin, jiji, makin, buruk, jaring...
# 2    [semua, juga, terkena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, pelepat, ilir, ...
# ..                                                 ...
# 452  [min, kode, voucher, yang, saya, beli, tidak, ...
# 453                           [, becanda, yah, tsel, ]
# 454  [percuma, karena, harus, ada, paket, utama, ba...
# 455  [pengen, posting, jga, min, tapi, gmna, liat, ...
# 456  [min, mau, tanya, ini, yang, unlimited, nya, b...
#
#                                               stopword  \
# 0    [telkomsel, parah, banget, udah, sebulanan, si...
# 1                  [forji, jiji, buruk, jaringannya, ]
# 2                 [terkena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, pelepat, ilir, ...
# ..                                                 ...
# 452                  [min, kode, voucher, beli, masuk]
# 453                                [, becanda, tsel, ]
# 454                   [paket, utama, bisah, beroprasi]
# 455    [pengen, posting, jga, min, gmna, liat, sinyal]
# 456  [min, unlimited, buka, shopee, dahh, kaga, pliss]
#
#                                               stemming
# 0    [telkomsel, parah, banget, udah, bulan, sinyal...
# 1                       [forji, jiji, buruk, jaring, ]
# 2                    [kena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, lepat, ilir, am...
# ..                                                 ...
# 452                  [min, kode, voucher, beli, masuk]
# 453                                [, becanda, tsel, ]
# 454                   [paket, utama, bisah, beroprasi]
# 455       [ken, posting, jga, min, gmna, liat, sinyal]
# 456  [min, unlimited, buka, shopee, dahh, kaga, pliss]
#
# [348 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [telkomsel, parah, banget, udah, bulan, sinyal...
# 1                       [forji, jiji, buruk, jaring, ]
# 2                    [kena, dampak, signal, lemoooott]
# 3    [sukabumi, kacauu, ahh, maen, game, stabill, m...
# 4    [knpa, koneksi, internet, kec, lepat, ilir, am...
# ..                                                 ...
# 452                  [min, kode, voucher, beli, masuk]
# 453                                [, becanda, tsel, ]
# 454                   [paket, utama, bisah, beroprasi]
# 455       [ken, posting, jga, min, gmna, liat, sinyal]
# 456  [min, unlimited, buka, shopee, dahh, kaga, pliss]
#
# [348 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_1.xlsx')
