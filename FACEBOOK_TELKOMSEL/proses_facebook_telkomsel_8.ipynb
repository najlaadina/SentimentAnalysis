# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                    *363# gangguan,  segera perbaikan
# 1    Sidang Tahunan MPR, 16 Agustus 2021, Konvensi ...
# 2                               Telkomsel kartu sultan
# 3    Pembelian koin untuk joylada sudah terkonfirma...
# 4    Dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  Solusinya pindah ke vropaider lain . Karena te...
# 363                               Ada kuota gratis kaa
# 364                           Dari 4G ke H biasa keong
# 365                 Rame² kasih rating ★1 di playstore
# 366  Nggak ada paket internet gratis min sambut ula...
#
# [367 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                    *363# gangguan,  segera perbaikan
# 1    Sidang Tahunan MPR, 16 Agustus 2021, Konvensi ...
# 2                               Telkomsel kartu sultan
# 3    Pembelian koin untuk joylada sudah terkonfirma...
# 4    Dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  Solusinya pindah ke vropaider lain . Karena te...
# 363                               Ada kuota gratis kaa
# 364                           Dari 4G ke H biasa keong
# 365                 Rame² kasih rating ★1 di playstore
# 366  Nggak ada paket internet gratis min sambut ula...
#
# [364 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                    *363# gangguan,  segera perbaikan
# 1    sidang tahunan mpr, 16 agustus 2021, konvensi ...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  solusinya pindah ke vropaider lain . karena te...
# 363                               ada kuota gratis kaa
# 364                           dari 4g ke h biasa keong
# 365                 rame² kasih rating ★1 di playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
# [364 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                    *363# gangguan,  segera perbaikan
# 1    sidang tahunan mpr, 16 agustus 2021, konvensi ...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  solusinya pindah ke vropaider lain . karena te...
# 363                               ada kuota gratis kaa
# 364                           dari 4g ke h biasa keong
# 365                 rame² kasih rating ★1 di playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                       cleaning_comment
# 0                            gangguan segera perbaikan
# 1    sidang tahunan mpr agustus   konvensi ketatane...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa malah gabisa mana pulsa a...
# ..                                                 ...
# 362  solusinya pindah vropaider lain karena telekom...
# 363                               ada kuota gratis kaa
# 364                                   dari biasa keong
# 365                        rame kasih rating playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
# [364 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                    *363# gangguan,  segera perbaikan
# 1    sidang tahunan mpr, 16 agustus 2021, konvensi ...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  solusinya pindah ke vropaider lain . karena te...
# 363                               ada kuota gratis kaa
# 364                           dari 4g ke h biasa keong
# 365                 rame² kasih rating ★1 di playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                       cleaning_comment  \
# 0                            gangguan segera perbaikan
# 1    sidang tahunan mpr agustus   konvensi ketatane...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa malah gabisa mana pulsa a...
# ..                                                 ...
# 362  solusinya pindah vropaider lain karena telekom...
# 363                               ada kuota gratis kaa
# 364                                   dari biasa keong
# 365                        rame kasih rating playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                             tokenisasi
# 0                      [, gangguan, segera, perbaikan]
# 1    [sidang, tahunan, mpr, agustus, konvensi, keta...
# 2                           [telkomsel, kartu, sultan]
# 3    [pembelian, koin, untuk, joylada, sudah, terko...
# 4    [dahlah, dah, isi, pulsa, malah, gabisa, mana,...
# ..                                                 ...
# 362  [solusinya, pindah, vropaider, lain, karena, t...
# 363                          [ada, kuota, gratis, kaa]
# 364                               [dari, biasa, keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, ada, paket, internet, gratis, min, sam...
#
# [364 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                    *363# gangguan,  segera perbaikan
# 1    sidang tahunan mpr, 16 agustus 2021, konvensi ...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  solusinya pindah ke vropaider lain . karena te...
# 363                               ada kuota gratis kaa
# 364                           dari 4g ke h biasa keong
# 365                 rame² kasih rating ★1 di playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                       cleaning_comment  \
# 0                            gangguan segera perbaikan
# 1    sidang tahunan mpr agustus   konvensi ketatane...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa malah gabisa mana pulsa a...
# ..                                                 ...
# 362  solusinya pindah vropaider lain karena telekom...
# 363                               ada kuota gratis kaa
# 364                                   dari biasa keong
# 365                        rame kasih rating playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                             tokenisasi  \
# 0                      [, gangguan, segera, perbaikan]
# 1    [sidang, tahunan, mpr, agustus, konvensi, keta...
# 2                           [telkomsel, kartu, sultan]
# 3    [pembelian, koin, untuk, joylada, sudah, terko...
# 4    [dahlah, dah, isi, pulsa, malah, gabisa, mana,...
# ..                                                 ...
# 362  [solusinya, pindah, vropaider, lain, karena, t...
# 363                          [ada, kuota, gratis, kaa]
# 364                               [dari, biasa, keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, ada, paket, internet, gratis, min, sam...
#
#                                               stopword
# 0                              [, gangguan, perbaikan]
# 1    [sidang, tahunan, mpr, agustus, konvensi, keta...
# 2                           [telkomsel, kartu, sultan]
# 3    [pembelian, koin, joylada, terkonfirmasi, tsel...
# 4            [dahlah, isi, pulsa, gabisa, pulsa, abis]
# ..                                                 ...
# 362  [solusinya, pindah, vropaider, telekomsel, tar...
# 363                               [kuota, gratis, kaa]
# 364                                            [keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, paket, internet, gratis, min, sambut, ...
#
# [364 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1020
# ------------------------
#  :
# gangguan : ganggu
# perbaikan : baik
# sidang : sidang
# tahunan : tahun
# mpr : mpr
# agustus : agustus
# konvensi : konvensi
# ketatanegaraan : ketatanegaraan
# rangka : rangka
# laporan : lapor
# kinerja : kerja
# lembaga : lembaga
# negara : negara
# telkomsel : telkomsel
# kartu : kartu
# sultan : sultan
# pembelian : beli
# koin : koin
# joylada : joylada
# terkonfirmasi : konfirmasi
# tsel : tsel
# masuk : masuk
# gimana : gimana
# dahlah : dah
# isi : isi
# pulsa : pulsa
# gabisa : gabisa
# abis : abis
# harga : harga
# kuota : kuota
# mahal : mahal
# promo : promo
# udah : udah
# veronika : veronika
# meresahkan : resah
# penjelasan : jelas
# arti : arti
# lambang : lambang
# pramuka : pramuka
# tunas : tunas
# kelapa : kelapa
# diperingati : ingat
# tanggal : tanggal
# balikin : balikin
# min : min
# dahalah : dahalah
# bnyak : bnyak
# skli : skli
# kendala : kendala
# telkom : telkom
# akses : akses
# ndi : ndi
# opratore : opratore
# gen : gen
# dudohi : dudohi
# daerahku : daerah
# jaringane : jaringane
# ruwet : ruwet
# error : error
# perbaiki : baik
# woi : woi
# beli : beli
# paketan : paket
# susah : susah
# benerin : benerin
# ngapa : ngapa
# hay : hay
# baga : baga
# paket : paket
# aplikasi : aplikasi
# terganggu : ganggu
# parah : parah
# mbokde : mbokde
# pakde : pakde
# kek : kek
# gini : gin
# gmna : gmna
# kode : kode
# dial : dial
# eniqs : eniqs
# bkl : bkl
# jelasin : jelasin
# sembelit : sembelit
# jdi : jdi
# ganguan : ganguan
# kota : kota
# demak : demak
# jateng : jateng
# unlimitedmax : unlimitedmax
# sombong : sombong
# mnh : mnh
# provider : provider
# sampah : sampah
# maunya : mau
# giliran : gilir
# internet : internet
# ngga : ngga
# nonton : nonton
# make : make
# mode : mode
# gratis : gratis
# tetangga : tetangga
# love : love
# you : you
# tolong : tolong
# inih : inih
# gmn : gmn
# trs : trs
# maaf : maaf
# nanya : nanya
# mengubah : ubah
# game : game
# regular : regular
# gua : gua
# masukin : masukin
# kouta : kouta
# voucher : voucher
# tpi : tpi
# sibuk : sibuk
# buruk : buruk
# tgl : tgl
# juni : juni
# kali : kali
# komplain : komplain
# jaringan : jaring
# sampek : sampek
# nyata : nyata
# episode : episode
# virus : virus
# binatang : binatang
# salah : salah
# episodenya : episode
# skrg : skrg
# alamin : alamin
# yaaa : yaaa
# tuker : tuker
# sinyal : sinyal
# lag : lag
# jancokkk : jancokkk
# unlimited : unlimited
# max : max
# seharga : harga
# rb : rb
# unlimitednya : unlimitednya
# pacar : pacar
# kenceng : kenceng
# bnget : bnget
# sinyalnya : sinyal
# deket : deket
# tower : tower
# hahaha : hahaha
# hayuk : hayuk
# jancokk : jancokk
# suu : suu
# anjai : anja
# orang : orang
# masihi : masih
# taik : taik
# warna : warna
# ungu : ungu
# pinjam : pinjam
# lemot : lot
# banget : banget
# hai : hai
# yuk : yuk
# support : support
# pendidikan : didik
# santri : santri
# penghafal : hafal
# alquran : alquran
# sepuluh : puluh
# ribu : ribu
# bantu : bantu
# donasi : donasi
# klik : klik
# turun : turun
# turunkan : turun
# malam : malam
# gb : gb
# play : play
# disneyhostar : disneyhostar
# giga : giga
# payaaaaah : payaaaaah
# dasarrr : dasarrr
# pegang : pegang
# order : order
# hilang : hilang
# karna : karna
# dri : dri
# pagi : pagi
# buta : buta
# samapai : samapai
# becus : becus
# pindah : pindah
# telkomnyet : telkomnyet
# amoas : amoas
# kasih : kasih
# ngelunjak : ngelunjak
# otw : otw
# pinda : pinda
# gunanya : guna
# sisa : sisa
# disneyhotstar : disneyhotstar
# dijalan : jalan
# cepet : cepet
# sugih : sugih
# kowe : kowe
# tel : tel
# teleleek : teleleek
# admim : admim
# menyadari : sadar
# keluhan : keluh
# user : user
# kadang : kadang
# maksud : maksud
# bayar : bayar
# utang : utang
# diambil : ambil
# ambil : ambil
# sebulan : bulan
# daerah : daerah
# jelek : jelek
# njingan : njingan
# kagga : kagga
# bsa : bsa
# pket : pket
# dlu : dlu
# noh : noh
# mind : mind
# naikin : naikin
# paketannya : paket
# kesini : kesini
# betulin : betulin
# bos : bos
# jingan : jingan
# focer : focer
# enggk : enggk
# ramai : ramai
# operator : operator
# menawarkan : tawar
# murah : murah
# kualitas : kualitas
# daftarin : daftarin
# penuh : penuh
# jalan : jalan
# ilang : ilang
# timbul : timbul
# cape : cape
# bgini : bgini
# hhaha : hhaha
# kencengan : kenceng
# nak : nak
# skolah : skolah
# paketny : paketny
# gue : gue
# pelanggan : langgan
# ribet : ribet
# tin : tin
# prov : prov
# jambi : jambi
# kab : kab
# tebo : tebo
# kec : kec
# muara : muara
# tabir : tabir
# desa : desa
# sei : sei
# jernih : jernih
# cok : cok
# oake : oake
# mengecewakan : kecewa
# semalem : semalem
# pakai : pakai
# wifi : wifi
# mulu : mulu
# kerjaan : kerja
# padat : padat
# telkomtod : telkomtod
# nomor : nomor
# nelpon : nelpon
# nerima : nerima
# tlpon : tlpon
# solusinya : solusi
# doank : doank
# gangguang : gangguang
# tanggapi : tanggap
# keras : keras
# kapala : kapala
# koment : koment
# admin : admin
# mengarahkan : arah
# veronica : veronica
# kak : kak
# ruangan : ruang
# kog : kog
# berwarna : warna
# pink : pink
# nihh : nihh
# kecewa : kecewa
# emosi : emosi
# cuk : cuk
# antiludes : antiludes
# eror : eror
# dompet : dompet
# huhuhu : huhuhu
# udahlah : udahlah
# bubarkan : bubar
# jaringannya : jaring
# kemaren : kemaren
# malem : malem
# ngeluh : ngeluh
# disuruh : suruh
# restart : restart
# berhenti : henti
# menganga : nganga
# lihat : lihat
# hpnya : hpnya
# emangnye : emangnye
# bagus : bagus
# nha : nha
# mun : mun
# maen : maen
# sok : sok
# ngelag : ngelag
# berpikir : pikir
# memutuskan : putus
# ganti : ganti
# knp : knp
# woy : woy
# pntk : pntk
# udh : udh
# kemarin : kemarin
# produktif : produktif
# matamu : mata
# tetaplah : tetap
# ngampas : ngampas
# menghela : hela
# napas : napas
# iya : iya
# anti : anti
# ludes : ludes
# berkurang : kurang
# ori : ori
# ato : ato
# lite : lite
# ngk : ngk
# mendukung : dukung
# ajenk : ajenk
# kebelet : kebelet
# nii : nii
# butuh : butuh
# pkt : pkt
# liaf : liaf
# kaga : kaga
# gambar : gambar
# sosmed : sosmed
# quota : quota
# terpakai : pakai
# automatis : automatis
# utama : utama
# sosmednya : sosmednya
# dipakai : pakai
# kampung : kampung
# ser : ser
# utuh : utuh
# surprise : surprise
# deal : deal
# kapa : kapa
# maketin : maketin
# woe : woe
# ampass : ampass
# cari : cari
# bejalar : bejalar
# sekarat : sekarat
# keong : keong
# ikutan : ikut
# begoh : begoh
# semoga : moga
# cepat : cepat
# bangkrut : bangkrut
# like : like
# halo : halo
# panggilan : panggil
# via : via
# seluler : seluler
# non : non
# daily : daily
# check : check
# perdana : perdana
# pas : pas
# penggunaan : guna
# tertera : tera
# kaget : kaget
# hiraukan : hirau
# mna : mna
# tipuan : tipu
# inhi : inhi
# ppkm : ppkm
# agstus : agstus
# perpanjangan : panjang
# shopee : shopee
# rakus : rakus
# tukar : tukar
# poin : poin
# kayak : kayak
# gara : gara
# kesedot : sedot
# anjg : anjg
# jngn : jngn
# ngecewain : ngecewain
# asw : asw
# fix : fix
# daftar : daftar
# rameeinn : rameeinn
# cpt : cpt
# njing : njing
# buruan : buru
# yaa : yaa
# heheeee : heheeee
# down : down
# nukar : nukar
# anjimwaktu : anjimwaktu
# masi : mas
# tod : tod
# macem : macem
# merah : merah
# buang : buang
# menu : menu
# claim : claim
# ngak : ngak
# dimasukin : dimasukin
# web : web
# diakses : akses
# ilmupedia : ilmupedia
# udemy : udemy
# skillshare : skillshare
# enak : enak
# cuman : cuman
# video : video
# sabar : sabar
# sampe : sampe
# jamuran : jamur
# ngegame : ngegame
# gajelas : gajelas
# sumpah : sumpah
# ngulang : ngulang
# refresh : refresh
# login : login
# tetep : tetep
# promonya : promonya
# astaga : astaga
# sel : sel
# bet : bet
# opm : opm
# mengadeh : adeh
# selamat : selamat
# aktivasi : aktivasi
# aktivasinya : aktivasinya
# nunggu : nunggu
# jam : jam
# tmpt : tmpt
# jrngan : jrngan
# lancar : lancar
# mlm : mlm
# smpe : smpe
# pgi : pgi
# nge : nge
# online : online
# emg : emg
# kau : kau
# pikir : pikir
# org : org
# main : main
# mikir : mikir
# tlkmsel : tlkmsel
# kta : kta
# kotor : kotor
# mulut : mulut
# musik : musik
# dengerin : dengerin
# resso : resso
# kalu : kalu
# joox : joox
# data : data
# intrnet : intrnet
# reedem : reedem
# kolektif : kolektif
# harian : hari
# dear : dear
# perihal : perihal
# nomer : nomer
# kemana : mana
# chat : chat
# sosial : sosial
# media : media
# awali : awal
# penawaran : tawar
# solusi : solusi
# dibawah : bawah
# saldo : saldo
# mlah : mlah
# yng : yng
# sungguh : sungguh
# merugikan : rugi
# pnjelasanya : pnjelasanya
# diskon : diskon
# diklaim : klaim
# sms : sms
# pembayaran : bayar
# pengisian : isi
# milik : milik
# kepotong : potong
# harganya : harga
# dimurahin : dimurahin
# lgi : lgi
# gmana : gmana
# bgi : bgi
# rakyat : rakyat
# miskin : miskin
# habis : habis
# logo : logo
# ngadat : ngadat
# jakbar : jakbar
# sistem : sistem
# menonaktifkan : nonaktif
# sya : sya
# tarik : tarik
# aktif : aktif
# barusan : barusan
# coba : coba
# message : message
# inbox : inbox
# lokasi : lokasi
# sulawesi : sulawesi
# selatan : selatan
# sinjai : sinjai
# terusin : terusin
# model : model
# alhamdulillah : alhamdulillah
# ngelatih : ngelatih
# kesabaran : sabar
# murahin : murahin
# puluhan : puluh
# dimakan : makan
# setan : setan
# trus : trus
# kb : kb
# man : man
# are : are
# kidding : kidding
# nggame : nggame
# signal : signal
# mentok : mentok
# kebanyakan : banyak
# pikirin : pikirin
# kenyamanan : nyaman
# customer : customer
# tolol : tolol
# cek : cek
# telfon : telfon
# suka : suka
# tips : tips
# ngatasin : ngatasin
# meminjam : pinjam
# ajha : ajha
# mohon : mohon
# bantuannya : bantu
# alasan : alas
# hapus : hapus
# ketengan : keteng
# youtube : youtube
# instagram : instagram
# dll : dll
# mengklaim : klaim
# tlg : tlg
# backup : backup
# listrik : listrik
# dipedalaman : dalam
# mti : mti
# mati : mati
# daring : daring
# nanjak : nanjak
# bukit : bukit
# bls : bls
# komntr : komntr
# boot : boot
# knpa : knpa
# vocer : vocer
# aktiv : aktiv
# sllu : sllu
# gote : gote
# bbrapa : bbrapa
# blm : blm
# maslah : mas
# kah : kah
# ayolah : ayo
# cepetan : cepetan
# normal : normal
# klewatan : klewatan
# ancur : ancur
# pesawat : pesawat
# lallu : lallu
# kmbli : kmbli
# arus : arus
# mod : mod
# peswat : peswat
# doang : doang
# payah : payah
# umur : umur
# cummulative : cummulative
# gliran : gliran
# gamemaxnya : gamemaxnya
# setiapplay : setiapplay
# rekonek : rekonek
# cridit : cridit
# score : score
# yutub : yutub
# hadeh : hadeh
# ngeodd : ngeodd
# utamanya : utama
# ngurang : ngurang
# ceria : ceria
# aktip : aktip
# paketin : paketin
# darurat : darurat
# yak : yak
# ubah : ubah
# nggak : nggak
# melulu : melulu
# gerangan : gerangan
# gamemax : gamemax
# bonus : bonus
# ditunggu : tunggu
# pesan : pesan
# burikkkk : burikkkk
# ngilang : ngilang
# bobrok : bobrok
# edge : edge
# ngauan : ngauan
# area : area
# jatim : jatim
# lupa : lupa
# buy : buy
# dana : dana
# keguna : guna
# dancok : dancok
# krja : krja
# promosi : promosi
# tok : tok
# hallo : hallo
# gitu : gitu
# sinyall : sinyall
# lemotttt : lemotttt
# pollll : pollll
# telaso : telaso
# sundala : sundala
# lambat : lambat
# bangetttttttttt : bangetttttttttt
# mending : mending
# tutup : tutup
# kapok : kapok
# gsm : gsm
# bye : bye
# hujan : hujan
# dikit : dikit
# nglagnya : nglagnya
# otak : otak
# dihidupin : dihidupin
# niat : niat
# minggu : minggu
# haduh : haduh
# hancur : hancur
# palingan : paling
# kepakai : pakai
# males : males
# nontonya : nontonya
# spotify : spotify
# nyedot : nyedot
# pffft : pffft
# kang : kang
# kibul : kibul
# kmi : kmi
# lampu : lampu
# registrasi : registrasi
# ngelawak : ngelawak
# pdhal : pdhal
# telkomselnya : telkomselnya
# force : force
# close : close
# dibuka : buka
# bentar : bentar
# langsung : langsung
# app : app
# merespon : merespon
# update : update
# menuhin : menuhin
# ram : ram
# aplikasinya : aplikasi
# sehat : sehat
# emang : emang
# pajang : pajang
# situ : situ
# diatas : atas
# gobloooog : gobloooog
# kencang : kencang
# burik : burik
# sengaja : sengaja
# cpat : cpat
# burikkkkk : burikkkkk
# lunasi : lunas
# sitelkomsel : sitelkomsel
# ngeles : ngeles
# ngawi : ngawi
# jawa : jawa
# timuri : timur
# muncul : muncul
# kmren : kmren
# huuuu : huuuu
# meh : meh
# piye : piye
# godblel : godblel
# impoten : impoten
# bangka : bangka
# ngaku : ngaku
# bermasalah : masalah
# ngotot : ngotot
# hape : hape
# beres : beres
# pelayanan : layan
# tingkatkan : tingkat
# parrah : parrah
# bener : bener
# lte : lte
# speednya : speednya
# segitu : segitu
# redem : redem
# numpang : numpang
# iklan : iklan
# kmna : kmna
# belajar : ajar
# robot : robot
# bicara : bicara
# aneh : aneh
# kaya : kaya
# kartunya : kartu
# telkomsell : telkomsell
# anjingg : anjingg
# gwoblokkk : gwoblokkk
# karyawan : karyawan
# makan : makan
# uang : uang
# haram : haram
# taek : taek
# in : in
# terimakasih : terimakasih
# berlangganan : langgan
# apk : apk
# vidio : vidio
# disney : disney
# hotstar : hotstar
# hoax : hoax
# pasir : pasir
# gunung : gunung
# cimanggis : cimanggis
# depok : depok
# menguna : menguna
# simpati : simpati
# tampah : tampah
# mond : mond
# plis : plis
# serius : serius
# ngerank : ngerank
# tbtb : tbtb
# airplane : airplane
# nyaman : nyaman
# uda : uda
# gtu : gtu
# kuotanya : kuota
# sebentar : sebentar
# cuiiihhhhhh : cuiiihhhhhh
# konter : konter
# blom : blom
# ancor : ancor
# kalah : kalah
# saing : saing
# sigli : sigli
# aceh : aceh
# putus : putus
# full : full
# segenap : segenap
# alam : alam
# semesta : semesta
# kondisi : kondisi
# komen : komen
# balasanya : balasanya
# perubahan : ubah
# spa : spa
# klok : klok
# paks : paks
# duanya : dua
# satunya : satu
# rank : rank
# repa : repa
# babui : babu
# kena : kena
# tenggang : tenggang
# pengunak : pengunak
# lanjutkan : lanjut
# kirim : kirim
# suprise : suprise
# please : please
# harap : harap
# hadiahnya : hadiah
# menarik : tarik
# meriah : riah
# dibagikan : bagi
# way : way
# kanan : kanan
# indah : indah
# sinyalya : sinyalya
# adapakah : adapakah
# btcnya : btcnya
# beda : beda
# merdeka : merdeka
# penipuan : tipu
# hadiah : hadiah
# anaku : ana
# dicek : cek
# dikampung : kampung
# bautnya : baut
# lepas : lepas
# biji : biji
# saking : saking
# keselnya : kesel
# sma : sma
# yes : yes
# perbaikin : perbaikin
# siput : siput
# ngisi : ngisi
# roli : rol
# rajin : rajin
# event : event
# dapet : dapet
# dsni : dsni
# hoki : hoki
# keokkk : keokkk
# rp : rp
# pemerintah : perintah
# memperhatikan : perhati
# suruh : suruh
# dirumah : rumah
# jalur : jalur
# onlinenya : onlinenya
# ngasih : ngasih
# pelajar : ajar
# tetp : tetp
# kumasia : kumasia
# anying : anying
# sesuai : sesuai
# minus : minus
# pop : pop
# nonaktifkan : nonaktif
# pemakai : pakai
# jasamu : jasa
# segini : gin
# disc : disc
# conec : conec
# sinyalmu : sinyal
# stabilkan : stabil
# trimakasih : trimakasih
# sayah : sayah
# tida : tida
# membeli : beli
# melaporkan : lapor
# proses : proses
# kembalikan : kembali
# amatir : amatir
# tri : tri
# ganteng : ganteng
# kenyang : kenyang
# terpaksa : paksa
# ehhhh : ehhhh
# kagak : kagak
# jlssss : jlssss
# minn : minn
# extra : extra
# bogor : bogor
# kakak : kakak
# tellkomsel : tellkomsel
# dunia : dunia
# sukses : sukses
# aktifin : aktifin
# hangus : hangus
# buset : buset
# pantesan : pantesan
# orderan : order
# jamping : jamping
# skg : skg
# gada : gada
# bagusnya : bagus
# sedikitpun : sedikit
# msh : msh
# bolak : bolak
# notif : notif
# indonesia : indonesia
# aduh : aduh
# trouble : trouble
# pantekkkkkkkk : pantekkkkkkkk
# mao : mao
# mengaktifkan : aktif
# gprs : gprs
# ternonaktifkan : nonaktif
# repot : repot
# prabayar : prabayar
# siang : siang
# kuning : kuning
# sore : sore
# ehk : ehk
# dasar : dasar
# iklas : iklas
# bot : bot
# terhormat : hormat
# biarpun : biarpun
# balesnya : balesnya
# gapernah : gapernah
# costumernya : costumernya
# kura : kura
# malm : malm
# ttp : ttp
# leletnya : lelet
# gokil : gokil
# gokilnya : gokilnya
# ms : ms
# sekarangan : sekarang
# hah : hah
# broo : broo
# kecepatan : cepat
# gede : gede
# halah : halah
# bacot : bacot
# yakali : yakali
# ampe : ampe
# ampun : ampun
# tagih : tagih
# ngutang : ngutang
# asyik : asyik
# ngadain : ngadain
# kuis : kuis
# facebook : facebook
# assalamu : assalamu
# alaikum : alaikum
# bang : bang
# google : google
# meet : meet
# emangnya : emang
# fungsi : fungsi
# kegunaannya : guna
# asli : asli
# loe : loe
# bodo : bodo
# kna : kna
# kyknya : kyknya
# bntuan : bntuan
# haters : haters
# rusak : rusak
# rating : rating
# playstore : playstore
# digubris : gubris
# jwb : jwb
# komentar : komentar
# bott : bott
# kayaknya : kayak
# kompak : kompak
# yukk : yukk
# ambyar : ambyar
# ditepat : tepat
# siyal : siyal
# bintang : bintang
# kedap : kedap
# ledip : ledip
# tolog : tolog
# hadeuuuuh : hadeuuuuh
# jaringanmu : jaring
# stabil : stabil
# timur : timur
# linkaja : linkaja
# sampaaaah : sampaaaah
# beralihlah : alih
# semartfren : semartfren
# murahh : murahh
# bun : bun
# ups : ups
# mayoritas : mayoritas
# ngbahas : ngbahas
# lampung : lampung
# trrnyata : trrnyata
# hmpir : hmpir
# telpon : telpon
# engga : engga
# deh : deh
# domisili : domisili
# ngen : ngen
# kalok : kalok
# mahall : mahall
# napa : napa
# gulung : gulung
# tikar : tikar
# vropaider : vropaider
# telekomsel : telekomsel
# tarip : tarip
# setabil : setabil
# ampaas : ampaas
# jelasss : jelasss
# kaa : kaa
# rame : rame
# sambut : sambut
# ulang : ulang
# republik : republik
# tunggu : tunggu
# {'': '', 'gangguan': 'ganggu', 'perbaikan': 'baik', 'sidang': 'sidang', 'tahunan': 'tahun', 'mpr': 'mpr', 'agustus': 'agustus', 'konvensi': 'konvensi', 'ketatanegaraan': 'ketatanegaraan', 'rangka': 'rangka', 'laporan': 'lapor', 'kinerja': 'kerja', 'lembaga': 'lembaga', 'negara': 'negara', 'telkomsel': 'telkomsel', 'kartu': 'kartu', 'sultan': 'sultan', 'pembelian': 'beli', 'koin': 'koin', 'joylada': 'joylada', 'terkonfirmasi': 'konfirmasi', 'tsel': 'tsel', 'masuk': 'masuk', 'gimana': 'gimana', 'dahlah': 'dah', 'isi': 'isi', 'pulsa': 'pulsa', 'gabisa': 'gabisa', 'abis': 'abis', 'harga': 'harga', 'kuota': 'kuota', 'mahal': 'mahal', 'promo': 'promo', 'udah': 'udah', 'veronika': 'veronika', 'meresahkan': 'resah', 'penjelasan': 'jelas', 'arti': 'arti', 'lambang': 'lambang', 'pramuka': 'pramuka', 'tunas': 'tunas', 'kelapa': 'kelapa', 'diperingati': 'ingat', 'tanggal': 'tanggal', 'balikin': 'balikin', 'min': 'min', 'dahalah': 'dahalah', 'bnyak': 'bnyak', 'skli': 'skli', 'kendala': 'kendala', 'telkom': 'telkom', 'akses': 'akses', 'ndi': 'ndi', 'opratore': 'opratore', 'gen': 'gen', 'dudohi': 'dudohi', 'daerahku': 'daerah', 'jaringane': 'jaringane', 'ruwet': 'ruwet', 'error': 'error', 'perbaiki': 'baik', 'woi': 'woi', 'beli': 'beli', 'paketan': 'paket', 'susah': 'susah', 'benerin': 'benerin', 'ngapa': 'ngapa', 'hay': 'hay', 'baga': 'baga', 'paket': 'paket', 'aplikasi': 'aplikasi', 'terganggu': 'ganggu', 'parah': 'parah', 'mbokde': 'mbokde', 'pakde': 'pakde', 'kek': 'kek', 'gini': 'gin', 'gmna': 'gmna', 'kode': 'kode', 'dial': 'dial', 'eniqs': 'eniqs', 'bkl': 'bkl', 'jelasin': 'jelasin', 'sembelit': 'sembelit', 'jdi': 'jdi', 'ganguan': 'ganguan', 'kota': 'kota', 'demak': 'demak', 'jateng': 'jateng', 'unlimitedmax': 'unlimitedmax', 'sombong': 'sombong', 'mnh': 'mnh', 'provider': 'provider', 'sampah': 'sampah', 'maunya': 'mau', 'giliran': 'gilir', 'internet': 'internet', 'ngga': 'ngga', 'nonton': 'nonton', 'make': 'make', 'mode': 'mode', 'gratis': 'gratis', 'tetangga': 'tetangga', 'love': 'love', 'you': 'you', 'tolong': 'tolong', 'inih': 'inih', 'gmn': 'gmn', 'trs': 'trs', 'maaf': 'maaf', 'nanya': 'nanya', 'mengubah': 'ubah', 'game': 'game', 'regular': 'regular', 'gua': 'gua', 'masukin': 'masukin', 'kouta': 'kouta', 'voucher': 'voucher', 'tpi': 'tpi', 'sibuk': 'sibuk', 'buruk': 'buruk', 'tgl': 'tgl', 'juni': 'juni', 'kali': 'kali', 'komplain': 'komplain', 'jaringan': 'jaring', 'sampek': 'sampek', 'nyata': 'nyata', 'episode': 'episode', 'virus': 'virus', 'binatang': 'binatang', 'salah': 'salah', 'episodenya': 'episode', 'skrg': 'skrg', 'alamin': 'alamin', 'yaaa': 'yaaa', 'tuker': 'tuker', 'sinyal': 'sinyal', 'lag': 'lag', 'jancokkk': 'jancokkk', 'unlimited': 'unlimited', 'max': 'max', 'seharga': 'harga', 'rb': 'rb', 'unlimitednya': 'unlimitednya', 'pacar': 'pacar', 'kenceng': 'kenceng', 'bnget': 'bnget', 'sinyalnya': 'sinyal', 'deket': 'deket', 'tower': 'tower', 'hahaha': 'hahaha', 'hayuk': 'hayuk', 'jancokk': 'jancokk', 'suu': 'suu', 'anjai': 'anja', 'orang': 'orang', 'masihi': 'masih', 'taik': 'taik', 'warna': 'warna', 'ungu': 'ungu', 'pinjam': 'pinjam', 'lemot': 'lot', 'banget': 'banget', 'hai': 'hai', 'yuk': 'yuk', 'support': 'support', 'pendidikan': 'didik', 'santri': 'santri', 'penghafal': 'hafal', 'alquran': 'alquran', 'sepuluh': 'puluh', 'ribu': 'ribu', 'bantu': 'bantu', 'donasi': 'donasi', 'klik': 'klik', 'turun': 'turun', 'turunkan': 'turun', 'malam': 'malam', 'gb': 'gb', 'play': 'play', 'disneyhostar': 'disneyhostar', 'giga': 'giga', 'payaaaaah': 'payaaaaah', 'dasarrr': 'dasarrr', 'pegang': 'pegang', 'order': 'order', 'hilang': 'hilang', 'karna': 'karna', 'dri': 'dri', 'pagi': 'pagi', 'buta': 'buta', 'samapai': 'samapai', 'becus': 'becus', 'pindah': 'pindah', 'telkomnyet': 'telkomnyet', 'amoas': 'amoas', 'kasih': 'kasih', 'ngelunjak': 'ngelunjak', 'otw': 'otw', 'pinda': 'pinda', 'gunanya': 'guna', 'sisa': 'sisa', 'disneyhotstar': 'disneyhotstar', 'dijalan': 'jalan', 'cepet': 'cepet', 'sugih': 'sugih', 'kowe': 'kowe', 'tel': 'tel', ...
# ------------------------
# Pandas Apply:   0%|          | 0/364 [00:11<?, ?it/s]
#                                                comment  \
# 0                    *363# gangguan,  segera perbaikan
# 1    sidang tahunan mpr, 16 agustus 2021, konvensi ...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa eh malah gabisa mana puls...
# ..                                                 ...
# 362  solusinya pindah ke vropaider lain . karena te...
# 363                               ada kuota gratis kaa
# 364                           dari 4g ke h biasa keong
# 365                 rame² kasih rating ★1 di playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                       cleaning_comment  \
# 0                            gangguan segera perbaikan
# 1    sidang tahunan mpr agustus   konvensi ketatane...
# 2                               telkomsel kartu sultan
# 3    pembelian koin untuk joylada sudah terkonfirma...
# 4    dahlah dah isi pulsa malah gabisa mana pulsa a...
# ..                                                 ...
# 362  solusinya pindah vropaider lain karena telekom...
# 363                               ada kuota gratis kaa
# 364                                   dari biasa keong
# 365                        rame kasih rating playstore
# 366  nggak ada paket internet gratis min sambut ula...
#
#                                             tokenisasi  \
# 0                      [, gangguan, segera, perbaikan]
# 1    [sidang, tahunan, mpr, agustus, konvensi, keta...
# 2                           [telkomsel, kartu, sultan]
# 3    [pembelian, koin, untuk, joylada, sudah, terko...
# 4    [dahlah, dah, isi, pulsa, malah, gabisa, mana,...
# ..                                                 ...
# 362  [solusinya, pindah, vropaider, lain, karena, t...
# 363                          [ada, kuota, gratis, kaa]
# 364                               [dari, biasa, keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, ada, paket, internet, gratis, min, sam...
#
#                                               stopword  \
# 0                              [, gangguan, perbaikan]
# 1    [sidang, tahunan, mpr, agustus, konvensi, keta...
# 2                           [telkomsel, kartu, sultan]
# 3    [pembelian, koin, joylada, terkonfirmasi, tsel...
# 4            [dahlah, isi, pulsa, gabisa, pulsa, abis]
# ..                                                 ...
# 362  [solusinya, pindah, vropaider, telekomsel, tar...
# 363                               [kuota, gratis, kaa]
# 364                                            [keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, paket, internet, gratis, min, sambut, ...
#
#                                               stemming
# 0                                     [, ganggu, baik]
# 1    [sidang, tahun, mpr, agustus, konvensi, ketata...
# 2                           [telkomsel, kartu, sultan]
# 3    [beli, koin, joylada, konfirmasi, tsel, koin, ...
# 4               [dah, isi, pulsa, gabisa, pulsa, abis]
# ..                                                 ...
# 362  [solusi, pindah, vropaider, telekomsel, tarip,...
# 363                               [kuota, gratis, kaa]
# 364                                            [keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, paket, internet, gratis, min, sambut, ...
#
# [364 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                     [, ganggu, baik]
# 1    [sidang, tahun, mpr, agustus, konvensi, ketata...
# 2                           [telkomsel, kartu, sultan]
# 3    [beli, koin, joylada, konfirmasi, tsel, koin, ...
# 4               [dah, isi, pulsa, gabisa, pulsa, abis]
# ..                                                 ...
# 362  [solusi, pindah, vropaider, telekomsel, tarip,...
# 363                               [kuota, gratis, kaa]
# 364                                            [keong]
# 365                   [rame, kasih, rating, playstore]
# 366  [nggak, paket, internet, gratis, min, sambut, ...
#
# [364 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_8.xlsx')
