# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                        Surat terbuka untuk telkomsel
# 1    Mendingan yg pelanggan telkomsel mendingan min...
# 2    Gimana sih saya mau belajar tapi voucher gabis...
# 3        Buat ngegame ngelag terus padahal sinyal full
# 4    Buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               Min kok Saya panggilan darurat terus
# 320                                              Mahal
# 321                             Yuhuu.. Dah Banyak Min
# 322                             Aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
# [324 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                        Surat terbuka untuk telkomsel
# 1    Mendingan yg pelanggan telkomsel mendingan min...
# 2    Gimana sih saya mau belajar tapi voucher gabis...
# 3        Buat ngegame ngelag terus padahal sinyal full
# 4    Buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               Min kok Saya panggilan darurat terus
# 320                                              Mahal
# 321                             Yuhuu.. Dah Banyak Min
# 322                             Aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
# [320 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                        surat terbuka untuk telkomsel
# 1    mendingan yg pelanggan telkomsel mendingan min...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                             yuhuu.. dah banyak min
# 322                             aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
# [320 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan yg pelanggan telkomsel mendingan min...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                             yuhuu.. dah banyak min
# 322                             aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
#                                       cleaning_comment
# 0                        surat terbuka untuk telkomsel
# 1    mendingan pelanggan telkomsel mendingan mingga...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka telkomsel aja bisaa paket aja mahal jarin...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                               yuhuu dah banyak min
# 322                             aku butuh kuota gratis
# 323                         bagaimana cara cek poin
#
# [320 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan yg pelanggan telkomsel mendingan min...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                             yuhuu.. dah banyak min
# 322                             aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
#                                       cleaning_comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan pelanggan telkomsel mendingan mingga...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka telkomsel aja bisaa paket aja mahal jarin...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                               yuhuu dah banyak min
# 322                             aku butuh kuota gratis
# 323                         bagaimana cara cek poin
#
#                                             tokenisasi
# 0                   [surat, terbuka, untuk, telkomsel]
# 1    [mendingan, pelanggan, telkomsel, mendingan, m...
# 2    [gimana, sih, saya, mau, belajar, tapi, vouche...
# 3    [buat, ngegame, ngelag, terus, padahal, sinyal...
# 4    [buka, telkomsel, aja, bisaa, paket, aja, maha...
# ..                                                 ...
# 319        [min, kok, saya, panggilan, darurat, terus]
# 320                                            [mahal]
# 321                          [yuhuu, dah, banyak, min]
# 322                        [aku, butuh, kuota, gratis]
# 323                     [bagaimana, cara, cek, poin, ]
#
# [320 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan yg pelanggan telkomsel mendingan min...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                             yuhuu.. dah banyak min
# 322                             aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
#                                       cleaning_comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan pelanggan telkomsel mendingan mingga...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka telkomsel aja bisaa paket aja mahal jarin...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                               yuhuu dah banyak min
# 322                             aku butuh kuota gratis
# 323                         bagaimana cara cek poin
#
#                                             tokenisasi  \
# 0                   [surat, terbuka, untuk, telkomsel]
# 1    [mendingan, pelanggan, telkomsel, mendingan, m...
# 2    [gimana, sih, saya, mau, belajar, tapi, vouche...
# 3    [buat, ngegame, ngelag, terus, padahal, sinyal...
# 4    [buka, telkomsel, aja, bisaa, paket, aja, maha...
# ..                                                 ...
# 319        [min, kok, saya, panggilan, darurat, terus]
# 320                                            [mahal]
# 321                          [yuhuu, dah, banyak, min]
# 322                        [aku, butuh, kuota, gratis]
# 323                     [bagaimana, cara, cek, poin, ]
#
#                                               stopword
# 0                          [surat, terbuka, telkomsel]
# 1    [mendingan, pelanggan, telkomsel, mendingan, m...
# 2    [gimana, belajar, voucher, gabisa, masuk, gang...
# 3                      [ngegame, ngelag, sinyal, full]
# 4    [buka, telkomsel, bisaa, paket, mahal, jaringa...
# ..                                                 ...
# 319                          [min, panggilan, darurat]
# 320                                            [mahal]
# 321                                       [yuhuu, min]
# 322                             [butuh, kuota, gratis]
# 323                                      [cek, poin, ]
#
# [320 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 963
# ------------------------
# surat : surat
# terbuka : buka
# telkomsel : telkomsel
# mendingan : mending
# pelanggan : langgan
# minggat : minggat
# kga : kga
# bener : bener
# shh : shh
# jaringannya : jaring
# msa : msa
# turun : turun
# konsisten : konsisten
# lgi : lgi
# dhh : dhh
# udh : udh
# kouta : kouta
# mahal : mahal
# alasan : alas
# lhh : lhh
# ihh : ihh
# mentang : mentang
# kerja : kerja
# mikirin : mikirin
# duit : duit
# emngnya : emngnya
# nongol : nongol
# ahh : ahh
# kaca : kaca
# orng : orng
# mhh : mhh
# gimana : gimana
# belajar : ajar
# voucher : voucher
# gabisa : gabisa
# masuk : masuk
# gangguan : ganggu
#  :
# ngegame : ngegame
# ngelag : ngelag
# sinyal : sinyal
# full : full
# buka : buka
# bisaa : bisaa
# paket : paket
# jaringan : jaring
# buruknluar : buruknluar
# biasaa : biasaa
# kemaren : kemaren
# ekstra : ekstra
# unlimited : unlimited
# perbaiki : baik
# jual : jual
# kecepatan : cepat
# internet : internet
# segitu : segitu
# mikir : mikir
# tarif : tarif
# dimahalin : dimahalin
# ancur : ancur
# goblokk : goblokk
# putus : putus
# coba : coba
# terangkan : terang
# kuota : kuota
# multimedia : multimedia
# beli : beli
# kaga : kaga
# pangalengan : pangalengan
# buruk : buruk
# banget : banget
# telkomnyet : telkomnyet
# stabil : stabil
# tolong : tolong
# konsumen : konsumen
# pindah : pindah
# paketnya : paket
# pakai : pakai
# utama : utama
# nonton : nonton
# dlu : dlu
# unlimated : unlimated
# min : min
# kartu : kartu
# perhitungan : hitung
# aktif : aktif
# berubah : ubah
# ngelek : ngelek
# ngak : ngak
# main : main
# game : game
# suprise : suprise
# deal : deal
# klean : klean
# komentar : komentar
# jwab : jwab
# bot : bot
# knp : knp
# pass : pass
# machingup : machingup
# ngelak : ngelak
# mulu : mulu
# pas : pas
# lancar : lancar
# ngelaknya : ngelaknya
# kali : kali
# berkali : kali
# relok : rok
# gua : gua
# teruntuk : untuk
# nomer : nomer
# combo : combo
# sakti : sakti
# gb : gb
# hrg : hrg
# gmn : gmn
# mabar : mabar
# kek : kek
# babyk : babyk
# kau : kau
# ping : ping
# lawaq : lawaq
# maxstrem : maxstrem
# tonton : tonton
# one : one
# connect : connect
# jaya : jaya
# chekc : chekc
# kin : kin
# hadiah : hadiah
# gimna : gimna
# ngambil : ngambil
# kbps : kbps
# habis : habis
# mitos : mitos
# halo : halo
# mati : mati
# hilang : hilang
# urus : urus
# grapari : grapari
# ditmpat : ditmpat
# gue : gue
# lemot : lot
# admin : admin
# gmna : gmna
# dinbok : dinbok
# muter : muter
# pertanyaannya : tanya
# kaya : kaya
# obat : obat
# nyamuk : nyamuk
# jelek : jelek
# mata : mata
# picek : picek
# bagus : bagus
# sekarng : sekarng
# mha : mha
# hai : hai
# kak : kak
# ilmupedia : ilmupedia
# harga : harga
# bayar : bayar
# shopeepay : shopeepay
# benerin : benerin
# adek : adek
# ulangan : ulang
# ngisi : ngisi
# gini : gin
# udah : udah
# isi : isi
# pulsa : pulsa
# nggak : nggak
# nambah : nambah
# ribu : ribu
# apk : apk
# mytelkomsel : mytelkomsel
# trus : trus
# abis : abis
# apdet : apdet
# burik : burik
# bye : bye
# ganti : ganti
# operator : operator
# ngga : ngga
# muluk : muluk
# kebanyakan : banyak
# tingkah : tingkah
# sendal : sendal
# bangke : bangke
# oii : oii
# telkomyet : telkomyet
# knepa : knepa
# youtube : youtube
# klaw : klaw
# dipakai : pakai
# karna : karna
# update : update
# jadiin : jadiin
# sampah : sampah
# elu : elu
# dipake : dipake
# kagakk : kagakk
# ntlol : ntlol
# lol : lol
# sayang : sayang
# kemana : mana
# kualitas : kualitas
# speed : speed
# internetnya : internetnya
# kecepetan : kecepetan
# paketan : paket
# hpnya : hpnya
# kesedot : sedot
# pulsanya : pulsa
# kena : kena
# biaya : biaya
# non : non
# unli : unli
# dibatasin : dibatasin
# ngotak : ngotak
# aduh : aduh
# massa : massa
# kompatibel : kompatibel
# promo : promo
# permanen : permanen
# yaaaa : yaaaa
# rb : rb
# kog : kog
# ajglah : ajglah
# oalahhhh : oalahhhh
# minn : minn
# kuotaa : kuotaa
# gratiss : gratiss
# anjirr : anjirr
# siyal : siyal
# mengecewakan : kecewa
# ywdah : ywdah
# maafin : maafin
# semalam : malam
# gara : gara
# orang : orang
# btw : btw
# dinaikin : dinaikin
# pangkat : pangkat
# diperbaiki : baik
# kocak : kocak
# untng : untng
# daerah : daerah
# flores : flores
# provider : provider
# mndngan : mndngan
# cma : cma
# kenceng : kenceng
# jrngannya : jrngannya
# auto : auto
# hnya : hnya
# tli : tli
# miskin : miskin
# sabtu : sabtu
# disuruh : suruh
# refersh : refersh
# off : off
# maaf : maaf
# dikasih : kasih
# iya : iya
# sedekahin : sedekahin
# kagak : kagak
# mintanya : minta
# nyesal : nyesal
# operat : operat
# kemarin : kemarin
# malem : malem
# kayak : kayak
# taik : taik
# malu : malu
# iklan : iklan
# baikin : baikin
# noh : noh
# ampas : ampas
# pda : pda
# make : make
# dri : dri
# jariangan : jariangan
# mengjembutt : mengjembutt
# siput : siput
# knpa : knpa
# layanan : layan
# fakta : fakta
# blm : blm
# kasi : kasi
# klarifikasi : klarifikasi
# kmaren : kmaren
# kmungkinan : kmungkinan
# mreka : mreka
# sndiri : sndiri
# penyebabnya : sebab
# kompensasi : kompensasi
# kondisi : kondisi
# tanggal : tanggal
# zoom : zoom
# janji : janji
# manis : manis
# palsu : palsu
# seminggu : minggu
# laut : laut
# jalan : jalan
# lupa : lupa
# nimbul : nimbul
# tenggelam : tenggelam
# dasar : dasar
# lautan : laut
# hnyut : hnyut
# sekelas : kelas
# maintenance : maintenance
# ngerugiin : ngerugiin
# berjalan : jalan
# batas : batas
# pemakaian : pakai
# ttep : ttep
# gausah : gausah
# dibales : dibales
# mind : mind
# lanjutkan : lanjut
# bakatnya : bakat
# ngezoom : ngezoom
# class : class
# kasih : kasih
# alpa : alpa
# pliss : pliss
# secepatnya : cepat
# nungguin : nungguin
# kuotanya : kuota
# sinyalnya : sinyal
# lemotnya : lot
# ampun : ampun
# kadang : kadang
# suka : suka
# ilang : ilang
# enak : enak
# kebalikannya : balik
# ngerti : ngerti
# lag : lag
# ntar : ntar
# kompensasinya : kompensasi
# sabilah : sabi
# bangga : bangga
# bagusan : bagus
# tri : tri
# bermutu : mutu
# doang : doang
# penyelesaiannya : selesai
# download : download
# indihome : indihome
# kb : kb
# sehat : sehat
# kah : kah
# down : down
# indonesia : indonesia
# kualitasnya : kualitas
# dibikin : bikin
# ngen : ngen
# ganguan : ganguan
# tpi : tpi
# maluku : malu
# sihh : sihh
# bangkrut : bangkrut
# pingin : pingin
# masker : masker
# ngx : ngx
# meluas : luas
# tertutup : tutup
# pingku : pingku
# merah : merah
# mobile : mobile
# legends : legends
# seru : seru
# liat : liat
# komennya : komennya
# nangis : nang
# akwowko : akwowko
# remux : remux
# gaes : gaes
# merahhh : merahhh
# terosssss : terosssss
# dengerin : dengerin
# kontl : kontl
# hangus : hangus
# hrs : hrs
# grafari : grafari
# parah : parah
# ayo : ayo
# woi : woi
# maen : maen
# gonta : gonta
# matikan : mati
# boot : boot
# ulang : ulang
# mode : mode
# pesawat : pesawat
# gratis : gratis
# malm : malm
# ganggu : ganggu
# aktifitas : aktifitas
# ginian : ginian
# lur : lur
# please : please
# jembot : jembot
# gae : gae
# aplikasi : aplikasi
# bank : bank
# ora : ora
# iso : iso
# cuk : cuk
# dancuk : dancuk
# berusaha : usaha
# bersabar : sabar
# fix : fix
# gni : gni
# sulawesi : sulawesi
# malam : malam
# kelar : kelar
# login : login
# klw : klw
# liaaatt : liaaatt
# beginin : beginin
# teruss : teruss
# kredit : kredit
# skor : skor
# sudh : sudh
# lalot : lalot
# woyyy : woyyy
# kembalikan : kembali
# woyy : woyy
# bangetttt : bangetttt
# legggg : legggg
# dijadikan : jadi
# telkomselnya : telkomselnya
# matot : matot
# menit : menit
# kendalanya : kendala
# mohon : mohon
# maju : maju
# hancur : hancur
# pelayanan : layan
# sistem : sistem
# karangnunggal : karangnunggal
# tasikmalaya : tasikmalaya
# dpt : dpt
# pemerintah : perintah
# bantuan : bantu
# gitu : gitu
# dikota : kota
# depok : depok
# cuman : cuman
# mentok : mentok
# bar : bar
# nge : nge
# murahin : murahin
# sms : sms
# nelponnya : nelponnya
# bertahun : tahun
# ahir : ahir
# wes : wes
# kapok : kapok
# point : point
# tuker : tuker
# legend : legend
# menghubungi : hubung
# perihal : perihal
# pembatalan : batal
# migrasi : migrasi
# msh : msh
# dibuatkan : buat
# laporannya : lapor
# prosesnya : proses
# dibatalkan : batal
# via : via
# telp : telp
# kesal : kesal
# sebentar : sebentar
# ngeleg : ngeleg
# ngelegnya : ngelegnya
# pantek : pantek
# alhamdulillah : alhamdulillah
# terhingga : hingga
# rusaknya : rusak
# kabel : kabel
# karma : karma
# keserakahan : serakah
# semoga : moga
# membaik : baik
# terdampak : dampak
# ngerjain : ngerjain
# tugas : tugas
# susah : susah
# berita : berita
# valid : valid
# mahalll : mahalll
# negara : negara
# untung : untung
# rakyatnya : rakyat
# buntung : buntung
# max : max
# terbuang : buang
# sia : sia
# jayi : jayi
# sukahaji : sukahaji
# majalengka : majalengka
# knapa : knapa
# sim : sim
# muncul : muncul
# pdahal : pdahal
# cek : cek
# sdah : sdah
# mnghbungi : mnghbungi
# callcenter : callcenter
# konfirmasi : konfirmasi
# skrang : skrang
# setia : setia
# mengenal : kenal
# terima : terima
# melayani : layan
# gaess : gaess
# marah : marah
# bandingkan : banding
# teman : teman
# sok : sok
# banggain : banggain
# ngeluh : ngeluh
# komen : komen
# volte : volte
# edge : edge
# jawa : jawa
# barat : barat
# terpilih : pilih
# sayangnya : sayang
# device : device
# mendukung : dukung
# teknologi : teknologi
# dikit : dikit
# ngomong : ngomong
# sesuai : sesuai
# ngapa : ngapa
# ppkm : ppkm
# tsel : tsel
# koutanya : koutanya
# berkurang : kurang
# murahan : murah
# surabaya : surabaya
# voltenya : voltenya
# mim : mim
# bufering : bufering
# buset : buset
# uda : uda
# masak : masak
# video : video
# facebook : facebook
# fokus : fokus
# problem : problem
# promosi : promosi
# siang : siang
# ngajak : ngajak
# ribut : ribut
# selangit : langit
# semangit : semangit
# kpn : kpn
# baiknya : baik
# woy : woy
# woii : woii
# ujian : uji
# sejagat : jagat
# bumi : bumi
# raya : raya
# discord : discord
# tgl : tgl
# telkom : telkom
# asemlah : asemlah
# korupsi : korupsi
# eror : eror
# pea : pea
# padam : padam
# total : total
# memakai : pakai
# keluhan : keluh
# tanggapan : tanggap
# status : status
# disaat : saat
# sungguh : sungguh
# terlaluuuj : terlaluuuj
# masi : mas
# superrr : superrr
# sukses : sukses
# apanya : apa
# normal : normal
# disumatera : disumatera
# emang : emang
# browser : browser
# sumpah : sumpah
# bnr : bnr
# user : user
# telcomsel : telcomsel
# like : like
# besok : besok
# otw : otw
# miin : miin
# daerahku : daerah
# lemotnha : lemotnha
# gila : gila
# perusahaan : usaha
# mulia : mulia
# pedagang : dagang
# tempe : tempe
# anu : anu
# langganan : langgan
# pesan : pesan
# bet : bet
# dritadi : dritadi
# urgent : urgent
# menang : menang
# gprs : gprs
# mudahan : mudah
# cepat : cepat
# ngibul : ngibul
# bngt : bngt
# ngiklan : ngiklan
# perbaikan : baik
# nol : nol
# jngan : jngan
# mencoba : coba
# tutup : tutup
# hujatan : hujat
# memng : memng
# kenyataannya : nyata
# jatingan : jatingan
# timbul : timbul
# kuoto : oto
# dibilang : bilang
# berbanding : banding
# terbalik : balik
# sisa : sisa
# intetnet : intetnet
# berlakunya : laku
# stiap : stiap
# ambil : ambil
# katengan : katengan
# ngecek : ngecek
# darurat : darurat
# salah : salah
# apaaaaaaa : apaaaaaaa
# penjelasannya : jelas
# selesainya : selesai
# kerjaan : kerja
# bangka : bangka
# belitung : belitung
# nanya : nanya
# outlet : outlet
# dana : dana
# yak : yak
# internetan : internetan
# pulak : pulak
# perusahan : usah
# bnyk : bnyk
# menawar : tawar
# kesini : kesini
# cape : cape
# lohhh : lohhh
# kalimantan : kalimantan
# kota : kota
# browsing : browsing
# bisanya : bisa
# nich : nich
# mlam : mlam
# mna : mna
# andal : andal
# mlah : mlah
# lma : lma
# pketan : pketan
# info : info
# aktifkan : aktif
# hujan : hujan
# badai : badai
# drop : drop
# payah : payah
# nyesel : nyesel
# kalah : kalah
# jaih : jaih
# recehan : receh
# sagup : sagup
# nyediain : nyediain
# masyrakat : masyrakat
# sekelasa : kelasa
# bumn : bumn
# astagaaaaa : astagaaaaa
# ngebut : ngebut
# jam : jam
# katany : katany
# september : september
# bacot : bacot
# gblk : gblk
# ken : ken
# haram : haram
# server : server
# mending : mending
# cuyy : cuyy
# jngn : jngn
# syukur : syukur
# sebulan : bulan
# singkawang : singkawang
# akir : akir
# thanks : thanks
# mantapppp : mantapppp
# terbaik : baik
# gede : gede
# games : games
# online : online
# lamban : lamban
# ovo : ovo
# gopay : gopay
# sekarat : sekarat
# xial : xial
# kantor : kantor
# pusatnya : pusat
# selamat : selamat
# singal : singal
# mmk : mmk
# ppk : ppk
# teros : ros
# kuning : kuning
# kuningnya : kuning
# sampe : sampe
# match : match
# selesai : selesai
# kusut : kusut
# gajelas : gajelas
# telcomcel : telcomcel
# nyet : nyet
# semangat : semangat
# perbaikin : perbaikin
# sistemnya : sistem
# tetep : tetep
# slalu : slalu
# nemenin : nemenin
# good : good
# luck : luck
# sher : sher
# lokasi : lokasi
# bangeettt : bangeettt
# sebanding : banding
# supeerr : supeerr
# murahh : murahh
# jangkauan : jangkau
# tercover : tercover
# wilayah : wilayah
# subang : subang
# jarigan : jarigan
# check : check
# terpotong : potong
# donk : donk
# balikin : balikin
# ancoooooorrrrrrr : ancoooooorrrrrrr
# gunain : gunain
# namax : namax
# pemeresan : meres
# disney : disney
# hotstar : hotstar
# bln : bln
# minggu : minggu
# rumah : rumah
# unlimitedmax : unlimitedmax
# contoh : contoh
# mainkan : main
# free : free
# fire : fire
# card : card
# rusak : rusak
# nomor : nomor
# doi : doi
# alesan : alesan
# gerimis : gerimis
# wanwan : wanwan
# diamond : diamond
# benernya : benernya
# berlaku : laku
# promoya : promoya
# gratisan : gratis
# mobelejen : mobelejen
# isiiin : isiiin
# aktifasi : aktifasi
# keburu : keburu
# perasaan : asa
# sblm : sblm
# custumer : custumer
# berhari : hari
# stuck : stuck
# anjg : anjg
# zalim : zalim
# anak : anak
# dakjal : dakjal
# laknatullah : laknatullah
# ngadat : ngadat
# asuuuuu : asuuuuu
# gamenya : gamenya
# kyk : kyk
# telkontol : telkontol
# tim : tim
# memek : memek
# nyuruh : nyuruh
# data : data
# penuh : penuh
# menjamin : jamin
# wajar : wajar
# kbs : kbs
# sarannya : saran
# nyedot : nyedot
# bang : bang
# koq : koq
# kab : kab
# serang : serang
# banten : banten
# kragilan : kragilan
# anyep : anyep
# bos : bos
# sceter : sceter
# nyakut : nyakut
# truz : truz
# ngasih : ngasih
# solusi : solusi
# mbak : mbak
# mas : mas
# kampung : kampung
# nelpon : nelpon
# tower : tower
# dikampung : kampung
# jgnkan : jgnkan
# intenetan : intenetan
# telponan : telpon
# warga : warga
# leletnya : lelet
# serasa : serasa
# pusat : pusat
# loyo : loyo
# peningkatan : tingkat
# haduh : haduh
# resah : resah
# lahhh : lahhh
# sosmed : sosmed
# suprese : suprese
# del : del
# mmin : mmin
# tangl : tangl
# garut : garut
# numpang : numpang
# semenjak : semenjak
# pemasangan : pasang
# tempatku : tempat
# informasinya : informasi
# jwb : jwb
# moga : moga
# bermasalah : masalah
# tergantung : gantung
# daerahny : daerahny
# salahkan : salah
# aneh : aneh
# gnti : gnti
# gabissa : gabissa
# aksek : aksek
# perbaik : baik
# semenit : menit
# menikmati : nikmat
# muyer : muyer
# mumet : mumet
# aktifin : aktifin
# nihh : nihh
# boss : boss
# koneksi : koneksi
# ilangan : ilangan
# hadeh : hadeh
# tok : tok
# harganya : harga
# rbu : rbu
# keatas : atas
# pembritahuan : pembritahuan
# lite : lite
# doank : doank
# dibenerin : dibenerin
# laporan : lapor
# disurung : disurung
# nunggu : nunggu
# sasageyo : sasageyo
# jengkel : jengkel
# sllu : sllu
# akun : akun
# sndri : sndri
# kartanya : kartanya
# sesi : sesi
# maksudnya : maksud
# pinjem : pinjem
# tuhh : tuhh
# bnrin : bnrin
# saran : saran
# berhenti : henti
# dipecat : pecat
# becus : becus
# urusin : urusin
# signal : signal
# penyu : penyu
# periksa : periksa
# teregister : register
# balasan : balas
# nyari : nyari
# chat : chat
# sultan : sultan
# alah : alah
# nyaran : nyaran
# patahkan : patah
# klian : klian
# kuotaku : kuota
# kcepatan : kcepatan
# kuntul : kuntul
# terluas : luas
# yaura : yaura
# poin : poin
# saudara : saudara
# sahabat : sahabat
# kenalan : kenal
# taun : taun
# ikutan : ikut
# satupun : satu
# tertera : tera
# tersisa : sisa
# anjeerrrr : anjeerrrr
# geratis : gerat
# aktifnya : aktif
# msih : msih
# dicek : cek
# hidup : hidup
# hutang : hutang
# sya : sya
# berulang : ulang
# kli : kli
# mlh : mlh
# suruh : suruh
# tukar : tukar
# asik : asik
# karokean : karokean
# terputus : putus
# ceria : ceria
# adain : adain
# butuh : butuh
# daring : daring
# perna : perna
# haloo : haloo
# bljr : bljr
# ngk : ngk
# ssh : ssh
# snyal : snyal
# may : may
# im : im
# jaringanmu : jaring
# veronica : veronica
# son : son
# panggilan : panggil
# yuhuu : yuhuu
# {'surat': 'surat', 'terbuka': 'buka', 'telkomsel': 'telkomsel', 'mendingan': 'mending', 'pelanggan': 'langgan', 'minggat': 'minggat', 'kga': 'kga', 'bener': 'bener', 'shh': 'shh', 'jaringannya': 'jaring', 'msa': 'msa', 'turun': 'turun', 'konsisten': 'konsisten', 'lgi': 'lgi', 'dhh': 'dhh', 'udh': 'udh', 'kouta': 'kouta', 'mahal': 'mahal', 'alasan': 'alas', 'lhh': 'lhh', 'ihh': 'ihh', 'mentang': 'mentang', 'kerja': 'kerja', 'mikirin': 'mikirin', 'duit': 'duit', 'emngnya': 'emngnya', 'nongol': 'nongol', 'ahh': 'ahh', 'kaca': 'kaca', 'orng': 'orng', 'mhh': 'mhh', 'gimana': 'gimana', 'belajar': 'ajar', 'voucher': 'voucher', 'gabisa': 'gabisa', 'masuk': 'masuk', 'gangguan': 'ganggu', '': '', 'ngegame': 'ngegame', 'ngelag': 'ngelag', 'sinyal': 'sinyal', 'full': 'full', 'buka': 'buka', 'bisaa': 'bisaa', 'paket': 'paket', 'jaringan': 'jaring', 'buruknluar': 'buruknluar', 'biasaa': 'biasaa', 'kemaren': 'kemaren', 'ekstra': 'ekstra', 'unlimited': 'unlimited', 'perbaiki': 'baik', 'jual': 'jual', 'kecepatan': 'cepat', 'internet': 'internet', 'segitu': 'segitu', 'mikir': 'mikir', 'tarif': 'tarif', 'dimahalin': 'dimahalin', 'ancur': 'ancur', 'goblokk': 'goblokk', 'putus': 'putus', 'coba': 'coba', 'terangkan': 'terang', 'kuota': 'kuota', 'multimedia': 'multimedia', 'beli': 'beli', 'kaga': 'kaga', 'pangalengan': 'pangalengan', 'buruk': 'buruk', 'banget': 'banget', 'telkomnyet': 'telkomnyet', 'stabil': 'stabil', 'tolong': 'tolong', 'konsumen': 'konsumen', 'pindah': 'pindah', 'paketnya': 'paket', 'pakai': 'pakai', 'utama': 'utama', 'nonton': 'nonton', 'dlu': 'dlu', 'unlimated': 'unlimated', 'min': 'min', 'kartu': 'kartu', 'perhitungan': 'hitung', 'aktif': 'aktif', 'berubah': 'ubah', 'ngelek': 'ngelek', 'ngak': 'ngak', 'main': 'main', 'game': 'game', 'suprise': 'suprise', 'deal': 'deal', 'klean': 'klean', 'komentar': 'komentar', 'jwab': 'jwab', 'bot': 'bot', 'knp': 'knp', 'pass': 'pass', 'machingup': 'machingup', 'ngelak': 'ngelak', 'mulu': 'mulu', 'pas': 'pas', 'lancar': 'lancar', 'ngelaknya': 'ngelaknya', 'kali': 'kali', 'berkali': 'kali', 'relok': 'rok', 'gua': 'gua', 'teruntuk': 'untuk', 'nomer': 'nomer', 'combo': 'combo', 'sakti': 'sakti', 'gb': 'gb', 'hrg': 'hrg', 'gmn': 'gmn', 'mabar': 'mabar', 'kek': 'kek', 'babyk': 'babyk', 'kau': 'kau', 'ping': 'ping', 'lawaq': 'lawaq', 'maxstrem': 'maxstrem', 'tonton': 'tonton', 'one': 'one', 'connect': 'connect', 'jaya': 'jaya', 'chekc': 'chekc', 'kin': 'kin', 'hadiah': 'hadiah', 'gimna': 'gimna', 'ngambil': 'ngambil', 'kbps': 'kbps', 'habis': 'habis', 'mitos': 'mitos', 'halo': 'halo', 'mati': 'mati', 'hilang': 'hilang', 'urus': 'urus', 'grapari': 'grapari', 'ditmpat': 'ditmpat', 'gue': 'gue', 'lemot': 'lot', 'admin': 'admin', 'gmna': 'gmna', 'dinbok': 'dinbok', 'muter': 'muter', 'pertanyaannya': 'tanya', 'kaya': 'kaya', 'obat': 'obat', 'nyamuk': 'nyamuk', 'jelek': 'jelek', 'mata': 'mata', 'picek': 'picek', 'bagus': 'bagus', 'sekarng': 'sekarng', 'mha': 'mha', 'hai': 'hai', 'kak': 'kak', 'ilmupedia': 'ilmupedia', 'harga': 'harga', 'bayar': 'bayar', 'shopeepay': 'shopeepay', 'benerin': 'benerin', 'adek': 'adek', 'ulangan': 'ulang', 'ngisi': 'ngisi', 'gini': 'gin', 'udah': 'udah', 'isi': 'isi', 'pulsa': 'pulsa', 'nggak': 'nggak', 'nambah': 'nambah', 'ribu': 'ribu', 'apk': 'apk', 'mytelkomsel': 'mytelkomsel', 'trus': 'trus', 'abis': 'abis', 'apdet': 'apdet', 'burik': 'burik', 'bye': 'bye', 'ganti': 'ganti', 'operator': 'operator', 'ngga': 'ngga', 'muluk': 'muluk', 'kebanyakan': 'banyak', 'tingkah': 'tingkah', 'sendal': 'sendal', 'bangke': 'bangke', 'oii': 'oii', 'telkomyet': 'telkomyet', 'knepa': 'knepa', 'youtube': 'youtube', 'klaw': 'klaw', 'dipakai': 'pakai', 'karna': 'karna', 'update': 'update', 'jadiin': 'jadiin', 'sampah': 'sampah', 'elu': 'elu', 'dipake': 'dipake', 'kagakk': 'kagakk', 'ntlol': 'ntlol', 'lol': 'lol', 'sayang': 'sayang', 'kemana': 'mana', 'kualitas': 'kualitas', 'speed': 'speed', 'internetnya': 'internetnya', 'kecepetan': 'kecepetan', 'paketan': 'paket', 'hpnya': 'hpnya', 'kesedot' ...
# ------------------------
# Pandas Apply:   0%|          | 0/320 [00:00<?, ?it/s]
#                                                comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan yg pelanggan telkomsel mendingan min...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka my telkomsel aja g bisaa paket aja mahal ...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                             yuhuu.. dah banyak min
# 322                             aku butuh kuota gratis
# 323                  bagaimana cara cek poin? di *777#
#
#                                       cleaning_comment  \
# 0                        surat terbuka untuk telkomsel
# 1    mendingan pelanggan telkomsel mendingan mingga...
# 2    gimana sih saya mau belajar tapi voucher gabis...
# 3        buat ngegame ngelag terus padahal sinyal full
# 4    buka telkomsel aja bisaa paket aja mahal jarin...
# ..                                                 ...
# 319               min kok saya panggilan darurat terus
# 320                                              mahal
# 321                               yuhuu dah banyak min
# 322                             aku butuh kuota gratis
# 323                         bagaimana cara cek poin
#
#                                             tokenisasi  \
# 0                   [surat, terbuka, untuk, telkomsel]
# 1    [mendingan, pelanggan, telkomsel, mendingan, m...
# 2    [gimana, sih, saya, mau, belajar, tapi, vouche...
# 3    [buat, ngegame, ngelag, terus, padahal, sinyal...
# 4    [buka, telkomsel, aja, bisaa, paket, aja, maha...
# ..                                                 ...
# 319        [min, kok, saya, panggilan, darurat, terus]
# 320                                            [mahal]
# 321                          [yuhuu, dah, banyak, min]
# 322                        [aku, butuh, kuota, gratis]
# 323                     [bagaimana, cara, cek, poin, ]
#
#                                               stopword  \
# 0                          [surat, terbuka, telkomsel]
# 1    [mendingan, pelanggan, telkomsel, mendingan, m...
# 2    [gimana, belajar, voucher, gabisa, masuk, gang...
# 3                      [ngegame, ngelag, sinyal, full]
# 4    [buka, telkomsel, bisaa, paket, mahal, jaringa...
# ..                                                 ...
# 319                          [min, panggilan, darurat]
# 320                                            [mahal]
# 321                                       [yuhuu, min]
# 322                             [butuh, kuota, gratis]
# 323                                      [cek, poin, ]
#
#                                               stemming
# 0                             [surat, buka, telkomsel]
# 1    [mending, langgan, telkomsel, mending, minggat...
# 2     [gimana, ajar, voucher, gabisa, masuk, ganggu, ]
# 3                      [ngegame, ngelag, sinyal, full]
# 4    [buka, telkomsel, bisaa, paket, mahal, jaring,...
# ..                                                 ...
# 319                            [min, panggil, darurat]
# 320                                            [mahal]
# 321                                       [yuhuu, min]
# 322                             [butuh, kuota, gratis]
# 323                                      [cek, poin, ]
#
# [320 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                             [surat, buka, telkomsel]
# 1    [mending, langgan, telkomsel, mending, minggat...
# 2     [gimana, ajar, voucher, gabisa, masuk, ganggu, ]
# 3                      [ngegame, ngelag, sinyal, full]
# 4    [buka, telkomsel, bisaa, paket, mahal, jaring,...
# ..                                                 ...
# 319                            [min, panggil, darurat]
# 320                                            [mahal]
# 321                                       [yuhuu, min]
# 322                             [butuh, kuota, gratis]
# 323                                      [cek, poin, ]
#
# [320 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_9.xlsx')
