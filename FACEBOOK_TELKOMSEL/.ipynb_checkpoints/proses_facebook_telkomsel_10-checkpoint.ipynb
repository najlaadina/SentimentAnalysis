# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Aahaii....telkomsel .....jaringan bagus..inter...
# 1    Adain lagi dong redem saldo link aja poin gw d...
# 2    Kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    Upgrade dari 3G ke 4G katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   Semoga dpt mobil
# 227  Kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            Dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             Udah mahal ngeleg lagi
# 230                                      Bukti kan....
#
# [231 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Aahaii....telkomsel .....jaringan bagus..inter...
# 1    Adain lagi dong redem saldo link aja poin gw d...
# 2    Kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    Upgrade dari 3G ke 4G katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   Semoga dpt mobil
# 227  Kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            Dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             Udah mahal ngeleg lagi
# 230                                      Bukti kan....
#
# [229 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    aahaii....telkomsel .....jaringan bagus..inter...
# 1    adain lagi dong redem saldo link aja poin gw d...
# 2    kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    upgrade dari 3g ke 4g katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             udah mahal ngeleg lagi
# 230                                      bukti kan....
#
# [229 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    aahaii....telkomsel .....jaringan bagus..inter...
# 1    adain lagi dong redem saldo link aja poin gw d...
# 2    kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    upgrade dari 3g ke 4g katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             udah mahal ngeleg lagi
# 230                                      bukti kan....
#
#                                       cleaning_comment
# 0    aahaii telkomsel jaringan bagus internet lanca...
# 1    adain lagi dong redem saldo link aja poin dah ...
# 2     kebanyakan korup nih kasian noh pegawai naek bts
# 3    upgrade dari katanya dapat bonus paket kok nom...
# 4                                     sinyal woooiiii
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228                    dapat hadiah dari   hadiah ada
# 229                             udah mahal ngeleg lagi
# 230                                         bukti kan
#
# [229 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    aahaii....telkomsel .....jaringan bagus..inter...
# 1    adain lagi dong redem saldo link aja poin gw d...
# 2    kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    upgrade dari 3g ke 4g katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             udah mahal ngeleg lagi
# 230                                      bukti kan....
#
#                                       cleaning_comment  \
# 0    aahaii telkomsel jaringan bagus internet lanca...
# 1    adain lagi dong redem saldo link aja poin dah ...
# 2     kebanyakan korup nih kasian noh pegawai naek bts
# 3    upgrade dari katanya dapat bonus paket kok nom...
# 4                                     sinyal woooiiii
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228                    dapat hadiah dari   hadiah ada
# 229                             udah mahal ngeleg lagi
# 230                                         bukti kan
#
#                                             tokenisasi
# 0    [aahaii, telkomsel, jaringan, bagus, internet,...
# 1    [adain, lagi, dong, redem, saldo, link, aja, p...
# 2    [kebanyakan, korup, nih, kasian, noh, pegawai,...
# 3    [upgrade, dari, katanya, dapat, bonus, paket, ...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                               [semoga, dpt, mobil]
# 227  [kak, knp, setiap, mau, mendaftar, pulsa, sya,...
# 228               [dapat, hadiah, dari, hadiah, ada, ]
# 229                        [udah, mahal, ngeleg, lagi]
# 230                                     [bukti, kan, ]
#
# [229 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    aahaii....telkomsel .....jaringan bagus..inter...
# 1    adain lagi dong redem saldo link aja poin gw d...
# 2    kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    upgrade dari 3g ke 4g katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             udah mahal ngeleg lagi
# 230                                      bukti kan....
#
#                                       cleaning_comment  \
# 0    aahaii telkomsel jaringan bagus internet lanca...
# 1    adain lagi dong redem saldo link aja poin dah ...
# 2     kebanyakan korup nih kasian noh pegawai naek bts
# 3    upgrade dari katanya dapat bonus paket kok nom...
# 4                                     sinyal woooiiii
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228                    dapat hadiah dari   hadiah ada
# 229                             udah mahal ngeleg lagi
# 230                                         bukti kan
#
#                                             tokenisasi  \
# 0    [aahaii, telkomsel, jaringan, bagus, internet,...
# 1    [adain, lagi, dong, redem, saldo, link, aja, p...
# 2    [kebanyakan, korup, nih, kasian, noh, pegawai,...
# 3    [upgrade, dari, katanya, dapat, bonus, paket, ...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                               [semoga, dpt, mobil]
# 227  [kak, knp, setiap, mau, mendaftar, pulsa, sya,...
# 228               [dapat, hadiah, dari, hadiah, ada, ]
# 229                        [udah, mahal, ngeleg, lagi]
# 230                                     [bukti, kan, ]
#
#                                               stopword
# 0    [aahaii, telkomsel, jaringan, bagus, internet,...
# 1    [adain, redem, saldo, link, poin, numpuk, beso...
# 2    [kebanyakan, korup, kasian, noh, pegawai, naek...
# 3    [upgrade, bonus, paket, nomor, bonus, paket, i...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                               [semoga, dpt, mobil]
# 227   [kak, knp, mendaftar, pulsa, sya, ketarik, mulu]
# 228                                 [hadiah, hadiah, ]
# 229                              [udah, mahal, ngeleg]
# 230                                          [bukti, ]
#
# [229 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 721
# ------------------------
# aahaii : aahaii
# telkomsel : telkomsel
# jaringan : jaring
# bagus : bagus
# internet : internet
# lancar : lancar
# menukar : tukar
# poin : poin
# kejutan : kejut
# hkhkhk : hkhkhk
# adain : adain
# redem : redem
# saldo : saldo
# link : link
# numpuk : numpuk
# besok : besok
# desember : desember
# angus : angus
# kebanyakan : banyak
# korup : korup
# kasian : kasi
# noh : noh
# pegawai : pegawai
# naek : naek
# bts : bts
# upgrade : upgrade
# bonus : bonus
# paket : paket
# nomor : nomor
#  :
# sinyal : sinyal
# woooiiii : woooiiii
# internetnya : internetnya
# menarik : tarik
# apalagj : apalagj
# penawarnya : tawar
# promo : promo
# sumpah : sumpah
# peronika : peronika
# ngga : ngga
# bener : bener
# hai : hai
# kak : kak
# cek : cek
# byk : byk
# bilangin : bilangin
# gratis : gratis
# ujung : ujung
# hubungi : hubung
# cnth : cnth
# blm : blm
# ambil : ambil
# koin : koin
# ujng : ujng
# download : download
# rool : rool
# mbosankn : mbosankn
# direedem : direedem
# beneran : beneran
# iklan : iklan
# min : min
# mohon : mohon
# diupdate : diupdate
# fitur : fitur
# safe : safe
# pulsa : pulsa
# kayak : kayak
# kartu : kartu
# dongkarena : dongkarena
# sayang : sayang
# banget : banget
# isi : isi
# tersedot : sedot
# dijadiin : dijadiin
# kouta : kouta
# sampe : sampe
# dibandingkan : banding
# beli : beli
# bergb : bergb
# membandingkan : banding
# minggu : minggu
# malam : malam
# skrg : skrg
# ancur : ancur
# balas : balas
# pending : pending
# konsumen : konsumen
# dirugikan : rugi
# uunya : uunya
# hak : hak
# uda : uda
# bayar : bayar
# pelayanan : layan
# fan : fan
# hancur : hancur
# gawat : gawat
# lokasi : lokasi
# sumut : sumut
# mendingan : mending
# jual : jual
# cina : cina
# perubahan : ubah
# kelola : kelola
# orang : orang
# mahal : mahal
# taik : taik
# tolong : tolong
# perbaikin : perbaikin
# signal : signal
# telfon : telfon
# iternet : iternet
# riau : riau
# woy : woy
# sehat : sehat
# megang : megang
# pas : pas
# smp : smp
# smpe : smpe
# skrng : skrng
# stabil : stabil
# pokok : pokok
# udah : udah
# selambat : lambat
# respond : respond
# memperbaiki : baik
# koneksi : koneksi
# belajar : ajar
# online : online
# keganggu : ganggu
# total : total
# daerah : daerah
# sitaro : sitaro
# khusus : khusus
# siau : siau
# benci : benci
# nge : nge
# game : game
# sinyalnya : sinyal
# mangkin : mangkin
# susah : susah
# sekedar : dar
# berbagi : bagi
# pengalaman : alam
# mengalami : alami
# alami : alami
# kuota : kuota
# sakti : sakti
# diiringi : iring
# ketenangan : tenang
# karna : karna
# ujungnya : ujung
# curangi : curang
# ketentuan : tentu
# sebulan : bulan
# sulawesi : sulawesi
# parah : parah
# keresahan : resah
# dengar : dengar
# jasa : jasa
# bot : bot
# pengguna : guna
# berasa : asa
# jenuh : jenuh
# layanan : layan
# dipinggir : pinggir
# jalan : jalan
# full : full
# masuk : masuk
# krmh : krmh
# jarak : jarak
# meter : meter
# kembang : kembang
# kempis : kempis
# moso : moso
# pindah : pindah
# rmh : rmh
# telkomel : telkomel
# pakai : pakai
# modem : modem
# advan : advan
# cpe : cpe
# seponsori : seponsori
# mmpan : mmpan
# solusi : solusi
# kah : kah
# mode : mode
# pesawat : pesawat
# udh : udh
# jam : jam
# segini : gin
# bapuk : bapuk
# anjiiim : anjiiim
# aneh : aneh
# ribu : ribu
# paketan : paket
# jamin : jamin
# kagak : kagak
# prnh : prnh
# urus : urus
# gitu : gitu
# hilang : hilang
# tlpan : tlpan
# asuk : asuk
# jarinqan : jarinqan
# kaya : kaya
# gini : gin
# mon : mon
# maap : maap
# knpa : knpa
# gaguna : gaguna
# gimang : gimang
# nich : nich
# paketnya : paket
# dimurahin : dimurahin
# mataram : mataram
# jelek : jelek
# pdahal : pdahal
# penuh : penuh
# terampas : ampas
# ilang : ilang
# terulang : ulang
# menerus : terus
# asw : asw
# merugikan : rugi
# macet : macet
# jakarta : jakarta
# asudahlah : asudahlah
# sultan : sultan
# telkom : telkom
# boss : boss
# senggol : senggol
# dipakai : pakai
# kena : kena
# tipu : tipu
# gendam : gendam
# promosinya : promosi
# ajah : ajah
# detik : detik
# buka : buka
# youtube : youtube
# diperbaiki : baik
# nyaman : nyaman
# teu : teu
# baleg : baleg
# anying : anying
# disilang : silang
# dasar : dasar
# bambang : bambang
# halo : halo
# berhenti : henti
# benerin : benerin
# kualitas : kualitas
# jaringannya : jaring
# seandainya : anda
# males : males
# tlkomsel : tlkomsel
# sial : sial
# hang : hang
# teruuuus : teruuuus
# beh : beh
# temen : temen
# murah : murah
# main : main
# malem : malem
# jumping : jumping
# emosi : emosi
# point : point
# tukar : tukar
# enakin : enakin
# dikit : dikit
# ngapa : ngapa
# harga : harga
# anjirr : anjirr
# perbaiki : baik
# ngpo : ngpo
# nian : nian
# iya : iya
# rinso : rinso
# yuci : yuci
# jaring : jaring
# bersih : bersih
# lemot : lot
# jaringanya : jaringanya
# aktifkan : aktif
# darurat : darurat
# muncul : muncul
# notifikasi : notifikasi
# komen : komen
# ngurusin : ngurusin
# red : red
# realmente : realmente
# mala : mala
# veces : veces
# emociono : emociono
# con : con
# ganti : ganti
# endorse : endorse
# ahh : ahh
# bangke : bangke
# boros : boros
# report : report
# akun : akun
# ngak : ngak
# pemasukan : pasu
# promosi : promosi
# woi : woi
# ngelag : ngelag
# registrasi : registrasi
# gmna : gmna
# desa : desa
# sinargalih : sinargalih
# lebak : lebak
# banten : banten
# bantuannya : bantu
# hadeh : hadeh
# ping : ping
# ekstra : ekstra
# unlimited : unlimited
# zoom : zoom
# sekolah : sekolah
# anjim : anjim
# chek : chek
# pagi : pagi
# sore : sore
# gangguan : ganggu
# ajakin : ajakin
# berantem : antem
# kntiiiilll : kntiiiilll
# jelekkk : jelekkk
# mintaaaa : mintaaaa
# ampuuuun : ampuuuun
# ogah : ogah
# burik : burik
# burix : burix
# situ : situ
# nyari : nyari
# karyawan : karyawan
# calo : calo
# teknisi : teknisi
# sesuai : sesuai
# bidang : bidang
# jijik : jijik
# gua : gua
# ngk : ngk
# check : check
# harian : hari
# tsel : tsel
# internetan : internetan
# dlu : dlu
# ngiklan : ngiklan
# mulu : mulu
# bicara : bicara
# sopan : sopan
# didik : didik
# bangkrut : bangkrut
# gimana : gimana
# keluhan : keluh
# dancuk : dancuk
# kntl : kntl
# anjg : anjg
# taikk : taikk
# komentar : komentar
# tae : tae
# tersedia : sedia
# games : games
# max : max
# jariangan : jariangan
# rusak : rusak
# gembel : gembel
# tod : tod
# susu : susu
# merk : merk
# ngentod : ngentod
# lemooott : lemooott
# down : down
# nonton : nonton
# rnhub : rnhub
# patah : patah
# karru : karru
# gbutuh : gbutuh
# detejen : detejen
# butuh : butuh
# cuman : cuman
# cuaca : cuaca
# doang : doang
# lambat : lambat
# mimin : mimin
# ngelawak : ngelawak
# sampah : sampah
# gaada : gaada
# menit : menit
# kacau : kacau
# ngentd : ngentd
# ngancurin : ngancurin
# mood : mood
# gara : gara
# ampas : ampas
# isiin : isiin
# kadang : kadang
# ngelak : ngelak
# ngepus : ngepus
# rank : rank
# turun : turun
# bronze : bronze
# dapatkan : dapat
# veronika : veronika
# brp : brp
# hadith : hadith
# berguna : guna
# tampilan : tampil
# connection : connection
# kasih : kasih
# auto : auto
# debet : debet
# pilihan : pilih
# bingung : bingung
# kesedot : sedot
# otomatis : otomatis
# aktif : aktif
# perpanjang : panjang
# maaf : maaf
# admin : admin
# saran : saran
# penikmat : nikmat
# harganya : harga
# puas : puas
# bermain : main
# streaming : streaming
# kekurangan : kurang
# mengakses : akses
# favorit : favorit
# dragon : dragon
# city : city
# bis : bis
# parahhhhhhhhhhhh : parahhhhhhhhhhhh
# jelekkkkk : jelekkkkk
# kalah : kalah
# indosatt : indosatt
# untung : untung
# emang : emang
# bab : bab
# buruk : buruk
# tolol : tolol
# tinggal : tinggal
# ngeleg : ngeleg
# owalah : owalah
# ngecek : ngecek
# setahun : tahun
# tutup : tutup
# pusat : pusat
# mental : mental
# kebal : kebal
# hujan : hujan
# kerasa : rasa
# amit : amit
# cocokx : cocokx
# nelpon : nelpon
# sapi : sapi
# beban : beban
# semangat : semangat
# memperburuk : buruk
# semugah : semugah
# abadi : abadi
# raj : raj
# jateng : jateng
# sragen : sragen
# lag : lag
# muda : muda
# han : han
# rejeki : rejeki
# allah : allah
# bet : bet
# kuda : kuda
# im : im
# nyimak : nyimak
# kek : kek
# eek : eek
# edge : edge
# cacat : cacat
# rb : rb
# postingan : postingan
# percaya : percaya
# mending : mending
# beralih : alih
# operator : operator
# penipuan : tipu
# modus : modus
# bacot : bacot
# berjaya : jaya
# gag : gag
# teouble : teouble
# kdang : kdang
# knp : knp
# plihan : plihan
# pkt : pkt
# omg : omg
# ngebug : ngebug
# push : push
# provider : provider
# ajng : ajng
# trlkom : trlkom
# pea : pea
# gencarin : gencarin
# asuuu : asuuu
# nnton : nnton
# anjimm : anjimm
# pokoknya : pokok
# combo : combo
# migrasi : migrasi
# hallo : hallo
# merasakan : rasa
# namanya : nama
# hadiah : hadiah
# gambarnya : gambar
# bat : bat
# pus : pus
# miskin : miskin
# hadiahnya : hadiah
# hoax : hoax
# nanya : nanya
# goblogg : goblogg
# kenpa : kenpa
# anjingg : anjingg
# tololl : tololl
# menang : menang
# undian : undi
# mingguan : minggu
# kupon : kupon
# dapet : dapet
# dalem : dalem
# tus : tus
# tusan : tus
# motor : motor
# stop : stop
# tersambung : sambung
# ketengan : keteng
# lgi : lgi
# gantinya : ganti
# lbh : lbh
# gue : gue
# lumutan : lumut
# hadiahapakah : hadiahapakah
# gampang : gampang
# lose : lose
# streak : streak
# kukukuntul : kuntul
# lainya : lai
# win : win
# terimakasih : terimakasih
# three : three
# selangit : langit
# sesak : sesak
# nafas : nafas
# pelanggan : langgan
# kabur : kabur
# saudi : saudi
# arabia : arabia
# data : data
# seluler : seluler
# trus : trus
# penyebab : sebab
# siang : siang
# kemarin : kemarin
# plus : plus
# tergsm : tergsm
# eiiiiii : eiiiiii
# paaket : paaket
# mahhal : mahhal
# koslestrol : koslestrol
# naikkk : naikkk
# sja : sja
# mantap : mantap
# sms : sms
# suruh : suruh
# daftar : daftar
# seminggu : minggu
# gabisa : gabisa
# dipake : dipake
# woooooooii : woooooooii
# napa : napa
# lemotttt : lemotttt
# pktn : pktn
# cepet : cepet
# habis : habis
# super : super
# dealnya : dealnya
# selesai : selesai
# anjlok : anjlok
# ngaruh : ngaruh
# aceh : aceh
# selatan : selatan
# labuhanhaji : labuhanhaji
# patahin : patahin
# luknut : luknut
# bos : bos
# manis : manis
# tlg : tlg
# jwb : jwb
# plnggn : plnggn
# thun : thun
# fake : fake
# recommended : recommended
# bnget : bnget
# pke : pke
# digital : digital
# eiiiii : eiiiii
# keong : keong
# give : give
# away : away
# diskon : diskon
# brensestifal : brensestifal
# jringn : jringn
# diperbaik : baik
# gajelas : gajelas
# bohong : bohong
# pon : pon
# papua : papua
# akui : aku
# janjikan : janji
# telkomsial : telkomsial
# abs : abs
# sprti : sprti
# sengaja : sengaja
# setting : setting
# ben : ben
# mobil : mobil
# cikupa : cikupa
# tangerang : tangerang
# multimedia : multimedia
# maketin : maketin
# utamanya : utama
# lagih : lagih
# tobat : tobat
# buktinya : bukti
# bertahun : tahun
# dear : dear
# via : via
# dana : dana
# transaksi : transaksi
# berhasil : hasil
# otaklu : otaklu
# kntol : kntol
# sinyalny : sinyalny
# robohin : robohin
# tower : tower
# telkomtol : telkomtol
# bantu : bantu
# drastis : drastis
# keseringan : sering
# dinaikin : dinaikin
# dikartu : kartu
# ditlp : ditlp
# ditawarin : ditawarin
# pascabayar : pascabayar
# complain : complain
# lonte : lonte
# gada : gada
# waras : waras
# komtol : komtol
# bangett : bangett
# komenan : komenan
# complan : complan
# make : make
# lemahnya : lemah
# kampung : kampung
# kuata : kuata
# letaknya : letak
# pegunungan : gunung
# tingkatkan : tingkat
# bahan : bahan
# evaluasi : evaluasi
# alamat : alamat
# ganggeng : ganggeng
# jogoresan : jogoresan
# purworejo : purworejo
# jawa : jawa
# trimakasih : trimakasih
# semoga : moga
# terbaiknya : baik
# pengen : ken
# handphone : handphone
# anak : anak
# laki : laki
# gede : gede
# coba : coba
# gaya : gaya
# burruk : burruk
# nikmati : nikmat
# setia : setia
# ama : ama
# katunya : katunya
# jadul : jadul
# ampe : ampe
# smartpon : smartpon
# hay : hay
# terblokir : blokir
# gagal : gagal
# terimakasi : terimakasi
# sya : sya
# dpt : dpt
# hadia : hadia
# hempon : hempon
# melemah : lemah
# sekarng : sekarng
# pidah : pidah
# untk : untk
# unlimitid : unlimitid
# utama : utama
# kmaren : kmaren
# aktifin : aktifin
# pls : pls
# keambil : ambil
# tulis : tulis
# kyk : kyk
# lemah : lemah
# mewah : mewah
# yahaaaa : yahaaaa
# lawak : lawak
# mendaftar : daftar
# ketarik : tarik
# bukti : bukti
# {'aahaii': 'aahaii', 'telkomsel': 'telkomsel', 'jaringan': 'jaring', 'bagus': 'bagus', 'internet': 'internet', 'lancar': 'lancar', 'menukar': 'tukar', 'poin': 'poin', 'kejutan': 'kejut', 'hkhkhk': 'hkhkhk', 'adain': 'adain', 'redem': 'redem', 'saldo': 'saldo', 'link': 'link', 'numpuk': 'numpuk', 'besok': 'besok', 'desember': 'desember', 'angus': 'angus', 'kebanyakan': 'banyak', 'korup': 'korup', 'kasian': 'kasi', 'noh': 'noh', 'pegawai': 'pegawai', 'naek': 'naek', 'bts': 'bts', 'upgrade': 'upgrade', 'bonus': 'bonus', 'paket': 'paket', 'nomor': 'nomor', '': '', 'sinyal': 'sinyal', 'woooiiii': 'woooiiii', 'internetnya': 'internetnya', 'menarik': 'tarik', 'apalagj': 'apalagj', 'penawarnya': 'tawar', 'promo': 'promo', 'sumpah': 'sumpah', 'peronika': 'peronika', 'ngga': 'ngga', 'bener': 'bener', 'hai': 'hai', 'kak': 'kak', 'cek': 'cek', 'byk': 'byk', 'bilangin': 'bilangin', 'gratis': 'gratis', 'ujung': 'ujung', 'hubungi': 'hubung', 'cnth': 'cnth', 'blm': 'blm', 'ambil': 'ambil', 'koin': 'koin', 'ujng': 'ujng', 'download': 'download', 'rool': 'rool', 'mbosankn': 'mbosankn', 'direedem': 'direedem', 'beneran': 'beneran', 'iklan': 'iklan', 'min': 'min', 'mohon': 'mohon', 'diupdate': 'diupdate', 'fitur': 'fitur', 'safe': 'safe', 'pulsa': 'pulsa', 'kayak': 'kayak', 'kartu': 'kartu', 'dongkarena': 'dongkarena', 'sayang': 'sayang', 'banget': 'banget', 'isi': 'isi', 'tersedot': 'sedot', 'dijadiin': 'dijadiin', 'kouta': 'kouta', 'sampe': 'sampe', 'dibandingkan': 'banding', 'beli': 'beli', 'bergb': 'bergb', 'membandingkan': 'banding', 'minggu': 'minggu', 'malam': 'malam', 'skrg': 'skrg', 'ancur': 'ancur', 'balas': 'balas', 'pending': 'pending', 'konsumen': 'konsumen', 'dirugikan': 'rugi', 'uunya': 'uunya', 'hak': 'hak', 'uda': 'uda', 'bayar': 'bayar', 'pelayanan': 'layan', 'fan': 'fan', 'hancur': 'hancur', 'gawat': 'gawat', 'lokasi': 'lokasi', 'sumut': 'sumut', 'mendingan': 'mending', 'jual': 'jual', 'cina': 'cina', 'perubahan': 'ubah', 'kelola': 'kelola', 'orang': 'orang', 'mahal': 'mahal', 'taik': 'taik', 'tolong': 'tolong', 'perbaikin': 'perbaikin', 'signal': 'signal', 'telfon': 'telfon', 'iternet': 'iternet', 'riau': 'riau', 'woy': 'woy', 'sehat': 'sehat', 'megang': 'megang', 'pas': 'pas', 'smp': 'smp', 'smpe': 'smpe', 'skrng': 'skrng', 'stabil': 'stabil', 'pokok': 'pokok', 'udah': 'udah', 'selambat': 'lambat', 'respond': 'respond', 'memperbaiki': 'baik', 'koneksi': 'koneksi', 'belajar': 'ajar', 'online': 'online', 'keganggu': 'ganggu', 'total': 'total', 'daerah': 'daerah', 'sitaro': 'sitaro', 'khusus': 'khusus', 'siau': 'siau', 'benci': 'benci', 'nge': 'nge', 'game': 'game', 'sinyalnya': 'sinyal', 'mangkin': 'mangkin', 'susah': 'susah', 'sekedar': 'dar', 'berbagi': 'bagi', 'pengalaman': 'alam', 'mengalami': 'alami', 'alami': 'alami', 'kuota': 'kuota', 'sakti': 'sakti', 'diiringi': 'iring', 'ketenangan': 'tenang', 'karna': 'karna', 'ujungnya': 'ujung', 'curangi': 'curang', 'ketentuan': 'tentu', 'sebulan': 'bulan', 'sulawesi': 'sulawesi', 'parah': 'parah', 'keresahan': 'resah', 'dengar': 'dengar', 'jasa': 'jasa', 'bot': 'bot', 'pengguna': 'guna', 'berasa': 'asa', 'jenuh': 'jenuh', 'layanan': 'layan', 'dipinggir': 'pinggir', 'jalan': 'jalan', 'full': 'full', 'masuk': 'masuk', 'krmh': 'krmh', 'jarak': 'jarak', 'meter': 'meter', 'kembang': 'kembang', 'kempis': 'kempis', 'moso': 'moso', 'pindah': 'pindah', 'rmh': 'rmh', 'telkomel': 'telkomel', 'pakai': 'pakai', 'modem': 'modem', 'advan': 'advan', 'cpe': 'cpe', 'seponsori': 'seponsori', 'mmpan': 'mmpan', 'solusi': 'solusi', 'kah': 'kah', 'mode': 'mode', 'pesawat': 'pesawat', 'udh': 'udh', 'jam': 'jam', 'segini': 'gin', 'bapuk': 'bapuk', 'anjiiim': 'anjiiim', 'aneh': 'aneh', 'ribu': 'ribu', 'paketan': 'paket', 'jamin': 'jamin', 'kagak': 'kagak', 'prnh': 'prnh', 'urus': 'urus', 'gitu': 'gitu', 'hilang': 'hilang', 'tlpan': 'tlpan', 'asuk': 'asuk', 'jarinqan': 'jarinqan', 'kaya': 'kaya', 'gini': 'gin', 'mon': 'mon', 'maap': 'maap', 'knpa': 'knpa', 'gaguna': 'gaguna', 'gimang': 'gimang', 'nich': 'ni ...
# ------------------------
# Pandas Apply:   0%|          | 0/229 [00:00<?, ?it/s]
#                                                comment  \
# 0    aahaii....telkomsel .....jaringan bagus..inter...
# 1    adain lagi dong redem saldo link aja poin gw d...
# 2    kebanyakan korup nih  kasian noh pegawai lo yg...
# 3    upgrade dari 3g ke 4g katanya dapat bonus pake...
# 4                                 sinyal woooiiii !!!!
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228            dapat 1 hadiah dari 2021 hadiah yg ada.
# 229                             udah mahal ngeleg lagi
# 230                                      bukti kan....
#
#                                       cleaning_comment  \
# 0    aahaii telkomsel jaringan bagus internet lanca...
# 1    adain lagi dong redem saldo link aja poin dah ...
# 2     kebanyakan korup nih kasian noh pegawai naek bts
# 3    upgrade dari katanya dapat bonus paket kok nom...
# 4                                     sinyal woooiiii
# ..                                                 ...
# 226                                   semoga dpt mobil
# 227  kak knp setiap mau mendaftar pulsa sya ketarik...
# 228                    dapat hadiah dari   hadiah ada
# 229                             udah mahal ngeleg lagi
# 230                                         bukti kan
#
#                                             tokenisasi  \
# 0    [aahaii, telkomsel, jaringan, bagus, internet,...
# 1    [adain, lagi, dong, redem, saldo, link, aja, p...
# 2    [kebanyakan, korup, nih, kasian, noh, pegawai,...
# 3    [upgrade, dari, katanya, dapat, bonus, paket, ...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                               [semoga, dpt, mobil]
# 227  [kak, knp, setiap, mau, mendaftar, pulsa, sya,...
# 228               [dapat, hadiah, dari, hadiah, ada, ]
# 229                        [udah, mahal, ngeleg, lagi]
# 230                                     [bukti, kan, ]
#
#                                               stopword  \
# 0    [aahaii, telkomsel, jaringan, bagus, internet,...
# 1    [adain, redem, saldo, link, poin, numpuk, beso...
# 2    [kebanyakan, korup, kasian, noh, pegawai, naek...
# 3    [upgrade, bonus, paket, nomor, bonus, paket, i...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                               [semoga, dpt, mobil]
# 227   [kak, knp, mendaftar, pulsa, sya, ketarik, mulu]
# 228                                 [hadiah, hadiah, ]
# 229                              [udah, mahal, ngeleg]
# 230                                          [bukti, ]
#
#                                               stemming
# 0    [aahaii, telkomsel, jaring, bagus, internet, l...
# 1    [adain, redem, saldo, link, poin, numpuk, beso...
# 2       [banyak, korup, kasi, noh, pegawai, naek, bts]
# 3    [upgrade, bonus, paket, nomor, bonus, paket, i...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                                 [moga, dpt, mobil]
# 227        [kak, knp, daftar, pulsa, sya, tarik, mulu]
# 228                                 [hadiah, hadiah, ]
# 229                              [udah, mahal, ngeleg]
# 230                                          [bukti, ]
#
# [229 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [aahaii, telkomsel, jaring, bagus, internet, l...
# 1    [adain, redem, saldo, link, poin, numpuk, beso...
# 2       [banyak, korup, kasi, noh, pegawai, naek, bts]
# 3    [upgrade, bonus, paket, nomor, bonus, paket, i...
# 4                                 [sinyal, woooiiii, ]
# ..                                                 ...
# 226                                 [moga, dpt, mobil]
# 227        [kak, knp, daftar, pulsa, sya, tarik, mulu]
# 228                                 [hadiah, hadiah, ]
# 229                              [udah, mahal, ngeleg]
# 230                                          [bukti, ]
#
# [229 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_10.xlsx')
