# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    Woi Telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          Min ko gak bisa isi voucher
# 4    Sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  Tiap hari login daily checkin pas mau ngambil ...
# 178                               Lancar dari hongkong
# 179                    Paket 25gb ko skrng ada fup nya
# 180  Kenapa Saya Tidak Bisa Mengirim SMS Di Nomor S...
#
# [181 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    Woi Telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          Min ko gak bisa isi voucher
# 4    Sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  Tiap hari login daily checkin pas mau ngambil ...
# 178                               Lancar dari hongkong
# 179                    Paket 25gb ko skrng ada fup nya
# 180  Kenapa Saya Tidak Bisa Mengirim SMS Di Nomor S...
#
# [179 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    woi telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          min ko gak bisa isi voucher
# 4    sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                    paket 25gb ko skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms di nomor s...
#
# [179 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    woi telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          min ko gak bisa isi voucher
# 4    sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                    paket 25gb ko skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms di nomor s...
#
#                                       cleaning_comment
# 0    duh signal telkomsel masa harus keluar rumah c...
# 1    woi telkomsel bikin pulsa save nya sudah beli ...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                             min gak bisa isi voucher
# 4     mau isi voucher paket data knp timbul tulisan...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                        paket  gb skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms nomor saya...
#
# [179 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    woi telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          min ko gak bisa isi voucher
# 4    sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                    paket 25gb ko skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms di nomor s...
#
#                                       cleaning_comment  \
# 0    duh signal telkomsel masa harus keluar rumah c...
# 1    woi telkomsel bikin pulsa save nya sudah beli ...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                             min gak bisa isi voucher
# 4     mau isi voucher paket data knp timbul tulisan...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                        paket  gb skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms nomor saya...
#
#                                             tokenisasi
# 0    [duh, signal, telkomsel, masa, harus, keluar, ...
# 1    [woi, telkomsel, bikin, pulsa, save, nya, suda...
# 2    [sehubungan, dengan, peraturan, pemerintah, te...
# 3                       [min, gak, bisa, isi, voucher]
# 4    [, mau, isi, voucher, paket, data, knp, timbul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggua...
# 177  [tiap, hari, login, daily, checkin, pas, mau, ...
# 178                           [lancar, dari, hongkong]
# 179                  [paket, gb, skrng, ada, fup, nya]
# 180  [kenapa, saya, tidak, bisa, mengirim, sms, nom...
#
# [179 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    woi telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          min ko gak bisa isi voucher
# 4    sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                    paket 25gb ko skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms di nomor s...
#
#                                       cleaning_comment  \
# 0    duh signal telkomsel masa harus keluar rumah c...
# 1    woi telkomsel bikin pulsa save nya sudah beli ...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                             min gak bisa isi voucher
# 4     mau isi voucher paket data knp timbul tulisan...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                        paket  gb skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms nomor saya...
#
#                                             tokenisasi  \
# 0    [duh, signal, telkomsel, masa, harus, keluar, ...
# 1    [woi, telkomsel, bikin, pulsa, save, nya, suda...
# 2    [sehubungan, dengan, peraturan, pemerintah, te...
# 3                       [min, gak, bisa, isi, voucher]
# 4    [, mau, isi, voucher, paket, data, knp, timbul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggua...
# 177  [tiap, hari, login, daily, checkin, pas, mau, ...
# 178                           [lancar, dari, hongkong]
# 179                  [paket, gb, skrng, ada, fup, nya]
# 180  [kenapa, saya, tidak, bisa, mengirim, sms, nom...
#
#                                               stopword
# 0    [duh, signal, telkomsel, rumah, cari, signal, ...
# 1    [woi, telkomsel, pulsa, save, beli, paket, dat...
# 2    [sehubungan, peraturan, pemerintah, ppkm, ppkm...
# 3                                  [min, isi, voucher]
# 4    [, isi, voucher, paket, data, knp, timbul, tul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggua...
# 177  [login, daily, checkin, pas, ngambil, puncak, ...
# 178                                 [lancar, hongkong]
# 179                            [paket, gb, skrng, fup]
# 180           [mengirim, sms, nomor, mohon, bantuanya]
#
# [179 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 640
# ------------------------
# duh : duh
# signal : signal
# telkomsel : telkomsel
# rumah : rumah
# cari : cari
# bagus : bagus
# woi : woi
# pulsa : pulsa
# save : save
# beli : beli
# paket : paket
# data : data
# kau : kau
# sedot : sedot
# drakula : drakula
#  :
# sehubungan : hubung
# peraturan : atur
# pemerintah : perintah
# ppkm : ppkm
# sinyal : sinyal
# jaringan : jaring
# internet : internet
# silkan : sil
# pindah : pindah
# provider : provider
# terimakasih : terimakasih
# min : min
# isi : isi
# voucher : voucher
# knp : knp
# timbul : timbul
# tulisan : tulis
# cobalah : coba
# sibuk : sibuk
# trus : trus
# restart : restart
# ttp : ttp
# gimana : gimana
# udh : udh
# kali : kali
# kuota : kuota
# ketengan : keteng
# youtube : youtube
# tpi : tpi
# pakai : pakai
# nggk : nggk
# coba : coba
# ganti : ganti
# kartupun : kartu
# pelayanannya : layan
# aktifkan : aktif
# forji : forji
# wilayah : wilayah
# ladolima : ladolima
# keotengah : keotengah
# triji : triji
# hutan : hutan
# unlimax : unlimax
# kena : kena
# fup : fup
# internya : internya
# gabisa : gabisa
# kirim : kirim
# chat : chat
# dasar : dasar
# telkont : telkont
# awas : awas
# paketnya : paket
# penuh : penuh
# konspirasi : konspirasi
# berubah : ubah
# makan : makan
# melapor : lapor
# infokan : info
# bahwasannya : bahwasannya
# bla : bla
# kesimpulannya : simpul
# menyalahk : menyalahk
# seandainya : anda
# unlimited : unlimited
# aktifnya : aktif
# pendek : pendek
# harganya : harga
# terjangkau : jangkau
# operator : operator
# sebelah : belah
# kenpa : kenpa
# mmasukin : mmasukin
# vocher : vocher
# poin : poin
# tuker : tuker
# mb : mb
# buka : buka
# mbanking : mbanking
# paketan : paket
# mahal : mahal
# bangat : bangat
# plis : plis
# tolong : tolong
# gangguan : ganggu
# titik : titik
# ditoko : toko
# geser : geser
# toko : toko
# meter : meter
# telkom : telkom
# bhong : bhong
# halo : halo
# unli : unli
# darurat : darurat
# mencekik : cekik
# merah : merah
# tunggu : tunggu
# tanggal : tanggal
# mainnya : main
# hadiah : hadiah
# max : max
# klaim : klaim
# btul : btul
# mnta : mnta
# dihadjarrrrr : dihadjarrrrr
# males : males
# mencapai : capai
# limit : limit
# lupa : lupa
# mematikan : mati
# wes : wes
# wassalam : wassalam
# pulsamu : pulsa
# habis : habis
# permisi : permisi
# beda : beda
# korban : korban
# dipakai : pakai
# kaga : kaga
# ludes : ludes
# maaf : maaf
# kak : kak
# kartu : kartu
# kontraknya : kontrak
# matikan : mati
# apn : apn
# home : home
# akses : akses
# internetan : internetan
# gratis : gratis
# kususnya : sus
# pulau : pulau
# jawa : jawa
# kecewa : kecewa
# gratisan : gratis
# adil : adil
# kenapaa : kenapaa
# nomor : nomor
# ter : ter
# registrasi : registrasi
# nomornya : nomor
# dlm : dlm
# tenggang : tenggang
# daerah : daerah
# jelek : jelek
# banget : banget
# jam : jam
# siang : siang
# jaringannya : jaring
# numpang : numpang
# knpa : knpa
# nerima : nerima
# pesan : pesan
# susah : susah
# bermasalah : masalah
# lolla : lolla
# aplikasi : aplikasi
# taik : taik
# kek : kek
# dancok : dancok
# lemot : lot
# speed : speed
# nyampe : nyampe
# kbps : kbps
# gajelas : gajelas
# hancur : hancur
# langsung : langsung
# taktersisa : taktersisa
# daftar : daftar
# mending : mending
# gua : gua
# nge : nge
# bug : bug
# parah : parah
# knapa : knapa
# pakek : pakek
# simpati : simpati
# indonesia : indonesia
# sambat : sambat
# pengguna : guna
# selamat : selamat
# malam : malam
# buhadi : buhadi
# udah : udah
# leletnya : lelet
# kaya : kaya
# kura : kura
# panik : panik
# gakk : gakk
# berulang : ulang
# inbok : inbok
# drespon : drespon
# tindakin : tindakin
# pembenahan : benah
# gerangan : gerangan
# komplin : komplin
# tersedot : sedot
# mubazir : mubazir
# donasikan : donasi
# jual : jual
# warna : warna
# logo : logo
# harga : harga
# smua : smua
# game : game
# ngakak : ngakak
# edan : edan
# skr : skr
# uda : uda
# madam : madam
# lambat : lambat
# main : main
# online : online
# mohon : mohon
# perbaiki : baik
# hai : hai
# nyaman : nyaman
# terkait : kait
# kendala : kendala
# stabil : stabil
# mencoba : coba
# refresh : refresh
# pindahkan : pindah
# mode : mode
# otomatis : otomatis
# manual : manual
# kembalikan : kembali
# khusus : khusus
# penguna : penguna
# android : android
# menghasil : hasil
# uang : uang
# lho : lho
# hah : hah
# gampang : gampang
# tinggal : tinggal
# hormat : hormat
# menghentikan : henti
# iklan : iklan
# mytelkomsel : mytelkomsel
# selangit : langit
# cacat : cacat
# bnget : bnget
# bwt : bwt
# von : von
# mkn : mkn
# plng : plng
# tuk : tuk
# memperbaki : baki
# kwalitas : kwalitas
# jaringn : jaringn
# skrng : skrng
# combo : combo
# sakti : sakti
# nonton : nonton
# ngelag : ngelag
# melulu : melulu
# serasa : serasa
# mengguna : guna
# lancar : lancar
# cuman : cuman
# kualitas : kualitas
# video : video
# elo : elo
# kmna : kmna
# klw : klw
# wktu : wktu
# ngangguan : ngangguan
# diamin : amin
# sistem : sistem
# mulu : mulu
# tidk : tidk
# dpt : dpt
# meng : meng
# lakukan : laku
# merestart : merestart
# eror : eror
# berkelanjutan : lanjut
# sampe : sampe
# vocer : vocer
# masuk : masuk
# hmm : hmm
# sinyalnya : sinyal
# beres : beres
# sinyale : sinyale
# picek : picek
# larang : larang
# bosok : bosok
# admin : admin
# paok : paok
# mna : mna
# setan : setan
# helehh : helehh
# ping : ping
# lag : lag
# woyy : woyy
# cek : cek
# multimedia : multimedia
# gamemax : gamemax
# ber : ber
# pubg : pubg
# murahkan : murah
# lgi : lgi
# jari : jari
# pke : pke
# blok : blok
# doang : doang
# kenceng : kenceng
# dafatrin : dafatrin
# harian : hari
# ngerti : ngerti
# gue : gue
# maen : maen
# mobile : mobile
# legend : legend
# benerin : benerin
# woy : woy
# tenang : tenang
# ilang : ilang
# ceria : ceria
# kepotong : potong
# minnnnnn : minnnnnn
# siyale : siyale
# kyok : kyok
# minjem : minjem
# daftarin : daftarin
# info : info
# promo : promo
# bekasi : bekas
# timur : timur
# taek : taek
# msih : msih
# lokal : lokal
# giliran : gilir
# woyyyyyyyy : woyyyyyyyy
# pegawai : pegawai
# kagak : kagak
# bot : bot
# selesai : selesai
# haduhhhh : haduhhhh
# namanya : nama
# payah : payah
# karti : karti
# minggu : minggu
# kemaren : kemaren
# keisi : isi
# puksa : puksa
# keblokir : blokir
# diaktifkan : aktif
# gpp : gpp
# nomernya : nomernya
# paketin : paketin
# oke : oke
# nggak : nggak
# pas : pas
# beranda : beranda
# muncul : muncul
# sedikitpun : sedikit
# nampak : nampak
# kode : kode
# dial : dial
# murah : murah
# tekomsel : tekomsel
# masker : masker
# kesini : kesini
# sempak : sempak
# gb : gb
# lol : lol
# gara : gara
# telat : telat
# terblokir : blokir
# diaktivkan : diaktivkan
# rekomendasi : rekomendasi
# sebanding : banding
# perasaan : asa
# komen : komen
# karna : karna
# bales : bales
# resmi : resmi
# barusan : barusan
# notifikasi : notifikasi
# dikasih : kasih
# kesempatan : sempat
# amplop : amplop
# berhadiah : hadiah
# gambar : gambar
# sertakan : serta
# beneran : beneran
# penipuan : tipu
# apk : apk
# pilihan : pilih
# saktinya : sakti
# dajjal : dajjal
# sampah : sampah
# dulunya : dulunya
# rb : rb
# tgl : tgl
# juli : juli
# kamfret : kamfret
# masah : masah
# sekelas : kelas
# sesuai : sesuai
# pinjam : pinjam
# pembayaran : bayar
# via : via
# dana : dana
# kah : kah
# login : login
# saran : saran
# dll : dll
# kurangi : kurang
# tambahkan : tambah
# utama : utama
# sayang : sayang
# tsb : tsb
# abis : abis
# hallo : hallo
# berkurang : kurang
# bru : bru
# kejadian : jadi
# terulang : ulang
# bener : bener
# kesal : kesal
# dijaman : jam
# duit : duit
# ngertiin : ngertiin
# rela : rela
# jajan : jajan
# dem : dem
# ngisi : ngisi
# dohkn : dohkn
# atlet : atlet
# glug : glug
# tikar : tikar
# pulg : pulg
# kerja : kerja
# sawa : sawa
# msi : msi
# bdok : bdok
# berholaraga : berholaraga
# ajng : ajng
# koc : koc
# sayag : sayag
# berumur : umur
# klik : klik
# tautan : taut
# bonus : bonus
# smsnya : smsnya
# gagal : gagal
# mls : mls
# semoga : moga
# berhasil : hasil
# amiin : amiin
# doa : doa
# tsel : tsel
# cepat : cepat
# bangkrut : bangkrut
# gulung : gulung
# banya : banya
# mengeluhkan : keluh
# emg : emg
# gadi : gadi
# denger : denger
# ditinggal : tinggal
# penggunanya : guna
# ancurr : ancurr
# bguss : bguss
# jdi : jdi
# kntl : kntl
# butut : butut
# sengja : sengja
# kerobek : kerobek
# makasih : makasih
# free : free
# pengumumannya : umum
# hilang : hilang
# diganti : ganti
# undian : undi
# hobi : hobi
# disarankan : saran
# telkomtod : telkomtod
# suka : suka
# kecopet : copet
# sulawesi : sulawesi
# niat : niat
# tolonglah : tolong
# plosok : plosok
# dikasi : kasi
# kembalikn : kembalikn
# sperti : sperti
# kesian : kesi
# kemahalan : mahal
# silver : silver
# kasihan : kasihan
# org : org
# misquen : misquen
# telkomselku : telkomselku
# sms : sms
# sma : sma
# nlfn : nlfn
# program : program
# lucky : lucky
# prize : prize
# penerima : terima
# bantuan : bantu
# belajar : ajar
# kemendikbud : kemendikbud
# undi : undi
# utara : utara
# tondano : tondano
# ancur : ancur
# hujan : hujan
# angin : angin
# rusak : rusak
# emosi : emosi
# ama : ama
# terdaftar : daftar
# nama : nama
# aneh : aneh
# asuuuuuu : asuuuuuu
# non : non
# ilangan : ilangan
# tertipu : tipu
# membeli : beli
# seharga : harga
# counter : counter
# zonk : zonk
# kartunya : kartu
# you : you
# tube : tube
# sanga : sanga
# katu : katu
# perihal : perihal
# unlimitedmax : unlimitedmax
# telkomnyet : telkomnyet
# perampok : rampok
# transaksi : transaksi
# pemakaian : pakai
# rupiah : rupiah
# berkomentar : komentar
# kekecewaannya : kecewa
# bkn : bkn
# dihuni : huni
# orang : orang
# anak : anak
# hrus : hrus
# diajarkan : ajar
# giga : giga
# sminggu : sminggu
# sinyalnx : sinyalnx
# unreg : unreg
# hangus : hangus
# hafal : hafal
# bgmn : bgmn
# turunkan : turun
# secepat : cepat
# cepatnya : cepat
# kerjaan : kerja
# gaada : gaada
# terhormat : hormat
# vhocer : vhocer
# tdi : tdi
# lainya : lai
# sel : sel
# sultan : sultan
# babyk : babyk
# bos : bos
# jan : jan
# produk : produk
# loe : loe
# geratis : gerat
# booster : booster
# berlaku : laku
# bln : bln
# nanya : nanya
# pagi : pagi
# ngaktifin : ngaktifin
# halah : halah
# puas : puas
# pertanyaanya : pertanyaanya
# daring : daring
# krna : krna
# mmng : mmng
# puncak : puncak
# gunung : gunung
# ttap : ttap
# lemott : lemott
# gurunya : guru
# marah : marah
# bljr : bljr
# padhal : padhal
# curang : curang
# bun : bun
# diatur : atur
# turun : turun
# nyedot : nyedot
# pulsaa : pulsaa
# ampe : ampe
# bisnis : bisnis
# bosque : bosque
# gitu : gitu
# jalan : jalan
# mendung : mendung
# huuuu : huuuu
# tra : tra
# gada : gada
# kualitaa : kualitaa
# klim : klim
# bunos : bunos
# sosmed : sosmed
# sihh : sihh
# watsapp : watsapp
# monetary : monetary
# maksud : maksud
# masukin : masukin
# emang : emang
# seharian : hari
# daily : daily
# checkin : checkin
# ngambil : ngambil
# hongkong : hongkong
# mengirim : kirim
# bantuanya : bantuanya
# {'duh': 'duh', 'signal': 'signal', 'telkomsel': 'telkomsel', 'rumah': 'rumah', 'cari': 'cari', 'bagus': 'bagus', 'woi': 'woi', 'pulsa': 'pulsa', 'save': 'save', 'beli': 'beli', 'paket': 'paket', 'data': 'data', 'kau': 'kau', 'sedot': 'sedot', 'drakula': 'drakula', '': '', 'sehubungan': 'hubung', 'peraturan': 'atur', 'pemerintah': 'perintah', 'ppkm': 'ppkm', 'sinyal': 'sinyal', 'jaringan': 'jaring', 'internet': 'internet', 'silkan': 'sil', 'pindah': 'pindah', 'provider': 'provider', 'terimakasih': 'terimakasih', 'min': 'min', 'isi': 'isi', 'voucher': 'voucher', 'knp': 'knp', 'timbul': 'timbul', 'tulisan': 'tulis', 'cobalah': 'coba', 'sibuk': 'sibuk', 'trus': 'trus', 'restart': 'restart', 'ttp': 'ttp', 'gimana': 'gimana', 'udh': 'udh', 'kali': 'kali', 'kuota': 'kuota', 'ketengan': 'keteng', 'youtube': 'youtube', 'tpi': 'tpi', 'pakai': 'pakai', 'nggk': 'nggk', 'coba': 'coba', 'ganti': 'ganti', 'kartupun': 'kartu', 'pelayanannya': 'layan', 'aktifkan': 'aktif', 'forji': 'forji', 'wilayah': 'wilayah', 'ladolima': 'ladolima', 'keotengah': 'keotengah', 'triji': 'triji', 'hutan': 'hutan', 'unlimax': 'unlimax', 'kena': 'kena', 'fup': 'fup', 'internya': 'internya', 'gabisa': 'gabisa', 'kirim': 'kirim', 'chat': 'chat', 'dasar': 'dasar', 'telkont': 'telkont', 'awas': 'awas', 'paketnya': 'paket', 'penuh': 'penuh', 'konspirasi': 'konspirasi', 'berubah': 'ubah', 'makan': 'makan', 'melapor': 'lapor', 'infokan': 'info', 'bahwasannya': 'bahwasannya', 'bla': 'bla', 'kesimpulannya': 'simpul', 'menyalahk': 'menyalahk', 'seandainya': 'anda', 'unlimited': 'unlimited', 'aktifnya': 'aktif', 'pendek': 'pendek', 'harganya': 'harga', 'terjangkau': 'jangkau', 'operator': 'operator', 'sebelah': 'belah', 'kenpa': 'kenpa', 'mmasukin': 'mmasukin', 'vocher': 'vocher', 'poin': 'poin', 'tuker': 'tuker', 'mb': 'mb', 'buka': 'buka', 'mbanking': 'mbanking', 'paketan': 'paket', 'mahal': 'mahal', 'bangat': 'bangat', 'plis': 'plis', 'tolong': 'tolong', 'gangguan': 'ganggu', 'titik': 'titik', 'ditoko': 'toko', 'geser': 'geser', 'toko': 'toko', 'meter': 'meter', 'telkom': 'telkom', 'bhong': 'bhong', 'halo': 'halo', 'unli': 'unli', 'darurat': 'darurat', 'mencekik': 'cekik', 'merah': 'merah', 'tunggu': 'tunggu', 'tanggal': 'tanggal', 'mainnya': 'main', 'hadiah': 'hadiah', 'max': 'max', 'klaim': 'klaim', 'btul': 'btul', 'mnta': 'mnta', 'dihadjarrrrr': 'dihadjarrrrr', 'males': 'males', 'mencapai': 'capai', 'limit': 'limit', 'lupa': 'lupa', 'mematikan': 'mati', 'wes': 'wes', 'wassalam': 'wassalam', 'pulsamu': 'pulsa', 'habis': 'habis', 'permisi': 'permisi', 'beda': 'beda', 'korban': 'korban', 'dipakai': 'pakai', 'kaga': 'kaga', 'ludes': 'ludes', 'maaf': 'maaf', 'kak': 'kak', 'kartu': 'kartu', 'kontraknya': 'kontrak', 'matikan': 'mati', 'apn': 'apn', 'home': 'home', 'akses': 'akses', 'internetan': 'internetan', 'gratis': 'gratis', 'kususnya': 'sus', 'pulau': 'pulau', 'jawa': 'jawa', 'kecewa': 'kecewa', 'gratisan': 'gratis', 'adil': 'adil', 'kenapaa': 'kenapaa', 'nomor': 'nomor', 'ter': 'ter', 'registrasi': 'registrasi', 'nomornya': 'nomor', 'dlm': 'dlm', 'tenggang': 'tenggang', 'daerah': 'daerah', 'jelek': 'jelek', 'banget': 'banget', 'jam': 'jam', 'siang': 'siang', 'jaringannya': 'jaring', 'numpang': 'numpang', 'knpa': 'knpa', 'nerima': 'nerima', 'pesan': 'pesan', 'susah': 'susah', 'bermasalah': 'masalah', 'lolla': 'lolla', 'aplikasi': 'aplikasi', 'taik': 'taik', 'kek': 'kek', 'dancok': 'dancok', 'lemot': 'lot', 'speed': 'speed', 'nyampe': 'nyampe', 'kbps': 'kbps', 'gajelas': 'gajelas', 'hancur': 'hancur', 'langsung': 'langsung', 'taktersisa': 'taktersisa', 'daftar': 'daftar', 'mending': 'mending', 'gua': 'gua', 'nge': 'nge', 'bug': 'bug', 'parah': 'parah', 'knapa': 'knapa', 'pakek': 'pakek', 'simpati': 'simpati', 'indonesia': 'indonesia', 'sambat': 'sambat', 'pengguna': 'guna', 'selamat': 'selamat', 'malam': 'malam', 'buhadi': 'buhadi', 'udah': 'udah', 'leletnya': 'lelet', 'kaya': 'kaya', 'kura': 'kura', 'panik': 'panik', 'gakk': 'gakk', 'berulang': 'ulang', 'inbok': 'inbok' ...
# ------------------------
# Pandas Apply:   0%|          | 0/179 [00:00<?, ?it/s]
#                                                comment  \
# 0    duh signal telkomsel,masa harus keluar rumah.c...
# 1    woi telkomsel  bikin pulsa save nya ...sudah b...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                          min ko gak bisa isi voucher
# 4    sy mau isi voucher paket data knp yg timbul tu...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                    paket 25gb ko skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms di nomor s...
#
#                                       cleaning_comment  \
# 0    duh signal telkomsel masa harus keluar rumah c...
# 1    woi telkomsel bikin pulsa save nya sudah beli ...
# 2    sehubungan dengan peraturan pemerintah tentang...
# 3                             min gak bisa isi voucher
# 4     mau isi voucher paket data knp timbul tulisan...
# ..                                                 ...
# 176  gua gabisa masukin voucher emang gangguan apa ...
# 177  tiap hari login daily checkin pas mau ngambil ...
# 178                               lancar dari hongkong
# 179                        paket  gb skrng ada fup nya
# 180  kenapa saya tidak bisa mengirim sms nomor saya...
#
#                                             tokenisasi  \
# 0    [duh, signal, telkomsel, masa, harus, keluar, ...
# 1    [woi, telkomsel, bikin, pulsa, save, nya, suda...
# 2    [sehubungan, dengan, peraturan, pemerintah, te...
# 3                       [min, gak, bisa, isi, voucher]
# 4    [, mau, isi, voucher, paket, data, knp, timbul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggua...
# 177  [tiap, hari, login, daily, checkin, pas, mau, ...
# 178                           [lancar, dari, hongkong]
# 179                  [paket, gb, skrng, ada, fup, nya]
# 180  [kenapa, saya, tidak, bisa, mengirim, sms, nom...
#
#                                               stopword  \
# 0    [duh, signal, telkomsel, rumah, cari, signal, ...
# 1    [woi, telkomsel, pulsa, save, beli, paket, dat...
# 2    [sehubungan, peraturan, pemerintah, ppkm, ppkm...
# 3                                  [min, isi, voucher]
# 4    [, isi, voucher, paket, data, knp, timbul, tul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggua...
# 177  [login, daily, checkin, pas, ngambil, puncak, ...
# 178                                 [lancar, hongkong]
# 179                            [paket, gb, skrng, fup]
# 180           [mengirim, sms, nomor, mohon, bantuanya]
#
#                                               stemming
# 0    [duh, signal, telkomsel, rumah, cari, signal, ...
# 1    [woi, telkomsel, pulsa, save, beli, paket, dat...
# 2    [hubung, atur, perintah, ppkm, ppkm, sinyal, j...
# 3                                  [min, isi, voucher]
# 4    [, isi, voucher, paket, data, knp, timbul, tul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggu,...
# 177  [login, daily, checkin, pas, ngambil, puncak, ...
# 178                                 [lancar, hongkong]
# 179                            [paket, gb, skrng, fup]
# 180              [kirim, sms, nomor, mohon, bantuanya]
#
# [179 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [duh, signal, telkomsel, rumah, cari, signal, ...
# 1    [woi, telkomsel, pulsa, save, beli, paket, dat...
# 2    [hubung, atur, perintah, ppkm, ppkm, sinyal, j...
# 3                                  [min, isi, voucher]
# 4    [, isi, voucher, paket, data, knp, timbul, tul...
# ..                                                 ...
# 176  [gua, gabisa, masukin, voucher, emang, ganggu,...
# 177  [login, daily, checkin, pas, ngambil, puncak, ...
# 178                                 [lancar, hongkong]
# 179                            [paket, gb, skrng, fup]
# 180              [kirim, sms, nomor, mohon, bantuanya]
#
# [179 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_7.xlsx')
