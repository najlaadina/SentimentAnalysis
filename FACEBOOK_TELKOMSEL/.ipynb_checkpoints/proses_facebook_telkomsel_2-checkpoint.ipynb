# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Gmna crax beli paket unlimited 25GB kartu baru...
# 1    Telkomsel tolol gw. Main game jaringan nya nge...
# 2                            Telkomsel is the best dah
# 3    Tolong donk sinyal di benerin. Sekarang buat m...
# 4    Kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          Min cara supaya jaringan gk tolol gimna.?
# 337  Ini gmn sih katanya unlimited game tapi pas ma...
# 338           Kenapa jaringan TELKOMSEL semakin parah?
# 339  Min kenapa promo paket unlimited saya selalu d...
# 340  Ini kenapa peket reguler sy yg kesedot ni kena...
#
# [341 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Gmna crax beli paket unlimited 25GB kartu baru...
# 1    Telkomsel tolol gw. Main game jaringan nya nge...
# 2                            Telkomsel is the best dah
# 3    Tolong donk sinyal di benerin. Sekarang buat m...
# 4    Kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          Min cara supaya jaringan gk tolol gimna.?
# 337  Ini gmn sih katanya unlimited game tapi pas ma...
# 338           Kenapa jaringan TELKOMSEL semakin parah?
# 339  Min kenapa promo paket unlimited saya selalu d...
# 340  Ini kenapa peket reguler sy yg kesedot ni kena...
#
# [332 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    gmna crax beli paket unlimited 25gb kartu baru...
# 1    telkomsel tolol gw. main game jaringan nya nge...
# 2                            telkomsel is the best dah
# 3    tolong donk sinyal di benerin. sekarang buat m...
# 4    kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          min cara supaya jaringan gk tolol gimna.?
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah?
# 339  min kenapa promo paket unlimited saya selalu d...
# 340  ini kenapa peket reguler sy yg kesedot ni kena...
#
# [332 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    gmna crax beli paket unlimited 25gb kartu baru...
# 1    telkomsel tolol gw. main game jaringan nya nge...
# 2                            telkomsel is the best dah
# 3    tolong donk sinyal di benerin. sekarang buat m...
# 4    kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          min cara supaya jaringan gk tolol gimna.?
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah?
# 339  min kenapa promo paket unlimited saya selalu d...
# 340  ini kenapa peket reguler sy yg kesedot ni kena...
#
#                                       cleaning_comment
# 0    gmna crax beli paket unlimited  gb kartu baru ...
# 1    telkomsel tolol main game jaringan nya ngedown...
# 2                               telkomsel the best dah
# 3    tolong donk sinyal benerin sekarang buat maen ...
# 4    kenapa sinyal unlimited sekarang jadi leemot bgt
# ..                                                 ...
# 336              min cara supaya jaringan tolol gimna
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah
# 339  min kenapa promo paket unlimited saya selalu a...
# 340  ini kenapa peket reguler kesedot kenapa pakaet...
#
# [332 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    gmna crax beli paket unlimited 25gb kartu baru...
# 1    telkomsel tolol gw. main game jaringan nya nge...
# 2                            telkomsel is the best dah
# 3    tolong donk sinyal di benerin. sekarang buat m...
# 4    kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          min cara supaya jaringan gk tolol gimna.?
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah?
# 339  min kenapa promo paket unlimited saya selalu d...
# 340  ini kenapa peket reguler sy yg kesedot ni kena...
#
#                                       cleaning_comment  \
# 0    gmna crax beli paket unlimited  gb kartu baru ...
# 1    telkomsel tolol main game jaringan nya ngedown...
# 2                               telkomsel the best dah
# 3    tolong donk sinyal benerin sekarang buat maen ...
# 4    kenapa sinyal unlimited sekarang jadi leemot bgt
# ..                                                 ...
# 336              min cara supaya jaringan tolol gimna
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah
# 339  min kenapa promo paket unlimited saya selalu a...
# 340  ini kenapa peket reguler kesedot kenapa pakaet...
#
#                                             tokenisasi
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1    [telkomsel, tolol, main, game, jaringan, nya, ...
# 2                          [telkomsel, the, best, dah]
# 3    [tolong, donk, sinyal, benerin, sekarang, buat...
# 4    [kenapa, sinyal, unlimited, sekarang, jadi, le...
# ..                                                 ...
# 336      [min, cara, supaya, jaringan, tolol, gimna, ]
# 337  [ini, gmn, sih, katanya, unlimited, game, tapi...
# 338    [kenapa, jaringan, telkomsel, semakin, parah, ]
# 339  [min, kenapa, promo, paket, unlimited, saya, s...
# 340  [ini, kenapa, peket, reguler, kesedot, kenapa,...
#
# [332 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    gmna crax beli paket unlimited 25gb kartu baru...
# 1    telkomsel tolol gw. main game jaringan nya nge...
# 2                            telkomsel is the best dah
# 3    tolong donk sinyal di benerin. sekarang buat m...
# 4    kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          min cara supaya jaringan gk tolol gimna.?
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah?
# 339  min kenapa promo paket unlimited saya selalu d...
# 340  ini kenapa peket reguler sy yg kesedot ni kena...
#
#                                       cleaning_comment  \
# 0    gmna crax beli paket unlimited  gb kartu baru ...
# 1    telkomsel tolol main game jaringan nya ngedown...
# 2                               telkomsel the best dah
# 3    tolong donk sinyal benerin sekarang buat maen ...
# 4    kenapa sinyal unlimited sekarang jadi leemot bgt
# ..                                                 ...
# 336              min cara supaya jaringan tolol gimna
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah
# 339  min kenapa promo paket unlimited saya selalu a...
# 340  ini kenapa peket reguler kesedot kenapa pakaet...
#
#                                             tokenisasi  \
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1    [telkomsel, tolol, main, game, jaringan, nya, ...
# 2                          [telkomsel, the, best, dah]
# 3    [tolong, donk, sinyal, benerin, sekarang, buat...
# 4    [kenapa, sinyal, unlimited, sekarang, jadi, le...
# ..                                                 ...
# 336      [min, cara, supaya, jaringan, tolol, gimna, ]
# 337  [ini, gmn, sih, katanya, unlimited, game, tapi...
# 338    [kenapa, jaringan, telkomsel, semakin, parah, ]
# 339  [min, kenapa, promo, paket, unlimited, saya, s...
# 340  [ini, kenapa, peket, reguler, kesedot, kenapa,...
#
#                                               stopword
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1    [telkomsel, tolol, main, game, jaringan, ngedown]
# 2                               [telkomsel, the, best]
# 3    [tolong, donk, sinyal, benerin, maen, game, la...
# 4                        [sinyal, unlimited, leemot, ]
# ..                                                 ...
# 336                    [min, jaringan, tolol, gimna, ]
# 337  [gmn, unlimited, game, pas, maen, game, ngeleg...
# 338                     [jaringan, telkomsel, parah, ]
# 339  [min, promo, paket, unlimited, rb, keluarga, k...
# 340  [peket, reguler, kesedot, pakaet, malam, aktif...
#
# [332 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1121
# ------------------------
# gmna : gmna
# crax : crax
# beli : beli
# paket : paket
# unlimited : unlimited
# gb : gb
# kartu : kartu
# habis : habis
# kouta : kouta
# unlimitedx : unlimitedx
#  :
# telkomsel : telkomsel
# tolol : tolol
# main : main
# game : game
# jaringan : jaring
# ngedown : ngedown
# the : the
# best : best
# tolong : tolong
# donk : donk
# sinyal : sinyal
# benerin : benerin
# maen : maen
# lag : lag
# trus : trus
# turun : turun
# mohon : mohon
# betulkan : betul
# pengguna : guna
# kecewa : kecewa
# leemot : leemot
# ehhh : ehhh
# wooy : wooy
# wkwkwkwkw : wkwkwkwkw
# ajukan : aju
# kak : kak
# sms : sms
# paketan : paket
# pas : pas
# cek : cek
# kagak : kagak
# isikan : isi
# napa : napa
# khusus : khusus
# puhg : puhg
# gada : gada
# tersampah : sampah
# dunia : dunia
# gimana : gimana
# khusu : khusu
# pubg : pubg
# gaada : gaada
# pesan : pesan
# please : please
# admin : admin
# roli : rol
# dapet : dapet
# veronika : veronika
# nyambung : nyambung
# kejutan : kejut
# februari : februari
# ditunggu : tunggu
# min : min
# pulsa : pulsa
# telepon : telepon
# toko : toko
# tegal : tegal
# grapari : grapari
# omg : omg
# kuota : kuota
# voucher : voucher
# pinter : pinter
# dikit : dikit
# daerahnya : daerah
# lemah : lemah
# telkomselnya : telkomselnya
# ganti : ganti
# sewot : sewot
# netizen : netizen
# bts : bts
# daerah : daerah
# kekuatan : kuat
# btsnya : btsnya
# berbeda : beda
# cobalah : coba
# mencari : cari
# internet : internet
# sosmed : sosmed
# bisanya : bisa
# parah : parah
# lemotnya : lot
# sekian : sekian
# komentar : komentar
# keluhan : keluh
# bagus : bagus
# permisi : permisi
# medan : medan
# mengeluh : keluh
# bln : bln
# seret : seret
# gini : gin
# mudah : mudah
# dpn : dpn
# pakai : pakai
# provider : provider
# knp : knp
# kupang : kupang
# buruk : buruk
# sii : sii
# telkomsell : telkomsell
# paketannya : paket
# mahal : mahal
# bngtt : bngtt
# siigk : siigk
# sesuaii : sesuai
# amaa : amaa
# kantong : kantong
# siswaa : siswaa
# tauu : tauu
# berubah : ubah
# minggu : minggu
# darurat : darurat
# data : data
# nelpon : nelpon
# penjelasannya : jelas
# anji : anji
# banget : banget
# gabisa : gabisa
# responnya : responnya
# yaa : yaa
# kah : kah
# udah : udah
# aktifin : aktifin
# pket : pket
# tmbah : tmbah
# lemot : lot
# lanjutkan : lanjut
# pindah : pindah
# tetangga : tetangga
# gosok : gosok
# bantuannya : bantu
# gue : gue
# ngga : ngga
# speed : speed
# royal : royal
# paham : paham
# wis : wis
# sak : sak
# karepmu : karepmu
# full : full
# ttep : ttep
# sisa : sisa
# lancar : lancar
# promosi : promosi
# mulu : mulu
# anjlok : anjlok
# astagaa : astagaa
# maha : maha
# kali : kali
# jaringanya : jaringanya
# kalii : kali
# ngeluh : ngeluh
# ujung : ujung
# cuman : cuman
# suruh : suruh
# ngobrol : ngobrol
# semenjak : semenjak
# make : make
# aplikasi : aplikasi
# unlimitednya : unlimitednya
# dll : dll
# dikenakan : kena
# pembatasan : batas
# kecepatan : cepat
# diperbaiki : baik
# sistemnya : sistem
# acur : acur
# haii : hai
# telkom : telkom
# jelek : jelek
# suka : suka
# hilang : hilang
# ngelag : ngelag
# signal : signal
# emang : emang
# woi : woi
# dongggggggg : dongggggggg
# cra : cra
# tsel : tsel
# kyak : kyak
# taek : taek
# punyaku : punya
# combo : combo
# sakti : sakti
# susah : susah
# registrasi : registrasi
# ktp : ktp
# berguna : guna
# sanggup : sanggup
# ngasi : ngasi
# hadiah : hadiah
# top : top
# free : free
# firee : firee
# rasanyaa : rasanyaa
# amjggggg : amjggggg
# perdana : perdana
# aktif : aktif
# muncul : muncul
# bingung : bingung
# tutup : tutup
# pinjam : pinjam
# pulasa : pulasa
# gunanya : guna
# poin : poin
# rb : rb
# bayar : bayar
# chat : chat
# bot : bot
# kemana : mana
# kocak : kocak
# usaha : usaha
# merapat : rapat
# ngisi : ngisi
# sinyalnya : sinyal
# lho : lho
# sekelas : kelas
# pionir : pionir
# seluler : seluler
# pelanggan : langgan
# rubah : rubah
# promo : promo
# ribet : ribet
# pengurusannya : urus
# setia : setia
# ditawarin : ditawarin
# duluan : duluan
# dilupakan : lupa
# sinyalmu : sinyal
# nmer : nmer
# kmren : kmren
# lupa : lupa
# isi : isi
# non : non
# aktifkan : aktif
# belli : belli
# ribu : ribu
# benarin : benarin
# ajha : ajha
# jaringanmu : jaring
# kau : kau
# annjer : annjer
# terparah : parah
# jaringannya : jaring
# meragukan : ragu
# adakannya : adakan
# save : save
# tersedot : sedot
# inimah : inimah
# sejutapun : juta
# beda : beda
# gua : gua
# pengen : ken
# cantik : cantik
# menunggu : tunggu
# murah : murah
# hello : hello
# tmpt : tmpt
# sekalii : sekali
# denganmu : dengan
# bye : bye
# udh : udh
# seminggu : minggu
# time : time
# out : out
# lost : lost
# connection : connection
# sim : sim
# ungu : ungu
# potong : potong
# ngak : ngak
# kesedot : sedot
# perbaiki : baik
# wanasalam : wanasalam
# banten : banten
# dibeli : beli
# knpa : knpa
# ikhlas : ikhlas
# ambil : ambil
# pemberitahuan : pemberitahuan
# kesel : kesel
# ceria : ceria
# malam : malam
# orang : orang
# tidur : tidur
# dengar : dengar
# telinga : telinga
# bicara : bicara
# cewek : cewek
# manado : manado
# menangis : menang
# air : air
# mata : mata
# tumpah : tumpah
# lapor : lapor
# kasih : kasih
# kenal : kenal
# bunyi : bunyi
# internetan : internetan
# koneksi : koneksi
# diganti : ganti
# all : all
# hadi : had
# mubazir : mubazir
# gnya : gnya
# inbox : inbox
# gratis : gratis
# sumpah : sumpah
# kcewa : kcewa
# woy : woy
# voucer : voucer
# sistem : sistem
# sibuk : sibuk
# aktivasi : aktivasi
# solusi : solusi
# interaksi : interaksi
# tunggu : tunggu
# bohingin : bohingin
# restart : restart
# sekalinya : sekali
# esmosii : esmosii
# hadeuhhh : hadeuhhh
# mendukung : dukung
# kota : kota
# ketengan : keteng
# twitter : twitter
# tambahin : tambahin
# telegram : telegram
# eror : eror
# kemarin : kemarin
# bar : bar
# kandang : kandang
# mucul : mucul
# kadang : kadang
# panggilan : panggil
# dlu : dlu
# wilayah : wilayah
# bengkulu : bengkulu
# harian : hari
# hri : hri
# byu : byu
# paketnya : paket
# alias : alias
# kosong : kosong
# ancur : ancur
# urusin : urusin
# telkomselpulsa : telkomselpulsa
# pret : pret
# tdi : tdi
# dicuri : curi
# simpati : simpati
# foto : foto
# sekolah : sekolah
# rame : rame
# harga : harga
# pelayanan : layan
# ampas : ampas
# kemendikbud : kemendikbud
# woiiiiiiiiiii : woiiiiiiiiiii
# mat : mat
# siang : siang
# kirim : kirim
# teman : teman
# ntb : ntb
# lambat : lambat
# dangdut : dangdut
# samawa : samawa
# kesalahan : salah
# sambungan : sambung
# kerjasama : kerjasama
# hai : hai
# maaf : maaf
# nyaman : nyaman
# terkait : kait
# internetnya : internetnya
# mencoba : coba
# airplane : airplane
# mode : mode
# off : off
# berkendala : kendala
# yuk : yuk
# interaksinya : interaksi
# dilanjut : lanjut
# via : via
# ccd : ccd
# yutube : yutube
# buka : buka
# tutube : tutube
# muter : muter
# info : info
# datanya : data
# gamasuk : gamasuk
# card : card
# bpk : bpk
# terbaca : baca
# nomer : nomer
# kena : kena
# notifikasi : notifikasi
# berhasil : hasil
# solusinya : solusi
# dial : dial
# dpt : dpt
# gagal : gagal
# pembelian : beli
# pastikan : pasti
# mas : mas
# mba : mba
# nggak : nggak
# login : login
# freefire : freefire
# mlm : mlm
# total : total
# bermain : main
# maksudnya : maksud
# kayak : kayak
# ngurang : ngurang
# berkali : kali
# ubah : ubah
# iya : iya
# ilang : ilang
# dateng : dateng
# tinggal : tinggal
# desa : desa
# anjimm : anjimm
# ilmupedia : ilmupedia
# njir : njir
# apk : apk
# nyedot : nyedot
# belajar : ajar
# sampe : sampe
# masuk : masuk
# gamenya : gamenya
# kepake : kepake
# gitu : gitu
# bantu : bantu
# pngisian : pngisian
# music : music
# games : games
# utama : utama
# puas : puas
# pengalaman : alam
# mobile : mobile
# legends : legends
# stabil : stabil
# uda : uda
# akses : akses
# hangus : hangus
# begtu : begtu
# sesuai : sesuai
# kualitas : kualitas
# bantuan : bantu
# keminkbud : keminkbud
# masak : masak
# sebading : sebading
# bangat : bangat
# youtube : youtube
# diisi : isi
# gmnada : gmnada
# pemenang : menang
# undi : undi
# hepi : hepi
# february : february
# wee : wee
# kaagak : kaagak
# mhl : mhl
# cok : cok
# tekhnologi : tekhnologi
# putus : putus
# bnyak : bnyak
# adil : adil
# kaya : kaya
# tampil : tampil
# doank : doank
# riau : riau
# pagi : pagi
# lupakan : lupa
# burik : burik
# ditempat : tempat
# dirano : dirano
# tanjung : tanjung
# jabung : jabung
# timur : timur
# org : org
# tekomsel : tekomsel
# baikan : baik
# tower : tower
# dak : dak
# lgi : lgi
# dibaikan : baik
# sebentar : sebentar
# skrng : skrng
# anak : anak
# onlen : onlen
# kyk : kyk
# ribuan : ribu
# hancur : hancur
# memalukan : malu
# jaringanx : jaringanx
# sloter : sloter
# gamingmembahas : gamingmembahas
# tengtang : tengtang
# slot : slot
# domino : domino
# island : island
# kunjungi : kunjung
# chanel : chanel
# nanya : nanya
# yng : yng
# kuotanya : kuota
# kb : kb
# terima : terima
# beranjak : anjak
# pergi : pergi
# berbicara : bicara
# anjim : anjim
# jdi : jdi
# murahan : murah
# download : download
# susahnya : susah
# ampun : ampun
# meng : meng
# agung : agung
# agungkan : agung
# no : no
# engga : engga
# bandingkan : banding
# kayanya : kaya
# group : group
# dgrrhrr : dgrrhrr
# rss : rss
# asedfe : asedfe
# bahagia : bahagia
# daring : daring
# muda : muda
# umor : umor
# yak : yak
# miskin : miskin
# give : give
# away : away
# ytb : ytb
# beserta : serta
# jajarannya : jajar
# tiktok : tiktok
# wifi : wifi
# dirumah : rumah
# down : down
# rumah : rumah
# standby : standby
# thetering : thetering
# handphone : handphone
# bangkrut : bangkrut
# langsung : langsung
# sedot : sedot
# berlangganan : langgan
# apapun : apa
# dibawa : bawa
# ngebrowsing : ngebrowsing
# ngegame : ngegame
# berani : berani
# mematok : patok
# layanan : layan
# apalag : apalag
# sore : sore
# nongol : nongol
# menit : menit
# abis : abis
# truuuasssss : truuuasssss
# ampe : ampe
# sejam : jam
# terusss : terusss
# harap : harap
# perhatikan : perhati
# sulawesi : sulawesi
# utara : utara
# thanks : thanks
# mah : mah
# bosen : bosen
# bacotin : bacotin
# mutiara : mutiara
# tetep : tetep
# bego : bego
# jakarta : jakarta
# trans : trans
# deket : deket
# kantor : kantor
# pusat : pusat
# seharus : harus
# prioritaskan : prioritas
# dibanding : banding
# dulunya : dulunya
# gass : gass
# kalah : kalah
# sebelah : belah
# diru : diru
# dear : dear
# perusahaan : usaha
# bumn : bumn
# pln : pln
# kesigapan : sigap
# memperbaiki : baik
# kerusakan : rusa
# ketinggalan : tinggal
# berfungsi : fungsi
# perbaikan : baik
# melapor : lapor
# cha : cha
# bali : bal
# max : max
# utamanya : utama
# lan : lan
# online : online
# mobil : mobil
# stak : stak
# loading : loading
# screen : screen
# tpi : tpi
# speednya : speednya
# buffering : buffering
# laging : laging
# bnget : bnget
# lemotttttt : lemotttttt
# lokasi : lokasi
# kecamatan : camat
# karangnongko : karangnongko
# klaten : klaten
# busukkk : busukkk
# kualitasnya : kualitas
# makasih : makasih
# telkomtod : telkomtod
# afk : afk
# matchnya : matchnya
# pengaduan : adu
# ditanggapi : tanggap
# menyelesaikan : selesai
# cepat : cepat
# tanggap : tanggap
# mengatasi : atas
# kendalanya : kendala
# minimal : minimal
# terkendalanya : kendala
# menganggu : menganggu
# produktivitas : produktivitas
# bertahun : tahun
# mlah : mlah
# normal : normal
# leletnya : lelet
# nambah : nambah
# emosi : emosi
# liat : liat
# huaa : huaa
# gnigra : gnigra
# gra : gra
# mlu : mlu
# sya : sya
# dengerin : dengerin
# pidato : pidato
# presiden : presiden
# barang : barang
# rakyat : rakyat
# gigit : gigit
# makan : makan
# gaji : gaji
# buta : buta
# dikantor : kantor
# pulang : pulang
# kerja : kerja
# shoping : shoping
# peduli : peduli
# masyarakat : masyarakat
# segini : gin
# dri : dri
# edge : edge
# garut : garut
# dipakai : pakai
# ngegoogle : ngegoogle
# chtn : chtn
# fitur : fitur
# chatan : chatan
# doang : doang
# gabut : gabut
# disana : sana
# didenger : didenger
# bilangnya : bilang
# dibenerin : dibenerin
# nomor : nomor
# sok : sok
# iye : iye
# bangt : bangt
# dikerjain : dikerjain
# jam : jam
# hasilnya : hasil
# nol : nol
# cht : cht
# digmai : digmai
# dibales : dibales
# ngirim : ngirim
# ngirimnya : ngirimnya
# semalam : malam
# tb : tb
# bangun : bangun
# lansung : lansung
# tenggang : tenggang
# kartunya : kartu
# warga : warga
# indonesia : indonesia
# tri : tri
# meresahkan : resah
# emnk : emnk
# sampah : sampah
# sialan : sial
# kurasakan : rasa
# bekasi : bekas
# lumyan : lumyan
# error : error
# barat : barat
# nlfn : nlfn
# kluar : kluar
# bangke : bangke
# kirain : kirain
# saking : saking
# penasran : penasran
# krtu : krtu
# pindahin : pindahin
# nokia : nokia
# ttp : ttp
# sma : sma
# bsa : bsa
# telkomsek : telkomsek
# mengganggu : ganggu
# membutuhkan : butuh
# sebanding : banding
# menurun : turun
# segi : segi
# seantero : antero
# jagat : jagat
# buktinya : bukti
# menganti : anti
# karuan : karuan
# tlpn : tlpn
# call : call
# center : center
# sayah : sayah
# setara : tara
# merah : merah
# mendingan : mending
# gausah : gausah
# adain : adain
# operator : operator
# cita : cita
# pemuda : pemuda
# negri : negri
# tolonglah : tolong
# terhormat : hormat
# kek : kek
# murahaan : murahaan
# karawang : karawang
# cikarang : cikarang
# bener : bener
# penuh : penuh
# ngelek : ngelek
# sayang : sayang
# grgr : grgr
# perbatasan : batas
# selamat : selamat
# hati : hati
# efek : efek
# pekerjanya : kerja
# korupsi : korupsi
# guys : guys
# bodoh : bodoh
# intetnet : intetnet
# muak : muak
# semalem : semalem
# hujan : hujan
# badai : badai
# ehh : ehh
# sedih : sedih
# euy : euy
# hutan : hutan
# layani : layan
# client : client
# disuruh : suruh
# ama : ama
# moga : moga
# cepet : cepet
# nyari : nyari
# sja : sja
# naikin : naikin
# credit : credit
# score : score
# rank : rank
# gaje : gaje
# cokcok : cokcok
# ghoib : ghoib
# haram : haram
# jaringang : jaringang
# pilihan : pilih
# reconect : reconect
# lbih : lbih
# gara : gara
# dirugikan : rugi
# ane : ane
# pecah : pecah
# kesabaran : sabar
# tae : tae
# fucek : fucek
# lite : lite
# perkotaan : kota
# ngalamin : ngalamin
# telkomtol : telkomtol
# indo : indo
# sebenernya : sebenernya
# gimic : gimic
# penyedia : sedia
# jarinangan : jarinangan
# ngk : ngk
# lihat : lihat
# smua : smua
# komenan : komenan
# dsni : dsni
# biss : biss
# diselesaikan : selesai
# oiy : oiy
# ngecrot : ngecrot
# knapa : knapa
# gede : gede
# anyenk : anyenk
# malem : malem
# ban : ban
# brp : brp
# bosok : bosok
# malu : malu
# kemaren : kemaren
# mbak : mbak
# saran : saran
# rekan : rekan
# antena : antena
# yagi : yagi
# penguat : kuat
# diperguanakan : diperguanakan
# terimakasih : terimakasih
# infonya : info
# lokal : lokal
# slalu : slalu
# sperti : sperti
# kuning : kuning
# taon : taon
# detik : detik
# msh : msh
# perubahan : ubah
# abal : abal
# kalibata : kalibata
# layak : layak
# coba : coba
# ulah : ulah
# goreng : goreng
# bae : bae
# sinyalna : sinyalna
# paketna : paketna
# ongkoh : ongkoh
# aneh : aneh
# aing : aing
# nge : nge
# patokbeusi : patokbeusi
# kelurahan : lurah
# gempolsari : gempolsari
# penurunan : turun
# duh : duh
# gangguan : ganggu
# kampung : kampung
# digunain : digunain
# buang : buang
# uang : uang
# laporan : lapor
# mencantumkan : cantum
# konter : konter
# dikiranya : kira
# ngambil : ngambil
# untung : untung
# pdhala : pdhala
# smsnya : smsnya
# tapos : tapos
# depok : depok
# adminnya : adminnya
# operatornya : operator
# numpang : numpang
# wifian : wifian
# kesempatan : sempat
# membatasi : batas
# bandwith : bandwith
# pea : pea
# balikin : balikin
# mimin : mimin
# survey : survey
# listrik : listrik
# padam : padam
# tidka : tidka
# mlbb : mlbb
# gerak : gerak
# pdhl : pdhl
# paketanku : paket
# sebulan : bulan
# tahan : tahan
# app : app
# mytelkomsel : mytelkomsel
# hrus : hrus
# memalui : palu
# link : link
# pasirbsdak : pasirbsdak
# peutey : peutey
# komen : komen
# lmod : lmod
# baiki : baik
# can : can
# you : you
# speak : speak
# english : english
# sidoarjo : sidoarjo
# gajelas : gajelas
# konexsi : konexsi
# sarain : sarain
# cari : cari
# keknya : kek
# terganti : ganti
# tkp : tkp
# melulu : melulu
# mb : mb
# termurah : murah
# ngx : ngx
# kenyataan : nyata
# hoax : hoax
# mending : mending
# musnahin : musnahin
# jringan : jringan
# masukan : masuk
# kode : kode
# vocher : vocher
# mengisi : isi
# migrasi : migrasi
# tercover : tercover
# gojek : gojek
# grab : grab
# gmn : gmn
# seharian : hari
# terbuka : buka
# astaga : astaga
# bro : bro
# ambilnya : ambil
# gmnh : gmnh
# hidup : hidup
# sultan : sultan
# dajjal : dajjal
# turunin : turunin
# syarat : syarat
# wajib : wajib
# setahu : tahu
# upgrade : upgrade
# mojokerto : mojokerto
# jawa : jawa
# diwajibkan : wajib
# pemaksaan : paksa
# kesannya : kesan
# midnigth : midnigth
# ditulis : tulis
# berlaku : laku
# sekrang : sekrang
# pdahal : pdahal
# bela : bela
# in : in
# begadang : begadang
# smpe : smpe
# zonk : zonk
# dapatkan : dapat
# puk : puk
# mna : mna
# selangit : langit
# kerjanya : kerja
# hongkong : hongkong
# erorr : erorr
# bkn : bkn
# emisi : emisi
# nanyak : nanyak
# seratus : ratus
# kenpa : kenpa
# mendadak : dadak
# blm : blm
# desember : desember
# pedesaan : desa
# pdhal : pdhal
# juara : juara
# bobrok : bobrok
# bosss : bosss
# ajir : ajir
# loss : loss
# sreak : sreak
# bapuk : bapuk
# ngojek : ngojek
# kaga : kaga
# nyusahin : nyusahin
# rezeki : rezeki
# area : area
# srono : srono
# kabupaten : kabupaten
# banyuwangi : banyuwangi
# gan : gan
# keong : keong
# daki : daki
# gunung : gunung
# cepatan : cepat
# semut : semut
# promi : promi
# belik : belik
# masukin : masukin
# kon : kon
# bli : bli
# gbisa : gbisa
# woyyy : woyyy
# kab : kab
# asahan : asah
# sumut : sumut
# rise : rise
# kingdom : kingdom
# support : support
# skrang : skrang
# payah : payah
# moba : moba
# ping : ping
# teruus : teruus
# bagusan : bagus
# dimasa : masa
# pandemi : pandemi
# nyekek : nyekek
# bgd : bgd
# paketanya : paketanya
# harganha : harganha
# niatan : niat
# mingguan : minggu
# bengini : bengini
# bobrook : bobrook
# gustiiii : gustiiii
# nuagung : nuagung
# dibantu : bantu
# jad : jad
# maju : maju
# daringggggg : daringggggg
# tapiii : tapiii
# pakek : pakek
# sellau : sellau
# nonton : nonton
# ijo : ijo
# kambuh : kambuh
# low : low
# lartu : lartu
# three : three
# ujan : ujan
# minnn : minnn
# dimasukin : dimasukin
# skrg : skrg
# jelekkkk : jelekkkk
# bagusnya : bagus
# disconnec : disconnec
# stengah : stengah
# btw : btw
# dikasih : kasih
# maxstream : maxstream
# dipake : dipake
# unlimetidmax : unlimetidmax
# chatt : chatt
# musik : musik
# sosmet : sosmet
# giliran : gilir
# legend : legend
# fix : fix
# rusak : rusak
# telkomshitt : telkomshitt
# sekaran : sekar
# halo : halo
# teblokir : teblokir
# suspent : suspent
# telat : telat
# bayat : bayat
# paketn : paketn
# jaringn : jaringn
# hdehhhh : hdehhhh
# gila : gila
# terkenal : kenal
# keok : keok
# becus : becus
# drtd : drtd
# sebel : sebel
# bayarnya : bayar
# gopay : gopay
# nyampe : nyampe
# saldo : saldo
# pay : pay
# wkwkwk : wkwkwk
# wilayh : wilayh
# pamanukan : pamanukan
# subang : subang
# bos : bos
# ulang : ulang
# gimna : gimna
# ngeleg : ngeleg
# mentok : mentok
# kbs : kbs
# keluarga : keluarga
# promonya : promonya
# peket : peket
# reguler : reguler
# pakaet : pakaet
# {'gmna': 'gmna', 'crax': 'crax', 'beli': 'beli', 'paket': 'paket', 'unlimited': 'unlimited', 'gb': 'gb', 'kartu': 'kartu', 'habis': 'habis', 'kouta': 'kouta', 'unlimitedx': 'unlimitedx', '': '', 'telkomsel': 'telkomsel', 'tolol': 'tolol', 'main': 'main', 'game': 'game', 'jaringan': 'jaring', 'ngedown': 'ngedown', 'the': 'the', 'best': 'best', 'tolong': 'tolong', 'donk': 'donk', 'sinyal': 'sinyal', 'benerin': 'benerin', 'maen': 'maen', 'lag': 'lag', 'trus': 'trus', 'turun': 'turun', 'mohon': 'mohon', 'betulkan': 'betul', 'pengguna': 'guna', 'kecewa': 'kecewa', 'leemot': 'leemot', 'ehhh': 'ehhh', 'wooy': 'wooy', 'wkwkwkwkw': 'wkwkwkwkw', 'ajukan': 'aju', 'kak': 'kak', 'sms': 'sms', 'paketan': 'paket', 'pas': 'pas', 'cek': 'cek', 'kagak': 'kagak', 'isikan': 'isi', 'napa': 'napa', 'khusus': 'khusus', 'puhg': 'puhg', 'gada': 'gada', 'tersampah': 'sampah', 'dunia': 'dunia', 'gimana': 'gimana', 'khusu': 'khusu', 'pubg': 'pubg', 'gaada': 'gaada', 'pesan': 'pesan', 'please': 'please', 'admin': 'admin', 'roli': 'rol', 'dapet': 'dapet', 'veronika': 'veronika', 'nyambung': 'nyambung', 'kejutan': 'kejut', 'februari': 'februari', 'ditunggu': 'tunggu', 'min': 'min', 'pulsa': 'pulsa', 'telepon': 'telepon', 'toko': 'toko', 'tegal': 'tegal', 'grapari': 'grapari', 'omg': 'omg', 'kuota': 'kuota', 'voucher': 'voucher', 'pinter': 'pinter', 'dikit': 'dikit', 'daerahnya': 'daerah', 'lemah': 'lemah', 'telkomselnya': 'telkomselnya', 'ganti': 'ganti', 'sewot': 'sewot', 'netizen': 'netizen', 'bts': 'bts', 'daerah': 'daerah', 'kekuatan': 'kuat', 'btsnya': 'btsnya', 'berbeda': 'beda', 'cobalah': 'coba', 'mencari': 'cari', 'internet': 'internet', 'sosmed': 'sosmed', 'bisanya': 'bisa', 'parah': 'parah', 'lemotnya': 'lot', 'sekian': 'sekian', 'komentar': 'komentar', 'keluhan': 'keluh', 'bagus': 'bagus', 'permisi': 'permisi', 'medan': 'medan', 'mengeluh': 'keluh', 'bln': 'bln', 'seret': 'seret', 'gini': 'gin', 'mudah': 'mudah', 'dpn': 'dpn', 'pakai': 'pakai', 'provider': 'provider', 'knp': 'knp', 'kupang': 'kupang', 'buruk': 'buruk', 'sii': 'sii', 'telkomsell': 'telkomsell', 'paketannya': 'paket', 'mahal': 'mahal', 'bngtt': 'bngtt', 'siigk': 'siigk', 'sesuaii': 'sesuai', 'amaa': 'amaa', 'kantong': 'kantong', 'siswaa': 'siswaa', 'tauu': 'tauu', 'berubah': 'ubah', 'minggu': 'minggu', 'darurat': 'darurat', 'data': 'data', 'nelpon': 'nelpon', 'penjelasannya': 'jelas', 'anji': 'anji', 'banget': 'banget', 'gabisa': 'gabisa', 'responnya': 'responnya', 'yaa': 'yaa', 'kah': 'kah', 'udah': 'udah', 'aktifin': 'aktifin', 'pket': 'pket', 'tmbah': 'tmbah', 'lemot': 'lot', 'lanjutkan': 'lanjut', 'pindah': 'pindah', 'tetangga': 'tetangga', 'gosok': 'gosok', 'bantuannya': 'bantu', 'gue': 'gue', 'ngga': 'ngga', 'speed': 'speed', 'royal': 'royal', 'paham': 'paham', 'wis': 'wis', 'sak': 'sak', 'karepmu': 'karepmu', 'full': 'full', 'ttep': 'ttep', 'sisa': 'sisa', 'lancar': 'lancar', 'promosi': 'promosi', 'mulu': 'mulu', 'anjlok': 'anjlok', 'astagaa': 'astagaa', 'maha': 'maha', 'kali': 'kali', 'jaringanya': 'jaringanya', 'kalii': 'kali', 'ngeluh': 'ngeluh', 'ujung': 'ujung', 'cuman': 'cuman', 'suruh': 'suruh', 'ngobrol': 'ngobrol', 'semenjak': 'semenjak', 'make': 'make', 'aplikasi': 'aplikasi', 'unlimitednya': 'unlimitednya', 'dll': 'dll', 'dikenakan': 'kena', 'pembatasan': 'batas', 'kecepatan': 'cepat', 'diperbaiki': 'baik', 'sistemnya': 'sistem', 'acur': 'acur', 'haii': 'hai', 'telkom': 'telkom', 'jelek': 'jelek', 'suka': 'suka', 'hilang': 'hilang', 'ngelag': 'ngelag', 'signal': 'signal', 'emang': 'emang', 'woi': 'woi', 'dongggggggg': 'dongggggggg', 'cra': 'cra', 'tsel': 'tsel', 'kyak': 'kyak', 'taek': 'taek', 'punyaku': 'punya', 'combo': 'combo', 'sakti': 'sakti', 'susah': 'susah', 'registrasi': 'registrasi', 'ktp': 'ktp', 'berguna': 'guna', 'sanggup': 'sanggup', 'ngasi': 'ngasi', 'hadiah': 'hadiah', 'top': 'top', 'free': 'free', 'firee': 'firee', 'rasanyaa': 'rasanyaa', 'amjggggg': 'amjggggg', 'perdana': 'perdana', 'aktif': 'aktif', 'muncul': 'muncul', 'bingung': 'bingung', 'tu ...
# ------------------------
# Pandas Apply:   0%|          | 0/332 [00:00<?, ?it/s]
#                                                comment  \
# 0    gmna crax beli paket unlimited 25gb kartu baru...
# 1    telkomsel tolol gw. main game jaringan nya nge...
# 2                            telkomsel is the best dah
# 3    tolong donk sinyal di benerin. sekarang buat m...
# 4    kenapa sinyal unlimited sekarang jadi leemot b...
# ..                                                 ...
# 336          min cara supaya jaringan gk tolol gimna.?
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah?
# 339  min kenapa promo paket unlimited saya selalu d...
# 340  ini kenapa peket reguler sy yg kesedot ni kena...
#
#                                       cleaning_comment  \
# 0    gmna crax beli paket unlimited  gb kartu baru ...
# 1    telkomsel tolol main game jaringan nya ngedown...
# 2                               telkomsel the best dah
# 3    tolong donk sinyal benerin sekarang buat maen ...
# 4    kenapa sinyal unlimited sekarang jadi leemot bgt
# ..                                                 ...
# 336              min cara supaya jaringan tolol gimna
# 337  ini gmn sih katanya unlimited game tapi pas ma...
# 338           kenapa jaringan telkomsel semakin parah
# 339  min kenapa promo paket unlimited saya selalu a...
# 340  ini kenapa peket reguler kesedot kenapa pakaet...
#
#                                             tokenisasi  \
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1    [telkomsel, tolol, main, game, jaringan, nya, ...
# 2                          [telkomsel, the, best, dah]
# 3    [tolong, donk, sinyal, benerin, sekarang, buat...
# 4    [kenapa, sinyal, unlimited, sekarang, jadi, le...
# ..                                                 ...
# 336      [min, cara, supaya, jaringan, tolol, gimna, ]
# 337  [ini, gmn, sih, katanya, unlimited, game, tapi...
# 338    [kenapa, jaringan, telkomsel, semakin, parah, ]
# 339  [min, kenapa, promo, paket, unlimited, saya, s...
# 340  [ini, kenapa, peket, reguler, kesedot, kenapa,...
#
#                                               stopword  \
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1    [telkomsel, tolol, main, game, jaringan, ngedown]
# 2                               [telkomsel, the, best]
# 3    [tolong, donk, sinyal, benerin, maen, game, la...
# 4                        [sinyal, unlimited, leemot, ]
# ..                                                 ...
# 336                    [min, jaringan, tolol, gimna, ]
# 337  [gmn, unlimited, game, pas, maen, game, ngeleg...
# 338                     [jaringan, telkomsel, parah, ]
# 339  [min, promo, paket, unlimited, rb, keluarga, k...
# 340  [peket, reguler, kesedot, pakaet, malam, aktif...
#
#                                               stemming
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1      [telkomsel, tolol, main, game, jaring, ngedown]
# 2                               [telkomsel, the, best]
# 3    [tolong, donk, sinyal, benerin, maen, game, la...
# 4                        [sinyal, unlimited, leemot, ]
# ..                                                 ...
# 336                      [min, jaring, tolol, gimna, ]
# 337  [gmn, unlimited, game, pas, maen, game, ngeleg...
# 338                       [jaring, telkomsel, parah, ]
# 339  [min, promo, paket, unlimited, rb, keluarga, k...
# 340  [peket, reguler, sedot, pakaet, malam, aktif, ...
#
# [332 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [gmna, crax, beli, paket, unlimited, gb, kartu...
# 1      [telkomsel, tolol, main, game, jaring, ngedown]
# 2                               [telkomsel, the, best]
# 3    [tolong, donk, sinyal, benerin, maen, game, la...
# 4                        [sinyal, unlimited, leemot, ]
# ..                                                 ...
# 336                      [min, jaring, tolol, gimna, ]
# 337  [gmn, unlimited, game, pas, maen, game, ngeleg...
# 338                       [jaring, telkomsel, parah, ]
# 339  [min, promo, paket, unlimited, rb, keluarga, k...
# 340  [peket, reguler, sedot, pakaet, malam, aktif, ...
#
# [332 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_2.xlsx')
