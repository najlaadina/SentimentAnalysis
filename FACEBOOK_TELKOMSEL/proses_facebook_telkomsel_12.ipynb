# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                                 Kuota paling ga guna
# 1    Menyesal saya beli kartu Telkomsel, jaringan g...
# 2                                        Promo kenceng
# 3    Sinyal Kaya Sampah Ampas Banget Paketan Makin ...
# 4                                 Iyah paket minggu ya
# ..                                                 ...
# 194                                            Bangkai
# 195                         Ayo semua pakek kartu lain
# 196  Lama orang dah bosen pake kartu Telkom terus k...
# 197  Kak ini gimana? Katanya kalo topup pulsa lewat...
# 198  Tembak/Inject Kuota Telkomsel 100 MB/30 Hari C...
#
# [199 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 5

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                                 Kuota paling ga guna
# 1    Menyesal saya beli kartu Telkomsel, jaringan g...
# 2                                        Promo kenceng
# 3    Sinyal Kaya Sampah Ampas Banget Paketan Makin ...
# 4                                 Iyah paket minggu ya
# ..                                                 ...
# 193  di tahun baru ini saya harap telkomsel memberi...
# 194                                            Bangkai
# 195                         Ayo semua pakek kartu lain
# 196  Lama orang dah bosen pake kartu Telkom terus k...
# 197  Kak ini gimana? Katanya kalo topup pulsa lewat...
#
# [189 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                                 kuota paling ga guna
# 1    menyesal saya beli kartu telkomsel, jaringan g...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                 iyah paket minggu ya
# ..                                                 ...
# 193  di tahun baru ini saya harap telkomsel memberi...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana? katanya kalo topup pulsa lewat...
#
# [189 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                                 kuota paling ga guna
# 1    menyesal saya beli kartu telkomsel, jaringan g...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                 iyah paket minggu ya
# ..                                                 ...
# 193  di tahun baru ini saya harap telkomsel memberi...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana? katanya kalo topup pulsa lewat...
#
#                                       cleaning_comment
# 0                                    kuota paling guna
# 1    menyesal saya beli kartu telkomsel jaringan pe...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                   iyah paket minggu
# ..                                                 ...
# 193   tahun baru ini saya harap telkomsel memberika...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana katanya kalo topup pulsa lewat ...
#
# [189 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                                 kuota paling ga guna
# 1    menyesal saya beli kartu telkomsel, jaringan g...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                 iyah paket minggu ya
# ..                                                 ...
# 193  di tahun baru ini saya harap telkomsel memberi...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana? katanya kalo topup pulsa lewat...
#
#                                       cleaning_comment  \
# 0                                    kuota paling guna
# 1    menyesal saya beli kartu telkomsel jaringan pe...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                   iyah paket minggu
# ..                                                 ...
# 193   tahun baru ini saya harap telkomsel memberika...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana katanya kalo topup pulsa lewat ...
#
#                                             tokenisasi
# 0                                [kuota, paling, guna]
# 1    [menyesal, saya, beli, kartu, telkomsel, jarin...
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paketan,...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, tahun, baru, ini, saya, harap, telkomsel, m...
# 194                                          [bangkai]
# 195                   [ayo, semua, pakek, kartu, lain]
# 196  [lama, orang, dah, bosen, pake, kartu, telkom,...
# 197  [kak, ini, gimana, katanya, kalo, topup, pulsa...
#
# [189 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                                 kuota paling ga guna
# 1    menyesal saya beli kartu telkomsel, jaringan g...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                 iyah paket minggu ya
# ..                                                 ...
# 193  di tahun baru ini saya harap telkomsel memberi...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana? katanya kalo topup pulsa lewat...
#
#                                       cleaning_comment  \
# 0                                    kuota paling guna
# 1    menyesal saya beli kartu telkomsel jaringan pe...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                   iyah paket minggu
# ..                                                 ...
# 193   tahun baru ini saya harap telkomsel memberika...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana katanya kalo topup pulsa lewat ...
#
#                                             tokenisasi  \
# 0                                [kuota, paling, guna]
# 1    [menyesal, saya, beli, kartu, telkomsel, jarin...
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paketan,...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, tahun, baru, ini, saya, harap, telkomsel, m...
# 194                                          [bangkai]
# 195                   [ayo, semua, pakek, kartu, lain]
# 196  [lama, orang, dah, bosen, pake, kartu, telkom,...
# 197  [kak, ini, gimana, katanya, kalo, topup, pulsa...
#
#                                               stopword
# 0                                              [kuota]
# 1    [menyesal, beli, kartu, telkomsel, jaringan, b...
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paketan,...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, harap, telkomsel, bonus, paket, data, pelan...
# 194                                          [bangkai]
# 195                                [ayo, pakek, kartu]
# 196  [orang, bosen, kartu, telkom, jaringan, kek, d...
# 197  [kak, gimana, topup, pulsa, aplikasi, mytsel, ...
#
# [189 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 578
# ------------------------
# kuota : kuota
# menyesal : sesal
# beli : beli
# kartu : kartu
# telkomsel : telkomsel
# jaringan : jaring
# beres : beres
# promo : promo
# kenceng : kenceng
# sinyal : sinyal
# kaya : kaya
# sampah : sampah
# ampas : ampas
# banget : banget
# paketan : paket
# mahal : mahal
# iyah : iyah
# paket : paket
# minggu : minggu
#  :
# min : min
# kasi : kasi
# yakali : yakali
# udah : udah
# langganan : langgan
# gapernah : gapernah
# dikasih : kasih
# murah : murah
# cok : cok
# benerin : benerin
# masuk : masuk
# musim : musim
# ujan : ujan
# ancur : ancur
# doank : doank
# seminggu : minggu
# down : down
# gadang : gadang
# nunggu : nunggu
# malem : malem
# bnr : bnr
# sibuk : sibuk
# unlimited : unlimited
# max : max
# maksud : maksud
# fup : fup
# gimana : gimana
# live : live
# chat : chat
# kah : kah
# bot : bot
# pelayanan : layan
# mengecewakan : kecewa
# pelanggan : langgan
# solusi : solusi
# menutupi : tutup
# mengabaikan : abai
# kecewa : kecewa
# internet : internet
# amb : amb
# jar : jar
# lokasi : lokasi
# aktif : aktif
# respon : respon
# sel : sel
# jelek : jelek
# klian : klian
# bsari : bsari
# komen : komen
# gini : gin
# gitu : gitu
# malu : malu
# taik : taik
# makasih : makasih
# telvonan : telvonan
# putus : putus
# ampun : ampun
# berhubungan : hubung
# data : data
# uuhh : uuhh
# sungguh : sungguh
# nyaman : nyaman
# oia : oia
# kau : kau
# bls : bls
# jawabanmu : jawab
# bahagia : bahagia
# membalas : balas
# smsku : smsku
# ngak : ngak
# urat : urat
# benarin : benarin
# tower : tower
# blok : blok
# desa : desa
# jaya : jaya
# bhakti : bhakti
# kec : kec
# mesuji : mesuji
# kab : kab
# ogan : ogan
# komering : komering
# ilir : ilir
# sum : sum
# potret : potret
# rumah : rumah
# kayu : kayu
# sempet : sempet
# ditawarin : ditawarin
# nomer : nomer
# prabayar : prabayar
# pasca : pasca
# bayar : bayar
# minat : minat
# tolak : tolak
# mutasi : mutasi
# aktifasi : aktifasi
# kantor : kantor
# telkom : telkom
# grapari : grapari
# via : via
# tlp : tlp
# harga : harga
# tetep : tetep
# tenan : tenan
# ubah : ubah
# aplikasi : aplikasi
# mytelkomsel : mytelkomsel
# habis : habis
# diupdate : diupdate
# dibuka : buka
# tlong : tlong
# mlm : mlm
# please : please
# perbaiki : baik
# sinyalnya : sinyal
# gangguan : ganggu
# mulu : mulu
# hargaa : hargaa
# jelekkkkk : jelekkkkk
# tolong : tolong
# gratis : gratis
# anak : anak
# belajar : ajar
# uang : uang
# woiiii : woiiii
# knpa : knpa
# kode : kode
# vocer : vocer
# masukin : masukin
# kyk : kyk
# cari : cari
# seru : seru
# registrasi : registrasi
# perdana : perdana
# sim : sim
# card : card
# sms : sms
# telpon : telpon
# contact : contact
# veronika : veronika
# website : website
# facebook : facebook
# messenger : messenger
# sorde : sorde
# bge : bge
# sinyall : sinyall
# hadohhhhh : hadohhhhh
# hoai : hoai
# gila : gila
# busukny : busukny
# telepon : telepon
# teman : teman
# udh : udh
# suka : suka
# kouta : kouta
# mlahan : mlahan
# pas : pas
# main : main
# game : game
# sinyak : sinyak
# hai : hai
# pakai : pakai
# asli : asli
# kak : kak
# isi : isi
# kuata : kuata
# gb : gb
# cepet : cepet
# cuman : cuman
# kartunya : kartu
# bukak : bukak
# doanh : doanh
# gua : gua
# reddem : reddem
# hoki : hoki
# keknya : kek
# scam : scam
# wilayah : wilayah
# kampar : kampar
# kiri : kiri
# rusak : rusak
# nggak : nggak
# terpakai : pakai
# ganti : ganti
# tuker : tuker
# dapet : dapet
# mna : mna
# cek : cek
# poin : poin
# refresh : refresh
# kali : kali
# jaringannya : jaring
# sumber : sumber
# jeleknya : jelek
# nyuruh : nyuruh
# hape : hape
# mumpuni : mumpuni
# direfresh : direfresh
# daerah : daerah
# enrekang : enrekang
# sulsel : sulsel
# bngt : bngt
# duh : duh
# perasaan : asa
# kemaren : kemaren
# eror : eror
# vendor : vendor
# kembalikan : kembali
# ngacir : ngacir
# didalam : dalam
# ngk : ngk
# buka : buka
# tdi : tdi
# siang : siang
# error : error
# hedehhhh : hedehhhh
# pulsa : pulsa
# hilang : hilang
# kesedot : sedot
# akibat : akibat
# terimakasih : terimakasih
# pemirsa : pirsa
# ngelaaggggg : ngelaaggggg
# kebanyakan : banyak
# rto : rto
# memuaskan : muas
# capee : capee
# deh : deh
# instagram : instagram
# donk : donk
# pilih : pilih
# kasih : kasih
# terpaksa : paksa
# mode : mode
# mahalnya : mahal
# lemot : lot
# rebahan : rebah
# darah : darah
# efek : efek
# patah : patah
# bagus : bagus
# ijo : ijo
# modem : modem
# mifi : mifi
# taro : taro
# nice : nice
# pokok : pokok
# sore : sore
# lambat : lambat
# ngga : ngga
# pemakai : pakai
# kadang : kadang
# mati : mati
# pesawat : pesawat
# dlu : dlu
# blank : blank
# cepat : cepat
# dahlah : dah
# nelpon : nelpon
# online : online
# kunci : kunci
# kmna : kmna
# rangkas : rangkas
# bitung : bitung
# lebak : lebak
# banten : banten
# diperbaiki : baik
# mahall : mahall
# pketanya : pketanya
# jringan : jringan
# tmbah : tmbah
# tambh : tambh
# capek : capek
# ama : ama
# jaringanmu : jaring
# cape : cape
# nge : nge
# signal : signal
# bye : bye
# komplen : komplen
# php : php
# lancar : lancar
# knp : knp
# gem : gem
# pdhl : pdhl
# gwe : gwe
# masi : mas
# ttp : ttp
# masiiiiiiii : masiiiiiiii
# signalnya : signalnya
# muter : muter
# buang : buang
# lupa : lupa
# unreg : unreg
# gerai : gerai
# bawa : bawa
# mending : mending
# semangat : semangat
# kayak : kayak
# ktl : ktl
# izin : izin
# giganet : giganet
# jam : jam
# terbagi : bagi
# hanyak : hanyak
# dikhusus : khusus
# gimna : gimna
# mklilum : mklilum
# pengguna : guna
# bru : bru
# tpi : tpi
# uda : uda
# dpt : dpt
# poinnya : poin
# perbagusi : bagus
# proses : proses
# gigit : gigit
# comen : comen
# makan : makan
# ikutan : ikut
# notifikasi : notifikasi
# menerus : terus
# luber : luber
# bos : bos
# terjangkau : jangkau
# gamemax : gamemax
# mobile : mobile
# legenda : legenda
# matching : matching
# aneh : aneh
# combosakti : combosakti
# wou : wou
# ikhlas : ikhlas
# pagi : pagi
# ajaaa : ajaaa
# ngabisin : ngabisin
# doang : doang
# download : download
# gagal : gagal
# gblk : gblk
# cacat : cacat
# ping : ping
# turun : turun
# parah : parah
# sinyalo : sinyalo
# bnerin : bnerin
# woee : woee
# boros : boros
# internetan : internetan
# ngidupin : ngidupin
# rb : rb
# tinggal : tinggal
# perak : perak
# telkomtod : telkomtod
# bacod : bacod
# duit : duit
# korup : korup
# balikin : balikin
# biaya : biaya
# operasional : operasional
# kasian : kasi
# ntar : ntar
# bangkrut : bangkrut
# aplikasinya : aplikasi
# trus : trus
# android : android
# ngeleg : ngeleg
# aplkasi : aplkasi
# tlkomsel : tlkomsel
# berxx : berxx
# hapus : hapus
# dnload : dnload
# layar : layar
# putih : putih
# tok : tok
# tmpilannya : tmpilannya
# ngotak : ngotak
# maen : maen
# kalah : kalah
# gara : gara
# ngelagh : ngelagh
# voucer : voucer
# regional : regional
# woi : woi
# gue : gue
# potong : potong
# ngutang : ngutang
# woy : woy
# bagusin : bagusin
# kya : kya
# lampu : lampu
# lintas : lintas
# segini : gin
# sebulanan : bulan
# alasan : alas
# lawak : lawak
# bercandanya : canda
# voucher : voucher
# belanja : belanja
# berlakunya : laku
# yea : yea
# bosan : bosan
# ngritik : ngritik
# bisanya : bisa
# mohon : mohon
# sisa : sisa
# kincir : kincir
# minum : minum
# obat : obat
# melulu : melulu
# mksd : mksd
# admin : admin
# streaming : streaming
# emang : emang
# juaranya : juara
# koneksinya : koneksi
# stabil : stabil
# sulit : sulit
# dimengerti : erti
# semoga : moga
# cpat : cpat
# diinvite : diinvite
# tuhan : tuhan
# tambahkan : tambah
# fitur : fitur
# sok : sok
# cerita : cerita
# buluk : buluk
# nyoba : nyoba
# restart : restart
# msih : msih
# skrg : skrg
# ilang : ilang
# ilangan : ilangan
# buruk : buruk
# ngisi : ngisi
# bacaannya : baca
# sistem : sistem
# report : report
# coy : coy
# angus : angus
# malam : malam
# lag : lag
# hllo : hllo
# thankyou : thankyou
# berkatmu : berkat
# afk : afk
# minus : minus
# bermutu : mutu
# tll : tll
# tlf : tlf
# jembt : jembt
# beut : beut
# palembang : palembang
# tempatku : tempat
# berhenti : henti
# pepek : pepek
# kota : kota
# bangkeee : bangkeee
# sebulan : bulan
# tkp : tkp
# sumatera : sumatera
# barat : barat
# pindah : pindah
# operator : operator
# sebelah : belah
# asuuu : asuuu
# halo : halo
# lancarkan : lancar
# lalod : lalod
# loading : loading
# sekian : sekian
# terima : terima
# jualan : jual
# ketoprak : ketoprak
# sono : sono
# bantuannya : bantu
# kanapa : kanapa
# geme : geme
# bantuan : bantu
# tombol : tombol
# riwayat : riwayat
# pembelian : beli
# magetan : magetan
# jatim : jatim
# jaringanya : jaringanya
# lihat : lihat
# status : status
# beki : bek
# aaah : aaah
# ngaco : ngaco
# kirim : kirim
# ngerank : ngerank
# cikahuripan : cikahuripan
# klpnunggal : klpnunggal
# bogor : bogor
# kacau : kacau
# kualitas : kualitas
# disesuaikan : sesuai
# trims : trims
# kek : kek
# dajal : dajal
# paok : paok
# mimin : mimin
# bet : bet
# sosmed : sosmed
# post : post
# pingeluh : pingeluh
# bangsad : bangsad
# undian : undi
# hepi : hepi
# tgl : tgl
# menang : menang
# posting : posting
# percaya : percaya
# beneran : beneran
# pengumuma : pengumuma
# undia : undia
# darurat : darurat
# maaf : maaf
# kaga : kaga
# hambur : hambur
# haburin : haburin
# borong : borong
# donasi : donasi
# insyaallah : insyaallah
# berguna : guna
# tukar : tukar
# sia : sia
# strategi : strategi
# marketing : marketing
# biarin : biarin
# emanggak : emanggak
# gunanya : guna
# coba : coba
# ditukar : tukar
# nukar : nukar
# siregar : siregar
# terkait : kait
# keluhan : keluh
# lemah : lemah
# mencoba : coba
# pindahkan : pindah
# otomatis : otomatis
# manual : manual
# harap : harap
# bonus : bonus
# bangkai : bangkai
# ayo : ayo
# pakek : pakek
# orang : orang
# bosen : bosen
# topup : topup
# mytsel : mytsel
# tambahan : tambah
# nambah : nambah
# difix : difix
# {'kuota': 'kuota', 'menyesal': 'sesal', 'beli': 'beli', 'kartu': 'kartu', 'telkomsel': 'telkomsel', 'jaringan': 'jaring', 'beres': 'beres', 'promo': 'promo', 'kenceng': 'kenceng', 'sinyal': 'sinyal', 'kaya': 'kaya', 'sampah': 'sampah', 'ampas': 'ampas', 'banget': 'banget', 'paketan': 'paket', 'mahal': 'mahal', 'iyah': 'iyah', 'paket': 'paket', 'minggu': 'minggu', '': '', 'min': 'min', 'kasi': 'kasi', 'yakali': 'yakali', 'udah': 'udah', 'langganan': 'langgan', 'gapernah': 'gapernah', 'dikasih': 'kasih', 'murah': 'murah', 'cok': 'cok', 'benerin': 'benerin', 'masuk': 'masuk', 'musim': 'musim', 'ujan': 'ujan', 'ancur': 'ancur', 'doank': 'doank', 'seminggu': 'minggu', 'down': 'down', 'gadang': 'gadang', 'nunggu': 'nunggu', 'malem': 'malem', 'bnr': 'bnr', 'sibuk': 'sibuk', 'unlimited': 'unlimited', 'max': 'max', 'maksud': 'maksud', 'fup': 'fup', 'gimana': 'gimana', 'live': 'live', 'chat': 'chat', 'kah': 'kah', 'bot': 'bot', 'pelayanan': 'layan', 'mengecewakan': 'kecewa', 'pelanggan': 'langgan', 'solusi': 'solusi', 'menutupi': 'tutup', 'mengabaikan': 'abai', 'kecewa': 'kecewa', 'internet': 'internet', 'amb': 'amb', 'jar': 'jar', 'lokasi': 'lokasi', 'aktif': 'aktif', 'respon': 'respon', 'sel': 'sel', 'jelek': 'jelek', 'klian': 'klian', 'bsari': 'bsari', 'komen': 'komen', 'gini': 'gin', 'gitu': 'gitu', 'malu': 'malu', 'taik': 'taik', 'makasih': 'makasih', 'telvonan': 'telvonan', 'putus': 'putus', 'ampun': 'ampun', 'berhubungan': 'hubung', 'data': 'data', 'uuhh': 'uuhh', 'sungguh': 'sungguh', 'nyaman': 'nyaman', 'oia': 'oia', 'kau': 'kau', 'bls': 'bls', 'jawabanmu': 'jawab', 'bahagia': 'bahagia', 'membalas': 'balas', 'smsku': 'smsku', 'ngak': 'ngak', 'urat': 'urat', 'benarin': 'benarin', 'tower': 'tower', 'blok': 'blok', 'desa': 'desa', 'jaya': 'jaya', 'bhakti': 'bhakti', 'kec': 'kec', 'mesuji': 'mesuji', 'kab': 'kab', 'ogan': 'ogan', 'komering': 'komering', 'ilir': 'ilir', 'sum': 'sum', 'potret': 'potret', 'rumah': 'rumah', 'kayu': 'kayu', 'sempet': 'sempet', 'ditawarin': 'ditawarin', 'nomer': 'nomer', 'prabayar': 'prabayar', 'pasca': 'pasca', 'bayar': 'bayar', 'minat': 'minat', 'tolak': 'tolak', 'mutasi': 'mutasi', 'aktifasi': 'aktifasi', 'kantor': 'kantor', 'telkom': 'telkom', 'grapari': 'grapari', 'via': 'via', 'tlp': 'tlp', 'harga': 'harga', 'tetep': 'tetep', 'tenan': 'tenan', 'ubah': 'ubah', 'aplikasi': 'aplikasi', 'mytelkomsel': 'mytelkomsel', 'habis': 'habis', 'diupdate': 'diupdate', 'dibuka': 'buka', 'tlong': 'tlong', 'mlm': 'mlm', 'please': 'please', 'perbaiki': 'baik', 'sinyalnya': 'sinyal', 'gangguan': 'ganggu', 'mulu': 'mulu', 'hargaa': 'hargaa', 'jelekkkkk': 'jelekkkkk', 'tolong': 'tolong', 'gratis': 'gratis', 'anak': 'anak', 'belajar': 'ajar', 'uang': 'uang', 'woiiii': 'woiiii', 'knpa': 'knpa', 'kode': 'kode', 'vocer': 'vocer', 'masukin': 'masukin', 'kyk': 'kyk', 'cari': 'cari', 'seru': 'seru', 'registrasi': 'registrasi', 'perdana': 'perdana', 'sim': 'sim', 'card': 'card', 'sms': 'sms', 'telpon': 'telpon', 'contact': 'contact', 'veronika': 'veronika', 'website': 'website', 'facebook': 'facebook', 'messenger': 'messenger', 'sorde': 'sorde', 'bge': 'bge', 'sinyall': 'sinyall', 'hadohhhhh': 'hadohhhhh', 'hoai': 'hoai', 'gila': 'gila', 'busukny': 'busukny', 'telepon': 'telepon', 'teman': 'teman', 'udh': 'udh', 'suka': 'suka', 'kouta': 'kouta', 'mlahan': 'mlahan', 'pas': 'pas', 'main': 'main', 'game': 'game', 'sinyak': 'sinyak', 'hai': 'hai', 'pakai': 'pakai', 'asli': 'asli', 'kak': 'kak', 'isi': 'isi', 'kuata': 'kuata', 'gb': 'gb', 'cepet': 'cepet', 'cuman': 'cuman', 'kartunya': 'kartu', 'bukak': 'bukak', 'doanh': 'doanh', 'gua': 'gua', 'reddem': 'reddem', 'hoki': 'hoki', 'keknya': 'kek', 'scam': 'scam', 'wilayah': 'wilayah', 'kampar': 'kampar', 'kiri': 'kiri', 'rusak': 'rusak', 'nggak': 'nggak', 'terpakai': 'pakai', 'ganti': 'ganti', 'tuker': 'tuker', 'dapet': 'dapet', 'mna': 'mna', 'cek': 'cek', 'poin': 'poin', 'refresh': 'refresh', 'kali': 'kali', 'jaringannya': 'jaring', 'sumber': 'sumber', 'jeleknya': 'jelek', 'nyuruh':  ...
# ------------------------
# Pandas Apply:   0%|          | 0/189 [00:00<?, ?it/s]
#                                                comment  \
# 0                                 kuota paling ga guna
# 1    menyesal saya beli kartu telkomsel, jaringan g...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                 iyah paket minggu ya
# ..                                                 ...
# 193  di tahun baru ini saya harap telkomsel memberi...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana? katanya kalo topup pulsa lewat...
#
#                                       cleaning_comment  \
# 0                                    kuota paling guna
# 1    menyesal saya beli kartu telkomsel jaringan pe...
# 2                                        promo kenceng
# 3    sinyal kaya sampah ampas banget paketan makin ...
# 4                                   iyah paket minggu
# ..                                                 ...
# 193   tahun baru ini saya harap telkomsel memberika...
# 194                                            bangkai
# 195                         ayo semua pakek kartu lain
# 196  lama orang dah bosen pake kartu telkom terus k...
# 197  kak ini gimana katanya kalo topup pulsa lewat ...
#
#                                             tokenisasi  \
# 0                                [kuota, paling, guna]
# 1    [menyesal, saya, beli, kartu, telkomsel, jarin...
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paketan,...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, tahun, baru, ini, saya, harap, telkomsel, m...
# 194                                          [bangkai]
# 195                   [ayo, semua, pakek, kartu, lain]
# 196  [lama, orang, dah, bosen, pake, kartu, telkom,...
# 197  [kak, ini, gimana, katanya, kalo, topup, pulsa...
#
#                                               stopword  \
# 0                                              [kuota]
# 1    [menyesal, beli, kartu, telkomsel, jaringan, b...
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paketan,...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, harap, telkomsel, bonus, paket, data, pelan...
# 194                                          [bangkai]
# 195                                [ayo, pakek, kartu]
# 196  [orang, bosen, kartu, telkom, jaringan, kek, d...
# 197  [kak, gimana, topup, pulsa, aplikasi, mytsel, ...
#
#                                               stemming
# 0                                              [kuota]
# 1       [sesal, beli, kartu, telkomsel, jaring, beres]
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paket, m...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, harap, telkomsel, bonus, paket, data, langg...
# 194                                          [bangkai]
# 195                                [ayo, pakek, kartu]
# 196  [orang, bosen, kartu, telkom, jaring, kek, dajal]
# 197  [kak, gimana, topup, pulsa, aplikasi, mytsel, ...
#
# [189 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                              [kuota]
# 1       [sesal, beli, kartu, telkomsel, jaring, beres]
# 2                                     [promo, kenceng]
# 3    [sinyal, kaya, sampah, ampas, banget, paket, m...
# 4                              [iyah, paket, minggu, ]
# ..                                                 ...
# 193  [, harap, telkomsel, bonus, paket, data, langg...
# 194                                          [bangkai]
# 195                                [ayo, pakek, kartu]
# 196  [orang, bosen, kartu, telkom, jaring, kek, dajal]
# 197  [kak, gimana, topup, pulsa, aplikasi, mytsel, ...
#
# [189 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_12.xlsx')
