# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                        Jaringan aja susah Alias eror
# 1                                    Moga bangkrut asw
# 2       Percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      Oke ver, setuju banget nian ya.
# 4        Iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 276  Telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 277                                                NaN
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           TELKOMSEL buat kesel....
#
# [281 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 9

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                        Jaringan aja susah Alias eror
# 1                                    Moga bangkrut asw
# 2       Percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      Oke ver, setuju banget nian ya.
# 4        Iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  Beli paket game pun jaringan nya tetep ngampas...
# 276  Telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           TELKOMSEL buat kesel....
#
# [268 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2       percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      oke ver, setuju banget nian ya.
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           telkomsel buat kesel....
#
# [268 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2       percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      oke ver, setuju banget nian ya.
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           telkomsel buat kesel....
#
#                                       cleaning_comment
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2          percuma ngeluh balas bot itu  aja balasanya
# 3                          oke ver setuju banget nian
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg udah bulan ngeras...
# 278      tapi percuma juga komen sini balas pasti bot
# 279                         antingleg kau pendusta min
# 280                              telkomsel buat kesel
#
# [268 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2       percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      oke ver, setuju banget nian ya.
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           telkomsel buat kesel....
#
#                                       cleaning_comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2          percuma ngeluh balas bot itu  aja balasanya
# 3                          oke ver setuju banget nian
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg udah bulan ngeras...
# 278      tapi percuma juga komen sini balas pasti bot
# 279                         antingleg kau pendusta min
# 280                              telkomsel buat kesel
#
#                                             tokenisasi
# 0                  [jaringan, aja, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2    [percuma, ngeluh, balas, bot, itu, aja, balasa...
# 3                   [oke, ver, setuju, banget, nian, ]
# 4    [iklan, keren, tapi, sinyal, internet, kok, te...
# ..                                                 ...
# 275  [beli, paket, game, pun, jaringan, nya, tetep,...
# 276  [telkomsel, lama, lama, kek, anjg, udah, bulan...
# 278  [tapi, percuma, juga, komen, sini, balas, past...
# 279                    [antingleg, kau, pendusta, min]
# 280                         [telkomsel, buat, kesel, ]
#
# [268 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2       percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      oke ver, setuju banget nian ya.
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           telkomsel buat kesel....
#
#                                       cleaning_comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2          percuma ngeluh balas bot itu  aja balasanya
# 3                          oke ver setuju banget nian
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg udah bulan ngeras...
# 278      tapi percuma juga komen sini balas pasti bot
# 279                         antingleg kau pendusta min
# 280                              telkomsel buat kesel
#
#                                             tokenisasi  \
# 0                  [jaringan, aja, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2    [percuma, ngeluh, balas, bot, itu, aja, balasa...
# 3                   [oke, ver, setuju, banget, nian, ]
# 4    [iklan, keren, tapi, sinyal, internet, kok, te...
# ..                                                 ...
# 275  [beli, paket, game, pun, jaringan, nya, tetep,...
# 276  [telkomsel, lama, lama, kek, anjg, udah, bulan...
# 278  [tapi, percuma, juga, komen, sini, balas, past...
# 279                    [antingleg, kau, pendusta, min]
# 280                         [telkomsel, buat, kesel, ]
#
#                                               stopword
# 0                       [jaringan, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2                      [ngeluh, balas, bot, balasanya]
# 3                   [oke, ver, setuju, banget, nian, ]
# 4           [iklan, keren, sinyal, internet, terparah]
# ..                                                 ...
# 275  [beli, paket, game, jaringan, tetep, ngampas, ...
# 276  [telkomsel, kek, anjg, udah, ngerasain, sinyal...
# 278                              [komen, balas, bot, ]
# 279                    [antingleg, kau, pendusta, min]
# 280                               [telkomsel, kesel, ]
#
# [268 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 822
# ------------------------
# jaringan : jaring
# susah : susah
# alias : alias
# eror : eror
# moga : moga
# bangkrut : bangkrut
# asw : asw
# ngeluh : ngeluh
# balas : balas
# bot : bot
# balasanya : balasanya
# oke : oke
# ver : ver
# setuju : tuju
# banget : banget
# nian : nian
#  :
# iklan : iklan
# keren : keren
# sinyal : sinyal
# internet : internet
# terparah : parah
# kota : kota
# jakarta : jakarta
# penawaran : tawar
# keluhan : keluh
# dibales : dibales
# tolong : tolong
# telkom : telkom
# perbaiki : baik
# ngelek : ngelek
# amt : amt
# paket : paket
# unlimited : unlimited
# game : game
# udah : udah
# paketan : paket
# kuota : kuota
# utama : utama
# knpa : knpa
# leg : leg
# laload : laload
# isi : isi
# normal : normal
# hadeh : hadeh
# lemot : lot
# rasah : rasah
# kakean : kakean
# ndes : ndes
# ampas : ampas
# hadia : hadia
# hoax : hoax
# ngasih : ngasih
# hadiah : hadiah
# ribet : ribet
# bantu : bantu
# pulsa : pulsa
# darurat : darurat
# mba : mba
# soalanya : soalanya
# ngk : ngk
# stabil : stabil
# dirmhku : dirmhku
# min : min
# halo : halo
# tsel : tsel
# mengganti : ganti
# nomor : nomor
# pambayaran : pambayaran
# dana : dana
# maxstrem : maxstrem
# update : update
# tonton : tonton
# layar : layar
# hitam : hitam
# doank : doank
# lawak : lawak
# bact : bact
# ngentt : ngentt
# tuker : tuker
# poin : poin
# ganti : ganti
# kartu : kartu
# wkwkwkwkkwkwkwkwkwkwk : wkwkwkwkkwkwkwkwkwkwk
# mind : mind
# gmna : gmna
# msk : msk
# sisa : sisa
# sedot : sedot
# beli : beli
# gb : gb
# bkn : bkn
# slalu : slalu
# buriq : buriq
# lose : lose
# streak : streak
# gara : gara
# parasit : parasit
# asuu : asuu
# nyingg : nyingg
# gua : gua
# kecewa : kecewa
# telkomsel : telkomsel
# ngecewain : ngecewain
# cek : cek
# usia : usia
# gimana : gimana
# lag : lag
# tross : tross
# bohong : bohong
# didesa : desa
# wanareja : wanareja
# kecamatan : camat
# rimbo : rimbo
# ulu : ulu
# kabupaten : kabupaten
# tebo : tebo
# jambi : jambi
# sinyalnya : sinyal
# ancur : ancur
# parah : parah
# semingguan : minggu
# mengganggu : ganggu
# ngeselin : ngeselin
# teman : teman
# aktifnya : aktif
# kelewat : lewat
# kartunya : kartu
# dipake : dipake
# diperbaiki : baik
# fokus : fokus
# segini : gin
# nggak : nggak
# warga : warga
# indo : indo
# perangkat : perangkat
# ber : ber
# signal : signal
# youtube : youtube
# appsnya : appsnya
# combo : combo
# sakti : sakti
# ditulis : tulis
# keterangan : terang
# selamat : selamat
# mendekati : dekat
# gulung : gulung
# tikar : tikar
# smakin : smakin
# lma : lma
# smkin : smkin
# buruk : buruk
# jaringanya : jaringanya
# aminn : aminn
# jarang : jarang
# promo : promo
# will : will
# buy : buy
# when : when
# you : you
# fix : fix
# your : your
# goddamn : goddamn
# sakit : sakit
# turun : turun
# alhasil : alhasil
# in : in
# lowbat : lowbat
# reset : reset
# kah : kah
# event : event
# tukar : tukar
# kouta : kouta
# boss : boss
# stabilkan : stabil
# do : do
# ng : ng
# thank : thank
# zzz : zzz
# ulang : ulang
# thn : thn
# semoga : moga
# sukses : sukses
# amin : amin
# terhubungan : hubung
# operatos : operatos
# pep : pep
# unlimeted : unlimeted
# harga : harga
# sayang : sayang
# kompensasinya : kompensasi
# bersaing : saing
# sehat : sehat
# wanita : wanita
# pria : pria
# tangguh : tangguh
# liat : liat
# pacar : pacar
# ntah : ntah
# atao : atao
# guw : guw
# rugikan : rugi
# main : main
# beginj : beginj
# only : only
# ttp : ttp
# kek : kek
# gini : gin
# mls : mls
# cok : cok
# buka : buka
# komik : komik
# error : error
# trus : trus
# nyimak : nyimak
# bae : bae
# inti : inti
# namah : namah
# mahal : mahal
# faket : faket
# kehabisan : habis
# kemaren : kemaren
# kesedot : sedot
# ama : ama
# keknya : kek
# bbvvippekenindo : bbvvippekenindo
# sebener : sebener
# masi : mas
# otak : otak
# kaga : kaga
# nyari : nyari
# cuan : cuan
# doang : doang
# coba : coba
# jaringannya : jaring
# deh : deh
# konten : konten
# trah : trah
# komen : komen
# positip : positip
# jngn : jngn
# keuntungan : untung
# jamban : jamban
# ngecek : ngecek
# data : data
# aplikasi : aplikasi
# tanda : tanda
# info : info
# kecepatan : cepat
# langsung : langsung
# auto : auto
# down : down
# mentok : mentok
# ksn : ksn
# mendingan : mending
# beralih : alih
# operator : operator
# nokia : nokia
# asha : asha
# anjjiiiiiiing : anjjiiiiiiing
# push : push
# rank : rank
# klw : klw
# atw : atw
# afk : afk
# mulu : mulu
# saranin : saranin
# maenya : maenya
# nyaman : nyaman
# hrs : hrs
# laen : laen
# setaun : taun
# karna : karna
# mengharapkan : harap
# bagus : bagus
# hbiskan : hbiskan
# kenyataan : nyata
# meninggalkan : tinggal
# turunin : turunin
# woe : woe
# gangguan : ganggu
# customer : customer
# suka : suka
# duitnya : duit
# pelanggan : langgan
# cuih : cuih
# lihat : lihat
# berkat : berkat
# menang : menang
# permahal : mahal
# evercoss : evercoss
# kompensasi : kompensasi
# player : player
# disebabkan : sebab
# diamond : diamond
# buang : buang
# advan : advan
# kakak : kakak
# mimim : mimim
# jadul : jadul
# lupa : lupa
# serienya : serienya
# pokoknya : pokok
# casingnya : casingnya
# gampang : gampang
# dilepas : lepas
# cdma : cdma
# mah : mah
# gtu : gtu
# udh : udh
# ngisi : ngisi
# paketin : paketin
# lgi : lgi
# giliran : gilir
# gda : gda
# pulsanya : pulsa
# angus : angus
# anjiing : anjiing
# jaringn : jaringn
# mengecewakan : kecewa
# putuskan : putus
# cairin : cairin
# uang : uang
# kayak : kayak
# taik : taik
# komtol : komtol
# ilang : ilang
# daerah : daerah
# mandailing : mandailing
# natal : natal
# panyabungan : panyabungan
# eeq : eeq
# khusus : khusus
# samsung : samsung
# hilang : hilang
# atasinya : atas
# mudah : mudah
# apk : apk
# telepon : telepon
# matikan : mati
# dial : dial
# klik : klik
# panggil : panggil
# muncul : muncul
# pesan : pesan
# ssid : ssid
# batal : batal
# otomatis : otomatis
# metode : metode
# off : off
# mode : mode
# ngelag : ngelag
# bngt : bngt
# gitu : gitu
# lostrek : lostrek
# subcreibe : subcreibe
# provider : provider
# anjim : anjim
# jelek : jelek
# pelanggannya : langgan
# iya : iya
# masak : masak
# pubg : pubg
# voucher : voucher
# diskon : diskon
# mohon : mohon
# maen : maen
# enk : enk
# awokawoka : awokawoka
# jaringgannya : jaringgannya
# ngotaklah : ngotaklah
# boros : boros
# mantep : mantep
# share : share
# viralkan : viralkan
# penyadapan : sadap
# pencurian : curi
# pribadi : pribadi
# percobaan : coba
# pembunuhan : bunuh
# berencana : rencana
# kudus : kudus
# jawa : jawa
# tekan : tekan
# nongol : nongol
# rajanya : raja
# tembak : tembak
# inject : inject
# cocok : cocok
# transfer : transfer
# sesuai : sesuai
# nominal : nominal
# oplos : oplos
# reguler : reguler
# propaider : propaider
# ampun : ampun
# sumpah : sumpah
# area : area
# timur : timur
# sidoarjo : sidoarjo
# malu : malu
# noh : noh
# woy : woy
# telkomtolll : telkomtolll
# pas : pas
# enak : enak
# enaknya : enak
# modar : modar
# ccad : ccad
# ngtd : ngtd
# hadej : hadej
# smpah : smpah
# internetan : internetan
# ininomer : ininomer
# sales : sales
# kuningan : kuningan
# desa : desa
# caguer : caguer
# tower : tower
# fiber : fiber
# optik : optik
# assalamulaikum : assalamulaikum
# mimin : mimin
# yng : yng
# kyak : kyak
# anjjiiiinnngggggg : anjjiiiinnngggggg
# pinjam : pinjam
# unreg : unreg
# aktip : aktip
# pamakaian : pamakaian
# tenggang : tenggang
# riau : riau
# hadirrrr : hadirrrr
# dicek : cek
# simpati : simpati
# nomer : nomer
# triji : triji
# dicoba : coba
# akses : akses
# tetep : tetep
# trimakasih : trimakasih
# sampah : sampah
# bucekk : bucekk
# jaringana : jaringana
# jaringannnya : jaringannnya
# ngilang : ngilang
# melulu : melulu
# pdahal : pdahal
# situ : situ
# nyolong : nyolong
# skrang : skrang
# benerin : benerin
# nmgntd : nmgntd
# jdi : jdi
# sekedar : dar
# saran : saran
# nama : nama
# telkomnyet : telkomnyet
# lancar : lancar
# julukan : juluk
# terkuat : kuat
# indonesia : indonesia
# nyata : nyata
# melebihi : lebih
# murahan : murah
# komplen : komplen
# memperbaiki : baik
# kesampah : sampah
# woi : woi
# gajelas : gajelas
# trs : trs
# cape : cape
# teris : ter
# gada : gada
# one : one
# simi : simi
# ngjak : ngjak
# ribut : ribut
# temen : temen
# pelit : pelit
# jaga : jaga
# sip : sip
# malem : malem
# sypa : sypa
# kak : kak
# jam : jam
# bet : bet
# anyiiing : anyiiing
# kenalin : kenalin
# teknologi : teknologi
# perbarui : baru
# setan : setan
# nonton : nonton
# omg : omg
# kepotong : potong
# aneh : aneh
# hai : hai
# uda : uda
# gila : gila
# pengguna : guna
# admin : admin
# aktifkan : aktif
# prabayar : prabayar
# tertarik : tarik
# utang : utang
# gatau : gatau
# berguna : guna
# gamemax : gamemax
# pke : pke
# apapun : apa
# pokonya : poko
# gunain : gunain
# yuk : yuk
# sim : sim
# lokal : lokal
# penjahat : jahat
# mempermainkan : main
# makah : makah
# dipakai : pakai
# lapor : lapor
# berkali : kali
# solusi : solusi
# perampok : rampok
# naikin : naikin
# teruuus : teruuus
# kualitasnya : kualitas
# taek : taek
# niat : niat
# seluler : seluler
# jualan : jual
# martabak : martabak
# kpn : kpn
# dpt : dpt
# geratisannya : geratisannya
# ayo : ayo
# gugat : gugat
# rame : rame
# wee : wee
# ribu : ribu
# wei : wei
# pilihan : pilih
# paketnya : paket
# ketengan : keteng
# instagram : instagram
# facebook : facebook
# ketik : ketik
# restart : restart
# jujur : jujur
# keceewa : keceewa
# pakai : pakai
# gprs : gprs
# surabaya : surabaya
# utara : utara
# kesini : kesini
# serius : serius
# online : online
# pelosok : pelosok
# ibukota : ibukota
# provinsi : provinsi
# lucu : lucu
# sehari : hari
# sisanya : sisa
# serasa : serasa
# terror : terror
# godean : godean
# sleman : sleman
# yogyakarta : yogyakarta
# malam : malam
# terima : terima
# kasih : kasih
# maxtsream : maxtsream
# vidio : vidio
# bola : bola
# maaf : maaf
# wilayah : wilayah
# jatiagung : jatiagung
# lampung : lampung
# selatan : selatan
# tempatku : tempat
# lombok : lombok
# gerangan : gerangan
# acok : acok
# timbua : timbua
# lambek : lambek
# bana : bana
# cando : cando
# langkitang : langkitang
# sawah : sawah
# anjeeng : anjeeng
# sibuk : sibuk
# becus : becus
# maximalin : maximalin
# ngluarin : ngluarin
# ancooorrr : ancooorrr
# heh : heh
# lol : lol
# gede : gede
# perusahaannya : usaha
# maju : maju
# ngatasi : ngatasi
# kagak : kagak
# becuss : becuss
# mudahan : mudah
# cepet : cepet
# tlkmtol : tlkmtol
# knp : knp
# lgsg : lgsg
# santai : santai
# reconnecting : reconnecting
# emang : emang
# perbaikin : perbaikin
# org : org
# bayar : bayar
# jenis : jenis
# males : males
# diauruh : diauruh
# lobby : lobby
# wkkwkkw : wkkwkkw
# obat : obat
# solusinya : solusi
# yok : yok
# move : move
# maxstream : maxstream
# ngga : ngga
# gunanya : guna
# gimanasih : gimanasih
# seenggak : enggak
# beritahu : beritahu
# kendalanya : kendala
# posting : posting
# msalah : msalah
# bsa : bsa
# emg : emg
# trobel : trobel
# mlah : mlah
# terua : rua
# besok : besok
# telkomtel : telkomtel
# bentar : bentar
# salah : salah
# sampe : sampe
# kadang : kadang
# payah : payah
# bar : bar
# ngilangin : ngilangin
# donk : donk
# monyet : monyet
# mesti : mesti
# bener : bener
# nyuruh : nyuruh
# jaringanmu : jaring
# didaerah : daerah
# medan : medan
# sunggal : sunggal
# telaga : telaga
# sari : sari
# putus : putus
# nyambung : nyambung
# seminggu : minggu
# sok : sok
# member : member
# asli : asli
# gedek : gedek
# bapuk : bapuk
# kelurahan : lurah
# gubris : gubris
# untung : untung
# kaya : kaya
# konto : konto
# jaraingan : jaraingan
# nglag : nglag
# akun : akun
# ngentodddd : ngentodddd
# berkurang : kurang
# bli : bli
# kepake : kepake
# contoh : contoh
# badut : badut
# corrupt : corrupt
# anjg : anjg
# kepala : kepala
# kau : kau
# mempermudah : mudah
# hidup : hidup
# keong : keong
# sampaaahhhhh : sampaaahhhhh
# babbiiiiiii : babbiiiiiii
# ulangan : ulang
# terefresh : terefresh
# menit : menit
# nilai : nilai
# suruh : suruh
# pindah : pindah
# rsah : rsah
# omong : omong
# bnerke : bnerke
# sek : sek
# blok : blok
# sabar : sabar
# mending : mending
# im : im
# downloadnya : downloadnya
# diratakan : rata
# towernya : towernya
# bang : bang
# jarigang : jarigang
# ubah : ubah
# jelekkan : jelek
# naudzubillah : naudzubillah
# sma : sma
# milik : milik
# negeri : negeri
# bikinnya : bikin
# ngeri : ngeri
# detik : detik
# maksimal : maksimal
# sukka : sukka
# ngebut : ngebut
# download : download
# upload : upload
# mantap : mantap
# kasi : kasi
# model : model
# bantuannya : bantu
# poinnya : poin
# lumayan : lumayan
# paketanya : paketanya
# bermanfaat : manfaat
# begooo : begooo
# burik : burik
# ditanggapin : ditanggapin
# transaksi : transaksi
# gue : gue
# belasan : bas
# gedung : gedung
# sulta : sulta
# kualitas : kualitas
# faktanya : fakta
# bertahun : tahun
# timbul : timbul
# buqt : buqt
# ping : ping
# ijo : ijo
# ngeleg : ngeleg
# kgk : kgk
# gamesmax : gamesmax
# lengkap : lengkap
# garena : garena
# masuk : masuk
# yaa : yaa
# dlu : dlu
# bru : bru
# dehh : dehh
# make : make
# nyalain : nyalain
# mic : mic
# tem : tem
# aduh : aduh
# nyesel : nyesel
# ngarep : ngarep
# dunk : dunk
# nyoba : nyoba
# classic : classic
# dusta : dusta
# fakta : fakta
# pinknya : pinknya
# merah : merah
# poco : poco
# pro : pro
# simcard : simcard
# bolak : bolak
# pengaruh : pengaruh
# mmg : mmg
# ktika : ktika
# lgsung : lgsung
# switch : switch
# hahaha : hahaha
# kakek : kakek
# full : full
# bekicot : bekicot
# paketahal : paketahal
# ujung : ujung
# nikmati : nikmat
# siang : siang
# tiktok : tiktok
# pugb : pugb
# aktifin : aktifin
# kemdikbud : kemdikbud
# games : games
# max : max
# tipu : tipu
# kuoota : kuoota
# utuh : utuh
# bangsad : bangsad
# peleerrrr : peleerrrr
# knapa : knapa
# lobi : lobi
# kmrn : kmrn
# sore : sore
# lanjar : lanjar
# alhamdulillah : alhamdulillah
# nggk : nggk
# thaek : thaek
# signaaaal : signaaaal
# mak : mak
# laknat : laknat
# taiksel : taiksel
# mimpiiiiiiiiiiiiiiiiiii : mimpiiiiiiiiiiiiiiiiiii
# anti : anti
# chat : chat
# mim : mim
# jahanam : jahanam
# hancur : hancur
# enggk : enggk
# fulll : fulll
# bacot : bacot
# ngampas : ngampas
# anying : anying
# ngerasain : ngerasain
# antingleg : antingleg
# pendusta : dusta
# kesel : kesel
# {'jaringan': 'jaring', 'susah': 'susah', 'alias': 'alias', 'eror': 'eror', 'moga': 'moga', 'bangkrut': 'bangkrut', 'asw': 'asw', 'ngeluh': 'ngeluh', 'balas': 'balas', 'bot': 'bot', 'balasanya': 'balasanya', 'oke': 'oke', 'ver': 'ver', 'setuju': 'tuju', 'banget': 'banget', 'nian': 'nian', '': '', 'iklan': 'iklan', 'keren': 'keren', 'sinyal': 'sinyal', 'internet': 'internet', 'terparah': 'parah', 'kota': 'kota', 'jakarta': 'jakarta', 'penawaran': 'tawar', 'keluhan': 'keluh', 'dibales': 'dibales', 'tolong': 'tolong', 'telkom': 'telkom', 'perbaiki': 'baik', 'ngelek': 'ngelek', 'amt': 'amt', 'paket': 'paket', 'unlimited': 'unlimited', 'game': 'game', 'udah': 'udah', 'paketan': 'paket', 'kuota': 'kuota', 'utama': 'utama', 'knpa': 'knpa', 'leg': 'leg', 'laload': 'laload', 'isi': 'isi', 'normal': 'normal', 'hadeh': 'hadeh', 'lemot': 'lot', 'rasah': 'rasah', 'kakean': 'kakean', 'ndes': 'ndes', 'ampas': 'ampas', 'hadia': 'hadia', 'hoax': 'hoax', 'ngasih': 'ngasih', 'hadiah': 'hadiah', 'ribet': 'ribet', 'bantu': 'bantu', 'pulsa': 'pulsa', 'darurat': 'darurat', 'mba': 'mba', 'soalanya': 'soalanya', 'ngk': 'ngk', 'stabil': 'stabil', 'dirmhku': 'dirmhku', 'min': 'min', 'halo': 'halo', 'tsel': 'tsel', 'mengganti': 'ganti', 'nomor': 'nomor', 'pambayaran': 'pambayaran', 'dana': 'dana', 'maxstrem': 'maxstrem', 'update': 'update', 'tonton': 'tonton', 'layar': 'layar', 'hitam': 'hitam', 'doank': 'doank', 'lawak': 'lawak', 'bact': 'bact', 'ngentt': 'ngentt', 'tuker': 'tuker', 'poin': 'poin', 'ganti': 'ganti', 'kartu': 'kartu', 'wkwkwkwkkwkwkwkwkwkwk': 'wkwkwkwkkwkwkwkwkwkwk', 'mind': 'mind', 'gmna': 'gmna', 'msk': 'msk', 'sisa': 'sisa', 'sedot': 'sedot', 'beli': 'beli', 'gb': 'gb', 'bkn': 'bkn', 'slalu': 'slalu', 'buriq': 'buriq', 'lose': 'lose', 'streak': 'streak', 'gara': 'gara', 'parasit': 'parasit', 'asuu': 'asuu', 'nyingg': 'nyingg', 'gua': 'gua', 'kecewa': 'kecewa', 'telkomsel': 'telkomsel', 'ngecewain': 'ngecewain', 'cek': 'cek', 'usia': 'usia', 'gimana': 'gimana', 'lag': 'lag', 'tross': 'tross', 'bohong': 'bohong', 'didesa': 'desa', 'wanareja': 'wanareja', 'kecamatan': 'camat', 'rimbo': 'rimbo', 'ulu': 'ulu', 'kabupaten': 'kabupaten', 'tebo': 'tebo', 'jambi': 'jambi', 'sinyalnya': 'sinyal', 'ancur': 'ancur', 'parah': 'parah', 'semingguan': 'minggu', 'mengganggu': 'ganggu', 'ngeselin': 'ngeselin', 'teman': 'teman', 'aktifnya': 'aktif', 'kelewat': 'lewat', 'kartunya': 'kartu', 'dipake': 'dipake', 'diperbaiki': 'baik', 'fokus': 'fokus', 'segini': 'gin', 'nggak': 'nggak', 'warga': 'warga', 'indo': 'indo', 'perangkat': 'perangkat', 'ber': 'ber', 'signal': 'signal', 'youtube': 'youtube', 'appsnya': 'appsnya', 'combo': 'combo', 'sakti': 'sakti', 'ditulis': 'tulis', 'keterangan': 'terang', 'selamat': 'selamat', 'mendekati': 'dekat', 'gulung': 'gulung', 'tikar': 'tikar', 'smakin': 'smakin', 'lma': 'lma', 'smkin': 'smkin', 'buruk': 'buruk', 'jaringanya': 'jaringanya', 'aminn': 'aminn', 'jarang': 'jarang', 'promo': 'promo', 'will': 'will', 'buy': 'buy', 'when': 'when', 'you': 'you', 'fix': 'fix', 'your': 'your', 'goddamn': 'goddamn', 'sakit': 'sakit', 'turun': 'turun', 'alhasil': 'alhasil', 'in': 'in', 'lowbat': 'lowbat', 'reset': 'reset', 'kah': 'kah', 'event': 'event', 'tukar': 'tukar', 'kouta': 'kouta', 'boss': 'boss', 'stabilkan': 'stabil', 'do': 'do', 'ng': 'ng', 'thank': 'thank', 'zzz': 'zzz', 'ulang': 'ulang', 'thn': 'thn', 'semoga': 'moga', 'sukses': 'sukses', 'amin': 'amin', 'terhubungan': 'hubung', 'operatos': 'operatos', 'pep': 'pep', 'unlimeted': 'unlimeted', 'harga': 'harga', 'sayang': 'sayang', 'kompensasinya': 'kompensasi', 'bersaing': 'saing', 'sehat': 'sehat', 'wanita': 'wanita', 'pria': 'pria', 'tangguh': 'tangguh', 'liat': 'liat', 'pacar': 'pacar', 'ntah': 'ntah', 'atao': 'atao', 'guw': 'guw', 'rugikan': 'rugi', 'main': 'main', 'beginj': 'beginj', 'only': 'only', 'ttp': 'ttp', 'kek': 'kek', 'gini': 'gin', 'mls': 'mls', 'cok': 'cok', 'buka': 'buka', 'komik': 'komik', 'error': 'error', 'trus': 'trus', 'nyimak': 'nyimak', 'bae': 'bae' ...
# ------------------------
# Pandas Apply:   0%|          | 0/268 [00:00<?, ?it/s]
#                                                comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2       percuma ngeluh yg balas bot,itu2 aja balasanya
# 3                      oke ver, setuju banget nian ya.
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg, udah 2 bulan gw ...
# 278  tapi percuma juga komen di sini, yg balas past...
# 279                         antingleg kau pendusta min
# 280                           telkomsel buat kesel....
#
#                                       cleaning_comment  \
# 0                        jaringan aja susah alias eror
# 1                                    moga bangkrut asw
# 2          percuma ngeluh balas bot itu  aja balasanya
# 3                          oke ver setuju banget nian
# 4        iklan keren tapi sinyal internet kok terparah
# ..                                                 ...
# 275  beli paket game pun jaringan nya tetep ngampas...
# 276  telkomsel lama lama kek anjg udah bulan ngeras...
# 278      tapi percuma juga komen sini balas pasti bot
# 279                         antingleg kau pendusta min
# 280                              telkomsel buat kesel
#
#                                             tokenisasi  \
# 0                  [jaringan, aja, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2    [percuma, ngeluh, balas, bot, itu, aja, balasa...
# 3                   [oke, ver, setuju, banget, nian, ]
# 4    [iklan, keren, tapi, sinyal, internet, kok, te...
# ..                                                 ...
# 275  [beli, paket, game, pun, jaringan, nya, tetep,...
# 276  [telkomsel, lama, lama, kek, anjg, udah, bulan...
# 278  [tapi, percuma, juga, komen, sini, balas, past...
# 279                    [antingleg, kau, pendusta, min]
# 280                         [telkomsel, buat, kesel, ]
#
#                                               stopword  \
# 0                       [jaringan, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2                      [ngeluh, balas, bot, balasanya]
# 3                   [oke, ver, setuju, banget, nian, ]
# 4           [iklan, keren, sinyal, internet, terparah]
# ..                                                 ...
# 275  [beli, paket, game, jaringan, tetep, ngampas, ...
# 276  [telkomsel, kek, anjg, udah, ngerasain, sinyal...
# 278                              [komen, balas, bot, ]
# 279                    [antingleg, kau, pendusta, min]
# 280                               [telkomsel, kesel, ]
#
#                                               stemming
# 0                         [jaring, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2                      [ngeluh, balas, bot, balasanya]
# 3                     [oke, ver, tuju, banget, nian, ]
# 4              [iklan, keren, sinyal, internet, parah]
# ..                                                 ...
# 275  [beli, paket, game, jaring, tetep, ngampas, an...
# 276  [telkomsel, kek, anjg, udah, ngerasain, sinyal...
# 278                              [komen, balas, bot, ]
# 279                       [antingleg, kau, dusta, min]
# 280                               [telkomsel, kesel, ]
#
# [268 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                         [jaring, susah, alias, eror]
# 1                                [moga, bangkrut, asw]
# 2                      [ngeluh, balas, bot, balasanya]
# 3                     [oke, ver, tuju, banget, nian, ]
# 4              [iklan, keren, sinyal, internet, parah]
# ..                                                 ...
# 275  [beli, paket, game, jaring, tetep, ngampas, an...
# 276  [telkomsel, kek, anjg, udah, ngerasain, sinyal...
# 278                              [komen, balas, bot, ]
# 279                       [antingleg, kau, dusta, min]
# 280                               [telkomsel, kesel, ]
#
# [268 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_11.xlsx')
