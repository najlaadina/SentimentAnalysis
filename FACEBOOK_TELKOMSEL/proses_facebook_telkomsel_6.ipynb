# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_TELKOMSEL\data mentah\facebook_telkomsel_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Kenapa setelah saya membeli paket di *363# lgs...
# 1    Maketin kouta blajar ga aktif aktif mana pulsa...
# 2    Masa aktifnya kemarin 16-06-21 trus gw isi Pul...
# 3    Benerin jaringan lu, promo sana sini di iklan ...
# 4                        Telkomsel beli paket kok lama
# ..                                                 ...
# 237  Wooyyy jaringan benerin woyyy... Di jakarta se...
# 238                           Kartu mahal,sinyal jelek
# 239                                         @Telkomsel
# 240                          Murah in paket gua anjeng
# 241  WOI PARAH MAEN GAME MERAH TERUS JARINGANNNYAA ...
#
# [242 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Kenapa setelah saya membeli paket di *363# lgs...
# 1    Maketin kouta blajar ga aktif aktif mana pulsa...
# 2    Masa aktifnya kemarin 16-06-21 trus gw isi Pul...
# 3    Benerin jaringan lu, promo sana sini di iklan ...
# 4                        Telkomsel beli paket kok lama
# ..                                                 ...
# 237  Wooyyy jaringan benerin woyyy... Di jakarta se...
# 238                           Kartu mahal,sinyal jelek
# 239                                         @Telkomsel
# 240                          Murah in paket gua anjeng
# 241  WOI PARAH MAEN GAME MERAH TERUS JARINGANNNYAA ...
#
# [239 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    kenapa setelah saya membeli paket di *363# lgs...
# 1    maketin kouta blajar ga aktif aktif mana pulsa...
# 2    masa aktifnya kemarin 16-06-21 trus gw isi pul...
# 3    benerin jaringan lu, promo sana sini di iklan ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy... di jakarta se...
# 238                           kartu mahal,sinyal jelek
# 239                                         @telkomsel
# 240                          murah in paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
# [239 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    kenapa setelah saya membeli paket di *363# lgs...
# 1    maketin kouta blajar ga aktif aktif mana pulsa...
# 2    masa aktifnya kemarin 16-06-21 trus gw isi pul...
# 3    benerin jaringan lu, promo sana sini di iklan ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy... di jakarta se...
# 238                           kartu mahal,sinyal jelek
# 239                                         @telkomsel
# 240                          murah in paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                       cleaning_comment
# 0    kenapa setelah saya membeli paket   lgsng jln ...
# 1    maketin kouta blajar aktif aktif mana pulsa da...
# 2    masa aktifnya kemarin trus isi pulsa malah akt...
# 3    benerin jaringan promo sana sini iklan sinyal ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy jakarta serasa p...
# 238                           kartu mahal sinyal jelek
# 239
# 240                             murah paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
# [239 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    kenapa setelah saya membeli paket di *363# lgs...
# 1    maketin kouta blajar ga aktif aktif mana pulsa...
# 2    masa aktifnya kemarin 16-06-21 trus gw isi pul...
# 3    benerin jaringan lu, promo sana sini di iklan ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy... di jakarta se...
# 238                           kartu mahal,sinyal jelek
# 239                                         @telkomsel
# 240                          murah in paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                       cleaning_comment  \
# 0    kenapa setelah saya membeli paket   lgsng jln ...
# 1    maketin kouta blajar aktif aktif mana pulsa da...
# 2    masa aktifnya kemarin trus isi pulsa malah akt...
# 3    benerin jaringan promo sana sini iklan sinyal ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy jakarta serasa p...
# 238                           kartu mahal sinyal jelek
# 239
# 240                             murah paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                             tokenisasi
# 0    [kenapa, setelah, saya, membeli, paket, lgsng,...
# 1    [maketin, kouta, blajar, aktif, aktif, mana, p...
# 2    [masa, aktifnya, kemarin, trus, isi, pulsa, ma...
# 3    [benerin, jaringan, promo, sana, sini, iklan, ...
# 4                  [telkomsel, beli, paket, kok, lama]
# ..                                                 ...
# 237  [wooyyy, jaringan, benerin, woyyy, jakarta, se...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, terus, jaringa...
#
# [239 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    kenapa setelah saya membeli paket di *363# lgs...
# 1    maketin kouta blajar ga aktif aktif mana pulsa...
# 2    masa aktifnya kemarin 16-06-21 trus gw isi pul...
# 3    benerin jaringan lu, promo sana sini di iklan ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy... di jakarta se...
# 238                           kartu mahal,sinyal jelek
# 239                                         @telkomsel
# 240                          murah in paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                       cleaning_comment  \
# 0    kenapa setelah saya membeli paket   lgsng jln ...
# 1    maketin kouta blajar aktif aktif mana pulsa da...
# 2    masa aktifnya kemarin trus isi pulsa malah akt...
# 3    benerin jaringan promo sana sini iklan sinyal ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy jakarta serasa p...
# 238                           kartu mahal sinyal jelek
# 239
# 240                             murah paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                             tokenisasi  \
# 0    [kenapa, setelah, saya, membeli, paket, lgsng,...
# 1    [maketin, kouta, blajar, aktif, aktif, mana, p...
# 2    [masa, aktifnya, kemarin, trus, isi, pulsa, ma...
# 3    [benerin, jaringan, promo, sana, sini, iklan, ...
# 4                  [telkomsel, beli, paket, kok, lama]
# ..                                                 ...
# 237  [wooyyy, jaringan, benerin, woyyy, jakarta, se...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, terus, jaringa...
#
#                                               stopword
# 0    [membeli, paket, lgsng, jln, internetny, sblm,...
# 1    [maketin, kouta, blajar, aktif, aktif, pulsa, ...
# 2    [aktifnya, kemarin, trus, isi, pulsa, aktif, t...
# 3    [benerin, jaringan, promo, iklan, sinyal, kuat...
# 4                             [telkomsel, beli, paket]
# ..                                                 ...
# 237  [wooyyy, jaringan, benerin, woyyy, jakarta, se...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, jaringannnyaa,...
#
# [239 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 846
# ------------------------
# membeli : beli
# paket : paket
# lgsng : lgsng
# jln : jln
# internetny : internetny
# sblm : sblm
# ngisi : ngisi
# lwt : lwt
# telkomsel : telkomsel
#  :
# maketin : maketin
# kouta : kouta
# blajar : blajar
# aktif : aktif
# pulsa : pulsa
# ambil : ambil
# gmana : gmana
# aduh : aduh
# aktifnya : aktif
# kemarin : kemarin
# trus : trus
# isi : isi
# tgl : tgl
# hrusnya : hrusnya
# sebulan : bulan
# benerin : benerin
# jaringan : jaring
# promo : promo
# iklan : iklan
# sinyal : sinyal
# kuat : kuat
# bagus : bagus
# bufering : bufering
# kipak : kipak
# parah : parah
# pembohongan : bohong
# publik : publik
# namanya : nama
# beli : beli
# loyo : loyo
# gmna : gmna
# kak : kak
# reedem : reedem
# lupa : lupa
# gbsa : gbsa
# min : min
# unlimitednya : unlimitednya
# dikembalikan : kembali
# paketnya : paket
# ngapain : ngapain
# darurat : darurat
# gue : gue
# pakai : pakai
# pulak : pulak
# ekstra : ekstra
# aktifin : aktifin
# tagihan : tagih
# doble : doble
# bill : bill
# rb : rb
# panas : panas
# batere : batere
# cepet : cepet
# habis : habis
# dipake : dipake
# jngn : jngn
# lalaikan : lalai
# donk : donk
# keamanan : aman
# kenyamananx : kenyamananx
# pelanggan : langgan
# berselancar : selancar
# menikmati : nikmat
# pelayananx : pelayananx
# bnr : bnr
# faedah : faedah
# konten : konten
# tolong : tolong
# diperbaiki : baik
# upgrade : upgrade
# daerah : daerah
# kab : kab
# bekasi : bekas
# cikarang : cikarang
# utara : utara
# bantu : bantu
# nama : nama
# udah : udah
# terkenal : kenal
# mahal : mahal
# pas : pas
# masukin : masukin
# kode : kode
# vouchr : vouchr
# gini : gin
# trs : trs
# kodenya : kode
# bener : bener
# giga : giga
# rp : rp
# sugan : sugan
# rek : rek
# turun : turun
# harga : harga
# kuota : kuota
# kalahkah : kalah
# ttp : ttp
# php : php
# elite : elite
# mode : mode
# tertawa : tertawa
# jelek : jelek
# in : in
# senang : senang
# kartu : kartu
# karna : karna
# murah : murah
# geratis : gerat
# drefresh : drefresh
# pesawat : pesawat
# sinyalnya : sinyal
# bejat : bejat
# keluhan : keluh
# lempar : lempar
# orang : orang
# makan : makan
# gaji : gaji
# buta : buta
# ente : ente
# ngaku : ngaku
# paketan : paket
# pemenang : menang
# voting : voting
# awards : awards
# kesel : kesel
# mb : mb
# kcepatan : kcepatan
# inet : inet
# kb : kb
# hrga : hrga
# naikin : naikin
# mlah : mlah
# ancoor : ancoor
# lemot : lot
# cileungsi : cileungsi
# bogor : bogor
# malem : malem
# minggu : minggu
# event : event
# main : main
# game : game
# nggak : nggak
# sya : sya
# susah : susah
# banget : banget
# singal : singal
# ntah : ntah
# award : award
# ultah : ultah
# tetep : tetep
# soak : soak
# keknya : kek
# gebrakan : gebrak
# setianya : setia
# kesekian : sekian
# kalinya : kali
# emosi : emosi
# gara : gara
# kek : kek
# keong : keong
# woy : woy
# koneksi : koneksi
# komen : komen
# bales : bales
# bot : bot
# telkmsel : telkmsel
# ngga : ngga
# ngetik : ngetik
# toba : toba
# quota : quota
# aktip : aktip
# kenap : kenap
# woii : woii
# gangguan : ganggu
# kah : kah
# kemana : mana
# tibatiba : tibatiba
# hilang : hilang
# telkom : telkom
# daruratny : daruratny
# unlimax : unlimax
# jan : jan
# kasih : kasih
# fup : fup
# pengguna : guna
# android : android
# update : update
# aplikasi : aplikasi
# kompatibel : kompatibel
# pindah : pindah
# lite : lite
# ganti : ganti
# contohnya : contoh
# vivo : vivo
# bapakku : bapak
# woi : woi
# medan : medan
# belawan : belawan
# ilang : ilang
# ngak : ngak
# nelpon : nelpon
# sms : sms
# gimana : gimana
# solusinya : solusi
# wak : wak
# hadeh : hadeh
# perbaiki : baik
# edge : edge
# ajaa : ajaa
# ngelepas : ngelepas
# nomor : nomor
# dipasaran : pasar
# pastikan : pasti
# fresh : fresh
# hoi : hoi
# nederland : nederland
# spraaken : spraaken
# biaya : biaya
# aktivasi : aktivasi
# plus : plus
# kepotong : potong
# rupiah : rupiah
# memperpanjang : panjang
# ngegame : ngegame
# mendung : mendung
# besok : besok
# burik : burik
# mls : mls
# make : make
# woooy : woooy
# perusahan : usah
# guoblok : guoblok
# lag : lag
# baikin : baikin
# bang : bang
# kayak : kayak
# dihilangkan : hilang
# bosok : bosok
# asuuuu : asuuuu
# bala : bala
# bodoamat : bodoamat
# anjay : anjay
# tersedot : sedot
# buka : buka
# internet : internet
# mark : mark
# maaf : maaf
# ktnya : ktnya
# ribu : ribu
# kabar : kabar
# buruk : buruk
# selepas : lepas
# listrik : listrik
# padam : padam
# provinsi : provinsi
# riau : riau
# kabupaten : kabupaten
# rokanhulu : rokanhulu
# kecamatan : camat
# ujungbatu : ujungbatu
# desa : desa
# pematang : pematang
# tebih : tebih
# tinjau : tinjau
# nanya : nanya
# extra : extra
# unlimited : unlimited
# ngikut : ngikut
# sue : sue
# kanapa : kanapa
# leg : leg
# masak : masak
# seharian : hari
# respon : respon
# sayah : sayah
# peguna : guna
# dlu : dlu
# sampe : sampe
# perkuat : kuat
# kecewa : kecewa
# klu : klu
# kendala : kendala
# beritahukan : beritahukan
# seruruh : seruruh
# indonesia : indonesia
# cek : cek
# codenya : codenya
# mohon : mohon
# akui : aku
# gatel : gatel
# bnget : bnget
# tngan : tngan
# gua : gua
# kasar : kasar
# tkut : tkut
# kena : kena
# pasal : pasal
# koment : koment
# masala : masala
# tanah : tanah
# air : air
# mengalami : alami
# kualitas : kualitas
# jaringannya : jaring
# allah : allah
# pecuma : cuma
# kaya : kaya
# rangkasbitung : rangkasbitung
# lebak : lebak
# banten : banten
# bnarin : bnarin
# njirr : njirr
# tdi : tdi
# tinggal : tinggal
# kota : kota
# kali : kali
# akses : akses
# area : area
# kawedanan : kawedanan
# magetan : magetan
# timur : timur
# dolopo : dolopo
# madiun : madiun
# ngirim : ngirim
# faile : faile
# print : print
# menit : menit
# data : data
# udh : udh
# seminggu : minggu
# masuk : masuk
# pemberitahuan : pemberitahuan
# sukses : sukses
# sueuh : sueuh
# komplen : komplen
# inbox : inbox
# kirim : kirim
# link : link
# klik : klik
# messengger : messengger
# barusan : barusan
# pembayaran : bayar
# ovo : ovo
# saldo : saldo
# terpotong : potong
# jringan : jringan
# tod : tod
# bangkrut : bangkrut
# bilng : bilng
# knpa : knpa
# eror : eror
# tanggal : tanggal
# haduhhh : haduhhh
# malam : malam
# wtf : wtf
# sistem : sistem
# sibuk : sibuk
# mengisi : isi
# voucher : voucher
# alhamdulillah : alhamdulillah
# lagii : lagi
# bismillah : bismillah
# semoga : moga
# staff : staff
# beserta : serta
# boss : boss
# managernya : managernya
# azab : azab
# pedih : pedih
# doa : doa
# anak : anak
# tersakiti : sakit
# nglag : nglag
# ujian : uji
# dikabulkan : kabul
# aamiin : aamiin
# wkwkwk : wkwkwk
# salam : salam
# hangat : hangat
# mnyusut : mnyusut
# persen : persen
# mnurt : mnurt
# temen : temen
# jringannya : jringannya
# jdi : jdi
# whats : whats
# wrong : wrong
# lokal : lokal
# sisa : sisa
# gb : gb
# browsing : browsing
# mending : mending
# beralih : alih
# internetnya : internetnya
# kntol : kntol
# kntolnya : kntolnya
# ditempat : tempat
# lost : lost
# signal : signal
# mas : mas
# mbak : mbak
# tolonglah : tolong
# fokus : fokus
# bos : bos
# adek : adek
# nangis : nang
# nggk : nggk
# nonton : nonton
# youtube : youtube
# hallo : hallo
# mnggu : mnggu
# koq : koq
# dimasukkan : masuk
# solusi : solusi
# aktifkn : aktifkn
# sayang : sayang
# duit : duit
# bsa : bsa
# kepake : kepake
# terhalang : halang
# membagikan : bagi
# merata : rata
# milih : milih
# device : device
# dahlah : dah
# males : males
# aktifkan : aktif
# memotong : potong
# ceueu : ceueu
# ganguan : ganguan
# terbaru : baru
# tingkatkan : tingkat
# keburukannya : keburu
# ayolah : ayo
# mint : mint
# sultan : sultan
# gacha : gacha
# hadehh : hadehh
# benerinnya : benerinnya
# gmn : gmn
# ngab : ngab
# info : info
# multimedia : multimedia
# vote : vote
# gunanya : guna
# ngasih : ngasih
# knp : knp
# pelit : pelit
# th : th
# lancar : lancar
# jaya : jaya
# bosque : bosque
# pembodohan : bodoh
# gamesmax : gamesmax
# gabisa : gabisa
# dibatas : batas
# woyy : woyy
# sampah : sampah
# taik : taik
# veronika : veronika
# sialan : sial
# rusak : rusak
# hpku : hpku
# emang : emang
# sch : sch
# slur : slur
# mimin : mimin
# nunggu : nunggu
# jam : jam
# datanya : data
# tel : tel
# komsel : komsel
# kuisi : kuis
# slalu : slalu
# tanpak : tanpak
# kuaktif : aktif
# seluler : seluler
# coba : coba
# ancur : ancur
# gasofun : gasofun
# bobrok : bobrok
# lop : lop
# tlkom : tlkom
# sosmed : sosmed
# gbs : gbs
# whatsap : whatsap
# mentallllll : mentallllll
# aduhai : aduhai
# masya : masya
# dukung : dukung
# tipu : tipu
# telkomtol : telkomtol
# turunkan : turun
# hujan : hujan
# elo : elo
# gamau : gamau
# mentok : mentok
# halo : halo
# admin : admin
# provider : provider
# terbaik : baik
# kritik : kritik
# saran : saran
# diperhatikan : perhati
# yaa : yaa
# cmn : cmn
# apapun : apa
# berlanggana : berlanggana
# kerja : kerja
# begadangnya : begadang
# sekian : sekian
# mendadak : dadak
# begadang : begadang
# mengaktifkan : aktif
# selulir : selulir
# diatas : atas
# rela : rela
# diambil : ambil
# kesalahan : salah
# selangit : langit
# bermutu : mutu
# selebihnya : lebih
# benarnya : benar
# net : net
# konflik : konflik
# jump : jump
# ping : ping
# loading : loading
# ngeluh : ngeluh
# suruh : suruh
# ngomong : ngomong
# ama : ama
# batu : batu
# gda : gda
# jalan : jalan
# medsos : medsos
# blsin : blsin
# setabil : setabil
# kadang : kadang
# ngilang : ngilang
# hadiah : hadiah
# apresiasi : apresiasi
# setia : setia
# undi : undi
# kuis : kuis
# peeusahan : peeusahan
# gede : gede
# bumn : bumn
# jaeingan : jaeingan
# swasta : swasta
# gila : gila
# ngadain : ngadain
# acara : acara
# ngesultan : ngesultan
# ehh : ehh
# jaringann : jaringann
# miskin : miskin
# banyakan : banyak
# jaringanya : jaringanya
# truss : truss
# dighosting : dighosting
# cewe : cewe
# nge : nge
# ghosting : ghosting
# nasib : nasib
# ditingalin : ditingalin
# truuss : truuss
# ampe : ampe
# hape : hape
# ikutan : ikut
# notifikasi : notifikasi
# berkurang : kurang
# kuotanya : kuota
# favorite : favorite
# song : song
# female : female
# singer : singer
# male : male
# group : group
# neeee : neeee
# kelakuan : laku
# prov : prov
# lampung : lampung
# aduuh : aduuh
# huhu : huhu
# ramaikan : ramai
# alah : alah
# bacot : bacot
# jaringanmu : jaring
# bat : bat
# mals : mals
# gitu : gitu
# mhal : mhal
# bantuanny : bantuanny
# tenggang : tenggang
# sdah : sdah
# batas : batas
# juni : juni
# counter : counter
# pengiriman : kirim
# gagal : gagal
# kalah : kalah
# bocil : bocil
# tindak : tindak
# crosscheck : crosscheck
# jelekmu : jelek
# kau : kau
# penyedia : sedia
# layanan : layan
# bulanan : bulan
# speednya : speednya
# mbps : mbps
# sangan : sangan
# jariangan : jariangan
# kemajuan : maju
# kemunduran : mundur
# bagusin : bagusin
# pekanbaru : pekanbaru
# sore : sore
# berhenti : henti
# ngajuin : ngajuin
# pertayaan : pertayaan
# padhal : padhal
# meber : meber
# platinum : platinum
# kecwa : kecwa
# bbi : bbi
# turunin : turunin
# harganya : harga
# perhatikan : perhati
# setan : setan
# terimakasih : terimakasih
# tulus : tulus
# ucapkan : ucap
# hatiku : hati
# smua : smua
# kebaikan : baik
# bocah : bocah
# skrg : skrg
# dipakai : pakai
# kaum : kaum
# milenial : milenial
# tua : tua
# perbaikin : perbaikin
# turnamen : turnamen
# tsel : tsel
# makasih : makasih
# defeat : defeat
# sekejap : kejap
# pengen : ken
# robohin : robohin
# sutet : sutet
# berguna : guna
# hadeeeh : hadeeeh
# atasi : atas
# tegal : tegal
# tlg : tlg
# pelayanannya : layan
# iya : iya
# tpi : tpi
# support : support
# sistemnya : sistem
# sesuai : sesuai
# blank : blank
# gtu : gtu
# signalnya : signalnya
# natuna : natuna
# kepulauan : pulau
# trimakasih : trimakasih
# giliran : gilir
# gada : gada
# the : the
# bone : bone
# cpk : cpk
# sumpah : sumpah
# sampaaaahhhhh : sampaaaahhhhh
# kompany : kompany
# terburuk : buruk
# seindonesia : indonesia
# pantesen : pantesen
# telkontol : telkontol
# bencana : bencana
# kompanynya : kompanynya
# gal : gal
# tanggung : tanggung
# bye : bye
# home : home
# back : back
# american : american
# kmaren : kmaren
# sengaja : sengaja
# simcard : simcard
# operator : operator
# serba : serba
# teernyata : teernyata
# sedih : sedih
# asembagus : asembagus
# diblokir : blokir
# diaktifkan : aktif
# ngeleg : ngeleg
# ngntl : ngntl
# kurangi : kurang
# kecepatan : cepat
# tae : tae
# doang : doang
# eek : eek
# mlu : mlu
# kebagian : bagi
# menunggu : tunggu
# telkomsol : telkomsol
# mengayal : ayal
# kuotany : kuotany
# kec : kec
# galela : galela
# selatan : selatan
# ori : ori
# tower : tower
# batam : batam
# mengeluh : keluh
# perihal : perihal
# down : down
# kondisikan : kondisi
# opsi : opsi
# menstabilkan : stabil
# trun : trun
# off : off
# and : and
# lgi : lgi
# lanjuti : lanjut
# wii : wii
# worth : worth
# manusia : manusia
# hajar : hajar
# normal : normal
# sok : sok
# hancur : hancur
# babuk : babuk
# owalah : owalah
# paketane : paketane
# hargane : hargane
# jaringane : jaringane
# burikkk : burikkk
# percaya : percaya
# berkhianat : khianat
# permintaan : minta
# proses : proses
# blm : blm
# kebeli : kebel
# paketanya : paketanya
# nias : nias
# bermsalah : bermsalah
# dri : dri
# pgii : pgii
# niat : niat
# kouota : kouota
# wkwkw : wkwkw
# rip : rip
# kesedot : sedot
# mulu : mulu
# berharap : harap
# dpt : dpt
# disana : sana
# dipecat : pecat
# komisaris : komisaris
# level : level
# komplain : komplain
# inte : inte
# cacad : cacad
# paraaaaaaah : paraaaaaaah
# sring : sring
# muantab : muantab
# daftar : daftar
# penerima : terima
# hadiahx : hadiahx
# selamat : selamat
# tukarkan : tukar
# poin : poin
# kualitasnya : kualitas
# karawang : karawang
# apkh : apkh
# perpanjang : panjang
# gembel : gembel
# najis : najis
# bangt : bangt
# tempatku : tempat
# taiiiii : taiiiii
# providermu : providermu
# cuih : cuih
# kesini : kesini
# terima : terima
# nihh : nihh
# simpati : simpati
# takut : takut
# hangus : hangus
# kelupaan : lupa
# pemakaian : pakai
# ribuan : ribu
# kotaku : kota
# gilasih : gilasih
# asli : asli
# cuman : cuman
# payah : payah
# suka : suka
# drop : drop
# nyaman : nyaman
# jarigan : jarigan
# jaring : jaring
# sia : sia
# minnn : minnn
# program : program
# undian : undi
# semudah : mudah
# dirubah : rubah
# rubah : rubah
# jadual : jadual
# hadeuhhh : hadeuhhh
# berasa : asa
# ceria : ceria
# smsnya : smsnya
# dibeli : beli
# kabur : kabur
# telkomnyet : telkomnyet
# suprise : suprise
# deal : deal
# ketengan : keteng
# stabil : stabil
# wooyyy : wooyyy
# woyyy : woyyy
# jakarta : jakarta
# serasa : serasa
# pelosok : pelosok
# anjeng : anjeng
# maen : maen
# merah : merah
# jaringannnyaa : jaringannnyaa
# payahhhhh : payahhhhh
# {'membeli': 'beli', 'paket': 'paket', 'lgsng': 'lgsng', 'jln': 'jln', 'internetny': 'internetny', 'sblm': 'sblm', 'ngisi': 'ngisi', 'lwt': 'lwt', 'telkomsel': 'telkomsel', '': '', 'maketin': 'maketin', 'kouta': 'kouta', 'blajar': 'blajar', 'aktif': 'aktif', 'pulsa': 'pulsa', 'ambil': 'ambil', 'gmana': 'gmana', 'aduh': 'aduh', 'aktifnya': 'aktif', 'kemarin': 'kemarin', 'trus': 'trus', 'isi': 'isi', 'tgl': 'tgl', 'hrusnya': 'hrusnya', 'sebulan': 'bulan', 'benerin': 'benerin', 'jaringan': 'jaring', 'promo': 'promo', 'iklan': 'iklan', 'sinyal': 'sinyal', 'kuat': 'kuat', 'bagus': 'bagus', 'bufering': 'bufering', 'kipak': 'kipak', 'parah': 'parah', 'pembohongan': 'bohong', 'publik': 'publik', 'namanya': 'nama', 'beli': 'beli', 'loyo': 'loyo', 'gmna': 'gmna', 'kak': 'kak', 'reedem': 'reedem', 'lupa': 'lupa', 'gbsa': 'gbsa', 'min': 'min', 'unlimitednya': 'unlimitednya', 'dikembalikan': 'kembali', 'paketnya': 'paket', 'ngapain': 'ngapain', 'darurat': 'darurat', 'gue': 'gue', 'pakai': 'pakai', 'pulak': 'pulak', 'ekstra': 'ekstra', 'aktifin': 'aktifin', 'tagihan': 'tagih', 'doble': 'doble', 'bill': 'bill', 'rb': 'rb', 'panas': 'panas', 'batere': 'batere', 'cepet': 'cepet', 'habis': 'habis', 'dipake': 'dipake', 'jngn': 'jngn', 'lalaikan': 'lalai', 'donk': 'donk', 'keamanan': 'aman', 'kenyamananx': 'kenyamananx', 'pelanggan': 'langgan', 'berselancar': 'selancar', 'menikmati': 'nikmat', 'pelayananx': 'pelayananx', 'bnr': 'bnr', 'faedah': 'faedah', 'konten': 'konten', 'tolong': 'tolong', 'diperbaiki': 'baik', 'upgrade': 'upgrade', 'daerah': 'daerah', 'kab': 'kab', 'bekasi': 'bekas', 'cikarang': 'cikarang', 'utara': 'utara', 'bantu': 'bantu', 'nama': 'nama', 'udah': 'udah', 'terkenal': 'kenal', 'mahal': 'mahal', 'pas': 'pas', 'masukin': 'masukin', 'kode': 'kode', 'vouchr': 'vouchr', 'gini': 'gin', 'trs': 'trs', 'kodenya': 'kode', 'bener': 'bener', 'giga': 'giga', 'rp': 'rp', 'sugan': 'sugan', 'rek': 'rek', 'turun': 'turun', 'harga': 'harga', 'kuota': 'kuota', 'kalahkah': 'kalah', 'ttp': 'ttp', 'php': 'php', 'elite': 'elite', 'mode': 'mode', 'tertawa': 'tertawa', 'jelek': 'jelek', 'in': 'in', 'senang': 'senang', 'kartu': 'kartu', 'karna': 'karna', 'murah': 'murah', 'geratis': 'gerat', 'drefresh': 'drefresh', 'pesawat': 'pesawat', 'sinyalnya': 'sinyal', 'bejat': 'bejat', 'keluhan': 'keluh', 'lempar': 'lempar', 'orang': 'orang', 'makan': 'makan', 'gaji': 'gaji', 'buta': 'buta', 'ente': 'ente', 'ngaku': 'ngaku', 'paketan': 'paket', 'pemenang': 'menang', 'voting': 'voting', 'awards': 'awards', 'kesel': 'kesel', 'mb': 'mb', 'kcepatan': 'kcepatan', 'inet': 'inet', 'kb': 'kb', 'hrga': 'hrga', 'naikin': 'naikin', 'mlah': 'mlah', 'ancoor': 'ancoor', 'lemot': 'lot', 'cileungsi': 'cileungsi', 'bogor': 'bogor', 'malem': 'malem', 'minggu': 'minggu', 'event': 'event', 'main': 'main', 'game': 'game', 'nggak': 'nggak', 'sya': 'sya', 'susah': 'susah', 'banget': 'banget', 'singal': 'singal', 'ntah': 'ntah', 'award': 'award', 'ultah': 'ultah', 'tetep': 'tetep', 'soak': 'soak', 'keknya': 'kek', 'gebrakan': 'gebrak', 'setianya': 'setia', 'kesekian': 'sekian', 'kalinya': 'kali', 'emosi': 'emosi', 'gara': 'gara', 'kek': 'kek', 'keong': 'keong', 'woy': 'woy', 'koneksi': 'koneksi', 'komen': 'komen', 'bales': 'bales', 'bot': 'bot', 'telkmsel': 'telkmsel', 'ngga': 'ngga', 'ngetik': 'ngetik', 'toba': 'toba', 'quota': 'quota', 'aktip': 'aktip', 'kenap': 'kenap', 'woii': 'woii', 'gangguan': 'ganggu', 'kah': 'kah', 'kemana': 'mana', 'tibatiba': 'tibatiba', 'hilang': 'hilang', 'telkom': 'telkom', 'daruratny': 'daruratny', 'unlimax': 'unlimax', 'jan': 'jan', 'kasih': 'kasih', 'fup': 'fup', 'pengguna': 'guna', 'android': 'android', 'update': 'update', 'aplikasi': 'aplikasi', 'kompatibel': 'kompatibel', 'pindah': 'pindah', 'lite': 'lite', 'ganti': 'ganti', 'contohnya': 'contoh', 'vivo': 'vivo', 'bapakku': 'bapak', 'woi': 'woi', 'medan': 'medan', 'belawan': 'belawan', 'ilang': 'ilang', 'ngak': 'ngak', 'nelpon': 'nelpon', 'sms': 'sms', 'gimana': 'gimana', 'solusinya': 'solusi', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/239 [00:00<?, ?it/s]
#                                                comment  \
# 0    kenapa setelah saya membeli paket di *363# lgs...
# 1    maketin kouta blajar ga aktif aktif mana pulsa...
# 2    masa aktifnya kemarin 16-06-21 trus gw isi pul...
# 3    benerin jaringan lu, promo sana sini di iklan ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy... di jakarta se...
# 238                           kartu mahal,sinyal jelek
# 239                                         @telkomsel
# 240                          murah in paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                       cleaning_comment  \
# 0    kenapa setelah saya membeli paket   lgsng jln ...
# 1    maketin kouta blajar aktif aktif mana pulsa da...
# 2    masa aktifnya kemarin trus isi pulsa malah akt...
# 3    benerin jaringan promo sana sini iklan sinyal ...
# 4                        telkomsel beli paket kok lama
# ..                                                 ...
# 237  wooyyy jaringan benerin woyyy jakarta serasa p...
# 238                           kartu mahal sinyal jelek
# 239
# 240                             murah paket gua anjeng
# 241  woi parah maen game merah terus jaringannnyaa ...
#
#                                             tokenisasi  \
# 0    [kenapa, setelah, saya, membeli, paket, lgsng,...
# 1    [maketin, kouta, blajar, aktif, aktif, mana, p...
# 2    [masa, aktifnya, kemarin, trus, isi, pulsa, ma...
# 3    [benerin, jaringan, promo, sana, sini, iklan, ...
# 4                  [telkomsel, beli, paket, kok, lama]
# ..                                                 ...
# 237  [wooyyy, jaringan, benerin, woyyy, jakarta, se...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, terus, jaringa...
#
#                                               stopword  \
# 0    [membeli, paket, lgsng, jln, internetny, sblm,...
# 1    [maketin, kouta, blajar, aktif, aktif, pulsa, ...
# 2    [aktifnya, kemarin, trus, isi, pulsa, aktif, t...
# 3    [benerin, jaringan, promo, iklan, sinyal, kuat...
# 4                             [telkomsel, beli, paket]
# ..                                                 ...
# 237  [wooyyy, jaringan, benerin, woyyy, jakarta, se...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, jaringannnyaa,...
#
#                                               stemming
# 0    [beli, paket, lgsng, jln, internetny, sblm, sb...
# 1    [maketin, kouta, blajar, aktif, aktif, pulsa, ...
# 2    [aktif, kemarin, trus, isi, pulsa, aktif, tgl,...
# 3    [benerin, jaring, promo, iklan, sinyal, kuat, ...
# 4                             [telkomsel, beli, paket]
# ..                                                 ...
# 237  [wooyyy, jaring, benerin, woyyy, jakarta, sera...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, jaringannnyaa,...
#
# [239 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [beli, paket, lgsng, jln, internetny, sblm, sb...
# 1    [maketin, kouta, blajar, aktif, aktif, pulsa, ...
# 2    [aktif, kemarin, trus, isi, pulsa, aktif, tgl,...
# 3    [benerin, jaring, promo, iklan, sinyal, kuat, ...
# 4                             [telkomsel, beli, paket]
# ..                                                 ...
# 237  [wooyyy, jaring, benerin, woyyy, jakarta, sera...
# 238                      [kartu, mahal, sinyal, jelek]
# 239                                                 []
# 240                        [murah, paket, gua, anjeng]
# 241  [woi, parah, maen, game, merah, jaringannnyaa,...
#
# [239 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_telkomsel_6.xlsx')
