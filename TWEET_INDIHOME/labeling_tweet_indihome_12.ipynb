# %%
import pandas as pd
from textblob import TextBlob

# %%
columns = ["tweet_english"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data bersih_translate tweet indihome\databersih_english_tweet_indihome_12.xlsx', usecols=columns)
df['label_awal'] = ''
for i,x in df.tweet_english.iteritems():
    label_awal = TextBlob(x)
    df['label_awal'][i] = label_awal.sentiment.polarity
    print("Index: ", i ,  "label_awal" , label_awal.sentiment.polarity)
# Out:
# Index:  0 label_awal 0.25
# Index:  1 label_awal -0.275
# Index:  2 label_awal 0.175
# Index:  3 label_awal 0.5
# Index:  4 label_awal 0.0
# Index:  5 label_awal 0.0
# Index:  6 label_awal 0.0
# Index:  7 label_awal 0.0
# Index:  8 label_awal 0.0
# Index:  9 label_awal 0.5
# Index:  10 label_awal 0.3770833333333333
# Index:  11 label_awal 0.0
# Index:  12 label_awal -0.6999999999999998
# Index:  13 label_awal 0.0
# Index:  14 label_awal 0.0
# Index:  15 label_awal 0.0
# Index:  16 label_awal 0.0
# Index:  17 label_awal 0.16666666666666666
# Index:  18 label_awal 0.8
# Index:  19 label_awal 0.18333333333333335
# Index:  20 label_awal 0.6199999999999999
# Index:  21 label_awal 0.13636363636363635
# Index:  22 label_awal 0.0
# Index:  23 label_awal 0.0875
# Index:  24 label_awal 0.39999999999999997
# Index:  25 label_awal 0.0
# Index:  26 label_awal 0.21428571428571427
# Index:  27 label_awal 0.21428571428571427
# Index:  28 label_awal 0.0
# Index:  29 label_awal 0.0
# ...

# %%
df.head()
# Out:
#                                        tweet_english label_awal
# 0  ['cloud', 'storage', 'save', 'file', 'digital'...       0.25
# 1  ['lawak', 'indihome', 'report', 'discribed', '...     -0.275
# 2  ['activity', 'ditemenin', 'net', 'cool', 'indi...      0.175
# 3  ['voyeur', 'detail', 'aspect', 'modification',...        0.5
# 4              ['woahh', 'indihome', 'gift', 'nihh']        0.0

# %%
df['label_awal'].value_counts()
# Out:
#  0.000000    571
#  0.500000     35
#  0.400000     24
#  0.200000     22
# -0.500000     17
#             ...
#  0.466667      1
# -0.275000      1
#  0.368182      1
#  0.088889      1
#  0.090476      1
# Name: label_awal, Length: 129, dtype: int64

# %%
label = []
for index, row in df.iterrows():
    if row['label_awal'] > 0.0:
        label.append("positive")
    else:
        label.append("negative")
df["label"] = label
df = df.drop(columns=['label_awal'])
df.head(2000)
# Out:
#                                          tweet_english     label
# 0    ['cloud', 'storage', 'save', 'file', 'digital'...  positive
# 1    ['lawak', 'indihome', 'report', 'discribed', '...  negative
# 2    ['activity', 'ditemenin', 'net', 'cool', 'indi...  positive
# 3    ['voyeur', 'detail', 'aspect', 'modification',...  positive
# 4                ['woahh', 'indihome', 'gift', 'nihh']  negative
# ..                                                 ...       ...
# 945  ['hello', 'process', 'installation', 'install'...  negative
# 946           ['leek', 'matiin', 'nya', 'yeaaayy', '']  negative
# 947  ['wifi', 'dead', 'yesterday', 'telephone', 're...  negative
# 948                ['people', 'kayak', 'indihome', '']  negative
# 949         ['finally', 'disconnected', 'yeaaayy', '']  negative
#
# [950 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# negative    685
# positive    265
# Name: label, dtype: int64

# %%
df.to_excel('labeling_databersih_tweet_indihome_12.xlsx')
