# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @riyaprmtsr Hai Kak Riya, selamat datang di ak...
# 1     @IndiHome Kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 Halo Kak Zaidan. Terkait akses inter...
# 3     Udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @Yosah22 ibantu langsung. Kakak juga dapat mel...
# 1996  @Yosah22 Halo, Kak Yosah. Perihal pemasangan b...
# 1997  @IndiHome halo kak. Internet mati, sepertinya ...
# 1998             @IndiHome @IndiHomeCare Udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
# [2000 rows x 1 columns]

# %%
print('Dataset size:', df.shape)
print('Columns are:', df.columns)
# Out:
# Dataset size: (2000, 1)
# Columns are: Index(['content'], dtype='object')

# %%
df.content.duplicated().sum()
# Out:
# 22

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @riyaprmtsr Hai Kak Riya, selamat datang di ak...
# 1     @IndiHome Kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 Halo Kak Zaidan. Terkait akses inter...
# 3     Udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @Yosah22 ibantu langsung. Kakak juga dapat mel...
# 1996  @Yosah22 Halo, Kak Yosah. Perihal pemasangan b...
# 1997  @IndiHome halo kak. Internet mati, sepertinya ...
# 1998             @IndiHome @IndiHomeCare Udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
# [1957 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @riyaprmtsr hai kak riya, selamat datang di ak...
# 1     @indihome kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 halo kak zaidan. terkait akses inter...
# 3     udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @yosah22 ibantu langsung. kakak juga dapat mel...
# 1996  @yosah22 halo, kak yosah. perihal pemasangan b...
# 1997  @indihome halo kak. internet mati, sepertinya ...
# 1998             @indihome @indihomecare udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
# [1957 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @riyaprmtsr hai kak riya, selamat datang di ak...
# 1     @indihome kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 halo kak zaidan. terkait akses inter...
# 3     udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @yosah22 ibantu langsung. kakak juga dapat mel...
# 1996  @yosah22 halo, kak yosah. perihal pemasangan b...
# 1997  @indihome halo kak. internet mati, sepertinya ...
# 1998             @indihome @indihomecare udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
#                                          cleaning_tweet
# 0     hai kak riya selamat datang akun layanan indih...
# 1     kenapa tempat koneksinya selalu tidak stabil s...
# 2     halo kak zaidan terkait akses internet nomor s...
# 3     udah mah indihome juga ngeselin pagi  ini lagi...
# 4                                       indihome sucks
# ...                                                 ...
# 1995  ibantu langsung kakak juga dapat melakukan pen...
# 1996  halo kak yosah perihal pemasangan baru nunik i...
# 1997  halo kak internet mati sepertinya kabel telkom...
# 1998                                           udah tuh
# 1999               hanya anak indihome yang bisa lihat
#
# [1957 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @riyaprmtsr hai kak riya, selamat datang di ak...
# 1     @indihome kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 halo kak zaidan. terkait akses inter...
# 3     udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @yosah22 ibantu langsung. kakak juga dapat mel...
# 1996  @yosah22 halo, kak yosah. perihal pemasangan b...
# 1997  @indihome halo kak. internet mati, sepertinya ...
# 1998             @indihome @indihomecare udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
#                                          cleaning_tweet  \
# 0     hai kak riya selamat datang akun layanan indih...
# 1     kenapa tempat koneksinya selalu tidak stabil s...
# 2     halo kak zaidan terkait akses internet nomor s...
# 3     udah mah indihome juga ngeselin pagi  ini lagi...
# 4                                       indihome sucks
# ...                                                 ...
# 1995  ibantu langsung kakak juga dapat melakukan pen...
# 1996  halo kak yosah perihal pemasangan baru nunik i...
# 1997  halo kak internet mati sepertinya kabel telkom...
# 1998                                           udah tuh
# 1999               hanya anak indihome yang bisa lihat
#
#                                              tokenisasi
# 0     [hai, kak, riya, selamat, datang, akun, layana...
# 1     [kenapa, tempat, koneksinya, selalu, tidak, st...
# 2     [halo, kak, zaidan, terkait, akses, internet, ...
# 3     [udah, mah, indihome, juga, ngeselin, pagi, in...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, juga, dapat, melakuk...
# 1996  [halo, kak, yosah, perihal, pemasangan, baru, ...
# 1997  [halo, kak, internet, mati, sepertinya, kabel,...
# 1998                                        [udah, tuh]
# 1999       [hanya, anak, indihome, yang, bisa, lihat, ]
#
# [1957 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'nya'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(3000)
# Out:
#                                                 content  \
# 0     @riyaprmtsr hai kak riya, selamat datang di ak...
# 1     @indihome kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 halo kak zaidan. terkait akses inter...
# 3     udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @yosah22 ibantu langsung. kakak juga dapat mel...
# 1996  @yosah22 halo, kak yosah. perihal pemasangan b...
# 1997  @indihome halo kak. internet mati, sepertinya ...
# 1998             @indihome @indihomecare udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
#                                          cleaning_tweet  \
# 0     hai kak riya selamat datang akun layanan indih...
# 1     kenapa tempat koneksinya selalu tidak stabil s...
# 2     halo kak zaidan terkait akses internet nomor s...
# 3     udah mah indihome juga ngeselin pagi  ini lagi...
# 4                                       indihome sucks
# ...                                                 ...
# 1995  ibantu langsung kakak juga dapat melakukan pen...
# 1996  halo kak yosah perihal pemasangan baru nunik i...
# 1997  halo kak internet mati sepertinya kabel telkom...
# 1998                                           udah tuh
# 1999               hanya anak indihome yang bisa lihat
#
#                                              tokenisasi  \
# 0     [hai, kak, riya, selamat, datang, akun, layana...
# 1     [kenapa, tempat, koneksinya, selalu, tidak, st...
# 2     [halo, kak, zaidan, terkait, akses, internet, ...
# 3     [udah, mah, indihome, juga, ngeselin, pagi, in...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, juga, dapat, melakuk...
# 1996  [halo, kak, yosah, perihal, pemasangan, baru, ...
# 1997  [halo, kak, internet, mati, sepertinya, kabel,...
# 1998                                        [udah, tuh]
# 1999       [hanya, anak, indihome, yang, bisa, lihat, ]
#
#                                                stopword
# 0     [hai, kak, riya, selamat, akun, layanan, indih...
# 1         [koneksinya, stabil, putus, cipayung, jaktim]
# 2     [halo, kak, zaidan, terkait, akses, internet, ...
# 3     [udah, mah, indihome, ngeselin, pagi, duit, gu...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, pengecekkan, keterse...
# 1996  [halo, kak, yosah, perihal, pemasangan, nunik,...
# 1997  [halo, kak, internet, mati, kabel, telkom, rum...
# 1998                                             [udah]
# 1999                          [anak, indihome, lihat, ]
#
# [1957 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3762
# ------------------------
# hai : hai
# kak : kak
# riya : riya
# selamat : selamat
# akun : akun
# layanan : layan
# indihome : indihome
# care : care
# wina : wina
# cek : cek
# jaringannya : jaring
# offline : offline
# perangkat : perangkat
# catuan : catu
# listrik : listrik
# pastikan : pasti
# perangkatnya : perangkat
# menyala : nyala
#  :
# koneksinya : koneksi
# stabil : stabil
# putus : putus
# cipayung : cipayung
# jaktim : jaktim
# halo : halo
# zaidan : zaidan
# terkait : kait
# akses : akses
# internet : internet
# nomor : nomor
# dibantu : bantu
# refresh : refresh
# sistem : sistem
# berkenan : kenan
# menunggu : tunggu
# menit : menit
# coba : coba
# hubungi : hubung
# twitter : twitter
# terima : terima
# kasih : kasih
# agit : agit
# udah : udah
# mah : mah
# ngeselin : ngeselin
# pagi : pagi
# duit : duit
# gue : gue
# nyangkut : nyangkut
# ntah : ntah
# dimana : mana
# masuk : masuk
# dana : dana
# sucks : sucks
# diadukan : adu
# via : via
# aplikasi : aplikasi
# open : open
# jasa : jasa
# tugas : tugas
# kaka : kaka
# plagiasi : plagiasi
# ketik : ketik
# tulis : tulis
# tangan : tangan
# daftar : daftar
# isi : isi
# halaman : halaman
# puisi : puisi
# cerpen : cerpen
# olah : olah
# data : data
# bab : bab
# paper : paper
# makalah : makalah
# uas : uas
# review : review
# jurnal : jurnal
# skripsi : skripsi
# seni : seni
# butuh : butuh
# bantuan : bantu
# seminggu : minggu
# lemot : lot
# ampe : ampe
# baca : baca
# komik : komik
# loadingnya : loadingnya
# bener : bener
# chapter : chapter
# goks : goks
# lemotnya : lot
# haloo : haloo
# los : los
# merah : merah
# diperbaiki : baik
# telpon : telpon
# mati : mati
# jam : jam
# feb : feb
# detail : detail
# kirim : kirim
# berhenti : henti
# berlangganan : langgan
# add : add
# movin : movin
# seamless : seamless
# oke : oke
# ijal : ijal
# kakak : kakak
# mona : mona
# bantu : bantu
# mohon : mohon
# ditunggu : tunggu
# kedepan : depan
# dikoneksikan : koneksi
# angga : angga
# direspon : direspon
# interaksi : interaksi
# iyo : iyo
# soale : soale
# outdihome : outdihome
# tower : tower
# uwong : uwong
# restart : restart
# push : push
# rank : rank
# lagiih : lagiih
# tuhkan : tuhkan
# tdi : tdi
# lose : lose
# streak : streak
# ihh : ihh
# mniii : mniii
# gmna : gmna
# atuh : atuh
# min : min
# sobat : sobat
# maaf : maaf
# nyaman : nyaman
# informasikan : informasi
# silakan : sila
# dicek : cek
# ade : ade
# elanjutnya : elanjutnya
# permintaannya : minta
# indihomecare : indihomecare
# nama : nama
# tagihan : tagih
# pembayaran : bayar
# password : password
# barunya : baru
# konfirmasi : konfirmasi
# telp : telp
# direct : direct
# message : message
# tolong : tolong
# ditangani : tangan
# thanks : thanks
# fitri : fitri
# kendalanya : kendala
# lokasinya : lokasi
# pemeliharaan : pelihara
# jaringan : jaring
# petugas : tugas
# lokasi : lokasi
# pemulihan : pulih
# informasi : informasi
# ganti : ganti
# wifi : wifi
# gimana : gimana
# fauzan : fauzan
# aktif : aktif
# pengecekan : kece
# konyol : konyol
# masi : mas
# buffering : buffering
# gajelas : gajelas
# banget : banget
# rumah : rumah
# lampunya : lampu
# nyala : nyala
# cepaaaaaat : cepaaaaaat
# aktifnya : aktif
# tindaklanjuti : tindaklanjuti
# alya : alya
# ifi : ifi
# maksimal : maksimal
# rekan : rekan
# senja : senja
# respons : respons
# portnya : portnya
# cabut : cabut
# colok : colok
# tetep : tetep
# kaya : kaya
# gini : gin
# solusinya : solusi
# besok : besok
# adek : adek
# ujian : uji
# fauziah : fauziah
# iya : iya
# kena : kena
# speed : speed
# limit : limit
# tekan : tekan
# afuk : afuk
# tenan : tenan
# cen : cen
# kang : kang
# beneran : beneran
# lho : lho
# update : update
# app : app
# galaxy : galaxy
# store : store
# vpn : vpn
# luambat : luambat
# ampun : ampun
# vpnin : vpnin
# misale : misale
# make : make
# cloudflare : cloudflare
# langsung : langsung
# ngebut : ngebut
# gangguan : ganggu
# seenggaknya : enggak
# poinnya : poin
# dimanfaatin : dimanfaatin
# gratisan : gratis
# lounge : lounge
# bandara : bandara
# agustina : agustina
# langkah : langkah
# kabel : kabel
# patch : patch
# cord : cord
# modem : modem
# terpasang : pasang
# kencang : kencang
# berwarna : warna
# hitam : hitam
# kuning : kuning
# ujung : ujung
# biru : biru
# menghubungi : hubung
# pas : pas
# postingan : postingan
# tweet : tweet
# nomer : nomer
# resminya : resmi
# deh : deh
# ngerasa : ngerasa
# aman : aman
# indikator : indikator
# pon : pon
# area : area
# banyuanyar : banyuanyar
# solo : solo
# gngguan : gngguan
# trimakasih : trimakasih
# udahan : udahan
# oxygen : oxygen
# enak : enak
# adinia : adinia
# dirasa : rasa
# mengalami : alami
# kondisi : kondisi
# dialami : alami
# sebelumya : sebelumya
# silahkan : silah
# menjaga : jaga
# kerahaiaan : kerahaiaan
# anto : anto
# makasih : makasih
# pastinya : pasti
# bingung : bingung
# guys : guys
# publikasikan : publikasi
# kayak : kayak
# perempuan : perempuan
# sampe : sampe
# kubanting : banting
# ont : ont
# yahh : yahh
# wkwkwkwkwk : wkwkwkwkwk
# gua : gua
# dicijantung : dicijantung
# down : down
# disukat : sukat
# kayaknya : kayak
# daerah : daerah
# noted : noted
# mention : mention
# mengaku : aku
# ngaku : ngaku
# resmi : resmi
# simpan : simpan
# bertanggung : tanggung
# afru : afru
# koneksi : koneksi
# patchcord : patchcord
# felas : felas
# infokan : info
# parah : parah
# bali : bal
# fiber : fiber
# teknisi : teknisi
# smp : smp
# minggu : minggu
# jelek : jelek
# penanganannya : tangan
# pandemik : pandemik
# orang : orang
# wfh : wfh
# asli : asli
# gajih : gajih
# buta : buta
# pindah : pindah
# kynya : kynya
# nyesel : nyesel
# balifiber : balifiber
# sumpah : sumpah
# kontol : kontol
# malam : malam
# sinyal : sinyal
# hujan : hujan
# padahl : padahl
# prkrjaan : prkrjaan
# proyek : proyek
# singkron : singkron
# tiori : tiori
# praktek : praktek
# praktik : praktik
# dlapangan : dlapangan
# kgk : kgk
# stlh : stlh
# barulah : baru
# diexsekusi : diexsekusi
# sesuai : sesuai
# rencana : rencana
# plan : plan
# paket : paket
# promo : promo
# pendaftaran : daftar
# tangerang : tangerang
# tangsel : tangsel
# tgrang : tgrang
# kantor : kantor
# deket : deket
# tukang : tukang
# air : air
# taunya : tau
# provider : provider
# informasinya : informasi
# bagus : bagus
# bangett : bangett
# progressnya : progressnya
# rady : rady
# sarankan : saran
# menghapus : hapus
# pribadi : pribadi
# seto : seto
# akhiran : akhir
# dilokasi : lokasi
# upayakan : upaya
# secepatnya : cepat
# solve : solve
# lancar : lancar
# ketersediaan : sedia
# cbn : cbn
# mem : mem
# blok : blok
# server : server
# game : game
# online : online
# fightcade : fightcade
# temen : temen
# konek : konek
# layar : layar
# item : item
# melulu : melulu
# nongol : nongol
# aneh : aneh
# telkom : telkom
# gitu : gitu
# mamin : mamin
# thx : thx
# igha : igha
# estimasinya : estimasi
# khawatir : khawatir
# penanganan : tangan
# tim : tim
# info : info
# kah : kah
# difumah : difumah
# istg : istg
# estimasi : estimasi
# setor : setor
# file : file
# kerjaan : kerja
# klien : klien
# yuk : yuk
# wilayah : wilayah
# progress : progress
# normal : normal
# trobel : trobel
# marketing : marketing
# jabodetabek : jabodetabek
# xxxx : xxxx
# capture : capture
# privasi : privasi
# datanya : data
# laporannya : lapor
# perbaikan : baik
# sisi : sisi
# sentral : sentral
# dikonfirmasi : konfirmasi
# dihubungi : hubung
# menikmati : nikmat
# mas : mas
# ttapi : ttapi
# skrg : skrg
# uda : uda
# nggk : nggk
# yaa : yaa
# nnti : nnti
# lag : lag
# komplen : komplen
# love : love
# diliat : liat
# liat : liat
# gaada : gaada
# niat : niat
# berubah : ubah
# konsisten : konsisten
# jeleknya : jelek
# mukan : mu
# menginformasikan : informasi
# inbox : inbox
# ario : ario
# hallo : hallo
# bagas : bagas
# dmnya : dmnya
# mengirimkan : kirim
# digit : digit
# angka : angka
# dite : dite
# save : save
# nomernya : nomernya
# hati : hati
# penipu : tipu
# aduuuuh : aduuuuh
# ajj : ajj
# tgl : tgl
# huuhhhh : huuhhhh
# ahh : ahh
# prodak : prodak
# kpn : kpn
# bersaing : saing
# kyk : kyk
# gnih : gnih
# bagusan : bagus
# rauter : rauter
# mbps : mbps
# udh : udh
# emmmm : emmmm
# bumn : bumn
# hasil : hasil
# tes : tes
# mbti : mbti
# malem : malem
# mulu : mulu
# kemusuhann : kemusuhann
# emang : emang
# penipuan : tipu
# marak : marak
# dilla : dilla
# knp : knp
# kadang : kadang
# trouble : trouble
# dunia : dunia
# teh : teh
# mendekati : dekat
# zaman : zaman
# terminator : terminator
# kecepatan : cepat
# download : download
# kb : kb
# nomornya : nomor
# telepon : telepon
# diabaikan : abai
# mudah : mudah
# membutuhkannya : butuh
# tinggal : tinggal
# kring : kring
# membutuhkan : butuh
# perihal : perihal
# internetnya : internetnya
# balas : balas
# jeri : jeri
# tindaklanjut : tindaklanjut
# progresnya : progres
# rizara : rizara
# nggak : nggak
# yes : yes
# ulah : ulah
# demand : demand
# tayang : tayang
# jumat : jumat
# sabtu : sabtu
# anjg : anjg
# posisi : posisi
# surabaya : surabaya
# barat : barat
# penyebab : sebab
# winz : winz
# respon : respon
# klik : klik
# link : link
# amin : amin
# nihh : nihh
# plm : plm
# paansi : paansi
# anjingg : anjingg
# apip : apip
# registrasi : registrasi
# myindihome : myindihome
# unduh : unduh
# play : play
# gadget : gadget
# kunjungi : kunjung
# website : website
# kenken : kenken
# bice : bice
# infoin : infoin
# beserta : serta
# pemilik : milik
# lakukan : laku
# kick : kick
# pebri : pebri
# sekolah : sekolah
# memasang : pasang
# pedesaan : desa
# verifikasi : verifikasi
# anjing : anjing
# diki : dik
# kenaikan : naik
# biaya : biaya
# perbulannya : bulan
# ppn : ppn
# detailnya : detail
# alamat : alamat
# pemasangan : pasang
# gjd : gjd
# stresss : stresss
# segini : gin
# kmrn : kmrn
# yaallah : yaallah
# cape : cape
# penyakit : sakit
# fakkkk : fakkkk
# tsel : tsel
# gaiso : gaiso
# lp : lp
# takut : takut
# ditag : ditag
# klian : klian
# ngakak : ngakak
# tainya : tainya
# gaketolongan : gaketolongan
# heran : heran
# kendala : kendala
# ditindak : tindak
# lanjuti : lanjut
# menanganinya : tangan
# lelah : lelah
# ttg : ttg
# upgrade : upgrade
# ribu : ribu
# maksudnya : maksud
# gmn : gmn
# read : read
# the : the
# news : news
# come : come
# bro : bro
# ajeng : ajeng
# dito : dito
# very : very
# noice : noice
# phoenix : phoenix
# approved : approved
# infonya : info
# tnya : tnya
# alami : alami
# mengakibatkan : akibat
# diakses : akses
# selanju : selanju
# nek : nek
# udan : udan
# dadi : dadi
# krecek : krecek
# tidur : tidur
# belom : bom
# shift : shift
# inetnya : inetnya
# kumat : kumat
# connect : connect
# disimpen : disimpen
# ketipu : tipu
# mengatas : atas
# namakan : nama
# pls : pls
# konser : konser
# amjinkkkk : amjinkkkk
# abal : abal
# rajin : rajin
# kali : kali
# suka : suka
# males : males
# rawan : rawan
# mengatasnamakan : mengatasnamakan
# waspada : waspada
# trending : trending
# piii : piii
# error : error
# jdi : jdi
# wmwkwk : wmwkwk
# sejam : jam
# minnn : minnn
# manfaat : manfaat
# nyanyi : nyanyi
# temenku : temenku
# marketplace : marketplace
# ohhh : ohhh
# lupa : lupa
# follow : follow
# kordinasi : kordinasi
# baiknya : baik
# susanto : susanto
# yonatan : yonatan
# maintenance : maintenance
# team : team
# mengupayakan : upaya
# sabar : sabar
# gilaaa : gilaaa
# mahal : mahal
# bergunaaaa : bergunaaaa
# eror : eror
# eunike : eunike
# abi : abi
# terkendala : kendala
# frans : frans
# ntar : ntar
# lulus : lulus
# kerja : kerja
# samaaa : samaaa
# punyaku : punya
# sby : sby
# woi : woi
# iyaa : iyaa
# anjirr : anjirr
# sebel : sebel
# fakk : fakk
# abaikan : abai
# dinomor : nomor
# berakhiran : akhir
# prosesnya : proses
# hebattt : hebattt
# memakan : makan
# ryuze : ryuze
# teknis : teknis
# ayunk : ayunk
# crying : crying
# over : over
# duh : duh
# dikamar : kamar
# mandi : mandi
# meningkatkan : tingkat
# antibodi : antibodi
# ambil : ambil
# dirumah : rumah
# cepet : cepet
# pasang : pasang
# baruu : baruu
# senin : senin
# frs : frs
# jirr : jirr
# cekkan : cek
# ditemukan : temu
# kirimkan : kirim
# cuk : cuk
# nelpon : nelpon
# takutnya : takut
# percaya : percaya
# tipu : tipu
# dipikiran : pikir
# seng : seng
# ati : ati
# kcuali : kcuali
# ancen : ancen
# buruk : buruk
# xixi : xixi
# ngejak : ngejak
# gelut : gelut
# tee : tee
# jatim : jatim
# pol : pol
# hartono : hartono
# jawa : jawa
# timur : timur
# novaya : novaya
# laporkan : lapor
# tiket : tiket
# in : in
# hilang : hilang
# pengaduan : adu
# andrew : andrew
# pelaporan : lapor
# kedatangan : datang
# sore : sore
# abdal : abdal
# cudud : cudud
# rezky : rezky
# edwin : edwin
# oiya : oiya
# kesel : kesel
# komplek : komplek
# terlanjur : lanjur
# lamaaa : lamaaa
# wkwkwk : wkwkwk
# tlg : tlg
# knapa : knapa
# hehehe : hehehe
# kemarin : kemarin
# kelar : kelar
# urusan : urus
# nunggu : nunggu
# seputar : putar
# sertakan : serta
# ponsel : ponsel
# maul : maul
# status : status
# ketidaknyamanannya : ketidaknyamanannya
# prioritaskan : prioritas
# progres : progres
# perbaikannya : baik
# abang : abang
# kasi : kasi
# makan : makan
# catat : catat
# mastiin : mastiin
# jancokk : jancokk
# lemote : lemote
# kesini : kesini
# nyebelin : nyebelin
# jir : jir
# bermasalah : masalah
# doang : doang
# chat : chat
# permasalahannya : masalah
# login : login
# zte : zte
# user : user
# name : name
# pasworrdnya : pasworrdnya
# langganan : langgan
# dikasih : kasih
# rizki : rizki
# tersolusikan : solusi
# permana : permana
# saputra : saputra
# ridho : ridho
# layanannya : layan
# konfirmasikan : konfirmasi
# handphone : handphone
# tinkerbell : tinkerbell
# bintang : bintang
# berlaku : laku
# permasalahan : masalah
# buka : buka
# tunggu : tunggu
# asnidar : asnidar
# tindak : tindak
# berkendala : kendala
# kam : kam
# berasa : asa
# kesiksa : siksa
# borosnya : boros
# naudzubillah : naudzubillah
# ohh : ohh
# dirimu : diri
# emosi : emosi
# keberadaanmu : ada
# inj : inj
# njj : njj
# woy : woy
# samain : samain
# nyata : nyata
# permainkann : permainkann
# ehhh : ehhh
# wkkwkw : wkkwkw
# rumahku : rumah
# lemoot : lemoot
# bos : bos
# wes : wes
# menang : menang
# undian : undi
# ujungnya : ujung
# nuna : nuna
# cari : cari
# lumayan : lumayan
# cashback : cashback
# begadang : begadang
# maraton : maraton
# nonton : nonton
# drakor : drakor
# ketar : ketar
# ketir : tir
# macet : macet
# jalan : jalan
# taik : taik
# bayaran : bayar
# telat : telat
# ngurusin : ngurusin
# matik : matik
# elo : elo
# gosah : gosah
# biniknya : bik
# hak : hak
# urusin : urusin
# paham : paham
# gladkiy : gladkiy
# device : device
# terhubung : hubung
# speedtes : speedtes
# menyebalkan : sebal
# menonton : tonton
# drama : drama
# loading : loading
# mood : mood
# tenang : tenang
# ngga : ngga
# ditunda : tunda
# kemusuhan : musuh
# keknya : kek
# del : del
# petunjuk : tunjuk
# bungkusnya : bungkus
# tulisan : tulis
# sakit : sakit
# berlanjut : lanjut
# dukun : dukun
# dokter : dokter
# butut : butut
# kalah : kalah
# main : main
# kartrider : kartrider
# berkali : kali
# anjim : anjim
# bangun : bangun
# dapet : dapet
# payung : payung
# ditebak : tebak
# hayo : hayo
# foto : foto
# penjelasan : jelas
# pledus : pledus
# statement : statement
# kaga : kaga
# keupload : keupload
# seru : seru
# gokil : gokil
# pertandingannya : tanding
# mengeluhkan : keluh
# harap : harap
# fokus : fokus
# ketuker : ketuker
# telponnya : telpon
# laporan : lapor
# blm : blm
# tndak : tndak
# dahla : dahla
# gembel : gembel
# bngt : bngt
# santai : santai
# kalem : kalem
# untung : untung
# kuota : kuota
# allah : allah
# kenceng : kenceng
# aplikasinya : aplikasi
# voucher : voucher
# murah : murah
# dipake : dipake
# wqwqwq : wqwqwq
# terimakasih : terimakasih
# salah : salah
# dirugikan : rugi
# dri : dri
# lapangan : lapang
# tabok : tabok
# monyetttttt : monyetttttt
# haruskah : harus
# free : free
# tag : tag
# wkwkwkwk : wkwkwkwk
# anjer : anjer
# ngapa : ngapa
# kabar : kabar
# ngegame : ngegame
# beli : beli
# printilannya : printilannya
# sinyalnya : sinyal
# mlbb : mlbb
# maapin : maapin
# nub : nub
# krna : krna
# ora : ora
# due : due
# genthong : genthong
# wis : wis
# pean : pean
# galau : galau
# pikirane : pikirane
# hudu : hudu
# indigo : indigo
# hahaha : hahaha
# pelis : pel
# bangbang : bangbang
# leg : leg
# mala : mala
# dibilang : bilang
# tmbh : tmbh
# dibuly : dibuly
# match : match
# njir : njir
# hamdalah : hamdalah
# ditinggal : tinggal
# pstie : pstie
# aveiro : aveiro
# yuda : yuda
# disana : sana
# fup : fup
# pliss : pliss
# knpa : knpa
# naek : naek
# turun : turun
# trus : trus
# bersahabat : sahabat
# sksksksksksk : sksksksksksk
# wkwkk : wkwkk
# tobat : tobat
# yud : yud
# anak : anak
# idn : idn
# yee : yee
# laaahh : laaahh
# mending : mending
# mnc : mnc
# ataoo : ataoo
# myrepublic : myrepublic
# bulannya : bulan
# begituan : begitu
# hubungan : hubung
# tangani : tangan
# gaperlu : gaperlu
# ngeraguin : ngeraguin
# kesabaran : sabar
# keren : keren
# palingan : paling
# pilih : pilih
# mutiara : mutiara
# wujudkan : wujud
# kemudahan : mudah
# hidup : hidup
# admin : admin
# pakai : pakai
# canda : canda
# numpang : numpang
# lapak : lapak
# masker : masker
# duckbill : duckbill
# edisi : edisi
# candy : candy
# pcs : pcs
# shopee : shopee
# emoy : emoy
# pilihan : pilih
# warna : warna
# cocok : cocok
# ootd : ootd
# njutnya : njutnya
# salsabila : salsabila
# kode : kode
# bang : bang
# naikin : naikin
# mbpsnya : mbpsnya
# hasilnya : hasil
# zong : zong
# habis : habis
# memaki : maki
# maki : maki
# have : have
# degradation : degradation
# kink : kink
# what : what
# otw : otw
# stel : stel
# cee : cee
# kevin : kevin
# hiro : hiro
# samanya : sama
# bandwith : bandwith
# lepak : lepak
# lelet : lelet
# mpwr : mpwr
# teees : teees
# gila : gila
# apaa : apaa
# aapaan : aapaan
# candra : candra
# arga : arga
# lambat : lambat
# suhu : suhu
# modemnya : modem
# melewati : lewat
# batas : batas
# dinon : non
# aktifkan : aktif
# suhunya : suhu
# bis : bis
# pantes : pantes
# grey : grey
# ayi : ayi
# amik : amik
# buatkan : buat
# percepatan : cepat
# alifaini : alifaini
# remote : remote
# dicoba : coba
# baterainya : baterai
# tampilan : tampil
# angel : angel
# sajak : sajak
# empire : empire
# wkwkwkwkwkwk : wkwkwkwkwkwk
# tetangga : tetangga
# drun : drun
# sinyalmu : sinyal
# ngapain : ngapain
# siiii : siiii
# brengsekkkk : brengsekkkk
# kampret : kampret
# qing : qing
# cukkkkkkk : cukkkkkkk
# anjinggg : anjinggg
# santay : santay
# gamiskin : gamiskin
# miskin : miskin
# cebongers : cebongers
# mgkn : mgkn
# rada : rada
# berfungsi : fungsi
# kontak : kontak
# jarang : jarang
# sehat : sehat
# arka : arka
# rka : rka
# bentuk : bentuk
# komitmen : komitmen
# pelayan : layan
# terbaik : baik
# hadir : hadir
# rabbun : rabbun
# maren : maren
# good : good
# job : job
# pemakaian : pakai
# diatas : atas
# penggunaan : guna
# wajar : wajar
# keluhannya : keluh
# ketidakstabilan : ketidakstabilan
# disebabkan : sebab
# faktor : faktor
# cuaca : cuaca
# redaman : redam
# trafic : trafic
# melebihi : lebih
# rekomendasi : rekomendasi
# optimum : optimum
# dikarena : karena
# call : call
# center : center
# bersedia : sedia
# menerima : terima
# keluh : keluh
# kesahmu : kesah
# pengguna : guna
# mncplay : mncplay
# pln : pln
# kolaborasi : kolaborasi
# surem : surem
# lapor : lapor
# yoga : yoga
# koneksikan : koneksi
# perkembangan : kembang
# terbaru : baru
# menghibur : hibur
# penthouse : penthouse
# dahhh : dahhh
# ngelag : ngelag
# guguk : guguk
# bedebah : bedebah
# terganggu : ganggu
# kiro : kiro
# mek : mek
# utekku : utekku
# adakno : adakno
# melok : lok
# sisan : sis
# lagg : lagg
# ahhh : ahhh
# bangke : bangke
# pesan : pesan
# tambahan : tambah
# mola : mola
# lgi : lgi
# sekar : sekar
# antrian : antri
# dat : dat
# nge : nge
# satsu : satsu
# pheonix : pheonix
# just : just
# too : too
# powerful : powerful
# stopped : stopped
# syarif : syarif
# jako : jako
# netflix : netflix
# disney : disney
# hotstar : hotstar
# nikmati : nikmat
# stb : stb
# tuhan : tuhan
# useetv : useetv
# bandung : bandung
# kebutuhan : butuh
# pelanggan : langgan
# hubungin : hubungin
# phone : phone
# happen : happen
# bat : bat
# terim : rim
# soebandrio : soebandrio
# proses : proses
# diupayakan : upaya
# bantuin : bantuin
# robohin : robohin
# mental : mental
# ajah : ajah
# tpi : tpi
# emng : emng
# kyknya : kyknya
# jjur : jjur
# kek : kek
# allahu : allahu
# akbar : akbar
# ren : ren
# bintaro : bintaro
# sektor : sektor
# firstmed : firstmed
# ketagihan : tagih
# hello : hello
# mrs : mrs
# sorry : sorry
# for : for
# inconvenience : inconvenience
# regarding : regarding
# problem : problem
# with : with
# network : network
# inform : inform
# immediately : immediately
# number : number
# registered : registered
# and : and
# active : active
# cellphone : cellphone
# our : our
# help : help
# process : process
# thank : thank
# you : you
# penurunan : turun
# nominasi : nominasi
# asik : asik
# gegara : gegara
# bengek : bengek
# overall : overall
# enjoy : enjoy
# rame : rame
# kuciang : kuciang
# padam : padam
# disekitar : sekitar
# remedial : remedial
# begimana : begimana
# tacenda : tacenda
# anik : anik
# renew : renew
# sod : sod
# mengembalikan : kembali
# kecepat : cepat
# dijadiin : dijadiin
# indikostan : indikostan
# ngalahin : ngalahin
# chae : chae
# zuko : zuko
# darso : darso
# konfirmasinya : konfirmasi
# alex : alex
# perasaan : asa
# bayar : bayar
# reset : reset
# kenapaa : kenapaa
# baikin : baikin
# giliran : gilir
# maaka : maaka
# laju : laju
# sms : sms
# siang : siang
# lampu : lampu
# blinking : blinking
# kompensasi : kompensasi
# apapun : apa
# rese : rese
# doain : doain
# atlit : atlit
# gamer : gamer
# citacitanya : citacitanya
# bilangnya : bilang
# youtuber : youtuber
# heuheuheu : heuheuheu
# streaming : streaming
# iyuh : iyuh
# trs : trs
# hadeuh : hadeuh
# tertekan : tekan
# respect : respect
# wifinya : wifinya
# kenceeeeeengggg : kenceeeeeengggg
# bantuannya : bantu
# novianti : novianti
# browser : browser
# berupaya : upaya
# mengupgrade : mengupgrade
# konten : konten
# gamesnya : gamesnya
# bareng : bareng
# michel : michel
# sampis : sampis
# badmood : badmood
# tae : tae
# fauzi : fauzi
# memudahkan : mudah
# bukti : bukti
# urgent : urgent
# mengurangi : kurang
# terhubungnya : hubung
# ubung : ubung
# mencoba : coba
# tvnya : tvnya
# interkasi : interkasi
# pras : pras
# terpantau : pantau
# kurangi : kurang
# terh : terh
# diupgrade : diupgrade
# semingguan : minggu
# sulit : sulit
# astaga : astaga
# indihomenya : indihomenya
# bales : bales
# kiky : kiky
# bermanfaat : manfaat
# telpnya : telpnya
# yuli : yuli
# penawaran : tawar
# permintaan : minta
# diinformasikan : informasi
# comes : comes
# closer : closer
# approaching : approaching
# your : your
# stunning : stunning
# figure : figure
# soon : soon
# his : his
# arms : arms
# belting : belting
# thin : thin
# waist : waist
# whispers : whispers
# ear : ear
# raspy : raspy
# voice : voice
# panggil : panggil
# usee : usee
# install : install
# tertulis : tulis
# uncompatible : uncompatible
# mengganggu : ganggu
# sedihnya : sedih
# desa : desa
# pelosok : pelosok
# pemerintah : perintah
# gencar : gencar
# gencarnya : gencar
# sosialisasi : sosialisasi
# daring : daring
# berharap : harap
# dpt : dpt
# gamenya : gamenya
# benefitnya : benefitnya
# harga : harga
# paketnya : paket
# terjangkau : jangkau
# berantem : antem
# ajalah : aja
# hikss : hikss
# bgtt : bgtt
# jdnya : jdnya
# nyari : nyari
# titik : titik
# manual : manual
# fast : fast
# dateline : dateline
# katalog : katalog
# flop : flop
# lbh : lbh
# ditelpon : telpon
# nanya : nanya
# persetujuan : tuju
# kerjanya : kerja
# nagih : nagih
# diingetin : diingetin
# bgtsi : bgtsi
# wkwkwkwkkwkw : wkwkwkwkkwkw
# diinfokan : info
# bintoro : bintoro
# bertujuan : tuju
# kualitas : kualitas
# terakhirnya : akhir
# ngeload : ngeload
# gdocs : gdocs
# buset : buset
# gambar : gambar
# video : video
# keplay : keplay
# plis : plis
# sedih : sedih
# nntn : nntn
# lodingnya : lodingnya
# bnr : bnr
# yaampun : yaampun
# jteumes : jteumes
# asikk : asikk
# benefit : benefit
# games : games
# semangat : semangat
# meresahkan : resah
# disave : disave
# keblokir : blokir
# menghilang : hilang
# terhalang : halang
# mlu : mlu
# teros : ros
# langgana : langgana
# bawaan : bawa
# koq : koq
# delay : delay
# bisnis : bisnis
# telkomcare : telkomcare
# diarahkan : arah
# membantu : bantu
# memberhentikan : henti
# tipe : tipe
# erwin : erwin
# pemohon : mohon
# base : base
# alam : alam
# tancap : tancap
# kerusakan : rusa
# budiman : budiman
# terindikasi : indikasi
# ter : ter
# komitme : komitme
# soleiman : soleiman
# uwam : uwam
# jiwa : jiwa
# aduh : aduh
# pengen : ken
# mahhh : mahhh
# optic : optic
# prosedur : prosedur
# kemarim : kemarim
# dtg : dtg
# plaza : plaza
# dapetin : dapetin
# bonus : bonus
# vouchernya : vouchernya
# seruu : seruu
# petugasnya : tugas
# kupang : kupang
# total : total
# hanaz : hanaz
# finally : finally
# macem : macem
# taek : taek
# terlemot : lot
# film : film
# jaman : jaman
# hr : hr
# merugikan : rugi
# sepekan : pek
# gampang : gampang
# klau : klau
# goblok : goblok
# anyeng : anyeng
# dinotice : dinotice
# capek : capek
# astaghfirullah : astaghfirullah
# pengaruh : pengaruh
# apanya : apa
# drop : drop
# bad : bad
# experience : experience
# klu : klu
# beralih : alih
# syngnya : syngnya
# komplain : komplain
# ditanggapi : tanggap
# komplainnya : komplain
# kemana : mana
# teruss : teruss
# yosua : yosua
# lampiran : lampir
# upload : upload
# lewati : lewat
# minsay : minsay
# maraknya : marak
# knph : knph
# iyh : iyh
# mentang : mentang
# ujan : ujan
# ikutnan : ikutnan
# mane : mane
# racunnn : racunnn
# ditabung : tabung
# uangnya : uang
# harganya : harga
# marah : marah
# diisi : isi
# btw : btw
# tengs : tengs
# atensinya : atensi
# karyawan : karyawan
# nanganin : nanganin
# ngentodddd : ngentodddd
# oalah : oalah
# ngentodd : ngentodd
# adib : adib
# sangattt : sangattt
# kirain : kirain
# drtd : drtd
# ngepause : ngepause
# videonya : video
# ahahahha : ahahahha
# kendalapun : kendala
# teratasi : atas
# puas : puas
# kluar : kluar
# tanda : tanda
# hadeuhhh : hadeuhhh
# busuk : busuk
# ketahui : tahu
# mksh : mksh
# kelakuan : laku
# gb : gb
# beyond : beyond
# evil : evil
# abis : abis
# ivan : ivan
# mendingan : mending
# konter : konter
# terhindar : hindar
# oknum : oknum
# bertanggungjawab : bertanggungjawab
# gabung : gabung
# serius : serius
# diseriusin : diseriusin
# skuyy : skuyy
# yng : yng
# telfon : telfon
# tiputipu : tiputipu
# mecare : mecare
# terputus : putus
# ckckck : ckckck
# mmg : mmg
# yha : yha
# wkwkw : wkwkw
# korban : korban
# jun : jun
# facebook : facebook
# herdi : herdi
# randy : randy
# huhu : huhu
# vin : vin
# solusikan : solusi
# aida : aida
# gampar : gampar
# asuk : asuk
# pager : pager
# apasih : apasih
# kaca : kaca
# twin : twin
# gabisa : gabisa
# qeish : qeish
# maybe : maybe
# mimpi : mimpi
# pikiran : pikir
# overthinking : overthinking
# smpe : smpe
# kebawa : bawa
# atao : atao
# mngkin : mngkin
# samsek : samsek
# dpikiran : dpikiran
# kenyataan : nyata
# waaahh : waaahh
# bibit : bibit
# mbaa : mbaa
# kutunggu : tunggu
# yaudah : yaudah
# mepet : mepet
# ginii : ginii
# mengecewakan : kecewa
# nyimpen : nyimpen
# mimin : mimin
# kerjasamanya : kerjasamanya
# ipam : ipam
# niko : niko
# pengcekan : cek
# yaaaa : yaaaa
# kota : kota
# padang : padang
# leletnya : lelet
# nasional : nasional
# berkala : kala
# karina : karina
# sebabkan : sebab
# skin : skin
# dikomen : dikomen
# lgie : lgie
# khats : khats
# cardy : cardy
# cantik : cantik
# gemes : gemes
# dipinang : pinang
# looh : looh
# nguras : nguras
# kantong : kantong
# meriah : riah
# gas : gas
# cuy : cuy
# mulyadi : mulyadi
# selesaikan : selesai
# dibutuhkan : butuh
# menunjang : tunjang
# aktifitas : aktifitas
# sehari : hari
# keluarga : keluarga
# dimasa : masa
# pandemi : pandemi
# pikirkan : pikir
# berlangganannya : langgan
# aka : aka
# responnya : responnya
# cepat : cepat
# punten : punten
# pedrossa : pedrossa
# optimal : optimal
# jarak : jarak
# ganggu : ganggu
# gwen : gwen
# muncul : muncul
# keterangan : terang
# nice : nice
# disimpan : simpan
# bersangkutan : sangkut
# lila : lila
# connection : connection
# please : please
# digits : digits
# owner : owner
# service : service
# account : account
# can : can
# check : check
# further : further
# kagak : kagak
# dahh : dahh
# urus : urus
# praktis : praktis
# faizal : faizal
# kontrak : kontrak
# mes : mes
# irwan : irwan
# infomasikan : infomasikan
# nurfitriah : nurfitriah
# mengestimasikannya : estimasi
# php : php
# kelupaan : lupa
# benget : benget
# youtube : youtube
# bisanya : bisa
# ngedrop : ngedrop
# username : username
# default : default
# bls : bls
# ngebantu : ngebantu
# nyoba : nyoba
# ajaa : ajaa
# jeleeekkk : jeleeekkk
# vani : vani
# malvino : malvino
# dapatkan : dapat
# berminat : minat
# email : email
# troy : troy
# mamakku : mamak
# biznet : biznet
# difollow : difollow
# andi : andi
# ever : ever
# are : are
# halooo : halooo
# inet : inet
# dtindak : dtindak
# gebukin : gebukin
# slek : slek
# pov : pov
# pcr : pcr
# hrs : hrs
# apply : apply
# sales : sales
# anyway : anyway
# contact : contact
# buru : buru
# baiklah : baik
# emosional : emosional
# dirumahku : rumah
# emqwkgnuuw : emqwkgnuuw
# arkgunbigavjukeg : arkgunbigavjukeg
# put : put
# huwaaaa : huwaaaa
# sponspop : sponspop
# jurig : jurig
# gtv : gtv
# produk : produk
# drakoran : drakoran
# gengs : gengs
# tele : tele
# sanggup : sanggup
# thankyou : thankyou
# jahil : jahil
# nanana : nanana
# dew : dew
# updatenya : updatenya
# diproses : proses
# slot : slot
# odp : odp
# full : full
# karus : karus
# kosong : kosong
# jbjb : jbjb
# menfess : menfess
# tebakan : tebak
# nak : nak
# whats : whats
# wrong : wrong
# wichu : wichu
# piece : piece
# stabilin : stabilin
# iyooooo : iyooooo
# smpek : smpek
# nontok : nontok
# raono : raono
# sing : sing
# share : share
# ndek : ndek
# general : general
# raiso : raiso
# maapkaanya : maapkaanya
# plus : plus
# alemong : alemong
# wanda : wanda
# gapaham : gapaham
# bedanya : beda
# roh : roh
# setan : setan
# makhluk : makhluk
# halus : halus
# this : this
# only : only
# reason : reason
# scared : scared
# asia : asia
# next : next
# szn : szn
# feri : feri
# udi : udi
# kuy : kuy
# yok : yok
# pacaran : pacar
# lahh : lahh
# gurung : gurung
# keneng : neng
# waeee : waeee
# kelewatan : lewat
# khotbah : khotbah
# wingi : wing
# kuseno : kuseno
# siyap : siyap
# marcmc : marcmc
# dek : dek
# sienna : sienna
# perbedaan : beda
# jawabannya : jawab
# hyung : hyung
# teruus : teruus
# kontaknya : kontak
# jualan : jual
# lettering : lettering
# kado : kado
# spesial : spesial
# pajangan : pajang
# anti : anti
# luntur : luntur
# line : line
# sdg : sdg
# ayolaa : ayolaa
# denger : denger
# spotify : spotify
# katro : katro
# rere : rere
# shahil : shahil
# makasi : makas
# miminnn : miminnn
# low : low
# yudha : yudha
# difol : difol
# wuri : wuri
# dicapture : dicapture
# tindaklanjutnya : tindaklanjutnya
# meluncur : luncur
# restu : restu
# dihomecare : dihomecare
# derajat : derajat
# trims : trims
# lof : lof
# pondok : pondok
# rajeg : rajeg
# chintya : chintya
# bondan : bondan
# aurani : aurani
# amru : amru
# irvan : irvan
# diawali : awal
# myir : myir
# ofy : ofy
# knpsi : knpsi
# nadia : nadia
# kordinasikan : kordinasikan
# sma : sma
# memiliki : milik
# study : study
# ukuran : ukur
# jas : jas
# anying : anying
# irs : irs
# mhs : mhs
# dietujui : dietujui
# suasana : suasana
# kepala : kepala
# migrain : migrain
# sembuh : sembuh
# mbankin : mbankin
# bri : bri
# eps : eps
# keliru : keliru
# gara : gara
# berpikir : pikir
# wireless : wireless
# teraneh : aneh
# bujuk : bujuk
# papa : papa
# masang : masang
# sksjksjsksusishs : sksjksjsksusishs
# bismillah : bismillah
# cutie : cutie
# okee : okee
# sempet : sempet
# temenin : temenin
# imin : imin
# kampus : kampus
# sekale : sekale
# pria : pria
# tampan : tampan
# wkwkwkkw : wkwkwkkw
# panggilan : panggil
# osti : osti
# gilang : gilang
# saa : saa
# iniiiiii : iniiiiii
# cipan : cipan
# dilanjutkan : lanjut
# ndihomecare : ndihomecare
# regina : regina
# notik : notik
# petigas : tigas
# tanggal : tanggal
# menghancurkan : hancur
# jaringanya : jaringanya
# mobile : mobile
# legend : legend
# doank : doank
# separah : parah
# ping : ping
# prusahaan : prusahaan
# pasangnya : pasang
# ane : ane
# aryun : aryun
# surya : surya
# jadwalkan : jadwal
# wanrha : wanrha
# hyou : hyou
# memperlancar : lancar
# kerahasiaan : rahasia
# pelangg : pelangg
# synar : synar
# menghap : hap
# ihomecare : ihomecare
# mayorani : mayorani
# maintance : maintance
# tweetnya : tweetnya
# sifatnya : sifat
# fckk : fckk
# michele : michele
# loss : loss
# menamba : menamba
# kolom : kolom
# sebelah : belah
# kanan : kanan
# rincian : rincian
# ceklis : ceklis
# syarat : syarat
# ketentuan : tentu
# lanjutkan : lanjut
# menyesuaikan : sesuai
# diaktifkan : aktif
# log : log
# aktivitas : aktivitas
# berjalan : jalan
# menyediakan : sedia
# miftah : miftah
# memantau : pantau
# ayok : ayok
# libur : libur
# sisa : sisa
# ayuk : ayuk
# marathon : marathon
# yukkkk : yukkkk
# lemottttt : lemottttt
# gada : gada
# penindakan : tindak
# seneng : neng
# emg : emg
# gablh : gablh
# rencanain : rencanain
# kontrakan : kontra
# tmn : tmn
# bultang : bultang
# cafe : cafe
# pdhl : pdhl
# baju : baju
# atm : atm
# petshop : petshop
# hamster : hamster
# toko : toko
# olahraga : olahraga
# anjrit : anjrit
# voteeee : voteeee
# kenapaaaa : kenapaaaa
# nangis : nang
# twt : twt
# tdnya : tdnya
# heboh : heboh
# brg : brg
# kaliam : kaliam
# abs : abs
# uyon : uyon
# ngandalin : ngandalin
# ngedet : ngedet
# seharian : hari
# indosat : indosat
# bye : bye
# yaelah : yaelah
# load : load
# acha : acha
# cintaku : cinta
# terhambat : hambat
# kait : kait
# arfi : arfi
# bertingkah : ting
# gbales : gbales
# senyum : senyum
# pacarnya : pacar
# heh : heh
# yth : yth
# keluhan : keluh
# tks : tks
# egk : egk
# tata : tata
# rizal : rizal
# setiawan : setiawan
# skskska : skskska
# aot : aot
# viu : viu
# mingguan : minggu
# mba : mba
# dimatikan : mati
# periksa : periksa
# homecare : homecare
# anang : anang
# pembelian : beli
# tiuz : tiuz
# teleponya : tepo
# gurez : gurez
# kiki : kiki
# nur : nur
# lesta : lesta
# taco : taco
# perubahan : ubah
# gun : gun
# adi : adi
# pesannya : pesan
# notifikasi : notifikasi
# mino : mino
# peralihan : alih
# tautan : taut
# ipal : ipal
# melanjutkan : lanjut
# bebey : bebey
# migrasi : migrasi
# mengajukan : aju
# cancel : cancel
# pelayanannya : layan
# tenggang : tenggang
# kadung : kadung
# marem : marem
# enek : enek
# notif : notif
# gasi : gas
# suruh : suruh
# alfry : alfry
# aryo : aryo
# arifiansyah : arifiansyah
# ndak : ndak
# lucu : lucu
# ditungguin : ditungguin
# berminggu : minggu
# nurha : nurha
# mega : mega
# ksian : ksi
# nurut : nurut
# brengsek : brengsek
# omecare : omecare
# manda : manda
# indih : indih
# quality : quality
# purchase : purchase
# beliin : beliin
# request : request
# huhuhu : huhuhu
# worth : worth
# sekaleeeeeeee : sekaleeeeeeee
# aaaa : aaaa
# npi : npi
# sja : sja
# kao : kao
# maunya : mau
# cewe : cewe
# candaa : candaa
# sayang : sayang
# menu : menu
# brp : brp
# sebulan : bulan
# karna : karna
# donggggg : donggggg
# gabakal : gabakal
# gigit : gigit
# kekirim : kirim
# anjrid : anjrid
# mngapasi : mngapasi
# ngajak : ngajak
# baku : baku
# hanyam : hanyam
# gpp : gpp
# skrng : skrng
# nnt : nnt
# caracal : caracal
# ngebayem : ngebayem
# wrror : wrror
# jringan : jringan
# wakakkakaka : wakakkakaka
# eek : eek
# code : code
# lengkap : lengkap
# mslh : mslh
# jojo : jojo
# acil : acil
# intan : intan
# menfollow : menfollow
# cyndy : cyndy
# andreas : andreas
# clear : clear
# cache : cache
# kondisinya : kondisi
# teri : teri
# ilham : ilham
# spee : spee
# kendor : kendor
# hmmmmmmmmmm : hmmmmmmmmmm
# kabelnya : kabel
# gracianus : gracianus
# plot : plot
# twist : twist
# martapura : martapura
# banjar : banjar
# war : war
# tetiba : tetiba
# disconnect : disconnect
# sora : sora
# bisabisanya : bisabisanya
# eluu : eluu
# baper : baper
# iyakah : iya
# eko : eko
# support : support
# bululawang : bululawang
# joss : joss
# rekomin : rekomin
# kenpa : kenpa
# notice : notice
# padhl : padhl
# dirumh : dirumh
# berdua : dua
# istri : istri
# smart : smart
# mentok : mentok
# masng : masng
# bedua : bedua
# sblun : sblun
# hamsa : hamsa
# mbak : mbak
# akupun : aku
# fotonya : foto
# anehnya : aneh
# duanya : dua
# hpku : hpku
# radit : radit
# aren : aren
# terupgrade : terupgrade
# rahmat : rahmat
# semoga : moga
# permohonannya : mohon
# realisasi : realisasi
# close : close
# permohonan : mohon
# tlp : tlp
# tehnisi : tehnisi
# dihidupkan : hidup
# repot : repot
# capeek : capeek
# point : point
# blank : blank
# putar : putar
# putri : putri
# pengaturan : atur
# nerbener : nerbener
# dikirim : kirim
# mikir : mikir
# bumi : bumi
# reply : reply
# ngambil : ngambil
# pasword : pasword
# mayat : mayat
# muka : muka
# diinget : diinget
# ngasih : ngasih
# pesen : sen
# ekspresi : ekspresi
# memohon : mohon
# gatau : gatau
# alurnya : alur
# terngiang : ngiang
# ngiang : ngiang
# dikepala : kepala
# josua : josua
# dipertimbangkan : timbang
# gilak : gilak
# ngjak : ngjak
# ribut : ribut
# koyone : koyone
# nganggo : nganggo
# hueheuhe : hueheuhe
# beres : beres
# jujur : jujur
# taeklah : taeklah
# weekend : weekend
# gerangan : gerangan
# tega : tega
# bayu : bayu
# web : web
# hbo : hbo
# ide : ide
# media : media
# sosial : sosial
# perbaiki : baik
# dikondisikan : kondisi
# selambat : lambat
# doi : doi
# yukkk : yukkk
# mabar : mabar
# fire : fire
# mumpung : mumpung
# bgtttt : bgtttt
# aaaaaaaaaaa : aaaaaaaaaaa
# dikatain : dikatain
# nyolot : nyolot
# ehh : ehh
# lhoo : lhoo
# kare : kare
# tersuspend : tersuspend
# ormasikan : ormasikan
# ciam : ciam
# anuin : anuin
# twibon : twibon
# jele : jele
# bgty : bgty
# monangis : monangis
# unggul : unggul
# dimohon : mohon
# inf : inf
# sambungkan : sambung
# gmana : gmana
# naq : naq
# merapat : rapat
# ngerjain : ngerjain
# ngeleg : ngeleg
# disayangkan : sayang
# kehilangan : hilang
# ranika : ranika
# podoo : podoo
# lorr : lorr
# omahku : omahku
# wenak : wenak
# goyang : goyang
# blas : blas
# filem : filem
# kabeh : kabeh
# kesuspen : kesuspen
# schwindelig : schwindelig
# maya : maya
# why : why
# selesaiin : selesaiin
# heeey : heeey
# ryan : ryan
# dibalas : balas
# penanga : penanga
# hariini : hariini
# saldo : saldo
# linkajanya : linkajanya
# terpotong : potong
# penambahan : tambah
# speednya : speednya
# gimanani : gimanani
# ganambah : ganambah
# beb : beb
# pretty : pretty
# terisolir : isolir
# loo : loo
# budal : budal
# tok : tok
# lor : lor
# pakek : pakek
# laaanjoot : laaanjoot
# model : model
# toong : toong
# fadhil : fadhil
# indihom : indihom
# kharis : kharis
# felicia : felicia
# tertancap : tancap
# bahan : bahan
# ngepush : ngepush
# cindy : cindy
# will : will
# respond : respond
# submitted : submitted
# click : click
# below : below
# tulung : tulung
# rto : rto
# pelangganmu : langgan
# stream : stream
# dota : dota
# wajib : wajib
# nyalanya : nyala
# don : don
# test : test
# menjual : jual
# cimahi : cimahi
# seharga : harga
# rp : rp
# kgak : kgak
# gereget : gereget
# history : history
# recorded : recorded
# teknisinya : teknisi
# janji : janji
# say : say
# goodbye : goodbye
# welcome : welcome
# firstmedia : firstmedia
# alhamdulillah : alhamdulillah
# stressssss : stressssss
# dear : dear
# possible : possible
# hanyaa : hanyaa
# akuuuuuu : akuuuuuu
# mahasantri : mahasantri
# perum : perum
# mustamindo : mustamindo
# rimbo : rimbo
# kec : kec
# tambang : tambang
# kab : kab
# kampar : kampar
# riau : riau
# betele : betele
# hoy : hoy
# kons : kons
# kesianan : sian
# indihomo : indihomo
# mb : mb
# ms : ms
# yuks : yuks
# godriel : godriel
# arif : arif
# channel : channel
# kento : kento
# iseng : iseng
# gmail : gmail
# mamaku : mama
# barusan : barusan
# ganteng : ganteng
# ngadat : ngadat
# hiks : hiks
# malmingan : malmingan
# nsy : nsy
# aliso : aliso
# dilokasinya : lokasi
# mantep : mantep
# alasannya : alas
# mesenger : mesenger
# emak : emak
# deg : deg
# isa : isa
# downgrade : downgrade
# ditempat : tempat
# kenapasih : kenapasih
# kampung : kampung
# blom : blom
# nyampe : nyampe
# seluler : seluler
# sial : sial
# speedtest : speedtest
# speedtestnya : speedtestnya
# denny : denny
# kunjungan : kunjung
# gapapaaaa : gapapaaaa
# lia : lia
# malu : malu
# maluin : maluin
# orgnya : orgnya
# alfamart : alfamart
# blgnya : blgnya
# indomaret : indomaret
# yuklah : yuk
# maen : maen
# jagonya : jago
# org : org
# unlimited : unlimited
# manggil : manggil
# jatipadang : jatipadang
# betott : betott
# kecepatanya : kecepatanya
# paketan : paket
# asah : asah
# juara : juara
# kebiasaan : biasa
# gueee : gueee
# rumaaaaahhh : rumaaaaahhh
# kedepannya : depan
# penunjang : tunjang
# kegiatan : giat
# work : work
# from : from
# home : home
# cixunk : cixunk
# wujud : wujud
# apresiasi : apresiasi
# pelayanan : layan
# hahahaa : hahahaa
# esmoriiii : esmoriiii
# kecanduan : candu
# pusat : pusat
# satrya : satrya
# iyaaa : iyaaa
# kaa : kaa
# daerahku : daerah
# trnyta : trnyta
# babi : babi
# senjata : senjata
# liza : liza
# kerahasiaa : kerahasiaa
# loncat : loncat
# pingnya : pingnya
# ardhia : ardhia
# kangen : kangen
# seluang : seluang
# janjian : janji
# pencabutan : cabut
# pengambilan : ambil
# alat : alat
# bekas : bekas
# benerin : benerin
# slowresp : slowresp
# linknya : linknya
# kereen : kereen
# yuuk : yuuk
# prams : prams
# daritadi : daritadi
# mode : mode
# dibanting : banting
# lost : lost
# diajak : ajak
# jungkook : jungkook
# fix : fix
# grgr : grgr
# melewatkan : lewat
# moment : moment
# jink : jink
# mang : mang
# when : when
# complain : complain
# about : about
# slow : slow
# but : but
# they : they
# always : always
# tell : tell
# instead : instead
# expensive : expensive
# trash : trash
# connections : connections
# wedi : wedi
# demit : demit
# ngerti : ngerti
# kasian : kasi
# nugas : nugas
# irra : irra
# ayah : ayah
# duwe : duwe
# opose : opose
# sajane : sajane
# dok : dok
# menyedihkan : sedih
# android : android
# bois : bois
# cant : cant
# relate : relate
# kereeen : kereeen
# super : super
# komplit : komplit
# paketnyaa : paketnyaa
# pppp : pppp
# zura : zura
# februari : februari
# customer : customer
# dialihkan : alih
# jumpa : jumpa
# ramein : ramein
# clubhouse : clubhouse
# rudy : rudy
# melampirkan : lampir
# pembayarannya : bayar
# refund : refund
# deposit : deposit
# dibayarkan : bayar
# izanagi : izanagi
# rutin : rutin
# bajigur : bajigur
# ksl : ksl
# riri : riri
# gecekan : gecek
# segenap : segenap
# finallyy : finallyy
# oit : oit
# bggtt : bggtt
# wihh : wihh
# cakepp : cakepp
# newbie : newbie
# byr : byr
# pke : pke
# linkaja : linkaja
# dijanjiin : dijanjiin
# ditelp : ditelp
# sorenya : sore
# sikkkkk : sikkkkk
# jurus : jurus
# maksud : maksud
# hajdhakdhjas : hajdhakdhjas
# anjng : anjng
# yeah : yeah
# suck : suck
# umen : umen
# narik : narik
# tambahin : tambahin
# ghan : ghan
# all : all
# hail : hail
# elah : elah
# theo : theo
# skarang : skarang
# sprti : sprti
# hzzzzz : hzzzzz
# dikantong : kantong
# cla : cla
# akti : akti
# astagfirullah : astagfirullah
# haloooooo : haloooooo
# hrsnya : hrsnya
# balikin : balikin
# heeh : heeh
# dimonopoli : monopoli
# didaerah : daerah
# urg : urg
# pisan : pis
# nisha : nisha
# statusnya : status
# dying : dying
# gasp : gasp
# berbunyi : bunyi
# connected : connected
# setadi : tadi
# woyy : woyy
# ish : ish
# ricka : ricka
# mensolusikan : solusi
# naia : naia
# asw : asw
# ngent : ngent
# ayo : ayo
# gakkk : gakkk
# persyaratan : syarat
# langkahnya : langkah
# sila : sila
# mengajukannya : aju
# corporate : corporate
# comm : comm
# instagram : instagram
# gunawan : gunawan
# quppa : quppa
# danny : danny
# aghvyubvff : aghvyubvff
# odan : odan
# ingan : ingan
# barcel : barcel
# disarankan : saran
# jar : jar
# parahnya : parah
# trancking : trancking
# case : case
# selesai : selesai
# datangin : datangin
# suara : suara
# penjelasannya : jelas
# lawas : lawas
# pgn : pgn
# ajgggg : ajgggg
# pantek : pantek
# wak : wak
# kau : kau
# record : record
# yaaa : yaaa
# yatuhan : yatuhan
# sesore : sore
# kaaihan : kaaihan
# telkomsel : telkomsel
# level : level
# rusak : rusak
# sia : sia
# luang : luang
# naufal : naufal
# koordinasi : koordinasi
# linda : linda
# refan : refan
# pengeceka : pengeceka
# desinta : desinta
# otomatis : otomatis
# indonesia : indonesia
# plasa : plasa
# jember : jember
# kukan : kuk
# tepi : tepi
# menurun : turun
# ato : ato
# gimanaaa : gimanaaa
# walo : walo
# sadddd : sadddd
# edan : edan
# sui : sui
# antu : antu
# alia : alia
# dib : dib
# shit : shit
# still : still
# stop : stop
# smoking : smoking
# crack : crack
# offices : offices
# simcard : simcard
# kuat : kuat
# haduh : haduh
# nyambung : nyambung
# iyud : iyud
# hermina : hermina
# dibawah : bawah
# muzammil : muzammil
# nungguin : nungguin
# bangsat : bangsat
# hri : hri
# kunjung : kunjung
# kecewa : kecewa
# kemaren : kemaren
# positip : positip
# ama : ama
# ralih : ralih
# memuat : muat
# disalahgunakan : disalahgunakan
# warizmi : warizmi
# tercancel : tercancel
# tersedia : sedia
# akt : akt
# yups : yups
# ajak : ajak
# saudara : saudara
# pengaduannya : adu
# nami : nami
# gabut : gabut
# joro : joro
# tari : tari
# provide : provide
# ngak : ngak
# losss : losss
# ajakin : ajakin
# krik : krik
# octobaran : octobaran
# njadi : njadi
# adil : adil
# vanmilano : vanmilano
# mara : mara
# mnghubungi : mnghubungi
# berisi : isi
# nomo : nomo
# rizky : rizky
# menunjukan : tunjuk
# longgar : longgar
# kabe : kabe
# cah : cah
# indihomeku : indihomeku
# mari : mari
# kesambit : sambit
# layangan : layang
# gaes : gaes
# gercep : gercep
# lur : lur
# semenjak : semenjak
# nggawe : nggawe
# maleh : maleh
# opo : opo
# out : out
# mego : mego
# berterimakasih : berterimakasih
# ambek : ambek
# menemani : tani
# iso : iso
# kerjasama : kerjasama
# banter : banter
# sungkem : sungkem
# pandu : pandu
# kerjaanku : kerja
# rek : rek
# iki : iki
# pubg : pubg
# mayo : mayo
# bunian : bunian
# nunik : nunik
# smpi : smpi
# kiamat : kiamat
# kedip : kedip
# ttp : ttp
# mew : mew
# mewmew : mewmew
# barbie : barbie
# kumalasari : kumalasari
# bosakah : bosakah
# konsumen : konsumen
# ulu : ulu
# elsa : elsa
# pdahal : pdahal
# huee : huee
# suplai : suplai
# makanan : makan
# bensin : bensin
# wisata : wisata
# disuplai : suplai
# guru : guru
# dibicarakan : bicara
# tya : tya
# pengecekkan : ecek
# virtual : virtual
# bca : bca
# kenape : kenape
# elu : elu
# kayanya : kaya
# sosmed : sosmed
# kirimin : kirimin
# jadwal : jadwal
# irsyaufan : irsyaufan
# patuhi : patuh
# protokol : protokol
# kesehatan : sehat
# kipasin : kipasin
# msh : msh
# gede : gede
# solusi : solusi
# kkn : kkn
# tyrawoke : tyrawoke
# anan : anan
# lay : lay
# kasim : kasim
# mengikuti : ikut
# mempermudah : mudah
# kucing : kucing
# ibadah : ibadah
# khusus : khusus
# mandiri : mandiri
# salwa : salwa
# knffh : knffh
# skli : skli
# hsoe : hsoe
# wkwkwkwi : wkwkwkwi
# miminnya : miminnya
# ngeluh : ngeluh
# packet : packet
# ditambah : tambah
# dogshit : dogshit
# apex : apex
# auto : auto
# cuman : cuman
# entar : entar
# legends : legends
# payah : payah
# ika : ika
# asep : asep
# dijadwal : jadwal
# alasan : alas
# muter : muter
# ngomongnya : ngomongnya
# kejadian : jadi
# pusing : pusing
# bolak : bolak
# desti : desti
# kerahasia : rahasia
# kind : kind
# laaah : laaah
# masalahny : masalahny
# bngung : bngung
# jga : jga
# ayoo : ayoo
# demo : demo
# dwi : dwi
# kecamatan : camat
# patokan : patok
# terdekat : dekat
# pelapor : lapor
# jugaa : jugaa
# drs : drs
# subaidi : subaidi
# metode : metode
# tokopedia : tokopedia
# margorejo : margorejo
# masjid : masjid
# buntu : buntu
# lembaga : lembaga
# pendidikan : didik
# kaaaa : kaaaa
# keluarin : keluarin
# celuler : celuler
# akunnya : akun
# digembok : gembok
# deq : deq
# kosan : kosan
# cobi : cobi
# pecahin : pecahin
# sebenrya : sebenrya
# tertarik : tarik
# disaat : saat
# gni : gni
# bsa : bsa
# tito : tito
# setting : setting
# firewall : firewall
# mengistirahatkan : istirahat
# oerangkat : oerangkat
# transaksi : transaksi
# tter : tter
# adril : adril
# twi : twi
# slaludihati : slaludihati
# gagal : gagal
# tukar : tukar
# pointnya : point
# kuotanya : kuota
# kopi : kopi
# cemilan : cemilan
# ngapelin : ngapelin
# dateng : dateng
# racunin : racunin
# gbs : gbs
# dhhhh : dhhhh
# panik : panik
# aing : aing
# mrym : mrym
# okd : okd
# ngentottt : ngentottt
# pembicaraan : bicara
# pikir : pikir
# menjangkau : jangkau
# surat : surat
# cinta : cinta
# pengeluh : keluh
# nuhun : nuhun
# hutao : hutao
# cnn : cnn
# headlinenya : headlinenya
# segininya : gin
# tegor : tegor
# reguler : reguler
# basuki : basuki
# gang : gang
# disapa : sapa
# kenapasihhhhh : kenapasihhhhh
# juju : juju
# ngasitau : ngasitau
# barangkali : barangkali
# sgt : sgt
# rambutku : rambut
# gondrong : gondrong
# musti : musti
# nyatok : nyatok
# engga : engga
# rambut : rambut
# kondisikan : kondisi
# lepas : lepas
# tiangnya : tiang
# herlina : herlina
# adik : adik
# freefire : freefire
# ikutan : ikut
# andri : andri
# ajarin : ajarin
# dimainin : dimainin
# killy : killy
# prihal : prihal
# mengubah : ubah
# televisi : televisi
# nawarin : nawarin
# azril : azril
# ngeliat : ngeliat
# efek : efek
# sebenerny : sebenerny
# feedback : feedback
# improvement : improvement
# mengaktifkan : aktif
# terlambat : lambat
# lunasi : lunas
# joni : joni
# rebu : rebu
# perbulan : bulan
# ayukkk : ayukkk
# bosen : bosen
# maria : maria
# jopar : jopar
# maghrib : maghrib
# calling : calling
# bsk : bsk
# saking : saking
# serunya : seru
# documentary : documentary
# van : van
# cuplikannya : cuplik
# fullnya : fullnya
# dmn : dmn
# nntonnya : nntonnya
# nat : nat
# geo : geo
# wild : wild
# done : done
# rsedia : rsedia
# tercover : tercover
# masukan : masuk
# raden : raden
# arda : arda
# holy : holy
# customercare : customercare
# beban : beban
# alhasil : alhasil
# makanin : makanin
# jajanan : jajan
# aan : aan
# seekar : seekar
# kerahasi : kerahasi
# egak : egak
# moots : moots
# ngadi : ngadi
# setuju : tuju
# bund : bund
# nobar : nobar
# penghilang : hilang
# penat : penat
# seharin : seharin
# pantesan : pantesan
# artikel : artikel
# isolir : isolir
# denda : denda
# jt : jt
# deal : deal
# edukasi : edukasi
# memberatkan : berat
# dea : dea
# isetiap : isetiap
# shadila : shadila
# berpengaruh : pengaruh
# diterima : terima
# tereset : tereset
# ajuin : ajuin
# disuruh : suruh
# rb : rb
# liburan : libur
# kabarnya : kabar
# performanya : performa
# ilang : ilang
# yukk : yukk
# kesiangan : siang
# besoknya : besok
# dijamin : jamin
# greget : greget
# gituuuu : gituuuu
# rxbf : rxbf
# kasongan : kasongan
# kal : kal
# teng : teng
# haekal : haekal
# neh : neh
# kaum : kaum
# rebahan : rebah
# mabarr : mabarr
# ngumpul : ngumpul
# teman : teman
# manfaatin : manfaatin
# ganguan : ganguan
# ciledug : ciledug
# kontolll : kontolll
# noob : noob
# berkumpul : kumpul
# pro : pro
# player : player
# susah : susah
# larry : larry
# hasan : hasan
# niii : niii
# enghubungi : enghubungi
# dir : dir
# akhirnyaaa : akhirnyaaa
# sentosa : sentosa
# namanya : nama
# apalah : apa
# pokonya : poko
# top : top
# markotop : markotop
# dibakar : bakar
# dengarkan : dengar
# reasons : reasons
# fall : fall
# hifi : hifi
# langit : langit
# musik : musik
# dipertahankan : tahan
# jaringanny : jaringanny
# spti : spti
# nahh : nahh
# suguhin : suguhin
# bloon : bloon
# mainnya : main
# nikmat : nikmat
# marain : marain
# inget : inget
# xx : xx
# tanyain : tanyain
# nape : nape
# ara : ara
# koordinasikan : koordinasi
# ketimbang : ketimbang
# din : din
# ngertiii : ngertiii
# ituuu : ituuu
# bayarin : bayarin
# nyemil : nyemil
# siapin : siapin
# lapangannya : lapang
# tumbennn : tumbennn
# luancar : luancar
# gmeet : gmeet
# dueress : dueress
# rafif : rafif
# abonemennya : abonemen
# sepaket : paket
# sewa : sewa
# malming : malming
# cepett : cepett
# snack : snack
# nambah : nambah
# ngurangin : ngurangin
# mantap : mantap
# soya : soya
# giffa : giffa
# minum : minum
# kopiii : kopiii
# ngerasain : ngerasain
# boo : boo
# dehh : dehh
# nemu : nemu
# hihihi : hihihi
# berkah : berkah
# dijokiin : dijokiin
# asiap : asiap
# gaskeun : gaskeun
# partner : partner
# ngecover : ngecover
# saingan : saing
# sebar : sebar
# luaskan : luas
# jangkauanmu : jangkau
# hayu : hayu
# join : join
# optik : optik
# instalasi : instalasi
# survey : survey
# pemasangannya : pasang
# mls : mls
# heheheh : heheheh
# hanafi : hanafi
# yak : yak
# sayangnya : sayang
# semangatin : semangatin
# nimbrung : nimbrung
# diaa : diaa
# bark : bark
# kliatan : kliatan
# nder : nder
# mainnnn : mainnnn
# onlinee : onlinee
# hatii : hati
# bunga : bunga
# win : win
# kakkkk : kakkkk
# alias : alias
# ngedukung : ngedukung
# keproduktifan : produktif
# hamba : hamba
# balasan : balas
# hiburan : hibur
# iniii : iniii
# sepupu : sepupu
# cus : cus
# gamers : gamers
# pindahin : pindahin
# mabarrrrr : mabarrrrr
# lets : lets
# meet : meet
# seungyoon : seungyoon
# fanmeet : fanmeet
# yoon : yoon
# special : special
# komputer : komputer
# daffy : daffy
# mabarrr : mabarrr
# sambilll : sambilll
# jajann : jajann
# seruuu : seruuu
# tuhh : tuhh
# tauu : tauu
# kosku : kosku
# jakarta : jakarta
# direstart : direstart
# lebaran : lebaran
# kuda : kuda
# donggg : donggg
# mainan : main
# michat : michat
# amel : amel
# hobi : hobi
# ...
# interaksinya : interaksi
# terak : terak
# lebi : lebi
# abila : abila
# matak : matak
# darah : darah
# wkwkwkw : wkwkwkw
# dilaporne : dilaporne
# isok : isok
# benhas : benhas
# prosenya : prosenya
# hpnya : hpnya
# bray : bray
# jendela : jendela
# burem : burem
# sukses : sukses
# dibales : dibales
# banyaknya : banyak
# ilakan : ilak
# adam : adam
# asemm : asemm
# never : never
# curse : curse
# hard : hard
# except : except
# yossy : yossy
# wahyu : wahyu
# pakenya : pakenya
# jngan : jngan
# fuck : fuck
# penghargaan : harga
# terba : terba
# kay : kay
# anu : anu
# ngurusi : ngurusi
# hei : hei
# bekicot : bekicot
# firman : firman
# telegram : telegram
# tergantung : gantung
# providernya : providernya
# downloadnya : downloadnya
# dibatasi : batas
# sialakan : sialakan
# disinipun : sin
# kerumah : rumah
# dylas : dylas
# astikan : astikan
# dichannel : dichannel
# gapapa : gapapa
# vps : vps
# google : google
# jaga : jaga
# pop : pop
# mie : mie
# juli : juli
# suspend : suspend
# sukabumj : sukabumj
# mainkan : main
# parung : parung
# reza : reza
# suyudi : suyudi
# irfan : irfan
# dimas : mas
# alamatnya : alamat
# has : has
# caps : caps
# htt : htt
# bayarnya : bayar
# nunggak : nunggak
# hahahah : hahahah
# tagihannya : tagih
# juta : juta
# benerinlah : benerinlah
# inic : inic
# bisaaa : bisaaa
# hantuu : hantuu
# ggn : ggn
# cuekin : cuekin
# taiiii : taiiii
# bagusnya : bagus
# wuaaakkk : wuaaakkk
# baarrr : baarrr
# sabaaarrr : sabaaarrr
# aldrian : aldrian
# dilakuka : dilakuka
# jale : jale
# jik : jik
# gampleng : gampleng
# urang : urang
# nginjem : nginjem
# wae : wae
# eta : eta
# hungkul : hungkul
# kamari : kamar
# asih : asih
# butuhkan : butuh
# pelambatan : lambat
# usage : usage
# tentukan : tentu
# router : router
# rizaldi : rizaldi
# dicabut : cabut
# teleponnya : telepon
# velica : velica
# merahhhh : merahhhh
# hhh : hhh
# raditaa : raditaa
# menggagu : gagu
# webtoon : webtoon
# lek : lek
# awak : awak
# gawe : gawe
# gaaasss : gaaasss
# write : write
# that : that
# guduk : guduk
# nang : nang
# who : who
# dicky : dicky
# dikurangi : rang
# medapat : medapat
# kenapasi : napas
# hmm : hmm
# ajar : ajar
# mila : mila
# wih : wih
# weees : weees
# ulan : ulan
# pengertian : erti
# ayolah : ayo
# let : let
# watch : watch
# ngentot : ngentot
# would : would
# dont : dont
# think : think
# its : its
# worst : worst
# like : like
# penyalahgunaan : penyalahgunaan
# dikenal : kenal
# terkoneksi : koneksi
# ontnya : ontnya
# ulang : ulang
# bella : bella
# tersambung : sambung
# rugikan : rugi
# respown : respown
# robbiiiiiii : robbiiiiiii
# kualitasnya : kualitas
# ntuk : ntuk
# morgan : morgan
# maap : maap
# ajh : ajh
# kepusat : pusat
# ind : ind
# irind : irind
# pergantian : ganti
# passwordnya : passwordnya
# imagine : imagine
# raining : raining
# using : using
# rendri : rendri
# gnti : gnti
# cpt : cpt
# hargany : hargany
# dad : dad
# really : really
# said : said
# pidi : pidi
# dikirimkan : kirim
# sekeluarga : keluarga
# jengah : jengah
# masal : masal
# terossss : terossss
# diakumulasiin : diakumulasiin
# gamake : gamake
# bertele : tele
# peke : peke
# asahi : asah
# rima : rima
# mengusahakan : usaha
# donny : donny
# budi : budi
# restar : restar
# improve : improve
# loop : loop
# mahh : mahh
# wgwg : wgwg
# ariyadi : ariyadi
# pembaharuan : baharu
# terselesaikan : selesai
# yunanto : yunanto
# tumben : tumben
# subuh : subuh
# gamas : gamas
# uga : uga
# pisuhin : pisuhin
# cok : cok
# exe : exe
# solver : solver
# didu : didu
# ampas : ampas
# diusahakan : usaha
# tian : tian
# lqs : lqs
# kesetiaannya : setia
# bahagia : bahagia
# pengurangan : kurang
# menstabilkan : stabil
# larasati : larasati
# adaptor : adaptor
# gamau : gamau
# tenant : tenant
# bravo : bravo
# yul : yul
# etikanya : etika
# huh : huh
# perlakukan : laku
# hkan : hkan
# diali : ali
# nadilla : nadilla
# dipandu : pandu
# dibuatkan : buat
# puku : puku
# early : early
# sebelas : sebelas
# nteraksi : nteraksi
# novan : novan
# kecepatannya : cepat
# devic : devic
# nanyadeh : nanyadeh
# gapake : gapake
# bayarmah : bayarmah
# alma : alma
# nnya : nnya
# dita : dita
# kedepa : depa
# soft : soft
# tombol : tombol
# power : power
# off : off
# response : response
# euy : euy
# gonta : gonta
# anon : anon
# tara : tara
# prioritas : prioritas
# gasing : gasing
# woe : woe
# internetan : internetan
# cloud : cloud
# storage : storage
# menyimpan : simpan
# kapasitas : kapasitas
# sesuaikan : sesuai
# setaun : taun
# aditya : aditya
# berkedip : kedip
# legok : legok
# selvina : selvina
# supportnya : supportnya
# jea : jea
# see : see
# merasakan : rasa
# akhirnyaa : akhirnyaa
# izzani : izzani
# move : move
# byu : byu
# lagu : lagu
# maaaal : maaaal
# heuh : heuh
# disalahin : disalahin
# fakhrur : fakhrur
# nugr : nugr
# kompak : kompak
# woo : woo
# ngaco : ngaco
# kebangetan : banget
# saran : saran
# muak : muak
# lampune : lampune
# ijo : ijo
# ono : ono
# sek : sek
# riq : riq
# apasi : apas
# nyandet : nyandet
# wooooy : wooooy
# errrrorrrrr : errrrorrrrr
# woooy : woooy
# lagiiii : lagiiii
# diputus : putus
# woooooyyyy : woooooyyyy
# gedeeeeeeee : gedeeeeeeee
# crm : crm
# sich : sich
# beda : beda
# template : template
# berulah : ulah
# wpgen : wpgen
# relogin : relogin
# kii : kii
# reski : reski
# didm : didm
# gavalidddd : gavalidddd
# diruma : diruma
# kepengen : ken
# yeee : yeee
# benerim : benerim
# wifikuuu : wifikuuu
# krs : krs
# kuliah : kuliah
# dimatiin : dimatiin
# bermasalahnya : masalah
# deis : deis
# rin : rin
# gedy : gedy
# hafizh : hafizh
# kesend : kesend
# arief : arief
# terputusnya : putus
# yag : yag
# dika : dika
# dongg : dongg
# yudhi : yudhi
# lanj : lanj
# slmt : slmt
# fakyu : fakyu
# stau : stau
# mreka : mreka
# makasii : makasii
# gausa : gausa
# nyuruh : nyuruh
# mpbs : mpbs
# ekitar : ekitar
# rendah : rendah
# lulusan : lulus
# ngopo : ngopo
# sentul : sentul
# bogor : bogor
# mata : mata
# makasiii : makasiii
# kiyowo : kiyowo
# oca : oca
# kemi : kemi
# interakasi : interakasi
# sebenernya : sebenernya
# lurus : lurus
# kerjain : kerjain
# lebar : lebar
# ngajarin : ngajarin
# internal : internal
# pencerahan : cerah
# lapornya : lapor
# ngurus : ngurus
# bsd : bsd
# tangga : tangga
# fungsinya : fungsi
# kecuali : kecuali
# partenne : partenne
# berhari : hari
# birokrasi : birokrasi
# izinkan : izin
# menyalahkan : salah
# untungnya : untung
# nada : nada
# datar : datar
# ngegas : ngegas
# hub : hub
# serpong : serpong
# ngecek : ngecek
# perboleh : boleh
# masuknya : masuk
# yass : yass
# dipasang : pasang
# cable : cable
# tsb : tsb
# menjatohkan : menjatohkan
# austin : austin
# first : first
# checking : checking
# nyaut : nyaut
# mvs : mvs
# bisaa : bisaa
# gituu : gituu
# kasali : kasali
# fizly : fizly
# stab : stab
# mkin : mkin
# ayu : ayu
# yumni : yumni
# balesnya : balesnya
# dikenakan : kena
# perak : perak
# muttaqin : muttaqin
# ketidak : tidak
# nyamannya : nyaman
# sinyale : sinyale
# old : old
# guard : guard
# sumpa : sumpa
# shitties : shitties
# signal : signal
# asap : asap
# mfs : mfs
# paid : paid
# yet : yet
# fuckers : fuckers
# mess : mess
# bruh : bruh
# keep : keep
# stealing : stealing
# money : money
# fools : fools
# ngejar : ngejar
# tunggakan : tunggak
# melayani : layan
# peperzak : peperzak
# joe : joe
# direfresh : direfresh
# system : system
# hapus : hapus
# napasiiiikkkk : napasiiiikkkk
# diprioritaskan : prioritas
# mudahan : mudah
# otewe : otewe
# indra : indra
# monyetttt : monyetttt
# hijau : hijau
# scoop : scoop
# shoot : shoot
# murka : murka
# trim : trim
# siapaaa : siapaaa
# cacat : cacat
# ading : ading
# mesms : mesms
# ditindaklanjuti : ditindaklanjuti
# merubah : rubah
# tbtb : tbtb
# merahnya : merah
# bnyk : bnyk
# sialan : sial
# tetanggaku : tetangga
# ngaseng : ngaseng
# tawwa : tawwa
# betulan : betul
# kmrin : kmrin
# skrgggg : skrgggg
# podo : podo
# maniane : maniane
# queen : queen
# halooww : halooww
# kepending : pending
# muchamad : muchamad
# irham : irham
# pad : pad
# melapor : lapor
# tindakan : tindak
# ferry : ferry
# achmad : achmad
# dypta : dypta
# even : even
# flash : flash
# sloth : sloth
# faster : faster
# than : than
# more : more
# since : since
# proper : proper
# now : now
# kinda : kinda
# remind : remind
# speedy : speedy
# should : should
# back : back
# forced : forced
# use : use
# these : these
# zoom : zoom
# classes : classes
# today : today
# nis : nis
# chii : chii
# depok : depok
# mesti : mesti
# weekday : weekday
# rapat : rapat
# ituu : ituu
# access : access
# setyawan : setyawan
# dilanjut : lanjut
# isuk : isuk
# diphp : diphp
# akeh : akeh
# filime : filime
# gobet : gobet
# jaringane : jaringane
# dianggurin : dianggurin
# smartphone : smartphone
# nindi : nindi
# lue : lue
# isoo : isoo
# saiki : saiki
# maneh : maneh
# keder : keder
# wenakk : wenakk
# puoll : puoll
# yana : yana
# wil : wil
# bar : bar
# amalia : amalia
# suwun : suwun
# diat : diat
# ngeelag : ngeelag
# masio : masio
# berharga : harga
# hadiahnya : hadiah
# menarik : tarik
# anjeng : anjeng
# jafar : jafar
# delok : dok
# pujawan : pujawan
# rusaknya : rusak
# tenkyuu : tenkyuu
# wkkw : wkkw
# mampus : mampus
# indigona : indigona
# ngareplay : ngareplay
# haziki : haziki
# akak : akak
# daniel : daniel
# try : try
# ibantu : ibantu
# yosah : yosah
# ngegantung : ngegantung
# lihat : lihat
# {'hai': 'hai', 'kak': 'kak', 'riya': 'riya', 'selamat': 'selamat', 'akun': 'akun', 'layanan': 'layan', 'indihome': 'indihome', 'care': 'care', 'wina': 'wina', 'cek': 'cek', 'jaringannya': 'jaring', 'offline': 'offline', 'perangkat': 'perangkat', 'catuan': 'catu', 'listrik': 'listrik', 'pastikan': 'pasti', 'perangkatnya': 'perangkat', 'menyala': 'nyala', '': '', 'koneksinya': 'koneksi', 'stabil': 'stabil', 'putus': 'putus', 'cipayung': 'cipayung', 'jaktim': 'jaktim', 'halo': 'halo', 'zaidan': 'zaidan', 'terkait': 'kait', 'akses': 'akses', 'internet': 'internet', 'nomor': 'nomor', 'dibantu': 'bantu', 'refresh': 'refresh', 'sistem': 'sistem', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'menit': 'menit', 'coba': 'coba', 'hubungi': 'hubung', 'twitter': 'twitter', 'terima': 'terima', 'kasih': 'kasih', 'agit': 'agit', 'udah': 'udah', 'mah': 'mah', 'ngeselin': 'ngeselin', 'pagi': 'pagi', 'duit': 'duit', 'gue': 'gue', 'nyangkut': 'nyangkut', 'ntah': 'ntah', 'dimana': 'mana', 'masuk': 'masuk', 'dana': 'dana', 'sucks': 'sucks', 'diadukan': 'adu', 'via': 'via', 'aplikasi': 'aplikasi', 'open': 'open', 'jasa': 'jasa', 'tugas': 'tugas', 'kaka': 'kaka', 'plagiasi': 'plagiasi', 'ketik': 'ketik', 'tulis': 'tulis', 'tangan': 'tangan', 'daftar': 'daftar', 'isi': 'isi', 'halaman': 'halaman', 'puisi': 'puisi', 'cerpen': 'cerpen', 'olah': 'olah', 'data': 'data', 'bab': 'bab', 'paper': 'paper', 'makalah': 'makalah', 'uas': 'uas', 'review': 'review', 'jurnal': 'jurnal', 'skripsi': 'skripsi', 'seni': 'seni', 'butuh': 'butuh', 'bantuan': 'bantu', 'seminggu': 'minggu', 'lemot': 'lot', 'ampe': 'ampe', 'baca': 'baca', 'komik': 'komik', 'loadingnya': 'loadingnya', 'bener': 'bener', 'chapter': 'chapter', 'goks': 'goks', 'lemotnya': 'lot', 'haloo': 'haloo', 'los': 'los', 'merah': 'merah', 'diperbaiki': 'baik', 'telpon': 'telpon', 'mati': 'mati', 'jam': 'jam', 'feb': 'feb', 'detail': 'detail', 'kirim': 'kirim', 'berhenti': 'henti', 'berlangganan': 'langgan', 'add': 'add', 'movin': 'movin', 'seamless': 'seamless', 'oke': 'oke', 'ijal': 'ijal', 'kakak': 'kakak', 'mona': 'mona', 'bantu': 'bantu', 'mohon': 'mohon', 'ditunggu': 'tunggu', 'kedepan': 'depan', 'dikoneksikan': 'koneksi', 'angga': 'angga', 'direspon': 'direspon', 'interaksi': 'interaksi', 'iyo': 'iyo', 'soale': 'soale', 'outdihome': 'outdihome', 'tower': 'tower', 'uwong': 'uwong', 'restart': 'restart', 'push': 'push', 'rank': 'rank', 'lagiih': 'lagiih', 'tuhkan': 'tuhkan', 'tdi': 'tdi', 'lose': 'lose', 'streak': 'streak', 'ihh': 'ihh', 'mniii': 'mniii', 'gmna': 'gmna', 'atuh': 'atuh', 'min': 'min', 'sobat': 'sobat', 'maaf': 'maaf', 'nyaman': 'nyaman', 'informasikan': 'informasi', 'silakan': 'sila', 'dicek': 'cek', 'ade': 'ade', 'elanjutnya': 'elanjutnya', 'permintaannya': 'minta', 'indihomecare': 'indihomecare', 'nama': 'nama', 'tagihan': 'tagih', 'pembayaran': 'bayar', 'password': 'password', 'barunya': 'baru', 'konfirmasi': 'konfirmasi', 'telp': 'telp', 'direct': 'direct', 'message': 'message', 'tolong': 'tolong', 'ditangani': 'tangan', 'thanks': 'thanks', 'fitri': 'fitri', 'kendalanya': 'kendala', 'lokasinya': 'lokasi', 'pemeliharaan': 'pelihara', 'jaringan': 'jaring', 'petugas': 'tugas', 'lokasi': 'lokasi', 'pemulihan': 'pulih', 'informasi': 'informasi', 'ganti': 'ganti', 'wifi': 'wifi', 'gimana': 'gimana', 'fauzan': 'fauzan', 'aktif': 'aktif', 'pengecekan': 'kece', 'konyol': 'konyol', 'masi': 'mas', 'buffering': 'buffering', 'gajelas': 'gajelas', 'banget': 'banget', 'rumah': 'rumah', 'lampunya': 'lampu', 'nyala': 'nyala', 'cepaaaaaat': 'cepaaaaaat', 'aktifnya': 'aktif', 'tindaklanjuti': 'tindaklanjuti', 'alya': 'alya', 'ifi': 'ifi', 'maksimal': 'maksimal', 'rekan': 'rekan', 'senja': 'senja', 'respons': 'respons', 'portnya': 'portnya', 'cabut': 'cabut', 'colok': 'colok', 'tetep': 'tetep', 'kaya': 'kaya', 'gini': 'gin', 'solusinya': 'solusi', 'besok': 'besok', 'adek': 'adek', 'ujian': 'uji', 'fauziah': 'fauziah', 'iya': 'iya', 'kena': 'kena', 'speed': 'speed', 'limit': 'limit', 'tekan': 'tekan', 'afuk ...
# ------------------------
# Pandas Apply:   0%|          | 0/1957 [00:00<?, ?it/s]
#                                                 content  \
# 0     @riyaprmtsr hai kak riya, selamat datang di ak...
# 1     @indihome kenapa di tempat sy koneksinya selal...
# 2     @zaidan95 halo kak zaidan. terkait akses inter...
# 3     udah mah indihome juga ngeselin pagi2, ini lag...
# 4                                       indihome sucks.
# ...                                                 ...
# 1995  @yosah22 ibantu langsung. kakak juga dapat mel...
# 1996  @yosah22 halo, kak yosah. perihal pemasangan b...
# 1997  @indihome halo kak. internet mati, sepertinya ...
# 1998             @indihome @indihomecare udah di dm tuh
# 1999   @thaiifess hanya anak indihome yang bisa lihat 🥲
#
#                                          cleaning_tweet  \
# 0     hai kak riya selamat datang akun layanan indih...
# 1     kenapa tempat koneksinya selalu tidak stabil s...
# 2     halo kak zaidan terkait akses internet nomor s...
# 3     udah mah indihome juga ngeselin pagi  ini lagi...
# 4                                       indihome sucks
# ...                                                 ...
# 1995  ibantu langsung kakak juga dapat melakukan pen...
# 1996  halo kak yosah perihal pemasangan baru nunik i...
# 1997  halo kak internet mati sepertinya kabel telkom...
# 1998                                           udah tuh
# 1999               hanya anak indihome yang bisa lihat
#
#                                              tokenisasi  \
# 0     [hai, kak, riya, selamat, datang, akun, layana...
# 1     [kenapa, tempat, koneksinya, selalu, tidak, st...
# 2     [halo, kak, zaidan, terkait, akses, internet, ...
# 3     [udah, mah, indihome, juga, ngeselin, pagi, in...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, juga, dapat, melakuk...
# 1996  [halo, kak, yosah, perihal, pemasangan, baru, ...
# 1997  [halo, kak, internet, mati, sepertinya, kabel,...
# 1998                                        [udah, tuh]
# 1999       [hanya, anak, indihome, yang, bisa, lihat, ]
#
#                                                stopword  \
# 0     [hai, kak, riya, selamat, akun, layanan, indih...
# 1         [koneksinya, stabil, putus, cipayung, jaktim]
# 2     [halo, kak, zaidan, terkait, akses, internet, ...
# 3     [udah, mah, indihome, ngeselin, pagi, duit, gu...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, pengecekkan, keterse...
# 1996  [halo, kak, yosah, perihal, pemasangan, nunik,...
# 1997  [halo, kak, internet, mati, kabel, telkom, rum...
# 1998                                             [udah]
# 1999                          [anak, indihome, lihat, ]
#
#                                                stemming
# 0     [hai, kak, riya, selamat, akun, layan, indihom...
# 1            [koneksi, stabil, putus, cipayung, jaktim]
# 2     [halo, kak, zaidan, kait, akses, internet, nom...
# 3     [udah, mah, indihome, ngeselin, pagi, duit, gu...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, ecek, sedia, jaring,...
# 1996  [halo, kak, yosah, perihal, pasang, nunik, inf...
# 1997  [halo, kak, internet, mati, kabel, telkom, rum...
# 1998                                             [udah]
# 1999                          [anak, indihome, lihat, ]
#
# [1957 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [hai, kak, riya, selamat, akun, layan, indihom...
# 1            [koneksi, stabil, putus, cipayung, jaktim]
# 2     [halo, kak, zaidan, kait, akses, internet, nom...
# 3     [udah, mah, indihome, ngeselin, pagi, duit, gu...
# 4                                   [indihome, sucks, ]
# ...                                                 ...
# 1995  [ibantu, langsung, kakak, ecek, sedia, jaring,...
# 1996  [halo, kak, yosah, perihal, pasang, nunik, inf...
# 1997  [halo, kak, internet, mati, kabel, telkom, rum...
# 1998                                             [udah]
# 1999                          [anak, indihome, lihat, ]
#
# [1957 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_2.xlsx')
