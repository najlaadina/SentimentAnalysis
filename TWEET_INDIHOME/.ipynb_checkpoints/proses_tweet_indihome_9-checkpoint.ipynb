# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0        Kampret lah Indihome mana mau kuliah lagi gblg
# 1     Indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @IndiHome halo saya mau tanya caranya membatal...
# 4     Kenapa yaa @IndiHome sering sekali memgalami g...
# ...                                                 ...
# 1995  Awet banget main hp buat belajar pakai Indihom...
# 1996  @IndiHomeCare Masa iya segini speednya? Nomor ...
# 1997  @FarahARizcher Gue pake indihome ☹️. Taya pake...
# 1998                       Indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 14

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0        Kampret lah Indihome mana mau kuliah lagi gblg
# 1     Indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @IndiHome halo saya mau tanya caranya membatal...
# 4     Kenapa yaa @IndiHome sering sekali memgalami g...
# ...                                                 ...
# 1995  Awet banget main hp buat belajar pakai Indihom...
# 1996  @IndiHomeCare Masa iya segini speednya? Nomor ...
# 1997  @FarahARizcher Gue pake indihome ☹️. Taya pake...
# 1998                       Indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
# [1974 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @indihome halo saya mau tanya caranya membatal...
# 4     kenapa yaa @indihome sering sekali memgalami g...
# ...                                                 ...
# 1995  awet banget main hp buat belajar pakai indihom...
# 1996  @indihomecare masa iya segini speednya? nomor ...
# 1997  @faraharizcher gue pake indihome ☹️. taya pake...
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
# [1974 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @indihome halo saya mau tanya caranya membatal...
# 4     kenapa yaa @indihome sering sekali memgalami g...
# ...                                                 ...
# 1995  awet banget main hp buat belajar pakai indihom...
# 1996  @indihomecare masa iya segini speednya? nomor ...
# 1997  @faraharizcher gue pake indihome ☹️. taya pake...
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
#                                          cleaning_tweet
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik jaman bat...
# 2     klo indihome gatau yaa aku bayar berapa tpi ki...
# 3     halo saya mau tanya caranya membatalkan paketa...
# 4          kenapa yaa sering sekali memgalami gangguan
# ...                                                 ...
# 1995      awet banget main buat belajar pakai indihome
# 1996     masa iya segini speednya nomor indihome saya
# 1997               gue pake indihome taya pake rep tay
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome firstmedia alias sama  gangguan mulu ...
#
# [1974 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @indihome halo saya mau tanya caranya membatal...
# 4     kenapa yaa @indihome sering sekali memgalami g...
# ...                                                 ...
# 1995  awet banget main hp buat belajar pakai indihom...
# 1996  @indihomecare masa iya segini speednya? nomor ...
# 1997  @faraharizcher gue pake indihome ☹️. taya pake...
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
#                                          cleaning_tweet  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik jaman bat...
# 2     klo indihome gatau yaa aku bayar berapa tpi ki...
# 3     halo saya mau tanya caranya membatalkan paketa...
# 4          kenapa yaa sering sekali memgalami gangguan
# ...                                                 ...
# 1995      awet banget main buat belajar pakai indihome
# 1996     masa iya segini speednya nomor indihome saya
# 1997               gue pake indihome taya pake rep tay
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome firstmedia alias sama  gangguan mulu ...
#
#                                              tokenisasi
# 0     [kampret, lah, indihome, mana, mau, kuliah, la...
# 1     [indihome, mau, bikin, orang, orang, balik, ja...
# 2     [klo, indihome, gatau, yaa, aku, bayar, berapa...
# 3     [halo, saya, mau, tanya, caranya, membatalkan,...
# 4     [kenapa, yaa, sering, sekali, memgalami, gangg...
# ...                                                 ...
# 1995  [awet, banget, main, buat, belajar, pakai, ind...
# 1996  [masa, iya, segini, speednya, nomor, indihome,...
# 1997      [gue, pake, indihome, taya, pake, rep, tay, ]
# 1998                 [indihome, kok, lemot, lagi, ishh]
# 1999  [indihome, firstmedia, alias, sama, gangguan, ...
#
# [1974 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(3000)
# Out:
#                                                 content  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @indihome halo saya mau tanya caranya membatal...
# 4     kenapa yaa @indihome sering sekali memgalami g...
# ...                                                 ...
# 1995  awet banget main hp buat belajar pakai indihom...
# 1996  @indihomecare masa iya segini speednya? nomor ...
# 1997  @faraharizcher gue pake indihome ☹️. taya pake...
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
#                                          cleaning_tweet  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik jaman bat...
# 2     klo indihome gatau yaa aku bayar berapa tpi ki...
# 3     halo saya mau tanya caranya membatalkan paketa...
# 4          kenapa yaa sering sekali memgalami gangguan
# ...                                                 ...
# 1995      awet banget main buat belajar pakai indihome
# 1996     masa iya segini speednya nomor indihome saya
# 1997               gue pake indihome taya pake rep tay
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome firstmedia alias sama  gangguan mulu ...
#
#                                              tokenisasi  \
# 0     [kampret, lah, indihome, mana, mau, kuliah, la...
# 1     [indihome, mau, bikin, orang, orang, balik, ja...
# 2     [klo, indihome, gatau, yaa, aku, bayar, berapa...
# 3     [halo, saya, mau, tanya, caranya, membatalkan,...
# 4     [kenapa, yaa, sering, sekali, memgalami, gangg...
# ...                                                 ...
# 1995  [awet, banget, main, buat, belajar, pakai, ind...
# 1996  [masa, iya, segini, speednya, nomor, indihome,...
# 1997      [gue, pake, indihome, taya, pake, rep, tay, ]
# 1998                 [indihome, kok, lemot, lagi, ishh]
# 1999  [indihome, firstmedia, alias, sama, gangguan, ...
#
#                                                stopword
# 0                     [kampret, indihome, kuliah, gblg]
# 1               [indihome, orang, orang, jaman, batu, ]
# 2     [indihome, gatau, yaa, bayar, tpi, kisaran, ri...
# 3        [halo, membatalkan, paketan, useetv, gimana, ]
# 4                          [yaa, memgalami, gangguan, ]
# ...                                                 ...
# 1995   [awet, banget, main, belajar, pakai, indihome, ]
# 1996         [iya, segini, speednya, nomor, indihome, ]
# 1997                  [gue, indihome, taya, rep, tay, ]
# 1998                            [indihome, lemot, ishh]
# 1999  [indihome, firstmedia, alias, gangguan, mulu, ...
#
# [1974 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3992
# ------------------------
# kampret : kampret
# indihome : indihome
# kuliah : kuliah
# gblg : gblg
# orang : orang
# jaman : jaman
# batu : batu
#  :
# gatau : gatau
# yaa : yaa
# bayar : bayar
# tpi : tpi
# kisaran : kisar
# ribu : ribu
# sma : sma
# pemasangan : pasang
# gratis : gratis
# nder : nder
# masang : masang
# pertengahan : tengah
# dikenakan : kena
# biaya : biaya
# dri : dri
# tergantung : gantung
# halo : halo
# membatalkan : batal
# paketan : paket
# useetv : useetv
# gimana : gimana
# memgalami : memgalami
# gangguan : ganggu
# error : error
# layanannya : layan
# telkomsel : telkomsel
# orbit : orbit
# telkom : telkom
# kanibal : kanibal
# berhenti : henti
# langganan : langgan
# tolong : tolong
# diperbaiki : baik
# please : please
# sort : sort
# the : the
# internet : internet
# out : out
# bandung : bandung
# kids : kids
# need : need
# for : for
# school : school
# aduh : aduh
# siih : siih
# puyeng : puyeng
# kelas : kelas
# jam : jam
# gue : gue
# semalem : semalem
# bangun : bangun
# pagi : pagi
# msh : msh
# menjual : jual
# promo : promo
# wifi : wifi
# seharga : harga
# rp : rp
# dapatkan : dapat
# shopee : shopee
# udah : udah
# mbps : mbps
# lelet : lelet
# tembus : tembus
# engga : engga
# kayanya : kaya
# udahlah : udahlah
# mahal : mahal
# telat : telat
# masuk : masuk
# online : online
# kesiangan : siang
# listrik : listrik
# mati : mati
# lupa : lupa
# salah : salah
# link : link
# dear : dear
# pindah : pindah
# alamat : alamat
# tgl : tgl
# sep : sep
# smpi : smpi
# koneksi : koneksi
# tlp : tlp
# mash : mash
# blm : blm
# konfrm : konfrm
# teknisi : teknisi
# marketingnya : marketingnya
# ttp : ttp
# mohon : mohon
# followupnya : followupnya
# nuhun : nuhun
# pls : pls
# ajg : ajg
# vfmebgmdmf : vfmebgmdmf
# pasang : pasang
# bulanan : bulan
# knapa : knapa
# lgi : lgi
# nomer : nomer
# inet : inet
# september : september
# permintaan : minta
# daring : daring
# anak : anak
# gede : gede
# gua : gua
# dipakai : pakai
# massal : massal
# azhar : azhar
# mslh : mslh
# andry : andry
# njirrr : njirrr
# wkwkkw : wkwkkw
# bmy : bmy
# ngga : ngga
# hatimu : hati
# unduhan : unduh
# data : data
# dayaku : daya
# mencapaimu : capa
# lelah : lelah
# mencintamu : cinta
# menyerah : serah
# lumayan : lumayan
# jaringan : jaring
# kaya : kaya
# hubungan : hubung
# turun : turun
# kadang : kadang
# happy : happy
# nyebelin : nyebelin
# semoga : moga
# cepat : cepat
# diatasi : atas
# kebutuhan : butuh
# hai : hai
# kak : kak
# latifah : latifah
# shiro : shiro
# bantu : bantu
# terkait : kait
# produk : produk
# layanan : layan
# silakan : sila
# informasikan : informasi
# detailnya : detail
# dibantu : bantu
# terima : terima
# kasih : kasih
# malem : malem
# gini : gin
# kosan : kosan
# emang : emang
# diandalkan : andal
# modus : modus
# pembaharuan : baharu
# perangkat : perangkat
# helloooo : helloooo
# sobat : sobat
# cerdas : cerdas
# mudah : mudah
# ditypu : ditypu
# gitu : gitu
# cek : cek
# kebenarannya : benar
# telfon : telfon
# langsung : langsung
# nggak : nggak
# bingung : bingung
# khawatir : khawatir
# keamanan : aman
# rumah : rumah
# smart : smart
# hadir : hadir
# fitur : fitur
# canggih : canggih
# pantau : pantau
# smartphone : smartphone
# aman : aman
# hati : hati
# tenang : tenang
# hay : hay
# belajar : ajar
# asyik : asyik
# nich : nich
# dimana : mana
# bener : bener
# study : study
# pelajar : ajar
# smp : smp
# kangen : kangen
# ganti : ganti
# ssid : ssid
# password : password
# kurangi : kurang
# total : total
# device : device
# akses : akses
# blokir : blokir
# wan : wan
# dikenal : kenal
# done : done
# lemot : lot
# gmn : gmn
# bang : bang
# minggu : minggu
# kemaren : kemaren
# dirumah : rumah
# channel : channel
# connect : connect
# maslah : mas
# ktnya : ktnya
# jarang : jarang
# pakai : pakai
# reset : reset
# ulang : ulang
# kyk : kyk
# hape : hape
# pabrik : pabrik
# min : min
# klw : klw
# dipake : dipake
# jdnya : jdnya
# pung : pung
# lamgganan : lamgganan
# jaringannya : jaring
# rusak : rusak
# sjk : sjk
# kmrn : kmrn
# kek : kek
# dirumh : dirumh
# video : video
# call : call
# yuk : yuk
# layar : layar
# aktifkan : aktif
# mantab : mantab
# pastinya : pasti
# lihat : lihat
# lawan : lawan
# bicara : bicara
# hurup : hurup
# ikutan : ikut
# sufria : sufria
# ando : ando
# hail : hail
# berfungsi : fungsi
# warga : warga
# kabelnya : kabel
# putus : putus
# nomor : nomor
# pelanggan : langgan
# modem : modem
# los : los
# warna : warna
# merah : merah
# hijau : hijau
# internetan : internetan
# efha : efha
# dialami : alami
# tiket : tiket
# diupayakan : upaya
# solved : solved
# berkenan : kenan
# menunggu : tunggu
# progres : progres
# konfirmasi : konfirmasi
# hadi : had
# capture : capture
# tampilan : tampil
# tindaklanjuti : tindaklanjuti
# atam : atam
# ganguan : ganguan
# champions : champions
# skrng : skrng
# udhgaada : udhgaada
# chelsea : chelsea
# kalah : kalah
# senggol : senggol
# today : today
# sumpah : sumpah
# luh : luh
# bapuk : bapuk
# bat : bat
# unistall : unistall
# donlot : donlot
# sampah : sampah
# bangsat : bangsat
# doang : doang
# kualitas : kualitas
# balikin : balikin
# vidio : vidio
# usee : usee
# kopet : kopet
# kye : kye
# pisan : pis
# golek : golek
# streaming : streaming
# payah : payah
# partai : partai
# ucl : ucl
# jelek : jelek
# bangettt : bangettt
# nnti : nnti
# duit : duit
# dperumahan : dperumahan
# dalem : dalem
# kmplek : kmplek
# rumh : rumh
# butuh : butuh
# pager : pager
# menghalangi : halang
# keindahan : indah
# bngunn : bngunn
# penyedia : sedia
# aneh : aneh
# cmn : cmn
# gaada : gaada
# pilihan : pilih
# upload : upload
# speed : speed
# parah : parah
# maaf : maaf
# crash : crash
# kentang : kentang
# sinyal : sinyal
# kntl : kntl
# woy : woy
# upgrade : upgrade
# tagihnnya : tagihnnya
# make : make
# org : org
# udh : udh
# didapet : didapet
# downloadnya : downloadnya
# uploadnya : uploadnya
# dikit : dikit
# harga : harga
# uploadny : uploadny
# fupnya : fupnya
# nonton : nonton
# restart : restart
# debu : debu
# alias : alias
# jancuk : jancuk
# ono : ono
# sinyale : sinyale
# ngertia : ngertia
# tku : tku
# kartu : kartu
# internetnya : internetnya
# cover : cover
# tamaaa : tamaaa
# tama : tama
# ansyah : ansyah
# sarankan : saran
# download : download
# aplikasinya : aplikasi
# gig : gig
# biznet : biznet
# daerah : daerah
# blom : blom
# tercover : tercover
# rep : rep
# chat : chat
# read : read
# dih : dih
# trs : trs
# skrg : skrg
# gabisa : gabisa
# konek : konek
# bagus : bagus
# dongg : dongg
# pinter : pinter
# harapannya : harap
# nyaman : nyaman
# paket : paket
# mesti : mesti
# sans : sans
# offcam : offcam
# gajelas : gajelas
# tar : tar
# molor : molor
# danny : danny
# kakak : kakak
# netflix : netflix
# tablet : tablet
# laptop : laptop
# disaksikan : saksi
# browser : browser
# stb : stb
# indibox : indibox
# subhanallord : subhanallord
# family : family
# paid : paid
# connection : connection
# not : not
# you : you
# test : test
# our : our
# patience : patience
# bola : bola
# jink : jink
# sinyalnya : sinyal
# dibenerin : dibenerin
# kompleks : kompleks
# cibinong : cibinong
# dapet : dapet
# menyusahkan : susah
# gapunya : gapunya
# kuota : kuota
# teroos : teroos
# marah : marah
# ngab : ngab
# kesel : kesel
# plis : plis
# kemarin : kemarin
# bermasalah : masalah
# bersalah : salah
# banget : banget
# enak : enak
# emma : emma
# tidur : tidur
# ngambek : ngambek
# lemotnya : lot
# kakon : kakon
# mode : mode
# hallo : hallo
# meredhian : meredhian
# ketidaknyamanannya : ketidaknyamanannya
# menginformasikan : informasi
# ponsel : ponsel
# aktifnya : aktif
# mempermudah : mudah
# pengecekan : kece
# iga : iga
# bayangin : bayangin
# maen : maen
# pokemon : pokemon
# unite : unite
# gegara : gegara
# kawan : kawan
# indintol : indintol
# kontol : kontol
# duh : duh
# anjg : anjg
# ksl : ksl
# bgtt : bgtt
# digital : digital
# rb : rb
# perbulan : bulan
# mafia : mafia
# ikan : ikan
# hiu : hiu
# sukanya : suka
# kabel : kabel
# ter : ter
# debest : debest
# buka : buka
# safari : safari
# kaga : kaga
# kuat : kuat
# najis : najis
# care : care
# bahas : bahas
# fiber : fiber
# optik : optik
# pengertian : erti
# beserta : serta
# fungsinya : fungsi
# simak : simak
# serius : serius
# amuk : amuk
# buron : buron
# ngadat : ngadat
# ngeselin : ngeselin
# janji : janji
# difollow : difollow
# tong : tong
# kosong : kosong
# nyaring : nyaring
# bunyinya : bunyi
# viralin : viralin
# nugas : nugas
# males : males
# inndy : inndy
# iya : iya
# dosa : dosa
# mencuri : curi
# iklas : iklas
# berlindung : lindung
# yaelah : yaelah
# cuman : cuman
# pelit : pelit
# pdhl : pdhl
# ramean : ramean
# rumahan : rumah
# murah : murah
# sebulan : bulan
# ditempatku : tempat
# knp : knp
# suka : suka
# loss : loss
# abis : abis
# deh : deh
# maunya : mau
# lancar : lancar
# pengen : ken
# darah : darah
# didm : didm
# status : status
# masi : mas
# heleh : heleh
# omongannya : omong
# manis : manis
# kya : kya
# pdktan : pdktan
# youtube : youtube
# loading : loading
# play : play
# suipaaa : suipaaa
# senang : senang
# mendengar : dengar
# kabar : kabar
# baiknya : baik
# selamat : selamat
# menikmati : nikmat
# stay : stay
# safe : safe
# healthy : healthy
# yudho : yudho
# dibuatkan : buat
# laporan : lapor
# pengaduan : adu
# telpon : telpon
# direstart : direstart
# modemnya : modem
# berulang : ulang
# kali : kali
# identitas : identitas
# pemilik : milik
# dibalas : balas
# kirim : kirim
# petugas : tugas
# memperbaiki : baik
# secepatnya : cepat
# mhy : mhy
# mkanya : mkanya
# ngirim : ngirim
# rewardny : rewardny
# pitam : pitam
# monyet : monyet
# first : first
# media : media
# cptt : cptt
# tnggung : tnggung
# jwap : jwap
# nylakan : nylakan
# rmh : rmh
# mskipun : mskipun
# bkn : bkn
# ulahmu : ulah
# pkknya : pkknya
# lad : lad
# butut : butut
# indomaret : indomaret
# indosat : indosat
# indomie : indomie
# indo : indo
# laen : laen
# emg : emg
# nad : nad
# wahooo : wahooo
# rese : rese
# kebiasaan : biasa
# segini : gin
# eror : eror
# mulu : mulu
# ngentot : ngentot
# childe : childe
# cok : cok
# diajak : ajak
# kerja : kerja
# kerjaan : kerja
# kelar : kelar
# ngelag : ngelag
# elah : elah
# drakor : drakor
# viu : viu
# betah : betah
# harshwords : harshwords
# see : see
# user : user
# cctv : cctv
# siaran : siar
# kayak : kayak
# milih : milih
# manggil : manggil
# abang : abang
# fix : fix
# this : this
# nangis : nang
# teriak : teriak
# anjing : anjing
# grgr : grgr
# drpd : drpd
# provider : provider
# digigit : gigit
# definisi : definisi
# benci : benci
# lepas : lepas
# awww : awww
# toxic : toxic
# relationship : relationship
# chin : chin
# home : home
# gasi : gas
# wakakakaa : wakakakaa
# ayo : ayo
# anjenkk : anjenkk
# btw : btw
# wifinya : wifinya
# sebenernya : sebenernya
# yeesss : yeesss
# wib : wib
# lokasi : lokasi
# sebelah : belah
# siang : siang
# sore : sore
# lambat : lambat
# kaxau : kaxau
# tlkm : tlkm
# temen : temen
# bentuk : bentuk
# aura : aura
# rajin : rajin
# ibadah : ibadah
# islam : islam
# tunaikan : tunai
# kewajiban : wajib
# skincare : skincare
# air : air
# wudhu : wudhu
# percaya : percaya
# gays : gays
# ngulah : ngulah
# pas : pas
# soft : soft
# hour : hour
# sakit : sakit
# gblk : gblk
# ngapa : ngapa
# anjeng : anjeng
# acha : acha
# galau : galau
# karna : karna
# pacarnya : pacar
# diculik : culik
# terkoneksi : koneksi
# perbaiki : baik
# masalahny : masalahny
# siram : siram
# foto : foto
# base : base
# keduluan : keduluan
# mrasa : mrasa
# dosen : dosen
# ngajar : ngajar
# trus : trus
# share : share
# slideshow : slideshow
# wakwkwkw : wakwkwkw
# kebalikannya : balik
# tumben : tumben
# bingit : bingit
# and : and
# still : still
# counting : counting
# ngomong : ngomong
# central : central
# perkembangan : kembang
# router : router
# banting : banting
# smk : smk
# bobol : bobol
# windows : windows
# diketawain : diketawain
# diharapkan : harap
# bayangkan : bayang
# kamar : kamar
# kos : kos
# ditunggu : tunggu
# spotv : spotv
# jele : jele
# sie : sie
# dni : dni
# daftarnya : daftar
# sulit : sulit
# dipersulit : sulit
# gara : gara
# copot : copot
# tvnya : tvnya
# pakein : pakein
# stbbox : stbbox
# disney : disney
# hotstar : hotstar
# hbored : hbored
# allah : allah
# nothing : nothing
# asli : asli
# bantuannya : bantu
# wilayah : wilayah
# desa : desa
# panggoi : panggoi
# muara : muara
# lhokseumawe : lhokseumawe
# aceh : aceh
# pke : pke
# bjxbsjsjjzjsjja : bjxbsjsjjzjsjja
# sgla : sgla
# jnis : jnis
# pnipuan : pnipuan
# mngatasnmkan : mngatasnmkan
# indonesia : indonesia
# mndptkn : mndptkn
# telepon : telepon
# dtg : dtg
# mengaku : aku
# kmu : kmu
# knl : knl
# kmudian : kmudian
# mmksa : mmksa
# mminta : mminta
# byrn : byrn
# mngmbil : mngmbil
# prngkt : prngkt
# ont : ont
# mngdukan : mngdukan
# lgsg : lgsg
# susah : susah
# pending : pending
# berantem : antem
# riasp : riasp
# sich : sich
# liat : liat
# story : story
# nge : nge
# blur : blur
# dihalo : halo
# zira : zira
# sucks : sucks
# asss : asss
# what : what
# fuckkk : fuckkk
# lola : lola
# gaes : gaes
# fakta : fakta
# menarik : tarik
# dunia : dunia
# game : game
# mobile : mobile
# league : league
# legend : legend
# pemerintah : perintah
# memasukan : pasu
# cabang : cabang
# olahraga : olahraga
# nasional : nasional
# didukung : dukung
# gamer : gamer
# okt : okt
# kompensasi : kompensasi
# spt : spt
# pemotongan : potong
# berlangganan : langgan
# merugikan : rugi
# full : full
# pekan : pekan
# uts : uts
# keanya : keanya
# rumahku : rumah
# sengebut : ngebut
# hadu : hadu
# naikin : naikin
# mending : mending
# cepet : cepet
# benerin : benerin
# sihh : sihh
# kamuuu : kamuuu
# sadar : sadar
# ilang : ilang
# pemeliharaan : pelihara
# info : info
# mah : mah
# namanya : nama
# termudah : mudah
# menghadapi : hadap
# komplen : komplen
# customer : customer
# review : review
# kucari : cari
# bangke : bangke
# abisan : abis
# tetangga : tetangga
# terputus : putus
# serumah : rumah
# nyambung : nyambung
# hubungi : hubung
# staff : staff
# dicheck : dicheck
# berubah : ubah
# merubah : rubah
# elbert : elbert
# ervien : ervien
# informasi : informasi
# dikeluhkan : keluh
# via : via
# kaget : kaget
# explain : explain
# shit : shit
# musuh : musuh
# beragam : agam
# rinciannya : rinciannya
# bun : bun
# ngapesi : ngapesi
# wkwkwk : wkwkwk
# hahaha : hahaha
# krena : krena
# prnah : prnah
# coba : coba
# slebeeewww : slebeeewww
# siiiieeeee : siiiieeeee
# dipercaya : percaya
# saksi : saksi
# kejadian : jadi
# penasaran : penasaran
# uda : uda
# gabs : gabs
# ditahan : tahan
# hantu : hantu
# terang : terang
# anti : anti
# sosial : sosial
# hassleblad : hassleblad
# kamera : kamera
# beresolusi : resolusi
# caper : caper
# didepan : depan
# ank : ank
# smua : smua
# leg : leg
# rumaha : rumaha
# kau : kau
# komplenan : komplenan
# haa : haa
# perhatikan : perhati
# costumer : costumer
# service : service
# mek : mek
# napa : napa
# indigo : indigo
# alarm : alarm
# power : power
# improve : improve
# load : load
# image : image
# muk : muk
# nngs : nngs
# sjj : sjj
# bnr : bnr
# awl : awl
# bln : bln
# bgs : bgs
# bismillah : bismillah
# sgt : sgt
# psng : psng
# slncr : slncr
# bab : bab
# punteun : punteun
# moots : moots
# jugaaaa : jugaaaa
# nanyaa : nanyaa
# disaat : saat
# dpt : dpt
# mood : mood
# disitulah : situ
# ajig : ajig
# aing : aing
# ngambis : ngambis
# goublooooo : goublooooo
# gamas : gamas
# lok : lok
# kalimalang : kalimalang
# jakarta : jakarta
# timur : timur
# gjls : gjls
# jujur : jujur
# wkwkk : wkwkk
# jdi : jdi
# auto : auto
# inget : inget
# jogja : jogja
# pengg : pengg
# bobrok : bobrok
# ampe : ampe
# trending : trending
# twiter : twiter
# untung : untung
# zoom : zoom
# posisi : posisi
# kaki : kaki
# gunung : gunung
# gasuka : gasuka
# admin : admin
# labrak : labrak
# mas : mas
# sol : sol
# setia : setia
# suporter : suporter
# novi : novi
# ohmi : ohm
# kecepatan : cepat
# ribet : ribet
# koneksinya : koneksi
# ceklis : ceklis
# kah : kah
# maniez : maniez
# bales : bales
# bot : bot
# twitter : twitter
# slow : slow
# respon : respon
# bedanya : beda
# ngemodal : ngemodal
# dibikin : bikin
# cabut : cabut
# sabar : sabar
# indihum : indihum
# twt : twt
# dritdi : dritdi
# allahu : allahu
# msih : msih
# benerkah : benerkah
# ato : ato
# ajsgdahaksbsjskbx : ajsgdahaksbsjskbx
# bomat : bomat
# iconnet : iconnet
# belumsi : belumsi
# satrya : satrya
# dipertimbangkan : timbang
# khawatirkan : khawatir
# tersediaanya : tersediaanya
# odp : odp
# nyolong : nyolong
# gabung : gabung
# bisnis : bisnis
# jual : jual
# followers : followers
# penghasilannya : hasil
# beli : beli
# gedung : gedung
# minat : minat
# nitipp : nitipp
# kumat : kumat
# genshin : genshin
# kasian : kasi
# stop : stop
# update : update
# tri : tri
# membagi : bagi
# bandwidth : bandwidth
# mikrotik : mikrotik
# dual : dual
# sim : sim
# hpnya : hpnya
# whatsapp : whatsapp
# iki : iki
# embuh : embuh
# blas : blas
# diacak : acak
# mbooottt : mbooottt
# malam : malam
# ganggu : ganggu
# cenderung : cenderung
# isolir : isolir
# pertanggungjawabannya : pertanggungjawabannya
# gasanggup : gasanggup
# kntoooolllll : kntoooolllll
# when : when
# cerita : cerita
# ngomongin : ngomongin
# knffh : knffh
# lancarnya : lancar
# chek : chek
# lampu : lampu
# berwarna : warna
# heammmm : heammmm
# yaaa : yaaa
# halooo : halooo
# lho : lho
# hemmmm : hemmmm
# cape : cape
# pengguna : guna
# bgkrutt : bgkrutt
# ama : ama
# lag : lag
# apaa : apaa
# yak : yak
# check : check
# refresh : refresh
# pusat : pusat
# tdi : tdi
# memiliki : milik
# gelut : gelut
# mengijinkan : mengijinkan
# gamake : gamake
# taiiiiiiiiiii : taiiiiiiiiiii
# ibab : ibab
# ares : ares
# pushrank : pushrank
# order : order
# tracking : tracking
# selesai : selesai
# proses : proses
# instalasi : instalasi
# statusnya : status
# non : non
# aktif : aktif
# menghubungi : hubung
# emosi : emosi
# jueleeekkk : jueleeekkk
# evalusi : evalusi
# hadoooooooooohhhhhh : hadoooooooooohhhhhh
# berbeda : beda
# balance : balance
# swasta : swasta
# peraturan : atur
# perusahaan : usaha
# jaminan : jamin
# kenyamanan : nyaman
# kuotaaa : kuotaaa
# dinosaurus : dinosaurus
# keless : keless
# perasaan : asa
# fast : fast
# jaya : jaya
# sik : sik
# wta : wta
# emng : emng
# premier : premier
# ver : ver
# pny : pny
# indihom : indihom
# logout : logout
# menit : menit
# ampun : ampun
# hadeh : hadeh
# gag : gag
# kayaknya : kayak
# perbaikan : baik
# disuruh : suruh
# berulah : ulah
# konser : konser
# karaoke : karaoke
# demand : demand
# keluarga : keluarga
# astagfirullah : astagfirullah
# sampe : sampe
# iwak : iwak
# kendala : kendala
# dicek : cek
# keluhannya : keluh
# mengalami : alami
# lemper : lemper
# tagihan : tagih
# uprage : uprage
# edan : edan
# exam : exam
# pearson : pearson
# vue : vue
# recording : recording
# guah : guah
# argh : argh
# hate : hate
# ngajak : ngajak
# ribut : ribut
# inspirasi : inspirasi
# wkkwkw : wkkwkw
# dikantor : kantor
# kantor : kantor
# serem : rem
# gelap : gelap
# kotor : kotor
# gtu : gtu
# ruko : ruko
# sempet : sempet
# dibersihin : dibersihin
# kebelet : kebelet
# pipis : pipis
# bnget : bnget
# blg : blg
# jen : jen
# ditoilet : toilet
# anker : anker
# bersih : bersih
# cont : cont
# kebuang : buang
# sia : sia
# tolonglah : tolong
# terganggu : ganggu
# kuwi : kuwi
# rak : rak
# disconnect : disconnect
# ngeliat : ngeliat
# routernya : routernya
# nyala : nyala
# terimakasih : terimakasih
# hello : hello
# nice : nice
# meet : meet
# too : too
# depends : depends
# where : where
# live : live
# tbh : tbh
# currently : currently
# using : using
# called : called
# its : its
# already : already
# enough : enough
# only : only
# that : that
# available : available
# place : place
# oke : oke
# nas : nas
# nanya : nanya
# cpt : cpt
# naudzubillah : naudzubillah
# ancur : ancur
# anying : anying
# sahabat : sahabat
# besok : besok
# fox : fox
# channels : channels
# resmi : resmi
# ditutup : tutup
# junior : junior
# national : national
# geographic : geographic
# wild : wild
# people : people
# foxcrime : foxcrime
# foxlife : foxlife
# star : star
# chinese : chinese
# muggle : muggle
# kpoppies : kpoppies
# indijib : indijib
# indiheol : indiheol
# mihoyo : mihoyo
# bala : bala
# anjirrrrrr : anjirrrrrr
# petunjuk : tunjuk
# ngecun : ngecun
# smaa : smaa
# trisom : trisom
# aamiin : aamiin
# hahahahahhaha : hahahahahhaha
# igoyy : igoyy
# cocok : cocok
# marketing : marketing
# capek : capek
# anas : anas
# polos : polos
# bngt : bngt
# baju : baju
# warung : warung
# telphone : telphone
# normal : normal
# telponnya : telpon
# pesan : pesan
# melunasin : melunasin
# dipasang : pasang
# nie : nie
# huhu : huhu
# sumpainn : sumpainn
# niiiii : niiiii
# searching : searching
# berbayar : bayar
# request : request
# dibuka : buka
# kebuka : buka
# dhan : dhan
# dhaniswara : dhaniswara
# pengurang : kurang
# open : open
# all : all
# myrepblc : myrepblc
# trble : trble
# persona : persona
# pesimis : pesimis
# wts : wts
# daritadi : daritadi
# jalan : jalan
# samsek : samsek
# ads : ads
# ichamp : ichamp
# apapun : apa
# melayani : layan
# registrasi : registrasi
# area : area
# barat : barat
# cafe : cafe
# warkop : warkop
# kontrakan : kontra
# kostan : kostan
# meninggalkan : tinggal
# denger : denger
# konpensasi : konpensasi
# diselesaikan : selesai
# permasalahan : masalah
# larangan : larang
# sayang : sayang
# wrong : wrong
# with : with
# bawaan : bawa
# memilih : pilih
# salam : salam
# yogyakarta : yogyakarta
# dibayarkan : bayar
# terpasang : pasang
# pembayaran : bayar
# atm : atm
# banking : banking
# minimarket : minimarket
# alfamart : alfamart
# commerce : commerce
# tokopedia : tokopedia
# loket : loket
# terhormat : hormat
# tanggal : tanggal
# agustus : agustus
# ppn : ppn
# uang : uang
# seting : ting
# regional : regional
# depok : depok
# stabil : stabil
# maintance : maintance
# kacau : kacau
# dirasani : rasan
# jare : jare
# nguneke : nguneke
# melu : melu
# ewu : ewu
# pertanyaaan : pertanyaaan
# laut : laut
# jasuka : jasuka
# cashback : cashback
# membayar : bayar
# astaghfirullah : astaghfirullah
# jlek : jlek
# hahahahahaha : hahahahahaha
# takut : takut
# seumur : umur
# umur : umur
# ngeri : ngeri
# fandom : fandom
# kasi : kasi
# bintang : bintang
# pass : pass
# gimanasi : gimanasi
# ikutin : ikutin
# gugel : gugel
# ngeleg : ngeleg
# seminggu : minggu
# cause : cause
# entertaining : entertaining
# but : but
# also : also
# edit : edit
# team : team
# they : they
# even : even
# used : used
# meme : meme
# before : before
# agus : agus
# fess : fess
# sii : sii
# tia : tia
# troublenya : troublenya
# ocaa : ocaa
# benerr : benerr
# sembuhnya : sembuh
# iniii : iniii
# wifiii : wifiii
# sayaaa : sayaaa
# bmst : bmst
# zell : zell
# agenda : agenda
# rutin : rutin
# kebangkitan : bangkit
# pki : pki
# ketinggalan : tinggal
# menteri : menteri
# hyper : hyper
# experimenting : experimenting
# pembelajaran : ajar
# tatap : tatap
# muka : muka
# kunjung : kunjung
# terlaksana : laksana
# selengkapnya : lengkap
# goblok : goblok
# ngahambat : ngahambat
# berasa : asa
# kualat : kualat
# ngetawain : ngetawain
# xlhome : xlhome
# bgttt : bgttt
# keliatan : liat
# berkali : kali
# dimaafkan : maaf
# hmmm : hmmm
# masal : masal
# dng : dng
# in : in
# yan : yan
# trims : trims
# cinta : cinta
# kpdmu : kpdmu
# woi : woi
# gbs : gbs
# ksel : ksel
# nikmatin : nikmatin
# muter : muter
# cerei : cere
# kakk : kakk
# inii : ini
# duren : duren
# sawit : sawit
# mksh : mksh
# infonya : info
# kenapaaa : kenapaaa
# bsa : bsa
# bacanya : baca
# telp : telp
# komplain : komplain
# gema : gema
# speedy : speedy
# ngk : ngk
# dididik : didik
# taik : taik
# firstmedia : firstmedia
# mamang : mamang
# rela : rela
# manjat : manjat
# meja : meja
# kursi : kursi
# deketin : deketin
# usaha : usaha
# jatuh : jatuh
# hadilnya : hadilnya
# tetep : tetep
# begimandos : begimandos
# penyebab : sebab
# jga : jga
# kind : kind
# sus : sus
# indihoe : indihoe
# sorry : sorry
# oot : oot
# mola : mola
# nyasama : nyasama
# segi : segi
# spotify : spotify
# billboard : billboard
# itunes : itunes
# lisa : lisa
# mimpin : mimpin
# mbak : mbak
# diakses : akses
# kaye : kaye
# gianne : gianne
# stress : stress
# anjrit : anjrit
# bgsd : bgsd
# gada : gada
# tlng : tlng
# mengajukan : aju
# aplikasi : aplikasi
# istg : istg
# laggggg : laggggg
# robiyanto : robiyanto
# down : down
# taaaaa : taaaaa
# gataulah : gataulah
# diproses : proses
# pengajuan : aju
# pemberhentian : henti
# giniii : giniii
# sialannnn : sialannnn
# pda : pda
# usus : usus
# lait : lait
# ipung : ipung
# rady : rady
# mengerti : erti
# pelaporan : lapor
# ketersediaan : sedia
# gummy : gummy
# ingih : ingih
# migrasi : migrasi
# indikasi : indikasi
# perbaiakan : perbaiakan
# sehat : sehat
# drtd : drtd
# yaallah : yaallah
# have : have
# lot : lot
# college : college
# task : task
# disabarin : disabarin
# akibat : akibat
# disconected : disconected
# sekolah : sekolah
# pekerjaan : kerja
# lapor : lapor
# makasi : makas
# rekii : rekii
# lebaran : lebaran
# gaperna : gaperna
# maafin : maafin
# komunikasi : komunikasi
# alasan : alas
# kompetitif : kompetitif
# tawari : tawar
# mencoba : coba
# menyala : nyala
# morris : morris
# makan : makan
# signal : signal
# lulus : lulus
# squid : squid
# mamak : mamak
# mertuaku : mertua
# manyun : manyun
# tabiatnya : tabiat
# wooow : wooow
# konsumen : konsumen
# iyalah : iya
# ngeluh : ngeluh
# guys : guys
# tagihannya : tagih
# berkurang : kurang
# janchuk : janchuk
# aseli : aseli
# pler : pler
# biasalah : biasa
# ldr : ldr
# life : life
# berjam : jam
# plus : plus
# uji : uji
# kena : kena
# prank : prank
# hujan : hujan
# kasihan : kasihan
# sayangku : sayang
# gantinya : ganti
# apaaaaaa : apaaaaaa
# asik : asik
# scroll : scroll
# hany : hany
# ucapkan : ucap
# healty : healty
# triya : triya
# sbar : sbar
# dlu : dlu
# maap : maap
# suudzon : suudzon
# bapa : bapa
# matiin : matiin
# dinyalain : dinyalain
# ujan : ujan
# kombinasi : kombinasi
# tua : tua
# indome : indome
# penanganan : tangan
# cepatnya : cepat
# berharap : harap
# kedepannya : depan
# menganggu : menganggu
# semangat : semangat
# pegawai : pegawai
# membantu : bantu
# benernya : benernya
# emosiii : emosiii
# perihal : perihal
# keluhan : keluh
# saudara : saudara
# silahkan : silah
# struk : struk
# terahir : terahir
# mimin : mimin
# sebel : sebel
# yaampun : yaampun
# maa : maa
# nelpon : nelpon
# dateng : dateng
# keringanan : ringan
# program : program
# pembukaan : buka
# undlap : undlap
# undlup : undlup
# kirain : kirain
# cso : cso
# ketidaknyamanan : ketidaknyamanan
# bersabar : sabar
# latihan : latih
# ikhlas : ikhlas
# bajeng : bajeng
# ngebug : ngebug
# terooooss : terooooss
# anjer : anjer
# indihomo : indihomo
# nggudo : nggudo
# jiwa : jiwa
# ancen : ancen
# dino : dino
# ngena : ngena
# ngeneae : ngeneae
# cant : cant
# relate : relate
# wkwkw : wkwkw
# literal : literal
# definition : definition
# perang : perang
# digebug : digebug
# nyambut : nyambut
# episode : episode
# spesial : spesial
# sharing : sharing
# session : session
# perjalanan : jalan
# rekrutmen : rekrutmen
# facebook : facebook
# jic : jic
# gapake : gapake
# dunks : dunks
# ditindak : tindak
# lanjuti : lanjut
# center : center
# bilangnya : bilang
# nontonin : nontonin
# dedek : dedek
# bayi : bayi
# main : main
# balo : balo
# waras : waras
# sek : sek
# papua : papua
# makasih : makasih
# lte : lte
# problem : problem
# sel : sel
# ttap : ttap
# fight : fight
# server : server
# genshinnya : genshinnya
# feedback : feedback
# tindak : tindak
# wujudnya : wujud
# pecut : pecut
# saking : saking
# yok : yok
# bumn : bumn
# bangsad : bangsad
# mokad : mokad
# komisaris : komisaris
# pembuat : buat
# kebijakannya : bijak
# paketaaan : paketaaan
# perbaikannya : baik
# penggantian : ganti
# remote : remote
# kang : kang
# sibuk : sibuk
# nii : nii
# pdahal : pdahal
# mumpung : mumpung
# ngebangsat : ngebangsat
# kubantu : bantu
# tae : tae
# hah : hah
# tyo : tyo
# vandi : vandi
# kesediaan : sedia
# prosesnya : proses
# tersolusikan : solusi
# expres : expres
# pliisss : pliisss
# habis : habis
# nemu : nemu
# jahat : jahat
# lahir : lahir
# responnya : responnya
# keempat : empat
# judul : judul
# seri : seri
# monolog : monolog
# tepi : tepi
# sejarah : sejarah
# tayang : tayang
# oktober : oktober
# channelnya : channelnya
# temuan : temu
# rock : rock
# entertainment : entertainment
# law : law
# svu : svu
# musim : musim
# terbaru : baru
# kyknya : kyknya
# extreme : extreme
# wisecrack : wisecrack
# ulasan : ulas
# film : film
# hitz : hitz
# three : three
# company : company
# little : little
# house : house
# praire : praire
# gangerti : gangerti
# operator : operator
# suruh : suruh
# tailah : tailah
# sabarin : sabarin
# ngelunjak : ngelunjak
# kaliwungu : kaliwungu
# ushankas : ushankas
# off : off
# baikan : baik
# kyai : kyai
# patt : patt
# infokan : info
# sebegai : bega
# gambar : gambar
# menerus : terus
# ditinjau : tinjau
# selatan : selatan
# jawa : jawa
# pucang : pucang
# gading : gading
# mranggen : mranggen
# trouble : trouble
# kemarenan : kemarenan
# jumat : jumat
# sabtu : sabtu
# deres : deres
# ade : ade
# nyebut : nyebut
# nama : nama
# gakenal : gakenal
# gausah : gausah
# noh : noh
# rawa : rawa
# menguras : uras
# emosii : emosi
# masib : masib
# indiehome : indiehome
# kedip : kedip
# pelayanan : layan
# gmmtv : gmmtv
# twit : twit
# dsn : dsn
# komen : komen
# wktu : wktu
# yas : yas
# tadii : tadi
# keknya : kek
# diapa : apa
# apain : apain
# koordinasi : koordinasi
# ngecatet : ngecatet
# akun : akun
# indihomenya : indihomenya
# sekian : sekian
# zzzz : zzzz
# lampunya : lampu
# nyaal : nyaal
# berhasil : hasil
# ngegas : ngegas
# perkara : perkara
# tiada : tiada
# berputar : putar
# sayuti : sayuti
# zayn : zayn
# isoliran : isolir
# dicoba : coba
# tunggu : tunggu
# oxgen : oxgen
# camera : camera
# produksi : produksi
# tdak : tdak
# jancok : jancok
# kerek : kerek
# babi : babi
# mbot : mbot
# pantek : pantek
# cibai : cibai
# bungul : bungul
# memek : memek
# pepek : pepek
# taek : taek
# aduuuuueh : aduuuuueh
# speedtest : speedtest
# cuy : cuy
# kegiatan : giat
# covid : covid
# andalan : andal
# genting : genting
# woyyyy : woyyyy
# tsel : tsel
# ditambah : tambah
# your : your
# network : network
# pay : pay
# month : month
# subscribe : subscribe
# spend : spend
# gb : gb
# because : because
# unstable : unstable
# often : often
# unusable : unusable
# nntn : nntn
# salahh : salahh
# ketidaknyamananya : ketidaknyamananya
# kendalanya : kendala
# upayakan : upaya
# terealisasi : realisasi
# ingi : ingi
# mengontol : kontol
# liatin : liatin
# numpang : numpang
# ahelah : ahelah
# anjerrr : anjerrr
# pngn : pngn
# kebantu : bantu
# niatan : niat
# takit : takit
# bershabat : bershabat
# drumah : drumah
# yaww : yaww
# penggantinya : ganti
# lucu : lucu
# sekategori : kategori
# berfokus : fokus
# terbaik : baik
# berangsur : angsur
# pulih : pulih
# kecewa : kecewa
# move : move
# giliran : gilir
# aduan : adu
# tanggepin : tanggepin
# blank : blank
# bayarnya : bayar
# hrs : hrs
# dinikmati : nikmat
# mampus : mampus
# kehilangan : hilang
# setianya : setia
# like : like
# wth : wth
# anjrittt : anjrittt
# astagaaa : astagaaa
# bntr : bntr
# sinting : sinting
# pgn : pgn
# tampar : tampar
# cariin : cariin
# golongan : golong
# based : based
# tonight : tonight
# riot : riot
# titik : titik
# terpantau : pantau
# berbarengan : bareng
# televisi : televisi
# terjangkau : jangkau
# plat : plat
# tbtb : tbtb
# nganu : nganu
# bisnet : bisnet
# karma : karma
# tungguin : tungguin
# sedihhhh : sedihhhh
# ajak : ajak
# ketemuan : ketemu
# wid : wid
# karo : karo
# ngopo : ngopo
# demiapasih : demiapasih
# nyabu : nyabu
# gamau : gamau
# malas : malas
# perjuangan : juang
# terhubung : hubung
# hey : hey
# tim : tim
# gajinya : gaji
# umr : umr
# plsksjwjdjw : plsksjwjdjw
# bewan : bewan
# buffering : buffering
# teroosssssss : teroosssssss
# habisnya : habis
# tlg : tlg
# anjayy : anjayy
# rasaa : rasaa
# baruu : baruu
# oknum : oknum
# menyalurkan : salur
# lwt : lwt
# pribadi : pribadi
# utama : utama
# mayalahi : mayalahi
# aturan : atur
# mreka : mreka
# slot : slot
# penuh : penuh
# memutus : putus
# kota : kota
# makassar : makassar
# belom : bom
# pelayanannya : layan
# sedih : sedih
# free : free
# practice : practice
# race : race
# haram : haram
# jadah : jadah
# soto : soto
# bedaa : bedaa
# random : random
# turnamen : turnamen
# dota : dota
# buset : buset
# ciri : ciri
# masokis : masokis
# dep : dep
# seputar : putar
# sungkan : sungkan
# sehhhh : sehhhh
# bunyi : bunyi
# klik : klik
# merahnya : merah
# kasusnya : kasus
# wani : wani
# behujung : behujung
# hidup : hidup
# plzz : plzz
# dahhh : dahhh
# ngerjainn : ngerjainn
# tugass : tugass
# plz : plz
# terlamjur : terlamjur
# bersahabatlah : sahabat
# denganku : dengan
# ngarepin : ngarepin
# apaansihhh : apaansihhh
# makalah : makalah
# kemana : mana
# mengadu : adu
# wkwkwkwk : wkwkwkwk
# apliaksi : apliaksi
# siii : siii
# hahahahaha : hahahahaha
# bantuan : bantu
# hilang : hilang
# jln : jln
# dimun : dimun
# cilodong : cilodong
# tampu : tampu
# matot : matot
# tolol : tolol
# capturing : capturing
# mountain : mountain
# pulau : pulau
# sumatera : sumatera
# alam : alam
# gunungnya : gunung
# sinabung : sabung
# terletak : letak
# meletus : letus
# terpungkiri : terpungkiri
# indah : indah
# potret : potret
# gelo : gelo
# nyak : nyak
# ppppp : ppppp
# netlix : netlix
# login : login
# kaka : kaka
# mmr : mmr
# minus : minus
# wkakkk : wkakkk
# super : super
# duper : duper
# basic : basic
# lantai : lantai
# tembok : tembok
# concrete : concrete
# wassalam : wassalam
# responding : responding
# thx : thx
# adminnya : adminnya
# gaji : gaji
# direspon : direspon
# mantap : mantap
# pegel : gel
# slain : slain
# plssss : plssss
# legends : legends
# garena : garena
# dibetulin : dibetulin
# nyoba : nyoba
# nordvpn : nordvpn
# plsss : plsss
# help : help
# shezzar : shezzar
# kyl : kyl
# tiang : tiang
# hitam : hitam
# didekat : dekat
# rumahmu : rumah
# body : body
# menentukan : tentu
# brp : brp
# byk : byk
# rugi : rugi
# parsh : parsh
# wkwwkkwk : wkwwkkwk
# dibayar : bayar
# knpa : knpa
# nihh : nihh
# indikator : indikator
# sos : sos
# kelap : kelap
# kelip : kelip
# disco : disco
# bolak : bolak
# hasil : hasil
# matur : matur
# suwun : suwun
# tebak : tebak
# terinspirasi : inspirasi
# hhh : hhh
# nyinyir : nyinyir
# ngontol : ngontol
# pengaruh : pengaruh
# ngadepin : ngadepin
# harinya : hari
# ngebatin : ngebatin
# premium : premium
# paymentnya : paymentnya
# qris : qris
# simpati : simpati
# apple : apple
# music : music
# dengerin : dengerin
# lagu : lagu
# vpn : vpn
# mksdnya : mksdnya
# sprt : sprt
# hub : hub
# plasa : plasa
# terdekat : dekat
# kerjasamanya : kerjasamanya
# gila : gila
# bos : bos
# efek : efek
# tangerang : tangerang
# datengnya : datengnya
# nax : nax
# how : how
# low : low
# can : can
# get : get
# bruh : bruh
# sepaket : paket
# gaa : gaa
# intel : intel
# notice : notice
# anu : anu
# ngetiknya : ngetiknya
# almarhum : almarhum
# dicuekin : dicuekin
# mention : mention
# ditekan : tekan
# muncul : muncul
# apanya : apa
# hnya : hnya
# wipi : wipi
# top : top
# pubg : pubg
# lejen : lejen
# freefire : freefire
# contact : contact
# isi : isi
# shopeepay : shopeepay
# ovo : ovo
# gopay : gopay
# voucher : voucher
# pulsa : pulsa
# thank : thank
# jpr : jpr
# kapa : kapa
# aslian : asli
# asw : asw
# dalemans : dalemans
# adie : adie
# ati : ati
# mon : mon
# bnyak : bnyak
# penipuan : tipu
# mengatasnamakan : mengatasnamakan
# bin : bin
# julukan : juluk
# badut : badut
# eropa : eropa
# menang : menang
# alhamdulillah : alhamdulillah
# diatas : atas
# tinggal : tinggal
# disana : sana
# melapor : lapor
# senin : senin
# smpai : smpai
# rabu : rabu
# kejelasan : jelas
# ulti : ulti
# miss : miss
# jeonghan : jeonghan
# gengsi : gengsi
# tetring : tetring
# member : member
# bau : bau
# baunya : bau
# gais : gais
# line : line
# leptop : leptop
# yutub : yutub
# wassap : wassap
# allahh : allahh
# tugas : tugas
# kelompok : kelompok
# tubes : tubes
# semuaaa : semuaaa
# kuatkanlah : kuat
# tabahkanlah : tabah
# kepental : pental
# malesin : malesin
# kenapasi : napas
# goooobbblookkkkk : goooobbblookkkkk
# ngelaggg : ngelaggg
# dahlah : dah
# teks : teks
# tag : tag
# pakettt : pakettt
# lagg : lagg
# klk : klk
# aga : aga
# disindir : sindir
# anjirrrr : anjirrrr
# orng : orng
# dak : dak
# gangguannya : ganggu
# tayangan : tayang
# macet : macet
# badminton : badminton
# mksd : mksd
# lhoh : lhoh
# maksud : maksud
# sangsotnye : sangsotnye
# bah : bah
# literally : literally
# always : always
# gik : gik
# ngedrakor : ngedrakor
# gelud : gelud
# ann : ann
# sesuai : sesuai
# unrequited : unrequited
# inu : inu
# astajim : astajim
# pnya : pnya
# palingn : palingn
# baingaooo : baingaooo
# woooiiiii : woooiiiii
# sialan : sial
# iklan : iklan
# budeg : budeg
# fuck : fuck
# muluk : muluk
# juve : juve
# koar : koar
# denada : denada
# dna : dna
# eropah : eropah
# indra : indra
# pengganti : ganti
# favorit : favorit
# ketahui : tahu
# dikuasai : asai
# kebagian : bagi
# kebayang : bayang
# kejar : kejar
# deadline : deadline
# buffer : buffer
# ambis : ambis
# spiral : spiral
# abyss : abyss
# wifimu : wifimu
# mandiri : mandiri
# situs : situs
# terkendala : kendala
# syittt : syittt
# ngantuk : ngantuk
# awas : awas
# wal : wal
# bgian : bgian
# bray : bray
# lau : lau
# kencengnya : kenceng
# tethring : tethring
# malu : malu
# kukang : kukang
# tambal : tambal
# ban : ban
# servis : servis
# rumhku : rumhku
# bis : bis
# myindihome : myindihome
# closed : closed
# buang : buang
# bro : bro
# seharian : hari
# nyobain : nyobain
# think : think
# much : much
# png : png
# lost : lost
# dol : dol
# temenan : temenan
# doski : doski
# demen : demen
# dms : dms
# real : real
# kejutan : kejut
# seru : seru
# suram : suram
# kack : kack
# digrogotin : digrogotin
# dugong : dugong
# kwowkwowkwow : kwowkwowkwow
# packet : packet
# meledak : ledak
# awkawk : awkawk
# wkk : wkk
# ampas : ampas
# jt : jt
# sudaaah : sudaaah
# sent : sent
# seluler : seluler
# beb : beb
# menangys : menangys
# ngupload : ngupload
# sminggu : sminggu
# jaringn : jaringn
# ketulis : ketul
# kekirim : kirim
# diumumin : diumumin
# panitia : panitia
# datanya : data
# hiksrot : hiksrot
# nomerku : nomerku
# daftar : daftar
# aseeekkk : aseeekkk
# istiqomah : istiqomah
# finalis : final
# teman : teman
# anjgggg : anjgggg
# meanwhile : meanwhile
# now : now
# nelfon : nelfon
# php : php
# notif : notif
# samsekkkkk : samsekkkkk
# dream : dream
# lagii : lagi
# berinternet : berinternet
# sepuasnya : puas
# chnanel : chnanel
# krna : krna
# smpe : smpe
# bdminton : bdminton
# ibok : ibok
# kvision : kvision
# gadpt : gadpt
# tvri : tvri
# dibutuhin : dibutuhin
# mlh : mlh
# bae : bae
# app : app
# fungsi : fungsi
# davina : davina
# baim : baim
# useesports : useesports
# yud : yud
# negara : negara
# jatoh : jatoh
# tempo : tempo
# udahd : udahd
# mang : mang
# pokoknya : pokok
# pujian : puji
# anime : anime
# ceritanya : cerita
# natsume : natsume
# makhluk : makhluk
# halus : halus
# dikejer : kejer
# setan : setan
# sejenis : jenis
# jin : jin
# nempel : nempel
# nyanko : nyanko
# sensei : sensei
# tepatnya : tepat
# hyunjin : hyunjin
# berisi : isi
# kulitnya : kulit
# saluran : salur
# kembaran : kembar
# marak : marak
# lhoo : lhoo
# meeting : meeting
# support : support
# beda : beda
# dibandung : bandung
# gilak : gilak
# jay : jay
# mantep : mantep
# cari : cari
# apalahi : apalahi
# uas : uas
# bosen : bosen
# ngedip : ngedip
# gusti : gusti
# kerjaanna : kerjaanna
# ngagantung : ngagantung
# atuh : atuh
# searchbar : searchbar
# google : google
# wkwkwkwkwkwk : wkwkwkwkwkwk
# indihomee : indihomee
# isp : isp
# reseller : reseller
# ilegal : ilegal
# pedit : pedit
# detail : detail
# lunas : lunas
# juvenya : juvenya
# mentok : mentok
# final : final
# agek : agek
# huruf : huruf
# cililitan : cililitan
# mba : mba
# yayuk : yayuk
# join : join
# atap : atap
# asbes : asbes
# rumahnya : rumah
# lulu : lulu
# sukses : sukses
# passwordnyaaa : passwordnyaaa
# bersatu : satu
# bercerai : cerai
# nunggu : nunggu
# queue : queue
# new : new
# world : world
# seribuan : ribu
# kntt : kntt
# pintu : pintu
# kayu : kayu
# kukira : kira
# lemari : lemari
# lorong : lorong
# merasakan : rasa
# ttg : ttg
# thinking : thinking
# about : about
# mercury : mercury
# started : started
# being : being
# broken : broken
# nationwide : nationwide
# won : won
# good : good
# fear : fear
# intertnya : intertnya
# gajalan : gajalan
# teh : teh
# diliat : liat
# kedepan : depan
# ngarumbay : ngarumbay
# pegat : pegat
# kaserepet : kaserepet
# truk : truk
# abra : abra
# muatan : muat
# bara : bara
# pertambangan : tambang
# ckuakzsasbwtwyqiqkwituqiwbsg : ckuakzsasbwtwyqiqkwituqiwbsg
# kabeh : kabeh
# laugh : laugh
# genre : genre
# folk : folk
# indie : indie
# met : met
# ngopi : ngopi
# langit : langit
# mikirin : mikirin
# keren : keren
# nawarin : nawarin
# berserta : serta
# lead : lead
# kesempatan : sempat
# asah : asah
# skill : skill
# set : set
# pola : pola
# berpikir : pikir
# pro : pro
# player : player
# esports : esports
# dilatih : latih
# mentor : mentor
# coach : coach
# berpengalaman : alam
# buruan : buru
# sports : sports
# astaga : astaga
# penghuni : huni
# halnya : hal
# hunian : huni
# aktivitas : aktivitas
# sehari : hari
# jastok : jastok
# wkwkwkwkwkwkwkwkwkwkwkwkwkwkkwkwk : wkwkwkwkwkwkwkwkwkwkwkwkwkwkkwkwk
# konten : konten
# interaktif : interaktif
# blockbuster : blockbuster
# drama : drama
# series : series
# dokumenter : dokumenter
# romance : romance
# tersedia : sedia
# lengkap : lengkap
# apps : apps
# store : store
# ngedukung : ngedukung
# his : his
# jisoo : jisoo
# ngeload : ngeload
# tyda : tyda
# langganannya : langgan
# kagak : kagak
# mari : mari
# myrep : myrep
# willy : willy
# mindah : mindah
# ohokey : ohokey
# meresahkan : resah
# brayy : brayy
# rapat : rapat
# cabutin : cabutin
# mnt : mnt
# saran : saran
# solutif : solutif
# sesange : sesange
# sorijilo : sorijilo
# delay : delay
# bcs : bcs
# dance : dance
# menghancurkan : hancur
# pendidikan : didik
# solusi : solusi
# rebahan : rebah
# love : love
# mercii : mercii
# askskskskks : askskskskks
# yessss : yessss
# unlock : unlock
# lol : lol
# chae : chae
# privasi : privasi
# yohanes : yohanes
# latokolan : latokolan
# easy : easy
# prioritas : prioritas
# wkwkwkwkwkwl : wkwkwkwkwkwl
# ngerasa : ngerasa
# kemahalan : mahal
# ribuan : ribu
# kenaikan : naik
# makenya : makenya
# fup : fup
# frend : frend
# silver : silver
# anjingggg : anjingggg
# skali : skali
# perubahan : ubah
# kepoin : poin
# mtv : mtv
# melulu : melulu
# oemang : oemang
# ferry : ferry
# terindikasi : indikasi
# fisik : fisik
# langkah : langkah
# pastikan : pasti
# patchcord : patchcord
# otw : otw
# ditelpon : telpon
# orangnya : orang
# bye : bye
# huftt : huftt
# internetmu : internetmu
# pan : pan
# tek : tek
# mengadukan : adu
# class : class
# bgini : bgini
# number : number
# one : one
# mainnya : main
# mya : mya
# usil : usil
# direpotin : direpotin
# im : im
# issss : issss
# bgtttt : bgtttt
# minions : minions
# anjggghh : anjggghh
# brand : brand
# terkena : kena
# dampak : dampak
# annjjjjgg : annjjjjgg
# tenan : tenan
# nol : nol
# jalur : jalur
# rempah : rempah
# mengenal : kenal
# budaya : budaya
# kisah : kisah
# ternate : ternate
# kekayaan : kaya
# rempahnya : rempah
# sept : sept
# temi : tem
# twitch : twitch
# tonton : tonton
# memudahkan : mudah
# apaansi : apaansi
# fibernya : fiber
# balikinn : balikinn
# setahun : tahun
# kocakkk : kocakkk
# ngapain : ngapain
# ambil : ambil
# bhuh : bhuh
# laaa : laaa
# bowo : bowo
# tiktok : tiktok
# kontlo : kontlo
# kambuh : kambuh
# maren : maren
# nungguin : nungguin
# tayangnya : tayang
# menguji : uji
# kesabaran : sabar
# subhanallah : subhanallah
# beredar : edar
# diklaim : klaim
# percakapan : cakap
# tsb : tsb
# lengkapnya : lengkap
# yatuhan : yatuhan
# astagaaaaa : astagaaaaa
# jra : jra
# tethering : tethering
# genah : genah
# agik : agik
# die : die
# seriusss : seriusss
# lamaa : lamaa
# mnta : mnta
# gantiiiiiiii : gantiiiiiiii
# jing : jing
# pophome : pophome
# mbok : mbok
# pamer : pamer
# mung : mung
# dinggo : dinggo
# tok : tok
# lannya : lannya
# kotaknya : kotak
# gibran : gibran
# arku : arku
# estimasi : estimasi
# ulun : ulun
# punyaaa : punyaaa
# eps : eps
# tutorialnya : tutorial
# berguna : guna
# taon : taon
# pecah : pecah
# meter : meter
# jaraknya : jarak
# lan : lan
# insya : insya
# kda : kda
# pingnya : pingnya
# gilaaa : gilaaa
# boros : boros
# dialoogi : dialoogi
# jongkok : jongkok
# lusa : lusa
# mengikuti : ikut
# kebijakan : bijak
# group : group
# menutup : tutup
# asia : asia
# biasaaa : biasaaa
# vidiooooo : vidiooooo
# ayoowww : ayoowww
# bulaaan : bulaaan
# hahahaha : hahahaha
# watch : watch
# peace : peace
# dinosuarus : dinosuarus
# connecting : connecting
# okee : okee
# fahmi : fahmi
# bersemangat : semangat
# hindari : hindar
# kerumunan : kerumun
# senantiasa : senantiasa
# jaga : jaga
# jarak : jarak
# apresiasi : apresiasi
# ily : ily
# ngajarin : ngajarin
# lelembut : lelembut
# ngelakuin : ngelakuin
# buruk : buruk
# diazab : azab
# kepikiran : pikir
# jinyoung : jinyoung
# joking : joking
# around : around
# suck : suck
# hell : hell
# couldn : couldn
# videos : videos
# fyp : fyp
# sue : sue
# bentar : bentar
# invest : invest
# tabungan : tabung
# sob : sob
# reply : reply
# nipuu : nipuu
# gituloh : gituloh
# suaranya : suara
# gapaham : gapaham
# change : change
# from : from
# hope : hope
# better : better
# than : than
# gaib : gaib
# libur : libur
# sudh : sudh
# nyadar : nyadar
# begging : begging
# let : let
# enjoy : enjoy
# frost : frost
# performance : performance
# mhn : mhn
# thanks : thanks
# pengecutnya : kecut
# bela : bela
# belain : bain
# yha : yha
# sambatnya : sambat
# ngahahhaa : ngahahhaa
# contohnya : contoh
# disintang : disintang
# gws : gws
# pusing : pusing
# mamah : mamah
# cacarek : cacarek
# wae : wae
# jaringanna : jaringanna
# namgi : namgi
# capekkkk : capekkkk
# saka : saka
# daaah : daaah
# ngecek : ngecek
# gapernah : gapernah
# angkat : angkat
# bwf : bwf
# sportnya : sport
# ticket : ticket
# close : close
# kenyataan : nyata
# dmn : dmn
# integritas : integritas
# pekerja : kerja
# lil : lil
# mamat : mamat
# pemutusan : putus
# dihentikan : henti
# terpakai : pakai
# lbh : lbh
# bny : bny
# wivi : wivi
# pelajaran : ajar
# diaktifkan : aktif
# last : last
# pon : pon
# tarik : tarik
# biru : biru
# dibelakang : belakang
# diidupin : diidupin
# horror : horror
# luarbiasa : luarbiasa
# neh : neh
# kmr : kmr
# diaktifin : diaktifin
# sptna : sptna
# disalahgunakan : disalahgunakan
# kamp : kamp
# annyeong : annyeong
# inetnya : inetnya
# hotspot : hotspot
# screw : screw
# rivalsyah : rivalsyah
# tindaklanjut : tindaklanjut
# sistem : sistem
# virgi : virgi
# interaksi : interaksi
# dipanggil : panggil
# istigfar : istigfar
# biasnya : bias
# hewanya : hewanya
# didalem : dalem
# perpaduan : padu
# liatkan : liat
# gambarnya : gambar
# diikutin : diikutin
# dimanapun : mana
# kompetisi : kompetisi
# fotografi : fotografi
# masyarakat : masyarakat
# diadakan : ada
# pemenang : menang
# kategori : kategori
# megalodon : megalodon
# punten : punten
# uma : uma
# musume : musume
# howons : howons
# dibilang : bilang
# totally : totally
# unlimited : unlimited
# usage : usage
# deg : deg
# ppt : ppt
# email : email
# mb : mb
# tanggung : tanggung
# bero : bero
# rupane : rupane
# koncoku : konco
# dadi : dadi
# roto : roto
# ngene : ngene
# koe : koe
# moment : moment
# knape : knape
# jls : jls
# bego : bego
# congrats : congrats
# dirasain : dirasain
# penduduk : duduk
# anjrot : anjrot
# afi : afi
# soya : soya
# harganya : harga
# nyampe : nyampe
# worth : worth
# offline : offline
# ntar : ntar
# kenape : kenape
# kesalahan : salah
# kon : kon
# mengeluarkan : keluar
# dimonopoli : monopoli
# monopoli : monopoli
# sosmed : sosmed
# yailah : yailah
# keganggu : ganggu
# minnn : minnn
# semulus : mulus
# pantat : pantat
# aaaamiiiinnn : aaaamiiiinnn
# next : next
# step : step
# tikus : tikus
# murni : murni
# laporannya : lapor
# cuna : cuna
# meluapkan : luap
# kekecewaan : kecewa
# janjian : janji
# gantian : ganti
# etdah : etdah
# berpisah : pisah
# corono : corono
# brengsex : brengsex
# aida : aida
# rekan : rekan
# tks : tks
# kia : kia
# lin : lin
# tolongg : tolongg
# yakkk : yakkk
# gabisaa : gabisaa
# pencet : pencet
# button : button
# tonjok : tonjok
# allhamdullilah : allhamdullilah
# blok : blok
# maslaah : maslaah
# siiikk : siiikk
# anjaaayy : anjaaayy
# numpuk : numpuk
# elaaaahh : elaaaahh
# plislahh : plislahh
# kuliahh : kuliahh
# ehh : ehh
# word : word
# reza : reza
# kondisi : kondisi
# nata : nata
# follow : follow
# dimaksimalkan : maksimal
# kaish : kaish
# ampunilah : ampun
# yaallahh : yaallahh
# woyy : woyy
# raya : raya
# pontianak : pontianak
# ngabang : ngabang
# kecamatan : camat
# kabupaten : kabupaten
# landak : landak
# hih : hih
# bucin : bucin
# terhalang : halang
# restu : restu
# inndihomee : inndihomee
# asssuuu : asssuuu
# baddjngan : baddjngan
# beralih : alih
# harapan : harap
# sekelas : kelas
# ngikut : ngikut
# separah : parah
# ckckck : ckckck
# pantesan : pantesan
# rada : rada
# chill : chill
# wak : wak
# semenjak : semenjak
# akademi : akademi
# khusus : khusus
# atlet : atlet
# sport : sport
# mencari : cari
# talenta : talenta
# bangsa : bangsa
# direkrut : rekrut
# temukan : temu
# regionmu : region
# jaringannyaaaaa : jaringannyaaaaa
# ngezoom : ngezoom
# anjrittttt : anjrittttt
# kontollll : kontollll
# ngaada : ngaada
# memukul : pukul
# ngasih : ngasih
# mendingan : mending
# yatim : yatim
# noona : noona
# dikasi : kasi
# krucil : krucil
# dikerjain : dikerjain
# satunya : satu
# beuh : beuh
# klepak : klepak
# palanya : pala
# sya : sya
# dftr : dftr
# website : website
# progress : progress
# ktanya : ktanya
# tggu : tggu
# hr : hr
# tumbang : tumbang
# maintenance : maintenance
# jujurlah : jujur
# bgmana : bgmana
# pethut : pethut
# logo : logo
# source : source
# tulung : tulung
# stupid : stupid
# jurusan : jurus
# teknik : teknik
# komputer : komputer
# tertolol : tolol
# didaerah : daerah
# cengkareng : cengkareng
# batasi : batas
# stackoverflow : stackoverflow
# ping : ping
# bandwith : bandwith
# lagunya : lagu
# bbb : bbb
# ynwa : ynwa
# suharsus : suharsus
# punyaa : punyaa
# istighfar : istighfar
# kalp : kalp
# yahh : yahh
# keputusan : putus
# wfh : wfh
# closingan : closingan
# mamba : mamba
# stands : stands
# merda : merda
# ketik : ketik
# bangkeeee : bangkeeee
# keno : keno
# semprot : semprot
# owalah : owalah
# kopeeet : kopeeet
# jelasin : jelasin
# heii : heii
# cakap : cakap
# aksi : aksi
# hebat : hebat
# paham : paham
# merata : rata
# saranin : saranin
# collab : collab
# frustrasi : frustrasi
# gpp : gpp
# dukung : dukung
# sekitaran : sekitar
# kampus : kampus
# pinya : pinya
# damn : damn
# who : who
# hurt : hurt
# sist : sist
# bner : bner
# duet : duet
# maut : maut
# mematikan : mati
# moderatorin : moderatorin
# debat : debat
# baca : baca
# sorong : sorong
# memulihkan : pulih
# kab : kab
# panas : panas
# bravo : bravo
# konfirmasihnya : konfirmasihnya
# jawabannya : jawab
# rakyat : rakyat
# echo : echo
# record : record
# nambahin : nambahin
# gawe : gawe
# nian : nian
# ujian : uji
# hahaa : hahaa
# teknisinya : teknisi
# laksisjeksn : laksisjeksn
# aknsjsnsnsiajn : aknsjsnsnsiajn
# teros : ros
# orangegame : orangegame
# games : games
# temui : temu
# mainkan : main
# gameworld : gameworld
# busidol : busidol
# eldorado : eldorado
# kalahkan : kalah
# menghadang : menghadang
# disetiap : tiap
# stage : stage
# beres : beres
# jaringanmu : jaring
# bestie : bestie
# praktikum : praktikum
# dilema : dilema
# bogor : bogor
# gercep : gercep
# kook : kook
# hhhhh : hhhhh
# apaaaa : apaaaa
# luhk : luhk
# behance : behance
# ngedrop : ngedrop
# loadingnya : loadingnya
# web : web
# apknya : apknya
# ipv : ipv
# lagiii : lagiii
# config : config
# sat : sat
# noted : noted
# keterangan : terang
# maslahnya : maslahnya
# kerusakan : rusa
# komponen : komponen
# gardu : gardu
# ciapus : ciapus
# berani : berani
# komponennya : komponen
# kontil : kontil
# dwie : dwie
# naha : naha
# diambil : ambil
# kompak : kompak
# gelutnya : gelut
# sayangnya : sayang
# denda : denda
# kepercayaan : percaya
# cobaan : coba
# gabakal : gabakal
# bajilak : bajilak
# ulangan : ulang
# ngelek : ngelek
# afia : afia
# lakukan : laku
# pach : pach
# cord : cord
# merefresh : merefresh
# taii : taii
# paus : paus
# tuhan : tuhan
# ngalahin : ngalahin
# siput : siput
# bebas : bebas
# reconnecting : reconnecting
# cancel : cancel
# bertingkah : ting
# bedua : bedua
# tobat : tobat
# ngadi : ngadi
# complain : complain
# pergerakan : gera
# yee : yee
# yoga : yoga
# claudi : claudi
# hapus : hapus
# tweet : tweet
# terjaga : jaga
# patch : patch
# ditindaklanjut : ditindaklanjut
# detect : detect
# taaaiiiiikkkkk : taaaiiiiikkkkk
# anjiiiiiiiiiingggggg : anjiiiiiiiiiingggggg
# nyangkut : nyangkut
# transferan : transfer
# ngentoooooooottt : ngentoooooooottt
# tempatku : tempat
# lurah : lurah
# lipat : lipat
# worse : worse
# aksesnya : akses
# benang : benang
# layangan : layang
# moga : moga
# anjj : anjj
# filenya : filenya
# textnya : textnya
# wow : wow
# baek : baek
# ape : ape
# vaffanculo : vaffanculo
# handsomenya : handsomenya
# kenapasih : kenapasih
# anyingggg : anyingggg
# nuzul : nuzul
# meika : meika
# menghapus : hapus
# jingan : jingan
# patah : patah
# pts : pts
# kholid : kholid
# ...
# hang : hang
# tewas : tewas
# liga : liga
# kessie : kessie
# red : red
# card : card
# gossh : gossh
# begadang : begadang
# smh : smh
# goaaallll : goaaallll
# leaaoo : leaaoo
# samaaa : samaaa
# jugaa : jugaa
# emnggg : emnggg
# gasiyyy : gasiyyy
# pliss : pliss
# dehh : dehh
# wifinyaaaa : wifinyaaaa
# kualitasnya : kualitas
# perunjuk : unjuk
# tolonglahhh : tolonglahhh
# detik : detik
# indosaat : indosaat
# phishing : phishing
# menarget : target
# arfan : arfan
# ubur : ubur
# mngkin : mngkin
# apdet : apdet
# ditoleransi : toleransi
# deuk : deuk
# lalajo : lalajo
# menbal : menbal
# senggang : senggang
# kesal : kesal
# persen : persen
# big : big
# speednya : speednya
# drsatis : drsatis
# terselesaikan : selesai
# sumedang : sumedang
# apasih : apasih
# kapok : kapok
# dirujak : rujak
# strikes : strikes
# babiiiiiiii : babiiiiiiii
# guy : guy
# woiiii : woiiii
# nehhhh : nehhhh
# aduhhhh : aduhhhh
# inj : inj
# ngent : ngent
# ngepush : ngepush
# compe : compe
# ngentott : ngentott
# hpku : hpku
# excited : excited
# giveawaynya : giveawaynya
# jtd : jtd
# ikuti : ikut
# rules : rules
# mulaaaii : mulaaaii
# implikasinya : implikasi
# tho : tho
# menghadehhh : menghadehhh
# diakhir : akhir
# inter : inter
# disiarin : disiarin
# sctv : sctv
# asyeeemmmm : asyeeemmmm
# maghrib : maghrib
# huft : huft
# bete : bete
# abzz : abzz
# kelurahan : lurah
# sei : sei
# kera : kera
# hilir : hilir
# medan : medan
# manganya : manganya
# dibaca : baca
# ngalemmm : ngalemmm
# wkwkkwkw : wkwkkwkw
# sumpahh : sumpahh
# opo : opo
# sumpahin : sumpahin
# teraniaya : aniaya
# jabah : jabah
# polll : polll
# tampilannya : tampil
# gta : gta
# onlen : onlen
# mtuallll : mtuallll
# pdaa : pdaa
# ilangg : ilangg
# smnjk : smnjk
# trabel : trabel
# masukin : masukin
# horizon : horizon
# sepadan : padan
# wuss : wuss
# gbisa : gbisa
# senpai : senpai
# post : post
# gertak : gertak
# perkebangannya : bang
# berenti : renti
# valo : valo
# jjga : jjga
# syg : syg
# enakan : enak
# sekomplek : sekomplek
# minoritas : minoritas
# seneng : neng
# ppny : ppny
# kgak : kgak
# ditungguin : ditungguin
# iseng : iseng
# tauny : tauny
# ditipu : tipu
# kesabaranku : sabar
# setebal : setebal
# kesabarannya : sabar
# renjun : renjun
# sekarat : sekarat
# betingkah : beting
# kntol : kntol
# nek : nek
# omahku : omahku
# iso : iso
# dipasangi : pasang
# ramasanh : ramasanh
# tod : tod
# ngikutin : ngikutin
# yaak : yaak
# situ : situ
# penampakan : tampak
# bayangan : bayang
# kardus : kardus
# samsekk : samsekk
# kenapee : kenapee
# lord : lord
# pasword : pasword
# kendalikan : kendali
# loo : loo
# bertambah : tambah
# ilmu : ilmu
# yukk : yukk
# berbagi : bagi
# nak : nak
# karyawan : karyawan
# buatin : buatin
# komandan : komandan
# members : members
# boyz : boyz
# signalnya : signalnya
# diatur : atur
# lock : lock
# anggeur : anggeur
# sakie : sakie
# jiga : jiga
# aish : aish
# slepett : slepett
# destra : destra
# heehe : heehe
# kenek : kenek
# maneh : maneh
# nang : nang
# kene : kene
# rangkai : rangkai
# kalimat : kalimat
# zatra : zatra
# kirimkan : kirim
# linkaja : linkaja
# beruntung : untung
# ngetwt : ngetwt
# ngetag : ngetag
# gile : gile
# hehhhh : hehhhh
# benernyaaa : benernyaaa
# steam : steam
# kgk : kgk
# seperjaringan : jaring
# dipajke : dipajke
# sumpe : sumpe
# peringatan : ingat
# afk : afk
# diganggu : ganggu
# pln : pln
# docx : docx
# heboh : heboh
# kebalik : balik
# andanya : anda
# ranked : ranked
# akusih : akusih
# tipi : tipi
# china : china
# intl : intl
# zhejiangtipi : zhejiangtipi
# shenzhentipi : shenzhentipi
# dll : dll
# kamprettt : kamprettt
# menghalu : menghalu
# luck : luck
# folks : folks
# banyakk : banyakk
# bangett : bangett
# ran : ran
# makanin : makanin
# kureeeeeeeeeeng : kureeeeeeeeeeng
# yth : yth
# bpk : bpk
# meminjamkan : pinjam
# seperangkat : perangkat
# alat : alat
# ges : ges
# membuka : buka
# berkomitmen : komitmen
# ngurangin : ngurangin
# lemoth : lemoth
# indohome : indohome
# putusnya : putus
# menyebabkan : sebab
# membutuhkan : butuh
# hadeuu : hadeuu
# wifii : wifii
# ganteng : ganteng
# dimakan : makan
# cicak : cicak
# been : been
# day : day
# week : week
# until : until
# recently : recently
# use : use
# microsoft : microsoft
# sense : sense
# those : those
# chaotic : chaotic
# energy : energy
# are : are
# raging : raging
# over : over
# couple : couple
# weeks : weeks
# masihblemot : masihblemot
# samaa : samaa
# gasiie : gasiie
# maksudku : maksud
# tebang : tebang
# pohonki : pohonki
# tongi : tong
# kabelna : kabelna
# ballassi : ballassi
# tommi : tommi
# kukata : kata
# takeomi : takeomi
# sampingan : samping
# wauw : wauw
# bermain : main
# lombakan : lomba
# ustadz : ustadz
# halal : halal
# dalil : dalil
# didalam : dalam
# habisa : habisa
# sm : sm
# hrg : hrg
# ngamuk : ngamuk
# kntr : kntr
# krng : krng
# jmbt : jmbt
# anggunan : anggun
# indi : indi
# sayabtidak : sayabtidak
# level : level
# ajaaa : ajaaa
# knphh : knphh
# yhh : yhh
# roblox : roblox
# fyi : fyi
# tertypu : tertypu
# minipack : minipack
# indisport : indisport
# strucksparkles : strucksparkles
# setannnn : setannnn
# kunaon : kunaon
# dei : dei
# gapapa : gapapa
# shhh : shhh
# serba : serba
# ngebayangin : ngebayangin
# menunjang : tunjang
# onlineku : onlineku
# tersampah : sampah
# sedunia : dunia
# run : run
# bts : bts
# anjeeeerrr : anjeeeerrr
# lsg : lsg
# menangani : tangan
# senyebelin : senyebelin
# haloooooo : haloooooo
# olis : olis
# nyesel : nyesel
# sumoahh : sumoahh
# anjinkkk : anjinkkk
# bangsatt : bangsatt
# kalimantan : kalimantan
# gan : gan
# rencana : rencana
# ajaa : ajaa
# beraktivitas : aktivitas
# building : building
# pulak : pulak
# tibatiba : tibatiba
# ngadatngadat : ngadatngadat
# sad : sad
# haloo : haloo
# musti : musti
# file : file
# kelarnya : kelar
# sims : sims
# momen : momen
# jera : jera
# replyan : replyan
# perbedaan : beda
# bisasa : bisasa
# tingkatkan : tingkat
# seng : seng
# jelaske : jelaske
# dengarkan : dengar
# gembel : gembel
# bersamaan : sama
# respons : respons
# duluan : duluan
# punyanya : punya
# ngambil : ngambil
# lovely : lovely
# daftarkan : daftar
# kpanjangan : kpanjangan
# nulisnya : nulisnya
# sch : sch
# maksudnya : maksud
# tetanggaan : tetangga
# github : github
# gratisan : gratis
# gbloj : gbloj
# sinyalu : sinyalu
# bgo : bgo
# donk : donk
# tanganin : tanganin
# punyaku : punya
# switch : switch
# connectionnya : connectionnya
# dina : dina
# korea : korea
# tele : tele
# kalii : kali
# hwhw : hwhw
# byyyye : byyyye
# ngapaaa : ngapaaa
# taiiiiiii : taiiiiiii
# macem : macem
# dibutuhkan : butuh
# menyelesaikan : selesai
# skripsi : skripsi
# perhatiannya : perhati
# dikomplek : dikomplek
# saing : saing
# radius : radius
# broadband : broadband
# cakupannya : cakup
# luas : luas
# nembus : nembus
# pelosok : pelosok
# diplay : diplay
# juju : juju
# potonya : potonya
# tebalikin : tebalikin
# yuukks : yuukks
# digitalmu : digital
# terjamin : jamin
# semingguan : minggu
# sadge : sadge
# kanugrahan : kanugrahan
# nanges : nanges
# quiz : quiz
# bagoos : bagoos
# jumping : jumping
# ms : ms
# tercepat : cepat
# loding : loding
# katany : katany
# wkakka : wkakka
# kemusuhan : musuh
# cacat : cacat
# melatih : latih
# manusia : manusia
# purba : purba
# mengganggu : ganggu
# kombo : kombo
# megalithikum : megalithikum
# inef : inef
# dede : dede
# gemash : gemash
# akb : akb
# gebuk : gebuk
# diem : diem
# memperjelekkan : jelek
# wkw : wkw
# lemottt : lemottt
# tertulisnya : tulis
# kompastekno : kompastekno
# ujiannya : uji
# ngerjain : ngerjain
# aminnnn : aminnnn
# fak : fak
# yuh : yuh
# nim : nim
# getok : getok
# fionyjkt : fionyjkt
# promosiin : promosiin
# ziza : ziza
# tergangguuuuuuuuuuuuuiiiiiii : tergangguuuuuuuuuuuuuiiiiiii
# iiiuuuuuuuu : iiiuuuuuuuu
# bengkak : bengkak
# kemapa : kemapa
# kumatttttt : kumatttttt
# memberitahu : memberitahu
# bahwasannya : bahwasannya
# mandani : mandani
# ingetin : ingetin
# logis : logis
# gigit : gigit
# why : why
# picture : picture
# acting : acting
# dimarahin : dimarahin
# bkann : bkann
# ditemenin : ditemenin
# temenmu : temenmu
# kwakah : kwakah
# jambi : jambi
# ketemu : ketemu
# siarannya : siar
# dvd : dvd
# bajakan : baja
# kwlah : kwlah
# mlihat : mlihat
# geus : geus
# poe : poe
# ieu : ieu
# mun : mun
# ngeunaheun : ngeunaheun
# teu : teu
# gandeng : gandeng
# jebred : jebred
# padat : padat
# healing : healing
# woee : woee
# mengbal : mengbal
# errr : errr
# pemakai : pakai
# tersakiti : sakit
# kepo : kepo
# kepingin : kepingin
# posesif : posesif
# diposesifin : diposesifin
# sebuln : sebuln
# tuhh : tuhh
# melalukan : lalu
# knpsi : knpsi
# entar : entar
# bercanda : canda
# hehehe : hehehe
# lom : lom
# tch : tch
# baka : baka
# ishhh : ishhh
# anjengg : anjengg
# berat : berat
# flop : flop
# lagging : lagging
# eeeeee : eeeeee
# teknologi : teknologi
# terbantu : bantu
# kemajuan : maju
# benahin : benahin
# tolongla : tolongla
# sariwangi : sariwangi
# didatengin : didatengin
# moal : moal
# services : services
# cannot : cannot
# trusted : trusted
# anymore : anymore
# ihh : ihh
# wihhh : wihhh
# galiat : galiat
# arda : arda
# sodara : sodara
# oxygen : oxygen
# setya : setya
# iyaa : iyaa
# gmna : gmna
# sangattt : sangattt
# amatt : amatt
# taya : taya
# tay : tay
# ishh : ishh
# cokkk : cokkk
# {'kampret': 'kampret', 'indihome': 'indihome', 'kuliah': 'kuliah', 'gblg': 'gblg', 'orang': 'orang', 'jaman': 'jaman', 'batu': 'batu', '': '', 'gatau': 'gatau', 'yaa': 'yaa', 'bayar': 'bayar', 'tpi': 'tpi', 'kisaran': 'kisar', 'ribu': 'ribu', 'sma': 'sma', 'pemasangan': 'pasang', 'gratis': 'gratis', 'nder': 'nder', 'masang': 'masang', 'pertengahan': 'tengah', 'dikenakan': 'kena', 'biaya': 'biaya', 'dri': 'dri', 'tergantung': 'gantung', 'halo': 'halo', 'membatalkan': 'batal', 'paketan': 'paket', 'useetv': 'useetv', 'gimana': 'gimana', 'memgalami': 'memgalami', 'gangguan': 'ganggu', 'error': 'error', 'layanannya': 'layan', 'telkomsel': 'telkomsel', 'orbit': 'orbit', 'telkom': 'telkom', 'kanibal': 'kanibal', 'berhenti': 'henti', 'langganan': 'langgan', 'tolong': 'tolong', 'diperbaiki': 'baik', 'please': 'please', 'sort': 'sort', 'the': 'the', 'internet': 'internet', 'out': 'out', 'bandung': 'bandung', 'kids': 'kids', 'need': 'need', 'for': 'for', 'school': 'school', 'aduh': 'aduh', 'siih': 'siih', 'puyeng': 'puyeng', 'kelas': 'kelas', 'jam': 'jam', 'gue': 'gue', 'semalem': 'semalem', 'bangun': 'bangun', 'pagi': 'pagi', 'msh': 'msh', 'menjual': 'jual', 'promo': 'promo', 'wifi': 'wifi', 'seharga': 'harga', 'rp': 'rp', 'dapatkan': 'dapat', 'shopee': 'shopee', 'udah': 'udah', 'mbps': 'mbps', 'lelet': 'lelet', 'tembus': 'tembus', 'engga': 'engga', 'kayanya': 'kaya', 'udahlah': 'udahlah', 'mahal': 'mahal', 'telat': 'telat', 'masuk': 'masuk', 'online': 'online', 'kesiangan': 'siang', 'listrik': 'listrik', 'mati': 'mati', 'lupa': 'lupa', 'salah': 'salah', 'link': 'link', 'dear': 'dear', 'pindah': 'pindah', 'alamat': 'alamat', 'tgl': 'tgl', 'sep': 'sep', 'smpi': 'smpi', 'koneksi': 'koneksi', 'tlp': 'tlp', 'mash': 'mash', 'blm': 'blm', 'konfrm': 'konfrm', 'teknisi': 'teknisi', 'marketingnya': 'marketingnya', 'ttp': 'ttp', 'mohon': 'mohon', 'followupnya': 'followupnya', 'nuhun': 'nuhun', 'pls': 'pls', 'ajg': 'ajg', 'vfmebgmdmf': 'vfmebgmdmf', 'pasang': 'pasang', 'bulanan': 'bulan', 'knapa': 'knapa', 'lgi': 'lgi', 'nomer': 'nomer', 'inet': 'inet', 'september': 'september', 'permintaan': 'minta', 'daring': 'daring', 'anak': 'anak', 'gede': 'gede', 'gua': 'gua', 'dipakai': 'pakai', 'massal': 'massal', 'azhar': 'azhar', 'mslh': 'mslh', 'andry': 'andry', 'njirrr': 'njirrr', 'wkwkkw': 'wkwkkw', 'bmy': 'bmy', 'ngga': 'ngga', 'hatimu': 'hati', 'unduhan': 'unduh', 'data': 'data', 'dayaku': 'daya', 'mencapaimu': 'capa', 'lelah': 'lelah', 'mencintamu': 'cinta', 'menyerah': 'serah', 'lumayan': 'lumayan', 'jaringan': 'jaring', 'kaya': 'kaya', 'hubungan': 'hubung', 'turun': 'turun', 'kadang': 'kadang', 'happy': 'happy', 'nyebelin': 'nyebelin', 'semoga': 'moga', 'cepat': 'cepat', 'diatasi': 'atas', 'kebutuhan': 'butuh', 'hai': 'hai', 'kak': 'kak', 'latifah': 'latifah', 'shiro': 'shiro', 'bantu': 'bantu', 'terkait': 'kait', 'produk': 'produk', 'layanan': 'layan', 'silakan': 'sila', 'informasikan': 'informasi', 'detailnya': 'detail', 'dibantu': 'bantu', 'terima': 'terima', 'kasih': 'kasih', 'malem': 'malem', 'gini': 'gin', 'kosan': 'kosan', 'emang': 'emang', 'diandalkan': 'andal', 'modus': 'modus', 'pembaharuan': 'baharu', 'perangkat': 'perangkat', 'helloooo': 'helloooo', 'sobat': 'sobat', 'cerdas': 'cerdas', 'mudah': 'mudah', 'ditypu': 'ditypu', 'gitu': 'gitu', 'cek': 'cek', 'kebenarannya': 'benar', 'telfon': 'telfon', 'langsung': 'langsung', 'nggak': 'nggak', 'bingung': 'bingung', 'khawatir': 'khawatir', 'keamanan': 'aman', 'rumah': 'rumah', 'smart': 'smart', 'hadir': 'hadir', 'fitur': 'fitur', 'canggih': 'canggih', 'pantau': 'pantau', 'smartphone': 'smartphone', 'aman': 'aman', 'hati': 'hati', 'tenang': 'tenang', 'hay': 'hay', 'belajar': 'ajar', 'asyik': 'asyik', 'nich': 'nich', 'dimana': 'mana', 'bener': 'bener', 'study': 'study', 'pelajar': 'ajar', 'smp': 'smp', 'kangen': 'kangen', 'ganti': 'ganti', 'ssid': 'ssid', 'password': 'password', 'kurangi': 'kurang', 'total': 'total', 'device': 'device', 'akses': 'akses', 'blokir': 'blokir', 'wan': 'wan', 'dik ...
# ------------------------
# Pandas Apply:   0%|          | 0/1974 [00:01<?, ?it/s]
#                                                 content  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik ke jaman ...
# 2     @convomf klo indihome gatau yaa aku bayar bera...
# 3     @indihome halo saya mau tanya caranya membatal...
# 4     kenapa yaa @indihome sering sekali memgalami g...
# ...                                                 ...
# 1995  awet banget main hp buat belajar pakai indihom...
# 1996  @indihomecare masa iya segini speednya? nomor ...
# 1997  @faraharizcher gue pake indihome ☹️. taya pake...
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome 🤝🏻 firstmedia\n\nalias sama2 gangguan...
#
#                                          cleaning_tweet  \
# 0        kampret lah indihome mana mau kuliah lagi gblg
# 1     indihome mau bikin orang orang balik jaman bat...
# 2     klo indihome gatau yaa aku bayar berapa tpi ki...
# 3     halo saya mau tanya caranya membatalkan paketa...
# 4          kenapa yaa sering sekali memgalami gangguan
# ...                                                 ...
# 1995      awet banget main buat belajar pakai indihome
# 1996     masa iya segini speednya nomor indihome saya
# 1997               gue pake indihome taya pake rep tay
# 1998                       indihome kok lemot lagi ishh
# 1999  indihome firstmedia alias sama  gangguan mulu ...
#
#                                              tokenisasi  \
# 0     [kampret, lah, indihome, mana, mau, kuliah, la...
# 1     [indihome, mau, bikin, orang, orang, balik, ja...
# 2     [klo, indihome, gatau, yaa, aku, bayar, berapa...
# 3     [halo, saya, mau, tanya, caranya, membatalkan,...
# 4     [kenapa, yaa, sering, sekali, memgalami, gangg...
# ...                                                 ...
# 1995  [awet, banget, main, buat, belajar, pakai, ind...
# 1996  [masa, iya, segini, speednya, nomor, indihome,...
# 1997      [gue, pake, indihome, taya, pake, rep, tay, ]
# 1998                 [indihome, kok, lemot, lagi, ishh]
# 1999  [indihome, firstmedia, alias, sama, gangguan, ...
#
#                                                stopword  \
# 0                     [kampret, indihome, kuliah, gblg]
# 1               [indihome, orang, orang, jaman, batu, ]
# 2     [indihome, gatau, yaa, bayar, tpi, kisaran, ri...
# 3        [halo, membatalkan, paketan, useetv, gimana, ]
# 4                          [yaa, memgalami, gangguan, ]
# ...                                                 ...
# 1995   [awet, banget, main, belajar, pakai, indihome, ]
# 1996         [iya, segini, speednya, nomor, indihome, ]
# 1997                  [gue, indihome, taya, rep, tay, ]
# 1998                            [indihome, lemot, ishh]
# 1999  [indihome, firstmedia, alias, gangguan, mulu, ...
#
#                                                stemming
# 0                     [kampret, indihome, kuliah, gblg]
# 1               [indihome, orang, orang, jaman, batu, ]
# 2     [indihome, gatau, yaa, bayar, tpi, kisar, ribu...
# 3                [halo, batal, paket, useetv, gimana, ]
# 4                            [yaa, memgalami, ganggu, ]
# ...                                                 ...
# 1995      [awet, banget, main, ajar, pakai, indihome, ]
# 1996            [iya, gin, speednya, nomor, indihome, ]
# 1997                  [gue, indihome, taya, rep, tay, ]
# 1998                              [indihome, lot, ishh]
# 1999  [indihome, firstmedia, alias, ganggu, mulu, co...
#
# [1974 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0                     [kampret, indihome, kuliah, gblg]
# 1               [indihome, orang, orang, jaman, batu, ]
# 2     [indihome, gatau, yaa, bayar, tpi, kisar, ribu...
# 3                [halo, batal, paket, useetv, gimana, ]
# 4                            [yaa, memgalami, ganggu, ]
# ...                                                 ...
# 1995      [awet, banget, main, ajar, pakai, indihome, ]
# 1996            [iya, gin, speednya, nomor, indihome, ]
# 1997                  [gue, indihome, taya, rep, tay, ]
# 1998                              [indihome, lot, ishh]
# 1999  [indihome, firstmedia, alias, ganggu, mulu, co...
#
# [1974 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_9.xlsx')
