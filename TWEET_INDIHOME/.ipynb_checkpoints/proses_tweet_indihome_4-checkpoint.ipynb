# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @basurjkt @IndiHome @TelkomCare ttp://myih.ch/...
# 1     @basurjkt @IndiHome @TelkomCare Hai, Kak Bamba...
# 2     @NetflixID @TelkomIndonesia @Telkomsel @IndiHo...
# 3              @seonghwacs @IndiHome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @IqbalDias @IndiHome Halo, Kak Iqbal. Maaf ata...
# 1996  @blontankpoer @IndiHome @IndiHomeCare Ujug2 ta...
# 1997  Pie sih indihome @LuckyMaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @FirstMediaCares @Ind...
# 1999                            Indihome kenapa siihh??
#
# [2000 rows x 1 columns]

# %%
print('Dataset size:', df.shape)
print('Columns are:', df.columns)
# Out:
# Dataset size: (2000, 1)
# Columns are: Index(['content'], dtype='object')

# %%
df.content.duplicated().sum()
# Out:
# 212

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @basurjkt @IndiHome @TelkomCare ttp://myih.ch/...
# 1     @basurjkt @IndiHome @TelkomCare Hai, Kak Bamba...
# 2     @NetflixID @TelkomIndonesia @Telkomsel @IndiHo...
# 3              @seonghwacs @IndiHome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @IqbalDias @IndiHome Halo, Kak Iqbal. Maaf ata...
# 1996  @blontankpoer @IndiHome @IndiHomeCare Ujug2 ta...
# 1997  Pie sih indihome @LuckyMaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @FirstMediaCares @Ind...
# 1999                            Indihome kenapa siihh??
#
# [1689 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @basurjkt @indihome @telkomcare ttp://myih.ch/...
# 1     @basurjkt @indihome @telkomcare hai, kak bamba...
# 2     @netflixid @telkomindonesia @telkomsel @indiho...
# 3              @seonghwacs @indihome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @iqbaldias @indihome halo, kak iqbal. maaf ata...
# 1996  @blontankpoer @indihome @indihomecare ujug2 ta...
# 1997  pie sih indihome @luckymaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @firstmediacares @ind...
# 1999                            indihome kenapa siihh??
#
# [1689 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @basurjkt @indihome @telkomcare ttp://myih.ch/...
# 1     @basurjkt @indihome @telkomcare hai, kak bamba...
# 2     @netflixid @telkomindonesia @telkomsel @indiho...
# 3              @seonghwacs @indihome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @iqbaldias @indihome halo, kak iqbal. maaf ata...
# 1996  @blontankpoer @indihome @indihomecare ujug2 ta...
# 1997  pie sih indihome @luckymaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @firstmediacares @ind...
# 1999                            indihome kenapa siihh??
#
#                                          cleaning_tweet
# 0     interaksinya beralih akun tersebut terima kasi...
# 1     hai kak bambang perihal akses jaringannya seba...
# 2                                       hmm sudah akur
# 3                                    mohon pngertiannya
# 4                                              indihome
# ...                                                 ...
# 1995  halo kak iqbal maaf atas ketidaknyamanannya sa...
# 1996  ujug  tarif mundhak wes lewat tgl mesti lsg sp...
# 1997                                  pie sih indihome
# 1998                   nya sudah mimin respon kak trims
# 1999                             indihome kenapa siihh
#
# [1689 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @basurjkt @indihome @telkomcare ttp://myih.ch/...
# 1     @basurjkt @indihome @telkomcare hai, kak bamba...
# 2     @netflixid @telkomindonesia @telkomsel @indiho...
# 3              @seonghwacs @indihome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @iqbaldias @indihome halo, kak iqbal. maaf ata...
# 1996  @blontankpoer @indihome @indihomecare ujug2 ta...
# 1997  pie sih indihome @luckymaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @firstmediacares @ind...
# 1999                            indihome kenapa siihh??
#
#                                          cleaning_tweet  \
# 0     interaksinya beralih akun tersebut terima kasi...
# 1     hai kak bambang perihal akses jaringannya seba...
# 2                                       hmm sudah akur
# 3                                    mohon pngertiannya
# 4                                              indihome
# ...                                                 ...
# 1995  halo kak iqbal maaf atas ketidaknyamanannya sa...
# 1996  ujug  tarif mundhak wes lewat tgl mesti lsg sp...
# 1997                                  pie sih indihome
# 1998                   nya sudah mimin respon kak trims
# 1999                             indihome kenapa siihh
#
#                                              tokenisasi
# 0     [interaksinya, beralih, akun, tersebut, terima...
# 1     [hai, kak, bambang, perihal, akses, jaringanny...
# 2                                  [hmm, sudah, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, atas, ketidaknyamanan...
# 1996  [ujug, tarif, mundhak, wes, lewat, tgl, mesti,...
# 1997                             [pie, sih, indihome, ]
# 1998          [, nya, sudah, mimin, respon, kak, trims]
# 1999                        [indihome, kenapa, siihh, ]
#
# [1689 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'nya'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(3000)
# Out:
#                                                 content  \
# 0     @basurjkt @indihome @telkomcare ttp://myih.ch/...
# 1     @basurjkt @indihome @telkomcare hai, kak bamba...
# 2     @netflixid @telkomindonesia @telkomsel @indiho...
# 3              @seonghwacs @indihome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @iqbaldias @indihome halo, kak iqbal. maaf ata...
# 1996  @blontankpoer @indihome @indihomecare ujug2 ta...
# 1997  pie sih indihome @luckymaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @firstmediacares @ind...
# 1999                            indihome kenapa siihh??
#
#                                          cleaning_tweet  \
# 0     interaksinya beralih akun tersebut terima kasi...
# 1     hai kak bambang perihal akses jaringannya seba...
# 2                                       hmm sudah akur
# 3                                    mohon pngertiannya
# 4                                              indihome
# ...                                                 ...
# 1995  halo kak iqbal maaf atas ketidaknyamanannya sa...
# 1996  ujug  tarif mundhak wes lewat tgl mesti lsg sp...
# 1997                                  pie sih indihome
# 1998                   nya sudah mimin respon kak trims
# 1999                             indihome kenapa siihh
#
#                                              tokenisasi  \
# 0     [interaksinya, beralih, akun, tersebut, terima...
# 1     [hai, kak, bambang, perihal, akses, jaringanny...
# 2                                  [hmm, sudah, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, atas, ketidaknyamanan...
# 1996  [ujug, tarif, mundhak, wes, lewat, tgl, mesti,...
# 1997                             [pie, sih, indihome, ]
# 1998          [, nya, sudah, mimin, respon, kak, trims]
# 1999                        [indihome, kenapa, siihh, ]
#
#                                                stopword
# 0     [interaksinya, beralih, akun, terima, kasih, r...
# 1     [hai, kak, bambang, perihal, akses, jaringanny...
# 2                                         [hmm, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, ketidaknyamanannya, l...
# 1996  [ujug, tarif, mundhak, wes, tgl, mesti, lsg, s...
# 1997                                  [pie, indihome, ]
# 1998                      [, mimin, respon, kak, trims]
# 1999                                [indihome, siihh, ]
#
# [1689 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3468
# ------------------------
# interaksinya : interaksi
# beralih : alih
# akun : akun
# terima : terima
# kasih : kasih
# refan : refan
#  :
# hai : hai
# kak : kak
# bambang : bambang
# perihal : perihal
# akses : akses
# jaringannya : jaring
# langkah : langkah
# pastikan : pasti
# kabel : kabel
# patch : patch
# cord : cord
# warna : warna
# hitam : hitam
# kuning : kuning
# ujung : ujung
# biru : biru
# terpasang : pasang
# kencang : kencang
# coba : coba
# koneksinya : koneksi
# informasikan : informasi
# via : via
# link : link
# hmm : hmm
# akur : akur
# mohon : mohon
# pngertiannya : pngertiannya
# indihome : indihome
# pagi : pagi
# mati : mati
# hrs : hrs
# telp : telp
# lapor : lapor
# nyala : nyala
# twitter : twitter
# koq : koq
# direspon : direspon
# finally : finally
# ditunggu : tunggu
# tunggu : tunggu
# seru : seru
# kerja : kerja
# netflix : netflix
# taii : taii
# wow : wow
# tranding : tranding
# thursdayonnetflix : thursdayonnetflix
# netfik : netfik
# diakses : akses
# betah : betah
# dirumah : rumah
# deh : deh
# melototin : melototin
# mantab : mantab
# selamat : selamat
# keluhan : keluh
# gangguan : ganggu
# sistem : sistem
# jaringan : jaring
# putus : putus
# ping : ping
# stabil : stabil
# disebabkan : sebab
# redaman : redam
# diganti : ganti
# bantuannya : bantu
# internet : internet
# kakak : kakak
# interaksi : interaksi
# silakan : sila
# hubungi : hubung
# tata : tata
# halo : halo
# julian : juli
# kendala : kendala
# pusat : pusat
# pemakaian : pakai
# melebihi : lebih
# fup : fup
# nomor : nomor
# pengecekan : kece
# dikasi : kasi
# uang : uang
# anak : anak
# anaknya : anak
# pengeluaran : keluar
# makan : makan
# listrik : listrik
# pdam : pdam
# dll : dll
# urusan : urus
# ditumpangi : tumpang
# uangnya : uang
# kumpul : kumpul
# cmn : cmn
# dapet : dapet
# speed : speed
# segini : gin
# berasa : asa
# tembaga : tembaga
# bkn : bkn
# fiber : fiber
# optik : optik
# bantuin : bantuin
# summon : summon
# sii : sii
# sukak : sukak
# gini : gin
# udh : udh
# istighfar : istighfar
# wkwkwkkwk : wkwkwkkwk
# nasiiibbb : nasiiibbb
# wilayah : wilayah
# entrop : entrop
# kecamatan : camat
# jayapura : jayapura
# selatan : selatan
# off : off
# subuh : subuh
# tolong : tolong
# ditangani : tangan
# sesang : sang
# ujian : uji
# online : online
# thanks : thanks
# min : min
# susukan : susu
# bojong : bojong
# gede : gede
# kab : kab
# bogor : bogor
# mengalami : alami
# isu : isu
# dikonfirmasi : konfirmasi
# penyelesaian : selesai
# perbaikan : baik
# rabu : rabu
# berkurang : kurang
# siangan : siang
# kambuh : kambuh
# bener : bener
# gua : gua
# ganti : ganti
# wifi : wifi
# woy : woy
# modem : modem
# ngelag : ngelag
# kacau : kacau
# access : access
# yaa : yaa
# udah : udah
# nyoba : nyoba
# reset : reset
# hasilnya : hasil
# nihil : nihil
# emridwan : emridwan
# ridwan : ridwan
# setia : setia
# emosi : emosi
# tod : tod
# masyallah : masyallah
# tsel : tsel
# ribut : ribut
# nyobain : nyobain
# main : main
# pubg : pubg
# character : character
# gue : gue
# salah : salah
# urat : urat
# anjirr : anjirr
# angger : angger
# hadir : hadir
# dilokasi : lokasi
# yuk : yuk
# bantu : bantu
# voting : voting
# intraksi : intraksi
# selanjut : lanjut
# indihomecare : indihomecare
# terimakasih : terimakasih
# wija : wija
# arief : arief
# nara : nara
# cek : cek
# informasi : informasi
# password : password
# stb : stb
# dibantu : bantu
# respon : respon
# rekan : rekan
# rumah : rumah
# gabisa : gabisa
# koneksi : koneksi
# pls : pls
# tega : tega
# anjg : anjg
# april : april
# source : source
# tertera : tera
# please : please
# nice : nice
# bagus : bagus
# banget : banget
# pengen : ken
# tiang : tiang
# problem : problem
# disuruh : suruh
# restart : restart
# yaak : yaak
# ngeslin : ngeslin
# ehh : ehh
# serius : serius
# gilaaaa : gilaaaa
# kuat : kuat
# bngttt : bngttt
# menghubungi : hubung
# amond : amond
# hallo : hallo
# aji : aji
# terkait : kait
# dilokasinya : lokasi
# pemeliharaan : pelihara
# khawatir : khawatir
# diupayakan : upaya
# secepatnya : cepat
# terselesaikan : selesai
# menunggu : tunggu
# progress : progress
# update : update
# desty : desty
# layanan : layan
# trion : trion
# lelet : lelet
# yaallah : yaallah
# knp : knp
# cape : cape
# haaa : haaa
# pny : pny
# debit : debit
# kaa : kaa
# bank : bank
# gtu : gtu
# mksdnyaa : mksdnyaa
# gajelas : gajelas
# anjing : anjing
# plissss : plissss
# kurleb : kurleb
# harian : hari
# turun : turun
# lemme : lemme
# donlot : donlot
# wooii : wooii
# admin : admin
# jam : jam
# sore : sore
# kemaren : kemaren
# followup : followup
# ldong : ldong
# aporan : aporan
# laporannya : lapor
# in : in
# bayar : bayar
# pas : pas
# tgl : tgl
# mulu : mulu
# emg : emg
# ngeselin : ngeselin
# wuspen : wuspen
# kmrn : kmrn
# astaga : astaga
# kek : kek
# babi : babi
# taunya : tau
# putri : putri
# mudah : mudah
# diteruskan : terus
# ayunk : ayunk
# pke : pke
# ngga : ngga
# aneh : aneh
# bet : bet
# kemarin : kemarin
# oiya : oiya
# emang : emang
# nunggu : nunggu
# kampret : kampret
# isp : isp
# gantinya : ganti
# anjim : anjim
# rusak : rusak
# laporan : lapor
# aplikasi : aplikasi
# ngetweet : ngetweet
# telat : telat
# denda : denda
# pinjaman : pinjam
# onlen : onlen
# tergantung : gantung
# amal : amal
# sie : sie
# berhenti : henti
# langganan : langgan
# deposito : deposito
# blm : blm
# refund : refund
# telpon : telpon
# universe : universe
# menyala : nyala
# koneksikan : koneksi
# perubahan : ubah
# konfirmasikan : konfirmasi
# ditindaklanjuti : ditindaklanjuti
# meutia : meutia
# akhiran : akhir
# indikasi : indikasi
# dibawah : bawah
# lampu : lampu
# power : power
# pon : pon
# modemn : modemn
# info : info
# terupdate : terupdate
# melanjutkan : lanjut
# linaldi : linaldi
# iqbal : iqbal
# maaf : maaf
# nyaman : nyaman
# menyebabkan : sebab
# terganggu : ganggu
# berkenan : kenan
# prosesnya : proses
# halooooo : halooooo
# lelah : lelah
# kabelnya : kabel
# error : error
# dipakai : pakai
# wifinya : wifinya
# kedap : kedap
# kedip : kedip
# merah : merah
# jaman : jaman
# dicek : cek
# karna : karna
# dibutuhin : dibutuhin
# adik : adik
# sekolah : sekolah
# puasa : puasa
# ndk : ndk
# bole : bole
# pendendam : dendam
# tomi : tom
# cieee : cieee
# haii : hai
# herdian : herdian
# elnik : elnik
# lagii : lagi
# masi : mas
# uhd : uhd
# hdr : hdr
# lemot : lot
# mond : mond
# ngasi : ngasi
# detail : detail
# egk : egk
# tetep : tetep
# ngntot : ngntot
# plis : plis
# bersahabat : sahabat
# gunanya : guna
# berlangganan : langgan
# firstmed : firstmed
# hit : hit
# the : the
# hardest : hardest
# throw : throw
# komar : komar
# modemnya : modem
# disarankan : saran
# kaya : kaya
# dear : dear
# channel : channel
# semenjak : semenjak
# muncul : muncul
# ket : ket
# sinyal : sinyal
# yaallahhhh : yaallahhhh
# ngeload : ngeload
# foto : foto
# disconnect : disconnect
# indihom : indihom
# blkgan : blkgan
# iki : iki
# fess : fess
# goreng : goreng
# herannya : heran
# ketemu : ketemu
# teman : teman
# jalan : jalan
# senyum : senyum
# ketutupan : tutup
# masker : masker
# mbales : mbales
# iya : iya
# kesel : kesel
# enak : enak
# enaknya : enak
# standar : standar
# kayak : kayak
# kebiasaan : biasa
# beli : beli
# kwetiau : kwetiau
# nemu : nemu
# instant : instant
# geus : geus
# normal : normal
# deui : deui
# jigana : jigana
# gara : gara
# butut : butut
# kamari : kamar
# soalna : soalna
# karek : karek
# pisan : pis
# jiga : jiga
# kitu : kitu
# gangguanna : gangguanna
# biasana : biasana
# mah : mah
# lgsg : lgsg
# konek : konek
# ont : ont
# berkendala : kendala
# infokan : info
# alfian : alfian
# terpantau : pantau
# penanganan : tangan
# berwarna : warna
# asw : asw
# dad : dad
# won : won
# stop : stop
# playing : playing
# video : video
# fucking : fucking
# help : help
# ngape : ngape
# bah : bah
# kenak : nak
# ente : ente
# bat : bat
# sampah : sampah
# cok : cok
# tetanggaku : tetangga
# sales : sales
# daftar : daftar
# kepasang : pasang
# kompetisi : kompetisi
# generasi : generasi
# prestasi : prestasi
# hadiahnya : hadiah
# ratusan : ratus
# juta : juta
# rupiah : rupiah
# pendaftaran : daftar
# gratis : gratis
# lho : lho
# ayo : ayo
# registrasi : registrasi
# powered : powered
# ngamuk : ngamuk
# telkomsel : telkomsel
# ngegame : ngegame
# kayaknya : kayak
# asyiik : asyiik
# semoga : moga
# kabar : kabar
# cepat : cepat
# temen : temen
# teknisi : teknisi
# sumpah : sumpah
# dont : dont
# use : use
# can : can
# stress : stress
# enough : enough
# ffssssssss : ffssssssss
# ancur : ancur
# bnrbnr : bnrbnr
# top : top
# gila : gila
# kalah : kalah
# males : males
# bang : bang
# nonton : nonton
# mas : mas
# malem : malem
# gpp : gpp
# kuota : kuota
# abisin : abisin
# bsk : bsk
# sedih : sedih
# index : index
# media : media
# tagihan : tagih
# pakai : pakai
# myindihome : myindihome
# caur : caur
# bubar : bubar
# maen : maen
# gaple : gaple
# terhindar : hindar
# isolir : isolir
# fadli : fadli
# darin : darin
# permintaanya : permintaanya
# tanggal : tanggal
# jatuh : jatuh
# tempo : tempo
# bulannya : bulan
# sarankan : saran
# pembayaran : bayar
# drmh : drmh
# hilang : hilang
# tanoe : tanoe
# malam : malam
# panji : panji
# ngentot : ngentot
# balikin : balikin
# mbps : mbps
# fuck : fuck
# kah : kah
# kejadian : jadi
# gimana : gimana
# solusi : solusi
# kirain : kirain
# yangbermsalah : yangbermsalah
# aceh : aceh
# aman : aman
# elah : elah
# bangke : bangke
# sinyalnya : sinyal
# opo : opo
# ngopo : ngopo
# telponin : telponin
# org : org
# bareng : bareng
# ajg : ajg
# untung : untung
# tejadi : tejadi
# masang : masang
# ieu : ieu
# gecekan : gecek
# internetnya : internetnya
# shortlink : shortlink
# stephanie : stephanie
# maksimal : maksimal
# pernyebab : pernyebab
# banyaknya : banyak
# traffic : traffic
# jarak : jarak
# gadget : gadget
# batas : batas
# siang : siang
# hey : hey
# bisi : bis
# tuaran : tuar
# tihangna : tihangna
# firda : firda
# sobat : sobat
# dialami : alami
# faktor : faktor
# kinerja : kerja
# optimal : optimal
# terdaftar : daftar
# guys : guys
# billkin : billkin
# ngewa : ngewa
# macet : macet
# buka : buka
# doang : doang
# ccd : ccd
# knpsi : knpsi
# juana : juana
# irfan : irfan
# nama : nama
# pemilik : milik
# aktif : aktif
# lakukan : laku
# koordinasi : koordinasi
# eby : eby
# ngajak : ngajak
# gelud : gelud
# pliss : pliss
# sya : sya
# nak : nak
# tugas : tugas
# jadiii : jadiii
# jan : jan
# dongg : dongg
# paket : paket
# include : include
# amin : amin
# alhamdulillah : alhamdulillah
# zahlul : zahlul
# perhal : hal
# aktifnya : aktif
# lovely : lovely
# eror : eror
# mengumpat : umpat
# korbankan : korban
# dijadiin : dijadiin
# hotspot : hotspot
# slowresp : slowresp
# ngalahin : ngalahin
# speedy : speedy
# aulia : aulia
# keluhannya : keluh
# lambat : lambat
# betol : betol
# nggak : nggak
# tnya : tnya
# alfi : alf
# tim : tim
# secepa : secepa
# lumnya : lum
# ponsel : ponsel
# kunjungi : kunjung
# gusti : gusti
# saipul : saipul
# core : core
# tertancap : tancap
# perangkat : perangkat
# sebe : sebe
# hello : hello
# sdg : sdg
# bermasalah : masalah
# connect : connect
# ndihomecare : ndihomecare
# wais : wais
# naufal : naufal
# petugas : tugas
# estimasi : estimasi
# perbaikannya : baik
# gitu : gitu
# gercep : gercep
# rawan : rawan
# sad : sad
# boy : boy
# shit : shit
# jrgan : jrgan
# wijaya : wijaya
# hafiz : hafiz
# seputar : putar
# silahkan : silah
# permintaan : minta
# pengaduan : adu
# knpa : knpa
# wee : wee
# gta : gta
# roleplay : roleplay
# lohh : lohh
# connection : connection
# gaada : gaada
# ujan : ujan
# angin : angin
# bertingkah : ting
# kupikir : pikir
# abis : abis
# berulah : ulah
# tba : tba
# bsa : bsa
# browsing : browsing
# tks : tks
# bapuk : bapuk
# download : download
# ios : ios
# ceunah : ceunah
# teu : teu
# hararayang : hararayang
# nape : nape
# ngelek : ngelek
# gjls : gjls
# sat : sat
# tag : tag
# anjutnya : anjutnya
# ahra : ahra
# sel : sel
# maap : maap
# setau : tau
# maksud : maksud
# poin : poin
# gmn : gmn
# menentukan : tentu
# bersinyal : sinyal
# benci : benci
# kaliii : kaliii
# ngaruuhh : ngaruuhh
# hpku : hpku
# super : super
# cepet : cepet
# kadang : kadang
# patah : patah
# game : game
# pindah : pindah
# provider : provider
# mainnya : main
# lancar : lancar
# jaringain : jaringain
# bros : bros
# intetnetnya : intetnetnya
# lekas : lekas
# sembuh : sembuh
# masriorita : masriorita
# fun : fun
# bangsat : bangsat
# ttttttttytyyy : ttttttttytyyy
# msalah : msalah
# jagonya : jago
# tetiba : tetiba
# betingkah : beting
# uda : uda
# baikan : baik
# asik : asik
# dibulan : bulan
# ehe : ehe
# allo : allo
# banda : banda
# kau : kau
# rto : rto
# shareloc : shareloc
# berantam : rantam
# ding : ding
# lancarr : lancarr
# harapkan : harap
# call : call
# center : center
# tlp : tlp
# bicara : bicara
# perlakuan : laku
# pelayanan : layan
# tuhan : tuhan
# nntn : nntn
# trus : trus
# tbtb : tbtb
# berenti : renti
# arli : arli
# dinomor : nomor
# meningkatkan : tingkat
# kualitas : kualitas
# kedepannya : depan
# solved : solved
# gambar : gambar
# burik : burik
# diajak : ajak
# kompromi : kompromi
# aaa : aaa
# barusan : barusan
# azhar : azhar
# fadillah : fadil
# tindak : tindak
# lanjuti : lanjut
# tiket : tiket
# adahal : adahal
# dihubungi : hubung
# nomo : nomo
# liat : liat
# sikon : sikon
# trouble : trouble
# enozi : enozi
# cam : cam
# bersedih : sedih
# sulit : sulit
# purbalingga : purbalingga
# ternyataa : ternyataa
# nggaa : nggaa
# jaminan : jamin
# pelanggan : langgan
# rafi : rafi
# ngepet : ngepet
# baturaden : baturaden
# susah : susah
# jha : jha
# maniac : maniac
# always : always
# begadang : begadang
# sampe : sampe
# bgsaatt : bgsaatt
# aissss : aissss
# marah : marah
# woi : woi
# kota : kota
# purwokerto : purwokerto
# kena : kena
# bismillah : bismillah
# konyoll : konyoll
# jaringanmu : jaring
# mengganggu : ganggu
# kesenanganku : senang
# ditempat : tempat
# syaa : syaa
# tersambung : sambung
# yaang : yaang
# permisi : permisi
# eek : eek
# progres : progres
# konfirmasi : konfirmasi
# aura : aura
# kondisi : kondisi
# dijadwalkan : jadwal
# kunjungan : kunjung
# besok : besok
# allah : allah
# dendam : dendam
# ama : ama
# dian : dian
# ragu : ragu
# arya : arya
# kenapasi : napas
# nanya : nanya
# trs : trs
# try : try
# again : again
# pulsa : pulsa
# gimanaa : gimanaa
# jelek : jelek
# mksh : mksh
# kerjaannya : kerja
# flat : flat
# idup : idup
# ngerasa : ngerasa
# neomu : neomu
# lonely : lonely
# kali : kali
# ngeluh : ngeluh
# baca : baca
# blaa : blaa
# sabar : sabar
# ngapain : ngapain
# matiin : matiin
# pemberitahuan : pemberitahuan
# ganggu : ganggu
# drama : drama
# ngirim : ngirim
# bulanan : bulan
# adhhshs : adhhshs
# hapus : hapus
# postingan : postingan
# menjaga : jaga
# privasi : privasi
# data : data
# nanang : nanang
# sbentar : sbentar
# allahuakbar : allahuakbar
# eala : eala
# bantuan : bantu
# tercabut : cabut
# dinyalakan : nyala
# nadsol : nadsol
# lokasi : lokasi
# mengakibatkan : akibat
# listriknya : listrik
# blum : blum
# nomer : nomer
# bamyak : bamyak
# buktikan : bukti
# nge : nge
# buffering : buffering
# dei : dei
# fagyu : fagyu
# bicj : bicj
# gb : gb
# seharian : hari
# njir : njir
# kelar : kelar
# mantap : mantap
# ngandelin : ngandelin
# pemerintah : perintah
# errornya : errornya
# barengann : barengann
# aplikasinya : aplikasi
# merasakan : rasa
# kekecewaan : kecewa
# memakai : pakai
# sehari : hari
# oke : oke
# faizal : faizal
# ciri : ciri
# upss : upss
# official : official
# pengguna : guna
# simpati : simpati
# aje : aje
# kagak : kagak
# khusus : khusus
# keluarga : keluarga
# bae : bae
# etamah : etamah
# mbali : mbali
# rani : rani
# down : down
# sisi : sisi
# sentral : sentral
# belajar : ajar
# kehalang : halang
# ntar : ntar
# nnti : nnti
# lulus : lulus
# ngespace : ngespace
# this : this
# school : school
# invisible : invisible
# only : only
# people : people
# see : see
# kopi : kopi
# lanang : lanang
# arti : arti
# kenikmatan : nikmat
# sejati : sejati
# belinya : beli
# full : full
# album : album
# streaming : streaming
# battle : battle
# janji : janji
# patuhi : patuh
# rules : rules
# depok : depok
# adili : adil
# teroris : teroris
# prutect : prutect
# care : care
# hospital : hospital
# cash : cash
# mnet : mnet
# dirut : dirut
# bpjs : bpjs
# kesehatan : sehat
# router : router
# ditanggapi : tanggap
# thr : thr
# akutuh : akutuh
# penasaran : penasaran
# mimin : mimin
# medsos : medsos
# instagram : instagram
# caption : caption
# sll : sll
# membuatku : buat
# tertawa : tertawa
# dikala : kala
# hati : hati
# gundah : gundah
# gulana : gulana
# menghadapi : hadap
# beratnya : berat
# dunia : dunia
# jadikan : jadi
# jodohmu : jodoh
# belom : bom
# dibayar : bayar
# tersendat : sendat
# sendat : sendat
# gad : gad
# kepala : kepala
# lsg : lsg
# pusing : pusing
# mata : mata
# berat : berat
# ternyta : ternyta
# kelapran : kelapran
# yaahhh : yaahhh
# keburu : keburu
# habis : habis
# film : film
# burem : burem
# rugi : rugi
# suram : suram
# cie : cie
# tahan : tahan
# pembatasan : batas
# riz : riz
# registrasikan : registrasi
# mahar : mahar
# berminat : minat
# pasang : pasang
# langsung : langsung
# unduh : unduh
# playstore : playstore
# device : device
# berbasis : bas
# android : android
# appstore : appstore
# website : website
# nangis : nang
# pledis : pledis
# deden : deden
# menghapus : hapus
# mention : mention
# kerahasiaan : rahasia
# yopi : yopi
# resmi : resmi
# terbaru : baru
# kenape : kenape
# siii : siii
# ilang : ilang
# ilangan : ilangan
# bonus : bonus
# detik : detik
# loading : loading
# duo : duo
# social : social
# artist : artist
# song : song
# iheart : iheart
# need : need
# songchelin : songchelin
# guide : guide
# anniversary : anniversary
# sunny : sunny
# with : with
# dita : dita
# welcome : welcome
# back : back
# golden : golden
# jungkook : jungkook
# btob : btob
# freeze : freeze
# together : together
# diwilayah : wilayah
# kec : kec
# bojonggede : bojonggede
# bayaran : bayar
# ttp : ttp
# kocak : kocak
# bettt : bettt
# aslian : asli
# dasar : dasar
# telkom : telkom
# ngebuka : ngebuka
# ngabuburit : ngabuburit
# marathon : marathon
# korea : korea
# serasa : serasa
# monangis : monangis
# terharu : haru
# rebahannya : rebah
# drakor : drakor
# akang : akang
# minnn : minnn
# gampangin : gampangin
# pembayarannya : bayar
# tambahin : tambahin
# jnius : jnius
# ndak : ndak
# ituuu : ituuu
# tercium : cium
# aroma : aroma
# surgawi : surgawi
# gerangan : gerangan
# mb : mb
# alarm : alarm
# ontnya : ontnya
# yophie : yophie
# windarli : windarli
# rrpi : rrpi
# asksksks : asksksks
# inggit : inggit
# ahh : ahh
# bangga : bangga
# dikit : dikit
# signal : signal
# lemotnya : lot
# tensi : tensi
# haryo : haryo
# dialihkan : alih
# giliran : gilir
# komplain : komplain
# cuman : cuman
# ngapa : ngapa
# cocok : cocok
# hobi : hobi
# berbulan : bulan
# netflixan : netflixan
# puas : puas
# terkoneksi : koneksi
# prio : prio
# meninggal : tinggal
# tdak : tdak
# berkabar : kabar
# mahal : mahal
# rb : rb
# ampuunn : ampuunn
# dikasih : kasih
# kompensasi : kompensasi
# pandemi : pandemi
# buruk : buruk
# work : work
# from : from
# home : home
# terpaksa : paksa
# indonesia : indonesia
# lapo : lapo
# eneh : eneh
# bangkeeeeeeeee : bangkeeeeeeeee
# matikan : mati
# diurupkan : urup
# mending : mending
# loss : loss
# kbps : kbps
# uji : uji
# informasiin : informasiin
# detailnya : detail
# ohiya : ohiya
# cibe : cibe
# kakaknya : kakak
# masuk : masuk
# discord : discord
# pending : pending
# beneran : beneran
# akh : akh
# sepakat : sepakat
# anti : anti
# gaseru : gaseru
# rei : rei
# sediain : ain
# bundling : bundling
# asap : asap
# bedanya : beda
# dipermudah : mudah
# mytelkomsel : mytelkomsel
# senengnya : neng
# gabut : gabut
# ditemenin : ditemenin
# netfixan : netfixan
# doi : doi
# ngertiin : ngertiin
# gapernah : gapernah
# galau : galau
# doong : doong
# guebpakenya : guebpakenya
# pakek : pakek
# berseteru : seteru
# bersatu : satu
# bernapas : napas
# lega : lega
# mba : mba
# membagongkan : bagong
# rudet : rudet
# dipepet : pepet
# nontonnya : nontonnya
# dijamin : jamin
# jaya : jaya
# kun : kun
# soni : soni
# kendalanya : kendala
# rj : rj
# tercolok : colok
# cabut : cabut
# colok : colok
# bunyi : bunyi
# klik : klik
# port : port
# phone : phone
# pots : pots
# tel : tel
# taik : taik
# terbukti : bukti
# natalia : natalia
# direset : direset
# nol : nol
# usage : usage
# dihitung : hitung
# dapetnya : dapetnya
# guw : guw
# hadeh : hadeh
# cover : cover
# sempet : sempet
# ditinggal : tinggal
# tidur : tidur
# pacar : pacar
# milih : milih
# seminggu : minggu
# diundur : undur
# perbaika : perbaika
# nnya : nnya
# selesai : selesai
# mundur : mundur
# mei : mei
# isi : isi
# nelponin : nelponin
# hasil : hasil
# wfh : wfh
# demen : demen
# kenceng : kenceng
# parah : parah
# deal : deal
# wtf : wtf
# qrt : qrt
# isinya : isi
# buzzer : buzzer
# sibuk : sibuk
# urusin : urusin
# lupa : lupa
# nonstop : nonstop
# hiburannya : hibur
# semangat : semangat
# bacanya : baca
# ngegass : ngegass
# btw : btw
# kasian : kasi
# inces : inces
# alone : alone
# bella : bella
# sok : sok
# meresahkn : meresahkn
# ikatan : ikat
# damai : damai
# manfaatnya : manfaat
# kelancaran : lancar
# app : app
# goblok : goblok
# ngecheat : ngecheat
# apex : apex
# legends : legends
# kaga : kaga
# gamenya : gamenya
# otaknya : otak
# dimana : mana
# jir : jir
# tlg : tlg
# nyaaa : nyaaa
# khir : khir
# seneng : neng
# auto : auto
# jayaaa : jayaaa
# ciee : ciee
# akurrr : akurrr
# buruan : buru
# join : join
# ngebut : ngebut
# donk : donk
# prikitiiiw : prikitiiiw
# diskon : diskon
# hah : hah
# emng : emng
# menurutku : turut
# perpaduan : padu
# next : next
# time : time
# ajakin : ajakin
# kantor : kantor
# duh : duh
# ramadhan : ramadhan
# cobain : cobain
# bahagia : bahagia
# streamingan : streamingan
# acara : acara
# yuhuu : yuhuu
# layarnya : layar
# jernih : jernih
# pecinta : cinta
# saranin : saranin
# series : series
# buktiin : buktiin
# percaya : percaya
# pokoknya : pokok
# waah : waah
# bangett : bangett
# ajah : ajah
# udha : udha
# suka : suka
# rebahan : rebah
# ditemani : tani
# juaranya : juara
# terdabest : terdabest
# terbaik : baik
# fix : fix
# wajib : wajib
# dapetin : dapetin
# kepuasan : puas
# orangnya : orang
# oake : oake
# gaskeun : gaskeun
# boss : boss
# jomblo : jomblo
# ajjah : ajjah
# sihhh : sihhh
# namanya : nama
# amanlah : aman
# pakenya : pakenya
# daerah : daerah
# kutawaringin : kutawaringin
# kabupaten : kabupaten
# bandung : bandung
# hehehe : hehehe
# woah : woah
# obat : obat
# macem : macem
# tontonan : tonton
# hoho : hoho
# bufferingnya : bufferingnya
# buangettttt : buangettttt
# asli : asli
# tercinta : cinta
# ragukan : ragu
# berjam : jam
# nyesel : nyesel
# ngerasain : ngerasain
# terusss : terusss
# asikkk : asikkk
# asikk : asikk
# rekomen : rekomen
# adem : adem
# makasih : makasih
# servet : servet
# best : best
# valid : valid
# mantul : mantul
# hobby : hobby
# yupss : yupss
# netfix : netfix
# lancarnya : lancar
# ampun : ampun
# buffer : buffer
# like : like
# bahagianyaah : bahagianyaah
# akuu : akuu
# inibisa : inibisa
# bersantai : santa
# ria : ria
# siih : siih
# orang : orang
# ramah : ramah
# sahur : sahur
# sempetin : sempetin
# harinya : hari
# yaps : yaps
# yuhuuy : yuhuuy
# euy : euy
# mayan : mayan
# kaan : kaan
# mendingan : mending
# netflixin : netflixin
# guyyss : guyyss
# beuhhh : beuhhh
# pengalaman : alam
# macetan : macet
# yey : yey
# gampang : gampang
# rame : rame
# ayok : ayok
# ngadat : ngadat
# andalan : andal
# overthinking : overthinking
# gilaa : gilaa
# abiss : abiss
# diraguin : diraguin
# laju : laju
# filmnya : film
# nahhh : nahhh
# rahasia : rahasia
# guyss : guyss
# serahin : serahin
# nggada : nggada
# kamus : kamus
# hidup : hidup
# and : and
# chill : chill
# ngecewain : ngecewain
# nontonin : nontonin
# manfaatin : manfaatin
# luang : luang
# adek : adek
# kamar : kamar
# haqiqi : haqiqi
# coy : coy
# yuhuuu : yuhuuu
# niih : niih
# pasangannya : pasang
# movienya : movienya
# ngalamin : ngalamin
# jabanin : jabanin
# netflixa : netflixa
# woww : woww
# nahh : nahh
# okeee : okeee
# doyan : doyan
# beuhh : beuhh
# mantepp : mantepp
# benerr : benerr
# combo : combo
# serial : serial
# excited : excited
# nagih : nagih
# sekian : sekian
# lamaaa : lamaaa
# bela : bela
# belain : bain
# sinyalnyaaa : sinyalnyaaa
# sekalii : sekali
# uwaa : uwaa
# sepuasnya : puas
# penuh : penuh
# stranger : stranger
# things : things
# kerasa : rasa
# kelancarannya : lancar
# hambatan : hambat
# resolusi : resolusi
# tinggilah : tinggi
# mantep : mantep
# bund : bund
# urang : urang
# nyobaan : nyobaan
# liwat : liwat
# gor : gor
# gagal : gagal
# weh : weh
# bales : bales
# eta : eta
# ciyeeee : ciyeeee
# ciyeeeee : ciyeeeee
# nginstall : nginstall
# teruuus : teruuus
# garda : garda
# pasangan : pasang
# pantesan : pantesan
# vip : vip
# bala : bala
# apkh : apkh
# indigo : indigo
# spt : spt
# rmh : rmh
# macetnya : macet
# hihihi : hihihi
# waras : waras
# sebentar : sebentar
# gopay : gopay
# plus : plus
# sabi : sabi
# lemottttt : lemottttt
# muluuuuu : muluuuuu
# yuhuuuuu : yuhuuuuu
# sesuka : suka
# keren : keren
# happy : happy
# boring : boring
# shay : shay
# hape : hape
# laptop : laptop
# astagfirullah : astagfirullah
# jujur : jujur
# ngaco : ngaco
# naudzubillah : naudzubillah
# wait : wait
# tolonglah : tolong
# youtube : youtube
# lag : lag
# kaliloooo : kaliloooo
# yahud : yahud
# dihomecare : dihomecare
# lol : lol
# depannya : depan
# huruf : huruf
# rizky : rizky
# tindaklanjuti : tindaklanjuti
# belakangnya : belakang
# bingitss : bingitss
# salfok : salfok
# makanannya : makan
# ngeri : ngeri
# pamer : pamer
# sempaakk : sempaakk
# not : not
# kawaaannn : kawaaannn
# yeayyyy : yeayyyy
# collab : collab
# heh : heh
# piyee : piyee
# lemotttt : lemotttt
# cuan : cuan
# arek : arek
# asia : asia
# maxstream : maxstream
# penayangan : tayang
# episode : episode
# sabtu : sabtu
# minggu : minggu
# wib : wib
# huaaa : huaaa
# kesana : kesana
# los : los
# landungsari : landungsari
# malang : malang
# moga : moga
# spill : spill
# serunyaaa : serunyaaa
# anjrit : anjrit
# mager : mager
# tukang : tukang
# jualan : jual
# yesss : yesss
# collabs : collabs
# terusssss : terusssss
# gedek : gedek
# test : test
# toefl : toefl
# persyaratannya : syarat
# make : make
# dahlah : dah
# dikucilkan : kucil
# indah : indah
# mengadakan : ada
# direct : direct
# peering : peering
# dihasilkan : hasil
# kode : kode
# lokal : lokal
# kepo : kepo
# ngobrolinnya : ngobrolinnya
# netflixid : netflixid
# conect : conect
# asem : asem
# yuukk : yuukk
# yuuukk : yuuukk
# cylo : cylo
# gasinnn : gasinnn
# ngenetflix : ngenetflix
# mouse : mouse
# yeay : yeay
# astaghfirullah : astaghfirullah
# azekk : azekk
# wagiman : wagiman
# menyediakan : sedia
# mengaksesnya : akses
# broadband : broadband
# zaf : zaf
# rima : rima
# yusuf : yusuf
# akhirannya : akhir
# refresh : refresh
# terhenti : henti
# menit : menit
# berkala : kala
# hahah : hahah
# berita : berita
# wacana : wacana
# agensinya : agens
# wkwkwk : wkwkwk
# adit : adit
# follow : follow
# ditungu : tungu
# progresnya : progres
# percepatannya : cepat
# segerain : gain
# useetvnya : useetvnya
# etjieee : etjieee
# temenan : temenan
# skrng : skrng
# ngobrolin : ngobrolin
# inovasi : inovasi
# phoenix : phoenix
# allahummarhamna : allahummarhamna
# bil : bil
# qur : qur
# rahmatilah : rahmat
# ikuti : ikut
# tadarus : tadarus
# air : air
# lingkar : lingkar
# faedah : faedah
# program : program
# didukung : dukung
# berkah : berkah
# dikosan : dikosan
# that : that
# what : what
# got : got
# being : being
# user : user
# for : for
# years : years
# mbok : mbok
# heran : heran
# perasaan : asa
# indihomeeee : indihomeeee
# kann : kann
# euyy : euyy
# bukber : bukber
# ortu : ortu
# sctv : sctv
# bentar : bentar
# lahh : lahh
# engga : engga
# dahh : dahh
# klian : klian
# wahh : wahh
# diblur : diblur
# pantes : pantes
# bandwidth : bandwidth
# batasi : batas
# gakenal : gakenal
# ohhh : ohhh
# mbaknya : mbak
# level : level
# xixixi : xixixi
# nihh : nihh
# ajaa : ajaa
# setuju : tuju
# diblokir : blokir
# skr : skr
# maunya : mau
# out : out
# siapkan : siap
# study : study
# berbuka : buka
# watch : watch
# minutes : minutes
# miya : miya
# marso : marso
# hoo : hoo
# yak : yak
# dibalesnya : dibalesnya
# buset : buset
# gontok : gontok
# gontokan : gontok
# skrg : skrg
# mut : mut
# hahaha : hahaha
# handphone : handphone
# ruqyah : ruqyah
# dokumenter : dokumenter
# judulnya : judul
# never : never
# gausah : gausah
# hoky : hoky
# tumben : tumben
# allahuakhbar : allahuakhbar
# kesimpulannya : simpul
# kecepatan : cepat
# thx : thx
# mengakuinya : aku
# oalah : oalah
# lola : lola
# cieeee : cieeee
# ronde : ronde
# jail : jail
# awas : awas
# dibomb : dibomb
# sensor : sensor
# kerjasama : kerjasama
# bumn : bumn
# kesempatan : sempat
# memenangkan : menang
# hadiah : hadiah
# total : total
# jutaan : juta
# mengikuti : ikut
# utbk : utbk
# kelewatan : lewat
# bisnisnya : bisnis
# lempeng : lempeng
# bayangin : bayangin
# harga : harga
# kwalitas : kwalitas
# jaub : jaub
# nyungsep : nyungsep
# area : area
# myrepublic : myrepublic
# marketing : marketing
# mampus : mampus
# yok : yok
# txtfromnetflik : txtfromnetflik
# mencoba : coba
# pindahkan : pindah
# mode : mode
# otomatis : otomatis
# manual : manual
# kembalikan : kembali
# gelut : gelut
# sejelek : jelek
# jeleknya : jelek
# youtubean : youtubean
# dri : dri
# kmren : kmren
# wid : wid
# yer : yer
# kartu : kartu
# sebelah : belah
# murah : murah
# check : check
# versi : versi
# akah : akah
# dikenakan : kena
# biaya : biaya
# gatau : gatau
# ketebak : tebak
# teros : ros
# jiahhh : jiahhh
# sip : sip
# kyk : kyk
# reddit : reddit
# telkosmel : telkosmel
# canda : canda
# donggggggggggt : donggggggggggt
# normalisasi : normalisasi
# membenci : benci
# firstmedia : firstmedia
# perdana : perdana
# tri : tri
# lita : lita
# layanannya : layan
# berubah : ubah
# berap : rap
# kenapaa : kenapaa
# instal : instal
# dzaky : dzaky
# tayang : tayang
# mendadak : dadak
# republic : republic
# dicinta : cinta
# penduduk : duduk
# nusantara : nusantara
# ebih : ebih
# nanda : nanda
# tebak : tebak
# kiri : kiri
# lagu : lagu
# any : any
# dipanggil : panggil
# asliiii : asliiii
# meresahkan : resah
# ampe : ampe
# jingga : jingga
# reply : reply
# dibalas : balas
# bot : bot
# cinta : cinta
# indomeh : indomeh
# sukses : sukses
# membuang : buang
# buang : buang
# sihh : sihh
# konektivitas : konektivitas
# diperbaiki : baik
# kuotaku : kuota
# sekarat : sekarat
# benr : benr
# ddulu : ddulu
# nugas : nugas
# bismillahh : bismillahh
# apapun : apa
# beliin : beliin
# ritwit : ritwit
# seribu : ribu
# ntu : ntu
# saldo : saldo
# diakun : akun
# kirimkan : kirim
# capture : capture
# panggil : panggil
# cpt : cpt
# bikinin : bikinin
# horror : horror
# tuyul : tuyul
# ngelawan : ngelawan
# detektif : detektif
# polisi : polisi
# tonton : tonton
# jagoan : jago
# saksikan : saksi
# keseruannya : seru
# subscribe : subscribe
# penentuan : tentu
# peserta : serta
# grand : grand
# final : final
# gita : gita
# nada : nada
# papua : papua
# penyakin : penyakin
# ulah : ulah
# wae : wae
# atuh : atuh
# keneh : keneh
# kaget : kaget
# buenci : buenci
# karo : karo
# asuuuu : asuuuu
# bestie : bestie
# kenala : nala
# binance : binance
# positif : positif
# adzan : adzan
# magrib : magrib
# muadzinnya : muadzinnya
# delay : delay
# awawawaw : awawawaw
# bertamunya : tamu
# kompetitor : kompetitor
# wih : wih
# jancok : jancok
# kabeh : kabeh
# ngomongin : ngomongin
# hantu : hantu
# notabene : notabene
# jin : jin
# ngotot : ngotot
# situ : situ
# setan : setan
# ngilang : ngilang
# manusia : manusia
# melulu : melulu
# dikatain : dikatain
# jahat : jahat
# beribadah : ibadah
# ngab : ngab
# sepaket : paket
# dicampakkan : campak
# duluuuuuuu : duluuuuuuu
# buluk : buluk
# sebulan : bulan
# massal : massal
# costumer : costumer
# experience : experience
# perbaiki : baik
# ngobrolnya : ngobrolnya
# rilis : rilis
# statistik : statistik
# berdasarkan : dasar
# operator : operator
# model : model
# kabur : kabur
# nambah : nambah
# renew : renew
# pilihannya : pilih
# disana : sana
# diharuskan : harus
# aktivasi : aktivasi
# dlu : dlu
# pin : pin
# saldonya : saldo
# dikirim : kirim
# kemana : mana
# email : email
# sms : sms
# benernya : benernya
# yes : yes
# paketan : paket
# setahun : tahun
# terputus : putus
# dehhhh : dehhhh
# suruh : suruh
# larang : larang
# tayangan : tayang
# ecieeee : ecieeee
# queen : queen
# abdul : abdul
# proses : proses
# pemasangan : pasang
# kepastian : pasti
# tersedia : sedia
# status : status
# pull : pull
# service : service
# uyy : uyy
# bakar : bakar
# sumpeh : sumpeh
# saingan : saing
# dkk : dkk
# melatih : latih
# kesabaran : sabar
# apaaaa : apaaaa
# lhooooo : lhooooo
# self : self
# upload : upload
# plot : plot
# twist : twist
# somehow : somehow
# loaded : loaded
# into : into
# world : world
# without : without
# even : even
# logging : logging
# your : your
# assed : assed
# managed : managed
# broke : broke
# fallout : fallout
# which : which
# itself : itself
# already : already
# buggy : buggy
# nasi : nasi
# projectan : projectan
# anyar : anyar
# notifikasi : notifikasi
# layar : layar
# aisia : aisia
# zasa : zasa
# laporkan : lapor
# selengkapnya : lengkap
# serba : serba
# blur : blur
# tipi : tipi
# tingkah : tingkah
# xixix : xixix
# ciye : ciye
# seriusan : serius
# collabnya : collabnya
# adain : adain
# pembelian : beli
# subscription : subscription
# hotstar : hotstar
# asikkkl : asikkkl
# pemutusan : putus
# dadan : dad
# dompet : dompet
# money : money
# add : add
# kredit : kredit
# slot : slot
# gueee : gueee
# slotnya : slotnya
# kosong : kosong
# dikejer : kejer
# emak : emak
# nie : nie
# monmaap : monmaap
# bilangin : bilangin
# lewatin : lewatin
# ngurangin : ngurangin
# ngilangin : ngilangin
# login : login
# akurr : akurr
# akurnya : akur
# senang : senang
# yya : yya
# diseluruh : seluruh
# pelosok : pelosok
# fo : fo
# dana : dana
# bayarnya : bayar
# ngampus : ngampus
# dada : dada
# loadingnya : loadingnya
# lamaaaa : lamaaaa
# bangetttttt : bangetttttt
# ovo : ovo
# diaku : dia
# tajem : tajem
# block : block
# makannya : makan
# tumpeng : tumpeng
# mini : mini
# ott : ott
# ato : ato
# pelanggannya : langgan
# premium : premium
# ono : ono
# neng : neng
# flop : flop
# yoo : yoo
# omah : omah
# iso : iso
# wifian : wifian
# bebas : bebas
# mudik : mudik
# teruss : teruss
# tamabahin : tamabahin
# metode : metode
# pembayarannyaa : pembayarannyaa
# first : first
# date : date
# bangettt : bangettt
# temanku : teman
# kroso : kroso
# disambi : sambi
# users : users
# salaman : salam
# nina : nina
# kmaren : kmaren
# dimention : dimention
# lemlot : lemlot
# meluncuuuurrr : meluncuuuurrr
# baris : baris
# ketersediaan : sedia
# mandiri : mandiri
# play : play
# store : store
# promo : promo
# dpet : dpet
# alat : alat
# chat : chat
# gaming : gaming
# samanya : sama
# non : non
# sengsara : sengsara
# konten : konten
# filtering : filtering
# nis : nis
# sahabat : sahabat
# karib : karib
# yookk : yookk
# gawean : gawean
# loba : loba
# nebeng : nebeng
# ketawa : ketawa
# netflixnya : netflixnya
# maksudnya : maksud
# box : box
# install : install
# taro : taro
# muka : muka
# meeting : meeting
# ikutan : ikut
# astagaaaa : astagaaaa
# satrya : satrya
# urusannya : urus
# monthversary : monthversary
# matinya : mati
# dirayain : dirayain
# gakk : gakk
# pasar : pasar
# jati : jati
# padang : padang
# tercover : tercover
# homecare : homecare
# valzz : valzz
# sesuai : sesuai
# amirsyarif : amirsyarif
# wkwkwkwkkkkk : wkwkwkwkkkkk
# dipuja : puja
# puja : puja
# dihina : hina
# hina : hina
# ngimpi : ngimpi
# ayolah : ayo
# permudah : mudah
# pribadi : pribadi
# kerjaan : kerja
# jagain : jagain
# khabisan : khabis
# dikabari : kabar
# bhw : bhw
# senin : senin
# selasa : selasa
# smp : smp
# dpasang : dpasang
# tmn : tmn
# trims : trims
# belajarnya : ajar
# takut : takut
# connected : connected
# disconnected : disconnected
# dulunya : dulunya
# musuhan : musuh
# deketan : deketan
# gemay : gemay
# kaka : kaka
# kenalaan : nala
# telegram : telegram
# dahhhh : dahhhh
# baiknya : baik
# menyusul : susul
# sensar : sensar
# apaaa : apaaa
# pira : pira
# arif : arif
# produk : produk
# rencana : rencana
# mendikbud : mendikbud
# jalin : jalin
# partnership : partnership
# statistika : statistika
# dikuras : kuras
# mengerti : erti
# eciee : eciee
# diajar : ajar
# ajarin : ajarin
# tanda : tanda
# tangan : tangan
# kontrak : kontrak
# mengajukan : aju
# gasi : gas
# kecepatannya : cepat
# maksut : maksut
# mmg : mmg
# butuh : butuh
# scepatbya : scepatbya
# dlm : dlm
# wkt : wkt
# trima : trima
# uppp : uppp
# kehabisan : habis
# ngecek : ngecek
# dipasang : pasang
# masangnya : masangnya
# kmgknan : kmgknan
# bnar : bnar
# dicekik : cekik
# bandwithnya : bandwithnya
# good : good
# kelen : kelen
# syg : syg
# akrab : akrab
# indomaret : indomaret
# utan : utan
# kayu : kayu
# utara : utara
# patria : patria
# love : love
# hate : hate
# relationship : relationship
# ciieee : ciieee
# langgeng : langgeng
# minn : minn
# least : least
# wallet : wallet
# widevine : widevine
# yutub : yutub
# rekomendasi : rekomendasi
# terhubung : hubung
# interaski : interaski
# lino : lino
# mengurangi : kurang
# karen : karen
# peluang : peluang
# dimaafkan : maaf
# sajaaaa : sajaaaa
# pingin : pingin
# nyenengno : nyenengno
# soale : soale
# mbah : mbah
# onok : onok
# gaet : gaet
# keliatan : liat
# sung : sung
# jokowi : jokowi
# prabowo : prabowo
# tflix : tflix
# hhh : hhh
# diliat : liat
# berantem : antem
# bedua : bedua
# blokir : blokir
# dibuka : buka
# blocknya : blocknya
# mahh : mahh
# cieeeee : cieeeee
# sohib : sohib
# digandeng : gandeng
# hih : hih
# dibuang : buang
# sepah : sepah
# dimanis : man
# pagawean : pagawean
# goblog : goblog
# yee : yee
# ayoooooo : ayoooooo
# pengumuman : umum
# rank : rank
# anjjjjjjj : anjjjjjjj
# aaaaaaaaa : aaaaaaaaa
# jadian : jadi
# tho : tho
# saia : saia
# seharga : harga
# rp : rp
# ppn : ppn
# arandi : arandi
# dibatalkan : batal
# pemasangannya : pasang
# disayangkan : sayang
# menikmati : nikmat
# benefit : benefit
# dipertimbangkan : timbang
#  : 
# bisain : bisain
# kawan : kawan
# kawannya : kawan
# diwujudkannya : wujud
# kantornya : kantor
# ngobrol : ngobrol
# sekijeu : sekijeu
# rohendi : rohendi
# menyaksikan : saksi
# uel : uel
# antena : antena
# uhf : uhf
# vidio : vidio
# anjuti : anjuti
# stevani : stevani
# angka : angka
# wkkwk : wkkwk
# kom : kom
# menyesuaikan : sesuai
# kebijakan : bijak
# antisipasi : antisipasi
# covid : covid
# prose : prose
# delis : delis
# operasional : operasional
# plasa : plasa
# jumat : jumat
# istirahat : istirahat
# bingung : bingung
# jt : jt
# capek : capek
# duhh : duhh
# gagabah : gagabah
# omahku : omahku
# gaonok : gaonok
# sing : sing
# ngecover : ngecover
# linkaja : linkaja
# smartfren : smartfren
# lgi : lgi
# gblok : gblok
# skz : skz
# gan : gan
# pdhl : pdhl
# alfatih : alfatih
# buber : buber
# bagikan : bagi
# momen : momen
# yaela : yaela
# gausa : gausa
# hbo : hbo
# sayang : sayang
# konslet : konslet
# masukan : masuk
# chanel : chanel
# fail : fail
# maw : maw
# dateng : dateng
# kecuali : kecuali
# kemaleman : maleman
# bersyukur : syukur
# galiat : galiat
# ngd : ngd
# when : when
# will : will
# spacex : spacex
# released : released
# bored : bored
# demiallah : allah
# solusinya : solusi
# nyerah : nyerah
# armalice : armalice
# ngulah : ngulah
# berbaik : baik
# akutu : akutu
# ujannnn : ujannnn
# hypera : hypera
# wrong : wrong
# diinformasikan : informasi
# teridentifikasi : identifikasi
# berdampak : dampak
# kayanya : kaya
# indohome : indohome
# ateez : ateez
# nana : nana
# suujon : suujon
# nyalanya : nyala
# dibagian : bagi
# internetnyq : internetnyq
# disalahin : disalahin
# aduh : aduh
# perform : perform
# mslah : mslah
# sma : sma
# anying : anying
# gypera : gypera
# kece : kece
# now : now
# efeknya : efek
# indomie : indomie
# bjinksut : bjinksut
# alah : alah
# knapa : knapa
# lemoott : lemoott
# skarang : skarang
# live : live
# tenang : tenang
# dogan : dog
# mendengar : dengar
# andre : andre
# sehat : sehat
# bersemangat : semangat
# hindari : hindar
# kerumunan : kerumun
# senantiasa : senantiasa
# jaga : jaga
# usahakan : usaha
# nnton : nnton
# mcm : mcm
# anjinggg : anjinggg
# tandain : tandain
# sumpa : sumpa
# inimah : inimah
# mutiara : mutiara
# kartika : kartika
# statusnya : status
# bun : bun
# akibat : akibat
# muscida : muscida
# sergeant : sergeant
# weiissss : weiissss
# cicaheum : cicaheum
# jelekan : jelek
# merayakan : raya
# lebaran : lebaran
# kemudahan : mudah
# festivalnya : festival
# lomba : lomba
# challenge : challenge
# abisan : abis
# tdi : tdi
# mih : mih
# dilaporin : dilaporin
# jga : jga
# ttep : ttep
# silah : silah
# mimpi : mimpi
# ngusap : ngusap
# jidat : jidat
# ngeliat : ngeliat
# badan : badan
# peluk : peluk
# kurus : kurus
# bangun : bangun
# posisi : posisi
# mumi : mumi
# mesir : mesir
# uga : uga
# interakasi : interakasi
# dhani : dhani
# mendaftarkan : daftar
# smooa : smooa
# landing : landing
# page : page
# memiliki : milik
# plisssss : plisssss
# anjrot : anjrot
# elh : elh
# telak : telak
# jamet : jamet
# jujuran : jujuran
# arifa : arifa
# gebyar : gebyar
# janjug : janjug
# are : are
# iyud : iyud
# joash : joash
# kirim : kirim
# inbox : inbox
# internetku : internetku
# enhypen : enhypen
# ngetwit : ngetwit
# beresnya : beres
# berbagi : bagi
# pancoran : pancoran
# berfungsi : fungsi
# yakyu : yakyu
# stay : stay
# safe : safe
# healthy : healthy
# exp : exp
# ngs : ngs
# saran : saran
# upgradenya : upgradenya
# harap : harap
# jdi : jdi
# kakakku : kakak
# muahh : muahh
# fahmi : fahmi
# cashback : cashback
# tunai : tunai
# mecahin : mecahin
# gelas : gelas
# kebanting : banting
# beling : beling
# berantakan : beranta
# serpihannya : serpih
# ketinggal : tinggal
# karpet : karpet
# kucing : kucing
# dalem : dalem
# kegesek : gesek
# lebar : lebar
# berdarah : darah
# wangga : wangga
# unpren : unpren
# tlng : tlng
# soalny : soalny
# pov : pov
# you : you
# semalem : semalem
# pos : pos
# jasa : jasa
# blom : blom
# haduuuuh : haduuuuh
# lgie : lgie
# mengambil : ambil
# alih : alih
# tanggung : tanggung
# nyawa : nyawa
# bayarannya : bayar
# nikmati : nikmat
# podcast : podcast
# horpen : horpen
# horor : horor
# pendek : pendek
# hifi : hifi
# langit : langit
# musik : musik
# adam : adam
# terindikasi : indikasi
# gas : gas
# podo : podo
# gawe : gawe
# wife : wife
# sapi : sapi
# kana : kana
# dodolan : dodol
# dimsum : dimsum
# lakoni : lakon
# sampek : sampek
# cowok : cowok
# benalu : benalu
# ceweknya : cewek
# jelasin : jelasin
# perjuangannya : juang
# perempuan : perempuan
# berdiri : diri
# gihan : gihan
# sigi : sigi
# din : din
# penggantian : ganti
# verifikasi : verifikasi
# alamat : alamat
# ape : ape
# gimane : gimane
# adryan : adryan
# upayakan : upaya
# tersolusikan : solusi
# sukanya : suka
# rewel : rewel
# atuhhh : atuhhh
# rek : rek
# plan : plan
# lebaranku : lebaran
# zoom : zoom
# kangen : kangen
# terbalaskan : balas
# naikkin : naikkin
# bngt : bngt
# bawa : bawa
# nopel : nopel
# indikator : indikator
# colek : colek
# yaaa : yaaa
# ngana : ngana
# nder : nder
# liane : liane
# kontrakan : kontra
# nyapo : nyapo
# ngene : ngene
# wes : wes
# enek : enek
# jebol : jebol
# seng : seng
# nengdi : nengdi
# koyo : koyo
# siput : siput
# cah : cah
# iklan : iklan
# aturan : atur
# larangan : larang
# pancet : pancet
# gbisa : gbisa
# gmnaaa : gmnaaa
# lur : lur
# maeng : maeng
# kuah : kuah
# ndog : ndog
# teh : teh
# anget : anget
# ngerti : ngerti
# awan : awan
# wkwkwkkw : wkwkwkkw
# iyaaa : iyaaa
# bgttttt : bgttttt
# bgr : bgr
# way : way
# adaa : adaa
# akeh : akeh
# niat : niat
# nyediain : nyediain
# useetv : useetv
# kiky : kiky
# dighosting : dighosting
# beres : beres
# sambung : sambung
# tante : tante
# merger : merger
# wkwkwkwk : wkwkwkwk
# festival : festival
# edisi : edisi
# spesial : spesial
# ramadan : ramadan
# posting : posting
# bertema : tema
# virtual : virtual
# menangkan : menang
# agung : agung
# mengaktifkan : aktif
# fitur : fitur
# seamless : seamless
# ane : ane
# dinotis : not
# ngezoom : ngezoom
# uts : uts
# menfess : menfess
# kbs : kbs
# url : url
# broo : broo
# ngontak : ngontak
# mksdunya : mksdunya
# apaa : apaa
# kiki : kiki
# memudahkan : mudah
# sertain : sertain
# terjaga : jaga
# pingnya : pingnya
# bos : bos
# ihh : ihh
# itupun : itu
# dikejar : kejar
# deadline : deadline
# dibutuhkan : butuh
# hiks : hiks
# babik : babik
# utama : utama
# com : com
# telkomdigitalsolution : telkomdigitalsolution
# lian : lian
# yuniar : yuniar
# surat : surat
# voice : voice
# fanpage : fanpage
# facebook : facebook
# digital : digital
# solution : solution
# pertanda : tanda
# masya : masya
# ukhti : ukhti
# membawa : bawa
# hnya : hnya
# lihat : lihat
# loe : loe
# lmbat : lmbat
# jinjja : jinjja
# membuka : buka
# juli : juli
# dikeluhkan : keluh
# berkualitas : kualitas
# msi : msi
# brapa : brapa
# match : match
# day : day
# group : group
# pertemuan : temu
# hero : hero
# imperial : imperial
# legacy : legacy
# gamer : gamer
# diklite : diklite
# esport : esport
# tournament : tournament
# season : season
# mobile : mobile
# logo : logo
# ares : ares
# ruang : ruang
# brisik : brisik
# bacain : bacain
# carrd : carrd
# tweet : tweet
# kacangin : kacangin
# telepon : telepon
# inu : inu
# desu : desu
# fisik : fisik
# either : either
# bias : bias
# tipe : tipe
# nerawang : nerawang
# batin : batin
# manner : manner
# pikiran : pikir
# nyambung : nyambung
# ganya : ganya
# mubadzir : mubadzir
# gapapa : gapapa
# membuah : buah
# muter : muter
# bertele : tele
# tele : tele
# ida : ida
# mendengarnya : dengar
# jincpaii : jincpaii
# kento : kento
# daniel : daniel
# sulis : sulis
# berisi : isi
# maksimalnya : maksimal
# bisnis : bisnis
# ema : ema
# nelpon : nelpon
# beda : beda
# ngomong : ngomong
# hooq : hooq
# laku : laku
# ditutup : tutup
# pengganti : ganti
# disney : disney
# iflix : iflix
# hahahahahaha : hahahahahaha
# say : say
# pelanggat : pelanggat
# tertanda : tanda
# prime : prime
# masyaallah : masyaallah
# pkonya : pkonya
# muluuuu : muluuuu
# ditelpon : telpon
# silang : silang
# iyaa : iyaa
# looh : looh
# terooss : terooss
# intra : intra
# vpn : vpn
# kontennya : konten
# blok : blok
# apasi : apas
# melapor : lapor
# pensiun : pensiun
# lawan : lawan
# gew : gew
# ttg : ttg
# deposit : deposit
# depri : depri
# oci : oci
# berhubung : hubung
# menghentikan : henti
# petunjuk : tunjuk
# penutupan : tutup
# ciputat : ciputat
# tangsel : tangsel
# rubah : rubah
# llow : llow
# auli : auli
# pedot : pedot
# kesampar : sampar
# truk : truk
# lek : lek
# dandani : dandan
# masal : masal
# bln : bln
# depositnya : deposit
# bayarkan : bayar
# penunjukan : tunjuk
# erima : erima
# tombol : tombol
# alami : alami
# jaah : jaah
# ketidaknyamanannya : ketidaknyamanannya
# tawaran : tawar
# nolak : nolak
# maksa : maksa
# dihubungin : dihubungin
# teratasi : atas
# allahhh : allahhh
# why : why
# doing : doing
# such : such
# bad : bad
# timing : timing
# tertanggal : tanggal
# dirasa : rasa
# kendur : kendur
# kelanjutan : lanjut
# katany : katany
# pnya : pnya
# ngeloss : ngeloss
# gapunya : gapunya
# balesan : balesan
# babibgt : babibgt
# nyebelin : nyebelin
# hdh : hdh
# maknai : makna
# suci : suci
# regional : regional
# wujudkan : wujud
# leyline : leyline
# jadwal : jadwal
# siaran : siar
# semifinal : semifinal
# europa : europa
# league : league
# champions : champions
# premier : premier
# prediksi : prediksi
# ara : ara
# moza : moza
# ngawasin : ngawasin
# neh : neh
# koe : koe
# ncen : ncen
# bangeet : bangeet
# wadidaw : wadidaw
# disetiap : tiap
# kegiatan : giat
# aziz : aziz
# menerapkan : terap
# protokol : protokol
# panas : panas
# haus : haus
# halu : halu
# ketiduran : tidur
# dimarain : dimarain
# daah : daah
# wetv : wetv
# nyetel : nyetel
# browser : browser
# iqiyi : iqiyi
# menahanku : tahan
# maren : maren
# kekirim : kirim
# menyebalkan : sebal
# bsd : bsd
# jls : jls
# hujan : hujan
# loyo : loyo
# hebat : hebat
# naila : naila
# terlebihi : lebih
# dipake : dipake
# nga : nga
# dhuhur : dhuhur
# buru : buru
# thank : thank
# uuu : uuu
# gaes : gaes
# tema : tema
# kuy : kuy
# lumayan : lumayan
# cirebon : cirebon
# menarik : tarik
# gratisan : gratis
# skin : skin
# legend : legend
# free : free
# fire : fire
# lokapala : lokapala
# hubungin : hubungin
# eldy : eldy
# roe : roe
# zheyenk : zheyenk
# ollow : ollow
# manda : manda
# sopi : sopi
# disalahgunakan : disalahgunakan
# ngambil : ngambil
# selebrasi : selebrasi
# corner : corner
# sambut : sambut
# tik : tik
# tok : tok
# setegar : tegar
# bangkit : bangkit
# ilustrator : ilustrator
# salut : salut
# bangsatttt : bangsatttt
# christian : christian
# lumrah : lumrah
# blessing : blessing
# dihe : dihe
# fida : fida
# geura : geura
# abd : abd
# brarti : brarti
# waalaikumsalam : waalaikumsalam
# disystem : disystem
# terbar : bar
# kgk : kgk
# nikah : nikah
# indomilk : indomilk
# indosat : indosat
# ngaku : ngaku
# bedakan : beda
# goa : goa
# tutup : tutup
# cbn : cbn
# eottoke : eottoke
# karinka : karinka
# alamatnya : alamat
# menginformasikan : informasi
# ciany : ciany
# assalamualaikum : assalamualaikum
# warahmatullahi : warahmatullahi
# wabarakatuh : wabarakatuh
# memancing : pancing
# kepancing : pancing
# speednya : speednya
# pindahnya : pindah
# dipindahkan : pindah
# amaravati : amaravati
# auzan : auzan
# maudi : maudi
# lengkap : lengkap
# valent : valent
# menemani : tani
# warga : warga
# smua : smua
# tbk : tbk
# kee : kee
# memng : memng
# demo : demo
# datangi : datang
# pindahin : pindahin
# andini : andini
# hoii : hoi
# manapun : mana
# benerin : benerin
# pemasanagan : pemasanagan
# iuran : iur
# neflix : neflix
# bolak : bolak
# mslh : mslh
# jawabannya : jawab
# jlas : jlas
# gada : gada
# remote : remote
# lib : lib
# haloo : haloo
# merintis : rintis
# odp : odp
# penambahan : tambah
# elo : elo
# cerita : cerita
# gbr : gbr
# nich : nich
# bacooot : bacooot
# otak : otak
# keciil : keciil
# baguslah : bagus
# throttle : throttle
# lrt : lrt
# jametnesia : jametnesia
# tolol : tolol
# dipiara : piara
# mari : mari
# jalanin : jalanin
# memangnya : memang
# dirmh : dirmh
# hp : hp
# ter : ter
# rosma : rosma
# respond : respond
# samsek : samsek
# cht : cht
# satupun : satu
# sekaliiiii : sekaliiiii
# adab : adab
# how : how
# spell : spell
# hoe : hoe
# adakah : ada
# powernya : powernya
# batre : batre
# menyusahkan : susah
# dunk : dunk
# bnegt : bnegt
# dwi : dwi
# ulia : ulia
# minipack : minipack
# telemarketing : telemarketing
# menawarkan : tawar
# sop : sop
# telemarketingnya : telemarketingnya
# dibaca : baca
# ubah : ubah
# daya : daya
# jangkau : jangkau
# jicha : jicha
# berpergian : pergi
# beraktifitas : beraktifitas
# lui : lui
# hadi : had
# support : support
# menikmatinya : nikmat
# mela : mela
# omg : omg
# selemat : lat
# berpuasa : puasa
# okay : okay
# gasie : gasie
# kerenn : kerenn
# puasanya : puasa
# mantapp : mantapp
# ambohhhhh : ambohhhhh
# bestlah : bestlah
# kereennn : kereennn
# mbak : mbak
# nawarin : nawarin
# upgrade : upgrade
# pikir : pikir
# tabungku : tabung
# disambungin : disambungin
# bocil : bocil
# praktis : praktis
# hide : hide
# munculin : munculin
# fasilitas : fasilitas
# tyan : tyan
# sod : sod
# berkat : berkat
# livenya : livenya
# ceramah : ceramah
# nntonnya : nntonnya
# ilmunya : ilmu
# terserap : serap
# keutamaan : utama
# surah : surah
# fatihah : fatihah
# fasting : fasting
# menjalankan : jalan
# kedepan : depan
# kolaborasi : kolaborasi
# bro : bro
# heck : heck
# hff : hff
# kumatt : kumatt
# aplod : aplod
# siah : siah
# zong : zong
# mood : mood
# kebangun : bangun
# mimpinya : mimpi
# demand : demand
# diaplikasinya : aplikasi
# multitasking : multitasking
# pilihan : pilih
# jitu : jitu
# eug : eug
# internya : internya
# potonya : potonya
# kebuka : buka
# mommy : mommy
# terrr : terrr
# mami : mami
# file : file
# nemenin : nemenin
# kartun : kartun
# kesayangannya : sayang
# priy : priy
# mola : mola
# njr : njr
# lgsng : lgsng
# ditanggepinnya : ditanggepinnya
# ree : ree
# tetangga : tetangga
# eeh : eeh
# medan : medan
# catchplay : catchplay
# movie : movie
# sinyalnye : sinyalnye
# maya : maya
# lokasinya : lokasi
# bruh : bruh
# luat : luat
# kyungwoo : kyungwoo
# situmorang : situmorang
# pengecekkan : ecek
# xixi : xixi
# ketajaman : tajam
# disesuaikan : sesuai
# alvin : alvin
# konfigurasi : konfigurasi
# inet : inet
# matiiiiiii : matiiiiiii
# penipuan : tipu
# lambaaat : lambaaat
# berkali : kali
# pengaruh : pengaruh
# dinormalkan : normal
# dialog : dialog
# parabola : parabola
# satelit : satelit
# frekwensi : frekwensi
# mhz : mhz
# rate : rate
# tvmui : tvmui
# unstabil : unstabil
# mikir : mikir
# sblm : sblm
# cari : cari
# customer : customer
# mmnk : mmnk
# terpkok : terpkok
# hola : hola
# pelambatan : lambat
# normalnya : normal
# sblmnya : sblmnya
# panen : panen
# wowww : wowww
# fatalnya : fatal
# dikonfirm : dikonfirm
# direfund : direfund
# berulang : ulang
# keong : keong
# dendanya : denda
# dibilang : bilang
# dinaikkan : naik
# skala : skala
# prioritas : prioritas
# dijanji : janji
# tertransfer : transfer
# kebrapa : kebrapa
# pengakhiran : akhir
# month : month
# throttling : throttling
# don : don
# feel : feel
# anymore : anymore
# maret : maret
# mengkonfirm : mengkonfirm
# nyok : nyok
# sinyak : sinyak
# pahamify : pahamify
# kenapasiiiiiii : kenapasiiiiiii
# aduuuuuuuhhhhhh : aduuuuuuuhhhhhh
# bgttttttt : bgttttttt
# drtd : drtd
# yaaaaa : yaaaaa
# anjiiiinkkkkkkkkkkkkk : anjiiiinkkkkkkkkkkkkk
# maa : maa
# im : im
# disistem : sistem
# teknisinya : teknisi
# lepas : lepas
# ibadah : ibadah
# oia : oia
# postingannya : postingannya
# hubung : hubung
# denga : denga
# dengerin : dengerin
# kiat : kiat
# membangun : bangun
# karakter : karakter
# smart : smart
# inovatif : inovatif
# fatonah : fatonah
# ustadz : ustadz
# materinya : materi
# penyampaian : sampai
# materi : materi
# lup : lup
# mnding : mnding
# telkomselnya : telkomselnya
# plss : plss
# pemberhentian : henti
# sandra : sandra
# protes : protes
# tae : tae
# yog : yog
# have : have
# gsung : gsung
# lan : lan
# charity : charity
# dek : dek
# rahma : rahma
# mengembangkan : kembang
# bakatnya : bakat
# indonseia : indonseia
# kasali : kasali
# ganguann : ganguann
# kohh : kohh
# komplekku : komplekku
# sagara : sagara
# mnc : mnc
# vision : vision
# whatsapp : whatsapp
# kapok : kapok
# kandang : kandang
# singa : singa
# macan : macan
# diperumahan : rumah
# tertulis : tulis
# perumahan : rumah
# req : req
# expand : expand
# tremor : tremor
# cakung : cakung
# timur : timur
# jakrta : jakrta
# saking : saking
# mantapnya : mantap
# periodik : periodik
# sinusoid : sinusoid
# echa : echa
# segmentasi : segmentasi
# ricky : ricky
# dicoba : coba
# digit : digit
# memutuskan : putus
# optimasi : optimasi
# domestik : domestik
# gbh : gbh
# rokuta : rokuta
# team : team
# babak : babak
# jawa : jawa
# barat : barat
# setel : setel
# pasir : pasir
# ditungguin : ditungguin
# sejam : jam
# berdamai : damai
# diserang : serang
# fans : fans
# ngeblok : ngeblok
# bau : bau
# adiet : adiet
# batal : batal
# aamiin : aamiin
# nyari : nyari
# jugaa : jugaa
# balesss : balesss
# menginformasikanya : menginformasikanya
# meginformasikan : meginformasikan
# bersifat : sifat
# pribati : pribati
# ngiklan : ngiklan
# bnr : bnr
# nirakhlak : nirakhlak
# lmao : lmao
# kanal : kanal
# alternatif : alternatif
# nurunin : nurunin
# tampilan : tampil
# budi : budi
# perangkatnya : perangkat
# unt : unt
# eksplorasi : eksplorasi
# dria : dria
# kalwibi : kalwibi
# konfirmasinya : konfirmasi
# jumpa : jumpa
# berinteraksi : interaksi
# riil : riil
# disengaja : sengaja
# azka : azka
# jojo : jojo
# ngida : ngida
# dirapihkan : dirapihkan
# dipotong : potong
# lei : lei
# melewati : lewat
# wajar : wajar
# suhu : suhu
# niatan : niat
# biznet : biznet
# chamidah : chamidah
# shopee : shopee
# barang : barang
# gagak : gagak
# jarang : jarang
# nyentuh : nyentuh
# kkwkwkkwkkw : kkwkwkkwkkw
# aiiihh : aiiihh
# ambil : ambil
# sub : sub
# nyaaaa : nyaaaa
# jerink : jerink
# meledug : meledug
# msup : msup
# omecare : omecare
# ytan : ytan
# hlo : hlo
# muluu : muluu
# kmarin : kmarin
# yakann : yakann
# punyaku : punya
# sialan : sial
# nelfon : nelfon
# csnya : csnya
# dilapangan : lapang
# dichat : dichat
# sorenya : sore
# wkwkwkw : wkwkwkw
# hadirkan : hadir
# netlix : netlix
# mengumumkan : umum
# kemitraan : mitra
# konsumen : konsumen
# slow : slow
# lately : lately
# hhhh : hhhh
# yahhhh : yahhhh
# bar : bar
# hmmmmm : hmmmmm
# floppppp : floppppp
# jamettt : jamettt
# nyanyi : nyanyi
# mon : mon
# ngeleg : ngeleg
# uas : uas
# saur : saur
# bab : bab
# dadah : dadah
# terngiang : ngiang
# ngiang : ngiang
# melayani : layan
# nasabah : nasabah
# aam : aam
# inisiatif : inisiatif
# perusahaan : usaha
# dibikin : bikin
# meledak : ledak
# palanya : pala
# ngen : ngen
# gembel : gembel
# kualat : kualat
# nyasar : nyasar
# misuhin : misuhin
# innalillahi : innalillahi
# hospot : hospot
# makek : makek
# ngablok : ngablok
# baheula : baheula
# masukk : masukk
# saski : saski
# ichandra : ichandra
# berbunyi : bunyi
# lamp : lamp
# rissa : rissa
# arvi : arvi
# nyebelinnnnnnnnnnn : nyebelinnnnnnnnnnn
# bner : bner
# anjjjj : anjjjj
# penyakit : sakit
# pulkam : pulkam
# noted : noted
# gbx : gbx
# kannn : kannn
# jeli : jeli
# extender : extender
# internetan : internetan
# sudut : sudut
# leluasa : leluasa
# nabilla : nabilla
# reboot : reboot
# nabila : nabila
# patty : patty
# tian : tian
# berakhiran : akhir
# keterbatasan : batas
# gaaaaaaa : gaaaaaaa
# baiklah : baik
# tulisan : tulis
# ditangguhkan : tangguh
# tvnya : tvnya
# leb : leb
# dtg : dtg
# plij : plij
# skskaksk : skskaksk
# ditangerang : ditangerang
# search : search
# google : google
# cariin : cariin
# nizam : nizam
# berhasil : hasil
# aryan : aryan
# penagdaun : penagdaun
# sj : sj
# andri : andri
# tekan : tekan
# geser : geser
# fakta : fakta
# tari : tari
# ketahui : tahu
# memperingati : ingat
# sedunia : dunia
# negara : negara
# kebudayaan : budaya
# tarian : tari
# khasnya : khas
# tetangganya : tetangga
# julid : julid
# iri : iri
# dengki : dengki
# nyantet : nyantet
# bapakku : bapak
# laris : laris
# larisnya : laris
# warung : warung
# berangkat : berangkat
# pulang : pulang
# pertahankan : tahan
# rid : rid
# hadeeee : hadeeee
# muehehheee : muehehheee
# halamannya : halaman
# keload : keload
# hduhh : hduhh
# garut : garut
# ujang : ujang
# jenis : jenis
# witel : witel
# adzimi : adzimi
# prank : prank
# pengelola : kelola
# jatiasih : jatiasih
# lemmmmmmod : lemmmmmmod
# banggggeet : banggggeet
# wahid : wahid
# zia : zia
# anjiir : anjiir
# telponnya : telpon
# yach : yach
# sengaja : sengaja
# diaktifkan : aktif
# virgo : virgo
# colokan : colok
# blank : blank
# kewajiban : wajib
# dibayarkan : bayar
# berez : berez
# yaah : yaah
# menambah : tambah
# memasangkannya : pasang
# ditampilkan : tampil
# wifiid : wifiid
# herma : herma
# restian : restian
# aktifitasnya : aktifitasnya
# enstars : enstars
# antagonisnya : antagonis
# uwu : uwu
# ersa : ersa
# anjut : anjut
# hanifah : hanifah
# pakdhe : pakdhe
# lapangan : lapang
# waingapu : waingapu
# sumba : sumba
# profesional : profesional
# kerusakan : rusa
# dihbngi : dihbngi
# sktr : sktr
# wita : wita
# menjelang : jelang
# sklh : sklh
# menghilang : hilang
# jwbn : jwbn
# dpt : dpt
# well : well
# done : done
# doesn : doesn
# deserve : deserve
# rights : rights
# honestly : honestly
# they : they
# act : act
# these : these
# last : last
# couple : couple
# days : days
# berkedip : kedip
# masakah : masa
# kerugian : rugi
# target : target
# simulasi : simulasi
# yukk : yukk
# pribadai : pribadai
# kukira : kira
# elalui : elalui
# majin : majin
# askes : askes
# patchcord : patchcord
# jamannya : jaman
# papa : papa
# mbahnya : mbah
# wkwkk : wkwkk
# walhasil : walhasil
# warnet : warnet
# sekejap : kejap
# petsos : petsos
# kelas : kelas
# dirumahku : rumah
# ktp : ktp
# thxs : thxs
# diinfokan : info
# beserta : serta
# lia : lia
# migora : migora
# apresiasinya : apresiasi
# feed : feed
# dibenerin : dibenerin
# diproses : proses
# temenmu : temenmu
# dom : dom
# domisili : domisili
# ngaruh : ngaruh
# keluhanya : keluhanya
# kotaku : kota
# bri : bri
# klau : klau
# gegara : gegara
# wompiri : wompiri
# gaikut : gaikut
# lanjutan : lanjut
# guru : guru
# pemakain : pemakain
# hehhe : hehhe
# nartooooo : nartooooo
# saskiiiihh : saskiiiihh
# dadakan : dada
# kelurahan : lurah
# beji : beji
# cendrawasih : cendrawasih
# bobsungjin : bobsungjin
# cupaps : cupaps
# satrio : satrio
# network : network
# maintenancenya : maintenancenya
# beritanya : berita
# niswa : niswa
# ipal : ipal
# aga : aga
# wawlohualam : wawlohualam
# bajar : bajar
# tautan : taut
# ujug : ujug
# tarif : tarif
# mundhak : mundhak
# mesti : mesti
# mudhun : mudhun
# drastis : drastis
# cobaan : coba
# tenan : tenan
# dhe : dhe
# pie : pie
# siihh : siihh
# {'interaksinya': 'interaksi', 'beralih': 'alih', 'akun': 'akun', 'terima': 'terima', 'kasih': 'kasih', 'refan': 'refan', '': '', 'hai': 'hai', 'kak': 'kak', 'bambang': 'bambang', 'perihal': 'perihal', 'akses': 'akses', 'jaringannya': 'jaring', 'langkah': 'langkah', 'pastikan': 'pasti', 'kabel': 'kabel', 'patch': 'patch', 'cord': 'cord', 'warna': 'warna', 'hitam': 'hitam', 'kuning': 'kuning', 'ujung': 'ujung', 'biru': 'biru', 'terpasang': 'pasang', 'kencang': 'kencang', 'coba': 'coba', 'koneksinya': 'koneksi', 'informasikan': 'informasi', 'via': 'via', 'link': 'link', 'hmm': 'hmm', 'akur': 'akur', 'mohon': 'mohon', 'pngertiannya': 'pngertiannya', 'indihome': 'indihome', 'pagi': 'pagi', 'mati': 'mati', 'hrs': 'hrs', 'telp': 'telp', 'lapor': 'lapor', 'nyala': 'nyala', 'twitter': 'twitter', 'koq': 'koq', 'direspon': 'direspon', 'finally': 'finally', 'ditunggu': 'tunggu', 'tunggu': 'tunggu', 'seru': 'seru', 'kerja': 'kerja', 'netflix': 'netflix', 'taii': 'taii', 'wow': 'wow', 'tranding': 'tranding', 'thursdayonnetflix': 'thursdayonnetflix', 'netfik': 'netfik', 'diakses': 'akses', 'betah': 'betah', 'dirumah': 'rumah', 'deh': 'deh', 'melototin': 'melototin', 'mantab': 'mantab', 'selamat': 'selamat', 'keluhan': 'keluh', 'gangguan': 'ganggu', 'sistem': 'sistem', 'jaringan': 'jaring', 'putus': 'putus', 'ping': 'ping', 'stabil': 'stabil', 'disebabkan': 'sebab', 'redaman': 'redam', 'diganti': 'ganti', 'bantuannya': 'bantu', 'internet': 'internet', 'kakak': 'kakak', 'interaksi': 'interaksi', 'silakan': 'sila', 'hubungi': 'hubung', 'tata': 'tata', 'halo': 'halo', 'julian': 'juli', 'kendala': 'kendala', 'pusat': 'pusat', 'pemakaian': 'pakai', 'melebihi': 'lebih', 'fup': 'fup', 'nomor': 'nomor', 'pengecekan': 'kece', 'dikasi': 'kasi', 'uang': 'uang', 'anak': 'anak', 'anaknya': 'anak', 'pengeluaran': 'keluar', 'makan': 'makan', 'listrik': 'listrik', 'pdam': 'pdam', 'dll': 'dll', 'urusan': 'urus', 'ditumpangi': 'tumpang', 'uangnya': 'uang', 'kumpul': 'kumpul', 'cmn': 'cmn', 'dapet': 'dapet', 'speed': 'speed', 'segini': 'gin', 'berasa': 'asa', 'tembaga': 'tembaga', 'bkn': 'bkn', 'fiber': 'fiber', 'optik': 'optik', 'bantuin': 'bantuin', 'summon': 'summon', 'sii': 'sii', 'sukak': 'sukak', 'gini': 'gin', 'udh': 'udh', 'istighfar': 'istighfar', 'wkwkwkkwk': 'wkwkwkkwk', 'nasiiibbb': 'nasiiibbb', 'wilayah': 'wilayah', 'entrop': 'entrop', 'kecamatan': 'camat', 'jayapura': 'jayapura', 'selatan': 'selatan', 'off': 'off', 'subuh': 'subuh', 'tolong': 'tolong', 'ditangani': 'tangan', 'sesang': 'sang', 'ujian': 'uji', 'online': 'online', 'thanks': 'thanks', 'min': 'min', 'susukan': 'susu', 'bojong': 'bojong', 'gede': 'gede', 'kab': 'kab', 'bogor': 'bogor', 'mengalami': 'alami', 'isu': 'isu', 'dikonfirmasi': 'konfirmasi', 'penyelesaian': 'selesai', 'perbaikan': 'baik', 'rabu': 'rabu', 'berkurang': 'kurang', 'siangan': 'siang', 'kambuh': 'kambuh', 'bener': 'bener', 'gua': 'gua', 'ganti': 'ganti', 'wifi': 'wifi', 'woy': 'woy', 'modem': 'modem', 'ngelag': 'ngelag', 'kacau': 'kacau', 'access': 'access', 'yaa': 'yaa', 'udah': 'udah', 'nyoba': 'nyoba', 'reset': 'reset', 'hasilnya': 'hasil', 'nihil': 'nihil', 'emridwan': 'emridwan', 'ridwan': 'ridwan', 'setia': 'setia', 'emosi': 'emosi', 'tod': 'tod', 'masyallah': 'masyallah', 'tsel': 'tsel', 'ribut': 'ribut', 'nyobain': 'nyobain', 'main': 'main', 'pubg': 'pubg', 'character': 'character', 'gue': 'gue', 'salah': 'salah', 'urat': 'urat', 'anjirr': 'anjirr', 'angger': 'angger', 'hadir': 'hadir', 'dilokasi': 'lokasi', 'yuk': 'yuk', 'bantu': 'bantu', 'voting': 'voting', 'intraksi': 'intraksi', 'selanjut': 'lanjut', 'indihomecare': 'indihomecare', 'terimakasih': 'terimakasih', 'wija': 'wija', 'arief': 'arief', 'nara': 'nara', 'cek': 'cek', 'informasi': 'informasi', 'password': 'password', 'stb': 'stb', 'dibantu': 'bantu', 'respon': 'respon', 'rekan': 'rekan', 'rumah': 'rumah', 'gabisa': 'gabisa', 'koneksi': 'koneksi', 'pls': 'pls', 'tega': 'tega', 'anjg': 'anjg', 'april': 'april', 'source': 'source', 'tertera': 'tera', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/1689 [00:01<?, ?it/s]
#                                                 content  \
# 0     @basurjkt @indihome @telkomcare ttp://myih.ch/...
# 1     @basurjkt @indihome @telkomcare hai, kak bamba...
# 2     @netflixid @telkomindonesia @telkomsel @indiho...
# 3              @seonghwacs @indihome mohon pngertiannya
# 4                                  @farahikhza indihome
# ...                                                 ...
# 1995  @iqbaldias @indihome halo, kak iqbal. maaf ata...
# 1996  @blontankpoer @indihome @indihomecare ujug2 ta...
# 1997  pie sih indihome @luckymaarif 😔😂😂😂 https://t.c...
# 1998  @213_fu @shabrinanurina_ @firstmediacares @ind...
# 1999                            indihome kenapa siihh??
#
#                                          cleaning_tweet  \
# 0     interaksinya beralih akun tersebut terima kasi...
# 1     hai kak bambang perihal akses jaringannya seba...
# 2                                       hmm sudah akur
# 3                                    mohon pngertiannya
# 4                                              indihome
# ...                                                 ...
# 1995  halo kak iqbal maaf atas ketidaknyamanannya sa...
# 1996  ujug  tarif mundhak wes lewat tgl mesti lsg sp...
# 1997                                  pie sih indihome
# 1998                   nya sudah mimin respon kak trims
# 1999                             indihome kenapa siihh
#
#                                              tokenisasi  \
# 0     [interaksinya, beralih, akun, tersebut, terima...
# 1     [hai, kak, bambang, perihal, akses, jaringanny...
# 2                                  [hmm, sudah, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, atas, ketidaknyamanan...
# 1996  [ujug, tarif, mundhak, wes, lewat, tgl, mesti,...
# 1997                             [pie, sih, indihome, ]
# 1998          [, nya, sudah, mimin, respon, kak, trims]
# 1999                        [indihome, kenapa, siihh, ]
#
#                                                stopword  \
# 0     [interaksinya, beralih, akun, terima, kasih, r...
# 1     [hai, kak, bambang, perihal, akses, jaringanny...
# 2                                         [hmm, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, ketidaknyamanannya, l...
# 1996  [ujug, tarif, mundhak, wes, tgl, mesti, lsg, s...
# 1997                                  [pie, indihome, ]
# 1998                      [, mimin, respon, kak, trims]
# 1999                                [indihome, siihh, ]
#
#                                                stemming
# 0       [interaksi, alih, akun, terima, kasih, refan, ]
# 1     [hai, kak, bambang, perihal, akses, jaring, la...
# 2                                         [hmm, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, ketidaknyamanannya, l...
# 1996  [ujug, tarif, mundhak, wes, tgl, mesti, lsg, s...
# 1997                                  [pie, indihome, ]
# 1998                      [, mimin, respon, kak, trims]
# 1999                                [indihome, siihh, ]
#
# [1689 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0       [interaksi, alih, akun, terima, kasih, refan, ]
# 1     [hai, kak, bambang, perihal, akses, jaring, la...
# 2                                         [hmm, akur, ]
# 3                                 [mohon, pngertiannya]
# 4                                            [indihome]
# ...                                                 ...
# 1995  [halo, kak, iqbal, maaf, ketidaknyamanannya, l...
# 1996  [ujug, tarif, mundhak, wes, tgl, mesti, lsg, s...
# 1997                                  [pie, indihome, ]
# 1998                      [, mimin, respon, kak, trims]
# 1999                                [indihome, siihh, ]
#
# [1689 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_4.xlsx')
