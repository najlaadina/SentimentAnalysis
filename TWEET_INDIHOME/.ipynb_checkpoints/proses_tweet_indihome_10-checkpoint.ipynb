# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0                    @mmarrierr @IndiHome min itu lemot
# 1     @newyorkdevotee @Gerindra @nutrisheid Min aku ...
# 2     dari sore masa gini terus si @IndiHome https:/...
# 3     @indihomejkt Jawabannya adalah BATAVIA \n\nYuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  Ya Allah indihome kenapa sihhh aku mau ngerjai...
# 1996  Sudah nonton trailer Lightyear gengs?\n\nSekil...
# 1997  Wifi Indihome parah banget asli tagihan tetep ...
# 1998            Keren @IndiHome https://t.co/DiALK9ET8i
# 1999        Stres gegara indihome belom kepasang pasang
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 22

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0                    @mmarrierr @IndiHome min itu lemot
# 1     @newyorkdevotee @Gerindra @nutrisheid Min aku ...
# 2     dari sore masa gini terus si @IndiHome https:/...
# 3     @indihomejkt Jawabannya adalah BATAVIA \n\nYuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  Ya Allah indihome kenapa sihhh aku mau ngerjai...
# 1996  Sudah nonton trailer Lightyear gengs?\n\nSekil...
# 1997  Wifi Indihome parah banget asli tagihan tetep ...
# 1998            Keren @IndiHome https://t.co/DiALK9ET8i
# 1999        Stres gegara indihome belom kepasang pasang
#
# [1958 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0                    @mmarrierr @indihome min itu lemot
# 1     @newyorkdevotee @gerindra @nutrisheid min aku ...
# 2     dari sore masa gini terus si @indihome https:/...
# 3     @indihomejkt jawabannya adalah batavia \n\nyuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  ya allah indihome kenapa sihhh aku mau ngerjai...
# 1996  sudah nonton trailer lightyear gengs?\n\nsekil...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998            keren @indihome https://t.co/dialk9et8i
# 1999        stres gegara indihome belom kepasang pasang
#
# [1958 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0                    @mmarrierr @indihome min itu lemot
# 1     @newyorkdevotee @gerindra @nutrisheid min aku ...
# 2     dari sore masa gini terus si @indihome https:/...
# 3     @indihomejkt jawabannya adalah batavia \n\nyuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  ya allah indihome kenapa sihhh aku mau ngerjai...
# 1996  sudah nonton trailer lightyear gengs?\n\nsekil...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998            keren @indihome https://t.co/dialk9et8i
# 1999        stres gegara indihome belom kepasang pasang
#
#                                          cleaning_tweet
# 0                                         min itu lemot
# 1     min aku juga mau gratis gak bayar sebulan bonu...
# 2                            dari sore masa gini terus
# 3     jawabannya adalah batavia yuk sobat jangan sam...
# 4        gada lbh monyet selain jaringan indihome pagi
# ...                                                 ...
# 1995   allah indihome kenapa sihhh aku mau ngerjain ...
# 1996  sudah nonton trailer lightyear gengs sekilas f...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998                                              keren
# 1999        stres gegara indihome belom kepasang pasang
#
# [1958 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0                    @mmarrierr @indihome min itu lemot
# 1     @newyorkdevotee @gerindra @nutrisheid min aku ...
# 2     dari sore masa gini terus si @indihome https:/...
# 3     @indihomejkt jawabannya adalah batavia \n\nyuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  ya allah indihome kenapa sihhh aku mau ngerjai...
# 1996  sudah nonton trailer lightyear gengs?\n\nsekil...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998            keren @indihome https://t.co/dialk9et8i
# 1999        stres gegara indihome belom kepasang pasang
#
#                                          cleaning_tweet  \
# 0                                         min itu lemot
# 1     min aku juga mau gratis gak bayar sebulan bonu...
# 2                            dari sore masa gini terus
# 3     jawabannya adalah batavia yuk sobat jangan sam...
# 4        gada lbh monyet selain jaringan indihome pagi
# ...                                                 ...
# 1995   allah indihome kenapa sihhh aku mau ngerjain ...
# 1996  sudah nonton trailer lightyear gengs sekilas f...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998                                              keren
# 1999        stres gegara indihome belom kepasang pasang
#
#                                              tokenisasi
# 0                                     [min, itu, lemot]
# 1     [min, aku, juga, mau, gratis, gak, bayar, sebu...
# 2                     [dari, sore, masa, gini, terus, ]
# 3     [jawabannya, adalah, batavia, yuk, sobat, jang...
# 4     [gada, lbh, monyet, selain, jaringan, indihome...
# ...                                                 ...
# 1995  [, allah, indihome, kenapa, sihhh, aku, mau, n...
# 1996  [sudah, nonton, trailer, lightyear, gengs, sek...
# 1997  [wifi, indihome, parah, banget, asli, tagihan,...
# 1998                                            [keren]
# 1999  [stres, gegara, indihome, belom, kepasang, pas...
#
# [1958 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                 content  \
# 0                    @mmarrierr @indihome min itu lemot
# 1     @newyorkdevotee @gerindra @nutrisheid min aku ...
# 2     dari sore masa gini terus si @indihome https:/...
# 3     @indihomejkt jawabannya adalah batavia \n\nyuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  ya allah indihome kenapa sihhh aku mau ngerjai...
# 1996  sudah nonton trailer lightyear gengs?\n\nsekil...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998            keren @indihome https://t.co/dialk9et8i
# 1999        stres gegara indihome belom kepasang pasang
#
#                                          cleaning_tweet  \
# 0                                         min itu lemot
# 1     min aku juga mau gratis gak bayar sebulan bonu...
# 2                            dari sore masa gini terus
# 3     jawabannya adalah batavia yuk sobat jangan sam...
# 4        gada lbh monyet selain jaringan indihome pagi
# ...                                                 ...
# 1995   allah indihome kenapa sihhh aku mau ngerjain ...
# 1996  sudah nonton trailer lightyear gengs sekilas f...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998                                              keren
# 1999        stres gegara indihome belom kepasang pasang
#
#                                              tokenisasi  \
# 0                                     [min, itu, lemot]
# 1     [min, aku, juga, mau, gratis, gak, bayar, sebu...
# 2                     [dari, sore, masa, gini, terus, ]
# 3     [jawabannya, adalah, batavia, yuk, sobat, jang...
# 4     [gada, lbh, monyet, selain, jaringan, indihome...
# ...                                                 ...
# 1995  [, allah, indihome, kenapa, sihhh, aku, mau, n...
# 1996  [sudah, nonton, trailer, lightyear, gengs, sek...
# 1997  [wifi, indihome, parah, banget, asli, tagihan,...
# 1998                                            [keren]
# 1999  [stres, gegara, indihome, belom, kepasang, pas...
#
#                                                stopword
# 0                                          [min, lemot]
# 1     [min, gratis, bayar, sebulan, bonus, clay, mas...
# 2                                        [sore, gini, ]
# 3             [jawabannya, batavia, yuk, sobat, ikutan]
# 4       [gada, lbh, monyet, jaringan, indihome, pagi, ]
# ...                                                 ...
# 1995    [, allah, indihome, sihhh, ngerjain, laporan, ]
# 1996  [nonton, trailer, lightyear, gengs, sekilas, f...
# 1997  [wifi, indihome, parah, banget, asli, tagihan,...
# 1998                                            [keren]
# 1999  [stres, gegara, indihome, belom, kepasang, pas...
#
# [1958 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 4165
# ------------------------
# min : min
# lemot : lot
# gratis : gratis
# bayar : bayar
# sebulan : bulan
# bonus : bonus
# clay : clay
# masknya : masknya
# npure : npure
#  :
# sore : sore
# gini : gin
# jawabannya : jawab
# batavia : batavia
# yuk : yuk
# sobat : sobat
# ikutan : ikut
# gada : gada
# lbh : lbh
# monyet : monyet
# jaringan : jaring
# indihome : indihome
# pagi : pagi
# lagu : lagu
# mendung : mendung
# tanpo : tanpo
# udan : udan
# lupa : lupa
# follow : follow
# woy : woy
# donk : donk
# pandemi : pandemi
# dirmh : dirmh
# bermanfaat : manfaat
# nich : nich
# join : join
# allah : allah
# keseruan : seru
# disore : sore
# sharing : sharing
# mutahir : mutahir
# protes : protes
# indirmh : indirmh
# waroo : waroo
# crying : crying
# look : look
# loading : loading
# streams : streams
# once : once
# love : love
# torturing : torturing
# internet : internet
# provider : provider
# berhenti : henti
# ppp : ppp
# sihhh : sihhh
# ospek : ospek
# jam : jam
# ayodong : ayodong
# kerjasamanyaaa : kerjasamanyaaa
# seru : seru
# ilmu : ilmu
# dot : dot
# bagus : bagus
# dirumah : rumah
# ajanjoin : ajanjoin
# keknya : kek
# rekor : rekor
# tercepat : cepat
# tumbenan : tumben
# banget : banget
# gua : gua
# download : download
# file : file
# ukuran : ukur
# gb : gb
# berhasil : hasil
# menit : menit
# malesin : malesin
# wall : wall
# putri : putri
# gagara : gagara
# ayo : ayo
# buruan : buru
# bergabung : gabung
# menarik : tarik
# update : update
# pertandingan : tanding
# nba : nba
# favorit : favorit
# dijamin : jamin
# ketinggalan : tinggal
# jadwal : jadwal
# terkini : kini
# informasi : informasi
# lengkap : lengkap
# dunia : dunia
# paket : paket
# minipack : minipack
# indibasketball : indibasketball
# seno : seno
# halo : halo
# care : care
# mhn : mhn
# bantuan : bantu
# dicek : cek
# telp : telp
# rmh : rmh
# mati : mati
# oktober : oktober
# sob : sob
# prima : prima
# yen : yen
# saiki : saiki
# wae : wae
# jawabane : jawabane
# ijin : ijin
# tag : tag
# astu : astu
# prsnlng : prsnlng
# keren : keren
# just : just
# musim : musim
# ujan : ujan
# udh : udh
# ngajak : ngajak
# ribut : ribut
# gila : gila
# sinyal : sinyal
# segini : gin
# emg : emg
# anehhhhhh : anehhhhhh
# phoenix : phoenix
# slowrespon : slowrespon
# trobel : trobel
# ajg : ajg
# fase : fase
# kehidupan : hidup
# kesepian : sepi
# pas : pas
# udah : udah
# nikah : nikah
# suami : suami
# sibuk : sibuk
# anak : anak
# les : les
# kumon : kumon
# trus : trus
# gangguan : ganggu
# detik : detik
# kejelasan : jelas
# pemasangan : pasang
# malu : malu
# kedok : kedok
# verifikasi : verifikasi
# gabut : gabut
# semalem : semalem
# tetangga : tetangga
# manggil : manggil
# petugas : tugas
# gatau : gatau
# ngapain : ngapain
# trs : trs
# malem : malem
# wifi : wifi
# rumah : rumah
# tanda : tanda
# serunya : seru
# lampunya : lampu
# kedip : kedip
# warna : warna
# merah : merah
# gitu : gitu
# deh : deh
# ngotak : ngotak
# ngatik : ngatik
# kabel : kabel
# sampe : sampe
# skrng : skrng
# masi : mas
# gabisa : gabisa
# baca : baca
# langganan : langgan
# telkom : telkom
# susah : susah
# bener : bener
# mengalami : alami
# error : error
# browser : browser
# berat : berat
# sst : sst
# kasih : kasih
# gimana : gimana
# mengatasi : atas
# performa : performa
# favoritmu : favorit
# lancar : lancar
# ngamuk : ngamuk
# kalem : kalem
# keun : keun
# santai : santai
# tanginas : tanginas
# keneuh : keneuh
# kela : kela
# abi : abi
# bari : bari
# maca : maca
# ayat : ayat
# kursi : kursi
# atuh : atuh
# sok : sok
# cekelan : cekel
# tangan : tangan
# iya : iya
# dibuka : buka
# huftt : huftt
# tahan : tahan
# tos : tos
# gue : gue
# jele : jele
# pdhl : pdhl
# hujan : hujan
# knp : knp
# oraikkk : oraikkk
# people : people
# mantau : mantau
# pergerakan : gera
# solana : solana
# bergerak : gerak
# breakout : breakout
# triangle : triangle
# patternnya : patternnya
# pakai : pakai
# speed : speed
# maksimum : maksimum
# tgl : tgl
# end : end
# lokasi : lokasi
# permata : permata
# depok : depok
# sesuai : sesuai
# ramalan : ramal
# mbah : mbah
# shiba : shiba
# inu : inu
# kenaikan : naik
# sekencang : kencang
# kemarin : kemarin
# pelan : pelan
# ngopo : ngopo
# ngkas : ngkas
# iki : iki
# ampoonnn : ampoonnn
# allahuakbar : allahuakbar
# buka : buka
# layanan : layan
# pelanggan : langgan
# khawatir : khawatir
# memilih : pilih
# tayangan : tayang
# kunjungi : kunjung
# aplikasi : aplikasi
# myindihome : myindihome
# diaktifkan : aktif
# interaktif : interaktif
# beh : beh
# ketat : ketat
# keblokir : blokir
# situsnya : situs
# vpn : vpn
# aman : aman
# takut : takut
# kecurian : curi
# datanya : data
# cek : cek
# ketersediaan : sedia
# seumur : umur
# hidup : hidup
# gapernah : gapernah
# serius : serius
# kuota : kuota
# habis : habis
# berlangganan : langgan
# tercover : tercover
# bingung : bingung
# orbit : orbit
# solusi : solusi
# internetan : internetan
# koneksi : koneksi
# kenceng : kenceng
# hati : hati
# klik : klik
# link : link
# data : data
# pribadimu : pribadi
# curi : curi
# orang : orang
# malam : malam
# kak : kak
# chopsueey : chopsueey
# terupdate : terupdate
# perbaikan : baik
# tim : tim
# normal : normal
# silahkan : silah
# dicoba : coba
# koneksinya : koneksi
# ditunggu : tunggu
# berita : berita
# terbaru : baru
# milik : milik
# kakak : kakak
# routernya : routernya
# restart : restart
# terima : terima
# wkwkwkwkwk : wkwkwkwkwk
# terpaksa : paksa
# masuk : masuk
# huhuhu : huhuhu
# bacanya : baca
# nadaaa : nadaaa
# kerasukan : rasuk
# liat : liat
# magrib : magrib
# konek : konek
# mulu : mulu
# why : why
# heh : heh
# rek : rek
# ngga : ngga
# kek : kek
# indomie : indomie
# abang : abang
# woi : woi
# mbps : mbps
# maksimal : maksimal
# tarif : tarif
# doang : doang
# mahal : mahal
# kualitas : kualitas
# emang : emang
# xlhome : xlhome
# the : the
# best : best
# duit : duit
# donasi : donasi
# beli : beli
# album : album
# grtisan : grtisan
# maling : maling
# lag : lag
# bangett : bangett
# busetetetwt : busetetetwt
# mohon : mohon
# kerjasama : kerjasama
# manfaatin : manfaatin
# promo : promo
# dapet : dapet
# kali : kali
# rip : rip
# make : make
# buobrok : buobrok
# gaa : gaa
# sheeshhh : sheeshhh
# jaya : jaya
# hiii : hiii
# bocok : bocok
# tugasku : tugas
# kekirim : kirim
# kirim : kirim
# channel : channel
# maxstream : maxstream
# besok : besok
# tayangnya : tayang
# admin : admin
# relate : relate
# internetnya : internetnya
# tolong : tolong
# bantuannya : bantu
# busuk : busuk
# bgttt : bgttt
# astagaaaa : astagaaaa
# abis : abis
# cmn : cmn
# hate : hate
# relationship : relationship
# ama : ama
# mentang : mentang
# cuman : cuman
# kampung : kampung
# trouble : trouble
# bgstt : bgstt
# hey : hey
# buruk : buruk
# pelayanan : layan
# officenya : officenya
# selamat : selamat
# papua : papua
# dipermainkan : main
# terkait : kait
# pengaduan : adu
# call : call
# center : center
# nelpon : nelpon
# permasalahan : masalah
# ditutupkan : tutup
# tlp : tlp
# bangkee : bangkee
# cocok : cocok
# kau : kau
# dimsumfav : dimsumfav
# kaluhan : kaluhan
# perihal : perihal
# produk : produk
# silakan : sila
# informasikan : informasi
# via : via
# eby : eby
# retweet : retweet
# like : like
# yuni : yuni
# urusan : urus
# belom : bom
# beres : beres
# tahugorengrebus : tahugorengrebus
# dihari : hari
# sumpah : sumpah
# pemuda : pemuda
# pengguna : guna
# menikmati : nikmat
# sehari : hari
# kendala : kendala
# komplain : komplain
# tanggapin : tanggapin
# dmnya : dmnya
# katro : katro
# najissss : najissss
# gajelas : gajelas
# nilai : nilai
# ancurrrr : ancurrrr
# grgr : grgr
# yaudah : yaudah
# wassalam : wassalam
# passed : passed
# salah : salah
# kaya : kaya
# ubah : ubah
# jualan : jual
# cilok : cilok
# ccd : ccd
# ditungguin : ditungguin
# guys : guys
# kuisnya : kuis
# belajar : ajar
# asik : asik
# study : study
# mengakses : akses
# buku : buku
# mata : mata
# pelajaran : ajar
# kurikulum : kurikulum
# try : try
# out : out
# video : video
# pendidikan : didik
# web : web
# isinya : isi
# eror : eror
# segede : gede
# perusahan : usah
# appnya : appnya
# hadee : hadee
# tae : tae
# bapuk : bapuk
# fans : fans
# anti : anti
# lelet : lelet
# raa : raa
# kece : kece
# handry : handry
# caksono : caksono
# nomor : nomor
# tiket : tiket
# in : in
# terhubung : hubung
# terdaftar : daftar
# bisnis : bisnis
# perbaikannya : baik
# disolusikan : solusi
# rekan : rekan
# dipake : dipake
# software : software
# app : app
# iphone : iphone
# lamaaaaaaa : lamaaaaaaa
# android : android
# hadeh : hadeh
# rangka : rangka
# menyemarakkan : semarak
# kuis : kuis
# pendapat : dapat
# terbaikmu : baik
# banyaknya : banyak
# tanggal : tanggal
# ngapesi : ngapesi
# lampu : lampu
# merahnya : merah
# kedap : kedap
# akuaja : akuaja
# riweuh : riweuh
# mah : mah
# teu : teu
# caper : caper
# oge : oge
# loba : loba
# merhati : merhati
# aduh : aduh
# loe : loe
# rese : rese
# siang : siang
# posisi : posisi
# nengdi : nengdi
# bos : bos
# neng : neng
# ngisor : ngisor
# awor : awor
# benerbener : benerbener
# asuw : asuw
# cinta : cinta
# kampret : kampret
# install : install
# lambaaaattt : lambaaaattt
# sihh : sihh
# global : global
# indonesia : indonesia
# pilihan : pilih
# hadir : hadir
# disney : disney
# superhero : superhero
# marvel : marvel
# serial : serial
# star : star
# wars : wars
# studio : studio
# hobi : hobi
# dengerin : dengerin
# langitmusik : langitmusik
# nikmati : nikmat
# musik : musik
# batas : batas
# temani : teman
# genggaman : genggam
# smart : smart
# komentar : komentar
# saran : saran
# seputar : putar
# langsung : langsung
# mention : mention
# temukan : temu
# pengalaman : alam
# terbaik : baik
# this : this
# irl : irl
# and : and
# zhongli : zhongli
# btw : btw
# kulihat : lihat
# berlaku : laku
# dibantu : bantu
# jaringannya : jaring
# suka : suka
# stabil : stabil
# kadang : kadang
# hilang : hilang
# thx : thx
# sudut : sudut
# nggak : nggak
# extender : extender
# memperluas : luas
# memperkuat : kuat
# ruangan : ruang
# jlegg : jlegg
# luhk : luhk
# cute : cute
# tetring : tetring
# gara : gara
# twitter : twitter
# kah : kah
# ngirim : ngirim
# foto : foto
# pacaran : pacar
# kecepatan : cepat
# terimakasih : terimakasih
# suruh : suruh
# router : router
# yaaa : yaaa
# kroni : kroni
# pls : pls
# berulah : ulah
# uzan : uzan
# apresiasinya : apresiasi
# yogi : yogi
# menghubungi : hubung
# semoga : moga
# keluarga : keluarga
# sehat : sehat
# stay : stay
# safe : safe
# healthy : healthy
# seh : seh
# tha : tha
# tpi : tpi
# sdg : sdg
# mendukung : dukung
# kegiatan : giat
# homo : homo
# wadaw : wadaw
# ide : ide
# bgus : bgus
# ngelagg : ngelagg
# parah : parah
# sekarat : sekarat
# diujung : ujung
# titik : titik
# penghabisan : habis
# yeap : yeap
# semingguan : minggu
# hiccup : hiccup
# walopun : walopun
# gotta : gotta
# give : give
# credit : credit
# memberesken : memberesken
# here : here
# pindah : pindah
# isp : isp
# lumayan : lumayan
# responsif : responsif
# capek : capek
# tetiba : tetiba
# bersahabat : sahabat
# dikit : dikit
# alhamdulilah : alhamdulilah
# quran : quran
# useetv : useetv
# mnt : mnt
# membaca : baca
# berbagi : bagi
# kalin : kalin
# online : online
# mic : mic
# check : check
# grandfinal : grandfinal
# proffesional : proffesional
# nouva : nouva
# lower : lower
# bracket : bracket
# please : please
# kocak : kocak
# gta : gta
# brow : brow
# terbuka : buka
# makan : makan
# youtube : youtube
# patah : patah
# nolong : nolong
# heyy : heyy
# hahaha : hahaha
# koplok : koplok
# ashuw : ashuw
# nonton : nonton
# ulang : ulang
# badminton : badminton
# french : french
# open : open
# kalu : kalu
# man : man
# ndak : ndak
# nntn : nntn
# ulng : ulng
# tvod : tvod
# playback : playback
# mantap : mantap
# daftar : daftar
# awas : awas
# bales : bales
# kamprett : kamprett
# kuy : kuy
# irpan : irpan
# only : only
# varian : varian
# harga : harga
# abonemen : abonemen
# biaya : biaya
# barunya : baru
# azani : azan
# hai : hai
# senang : senang
# mendengar : dengar
# kabar : kabar
# baiknya : baik
# membantu : bantu
# menajalani : menajalani
# aktivitasnya : aktivitas
# aris : aris
# dicari : cari
# letak : letak
# bagusnya : bagus
# kaga : kaga
# jelek : jelek
# renew : renew
# biasany : biasany
# selfi : selfi
# anaknya : anak
# yaya : yaya
# wifinya : wifinya
# yaallah : yaallah
# sabar : sabar
# kampanggg : kampanggg
# anjengg : anjengg
# mlaku : mlaku
# bebarengan : bebarengan
# bar : bar
# kui : kui
# kangen : kangen
# kangenan : kangen
# sedih : sedih
# lan : lan
# kebahagiaan : bahagia
# dilewati : lewat
# tahunan : tahun
# judule : judule
# astaghfirullah : astaghfirullah
# kenapaaa : kenapaaa
# siihh : siihh
# telat : telat
# denda : denda
# kaaya : kaaya
# teknisi : teknisi
# bnayak : bnayak
# dsini : dsini
# kumaha : maha
# maneh : maneh
# piki : piki
# rebus : rebus
# telor : telor
# mateng : mateng
# ndk : ndk
# bioskop : bioskop
# fasilitas : fasilitas
# tentunyasilahkan : tentunyasilahkan
# chanel : chanel
# indihe : indihe
# chinema : chinema
# dapatkan : dapat
# siaran : siar
# terfavorit : favorit
# mari : mari
# merajut : rajut
# cemerlang : cemerlang
# berkarya : karya
# mengharumkan : harum
# nama : nama
# bangsa : bangsa
# last : last
# match : match
# gagal : gagal
# menghubungkan : hubung
# krna : krna
# gapunya : gapunya
# paketan : paket
# matchnya : matchnya
# kelar : kelar
# kalah : kalah
# basket : basket
# lancaaaaar : lancaaaaar
# info : info
# temanggung : tanggung
# rincian : rincian
# tagihan : tagih
# cape : cape
# share : share
# cuan : cuan
# rebahan : rebah
# modal : modal
# menguntungkan : untung
# program : program
# simak : simak
# gabungnya : gabung
# iyaaaa : iyaaaa
# telkomsel : telkomsel
# jum : jum
# berkah : berkah
# ketemu : ketemu
# guru : guru
# alhamdulillah : alhamdulillah
# sambungin : sambungin
# udon : udon
# rasyid : rasyid
# arghhhhhh : arghhhhhh
# bayare : bayare
# mb : mb
# entuk : entuk
# banter : banter
# mung : mung
# nek : nek
# ana : ana
# gaiss : gaiss
# maksud : maksud
# sender : sender
# nungguin : nungguin
# marah : marah
# trnyata : trnyata
# gambarnya : gambar
# giliran : gilir
# voice : voice
# chat : chat
# discord : discord
# main : main
# iron : iron
# saga : saga
# aneh : aneh
# barusan : barusan
# notice : notice
# lunas : lunas
# kerasa : rasa
# minggu : minggu
# spesial : spesial
# season : season
# yuswohady : yuswohady
# eps : eps
# tema : tema
# shopping : shopping
# widening : widening
# deepening : deepening
# from : from
# wants : wants
# needs : needs
# sabtu : sabtu
# wib : wib
# free : free
# eksklusif : eksklusif
# certificate : certificate
# website : website
# haduhhhhhhh : haduhhhhhhh
# bentar : bentar
# reload : reload
# lihat : lihat
# bangsat : bangsat
# wkwkkw : wkwkkw
# kuat : kuat
# ngadat : ngadat
# penasaran : penasaran
# buzzer : buzzer
# dibayar : bayar
# bet : bet
# nye : nye
# kontol : kontol
# kopet : kopet
# kesel : kesel
# yaampun : yaampun
# gamo : gamo
# complain : complain
# ngadingadi : ngadingadi
# buffering : buffering
# buyar : buyar
# peka : peka
# perasaan : asa
# alus : alus
# milih : milih
# goblog : goblog
# tkut : tkut
# mengartikan : arti
# sorry : sorry
# say : say
# nvm : nvm
# tks : tks
# fwb : fwb
# kelanjutan : lanjut
# cerita : cerita
# sahabatku : sahabat
# indigo : indigo
# temenku : temenku
# jendela : jendela
# jumat : jumat
# bkin : bkin
# drh : drh
# heran : heran
# hotstar : hotstar
# lengkapnya : lengkap
# bgtsi : bgtsi
# ngatain : ngatain
# manga : manga
# orangtua : orangtua
# dpr : dpr
# pulici : pulici
# presiden : presiden
# dll : dll
# ngelakuin : ngelakuin
# kerjaan : kerja
# pengen : ken
# ganti : ganti
# biznet : biznet
# republik : republik
# astaga : astaga
# syaiton : syaiton
# self : self
# proclaimed : proclaimed
# tidur : tidur
# dikamar : kamar
# pokoknya : pokok
# smp : smp
# sma : sma
# kamar : kamar
# intense : intense
# kejadian : jadi
# bremgsk : bremgsk
# bppcityx : bppcityx
# udi : udi
# mengganti : ganti
# password : password
# ikuti : ikut
# langkah : langkah
# hubungkan : hubung
# gadget : gadget
# alamat : alamat
# sensitif : sensitif
# huntu : huntu
# berhubung : hubung
# belai : belai
# skksks : skksks
# good : good
# night : night
# bukis : buk
# isolir : isolir
# mksh : mksh
# dikatain : dikatain
# kayanya : kaya
# aleeya : aleeya
# kasi : kasi
# plis : plis
# butuh : butuh
# maaf : maaf
# oot : oot
# temen : temen
# nanya : nanya
# rumahnya : rumah
# gaada : gaada
# tvri : tvri
# sport : sport
# win : win
# bulu : bulu
# ketiak : ketiak
# serasa : serasa
# balikin : balikin
# bisaeror : bisaeror
# ilang : ilang
# bnr : bnr
# still : still
# haven : haven
# see : see
# yumi : yumi
# cell : cell
# ep : ep
# because : because
# hates : hates
# fak : fak
# yuks : yuks
# sebel : sebel
# hshshhshs : hshshhshs
# banting : banting
# hanyan : hanyan
# playlist : playlist
# andalan : andal
# konco : konco
# melu : melu
# giveaway : giveaway
# ojo : ojo
# lali : lali
# akun : akun
# jing : jing
# kagak : kagak
# remaja : remaja
# moodyan : moodyan
# geliss : geliss
# dapetin : dapetin
# uang : uang
# tambahan : tambah
# ribet : ribet
# smartphone : smartphone
# ratusan : ratus
# ribu : ribu
# rupiah : rupiah
# mudah : mudah
# gabung : gabung
# gatauuu : gatauuu
# biasalah : biasa
# huhu : huhu
# untung : untung
# kemdikbud : kemdikbud
# twt : twt
# beneran : beneran
# kayak : kayak
# goa : goa
# masang : masang
# bayarnya : bayar
# diawal : awal
# ngasih : ngasih
# rb : rb
# sosial : sosial
# media : media
# beruntung : untung
# aamiin : aamiin
# gaes : gaes
# konser : konser
# gigi : gigi
# band : band
# catat : catat
# tanggalnya : tanggal
# masimu : mas
# pemilik : milik
# aktif : aktif
# bantu : bantu
# lakukan : laku
# pengecekan : kece
# webinar : webinar
# neeh : neeh
# nak : nak
# achmad : achmad
# keluhan : keluh
# dinomor : nomor
# akhiran : akhir
# radyan : radyan
# setting : setting
# sistem : sistem
# berkala : kala
# tangga : tangga
# game : game
# jaman : jaman
# fup : fup
# maks : maks
# asw : asw
# wkwkwk : wkwkwk
# dilukis : luk
# cangkangnya : cangkang
# ngapa : ngapa
# lgi : lgi
# anjing : anjing
# memanggil : panggil
# sunoo : sunoo
# kena : kena
# ngeselin : ngeselin
# yak : yak
# antonius : antonius
# berkenan : kenan
# dijkt : dijkt
# kekk : kekk
# kekkk : kekkk
# keekkk : keekkk
# mending : mending
# lemotnya : lot
# konsisten : konsisten
# quiz : quiz
# jempol : jempol
# bang : bang
# hallo : hallo
# internetku : internetku
# nii : nii
# tik : tik
# tok : tok
# instagram : instagram
# ifad : ifad
# iyani : iyani
# kabelnya : kabel
# digigit : gigit
# paus : paus
# drtd : drtd
# kompak : kompak
# sinyalnya : sinyal
# yenni : yenni
# court : court
# andai : andai
# streaming : streaming
# legalnya : legal
# gimane : gimane
# yee : yee
# bund : bund
# menembus : tembus
# perancis : perancis
# gelut : gelut
# smtm : smtm
# napa : napa
# chindev : chindev
# abadi : abadi
# harian : hari
# apex : apex
# csgo : csgo
# valorant : valorant
# packet : packet
# loss : loss
# bareng : bareng
# lemotnyaaaa : lemotnyaaaa
# weekend : weekend
# ranked : ranked
# kedelai : kedelai
# gass : gass
# kasireup : kasireup
# atawa : atawa
# asa : asa
# lila : lila
# emosi : emosi
# astagaaa : astagaaa
# idol : idol
# mas : mas
# minum : minum
# tenggorokan : tenggorok
# kering : kering
# ish : ish
# dibenerin : dibenerin
# sewot : sewot
# dingin : dingin
# jeruk : jeruk
# dih : dih
# malunya : malu
# tweet : tweet
# makasih : makasih
# reply : reply
# katain : katain
# refleks : refleks
# elhayo : elhayo
# wayah : wayah
# ngeneki : ngeneki
# mesti : mesti
# ketepakan : tepa
# enek : enek
# halangane : halangane
# kenek : kenek
# backhoe : backhoe
# listrik : listrik
# ket : ket
# mengkurep : mengkurep
# fotbar : fotbar
# sokap : sokap
# terlintas : lintas
# pro : pro
# player : player
# gengs : gengs
# roadshow : roadshow
# leads : leads
# beralih : alih
# kota : kota
# medan : medan
# session : session
# guest : guest
# roadshownya : roadshownya
# live : live
# jujur : jujur
# always : always
# omg : omg
# drakor : drakor
# jirisan : jirisan
# tvn : tvn
# sungkem : sungkem
# dlu : dlu
# lachhh : lachhh
# iqiyi : iqiyi
# wkwkkwkwkw : wkwkkwkwkw
# with : with
# tempatku : tempat
# izin : izin
# kaa : kaa
# ngadain : ngadain
# lomba : lomba
# poster : poster
# lohh : lohh
# sabarrrrr : sabarrrrr
# waaaah : waaaah
# paraah : paraah
# wow : wow
# inet : inet
# bolak : bolak
# melulu : melulu
# lapor : lapor
# mrk : mrk
# pamit : pamit
# jumatan : jumat
# selesai : selesai
# msh : msh
# tanggung : tanggung
# acara : acara
# uda : uda
# template : template
# modem : modem
# ngetweet : ngetweet
# dimari : mari
# mwnit : mwnit
# pantengin : pantengin
# coba : coba
# idup : idup
# nagih : nagih
# cepet : cepet
# jeleg : jeleg
# nadya : nadya
# mahh : mahh
# baguss : baguss
# gengss : gengss
# suhardi : suhardi
# asli : asli
# sebenernya : sebenernya
# ngeluh : ngeluh
# alias : alias
# nikhoon : nikhoon
# where : where
# shoon : shoon
# musuhan : musuh
# infokan : info
# beserta : serta
# namanya : nama
# lia : lia
# login : login
# maju : maju
# kebiasaan : biasa
# mlm : mlm
# ngebug : ngebug
# menfess : menfess
# cus : cus
# tonton : tonton
# apk : apk
# bsk : bsk
# special : special
# chan : chan
# diharap : harap
# dimaki : maki
# judul : judul
# bulanan : bulan
# cabut : cabut
# colokin : colokin
# ampe : ampe
# lobang : lobang
# colokannya : colok
# longgar : longgar
# lapornya : lapor
# gituuu : gituuu
# solok : solok
# sumatera : sumatera
# barat : barat
# bertahan : tahan
# salam : salam
# sejahtera : sejahtera
# sebelumnye : sebelumnye
# ahom : ahom
# pepaya : pepaya
# simpati : simpati
# barengan : bareng
# anjeng : anjeng
# perdana : perdana
# njir : njir
# nyesek : nyesek
# muter : muter
# blm : blm
# indihim : indihim
# luplep : luplep
# diperbaiki : baik
# chena : chena
# lncar : lncar
# sinyale : sinyale
# koyok : koyok
# taek : taek
# mnc : mnc
# vision : vision
# nayangin : nayangin
# lawak : lawak
# gampang : gampang
# laporan : lapor
# diilangin : diilangin
# bertahun : tahun
# resmi : resmi
# myrepublic : myrepublic
# jangkauannya : jangkau
# reaksi : reaksi
# seriously : seriously
# aing : aing
# bae : bae
# marahin : marahin
# payah : payah
# bisanya : bisa
# gabsa : gabsa
# dpt : dpt
# pemerintah : perintah
# backup : backup
# plan : plan
# jsg : jsg
# sumpahhhh : sumpahhhh
# dahh : dahh
# weverse : weverse
# kapasitas : kapasitas
# speednya : speednya
# melemah : lemah
# wallahuuuu : wallahuuuu
# denger : denger
# pke : pke
# pemakaian : pakai
# dikurangin : rangin
# beyoungchan : beyoungchan
# yaa : yaa
# inii : ini
# istighfar : istighfar
# nawarin : nawarin
# tsel : tsel
# taik : taik
# ngeleg : ngeleg
# kelakuan : laku
# gregetan : gregetan
# makasihhh : makasihhh
# tanganku : tangan
# greatttt : greatttt
# yuhuuuuuu : yuhuuuuuu
# makassihhhh : makassihhhh
# maki : maki
# kacau : kacau
# finish : finish
# pemanasan : panas
# jopang : jopang
# jahat : jahat
# salahin : salahin
# eeea : eeea
# vibe : vibe
# mencekamnya : cekam
# thriller : thriller
# terror : terror
# horror : horror
# setan : setan
# enjoy : enjoy
# show : show
# nanuell : nanuell
# madrid : madrid
# barkui : barkui
# bermasalah : masalah
# berantem : antem
# hello : hello
# kecenya : kece
# akunnya : akun
# pergi : pergi
# pasar : pasar
# bebek : bebek
# penjual : jual
# bebeknya : bebek
# sukses : sukses
# jabodetabek : jabodetabek
# siska : siska
# ndarboy : ndarboy
# genk : genk
# gays : gays
# wiro : wiro
# desi : desi
# diatas : atas
# ian : ian
# cindynarulita : cindynarulita
# ramekan : ramekan
# bete : bete
# lancaaaaaarrr : lancaaaaaarrr
# floppppp : floppppp
# signal : signal
# kasian : kasi
# dipersalahkan : salah
# inbox : inbox
# maunya : mau
# kerja : kerja
# kemana : mana
# sembuhnya : sembuh
# anjg : anjg
# frans : frans
# plg : plg
# byk : byk
# dipakai : pakai
# masyarakat : masyarakat
# websitemu : websitemu
# diblokir : blokir
# alat : alat
# situs : situs
# now : now
# halooooo : halooooo
# mimin : mimin
# indihomeeeee : indihomeeeee
# gimanaaaaa : gimanaaaaa
# iniiii : iniiii
# muluuuu : muluuuu
# nyambung : nyambung
# internettttty : internettttty
# kenapaaaaaa : kenapaaaaaa
# yaaaahhhh : yaaaahhhh
# padahalll : padahalll
# indah : indah
# inboxxxxx : inboxxxxx
# nggakkk : nggakkk
# balesaaaannnnn : balesaaaannnnn
# indosat : indosat
# rada : rada
# alert : alert
# susun : susun
# tebak : tebak
# lirik : lirik
# saldo : saldo
# linkaja : linkaja
# pemenang : menang
# rules : rules
# goodluck : goodluck
# nugas : nugas
# hik : hik
# jug : jug
# mantaff : mantaff
# gws : gws
# respon : respon
# pastinya : pasti
# ngakak : ngakak
# betah : betah
# saksikan : saksi
# jalur : jalur
# rempah : rempah
# episode : episode
# puteri : puter
# pala : pala
# monolog : monolog
# ronggeng : ronggeng
# disaksikan : saksi
# berdoa : doa
# tuhan : tuhan
# gapake : gapake
# soale : soale
# berapaa : berapaa
# gil : gil
# aowkwkwkw : aowkwkwkw
# masal : masal
# berhari : hari
# komedi : komedi
# weeee : weeee
# jaring : jaring
# berdua : dua
# buset : buset
# dahhh : dahhh
# flop : flop
# ksksksksksk : ksksksksksk
# seungmin : seungmin
# seeehhhh : seeehhhh
# dipercaya : percaya
# adiknya : adik
# tante : tante
# maya : maya
# berangkat : berangkat
# membawa : bawa
# pegawai : pegawai
# kepercayaannya : percaya
# yos : yos
# melki : melki
# sumba : sumba
# mengelola : kelola
# hotel : hotel
# anyer : anyer
# tingkah : tingkah
# lucu : lucu
# aktifkan : aktif
# marsyel : marsyel
# syarat : syarat
# ketentuan : tentu
# viu : viu
# prem : prem
# sfu : sfu
# pecinta : cinta
# olahraga : olahraga
# ngadi : ngadi
# tegal : tegal
# daerah : daerah
# benerin : benerin
# film : film
# series : series
# tayang : tayang
# bgtttt : bgtttt
# kawasan : kawasan
# pakualaman : pakualaman
# yogyakarta : yogyakarta
# didaerah : daerah
# cijantung : cijantung
# gelo : gelo
# fuji : fuji
# tertumben : tumben
# vlive : vlive
# kawan : kawan
# sadar : sadar
# kemajuan : maju
# teknologi : teknologi
# simpel : simpel
# manfaatkan : manfaat
# positif : positif
# mengasah : asah
# skill : skill
# mengembangkan : kembang
# potensi : potensi
# cah : cah
# guyu : guyu
# kepingkel : kepingkel
# bengi : bengi
# ndelok : ndelok
# cak : cak
# precil : precil
# ndek : ndek
# streming : streming
# suwun : suwun
# wes : wes
# ihiiirrr : ihiiirrr
# sek : sek
# godok : godok
# telo : telo
# opo : opo
# kacang : kacang
# bala : bala
# lur : lur
# ngene : ngene
# kebanggaan : bangga
# muda : muda
# mumpung : mumpung
# percil : percil
# iso : iso
# guyon : guyon
# karo : karo
# hahahah : hahahah
# nangis : nang
# zoom : zoom
# kebanggane : kebanggane
# blitar : blitar
# tonggan : tonggan
# waktune : waktune
# golek : golek
# godokan : godok
# gas : gas
# tet : tet
# ojok : ojok
# diusahakan : usaha
# jarang : jarang
# protein : protein
# hewani : hewani
# jajan : jajan
# bubur : bubur
# angkringan : angkring
# seng : seng
# seneng : neng
# campursari : campursari
# masio : masio
# demen : demen
# kene : kene
# ngenteni : ngenteni
# streminge : streminge
# lop : lop
# ngundang : ngundang
# ahahhah : ahahhah
# peh : peh
# kolaborasi : kolaborasi
# apik : apik
# garai : garai
# nemen : nemen
# sak : sak
# omah : omah
# kebutulan : butul
# siapp : siapp
# tempur : tempur
# ampun : ampun
# onok : onok
# suwe : suwe
# akhire : akhire
# acarane : acarane
# gpp : gpp
# gambar : gambar
# indohome : indohome
# serapah : serapah
# pelayanannya : layan
# karna : karna
# betapa : betapa
# sulitnya : sulit
# pekerjaan : kerja
# membayar : bayar
# semangat : semangat
# perbaikanya : perbaikanya
# kedepannya : depan
# rulesnya : rulesnya
# wajib : wajib
# teman : teman
# sertakan : serta
# hashtag : hashtag
# hhhh : hhhh
# janji : janji
# cluenya : cluenya
# luck : luck
# assalamualaikum : assalamualaikum
# junaedi : junaedi
# karawang : karawang
# top : top
# warrior : warrior
# penuh : penuh
# pengumuman : umum
# bersyukur : syukur
# ditemenin : ditemenin
# bismillahirrahmanirrahim : bismillahirrahmanirrahim
# rezeki : rezeki
# setahun : tahun
# kegigit : gigit
# tikus : tikus
# tiang : tiang
# hitungan : hitung
# pemeliharaan : pelihara
# gaib : gaib
# dwi : dwi
# kiki : kiki
# lancaaaarr : lancaaaarr
# dumbela : dumbela
# ronnie : ronnie
# detail : detail
# menertakan : tak
# layanana : layanana
# cepat : cepat
# terselesaikan : selesai
# matikan : mati
# mirary : mirary
# shihab : shihab
# oooo : oooo
# latencynya : latencynya
# ngesavage : ngesavage
# kosan : kosan
# nggk : nggk
# astagfir : astagfir
# service : service
# telponnya : telpon
# dicabut : cabut
# berkurang : kurang
# wiwien : wiwien
# mekanisme : mekanisme
# kartu : kartu
# berkesempatan : sempat
# registrasi : registrasi
# pre : pre
# post : post
# test : test
# isi : isi
# testimoninya : testimoninya
# usaha : usaha
# mencari : cari
# tips : tips
# belanja : belanja
# nyaman : nyaman
# mempengaruhi : pengaruh
# pola : pola
# offline : offline
# memiliki : milik
# manfaat : manfaat
# murah : murah
# efisien : efisien
# hemat : hemat
# berubah : ubah
# perlahan : perlahan
# penyesuaian : sesuai
# kebijakan : bijak
# pembatasan : batas
# alternatif : alternatif
# menghindari : hindar
# kontak : kontak
# fisik : fisik
# kalimat : kalimat
# tumben : tumben
# mendingan : mending
# haram : haram
# canva : canva
# mengsedih : mengsedih
# kondisi : kondisi
# kode : kode
# tampilan : tampil
# capture : capture
# channelnya : channelnya
# terkoneksi : koneksi
# bayaran : bayar
# jalan : jalan
# pdhal : pdhal
# layarnya : layar
# item : item
# diprioritaskan : prioritas
# sepuluh : puluh
# aah : aah
# enoughisenough : enoughisenough
# monyeet : monyeet
# permisi : permisi
# silang : silang
# akses : akses
# sialan : sial
# asrin : asrin
# pembayaran : bayar
# plasa : plasa
# terdekat : dekat
# fisya : fisya
# bakset : bakset
# bbrp : bbrp
# ktng : ktng
# tunggu : tunggu
# terlambat : lambat
# klu : klu
# dispensasi : dispensasi
# eee : eee
# engga : engga
# byr : byr
# senasib : nasib
# dimaklumin : dimaklumin
# dicuaca : cuaca
# cerah : cerah
# labilnya : labil
# mood : mood
# pgn : pgn
# ngaco : ngaco
# back : back
# kanugrahan : kanugrahan
# hubungi : hubung
# bergunanya : guna
# dirimu : diri
# mengupload : mengupload
# tether : tether
# hapeku : hapeku
# aje : aje
# shorts : shorts
# tertawa : tertawa
# wtp : wtp
# xixixixi : xixixixi
# knppp : knppp
# enak : enak
# donlot : donlot
# los : los
# think : think
# all : all
# user : user
# could : could
# tuduh : tuduh
# ajjjngngngngngngngnggn : ajjjngngngngngngngnggn
# sahab : sahab
# lanjutan : lanjut
# intetnet : intetnet
# sebentar : sebentar
# conect : conect
# telpon : telpon
# optik : optik
# nyata : nyata
# akibat : akibat
# diputusin : diputusin
# plus : plus
# traveler : traveler
# limit : limit
# connect : connect
# nshwjjsjsbska : nshwjjsjsbska
# mksih : mksih
# qrorun : qrorun
# pertanyaannya : tanya
# tedy : tedy
# stop : stop
# rugi : rugi
# proses : proses
# mobile : mobile
# ios : ios
# tehe : tehe
# knapa : knapa
# diem : diem
# jancuk : jancuk
# karyawan : karyawan
# laut : laut
# nyelem : nyelem
# gapeduli : gapeduli
# ngemis : ngemis
# perhatian : perhati
# kesabaran : sabar
# tolol : tolol
# bubar : bubar
# myfwreen : myfwreen
# gosipnya : gosip
# beliau : beliau
# dlm : dlm
# istana : istana
# kerajaan : raja
# kejayaan : jaya
# majapahit : majapahit
# enaknya : enak
# support : support
# lae : lae
# waduuh : waduuh
# myfwreeen : myfwreeen
# gonta : gonta
# resep : resep
# perundungan : rundung
# masuknya : masuk
# insecure : insecure
# mentalnya : mental
# psikiater : psikiater
# fwren : fwren
# ngebutan : ngebut
# smartfwreeen : smartfwreeen
# kwwkwk : kwwkwk
# indikator : indikator
# nyala : nyala
# terputus : putus
# copot : copot
# nyalain : nyalain
# gambarny : gambarny
# lola : lola
# ytb : ytb
# noh : noh
# mayar : mayar
# ambyar : ambyar
# punten : punten
# sina : sina
# maruka : maruka
# wartel : wartel
# weh : weh
# fren : fren
# seharian : hari
# erorr : erorr
# halooo : halooo
# hei : hei
# iyh : iyh
# hom : hom
# knpwa : knpwa
# direset : direset
# modemnya : modem
# sis : sis
# agent : agent
# mengaktifkan : aktif
# lucunya : lucu
# pegawainya : pegawai
# seminggu : minggu
# kayaknya : kayak
# fess : fess
# dikasi : kasi
# kentankkk : kentankkk
# moots : moots
# rusak : rusak
# samuel : samuel
# hayoo : hayoo
# menyaksikan : saksi
# merapat : rapat
# dont : dont
# miss : miss
# indihomo : indihomo
# dibom : bom
# sang : sang
# hebat : hebat
# hayo : hayo
# curhat : curhat
# boring : boring
# drumah : drumah
# hayok : hayok
# kerumah : rumah
# ajakin : ajakin
# maraton : maraton
# fil : fil
# mmoung : mmoung
# jisoo : jisoo
# interview : interview
# cakep : cakep
# drama : drama
# nyaa : nyaa
# hiks : hiks
# ayok : ayok
# duluuu : duluuu
# bajakan : baja
# let : let
# friends : friends
# clear : clear
# bangeeet : bangeeet
# sinting : sinting
# monmaap : monmaap
# ege : ege
# wkwkw : wkwkw
# mengecek : ecek
# tidurr : tidurr
# akhirnyaa : akhirnyaa
# snowdrop : snowdrop
# otw : otw
# beliii : beliii
# pakettttt : pakettttt
# potong : potong
# soreee : soreee
# area : area
# luwung : luwung
# adiwerna : adiwerna
# nugro : nugro
# menunggu : tunggu
# bismillah : bismillah
# reza : reza
# rahadian : rahadian
# matulessy : matulessy
# anjengblemot : anjengblemot
# disuruh : suruh
# wtf : wtf
# nyanyi : nyanyi
# dance : dance
# ngehost : ngehost
# acting : acting
# duh : duh
# mba : mba
# idola : idola
# minneo : minneo
# mbanya : mbanya
# plisss : plisss
# ahhh : ahhh
# haein : haein
# gemes : gemes
# nyaaa : nyaaa
# ngelag : ngelag
# ooh : ooh
# kelap : kelap
# kelip : kelip
# harap : harap
# diproses : proses
# dipercepat : cepat
# mesjid : mesjid
# raudhan : raudhan
# idjen : idjen
# bolevard : bolevard
# keputus : putus
# ridha : ridha
# eyang : eyang
# titiek : titiek
# puspa : puspa
# merilis : rilis
# menandai : tanda
# perjalanan : jalan
# karirnya : karirnya
# karir : karir
# langit : langit
# kmrn : kmrn
# diulang : ulang
# smpe : smpe
# skrg : skrg
# blsan : blsan
# kebangetan : banget
# desember : desember
# tanggapan : tanggap
# hrs : hrs
# jami : jam
# alhakim : alhakim
# ruwadi : ruwadi
# ngungsi : ngungsi
# dmn : dmn
# sayano : sayano
# sabilillah : sabilillah
# minimal : minimal
# kepikiran : pikir
# lempar : lempar
# network : network
# lokal : lokal
# kakean : kakean
# fafifu : fafifu
# prettttttt : prettttttt
# buffer : buffer
# stream : stream
# manapun : mana
# suudzon : suudzon
# wipi : wipi
# abut : abut
# paman : paman
# penyebabnya : sebab
# kalinya : kali
# fibernya : fiber
# tabas : tabas
# sbgai : sbgai
# sarik : sarik
# menabas : menabas
# sengaja : sengaja
# mulahh : mulahh
# gawiaan : gawiaan
# tdii : tdii
# guee : guee
# jugaa : jugaa
# hampirr : hampirr
# sksksk : sksksk
# emangg : emangg
# drii : drii
# kbs : kbs
# wkwkwkwk : wkwkwkwk
# jdi : jdi
# memudahkan : mudah
# serba : serba
# kann : kann
# udhh : udhh
# suuzon : suuzon
# smaa : smaa
# tpii : tpii
# penggunanny : penggunanny
# pasang : pasang
# ongkos : ongkos
# pasangnya : pasang
# nyerah : nyerah
# tri : tri
# cepetan : cepetan
# kgk : kgk
# kiraiin : kiraiin
# menuduh : tuduh
# etmin : etmin
# fix : fix
# wkwkwkw : wkwkwkw
# owalah : owalah
# siii : siii
# nyalahin : nyalahin
# mubank : mubank
# music : music
# bank : bank
# kirain : kirain
# rmhku : rmhku
# flopp : flopp
# gaess : gaess
# apapun : apa
# bia : bia
# ikutin : ikutin
# panduan : pandu
# macem : macem
# macet : macet
# sekrang : sekrang
# indibasket : indibasket
# sederas : deras
# fei : fei
# ditag : ditag
# misuh : misuh
# nyantai : nyantai
# sosmed : sosmed
# friday : friday
# happy : happy
# temenin : temenin
# laporrrr : laporrrr
# nyari : nyari
# sepatu : sepatu
# canggih : canggih
# search : search
# zalora : zalora
# searchingan : searchingan
# syahbandar : syahbandar
# palang : palang
# dada : dada
# betawi : betawi
# bapuknya : bapuknya
# hhe : hhe
# boss : boss
# sever : sever
# nasa : nasa
# cobaan : coba
# janjiaan : janjiaan
# mengatasnamakan : mengatasnamakan
# keamanan : aman
# prioritas : prioritas
# appsnya : appsnya
# lambat : lambat
# webnya : webnya
# ngeload : ngeload
# csnya : csnya
# didm : didm
# direspon : direspon
# gelud : gelud
# nnti : nnti
# mikirin : mikirin
# teori : teori
# persekutuan : sekutu
# tersembunyi : sembunyi
# dajjal : dajjal
# hilal : hilal
# sembuh : sembuh
# cililitan : cililitan
# yayuk : yayuk
# jkt : jkt
# saluran : salur
# tembaga : tembaga
# memakai : pakai
# serat : serat
# optic : optic
# memasang : pasang
# pliss : pliss
# emm : emm
# inventaris : inventaris
# bantalan : bantal
# bigwin : bigwin
# lawan : lawan
# nontonnya : nontonnya
# lgsg : lgsg
# tinggal : tinggal
# pilih : pilih
# seepisode : episode
# bqngey : bqngey
# jumbo : jumbo
# satunya : satu
# naikin : naikin
# laennya : laennya
# mantul : mantul
# melancarkan : lancar
# aktifitas : aktifitas
# sekeren : keren
# knpa : knpa
# bermain : main
# benerr : benerr
# presentasinya : presentasi
# sekian : sekian
# kelompok : kelompok
# krena : krena
# jini : jin
# ntah : ntah
# nda : nda
# striming : striming
# dngan : dngan
# kantor : kantor
# kencang : kencang
# ditemani : tani
# tutorial : tutorial
# bersihkan : sih
# udang : udang
# pagiku : pagi
# berfaedah : faedah
# rebahanpun : rebah
# pengetahuan : tahu
# chef : chef
# suamikkk : suamikkk
# cokkkk : cokkkk
# putus : putus
# ramah : ramah
# dtg : dtg
# subakti : subakti
# boang : boang
# istrahat : istrahat
# nge : nge
# ninjaku : ninjaku
# auto : auto
# winn : winn
# dijanjikan : janji
# nongol : nongol
# generasi : generasi
# milenial : milenial
# bangun : bangun
# ketidaknyamanan : ketidaknyamanan
# dialami : alami
# berusaha : usaha
# memperbaiki : baik
# secepatnya : cepat
# presentasi : presentasi
# thank : thank
# you : you
# tewas : tewas
# batesi : batesi
# tele : tele
# dag : dag
# dig : dig
# dug : dug
# tindak : tindak
# thanks : thanks
# jejak : jejak
# laptop : laptop
# seseru : seru
# afternoon : afternoon
# are : are
# for : for
# your : your
# inconvenience : inconvenience
# there : there
# disruption : disruption
# some : some
# providers : providers
# currently : currently
# can : can
# access : access
# using : using
# repairing : repairing
# soon : soon
# possible : possible
# penerapan : terap
# ppkm : ppkm
# setia : setia
# aktivitas : aktivitas
# digital : digital
# wfh : wfh
# lfh : lfh
# responnya : responnya
# apasih : apasih
# tulungagung : tulungagung
# jawa : jawa
# timur : timur
# apak : apak
# azam : azam
# nurliana : nurliana
# asyik : asyik
# elvio : elvio
# ketidaknyamanannya : ketidaknyamanannya
# alami : alami
# adanyaa : adanyaa
# ngaded : ngaded
# lek : lek
# podo : podo
# temanku : teman
# have : have
# fun : fun
# ngandalin : ngandalin
# ter : ter
# cover : cover
# real : real
# kesekian : sekian
# lepas : lepas
# patch : patch
# cord : cord
# kelas : kelas
# seruan : seru
# gantia : gantia
# adik : adik
# tenang : tenang
# add : add
# layan : layan
# usee : usee
# perangkat : perangkat
# waah : waah
# pack : pack
# bahar : bahar
# hlow : hlow
# juned : juned
# typing : typing
# jamet : jamet
# allahuakbarr : allahuakbarr
# segitu : segitu
# peran : peran
# drawing : drawing
# kursus : kursus
# ajarin : ajarin
# platform : platform
# rasah : rasah
# njur : njur
# ngedown : ngedown
# mbarang : mbarang
# waahh : waahh
# genee : genee
# meh : meh
# dadi : dadi
# training : training
# kenali : kenal
# pahami : paham
# ekspresi : ekspresi
# goodvibe : goodvibe
# chaerim : chaerim
# halou : halou
# adi : adi
# mengisi : isi
# istirahat : istirahat
# indikids : indikids
# kamis : kamis
# pagitentunya : pagitentunya
# belajarnya : ajar
# goodbye : goodbye
# motherfader : motherfader
# wingi : wing
# lebar : lebar
# seko : seko
# gonku : gonku
# gmna : gmna
# otomatis : otomatis
# inteligent : inteligent
# home : home
# mengontrol : kontrol
# upgrade : upgrade
# solusine : solusine
# podcast : podcast
# berdurasi : durasi
# berkat : berkat
# report : report
# jago : jago
# excel : excel
# uwes : uwes
# menyakan : nyak
# teruss : teruss
# dikon : dikon
# ngecek : ngecek
# sipek : sipek
# jeh : jeh
# wkww : wkww
# percayakan : percaya
# wakeeh : wakeeh
# status : status
# entek : entek
# nalla : nalla
# papa : papa
# angry : angry
# poor : poor
# performance : performance
# but : but
# his : his
# anger : anger
# crushed : crushed
# geprek : geprek
# bensu : bensu
# njs : njs
# threatened : threatened
# cut : cut
# off : off
# use : use
# complaint : complaint
# was : was
# not : not
# responded : responded
# well : well
# ibaratkeun : ibaratkeun
# geus : geus
# awewe : awewe
# dihakan : hak
# batur : batur
# kasar : kasar
# nez : nez
# hanna : hanna
# disebabkan : sebab
# device : device
# redaman : redam
# faktor : faktor
# cuaca : cuaca
# ditindaklanjuti : ditindaklanjuti
# ristri : ristri
# lmao : lmao
# working : working
# congratulations : congratulations
# indiehome : indiehome
# memahami : paham
# kegalauan : galau
# lead : lead
# ers : ers
# menjangkau : jangkau
# gamer : gamer
# berbakat : bakat
# diperpanjang : panjang
# november : november
# menyadari : sadar
# sejam : jam
# ngeloop : ngeloop
# natsuno : natsuno
# easy : easy
# gaya : gaya
# pekan : pekan
# tontonan : tonton
# nobar : nobar
# laga : laga
# paketnya : paket
# oiyah : oiyah
# bner : bner
# lhoooo : lhoooo
# nyeles : nyeles
# down : down
# cirofatah : cirofatah
# kyk : kyk
# email : email
# dbs : dbs
# berkaitan : kait
# pencabutan : cabut
# minting : minting
# jan : jan
# bot : bot
# perbedaan : beda
# pelajar : ajar
# segi : segi
# streamingnya : streamingnya
# jatimbalinusra : jatimbalinusra
# gladies : gladies
# lariesa : lariesa
# peraih : raih
# iii : iii
# medali : medali
# emas : emas
# ajang : ajang
# pon : pon
# okt : okt
# imam : imam
# januar : januar
# komunikasi : komunikasi
# smooa : smooa
# perpanjang : panjang
# ngetrol : ngetrol
# baliknya : balik
# niat : niat
# ngestream : ngestream
# gakerasa : gakerasa
# disaat : saat
# scrolling : scrolling
# cari : cari
# refrensi : refrensi
# rencana : rencana
# libur : libur
# menu : menu
# ngiler : ngiler
# krg : krg
# ajr : ajr
# cantik : cantik
# gilakk : gilakk
# gasabar : gasabar
# doi : doi
# frog : frog
# ganggung : ganggung
# gmbar : gmbar
# gayakin : gayakin
# lemootttt : lemootttt
# hancur : hancur
# wiwi : wiwi
# nisaku : nisaku
# daerahku : daerah
# sihhhh : sihhhh
# hellooooo : hellooooo
# merugy : merugy
# dapetnya : dapetnya
# nyampe : nyampe
# stb : stb
# gmn : gmn
# seee : seee
# mewhiterose : mewhiterose
# guyss : guyss
# hans : hans
# swing : swing
# hiburan : hibur
# searching : searching
# didukung : dukung
# massal : massal
# kesimpulan : simpul
# connection : connection
# unstable : unstable
# hadehhh : hadehhh
# pendaftarannya : daftar
# floop : floop
# seribu : ribu
# tua : tua
# bermimpi : mimpi
# mengubah : ubah
# karno : karno
# kuliah : kuliah
# ngecrash : ngecrash
# ngasal : ngasal
# intip : intip
# sesantai : santa
# santaipun : santai
# byu : byu
# sit : sit
# same : same
# table : table
# org : org
# ngecap : ngecap
# matiin : matiin
# bat : bat
# lnjut : lnjut
# kecewa : kecewa
# mengajukan : aju
# pda : pda
# odp : odp
# headset : headset
# kartun : kartun
# berasa : asa
# vibes : vibes
# allahu : allahu
# akbar : akbar
# maha : maha
# mikaf : mikaf
# nana : nana
# konfirmasi : konfirmasi
# pengaturan : atur
# volume : volume
# remote : remote
# interaksi : interaksi
# operasikan : operasi
# pintar : pintar
# kehilangan : hilang
# kunci : kunci
# door : door
# lock : lock
# diatur : atur
# suaranya : suara
# suara : suara
# emoji : emoji
# capedeh : capedeh
# request : request
# approve : approve
# nunggu : nunggu
# team : team
# berkali : kali
# tetep : tetep
# skg : skg
# dipasang : pasang
# yukk : yukk
# one : one
# punch : punch
# animax : animax
# sepuasnya : puas
# progress : progress
# pengajuan : aju
# penambahan : tambah
# worth : worth
# mwmuaskan : mwmuaskan
# tugas : tugas
# loadingnya : loadingnya
# penukaran : tukar
# redeem : redeem
# poin : poin
# lounge : lounge
# concordia : concordia
# bandara : bandara
# inrenasional : inrenasional
# lombok : lombok
# kehabisan : habis
# melangkah : lang
# yukkk : yukkk
# sdah : sdah
# lemod : lemod
# perusahaan : usaha
# bumn : bumn
# kya : kya
# bnyak : bnyak
# imet : imet
# diganti : ganti
# ont : ont
# trrus : trrus
# opsi : opsi
# gtu : gtu
# viral : viral
# kompensasinya : kompensasi
# selali : lali
# psang : psang
# pkai : pkai
# toloooongg : toloooongg
# troubleeeeeee : troubleeeeeee
# senyum : senyum
# merekah : mere
# penyelamat : selamat
# lakuin : lakuin
# dibaca : baca
# uwe : uwe
# ner : ner
# aseli : aseli
# karaokean : karaoke
# serc : serc
# lagilu : lagilu
# kesukaan : suka
# kontrakan : kontra
# renek : renek
# kabeh : kabeh
# kecuali : kecuali
# tenan : tenan
# hobby : hobby
# lho : lho
# pantau : pantau
# sekolah : sekolah
# puas : puas
# waswas : waswas
# terpantau : pantau
# bagimana : bagimana
# set : set
# box : box
# browsing : browsing
# sprt : sprt
# ditonton : tonton
# iklan : iklan
# ubur : ubur
# chizuru : chizuru
# nikaido : nikaido
# hlo : hlo
# shinonome : shinonome
# true : true
# jia : jia
# logout : logout
# loginnya : loginnya
# dmna : dmna
# don : don
# know : know
# feel : feel
# blessing : blessing
# made : made
# everything : everything
# going : going
# eazy : eazy
# day : day
# sebulanan : bulan
# timbul : timbul
# tenggelem : tenggelem
# bsa : bsa
# tolonglah : tolong
# goyang : goyang
# mbok : mbok
# monopoli : monopoli
# penghargaan : harga
# blablabla : blablabla
# koneksimu : koneksi
# benakno : benakno
# kumat : kumat
# emng : emng
# firstmedia : firstmedia
# pakenya : pakenya
# bye : bye
# bgaimna : bgaimna
# percaya : percaya
# plss : plss
# bri : bri
# liga : liga
# useesports : useesports
# tersedia : sedia
# indisport : indisport
# ambil : ambil
# compensate : compensate
# kerugian : rugi
# nomer : nomer
# spill : spill
# tea : tea
# pertandingannya : tanding
# beraksi : aksi
# menghadapi : hadap
# australia : australia
# vidio : vidio
# apps : apps
# store : store
# googlemeet : googlemeet
# tiada : tiada
# super : super
# pencariannya : cari
# playstore : playstore
# wey : wey
# stress : stress
# perbaiki : baik
# ghosting : ghosting
# kroso : kroso
# abot : abot
# yonan : yonan
# arek : arek
# paham : paham
# diskon : diskon
# bibong : bibong
# bio : bio
# mat : mat
# karbo : karbo
# rice : rice
# cooker : cooker
# bread : bread
# master : master
# lewatkan : lewat
# payday : payday
# sale : sale
# ajak : ajak
# fee : fee
# sales : sales
# kesempatan : sempat
# menghasilkan : hasil
# hardi : hardi
# sandi : sandi
# segmentasi : segmentasi
# perbarui : baru
# heheh : heheh
# jiakh : jiakh
# dha : dha
# tlfon : tlfon
# kaget : kaget
# kebangun : bangun
# direktur : direktur
# ges : ges
# kerjasamanyam : kerjasamanyam
# volunteer : volunteer
# njawab : njawab
# bad : bad
# frustasi : frustasi
# jawabanku : jawab
# creditnya : creditnya
# kepotong : potong
# saldonya : saldo
# bln : bln
# ntn : ntn
# premium : premium
# icare : icare
# alun : alun
# never : never
# qwq : qwq
# dukung : dukung
# timnas : timnas
# nyopot : nyopot
# nder : nder
# bawa : bawa
# dibalikne : dibalikne
# peler : peler
# memek : memek
# nagita : nagita
# lucuan : lucu
# yach : yach
# menghibur : hibur
# kosong : kosong
# oyi : oyi
# ngno : ngno
# iku : iku
# sixsense : sixsense
# trust : trust
# pikirkan : pikir
# rahardian : rahardian
# concierge : concierge
# reboot : reboot
# sehak : hak
# efek : efek
# membaik : baik
# sempurna : sempurna
# lelamaan : lama
# magribkek : magribkek
# anjj : anjj
# menang : menang
# scroll : scroll
# tiktok : tiktok
# stalk : stalk
# crush : crush
# cakepnya : cakep
# heheheu : heheheu
# perbucinanku : perbucinanku
# ehehe : ehehe
# hahahahahhaahah : hahahahahhaahah
# tutupi : tutup
# aibmu : aib
# temenmu : temenmu
# keke : keke
# menginspirasi : inspirasi
# goblok : goblok
# cahaya : cahaya
# lamp : lamp
# mengatur : atur
# intensitas : intensitas
# fitur : fitur
# intelligent : intelligent
# mark : mark
# zuckerberg : zuckerberg
# umumkan : umum
# facebook : facebook
# meta : meta
# singkatnya : singkat
# frontier : frontier
# membangun : bangun
# metaverse : metaverse
# dimana : mana
# menyatu : satu
# hasil : hasil
# bukti : bukti
# indo : indo
# legal : legal
# kplus : kplus
# khusus : khusus
# diluar : luar
# ngelacak : ngelacak
# full : full
# gasih : gasih
# switch : switch
# ringan : ringan
# kelapa : kelapa
# cimanggis : cimanggis
# nyeselin : nyeselin
# bangettt : bangettt
# lemooott : lemooott
# kacaw : kacaw
# tydac : tydac
# sarapan : sarap
# buryam : buryam
# oke : oke
# multitalent : multitalent
# dateng : dateng
# kooperatif : kooperatif
# fuck : fuck
# nemu : nemu
# simple : simple
# ngescroll : ngescroll
# senggang : senggang
# dihati : hati
# hahahahhahah : hahahahhahah
# mangkanya : mangkanya
# cuss : cuss
# sapa : sapa
# virtual : virtual
# aktifitasnya : aktifitasnya
# keu : keu
# bizznet : bizznet
# bawaannya : bawa
# emosian : emosi
# senilai : nila
# juta : juta
# charity : charity
# lemott : lemott
# kacauuuuuuu : kacauuuuuuu
# kb : kb
# commerce : commerce
# menitan : menit
# muncul : muncul
# alasannya : alas
# turunkan : turun
# tekor : tekor
# hiu : hiu
# perjanjian : janji
# jt : jt
# menjebak : jebak
# tricknya : tricknya
# nxjsns : nxjsns
# snajns : snajns
# contoh : contoh
# layout : layout
# zayn : zayn
# khai : kha
# premier : premier
# platinum : platinum
# kesayanganmu : sayang
# uefa : uefa
# champions : champions
# league : league
# gigit : gigit
# pakek : pakek
# talkshow : talkshow
# kenalan : kenal
# pkl : pkl
# air : air
# fm : fm
# sonora : sonora
# mengahadirkan : mengahadirkan
# mingdep : mingdep
# uts : uts
# myrep : myrep
# satupun : satu
# coverage : coverage
# hold : hold
# tight : tight
# fellas : fellas
# rto : rto
# coming : coming
# kecamatan : camat
# bandung : bandung
# urang : urang
# ngerjain : ngerjain
# galian : gali
# flyover : flyover
# sekelurahan : lurah
# gunawan : gunawan
# herdians : herdians
# putra : putra
# narik : narik
# wijaya : wijaya
# silit : silit
# dijadiin : dijadiin
# sampah : sampah
# ditingkatin : ditingkatin
# roblox : roblox
# telepon : telepon
# customer : customer
# oct : oct
# cuy : cuy
# senin : senin
# permintaan : minta
# surat : surat
# pemurusan : murus
# koreksi : koreksi
# supriadi : supriadi
# mengirimkan : kirim
# pribadi : pribadi
# rekening : rekening
# direfund : direfund
# kaf : kaf
# skalian : skalian
# melatih : latih
# fck : fck
# sake : sake
# listening : listening
# german : german
# dosen : dosen
# hearteu : hearteu
# opseo : opseo
# telkomselku : telkomselku
# prank : prank
# bgitu : bgitu
# message : message
# pelaporan : lapor
# realisasi : realisasi
# skp : skp
# dinas : dinas
# mulus : mulus
# connec : connec
# disconnects : disconnects
# isolasi : isolasi
# fitriana : fitriana
# otaknya : otak
# dngn : dngn
# nmr : nmr
# hunter : hunter
# wta : wta
# cbn : cbn
# hope : hope
# hahah : hahah
# gokilll : gokilll
# peri : peri
# bacain : bacain
# puisi : puisi
# merinding : merinding
# ngerasa : ngerasa
# janggal : janggal
# benerran : benerran
# editan : edit
# adekku : adekku
# ngumpul : ngumpul
# temennya : temennya
# ernest : ernest
# kadrun : kadrun
# merespon : merespon
# pelanggannya : langgan
# melestarikan : lestari
# budaya : budaya
# jajaran : jajar
# saudara : saudara
# partisipasi : partisipasi
# dukungan : dukung
# duta : duta
# akhlaqnya : akhlaqnya
# upload : upload
# mosok : mosok
# sakjam : sakjam
# garap : garap
# tangi : tang
# esuk : esuk
# aktifin : aktifin
# indijapan : indijapan
# telkomgroup : telkomgroup
# likes : likes
# comment : comment
# afriwandi : afriwandi
# ditangani : tangan
# nihhhh : nihhhh
# jeblok : jeblok
# nganggo : nganggo
# omhku : omhku
# bosok : bosok
# andani : andan
# pelosok : pelosok
# non : non
# dibohongi : bohong
# diakses : akses
# menyalahi : salah
# aturan : atur
# nyusahin : nyusahin
# strategis : strategis
# berkelanjutan : lanjut
# tsb : tsb
# menentukan : tentu
# sewa : sewa
# beragam : agam
# semurah : murah
# timpuk : timpuk
# explore : explore
# keyword : keyword
# trending : trending
# fauzan : fauzan
# berpartisipasi : partisipasi
# marsha : marsha
# jelekkkkkkkkk : jelekkkkkkkkk
# anjeeeeeng : anjeeeeeng
# bercanda : canda
# dehh : dehh
# lemah : lemah
# tipsnya : tipsnya
# litek : litek
# asyn : asyn
# tubesnya : tubesnya
# review : review
# adakah : ada
# sambungan : sambung
# ditindak : tindak
# lanjuti : lanjut
# gmeet : gmeet
# oncam : oncam
# dimaragin : dimaragin
# anjirtt : anjirtt
# pindag : pindag
# micnya : micnya
# taulahya : taulahya
# dimarahin : dimarahin
# anjirr : anjirr
# dibilang : bilang
# alesan : alesan
# ngasi : ngasi
# membuka : buka
# disconnect : disconnect
# maintain : maintain
# cluster : cluster
# koq : koq
# kesini : kesini
# sech : sech
# alasan : alas
# dikampung : kampung
# disiapkan : siap
# iye : iye
# papaku : papa
# senior : senior
# memperhatikan : perhati
# lagee : lagee
# sharelok : sharelok
# dipinggir : pinggir
# jln : jln
# senggol : senggol
# buu : buu
# arrrggggggh : arrrggggggh
# ngawur : ngawur
# speedtest : speedtest
# appstore : appstore
# siput : siput
# terlewatkan : lewat
# melalukan : lalu
# kenappa : kenappa
# lost : lost
# ayati : ayat
# anjrit : anjrit
# komitmen : komitmen
# laporkan : lapor
# wooiiii : wooiiii
# sii : sii
# pagii : pagi
# parahh : parahh
# kecewaaa : kecewaaa
# allag : allag
# kel : kel
# margahayu : margahayu
# bekasi : bekas
# kemaren : kemaren
# nyuruhnya : nyuruhnya
# mank : mank
# daon : daon
# egk : egk
# jngn : jngn
# tempe : tempe
# ragi : ragi
# dimasak : masak
# bumbunya : bumbu
# kecap : kecap
# yuhuuu : yuhuuu
# sendernya : sender
# nyeremin : nyeremin
# barangkali : barangkali
# tambahin : tambahin
# keliatan : liat
# infonya : info
# wilayah : wilayah
# beji : beji
# reswt : reswt
# ...
# peduliin : peduliin
# aaya : aaya
# load : load
# dikasarin : dikasarin
# netijen : netijen
# linknya : linknya
# muluk : muluk
# anjer : anjer
# kerjain : kerjain
# gajian : gaji
# kerjanya : kerja
# umr : umr
# parahan : parah
# yups : yups
# njenengan : njenengan
# ngadatnya : ngadatnya
# anjiiirr : anjiiirr
# slah : slah
# daily : daily
# reminder : reminder
# antek : antek
# anteknya : antek
# knpsi : knpsi
# send : send
# dududu : dududu
# janhan : janhan
# korosu : korosu
# mukul : mukul
# mntang : mntang
# jrng : jrng
# bngt : bngt
# kenape : kenape
# njim : njim
# anjirrr : anjirrr
# progres : progres
# daritadi : daritadi
# menyala : nyala
# refresh : refresh
# haduhhh : haduhhh
# tuhkan : tuhkan
# gmbr : gmbr
# kelangan : kelang
# sing : sing
# diarani : diarani
# mantan : mantan
# better : better
# bitch : bitch
# berjumpa : jumpa
# wak : wak
# optimal : optimal
# moehammad : moehammad
# yamin : yamin
# delapan : delapan
# nst : nst
# buktinya : bukti
# anjigngngn : anjigngngn
# penyesalann : penyesalann
# otta : otta
# troublenya : troublenya
# masalahkah : masalah
# ofc : ofc
# demilkian : demilkian
# rabu : rabu
# total : total
# kpi : kpi
# ngomel : ngomel
# gen : gen
# mot : mot
# polibek : polibek
# kucell : kucell
# kmarin : kmarin
# dimakan : makan
# twiti : twiti
# neh : neh
# broadband : broadband
# unggulan : unggul
# mengedepankan : depan
# aspek : aspek
# dicanangkan : canang
# regular : regular
# kuartalnya : kuartal
# left : left
# ipad : ipad
# cookie : cookie
# run : run
# guess : guess
# what : what
# its : its
# waiting : waiting
# hours : hours
# shit : shit
# kesamber : kesamber
# gledeg : gledeg
# cuacanya : cuaca
# bangsattttttt : bangsattttttt
# adzan : adzan
# jisung : jisung
# komitmennya : komitmen
# bangkit : bangkit
# tantangan : tantang
# covid : covid
# deras : deras
# thebodyshop : thebodyshop
# gulf : gulf
# wkwkwkwkwkw : wkwkwkwkwkw
# aslii : asli
# keuangan : uang
# mine : mine
# jsjsjsjsjsj : jsjsjsjsjsj
# berulahnya : ulah
# joan : joan
# bangkitkan : bangkit
# pademi : pademi
# pacar : pacar
# kerjaannya : kerja
# penjaga : jaga
# warnet : warnet
# tukang : tukang
# bakso : bakso
# plz : plz
# komentatornya : komentator
# dancok : dancok
# draw : draw
# sumon : sumon
# gemoy : gemoy
# hhhhh : hhhhh
# installasi : installasi
# wonu : wonu
# maliiihhhh : maliiihhhh
# numpang : numpang
# sebelah : belah
# kenapaasih : kenapaasih
# migrasi : migrasi
# maap : maap
# ngenes : ngenes
# ramekne : ramekne
# rahmatika : rahmatika
# sotoy : sotoy
# plat : plat
# misii : misi
# sanggup : sanggup
# twitteran : twitteran
# tipu : tipu
# yaelah : yaelah
# komplekku : komplekku
# ngajuin : ngajuin
# oxygen : oxygen
# garr : garr
# mawar : mawar
# berlika : berlika
# liku : liku
# sakit : sakit
# hatinya : hati
# setres : tres
# mikrotik : mikrotik
# pengaturannya : atur
# bridge : bridge
# diisi : isi
# pppoe : pppoe
# mengetahuinya : tahu
# robi : robi
# form : form
# mendapatkannya : dapat
# iyaa : iyaa
# formulir : formulir
# pendaftaran : daftar
# liburan : libur
# honeymoon : honeymoon
# lampung : lampung
# mnet : mnet
# zee : zee
# than : than
# book : book
# sbnrnya : sbnrnya
# rebutan : rebut
# anjgg : anjgg
# tegesin : tegesin
# mauu : mauu
# gapujya : gapujya
# bekingan : beking
# mslh : mslh
# penelitian : teliti
# oenelitian : oenelitian
# nilainya : nilai
# penipu : tipu
# terjuntai : juntai
# telfon : telfon
# partai : partai
# sumpat : sumpat
# kaulamuda : kaulamuda
# berlebih : lebih
# chitaex : chitaex
# mahadewa : mahadewa
# menemukan : temu
# dikirimkan : kirim
# somasi : somasi
# bandar : bandar
# hypera : hypera
# bangke : bangke
# ngefitnah : ngefitnah
# pencerahannya : cerah
# mint : mint
# ksian : ksi
# ade : ade
# giveawaynya : giveawaynya
# dikasih : kasih
# should : should
# word : word
# multiplayer : multiplayer
# anjrot : anjrot
# perubahan : ubah
# terusan : terus
# tengs : tengs
# deng : deng
# pacarku : pacar
# ihhh : ihhh
# nerbener : nerbener
# ilichil : ilichil
# diinfokan : info
# perkiraan : kira
# pengawalan : awal
# raja : raja
# apee : apee
# ujannya : ujannya
# bru : bru
# nelp : nelp
# magang : magang
# angkat : angkat
# lix : lix
# hajar : hajar
# lannya : lannya
# passwordnya : passwordnya
# nuranisa : nuranisa
# maulida : maulida
# melampirkan : lampir
# layar : layar
# oscar : oscar
# ijazah : ijazah
# hotspot : hotspot
# smg : smg
# jafar : jafar
# menerima : terima
# promosi : promosi
# ari : ari
# kentod : kentod
# pissed : pissed
# usd : usd
# koreo : koreo
# berkomitmen : komitmen
# produktif : produktif
# kreatif : kreatif
# enha : enha
# tampil : tampil
# nangiss : nangiss
# seventeen : seventeen
# nct : nct
# judulnya : judul
# pokonya : poko
# energinya : energi
# direstrat : direstrat
# robot : robot
# sedari : dar
# cornelia : cornelia
# diinformasikan : informasi
# blur : blur
# lebat : lebat
# hmmnnn : hmmnnn
# nas : nas
# rakitan : rakit
# hahahaaaaa : hahahaaaaa
# omv : omv
# kebutuhan : butuh
# waras : waras
# kasusnya : kasus
# reinstall : reinstall
# mac : mac
# big : big
# sur : sur
# server : server
# cdn : cdn
# ngulang : ngulang
# dipancing : pancing
# hong : hong
# kong : kong
# had : had
# job : job
# cecan : cecan
# joget : joget
# ekslusif : ekslusif
# perhatikan : perhati
# menambah : tambah
# harimu : hari
# deres : deres
# kupas : kupas
# tuntas : tuntas
# fiber : fiber
# bahas : bahas
# pengertian : erti
# berserta : serta
# fungsinya : fungsi
# gomong : gomong
# naia : naia
# useesport : useesport
# trims : trims
# doain : doain
# kepo : kepo
# brp : brp
# penggajiannya : gaji
# dikss : dikss
# senikmat : nikmat
# provinsi : provinsi
# rezha : rezha
# claudi : claudi
# hapus : hapus
# memenangi : tang
# selisih : selisih
# gol : gol
# juara : juara
# grup : grup
# pdf : pdf
# darlinkkk : darlinkkk
# siihhh : siihhh
# gabisaa : gabisaa
# detailnya : detail
# spike : spike
# rox : rox
# kluar : kluar
# baphomet : baphomet
# nauzubillah : nauzubillah
# temanmu : teman
# diumumkan : umum
# lengkapi : lengkap
# pemutusan : putus
# gabener : gabener
# gerimis : gerimis
# compe : compe
# nyokap : nyokap
# ponseltersedia : ponseltersedia
# siiiiiii : siiiiiii
# menemani : tani
# perjuangan : juang
# tayangannya : tayang
# klub : klub
# jagoan : jago
# seluru : seluru
# pemudi : pemudi
# indinesia : indinesia
# keseharian : hari
# sasa : sasa
# jasa : jasa
# bocil : bocil
# wawasan : wawas
# atasi : atas
# sadarnya : sadar
# xiao : xiao
# venti : venti
# dtng : dtng
# tapj : tapj
# bgsd : bgsd
# ava : ava
# ngevote : ngevote
# wkwkwkwkw : wkwkwkwkw
# bebas : bebas
# senpai : senpai
# ngakakak : ngakakak
# tbtb : tbtb
# menyediakan : sedia
# dipilih : pilih
# tersebar : sebar
# indones : indones
# artian : arti
# ngeliat : ngeliat
# respons : respons
# kentongan : kentongan
# pengelihatan : lihat
# pojok : pojok
# kanan : kanan
# liatin : liatin
# kuda : kuda
# slide : slide
# photo : photo
# wan : wan
# traffic : traffic
# tetunya : tetunya
# pencarian : cari
# balas : balas
# dikelasnya : kelas
# hijau : hijau
# zte : zte
# ingfo : ingfo
# repeater : repeater
# wakakakaa : wakakakaa
# sinet : set
# doank : doank
# applikasi : applikasi
# annya : annya
# bahagia : bahagia
# uma : uma
# lwn : lwn
# buhan : buhan
# gin : gin
# drmh : drmh
# lancarku : lancar
# uduudud : uduudud
# makeup : makeup
# transition : transition
# thomas : thomas
# uber : uber
# cup : cup
# tangkis : tangkis
# merebut : rebut
# panggung : panggung
# olimpiade : olimpiade
# barcelona : barcelona
# pelajari : ajar
# keuntungan : untung
# high : high
# value : value
# telponan : telpon
# ngaggur : ngaggur
# menyenangkan : senang
# ibadah : ibadah
# ytnya : ytnya
# kepental : pental
# bengcek : bengcek
# line : line
# gamau : gamau
# kids : kids
# kereen : kereen
# jae : jae
# cosplay : cosplay
# echo : echo
# aulia : aulia
# handphone : handphone
# lantai : lantai
# kmr : kmr
# tdr : tdr
# mtr : mtr
# utama : utama
# sumber : sumber
# pdam : pdam
# sumur : sumur
# submarsible : submarsible
# filter : filter
# kichen : kichen
# huni : huni
# nego : nego
# mantep : mantep
# prosedur : prosedur
# sugil : sugil
# gaje : gaje
# nelfon : nelfon
# mbak : mbak
# gilbrania : gilbrania
# get : get
# wifiku : wifiku
# agus : agus
# nata : nata
# pach : pach
# menstabilkan : stabil
# simpang : simpang
# bengkulu : bengkulu
# pasword : pasword
# rajanya : raja
# menangis : menang
# kostum : kostum
# diy : diy
# bahan : bahan
# seadanya : ada
# dominan : dominan
# kantong : kantong
# kresek : kresek
# pinter : pinter
# masak : masak
# cpe : cpe
# bget : bget
# menginformasikan : informasi
# regitrasikan : regitrasikan
# lgie : lgie
# skolah : skolah
# onlen : onlen
# nie : nie
# hrus : hrus
# bgaimana : bgaimana
# kerena : rena
# makannya : makan
# ngk : ngk
# obatnya : obat
# btul : btul
# costumer : costumer
# cerdas : cerdas
# cermat : cermat
# dlam : dlam
# menanggapi : tanggap
# berinternetan : berinternetan
# tnpa : tnpa
# bts : bts
# brsma : brsma
# sisa : sisa
# garis : garis
# erma : erma
# eshal : eshal
# dnger : dnger
# psti : psti
# jringnnya : jringnnya
# tuhh : tuhh
# stgh : stgh
# kerennya : keren
# information : information
# trailer : trailer
# lightyear : lightyear
# sekilas : kilas
# biopik : biopik
# karakter : karakter
# legendaris : legendaris
# buzz : buzz
# toy : toy
# filmnya : film
# latar : latar
# stres : stres
# kepasang : pasang
# {'min': 'min', 'lemot': 'lot', 'gratis': 'gratis', 'bayar': 'bayar', 'sebulan': 'bulan', 'bonus': 'bonus', 'clay': 'clay', 'masknya': 'masknya', 'npure': 'npure', '': '', 'sore': 'sore', 'gini': 'gin', 'jawabannya': 'jawab', 'batavia': 'batavia', 'yuk': 'yuk', 'sobat': 'sobat', 'ikutan': 'ikut', 'gada': 'gada', 'lbh': 'lbh', 'monyet': 'monyet', 'jaringan': 'jaring', 'indihome': 'indihome', 'pagi': 'pagi', 'lagu': 'lagu', 'mendung': 'mendung', 'tanpo': 'tanpo', 'udan': 'udan', 'lupa': 'lupa', 'follow': 'follow', 'woy': 'woy', 'donk': 'donk', 'pandemi': 'pandemi', 'dirmh': 'dirmh', 'bermanfaat': 'manfaat', 'nich': 'nich', 'join': 'join', 'allah': 'allah', 'keseruan': 'seru', 'disore': 'sore', 'sharing': 'sharing', 'mutahir': 'mutahir', 'protes': 'protes', 'indirmh': 'indirmh', 'waroo': 'waroo', 'crying': 'crying', 'look': 'look', 'loading': 'loading', 'streams': 'streams', 'once': 'once', 'love': 'love', 'torturing': 'torturing', 'internet': 'internet', 'provider': 'provider', 'berhenti': 'henti', 'ppp': 'ppp', 'sihhh': 'sihhh', 'ospek': 'ospek', 'jam': 'jam', 'ayodong': 'ayodong', 'kerjasamanyaaa': 'kerjasamanyaaa', 'seru': 'seru', 'ilmu': 'ilmu', 'dot': 'dot', 'bagus': 'bagus', 'dirumah': 'rumah', 'ajanjoin': 'ajanjoin', 'keknya': 'kek', 'rekor': 'rekor', 'tercepat': 'cepat', 'tumbenan': 'tumben', 'banget': 'banget', 'gua': 'gua', 'download': 'download', 'file': 'file', 'ukuran': 'ukur', 'gb': 'gb', 'berhasil': 'hasil', 'menit': 'menit', 'malesin': 'malesin', 'wall': 'wall', 'putri': 'putri', 'gagara': 'gagara', 'ayo': 'ayo', 'buruan': 'buru', 'bergabung': 'gabung', 'menarik': 'tarik', 'update': 'update', 'pertandingan': 'tanding', 'nba': 'nba', 'favorit': 'favorit', 'dijamin': 'jamin', 'ketinggalan': 'tinggal', 'jadwal': 'jadwal', 'terkini': 'kini', 'informasi': 'informasi', 'lengkap': 'lengkap', 'dunia': 'dunia', 'paket': 'paket', 'minipack': 'minipack', 'indibasketball': 'indibasketball', 'seno': 'seno', 'halo': 'halo', 'care': 'care', 'mhn': 'mhn', 'bantuan': 'bantu', 'dicek': 'cek', 'telp': 'telp', 'rmh': 'rmh', 'mati': 'mati', 'oktober': 'oktober', 'sob': 'sob', 'prima': 'prima', 'yen': 'yen', 'saiki': 'saiki', 'wae': 'wae', 'jawabane': 'jawabane', 'ijin': 'ijin', 'tag': 'tag', 'astu': 'astu', 'prsnlng': 'prsnlng', 'keren': 'keren', 'just': 'just', 'musim': 'musim', 'ujan': 'ujan', 'udh': 'udh', 'ngajak': 'ngajak', 'ribut': 'ribut', 'gila': 'gila', 'sinyal': 'sinyal', 'segini': 'gin', 'emg': 'emg', 'anehhhhhh': 'anehhhhhh', 'phoenix': 'phoenix', 'slowrespon': 'slowrespon', 'trobel': 'trobel', 'ajg': 'ajg', 'fase': 'fase', 'kehidupan': 'hidup', 'kesepian': 'sepi', 'pas': 'pas', 'udah': 'udah', 'nikah': 'nikah', 'suami': 'suami', 'sibuk': 'sibuk', 'anak': 'anak', 'les': 'les', 'kumon': 'kumon', 'trus': 'trus', 'gangguan': 'ganggu', 'detik': 'detik', 'kejelasan': 'jelas', 'pemasangan': 'pasang', 'malu': 'malu', 'kedok': 'kedok', 'verifikasi': 'verifikasi', 'gabut': 'gabut', 'semalem': 'semalem', 'tetangga': 'tetangga', 'manggil': 'manggil', 'petugas': 'tugas', 'gatau': 'gatau', 'ngapain': 'ngapain', 'trs': 'trs', 'malem': 'malem', 'wifi': 'wifi', 'rumah': 'rumah', 'tanda': 'tanda', 'serunya': 'seru', 'lampunya': 'lampu', 'kedip': 'kedip', 'warna': 'warna', 'merah': 'merah', 'gitu': 'gitu', 'deh': 'deh', 'ngotak': 'ngotak', 'ngatik': 'ngatik', 'kabel': 'kabel', 'sampe': 'sampe', 'skrng': 'skrng', 'masi': 'mas', 'gabisa': 'gabisa', 'baca': 'baca', 'langganan': 'langgan', 'telkom': 'telkom', 'susah': 'susah', 'bener': 'bener', 'mengalami': 'alami', 'error': 'error', 'browser': 'browser', 'berat': 'berat', 'sst': 'sst', 'kasih': 'kasih', 'gimana': 'gimana', 'mengatasi': 'atas', 'performa': 'performa', 'favoritmu': 'favorit', 'lancar': 'lancar', 'ngamuk': 'ngamuk', 'kalem': 'kalem', 'keun': 'keun', 'santai': 'santai', 'tanginas': 'tanginas', 'keneuh': 'keneuh', 'kela': 'kela', 'abi': 'abi', 'bari': 'bari', 'maca': 'maca', 'ayat': 'ayat', 'kursi': 'kursi', 'atuh': 'atuh', 'sok': 'sok', 'cekelan': 'cekel', 'tangan': 'tangan', 'iya ...
# ------------------------
# Pandas Apply:   0%|          | 0/1958 [00:03<?, ?it/s]
#                                                 content  \
# 0                    @mmarrierr @indihome min itu lemot
# 1     @newyorkdevotee @gerindra @nutrisheid min aku ...
# 2     dari sore masa gini terus si @indihome https:/...
# 3     @indihomejkt jawabannya adalah batavia \n\nyuk...
# 4     gada yg lbh monyet selain jaringan indihome pa...
# ...                                                 ...
# 1995  ya allah indihome kenapa sihhh aku mau ngerjai...
# 1996  sudah nonton trailer lightyear gengs?\n\nsekil...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998            keren @indihome https://t.co/dialk9et8i
# 1999        stres gegara indihome belom kepasang pasang
#
#                                          cleaning_tweet  \
# 0                                         min itu lemot
# 1     min aku juga mau gratis gak bayar sebulan bonu...
# 2                            dari sore masa gini terus
# 3     jawabannya adalah batavia yuk sobat jangan sam...
# 4        gada lbh monyet selain jaringan indihome pagi
# ...                                                 ...
# 1995   allah indihome kenapa sihhh aku mau ngerjain ...
# 1996  sudah nonton trailer lightyear gengs sekilas f...
# 1997  wifi indihome parah banget asli tagihan tetep ...
# 1998                                              keren
# 1999        stres gegara indihome belom kepasang pasang
#
#                                              tokenisasi  \
# 0                                     [min, itu, lemot]
# 1     [min, aku, juga, mau, gratis, gak, bayar, sebu...
# 2                     [dari, sore, masa, gini, terus, ]
# 3     [jawabannya, adalah, batavia, yuk, sobat, jang...
# 4     [gada, lbh, monyet, selain, jaringan, indihome...
# ...                                                 ...
# 1995  [, allah, indihome, kenapa, sihhh, aku, mau, n...
# 1996  [sudah, nonton, trailer, lightyear, gengs, sek...
# 1997  [wifi, indihome, parah, banget, asli, tagihan,...
# 1998                                            [keren]
# 1999  [stres, gegara, indihome, belom, kepasang, pas...
#
#                                                stopword  \
# 0                                          [min, lemot]
# 1     [min, gratis, bayar, sebulan, bonus, clay, mas...
# 2                                        [sore, gini, ]
# 3             [jawabannya, batavia, yuk, sobat, ikutan]
# 4       [gada, lbh, monyet, jaringan, indihome, pagi, ]
# ...                                                 ...
# 1995    [, allah, indihome, sihhh, ngerjain, laporan, ]
# 1996  [nonton, trailer, lightyear, gengs, sekilas, f...
# 1997  [wifi, indihome, parah, banget, asli, tagihan,...
# 1998                                            [keren]
# 1999  [stres, gegara, indihome, belom, kepasang, pas...
#
#                                                stemming
# 0                                            [min, lot]
# 1     [min, gratis, bayar, bulan, bonus, clay, maskn...
# 2                                         [sore, gin, ]
# 3                    [jawab, batavia, yuk, sobat, ikut]
# 4         [gada, lbh, monyet, jaring, indihome, pagi, ]
# ...                                                 ...
# 1995      [, allah, indihome, sihhh, ngerjain, lapor, ]
# 1996  [nonton, trailer, lightyear, gengs, kilas, fil...
# 1997  [wifi, indihome, parah, banget, asli, tagih, t...
# 1998                                            [keren]
# 1999     [stres, gegara, indihome, bom, pasang, pasang]
#
# [1958 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0                                            [min, lot]
# 1     [min, gratis, bayar, bulan, bonus, clay, maskn...
# 2                                         [sore, gin, ]
# 3                    [jawab, batavia, yuk, sobat, ikut]
# 4         [gada, lbh, monyet, jaring, indihome, pagi, ]
# ...                                                 ...
# 1995      [, allah, indihome, sihhh, ngerjain, lapor, ]
# 1996  [nonton, trailer, lightyear, gengs, kilas, fil...
# 1997  [wifi, indihome, parah, banget, asli, tagih, t...
# 1998                                            [keren]
# 1999     [stres, gegara, indihome, bom, pasang, pasang]
#
# [1958 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_10.xlsx')
