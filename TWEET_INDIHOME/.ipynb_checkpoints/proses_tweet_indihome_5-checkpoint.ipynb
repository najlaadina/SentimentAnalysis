# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     Pihak Telkom/@TelkomIndonesia sudah menggelar ...
# 1        Anjirlah ini spotify sama indihome knp bangsat
# 2     Di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @IndiHomeCare @IndiHome Wkwkwk d...
# 4     @EKCTR @ibnvakbar @IndiHome @IndiHomeCare Iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\nIya gr2 indihome tern...
# 1996  @IndiHomeCare selamat pagi, mohon bantuan meng...
# 1997  @Jimmy62640418 Hai Kak Jimmy, Hiro informasika...
# 1998  Kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire Hi Kak Ardy, Embun cek saat in...
#
# [2000 rows x 1 columns]

# %%
print('Dataset size:', df.shape)
print('Columns are:', df.columns)
# Out:
# Dataset size: (2000, 1)
# Columns are: Index(['content'], dtype='object')

# %%
df.content.duplicated().sum()
# Out:
# 5

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     Pihak Telkom/@TelkomIndonesia sudah menggelar ...
# 1        Anjirlah ini spotify sama indihome knp bangsat
# 2     Di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @IndiHomeCare @IndiHome Wkwkwk d...
# 4     @EKCTR @ibnvakbar @IndiHome @IndiHomeCare Iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\nIya gr2 indihome tern...
# 1996  @IndiHomeCare selamat pagi, mohon bantuan meng...
# 1997  @Jimmy62640418 Hai Kak Jimmy, Hiro informasika...
# 1998  Kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire Hi Kak Ardy, Embun cek saat in...
#
# [1991 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     pihak telkom/@telkomindonesia sudah menggelar ...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2     di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @indihomecare @indihome wkwkwk d...
# 4     @ekctr @ibnvakbar @indihome @indihomecare iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\niya gr2 indihome tern...
# 1996  @indihomecare selamat pagi, mohon bantuan meng...
# 1997  @jimmy62640418 hai kak jimmy, hiro informasika...
# 1998  kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire hi kak ardy, embun cek saat in...
#
# [1991 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     pihak telkom/@telkomindonesia sudah menggelar ...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2     di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @indihomecare @indihome wkwkwk d...
# 4     @ekctr @ibnvakbar @indihome @indihomecare iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\niya gr2 indihome tern...
# 1996  @indihomecare selamat pagi, mohon bantuan meng...
# 1997  @jimmy62640418 hai kak jimmy, hiro informasika...
# 1998  kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire hi kak ardy, embun cek saat in...
#
#                                          cleaning_tweet
# 0     pihak telkom sudah menggelar aksi peduli indih...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2      tempat sepuluh rebu bisa dapat bakso semangko...
# 3                       wkwkwk ghosting sama embun dari
# 4                       iyooo bangun tdr bambet ini euy
# ...                                                 ...
# 1995  uwaw thanks iya gr  indihome ternyata habis ga...
# 1996  selamat pagi mohon bantuan mengecek status ind...
# 1997  hai kak jimmy hiro informasikan jatuh tempo pe...
# 1998      kak untuk tagihan jatuh tempo tanggal berapa
# 1999   stormfire kak ardy embun cek saat ini dilokas...
#
# [1991 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     pihak telkom/@telkomindonesia sudah menggelar ...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2     di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @indihomecare @indihome wkwkwk d...
# 4     @ekctr @ibnvakbar @indihome @indihomecare iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\niya gr2 indihome tern...
# 1996  @indihomecare selamat pagi, mohon bantuan meng...
# 1997  @jimmy62640418 hai kak jimmy, hiro informasika...
# 1998  kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire hi kak ardy, embun cek saat in...
#
#                                          cleaning_tweet  \
# 0     pihak telkom sudah menggelar aksi peduli indih...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2      tempat sepuluh rebu bisa dapat bakso semangko...
# 3                       wkwkwk ghosting sama embun dari
# 4                       iyooo bangun tdr bambet ini euy
# ...                                                 ...
# 1995  uwaw thanks iya gr  indihome ternyata habis ga...
# 1996  selamat pagi mohon bantuan mengecek status ind...
# 1997  hai kak jimmy hiro informasikan jatuh tempo pe...
# 1998      kak untuk tagihan jatuh tempo tanggal berapa
# 1999   stormfire kak ardy embun cek saat ini dilokas...
#
#                                              tokenisasi
# 0     [pihak, telkom, sudah, menggelar, aksi, peduli...
# 1     [anjirlah, ini, spotify, sama, indihome, knp, ...
# 2     [, tempat, sepuluh, rebu, bisa, dapat, bakso, ...
# 3                 [wkwkwk, ghosting, sama, embun, dari]
# 4                [iyooo, bangun, tdr, bambet, ini, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, ternyata, ha...
# 1996  [selamat, pagi, mohon, bantuan, mengecek, stat...
# 1997  [hai, kak, jimmy, hiro, informasikan, jatuh, t...
# 1998  [kak, untuk, tagihan, jatuh, tempo, tanggal, b...
# 1999  [, stormfire, kak, ardy, embun, cek, saat, ini...
#
# [1991 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'nya'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(3000)
# Out:
#                                                 content  \
# 0     pihak telkom/@telkomindonesia sudah menggelar ...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2     di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @indihomecare @indihome wkwkwk d...
# 4     @ekctr @ibnvakbar @indihome @indihomecare iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\niya gr2 indihome tern...
# 1996  @indihomecare selamat pagi, mohon bantuan meng...
# 1997  @jimmy62640418 hai kak jimmy, hiro informasika...
# 1998  kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire hi kak ardy, embun cek saat in...
#
#                                          cleaning_tweet  \
# 0     pihak telkom sudah menggelar aksi peduli indih...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2      tempat sepuluh rebu bisa dapat bakso semangko...
# 3                       wkwkwk ghosting sama embun dari
# 4                       iyooo bangun tdr bambet ini euy
# ...                                                 ...
# 1995  uwaw thanks iya gr  indihome ternyata habis ga...
# 1996  selamat pagi mohon bantuan mengecek status ind...
# 1997  hai kak jimmy hiro informasikan jatuh tempo pe...
# 1998      kak untuk tagihan jatuh tempo tanggal berapa
# 1999   stormfire kak ardy embun cek saat ini dilokas...
#
#                                              tokenisasi  \
# 0     [pihak, telkom, sudah, menggelar, aksi, peduli...
# 1     [anjirlah, ini, spotify, sama, indihome, knp, ...
# 2     [, tempat, sepuluh, rebu, bisa, dapat, bakso, ...
# 3                 [wkwkwk, ghosting, sama, embun, dari]
# 4                [iyooo, bangun, tdr, bambet, ini, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, ternyata, ha...
# 1996  [selamat, pagi, mohon, bantuan, mengecek, stat...
# 1997  [hai, kak, jimmy, hiro, informasikan, jatuh, t...
# 1998  [kak, untuk, tagihan, jatuh, tempo, tanggal, b...
# 1999  [, stormfire, kak, ardy, embun, cek, saat, ini...
#
#                                                stopword
# 0     [telkom, menggelar, aksi, peduli, indihome, me...
# 1           [anjirlah, spotify, indihome, knp, bangsat]
# 2     [, sepuluh, rebu, bakso, semangkok, indihome, ...
# 3                             [wkwkwk, ghosting, embun]
# 4                     [iyooo, bangun, tdr, bambet, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, habis, ganti...
# 1996  [selamat, pagi, mohon, bantuan, mengecek, stat...
# 1997  [hai, kak, jimmy, hiro, informasikan, jatuh, t...
# 1998            [kak, tagihan, jatuh, tempo, tanggal, ]
# 1999  [, stormfire, kak, ardy, embun, cek, dilokasin...
#
# [1991 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3786
# ------------------------
# telkom : telkom
# menggelar : gelar
# aksi : aksi
# peduli : peduli
# indihome : indihome
# membangkitan : bangkit
# ekonomi : ekonomi
# dll : dll
# propinsi : propinsi
# ntt : ntt
# kemarin : kemarin
# diterjang : terjang
# badai : badai
# seroja : seroja
# anjirlah : anjir
# spotify : spotify
# knp : knp
# bangsat : bangsat
#  :
# sepuluh : puluh
# rebu : rebu
# bakso : bakso
# semangkok : semangkok
# lgsg : lgsg
# berlangganan : langgan
# wkwkwk : wkwkwk
# ghosting : ghosting
# embun : embun
# iyooo : iyooo
# bangun : bangun
# tdr : tdr
# bambet : bambet
# euy : euy
# tolong : tolong
# temen : temen
# sampe : sampe
# hape : hape
# android : android
# connect : connect
# jaringan : jaring
# error : error
# spotifynya : spotifynya
# hee : hee
# neh : neh
# dipanggil : panggil
# mohon : mohon
# maap : maap
# gamas : gamas
# krena : krena
# pnya : pnya
# ane : ane
# sinyal : sinyal
# paket : paket
# data : data
# tilkumsil : tilkumsil
# lemot : lot
# kemaren : kemaren
# anjing : anjing
# alah : alah
# screw : screw
# kak : kak
# ibnu : ibnu
# internetnya : internetnya
# silakan : sila
# informasikan : informasi
# nomor : nomor
# layanan : layan
# care : care
# datanya : data
# aman : aman
# dibantu : bantu
# cek : cek
# jean : jean
# nuk : nuk
# makasih : makasih
# fan : fan
# provider : provider
# hai : hai
# arabel : arabel
# terkait : kait
# kondisi : kondisi
# layanannya : layan
# bantu : bantu
# yuk : yuk
# internet : internet
# nama : nama
# pemilik : milik
# twitter : twitter
# terima : terima
# kasih : kasih
# windys : windys
# halo : halo
# berri : berri
# detail : detail
# kakak : kakak
# alami : alami
# akun : akun
# kayi : kayi
# banget : banget
# deh : deh
# portal : portal
# keluhan : keluh
# cepat : cepat
# pagi : pagi
# tulung : tulung
# iya : iya
# kerja : kerja
# plis : plis
# dirumah : rumah
# ngalamin : ngalamin
# down : down
# logo : logo
# myindihome : myindihome
# ikutan : ikut
# quiz : quiz
# rasi : rasi
# emosi : emosi
# riski : riski
# ifa : ifa
# diakses : akses
# dicoba : coba
# akses : akses
# blokir : blokir
# pakai : pakai
# vpn : vpn
# blok : blok
# pantesan : pantesan
# mslh : mslh
# emen : emen
# masri : masri
# kendalanya : kendala
# tunggu : tunggu
# laporan : lapor
# koneksi : koneksi
# telepon : telepon
# mati : mati
# putus : putus
# telp : telp
# perhatian : perhati
# pelanggan : langgan
# mengeluhkan : keluh
# diperhatikan : perhati
# diperbaiki : baik
# lapor : lapor
# kemana : mana
# problem : problem
# langsungdi : langsungdi
# tangani : tangan
# posisi : posisi
# balikpapan : balikpapan
# hallo : hallo
# sobat : sobat
# terkendala : kendala
# ponsel : ponsel
# gua : gua
# mah : mah
# ganti : ganti
# wifi : wifi
# laen : laen
# wifinya : wifinya
# laginya : lagi
# menghubungkan : hubung
# games : games
# pokok : pokok
# sosmed : sosmed
# koneksinya : koneksi
# masak : masak
# pembetulan : betul
# udah : udah
# kecewa : kecewa
# langganan : langgan
# halooo : halooo
# mbps : mbps
# izza : izza
# maaf : maaf
# ketidaknyamanannya : ketidaknyamanannya
# aktif : aktif
# via : via
# pengecekan : kece
# pudin : pudin
# finally : finally
# got : got
# their : their
# shit : shit
# together : together
# and : and
# now : now
# working : working
# would : would
# like : like
# thank : thank
# not : not
# only : only
# god : god
# but : but
# also : also
# jesus : jesus
# lerenono : lerenono
# jancok : jancok
# gini : gin
# udh : udh
# bae : bae
# hate : hate
# you : you
# srs : srs
# perihal : perihal
# maksimal : maksimal
# rionald : rionald
# sarankan : saran
# coba : coba
# lakukan : laku
# install : install
# ulang : ulang
# berkala : kala
# interaksi : interaksi
# hubungi : hubung
# semoga : moga
# malas : malas
# lihat : lihat
# tagihan : tagih
# kartu : kartu
# full : full
# nikmati : nikmat
# ikhlas : ikhlas
# bayar : bayar
# perbaikan : baik
# pulihnya : pulih
# juni : juni
# kerusakan : rusa
# april : april
# tagihannya : tagih
# sim : sim
# card : card
# sms : sms
# kadang : kadang
# erro : erro
# karir : karir
# cerah : cerah
# anak : anak
# masyarakat : masyarakat
# tagihannnya : tagihannnya
# dibalik : balik
# hilang : hilang
# sedih : sedih
# tanggal : tanggal
# mei : mei
# sekrang : sekrang
# akbar : akbar
# pabji : pabji
# anying : anying
# judulnya : judul
# ngemtot : ngemtot
# fork : fork
# too : too
# aaaaaah : aaaaaah
# lag : lag
# anjg : anjg
# samaa : samaa
# gabisa : gabisa
# muter : muter
# doang : doang
# dibalas : balas
# modem : modem
# bolak : bolak
# orang : orang
# tua : tua
# ngamuk : ngamuk
# pelayanan : layan
# berhentikan : henti
# dita : dita
# tindak : tindak
# lanjuti : lanjut
# berkenan : kenan
# mengalami : alami
# gangguan : ganggu
# lambat : lambat
# useless : useless
# caper : caper
# babi : babi
# tulisannya : tulis
# diarahkan : arah
# chanel : chanel
# connection : connection
# derogatory : derogatory
# just : just
# wanna : wanna
# inniter : inniter
# why : why
# cant : cant
# supportive : supportive
# fuckkkkkkksssss : fuckkkkkkksssss
# bener : bener
# fuxking : fuxking
# deaddddddd : deaddddddd
# survival : survival
# game : game
# useetv : useetv
# min : min
# disuruh : suruh
# beli : beli
# molatv : molatv
# kualitas : kualitas
# patut : patut
# diacungi : acung
# jempol : jempol
# biang : biang
# kerok : kerok
# paketan : paket
# lancar : lancar
# bantuannya : bantu
# bro : bro
# chaelch : chaelch
# link : link
# dongs : dongs
# bengek : bengek
# streaming : streaming
# nonton : nonton
# ucl : ucl
# access : access
# rmdhn : rmdhn
# bang : bang
# makannya : makan
# nyari : nyari
# streamingan : streamingan
# berhenti : henti
# kabel : kabel
# nder : nder
# chat : chat
# pending : pending
# gara : gara
# ngadat : ngadat
# cobain : cobain
# imma : imma
# continue : continue
# sleep : sleep
# keep : keep
# being : being
# shitty : shitty
# ngab : ngab
# taik : taik
# emg : emg
# won : won
# let : let
# watch : watch
# tommy : tommy
# pov : pov
# sad : sad
# already : already
# ended : ended
# career : career
# stop : stop
# taking : taking
# pixels : pixels
# away : away
# wilbannies : wilbannies
# peace : peace
# beresss : beresss
# dibenerin : dibenerin
# drama : drama
# kelar : kelar
# mudah : mudah
# kedepannya : depan
# rio : rio
# pastikan : pasti
# versi : versi
# terbaru : baru
# clear : clear
# cache : cache
# aplikasi : aplikasi
# michel : michel
# digampar : gampar
# kayak : kayak
# efem : efem
# wkwkw : wkwkw
# hahah : hahah
# glad : glad
# don : don
# use : use
# anymore : anymore
# anjingg : anjingg
# when : when
# wilburs : wilburs
# stream : stream
# its : its
# perfectly : perfectly
# fucking : fucking
# quick : quick
# are : are
# kenape : kenape
# berantem : antem
# gimana : gimana
# buka : buka
# anjay : anjay
# susah : susah
# bat : bat
# haram : haram
# taikkk : taikkk
# kenny : kenny
# vidio : vidio
# pengekan : kek
# tim : tim
# menunggu : tunggu
# prosesnya : proses
# menghubungi : hubung
# rekan : rekan
# mahes : mahes
# kooperatif : kooperatif
# njeng : njeng
# even : even
# fuck : fuck
# minn : minn
# ryan : ryan
# gue : gue
# mulu : mulu
# goblok : goblok
# sampah : sampah
# user : user
# kah : kah
# pass : pass
# dns : dns
# aneh : aneh
# kmrn : kmrn
# parah : parah
# will : will
# the : the
# death : death
# istg : istg
# bangggggs : bangggggs
# cape : cape
# tetangga : tetangga
# sctv : sctv
# nnton : nnton
# liga : liga
# champions : champions
# users : users
# make : make
# website : website
# bgd : bgd
# alhamdulilah : alhamdulilah
# jdi : jdi
# rely : rely
# fucken : fucken
# unreliable : unreliable
# bitschhh : bitschhh
# surprised : surprised
# really : really
# well : well
# rven : rven
# close : close
# router : router
# ngga : ngga
# nyiarin : nyiarin
# yes : yes
# lelet : lelet
# disaat : saat
# stayed : stayed
# until : until
# this : this
# hour : hour
# loading : loading
# streamm : streamm
# youuuu : youuuu
# more : more
# indigotohelll : indigotohelll
# yuni : yuni
# senang : senang
# mendengarnya : dengar
# apresiasinya : apresiasi
# mention : mention
# feed : feed
# lupa : lupa
# hastag : hastag
# amaaat : amaaat
# bola : bola
# kaga : kaga
# lled : lled
# grandma : grandma
# actually : actually
# youuuuuuuuu : youuuuuuuuu
# ngajak : ngajak
# ngelag : ngelag
# sialan : sial
# tlong : tlong
# bls : bls
# wilda : wilda
# tayangan : tayang
# channel : channel
# hak : hak
# siar : siar
# menyaksikan : saksi
# pertandingan : tanding
# sepak : sepak
# lengkap : lengkap
# add : add
# minipack : minipack
# indisport : indisport
# yulio : yulio
# lagging : lagging
# all : all
# resolution : resolution
# lucky : lucky
# day : day
# bestie : bestie
# indosat : indosat
# how : how
# live : live
# mingguan : minggu
# speednya : speednya
# kbps : kbps
# nyampe : nyampe
# youtube : youtube
# kuat : kuat
# kaco : kaco
# can : can
# way : way
# zen : zen
# audacity : audacity
# have : have
# ditunggu : tunggu
# konfirmasinya : konfirmasi
# lwt : lwt
# suka : suka
# beda : beda
# cempion : cempion
# bein : bein
# blaming : blaming
# everything : everything
# seharian : hari
# yup : yup
# peningkatan : tingkat
# sisi : sisi
# tpi : tpi
# anehnya : aneh
# apk : apk
# kena : kena
# pengaruhnya : pengaruh
# jaya : jaya
# nntn : nntn
# dsana : dsana
# had : had
# puol : puol
# hadehhh : hadehhh
# tolongggggg : tolongggggg
# kendala : kendala
# membuka : buka
# sambungan : sambung
# mobile : mobile
# menikmati : nikmat
# pengguna : guna
# music : music
# relate : relate
# pas : pas
# upload : upload
# wrapped : wrapped
# ohh : ohh
# gitu : gitu
# malem : malem
# want : want
# mcc : mcc
# decided : decided
# bad : bad
# mantap : mantap
# uda : uda
# ditonton : tonton
# menit : menit
# kick : kick
# off : off
# payah : payah
# smua : smua
# pls : pls
# goddamnit : goddamnit
# caca : caca
# stabil : stabil
# indihomecare : indihomecare
# obie : obie
# cocok : cocok
# karna : karna
# menyebalkan : sebal
# omg : omg
# putranto : putranto
# maintenance : maintenance
# stb : stb
# progress : progress
# update : update
# upayakan : upaya
# secepatnya : cepat
# normal : normal
# ansyah : ansyah
# silentmary : silentmary
# otw : otw
# ngeluh : ngeluh
# sehat : sehat
# jaringannya : jaring
# atiolo : atiolo
# aatii : aatii
# dibuka : buka
# uel : uel
# final : final
# lho : lho
# enak : enak
# mabar : mabar
# was : was
# meraaah : meraaah
# kuning : kuning
# merah : merah
# gws : gws
# membenahi : benah
# kwalitas : kwalitas
# mon : mon
# twitch : twitch
# napa : napa
# buffer : buffer
# burik : burik
# layarnya : layar
# vct : vct
# besok : besok
# grand : grand
# tenang : tenang
# melewati : lewat
# minggu : minggu
# indah : indah
# iyaaaa : iyaaaa
# lebaran : lebaran
# maafin : maafin
# kemusuhan : musuh
# yaa : yaa
# ama : ama
# elearning : elearning
# kampus : kampus
# seminggu : minggu
# gabisaa : gabisaa
# ngakses : ngakses
# lohhh : lohhh
# kejadian : jadi
# kali : kali
# enek : enek
# emang : emang
# ashu : ashu
# abigail : abigail
# yatna : yatna
# respon : respon
# informasi : informasi
# selanjunya : selanjunya
# melampirkan : lampir
# saint : saint
# proses : proses
# perbaikannya : baik
# ngucap : ngucap
# istighfar : istighfar
# komisaris : komisaris
# kenceng : kenceng
# bismillah : bismillah
# allah : allah
# sucks : sucks
# capture : capture
# pengaduannya : adu
# soni : soni
# siang : siang
# ampe : ampe
# skr : skr
# gift : gift
# sebel : sebel
# admin : admin
# layar : layar
# muncul : muncul
# launcher : launcher
# app : app
# has : has
# stopped : stopped
# factory : factory
# reset : reset
# password : password
# stuck : stuck
# login : login
# anjrit : anjrit
# gun : gun
# menjaga : jaga
# privasi : privasi
# fadhil : fadhil
# pelaporan : lapor
# siih : siih
# iyaa : iyaa
# diblok : blok
# rizky : rizky
# mengirimkan : kirim
# indri : indri
# gasuka : gasuka
# jam : jam
# segini : gin
# tri : tri
# malkon : malkon
# temon : ton
# nyoba : nyoba
# speed : speed
# test : test
# setara : tara
# ngerep : ngerep
# gegara : gegara
# malam : malam
# baca : baca
# knapa : knapa
# puter : puter
# maksa : maksa
# playstore : playstore
# untung : untung
# hadeh : hadeh
# anjinggg : anjinggg
# bgus : bgus
# oci : oci
# aduh : aduh
# cacat : cacat
# kgk : kgk
# becus : becus
# astagfirullah : astagfirullah
# gile : gile
# ngeleg : ngeleg
# uninstall : uninstall
# ttp : ttp
# ngefek : ngefek
# dengerinnya : dengerinnya
# soundcloud : soundcloud
# tolol : tolol
# valo : valo
# asuuuuu : asuuuuu
# ngen : ngen
# drakor : drakor
# mnc : mnc
# duh : duh
# kesel : kesel
# hey : hey
# micel : micel
# seputar : putar
# solusikan : solusi
# anne : anne
# lucu : lucu
# darimana : darimana
# etdah : etdah
# dimas : mas
# prihal : prihal
# public : public
# telkomsel : telkomsel
# bos : bos
# kekmana : kekmana
# beneran : beneran
# nge : nge
# block : block
# gmn : gmn
# rlly : rlly
# testing : testing
# jamnya : jam
# gembel : gembel
# tam : tam
# isu : isu
# jawabannya : jawab
# masuk : masuk
# akal : akal
# dipersulit : sulit
# firstmedia : firstmedia
# aing : aing
# gantiii : gantiii
# tasya : tasya
# faeru : faeru
# semalem : semalem
# bet : bet
# lemotnya : lot
# jkt : jkt
# kos : kos
# smartyoutube : smartyoutube
# ditendang : tendang
# anjae : anjae
# lgi : lgi
# sumpah : sumpah
# bejek : bejek
# aaaaagh : aaaaagh
# jalan : jalan
# videonya : video
# pixel : pixel
# layak : layak
# visual : visual
# ateez : ateez
# dikasih : kasih
# nyusahin : nyusahin
# butuh : butuh
# woi : woi
# daritadi : daritadi
# kuota : kuota
# pdhl : pdhl
# melaporkn : melaporkn
# aduuhhhh : aduuhhhh
# brp : brp
# anjinggggggg : anjinggggggg
# sprt : sprt
# kesalahn : kesalahn
# ato : ato
# gimna : gimna
# smsny : smsny
# tulisan : tulis
# invalid : invalid
# membutuhkan : butuh
# ktp : ktp
# ttd : ttd
# film : film
# sprti : sprti
# iseng : iseng
# tnyakan : tnyakan
# approve : approve
# pdahl : pdahl
# pernh : pernh
# upgrade : upgrade
# makasiii : makasiii
# download : download
# nihh : nihh
# menelepon : telepon
# melaporkan : lapor
# dijalankan : jalan
# membuang : buang
# uang : uang
# minimal : minimal
# terbuang : buang
# kasian : kasi
# kejaman : kejam
# batu : batu
# msh : msh
# lembek : lembek
# jlas : jlas
# oala : oala
# keknya : kek
# teknisi : teknisi
# dijanjikan : janji
# diselesaikan : selesai
# sinyalnya : sinyal
# ampas : ampas
# memek : memek
# dipake : dipake
# eek : eek
# berulah : ulah
# muluu : muluu
# astaga : astaga
# tdi : tdi
# knpaa : knpaa
# sabar : sabar
# selesai : selesai
# bermasalah : masalah
# jumat : jumat
# fikrie : fikrie
# progres : progres
# celio : celio
# gembok : gembok
# ngequote : ngequote
# dimention : dimention
# joro : joro
# laporkan : lapor
# tiket : tiket
# in : in
# estimasi : estimasi
# jadwalkan : jadwal
# hello : hello
# produk : produk
# akur : akur
# nga : nga
# kawan : kawan
# sorry : sorry
# bodoh : bodoh
# league : league
# konfirmasi : konfirmasi
# foto : foto
# gadengerin : gadengerin
# lagu : lagu
# huhuhuhuhu : huhuhuhuhu
# ketawa : ketawa
# kekekekekke : kekekekekke
# udaaaah : udaaaah
# dengerin : dengerin
# premium : premium
# jahat : jahat
# mahasiswa : mahasiswa
# ngetik : ngetik
# gunanya : guna
# playlist : playlist
# balas : balas
# nyebelin : nyebelin
# hdh : hdh
# indih : indih
# me : me
# masi : mas
# jaman : jaman
# wkw : wkw
# smartphone : smartphone
# sebentat : sebentat
# kontoool : kontoool
# emon : emon
# pengaduan : adu
# kmrin : kmrin
# sinting : sinting
# hilmy : hilmy
# fix : fix
# been : been
# days : days
# erorr : erorr
# turn : turn
# cellular : cellular
# bcs : bcs
# play : play
# since : since
# yesterdsy : yesterdsy
# smh : smh
# rafi : rafi
# rifqi : rifqi
# agil : agil
# infomasikan : infomasikan
# lahh : lahh
# sore : sore
# pke : pke
# bisaa : bisaa
# laptop : laptop
# sieeh : sieeh
# wkwkwkwk : wkwkwkwk
# angeel : angeel
# angeell : angeell
# mending : mending
# bedua : bedua
# ketemuan : ketemu
# obrolin : obrolin
# warga : warga
# skrg : skrg
# ara : ara
# muk : muk
# notis : not
# maen : maen
# valorant : valorant
# alfaraby : alfaraby
# silahkan : silah
# aktifnya : aktif
# kirimkan : kirim
# aeguing : aeguing
# with : with
# your : your
# damn : damn
# technicians : technicians
# for : for
# whole : whole
# avail : avail
# done : done
# yall : yall
# guys : guys
# called : called
# helpful : helpful
# attitude : attitude
# there : there
# said : said
# hope : hope
# people : people
# get : get
# pleasant : pleasant
# dinda : dinda
# dibaca : baca
# tlg : tlg
# sekampung : kampung
# gaada : gaada
# ngalahin : ngalahin
# ujan : ujan
# sir : sir
# inconvenience : inconvenience
# please : please
# inform : inform
# number : number
# name : name
# could : could
# check : check
# wait : wait
# further : further
# confirmation : confirmation
# flash : flash
# drimana : drimana
# tmap : tmap
# blom : blom
# anjggg : anjggg
# taiiii : taiiii
# kenapaa : kenapaa
# nenden : nenden
# ijal : ijal
# anjeeeeeeeeeng : anjeeeeeeeeeng
# dalem : dalem
# dungeon : dungeon
# givtario : givtario
# alamat : alamat
# arn : arn
# rekam : rekam
# jejaknyo : jejaknyo
# yan : yan
# miss : miss
# asap : asap
# gedung : gedung
# bagus : bagus
# disana : sana
# ajg : ajg
# pusat : pusat
# pusatnye : pusatnye
# woii : woii
# ngisinggggg : ngisinggggg
# iki : iki
# mestine : mestine
# abdeeslank : abdeeslank
# effect : effect
# hadeuh : hadeuh
# biasaan : biasa
# restart : restart
# disambung : sambung
# giliran : gilir
# nall : nall
# before : before
# head : head
# night : night
# lemme : lemme
# judt : judt
# vent : vent
# out : out
# one : one
# personal : personal
# rant : rant
# ruining : ruining
# adding : adding
# salt : salt
# special : special
# year : year
# sincerely : sincerely
# forced : forced
# bossss : bossss
# josi : josi
# boby : boby
# load : load
# halaman : halaman
# build : build
# gradle : gradle
# bkn : bkn
# egk : egk
# liat : liat
# walah : walah
# tuman : tuman
# ishhhhhhhh : ishhhhhhhh
# makasi : makas
# yaaa : yaaa
# lagg : lagg
# zzzz : zzzz
# dukung : dukung
# bangkit : bangkit
# gelar : gelar
# wei : wei
# nape : nape
# salah : salah
# never : never
# ending : ending
# saga : saga
# rara : rara
# bickering : bickering
# haloo : haloo
# dongg : dongg
# adhan : adhan
# rumah : rumah
# nasibku : nasib
# jelek : jelek
# feetrya : feetrya
# tira : tira
# tindaklanjut : tindaklanjut
# hapus : hapus
# postingan : postingan
# jago : jago
# gelud : gelud
# koi : koi
# selamat : selamat
# gejala : gejala
# mlu : mlu
# sendernyaa : sendernyaa
# mksii : mksii
# banyakkk : banyakkk
# dibantuin : dibantuin
# perkara : perkara
# spotifyy : spotifyy
# fast : fast
# ganyangka : ganyangka
# kirain : kirain
# direspon : direspon
# bsk : bsk
# nambah : nambah
# kerjaan : kerja
# adminn : adminn
# tyasss : tyasss
# nani : nan
# mencoba : coba
# spoti : spoti
# chelsea : chelsea
# asyem : asyem
# qouta : qouta
# ready : ready
# oooooo : oooooo
# heem : heem
# lupaaak : lupaaak
# dormnya : dormnya
# saranin : saranin
# dorm : dorm
# capek : capek
# haechan : haechan
# vlive : vlive
# nyendat : nyendat
# yaelah : yaelah
# loss : loss
# lampu : lampu
# fatih : fatih
# husilmi : husilmi
# desa : desa
# cot : cot
# keutapang : keutapang
# kecamatan : camat
# jeumpa : jeumpa
# kabupaten : kabupaten
# bireuen : bireuen
# aceh : aceh
# stress : stress
# nangis : nang
# hampa : hampa
# hidupppp : hidupppp
# hubungan : hubung
# gakjelas : gakjelas
# detik : detik
# iso : iso
# ora : ora
# bully : bully
# monyet : monyet
# thanks : thanks
# keputus : putus
# huhuhuhu : huhuhuhu
# episode : episode
# giant : giant
# leap : leap
# targeted : targeted
# teaser : teaser
# fight : fight
# feeling : feeling
# flop : flop
# biznet : biznet
# tong : tong
# endorse : endorse
# kejadiannya : jadi
# serius : serius
# woy : woy
# benerin : benerin
# ayodongggggg : ayodongggggg
# hidup : hidup
# trying : trying
# listen : listen
# mean : mean
# huh : huh
# mmg : mmg
# betty : betty
# gilasih : gilasih
# viu : viu
# nax : nax
# lol : lol
# ribut : ribut
# ayo : ayo
# teruss : teruss
# sekedar : dar
# nunggu : nunggu
# smpe : smpe
# prsaan : prsaan
# twt : twt
# pay : pay
# last : last
# pemerintah : perintah
# kwwkwkw : kwwkwkw
# dih : dih
# ngaco : ngaco
# noice : noice
# gbs : gbs
# rakyat : rakyat
# indihoe : indihoe
# btw : btw
# veyy : veyy
# net : net
# kopong : kopong
# canda : canda
# adek : adek
# jwi : jwi
# abon : abon
# usagi : usagi
# tekecuali : tekecuali
# indihim : indihim
# aktifkan : aktif
# champion : champion
# tks : tks
# ketemu : ketemu
# makhluk : makhluk
# halus : halus
# ketimbang : ketimbang
# org : org
# kmren : kmren
# denganmu : dengan
# macet : macet
# mutar : mutar
# lagunya : lagu
# nyambung : nyambung
# spo : spo
# supportnya : supportnya
# support : support
# trus : trus
# tidaa : tidaa
# jaringanmu : jaring
# cemana : cemana
# heni : heni
# rto : rto
# solusinya : solusi
# musuhan : musuh
# diablos : diablos
# much : much
# sjw : sjw
# roll : roll
# they : they
# great : great
# ppl : ppl
# sucky : sucky
# setel : setel
# kereen : kereen
# kesigapan : sigap
# petugas : tugas
# apresiasi : apresiasi
# pembenahan : benah
# primetime : primetime
# alesan : alesan
# traffic : traffic
# naek : naek
# turun : turun
# niat : niat
# gada : gada
# diusahain : diusahain
# goblog : goblog
# langsung : langsung
# anjiir : anjiir
# unistall : unistall
# pocong : pocong
# jemuran : jemur
# kain : kain
# putih : putih
# weh : weh
# pantes : pantes
# irfan : irfan
# army : army
# trs : trs
# ajaaaaaaaaaaaaa : ajaaaaaaaaaaaaa
# cepet : cepet
# monmaap : monmaap
# nanyain : nanyain
# reply : reply
# bwrtengkar : bwrtengkar
# bangga : bangga
# armydull : armydull
# chingudull : chingudull
# chaca : chaca
# nctzh : nctzh
# yok : yok
# ketawain : ketawain
# kelakuan : laku
# kania : kania
# yatuhan : yatuhan
# samsek : samsek
# bisaaa : bisaaa
# matiin : matiin
# lgsng : lgsng
# menitan : menit
# aktifin : aktifin
# habistu : habistu
# rusuh : rusuh
# rese : rese
# notice : notice
# gapake : gapake
# grgr : grgr
# perbaiki : baik
# konek : konek
# detailnya : detail
# konsumen : konsumen
# bertambah : tambah
# juta : juta
# main : main
# kesabaran : sabar
# cinta : cinta
# kurnia : kurnia
# sononya : sono
# ramdan : ramdan
# segmentasi : segmentasi
# enterprise : enterprise
# ykann : ykann
# manja : manja
# trnyt : trnyt
# dasar : dasar
# indipret : indipret
# yaaaaah : yaaaaah
# yauda : yauda
# wkwkwkw : wkwkwkw
# bantuin : bantuin
# gratis : gratis
# becanda : becanda
# rudett : rudett
# nggak : nggak
# oke : oke
# punten : punten
# melemot : lot
# pdhal : pdhal
# mesti : mesti
# diapain : diapain
# indiehome : indiehome
# hazzzzz : hazzzzz
# networknya : networknya
# trouble : trouble
# weeeey : weeeey
# kebangetan : banget
# ruwet : ruwet
# angel : angel
# tuturanmu : tutur
# hmm : hmm
# ngawur : ngawur
# thx : thx
# yulia : yulia
# penanganannya : tangan
# gege : gege
# arggghhh : arggghhh
# jgan : jgan
# nilep : nilep
# meiiii : meiiii
# blm : blm
# anjrtttt : anjrtttt
# kenapaaa : kenapaaa
# lagii : lagi
# ditelkom : ditelkom
# usaha : usaha
# mknya : mknya
# arya : arya
# pindah : pindah
# inalum : inalum
# nasabah : nasabah
# unt : unt
# bidang : bidang
# apapun : apa
# contoh : contoh
# digital : digital
# dijual : jual
# tudak : tudak
# mas : mas
# mba : mba
# blgnya : blgnya
# mempersulit : sulit
# sejujurnya : jujur
# cuman : cuman
# doangg : doangg
# makanan : makan
# sehari : hari
# duhh : duhh
# daerah : daerah
# kuningan : kuningan
# jancuk : jancuk
# betulinnya : betulinnya
# bot : bot
# nanya : nanya
# selular : selular
# responnya : responnya
# hrs : hrs
# pulsa : pulsa
# eleanor : eleanor
# plss : plss
# diputer : puter
# dimatiin : dimatiin
# sebenernya : sebenernya
# sahabat : sahabat
# oiya : oiya
# sempet : sempet
# telfon : telfon
# problemnya : problem
# moga : moga
# coacoac : coacoac
# yuhuuuuu : yuhuuuuu
# membantu : bantu
# salam : salam
# hangat : hangat
# keluarga : keluarga
# jaga : jaga
# kesehatan : sehat
# gangerti : gangerti
# kayanya : kaya
# menganggu : menganggu
# diputar : putar
# mngalami : mngalami
# smpai : smpai
# msih : msih
# bsa : bsa
# ketmau : ketmau
# clash : clash
# yaallah : yaallah
# buruan : buru
# keseruan : seru
# promo : promo
# haters : haters
# merjuangin : merjuangin
# premku : premku
# namanya : nama
# setujuuu : setujuuu
# buddy : buddy
# sure : sure
# updated : updated
# first : first
# then : then
# try : try
# again : again
# still : still
# changes : changes
# telephone : telephone
# that : that
# help : help
# handle : handle
# bima : bima
# dimen : dimen
# konten : konten
# pembaruan : baru
# sistem : sistem
# penanganan : tangan
# diupayakan : upaya
# yaampun : yaampun
# bibi : bibi
# kuganggu : ganggu
# semangat : semangat
# kerjanya : kerja
# bapuk : bapuk
# brengsek : brengsek
# awokawok : awokawok
# nitnitnitnit : nitnitnitnit
# brgsk : brgsk
# ngegame : ngegame
# mcd : mcd
# aaaaaa : aaaaaa
# mood : mood
# terbang : terbang
# tower : tower
# knf : knf
# peka : peka
# saking : saking
# pekanya : peka
# nampakin : nampakin
# prem : prem
# tar : tar
# sia : sia
# hujan : hujan
# kacrut : kacrut
# muhasabah : muhasabah
# ujian : uji
# kesal : kesal
# rutin : rutin
# semenjak : semenjak
# musim : musim
# smp : smp
# rewel : rewel
# oiy : oiy
# kebuka : buka
# musiknya : musik
# led : led
# merahnya : merah
# cmonnn : cmonnn
# seriously : seriously
# explain : explain
# yee : yee
# karatan : karat
# dicek : cek
# gasih : gasih
# deddy : deddy
# tersolusikan : solusi
# ceceng : ceceng
# kayaknya : kayak
# tengkar : tengkar
# keluhannya : keluh
# suasana : suasana
# pandemi : pandemi
# terpaksa : paksa
# ndak : ndak
# mengikuti : ikut
# kegiatan : giat
# majlisan : majlisan
# striming : striming
# terimakasih : terimakasih
# koneksimu : koneksi
# vincenzo : vincenzo
# sadar : sadar
# bentuknya : bentuk
# diriku : diri
# pengen : ken
# song : song
# joong : joong
# seh : seh
# otakku : otak
# gaikutan : gaikutan
# lemooott : lemooott
# mbah : mbah
# sdg : sdg
# memperjuangkan : juang
# ntar : ntar
# smart : smart
# rose : rose
# dialami : alami
# wintersugar : wintersugar
# eja : eja
# gils : gils
# najong : najong
# mahal : mahal
# las : las
# andluna : andluna
# berkendala : kendala
# iyakan : iya
# kenapasih : kenapasih
# hah : hah
# setan : setan
# kek : kek
# temenku : temenku
# dit : dit
# indi : indi
# wkwkwkk : wkwkwkk
# syafi : syafi
# ngandelin : ngandelin
# massal : massal
# ketinggalan : tinggal
# serbu : serbu
# seru : seru
# ribu : ribu
# indibox : indibox
# mengingatkanku : ingat
# bwl : bwl
# watdehel : watdehel
# segitu : segitu
# com : com
# gerangan : gerangan
# tk : tk
# nggo : nggo
# ted : ted
# nggonku : nggonku
# raiso : raiso
# ngecek : ngecek
# kolom : kolom
# search : search
# akeh : akeh
# sing : sing
# protes : protes
# soale : soale
# ayokkk : ayokkk
# doesn : doesn
# work : work
# connected : connected
# wasting : wasting
# money : money
# beg : beg
# heuuuu : heuuuu
# duanya : dua
# malming : malming
# yak : yak
# virtual : virtual
# pacarku : pacar
# signalnya : signalnya
# mendukung : dukung
# dikondisikan : kondisi
# zoom : zoom
# benerrrr : benerrrr
# bangttttt : bangttttt
# spotifyku : spotifyku
# antis : antis
# bts : bts
# sengaja : sengaja
# nganyeli : nganyeli
# gar : gar
# adminnya : adminnya
# elah : elah
# barusan : barusan
# primer : primer
# bantunya : bantu
# bangke : bangke
# laporannya : lapor
# kelarin : kelarin
# salahnya : salah
# tindaklanjuti : tindaklanjuti
# beres : beres
# nak : nak
# young : young
# dipancing : pancing
# dibalikin : dibalikin
# gatau : gatau
# eror : eror
# merekanya : mereka
# belajar : ajar
# dip : dip
# gasemua : gasemua
# alhamdulillah : alhamdulillah
# teman : teman
# rame : rame
# dipasangi : pasang
# pelangan : pelang
# ngopi : ngopi
# wiffi : wiffi
# hellooww : hellooww
# mbok : mbok
# olehi : oleh
# sinau : sinau
# lek : lek
# gaoleh : gaoleh
# gpp : gpp
# turu : turu
# anjirr : anjirr
# diacak : acak
# dihpku : dihpku
# mengakses : akses
# web : web
# sumpaaa : sumpaaa
# denger : denger
# weeeeh : weeeeh
# yusuf : yusuf
# kerahasiaan : rahasia
# teeyne : teeyne
# follow : follow
# yailaaaahhhh : yailaaaahhhh
# giniin : giniin
# redup : redup
# telkommmm : telkommmm
# heyy : heyy
# diskon : diskon
# iyahhh : iyahhh
# sata : sata
# brengjekkk : brengjekkk
# patience : patience
# ngeselin : ngeselin
# jeleknya : jelek
# bagusnya : bagus
# punyaku : punya
# tempatku : tempat
# jarang : jarang
# kece : kece
# korban : korban
# kyk : kyk
# goa : goa
# meng : meng
# disebabkan : sebab
# server : server
# sesuai : sesuai
# registrasi : registrasi
# firda : firda
# deddoy : deddoy
# memiliki : milik
# fadel : fadel
# sidik : sidik
# biaya : biaya
# gaess : gaess
# jls : jls
# lets : lets
# diuseetv : diuseetv
# ray : ray
# services : services
# quality : quality
# currently : currently
# improved : improved
# solve : solve
# immidiately : immidiately
# interaction : interaction
# call : call
# jaminan : jamin
# pemasangan : pasang
# tersambung : sambung
# wifiid : wifiid
# kampret : kampret
# sug : sug
# weee : weee
# jngan : jngan
# jakk : jakk
# wkwkkw : wkwkkw
# seliweran : seliwer
# timeline : timeline
# byk : byk
# komplen : komplen
# cari : cari
# twitnya : twitnya
# nyet : nyet
# prime : prime
# time : time
# abis : abis
# menghabiskan : habis
# weekend : weekend
# koentji : koentji
# menghilangkan : hilang
# jenuh : jenuh
# bosan : bosan
# suntuk : suntuk
# segudang : gudang
# fitur : fitur
# menarik : tarik
# satunya : satu
# serbuuu : serbuuu
# docfiq : docfiq
# uefa : uefa
# euro : euro
# mola : mola
# ditayangkan : tayang
# betterfangs : betterfangs
# iyo : iyo
# cuy : cuy
# tuku : tuku
# lak : lak
# onok : onok
# apasiiii : apasiiii
# ditotok : totok
# mikir : mikir
# positive : positive
# senen : senen
# tarif : tarif
# selalunada : selalunada
# kejutan : kejut
# wes : wes
# rek : rek
# waras : waras
# kenapasihhhhhhh : kenapasihhhhhhh
# syahid : syahid
# adekku : adekku
# abdi : abdi
# slank : slank
# diangkat : angkat
# tekhinisi : tekhinisi
# jambula : jambula
# odp : odp
# taun : taun
# daftar : daftar
# penuh : penuh
# melulu : melulu
# ajah : ajah
# astaghfirulloh : astaghfirulloh
# seumur : umur
# pasang : pasang
# anyone : anyone
# open : open
# mine : mine
# budiman : budiman
# berlaku : laku
# pha : pha
# menayangkan : tayang
# partai : partai
# marah : marah
# okedeh : okedeh
# dlu : dlu
# novi : novi
# tutup : tutup
# direspons : respons
# marahan : marah
# ngapa : ngapa
# kagak : kagak
# pokemon : pokemon
# ngeblok : ngeblok
# folk : folk
# senja : senja
# kopi : kopi
# hitam : hitam
# pahit : pahit
# gila : gila
# aaakkhh : aaakkhh
# direspom : direspom
# infonya : info
# reywoo : reywoo
# info : info
# updatenya : updatenya
# gedek : gedek
# dituduh : tuduh
# afk : afk
# banned : banned
# tanyakn : tanyakn
# anggota : anggota
# dilapangan : lapang
# sibuk : sibuk
# jualan : jual
# penyedia : sedia
# swasta : swasta
# ngerjain : ngerjain
# event : event
# ketik : ketik
# mengbabi : mengbabi
# musuan : musuan
# senasib : nasib
# nyaa : nyaa
# gr : gr
# francis : francis
# dipersilahkan : silah
# kiw : kiw
# farhan : farhan
# saldo : saldo
# dompet : dompet
# dialihkan : alih
# pembayaran : bayar
# pembelian : beli
# cpk : cpk
# ahh : ahh
# yoyo : yoyo
# langkah : langkah
# patch : patch
# cord : cord
# ont : ont
# terpasang : pasang
# kencang : kencang
# berwarna : warna
# nyantet : nyantet
# bjir : bjir
# thankyouuu : thankyouuu
# asik : asik
# seruan : seru
# ngambek : ngambek
# malmingan : malmingan
# jempolen : jempolen
# kontol : kontol
# kebiri : kebiri
# aje : aje
# rasanye : rasanye
# lemod : lemod
# pemain : main
# gitar : gitar
# apis : apis
# vdiodotcom : vdiodotcom
# seluler : seluler
# moots : moots
# dpt : dpt
# biasaya : biasaya
# rbu : rbu
# naufal : naufal
# suhu : suhu
# terpantau : pantau
# mengistirahatkan : istirahat
# appmus : appmus
# barengan : bareng
# baikan : baik
# jmbt : jmbt
# comment : comment
# rph : rph
# dikunci : kunci
# akunnya : akun
# direply : direply
# indigey : indigey
# komentar : komentar
# saran : saran
# temukan : temu
# pengalaman : alam
# terbaik : baik
# gamood : gamood
# encore : encore
# capeeeeeee : capeeeeeee
# dehhhh : dehhhh
# urusan : urus
# irene : irene
# know : know
# aplikasinya : aplikasi
# bertahun : tahun
# setia : setia
# wtf : wtf
# jeez : jeez
# dipindahkannya : pindah
# pemutusan : putus
# mengajak : ajak
# warganet : warganet
# memposting : memposting
# media : media
# sosial : sosial
# berdasarkan : dasar
# unduhan : unduh
# template : template
# frame : frame
# donasi : donasi
# dikonversi : konversi
# bentuk : bentuk
# rupiah : rupiah
# wth : wth
# komplek : komplek
# kaa : kaa
# warna : warna
# berubah : ubah
# bantuan : bantu
# komplain : komplain
# ditanggepin : ditanggepin
# gab : gab
# bosok : bosok
# berak : berak
# fakkkk : fakkkk
# rugi : rugi
# freya : freya
# panduan : pandu
# bring : bring
# back : back
# kaya : kaya
# koordinasikan : koordinasi
# dngan : dngan
# harga : harga
# pon : pon
# nyala : nyala
# kedap : kedap
# kedip : kedip
# dipakai : pakai
# tgl : tgl
# samarinda : samarinda
# ngarepnya : ngarepnya
# murahin : murahin
# gofood : gofood
# suruh : suruh
# isp : isp
# klasik : klasik
# lemooot : lemooot
# jatimbalinusra : jatimbalinusra
# keren : keren
# santripreneur : santripreneur
# business : business
# idea : idea
# competition : competition
# diikuti : ikut
# santri : santri
# santriwati : santriwati
# wilayah : wilayah
# jawa : jawa
# timur : timur
# bali : bal
# nusa : nusa
# tenggara : tenggara
# pemenang : menang
# hadiah : hadiah
# puluhan : puluh
# luaaamaaaaa : luaaamaaaaa
# ririn : ririn
# wujudkan : wujud
# kemudahan : mudah
# stay : stay
# safe : safe
# healthy : healthy
# rizara : rizara
# gan : gan
# terkendali : kendali
# engga : engga
# kasusnya : kasus
# ngeplay : ngeplay
# dipindahkan : pindah
# nisa : nisa
# jomblo : jomblo
# perfect : perfect
# ruma : ruma
# anjrlah : anjrlah
# ngentot : ngentot
# sii : sii
# ink : ink
# iqbalwahyuda : iqbalwahyuda
# hebat : hebat
# tsb : tsb
# response : response
# tulis : tulis
# report : report
# dibales : dibales
# dimobil : mobil
# kabarnya : kabar
# betulan : betul
# ngak : ngak
# duduk : duduk
# manis : manis
# olnly : olnly
# chaerandi : chaerandi
# nyaman : nyaman
# gus : gus
# ditelponin : ditelponin
# dri : dri
# hiks : hiks
# diblock : diblock
# sainganya : sainganya
# huhu : huhu
# siii : siii
# cerita : cerita
# gabut : gabut
# lurrr : lurrr
# nemui : nemui
# murah : murah
# nomernya : nomernya
# sukses : sukses
# tangkep : tangkep
# bocah : bocah
# bun : bun
# strimingnya : strimingnya
# harian : hari
# menyarankan : saran
# investigasi : investigasi
# trims : trims
# indohome : indohome
# berfungsi : fungsi
# pasar : pasar
# kenspa : kenspa
# kesediaannya : sedia
# disarankan : saran
# putusin : putusin
# kunjungi : kunjung
# bentar : bentar
# pokoknya : pokok
# istilah : istilah
# kuata : kuata
# habis : habis
# eifi : eifi
# super : super
# amanlah : aman
# dirasa : rasa
# refresh : refresh
# byarpet : byarpet
# balikin : balikin
# imah : imah
# hahaha : hahaha
# anti : anti
# cempyen : cempyen
# klub : klub
# pemakai : pakai
# kabar : kabar
# dlm : dlm
# molin : molin
# dmnya : dmnya
# heran : heran
# konser : konser
# berkibar : kibar
# bendera : bendera
# benci : benci
# fup : fup
# nangissssss : nangissssss
# ketertarikannya : tari
# diinformasikan : informasi
# kota : kota
# kelurahan : lurah
# pengecekannya : kece
# rzk : rzk
# youre : youre
# miin : miin
# dipakeee : dipakeee
# kronologis : kronologis
# penutupan : tutup
# diproses : proses
# perangkat : perangkat
# satupun : satu
# indihomeny : indihomeny
# zzz : zzz
# bagusprstyoo : bagusprstyoo
# bayu : bayu
# knowing : knowing
# brossnya : brossnya
# real : real
# fixed : fixed
# soon : soon
# gbisa : gbisa
# omongin : omongin
# siapatau : siapatau
# yakan : yakan
# pornhub : pornhub
# notif : notif
# gmail : gmail
# gajelas : gajelas
# fess : fess
# anjim : anjim
# signal : signal
# melendung : lendung
# tahan : tahan
# kayu : kayu
# awut : awut
# apalgi : apalgi
# mengganggu : ganggu
# rmh : rmh
# haduuu : haduuu
# kebiasaan : biasa
# rofied : rofied
# terhormat : hormat
# zie : zie
# astri : astri
# leyeh : leyeh
# bete : bete
# bonceng : bonceng
# genderuwo : genderuwo
# albino : albino
# knpsi : knpsi
# gjls : gjls
# sesuaikan : sesuai
# terdaftar : daftar
# kebanyakan : banyak
# plssssssss : plssssssss
# crita : crita
# jaringanny : jaringanny
# jeleekkk : jeleekkk
# bgttt : bgttt
# faak : faak
# bubidaya : bubidaya
# lopster : lopster
# air : air
# tawar : tawar
# putusnya : putus
# brgsek : brgsek
# ngancurin : ngancurin
# fungsi : fungsi
# top : top
# plat : plat
# kenapasik : kenapasik
# contact : contact
# center : center
# resminya : resmi
# spotipai : spotipai
# gelut : gelut
# ajaaaaa : ajaaaaa
# wew : wew
# ngeblokir : ngeblokir
# pemeliharaannya : pelihara
# dapet : dapet
# pemberitahuan : pemberitahuan
# whatsapp : whatsapp
# mantep : mantep
# qqq : qqq
# ita : ita
# mencobanya : coba
# ditangani : tangan
# noah : noah
# rencananya : rencana
# diberhentikan : henti
# situs : situs
# risheee : risheee
# koneksikan : koneksi
# ceng : ceng
# naxt : naxt
# panggil : panggil
# rumaaah : rumaaah
# genre : genre
# favoritmu : favorit
# store : store
# google : google
# dapatkan : dapat
# spesial : spesial
# after : after
# almost : almost
# streamed : streamed
# indihomenya : indihomenya
# perumahan : rumah
# pondok : pondok
# bintaro : bintaro
# sektor : sektor
# tampilannya : tampil
# aslian : asli
# locked : locked
# sakit : sakit
# hati : hati
# fio : fio
# bbrp : bbrp
# competible : competible
# apple : apple
# bisaaaaa : bisaaaaa
# absolutely : absolutely
# brutal : brutal
# handled : handled
# postpone : postpone
# spooky : spooky
# talks : talks
# from : from
# schedule : schedule
# due : due
# reasons : reasons
# didnt : didnt
# prep : prep
# anything : anything
# celebrate : celebrate
# own : own
# birthday : birthday
# man : man
# wish : wish
# someone : someone
# surprise : surprise
# party : party
# ganjar : ganjar
# reconnect : reconnect
# dahuu : dahuu
# perubahan : ubah
# ulah : ulah
# rehat : rehat
# hhh : hhh
# dhasty : dhasty
# sertakan : serta
# wahyu : wahyu
# duffy : duffy
# sentral : sentral
# slebew : slebew
# ono : ono
# opo : opo
# taraje : taraje
# gabisanya : gabisanya
# nyadar : nyadar
# menariknya : tarik
# ihh : ihh
# otak : otak
# kau : kau
# mirsa : mirsa
# cus : cus
# www : www
# yasud : yasud
# ngaku : ngaku
# case : case
# closed : closed
# profider : profider
# berkali : kali
# tetep : tetep
# tolonglah : tolong
# bwosss : bwosss
# whose : whose
# fault : fault
# end : end
# indonesia : indonesia
# paying : paying
# blank : blank
# screen : screen
# waaaah : waaaah
# asiiik : asiiik
# umpung : umpung
# inii : ini
# makan : makan
# gais : gais
# fehmi : fehmi
# surya : surya
# resmi : resmi
# bersangkutan : sangkut
# ngasih : ngasih
# jokowi : jokowi
# wibawa : wibawa
# negara : negara
# direktur : direktur
# misi : misi
# burung : burung
# gendatz : gendatz
# perpaduan : padu
# trimakasih : trimakasih
# what : what
# hell : hell
# asyikk : asyikk
# nihhh : nihhh
# elu : elu
# dajjal : dajjal
# diana : ana
# dach : dach
# telpon : telpon
# dachlach : dachlach
# mereun : mereun
# bebs : bebs
# haloooo : haloooo
# acara : acara
# kesulitan : sulit
# opsi : opsi
# speedy : speedy
# home : home
# gig : gig
# tersedia : sedia
# sue : sue
# jay : jay
# kompensasi : kompensasi
# buruk : buruk
# kelanjutannya : lanjut
# penghancur : hancur
# anjirau : anjirau
# haiboku : haiboku
# hero : hero
# bngst : bngst
# tunggakan : tunggak
# th : th
# indikator : indikator
# james : james
# rico : rico
# hrus : hrus
# dibenahi : benah
# ketersediaan : sedia
# inden : inden
# infrastruktur : infrastruktur
# christian : christian
# ditanyaaaa : ditanyaaaa
# bau : bau
# sukaa : sukaa
# depok : depok
# takut : takut
# kontak : kontak
# rivandi : rivandi
# ayuni : ayun
# evans : evans
# lampirkan : lampir
# tertib : tertib
# sepakat : sepakat
# denda : denda
# memutuskan : putus
# solusi : solusi
# dimana : mana
# pemeliharaan : pelihara
# lokasi : lokasi
# jarak : jarak
# berdekatan : dekat
# oshi : oshi
# kyoku : kyoku
# pdahal : pdahal
# males : males
# langit : langit
# musik : musik
# bales : bales
# maghrib : maghrib
# ajj : ajj
# anjr : anjr
# heyyy : heyyy
# gimane : gimane
# busuk : busuk
# tanda : tanda
# budak : budak
# istirahat : istirahat
# jerry : jerry
# permintaannya : minta
# dipertimbangkan : timbang
# disayangkan : sayang
# benefit : benefit
# didapatkan : dapat
# pilihan : pilih
# niihh : niihh
# best : best
# cabut : cabut
# dots : dots
# service : service
# gcp : gcp
# mitigasinya : mitigasinya
# pemindahan : pindah
# pengumumaaan : pengumumaaan
# mempermudah : mudah
# menindaklanjutinya : menindaklanjutinya
# dtunggu : dtunggu
# boc : boc
# bod : bod
# diblokir : blokir
# mat : mat
# cusss : cusss
# ahhh : ahhh
# promonya : promonya
# putri : putri
# terkoneksi : koneksi
# better : better
# relationship : relationship
# between : between
# heavy : heavy
# rain : rain
# wahh : wahh
# mantuaapp : mantuaapp
# mnet : mnet
# deobo : deobo
# fanwar : fanwar
# sekeluarga : keluarga
# keyla : keyla
# kantorku : kantor
# informasinya : informasi
# wkwkwkwkw : wkwkwkwkw
# sena : sena
# nguuuweriii : nguuuweriii
# totally : totally
# dukuh : dukuh
# kupang : kupang
# surabays : surabays
# solution : solution
# hadehh : hadehh
# bumn : bumn
# susahnya : susah
# ampun : ampun
# disalahgunakan : disalahgunakan
# kiki : kiki
# skrng : skrng
# allahuakbar : allahuakbar
# mita : mita
# essential : essential
# join : join
# fiesta : fiesta
# payient : payient
# edhi : edhi
# sape : sape
# anyeng : anyeng
# bandung : bandung
# phonix : phonix
# jan : jan
# ngadi : ngadi
# idih : idih
# durasi : durasi
# motto : motto
# kejang : kejang
# andrie : andrie
# shas : shas
# asli : asli
# rumahku : rumah
# malang : malang
# berhubung : hubung
# bisanya : bisa
# kepaksa : paksa
# apps : apps
# sungguh : sungguh
# apaka : apaka
# senyebelin : senyebelin
# ituuu : ituuu
# ragu : ragu
# slek : slek
# mangat : mangat
# nice : nice
# aji : aji
# stabilnya : stabil
# mhn : mhn
# terkena : kena
# dampak : dampak
# pulih : pulih
# tanggung : tanggung
# lolos : lolos
# ptn : ptn
# sinyalnyaaa : sinyalnyaaa
# arsen : arsen
# beserta : serta
# ponselnya : ponselnya
# systemnya : systemnya
# wahhh : wahhh
# juaraaa : juaraaa
# dehhh : dehhh
# yep : yep
# usual : usual
# vairen : vairen
# lecha : lecha
# dito : dito
# dikit : dikit
# lost : lost
# gblk : gblk
# irul : irul
# indihomo : indihomo
# ccd : ccd
# saban : saban
# exo : exo
# idupin : idupin
# roater : roater
# awas : awas
# gwa : gwa
# bgitu : bgitu
# dhlah : dhlah
# mls : mls
# think : think
# feel : feel
# stupid : stupid
# ass : ass
# petugasnya : tugas
# bajunya : baju
# basah : basah
# memperbaiki : baik
# ramah : ramah
# bpk : bpk
# suhartono : suhartono
# maju : maju
# dialamat : alamat
# tahapannya : tahap
# gantian : ganti
# ovo : ovo
# gopay : gopay
# linkaja : linkaja
# adit : adit
# referensi : referensi
# wifiku : wifiku
# gal : gal
# bimo : bimo
# spekulasi : spekulasi
# gajaln : gajaln
# yailah : yailah
# rekomendasi : rekomendasi
# cable : cable
# pemblokiran : blokir
# memutar : putar
# force : force
# permintaan : minta
# dikirim : kirim
# dire : dire
# olive : olive
# syavi : syavi
# anakkolong : anakkolong
# llestari : llestari
# nixon : nixon
# kuntadhi : kuntadhi
# nii : nii
# kingdom : kingdom
# tauu : tauu
# laku : laku
# netflix : netflix
# grow : grow
# asshole : asshole
# gaes : gaes
# indimovie : indimovie
# friend : friend
# reunion : reunion
# wib : wib
# mahruf : mahruf
# khaerul : khaerul
# akhiran : akhir
# penggunaan : guna
# melebihi : lebih
# batas : batas
# pemakaian : pakai
# wajar : wajar
# mempengaruhi : pengaruh
# penurunan : turun
# kecepatan : cepat
# tangan : tangan
# pegel : gel
# situ : situ
# omel : omel
# temanku : teman
# warkopnya : warkopnya
# dipasang : pasang
# ribet : ribet
# verifikasi : verifikasi
# klean : klean
# ayolah : ayo
# cepetan : cepetan
# gangguannya : ganggu
# nyusun : nyusun
# skripsi : skripsi
# kosan : kosan
# kang : kang
# memperingati : ingat
# wajib : wajib
# favorit : favorit
# waiting : waiting
# some : some
# halu : halu
# says : says
# meteor : meteor
# cok : cok
# ngetest : ngetest
# senjata : senjata
# astral : astral
# buatan : buat
# sihh : sihh
# anjrottttt : anjrottttt
# mengkesalllllllllll : mengkesalllllllllll
# indihomeeee : indihomeeee
# kejelasan : jelas
# ngechargenyyy : ngechargenyyy
# monyettt : monyettt
# kejauhaannnnnnnnnnnn : kejauhaannnnnnnnnnnn
# jelekkkkk : jelekkkkk
# msk : msk
# kemendikbud : kemendikbud
# theater : theater
# pribadi : pribadi
# niatnya : niat
# rayain : rayain
# ultah : ultah
# sambut : sambut
# podcast : podcast
# nungguin : nungguin
# kumat : kumat
# badmood : badmood
# least : least
# mendokusai : mendokusai
# indeed : indeed
# kouta : kouta
# ian : ian
# dzuhur : dzuhur
# los : los
# knpa : knpa
# gardu : gardu
# perluas : luas
# cakupan : cakup
# wirasaba : wirasaba
# tidur : tidur
# gelap : gelap
# sholawat : sholawat
# telek : telek
# kinn : kinn
# surabaya : surabaya
# uci : uci
# playback : playback
# pause : pause
# rewind : rewind
# menonton : tonton
# kesukaan : suka
# manfaatkan : manfaat
# eskalasi : eskalasi
# twit : twit
# zanel : zanel
# mendengar : dengar
# baiknya : baik
# beraktivitas : aktivitas
# ann : ann
# ndang : ndang
# periksa : periksa
# tiktok : tiktok
# yutub : yutub
# memuaskan : muas
# bravo : bravo
# dijaringan : jaring
# kalah : kalah
# saing : saing
# ngeunaheun : ngeunaheun
# drpd : drpd
# alfath : alfath
# about : about
# issue : issue
# kindly : kindly
# checking : checking
# heh : heh
# marlina : marlina
# mamun : mamun
# eskalasikan : eskalasi
# gakbisa : gakbisa
# ishh : ishh
# mengkesal : kesal
# munculnya : muncul
# lumayan : lumayan
# kirim : kirim
# pesan : pesan
# dongggg : dongggg
# siiii : siiii
# bissss : bissss
# klau : klau
# manaan : mana
# tangsel : tangsel
# dihubungkan : hubung
# seem : seem
# while : while
# ever : ever
# yesterday : yesterday
# works : works
# other : other
# resolve : resolve
# cempiyen : cempiyen
# inimh : inimh
# kedetek : kedetek
# nyalain : nyalain
# hotspot : hotspot
# viki : viki
# iqiyi : iqiyi
# selancarnya : selancar
# tsel : tsel
# ktimbang : ktimbang
# piye : piye
# karang : karang
# progresnyalah : progres
# total : total
# digua : gua
# selek : selek
# downloadnya : downloadnya
# sisanya : sisa
# marta : marta
# jalanin : jalanin
# nasip : nasip
# blum : blum
# robby : robby
# infokan : info
# suaranya : suara
# speakernya : speakernya
# ipon : ipon
# bluetooth : bluetooth
# headsetnua : headsetnua
# dipatahin : dipatahin
# persero : persero
# tbk : tbk
# bergerak : gerak
# pemulihan : pulih
# bencana : bencana
# alam : alam
# mengguncang : guncang
# ocha : ocha
# dhea : dhea
# terjaga : jaga
# okeyy : okeyy
# listrik : listrik
# kelebihan : lebih
# kekurangan : kurang
# akhlak : akhlak
# plisss : plisss
# bangett : bangett
# kynya : kynya
# ginj : ginj
# ekosuwandi : ekosuwandi
# simo : simo
# katrungan : katrungan
# kidul : kidul
# langgar : langgar
# ngedown : ngedown
# uwoo : uwoo
# terganggu : ganggu
# datangnya : datang
# membayar : bayar
# commerce : commerce
# merchant : merchant
# tokopedia : tokopedia
# shopee : shopee
# lazada : lazada
# blibli : blibli
# simak : simak
# band : band
# indie : indie
# disponsori : sponsor
# berganti : ganti
# telkomslank : telkomslank
# ontrog : ontrog
# kelap : kelap
# kelip : kelip
# fariq : fariq
# eca : eca
# nata : nata
# pengembalian : kembali
# deposit : deposit
# dimaksimalkan : maksimal
# terealisasi : realisasi
# sombong : sombong
# ksl : ksl
# dhjekskwo : dhjekskwo
# sebulan : bulan
# dana : dana
# muka : muka
# diterima : terima
# internetan : internetan
# ilang : ilang
# alias : alias
# junaidi : junaidi
# idha : idha
# abdee : abdee
# menjabat : jabat
# sambung : sambung
# offline : offline
# far : far
# dilemotin : dilemotin
# sial : sial
# nasution : nasution
# kelebihannya : lebih
# kekurangannya : kurang
# marketing : marketing
# area : area
# sidoarjo : sidoarjo
# matur : matur
# nuwun : nuwun
# kamar : kamar
# sya : sya
# connec : connec
# cpt : cpt
# iwan : iwan
# belakangnya : belakang
# nasi : nasi
# padang : padang
# juara : juara
# thankyou : thankyou
# mendingan : mending
# libur : libur
# seneng : neng
# menyala : nyala
# ngaruh : ngaruh
# inet : inet
# berdedikasi : dedikasi
# pekerjaannya : kerja
# badannya : badan
# dipercepat : cepat
# rizkya : rizkya
# dhika : dhika
# didm : didm
# interaksinya : interaksi
# radyan : radyan
# lega : lega
# lepas : lepas
# megavision : megavision
# bebas : bebas
# berkontribusi : kontribusi
# komuniti : komuniti
# seeding : seeding
# habe : habe
# barunya : baru
# diawali : awal
# myir : myir
# myid : myid
# hdeh : hdeh
# dina : dina
# spotifyan : spotifyan
# hdhsjajssjanan : hdhsjajssjanan
# rinka : rinka
# echa : echa
# maksudnya : maksud
# nelpon : nelpon
# ncdream : ncdream
# blur : blur
# mental : mental
# berisi : isi
# ajakan : aja
# mutia : mutia
# euyy : euyy
# show : show
# akunya : aku
# iyaaa : iyaaa
# pantesannn : pantesannn
# aduan : adu
# dipanggilkan : panggil
# gsp : gsp
# komisarisnya : komisaris
# doi : doi
# tida : tida
# wonwoo : wonwoo
# anin : anin
# flaw : flaw
# menginformasikan : informasi
# privacy : privacy
# indikatornya : indikator
# bles : bles
# kenapasiii : kenapasiii
# bsknya : bsknya
# subscriptionnya : subscriptionnya
# universe : universe
# telling : telling
# wolfgang : wolfgang
# websitenya : websitenya
# meki : mek
# tugas : tugas
# kondisinya : kondisi
# teteh : teteh
# kann : kann
# anjjjrtff : anjjjrtff
# ngirim : ngirim
# video : video
# jlk : jlk
# mari : mari
# bersahabat : sahabat
# mendaftar : daftar
# tembaga : tembaga
# ufiq : ufiq
# rajab : rajab
# memblokir : blokir
# ngomel : ngomel
# njg : njg
# marsella : marsella
# urgent : urgent
# voucher : voucher
# luv : luv
# emng : emng
# ajr : ajr
# ahilah : ahilah
# kode : kode
# membukanya : buka
# fivi : fivi
# tampilan : tampil
# mencegah : cegah
# mrs : mrs
# innara : innara
# product : product
# account : account
# doski : doski
# jamin : jamin
# lokal : lokal
# lanjtar : lanjtar
# ranadipura : ranadipura
# dibetul : betul
# dijanjiin : dijanjiin
# gilaaa : gilaaa
# ste : ste
# konfigurasi : konfigurasi
# private : private
# wid : wid
# berakhiran : akhir
# mksdnya : mksdnya
# switch : switch
# lanjay : lanjay
# ngedumel : ngedumel
# boyke : boyke
# nufi : nufi
# bertingkah : ting
# bandwith : bandwith
# dikurangin : rangin
# bucin : bucin
# gaaaaa : gaaaaa
# ngetweet : ngetweet
# gambar : gambar
# renew : renew
# bukti : bukti
# berhasil : hasil
# dtg : dtg
# bilangnya : bilang
# nyabut : nyabut
# atasannya : atas
# dikasi : kasi
# lan : lan
# ajaa : ajaa
# sw : sw
# nto : nto
# welcome : welcome
# heri : heri
# desktop : desktop
# hhmm : hhmm
# kunjungan : kunjung
# teknisinya : teknisi
# dicancel : dicancel
# ngedet : ngedet
# mpe : mpe
# software : software
# hardware : hardware
# betapa : betapa
# menyebalkannya : sebal
# ngajar : ngajar
# presentasi : presentasi
# apasih : apasih
# heeh : heeh
# ditambah : tambah
# ngaji : ngaji
# ras : ras
# slankers : slankers
# selles : selles
# njem : njem
# survey : survey
# maya : maya
# infrom : infrom
# through : through
# direct : direct
# mesage : mesage
# action : action
# arvi : arvi
# kompakan : kompak
# deadline : deadline
# bantuaannya : bantuaannya
# duit : duit
# berjam : jam
# hahahahah : hahahahah
# bgini : bgini
# bngt : bngt
# permisi : permisi
# restrat : restrat
# isi : isi
# tweet : tweet
# katya : katya
# alasan : alas
# tara : tara
# rasyid : rasyid
# nyerah : nyerah
# dikoordinasikan : koordinasi
# telco : telco
# cekcok : cekcok
# deva : deva
# reinstall : reinstall
# terupdate : terupdate
# keversi : versi
# mengalaminya : alam
# bersiaplah : siap
# unlimited : unlimited
# syarat : syarat
# koleksi : koleksi
# asking : asking
# nomu : nomu
# jjang : jjang
# izin : izin
# jumaini : jumaini
# device : device
# terhubung : hubung
# optimal : optimal
# mengurangi : kurang
# violla : violla
# xxxxxxxxxx : xxxxxxxxxx
# lengkapnya : lengkap
# interkasi : interkasi
# ikra : ikra
# menemui : temu
# netfilx : netfilx
# flat : flat
# tobat : tobat
# tio : tio
# struggle : struggle
# camera : camera
# memantau : pantau
# rumahmu : rumah
# bermanfaat : manfaat
# dedi : dedi
# bersedia : sedia
# teratasi : atas
# aysa : aysa
# slow : slow
# yeuh : yeuh
# pftt : pftt
# penakut : takut
# kebayang : bayang
# ngeliat : ngeliat
# kelas : kelas
# temenan : temenan
# jin : jin
# penunggu : tunggu
# gang : gang
# tinggal : tinggal
# boneka : boneka
# kesayangan : sayang
# geger : geger
# cipanas : cipanas
# cianjur : cianjur
# dipotong : potong
# sisa : sisa
# terpakai : pakai
# depositnya : deposit
# utuh : utuh
# donk : donk
# mengharap : harap
# berharap : harap
# modemnya : modem
# dibuang : buang
# menagih : tagih
# sibagas : sibagas
# spotifnya : spotifnya
# berinteraksi : interaksi
# official : official
# mempercepat : cepat
# lengkapi : lengkap
# darman : darman
# andreas : andreas
# greta : greta
# syamsuddin : syamsuddin
# percepatan : cepat
# xxxx : xxxx
# prioritas : prioritas
# cacacacacacacat : cacacacacacacat
# musnah : musnah
# lau : lau
# pluto : pluto
# sekelas : kelas
# bayarny : bayarny
# serumah : rumah
# ngeblock : ngeblock
# sent : sent
# email : email
# network : network
# warning : warning
# message : message
# firewall : firewall
# blocking : blocking
# using : using
# fine : fine
# phone : phone
# sayang : sayang
# dibutuhkan : butuh
# buatin : buatin
# tiketnya : tiket
# myin : myin
# ngeload : ngeload
# gif : gif
# telat : telat
# ari : ari
# gausah : gausah
# monyett : monyett
# parel : parel
# engene : engene
# september : september
# jalur : jalur
# gasengaja : gasengaja
# iland : iland
# eps : eps
# ...
# edukatif : edukatif
# insan : insan
# dunia : dunia
# mempersembahkan : sembah
# guru : guru
# pelajar : ajar
# aktivitas : aktivitas
# mengajar : ajar
# online : online
# donggg : donggg
# menyimpulkan : simpul
# pengganti : ganti
# sepadan : padan
# barang : barang
# bekas : bekas
# jatuh : jatuh
# gjelas : gjelas
# kaka : kaka
# base : base
# ctbz : ctbz
# note : note
# apaaa : apaaa
# putt : putt
# ahmad : ahmad
# dhani : dhani
# abde : abde
# nasib : nasib
# musisi : musisi
# terpuruk : puruk
# operator : operator
# fanne : fanne
# catuan : catu
# adaptor : adaptor
# sekalinya : sekali
# gangguang : gangguang
# berhari : hari
# wow : wow
# njing : njing
# usk : usk
# internetku : internetku
# rusak : rusak
# semingguan : minggu
# aisye : aisye
# available : available
# sontoloyo : sontoloyo
# menipu : tipu
# complaint : complaint
# kerumah : rumah
# kunjung : kunjung
# penipu : tipu
# andaikan : andai
# ruined : ruined
# ren : ren
# sungkan : sungkan
# masukin : masukin
# ridho : ridho
# roma : roma
# majuan : maju
# milih : milih
# memilihnya : pilih
# jeanna : jeanna
# sanggup : sanggup
# cht : cht
# nvm : nvm
# siapin : siapin
# batalin : batalin
# janji : janji
# hilalnya : hilal
# belom : bom
# anjrot : anjrot
# keselll : keselll
# wallaikumsallam : wallaikumsallam
# nungsky : nungsky
# assalamualaikum : assalamualaikum
# beloman : bom
# imron : imron
# aksesnya : akses
# berhadapan : hadap
# ncen : ncen
# nggarai : nggarai
# kezelll : kezelll
# pisan : pis
# meeting : meeting
# curhat : curhat
# ceo : ceo
# beliin : beliin
# fullset : fullset
# bbyy : bbyy
# gituu : gituu
# kapok : kapok
# berkedok : kedok
# fiber : fiber
# optik : optik
# gampang : gampang
# mengajukan : aju
# diputus : putus
# menajukan : taju
# jt : jt
# bus : bus
# drtd : drtd
# berkecimpung : kecimpung
# perkabelan : kabel
# darah : darah
# sdang : sdang
# juanda : juanda
# aktivasi : aktivasi
# virusnya : virus
# yaaah : yaaah
# biismillah : biismillah
# gula : gula
# jbjb : jbjb
# cabik : cabik
# mayan : mayan
# tmn : tmn
# ngobrol : ngobrol
# beji : beji
# jabar : jabar
# aer : aer
# tercapai : capai
# dirut : dirut
# minum : minum
# julian : juli
# dikeplak : keplak
# mit : mit
# cmn : cmn
# atasan : atas
# routing : routing
# ping : ping
# mlm : mlm
# hdhdhdhd : hdhdhdhd
# gamau : gamau
# khusunya : khusunya
# sales : sales
# collab : collab
# wonder : wonder
# does : does
# blocked : blocked
# strange : strange
# ffs : ffs
# dibenahin : dibenahin
# heisenberg : heisenberg
# ngehe : ngehe
# tanggapan : tanggap
# program : program
# telk : telk
# unggulan : unggul
# minoritas : minoritas
# kartuhalo : kartuhalo
# kartuvirus : kartuvirus
# generasi : generasi
# tandur : tandur
# plurhome : plurhome
# gabisaaa : gabisaaa
# gabisaaaa : gabisaaaa
# spotifunya : spotifunya
# kmaren : kmaren
# iphone : iphone
# nggabisa : nggabisa
# iniiiii : iniiiii
# permasalahan : masalah
# gmna : gmna
# fans : fans
# aaa : aaa
# gapapa : gapapa
# jabatan : jabat
# menjadikan : jadi
# dividen : dividen
# subcribe : subcribe
# panic : panic
# billing : billing
# seringan : sering
# gojek : gojek
# atuhhh : atuhhh
# knppp : knppp
# dendanya : denda
# ckckck : ckckck
# lucletta : lucletta
# informasiikan : informasiikan
# perminntaan : perminntaan
# tercabut : cabut
# menghapus : hapus
# dependency : dependency
# box : box
# gambarnya : gambar
# ringan : ringan
# hhhhh : hhhhh
# banter : banter
# njir : njir
# fals : fals
# stem : stem
# butuhkan : butuh
# joget : joget
# kacamata : kacamata
# cool : cool
# ngrasa : ngrasa
# binggung : binggung
# enci : enci
# direkrut : rekrut
# ikeu : ikeu
# playoff : playoff
# jua : jua
# wal : wal
# terhalang : halang
# bca : bca
# tokped : tokped
# makanannya : makan
# hshshshs : hshshshs
# complainnya : complainnya
# nba : nba
# mke : mke
# citranet : citranet
# kafe : kafe
# kenapasi : napas
# yeuuu : yeuuu
# ban : ban
# dick : dick
# starboi : starboi
# baperan : baperan
# makalah : makalah
# muzik : muzik
# duel : duel
# tergantung : gantung
# jogjanya : jogjanya
# ringroad : ringroad
# keselatan : selat
# daily : daily
# dauntless : dauntless
# kocak : kocak
# cem : cem
# bokep : bokep
# sapa : sapa
# sange : sange
# berang : berang
# desktopku : desktopku
# apaansiiii : apaansiiii
# gamers : gamers
# ikuti : ikut
# tips : tips
# teratur : atur
# kebersihan : bersih
# perhatikan : perhati
# pola : pola
# gamenya : gamenya
# gamer : gamer
# raditya : raditya
# lokasinya : lokasi
# sok : sok
# atuh : atuh
# selfie : selfie
# gaa : gaa
# bagusann : bagusann
# hrsnya : hrsnya
# komut : komut
# helpppp : helpppp
# wooyyy : wooyyy
# pengaduaannya : pengaduaannya
# haris : haris
# bocorkah : bocor
# sihhhh : sihhhh
# balap : balap
# sepeda : sepeda
# eurosport : eurosport
# heuheu : heuheu
# tangga : tangga
# nurunin : nurunin
# gitaran : gitar
# ide : ide
# bisnisku : bisnis
# mengedukasi : edukasi
# memberdayakan : daya
# jtb : jtb
# tyas : tyas
# jeki : jeki
# kawin : kawin
# babik : babik
# ttng : ttng
# radiyya : radiyya
# adeuuuhh : adeuuuhh
# ahuy : ahuy
# jeng : jeng
# idihom : idihom
# gp : gp
# tlp : tlp
# kunci : kunci
# didiskon : diskon
# sepersekian : sekian
# ngadepin : ngadepin
# netplix : netplix
# dot : dot
# mentang : mentang
# indiehom : indiehom
# ekekekkeke : ekekekkeke
# pgi : pgi
# mlh : mlh
# prosedur : prosedur
# saiful : saiful
# cie : cie
# nyuruh : nyuruh
# sik : sik
# dibayar : bayar
# luama : luama
# tumbenan : tumben
# jaringanku : jaring
# customer : customer
# kigp : kigp
# jadwal : jadwal
# bye : bye
# monster : monster
# hunter : hunter
# sokor : sokor
# asa : asa
# definitely : definitely
# unsubscibe : unsubscibe
# bagusan : bagus
# lomba : lomba
# kgip : kgip
# terburuk : buruk
# platform : platform
# hanifalmuhamadyhasyim : hanifalmuhamadyhasyim
# hmmmm : hmmmm
# persis : persis
# tadii : tadi
# menginfokan : info
# purwokerto : purwokerto
# bisaaaa : bisaaaa
# tolongggg : tolongggg
# olim : olim
# masy : masy
# ksh : ksh
# solarsystem : solarsystem
# samaaa : samaaa
# aya : aya
# khaiqal : khaiqal
# ajaib : ajaib
# jasa : jasa
# relawan : rawan
# jauuuh : jauuuh
# muu : muu
# yess : yess
# kans : kans
# komi : kom
# epon : epon
# bunyinya : bunyi
# uhmm : uhmm
# palagi : palagi
# disni : disni
# mraz : mraz
# nugas : nugas
# smgt : smgt
# kekuasaan : kuasa
# pegang : pegang
# olh : olh
# orng : orng
# ahlinya : ahli
# mka : mka
# hnya : hnya
# mnunggu : mnunggu
# kehancurannya : hancur
# klw : klw
# dwng : dwng
# sandhara : sandhara
# postingannya : postingannya
# terindikasi : indikasi
# dibikin : bikin
# lapisan : lapis
# cakrawala : cakrawala
# chels : chels
# meg : meg
# aish : aish
# ndada : ndada
# mod : mod
# diinfokan : info
# nda : nda
# kubaca : baca
# tweenya : tweenya
# dikonfirmasi : konfirmasi
# amond : amond
# ampli : ampli
# kevin : kevin
# ngrasain : ngrasain
# nie : nie
# indihom : indihom
# merakyat : rakyat
# ambilnya : ambil
# kosong : kosong
# kesambung : sambung
# elahh : elahh
# effort : effort
# terselesaikan : selesai
# abi : abi
# gilang : gilang
# parmaditya : parmaditya
# membawa : bawa
# nitip : nitip
# buzzerp : buzzerp
# paham : paham
# tur : tur
# album : album
# laluu : laluu
# terdeteksi : deteksi
# kalapia : kalapia
# ganggu : ganggu
# aktifitasnya : aktifitasnya
# diprioritaskan : prioritas
# dihapus : hapus
# myrepublic : myrepublic
# diluar : luar
# perusahaan : usaha
# beh : beh
# tupoksinya : tupoksinya
# merubah : rubah
# slanker : slanker
# memakai : pakai
# memasang : pasang
# sukarela : sukarela
# percaya : percaya
# kedunguan : dungu
# tlh : tlh
# devina : devina
# kfc : kfc
# bank : bank
# kritik : kritik
# sejelek : jelek
# ditanyain : ditanyain
# kenyamanan : nyaman
# cabang : cabang
# resi : resi
# fajar : fajar
# sebentar : sebentar
# bagask : bagask
# sawangan : sawangan
# snansjjwjwjehehuwjwwjna : snansjjwjwjehehuwjwwjna
# bagas : bagas
# ngebug : ngebug
# mnggunakan : mnggunakan
# mempertimbangkan : timbang
# seksama : seksama
# pengangkatan : angkat
# suudzon : suudzon
# fasilitas : fasilitas
# biarkan : biar
# pelangga : pelangga
# mentakedown : mentakedown
# over : over
# flippin : flippin
# terkendalanya : kendala
# lia : lia
# diupload : diupload
# kpn : kpn
# benernya : benernya
# siaran : siar
# championstv : championstv
# premier : premier
# sun : sun
# manchester : manchester
# city : city
# prediksi : prediksi
# angkat : angkat
# bosss : bosss
# bgtttt : bgtttt
# demanding : demanding
# pol : pol
# marmari : marmari
# mar : mar
# dtk : dtk
# keplay : keplay
# intinya : inti
# airplane : airplane
# mode : mode
# wkwkwkwkwk : wkwkwkwkwk
# bar : bar
# gamake : gamake
# penukaran : tukar
# point : point
# loungenya : loungenya
# needy : needy
# pakenya : pakenya
# skarang : skarang
# art : art
# fian : fian
# pactcord : pactcord
# auto : auto
# matin : matin
# alessandro : alessandro
# forgot : forgot
# trhubung : trhubung
# fyi : fyi
# dvice : dvice
# browsing : browsing
# byu : byu
# yaudah : yaudah
# eksis : eks
# dimari : mari
# frenata : frenata
# zikri : zikri
# alasannya : alas
# matang : matang
# dimasa : masa
# uwaw : uwaw
# mengecek : ecek
# masoh : masoh
# yerisolir : yerisolir
# jimmy : jimmy
# hiro : hiro
# tempo : tempo
# pelunasan : lunas
# bulanan : bulan
# bulannya : bulan
# stormfire : stormfire
# ardy : ardy
# dilokasinya : lokasi
# progressnya : progressnya
# menghindari : hindar
# {'telkom': 'telkom', 'menggelar': 'gelar', 'aksi': 'aksi', 'peduli': 'peduli', 'indihome': 'indihome', 'membangkitan': 'bangkit', 'ekonomi': 'ekonomi', 'dll': 'dll', 'propinsi': 'propinsi', 'ntt': 'ntt', 'kemarin': 'kemarin', 'diterjang': 'terjang', 'badai': 'badai', 'seroja': 'seroja', 'anjirlah': 'anjir', 'spotify': 'spotify', 'knp': 'knp', 'bangsat': 'bangsat', '': '', 'sepuluh': 'puluh', 'rebu': 'rebu', 'bakso': 'bakso', 'semangkok': 'semangkok', 'lgsg': 'lgsg', 'berlangganan': 'langgan', 'wkwkwk': 'wkwkwk', 'ghosting': 'ghosting', 'embun': 'embun', 'iyooo': 'iyooo', 'bangun': 'bangun', 'tdr': 'tdr', 'bambet': 'bambet', 'euy': 'euy', 'tolong': 'tolong', 'temen': 'temen', 'sampe': 'sampe', 'hape': 'hape', 'android': 'android', 'connect': 'connect', 'jaringan': 'jaring', 'error': 'error', 'spotifynya': 'spotifynya', 'hee': 'hee', 'neh': 'neh', 'dipanggil': 'panggil', 'mohon': 'mohon', 'maap': 'maap', 'gamas': 'gamas', 'krena': 'krena', 'pnya': 'pnya', 'ane': 'ane', 'sinyal': 'sinyal', 'paket': 'paket', 'data': 'data', 'tilkumsil': 'tilkumsil', 'lemot': 'lot', 'kemaren': 'kemaren', 'anjing': 'anjing', 'alah': 'alah', 'screw': 'screw', 'kak': 'kak', 'ibnu': 'ibnu', 'internetnya': 'internetnya', 'silakan': 'sila', 'informasikan': 'informasi', 'nomor': 'nomor', 'layanan': 'layan', 'care': 'care', 'datanya': 'data', 'aman': 'aman', 'dibantu': 'bantu', 'cek': 'cek', 'jean': 'jean', 'nuk': 'nuk', 'makasih': 'makasih', 'fan': 'fan', 'provider': 'provider', 'hai': 'hai', 'arabel': 'arabel', 'terkait': 'kait', 'kondisi': 'kondisi', 'layanannya': 'layan', 'bantu': 'bantu', 'yuk': 'yuk', 'internet': 'internet', 'nama': 'nama', 'pemilik': 'milik', 'twitter': 'twitter', 'terima': 'terima', 'kasih': 'kasih', 'windys': 'windys', 'halo': 'halo', 'berri': 'berri', 'detail': 'detail', 'kakak': 'kakak', 'alami': 'alami', 'akun': 'akun', 'kayi': 'kayi', 'banget': 'banget', 'deh': 'deh', 'portal': 'portal', 'keluhan': 'keluh', 'cepat': 'cepat', 'pagi': 'pagi', 'tulung': 'tulung', 'iya': 'iya', 'kerja': 'kerja', 'plis': 'plis', 'dirumah': 'rumah', 'ngalamin': 'ngalamin', 'down': 'down', 'logo': 'logo', 'myindihome': 'myindihome', 'ikutan': 'ikut', 'quiz': 'quiz', 'rasi': 'rasi', 'emosi': 'emosi', 'riski': 'riski', 'ifa': 'ifa', 'diakses': 'akses', 'dicoba': 'coba', 'akses': 'akses', 'blokir': 'blokir', 'pakai': 'pakai', 'vpn': 'vpn', 'blok': 'blok', 'pantesan': 'pantesan', 'mslh': 'mslh', 'emen': 'emen', 'masri': 'masri', 'kendalanya': 'kendala', 'tunggu': 'tunggu', 'laporan': 'lapor', 'koneksi': 'koneksi', 'telepon': 'telepon', 'mati': 'mati', 'putus': 'putus', 'telp': 'telp', 'perhatian': 'perhati', 'pelanggan': 'langgan', 'mengeluhkan': 'keluh', 'diperhatikan': 'perhati', 'diperbaiki': 'baik', 'lapor': 'lapor', 'kemana': 'mana', 'problem': 'problem', 'langsungdi': 'langsungdi', 'tangani': 'tangan', 'posisi': 'posisi', 'balikpapan': 'balikpapan', 'hallo': 'hallo', 'sobat': 'sobat', 'terkendala': 'kendala', 'ponsel': 'ponsel', 'gua': 'gua', 'mah': 'mah', 'ganti': 'ganti', 'wifi': 'wifi', 'laen': 'laen', 'wifinya': 'wifinya', 'laginya': 'lagi', 'menghubungkan': 'hubung', 'games': 'games', 'pokok': 'pokok', 'sosmed': 'sosmed', 'koneksinya': 'koneksi', 'masak': 'masak', 'pembetulan': 'betul', 'udah': 'udah', 'kecewa': 'kecewa', 'langganan': 'langgan', 'halooo': 'halooo', 'mbps': 'mbps', 'izza': 'izza', 'maaf': 'maaf', 'ketidaknyamanannya': 'ketidaknyamanannya', 'aktif': 'aktif', 'via': 'via', 'pengecekan': 'kece', 'pudin': 'pudin', 'finally': 'finally', 'got': 'got', 'their': 'their', 'shit': 'shit', 'together': 'together', 'and': 'and', 'now': 'now', 'working': 'working', 'would': 'would', 'like': 'like', 'thank': 'thank', 'not': 'not', 'only': 'only', 'god': 'god', 'but': 'but', 'also': 'also', 'jesus': 'jesus', 'lerenono': 'lerenono', 'jancok': 'jancok', 'gini': 'gin', 'udh': 'udh', 'bae': 'bae', 'hate': 'hate', 'you': 'you', 'srs': 'srs', 'perihal': 'perihal', 'maksimal': 'maksimal', 'rionald': 'rionald', 'sarankan': 'saran', 'coba': 'coba', 'la ...
# ------------------------
# Pandas Apply:   0%|          | 0/1991 [00:00<?, ?it/s]
#                                                 content  \
# 0     pihak telkom/@telkomindonesia sudah menggelar ...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2     di tempat ak, sepuluh rebu bisa dapat bakso se...
# 3     @pempersweety @indihomecare @indihome wkwkwk d...
# 4     @ekctr @ibnvakbar @indihome @indihomecare iyoo...
# ...                                                 ...
# 1995  @babyflakey uwaw thanks\niya gr2 indihome tern...
# 1996  @indihomecare selamat pagi, mohon bantuan meng...
# 1997  @jimmy62640418 hai kak jimmy, hiro informasika...
# 1998  kak untuk tagihan jatuh tempo di tanggal berap...
# 1999  @ardy_stormfire hi kak ardy, embun cek saat in...
#
#                                          cleaning_tweet  \
# 0     pihak telkom sudah menggelar aksi peduli indih...
# 1        anjirlah ini spotify sama indihome knp bangsat
# 2      tempat sepuluh rebu bisa dapat bakso semangko...
# 3                       wkwkwk ghosting sama embun dari
# 4                       iyooo bangun tdr bambet ini euy
# ...                                                 ...
# 1995  uwaw thanks iya gr  indihome ternyata habis ga...
# 1996  selamat pagi mohon bantuan mengecek status ind...
# 1997  hai kak jimmy hiro informasikan jatuh tempo pe...
# 1998      kak untuk tagihan jatuh tempo tanggal berapa
# 1999   stormfire kak ardy embun cek saat ini dilokas...
#
#                                              tokenisasi  \
# 0     [pihak, telkom, sudah, menggelar, aksi, peduli...
# 1     [anjirlah, ini, spotify, sama, indihome, knp, ...
# 2     [, tempat, sepuluh, rebu, bisa, dapat, bakso, ...
# 3                 [wkwkwk, ghosting, sama, embun, dari]
# 4                [iyooo, bangun, tdr, bambet, ini, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, ternyata, ha...
# 1996  [selamat, pagi, mohon, bantuan, mengecek, stat...
# 1997  [hai, kak, jimmy, hiro, informasikan, jatuh, t...
# 1998  [kak, untuk, tagihan, jatuh, tempo, tanggal, b...
# 1999  [, stormfire, kak, ardy, embun, cek, saat, ini...
#
#                                                stopword  \
# 0     [telkom, menggelar, aksi, peduli, indihome, me...
# 1           [anjirlah, spotify, indihome, knp, bangsat]
# 2     [, sepuluh, rebu, bakso, semangkok, indihome, ...
# 3                             [wkwkwk, ghosting, embun]
# 4                     [iyooo, bangun, tdr, bambet, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, habis, ganti...
# 1996  [selamat, pagi, mohon, bantuan, mengecek, stat...
# 1997  [hai, kak, jimmy, hiro, informasikan, jatuh, t...
# 1998            [kak, tagihan, jatuh, tempo, tanggal, ]
# 1999  [, stormfire, kak, ardy, embun, cek, dilokasin...
#
#                                                stemming
# 0     [telkom, gelar, aksi, peduli, indihome, bangki...
# 1              [anjir, spotify, indihome, knp, bangsat]
# 2     [, puluh, rebu, bakso, semangkok, indihome, lg...
# 3                             [wkwkwk, ghosting, embun]
# 4                     [iyooo, bangun, tdr, bambet, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, habis, ganti...
# 1996  [selamat, pagi, mohon, bantu, ecek, status, in...
# 1997  [hai, kak, jimmy, hiro, informasi, jatuh, temp...
# 1998              [kak, tagih, jatuh, tempo, tanggal, ]
# 1999  [, stormfire, kak, ardy, embun, cek, lokasi, p...
#
# [1991 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [telkom, gelar, aksi, peduli, indihome, bangki...
# 1              [anjir, spotify, indihome, knp, bangsat]
# 2     [, puluh, rebu, bakso, semangkok, indihome, lg...
# 3                             [wkwkwk, ghosting, embun]
# 4                     [iyooo, bangun, tdr, bambet, euy]
# ...                                                 ...
# 1995  [uwaw, thanks, iya, gr, indihome, habis, ganti...
# 1996  [selamat, pagi, mohon, bantu, ecek, status, in...
# 1997  [hai, kak, jimmy, hiro, informasi, jatuh, temp...
# 1998              [kak, tagih, jatuh, tempo, tanggal, ]
# 1999  [, stormfire, kak, ardy, embun, cek, lokasi, p...
#
# [1991 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_5.xlsx')
