# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     @IndiHome Selamat Pagi silahkan menghubungi ka...
# 1     @Iqrajs k termasuk dalam segmentasi Bisnis. Te...
# 2     @Iqrajs Hallo, Kak Iqra. Maaf yah jadi bikin K...
# 3     @IndiHome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1995                                   @IndiHome cek dm
# 1996                             @mlbbfess Indihome ya?
# 1997           @IndiHome wow idenya kreatif banget nihh
# 1998  @IndiHome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
# [2000 rows x 1 columns]

# %%
print('Dataset size:', df.shape)
print('Columns are:', df.columns)
# Out:
# Dataset size: (2000, 1)
# Columns are: Index(['content'], dtype='object')

# %%
df.content.duplicated().sum()
# Out:
# 48

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     @IndiHome Selamat Pagi silahkan menghubungi ka...
# 1     @Iqrajs k termasuk dalam segmentasi Bisnis. Te...
# 2     @Iqrajs Hallo, Kak Iqra. Maaf yah jadi bikin K...
# 3     @IndiHome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1993                           @FWBESS id indihome ya ?
# 1996                             @mlbbfess Indihome ya?
# 1997           @IndiHome wow idenya kreatif banget nihh
# 1998  @IndiHome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
# [1943 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     @indihome selamat pagi silahkan menghubungi ka...
# 1     @iqrajs k termasuk dalam segmentasi bisnis. te...
# 2     @iqrajs hallo, kak iqra. maaf yah jadi bikin k...
# 3     @indihome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1993                           @fwbess id indihome ya ?
# 1996                             @mlbbfess indihome ya?
# 1997           @indihome wow idenya kreatif banget nihh
# 1998  @indihome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
# [1943 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     @indihome selamat pagi silahkan menghubungi ka...
# 1     @iqrajs k termasuk dalam segmentasi bisnis. te...
# 2     @iqrajs hallo, kak iqra. maaf yah jadi bikin k...
# 3     @indihome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1993                           @fwbess id indihome ya ?
# 1996                             @mlbbfess indihome ya?
# 1997           @indihome wow idenya kreatif banget nihh
# 1998  @indihome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
#                                          cleaning_tweet
# 0     selamat pagi silahkan menghubungi kami via ter...
# 1      termasuk dalam segmentasi bisnis terima kasih...
# 2     hallo kak iqra maaf yah jadi bikin kakak gak n...
# 3     admin ini wifi saya rumah kok bermasalah terus...
# 4     yang wifi nya indihome pada error gak dari sem...
# ...                                                 ...
# 1993                                          indihome
# 1996                                          indihome
# 1997                     wow idenya kreatif banget nihh
# 1998             kereen infonya jadi nambah wawasan nih
# 1999  sungguh mulia sekali indihome nonton aot last ...
#
# [1943 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     @indihome selamat pagi silahkan menghubungi ka...
# 1     @iqrajs k termasuk dalam segmentasi bisnis. te...
# 2     @iqrajs hallo, kak iqra. maaf yah jadi bikin k...
# 3     @indihome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1993                           @fwbess id indihome ya ?
# 1996                             @mlbbfess indihome ya?
# 1997           @indihome wow idenya kreatif banget nihh
# 1998  @indihome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
#                                          cleaning_tweet  \
# 0     selamat pagi silahkan menghubungi kami via ter...
# 1      termasuk dalam segmentasi bisnis terima kasih...
# 2     hallo kak iqra maaf yah jadi bikin kakak gak n...
# 3     admin ini wifi saya rumah kok bermasalah terus...
# 4     yang wifi nya indihome pada error gak dari sem...
# ...                                                 ...
# 1993                                          indihome
# 1996                                          indihome
# 1997                     wow idenya kreatif banget nihh
# 1998             kereen infonya jadi nambah wawasan nih
# 1999  sungguh mulia sekali indihome nonton aot last ...
#
#                                              tokenisasi
# 0     [selamat, pagi, silahkan, menghubungi, kami, v...
# 1     [, termasuk, dalam, segmentasi, bisnis, terima...
# 2     [hallo, kak, iqra, maaf, yah, jadi, bikin, kak...
# 3     [admin, ini, wifi, saya, rumah, kok, bermasala...
# 4     [yang, wifi, nya, indihome, pada, error, gak, ...
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997               [wow, idenya, kreatif, banget, nihh]
# 1998      [kereen, infonya, jadi, nambah, wawasan, nih]
# 1999  [sungguh, mulia, sekali, indihome, nonton, aot...
#
# [1943 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'nya'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(3000)
# Out:
#                                                 content  \
# 0     @indihome selamat pagi silahkan menghubungi ka...
# 1     @iqrajs k termasuk dalam segmentasi bisnis. te...
# 2     @iqrajs hallo, kak iqra. maaf yah jadi bikin k...
# 3     @indihome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1993                           @fwbess id indihome ya ?
# 1996                             @mlbbfess indihome ya?
# 1997           @indihome wow idenya kreatif banget nihh
# 1998  @indihome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
#                                          cleaning_tweet  \
# 0     selamat pagi silahkan menghubungi kami via ter...
# 1      termasuk dalam segmentasi bisnis terima kasih...
# 2     hallo kak iqra maaf yah jadi bikin kakak gak n...
# 3     admin ini wifi saya rumah kok bermasalah terus...
# 4     yang wifi nya indihome pada error gak dari sem...
# ...                                                 ...
# 1993                                          indihome
# 1996                                          indihome
# 1997                     wow idenya kreatif banget nihh
# 1998             kereen infonya jadi nambah wawasan nih
# 1999  sungguh mulia sekali indihome nonton aot last ...
#
#                                              tokenisasi  \
# 0     [selamat, pagi, silahkan, menghubungi, kami, v...
# 1     [, termasuk, dalam, segmentasi, bisnis, terima...
# 2     [hallo, kak, iqra, maaf, yah, jadi, bikin, kak...
# 3     [admin, ini, wifi, saya, rumah, kok, bermasala...
# 4     [yang, wifi, nya, indihome, pada, error, gak, ...
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997               [wow, idenya, kreatif, banget, nihh]
# 1998      [kereen, infonya, jadi, nambah, wawasan, nih]
# 1999  [sungguh, mulia, sekali, indihome, nonton, aot...
#
#                                                stopword
# 0     [selamat, pagi, silahkan, menghubungi, via, te...
# 1          [, segmentasi, bisnis, terima, kasih, nay, ]
# 2     [hallo, kak, iqra, maaf, kakak, nyaman, periha...
# 3     [admin, wifi, rumah, bermasalah, adik, sekolah...
# 4                    [wifi, indihome, error, semalem, ]
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997               [wow, idenya, kreatif, banget, nihh]
# 1998                 [kereen, infonya, nambah, wawasan]
# 1999  [sungguh, mulia, indihome, nonton, aot, last, ...
#
# [1943 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3683
# ------------------------
# selamat : selamat
# pagi : pagi
# silahkan : silah
# menghubungi : hubung
# via : via
# terima : terima
# kasih : kasih
# ichal : ichal
#  :
# segmentasi : segmentasi
# bisnis : bisnis
# nay : nay
# hallo : hallo
# kak : kak
# iqra : iqra
# maaf : maaf
# kakak : kakak
# nyaman : nyaman
# perihal : perihal
# karingan : karingan
# maksimal : maksimal
# sarankan : saran
# rekan : rekan
# email : email
# twitter : twitter
# fanpage : fanpage
# facebook : facebook
# telkom : telkom
# digital : digital
# solution : solution
# karna : karna
# layanan : layan
# kaka : kaka
# admin : admin
# wifi : wifi
# rumah : rumah
# bermasalah : masalah
# adik : adik
# sekolah : sekolah
# daring : daring
# tolong : tolong
# dicek : cek
# pembayaran : bayar
# telat : telat
# tks : tks
# indihome : indihome
# error : error
# semalem : semalem
# jam : jam
# kek : kek
# surya : surya
# perbaikan : baik
# pembersihan : bersih
# plug : plug
# unplug : unplug
# modem : modem
# naia : naia
# cek : cek
# sistem : sistem
# jaringan : jaring
# online : online
# lokasi : lokasi
# stabil : stabil
# said : said
# tetepin : tetepin
# pilih : pilih
# kerja : kerja
# bener : bener
# sabar : sabar
# halo : halo
# internet : internet
# mati : mati
# udah : udah
# direstart : direstart
# cabut : cabut
# kabel : kabel
# power : power
# telpon : telpon
# ngaruh : ngaruh
# mohon : mohon
# bantuan : bantu
# sehari : hari
# diperbaiki : baik
# internetnya : internetnya
# ayolah : ayo
# gini : gin
# homecare : homecare
# shortlink : shortlink
# nunik : nunik
# zulfa : zulfa
# akses : akses
# bantu : bantu
# refresh : refresh
# pusat : pusat
# menunggu : tunggu
# menit : menit
# koneksikan : koneksi
# berkala : kala
# interaksi : interaksi
# silakan : sila
# hubungi : hubung
# akun : akun
# useetv : useetv
# konek : konek
# karantina : karantina
# bro : bro
# iya : iya
# eeq : eeq
# teknisi : teknisi
# solve : solve
# kompensasinya : kompensasi
# terkait : kait
# jasa : jasa
# bayar : bayar
# tagihan : tagih
# full : full
# pindah : pindah
# alamat : alamat
# bawa : bawa
# alat : alat
# alatnya : alat
# ganti : ganti
# anand : anand
# septiwi : septiwi
# bagus : bagus
# terpantau : pantau
# laporannya : lapor
# berkenan : kenan
# dicoba : coba
# berkendala : kendala
# nggak : nggak
# lost : lost
# min : min
# liem : liem
# ketidaknyamanannya : ketidaknyamanannya
# proses : proses
# pemasangan : pasang
# registrasi : registrasi
# mengirimkan : kirim
# nomor : nomor
# registrasinya : registrasi
# pengecekan : kece
# progresnya : progres
# gus : gus
# allhamdulilah : allhamdulilah
# eheh : eheh
# wiffinya : wiffinya
# ape : ape
# leh : leh
# allah : allah
# bapakku : bapak
# tanggal : tanggal
# kemarin : kemarin
# malem : malem
# dibiarin : dibiarin
# semaleman : maleman
# lancar : lancar
# tetep : tetep
# gimana : gimana
# hai : hai
# rismawati : rismawati
# jaringannya : jaring
# pemeliharaan : pelihara
# penanganan : tangan
# tim : tim
# upayakan : upaya
# koneksinya : koneksi
# normal : normal
# chat : chat
# kukira : kira
# doang : doang
# hiiih : hiiih
# gemash : gemash
# dibayar : bayar
# lemot : lot
# restart : restart
# modemnya : modem
# ngusik : ngusik
# ketenangan : tenang
# hidupku : hidup
# subuh : subuh
# yaaa : yaaa
# trouble : trouble
# ckckck : ckckck
# keluhan : keluh
# koneksi : koneksi
# dirumah : rumah
# landing : landing
# page : page
# muncul : muncul
# lampu : lampu
# indikator : indikator
# nyala : nyala
# bantuannya : bantu
# trimakasih : trimakasih
# harap : harap
# bersabar : sabar
# biasalah : biasa
# febri : febri
# panca : panca
# kudo : kudo
# hiiihh : hiiihh
# down : down
# sbntr : sbntr
# baca : baca
# dude : dude
# idk : idk
# but : but
# your : your
# connection : connection
# definitely : definitely
# not : not
# jul : jul
# dibantu : bantu
# udab : udab
# responnya : responnya
# kampung : kampung
# halloo : halloo
# sampe : sampe
# segini : gin
# masi : mas
# samaaa : samaaa
# btw : btw
# serang : serang
# wkwkw : wkwkw
# teman : teman
# kaya : kaya
# setan : setan
# golongan : golong
# paket : paket
# tersedia : sedia
# kunjungi : kunjung
# web : web
# resmi : resmi
# gerry : gerry
# ferdi : ferdi
# informasikan : informasi
# only : only
# kecepatan : cepat
# mbps : mbps
# seratus : ratus
# detail : detail
# buffer : buffer
# muuuluu : muuuluu
# drikemarin : drikemarin
# trus : trus
# msih : msih
# ngelagg : ngelagg
# derri : derri
# ketidaknyamannya : ketidaknyamannya
# maintenance : maintenance
# diupayakan : upaya
# tersolusikan : solusi
# berupaya : upaya
# meningkatkan : tingkat
# pelayanan : layan
# anip : anip
# fahrel : fahrel
# packet : packet
# lossnya : lossnya
# knp : knp
# diinfokan : info
# berkali : kali
# dibilangin : dibilangin
# pelanggan : langgan
# hrs : hrs
# mimin : mimin
# lengkap : lengkap
# ketersediaan : sedia
# thanks : thanks
# hdr : hdr
# dilokasi : lokasi
# mainteance : mainteance
# secepatnya : cepat
# ditunggu : tunggu
# informasi : informasi
# update : update
# selanjut : lanjut
# woiiii : woiiii
# heh : heh
# ngapa : ngapa
# muter : muter
# make : make
# sinyalnya : sinyal
# ngeselin : ngeselin
# deh : deh
# gemes : gemes
# cubit : cubit
# minnn : minnn
# lola : lola
# nihh : nihh
# dicekk : dicekk
# parah : parah
# nyetel : nyetel
# spotify : spotify
# lemottt : lemottt
# gakuat : gakuat
# streaming : streaming
# youtube : youtube
# kalah : kalah
# provider : provider
# terkenal : kenal
# murah : murah
# susah : susah
# sinyal : sinyal
# mlah : mlah
# rizky : rizky
# menjaga : jaga
# privasi : privasi
# data : data
# verifikasi : verifikasi
# nama : nama
# simpati : simpati
# signal : signal
# speed : speed
# blm : blm
# direspond : direspond
# mantap : mantap
# benci : benci
# gshanan : gshanan
# wkwkwkwkwkwkwk : wkwkwkwkwkwkwk
# opini : opini
# router : router
# malam : malam
# ngajak : ngajak
# ribut : ribut
# cacat : cacat
# ponsel : ponsel
# aktif : aktif
# sobat : sobat
# enak : enak
# panggil : panggil
# salah : salah
# penyebab : sebab
# lambat : lambat
# device : device
# terhubung : hubung
# melebihi : lebih
# batas : batas
# pemakaian : pakai
# menindaklanjuti : menindaklanjuti
# laporanny : laporanny
# puasa : puasa
# ngomong : ngomong
# kasar : kasar
# berlaku : laku
# alias : alias
# anjing : anjing
# woy : woy
# mas : mas
# eror : eror
# mulu : mulu
# masssss : masssss
# bangsttttt : bangsttttt
# tiada : tiada
# erorr : erorr
# hahhh : hahhh
# fakyu : fakyu
# fak : fak
# air : air
# daerah : daerah
# gabisa : gabisa
# irish : irish
# kare : kare
# wilayah : wilayah
# mai : mai
# nira : nira
# penyabab : penyabab
# akti : akti
# sesungguhnya : sungguh
# orang : orang
# banget : banget
# temen : temen
# urgent : urgent
# quest : quest
# rampage : rampage
# ber : ber
# pas : pas
# bleep : bleep
# discord : discord
# keputus : putus
# modar : modar
# hub : hub
# kampret : kampret
# emg : emg
# untung : untung
# kelar : kelar
# dpt : dpt
# mantapp : mantapp
# indonesia : indonesia
# kont : kont
# nunggu : nunggu
# yuda : yuda
# pengaduan : adu
# langsung : langsung
# ika : ika
# lakukan : laku
# nomer : nomer
# ditangani : tangan
# kbps : kbps
# fadli : fadli
# iqbal : iqbal
# kondisi : kondisi
# langkah : langkah
# sisi : sisi
# sentral : sentral
# progres : progres
# coba : coba
# emang : emang
# kebiasaan : biasa
# tolol : tolol
# gaada : gaada
# melawak : lawak
# yourbaey : yourbaey
# gue : gue
# belom : bom
# kali : kali
# yakan : yakan
# kannn : kannn
# jaringanya : jaringanya
# putus : putus
# maen : maen
# game : game
# oke : oke
# mba : mba
# firda : firda
# nonton : nonton
# close : close
# the : the
# door : door
# tri : tri
# koordinasikan : koordinasi
# ketidaknyamananya : ketidaknyamananya
# jelek : jelek
# fahmi : fahmi
# wija : wija
# catuan : catu
# listrik : listrik
# sesuai : sesuai
# pastikan : pasti
# menyala : nyala
# klik : klik
# link : link
# terimakasih : terimakasih
# joshua : joshua
# uda : uda
# deng : deng
# makasi : makas
# yaks : yaks
# wkwkwkwkwk : wkwkwkwkwk
# sopan : sopan
# trust : trust
# ilang : ilang
# bih : bih
# doru : doru
# jongie : jongie
# satunya : satu
# disebabkan : sebab
# suhu : suhu
# pengecekkan : ecek
# suka : suka
# gangguan : ganggu
# hadeh : hadeh
# hujan : hujan
# trs : trs
# jane : jane
# koordinasi : koordinasi
# tindaklanjuti : tindaklanjuti
# disolusikan : solusi
# him : him
# napa : napa
# ngab : ngab
# metong : metong
# butuhin : butuhin
# wey : wey
# tindak : tindak
# maintance : maintance
# terosss : terosss
# wkwkwkw : wkwkwkw
# marah : marah
# marahnya : marah
# mentionnya : mentionnya
# asiiaappp : asiiaappp
# sung : sung
# damario : damario
# dirasa : rasa
# kendala : kendala
# customer : customer
# service : service
# terimakasihh : terimakasihh
# kibo : kibo
# hadeeeehhh : hadeeeehhh
# war : war
# afk : afk
# beneeeerr : beneeeerr
# kacau : kacau
# ngerjain : ngerjain
# tugas : tugas
# beribu : ibu
# ribu : ribu
# call : call
# center : center
# tlp : tlp
# pembenahan : benah
# turun : turun
# lapangan : lapang
# berbuat : buat
# lgi : lgi
# kmue : kmue
# mniezz : mniezz
# tahap : tahap
# estimasi : estimasi
# terhitung : hitung
# cepat : cepat
# rafly : rafly
# indihomecare : indihomecare
# baim : baim
# icha : icha
# akhiran : akhir
# terputus : putus
# mengupayakan : upaya
# diselesaikan : selesai
# nurul : nurul
# terkena : kena
# dampak : dampak
# lokasinya : lokasi
# indihom : indihom
# besok : besok
# siii : siii
# pekerjaan : kerja
# gajetot : gajetot
# ngaa : ngaa
# jarang : jarang
# omecare : omecare
# zasqi : zasqi
# berakhiran : akhir
# dlm : dlm
# evi : evi
# syam : syam
# ahmad : ahmad
# natsu : natsu
# cipto : cipto
# optimal : optimal
# aktifnya : aktif
# tunggu : tunggu
# ganannya : ganannya
# ansyah : ansyah
# statusnya : status
# progress : progress
# memaksimalkan : maksimal
# penan : pen
# dihomecare : dihomecare
# sesi : sesi
# konfirmasi : konfirmasi
# fahrurozy : fahrurozy
# meneruskan : terus
# alami : alami
# ter : ter
# reja : reja
# respon : respon
# clarta : clarta
# sif : sif
# dmnya : dmnya
# permintaannya : minta
# emailnya : email
# itjantik : itjantik
# tsb : tsb
# ungi : ungi
# wisnu : wisnu
# dimz : dimz
# menghub : menghub
# kontol : kontol
# ditambah : tambah
# duo : duo
# nikmati : nikmat
# kepedihanmu : pedih
# kmu : kmu
# knapa : knapa
# gajelas : gajelas
# ketidak : tidak
# nyamanannya : nyaman
# ulang : ulang
# doakan : doa
# kantor : kantor
# vania : vania
# triya : triya
# penangan : nang
# rezki : rezki
# kilua : kilua
# konfirmasinya : konfirmasi
# compe : compe
# makasih : makasih
# berulah : ulah
# tbtb : tbtb
# classic : classic
# koo : koo
# direspon : direspon
# pakeeet : pakeeet
# ngejambak : ngejambak
# jambak : jambak
# regar : regar
# amalia : amalia
# jleg : jleg
# goblok : goblok
# rbu : rbu
# kualitas : kualitas
# buruk : buruk
# centre : centre
# pokoknya : pokok
# sales : sales
# abaikan : abai
# bicara : bicara
# manis : manis
# kenyataan : nyata
# pahit : pahit
# everyone : everyone
# who : who
# use : use
# does : does
# always : always
# fucked : fucked
# night : night
# just : just
# bapuk : bapuk
# mlm : mlm
# dewa : dewa
# kedepan : depan
# multazam : multazam
# ahda : ahda
# indigo : indigo
# setahun : tahun
# sebel : sebel
# cuman : cuman
# plesetan : plesetan
# weh : weh
# gua : gua
# ngerank : ngerank
# mlu : mlu
# arief : arief
# meengenai : meengenai
# tindaklanjut : tindaklanjut
# richi : richi
# masuk : masuk
# kumat : kumat
# gelut : gelut
# yee : yee
# rayhan : rayhan
# mengganggu : ganggu
# aktivitas : aktivitas
# unt : unt
# jalur : jalur
# watsap : watsap
# orion : orion
# bayarnya : bayar
# bengkak : bengkak
# sampah : sampah
# pasang : pasang
# kecewa : kecewa
# ngeliat : ngeliat
# penampakan : tampak
# mention : mention
# slow : slow
# arditya : arditya
# ingan : ingan
# ngentot : ngentot
# emosi : emosi
# wahyu : wahyu
# jar : jar
# gifari : gifari
# naktifkan : naktifkan
# abizar : abizar
# keluhannya : keluh
# temperatur : temperatur
# tesebut : tesebut
# menyebabkan : sebab
# meno : meno
# cape : cape
# sma : sma
# giliran : gilir
# reminder : reminder
# getol : getol
# busuk : busuk
# ngirim : ngirim
# minn : minn
# deadline : deadline
# soalnyaa : soalnyaa
# astagfirullah : astagfirullah
# nyebut : nyebut
# julie : julie
# seputar : putar
# menyertakan : serta
# fadel : fadel
# monggo : monggo
# nii : nii
# kenapaa : kenapaa
# emng : emng
# disuruh : suruh
# tidur : tidur
# kyanya : kyanya
# domisili : domisili
# jakarta : jakarta
# kah : kah
# yak : yak
# mbak : mbak
# dipersilahkan : silah
# sepuasnya : puas
# adminnya : adminnya
# main : main
# sempet : sempet
# dipake : dipake
# mmm : mmm
# ner : ner
# ingfo : ingfo
# bang : bang
# vikiet : vikiet
# alah : alah
# kejar : kejar
# knpa : knpa
# cahyaranie : cahyaranie
# disarankan : saran
# mengistirahatkan : istirahat
# nyalakan : nyala
# hobi : hobi
# heran : heran
# suruh : suruh
# jualan : jual
# kerupuk : kerupuk
# pasir : pasir
# ngelag : ngelag
# kmrn : kmrn
# sdg : sdg
# gada : gada
# namanya : nama
# jaya : jaya
# jiwa : jiwa
# pler : pler
# punten : punten
# ngerjar : ngerjar
# budi : budi
# spesifikan : spesifik
# myih : myih
# sat : sat
# thank : thank
# you : you
# buffering : buffering
# kaga : kaga
# klk : klk
# geng : geng
# matii : mati
# dahhhh : dahhhh
# inet : inet
# yaaaa : yaaaa
# akutuh : akutuh
# ngadepin : ngadepin
# permisiiiii : permisiiiii
# ngentoooooooodddddd : ngentoooooooodddddd
# tol : tol
# buka : buka
# otomatis : otomatis
# kevin : kevin
# meldi : meldi
# menindak : tindak
# lanjuti : lanjut
# bau : bau
# anjrit : anjrit
# nge : nge
# valo : valo
# blom : blom
# pick : pick
# agentnya : agentnya
# plis : plis
# loss : loss
# merah : merah
# pffttt : pffttt
# tydac : tydac
# akal : akal
# kebanyakan : banyak
# troll : troll
# eyi : eyi
# kartu : kartu
# perdanalaaaah : perdanalaaaah
# ngedeadline : ngedeadline
# reconnect : reconnect
# end : end
# hubungan : hubung
# ajg : ajg
# ping : ping
# cok : cok
# nie : nie
# bodo : bodo
# berhenti : henti
# langganan : langgan
# jelass : jelass
# rugi : rugi
# ribet : ribet
# pakai : pakai
# josss : josss
# bngt : bngt
# datanya : data
# kenyamanan : nyaman
# privas : privas
# haris : haris
# layanannya : layan
# status : status
# ont : ont
# dying : dying
# gasp : gasp
# menunjukan : tunjuk
# perangkat : perangkat
# lepas : lepas
# adapter : adapter
# yaoshi : yaoshi
# restu : restu
# ceuk : ceuk
# aing : aing
# mayar : mayar
# lar : lar
# drakor : drakor
# lemotmotmot : lemotmotmot
# loading : loading
# samsekk : samsekk
# hehehehhehe : hehehehhehe
# risca : risca
# amond : amond
# astaga : astaga
# nangis : nang
# downloadnya : downloadnya
# upload : upload
# beserta : serta
# telp : telp
# kirim : kirim
# maunya : mau
# minimal : minimal
# itupun : itu
# lemotnya : lot
# aca : aca
# los : los
# patch : patch
# cord : cord
# terpasang : pasang
# rapiin : rapiin
# moment : moment
# keubah : ubah
# tujuan : tuju
# santet : santet
# farel : farel
# tersambung : sambung
# ngepres : ngepres
# skripsi : skripsi
# haloo : haloo
# costumer : costumer
# jngn : jngn
# lupa : lupa
# reset : reset
# sigj : sigj
# madina : madina
# prosesnya : proses
# petugas : tugas
# nda : nda
# jutnya : jutnya
# yuika : yuika
# selan : selan
# rese : rese
# love : love
# ayok : ayok
# aneh : aneh
# heheh : heheh
# rasyid : rasyid
# ronald : ronald
# pengaduannya : adu
# follow : follow
# maju : maju
# beres : beres
# urusan : urus
# ampe : ampe
# mampus : mampus
# reply : reply
# postingan : postingan
# loe : loe
# yeee : yeee
# profesional : profesional
# pade : pade
# makan : makan
# gaji : gaji
# buta : buta
# tlg : tlg
# diberesin : resin
# berguna : guna
# lapor : lapor
# diproses : proses
# maros : maros
# pelayanannya : layan
# gitu : gitu
# dech : dech
# khusus : khusus
# tjukup : tjukup
# yuk : yuk
# opose : opose
# ampas : ampas
# najonk : najonk
# heuh : heuh
# nct : nct
# informasinya : informasi
# produk : produk
# kerahasiaan : rahasia
# terkendala : kendala
# hapus : hapus
# berdasarkan : dasar
# berwarna : warna
# hitam : hitam
# kuning : kuning
# ujung : ujung
# biru : biru
# kampang : kampang
# natasya : natasya
# bersedia : sedia
# progressnya : progressnya
# ice : ice
# pelaggan : pelaggan
# memilik : milik
# sebelah : belah
# diapain : diapain
# penayangan : tayang
# korea : korea
# gede : gede
# subtitle : subtitle
# tvn : tvn
# asia : asia
# viu : viu
# hmm : hmm
# kbs : kbs
# vlive : vlive
# special : special
# hahaha : hahaha
# beb : beb
# nguji : nguji
# kesabaran : sabar
# anhar : anhar
# babi : babi
# pelangga : pelangga
# check : check
# capek : capek
# kesal : kesal
# novanda : novanda
# penggunaan : guna
# wajar : wajar
# fup : fup
# kecepatannya : cepat
# diturunkan : turun
# sil : sil
# minggu : minggu
# hadeuh : hadeuh
# onlinenya : onlinenya
# gapake : gapake
# grogol : grogol
# limo : limo
# pon : pon
# kakk : kakk
# demand : demand
# taehyung : taehyung
# keknya : kek
# intuisi : intuisi
# kuat : kuat
# perasaan : asa
# ngomongin : ngomongin
# malaikat : malaikat
# nunjuk : nunjuk
# langit : langit
# liat : liat
# sampek : sampek
# ojok : ojok
# anak : anak
# tulung : tulung
# bos : bos
# atuhlah : atuhlah
# euy : euy
# gilasih : gilasih
# genshin : genshin
# lappys : lappys
# ayo : ayo
# semangat : semangat
# diteruskan : terus
# tter : tter
# zimi : zimi
# alcaca : alcaca
# laporan : lapor
# faktor : faktor
# redaman : redam
# inbox : inbox
# terbaru : baru
# ecek : ecek
# bodoh : bodoh
# bget : bget
# mabok : mabok
# bales : bales
# jual : jual
# beli : beli
# sbntar : sbntar
# rusan : rusan
# pnh : pnh
# habis : habis
# tlong : tlong
# jelasin : jelasin
# hubungannya : hubung
# lho : lho
# dpet : dpet
# fiber : fiber
# meter : meter
# kasi : kasi
# server : server
# pny : pny
# otak : otak
# umak : umak
# saluran : salur
# ngga : ngga
# yaa : yaa
# berapaaa : berapaaa
# digonceng : digonceng
# celot : celot
# dalan : dal
# delok : dok
# opoan : opoan
# akhire : akhire
# akeh : akeh
# merem : merem
# wedian : wedian
# adan : adan
# yaallah : yaallah
# semoga : moga
# dapet : dapet
# kursi : kursi
# utbk : utbk
# universitas : universitas
# lemotttt : lemotttt
# kerjasama : kerjasama
# lof : lof
# yuuuuu : yuuuuu
# membaca : baca
# aman : aman
# wayv : wayv
# pertanyaannya : tanya
# abang : abang
# travel : travel
# rda : rda
# nanganan : nanganan
# zoy : zoy
# hubung : hubung
# optimum : optimum
# mengurangi : kurang
# hshsh : hshsh
# heng : heng
# abis : abis
# nugas : nugas
# beraturan : atur
# sii : sii
# internal : internal
# kautsar : tsar
# kau : kau
# tokyo : tokyo
# aib : aib
# kekirim : kirim
# mahal : mahal
# lelet : lelet
# harga : harga
# terbuka : buka
# rb : rb
# ngakalin : ngakalin
# ancrooit : ancrooit
# ytube : ytube
# hype : hype
# njaluk : njaluk
# gelot : got
# seleraku : selera
# hahay : hahay
# iye : iye
# buruan : buru
# urusin : urusin
# fyi : fyi
# pilihan : pilih
# katro : katro
# protes : protes
# dek : dek
# dibilang : bilang
# pemadaman : madam
# pengguna : guna
# gatau : gatau
# download : download
# minim : minim
# wkwkwk : wkwkwk
# ndihomecare : ndihomecare
# roger : roger
# dibukakan : buka
# isolirnya : isolir
# hubungkan : hubung
# embali : embal
# hamid : hamid
# ketidaknyamanan : ketidaknyamanan
# tiket : tiket
# isro : isro
# prihal : prihal
# core : core
# tertancap : tancap
# kencang : kencang
# anjggggg : anjggggg
# ngapasi : ngapasi
# bat : bat
# destaria : destaria
# permintaan : minta
# dahhh : dahhh
# anjirrr : anjirrr
# macet : macet
# yoongi : yoongi
# jimin : jimin
# dee : dee
# gda : gda
# mmrah : mmrah
# bryan : bryan
# diinformasikan : informasi
# parahhh : parahhh
# neh : neh
# denda : denda
# disuspend : disuspend
# kaccauuuuuuu : kaccauuuuuuu
# selasai : selasa
# ditinggal : tinggal
# kerjain : kerjain
# haloooooo : haloooooo
# tolonggggg : tolonggggg
# kapasitas : kapasitas
# klw : klw
# trims : trims
# maulan : maulan
# hutaman : hutaman
# trobel : trobel
# jdi : jdi
# gatauuu : gatauuu
# isi : isi
# pulsa : pulsa
# atoga : atoga
# ketemuu : ketemuu
# jumping : jumping
# ngepush : ngepush
# biznet : biznet
# komplek : komplek
# bangke : bangke
# browser : browser
# resolusi : resolusi
# ketampanan : tampan
# suamiku : suami
# memancar : pancar
# terhalang : halang
# dahlah : dah
# brooi : brooi
# siang : siang
# smpe : smpe
# rora : rora
# ajarin : ajarin
# lekas : lekas
# membaik : baik
# sod : sod
# fixed : fixed
# batal : batal
# dana : dana
# refund : refund
# diterima : terima
# dompet : dompet
# woi : woi
# gembel : gembel
# waler : waler
# nuhun : nuhun
# kannya : kan
# nasya : nasya
# mengakibatkan : akibat
# diakses : akses
# perbai : perbai
# sharelok : sharelok
# ngajakin : ngajakin
# mabar : mabar
# bersahabt : bersahabt
# astaghfirullah : astaghfirullah
# meeting : meeting
# bouz : bouz
# gmn : gmn
# tanggapan : tanggap
# komplenan : komplenan
# lemottttttt : lemottttttt
# wawan : wawan
# nugro : nugro
# ade : ade
# in : in
# terakhirnya : akhir
# myindihome : myindihome
# login : login
# aplikasi : aplikasi
# saldo : saldo
# cari : cari
# korban : korban
# teai : teai
# penipu : tipu
# irawati : irawati
# kirimkan : kirim
# capture : capture
# tampilan : tampil
# tvnya : tvnya
# gory : gory
# bad : bad
# fix : fix
# shit : shit
# user : user
# kambing : kambing
# jarak : jarak
# perbulan : bulan
# speednya : speednya
# brp : brp
# serius : serius
# pending : pending
# guee : guee
# apat : apat
# commentnya : commentnya
# bersifat : sifat
# pribadi : pribadi
# ban : ban
# speedy : speedy
# payah : payah
# please : please
# thx : thx
# rain : rain
# dokter : dokter
# forensik : forensik
# org : org
# november : november
# nur : nur
# laporkan : lapor
# ghubungi : ghubungi
# stikan : stik
# secepat : cepat
# kedepannya : depan
# men : men
# feb : feb
# berdampak : dampak
# ringannya : ringan
# nanu : nanu
# dilaporkan : lapor
# dibutuhkan : butuh
# dihubungi : hubung
# handphone : handphone
# maksud : maksud
# konfirmasikan : konfirmasi
# pln : pln
# indnsia : indnsia
# sya : sya
# dsni : dsni
# sbg : sbg
# msyrkt : msyrkt
# ckp : ckp
# resah : resah
# polusi : polusi
# numpng : numpng
# tiang : tiang
# mrk : mrk
# bbrp : bbrp
# kli : kli
# tarik : tarik
# mnarik : mnarik
# psng : psng
# memasng : memasng
# bnyk : bnyk
# mnurut : mnurut
# shnga : shnga
# memtskn : memtskn
# scra : scra
# official : official
# rsmi : rsmi
# itpun : itpun
# skali : skali
# bgmn : bgmn
# tnggpn : tnggpn
# tntng : tntng
# kbel : kbel
# rima : rima
# dusun : dusun
# bontobiraeng : bontobiraeng
# desa : desa
# panakkukang : panakkukang
# kec : kec
# pallang : pallang
# kab : kab
# gowa : gowa
# tercover : tercover
# optik : optik
# pemerataan : perata
# sungguh : sungguh
# mlarat : mlarat
# ambil : ambil
# tgl : tgl
# skrg : skrg
# bukti : bukti
# bni : bni
# diemail : email
# manaaaa : manaaaa
# gajadi : gajadi
# balikin : balikin
# duit : duit
# udh : udh
# cekkin : cekkin
# konsultasi : konsultasi
# naikin : naikin
# lamban : lamban
# anying : anying
# daritadi : daritadi
# maraaahhhh : maraaahhhh
# haeh : haeh
# tele : tele
# gasss : gasss
# antu : antu
# devs : devs
# jeje : jeje
# haltersebut : haltersebut
# situs : situs
# media : media
# melanjutkan : lanjut
# interkasinya : interkasinya
# rrrrer : rrrrer
# perumahan : rumah
# mengajukan : aju
# syaratnya : syarat
# kapok : kapok
# apasi : apas
# ait : ait
# rifai : rifai
# pemilik : milik
# diatas : atas
# terk : terk
# channel : channel
# available : available
# indibox : indibox
# have : have
# excuse : excuse
# yoga : yoga
# with : with
# caitlyn : caitlyn
# turner : turner
# bliss : bliss
# cooking : cooking
# fave : fave
# indonesian : indonesian
# cuisine : cuisine
# winnie : winnie
# foodiepedia : foodiepedia
# leb : leb
# riyendi : riyendi
# teluk : teluk
# kenidai : kenidai
# connect : connect
# dialami : alami
# traffic : traffic
# dinding : dinding
# cipa : cipa
# digit : digit
# sumpa : sumpa
# janji : janji
# dateng : dateng
# benerin : benerin
# kedengeran : kedengeran
# suara : suara
# sepatunya : sepatu
# dusunku : dusun
# blum : blum
# box : box
# puluhan : puluh
# reka : reka
# tonton : tonton
# disesuaikan : sesuai
# pengelola : kelola
# wtf : wtf
# isna : isna
# upgrade : upgrade
# anyg : anyg
# melengkapi : lengkap
# terimakasi : terimakasi
# faruk : faruk
# tindaklanjutnya : tindaklanjutnya
# wal : wal
# patchcord : patchcord
# berbunyi : bunyi
# terkoneksi : koneksi
# terindikasi : indikasi
# kawatir : kawatir
# twt : twt
# alu : alu
# gba : gba
# load : load
# ayu : ayu
# mempermudah : mudah
# unsur : unsur
# terjaga : jaga
# cuy : cuy
# idlix : idlix
# pdhl : pdhl
# gpp : gpp
# byr : byr
# longtime : longtime
# see : see
# mengenaliku : kenal
# nontonnya : nontonnya
# pls : pls
# mengembalikan : kembali
# anggita : anggita
# indikasi : indikasi
# over : over
# heat : heat
# kinerja : kerja
# oik : oik
# lumayan : lumayan
# subnya : sub
# dikit : dikit
# samanya : sama
# bela : bela
# belain : bain
# cepet : cepet
# let : let
# bts : bts
# elah : elah
# bgtttttt : bgtttttt
# crash : crash
# world : world
# lol : lol
# lololol : lololol
# ntar : ntar
# sumpah : sumpah
# pengen : ken
# ngebucin : ngebucin
# canda : canda
# maksudnya : maksud
# belajar : ajar
# dibetulin : dibetulin
# seminggu : minggu
# jancok : jancok
# hasan : hasan
# solved : solved
# nntn : nntn
# relosuli : relosuli
# kyk : kyk
# nice : nice
# bingung : bingung
# sihhhh : sihhhh
# curiga : curiga
# tetangga : tetangga
# bobol : bobol
# sedipakenya : sedipakenya
# apapun : apa
# ditag : ditag
# first : first
# wuswus : wuswus
# rebu : rebu
# dri : dri
# tdi : tdi
# nye : nye
# fuck : fuck
# dicky : dicky
# huhu : huhu
# jia : jia
# knpasiii : knpasiii
# jamil : jamil
# dahla : dahla
# kentang : kentang
# sandra : sandra
# memiliki : milik
# detailnya : detail
# kasian : kasi
# kgk : kgk
# acara : acara
# siaran : siar
# lag : lag
# anjgggg : anjgggg
# apasih : apasih
# oxygen : oxygen
# tanggapannya : tanggap
# goodday : goodday
# ugh : ugh
# sertakan : serta
# jerniah : jerniah
# bangett : bangett
# sayang : sayang
# bangtan : bangtan
# sna : sna
# dapatkan : dapat
# phonix : phonix
# bonus : bonus
# nelpon : nelpon
# daftar : daftar
# pengulangan : ulang
# kesel : kesel
# lampung : lampung
# istg : istg
# hate : hate
# asjsjsjsj : asjsjsjsj
# disuspen : disuspen
# kena : kena
# pketan : pketan
# nyink : nyink
# jlek : jlek
# dmi : dmi
# taiiiiiiiii : taiiiiiiiii
# ngamuk : ngamuk
# under : under
# bed : bed
# settings : settings
# password : password
# samaa : samaa
# anjingin : anjingin
# mah : mah
# alamatnye : alamatnye
# ditindaklanjuti : ditindaklanjuti
# nomo : nomo
# keselll : keselll
# kesayangan : sayang
# samaaaa : samaaaa
# ala : ala
# siiih : siiih
# melulu : melulu
# dipasang : pasang
# tiangnya : tiang
# beudh : beudh
# gan : gan
# kayanya : kaya
# perbaikannya : baik
# dimaksimalkan : maksimal
# han : han
# menghapus : hapus
# postingannya : postingannya
# kerahasian : kerahasian
# ditung : tung
# rumahku : rumah
# lemotttttt : lemotttttt
# tembus : tembus
# translet : translet
# bangsat : bangsat
# donggg : donggg
# woeee : woeee
# rii : rii
# lelett : lelett
# jan : jan
# ngadi : ngadi
# app : app
# ngecrash : ngecrash
# teruntuk : untuk
# jejsjwjsjsjs : jejsjwjsjsjs
# mengeluh : keluh
# routernya : routernya
# alhamdulillah : alhamdulillah
# nemu : nemu
# huhuhu : huhuhu
# donlot : donlot
# kayaknya : kayak
# anjinggg : anjinggg
# asli : asli
# bangetlah : banget
# pacaran : pacar
# wifinya : wifinya
# mood : mood
# nnton : nnton
# babget : babget
# nambah : nambah
# beban : beban
# pikiran : pikir
# akdjakjsa : akdjakjsa
# stress : stress
# anjrittt : anjrittt
# gaush : gaush
# gelud : gelud
# plislah : plislah
# udahan : udahan
# juara : juara
# dha : dha
# asik : asik
# disaat : saat
# tereset : tereset
# bulannya : bulan
# melambat : lambat
# membeli : beli
# add : add
# renew : renew
# devi : devi
# ica : ica
# yaallan : yaallan
# sepenuh : sepenuh
# telkomsel : telkomsel
# katain : katain
# bgtlu : bgtlu
# hgt : hgt
# bsk : bsk
# bljr : bljr
# meant : meant
# dibales : dibales
# paham : paham
# kelas : kelas
# ajak : ajak
# promo : promo
# pke : pke
# wkakakakak : wkakakakak
# teknisinya : teknisi
# sms : sms
# butuh : butuh
# belun : bun
# ayook : ayook
# ksian : ksi
# lihat : lihat
# jga : jga
# mikir : mikir
# fuckin : fuckin
# plsss : plsss
# ily : ily
# wanna : wanna
# fight : fight
# huh : huh
# tired : tired
# kuota : kuota
# percaya : percaya
# rmal : rmal
# kura : kura
# amt : amt
# ccccccccccccccccc : ccccccccccccccccc
# normaaaaaal : normaaaaaal
# kolaborasi : kolaborasi
# lia : lia
# akin : akin
# cover : cover
# bsajldwscnjds : bsajldwscnjds
# firstmedia : firstmedia
# area : area
# zam : zam
# zum : zum
# wasu : wasu
# diketawain : diketawain
# xixixi : xixixi
# lagu : lagu
# ilangan : ilangan
# teruss : teruss
# hmmm : hmmm
# hermawan : hermawan
# sidik : sidik
# beralih : alih
# iris : iris
# alui : alu
# jadwal : jadwal
# sore : sore
# mel : mel
# dmynti : dmynti
# elfin : elfin
# diconfig : diconfig
# mengalami : alami
# troy : troy
# micasaa : micasaa
# kwkwkw : kwkwkw
# otakmu : otak
# tolooongggg : tolooongggg
# bulanan : bulan
# kuuuuuuuuuuu : kuuuuuuuuuuu
# kubayar : bayar
# engkaauuuu : engkaauuuu
# gajikuuuuuuuuuuu : gajikuuuuuuuuuuu
# this : this
# much : much
# menyedihkan : sedih
# spa : spa
# disni : disni
# citacitanya : citacitanya
# naoki : naoki
# teleponnya : telepon
# memanggil : panggil
# dipanggil : panggil
# nada : nada
# robot : robot
# perubahan : ubah
# ujungnya : ujung
# longgar : longgar
# done : done
# ikutan : ikut
# cezh : cezh
# uluq : uluq
# sophie : sophie
# casambro : casambro
# casambrow : casambrow
# bone : bone
# udeh : udeh
# akrab : akrab
# niiiih : niiiih
# diajak : ajak
# kelasnya : kelas
# nanya : nanya
# care : care
# dida : dida
# dilanjutkan : lanjut
# diakun : akun
# isp : isp
# softreboot : softreboot
# hardreboot : hardreboot
# mesti : mesti
# gimn : gimn
# ceuceu : ceuceu
# er : er
# mpuy : mpuy
# wirawan : wirawan
# abdul : abdul
# photo : photo
# ane : ane
# jamin : jamin
# wkwkkwkw : wkwkkwkw
# manusia : manusia
# panci : panci
# ding : ding
# indomie : indomie
# nyari : nyari
# yaudah : yaudah
# ronal : ronal
# mendekati : dekat
# kayak : kayak
# indomy : indomy
# tayangkan : tayang
# talk : talk
# show : show
# wib : wib
# kemaren : kemaren
# petir : petir
# deket : deket
# gmna : gmna
# benerinnya : benerinnya
# berlangganan : langgan
# susahny : susahny
# nak : nak
# fms : fms
# fred : fred
# apri : apri
# infokan : info
# vidio : vidio
# wae : wae
# aji : aji
# bel : bel
# kyknya : kyknya
# dicolokan : colok
# astagaa : astagaa
# jalan : jalan
# aufa : aufa
# ragu : ragu
# stay : stay
# safe : safe
# too : too
# ohh : ohh
# pencerahan : cerah
# ukey : ukey
# hr : hr
# ngadu : ngadu
# ngabisin : ngabisin
# solusinya : solusi
# perbaiki : baik
# haduhh : haduhh
# alesannya : alesannya
# gantiiii : gantiiii
# kujuga : juga
# gantiii : gantiii
# merahnya : merah
# esme : esme
# such : such
# joke : joke
# jaringa : jaringa
# agus : agus
# supriadi : supriadi
# kedip : kedip
# nder : nder
# unlimited : unlimited
# disana : sana
# responsif : responsif
# nugra : nugra
# positif : positif
# thinking : thinking
# fotonya : foto
# remuuk : remuuk
# anjg : anjg
# gtu : gtu
# narik : narik
# lamaaaak : lamaaaak
# seharian : hari
# niat : niat
# uang : uang
# dikemanain : dikemanain
# komplain : komplain
# ditelepon : telepon
# gimanasih : gimanasih
# christian : christian
# lengkapnya : lengkap
# lagii : lagi
# tumbeenn : tumbeenn
# leleeeettt : leleeeettt
# solusi : solusi
# permasalahan : masalah
# idup : idup
# gaa : gaa
# kotak : kotak
# koq : koq
# dipelajari : ajar
# kindly : kindly
# informasian : informasi
# teh : teh
# kagak : kagak
# kemana : mana
# gws : gws
# for : for
# jempol : jempol
# and : and
# nanad : nanad
# pembelian : beli
# minipack : minipack
# merubah : rubah
# gila : gila
# gtau : gtau
# broo : broo
# astga : astga
# gmba : gmba
# njirr : njirr
# helen : helen
# mengatahui : mengatahui
# rogress : rogress
# penanganann : penanganann
# membutuhkan : butuh
# pengembalian : kembali
# jaminan : jamin
# dikirim : kirim
# allahuakbar : allahuakbar
# ngereset : ngereset
# perubahannya : ubah
# ditindak : tindak
# hatipun : hati
# senang : senang
# shan : shan
# amin : amin
# gaje : gaje
# bet : bet
# dibenerin : dibenerin
# semog : semog
# gara : gara
# qomara : qomara
# nannya : nan
# penanga : penanga
# naver : naver
# now : now
# engak : engak
# nissa : nissa
# arif : arif
# sosial : sosial
# kepenuhan : penuh
# sedih : sedih
# kurniasari : kurniasari
# kiki : kiki
# nyindir : nyindir
# nana : nana
# positip : positip
# thingking : thingking
# ngadat : ngadat
# indiho : indiho
# dimatikan : mati
# diam : diam
# csnya : csnya
# balas : balas
# doi : doi
# belajr : belajr
# website : website
# maksimalnya : maksimal
# penanganannya : tangan
# ima : ima
# ive : ive
# tried : tried
# bothhh : bothhh
# sblmnya : sblmnya
# besoknya : besok
# berhari : hari
# ahahha : ahahha
# bnget : bnget
# rep : rep
# bosss : bosss
# jumat : jumat
# rto : rto
# same : same
# heree : heree
# sounds : sounds
# worse : worse
# krista : krista
# bund : bund
# pacarku : pacar
# postan : postan
# ngeblur : ngeblur
# saking : saking
# ichsan : ichsan
# rungsing : rungsing
# terhormat : hormat
# rapnya : rap
# mark : mark
# mad : mad
# city : city
# andi : andi
# penelusuran : telusur
# berjalan : jalan
# dll : dll
# seriusan : serius
# sebenernya : sebenernya
# sekalinya : sekali
# aduh : aduh
# maul : maul
# solusikan : solusi
# kepake : kepake
# dipakein : dipakein
# butek : butek
# dasarnya : dasar
# taugasi : taugasi
# frustasi : frustasi
# eum : eum
# moots : moots
# riskha : riskha
# instagram : instagram
# matiin : matiin
# jyalain : jyalain
# frs : frs
# remote : remote
# perganti : ganti
# batterai : batterai
# raya : raya
# warganya : warga
# oalah : oalah
# ajar : ajar
# knpsi : knpsi
# ujan : ujan
# membayar : bayar
# mbanking : mbanking
# bca : bca
# tulisannya : tulis
# lunas : lunas
# terdaftar : daftar
# pemberitahuan : pemberitahuan
# boxnya : boxnya
# tetanggaku : tetangga
# pcr : pcr
# wifinyav : wifinyav
# weiiii : weiiii
# dibacain : dibacain
# wejangan : wejang
# foto : foto
# bacaannya : baca
# beda : beda
# lam : lam
# padam : padam
# nurmala : nurmala
# bisaan : bisa
# ngelagnya : ngelagnya
# ncub : ncub
# well : well
# actually : actually
# sucks : sucks
# greater : greater
# moved : moved
# back : back
# surabaya : surabaya
# works : works
# like : like
# charm : charm
# cooooyyyyyy : cooooyyyyyy
# kontraksiiiiiiii : kontraksiiiiiiii
# tenang : tenang
# melayani : layan
# laily : laily
# memaki : maki
# ngemis : ngemis
# beach : beach
# kreatif : kreatif
# inovatif : inovatif
# yuuuk : yuuuk
# tayangan : tayang
# hbo : hbo
# instal : instal
# apps : apps
# billing : billing
# gratis : gratis
# barusan : barusan
# curhat : curhat
# tertarik : tarik
# memutuskan : putus
# kejelasan : jelas
# fiktif : fiktif
# lan : lan
# port : port
# express : express
# april : april
# sabtu : sabtu
# dont : dont
# even : even
# hear : hear
# anything : anything
# bcs : bcs
# pause : pause
# better : better
# improve : improve
# bismillah : bismillah
# monyet : monyet
# bedanya : beda
# optic : optic
# nyambung : nyambung
# orbit : orbit
# mifi : mifi
# ggwp : ggwp
# nyaut : nyaut
# rame : rame
# dibahas : bahas
# grup : grup
# info : info
# cegatan : cegat
# jogja : jogja
# ati : ati
# kwn : kwn
# didedikasikan : dedikasi
# rant : rant
# hidup : hidup
# kedap : kedap
# warna : warna
# ppn : ppn
# dikasih : kasih
# flyerndengan : flyerndengan
# mps : mps
# after : after
# mhn : mhn
# penjelasan : jelas
# mode : mode
# keong : keong
# alfath : alfath
# mendengar : dengar
# kabar : kabar
# baiknya : baik
# darinpusat : darinpusat
# gunanya : guna
# system : system
# dirmhku : dirmhku
# jump : jump
# atep : atep
# telepon : telepon
# klu : klu
# bgtt : bgtt
# tiktok : tiktok
# anehhh : anehhh
# okeh : okeh
# hlo : hlo
# kemba : kemba
# myir : myir
# nmr : nmr
# kendalanya : kendala
# maret : maret
# sop : sop
# bukain : bukain
# persib : persib
# terisolir : isolir
# ahelahhhh : ahelahhhh
# sihh : sihh
# ditengah : tengah
# keramaian : ramai
# alekkk : alekkk
# njebret : njebret
# ganguan : ganguan
# merusak : rusak
# suasana : suasana
# menonton : tonton
# ara : ara
# dins : dins
# kampreet : kampreet
# tepatnya : tepat
# bali : bal
# clear : clear
# cache : cache
# versi : versi
# kem : kem
# jgan : jgan
# tag : tag
# anjrot : anjrot
# chintya : chintya
# selanjutny : selanjutny
# crush : crush
# maluu : maluu
# ghosting : ghosting
# muluuu : muluuu
# ditungguin : ditungguin
# mpe : mpe
# heloh : heloh
# log : log
# diinput : diinput
# help : help
# meraviglioso : meraviglioso
# mecare : mecare
# berlangganannya : langgan
# terealisasikan : realisasi
# penggunaaan : penggunaaan
# dihitung : hitung
# prorata : prorata
# dipertimbangkan : timbang
# langganannya : langgan
# kehilangan : hilang
# benefit : benefit
# open : open
# ras : ras
# diliat : liat
# ama : ama
# rangorang : rangorang
# indiego : indiego
# bertindak : tindak
# suami : suami
# wfh : wfh
# duduk : duduk
# wakaka : wakaka
# satupun : satu
# sederhana : sederhana
# mending : mending
# tulisan : tulis
# kemampuan : mampu
# konsumen : konsumen
# ngaco : ngaco
# jajan : jajan
# lazada : lazada
# belangganan : banggan
# olahraga : olahraga
# arli : arli
# req : req
# chandra : chandra
# kakmi : kakmi
# rekening : rekening
# bank : bank
# aisshhh : aisshhh
# horizzon : horizzon
# ehh : ehh
# masang : masang
# samsat : samsat
# dengarkan : dengar
# found : found
# rama : rama
# terbaik : baik
# hifi : hifi
# musik : musik
# bandwith : bandwith
# apaa : apaa
# gagal : gagal
# vicky : vicky
# terim : rim
# boshhh : boshhh
# gerai : gerai
# deposit : deposit
# prorate : prorate
# netflix : netflix
# maap : maap
# ancha : ancha
# disney : disney
# alamatnya : alamat
# mandiri : mandiri
# sehariiiiiii : sehariiiiiii
# sebulan : bulan
# sehariiiiii : sehariiiiii
# ajaaa : ajaaa
# deposito : deposito
# welcome : welcome
# hantu : hantu
# kesini : kesini
# ngerasa : ngerasa
# wms : wms
# pasword : pasword
# salesnya : salesnya
# cuek : cuek
# username : username
# permisi : permisi
# cilaki : cilaki
# rangkas : rangkas
# bitung : bitung
# kemusuhan : musuh
# stb : stb
# usee : usee
# gni : gni
# jeno : jeno
# sbenernya : sbenernya
# member : member
# skz : skz
# seungmin : seungmin
# sbnernya : sbnernya
# ank : ank
# lum : lum
# syarat : syarat
# dilengkapi : lengkap
# alasan : alas
# rita : rita
# jarjel : jarjel
# nena : nena
# gsm : gsm
# paleng : paleng
# menengah : tengah
# kedodoran : kedodoran
# problematika : problematika
# pinggir : pinggir
# komen : komen
# hashtag : hashtag
# pemenang : menang
# giveaway : giveaway
# dipilih : pilih
# menarik : tarik
# beruntung : untung
# yeyayy : yeyayy
# good : good
# borneo : borneo
# tahapannya : tahap
# tinggal : tinggal
# wajib : wajib
# private : private
# share : share
# jawabannya : jawab
# insta : insta
# story : story
# caption : caption
# luv : luv
# meraih : raih
# penghargaan : harga
# gold : gold
# champion : champion
# perdana : perdana
# eta : eta
# wkwkkw : wkwkkw
# klaim : klaim
# tdak : tdak
# timur : timur
# rajanya : raja
# cicing : cicing
# sia : sia
# woke : woke
# choose : choose
# violent : violent
# resolved : resolved
# kelarnya : kelar
# lempar : lempar
# malang : malang
# kota : kota
# mentok : mentok
# gang : gang
# seberang : seberang
# masangnya : masangnya
# ghaib : ghaib
# deg : deg
# degan : degan
# block : block
# mental : mental
# kesian : kesi
# klean : klean
# guys : guys
# binggow : binggow
# makanyaaa : makanyaaa
# klaimnya : klaim
# ajaib : ajaib
# kelakuan : laku
# model : model
# gampang : gampang
# rebut : rebut
# ooooooooo : ooooooooo
# karo : karo
# dodolan : dodol
# gethuk : gethuk
# pingnya : pingnya
# fauziah : fauziah
# teindikasi : teindikasi
# patchcore : patchcore
# posisinya : posisi
# dibawah : bawah
# alfia : alfia
# putri : putri
# widiihh : widiihh
# sabi : sabi
# yaakk : yaakk
# pengalaman : alam
# berurusan : urus
# kucoba : coba
# dicekin : dicekin
# takutnya : takut
# diatap : atap
# binatang : binatang
# tikus : tikus
# kabelnya : kabel
# kegigit : gigit
# tolongin : tolongin
# mutual : mutual
# peduli : peduli
# kuliah : kuliah
# gantung : gantung
# free : free
# selesai : selesai
# review : review
# sdm : sdm
# pintar : pintar
# blas : blas
# prabu : prabu
# dahuluvia : dahuluvia
# chatingan : chatingan
# mathew : mathew
# berawalan : awal
# exo : exo
# blmn : blmn
# updt : updt
# pala : pala
# botak : botak
# omongnya : omong
# negara : negara
# ato : ato
# brapa : brapa
# layani : layan
# fokus : fokus
# kelen : kelen
# rada : rada
# eka : eka
# nnt : nnt
# ngedm : ngedm
# digubris : gubris
# wkwkkwkwkwkwkwkw : wkwkkwkwkwkwkwkw
# erima : erima
# ren : ren
# teratasi : atas
# tempaktu : tempaktu
# tombol : tombol
# off : off
# abaz : abaz
# terpasa : terpasa
# lukman : lukman
# istighfar : istighfar
# kakakku : kakak
# tersayang : sayang
# kenape : kenape
# asyanti : asyanti
# kocak : kocak
# berasa : asa
# net : net
# instant : instant
# penempatan : tempat
# diletakkan : letak
# sejuk : sejuk
# berdekatan : dekat
# barang : barang
# elektronik : elektronik
# yudho : yudho
# kode : kode
# ageng : ageng
# barunya : baru
# syg : syg
# firstmed : firstmed
# ngescroll : ngescroll
# detik : detik
# induk : induk
# usahanya : usaha
# analis : analis
# programmernya : programmernya
# bejibun : bejibun
# pelanggannya : langgan
# galau : galau
# kepastian : pasti
# digantung : gantung
# lgsng : lgsng
# naro : naro
# terfikir : terfikir
# modul : modul
# pelacakan : lacak
# myindiehome : myindiehome
# direspons : respons
# anu : anu
# otw : otw
# sekian : sekian
# troubleshoot : troubleshoot
# pengerjaan : kerja
# ticket : ticket
# sunshine : sunshine
# katherine : katherine
# rmhku : rmhku
# marketing : marketing
# nyaranin : nyaranin
# usa : usa
# diikutin : diikutin
# infonya : info
# ineternet : ineternet
# dimohon : mohon
# ketersediaannya : sedia
# iyse : iyse
# wahh : wahh
# ush : ush
# urus : urus
# perekrutan : rekrut
# sdmnya : sdmnya
# bloon : bloon
# masinya : mas
# git : git
# konfir : konfir
# nggu : nggu
# reza : reza
# ditu : ditu
# gbr : gbr
# seru : seru
# konekkk : konekkk
# kirainn : kirainn
# ngedown : ngedown
# taunya : tau
# bangcaad : bangcaad
# nyalanya : nyala
# pamulanh : pamulanh
# dipakai : pakai
# dede : dede
# damis : dam
# agustus : agustus
# diaksesnya : akses
# akumulasi : akumulasi
# sisanya : sisa
# yutuban : yutuban
# yutub : yutub
# zoom : zoom
# pelajar : ajar
# ngakaka : ngakaka
# daegal : daegal
# dihunakan : dihunakan
# ganggungan : ganggungan
# komponen : komponen
# phone : phone
# berminat : minat
# kondfirmasi : kondfirmasi
# menginformasikan : informasi
# tarif : tarif
# rp : rp
# ind : ind
# ali : ali
# harganyanya : harganyanya
# palbotnya : palbotnya
# larang : larang
# tur : tur
# wess : wess
# kapokk : kapokk
# wes : wes
# syuuuuu : syuuuuu
# maling : maling
# oranggg : oranggg
# indihum : indihum
# staff : staff
# hotspot : hotspot
# koko : koko
# ramadhan : ramadhan
# pantau : pantau
# killjoy : killjoy
# patah : patah
# cypher : cypher
# whatsapp : whatsapp
# kang : kang
# dibogor : bogor
# bbisa : bbisa
# keterangan : terang
# merk : merk
# firman : firman
# indi : indi
# home : home
# memuaskan : muas
# wahyudi : wahyudi
# tuman : tuman
# capturekan : capturekan
# dimatiin : dimatiin
# nunggak : nunggak
# kartrider : kartrider
# lgsg : lgsg
# ajeng : ajeng
# konten : konten
# lisa : lisa
# wita : wita
# tpi : tpi
# brimonya : brimonya
# terkahir : terkahir
# kacaunya : kacau
# aiman : aiman
# piala : piala
# menpora : menpora
# tayang : tayang
# respons : respons
# veni : veni
# total : total
# store : store
# google : google
# play : play
# aplikasinya : aplikasi
# halaman : halaman
# jerry : jerry
# balasan : balas
# dijogja : dijogja
# indiehome : indiehome
# response : response
# utam : utam
# dino : dino
# terselesaikan : selesai
# diak : diak
# monita : monita
# venkania : venkania
# setia : setia
# terjangkau : jangkau
# indovision : indovision
# saksikan : saksi
# pertandingan : tanding
# pertarungan : tarung
# dendam : dendam
# ldu : ldu
# bpj : bpj
# smp : smp
# wbs : wbs
# berhasil : hasil
# ibl : ibl
# hello : hello
# jatuh : jatuh
# tempo : tempo
# non : non
# dikorea : dikorea
# etminnya : etminnya
# shyton : shyton
# elzha : elzha
# dinomor : nomor
# tercancel : tercancel
# pesan : pesan
# tertera : tera
# fiora : fiora
# indihomo : indihomo
# memed : memed
# penjaga : jaga
# besties : besties
# bungsu : bungsu
# bayik : bayik
# hobby : hobby
# bak : bak
# keliatan : liat
# cogan : cogan
# arab : arab
# salam : salam
# kenal : kenal
# anehnya : aneh
# cba : cba
# silvi : silvi
# apt : apt
# puri : puri
# mansion : mansion
# pembohongan : bohong
# publik : publik
# hachim : hachim
# aris : aris
# penambahan : tambah
# kebijakan : bijak
# witel : witel
# disediakan : sedia
# anjrott : anjrott
# velycia : velycia
# percepatan : cepat
# padamu : pada
# bagan : bagan
# save : save
# maklum : maklum
# nek : nek
# ncen : ncen
# koe : koe
# xxorg : xxorg
# koryah : koryah
# koryahh : koryahh
# praktikum : praktikum
# dimaklumi : maklum
# ngakak : ngakak
# oge : oge
# keuna : keuna
# acak : acak
# teu : teu
# indosiar : indosiar
# bolana : bolana
# gencar : gencar
# iklan : iklan
# regis : regis
# cancel : cancel
# hah : hah
# uts : uts
# syalann : syalann
# hiks : hiks
# ananda : ananda
# kayi : kayi
# boss : boss
# psps : psps
# edit : edit
# chanyeol : chanyeol
# selfie : selfie
# goyang : goyang
# terkuras : kuras
# pantatnya : pantat
# lebar : lebar
# keke : keke
# indah : indah
# tanda : tanda
# bacaan : baca
# dipercepat : cepat
# ujian : uji
# yayu : yayu
# responnn : responnn
# smoga : smoga
# komentar : komentar
# saran : saran
# temukan : temu
# patokan : patok
# harganya : harga
# diputus : putus
# dbm : dbm
# naufal : naufal
# ubah : ubah
# myrepublic : myrepublic
# bnetfit : bnetfit
# domanullang : domanullang
# fernando : fernando
# yayas : yayas
# diannita : diannita
# hug : hug
# mari : mari
# jyp : jyp
# ngak : ngak
# mendaftarkan : daftar
# dijadwalkan : jadwal
# kedatangan : datang
# slot : slot
# odp : odp
# penuh : penuh
# kebutuhan : butuh
# levi : levi
# hrusnya : hrusnya
# dongg : dongg
# palbot : palbot
# klarifikasi : klarifikasi
# gebukin : gebukin
# marketingnya : marketingnya
# menurutku : turut
# telfon : telfon
# korbannya : korban
# bantuin : bantuin
# renaldy : renaldy
# potensi : potensi
# penyebabya : penyebabya
# memastikannya : pasti
# sial : sial
# spoiler : spoiler
# iyah : iyah
# staffnya : staffnya
# kcptn : kcptn
# ditelfon : ditelfon
# tlfn : tlfn
# ketentuan : tentu
# sgitu : sgitu
# infonyaa : infonyaa
# manggil : manggil
# aurora : aurora
# betumbuk : betumbuk
# dear : dear
# ask : ask
# emgnya : emgnya
# maksa : maksa
# segitu : segitu
# erorrr : erorrr
# komplen : komplen
# solusiiii : solusiiii
# ayubie : ayubie
# doy : doy
# bolos : bolos
# mahasis : mahasis
# scroll : scroll
# twiter : twiter
# statussss : statussss
# basing : basing
# nebula : nebula
# bee : bee
# yuknowlah : yuknowlah
# bayangin : bayangin
# ono : ono
# kowe : kowe
# biasane : biasane
# ketok : ketok
# hens : hens
# kondisinya : kondisi
# lanjutkan : lanjut
# ratih : ratih
# wgwgw : wgwgw
# simaster : simaster
# noh : noh
# kerjaan : kerja
# rumit : rumit
# tolonglahhhb : tolonglahhhb
# dwi : dwi
# yulia : yulia
# pembaharuan : baharu
# maja : maja
# protokol : protokol
# http : http
# ilegal : ilegal
# https : https
# learning : learning
# vpn : vpn
# zya : zya
# kedalam : dalam
# voice : voice
# www : www
# com : com
# telkomdigitalsolution : telkomdigitalsolution
# donggggg : donggggg
# yatuhannnn : yatuhannnn
# rahayu : rahayu
# bakar : bakar
# yaaah : yaaah
# mkasihhh : mkasihhh
# gapernah : gapernah
# nitip : nitip
# makasihh : makasihh
# ngeluddd : ngeluddd
# tayangannya : tayang
# sub : sub
# jue : jue
# kurangi : kurang
# stabi : stabi
# terminate : mate
# kontrak : kontrak
# plaza : plaza
# citayem : citayem
# tumben : tumben
# ngumpulin : ngumpulin
# remedial : remedial
# paketan : paket
# kampretttttt : kampretttttt
# elsa : elsa
# tiketnya : tiket
# nofrizal : nofrizal
# ontnya : ontnya
# villa : villa
# citayam : citayam
# pengaruh : pengaruh
# nelp : nelp
# payment : payment
# bekti : bekti
# nulis : nulis
# gblk : gblk
# direkomendasiin : direkomendasiin
# begindang : begindang
# bambangggg : bambangggg
# jaga : jaga
# donny : donny
# ditiket : tiket
# ngasih : ngasih
# dibikin : bikin
# kumulatif : kumulatif
# pelat : pelat
# nadya : nadya
# riry : riry
# dtg : dtg
# sla : sla
# blg : blg
# nyut : nyut
# nyutan : nyut
# tethering : tethering
# troublenya : troublenya
# didepan : depan
# dibalikin : dibalikin
# naek : naek
# darah : darah
# iki : iki
# puwancet : puwancet
# hngggggg : hngggggg
# knpsiii : knpsiii
# nyahahahah : nyahahahah
# alfa : alfa
# coeg : coeg
# cerita : cerita
# memperlelet : lelet
# nyuruh : nyuruh
# downloadin : downloadin
# episode : episode
# eko : eko
# pembuatan : buat
# rutinitas : rutinitas
# dimudahkan : mudah
# gann : gann
# sakit : sakit
# jln : jln
# diem : diem
# agil : agil
# ndu : ndu
# lingkunganku : lingkung
# kun : kun
# fikri : fikri
# anisa : anisa
# yasmin : yasmin
# privat : privat
# riza : riza
# dipaket : paket
# cimanggis : cimanggis
# depok : depok
# irsan : irsan
# migrasi : migrasi
# infomasi : infomasi
# meng : meng
# pt : pt
# gangerti : gangerti
# harian : hari
# ngerugiin : ngerugiin
# gmeet : gmeet
# dsb : dsb
# ramah : ramah
# ryan : ryan
# febriyan : febriyan
# noela : noela
# gema : gema
# ran : ran
# metodenya : metode
# sulit : sulit
# mendeteksi : deteksi
# berbicara : bicara
# berbeda : beda
# hasil : hasil
# hehehe : hehehe
# urtype : urtype
# witter : witter
# soya : soya
# win : win
# peralihan : alih
# burger : burger
# king : king
# ege : ege
# awowkwk : awowkwk
# maaff : maaff
# waduuuu : waduuuu
# nichhhh : nichhhh
# wil : wil
# blora : blora
# offline : offline
# atm : atm
# jarkom : jarkom
# cctv : cctv
# alhasil : alhasil
# omel : omel
# tangga : tangga
# keringetan : keringetan
# gamaunya : gamaunya
# dibanding : banding
# zulfan : zulfan
# keganggu : ganggu
# krna : krna
# masaiya : masaiya
# ipong : ipong
# oiya : oiya
# jumpa : jumpa
# berinteraksi : interaksi
# ngilang : ngilang
# umma : umma
# hahahahah : hahahahah
# gamau : gamau
# divakein : divakein
# kotor : kotor
# welcomeeeee : welcomeeeee
# kebutuhannya : butuh
# tambahan : tambah
# biaya : biaya
# instalasi : instalasi
# biayanya : biaya
# tergantung : gantung
# oia : oia
# berisi : isi
# sesuaikan : sesuai
# erlangga : erlangga
# anjeng : anjeng
# fafa : fafa
# kohl : kohl
# uji : uji
# kesabaranku : sabar
# rusak : rusak
# cpt : cpt
# kampus : kampus
# internetan : internetan
# nyebelin : nyebelin
# dips : dips
# hukum : hukum
# islam : islam
# prayekti : prayekti
# ngape : ngape
# tagihannya : tagih
# wallahu : wallahu
# alam : alam
# berprasangka : prasangka
# gabut : gabut
# dunia : dunia
# metafisika : metafisika
# penglihatannya : lihat
# hatur : hatur
# cib : cib
# irwan : irwan
# rincian : rincian
# dibalas : balas
# berbeza : berbeza
# bye : bye
# sip : sip
# rekomendasinya : rekomendasi
# haura : haura
# mam : mam
# iperlukan : iperlukan
# imam : imam
# pelaporan : lapor
# updatennya : updatennya
# ite : ite
# direvisi : revisi
# ujaran : ujar
# kebencian : benci
# kecuali : kecuali
# jastippp : jastippp
# musuhan : musuh
# responmu : responmu
# koyok : koyok
# sinyale : sinyale
# oftik : oftik
# cibarengkok : cibarengkok
# jatiwangi : jatiwangi
# cikarang : cikarang
# barat : barat
# cmn : cmn
# yth : yth
# herawan : herawan
# perkiraan : kira
# mar : mar
# ngetweet : ngetweet
# hubungin : hubungin
# dikirimin : dikirimin
# secepetnya : secepetnya
# rokok : rokok
# puas : puas
# gimina : gimina
# hidupin : hidupin
# kebel : kebel
# copot : copot
# buatin : buatin
# kajian : kaji
# disya : disya
# didi : didi
# terealisasi : realisasi
# colok : colok
# fabble : fabble
# terletak : letak
# terakses : akses
# ankan : ankan
# disalahgunakan : disalahgunakan
# arie : arie
# sar : sar
# sendernya : sender
# fitria : fitria
# zaaa : zaaa
# tonjok : tonjok
# tonjokan : tonjok
# anjirt : anjirt
# brengski : brengski
# gadenger : gadenger
# kelompok : kelompok
# dibatelin : dibatelin
# bajingan : bajing
# okay : okay
# riel : riel
# mencoba : coba
# hahahah : hahahah
# sapa : sapa
# anjai : anja
# reiza : reiza
# tekan : tekan
# menekan : tekan
# infrared : infrared
# chace : chace
# duma : duma
# install : install
# bening : bening
# perhatian : perhati
# suu : suu
# kaaaa : kaaaa
# bilangnya : bilang
# ampun : ampun
# sambat : sambat
# jugaa : jugaa
# ogel : ogel
# sehat : sehat
# modyaro : modyaro
# nyampah : nyampah
# akunnya : akun
# ririn : ririn
# bendino : bendino
# bosok : bosok
# ancen : ancen
# ngk : ngk
# losnya : los
# merahhhh : merahhhh
# purwa : purwa
# optiknya : optik
# aulia : aulia
# desta : desta
# mengakses : akses
# seluler : seluler
# stefanie : stefanie
# angka : angka
# diawali : awal
# metode : metode
# ariardi : ariardi
# takkk : takkk
# louis : louis
# tekoneksi : tekoneksi
# rahma : rahma
# adai : ada
# hehehhe : hehehhe
# minnnn : minnnn
# keren : keren
# deeh : deeh
# indihomenya : indihomenya
# nembak : nembak
# tower : tower
# terdekat : dekat
# km : km
# tercoverage : tercoverage
# mematikan : mati
# prosedurnya : prosedur
# spt : spt
# helmi : helm
# mary : mary
# hafidz : hafidz
# profiling : profiling
# pika : pika
# murara : murara
# perbedaan : beda
# gangguaan : gangguaan
# diakibatkan : akibat
# titik : titik
# mutiara : mutiara
# sambungan : sambung
# terpakai : pakai
# loly : loly
# dipetimbangkan : timbang
# berlanggananya : berlanggananya
# disayangkan : sayang
# menikmati : nikmat
# awan : awan
# liga : liga
# inggris : inggris
# ...
# star : star
# xx : xx
# dea : dea
# aupra : aupra
# sure : sure
# being : being
# crap : crap
# classes : classes
# today : today
# keeps : keeps
# going : going
# adios : adios
# reason : reason
# gausah : gausah
# disconnected : disconnected
# carrier : carrier
# pusatnya : pusat
# agust : agust
# pergantian : ganti
# dikenakan : kena
# nderr : nderr
# firdhan : firdhan
# melewati : lewat
# paketnya : paket
# what : what
# fucking : fucking
# problem : problem
# mene : mene
# teko : teko
# omh : omh
# gae : gae
# seh : seh
# lek : lek
# jaringane : jaringane
# mlbu : mlbu
# daerahmu : daerah
# nggae : nggae
# republic : republic
# seng : seng
# liyane : liyane
# gaonok : gaonok
# gawe : gawe
# ndek : ndek
# jajal : jajal
# ngecek : ngecek
# fadlan : fadlan
# iska : iska
# iso : iso
# daftare : daftare
# cah : cah
# pingin : pingin
# ngerubah : ngerubah
# tekok : tekok
# sing : sing
# nduwe : nduwe
# fahrul : fahrul
# rek : rek
# sopo : sopo
# ngerti : ngerti
# pie : pie
# mama : mama
# aluna : aluna
# syifa : syifa
# kelengkapan : lengkap
# kerumah : rumah
# fotokan : foto
# danial : danial
# chache : chache
# pengaturan : atur
# moh : moh
# rana : rana
# kirana : kirana
# mona : mona
# nyoba : nyoba
# saiki : saiki
# helooww : helooww
# saiful : saiful
# yallah : yallah
# aprilia : aprilia
# konfigurasi : konfigurasi
# best : best
# menjatuhkan : jatuh
# ibuk : ibuk
# ngamok : ngamok
# podooo : podooo
# adek : adek
# ayah : ayah
# mengajar : ajar
# rapat : rapat
# hahahaha : hahahaha
# prosedur : prosedur
# ganggu : ganggu
# saman : saman
# pleas : pleas
# ender : ender
# mkany : mkany
# megavision : megavision
# can : can
# relate : relate
# ndak : ndak
# jak : jak
# gamuncul : gamuncul
# suaranya : suara
# asap : asap
# buset : buset
# arini : arini
# hummm : hummm
# marahin : marahin
# kip : kip
# single : single
# sambung : sambung
# bole : bole
# nyabutnya : nyabutnya
# salahnya : salah
# dilaporin : dilaporin
# pengelolanya : kelola
# weverse : weverse
# bianglala : bianglala
# lelah : lelah
# caper : caper
# indihomee : indihomee
# new : new
# technology : technology
# create : create
# opportunities : opportunities
# job : job
# that : that
# customers : customers
# want : want
# reilly : reilly
# duel : duel
# kualitasnya : kualitas
# mirza : mirza
# reynatha : reynatha
# alhamudulillah : alhamudulillah
# should : should
# start : start
# push : push
# damn : damn
# happen : happen
# sinyallnya : sinyallnya
# perbaiin : perbaiin
# huangrenjunsi : huangrenjunsi
# nax : nax
# flop : flop
# omdo : omdo
# sekebon : kebon
# wkkww : wkkww
# diana : ana
# zainul : zainul
# tahapan : tahap
# detai : detai
# ngancem : ngancem
# berprinsip : prinsip
# ciri : ciri
# duta : duta
# merlin : merlin
# alma : alma
# telkomselnya : telkomselnya
# irham : irham
# fina : fina
# dikembalikan : kembali
# hii : hii
# pagii : pagi
# diinfo : info
# normalnya : normal
# jayapura : jayapura
# awas : awas
# gajian : gaji
# kurleb : kurleb
# penutupan : tutup
# kembalikan : kembali
# iga : iga
# farah : farah
# disekitar : sekitar
# pram : pram
# permasalahannya : masalah
# memassikan : memassikan
# aditya : aditya
# kwkwkwkw : kwkwkwkw
# pela : pela
# kejadian : jadi
# kecamatan : camat
# airplane : airplane
# rencana : rencana
# two : two
# last : last
# standing : standing
# geura : geura
# goblog : goblog
# negeri : negeri
# pekalongan : kalong
# jawa : jawa
# mingguan : minggu
# berfungsi : fungsi
# aduan : adu
# cabang : cabang
# suwun : suwun
# hahahha : hahahha
# kpn : kpn
# dijadikan : jadi
# ajang : ajang
# makian : maki
# serapah : serapah
# ditolelir : ditolelir
# kecanggihan : canggih
# teknologinya : teknologi
# dibarengi : bareng
# antisipasi : antisipasi
# sigap : sigap
# layannanya : layannanya
# apaansi : apaansi
# bayarkan : bayar
# antonio : antonio
# rya : rya
# yabes : yabes
# periksa : periksa
# dibalik : balik
# bunyi : bunyi
# bzing : bzing
# kompromie : kompromie
# sklie : sklie
# bersahabatlah : sahabat
# signalnya : signalnya
# lemah : lemah
# mencapai : capai
# ketimbang : ketimbang
# mendingan : mending
# membantu : bantu
# memperkaya : kaya
# asuuuuuuuuu : asuuuuuuuuu
# syarif : syarif
# panduan : pandu
# langkahnya : langkah
# dimas : mas
# desna : desna
# sherin : sherin
# semalam : malam
# dibandingkan : banding
# live : live
# nangkep : nangkep
# disconnecting : disconnecting
# tvod : tvod
# sarapan : sarap
# diruma : diruma
# rasbby : rasbby
# pica : pica
# panas : panas
# banyaknya : banyak
# pikir : pikir
# seumur : umur
# umur : umur
# onlen : onlen
# bego : bego
# meledak : ledak
# ledak : ledak
# kecerdasan : cerdas
# lampunya : lampu
# iyan : iyan
# drum : drum
# day : day
# thankyou : thankyou
# awali : awal
# hadeeehhh : hadeeehhh
# ironisnya : ironis
# menawarkan : tawar
# aneka : aneka
# miring : miring
# sapaan : sapa
# terhomat : terhomat
# study : study
# mb : mb
# muflih : muflih
# amel : amel
# mumgkin : mumgkin
# ediaannya : ediaannya
# usahakan : usaha
# heri : heri
# menghambat : hambat
# ujiannya : uji
# khawatir : khawatir
# menangani : tangan
# kes : kes
# gmne : gmne
# sign : sign
# appnya : appnya
# handika : handika
# melalaui : lalau
# indihomeee : indihomeee
# chia : chia
# java : java
# vision : vision
# ning : ning
# sak : sak
# durunge : durunge
# setaun : taun
# coro : coro
# kenek : kenek
# dendo : dendo
# juta : juta
# lak : lak
# hargai : harga
# diabaikan : abai
# ketauan : tau
# orgny : orgny
# berubah : ubah
# hak : hak
# menerima : terima
# bangt : bangt
# inimah : inimah
# yadi : yad
# herlambang : herlambang
# petani : tani
# pscyhedelic : pscyhedelic
# dengerin : dengerin
# pink : pink
# floyd : floyd
# tame : tame
# impala : impala
# bercocok : cocok
# tanam : tanam
# kerjanya : kerja
# closing : closing
# disitu : situ
# sekomplek : sekomplek
# tokped : tokped
# token : token
# hemat : hemat
# god : god
# sake : sake
# gimanaa : gimanaa
# rizki : rizki
# pergi : pergi
# uaneh : uaneh
# pernahnya : pernah
# stabilnya : stabil
# sepil : pil
# ngomelin : ngomelin
# dipecat : pecat
# nambahin : nambahin
# masker : masker
# hand : hand
# sanitizer : sanitizer
# enunggu : enunggu
# rendie : rendie
# nyauri : nyauri
# cen : cen
# amuba : amuba
# tenan : tenan
# owk : owk
# sesuk : sesuk
# liane : liane
# wis : wis
# tep : tep
# arep : arep
# send : send
# kacang : kacang
# goreng : goreng
# pesen : sen
# team : team
# menang : menang
# maria : maria
# becus : becus
# terputusnya : putus
# klapanunggal : klapanunggal
# bogor : bogor
# bukaaa : bukaaa
# tenet : tenet
# saye : saye
# shubuh : shubuh
# ngerasain : ngerasain
# ngelek : ngelek
# bangsyat : bangsyat
# bola : bola
# starter : starter
# packnya : packnya
# anjim : anjim
# indra : indra
# penonaktifan : nonaktif
# mempertimbangkan : timbang
# pisan : pis
# euyy : euyy
# nyimpen : nyimpen
# tweetan : tweetan
# markah : markah
# bisaa : bisaa
# kenapaaa : kenapaaa
# garis : garis
# mumpung : mumpung
# hati : hati
# snacknya : snacknya
# rumahh : rumahh
# alihkan : alih
# rumahan : rumah
# mayan : mayan
# fuk : fuk
# games : games
# komplaian : komplaian
# akibatnya : akibat
# kenaikan : naik
# nangkap : nangkap
# kepuluhan : puluh
# isunya : isu
# engan : engan
# hidayat : hidayat
# nikmatin : nikmatin
# diharapkan : harap
# lampirkan : lampir
# layarnya : layar
# sorry : sorry
# cant : cant
# because : because
# disalah : salah
# avin : avin
# pam : pam
# base : base
# ttp : ttp
# hebat : hebat
# jughaaa : jughaaa
# arya : arya
# program : program
# ecommerce : ecommerce
# dimana : mana
# voucher : voucher
# diskon : diskon
# maksimum : maksimum
# lapak : lapak
# husein : husein
# combo : combo
# sport : sport
# ketentuannya : tentu
# novi : novi
# ngalah : ngalah
# ngalahin : ngalahin
# redo : redo
# puspa : puspa
# phoenix : phoenix
# song : song
# basket : basket
# deasy : deasy
# doanggggggg : doanggggggg
# menolak : tolak
# tawaran : tawar
# haduh : haduh
# ikhlashul : ikhlashul
# asta : asta
# ubur : ubur
# ricotta : ricotta
# gangguankah : ganggu
# podcast : podcast
# asyik : asyik
# menemani : tani
# ahhhhhh : ahhhhhh
# gambar : gambar
# stands : stands
# hoe : hoe
# kematian : mati
# drumah : drumah
# kereen : kereen
# filmnya : film
# agida : agida
# permitaan : permitaan
# disetiap : tiap
# mantul : mantul
# karyawan : karyawan
# minus : minus
# adab : adab
# kpd : kpd
# tua : tua
# jernih : jernih
# extra : extra
# menu : menu
# layananan : layananan
# asah : asah
# skill : skill
# dipraktekin : dipraktekin
# bermanfaat : manfaat
# menambah : tambah
# wawasan : wawas
# aginda : aginda
# fess : fess
# wow : wow
# tipsnya : tipsnya
# patut : patut
# tips : tips
# astri : astri
# arel : arel
# monkey : monkey
# luffy : luffy
# janu : janu
# jojo : jojo
# nnti : nnti
# donk : donk
# work : work
# faria : faria
# yauda : yauda
# shawn : shawn
# mendes : mendes
# fallin : fallin
# all : all
# ajib : ajib
# sangatt : sangatt
# ampuh : ampuh
# why : why
# time : time
# when : when
# need : need
# most : most
# mukti : mukti
# pemiliknya : milik
# dicooba : dicooba
# mencobanya : coba
# mudah : mudah
# ngegame : ngegame
# manfaatnya : manfaat
# panduannya : pandu
# fitur : fitur
# ajibb : ajibb
# bioskop : bioskop
# ngelanjut : ngelanjut
# mendukung : dukung
# tempek : tempek
# elbert : elbert
# berkaitan : kait
# jujur : jujur
# lahir : lahir
# idenya : ide
# mulia : mulia
# aot : aot
# eps : eps
# durasinya : durasi
# {'selamat': 'selamat', 'pagi': 'pagi', 'silahkan': 'silah', 'menghubungi': 'hubung', 'via': 'via', 'terima': 'terima', 'kasih': 'kasih', 'ichal': 'ichal', '': '', 'segmentasi': 'segmentasi', 'bisnis': 'bisnis', 'nay': 'nay', 'hallo': 'hallo', 'kak': 'kak', 'iqra': 'iqra', 'maaf': 'maaf', 'kakak': 'kakak', 'nyaman': 'nyaman', 'perihal': 'perihal', 'karingan': 'karingan', 'maksimal': 'maksimal', 'sarankan': 'saran', 'rekan': 'rekan', 'email': 'email', 'twitter': 'twitter', 'fanpage': 'fanpage', 'facebook': 'facebook', 'telkom': 'telkom', 'digital': 'digital', 'solution': 'solution', 'karna': 'karna', 'layanan': 'layan', 'kaka': 'kaka', 'admin': 'admin', 'wifi': 'wifi', 'rumah': 'rumah', 'bermasalah': 'masalah', 'adik': 'adik', 'sekolah': 'sekolah', 'daring': 'daring', 'tolong': 'tolong', 'dicek': 'cek', 'pembayaran': 'bayar', 'telat': 'telat', 'tks': 'tks', 'indihome': 'indihome', 'error': 'error', 'semalem': 'semalem', 'jam': 'jam', 'kek': 'kek', 'surya': 'surya', 'perbaikan': 'baik', 'pembersihan': 'bersih', 'plug': 'plug', 'unplug': 'unplug', 'modem': 'modem', 'naia': 'naia', 'cek': 'cek', 'sistem': 'sistem', 'jaringan': 'jaring', 'online': 'online', 'lokasi': 'lokasi', 'stabil': 'stabil', 'said': 'said', 'tetepin': 'tetepin', 'pilih': 'pilih', 'kerja': 'kerja', 'bener': 'bener', 'sabar': 'sabar', 'halo': 'halo', 'internet': 'internet', 'mati': 'mati', 'udah': 'udah', 'direstart': 'direstart', 'cabut': 'cabut', 'kabel': 'kabel', 'power': 'power', 'telpon': 'telpon', 'ngaruh': 'ngaruh', 'mohon': 'mohon', 'bantuan': 'bantu', 'sehari': 'hari', 'diperbaiki': 'baik', 'internetnya': 'internetnya', 'ayolah': 'ayo', 'gini': 'gin', 'homecare': 'homecare', 'shortlink': 'shortlink', 'nunik': 'nunik', 'zulfa': 'zulfa', 'akses': 'akses', 'bantu': 'bantu', 'refresh': 'refresh', 'pusat': 'pusat', 'menunggu': 'tunggu', 'menit': 'menit', 'koneksikan': 'koneksi', 'berkala': 'kala', 'interaksi': 'interaksi', 'silakan': 'sila', 'hubungi': 'hubung', 'akun': 'akun', 'useetv': 'useetv', 'konek': 'konek', 'karantina': 'karantina', 'bro': 'bro', 'iya': 'iya', 'eeq': 'eeq', 'teknisi': 'teknisi', 'solve': 'solve', 'kompensasinya': 'kompensasi', 'terkait': 'kait', 'jasa': 'jasa', 'bayar': 'bayar', 'tagihan': 'tagih', 'full': 'full', 'pindah': 'pindah', 'alamat': 'alamat', 'bawa': 'bawa', 'alat': 'alat', 'alatnya': 'alat', 'ganti': 'ganti', 'anand': 'anand', 'septiwi': 'septiwi', 'bagus': 'bagus', 'terpantau': 'pantau', 'laporannya': 'lapor', 'berkenan': 'kenan', 'dicoba': 'coba', 'berkendala': 'kendala', 'nggak': 'nggak', 'lost': 'lost', 'min': 'min', 'liem': 'liem', 'ketidaknyamanannya': 'ketidaknyamanannya', 'proses': 'proses', 'pemasangan': 'pasang', 'registrasi': 'registrasi', 'mengirimkan': 'kirim', 'nomor': 'nomor', 'registrasinya': 'registrasi', 'pengecekan': 'kece', 'progresnya': 'progres', 'gus': 'gus', 'allhamdulilah': 'allhamdulilah', 'eheh': 'eheh', 'wiffinya': 'wiffinya', 'ape': 'ape', 'leh': 'leh', 'allah': 'allah', 'bapakku': 'bapak', 'tanggal': 'tanggal', 'kemarin': 'kemarin', 'malem': 'malem', 'dibiarin': 'dibiarin', 'semaleman': 'maleman', 'lancar': 'lancar', 'tetep': 'tetep', 'gimana': 'gimana', 'hai': 'hai', 'rismawati': 'rismawati', 'jaringannya': 'jaring', 'pemeliharaan': 'pelihara', 'penanganan': 'tangan', 'tim': 'tim', 'upayakan': 'upaya', 'koneksinya': 'koneksi', 'normal': 'normal', 'chat': 'chat', 'kukira': 'kira', 'doang': 'doang', 'hiiih': 'hiiih', 'gemash': 'gemash', 'dibayar': 'bayar', 'lemot': 'lot', 'restart': 'restart', 'modemnya': 'modem', 'ngusik': 'ngusik', 'ketenangan': 'tenang', 'hidupku': 'hidup', 'subuh': 'subuh', 'yaaa': 'yaaa', 'trouble': 'trouble', 'ckckck': 'ckckck', 'keluhan': 'keluh', 'koneksi': 'koneksi', 'dirumah': 'rumah', 'landing': 'landing', 'page': 'page', 'muncul': 'muncul', 'lampu': 'lampu', 'indikator': 'indikator', 'nyala': 'nyala', 'bantuannya': 'bantu', 'trimakasih': 'trimakasih', 'harap': 'harap', 'bersabar': 'sabar', 'biasalah': 'biasa', 'febri': 'febri', 'panca': 'panca', 'kudo': 'kudo', 'hii ...
# ------------------------
# Pandas Apply:   0%|          | 0/1943 [00:02<?, ?it/s]
#                                                 content  \
# 0     @indihome selamat pagi silahkan menghubungi ka...
# 1     @iqrajs k termasuk dalam segmentasi bisnis. te...
# 2     @iqrajs hallo, kak iqra. maaf yah jadi bikin k...
# 3     @indihome admin ini wifi saya di rumah kok ber...
# 4     yang wifi nya indihome pada error gak si dari ...
# ...                                                 ...
# 1993                           @fwbess id indihome ya ?
# 1996                             @mlbbfess indihome ya?
# 1997           @indihome wow idenya kreatif banget nihh
# 1998  @indihome kereen infonya, jadi nambah wawasan ...
# 1999  sungguh mulia sekali indihome,nonton aot last ...
#
#                                          cleaning_tweet  \
# 0     selamat pagi silahkan menghubungi kami via ter...
# 1      termasuk dalam segmentasi bisnis terima kasih...
# 2     hallo kak iqra maaf yah jadi bikin kakak gak n...
# 3     admin ini wifi saya rumah kok bermasalah terus...
# 4     yang wifi nya indihome pada error gak dari sem...
# ...                                                 ...
# 1993                                          indihome
# 1996                                          indihome
# 1997                     wow idenya kreatif banget nihh
# 1998             kereen infonya jadi nambah wawasan nih
# 1999  sungguh mulia sekali indihome nonton aot last ...
#
#                                              tokenisasi  \
# 0     [selamat, pagi, silahkan, menghubungi, kami, v...
# 1     [, termasuk, dalam, segmentasi, bisnis, terima...
# 2     [hallo, kak, iqra, maaf, yah, jadi, bikin, kak...
# 3     [admin, ini, wifi, saya, rumah, kok, bermasala...
# 4     [yang, wifi, nya, indihome, pada, error, gak, ...
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997               [wow, idenya, kreatif, banget, nihh]
# 1998      [kereen, infonya, jadi, nambah, wawasan, nih]
# 1999  [sungguh, mulia, sekali, indihome, nonton, aot...
#
#                                                stopword  \
# 0     [selamat, pagi, silahkan, menghubungi, via, te...
# 1          [, segmentasi, bisnis, terima, kasih, nay, ]
# 2     [hallo, kak, iqra, maaf, kakak, nyaman, periha...
# 3     [admin, wifi, rumah, bermasalah, adik, sekolah...
# 4                    [wifi, indihome, error, semalem, ]
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997               [wow, idenya, kreatif, banget, nihh]
# 1998                 [kereen, infonya, nambah, wawasan]
# 1999  [sungguh, mulia, indihome, nonton, aot, last, ...
#
#                                                stemming
# 0     [selamat, pagi, silah, hubung, via, terima, ka...
# 1          [, segmentasi, bisnis, terima, kasih, nay, ]
# 2     [hallo, kak, iqra, maaf, kakak, nyaman, periha...
# 3     [admin, wifi, rumah, masalah, adik, sekolah, d...
# 4                    [wifi, indihome, error, semalem, ]
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997                  [wow, ide, kreatif, banget, nihh]
# 1998                      [kereen, info, nambah, wawas]
# 1999  [sungguh, mulia, indihome, nonton, aot, last, ...
#
# [1943 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [selamat, pagi, silah, hubung, via, terima, ka...
# 1          [, segmentasi, bisnis, terima, kasih, nay, ]
# 2     [hallo, kak, iqra, maaf, kakak, nyaman, periha...
# 3     [admin, wifi, rumah, masalah, adik, sekolah, d...
# 4                    [wifi, indihome, error, semalem, ]
# ...                                                 ...
# 1993                                     [, indihome, ]
# 1996                                       [indihome, ]
# 1997                  [wow, ide, kreatif, banget, nihh]
# 1998                      [kereen, info, nambah, wawas]
# 1999  [sungguh, mulia, indihome, nonton, aot, last, ...
#
# [1943 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_3.xlsx')
