# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["content"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\TWEET_INDIHOME\data mentah\crawlingtweet_indihome_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                 content
# 0     dear @IndiHome , kapan bisa kasih layanan yang...
# 1                        @BangunSubekti @IndiHome pegel
# 2                              Indihome lagi kenapa sih
# 3     @IndiHomeCare @IndiHome tolong bgt lampu inter...
# 4          @3O4misser @IndiHome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  Indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  Halo min @IndiHome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @IndiHome
#
# [2000 rows x 1 columns]

# %%
df.content.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(subset="content", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                 content
# 0     dear @IndiHome , kapan bisa kasih layanan yang...
# 1                        @BangunSubekti @IndiHome pegel
# 2                              Indihome lagi kenapa sih
# 3     @IndiHomeCare @IndiHome tolong bgt lampu inter...
# 4          @3O4misser @IndiHome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  Indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  Halo min @IndiHome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @IndiHome
#
# [1989 rows x 1 columns]

# %%
#case folding
df['content'] = df['content'].str.lower()
df.head(2000)
# Out:
#                                                 content
# 0     dear @indihome , kapan bisa kasih layanan yang...
# 1                        @bangunsubekti @indihome pegel
# 2                              indihome lagi kenapa sih
# 3     @indihomecare @indihome tolong bgt lampu inter...
# 4          @3o4misser @indihome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min @indihome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @indihome
#
# [1989 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_tweet'] = df['content'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                 content  \
# 0     dear @indihome , kapan bisa kasih layanan yang...
# 1                        @bangunsubekti @indihome pegel
# 2                              indihome lagi kenapa sih
# 3     @indihomecare @indihome tolong bgt lampu inter...
# 4          @3o4misser @indihome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min @indihome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @indihome
#
#                                          cleaning_tweet
# 0     dear kapan bisa kasih layanan yang minimal jar...
# 1                                                 pegel
# 2                              indihome lagi kenapa sih
# 3     tolong bgt lampu internet dari malem masih mer...
# 4                                     tau nih peka bgt
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min untuk prosedur pemutusan itu apa aja ...
# 1998             indihome pengen tak tampol lemot amat
# 1999                                lemot marai mangkel
#
# [1989 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_tweet'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                 content  \
# 0     dear @indihome , kapan bisa kasih layanan yang...
# 1                        @bangunsubekti @indihome pegel
# 2                              indihome lagi kenapa sih
# 3     @indihomecare @indihome tolong bgt lampu inter...
# 4          @3o4misser @indihome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min @indihome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @indihome
#
#                                          cleaning_tweet  \
# 0     dear kapan bisa kasih layanan yang minimal jar...
# 1                                                 pegel
# 2                              indihome lagi kenapa sih
# 3     tolong bgt lampu internet dari malem masih mer...
# 4                                     tau nih peka bgt
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min untuk prosedur pemutusan itu apa aja ...
# 1998             indihome pengen tak tampol lemot amat
# 1999                                lemot marai mangkel
#
#                                              tokenisasi
# 0     [dear, kapan, bisa, kasih, layanan, yang, mini...
# 1                                               [pegel]
# 2                         [indihome, lagi, kenapa, sih]
# 3     [tolong, bgt, lampu, internet, dari, malem, ma...
# 4                               [tau, nih, peka, bgt, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, mengganggu, saja, meeti...
# 1996  [guys, maaf, boleh, minta, tolong, cek, pinned...
# 1997  [halo, min, untuk, prosedur, pemutusan, itu, a...
# 1998     [indihome, pengen, tak, tampol, lemot, amat, ]
# 1999                            [lemot, marai, mangkel]
#
# [1989 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'nya'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(3000)
# Out:
#                                                 content  \
# 0     dear @indihome , kapan bisa kasih layanan yang...
# 1                        @bangunsubekti @indihome pegel
# 2                              indihome lagi kenapa sih
# 3     @indihomecare @indihome tolong bgt lampu inter...
# 4          @3o4misser @indihome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min @indihome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @indihome
#
#                                          cleaning_tweet  \
# 0     dear kapan bisa kasih layanan yang minimal jar...
# 1                                                 pegel
# 2                              indihome lagi kenapa sih
# 3     tolong bgt lampu internet dari malem masih mer...
# 4                                     tau nih peka bgt
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min untuk prosedur pemutusan itu apa aja ...
# 1998             indihome pengen tak tampol lemot amat
# 1999                                lemot marai mangkel
#
#                                              tokenisasi  \
# 0     [dear, kapan, bisa, kasih, layanan, yang, mini...
# 1                                               [pegel]
# 2                         [indihome, lagi, kenapa, sih]
# 3     [tolong, bgt, lampu, internet, dari, malem, ma...
# 4                               [tau, nih, peka, bgt, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, mengganggu, saja, meeti...
# 1996  [guys, maaf, boleh, minta, tolong, cek, pinned...
# 1997  [halo, min, untuk, prosedur, pemutusan, itu, a...
# 1998     [indihome, pengen, tak, tampol, lemot, amat, ]
# 1999                            [lemot, marai, mangkel]
#
#                                                stopword
# 0     [dear, kasih, layanan, minimal, jaringan, jala...
# 1                                               [pegel]
# 2                                            [indihome]
# 3      [tolong, lampu, internet, malem, merah, sekolah]
# 4                                              [peka, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, mengganggu, meetingku, ...
# 1996  [guys, maaf, tolong, cek, pinned, trs, tag, ak...
# 1997  [halo, min, prosedur, pemutusan, rumah, telepo...
# 1998                [indihome, pengen, tampol, lemot, ]
# 1999                            [lemot, marai, mangkel]
#
# [1989 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 3913
# ------------------------
# dear : dear
# kasih : kasih
# layanan : layan
# minimal : minimal
# jaringan : jaring
# jalan : jalan
# normal : normal
# bumn : bumn
# kaki : kaki
# pegel : gel
# indihome : indihome
# tolong : tolong
# lampu : lampu
# internet : internet
# malem : malem
# merah : merah
# sekolah : sekolah
# peka : peka
#  :
# dirumah : rumah
# kendalanya : kendala
# mengikuti : ikut
# anjuran : anjur
# pemerintah : perintah
# rumah : rumah
# kerja : kerja
# kendala : kendala
# udah : udah
# jam : jam
# laporan : lapor
# nyala : nyala
# pppp : pppp
# gimana : gimana
# wifi : wifi
# gue : gue
# mati : mati
# abangnya : abang
# ngecek : ngecek
# dateng : dateng
# allah : allah
# nyolong : nyolong
# tetangga : tetangga
# bener : bener
# kemarin : kemarin
# siang : siang
# sampe : sampe
# belom : bom
# susah : susah
# kuota : kuota
# sehari : hari
# bayar : bayar
# tetep : tetep
# ampun : ampun
# iya : iya
# nunggu : nunggu
# astagfirullah : astagfirullah
# banggarr : banggarr
# apapun : apa
# kkegiatanmu : kkegiatanmu
# akses : akses
# diandalkan : andal
# upgrade : upgrade
# speed : speed
# demand : demand
# mantap : mantap
# semaleman : maleman
# fakk : fakk
# jadwal : jadwal
# olimpiade : olimpiade
# tokyo : tokyo
# indonesia : indonesia
# juli : juli
# saksikan : saksi
# download : download
# aplikasinya : aplikasi
# usee : usee
# apps : apps
# store : store
# hybrid : hybrid
# box : box
# sumpah : sumpah
# ngambek : ngambek
# lihat : lihat
# live : live
# gara : gara
# kebawa : bawa
# mimpi : mimpi
# antena : antena
# mbak : mbak
# ayo : ayo
# jaringannya : jaring
# arang : arang
# enggk : enggk
# sinyal : sinyal
# stabil : stabil
# pke : pke
# gra : gra
# penyimpanan : simpan
# emng : emng
# minim : minim
# bnget : bnget
# min : min
# gabisa : gabisa
# dipake : dipake
# yaa : yaa
# router : router
# pasangin : pasangin
# siswa : siswa
# laptop : laptop
# emang : emang
# larinya : lari
# pakai : pakai
# sistem : sistem
# sewa : sewa
# subuh : subuh
# lemot : lot
# kirain : kirain
# kmrin : kmrin
# parah : parah
# bro : bro
# halo : halo
# lelet : lelet
# banget : banget
# streaming : streaming
# lagu : lagu
# update : update
# aplikasi : aplikasi
# cuman : cuman
# doang : doang
# pagi : pagi
# orang : orang
# emosi : emosi
# perluas : luas
# jangkauan : jangkau
# game : game
# berbasis : bas
# komputasi : komputasi
# awan : awan
# registrasi : registrasi
# promo : promo
# online : online
# lancar : lancar
# cuan : cuan
# gencar : gencar
# banner : banner
# twitter : twitter
# harapan : harap
# dpt : dpt
# channel : channel
# tambahan : tambah
# kunjung : kunjung
# muncul : muncul
# bbrp : bbrp
# kali : kali
# komplain : komplain
# petugas : tugas
# kwkwkwkwk : kwkwkwkwk
# nay : nay
# kebangun : bangun
# gegara : gegara
# bangun : bangun
# kah : kah
# hallo : hallo
# kak : kak
# yuk : yuk
# kepoin : poin
# paket : paket
# kecepatan : cepat
# gaming : gaming
# harga : harga
# regulernya : reguler
# ghodit : ghodit
# jancoook : jancoook
# emg : emg
# kencengan : kenceng
# mah : mah
# knp : knp
# skrg : skrg
# kon : kon
# cah : cah
# ente : ente
# toling : toling
# perbaikin : perbaikin
# kualitas : kualitas
# temen : temen
# ane : ane
# ampe : ampe
# gavisa : gavisa
# vcall : vcall
# ngga : ngga
# bang : bang
# taee : taee
# vcal : vcal
# blauervogel : blauervogel
# gimananih : gimananih
# hai : hai
# riki : riki
# koneksi : koneksi
# bantu : bantu
# cek : cek
# silakan : sila
# kakak : kakak
# infokan : info
# nomor : nomor
# aktif : aktif
# via : via
# menjaga : jaga
# kerahasiaan : rahasia
# data : data
# tunggu : tunggu
# konfirmasi : konfirmasi
# terima : terima
# fanzila : fanzila
# pad : pad
# alpad : alpad
# dramaga : dramaga
# wife : wife
# trus : trus
# mba : mba
# perbulan : bulan
# nda : nda
# berubah : ubah
# plus : plus
# perbaikan : baik
# dilokasi : lokasi
# hasil : hasil
# speedtest : speedtest
# kalah : kalah
# telak : telak
# traffic : traffic
# padat : padat
# minggu : minggu
# pilihan : pilih
# bandwidth : bandwidth
# gede : gede
# ping : ping
# mesti : mesti
# nanya : nanya
# myrepublic : myrepublic
# biznet : biznet
# home : home
# fiber : fiber
# kesekian : sekian
# anying : anying
# iklan : iklan
# meme : meme
# terkenal : kenal
# bet : bet
# wkwkwk : wkwkwk
# berkali : kali
# restart : restart
# led : led
# gangguan : ganggu
# mohon : mohon
# penanganannya : tangan
# menggangu : menggangu
# ribut : ribut
# reject : reject
# kubaca : baca
# makan : makan
# baca : baca
# daah : daah
# gemes : gemes
# jarang : jarang
# sekaliny : sekaliny
# sebulan : bulan
# kekw : kekw
# telat : telat
# langsung : langsung
# isolir : isolir
# towewewew : towewewew
# telkom : telkom
# menyambut : sambut
# anak : anak
# nasional : nasional
# meluncurkan : luncur
# spesial : spesial
# bernama : nama
# indikids : indikids
# kanal : kanal
# menyajikan : saji
# tayangan : tayang
# hiburan : hibur
# edukasi : edukasi
# sing : sing
# sabar : sabar
# jualan : jual
# onlen : onlen
# cari : cari
# tagihan : tagih
# intinya : inti
# pelanggan : langgan
# memutus : putus
# pengaduan : adu
# terkait : kait
# tindaklanjutnya : tindaklanjutnya
# mending : mending
# deh : deh
# mengkawan : kawan
# kntl : kntl
# hello : hello
# kellin : kellin
# informasikan : informasi
# detail : detail
# seputar : putar
# rijali : rijal
# duh : duh
# fans : fans
# akoh : akoh
# anjing : anjing
# kabel : kabel
# bawaannya : bawa
# bermasalah : masalah
# ppkm : ppkm
# hariku : hari
# disibukkan : sibuk
# pelajaran : ajar
# matematika : matematika
# terkadang : terkadang
# menentukan : tentu
# rumus : rumus
# mencari : cari
# google : google
# untung : untung
# napa : napa
# telkomsel : telkomsel
# lag : lag
# kaya : kaya
# gini : gin
# napasih : napasih
# segini : gin
# ngulah : ngulah
# mulu : mulu
# febriani : febriani
# sebel : sebel
# bangett : bangett
# pas : pas
# nntn : nntn
# ngajak : ngajak
# kelahi : kelahi
# rincian : rincian
# pdhal : pdhal
# verikasi : verikasi
# ktp : ktp
# tlp : tlp
# tulisannya : tulis
# mp : mp
# gotchu : gotchu
# phoenix : phoenix
# liat : liat
# gunung : gunung
# sindur : sindur
# pjm : pjm
# kyk : kyk
# eek : eek
# pasang : pasang
# pip : pip
# call : call
# center : center
# fergie : fergie
# lak : lak
# misale : misale
# stb : stb
# piye : piye
# opo : opo
# nduwe : nduwe
# maneh : maneh
# mak : mak
# bilangnya : bilang
# emgg : emgg
# kaan : kaan
# pindah : pindah
# bogor : bogor
# jadii : jadi
# takut : takut
# gaada : gaada
# kagak : kagak
# buru : buru
# kesono : sono
# taun : taun
# hekhhhhh : hekhhhhh
# seminggu : minggu
# mayan : mayan
# kenceng : kenceng
# aneh : aneh
# pls : pls
# buka : buka
# safari : safari
# loading : loading
# ayolah : ayo
# udh : udh
# perihal : perihal
# silahkan : silah
# menghubungi : hubung
# bayu : bayu
# ngelag : ngelag
# main : main
# coba : coba
# belajar : ajar
# cape : cape
# mobile : mobile
# legend : legend
# intermiten : intermiten
# smpe : smpe
# tendang : tendang
# tuhan : tuhan
# jelek : jelek
# dri : dri
# alias : alias
# yaallah : yaallah
# kenapaaaaaa : kenapaaaaaa
# ngeleg : ngeleg
# tuhh : tuhh
# kenapaa : kenapaa
# tell : tell
# salahin : salahin
# maaf : maaf
# tunda : tunda
# yank : yank
# nonton : nonton
# clock : clock
# paketan : paket
# tinggal : tinggal
# dikit : dikit
# neeeeeeh : neeeeeeh
# sobat : sobat
# perangkat : perangkat
# terhubung : hubung
# berpengaruh : pengaruh
# bandwith : bandwith
# pastikan : pasti
# sesuai : sesuai
# bandwidh : bandwidh
# optimal : optimal
# bebas : bebas
# hambatan : hambat
# keren : keren
# shopee : shopee
# keong : keong
# ouhh : ouhh
# ajh : ajh
# trs : trs
# indihomenye : indihomenye
# muak : muak
# azk : azk
# nangis : nang
# gitu : gitu
# beneran : beneran
# nyebelin : nyebelin
# asiiik : asiiik
# giveaway : giveaway
# suka : suka
# aura : aura
# menyebalkan : sebal
# indih : indih
# suruh : suruh
# modem : modem
# ajg : ajg
# telek : telek
# make : make
# groovy : groovy
# patah : patah
# kayak : kayak
# gagap : gagap
# sales : sales
# makai : maka
# seragam : seragam
# acara : acara
# roadshow : roadshow
# what : what
# lawak : lawak
# moment : moment
# melek : melek
# malam : malam
# jumat : jumat
# ngbrol : ngbrol
# makhluk : makhluk
# lelembut : lelembut
# jenis : jenis
# gmn : gmn
# neh : neh
# sihhh : sihhh
# complain : complain
# laah : laah
# kebiasaan : biasa
# internetnya : internetnya
# warna : warna
# febrian : febrian
# urusin : urusin
# weverse : weverse
# tebak : tebak
# provider : provider
# berulahhhhh : berulahhhhh
# dlu : dlu
# gua : gua
# pecicilan : pecicilan
# diem : diem
# rusuh : rusuh
# hiperaktif : hiperaktif
# kgk : kgk
# mata : mata
# batin : batin
# ketutupan : tutup
# setan : setan
# jungkook : jungkook
# habis : habis
# alhamdulilah : alhamdulilah
# trims : trims
# maul : maul
# besok : besok
# trouble : trouble
# love : love
# kirimin : kirimin
# pricelist : pricelist
# redmibook : redmibook
# printer : printer
# scanner : scanner
# kasi : kasi
# murah : murah
# sedih : sedih
# gasi : gas
# ditindaklanjuti : ditindaklanjuti
# nggak : nggak
# lhoooo : lhoooo
# ampas : ampas
# kadang : kadang
# useless : useless
# providernya : providernya
# bntr : bntr
# kno : kno
# benci : benci
# bngt : bngt
# kek : kek
# anjirrr : anjirrr
# yaah : yaah
# jawabannya : jawab
# fllowup : fllowup
# dikoordinasikan : koordinasi
# tahap : tahap
# verifikasi : verifikasi
# identitas : identitas
# zonk : zonk
# sabtu : sabtu
# pdahal : pdahal
# lengkap : lengkap
# siii : siii
# alex : alex
# gus : gus
# iflix : iflix
# gratis : gratis
# daftar : daftar
# web : web
# terkoneksi : koneksi
# masak : masak
# goreng : goreng
# ditwt : ditwt
# mehh : mehh
# manfaat : manfaat
# bermain : main
# melatih : latih
# kerjasama : kerjasama
# tim : tim
# sikap : sikap
# percaya : percaya
# bijak : bijak
# mengambil : ambil
# keputusan : putus
# gamer : gamer
# sweet : sweet
# sisa : sisa
# eps : eps
# however : however
# menyarankan : saran
# membuktikan : bukti
# instagram : instagram
# abu : abu
# sumpa : sumpa
# teh : teh
# bapuk : bapuk
# goblok : goblok
# lgsg : lgsg
# reply : reply
# care : care
# sudahi : sudah
# galaumu : galau
# mari : mari
# mabar : mabar
# eeeiiittsss : eeeiiittsss
# lupa : lupa
# koneksinya : koneksi
# ind : ind
# town : town
# yes : yes
# other : other
# than : than
# they : they
# are : are
# not : not
# available : available
# far : far
# comparing : comparing
# with : with
# costumer : costumer
# service : service
# still : still
# better : better
# bul : bul
# ganti : ganti
# pantek : pantek
# kau : kau
# kegiatan : giat
# enak : enak
# duit : duit
# mall : mall
# ditutup : tutup
# duitnya : duit
# didukung : dukung
# jaya : jaya
# skg : skg
# kebutuhan : butuh
# pokok : pokok
# hadir : hadir
# luas : luas
# manapun : mana
# aman : aman
# nyaman : nyaman
# sialan : sial
# solusinya : solusi
# pokoknya : pokok
# daring : daring
# gabut : gabut
# karaokean : karaoke
# wfh : wfh
# diatasi : atas
# lur : lur
# ngirim : ngirim
# foto : foto
# videon : videon
# happened : happened
# you : you
# suddenly : suddenly
# went : went
# faster : faster
# glad : glad
# tho : tho
# samaa : samaa
# gaaada : gaaada
# kejelasan : jelas
# dipasang : pasang
# hhaha : hhaha
# agus : agus
# wkwkw : wkwkw
# kaka : kaka
# slank : slank
# sembur : sembur
# tenan : tenan
# well : well
# wasn : wasn
# beacuse : beacuse
# but : but
# where : where
# blame : blame
# tlg : tlg
# lagiii : lagiii
# huaaa : huaaa
# nyanyinya : nyanyi
# loncat : loncat
# gegra : gegra
# hadehhhh : hadehhhh
# bagus : bagus
# mengcape : mengcape
# kaga : kaga
# kelar : kelar
# ntr : ntr
# notip : notip
# bgtttt : bgtttt
# lem : lem
# wait : wait
# have : have
# any : any
# option : option
# lucky : lucky
# those : those
# assuming : assuming
# include : include
# and : and
# that : that
# pln : pln
# thingy : thingy
# agree : agree
# the : the
# best : best
# choice : choice
# though : though
# even : even
# their : their
# policy : policy
# shady : shady
# heck : heck
# trima : trima
# protes : protes
# kucing : kucing
# apasi : apas
# jlk : jlk
# dibikin : bikin
# kapok : kapok
# anjrit : anjrit
# pengen : ken
# nge : nge
# war : war
# kuntul : kuntul
# legendary : legendary
# eug : eug
# sungguh : sungguh
# paham : paham
# mekanisme : mekanisme
# pelayanan : layan
# maksimal : maksimal
# terhitung : hitung
# wifinya : wifinya
# ahahahah : ahahahah
# datanya : data
# pantes : pantes
# maintenance : maintenance
# sial : sial
# gws : gws
# santet : santet
# apaa : apaa
# drtd : drtd
# nyendat : nyendat
# vlive : vlive
# butuh : butuh
# yth : yth
# dibilang : bilang
# melengkapi : lengkap
# dimana : mana
# out : out
# topic : topic
# sattttttt : sattttttt
# tandain : tandain
# gelud : gelud
# dahlah : dah
# cok : cok
# nyerah : nyerah
# ama : ama
# kecewa : kecewa
# gpp : gpp
# pembngunan : pembngunan
# situ : situ
# sangaaaaaaaaaaaaaaaaaaaaaaat : sangaaaaaaaaaaaaaaaaaaaaaaat
# laaaaaaaaaaaamaaaaaaaa : laaaaaaaaaaaamaaaaaaaa
# thn : thn
# daftr : daftr
# pliss : pliss
# baepsae : baepsae
# dongggf : dongggf
# allahuakbar : allahuakbar
# kantor : kantor
# bersahabat : sahabat
# tlong : tlong
# samanya : sama
# nnton : nnton
# pacar : pacar
# dek : dek
# ajak : ajak
# gnight : gnight
# syg : syg
# met : met
# bobo : bobo
# duluan : duluan
# tolonf : tolonf
# anjrittt : anjrittt
# nangissssssssssssssss : nangissssssssssssssss
# livenya : livenya
# kolaborasi : kolaborasi
# jabotabek : jabotabek
# batavia : batavia
# see : see
# day : day
# menghadirkan : hadir
# keynote : keynote
# speaker : speaker
# founder : founder
# generation : generation
# girl : girl
# opening : opening
# speech : speech
# venusiana : venusiana
# direktur : direktur
# consumer : consumer
# udahlah : udahlah
# serunya : seru
# quiet : quiet
# place : place
# part : part
# catchplay : catchplay
# dagdigdug : dagdigdug
# babi : babi
# plis : plis
# laaaaaaab : laaaaaaab
# jancok : jancok
# ngapa : ngapa
# yaallahhh : yaallahhh
# manajemen : manajemen
# keuangan : uang
# kang : kang
# ojek : ojek
# kontrakan : kontra
# listrik : listrik
# uang : uang
# dapur : dapur
# pajak : pajak
# kuliah : kuliah
# amal : amal
# jajan : jajan
# nabung : nabung
# dll : dll
# pendapatan : dapat
# tukang : tukang
# bln : bln
# tampa : tampa
# utang : utang
# down : down
# bangsat : bangsat
# asik : asik
# ngelaggg : ngelaggg
# aaaaaa : aaaaaa
# anjj : anjj
# cimahi : cimahi
# utara : utara
# mbps : mbps
# donlot : donlot
# photo : photo
# nyamp : nyamp
# mb : mb
# menit : menit
# ohhh : ohhh
# pdhl : pdhl
# tgl : tgl
# sat : sat
# muter : muter
# spotify : spotify
# ngelagnya : ngelagnya
# berhenti : henti
# berlangganan : langgan
# makasih : makasih
# weyy : weyy
# buset : buset
# nowwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww : nowwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
# umsfess : umsfess
# zoom : zoom
# oke : oke
# indosat : indosat
# trnyata : trnyata
# pantesan : pantesan
# gada : gada
# lgie : lgie
# error : error
# tulung : tulung
# takokke : takokke
# sisan : sis
# kantore : kantore
# sok : sok
# ora : ora
# internete : internete
# asuuuu : asuuuu
# anjenkkk : anjenkkk
# kemusuhan : musuh
# bangtan : bangtan
# ngadat : ngadat
# gausah : gausah
# marah : marah
# gajelas : gajelas
# pingnya : pingnya
# hadehhh : hadehhh
# dikorup : korup
# berulah : ulah
# anjeng : anjeng
# kauuu : kauuu
# bgtbgt : bgtbgt
# first : first
# media : media
# meeting : meeting
# trsss : trsss
# ayok : ayok
# berantem : antem
# ngeselin : ngeselin
# oxygen : oxygen
# dapet : dapet
# review : review
# nder : nder
# mahal : mahal
# tbtb : tbtb
# brisik : brisik
# plislah : plislah
# apaniii : apaniii
# hah : hah
# ngadi : ngadi
# loe : loe
# urang : urang
# keur : keur
# tong : tong
# atuh : atuh
# mlm : mlm
# jlek : jlek
# yaaa : yaaa
# tag : tag
# ngelatih : ngelatih
# kesabaran : sabar
# mumpung : mumpung
# niat : niat
# temenan : temenan
# guys : guys
# kaliak : kaliak
# solo : solo
# biayanya : biaya
# kerjasamanya : kerjasamanya
# ngelagg : ngelagg
# anjirr : anjirr
# jel : jel
# banhet : banhet
# jaringannyabadehhh : jaringannyabadehhh
# knapa : knapa
# sihh : sihh
# ahhh : ahhh
# woi : woi
# tolonglah : tolong
# oalaa : oalaa
# asww : asww
# bat : bat
# anjenk : anjenk
# ijinin : ijinin
# vlivenya : vlivenya
# brenti : brenti
# langganan : langgan
# percepat : cepat
# perlemot : lot
# anjid : anjid
# busuk : busuk
# lucas : lucas
# pengaturan : atur
# sisi : sisi
# sentral : sentral
# dicoba : coba
# balas : balas
# lbh : lbh
# sehat : sehat
# aplgi : aplgi
# blh : blh
# kluar : kluar
# mkn : mkn
# warteg : warteg
# jtah : jtah
# wktu : wktu
# mnt : mnt
# bru : bru
# nyuci : nyuci
# tgn : tgn
# digedor : gedor
# satpol : satpol
# ngisi : ngisi
# luang : luang
# marathon : marathon
# film : film
# series : series
# drakor : drakor
# angin : angin
# musim : musim
# berbaik : baik
# hati : hati
# karna : karna
# tumben : tumben
# hdh : hdh
# nit : nit
# now : now
# swear : swear
# god : god
# dighosting : dighosting
# apaaan : apaaan
# dahh : dahh
# nelfon : nelfon
# nawar : nawar
# nawarin : nawarin
# aduh : aduh
# tolonglaaahhh : tolonglaaahhh
# bngtttt : bngtttt
# nihhh : nihhh
# daerah : daerah
# pondok : pondok
# melati : melati
# bgttt : bgttt
# ngeh : ngeh
# tersembunyi : sembunyi
# iklannya : iklan
# terendah : rendah
# telepon : telepon
# telpon : telpon
# mksh : mksh
# dibantu : bantu
# slow : slow
# respon : respon
# bangaaatttsss : bangaaatttsss
# tpi : tpi
# asli : asli
# gapernah : gapernah
# sepengen : ken
# nampol : nampol
# kepengen : ken
# mendadak : dadak
# heran : heran
# jujur : jujur
# kaget : kaget
# sma : sma
# kompromi : kompromi
# anjg : anjg
# ngerti : ngerti
# iki : iki
# kos : kos
# nganggo : nganggo
# dudu : dudu
# pokoke : pokoke
# souwiii : souwiii
# pol : pol
# victor : victor
# mengalami : alami
# betingkah : beting
# patch : patch
# genshin : genshin
# selese : selese
# buffering : buffering
# muluu : muluu
# gabisaa : gabisaa
# twitch : twitch
# skrng : skrng
# gblk : gblk
# duel : duel
# menang : menang
# super : super
# terjangkau : jangkau
# pulau : pulau
# jawa : jawa
# tenang : tenang
# melayani : layan
# pemasangan : pasang
# hubungi : hubung
# keroyok : keroyok
# help : help
# samaan : sama
# ngotak : ngotak
# iih : iih
# bunny : bunny
# hahh : hahh
# engga : engga
# dongg : dongg
# nieeee : nieeee
# guebmau : guebmau
# bangkek : bangkek
# koneksine : koneksine
# mosok : mosok
# yutub : yutub
# soalny : soalny
# drtadi : drtadi
# asikk : asikk
# brader : brader
# gameqoo : gameqoo
# diakses : akses
# skripsian : skripsi
# trace : trace
# internal : internal
# singapore : singapore
# jelekkkkk : jelekkkkk
# kenapasih : kenapasih
# luuuuuuuu : luuuuuuuu
# plsss : plsss
# nyanyi : nyanyi
# masyaallag : masyaallag
# lumayan : lumayan
# bentaran : bentar
# please : please
# beg : beg
# plss : plss
# ngandet : ngandet
# menuntut : tuntut
# ilmu : ilmu
# indischool : indischool
# diniatin : diniatin
# gelar : gelar
# sarjana : sarjana
# bgstttttttttt : bgstttttttttt
# ngelive : ngelive
# bis : bis
# abisanyavlo : abisanyavlo
# sekahrang : sekahrang
# kondisi : kondisi
# darah : darah
# ppp : ppp
# gangguann : gangguann
# ddeeehh : ddeeehh
# beut : beut
# netflixan : netflixan
# stalking : stalking
# opa : opa
# korea : korea
# internetan : internetan
# ngacir : ngacir
# betah : betah
# maksutnya : maksutnya
# pingin : pingin
# gebug : gebug
# siah : siah
# waferkeju : waferkeju
# hdk : hdk
# mngeluh : mngeluh
# cuss : cuss
# maraaaah : maraaaah
# daritadi : daritadi
# file : file
# disconnect : disconnect
# indikatornya : indikator
# netflix : netflix
# gaksi : gaksi
# lemotttt : lemotttt
# anji : anji
# ayodong : ayodong
# bismillah : bismillah
# kerjasamamnya : kerjasamamnya
# mengsedih : mengsedih
# brengsseeeeeeekkk : brengsseeeeeeekkk
# pandemi : pandemi
# menguatkan : kuat
# menyemangati : semangat
# dukung : dukung
# atlet : atlet
# games : games
# bangga : bangga
# semangatin : semangatin
# sbln : sbln
# lemottt : lemottt
# lwmot : lwmot
# skl : skl
# rebahan : rebah
# perfect : perfect
# filmnya : film
# lancarr : lancarr
# ngapasi : ngapasi
# loose : loose
# streak : streak
# can : can
# suck : suck
# dick : dick
# ngehe : ngehe
# houseki : houseki
# kuni : kuni
# asstaghfirullah : asstaghfirullah
# lemotnya : lot
# think : think
# whats : whats
# wrong : wrong
# beomgyu : beomgyu
# istipar : istipar
# brati : brati
# prnah : prnah
# murahnya : murah
# gatau : gatau
# jan : jan
# wtf : wtf
# space : space
# medsos : medsos
# serasa : serasa
# goa : goa
# pusat : pusat
# lamcar : lamcar
# ber : ber
# alamat : alamat
# namanya : nama
# taunya : tau
# chat : chat
# nangid : nangid
# kupake : kupake
# ajasi : ajasi
# asliii : asliii
# problem : problem
# mben : mben
# dino : dino
# jua : jua
# didatangi : datang
# aturannya : atur
# masuk : masuk
# otomatis : otomatis
# putus : putus
# misuh : misuh
# new : new
# fitur : fitur
# pengingat : ingat
# pembayaran : bayar
# diunduh : unduh
# mudah : mudah
# praktis : praktis
# smart : smart
# serem : rem
# sinyalnya : sinyal
# too : too
# good : good
# true : true
# jaem : jaem
# ne : ne
# jwb : jwb
# isinya : isi
# heatubun : heatubun
# aiz : aiz
# diperoleh : oleh
# surat : surat
# kontrak : kontrak
# myindihome : myindihome
# struk : struk
# bukti : bukti
# hamzi : hamzi
# peli : pel
# konek : konek
# linetoday : linetoday
# dibuka : buka
# terimakasih : terimakasih
# kualitasnya : kualitas
# berdoa : doa
# ampuni : ampun
# tabab : tabab
# ketahui : tahu
# pahami : paham
# ketersediaan : sedia
# pilih : pilih
# penawaran : tawar
# yuuukkk : yuuukkk
# salah : salah
# njrrrr : njrrrr
# bersntem : bersntem
# bange : bange
# nihhhhh : nihhhhh
# gapapa : gapapa
# beda : beda
# pelangi : pelangi
# utama : utama
# sedingin : sedingin
# diluar : luar
# memberulkan : memberulkan
# angka : angka
# soraya : soraya
# ratau : ratau
# sinyale : sinyale
# melu : melu
# yoan : yoan
# lemote : lemote
# nget : nget
# tersayang : sayang
# dibalas : balas
# akutu : akutu
# berhari : hari
# rto : rto
# gbisa : gbisa
# chrome : chrome
# fadel : fadel
# karakter : karakter
# terbaik : baik
# penentu : tentu
# kemenangan : menang
# rekomendasi : rekomendasi
# memutuskan : putus
# push : push
# rank : rank
# beneur : beneur
# gais : gais
# info : info
# hide : hide
# nama : nama
# nutup : nutup
# step : step
# gmna : gmna
# keponakan : keponakan
# ngegamenya : ngegamenya
# senang : senang
# pakek : pakek
# ngelek : ngelek
# istighfar : istighfar
# selamat : selamat
# fahri : fahri
# membayar : bayar
# tanggal : tanggal
# aktifkan : aktif
# ngelunjak : ngelunjak
# gambar : gambar
# perumahan : rumah
# taman : taman
# ria : ria
# persada : persada
# kmpng : kmpng
# cigabel : cigabel
# kel : kel
# cibeuteng : cibeuteng
# muara : muara
# kec : kec
# ciseeng : ciseeng
# beli : beli
# rmh : rmh
# perum : perum
# tsb : tsb
# desember : desember
# blm : blm
# krg : krg
# hrs : hrs
# kolektip : kolektip
# busetdah : busetdah
# nerbener : nerbener
# webtoon : webtoon
# nongol : nongol
# halamannya : halaman
# weyyy : weyyy
# gila : gila
# gilaan : gila
# ancurnya : ancurnya
# capeee : capeee
# menurun : turun
# mencapai : capai
# fup : fup
# ayolaah : ayolaah
# mulaiiiiiiiiiiiiiiiiiii : mulaiiiiiiiiiiiiiiiiiii
# github : github
# stackoverflow : stackoverflow
# quora : quora
# reddit : reddit
# ngetroll : ngetroll
# tae : tae
# giliran : gilir
# ketemu : ketemu
# musuh : musuh
# perbulannya : bulan
# area : area
# bsd : bsd
# getting : getting
# nerves : nerves
# kenapasi : napas
# rlly : rlly
# works : works
# fine : fine
# just : just
# doesnt : doesnt
# reach : reach
# room : room
# smartfren : smartfren
# smua : smua
# hidup : hidup
# aaaaa : aaaaa
# follow : follow
# like : like
# retweet : retweet
# bisaaa : bisaaa
# kenape : kenape
# lambat : lambat
# video : video
# youtube : youtube
# rendah : rendah
# loadingnya : loadingnya
# sukanya : suka
# wkwkkwkw : wkwkkwkw
# membara : bara
# mereview : mereview
# kecacatan : cacat
# indi : indi
# woy : woy
# influencer : influencer
# product : product
# tanggung : tanggung
# productnya : productnya
# monyet : monyet
# wkawkw : wkawkw
# niatan : niat
# valo : valo
# bngsd : bngsd
# cacaddd : cacaddd
# admin : admin
# infonya : info
# badmood : badmood
# indihomo : indihomo
# ledig : ledig
# mampussss : mampussss
# fyi : fyi
# eror : eror
# limit : limit
# kmaren : kmaren
# dikasih : kasih
# ttg : ttg
# gfriend : gfriend
# mean : mean
# ceunah : ceunah
# setahun : tahun
# ngira : ngira
# ngasal : ngasal
# quote : quote
# kebeneran : kebeneran
# anaknya : anak
# ramalan : ramal
# adi : adi
# uman : uman
# kasian : kasi
# mbs : mbs
# raja : raja
# eja : eja
# sucks : sucks
# gelut : gelut
# name : name
# dikomplain : komplain
# beribu : ibu
# ribu : ribu
# ndak : ndak
# wkwkwkw : wkwkwkw
# terossss : terossss
# sejam : jam
# ubah : ubah
# nontom : nontom
# syaland : syaland
# bye : bye
# semalem : semalem
# scroll : scroll
# archive : archive
# story : story
# auto : auto
# flashback : flashback
# ngelakuin : ngelakuin
# aktivitas : aktivitas
# batas : batas
# pcr : pcr
# terusssss : terusssss
# maksud : maksud
# lukhhh : lukhhh
# alasan : alas
# makek : makek
# punten : punten
# nuhun : nuhun
# ngerjain : ngerjain
# kerjaan : kerja
# teknisi : teknisi
# monggo : monggo
# zzzz : zzzz
# hhhhhh : hhhhhh
# yaampunn : yaampunn
# kelas : kelas
# woyy : woyy
# bantuin : bantuin
# pengguna : guna
# tayaaa : tayaaa
# bgtt : bgtt
# mnyet : mnyet
# nugas : nugas
# makasihhh : makasihhh
# netflikss : netflikss
# yakk : yakk
# males : males
# yeee : yeee
# menangis : menang
# playlist : playlist
# sebwah : sebwah
# musik : musik
# mendengarkan : dengar
# slur : slur
# bantuannya : bantu
# linknya : linknya
# power : power
# menyala : nyala
# gress : gress
# okay : okay
# princess : princess
# hug : hug
# ngasi : ngasi
# gif : gif
# bcs : bcs
# batesin : batesin
# penggunaan : guna
# ngalapain : ngalapain
# hantu : hantu
# mas : mas
# nyesel : nyesel
# jt : jt
# link : link
# wr : wr
# rb : rb
# canon : canon
# pixma : pixma
# all : all
# one : one
# print : print
# scan : scan
# copy : copy
# windows : windows
# pro : pro
# original : original
# microsoft : microsoft
# office : office
# student : student
# tambahlah : tambah
# biaya : biaya
# total : total
# aaaaaaaaa : aaaaaaaaa
# bgdd : bgdd
# maraton : maraton
# marvel : marvel
# tanjung : tanjung
# pandan : pandan
# manggar : manggar
# gang : gang
# sesempit : sempit
# tercapai : capai
# tapian : tapi
# kemon : kemon
# men : men
# realitas : realitas
# elu : elu
# nyusahin : nyusahin
# gueee : gueee
# kumat : kumat
# huhu : huhu
# ksl : ksl
# bangkrut : bangkrut
# seru : seru
# andreas : andreas
# pemilik : milik
# lakukan : laku
# pengecekan : kece
# koordinasi : koordinasi
# ikutan : ikut
# wiro : wiro
# vendy : vendy
# webinar : webinar
# santripreneur : santripreneur
# nol : nol
# ira : ira
# wan : wan
# aleeya : aleeya
# kaum : kaum
# menghasilkan : hasil
# gampang : gampang
# let : let
# check : check
# this : this
# busetdeh : busetdeh
# ngape : ngape
# ieiend : ieiend
# ketawa : ketawa
# trending : trending
# kedip : kedip
# interenetnya : interenetnya
# ass : ass
# kampret : kampret
# benang : benang
# layangan : layang
# bngst : bngst
# malu : malu
# ntar : ntar
# user : user
# hungkul : hungkul
# kebuka : buka
# videonya : video
# penyebab : sebab
# imun : imun
# turun : turun
# terkena : kena
# covid : covid
# hahaha : hahaha
# sngat : sngat
# lemodh : lemodh
# asuuuuu : asuuuuu
# kontak : kontak
# kecot : kecot
# bacot : bacot
# ngelagfgg : ngelagfgg
# maen : maen
# buriq : buriq
# dpan : dpan
# tmpat : tmpat
# jualnya : jual
# mnta : mnta
# puter : puter
# pgn : pgn
# boker : boker
# samping : samping
# gerobak : gerobak
# abng : abng
# ijo : ijo
# liurnya : liur
# netes : netes
# kuah : kuah
# njir : njir
# ran : ran
# diinformasikan : informasi
# permintaan : minta
# solusikan : solusi
# colok : colok
# mouse : mouse
# hadeeehhhh : hadeeehhhh
# hyunbaek : hyunbaek
# wkwkwkwk : wkwkwkwk
# gatel : gatel
# ngedown : ngedown
# broo : broo
# who : who
# hurt : hurt
# saran : saran
# mantep : mantep
# guysss : guysss
# najis : najis
# jijik : jijik
# gaess : gaess
# tonton : tonton
# dpet : dpet
# tvri : tvri
# indosiar : indosiar
# champions : champions
# tsel : tsel
# jele : jele
# taii : taii
# berlaku : laku
# wilayah : wilayah
# gadeng : gadeng
# kayanya : kaya
# idk : idk
# mancing : mancing
# surprised : surprised
# quipper : quipper
# apk : apk
# didiemin : didiemin
# brengseknya : brengsek
# cepet : cepet
# direfresh : direfresh
# talent : talent
# dorm : dorm
# test : test
# paketnya : paket
# connect : connect
# kedap : kedap
# los : los
# jahat : jahat
# uwu : uwu
# having : having
# another : another
# level : level
# patience : patience
# thread : thread
# post : post
# real : real
# pict : pict
# tweeps : tweeps
# master : master
# indigo : indigo
# indomie : indomie
# taikkk : taikkk
# anjink : anjink
# connecting : connecting
# cacad : cacad
# dengerin : dengerin
# discord : discord
# macem : macem
# robot : robot
# flis : flis
# ngegame : ngegame
# keprett : keprett
# dunia : dunia
# cerah : cerah
# jatimbalinusra : jatimbalinusra
# karya : karya
# tanpabatas : tanpabatas
# horror : horror
# ceramah : ceramah
# jilat : jilat
# kwooon : kwooon
# telk : telk
# msel : msel
# gamampu : gamampu
# diganti : ganti
# routernya : routernya
# tiket : tiket
# whyyy : whyyy
# ngedaftar : ngedaftar
# pegang : pegang
# njeng : njeng
# nik : nik
# kesel : kesel
# akbar : akbar
# sampah : sampah
# kdng : kdng
# bgus : bgus
# capek : capek
# jing : jing
# in : in
# guoblok : guoblok
# butuhin : butuhin
# tugas : tugas
# deadline : deadline
# bentar : bentar
# skakdbfkjshs : skakdbfkjshs
# uploadddd : uploadddd
# bareng : bareng
# rossa : rossa
# musisi : musisi
# langit : langit
# fina : fina
# lan : lan
# ont : ont
# port : port
# ditunggu : tunggu
# prully : prully
# doru : doru
# pemakaian : pakai
# melebihi : lebih
# berdampak : dampak
# direset : direset
# cabut : cabut
# selfie : selfie
# nyuruh : nyuruh
# pinjol : pinjol
# emosii : emosi
# kay : kay
# misuhin : misuhin
# asyik : asyik
# kontol : kontol
# jernih : jernih
# hadeh : hadeh
# seneng : neng
# kamprett : kamprett
# assalamualaikum : assalamualaikum
# rockstar : rockstar
# services : services
# korean : korean
# diblock : diblock
# bingung : bingung
# dibelakang : belakang
# tower : tower
# nyampee : nyampee
# maju : maju
# mimin : mimin
# tweet : tweet
# jaman : jaman
# modern : modern
# ngabisin : ngabisin
# speednya : speednya
# iseng : iseng
# semoga : moga
# adminnya : adminnya
# nyamper : nyamper
# hey : hey
# ngapain : ngapain
# taggg : taggg
# doi : doi
# trobel : trobel
# ilang : ilang
# ilangan : ilangan
# sekarat : sekarat
# jurus : jurus
# kambing : kambing
# berperang : perang
# jamall : jamall
# kena : kena
# lagii : lagi
# aduhhh : aduhhh
# csnya : csnya
# mint : mint
# xixixi : xixixi
# kad : kad
# galo : galo
# keknya : kek
# wifiny : wifiny
# lost : lost
# connection : connection
# ihhh : ihhh
# nyetor : nyetor
# mintol : mintol
# kumpulin : kumpulin
# tri : tri
# kaah : kaah
# welcome : welcome
# club : club
# late : late
# adalagi : adalagi
# layani : layan
# orbit : orbit
# dipakai : pakai
# spt : spt
# plasa : plasa
# terdekat : dekat
# guyss : guyss
# solusi : solusi
# jitu : jitu
# msuk : msuk
# bertumboook : bertumboook
# seharian : hari
# unlimited : unlimited
# jamin : jamin
# lgi : lgi
# astagaa : astagaa
# docx : docx
# serverr : serverr
# tangerang : tangerang
# kota : kota
# tepatnya : tepat
# dinperum : dinperum
# mendengar : dengar
# kabar : kabar
# baiknya : baik
# menikmati : nikmat
# nugro : nugro
# rekomended : rekomended
# cepat : cepat
# useetv : useetv
# bangsatlah : bangsat
# dajjal : dajjal
# izin : izin
# kmrn : kmrn
# nikah : nikah
# stresssss : stresssss
# astaga : astaga
# sena : sena
# informasi : informasi
# ragu : ragu
# azhar : azhar
# remote : remote
# rusak : rusak
# usulan : usul
# mengganti : ganti
# baterai : baterai
# ttp : ttp
# berfungsi : fungsi
# thankyou : thankyou
# dobel : dobel
# ultraman : ultraman
# komisaris : komisaris
# mengganggu : ganggu
# bandung : bandung
# tersambung : sambung
# tmn : tmn
# indihomenya : indihomenya
# fast : fast
# mantul : mantul
# tuo : tuo
# ngene : ngene
# karo : karo
# cepetan : cepetan
# ngebadut : ngebadut
# tulong : tulong
# wingi : wing
# arep : arep
# omahku : omahku
# jare : jare
# terpencil : pencil
# geret : geret
# ndek : ndek
# pinggir : pinggir
# dalan : dal
# gedhe : gedhe
# ben : ben
# iso : iso
# masang : masang
# conection : conection
# kyknya : kyknya
# rasis : ras
# gamers : gamers
# hadeuhh : hadeuhh
# laju : laju
# hujan : hujan
# turboo : turboo
# glory : glory
# buangetttt : buangetttt
# kehambat : hambat
# anjjjjjj : anjjjjjj
# abdurrh : abdurrh
# otw : otw
# blokir : blokir
# username : username
# bulukehidupan : bulukehidupan
# langganannya : langgan
# transaksi : transaksi
# sahabat : sahabat
# bangeet : bangeet
# bosan : bosan
# kegiatanku : giat
# slama : slama
# anime : anime
# oasuuu : oasuuu
# headline : headline
# melaporkan : lapor
# demak : demak
# mahasiswa : mahasiswa
# berinisial : inisial
# sad : sad
# digrebek : digrebek
# lantaran : lantar
# pelaku : laku
# mencoba : coba
# kerusuhan : rusuh
# nekat : nekat
# menerobos : terobos
# pagar : pagar
# penjelasan : jelas
# nisa : nisa
# lebihlanjut : lebihlanjut
# selanjut : lanjut
# sgini : sgini
# gamau : gamau
# pulpen : pulpen
# putih : putih
# ajukan : aju
# keluhan : keluh
# petang : petang
# action : action
# selemot : lot
# peltaman : peltaman
# pcrn : pcrn
# virtual : virtual
# gasuka : gasuka
# overthinking : overthinking
# nungguin : nungguin
# telfonan : telfonan
# berjam : jam
# sayang : sayang
# hubunganku : hubung
# kandas : kandas
# menemaniku : teman
# pacarku : pacar
# gapai : gapai
# drakoran : drakoran
# tuwek : tuwek
# anti : anti
# gan : gan
# ngapaseh : ngapaseh
# item : item
# postingannya : postingannya
# tnya : tnya
# dunk : dunk
# sodara : sodara
# memasang : pasang
# hadiah : hadiah
# honestly : honestly
# debat : debat
# kinda : kinda
# them : them
# hufft : hufft
# digit : digit
# lampunya : lampu
# bos : bos
# fifa : fifa
# perasaan : asa
# jatuh : jatuh
# tempo : tempo
# nelpon : nelpon
# cant : cant
# play : play
# for : for
# week : week
# lapor : lapor
# blum : blum
# tindakan : tindak
# anjr : anjr
# baikan : baik
# sepuasnya : puas
# cerita : cerita
# naikin : naikin
# nambah : nambah
# diskon : diskon
# huellooww : huellooww
# kmn : kmn
# ngeluh : ngeluh
# luanmaaa : luanmaaa
# bin : bin
# ribet : ribet
# pemutusan : putus
# berjalan : jalan
# isshhh : isshhh
# lemott : lemott
# trss : trss
# mslh : mslh
# istri : istri
# campur : campur
# kuping : kuping
# dikorekin : dikorekin
# cotton : cotton
# bud : bud
# tinggl : tinggl
# kesulitan : sulit
# skolh : skolh
# jrngan : jrngan
# psng : psng
# orbitstar : orbitstar
# ktnya : ktnya
# wuss : wuss
# wusss : wusss
# parlay : parlay
# masbit : masbit
# nyimak : nyimak
# twitwar : twitwar
# pastinya : pasti
# berkah : berkah
# ujian : uji
# perpajakan : paja
# international : international
# matkul : matkul
# setia : setia
# beraktivitas : aktivitas
# waaw : waaw
# ajah : ajah
# bersyukur : syukur
# gaees : gaees
# sekaliii : sekaliii
# putra : putra
# webinarnya : webinarnya
# bermanfaat : manfaat
# berjuang : juang
# rebahahan : rebahahan
# chill : chill
# abis : abis
# pacaran : pacar
# kampuang : kampuang
# ngak : ngak
# ngaruh : ngaruh
# tethering : tethering
# cuaca : cuaca
# puanas : puanas
# posisi : posisi
# berangin : angin
# tembok : tembok
# bahagia : bahagia
# bit : bit
# dimenangke : dimenangke
# liyo : liyo
# wae : wae
# ketiduran : tidur
# tiduran : tidur
# nga : nga
# apresiasinya : apresiasi
# tmen : tmen
# donk : donk
# mlez : mlez
# maki : maki
# soale : soale
# sedino : sedino
# signale : signale
# koyo : koyo
# urip : urip
# nang : nang
# alas : alas
# purwo : purwo
# diomelin : diomelin
# bsa : bsa
# laen : laen
# calon : calon
# ditelp : ditelp
# keangkat : angkat
# nelp : nelp
# mandi : mandi
# tidur : tidur
# training : training
# personilnya : personilnya
# hour : hour
# vaksin : vaksin
# microchip : microchip
# nyobain : nyobain
# retwit : retwit
# hestek : hestek
# penyakit : sakit
# perjalanan : jalan
# padang : padang
# mahsyar : mahsyar
# lemooooot : lemooooot
# ngeluarin : ngeluarin
# khusus : khusus
# enyah : enyah
# artistic : artistic
# gymnastic : gymnastic
# keburu : keburu
# bersaing : saing
# idih : idih
# vidio : vidio
# stress : stress
# enhypen : enhypen
# sedap : sedap
# tagline : tagline
# sore : sore
# haram : haram
# ihh : ihh
# jossss : jossss
# gandos : gandos
# kemaren : kemaren
# reset : reset
# anjingg : anjingg
# olympics : olympics
# yak : yak
# diatur : atur
# laach : laach
# dns : dns
# brouu : brouu
# situs : situs
# porn : porn
# matiii : matiii
# membahas : bahas
# berlanganan : berlanganan
# lho : lho
# jarene : jarene
# laaaaahhh : laaaaahhh
# wis : wis
# durung : durung
# suami : suami
# beres : beres
# kabelnya : kabel
# aan : aan
# sigap : sigap
# hatur : hatur
# umur : umur
# rezeki : rezeki
# ngeload : ngeload
# stream : stream
# vidiodotcom : vidiodotcom
# keseruannya : seru
# alhamdulillah : alhamdulillah
# mantaps : mantaps
# sabarr : sabarr
# pngn : pngn
# banting : banting
# rese : rese
# mbayar : mbayar
# cuk : cuk
# reconnecting : reconnecting
# yaahhh : yaahhh
# staytune : staytune
# barang : barang
# semangatt : semangatt
# samalah : sama
# dipedalaman : dalam
# hutan : hutan
# tembung : tembung
# stick : stick
# kelap : kelap
# kelip : kelip
# ajaaaa : ajaaaa
# askrl : askrl
# numpang : numpang
# disitu : situ
# btw : btw
# kesini : kesini
# drugstore : drugstore
# salty : salty
# firstmed : firstmed
# erlianto : erlianto
# coverage : coverage
# isp : isp
# budget : budget
# perusahaan : usaha
# dedicated : dedicated
# astinet : astinet
# iforte : iforte
# broadband : broadband
# beralih : alih
# listnya : listnya
# aksi : aksi
# ugh : ugh
# les : les
# aaaahh : aaaahh
# ngedet : ngedet
# serius : serius
# kabell : kabell
# customernya : customernya
# ngeluhnya : ngeluhnya
# jugaa : jugaa
# ngeblock : ngeblock
# olympic : olympic
# bokek : bokek
# hmm : hmm
# kawan : kawan
# gajian : gaji
# eiitss : eiitss
# mindie : mindie
# tips : tips
# bertahan : tahan
# frik : frik
# bangsatt : bangsatt
# lemotnyaa : lemotnyaa
# ceknya : cek
# naiknya : naik
# benerin : benerin
# tiang : tiang
# deket : deket
# guwa : guwa
# magrib : magrib
# kerumah : rumah
# abang : abang
# nye : nye
# nko : nko
# viral : viral
# mahasiswi : mahasiswi
# kaliya : kaliya
# awam : awam
# sam : sam
# dikantor : kantor
# local : local
# server : server
# software : software
# pergudangan : gudang
# penjualan : jual
# distributor : distributor
# fmcg : fmcg
# dahhhh : dahhhh
# jojo : jojo
# bawa : bawa
# disuruh : suruh
# anthony : anthony
# ginting : ginting
# melaju : laju
# babak : babak
# perempat : empat
# final : final
# bulutangkis : bulutangkis
# pria : pria
# kanta : kanta
# tsuneyama : tsuneyama
# set : set
# lahhh : lahhh
# kesayangan : sayang
# apaansi : apaansi
# hilih : hilih
# daryati : daryati
# stop : stop
# ekspetasi : ekspetasi
# raka : raka
# berkas : berkas
# khawatir : khawatir
# upload : upload
# tibalik : tibalik
# genti : genti
# ngurusna : ngurusna
# sieta : sieta
# jeung : jeung
# balesnya : balesnya
# bersabar : sabar
# menta : menta
# persyaratan : syarat
# kodir : kodir
# ajaaaaaa : ajaaaaaa
# sigit : sigit
# sempet : sempet
# kelewat : lewat
# yoongi : yoongi
# galau : galau
# ulangnya : ulang
# hilang : hilang
# tar : tar
# pesaingannya : saing
# tinggalin : tinggalin
# mampus : mampus
# awiez : awiez
# telfon : telfon
# line : line
# busy : busy
# panggilan : panggil
# pasar : pasar
# bkn : bkn
# app : app
# fakyu : fakyu
# gapaham : gapaham
# maunya : mau
# apasiiiiii : apasiiiiii
# sim : sim
# card : card
# settings : settings
# matiin : matiin
# nyalain : nyalain
# bales : bales
# fiks : fiks
# imperfect : imperfect
# kocak : kocak
# wetv : wetv
# untungnya : untung
# nontonnya : nontonnya
# suckss : suckss
# hape : hape
# vpn : vpn
# turnam : turnam
# salahnya : salah
# luncurkan : luncur
# gandeng : gandeng
# artis : artis
# content : content
# creator : creator
# pekalongan : kalong
# syaratnya : syarat
# keperluan : perlu
# dilanjut : lanjut
# dongggg : dongggg
# disluru : disluru
# mnyajikn : mnyajikn
# chanel : chanel
# bgs : bgs
# lncr : lncr
# kintil : kintil
# plsssss : plsssss
# berkwalitas : berkwalitas
# bultang : bultang
# sll : sll
# flop : flop
# bisaa : bisaa
# punga : punga
# vari : vari
# haloo : haloo
# tdi : tdi
# conect : conect
# ketrngan : ketrngan
# sprti : sprti
# mhon : mhon
# nyari : nyari
# manjur : manjur
# diajak : ajak
# kirim : kirim
# diawal : awal
# dijelasin : dijelasin
# teknis : teknis
# syarat : syarat
# ketentuan : tentu
# scr : scr
# rinci : rinci
# akunya : aku
# form : form
# dibilangin : dibilangin
# kontraknya : kontrak
# cont : cont
# mabarnya : mabarnya
# keganggu : ganggu
# nisatun : nisatun
# teume : teume
# trbaik : trbaik
# pstikn : pstikn
# cpt : cpt
# stbil : stbil
# untk : untk
# mmenuhi : mmenuhi
# kbthn : kbthn
# srba : srba
# mensyen : mensyen
# ajig : ajig
# ayeuna : ayeuna
# heubeul : heubeul
# dilemparin : dilemparin
# solehudin : solehudin
# permainkan : main
# corporate : corporate
# kebutuhannya : butuh
# pilihannya : pilih
# icon : icon
# browsing : browsing
# standar : standar
# mnc : mnc
# firstmedia : firstmedia
# wnya : wnya
# customer : customer
# dibereskan : beres
# bekas : bekas
# terpakai : pakai
# gtgt : gtgt
# bedaaa : bedaaa
# bisanya : bisa
# antenaaa : antenaaa
# anjrod : anjrod
# jsxjjajdjjs : jsxjjajdjjs
# dilombok : lombok
# fuck : fuck
# colokan : colok
# agentnya : agentnya
# wiyono : wiyono
# aduhhhh : aduhhhh
# quest : quest
# cutscene : cutscene
# timed : timed
# login : login
# screen : screen
# fawk : fawk
# yewww : yewww
# kejadian : jadi
# slalu : slalu
# abdillah : abdillah
# refreshkan : refreshkan
# sarankan : saran
# menghapus : hapus
# postingan : postingan
# berisi : isi
# nanganinnya : nanganinnya
# huft : huft
# iyaaa : iyaaa
# fansign : fansign
# bangeeet : bangeeet
# gaes : gaes
# guess : guess
# depends : depends
# resides : resides
# maaci : maaci
# terpaksa : paksa
# score : score
# letoy : letoy
# bhay : bhay
# terbaru : baru
# sharing : sharing
# pkak : pkak
# indikator : indikator
# merahnya : merah
# krna : krna
# kemana : mana
# bal : bal
# dibagi : bagi
# astaghfirullah : astaghfirullah
# gapunya : gapunya
# premium : premium
# perbaiki : baik
# ceria : ceria
# datangkan : datang
# team : team
# mengecek : ecek
# bray : bray
# rival : rival
# kageyama : kageyama
# hinata : hinata
# rivalitas : rivalitas
# enjoy : enjoy
# again : again
# ismi : ismi
# ati : ati
# menemani : tani
# buruk : buruk
# yahhh : yahhh
# noninternet : noninternet
# minn : minn
# oala : oala
# yupie : yupie
# dicek : cek
# joro : joro
# kmu : kmu
# ajung : ajung
# diblokir : blokir
# penangan : nang
# benget : benget
# pelosok : pelosok
# mengecewakan : kecewa
# ktanya : ktanya
# klau : klau
# wkkwkak : wkkwkak
# guee : guee
# ajaaa : ajaaa
# brengsek : brengsek
# password : password
# diksh : diksh
# passwordnya : passwordnya
# riky : riky
# perbandingan : banding
# idya : idya
# produk : produk
# penampakan : tampak
# mengcover : mengcover
# karyawan : karyawan
# manteb : manteb
# mam : mam
# lamun : lamun
# mencet : mencet
# tombol : tombol
# off : off
# teubisa : teubisa
# pencet : pencet
# jerawat : jerawat
# batur : batur
# kitu : kitu
# temanku : teman
# absen : absen
# podcast : podcast
# wajar : wajar
# berlama : lama
# yaampun : yaampun
# nie : nie
# dasar : dasar
# ngangkat : ngangkat
# jago : jago
# gamenya : gamenya
# skill : skill
# trik : trik
# ahh : ahh
# hebat : hebat
# mainnya : main
# nikmati : nikmat
# seamless : seamless
# kemudahan : mudah
# genggaman : genggam
# segitu : segitu
# saluran : salur
# masaa : masaa
# makasiihh : makasiihh
# udic : udic
# kiriman : kirim
# lampiran : lampir
# draft : draft
# kb : kb
# nomer : nomer
# myid : myid
# geus : geus
# kumaha : maha
# keluh : keluh
# kesah : kesah
# deui : deui
# log : log
# menu : menu
# navigasi : navigasi
# beranda : beranda
# klik : klik
# ikon : ikon
# add : add
# halaman : halaman
# ressurect : ressurect
# ahiyaa : ahiyaa
# waittt : waittt
# dicepuin : dicepuin
# sie : sie
# nnt : nnt
# krs : krs
# tercinta : cinta
# mgg : mgg
# hikkssssssssssssssssssssssssss : hikkssssssssssssssssssssssssss
# bsk : bsk
# annya : annya
# ariefianto : ariefianto
# keluarga : keluarga
# patuhi : patuh
# protocol : protocol
# kesehatan : sehat
# nice : nice
# setannn : setannn
# asdfghjkl : asdfghjkl
# tetiba : tetiba
# badminton : badminton
# iniii : iniii
# bayangin : bayangin
# betapa : betapa
# hampa : hampa
# wkwkkw : wkwkkw
# disituasi : situasi
# aloo : aloo
# cdm : cdm
# mamang : mamang
# pleng : pleng
# puncak : puncak
# komedi : komedi
# hubungannya : hubung
# enaknya : enak
# wkkwkwk : wkkwkwk
# mantab : mantab
# biarkan : biar
# tanggapan : tanggap
# akun : akun
# fungsi : fungsi
# sentausa : sentausa
# gasss : gasss
# yukk : yukk
# yakkkk : yakkkk
# pules : pules
# ditlp : ditlp
# mauk : mauk
# selesai : selesai
# ngomong : ngomong
# sopan : sopan
# santunnya : santun
# tika : tika
# interactive : interactive
# tweeted : tweeted
# yahh : yahh
# gamake : gamake
# infonyaa : infonyaa
# dramanya : drama
# inilho : inilho
# iye : iye
# huhuhu : huhuhu
# periscope : periscope
# graha : graha
# raya : raya
# bintaro : bintaro
# selatan : selatan
# republic : republic
# jangkauannya : jangkau
# kayaknya : kayak
# ngeledek : ngeledek
# kedok : kedok
# icha : icha
# rekan : rekan
# dwika : dwika
# btul : btul
# kaaa : kaaa
# otak : otak
# wkkw : wkkw
# kunci : kunci
# profesional : profesional
# wujudkan : wujud
# impianmu : impi
# berkualitas : kualitas
# malas : malas
# olahraga : olahraga
# semangat : semangat
# ryan : ryan
# jarak : jarak
# odp : odp
# lokasi : lokasi
# meter : meter
# permintaannya : minta
# terealisasi : realisasi
# pemasangannya : pasang
# indah : indah
# modemnya : modem
# tersedia : sedia
# thanks : thanks
# bnu : bnu
# ravi : ravi
# sya : sya
# hindari : hindar
# kerumunan : kerumun
# senantiasa : senantiasa
# jaga : jaga
# usahakan : usaha
# beraktifitas : beraktifitas
# lola : lola
# sngaja : sngaja
# agr : agr
# bermalas : malas
# malasan : malas
# langananya : langananya
# peoses : peoses
# drakorku : drakorku
# terhalng : terhalng
# indihumb : indihumb
# rama : rama
# website : website
# apaansih : apaansih
# titik : titik
# boros : boros
# lolaa : lolaa
# hmmm : hmmm
# alesan : alesan
# pemeliharaan : pelihara
# aje : aje
# wisnu : wisnu
# dialami : alami
# milik : milik
# nata : nata
# baek : baek
# php : php
# kinerja : kerja
# caper : caper
# hoby : hoby
# recommended : recommended
# ketinggalan : tinggal
# support : support
# gawe : gawe
# lancarrr : lancarrr
# bangetttt : bangetttt
# ohh : ohh
# indihomee : indihomee
# bergelud : bergelud
# indigone : indigone
# dibaca : baca
# wahhhh : wahhhh
# seruh : seruh
# pubg : pubg
# irsal : irsal
# nurhakim : nurhakim
# telp : telp
# ambereguel : ambereguel
# called : called
# konsumen : konsumen
# struktur : struktur
# merepotkan : repot
# diharuskan : harus
# gonta : gonta
# terkendala : kendala
# penuh : penuh
# urus : urus
# fess : fess
# sebenernya : sebenernya
# bnyk : bnyk
# hhh : hhh
# serumah : rumah
# nyman : nyman
# gb : gb
# program : program
# charity : charity
# mengalokasikan : alokasi
# dana : dana
# senilai : nila
# rp : rp
# juta : juta
# masyarakat : masyarakat
# dampak : dampak
# selengkapnya : lengkap
# ajiggggggg : ajiggggggg
# catat : catat
# wib : wib
# siapkan : siap
# terpilih : pilih
# fadly : fadly
# nurfandi : nurfandi
# community : community
# dibahas : bahas
# dapetin : dapetin
# penghasilan : hasil
# komunitas : komunitas
# modal : modal
# febtriany : febtriany
# host : host
# head : head
# digital : digital
# haykal : haykal
# kamil : kamil
# ceo : ceo
# kals : kals
# corpora : corpora
# dibenerin : dibenerin
# beru : beru
# gjls : gjls
# saham : saham
# lucu : lucu
# bmrs : bmrs
# yelo : yelo
# amsyong : amsyong
# dendam : dendam
# kuisnya : kuis
# ikfina : ikfina
# rachmatika : rachmatika
# ngalamin : ngalamin
# sob : sob
# kuy : kuy
# giveawaynya : giveawaynya
# faesal : faesal
# sekedar : dar
# emank : emank
# terganggu : ganggu
# nokia : nokia
# dijamin : jamin
# mind : mind
# msh : msh
# asjam : asjam
# yuu : yuu
# applikasi : applikasi
# serba : serba
# wow : wow
# komplit : komplit
# dibutuhkan : butuh
# lorong : lorong
# teknisinya : teknisi
# gaenak : gaenak
# badan : badan
# mens : mens
# kombinasi : kombinasi
# perfek : perfek
# awali : awal
# minnnnnn : minnnnnn
# ayolaaahhh : ayolaaahhh
# ditangani : tangan
# pengecekkan : ecek
# dibales : dibales
# punyaku : punya
# musti : musti
# disuru : disuru
# nota : nota
# mengada : ada
# ngada : ngada
# cinta : cinta
# zepeto : zepeto
# guguk : guguk
# smw : smw
# panggil : panggil
# indiehome : indiehome
# matot : matot
# skr : skr
# dibetulkan : betul
# voucher : voucher
# hatipun : hati
# puas : puas
# ekavira : ekavira
# ngeliat : ngeliat
# mika : mika
# dihati : hati
# bujuki : bujuk
# dwiki : dwiki
# memantau : pantau
# keamanan : aman
# kencang : kencang
# city : city
# innalilahi : innalilahi
# kaput : kaput
# ricek : ricek
# asuw : asuw
# sobi : sobi
# mainkan : main
# stay : stay
# safe : safe
# healthy : healthy
# bkin : bkin
# org : org
# penjelasannya : jelas
# menunggu : tunggu
# peminat : minat
# behave : behave
# anjer : anjer
# reia : reia
# deninta : deninta
# search : search
# bar : bar
# keluhannya : keluh
# knpa : knpa
# notice : notice
# done : done
# socmednya : socmednya
# kue : kue
# ketan : ketan
# diatas : atas
# meja : meja
# dimakan : makan
# kenyang : kenyang
# teman : teman
# pemenang : menang
# aminnn : aminnn
# gonna : gonna
# sue : sue
# joss : joss
# terlengkap : lengkap
# hate : hate
# account : account
# xlhome : xlhome
# proposal : proposal
# anyeng : anyeng
# yasinin : yasinin
# gabales : gabales
# ngereview : ngereview
# alokasikan : alokasi
# bantuan : bantu
# kuartal : kuartal
# semingguan : minggu
# dih : dih
# menonaktifkan : nonaktif
# puki : puki
# vouchernya : vouchernya
# muehehe : muehehe
# yusa : yusa
# cinangka : cinangka
# bungursari : bungursari
# kab : kab
# purwakarta : purwakarta
# tercover : tercover
# woe : woe
# padhal : padhal
# rek : rek
# mini : mini
# losssss : losssss
# tanpabantas : tanpabantas
# menambah : tambah
# triple : triple
# memadia : madia
# ticket : ticket
# blur : blur
# penggantian : ganti
# bonus : bonus
# benefitnya : benefitnya
# registrasinya : registrasi
# bonusnya : bonus
# whatsapp : whatsapp
# device : device
# nyangkut : nyangkut
# hri : hri
# menyebut : sebut
# grgr : grgr
# hrus : hrus
# jdi : jdi
# gwsh : gwsh
# nyri : nyri
# perkara : perkara
# jype : jype
# didenda : denda
# audzubillahh : audzubillahh
# jurnal : jurnal
# terhambat : hambat
# gercep : gercep
# bestie : bestie
# samarinda : samarinda
# terkesan : kes
# cuek : cuek
# eddy : eddy
# ketidaknyamanannya : ketidaknyamanannya
# laporannya : lapor
# penanganan : tangan
# meika : meika
# prioritaskan : prioritas
# progres : progres
# perbaikannya : baik
# gagal : gagal
# damnnn : damnnn
# mina : mina
# tiktokan : tiktokan
# faktor : faktor
# penambah : tambah
# dosa : dosa
# pkl : pkl
# wita : wita
# taknisi : taknisi
# janjinya : janji
# uas : uas
# versiku : versi
# headset : headset
# kopi : kopi
# susu : susu
# perpaduan : padu
# maksudnya : maksud
# guru : guru
# pidio : pidio
# tenggat : tenggat
# hyunjae : hyunjae
# psb : psb
# disesuaikan : sesuai
# dipilih : pilih
# ppn : ppn
# lau : lau
# ulan : ulan
# email : email
# temukan : temu
# proses : proses
# bypass : bypass
# lipat : lipat
# gnti : gnti
# misi : misi
# angkat : angkat
# landline : landline
# telemarketer : telemarketer
# jenius : jenius
# nomornya : nomor
# penagih : tagih
# hutang : hutang
# gojek : gojek
# paylater : paylater
# aktifin : aktifin
# lemoteeee : lemoteeee
# pundung : pundung
# kakkkk : kakkkk
# plisss : plisss
# excited : excited
# yaudah : yaudah
# sksksk : sksksk
# membership : membership
# bahasa : bahasa
# rumahku : rumah
# pakenya : pakenya
# skskskks : skskskks
# maap : maap
# indirumah : indirumah
# konser : konser
# offlinee : offlinee
# packet : packet
# loss : loss
# low : low
# priority : priority
# dota : dota
# faiz : faiz
# berkenan : kenan
# tindaklanjut : tindaklanjut
# dcek : dcek
# urgent : urgent
# nguji : nguji
# suaranya : suara
# yutup : yutup
# full : full
# kimbe : kimbe
# stabilnya : stabil
# istimewa : istimewa
# gaessss : gaessss
# okta : okta
# pergantian : ganti
# mengunjungi : unjung
# nii : nii
# mbouss : mbouss
# gituan : gituan
# cbn : cbn
# pulo : pulo
# gebang : gebang
# aarregghhh : aarregghhh
# cakep : cakep
# sis : sis
# instalasi : instalasi
# dinaikkan : naik
# kara : kara
# terpantau : pantau
# refresh : refresh
# terputus : putus
# dirimu : diri
# son : son
# soreang : soreang
# david : david
# madet : madet
# cik : cik
# euy : euy
# aing : aing
# hehehe : hehehe
# maksudku : maksud
# datenge : datenge
# looo : looo
# tangan : tangan
# kanan : kanan
# tanagn : tanagn
# kiri : kiri
# wahahaha : wahahaha
# ampoonnn : ampoonnn
# webserver : webserver
# mmg : mmg
# anu : anu
# walopun : walopun
# berat : berat
# cihhh : cihhh
# setuju : tuju
# helpful : helpful
# brb : brb
# membantu : bantu
# benaran : benar
# memudahkan : mudah
# bangke : bangke
# sihir : sihir
# kuat : kuat
# dena : dena
# nyuakk : nyuakk
# bisnis : bisnis
# mengajukan : aju
# penghentian : henti
# thx : thx
# disebabkan : sebab
# address : address
# kesalahan : salah
# arif : arif
# bersemangat : semangat
# masker : masker
# berpergian : pergi
# ngumpulin : ngumpulin
# ancur : ancur
# lolos : lolos
# doakan : doa
# tahan : tahan
# aamiin : aamiin
# heyyy : heyyy
# ceek : ceek
# ...
# ngeri : ngeri
# sinting : sinting
# bizanet : bizanet
# ketanah : tanah
# busway : busway
# balikny : balikny
# paku : paku
# palu : palu
# give : give
# away : away
# kudoakan : doa
# sumatera : sumatera
# fatikhin : fatikhin
# ponsel : ponsel
# hiro : hiro
# mntp : mntp
# bekerjasama : bekerjasama
# glitchnya : glitchnya
# sadis : sadis
# jayapura : jayapura
# bgni : bgni
# dibener : dibener
# bulanan : bulan
# murka : murka
# pamulang : pamulang
# ditolerir : tolerir
# banyaknya : banyak
# tertolong : tolong
# kecepatannya : cepat
# layananmu : layan
# gaiso : gaiso
# isin : isin
# chindev : chindev
# suci : suci
# ehh : ehh
# read : read
# dude : dude
# appstore : appstore
# pekanbaru : pekanbaru
# lbih : lbih
# cpat : cpat
# drpada : drpada
# cpet : cpet
# tiketnya : tiket
# myin : myin
# kebahagian : kebahagian
# milih : milih
# nontok : nontok
# pertandinyan : pertandinyan
# championship : championship
# terbatas : batas
# ngikutin : ngikutin
# disiarin : disiarin
# lala : lala
# detailnya : detail
# tirai : tirai
# gelap : gelap
# kelasnya : kelas
# istirahat : istirahat
# jamkos : jamkos
# aula : aula
# apple : apple
# skali : skali
# sperti : sperti
# throtle : throtle
# tersendiri : sendiri
# consider : consider
# iconnet : iconnet
# ios : ios
# abad : abad
# qubro : qubro
# sulit : sulit
# kesambung : sambung
# pudji : pudji
# astya : astya
# beruntung : untung
# pemenangnya : menang
# saqif : saqif
# yogi : yogi
# menyertakan : serta
# bau : bau
# curhatan : curhatan
# jilid : jilid
# sharp : sharp
# netlix : netlix
# model : model
# annjing : annjing
# gapake : gapake
# vidcall : vidcall
# ngomel : ngomel
# duwe : duwe
# ndueno : ndueno
# konco : konco
# megavision : megavision
# hdeh : hdeh
# lma : lma
# bnernya : bnernya
# twt : twt
# lalot : lalot
# payah : payah
# prnh : prnh
# tmpt : tmpt
# kampng : kampng
# jatibulak : jatibulak
# jatimulya : jatimulya
# mengandalkan : andal
# lancaarf : lancaarf
# merusak : rusak
# pencaharian : cahari
# massal : massal
# onk : onk
# seh : seh
# asline : asline
# budhe : budhe
# bpk : bpk
# gelek : gelek
# mekso : mekso
# nginep : nginep
# omah : omah
# putu : putu
# akeh : akeh
# dipekso : dipekso
# tok : tok
# adoh : adoh
# wedi : wedi
# dewe : dewe
# koreksi : koreksi
# nggga : nggga
# dikoreksi : koreksi
# sepenuh : sepenuh
# marahthon : marahthon
# gimanasi : gimanasi
# netpliks : netpliks
# dirumahku : rumah
# ssmpe : ssmpe
# luu : luu
# diomongin : diomongin
# andre : andre
# alhasil : alhasil
# hahahhahahahahahhahahahahahhahahahahahahahahgabisangapa : hahahhahahahahahhahahahahahhahahahahahahahahgabisangapa
# inhahahahhahahaha : inhahahahhahahaha
# toast : toast
# keriting : keriting
# kit : kit
# maklum : maklum
# cuy : cuy
# bocah : bocah
# diam : diam
# kotor : kotor
# terkikis : kikis
# mengurangi : kurang
# iyaa : iyaa
# kaa : kaa
# sfu : sfu
# biasanye : biasanye
# genting : genting
# benefit : benefit
# interaktif : interaktif
# sambungan : sambung
# responnya : responnya
# indihomeku : indihomeku
# blom : blom
# kelanjutan : lanjut
# ngeganggu : ngeganggu
# gasihh : gasihh
# soksok : soksok
# ngebingungin : ngebingungin
# giniiii : giniiii
# kejar : kejar
# mimpimu : mimpi
# submit : submit
# estimasi : estimasi
# inet : inet
# onlinenya : onlinenya
# beramai : ama
# ramai : ramai
# kondusif : kondusif
# koq : koq
# glee : glee
# arwahnya : arwah
# inii : ini
# masii : masii
# berasa : asa
# cellular : cellular
# aning : aning
# same : same
# berbagi : bagi
# momen : momen
# skripsi : skripsi
# danta : danta
# berisik : berisik
# rifqi : rifqi
# wisnuw : wisnuw
# wkwkkwk : wkwkkwk
# kasihan : kasihan
# jilakkkkk : jilakkkkk
# fleets : fleets
# mayah : mayah
# bli : bli
# sibuk : sibuk
# ngandelin : ngandelin
# tot : tot
# nek : nek
# senggel : senggel
# sesok : sok
# enteni : enten
# ngarep : ngarep
# dprd : dprd
# sambat : sambat
# copot : copot
# struggles : struggles
# joni : joni
# tercatat : catat
# memiliki : milik
# mauu : mauu
# bakar : bakar
# antok : antok
# diupayakan : upaya
# bosok : bosok
# anjinggg : anjinggg
# being : being
# bts : bts
# army : army
# hahahahha : hahahahha
# curhat : curhat
# toefl : toefl
# testnya : testnya
# persis : persis
# sebelah : belah
# kamar : kamar
# makanan : makan
# dimeja : meja
# cemilan : cemilan
# dikamar : kamar
# camera : camera
# mengawasi : awas
# gadget : gadget
# pribadi : pribadi
# hamlir : hamlir
# sjj : sjj
# nyalahin : nyalahin
# egk : egk
# ngentot : ngentot
# hancur : hancur
# yatuhann : yatuhann
# dichat : dichat
# carenya : carenya
# blgnya : blgnya
# devicenya : devicenya
# kebanyakan : banyak
# cmn : cmn
# sblm : sblm
# tiangnya : tiang
# ahir : ahir
# meresahkan : resah
# bund : bund
# ditambah : tambah
# populer : populer
# hero : hero
# weapon : weapon
# ability : ability
# hih : hih
# kentang : kentang
# buosookkk : buosookkk
# polll : polll
# iyo : iyo
# jiilaan : jiilaan
# rabb : rabb
# salamm : salamm
# dosen : dosen
# semester : semester
# laluuu : laluuu
# dimintain : dimintain
# meh : meh
# jokiin : jokiin
# sinyalmu : sinyal
# weightlifting : weightlifting
# partai : partai
# siiiiiii : siiiiiii
# balifiber : balifiber
# direstui : restu
# hahahahahahahahahahahah : hahahahahahahahahahahah
# babe : babe
# praptono : praptono
# leletnyaaaaaa : leletnyaaaaaa
# indihomeee : indihomeee
# overall : overall
# bangsattt : bangsattt
# domisili : domisili
# ntt : ntt
# kupang : kupang
# apain : apain
# tindak : tindak
# menyalah : salah
# terisolir : isolir
# apex : apex
# creker : creker
# disana : sana
# tanggap : tanggap
# penasaran : penasaran
# fajrun : fajrun
# sesuaikan : sesuai
# lewatnya : lewat
# verif : verif
# merasakannya : rasa
# pinter : pinter
# tomorrow : tomorrow
# barusan : barusan
# tes : tes
# awas : awas
# sbpu : sbpu
# menguasai : kuasa
# jedag : jedag
# jedug : jedug
# erwin : erwin
# flash : flash
# ebet : ebet
# harris : harris
# awwkwkwk : awwkwkwk
# menjauh : jauh
# zona : zona
# never : never
# trust : trust
# berlima : lima
# ampassssss : ampassssss
# useetvgo : useetvgo
# zomm : zomm
# darat : darat
# laut : laut
# udara : udara
# pasword : pasword
# kepikirannya : pikir
# lowbat : lowbat
# alarm : alarm
# mhn : mhn
# grup : grup
# cctv : cctv
# hasilnya : hasil
# kosong : kosong
# tks : tks
# rang : rang
# indo : indo
# kepilih : pilih
# event : event
# taek : taek
# berbakti : bakti
# negeri : negeri
# ala : ala
# uti : uti
# cobalah : coba
# impact : impact
# dibarengi : bareng
# sekian : sekian
# dijadikan : jadi
# menerima : terima
# cobaan : coba
# okeh : okeh
# free : free
# mulain : mulain
# nyalanya : nyala
# hiiiii : hiiiii
# sistur : sistur
# july : july
# naek : naek
# viralkan : viralkan
# begimane : begimane
# arek : arek
# hola : hola
# merugikan : rugi
# era : era
# passpor : passpor
# ktalk : ktalk
# kesempatan : sempat
# inggris : inggris
# refli : refli
# apri : apri
# lanjuti : lanjut
# manual : manual
# barokah : barokah
# motivasi : motivasi
# beradaptasi : adaptasi
# dibetot : betot
# ris : ris
# knppp : knppp
# siee : siee
# mencintai : cinta
# mention : mention
# hashtag : hashtag
# terbiasa : biasa
# bohongin : bohongin
# status : status
# nunggak : nunggak
# drachin : drachin
# samaaaa : samaaaa
# nyalaaa : nyalaaa
# nyalaaaaa : nyalaaaaa
# terdeteksi : deteksi
# ngehang : ngehang
# siiiii : siiiii
# cengkareng : cengkareng
# timur : timur
# jakarta : jakarta
# only : only
# rabu : rabu
# ributt : ributt
# ndlap : ndlap
# ndlup : ndlup
# report : report
# yosua : yosua
# skema : skema
# bgmn : bgmn
# mangkannya : mang
# padamg : padamg
# kerusakan : rusa
# fun : fun
# until : until
# realize : realize
# wifimu : wifimu
# hahahahahahhaah : hahahahahahhaah
# nabok : nabok
# apaaa : apaaa
# lila : lila
# kemi : kemi
# sii : sii
# gituu : gituu
# routing : routing
# macet : macet
# mwheheheheh : mwheheheheh
# kyaaa : kyaaa
# internetku : internetku
# relate : relate
# diberesin : resin
# beresin : resin
# sitsiw : sitsiw
# jikyu : jikyu
# guwe : guwe
# hasbi : hasbi
# dimushola : dimushola
# pipis : pipis
# dibalik : balik
# pohon : pohon
# mangga : mangga
# panik : panik
# smbil : smbil
# treak : treak
# daun : daun
# pisang : pisang
# ketiup : tiup
# maghrib : maghrib
# oleng : oleng
# niccccccc : niccccccc
# mentang : mentang
# apac : apac
# bsok : bsok
# huuuhhh : huuuhhh
# gurunya : guru
# dijlsin : dijlsin
# hdhh : hdhh
# dom : dom
# wifiku : wifiku
# huehue : huehue
# gemana : gana
# niy : niy
# elo : elo
# sungkan : sungkan
# bansgsyyatattttt : bansgsyyatattttt
# berwirausaha : berwirausaha
# ibadah : ibadah
# ta : ta
# zheyeng : zheyeng
# mark : mark
# oii : oii
# ngentit : ngentit
# ditingkatkan : tingkat
# mood : mood
# kuantitas : kuantitas
# contohnya : contoh
# which : which
# ganggu : ganggu
# kerjanya : kerja
# requires : requires
# yaaaa : yaaaa
# cacat : cacat
# kick : kick
# wirausaha : wirausaha
# aherat : aherat
# dragon : dragon
# nessa : nessa
# mandiri : mandiri
# ajege : ajege
# melintas : lintas
# mengenali : nali
# pengin : pengin
# khan : khan
# singgahi : singgah
# datangi : datang
# always : always
# niiiii : niiiii
# uhhh : uhhh
# hell : hell
# sticker : sticker
# alek : alek
# tayio : tayio
# heeeeyyyyy : heeeeyyyyy
# meetingku : meetingku
# pitchingnya : pitchingnya
# deal : deal
# pinned : pinned
# prosedur : prosedur
# tampol : tampol
# marai : mara
# mangkel : mangkel
# {'dear': 'dear', 'kasih': 'kasih', 'layanan': 'layan', 'minimal': 'minimal', 'jaringan': 'jaring', 'jalan': 'jalan', 'normal': 'normal', 'bumn': 'bumn', 'kaki': 'kaki', 'pegel': 'gel', 'indihome': 'indihome', 'tolong': 'tolong', 'lampu': 'lampu', 'internet': 'internet', 'malem': 'malem', 'merah': 'merah', 'sekolah': 'sekolah', 'peka': 'peka', '': '', 'dirumah': 'rumah', 'kendalanya': 'kendala', 'mengikuti': 'ikut', 'anjuran': 'anjur', 'pemerintah': 'perintah', 'rumah': 'rumah', 'kerja': 'kerja', 'kendala': 'kendala', 'udah': 'udah', 'jam': 'jam', 'laporan': 'lapor', 'nyala': 'nyala', 'pppp': 'pppp', 'gimana': 'gimana', 'wifi': 'wifi', 'gue': 'gue', 'mati': 'mati', 'abangnya': 'abang', 'ngecek': 'ngecek', 'dateng': 'dateng', 'allah': 'allah', 'nyolong': 'nyolong', 'tetangga': 'tetangga', 'bener': 'bener', 'kemarin': 'kemarin', 'siang': 'siang', 'sampe': 'sampe', 'belom': 'bom', 'susah': 'susah', 'kuota': 'kuota', 'sehari': 'hari', 'bayar': 'bayar', 'tetep': 'tetep', 'ampun': 'ampun', 'iya': 'iya', 'nunggu': 'nunggu', 'astagfirullah': 'astagfirullah', 'banggarr': 'banggarr', 'apapun': 'apa', 'kkegiatanmu': 'kkegiatanmu', 'akses': 'akses', 'diandalkan': 'andal', 'upgrade': 'upgrade', 'speed': 'speed', 'demand': 'demand', 'mantap': 'mantap', 'semaleman': 'maleman', 'fakk': 'fakk', 'jadwal': 'jadwal', 'olimpiade': 'olimpiade', 'tokyo': 'tokyo', 'indonesia': 'indonesia', 'juli': 'juli', 'saksikan': 'saksi', 'download': 'download', 'aplikasinya': 'aplikasi', 'usee': 'usee', 'apps': 'apps', 'store': 'store', 'hybrid': 'hybrid', 'box': 'box', 'sumpah': 'sumpah', 'ngambek': 'ngambek', 'lihat': 'lihat', 'live': 'live', 'gara': 'gara', 'kebawa': 'bawa', 'mimpi': 'mimpi', 'antena': 'antena', 'mbak': 'mbak', 'ayo': 'ayo', 'jaringannya': 'jaring', 'arang': 'arang', 'enggk': 'enggk', 'sinyal': 'sinyal', 'stabil': 'stabil', 'pke': 'pke', 'gra': 'gra', 'penyimpanan': 'simpan', 'emng': 'emng', 'minim': 'minim', 'bnget': 'bnget', 'min': 'min', 'gabisa': 'gabisa', 'dipake': 'dipake', 'yaa': 'yaa', 'router': 'router', 'pasangin': 'pasangin', 'siswa': 'siswa', 'laptop': 'laptop', 'emang': 'emang', 'larinya': 'lari', 'pakai': 'pakai', 'sistem': 'sistem', 'sewa': 'sewa', 'subuh': 'subuh', 'lemot': 'lot', 'kirain': 'kirain', 'kmrin': 'kmrin', 'parah': 'parah', 'bro': 'bro', 'halo': 'halo', 'lelet': 'lelet', 'banget': 'banget', 'streaming': 'streaming', 'lagu': 'lagu', 'update': 'update', 'aplikasi': 'aplikasi', 'cuman': 'cuman', 'doang': 'doang', 'pagi': 'pagi', 'orang': 'orang', 'emosi': 'emosi', 'perluas': 'luas', 'jangkauan': 'jangkau', 'game': 'game', 'berbasis': 'bas', 'komputasi': 'komputasi', 'awan': 'awan', 'registrasi': 'registrasi', 'promo': 'promo', 'online': 'online', 'lancar': 'lancar', 'cuan': 'cuan', 'gencar': 'gencar', 'banner': 'banner', 'twitter': 'twitter', 'harapan': 'harap', 'dpt': 'dpt', 'channel': 'channel', 'tambahan': 'tambah', 'kunjung': 'kunjung', 'muncul': 'muncul', 'bbrp': 'bbrp', 'kali': 'kali', 'komplain': 'komplain', 'petugas': 'tugas', 'kwkwkwkwk': 'kwkwkwkwk', 'nay': 'nay', 'kebangun': 'bangun', 'gegara': 'gegara', 'bangun': 'bangun', 'kah': 'kah', 'hallo': 'hallo', 'kak': 'kak', 'yuk': 'yuk', 'kepoin': 'poin', 'paket': 'paket', 'kecepatan': 'cepat', 'gaming': 'gaming', 'harga': 'harga', 'regulernya': 'reguler', 'ghodit': 'ghodit', 'jancoook': 'jancoook', 'emg': 'emg', 'kencengan': 'kenceng', 'mah': 'mah', 'knp': 'knp', 'skrg': 'skrg', 'kon': 'kon', 'cah': 'cah', 'ente': 'ente', 'toling': 'toling', 'perbaikin': 'perbaikin', 'kualitas': 'kualitas', 'temen': 'temen', 'ane': 'ane', 'ampe': 'ampe', 'gavisa': 'gavisa', 'vcall': 'vcall', 'ngga': 'ngga', 'bang': 'bang', 'taee': 'taee', 'vcal': 'vcal', 'blauervogel': 'blauervogel', 'gimananih': 'gimananih', 'hai': 'hai', 'riki': 'riki', 'koneksi': 'koneksi', 'bantu': 'bantu', 'cek': 'cek', 'silakan': 'sila', 'kakak': 'kakak', 'infokan': 'info', 'nomor': 'nomor', 'aktif': 'aktif', 'via': 'via', 'menjaga': 'jaga', 'kerahasiaan': 'rahasia', 'data': 'data', 'tunggu': 'tunggu', 'ko ...
# ------------------------
# Pandas Apply:   0%|          | 0/1989 [00:01<?, ?it/s]
#                                                 content  \
# 0     dear @indihome , kapan bisa kasih layanan yang...
# 1                        @bangunsubekti @indihome pegel
# 2                              indihome lagi kenapa sih
# 3     @indihomecare @indihome tolong bgt lampu inter...
# 4          @3o4misser @indihome tau nih ga peka bgt yy😔
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min @indihome untuk prosedur pemutusan it...
# 1998  indihome pengen tak tampol , lemot amat si htt...
# 1999                      lemot marai mangkel @indihome
#
#                                          cleaning_tweet  \
# 0     dear kapan bisa kasih layanan yang minimal jar...
# 1                                                 pegel
# 2                              indihome lagi kenapa sih
# 3     tolong bgt lampu internet dari malem masih mer...
# 4                                     tau nih peka bgt
# ...                                                 ...
# 1995  indihome heeeeyyyyy mengganggu saja meetingku ...
# 1996  guys maaf boleh minta tolong cek pinned trs ta...
# 1997  halo min untuk prosedur pemutusan itu apa aja ...
# 1998             indihome pengen tak tampol lemot amat
# 1999                                lemot marai mangkel
#
#                                              tokenisasi  \
# 0     [dear, kapan, bisa, kasih, layanan, yang, mini...
# 1                                               [pegel]
# 2                         [indihome, lagi, kenapa, sih]
# 3     [tolong, bgt, lampu, internet, dari, malem, ma...
# 4                               [tau, nih, peka, bgt, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, mengganggu, saja, meeti...
# 1996  [guys, maaf, boleh, minta, tolong, cek, pinned...
# 1997  [halo, min, untuk, prosedur, pemutusan, itu, a...
# 1998     [indihome, pengen, tak, tampol, lemot, amat, ]
# 1999                            [lemot, marai, mangkel]
#
#                                                stopword  \
# 0     [dear, kasih, layanan, minimal, jaringan, jala...
# 1                                               [pegel]
# 2                                            [indihome]
# 3      [tolong, lampu, internet, malem, merah, sekolah]
# 4                                              [peka, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, mengganggu, meetingku, ...
# 1996  [guys, maaf, tolong, cek, pinned, trs, tag, ak...
# 1997  [halo, min, prosedur, pemutusan, rumah, telepo...
# 1998                [indihome, pengen, tampol, lemot, ]
# 1999                            [lemot, marai, mangkel]
#
#                                                stemming
# 0     [dear, kasih, layan, minimal, jaring, jalan, n...
# 1                                                 [gel]
# 2                                            [indihome]
# 3      [tolong, lampu, internet, malem, merah, sekolah]
# 4                                              [peka, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, ganggu, meetingku, bere...
# 1996  [guys, maaf, tolong, cek, pinned, trs, tag, ak...
# 1997  [halo, min, prosedur, putus, rumah, telepon, r...
# 1998                     [indihome, ken, tampol, lot, ]
# 1999                               [lot, mara, mangkel]
#
# [1989 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'Tweets'})

# %%
Final
# Out:
#                                                  Tweets
# 0     [dear, kasih, layan, minimal, jaring, jalan, n...
# 1                                                 [gel]
# 2                                            [indihome]
# 3      [tolong, lampu, internet, malem, merah, sekolah]
# 4                                              [peka, ]
# ...                                                 ...
# 1995  [indihome, heeeeyyyyy, ganggu, meetingku, bere...
# 1996  [guys, maaf, tolong, cek, pinned, trs, tag, ak...
# 1997  [halo, min, prosedur, putus, rumah, telepon, r...
# 1998                     [indihome, ken, tampol, lot, ]
# 1999                               [lot, mara, mangkel]
#
# [1989 rows x 1 columns]

# %%
Final.to_excel('databersih_tweet_indihome_7.xlsx')
