# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#Scrape desired number of reviews

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.telkomsel.telkomselcm',
    lang='id', # defaults to 'en'
    country='id', 
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=250000, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_telkomsel = pd.DataFrame(np.array(result),columns=['review'])
df_telkomsel = df_telkomsel.join(pd.DataFrame(df_telkomsel.pop('review').tolist()))
df_telkomsel.head(250000)
# Out:
#                                                  reviewId  \
# 0       gp:AOqpTOGM3SMRG-J38ROjdvMXSh7QNGHgEDFiW7e3T7v...
# 1       gp:AOqpTOGR8v39sfXXjdOBtFHIllZTZfkG1xOjPfSGjkE...
# 2       gp:AOqpTOETRm9ejYktnHChzx7CS7bTD5MfH0BFVdh3Smb...
# 3       gp:AOqpTOG2zo3HJBFpsa4oUdRo5xxLNQMf5MSJ1SChJWN...
# 4       gp:AOqpTOHSn17hT-9CvP4A_P3wurlYpToNcmmZhXZhMw9...
# ...                                                   ...
# 142678  gp:AOqpTOE0mZpwtAqKJaVeDSXZAmaFV3n_ilyzlOHN86Y...
# 142679  gp:AOqpTOEam2SkZMjsbY3iWFvo3kETL0HeLHYL5mpbQSR...
# 142680  gp:AOqpTOE1oeFAaF132TOUrf2v1zKd5NTKENXAJZsxqKz...
# 142681  gp:AOqpTOHQFR7KqFNtIyoTnbG9WaZKCESf2Cv0tE-cg-E...
# 142682  gp:AOqpTOEomlFhhKd8D3N9sHCsjRrOQRt7O2jMQMCgld9...
#
#                         userName  \
# 0                      Gaming 01
# 1        Eustasius Heru Setianto
# 2                     Karin Feby
# 3                  DESI FEBRIANI
# 4       Bakso benhil Kebon pedes
# ...                          ...
# ...

# %%
len(df_telkomsel.index) #count the number of data we got
# Out:
# 142683

# %%
#Run This Code to Sort the Data By Date 

new_df = df_telkomsel[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head(250000)
# Out:
#               userName  score                  at  \
# 19812      Gaming Kopi      5 2022-02-25 23:16:56
# 29796      Rafael Aldo      1 2022-02-25 19:47:22
# 14202   Vanesa Lestari      1 2022-02-25 18:57:17
# 17446        P_ Santuy      5 2022-02-25 17:54:21
# 10791         ezzad 06      1 2022-02-25 15:29:04
# ...                ...    ...                 ...
# 131960  Aditya Pratama      2 2018-09-12 18:09:40
# 130353   HIJRAH NATION      1 2018-09-12 17:14:36
# 129610         Jhon 08      1 2018-09-12 15:47:12
# 132723       Mio Sunny      1 2018-09-12 15:28:41
# 95548   JJAS Adventure      5 2018-09-12 14:23:52
#
#                                                   content
# 19812                                     Sangat membantu
# 29796   Udah beli mahal2 tulisannya 4g buat ngegame si...
# 14202   Semakin lama Telkomsel semakin jelek Auto pind...
# 17446                                Internet lu kaya tai
# 10791   Kapan ya jaringan telkomsel bisa stabil lagi ?...
# ...

# %%
sorted_df.to_excel('data_playstore_mytelkomsel.xlsx')
