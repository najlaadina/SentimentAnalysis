# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_11.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Hallo min, kenapa di rumah saya beberapa hp ti...
# 1             Sya mw tanya ko tagihan saya berbeda2...
# 2                      Sore mintol refresh jaringan ya
# 3               Kak mau cek tagihan bln November bisa?
# 4    Mimin. Saya mau tanya dong. Bagaimana cara kon...
# ..                                                 ...
# 374               Gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  Dri setelah pembayaran sampe skrg lemot terus,...
# 377  Tolong kalau laporan di respon,  sudah sya inb...
# 378  Kak mau pengaduan layanan IndiHome-nya terhubu...
#
# [379 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 28

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Hallo min, kenapa di rumah saya beberapa hp ti...
# 1             Sya mw tanya ko tagihan saya berbeda2...
# 2                      Sore mintol refresh jaringan ya
# 3               Kak mau cek tagihan bln November bisa?
# 4    Mimin. Saya mau tanya dong. Bagaimana cara kon...
# ..                                                 ...
# 374               Gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  Dri setelah pembayaran sampe skrg lemot terus,...
# 377  Tolong kalau laporan di respon,  sudah sya inb...
# 378  Kak mau pengaduan layanan IndiHome-nya terhubu...
#
# [336 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    hallo min, kenapa di rumah saya beberapa hp ti...
# 1             sya mw tanya ko tagihan saya berbeda2...
# 2                      sore mintol refresh jaringan ya
# 3               kak mau cek tagihan bln november bisa?
# 4    mimin. saya mau tanya dong. bagaimana cara kon...
# ..                                                 ...
# 374               gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  dri setelah pembayaran sampe skrg lemot terus,...
# 377  tolong kalau laporan di respon,  sudah sya inb...
# 378  kak mau pengaduan layanan indihome-nya terhubu...
#
# [336 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    hallo min, kenapa di rumah saya beberapa hp ti...
# 1             sya mw tanya ko tagihan saya berbeda2...
# 2                      sore mintol refresh jaringan ya
# 3               kak mau cek tagihan bln november bisa?
# 4    mimin. saya mau tanya dong. bagaimana cara kon...
# ..                                                 ...
# 374               gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  dri setelah pembayaran sampe skrg lemot terus,...
# 377  tolong kalau laporan di respon,  sudah sya inb...
# 378  kak mau pengaduan layanan indihome-nya terhubu...
#
#                                       cleaning_comment
# 0    hallo min kenapa rumah saya beberapa tidak bis...
# 1                     sya tanya tagihan saya berbeda
# 2                        sore mintol refresh jaringan
# 3               kak mau cek tagihan bln november bisa
# 4    mimin saya mau tanya dong bagaimana cara konek...
# ..                                                 ...
# 374                gini amat ienternet indonesia miris
# 375  wah main tambah wawasan aja nih makasih inform...
# 376  dri setelah pembayaran sampe skrg lemot terus ...
# 377  tolong kalau laporan respon sudah sya inbox ha...
# 378  kak mau pengaduan layanan indihome nya terhubu...
#
# [336 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    hallo min, kenapa di rumah saya beberapa hp ti...
# 1             sya mw tanya ko tagihan saya berbeda2...
# 2                      sore mintol refresh jaringan ya
# 3               kak mau cek tagihan bln november bisa?
# 4    mimin. saya mau tanya dong. bagaimana cara kon...
# ..                                                 ...
# 374               gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  dri setelah pembayaran sampe skrg lemot terus,...
# 377  tolong kalau laporan di respon,  sudah sya inb...
# 378  kak mau pengaduan layanan indihome-nya terhubu...
#
#                                       cleaning_comment  \
# 0    hallo min kenapa rumah saya beberapa tidak bis...
# 1                     sya tanya tagihan saya berbeda
# 2                        sore mintol refresh jaringan
# 3               kak mau cek tagihan bln november bisa
# 4    mimin saya mau tanya dong bagaimana cara konek...
# ..                                                 ...
# 374                gini amat ienternet indonesia miris
# 375  wah main tambah wawasan aja nih makasih inform...
# 376  dri setelah pembayaran sampe skrg lemot terus ...
# 377  tolong kalau laporan respon sudah sya inbox ha...
# 378  kak mau pengaduan layanan indihome nya terhubu...
#
#                                             tokenisasi
# 0    [hallo, min, kenapa, rumah, saya, beberapa, ti...
# 1               [sya, tanya, tagihan, saya, berbeda, ]
# 2                  [sore, mintol, refresh, jaringan, ]
# 3      [kak, mau, cek, tagihan, bln, november, bisa, ]
# 4    [mimin, saya, mau, tanya, dong, bagaimana, car...
# ..                                                 ...
# 374          [gini, amat, ienternet, indonesia, miris]
# 375  [wah, main, tambah, wawasan, aja, nih, makasih...
# 376  [dri, setelah, pembayaran, sampe, skrg, lemot,...
# 377  [tolong, kalau, laporan, respon, sudah, sya, i...
# 378  [kak, mau, pengaduan, layanan, indihome, nya, ...
#
# [336 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    hallo min, kenapa di rumah saya beberapa hp ti...
# 1             sya mw tanya ko tagihan saya berbeda2...
# 2                      sore mintol refresh jaringan ya
# 3               kak mau cek tagihan bln november bisa?
# 4    mimin. saya mau tanya dong. bagaimana cara kon...
# ..                                                 ...
# 374               gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  dri setelah pembayaran sampe skrg lemot terus,...
# 377  tolong kalau laporan di respon,  sudah sya inb...
# 378  kak mau pengaduan layanan indihome-nya terhubu...
#
#                                       cleaning_comment  \
# 0    hallo min kenapa rumah saya beberapa tidak bis...
# 1                     sya tanya tagihan saya berbeda
# 2                        sore mintol refresh jaringan
# 3               kak mau cek tagihan bln november bisa
# 4    mimin saya mau tanya dong bagaimana cara konek...
# ..                                                 ...
# 374                gini amat ienternet indonesia miris
# 375  wah main tambah wawasan aja nih makasih inform...
# 376  dri setelah pembayaran sampe skrg lemot terus ...
# 377  tolong kalau laporan respon sudah sya inbox ha...
# 378  kak mau pengaduan layanan indihome nya terhubu...
#
#                                             tokenisasi  \
# 0    [hallo, min, kenapa, rumah, saya, beberapa, ti...
# 1               [sya, tanya, tagihan, saya, berbeda, ]
# 2                  [sore, mintol, refresh, jaringan, ]
# 3      [kak, mau, cek, tagihan, bln, november, bisa, ]
# 4    [mimin, saya, mau, tanya, dong, bagaimana, car...
# ..                                                 ...
# 374          [gini, amat, ienternet, indonesia, miris]
# 375  [wah, main, tambah, wawasan, aja, nih, makasih...
# 376  [dri, setelah, pembayaran, sampe, skrg, lemot,...
# 377  [tolong, kalau, laporan, respon, sudah, sya, i...
# 378  [kak, mau, pengaduan, layanan, indihome, nya, ...
#
#                                               stopword
# 0                   [hallo, min, rumah, konek, wifi, ]
# 1                            [sya, tagihan, berbeda, ]
# 2                  [sore, mintol, refresh, jaringan, ]
# 3                 [kak, cek, tagihan, bln, november, ]
# 4    [mimin, konek, modem, indihome, windows, plug,...
# ..                                                 ...
# 374                [gini, ienternet, indonesia, miris]
# 375              [main, wawasan, makasih, informisnya]
# 376  [dri, pembayaran, sampe, skrg, lemot, nerima, ...
# 377  [tolong, laporan, respon, sya, inbox, harap, t...
# 378  [kak, pengaduan, layanan, indihome, terhubung,...
#
# [336 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 852
# ------------------------
# hallo : hallo
# min : min
# rumah : rumah
# konek : konek
# wifi : wifi
#  :
# sya : sya
# tagihan : tagih
# berbeda : beda
# sore : sore
# mintol : mintol
# refresh : refresh
# jaringan : jaring
# kak : kak
# cek : cek
# bln : bln
# november : november
# mimin : mimin
# modem : modem
# indihome : indihome
# windows : windows
# plug : plug
# and : and
# play : play
# setting : setting
# koneksi : koneksi
# los : los
# malam : malam
# pagi : pagi
# jam : jam
# alhamdulillah : alhamdulillah
# tagihanku : tagih
# lancar : lancar
# koneksimu : koneksi
# ngak : ngak
# bener : bener
# bayar : bayar
# langsung : langsung
# dpt : dpt
# gratis : gratis
# cocok : cocok
# letakin : letakin
# bagus : bagus
# ruangan : ruang
# terjangkau : jangkau
# skrng : skrng
# buka : buka
# bbrpa : bbrpa
# app : app
# stuk : stuk
# masuk : masuk
# data : data
# tolong : tolong
# bantuan : bantu
# upgrade : upgrade
# bgmna : bgmna
# mengatasi : atas
# authentifikasi : authentifikasi
# keren : keren
# membantu : bantu
# siaran : siar
# muncul : muncul
# ganti : ganti
# password : password
# gimana : gimana
# stop : stop
# ber : ber
# langganan : langgan
# alat : alat
# balikin : balikin
# plaza : plaza
# telat : telat
# sehari : hari
# mati : mati
# inet : inet
# eror : eror
# sampe : sampe
# berlangganan : langgan
# kemarin : kemarin
# siang : siang
# sinyalnya : sinyal
# mengalami : alami
# gangguan : ganggu
# sorenya : sore
# dikutak : kutak
# kutik : kutik
# gambar : gambar
# bermasalah : masalah
# layar : layar
# nggak : nggak
# terbuka : buka
# mohon : mohon
# teknisi : teknisi
# indihom : indihom
# turun : turun
# tangan : tangan
# membetulkan : betul
# kaya : kaya
# gini : gin
# dimn : dimn
# lemot : lot
# cak : cak
# akses : akses
# org : org
# maaf : maaf
# putus : putus
# blm : blm
# pemakaian : pakai
# kena : kena
# denda : denda
# drumh : drumh
# kbelny : kbelny
# btulin : btulin
# kpn : kpn
# lmbt : lmbt
# bnr : bnr
# bls : bls
# inbok : inbok
# respon : respon
# trus : trus
# perbaiki : baik
# indohome : indohome
# nagih : nagih
# jelek : jelek
# dear : dear
# dikit : dikit
# funishment : funishment
# gue : gue
# gua : gua
# neko : neko
# elu : elu
# alasan : alas
# fup : fup
# terisolir : isolir
# udah : udah
# tgl : tgl
# oct : oct
# telp : telp
# dibuka : buka
# giliran : gilir
# cepet : cepet
# pelayanan : layan
# berbanding : banding
# lurus : lurus
# dibayar : bayar
# balesnya : balesnya
# lelet : lelet
# aneh : aneh
# lapor : lapor
# kantor : kantor
# ttp : ttp
# enggk : enggk
# tanggapi : tanggap
# tagih : tagih
# mbps : mbps
# teman : teman
# gmn : gmn
# nie : nie
# daerah : daerah
# kalbar : kalbar
# karna : karna
# bencana : bencana
# stb : stb
# nyala : nyala
# colok : colok
# adapter : adapter
# adaptor : adaptor
# menyala : nyala
# diganti : ganti
# unit : unit
# semalam : malam
# pleaseeeeeeee : pleaseeeeeeee
# kerja : kerja
# wihhh : wihhh
# makasih : makasih
# informasinya : informasi
# mengerti : erti
# loginnya : loginnya
# username : username
# pencerahan : cerah
# ketentuan : tentu
# deposit : deposit
# skrang : skrang
# wfh : wfh
# cinta : cinta
# sod : sod
# aplikasi : aplikasi
# malem : malem
# nomor : nomor
# internet : internet
# segampang : gampang
# ssid : ssid
# infonya : info
# restart : restart
# connection : connection
# selamat : selamat
# pahlawan : pahlawan
# salah : salah
# era : era
# digital : digital
# nomer : nomer
# kontrak : kontrak
# daftar : daftar
# pemasangan : pasang
# jum : jum
# sekrg : sekrg
# blom : blom
# info : info
# deh : deh
# bermanfaat : manfaat
# banget : banget
# semangat : semangat
# kerjanya : kerja
# seneng : neng
# pakai : pakai
# buffering : buffering
# pas : pas
# streaming : streaming
# pecah : pecah
# gitu : gitu
# nyaman : nyaman
# gan : gan
# lampu : lampu
# indikator : indikator
# terputus : putus
# bantu : bantu
# disana : sana
# butuh : butuh
# cakep : cakep
# diedukasi : edukasi
# indihomenya : indihomenya
# gaperlu : gaperlu
# ribet : ribet
# cari : cari
# mantull : mantull
# nonton : nonton
# channel : channel
# hbo : hbo
# minn : minn
# psb : psb
# doong : doong
# jatuh : jatuh
# tempo : tempo
# tagihannya : tagih
# mengecewakan : kecewa
# adi : adi
# nambah : nambah
# ilmu : ilmu
# terima : terima
# kasih : kasih
# down : down
# kah : kah
# film : film
# gabisa : gabisa
# paswot : paswot
# login : login
# susah : susah
# mind : mind
# help : help
# molor : molor
# cepat : cepat
# kalai : kalai
# putusin : putusin
# wifinya : wifinya
# mendingan : mending
# kuota : kuota
# berhenti : henti
# mesin : mesin
# dicabut : cabut
# oiya : oiya
# memperluas : luas
# namanya : nama
# harganya : harga
# biaya : biaya
# izin : izin
# bos : bos
# member : member
# youtube : youtube
# putar : putar
# puter : puter
# harga : harga
# paket : paket
# prosesnya : proses
# engga : engga
# mempermudah : mudah
# pelanggan : langgan
# good : good
# jobbb : jobbb
# lost : lost
# mulu : mulu
# nyesel : nyesel
# pasang : pasang
# tindaklanjut : tindaklanjut
# laporannya : lapor
# ditempat : tempat
# keterangannya : terang
# mantul : mantul
# thankyou : thankyou
# sekrnag : sekrnag
# jaringanya : jaringanya
# terusss : terusss
# penjualan : jual
# jasa : jasa
# komunikasi : komunikasi
# kelas : kelas
# nasional : nasional
# sekelas : kelas
# bumn : bumn
# memiliki : milik
# skema : skema
# tarif : tarif
# istilahnya : istilah
# menyaksikan : saksi
# liga : liga
# inggris : inggris
# dmana : dmana
# wkekwk : wkekwk
# untung : untung
# depok : depok
# maaciw : maaciw
# area : area
# lubang : lubang
# buaya : buaya
# jakarta : jakarta
# timur : timur
# sekalihhhh : sekalihhhh
# jaya : jaya
# kesini : kesini
# ulangan : ulang
# nugas : nugas
# numpuk : numpuk
# yeay : yeay
# fast : fast
# tdi : tdi
# normal : normal
# payah : payah
# suka : suka
# loss : loss
# emang : emang
# sengaja : sengaja
# ambruk : ambruk
# donlod : donlod
# apps : apps
# myindihome : myindihome
# dimnaa : dimnaa
# mba : mba
# knpa : knpa
# layanan : layan
# iklannya : iklan
# versi : versi
# terhapus : hapus
# instal : instal
# youtubenya : youtubenya
# henti : henti
# menganggu : menganggu
# pembayaran : bayar
# tanggal : tanggal
# segini : gin
# vidio : vidio
# terlambat : lambat
# dikenakan : kena
# dendanya : denda
# kenceng : kenceng
# polll : polll
# trs : trs
# ditambah : tambah
# conect : conect
# mhn : mhn
# solusi : solusi
# memecahkan : pecah
# teoritis : teoritis
# ngeleg : ngeleg
# telkomsel : telkomsel
# adminn : adminn
# knp : knp
# mkin : mkin
# ksini : ksini
# tlong : tlong
# donk : donk
# byar : byar
# puas : puas
# jringan : jringan
# sma : sma
# bohong : bohong
# shiaap : shiaap
# sukses : sukses
# power : power
# carany : carany
# banyuanny : banyuanny
# jalur : jalur
# teleponnya : telepon
# barusan : barusan
# coba : coba
# wahh : wahh
# mantapp : mantapp
# pahlawannya : pahlawan
# telkom : telkom
# provider : provider
# membanggakan : bangga
# tombol : tombol
# powwe : powwe
# remote : remote
# sulit : sulit
# dihidupkan : hidup
# dimatikan : mati
# solusinya : solusi
# download : download
# dimana : mana
# cabut : cabut
# kabel : kabel
# restat : restat
# jwban : jwban
# klian : klian
# seamless : seamless
# maksimal : maksimal
# device : device
# restar : restar
# fungsinya : fungsi
# oke : oke
# tlp : tlp
# nov : nov
# smp : smp
# skrg : skrg
# tindakan : tindak
# rmh : rmh
# janji : janji
# dtg : dtg
# memperbaiki : baik
# super : super
# lambat : lambat
# internetnya : internetnya
# upload : upload
# lokasi : lokasi
# tangerang : tangerang
# balaraja : balaraja
# inbox : inbox
# terkirim : kirim
# mbantuannha : mbantuannha
# pket : pket
# telponnya : telpon
# dhapus : dhapus
# brp : brp
# dihati : hati
# buruab : buruab
# halooo : halooo
# skg : skg
# pengaduan : adu
# unduh : unduh
# woi : woi
# lagging : lagging
# interlokalnya : interlokal
# maen : maen
# game : game
# nonaktifkan : nonaktif
# kaka : kaka
# halo : halo
# mafi : mafi
# aamai : aamai
# mlm : mlm
# nga : nga
# dri : dri
# kereen : kereen
# stabil : stabil
# whf : whf
# berkat : berkat
# perkerjaan : kerja
# odc : odc
# alamat : alamat
# adress : adress
# apaaa : apaaa
# sip : sip
# informasi : informasi
# berguna : guna
# pengetahuan : tahu
# kotak : kotak
# besi : besi
# pinggir : pinggir
# jalan : jalan
# sungguh : sungguh
# kecewa : kecewa
# berfungsi : fungsi
# anak : anak
# belajar : ajar
# online : online
# wawasan : wawas
# nice : nice
# hub : hub
# orang : orang
# wfnya : wfnya
# liat : liat
# bingung : bingung
# menurunkan : turun
# speed : speed
# terimakasih : terimakasih
# sebulan : bulan
# dng : dng
# oktober : oktober
# sayang : sayang
# paksa : paksa
# mengecewak : mengecewak
# kumat : kumat
# nyambung : nyambung
# ngga : ngga
# diakses : akses
# aduh : aduh
# indikontol : indikontol
# ngelag : ngelag
# nanya : nanya
# nunggak : nunggak
# tingkatkan : tingkat
# rugi : rugi
# via : via
# minimarket : minimarket
# tokoped : tokoped
# shopee : shopee
# dana : dana
# pon : pon
# merah : merah
# terkoneksi : koneksi
# dibantu : bantu
# mantep : mantep
# tnya : tnya
# router : router
# dirmh : dirmh
# berkedip : kedip
# benerin : benerin
# seminggu : minggu
# ajah : ajah
# kerusakan : rusa
# hadeuh : hadeuh
# cape : cape
# konsumen : konsumen
# waah : waah
# kesalahan : salah
# server : server
# pokoknya : pokok
# berwarna : warna
# direspon : direspon
# ketemu : ketemu
# bot : bot
# balasannya : balas
# laporan : lapor
# ditanggepin : ditanggepin
# message : message
# komplain : komplain
# disalahin : disalahin
# tersambung : sambung
# req : req
# uda : uda
# jadul : jadul
# tahunan : tahun
# ktny : ktny
# rusak : rusak
# gwblck : gwblck
# hancurin : hancurin
# jengkel : jengkel
# baca : baca
# waw : waw
# yaaa : yaaa
# infonyaa : infonyaa
# sehat : sehat
# ciangsana : ciangsana
# yeayyy : yeayyy
# dennda : dennda
# misi : misi
# pesan : pesan
# main : main
# bantuannya : bantu
# sesuai : sesuai
# kesepakatan : sepakat
# penjelasannya : jelas
# konsisten : konsisten
# melayani : layan
# keluhan : keluh
# jawabannya : jawab
# sabtu : sabtu
# novenber : novenber
# kamis : kamis
# koneksinya : koneksi
# tok : tok
# bales : bales
# bhwa : bhwa
# truss : truss
# udh : udh
# harian : hari
# hati : hati
# minggu : minggu
# dicuekin : dicuekin
# klu : klu
# ngk : ngk
# kabelnya : kabel
# kedip : kedip
# arep : arep
# mbayar : mbayar
# ket : ket
# wingi : wing
# mancen : mancen
# celeng : celeng
# babi : babi
# kemaren : kemaren
# menunggu : tunggu
# teknisinya : teknisi
# dikampung : kampung
# lancarr : lancarr
# bangett : bangett
# menghubungi : hubung
# petugas : tugas
# belom : bom
# mat : mat
# sedangkn : sedangkn
# optik : optik
# kirim : kirim
# balas : balas
# siangnya : siang
# ehh : ehh
# mantappppppp : mantappppppp
# bangetttt : bangetttt
# hadir : hadir
# menemani : tani
# malas : malas
# lihat : lihat
# pura : pura
# answering : answering
# machine : machine
# konyol : konyol
# nurunin : nurunin
# mantap : mantap
# banjar : banjar
# patroman : patroman
# anton : anton
# disney : disney
# bosen : bosen
# smua : smua
# terhubung : hubung
# sinyal : sinyal
# ilang : ilang
# semoga : moga
# yaa : yaa
# kecepatan : cepat
# istilah : istilah
# nomad : nomad
# bkn : bkn
# dinomor : nomor
# gunakn : gunakn
# internetx : internetx
# lancaaaaar : lancaaaaar
# berdoa : doa
# aplikask : aplikask
# pilihannya : pilih
# chat : chat
# messenger : messenger
# mesti : mesti
# pasrah : pasrah
# order : order
# myid : myid
# xxxxxx : xxxxxx
# besoknya : besok
# penuh : penuh
# kejelasan : jelas
# konfirmasi : konfirmasi
# kelanjutan : lanjut
# prosesny : prosesny
# penanganya : penanganya
# loz : loz
# melaporkan : lapor
# pilihan : pilih
# buset : buset
# macet : macet
# angka : angka
# lgi : lgi
# ngapain : ngapain
# membayar : bayar
# moban : mob
# follup : follup
# hubungi : hubung
# masanger : masanger
# sudh : sudh
# bulanan : bulan
# rto : rto
# perbaikan : baik
# nggk : nggk
# tanggapan : tanggap
# tunggakan : tunggak
# diblokir : blokir
# usetv : usetv
# bermain : main
# ping : ping
# downgrade : downgrade
# robot : robot
# mola : mola
# biayanya : biaya
# brpa : brpa
# indiehome : indiehome
# viu : viu
# woyy : woyy
# error : error
# facebook : facebook
# mahal : mahal
# permisi : permisi
# admin : admin
# mengajukan : aju
# dipasang : pasang
# aktivasi : aktivasi
# ribu : ribu
# bgitu : bgitu
# mengpa : mengpa
# sekrang : sekrang
# cuman : cuman
# kuat : kuat
# beda : beda
# enakan : enak
# mah : mah
# make : make
# kgk : kgk
# memakai : pakai
# perbulan : bulan
# terpantau : pantau
# iklan : iklan
# contohnya : contoh
# gta : gta
# betulkan : betul
# indita : indita
# kesel : kesel
# registrasi : registrasi
# makasi : makas
# selaluu : selaluu
# penanganan : tangan
# ampun : ampun
# huawei : huawei
# kadang : kadang
# hilang : hilang
# sring : sring
# bnget : bnget
# custumer : custumer
# service : service
# buruk : buruk
# koq : koq
# kerumah : rumah
# parah : parah
# renew : renew
# comment : comment
# wall : wall
# tlg : tlg
# check : check
# plh : plh
# hasil : hasil
# asyek : asyek
# bin : bin
# ajaib : ajaib
# sumpah : sumpah
# pelayan : layan
# berubah : ubah
# instant : instant
# naek : naek
# speednya : speednya
# anjg : anjg
# bank : bank
# macem : macem
# urusannya : urus
# byr : byr
# ditawarkan : tawar
# gmna : gmna
# kemari : kemari
# pindah : pindah
# menyesuaikan : sesuai
# kebutuhan : butuh
# system : system
# permintaan : minta
# sabi : sabi
# bedanya : beda
# renewspeed : renewspeed
# contoh : contoh
# katay : katay
# perbln : perbln
# ngambil : ngambil
# live : live
# spanyol : spanyol
# italia : italia
# champion : champion
# menampilkan : tampil
# siput : siput
# care : care
# dahh : dahh
# kmrin : kmrin
# cust : cust
# perhari : hari
# berulang : ulang
# kali : kali
# kmrn : kmrn
# subuh : subuh
# kurleb : kurleb
# ditangani : tangan
# senang : senang
# proses : proses
# brapa : brapa
# msh : msh
# hadeeeeh : hadeeeeh
# terhebat : hebat
# petukangan : tukang
# utara : utara
# jaksel : jaksel
# browser : browser
# miiin : miiin
# merugikan : rugi
# aktifitas : aktifitas
# seru : seru
# ditunda : tunda
# nontonnya : nontonnya
# byk : byk
# kerjaan : kerja
# heheh : heheh
# pause : pause
# stiap : stiap
# kopisoe : kopisoe
# moto : moto
# jangkuan : jangkuan
# mantabbb : mantabbb
# lancarrr : lancarrr
# ganguan : ganguan
# kabar : kabar
# habis : habis
# rb : rb
# masal : masal
# wilah : wilah
# herannya : heran
# tetangga : tetangga
# pilih : pilih
# zoom : zoom
# ragu : ragu
# kencang : kencang
# dijamin : jamin
# kegiatan : giat
# aman : aman
# terkendali : kendali
# indie : indie
# home : home
# laporkan : lapor
# ienternet : ienternet
# indonesia : indonesia
# miris : miris
# informisnya : informisnya
# nerima : nerima
# tlpn : tlpn
# whatsup : whatsup
# menghubungkan : hubung
# tpi : tpi
# kualitas : kualitas
# nol : nol
# harap : harap
# tiket : tiket
# acces : acces
# internetkak : internetkak
# {'hallo': 'hallo', 'min': 'min', 'rumah': 'rumah', 'konek': 'konek', 'wifi': 'wifi', '': '', 'sya': 'sya', 'tagihan': 'tagih', 'berbeda': 'beda', 'sore': 'sore', 'mintol': 'mintol', 'refresh': 'refresh', 'jaringan': 'jaring', 'kak': 'kak', 'cek': 'cek', 'bln': 'bln', 'november': 'november', 'mimin': 'mimin', 'modem': 'modem', 'indihome': 'indihome', 'windows': 'windows', 'plug': 'plug', 'and': 'and', 'play': 'play', 'setting': 'setting', 'koneksi': 'koneksi', 'los': 'los', 'malam': 'malam', 'pagi': 'pagi', 'jam': 'jam', 'alhamdulillah': 'alhamdulillah', 'tagihanku': 'tagih', 'lancar': 'lancar', 'koneksimu': 'koneksi', 'ngak': 'ngak', 'bener': 'bener', 'bayar': 'bayar', 'langsung': 'langsung', 'dpt': 'dpt', 'gratis': 'gratis', 'cocok': 'cocok', 'letakin': 'letakin', 'bagus': 'bagus', 'ruangan': 'ruang', 'terjangkau': 'jangkau', 'skrng': 'skrng', 'buka': 'buka', 'bbrpa': 'bbrpa', 'app': 'app', 'stuk': 'stuk', 'masuk': 'masuk', 'data': 'data', 'tolong': 'tolong', 'bantuan': 'bantu', 'upgrade': 'upgrade', 'bgmna': 'bgmna', 'mengatasi': 'atas', 'authentifikasi': 'authentifikasi', 'keren': 'keren', 'membantu': 'bantu', 'siaran': 'siar', 'muncul': 'muncul', 'ganti': 'ganti', 'password': 'password', 'gimana': 'gimana', 'stop': 'stop', 'ber': 'ber', 'langganan': 'langgan', 'alat': 'alat', 'balikin': 'balikin', 'plaza': 'plaza', 'telat': 'telat', 'sehari': 'hari', 'mati': 'mati', 'inet': 'inet', 'eror': 'eror', 'sampe': 'sampe', 'berlangganan': 'langgan', 'kemarin': 'kemarin', 'siang': 'siang', 'sinyalnya': 'sinyal', 'mengalami': 'alami', 'gangguan': 'ganggu', 'sorenya': 'sore', 'dikutak': 'kutak', 'kutik': 'kutik', 'gambar': 'gambar', 'bermasalah': 'masalah', 'layar': 'layar', 'nggak': 'nggak', 'terbuka': 'buka', 'mohon': 'mohon', 'teknisi': 'teknisi', 'indihom': 'indihom', 'turun': 'turun', 'tangan': 'tangan', 'membetulkan': 'betul', 'kaya': 'kaya', 'gini': 'gin', 'dimn': 'dimn', 'lemot': 'lot', 'cak': 'cak', 'akses': 'akses', 'org': 'org', 'maaf': 'maaf', 'putus': 'putus', 'blm': 'blm', 'pemakaian': 'pakai', 'kena': 'kena', 'denda': 'denda', 'drumh': 'drumh', 'kbelny': 'kbelny', 'btulin': 'btulin', 'kpn': 'kpn', 'lmbt': 'lmbt', 'bnr': 'bnr', 'bls': 'bls', 'inbok': 'inbok', 'respon': 'respon', 'trus': 'trus', 'perbaiki': 'baik', 'indohome': 'indohome', 'nagih': 'nagih', 'jelek': 'jelek', 'dear': 'dear', 'dikit': 'dikit', 'funishment': 'funishment', 'gue': 'gue', 'gua': 'gua', 'neko': 'neko', 'elu': 'elu', 'alasan': 'alas', 'fup': 'fup', 'terisolir': 'isolir', 'udah': 'udah', 'tgl': 'tgl', 'oct': 'oct', 'telp': 'telp', 'dibuka': 'buka', 'giliran': 'gilir', 'cepet': 'cepet', 'pelayanan': 'layan', 'berbanding': 'banding', 'lurus': 'lurus', 'dibayar': 'bayar', 'balesnya': 'balesnya', 'lelet': 'lelet', 'aneh': 'aneh', 'lapor': 'lapor', 'kantor': 'kantor', 'ttp': 'ttp', 'enggk': 'enggk', 'tanggapi': 'tanggap', 'tagih': 'tagih', 'mbps': 'mbps', 'teman': 'teman', 'gmn': 'gmn', 'nie': 'nie', 'daerah': 'daerah', 'kalbar': 'kalbar', 'karna': 'karna', 'bencana': 'bencana', 'stb': 'stb', 'nyala': 'nyala', 'colok': 'colok', 'adapter': 'adapter', 'adaptor': 'adaptor', 'menyala': 'nyala', 'diganti': 'ganti', 'unit': 'unit', 'semalam': 'malam', 'pleaseeeeeeee': 'pleaseeeeeeee', 'kerja': 'kerja', 'wihhh': 'wihhh', 'makasih': 'makasih', 'informasinya': 'informasi', 'mengerti': 'erti', 'loginnya': 'loginnya', 'username': 'username', 'pencerahan': 'cerah', 'ketentuan': 'tentu', 'deposit': 'deposit', 'skrang': 'skrang', 'wfh': 'wfh', 'cinta': 'cinta', 'sod': 'sod', 'aplikasi': 'aplikasi', 'malem': 'malem', 'nomor': 'nomor', 'internet': 'internet', 'segampang': 'gampang', 'ssid': 'ssid', 'infonya': 'info', 'restart': 'restart', 'connection': 'connection', 'selamat': 'selamat', 'pahlawan': 'pahlawan', 'salah': 'salah', 'era': 'era', 'digital': 'digital', 'nomer': 'nomer', 'kontrak': 'kontrak', 'daftar': 'daftar', 'pemasangan': 'pasang', 'jum': 'jum', 'sekrg': 'sekrg', 'blom': 'blom', 'info': 'info', 'deh': 'deh', 'bermanfaat': 'manfaat', 'banget': 'banget',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/336 [00:00<?, ?it/s]
#                                                comment  \
# 0    hallo min, kenapa di rumah saya beberapa hp ti...
# 1             sya mw tanya ko tagihan saya berbeda2...
# 2                      sore mintol refresh jaringan ya
# 3               kak mau cek tagihan bln november bisa?
# 4    mimin. saya mau tanya dong. bagaimana cara kon...
# ..                                                 ...
# 374               gini amat ienternet indonesia  miris
# 375  wah main tambah wawasan aja nih, makasih ya in...
# 376  dri setelah pembayaran sampe skrg lemot terus,...
# 377  tolong kalau laporan di respon,  sudah sya inb...
# 378  kak mau pengaduan layanan indihome-nya terhubu...
#
#                                       cleaning_comment  \
# 0    hallo min kenapa rumah saya beberapa tidak bis...
# 1                     sya tanya tagihan saya berbeda
# 2                        sore mintol refresh jaringan
# 3               kak mau cek tagihan bln november bisa
# 4    mimin saya mau tanya dong bagaimana cara konek...
# ..                                                 ...
# 374                gini amat ienternet indonesia miris
# 375  wah main tambah wawasan aja nih makasih inform...
# 376  dri setelah pembayaran sampe skrg lemot terus ...
# 377  tolong kalau laporan respon sudah sya inbox ha...
# 378  kak mau pengaduan layanan indihome nya terhubu...
#
#                                             tokenisasi  \
# 0    [hallo, min, kenapa, rumah, saya, beberapa, ti...
# 1               [sya, tanya, tagihan, saya, berbeda, ]
# 2                  [sore, mintol, refresh, jaringan, ]
# 3      [kak, mau, cek, tagihan, bln, november, bisa, ]
# 4    [mimin, saya, mau, tanya, dong, bagaimana, car...
# ..                                                 ...
# 374          [gini, amat, ienternet, indonesia, miris]
# 375  [wah, main, tambah, wawasan, aja, nih, makasih...
# 376  [dri, setelah, pembayaran, sampe, skrg, lemot,...
# 377  [tolong, kalau, laporan, respon, sudah, sya, i...
# 378  [kak, mau, pengaduan, layanan, indihome, nya, ...
#
#                                               stopword  \
# 0                   [hallo, min, rumah, konek, wifi, ]
# 1                            [sya, tagihan, berbeda, ]
# 2                  [sore, mintol, refresh, jaringan, ]
# 3                 [kak, cek, tagihan, bln, november, ]
# 4    [mimin, konek, modem, indihome, windows, plug,...
# ..                                                 ...
# 374                [gini, ienternet, indonesia, miris]
# 375              [main, wawasan, makasih, informisnya]
# 376  [dri, pembayaran, sampe, skrg, lemot, nerima, ...
# 377  [tolong, laporan, respon, sya, inbox, harap, t...
# 378  [kak, pengaduan, layanan, indihome, terhubung,...
#
#                                               stemming
# 0                   [hallo, min, rumah, konek, wifi, ]
# 1                                 [sya, tagih, beda, ]
# 2                    [sore, mintol, refresh, jaring, ]
# 3                   [kak, cek, tagih, bln, november, ]
# 4    [mimin, konek, modem, indihome, windows, plug,...
# ..                                                 ...
# 374                 [gin, ienternet, indonesia, miris]
# 375                [main, wawas, makasih, informisnya]
# 376  [dri, bayar, sampe, skrg, lot, nerima, tlpn, w...
# 377  [tolong, lapor, respon, sya, inbox, harap, tik...
# 378  [kak, adu, layan, indihome, hubung, acces, int...
#
# [336 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                   [hallo, min, rumah, konek, wifi, ]
# 1                                 [sya, tagih, beda, ]
# 2                    [sore, mintol, refresh, jaring, ]
# 3                   [kak, cek, tagih, bln, november, ]
# 4    [mimin, konek, modem, indihome, windows, plug,...
# ..                                                 ...
# 374                 [gin, ienternet, indonesia, miris]
# 375                [main, wawas, makasih, informisnya]
# 376  [dri, bayar, sampe, skrg, lot, nerima, tlpn, w...
# 377  [tolong, lapor, respon, sya, inbox, harap, tik...
# 378  [kak, adu, layan, indihome, hubung, acces, int...
#
# [336 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_11.xlsx')
