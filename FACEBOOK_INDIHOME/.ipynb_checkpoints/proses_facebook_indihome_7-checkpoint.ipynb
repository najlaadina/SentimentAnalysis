# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_7.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    Bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             Aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  Iklan kencang banget tapi kualitas internet do...
# 437  Kalau sudah berlangganan add on seamless cara ...
# 438  Bayarnya paket 20Mbps, dapetnya gak  nyampe 10...
#
# [439 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    Bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             Aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  Iklan kencang banget tapi kualitas internet do...
# 437  Kalau sudah berlangganan add on seamless cara ...
# 438  Bayarnya paket 20Mbps, dapetnya gak  nyampe 10...
#
# [427 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add on seamless cara ...
# 438  bayarnya paket 20mbps, dapetnya gak  nyampe 10...
#
# [427 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add on seamless cara ...
# 438  bayarnya paket 20mbps, dapetnya gak  nyampe 10...
#
#                                       cleaning_comment
# 0    min ada kompensasi gak untuk pelanggan jika ja...
# 1    indicare tampilan depan indi knp hari ini begi...
# 2    paket mbps fakta mbps ada min gimana min kemar...
# 3    kenapa layanan chat indihome dibalas banyak na...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                               aku mau pasang wifi
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add seamless cara men...
# 438  bayarnya paket  mbps dapetnya gak nyampe  mbps...
#
# [427 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add on seamless cara ...
# 438  bayarnya paket 20mbps, dapetnya gak  nyampe 10...
#
#                                       cleaning_comment  \
# 0    min ada kompensasi gak untuk pelanggan jika ja...
# 1    indicare tampilan depan indi knp hari ini begi...
# 2    paket mbps fakta mbps ada min gimana min kemar...
# 3    kenapa layanan chat indihome dibalas banyak na...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                               aku mau pasang wifi
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add seamless cara men...
# 438  bayarnya paket  mbps dapetnya gak nyampe  mbps...
#
#                                             tokenisasi
# 0    [min, ada, kompensasi, gak, untuk, pelanggan, ...
# 1    [indicare, tampilan, depan, indi, knp, hari, i...
# 2    [paket, mbps, fakta, mbps, ada, min, gimana, m...
# 3    [kenapa, layanan, chat, indihome, dibalas, ban...
# 4    [bulan, april, saya, sudah, mengajukan, peruba...
# ..                                                 ...
# 434                         [aku, mau, pasang, wifi, ]
# 435        [praktis, banget, dah, ada, aplikasi, myih]
# 436  [iklan, kencang, banget, tapi, kualitas, inter...
# 437  [kalau, sudah, berlangganan, add, seamless, ca...
# 438  [bayarnya, paket, mbps, dapetnya, gak, nyampe,...
#
# [427 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add on seamless cara ...
# 438  bayarnya paket 20mbps, dapetnya gak  nyampe 10...
#
#                                       cleaning_comment  \
# 0    min ada kompensasi gak untuk pelanggan jika ja...
# 1    indicare tampilan depan indi knp hari ini begi...
# 2    paket mbps fakta mbps ada min gimana min kemar...
# 3    kenapa layanan chat indihome dibalas banyak na...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                               aku mau pasang wifi
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add seamless cara men...
# 438  bayarnya paket  mbps dapetnya gak nyampe  mbps...
#
#                                             tokenisasi  \
# 0    [min, ada, kompensasi, gak, untuk, pelanggan, ...
# 1    [indicare, tampilan, depan, indi, knp, hari, i...
# 2    [paket, mbps, fakta, mbps, ada, min, gimana, m...
# 3    [kenapa, layanan, chat, indihome, dibalas, ban...
# 4    [bulan, april, saya, sudah, mengajukan, peruba...
# ..                                                 ...
# 434                         [aku, mau, pasang, wifi, ]
# 435        [praktis, banget, dah, ada, aplikasi, myih]
# 436  [iklan, kencang, banget, tapi, kualitas, inter...
# 437  [kalau, sudah, berlangganan, add, seamless, ca...
# 438  [bayarnya, paket, mbps, dapetnya, gak, nyampe,...
#
#                                               stopword
# 0    [min, kompensasi, pelanggan, jaringan, interne...
# 1    [indicare, tampilan, indi, knp, off, pakai, re...
# 2    [paket, mbps, fakta, mbps, min, gimana, min, k...
# 3    [layanan, chat, indihome, dibalas, nama, raska...
# 4    [april, mengajukan, perubahan, tagihan, pembay...
# ..                                                 ...
# 434                                   [pasang, wifi, ]
# 435                  [praktis, banget, aplikasi, myih]
# 436  [iklan, kencang, banget, kualitas, internet, d...
# 437    [berlangganan, add, seamless, menggunakannya, ]
# 438  [bayarnya, paket, mbps, dapetnya, nyampe, mbps...
#
# [427 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1204
# ------------------------
# min : min
# kompensasi : kompensasi
# pelanggan : langgan
# jaringan : jaring
# internet : internet
# bermasalah : masalah
#  :
# indicare : indicare
# tampilan : tampil
# indi : indi
# knp : knp
# off : off
# pakai : pakai
# remote : remote
# sttb : sttb
# box : box
# tetep : tetep
# spt : spt
# paket : paket
# mbps : mbps
# fakta : fakta
# gimana : gimana
# kemarin : kemarin
# komplin : komplin
# layanan : layan
# chat : chat
# indihome : indihome
# dibalas : balas
# nama : nama
# raska : raska
# ara : ara
# indri : indri
# lumi : lum
# akun : akun
# abal : abal
# april : april
# mengajukan : aju
# perubahan : ubah
# tagihan : tagih
# pembayaran : bayar
# ribu : ribu
# disetujui : tuju
# bayar : bayar
# wifinya : wifinya
# knpa : knpa
# losnya : los
# berwarna : warna
# merah : merah
# malam : malam
# solusi : solusi
# responnya : responnya
# bru : bru
# paaang : paaang
# dri : dri
# pasang : pasang
# blm : blm
# minggu : minggu
# tpi : tpi
# ngadat : ngadat
# lemot : lot
# intrrnetnya : intrrnetnya
# ganti : ganti
# mesin : mesin
# modemnya : modem
# teknisi : teknisi
# ttp : ttp
# nfadat : nfadat
# los : los
# udah : udah
# tlp : tlp
# tersambung : sambung
# customer : customer
# servis : servis
# pls : pls
# habis : habis
# nunggu : nunggu
# kesambung : sambung
# via : via
# apk : apk
# nomer : nomer
# hai : hai
# sodara : sodara
# senin : senin
# kamis : kamis
# terselesaikan : selesai
# wifi : wifi
# kendala : kendala
# gini : gin
# kasih : kasih
# sesuai : sesuai
# harga : harga
# gmn : gmn
# bos : bos
# sinyal : sinyal
# rmh : rmh
# jelek : jelek
# trobel : trobel
# inbox : inbox
# tanggapi : tanggap
# daftar : daftar
# ferifikasi : ferifikasi
# wkwkkw : wkwkkw
# dirumah : rumah
# lambat : lambat
# mohon : mohon
# diperbaiki : baik
# izin : izin
# lampu : lampu
# router : router
# koneksi : koneksi
# solusinya : solusi
# alhamdulillah : alhamdulillah
# menukar : tukar
# poin : poin
# seharus : harus
# dimasa : masa
# ppkm : ppkm
# darurat : darurat
# kelonggaran : longgar
# discount : discount
# mulu : mulu
# membengkak : bengkak
# padhal : padhal
# aplikasi : aplikasi
# tambahan : tambah
# seamless : seamless
# maksimal : maksimal
# device : device
# maaf : maaf
# tolong : tolong
# bantu : bantu
# tersenyum : senyum
# tertawaaaaa : tertawaaaaa
# malem : malem
# penuh : penuh
# call : call
# center : center
# brp : brp
# gangguan : ganggu
# jam : jam
# dibantu : bantu
# admin : admin
# ajh : ajh
# pikirin : pikirin
# mati : mati
# semalem : semalem
# kunjung : kunjung
# bener : bener
# account : account
# password : password
# stb : stb
# dimana : mana
# mudah : mudah
# banget : banget
# makasih : makasih
# infonya : info
# mimin : mimin
# kak : kak
# loss : loss
# unsubscribe : unsubscribe
# cloud : cloud
# storage : storage
# coba : coba
# app : app
# pilihan : pilih
# pakek : pakek
# dana : dana
# kaga : kaga
# nomor : nomor
# salah : salah
# sebulan : bulan
# ngga : ngga
# sampe : sampe
# cape : cape
# laporan : lapor
# cek : cek
# inboxx : inboxx
# minn : minn
# restart : restart
# permisi : permisi
# myindihome : myindihome
# dilogin : dilogin
# kpan : kpan
# jaringgan : jaringgan
# pengen : ken
# masuk : masuk
# bsa : bsa
# hapus : hapus
# cache : cache
# udh : udh
# update : update
# kali : kali
# tgl : tgl
# laporkan : lapor
# dpt : dpt
# juni : juni
# direspon : direspon
# normal : normal
# bln : bln
# dikurang : kurang
# sya : sya
# ngk : ngk
# tanggal : tanggal
# smpe : smpe
# skarang : skarang
# lapor : lapor
# kantor : kantor
# blum : blum
# kolom : kolom
# pemakaian : pakai
# kuota : kuota
# pdhl : pdhl
# refresh : refresh
# trs : trs
# kyk : kyk
# gni : gni
# jdi : jdi
# gatau : gatau
# pemasangan : pasang
# trus : trus
# ppn : ppn
# perjanjian : janji
# strusnya : strusnya
# baca : baca
# chatt : chatt
# miminnnnnnnn : miminnnnnnnn
# restar : restar
# halooo : halooo
# miminnnnnnnnnn : miminnnnnnnnnn
# email : email
# konfirmasi : konfirmasi
# nanya : nanya
# konfirm : konfirm
# ngirim : ngirim
# lanjutkan : lanjut
# indihomecare : indihomecare
# pindah : pindah
# alamat : alamat
# perangkat : perangkat
# ribet : ribet
# prosesnya : proses
# region : region
# kecamatan : camat
# ditunggu : tunggu
# ajukan : aju
# full : full
# apapun : apa
# dihub : dihub
# maintenance : maintenance
# pagi : pagi
# nyata : nyata
# skrg : skrg
# nihil : nihil
# belom : bom
# nyala : nyala
# harapan : harap
# bayaran : bayar
# mah : mah
# error : error
# hilang : hilang
# connected : connected
# ngatasi : ngatasi
# info : info
# internetnya : internetnya
# yaah : yaah
# langganan : langgan
# cable : cable
# berdasarkan : dasar
# kecepatan : cepat
# hallo : hallo
# bantuan : bantu
# kmna : kmna
# program : program
# acak : acak
# inhouse : inhouse
# induse : induse
# kmrin : kmrin
# modem : modem
# putih : putih
# kaya : kaya
# ditertibkan : tertib
# memalukan : malu
# beli : beli
# dmn : dmn
# karyawan : karyawan
# cipongkor : cipongkor
# kab : kab
# bandung : bandung
# barat : barat
# routerny : routerny
# penggantian : ganti
# gtu : gtu
# usianamy : usianamy
# thun : thun
# pny : pny
# tetangga : tetangga
# tulisan : tulis
# msh : msh
# jadul : jadul
# peninggaran : peninggaran
# typo : typo
# pelayanan : layan
# amburadul : amburadul
# permintaan : minta
# upgrade : upgrade
# speed : speed
# juli : juli
# smp : smp
# progress : progress
# telpon : telpon
# progres : progres
# pendaftaran : daftar
# petunjuk : tunjuk
# berlangganan : langgan
# nambah : nambah
# buka : buka
# channel : channel
# dilayar : layar
# jwbnya : jwbnya
# perbaikan : baik
# ampe : ampe
# segtu : segtu
# pemberitahuan : pemberitahuan
# kondisi : kondisi
# mang : mang
# kena : kena
# aturan : atur
# bulanan : bulan
# muncul : muncul
# gambar : gambar
# matikan : mati
# nyalakan : nyala
# kadang : kadang
# gitu : gitu
# menyala : nyala
# berfungsi : fungsi
# petunjuknya : tunjuk
# halo : halo
# promo : promo
# berlaku : laku
# karawang : karawang
# care : care
# informasinya : informasi
# open : open
# chanel : chanel
# koq : koq
# close : close
# free : free
# diaktifkan : aktif
# respon : respon
# keluhan : keluh
# konfirmasinya : konfirmasi
# aktifkan : aktif
# youtube : youtube
# aktif : aktif
# alokasi : alokasi
# bulananya : bulananya
# pon : pon
# berkedip : kedip
# yaa : yaa
# secepatnya : cepat
# fix : fix
# kegiatan : giat
# sehari : hari
# terganggu : ganggu
# akibat : akibat
# issue : issue
# anjj : anjj
# berhenti : henti
# gmna : gmna
# konek : konek
# pengaduan : adu
# kemana : mana
# nelpon : nelpon
# nggk : nggk
# dpart : dpart
# telponnya : telpon
# emang : emang
# devuce : devuce
# turunkan : turun
# pelayan : layan
# serba : serba
# lelet : lelet
# slot : slot
# sllu : sllu
# stiap : stiap
# penambahan : tambah
# iflix : iflix
# terjemahan : terjemah
# movie : movie
# akunnya : akun
# nyambung : nyambung
# pulsa : pulsa
# kedip : kedip
# aapkah : aapkah
# sdg : sdg
# eror : eror
# root : root
# assalamualaikum : assalamualaikum
# tmbah : tmbah
# add : add
# simless : simless
# susah : susah
# klik : klik
# registrasi : registrasi
# blink : blink
# inet : inet
# indikator : indikator
# wlan : wlan
# hidup : hidup
# gabisa : gabisa
# login : login
# game : game
# main : main
# dll : dll
# lancar : lancar
# servermya : servermya
# kebanyakan : banyak
# ngak : ngak
# kuat : kuat
# kodenya : kode
# munculnya : muncul
# refund : refund
# skr : skr
# remot : remot
# rusak : rusak
# hadeh : hadeh
# sinyalnya : sinyal
# dodol : dodol
# terputus : putus
# complain : complain
# bereskan : beres
# dibuka : buka
# verifikasi : verifikasi
# kabar : kabar
# drop : drop
# woooyyy : woooyyy
# berulang : ulang
# ulang : ulang
# rincian : rincian
# biaya : biaya
# useetv : useetv
# siarkan : siar
# seri : seri
# kah : kah
# musim : musim
# all : all
# ndak : ndak
# putar : putar
# yutub : yutub
# pilih : pilih
# gratisan : gratis
# ultah : ultah
# aktifnya : aktif
# otomatis : otomatis
# kualitas : kualitas
# kebanggaan : bangga
# indonesia : indonesia
# menyesal : sesal
# enak : enak
# bulanannya : bulan
# murah : murah
# tagihannya : tagih
# rutin : rutin
# tlg : tlg
# legal : legal
# tks : tks
# instagram : instagram
# disuruh : suruh
# cabut : cabut
# kabel : kabel
# petugas : tugas
# rumah : rumah
# maksud : maksud
# gimna : gimna
# tiket : tiket
# in : in
# diakses : akses
# komplain : komplain
# barangkali : barangkali
# cover : cover
# area : area
# jabodetabek : jabodetabek
# tindak : tindak
# digrubis : digrubis
# mucul : mucul
# jaringannya : jaring
# cbg : cbg
# tegal : tegal
# peninggalan : tinggal
# gang : gang
# candra : candra
# jalan : jalan
# dibantun : bantun
# kerusakan : rusa
# work : work
# panduannya : pandu
# orbit : orbit
# ngih : ngih
# wilayah : wilayah
# badung : badung
# denpasar : denpasar
# infox : infox
# woy : woy
# bangsat : bangsat
# rb : rb
# februari : februari
# grapari : grapari
# telkomsel : telkomsel
# group : group
# dinoyo : dinoyo
# surabaya : surabaya
# seputar : putar
# downgrade : downgrade
# uninstall : uninstall
# mola : mola
# service : service
# mengkonfirmasi : konfirmasi
# tag : tag
# menghubungkan : hubung
# kirim : kirim
# screenshot : screenshot
# maksudnya : maksud
# keempat : empat
# kelar : kelar
# status : status
# massal : massal
# indihomenya : indihomenya
# selamat : selamat
# pemindahan : pindah
# instalas : instalas
# kemaren : kemaren
# blom : blom
# ditangani : tangan
# besok : besok
# libursusah : libursusah
# anak : anak
# sekolah : sekolah
# daring : daring
# fungsi : fungsi
# set : set
# membantu : bantu
# yth : yth
# domisili : domisili
# kabupaten : kabupaten
# banyumas : banyumas
# lamban : lamban
# bumn : bumn
# slalu : slalu
# stabil : stabil
# hariii : hariii
# mind : mind
# perbaiki : baik
# not : not
# conected : conected
# bantuannya : bantu
# terima : terima
# dibenerin : dibenerin
# ehhh : ehhh
# indiehome : indiehome
# hadeeehhhhh : hadeeehhhhh
# wew : wew
# tips : tips
# wooi : wooi
# gua : gua
# pelayannannya : pelayannannya
# cepet : cepet
# oke : oke
# yutube : yutube
# putus : putus
# penyebabnya : sebab
# skrng : skrng
# tunggu : tunggu
# bls : bls
# awet : awet
# soak : soak
# semalam : malam
# terkoneksi : koneksi
# trimksh : trimksh
# remotnya : remotnya
# diganti : ganti
# syarat : syarat
# pencabutan : cabut
# plastikin : plastikin
# remotenya : remotenya
# cpm : cpm
# pesan : pesan
# tersedia : sedia
# paketan : paket
# gantinya : ganti
# july : july
# tangerang : tangerang
# lost : lost
# wadduh : wadduh
# hebatnya : hebat
# nikmati : nikmat
# siaran : siar
# langsung : langsung
# kempetisi : kempetisi
# bola : bola
# voly : voly
# dunia : dunia
# diselenggarakan : selenggara
# emelia : emelia
# romagna : romagna
# itali : itali
# manado : manado
# indikasi : indikasi
# redaman : redam
# pelayannya : layan
# sampek : sampek
# detik : detik
# fuul : fuul
# melulu : melulu
# komplen : komplen
# betulin : betulin
# trouble : trouble
# ngangkat : ngangkat
# donlod : donlod
# ato : ato
# hati : hati
# mb : mb
# fup : fup
# mentok : mentok
# kb : kb
# banter : banter
# gaada : gaada
# terhubung : hubung
# mempengaruhi : pengaruh
# lapangan : lapang
# pengawas : awas
# quality : quality
# control : control
# wana : wana
# nangani : nangani
# gmana : gmana
# komen : komen
# cht : cht
# skali : skali
# kecewa : kecewa
# tanggung : tanggung
# request : request
# tiang : tiang
# itupun : itu
# setahun : tahun
# teknisinya : teknisi
# geleng : geleng
# kepala : kepala
# sambungan : sambung
# berkali : kali
# sore : sore
# nggak : nggak
# lokasi : lokasi
# puri : puri
# pangen : pangen
# purwokerto : purwokerto
# colomadu : colomadu
# karanganyar : karanganyar
# niatnya : niat
# kerja : kerja
# tanda : tanda
# nerah : nerah
# menu : menu
# boro : boro
# pengajuan : aju
# odp : odp
# ponorogo : ponorogo
# orang : orang
# lbh : lbh
# kepikiran : pikir
# provider : provider
# klw : klw
# kambuh : kambuh
# terhambat : hambat
# kmrn : kmrn
# kirain : kirain
# ditgg : ditgg
# semlm : semlm
# mlmny : mlmny
# kabelnya : kabel
# gegara : gegara
# digigit : gigit
# tikusemank : tikusemank
# ganas : ganas
# tikus : tikus
# drmh : drmh
# wil : wil
# dki : dki
# sisi : sisi
# siang : siang
# lakukan : laku
# keterangan : terang
# hubungi : hubung
# tindakan : tindak
# sambit : sambit
# troubel : troubel
# sananya : sana
# pgn : pgn
# kelanjutannya : lanjut
# tombol : tombol
# khusus : khusus
# daerah : daerah
# binong : bong
# subang : subang
# jawabarat : jawabarat
# bawa : bawa
# kabur : kabur
# uang : uang
# deposit : deposit
# duit : duit
# maling : maling
# rmah : rmah
# krang : krang
# meter : meter
# tepi : tepi
# pel : pel
# eeh : eeh
# wakakak : wakakak
# sabar : sabar
# merahnya : merah
# ooiw : ooiw
# ganggu : ganggu
# oouuuuuuuu : oouuuuuuuu
# llampu : llampu
# sebentar : sebentar
# wajar : wajar
# indigo : indigo
# lusa : lusa
# harian : hari
# layangan : layang
# arek : arek
# tibak : tibak
# sonone : sonone
# say : say
# bengkulu : bengkulu
# kota : kota
# singaran : singaran
# pati : pati
# download : download
# online : online
# mengatasi : atas
# ngeleg : ngeleg
# permasalahan : masalah
# suruh : suruh
# jwban : jwban
# kasihan : kasihan
# ank : ank
# gue : gue
# pelayananya : pelayananya
# pnya : pnya
# sprt : sprt
# mbak : mbak
# misi : misi
# cuman : cuman
# losss : losss
# ngelag : ngelag
# keknya : kek
# kesalahan : salah
# pengguna : guna
# proses : proses
# seharian : hari
# diperluas : luas
# lgi : lgi
# komp : komp
# pwi : pwi
# jaya : jaya
# perum : perum
# cilebut : cilebut
# garden : garden
# telkom : telkom
# pas : pas
# mlm : mlm
# paginya : pagi
# teri : teri
# bosan : bosan
# baterei : baterei
# onmohon : onmohon
# dear : dear
# team : team
# ngecek : ngecek
# didepan : depan
# selesai : selesai
# kejelasannya : jelas
# hri : hri
# jga : jga
# follow : follow
# hasil : hasil
# masal : masal
# nagih : nagih
# penalti : penalti
# jt : jt
# silahkan : silah
# kerumah : rumah
# bedanya : beda
# berharap : harap
# kenceng : kenceng
# hemmmm : hemmmm
# sdah : sdah
# seminggu : minggu
# ngajukan : ngajukan
# tungguin : tungguin
# iuran : iur
# nyalan : nyalan
# warna : warna
# assalamu : assalamu
# allaikum : allaikum
# hijaunya : hijau
# hrs : hrs
# buana : buana
# kencana : kencana
# kpn : kpn
# vidio : vidio
# olimpiade : olimpiade
# nonton : nonton
# dtemukan : dtemukan
# ditelpon : telpon
# pusat : pusat
# sayang : sayang
# uda : uda
# pindahan : pindah
# kekantor : kantor
# profesional : profesional
# tahunan : tahun
# donk : donk
# mao : mao
# belajar : ajar
# inernet : inernet
# dinilmati : dinilmati
# wifintertulis : wifintertulis
# direset : direset
# hasilnya : hasil
# internaet : internaet
# dibrowser : browser
# ditindak : tindak
# lanjuti : lanjut
# slow : slow
# respond : respond
# telp : telp
# unlimited : unlimited
# mnc : mnc
# demangan : demang
# conec : conec
# tim : tim
# ahli : ahli
# kesana : kesana
# pasw : pasw
# berubah : ubah
# user : user
# klu : klu
# ekonomi : ekonomi
# jeblok : jeblok
# bro : bro
# lupa : lupa
# kpake : kpake
# berhentiin : berhentiin
# segini : gin
# sabtu : sabtu
# libur : libur
# kek : kek
# ngemis : ngemis
# anjg : anjg
# wkwkwk : wkwkwk
# gila : gila
# halaman : halaman
# gonta : gonta
# telkomcare : telkomcare
# diserang : serang
# tanggepin : tanggepin
# serang : serang
# orangmah : orangmah
# benahin : benahin
# pengetikan : keti
# ngomongnya : ngomongnya
# dibales : dibales
# haduhh : haduhh
# ambil : ambil
# denda : denda
# pergantian : ganti
# usee : usee
# android : android
# chanelx : chanelx
# tekhnisi : tekhnisi
# dtg : dtg
# peningkatan : tingkat
# ter : ter
# pelayanannya : layan
# tanggapan : tanggap
# reguler : reguler
# opsi : opsi
# movies : movies
# dapet : dapet
# pandemi : pandemi
# masaa : masaa
# curhat : curhat
# eric : eric
# tohir : tohir
# langkah : langkah
# ketiga : tiga
# streaming : streaming
# film : film
# twitter : twitter
# buffering : buffering
# mantap : mantap
# jawara : jawara
# renew : renew
# iki : iki
# piye : piye
# benerin : benerin
# lok : lok
# lhoksukom : lhoksukom
# aceh : aceh
# utara : utara
# tlpn : tlpn
# peri : peri
# digubris : gubris
# dimati : mati
# hadehhh : hadehhh
# malas : malas
# emosi : emosi
# janji : janji
# darimananya : darimananya
# kordinasi : kordinasi
# apanya : apa
# liat : liat
# track : track
# order : order
# tracking : tracking
# stuck : stuck
# persulit : sulit
# gara : gara
# jng : jng
# php : php
# jujur : jujur
# alesanya : alesanya
# data : data
# krja : krja
# messenger : messenger
# blsnya : blsnya
# pemeliharaan : pelihara
# bgtu : bgtu
# arahkan : arah
# trnyta : trnyta
# sepele : sepele
# rugi : rugi
# gangguannya : ganggu
# starbucks : starbucks
# jual : jual
# cendol : cendol
# parah : parah
# adukan : adu
# jgan : jgan
# sprti : sprti
# waifi : waifi
# trimakasi : trimakasi
# batalin : batalin
# kayak : kayak
# hr : hr
# dipasang : pasang
# mengganti : ganti
# terbaru : baru
# google : google
# voice : voice
# tangani : tangan
# estimasi : estimasi
# masi : mas
# lumayan : lumayan
# dpn : dpn
# samping : samping
# mobile : mobile
# legend : legend
# pdhal : pdhal
# speednya : speednya
# otp : otp
# gagal : gagal
# sulit : sulit
# rencana : rencana
# perpindahan : pindah
# biayanya : biaya
# cancel : cancel
# bbrp : bbrp
# suka : suka
# rto : rto
# mengganggu : ganggu
# krna : krna
# dipake : dipake
# trmksh : trmksh
# salesnya : salesnya
# slotnya : slotnya
# nyndir : nyndir
# mobel : mobel
# lejen : lejen
# putusss : putusss
# promonya : promonya
# sok : sok
# ngajarin : ngajarin
# org : org
# ngomong : ngomong
# koordinasinkan : koordinasinkan
# prioritaskan : prioritas
# dsb : dsb
# zonk : zonk
# cpt : cpt
# bales : bales
# hero : hero
# mmr : mmr
# afk : afk
# skor : skor
# kredit : kredit
# turun : turun
# rank : rank
# speerti : speerti
# swperti : swperti
# berpengaruh : pengaruh
# bangunan : bangun
# tembok : tembok
# bagus : bagus
# lantai : lantai
# point : point
# perhatikan : perhati
# bantuanya : bantuanya
# eroor : eroor
# menarik : tarik
# euy : euy
# ijo : ijo
# makan : makan
# anti : anti
# buffer : buffer
# tidur : tidur
# make : make
# bgni : bgni
# btw : btw
# monyet : monyet
# benernya : benernya
# lolos : lolos
# wahhh : wahhh
# dicoba : coba
# ngaruh : ngaruh
# satunya : satu
# gunain : gunain
# bandwidth : bandwidth
# ont : ont
# pembagian : bagi
# mosok : mosok
# bia : bia
# high : high
# same : same
# price : price
# kayaknya : kayak
# janjian : janji
# wfh : wfh
# hub : hub
# berkas : berkas
# link : link
# diturunkan : turun
# operator : operator
# toel : toel
# kebijakan : bijak
# leletnya : lelet
# ampun : ampun
# dech : dech
# kuliah : kuliah
# parangkusumo : parangkusumo
# bantul : bantul
# yogyakarta : yogyakarta
# terobel : terobel
# nongol : nongol
# emng : emng
# tlong : tlong
# dijelaskn : dijelaskn
# ttng : ttng
# semarak : semarak
# merdeka : merdeka
# udahh : udahh
# gmnaa : gmnaa
# pitus : pitus
# punyaku : punya
# mahal : mahal
# bayarnya : bayar
# tettap : tettap
# indohome : indohome
# ssh : ssh
# sekrang : sekrang
# mengurangi : kurang
# mangkin : mangkin
# nyaman : nyaman
# zoom : zoom
# lag : lag
# tulisane : tulisane
# bandwith : bandwith
# low : low
# mananya : mana
# dicek : cek
# sekarng : sekarng
# akses : akses
# nampilin : nampilin
# taun : taun
# pke : pke
# zte : zte
# offline : offline
# diwilayah : wilayah
# bermanfaat : manfaat
# capek : capek
# realisasinya : realisasi
# serperti : serperti
# senang : senang
# blok : blok
# lokal : lokal
# tonton : tonton
# banyar : banyar
# maha : maha
# siapp : siapp
# bobol : bobol
# pasword : pasword
# keamanan : aman
# ideal : ideal
# responya : responya
# cepat : cepat
# tarif : tarif
# disesuaikanlah : sesuai
# meeting : meeting
# kuliatas : kuliatas
# pendaftar : daftar
# paketnya : paket
# biarkan : biar
# menunggu : tunggu
# berhari : hari
# folow : folow
# gunanya : guna
# halah : halah
# kepastiannya : pasti
# smpek : smpek
# mengadu : adu
# penanganan : tangan
# kacau : kacau
# males : males
# telat : telat
# acuhin : acuhin
# tinggal : tinggal
# telfon : telfon
# dihubungi : hubung
# terimakasih : terimakasih
# secepat : cepat
# dibenahi : benah
# utama : utama
# bahagia : bahagia
# merk : merk
# kwalitas : kwalitas
# dibaband : dibaband
# tanggl : tanggl
# bner : bner
# orangnya : orang
# lampunya : lampu
# hujan : hujan
# saye : saye
# ape : ape
# terooosss : terooosss
# menguntungkan : untung
# kenyaman : kenyam
# fasilitas : fasilitas
# mumet : mumet
# karna : karna
# thanks : thanks
# tipsnya : tipsnya
# putusin : putusin
# muluuuu : muluuuu
# done : done
# seamles : seamles
# maklum : maklum
# produk : produk
# takseabanding : takseabanding
# kenyataan : nyata
# ujung : ujung
# ujungnya : ujung
# didiemin : didiemin
# metode : metode
# ngumpulin : ngumpulin
# nol : nol
# ent : ent
# abdi : abdi
# negara : negara
# daftarindihome : daftarindihome
# terealisasi : realisasi
# alesan : alesan
# documen : documen
# permainkan : main
# merugikan : rugi
# boss : boss
# setaun : taun
# namanya : nama
# aneh : aneh
# iya : iya
# mantep : mantep
# kacokk : kacokk
# blokir : blokir
# internetan : internetan
# ganguan : ganguan
# praktis : praktis
# myih : myih
# iklan : iklan
# kencang : kencang
# menggunakannya : guna
# dapetnya : dapetnya
# nyampe : nyampe
# upload : upload
# {'min': 'min', 'kompensasi': 'kompensasi', 'pelanggan': 'langgan', 'jaringan': 'jaring', 'internet': 'internet', 'bermasalah': 'masalah', '': '', 'indicare': 'indicare', 'tampilan': 'tampil', 'indi': 'indi', 'knp': 'knp', 'off': 'off', 'pakai': 'pakai', 'remote': 'remote', 'sttb': 'sttb', 'box': 'box', 'tetep': 'tetep', 'spt': 'spt', 'paket': 'paket', 'mbps': 'mbps', 'fakta': 'fakta', 'gimana': 'gimana', 'kemarin': 'kemarin', 'komplin': 'komplin', 'layanan': 'layan', 'chat': 'chat', 'indihome': 'indihome', 'dibalas': 'balas', 'nama': 'nama', 'raska': 'raska', 'ara': 'ara', 'indri': 'indri', 'lumi': 'lum', 'akun': 'akun', 'abal': 'abal', 'april': 'april', 'mengajukan': 'aju', 'perubahan': 'ubah', 'tagihan': 'tagih', 'pembayaran': 'bayar', 'ribu': 'ribu', 'disetujui': 'tuju', 'bayar': 'bayar', 'wifinya': 'wifinya', 'knpa': 'knpa', 'losnya': 'los', 'berwarna': 'warna', 'merah': 'merah', 'malam': 'malam', 'solusi': 'solusi', 'responnya': 'responnya', 'bru': 'bru', 'paaang': 'paaang', 'dri': 'dri', 'pasang': 'pasang', 'blm': 'blm', 'minggu': 'minggu', 'tpi': 'tpi', 'ngadat': 'ngadat', 'lemot': 'lot', 'intrrnetnya': 'intrrnetnya', 'ganti': 'ganti', 'mesin': 'mesin', 'modemnya': 'modem', 'teknisi': 'teknisi', 'ttp': 'ttp', 'nfadat': 'nfadat', 'los': 'los', 'udah': 'udah', 'tlp': 'tlp', 'tersambung': 'sambung', 'customer': 'customer', 'servis': 'servis', 'pls': 'pls', 'habis': 'habis', 'nunggu': 'nunggu', 'kesambung': 'sambung', 'via': 'via', 'apk': 'apk', 'nomer': 'nomer', 'hai': 'hai', 'sodara': 'sodara', 'senin': 'senin', 'kamis': 'kamis', 'terselesaikan': 'selesai', 'wifi': 'wifi', 'kendala': 'kendala', 'gini': 'gin', 'kasih': 'kasih', 'sesuai': 'sesuai', 'harga': 'harga', 'gmn': 'gmn', 'bos': 'bos', 'sinyal': 'sinyal', 'rmh': 'rmh', 'jelek': 'jelek', 'trobel': 'trobel', 'inbox': 'inbox', 'tanggapi': 'tanggap', 'daftar': 'daftar', 'ferifikasi': 'ferifikasi', 'wkwkkw': 'wkwkkw', 'dirumah': 'rumah', 'lambat': 'lambat', 'mohon': 'mohon', 'diperbaiki': 'baik', 'izin': 'izin', 'lampu': 'lampu', 'router': 'router', 'koneksi': 'koneksi', 'solusinya': 'solusi', 'alhamdulillah': 'alhamdulillah', 'menukar': 'tukar', 'poin': 'poin', 'seharus': 'harus', 'dimasa': 'masa', 'ppkm': 'ppkm', 'darurat': 'darurat', 'kelonggaran': 'longgar', 'discount': 'discount', 'mulu': 'mulu', 'membengkak': 'bengkak', 'padhal': 'padhal', 'aplikasi': 'aplikasi', 'tambahan': 'tambah', 'seamless': 'seamless', 'maksimal': 'maksimal', 'device': 'device', 'maaf': 'maaf', 'tolong': 'tolong', 'bantu': 'bantu', 'tersenyum': 'senyum', 'tertawaaaaa': 'tertawaaaaa', 'malem': 'malem', 'penuh': 'penuh', 'call': 'call', 'center': 'center', 'brp': 'brp', 'gangguan': 'ganggu', 'jam': 'jam', 'dibantu': 'bantu', 'admin': 'admin', 'ajh': 'ajh', 'pikirin': 'pikirin', 'mati': 'mati', 'semalem': 'semalem', 'kunjung': 'kunjung', 'bener': 'bener', 'account': 'account', 'password': 'password', 'stb': 'stb', 'dimana': 'mana', 'mudah': 'mudah', 'banget': 'banget', 'makasih': 'makasih', 'infonya': 'info', 'mimin': 'mimin', 'kak': 'kak', 'loss': 'loss', 'unsubscribe': 'unsubscribe', 'cloud': 'cloud', 'storage': 'storage', 'coba': 'coba', 'app': 'app', 'pilihan': 'pilih', 'pakek': 'pakek', 'dana': 'dana', 'kaga': 'kaga', 'nomor': 'nomor', 'salah': 'salah', 'sebulan': 'bulan', 'ngga': 'ngga', 'sampe': 'sampe', 'cape': 'cape', 'laporan': 'lapor', 'cek': 'cek', 'inboxx': 'inboxx', 'minn': 'minn', 'restart': 'restart', 'permisi': 'permisi', 'myindihome': 'myindihome', 'dilogin': 'dilogin', 'kpan': 'kpan', 'jaringgan': 'jaringgan', 'pengen': 'ken', 'masuk': 'masuk', 'bsa': 'bsa', 'hapus': 'hapus', 'cache': 'cache', 'udh': 'udh', 'update': 'update', 'kali': 'kali', 'tgl': 'tgl', 'laporkan': 'lapor', 'dpt': 'dpt', 'juni': 'juni', 'direspon': 'direspon', 'normal': 'normal', 'bln': 'bln', 'dikurang': 'kurang', 'sya': 'sya', 'ngk': 'ngk', 'tanggal': 'tanggal', 'smpe': 'smpe', 'skarang': 'skarang', 'lapor': 'lapor', 'kantor': 'kantor', 'blum': 'blum', 'kolom': 'kolom', 'pemakaian': 'pakai', 'kuota': 'kuo ...
# ------------------------
# Pandas Apply:   0%|          | 0/427 [00:00<?, ?it/s]
#                                                comment  \
# 0    min, ada kompensasi gak untuk pelanggan jika j...
# 1    indicare tampilan depan tv-indi knp 2 hari ini...
# 2    paket 20 mbps, fakta. 1 mbps g ada min gimana ...
# 3    kenapa layanan chat dg indihome dibalas dg ban...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                             aku mau pasang wifi ya
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add on seamless cara ...
# 438  bayarnya paket 20mbps, dapetnya gak  nyampe 10...
#
#                                       cleaning_comment  \
# 0    min ada kompensasi gak untuk pelanggan jika ja...
# 1    indicare tampilan depan indi knp hari ini begi...
# 2    paket mbps fakta mbps ada min gimana min kemar...
# 3    kenapa layanan chat indihome dibalas banyak na...
# 4    bulan april saya sudah mengajukan perubahan ta...
# ..                                                 ...
# 434                               aku mau pasang wifi
# 435               praktis banget dah ada aplikasi myih
# 436  iklan kencang banget tapi kualitas internet do...
# 437  kalau sudah berlangganan add seamless cara men...
# 438  bayarnya paket  mbps dapetnya gak nyampe  mbps...
#
#                                             tokenisasi  \
# 0    [min, ada, kompensasi, gak, untuk, pelanggan, ...
# 1    [indicare, tampilan, depan, indi, knp, hari, i...
# 2    [paket, mbps, fakta, mbps, ada, min, gimana, m...
# 3    [kenapa, layanan, chat, indihome, dibalas, ban...
# 4    [bulan, april, saya, sudah, mengajukan, peruba...
# ..                                                 ...
# 434                         [aku, mau, pasang, wifi, ]
# 435        [praktis, banget, dah, ada, aplikasi, myih]
# 436  [iklan, kencang, banget, tapi, kualitas, inter...
# 437  [kalau, sudah, berlangganan, add, seamless, ca...
# 438  [bayarnya, paket, mbps, dapetnya, gak, nyampe,...
#
#                                               stopword  \
# 0    [min, kompensasi, pelanggan, jaringan, interne...
# 1    [indicare, tampilan, indi, knp, off, pakai, re...
# 2    [paket, mbps, fakta, mbps, min, gimana, min, k...
# 3    [layanan, chat, indihome, dibalas, nama, raska...
# 4    [april, mengajukan, perubahan, tagihan, pembay...
# ..                                                 ...
# 434                                   [pasang, wifi, ]
# 435                  [praktis, banget, aplikasi, myih]
# 436  [iklan, kencang, banget, kualitas, internet, d...
# 437    [berlangganan, add, seamless, menggunakannya, ]
# 438  [bayarnya, paket, mbps, dapetnya, nyampe, mbps...
#
#                                               stemming
# 0    [min, kompensasi, langgan, jaring, internet, m...
# 1    [indicare, tampil, indi, knp, off, pakai, remo...
# 2    [paket, mbps, fakta, mbps, min, gimana, min, k...
# 3    [layan, chat, indihome, balas, nama, raska, ar...
# 4    [april, aju, ubah, tagih, bayar, ribu, tuju, b...
# ..                                                 ...
# 434                                   [pasang, wifi, ]
# 435                  [praktis, banget, aplikasi, myih]
# 436  [iklan, kencang, banget, kualitas, internet, d...
# 437                   [langgan, add, seamless, guna, ]
# 438  [bayar, paket, mbps, dapetnya, nyampe, mbps, u...
#
# [427 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [min, kompensasi, langgan, jaring, internet, m...
# 1    [indicare, tampil, indi, knp, off, pakai, remo...
# 2    [paket, mbps, fakta, mbps, min, gimana, min, k...
# 3    [layan, chat, indihome, balas, nama, raska, ar...
# 4    [april, aju, ubah, tagih, bayar, ribu, tuju, b...
# ..                                                 ...
# 434                                   [pasang, wifi, ]
# 435                  [praktis, banget, aplikasi, myih]
# 436  [iklan, kencang, banget, kualitas, internet, d...
# 437                   [langgan, add, seamless, guna, ]
# 438  [bayar, paket, mbps, dapetnya, nyampe, mbps, u...
#
# [427 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_7.xlsx')
