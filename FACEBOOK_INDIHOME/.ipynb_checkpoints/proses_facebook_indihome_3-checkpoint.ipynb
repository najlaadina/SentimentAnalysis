# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_3.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Saya laporan seminggu g kelar2 katanya d siste...
# 1    Di bantu min... Saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 3                                         nice infonya
# 4                                             tipsnyaa
# ..                                                 ...
# 492  mendingan CS - CS yg ada di indihome care di p...
# 493                          info yang sangat membantu
# 494                          info yang sangat membantu
# 495                          info yang sangat membantu
# 496                                  keren nih infonya
#
# [497 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 151

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Saya laporan seminggu g kelar2 katanya d siste...
# 1    Di bantu min... Saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                Makasih tips nya min.
# ..                                                 ...
# 487               Ini kenapa lagi ya wifi nya ? Astaga
# 490   Hallo ka saya ingin dowgrade paket mohon bles dm
# 491                                      Cek pesan min
# 492  mendingan CS - CS yg ada di indihome care di p...
# 496                                  keren nih infonya
#
# [274 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    saya laporan seminggu g kelar2 katanya d siste...
# 1    di bantu min... saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min.
# ..                                                 ...
# 487               ini kenapa lagi ya wifi nya ? astaga
# 490   hallo ka saya ingin dowgrade paket mohon bles dm
# 491                                      cek pesan min
# 492  mendingan cs - cs yg ada di indihome care di p...
# 496                                  keren nih infonya
#
# [274 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    saya laporan seminggu g kelar2 katanya d siste...
# 1    di bantu min... saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min.
# ..                                                 ...
# 487               ini kenapa lagi ya wifi nya ? astaga
# 490   hallo ka saya ingin dowgrade paket mohon bles dm
# 491                                      cek pesan min
# 492  mendingan cs - cs yg ada di indihome care di p...
# 496                                  keren nih infonya
#
#                                       cleaning_comment
# 0    saya laporan seminggu kelar  katanya sistem be...
# 1     bantu min saya sudah daftar indihome lebih da...
# 2                       yoiii panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min
# ..                                                 ...
# 487                    ini kenapa lagi wifi nya astaga
# 490        hallo saya ingin dowgrade paket mohon bles
# 491                                      cek pesan min
# 492  mendingan ada indihome care pikirkan lagi kebe...
# 496                                  keren nih infonya
#
# [274 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    saya laporan seminggu g kelar2 katanya d siste...
# 1    di bantu min... saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min.
# ..                                                 ...
# 487               ini kenapa lagi ya wifi nya ? astaga
# 490   hallo ka saya ingin dowgrade paket mohon bles dm
# 491                                      cek pesan min
# 492  mendingan cs - cs yg ada di indihome care di p...
# 496                                  keren nih infonya
#
#                                       cleaning_comment  \
# 0    saya laporan seminggu kelar  katanya sistem be...
# 1     bantu min saya sudah daftar indihome lebih da...
# 2                       yoiii panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min
# ..                                                 ...
# 487                    ini kenapa lagi wifi nya astaga
# 490        hallo saya ingin dowgrade paket mohon bles
# 491                                      cek pesan min
# 492  mendingan ada indihome care pikirkan lagi kebe...
# 496                                  keren nih infonya
#
#                                             tokenisasi
# 0    [saya, laporan, seminggu, kelar, katanya, sist...
# 1    [, bantu, min, saya, sudah, daftar, indihome, ...
# 2                  [yoiii, panduannya, sangat, ampuhh]
# 4                                           [tipsnyaa]
# 5                          [makasih, tips, nya, min, ]
# ..                                                 ...
# 487             [ini, kenapa, lagi, wifi, nya, astaga]
# 490  [hallo, saya, ingin, dowgrade, paket, mohon, b...
# 491                                  [cek, pesan, min]
# 492  [mendingan, ada, indihome, care, pikirkan, lag...
# 496                              [keren, nih, infonya]
#
# [274 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    saya laporan seminggu g kelar2 katanya d siste...
# 1    di bantu min... saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min.
# ..                                                 ...
# 487               ini kenapa lagi ya wifi nya ? astaga
# 490   hallo ka saya ingin dowgrade paket mohon bles dm
# 491                                      cek pesan min
# 492  mendingan cs - cs yg ada di indihome care di p...
# 496                                  keren nih infonya
#
#                                       cleaning_comment  \
# 0    saya laporan seminggu kelar  katanya sistem be...
# 1     bantu min saya sudah daftar indihome lebih da...
# 2                       yoiii panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min
# ..                                                 ...
# 487                    ini kenapa lagi wifi nya astaga
# 490        hallo saya ingin dowgrade paket mohon bles
# 491                                      cek pesan min
# 492  mendingan ada indihome care pikirkan lagi kebe...
# 496                                  keren nih infonya
#
#                                             tokenisasi  \
# 0    [saya, laporan, seminggu, kelar, katanya, sist...
# 1    [, bantu, min, saya, sudah, daftar, indihome, ...
# 2                  [yoiii, panduannya, sangat, ampuhh]
# 4                                           [tipsnyaa]
# 5                          [makasih, tips, nya, min, ]
# ..                                                 ...
# 487             [ini, kenapa, lagi, wifi, nya, astaga]
# 490  [hallo, saya, ingin, dowgrade, paket, mohon, b...
# 491                                  [cek, pesan, min]
# 492  [mendingan, ada, indihome, care, pikirkan, lag...
# 496                              [keren, nih, infonya]
#
#                                               stopword
# 0    [laporan, seminggu, kelar, sistem, complete, s...
# 1    [, bantu, min, daftar, indihome, seminggu, kab...
# 2                          [yoiii, panduannya, ampuhh]
# 4                                           [tipsnyaa]
# 5                               [makasih, tips, min, ]
# ..                                                 ...
# 487                                     [wifi, astaga]
# 490            [hallo, dowgrade, paket, mohon, bles, ]
# 491                                  [cek, pesan, min]
# 492  [mendingan, indihome, care, pikirkan, keberada...
# 496                                   [keren, infonya]
#
# [274 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 776
# ------------------------
# laporan : lapor
# seminggu : minggu
# kelar : kelar
# sistem : sistem
# complete : complete
# sempet : sempet
# connect : connect
# internet : internet
#  :
# bantu : bantu
# min : min
# daftar : daftar
# indihome : indihome
# kabel : kabel
# sinyal : sinyal
# lokasi : lokasi
# teknisi : teknisi
# tarik : tarik
# ulur : ulur
# alasanya : alasanya
# jalur : jalur
# maksudnya : maksud
# butuh : butuh
# mengajar : ajar
# yoiii : yoiii
# panduannya : pandu
# ampuhh : ampuhh
# tipsnyaa : tipsnyaa
# makasih : makasih
# tips : tips
# tipssnyaaaaaaa : tipssnyaaaaaaa
# tipsnya : tipsnya
# infonya : info
# gangguan : ganggu
# mulu : mulu
# menemani : tani
# panik : panik
# solusi : solusi
# kontol : kontol
# lemot : lot
# banget : banget
# anjing : anjing
# bermanfaat : manfaat
# informatif : informatif
# pastinya : pasti
# berguna : guna
# langkah : langkah
# mantaaappp : mantaaappp
# miminnn : miminnn
# jaya : jaya
# teruss : teruss
# cek : cek
# selamat : selamat
# siang : siang
# sayang : sayang
# nanya : nanya
# rencana : rencana
# pemasangan : pasang
# nunggu : nunggu
# meninggal : tinggal
# udah : udah
# minggu : minggu
# tanda : tanda
# pengecekan : kece
# wifi : wifi
# gmn : gmn
# hallo : hallo
# tagihan : tagih
# lapor : lapor
# ditindak : tindak
# lanjuti : lanjut
# terima : terima
# kasih : kasih
# informasi : informasi
# good : good
# info : info
# mimin : mimin
# mah : mah
# share : share
# berfaedah : faedah
# wae : wae
# mantappp : mantappp
# minnn : minnn
# halo : halo
# alat : alat
# cabut : cabut
# menunggu : tunggu
# sebulan : bulan
# reschedule : reschedule
# smp : smp
# telan : telan
# uang : uang
# refound : refound
# yauda : yauda
# bawa : bawa
# mengecewakan : kecewa
# bumn : bumn
# jawa : jawa
# sentris : sentris
# bang : bang
# skkl : skkl
# aktif : aktif
# topologi : topologi
# radio : radio
# terputus : putus
# kamis : kamis
# tgl : tgl
# maret : maret
# jam : jam
# pakai : pakai
# woyyy : woyyy
# kali : kali
# kau : kau
# otaknya : otak
# gini : gin
# jaringannya : jaring
# keren : keren
# malam : malam
# dibantu : bantu
# los : los
# merah : merah
# kedip : kedip
# pelanggan : langgan
# mbps : mbps
# test : test
# speed : speed
# dapet : dapet
# marasa : marasa
# tipu : tipu
# nihhh : nihhh
# bayar : bayar
# dikasih : kasih
# usee : usee
# siaran : siar
# dilaporkan : lapor
# statusnya : status
# selesai : selesai
# modemnya : modem
# reset : reset
# parah : parah
# nyambung : nyambung
# terpaksa : paksa
# gimana : gimana
# bingung : bingung
# mantapppp : mantapppp
# minnnn : minnnn
# gangguannterus : gangguannterus
# promo : promo
# giliran : gilir
# beli : beli
# dipasang : pasang
# minn : minn
# mengaktifkan : aktif
# modem : modem
# apakh : apakh
# kesedot : sedot
# data : data
# bandwidth : bandwidth
# diambil : ambil
# pusat : pusat
# tinggal : tinggal
# pasang : pasang
# dimana : mana
# kak : kak
# mohon : mohon
# dibaca : baca
# inboxnya : inboxnya
# keluhan : keluh
# konek : konek
# admin : admin
# mantaps : mantaps
# informasinya : informasi
# kaya : kaya
# yoe : yoe
# era : era
# serba : serba
# canggih : canggih
# satset : satset
# fitur : fitur
# seru : seru
# tuu : tuu
# iya : iya
# rumah : rumah
# masak : masak
# cepat : cepat
# paket : paket
# mengalami : alami
# error : error
# tolong : tolong
# proses : proses
# secepatnya : cepat
# kemarin : kemarin
# berubah : ubah
# layanan : layan
# perbulannya : bulan
# kena : kena
# quota : quota
# fup : fup
# coba : coba
# upgrade : upgrade
# langsung : langsung
# eksekusi : eksekusi
# hadeh : hadeh
# comentnya : comentnya
# protes : protes
# jelek : jelek
# kasian : kasi
# costumersnya : costumersnya
# nice : nice
# infooo : infooo
# jal : jal
# dalamnya : dalam
# bentar : bentar
# hilang : hilang
# donk : donk
# cmn : cmn
# segitu : segitu
# kenceng : kenceng
# umpetin : umpetin
# kmn : kmn
# sisanya : sisa
# knp : knp
# jaringan : jaring
# timbul : timbul
# tenggelam : tenggelam
# kyk : kyk
# orang : orang
# kelelep : lelep
# tutup : tutup
# tiket : tiket
# kasihan : kasihan
# lihat : lihat
# salah : salah
# pimpinan : pimpin
# lamban : lamban
# masang : masang
# selagi : selagi
# paham : paham
# trknisi : trknisi
# dipaksa : paksa
# bagusin : bagusin
# topo : topo
# nyekik : nyekik
# org : org
# pinggiran : pinggir
# anak : anak
# ujin : ujin
# mati : mati
# case : case
# closed : closed
# dirumah : rumah
# putus : putus
# ketiga : tiga
# kalinya : kali
# diperbaiki : baik
# janjinya : janji
# sore : sore
# dtg : dtg
# blm : blm
# nomor : nomor
# hub : hub
# rosa : rosa
# respon : respon
# kmrn : kmrn
# kakak : kakak
# setting : setting
# apk : apk
# shopee : shopee
# fupnya : fupnya
# download : download
# bales : bales
# inbok : inbok
# nur : nur
# fitriyani : fitriyani
# arifuddin : arifuddin
# terimakasih : terimakasih
# berinteraksi : interaksi
# official : official
# akun : akun
# byr : byr
# lncar : lncar
# permh : permh
# telat : telat
# jringn : jringn
# trus : trus
# kpn : kpn
# perbaikn : perbaikn
# asl : asl
# tlp : tlp
# jwbn : jwbn
# slalu : slalu
# dlm : dlm
# diundur : undur
# smpai : smpai
# hrp : hrp
# hrs : hrs
# kompensasi : kompensasi
# rugi : rugi
# rb : rb
# bli : bli
# kuota : kuota
# agr : agr
# seamless : seamless
# maksimal : maksimal
# device : device
# udh : udh
# tersambung : sambung
# wifinya : wifinya
# suruh : suruh
# inbox : inbox
# tetangga : tetangga
# diputus : putus
# apkah : apkah
# disalurkan : salur
# sumpah : sumpah
# kagak : kagak
# sebentar : sebentar
# eror : eror
# ganti : ganti
# terisolir : isolir
# indi : indi
# home : home
# sdah : sdah
# ptus : ptus
# tdak : tdak
# aktifkan : aktif
# jaminan : jamin
# malamnya : malam
# terisoler : terisoler
# tanggal : tanggal
# malem : malem
# isolir : isolir
# loss : loss
# kirim : kirim
# pengaduan : adu
# aplikasi : aplikasi
# belom : bom
# bulanan : bulan
# sekrang : sekrang
# okeh : okeh
# mantep : mantep
# ingetin : ingetin
# wooiiii : wooiiii
# benerin : benerin
# erorr : erorr
# perbaikan : baik
# kamai : kama
# pemakai : pakai
# terganggu : ganggu
# sehari : hari
# hati : hati
# berlangganan : langgan
# tertipu : tipu
# buktinya : bukti
# alhamdulillah : alhamdulillah
# kamipun : kami
# diam : diam
# mengajukan : aju
# pemutusan : putus
# persyaratan : syarat
# lengkapi : lengkap
# moh : moh
# nglad : nglad
# napa : napa
# kaka : kaka
# telantar : telantar
# biarkan : biar
# tambahan : tambah
# pembyrn : pembyrn
# denda : denda
# tagihanya : tagihanya
# lancar : lancar
# indihomenya : indihomenya
# suka : suka
# mutus : mutus
# pemberitahuan : pemberitahuan
# pusing : pusing
# pembayaran : bayar
# semalam : malam
# tanggapannya : tanggap
# kondisinya : kondisi
# kya : kya
# bgni : bgni
# less : less
# indhihome : indhihome
# nge : nge
# lag : lag
# main : main
# game : game
# harii : hari
# koneksi : koneksi
# seyiap : seyiap
# komplen : komplen
# estimasi : estimasi
# dikenakan : kena
# tanggapan : tanggap
# serang : serang
# city : city
# terhitung : hitung
# alasan : alas
# tindak : tindak
# nimer : nimer
# in : in
# kejelasan : jelas
# penanganan : tangan
# timdakan : timdakan
# merugikan : rugi
# dibatam : dibatam
# pemeliharaan : pelihara
# lelet : lelet
# karna : karna
# isolasi : isolasi
# dongs : dongs
# thanks : thanks
# sinya : sinya
# mantappppp : mantappppp
# jayalahh : jayalahh
# telkom : telkom
# tidaknada : tidaknada
# internetnya : internetnya
# hoax : hoax
# menjatuhkan : jatuh
# babi : babi
# anjeng : anjeng
# geram : geram
# pelayanan : layan
# beres : beres
# kerja : kerja
# kecepatan : cepat
# baca : baca
# waaaaaahhhhj : waaaaaahhhhj
# beneran : beneran
# lho : lho
# terlanjur : lanjur
# leboh : leboh
# cari : cari
# provider : provider
# swasta : swasta
# cermat : cermat
# berita : berita
# nonton : nonton
# tpi : tpi
# cabel : cabel
# smart : smart
# terputs : terputs
# iyah : iyah
# bangga : bangga
# complain : complain
# lmao : lmao
# dicek : cek
# otak : otak
# ampas : ampas
# janji : janji
# teksniksi : teksniksi
# ditunggu : tunggu
# ngan : ngan
# alsan : alsan
# dilempar : lempar
# biki : bik
# instal : instal
# mola : mola
# gmna : gmna
# pengen : ken
# liga : liga
# inggris : inggris
# work : work
# mantul : mantul
# teruskan : terus
# bagus : bagus
# berhenti : henti
# langganan : langgan
# february : february
# gubris : gubris
# ahirnya : ahirnya
# plus : plus
# taaaaaapiiiiiiii : taaaaaapiiiiiiii
# gila : gila
# uda : uda
# subuh : subuh
# diakses : akses
# routernya : routernya
# terestart : terestart
# harga : harga
# buktikan : bukti
# percaya : percaya
# pengguna : guna
# gunungpati : gunungpati
# semarang : semarang
# patemon : patemon
# hubungi : hubung
# mas : mas
# restart : restart
# berkali : kali
# myindihome : myindihome
# dibenerin : dibenerin
# skrng : skrng
# connection : connection
# pon : pon
# kedap : kedap
# patch : patch
# core : core
# terpasang : pasang
# sempurna : sempurna
# msh : msh
# cuman : cuman
# disuruh : suruh
# clear : clear
# cache : cache
# login : login
# logout : logout
# terusss : terusss
# perubahan : ubah
# posisi : posisi
# poin : poin
# bln : bln
# feb : feb
# anteng : anteng
# diikat : ikat
# tali : tali
# tambang : tambang
# ngak : ngak
# panduan : pandu
# solusinya : solusi
# only : only
# berkurang : kurang
# terhubung : hubung
# malas : malas
# kayak : kayak
# keong : keong
# sopan : sopan
# komplain : komplain
# diblock : diblock
# mentang : mentang
# plasa : plasa
# melayani : layan
# service : service
# btw : btw
# tamblong : tamblong
# belu : belu
# indikator : indikator
# router : router
# pas : pas
# wilayah : wilayah
# jogja : jogja
# kah : kah
# duit : duit
# doang : doang
# refresh : refresh
# alias : alias
# restar : restar
# perbaikin : perbaikin
# ngerasain : ngerasain
# ngelag : ngelag
# maen : maen
# komputer : komputer
# laptop : laptop
# bener : bener
# teta : teta
# gajelas : gajelas
# bantuanya : bantuanya
# siran : sir
# muncul : muncul
# tagar : tagar
# trending : trending
# post : post
# puluhan : puluh
# bukti : bukti
# bobrok : bobrok
# tertarik : tarik
# bogor : bogor
# slot : slot
# gabisa : gabisa
# kendala : kendala
# melebihi : lebih
# disediakan : sedia
# tvnya : tvnya
# servernya : servernya
# karyawan : karyawan
# minim : minim
# etika : etika
# santun : santun
# law : law
# deh : deh
# kode : kode
# gagal : gagal
# lambat : lambat
# diatasi : atas
# kesulitan : sulit
# belajar : ajar
# online : online
# pecat : pecat
# oshin : oshin
# beauty : beauty
# skincare : skincare
# email : email
# semihoke : semihoke
# com : com
# registrasi : registrasi
# myd : myd
# draf : draf
# kontrak : kontrak
# tertanggal : tanggal
# desember : desember
# billing : billing
# wow : wow
# award : award
# benarkan : benar
# segeraa : segeraa
# adakah : ada
# tunggu : tunggu
# sales : sales
# besok : besok
# berlanganan : berlanganan
# telpon : telpon
# ditawarkan : tawar
# useetv : useetv
# pemakaian : pakai
# januari : januari
# cctv : cctv
# unit : unit
# camera : camera
# warna : warna
# ditulisan : tulis
# menonton : tonton
# gmnaa : gmnaa
# tuhh : tuhh
# jauhh : jauhh
# unsubscribe : unsubscribe
# add : add
# subscribe : subscribe
# gampang : gampang
# keamanan : aman
# terjaga : jaga
# was : was
# pagi : pagi
# brpa : brpa
# woy : woy
# internetku : internetku
# lampu : lampu
# balas : balas
# pesan : pesan
# semalem : semalem
# trs : trs
# emang : emang
# penanganannya : tangan
# nihh : nihh
# aman : aman
# ping : ping
# sampe : sampe
# guys : guys
# offline : offline
# pikirkan : pikir
# via : via
# sms : sms
# lekang : lekang
# pegawai : pegawai
# kelakuan : laku
# roby : roby
# ndi : ndi
# asline : asline
# raine : raine
# gateli : gateli
# prbaikan : prbaikan
# ggal : ggal
# sya : sya
# terpantau : pantau
# skrg : skrg
# full : full
# mentok : mentok
# upload : upload
# banjararum : banjararum
# kec : kec
# singosari : singosari
# kab : kab
# malang : malang
# disconnected : disconnected
# inipun : ini
# telp : telp
# koneksinya : koneksi
# distorsi : distorsi
# suara : suara
# anehnya : aneh
# forwardkan : forwardkan
# suaranya : suara
# jernih : jernih
# sehar : sehar
# comment : comment
# boonk : boonk
# iklan : iklan
# bereskan : beres
# maaf : maaf
# yamin : yamin
# nio : nio
# lakukan : laku
# alamat : alamat
# lintas : lintas
# bagan : bagan
# siapiapi : siapiapi
# ujung : ujung
# tanjung : tanjung
# kampung : kampung
# melati : melati
# kelurahan : lurah
# melayu : melayu
# kota : kota
# kecamatan : camat
# tanah : tanah
# putih : putih
# melawan : lawan
# riau : riau
# tercover : tercover
# fiber : fiber
# optic : optic
# slli : slli
# shit : shit
# inidihome : inidihome
# emosi : emosi
# ndihome : ndihome
# hai : hai
# masi : mas
# buta : buta
# butuhkan : butuh
# daring : daring
# sehat : sehat
# pindah : pindah
# dibls : dibls
# istri : istri
# kabari : kabar
# twitter : twitter
# liat : liat
# remote : remote
# bermasalahan : masalah
# balasan : balas
# ringan : ringan
# siput : siput
# leletnya : lelet
# sekelas : kelas
# jalan : jalan
# solok : solok
# sumbar : sumbar
# hidup : hidup
# dihubungi : hubung
# petugas : tugas
# after : after
# ombudsman : ombudsman
# please : please
# trik : trik
# ugha : ugha
# yaa : yaa
# mmulu : mmulu
# pantau : pantau
# terussss : terussss
# euy : euy
# durasi : durasi
# menit : menit
# sejam : jam
# responnya : responnya
# ayoolaah : ayoolaah
# siank : siank
# digital : digital
# proteksi : proteksi
# hello : hello
# pantesan : pantesan
# seharian : hari
# beku : beku
# gino : gino
# pemindahan : pindah
# tiang : tiang
# posisinya : posisi
# mengganggu : ganggu
# astaga : astaga
# dowgrade : dowgrade
# bles : bles
# mendingan : mending
# care : care
# keberadaannya : ada
# {'laporan': 'lapor', 'seminggu': 'minggu', 'kelar': 'kelar', 'sistem': 'sistem', 'complete': 'complete', 'sempet': 'sempet', 'connect': 'connect', 'internet': 'internet', '': '', 'bantu': 'bantu', 'min': 'min', 'daftar': 'daftar', 'indihome': 'indihome', 'kabel': 'kabel', 'sinyal': 'sinyal', 'lokasi': 'lokasi', 'teknisi': 'teknisi', 'tarik': 'tarik', 'ulur': 'ulur', 'alasanya': 'alasanya', 'jalur': 'jalur', 'maksudnya': 'maksud', 'butuh': 'butuh', 'mengajar': 'ajar', 'yoiii': 'yoiii', 'panduannya': 'pandu', 'ampuhh': 'ampuhh', 'tipsnyaa': 'tipsnyaa', 'makasih': 'makasih', 'tips': 'tips', 'tipssnyaaaaaaa': 'tipssnyaaaaaaa', 'tipsnya': 'tipsnya', 'infonya': 'info', 'gangguan': 'ganggu', 'mulu': 'mulu', 'menemani': 'tani', 'panik': 'panik', 'solusi': 'solusi', 'kontol': 'kontol', 'lemot': 'lot', 'banget': 'banget', 'anjing': 'anjing', 'bermanfaat': 'manfaat', 'informatif': 'informatif', 'pastinya': 'pasti', 'berguna': 'guna', 'langkah': 'langkah', 'mantaaappp': 'mantaaappp', 'miminnn': 'miminnn', 'jaya': 'jaya', 'teruss': 'teruss', 'cek': 'cek', 'selamat': 'selamat', 'siang': 'siang', 'sayang': 'sayang', 'nanya': 'nanya', 'rencana': 'rencana', 'pemasangan': 'pasang', 'nunggu': 'nunggu', 'meninggal': 'tinggal', 'udah': 'udah', 'minggu': 'minggu', 'tanda': 'tanda', 'pengecekan': 'kece', 'wifi': 'wifi', 'gmn': 'gmn', 'hallo': 'hallo', 'tagihan': 'tagih', 'lapor': 'lapor', 'ditindak': 'tindak', 'lanjuti': 'lanjut', 'terima': 'terima', 'kasih': 'kasih', 'informasi': 'informasi', 'good': 'good', 'info': 'info', 'mimin': 'mimin', 'mah': 'mah', 'share': 'share', 'berfaedah': 'faedah', 'wae': 'wae', 'mantappp': 'mantappp', 'minnn': 'minnn', 'halo': 'halo', 'alat': 'alat', 'cabut': 'cabut', 'menunggu': 'tunggu', 'sebulan': 'bulan', 'reschedule': 'reschedule', 'smp': 'smp', 'telan': 'telan', 'uang': 'uang', 'refound': 'refound', 'yauda': 'yauda', 'bawa': 'bawa', 'mengecewakan': 'kecewa', 'bumn': 'bumn', 'jawa': 'jawa', 'sentris': 'sentris', 'bang': 'bang', 'skkl': 'skkl', 'aktif': 'aktif', 'topologi': 'topologi', 'radio': 'radio', 'terputus': 'putus', 'kamis': 'kamis', 'tgl': 'tgl', 'maret': 'maret', 'jam': 'jam', 'pakai': 'pakai', 'woyyy': 'woyyy', 'kali': 'kali', 'kau': 'kau', 'otaknya': 'otak', 'gini': 'gin', 'jaringannya': 'jaring', 'keren': 'keren', 'malam': 'malam', 'dibantu': 'bantu', 'los': 'los', 'merah': 'merah', 'kedip': 'kedip', 'pelanggan': 'langgan', 'mbps': 'mbps', 'test': 'test', 'speed': 'speed', 'dapet': 'dapet', 'marasa': 'marasa', 'tipu': 'tipu', 'nihhh': 'nihhh', 'bayar': 'bayar', 'dikasih': 'kasih', 'usee': 'usee', 'siaran': 'siar', 'dilaporkan': 'lapor', 'statusnya': 'status', 'selesai': 'selesai', 'modemnya': 'modem', 'reset': 'reset', 'parah': 'parah', 'nyambung': 'nyambung', 'terpaksa': 'paksa', 'gimana': 'gimana', 'bingung': 'bingung', 'mantapppp': 'mantapppp', 'minnnn': 'minnnn', 'gangguannterus': 'gangguannterus', 'promo': 'promo', 'giliran': 'gilir', 'beli': 'beli', 'dipasang': 'pasang', 'minn': 'minn', 'mengaktifkan': 'aktif', 'modem': 'modem', 'apakh': 'apakh', 'kesedot': 'sedot', 'data': 'data', 'bandwidth': 'bandwidth', 'diambil': 'ambil', 'pusat': 'pusat', 'tinggal': 'tinggal', 'pasang': 'pasang', 'dimana': 'mana', 'kak': 'kak', 'mohon': 'mohon', 'dibaca': 'baca', 'inboxnya': 'inboxnya', 'keluhan': 'keluh', 'konek': 'konek', 'admin': 'admin', 'mantaps': 'mantaps', 'informasinya': 'informasi', 'kaya': 'kaya', 'yoe': 'yoe', 'era': 'era', 'serba': 'serba', 'canggih': 'canggih', 'satset': 'satset', 'fitur': 'fitur', 'seru': 'seru', 'tuu': 'tuu', 'iya': 'iya', 'rumah': 'rumah', 'masak': 'masak', 'cepat': 'cepat', 'paket': 'paket', 'mengalami': 'alami', 'error': 'error', 'tolong': 'tolong', 'proses': 'proses', 'secepatnya': 'cepat', 'kemarin': 'kemarin', 'berubah': 'ubah', 'layanan': 'layan', 'perbulannya': 'bulan', 'kena': 'kena', 'quota': 'quota', 'fup': 'fup', 'coba': 'coba', 'upgrade': 'upgrade', 'langsung': 'langsung', 'eksekusi': 'eksekusi', 'hadeh': 'hadeh', 'comentnya': 'comentnya', 'protes': 'protes', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/274 [00:00<?, ?it/s]
#                                                comment  \
# 0    saya laporan seminggu g kelar2 katanya d siste...
# 1    di bantu min... saya sudah daftar indihome leb...
# 2                      yoiii, panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min.
# ..                                                 ...
# 487               ini kenapa lagi ya wifi nya ? astaga
# 490   hallo ka saya ingin dowgrade paket mohon bles dm
# 491                                      cek pesan min
# 492  mendingan cs - cs yg ada di indihome care di p...
# 496                                  keren nih infonya
#
#                                       cleaning_comment  \
# 0    saya laporan seminggu kelar  katanya sistem be...
# 1     bantu min saya sudah daftar indihome lebih da...
# 2                       yoiii panduannya sangat ampuhh
# 4                                             tipsnyaa
# 5                                makasih tips nya min
# ..                                                 ...
# 487                    ini kenapa lagi wifi nya astaga
# 490        hallo saya ingin dowgrade paket mohon bles
# 491                                      cek pesan min
# 492  mendingan ada indihome care pikirkan lagi kebe...
# 496                                  keren nih infonya
#
#                                             tokenisasi  \
# 0    [saya, laporan, seminggu, kelar, katanya, sist...
# 1    [, bantu, min, saya, sudah, daftar, indihome, ...
# 2                  [yoiii, panduannya, sangat, ampuhh]
# 4                                           [tipsnyaa]
# 5                          [makasih, tips, nya, min, ]
# ..                                                 ...
# 487             [ini, kenapa, lagi, wifi, nya, astaga]
# 490  [hallo, saya, ingin, dowgrade, paket, mohon, b...
# 491                                  [cek, pesan, min]
# 492  [mendingan, ada, indihome, care, pikirkan, lag...
# 496                              [keren, nih, infonya]
#
#                                               stopword  \
# 0    [laporan, seminggu, kelar, sistem, complete, s...
# 1    [, bantu, min, daftar, indihome, seminggu, kab...
# 2                          [yoiii, panduannya, ampuhh]
# 4                                           [tipsnyaa]
# 5                               [makasih, tips, min, ]
# ..                                                 ...
# 487                                     [wifi, astaga]
# 490            [hallo, dowgrade, paket, mohon, bles, ]
# 491                                  [cek, pesan, min]
# 492  [mendingan, indihome, care, pikirkan, keberada...
# 496                                   [keren, infonya]
#
#                                               stemming
# 0    [lapor, minggu, kelar, sistem, complete, sempe...
# 1    [, bantu, min, daftar, indihome, minggu, kabel...
# 2                               [yoiii, pandu, ampuhh]
# 4                                           [tipsnyaa]
# 5                               [makasih, tips, min, ]
# ..                                                 ...
# 487                                     [wifi, astaga]
# 490            [hallo, dowgrade, paket, mohon, bles, ]
# 491                                  [cek, pesan, min]
# 492            [mending, indihome, care, pikir, ada, ]
# 496                                      [keren, info]
#
# [274 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [lapor, minggu, kelar, sistem, complete, sempe...
# 1    [, bantu, min, daftar, indihome, minggu, kabel...
# 2                               [yoiii, pandu, ampuhh]
# 4                                           [tipsnyaa]
# 5                               [makasih, tips, min, ]
# ..                                                 ...
# 487                                     [wifi, astaga]
# 490            [hallo, dowgrade, paket, mohon, bles, ]
# 491                                  [cek, pesan, min]
# 492            [mending, indihome, care, pikir, ada, ]
# 496                                      [keren, info]
#
# [274 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_3.xlsx')
