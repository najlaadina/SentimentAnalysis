# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_10.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Min tolong di respon nomor IN111995854 pelapor...
# 1                   Masih tanggal muda sudah LOS lagi.
# 2    Internetku mati 3 hari tanpa penanganan... Tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    Gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  Malam min, mau tanya untuk pembayaran tagihan ...
# 328  Min, 1 IndiHome TV bisa gak berlangganan 3 STB...
# 329  Wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            Makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
# [332 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 20

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Min tolong di respon nomor IN111995854 pelapor...
# 1                   Masih tanggal muda sudah LOS lagi.
# 2    Internetku mati 3 hari tanpa penanganan... Tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    Gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  Malam min, mau tanya untuk pembayaran tagihan ...
# 328  Min, 1 IndiHome TV bisa gak berlangganan 3 STB...
# 329  Wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            Makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
# [302 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    min tolong di respon nomor in111995854 pelapor...
# 1                   masih tanggal muda sudah los lagi.
# 2    internetku mati 3 hari tanpa penanganan... tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  malam min, mau tanya untuk pembayaran tagihan ...
# 328  min, 1 indihome tv bisa gak berlangganan 3 stb...
# 329  wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
# [302 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    min tolong di respon nomor in111995854 pelapor...
# 1                   masih tanggal muda sudah los lagi.
# 2    internetku mati 3 hari tanpa penanganan... tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  malam min, mau tanya untuk pembayaran tagihan ...
# 328  min, 1 indihome tv bisa gak berlangganan 3 stb...
# 329  wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                       cleaning_comment
# 0    min tolong respon nomor in  pelaporan gangguan...
# 1                   masih tanggal muda sudah los lagi
# 2    internetku mati hari tanpa penanganan telat di...
# 3    ini kenapaa jaringan rumah saya menit putus me...
# 4    gangguan indihome dari siang hadeuh kalau tagi...
# ..                                                 ...
# 327  malam min mau tanya untuk pembayaran tagihan i...
# 328  min indihome bisa gak berlangganan stb sekaligus
# 329  wifi gua lelet setiap kali komplen pihak indih...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
# [302 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    min tolong di respon nomor in111995854 pelapor...
# 1                   masih tanggal muda sudah los lagi.
# 2    internetku mati 3 hari tanpa penanganan... tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  malam min, mau tanya untuk pembayaran tagihan ...
# 328  min, 1 indihome tv bisa gak berlangganan 3 stb...
# 329  wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                       cleaning_comment  \
# 0    min tolong respon nomor in  pelaporan gangguan...
# 1                   masih tanggal muda sudah los lagi
# 2    internetku mati hari tanpa penanganan telat di...
# 3    ini kenapaa jaringan rumah saya menit putus me...
# 4    gangguan indihome dari siang hadeuh kalau tagi...
# ..                                                 ...
# 327  malam min mau tanya untuk pembayaran tagihan i...
# 328  min indihome bisa gak berlangganan stb sekaligus
# 329  wifi gua lelet setiap kali komplen pihak indih...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                             tokenisasi
# 0    [min, tolong, respon, nomor, in, pelaporan, ga...
# 1           [masih, tanggal, muda, sudah, los, lagi, ]
# 2    [internetku, mati, hari, tanpa, penanganan, te...
# 3    [ini, kenapaa, jaringan, rumah, saya, menit, p...
# 4    [gangguan, indihome, dari, siang, hadeuh, kala...
# ..                                                 ...
# 327  [malam, min, mau, tanya, untuk, pembayaran, ta...
# 328  [min, indihome, bisa, gak, berlangganan, stb, ...
# 329  [wifi, gua, lelet, setiap, kali, komplen, piha...
# 330                        [makasih, info, pentingnya]
# 331  [min, apa, iya, orang, indihome, bisa, liat, p...
#
# [302 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    min tolong di respon nomor in111995854 pelapor...
# 1                   masih tanggal muda sudah los lagi.
# 2    internetku mati 3 hari tanpa penanganan... tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  malam min, mau tanya untuk pembayaran tagihan ...
# 328  min, 1 indihome tv bisa gak berlangganan 3 stb...
# 329  wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                       cleaning_comment  \
# 0    min tolong respon nomor in  pelaporan gangguan...
# 1                   masih tanggal muda sudah los lagi
# 2    internetku mati hari tanpa penanganan telat di...
# 3    ini kenapaa jaringan rumah saya menit putus me...
# 4    gangguan indihome dari siang hadeuh kalau tagi...
# ..                                                 ...
# 327  malam min mau tanya untuk pembayaran tagihan i...
# 328  min indihome bisa gak berlangganan stb sekaligus
# 329  wifi gua lelet setiap kali komplen pihak indih...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                             tokenisasi  \
# 0    [min, tolong, respon, nomor, in, pelaporan, ga...
# 1           [masih, tanggal, muda, sudah, los, lagi, ]
# 2    [internetku, mati, hari, tanpa, penanganan, te...
# 3    [ini, kenapaa, jaringan, rumah, saya, menit, p...
# 4    [gangguan, indihome, dari, siang, hadeuh, kala...
# ..                                                 ...
# 327  [malam, min, mau, tanya, untuk, pembayaran, ta...
# 328  [min, indihome, bisa, gak, berlangganan, stb, ...
# 329  [wifi, gua, lelet, setiap, kali, komplen, piha...
# 330                        [makasih, info, pentingnya]
# 331  [min, apa, iya, orang, indihome, bisa, liat, p...
#
#                                               stopword
# 0    [min, tolong, respon, nomor, in, pelaporan, ga...
# 1                               [tanggal, muda, los, ]
# 2    [internetku, mati, penanganan, telat, dikit, k...
# 3    [kenapaa, jaringan, rumah, menit, putus, menit...
# 4    [gangguan, indihome, siang, hadeuh, tagihan, d...
# ..                                                 ...
# 327  [malam, min, pembayaran, tagihan, indihome, vi...
# 328               [min, indihome, berlangganan, stb, ]
# 329  [wifi, gua, lelet, kali, komplen, indihome, re...
# 330                                    [makasih, info]
# 331  [min, iya, orang, indihome, liat, penggunanya,...
#
# [302 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 980
# ------------------------
# min : min
# tolong : tolong
# respon : respon
# nomor : nomor
# in : in
# pelaporan : lapor
# gangguan : ganggu
# petugas : tugas
# turun : turun
# lokasi : lokasi
# brp : brp
# menunggu : tunggu
# tanggal : tanggal
# muda : muda
# los : los
#  :
# internetku : internetku
# mati : mati
# penanganan : tangan
# telat : telat
# dikit : dikit
# kena : kena
# denda : denda
# ditangani : tangan
# kenapaa : kenapaa
# jaringan : jaring
# rumah : rumah
# menit : menit
# putus : putus
# konek : konek
# gitu : gitu
# indihome : indihome
# siang : siang
# hadeuh : hadeuh
# tagihan : tagih
# dikejar : kejar
# pdhal : pdhal
# tempo : tempo
# bermasalah : masalah
# wifi : wifi
# knp : knp
# ampun : ampun
# lambat : lambat
# lola : lola
# darah : darah
# nyaman : nyaman
# sptnya : sptnya
# pindah : pindah
# mnc : mnc
# hey : hey
# gigit : gigit
# hiu : hiu
# berhari : hari
# internet : internet
# hubungi : hubung
# tindak : tindak
# nama : nama
# sakit : sakit
# kepala : kepala
# ahhh : ahhh
# hallo : hallo
# slmt : slmt
# malam : malam
# data : data
# paket : paket
# yerlak : yerlak
# bagimana : bagimana
# kenpa : kenpa
# indita : indita
# respons : respons
# berhenti : henti
# berlangganan : langgan
# diturunkan : turun
# mbps : mbps
# karna : karna
# dinaikkan : naik
# kualitasnya : kualitas
# bayarannya : bayar
# mahal : mahal
# mohon : mohon
# maaf : maaf
# layanan : layan
# siaran : siar
# olahraga : olahraga
# hilang : hilang
# channel : channel
# fox : fox
# sports : sports
# champions : champions
# tlng : tlng
# indihomeku : indihomeku
# bayar : bayar
# koq : koq
# diingetkan : diingetkan
# disuruh : suruh
# via : via
# lucu : lucu
# bantuannya : bantu
# nlpn : nlpn
# kasih : kasih
# tehnisi : tehnisi
# gimana : gimana
# butuh : butuh
# banget : banget
# anak : anak
# belajar : ajar
# solusinya : solusi
# udah : udah
# dituntut : tuntut
# tgl : tgl
# jaringannya : jaring
# sebulan : bulan
# woi : woi
# admin : admin
# akses : akses
# hapus : hapus
# add : add
# program : program
# halo : halo
# putusin : putusin
# lampu : lampu
# wrna : wrna
# merah : merah
# teknisi : teknisi
# aktif : aktif
# bantuan : bantu
# masuk : masuk
# infonta : infonta
# trims : trims
# mind : mind
# enak : enak
# nggak : nggak
# gunain : gunain
# kenakan : kena
# haruskan : harus
# ngeleg : ngeleg
# memuaskan : muas
# maksimal : maksimal
# seamless : seamless
# device : device
# nanya : nanya
# dirumah : rumah
# restar : restar
# ttp : ttp
# nyala : nyala
# kak : kak
# check : check
# jon : jon
# cek : cek
# inbox : inbox
# berlaku : laku
# ont : ont
# zte : zte
# hlo : hlo
# kontol : kontol
# burij : burij
# indidongdong : indidongdong
# sengaja : sengaja
# putuskan : putus
# internetnya : internetnya
# terkenal : kenal
# demen : demen
# complain : complain
# dede : dede
# bojong : bojong
# gede : gede
# kntoolll : kntoolll
# terputus : putus
# kayaknya : kayak
# provider : provider
# separah : parah
# penyakit : sakit
# akut : akut
# obatnya : obat
# sampah : sampah
# knpa : knpa
# terhubung : hubung
# mlm : mlm
# dinihari : dinihari
# jam : jam
# shubuh : shubuh
# suka : suka
# lost : lost
# conection : conection
# untungnya : untung
# berjam : jam
# semoga : moga
# berjamjam : berjamjam
# mnit : mnit
# pengen : ken
# kepikira : kepikira
# merubah : rubah
# chanel : chanel
# movie : movie
# lahi : lah
# rubah : rubah
# hbo : hbo
# gen : gen
# entwrtiment : entwrtiment
# axn : axn
# distop : stop
# ganti : ganti
# lifetime : lifetime
# bagaimna : bagaimna
# pakai : pakai
# fup : fup
# kos : kos
# dipakai : pakai
# org : org
# bnyk : bnyk
# isp : isp
# lho : lho
# fupnya : fupnya
# lemot : lot
# renuw : renuw
# diperhatikan : perhati
# area : area
# pondok : pondok
# kacang : kacang
# barat : barat
# aren : aren
# tangsel : tangsel
# melulu : melulu
# kayak : kayak
# gini : gin
# ganggu : ganggu
# pekerjaan : kerja
# online : online
# renew : renew
# pagi : pagi
# wahhh : wahhh
# koneksi : koneksi
# sampe : sampe
# skrng : skrng
# perbaiki : baik
# frengki : frengki
# khabar : khabar
# sehat : sehat
# salam : salam
# mama : mama
# tulang : tulang
# malang : malang
# sya : sya
# lakukan : laku
# speed : speed
# kecepatannya : cepat
# msih : msih
# gmna : gmna
# udh : udh
# kmrin : kmrin
# nyampe : nyampe
# gaada : gaada
# massal : massal
# bener : bener
# diperbaikinya : baik
# kompensasi : kompensasi
# dibandingkannya : banding
# cbn : cbn
# bagus : bagus
# indigo : indigo
# muncul : muncul
# tanda : tanda
# callcenter : callcenter
# gmn : gmn
# downgrade : downgrade
# bbrp : bbrp
# dri : dri
# normalnya : normal
# besok : besok
# paginya : pagi
# putusnya : putus
# sore : sore
# bagusnya : bagus
# biaaasaaa : biaaasaaa
# dikata : kata
# teknisinya : teknisi
# sempet : sempet
# pulang : pulang
# kerumah : rumah
# ngecek : ngecek
# baguuuusssss : baguuuusssss
# teruskan : terus
# perfoma : perfoma
# kaliann : kaliann
# luuuuarr : luuuuarr
# kmna : kmna
# sampei : sampei
# blm : blm
# oktober : oktober
# cuman : cuman
# benarn : benarn
# kecewa : kecewa
# berat : berat
# dibantu : bantu
# konfirmasi : konfirmasi
# apapun : apa
# follow : follow
# normal : normal
# assalamualaikum : assalamualaikum
# bantu : bantu
# wivi : wivi
# bget : bget
# ganguan : ganguan
# bsa : bsa
# kmaren : kmaren
# indiehomecare : indiehomecare
# rajeg : rajeg
# banten : banten
# hadehh : hadehh
# bayarnya : bayar
# cepat : cepat
# slalu : slalu
# disconnect : disconnect
# harga : harga
# sesuaikan : sesuai
# kwalitas : kwalitas
# selamat : selamat
# menyala : nyala
# perusahaan : usaha
# bumn : bumn
# telkom : telkom
# melucu : lucu
# hri : hri
# rumh : rumh
# full : full
# tpi : tpi
# smua : smua
# aplikasi : aplikasi
# buka : buka
# laporan : lapor
# sanah : sanah
# dtng : dtng
# beli : beli
# sod : sod
# dinyatakan : nyata
# gagal : gagal
# aktivasi : aktivasi
# dana : dana
# terpotong : potong
# direfound : direfound
# dlm : dlm
# kerja : kerja
# berhasil : hasil
# skli : skli
# kondisi : kondisi
# pon : pon
# kelap : kelap
# kelip : kelip
# kualitas : kualitas
# lemottt : lemottt
# biaya : biaya
# perbulan : bulan
# naikkk : naikkk
# bangkeeeeee : bangkeeeeee
# site : site
# kumat : kumat
# mempertahankan : tahan
# system : system
# layanannya : layan
# kalah : kalah
# bersaing : saing
# kompetitor : kompetitor
# swasta : swasta
# tetangga : tetangga
# sebelah : belah
# ckckck : ckckck
# foxsport : foxsport
# diganti : ganti
# terpaksa : paksa
# tulis : tulis
# keluhan : keluh
# myindihome : myindihome
# error : error
# semalam : malam
# tanggapan : tanggap
# wfi : wfi
# inbok : inbok
# krna : krna
# coba : coba
# pdhl : pdhl
# nonton : nonton
# netflix : netflix
# daerah : daerah
# pangandaran : pangandaran
# berkali : kali
# ngga : ngga
# pasang : pasang
# perbaikan : baik
# kemarin : kemarin
# jogja : jogja
# makan : makan
# uang : uang
# haram : haram
# pelayanannya : layan
# jelek : jelek
# habis : habis
# turunnya : turun
# langsung : langsung
# masak : masak
# langganan : langgan
# aturan : atur
# spt : spt
# dlu : dlu
# trus : trus
# msh : msh
# akal : akal
# skrg : skrg
# memberatkan : berat
# nyesel : nyesel
# nambah : nambah
# bulanan : bulan
# parah : parah
# tdi : tdi
# lemmot : lemmot
# isolir : isolir
# juli : juli
# sudsh : sudsh
# selesai : selesai
# koh : koh
# dtik : dtik
# dihidupin : dihidupin
# gmana : gmana
# bgmn : bgmn
# kabar : kabar
# penambahan : tambah
# tiang : tiang
# kel : kel
# soreang : soreang
# kab : kab
# maros : maros
# berulang : ulang
# kali : kali
# pengajuan : aju
# brpa : brpa
# kya : kya
# ketentuannya : tentu
# terima : terima
# informasinya : informasi
# bermanfaat : manfaat
# mas : mas
# ngangguan : ngangguan
# teknisix : teknisix
# smaa : smaa
# zoom : zoom
# tekhnisi : tekhnisi
# drtd : drtd
# pgi : pgi
# down : down
# kah : kah
# muter : muter
# super : super
# sperti : sperti
# restart : restart
# jugaaa : jugaaa
# trimakasih : trimakasih
# sagat : sagat
# membantu : bantu
# registrasi : registrasi
# tips : tips
# dikasih : kasih
# modem : modem
# bekas : bekas
# semalem : semalem
# main : main
# dota : dota
# efek : efek
# lelet : lelet
# molatv : molatv
# youtube : youtube
# lancar : lancar
# wetv : wetv
# macet : macet
# loading : loading
# mesenjer : mesenjer
# email : email
# periksa : periksa
# kabel : kabel
# seringin : ringin
# langkah : langkah
# josss : josss
# informasi : informasi
# ngebantu : ngebantu
# berfungsi : fungsi
# woy : woy
# lapor : lapor
# kaya : kaya
# babi : babi
# pelayanan : layan
# seindah : indah
# iklannya : iklan
# mengecewakan : kecewa
# internetny : internetny
# mulu : mulu
# batal : batal
# berlanggan : langgan
# brapa : brapa
# tumben : tumben
# daftar : daftar
# seamlessnya : seamlessnya
# login : login
# memangnya : memang
# dibuka : buka
# semenjak : semenjak
# pandemi : pandemi
# corner : corner
# kantor : kantor
# ditutup : tutup
# nongkrong : nongkrong
# nelpon : nelpon
# sehari : hari
# dibenerin : dibenerin
# pgn : pgn
# nglamar : nglamar
# off : off
# deadline : deadline
# knapa : knapa
# diatas : atas
# alias : alias
# browsing : browsing
# lalot : lalot
# abis : abis
# ndak : ndak
# disney : disney
# junior : junior
# slh : slh
# senilai : nila
# rb : rb
# bln : bln
# skitar : skitar
# thn : thn
# channelnya : channelnya
# tagihannya : tagih
# edukasi : edukasi
# ato : ato
# kirim : kirim
# kendala : kendala
# nonaktifkan : nonaktif
# indipacket : indipacket
# kids : kids
# sabtu : sabtu
# telp : telp
# minggu : minggu
# selasa : selasa
# ktnya : ktnya
# progress : progress
# penyelesaian : selesai
# loss : loss
# truss : truss
# nyalanya : nyala
# kgk : kgk
# nunggak : nunggak
# pelanggan : langgan
# ijin : ijin
# melaporkan : lapor
# router : router
# tersambar : sambar
# petir : petir
# prosedur : prosedur
# mengajukan : aju
# sampek : sampek
# make : make
# eco : eco
# sumpah : sumpah
# pemuda : pemuda
# mengajarkan : ajar
# menyerah : serah
# teriakan : ria
# semangat : semangat
# pahlawan : pahlawan
# menggema : gema
# lubuk : lubuk
# hati : hati
# menua : tua
# ingatlah : ingat
# memajukan : maju
# bangsa : bangsa
# payah : payah
# suda : suda
# dirugikan : rugi
# semntara : semntara
# balapan : balap
# virtual : virtual
# diperbaiki : baik
# secepatnya : cepat
# care : care
# tertasi : tas
# setingan : ting
# lan : lan
# colkannya : colkannya
# pasword : pasword
# usernamenya : usernamenya
# username : username
# port : port
# huawei : huawei
# biaasa : biaasa
# pedurungan : pedurungan
# kota : kota
# semarang : semarang
# woww : woww
# murah : murah
# buangettttss : buangettttss
# mengaktifkan : aktif
# saldo : saldo
# wms : wms
# mb : mb
# ssid : ssid
# yth : yth
# meutuah : meutuah
# cuan : cuan
# seharian : hari
# woyy : woyy
# doong : doong
# kreatif : kreatif
# sampingan : samping
# dirmh : dirmh
# apanya : apa
# fiber : fiber
# digondol : gondol
# orang : orang
# kebelet : kebelet
# nyabu : nyabu
# penyelesaiannya : selesai
# anehnya : aneh
# ganjil : ganjil
# upgrade : upgrade
# estimasi : estimasi
# permohonan : mohon
# alamat : alamat
# tinggal : tinggal
# dipindah : pindah
# kealamat : alamat
# rmh : rmh
# menginspirasi : inspirasi
# magerrrrr : magerrrrr
# semaleman : maleman
# tetep : tetep
# gabisa : gabisa
# patch : patch
# chord : chord
# sesuai : sesuai
# tangkit : tangkit
# batu : batu
# muara : muara
# putih : putih
# natar : natar
# tlg : tlg
# masal : masal
# wkt : wkt
# belom : bom
# wilayah : wilayah
# gabung : gabung
# aliran : alir
# dibener : dibener
# benerin : benerin
# hadehhh : hadehhh
# promo : promo
# pas : pas
# setel : setel
# timbul : timbul
# pemberitahuan : pemberitahuan
# distribusi : distribusi
# nunggu : nunggu
# kesadaran : sadar
# tanggung : tanggung
# farhan : farhan
# okt : okt
# dpt : dpt
# terlambat : lambat
# dikenakan : kena
# dendanya : denda
# mentenain : mentenain
# sibuk : sibuk
# cabang : cabang
# randudongkal : randudongkal
# suruh : suruh
# ngadu : ngadu
# pengaduan : adu
# jalan : jalan
# merahnya : merah
# rusak : rusak
# pln : pln
# ciateul : ciateul
# bandung : bandung
# ditunggu : tunggu
# cuangki : cuangki
# survey : survey
# ujan : ujan
# terisolir : isolir
# harian : hari
# wlan : wlan
# tersambung : sambung
# napa : napa
# puk : puk
# konpirmasi : konpirmasi
# karywn : karywn
# pimpinan : pimpin
# blas : blas
# pemelihraan : pemelihraan
# trs : trs
# ternganggu : ternganggu
# sapa : sapa
# kesel : kesel
# byr : byr
# rutin : rutin
# samain : samain
# donk : donk
# bulannnya : bulannnya
# buruk : buruk
# bertahan : tahan
# coverage : coverage
# sudh : sudh
# heran : heran
# ambil : ambil
# kadang : kadang
# yach : yach
# perangkat : perangkat
# terimakasih : terimakasih
# tersedia : sedia
# kartu : kartu
# perdana : perdana
# sekolah : sekolah
# sdn : sdn
# cintaasih : cintaasih
# majalengka : majalengka
# gladi : gladi
# anbk : anbk
# gimna : gimna
# indihomenya : indihomenya
# nihh : nihh
# kapok : kapok
# metok : metok
# enk : enk
# mentok : mentok
# hbs : hbs
# menyiksa : siksa
# rame : rame
# kebijakan : bijak
# tmpt : tmpt
# usaha : usaha
# amburadul : amburadul
# systemnya : systemnya
# beruntung : untung
# arti : arti
# indonesia : indonesia
# peristiwa : peristiwa
# salah : salah
# kekuatan : kuat
# membangun : bangun
# kepribadian : pribadi
# nilai : nilai
# luhur : luhur
# indhome : indhome
# plus : plus
# teman : teman
# kerjaan : kerja
# game : game
# ane : ane
# proplayer : proplayer
# mobile : mobile
# legend : legend
# hidup : hidup
# sinyalnya : sinyal
# dibayar : bayar
# rajin : rajin
# status : status
# gtu : gtu
# kek : kek
# diem : diem
# bae : bae
# dipirit : pirit
# pirit : pirit
# kyk : kyk
# kelar : kelar
# season : season
# you : you
# may : may
# fallin : fallin
# love : love
# another : another
# country : country
# languages : languages
# people : people
# around : around
# the : the
# world : world
# but : but
# soul : soul
# and : and
# home : home
# still : still
# bermalas : malas
# malasan : malas
# jiwa : jiwa
# penuh : penuh
# api : api
# kemajuan : maju
# bukti : bukti
# negara : negara
# kuat : kuat
# generasi : generasi
# mudanya : muda
# intelektual : intelektual
# mari : mari
# bangun : bangun
# keren : keren
# hotstar : hotstar
# sekedar : dar
# tekad : tekad
# menjunjung : junjung
# persatuan : satu
# banyaknya : banyak
# perbedaan : beda
# tunjukan : tunjuk
# indah : indah
# are : are
# youth : youth
# strong : strong
# independent : independent
# one : one
# future : future
# ditempat : tempat
# babakan : babakan
# cikedal : cikedal
# melangkah : lang
# batas : batas
# mengalahkan : kalah
# takut : takut
# terbatas : batas
# hebat : hebat
# alam : alam
# bahu : bahu
# membahu : bahu
# mewujudkannya : wujud
# yuk : yuk
# kakak : kakak
# pantang : pantang
# mundur : mundur
# mudah : mudah
# meeting : meeting
# tatap : tatap
# muka : muka
# maya : maya
# mencoba : coba
# biarkan : biar
# penyesalan : sesal
# selangkah : selang
# menang : menang
# berani : berani
# tangguh : tangguh
# berprinsip : prinsip
# ragu : ragu
# stabil : stabil
# kencang : kencang
# beres : beres
# kemaren : kemaren
# indihom : indihom
# asik : asik
# nikmatin : nikmatin
# makasih : makasih
# hamya : hamya
# agas : agas
# harganya : harga
# cerita : cerita
# susah : susah
# sinyal : sinyal
# beneran : beneran
# deh : deh
# mempermudah : mudah
# proses : proses
# wfh : wfh
# kerjanya : kerja
# diwesing : diwesing
# penjelasan : jelas
# sihh : sihh
# batam : batam
# menyaksikan : saksi
# liga : liga
# inggris : inggris
# dmana : dmana
# buru : buru
# yaa : yaa
# mat : mat
# indihomi : indihomi
# smoaa : smoaa
# indikator : indikator
# astaufirlah : astaufirlah
# bkin : bkin
# gni : gni
# klw : klw
# dtlp : dtlp
# seneng : neng
# nyaaaa : nyaaaa
# hadeh : hadeh
# lose : lose
# mengatasi : atas
# pembobol : bobol
# terdektesi : terdektesi
# teknologi : teknologi
# memudahkan : mudah
# beraktifitas : beraktifitas
# memudahkanku : mudah
# menjalankan : jalan
# kegiatan : giat
# aman : aman
# terkendali : kendali
# jaya : jaya
# nemenin : nemenin
# waaaahhh : waaaahhh
# puas : puas
# menjalani : jalan
# aktivitas : aktivitas
# mola : mola
# terusssssss : terusssssss
# makasiii : makasiii
# makasi : makas
# kuuuu : kuuuu
# connect : connect
# mimin : mimin
# berharap : harap
# digital : digital
# maju : maju
# canggih : canggih
# usahaku : usaha
# kacau : kacau
# bahaya : bahaya
# infonya : info
# info : info
# vpn : vpn
# gratis : gratis
# sip : sip
# curi : curi
# bahayanya : bahaya
# best : best
# komplain : komplain
# ditanggepin : ditanggepin
# mengutamakan : utama
# customer : customer
# platform : platform
# berkat : berkat
# nugas : nugas
# kehambat : hambat
# menemani : tani
# terusssss : terusssss
# dikala : kala
# beteeeee : beteeeee
# wifinya : wifinya
# eror : eror
# alusan : alusan
# aokawoak : aokawoak
# minn : minn
# solusi : solusi
# lupa : lupa
# password : password
# mengganti : ganti
# sandi : sandi
# panik : panik
# tlp : tlp
# ngabisin : ngabisin
# pulsa : pulsa
# ndengerij : ndengerij
# operator : operator
# akirnya : akirnya
# ludes : ludes
# auto : auto
# rugi : rugi
# dobel : dobel
# lanjutan : lanjut
# pantesan : pantesan
# skr : skr
# nga : nga
# pembayaran : bayar
# stb : stb
# gua : gua
# komplen : komplen
# respos : respos
# iya : iya
# liat : liat
# penggunanya : guna
# web : web
# apk : apk
# {'min': 'min', 'tolong': 'tolong', 'respon': 'respon', 'nomor': 'nomor', 'in': 'in', 'pelaporan': 'lapor', 'gangguan': 'ganggu', 'petugas': 'tugas', 'turun': 'turun', 'lokasi': 'lokasi', 'brp': 'brp', 'menunggu': 'tunggu', 'tanggal': 'tanggal', 'muda': 'muda', 'los': 'los', '': '', 'internetku': 'internetku', 'mati': 'mati', 'penanganan': 'tangan', 'telat': 'telat', 'dikit': 'dikit', 'kena': 'kena', 'denda': 'denda', 'ditangani': 'tangan', 'kenapaa': 'kenapaa', 'jaringan': 'jaring', 'rumah': 'rumah', 'menit': 'menit', 'putus': 'putus', 'konek': 'konek', 'gitu': 'gitu', 'indihome': 'indihome', 'siang': 'siang', 'hadeuh': 'hadeuh', 'tagihan': 'tagih', 'dikejar': 'kejar', 'pdhal': 'pdhal', 'tempo': 'tempo', 'bermasalah': 'masalah', 'wifi': 'wifi', 'knp': 'knp', 'ampun': 'ampun', 'lambat': 'lambat', 'lola': 'lola', 'darah': 'darah', 'nyaman': 'nyaman', 'sptnya': 'sptnya', 'pindah': 'pindah', 'mnc': 'mnc', 'hey': 'hey', 'gigit': 'gigit', 'hiu': 'hiu', 'berhari': 'hari', 'internet': 'internet', 'hubungi': 'hubung', 'tindak': 'tindak', 'nama': 'nama', 'sakit': 'sakit', 'kepala': 'kepala', 'ahhh': 'ahhh', 'hallo': 'hallo', 'slmt': 'slmt', 'malam': 'malam', 'data': 'data', 'paket': 'paket', 'yerlak': 'yerlak', 'bagimana': 'bagimana', 'kenpa': 'kenpa', 'indita': 'indita', 'respons': 'respons', 'berhenti': 'henti', 'berlangganan': 'langgan', 'diturunkan': 'turun', 'mbps': 'mbps', 'karna': 'karna', 'dinaikkan': 'naik', 'kualitasnya': 'kualitas', 'bayarannya': 'bayar', 'mahal': 'mahal', 'mohon': 'mohon', 'maaf': 'maaf', 'layanan': 'layan', 'siaran': 'siar', 'olahraga': 'olahraga', 'hilang': 'hilang', 'channel': 'channel', 'fox': 'fox', 'sports': 'sports', 'champions': 'champions', 'tlng': 'tlng', 'indihomeku': 'indihomeku', 'bayar': 'bayar', 'koq': 'koq', 'diingetkan': 'diingetkan', 'disuruh': 'suruh', 'via': 'via', 'lucu': 'lucu', 'bantuannya': 'bantu', 'nlpn': 'nlpn', 'kasih': 'kasih', 'tehnisi': 'tehnisi', 'gimana': 'gimana', 'butuh': 'butuh', 'banget': 'banget', 'anak': 'anak', 'belajar': 'ajar', 'solusinya': 'solusi', 'udah': 'udah', 'dituntut': 'tuntut', 'tgl': 'tgl', 'jaringannya': 'jaring', 'sebulan': 'bulan', 'woi': 'woi', 'admin': 'admin', 'akses': 'akses', 'hapus': 'hapus', 'add': 'add', 'program': 'program', 'halo': 'halo', 'putusin': 'putusin', 'lampu': 'lampu', 'wrna': 'wrna', 'merah': 'merah', 'teknisi': 'teknisi', 'aktif': 'aktif', 'bantuan': 'bantu', 'masuk': 'masuk', 'infonta': 'infonta', 'trims': 'trims', 'mind': 'mind', 'enak': 'enak', 'nggak': 'nggak', 'gunain': 'gunain', 'kenakan': 'kena', 'haruskan': 'harus', 'ngeleg': 'ngeleg', 'memuaskan': 'muas', 'maksimal': 'maksimal', 'seamless': 'seamless', 'device': 'device', 'nanya': 'nanya', 'dirumah': 'rumah', 'restar': 'restar', 'ttp': 'ttp', 'nyala': 'nyala', 'kak': 'kak', 'check': 'check', 'jon': 'jon', 'cek': 'cek', 'inbox': 'inbox', 'berlaku': 'laku', 'ont': 'ont', 'zte': 'zte', 'hlo': 'hlo', 'kontol': 'kontol', 'burij': 'burij', 'indidongdong': 'indidongdong', 'sengaja': 'sengaja', 'putuskan': 'putus', 'internetnya': 'internetnya', 'terkenal': 'kenal', 'demen': 'demen', 'complain': 'complain', 'dede': 'dede', 'bojong': 'bojong', 'gede': 'gede', 'kntoolll': 'kntoolll', 'terputus': 'putus', 'kayaknya': 'kayak', 'provider': 'provider', 'separah': 'parah', 'penyakit': 'sakit', 'akut': 'akut', 'obatnya': 'obat', 'sampah': 'sampah', 'knpa': 'knpa', 'terhubung': 'hubung', 'mlm': 'mlm', 'dinihari': 'dinihari', 'jam': 'jam', 'shubuh': 'shubuh', 'suka': 'suka', 'lost': 'lost', 'conection': 'conection', 'untungnya': 'untung', 'berjam': 'jam', 'semoga': 'moga', 'berjamjam': 'berjamjam', 'mnit': 'mnit', 'pengen': 'ken', 'kepikira': 'kepikira', 'merubah': 'rubah', 'chanel': 'chanel', 'movie': 'movie', 'lahi': 'lah', 'rubah': 'rubah', 'hbo': 'hbo', 'gen': 'gen', 'entwrtiment': 'entwrtiment', 'axn': 'axn', 'distop': 'stop', 'ganti': 'ganti', 'lifetime': 'lifetime', 'bagaimna': 'bagaimna', 'pakai': 'pakai', 'fup': 'fup', 'kos': 'kos', 'dipakai': 'pakai', 'org': 'org', 'bnyk': 'bnyk',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/302 [00:00<?, ?it/s]
#                                                comment  \
# 0    min tolong di respon nomor in111995854 pelapor...
# 1                   masih tanggal muda sudah los lagi.
# 2    internetku mati 3 hari tanpa penanganan... tel...
# 3    ini kenapaa jaringan di rumah saya 5 menit put...
# 4    gangguan indihome dari siang, hadeuh, kalau ta...
# ..                                                 ...
# 327  malam min, mau tanya untuk pembayaran tagihan ...
# 328  min, 1 indihome tv bisa gak berlangganan 3 stb...
# 329  wifi gua lelet, setiap kali komplen ke pihak i...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                       cleaning_comment  \
# 0    min tolong respon nomor in  pelaporan gangguan...
# 1                   masih tanggal muda sudah los lagi
# 2    internetku mati hari tanpa penanganan telat di...
# 3    ini kenapaa jaringan rumah saya menit putus me...
# 4    gangguan indihome dari siang hadeuh kalau tagi...
# ..                                                 ...
# 327  malam min mau tanya untuk pembayaran tagihan i...
# 328  min indihome bisa gak berlangganan stb sekaligus
# 329  wifi gua lelet setiap kali komplen pihak indih...
# 330                            makasih info pentingnya
# 331  min apa iya orang indihome bisa liat penggunan...
#
#                                             tokenisasi  \
# 0    [min, tolong, respon, nomor, in, pelaporan, ga...
# 1           [masih, tanggal, muda, sudah, los, lagi, ]
# 2    [internetku, mati, hari, tanpa, penanganan, te...
# 3    [ini, kenapaa, jaringan, rumah, saya, menit, p...
# 4    [gangguan, indihome, dari, siang, hadeuh, kala...
# ..                                                 ...
# 327  [malam, min, mau, tanya, untuk, pembayaran, ta...
# 328  [min, indihome, bisa, gak, berlangganan, stb, ...
# 329  [wifi, gua, lelet, setiap, kali, komplen, piha...
# 330                        [makasih, info, pentingnya]
# 331  [min, apa, iya, orang, indihome, bisa, liat, p...
#
#                                               stopword  \
# 0    [min, tolong, respon, nomor, in, pelaporan, ga...
# 1                               [tanggal, muda, los, ]
# 2    [internetku, mati, penanganan, telat, dikit, k...
# 3    [kenapaa, jaringan, rumah, menit, putus, menit...
# 4    [gangguan, indihome, siang, hadeuh, tagihan, d...
# ..                                                 ...
# 327  [malam, min, pembayaran, tagihan, indihome, vi...
# 328               [min, indihome, berlangganan, stb, ]
# 329  [wifi, gua, lelet, kali, komplen, indihome, re...
# 330                                    [makasih, info]
# 331  [min, iya, orang, indihome, liat, penggunanya,...
#
#                                               stemming
# 0    [min, tolong, respon, nomor, in, lapor, ganggu...
# 1                               [tanggal, muda, los, ]
# 2    [internetku, mati, tangan, telat, dikit, kena,...
# 3    [kenapaa, jaring, rumah, menit, putus, menit, ...
# 4    [ganggu, indihome, siang, hadeuh, tagih, kejar...
# ..                                                 ...
# 327  [malam, min, bayar, tagih, indihome, via, apli...
# 328                    [min, indihome, langgan, stb, ]
# 329  [wifi, gua, lelet, kali, komplen, indihome, re...
# 330                                    [makasih, info]
# 331  [min, iya, orang, indihome, liat, guna, masuk,...
#
# [302 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [min, tolong, respon, nomor, in, lapor, ganggu...
# 1                               [tanggal, muda, los, ]
# 2    [internetku, mati, tangan, telat, dikit, kena,...
# 3    [kenapaa, jaring, rumah, menit, putus, menit, ...
# 4    [ganggu, indihome, siang, hadeuh, tagih, kejar...
# ..                                                 ...
# 327  [malam, min, bayar, tagih, indihome, via, apli...
# 328                    [min, indihome, langgan, stb, ]
# 329  [wifi, gua, lelet, kali, komplen, indihome, re...
# 330                                    [makasih, info]
# 331  [min, iya, orang, indihome, liat, guna, masuk,...
#
# [302 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_10.xlsx')
