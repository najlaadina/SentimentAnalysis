# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_12.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Min ini kok WiFi gw hilang, padahal modemnya n...
# 1    Min, saat saya login keaplikasi MyIndiHome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               Makasih min, infonya bermanfaat bgttt.
# 4                Kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 382       min wifi.id seamless maksimal berapa device?
# 383  Min kamu itu bilang waspada penipuan tp kamu s...
# 384      Makasih IndiHome, WFH aku lancar sangat aman.
# 385  Bener banget min! Thank you imbauannya.  IndiHome
# 386                                makasih infonya min
#
# [387 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 23

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Min ini kok WiFi gw hilang, padahal modemnya n...
# 1    Min, saat saya login keaplikasi MyIndiHome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               Makasih min, infonya bermanfaat bgttt.
# 4                Kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 379  Min ni Indihome sejak gangguan masal  sampek s...
# 381  Min. Knpa speed Upload Indihome dibawa 5 Mbps ...
# 383  Min kamu itu bilang waspada penipuan tp kamu s...
# 384      Makasih IndiHome, WFH aku lancar sangat aman.
# 385  Bener banget min! Thank you imbauannya.  IndiHome
#
# [347 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    min ini kok wifi gw hilang, padahal modemnya n...
# 1    min, saat saya login keaplikasi myindihome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               makasih min, infonya bermanfaat bgttt.
# 4                kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 379  min ni indihome sejak gangguan masal  sampek s...
# 381  min. knpa speed upload indihome dibawa 5 mbps ...
# 383  min kamu itu bilang waspada penipuan tp kamu s...
# 384      makasih indihome, wfh aku lancar sangat aman.
# 385  bener banget min! thank you imbauannya.  indihome
#
# [347 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    min ini kok wifi gw hilang, padahal modemnya n...
# 1    min, saat saya login keaplikasi myindihome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               makasih min, infonya bermanfaat bgttt.
# 4                kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 379  min ni indihome sejak gangguan masal  sampek s...
# 381  min. knpa speed upload indihome dibawa 5 mbps ...
# 383  min kamu itu bilang waspada penipuan tp kamu s...
# 384      makasih indihome, wfh aku lancar sangat aman.
# 385  bener banget min! thank you imbauannya.  indihome
#
#                                       cleaning_comment
# 0    min ini kok wifi hilang padahal modemnya nyala...
# 1    min saat saya login keaplikasi myindihome dan ...
# 2      ini mau buat laporan botnya nggk ngerespon gmn
# 3                makasih min infonya bermanfaat bgttt
# 4                 kak cek tagihan lewat aplikasi bisa
# ..                                                 ...
# 379  min indihome sejak gangguan masal sampek sekar...
# 381  min knpa speed upload indihome dibawa mbps dim...
# 383  min kamu itu bilang waspada penipuan kamu send...
# 384       makasih indihome wfh aku lancar sangat aman
# 385     bener banget min thank you imbauannya indihome
#
# [347 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    min ini kok wifi gw hilang, padahal modemnya n...
# 1    min, saat saya login keaplikasi myindihome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               makasih min, infonya bermanfaat bgttt.
# 4                kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 379  min ni indihome sejak gangguan masal  sampek s...
# 381  min. knpa speed upload indihome dibawa 5 mbps ...
# 383  min kamu itu bilang waspada penipuan tp kamu s...
# 384      makasih indihome, wfh aku lancar sangat aman.
# 385  bener banget min! thank you imbauannya.  indihome
#
#                                       cleaning_comment  \
# 0    min ini kok wifi hilang padahal modemnya nyala...
# 1    min saat saya login keaplikasi myindihome dan ...
# 2      ini mau buat laporan botnya nggk ngerespon gmn
# 3                makasih min infonya bermanfaat bgttt
# 4                 kak cek tagihan lewat aplikasi bisa
# ..                                                 ...
# 379  min indihome sejak gangguan masal sampek sekar...
# 381  min knpa speed upload indihome dibawa mbps dim...
# 383  min kamu itu bilang waspada penipuan kamu send...
# 384       makasih indihome wfh aku lancar sangat aman
# 385     bener banget min thank you imbauannya indihome
#
#                                             tokenisasi
# 0    [min, ini, kok, wifi, hilang, padahal, modemny...
# 1    [min, saat, saya, login, keaplikasi, myindihom...
# 2    [ini, mau, buat, laporan, botnya, nggk, ngeres...
# 3         [makasih, min, infonya, bermanfaat, bgttt, ]
# 4         [kak, cek, tagihan, lewat, aplikasi, bisa, ]
# ..                                                 ...
# 379  [min, indihome, sejak, gangguan, masal, sampek...
# 381  [min, knpa, speed, upload, indihome, dibawa, m...
# 383  [min, kamu, itu, bilang, waspada, penipuan, ka...
# 384  [makasih, indihome, wfh, aku, lancar, sangat, ...
# 385  [bener, banget, min, thank, you, imbauannya, i...
#
# [347 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    min ini kok wifi gw hilang, padahal modemnya n...
# 1    min, saat saya login keaplikasi myindihome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               makasih min, infonya bermanfaat bgttt.
# 4                kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 379  min ni indihome sejak gangguan masal  sampek s...
# 381  min. knpa speed upload indihome dibawa 5 mbps ...
# 383  min kamu itu bilang waspada penipuan tp kamu s...
# 384      makasih indihome, wfh aku lancar sangat aman.
# 385  bener banget min! thank you imbauannya.  indihome
#
#                                       cleaning_comment  \
# 0    min ini kok wifi hilang padahal modemnya nyala...
# 1    min saat saya login keaplikasi myindihome dan ...
# 2      ini mau buat laporan botnya nggk ngerespon gmn
# 3                makasih min infonya bermanfaat bgttt
# 4                 kak cek tagihan lewat aplikasi bisa
# ..                                                 ...
# 379  min indihome sejak gangguan masal sampek sekar...
# 381  min knpa speed upload indihome dibawa mbps dim...
# 383  min kamu itu bilang waspada penipuan kamu send...
# 384       makasih indihome wfh aku lancar sangat aman
# 385     bener banget min thank you imbauannya indihome
#
#                                             tokenisasi  \
# 0    [min, ini, kok, wifi, hilang, padahal, modemny...
# 1    [min, saat, saya, login, keaplikasi, myindihom...
# 2    [ini, mau, buat, laporan, botnya, nggk, ngeres...
# 3         [makasih, min, infonya, bermanfaat, bgttt, ]
# 4         [kak, cek, tagihan, lewat, aplikasi, bisa, ]
# ..                                                 ...
# 379  [min, indihome, sejak, gangguan, masal, sampek...
# 381  [min, knpa, speed, upload, indihome, dibawa, m...
# 383  [min, kamu, itu, bilang, waspada, penipuan, ka...
# 384  [makasih, indihome, wfh, aku, lancar, sangat, ...
# 385  [bener, banget, min, thank, you, imbauannya, i...
#
#                                               stopword
# 0    [min, wifi, hilang, modemnya, nyala, sengaja, ...
# 1    [min, login, keaplikasi, myindihome, pilih, me...
# 2            [laporan, botnya, nggk, ngerespon, gmn, ]
# 3         [makasih, min, infonya, bermanfaat, bgttt, ]
# 4                      [kak, cek, tagihan, aplikasi, ]
# ..                                                 ...
# 379  [min, indihome, gangguan, masal, sampek, maen,...
# 381  [min, knpa, speed, upload, indihome, dibawa, m...
# 383  [min, waspada, penipuan, pelanggan, mu, dibuat...
# 384           [makasih, indihome, wfh, lancar, aman, ]
# 385  [bener, banget, min, thank, you, imbauannya, i...
#
# [347 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 962
# ------------------------
# min : min
# wifi : wifi
# hilang : hilang
# modemnya : modem
# nyala : nyala
# sengaja : sengaja
# komplain : komplain
# chat : chat
# bener : bener
# responnya : responnya
# login : login
# keaplikasi : aplikasi
# myindihome : myindihome
# pilih : pilih
# metode : metode
# otentikasi : otentikasi
# sms : sms
# muncul : muncul
# pesan : pesan
# service : service
# error : error
# clear : clear
# cache : cache
# data : data
# install : install
# ulang : ulang
#  :
# laporan : lapor
# botnya : bot
# nggk : nggk
# ngerespon : ngerespon
# gmn : gmn
# makasih : makasih
# infonya : info
# bermanfaat : manfaat
# bgttt : bgttt
# kak : kak
# cek : cek
# tagihan : tagih
# aplikasi : aplikasi
# udah : udah
# via : via
# messanger : messanger
# koneksi : koneksi
# internet : internet
# mati : mati
# lampu : lampu
# pon : pon
# menyala : nyala
# merah : merah
# subuh : subuh
# restart : restart
# kali : kali
# kabel : kabel
# terpasang : pasang
# gimana : gimana
# modem : modem
# zoom : zoom
# meeting : meeting
# aelaaah : aelaaah
# putus : putus
# nyambung : nyambung
# mingguan : minggu
# asyik : asyik
# nonton : nonton
# jaringan : jaring
# mbps : mbps
# dijam : jam
# witeng : witeng
# videinya : vide
# lemot : lot
# yahh : yahh
# mohon : mohon
# solusinya : solusi
# wilayah : wilayah
# ntt : ntt
# mantap : mantap
# eror : eror
# kayak : kayak
# hantu : hantu
# gmna : gmna
# perubahan : ubah
# kmaren : kmaren
# skarang : skarang
# konfirmasi : konfirmasi
# memberitahu : memberitahu
# apapun : apa
# telkom : telkom
# sore : sore
# inet : inet
# stabil : stabil
# skrang : skrang
# infonyaa : infonyaa
# byk : byk
# mimin : mimin
# gini : gin
# yaa : yaa
# ngga : ngga
# loss : loss
# tanggal : tanggal
# november : november
# gitu : gitu
# gerus : gerus
# inbox : inbox
# respon : respon
# bot : bot
# indihome : indihome
# tlong : tlong
# dbntu : dbntu
# masuk : masuk
# aduuuhhhh : aduuuhhhh
# kesel : kesel
# sayaaaa : sayaaaa
# bgmn : bgmn
# membantu : bantu
# banget : banget
# wifinya : wifinya
# lelet : lelet
# konek : konek
# down : down
# thx : thx
# informasinya : informasi
# gada : gada
# otak : otak
# main : main
# ping : ping
# mulu : mulu
# kirain : kirain
# gua : gua
# doang : doang
# user : user
# bagus : bagus
# sungguh : sungguh
# disayangkan : sayang
# cuman : cuman
# info : info
# pelayanan : layan
# layanan : layan
# menganggap : anggap
# sampah : sampah
# keluhan : keluh
# pelanggan : langgan
# alasan : alas
# logika : logika
# mengada : ada
# nice : nice
# uang : uang
# deposit : deposit
# sya : sya
# udh : udh
# proses : proses
# blum : blum
# nemu : nemu
# gajelas : gajelas
# gaguna : gaguna
# gapernah : gapernah
# nuntasin : nuntasin
# care : care
# ngatasinnya : ngatasinnya
# the : the
# best : best
# cmn : cmn
# dpt : dpt
# segini : gin
# kemarin : kemarin
# penuh : penuh
# loading : loading
# game : game
# kayanya : kaya
# jalan : jalan
# stuck : stuck
# hahah : hahah
# well : well
# played : played
# bro : bro
# sinyal : sinyal
# bnget : bnget
# llt : llt
# keterangan : terang
# tersedia : sedia
# bayar : bayar
# pasang : pasang
# jaminan : jamin
# thn : thn
# kembalikan : kembali
# potong : potong
# pembayaran : bayar
# msh : msh
# segitu : segitu
# otomatis : otomatis
# merugikan : rugi
# los : los
# warna : warna
# penangananya : penangananya
# yayaya : yayaya
# indi : indi
# dimata : mata
# gamer : gamer
# upgrade : upgrade
# pantesan : pantesan
# langsung : langsung
# terima : terima
# kasih : kasih
# tolonglah : tolong
# tolong : tolong
# customer : customer
# dateng : dateng
# teknisi : teknisi
# daerah : daerah
# lost : lost
# dipercepat : cepat
# perbaikannya : baik
# pelaporan : lapor
# benefit : benefit
# extender : extender
# des : des
# lapor : lapor
# petugas : tugas
# ceklis : ceklis
# tiketnya : tiket
# perbaikan : baik
# jatuh : jatuh
# tempo : tempo
# registrasi : registrasi
# memperluas : luas
# benefitnya : benefitnya
# iya : iya
# sampe : sampe
# lantai : lantai
# rumah : rumah
# keuntungan : untung
# nyampe : nyampe
# brp : brp
# meter : meter
# jangkauannya : jangkau
# luas : luas
# nggak : nggak
# youtube : youtube
# kadang : kadang
# vidio : vidio
# muter : muter
# minat : minat
# gangguan : ganggu
# mempersulit : sulit
# pilihannya : pilih
# extendernya : extendernya
# kebantu : bantu
# pojokan : pojok
# beda : beda
# tetep : tetep
# kenceng : kenceng
# signal : signal
# yuhu : yuhu
# pakai : pakai
# koneksinya : koneksi
# promo : promo
# pengen : ken
# carah : carah
# daftar : daftar
# memasang : pasang
# brpa : brpa
# solusi : solusi
# ruangan : ruang
# lemah : lemah
# ran : ran
# sinyalnya : sinyal
# bisnis : bisnis
# melayani : layan
# ingay : ingay
# slogan : slogan
# mmg : mmg
# jangkauan : jangkau
# jarahnya : jarah
# bertambah : tambah
# pemasangan : pasang
# conek : conek
# klu : klu
# asalnya : asal
# lalod : lalod
# perluas : luas
# makasi : makas
# wooww : wooww
# murah : murah
# reboo : reboo
# gkk : gkk
# utama : utama
# penghalang : halang
# mustahil : mustahil
# blm : blm
# disesuaikan : sesuai
# modar : modar
# dihitung : hitung
# full : full
# kompensasi : kompensasi
# pokoknya : pokok
# berlangganan : langgan
# indihone : indihone
# trus : trus
# ganti : ganti
# kinerja : kerja
# gabut : gabut
# rb : rb
# lambat : lambat
# dipakai : pakai
# dibantu : bantu
# waah : waah
# vouchernya : vouchernya
# box : box
# konsumen : konsumen
# rmh : rmh
# minggu : minggu
# skali : skali
# mantep : mantep
# dibantubtindak : dibantubtindak
# lanjuti : lanjut
# haii : hai
# connect : connect
# tabung : tabung
# kabelnya : kabel
# dimasukan : masuk
# sandi : sandi
# menunya : menu
# tgl : tgl
# melimpahh : melimpahh
# euyy : euyy
# nikmat : nikmat
# lancar : lancar
# nyaman : nyaman
# hadiahnya : hadiah
# dibetulin : dibetulin
# sebulan : bulan
# terhubung : hubung
# malam : malam
# gardu : gardu
# terbuka : buka
# berbahaya : bahaya
# hujan : hujan
# ditempat : tempat
# kendala : kendala
# pas : pas
# pusatnya : pusat
# status : status
# lose : lose
# sesuai : sesuai
# informasi : informasi
# kerumah : rumah
# tungguin : tungguin
# handovrr : handovrr
# dadakan : dada
# apk : apk
# benerin : benerin
# seluler : seluler
# lemotnya : lot
# ampun : ampun
# berat : berat
# segede : gede
# seringan : sering
# swasta : swasta
# mud : mud
# tri : tri
# asri : asri
# desindotama : desindotama
# ciputat : ciputat
# kamis : kamis
# internetnya : internetnya
# puluhan : puluh
# janji : janji
# diperbaiki : baik
# wiffi : wiffi
# ilang : ilang
# refresh : refresh
# pengeluaran : keluar
# bengkak : bengkak
# lom : lom
# beli : beli
# kuota : kuota
# indah : indah
# permisi : permisi
# fallout : fallout
# screen : screen
# loginnya : loginnya
# hotspot : hotspot
# handphone : handphone
# diganti : ganti
# halo : halo
# ponnya : pon
# atasi : atas
# ubah : ubah
# kepemilikan : milik
# gara : gara
# sharing : sharing
# nama : nama
# temen : temen
# orangnya : orang
# nomer : nomer
# email : email
# telfon : telfon
# ribet : ribet
# tobat : tobat
# disurug : disurug
# nunggu : nunggu
# belom : bom
# tanggepin : tanggepin
# terputus : putus
# tpi : tpi
# jasa : jasa
# dtang : dtang
# minnn : minnn
# direspon : direspon
# seminggu : minggu
# arjawinangun : arjawinangun
# parah : parah
# melapor : lapor
# tehnisinya : tehnisinya
# sunggu : sunggu
# payah : payah
# buruk : buruk
# woy : woy
# admin : admin
# komplen : komplen
# telepon : telepon
# jelek : jelek
# mending : mending
# pindah : pindah
# oxgen : oxgen
# biznet : biznet
# slalu : slalu
# rusak : rusak
# langganan : langgan
# dptnya : dptnya
# wkwkwkkw : wkwkwkkw
# maen : maen
# ngelag : ngelag
# ditindaklanjuti : ditindaklanjuti
# router : router
# indikasi : indikasi
# access : access
# waaah : waaah
# hadiah : hadiah
# spesial : spesial
# bangeeet : bangeeet
# lon : lon
# kedip : kedip
# selasa : selasa
# dibenerin : dibenerin
# azis : azis
# maulana : maulana
# berguna : guna
# langanan : langanan
# minipack : minipack
# tonton : tonton
# browser : browser
# stb : stb
# update : update
# angus : angus
# poin : poin
# kirim : kirim
# zte : zte
# berubah : ubah
# pass : pass
# telkomdso : telkomdso
# pasword : pasword
# terimakasih : terimakasih
# tlpn : tlpn
# kerja : kerja
# robot : robot
# butuh : butuh
# pusat : pusat
# terganggu : ganggu
# kerjaan : kerja
# push : push
# rank : rank
# dri : dri
# bgini : bgini
# restar : restar
# perusahaan : usaha
# kasi : kasi
# kyk : kyk
# gni : gni
# jaringannya : jaring
# purus : purus
# gamepad : gamepad
# rexus : rexus
# gx : gx
# jenis : jenis
# kereen : kereen
# bermasalah : masalah
# lmao : lmao
# indikator : indikator
# gaada : gaada
# kantor : kantor
# kebakar : bakar
# hangus : hangus
# busuk : busuk
# smpi : smpi
# skrg : skrg
# kabarnya : kabar
# telat : telat
# putusin : putusin
# banyakin : banyakin
# promosi : promosi
# castamer : castamer
# undur : undur
# laporkan : lapor
# abis : abis
# speed : speed
# kereennn : kereennn
# jayaaa : jayaaa
# seumpamanya : umpama
# nambah : nambah
# kalel : kalel
# biaya : biaya
# permeternya : meter
# gagal : gagal
# turus : turus
# menghubungkan : hubung
# isolir : isolir
# bos : bos
# rugi : rugi
# fitur : fitur
# renew : renew
# lokasi : lokasi
# kota : kota
# pontianak : pontianak
# initinya : initinya
# suruh : suruh
# paket : paket
# dimna : dimna
# melambat : lambat
# permasalahan : masalah
# kunjung : kunjung
# selesai : selesai
# alesan : alesan
# perbaiki : baik
# sisi : sisi
# sentral : sentral
# kah : kah
# bukti : bukti
# sem : sem
# total : total
# bantuannya : bantu
# senior : senior
# trimakasih : trimakasih
# pusing : pusing
# mkin : mkin
# karywan : karywan
# lengkap : lengkap
# kode : kode
# otp : otp
# scpatnya : scpatnya
# dihub : dihub
# pengaktifan : aktif
# tlp : tlp
# indihomenya : indihomenya
# permohonan : mohon
# nda : nda
# modal : modal
# dilayani : layan
# harapan : harap
# palsu : palsu
# trik : trik
# makan : makan
# siang : siang
# gratis : gratis
# tersambung : sambung
# kerusakan : rusa
# otentifikasi : otentifikasi
# sped : sped
# demand : demand
# blank : blank
# memenuhi : penuh
# syarat : syarat
# melakuan : laku
# pembelian : beli
# nyalahin : nyalahin
# kambing : kambing
# saudara : saudara
# surat : surat
# juta : juta
# inbok : inbok
# balas : balas
# kaya : kaya
# pelayanannya : layan
# kecewa : kecewa
# kenape : kenape
# lihat : lihat
# penurunan : turun
# kecepatan : cepat
# estimasi : estimasi
# mantab : mantab
# mengalami : alami
# normal : normal
# pemakaian : pakai
# melebihi : lebih
# anak : anak
# you : you
# tube : tube
# libur : libur
# sekolah : sekolah
# taikan : taikan
# ugered : ugered
# pertanyaanya : pertanyaanya
# turunkan : turun
# seed : seed
# tlng : tlng
# dbantu : dbantu
# hilangkangkan : hilangkangkan
# tautan : taut
# krna : krna
# sdah : sdah
# tidk : tidk
# bkrja : bkrja
# ditmpat : ditmpat
# wohooo : wohooo
# sukses : sukses
# yaaaa : yaaaa
# berbagi : bagi
# inisih : inisih
# suka : suka
# lupa : lupa
# wii : wii
# miiin : miiin
# oke : oke
# keren : keren
# dahh : dahh
# alamat : alamat
# tindak : tindak
# miminnn : miminnn
# balass : balass
# migrasi : migrasi
# mengurangi : kurang
# bulanan : bulan
# desember : desember
# point : point
# siapp : siapp
# mojokerto : mojokerto
# magersari : magersari
# wates : wates
# dendaan : denda
# jt : jt
# permainan : main
# gausah : gausah
# ragu : ragu
# jaya : jaya
# terusssssss : terusssssss
# takutnya : takut
# berbulan : bulan
# lag : lag
# sebentar : sebentar
# macet : macet
# bantu : bantu
# dicek : cek
# mengajukan : aju
# cipayung : cipayung
# depok : depok
# tepatnya : tepat
# kecamatan : camat
# jatirejo : jatirejo
# trouble : trouble
# mhon : mhon
# pencerahanya : pencerahanya
# hallo : hallo
# kakak : kakak
# bsaa : bsaa
# minnnnnn : minnnnnn
# tengkyu : tengkyu
# tips : tips
# ngak : ngak
# adaa : adaa
# ahh : ahh
# pke : pke
# indiehome : indiehome
# layanannya : layan
# hubungi : hubung
# maaf : maaf
# waduuhhh : waduuhhh
# kmrn : kmrn
# gag : gag
# ketemu : ketemu
# nomor : nomor
# infonyaaa : infonyaaa
# isp : isp
# korup : korup
# serang : serang
# banten : banten
# seauai : seauai
# dengn : dengn
# sod : sod
# yaaa : yaaa
# inboxnya : inboxnya
# thank : thank
# uangnya : uang
# giliran : gilir
# teknisinya : teknisi
# mengecek : ecek
# kecurangan : curang
# kyak : kyak
# kaliii : kaliii
# dihati : hati
# deh : deh
# thanks : thanks
# cakep : cakep
# bahaya : bahaya
# bgtt : bgtt
# sekaliinfonya : sekaliinfonya
# ngingetin : ngingetin
# hati : hati
# profesional : profesional
# eksis : eks
# bersaing : saing
# sop : sop
# pengaduan : adu
# tahunan : tahun
# detik : detik
# andaikan : andai
# kidz : kidz
# zaman : zaman
# now : now
# betah : betah
# verifikasi : verifikasi
# sedih : sedih
# baffering : baffering
# maacih : maacih
# harga : harga
# nicie : nicie
# terbaru : baru
# logonya : logo
# diskon : diskon
# commerce : commerce
# smpe : smpe
# kibulin : kibulin
# oknum : oknum
# reguler : reguler
# lite : lite
# mah : mah
# php : php
# jawabannya : jawab
# ngawur : ngawur
# berasa : asa
# dejavu : dejavu
# ingetin : ingetin
# insyallah : insyallah
# knp : knp
# ms : ms
# support : support
# bwt : bwt
# terimaksih : terimaksih
# donwload : donwload
# dmna : dmna
# deposite : deposite
# soooo : soooo
# bad : bad
# loosing : loosing
# patience : patience
# since : since
# th : th
# december : december
# our : our
# customers : customers
# are : are
# really : really
# angry : angry
# and : and
# they : they
# ask : ask
# for : for
# refund : refund
# because : because
# there : there
# during : during
# christmas : christmas
# couldn : couldn
# speak : speak
# with : with
# their : their
# family : family
# penipuan : tipu
# digital : digital
# ditawarkan : tawar
# provider : provider
# sehari : hari
# kewajiban : wajib
# kacau : kacau
# detailnya : detail
# moho : moho
# anggap : anggap
# pala : pala
# kau : kau
# akal : akal
# akalan : akal
# jam : jam
# ngeri : ngeri
# mnc : mnc
# grup : grup
# gabung : gabung
# dupercepat : dupercepat
# erte : erte
# mesti : mesti
# kontak : kontak
# messenger : messenger
# balasan : balas
# berulang : ulang
# separah : parah
# after : after
# sales : sales
# indihom : indihom
# kumat : kumat
# habis : habis
# deras : deras
# auto : auto
# sehat : sehat
# kerasnya : keras
# permintaan : minta
# akses : akses
# ijo : ijo
# downgrade : downgrade
# only : only
# bales : bales
# waspadai : waspada
# dasar : dasar
# becus : becus
# semoga : moga
# membawa : bawa
# keberkahan : berkah
# lancarr : lancarr
# cnn : cnn
# channel : channel
# kids : kids
# movie : movie
# live : live
# berkali : kali
# bolak : bolak
# realisasinya : realisasi
# download : download
# dimana : mana
# wifine : wifine
# karmin : karmin
# hem : hem
# nnton : nnton
# liga : liga
# inggris : inggris
# klau : klau
# kecamtan : kecamtan
# malunda : malunda
# heleh : heleh
# bacot : bacot
# januari : januari
# pengurangan : kurang
# buka : buka
# bumn : bumn
# aman : aman
# tlg : tlg
# fup : fup
# untung : untung
# mnta : mnta
# pengajuan : aju
# pemutusan : putus
# isi : isi
# berita : berita
# acara : acara
# lunasi : lunas
# dtg : dtg
# mengambil : ambil
# perangkat : perangkat
# ditagihkan : tagih
# makasiii : makasiii
# tipsnya : tipsnya
# selamat : selamat
# happy : happy
# holiday : holiday
# saran : saran
# app : app
# useetvgo : useetvgo
# pilihan : pilih
# audio : audio
# siaran : siar
# dual : dual
# language : language
# bahasa : bahasa
# enak : enak
# dengernya : dengernya
# telpon : telpon
# mengaku : aku
# kirimkan : kirim
# beritahukan : beritahukan
# tanda : tanda
# pentung : pentung
# bang : bang
# unlimited : unlimited
# msih : msih
# adakah : ada
# ngsih : ngsih
# tindakan : tindak
# browsing : browsing
# menit : menit
# mala : mala
# pekerja : kerja
# indihomnya : indihomnya
# bantuan : bantu
# password : password
# donk : donk
# manis : manis
# berlanganan : berlanganan
# sulit : sulit
# bah : bah
# harganya : harga
# hdeeehh : hdeeehh
# oaky : oaky
# fix : fix
# berhenti : henti
# brlangganan : brlangganan
# kena : kena
# pinalti : pinalti
# byar : byar
# abonemen : abonemen
# genap : genap
# dmana : dmana
# menyaksikan : saksi
# tangal : tangal
# wahh : wahh
# jatu : jatu
# temp : temp
# visit : visit
# besok : besok
# tgg : tgg
# besoknya : besok
# malamnya : malam
# lagiiiii : lagiiiii
# sekitaran : sekitar
# setahu : tahu
# pengguna : guna
# mencapai : capai
# limit : limit
# kebijakan : bijak
# terkait : kait
# donkk : donkk
# menaikkan : naik
# bahasanya : bahasa
# tagihannyaaaaa : tagihannyaaaaa
# kannn : kannn
# mijn : mijn
# masal : masal
# sampek : sampek
# league : league
# legend : legend
# knpa : knpa
# upload : upload
# dibawa : bawa
# unduhnya : unduh
# diatas : atas
# waspada : waspada
# mu : mu
# dibuatin : dibuatin
# tiket : tiket
# direstart : direstart
# ditelpon : telpon
# beres : beres
# belommmmm : belommmmm
# capek : capek
# nutup : nutup
# wfh : wfh
# imbauannya : imbau
# {'min': 'min', 'wifi': 'wifi', 'hilang': 'hilang', 'modemnya': 'modem', 'nyala': 'nyala', 'sengaja': 'sengaja', 'komplain': 'komplain', 'chat': 'chat', 'bener': 'bener', 'responnya': 'responnya', 'login': 'login', 'keaplikasi': 'aplikasi', 'myindihome': 'myindihome', 'pilih': 'pilih', 'metode': 'metode', 'otentikasi': 'otentikasi', 'sms': 'sms', 'muncul': 'muncul', 'pesan': 'pesan', 'service': 'service', 'error': 'error', 'clear': 'clear', 'cache': 'cache', 'data': 'data', 'install': 'install', 'ulang': 'ulang', '': '', 'laporan': 'lapor', 'botnya': 'bot', 'nggk': 'nggk', 'ngerespon': 'ngerespon', 'gmn': 'gmn', 'makasih': 'makasih', 'infonya': 'info', 'bermanfaat': 'manfaat', 'bgttt': 'bgttt', 'kak': 'kak', 'cek': 'cek', 'tagihan': 'tagih', 'aplikasi': 'aplikasi', 'udah': 'udah', 'via': 'via', 'messanger': 'messanger', 'koneksi': 'koneksi', 'internet': 'internet', 'mati': 'mati', 'lampu': 'lampu', 'pon': 'pon', 'menyala': 'nyala', 'merah': 'merah', 'subuh': 'subuh', 'restart': 'restart', 'kali': 'kali', 'kabel': 'kabel', 'terpasang': 'pasang', 'gimana': 'gimana', 'modem': 'modem', 'zoom': 'zoom', 'meeting': 'meeting', 'aelaaah': 'aelaaah', 'putus': 'putus', 'nyambung': 'nyambung', 'mingguan': 'minggu', 'asyik': 'asyik', 'nonton': 'nonton', 'jaringan': 'jaring', 'mbps': 'mbps', 'dijam': 'jam', 'witeng': 'witeng', 'videinya': 'vide', 'lemot': 'lot', 'yahh': 'yahh', 'mohon': 'mohon', 'solusinya': 'solusi', 'wilayah': 'wilayah', 'ntt': 'ntt', 'mantap': 'mantap', 'eror': 'eror', 'kayak': 'kayak', 'hantu': 'hantu', 'gmna': 'gmna', 'perubahan': 'ubah', 'kmaren': 'kmaren', 'skarang': 'skarang', 'konfirmasi': 'konfirmasi', 'memberitahu': 'memberitahu', 'apapun': 'apa', 'telkom': 'telkom', 'sore': 'sore', 'inet': 'inet', 'stabil': 'stabil', 'skrang': 'skrang', 'infonyaa': 'infonyaa', 'byk': 'byk', 'mimin': 'mimin', 'gini': 'gin', 'yaa': 'yaa', 'ngga': 'ngga', 'loss': 'loss', 'tanggal': 'tanggal', 'november': 'november', 'gitu': 'gitu', 'gerus': 'gerus', 'inbox': 'inbox', 'respon': 'respon', 'bot': 'bot', 'indihome': 'indihome', 'tlong': 'tlong', 'dbntu': 'dbntu', 'masuk': 'masuk', 'aduuuhhhh': 'aduuuhhhh', 'kesel': 'kesel', 'sayaaaa': 'sayaaaa', 'bgmn': 'bgmn', 'membantu': 'bantu', 'banget': 'banget', 'wifinya': 'wifinya', 'lelet': 'lelet', 'konek': 'konek', 'down': 'down', 'thx': 'thx', 'informasinya': 'informasi', 'gada': 'gada', 'otak': 'otak', 'main': 'main', 'ping': 'ping', 'mulu': 'mulu', 'kirain': 'kirain', 'gua': 'gua', 'doang': 'doang', 'user': 'user', 'bagus': 'bagus', 'sungguh': 'sungguh', 'disayangkan': 'sayang', 'cuman': 'cuman', 'info': 'info', 'pelayanan': 'layan', 'layanan': 'layan', 'menganggap': 'anggap', 'sampah': 'sampah', 'keluhan': 'keluh', 'pelanggan': 'langgan', 'alasan': 'alas', 'logika': 'logika', 'mengada': 'ada', 'nice': 'nice', 'uang': 'uang', 'deposit': 'deposit', 'sya': 'sya', 'udh': 'udh', 'proses': 'proses', 'blum': 'blum', 'nemu': 'nemu', 'gajelas': 'gajelas', 'gaguna': 'gaguna', 'gapernah': 'gapernah', 'nuntasin': 'nuntasin', 'care': 'care', 'ngatasinnya': 'ngatasinnya', 'the': 'the', 'best': 'best', 'cmn': 'cmn', 'dpt': 'dpt', 'segini': 'gin', 'kemarin': 'kemarin', 'penuh': 'penuh', 'loading': 'loading', 'game': 'game', 'kayanya': 'kaya', 'jalan': 'jalan', 'stuck': 'stuck', 'hahah': 'hahah', 'well': 'well', 'played': 'played', 'bro': 'bro', 'sinyal': 'sinyal', 'bnget': 'bnget', 'llt': 'llt', 'keterangan': 'terang', 'tersedia': 'sedia', 'bayar': 'bayar', 'pasang': 'pasang', 'jaminan': 'jamin', 'thn': 'thn', 'kembalikan': 'kembali', 'potong': 'potong', 'pembayaran': 'bayar', 'msh': 'msh', 'segitu': 'segitu', 'otomatis': 'otomatis', 'merugikan': 'rugi', 'los': 'los', 'warna': 'warna', 'penangananya': 'penangananya', 'yayaya': 'yayaya', 'indi': 'indi', 'dimata': 'mata', 'gamer': 'gamer', 'upgrade': 'upgrade', 'pantesan': 'pantesan', 'langsung': 'langsung', 'terima': 'terima', 'kasih': 'kasih', 'tolonglah': 'tolong', 'tolong': 'tolong', 'customer': 'customer', 'dateng': 'dateng', 'teknisi': 'teknisi', 'dae ...
# ------------------------
# Pandas Apply:   0%|          | 0/347 [00:00<?, ?it/s]
#                                                comment  \
# 0    min ini kok wifi gw hilang, padahal modemnya n...
# 1    min, saat saya login keaplikasi myindihome dan...
# 2     ini mau buat laporan botnya nggk ngerespon gmn.?
# 3               makasih min, infonya bermanfaat bgttt.
# 4                kak, cek tagihan lewat aplikasi bisa?
# ..                                                 ...
# 379  min ni indihome sejak gangguan masal  sampek s...
# 381  min. knpa speed upload indihome dibawa 5 mbps ...
# 383  min kamu itu bilang waspada penipuan tp kamu s...
# 384      makasih indihome, wfh aku lancar sangat aman.
# 385  bener banget min! thank you imbauannya.  indihome
#
#                                       cleaning_comment  \
# 0    min ini kok wifi hilang padahal modemnya nyala...
# 1    min saat saya login keaplikasi myindihome dan ...
# 2      ini mau buat laporan botnya nggk ngerespon gmn
# 3                makasih min infonya bermanfaat bgttt
# 4                 kak cek tagihan lewat aplikasi bisa
# ..                                                 ...
# 379  min indihome sejak gangguan masal sampek sekar...
# 381  min knpa speed upload indihome dibawa mbps dim...
# 383  min kamu itu bilang waspada penipuan kamu send...
# 384       makasih indihome wfh aku lancar sangat aman
# 385     bener banget min thank you imbauannya indihome
#
#                                             tokenisasi  \
# 0    [min, ini, kok, wifi, hilang, padahal, modemny...
# 1    [min, saat, saya, login, keaplikasi, myindihom...
# 2    [ini, mau, buat, laporan, botnya, nggk, ngeres...
# 3         [makasih, min, infonya, bermanfaat, bgttt, ]
# 4         [kak, cek, tagihan, lewat, aplikasi, bisa, ]
# ..                                                 ...
# 379  [min, indihome, sejak, gangguan, masal, sampek...
# 381  [min, knpa, speed, upload, indihome, dibawa, m...
# 383  [min, kamu, itu, bilang, waspada, penipuan, ka...
# 384  [makasih, indihome, wfh, aku, lancar, sangat, ...
# 385  [bener, banget, min, thank, you, imbauannya, i...
#
#                                               stopword  \
# 0    [min, wifi, hilang, modemnya, nyala, sengaja, ...
# 1    [min, login, keaplikasi, myindihome, pilih, me...
# 2            [laporan, botnya, nggk, ngerespon, gmn, ]
# 3         [makasih, min, infonya, bermanfaat, bgttt, ]
# 4                      [kak, cek, tagihan, aplikasi, ]
# ..                                                 ...
# 379  [min, indihome, gangguan, masal, sampek, maen,...
# 381  [min, knpa, speed, upload, indihome, dibawa, m...
# 383  [min, waspada, penipuan, pelanggan, mu, dibuat...
# 384           [makasih, indihome, wfh, lancar, aman, ]
# 385  [bener, banget, min, thank, you, imbauannya, i...
#
#                                               stemming
# 0    [min, wifi, hilang, modem, nyala, sengaja, kom...
# 1    [min, login, aplikasi, myindihome, pilih, meto...
# 2                 [lapor, bot, nggk, ngerespon, gmn, ]
# 3               [makasih, min, info, manfaat, bgttt, ]
# 4                        [kak, cek, tagih, aplikasi, ]
# ..                                                 ...
# 379  [min, indihome, ganggu, masal, sampek, maen, g...
# 381  [min, knpa, speed, upload, indihome, bawa, mbp...
# 383  [min, waspada, tipu, langgan, mu, dibuatin, ti...
# 384           [makasih, indihome, wfh, lancar, aman, ]
# 385  [bener, banget, min, thank, you, imbau, indihome]
#
# [347 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [min, wifi, hilang, modem, nyala, sengaja, kom...
# 1    [min, login, aplikasi, myindihome, pilih, meto...
# 2                 [lapor, bot, nggk, ngerespon, gmn, ]
# 3               [makasih, min, info, manfaat, bgttt, ]
# 4                        [kak, cek, tagih, aplikasi, ]
# ..                                                 ...
# 379  [min, indihome, ganggu, masal, sampek, maen, g...
# 381  [min, knpa, speed, upload, indihome, bawa, mbp...
# 383  [min, waspada, tipu, langgan, mu, dibuatin, ti...
# 384           [makasih, indihome, wfh, lancar, aman, ]
# 385  [bener, banget, min, thank, you, imbau, indihome]
#
# [347 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_12.xlsx')
