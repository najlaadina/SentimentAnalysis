# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_4.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    Kecewa sama indihome,jaringan si rumh ku lemot...
# 2    Sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    Min, brp sebenarnya Fup 10 Mbps & 20 Mbps skrg...
# 4    Area Makassar jaringan rusak ....dari hari Jum...
# ..                                                 ...
# 336  Indihome bobrok terputus. Modemnya harus masuk...
# 337                      Indihome bobrok terputus lagi
# 338                                  nah ini tips lagi
# 339                                  nah ini tips lagi
# 340                      makin ngebut aja nih koneksi.
#
# [341 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 32

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    Kecewa sama indihome,jaringan si rumh ku lemot...
# 2    Sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    Min, brp sebenarnya Fup 10 Mbps & 20 Mbps skrg...
# 4    Area Makassar jaringan rusak ....dari hari Jum...
# ..                                                 ...
# 334  Suhu modem stabil dibahas, bahas tuh sistem ka...
# 335                                        oke minnnnn
# 336  Indihome bobrok terputus. Modemnya harus masuk...
# 337                      Indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi.
#
# [291 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    kecewa sama indihome,jaringan si rumh ku lemot...
# 2    sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    min, brp sebenarnya fup 10 mbps & 20 mbps skrg...
# 4    area makassar jaringan rusak ....dari hari jum...
# ..                                                 ...
# 334  suhu modem stabil dibahas, bahas tuh sistem ka...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus. modemnya harus masuk...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi.
#
# [291 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    kecewa sama indihome,jaringan si rumh ku lemot...
# 2    sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    min, brp sebenarnya fup 10 mbps & 20 mbps skrg...
# 4    area makassar jaringan rusak ....dari hari jum...
# ..                                                 ...
# 334  suhu modem stabil dibahas, bahas tuh sistem ka...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus. modemnya harus masuk...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi.
#
#                                       cleaning_comment
# 0    gimana yah jaringan saya ngga betul hehe tekni...
# 1     kecewa sama indihome jaringan rumh lemot sangat
# 2    sudah bln ada saja gangguan bulan lalu malah s...
# 3           min brp sebenarnya fup mbps mbps skrg ini
# 4    area makassar jaringan rusak dari hari jumat s...
# ..                                                 ...
# 334  suhu modem stabil dibahas bahas tuh sistem kam...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus modemnya harus masuk ...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi
#
# [291 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    kecewa sama indihome,jaringan si rumh ku lemot...
# 2    sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    min, brp sebenarnya fup 10 mbps & 20 mbps skrg...
# 4    area makassar jaringan rusak ....dari hari jum...
# ..                                                 ...
# 334  suhu modem stabil dibahas, bahas tuh sistem ka...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus. modemnya harus masuk...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi.
#
#                                       cleaning_comment  \
# 0    gimana yah jaringan saya ngga betul hehe tekni...
# 1     kecewa sama indihome jaringan rumh lemot sangat
# 2    sudah bln ada saja gangguan bulan lalu malah s...
# 3           min brp sebenarnya fup mbps mbps skrg ini
# 4    area makassar jaringan rusak dari hari jumat s...
# ..                                                 ...
# 334  suhu modem stabil dibahas bahas tuh sistem kam...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus modemnya harus masuk ...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi
#
#                                             tokenisasi
# 0    [gimana, yah, jaringan, saya, ngga, betul, heh...
# 1    [kecewa, sama, indihome, jaringan, rumh, lemot...
# 2    [sudah, bln, ada, saja, gangguan, bulan, lalu,...
# 3    [min, brp, sebenarnya, fup, mbps, mbps, skrg, ...
# 4    [area, makassar, jaringan, rusak, dari, hari, ...
# ..                                                 ...
# 334  [suhu, modem, stabil, dibahas, bahas, tuh, sis...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, terputus, modemnya, harus, ...
# 337                 [indihome, bobrok, terputus, lagi]
# 340               [makin, ngebut, aja, nih, koneksi, ]
#
# [291 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    kecewa sama indihome,jaringan si rumh ku lemot...
# 2    sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    min, brp sebenarnya fup 10 mbps & 20 mbps skrg...
# 4    area makassar jaringan rusak ....dari hari jum...
# ..                                                 ...
# 334  suhu modem stabil dibahas, bahas tuh sistem ka...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus. modemnya harus masuk...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi.
#
#                                       cleaning_comment  \
# 0    gimana yah jaringan saya ngga betul hehe tekni...
# 1     kecewa sama indihome jaringan rumh lemot sangat
# 2    sudah bln ada saja gangguan bulan lalu malah s...
# 3           min brp sebenarnya fup mbps mbps skrg ini
# 4    area makassar jaringan rusak dari hari jumat s...
# ..                                                 ...
# 334  suhu modem stabil dibahas bahas tuh sistem kam...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus modemnya harus masuk ...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi
#
#                                             tokenisasi  \
# 0    [gimana, yah, jaringan, saya, ngga, betul, heh...
# 1    [kecewa, sama, indihome, jaringan, rumh, lemot...
# 2    [sudah, bln, ada, saja, gangguan, bulan, lalu,...
# 3    [min, brp, sebenarnya, fup, mbps, mbps, skrg, ...
# 4    [area, makassar, jaringan, rusak, dari, hari, ...
# ..                                                 ...
# 334  [suhu, modem, stabil, dibahas, bahas, tuh, sis...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, terputus, modemnya, harus, ...
# 337                 [indihome, bobrok, terputus, lagi]
# 340               [makin, ngebut, aja, nih, koneksi, ]
#
#                                               stopword
# 0    [gimana, jaringan, ngga, teknisi, minggu, nama...
# 1          [kecewa, indihome, jaringan, rumh, lemot, ]
# 2    [bln, gangguan, gangguan, dlm, jelek, layanan,...
# 3                  [min, brp, fup, mbps, mbps, skrg, ]
# 4      [area, makassar, jaringan, rusak, jumat, bagus]
# ..                                                 ...
# 334  [suhu, modem, stabil, dibahas, bahas, sistem, ...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, terputus, modemnya, masuk, ...
# 337                       [indihome, bobrok, terputus]
# 340                                [ngebut, koneksi, ]
#
# [291 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 964
# ------------------------
# gimana : gimana
# jaringan : jaring
# ngga : ngga
# teknisi : teknisi
# minggu : minggu
# nama : nama
# kantor : kantor
# indihome : indihome
# helpdesk : helpdesk
# selesai : selesai
# heran : heran
# kecewa : kecewa
# rumh : rumh
# lemot : lot
#  :
# bln : bln
# gangguan : ganggu
# dlm : dlm
# jelek : jelek
# layanan : layan
# min : min
# brp : brp
# fup : fup
# mbps : mbps
# skrg : skrg
# area : area
# makassar : makassar
# rusak : rusak
# jumat : jumat
# bagus : bagus
# langganan : langgan
# mengecewakan : kecewa
# error : error
# siaran : siar
# tehnisi : tehnisi
# dtg : dtg
# mslh : mslh
# nyela : nyela
# disuruh : suruh
# tlp : tlp
# siapin : siapin
# pulsa : pulsa
# lambat : lambat
# responnya : responnya
# menguras : uras
# payah : payah
# lupa : lupa
# password : password
# coba : coba
# nomor : nomor
# masukan : masuk
# user : user
# admin : admin
# gabisa : gabisa
# eror : eror
# cek : cek
# inbok : inbok
# kak : kak
# tolong : tolong
# buatkan : buat
# tiket : tiket
# internet : internet
# terputus : putus
# bambu : bambu
# apus : apus
# progres : progres
# aman : aman
# dimasukan : masuk
# white : white
# list : list
# keluarga : keluarga
# terhubung : hubung
# wifi : wifi
# tsb : tsb
# validasi : validasi
# data : data
# daerah : daerah
# lgi : lgi
# bayar : bayar
# mah : mah
# tetep : tetep
# lanjuuuut : lanjuuuut
# in : in
# jam : jam
# konfirmasi : konfirmasi
# indihomecare : indihomecare
# ganti : ganti
# republic : republic
# zal : zal
# anteng : anteng
# lancar : lancar
# jaya : jaya
# useetv : useetv
# login : login
# android : android
# trus : trus
# diperangkatnya : perangkat
# lampu : lampu
# merah : merah
# gtu : gtu
# gmana : gmana
# yaa : yaa
# mengatasinya : atas
# kwalitas : kwalitas
# pelayanan : layan
# tingkatkan : tingkat
# dikit : dikit
# nyesel : nyesel
# langgangan : langgang
# stop : stop
# pinalty : pinalty
# blm : blm
# thn : thn
# menyesatkan : sesat
# customer : customer
# terimakasih : terimakasih
# inponya : inponya
# tipsnya : tipsnya
# nihh : nihh
# klw : klw
# putusin : putusin
# langanan : langanan
# tarif : tarif
# nyaaa : nyaaa
# pemakaian : pakai
# berkurang : kurang
# rumah : rumah
# tingal : tingal
# matraman : matraman
# raya : raya
# jakarta : jakarta
# timur : timur
# perbaikan : baik
# internetnya : internetnya
# sampe : sampe
# selasa : selasa
# los : los
# beli : beli
# kuota : kuota
# takut : takut
# lgsg : lgsg
# normal : normal
# sayang : sayang
# kuotanya : kuota
# nanya : nanya
# setting : setting
# dns : dns
# manual : manual
# windows : windows
# wahhh : wahhh
# bermanfaat : manfaat
# otw : otw
# henhg : henhg
# teruss : teruss
# bos : bos
# haurgeulis : haurgeulis
# indramayu : indramayu
# kah : kah
# subuh : subuh
# terima : terima
# kasih : kasih
# informasinya : informasi
# malam : malam
# minnn : minnn
# nanyaa : nanyaa
# mintol : mintol
# thanks : thanks
# dcek : dcek
# sharian : sharian
# akses : akses
# pertimbangkan : timbang
# berkali : kali
# iklan : iklan
# penuh : penuh
# complain : complain
# pahamkan : paham
# betapa : betapa
# buruknya : buruk
# manfaat : manfaat
# beneran : beneran
# deh : deh
# yaelah : yaelah
# kualitas : kualitas
# sinyal : sinyal
# bumn : bumn
# buruk : buruk
# nice : nice
# info : info
# mohon : mohon
# diperbaiki : baik
# tips : tips
# jitu : jitu
# ala : ala
# mantul : mantul
# shit : shit
# njir : njir
# putus : putus
# berlangganan : langgan
# terpasang : pasang
# dirumah : rumah
# wms : wms
# jaringannya : jaring
# komen : komen
# bantu : bantu
# barombong : barombong
# malem : malem
# halah : halah
# met : met
# pagi : pagi
# setip : setip
# lose : lose
# sprti : sprti
# pdhal : pdhal
# sya : sya
# rajin : rajin
# membayar : bayar
# melapor : lapor
# tpi : tpi
# tindakan : tindak
# pekerjaan : kerja
# jdi : jdi
# trhambat : trhambat
# upload : upload
# doang : doang
# reboot : reboot
# via : via
# web : web
# konek : konek
# mati : mati
# banget : banget
# boros : boros
# kabar : kabar
# pemasangan : pasang
# modem : modem
# gini : gin
# trs : trs
# udah : udah
# teknisinya : teknisi
# dtng : dtng
# tunggu : tunggu
# nggak : nggak
# permintaan : minta
# pindah : pindah
# respon : respon
# koneksi : koneksi
# pembayarannya : bayar
# bulannya : bulan
# selamat : selamat
# semoga : moga
# pelanggan : langgan
# kota : kota
# kupang : kupang
# ntt : ntt
# kompensasi : kompensasi
# kerusakan : rusa
# akibat : akibat
# badai : badai
# siklon : siklon
# seroja : seroja
# diakses : akses
# inbox : inbox
# bersedia : sedia
# ngomel : ngomel
# difb : difb
# eeeh : eeeh
# bingung : bingung
# cabut : cabut
# minipack : minipack
# indikorea : indikorea
# kendala : kendala
# nonaktifkan : nonaktif
# baca : baca
# mencari : cari
# akun : akun
# pengaturan : atur
# kereeen : kereeen
# news : news
# berita : berita
# terupdate : terupdate
# seminggu : minggu
# komfirmasi : komfirmasi
# bener : bener
# tanganinya : tangan
# hallo : hallo
# seamless : seamless
# maksimal : maksimal
# device : device
# bantuannya : bantu
# bang : bang
# indhihome : indhihome
# nga : nga
# kejadian : jadi
# cape : cape
# telp : telp
# massal : massal
# laporan : lapor
# diaplikasi : aplikasi
# myindihome : myindihome
# tks : tks
# mantep : mantep
# terkini : kini
# seputar : putar
# refresh : refresh
# aplikasi : aplikasi
# tertulis : tulis
# restarting : restarting
# the : the
# playing : playing
# content : content
# pasang : pasang
# wilayah : wilayah
# cirebon : cirebon
# kabupaten : kabupaten
# susah : susah
# petugas : tugas
# kadang : kadang
# menawarkan : tawar
# jasa : jasa
# swasta : swasta
# memasang : pasang
# antena : antena
# duh : duh
# indihomenya : indihomenya
# kerja : kerja
# online : online
# pengaduan : adu
# penyelesaian : selesai
# sod : sod
# kmren : kmren
# smpe : smpe
# indihom : indihom
# planggan : planggan
# bruk : bruk
# menyala : nyala
# keterangannya : terang
# tersambung : sambung
# mlm : mlm
# lakukan : laku
# penurunan : turun
# gb : gb
# pke : pke
# pket : pket
# intrnt : intrnt
# knpa : knpa
# cma : cma
# bsa : bsa
# intent : intent
# udh : udh
# byr : byr
# full : full
# pketnya : pketnya
# pndh : pndh
# internt : internt
# aduh : aduh
# mnggu : mnggu
# skrng : skrng
# tdj : tdj
# angin : angin
# petir : petir
# menyesal : sesal
# secepatnya : cepat
# ditempat : tempat
# mendaftar : daftar
# kabel : kabel
# ganggu : ganggu
# tetangga : tetangga
# ngak : ngak
# point : point
# kemampuan : mampu
# menugaskan : tugas
# maret : maret
# tagihan : tagih
# sistim : sistim
# bagaimna : bagaimna
# tag : tag
# conect : conect
# jln : jln
# mengajukan : aju
# upgrade : upgrade
# speed : speed
# direalisasikan : realisasi
# pelayanannya : layan
# persiapan : siap
# wfh : wfh
# add : add
# downgrade : downgrade
# estimasi : estimasi
# lapangan : lapang
# pengecekan : kece
# paket : paket
# telepon : telepon
# seandainya : anda
# migrasi : migrasi
# erorr : erorr
# telat : telat
# kemarin : kemarin
# mudah : mudah
# hindari : hindar
# janji : janji
# palsu : palsu
# mengatasnamakan : mengatasnamakan
# habis : habis
# update : update
# ota : ota
# tampilan : tampil
# menu : menu
# terbaru : baru
# pakai : pakai
# mouse : mouse
# klik : klik
# kiri : kiri
# mending : mending
# balikin : balikin
# org : org
# butuh : butuh
# kayak : kayak
# matot : matot
# parah : parah
# telpon : telpon
# mahal : mahal
# sehari : hari
# blum : blum
# penanganan : tangan
# siapp : siapp
# realisasix : realisasix
# biaya : biaya
# transfer : transfer
# follow : follow
# penanganannya : tangan
# kuntilanak : kuntilanak
# dipaksa : paksa
# aktif : aktif
# merugikan : rugi
# konsumen : konsumen
# rating : rating
# telkomsel : telkomsel
# ditinggalkan : tinggal
# indonesia : indonesia
# lapor : lapor
# indhomecare : indhomecare
# kerjanya : kerja
# cepat : cepat
# rugi : rugi
# hrs : hrs
# sdgkan : sdgkan
# berhenti : henti
# proses : proses
# penagihan : tagih
# berjalan : jalan
# membengkak : bengkak
# profesional : profesional
# melayani : layan
# masyarakat : masyarakat
# menagih : tagih
# menganggur : anggur
# knapa : knapa
# haduhhh : haduhhh
# pakainya : pakai
# sepulang : pulang
# diinbox : diinbox
# tanggapannya : tanggap
# cuman : cuman
# bot : bot
# mmbalas : mmbalas
# pesan : pesan
# realitas : realitas
# dilapangan : lapang
# super : super
# servisnya : servis
# jelex : jelex
# nyala : nyala
# hadeeh : hadeeh
# semenjak : semenjak
# kog : kog
# komputer : komputer
# lan : lan
# semarang : semarang
# good : good
# pungsi : pungsi
# komplen : komplen
# keluhan : keluh
# tanggapi : tanggap
# chat : chat
# fungsi : fungsi
# masak : masak
# iya : iya
# biarkan : biar
# perusahaan : usaha
# membiarkan : biar
# sekelas : kelas
# telkom : telkom
# merubah : rubah
# langsung : langsung
# meriset : riset
# terkoneksi : koneksi
# restar : restar
# kena : kena
# pohon : pohon
# tumbang : tumbang
# kunjung : kunjung
# beres : beres
# sore : sore
# kpan : kpan
# berea : berea
# lokasi : lokasi
# bandung : bandung
# sindanglaya : sindanglaya
# kedip : kedip
# nunggu : nunggu
# viral : viral
# tangani : tangan
# service : service
# kampret : kampret
# kau : kau
# miin : miin
# mengadukan : adu
# sebulan : bulan
# bantuan : bantu
# bisnis : bisnis
# kuo : kuo
# tekhisinya : tekhisinya
# action : action
# dateng : dateng
# ngerasain : ngerasain
# mulut : mulut
# adminnya : adminnya
# bulshit : bulshit
# menikmati : nikmat
# stb : stb
# versi : versi
# google : google
# certified : certified
# peruntukan : untuk
# mata : mata
# status : status
# membaya : baya
# pemastian : pasti
# kesal : kesal
# haii : hai
# angapusi : angapusi
# mbak : mbak
# kemaren : kemaren
# tgl : tgl
# katanua : katanua
# bonus : bonus
# channel : channel
# pilih : pilih
# movie : movie
# golive : golive
# indikator : indikator
# modemnya : modem
# muncul : muncul
# karesa : karesa
# profesionalnya : profesional
# pengertiannya : erti
# prof : prof
# ping : ping
# average : average
# suruh : suruh
# bernama : nama
# abi : abi
# kesini : kesini
# page : page
# sdr : sdr
# reset : reset
# segini : gin
# neh : neh
# giliran : gilir
# sblm : sblm
# tanggal : tanggal
# tlpn : tlpn
# favorit : favorit
# chanel : chanel
# tambahan : tambah
# blom : blom
# nikmati : nikmat
# rabu : rabu
# dpt : dpt
# brnefit : brnefit
# progress : progress
# vngst : vngst
# penhaduan : penhaduan
# balasnya : balas
# slowrespon : slowrespon
# router : router
# loss : loss
# apanya : apa
# dear : dear
# semalam : malam
# tidsk : tidsk
# balasan : balas
# diajuin : diajuin
# mb : mb
# diberhentikan : henti
# gratis : gratis
# renew : renew
# remote : remote
# balas : balas
# lelah : lelah
# boyar : boyar
# seng : seng
# omongi : omong
# jaringane : jaringane
# pedot : pedot
# openi : open
# cok : cok
# taunya : tau
# mebayar : mebayar
# denda : denda
# report : report
# tindak : tindak
# dapet : dapet
# ngegas : ngegas
# bukti : bukti
# addon : addon
# cloud : cloud
# kapok : kapok
# melaporkan : lapor
# permohonan : mohon
# billing : billing
# lepas : lepas
# pinda : pinda
# tulisan : tulis
# burukkkkkkkkk : burukkkkkkkkk
# dibayar : bayar
# lelet : lelet
# kali : kali
# ampun : ampun
# bah : bah
# berlanganan : berlanganan
# plasa : plasa
# trik : trik
# bohong : bohong
# ajaib : ajaib
# dikasi : kasi
# bego : bego
# ketulungan : ketulungan
# melebihkan : lebih
# batas : batas
# fub : fub
# bulanan : bulan
# knp : knp
# nda : nda
# jeblog : jeblog
# tempatku : tempat
# helppp : helppp
# kambuh : kambuh
# indie : indie
# home : home
# serasa : serasa
# optik : optik
# gsm : gsm
# kalah : kalah
# oprator : oprator
# tri : tri
# ngalamin : ngalamin
# sportif : sportif
# uang : uang
# deposit : deposit
# skq : skq
# kembalikan : kembali
# pengembalian : kembali
# rooter : rooter
# gerai : gerai
# grahapari : grahapari
# dinoyo : dinoyo
# surabaya : surabaya
# gagal : gagal
# restart : restart
# dipakai : pakai
# guys : guys
# mengalami : alami
# lho : lho
# terosss : terosss
# kontol : kontol
# memek : memek
# pepek : pepek
# kentod : kentod
# anak : anak
# ajg : ajg
# kntod : kntod
# babi : babi
# asw : asw
# hai : hai
# sobat : sobat
# berinteraksi : interaksi
# official : official
# mempercepat : cepat
# lengkapi : lengkap
# kvgmc : kvgmc
# enak : enak
# main : main
# padam : padam
# total : total
# bawa : bawa
# motor : motor
# isi : isi
# minyak : minyak
# lost : lost
# respons : respons
# indiohme : indiohme
# bolak : bolak
# hidup : hidup
# berjam : jam
# hilang : hilang
# layar : layar
# smartphone : smartphone
# perbaiki : baik
# memuat : muat
# wfi : wfi
# warkop : warkop
# macet : macet
# superlelet : superlelet
# ditandai : tanda
# jaringa : jaringa
# bobrok : bobrok
# dengar : dengar
# spotify : spotify
# hadeh : hadeh
# biarpun : biarpun
# menit : menit
# download : download
# failed : failed
# sinyalnya : sinyal
# dodol : dodol
# melulu : melulu
# nonton : nonton
# waoow : waoow
# mantaapp : mantaapp
# miminnn : miminnn
# siang : siang
# momentum : momentum
# tinggal : tinggal
# hitung : hitung
# cafe : cafe
# warung : warung
# dipidie : dipidie
# kacau : kacau
# slang : slang
# dilayarnya : layar
# panas : panas
# smartphonenya : smartphonenya
# munculnya : muncul
# rutin : rutin
# balau : balau
# penyakit : sakit
# sibuk : sibuk
# mengejar : kejar
# omzet : omzet
# target : target
# pemasukan : pasu
# tagihannya : tagih
# jaringanya : jaringanya
# diblokir : blokir
# keluluhan : luluh
# buka : buka
# ulang : ulang
# tulisannya : tulis
# ditanggapi : tanggap
# kode : kode
# otp : otp
# salah : salah
# hadeehh : hadeehh
# menolaknya : tolak
# april : april
# terbayar : bayar
# solusinya : solusi
# aneh : aneh
# masuk : masuk
# beda : beda
# rb : rb
# temen : temen
# senasib : nasib
# dana : dana
# refund : refund
# tanggapan : tanggap
# sesuai : sesuai
# ngadi : ngadi
# provider : provider
# nambah : nambah
# mengaksesnya : akses
# dibuka : buka
# gambar : gambar
# aplikasnya : aplikasnya
# jawabannya : jawab
# merespons : respons
# membukanya : buka
# menunggu : tunggu
# meresponsnya : respons
# layanannya : layan
# gmn : gmn
# ohhhh : ohhhh
# ternyataaaaa : ternyataaaaa
# tobat : tobat
# gua : gua
# jalan : jalan
# tanggung : tanggung
# berhari : hari
# cctv : cctv
# offline : offline
# setahun : tahun
# dinihari : dinihari
# shutdown : shutdown
# bedanya : beda
# nomer : nomer
# berat : berat
# sebentar : sebentar
# barang : barang
# pengiriman : kirim
# signifikan : signifikan
# menagihnya : tagih
# menjelang : jelang
# akhit : akhit
# aksesnya : akses
# tersendat : sendat
# omong : omong
# kosong : kosong
# kabelnya : kabel
# nglewer : nglewer
# gang : gang
# gor : gor
# wonokusumo : wonokusumo
# mojosari : mojosari
# perihal : perihal
# tiang : tiang
# odp : odp
# kelanjutannya : lanjut
# busuk : busuk
# sabtu : sabtu
# suda : suda
# komplain : komplain
# twitter : twitter
# email : email
# hasilnya : hasil
# tipu : tipu
# daya : daya
# you : you
# should : should
# show : show
# more : more
# realistic : realistic
# portrait : portrait
# what : what
# like : like
# your : your
# they : they
# look : look
# angry : angry
# that : that
# have : have
# use : use
# mobile : mobile
# credit : credit
# access : access
# because : because
# are : are
# failing : failing
# provide : provide
# broadband : broadband
# fiber : fiber
# paying : paying
# for : for
# kenap : kenap
# stabil : stabil
# semangat : semangat
# bismillah : bismillah
# tabe : tabe
# dilunasi : lunas
# putar : putar
# jadwal : jadwal
# kepakai : pakai
# iniii : iniii
# promo : promo
# ketentuan : tentu
# ragu : ragu
# care : care
# inboxxx : inboxxx
# ganguan : ganguan
# mantapsss : mantapsss
# patut : patut
# renewspeed : renewspeed
# block : block
# bobol : bobol
# terhormat : hormat
# maaf : maaf
# dirmh : dirmh
# dri : dri
# tnggal : tnggal
# smpai : smpai
# diperbaki : baki
# pas : pas
# pembayaran : bayar
# laporkan : lapor
# plaza : plaza
# ditulis : tulis
# dikrtas : dikrtas
# mempe : mempe
# kalay : kalay
# namanya : nama
# wajar : wajar
# post : post
# isinya : isi
# mih : mih
# pelangan : pelang
# diselesaikan : selesai
# dibantu : bantu
# menambah : tambah
# titik : titik
# hubungi : hubung
# witel : witel
# hub : hub
# followup : followup
# halo : halo
# link : link
# ramadan : ramadan
# dingin : dingin
# berkarat : karat
# efek : efek
# brengsek : brengsek
# liat : liat
# ribet : ribet
# loding : loding
# laptop : laptop
# solusi : solusi
# gimna : gimna
# muter : muter
# messenger : messenger
# suara : suara
# lihat : lihat
# perasaan : asa
# tertimpa : timpa
# bencana : bencana
# minn : minn
# sayan : sayan
# daftar : daftar
# malh : malh
# moban : mob
# kakak : kakak
# tdi : tdi
# pemeliharaan : pelihara
# ktnya : ktnya
# dimana : mana
# hilangkan : hilang
# monitoring : monitoring
# tools : tools
# suhunya : suhu
# kereen : kereen
# benering : benering
# goblok : goblok
# kaaa : kaaa
# mantepp : mantepp
# force : force
# close : close
# mulu : mulu
# suhu : suhu
# dibahas : bahas
# bahas : bahas
# sistem : sistem
# amburadul : amburadul
# tensi : tensi
# oke : oke
# minnnnn : minnnnn
# freezer : freezer
# ngebut : ngebut
# {'gimana': 'gimana', 'jaringan': 'jaring', 'ngga': 'ngga', 'teknisi': 'teknisi', 'minggu': 'minggu', 'nama': 'nama', 'kantor': 'kantor', 'indihome': 'indihome', 'helpdesk': 'helpdesk', 'selesai': 'selesai', 'heran': 'heran', 'kecewa': 'kecewa', 'rumh': 'rumh', 'lemot': 'lot', '': '', 'bln': 'bln', 'gangguan': 'ganggu', 'dlm': 'dlm', 'jelek': 'jelek', 'layanan': 'layan', 'min': 'min', 'brp': 'brp', 'fup': 'fup', 'mbps': 'mbps', 'skrg': 'skrg', 'area': 'area', 'makassar': 'makassar', 'rusak': 'rusak', 'jumat': 'jumat', 'bagus': 'bagus', 'langganan': 'langgan', 'mengecewakan': 'kecewa', 'error': 'error', 'siaran': 'siar', 'tehnisi': 'tehnisi', 'dtg': 'dtg', 'mslh': 'mslh', 'nyela': 'nyela', 'disuruh': 'suruh', 'tlp': 'tlp', 'siapin': 'siapin', 'pulsa': 'pulsa', 'lambat': 'lambat', 'responnya': 'responnya', 'menguras': 'uras', 'payah': 'payah', 'lupa': 'lupa', 'password': 'password', 'coba': 'coba', 'nomor': 'nomor', 'masukan': 'masuk', 'user': 'user', 'admin': 'admin', 'gabisa': 'gabisa', 'eror': 'eror', 'cek': 'cek', 'inbok': 'inbok', 'kak': 'kak', 'tolong': 'tolong', 'buatkan': 'buat', 'tiket': 'tiket', 'internet': 'internet', 'terputus': 'putus', 'bambu': 'bambu', 'apus': 'apus', 'progres': 'progres', 'aman': 'aman', 'dimasukan': 'masuk', 'white': 'white', 'list': 'list', 'keluarga': 'keluarga', 'terhubung': 'hubung', 'wifi': 'wifi', 'tsb': 'tsb', 'validasi': 'validasi', 'data': 'data', 'daerah': 'daerah', 'lgi': 'lgi', 'bayar': 'bayar', 'mah': 'mah', 'tetep': 'tetep', 'lanjuuuut': 'lanjuuuut', 'in': 'in', 'jam': 'jam', 'konfirmasi': 'konfirmasi', 'indihomecare': 'indihomecare', 'ganti': 'ganti', 'republic': 'republic', 'zal': 'zal', 'anteng': 'anteng', 'lancar': 'lancar', 'jaya': 'jaya', 'useetv': 'useetv', 'login': 'login', 'android': 'android', 'trus': 'trus', 'diperangkatnya': 'perangkat', 'lampu': 'lampu', 'merah': 'merah', 'gtu': 'gtu', 'gmana': 'gmana', 'yaa': 'yaa', 'mengatasinya': 'atas', 'kwalitas': 'kwalitas', 'pelayanan': 'layan', 'tingkatkan': 'tingkat', 'dikit': 'dikit', 'nyesel': 'nyesel', 'langgangan': 'langgang', 'stop': 'stop', 'pinalty': 'pinalty', 'blm': 'blm', 'thn': 'thn', 'menyesatkan': 'sesat', 'customer': 'customer', 'terimakasih': 'terimakasih', 'inponya': 'inponya', 'tipsnya': 'tipsnya', 'nihh': 'nihh', 'klw': 'klw', 'putusin': 'putusin', 'langanan': 'langanan', 'tarif': 'tarif', 'nyaaa': 'nyaaa', 'pemakaian': 'pakai', 'berkurang': 'kurang', 'rumah': 'rumah', 'tingal': 'tingal', 'matraman': 'matraman', 'raya': 'raya', 'jakarta': 'jakarta', 'timur': 'timur', 'perbaikan': 'baik', 'internetnya': 'internetnya', 'sampe': 'sampe', 'selasa': 'selasa', 'los': 'los', 'beli': 'beli', 'kuota': 'kuota', 'takut': 'takut', 'lgsg': 'lgsg', 'normal': 'normal', 'sayang': 'sayang', 'kuotanya': 'kuota', 'nanya': 'nanya', 'setting': 'setting', 'dns': 'dns', 'manual': 'manual', 'windows': 'windows', 'wahhh': 'wahhh', 'bermanfaat': 'manfaat', 'otw': 'otw', 'henhg': 'henhg', 'teruss': 'teruss', 'bos': 'bos', 'haurgeulis': 'haurgeulis', 'indramayu': 'indramayu', 'kah': 'kah', 'subuh': 'subuh', 'terima': 'terima', 'kasih': 'kasih', 'informasinya': 'informasi', 'malam': 'malam', 'minnn': 'minnn', 'nanyaa': 'nanyaa', 'mintol': 'mintol', 'thanks': 'thanks', 'dcek': 'dcek', 'sharian': 'sharian', 'akses': 'akses', 'pertimbangkan': 'timbang', 'berkali': 'kali', 'iklan': 'iklan', 'penuh': 'penuh', 'complain': 'complain', 'pahamkan': 'paham', 'betapa': 'betapa', 'buruknya': 'buruk', 'manfaat': 'manfaat', 'beneran': 'beneran', 'deh': 'deh', 'yaelah': 'yaelah', 'kualitas': 'kualitas', 'sinyal': 'sinyal', 'bumn': 'bumn', 'buruk': 'buruk', 'nice': 'nice', 'info': 'info', 'mohon': 'mohon', 'diperbaiki': 'baik', 'tips': 'tips', 'jitu': 'jitu', 'ala': 'ala', 'mantul': 'mantul', 'shit': 'shit', 'njir': 'njir', 'putus': 'putus', 'berlangganan': 'langgan', 'terpasang': 'pasang', 'dirumah': 'rumah', 'wms': 'wms', 'jaringannya': 'jaring', 'komen': 'komen', 'bantu': 'bantu', 'barombong': 'barombong', 'malem': 'malem', 'halah': 'halah', 'met': 'm ...
# ------------------------
# Pandas Apply:   0%|          | 0/291 [00:00<?, ?it/s]
#                                                comment  \
# 0    gimana yah jaringan saya ngga betul'' hehe,tek...
# 1    kecewa sama indihome,jaringan si rumh ku lemot...
# 2    sudah 4 bln ada saja gangguan .. bulan lalu ma...
# 3    min, brp sebenarnya fup 10 mbps & 20 mbps skrg...
# 4    area makassar jaringan rusak ....dari hari jum...
# ..                                                 ...
# 334  suhu modem stabil dibahas, bahas tuh sistem ka...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus. modemnya harus masuk...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi.
#
#                                       cleaning_comment  \
# 0    gimana yah jaringan saya ngga betul hehe tekni...
# 1     kecewa sama indihome jaringan rumh lemot sangat
# 2    sudah bln ada saja gangguan bulan lalu malah s...
# 3           min brp sebenarnya fup mbps mbps skrg ini
# 4    area makassar jaringan rusak dari hari jumat s...
# ..                                                 ...
# 334  suhu modem stabil dibahas bahas tuh sistem kam...
# 335                                        oke minnnnn
# 336  indihome bobrok terputus modemnya harus masuk ...
# 337                      indihome bobrok terputus lagi
# 340                      makin ngebut aja nih koneksi
#
#                                             tokenisasi  \
# 0    [gimana, yah, jaringan, saya, ngga, betul, heh...
# 1    [kecewa, sama, indihome, jaringan, rumh, lemot...
# 2    [sudah, bln, ada, saja, gangguan, bulan, lalu,...
# 3    [min, brp, sebenarnya, fup, mbps, mbps, skrg, ...
# 4    [area, makassar, jaringan, rusak, dari, hari, ...
# ..                                                 ...
# 334  [suhu, modem, stabil, dibahas, bahas, tuh, sis...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, terputus, modemnya, harus, ...
# 337                 [indihome, bobrok, terputus, lagi]
# 340               [makin, ngebut, aja, nih, koneksi, ]
#
#                                               stopword  \
# 0    [gimana, jaringan, ngga, teknisi, minggu, nama...
# 1          [kecewa, indihome, jaringan, rumh, lemot, ]
# 2    [bln, gangguan, gangguan, dlm, jelek, layanan,...
# 3                  [min, brp, fup, mbps, mbps, skrg, ]
# 4      [area, makassar, jaringan, rusak, jumat, bagus]
# ..                                                 ...
# 334  [suhu, modem, stabil, dibahas, bahas, sistem, ...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, terputus, modemnya, masuk, ...
# 337                       [indihome, bobrok, terputus]
# 340                                [ngebut, koneksi, ]
#
#                                               stemming
# 0    [gimana, jaring, ngga, teknisi, minggu, nama, ...
# 1              [kecewa, indihome, jaring, rumh, lot, ]
# 2    [bln, ganggu, ganggu, dlm, jelek, layan, indih...
# 3                  [min, brp, fup, mbps, mbps, skrg, ]
# 4        [area, makassar, jaring, rusak, jumat, bagus]
# ..                                                 ...
# 334  [suhu, modem, stabil, bahas, bahas, sistem, sa...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, putus, modem, masuk, freeze...
# 337                          [indihome, bobrok, putus]
# 340                                [ngebut, koneksi, ]
#
# [291 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [gimana, jaring, ngga, teknisi, minggu, nama, ...
# 1              [kecewa, indihome, jaring, rumh, lot, ]
# 2    [bln, ganggu, ganggu, dlm, jelek, layan, indih...
# 3                  [min, brp, fup, mbps, mbps, skrg, ]
# 4        [area, makassar, jaring, rusak, jumat, bagus]
# ..                                                 ...
# 334  [suhu, modem, stabil, bahas, bahas, sistem, sa...
# 335                                     [oke, minnnnn]
# 336  [indihome, bobrok, putus, modem, masuk, freeze...
# 337                          [indihome, bobrok, putus]
# 340                                [ngebut, koneksi, ]
#
# [291 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_4.xlsx')
