# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_2.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Halo kak, barusan saya dapat telp daro 1500620...
# 1    Padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    Halo kak, kemaren wifi copot terus saya pasang...
# 4                                                  NaN
# ..                                                 ...
# 222  kenapa kok layanan OTT Disney Plus Hotstar bel...
# 223  Admin. Maaf kok setelah update aplikasi My Ind...
# 224  Pakai IndiHome jaringan lancar jaya dan aman t...
# 225                                       152435909529
# 226                                       152458201494
#
# [227 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 48

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Halo kak, barusan saya dapat telp daro 1500620...
# 1    Padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    Halo kak, kemaren wifi copot terus saya pasang...
# 5                                       Lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan OTT Disney Plus Hotstar bel...
# 223  Admin. Maaf kok setelah update aplikasi My Ind...
# 224  Pakai IndiHome jaringan lancar jaya dan aman t...
# 225                                       152435909529
# 226                                       152458201494
#
# [140 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    halo kak, barusan saya dapat telp daro 1500620...
# 1    padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak, kemaren wifi copot terus saya pasang...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin. maaf kok setelah update aplikasi my ind...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                NaN
# 226                                                NaN
#
# [140 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    halo kak, barusan saya dapat telp daro 1500620...
# 1    padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak, kemaren wifi copot terus saya pasang...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin. maaf kok setelah update aplikasi my ind...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                NaN
# 226                                                NaN
#
#                                       cleaning_comment
# 0    halo kak barusan saya dapat telp daro   konfir...
# 1    padahal mau bayar tagihan mlh gangguan mulu ud...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak kemaren wifi copot terus saya pasang ...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin maaf kok setelah update aplikasi indihom...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                nan
# 226                                                nan
#
# [140 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    halo kak, barusan saya dapat telp daro 1500620...
# 1    padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak, kemaren wifi copot terus saya pasang...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin. maaf kok setelah update aplikasi my ind...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                NaN
# 226                                                NaN
#
#                                       cleaning_comment  \
# 0    halo kak barusan saya dapat telp daro   konfir...
# 1    padahal mau bayar tagihan mlh gangguan mulu ud...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak kemaren wifi copot terus saya pasang ...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin maaf kok setelah update aplikasi indihom...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                nan
# 226                                                nan
#
#                                             tokenisasi
# 0    [halo, kak, barusan, saya, dapat, telp, daro, ...
# 1    [padahal, mau, bayar, tagihan, mlh, gangguan, ...
# 2    [caranya, gimana, kalau, lupa, paswoord, dan, ...
# 3    [halo, kak, kemaren, wifi, copot, terus, saya,...
# 5                                    [lapor, gangguan]
# ..                                                 ...
# 222  [kenapa, kok, layanan, ott, disney, plus, hots...
# 223  [admin, maaf, kok, setelah, update, aplikasi, ...
# 224  [pakai, indihome, jaringan, lancar, jaya, dan,...
# 225                                              [nan]
# 226                                              [nan]
#
# [140 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    halo kak, barusan saya dapat telp daro 1500620...
# 1    padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak, kemaren wifi copot terus saya pasang...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin. maaf kok setelah update aplikasi my ind...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                NaN
# 226                                                NaN
#
#                                       cleaning_comment  \
# 0    halo kak barusan saya dapat telp daro   konfir...
# 1    padahal mau bayar tagihan mlh gangguan mulu ud...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak kemaren wifi copot terus saya pasang ...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin maaf kok setelah update aplikasi indihom...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                nan
# 226                                                nan
#
#                                             tokenisasi  \
# 0    [halo, kak, barusan, saya, dapat, telp, daro, ...
# 1    [padahal, mau, bayar, tagihan, mlh, gangguan, ...
# 2    [caranya, gimana, kalau, lupa, paswoord, dan, ...
# 3    [halo, kak, kemaren, wifi, copot, terus, saya,...
# 5                                    [lapor, gangguan]
# ..                                                 ...
# 222  [kenapa, kok, layanan, ott, disney, plus, hots...
# 223  [admin, maaf, kok, setelah, update, aplikasi, ...
# 224  [pakai, indihome, jaringan, lancar, jaya, dan,...
# 225                                              [nan]
# 226                                              [nan]
#
#                                               stopword
# 0    [halo, kak, barusan, telp, daro, konfirmasi, d...
# 1    [bayar, tagihan, mlh, gangguan, mulu, udh, kal...
# 2        [gimana, lupa, paswoord, nama, pengguna, stb]
# 3    [halo, kak, kemaren, wifi, copot, pasang, jala...
# 5                                    [lapor, gangguan]
# ..                                                 ...
# 222  [layanan, ott, disney, plus, hotstar, aktifkan...
# 223  [admin, maaf, update, aplikasi, indihome, masu...
# 224  [pakai, indihome, jaringan, lancar, jaya, aman...
# 225                                                 []
# 226                                                 []
#
# [140 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 481
# ------------------------
# halo : halo
# kak : kak
# barusan : barusan
# telp : telp
# daro : daro
# konfirmasi : konfirmasi
# data : data
# pelanggan : langgan
# registrasi : registrasi
# email : email
# salah : salah
# billing : billing
# pembayaran : bayar
# diemail : email
# emailnya : email
# gimana : gimana
# wifi : wifi
# nyala : nyala
# udah : udah
# seminggu : minggu
# pasang : pasang
# aktif : aktif
# tolong : tolong
# dibantu : bantu
# yaaa : yaaa
# bayar : bayar
# tagihan : tagih
# mlh : mlh
# gangguan : ganggu
# mulu : mulu
# udh : udh
# kali : kali
# jaringan : jaring
# los : los
# trs : trs
# lupa : lupa
# paswoord : paswoord
# nama : nama
# pengguna : guna
# stb : stb
# kemaren : kemaren
# copot : copot
# jalan : jalan
# muncul : muncul
# lampu : lampu
# merah : merah
# tuuh : tuuh
# benerinx : benerinx
#  :
# lapor : lapor
# pagi : pagi
# tulisan : tulis
# lampunya : lampu
# koneksinya : koneksi
# makasih : makasih
# min : min
# tips : tips
# bagus : bagus
# mantap : mantap
# tipsnya : tipsnya
# coba : coba
# kirain : kirain
# unlock : unlock
# channel : channel
# useetv : useetv
# imlek : imlek
# lock : lock
# alamat : alamat
# link : link
# blom : blom
# masuk : masuk
# pdhal : pdhal
# jam : jam
# siang : siang
# ditelpon : telpon
# telkom : telkom
# adukan : adu
# dlm : dlm
# kecewa : kecewa
# perbaiki : baik
# betah : betah
# dirumah : rumah
# deh : deh
# internetnya : internetnya
# lancar : lancar
# parah : parah
# seneng : neng
# banget : banget
# dpt : dpt
# bermanfaat : manfaat
# mimin : mimin
# keren : keren
# mantul : mantul
# indihome : indihome
# kirim : kirim
# gambar : gambar
# via : via
# whatsapp : whatsapp
# meresahkan : resah
# diganti : ganti
# dibobol : bobol
# tetangga : tetangga
# ganti : ganti
# cuapek : cuapek
# trobel : trobel
# internet : internet
# haloo : haloo
# refresh : refresh
# sistem : sistem
# skrg : skrg
# lelet : lelet
# ulang : ulang
# iini : iini
# disuruh : suruh
# sabar : sabar
# antri : antri
# perbaikan : baik
# teknisi : teknisi
# iya : iya
# selesai : selesai
# ngaco : ngaco
# profesional : profesional
# org : org
# layanan : layan
# emang : emang
# terkenal : kenal
# super : super
# duper : duper
# jelek : jelek
# komplen : komplen
# laporan : lapor
# telepon : telepon
# msh : msh
# terima : terima
# telat : telat
# pemberitahuan : pemberitahuan
# panggilan : panggil
# terblokir : blokir
# terisolir : isolir
# terlambat : lambat
# dibuka : buka
# tunggu : tunggu
# menit : menit
# modem : modem
# direstart : direstart
# nunggu : nunggu
# sampe : sampe
# jaman : jaman
# berkali : kali
# tetep : tetep
# blm : blm
# hadeuuhh : hadeuuhh
# bener : bener
# memuaskan : muas
# berhenti : henti
# berlangganan : langgan
# hariii : hariii
# martpura : martpura
# kalsel : kalsel
# kmn : kmn
# spy : spy
# diperbaiki : baik
# messenger : messenger
# dsruh : dsruh
# gini : gin
# smpai : smpai
# kiamat : kiamat
# maaf : maaf
# renewe : renewe
# speed : speed
# hapus : hapus
# butuh : butuh
# adik : adik
# kakak : kakak
# custemer : custemer
# provider : provider
# trimakasih : trimakasih
# kota : kota
# tanjungbalai : tanjungbalai
# provinsi : provinsi
# sumatera : sumatera
# utara : utara
# susah : susah
# putus : putus
# mohon : mohon
# perbaikannya : baik
# dipercepat : cepat
# kesini : kesini
# mengecewakan : kecewa
# bngt : bngt
# hahaha : hahaha
# mbps : mbps
# langganan : langgan
# segitu : segitu
# malam : malam
# menyabut : sabut
# kabel : kabel
# tiang : tiang
# dipersulit : sulit
# selamat : selamat
# terlayani : layan
# bantuanya : bantuanya
# hasan : hasan
# basri : basri
# kasih : kasih
# fokus : fokus
# menangani : tangan
# merugikan : rugi
# konsumen : konsumen
# koment : koment
# kbanyakan : kbanyakan
# keluhan : keluh
# gua : gua
# inbox : inbox
# jga : jga
# blum : blum
# respon : respon
# sma : sma
# payahhh : payahhh
# marak : marak
# kaya : kaya
# dapet : dapet
# mah : mah
# insyaallah : insyaallah
# aware : aware
# for : for
# daftar : daftar
# pemasangan : pasang
# dipasang : pasang
# teknisinya : teknisi
# full : full
# diregistrasi : registrasi
# solusi : solusi
# download : download
# aplikasi : aplikasi
# indhome : indhome
# cek : cek
# dmn : dmn
# downloadnya : downloadnya
# dri : dri
# kelar : kelar
# ngapa : ngapa
# njir : njir
# chanel : chanel
# main : main
# game : game
# pribadi : pribadi
# jaringanya : jaringanya
# ancur : ancur
# nihh : nihh
# pengaduan : adu
# tanggapan : tanggap
# nomor : nomor
# sdah : sdah
# dpat : dpat
# tpi : tpi
# tindaklanjut : tindaklanjut
# smp : smp
# virus : virus
# mantep : mantep
# intenetnya : intenetnya
# sulusinya : sulusinya
# seamles : seamles
# device : device
# top : top
# gampang : gampang
# ampe : ampe
# jaringannya : jaring
# akses : akses
# orang : orang
# batam : batam
# nyampenya : nyampenya
# nihhh : nihhh
# sehari : hari
# kena : kena
# denda : denda
# mati : mati
# reaksinya : reaksi
# nanya : nanya
# membayar : bayar
# paket : paket
# brp : brp
# hrs : hrs
# dapatkan : dapat
# lemot : lot
# kendala : kendala
# normal : normal
# berguna : guna
# nyaman : nyaman
# stabil : stabil
# kerjaan : kerja
# terganggu : ganggu
# stress : stress
# karna : karna
# beli : beli
# simple : simple
# ribet : ribet
# thanks : thanks
# informasinya : informasi
# info : info
# otw : otw
# hehehe : hehehe
# nice : nice
# tipsss : tipsss
# inbok : inbok
# mamen : mamen
# melapor : lapor
# kemarin : kemarin
# dateng : dateng
# sni : sni
# pakai : pakai
# rugi : rugi
# kuota : kuota
# gara : gara
# tergitung : tergitung
# siaran : siar
# televisinya : televisi
# datengi : datengi
# ktnya : ktnya
# secepatnya : cepat
# ngirim : ngirim
# ngga : ngga
# smua : smua
# anak : anak
# belajar : ajar
# online : online
# cut : cut
# catchplay : catchplay
# molatv : molatv
# vidio : vidio
# diinstall : diinstall
# sungguh : sungguh
# php : php
# pel : pel
# kebangetan : banget
# janji : janji
# kondisi : kondisi
# ekonomi : ekonomi
# sulit : sulit
# biaya : biaya
# inet : inet
# error : error
# ikutin : ikutin
# kerja : kerja
# hadeh : hadeh
# pembaharuan : baharu
# koneksi : koneksi
# maksimal : maksimal
# tanggal : tanggal
# mola : mola
# youtobe : youtobe
# isi : isi
# kolom : kolom
# komen : komen
# komplain : komplain
# kostumer : kostumer
# singapuranya : singapuranya
# server : server
# cob : cob
# binggung : binggung
# bahasa : bahasa
# bermasalahnya : masalah
# nnti : nnti
# aktifnya : aktif
# pas : pas
# sialan : sial
# kabelnya : kabel
# sia : sia
# indhihome : indhihome
# jlk : jlk
# pdhl : pdhl
# buka : buka
# muter : muter
# trus : trus
# bagak : bagak
# knp : knp
# jumat : jumat
# mlam : mlam
# smpe : smpe
# sabtu : sabtu
# sinyal : sinyal
# telpon : telpon
# rekan : rekan
# leggg : leggg
# parahhh : parahhh
# anti : anti
# nyaa : nyaa
# ikutan : ikut
# guys : guys
# yaa : yaa
# heran : heran
# perusahaan : usaha
# jelangkung : jelangkung
# imunitas : imunitas
# meningkat : tingkat
# kesehatan : sehat
# terjaga : jaga
# bales : bales
# sepak : sepak
# bola : bola
# nonton : nonton
# seru : seru
# menyaksikan : saksi
# liga : liga
# inggris : inggris
# dmana : dmana
# infonya : info
# pasword : pasword
# konek : konek
# gmn : gmn
# jangkauan : jangkau
# buruk : buruk
# msa : msa
# jarak : jarak
# router : router
# kamar : kamar
# meter : meter
# cma : cma
# boneng : boneng
# tawarin : tawarin
# extender : extender
# warung : warung
# tutup : tutup
# uas : uas
# gaada : gaada
# mahal : mahal
# kayak : kayak
# seandainya : anda
# pindah : pindah
# nggak : nggak
# bantuan : bantu
# hubungi : hubung
# giliran : gilir
# langsung : langsung
# bgmna : bgmna
# periode : periode
# januari : januari
# february : february
# memakai : pakai
# inetnya : inetnya
# dibayar : bayar
# masang : masang
# promo : promo
# kabar : kabar
# rumah : rumah
# pindahkan : pindah
# lengkap : lengkap
# wii : wii
# miminnnn : miminnnn
# nntn : nntn
# basket : basket
# malem : malem
# mingguan : minggu
# sod : sod
# bls : bls
# robot : robot
# support : support
# tuk : tuk
# disney : disney
# hotstar : hotstar
# tukar : tukar
# dng : dng
# andrew : andrew
# membengkan : membengkan
# modemnya : modem
# lost : lost
# conect : conect
# jaya : jaya
# aman : aman
# terkendali : kendali
# mudah : mudah
# menjalani : jalan
# aktivitas : aktivitas
# area : area
# rangkasbitung : rangkasbitung
# ott : ott
# plus : plus
# aktifkan : aktif
# admin : admin
# update : update
# bantuannya : bantu
# {'halo': 'halo', 'kak': 'kak', 'barusan': 'barusan', 'telp': 'telp', 'daro': 'daro', 'konfirmasi': 'konfirmasi', 'data': 'data', 'pelanggan': 'langgan', 'registrasi': 'registrasi', 'email': 'email', 'salah': 'salah', 'billing': 'billing', 'pembayaran': 'bayar', 'diemail': 'email', 'emailnya': 'email', 'gimana': 'gimana', 'wifi': 'wifi', 'nyala': 'nyala', 'udah': 'udah', 'seminggu': 'minggu', 'pasang': 'pasang', 'aktif': 'aktif', 'tolong': 'tolong', 'dibantu': 'bantu', 'yaaa': 'yaaa', 'bayar': 'bayar', 'tagihan': 'tagih', 'mlh': 'mlh', 'gangguan': 'ganggu', 'mulu': 'mulu', 'udh': 'udh', 'kali': 'kali', 'jaringan': 'jaring', 'los': 'los', 'trs': 'trs', 'lupa': 'lupa', 'paswoord': 'paswoord', 'nama': 'nama', 'pengguna': 'guna', 'stb': 'stb', 'kemaren': 'kemaren', 'copot': 'copot', 'jalan': 'jalan', 'muncul': 'muncul', 'lampu': 'lampu', 'merah': 'merah', 'tuuh': 'tuuh', 'benerinx': 'benerinx', '': '', 'lapor': 'lapor', 'pagi': 'pagi', 'tulisan': 'tulis', 'lampunya': 'lampu', 'koneksinya': 'koneksi', 'makasih': 'makasih', 'min': 'min', 'tips': 'tips', 'bagus': 'bagus', 'mantap': 'mantap', 'tipsnya': 'tipsnya', 'coba': 'coba', 'kirain': 'kirain', 'unlock': 'unlock', 'channel': 'channel', 'useetv': 'useetv', 'imlek': 'imlek', 'lock': 'lock', 'alamat': 'alamat', 'link': 'link', 'blom': 'blom', 'masuk': 'masuk', 'pdhal': 'pdhal', 'jam': 'jam', 'siang': 'siang', 'ditelpon': 'telpon', 'telkom': 'telkom', 'adukan': 'adu', 'dlm': 'dlm', 'kecewa': 'kecewa', 'perbaiki': 'baik', 'betah': 'betah', 'dirumah': 'rumah', 'deh': 'deh', 'internetnya': 'internetnya', 'lancar': 'lancar', 'parah': 'parah', 'seneng': 'neng', 'banget': 'banget', 'dpt': 'dpt', 'bermanfaat': 'manfaat', 'mimin': 'mimin', 'keren': 'keren', 'mantul': 'mantul', 'indihome': 'indihome', 'kirim': 'kirim', 'gambar': 'gambar', 'via': 'via', 'whatsapp': 'whatsapp', 'meresahkan': 'resah', 'diganti': 'ganti', 'dibobol': 'bobol', 'tetangga': 'tetangga', 'ganti': 'ganti', 'cuapek': 'cuapek', 'trobel': 'trobel', 'internet': 'internet', 'haloo': 'haloo', 'refresh': 'refresh', 'sistem': 'sistem', 'skrg': 'skrg', 'lelet': 'lelet', 'ulang': 'ulang', 'iini': 'iini', 'disuruh': 'suruh', 'sabar': 'sabar', 'antri': 'antri', 'perbaikan': 'baik', 'teknisi': 'teknisi', 'iya': 'iya', 'selesai': 'selesai', 'ngaco': 'ngaco', 'profesional': 'profesional', 'org': 'org', 'layanan': 'layan', 'emang': 'emang', 'terkenal': 'kenal', 'super': 'super', 'duper': 'duper', 'jelek': 'jelek', 'komplen': 'komplen', 'laporan': 'lapor', 'telepon': 'telepon', 'msh': 'msh', 'terima': 'terima', 'telat': 'telat', 'pemberitahuan': 'pemberitahuan', 'panggilan': 'panggil', 'terblokir': 'blokir', 'terisolir': 'isolir', 'terlambat': 'lambat', 'dibuka': 'buka', 'tunggu': 'tunggu', 'menit': 'menit', 'modem': 'modem', 'direstart': 'direstart', 'nunggu': 'nunggu', 'sampe': 'sampe', 'jaman': 'jaman', 'berkali': 'kali', 'tetep': 'tetep', 'blm': 'blm', 'hadeuuhh': 'hadeuuhh', 'bener': 'bener', 'memuaskan': 'muas', 'berhenti': 'henti', 'berlangganan': 'langgan', 'hariii': 'hariii', 'martpura': 'martpura', 'kalsel': 'kalsel', 'kmn': 'kmn', 'spy': 'spy', 'diperbaiki': 'baik', 'messenger': 'messenger', 'dsruh': 'dsruh', 'gini': 'gin', 'smpai': 'smpai', 'kiamat': 'kiamat', 'maaf': 'maaf', 'renewe': 'renewe', 'speed': 'speed', 'hapus': 'hapus', 'butuh': 'butuh', 'adik': 'adik', 'kakak': 'kakak', 'custemer': 'custemer', 'provider': 'provider', 'trimakasih': 'trimakasih', 'kota': 'kota', 'tanjungbalai': 'tanjungbalai', 'provinsi': 'provinsi', 'sumatera': 'sumatera', 'utara': 'utara', 'susah': 'susah', 'putus': 'putus', 'mohon': 'mohon', 'perbaikannya': 'baik', 'dipercepat': 'cepat', 'kesini': 'kesini', 'mengecewakan': 'kecewa', 'bngt': 'bngt', 'hahaha': 'hahaha', 'mbps': 'mbps', 'langganan': 'langgan', 'segitu': 'segitu', 'malam': 'malam', 'menyabut': 'sabut', 'kabel': 'kabel', 'tiang': 'tiang', 'dipersulit': 'sulit', 'selamat': 'selamat', 'terlayani': 'layan', 'bantuanya': 'bantuanya', 'hasan': 'hasan', 'basri': 'basri', 'kasih': 'kasih', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/140 [00:00<?, ?it/s]
#                                                comment  \
# 0    halo kak, barusan saya dapat telp daro 1500620...
# 1    padahal mau bayar tagihan eh mlh gangguan mulu...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak, kemaren wifi copot terus saya pasang...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin. maaf kok setelah update aplikasi my ind...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                NaN
# 226                                                NaN
#
#                                       cleaning_comment  \
# 0    halo kak barusan saya dapat telp daro   konfir...
# 1    padahal mau bayar tagihan mlh gangguan mulu ud...
# 2    caranya gimana kalau lupa paswoord dan nama pe...
# 3    halo kak kemaren wifi copot terus saya pasang ...
# 5                                       lapor gangguan
# ..                                                 ...
# 222  kenapa kok layanan ott disney plus hotstar bel...
# 223  admin maaf kok setelah update aplikasi indihom...
# 224  pakai indihome jaringan lancar jaya dan aman t...
# 225                                                nan
# 226                                                nan
#
#                                             tokenisasi  \
# 0    [halo, kak, barusan, saya, dapat, telp, daro, ...
# 1    [padahal, mau, bayar, tagihan, mlh, gangguan, ...
# 2    [caranya, gimana, kalau, lupa, paswoord, dan, ...
# 3    [halo, kak, kemaren, wifi, copot, terus, saya,...
# 5                                    [lapor, gangguan]
# ..                                                 ...
# 222  [kenapa, kok, layanan, ott, disney, plus, hots...
# 223  [admin, maaf, kok, setelah, update, aplikasi, ...
# 224  [pakai, indihome, jaringan, lancar, jaya, dan,...
# 225                                              [nan]
# 226                                              [nan]
#
#                                               stopword  \
# 0    [halo, kak, barusan, telp, daro, konfirmasi, d...
# 1    [bayar, tagihan, mlh, gangguan, mulu, udh, kal...
# 2        [gimana, lupa, paswoord, nama, pengguna, stb]
# 3    [halo, kak, kemaren, wifi, copot, pasang, jala...
# 5                                    [lapor, gangguan]
# ..                                                 ...
# 222  [layanan, ott, disney, plus, hotstar, aktifkan...
# 223  [admin, maaf, update, aplikasi, indihome, masu...
# 224  [pakai, indihome, jaringan, lancar, jaya, aman...
# 225                                                 []
# 226                                                 []
#
#                                               stemming
# 0    [halo, kak, barusan, telp, daro, konfirmasi, d...
# 1    [bayar, tagih, mlh, ganggu, mulu, udh, kali, j...
# 2            [gimana, lupa, paswoord, nama, guna, stb]
# 3    [halo, kak, kemaren, wifi, copot, pasang, jala...
# 5                                      [lapor, ganggu]
# ..                                                 ...
# 222  [layan, ott, disney, plus, hotstar, aktif, pak...
# 223  [admin, maaf, update, aplikasi, indihome, masu...
# 224  [pakai, indihome, jaring, lancar, jaya, aman, ...
# 225                                                 []
# 226                                                 []
#
# [140 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [halo, kak, barusan, telp, daro, konfirmasi, d...
# 1    [bayar, tagih, mlh, ganggu, mulu, udh, kali, j...
# 2            [gimana, lupa, paswoord, nama, guna, stb]
# 3    [halo, kak, kemaren, wifi, copot, pasang, jala...
# 5                                      [lapor, ganggu]
# ..                                                 ...
# 222  [layan, ott, disney, plus, hotstar, aktif, pak...
# 223  [admin, maaf, update, aplikasi, indihome, masu...
# 224  [pakai, indihome, jaring, lancar, jaya, aman, ...
# 225                                                 []
# 226                                                 []
#
# [140 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_2.xlsx')
