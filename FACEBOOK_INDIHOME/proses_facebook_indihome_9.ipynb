# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_9.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Yang saya bingung ya min, teknisi sudah datang...
# 1    Min selama saya pake Indihome kalau LOS merah ...
# 2    Selamat siang indihome..dr td indihome saya lo...
# 3    Min,   internet saya loss dari hari jum'at,  t...
# 4           Punya saya begini, baru tadi pagi 9 Okt 21
# ..                                                 ...
# 435  Kabel fiber di tempatku molor ke bawah tolong ...
# 436  Buat yg gk langganan useetv apa ni kak kompens...
# 437                        Di restart sekarang bisa ??
# 438  Lebih baik kalau kompensasinya berupa free bil...
# 439           Yeeeee mayan sampai tgl 15 Okto  Yahuuut
#
# [440 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Yang saya bingung ya min, teknisi sudah datang...
# 1    Min selama saya pake Indihome kalau LOS merah ...
# 2    Selamat siang indihome..dr td indihome saya lo...
# 3    Min,   internet saya loss dari hari jum'at,  t...
# 4           Punya saya begini, baru tadi pagi 9 Okt 21
# ..                                                 ...
# 435  Kabel fiber di tempatku molor ke bawah tolong ...
# 436  Buat yg gk langganan useetv apa ni kak kompens...
# 437                        Di restart sekarang bisa ??
# 438  Lebih baik kalau kompensasinya berupa free bil...
# 439           Yeeeee mayan sampai tgl 15 Okto  Yahuuut
#
# [431 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    yang saya bingung ya min, teknisi sudah datang...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome..dr td indihome saya lo...
# 3    min,   internet saya loss dari hari jum'at,  t...
# 4           punya saya begini, baru tadi pagi 9 okt 21
# ..                                                 ...
# 435  kabel fiber di tempatku molor ke bawah tolong ...
# 436  buat yg gk langganan useetv apa ni kak kompens...
# 437                        di restart sekarang bisa ??
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439           yeeeee mayan sampai tgl 15 okto  yahuuut
#
# [431 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    yang saya bingung ya min, teknisi sudah datang...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome..dr td indihome saya lo...
# 3    min,   internet saya loss dari hari jum'at,  t...
# 4           punya saya begini, baru tadi pagi 9 okt 21
# ..                                                 ...
# 435  kabel fiber di tempatku molor ke bawah tolong ...
# 436  buat yg gk langganan useetv apa ni kak kompens...
# 437                        di restart sekarang bisa ??
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439           yeeeee mayan sampai tgl 15 okto  yahuuut
#
#                                       cleaning_comment
# 0    yang saya bingung min teknisi sudah datang ker...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome indihome saya los dol m...
# 3    min internet saya loss dari hari jum terus dap...
# 4                punya saya begini baru tadi pagi okt
# ..                                                 ...
# 435  kabel fiber tempatku molor bawah tolong dikiri...
# 436        buat langganan useetv apa kak kompensasinya
# 437                             restart sekarang bisa
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439               yeeeee mayan sampai tgl okto yahuuut
#
# [431 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    yang saya bingung ya min, teknisi sudah datang...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome..dr td indihome saya lo...
# 3    min,   internet saya loss dari hari jum'at,  t...
# 4           punya saya begini, baru tadi pagi 9 okt 21
# ..                                                 ...
# 435  kabel fiber di tempatku molor ke bawah tolong ...
# 436  buat yg gk langganan useetv apa ni kak kompens...
# 437                        di restart sekarang bisa ??
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439           yeeeee mayan sampai tgl 15 okto  yahuuut
#
#                                       cleaning_comment  \
# 0    yang saya bingung min teknisi sudah datang ker...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome indihome saya los dol m...
# 3    min internet saya loss dari hari jum terus dap...
# 4                punya saya begini baru tadi pagi okt
# ..                                                 ...
# 435  kabel fiber tempatku molor bawah tolong dikiri...
# 436        buat langganan useetv apa kak kompensasinya
# 437                             restart sekarang bisa
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439               yeeeee mayan sampai tgl okto yahuuut
#
#                                             tokenisasi
# 0    [yang, saya, bingung, min, teknisi, sudah, dat...
# 1    [min, selama, saya, pake, indihome, kalau, los...
# 2    [selamat, siang, indihome, indihome, saya, los...
# 3    [min, internet, saya, loss, dari, hari, jum, t...
# 4       [punya, saya, begini, baru, tadi, pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempatku, molor, bawah, tolong,...
# 436  [buat, langganan, useetv, apa, kak, kompensasi...
# 437                      [, restart, sekarang, bisa, ]
# 438  [lebih, baik, kalau, kompensasinya, berupa, fr...
# 439        [yeeeee, mayan, sampai, tgl, okto, yahuuut]
#
# [431 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    yang saya bingung ya min, teknisi sudah datang...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome..dr td indihome saya lo...
# 3    min,   internet saya loss dari hari jum'at,  t...
# 4           punya saya begini, baru tadi pagi 9 okt 21
# ..                                                 ...
# 435  kabel fiber di tempatku molor ke bawah tolong ...
# 436  buat yg gk langganan useetv apa ni kak kompens...
# 437                        di restart sekarang bisa ??
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439           yeeeee mayan sampai tgl 15 okto  yahuuut
#
#                                       cleaning_comment  \
# 0    yang saya bingung min teknisi sudah datang ker...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome indihome saya los dol m...
# 3    min internet saya loss dari hari jum terus dap...
# 4                punya saya begini baru tadi pagi okt
# ..                                                 ...
# 435  kabel fiber tempatku molor bawah tolong dikiri...
# 436        buat langganan useetv apa kak kompensasinya
# 437                             restart sekarang bisa
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439               yeeeee mayan sampai tgl okto yahuuut
#
#                                             tokenisasi  \
# 0    [yang, saya, bingung, min, teknisi, sudah, dat...
# 1    [min, selama, saya, pake, indihome, kalau, los...
# 2    [selamat, siang, indihome, indihome, saya, los...
# 3    [min, internet, saya, loss, dari, hari, jum, t...
# 4       [punya, saya, begini, baru, tadi, pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempatku, molor, bawah, tolong,...
# 436  [buat, langganan, useetv, apa, kak, kompensasi...
# 437                      [, restart, sekarang, bisa, ]
# 438  [lebih, baik, kalau, kompensasinya, berupa, fr...
# 439        [yeeeee, mayan, sampai, tgl, okto, yahuuut]
#
#                                               stopword
# 0    [bingung, min, teknisi, kerumah, pengaruh, tek...
# 1    [min, indihome, los, merah, kendala, kabel, ja...
# 2    [selamat, siang, indihome, indihome, los, dol,...
# 3    [min, internet, loss, jum, terdampak, perbaika...
# 4                                        [pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempatku, molor, tolong, dikiri...
# 436            [langganan, useetv, kak, kompensasinya]
# 437                                      [, restart, ]
# 438                   [kompensasinya, free, billing, ]
# 439                [yeeeee, mayan, tgl, okto, yahuuut]
#
# [431 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1528
# ------------------------
# bingung : bingung
# min : min
# teknisi : teknisi
# kerumah : rumah
# pengaruh : pengaruh
# maintenance : maintenance
# pusat : pusat
# tunggu : tunggu
# bener : bener
# bayar : bayar
# dpat : dpat
# dijanjikan : janji
# diiklanka : diiklanka
#  :
# indihome : indihome
# los : los
# merah : merah
# kendala : kendala
# kabel : kabel
# jaringan : jaring
# modem : modem
# rumah : rumah
# infonya : info
# gini : gin
# aplikasi : aplikasi
# selamat : selamat
# siang : siang
# dol : dol
# matikan : mati
# cabut : cabut
# sampe : sampe
# mohon : mohon
# pencerahannya : cerah
# telat : telat
# internet : internet
# loss : loss
# jum : jum
# terdampak : dampak
# perbaikan : baik
# masal : masal
# pagi : pagi
# okt : okt
# kendalanya : kendala
# kotak : kotak
# pasang : pasang
# jln : jln
# lintas : lintas
# duri : duri
# pekanbaru : pekanbaru
# kandis : kandis
# riau : riau
# bermasalah : masalah
# connection : connection
# cek : cek
# restart : restart
# tolong : tolong
# solusinya : solusi
# saranmu : saran
# diatas : atas
# lampu : lampu
# kedap : kedap
# kedip : kedip
# manja : manja
# hallo : hallo
# idihome : idihome
# gmn : gmn
# daftar : daftar
# tgl : tgl
# agustus : agustus
# blum : blum
# dipasang : pasang
# profesional : profesional
# alasannya : alas
# klu : klu
# dicencel : dicencel
# daerah : daerah
# dki : dki
# jakarta : jakarta
# sinyal : sinyal
# gimana : gimana
# kelar : kelar
# koneksinya : koneksi
# parah : parah
# mpbs : mpbs
# pemakaian : pakai
# cuman : cuman
# daring : daring
# youtube : youtube
# delay : delay
# nawarin : nawarin
# udah : udah
# hr : hr
# wifi : wifi
# trs : trs
# anak : anak
# kerjakan : kerja
# tugas : tugas
# sklh : sklh
# pemindahan : pindah
# gmna : gmna
# pengaduannya : adu
# kak : kak
# inbox : inbox
# halo : halo
# care : care
# september : september
# lose : lose
# telpon : telpon
# berkali : kali
# solusi : solusi
# disuruh : suruh
# dtg : dtg
# tidaak : tidaak
# punyaku : punya
# nyala : nyala
# berkedip : kedip
# ngatasinga : ngatasinga
# alhamdulillah : alhamdulillah
# gangguan : ganggu
# teknisinya : teknisi
# bergerak : gerak
# cepat : cepat
# perasaan : asa
# hoby : hoby
# banget : banget
# knp : knp
# rore : rore
# tanayak : tanayak
# rmh : rmh
# jangguan : jangguan
# internetnya : internetnya
# mkasi : mkasi
# masang : masang
# lihat : lihat
# komentarnya : komentar
# puas : puas
# ama : ama
# pelayananya : pelayananya
# malam : malam
# koneksi : koneksi
# sambungan : sambung
# udh : udh
# udhh : udhh
# nelpon : nelpon
# tapii : tapi
# gaada : gaada
# respon : respon
# pengalaman : alam
# komplain : komplain
# warna : warna
# dlm : dlm
# jam : jam
# ditangani : tangan
# mati : mati
# gsk : gsk
# laporan : lapor
# fast : fast
# bantu : bantu
# berhenti : henti
# yaa : yaa
# mbps : mbps
# gambar : gambar
# maaf : maaf
# sakpailllll : sakpailllll
# skrang : skrang
# tekhnisi : tekhnisi
# susah : susah
# dihubungi : hubung
# mendingan : mending
# putus : putus
# berlangganan : langgan
# niy : niy
# eror : eror
# coba : coba
# lpas : lpas
# kbel : kbel
# ttp : ttp
# ajha : ajha
# bos : bos
# perangkat : perangkat
# rusak : rusak
# pdhl : pdhl
# rutin : rutin
# tagihan : tagih
# gmana : gmana
# rugi : rugi
# donk : donk
# kanapa : kanapa
# lgi : lgi
# wilayah : wilayah
# penanggalan : tanggal
# subulussalam : subulussalam
# kualitas : kualitas
# stb : stb
# jelek : jelek
# patah : patah
# tbtb : tbtb
# ayo : ayo
# perbaiki : baik
# pon : pon
# konek : konek
# kemaren : kemaren
# sore : sore
# rencana : rencana
# blm : blm
# via : via
# instagram : instagram
# bantuan : bantu
# slur : slur
# call : call
# nomor : nomor
# operatornya : operator
# bontang : bontang
# kaltim : kaltim
# tindak : tindak
# berfungsi : fungsi
# bantuannya : bantu
# info : info
# ganti : ganti
# router : router
# kemarin : kemarin
# tlp : tlp
# center : center
# kali : kali
# pulsa : pulsa
# habis : habis
# tlg : tlg
# baca : baca
# pesan : pesan
# cover : cover
# area : area
# terluas : luas
# tpi : tpi
# ter : ter
# bandingin : bandingin
# paket : paket
# kuota : kuota
# kenceng : kenceng
# telkomsel : telkomsel
# admin : admin
# kasih : kasih
# pembayaran : bayar
# gabisa : gabisa
# butut : butut
# bangd : bangd
# pelayanan : layan
# hilang : hilang
# cuaca : cuaca
# hujan : hujan
# takut : takut
# besok : besok
# pts : pts
# online : online
# provider : provider
# kemajuan : maju
# sedikitpun : sedikit
# jaringannya : jaring
# kerja : kerja
# bolak : bolak
# promo : promo
# nafsu : nafsu
# bnget : bnget
# mulut : mulut
# ngomong : ngomong
# maksa : maksa
# upgrade : upgrade
# speed : speed
# hancur : hancur
# kyak : kyak
# diem : diem
# copas : copas
# kyk : kyk
# orng : orng
# malak : malak
# joss : joss
# pakai : pakai
# enak : enak
# lemot : lot
# kena : kena
# denda : denda
# terisolir : isolir
# mlm : mlm
# mulu : mulu
# ampas : ampas
# kaya : kaya
# lapor : lapor
# tayangan : tayang
# tivi : tivi
# mnyambungkan : mnyambungkan
# arahan : arah
# hrs : hrs
# kgk : kgk
# balas : balas
# follow : follow
# emosi : emosi
# down : down
# heran : heran
# liat : liat
# tuhan : tuhan
# seminggu : minggu
# pengurangan : kurang
# pengen : ken
# pindah : pindah
# sumpah : sumpah
# mahal : mahal
# knpa : knpa
# bias : bias
# lafa : lafa
# indomart : indomart
# bsk : bsk
# jatuh : jatuh
# tempo : tempo
# waduhh : waduhh
# kepurus : purus
# dilaut : laut
# megalodon : megalodon
# punah : punah
# pelanggan : langgan
# dirugikan : rugi
# full : full
# potong : potong
# biaya : biaya
# akibat : akibat
# install : install
# mola : mola
# status : status
# incompatible : incompatible
# langanan : langanan
# propeder : propeder
# bumn : bumn
# mending : mending
# cari : cari
# kecewa : kecewa
# berat : berat
# layanan : layan
# biznet : biznet
# lancar : lancar
# jaya : jaya
# mantap : mantap
# pokoknya : pokok
# penanganannya : tangan
# sebulan : bulan
# ngak : ngak
# nyaman : nyaman
# pakainya : pakai
# ketapang : ketapang
# kalbar : kalbar
# karna : karna
# menggunakn : menggunakn
# sebangai : bangai
# konsumen : konsumen
# rugikan : rugi
# kenakan : kena
# sangsi : sangsi
# isolir : isolir
# terima : terima
# memperbaiki : baik
# memperburuk : buruk
# slot : slot
# penuh : penuh
# nyuri : nyuri
# namanya : nama
# fungsi : fungsi
# lakukan : laku
# pembyran : pembyran
# putusin : putusin
# rumhku : rumhku
# jdi : jdi
# msihh : msihh
# minggu : minggu
# dijepara : dijepara
# trobel : trobel
# ditindak : tindak
# lanjuti : lanjut
# etdah : etdah
# kek : kek
# dateng : dateng
# hasil : hasil
# gada : gada
# tanggal : tanggal
# kemaleman : maleman
# pas : pas
# indomaret : indomaret
# was : was
# pagii : pagi
# indiehome : indiehome
# ngadu : ngadu
# parahnya : parah
# rb : rb
# perkenalan : kenal
# bicara : bicara
# lebar : lebar
# bis : bis
# selesai : selesai
# belom : bom
# sarimin : sarimin
# sangkutin : sangkutin
# pohon : pohon
# mangga : mangga
# rubuhin : rubuhin
# tiang : tiang
# sgra : sgra
# pindahin : pindahin
# nggak : nggak
# aneh : aneh
# hadehhh : hadehhh
# indiehomee : indiehomee
# bngt : bngt
# smoga : smoga
# doang : doang
# soalmya : soalmya
# bsok : bsok
# erorrrrr : erorrrrr
# hufttt : hufttt
# jrgn : jrgn
# error : error
# dri : dri
# aktif : aktif
# akses : akses
# sring : sring
# refresh : refresh
# pimpinan : pimpin
# becus : becus
# ancur : ancur
# dear : dear
# puluhan : puluh
# dipakai : pakai
# aplikasinya : aplikasi
# login : login
# kmrn : kmrn
# msh : msh
# ngelogout : ngelogout
# stuck : stuck
# dihalamana : dihalamana
# chatnya : chatnya
# jarang : jarang
# dibalas : balas
# mengalami : alami
# terkadang : terkadang
# berjalan : jalan
# normal : normal
# bhkn : bhkn
# spesifikasi : spesifikasi
# lbh : lbh
# giliran : gilir
# telp : telp
# ampe : ampe
# keujung : ujung
# dunia : dunia
# suruh : suruh
# diputus : putus
# inet : inet
# trouble : trouble
# proses : proses
# setor : setor
# intetnet : intetnet
# kaga : kaga
# secepatnya : cepat
# makasih : makasih
# masuk : masuk
# apli : apli
# sandi : sandi
# complen : complen
# tetangga : tetangga
# uwa : uwa
# mamang : mamang
# gimn : gimn
# hostpot : hostpot
# wif : wif
# nggk : nggk
# bales : bales
# capek : capek
# plingan : plingan
# kna : kna
# duwit : duwit
# kaget : kaget
# hnya : hnya
# konfirmasi : konfirmasi
# indohome : indohome
# berhasil : hasil
# payah : payah
# bgd : bgd
# gbsa : gbsa
# dihubungin : dihubungin
# dpke : dpke
# katax : katax
# maintanance : maintanance
# hrni : hrni
# useetv : useetv
# seharian : hari
# loading : loading
# melulu : melulu
# kompensasi : kompensasi
# ngasih : ngasih
# gratis : gratis
# match : match
# euro : euro
# kmarin : kmarin
# jujur : jujur
# mengganggu : ganggu
# pekerjaan : kerja
# guru : guru
# kasian : kasi
# murid : murid
# terganggu : ganggu
# belajarnya : ajar
# percepatan : cepat
# test : test
# dipaksakan : paksa
# mikir : mikir
# layanannya : layan
# pilihan : pilih
# orang : orang
# ngetawain : ngetawain
# maki : maki
# indihomo : indihomo
# ketemu : ketemu
# langsung : langsung
# sehumble : sehumble
# salah : salah
# satunya : satu
# ngamuk : ngamuk
# temen : temen
# sependapat : dapat
# cangkemmu : cangkemmu
# uda : uda
# rajin : rajin
# aduan : adu
# digubris : gubris
# sampah : sampah
# alasan : alas
# penghematan : hemat
# dimasa : masa
# pandemi : pandemi
# pertimbangan : timbang
# plat : plat
# bea : bea
# instalasi : instalasi
# eehhh : eehhh
# pulih : pulih
# kayak : kayak
# request : request
# time : time
# out : out
# ping : ping
# normalnya : normal
# didenda : denda
# tabil : tabil
# langganan : langgan
# isp : isp
# truzzzz : truzzzz
# semangat : semangat
# tehnisi : tehnisi
# pntang : pntang
# mxerah : mxerah
# moga : moga
# ttep : ttep
# sehat : sehat
# mgembalikan : mgembalikan
# sejahtera : sejahtera
# sprti : sprti
# sdia : sdia
# kalax : kalax
# mencoba : coba
# merestart : merestart
# jebol : jebol
# semoga : moga
# kekuatan : kuat
# kesehatan : sehat
# keselamatan : selamat
# allah : allah
# swt : swt
# resikonya : resiko
# fup : fup
# yak : yak
# bully : bully
# makassar : makassar
# menjanjikan : janji
# laut : laut
# intinya : inti
# total : total
# suka : suka
# rto : rto
# slow : slow
# foto : foto
# twitter : twitter
# muncul : muncul
# munculny : munculny
# fisik : fisik
# pemasangan : pasang
# memperhatikan : perhati
# standard : standard
# kota : kota
# berantakan : beranta
# semrawut : semrawut
# terkesan : kes
# dimaklumi : maklum
# buruk : buruk
# pengguna : guna
# operator : operator
# sebelah : belah
# jasa : jasa
# telkom : telkom
# kerasnya : keras
# utamakan : utama
# keong : keong
# wonogiri : wonogiri
# skrg : skrg
# nonton : nonton
# ngga : ngga
# dpt : dpt
# diskon : diskon
# untk : untk
# bulanannya : bulan
# mah : mah
# dirmh : dirmh
# dilayar : layar
# kantor : kantor
# tindakan : tindak
# keras : keras
# penagihan : tagih
# tagih : tagih
# jangn : jangn
# depressi : depressi
# nyaa : nyaa
# salam : salam
# berribu : ribu
# mingguan : minggu
# lumayan : lumayan
# nunggu : nunggu
# dijanjiin : dijanjiin
# dinrugikan : dinrugikan
# kadang : kadang
# ganggunman : ganggunman
# sehari : hari
# sadiz : sadiz
# blokir : blokir
# terpotomg : terpotomg
# kom : kom
# kecepatan : cepat
# download : download
# upload : upload
# quota : quota
# unlimited : unlimited
# dibanding : banding
# harga : harga
# murah : murah
# dikit : dikit
# ditelpon : telpon
# dtanya : dtanya
# jawabannnya : jawabannnya
# stabil : stabil
# lantas : lantas
# diundur : undur
# adil : adil
# menikmati : nikmat
# petunjuk : tunjuk
# memuaskan : muas
# ampun : ampun
# saiki : saiki
# lom : lom
# byar : byar
# kacau : kacau
# nnti : nnti
# server : server
# percepat : cepat
# pinginnya : pinginnya
# segitu : segitu
# lelet : lelet
# klau : klau
# angin : angin
# leletnya : lelet
# untung : untung
# akalin : akalin
# pinjem : pinjem
# vpn : vpn
# mikrotik : mikrotik
# kalimantan : kalimantan
# lambat : lambat
# tetep : tetep
# dehhh : dehhh
# lempuyengan : lempuyengan
# numpuk : numpuk
# sing : sing
# tepuk : tepuk
# samapai : samapai
# dicoba : coba
# mematikan : mati
# sesuai : sesuai
# teknisnya : teknis
# nagih : nagih
# cpet : cpet
# bner : bner
# jtuh : jtuh
# kerusakan : rusa
# lemooooottt : lemooooottt
# kompensasinya : kompensasi
# pasuruan : pasuruan
# noh : noh
# mataamu : mataamu
# ciracas : ciracas
# timur : timur
# sambung : sambung
# kejelasan : jelas
# berulang : ulang
# yerputus : yerputus
# bnyak : bnyak
# kecewakan : kecewa
# pelayanannya : layan
# pengaduan : adu
# myindihome : myindihome
# fitur : fitur
# dibuka : buka
# teknis : teknis
# skr : skr
# diterima : terima
# mb : mb
# mentok : mentok
# log : log
# game : game
# apapun : apa
# streaming : streaming
# nyendat : nyendat
# membaik : baik
# sekolah : sekolah
# hasilnya : hasil
# beli : beli
# otw : otw
# bosan : bosan
# papua : papua
# barat : barat
# manokwari : manokwari
# masi : mas
# apakahhh : apakahhh
# teratasi : atas
# buffering : buffering
# dab : dab
# main : main
# pingnya : pingnya
# packet : packet
# meanwhile : meanwhile
# manado : manado
# woe : woe
# msuk : msuk
# klw : klw
# pilih : pilih
# doank : doank
# meter : meter
# menyala : nyala
# dengar : dengar
# makan : makan
# minimal : minimal
# pontianak : pontianak
# speednya : speednya
# diperbaiki : baik
# krg : krg
# ul : ul
# el : el
# kab : kab
# takalar : takalar
# usee : usee
# trus : trus
# sms : sms
# banking : banking
# dikenai : kena
# anehnya : aneh
# mengakes : mengakes
# siaran : siar
# iuran : iur
# bulanan : bulan
# alfamart : alfamart
# dll : dll
# wkwkwkw : wkwkwkw
# mananya : mana
# sepenuhnya : sepenuh
# berupaya : upaya
# sma : sma
# bohong : bohong
# bro : bro
# lolak : lolak
# hrus : hrus
# stdknya : stdknya
# keringana : keringana
# peguna : guna
# indihom : indihom
# mebyar : mebyar
# tpat : tpat
# mndptkan : mndptkan
# masak : masak
# pkek : pkek
# tiket : tiket
# wfh : wfh
# dijanjijan : dijanjijan
# kuta : kuta
# rumsh : rumsh
# habiskan : habis
# ribu : ribu
# keterlambatan : lambat
# system : system
# dikenakan : kena
# bln : bln
# kedepan : depan
# kalah : kalah
# terlambat : lambat
# sejam : jam
# negini : negini
# terimakasih : terimakasih
# diusahakan : usaha
# jaman : jaman
# telkomnet : telkomnet
# instan : instan
# google : google
# rtonya : rtonya
# sea : sea
# but : but
# overall : overall
# ngapa : ngapa
# ngpain : ngpain
# nnton : nnton
# beres : beres
# cepet : cepet
# sabar : sabar
# wkwkwkwk : wkwkwkwk
# apanya : apa
# putuspun : putus
# buka : buka
# ngelag : ngelag
# diliat : liat
# apain : apain
# sya : sya
# jwbannya : jwbannya
# kepastian : pasti
# mantab : mantab
# samarinda : samarinda
# nie : nie
# mudahan : mudah
# kmbl : kmbl
# berangsur : angsur
# haloo : haloo
# gimna : gimna
# benerin : benerin
# browser : browser
# notif : notif
# maen : maen
# putas : putas
# diakses : akses
# alamat : alamat
# taman : taman
# sari : sari
# metropolitan : metropolitan
# hbs : hbs
# magrib : magrib
# harinya : hari
# stgh : stgh
# blg : blg
# ktnya : ktnya
# gpp : gpp
# gda : gda
# msalah : msalah
# mgrib : mgrib
# gangguannya : ganggu
# pengumuman : umum
# kejutan : kejut
# dipake : dipake
# selesainya : selesai
# oxygen : oxygen
# ajalah : aja
# mendadak : dadak
# indonesia : indonesia
# brengsek : brengsek
# bntr : bntr
# weekend : weekend
# org : org
# liburan : libur
# pgn : pgn
# enjoy : enjoy
# mala : mala
# gedeg : gedeg
# grgr : grgr
# batas : batas
# auto : auto
# matiin : matiin
# ganguan : ganguan
# win : win
# solutionnya : solutionnya
# setia : setia
# hee : hee
# ntol : ntol
# kbanyakan : kbanyakan
# terpaksa : paksa
# krna : krna
# disitu : situ
# wadduh : wadduh
# msih : msih
# sudh : sudh
# bxr : bxr
# pekerja : kerja
# dlu : dlu
# banjar : banjar
# jawa : jawa
# aman : aman
# kirim : kirim
# hai : hai
# percaya : percaya
# omongan : omong
# omong : omong
# kosong : kosong
# lemotnya : lot
# komplen : komplen
# japri : japri
# tanggepin : tanggepin
# komen : komen
# omongannya : omong
# langit : langit
# harapan : harap
# palsu : palsu
# bayarnya : bayar
# kasihan : kasihan
# tugs : tugs
# terhambat : hambat
# ngene : ngene
# iki : iki
# brp : brp
# kerugian : rugi
# nich : nich
# malem : malem
# lemoot : lemoot
# apps : apps
# ik : ik
# pasword : pasword
# sukses : sukses
# responya : responya
# terganti : ganti
# ngegame : ngegame
# lag : lag
# malang : malang
# muter : muter
# ajj : ajj
# sinyalnya : sinyal
# data : data
# hati : hati
# cas : cas
# deh : deh
# jember : jember
# tiarap : tiarap
# dunk : dunk
# permohonan : mohon
# perpindahan : pindah
# indhome : indhome
# soale : soale
# suda : suda
# kebutuhan : butuh
# pokok : pokok
# spt : spt
# nasi : nasi
# ngerti : ngerti
# mengerti : erti
# mnta : mnta
# dikurangi : rang
# ats : ats
# ketergangguan : ganggu
# bli : bli
# pembeljran : pembeljran
# berlngsung : berlngsung
# koneck : koneck
# kode : kode
# dilaporkan : lapor
# informasi : informasi
# petugas : tugas
# menindaklanjuti : menindaklanjuti
# update : update
# kah : kah
# estimasinya : estimasi
# hidup : hidup
# susahhh : susahhh
# event : event
# kelewat : lewat
# ngejarnya : ngejarnya
# dapet : dapet
# membayar : bayar
# permintaan : minta
# gunanya : guna
# maksimalkan : maksimal
# box : box
# fasilitas : fasilitas
# sun : sun
# shafira : shafira
# buduran : budur
# sidoarjo : sidoarjo
# mna : mna
# diperinci : perinci
# ditempat : tempat
# cilegon : cilegon
# dinamain : dinamain
# jasuka : jasuka
# sujaka : sujaka
# sukaja : sukaja
# nambah : nambah
# kletes : kletes
# optic : optic
# batam : batam
# anambas : anambas
# latency : latency
# ms : ms
# awalny : awalny
# selatan : selatan
# bonafit : bonafit
# ikutan : ikut
# halu : halu
# indihomecare : indihomecare
# gagal : gagal
# perusahaan : usaha
# monopoli : monopoli
# syarat : syarat
# ketentuannya : tentu
# blas : blas
# pasah : pasah
# costumer : costumer
# servisnya : servis
# melayani : layan
# undur : undur
# true : true
# padam : padam
# listrik : listrik
# prosedurnya : prosedur
# pdahal : pdahal
# bberapa : bberapa
# pemberitahuan : pemberitahuan
# indihomenya : indihomenya
# pusing : pusing
# liatnya : liat
# srg : srg
# komplent : komplent
# bgtu : bgtu
# terjelek : jelek
# wifinya : wifinya
# mao : mao
# laen : laen
# usaha : usaha
# rental : rental
# perbulan : bulan
# barusan : barusan
# live : live
# kompas : kompas
# skali : skali
# loding : loding
# tolonv : tolonv
# campurdarat : campurdarat
# skarang : skarang
# kcepatan : kcepatan
# korupsi : korupsi
# pulak : pulak
# pelanggannya : langgan
# sekalinya : sekali
# gni : gni
# sdah : sdah
# kenaikan : naik
# konektifitas : konektifitas
# lmpu : lmpu
# hijau : hijau
# jatinegara : jatinegara
# kaum : kaum
# sihlakan : sihlakan
# bendera : bendera
# pln : pln
# kupang : kupang
# ntt : ntt
# drop : drop
# berdomisili : domisili
# tambun : tambun
# tepatny : tepatny
# sawah : sawah
# bogo : bogo
# kejadian : jadi
# memaklumi : maklum
# kar : kar
# jalan : jalan
# shrsnya : shrsnya
# bgin : bgin
# potongan : potong
# hrga : hrga
# pmbyrn : pmbyrn
# byr : byr
# bgni : bgni
# trhmbt : trhmbt
# krja : krja
# berubah : ubah
# beban : beban
# bertanggung : tanggung
# kabupaten : kabupaten
# karanganyar : karanganyar
# pembayarannya : bayar
# takutnya : takut
# ujung : ujung
# keputus : putus
# karenakan : karena
# eug : eug
# nanyak : nanyak
# jugak : jugak
# meme : meme
# nyindir : nyindir
# iyak : iyak
# customer : customer
# kenak : nak
# dendak : dendak
# harik : harik
# hargak : hargak
# besoknya : besok
# pikir : pikir
# sodara : sodara
# numpang : numpang
# absen : absen
# wingi : wing
# kiro : kiro
# gur : gur
# ngomahku : ngomahku
# mas : mas
# tuwas : tuwas
# jebule : jebule
# rombongan : rombong
# ditimika : ditimika
# kebangetan : banget
# izin : izin
# facebook : facebook
# lite : lite
# memakai : pakai
# ngeremote : ngeremote
# client : client
# kabar : kabar
# kerjaan : kerja
# amburadul : amburadul
# kepihak : pihak
# blom : blom
# tanggapan : tanggap
# rumahku : rumah
# gangguane : gangguane
# yng : yng
# perpanjangan : panjang
# pke : pke
# boss : boss
# browsing : browsing
# kdang : kdang
# skli : skli
# ngehujat : ngehujat
# ehhh : ehhh
# bakul : bakul
# reseler : reseler
# bandwith : bandwith
# betah : betah
# dikomplain : komplain
# klien : klien
# palembang : palembang
# babar : babar
# pengusaha : usaha
# intrrnet : intrrnet
# bunga : bunga
# enggk : enggk
# smpai : smpai
# brpa : brpa
# hello : hello
# need : need
# quick : quick
# respond : respond
# off : off
# roter : roter
# perbaikannya : baik
# apes : apes
# ndak : ndak
# alfa : alfa
# kpan : kpan
# gabut : gabut
# byat : byat
# rumor : rumor
# dikurang : kurang
# pulau : pulau
# sumba : sumba
# dtmpt : dtmpt
# madiun : madiun
# ngk : ngk
# validasi : validasi
# taroh : taroh
# anakku : anak
# sekolahnya : sekolah
# diperhatikan : perhati
# keluhan : keluh
# setting : setting
# reboot : reboot
# fiberhome : fiberhome
# otomatis : otomatis
# manual : manual
# yess : yess
# super : super
# bola : bola
# ngebantai : ngebantai
# lawan : lawan
# kiamat : kiamat
# cobra : cobra
# tumben : tumben
# tdi : tdi
# turun : turun
# ngebut : ngebut
# lokasi : lokasi
# progress : progress
# batrei : batrei
# tinggal : tinggal
# lagu : lagu
# kuat : kuat
# busuk : busuk
# menaikan : naik
# kbps : kbps
# gues : gues
# modemnya : modem
# butuh : butuh
# istirahat : istirahat
# dimatikan : mati
# dijamin : jamin
# tersambung : sambung
# semu : semu
# tipsss : tipsss
# mudah : mudah
# bermanfaat : manfaat
# jateng : jateng
# push : push
# rank : rank
# smpe : smpe
# afk : afk
# balikin : balikin
# credit : credit
# score : score
# woey : woey
# gift : gift
# skin : skin
# itamnya : itamnya
# reset : reset
# in : in
# dibantu : bantu
# aktifkan : aktif
# trima : trima
# segini : gin
# busnis : busnis
# brengs : brengs
# pengajuan : aju
# tim : tim
# marketing : marketing
# nyuruh : nyuruh
# barengan : bareng
# promosi : promosi
# sales : sales
# perubahan : ubah
# saran : saran
# kepanasan : panas
# kipas : kipas
# kecuali : kecuali
# ruang : ruang
# ber : ber
# eksternalnya : eksternal
# anu : anu
# youtlube : youtlube
# tutortinularnya : tutortinularnya
# hidupkan : hidup
# ip : ip
# beda : beda
# tok : tok
# ngalamin : ngalamin
# kemarinya : kemari
# imbas : imbas
# jan : jan
# performa : performa
# menurun : turun
# sewa : sewa
# eeh : eeh
# bergentanyangan : bergentanyangan
# tasikmalaya : tasikmalaya
# gres : gres
# providernya : providernya
# kentang : kentang
# traffic : traffic
# bad : bad
# rep : rep
# beneran : beneran
# banting : banting
# jalanin : jalanin
# marah : marah
# emang : emang
# ckckck : ckckck
# kondisi : kondisi
# teman : teman
# alhamdullilah : alhamdullilah
# dedy : dedy
# sabu : sabu
# raijua : raijua
# asw : asw
# direspon : direspon
# samasekali : samasekali
# dikota : kota
# ponorogo : ponorogo
# maksimal : maksimal
# mesin : mesin
# th : th
# dijanji : janji
# kelanjutannya : lanjut
# terhormat : hormat
# perihal : perihal
# slalu : slalu
# kritik : kritik
# menyesal : sesal
# merekomendasikan : rekomendasi
# ntah : ntah
# mat : mat
# indehome : indehome
# bsa : bsa
# jringn : jringn
# semuah : semuah
# knpah : knpah
# kepedulian : peduli
# peduli : peduli
# sisi : sisi
# niat : niat
# males : males
# cibinong : cibinong
# lgn : lgn
# lbih : lbih
# janji : janji
# terbaiknya : baik
# rekans : rekans
# tekas : tekas
# gb : gb
# turunin : turunin
# indo : indo
# indie : indie
# melapor : lapor
# benarin : benarin
# dirumah : rumah
# bnyk : bnyk
# petugasnya : tugas
# krmh : krmh
# ambil : ambil
# hssp : hssp
# terkoneksi : koneksi
# terhubung : hubung
# kontrak : kontrak
# erna : erna
# sipitu : sipitu
# keren : keren
# nyesal : nyesal
# lho : lho
# gua : gua
# panggil : panggil
# curhatan : curhatan
# lost : lost
# perbaki : baki
# celana : celana
# usse : usse
# tvnya : tvnya
# qta : qta
# jamu : jamu
# kopi : kopi
# gorengan : goreng
# uang : uang
# ongkos : ongkos
# tolonglah : tolong
# toddopuli : toddopuli
# raya : raya
# ganggguan : ganggguan
# massal : massal
# prosedur : prosedur
# mindahin : mindahin
# alat : alat
# istilah : istilah
# ituu : ituu
# lunas : lunas
# dikembalikan : kembali
# perduli : duli
# demand : demand
# indiho : indiho
# indidodol : indidodol
# jagonya : jago
# terputus : putus
# pls : pls
# actionnnnn : actionnnnn
# tangerang : tangerang
# menyapa : sapa
# duhhhh : duhhhh
# lagiiii : lagiiii
# odp : odp
# kiri : kiri
# kana : kana
# servis : servis
# sobat : sobat
# sobit : sobit
# beresin : resin
# ditguuu : ditguuu
# dtanggepinn : dtanggepinn
# complainant : complainant
# haii : hai
# indi : indi
# nieeeee : nieeeee
# ajaa : ajaa
# heloooooooooooooo : heloooooooooooooo
# sobattt : sobattt
# the : the
# best : best
# aslamu : aslamu
# alalikum : alalikum
# wrh : wrh
# matulohi : matulohi
# wabarokatuh : wabarokatuh
# salaramf : salaramf
# hubungi : hubung
# ngomongnya : ngomongnya
# gading : gading
# serpong : serpong
# kawasan : kawasan
# berani : berani
# open : open
# all : all
# channel : channel
# wahhh : wahhh
# fair : fair
# inetnya : inetnya
# kepake : kepake
# rubah : rubah
# bls : bls
# tel : tel
# nyambung : nyambung
# blast : blast
# hmpr : hmpr
# thn : thn
# wooii : wooii
# kebanyakan : banyak
# wacana : wacana
# dipotong : potong
# tagihannya : tagih
# ditambahin : ditambahin
# program : program
# penambahan : tambah
# phone : phone
# ijin : ijin
# ket : ket
# konpensasi : konpensasi
# ohya : ohya
# adminn : adminn
# chanelnya : chanelnya
# done : done
# sport : sport
# dibatalin : dibatalin
# bonus : bonus
# only : only
# kompensasikah : kompensasi
# jgan : jgan
# milih : milih
# imbasnya : imbas
# bijak : bijak
# mngambil : mngambil
# keputusan : putus
# alatnya : alat
# sampek : sampek
# telpn : telpn
# nomer : nomer
# maksutnya : maksutnya
# jelasin : jelasin
# komplein : komplein
# jadwalkan : jadwal
# satupun : satu
# terealisasi : realisasi
# kunjungan : kunjung
# perhatiannya : perhati
# thx : thx
# asik : asik
# kvm : kvm
# losnya : los
# fox : fox
# grup : grup
# disney : disney
# tgal : tgal
# oktober : oktober
# cianjur : cianjur
# jumat : jumat
# terkait : kait
# bilangnya : bilang
# menunggu : tunggu
# tanggaoannya : tanggaoannya
# telepon : telepon
# film : film
# horror : horror
# susaah : susaah
# pisan : pis
# thank : thank
# you : you
# nikmatin : nikmatin
# menit : menit
# sangkut : sangkut
# mranggen : mranggen
# sgr : sgr
# brlangganan : brlangganan
# smua : smua
# pelnggan : pelnggan
# sll : sll
# maksudnye : maksudnye
# apeeeeeee : apeeeeeee
# miskaaaahhh : miskaaaahhh
# deposit : deposit
# katanta : katanta
# pembyaran : pembyaran
# malab : malab
# internetan : internetan
# chanel : chanel
# woi : woi
# yuhu : yuhu
# kereeennn : kereeennn
# telfp : telfp
# gigit : gigit
# jari : jari
# champions : champions
# fiber : fiber
# tempatku : tempat
# molor : molor
# dikirimkan : kirim
# kesini : kesini
# pintu : pintu
# halaman : halaman
# terlewati : lewat
# free : free
# billing : billing
# yeeeee : yeeeee
# mayan : mayan
# okto : okto
# yahuuut : yahuuut
# {'bingung': 'bingung', 'min': 'min', 'teknisi': 'teknisi', 'kerumah': 'rumah', 'pengaruh': 'pengaruh', 'maintenance': 'maintenance', 'pusat': 'pusat', 'tunggu': 'tunggu', 'bener': 'bener', 'bayar': 'bayar', 'dpat': 'dpat', 'dijanjikan': 'janji', 'diiklanka': 'diiklanka', '': '', 'indihome': 'indihome', 'los': 'los', 'merah': 'merah', 'kendala': 'kendala', 'kabel': 'kabel', 'jaringan': 'jaring', 'modem': 'modem', 'rumah': 'rumah', 'infonya': 'info', 'gini': 'gin', 'aplikasi': 'aplikasi', 'selamat': 'selamat', 'siang': 'siang', 'dol': 'dol', 'matikan': 'mati', 'cabut': 'cabut', 'sampe': 'sampe', 'mohon': 'mohon', 'pencerahannya': 'cerah', 'telat': 'telat', 'internet': 'internet', 'loss': 'loss', 'jum': 'jum', 'terdampak': 'dampak', 'perbaikan': 'baik', 'masal': 'masal', 'pagi': 'pagi', 'okt': 'okt', 'kendalanya': 'kendala', 'kotak': 'kotak', 'pasang': 'pasang', 'jln': 'jln', 'lintas': 'lintas', 'duri': 'duri', 'pekanbaru': 'pekanbaru', 'kandis': 'kandis', 'riau': 'riau', 'bermasalah': 'masalah', 'connection': 'connection', 'cek': 'cek', 'restart': 'restart', 'tolong': 'tolong', 'solusinya': 'solusi', 'saranmu': 'saran', 'diatas': 'atas', 'lampu': 'lampu', 'kedap': 'kedap', 'kedip': 'kedip', 'manja': 'manja', 'hallo': 'hallo', 'idihome': 'idihome', 'gmn': 'gmn', 'daftar': 'daftar', 'tgl': 'tgl', 'agustus': 'agustus', 'blum': 'blum', 'dipasang': 'pasang', 'profesional': 'profesional', 'alasannya': 'alas', 'klu': 'klu', 'dicencel': 'dicencel', 'daerah': 'daerah', 'dki': 'dki', 'jakarta': 'jakarta', 'sinyal': 'sinyal', 'gimana': 'gimana', 'kelar': 'kelar', 'koneksinya': 'koneksi', 'parah': 'parah', 'mpbs': 'mpbs', 'pemakaian': 'pakai', 'cuman': 'cuman', 'daring': 'daring', 'youtube': 'youtube', 'delay': 'delay', 'nawarin': 'nawarin', 'udah': 'udah', 'hr': 'hr', 'wifi': 'wifi', 'trs': 'trs', 'anak': 'anak', 'kerjakan': 'kerja', 'tugas': 'tugas', 'sklh': 'sklh', 'pemindahan': 'pindah', 'gmna': 'gmna', 'pengaduannya': 'adu', 'kak': 'kak', 'inbox': 'inbox', 'halo': 'halo', 'care': 'care', 'september': 'september', 'lose': 'lose', 'telpon': 'telpon', 'berkali': 'kali', 'solusi': 'solusi', 'disuruh': 'suruh', 'dtg': 'dtg', 'tidaak': 'tidaak', 'punyaku': 'punya', 'nyala': 'nyala', 'berkedip': 'kedip', 'ngatasinga': 'ngatasinga', 'alhamdulillah': 'alhamdulillah', 'gangguan': 'ganggu', 'teknisinya': 'teknisi', 'bergerak': 'gerak', 'cepat': 'cepat', 'perasaan': 'asa', 'hoby': 'hoby', 'banget': 'banget', 'knp': 'knp', 'rore': 'rore', 'tanayak': 'tanayak', 'rmh': 'rmh', 'jangguan': 'jangguan', 'internetnya': 'internetnya', 'mkasi': 'mkasi', 'masang': 'masang', 'lihat': 'lihat', 'komentarnya': 'komentar', 'puas': 'puas', 'ama': 'ama', 'pelayananya': 'pelayananya', 'malam': 'malam', 'koneksi': 'koneksi', 'sambungan': 'sambung', 'udh': 'udh', 'udhh': 'udhh', 'nelpon': 'nelpon', 'tapii': 'tapi', 'gaada': 'gaada', 'respon': 'respon', 'pengalaman': 'alam', 'komplain': 'komplain', 'warna': 'warna', 'dlm': 'dlm', 'jam': 'jam', 'ditangani': 'tangan', 'mati': 'mati', 'gsk': 'gsk', 'laporan': 'lapor', 'fast': 'fast', 'bantu': 'bantu', 'berhenti': 'henti', 'yaa': 'yaa', 'mbps': 'mbps', 'gambar': 'gambar', 'maaf': 'maaf', 'sakpailllll': 'sakpailllll', 'skrang': 'skrang', 'tekhnisi': 'tekhnisi', 'susah': 'susah', 'dihubungi': 'hubung', 'mendingan': 'mending', 'putus': 'putus', 'berlangganan': 'langgan', 'niy': 'niy', 'eror': 'eror', 'coba': 'coba', 'lpas': 'lpas', 'kbel': 'kbel', 'ttp': 'ttp', 'ajha': 'ajha', 'bos': 'bos', 'perangkat': 'perangkat', 'rusak': 'rusak', 'pdhl': 'pdhl', 'rutin': 'rutin', 'tagihan': 'tagih', 'gmana': 'gmana', 'rugi': 'rugi', 'donk': 'donk', 'kanapa': 'kanapa', 'lgi': 'lgi', 'wilayah': 'wilayah', 'penanggalan': 'tanggal', 'subulussalam': 'subulussalam', 'kualitas': 'kualitas', 'stb': 'stb', 'jelek': 'jelek', 'patah': 'patah', 'tbtb': 'tbtb', 'ayo': 'ayo', 'perbaiki': 'baik', 'pon': 'pon', 'konek': 'konek', 'kemaren': 'kemaren', 'sore': 'sore', 'rencana': 'rencana', 'blm': 'blm', 'via': 'via', 'instagram': 'instagram', 'bantuan': 'b ...
# ------------------------
# Pandas Apply:   0%|          | 0/431 [00:00<?, ?it/s]
#                                                comment  \
# 0    yang saya bingung ya min, teknisi sudah datang...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome..dr td indihome saya lo...
# 3    min,   internet saya loss dari hari jum'at,  t...
# 4           punya saya begini, baru tadi pagi 9 okt 21
# ..                                                 ...
# 435  kabel fiber di tempatku molor ke bawah tolong ...
# 436  buat yg gk langganan useetv apa ni kak kompens...
# 437                        di restart sekarang bisa ??
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439           yeeeee mayan sampai tgl 15 okto  yahuuut
#
#                                       cleaning_comment  \
# 0    yang saya bingung min teknisi sudah datang ker...
# 1    min selama saya pake indihome kalau los merah ...
# 2    selamat siang indihome indihome saya los dol m...
# 3    min internet saya loss dari hari jum terus dap...
# 4                punya saya begini baru tadi pagi okt
# ..                                                 ...
# 435  kabel fiber tempatku molor bawah tolong dikiri...
# 436        buat langganan useetv apa kak kompensasinya
# 437                             restart sekarang bisa
# 438  lebih baik kalau kompensasinya berupa free bil...
# 439               yeeeee mayan sampai tgl okto yahuuut
#
#                                             tokenisasi  \
# 0    [yang, saya, bingung, min, teknisi, sudah, dat...
# 1    [min, selama, saya, pake, indihome, kalau, los...
# 2    [selamat, siang, indihome, indihome, saya, los...
# 3    [min, internet, saya, loss, dari, hari, jum, t...
# 4       [punya, saya, begini, baru, tadi, pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempatku, molor, bawah, tolong,...
# 436  [buat, langganan, useetv, apa, kak, kompensasi...
# 437                      [, restart, sekarang, bisa, ]
# 438  [lebih, baik, kalau, kompensasinya, berupa, fr...
# 439        [yeeeee, mayan, sampai, tgl, okto, yahuuut]
#
#                                               stopword  \
# 0    [bingung, min, teknisi, kerumah, pengaruh, tek...
# 1    [min, indihome, los, merah, kendala, kabel, ja...
# 2    [selamat, siang, indihome, indihome, los, dol,...
# 3    [min, internet, loss, jum, terdampak, perbaika...
# 4                                        [pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempatku, molor, tolong, dikiri...
# 436            [langganan, useetv, kak, kompensasinya]
# 437                                      [, restart, ]
# 438                   [kompensasinya, free, billing, ]
# 439                [yeeeee, mayan, tgl, okto, yahuuut]
#
#                                               stemming
# 0    [bingung, min, teknisi, rumah, pengaruh, tekni...
# 1    [min, indihome, los, merah, kendala, kabel, ja...
# 2    [selamat, siang, indihome, indihome, los, dol,...
# 3    [min, internet, loss, jum, dampak, baik, masal, ]
# 4                                        [pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempat, molor, tolong, kirim, t...
# 436                 [langgan, useetv, kak, kompensasi]
# 437                                      [, restart, ]
# 438                      [kompensasi, free, billing, ]
# 439                [yeeeee, mayan, tgl, okto, yahuuut]
#
# [431 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [bingung, min, teknisi, rumah, pengaruh, tekni...
# 1    [min, indihome, los, merah, kendala, kabel, ja...
# 2    [selamat, siang, indihome, indihome, los, dol,...
# 3    [min, internet, loss, jum, dampak, baik, masal, ]
# 4                                        [pagi, okt, ]
# ..                                                 ...
# 435  [kabel, fiber, tempat, molor, tolong, kirim, t...
# 436                 [langgan, useetv, kak, kompensasi]
# 437                                      [, restart, ]
# 438                      [kompensasi, free, billing, ]
# 439                [yeeeee, mayan, tgl, okto, yahuuut]
#
# [431 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_9.xlsx')
