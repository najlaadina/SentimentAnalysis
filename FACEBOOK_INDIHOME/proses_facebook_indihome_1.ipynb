# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_1.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 2                                   indihome keren bgt
# 3                       Keren min tipsnya, pas banget.
# 4                                 sip min, bagus tips.
# ..                                                 ...
# 107  IndiHome yg ga tau malu penuh complain terputu...
# 108                                    No 142204101227
# 109          Mau lapor gangguan jaringan WiFi Indihome
# 110  Lapor gangguan jaringan WiFi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
# [112 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren.
# 7                      hmmm benar juga nih tips mimin.
# 9    Tiket saya tidak yang merespon, Bagaimana ini ...
# ..                                                 ...
# 107  IndiHome yg ga tau malu penuh complain terputu...
# 108                                    No 142204101227
# 109          Mau lapor gangguan jaringan WiFi Indihome
# 110  Lapor gangguan jaringan WiFi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
# [100 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren.
# 7                      hmmm benar juga nih tips mimin.
# 9    tiket saya tidak yang merespon, bagaimana ini ...
# ..                                                 ...
# 107  indihome yg ga tau malu penuh complain terputu...
# 108                                    no 142204101227
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
# [100 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren.
# 7                      hmmm benar juga nih tips mimin.
# 9    tiket saya tidak yang merespon, bagaimana ini ...
# ..                                                 ...
# 107  indihome yg ga tau malu penuh complain terputu...
# 108                                    no 142204101227
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                       cleaning_comment
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren
# 7                      hmmm benar juga nih tips mimin
# 9    tiket saya tidak yang merespon bagaimana ini i...
# ..                                                 ...
# 107  indihome tau malu penuh complain terputus lagi...
# 108
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom internet ...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
# [100 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren.
# 7                      hmmm benar juga nih tips mimin.
# 9    tiket saya tidak yang merespon, bagaimana ini ...
# ..                                                 ...
# 107  indihome yg ga tau malu penuh complain terputu...
# 108                                    no 142204101227
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                       cleaning_comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren
# 7                      hmmm benar juga nih tips mimin
# 9    tiket saya tidak yang merespon bagaimana ini i...
# ..                                                 ...
# 107  indihome tau malu penuh complain terputus lagi...
# 108
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom internet ...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                             tokenisasi
# 0                            [ini, saran, yang, bagus]
# 1                            [ini, saran, yang, keren]
# 5                          [ini, saran, yang, keren, ]
# 7              [hmmm, benar, juga, nih, tips, mimin, ]
# 9    [tiket, saya, tidak, yang, merespon, bagaimana...
# ..                                                 ...
# 107  [indihome, tau, malu, penuh, complain, terputu...
# 108                                               [, ]
# 109   [mau, lapor, gangguan, jaringan, wifi, indihome]
# 110  [lapor, gangguan, jaringan, wifi, indihom, int...
# 111  [mau, lapor, gangguan, jaringan, wifi, indihom...
#
# [100 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren.
# 7                      hmmm benar juga nih tips mimin.
# 9    tiket saya tidak yang merespon, bagaimana ini ...
# ..                                                 ...
# 107  indihome yg ga tau malu penuh complain terputu...
# 108                                    no 142204101227
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                       cleaning_comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren
# 7                      hmmm benar juga nih tips mimin
# 9    tiket saya tidak yang merespon bagaimana ini i...
# ..                                                 ...
# 107  indihome tau malu penuh complain terputus lagi...
# 108
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom internet ...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                             tokenisasi  \
# 0                            [ini, saran, yang, bagus]
# 1                            [ini, saran, yang, keren]
# 5                          [ini, saran, yang, keren, ]
# 7              [hmmm, benar, juga, nih, tips, mimin, ]
# 9    [tiket, saya, tidak, yang, merespon, bagaimana...
# ..                                                 ...
# 107  [indihome, tau, malu, penuh, complain, terputu...
# 108                                               [, ]
# 109   [mau, lapor, gangguan, jaringan, wifi, indihome]
# 110  [lapor, gangguan, jaringan, wifi, indihom, int...
# 111  [mau, lapor, gangguan, jaringan, wifi, indihom...
#
#                                               stopword
# 0                                       [saran, bagus]
# 1                                       [saran, keren]
# 5                                     [saran, keren, ]
# 7                                [hmmm, tips, mimin, ]
# 9    [tiket, merespon, indohome, berdasarkan, email...
# ..                                                 ...
# 107  [indihome, malu, penuh, complain, terputus, bu...
# 108                                               [, ]
# 109        [lapor, gangguan, jaringan, wifi, indihome]
# 110  [lapor, gangguan, jaringan, wifi, indihom, int...
# 111        [lapor, gangguan, jaringan, wifi, indihome]
#
# [100 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 330
# ------------------------
# saran : saran
# bagus : bagus
# keren : keren
#  :
# hmmm : hmmm
# tips : tips
# mimin : mimin
# tiket : tiket
# merespon : merespon
# indohome : indohome
# berdasarkan : dasar
# email : email
# terima : terima
# laporannya : lapor
# buatkan : buat
# pelaporan : lapor
# nomor : nomor
# in : in
# berkenan : kenan
# menunggu : tunggu
# progress : progress
# dibutuhkan : butuh
# konfirmasi : konfirmasi
# dihubungi : hubung
# ponsel : ponsel
# aktif : aktif
# informasikan : informasi
# pengecekan : kece
# mandiri : mandiri
# status : status
# website : website
# link : link
# berguna : guna
# banget : banget
# min : min
# mantap : mantap
# tipn : tipn
# makasih : makasih
# indihome : indihome
# tipsnya : tipsnya
# kakak : kakak
# bermanfaat : manfaat
# wuih : wuih
# kak : kak
# seru : seru
# main : main
# bareng : bareng
# keluarga : keluarga
# tolong : tolong
# bantu : bantu
# tutup : tutup
# secepat : cepat
# gimana : gimana
# msu : msu
# belajar : ajar
# daring : daring
# daftar : daftar
# udah : udah
# minggu : minggu
# dipasang : pasang
# edukasinya : edukasi
# bener : bener
# nambah : nambah
# ilmu : ilmu
# mantul : mantul
# kerenn : kerenn
# nicee : nicee
# telepon : telepon
# suara : suara
# mohon : mohon
# dibantu : bantu
# perbaiki : baik
# indihom : indihom
# koneksi : koneksi
# internetnnya : internetnnya
# pengaduan : adu
# myindihom : myindihom
# app : app
# buka : buka
# tagihan : tagih
# juli : juli
# terbayat : bayat
# hilang : hilang
# sinyalnya : sinyal
# pelanggan : langgan
# fery : fery
# foroncius : foroncius
# mengalami : alami
# gangguan : ganggu
# tlg : tlg
# respon : respon
# secepatnya : cepat
# responnya : responnya
# seminggu : minggu
# jaringan : jaring
# wifi : wifi
# dilapor : lapor
# teknisinya : teknisi
# dtg : dtg
# rumah : rumah
# tlong : tlong
# lampu : lampu
# merah : merah
# kedip : kedip
# wiffi : wiffi
# drmh : drmh
# uda : uda
# pagi : pagi
# tetangga : tetangga
# lambat : lambat
# penanganan : tangan
# mendaftarkan : daftar
# internet : internet
# tgl : tgl
# januari : januari
# kunjungan : kunjung
# teknisi : teknisi
# diperbaiki : baik
# direspon : direspon
# dirumah : rumah
# eror : eror
# diberin : diberin
# bayarnya : bayar
# rutin : rutin
# off : off
# signal : signal
# full : full
# bayar : bayar
# bln : bln
# sept : sept
# mhn : mhn
# tuk : tuk
# ditindak : tindak
# lanjuti : lanjut
# cek : cek
# online : online
# biayanya : biaya
# menit : menit
# langsung : langsung
# maaf : maaf
# melaporkan : lapor
# berfungsi : fungsi
# barangkali : barangkali
# trim : trim
# pramudyah : pramudyah
# ananda : ananda
# perum : perum
# abr : abr
# kebomas : kebomas
# kembangan : kembang
# gresik : gresik
# konek : konek
# modem : modem
# berkedip : kedip
# warna : warna
# indikator : indikator
# los : los
# sedari : dar
# siang : siang
# smpai : smpai
# skarang : skarang
# bklok : bklok
# besok : besok
# anak : anak
# sekolah : sekolah
# trm : trm
# bantuannya : bantu
# menaikan : naik
# kecepatan : cepat
# mbps : mbps
# perbulan : bulan
# byar : byar
# diblok : blok
# profesional : profesional
# skli : skli
# sgera : sgera
# bbrp : bbrp
# hri : hri
# lemott : lemott
# dipkei : dipkei
# gbr : gbr
# youtube : youtube
# munterrrrrr : munterrrrrr
# terussan : terussan
# jln : jln
# emng : emng
# parah : parah
# halo : halo
# fiber : fiber
# error : error
# keluhan : keluh
# stak : stak
# apkh : apkh
# kontak : kontak
# nyala : nyala
# telpon : telpon
# mati : mati
# kemaren : kemaren
# respond : respond
# tangap : tangap
# telkom : telkom
# sistem : sistem
# danpantau : danpantau
# membedakan : beda
# pantauan : pantau
# padam : padam
# game : game
# terputus : putus
# lods : lods
# menyalah : salah
# kasih : kasih
# maksimal : maksimal
# putus : putus
# says : says
# laporkan : lapor
# digubris : gubris
# jalan : jalan
# demang : demang
# akub : akub
# sinyal : sinyal
# lelet : lelet
# iya : iya
# donk : donk
# respons : respons
# woy : woy
# knpa : knpa
# gaangguan : gaangguan
# aman : aman
# pakai : pakai
# bantuan : bantu
# undian : undi
# berhadiah : hadiah
# tukar : tukar
# poin : poin
# hoax : hoax
# dicuekin : dicuekin
# allah : allah
# tega : tega
# adminnya : adminnya
# alat : alat
# total : total
# kayanya : kaya
# jalur : jalur
# berhenti : henti
# berlangganan : langgan
# dol : dol
# nama : nama
# fitria : fitria
# ganti : ganti
# sandi : sandi
# gmn : gmn
# lampunya : lampu
# kelap : kelap
# kelip : kelip
# bos : bos
# selamat : selamat
# terhubung : hubung
# gara : gara
# kemarin : kemarin
# petir : petir
# responny : responny
# laporan : lapor
# kali : kali
# nomer : nomer
# berbeda : beda
# blm : blm
# evaluasi : evaluasi
# kompensasi : kompensasi
# pengen : ken
# hiburan : hibur
# ngeselin : ngeselin
# lapor : lapor
# ditangani : tangan
# sllalu : sllalu
# terlambat : lambat
# slamat : slamat
# stabil : stabil
# login : login
# router : router
# waipi : waipi
# mendadak : dadak
# jelaskah : jelas
# loporan : lopor
# knp : knp
# nga : nga
# stb : stb
# gagal : gagal
# terbayar : bayar
# msh : msh
# terisolir : isolir
# membayar : bayar
# layanan : layan
# konfigurasi : konfigurasi
# komplan : komplan
# lapangan : lapang
# tindak : tindak
# terimakasih : terimakasih
# ttg : ttg
# berita : berita
# kelanjutan : lanjut
# pelayanan : layan
# cepat : cepat
# tpi : tpi
# komplenan : komplenan
# perhatikan : perhati
# jarikan : jari
# kerja : kerja
# malam : malam
# harga : harga
# paket : paket
# langganan : langgan
# promo : promo
# masang : masang
# lok : lok
# garut : garut
# sore : sore
# connect : connect
# log : log
# seamles : seamles
# wkt : wkt
# masukkan : masuk
# otp : otp
# notifikasi : notifikasi
# user : user
# msuk : msuk
# malu : malu
# penuh : penuh
# complain : complain
# bubarkan : bubar
# nurokhim : nurokhim
# {'saran': 'saran', 'bagus': 'bagus', 'keren': 'keren', '': '', 'hmmm': 'hmmm', 'tips': 'tips', 'mimin': 'mimin', 'tiket': 'tiket', 'merespon': 'merespon', 'indohome': 'indohome', 'berdasarkan': 'dasar', 'email': 'email', 'terima': 'terima', 'laporannya': 'lapor', 'buatkan': 'buat', 'pelaporan': 'lapor', 'nomor': 'nomor', 'in': 'in', 'berkenan': 'kenan', 'menunggu': 'tunggu', 'progress': 'progress', 'dibutuhkan': 'butuh', 'konfirmasi': 'konfirmasi', 'dihubungi': 'hubung', 'ponsel': 'ponsel', 'aktif': 'aktif', 'informasikan': 'informasi', 'pengecekan': 'kece', 'mandiri': 'mandiri', 'status': 'status', 'website': 'website', 'link': 'link', 'berguna': 'guna', 'banget': 'banget', 'min': 'min', 'mantap': 'mantap', 'tipn': 'tipn', 'makasih': 'makasih', 'indihome': 'indihome', 'tipsnya': 'tipsnya', 'kakak': 'kakak', 'bermanfaat': 'manfaat', 'wuih': 'wuih', 'kak': 'kak', 'seru': 'seru', 'main': 'main', 'bareng': 'bareng', 'keluarga': 'keluarga', 'tolong': 'tolong', 'bantu': 'bantu', 'tutup': 'tutup', 'secepat': 'cepat', 'gimana': 'gimana', 'msu': 'msu', 'belajar': 'ajar', 'daring': 'daring', 'daftar': 'daftar', 'udah': 'udah', 'minggu': 'minggu', 'dipasang': 'pasang', 'edukasinya': 'edukasi', 'bener': 'bener', 'nambah': 'nambah', 'ilmu': 'ilmu', 'mantul': 'mantul', 'kerenn': 'kerenn', 'nicee': 'nicee', 'telepon': 'telepon', 'suara': 'suara', 'mohon': 'mohon', 'dibantu': 'bantu', 'perbaiki': 'baik', 'indihom': 'indihom', 'koneksi': 'koneksi', 'internetnnya': 'internetnnya', 'pengaduan': 'adu', 'myindihom': 'myindihom', 'app': 'app', 'buka': 'buka', 'tagihan': 'tagih', 'juli': 'juli', 'terbayat': 'bayat', 'hilang': 'hilang', 'sinyalnya': 'sinyal', 'pelanggan': 'langgan', 'fery': 'fery', 'foroncius': 'foroncius', 'mengalami': 'alami', 'gangguan': 'ganggu', 'tlg': 'tlg', 'respon': 'respon', 'secepatnya': 'cepat', 'responnya': 'responnya', 'seminggu': 'minggu', 'jaringan': 'jaring', 'wifi': 'wifi', 'dilapor': 'lapor', 'teknisinya': 'teknisi', 'dtg': 'dtg', 'rumah': 'rumah', 'tlong': 'tlong', 'lampu': 'lampu', 'merah': 'merah', 'kedip': 'kedip', 'wiffi': 'wiffi', 'drmh': 'drmh', 'uda': 'uda', 'pagi': 'pagi', 'tetangga': 'tetangga', 'lambat': 'lambat', 'penanganan': 'tangan', 'mendaftarkan': 'daftar', 'internet': 'internet', 'tgl': 'tgl', 'januari': 'januari', 'kunjungan': 'kunjung', 'teknisi': 'teknisi', 'diperbaiki': 'baik', 'direspon': 'direspon', 'dirumah': 'rumah', 'eror': 'eror', 'diberin': 'diberin', 'bayarnya': 'bayar', 'rutin': 'rutin', 'off': 'off', 'signal': 'signal', 'full': 'full', 'bayar': 'bayar', 'bln': 'bln', 'sept': 'sept', 'mhn': 'mhn', 'tuk': 'tuk', 'ditindak': 'tindak', 'lanjuti': 'lanjut', 'cek': 'cek', 'online': 'online', 'biayanya': 'biaya', 'menit': 'menit', 'langsung': 'langsung', 'maaf': 'maaf', 'melaporkan': 'lapor', 'berfungsi': 'fungsi', 'barangkali': 'barangkali', 'trim': 'trim', 'pramudyah': 'pramudyah', 'ananda': 'ananda', 'perum': 'perum', 'abr': 'abr', 'kebomas': 'kebomas', 'kembangan': 'kembang', 'gresik': 'gresik', 'konek': 'konek', 'modem': 'modem', 'berkedip': 'kedip', 'warna': 'warna', 'indikator': 'indikator', 'los': 'los', 'sedari': 'dar', 'siang': 'siang', 'smpai': 'smpai', 'skarang': 'skarang', 'bklok': 'bklok', 'besok': 'besok', 'anak': 'anak', 'sekolah': 'sekolah', 'trm': 'trm', 'bantuannya': 'bantu', 'menaikan': 'naik', 'kecepatan': 'cepat', 'mbps': 'mbps', 'perbulan': 'bulan', 'byar': 'byar', 'diblok': 'blok', 'profesional': 'profesional', 'skli': 'skli', 'sgera': 'sgera', 'bbrp': 'bbrp', 'hri': 'hri', 'lemott': 'lemott', 'dipkei': 'dipkei', 'gbr': 'gbr', 'youtube': 'youtube', 'munterrrrrr': 'munterrrrrr', 'terussan': 'terussan', 'jln': 'jln', 'emng': 'emng', 'parah': 'parah', 'halo': 'halo', 'fiber': 'fiber', 'error': 'error', 'keluhan': 'keluh', 'stak': 'stak', 'apkh': 'apkh', 'kontak': 'kontak', 'nyala': 'nyala', 'telpon': 'telpon', 'mati': 'mati', 'kemaren': 'kemaren', 'respond': 'respond', 'tangap': 'tangap', 'telkom': 'telkom', 'sistem': 'sistem', 'danpantau': 'danpantau', 'membedakan': 'b ...
# ------------------------
# Pandas Apply:   0%|          | 0/100 [00:00<?, ?it/s]
#                                                comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren.
# 7                      hmmm benar juga nih tips mimin.
# 9    tiket saya tidak yang merespon, bagaimana ini ...
# ..                                                 ...
# 107  indihome yg ga tau malu penuh complain terputu...
# 108                                    no 142204101227
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom,no.intern...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                       cleaning_comment  \
# 0                                 ini saran yang bagus
# 1                                 ini saran yang keren
# 5                                ini saran yang keren
# 7                      hmmm benar juga nih tips mimin
# 9    tiket saya tidak yang merespon bagaimana ini i...
# ..                                                 ...
# 107  indihome tau malu penuh complain terputus lagi...
# 108
# 109          mau lapor gangguan jaringan wifi indihome
# 110  lapor gangguan jaringan wifi indihom internet ...
# 111      mau lapor gangguan jaringan wifi indihome ini
#
#                                             tokenisasi  \
# 0                            [ini, saran, yang, bagus]
# 1                            [ini, saran, yang, keren]
# 5                          [ini, saran, yang, keren, ]
# 7              [hmmm, benar, juga, nih, tips, mimin, ]
# 9    [tiket, saya, tidak, yang, merespon, bagaimana...
# ..                                                 ...
# 107  [indihome, tau, malu, penuh, complain, terputu...
# 108                                               [, ]
# 109   [mau, lapor, gangguan, jaringan, wifi, indihome]
# 110  [lapor, gangguan, jaringan, wifi, indihom, int...
# 111  [mau, lapor, gangguan, jaringan, wifi, indihom...
#
#                                               stopword  \
# 0                                       [saran, bagus]
# 1                                       [saran, keren]
# 5                                     [saran, keren, ]
# 7                                [hmmm, tips, mimin, ]
# 9    [tiket, merespon, indohome, berdasarkan, email...
# ..                                                 ...
# 107  [indihome, malu, penuh, complain, terputus, bu...
# 108                                               [, ]
# 109        [lapor, gangguan, jaringan, wifi, indihome]
# 110  [lapor, gangguan, jaringan, wifi, indihom, int...
# 111        [lapor, gangguan, jaringan, wifi, indihome]
#
#                                               stemming
# 0                                       [saran, bagus]
# 1                                       [saran, keren]
# 5                                     [saran, keren, ]
# 7                                [hmmm, tips, mimin, ]
# 9    [tiket, merespon, indohome, dasar, email, teri...
# ..                                                 ...
# 107  [indihome, malu, penuh, complain, putus, bubar...
# 108                                               [, ]
# 109            [lapor, ganggu, jaring, wifi, indihome]
# 110  [lapor, ganggu, jaring, wifi, indihom, interne...
# 111            [lapor, ganggu, jaring, wifi, indihome]
#
# [100 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                       [saran, bagus]
# 1                                       [saran, keren]
# 5                                     [saran, keren, ]
# 7                                [hmmm, tips, mimin, ]
# 9    [tiket, merespon, indohome, dasar, email, teri...
# ..                                                 ...
# 107  [indihome, malu, penuh, complain, putus, bubar...
# 108                                               [, ]
# 109            [lapor, ganggu, jaring, wifi, indihome]
# 110  [lapor, ganggu, jaring, wifi, indihom, interne...
# 111            [lapor, ganggu, jaring, wifi, indihome]
#
# [100 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_1.xlsx')
