# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_5.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0         layanan SOD apa masih ada atau sdh tidak ada
# 1    Halo... Sudh 1 bulan internet sya g bsa d pake...
# 2    Halo  ... Tolong dong... wifi saya sudah tiga ...
# 3    Harapan saya sih Indihome bisa menurunkan (nor...
# 4    Wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  Kapan normal jaringan indihome di jayapura, sd...
# 280                     Internet saya tiba tiba hilang
# 281         Internet saya tiba tiba hilang sudah 2hari
# 282  Tolong bantu infonya : 3 hari ini wifi kami td...
# 283          Halo Min seamless maksimal berapa device?
#
# [284 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 51

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0         layanan SOD apa masih ada atau sdh tidak ada
# 1    Halo... Sudh 1 bulan internet sya g bsa d pake...
# 2    Halo  ... Tolong dong... wifi saya sudah tiga ...
# 3    Harapan saya sih Indihome bisa menurunkan (nor...
# 4    Wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  Kapan normal jaringan indihome di jayapura, sd...
# 280                     Internet saya tiba tiba hilang
# 281         Internet saya tiba tiba hilang sudah 2hari
# 282  Tolong bantu infonya : 3 hari ini wifi kami td...
# 283          Halo Min seamless maksimal berapa device?
#
# [192 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo... sudh 1 bulan internet sya g bsa d pake...
# 2    halo  ... tolong dong... wifi saya sudah tiga ...
# 3    harapan saya sih indihome bisa menurunkan (nor...
# 4    wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  kapan normal jaringan indihome di jayapura, sd...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah 2hari
# 282  tolong bantu infonya : 3 hari ini wifi kami td...
# 283          halo min seamless maksimal berapa device?
#
# [192 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo... sudh 1 bulan internet sya g bsa d pake...
# 2    halo  ... tolong dong... wifi saya sudah tiga ...
# 3    harapan saya sih indihome bisa menurunkan (nor...
# 4    wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  kapan normal jaringan indihome di jayapura, sd...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah 2hari
# 282  tolong bantu infonya : 3 hari ini wifi kami td...
# 283          halo min seamless maksimal berapa device?
#
#                                       cleaning_comment
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo sudh bulan internet sya bsa pake udh lbh ...
# 2    halo tolong dong wifi saya sudah tiga hari ini...
# 3    harapan saya sih indihome bisa menurunkan norm...
# 4    wifi gua tiba tiba gam ada jaringan gmna mau k...
# ..                                                 ...
# 279  kapan normal jaringan indihome jayapura sdah s...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah  hari
# 282  tolong bantu infonya hari ini wifi kami tdk la...
# 283          halo min seamless maksimal berapa device
#
# [192 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo... sudh 1 bulan internet sya g bsa d pake...
# 2    halo  ... tolong dong... wifi saya sudah tiga ...
# 3    harapan saya sih indihome bisa menurunkan (nor...
# 4    wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  kapan normal jaringan indihome di jayapura, sd...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah 2hari
# 282  tolong bantu infonya : 3 hari ini wifi kami td...
# 283          halo min seamless maksimal berapa device?
#
#                                       cleaning_comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo sudh bulan internet sya bsa pake udh lbh ...
# 2    halo tolong dong wifi saya sudah tiga hari ini...
# 3    harapan saya sih indihome bisa menurunkan norm...
# 4    wifi gua tiba tiba gam ada jaringan gmna mau k...
# ..                                                 ...
# 279  kapan normal jaringan indihome jayapura sdah s...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah  hari
# 282  tolong bantu infonya hari ini wifi kami tdk la...
# 283          halo min seamless maksimal berapa device
#
#                                             tokenisasi
# 0    [layanan, sod, apa, masih, ada, atau, sdh, tid...
# 1    [halo, sudh, bulan, internet, sya, bsa, pake, ...
# 2    [halo, tolong, dong, wifi, saya, sudah, tiga, ...
# 3    [harapan, saya, sih, indihome, bisa, menurunka...
# 4    [wifi, gua, tiba, tiba, gam, ada, jaringan, gm...
# ..                                                 ...
# 279  [kapan, normal, jaringan, indihome, jayapura, ...
# 280               [internet, saya, tiba, tiba, hilang]
# 281  [internet, saya, tiba, tiba, hilang, sudah, hari]
# 282  [tolong, bantu, infonya, hari, ini, wifi, kami...
# 283  [halo, min, seamless, maksimal, berapa, device, ]
#
# [192 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo... sudh 1 bulan internet sya g bsa d pake...
# 2    halo  ... tolong dong... wifi saya sudah tiga ...
# 3    harapan saya sih indihome bisa menurunkan (nor...
# 4    wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  kapan normal jaringan indihome di jayapura, sd...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah 2hari
# 282  tolong bantu infonya : 3 hari ini wifi kami td...
# 283          halo min seamless maksimal berapa device?
#
#                                       cleaning_comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo sudh bulan internet sya bsa pake udh lbh ...
# 2    halo tolong dong wifi saya sudah tiga hari ini...
# 3    harapan saya sih indihome bisa menurunkan norm...
# 4    wifi gua tiba tiba gam ada jaringan gmna mau k...
# ..                                                 ...
# 279  kapan normal jaringan indihome jayapura sdah s...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah  hari
# 282  tolong bantu infonya hari ini wifi kami tdk la...
# 283          halo min seamless maksimal berapa device
#
#                                             tokenisasi  \
# 0    [layanan, sod, apa, masih, ada, atau, sdh, tid...
# 1    [halo, sudh, bulan, internet, sya, bsa, pake, ...
# 2    [halo, tolong, dong, wifi, saya, sudah, tiga, ...
# 3    [harapan, saya, sih, indihome, bisa, menurunka...
# 4    [wifi, gua, tiba, tiba, gam, ada, jaringan, gm...
# ..                                                 ...
# 279  [kapan, normal, jaringan, indihome, jayapura, ...
# 280               [internet, saya, tiba, tiba, hilang]
# 281  [internet, saya, tiba, tiba, hilang, sudah, hari]
# 282  [tolong, bantu, infonya, hari, ini, wifi, kami...
# 283  [halo, min, seamless, maksimal, berapa, device, ]
#
#                                               stopword
# 0                                       [layanan, sod]
# 1    [halo, sudh, internet, sya, bsa, udh, lbh, rb,...
# 2                     [halo, tolong, wifi, gangguan, ]
# 3    [harapan, indihome, menurunkan, normalisasi, h...
# 4    [wifi, gua, gam, jaringan, gmna, kerja, niih, ...
# ..                                                 ...
# 279  [normal, jaringan, indihome, jayapura, sdah, s...
# 280                                 [internet, hilang]
# 281                                 [internet, hilang]
# 282  [tolong, bantu, infonya, wifi, lancar, pkl, pk...
# 283          [halo, min, seamless, maksimal, device, ]
#
# [192 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 651
# ------------------------
# layanan : layan
# sod : sod
# halo : halo
# sudh : sudh
# internet : internet
# sya : sya
# bsa : bsa
# udh : udh
# lbh : lbh
# rb : rb
# pulsa : pulsa
# pke : pke
# nlfn : nlfn
# proses : proses
# teruskan : terus
# pertamakali : pertamakali
# tlfn : tlfn
# suruh : suruh
# bayar : bayar
# tagihan : tagih
# perbaiki : baik
# lgsung : lgsung
#  :
# tolong : tolong
# wifi : wifi
# gangguan : ganggu
# harapan : harap
# indihome : indihome
# menurunkan : turun
# normalisasi : normalisasi
# harga : harga
# provider : provider
# sewa : sewa
# modem : modem
# ppn : ppn
# dpt : dpt
# mbps : mbps
# belom : bom
# home : home
# fiber : fiber
# masuk : masuk
# murah : murah
# gua : gua
# gam : gam
# jaringan : jaring
# gmna : gmna
# kerja : kerja
# niih : niih
# cek : cek
# yaa : yaa
# lihat : lihat
# udah : udah
# perasaan : asa
# masyarakat : masyarakat
# kota : kota
# kupang : kupang
# tertimpa : timpa
# bencana : bencana
# tlg : tlg
# hai : hai
# min : min
# kak : kak
# inbox : inbox
# ribu : ribu
# kemana : mana
# keadilan : adil
# rakyat : rakyat
# indonesia : indonesia
# cuk : cuk
# turun : turun
# tarip : tarip
# gue : gue
# lahhhh : lahhhh
# admin : admin
# nanya : nanya
# selamat : selamat
# malam : malam
# pengguna : guna
# memangnya : memang
# jam : jam
# onlinenya : onlinenya
# terima : terima
# kasih : kasih
# janji : janji
# tinggal : tinggal
# janjinya : janji
# bermasalah : masalah
# lapor : lapor
# jawabannya : jawab
# dicek : cek
# nggk : nggk
# kelar : kelar
# minipack : minipack
# indikorea : indikorea
# channelnya : channelnya
# mengajukan : aju
# penggantian : ganti
# router : router
# warna : warna
# item : item
# diganti : ganti
# putih : putih
# rusak : rusak
# jangkauannya : jangkau
# petunjuk : tunjuk
# berhenti : henti
# berlangganan : langgan
# aplikasi : aplikasi
# karaoke : karaoke
# cari : cari
# ngebut : ngebut
# koneksi : koneksi
# syart : syart
# pasang : pasang
# bagimana : bagimana
# promo : promo
# bobrok : bobrok
# terputus : putus
# met : met
# siang : siang
# libur : libur
# spt : spt
# lebaran : lebaran
# free : free
# open : open
# all : all
# channel : channel
# nggak : nggak
# dibantu : bantu
# pelanggan : langgan
# menambah : tambah
# titik : titik
# kode : kode
# hubungi : hubung
# witel : witel
# teknisi : teknisi
# hub : hub
# followup : followup
# ribet : ribet
# indi : indi
# sobat : sobat
# terimakasih : terimakasih
# berinteraksi : interaksi
# official : official
# akun : akun
# indihomecare : indihomecare
# mempercepat : cepat
# penanganan : tangan
# keluhan : keluh
# permintaan : minta
# lengkapi : lengkap
# data : data
# rmh : rmh
# eror : eror
# daerah : daerah
# batu : batu
# jaya : jaya
# karawang : karawang
# gmn : gmn
# manggil : manggil
# tukang : tukang
# servisnya : servis
# server : server
# dns : dns
# mati : mati
# signal : signal
# kemarin : kemarin
# pdhl : pdhl
# merestart : merestart
# ulang : ulang
# indiehome : indiehome
# laporkan : lapor
# kekantor : kantor
# sampe : sampe
# muncul : muncul
# harusny : harusny
# opsi : opsi
# random : random
# password : password
# terjadwal : jadwal
# perhari : hari
# karen : karen
# pemanfaatm : pemanfaatm
# skrg : skrg
# untk : untk
# bisnis : bisnis
# hotspot : hotspot
# sdikit : sdikit
# merpotkan : merpotkan
# mesti : mesti
# mengganti : ganti
# laporan : lapor
# follow : follow
# hapal : hapal
# lupa : lupa
# gadget : gadget
# terhubung : hubung
# reset : reset
# gimana : gimana
# papua : papua
# padam : padam
# toleransi : toleransi
# pembayaran : bayar
# in : in
# pagi : pagi
# error : error
# urgent : urgent
# bangett : bangett
# online : online
# jalan : jalan
# anak : anak
# belajar : ajar
# daring : daring
# care : care
# work : work
# banget : banget
# panduannya : pandu
# fiberhome : fiberhome
# ngontrol : ngontrol
# jaringannya : jaring
# desa : desa
# pendowo : pendowo
# bodeh : bodeh
# pemalang : malang
# perintah : perintah
# isi : isi
# nama : nama
# sandi : sandi
# kaaa : kaaa
# download : download
# dimana : mana
# inbx : inbx
# thanks : thanks
# mudah : mudah
# tipsnya : tipsnya
# kuntilanak : kuntilanak
# intermetan : intermetan
# bubarkan : bubar
# telkom : telkom
# internetnya : internetnya
# nice : nice
# hilang : hilang
# sinyal : sinyal
# nonton : nonton
# tlong : tlong
# nomor : nomor
# planggan : planggan
# langsung : langsung
# whatsapp : whatsapp
# sesuai : sesuai
# instruksi : instruksi
# kabel : kabel
# rumah : rumah
# putus : putus
# dibiarkan : biar
# kabelnya : kabel
# terurai : urai
# menghalangi : halang
# pagar : pagar
# diatas : atas
# atap : atap
# statusnya : status
# prioritas : prioritas
# mohon : mohon
# dilingkungan : lingkung
# tiang : tiang
# dompleng : dompleng
# tembok : tembok
# warga : warga
# terisolir : isolir
# nlpn : nlpn
# status : status
# masiih : masiih
# pas : pas
# dipasang : pasang
# oktober : oktober
# dijanjikan : janji
# januari : januari
# useetv : useetv
# smpai : smpai
# kbrny : kbrny
# msh : msh
# diisolir : isolir
# konsumen : konsumen
# dengarkan : dengar
# kualitas : kualitas
# memuaskan : muas
# komplain : komplain
# dengar : dengar
# kali : kali
# kantor : kantor
# kirjm : kirjm
# email : email
# inbok : inbok
# masi : mas
# telat : telat
# solusinya : solusi
# hr : hr
# wifiki : wifiki
# telpon : telpon
# angkat : angkat
# tangan : tangan
# solve : solve
# problem : problem
# ogah : ogah
# jls : jls
# plus : plus
# genap : genap
# ehh : ehh
# biaya : biaya
# lag : lag
# terusssssss : terusssssss
# capekkk : capekkk
# daftar : daftar
# tpi : tpi
# pembukaan : buka
# isolir : isolir
# tgl : tgl
# tlp : tlp
# berfungsi : fungsi
# mlm : mlm
# mendaftar : daftar
# pemasangan : pasang
# lampu : lampu
# merah : merah
# wilayah : wilayah
# curug : curug
# bogor : bogor
# sehari : hari
# semalam : malam
# akses : akses
# detik : detik
# selesai : selesai
# knp : knp
# sring : sring
# mngalami : mngalami
# mnyala : mnyala
# lmpu : lmpu
# kbel : kbel
# adaan : ada
# ujung : ujung
# bnrin : bnrin
# ganti : ganti
# trs : trs
# byar : byar
# kendala : kendala
# sprti : sprti
# bgtt : bgtt
# blum : blum
# paket : paket
# second : second
# set : set
# top : top
# box : box
# hybrid : hybrid
# minat : minat
# trus : trus
# tolak : tolak
# penelpon : telpon
# bersedia : sedia
# telepon : telepon
# keluhkan : keluh
# blm : blm
# dinikmati : nikmat
# sore : sore
# harinya : hari
# nikmati : nikmat
# eeeh : eeeh
# malamnya : malam
# layannan : layannan
# youtube : youtube
# anjuran : anjur
# disu : disu
# smpt : smpt
# coba : coba
# refresh : refresh
# kayanya : kaya
# kcptn : kcptn
# makmsimal : makmsimal
# respon : respon
# thx : thx
# oke : oke
# sippp : sippp
# rajin : rajin
# byr : byr
# sllu : sllu
# uda : uda
# lunas : lunas
# kena : kena
# plaza : plaza
# buka : buka
# renew : renew
# speed : speed
# batas : batas
# fub : fub
# berkurang : kurang
# perubahan : ubah
# slalu : slalu
# semenjak : semenjak
# raya : raya
# idul : idul
# fitri : fitri
# browser : browser
# crome : crome
# google : google
# kadang : kadang
# trsambung : trsambung
# indikator : indikator
# aktif : aktif
# laporam : laporam
# ganguan : ganguan
# mahal : mahal
# liat : liat
# org : org
# infihome : infihome
# membenarkan : benar
# gantian : ganti
# tetep : tetep
# myindihome : myindihome
# pesanan : pesan
# myir : myir
# ketersediaan : sedia
# hasilnya : hasil
# lokasi : lokasi
# ter : ter
# cover : cover
# bebe : bebe
# bantu : bantu
# applikasi : applikasi
# login : login
# tercepat : cepat
# pengaduan : adu
# perihal : perihal
# perbaikan : baik
# cepat : cepat
# pembatalan : batal
# karna : karna
# butuh : butuh
# cpt : cpt
# tersambung : sambung
# tanggal : tanggal
# mei : mei
# gagal : gagal
# masukin : masukin
# otp : otp
# berbeda : beda
# blom : blom
# dibuka : buka
# apk : apk
# log : log
# ketik : ketik
# salah : salah
# pdahal : pdahal
# bner : bner
# dateng : dateng
# alesannya : alesannya
# jarak : jarak
# odp : odp
# tarik : tarik
# kab : kab
# solusi : solusi
# disuatu : suatu
# perumahan : rumah
# sambung : sambung
# full : full
# adalagi : adalagi
# penambahan : tambah
# nunggu : nunggu
# tersedia : sedia
# slot : slot
# kosong : kosong
# bulankemaren : bulankemaren
# bln : bln
# tagihanya : tagihanya
# ndk : ndk
# ngonek : ngonek
# pusat : pusat
# babii : babi
# beritanya : berita
# minggu : minggu
# please : please
# messenger : messenger
# dibayar : bayar
# koreksi : koreksi
# complain : complain
# indhihome : indhihome
# los : los
# helpp : helpp
# registrasi : registrasi
# pendaftaran : daftar
# verifikasi : verifikasi
# dibilang : bilang
# penuh : penuh
# tiket : tiket
# pengajuan : aju
# cancel : cancel
# dasar : dasar
# kampret : kampret
# down : down
# jualan : jual
# susah : susah
# restart : restart
# blok : blok
# lost : lost
# hallo : hallo
# seamless : seamless
# maksimal : maksimal
# device : device
# trouble : trouble
# via : via
# tweeter : tweeter
# reply : reply
# indihomeku : indihomeku
# indihomenya : indihomenya
# mengatasinya : atas
# bismillah : bismillah
# payakumbuh : payakumbuh
# sumatera : sumatera
# barat : barat
# perbulan : bulan
# kuotanya : kuota
# gb : gb
# perangkat : perangkat
# tarif : tarif
# ydah : ydah
# tibdak : tibdak
# telfon : telfon
# dikasih : kasih
# aduan : adu
# messaget : messaget
# cuman : cuman
# balas : balas
# pembeharuan : pembeharuan
# ttg : ttg
# pengembalian : kembali
# deposit : deposit
# dana : dana
# alat : alat
# diambil : ambil
# pon : pon
# kedap : kedap
# kedip : kedip
# mlu : mlu
# semaleman : maleman
# cabut : cabut
# msih : msih
# kga : kga
# ngaruh : ngaruh
# mengikuti : ikut
# langkah : langkah
# leg : leg
# simple : simple
# informasinya : informasi
# berguna : guna
# mantul : mantul
# alokasi : alokasi
# suka : suka
# tips : tips
# makasih : makasih
# info : info
# mensolusikan : solusi
# mengedukasi : edukasi
# loss : loss
# lambat : lambat
# miminnnn : miminnnn
# rupiah : rupiah
# kebutuhan : butuh
# kbm : kbm
# meng : meng
# upgrade : upgrade
# aplkasi : aplkasi
# disitu : situ
# tertulis : tulis
# bulannya : bulan
# dihitung : hitung
# kebangetan : banget
# disuruh : suruh
# bambet : bambet
# ruwet : ruwet
# parah : parah
# payah : payah
# angel : angel
# temen : temen
# tuturanmu : tutur
# langganan : langgan
# film : film
# tonton : tonton
# nambah : nambah
# badmood : badmood
# janjikan : janji
# masal : masal
# tanganin : tanganin
# besook : besook
# mending : mending
# profider : profider
# ditindaklanjuti : ditindaklanjuti
# denhan : denhan
# ngomong : ngomong
# game : game
# diblok : blok
# dibatasi : batas
# main : main
# eleven : eleven
# last : last
# shelter : shelter
# seluler : seluler
# lancar : lancar
# penjelasan : jelas
# ditangani : tangan
# bos : bos
# sebulan : bulan
# dirumahsaja : dirumahsaja
# lemot : lot
# oooooy : oooooy
# kirim : kirim
# twitter : twitter
# bls : bls
# pegih : pegih
# uang : uang
# refund : refund
# lakukan : laku
# order : order
# stb : stb
# pakai : pakai
# bantuanya : bantuanya
# muh : muh
# saleh : saleh
# thahir : thahir
# muhammad : muhammad
# ismail : ismail
# nyala : nyala
# kalinya : kali
# telp : telp
# diangkat : angkat
# ttp : ttp
# ancur : ancur
# gamer : gamer
# teratasi : atas
# aduuuuhhh : aduuuuhhh
# gimna : gimna
# nyambung : nyambung
# doank : doank
# jlek : jlek
# normal : normal
# jayapura : jayapura
# sdah : sdah
# alasan : alas
# infonya : info
# pkl : pkl
# ditindak : tindak
# tks : tks
# {'layanan': 'layan', 'sod': 'sod', 'halo': 'halo', 'sudh': 'sudh', 'internet': 'internet', 'sya': 'sya', 'bsa': 'bsa', 'udh': 'udh', 'lbh': 'lbh', 'rb': 'rb', 'pulsa': 'pulsa', 'pke': 'pke', 'nlfn': 'nlfn', 'proses': 'proses', 'teruskan': 'terus', 'pertamakali': 'pertamakali', 'tlfn': 'tlfn', 'suruh': 'suruh', 'bayar': 'bayar', 'tagihan': 'tagih', 'perbaiki': 'baik', 'lgsung': 'lgsung', '': '', 'tolong': 'tolong', 'wifi': 'wifi', 'gangguan': 'ganggu', 'harapan': 'harap', 'indihome': 'indihome', 'menurunkan': 'turun', 'normalisasi': 'normalisasi', 'harga': 'harga', 'provider': 'provider', 'sewa': 'sewa', 'modem': 'modem', 'ppn': 'ppn', 'dpt': 'dpt', 'mbps': 'mbps', 'belom': 'bom', 'home': 'home', 'fiber': 'fiber', 'masuk': 'masuk', 'murah': 'murah', 'gua': 'gua', 'gam': 'gam', 'jaringan': 'jaring', 'gmna': 'gmna', 'kerja': 'kerja', 'niih': 'niih', 'cek': 'cek', 'yaa': 'yaa', 'lihat': 'lihat', 'udah': 'udah', 'perasaan': 'asa', 'masyarakat': 'masyarakat', 'kota': 'kota', 'kupang': 'kupang', 'tertimpa': 'timpa', 'bencana': 'bencana', 'tlg': 'tlg', 'hai': 'hai', 'min': 'min', 'kak': 'kak', 'inbox': 'inbox', 'ribu': 'ribu', 'kemana': 'mana', 'keadilan': 'adil', 'rakyat': 'rakyat', 'indonesia': 'indonesia', 'cuk': 'cuk', 'turun': 'turun', 'tarip': 'tarip', 'gue': 'gue', 'lahhhh': 'lahhhh', 'admin': 'admin', 'nanya': 'nanya', 'selamat': 'selamat', 'malam': 'malam', 'pengguna': 'guna', 'memangnya': 'memang', 'jam': 'jam', 'onlinenya': 'onlinenya', 'terima': 'terima', 'kasih': 'kasih', 'janji': 'janji', 'tinggal': 'tinggal', 'janjinya': 'janji', 'bermasalah': 'masalah', 'lapor': 'lapor', 'jawabannya': 'jawab', 'dicek': 'cek', 'nggk': 'nggk', 'kelar': 'kelar', 'minipack': 'minipack', 'indikorea': 'indikorea', 'channelnya': 'channelnya', 'mengajukan': 'aju', 'penggantian': 'ganti', 'router': 'router', 'warna': 'warna', 'item': 'item', 'diganti': 'ganti', 'putih': 'putih', 'rusak': 'rusak', 'jangkauannya': 'jangkau', 'petunjuk': 'tunjuk', 'berhenti': 'henti', 'berlangganan': 'langgan', 'aplikasi': 'aplikasi', 'karaoke': 'karaoke', 'cari': 'cari', 'ngebut': 'ngebut', 'koneksi': 'koneksi', 'syart': 'syart', 'pasang': 'pasang', 'bagimana': 'bagimana', 'promo': 'promo', 'bobrok': 'bobrok', 'terputus': 'putus', 'met': 'met', 'siang': 'siang', 'libur': 'libur', 'spt': 'spt', 'lebaran': 'lebaran', 'free': 'free', 'open': 'open', 'all': 'all', 'channel': 'channel', 'nggak': 'nggak', 'dibantu': 'bantu', 'pelanggan': 'langgan', 'menambah': 'tambah', 'titik': 'titik', 'kode': 'kode', 'hubungi': 'hubung', 'witel': 'witel', 'teknisi': 'teknisi', 'hub': 'hub', 'followup': 'followup', 'ribet': 'ribet', 'indi': 'indi', 'sobat': 'sobat', 'terimakasih': 'terimakasih', 'berinteraksi': 'interaksi', 'official': 'official', 'akun': 'akun', 'indihomecare': 'indihomecare', 'mempercepat': 'cepat', 'penanganan': 'tangan', 'keluhan': 'keluh', 'permintaan': 'minta', 'lengkapi': 'lengkap', 'data': 'data', 'rmh': 'rmh', 'eror': 'eror', 'daerah': 'daerah', 'batu': 'batu', 'jaya': 'jaya', 'karawang': 'karawang', 'gmn': 'gmn', 'manggil': 'manggil', 'tukang': 'tukang', 'servisnya': 'servis', 'server': 'server', 'dns': 'dns', 'mati': 'mati', 'signal': 'signal', 'kemarin': 'kemarin', 'pdhl': 'pdhl', 'merestart': 'merestart', 'ulang': 'ulang', 'indiehome': 'indiehome', 'laporkan': 'lapor', 'kekantor': 'kantor', 'sampe': 'sampe', 'muncul': 'muncul', 'harusny': 'harusny', 'opsi': 'opsi', 'random': 'random', 'password': 'password', 'terjadwal': 'jadwal', 'perhari': 'hari', 'karen': 'karen', 'pemanfaatm': 'pemanfaatm', 'skrg': 'skrg', 'untk': 'untk', 'bisnis': 'bisnis', 'hotspot': 'hotspot', 'sdikit': 'sdikit', 'merpotkan': 'merpotkan', 'mesti': 'mesti', 'mengganti': 'ganti', 'laporan': 'lapor', 'follow': 'follow', 'hapal': 'hapal', 'lupa': 'lupa', 'gadget': 'gadget', 'terhubung': 'hubung', 'reset': 'reset', 'gimana': 'gimana', 'papua': 'papua', 'padam': 'padam', 'toleransi': 'toleransi', 'pembayaran': 'bayar', 'in': 'in', 'pagi': 'pagi', 'error': 'error', 'urgent': 'urgent', 'b ...
# ------------------------
# Pandas Apply:   0%|          | 0/192 [00:00<?, ?it/s]
#                                                comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo... sudh 1 bulan internet sya g bsa d pake...
# 2    halo  ... tolong dong... wifi saya sudah tiga ...
# 3    harapan saya sih indihome bisa menurunkan (nor...
# 4    wifi gua tiba-tiba gam ada jaringan, gmna mau ...
# ..                                                 ...
# 279  kapan normal jaringan indihome di jayapura, sd...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah 2hari
# 282  tolong bantu infonya : 3 hari ini wifi kami td...
# 283          halo min seamless maksimal berapa device?
#
#                                       cleaning_comment  \
# 0         layanan sod apa masih ada atau sdh tidak ada
# 1    halo sudh bulan internet sya bsa pake udh lbh ...
# 2    halo tolong dong wifi saya sudah tiga hari ini...
# 3    harapan saya sih indihome bisa menurunkan norm...
# 4    wifi gua tiba tiba gam ada jaringan gmna mau k...
# ..                                                 ...
# 279  kapan normal jaringan indihome jayapura sdah s...
# 280                     internet saya tiba tiba hilang
# 281         internet saya tiba tiba hilang sudah  hari
# 282  tolong bantu infonya hari ini wifi kami tdk la...
# 283          halo min seamless maksimal berapa device
#
#                                             tokenisasi  \
# 0    [layanan, sod, apa, masih, ada, atau, sdh, tid...
# 1    [halo, sudh, bulan, internet, sya, bsa, pake, ...
# 2    [halo, tolong, dong, wifi, saya, sudah, tiga, ...
# 3    [harapan, saya, sih, indihome, bisa, menurunka...
# 4    [wifi, gua, tiba, tiba, gam, ada, jaringan, gm...
# ..                                                 ...
# 279  [kapan, normal, jaringan, indihome, jayapura, ...
# 280               [internet, saya, tiba, tiba, hilang]
# 281  [internet, saya, tiba, tiba, hilang, sudah, hari]
# 282  [tolong, bantu, infonya, hari, ini, wifi, kami...
# 283  [halo, min, seamless, maksimal, berapa, device, ]
#
#                                               stopword  \
# 0                                       [layanan, sod]
# 1    [halo, sudh, internet, sya, bsa, udh, lbh, rb,...
# 2                     [halo, tolong, wifi, gangguan, ]
# 3    [harapan, indihome, menurunkan, normalisasi, h...
# 4    [wifi, gua, gam, jaringan, gmna, kerja, niih, ...
# ..                                                 ...
# 279  [normal, jaringan, indihome, jayapura, sdah, s...
# 280                                 [internet, hilang]
# 281                                 [internet, hilang]
# 282  [tolong, bantu, infonya, wifi, lancar, pkl, pk...
# 283          [halo, min, seamless, maksimal, device, ]
#
#                                               stemming
# 0                                         [layan, sod]
# 1    [halo, sudh, internet, sya, bsa, udh, lbh, rb,...
# 2                       [halo, tolong, wifi, ganggu, ]
# 3    [harap, indihome, turun, normalisasi, harga, p...
# 4     [wifi, gua, gam, jaring, gmna, kerja, niih, gua]
# ..                                                 ...
# 279  [normal, jaring, indihome, jayapura, sdah, bul...
# 280                                 [internet, hilang]
# 281                                 [internet, hilang]
# 282  [tolong, bantu, info, wifi, lancar, pkl, pkl, ...
# 283          [halo, min, seamless, maksimal, device, ]
#
# [192 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                                         [layan, sod]
# 1    [halo, sudh, internet, sya, bsa, udh, lbh, rb,...
# 2                       [halo, tolong, wifi, ganggu, ]
# 3    [harap, indihome, turun, normalisasi, harga, p...
# 4     [wifi, gua, gam, jaring, gmna, kerja, niih, gua]
# ..                                                 ...
# 279  [normal, jaring, indihome, jayapura, sdah, bul...
# 280                                 [internet, hilang]
# 281                                 [internet, hilang]
# 282  [tolong, bantu, info, wifi, lancar, pkl, pkl, ...
# 283          [halo, min, seamless, maksimal, device, ]
#
# [192 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_5.xlsx')
