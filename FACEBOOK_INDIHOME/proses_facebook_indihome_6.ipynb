# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_6.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Duh akhir2 ini indihome kok parah sekali, stre...
# 1      Wifi los, saya butuh banget.. Kerjaan numpuk...
# 2    Damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    Tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 292                                                Cpm
# 293                       Tolong di cek CHAT SAYA !!!!
# 294        Tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    Saya sudah inbox tolong dibalas
#
# [297 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 31

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Duh akhir2 ini indihome kok parah sekali, stre...
# 1      Wifi los, saya butuh banget.. Kerjaan numpuk...
# 2    Damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    Tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 290  Min, ini tadi di beranda ada nongol iklan ini ...
# 293                       Tolong di cek CHAT SAYA !!!!
# 294        Tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    Saya sudah inbox tolong dibalas
#
# [252 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    duh akhir2 ini indihome kok parah sekali, stre...
# 1      wifi los, saya butuh banget.. kerjaan numpuk...
# 2    damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 290  min, ini tadi di beranda ada nongol iklan ini ...
# 293                       tolong di cek chat saya !!!!
# 294        tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
# [252 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    duh akhir2 ini indihome kok parah sekali, stre...
# 1      wifi los, saya butuh banget.. kerjaan numpuk...
# 2    damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 290  min, ini tadi di beranda ada nongol iklan ini ...
# 293                       tolong di cek chat saya !!!!
# 294        tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                       cleaning_comment
# 0    duh akhir  ini indihome kok parah sekali strea...
# 1           wifi los saya butuh banget kerjaan numpuk
# 2    damn wifi los mulai kemarin sampai sekarang di...
# 3    ini gimana sih udh dilapor kan msih aja idupin...
# 4    tiket pengaduan gada kejelasannya tiba  udah s...
# ..                                                 ...
# 290  min ini tadi beranda ada nongol iklan ini dan ...
# 293                              tolong cek chat saya
# 294           tlong balas inbok saya dan segera benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
# [252 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    duh akhir2 ini indihome kok parah sekali, stre...
# 1      wifi los, saya butuh banget.. kerjaan numpuk...
# 2    damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 290  min, ini tadi di beranda ada nongol iklan ini ...
# 293                       tolong di cek chat saya !!!!
# 294        tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                       cleaning_comment  \
# 0    duh akhir  ini indihome kok parah sekali strea...
# 1           wifi los saya butuh banget kerjaan numpuk
# 2    damn wifi los mulai kemarin sampai sekarang di...
# 3    ini gimana sih udh dilapor kan msih aja idupin...
# 4    tiket pengaduan gada kejelasannya tiba  udah s...
# ..                                                 ...
# 290  min ini tadi beranda ada nongol iklan ini dan ...
# 293                              tolong cek chat saya
# 294           tlong balas inbok saya dan segera benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                             tokenisasi
# 0    [duh, akhir, ini, indihome, kok, parah, sekali...
# 1    [wifi, los, saya, butuh, banget, kerjaan, nump...
# 2    [damn, wifi, los, mulai, kemarin, sampai, seka...
# 3    [ini, gimana, sih, udh, dilapor, kan, msih, aj...
# 4    [tiket, pengaduan, gada, kejelasannya, tiba, u...
# ..                                                 ...
# 290  [min, ini, tadi, beranda, ada, nongol, iklan, ...
# 293                        [tolong, cek, chat, saya, ]
# 294   [tlong, balas, inbok, saya, dan, segera, benahi]
# 295                                  [cek, pesan, min]
# 296              [saya, sudah, inbox, tolong, dibalas]
#
# [252 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    duh akhir2 ini indihome kok parah sekali, stre...
# 1      wifi los, saya butuh banget.. kerjaan numpuk...
# 2    damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 290  min, ini tadi di beranda ada nongol iklan ini ...
# 293                       tolong di cek chat saya !!!!
# 294        tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                       cleaning_comment  \
# 0    duh akhir  ini indihome kok parah sekali strea...
# 1           wifi los saya butuh banget kerjaan numpuk
# 2    damn wifi los mulai kemarin sampai sekarang di...
# 3    ini gimana sih udh dilapor kan msih aja idupin...
# 4    tiket pengaduan gada kejelasannya tiba  udah s...
# ..                                                 ...
# 290  min ini tadi beranda ada nongol iklan ini dan ...
# 293                              tolong cek chat saya
# 294           tlong balas inbok saya dan segera benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                             tokenisasi  \
# 0    [duh, akhir, ini, indihome, kok, parah, sekali...
# 1    [wifi, los, saya, butuh, banget, kerjaan, nump...
# 2    [damn, wifi, los, mulai, kemarin, sampai, seka...
# 3    [ini, gimana, sih, udh, dilapor, kan, msih, aj...
# 4    [tiket, pengaduan, gada, kejelasannya, tiba, u...
# ..                                                 ...
# 290  [min, ini, tadi, beranda, ada, nongol, iklan, ...
# 293                        [tolong, cek, chat, saya, ]
# 294   [tlong, balas, inbok, saya, dan, segera, benahi]
# 295                                  [cek, pesan, min]
# 296              [saya, sudah, inbox, tolong, dibalas]
#
#                                               stopword
# 0    [duh, indihome, parah, streaming, youtube, buf...
# 1        [wifi, los, butuh, banget, kerjaan, numpuk, ]
# 2              [damn, wifi, los, kemarin, diperbaikin]
# 3    [gimana, udh, dilapor, msih, idupin, internetn...
# 4    [tiket, pengaduan, gada, kejelasannya, udah, s...
# ..                                                 ...
# 290  [min, beranda, nongol, iklan, disuruh, page, a...
# 293                              [tolong, cek, chat, ]
# 294                      [tlong, balas, inbok, benahi]
# 295                                  [cek, pesan, min]
# 296                           [inbox, tolong, dibalas]
#
# [252 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 750
# ------------------------
# duh : duh
# indihome : indihome
# parah : parah
# streaming : streaming
# youtube : youtube
# buffering : buffering
# padaha : padaha
# tolong : tolong
# perbaiki : baik
# stabilan : stabil
# kecepatannya : cepat
# janji : janji
# mbps : mbps
# realitanya : realitanya
# wifi : wifi
# los : los
# butuh : butuh
# banget : banget
# kerjaan : kerja
# numpuk : numpuk
#  :
# damn : damn
# kemarin : kemarin
# diperbaikin : diperbaikin
# gimana : gimana
# udh : udh
# dilapor : lapor
# msih : msih
# idupin : idupin
# internetnya : internetnya
# kmren : kmren
# tiket : tiket
# pengaduan : adu
# gada : gada
# kejelasannya : jelas
# udah : udah
# selesai : selesai
# progresnya : progres
# modem : modem
# diganti : ganti
# antena : antena
# selamat : selamat
# siang : siang
# min : min
# maaf : maaf
# ganggu : ganggu
# apakaj : apakaj
# cek : cek
# tagihan : tagih
# sudaj : sudaj
# terbayar : bayar
# bayar : bayar
# wifinya : wifinya
# email : email
# masuk : masuk
# ringkasan : ringkas
# indihomenya : indihomenya
# terima : terima
# terkoneksi : koneksi
# trouble : trouble
# tetangga : tetangga
# samping : samping
# rumah : rumah
# aman : aman
# tips : tips
# bermanfaat : manfaat
# dicoba : coba
# deh : deh
# daftar : daftar
# gmna : gmna
# jaringan : jaring
# internet : internet
# jayapura : jayapura
# sebulan : bulan
# mati : mati
# dibayar : bayar
# jaringannya : jaring
# tersambung : sambung
# kagak : kagak
# kabel : kabel
# fiber : fiber
# putus : putus
# teknisi : teknisi
# dtg : dtg
# kerumah : rumah
# perumahan : rumah
# lgi : lgi
# cor : cor
# ketarik : tarik
# mobil : mobil
# moln : moln
# pon : pon
# merah : merah
# cabut : cabut
# biru : biru
# pasang : pasang
# gitu : gitu
# ngaruh : ngaruh
# tlpn : tlpn
# paket : paket
# nelpon : nelpon
# all : all
# operator : operator
# wajib : wajib
# pulsa : pulsa
# saia : saia
# tewas : tewas
# malam : malam
# proses : proses
# aneh : aneh
# satupun : satu
# lho : lho
# lampu : lampu
# mateng : mateng
# berkedip : kedip
# kecamatan : camat
# baros : baros
# kota : kota
# sukabumi : sukabumi
# jawabarat : jawabarat
# mengalami : alami
# mohon : mohon
# tindak : tindak
# lanjuti : lanjut
# deret : deret
# jawara : jawara
# emang : emang
# lumayan : lumayan
# kecepatan : cepat
# mola : mola
# lemot : lot
# kereeen : kereeen
# bagus : bagus
# bermanfaatt : bermanfaatt
# led : led
# menit : menit
# gangguan : ganggu
# tanjung : tanjung
# barat : barat
# kah : kah
# nggak : nggak
# yaa : yaa
# layanan : layan
# normal : normal
# terimakasih : terimakasih
# bbrp : bbrp
# stabil : stabil
# permisi : permisi
# knp : knp
# power : power
# phone : phone
# hidup : hidup
# kedap : kedap
# kedip : kedip
# solusinya : solusi
# masang : masang
# siaran : siar
# euro : euro
# kuat : kuat
# meter : meter
# jga : jga
# respon : respon
# admin : admin
# laporan : lapor
# gabisa : gabisa
# didowload : didowload
# nyala : nyala
# koneksi : koneksi
# inet : inet
# balekambang : balekambang
# kramat : kramat
# jati : jati
# bantu : bantu
# refresh : refresh
# basis : basis
# telkom : telkom
# down : down
# mantul : mantul
# tipsnya : tipsnya
# patut : patut
# bener : bener
# dirawat : rawat
# modemnya : modem
# info : info
# tpi : tpi
# kak : kak
# perihal : perihal
# banyu : banyu
# yahhhh : yahhhh
# stb : stb
# indihomeku : indihomeku
# instal : instal
# incompatible : incompatible
# trus : trus
# bgm : bgm
# keluhkan : keluh
# kantor : kantor
# blm : blm
# ditelpon : telpon
# pusat : pusat
# error : error
# rto : rto
# saran : saran
# inbox : inbox
# selesnya : les
# sok : sok
# sibuk : sibuk
# tlp : tlp
# daerah : daerah
# gianyar : gianyar
# membiarkan : biar
# keberadaan : ada
# website : website
# resmi : resmi
# adminnya : adminnya
# dihubungi : hubung
# berlagak : lagak
# petugas : tugas
# halo : halo
# dibantu : bantu
# keluarga : keluarga
# melaporkan : lapor
# keluhan : keluh
# ditindaklanjuti : ditindaklanjuti
# nomor : nomor
# in : in
# dritdi : dritdi
# nunggu : nunggu
# berubah : ubah
# statusnya : status
# penanganan : tangan
# maap : maap
# knapa : knapa
# pengontrolan : kontrol
# bantuan : bantu
# tlong : tlong
# btuh : btuh
# sya : sya
# kerja : kerja
# signal : signal
# off : off
# stiap : stiap
# habis : habis
# wkt : wkt
# tes : tes
# jam : jam
# sampe : sampe
# tnggal : tnggal
# smp : smp
# brusan : brusan
# langsung : langsung
# bln : bln
# tambahan : tambah
# biaya : biaya
# pembayaran : bayar
# mengaktifkan : aktif
# muncul : muncul
# terputus : putus
# gambar : gambar
# hitam : hitam
# bantuaannya : bantuaannya
# telpon : telpon
# ganti : ganti
# waw : waw
# panik : panik
# gimna : gimna
# indihom : indihom
# help : help
# malammm : malammm
# minnn : minnn
# estimasi : estimasi
# perpindahan : pindah
# alamat : alamat
# dateng : dateng
# menghubungi : hubung
# telfon : telfon
# ngabis : ngabis
# pasword : pasword
# wms : wms
# emailkan : email
# berhenti : henti
# berlangganan : langgan
# pemakaian : pakai
# genap : genap
# msh : msh
# kena : kena
# denda : denda
# kereen : kereen
# work : work
# panduan : pandu
# makasih : makasih
# dijwb : dijwb
# donk : donk
# mantaapp : mantaapp
# coba : coba
# aahhh : aahhh
# yth : yth
# bayaran : bayar
# juni : juni
# suda : suda
# masi : mas
# ntk : ntk
# seminggu : minggu
# download : download
# cuman : cuman
# mentol : mentol
# sec : sec
# pelanggang : langgang
# nikmati : nikmat
# kecewa : kecewa
# tehnis : tehnis
# dimana : mana
# perbaikan : baik
# diam : diam
# kasi : kasi
# trobel : trobel
# semalam : malam
# terhubung : hubung
# gaada : gaada
# emangnya : emang
# kenpa : kenpa
# contact : contact
# office : office
# teksnisi : teksnisi
# tertera : tera
# indikator : indikator
# warna : warna
# rusak : rusak
# masak : masak
# nulis : nulis
# rame : rame
# akun : akun
# telkomcare : telkomcare
# balas : balas
# menindaklanjuti : menindaklanjuti
# komplain : komplain
# gabut : gabut
# buang : buang
# anggaran : anggar
# hacker : hacker
# takedown : takedown
# tetep : tetep
# jln : jln
# sebel : sebel
# hrs : hrs
# anak : anak
# sekolah : sekolah
# mei : mei
# eee : eee
# astaghfirullah : astaghfirullah
# kemarinnya : kemarin
# upgrade : upgrade
# mbos : mbos
# mpbs : mpbs
# kasihan : kasihan
# kost : kost
# tugas : tugas
# pelayanan : layan
# gguan : gguan
# kapel : kapel
# baikki : baikki
# sambung : sambung
# jgan : jgan
# lelet : lelet
# dri : dri
# pemasangan : pasang
# smpai : smpai
# pdhl : pdhl
# byr : byr
# disuruh : suruh
# bsa : bsa
# pagi : pagi
# ditindak : tindak
# lapor : lapor
# bnyak : bnyak
# kali : kali
# mensolusikan : solusi
# mksih : mksih
# berenti : renti
# penggunaan : guna
# dikasih : kasih
# link : link
# upload : upload
# modar : modar
# duit : duit
# waduuuhhh : waduuuhhh
# mulu : mulu
# bales : bales
# intermitten : intermitten
# mudah : mudah
# amaat : amaat
# komen : komen
# ampun : ampun
# connect : connect
# merahnya : merah
# menyala : nyala
# makan : makan
# assalamualaikum : assalamualaikum
# restar : restar
# mantulsss : mantulsss
# nambah : nambah
# ilmu : ilmu
# nanganin : nanganin
# seamless : seamless
# maksimal : maksimal
# brp : brp
# device : device
# murah : murah
# berapaan : berapa
# lambat : lambat
# weekend : weekend
# dirasakan : rasa
# teman : teman
# pelanggan : langgan
# didaerah : daerah
# senin : senin
# sore : sore
# bilngnya : bilngnya
# jum : jum
# tunggu : tunggu
# ngk : ngk
# gmn : gmn
# hri : hri
# mahal : mahal
# tingkatkan : tingkat
# pilih : pilih
# harga : harga
# bohong : bohong
# pengguna : guna
# tanggal : tanggal
# ngelos : ngelos
# ketar : ketar
# ketir : tir
# dipake : dipake
# usaha : usaha
# ngadu : ngadu
# susahnya : susah
# miminnya : miminnya
# chat : chat
# mps : mps
# matikan : mati
# telfonnya : telfonnya
# gunain : gunain
# only : only
# extender : extender
# pandemi : pandemi
# pindah : pindah
# domisili : domisili
# instalasinya : instalasi
# ikutan : ikut
# kemaren : kemaren
# turun : turun
# sesuai : sesuai
# detail : detail
# potongan : potong
# deposit : deposit
# nice : nice
# infonya : info
# slamat : slamat
# tamba : tamba
# bola : bola
# brapa : brapa
# wih : wih
# indonesia : indonesia
# infoooo : infoooo
# asik : asik
# indihoy : indihoy
# klu : klu
# hujan : hujan
# koneksinya : koneksi
# salah : salah
# pulogebang : pulogebang
# diperbaiki : baik
# fup : fup
# ooh : ooh
# lemotnyaaa : lemotnyaaa
# internetku : internetku
# over : over
# bgmn : bgmn
# menormalkan : normal
# tarifnya : tarif
# wkwkwkwkw : wkwkwkwkw
# promosinya : promosi
# kenceng : kenceng
# indigo : indigo
# kebanggaan : bangga
# complain : complain
# inditod : inditod
# ane : ane
# naek : naek
# promo : promo
# rb : rb
# naikin : naikin
# aplikasi : aplikasi
# myindihome : myindihome
# drakor : drakor
# ditelegram : telegram
# cepat : cepat
# wlan : wlan
# reset : reset
# tekan : tekan
# tombolnya : tombol
# nonton : nonton
# yuotube : yuotube
# keberanda : beranda
# penyebabnya : sebab
# wilayah : wilayah
# aceh : aceh
# buka : buka
# telegram : telegram
# iya : iya
# doong : doong
# mintol : mintol
# sod : sod
# patokan : patok
# apalahi : apalahi
# sosmed : sosmed
# wahhh : wahhh
# berguna : guna
# nuhun : nuhun
# aahh : aahh
# kalu : kalu
# gemer : gemer
# lemoot : lemoot
# colokan : colok
# router : router
# hidupin : hidupin
# boss : boss
# kasih : kasih
# konsistent : konsistent
# giliran : gilir
# reguler : reguler
# minum : minum
# obat : obat
# motogp : motogp
# ditonton : tonton
# sebenernya : sebenernya
# speed : speed
# gb : gb
# mencapai : capai
# layanannya : layan
# bulanan : bulan
# tanggak : tanggak
# cocok : cocok
# wihhhhhh : wihhhhhh
# indi : indi
# kebanggan : banggan
# konsisten : konsisten
# complainnnya : complainnnya
# diarahkan : arah
# kesini : kesini
# page : page
# penuh : penuh
# yacek : yacek
# mntol : mntol
# mkasih : mkasih
# seamles : seamles
# sinyalnya : sinyal
# mengecewakan : kecewa
# kpn : kpn
# copot : copot
# pengaruh : pengaruh
# lokasi : lokasi
# kebun : kebun
# jeruk : jeruk
# jakarta : jakarta
# wib : wib
# opo : opo
# karepe : karepe
# lancar : lancar
# payah : payah
# pemula : mula
# dftr : dftr
# kantornya : kantor
# tasikmalaya : tasikmalaya
# dibalas : balas
# operasional : operasional
# lapangan : lapang
# dilanjutkan : lanjut
# karna : karna
# membawa : bawa
# lan : lan
# penghubung : hubung
# laptop : laptop
# data : data
# menunggu : tunggu
# toko : toko
# terganggu : ganggu
# losss : losss
# sinyal : sinyal
# jawabannya : jawab
# buruk : buruk
# bnrin : bnrin
# komplen : komplen
# bnr : bnr
# pengajuan : aju
# penambahan : tambah
# cloud : cloud
# storagenya : storagenya
# posting : posting
# dicari : cari
# mantaaaaapppp : mantaaaaapppp
# care : care
# tanggaan : tangga
# hahahahaha : hahahahaha
# dmn : dmn
# kwalitas : kwalitas
# pekan : pekan
# drastis : drastis
# stroomnet : stroomnet
# panen : panen
# kesempatan : sempat
# ambil : ambil
# baca : baca
# woi : woi
# bang : bang
# benerin : benerin
# main : main
# leg : leg
# nga : nga
# game : game
# gua : gua
# renew : renew
# gagal : gagal
# pengen : ken
# alasannya : alas
# boxnya : boxnya
# alias : alias
# busuk : busuk
# tempatku : tempat
# menjangkau : jangkau
# minn : minn
# dikurangi : rang
# ganguan : ganguan
# simpen : simpen
# file : file
# essential : essential
# rp : rp
# terealisasi : realisasi
# kencang : kencang
# karto : karto
# telat : telat
# dimatikan : mati
# dirugikan : rugi
# lbh : lbh
# indihomecare : indihomecare
# twiter : twiter
# udaah : udaah
# inbok : inbok
# problem : problem
# transfer : transfer
# ktp : ktp
# selfie : selfie
# punyaku : punya
# konek : konek
# vpn : vpn
# temans : temans
# provider : provider
# perluas : luas
# kampung : kampung
# sebelah : belah
# dapet : dapet
# kebutuhan : butuh
# jngan : jngan
# cman : cman
# pinggir : pinggir
# jalan : jalan
# pasangin : pasangin
# jaman : jaman
# spert : spert
# skarnag : skarnag
# smua : smua
# serba : serba
# dirumah : rumah
# pda : pda
# lakukan : laku
# percepat : cepat
# dibandingkan : banding
# melapor : lapor
# tgl : tgl
# informasikan : informasi
# perkembangan : kembang
# dapatnya : dapat
# akses : akses
# doank : doank
# nongol : nongol
# memutuskan : putus
# pasangan : pasang
# conec : conec
# pemindahan : pindah
# diperluas : luas
# ngajuin : ngajuin
# orang : orang
# hadewwwwhhh : hadewwwwhhh
# luas : luas
# brenti : brenti
# langganan : langgan
# eror : eror
# keputus : putus
# kualitasnya : kualitas
# ngakak : ngakak
# iklan : iklan
# susah : susah
# solusi : solusi
# registrasinya : registrasi
# gan : gan
# keunggulannya : unggul
# menurun : turun
# gara : gara
# ngeluh : ngeluh
# komplanan : komplanan
# bedanya : beda
# poenix : poenix
# denagan : denagan
# telepon : telepon
# skrng : skrng
# lagu : lagu
# memperluas : luas
# barusan : barusan
# ngapa : ngapa
# ngapain : ngapain
# gag : gag
# jarak : jarak
# instalasi : instalasi
# free : free
# tnya : tnya
# berbentuk : bentuk
# penjualan : jual
# vocer : vocer
# diindihome : diindihome
# alat : alat
# terpasang : pasang
# beralih : alih
# home : home
# sblumnya : sblumnya
# trima : trima
# full : full
# kmrn : kmrn
# dikasi : kasi
# via : via
# direspon : direspon
# selebihnya : lebih
# dicuekin : dicuekin
# biarkan : biar
# terhambat : hambat
# jangkauan : jangkau
# terbatas : batas
# beranda : beranda
# benahi : benah
# pesan : pesan
# {'duh': 'duh', 'indihome': 'indihome', 'parah': 'parah', 'streaming': 'streaming', 'youtube': 'youtube', 'buffering': 'buffering', 'padaha': 'padaha', 'tolong': 'tolong', 'perbaiki': 'baik', 'stabilan': 'stabil', 'kecepatannya': 'cepat', 'janji': 'janji', 'mbps': 'mbps', 'realitanya': 'realitanya', 'wifi': 'wifi', 'los': 'los', 'butuh': 'butuh', 'banget': 'banget', 'kerjaan': 'kerja', 'numpuk': 'numpuk', '': '', 'damn': 'damn', 'kemarin': 'kemarin', 'diperbaikin': 'diperbaikin', 'gimana': 'gimana', 'udh': 'udh', 'dilapor': 'lapor', 'msih': 'msih', 'idupin': 'idupin', 'internetnya': 'internetnya', 'kmren': 'kmren', 'tiket': 'tiket', 'pengaduan': 'adu', 'gada': 'gada', 'kejelasannya': 'jelas', 'udah': 'udah', 'selesai': 'selesai', 'progresnya': 'progres', 'modem': 'modem', 'diganti': 'ganti', 'antena': 'antena', 'selamat': 'selamat', 'siang': 'siang', 'min': 'min', 'maaf': 'maaf', 'ganggu': 'ganggu', 'apakaj': 'apakaj', 'cek': 'cek', 'tagihan': 'tagih', 'sudaj': 'sudaj', 'terbayar': 'bayar', 'bayar': 'bayar', 'wifinya': 'wifinya', 'email': 'email', 'masuk': 'masuk', 'ringkasan': 'ringkas', 'indihomenya': 'indihomenya', 'terima': 'terima', 'terkoneksi': 'koneksi', 'trouble': 'trouble', 'tetangga': 'tetangga', 'samping': 'samping', 'rumah': 'rumah', 'aman': 'aman', 'tips': 'tips', 'bermanfaat': 'manfaat', 'dicoba': 'coba', 'deh': 'deh', 'daftar': 'daftar', 'gmna': 'gmna', 'jaringan': 'jaring', 'internet': 'internet', 'jayapura': 'jayapura', 'sebulan': 'bulan', 'mati': 'mati', 'dibayar': 'bayar', 'jaringannya': 'jaring', 'tersambung': 'sambung', 'kagak': 'kagak', 'kabel': 'kabel', 'fiber': 'fiber', 'putus': 'putus', 'teknisi': 'teknisi', 'dtg': 'dtg', 'kerumah': 'rumah', 'perumahan': 'rumah', 'lgi': 'lgi', 'cor': 'cor', 'ketarik': 'tarik', 'mobil': 'mobil', 'moln': 'moln', 'pon': 'pon', 'merah': 'merah', 'cabut': 'cabut', 'biru': 'biru', 'pasang': 'pasang', 'gitu': 'gitu', 'ngaruh': 'ngaruh', 'tlpn': 'tlpn', 'paket': 'paket', 'nelpon': 'nelpon', 'all': 'all', 'operator': 'operator', 'wajib': 'wajib', 'pulsa': 'pulsa', 'saia': 'saia', 'tewas': 'tewas', 'malam': 'malam', 'proses': 'proses', 'aneh': 'aneh', 'satupun': 'satu', 'lho': 'lho', 'lampu': 'lampu', 'mateng': 'mateng', 'berkedip': 'kedip', 'kecamatan': 'camat', 'baros': 'baros', 'kota': 'kota', 'sukabumi': 'sukabumi', 'jawabarat': 'jawabarat', 'mengalami': 'alami', 'mohon': 'mohon', 'tindak': 'tindak', 'lanjuti': 'lanjut', 'deret': 'deret', 'jawara': 'jawara', 'emang': 'emang', 'lumayan': 'lumayan', 'kecepatan': 'cepat', 'mola': 'mola', 'lemot': 'lot', 'kereeen': 'kereeen', 'bagus': 'bagus', 'bermanfaatt': 'bermanfaatt', 'led': 'led', 'menit': 'menit', 'gangguan': 'ganggu', 'tanjung': 'tanjung', 'barat': 'barat', 'kah': 'kah', 'nggak': 'nggak', 'yaa': 'yaa', 'layanan': 'layan', 'normal': 'normal', 'terimakasih': 'terimakasih', 'bbrp': 'bbrp', 'stabil': 'stabil', 'permisi': 'permisi', 'knp': 'knp', 'power': 'power', 'phone': 'phone', 'hidup': 'hidup', 'kedap': 'kedap', 'kedip': 'kedip', 'solusinya': 'solusi', 'masang': 'masang', 'siaran': 'siar', 'euro': 'euro', 'kuat': 'kuat', 'meter': 'meter', 'jga': 'jga', 'respon': 'respon', 'admin': 'admin', 'laporan': 'lapor', 'gabisa': 'gabisa', 'didowload': 'didowload', 'nyala': 'nyala', 'koneksi': 'koneksi', 'inet': 'inet', 'balekambang': 'balekambang', 'kramat': 'kramat', 'jati': 'jati', 'bantu': 'bantu', 'refresh': 'refresh', 'basis': 'basis', 'telkom': 'telkom', 'down': 'down', 'mantul': 'mantul', 'tipsnya': 'tipsnya', 'patut': 'patut', 'bener': 'bener', 'dirawat': 'rawat', 'modemnya': 'modem', 'info': 'info', 'tpi': 'tpi', 'kak': 'kak', 'perihal': 'perihal', 'banyu': 'banyu', 'yahhhh': 'yahhhh', 'stb': 'stb', 'indihomeku': 'indihomeku', 'instal': 'instal', 'incompatible': 'incompatible', 'trus': 'trus', 'bgm': 'bgm', 'keluhkan': 'keluh', 'kantor': 'kantor', 'blm': 'blm', 'ditelpon': 'telpon', 'pusat': 'pusat', 'error': 'error', 'rto': 'rto', 'saran': 'saran', 'inbox': 'inbox', 'selesnya': 'les', 'sok': 'sok', 'sibuk': 'sibuk', 'tlp ...
# ------------------------
# Pandas Apply:   0%|          | 0/252 [00:00<?, ?it/s]
#                                                comment  \
# 0    duh akhir2 ini indihome kok parah sekali, stre...
# 1      wifi los, saya butuh banget.. kerjaan numpuk...
# 2    damn wifi gw los mulai kemarin sampai sekarang...
# 3    ini gimana sih udh dilapor kan msih aja gk idu...
# 4    tiket pengaduan gada kejelasannya, tiba2 udah ...
# ..                                                 ...
# 290  min, ini tadi di beranda ada nongol iklan ini ...
# 293                       tolong di cek chat saya !!!!
# 294        tlong balas inbok saya dan segera di benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                       cleaning_comment  \
# 0    duh akhir  ini indihome kok parah sekali strea...
# 1           wifi los saya butuh banget kerjaan numpuk
# 2    damn wifi los mulai kemarin sampai sekarang di...
# 3    ini gimana sih udh dilapor kan msih aja idupin...
# 4    tiket pengaduan gada kejelasannya tiba  udah s...
# ..                                                 ...
# 290  min ini tadi beranda ada nongol iklan ini dan ...
# 293                              tolong cek chat saya
# 294           tlong balas inbok saya dan segera benahi
# 295                                      cek pesan min
# 296                    saya sudah inbox tolong dibalas
#
#                                             tokenisasi  \
# 0    [duh, akhir, ini, indihome, kok, parah, sekali...
# 1    [wifi, los, saya, butuh, banget, kerjaan, nump...
# 2    [damn, wifi, los, mulai, kemarin, sampai, seka...
# 3    [ini, gimana, sih, udh, dilapor, kan, msih, aj...
# 4    [tiket, pengaduan, gada, kejelasannya, tiba, u...
# ..                                                 ...
# 290  [min, ini, tadi, beranda, ada, nongol, iklan, ...
# 293                        [tolong, cek, chat, saya, ]
# 294   [tlong, balas, inbok, saya, dan, segera, benahi]
# 295                                  [cek, pesan, min]
# 296              [saya, sudah, inbox, tolong, dibalas]
#
#                                               stopword  \
# 0    [duh, indihome, parah, streaming, youtube, buf...
# 1        [wifi, los, butuh, banget, kerjaan, numpuk, ]
# 2              [damn, wifi, los, kemarin, diperbaikin]
# 3    [gimana, udh, dilapor, msih, idupin, internetn...
# 4    [tiket, pengaduan, gada, kejelasannya, udah, s...
# ..                                                 ...
# 290  [min, beranda, nongol, iklan, disuruh, page, a...
# 293                              [tolong, cek, chat, ]
# 294                      [tlong, balas, inbok, benahi]
# 295                                  [cek, pesan, min]
# 296                           [inbox, tolong, dibalas]
#
#                                               stemming
# 0    [duh, indihome, parah, streaming, youtube, buf...
# 1          [wifi, los, butuh, banget, kerja, numpuk, ]
# 2              [damn, wifi, los, kemarin, diperbaikin]
# 3    [gimana, udh, lapor, msih, idupin, internetnya...
# 4    [tiket, adu, gada, jelas, udah, selesai, progr...
# ..                                                 ...
# 290  [min, beranda, nongol, iklan, suruh, page, adm...
# 293                              [tolong, cek, chat, ]
# 294                       [tlong, balas, inbok, benah]
# 295                                  [cek, pesan, min]
# 296                             [inbox, tolong, balas]
#
# [252 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0    [duh, indihome, parah, streaming, youtube, buf...
# 1          [wifi, los, butuh, banget, kerja, numpuk, ]
# 2              [damn, wifi, los, kemarin, diperbaikin]
# 3    [gimana, udh, lapor, msih, idupin, internetnya...
# 4    [tiket, adu, gada, jelas, udah, selesai, progr...
# ..                                                 ...
# 290  [min, beranda, nongol, iklan, suruh, page, adm...
# 293                              [tolong, cek, chat, ]
# 294                       [tlong, balas, inbok, benah]
# 295                                  [cek, pesan, min]
# 296                             [inbox, tolong, balas]
#
# [252 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_6.xlsx')
