# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import string
import re
import openpyxl
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
columns = ["comment"]
df = pd.read_excel(r'C:\Users\Hp\TUGAS AKHIR 2\FACEBOOK_INDIHOME\data mentah\facebook_indihome_8.xlsx', usecols=columns)
df.head(2000)
# Out:
#                                                comment
# 0    Kok blm datang petugas ? Dijanjikan jam 8, sek...
# 1            Cek dm dong mau laporan tp ga ada balesan
# 2    Gimana ngatasi "login fail,please try again la...
# 3    Admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  Gmn klo STB tdk hidup sm skali.. Pdhl jarang d...
# 354  Nmr indihome saya 1723 0240 7998. Saya request...
# 355                                  Selamat siang ka.
# 356  Udah 3 hari belum bisa di gunakan padahal suda...
#
# [357 rows x 1 columns]

# %%
df.comment.duplicated().sum()
# Out:
# 16

# %%
df.drop_duplicates(subset="comment", keep=False, inplace=True)
df.head(2000)
# Out:
#                                                comment
# 0    Kok blm datang petugas ? Dijanjikan jam 8, sek...
# 1            Cek dm dong mau laporan tp ga ada balesan
# 2    Gimana ngatasi "login fail,please try again la...
# 3    Admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  Gmn klo STB tdk hidup sm skali.. Pdhl jarang d...
# 354  Nmr indihome saya 1723 0240 7998. Saya request...
# 355                                  Selamat siang ka.
# 356  Udah 3 hari belum bisa di gunakan padahal suda...
#
# [335 rows x 1 columns]

# %%
#case folding
df['comment'] = df['comment'].str.lower()
df.head(2000)
# Out:
#                                                comment
# 0    kok blm datang petugas ? dijanjikan jam 8, sek...
# 1            cek dm dong mau laporan tp ga ada balesan
# 2    gimana ngatasi "login fail,please try again la...
# 3    admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  gmn klo stb tdk hidup sm skali.. pdhl jarang d...
# 354  nmr indihome saya 1723 0240 7998. saya request...
# 355                                  selamat siang ka.
# 356  udah 3 hari belum bisa di gunakan padahal suda...
#
# [335 rows x 1 columns]

# %%
#cleaning text
import nltk
import string
import re
nltk.download('punkt')

#import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#proses cleaning text
def remove_special_tweet(text):
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", "", str(text)).split())
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r'\b\w{1,2}\b', ' ', str(text))
    text = re.sub(r'\s\s+',' ',  str(text))
    text = re.sub(r'\d+', ' ', str(text))
    text = re.sub(r'\b[a-zA-Z]\b', ' ', str(text))
    text = re.sub(r'/(?:https?|ftp):\/\/[\n\S]+/g, ''', ' ', str(text))
    text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', str(text))
    text = re.sub(r'[0]', r' ', str(text))
    return text
    return df
df['cleaning_comment'] = df['comment'].apply(remove_special_tweet)
df.head(2000)
# Out:
#                                                comment  \
# 0    kok blm datang petugas ? dijanjikan jam 8, sek...
# 1            cek dm dong mau laporan tp ga ada balesan
# 2    gimana ngatasi "login fail,please try again la...
# 3    admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  gmn klo stb tdk hidup sm skali.. pdhl jarang d...
# 354  nmr indihome saya 1723 0240 7998. saya request...
# 355                                  selamat siang ka.
# 356  udah 3 hari belum bisa di gunakan padahal suda...
#
#                                       cleaning_comment
# 0      kok blm datang petugas dijanjikan jam sekarang
# 1                     cek dong mau laporan ada balesan
# 2    gimana ngatasi login fail please try again lat...
# 3    admin tolong pemasangan wifinya jangan lambat ...
# 4     mohon informasi untuk layanan iflix saya kesu...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas indiho...
# 353     gmn klo stb tdk hidup skali pdhl jarang hidup
# 354  nmr indihome saya       saya request lewat app...
# 355                                     selamat siang
# 356  udah hari belum bisa gunakan padahal sudah bay...
#
# [335 rows x 2 columns]

# %%
#proses tokenisasi
def tokenisasi(text):
    text = re.split('\W+', str(text))
    return text
    return df
df['tokenisasi'] = df['cleaning_comment'].apply(tokenisasi)
df.head(2000)
# Out:
#                                                comment  \
# 0    kok blm datang petugas ? dijanjikan jam 8, sek...
# 1            cek dm dong mau laporan tp ga ada balesan
# 2    gimana ngatasi "login fail,please try again la...
# 3    admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  gmn klo stb tdk hidup sm skali.. pdhl jarang d...
# 354  nmr indihome saya 1723 0240 7998. saya request...
# 355                                  selamat siang ka.
# 356  udah 3 hari belum bisa di gunakan padahal suda...
#
#                                       cleaning_comment  \
# 0      kok blm datang petugas dijanjikan jam sekarang
# 1                     cek dong mau laporan ada balesan
# 2    gimana ngatasi login fail please try again lat...
# 3    admin tolong pemasangan wifinya jangan lambat ...
# 4     mohon informasi untuk layanan iflix saya kesu...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas indiho...
# 353     gmn klo stb tdk hidup skali pdhl jarang hidup
# 354  nmr indihome saya       saya request lewat app...
# 355                                     selamat siang
# 356  udah hari belum bisa gunakan padahal sudah bay...
#
#                                             tokenisasi
# 0    [kok, blm, datang, petugas, dijanjikan, jam, s...
# 1              [cek, dong, mau, laporan, ada, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pemasangan, wifinya, jangan, l...
# 4    [, mohon, informasi, untuk, layanan, iflix, sa...
# ..                                                 ...
# 352  [apa, selain, internetan, apa, ada, fasilitas,...
# 353  [gmn, klo, stb, tdk, hidup, skali, pdhl, jaran...
# 354  [nmr, indihome, saya, saya, request, lewat, ap...
# 355                                 [selamat, siang, ]
# 356  [udah, hari, belum, bisa, gunakan, padahal, su...
#
# [335 rows x 3 columns]

# %%
#import nltk stopword
from nltk.corpus import stopwords

#proses stopword
stopword = nltk.corpus.stopwords.words('indonesian')
stopword.extend(["nmr", "yg", "dg", "rt", "dgn", "ny", "d", 'klo','kalo', 'amp', 'biar', 'bikin', 'bilang','gak', 'ga', 'krn', 'nya', 
                 'nih', 'sih','si', 'tau', 'tdk', 'tuh', 'tai', 'juga', 'utk', 'ya','jd', 'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe',
                 'pen', 'u', 'nan', 'loh', 'rt', 'kudu', 'mks', 'wkwk', 'kwkwkw', 'an', 'lah', 'dah', 'asu', 'mjb', 'haha',
                 'yah', 'lha', 'lah', 'hihi', 'ih', 'anjir', 'bgt', 'pake', 'anj', 'bgst', 'anjir'])
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    return df
df['stopword'] = df['tokenisasi'].apply(remove_stopwords)
df.head(2000)
# Out:
#                                                comment  \
# 0    kok blm datang petugas ? dijanjikan jam 8, sek...
# 1            cek dm dong mau laporan tp ga ada balesan
# 2    gimana ngatasi "login fail,please try again la...
# 3    admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  gmn klo stb tdk hidup sm skali.. pdhl jarang d...
# 354  nmr indihome saya 1723 0240 7998. saya request...
# 355                                  selamat siang ka.
# 356  udah 3 hari belum bisa di gunakan padahal suda...
#
#                                       cleaning_comment  \
# 0      kok blm datang petugas dijanjikan jam sekarang
# 1                     cek dong mau laporan ada balesan
# 2    gimana ngatasi login fail please try again lat...
# 3    admin tolong pemasangan wifinya jangan lambat ...
# 4     mohon informasi untuk layanan iflix saya kesu...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas indiho...
# 353     gmn klo stb tdk hidup skali pdhl jarang hidup
# 354  nmr indihome saya       saya request lewat app...
# 355                                     selamat siang
# 356  udah hari belum bisa gunakan padahal sudah bay...
#
#                                             tokenisasi  \
# 0    [kok, blm, datang, petugas, dijanjikan, jam, s...
# 1              [cek, dong, mau, laporan, ada, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pemasangan, wifinya, jangan, l...
# 4    [, mohon, informasi, untuk, layanan, iflix, sa...
# ..                                                 ...
# 352  [apa, selain, internetan, apa, ada, fasilitas,...
# 353  [gmn, klo, stb, tdk, hidup, skali, pdhl, jaran...
# 354  [nmr, indihome, saya, saya, request, lewat, ap...
# 355                                 [selamat, siang, ]
# 356  [udah, hari, belum, bisa, gunakan, padahal, su...
#
#                                               stopword
# 0                    [blm, petugas, dijanjikan, jam, ]
# 1                              [cek, laporan, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pemasangan, wifinya, lambat, m...
# 4    [, mohon, informasi, layanan, iflix, kesulitan...
# ..                                                 ...
# 352           [internetan, fasilitas, indihome, tks, ]
# 353    [gmn, stb, hidup, skali, pdhl, jarang, hidup, ]
# 354  [indihome, request, app, sabtu, pagi, speed, l...
# 355                                 [selamat, siang, ]
# 356                        [udah, bayar, mohon, bantu]
#
# [335 rows x 4 columns]

# %%
#stemming
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]
    return df

df['stemming'] = df['stopword'].swifter.apply(get_stemmed_term)
df.head(2000)
# Out:
# 1089
# ------------------------
# blm : blm
# petugas : tugas
# dijanjikan : janji
# jam : jam
#  :
# cek : cek
# laporan : lapor
# balesan : balesan
# gimana : gimana
# ngatasi : ngatasi
# login : login
# fail : fail
# please : please
# try : try
# again : again
# later : later
# pusing : pusing
# admin : admin
# tolong : tolong
# pemasangan : pasang
# wifinya : wifinya
# lambat : lambat
# menunggu : tunggu
# beum : beum
# teknisi : teknisi
# nelfon : nelfon
# nunggu : nunggu
# doang : doang
# masang : masang
# coba : coba
# cari : cari
# wifi : wifi
# mohon : mohon
# informasi : informasi
# layanan : layan
# iflix : iflix
# kesulitan : sulit
# subtitle : subtitle
# bahasa : bahasa
# indonesia : indonesia
# film : film
# drama : drama
# korea : korea
# sebulan : bulan
# pdhl : pdhl
# msh : msh
# tersedia : sedia
# terimakasih : terimakasih
# gini : gin
# indihumu : indihumu
# koneksi : koneksi
# putus : putus
# daerah : daerah
# timur : timur
# ganti : ganti
# provider : provider
# masuk : masuk
# sumpah : sumpah
# mending : mending
# tutup : tutup
# kasihan : kasihan
# ppkm : ppkm
# bayar : bayar
# mahal : mahal
# kualitas : kualitas
# sampah : sampah
# ping : ping
# google : google
# pemirsa : pirsa
# kak : kak
# pindah : pindah
# lokasi : lokasi
# intalasi : intalasi
# jaringan : jaring
# telkom : telkom
# berusaha : usaha
# mengajak : ajak
# tetangga : tetangga
# mengajukan : aju
# plaza : plaza
# ngawi : ngawi
# konfirma : konfirma
# pengaduan : adu
# skarang : skarang
# kabarnya : kabar
# myindihome : myindihome
# tagihan : tagih
# milik : milik
# full : full
# dibantukah : bantu
# udah : udah
# pengajuan : aju
# perpindahan : pindah
# paket : paket
# datanya : data
# kirim : kirim
# via : via
# sms : sms
# email : email
# pesannya : pesan
# pengaduano : pengaduano
# nyala : nyala
# duit : duit
# internetku : internetku
# terhubung : hubung
# tanda : tanda
# drmh : drmh
# sya : sya
# gangguan : ganggu
# wil : wil
# banyumas : banyumas
# lol : lol
# min : min
# indihome : indihome
# berguna : guna
# device : device
# nonton : nonton
# acara : acara
# suka : suka
# stop : stop
# biarain : biarain
# hasil : hasil
# what : what
# lying : lying
# udh : udh
# restart : restart
# tetep : tetep
# nyambung : nyambung
# otak : otak
# anjing : anjing
# nyolong : nyolong
# uang : uang
# deposit : deposit
# dibalikin : dibalikin
# saranku : saran
# padang : padang
# pas : pas
# dibayar : bayar
# pemutusan : putus
# pemakaian : pakai
# terakir : terakir
# bawa : bawa
# skalian : skalian
# modemnya : modem
# karna : karna
# skrng : skrng
# teknis : teknis
# yangbdtang : yangbdtang
# kemarin : kemarin
# kadang : kadang
# limited : limited
# pon : pon
# warna : warna
# merah : merah
# lepas : lepas
# pasang : pasang
# kabel : kabel
# patchcord : patchcord
# inet : inet
# inbox : inbox
# manado : manado
# kantor : kantor
# konfirmasi : konfirmasi
# akn : akn
# pengecekan : kece
# dikit : dikit
# ngelag : ngelag
# pulsa : pulsa
# kwalitas : kwalitas
# pertahankan : tahan
# sudh : sudh
# internet : internet
# message : message
# kirimkan : kirim
# komplain : komplain
# makasih : makasih
# solusinya : solusi
# mengalami : alami
# berlangganan : langgan
# mati : mati
# pagi : pagi
# duh : duh
# medan : medan
# lost : lost
# connect : connect
# semalam : malam
# work : work
# bangett : bangett
# semarang : semarang
# slot : slot
# jateng : jateng
# kudus : kudus
# banyakin : banyakin
# msa : msa
# bsa : bsa
# area : area
# kota : kota
# postingan : postingan
# bermanfaat : manfaat
# lapor : lapor
# eror : eror
# diprobolinggo : diprobolinggo
# loss : loss
# iklan : iklan
# gratis : gratis
# status : status
# update : update
# pakai : pakai
# internetnya : internetnya
# membanggakan : bangga
# siang : siang
# pembayaran : bayar
# linkaja : linkaja
# cashback : cashback
# kah : kah
# odpnya : odpnya
# penuh : penuh
# odp : odp
# rumah : rumah
# bkn : bkn
# banget : banget
# panduannya : pandu
# respon : respon
# pesan : pesan
# stabil : stabil
# bantuan : bantu
# dear : dear
# setia : setia
# info : info
# syarat : syarat
# biaya : biaya
# upgrade : upgrade
# wms : wms
# mbps : mbps
# banjarnegara : banjarnegara
# trimakasih : trimakasih
# parah : parah
# cuman : cuman
# sayang : sayang
# sampe : sampe
# sore : sore
# total : total
# tindak : tindak
# halo : halo
# indiehome : indiehome
# pasng : pasng
# akses : akses
# lampu : lampu
# bolak : bolak
# perbaiki : baik
# ttp : ttp
# kerusakan : rusa
# perhatikan : perhati
# masala : masala
# kali : kali
# website : website
# keterangan : terang
# web : web
# dibiarkan : biar
# permintaan : minta
# close : close
# akhi : akh
# didaftar : daftar
# register : register
# instalasi : instalasi
# bantuannya : bantu
# pelaksanaan : laksana
# spot : spot
# bilangnya : bilang
# kebijakan : bijak
# minggu : minggu
# tindakan : tindak
# maaf : maaf
# nanya : nanya
# bgaimana : bgaimana
# mengamankan : aman
# kode : kode
# gampang : gampang
# bobol : bobol
# malan : malan
# semenjak : semenjak
# terima : terima
# isinya : isi
# selamat : selamat
# indohome : indohome
# agustus : agustus
# pelanggan : langgan
# aktif : aktif
# tlp : tlp
# indi : indi
# ngak : ngak
# renew : renew
# speed : speed
# depositnya : deposit
# dikembalikan : kembali
# suruh : suruh
# denda : denda
# pengakhiran : akhir
# mikir : mikir
# ajh : ajh
# jt : jt
# pelanggannya : langgan
# keberatan : berat
# dipakai : pakai
# berjalan : jalan
# lola : lola
# ane : ane
# dibilang : bilang
# daerahnya : daerah
# macem : macem
# jalan : jalan
# raya : raya
# wib : wib
# browsing : browsing
# signal : signal
# daftar : daftar
# wilayah : wilayah
# gempol : gempol
# pusakanagara : pusakanagara
# subang : subang
# smpe : smpe
# blom : blom
# kaga : kaga
# kejelasan : jelas
# dri : dri
# gua : gua
# kemaren : kemaren
# terdeteksi : deteksi
# nama : nama
# komplen : komplen
# dijanjiin : dijanjiin
# dtg : dtg
# tungguin : tungguin
# angsuran : angsur
# diperbarui : baru
# knp : knp
# pelayanan : layan
# direspon : direspon
# anak : anak
# jln : jln
# nokilalaki : nokilalaki
# pendek : pendek
# ditambah : tambah
# ngurangin : ngurangin
# jenis : jenis
# langgganannya : langgganannya
# kayak : kayak
# berhenti : henti
# usee : usee
# aplikasi : aplikasi
# langganan : langgan
# low : low
# fup : fup
# capek : capek
# terusss : terusss
# oke : oke
# praktekan : praktek
# care : care
# tigabulan : tigabulan
# speetes : speetes
# dapatnya : dapat
# dirugikan : rugi
# bacaan : baca
# los : los
# kedip : kedip
# kmrn : kmrn
# bulanannya : bulan
# arep : arep
# password : password
# mbah : mbah
# tunggu : tunggu
# alasanya : alasanya
# jakarta : jakarta
# barat : barat
# kalideres : kalideres
# sring : sring
# nyaman : nyaman
# modem : modem
# inboknya : inboknya
# boss : boss
# dirumah : rumah
# bermasalah : masalah
# sehari : hari
# lancar : lancar
# hilang : hilang
# hilangan : hilang
# sesuai : sesuai
# ambil : ambil
# pilih : pilih
# informasinya : informasi
# membantu : bantu
# save : save
# inbok : inbok
# tombol : tombol
# off : off
# perubahan : ubah
# jumat : jumat
# kena : kena
# gamas : gamas
# kacaaau : kacaaau
# abis : abis
# sabtu : sabtu
# skrang : skrang
# senin : senin
# gilaa : gilaa
# pdahal : pdahal
# slmat : slmat
# malammin : malammin
# melapor : lapor
# nyalakan : nyala
# liat : liat
# dblkg : dblkg
# blkg : blkg
# membangun : bangun
# optik : optik
# dindinh : dindinh
# rumahnya : rumah
# gmn : gmn
# proses : proses
# sekedar : dar
# alfamart : alfamart
# indomaret : indomaret
# telpon : telpon
# harga : harga
# perbulannya : bulan
# nambah : nambah
# paseban : paseban
# bener : bener
# malam : malam
# vip : vip
# gimna : gimna
# terputus : putus
# tulisan : tulis
# timbul : timbul
# routernya : routernya
# subuh : subuh
# pekanbaru : pekanbaru
# riau : riau
# panam : panam
# memasang : pasang
# brpa : brpa
# langsung : langsung
# zte : zte
# jga : jga
# kmrin : kmrin
# kirain : kirain
# bsoknya : bsoknya
# bnr : bnr
# tnyata : tnyata
# lengkap : lengkap
# terpasang : pasang
# ditinggal : tinggal
# besok : besok
# kerja : kerja
# maksudnya : maksud
# seharian : hari
# berantakan : beranta
# ngedrop : ngedrop
# promo : promo
# normal : normal
# lgi : lgi
# naikan : naik
# sangsi : sangsi
# informationnya : informationnya
# kosong : kosong
# bambang : bambang
# nggak : nggak
# uda : uda
# tehnisi : tehnisi
# diwilayah : wilayah
# jaringa : jaringa
# kesini : kesini
# sinyal : sinyal
# mobat : mobat
# mabitt : mabitt
# asalamualikum : asalamualikum
# kuotanya : kuota
# brapa : brapa
# you : you
# tube : tube
# conect : conect
# hobiku : hobi
# bgmn : bgmn
# spy : spy
# lbh : lbh
# sekian : sekian
# belas : belas
# menit : menit
# kesal : kesal
# seamless : seamless
# maksimal : maksimal
# keknya : kek
# komplek : komplek
# murah : murah
# tdi : tdi
# yaaaak : yaaaak
# hri : hri
# msih : msih
# pmasangan : pmasangan
# stiap : stiap
# tnya : tnya
# jawabannya : jawab
# mnunggu : mnunggu
# follow : follow
# sudaj : sudaj
# dlam : dlam
# teruskan : terus
# tim : tim
# terkait : kait
# ribu : ribu
# rinciannya : rinciannya
# dikasi : kasi
# kasian : kasi
# kaget : kaget
# penjelasa : jasa
# autoreply : autoreply
# ngabbb : ngabbb
# router : router
# lupa : lupa
# diatas : atas
# dodol : dodol
# dikomentarin : dikomentarin
# aduh : aduh
# indibini : indibini
# paing : paing
# bxa : bxa
# assalamualaikum : assalamualaikum
# kamiada : kamiada
# keluhan : keluh
# jaringn : jaringn
# lab : lab
# komputer : komputer
# kerusakn : kerusakn
# petunjuk : tunjuk
# skb : skb
# lampunga : lampunga
# utara : utara
# diperbaiki : baik
# servicenya : servicenya
# segini : gin
# hasilnya : hasil
# kompensasi : kompensasi
# keruugian : keruugian
# customer : customer
# maunya : mau
# untung : untung
# untuungg : untuungg
# baeee : baeee
# kereeen : kereeen
# ajukan : aju
# bantu : bantu
# sll : sll
# klu : klu
# telp : telp
# mengadukan : adu
# hny : hny
# mengirim : kirim
# laptop : laptop
# seka : seka
# bpk : bpk
# youtube : youtube
# lemot : lot
# bagus : bagus
# tgl : tgl
# brp : brp
# batas : batas
# paketnya : paket
# berhubung : hubung
# org : org
# berkurang : kurang
# ktnya : ktnya
# lapangan : lapang
# dateng : dateng
# lapangannya : lapang
# bingung : bingung
# betulin : betulin
# gassal : gassal
# masal : masal
# hrsnya : hrsnya
# bnyk : bnyk
# pelayanannya : layan
# keseringan : sering
# error : error
# bafug : bafug
# suami : suami
# ngomel : ngomel
# wfh : wfh
# butuh : butuh
# langkah : langkah
# wrong : wrong
# use : use
# meme : meme
# gara : gara
# diupdate : diupdate
# korban : korban
# saldo : saldo
# kepotong : potong
# muncul : muncul
# disuruh : suruh
# smp : smp
# terisolir : isolir
# dikerjain : dikerjain
# palingan : paling
# hbs : hbs
# komen : komen
# dblg : dblg
# dihub : dihub
# jutaan : juta
# ogah : ogah
# sinyalnya : sinyal
# trus : trus
# terkendala : kendala
# melalu : lalu
# lan : lan
# terkoneksi : koneksi
# bantuannyah : bantuannyah
# dibikin : bikin
# kesel : kesel
# app : app
# gagal : gagal
# mulu : mulu
# giliran : gilir
# mantap : mantap
# tsb : tsb
# berubah : ubah
# bln : bln
# pengertiannya : erti
# daring : daring
# perhatiannya : perhati
# ucapkan : ucap
# kasih : kasih
# tempatku : tempat
# dipasangi : pasang
# gmna : gmna
# ngaktifin : ngaktifin
# berkali : kali
# habiskan : habis
# petugasnya : tugas
# seminggu : minggu
# juli : juli
# penambahan : tambah
# pusat : pusat
# mengiirimkan : mengiirimkan
# supplier : supplier
# terebut : rebut
# pela : pela
# cabut : cabut
# rumh : rumh
# bppn : bppn
# gegara : gegara
# pulak : pulak
# ujung : ujung
# data : data
# celuler : celuler
# indikator : indikator
# smua : smua
# konek : konek
# mnonaktifkan : mnonaktifkan
# add : add
# combo : combo
# sport : sport
# skrg : skrg
# apkh : apkh
# sept : sept
# hrs : hrs
# membayar : bayar
# cut : cut
# tivi : tivi
# gambarnya : gambar
# lmbat : lmbat
# bngt : bngt
# pdh : pdh
# byar : byar
# myindihomenya : myindihomenya
# byr : byr
# hdeuh : hdeuh
# selamay : selamay
# phoenix : phoenix
# bulanan : bulan
# benerin : benerin
# alhasil : alhasil
# ampe : ampe
# hadehhh : hadehhh
# nomor : nomor
# ngga : ngga
# pdhal : pdhal
# restar : restar
# bbrapa : bbrapa
# sebentar : sebentar
# ditindak : tindak
# lanjuti : lanjut
# bos : bos
# jagakarsa : jagakarsa
# down : down
# wfi : wfi
# bebas : bebas
# chat : chat
# direstart : direstart
# kencang : kencang
# home : home
# leletnya : lelet
# ampun : ampun
# loading : loading
# remot : remot
# stb : stb
# rusak : rusak
# diganti : ganti
# port : port
# cepet : cepet
# minum : minum
# vegeta : vegeta
# makan : makan
# pepaya : pepaya
# lihat : lihat
# lag : lag
# ketulung : ketulung
# valid : valid
# efek : efek
# alah : alah
# bacot : bacot
# juni : juni
# dirampok : rampok
# solusi : solusi
# tekankan : tekan
# upload : upload
# file : file
# materi : materi
# meeting : meeting
# emosi : emosi
# tolol : tolol
# ganguang : ganguang
# tmasal : tmasal
# teroz : teroz
# lncar : lncar
# telepon : telepon
# puas : puas
# silahkan : silah
# kecewa : kecewa
# telat : telat
# kejahatan : jahat
# percaya : percaya
# buka : buka
# isolir : isolir
# susah : susah
# jaman : jaman
# penjajahan : jajah
# eth : eth
# lampunya : lampu
# punyaku : punya
# mbs : mbs
# tabahin : tabahin
# cepat : cepat
# kog : kog
# jelek : jelek
# tagihannya : tagih
# diakses : akses
# jaminan : jamin
# direfund : direfund
# tanggapannya : tanggap
# semoga : moga
# malamm : malamm
# minn : minn
# lom : lom
# pasword : pasword
# direstat : direstat
# internetx : internetx
# responx : responx
# sich : sich
# menghubungi : hubung
# csnya : csnya
# bbrp : bbrp
# registrasi : registrasi
# kug : kug
# dipakek : dipakek
# pakett : pakett
# udahan : udahan
# syaratnya : syarat
# thebest : thebest
# infonya : info
# gan : gan
# jaya : jaya
# bales : bales
# yaa : yaa
# kedap : kedap
# aman : aman
# punten : punten
# atuh : atuh
# mba : mba
# prosedur : prosedur
# jamannya : jaman
# setoran : setor
# berat : berat
# gitu : gitu
# lagii : lagi
# dibhubungi : dibhubungi
# balasan : balas
# urus : urus
# kerjaan : kerja
# terbangkalai : terbangkalai
# bosen : bosen
# bro : bro
# kendala : kendala
# apapun : apa
# ribet : ribet
# pke : pke
# njelasinnya : njelasinnya
# nnya : nnya
# box : box
# losnya : los
# nyalah : nyalah
# deh : deh
# usaha : usaha
# merugikan : rugi
# alamat : alamat
# telfon : telfon
# ganguan : ganguan
# kerumah : rumah
# bersaing : saing
# konsumen : konsumen
# membutuhkan : butuh
# progress : progress
# tggu : tggu
# ditempat : tempat
# yoututbe : yoututbe
# tifak : tifak
# dibantu : bantu
# ngembalikan : ngembalikan
# mksi : mksi
# kebanyakan : banyak
# dlu : dlu
# mahluk : mahluk
# perngkat : perngkat
# bot : bot
# brengsek : brengsek
# sialan : sial
# emang : emang
# dimonopoli : monopoli
# stel : stel
# siaran : siar
# trans : trans
# moto : moto
# permisi : permisi
# berwarna : warna
# pisangan : pisang
# matraman : matraman
# ditanggapi : tanggap
# shubuh : shubuh
# streaming : streaming
# mola : mola
# beku : beku
# mintol : mintol
# jaringannya : jaring
# bagusin : bagusin
# woy : woy
# ajalah : aja
# utamakan : utama
# bosss : bosss
# nilai : nilai
# nol : nol
# tanjung : tanjung
# enim : enim
# sumatra : sumatra
# selatan : selatan
# dibtn : dibtn
# mandala : mandala
# tpi : tpi
# nunggak : nunggak
# dibuka : buka
# yukk : yukk
# pom : pom
# semalem : semalem
# nihhh : nihhh
# menyala : nyala
# untk : untk
# kerumh : kerumh
# sumurbor : sumurbor
# diprogress : diprogress
# ibadah : ibadah
# online : online
# lamou : lamou
# mksudnya : mksudnya
# kecepatan : cepat
# idup : idup
# datengin : datengin
# mantapp : mantapp
# berhasil : hasil
# smart : smart
# tethering : tethering
# smartfren : smartfren
# muter : muter
# ckckck : ckckck
# ats : ats
# onis : onis
# assisten : assisten
# jarak : jarak
# meter : meter
# ndak : ndak
# komitmen : komitmen
# ehh : ehh
# cancel : cancel
# channelx : channelx
# dsuru : dsuru
# matikan : mati
# dst : dst
# donk : donk
# pemangan : mang
# alasan : alas
# skr : skr
# dsuruh : dsuruh
# kasi : kasi
# kek : kek
# lalang : lalang
# dfb : dfb
# ajuakan : ajuakan
# kpelosok : kpelosok
# negri : negri
# fair : fair
# mudah : mudah
# singkatannya : singkat
# ditetapkan : tetap
# pengurangan : kurang
# kuota : kuota
# dipilih : pilih
# penurunan : turun
# bismillah : bismillah
# biznet : biznet
# teralokasi : alokasi
# samarinda : samarinda
# nda : nda
# laku : laku
# bayaran : bayar
# ulala : ulala
# indidongdong : indidongdong
# offline : offline
# dibenerin : dibenerin
# tukang : tukang
# selang : selang
# iuran : iur
# numpuk : numpuk
# gra : gra
# hebat : hebat
# otomatis : otomatis
# harian : hari
# dapet : dapet
# segitu : segitu
# tarif : tarif
# rb : rb
# kenaikan : naik
# operator : operator
# itikad : itikad
# memperbaiki : baik
# persyaratannya : syarat
# barusan : barusan
# spam : spam
# akun : akun
# berisi : isi
# penawaran : tawar
# indibox : indibox
# diterakan : tera
# disengaja : sengaja
# terpencet : pencet
# tagi : tagi
# berlaku : laku
# resmi : resmi
# penangan : nang
# hati : hati
# penanganan : tangan
# ama : ama
# inih : inih
# thn : thn
# alasannya : alas
# aneh : aneh
# kurleb : kurleb
# padurenan : padurenan
# malu : malu
# prshn : prshn
# open : open
# donasi : donasi
# bangkrut : bangkrut
# kyknya : kyknya
# server : server
# perbulan : bulan
# buruk : buruk
# jual : jual
# kasihlah : kasih
# lucu : lucu
# tiang : tiang
# listrik : listrik
# nolak : nolak
# rezeki : rezeki
# sorry : sorry
# oot : oot
# download : download
# dimana : mana
# spedd : spedd
# ken : ken
# rin : rin
# mari : mari
# bay : bay
# tag : tag
# gihan : gihan
# atanya : atanya
# napa : napa
# aktifnya : aktif
# lamaaa : lamaaa
# beda : beda
# aktifkan : aktif
# sped : sped
# demon : demon
# demand : demand
# milih : milih
# kecepatannya : cepat
# mpbs : mpbs
# bukti : bukti
# short : short
# resolusinya : resolusi
# bagusan : bagus
# resolusi : resolusi
# hitam : hitam
# putih : putih
# ajg : ajg
# dech : dech
# pertimbangkan : timbang
# giga : giga
# wih : wih
# kencangnya : kencang
# binasa : binasa
# rahasianya : rahasia
# bumn : bumn
# dibandingkan : banding
# selular : selular
# tlong : tlong
# kec : kec
# tenga : tenga
# minahasa : minahasa
# sulut : sulut
# mhn : mhn
# tambahin : tambahin
# bayangin : bayangin
# berbulan : bulan
# realisasi : realisasi
# biarkan : biar
# tali : tali
# jemuran : jemur
# baju : baju
# sampek : sampek
# penjelasannya : jelas
# terdaftar : daftar
# paketan : paket
# melonjak : lonjak
# channelnya : channelnya
# terbaru : baru
# support : support
# channel : channel
# turun : turun
# dikenakan : kena
# naiknya : naik
# taagihan : taagihan
# diposisi : posisi
# ceknya : cek
# hallo : hallo
# myid : myid
# produk : produk
# wihhhhhh : wihhhhhh
# pengen : ken
# hub : hub
# benas : benas
# plz : plz
# pengguna : guna
# speedy : speedy
# mautanya : mautanya
# menambah : tambah
# posisi : posisi
# paham : paham
# dab : dab
# berwajib : wajib
# penjualan : jual
# bom : bom
# kelar : kelar
# meresahkan : resah
# internetan : internetan
# fasilitas : fasilitas
# tks : tks
# hidup : hidup
# skali : skali
# jarang : jarang
# request : request
# ditelpon : telpon
# tinggal : tinggal
# {'blm': 'blm', 'petugas': 'tugas', 'dijanjikan': 'janji', 'jam': 'jam', '': '', 'cek': 'cek', 'laporan': 'lapor', 'balesan': 'balesan', 'gimana': 'gimana', 'ngatasi': 'ngatasi', 'login': 'login', 'fail': 'fail', 'please': 'please', 'try': 'try', 'again': 'again', 'later': 'later', 'pusing': 'pusing', 'admin': 'admin', 'tolong': 'tolong', 'pemasangan': 'pasang', 'wifinya': 'wifinya', 'lambat': 'lambat', 'menunggu': 'tunggu', 'beum': 'beum', 'teknisi': 'teknisi', 'nelfon': 'nelfon', 'nunggu': 'nunggu', 'doang': 'doang', 'masang': 'masang', 'coba': 'coba', 'cari': 'cari', 'wifi': 'wifi', 'mohon': 'mohon', 'informasi': 'informasi', 'layanan': 'layan', 'iflix': 'iflix', 'kesulitan': 'sulit', 'subtitle': 'subtitle', 'bahasa': 'bahasa', 'indonesia': 'indonesia', 'film': 'film', 'drama': 'drama', 'korea': 'korea', 'sebulan': 'bulan', 'pdhl': 'pdhl', 'msh': 'msh', 'tersedia': 'sedia', 'terimakasih': 'terimakasih', 'gini': 'gin', 'indihumu': 'indihumu', 'koneksi': 'koneksi', 'putus': 'putus', 'daerah': 'daerah', 'timur': 'timur', 'ganti': 'ganti', 'provider': 'provider', 'masuk': 'masuk', 'sumpah': 'sumpah', 'mending': 'mending', 'tutup': 'tutup', 'kasihan': 'kasihan', 'ppkm': 'ppkm', 'bayar': 'bayar', 'mahal': 'mahal', 'kualitas': 'kualitas', 'sampah': 'sampah', 'ping': 'ping', 'google': 'google', 'pemirsa': 'pirsa', 'kak': 'kak', 'pindah': 'pindah', 'lokasi': 'lokasi', 'intalasi': 'intalasi', 'jaringan': 'jaring', 'telkom': 'telkom', 'berusaha': 'usaha', 'mengajak': 'ajak', 'tetangga': 'tetangga', 'mengajukan': 'aju', 'plaza': 'plaza', 'ngawi': 'ngawi', 'konfirma': 'konfirma', 'pengaduan': 'adu', 'skarang': 'skarang', 'kabarnya': 'kabar', 'myindihome': 'myindihome', 'tagihan': 'tagih', 'milik': 'milik', 'full': 'full', 'dibantukah': 'bantu', 'udah': 'udah', 'pengajuan': 'aju', 'perpindahan': 'pindah', 'paket': 'paket', 'datanya': 'data', 'kirim': 'kirim', 'via': 'via', 'sms': 'sms', 'email': 'email', 'pesannya': 'pesan', 'pengaduano': 'pengaduano', 'nyala': 'nyala', 'duit': 'duit', 'internetku': 'internetku', 'terhubung': 'hubung', 'tanda': 'tanda', 'drmh': 'drmh', 'sya': 'sya', 'gangguan': 'ganggu', 'wil': 'wil', 'banyumas': 'banyumas', 'lol': 'lol', 'min': 'min', 'indihome': 'indihome', 'berguna': 'guna', 'device': 'device', 'nonton': 'nonton', 'acara': 'acara', 'suka': 'suka', 'stop': 'stop', 'biarain': 'biarain', 'hasil': 'hasil', 'what': 'what', 'lying': 'lying', 'udh': 'udh', 'restart': 'restart', 'tetep': 'tetep', 'nyambung': 'nyambung', 'otak': 'otak', 'anjing': 'anjing', 'nyolong': 'nyolong', 'uang': 'uang', 'deposit': 'deposit', 'dibalikin': 'dibalikin', 'saranku': 'saran', 'padang': 'padang', 'pas': 'pas', 'dibayar': 'bayar', 'pemutusan': 'putus', 'pemakaian': 'pakai', 'terakir': 'terakir', 'bawa': 'bawa', 'skalian': 'skalian', 'modemnya': 'modem', 'karna': 'karna', 'skrng': 'skrng', 'teknis': 'teknis', 'yangbdtang': 'yangbdtang', 'kemarin': 'kemarin', 'kadang': 'kadang', 'limited': 'limited', 'pon': 'pon', 'warna': 'warna', 'merah': 'merah', 'lepas': 'lepas', 'pasang': 'pasang', 'kabel': 'kabel', 'patchcord': 'patchcord', 'inet': 'inet', 'inbox': 'inbox', 'manado': 'manado', 'kantor': 'kantor', 'konfirmasi': 'konfirmasi', 'akn': 'akn', 'pengecekan': 'kece', 'dikit': 'dikit', 'ngelag': 'ngelag', 'pulsa': 'pulsa', 'kwalitas': 'kwalitas', 'pertahankan': 'tahan', 'sudh': 'sudh', 'internet': 'internet', 'message': 'message', 'kirimkan': 'kirim', 'komplain': 'komplain', 'makasih': 'makasih', 'solusinya': 'solusi', 'mengalami': 'alami', 'berlangganan': 'langgan', 'mati': 'mati', 'pagi': 'pagi', 'duh': 'duh', 'medan': 'medan', 'lost': 'lost', 'connect': 'connect', 'semalam': 'malam', 'work': 'work', 'bangett': 'bangett', 'semarang': 'semarang', 'slot': 'slot', 'jateng': 'jateng', 'kudus': 'kudus', 'banyakin': 'banyakin', 'msa': 'msa', 'bsa': 'bsa', 'area': 'area', 'kota': 'kota', 'postingan': 'postingan', 'bermanfaat': 'manfaat', 'lapor': 'lapor', 'eror': 'eror', 'diprobolinggo': 'diprobolinggo', 'loss': 'loss', 'iklan': 'iklan',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/335 [00:00<?, ?it/s]
#                                                comment  \
# 0    kok blm datang petugas ? dijanjikan jam 8, sek...
# 1            cek dm dong mau laporan tp ga ada balesan
# 2    gimana ngatasi "login fail,please try again la...
# 3    admin tolong, pemasangan wifinya jangan lambat...
# 4    ..mohon informasi, untuk layanan iflix saya ke...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas di ind...
# 353  gmn klo stb tdk hidup sm skali.. pdhl jarang d...
# 354  nmr indihome saya 1723 0240 7998. saya request...
# 355                                  selamat siang ka.
# 356  udah 3 hari belum bisa di gunakan padahal suda...
#
#                                       cleaning_comment  \
# 0      kok blm datang petugas dijanjikan jam sekarang
# 1                     cek dong mau laporan ada balesan
# 2    gimana ngatasi login fail please try again lat...
# 3    admin tolong pemasangan wifinya jangan lambat ...
# 4     mohon informasi untuk layanan iflix saya kesu...
# ..                                                 ...
# 352  apa selain internetan apa ada fasilitas indiho...
# 353     gmn klo stb tdk hidup skali pdhl jarang hidup
# 354  nmr indihome saya       saya request lewat app...
# 355                                     selamat siang
# 356  udah hari belum bisa gunakan padahal sudah bay...
#
#                                             tokenisasi  \
# 0    [kok, blm, datang, petugas, dijanjikan, jam, s...
# 1              [cek, dong, mau, laporan, ada, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pemasangan, wifinya, jangan, l...
# 4    [, mohon, informasi, untuk, layanan, iflix, sa...
# ..                                                 ...
# 352  [apa, selain, internetan, apa, ada, fasilitas,...
# 353  [gmn, klo, stb, tdk, hidup, skali, pdhl, jaran...
# 354  [nmr, indihome, saya, saya, request, lewat, ap...
# 355                                 [selamat, siang, ]
# 356  [udah, hari, belum, bisa, gunakan, padahal, su...
#
#                                               stopword  \
# 0                    [blm, petugas, dijanjikan, jam, ]
# 1                              [cek, laporan, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pemasangan, wifinya, lambat, m...
# 4    [, mohon, informasi, layanan, iflix, kesulitan...
# ..                                                 ...
# 352           [internetan, fasilitas, indihome, tks, ]
# 353    [gmn, stb, hidup, skali, pdhl, jarang, hidup, ]
# 354  [indihome, request, app, sabtu, pagi, speed, l...
# 355                                 [selamat, siang, ]
# 356                        [udah, bayar, mohon, bantu]
#
#                                               stemming
# 0                           [blm, tugas, janji, jam, ]
# 1                                [cek, lapor, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pasang, wifinya, lambat, tungg...
# 4    [, mohon, informasi, layan, iflix, sulit, subt...
# ..                                                 ...
# 352           [internetan, fasilitas, indihome, tks, ]
# 353    [gmn, stb, hidup, skali, pdhl, jarang, hidup, ]
# 354  [indihome, request, app, sabtu, pagi, speed, l...
# 355                                 [selamat, siang, ]
# 356                        [udah, bayar, mohon, bantu]
#
# [335 rows x 5 columns]

# %%
Final = df[['stemming']]
Final = Final.rename(columns={'stemming':'comment'})

# %%
Final
# Out:
#                                                comment
# 0                           [blm, tugas, janji, jam, ]
# 1                                [cek, lapor, balesan]
# 2    [gimana, ngatasi, login, fail, please, try, ag...
# 3    [admin, tolong, pasang, wifinya, lambat, tungg...
# 4    [, mohon, informasi, layan, iflix, sulit, subt...
# ..                                                 ...
# 352           [internetan, fasilitas, indihome, tks, ]
# 353    [gmn, stb, hidup, skali, pdhl, jarang, hidup, ]
# 354  [indihome, request, app, sabtu, pagi, speed, l...
# 355                                 [selamat, siang, ]
# 356                        [udah, bayar, mohon, bantu]
#
# [335 rows x 1 columns]

# %%
Final.to_excel('databersih_facebook_indihome_8.xlsx')
